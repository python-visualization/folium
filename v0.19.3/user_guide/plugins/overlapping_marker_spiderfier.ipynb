# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e67fbccc9aed7e8d460b8eeb554b1e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e67fbccc9aed7e8d460b8eeb554b1e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e67fbccc9aed7e8d460b8eeb554b1e4 = L.map(
#                 &quot;map_1e67fbccc9aed7e8d460b8eeb554b1e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c61be7e14550d24e29e9ce2d39f84b64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c61be7e14550d24e29e9ce2d39f84b64.addTo(map_1e67fbccc9aed7e8d460b8eeb554b1e4);
#
#
#             var marker_b22b2af8d5565aa97d9417280170f09b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1e67fbccc9aed7e8d460b8eeb554b1e4);
#
#
#         var popup_9caa4fad82b9ccfbd9f91623ec0313a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ebfadf1126c9614b29219380991423c = $(`&lt;div id=&quot;html_5ebfadf1126c9614b29219380991423c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9caa4fad82b9ccfbd9f91623ec0313a9.setContent(html_5ebfadf1126c9614b29219380991423c);
#
#
#
#         marker_b22b2af8d5565aa97d9417280170f09b.bindPopup(popup_9caa4fad82b9ccfbd9f91623ec0313a9)
#         ;
#
#
#
#
#             var marker_1306b02b506fc675b9e29e63fce40b49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1e67fbccc9aed7e8d460b8eeb554b1e4);
#
#
#         var popup_7438e4e3f279faf4e95da0fd24206e90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb59fe0eb3c2b487a38377b75d6c2b25 = $(`&lt;div id=&quot;html_eb59fe0eb3c2b487a38377b75d6c2b25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7438e4e3f279faf4e95da0fd24206e90.setContent(html_eb59fe0eb3c2b487a38377b75d6c2b25);
#
#
#
#         marker_1306b02b506fc675b9e29e63fce40b49.bindPopup(popup_7438e4e3f279faf4e95da0fd24206e90)
#         ;
#
#
#
#
#             var marker_2b506c9436204bcc5ba3b4ad29686336 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1e67fbccc9aed7e8d460b8eeb554b1e4);
#
#
#         var popup_680148a2415e31efa781b4056c24e9e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7a4941ac9957f7de54263382ea4e258 = $(`&lt;div id=&quot;html_c7a4941ac9957f7de54263382ea4e258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_680148a2415e31efa781b4056c24e9e6.setContent(html_c7a4941ac9957f7de54263382ea4e258);
#
#
#
#         marker_2b506c9436204bcc5ba3b4ad29686336.bindPopup(popup_680148a2415e31efa781b4056c24e9e6)
#         ;
#
#
#
#
#             var marker_710b893fdff6033db322646f1d05d690 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1e67fbccc9aed7e8d460b8eeb554b1e4);
#
#
#         var popup_cd54564cd85043734697df3b7a215d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_181a36d3a282e087026aeaf162bc336a = $(`&lt;div id=&quot;html_181a36d3a282e087026aeaf162bc336a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cd54564cd85043734697df3b7a215d78.setContent(html_181a36d3a282e087026aeaf162bc336a);
#
#
#
#         marker_710b893fdff6033db322646f1d05d690.bindPopup(popup_cd54564cd85043734697df3b7a215d78)
#         ;
#
#
#
#
#             var marker_9ccb009455052787adf8ebd4bf706cfe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1e67fbccc9aed7e8d460b8eeb554b1e4);
#
#
#         var popup_f49ff4ce7075a04fcd0f36d31af349c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94566d3815b7944926645cf26a35ab79 = $(`&lt;div id=&quot;html_94566d3815b7944926645cf26a35ab79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f49ff4ce7075a04fcd0f36d31af349c5.setContent(html_94566d3815b7944926645cf26a35ab79);
#
#
#
#         marker_9ccb009455052787adf8ebd4bf706cfe.bindPopup(popup_f49ff4ce7075a04fcd0f36d31af349c5)
#         ;
#
#
#
#
#             var marker_ffc0b92a7c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2ddc501c279a5a63ee04af11516ead5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2ddc501c279a5a63ee04af11516ead5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2ddc501c279a5a63ee04af11516ead5 = L.map(
#                 &quot;map_a2ddc501c279a5a63ee04af11516ead5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34f80767e59333a3998b983a9c304d89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34f80767e59333a3998b983a9c304d89.addTo(map_a2ddc501c279a5a63ee04af11516ead5);
#
#
#             var feature_group_bdf89818c5b60988339f1dcaa62c5d5a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_235577d7efbd38e912392a7dcbb145a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bdf89818c5b60988339f1dcaa62c5d5a);
#
#
#         var popup_a6ef36991fe9f1c5d3b709a3ec553c98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7252a601ac94447800ffa35a7bfc5e4 = $(`&lt;div id=&quot;html_c7252a601ac94447800ffa35a7bfc5e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a6ef36991fe9f1c5d3b709a3ec553c98.setContent(html_c7252a601ac94447800ffa35a7bfc5e4);
#
#
#
#         marker_235577d7efbd38e912392a7dcbb145a3.bindPopup(popup_a6ef36991fe9f1c5d3b709a3ec553c98)
#         ;
#
#
#
#
#             var marker_3f03b994ed8f2607d929c7c14e230784 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bdf89818c5b60988339f1dcaa62c5d5a);
#
#
#         var popup_6ea1377c166000cc0d6d6c52600e6b19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_197a02ee12ed8fed4fce4384920a3c1c = $(`&lt;div id=&quot;html_197a02ee12ed8fed4fce4384920a3c1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6ea1377c166000cc0d6d6c52600e6b19.setContent(html_197a02ee12ed8fed4fce4384920a3c1c);
#
#
#
#         marker_3f03b994ed8f2607d929c7c14e230784.bindPopup(popup_6ea1377c166000cc0d6d6c52600e6b19)
#         ;
#
#
#
#
#             var marker_d9d9a7cbdebc344a7bd5e7ac033d2159 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bdf89818c5b60988339f1dcaa62c5d5a);
#
#
#         var popup_e4cc6b10d21e23e4b26398b78568ef3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_910aad6f5d296602f2508b2c461e6de7 = $(`&lt;div id=&quot;html_910aad6f5d296602f2508b2c461e6de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e4cc6b10d21e23e4b26398b78568ef3c.setContent(html_910aad6f5d296602f2508b2c461e6de7);
#
#
#
#         marker_d9d9a7cbdebc344a7bd5e7ac033d2159.bindPopup(popup_e4cc6b10d21e23e4b26398b78568ef3c)
#         ;
#
#
#
#
#             var marker_9527f740d2c35303f0b11681b24df882 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bdf89818c5b60988339f1dcaa62c5d5a);
#
#
#         var popup_48a85302b73f5cada188030ed7099d14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d4e39fdc80687f1bf84807b00a2fe71 = $(`&lt;div id=&quot;html_2d4e39fdc80687f1bf84807b00a2fe71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_48a85302b73f5cada188030ed7099d14.setContent(html_2d4e39fdc80687f1bf84807b00a2fe71);
#
#
#
#         marker_9527f740d2c35303f0b11681b24df882.bindPopup(popup_48a85302b73f5cada188030ed7099d14)
#         ;
#
#
#
#
#             var marker_23fb0818f7575745856cc66a623c458a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bdf89818c5b60988339f1dcaa62c5d5a);
#
#
#         var popup_7a31b6b1905bb74d8409ab3e486a0cb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba3dee106e5aab5747a284334b5b93f5 = $(`&lt;div id=&quot;html_ba3dee106e5aab5747a284334b5b93f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_7a31b6b1905bb74d84

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0268b187c67acc2989f58e191615966f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0268b187c67acc2989f58e191615966f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0268b187c67acc2989f58e191615966f = L.map(
#                 &quot;map_0268b187c67acc2989f58e191615966f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d7353dfd0848296f0bd219e8ae37882 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d7353dfd0848296f0bd219e8ae37882.addTo(map_0268b187c67acc2989f58e191615966f);
#
#
#             var feature_group_1e836a4762778360683582b99278be4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1e836a4762778360683582b99278be4c.addTo(map_0268b187c67acc2989f58e191615966f);
#
#
#             var feature_group_sub_group_be0db8477e2ede06b760ec91262054e3 = L.featureGroup.subGroup(
#                 feature_group_1e836a4762778360683582b99278be4c
#             );
#
#
#             var marker_4a346d8b98ae762f12b092d5c6c00140 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_be0db8477e2ede06b760ec91262054e3);
#
#
#         var popup_efeb8a9daae60352a9968887e5adb9f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e623e7d8bffae6b05ce25cb48da47e60 = $(`&lt;div id=&quot;html_e623e7d8bffae6b05ce25cb48da47e60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_efeb8a9daae60352a9968887e5adb9f3.setContent(html_e623e7d8bffae6b05ce25cb48da47e60);
#
#
#
#         marker_4a346d8b98ae762f12b092d5c6c00140.bindPopup(popup_efeb8a9daae60352a9968887e5adb9f3)
#         ;
#
#
#
#
#             var marker_26ad61deb1ff2c008741801f5c9b276a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_be0db8477e2ede06b760ec91262054e3);
#
#
#         var popup_8fda8b249733c8edd02bf649228985fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42e75b45d80849336a341b698611f541 = $(`&lt;div id=&quot;html_42e75b45d80849336a341b698611f541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8fda8b249733c8edd02bf649228985fb.setContent(html_42e75b45d80849336a341b698611f541);
#
#
#
#         marker_26ad61deb1ff2c008741801f5c9b276a.bindPopup(popup_8fda8b249733c8edd02bf649228985fb)
#         ;
#
#
#
#
#             var marker_ed68d2551db5cdcfd0fe05df6d270207 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_be0db8477e2ede06b760ec91262054e3);
#
#
#         var popup_bef661db306b1513039f0e5e19ab0bf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f79786088e4e0310278f89140957a7b0 = $(`&lt;div id=&quot;html_f79786088e4e0310278f89140957a7b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bef661db306b1513039f0e5e19ab0bf9.setContent(html_f79786088e4e0310278f89140957a7b0);
#
#
#
#         marker_ed68d2551db5cdcfd0fe05df6d270207.bindPopup(popup_bef661db306b1513039f0e5e19ab0bf9)
#         ;
#
#
#
#
#             var marker_d5ee093017949b62f9564cdac6f00644 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_be0db8477e2ede06b760ec91262054e3);
#
#
#         var popup_d54fa00d711a1a54c0bc0c378171d9b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e74600714acf0fe7753a71f9ab52e88 = $(`&lt;div id=&quot;html_7e74600714acf0fe7753a71f9ab52e88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d54fa00d711a1a54c0bc0c378171d9b8.setContent(html_7e74600714acf0fe7753a71f9ab52e88);
#
#
#
#         marker_d5ee093017949b62f9564cdac6f00644.bindPopup(popup_d54fa00d711a1a54c0bc0c378171d9b8)
#         ;
#
#
#
#
#             var marker_4aaec87b8b7b2e918b6f1cec3870ff73 = L.marker(
#                 [45.050399999999996, 3.0504],
