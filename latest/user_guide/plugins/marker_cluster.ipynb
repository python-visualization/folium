# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71656b8095765ef076d6729f652c5da4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71656b8095765ef076d6729f652c5da4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71656b8095765ef076d6729f652c5da4 = L.map(
#                 &quot;map_71656b8095765ef076d6729f652c5da4&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89a80649d13aaed37d891f00d7555f0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_89a80649d13aaed37d891f00d7555f0a.addTo(map_71656b8095765ef076d6729f652c5da4);
#
#
#             var marker_cluster_67a7582095fe4b723068164b1e5c369d = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7c60365af2802de90da28c6a97b38c4b = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_67a7582095fe4b723068164b1e5c369d);
#
#
#             var icon_acc77d4586e7fffd099429ac1ca45945 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c60365af2802de90da28c6a97b38c4b.setIcon(icon_acc77d4586e7fffd099429ac1ca45945);
#
#
#         var popup_68c68e4ea19158f6e16085059b965097 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_066f60b8888799136e0118899f515319 = $(`&lt;div id=&quot;html_066f60b8888799136e0118899f515319&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_68c68e4ea19158f6e16085059b965097.setContent(html_066f60b8888799136e0118899f515319);
#
#
#
#         marker_7c60365af2802de90da28c6a97b38c4b.bindPopup(popup_68c68e4ea19158f6e16085059b965097)
#         ;
#
#
#
#
#             var marker_04e73356d8f824a18e199dee1f85593a = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_67a7582095fe4b723068164b1e5c369d);
#
#
#             var icon_c2d73215ac6224fcc763c288afbe009f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_04e73356d8f824a18e199dee1f85593a.setIcon(icon_c2d73215ac6224fcc763c288afbe009f);
#
#
#         var popup_26bd21dfa03ae7ac970ce905d22ca846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1e6cdaf6c311a0f40a93b5bbe72f314 = $(`&lt;div id=&quot;html_d1e6cdaf6c311a0f40a93b5bbe72f314&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_26bd21dfa03ae7ac970ce905d22ca846.setContent(html_d1e6cdaf6c311a0f40a93b5bbe72f314);
#
#
#
#         marker_04e73356d8f824a18e199dee1f85593a.bindPopup(popup_26bd21dfa03ae7ac970ce905d22ca846)
#         ;
#
#
#
#
#             var marker_33a6516b01b03ed9c96d6cf5c92ca58d = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_67a7582095fe4b723068164b1e5c369d);
#
#
#         var popup_133eed7505700f6a30745aa243f83b10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47c5c938f2e34a9f5f1e056b5345fa33 = $(`&lt;div id=&quot;html_47c5c938f2e34a9f5f1e056b5345fa33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_133eed7505700f6a30745aa243f83b10.setContent(html_47c5c938f2e34a9f5f1e056b5345fa33);
#
#
#
#         marker_33a6516b01b03ed9c96d6cf5c92ca58d.bindPopup(popup_133eed7505700f6a30745aa243f83b10)
#         ;
#
#
#
#
#             marker_cluster_67a7582095fe4b723068164b1e5c369d.addTo(map_71656b8095765ef076d6729f652c5da4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0433ce83d8d4ecdb9453351e609824e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0433ce83d8d4ecdb9453351e609824e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0433ce83d8d4ecdb9453351e609824e = L.map(
#                 &quot;map_e0433ce83d8d4ecdb9453351e609824e&quot;,
#                 {
#                     center: [-0.37, -1.44],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04ad80a6d62f453fff56430aec896291 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_04ad80a6d62f453fff56430aec896291.addTo(map_e0433ce83d8d4ecdb9453351e609824e);
#
#
#             var marker_cluster_5adcf6f041a4d4e25b2db349693db537 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_5adcf6f041a4d4e25b2db349693db537.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_97040a55b04f7640f7de45f458efbbbc = L.marker(
#                 [15.0, 124.0],
#                 {}
#             ).addTo(marker_cluster_5adcf6f041a4d4e25b2db349693db537);
#
#
#         var popup_d880fa5b3f348a02e4985bee78a64bd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc224cca1fc4e57f06013d51eeb14cbb = $(`&lt;div id=&quot;html_fc224cca1fc4e57f06013d51eeb14cbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:124&lt;br&gt;lat:15&lt;/div&gt;`)[0];
#                 popup_d880fa5b3f348a02e4985bee78a64bd0.setContent(html_fc224cca1fc4e57f06013d51eeb14cbb);
#
#
#
#         marker_97040a55b04f7640f7de45f458efbbbc.bindPopup(popup_d880fa5b3f348a02e4985bee78a64bd0)
#         ;
#
#
#
#
#             var marker_5d5c407980313e033da98428435a704c = L.marker(
#                 [-54.0, 49.0],
#                 {}
#             ).addTo(marker_cluster_5adcf6f041a4d4e25b2db349693db537);
#
#
#         var popup_73a6a554005bdd56fc2ffa2e96c80d66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb23e0466051b0093e1e00ae2cbfb0b7 = $(`&lt;div id=&quot;html_bb23e0466051b0093e1e00ae2cbfb0b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:-54&lt;/div&gt;`)[0];
#                 popup_73a6a554005bdd56fc2ffa2e96c80d66.setContent(html_bb23e0466051b0093e1e00ae2cbfb0b7);
#
#
#
#         marker_5d5c407980313e033da98428435a704c.bindPopup(popup_73a6a554005bdd56fc2ffa2e96c80d66)
#         ;
#
#
#
#
#             var marker_88e3e5c72c32b3204bcd460b42089e6d = L.marker(
#                 [19.0, 75.0],
#                 {}
#             ).addTo(marker_cluster_5adcf6f041a4d4e25b2db349693db537);
#
#
#         var popup_60c05fc67c4d110115a7ce0c49287f99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f95bb551af42dd7badb072c587ba28a = $(`&lt;div id=&quot;html_1f95bb551af42dd7badb072c587ba28a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:75&lt;br&gt;lat:19&lt;/div&gt;`)[0];
#                 popup_60c05fc67c4d110115a7ce0c49287f99.setContent(html_1f95bb551af42dd7badb072c587ba28a);
#
#
#
#         marker_88e3e5c72c32b3204bcd460b42089e6d.bindPopup(popup_60c05fc67c4d110115a7ce0c49287f99)
#         ;
#
#
#
#
#             var marker_a66f9826d92c93a3655292d0361c9ae8 = L.marker(
#                 [33.0, -59.0],
#                 {}
#             ).addTo(marker_cluster_5adcf6f041a4d4e25b2db349693db537);
#
#
#         var popup_cc5cc003db78153b58ac46e639112431 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6f2b8faa0f54c8cd25712ae42ee74a3 = $(`&lt;div id=&quot;html_d6f2b8faa0f54c8cd25712ae42ee74a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-59&lt;br&gt;lat:33&lt;/div&gt;`)[0];
#                 popup_cc5cc003db78153b58ac46e639112431.setContent(html_d6f2b8faa0f54c8cd25712ae42ee74a3);
#
#
#
#         marker_a66f9826d92c93a36552

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed664cc82fbbb06071db5af0da29aed8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed664cc82fbbb06071db5af0da29aed8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed664cc82fbbb06071db5af0da29aed8 = L.map(
#                 &quot;map_ed664cc82fbbb06071db5af0da29aed8&quot;,
#                 {
#                     center: [-0.37, -1.44],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd814936f8e3a8d310fe76b64a19d4a3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dd814936f8e3a8d310fe76b64a19d4a3.addTo(map_ed664cc82fbbb06071db5af0da29aed8);
#
#
#             var marker_cluster_0ac8b8df31252f081d0f22bcf4c2012e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_47394be77cfcac2eb0390729f139a131 = L.marker(
#                 [15.0, 124.0],
#                 {}
#             ).addTo(marker_cluster_0ac8b8df31252f081d0f22bcf4c2012e);
#
#
#         var popup_d247e320136549b2dbada6c4e394c0f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2ddf8388e06bfdd751ebaa870079819 = $(`&lt;div id=&quot;html_f2ddf8388e06bfdd751ebaa870079819&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:124&lt;br&gt;lat:15&lt;/div&gt;`)[0];
#                 popup_d247e320136549b2dbada6c4e394c0f8.setContent(html_f2ddf8388e06bfdd751ebaa870079819);
#
#
#
#         marker_47394be77cfcac2eb0390729f139a131.bindPopup(popup_d247e320136549b2dbada6c4e394c0f8)
#         ;
#
#
#
#
#             var marker_e99f68715029b9b4c7fb2c9b710d2731 = L.marker(
#                 [-54.0, 49.0],
#                 {}
#             ).addTo(marker_cluster_0ac8b8df31252f081d0f22bcf4c2012e);
#
#
#         var popup_fb062d6fe1181babdade66a06ebbd0bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e662e5902228e37a412b9bbb06539aab = $(`&lt;div id=&quot;html_e662e5902228e37a412b9bbb06539aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:-54&lt;/div&gt;`)[0];
#                 popup_fb062d6fe1181babdade66a06ebbd0bc.setContent(html_e662e5902228e37a412b9bbb06539aab);
#
#
#
#         marker_e99f68715029b9b4c7fb2c9b710d2731.bindPopup(popup_fb062d6fe1181babdade66a06ebbd0bc)
#         ;
#
#
#
#
#             var marker_9a0e01eb806272ed66c96aacfefd20f7 = L.marker(
#                 [19.0, 75.0],
#                 {}
#             ).addTo(marker_cluster_0ac8b8df31252f081d0f22bcf4c2012e);
#
#
#         var popup_931de68fcfcdac1edb94191fb881d033 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d897950b4bb1b2f202c5abb11a37f86c = $(`&lt;div id=&quot;html_d897950b4bb1b2f202c5abb11a37f86c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:75&lt;br&gt;lat:19&lt;/div&gt;`)[0];
#                 popup_931de68fcfcdac1edb94191fb881d033.setContent(html_d897950b4bb1b2f202c5abb11a37f86c);
#
#
#
#         marker_9a0e01eb806272ed66c96aacfefd20f7.bindPopup(popup_931de68fcfcdac1edb94191fb881d033)
#         ;
#
#
#
#
#             var marker_18e9c05dd15a9cec259096767c7c0b4d = L.marker(
#                 [33.0, -59.0],
#                 {}
#             ).addTo(marker_cluster_0ac8b8df31252f081d0f22bcf4c2012e);
#
#
#         var popup_2fa489dc21a192844b3eed76a561feac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37430281143b890fb86e999cc5c843c3 = $(`&lt;div id=&quot;html_37430281143b890fb86e999cc5c843c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-59&lt;br&gt;lat:33&lt;/div&gt;`)[0];
#                 popup_2fa489dc21a192844b3eed76a561feac.setContent(html_37430281143b890fb86e999cc5c843c3);
#
#
#
#         marker_18e9c05dd15a9cec259096767c7c0b4d.bindPopup(popup_2fa489dc21a192844b3eed76a561feac)
#         ;
#
#
#
#
#             var marker_9cec5d34eaf1529e4a8648c178dc3fff = L.marker(
#                 [21.0, -30.0],
#                 {}
#             ).addTo(marker_cluster_0ac8b8df31252f081d0f22bcf4c2012e);
#
#
#         var popup_dd051eed3ac1f82a57f5e670fcf5

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4da7cd3ffe8b11c9b47cd792994f17b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4da7cd3ffe8b11c9b47cd792994f17b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4da7cd3ffe8b11c9b47cd792994f17b9 = L.map(
#                 &quot;map_4da7cd3ffe8b11c9b47cd792994f17b9&quot;,
#                 {
#                     center: [-0.37, -1.44],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e22b686b734655591e081188ac34422a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_