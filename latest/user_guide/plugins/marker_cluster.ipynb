# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c4d86bf29737d756ace95789b38167a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c4d86bf29737d756ace95789b38167a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c4d86bf29737d756ace95789b38167a = L.map(
#                 &quot;map_3c4d86bf29737d756ace95789b38167a&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33d7c7af4ad27a21d7fb3d75f0b0c629 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_33d7c7af4ad27a21d7fb3d75f0b0c629.addTo(map_3c4d86bf29737d756ace95789b38167a);
#
#
#             var marker_cluster_1c3f5a20aa3a11361f2649f44767de4e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_54d08caf7e2f7e3a8f1ebbff496cb61d = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_1c3f5a20aa3a11361f2649f44767de4e);
#
#
#             var icon_940a1754ea54a3645ae4aa195dec9089 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54d08caf7e2f7e3a8f1ebbff496cb61d.setIcon(icon_940a1754ea54a3645ae4aa195dec9089);
#
#
#         var popup_f46adde9712fd8d209158a51baf8ff70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9094548a9eb484a2373eb0d5fdde8b98 = $(`&lt;div id=&quot;html_9094548a9eb484a2373eb0d5fdde8b98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_f46adde9712fd8d209158a51baf8ff70.setContent(html_9094548a9eb484a2373eb0d5fdde8b98);
#
#
#
#         marker_54d08caf7e2f7e3a8f1ebbff496cb61d.bindPopup(popup_f46adde9712fd8d209158a51baf8ff70)
#         ;
#
#
#
#
#             var marker_eeabbd5cba4d0402158fd5420e0f6f8b = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_1c3f5a20aa3a11361f2649f44767de4e);
#
#
#             var icon_69448dededebee86d50176e990ae1e53 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eeabbd5cba4d0402158fd5420e0f6f8b.setIcon(icon_69448dededebee86d50176e990ae1e53);
#
#
#         var popup_8fdbad32f046a761fd5989a0aaad610b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec2b44345ed024e62b5ffc54336217c3 = $(`&lt;div id=&quot;html_ec2b44345ed024e62b5ffc54336217c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8fdbad32f046a761fd5989a0aaad610b.setContent(html_ec2b44345ed024e62b5ffc54336217c3);
#
#
#
#         marker_eeabbd5cba4d0402158fd5420e0f6f8b.bindPopup(popup_8fdbad32f046a761fd5989a0aaad610b)
#         ;
#
#
#
#
#             var marker_9c2c1bbac262c56a3f0a14c18d4a8256 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_1c3f5a20aa3a11361f2649f44767de4e);
#
#
#         var popup_c04c98779ff2ecf3bf8fddc7ee663390 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_632c16a92d426601567d3d5b3441b836 = $(`&lt;div id=&quot;html_632c16a92d426601567d3d5b3441b836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c04c98779ff2ecf3bf8fddc7ee663390.setContent(html_632c16a92d426601567d3d5b3441b836);
#
#
#
#         marker_9c2c1bbac262c56a3f0a14c18d4a8256.bindPopup(popup_c04c98779ff2ecf3bf8fddc7ee663390)
#         ;
#
#
#
#
#             marker_cluster_1c3f5a20aa3a11361f2649f44767de4e.addTo(map_3c4d86bf29737d756ace95789b38167a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb9c910d53489cabcf151ce275ffc77b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb9c910d53489cabcf151ce275ffc77b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb9c910d53489cabcf151ce275ffc77b = L.map(
#                 &quot;map_cb9c910d53489cabcf151ce275ffc77b&quot;,
#                 {
#                     center: [-2.02, 15.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b59d26238930099ded7da9fc2acb7e2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b59d26238930099ded7da9fc2acb7e2.addTo(map_cb9c910d53489cabcf151ce275ffc77b);
#
#
#             var marker_cluster_774d75ab4df30e2b10a45b2eb309b809 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_774d75ab4df30e2b10a45b2eb309b809.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_f3443a3dabf7f01279e3e639ee85b121 = L.marker(
#                 [-33.0, 31.0],
#                 {}
#             ).addTo(marker_cluster_774d75ab4df30e2b10a45b2eb309b809);
#
#
#         var popup_cd5710db72baa17db00ce68a8bbec44c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd4aaab4dacfc0dfb35600c4806b1257 = $(`&lt;div id=&quot;html_fd4aaab4dacfc0dfb35600c4806b1257&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:31&lt;br&gt;lat:-33&lt;/div&gt;`)[0];
#                 popup_cd5710db72baa17db00ce68a8bbec44c.setContent(html_fd4aaab4dacfc0dfb35600c4806b1257);
#
#
#
#         marker_f3443a3dabf7f01279e3e639ee85b121.bindPopup(popup_cd5710db72baa17db00ce68a8bbec44c)
#         ;
#
#
#
#
#             var marker_05f5aaa354a1ac56a98b9adcd5a802c7 = L.marker(
#                 [21.0, 126.0],
#                 {}
#             ).addTo(marker_cluster_774d75ab4df30e2b10a45b2eb309b809);
#
#
#         var popup_7847e72c03fea73bedbb1b38e2a50a91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_edd68caab8cd17d9838435caccf0c17e = $(`&lt;div id=&quot;html_edd68caab8cd17d9838435caccf0c17e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:126&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_7847e72c03fea73bedbb1b38e2a50a91.setContent(html_edd68caab8cd17d9838435caccf0c17e);
#
#
#
#         marker_05f5aaa354a1ac56a98b9adcd5a802c7.bindPopup(popup_7847e72c03fea73bedbb1b38e2a50a91)
#         ;
#
#
#
#
#             var marker_b85e7c9cb7f7344d306365b39c2fdac4 = L.marker(
#                 [-42.0, 156.0],
#                 {}
#             ).addTo(marker_cluster_774d75ab4df30e2b10a45b2eb309b809);
#
#
#         var popup_4f5af750cd6d2a2fd0d44f0e6ba54dad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7603864bf61cf0170dc14e5ecdd20af = $(`&lt;div id=&quot;html_a7603864bf61cf0170dc14e5ecdd20af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:156&lt;br&gt;lat:-42&lt;/div&gt;`)[0];
#                 popup_4f5af750cd6d2a2fd0d44f0e6ba54dad.setContent(html_a7603864bf61cf0170dc14e5ecdd20af);
#
#
#
#         marker_b85e7c9cb7f7344d306365b39c2fdac4.bindPopup(popup_4f5af750cd6d2a2fd0d44f0e6ba54dad)
#         ;
#
#
#
#
#             var marker_2b751574f5ee95d74400e6206169ac8e = L.marker(
#                 [-33.0, -7.0],
#                 {}
#             ).addTo(marker_cluster_774d75ab4df30e2b10a45b2eb309b809);
#
#
#         var popup_37678f9dfc8ce4648d2c25911a44e58e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a20f41c234b72ed49462cd07259ba50 = $(`&lt;div id=&quot;html_0a20f41c234b72ed49462cd07259ba50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-7&lt;br&gt;lat:-33&lt;/div&gt;`)[0];
#                 popup_37678f9dfc8ce4648d2c25911a44e58e.setContent(html_0a20f41c234b72ed49462cd07259ba50);
#
#
#
#         marker_2b751574f5ee95d74400e62

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54706e400713aa637cdc75208964aa31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54706e400713aa637cdc75208964aa31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54706e400713aa637cdc75208964aa31 = L.map(
#                 &quot;map_54706e400713aa637cdc75208964aa31&quot;,
#                 {
#                     center: [-2.02, 15.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40b63fe1bc885e35747cb0fe5907f71e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_40b63fe1bc885e35747cb0fe5907f71e.addTo(map_54706e400713aa637cdc75208964aa31);
#
#
#             var marker_cluster_3162239ae8b976d3cdb4e304f5f30b4b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_26c700ba811ad4c20b7bed9f1e766d7a = L.marker(
#                 [-33.0, 31.0],
#                 {}
#             ).addTo(marker_cluster_3162239ae8b976d3cdb4e304f5f30b4b);
#
#
#         var popup_e50f2435b262acafb56d036bf6582c98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08ec649dcb67a6804467355d8b67c167 = $(`&lt;div id=&quot;html_08ec649dcb67a6804467355d8b67c167&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:31&lt;br&gt;lat:-33&lt;/div&gt;`)[0];
#                 popup_e50f2435b262acafb56d036bf6582c98.setContent(html_08ec649dcb67a6804467355d8b67c167);
#
#
#
#         marker_26c700ba811ad4c20b7bed9f1e766d7a.bindPopup(popup_e50f2435b262acafb56d036bf6582c98)
#         ;
#
#
#
#
#             var marker_0a843ee4c4ddb2d3a45e17fbd6d04e2f = L.marker(
#                 [21.0, 126.0],
#                 {}
#             ).addTo(marker_cluster_3162239ae8b976d3cdb4e304f5f30b4b);
#
#
#         var popup_98ddb2291a4637d4c612c9325111d961 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb304240a02620ad2811e5a619e2b308 = $(`&lt;div id=&quot;html_cb304240a02620ad2811e5a619e2b308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:126&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_98ddb2291a4637d4c612c9325111d961.setContent(html_cb304240a02620ad2811e5a619e2b308);
#
#
#
#         marker_0a843ee4c4ddb2d3a45e17fbd6d04e2f.bindPopup(popup_98ddb2291a4637d4c612c9325111d961)
#         ;
#
#
#
#
#             var marker_de08d3e2184a9ed97d46ef3b366ab5d4 = L.marker(
#                 [-42.0, 156.0],
#                 {}
#             ).addTo(marker_cluster_3162239ae8b976d3cdb4e304f5f30b4b);
#
#
#         var popup_612f196e72ef81d59bccdd4b73ad1cdd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee795f9c8302c68f6f0907f90828cd06 = $(`&lt;div id=&quot;html_ee795f9c8302c68f6f0907f90828cd06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:156&lt;br&gt;lat:-42&lt;/div&gt;`)[0];
#                 popup_612f196e72ef81d59bccdd4b73ad1cdd.setContent(html_ee795f9c8302c68f6f0907f90828cd06);
#
#
#
#         marker_de08d3e2184a9ed97d46ef3b366ab5d4.bindPopup(popup_612f196e72ef81d59bccdd4b73ad1cdd)
#         ;
#
#
#
#
#             var marker_6d255b9eab96a46758db06cb41b2a395 = L.marker(
#                 [-33.0, -7.0],
#                 {}
#             ).addTo(marker_cluster_3162239ae8b976d3cdb4e304f5f30b4b);
#
#
#         var popup_377a75b9215d481775c7b9074ccc7c4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da550dfd7cbfa5f3545d099577e85f64 = $(`&lt;div id=&quot;html_da550dfd7cbfa5f3545d099577e85f64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-7&lt;br&gt;lat:-33&lt;/div&gt;`)[0];
#                 popup_377a75b9215d481775c7b9074ccc7c4a.setContent(html_da550dfd7cbfa5f3545d099577e85f64);
#
#
#
#         marker_6d255b9eab96a46758db06cb41b2a395.bindPopup(popup_377a75b9215d481775c7b9074ccc7c4a)
#         ;
#
#
#
#
#             var marker_ae49d89bd28aa706ed4874551e4a3b30 = L.marker(
#                 [-29.0, 151.0],
#                 {}
#             ).addTo(marker_cluster_3162239ae8b976d3cdb4e304f5f30b4b);
#
#
#         var popup_404f34af75f31cee481c725cba9e1f

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18c35206206bd6ba701c1504da6f91a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18c35206206bd6ba701c1504da6f91a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18c35206206bd6ba701c1504da6f91a3 = L.map(
#                 &quot;map_18c35206206bd6ba701c1504da6f91a3&quot;,
#                 {
#                     center: [-2.02, 15.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_004e86a828a65afabf355ccd6c2d85f2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer