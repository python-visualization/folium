# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fa9bb69130ed69c3304ce5709a1526b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fa9bb69130ed69c3304ce5709a1526b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fa9bb69130ed69c3304ce5709a1526b = L.map(
#                 &quot;map_4fa9bb69130ed69c3304ce5709a1526b&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1a0be3439e67ff7e696564e4bdbc23f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f1a0be3439e67ff7e696564e4bdbc23f.addTo(map_4fa9bb69130ed69c3304ce5709a1526b);
#
#
#             var marker_cluster_4d422c97ccc6a6ad90c25f31ccfc11c4 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7019d449f2eb11763d927f7cb0decc50 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_4d422c97ccc6a6ad90c25f31ccfc11c4);
#
#
#             var icon_2432fa8ce5c879f83474cfa7a29f8b43 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7019d449f2eb11763d927f7cb0decc50.setIcon(icon_2432fa8ce5c879f83474cfa7a29f8b43);
#
#
#         var popup_873c61e38beaa587cafebf8d338e0a4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8cae17bc7f787517051138dfdbe679fa = $(`&lt;div id=&quot;html_8cae17bc7f787517051138dfdbe679fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_873c61e38beaa587cafebf8d338e0a4c.setContent(html_8cae17bc7f787517051138dfdbe679fa);
#
#
#
#         marker_7019d449f2eb11763d927f7cb0decc50.bindPopup(popup_873c61e38beaa587cafebf8d338e0a4c)
#         ;
#
#
#
#
#             var marker_1ec52a5e935539c9f648224cff6e2486 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_4d422c97ccc6a6ad90c25f31ccfc11c4);
#
#
#             var icon_306233f580ead24b2b1b8934eacf1f34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ec52a5e935539c9f648224cff6e2486.setIcon(icon_306233f580ead24b2b1b8934eacf1f34);
#
#
#         var popup_4f2b9d93b1cb5ce5875e896be2d40ff4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28486e0b7f214ddc2e977eb9d90bfb21 = $(`&lt;div id=&quot;html_28486e0b7f214ddc2e977eb9d90bfb21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_4f2b9d93b1cb5ce5875e896be2d40ff4.setContent(html_28486e0b7f214ddc2e977eb9d90bfb21);
#
#
#
#         marker_1ec52a5e935539c9f648224cff6e2486.bindPopup(popup_4f2b9d93b1cb5ce5875e896be2d40ff4)
#         ;
#
#
#
#
#             var marker_8d6a43fc301bebe62ed4fc72babeac1d = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_4d422c97ccc6a6ad90c25f31ccfc11c4);
#
#
#         var popup_67694504232a2533533b422d69495b9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_440e4f64981e76892619999e90a614cc = $(`&lt;div id=&quot;html_440e4f64981e76892619999e90a614cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_67694504232a2533533b422d69495b9b.setContent(html_440e4f64981e76892619999e90a614cc);
#
#
#
#         marker_8d6a43fc301bebe62ed4fc72babeac1d.bindPopup(popup_67694504232a2533533b422d69495b9b)
#         ;
#
#
#
#
#             marker_cluster_4d422c97ccc6a6ad90c25f31ccfc11c4.addTo(map_4fa9bb69130ed69c3304ce5709a1526b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12e172188f9c06327fbd2a98083cc997 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12e172188f9c06327fbd2a98083cc997&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12e172188f9c06327fbd2a98083cc997 = L.map(
#                 &quot;map_12e172188f9c06327fbd2a98083cc997&quot;,
#                 {
#                     center: [4.64, 12.94],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_576930baa188b2561931b0ba2514047e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_576930baa188b2561931b0ba2514047e.addTo(map_12e172188f9c06327fbd2a98083cc997);
#
#
#             var marker_cluster_abc9f3d32ebb5b94bbc224735498ed86 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_abc9f3d32ebb5b94bbc224735498ed86.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_5cacee8a0dcc321e673985a7dd2bac74 = L.marker(
#                 [-6.0, 43.0],
#                 {}
#             ).addTo(marker_cluster_abc9f3d32ebb5b94bbc224735498ed86);
#
#
#         var popup_ceb1d02a10c5825ebf6180997945c6ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98744b64791fedc3288a3858f5f0087d = $(`&lt;div id=&quot;html_98744b64791fedc3288a3858f5f0087d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:43&lt;br&gt;lat:-6&lt;/div&gt;`)[0];
#                 popup_ceb1d02a10c5825ebf6180997945c6ca.setContent(html_98744b64791fedc3288a3858f5f0087d);
#
#
#
#         marker_5cacee8a0dcc321e673985a7dd2bac74.bindPopup(popup_ceb1d02a10c5825ebf6180997945c6ca)
#         ;
#
#
#
#
#             var marker_c4a55ff659cfcca3a0d98a4cc8005020 = L.marker(
#                 [45.0, -31.0],
#                 {}
#             ).addTo(marker_cluster_abc9f3d32ebb5b94bbc224735498ed86);
#
#
#         var popup_2358d16b993d4211206aca4103aeb5f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e62647be3b7ad51db25e7e9d8fedcee5 = $(`&lt;div id=&quot;html_e62647be3b7ad51db25e7e9d8fedcee5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-31&lt;br&gt;lat:45&lt;/div&gt;`)[0];
#                 popup_2358d16b993d4211206aca4103aeb5f3.setContent(html_e62647be3b7ad51db25e7e9d8fedcee5);
#
#
#
#         marker_c4a55ff659cfcca3a0d98a4cc8005020.bindPopup(popup_2358d16b993d4211206aca4103aeb5f3)
#         ;
#
#
#
#
#             var marker_a5e5b9dd8b00b5311215a0ed02a57f87 = L.marker(
#                 [85.0, -160.0],
#                 {}
#             ).addTo(marker_cluster_abc9f3d32ebb5b94bbc224735498ed86);
#
#
#         var popup_5da3cd1a7b9d405fef26743f3e4ad7dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e929e6408257ad77a199d9c6d74cbadf = $(`&lt;div id=&quot;html_e929e6408257ad77a199d9c6d74cbadf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-160&lt;br&gt;lat:85&lt;/div&gt;`)[0];
#                 popup_5da3cd1a7b9d405fef26743f3e4ad7dd.setContent(html_e929e6408257ad77a199d9c6d74cbadf);
#
#
#
#         marker_a5e5b9dd8b00b5311215a0ed02a57f87.bindPopup(popup_5da3cd1a7b9d405fef26743f3e4ad7dd)
#         ;
#
#
#
#
#             var marker_0dd358539c8ad7425547a6afaa6f5513 = L.marker(
#                 [87.0, 166.0],
#                 {}
#             ).addTo(marker_cluster_abc9f3d32ebb5b94bbc224735498ed86);
#
#
#         var popup_7685709005623427e39f99de1745f594 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4642b970dab7c73b68cf049e394a0a3 = $(`&lt;div id=&quot;html_e4642b970dab7c73b68cf049e394a0a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:166&lt;br&gt;lat:87&lt;/div&gt;`)[0];
#                 popup_7685709005623427e39f99de1745f594.setContent(html_e4642b970dab7c73b68cf049e394a0a3);
#
#
#
#         marker_0dd358539c8ad742554

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12925c5e5e02f89e444f13dfa1983f88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12925c5e5e02f89e444f13dfa1983f88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12925c5e5e02f89e444f13dfa1983f88 = L.map(
#                 &quot;map_12925c5e5e02f89e444f13dfa1983f88&quot;,
#                 {
#                     center: [4.64, 12.94],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be4f0cd73a2482afc5581628403b81d5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be4f0cd73a2482afc5581628403b81d5.addTo(map_12925c5e5e02f89e444f13dfa1983f88);
#
#
#             var marker_cluster_2a0f75410970c6ec23395bd202936f2c = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_faf30bd7b78a6ceb434b5c2ebf174c2f = L.marker(
#                 [-6.0, 43.0],
#                 {}
#             ).addTo(marker_cluster_2a0f75410970c6ec23395bd202936f2c);
#
#
#         var popup_c13a0f02821ff6d3fd43a4ad93bf151e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9328727c19705b48bd65833da3641bef = $(`&lt;div id=&quot;html_9328727c19705b48bd65833da3641bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:43&lt;br&gt;lat:-6&lt;/div&gt;`)[0];
#                 popup_c13a0f02821ff6d3fd43a4ad93bf151e.setContent(html_9328727c19705b48bd65833da3641bef);
#
#
#
#         marker_faf30bd7b78a6ceb434b5c2ebf174c2f.bindPopup(popup_c13a0f02821ff6d3fd43a4ad93bf151e)
#         ;
#
#
#
#
#             var marker_01fd80f4950ca92898451223bdb465ef = L.marker(
#                 [45.0, -31.0],
#                 {}
#             ).addTo(marker_cluster_2a0f75410970c6ec23395bd202936f2c);
#
#
#         var popup_b231b8e682472e8e2f9db1fb6c0c85a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2308663e4906b360a0b0560b3b474a63 = $(`&lt;div id=&quot;html_2308663e4906b360a0b0560b3b474a63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-31&lt;br&gt;lat:45&lt;/div&gt;`)[0];
#                 popup_b231b8e682472e8e2f9db1fb6c0c85a2.setContent(html_2308663e4906b360a0b0560b3b474a63);
#
#
#
#         marker_01fd80f4950ca92898451223bdb465ef.bindPopup(popup_b231b8e682472e8e2f9db1fb6c0c85a2)
#         ;
#
#
#
#
#             var marker_4f5ddc76de7d576f18beaafbb80e8a75 = L.marker(
#                 [85.0, -160.0],
#                 {}
#             ).addTo(marker_cluster_2a0f75410970c6ec23395bd202936f2c);
#
#
#         var popup_2ad6be4f97e180a16340966bffe6a5cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3988c83a44dc2d059d9e77a1302a5dc3 = $(`&lt;div id=&quot;html_3988c83a44dc2d059d9e77a1302a5dc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-160&lt;br&gt;lat:85&lt;/div&gt;`)[0];
#                 popup_2ad6be4f97e180a16340966bffe6a5cf.setContent(html_3988c83a44dc2d059d9e77a1302a5dc3);
#
#
#
#         marker_4f5ddc76de7d576f18beaafbb80e8a75.bindPopup(popup_2ad6be4f97e180a16340966bffe6a5cf)
#         ;
#
#
#
#
#             var marker_763590e36e1d05d277ae9c8567d21a20 = L.marker(
#                 [87.0, 166.0],
#                 {}
#             ).addTo(marker_cluster_2a0f75410970c6ec23395bd202936f2c);
#
#
#         var popup_50c658aec33b92ebe08517d38b5de101 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbcfa95827e49aefb8e972d3ada9aaab = $(`&lt;div id=&quot;html_dbcfa95827e49aefb8e972d3ada9aaab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:166&lt;br&gt;lat:87&lt;/div&gt;`)[0];
#                 popup_50c658aec33b92ebe08517d38b5de101.setContent(html_dbcfa95827e49aefb8e972d3ada9aaab);
#
#
#
#         marker_763590e36e1d05d277ae9c8567d21a20.bindPopup(popup_50c658aec33b92ebe08517d38b5de101)
#         ;
#
#
#
#
#             var marker_fa4221ca555f66a4bcf31a0dced863fa = L.marker(
#                 [17.0, -4.0],
#                 {}
#             ).addTo(marker_cluster_2a0f75410970c6ec23395bd202936f2c);
#
#
#         var popup_95ee7635012217577ef8de2d81c0

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a0d00480c4b6b33d7357f2b330b5948 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a0d00480c4b6b33d7357f2b330b5948&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a0d00480c4b6b33d7357f2b330b5948 = L.map(
#                 &quot;map_0a0d00480c4b6b33d7357f2b330b5948&quot;,
#                 {
#                     center: [4.64, 12.94],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_