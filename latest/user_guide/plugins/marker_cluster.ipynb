# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab3fa9107c323be7b85ce266663c24e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab3fa9107c323be7b85ce266663c24e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab3fa9107c323be7b85ce266663c24e2 = L.map(
#                 &quot;map_ab3fa9107c323be7b85ce266663c24e2&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ebecef3bf9ec3310baeeb609abf0a31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ebecef3bf9ec3310baeeb609abf0a31.addTo(map_ab3fa9107c323be7b85ce266663c24e2);
#
#
#             var marker_cluster_058ddf8a3e463ac34df51bcc66e794a9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_360c511897f2dc20ed7994f0b3a3c281 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_058ddf8a3e463ac34df51bcc66e794a9);
#
#
#             var icon_e0dbb3aa06da59bffc9305ee6a2396cf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_360c511897f2dc20ed7994f0b3a3c281.setIcon(icon_e0dbb3aa06da59bffc9305ee6a2396cf);
#
#
#         var popup_8ed261714bd5fb157fdc5a8b20b786ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95ce5dd5d6c13aa48b2226b07cf2eb7d = $(`&lt;div id=&quot;html_95ce5dd5d6c13aa48b2226b07cf2eb7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8ed261714bd5fb157fdc5a8b20b786ec.setContent(html_95ce5dd5d6c13aa48b2226b07cf2eb7d);
#
#
#
#         marker_360c511897f2dc20ed7994f0b3a3c281.bindPopup(popup_8ed261714bd5fb157fdc5a8b20b786ec)
#         ;
#
#
#
#
#             var marker_7adec8d23cb4766fee19ee4f20cd12ef = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_058ddf8a3e463ac34df51bcc66e794a9);
#
#
#             var icon_35610106019033b5eddb4d88b91a8c0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7adec8d23cb4766fee19ee4f20cd12ef.setIcon(icon_35610106019033b5eddb4d88b91a8c0b);
#
#
#         var popup_ac5050b778b3d9c4c71f09cbc443a92a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63e40e7b10233f8d69e26c1a9762014c = $(`&lt;div id=&quot;html_63e40e7b10233f8d69e26c1a9762014c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ac5050b778b3d9c4c71f09cbc443a92a.setContent(html_63e40e7b10233f8d69e26c1a9762014c);
#
#
#
#         marker_7adec8d23cb4766fee19ee4f20cd12ef.bindPopup(popup_ac5050b778b3d9c4c71f09cbc443a92a)
#         ;
#
#
#
#
#             var marker_1ea55df55ca751b8b59a28e20b510521 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_058ddf8a3e463ac34df51bcc66e794a9);
#
#
#         var popup_0c12fe8d533c6db675d2da9650106d2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e3150a869e722ea8530047dba402451 = $(`&lt;div id=&quot;html_3e3150a869e722ea8530047dba402451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0c12fe8d533c6db675d2da9650106d2b.setContent(html_3e3150a869e722ea8530047dba402451);
#
#
#
#         marker_1ea55df55ca751b8b59a28e20b510521.bindPopup(popup_0c12fe8d533c6db675d2da9650106d2b)
#         ;
#
#
#
#
#             marker_cluster_058ddf8a3e463ac34df51bcc66e794a9.addTo(map_ab3fa9107c323be7b85ce266663c24e2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aebe264b9df2d8f1fe96031a5b92e5d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aebe264b9df2d8f1fe96031a5b92e5d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aebe264b9df2d8f1fe96031a5b92e5d7 = L.map(
#                 &quot;map_aebe264b9df2d8f1fe96031a5b92e5d7&quot;,
#                 {
#                     center: [3.29, -5.44],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2d8d485d5b203b978ac676bb73c001a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e2d8d485d5b203b978ac676bb73c001a.addTo(map_aebe264b9df2d8f1fe96031a5b92e5d7);
#
#
#             var marker_cluster_5b6d33f7e8eaa39333b002d14c76e91e = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_5b6d33f7e8eaa39333b002d14c76e91e.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_7d563957fcef8cacd379bde09b15e3d1 = L.marker(
#                 [51.0, -116.0],
#                 {}
#             ).addTo(marker_cluster_5b6d33f7e8eaa39333b002d14c76e91e);
#
#
#         var popup_177a01f8899c5d2dfadf3e0b423ad4cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba131b0d7b257edec1e21f0936979bf6 = $(`&lt;div id=&quot;html_ba131b0d7b257edec1e21f0936979bf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-116&lt;br&gt;lat:51&lt;/div&gt;`)[0];
#                 popup_177a01f8899c5d2dfadf3e0b423ad4cb.setContent(html_ba131b0d7b257edec1e21f0936979bf6);
#
#
#
#         marker_7d563957fcef8cacd379bde09b15e3d1.bindPopup(popup_177a01f8899c5d2dfadf3e0b423ad4cb)
#         ;
#
#
#
#
#             var marker_595c43dc9f2badf298401b98d26d807b = L.marker(
#                 [-60.0, 7.0],
#                 {}
#             ).addTo(marker_cluster_5b6d33f7e8eaa39333b002d14c76e91e);
#
#
#         var popup_3506506c849d64ba6ab60335650c7524 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2950b86431b9418eb47dfbc6f8777f38 = $(`&lt;div id=&quot;html_2950b86431b9418eb47dfbc6f8777f38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:7&lt;br&gt;lat:-60&lt;/div&gt;`)[0];
#                 popup_3506506c849d64ba6ab60335650c7524.setContent(html_2950b86431b9418eb47dfbc6f8777f38);
#
#
#
#         marker_595c43dc9f2badf298401b98d26d807b.bindPopup(popup_3506506c849d64ba6ab60335650c7524)
#         ;
#
#
#
#
#             var marker_1070f98439e994ed7a9cbfca86501374 = L.marker(
#                 [-35.0, -6.0],
#                 {}
#             ).addTo(marker_cluster_5b6d33f7e8eaa39333b002d14c76e91e);
#
#
#         var popup_1c4b104294eb3e9332e5a0eef589c26b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a88fb625a5696568a4483268a6f6c5ed = $(`&lt;div id=&quot;html_a88fb625a5696568a4483268a6f6c5ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-6&lt;br&gt;lat:-35&lt;/div&gt;`)[0];
#                 popup_1c4b104294eb3e9332e5a0eef589c26b.setContent(html_a88fb625a5696568a4483268a6f6c5ed);
#
#
#
#         marker_1070f98439e994ed7a9cbfca86501374.bindPopup(popup_1c4b104294eb3e9332e5a0eef589c26b)
#         ;
#
#
#
#
#             var marker_c69a65f5ba30d04d8bb7bebbac503ab6 = L.marker(
#                 [-1.0, -53.0],
#                 {}
#             ).addTo(marker_cluster_5b6d33f7e8eaa39333b002d14c76e91e);
#
#
#         var popup_b8911c727097f4ca363fcb7f8064ab36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d8476c7af64d891a51d4b21233253d6 = $(`&lt;div id=&quot;html_2d8476c7af64d891a51d4b21233253d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-53&lt;br&gt;lat:-1&lt;/div&gt;`)[0];
#                 popup_b8911c727097f4ca363fcb7f8064ab36.setContent(html_2d8476c7af64d891a51d4b21233253d6);
#
#
#
#         marker_c69a65f5ba30d04d8bb

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_829cd6b6b0d603a980ca5bd33fc82023 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_829cd6b6b0d603a980ca5bd33fc82023&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_829cd6b6b0d603a980ca5bd33fc82023 = L.map(
#                 &quot;map_829cd6b6b0d603a980ca5bd33fc82023&quot;,
#                 {
#                     center: [3.29, -5.44],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43627bbe0138693c7a3a0685890afc33 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_43627bbe0138693c7a3a0685890afc33.addTo(map_829cd6b6b0d603a980ca5bd33fc82023);
#
#
#             var marker_cluster_4b5db6f9ff114dcb21c3972b42575d0b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_1587a45d97041e65162cb823b86b09c1 = L.marker(
#                 [51.0, -116.0],
#                 {}
#             ).addTo(marker_cluster_4b5db6f9ff114dcb21c3972b42575d0b);
#
#
#         var popup_58ee6f62c4294941052f29e825bcc2fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_638e1acb4e2256b708addbce2b03e4a3 = $(`&lt;div id=&quot;html_638e1acb4e2256b708addbce2b03e4a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-116&lt;br&gt;lat:51&lt;/div&gt;`)[0];
#                 popup_58ee6f62c4294941052f29e825bcc2fd.setContent(html_638e1acb4e2256b708addbce2b03e4a3);
#
#
#
#         marker_1587a45d97041e65162cb823b86b09c1.bindPopup(popup_58ee6f62c4294941052f29e825bcc2fd)
#         ;
#
#
#
#
#             var marker_9670e0460615869859066bb03aa11dad = L.marker(
#                 [-60.0, 7.0],
#                 {}
#             ).addTo(marker_cluster_4b5db6f9ff114dcb21c3972b42575d0b);
#
#
#         var popup_69ff6f825fe2a414c9d2fc688c798df3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8aa18bd7a800cc5846a7a4964e524666 = $(`&lt;div id=&quot;html_8aa18bd7a800cc5846a7a4964e524666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:7&lt;br&gt;lat:-60&lt;/div&gt;`)[0];
#                 popup_69ff6f825fe2a414c9d2fc688c798df3.setContent(html_8aa18bd7a800cc5846a7a4964e524666);
#
#
#
#         marker_9670e0460615869859066bb03aa11dad.bindPopup(popup_69ff6f825fe2a414c9d2fc688c798df3)
#         ;
#
#
#
#
#             var marker_651b643604b97ae3e65862d94ca3cae3 = L.marker(
#                 [-35.0, -6.0],
#                 {}
#             ).addTo(marker_cluster_4b5db6f9ff114dcb21c3972b42575d0b);
#
#
#         var popup_b0fd05cbc8cf00619301c1c29198bf57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_664f444556c3ecd4777c7d125a4f5e34 = $(`&lt;div id=&quot;html_664f444556c3ecd4777c7d125a4f5e34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-6&lt;br&gt;lat:-35&lt;/div&gt;`)[0];
#                 popup_b0fd05cbc8cf00619301c1c29198bf57.setContent(html_664f444556c3ecd4777c7d125a4f5e34);
#
#
#
#         marker_651b643604b97ae3e65862d94ca3cae3.bindPopup(popup_b0fd05cbc8cf00619301c1c29198bf57)
#         ;
#
#
#
#
#             var marker_f2171fbc8c49d559240fea39b8b7ce81 = L.marker(
#                 [-1.0, -53.0],
#                 {}
#             ).addTo(marker_cluster_4b5db6f9ff114dcb21c3972b42575d0b);
#
#
#         var popup_c4cf9bb5ccdd5cdcae6bdb750c6ba932 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3b7a2ae69297c7c272019af66ee3849 = $(`&lt;div id=&quot;html_c3b7a2ae69297c7c272019af66ee3849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-53&lt;br&gt;lat:-1&lt;/div&gt;`)[0];
#                 popup_c4cf9bb5ccdd5cdcae6bdb750c6ba932.setContent(html_c3b7a2ae69297c7c272019af66ee3849);
#
#
#
#         marker_f2171fbc8c49d559240fea39b8b7ce81.bindPopup(popup_c4cf9bb5ccdd5cdcae6bdb750c6ba932)
#         ;
#
#
#
#
#             var marker_7aa4743568685d12e255d3731f3cde03 = L.marker(
#                 [42.0, 89.0],
#                 {}
#             ).addTo(marker_cluster_4b5db6f9ff114dcb21c3972b42575d0b);
#
#
#         var popup_ae3ed2deae45736d428ad7c654ba

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42a213bc192748dfab721d816b0048e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42a213bc192748dfab721d816b0048e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42a213bc192748dfab721d816b0048e5 = L.map(
#                 &quot;map_42a213bc192748dfab721d816b0048e5&quot;,
#                 {
#                     center: [3.29, -5.44],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18bfb644015b14a8d01feb165b594a85 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer