# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4596d1edca185198391489dff4b60bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4596d1edca185198391489dff4b60bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4596d1edca185198391489dff4b60bd = L.map(
#                 &quot;map_a4596d1edca185198391489dff4b60bd&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35feb081a9dcdc074530b83cc36738d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_35feb081a9dcdc074530b83cc36738d7.addTo(map_a4596d1edca185198391489dff4b60bd);
#
#
#             var marker_cluster_3ddd4240c37d45f1c46a3ff2e352f7d7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_5cf1730fc56ea4d776b9bb017a2b46c2 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_3ddd4240c37d45f1c46a3ff2e352f7d7);
#
#
#             var icon_612fe58e1003d732ff58da6a6e9c9e07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5cf1730fc56ea4d776b9bb017a2b46c2.setIcon(icon_612fe58e1003d732ff58da6a6e9c9e07);
#
#
#         var popup_ef2a3f1f7e0507eefe5ff9cba057eefa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18c908bb4f7792d15e88cedfd04c1c46 = $(`&lt;div id=&quot;html_18c908bb4f7792d15e88cedfd04c1c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ef2a3f1f7e0507eefe5ff9cba057eefa.setContent(html_18c908bb4f7792d15e88cedfd04c1c46);
#
#
#
#         marker_5cf1730fc56ea4d776b9bb017a2b46c2.bindPopup(popup_ef2a3f1f7e0507eefe5ff9cba057eefa)
#         ;
#
#
#
#
#             var marker_d62fee328be7ae0f8764eddcfb5eec69 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_3ddd4240c37d45f1c46a3ff2e352f7d7);
#
#
#             var icon_29866f5ba7f59a8831344037c796d72d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d62fee328be7ae0f8764eddcfb5eec69.setIcon(icon_29866f5ba7f59a8831344037c796d72d);
#
#
#         var popup_8b9c0074b8bbe4e3001846b62755525c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f86525fc5c58a57e166110f1411d6d2 = $(`&lt;div id=&quot;html_2f86525fc5c58a57e166110f1411d6d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8b9c0074b8bbe4e3001846b62755525c.setContent(html_2f86525fc5c58a57e166110f1411d6d2);
#
#
#
#         marker_d62fee328be7ae0f8764eddcfb5eec69.bindPopup(popup_8b9c0074b8bbe4e3001846b62755525c)
#         ;
#
#
#
#
#             var marker_d94145738932991ae2e36ce1f1f4d16a = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_3ddd4240c37d45f1c46a3ff2e352f7d7);
#
#
#         var popup_c2bc243732160f9e67832437266e2308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d54378729b89321eb33e28440acf33e = $(`&lt;div id=&quot;html_8d54378729b89321eb33e28440acf33e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c2bc243732160f9e67832437266e2308.setContent(html_8d54378729b89321eb33e28440acf33e);
#
#
#
#         marker_d94145738932991ae2e36ce1f1f4d16a.bindPopup(popup_c2bc243732160f9e67832437266e2308)
#         ;
#
#
#
#
#             marker_cluster_3ddd4240c37d45f1c46a3ff2e352f7d7.addTo(map_a4596d1edca185198391489dff4b60bd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7ead6780a2cd3aaea316d07ef38082e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7ead6780a2cd3aaea316d07ef38082e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7ead6780a2cd3aaea316d07ef38082e = L.map(
#                 &quot;map_a7ead6780a2cd3aaea316d07ef38082e&quot;,
#                 {
#                     center: [-1.56, -1.93],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd172d9e822e3cfeeef005fc1fe1955a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd172d9e822e3cfeeef005fc1fe1955a.addTo(map_a7ead6780a2cd3aaea316d07ef38082e);
#
#
#             var marker_cluster_5430e3767c2630c6c4f82f8a5899a528 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_5430e3767c2630c6c4f82f8a5899a528.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_517ecd3831377423577914e12600b1b4 = L.marker(
#                 [24.0, -142.0],
#                 {}
#             ).addTo(marker_cluster_5430e3767c2630c6c4f82f8a5899a528);
#
#
#         var popup_a7b1f6abcfc4bfd1ad3f18a37eac25eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2c7262cb660080d23ff64893f945d39 = $(`&lt;div id=&quot;html_d2c7262cb660080d23ff64893f945d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-142&lt;br&gt;lat:24&lt;/div&gt;`)[0];
#                 popup_a7b1f6abcfc4bfd1ad3f18a37eac25eb.setContent(html_d2c7262cb660080d23ff64893f945d39);
#
#
#
#         marker_517ecd3831377423577914e12600b1b4.bindPopup(popup_a7b1f6abcfc4bfd1ad3f18a37eac25eb)
#         ;
#
#
#
#
#             var marker_ae149f150ad0a71c6c24f0d439474c88 = L.marker(
#                 [52.0, 74.0],
#                 {}
#             ).addTo(marker_cluster_5430e3767c2630c6c4f82f8a5899a528);
#
#
#         var popup_e9460f6936778e79787b292050ecae3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54971894793385d49a2b345da0501087 = $(`&lt;div id=&quot;html_54971894793385d49a2b345da0501087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:74&lt;br&gt;lat:52&lt;/div&gt;`)[0];
#                 popup_e9460f6936778e79787b292050ecae3a.setContent(html_54971894793385d49a2b345da0501087);
#
#
#
#         marker_ae149f150ad0a71c6c24f0d439474c88.bindPopup(popup_e9460f6936778e79787b292050ecae3a)
#         ;
#
#
#
#
#             var marker_9507ef41fda62edb2e95407082861d31 = L.marker(
#                 [-75.0, 151.0],
#                 {}
#             ).addTo(marker_cluster_5430e3767c2630c6c4f82f8a5899a528);
#
#
#         var popup_18a8737c6175c494c9807c23056a6a81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48aa1f3845e97f99d2435b4977543765 = $(`&lt;div id=&quot;html_48aa1f3845e97f99d2435b4977543765&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:151&lt;br&gt;lat:-75&lt;/div&gt;`)[0];
#                 popup_18a8737c6175c494c9807c23056a6a81.setContent(html_48aa1f3845e97f99d2435b4977543765);
#
#
#
#         marker_9507ef41fda62edb2e95407082861d31.bindPopup(popup_18a8737c6175c494c9807c23056a6a81)
#         ;
#
#
#
#
#             var marker_44b57f0fc62037537a719b47c1a14099 = L.marker(
#                 [-47.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_5430e3767c2630c6c4f82f8a5899a528);
#
#
#         var popup_b67001ba9610661bf4177045a49911ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_950504fe46ba6c5dcb635229e0e05578 = $(`&lt;div id=&quot;html_950504fe46ba6c5dcb635229e0e05578&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-47&lt;/div&gt;`)[0];
#                 popup_b67001ba9610661bf4177045a49911ad.setContent(html_950504fe46ba6c5dcb635229e0e05578);
#
#
#
#         marker_44b57f0fc62037

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_744288768db9c4e671ee516a3413f2a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_744288768db9c4e671ee516a3413f2a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_744288768db9c4e671ee516a3413f2a3 = L.map(
#                 &quot;map_744288768db9c4e671ee516a3413f2a3&quot;,
#                 {
#                     center: [-1.56, -1.93],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1bad1c256ef3585809c3ca6f8b7ab79 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a1bad1c256ef3585809c3ca6f8b7ab79.addTo(map_744288768db9c4e671ee516a3413f2a3);
#
#
#             var marker_cluster_c538e78546174eec7dd803cd8775b7af = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_800482c83805fdbbca0ecada8404c570 = L.marker(
#                 [24.0, -142.0],
#                 {}
#             ).addTo(marker_cluster_c538e78546174eec7dd803cd8775b7af);
#
#
#         var popup_690e6a152cf4177a9d68774f1fed93e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_246ec9807bddf028b6b6c50f109e03e3 = $(`&lt;div id=&quot;html_246ec9807bddf028b6b6c50f109e03e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-142&lt;br&gt;lat:24&lt;/div&gt;`)[0];
#                 popup_690e6a152cf4177a9d68774f1fed93e7.setContent(html_246ec9807bddf028b6b6c50f109e03e3);
#
#
#
#         marker_800482c83805fdbbca0ecada8404c570.bindPopup(popup_690e6a152cf4177a9d68774f1fed93e7)
#         ;
#
#
#
#
#             var marker_5f289a90bc9964bfd74436631ea9c161 = L.marker(
#                 [52.0, 74.0],
#                 {}
#             ).addTo(marker_cluster_c538e78546174eec7dd803cd8775b7af);
#
#
#         var popup_5e44d5e7d901a90501eabe3d7ea306cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ff7e1ee014bb57f50b0f323358a425b = $(`&lt;div id=&quot;html_6ff7e1ee014bb57f50b0f323358a425b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:74&lt;br&gt;lat:52&lt;/div&gt;`)[0];
#                 popup_5e44d5e7d901a90501eabe3d7ea306cb.setContent(html_6ff7e1ee014bb57f50b0f323358a425b);
#
#
#
#         marker_5f289a90bc9964bfd74436631ea9c161.bindPopup(popup_5e44d5e7d901a90501eabe3d7ea306cb)
#         ;
#
#
#
#
#             var marker_47f006c09cce2462b7cd858f4d27c287 = L.marker(
#                 [-75.0, 151.0],
#                 {}
#             ).addTo(marker_cluster_c538e78546174eec7dd803cd8775b7af);
#
#
#         var popup_35f07eb5f79b77d58e7f6600ef4c9369 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c24abff3a76d591ae2604eddf9e9252 = $(`&lt;div id=&quot;html_3c24abff3a76d591ae2604eddf9e9252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:151&lt;br&gt;lat:-75&lt;/div&gt;`)[0];
#                 popup_35f07eb5f79b77d58e7f6600ef4c9369.setContent(html_3c24abff3a76d591ae2604eddf9e9252);
#
#
#
#         marker_47f006c09cce2462b7cd858f4d27c287.bindPopup(popup_35f07eb5f79b77d58e7f6600ef4c9369)
#         ;
#
#
#
#
#             var marker_038f2729c38679bc5f0c77fa85c20a02 = L.marker(
#                 [-47.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_c538e78546174eec7dd803cd8775b7af);
#
#
#         var popup_4667dfd97652293be1e660816f53458d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0aa3294b8118f9387769b5a19f559208 = $(`&lt;div id=&quot;html_0aa3294b8118f9387769b5a19f559208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-47&lt;/div&gt;`)[0];
#                 popup_4667dfd97652293be1e660816f53458d.setContent(html_0aa3294b8118f9387769b5a19f559208);
#
#
#
#         marker_038f2729c38679bc5f0c77fa85c20a02.bindPopup(popup_4667dfd97652293be1e660816f53458d)
#         ;
#
#
#
#
#             var marker_d60a2e84ce6b6334802d085ca7f59377 = L.marker(
#                 [-28.0, 37.0],
#                 {}
#             ).addTo(marker_cluster_c538e78546174eec7dd803cd8775b7af);
#
#
#         var popup_11dcfab05898b8911c5d17

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83d17642b144eebaa7c21d1be1e42280 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83d17642b144eebaa7c21d1be1e42280&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83d17642b144eebaa7c21d1be1e42280 = L.map(
#                 &quot;map_83d17642b144eebaa7c21d1be1e42280&quot;,
#                 {
#                     center: [-1.56, -1.93],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbf219ffe1720e6a702c0a5dfbf8787c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dbf219ffe1720e6a702c0a5dfbf8787c.addTo(map_83d17642b144eebaa7c21d1be1e42280);
#
#
#             var fast_marker_cluster_b8b6193f6255943409d7d503c97e1d77 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[24.0, -142.0], [52.0, 74.0], [-75.0, 151.0], [-47.0, -76.0], [-28.0, 37.0], [3.0, 116.0], [36.0, -4.0], [-21.0, 12.0], [-52.0, 45.0], [67.0, -44.0], [7.0, 150.0], [49.0, -124.0], [-27.0, -85.0], [-33.0, 109.0], [-82.0, 57.0], [77.0, -119.0], [-69.0, 24.0], [-14.0, 151.0], [-69.0, -40.0], [-25.0, -131.0], [16.0, -56.0], [-62.0, 15.0], [-6.0, -39.0], [4.0, 29.0], [77.0, 87.0], [-56.0, 173.0], [-67.0, -137.0], [32.0, 107.0], [-87.0, 27.0], [4.0, 88.0], [37.0, 129.0], [76.0, 140.0], [6.0, -145.0], [-33.0, -125.0], [-51.0, -163.0], [-10.0, -147.0], [9.0, -150.0], [-34.0, -50.0], [-57.0, -139.0], [-7.0, -154.0], [36.0, -120.0], [45.0, 0.0], [35.0, 29.0], [-44.0, -53.0], [75.0, -113.0], [-75.0, -67.0], [44.0, 165.0], [-67.0, 29.0], [-20.0, 76.0], [70.0, -96.0], [23.0, 58.0], [-71.0, 148.0], [-24.0, -41.0], [-84.0, -65.0], [33.0, 112.0], [-47.0, 58.0], [-22.0, -60.0], [83.0, -74.0], [4.0, -115.0], [-73.0, -66.0], [-15.0, 167.0], [32.0, 153.0], [-30.0, 40.0], [82.0, 73.0], [-67.0, 34.0], [-27.0, -81.0], [64.0, 171.0], [-56.0, -115.0], [12.0, -60.0], [40.0, 61.0], [-19.0, 120.0], [4.0, 13.0], [34.0, 116.0], [10.0, -125.0], [53.0, -45.0], [81.0, -76.0], [-33.0, -19.0], [10.0, -102.0], [78.0, 47.0], [31.0, 167.0], [82.0, -180.0], [-63.0, 162.0], [13.0, 24.0], [-90.0, -175.0], [-51.0, -45.0], [32.0, -11.0], [-60.0, 61.0], [44.0, -133.0], [-79.0, -77.0], [74.0, 113.0], [47.0, -96.0], [9.0, -10.0], [-76.0, 133.0], [62.0, -117.0], [77.0, 84.0], [-26.0, -115.0], [-33.0, -7.0], [87.0, 28.0], [6.0, 139.0], [20.0, 34.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_83d17642b144eebaa7c21d1be1e42280);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_b8b6193f6255943409d7d503c97e1d77.addTo(map_83d17642b144eebaa7c21d1be1e42280);
#
#
#             var layer_control_487d7f750479ea2ab0097d7b5b1fa706_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_dbf219ffe1720e6a702c0a5dfbf8787c,
#                 },
#                 overlays :  {
#                     &quot;macro_element_b8b6193f6255943409d7d503c97e1d77&quot; : fast_marker_cluster_b8b6193f6255943409d7d503c97e1d77,
#                 },
#             };
#             let layer_control_487d7f750479ea2ab0097d7b5b1fa706 = L.control.layers(
#                 layer_control_487d7f750479ea2ab0097d7b5b1fa706_layers.base_layers,
#                 layer_control_487d7f750479ea2ab0097d7b5b1fa706_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_83d17642b144eebaa7c21d1be1e42280);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5aa17200d4eab97a0fdfae647b3563e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5aa17200d4eab97a0fdfae647b3563e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5aa17200d4eab97a0fdfae647b3563e2 = L.map(
#                 &quot;map_5aa17200d4eab97a0fdfae647b3563e2&quot;,
#                 {
#                     center: [-1.56, -1.93],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94a5eb54aca0068729c6447ecf96f9a7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_94a5eb54aca0068729c6447ecf96f9a7.addTo(map_5aa17200d4eab97a0fdfae647b3563e2);
#
#
#             var fast_marker_cluster_ee0705c9ba902d1019c288eb41c4ce24 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[24.0, -142.0], [52.0, 74.0], [-75.0, 151.0], [-47.0, -76.0], [-28.0, 37.0], [3.0, 116.0], [36.0, -4.0], [-21.0, 12.0], [-52.0, 45.0], [67.0, -44.0], [7.0, 150.0], [49.0, -124.0], [-27.0, -85.0], [-33.0, 109.0], [-82.0, 57.0], [77.0, -119.0], [-69.0, 24.0], [-14.0, 151.0], [-69.0, -40.0], [-25.0, -131.0], [16.0, -56.0], [-62.0, 15.0], [-6.0, -39.0], [4.0, 29.0], [77.0, 87.0], [-56.0, 173.0], [-67.0, -137.0], [32.0, 107.0], [-87.0, 27.0], [4.0, 88.0], [37.0, 129.0], [76.0, 140.0], [6.0, -145.0], [-33.0, -125.0], [-51.0, -163.0], [-10.0, -147.0], [9.0, -150.0], [-34.0, -50.0], [-57.0, -139.0], [-7.0, -154.0], [36.0, -120.0], [45.0, 0.0], [35.0, 29.0], [-44.0, -53.0], [75.0, -113.0], [-75.0, -67.0], [44.0, 165.0], [-67.0, 29.0], [-20.0, 76.0], [70.0, -96.0], [23.0, 58.0], [-71.0, 148.0], [-24.0, -41.0], [-84.0, -65.0], [33.0, 112.0], [-47.0, 58.0], [-22.0, -60.0], [83.0, -74.0], [4.0, -115.0], [-73.0, -66.0], [-15.0, 167.0], [32.0, 153.0], [-30.0, 40.0], [82.0, 73.0], [-67.0, 34.0], [-27.0, -81.0], [64.0, 171.0], [-56.0, -115.0], [12.0, -60.0], [40.0, 61.0], [-19.0, 120.0], [4.0, 13.0], [34.0, 116.0], [10.0, -125.0], [53.0, -45.0], [81.0, -76.0], [-33.0, -19.0], [10.0, -102.0], [78.0, 47.0], [31.0, 167.0], [82.0, -180.0], [-63.0, 162.0], [13.0, 24.0], [-90.0, -175.0], [-51.0, -45.0], [32.0, -11.0], [-60.0, 61.0], [44.0, -133.0], [-79.0, -77.0], [74.0, 113.0], [47.0, -96.0], [9.0, -10.0], [-76.0, 133.0], [62.0, -117.0], [77.0, 84.0], [-26.0, -115.0], [-33.0, -7.0], [87.0, 28.0], [6.0, 139.0], [20.0, 34.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_5aa17200d4eab97a0fdfae647b3563e2);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_ee0705c9ba902d1019c288eb41c4ce24.addTo(map_5aa17200d4eab97a0fdfae647b3563e2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
