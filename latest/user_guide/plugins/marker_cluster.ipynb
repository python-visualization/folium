# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36e2e24cf225732dc7515469c215c0c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36e2e24cf225732dc7515469c215c0c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36e2e24cf225732dc7515469c215c0c8 = L.map(
#                 &quot;map_36e2e24cf225732dc7515469c215c0c8&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1568c4e2af9fef580ee90364a973cd0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1568c4e2af9fef580ee90364a973cd0a.addTo(map_36e2e24cf225732dc7515469c215c0c8);
#
#
#             var marker_cluster_d8116ea631b438b1790ca48cb7ac4f9e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_20a8914cccc7975e8f5c2188a0ccc5ec = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_d8116ea631b438b1790ca48cb7ac4f9e);
#
#
#             var icon_30cda03afe49e9d51e9e3f884d17d2a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_20a8914cccc7975e8f5c2188a0ccc5ec.setIcon(icon_30cda03afe49e9d51e9e3f884d17d2a3);
#
#
#         var popup_c8a4a5a706a979505dfcdfd2a7b016c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02be6a76b30ed2b0c6a09e334d850c34 = $(`&lt;div id=&quot;html_02be6a76b30ed2b0c6a09e334d850c34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c8a4a5a706a979505dfcdfd2a7b016c1.setContent(html_02be6a76b30ed2b0c6a09e334d850c34);
#
#
#
#         marker_20a8914cccc7975e8f5c2188a0ccc5ec.bindPopup(popup_c8a4a5a706a979505dfcdfd2a7b016c1)
#         ;
#
#
#
#
#             var marker_44976b7fea6e5a18618932732f82ab80 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_d8116ea631b438b1790ca48cb7ac4f9e);
#
#
#             var icon_201f3dcb16610afda6a55cc54fd7e2c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_44976b7fea6e5a18618932732f82ab80.setIcon(icon_201f3dcb16610afda6a55cc54fd7e2c9);
#
#
#         var popup_7bbd9518afdbe56804cfb1929a572df0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf30771ceee7f83415b4a3e992626987 = $(`&lt;div id=&quot;html_cf30771ceee7f83415b4a3e992626987&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7bbd9518afdbe56804cfb1929a572df0.setContent(html_cf30771ceee7f83415b4a3e992626987);
#
#
#
#         marker_44976b7fea6e5a18618932732f82ab80.bindPopup(popup_7bbd9518afdbe56804cfb1929a572df0)
#         ;
#
#
#
#
#             var marker_309e2b9bb122bdb948a6621d8799bf82 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_d8116ea631b438b1790ca48cb7ac4f9e);
#
#
#         var popup_1334dde396521bbcd4c2954d3eb4cbf6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5271b24712491358e0f41e3c942e1fe0 = $(`&lt;div id=&quot;html_5271b24712491358e0f41e3c942e1fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_1334dde396521bbcd4c2954d3eb4cbf6.setContent(html_5271b24712491358e0f41e3c942e1fe0);
#
#
#
#         marker_309e2b9bb122bdb948a6621d8799bf82.bindPopup(popup_1334dde396521bbcd4c2954d3eb4cbf6)
#         ;
#
#
#
#
#             marker_cluster_d8116ea631b438b1790ca48cb7ac4f9e.addTo(map_36e2e24cf225732dc7515469c215c0c8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3389ada4a5ae1a786f39ff92c3455924 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3389ada4a5ae1a786f39ff92c3455924&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3389ada4a5ae1a786f39ff92c3455924 = L.map(
#                 &quot;map_3389ada4a5ae1a786f39ff92c3455924&quot;,
#                 {
#                     center: [11.39, -2.39],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ff8805de1da74204c328aa6d775cc38 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1ff8805de1da74204c328aa6d775cc38.addTo(map_3389ada4a5ae1a786f39ff92c3455924);
#
#
#             var marker_cluster_2d4d6663deca0a5e3ee2d110224ebe0e = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_2d4d6663deca0a5e3ee2d110224ebe0e.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_4c3e5fb7307416d76a3895d6cebe7d27 = L.marker(
#                 [73.0, 37.0],
#                 {}
#             ).addTo(marker_cluster_2d4d6663deca0a5e3ee2d110224ebe0e);
#
#
#         var popup_b9cb0c08fe3e81c8c8f3132b3ad943be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ba7ae145a030743f108c10d22ccb16d = $(`&lt;div id=&quot;html_2ba7ae145a030743f108c10d22ccb16d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:37&lt;br&gt;lat:73&lt;/div&gt;`)[0];
#                 popup_b9cb0c08fe3e81c8c8f3132b3ad943be.setContent(html_2ba7ae145a030743f108c10d22ccb16d);
#
#
#
#         marker_4c3e5fb7307416d76a3895d6cebe7d27.bindPopup(popup_b9cb0c08fe3e81c8c8f3132b3ad943be)
#         ;
#
#
#
#
#             var marker_c317e51572d7d3780bd3840fd99abddd = L.marker(
#                 [55.0, -69.0],
#                 {}
#             ).addTo(marker_cluster_2d4d6663deca0a5e3ee2d110224ebe0e);
#
#
#         var popup_ea2eaff673739e1cb04d2903df6cea13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e62ceaedac5b1ff40f09596cc69f513 = $(`&lt;div id=&quot;html_8e62ceaedac5b1ff40f09596cc69f513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-69&lt;br&gt;lat:55&lt;/div&gt;`)[0];
#                 popup_ea2eaff673739e1cb04d2903df6cea13.setContent(html_8e62ceaedac5b1ff40f09596cc69f513);
#
#
#
#         marker_c317e51572d7d3780bd3840fd99abddd.bindPopup(popup_ea2eaff673739e1cb04d2903df6cea13)
#         ;
#
#
#
#
#             var marker_3491d85ef86707fedf557232a521a9e6 = L.marker(
#                 [11.0, -146.0],
#                 {}
#             ).addTo(marker_cluster_2d4d6663deca0a5e3ee2d110224ebe0e);
#
#
#         var popup_13a91a9ff52c33d04a042cc83bff1502 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e46461aae2ba8deda7e32415698a919 = $(`&lt;div id=&quot;html_7e46461aae2ba8deda7e32415698a919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-146&lt;br&gt;lat:11&lt;/div&gt;`)[0];
#                 popup_13a91a9ff52c33d04a042cc83bff1502.setContent(html_7e46461aae2ba8deda7e32415698a919);
#
#
#
#         marker_3491d85ef86707fedf557232a521a9e6.bindPopup(popup_13a91a9ff52c33d04a042cc83bff1502)
#         ;
#
#
#
#
#             var marker_5d19da3e85652e21d83df4b250f47e70 = L.marker(
#                 [28.0, 81.0],
#                 {}
#             ).addTo(marker_cluster_2d4d6663deca0a5e3ee2d110224ebe0e);
#
#
#         var popup_32c4764908c2dd7f062fcbbd2a8dc722 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c162938151a44584c72d01ae4604ab29 = $(`&lt;div id=&quot;html_c162938151a44584c72d01ae4604ab29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:81&lt;br&gt;lat:28&lt;/div&gt;`)[0];
#                 popup_32c4764908c2dd7f062fcbbd2a8dc722.setContent(html_c162938151a44584c72d01ae4604ab29);
#
#
#
#         marker_5d19da3e85652e21d83d

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_186278aac5aae2836ee22eb84bc56aa3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_186278aac5aae2836ee22eb84bc56aa3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_186278aac5aae2836ee22eb84bc56aa3 = L.map(
#                 &quot;map_186278aac5aae2836ee22eb84bc56aa3&quot;,
#                 {
#                     center: [11.39, -2.39],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cdc04b97a01a9e4716d1fee8438761f4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cdc04b97a01a9e4716d1fee8438761f4.addTo(map_186278aac5aae2836ee22eb84bc56aa3);
#
#
#             var marker_cluster_8ea98cf867f338aca70a2d75634c385c = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_b9c5e47ddb28260d8ceb06cfcfc5bd66 = L.marker(
#                 [73.0, 37.0],
#                 {}
#             ).addTo(marker_cluster_8ea98cf867f338aca70a2d75634c385c);
#
#
#         var popup_1a04b094c6d57238adaf1a0b652eb310 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecb7957615de413ab769695e561c821a = $(`&lt;div id=&quot;html_ecb7957615de413ab769695e561c821a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:37&lt;br&gt;lat:73&lt;/div&gt;`)[0];
#                 popup_1a04b094c6d57238adaf1a0b652eb310.setContent(html_ecb7957615de413ab769695e561c821a);
#
#
#
#         marker_b9c5e47ddb28260d8ceb06cfcfc5bd66.bindPopup(popup_1a04b094c6d57238adaf1a0b652eb310)
#         ;
#
#
#
#
#             var marker_90aa5550b6954b423e0046ea7911909f = L.marker(
#                 [55.0, -69.0],
#                 {}
#             ).addTo(marker_cluster_8ea98cf867f338aca70a2d75634c385c);
#
#
#         var popup_e7531b1c8fbaa6773c64bb35308aee81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_150dfe5189dfc591e7dcbbdd511fa2c8 = $(`&lt;div id=&quot;html_150dfe5189dfc591e7dcbbdd511fa2c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-69&lt;br&gt;lat:55&lt;/div&gt;`)[0];
#                 popup_e7531b1c8fbaa6773c64bb35308aee81.setContent(html_150dfe5189dfc591e7dcbbdd511fa2c8);
#
#
#
#         marker_90aa5550b6954b423e0046ea7911909f.bindPopup(popup_e7531b1c8fbaa6773c64bb35308aee81)
#         ;
#
#
#
#
#             var marker_a5153a55142805f2eb275ae13217f232 = L.marker(
#                 [11.0, -146.0],
#                 {}
#             ).addTo(marker_cluster_8ea98cf867f338aca70a2d75634c385c);
#
#
#         var popup_8563d332c4eb424f9c9f52bab857547a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6f8d66432ee208896150bf4f352ebcb = $(`&lt;div id=&quot;html_a6f8d66432ee208896150bf4f352ebcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-146&lt;br&gt;lat:11&lt;/div&gt;`)[0];
#                 popup_8563d332c4eb424f9c9f52bab857547a.setContent(html_a6f8d66432ee208896150bf4f352ebcb);
#
#
#
#         marker_a5153a55142805f2eb275ae13217f232.bindPopup(popup_8563d332c4eb424f9c9f52bab857547a)
#         ;
#
#
#
#
#             var marker_254113ba9131b263bac61a5059be09f7 = L.marker(
#                 [28.0, 81.0],
#                 {}
#             ).addTo(marker_cluster_8ea98cf867f338aca70a2d75634c385c);
#
#
#         var popup_a6d5b212342b84c32095be767bfdd50c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1c2f5ea40eadaf4215cb6fd18a12f64 = $(`&lt;div id=&quot;html_e1c2f5ea40eadaf4215cb6fd18a12f64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:81&lt;br&gt;lat:28&lt;/div&gt;`)[0];
#                 popup_a6d5b212342b84c32095be767bfdd50c.setContent(html_e1c2f5ea40eadaf4215cb6fd18a12f64);
#
#
#
#         marker_254113ba9131b263bac61a5059be09f7.bindPopup(popup_a6d5b212342b84c32095be767bfdd50c)
#         ;
#
#
#
#
#             var marker_4f6da9a2aa267417b7470416a568ffdf = L.marker(
#                 [68.0, 152.0],
#                 {}
#             ).addTo(marker_cluster_8ea98cf867f338aca70a2d75634c385c);
#
#
#         var popup_5aa08bb2565fe343bf8299c399a9

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c3f2e5e397d6ce608fea3569483bca5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c3f2e5e397d6ce608fea3569483bca5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c3f2e5e397d6ce608fea3569483bca5 = L.map(
#                 &quot;map_2c3f2e5e397d6ce608fea3569483bca5&quot;,
#                 {
#                     center: [11.39, -2.39],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7