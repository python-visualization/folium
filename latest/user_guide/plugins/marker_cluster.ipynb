# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d96ac28ad47018b321c5415d6d2865f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d96ac28ad47018b321c5415d6d2865f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d96ac28ad47018b321c5415d6d2865f2 = L.map(
#                 &quot;map_d96ac28ad47018b321c5415d6d2865f2&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e24638fe8fa787a9a712c3f546d7a79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e24638fe8fa787a9a712c3f546d7a79.addTo(map_d96ac28ad47018b321c5415d6d2865f2);
#
#
#             var marker_cluster_b7c02fe17ee64480f38f3a845009a00f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_9c57564f0e08b112b148540c998a9c0b = L.marker(
#                 [40.67, -73.94],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_b7c02fe17ee64480f38f3a845009a00f);
#
#
#             var icon_fbb0cd7e7045e67e6d9f49eb6548b961 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9c57564f0e08b112b148540c998a9c0b.setIcon(icon_fbb0cd7e7045e67e6d9f49eb6548b961);
#
#
#         var popup_b1f28c4b7ffcb546a075580b966159e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_e78e872a71b214f209dbf0584540b11f = $(`&lt;div id=&quot;html_e78e872a71b214f209dbf0584540b11f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_b1f28c4b7ffcb546a075580b966159e4.setContent(html_e78e872a71b214f209dbf0584540b11f);
#
#
#
#         marker_9c57564f0e08b112b148540c998a9c0b.bindPopup(popup_b1f28c4b7ffcb546a075580b966159e4)
#         ;
#
#
#
#
#             var marker_a269d8f57020163574ff0cbe4a34f0ff = L.marker(
#                 [44.67, -73.94],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_b7c02fe17ee64480f38f3a845009a00f);
#
#
#             var icon_2b1d2845b0d6446a8fd26a9920e5759d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a269d8f57020163574ff0cbe4a34f0ff.setIcon(icon_2b1d2845b0d6446a8fd26a9920e5759d);
#
#
#         var popup_b62454b39526bafcb2d7dc3d6557c24d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_36c68cf871247df00117a76158f9709b = $(`&lt;div id=&quot;html_36c68cf871247df00117a76158f9709b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_b62454b39526bafcb2d7dc3d6557c24d.setContent(html_36c68cf871247df00117a76158f9709b);
#
#
#
#         marker_a269d8f57020163574ff0cbe4a34f0ff.bindPopup(popup_b62454b39526bafcb2d7dc3d6557c24d)
#         ;
#
#
#
#
#             var marker_e12f0bbac91b5def6e2b807188e8a5eb = L.marker(
#                 [44.67, -71.94],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_b7c02fe17ee64480f38f3a845009a00f);
#
#
#         var popup_fa34d0cef7587dbd22dae3a77d9aafff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_2028ca6c42c8eae7dc3dc1bffbe13bf4 = $(`&lt;div id=&quot;html_2028ca6c42c8eae7dc3dc1bffbe13bf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fa34d0cef7587dbd22dae3a77d9a

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e48a5b6ef8751d62ef7e3a9727121c22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e48a5b6ef8751d62ef7e3a9727121c22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e48a5b6ef8751d62ef7e3a9727121c22 = L.map(
#                 &quot;map_e48a5b6ef8751d62ef7e3a9727121c22&quot;,
#                 {
#                     center: [-1.22, 6.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e073d07ad9aaa7e50599877bf0081032 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e073d07ad9aaa7e50599877bf0081032.addTo(map_e48a5b6ef8751d62ef7e3a9727121c22);
#
#
#             var marker_cluster_961c03e9bee893b762efcb155e8f4e2b = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_961c03e9bee893b762efcb155e8f4e2b.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_e525070f5db8c8bc68bc0616566a64cd = L.marker(
#                 [63.0, -113.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_961c03e9bee893b762efcb155e8f4e2b);
#
#
#         var popup_e8d1d53edb39590950908ea75774502a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_b5cd598777fda613c1865e7ead893689 = $(`&lt;div id=&quot;html_b5cd598777fda613c1865e7ead893689&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-113&lt;br&gt;lat:63&lt;/div&gt;`)[0];
#                 popup_e8d1d53edb39590950908ea75774502a.setContent(html_b5cd598777fda613c1865e7ead893689);
#
#
#
#         marker_e525070f5db8c8bc68bc0616566a64cd.bindPopup(popup_e8d1d53edb39590950908ea75774502a)
#         ;
#
#
#
#
#             var marker_f22d151fd07ffe9d4bb770a536b0ce6e = L.marker(
#                 [-39.0, 30.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_961c03e9bee893b762efcb155e8f4e2b);
#
#
#         var popup_303eac06b0cfd481383b74f9d1b3d56c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_3ee49dc80e37a3609477121c1f015718 = $(`&lt;div id=&quot;html_3ee49dc80e37a3609477121c1f015718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:30&lt;br&gt;lat:-39&lt;/div&gt;`)[0];
#                 popup_303eac06b0cfd481383b74f9d1b3d56c.setContent(html_3ee49dc80e37a3609477121c1f015718);
#
#
#
#         marker_f22d151fd07ffe9d4bb770a536b0ce6e.bindPopup(popup_303eac06b0cfd481383b74f9d1b3d56c)
#         ;
#
#
#
#
#             var marker_3e1176354c80dfd15014133b6b014bb0 = L.marker(
#                 [-88.0, -140.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_961c03e9bee893b762efcb155e8f4e2b);
#
#
#         var popup_eedf739cb7e25677ab1ea735206acc5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_032dd2d26215108255fcd9419c4bb647 = $(`&lt;div id=&quot;html_032dd2d26215108255fcd9419c4bb647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-140&lt;br&gt;lat:-88&lt;/div&gt;`)[0];
#                 popup_eedf739cb7e25677ab1ea735206acc5d.setContent(html_032dd2d26215108255fcd9419c4bb647);
#
#
#
#         marker_3e1176354c80dfd15014133b6b014bb0.bindPopup(popup_eedf739cb7e25677ab1ea735206acc5d)
#         ;
#
#
#
#
#             var marker_ee5a88f5b39eed8aad81cf63053b9ad4 = L.marker(
#                 [-80.0, 23.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_961c03e9bee893b762efcb155e8f4e2b);

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25eb14b830ea01601bfe7e54d81d87e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25eb14b830ea01601bfe7e54d81d87e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25eb14b830ea01601bfe7e54d81d87e6 = L.map(
#                 &quot;map_25eb14b830ea01601bfe7e54d81d87e6&quot;,
#                 {
#                     center: [-1.22, 6.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8494df9555576a6f5b5b1566545e933 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8494df9555576a6f5b5b1566545e933.addTo(map_25eb14b830ea01601bfe7e54d81d87e6);
#
#
#             var marker_cluster_255468ee26bbacb1457164e361d633c2 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_1b35cc73a589a79f4f4faf654fb6b48e = L.marker(
#                 [63.0, -113.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_255468ee26bbacb1457164e361d633c2);
#
#
#         var popup_13887ab2ab4705cd41a7c8ccd2b53f9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_52952dfca654eb0cb88c92e57d520870 = $(`&lt;div id=&quot;html_52952dfca654eb0cb88c92e57d520870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-113&lt;br&gt;lat:63&lt;/div&gt;`)[0];
#                 popup_13887ab2ab4705cd41a7c8ccd2b53f9a.setContent(html_52952dfca654eb0cb88c92e57d520870);
#
#
#
#         marker_1b35cc73a589a79f4f4faf654fb6b48e.bindPopup(popup_13887ab2ab4705cd41a7c8ccd2b53f9a)
#         ;
#
#
#
#
#             var marker_fe2131273e4b915016f21598086095ff = L.marker(
#                 [-39.0, 30.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_255468ee26bbacb1457164e361d633c2);
#
#
#         var popup_279f4d919ba712ee21bf69a0bb184d50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_79c742cad18132052b2b18ec60ff157f = $(`&lt;div id=&quot;html_79c742cad18132052b2b18ec60ff157f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:30&lt;br&gt;lat:-39&lt;/div&gt;`)[0];
#                 popup_279f4d919ba712ee21bf69a0bb184d50.setContent(html_79c742cad18132052b2b18ec60ff157f);
#
#
#
#         marker_fe2131273e4b915016f21598086095ff.bindPopup(popup_279f4d919ba712ee21bf69a0bb184d50)
#         ;
#
#
#
#
#             var marker_2cc436d820f9bda3ad4824305aa39c55 = L.marker(
#                 [-88.0, -140.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_255468ee26bbacb1457164e361d633c2);
#
#
#         var popup_6be3ef3b5316f56f278515033e197eb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_5bbc3555134472ab50cc997ddd59dc4e = $(`&lt;div id=&quot;html_5bbc3555134472ab50cc997ddd59dc4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-140&lt;br&gt;lat:-88&lt;/div&gt;`)[0];
#                 popup_6be3ef3b5316f56f278515033e197eb6.setContent(html_5bbc3555134472ab50cc997ddd59dc4e);
#
#
#
#         marker_2cc436d820f9bda3ad4824305aa39c55.bindPopup(popup_6be3ef3b5316f56f278515033e197eb6)
#         ;
#
#
#
#
#             var marker_91b38b9697f29105d583310f790f50c8 = L.marker(
#                 [-80.0, 23.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_255468ee26bbacb1457164e361d633c2);
#
#
#         var popup_20d7f2e9d91377c77bd9bd484542bfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_f9a083930a4ce89ab5c0df493c90f322 = $(`&lt;div id=&quot;html_f9a083930a4ce89ab5c0df493c90f322&quot; style

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a29b1ccdde4e4cab4e74aa7ac97001bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a29b1ccdde4e4cab4e74aa7ac97001bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a29b1ccdde4e4cab4e74aa7ac97001bb = L.map(
#                 &quot;map_a29b1ccdde4e4cab4e74aa7ac97001bb&quot;,
#                 {
#                     center: [-1.22, 6.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c61fd3925c22c63eb0242e2f8bf5a16 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c61fd3925c22c63eb0242e2f8bf5a16.addTo(map_a29b1ccdde4e4cab4e74aa7ac97001bb);
#
#
#             var fast_marker_cluster_90698a9e98eadf4a2371485124044a27 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[63.0, -113.0], [-39.0, 30.0], [-88.0, -140.0], [-80.0, 23.0], [-71.0, 171.0], [-79.0, -94.0], [-59.0, -91.0], [41.0, 54.0], [-28.0, -9.0], [-72.0, -147.0], [-53.0, -16.0], [67.0, -70.0], [74.0, 129.0], [-88.0, -54.0], [35.0, 144.0], [48.0, 72.0], [-70.0, -76.0], [51.0, 83.0], [82.0, -64.0], [-77.0, -167.0], [-59.0, 160.0], [14.0, 66.0], [-65.0, 115.0], [-60.0, 88.0], [31.0, 127.0], [68.0, 137.0], [-17.0, -100.0], [24.0, 60.0], [77.0, -165.0], [-71.0, 9.0], [-5.0, 142.0], [47.0, 179.0], [1.0, -12.0], [53.0, 3.0], [49.0, -95.0], [86.0, 172.0], [-14.0, -9.0], [41.0, 117.0], [84.0, 166.0], [-37.0, 91.0], [-74.0, -29.0], [-22.0, 143.0], [10.0, -76.0], [-47.0, -107.0], [-49.0, 150.0], [61.0, 14.0], [77.0, -6.0], [68.0, -101.0], [10.0, -155.0], [40.0, 142.0], [-74.0, -170.0], [-6.0, 172.0], [-67.0, -80.0], [-21.0, -32.0], [21.0, -153.0], [-86.0, -162.0], [-21.0, -126.0], [-61.0, 141.0], [-34.0, -163.0], [41.0, 79.0], [53.0, -95.0], [48.0, -2.0], [-80.0, 64.0], [-40.0, 135.0], [-3.0, -30.0], [-89.0, -33.0], [40.0, 58.0], [59.0, 1.0], [-59.0, -149.0], [12.0, 25.0], [55.0, -71.0], [75.0, 9.0], [18.0, 2.0], [-27.0, -34.0], [-33.0, 113.0], [11.0, 153.0], [56.0, 179.0], [-9.0, 36.0], [-61.0, -87.0], [-23.0, -26.0], [70.0, 8.0], [74.0, 6.0], [78.0, 81.0], [-17.0, -80.0], [-85.0, 101.0], [81.0, 163.0], [28.0, -87.0], [-36.0, 161.0], [58.0, -50.0], [-22.0, -64.0], [-10.0, -78.0], [-79.0, 4.0], [66.0, -142.0], [-52.0, -165.0], [-7.0, 41.0], [-13.0, -35.0], [1.0, 135.0], [84.0, -17.0], [-29.0, 33.0], [15.0, 30.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_a29b1ccdde4e4cab4e74aa7ac97001bb);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_90698a9e98eadf4a2371485124044a27.addTo(map_a29b1ccdde4e4cab4e74aa7ac97001bb);
#
#
#             var layer_control_5753a79f654b0fc78413813cc072cb8d_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_3c61fd3925c22c63eb0242e2f8bf5a16,
#                 },
#                 overlays :  {
#                     &quot;macro_element_90698a9e98eadf4a2371485124044a27&quot; : fast_marker_cluster_90698a9e98eadf4a2371485124044a27,
#                 },
#             };
#             let layer_control_5753a79f654b0fc78413813cc072cb8d = L.control.layers(
#                 layer_control_5753a79f654b0fc78413813cc072cb8d_layers.base_layers,
#                 layer_control_5753a79f654b0fc78413813cc072cb8d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_a29b1ccdde4e4cab4e74aa7ac97001bb);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8b0e8a442a3a382535beb0672f081c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8b0e8a442a3a382535beb0672f081c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8b0e8a442a3a382535beb0672f081c6 = L.map(
#                 &quot;map_c8b0e8a442a3a382535beb0672f081c6&quot;,
#                 {
#                     center: [-1.22, 6.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30d8951518ca973a860ad7c4e7cc3659 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30d8951518ca973a860ad7c4e7cc3659.addTo(map_c8b0e8a442a3a382535beb0672f081c6);
#
#
#             var fast_marker_cluster_fd3b95ba0233be9b4f9c63def6c91569 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[63.0, -113.0], [-39.0, 30.0], [-88.0, -140.0], [-80.0, 23.0], [-71.0, 171.0], [-79.0, -94.0], [-59.0, -91.0], [41.0, 54.0], [-28.0, -9.0], [-72.0, -147.0], [-53.0, -16.0], [67.0, -70.0], [74.0, 129.0], [-88.0, -54.0], [35.0, 144.0], [48.0, 72.0], [-70.0, -76.0], [51.0, 83.0], [82.0, -64.0], [-77.0, -167.0], [-59.0, 160.0], [14.0, 66.0], [-65.0, 115.0], [-60.0, 88.0], [31.0, 127.0], [68.0, 137.0], [-17.0, -100.0], [24.0, 60.0], [77.0, -165.0], [-71.0, 9.0], [-5.0, 142.0], [47.0, 179.0], [1.0, -12.0], [53.0, 3.0], [49.0, -95.0], [86.0, 172.0], [-14.0, -9.0], [41.0, 117.0], [84.0, 166.0], [-37.0, 91.0], [-74.0, -29.0], [-22.0, 143.0], [10.0, -76.0], [-47.0, -107.0], [-49.0, 150.0], [61.0, 14.0], [77.0, -6.0], [68.0, -101.0], [10.0, -155.0], [40.0, 142.0], [-74.0, -170.0], [-6.0, 172.0], [-67.0, -80.0], [-21.0, -32.0], [21.0, -153.0], [-86.0, -162.0], [-21.0, -126.0], [-61.0, 141.0], [-34.0, -163.0], [41.0, 79.0], [53.0, -95.0], [48.0, -2.0], [-80.0, 64.0], [-40.0, 135.0], [-3.0, -30.0], [-89.0, -33.0], [40.0, 58.0], [59.0, 1.0], [-59.0, -149.0], [12.0, 25.0], [55.0, -71.0], [75.0, 9.0], [18.0, 2.0], [-27.0, -34.0], [-33.0, 113.0], [11.0, 153.0], [56.0, 179.0], [-9.0, 36.0], [-61.0, -87.0], [-23.0, -26.0], [70.0, 8.0], [74.0, 6.0], [78.0, 81.0], [-17.0, -80.0], [-85.0, 101.0], [81.0, 163.0], [28.0, -87.0], [-36.0, 161.0], [58.0, -50.0], [-22.0, -64.0], [-10.0, -78.0], [-79.0, 4.0], [66.0, -142.0], [-52.0, -165.0], [-7.0, 41.0], [-13.0, -35.0], [1.0, 135.0], [84.0, -17.0], [-29.0, 33.0], [15.0, 30.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_c8b0e8a442a3a382535beb0672f081c6);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_fd3b95ba0233be9b4f9c63def6c91569.addTo(map_c8b0e8a442a3a382535beb0672f081c6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
