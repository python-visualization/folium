# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bda2bbb081bd01b516768ceced2b1da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bda2bbb081bd01b516768ceced2b1da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bda2bbb081bd01b516768ceced2b1da = L.map(
#                 &quot;map_3bda2bbb081bd01b516768ceced2b1da&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_889d8c08a9b7687a7765f291d6a2767b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_889d8c08a9b7687a7765f291d6a2767b.addTo(map_3bda2bbb081bd01b516768ceced2b1da);
#
#
#             var marker_cluster_ccbb2a55a73783b1ba8edb58c9385451 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_fcdbe33236987edd405859f202bf392b = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_ccbb2a55a73783b1ba8edb58c9385451);
#
#
#             var icon_b65084b682342e00f6475f726e6e7142 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fcdbe33236987edd405859f202bf392b.setIcon(icon_b65084b682342e00f6475f726e6e7142);
#
#
#         var popup_d845b5905947ad0658ea694e88edb735 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4db33fa9c6900827e0ed1e32755badb0 = $(`&lt;div id=&quot;html_4db33fa9c6900827e0ed1e32755badb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_d845b5905947ad0658ea694e88edb735.setContent(html_4db33fa9c6900827e0ed1e32755badb0);
#
#
#
#         marker_fcdbe33236987edd405859f202bf392b.bindPopup(popup_d845b5905947ad0658ea694e88edb735)
#         ;
#
#
#
#
#             var marker_fa3619b52d445725f2e42a8d165bda02 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_ccbb2a55a73783b1ba8edb58c9385451);
#
#
#             var icon_f87eeca51d662274bf641d8988bf57be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa3619b52d445725f2e42a8d165bda02.setIcon(icon_f87eeca51d662274bf641d8988bf57be);
#
#
#         var popup_48e6b5e154e4c955f74443fd812c8f67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3735b0e1ee8d0a62f2909e4a704129de = $(`&lt;div id=&quot;html_3735b0e1ee8d0a62f2909e4a704129de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_48e6b5e154e4c955f74443fd812c8f67.setContent(html_3735b0e1ee8d0a62f2909e4a704129de);
#
#
#
#         marker_fa3619b52d445725f2e42a8d165bda02.bindPopup(popup_48e6b5e154e4c955f74443fd812c8f67)
#         ;
#
#
#
#
#             var marker_1bd7b46b69c56bb70956234ccba842ad = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_ccbb2a55a73783b1ba8edb58c9385451);
#
#
#         var popup_94f98148299a3d425ffd7e0a6dcfd88e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bad1d51ee015a83245dd3046a45616c1 = $(`&lt;div id=&quot;html_bad1d51ee015a83245dd3046a45616c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_94f98148299a3d425ffd7e0a6dcfd88e.setContent(html_bad1d51ee015a83245dd3046a45616c1);
#
#
#
#         marker_1bd7b46b69c56bb70956234ccba842ad.bindPopup(popup_94f98148299a3d425ffd7e0a6dcfd88e)
#         ;
#
#
#
#
#             marker_cluster_ccbb2a55a73783b1ba8edb58c9385451.addTo(map_3bda2bbb081bd01b516768ceced2b1da);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_504ef530cfcb94ba95d2ede9d93fc963 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_504ef530cfcb94ba95d2ede9d93fc963&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_504ef530cfcb94ba95d2ede9d93fc963 = L.map(
#                 &quot;map_504ef530cfcb94ba95d2ede9d93fc963&quot;,
#                 {
#                     center: [0.43, 3.06],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8c5f9cf76a463b18f246eeb7dc8ef51 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a8c5f9cf76a463b18f246eeb7dc8ef51.addTo(map_504ef530cfcb94ba95d2ede9d93fc963);
#
#
#             var marker_cluster_fa86ac2fc6b535acacfd9596ee6c4e6b = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_fa86ac2fc6b535acacfd9596ee6c4e6b.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_d9825f8cdc1c382af9e0ed0795f3bb6c = L.marker(
#                 [69.0, -54.0],
#                 {}
#             ).addTo(marker_cluster_fa86ac2fc6b535acacfd9596ee6c4e6b);
#
#
#         var popup_e2cfaf7c7d347c3bbc546d92918a25fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d10b34f3854880e971390660f5154a1 = $(`&lt;div id=&quot;html_7d10b34f3854880e971390660f5154a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-54&lt;br&gt;lat:69&lt;/div&gt;`)[0];
#                 popup_e2cfaf7c7d347c3bbc546d92918a25fc.setContent(html_7d10b34f3854880e971390660f5154a1);
#
#
#
#         marker_d9825f8cdc1c382af9e0ed0795f3bb6c.bindPopup(popup_e2cfaf7c7d347c3bbc546d92918a25fc)
#         ;
#
#
#
#
#             var marker_5ba01ce3a6d7d570455bceee12436f1c = L.marker(
#                 [63.0, -94.0],
#                 {}
#             ).addTo(marker_cluster_fa86ac2fc6b535acacfd9596ee6c4e6b);
#
#
#         var popup_237f345d0a6a429d67b22f183700d286 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ab85e486ced58437b3bd9e8e8545ba5 = $(`&lt;div id=&quot;html_9ab85e486ced58437b3bd9e8e8545ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-94&lt;br&gt;lat:63&lt;/div&gt;`)[0];
#                 popup_237f345d0a6a429d67b22f183700d286.setContent(html_9ab85e486ced58437b3bd9e8e8545ba5);
#
#
#
#         marker_5ba01ce3a6d7d570455bceee12436f1c.bindPopup(popup_237f345d0a6a429d67b22f183700d286)
#         ;
#
#
#
#
#             var marker_07e20151028e9f18c3fdc4d3c59da1aa = L.marker(
#                 [-30.0, 99.0],
#                 {}
#             ).addTo(marker_cluster_fa86ac2fc6b535acacfd9596ee6c4e6b);
#
#
#         var popup_7dfab20853c846f1aa16a0ae4cba608b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9bd0122c26f4b25757da1e7ac98db29 = $(`&lt;div id=&quot;html_f9bd0122c26f4b25757da1e7ac98db29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:99&lt;br&gt;lat:-30&lt;/div&gt;`)[0];
#                 popup_7dfab20853c846f1aa16a0ae4cba608b.setContent(html_f9bd0122c26f4b25757da1e7ac98db29);
#
#
#
#         marker_07e20151028e9f18c3fdc4d3c59da1aa.bindPopup(popup_7dfab20853c846f1aa16a0ae4cba608b)
#         ;
#
#
#
#
#             var marker_a9dc31a33749c9fccb09f8d8c1e44355 = L.marker(
#                 [22.0, 42.0],
#                 {}
#             ).addTo(marker_cluster_fa86ac2fc6b535acacfd9596ee6c4e6b);
#
#
#         var popup_8dae62fdab3daef31ae984bdfab4f6a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d87d94de26328f35399f20536ebf9327 = $(`&lt;div id=&quot;html_d87d94de26328f35399f20536ebf9327&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:42&lt;br&gt;lat:22&lt;/div&gt;`)[0];
#                 popup_8dae62fdab3daef31ae984bdfab4f6a5.setContent(html_d87d94de26328f35399f20536ebf9327);
#
#
#
#         marker_a9dc31a33749c9fccb09f8

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2beb9a71411b54e704b87e2984f54889 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2beb9a71411b54e704b87e2984f54889&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2beb9a71411b54e704b87e2984f54889 = L.map(
#                 &quot;map_2beb9a71411b54e704b87e2984f54889&quot;,
#                 {
#                     center: [0.43, 3.06],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4d01fbfb6fdfc2353ce6972c89d84fb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c4d01fbfb6fdfc2353ce6972c89d84fb.addTo(map_2beb9a71411b54e704b87e2984f54889);
#
#
#             var marker_cluster_37a4b998c17a452e7880d9bfed049ac3 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f4b813f3002e5c48d557d87625acb892 = L.marker(
#                 [69.0, -54.0],
#                 {}
#             ).addTo(marker_cluster_37a4b998c17a452e7880d9bfed049ac3);
#
#
#         var popup_a9b4f41bd904627f6f47d632e8a161f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a3b712d233df8ad6db369b7d40b824e = $(`&lt;div id=&quot;html_7a3b712d233df8ad6db369b7d40b824e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-54&lt;br&gt;lat:69&lt;/div&gt;`)[0];
#                 popup_a9b4f41bd904627f6f47d632e8a161f1.setContent(html_7a3b712d233df8ad6db369b7d40b824e);
#
#
#
#         marker_f4b813f3002e5c48d557d87625acb892.bindPopup(popup_a9b4f41bd904627f6f47d632e8a161f1)
#         ;
#
#
#
#
#             var marker_ed663e77529e0490a60cc7bbf7f49e3a = L.marker(
#                 [63.0, -94.0],
#                 {}
#             ).addTo(marker_cluster_37a4b998c17a452e7880d9bfed049ac3);
#
#
#         var popup_d91226cd9afe0b4ec19e120781187077 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82d06d5690a6e64f035093481b9b3f89 = $(`&lt;div id=&quot;html_82d06d5690a6e64f035093481b9b3f89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-94&lt;br&gt;lat:63&lt;/div&gt;`)[0];
#                 popup_d91226cd9afe0b4ec19e120781187077.setContent(html_82d06d5690a6e64f035093481b9b3f89);
#
#
#
#         marker_ed663e77529e0490a60cc7bbf7f49e3a.bindPopup(popup_d91226cd9afe0b4ec19e120781187077)
#         ;
#
#
#
#
#             var marker_c43af0837534d6b6b1e16cbc211cd590 = L.marker(
#                 [-30.0, 99.0],
#                 {}
#             ).addTo(marker_cluster_37a4b998c17a452e7880d9bfed049ac3);
#
#
#         var popup_be8d7262c6e99b74b2d548d2344be470 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94de7f01626638e4e3e53f548fc94fbb = $(`&lt;div id=&quot;html_94de7f01626638e4e3e53f548fc94fbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:99&lt;br&gt;lat:-30&lt;/div&gt;`)[0];
#                 popup_be8d7262c6e99b74b2d548d2344be470.setContent(html_94de7f01626638e4e3e53f548fc94fbb);
#
#
#
#         marker_c43af0837534d6b6b1e16cbc211cd590.bindPopup(popup_be8d7262c6e99b74b2d548d2344be470)
#         ;
#
#
#
#
#             var marker_9c02d1f007a946f66c5377702a4e55e5 = L.marker(
#                 [22.0, 42.0],
#                 {}
#             ).addTo(marker_cluster_37a4b998c17a452e7880d9bfed049ac3);
#
#
#         var popup_aa0bb365082e5695d8e3df517870f6e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_162b48a47d8474ceaaf4a92d35601774 = $(`&lt;div id=&quot;html_162b48a47d8474ceaaf4a92d35601774&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:42&lt;br&gt;lat:22&lt;/div&gt;`)[0];
#                 popup_aa0bb365082e5695d8e3df517870f6e4.setContent(html_162b48a47d8474ceaaf4a92d35601774);
#
#
#
#         marker_9c02d1f007a946f66c5377702a4e55e5.bindPopup(popup_aa0bb365082e5695d8e3df517870f6e4)
#         ;
#
#
#
#
#             var marker_911c7ea4f13a60b9af3eff7d5aeac44a = L.marker(
#                 [87.0, -43.0],
#                 {}
#             ).addTo(marker_cluster_37a4b998c17a452e7880d9bfed049ac3);
#
#
#         var popup_6cb7948207eab5618e37b6d99f6ba9

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4571b6fc1207dec08fb7ee11ab93b130 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4571b6fc1207dec08fb7ee11ab93b130&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4571b6fc1207dec08fb7ee11ab93b130 = L.map(
#                 &quot;map_4571b6fc1207dec08fb7ee11ab93b130&quot;,
#                 {
#                     center: [0.43, 3.06],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e55aee177727854e47ef0ec52cb730a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_