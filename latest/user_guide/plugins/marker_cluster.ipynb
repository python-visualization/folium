# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b74a841270239923f4f2f0ca5e7b34e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b74a841270239923f4f2f0ca5e7b34e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b74a841270239923f4f2f0ca5e7b34e5 = L.map(
#                 &quot;map_b74a841270239923f4f2f0ca5e7b34e5&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e19981ca0c509a959929eb00c6bae8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e19981ca0c509a959929eb00c6bae8b.addTo(map_b74a841270239923f4f2f0ca5e7b34e5);
#
#
#             var marker_cluster_a5fef6f014d093c772377321a74d3666 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_83a47f4490f188b1c49c51cb559c9e36 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a5fef6f014d093c772377321a74d3666);
#
#
#             var icon_8de2b8a1308e18adc022f0e27f696f65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83a47f4490f188b1c49c51cb559c9e36.setIcon(icon_8de2b8a1308e18adc022f0e27f696f65);
#
#
#         var popup_69ef4c0ba42f2557743fb99fac376fae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb83f1196dba8b86880988c9aab896c8 = $(`&lt;div id=&quot;html_eb83f1196dba8b86880988c9aab896c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_69ef4c0ba42f2557743fb99fac376fae.setContent(html_eb83f1196dba8b86880988c9aab896c8);
#
#
#
#         marker_83a47f4490f188b1c49c51cb559c9e36.bindPopup(popup_69ef4c0ba42f2557743fb99fac376fae)
#         ;
#
#
#
#
#             var marker_cab215b69080a5865f4181c68b3aa898 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a5fef6f014d093c772377321a74d3666);
#
#
#             var icon_f48216542ac1ac26a9f2d5497c0b26e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cab215b69080a5865f4181c68b3aa898.setIcon(icon_f48216542ac1ac26a9f2d5497c0b26e7);
#
#
#         var popup_4ab700c9c24aa15b5ad68425e2bd124c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43fb916f8edef7b685204d32dbb68295 = $(`&lt;div id=&quot;html_43fb916f8edef7b685204d32dbb68295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_4ab700c9c24aa15b5ad68425e2bd124c.setContent(html_43fb916f8edef7b685204d32dbb68295);
#
#
#
#         marker_cab215b69080a5865f4181c68b3aa898.bindPopup(popup_4ab700c9c24aa15b5ad68425e2bd124c)
#         ;
#
#
#
#
#             var marker_9e6bb8a07e9395d34f6bb273cdf14636 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_a5fef6f014d093c772377321a74d3666);
#
#
#         var popup_95b8d6517bacc85ed46d38eac5a472b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8b5dbee8ad152652ccd67a4bc20d79c = $(`&lt;div id=&quot;html_c8b5dbee8ad152652ccd67a4bc20d79c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_95b8d6517bacc85ed46d38eac5a472b0.setContent(html_c8b5dbee8ad152652ccd67a4bc20d79c);
#
#
#
#         marker_9e6bb8a07e9395d34f6bb273cdf14636.bindPopup(popup_95b8d6517bacc85ed46d38eac5a472b0)
#         ;
#
#
#
#
#             marker_cluster_a5fef6f014d093c772377321a74d3666.addTo(map_b74a841270239923f4f2f0ca5e7b34e5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_600012b178451c6d01fb38e8dcc4ede1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_600012b178451c6d01fb38e8dcc4ede1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_600012b178451c6d01fb38e8dcc4ede1 = L.map(
#                 &quot;map_600012b178451c6d01fb38e8dcc4ede1&quot;,
#                 {
#                     center: [-1.95, -6.32],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fda0d7f1bbac44f6e45c3425916a5b2e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fda0d7f1bbac44f6e45c3425916a5b2e.addTo(map_600012b178451c6d01fb38e8dcc4ede1);
#
#
#             var marker_cluster_0f4296525c29883f90b41bb08a3a7e6b = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_0f4296525c29883f90b41bb08a3a7e6b.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_48ef1b7c97690bc21666f054752cf5c4 = L.marker(
#                 [-25.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_0f4296525c29883f90b41bb08a3a7e6b);
#
#
#         var popup_145a57015d9d36fafba71ab4e758c8c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_430c1af29b1003ab24166752c6e235b1 = $(`&lt;div id=&quot;html_430c1af29b1003ab24166752c6e235b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-25&lt;/div&gt;`)[0];
#                 popup_145a57015d9d36fafba71ab4e758c8c1.setContent(html_430c1af29b1003ab24166752c6e235b1);
#
#
#
#         marker_48ef1b7c97690bc21666f054752cf5c4.bindPopup(popup_145a57015d9d36fafba71ab4e758c8c1)
#         ;
#
#
#
#
#             var marker_cd5862fc1df2f9e387959ce237962b21 = L.marker(
#                 [3.0, -59.0],
#                 {}
#             ).addTo(marker_cluster_0f4296525c29883f90b41bb08a3a7e6b);
#
#
#         var popup_34a01907e67d76c9c1cfe37f6e95c4e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7def3e417591912463d8f087a3263e85 = $(`&lt;div id=&quot;html_7def3e417591912463d8f087a3263e85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-59&lt;br&gt;lat:3&lt;/div&gt;`)[0];
#                 popup_34a01907e67d76c9c1cfe37f6e95c4e3.setContent(html_7def3e417591912463d8f087a3263e85);
#
#
#
#         marker_cd5862fc1df2f9e387959ce237962b21.bindPopup(popup_34a01907e67d76c9c1cfe37f6e95c4e3)
#         ;
#
#
#
#
#             var marker_e56912bc423181a096515357dc3acd2b = L.marker(
#                 [-55.0, 61.0],
#                 {}
#             ).addTo(marker_cluster_0f4296525c29883f90b41bb08a3a7e6b);
#
#
#         var popup_7d941fb69b15d8250d1f625dc89e55f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ea360e087e6c93609df60bcb503b954 = $(`&lt;div id=&quot;html_4ea360e087e6c93609df60bcb503b954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:61&lt;br&gt;lat:-55&lt;/div&gt;`)[0];
#                 popup_7d941fb69b15d8250d1f625dc89e55f9.setContent(html_4ea360e087e6c93609df60bcb503b954);
#
#
#
#         marker_e56912bc423181a096515357dc3acd2b.bindPopup(popup_7d941fb69b15d8250d1f625dc89e55f9)
#         ;
#
#
#
#
#             var marker_b352f3174cd32683aa090c009449857e = L.marker(
#                 [-61.0, 0.0],
#                 {}
#             ).addTo(marker_cluster_0f4296525c29883f90b41bb08a3a7e6b);
#
#
#         var popup_e71bcad6d919b7380612ba05e13e8405 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35766f7afe98479cb534ae6026d4510a = $(`&lt;div id=&quot;html_35766f7afe98479cb534ae6026d4510a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:0&lt;br&gt;lat:-61&lt;/div&gt;`)[0];
#                 popup_e71bcad6d919b7380612ba05e13e8405.setContent(html_35766f7afe98479cb534ae6026d4510a);
#
#
#
#         marker_b352f3174cd32683aa090c00944

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5e3cc86bd3bc5309c27b8efacd8aba5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5e3cc86bd3bc5309c27b8efacd8aba5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5e3cc86bd3bc5309c27b8efacd8aba5 = L.map(
#                 &quot;map_a5e3cc86bd3bc5309c27b8efacd8aba5&quot;,
#                 {
#                     center: [-1.95, -6.32],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b8801e05c86ad33bf7b3b98c0f3900b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b8801e05c86ad33bf7b3b98c0f3900b.addTo(map_a5e3cc86bd3bc5309c27b8efacd8aba5);
#
#
#             var marker_cluster_2a93a7b8365ac340181e0dd7922138ed = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_ee6fb7927a70bd91d7c6c03f5c8a2408 = L.marker(
#                 [-25.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_2a93a7b8365ac340181e0dd7922138ed);
#
#
#         var popup_7dd57790acbfbcd7b74f6a796f36564e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7beea3e7d97412c64928c3764f07abc3 = $(`&lt;div id=&quot;html_7beea3e7d97412c64928c3764f07abc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-25&lt;/div&gt;`)[0];
#                 popup_7dd57790acbfbcd7b74f6a796f36564e.setContent(html_7beea3e7d97412c64928c3764f07abc3);
#
#
#
#         marker_ee6fb7927a70bd91d7c6c03f5c8a2408.bindPopup(popup_7dd57790acbfbcd7b74f6a796f36564e)
#         ;
#
#
#
#
#             var marker_ca1a192937e5e39a314a910400eb427a = L.marker(
#                 [3.0, -59.0],
#                 {}
#             ).addTo(marker_cluster_2a93a7b8365ac340181e0dd7922138ed);
#
#
#         var popup_21613bc4ff3b7af1cfdb3a761a2af96e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fba1f1c221bcfde03d3703a5a3b46a6c = $(`&lt;div id=&quot;html_fba1f1c221bcfde03d3703a5a3b46a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-59&lt;br&gt;lat:3&lt;/div&gt;`)[0];
#                 popup_21613bc4ff3b7af1cfdb3a761a2af96e.setContent(html_fba1f1c221bcfde03d3703a5a3b46a6c);
#
#
#
#         marker_ca1a192937e5e39a314a910400eb427a.bindPopup(popup_21613bc4ff3b7af1cfdb3a761a2af96e)
#         ;
#
#
#
#
#             var marker_408f711d311ace35059ece3a522d3a16 = L.marker(
#                 [-55.0, 61.0],
#                 {}
#             ).addTo(marker_cluster_2a93a7b8365ac340181e0dd7922138ed);
#
#
#         var popup_6a514b81bda980c88e2f2a418f671514 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8ad61c837c1e221f35ecc6404d727b2 = $(`&lt;div id=&quot;html_b8ad61c837c1e221f35ecc6404d727b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:61&lt;br&gt;lat:-55&lt;/div&gt;`)[0];
#                 popup_6a514b81bda980c88e2f2a418f671514.setContent(html_b8ad61c837c1e221f35ecc6404d727b2);
#
#
#
#         marker_408f711d311ace35059ece3a522d3a16.bindPopup(popup_6a514b81bda980c88e2f2a418f671514)
#         ;
#
#
#
#
#             var marker_6646d32796c7b5d85846004bd499042c = L.marker(
#                 [-61.0, 0.0],
#                 {}
#             ).addTo(marker_cluster_2a93a7b8365ac340181e0dd7922138ed);
#
#
#         var popup_5dbdb1feffcf5de6e27fa6c240ab9bfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_702df1e8cfbb519d721605359285fc8b = $(`&lt;div id=&quot;html_702df1e8cfbb519d721605359285fc8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:0&lt;br&gt;lat:-61&lt;/div&gt;`)[0];
#                 popup_5dbdb1feffcf5de6e27fa6c240ab9bfe.setContent(html_702df1e8cfbb519d721605359285fc8b);
#
#
#
#         marker_6646d32796c7b5d85846004bd499042c.bindPopup(popup_5dbdb1feffcf5de6e27fa6c240ab9bfe)
#         ;
#
#
#
#
#             var marker_683c363287550efc5be32ac2a93a3962 = L.marker(
#                 [28.0, 178.0],
#                 {}
#             ).addTo(marker_cluster_2a93a7b8365ac340181e0dd7922138ed);
#
#
#         var popup_07493893b3d33e5a405f2447be03f074 =

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1dfce4dc7021998e912445aa384b109c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1dfce4dc7021998e912445aa384b109c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1dfce4dc7021998e912445aa384b109c = L.map(
#                 &quot;map_1dfce4dc7021998e912445aa384b109c&quot;,
#                 {
#                     center: [-1.95, -6.32],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a8115bb7dad80c4d8946ce0b24aa31a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_