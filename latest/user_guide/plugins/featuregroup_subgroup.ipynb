# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c9174e96e47b47ccb49d640fb684f93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c9174e96e47b47ccb49d640fb684f93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c9174e96e47b47ccb49d640fb684f93 = L.map(
#                 &quot;map_4c9174e96e47b47ccb49d640fb684f93&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a26258d44bbe08c0e990e9e7b62c3f5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a26258d44bbe08c0e990e9e7b62c3f5f.addTo(map_4c9174e96e47b47ccb49d640fb684f93);
#
#
#             var feature_group_8196eced4b3217f4a953fcee8ce35c45 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_8196eced4b3217f4a953fcee8ce35c45.addTo(map_4c9174e96e47b47ccb49d640fb684f93);
#
#
#             var feature_group_sub_group_62c8f402d66e0f6d9d7667452e2246e2 = L.featureGroup.subGroup(
#                 feature_group_8196eced4b3217f4a953fcee8ce35c45
#             );
#
#
#             var marker_a69a24b8e2d9a17b6ec3b7cc78900ad3 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_62c8f402d66e0f6d9d7667452e2246e2);
#
#
#             var marker_3bac247d31241d3bb1eb70fbe72e0ff0 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_62c8f402d66e0f6d9d7667452e2246e2);
#
#
#             feature_group_sub_group_62c8f402d66e0f6d9d7667452e2246e2.addTo(map_4c9174e96e47b47ccb49d640fb684f93);
#
#
#             var feature_group_sub_group_5bf990282716f20c6ac0f14aab4ffa99 = L.featureGroup.subGroup(
#                 feature_group_8196eced4b3217f4a953fcee8ce35c45
#             );
#
#
#             var marker_fe1fe97f2d5befc702f6ee9804376687 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5bf990282716f20c6ac0f14aab4ffa99);
#
#
#             var marker_c2d6d8427df6208be6c77520154ad636 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5bf990282716f20c6ac0f14aab4ffa99);
#
#
#             feature_group_sub_group_5bf990282716f20c6ac0f14aab4ffa99.addTo(map_4c9174e96e47b47ccb49d640fb684f93);
#
#
#             var layer_control_0aa03cf509e92fe44e7d40ff8c08acb6_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a26258d44bbe08c0e990e9e7b62c3f5f,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_8196eced4b3217f4a953fcee8ce35c45,
#                     &quot;group1&quot; : feature_group_sub_group_62c8f402d66e0f6d9d7667452e2246e2,
#                     &quot;group2&quot; : feature_group_sub_group_5bf990282716f20c6ac0f14aab4ffa99,
#                 },
#             };
#             let layer_control_0aa03cf509e92fe44e7d40ff8c08acb6 = L.control.layers(
#                 layer_control_0aa03cf509e92fe44e7d40ff8c08acb6_layers.base_layers,
#                 layer_control_0aa03cf509e92fe44e7d40ff8c08acb6_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4c9174e96e47b47ccb49d640fb684f93);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_567655e1e5caa34806083a554ad71bed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_567655e1e5caa34806083a554ad71bed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_567655e1e5caa34806083a554ad71bed = L.map(
#                 &quot;map_567655e1e5caa34806083a554ad71bed&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cba94fc30e1342107a0b8e71ce492b0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cba94fc30e1342107a0b8e71ce492b0a.addTo(map_567655e1e5caa34806083a554ad71bed);
#
#
#             var marker_cluster_8d6b6267e7cc4c1d3068ee2ea76d21ee = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_8d6b6267e7cc4c1d3068ee2ea76d21ee.addTo(map_567655e1e5caa34806083a554ad71bed);
#
#
#             var feature_group_sub_group_83f98e95d18c1635c880c7ad395e3724 = L.featureGroup.subGroup(
#                 marker_cluster_8d6b6267e7cc4c1d3068ee2ea76d21ee
#             );
#
#
#             var marker_8196d516bd9efa7826b90c4f3aeac106 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_83f98e95d18c1635c880c7ad395e3724);
#
#
#             var marker_acb454958dd3a3d47280337e221539de = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_83f98e95d18c1635c880c7ad395e3724);
#
#
#             feature_group_sub_group_83f98e95d18c1635c880c7ad395e3724.addTo(map_567655e1e5caa34806083a554ad71bed);
#
#
#             var feature_group_sub_group_25d19c1f902bab437ccb034cd6ce5620 = L.featureGroup.subGroup(
#                 marker_cluster_8d6b6267e7cc4c1d3068ee2ea76d21ee
#             );
#
#
#             var marker_ea0be8015809b0e227d529818669bda4 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_25d19c1f902bab437ccb034cd6ce5620);
#
#
#             var marker_0857f8402ce96ff4a066640182f0b2cb = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_25d19c1f902bab437ccb034cd6ce5620);
#
#
#             feature_group_sub_group_25d19c1f902bab437ccb034cd6ce5620.addTo(map_567655e1e5caa34806083a554ad71bed);
#
#
#             var layer_control_a3b7085ad8ae1aa5a180b9b03a1fe082_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cba94fc30e1342107a0b8e71ce492b0a,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_83f98e95d18c1635c880c7ad395e3724,
#                     &quot;group2&quot; : feature_group_sub_group_25d19c1f902bab437ccb034cd6ce5620,
#                 },
#             };
#             let layer_control_a3b7085ad8ae1aa5a180b9b03a1fe082 = L.control.layers(
#                 layer_control_a3b7085ad8ae1aa5a180b9b03a1fe082_layers.base_layers,
#                 layer_control_a3b7085ad8ae1aa5a180b9b03a1fe082_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_567655e1e5caa34806083a554ad71bed);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
