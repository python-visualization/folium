# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84d8bc3904c5c990ef5fbafeb6a3fbcc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84d8bc3904c5c990ef5fbafeb6a3fbcc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84d8bc3904c5c990ef5fbafeb6a3fbcc = L.map(
#                 &quot;map_84d8bc3904c5c990ef5fbafeb6a3fbcc&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_853277e12a1cd6360cd03bae5f4faccd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_853277e12a1cd6360cd03bae5f4faccd.addTo(map_84d8bc3904c5c990ef5fbafeb6a3fbcc);
#
#
#             var feature_group_25081a62432c90c7b53e9c1c58a2f63c = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_25081a62432c90c7b53e9c1c58a2f63c.addTo(map_84d8bc3904c5c990ef5fbafeb6a3fbcc);
#
#
#             var feature_group_sub_group_546a7fff523b6b458c7b391d44be5216 = L.featureGroup.subGroup(
#                 feature_group_25081a62432c90c7b53e9c1c58a2f63c
#             );
#
#
#             var marker_f437d8facf79241915729c28494728e7 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_546a7fff523b6b458c7b391d44be5216);
#
#
#             var marker_c4c79004da1670b4b41e28b4a1993dac = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_546a7fff523b6b458c7b391d44be5216);
#
#
#             feature_group_sub_group_546a7fff523b6b458c7b391d44be5216.addTo(map_84d8bc3904c5c990ef5fbafeb6a3fbcc);
#
#
#             var feature_group_sub_group_26800ee16b2b5974e3dd1722fb3f4bca = L.featureGroup.subGroup(
#                 feature_group_25081a62432c90c7b53e9c1c58a2f63c
#             );
#
#
#             var marker_bd5a169f3b2fcd26b3ce2e70dcc6b387 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_26800ee16b2b5974e3dd1722fb3f4bca);
#
#
#             var marker_209bfdd76dbc172dcd7e47ad30cf86bd = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_26800ee16b2b5974e3dd1722fb3f4bca);
#
#
#             feature_group_sub_group_26800ee16b2b5974e3dd1722fb3f4bca.addTo(map_84d8bc3904c5c990ef5fbafeb6a3fbcc);
#
#
#             var layer_control_bc982e8e66cf2bb25c5ad470fbc8c9e1_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_853277e12a1cd6360cd03bae5f4faccd,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_25081a62432c90c7b53e9c1c58a2f63c,
#                     &quot;group1&quot; : feature_group_sub_group_546a7fff523b6b458c7b391d44be5216,
#                     &quot;group2&quot; : feature_group_sub_group_26800ee16b2b5974e3dd1722fb3f4bca,
#                 },
#             };
#             let layer_control_bc982e8e66cf2bb25c5ad470fbc8c9e1 = L.control.layers(
#                 layer_control_bc982e8e66cf2bb25c5ad470fbc8c9e1_layers.base_layers,
#                 layer_control_bc982e8e66cf2bb25c5ad470fbc8c9e1_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_84d8bc3904c5c990ef5fbafeb6a3fbcc);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58fee80e5b936df007dd536f28635dbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58fee80e5b936df007dd536f28635dbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58fee80e5b936df007dd536f28635dbb = L.map(
#                 &quot;map_58fee80e5b936df007dd536f28635dbb&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1ca738db20880644375e35eebcfb598 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1ca738db20880644375e35eebcfb598.addTo(map_58fee80e5b936df007dd536f28635dbb);
#
#
#             var marker_cluster_3b7db3603fe4ee953c1bd2be4935fe3f = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_3b7db3603fe4ee953c1bd2be4935fe3f.addTo(map_58fee80e5b936df007dd536f28635dbb);
#
#
#             var feature_group_sub_group_cd66caeef6027ea770bb3d41c7276b63 = L.featureGroup.subGroup(
#                 marker_cluster_3b7db3603fe4ee953c1bd2be4935fe3f
#             );
#
#
#             var marker_75cae3723e5a1bd005546b90ebe3d0ca = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_cd66caeef6027ea770bb3d41c7276b63);
#
#
#             var marker_7a86f897504fbf89580e4b370da86354 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_cd66caeef6027ea770bb3d41c7276b63);
#
#
#             feature_group_sub_group_cd66caeef6027ea770bb3d41c7276b63.addTo(map_58fee80e5b936df007dd536f28635dbb);
#
#
#             var feature_group_sub_group_39a15e58409bfc4194e8906af9939c44 = L.featureGroup.subGroup(
#                 marker_cluster_3b7db3603fe4ee953c1bd2be4935fe3f
#             );
#
#
#             var marker_a3f77c273180ff4e98f56e81a2bc239a = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_39a15e58409bfc4194e8906af9939c44);
#
#
#             var marker_f8e477ce1ebc91b257b73c4ccd7d24b7 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_39a15e58409bfc4194e8906af9939c44);
#
#
#             feature_group_sub_group_39a15e58409bfc4194e8906af9939c44.addTo(map_58fee80e5b936df007dd536f28635dbb);
#
#
#             var layer_control_d331762bdaf43a49159f13870b29c3cf_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d1ca738db20880644375e35eebcfb598,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_cd66caeef6027ea770bb3d41c7276b63,
#                     &quot;group2&quot; : feature_group_sub_group_39a15e58409bfc4194e8906af9939c44,
#                 },
#             };
#             let layer_control_d331762bdaf43a49159f13870b29c3cf = L.control.layers(
#                 layer_control_d331762bdaf43a49159f13870b29c3cf_layers.base_layers,
#                 layer_control_d331762bdaf43a49159f13870b29c3cf_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_58fee80e5b936df007dd536f28635dbb);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
