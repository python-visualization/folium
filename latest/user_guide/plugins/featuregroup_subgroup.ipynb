# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d07c127887eff159b3387586a9e68fc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d07c127887eff159b3387586a9e68fc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d07c127887eff159b3387586a9e68fc2 = L.map(
#                 &quot;map_d07c127887eff159b3387586a9e68fc2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a80ff1aee40a42d0024b14cd991cd6ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a80ff1aee40a42d0024b14cd991cd6ac.addTo(map_d07c127887eff159b3387586a9e68fc2);
#
#
#             var feature_group_3d5ca30943945ba0c6e81489063c044f = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_3d5ca30943945ba0c6e81489063c044f.addTo(map_d07c127887eff159b3387586a9e68fc2);
#
#
#             var feature_group_sub_group_1ee456bab7d44ca0b86975b21d27d857 = L.featureGroup.subGroup(
#                 feature_group_3d5ca30943945ba0c6e81489063c044f
#             );
#
#
#             var marker_602bf8e5be20f77cf2756f62a361e079 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_1ee456bab7d44ca0b86975b21d27d857);
#
#
#             var marker_1ed6bcf26c28eaf6aa9b1f9b8a2a8ab8 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_1ee456bab7d44ca0b86975b21d27d857);
#
#
#             feature_group_sub_group_1ee456bab7d44ca0b86975b21d27d857.addTo(map_d07c127887eff159b3387586a9e68fc2);
#
#
#             var feature_group_sub_group_1c2fc845f5d2a927e97ad79ab8c3e616 = L.featureGroup.subGroup(
#                 feature_group_3d5ca30943945ba0c6e81489063c044f
#             );
#
#
#             var marker_6f383fe1b9e9fecf64ec96bce9d7ab2d = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_1c2fc845f5d2a927e97ad79ab8c3e616);
#
#
#             var marker_119f2640275075cfef481024738e5fdc = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_1c2fc845f5d2a927e97ad79ab8c3e616);
#
#
#             feature_group_sub_group_1c2fc845f5d2a927e97ad79ab8c3e616.addTo(map_d07c127887eff159b3387586a9e68fc2);
#
#
#             var layer_control_c5f8d02cabb2c48b9e46ccd9d5233f70_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a80ff1aee40a42d0024b14cd991cd6ac,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_3d5ca30943945ba0c6e81489063c044f,
#                     &quot;group1&quot; : feature_group_sub_group_1ee456bab7d44ca0b86975b21d27d857,
#                     &quot;group2&quot; : feature_group_sub_group_1c2fc845f5d2a927e97ad79ab8c3e616,
#                 },
#             };
#             let layer_control_c5f8d02cabb2c48b9e46ccd9d5233f70 = L.control.layers(
#                 layer_control_c5f8d02cabb2c48b9e46ccd9d5233f70_layers.base_layers,
#                 layer_control_c5f8d02cabb2c48b9e46ccd9d5233f70_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_d07c127887eff159b3387586a9e68fc2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ee50d2ea45038d92adff0a2102bdb2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ee50d2ea45038d92adff0a2102bdb2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ee50d2ea45038d92adff0a2102bdb2c = L.map(
#                 &quot;map_4ee50d2ea45038d92adff0a2102bdb2c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5f826e5b11746a7c8b8c952c988cd2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c5f826e5b11746a7c8b8c952c988cd2e.addTo(map_4ee50d2ea45038d92adff0a2102bdb2c);
#
#
#             var marker_cluster_3f20469eb4e838d2a0ea500b25bb83e2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_3f20469eb4e838d2a0ea500b25bb83e2.addTo(map_4ee50d2ea45038d92adff0a2102bdb2c);
#
#
#             var feature_group_sub_group_a200424f578acccbf68ed7929d89ad3f = L.featureGroup.subGroup(
#                 marker_cluster_3f20469eb4e838d2a0ea500b25bb83e2
#             );
#
#
#             var marker_338264048c53245e36d9b8ee0682a58d = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_a200424f578acccbf68ed7929d89ad3f);
#
#
#             var marker_360711d23ea24d15bb2727158db979c6 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_a200424f578acccbf68ed7929d89ad3f);
#
#
#             feature_group_sub_group_a200424f578acccbf68ed7929d89ad3f.addTo(map_4ee50d2ea45038d92adff0a2102bdb2c);
#
#
#             var feature_group_sub_group_8e388f2e1d01a0dc3c84221c930eb6fd = L.featureGroup.subGroup(
#                 marker_cluster_3f20469eb4e838d2a0ea500b25bb83e2
#             );
#
#
#             var marker_4b3d670d923df2613e88af8beebbafed = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_8e388f2e1d01a0dc3c84221c930eb6fd);
#
#
#             var marker_c212693f6e4e2b9f62f5191f7cf25c61 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_8e388f2e1d01a0dc3c84221c930eb6fd);
#
#
#             feature_group_sub_group_8e388f2e1d01a0dc3c84221c930eb6fd.addTo(map_4ee50d2ea45038d92adff0a2102bdb2c);
#
#
#             var layer_control_e7221c81e7580fe3517ec2b5108f0356_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c5f826e5b11746a7c8b8c952c988cd2e,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_a200424f578acccbf68ed7929d89ad3f,
#                     &quot;group2&quot; : feature_group_sub_group_8e388f2e1d01a0dc3c84221c930eb6fd,
#                 },
#             };
#             let layer_control_e7221c81e7580fe3517ec2b5108f0356 = L.control.layers(
#                 layer_control_e7221c81e7580fe3517ec2b5108f0356_layers.base_layers,
#                 layer_control_e7221c81e7580fe3517ec2b5108f0356_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4ee50d2ea45038d92adff0a2102bdb2c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
