# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a2d99a75a50f11b16b61c0977c65d2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a2d99a75a50f11b16b61c0977c65d2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a2d99a75a50f11b16b61c0977c65d2c = L.map(
#                 &quot;map_4a2d99a75a50f11b16b61c0977c65d2c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6439302ad886e9a4facbe34ef1fecdd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6439302ad886e9a4facbe34ef1fecdd.addTo(map_4a2d99a75a50f11b16b61c0977c65d2c);
#
#
#             var feature_group_276208b45ac05b376ecbc917ad059c53 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_276208b45ac05b376ecbc917ad059c53.addTo(map_4a2d99a75a50f11b16b61c0977c65d2c);
#
#
#             var feature_group_sub_group_d472e29e3ebe8d493d81942c933a65a3 = L.featureGroup.subGroup(
#                 feature_group_276208b45ac05b376ecbc917ad059c53
#             );
#
#
#             var marker_1058d7698707a95c736dd51502dc6633 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d472e29e3ebe8d493d81942c933a65a3);
#
#
#             var marker_6910f05d01af56203f36665844a5de7f = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d472e29e3ebe8d493d81942c933a65a3);
#
#
#             feature_group_sub_group_d472e29e3ebe8d493d81942c933a65a3.addTo(map_4a2d99a75a50f11b16b61c0977c65d2c);
#
#
#             var feature_group_sub_group_fa1fb883e64e6b205a0be47e0a2b78b9 = L.featureGroup.subGroup(
#                 feature_group_276208b45ac05b376ecbc917ad059c53
#             );
#
#
#             var marker_c0657fd2bbc065ed2147e86db40b24be = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_fa1fb883e64e6b205a0be47e0a2b78b9);
#
#
#             var marker_84e066072dea25962dd74b6439cf2d4c = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_fa1fb883e64e6b205a0be47e0a2b78b9);
#
#
#             feature_group_sub_group_fa1fb883e64e6b205a0be47e0a2b78b9.addTo(map_4a2d99a75a50f11b16b61c0977c65d2c);
#
#
#             var layer_control_08ccd330616179052805222463833122_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e6439302ad886e9a4facbe34ef1fecdd,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_276208b45ac05b376ecbc917ad059c53,
#                     &quot;group1&quot; : feature_group_sub_group_d472e29e3ebe8d493d81942c933a65a3,
#                     &quot;group2&quot; : feature_group_sub_group_fa1fb883e64e6b205a0be47e0a2b78b9,
#                 },
#             };
#             let layer_control_08ccd330616179052805222463833122 = L.control.layers(
#                 layer_control_08ccd330616179052805222463833122_layers.base_layers,
#                 layer_control_08ccd330616179052805222463833122_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4a2d99a75a50f11b16b61c0977c65d2c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9d7f6db5d178be02556e97f14cba53a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9d7f6db5d178be02556e97f14cba53a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9d7f6db5d178be02556e97f14cba53a = L.map(
#                 &quot;map_b9d7f6db5d178be02556e97f14cba53a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14de69a798a183bacfc983ff1335fc1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_14de69a798a183bacfc983ff1335fc1e.addTo(map_b9d7f6db5d178be02556e97f14cba53a);
#
#
#             var marker_cluster_84a8d1c707fc1e12c6e2faf29bae30a2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_84a8d1c707fc1e12c6e2faf29bae30a2.addTo(map_b9d7f6db5d178be02556e97f14cba53a);
#
#
#             var feature_group_sub_group_2f0e4ca314ed3f4b35964a9589f6583c = L.featureGroup.subGroup(
#                 marker_cluster_84a8d1c707fc1e12c6e2faf29bae30a2
#             );
#
#
#             var marker_1ca255e0f40952ee299b29e9af2c4b78 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_2f0e4ca314ed3f4b35964a9589f6583c);
#
#
#             var marker_711f7cb376ba065c02244da349b404a3 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_2f0e4ca314ed3f4b35964a9589f6583c);
#
#
#             feature_group_sub_group_2f0e4ca314ed3f4b35964a9589f6583c.addTo(map_b9d7f6db5d178be02556e97f14cba53a);
#
#
#             var feature_group_sub_group_c95da33309bd689fe9c7ea9b3f42f55c = L.featureGroup.subGroup(
#                 marker_cluster_84a8d1c707fc1e12c6e2faf29bae30a2
#             );
#
#
#             var marker_c58f521e19b414a1ff69bd8f97565f2c = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_c95da33309bd689fe9c7ea9b3f42f55c);
#
#
#             var marker_f47b6ae6ffa7dbd70bc8082bcaef990d = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_c95da33309bd689fe9c7ea9b3f42f55c);
#
#
#             feature_group_sub_group_c95da33309bd689fe9c7ea9b3f42f55c.addTo(map_b9d7f6db5d178be02556e97f14cba53a);
#
#
#             var layer_control_e1aebcba61aabaeea28172ebdd5d9bbd_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_14de69a798a183bacfc983ff1335fc1e,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_2f0e4ca314ed3f4b35964a9589f6583c,
#                     &quot;group2&quot; : feature_group_sub_group_c95da33309bd689fe9c7ea9b3f42f55c,
#                 },
#             };
#             let layer_control_e1aebcba61aabaeea28172ebdd5d9bbd = L.control.layers(
#                 layer_control_e1aebcba61aabaeea28172ebdd5d9bbd_layers.base_layers,
#                 layer_control_e1aebcba61aabaeea28172ebdd5d9bbd_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b9d7f6db5d178be02556e97f14cba53a);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
