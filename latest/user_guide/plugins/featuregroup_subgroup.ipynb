# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b9a918ee7bead6da823a9938e1176a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b9a918ee7bead6da823a9938e1176a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b9a918ee7bead6da823a9938e1176a9 = L.map(
#                 &quot;map_4b9a918ee7bead6da823a9938e1176a9&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc031d800c8930469ab3c8a6558e4714 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc031d800c8930469ab3c8a6558e4714.addTo(map_4b9a918ee7bead6da823a9938e1176a9);
#
#
#             var feature_group_13d22eeed4f614ce5c1ee49216389468 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_13d22eeed4f614ce5c1ee49216389468.addTo(map_4b9a918ee7bead6da823a9938e1176a9);
#
#
#             var feature_group_sub_group_793d3bd1a19437b6adf3cd28d460dc5d = L.featureGroup.subGroup(
#                 feature_group_13d22eeed4f614ce5c1ee49216389468
#             );
#
#
#             var marker_347ba670a340e367d89acdf36cfb96cc = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_793d3bd1a19437b6adf3cd28d460dc5d);
#
#
#             var marker_7041235ea1b384c33c9930ea28759e95 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_793d3bd1a19437b6adf3cd28d460dc5d);
#
#
#             feature_group_sub_group_793d3bd1a19437b6adf3cd28d460dc5d.addTo(map_4b9a918ee7bead6da823a9938e1176a9);
#
#
#             var feature_group_sub_group_fc991d7503f76b0375f8beccce26d1e6 = L.featureGroup.subGroup(
#                 feature_group_13d22eeed4f614ce5c1ee49216389468
#             );
#
#
#             var marker_f3acce07a42ba706988d832656da2853 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_fc991d7503f76b0375f8beccce26d1e6);
#
#
#             var marker_ace15c79a58c112ac00c3d139f0486ec = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_fc991d7503f76b0375f8beccce26d1e6);
#
#
#             feature_group_sub_group_fc991d7503f76b0375f8beccce26d1e6.addTo(map_4b9a918ee7bead6da823a9938e1176a9);
#
#
#             var layer_control_e873e7825eaf1ded31d03d84610cb7cc_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_bc031d800c8930469ab3c8a6558e4714,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_13d22eeed4f614ce5c1ee49216389468,
#                     &quot;group1&quot; : feature_group_sub_group_793d3bd1a19437b6adf3cd28d460dc5d,
#                     &quot;group2&quot; : feature_group_sub_group_fc991d7503f76b0375f8beccce26d1e6,
#                 },
#             };
#             let layer_control_e873e7825eaf1ded31d03d84610cb7cc = L.control.layers(
#                 layer_control_e873e7825eaf1ded31d03d84610cb7cc_layers.base_layers,
#                 layer_control_e873e7825eaf1ded31d03d84610cb7cc_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4b9a918ee7bead6da823a9938e1176a9);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9edfb443b1bac013ffc66c3853a1ec76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9edfb443b1bac013ffc66c3853a1ec76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9edfb443b1bac013ffc66c3853a1ec76 = L.map(
#                 &quot;map_9edfb443b1bac013ffc66c3853a1ec76&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ceaea88541e84fad808cbc980e90437 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0ceaea88541e84fad808cbc980e90437.addTo(map_9edfb443b1bac013ffc66c3853a1ec76);
#
#
#             var marker_cluster_94e307bfa2f890122a4c411c2a2c2b91 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_94e307bfa2f890122a4c411c2a2c2b91.addTo(map_9edfb443b1bac013ffc66c3853a1ec76);
#
#
#             var feature_group_sub_group_9526bd7fcf1a5bb6d588ea61fde1ab9e = L.featureGroup.subGroup(
#                 marker_cluster_94e307bfa2f890122a4c411c2a2c2b91
#             );
#
#
#             var marker_bed7e802e470de7835fa88d8d5df4cee = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_9526bd7fcf1a5bb6d588ea61fde1ab9e);
#
#
#             var marker_16ca8f4debea86389d55c2bc94550e45 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_9526bd7fcf1a5bb6d588ea61fde1ab9e);
#
#
#             feature_group_sub_group_9526bd7fcf1a5bb6d588ea61fde1ab9e.addTo(map_9edfb443b1bac013ffc66c3853a1ec76);
#
#
#             var feature_group_sub_group_5319c4e5b30ce13d14eaddb3cb16db7f = L.featureGroup.subGroup(
#                 marker_cluster_94e307bfa2f890122a4c411c2a2c2b91
#             );
#
#
#             var marker_5d42a93a5c8d4df55b219e1e895c53d3 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5319c4e5b30ce13d14eaddb3cb16db7f);
#
#
#             var marker_6b3fbf8c6c96a91a62879dd153f0c39d = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5319c4e5b30ce13d14eaddb3cb16db7f);
#
#
#             feature_group_sub_group_5319c4e5b30ce13d14eaddb3cb16db7f.addTo(map_9edfb443b1bac013ffc66c3853a1ec76);
#
#
#             var layer_control_26c31c5e2f75ea3d7d3500158f6526d0_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_0ceaea88541e84fad808cbc980e90437,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_9526bd7fcf1a5bb6d588ea61fde1ab9e,
#                     &quot;group2&quot; : feature_group_sub_group_5319c4e5b30ce13d14eaddb3cb16db7f,
#                 },
#             };
#             let layer_control_26c31c5e2f75ea3d7d3500158f6526d0 = L.control.layers(
#                 layer_control_26c31c5e2f75ea3d7d3500158f6526d0_layers.base_layers,
#                 layer_control_26c31c5e2f75ea3d7d3500158f6526d0_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_9edfb443b1bac013ffc66c3853a1ec76);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
