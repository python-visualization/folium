# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5942aad8e2f92bfa96c6ef9a33c7e2eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5942aad8e2f92bfa96c6ef9a33c7e2eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5942aad8e2f92bfa96c6ef9a33c7e2eb = L.map(
#                 &quot;map_5942aad8e2f92bfa96c6ef9a33c7e2eb&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d02b892d08ff7e264eab72ffff167955 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d02b892d08ff7e264eab72ffff167955.addTo(map_5942aad8e2f92bfa96c6ef9a33c7e2eb);
#
#
#             var feature_group_10fa91fcc54587f0bf04f625b794092a = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_10fa91fcc54587f0bf04f625b794092a.addTo(map_5942aad8e2f92bfa96c6ef9a33c7e2eb);
#
#
#             var feature_group_sub_group_5a13e4b7298e95ab8aa41892b58f2433 = L.featureGroup.subGroup(
#                 feature_group_10fa91fcc54587f0bf04f625b794092a
#             );
#
#
#             var marker_57b1e6ea3780004d1195345defd87999 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5a13e4b7298e95ab8aa41892b58f2433);
#
#
#             var marker_dd257e09bab94dc8f4b739a6754bec46 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5a13e4b7298e95ab8aa41892b58f2433);
#
#
#             feature_group_sub_group_5a13e4b7298e95ab8aa41892b58f2433.addTo(map_5942aad8e2f92bfa96c6ef9a33c7e2eb);
#
#
#             var feature_group_sub_group_09f0ddc9587c53e80a054b1e59d8b5b3 = L.featureGroup.subGroup(
#                 feature_group_10fa91fcc54587f0bf04f625b794092a
#             );
#
#
#             var marker_4f6c75b544d650346ab07700aaf745d2 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_09f0ddc9587c53e80a054b1e59d8b5b3);
#
#
#             var marker_75b014533580d7934c9ebef7d6d93ce0 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_09f0ddc9587c53e80a054b1e59d8b5b3);
#
#
#             feature_group_sub_group_09f0ddc9587c53e80a054b1e59d8b5b3.addTo(map_5942aad8e2f92bfa96c6ef9a33c7e2eb);
#
#
#             var layer_control_65e558ec63ad87c8827b4e09537e3e8e_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d02b892d08ff7e264eab72ffff167955,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_10fa91fcc54587f0bf04f625b794092a,
#                     &quot;group1&quot; : feature_group_sub_group_5a13e4b7298e95ab8aa41892b58f2433,
#                     &quot;group2&quot; : feature_group_sub_group_09f0ddc9587c53e80a054b1e59d8b5b3,
#                 },
#             };
#             let layer_control_65e558ec63ad87c8827b4e09537e3e8e = L.control.layers(
#                 layer_control_65e558ec63ad87c8827b4e09537e3e8e_layers.base_layers,
#                 layer_control_65e558ec63ad87c8827b4e09537e3e8e_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_5942aad8e2f92bfa96c6ef9a33c7e2eb);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d0f3234f8aaf60ba8c71c31436cb043 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d0f3234f8aaf60ba8c71c31436cb043&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d0f3234f8aaf60ba8c71c31436cb043 = L.map(
#                 &quot;map_4d0f3234f8aaf60ba8c71c31436cb043&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c988e30269abde27fde476a40a79f81 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9c988e30269abde27fde476a40a79f81.addTo(map_4d0f3234f8aaf60ba8c71c31436cb043);
#
#
#             var marker_cluster_998e55e2c9d4663d7562f1474ce6ea1c = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_998e55e2c9d4663d7562f1474ce6ea1c.addTo(map_4d0f3234f8aaf60ba8c71c31436cb043);
#
#
#             var feature_group_sub_group_3e0b3c8f10f82ae108f7860587b85097 = L.featureGroup.subGroup(
#                 marker_cluster_998e55e2c9d4663d7562f1474ce6ea1c
#             );
#
#
#             var marker_34f788c20525935f644280e8bf3d6789 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3e0b3c8f10f82ae108f7860587b85097);
#
#
#             var marker_e92dedc37874599b30f91e9e033fb340 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3e0b3c8f10f82ae108f7860587b85097);
#
#
#             feature_group_sub_group_3e0b3c8f10f82ae108f7860587b85097.addTo(map_4d0f3234f8aaf60ba8c71c31436cb043);
#
#
#             var feature_group_sub_group_9487ab000a7a5ec21bfec38921edfe8a = L.featureGroup.subGroup(
#                 marker_cluster_998e55e2c9d4663d7562f1474ce6ea1c
#             );
#
#
#             var marker_04a126454cdbce2084f39b7fc199c0d8 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_9487ab000a7a5ec21bfec38921edfe8a);
#
#
#             var marker_f453d5b00ae0a6d7325a4183182a9246 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_9487ab000a7a5ec21bfec38921edfe8a);
#
#
#             feature_group_sub_group_9487ab000a7a5ec21bfec38921edfe8a.addTo(map_4d0f3234f8aaf60ba8c71c31436cb043);
#
#
#             var layer_control_a8ee8ca354f6e59168cbcb6e936f0862_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_9c988e30269abde27fde476a40a79f81,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_3e0b3c8f10f82ae108f7860587b85097,
#                     &quot;group2&quot; : feature_group_sub_group_9487ab000a7a5ec21bfec38921edfe8a,
#                 },
#             };
#             let layer_control_a8ee8ca354f6e59168cbcb6e936f0862 = L.control.layers(
#                 layer_control_a8ee8ca354f6e59168cbcb6e936f0862_layers.base_layers,
#                 layer_control_a8ee8ca354f6e59168cbcb6e936f0862_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_4d0f3234f8aaf60ba8c71c31436cb043);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
