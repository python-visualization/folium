# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78051c72a16317efaa4386c5d5cb0d95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78051c72a16317efaa4386c5d5cb0d95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78051c72a16317efaa4386c5d5cb0d95 = L.map(
#                 &quot;map_78051c72a16317efaa4386c5d5cb0d95&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e0e96bf028ba444fa79deffd4d43842 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7e0e96bf028ba444fa79deffd4d43842.addTo(map_78051c72a16317efaa4386c5d5cb0d95);
#
#
#             var feature_group_074fe711769f955e7939d025e37f77d1 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_074fe711769f955e7939d025e37f77d1.addTo(map_78051c72a16317efaa4386c5d5cb0d95);
#
#
#             var feature_group_sub_group_d5098a9b34d6f6c5bb61aa9ab39a5ff9 = L.featureGroup.subGroup(
#                 feature_group_074fe711769f955e7939d025e37f77d1
#             );
#
#
#             var marker_0ed9696d713f64c1f7c6c808bb7185cf = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d5098a9b34d6f6c5bb61aa9ab39a5ff9);
#
#
#             var marker_9cbc3b07e9a8dca00b5b33f01d9573c3 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d5098a9b34d6f6c5bb61aa9ab39a5ff9);
#
#
#             feature_group_sub_group_d5098a9b34d6f6c5bb61aa9ab39a5ff9.addTo(map_78051c72a16317efaa4386c5d5cb0d95);
#
#
#             var feature_group_sub_group_dbcbf244b07f1a6a3210e19e78472e9a = L.featureGroup.subGroup(
#                 feature_group_074fe711769f955e7939d025e37f77d1
#             );
#
#
#             var marker_335d0ccc558700f0af50dd6be93c5abd = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_dbcbf244b07f1a6a3210e19e78472e9a);
#
#
#             var marker_e58cd95cb583cb9aedddd3d2d8c1d596 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_dbcbf244b07f1a6a3210e19e78472e9a);
#
#
#             feature_group_sub_group_dbcbf244b07f1a6a3210e19e78472e9a.addTo(map_78051c72a16317efaa4386c5d5cb0d95);
#
#
#             var layer_control_d1e63e6ac45959b6f91315e9ac1fdeb8_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7e0e96bf028ba444fa79deffd4d43842,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_074fe711769f955e7939d025e37f77d1,
#                     &quot;group1&quot; : feature_group_sub_group_d5098a9b34d6f6c5bb61aa9ab39a5ff9,
#                     &quot;group2&quot; : feature_group_sub_group_dbcbf244b07f1a6a3210e19e78472e9a,
#                 },
#             };
#             let layer_control_d1e63e6ac45959b6f91315e9ac1fdeb8 = L.control.layers(
#                 layer_control_d1e63e6ac45959b6f91315e9ac1fdeb8_layers.base_layers,
#                 layer_control_d1e63e6ac45959b6f91315e9ac1fdeb8_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_78051c72a16317efaa4386c5d5cb0d95);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d34da848a6609af7a7a8425a02503d88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d34da848a6609af7a7a8425a02503d88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d34da848a6609af7a7a8425a02503d88 = L.map(
#                 &quot;map_d34da848a6609af7a7a8425a02503d88&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24189b3e030e2b3f1d2f1a8b4deedf11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_24189b3e030e2b3f1d2f1a8b4deedf11.addTo(map_d34da848a6609af7a7a8425a02503d88);
#
#
#             var marker_cluster_d426f70679c9ab881effdb3ccfebc443 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_d426f70679c9ab881effdb3ccfebc443.addTo(map_d34da848a6609af7a7a8425a02503d88);
#
#
#             var feature_group_sub_group_93947bf31f8005d28c90cabee9bdba67 = L.featureGroup.subGroup(
#                 marker_cluster_d426f70679c9ab881effdb3ccfebc443
#             );
#
#
#             var marker_794f91b6741947db97989609363ef4a4 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_93947bf31f8005d28c90cabee9bdba67);
#
#
#             var marker_50cdffc2766061db1c3c1f49b491445e = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_93947bf31f8005d28c90cabee9bdba67);
#
#
#             feature_group_sub_group_93947bf31f8005d28c90cabee9bdba67.addTo(map_d34da848a6609af7a7a8425a02503d88);
#
#
#             var feature_group_sub_group_5b384e96b694d7e273ab333ae6ad25dd = L.featureGroup.subGroup(
#                 marker_cluster_d426f70679c9ab881effdb3ccfebc443
#             );
#
#
#             var marker_8b4342201ceff8ba4777e53197319b44 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5b384e96b694d7e273ab333ae6ad25dd);
#
#
#             var marker_ec438c3065fe45201a6fcce632c20c7c = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5b384e96b694d7e273ab333ae6ad25dd);
#
#
#             feature_group_sub_group_5b384e96b694d7e273ab333ae6ad25dd.addTo(map_d34da848a6609af7a7a8425a02503d88);
#
#
#             var layer_control_7c0f25c95fb920246ff7ad5f0a3f8564_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_24189b3e030e2b3f1d2f1a8b4deedf11,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_93947bf31f8005d28c90cabee9bdba67,
#                     &quot;group2&quot; : feature_group_sub_group_5b384e96b694d7e273ab333ae6ad25dd,
#                 },
#             };
#             let layer_control_7c0f25c95fb920246ff7ad5f0a3f8564 = L.control.layers(
#                 layer_control_7c0f25c95fb920246ff7ad5f0a3f8564_layers.base_layers,
#                 layer_control_7c0f25c95fb920246ff7ad5f0a3f8564_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_d34da848a6609af7a7a8425a02503d88);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
