# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1eac419441c0d10acdacddd30d0d8ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1eac419441c0d10acdacddd30d0d8ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1eac419441c0d10acdacddd30d0d8ce = L.map(
#                 &quot;map_d1eac419441c0d10acdacddd30d0d8ce&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b23f6be7f831db2616b912596bbe6d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b23f6be7f831db2616b912596bbe6d6.addTo(map_d1eac419441c0d10acdacddd30d0d8ce);
#
#
#             var feature_group_971faf6ffc9708d9292f588d0fc2ee9e = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_971faf6ffc9708d9292f588d0fc2ee9e.addTo(map_d1eac419441c0d10acdacddd30d0d8ce);
#
#
#             var feature_group_sub_group_40caf6431d1084fd25aa50765dea6034 = L.featureGroup.subGroup(
#                 feature_group_971faf6ffc9708d9292f588d0fc2ee9e
#             );
#
#
#             var marker_21ea55c5aaae71294b8dac33e27a6f01 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_40caf6431d1084fd25aa50765dea6034);
#
#
#             var marker_4a13a7f0c920f13ee8f8cafa90236a8d = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_40caf6431d1084fd25aa50765dea6034);
#
#
#             feature_group_sub_group_40caf6431d1084fd25aa50765dea6034.addTo(map_d1eac419441c0d10acdacddd30d0d8ce);
#
#
#             var feature_group_sub_group_b062a5f4fdb2f2d789a18086fa8ac9da = L.featureGroup.subGroup(
#                 feature_group_971faf6ffc9708d9292f588d0fc2ee9e
#             );
#
#
#             var marker_dd6910d3cd9bb7440d5f7e3f1ec06a08 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_b062a5f4fdb2f2d789a18086fa8ac9da);
#
#
#             var marker_c43d3b072228acc24a282b605d199b5b = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_b062a5f4fdb2f2d789a18086fa8ac9da);
#
#
#             feature_group_sub_group_b062a5f4fdb2f2d789a18086fa8ac9da.addTo(map_d1eac419441c0d10acdacddd30d0d8ce);
#
#
#             var layer_control_ee88d36386b2b6dfdec83252c6f575a7_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_9b23f6be7f831db2616b912596bbe6d6,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_971faf6ffc9708d9292f588d0fc2ee9e,
#                     &quot;group1&quot; : feature_group_sub_group_40caf6431d1084fd25aa50765dea6034,
#                     &quot;group2&quot; : feature_group_sub_group_b062a5f4fdb2f2d789a18086fa8ac9da,
#                 },
#             };
#             let layer_control_ee88d36386b2b6dfdec83252c6f575a7 = L.control.layers(
#                 layer_control_ee88d36386b2b6dfdec83252c6f575a7_layers.base_layers,
#                 layer_control_ee88d36386b2b6dfdec83252c6f575a7_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_d1eac419441c0d10acdacddd30d0d8ce);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad82163c99ccec70ed4f9a9a7e6c7413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad82163c99ccec70ed4f9a9a7e6c7413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad82163c99ccec70ed4f9a9a7e6c7413 = L.map(
#                 &quot;map_ad82163c99ccec70ed4f9a9a7e6c7413&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72485e2c2f3fcdc3a69bdbcce19a7ebb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_72485e2c2f3fcdc3a69bdbcce19a7ebb.addTo(map_ad82163c99ccec70ed4f9a9a7e6c7413);
#
#
#             var marker_cluster_702d98b25551a87ba57935e9e358d7ba = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_702d98b25551a87ba57935e9e358d7ba.addTo(map_ad82163c99ccec70ed4f9a9a7e6c7413);
#
#
#             var feature_group_sub_group_d2e898b7ef11a44af59fb13cce1579ef = L.featureGroup.subGroup(
#                 marker_cluster_702d98b25551a87ba57935e9e358d7ba
#             );
#
#
#             var marker_38f770565b89788f72619a609490cbe8 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d2e898b7ef11a44af59fb13cce1579ef);
#
#
#             var marker_7e32f5832ae67bdc767ae9c6b0cb5974 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d2e898b7ef11a44af59fb13cce1579ef);
#
#
#             feature_group_sub_group_d2e898b7ef11a44af59fb13cce1579ef.addTo(map_ad82163c99ccec70ed4f9a9a7e6c7413);
#
#
#             var feature_group_sub_group_d6ebe9c380440b025efa1998d8a104ac = L.featureGroup.subGroup(
#                 marker_cluster_702d98b25551a87ba57935e9e358d7ba
#             );
#
#
#             var marker_35fa06fbc1cf18eccadc47fb2e9c7ebf = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d6ebe9c380440b025efa1998d8a104ac);
#
#
#             var marker_78e4f866a23338567630ebe43f5ce822 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_d6ebe9c380440b025efa1998d8a104ac);
#
#
#             feature_group_sub_group_d6ebe9c380440b025efa1998d8a104ac.addTo(map_ad82163c99ccec70ed4f9a9a7e6c7413);
#
#
#             var layer_control_a69e0f0887eaa6484371e35691e37957_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_72485e2c2f3fcdc3a69bdbcce19a7ebb,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_d2e898b7ef11a44af59fb13cce1579ef,
#                     &quot;group2&quot; : feature_group_sub_group_d6ebe9c380440b025efa1998d8a104ac,
#                 },
#             };
#             let layer_control_a69e0f0887eaa6484371e35691e37957 = L.control.layers(
#                 layer_control_a69e0f0887eaa6484371e35691e37957_layers.base_layers,
#                 layer_control_a69e0f0887eaa6484371e35691e37957_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_ad82163c99ccec70ed4f9a9a7e6c7413);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
