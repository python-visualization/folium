# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_808e0bede3b4d161c5cc1ae6ce2f679d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_808e0bede3b4d161c5cc1ae6ce2f679d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_808e0bede3b4d161c5cc1ae6ce2f679d = L.map(
#                 &quot;map_808e0bede3b4d161c5cc1ae6ce2f679d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_165ee98b6f169cb6095fe8626d6c6577 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_165ee98b6f169cb6095fe8626d6c6577.addTo(map_808e0bede3b4d161c5cc1ae6ce2f679d);
#
#
#             var feature_group_5bf23c237552a38392b32935f74eed05 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_5bf23c237552a38392b32935f74eed05.addTo(map_808e0bede3b4d161c5cc1ae6ce2f679d);
#
#
#             var feature_group_sub_group_393307d0a13f8ff624f156c2e0f431c8 = L.featureGroup.subGroup(
#                 feature_group_5bf23c237552a38392b32935f74eed05
#             );
#
#
#             var marker_02d0ee85574161ad957b4bda714764e3 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_393307d0a13f8ff624f156c2e0f431c8);
#
#
#             var marker_986b45005c042d585facb0ee5b5e550b = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_393307d0a13f8ff624f156c2e0f431c8);
#
#
#             feature_group_sub_group_393307d0a13f8ff624f156c2e0f431c8.addTo(map_808e0bede3b4d161c5cc1ae6ce2f679d);
#
#
#             var feature_group_sub_group_1eb8f2baeb0ed2357c1f8cea00f3cd7b = L.featureGroup.subGroup(
#                 feature_group_5bf23c237552a38392b32935f74eed05
#             );
#
#
#             var marker_f6e5c764adfab5c538b96e8e63e1ccab = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_1eb8f2baeb0ed2357c1f8cea00f3cd7b);
#
#
#             var marker_15615b3ccc5ab8f96012a99deeddaf66 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_1eb8f2baeb0ed2357c1f8cea00f3cd7b);
#
#
#             feature_group_sub_group_1eb8f2baeb0ed2357c1f8cea00f3cd7b.addTo(map_808e0bede3b4d161c5cc1ae6ce2f679d);
#
#
#             var layer_control_9c61add5f44c64d410ca3f572b1648e9_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_165ee98b6f169cb6095fe8626d6c6577,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_5bf23c237552a38392b32935f74eed05,
#                     &quot;group1&quot; : feature_group_sub_group_393307d0a13f8ff624f156c2e0f431c8,
#                     &quot;group2&quot; : feature_group_sub_group_1eb8f2baeb0ed2357c1f8cea00f3cd7b,
#                 },
#             };
#             let layer_control_9c61add5f44c64d410ca3f572b1648e9 = L.control.layers(
#                 layer_control_9c61add5f44c64d410ca3f572b1648e9_layers.base_layers,
#                 layer_control_9c61add5f44c64d410ca3f572b1648e9_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_808e0bede3b4d161c5cc1ae6ce2f679d);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f49e29f03281a58474b6f0d645d6c482 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f49e29f03281a58474b6f0d645d6c482&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f49e29f03281a58474b6f0d645d6c482 = L.map(
#                 &quot;map_f49e29f03281a58474b6f0d645d6c482&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7f40936f3a936c3727ea6513d67efcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7f40936f3a936c3727ea6513d67efcf.addTo(map_f49e29f03281a58474b6f0d645d6c482);
#
#
#             var marker_cluster_1850646bf9e38ea5d3f14c5a93021e45 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_1850646bf9e38ea5d3f14c5a93021e45.addTo(map_f49e29f03281a58474b6f0d645d6c482);
#
#
#             var feature_group_sub_group_ec273a1e86efc7db79981c5a692f5c18 = L.featureGroup.subGroup(
#                 marker_cluster_1850646bf9e38ea5d3f14c5a93021e45
#             );
#
#
#             var marker_d1208b5b6f0b95807d4933006157a477 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_ec273a1e86efc7db79981c5a692f5c18);
#
#
#             var marker_1937983235cfe2015e55ee7ec9fa8e51 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_ec273a1e86efc7db79981c5a692f5c18);
#
#
#             feature_group_sub_group_ec273a1e86efc7db79981c5a692f5c18.addTo(map_f49e29f03281a58474b6f0d645d6c482);
#
#
#             var feature_group_sub_group_e835e03231cf71abedaef13a69b7c2a5 = L.featureGroup.subGroup(
#                 marker_cluster_1850646bf9e38ea5d3f14c5a93021e45
#             );
#
#
#             var marker_eba3258818f18c1a0f8812625033fc22 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_e835e03231cf71abedaef13a69b7c2a5);
#
#
#             var marker_d0f890658fc590dff27496950ae80ac6 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_e835e03231cf71abedaef13a69b7c2a5);
#
#
#             feature_group_sub_group_e835e03231cf71abedaef13a69b7c2a5.addTo(map_f49e29f03281a58474b6f0d645d6c482);
#
#
#             var layer_control_d8637cfb8ea35e891a1c8eca72e29e35_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e7f40936f3a936c3727ea6513d67efcf,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_ec273a1e86efc7db79981c5a692f5c18,
#                     &quot;group2&quot; : feature_group_sub_group_e835e03231cf71abedaef13a69b7c2a5,
#                 },
#             };
#             let layer_control_d8637cfb8ea35e891a1c8eca72e29e35 = L.control.layers(
#                 layer_control_d8637cfb8ea35e891a1c8eca72e29e35_layers.base_layers,
#                 layer_control_d8637cfb8ea35e891a1c8eca72e29e35_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_f49e29f03281a58474b6f0d645d6c482);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
