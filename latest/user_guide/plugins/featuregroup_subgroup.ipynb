# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3aa0144453deaac35f8231333011d82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3aa0144453deaac35f8231333011d82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3aa0144453deaac35f8231333011d82 = L.map(
#                 &quot;map_a3aa0144453deaac35f8231333011d82&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfeb9346ce71cb4397308a41326ee70a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dfeb9346ce71cb4397308a41326ee70a.addTo(map_a3aa0144453deaac35f8231333011d82);
#
#
#             var feature_group_2674853391791bbd6916afa7bb7fe140 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_2674853391791bbd6916afa7bb7fe140.addTo(map_a3aa0144453deaac35f8231333011d82);
#
#
#             var feature_group_sub_group_b3edea80ebf3ae727740e7fe1e6673e4 = L.featureGroup.subGroup(
#                 feature_group_2674853391791bbd6916afa7bb7fe140
#             );
#
#
#             var marker_cdcea3a3b6e24d3a47d6674d7444c6a2 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_b3edea80ebf3ae727740e7fe1e6673e4);
#
#
#             var marker_a9648d249db075439e045e78eed08214 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_b3edea80ebf3ae727740e7fe1e6673e4);
#
#
#             feature_group_sub_group_b3edea80ebf3ae727740e7fe1e6673e4.addTo(map_a3aa0144453deaac35f8231333011d82);
#
#
#             var feature_group_sub_group_4e68bf9bc9ee66295257bdcbc23c8977 = L.featureGroup.subGroup(
#                 feature_group_2674853391791bbd6916afa7bb7fe140
#             );
#
#
#             var marker_8ed1d4af60fb5662c56cb67042b7a175 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4e68bf9bc9ee66295257bdcbc23c8977);
#
#
#             var marker_29cefdb6844e28b64567294db965f9cf = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4e68bf9bc9ee66295257bdcbc23c8977);
#
#
#             feature_group_sub_group_4e68bf9bc9ee66295257bdcbc23c8977.addTo(map_a3aa0144453deaac35f8231333011d82);
#
#
#             var layer_control_048c34f273d8ffe29a767db0419cee90_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_dfeb9346ce71cb4397308a41326ee70a,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_2674853391791bbd6916afa7bb7fe140,
#                     &quot;group1&quot; : feature_group_sub_group_b3edea80ebf3ae727740e7fe1e6673e4,
#                     &quot;group2&quot; : feature_group_sub_group_4e68bf9bc9ee66295257bdcbc23c8977,
#                 },
#             };
#             let layer_control_048c34f273d8ffe29a767db0419cee90 = L.control.layers(
#                 layer_control_048c34f273d8ffe29a767db0419cee90_layers.base_layers,
#                 layer_control_048c34f273d8ffe29a767db0419cee90_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_a3aa0144453deaac35f8231333011d82);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4c5b4ba6f891945e0d4070ae2d099b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4c5b4ba6f891945e0d4070ae2d099b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4c5b4ba6f891945e0d4070ae2d099b3 = L.map(
#                 &quot;map_c4c5b4ba6f891945e0d4070ae2d099b3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98f2adc6c485fc6ef555e90cb1b870be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_98f2adc6c485fc6ef555e90cb1b870be.addTo(map_c4c5b4ba6f891945e0d4070ae2d099b3);
#
#
#             var marker_cluster_4a7f70e4ad4a29f72bd2dd2f85cb76a9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_4a7f70e4ad4a29f72bd2dd2f85cb76a9.addTo(map_c4c5b4ba6f891945e0d4070ae2d099b3);
#
#
#             var feature_group_sub_group_3f1b2d4d28aedd7f5b74ef77a21c8717 = L.featureGroup.subGroup(
#                 marker_cluster_4a7f70e4ad4a29f72bd2dd2f85cb76a9
#             );
#
#
#             var marker_a02a471d39ed515c5bec420c42e67c01 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3f1b2d4d28aedd7f5b74ef77a21c8717);
#
#
#             var marker_7f9c9848e5038ab687c53f59fed7fd47 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3f1b2d4d28aedd7f5b74ef77a21c8717);
#
#
#             feature_group_sub_group_3f1b2d4d28aedd7f5b74ef77a21c8717.addTo(map_c4c5b4ba6f891945e0d4070ae2d099b3);
#
#
#             var feature_group_sub_group_905e6d7fc07017d6e5320d745c51a128 = L.featureGroup.subGroup(
#                 marker_cluster_4a7f70e4ad4a29f72bd2dd2f85cb76a9
#             );
#
#
#             var marker_f0d3e00ebcf436b95081ee8a00ee004c = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_905e6d7fc07017d6e5320d745c51a128);
#
#
#             var marker_28971006eea9d8a2b3df499f28e2c6ef = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_905e6d7fc07017d6e5320d745c51a128);
#
#
#             feature_group_sub_group_905e6d7fc07017d6e5320d745c51a128.addTo(map_c4c5b4ba6f891945e0d4070ae2d099b3);
#
#
#             var layer_control_7f85691bf53d5fbca33301be19fa3349_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_98f2adc6c485fc6ef555e90cb1b870be,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_3f1b2d4d28aedd7f5b74ef77a21c8717,
#                     &quot;group2&quot; : feature_group_sub_group_905e6d7fc07017d6e5320d745c51a128,
#                 },
#             };
#             let layer_control_7f85691bf53d5fbca33301be19fa3349 = L.control.layers(
#                 layer_control_7f85691bf53d5fbca33301be19fa3349_layers.base_layers,
#                 layer_control_7f85691bf53d5fbca33301be19fa3349_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c4c5b4ba6f891945e0d4070ae2d099b3);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
