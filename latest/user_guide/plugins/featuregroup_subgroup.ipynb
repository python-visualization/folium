# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44b21dd8060852473739f279ecbcdcc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44b21dd8060852473739f279ecbcdcc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44b21dd8060852473739f279ecbcdcc4 = L.map(
#                 &quot;map_44b21dd8060852473739f279ecbcdcc4&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbc52071c31f3c0045fbc2e350e293eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bbc52071c31f3c0045fbc2e350e293eb.addTo(map_44b21dd8060852473739f279ecbcdcc4);
#
#
#             var feature_group_8598b402fa739ea9c6cd01e9e5f8dab5 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_8598b402fa739ea9c6cd01e9e5f8dab5.addTo(map_44b21dd8060852473739f279ecbcdcc4);
#
#
#             var feature_group_sub_group_c961176ad81d341ac6c323656c540493 = L.featureGroup.subGroup(
#                 feature_group_8598b402fa739ea9c6cd01e9e5f8dab5
#             );
#
#
#             var marker_cf183e974e9ba8d275aad70436f573ab = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_c961176ad81d341ac6c323656c540493);
#
#
#             var marker_5297fa4ab26cd2dabd8de721487c1596 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_c961176ad81d341ac6c323656c540493);
#
#
#             feature_group_sub_group_c961176ad81d341ac6c323656c540493.addTo(map_44b21dd8060852473739f279ecbcdcc4);
#
#
#             var feature_group_sub_group_802f6cb135be52314c69be14e9bb1f46 = L.featureGroup.subGroup(
#                 feature_group_8598b402fa739ea9c6cd01e9e5f8dab5
#             );
#
#
#             var marker_f5bff78382efe8d6364122b71058c3b8 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_802f6cb135be52314c69be14e9bb1f46);
#
#
#             var marker_e96c31b09754887e480952fabd528959 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_802f6cb135be52314c69be14e9bb1f46);
#
#
#             feature_group_sub_group_802f6cb135be52314c69be14e9bb1f46.addTo(map_44b21dd8060852473739f279ecbcdcc4);
#
#
#             var layer_control_85be93833903e9ff7e4425e6ff3b0f5b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_bbc52071c31f3c0045fbc2e350e293eb,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_8598b402fa739ea9c6cd01e9e5f8dab5,
#                     &quot;group1&quot; : feature_group_sub_group_c961176ad81d341ac6c323656c540493,
#                     &quot;group2&quot; : feature_group_sub_group_802f6cb135be52314c69be14e9bb1f46,
#                 },
#             };
#             let layer_control_85be93833903e9ff7e4425e6ff3b0f5b = L.control.layers(
#                 layer_control_85be93833903e9ff7e4425e6ff3b0f5b_layers.base_layers,
#                 layer_control_85be93833903e9ff7e4425e6ff3b0f5b_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_44b21dd8060852473739f279ecbcdcc4);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3478d1fbf4db8ba6ee7a2ef7f33d9261 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3478d1fbf4db8ba6ee7a2ef7f33d9261&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3478d1fbf4db8ba6ee7a2ef7f33d9261 = L.map(
#                 &quot;map_3478d1fbf4db8ba6ee7a2ef7f33d9261&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dd3a26534d8f249ee7783a18823df6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8dd3a26534d8f249ee7783a18823df6e.addTo(map_3478d1fbf4db8ba6ee7a2ef7f33d9261);
#
#
#             var marker_cluster_5e9fefb4ba5dd62b09128662a9f5f8d7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_5e9fefb4ba5dd62b09128662a9f5f8d7.addTo(map_3478d1fbf4db8ba6ee7a2ef7f33d9261);
#
#
#             var feature_group_sub_group_baf51087fbcbaf70f39ab69d789e90bc = L.featureGroup.subGroup(
#                 marker_cluster_5e9fefb4ba5dd62b09128662a9f5f8d7
#             );
#
#
#             var marker_b3c4b67905cfccef8845855dd4432fc8 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_baf51087fbcbaf70f39ab69d789e90bc);
#
#
#             var marker_d0ec2fc6b60f9ce6bddb17c39ea43fd5 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_baf51087fbcbaf70f39ab69d789e90bc);
#
#
#             feature_group_sub_group_baf51087fbcbaf70f39ab69d789e90bc.addTo(map_3478d1fbf4db8ba6ee7a2ef7f33d9261);
#
#
#             var feature_group_sub_group_83acb66ef79ef401402d372924bf651d = L.featureGroup.subGroup(
#                 marker_cluster_5e9fefb4ba5dd62b09128662a9f5f8d7
#             );
#
#
#             var marker_03c25fdbf74c0154d48db95be7ad99cd = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_83acb66ef79ef401402d372924bf651d);
#
#
#             var marker_7f0404154edab84d544ff9cb543f21bd = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_83acb66ef79ef401402d372924bf651d);
#
#
#             feature_group_sub_group_83acb66ef79ef401402d372924bf651d.addTo(map_3478d1fbf4db8ba6ee7a2ef7f33d9261);
#
#
#             var layer_control_1e79c193fdb9d8d15a05514730e7517d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_8dd3a26534d8f249ee7783a18823df6e,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_baf51087fbcbaf70f39ab69d789e90bc,
#                     &quot;group2&quot; : feature_group_sub_group_83acb66ef79ef401402d372924bf651d,
#                 },
#             };
#             let layer_control_1e79c193fdb9d8d15a05514730e7517d = L.control.layers(
#                 layer_control_1e79c193fdb9d8d15a05514730e7517d_layers.base_layers,
#                 layer_control_1e79c193fdb9d8d15a05514730e7517d_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_3478d1fbf4db8ba6ee7a2ef7f33d9261);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
