# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf3ad5f742a8918e3f0e5322e284b29e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf3ad5f742a8918e3f0e5322e284b29e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf3ad5f742a8918e3f0e5322e284b29e = L.map(
#                 &quot;map_cf3ad5f742a8918e3f0e5322e284b29e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd06c15f990c41cbca8024577caf73c9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fd06c15f990c41cbca8024577caf73c9.addTo(map_cf3ad5f742a8918e3f0e5322e284b29e);
#
#
#             var feature_group_3049cafb6c6ea3f2a2ab0b2da9e61a7a = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_3049cafb6c6ea3f2a2ab0b2da9e61a7a.addTo(map_cf3ad5f742a8918e3f0e5322e284b29e);
#
#
#             var feature_group_sub_group_7e60eb8e363f35146c2a07fc0fef6747 = L.featureGroup.subGroup(
#                 feature_group_3049cafb6c6ea3f2a2ab0b2da9e61a7a
#             );
#
#
#             var marker_52140efff2023905aab0624997529ecb = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7e60eb8e363f35146c2a07fc0fef6747);
#
#
#             var marker_bab93fa42e277dba5fd01da53c2c556b = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7e60eb8e363f35146c2a07fc0fef6747);
#
#
#             feature_group_sub_group_7e60eb8e363f35146c2a07fc0fef6747.addTo(map_cf3ad5f742a8918e3f0e5322e284b29e);
#
#
#             var feature_group_sub_group_29ea93435763bd89ec259d0803e9684d = L.featureGroup.subGroup(
#                 feature_group_3049cafb6c6ea3f2a2ab0b2da9e61a7a
#             );
#
#
#             var marker_eaa2b7f675fee97c43653150d420c6a2 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_29ea93435763bd89ec259d0803e9684d);
#
#
#             var marker_d21038c065cd2e72015866d83473ebea = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_29ea93435763bd89ec259d0803e9684d);
#
#
#             feature_group_sub_group_29ea93435763bd89ec259d0803e9684d.addTo(map_cf3ad5f742a8918e3f0e5322e284b29e);
#
#
#             var layer_control_7d9a1c8a9b2b7f70f6f12186879084e0_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_fd06c15f990c41cbca8024577caf73c9,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_3049cafb6c6ea3f2a2ab0b2da9e61a7a,
#                     &quot;group1&quot; : feature_group_sub_group_7e60eb8e363f35146c2a07fc0fef6747,
#                     &quot;group2&quot; : feature_group_sub_group_29ea93435763bd89ec259d0803e9684d,
#                 },
#             };
#             let layer_control_7d9a1c8a9b2b7f70f6f12186879084e0 = L.control.layers(
#                 layer_control_7d9a1c8a9b2b7f70f6f12186879084e0_layers.base_layers,
#                 layer_control_7d9a1c8a9b2b7f70f6f12186879084e0_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_cf3ad5f742a8918e3f0e5322e284b29e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cfd5b4398c9b7736a474840c068fa20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cfd5b4398c9b7736a474840c068fa20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cfd5b4398c9b7736a474840c068fa20 = L.map(
#                 &quot;map_8cfd5b4398c9b7736a474840c068fa20&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_541c9c66f10a232e184ae8f711b84432 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_541c9c66f10a232e184ae8f711b84432.addTo(map_8cfd5b4398c9b7736a474840c068fa20);
#
#
#             var marker_cluster_71ec026011f6d2fe36d97c5e2bffd6fd = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_71ec026011f6d2fe36d97c5e2bffd6fd.addTo(map_8cfd5b4398c9b7736a474840c068fa20);
#
#
#             var feature_group_sub_group_4814cf718747c1a867e25da3ee3b9d51 = L.featureGroup.subGroup(
#                 marker_cluster_71ec026011f6d2fe36d97c5e2bffd6fd
#             );
#
#
#             var marker_ef805b157ca6fbc0530c044b01dcfc22 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4814cf718747c1a867e25da3ee3b9d51);
#
#
#             var marker_2d4a54ef81dc664d03c6dac9ee149ff6 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4814cf718747c1a867e25da3ee3b9d51);
#
#
#             feature_group_sub_group_4814cf718747c1a867e25da3ee3b9d51.addTo(map_8cfd5b4398c9b7736a474840c068fa20);
#
#
#             var feature_group_sub_group_27d76075c5cc544e41776f15fe45fb60 = L.featureGroup.subGroup(
#                 marker_cluster_71ec026011f6d2fe36d97c5e2bffd6fd
#             );
#
#
#             var marker_946dcdf0259fe10d307e6854e2eb4831 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_27d76075c5cc544e41776f15fe45fb60);
#
#
#             var marker_455a590f46be3ebb12110137c1911661 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_27d76075c5cc544e41776f15fe45fb60);
#
#
#             feature_group_sub_group_27d76075c5cc544e41776f15fe45fb60.addTo(map_8cfd5b4398c9b7736a474840c068fa20);
#
#
#             var layer_control_9cb62043121efd3cf6b4a7e9e102c376_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_541c9c66f10a232e184ae8f711b84432,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_4814cf718747c1a867e25da3ee3b9d51,
#                     &quot;group2&quot; : feature_group_sub_group_27d76075c5cc544e41776f15fe45fb60,
#                 },
#             };
#             let layer_control_9cb62043121efd3cf6b4a7e9e102c376 = L.control.layers(
#                 layer_control_9cb62043121efd3cf6b4a7e9e102c376_layers.base_layers,
#                 layer_control_9cb62043121efd3cf6b4a7e9e102c376_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_8cfd5b4398c9b7736a474840c068fa20);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
