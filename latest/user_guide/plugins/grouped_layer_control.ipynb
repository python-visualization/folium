# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10a5ff1610f7d3aa2487395769b2c534 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10a5ff1610f7d3aa2487395769b2c534&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10a5ff1610f7d3aa2487395769b2c534 = L.map(
#                 &quot;map_10a5ff1610f7d3aa2487395769b2c534&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3be673a2ed2bfa334649eaf362000c17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3be673a2ed2bfa334649eaf362000c17.addTo(map_10a5ff1610f7d3aa2487395769b2c534);
#
#
#             var feature_group_afcb8b86c1d684fadd9d97b7341b37a8 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_616e5cf9a13b511c79125be1f3a47914 = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_afcb8b86c1d684fadd9d97b7341b37a8);
#
#
#             feature_group_afcb8b86c1d684fadd9d97b7341b37a8.addTo(map_10a5ff1610f7d3aa2487395769b2c534);
#
#
#             var feature_group_82ef760b2f4e02fc7ade574a1a69b3e4 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_d8f0b2558d0bdbbc1a8a3a8018c98788 = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_82ef760b2f4e02fc7ade574a1a69b3e4);
#
#
#             feature_group_82ef760b2f4e02fc7ade574a1a69b3e4.addTo(map_10a5ff1610f7d3aa2487395769b2c534);
#
#
#             var feature_group_4ff2a5e53684d9e80cd3592d314a6dbd = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_f8b08e60f9cf1443721cfd7eeecbc591 = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_4ff2a5e53684d9e80cd3592d314a6dbd);
#
#
#             feature_group_4ff2a5e53684d9e80cd3592d314a6dbd.addTo(map_10a5ff1610f7d3aa2487395769b2c534);
#
#
#             var layer_control_7ead02700ab7d88f59bbdc3915620aaf_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3be673a2ed2bfa334649eaf362000c17,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_4ff2a5e53684d9e80cd3592d314a6dbd,
#                 },
#             };
#             let layer_control_7ead02700ab7d88f59bbdc3915620aaf = L.control.layers(
#                 layer_control_7ead02700ab7d88f59bbdc3915620aaf_layers.base_layers,
#                 layer_control_7ead02700ab7d88f59bbdc3915620aaf_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_10a5ff1610f7d3aa2487395769b2c534);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_afcb8b86c1d684fadd9d97b7341b37a8,
#                         &quot;g2&quot; : feature_group_82ef760b2f4e02fc7ade574a1a69b3e4,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false, &quot;exclusiveGroups&quot;: [&quot;groups1&quot;]},
#             ).addTo(map_10a5ff1610f7d3aa2487395769b2c534);
#             feature_group_82ef760b2f4e02fc7ade574a1a69b3e4.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fd53e4c8423e128305544e4de7e6840 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fd53e4c8423e128305544e4de7e6840&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fd53e4c8423e128305544e4de7e6840 = L.map(
#                 &quot;map_9fd53e4c8423e128305544e4de7e6840&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_baf722ede9b61c428e0bb5c2f21c6d62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_baf722ede9b61c428e0bb5c2f21c6d62.addTo(map_9fd53e4c8423e128305544e4de7e6840);
#
#
#             var feature_group_cf0c76545fec7a6e9f551cdbc7c3ac18 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_18bf21ec6a02056fb678dc493c9b01bc = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_cf0c76545fec7a6e9f551cdbc7c3ac18);
#
#
#             var feature_group_cd8ee3ace7869338728739beb86c4c09 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_e6097a073a9fbcae4828792a08ff0086 = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_cd8ee3ace7869338728739beb86c4c09);
#
#
#             var feature_group_b358706c1abc4cf2bc47470a1160f289 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_10bd82f64291c801467dfb36b430aae2 = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_b358706c1abc4cf2bc47470a1160f289);
#
#
#             feature_group_b358706c1abc4cf2bc47470a1160f289.addTo(map_9fd53e4c8423e128305544e4de7e6840);
#
#
#             var layer_control_c2168575f1ea43082bacdd1711d7b991_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_baf722ede9b61c428e0bb5c2f21c6d62,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_b358706c1abc4cf2bc47470a1160f289,
#                 },
#             };
#             let layer_control_c2168575f1ea43082bacdd1711d7b991 = L.control.layers(
#                 layer_control_c2168575f1ea43082bacdd1711d7b991_layers.base_layers,
#                 layer_control_c2168575f1ea43082bacdd1711d7b991_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_9fd53e4c8423e128305544e4de7e6840);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_cf0c76545fec7a6e9f551cdbc7c3ac18,
#                         &quot;g2&quot; : feature_group_cd8ee3ace7869338728739beb86c4c09,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false},
#             ).addTo(map_9fd53e4c8423e128305544e4de7e6840);
#             feature_group_cd8ee3ace7869338728739beb86c4c09.remove();
#             feature_group_cf0c76545fec7a6e9f551cdbc7c3ac18.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
