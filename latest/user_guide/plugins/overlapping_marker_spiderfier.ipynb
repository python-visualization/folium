# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b54e47575d86e4e24e66a0548f657fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b54e47575d86e4e24e66a0548f657fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b54e47575d86e4e24e66a0548f657fb = L.map(
#                 &quot;map_5b54e47575d86e4e24e66a0548f657fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e97e6e1824ab9ae6a8b1dcbe045b211 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e97e6e1824ab9ae6a8b1dcbe045b211.addTo(map_5b54e47575d86e4e24e66a0548f657fb);
#
#
#             var marker_8a219267a8f86a384109582850076239 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5b54e47575d86e4e24e66a0548f657fb);
#
#
#         var popup_4dff4542c490d8c5662e9ca9995aed29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a031ff1f00ce5ed76b13bc4dc42fbfd3 = $(`&lt;div id=&quot;html_a031ff1f00ce5ed76b13bc4dc42fbfd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4dff4542c490d8c5662e9ca9995aed29.setContent(html_a031ff1f00ce5ed76b13bc4dc42fbfd3);
#
#
#
#         marker_8a219267a8f86a384109582850076239.bindPopup(popup_4dff4542c490d8c5662e9ca9995aed29)
#         ;
#
#
#
#
#             var marker_a25f2713be67bf77156cd3d5deddfb48 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5b54e47575d86e4e24e66a0548f657fb);
#
#
#         var popup_b9ee208e9199591fd84484087a932239 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53145abf290ca51e9f59c96ca06dd885 = $(`&lt;div id=&quot;html_53145abf290ca51e9f59c96ca06dd885&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b9ee208e9199591fd84484087a932239.setContent(html_53145abf290ca51e9f59c96ca06dd885);
#
#
#
#         marker_a25f2713be67bf77156cd3d5deddfb48.bindPopup(popup_b9ee208e9199591fd84484087a932239)
#         ;
#
#
#
#
#             var marker_b71747f81132988d9ab1c61fdbcacb00 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5b54e47575d86e4e24e66a0548f657fb);
#
#
#         var popup_2a1326e4c82f926ec1921e4e26516b23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3358514906de6b4aa8a448720f946266 = $(`&lt;div id=&quot;html_3358514906de6b4aa8a448720f946266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2a1326e4c82f926ec1921e4e26516b23.setContent(html_3358514906de6b4aa8a448720f946266);
#
#
#
#         marker_b71747f81132988d9ab1c61fdbcacb00.bindPopup(popup_2a1326e4c82f926ec1921e4e26516b23)
#         ;
#
#
#
#
#             var marker_af1064c41cfca74872e3ec0c3251d255 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5b54e47575d86e4e24e66a0548f657fb);
#
#
#         var popup_2afa41ecb554e846bd8ea07f14f336da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09bd5d1fdb7695282523cdcbc8139f36 = $(`&lt;div id=&quot;html_09bd5d1fdb7695282523cdcbc8139f36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2afa41ecb554e846bd8ea07f14f336da.setContent(html_09bd5d1fdb7695282523cdcbc8139f36);
#
#
#
#         marker_af1064c41cfca74872e3ec0c3251d255.bindPopup(popup_2afa41ecb554e846bd8ea07f14f336da)
#         ;
#
#
#
#
#             var marker_a38f0e45c92e5bcb0c8c5e675481423b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5b54e47575d86e4e24e66a0548f657fb);
#
#
#         var popup_170dbe82431eb8b196cffe08e907978d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_579e99d688b40578b5ae225ab4f29262 = $(`&lt;div id=&quot;html_579e99d688b40578b5ae225ab4f29262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_170dbe82431eb8b196cffe08e907978d.setContent(html_579e99d688b40578b5ae225ab4f29262);
#
#
#
#         marker_a38f0e45c92e5bcb0c8c5e675481423b.bindPopup(popup_170dbe82431eb8b196cffe08e907978d)
#         ;
#
#
#
#
#             var marker_ac73cc478c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58154c0e8ef091c1fabce35decbead47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58154c0e8ef091c1fabce35decbead47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58154c0e8ef091c1fabce35decbead47 = L.map(
#                 &quot;map_58154c0e8ef091c1fabce35decbead47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22058aa461d6f6c84b3c8a9b620f0a45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22058aa461d6f6c84b3c8a9b620f0a45.addTo(map_58154c0e8ef091c1fabce35decbead47);
#
#
#             var feature_group_e423dc2b0bbbfc8293c8ba559d32f26f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_66e4bb072fc329b087f59217411f4861 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e423dc2b0bbbfc8293c8ba559d32f26f);
#
#
#         var popup_09df0cbe02ef4c827b456d9fe1a1f860 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b0ce7539a41d5c0a7a6ed456a73ad4b = $(`&lt;div id=&quot;html_4b0ce7539a41d5c0a7a6ed456a73ad4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_09df0cbe02ef4c827b456d9fe1a1f860.setContent(html_4b0ce7539a41d5c0a7a6ed456a73ad4b);
#
#
#
#         marker_66e4bb072fc329b087f59217411f4861.bindPopup(popup_09df0cbe02ef4c827b456d9fe1a1f860)
#         ;
#
#
#
#
#             var marker_0b5b9ffa1ed2e861e6b377fe64b49d69 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e423dc2b0bbbfc8293c8ba559d32f26f);
#
#
#         var popup_7ca03130b0ebfa15cb05a5c870bd5793 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3896260aeeb558d82a608b8b78255f49 = $(`&lt;div id=&quot;html_3896260aeeb558d82a608b8b78255f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7ca03130b0ebfa15cb05a5c870bd5793.setContent(html_3896260aeeb558d82a608b8b78255f49);
#
#
#
#         marker_0b5b9ffa1ed2e861e6b377fe64b49d69.bindPopup(popup_7ca03130b0ebfa15cb05a5c870bd5793)
#         ;
#
#
#
#
#             var marker_47eec293558195787be83af5c6aeabaa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e423dc2b0bbbfc8293c8ba559d32f26f);
#
#
#         var popup_990e72ff36acbed89df0c5d67ecbc8e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d79d59b8306ffe65c4b9ad29cac6ff7 = $(`&lt;div id=&quot;html_4d79d59b8306ffe65c4b9ad29cac6ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_990e72ff36acbed89df0c5d67ecbc8e8.setContent(html_4d79d59b8306ffe65c4b9ad29cac6ff7);
#
#
#
#         marker_47eec293558195787be83af5c6aeabaa.bindPopup(popup_990e72ff36acbed89df0c5d67ecbc8e8)
#         ;
#
#
#
#
#             var marker_4ac166bedf65b1ebc83a67fce5999d3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e423dc2b0bbbfc8293c8ba559d32f26f);
#
#
#         var popup_6d0faf8bdbeabef6e613bbe8f23858db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c47c21d623479e7e49b4082b479ad1fa = $(`&lt;div id=&quot;html_c47c21d623479e7e49b4082b479ad1fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6d0faf8bdbeabef6e613bbe8f23858db.setContent(html_c47c21d623479e7e49b4082b479ad1fa);
#
#
#
#         marker_4ac166bedf65b1ebc83a67fce5999d3a.bindPopup(popup_6d0faf8bdbeabef6e613bbe8f23858db)
#         ;
#
#
#
#
#             var marker_67981bd0d6e99e5cbce2bb5fc435f8d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e423dc2b0bbbfc8293c8ba559d32f26f);
#
#
#         var popup_f1379e82ea13b9f69eaa3b89736c1129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de76e50716ce7ac73eb891028681e741 = $(`&lt;div id=&quot;html_de76e50716ce7ac73eb891028681e741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_f1379e82ea13b9f69e

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05851f412a18ccbea7991b9fbcb7ab0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05851f412a18ccbea7991b9fbcb7ab0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05851f412a18ccbea7991b9fbcb7ab0a = L.map(
#                 &quot;map_05851f412a18ccbea7991b9fbcb7ab0a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04ad9727e1c27a4d89593b8975ba361b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04ad9727e1c27a4d89593b8975ba361b.addTo(map_05851f412a18ccbea7991b9fbcb7ab0a);
#
#
#             var feature_group_93cf27427c7418aec7dce0b15127d594 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_93cf27427c7418aec7dce0b15127d594.addTo(map_05851f412a18ccbea7991b9fbcb7ab0a);
#
#
#             var feature_group_sub_group_206b6e210e309110404837713e543f73 = L.featureGroup.subGroup(
#                 feature_group_93cf27427c7418aec7dce0b15127d594
#             );
#
#
#             var marker_560d0dc1cea267f86f21808e89f7e483 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_206b6e210e309110404837713e543f73);
#
#
#         var popup_1f9d6d0fcd5ae3fc4f8e02bd1dfe2ffb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dad8d44a11ce65e7346f5d74007dafb = $(`&lt;div id=&quot;html_9dad8d44a11ce65e7346f5d74007dafb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1f9d6d0fcd5ae3fc4f8e02bd1dfe2ffb.setContent(html_9dad8d44a11ce65e7346f5d74007dafb);
#
#
#
#         marker_560d0dc1cea267f86f21808e89f7e483.bindPopup(popup_1f9d6d0fcd5ae3fc4f8e02bd1dfe2ffb)
#         ;
#
#
#
#
#             var marker_86d8121feb2fc442985c4f6f6b53b115 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_206b6e210e309110404837713e543f73);
#
#
#         var popup_07572c3c8e3d93a62a11f8d374bac428 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a101d07ee096b124c8a9127a820bd518 = $(`&lt;div id=&quot;html_a101d07ee096b124c8a9127a820bd518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_07572c3c8e3d93a62a11f8d374bac428.setContent(html_a101d07ee096b124c8a9127a820bd518);
#
#
#
#         marker_86d8121feb2fc442985c4f6f6b53b115.bindPopup(popup_07572c3c8e3d93a62a11f8d374bac428)
#         ;
#
#
#
#
#             var marker_a071ff51d3d6aaa858c14a92366da26b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_206b6e210e309110404837713e543f73);
#
#
#         var popup_ccd9e2090f694304674d0476ad1a852f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6345ac898b869ab0e886812b01997f33 = $(`&lt;div id=&quot;html_6345ac898b869ab0e886812b01997f33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ccd9e2090f694304674d0476ad1a852f.setContent(html_6345ac898b869ab0e886812b01997f33);
#
#
#
#         marker_a071ff51d3d6aaa858c14a92366da26b.bindPopup(popup_ccd9e2090f694304674d0476ad1a852f)
#         ;
#
#
#
#
#             var marker_2e2a0166e44d8175d07634c632f7b891 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_206b6e210e309110404837713e543f73);
#
#
#         var popup_960ffa1656978b82f451aabecf70e754 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f2ba48ea9dbf79b7414a3a6cab3398d = $(`&lt;div id=&quot;html_0f2ba48ea9dbf79b7414a3a6cab3398d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_960ffa1656978b82f451aabecf70e754.setContent(html_0f2ba48ea9dbf79b7414a3a6cab3398d);
#
#
#
#         marker_2e2a0166e44d8175d07634c632f7b891.bindPopup(popup_960ffa1656978b82f451aabecf70e754)
#         ;
#
#
#
#
#             var marker_31d8190e62b36e7a7dd9b5b5feb453bd = L.marker(
#                 [45.050399999999996, 3.0504],
