# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fc84d392fcf2e56355cbf24994587cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fc84d392fcf2e56355cbf24994587cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fc84d392fcf2e56355cbf24994587cb = L.map(
#                 &quot;map_6fc84d392fcf2e56355cbf24994587cb&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aab4bbb9ee1dfb0198b3682839fabc7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aab4bbb9ee1dfb0198b3682839fabc7f.addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_2ea141cfad9f646d1e39d688ed12a2a4 = L.marker(
#                 [49.140849819008, 5.341920909796252],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_3ad0e4e2a8f9a80c82b192c56a445f83 = L.marker(
#                 [47.66992483203439, 5.594918228337862],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_2f99de85b6de9eae9ee85f8cfe608d9d = L.marker(
#                 [48.39782306072522, 4.973597255377943],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_b7a48e1b91e10aa74b6cf025db61f5b0 = L.marker(
#                 [47.80630446370204, 5.268963573464129],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_88fcbea38281d4fa7b902f71b936585c = L.marker(
#                 [49.28404754193959, 4.72815834556274],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_0df36f51344c4575d2de4e6b70c5f25a = L.marker(
#                 [46.41164992091441, 5.699197742847859],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_63bc1878c195bdf182eb8423897113aa = L.marker(
#                 [49.79915999838734, 4.784525805105027],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_e0eafcb8bf47d0023fb835d516272a60 = L.marker(
#                 [49.09055620454983, 5.462116176164631],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_e47409c6610fdcdf9f3ecebf8aeb1f8d = L.marker(
#                 [48.053135916254256, 5.614159133399065],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_3fe3d1cffeb40fddd62b508430d56817 = L.marker(
#                 [48.724532570375956, 3.2097876791119244],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_891199a66ad8775829e12a90358ea664 = L.marker(
#                 [47.97392029835614, 4.839767548064898],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_1517f3db1574f77112d8d1216cdfbbc9 = L.marker(
#                 [46.10867286286514, 4.628024152827371],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_a7f88253c8a178de2390c2e2c44d069a = L.marker(
#                 [48.509504341115935, 6.319578141416077],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_6fc84d392fcf2e56355cbf24994587cb);
#
#
#             var marker_e8e21054a9948eae8fa423c05aaa4943 = L.marker(
#                 [48.95303407493143, 4.938890686601252],
#                 {&quot;
