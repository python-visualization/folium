# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cd52e2c3e827bc745c30455eb99de4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cd52e2c3e827bc745c30455eb99de4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cd52e2c3e827bc745c30455eb99de4b = L.map(
#                 &quot;map_8cd52e2c3e827bc745c30455eb99de4b&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec0a165042948153fc46b6314bd50a22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ec0a165042948153fc46b6314bd50a22.addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_0e69b4088c127fc0c01a3fb7b075d53d = L.marker(
#                 [48.09395952437877, 3.7879981420935542],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_414ddb1e41c6b4d9b0b7f996de50dbb0 = L.marker(
#                 [47.78688650147474, 3.8254050870233263],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_e331b86505af7718572db525fe4e65f2 = L.marker(
#                 [47.31424657615831, 4.64049257615097],
#                 {&quot;tags&quot;: [&quot;category1&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_a1ded2e530682eecb72caa50ad331b42 = L.marker(
#                 [47.24946566572699, 3.6470919687973904],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_2bfd6ef60ee00b251296629bdcd32b25 = L.marker(
#                 [48.512354765073404, 2.9805881245373254],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_9efe01eaf68a44b60f6368e0d737a665 = L.marker(
#                 [47.24899941020005, 5.092388156366022],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_f5c40f31102ddd47d966901596086ea2 = L.marker(
#                 [47.40702944154478, 4.743701996393991],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_10dd0e0d0c9dfa606b697680cc38d438 = L.marker(
#                 [46.899741122310466, 5.636079917744578],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_2148d95decabe283fbe26052363d0dc9 = L.marker(
#                 [48.411913034361206, 4.968095813466735],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_ddf7124cbdf96b96ce69ab700cd6ec52 = L.marker(
#                 [48.05781259230218, 5.593273695140078],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_686bf67feee1a52c64d1d39b040303a5 = L.marker(
#                 [48.381061463900565, 4.876754529465785],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_7de505230fc908ec3487ed98362ab85d = L.marker(
#                 [48.31391244726907, 5.258704468439609],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_5b49d87eb3289356244b68859ee60876 = L.marker(
#                 [46.912316207513065, 4.251760756336409],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_8cd52e2c3e827bc745c30455eb99de4b);
#
#
#             var marker_fe0bc0a8291e7671cba0bbae5a242745 = L.marker(
#                 [47.00091678364697, 5.908706685960431],
