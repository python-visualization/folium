# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad564f6001e15082b4bf1a2c5ebba255 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad564f6001e15082b4bf1a2c5ebba255&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad564f6001e15082b4bf1a2c5ebba255 = L.map(
#                 &quot;map_ad564f6001e15082b4bf1a2c5ebba255&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_063657d0116c9cefdccdfefd3f46021b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_063657d0116c9cefdccdfefd3f46021b.addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_e7f7e6e2fb0c558d4bfeba5e7c4c7380 = L.marker(
#                 [47.17760007065927, 4.959923996898908],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_db84a323af58e0c1e8e0824868c2c079 = L.marker(
#                 [46.79523977403763, 5.701473125745523],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_68984bd4e93b2eab528ea6e530a413d3 = L.marker(
#                 [46.70344656488628, 3.5182563836266576],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_85b6d805a81e0e86d54ee34dd6b616e3 = L.marker(
#                 [48.327640952495656, 5.430050458735578],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_e6d6649940f2204e52bb56cbdca1a1ea = L.marker(
#                 [50.93106435086563, 5.435785662233669],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_1873a62c89bfe1d534fde6181ecb5d1f = L.marker(
#                 [49.3242163251884, 4.760054577689223],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_5d1f966b9fb3b1567e3e3ca540c748e7 = L.marker(
#                 [48.399995983904226, 7.239367830167053],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_370967897aa870afd0f55ecf8140ad28 = L.marker(
#                 [47.55037564014303, 4.726213687339788],
#                 {&quot;tags&quot;: [&quot;category3&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_58fd3797305e2251644265899af3d8c9 = L.marker(
#                 [45.960694921309944, 4.16080817837959],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_b5ff0e71191c5ace959f40412b855f1a = L.marker(
#                 [47.8393498109836, 5.533185453113471],
#                 {&quot;tags&quot;: [&quot;category5&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_518a7f50db596ea16faf64f36523cbf1 = L.marker(
#                 [49.053683205118126, 5.647697719617403],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_bc80b9c99d20025f1a2836562b00f0ec = L.marker(
#                 [48.768791334788716, 5.673898271084051],
#                 {&quot;tags&quot;: [&quot;category4&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_a443b03a5493b273ce2f4fa2fd72c719 = L.marker(
#                 [49.77589020266346, 5.602812286583076],
#                 {&quot;tags&quot;: [&quot;category2&quot;]}
#             ).addTo(map_ad564f6001e15082b4bf1a2c5ebba255);
#
#
#             var marker_31f6c77e28de407cb84a2b3096f042be = L.marker(
#                 [48.77288986408706, 3.308721664346841],
#                 {&quo
