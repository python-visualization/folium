# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d73e8211829caec9644da7fcaed7db9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d73e8211829caec9644da7fcaed7db9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d73e8211829caec9644da7fcaed7db9 = L.map(
#                 &quot;map_4d73e8211829caec9644da7fcaed7db9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f53a061ee68a7a2016a7d1a9d8ac70b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f53a061ee68a7a2016a7d1a9d8ac70b.addTo(map_4d73e8211829caec9644da7fcaed7db9);
#
#
#             var marker_775e7af18e7be3c067f80d3072d5e4f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4d73e8211829caec9644da7fcaed7db9);
#
#
#         var popup_0f40bfb08e8dac6beae9545a43854bbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71cfa0f79b4c17e3640f8d49b052be4e = $(`&lt;div id=&quot;html_71cfa0f79b4c17e3640f8d49b052be4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0f40bfb08e8dac6beae9545a43854bbf.setContent(html_71cfa0f79b4c17e3640f8d49b052be4e);
#
#
#
#         marker_775e7af18e7be3c067f80d3072d5e4f0.bindPopup(popup_0f40bfb08e8dac6beae9545a43854bbf)
#         ;
#
#
#
#
#             var marker_2c97dfcbd3ce5bd0235aaf007b8b0b80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4d73e8211829caec9644da7fcaed7db9);
#
#
#         var popup_2e0f0995936b0eb858670506e4cdbb56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e54fd684c0283b6f3e61b9e7435c33c4 = $(`&lt;div id=&quot;html_e54fd684c0283b6f3e61b9e7435c33c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2e0f0995936b0eb858670506e4cdbb56.setContent(html_e54fd684c0283b6f3e61b9e7435c33c4);
#
#
#
#         marker_2c97dfcbd3ce5bd0235aaf007b8b0b80.bindPopup(popup_2e0f0995936b0eb858670506e4cdbb56)
#         ;
#
#
#
#
#             var marker_b6598ccc691cb41bc7e6caf0b6b6a53e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4d73e8211829caec9644da7fcaed7db9);
#
#
#         var popup_0d3defa56d1ae524da58d2349869f647 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a114fb929c05c79526a705238c6eeb27 = $(`&lt;div id=&quot;html_a114fb929c05c79526a705238c6eeb27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0d3defa56d1ae524da58d2349869f647.setContent(html_a114fb929c05c79526a705238c6eeb27);
#
#
#
#         marker_b6598ccc691cb41bc7e6caf0b6b6a53e.bindPopup(popup_0d3defa56d1ae524da58d2349869f647)
#         ;
#
#
#
#
#             var marker_b7dbc5578ab0127ba9dce233d5240d89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4d73e8211829caec9644da7fcaed7db9);
#
#
#         var popup_c71bd8dfc693213e8e0715c3204e2f20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58c862127e07886a748f42236c4d9486 = $(`&lt;div id=&quot;html_58c862127e07886a748f42236c4d9486&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c71bd8dfc693213e8e0715c3204e2f20.setContent(html_58c862127e07886a748f42236c4d9486);
#
#
#
#         marker_b7dbc5578ab0127ba9dce233d5240d89.bindPopup(popup_c71bd8dfc693213e8e0715c3204e2f20)
#         ;
#
#
#
#
#             var marker_a796c5292f21ca3ff2fd8735d37344bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4d73e8211829caec9644da7fcaed7db9);
#
#
#         var popup_62ce6f0cc5b166926970636212414118 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a33f52f2dc7f9be8bd069d91c7f0ca8b = $(`&lt;div id=&quot;html_a33f52f2dc7f9be8bd069d91c7f0ca8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_62ce6f0cc5b166926970636212414118.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2b2af3c9f3f44db90c92a342c66094c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2b2af3c9f3f44db90c92a342c66094c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2b2af3c9f3f44db90c92a342c66094c = L.map(
#                 &quot;map_f2b2af3c9f3f44db90c92a342c66094c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d16dc5f24a2250a56b31c160b02ba67f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d16dc5f24a2250a56b31c160b02ba67f.addTo(map_f2b2af3c9f3f44db90c92a342c66094c);
#
#
#             var feature_group_345d6b8b81c00ac43814a6642f7b9fc5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9c58a3f15bcba1f8cb56b3018092b250 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_345d6b8b81c00ac43814a6642f7b9fc5);
#
#
#         var popup_53eec97e3b7c0641e4cdcbb4895e7050 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b96005b1c501d8c92ac2b3a3e4d2c93 = $(`&lt;div id=&quot;html_9b96005b1c501d8c92ac2b3a3e4d2c93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_53eec97e3b7c0641e4cdcbb4895e7050.setContent(html_9b96005b1c501d8c92ac2b3a3e4d2c93);
#
#
#
#         marker_9c58a3f15bcba1f8cb56b3018092b250.bindPopup(popup_53eec97e3b7c0641e4cdcbb4895e7050)
#         ;
#
#
#
#
#             var marker_045fba30f246e4b2fed123d41093587b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_345d6b8b81c00ac43814a6642f7b9fc5);
#
#
#         var popup_26b3660da5c08b6163400728adb466c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39946bf4306da6701df779b693268038 = $(`&lt;div id=&quot;html_39946bf4306da6701df779b693268038&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_26b3660da5c08b6163400728adb466c4.setContent(html_39946bf4306da6701df779b693268038);
#
#
#
#         marker_045fba30f246e4b2fed123d41093587b.bindPopup(popup_26b3660da5c08b6163400728adb466c4)
#         ;
#
#
#
#
#             var marker_b82ed03e5badfeb9b7241f6be34bc0ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_345d6b8b81c00ac43814a6642f7b9fc5);
#
#
#         var popup_29186077e6073d51eda5b66929979c5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53743a4c5183e20f4d5320b59f7dfdd7 = $(`&lt;div id=&quot;html_53743a4c5183e20f4d5320b59f7dfdd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_29186077e6073d51eda5b66929979c5e.setContent(html_53743a4c5183e20f4d5320b59f7dfdd7);
#
#
#
#         marker_b82ed03e5badfeb9b7241f6be34bc0ae.bindPopup(popup_29186077e6073d51eda5b66929979c5e)
#         ;
#
#
#
#
#             var marker_e8b19c8b202dba81d3e83dd78d593529 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_345d6b8b81c00ac43814a6642f7b9fc5);
#
#
#         var popup_daa6ec39a4afa9b2941dcb2cb1ac0c11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_066f83d1190b1bd135b3098c1ef49910 = $(`&lt;div id=&quot;html_066f83d1190b1bd135b3098c1ef49910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_daa6ec39a4afa9b2941dcb2cb1ac0c11.setContent(html_066f83d1190b1bd135b3098c1ef49910);
#
#
#
#         marker_e8b19c8b202dba81d3e83dd78d593529.bindPopup(popup_daa6ec39a4afa9b2941dcb2cb1ac0c11)
#         ;
#
#
#
#
#             var marker_e26a94f8cbf47feba6fae987f843a40c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_345d6b8b81c00ac43814a6642f7b9fc5);
#
#
#         var popup_55ac09b4103f43973a7a0f1f21e9348c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f9479d62d5d65513a4667ff5db52e7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f9479d62d5d65513a4667ff5db52e7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f9479d62d5d65513a4667ff5db52e7e = L.map(
#                 &quot;map_7f9479d62d5d65513a4667ff5db52e7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afb841a431477be5013b3ef4a7cbc9c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afb841a431477be5013b3ef4a7cbc9c2.addTo(map_7f9479d62d5d65513a4667ff5db52e7e);
#
#
#             var feature_group_f6503f2551c6d237a93137203410b37b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f6503f2551c6d237a93137203410b37b.addTo(map_7f9479d62d5d65513a4667ff5db52e7e);
#
#
#             var feature_group_sub_group_6cd96d97ec23046f242700d63dd046c8 = L.featureGroup.subGroup(
#                 feature_group_f6503f2551c6d237a93137203410b37b
#             );
#
#
#             var marker_e3930607dd85a67be94781fb557797a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6cd96d97ec23046f242700d63dd046c8);
#
#
#         var popup_78a627ef48dae8e01e0079212f0fd57a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e1ef8e6255480ed95a97cd3fb9d2535 = $(`&lt;div id=&quot;html_9e1ef8e6255480ed95a97cd3fb9d2535&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_78a627ef48dae8e01e0079212f0fd57a.setContent(html_9e1ef8e6255480ed95a97cd3fb9d2535);
#
#
#
#         marker_e3930607dd85a67be94781fb557797a6.bindPopup(popup_78a627ef48dae8e01e0079212f0fd57a)
#         ;
#
#
#
#
#             var marker_b0293ea68bb36701e6d4854944cae556 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6cd96d97ec23046f242700d63dd046c8);
#
#
#         var popup_0d3a9a6a2bcfbe13959fec429421058a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45f057799e48251852a7615c9229e9a9 = $(`&lt;div id=&quot;html_45f057799e48251852a7615c9229e9a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0d3a9a6a2bcfbe13959fec429421058a.setContent(html_45f057799e48251852a7615c9229e9a9);
#
#
#
#         marker_b0293ea68bb36701e6d4854944cae556.bindPopup(popup_0d3a9a6a2bcfbe13959fec429421058a)
#         ;
#
#
#
#
#             var marker_f455d30d4c96ce39d50fa97601c57ae0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6cd96d97ec23046f242700d63dd046c8);
#
#
#         var popup_c3e9b0d0d6c594828739530dc242f014 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42acb4085bde5d8a67fcbd397db59653 = $(`&lt;div id=&quot;html_42acb4085bde5d8a67fcbd397db59653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c3e9b0d0d6c594828739530dc242f014.setContent(html_42acb4085bde5d8a67fcbd397db59653);
#
#
#
#         marker_f455d30d4c96ce39d50fa97601c57ae0.bindPopup(popup_c3e9b0d0d6c594828739530dc242f014)
#         ;
#
#
#
#
#             var marker_0c14f4259b8837ddd3b776c18c72e720 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6cd96d97ec23046f242700d63dd046c8);
#
#
#         var popup_2cfcbe64d618ad0f52ff2e26f3abf1a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f514ac99afd2084f0eb77df084e4d04c = $(`&lt;div id=&quot;html_f514ac99afd2084f0eb77df084e4d04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2cfcbe64d618ad0f52ff2e26f3abf1a2.setContent(html_f514ac99afd2084f0eb77df084e4d04c);
#
#
#
#         marker_
