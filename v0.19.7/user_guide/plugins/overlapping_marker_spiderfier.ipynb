# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b72444c1118240ab3ebd29c2361261b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b72444c1118240ab3ebd29c2361261b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b72444c1118240ab3ebd29c2361261b = L.map(
#                 &quot;map_4b72444c1118240ab3ebd29c2361261b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b89a14aaa9a41e531197b3021255db0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b89a14aaa9a41e531197b3021255db0e.addTo(map_4b72444c1118240ab3ebd29c2361261b);
#
#
#             var marker_43ab93ea20d46ebf6d3c08d224233207 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4b72444c1118240ab3ebd29c2361261b);
#
#
#         var popup_410ba331d18600f7e6814d23baef2672 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84698b936db121edd344141d13d3e94d = $(`&lt;div id=&quot;html_84698b936db121edd344141d13d3e94d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_410ba331d18600f7e6814d23baef2672.setContent(html_84698b936db121edd344141d13d3e94d);
#
#
#
#         marker_43ab93ea20d46ebf6d3c08d224233207.bindPopup(popup_410ba331d18600f7e6814d23baef2672)
#         ;
#
#
#
#
#             var marker_237181d1c98eaebeaf1851d61001f9bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4b72444c1118240ab3ebd29c2361261b);
#
#
#         var popup_84376448c9a26722f22118c810eb3dd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3023a0549427445e350911e149f1afe2 = $(`&lt;div id=&quot;html_3023a0549427445e350911e149f1afe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_84376448c9a26722f22118c810eb3dd9.setContent(html_3023a0549427445e350911e149f1afe2);
#
#
#
#         marker_237181d1c98eaebeaf1851d61001f9bf.bindPopup(popup_84376448c9a26722f22118c810eb3dd9)
#         ;
#
#
#
#
#             var marker_177a6d94d5d1b724851d754e24cf8374 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4b72444c1118240ab3ebd29c2361261b);
#
#
#         var popup_ae0e445762e4bb6c2f1091e8d63d141a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_883baef1ddba01c2a718bf0d18caadf5 = $(`&lt;div id=&quot;html_883baef1ddba01c2a718bf0d18caadf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ae0e445762e4bb6c2f1091e8d63d141a.setContent(html_883baef1ddba01c2a718bf0d18caadf5);
#
#
#
#         marker_177a6d94d5d1b724851d754e24cf8374.bindPopup(popup_ae0e445762e4bb6c2f1091e8d63d141a)
#         ;
#
#
#
#
#             var marker_17215b98710e75e5aade34ae61cdbc4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4b72444c1118240ab3ebd29c2361261b);
#
#
#         var popup_90e9633ed05d06377c49607c71adf447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb3c04a79537ffc6a335f72fe5dc74a3 = $(`&lt;div id=&quot;html_bb3c04a79537ffc6a335f72fe5dc74a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_90e9633ed05d06377c49607c71adf447.setContent(html_bb3c04a79537ffc6a335f72fe5dc74a3);
#
#
#
#         marker_17215b98710e75e5aade34ae61cdbc4f.bindPopup(popup_90e9633ed05d06377c49607c71adf447)
#         ;
#
#
#
#
#             var marker_b9dfa52662bfba22718a4f75b912b537 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4b72444c1118240ab3ebd29c2361261b);
#
#
#         var popup_3592258a5ec68f22065d2ca6147b00f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c05cef2a9f14ea64bd4325560b165db8 = $(`&lt;div id=&quot;html_c05cef2a9f14ea64bd4325560b165db8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3592258a5ec68f22065d2ca6147b00f4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a90df00e855de4f66736b85171d05f9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a90df00e855de4f66736b85171d05f9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a90df00e855de4f66736b85171d05f9e = L.map(
#                 &quot;map_a90df00e855de4f66736b85171d05f9e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1ed4dae480c824a6749e64d9ca379e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1ed4dae480c824a6749e64d9ca379e3.addTo(map_a90df00e855de4f66736b85171d05f9e);
#
#
#             var feature_group_3a5b11a5f871aed7ea93e7080e499942 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_93f16d9c7648203ab2ad3489b3143bdc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3a5b11a5f871aed7ea93e7080e499942);
#
#
#         var popup_8ce5d6a529bc458b13ac323246198dbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a4678ecf5a5d7b8e642f9964a2061bf = $(`&lt;div id=&quot;html_5a4678ecf5a5d7b8e642f9964a2061bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8ce5d6a529bc458b13ac323246198dbc.setContent(html_5a4678ecf5a5d7b8e642f9964a2061bf);
#
#
#
#         marker_93f16d9c7648203ab2ad3489b3143bdc.bindPopup(popup_8ce5d6a529bc458b13ac323246198dbc)
#         ;
#
#
#
#
#             var marker_563ba7a3d0d9a75e78953ce8fa36d126 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3a5b11a5f871aed7ea93e7080e499942);
#
#
#         var popup_990413661ddea8bf7988e4b887b884cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fca0d16a79f8e237969dcc194efd387 = $(`&lt;div id=&quot;html_6fca0d16a79f8e237969dcc194efd387&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_990413661ddea8bf7988e4b887b884cc.setContent(html_6fca0d16a79f8e237969dcc194efd387);
#
#
#
#         marker_563ba7a3d0d9a75e78953ce8fa36d126.bindPopup(popup_990413661ddea8bf7988e4b887b884cc)
#         ;
#
#
#
#
#             var marker_6e172bd6aec0efec2f368b533c00fe35 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3a5b11a5f871aed7ea93e7080e499942);
#
#
#         var popup_33cde53bfc389ea7c07e3cb49fae1701 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1be6cddb99d3b87c00ec16fdd246200b = $(`&lt;div id=&quot;html_1be6cddb99d3b87c00ec16fdd246200b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_33cde53bfc389ea7c07e3cb49fae1701.setContent(html_1be6cddb99d3b87c00ec16fdd246200b);
#
#
#
#         marker_6e172bd6aec0efec2f368b533c00fe35.bindPopup(popup_33cde53bfc389ea7c07e3cb49fae1701)
#         ;
#
#
#
#
#             var marker_3018484bd339fdb6242da15319aea292 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3a5b11a5f871aed7ea93e7080e499942);
#
#
#         var popup_a6fe1f1be230f755e1f7ff34ab6028d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_452e98c2f76df1a9784f8d1c7e0cb61b = $(`&lt;div id=&quot;html_452e98c2f76df1a9784f8d1c7e0cb61b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a6fe1f1be230f755e1f7ff34ab6028d7.setContent(html_452e98c2f76df1a9784f8d1c7e0cb61b);
#
#
#
#         marker_3018484bd339fdb6242da15319aea292.bindPopup(popup_a6fe1f1be230f755e1f7ff34ab6028d7)
#         ;
#
#
#
#
#             var marker_c21d6d4f5ac5b788c0ff1786ba9c2706 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3a5b11a5f871aed7ea93e7080e499942);
#
#
#         var popup_b9e027457598a5846c2401357ce82f30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d53ea0cb621769eec2cf072a0e5f7475 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d53ea0cb621769eec2cf072a0e5f7475&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d53ea0cb621769eec2cf072a0e5f7475 = L.map(
#                 &quot;map_d53ea0cb621769eec2cf072a0e5f7475&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03d6c991cedbc85c4bfc09a30648a15f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03d6c991cedbc85c4bfc09a30648a15f.addTo(map_d53ea0cb621769eec2cf072a0e5f7475);
#
#
#             var feature_group_e660887b157343af2232d29a96a216bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e660887b157343af2232d29a96a216bd.addTo(map_d53ea0cb621769eec2cf072a0e5f7475);
#
#
#             var feature_group_sub_group_d77e9f4ebe6a500cc33ae8c46624a84e = L.featureGroup.subGroup(
#                 feature_group_e660887b157343af2232d29a96a216bd
#             );
#
#
#             var marker_1d4741e64fa546322e5b554f38a378e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d77e9f4ebe6a500cc33ae8c46624a84e);
#
#
#         var popup_1e383e6784f5df24a5ade97382068669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0c3eb6e42c4f7269d2a9a6f2905990f = $(`&lt;div id=&quot;html_f0c3eb6e42c4f7269d2a9a6f2905990f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1e383e6784f5df24a5ade97382068669.setContent(html_f0c3eb6e42c4f7269d2a9a6f2905990f);
#
#
#
#         marker_1d4741e64fa546322e5b554f38a378e1.bindPopup(popup_1e383e6784f5df24a5ade97382068669)
#         ;
#
#
#
#
#             var marker_9cc293ee28d1c97ca6392baee5bdd644 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d77e9f4ebe6a500cc33ae8c46624a84e);
#
#
#         var popup_a58146f560739efe1382aefec20393f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92fe43dc385d821f9be3bdc37183c9fd = $(`&lt;div id=&quot;html_92fe43dc385d821f9be3bdc37183c9fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a58146f560739efe1382aefec20393f2.setContent(html_92fe43dc385d821f9be3bdc37183c9fd);
#
#
#
#         marker_9cc293ee28d1c97ca6392baee5bdd644.bindPopup(popup_a58146f560739efe1382aefec20393f2)
#         ;
#
#
#
#
#             var marker_ddd66c13e3709aa642c18affe5c120a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d77e9f4ebe6a500cc33ae8c46624a84e);
#
#
#         var popup_4472583ef651bba00992138c9a5b2de0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e475df6af19e8538fed0cce06f244b67 = $(`&lt;div id=&quot;html_e475df6af19e8538fed0cce06f244b67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4472583ef651bba00992138c9a5b2de0.setContent(html_e475df6af19e8538fed0cce06f244b67);
#
#
#
#         marker_ddd66c13e3709aa642c18affe5c120a0.bindPopup(popup_4472583ef651bba00992138c9a5b2de0)
#         ;
#
#
#
#
#             var marker_4b08c41802a5e2cd3f306441ad47b351 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d77e9f4ebe6a500cc33ae8c46624a84e);
#
#
#         var popup_2dd723a8662025ef95bbdc4103a41ddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_660cdf06250eea55c432b89ef24c6620 = $(`&lt;div id=&quot;html_660cdf06250eea55c432b89ef24c6620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2dd723a8662025ef95bbdc4103a41ddc.setContent(html_660cdf06250eea55c432b89ef24c6620);
#
#
#
#         marker_
