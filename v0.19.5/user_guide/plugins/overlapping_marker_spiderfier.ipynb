# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a55fbea321c5ea6de942c8f16d701373 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a55fbea321c5ea6de942c8f16d701373&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a55fbea321c5ea6de942c8f16d701373 = L.map(
#                 &quot;map_a55fbea321c5ea6de942c8f16d701373&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53df74c7be42cffc7f02de90a3b16399 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53df74c7be42cffc7f02de90a3b16399.addTo(map_a55fbea321c5ea6de942c8f16d701373);
#
#
#             var marker_ef5998510b1ecebe95db378474109ed0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a55fbea321c5ea6de942c8f16d701373);
#
#
#         var popup_2fa6549e3607eeb64d6425b7501e44d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13d587f030380610bea22b687c0e8de9 = $(`&lt;div id=&quot;html_13d587f030380610bea22b687c0e8de9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2fa6549e3607eeb64d6425b7501e44d6.setContent(html_13d587f030380610bea22b687c0e8de9);
#
#
#
#         marker_ef5998510b1ecebe95db378474109ed0.bindPopup(popup_2fa6549e3607eeb64d6425b7501e44d6)
#         ;
#
#
#
#
#             var marker_15c729eed18020b71b2176aaef42c9ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a55fbea321c5ea6de942c8f16d701373);
#
#
#         var popup_21c556f541802eaed1c2e692267aa2d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8aa7766954eea02768942e2d51ae9e50 = $(`&lt;div id=&quot;html_8aa7766954eea02768942e2d51ae9e50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_21c556f541802eaed1c2e692267aa2d5.setContent(html_8aa7766954eea02768942e2d51ae9e50);
#
#
#
#         marker_15c729eed18020b71b2176aaef42c9ea.bindPopup(popup_21c556f541802eaed1c2e692267aa2d5)
#         ;
#
#
#
#
#             var marker_3028c18985b4f3dc3927e7be9495c14e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a55fbea321c5ea6de942c8f16d701373);
#
#
#         var popup_e192972d4c2f5a32a7a01f0181f8ea89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e6a61a6f4f3b876648f8f1a7f9f3302 = $(`&lt;div id=&quot;html_7e6a61a6f4f3b876648f8f1a7f9f3302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e192972d4c2f5a32a7a01f0181f8ea89.setContent(html_7e6a61a6f4f3b876648f8f1a7f9f3302);
#
#
#
#         marker_3028c18985b4f3dc3927e7be9495c14e.bindPopup(popup_e192972d4c2f5a32a7a01f0181f8ea89)
#         ;
#
#
#
#
#             var marker_acb314ad6222a2aae6ed8e1674e70097 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a55fbea321c5ea6de942c8f16d701373);
#
#
#         var popup_9053d70a5b969ebb3ed0aa01228251ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddf23cfffd2f28ccca3ec8527a3cb766 = $(`&lt;div id=&quot;html_ddf23cfffd2f28ccca3ec8527a3cb766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9053d70a5b969ebb3ed0aa01228251ed.setContent(html_ddf23cfffd2f28ccca3ec8527a3cb766);
#
#
#
#         marker_acb314ad6222a2aae6ed8e1674e70097.bindPopup(popup_9053d70a5b969ebb3ed0aa01228251ed)
#         ;
#
#
#
#
#             var marker_ed8d696406995fea3ab4404fcae11f62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a55fbea321c5ea6de942c8f16d701373);
#
#
#         var popup_4eaa7bc366fe0ac0423bad111414a425 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f181e8be9ed72633f13e1c092b49eb0 = $(`&lt;div id=&quot;html_3f181e8be9ed72633f13e1c092b49eb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4eaa7bc366fe0ac0423bad111414a425.setContent(html_3f181e8be9ed72633f13e1c092b49eb0);
#
#
#
#         marker_ed8d696406995fea3ab4404fcae11f62.bindPopup(popup_4eaa7bc366fe0ac0423bad111414a425)
#         ;
#
#
#
#
#             var marker_b2107c9e18

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed5102e807d0744c9c3bc3769a5d4796 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed5102e807d0744c9c3bc3769a5d4796&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed5102e807d0744c9c3bc3769a5d4796 = L.map(
#                 &quot;map_ed5102e807d0744c9c3bc3769a5d4796&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_520b0c5f90beb512afb864ca6aae184c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_520b0c5f90beb512afb864ca6aae184c.addTo(map_ed5102e807d0744c9c3bc3769a5d4796);
#
#
#             var feature_group_85693567e1a77a704dce48b4f0c73b1e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_42f2024165562e3140fc605185532418 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_85693567e1a77a704dce48b4f0c73b1e);
#
#
#         var popup_26ae18d5ac3e09c76b72cfcbd4406a0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b32dd225c7c2465864ba5e3444ef1d08 = $(`&lt;div id=&quot;html_b32dd225c7c2465864ba5e3444ef1d08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_26ae18d5ac3e09c76b72cfcbd4406a0e.setContent(html_b32dd225c7c2465864ba5e3444ef1d08);
#
#
#
#         marker_42f2024165562e3140fc605185532418.bindPopup(popup_26ae18d5ac3e09c76b72cfcbd4406a0e)
#         ;
#
#
#
#
#             var marker_543150e83f3dc045770f90a5ecdc9b71 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_85693567e1a77a704dce48b4f0c73b1e);
#
#
#         var popup_3b9ded3be19e4f43a841df6f8db0799d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ba408bbf07bb843920eb091a58f03c9 = $(`&lt;div id=&quot;html_0ba408bbf07bb843920eb091a58f03c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3b9ded3be19e4f43a841df6f8db0799d.setContent(html_0ba408bbf07bb843920eb091a58f03c9);
#
#
#
#         marker_543150e83f3dc045770f90a5ecdc9b71.bindPopup(popup_3b9ded3be19e4f43a841df6f8db0799d)
#         ;
#
#
#
#
#             var marker_81c99d91e390c71e10576aac8c754b0d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_85693567e1a77a704dce48b4f0c73b1e);
#
#
#         var popup_21018e67df239690637a8b2d724a354d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab6127dcef09aa31552dc216b8f9c8be = $(`&lt;div id=&quot;html_ab6127dcef09aa31552dc216b8f9c8be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_21018e67df239690637a8b2d724a354d.setContent(html_ab6127dcef09aa31552dc216b8f9c8be);
#
#
#
#         marker_81c99d91e390c71e10576aac8c754b0d.bindPopup(popup_21018e67df239690637a8b2d724a354d)
#         ;
#
#
#
#
#             var marker_41facb3785a16f26545448ceb39002cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_85693567e1a77a704dce48b4f0c73b1e);
#
#
#         var popup_662407df161022a7afe7ed34baa79481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63bf4b9dce51b401bf482cdbb9d7385a = $(`&lt;div id=&quot;html_63bf4b9dce51b401bf482cdbb9d7385a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_662407df161022a7afe7ed34baa79481.setContent(html_63bf4b9dce51b401bf482cdbb9d7385a);
#
#
#
#         marker_41facb3785a16f26545448ceb39002cd.bindPopup(popup_662407df161022a7afe7ed34baa79481)
#         ;
#
#
#
#
#             var marker_3f27ed81e969fec6d0fdeff9d6d1423e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_85693567e1a77a704dce48b4f0c73b1e);
#
#
#         var popup_8d22cd4cb4769338165298424947b614 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e11b54bcf178e303f39d71498d9d08d = $(`&lt;div id=&quot;html_8e11b54bcf178e303f39d71498d9d08d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_8d22cd4cb476933816

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d2f09e50fdac085e9063b223ea9b36b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d2f09e50fdac085e9063b223ea9b36b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d2f09e50fdac085e9063b223ea9b36b = L.map(
#                 &quot;map_6d2f09e50fdac085e9063b223ea9b36b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e00817e6170fedb4c1429dce70fda9d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e00817e6170fedb4c1429dce70fda9d7.addTo(map_6d2f09e50fdac085e9063b223ea9b36b);
#
#
#             var feature_group_f3bf279afa309c063e597dacfaa0d336 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f3bf279afa309c063e597dacfaa0d336.addTo(map_6d2f09e50fdac085e9063b223ea9b36b);
#
#
#             var feature_group_sub_group_f0196c9caf16d4cf556ba50a6dcb3c0b = L.featureGroup.subGroup(
#                 feature_group_f3bf279afa309c063e597dacfaa0d336
#             );
#
#
#             var marker_8bae2b3699469f49b668027ba496d803 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0196c9caf16d4cf556ba50a6dcb3c0b);
#
#
#         var popup_6037c347c823b0fce860c48bbe58d9cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f322a29460d478f75a66bab69553ae19 = $(`&lt;div id=&quot;html_f322a29460d478f75a66bab69553ae19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6037c347c823b0fce860c48bbe58d9cf.setContent(html_f322a29460d478f75a66bab69553ae19);
#
#
#
#         marker_8bae2b3699469f49b668027ba496d803.bindPopup(popup_6037c347c823b0fce860c48bbe58d9cf)
#         ;
#
#
#
#
#             var marker_fe62ab1769cdcc6aa23a8ac03cec7525 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0196c9caf16d4cf556ba50a6dcb3c0b);
#
#
#         var popup_2c77ba634413740e08803c42eaef8b71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_babd9025e847e978fea0ba0b2e18ab88 = $(`&lt;div id=&quot;html_babd9025e847e978fea0ba0b2e18ab88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2c77ba634413740e08803c42eaef8b71.setContent(html_babd9025e847e978fea0ba0b2e18ab88);
#
#
#
#         marker_fe62ab1769cdcc6aa23a8ac03cec7525.bindPopup(popup_2c77ba634413740e08803c42eaef8b71)
#         ;
#
#
#
#
#             var marker_bc31721656a9d89758b1d90850c1cb49 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0196c9caf16d4cf556ba50a6dcb3c0b);
#
#
#         var popup_78e3713a5600d81f8ddd24e712680eb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a98608da4e5bdfc74a727f7d7749513 = $(`&lt;div id=&quot;html_3a98608da4e5bdfc74a727f7d7749513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_78e3713a5600d81f8ddd24e712680eb8.setContent(html_3a98608da4e5bdfc74a727f7d7749513);
#
#
#
#         marker_bc31721656a9d89758b1d90850c1cb49.bindPopup(popup_78e3713a5600d81f8ddd24e712680eb8)
#         ;
#
#
#
#
#             var marker_bf6940b8ba95f60e003d0d350c3a71f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0196c9caf16d4cf556ba50a6dcb3c0b);
#
#
#         var popup_eb8b3c44e9e3589c5caae0818b883bc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02a466d99433f0061615139e57894f4a = $(`&lt;div id=&quot;html_02a466d99433f0061615139e57894f4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eb8b3c44e9e3589c5caae0818b883bc9.setContent(html_02a466d99433f0061615139e57894f4a);
#
#
#
#         marker_bf6940b8ba95f60e003d0d350c3a71f4.bindPopup(popup_eb8b3c44e9e3589c5caae0818b883bc9)
#         ;
#
#
#
#
#             var marker_15969491a39f2a4e8a8d0d6c6187d0d7 = L.marker(
#                 [45.050399999999996, 3.0504],
