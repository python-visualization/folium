# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0394534a1d1700bd42738fbf3820a0a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0394534a1d1700bd42738fbf3820a0a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0394534a1d1700bd42738fbf3820a0a0 = L.map(
#                 &quot;map_0394534a1d1700bd42738fbf3820a0a0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e4e65528b7ae133aa91defefe76db91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e4e65528b7ae133aa91defefe76db91.addTo(map_0394534a1d1700bd42738fbf3820a0a0);
#
#
#             var marker_d5d9f43deb7e9a0157f8142cfeb54cc4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0394534a1d1700bd42738fbf3820a0a0);
#
#
#         var popup_ea5308a2201ba0b255d96c4eb82f69d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e442ab270b10fa99d9c6c38fbe59e1b6 = $(`&lt;div id=&quot;html_e442ab270b10fa99d9c6c38fbe59e1b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ea5308a2201ba0b255d96c4eb82f69d2.setContent(html_e442ab270b10fa99d9c6c38fbe59e1b6);
#
#
#
#         marker_d5d9f43deb7e9a0157f8142cfeb54cc4.bindPopup(popup_ea5308a2201ba0b255d96c4eb82f69d2)
#         ;
#
#
#
#
#             var marker_446358aa49df6cf9726af6288c06372f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0394534a1d1700bd42738fbf3820a0a0);
#
#
#         var popup_8babc2af45314225086100bcd498a690 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6285fe3ed5ef7146b03ae5e250960b5b = $(`&lt;div id=&quot;html_6285fe3ed5ef7146b03ae5e250960b5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8babc2af45314225086100bcd498a690.setContent(html_6285fe3ed5ef7146b03ae5e250960b5b);
#
#
#
#         marker_446358aa49df6cf9726af6288c06372f.bindPopup(popup_8babc2af45314225086100bcd498a690)
#         ;
#
#
#
#
#             var marker_219034629b410ffe601fabe072b10143 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0394534a1d1700bd42738fbf3820a0a0);
#
#
#         var popup_0f2ea82c2f32ccd4d79bebb975377aa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9caf6bc9dd32928c7dd8962c573f8f8f = $(`&lt;div id=&quot;html_9caf6bc9dd32928c7dd8962c573f8f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0f2ea82c2f32ccd4d79bebb975377aa7.setContent(html_9caf6bc9dd32928c7dd8962c573f8f8f);
#
#
#
#         marker_219034629b410ffe601fabe072b10143.bindPopup(popup_0f2ea82c2f32ccd4d79bebb975377aa7)
#         ;
#
#
#
#
#             var marker_1e184140532109bf97550ce557be9181 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0394534a1d1700bd42738fbf3820a0a0);
#
#
#         var popup_f33915208355b30674d31c4d94c9b1f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7af71240a30546fad8de6fffc43a2338 = $(`&lt;div id=&quot;html_7af71240a30546fad8de6fffc43a2338&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f33915208355b30674d31c4d94c9b1f1.setContent(html_7af71240a30546fad8de6fffc43a2338);
#
#
#
#         marker_1e184140532109bf97550ce557be9181.bindPopup(popup_f33915208355b30674d31c4d94c9b1f1)
#         ;
#
#
#
#
#             var marker_2f5fd03ef3a2e5210f11a885f057f133 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0394534a1d1700bd42738fbf3820a0a0);
#
#
#         var popup_29a2d0f39ad25892f34e8c029e2b59dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a2456816198b00b33334a0b9cc60b8b = $(`&lt;div id=&quot;html_0a2456816198b00b33334a0b9cc60b8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_29a2d0f39ad25892f34e8c029e2b59dc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a83e5ec65053b81d987c5f647ca8bef6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a83e5ec65053b81d987c5f647ca8bef6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a83e5ec65053b81d987c5f647ca8bef6 = L.map(
#                 &quot;map_a83e5ec65053b81d987c5f647ca8bef6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50041359970629e5423ec6c14dc87194 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50041359970629e5423ec6c14dc87194.addTo(map_a83e5ec65053b81d987c5f647ca8bef6);
#
#
#             var feature_group_9076cdb240fd6551d51cef8904555800 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_78a3c7bcb6892cdef42b10dcedbdda56 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9076cdb240fd6551d51cef8904555800);
#
#
#         var popup_991d09ee49f5d9a7f9b582c742085cbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f05401c71e4b8eb0dae988b882b91137 = $(`&lt;div id=&quot;html_f05401c71e4b8eb0dae988b882b91137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_991d09ee49f5d9a7f9b582c742085cbb.setContent(html_f05401c71e4b8eb0dae988b882b91137);
#
#
#
#         marker_78a3c7bcb6892cdef42b10dcedbdda56.bindPopup(popup_991d09ee49f5d9a7f9b582c742085cbb)
#         ;
#
#
#
#
#             var marker_b98d1b34167c4d408d63f4a61be8a9f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9076cdb240fd6551d51cef8904555800);
#
#
#         var popup_55d6dc4d3cbdbf557df767f06fcd946d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f1799f320c4018e1cbab528ee2ac96d = $(`&lt;div id=&quot;html_8f1799f320c4018e1cbab528ee2ac96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_55d6dc4d3cbdbf557df767f06fcd946d.setContent(html_8f1799f320c4018e1cbab528ee2ac96d);
#
#
#
#         marker_b98d1b34167c4d408d63f4a61be8a9f4.bindPopup(popup_55d6dc4d3cbdbf557df767f06fcd946d)
#         ;
#
#
#
#
#             var marker_4851724243f757c3046935d7e07e3f77 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9076cdb240fd6551d51cef8904555800);
#
#
#         var popup_9392a17cdd13a349254839ec8b04cc96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9033351e9a6a37505f5b7d3036b25cc2 = $(`&lt;div id=&quot;html_9033351e9a6a37505f5b7d3036b25cc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9392a17cdd13a349254839ec8b04cc96.setContent(html_9033351e9a6a37505f5b7d3036b25cc2);
#
#
#
#         marker_4851724243f757c3046935d7e07e3f77.bindPopup(popup_9392a17cdd13a349254839ec8b04cc96)
#         ;
#
#
#
#
#             var marker_b99495db52edf69cb6224bfe06b32d82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9076cdb240fd6551d51cef8904555800);
#
#
#         var popup_8551f308219d10603f698b7b09675f70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef8247ba99e3e15f79694fa7c305dee = $(`&lt;div id=&quot;html_eef8247ba99e3e15f79694fa7c305dee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8551f308219d10603f698b7b09675f70.setContent(html_eef8247ba99e3e15f79694fa7c305dee);
#
#
#
#         marker_b99495db52edf69cb6224bfe06b32d82.bindPopup(popup_8551f308219d10603f698b7b09675f70)
#         ;
#
#
#
#
#             var marker_bc238a0b6259d5a03295e705b81b092c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9076cdb240fd6551d51cef8904555800);
#
#
#         var popup_8ed75ac3aed5b5c725c1e1935c2a9eaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75ad2b687519d67741412d2d12dbf715 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75ad2b687519d67741412d2d12dbf715&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75ad2b687519d67741412d2d12dbf715 = L.map(
#                 &quot;map_75ad2b687519d67741412d2d12dbf715&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be92a162bce1be918b60a9b403f3f361 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be92a162bce1be918b60a9b403f3f361.addTo(map_75ad2b687519d67741412d2d12dbf715);
#
#
#             var feature_group_37c5cc141cf9f998319818f2f93e4712 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_37c5cc141cf9f998319818f2f93e4712.addTo(map_75ad2b687519d67741412d2d12dbf715);
#
#
#             var feature_group_sub_group_c168ccd636fc1308a18c882de531f97a = L.featureGroup.subGroup(
#                 feature_group_37c5cc141cf9f998319818f2f93e4712
#             );
#
#
#             var marker_500796d125ffc18a897963c8393a98f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c168ccd636fc1308a18c882de531f97a);
#
#
#         var popup_f83470cf575723f5d33b1b8c4827be23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e2fb4c43e74232b1d84cd04b570edfe = $(`&lt;div id=&quot;html_5e2fb4c43e74232b1d84cd04b570edfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f83470cf575723f5d33b1b8c4827be23.setContent(html_5e2fb4c43e74232b1d84cd04b570edfe);
#
#
#
#         marker_500796d125ffc18a897963c8393a98f1.bindPopup(popup_f83470cf575723f5d33b1b8c4827be23)
#         ;
#
#
#
#
#             var marker_8a93e68f6e584bb0c02c4c0659755f04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c168ccd636fc1308a18c882de531f97a);
#
#
#         var popup_a8a1fe5936d0849304d58f7229baf132 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_266edd63b6158b70deedb8aa807f6b1a = $(`&lt;div id=&quot;html_266edd63b6158b70deedb8aa807f6b1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a8a1fe5936d0849304d58f7229baf132.setContent(html_266edd63b6158b70deedb8aa807f6b1a);
#
#
#
#         marker_8a93e68f6e584bb0c02c4c0659755f04.bindPopup(popup_a8a1fe5936d0849304d58f7229baf132)
#         ;
#
#
#
#
#             var marker_a44952bfec00de53af77ce363335590e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c168ccd636fc1308a18c882de531f97a);
#
#
#         var popup_224c9f7f46050d8179414a9b33dac7c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c356cb8599428fadcbe93dffa241ff01 = $(`&lt;div id=&quot;html_c356cb8599428fadcbe93dffa241ff01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_224c9f7f46050d8179414a9b33dac7c4.setContent(html_c356cb8599428fadcbe93dffa241ff01);
#
#
#
#         marker_a44952bfec00de53af77ce363335590e.bindPopup(popup_224c9f7f46050d8179414a9b33dac7c4)
#         ;
#
#
#
#
#             var marker_fe7a19ce9a165985b80a6fbd7cbba7d4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c168ccd636fc1308a18c882de531f97a);
#
#
#         var popup_4fde442cfdd5e67f9bd5158c0a7ed86c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ead4e39c5d604efb907bc0a1d1439d8f = $(`&lt;div id=&quot;html_ead4e39c5d604efb907bc0a1d1439d8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4fde442cfdd5e67f9bd5158c0a7ed86c.setContent(html_ead4e39c5d604efb907bc0a1d1439d8f);
#
#
#
#         marker_
