# %%
import os
import folium

print(folium.__version__)
# Out:
# 0.3.0.dev

# %%
from folium import Map, FeatureGroup, Marker, LayerControl

m = Map(location=[45.372, -121.6972], zoom_start=12, tiles='Stamen Terrain')

feature_group = FeatureGroup(name='Some icons')
Marker([45.3288, -121.6625], popup='Mt. Hood Meadows').add_to(feature_group)
Marker([45.3311, -121.7113], popup='Timberline Lodge').add_to(feature_group)

feature_group.add_to(m)
LayerControl().add_to(m)

m.save(os.path.join('results', 'FeatureGroup.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
