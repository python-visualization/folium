# %% [markdown]
# # FitOverlays
#
# When you add this class to your map, the map will pan and zoom to fit the enabled overlays.

# %%
from folium import Map, LayerControl, FeatureGroup, Marker, FitOverlays

# %% [markdown]
# In this first map we placed two markers, but they are not in view. You have to pan or zoom out to find them.

# %%
def get_map_with_markers():
    m = Map((52, 0), tiles='cartodbpositron', zoom_start=8)

    fg1 = FeatureGroup().add_to(m)
    Marker((52, 5)).add_to(fg1)

    fg2 = FeatureGroup(show=False).add_to(m)
    Marker((52, 5.1)).add_to(fg2)

    LayerControl(collapsed=False).add_to(m)
    
    return m

get_map_with_markers()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5792552ae3aabe329eb615623a695b46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5792552ae3aabe329eb615623a695b46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5792552ae3aabe329eb615623a695b46 = L.map(
#                 &quot;map_5792552ae3aabe329eb615623a695b46&quot;,
#                 {
#                     center: [52.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffc863a902a0bd1862a00f1e2fd366af = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5792552ae3aabe329eb615623a695b46);
#
#
#             var feature_group_d124be0f20e687545e223db2f4ffe0e4 = L.featureGroup(
#                 {}
#             ).addTo(map_5792552ae3aabe329eb615623a695b46);
#
#
#             var marker_724e177bdd71441dd2e858b85bcac6d7 = L.marker(
#                 [52.0, 5.0],
#                 {}
#             ).addTo(feature_group_d124be0f20e687545e223db2f4ffe0e4);
#
#
#             var feature_group_76a1c09c0db5f8d96142d711357b27e6 = L.featureGroup(
#                 {}
#             ).addTo(map_5792552ae3aabe329eb615623a695b46);
#
#
#             var marker_cda945323c505ce63d4cd5bf9fc60110 = L.marker(
#                 [52.0, 5.1],
#                 {}
#             ).addTo(feature_group_76a1c09c0db5f8d96142d711357b27e6);
#
#
#             var layer_control_487afdfacd57234f296af5c58a7c5303 = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_ffc863a902a0bd1862a00f1e2fd366af,
#                 },
#                 overlays :  {
#                     &quot;macro_element_d124be0f20e687545e223db2f4ffe0e4&quot; : feature_group_d124be0f20e687545e223db2f4ffe0e4,
#                     &quot;macro_element_76a1c09c0db5f8d96142d711357b27e6&quot; : feature_group_76a1c09c0db5f8d96142d711357b27e6,
#                 },
#             };
#             L.control.layers(
#                 layer_control_487afdfacd57234f296af5c58a7c5303.base_layers,
#                 layer_control_487afdfacd57234f296af5c58a7c5303.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_5792552ae3aabe329eb615623a695b46);
#             feature_group_76a1c09c0db5f8d96142d711357b27e6.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we add the `FitOverlays` class, which automatically pans and zooms to show the enabled overlays. We show only the first marker by default, if we enable the second marker, the view changes to include it.

# %%
m = get_map_with_markers()

FitOverlays().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bfe9e8bc6aaa307c4057a82ec7cc9f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bfe9e8bc6aaa307c4057a82ec7cc9f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bfe9e8bc6aaa307c4057a82ec7cc9f2 = L.map(
#                 &quot;map_3bfe9e8bc6aaa307c4057a82ec7cc9f2&quot;,
#                 {
#                     center: [52.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e15a436610b5e9f8935187c29d6b0e7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3bfe9e8bc6aaa307c4057a82ec7cc9f2);
#
#
#             var feature_group_00b3fd6ef2ab806464cea5e5db501502 = L.featureGroup(
#                 {}
#             ).addTo(map_3bfe9e8bc6aaa307c4057a82ec7cc9f2);
#
#
#             var marker_06ee63882c8c4eacba93cbe0451c104b = L.marker(
#                 [52.0, 5.0],
#                 {}
#             ).addTo(feature_group_00b3fd6ef2ab806464cea5e5db501502);
#
#
#             var feature_group_2f0bee6daaa703cf9a6ad599550e992d = L.featureGroup(
#                 {}
#             ).addTo(map_3bfe9e8bc6aaa307c4057a82ec7cc9f2);
#
#
#             var marker_be80e6288a65847b9401e9d5fccfd7ae = L.marker(
#                 [52.0, 5.1],
#                 {}
#             ).addTo(feature_group_2f0bee6daaa703cf9a6ad599550e992d);
#
#
#             var layer_control_d10b5a031333ffff0b3d4c3d1b6d9b4f = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_0e15a436610b5e9f8935187c29d6b0e7,
#                 },
#                 overlays :  {
#                     &quot;macro_element_00b3fd6ef2ab806464cea5e5db501502&quot; : feature_group_00b3fd6ef2ab806464cea5e5db501502,
#                     &quot;macro_element_2f0bee6daaa703cf9a6ad599550e992d&quot; : feature_group_2f0bee6daaa703cf9a6ad599550e992d,
#                 },
#             };
#             L.control.layers(
#                 layer_control_d10b5a031333ffff0b3d4c3d1b6d9b4f.base_layers,
#                 layer_control_d10b5a031333ffff0b3d4c3d1b6d9b4f.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_3bfe9e8bc6aaa307c4057a82ec7cc9f2);
#             feature_group_2f0bee6daaa703cf9a6ad599550e992d.remove();
#
#
#
#         function customFlyToBounds() {
#             let bounds = L.latLngBounds([]);
#             map_3bfe9e8bc6aaa307c4057a82ec7cc9f2.eachLayer(function(layer) {
#                 if (typeof layer.getBounds === &#x27;function&#x27;) {
#                     bounds.extend(layer.getBounds());
#                 }
#             });
#             if (bounds.isValid()) {
#                 map_3bfe9e8bc6aaa307c4057a82ec7cc9f2.fitBounds(bounds, {&quot;padding&quot;: [0, 0]});
#             }
#         }
#         map_3bfe9e8bc6aaa307c4057a82ec7cc9f2.on(&#x27;overlayadd&#x27;, customFlyToBounds);
#         customFlyToBounds();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# `FitOverlays` has a couple options:
# - `padding` adds pixels around the bounds.
# - `max_zoom` can be used to prevent zooming in too far.
# - `fly` enables a smoother, longer animation, so you can see how the view changes.
# - `fit_on_map_load` can be used to disable the fitting that happens when the map loads.
#
# Note that `padding` and `max_zoom` can achieve the same effect.

# %%
m = get_map_with_markers()

FitOverlays(
    padding=0,
    max_zoom=10,
    fly=True,
    fit_on_map_load=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cabc693b9fbd2ae05d4ff1817e2f1ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cabc693b9fbd2ae05d4ff1817e2f1ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cabc693b9fbd2ae05d4ff1817e2f1ef = L.map(
#                 &quot;map_0cabc693b9fbd2ae05d4ff1817e2f1ef&quot;,
#                 {
#                     center: [52.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9f42549fc64acfe5e70de24132f3a3c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0cabc693b9fbd2ae05d4ff1817e2f1ef);
#
#
#             var feature_group_6fc8837530daa3711b627bded28ad98e = L.featureGroup(
#                 {}
#             ).addTo(map_0cabc693b9fbd2ae05d4ff1817e2f1ef);
#
#
#             var marker_9d80b681c17f5a2aeb69564564210edd = L.marker(
#                 [52.0, 5.0],
#                 {}
#             ).addTo(feature_group_6fc8837530daa3711b627bded28ad98e);
#
#
#             var feature_group_b7652d7a76c9b7fee702ef332d989f45 = L.featureGroup(
#                 {}
#             ).addTo(map_0cabc693b9fbd2ae05d4ff1817e2f1ef);
#
#
#             var marker_772db1ae74174210cb485ac9553a53d7 = L.marker(
#                 [52.0, 5.1],
#                 {}
#             ).addTo(feature_group_b7652d7a76c9b7fee702ef332d989f45);
#
#
#             var layer_control_966a7f5de7b131b40f341825ba9ef811 = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_b9f42549fc64acfe5e70de24132f3a3c,
#                 },
#                 overlays :  {
#                     &quot;macro_element_6fc8837530daa3711b627bded28ad98e&quot; : feature_group_6fc8837530daa3711b627bded28ad98e,
#                     &quot;macro_element_b7652d7a76c9b7fee702ef332d989f45&quot; : feature_group_b7652d7a76c9b7fee702ef332d989f45,
#                 },
#             };
#             L.control.layers(
#                 layer_control_966a7f5de7b131b40f341825ba9ef811.base_layers,
#                 layer_control_966a7f5de7b131b40f341825ba9ef811.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_0cabc693b9fbd2ae05d4ff1817e2f1ef);
#             feature_group_b7652d7a76c9b7fee702ef332d989f45.remove();
#
#
#
#         function customFlyToBounds() {
#             let bounds = L.latLngBounds([]);
#             map_0cabc693b9fbd2ae05d4ff1817e2f1ef.eachLayer(function(layer) {
#                 if (typeof layer.getBounds === &#x27;function&#x27;) {
#                     bounds.extend(layer.getBounds());
#                 }
#             });
#             if (bounds.isValid()) {
#                 map_0cabc693b9fbd2ae05d4ff1817e2f1ef.flyToBounds(bounds, {&quot;maxZoom&quot;: 10, &quot;padding&quot;: [0, 0]});
#             }
#         }
#         map_0cabc693b9fbd2ae05d4ff1817e2f1ef.on(&#x27;overlayadd&#x27;, customFlyToBounds);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
