# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46721c48affcff03600ef3b84e000fbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46721c48affcff03600ef3b84e000fbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46721c48affcff03600ef3b84e000fbb = L.map(
#                 &quot;map_46721c48affcff03600ef3b84e000fbb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a851c581ab58b6678298800b3478e365 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a851c581ab58b6678298800b3478e365.addTo(map_46721c48affcff03600ef3b84e000fbb);
#
#
#             var marker_2f7948be517ba72389c6d2b8df43fd92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_46721c48affcff03600ef3b84e000fbb);
#
#
#         var popup_41a2cb8559068e327d43bcdacf2992e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25c963892f5184daec19c7eda5d07070 = $(`&lt;div id=&quot;html_25c963892f5184daec19c7eda5d07070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_41a2cb8559068e327d43bcdacf2992e0.setContent(html_25c963892f5184daec19c7eda5d07070);
#
#
#
#         marker_2f7948be517ba72389c6d2b8df43fd92.bindPopup(popup_41a2cb8559068e327d43bcdacf2992e0)
#         ;
#
#
#
#
#             var marker_8e13ab2c87eb6df46c2839e75063d8b2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_46721c48affcff03600ef3b84e000fbb);
#
#
#         var popup_3a0e563918224ae25172b6b7b3849bf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3735891a4edf35fd09c21bae192eb7d = $(`&lt;div id=&quot;html_c3735891a4edf35fd09c21bae192eb7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3a0e563918224ae25172b6b7b3849bf5.setContent(html_c3735891a4edf35fd09c21bae192eb7d);
#
#
#
#         marker_8e13ab2c87eb6df46c2839e75063d8b2.bindPopup(popup_3a0e563918224ae25172b6b7b3849bf5)
#         ;
#
#
#
#
#             var marker_fee8049ecc431dad6154ed576f508892 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_46721c48affcff03600ef3b84e000fbb);
#
#
#         var popup_72af583e8c207164adbd714cf7fa3342 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_372545be4eba5dff8f59dbd014b50c0c = $(`&lt;div id=&quot;html_372545be4eba5dff8f59dbd014b50c0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_72af583e8c207164adbd714cf7fa3342.setContent(html_372545be4eba5dff8f59dbd014b50c0c);
#
#
#
#         marker_fee8049ecc431dad6154ed576f508892.bindPopup(popup_72af583e8c207164adbd714cf7fa3342)
#         ;
#
#
#
#
#             var marker_590ecc279e45f448cf74e7003452e0e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_46721c48affcff03600ef3b84e000fbb);
#
#
#         var popup_99bb1ba1c14edeb4e73152dbc84ac49b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1438623fd6edfe84962073056af43790 = $(`&lt;div id=&quot;html_1438623fd6edfe84962073056af43790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_99bb1ba1c14edeb4e73152dbc84ac49b.setContent(html_1438623fd6edfe84962073056af43790);
#
#
#
#         marker_590ecc279e45f448cf74e7003452e0e6.bindPopup(popup_99bb1ba1c14edeb4e73152dbc84ac49b)
#         ;
#
#
#
#
#             var marker_ef1896829544e7f719b04d417597dfe0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_46721c48affcff03600ef3b84e000fbb);
#
#
#         var popup_06e513b31fdd9cefa09446e2114307cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd6096b5a1f4c71085ab9618f8076c17 = $(`&lt;div id=&quot;html_bd6096b5a1f4c71085ab9618f8076c17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_06e513b31fdd9cefa09446e2114307cf.setContent(html_bd6096b5a1f4c71085ab9618f8076c17);
#
#
#
#         marker_ef1896829544e7f719b04d417597dfe0.bindPopup(popup_06e513b31fdd9cefa09446e2114307cf)
#         ;
#
#
#
#
#             var marker_c1734ff8e0

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e7959bd99437cb272bc64f2eb8e060d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e7959bd99437cb272bc64f2eb8e060d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e7959bd99437cb272bc64f2eb8e060d = L.map(
#                 &quot;map_5e7959bd99437cb272bc64f2eb8e060d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57f9641736db99c78939913e6c5cad5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57f9641736db99c78939913e6c5cad5e.addTo(map_5e7959bd99437cb272bc64f2eb8e060d);
#
#
#             var feature_group_60293a5a3603e4bd8fdc9833ef203123 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_27e0bafa4d7e6cf33f2d056ee38bfff6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_60293a5a3603e4bd8fdc9833ef203123);
#
#
#         var popup_98f7f19a93a4db9696098a08dc3d0fbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49a3dc243017ff7d89e576f8fc84c33a = $(`&lt;div id=&quot;html_49a3dc243017ff7d89e576f8fc84c33a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_98f7f19a93a4db9696098a08dc3d0fbd.setContent(html_49a3dc243017ff7d89e576f8fc84c33a);
#
#
#
#         marker_27e0bafa4d7e6cf33f2d056ee38bfff6.bindPopup(popup_98f7f19a93a4db9696098a08dc3d0fbd)
#         ;
#
#
#
#
#             var marker_cef3ec09477b9d2c908fd42e86a68378 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_60293a5a3603e4bd8fdc9833ef203123);
#
#
#         var popup_9936b7c0a7cd4e6a6a8952cb6ac332de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5daacb565e0da2a012a2146a7f531b86 = $(`&lt;div id=&quot;html_5daacb565e0da2a012a2146a7f531b86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9936b7c0a7cd4e6a6a8952cb6ac332de.setContent(html_5daacb565e0da2a012a2146a7f531b86);
#
#
#
#         marker_cef3ec09477b9d2c908fd42e86a68378.bindPopup(popup_9936b7c0a7cd4e6a6a8952cb6ac332de)
#         ;
#
#
#
#
#             var marker_c1f9aa67990036d035e5dabaf904ea65 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_60293a5a3603e4bd8fdc9833ef203123);
#
#
#         var popup_c255b62f56b244882057992952065f42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_821bc20b6f4f3688661cdad7fd475741 = $(`&lt;div id=&quot;html_821bc20b6f4f3688661cdad7fd475741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c255b62f56b244882057992952065f42.setContent(html_821bc20b6f4f3688661cdad7fd475741);
#
#
#
#         marker_c1f9aa67990036d035e5dabaf904ea65.bindPopup(popup_c255b62f56b244882057992952065f42)
#         ;
#
#
#
#
#             var marker_9345f65352271643c452e0901bd590ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_60293a5a3603e4bd8fdc9833ef203123);
#
#
#         var popup_e678d09595e59879ff334facda8e396e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f36cd5425751fb795b8cce846f20c8c3 = $(`&lt;div id=&quot;html_f36cd5425751fb795b8cce846f20c8c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e678d09595e59879ff334facda8e396e.setContent(html_f36cd5425751fb795b8cce846f20c8c3);
#
#
#
#         marker_9345f65352271643c452e0901bd590ca.bindPopup(popup_e678d09595e59879ff334facda8e396e)
#         ;
#
#
#
#
#             var marker_e8bc82bd2c1dcbc98ac5f11a0b9f2047 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_60293a5a3603e4bd8fdc9833ef203123);
#
#
#         var popup_df3859b757fdd7e8528b0c71bf7e016a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95a497edc65134087c06b64a81e50f01 = $(`&lt;div id=&quot;html_95a497edc65134087c06b64a81e50f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_df3859b757fdd7e852

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99a29918b901786693c28f010a469617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99a29918b901786693c28f010a469617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99a29918b901786693c28f010a469617 = L.map(
#                 &quot;map_99a29918b901786693c28f010a469617&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e4eb3ea5f292d65fa3bc84a6d0c0079 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e4eb3ea5f292d65fa3bc84a6d0c0079.addTo(map_99a29918b901786693c28f010a469617);
#
#
#             var feature_group_87d856073813852a74d03b783f4596ff = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_87d856073813852a74d03b783f4596ff.addTo(map_99a29918b901786693c28f010a469617);
#
#
#             var feature_group_sub_group_1542d2ffeedeac05c795777e10a7ca4b = L.featureGroup.subGroup(
#                 feature_group_87d856073813852a74d03b783f4596ff
#             );
#
#
#             var marker_db40064faf547d4b93897d03cb0dae0d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1542d2ffeedeac05c795777e10a7ca4b);
#
#
#         var popup_7176dae2fd66df93e740464711218ee2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55bc7bbb17cbed3b82e09a84fc815f37 = $(`&lt;div id=&quot;html_55bc7bbb17cbed3b82e09a84fc815f37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7176dae2fd66df93e740464711218ee2.setContent(html_55bc7bbb17cbed3b82e09a84fc815f37);
#
#
#
#         marker_db40064faf547d4b93897d03cb0dae0d.bindPopup(popup_7176dae2fd66df93e740464711218ee2)
#         ;
#
#
#
#
#             var marker_e1de2ffd8929d701745aa57c2ca4f628 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1542d2ffeedeac05c795777e10a7ca4b);
#
#
#         var popup_7410f81018a53c6964e616620b4ea2de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9da6ab0617455e06d7118a8aeb52f273 = $(`&lt;div id=&quot;html_9da6ab0617455e06d7118a8aeb52f273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7410f81018a53c6964e616620b4ea2de.setContent(html_9da6ab0617455e06d7118a8aeb52f273);
#
#
#
#         marker_e1de2ffd8929d701745aa57c2ca4f628.bindPopup(popup_7410f81018a53c6964e616620b4ea2de)
#         ;
#
#
#
#
#             var marker_e965bd0d25d134c999790e7314a21f2b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1542d2ffeedeac05c795777e10a7ca4b);
#
#
#         var popup_4abd67fc55b603b3b2c14dc164a3a345 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3171be427cb34d60cec3fec571a66cc3 = $(`&lt;div id=&quot;html_3171be427cb34d60cec3fec571a66cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4abd67fc55b603b3b2c14dc164a3a345.setContent(html_3171be427cb34d60cec3fec571a66cc3);
#
#
#
#         marker_e965bd0d25d134c999790e7314a21f2b.bindPopup(popup_4abd67fc55b603b3b2c14dc164a3a345)
#         ;
#
#
#
#
#             var marker_de8deb17582c1a3af319a5164c418ce4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1542d2ffeedeac05c795777e10a7ca4b);
#
#
#         var popup_f1bce6554e412049783c289693a4ed81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c42f1e7ac61636655c0b05a2e661ee32 = $(`&lt;div id=&quot;html_c42f1e7ac61636655c0b05a2e661ee32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f1bce6554e412049783c289693a4ed81.setContent(html_c42f1e7ac61636655c0b05a2e661ee32);
#
#
#
#         marker_de8deb17582c1a3af319a5164c418ce4.bindPopup(popup_f1bce6554e412049783c289693a4ed81)
#         ;
#
#
#
#
#             var marker_b678050ca4f3615baf54bfb549295d7c = L.marker(
#                 [45.050399999999996, 3.0504],
