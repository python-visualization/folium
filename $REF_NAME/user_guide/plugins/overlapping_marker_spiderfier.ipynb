# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b6d7ec7a1b931e645316e4ef3b1e13 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b6d7ec7a1b931e645316e4ef3b1e13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4b6d7ec7a1b931e645316e4ef3b1e13 = L.map(
#                 &quot;map_d4b6d7ec7a1b931e645316e4ef3b1e13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a63466aa3e13400f7598a62a79f29004 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a63466aa3e13400f7598a62a79f29004.addTo(map_d4b6d7ec7a1b931e645316e4ef3b1e13);
#
#
#             var marker_683f733ec4ecc3641d5f4b7c235c9024 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d4b6d7ec7a1b931e645316e4ef3b1e13);
#
#
#         var popup_39a7f66299257f13b9406dcf5dab29c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fdf2637b442c725ec4912c7eac5032f = $(`&lt;div id=&quot;html_6fdf2637b442c725ec4912c7eac5032f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_39a7f66299257f13b9406dcf5dab29c0.setContent(html_6fdf2637b442c725ec4912c7eac5032f);
#
#
#
#         marker_683f733ec4ecc3641d5f4b7c235c9024.bindPopup(popup_39a7f66299257f13b9406dcf5dab29c0)
#         ;
#
#
#
#
#             var marker_12ecbdf6cc180fbb1e23a9fdc900c307 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d4b6d7ec7a1b931e645316e4ef3b1e13);
#
#
#         var popup_0208a901dea7aec3f761fd5704b85bd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f2471f09329c5717bcde5341b87e525 = $(`&lt;div id=&quot;html_5f2471f09329c5717bcde5341b87e525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0208a901dea7aec3f761fd5704b85bd8.setContent(html_5f2471f09329c5717bcde5341b87e525);
#
#
#
#         marker_12ecbdf6cc180fbb1e23a9fdc900c307.bindPopup(popup_0208a901dea7aec3f761fd5704b85bd8)
#         ;
#
#
#
#
#             var marker_c2ac8d0ab74385facf4f565c37cf83c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d4b6d7ec7a1b931e645316e4ef3b1e13);
#
#
#         var popup_ddd47e12b902446a4d85c5ff09a31237 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab2d4179f5a4cb7989860e1b0c13798f = $(`&lt;div id=&quot;html_ab2d4179f5a4cb7989860e1b0c13798f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ddd47e12b902446a4d85c5ff09a31237.setContent(html_ab2d4179f5a4cb7989860e1b0c13798f);
#
#
#
#         marker_c2ac8d0ab74385facf4f565c37cf83c5.bindPopup(popup_ddd47e12b902446a4d85c5ff09a31237)
#         ;
#
#
#
#
#             var marker_dd46b2fa1d6cd6bc9cfdae3ba0bbeed0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d4b6d7ec7a1b931e645316e4ef3b1e13);
#
#
#         var popup_d0f01326307a9acb02625b4d7a7ce907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2e29f81e742c5ecf26ff2a69afb8469 = $(`&lt;div id=&quot;html_e2e29f81e742c5ecf26ff2a69afb8469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d0f01326307a9acb02625b4d7a7ce907.setContent(html_e2e29f81e742c5ecf26ff2a69afb8469);
#
#
#
#         marker_dd46b2fa1d6cd6bc9cfdae3ba0bbeed0.bindPopup(popup_d0f01326307a9acb02625b4d7a7ce907)
#         ;
#
#
#
#
#             var marker_6ccbd37766c58cee439c75fb4716dfc5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d4b6d7ec7a1b931e645316e4ef3b1e13);
#
#
#         var popup_135bf462790e709c7293abc9c49d9ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6149bb3eecbb904cbdfe947213c6de0 = $(`&lt;div id=&quot;html_a6149bb3eecbb904cbdfe947213c6de0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_135bf462790e709c7293abc9c49d9a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9af488d4466c70913cc192c8491c0b3f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9af488d4466c70913cc192c8491c0b3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9af488d4466c70913cc192c8491c0b3f = L.map(
#                 &quot;map_9af488d4466c70913cc192c8491c0b3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d672cc1fb2da5ccadc1b14df20008979 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d672cc1fb2da5ccadc1b14df20008979.addTo(map_9af488d4466c70913cc192c8491c0b3f);
#
#
#             var feature_group_b6f8f75ca3992269c49351b4058c5d47 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_936a57a9272557e2cb6e91863d7eef0b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b6f8f75ca3992269c49351b4058c5d47);
#
#
#         var popup_e06c7e35be02bf2eb2949bd7f782d241 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43afa2b24cff3aa163f3c8959c8ad6da = $(`&lt;div id=&quot;html_43afa2b24cff3aa163f3c8959c8ad6da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e06c7e35be02bf2eb2949bd7f782d241.setContent(html_43afa2b24cff3aa163f3c8959c8ad6da);
#
#
#
#         marker_936a57a9272557e2cb6e91863d7eef0b.bindPopup(popup_e06c7e35be02bf2eb2949bd7f782d241)
#         ;
#
#
#
#
#             var marker_45f96791037a99e8f0d39dcc171e2cec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b6f8f75ca3992269c49351b4058c5d47);
#
#
#         var popup_dee00360aa705c9c8f0a663612e85bc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc1d2eee56c54453f68ac75f2442c77 = $(`&lt;div id=&quot;html_ddc1d2eee56c54453f68ac75f2442c77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dee00360aa705c9c8f0a663612e85bc0.setContent(html_ddc1d2eee56c54453f68ac75f2442c77);
#
#
#
#         marker_45f96791037a99e8f0d39dcc171e2cec.bindPopup(popup_dee00360aa705c9c8f0a663612e85bc0)
#         ;
#
#
#
#
#             var marker_d3a569e9277cb869722e5d94ff649793 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b6f8f75ca3992269c49351b4058c5d47);
#
#
#         var popup_e3fee2344203549d16566258f2509753 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_deb659b7a90d6ccc972f5f8df23f047c = $(`&lt;div id=&quot;html_deb659b7a90d6ccc972f5f8df23f047c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e3fee2344203549d16566258f2509753.setContent(html_deb659b7a90d6ccc972f5f8df23f047c);
#
#
#
#         marker_d3a569e9277cb869722e5d94ff649793.bindPopup(popup_e3fee2344203549d16566258f2509753)
#         ;
#
#
#
#
#             var marker_3a43cef3d53e49719458f5ac4a473cfd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b6f8f75ca3992269c49351b4058c5d47);
#
#
#         var popup_1b2738ab3a2aacbc0bcc49db38745a13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a52bf7f907ada5e311c131060fc88ffb = $(`&lt;div id=&quot;html_a52bf7f907ada5e311c131060fc88ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1b2738ab3a2aacbc0bcc49db38745a13.setContent(html_a52bf7f907ada5e311c131060fc88ffb);
#
#
#
#         marker_3a43cef3d53e49719458f5ac4a473cfd.bindPopup(popup_1b2738ab3a2aacbc0bcc49db38745a13)
#         ;
#
#
#
#
#             var marker_a9abc920617b213223409a155f46119f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b6f8f75ca3992269c49351b4058c5d47);
#
#
#         var popup_9ec38b7ece5c16fff9220b93c87d18ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20119abff8e901a42c9f10679293f8ac {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20119abff8e901a42c9f10679293f8ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20119abff8e901a42c9f10679293f8ac = L.map(
#                 &quot;map_20119abff8e901a42c9f10679293f8ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc7f4d7a3846691fb9a611ad021e24ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc7f4d7a3846691fb9a611ad021e24ed.addTo(map_20119abff8e901a42c9f10679293f8ac);
#
#
#             var feature_group_d4780b306c661efc71d339009ad050b9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d4780b306c661efc71d339009ad050b9.addTo(map_20119abff8e901a42c9f10679293f8ac);
#
#
#             var feature_group_sub_group_f00d1191beae9cb6b82b80bd33beaa0a = L.featureGroup.subGroup(
#                 feature_group_d4780b306c661efc71d339009ad050b9
#             );
#
#
#             var marker_1a41560292761c40214d3081a54cd4a8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f00d1191beae9cb6b82b80bd33beaa0a);
#
#
#         var popup_ea80f075a958364a434b6ff41ff7cb09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5130d5b68332ee36df721e4fe5ac9c3c = $(`&lt;div id=&quot;html_5130d5b68332ee36df721e4fe5ac9c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ea80f075a958364a434b6ff41ff7cb09.setContent(html_5130d5b68332ee36df721e4fe5ac9c3c);
#
#
#
#         marker_1a41560292761c40214d3081a54cd4a8.bindPopup(popup_ea80f075a958364a434b6ff41ff7cb09)
#         ;
#
#
#
#
#             var marker_fc27654a670846ad1fff767a1be3c9ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f00d1191beae9cb6b82b80bd33beaa0a);
#
#
#         var popup_f8fc814589ea3bb39e08e23ee4157707 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ddb7c031d02ee223d18c62bce8392b3 = $(`&lt;div id=&quot;html_6ddb7c031d02ee223d18c62bce8392b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f8fc814589ea3bb39e08e23ee4157707.setContent(html_6ddb7c031d02ee223d18c62bce8392b3);
#
#
#
#         marker_fc27654a670846ad1fff767a1be3c9ac.bindPopup(popup_f8fc814589ea3bb39e08e23ee4157707)
#         ;
#
#
#
#
#             var marker_28241069aaac03978b67a090e4f450b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f00d1191beae9cb6b82b80bd33beaa0a);
#
#
#         var popup_b936801ebfed8a337fdfda264224585c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fa6e999f7643966bb928b484c93fdd8 = $(`&lt;div id=&quot;html_5fa6e999f7643966bb928b484c93fdd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b936801ebfed8a337fdfda264224585c.setContent(html_5fa6e999f7643966bb928b484c93fdd8);
#
#
#
#         marker_28241069aaac03978b67a090e4f450b7.bindPopup(popup_b936801ebfed8a337fdfda264224585c)
#         ;
#
#
#
#
#             var marker_a461590634e8f4bda33d80d4558f3ab3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f00d1191beae9cb6b82b80bd33beaa0a);
#
#
#         var popup_f5e83a8f542020e5f2c4a251e5b64641 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05fc92f0d9ce478c61df9ff51dd2b463 = $(`&lt;div id=&quot;html_05fc92f0d9ce478c61df9ff51dd2b463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f5e83a8f542020e5f2c4a251e5b64641.setContent(html_05fc92f0d9ce478c61df9ff51dd2b463);
#
#
#
#         mark
