# %%
import folium
import folium.plugins

# %% [markdown]
# ## SemiCircle
#
# This can be used to display a semicircle or sector on a map. Whilst called SemiCircle it is not limited to 180 degree angles and can be used to display a sector of any angle.
#
# The semicircle is defined with a location (the central point, if it was a full circle), a radius and will either have a direction and an arc **or** a start angle and a stop angle.

# %%
m = folium.Map([45, 3], zoom_start=5)

folium.plugins.SemiCircle(
    (45, 3),
    radius=400000,
    start_angle=50,
    stop_angle=200,
    color="green",
    fill_color="green",
    opacity=0,
    popup="start angle - 50 degrees, stop angle - 200 degrees",
).add_to(m)

folium.plugins.SemiCircle(
    (46.5, 9.5),
    radius=200000,
    direction=360,
    arc=90,
    color="red",
    fill_color="red",
    opacity=0,
    popup="Direction - 0 degrees, arc 90 degrees",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6171ded1e11ff473b12d67d1f8a4a42a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-semicircle@2.0.4/Semicircle.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6171ded1e11ff473b12d67d1f8a4a42a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6171ded1e11ff473b12d67d1f8a4a42a = L.map(
#                 &quot;map_6171ded1e11ff473b12d67d1f8a4a42a&quot;,
#                 {
#                     center: [45.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ac436f1d0a1a7bdca2d4b901a1d975c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ac436f1d0a1a7bdca2d4b901a1d975c.addTo(map_6171ded1e11ff473b12d67d1f8a4a42a);
#
#
#             var semi_circle_8ad8408e9efb4b3ad6f53322bd68fa1c = L.semiCircle(
#                 [45.0, 3.0],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 400000,
#   &quot;startAngle&quot;: 50,
#   &quot;stopAngle&quot;: 200,
# }
#                 )
#                 .addTo(map_6171ded1e11ff473b12d67d1f8a4a42a);
#
#
#         var popup_c597853a845be27031bc8a84f8cb9a96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d78d4fe25aa891b377a1dbee772ed313 = $(`&lt;div id=&quot;html_d78d4fe25aa891b377a1dbee772ed313&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;start angle - 50 degrees, stop angle - 200 degrees&lt;/div&gt;`)[0];
#                 popup_c597853a845be27031bc8a84f8cb9a96.setContent(html_d78d4fe25aa891b377a1dbee772ed313);
#
#
#
#         semi_circle_8ad8408e9efb4b3ad6f53322bd68fa1c.bindPopup(popup_c597853a845be27031bc8a84f8cb9a96)
#         ;
#
#
#
#
#             var semi_circle_c96534f1a6ca3b73d0c2aa5d1d5c4231 = L.semiCircle(
#                 [46.5, 9.5],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;red&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 200000,
# }
#                 )
#                     .setDirection(360, 90)
#                 .addTo(map_6171ded1e11ff473b12d67d1f8a4a42a);
#
#
#         var popup_5bd98ab8551699d3f69ffe4f54751a25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1878aba5f744d002812b6fb765f7eade = $(`&lt;div id=&quot;html_1878aba5f744d002812b6fb765f7eade&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction - 0 degrees, arc 90 degrees&lt;/div&gt;`)[0];
#                 popup_5bd98ab8551699d3f69ffe4f54751a25.setContent(html_1878aba5f744d002812b6fb765f7eade);
#
#
#
#         semi_circle_c96534f1a6ca3b73d0c2aa5d1d5c4231.bindPopup(popup_5bd98ab8551699d3f69ffe4f54751a25)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
