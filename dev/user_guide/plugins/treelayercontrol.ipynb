# %%
import folium
import folium.plugins

# %% [markdown]
# # TreeLayerControl
# Create a Layer Control allowing a tree structure for the layers.
#
# See https://github.com/jjimenezshaw/Leaflet.Control.Layers.Tree for more
# information.
#
# ## Simple example

# %%
import folium
from folium.plugins.treelayercontrol import TreeLayerControl
from folium.features import Marker

m = folium.Map(location=[46.603354, 1.8883335], zoom_start=5)

overlay_tree = {
    "label": "Points of Interest",
    "select_all_checkbox": "Un/select all",
    "children": [
        {
            "label": "Europe",
            "select_all_checkbox": True,
            "children": [
                {
                    "label": "France",
                    "select_all_checkbox": True,
                    "children": [
                        { "label": "Tour Eiffel", "layer": Marker([48.8582441, 2.2944775]).add_to(m) },
                        { "label": "Notre Dame", "layer": Marker([48.8529540, 2.3498726]).add_to(m) },
                        { "label": "Louvre", "layer": Marker([48.8605847, 2.3376267]).add_to(m) },
                    ]
                }, {
                    "label": "Germany",
                    "select_all_checkbox": True,
                    "children": [
                        { "label": "Branderburger Tor", "layer": Marker([52.5162542, 13.3776805]).add_to(m)},
                        { "label": "Kölner Dom", "layer": Marker([50.9413240, 6.9581201]).add_to(m)},
                    ]
                }, {"label": "Spain",
                    "select_all_checkbox": "De/seleccionar todo",
                    "children": [
                        { "label": "Palacio Real", "layer": Marker([40.4184145, -3.7137051]).add_to(m)},
                        { "label": "La Alhambra", "layer": Marker([37.1767829, -3.5892795]).add_to(m)},
                    ]
                }
            ]
        }, {
            "label": "Asia",
            "select_all_checkbox": True,
            "children": [
                {
                    "label": "Jordan",
                    "select_all_checkbox": True,
                    "children": [
                        { "label": "Petra", "layer": Marker([30.3292215, 35.4432464]).add_to(m) },
                        { "label": "Wadi Rum", "layer": Marker([29.6233486, 35.4390656]).add_to(m) }
                    ]
                }, {
                }
            ]
        }
    ]
}

TreeLayerControl(overlay_tree=overlay_tree).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03c431ee14d2fd07d67de9dc837d0e94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.control.layers.tree@1.1.0/L.Control.Layers.Tree.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.control.layers.tree@1.1.0/L.Control.Layers.Tree.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03c431ee14d2fd07d67de9dc837d0e94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03c431ee14d2fd07d67de9dc837d0e94 = L.map(
#                 &quot;map_03c431ee14d2fd07d67de9dc837d0e94&quot;,
#                 {
#                     center: [46.603354, 1.8883335],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1074e03bbad094766406cec0fd3fe178 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1074e03bbad094766406cec0fd3fe178.addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_73b30af7c81d5d88885da1f25e733fbe = L.marker(
#                 [48.8582441, 2.2944775],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_d578e92878bf0a6fc4789cb15164ffdf = L.marker(
#                 [48.852954, 2.3498726],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_0e12506a777ac62a8ed2fdfa8512166c = L.marker(
#                 [48.8605847, 2.3376267],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_aa0a4d67e247720cece09956f999e2ac = L.marker(
#                 [52.5162542, 13.3776805],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_fdfd8441ebb75f9bb1be8ede50c3b3c9 = L.marker(
#                 [50.941324, 6.9581201],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_206a5375cd8a94de5ff7c867d0f73903 = L.marker(
#                 [40.4184145, -3.7137051],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_b5a5ba040fa84c3bd26406916475b8ff = L.marker(
#                 [37.1767829, -3.5892795],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_42a0f9242bacb07fd4d6201c9f736576 = L.marker(
#                 [30.3292215, 35.4432464],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             var marker_bb4f6c077cc19191e31563e88ff59ce4 = L.marker(
#                 [29.6233486, 35.4390656],
#                 {
# }
#             ).addTo(map_03c431ee14d2fd07d67de9dc837d0e94);
#
#
#             L.control.layers.tree(
#                 null,
#                 {
#   &quot;label&quot;: &quot;Points of Interest&quot;,
#   &quot;selectAllCheckbox&quot;: &quot;Un/select all&quot;,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;Europe&quot;,
#   &quot;selectAllCheckbox&quot;: true,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;France&quot;,
#   &quot;selectAllCheckbox&quot;: true,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;Tour Eiffel&quot;,
#   &quot;layer&quot;: marker_73b30af7c81d5d88885da1f25e733fbe,
# },
# {
#   &quot;label&quot;: &quot;Notre Dame&quot;,
#   &quot;layer&quot;: marker_d578e92878bf0a6fc4789cb15164ffdf,
# },
# {
#   &quot;label&quot;: &quot;Louvre&quot;,
#   &quot;layer&quot;: marker_0e12506a777ac62a8ed2fdfa8512166c,
# },
# ],
# },
# {
#   &quot;label&quot;: &quot;Germany&quot;,
#   &quot;selectAllCheckbox&quot;: true,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;Branderburger Tor&quot;,
#   &quot;layer&quot;: marker_aa0a4d67e247720cece09956f999e2ac,
# },
# {
#   &quot;label&quot;: &quot;K\u00f6lner Dom&quot;,
#   &quot;layer&quot;: marker_fdfd8441ebb75f9bb1be8ede50c3b3c9,
# },
# ],
# },
# {
#   &quot;label&quot;: &quot;Spain&quot;,
#   &quot;selectAllCheckbox&quot;: &quot;De/seleccionar todo&quot;,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;Palacio Real&quot;,
#   &quot;layer&quot;: marker_206a5375cd8a94de5ff7c867d0f73903,
# },
# {
#   &quot;label&quot;: &quot;La Alhambra&quot;,
#   &quot;layer&quot;: marker_b5a5ba040fa84c3bd26406916475b8ff,
# },
# ],
# },
# ],
# },
# {
#   &quot;label&quot;: &quot;Asia&quot;,
#   &quot;selectAllCheckbox&quot;: true,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;Jordan&quot;,
#   &quot;selectAllCheckbox&quot;: true,
#   &quot;children&quot;: [
# {
#   &quot;label&quot;: &quot;Petra&quot;,
#   &quot;laye
