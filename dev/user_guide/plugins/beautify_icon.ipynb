# %%
import folium
import folium.plugins

# %% [markdown]
# ## BeautifyIcon

# %%
m = folium.Map([45.5, -122], zoom_start=3)

icon_plane = folium.plugins.BeautifyIcon(
    icon="plane", border_color="#b3334f", text_color="#b3334f", icon_shape="triangle"
)

icon_number = folium.plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=10,
    inner_icon_style="margin-top:0;",
)

folium.Marker(location=[46, -122], popup="Portland, OR", icon=icon_plane).add_to(m)

folium.Marker(location=[50, -122], popup="Portland, OR", icon=icon_number).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d271210ef3db6979db5d2ab7044f5ada {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d271210ef3db6979db5d2ab7044f5ada&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d271210ef3db6979db5d2ab7044f5ada = L.map(
#                 &quot;map_d271210ef3db6979db5d2ab7044f5ada&quot;,
#                 {
#                     center: [45.5, -122.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_547271028e83303d3c7653084ed62265 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_547271028e83303d3c7653084ed62265.addTo(map_d271210ef3db6979db5d2ab7044f5ada);
#
#
#             var marker_5354d16ffb9a074535400ccb33acc07c = L.marker(
#                 [46.0, -122.0],
#                 {
# }
#             ).addTo(map_d271210ef3db6979db5d2ab7044f5ada);
#
#
#             var beautify_icon_a601c424522c119a20a692f591b0e9ba = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;plane&quot;,
#   &quot;iconShape&quot;: &quot;triangle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#b3334f&quot;,
#   &quot;textColor&quot;: &quot;#b3334f&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_5354d16ffb9a074535400ccb33acc07c.setIcon(beautify_icon_a601c424522c119a20a692f591b0e9ba);
#
#
#         var popup_90c5f32e061878866eed9b732db4ae94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_255ff8fd334c6446890f0d8c76e7b1aa = $(`&lt;div id=&quot;html_255ff8fd334c6446890f0d8c76e7b1aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_90c5f32e061878866eed9b732db4ae94.setContent(html_255ff8fd334c6446890f0d8c76e7b1aa);
#
#
#
#         marker_5354d16ffb9a074535400ccb33acc07c.bindPopup(popup_90c5f32e061878866eed9b732db4ae94)
#         ;
#
#
#
#
#                 marker_5354d16ffb9a074535400ccb33acc07c.setIcon(beautify_icon_a601c424522c119a20a692f591b0e9ba);
#
#
#             var marker_b0575254aed800d1ec3622f489842a90 = L.marker(
#                 [50.0, -122.0],
#                 {
# }
#             ).addTo(map_d271210ef3db6979db5d2ab7044f5ada);
#
#
#             var beautify_icon_3f6e1343a2c5d41ac33cd2b0c8d757e1 = new L.BeautifyIcon.icon(
#                 {
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#00ABDC&quot;,
#   &quot;textColor&quot;: &quot;#00ABDC&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;margin-top:0;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: true,
#   &quot;text&quot;: 10,
# }
#             )
#             marker_b0575254aed800d1ec3622f489842a90.setIcon(beautify_icon_3f6e1343a2c5d41ac33cd2b0c8d757e1);
#
#
#         var popup_ae0db879b93449bd790aac77cc5796c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_022b13e5365dfe92342d46493204104a = $(`&lt;div id=&quot;html_022b13e5365dfe92342d46493204104a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_ae0db879b93449bd790aac77cc5796c1.setContent(html_022b13e5365dfe92342d46493204104a);
#
#
#
#         marker_b0575254aed800d1ec3622f489842a90.bindPopup(popup_ae0db879b93449bd790aac77cc5796c1)
#         ;
#
#
#
#
#                 marker_b0575254aed800d1ec3622f489842a90.setIcon(beautify_icon_3f6e1343a2c5d41ac33cd2b0c8d757e1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
