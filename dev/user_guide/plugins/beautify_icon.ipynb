# %%
import folium
import folium.plugins

# %% [markdown]
# ## BeautifyIcon

# %%
m = folium.Map([45.5, -122], zoom_start=3)

icon_plane = folium.plugins.BeautifyIcon(
    icon="plane", border_color="#b3334f", text_color="#b3334f", icon_shape="triangle"
)

icon_number = folium.plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=10,
    inner_icon_style="margin-top:0;",
)

folium.Marker(location=[46, -122], popup="Portland, OR", icon=icon_plane).add_to(m)

folium.Marker(location=[50, -122], popup="Portland, OR", icon=icon_number).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_112b75d5d378acc37abdce48bb15b24f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_112b75d5d378acc37abdce48bb15b24f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_112b75d5d378acc37abdce48bb15b24f = L.map(
#                 &quot;map_112b75d5d378acc37abdce48bb15b24f&quot;,
#                 {
#                     center: [45.5, -122.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94182da23cc86b7e968c0932de1c7c2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94182da23cc86b7e968c0932de1c7c2e.addTo(map_112b75d5d378acc37abdce48bb15b24f);
#
#
#             var marker_81bcbe5bab0191aab610b6a778ed4704 = L.marker(
#                 [46.0, -122.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_112b75d5d378acc37abdce48bb15b24f);
#
#
#             var beautify_icon_886dae1179012a01601ee60382520343 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;plane&quot;,
#   &quot;iconShape&quot;: &quot;triangle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#b3334f&quot;,
#   &quot;textColor&quot;: &quot;#b3334f&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
#   &quot;text&quot;: null,
# }
#             )
#             marker_81bcbe5bab0191aab610b6a778ed4704.setIcon(beautify_icon_886dae1179012a01601ee60382520343);
#
#
#         var popup_24d8dd3ae5328a91ed4f3a5b02b1c3a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_e6dccee8a061f85b3bbe870342a4644c = $(`&lt;div id=&quot;html_e6dccee8a061f85b3bbe870342a4644c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_24d8dd3ae5328a91ed4f3a5b02b1c3a5.setContent(html_e6dccee8a061f85b3bbe870342a4644c);
#
#
#
#         marker_81bcbe5bab0191aab610b6a778ed4704.bindPopup(popup_24d8dd3ae5328a91ed4f3a5b02b1c3a5)
#         ;
#
#
#
#
#             var marker_808f43f1f9131a386872db2001ffc706 = L.marker(
#                 [50.0, -122.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_112b75d5d378acc37abdce48bb15b24f);
#
#
#             var beautify_icon_c7d907a0e20c883d044fb601a050ba42 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: null,
#   &quot;iconShape&quot;: null,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#00ABDC&quot;,
#   &quot;textColor&quot;: &quot;#00ABDC&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;margin-top:0;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: true,
#   &quot;text&quot;: 10,
# }
#             )
#             marker_808f43f1f9131a386872db2001ffc706.setIcon(beautify_icon_c7d907a0e20c883d044fb601a050ba42);
#
#
#         var popup_4fb9f6f554410694e99aa91f809bae27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_6c33e2398f8e9576686a598863e138cd = $(`&lt;div id=&quot;html_6c33e2398f8e9576686a598863e138cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_4fb9f6f554410694e99aa91f809bae27.setContent(html_6c33e2398f8e9576686a598863e138cd);
#
#
#
#         marker_808f43f1f9131a386872db2001ffc706.bindPopup(popup_4fb9f6f554410694e99aa91f809bae27)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
