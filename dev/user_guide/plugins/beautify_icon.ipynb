# %%
import folium
import folium.plugins

# %% [markdown]
# ## BeautifyIcon

# %%
m = folium.Map([45.5, -122], zoom_start=3)

icon_plane = folium.plugins.BeautifyIcon(
    icon="plane", border_color="#b3334f", text_color="#b3334f", icon_shape="triangle"
)

icon_number = folium.plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=10,
    inner_icon_style="margin-top:0;",
)

folium.Marker(location=[46, -122], popup="Portland, OR", icon=icon_plane).add_to(m)

folium.Marker(location=[50, -122], popup="Portland, OR", icon=icon_number).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dbb436c7ff1b050cff26eeea9706e6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dbb436c7ff1b050cff26eeea9706e6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dbb436c7ff1b050cff26eeea9706e6a = L.map(
#                 &quot;map_6dbb436c7ff1b050cff26eeea9706e6a&quot;,
#                 {
#                     center: [45.5, -122.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4b6ebcf36855b8c3d642e90ded229ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4b6ebcf36855b8c3d642e90ded229ff.addTo(map_6dbb436c7ff1b050cff26eeea9706e6a);
#
#
#             var marker_ece809ec9531c749be2d7a78ebeae8bb = L.marker(
#                 [46.0, -122.0],
#                 {
# }
#             ).addTo(map_6dbb436c7ff1b050cff26eeea9706e6a);
#
#
#             var beautify_icon_a3b4f29f7d22dc891d271f1ca5caaca8 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;plane&quot;,
#   &quot;iconShape&quot;: &quot;triangle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#b3334f&quot;,
#   &quot;textColor&quot;: &quot;#b3334f&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_ece809ec9531c749be2d7a78ebeae8bb.setIcon(beautify_icon_a3b4f29f7d22dc891d271f1ca5caaca8);
#
#
#         var popup_c5f945606a4dcf0a7438ee22cec76178 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d6e36021279dc595f517d19b22aeb10 = $(`&lt;div id=&quot;html_8d6e36021279dc595f517d19b22aeb10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_c5f945606a4dcf0a7438ee22cec76178.setContent(html_8d6e36021279dc595f517d19b22aeb10);
#
#
#
#         marker_ece809ec9531c749be2d7a78ebeae8bb.bindPopup(popup_c5f945606a4dcf0a7438ee22cec76178)
#         ;
#
#
#
#
#                 marker_ece809ec9531c749be2d7a78ebeae8bb.setIcon(beautify_icon_a3b4f29f7d22dc891d271f1ca5caaca8);
#
#
#             var marker_bf1b6215113b5f14b8204237ff834ce4 = L.marker(
#                 [50.0, -122.0],
#                 {
# }
#             ).addTo(map_6dbb436c7ff1b050cff26eeea9706e6a);
#
#
#             var beautify_icon_d4fe41a4f2f754465805d6bbe04579de = new L.BeautifyIcon.icon(
#                 {
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#00ABDC&quot;,
#   &quot;textColor&quot;: &quot;#00ABDC&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;margin-top:0;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: true,
#   &quot;text&quot;: 10,
# }
#             )
#             marker_bf1b6215113b5f14b8204237ff834ce4.setIcon(beautify_icon_d4fe41a4f2f754465805d6bbe04579de);
#
#
#         var popup_f2961e1f4b6a3a03bc168d7b6a8b7815 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67f543bdc8bb76829d5f4b02d3725c17 = $(`&lt;div id=&quot;html_67f543bdc8bb76829d5f4b02d3725c17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_f2961e1f4b6a3a03bc168d7b6a8b7815.setContent(html_67f543bdc8bb76829d5f4b02d3725c17);
#
#
#
#         marker_bf1b6215113b5f14b8204237ff834ce4.bindPopup(popup_f2961e1f4b6a3a03bc168d7b6a8b7815)
#         ;
#
#
#
#
#                 marker_bf1b6215113b5f14b8204237ff834ce4.setIcon(beautify_icon_d4fe41a4f2f754465805d6bbe04579de);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
