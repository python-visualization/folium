# %%
import folium
import folium.plugins

# %% [markdown]
# ## BeautifyIcon

# %%
m = folium.Map([45.5, -122], zoom_start=3)

icon_plane = folium.plugins.BeautifyIcon(
    icon="plane", border_color="#b3334f", text_color="#b3334f", icon_shape="triangle"
)

icon_number = folium.plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=10,
    inner_icon_style="margin-top:0;",
)

folium.Marker(location=[46, -122], popup="Portland, OR", icon=icon_plane).add_to(m)

folium.Marker(location=[50, -122], popup="Portland, OR", icon=icon_number).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27578a8657f27be8fe88f8b9579e0f6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27578a8657f27be8fe88f8b9579e0f6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27578a8657f27be8fe88f8b9579e0f6e = L.map(
#                 &quot;map_27578a8657f27be8fe88f8b9579e0f6e&quot;,
#                 {
#                     center: [45.5, -122.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b30e4bf0607966c90f003b5acf4780f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b30e4bf0607966c90f003b5acf4780f.addTo(map_27578a8657f27be8fe88f8b9579e0f6e);
#
#
#             var marker_86c30ca98ed8fc6368d1b64a3cb14bf9 = L.marker(
#                 [46.0, -122.0],
#                 {
# }
#             ).addTo(map_27578a8657f27be8fe88f8b9579e0f6e);
#
#
#             var beautify_icon_ead1faef0157018d7f611c654a0f58a4 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;plane&quot;,
#   &quot;iconShape&quot;: &quot;triangle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#b3334f&quot;,
#   &quot;textColor&quot;: &quot;#b3334f&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_86c30ca98ed8fc6368d1b64a3cb14bf9.setIcon(beautify_icon_ead1faef0157018d7f611c654a0f58a4);
#
#
#         var popup_56322a03b72551ce3376a601bb678753 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d724d29aa4f75e541178c9983b378484 = $(`&lt;div id=&quot;html_d724d29aa4f75e541178c9983b378484&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_56322a03b72551ce3376a601bb678753.setContent(html_d724d29aa4f75e541178c9983b378484);
#
#
#
#         marker_86c30ca98ed8fc6368d1b64a3cb14bf9.bindPopup(popup_56322a03b72551ce3376a601bb678753)
#         ;
#
#
#
#
#                 marker_86c30ca98ed8fc6368d1b64a3cb14bf9.setIcon(beautify_icon_ead1faef0157018d7f611c654a0f58a4);
#
#
#             var marker_2d547f6377354910eb1e024add901cc4 = L.marker(
#                 [50.0, -122.0],
#                 {
# }
#             ).addTo(map_27578a8657f27be8fe88f8b9579e0f6e);
#
#
#             var beautify_icon_96dbe2454b52e61f875a80bfa98be646 = new L.BeautifyIcon.icon(
#                 {
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;#00ABDC&quot;,
#   &quot;textColor&quot;: &quot;#00ABDC&quot;,
#   &quot;backgroundColor&quot;: &quot;#FFF&quot;,
#   &quot;innerIconStyle&quot;: &quot;margin-top:0;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: true,
#   &quot;text&quot;: 10,
# }
#             )
#             marker_2d547f6377354910eb1e024add901cc4.setIcon(beautify_icon_96dbe2454b52e61f875a80bfa98be646);
#
#
#         var popup_124d3e5a61af7f0c2f109939570e1e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f91038e7727980f5a7049116809ea37a = $(`&lt;div id=&quot;html_f91038e7727980f5a7049116809ea37a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portland, OR&lt;/div&gt;`)[0];
#                 popup_124d3e5a61af7f0c2f109939570e1e7b.setContent(html_f91038e7727980f5a7049116809ea37a);
#
#
#
#         marker_2d547f6377354910eb1e024add901cc4.bindPopup(popup_124d3e5a61af7f0c2f109939570e1e7b)
#         ;
#
#
#
#
#                 marker_2d547f6377354910eb1e024add901cc4.setIcon(beautify_icon_96dbe2454b52e61f875a80bfa98be646);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
