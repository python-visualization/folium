# %%
import folium
import folium.plugins

# %% [markdown]
# # WebGL Earth
#
# Render a 3D interactive globe instead of a flat map, using the
# WebGL Earth v2 library.
#
# Based on: https://www.webglearth.com/
#
# The flat Leaflet map is replaced by a 3D globe. Markers, tile
# layers, and live data updates are all supported.
#
# ## Simple example

# %%
import folium
from folium.plugins import WebGLEarth, WebGLEarthMarker

m = folium.Map()

globe = WebGLEarth(center=[20, 0], zoom=2)
globe.add_to(m)

WebGLEarthMarker(location=[48.8566, 2.3522], popup="Paris").add_to(globe)
WebGLEarthMarker(location=[35.6762, 139.6503], popup="Tokyo").add_to(globe)
WebGLEarthMarker(location=[40.7128, -74.0060], popup="New York").add_to(globe)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24fbe63da97ea926dad54e01780d29ad {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://www.webglearth.com/v2/api.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt;
#                 #map_24fbe63da97ea926dad54e01780d29ad {
#                     display: none !important;
#                 }
#                 #webgl-earth-web_gl_earth_44e6adac6c0f2d41e040e68f804b594a {
#                     height: 600px;
#                     width: 100%;
#                     position: relative;
#                     z-index: 9999;
#                 }
#                 .webgl-earth-reset-btn {
#                     position: absolute;
#                     top: 10px;
#                     right: 10px;
#                     z-index: 10000;
#                     background: white;
#                     border: 1px solid #ccc;
#                     padding: 6px 12px;
#                     border-radius: 4px;
#                     cursor: pointer;
#                     font-size: 13px;
#                 }
#                 .webgl-earth-reset-btn:hover {
#                     background: #f0f0f0;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24fbe63da97ea926dad54e01780d29ad&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div style=&quot;position: relative;&quot;&gt;
#                 &lt;div id=&quot;webgl-earth-web_gl_earth_44e6adac6c0f2d41e040e68f804b594a&quot;&gt;&lt;/div&gt;
#                 &lt;button
#                     class=&quot;webgl-earth-reset-btn&quot;
#                     onclick=&quot;web_gl_earth_44e6adac6c0f2d41e040e68f804b594a.setView(
#                         [20.0, 0.0],
#                         2
#                     )&quot;
#                 &gt;
#                     &amp;#8679; Reset View
#                 &lt;/button&gt;
#             &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24fbe63da97ea926dad54e01780d29ad = L.map(
#                 &quot;map_24fbe63da97ea926dad54e01780d29ad&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38e395e8027532d4f3e1940ceeadebb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38e395e8027532d4f3e1940ceeadebb1.addTo(map_24fbe63da97ea926dad54e01780d29ad);
#
#
#             var web_gl_earth_44e6adac6c0f2d41e040e68f804b594a = WE.map(
#                 &#x27;webgl-earth-web_gl_earth_44e6adac6c0f2d41e040e68f804b594a&#x27;,
#                 {
#   &quot;center&quot;: [
# 20.0,
# 0.0,
# ],
#   &quot;zoom&quot;: 2,
#   &quot;atmosphere&quot;: true,
# }
#             );
#
#             WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#                     attribution: &#x27;&amp;copy; OpenStreetMap contributors&#x27;,
#                     subdomains: [&quot;a&quot;, &quot;b&quot;, &quot;c&quot;]
#                 }
#             ).addTo(web_gl_earth_44e6adac6c0f2d41e040e68f804b594a);
#
#             // Block right-click tilt
#             (function() {
#                 var container = document.getElementById(&#x27;webgl-earth-web_gl_earth_44e6adac6c0f2d41e040e68f804b594a&#x27;);
#                 container.addEventListener(&#x27;contextmenu&#x27;, function(e) {
#                     e.preventDefault();
#                     e.stopPropagation();
#                 });
#                 container.addEventListener(&#x27;mousedown&#x27;, function(e) {
#                     if (e.button === 2) {
#                         e.preventDefault();
#                         e.stopPropagation();
#                     }
#                 });
#             })();
#
#
#             var web_gl_earth_marker_2b94ec1afcdc558137278680517750eb = WE.marker(
#                 [48.8566, 2.3522]
#             ).addTo(web_gl_earth_44e6adac6c0f2d41e040e68f804b594a);
#
#             web_gl_earth_marker_2b94ec1afcdc558137278680517750eb.bindPopup(&quot;Paris&quot;);
#
#
#
#             var web_gl_earth_marker_c61bea403a8990e288c5325d4211dba3 = WE.marker(
#                 [35.6762, 139.6503]
#             ).addTo(web_gl_earth_44e6adac6c0f2d41e040e68f804b594a);
#
#             web_gl_earth_marker_c61bea403a8990e288c5325d4211dba3.bindPopup(&quot;Tokyo&quot;);
#
#
#
#             var web_gl_earth_marker_1d02d386133da23d0656c43064f6223a = WE.marker(
#                 [40.7128, -74.006]
#             ).addTo(web_gl_earth_44e6adac6c0f2d41e040e68f804b594a);
#
#             web_gl_earth_marker_1d02d386133da23d0656c43064f6223a.bindPopup(&quot;New York&quot;);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div><

# %% [markdown]
# ## Custom tile layer
#
# Add an additional tile overlay on top of the default OpenStreetMap tiles.

# %%
import folium
from folium.plugins import WebGLEarth, WebGLEarthTileLayer

m = folium.Map()

globe = WebGLEarth(center=[20, 0], zoom=2)
globe.add_to(m)

WebGLEarthTileLayer(
    url="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
    attribution="© OpenStreetMap contributors",
    opacity=0.5,
).add_to(globe)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1618e458679ed45269fe4135cc84d9f9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://www.webglearth.com/v2/api.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt;
#                 #map_1618e458679ed45269fe4135cc84d9f9 {
#                     display: none !important;
#                 }
#                 #webgl-earth-web_gl_earth_2bf8845f1de538761078d8db91097e78 {
#                     height: 600px;
#                     width: 100%;
#                     position: relative;
#                     z-index: 9999;
#                 }
#                 .webgl-earth-reset-btn {
#                     position: absolute;
#                     top: 10px;
#                     right: 10px;
#                     z-index: 10000;
#                     background: white;
#                     border: 1px solid #ccc;
#                     padding: 6px 12px;
#                     border-radius: 4px;
#                     cursor: pointer;
#                     font-size: 13px;
#                 }
#                 .webgl-earth-reset-btn:hover {
#                     background: #f0f0f0;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1618e458679ed45269fe4135cc84d9f9&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div style=&quot;position: relative;&quot;&gt;
#                 &lt;div id=&quot;webgl-earth-web_gl_earth_2bf8845f1de538761078d8db91097e78&quot;&gt;&lt;/div&gt;
#                 &lt;button
#                     class=&quot;webgl-earth-reset-btn&quot;
#                     onclick=&quot;web_gl_earth_2bf8845f1de538761078d8db91097e78.setView(
#                         [20.0, 0.0],
#                         2
#                     )&quot;
#                 &gt;
#                     &amp;#8679; Reset View
#                 &lt;/button&gt;
#             &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1618e458679ed45269fe4135cc84d9f9 = L.map(
#                 &quot;map_1618e458679ed45269fe4135cc84d9f9&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b827a95e3673d5e9c87c7cc0aa8b2d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b827a95e3673d5e9c87c7cc0aa8b2d5.addTo(map_1618e458679ed45269fe4135cc84d9f9);
#
#
#             var web_gl_earth_2bf8845f1de538761078d8db91097e78 = WE.map(
#                 &#x27;webgl-earth-web_gl_earth_2bf8845f1de538761078d8db91097e78&#x27;,
#                 {
#   &quot;center&quot;: [
# 20.0,
# 0.0,
# ],
#   &quot;zoom&quot;: 2,
#   &quot;atmosphere&quot;: true,
# }
#             );
#
#             WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#                     attribution: &#x27;&amp;copy; OpenStreetMap contributors&#x27;,
#                     subdomains: [&quot;a&quot;, &quot;b&quot;, &quot;c&quot;]
#                 }
#             ).addTo(web_gl_earth_2bf8845f1de538761078d8db91097e78);
#
#             // Block right-click tilt
#             (function() {
#                 var container = document.getElementById(&#x27;webgl-earth-web_gl_earth_2bf8845f1de538761078d8db91097e78&#x27;);
#                 container.addEventListener(&#x27;contextmenu&#x27;, function(e) {
#                     e.preventDefault();
#                     e.stopPropagation();
#                 });
#                 container.addEventListener(&#x27;mousedown&#x27;, function(e) {
#                     if (e.button === 2) {
#                         e.preventDefault();
#                         e.stopPropagation();
#                     }
#                 });
#             })();
#
#
#             var web_gl_earth_tile_layer_d200b0079b9fdef43f44b4a84e1acbfd = WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;attribution&quot;: &quot;\u00a9 OpenStreetMap contributors&quot;,
#   &quot;subdomains&quot;: [
# &quot;a&quot;,
# &quot;b&quot;,
# &quot;c&quot;,
# ],
#   &quot;opacity&quot;: 0.5,
# }
#             ).addTo(web_gl_earth_2bf8845f1de538761078d8db91097e78);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Live ISS tracker
#
# Use `WebGLEarthRealtime` to show live-updating data on the globe.
# In this example we track the International Space Station using a
# public API — the 3D equivalent of the Realtime plugin demo.

# %%
import folium
from folium import JsCode
from folium.plugins import WebGLEarth, WebGLEarthRealtime

m = folium.Map()

globe = WebGLEarth(center=[0, 0], zoom=1.8)
globe.add_to(m)

WebGLEarthRealtime(
    source_url="https://api.wheretheiss.at/v1/satellites/25544",
    interval=3000,
    on_update=JsCode("""
        function(data, earth) {
            if (window._issMarker) window._issMarker.removeFrom(earth);
            window._issMarker = WE.marker(
                [data.latitude, data.longitude]
            ).addTo(earth);
            window._issMarker.bindPopup(
                '<b>ISS</b><br>'
                + 'Lat: ' + data.latitude.toFixed(2)
                + '<br>Lng: ' + data.longitude.toFixed(2)
                + '<br>Alt: ' + data.altitude.toFixed(1) + ' km'
            );
        }
    """),
).add_to(globe)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6eec48bde804181c1632d9a07e5b9b6c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://www.webglearth.com/v2/api.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt;
#                 #map_6eec48bde804181c1632d9a07e5b9b6c {
#                     display: none !important;
#                 }
#                 #webgl-earth-web_gl_earth_ee76a476858986f08777f76eea1587dc {
#                     height: 600px;
#                     width: 100%;
#                     position: relative;
#                     z-index: 9999;
#                 }
#                 .webgl-earth-reset-btn {
#                     position: absolute;
#                     top: 10px;
#                     right: 10px;
#                     z-index: 10000;
#                     background: white;
#                     border: 1px solid #ccc;
#                     padding: 6px 12px;
#                     border-radius: 4px;
#                     cursor: pointer;
#                     font-size: 13px;
#                 }
#                 .webgl-earth-reset-btn:hover {
#                     background: #f0f0f0;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6eec48bde804181c1632d9a07e5b9b6c&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div style=&quot;position: relative;&quot;&gt;
#                 &lt;div id=&quot;webgl-earth-web_gl_earth_ee76a476858986f08777f76eea1587dc&quot;&gt;&lt;/div&gt;
#                 &lt;button
#                     class=&quot;webgl-earth-reset-btn&quot;
#                     onclick=&quot;web_gl_earth_ee76a476858986f08777f76eea1587dc.setView(
#                         [0.0, 0.0],
#                         1.8
#                     )&quot;
#                 &gt;
#                     &amp;#8679; Reset View
#                 &lt;/button&gt;
#             &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6eec48bde804181c1632d9a07e5b9b6c = L.map(
#                 &quot;map_6eec48bde804181c1632d9a07e5b9b6c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8424816331ac4db4aec3eee5152c6260 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8424816331ac4db4aec3eee5152c6260.addTo(map_6eec48bde804181c1632d9a07e5b9b6c);
#
#
#             var web_gl_earth_ee76a476858986f08777f76eea1587dc = WE.map(
#                 &#x27;webgl-earth-web_gl_earth_ee76a476858986f08777f76eea1587dc&#x27;,
#                 {
#   &quot;center&quot;: [
# 0.0,
# 0.0,
# ],
#   &quot;zoom&quot;: 1.8,
#   &quot;atmosphere&quot;: true,
# }
#             );
#
#             WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#                     attribution: &#x27;&amp;copy; OpenStreetMap contributors&#x27;,
#                     subdomains: [&quot;a&quot;, &quot;b&quot;, &quot;c&quot;]
#                 }
#             ).addTo(web_gl_earth_ee76a476858986f08777f76eea1587dc);
#
#             // Block right-click tilt
#             (function() {
#                 var container = document.getElementById(&#x27;webgl-earth-web_gl_earth_ee76a476858986f08777f76eea1587dc&#x27;);
#                 container.addEventListener(&#x27;contextmenu&#x27;, function(e) {
#                     e.preventDefault();
#                     e.stopPropagation();
#                 });
#                 container.addEventListener(&#x27;mousedown&#x27;, function(e) {
#                     if (e.button === 2) {
#                         e.preventDefault();
#                         e.stopPropagation();
#                     }
#                 });
#             })();
#
#
#             (function() {
#                 var earth = web_gl_earth_ee76a476858986f08777f76eea1587dc;
#                 function web_gl_earth_realtime_05060d0783ae726a7a3e2aaa55fc0ad7_update() {
#                     fetch(&quot;https://api.wheretheiss.at/v1/satellites/25544&quot;)
#                         .then(function(response) { return response.json(); })
#                         .then(function(data) {
#                             var callback =
#         function(data, earth) {
#             if (window._issMarker) window._issMarker.removeFrom(earth);
#             window._issMarker = WE.marker(
#                 [data.latitude, data.longitude]
#             ).addTo(earth);
#             window._issMarker.bindPopup(
#                 &#x27;&lt;b&gt;ISS&lt;/b&gt;&lt;br&gt;&#x27;
#                 + &#x27;Lat: &#x27; + data.latitude.toFixed(2)
#                 + &#x27;&lt;br&gt;Lng: &#x27; + data.longitude.toFixed(2)
#                 + &#x27;&lt;br&gt;Alt: &#x27; + data.altitude.toFixed(1) + &#x27; km&#x27;
#             );
#         }
#     ;
#                             callback(data, earth);
#                         })
#                         .catch(functi
