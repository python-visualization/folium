# %%
import folium
import folium.plugins

# %% [markdown]
# # WebGL Earth
#
# Render a 3D interactive globe instead of a flat map, using the
# WebGL Earth v2 library.
#
# Based on: https://www.webglearth.com/
#
# The flat Leaflet map is replaced by a 3D globe. Markers, tile
# layers, and live data updates are all supported.
#
# ## Simple example

# %%
import folium
from folium.plugins import WebGLEarth, WebGLEarthMarker

m = folium.Map()

globe = WebGLEarth(center=[20, 0], zoom=2)
globe.add_to(m)

WebGLEarthMarker(location=[48.8566, 2.3522], popup="Paris").add_to(globe)
WebGLEarthMarker(location=[35.6762, 139.6503], popup="Tokyo").add_to(globe)
WebGLEarthMarker(location=[40.7128, -74.0060], popup="New York").add_to(globe)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47d38c089bb8d3109477eabdc5662f74 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://www.webglearth.com/v2/api.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt;
#                 #map_47d38c089bb8d3109477eabdc5662f74 {
#                     display: none !important;
#                 }
#                 #webgl-earth-web_gl_earth_fbec9fd08e4db497c7d77284e3c81840 {
#                     height: 600px;
#                     width: 100%;
#                     position: relative;
#                     z-index: 9999;
#                 }
#                 .webgl-earth-reset-btn {
#                     position: absolute;
#                     top: 10px;
#                     right: 10px;
#                     z-index: 10000;
#                     background: white;
#                     border: 1px solid #ccc;
#                     padding: 6px 12px;
#                     border-radius: 4px;
#                     cursor: pointer;
#                     font-size: 13px;
#                 }
#                 .webgl-earth-reset-btn:hover {
#                     background: #f0f0f0;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47d38c089bb8d3109477eabdc5662f74&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div style=&quot;position: relative;&quot;&gt;
#                 &lt;div id=&quot;webgl-earth-web_gl_earth_fbec9fd08e4db497c7d77284e3c81840&quot;&gt;&lt;/div&gt;
#                 &lt;button
#                     class=&quot;webgl-earth-reset-btn&quot;
#                     onclick=&quot;web_gl_earth_fbec9fd08e4db497c7d77284e3c81840.setView(
#                         [20.0, 0.0],
#                         2
#                     )&quot;
#                 &gt;
#                     &amp;#8679; Reset View
#                 &lt;/button&gt;
#             &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47d38c089bb8d3109477eabdc5662f74 = L.map(
#                 &quot;map_47d38c089bb8d3109477eabdc5662f74&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b58d356dee167842107bff48dde0cb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b58d356dee167842107bff48dde0cb1.addTo(map_47d38c089bb8d3109477eabdc5662f74);
#
#
#             var web_gl_earth_fbec9fd08e4db497c7d77284e3c81840 = WE.map(
#                 &#x27;webgl-earth-web_gl_earth_fbec9fd08e4db497c7d77284e3c81840&#x27;,
#                 {
#   &quot;center&quot;: [
# 20.0,
# 0.0,
# ],
#   &quot;zoom&quot;: 2,
#   &quot;atmosphere&quot;: true,
# }
#             );
#
#             WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#                     attribution: &#x27;&amp;copy; OpenStreetMap contributors&#x27;,
#                     subdomains: [&quot;a&quot;, &quot;b&quot;, &quot;c&quot;]
#                 }
#             ).addTo(web_gl_earth_fbec9fd08e4db497c7d77284e3c81840);
#
#             // Block right-click tilt
#             (function() {
#                 var container = document.getElementById(&#x27;webgl-earth-web_gl_earth_fbec9fd08e4db497c7d77284e3c81840&#x27;);
#                 container.addEventListener(&#x27;contextmenu&#x27;, function(e) {
#                     e.preventDefault();
#                     e.stopPropagation();
#                 });
#                 container.addEventListener(&#x27;mousedown&#x27;, function(e) {
#                     if (e.button === 2) {
#                         e.preventDefault();
#                         e.stopPropagation();
#                     }
#                 });
#             })();
#
#
#             var web_gl_earth_marker_dd1233c7339b5bc0bc6f7cc2784de19f = WE.marker(
#                 [48.8566, 2.3522]
#             ).addTo(web_gl_earth_fbec9fd08e4db497c7d77284e3c81840);
#
#             web_gl_earth_marker_dd1233c7339b5bc0bc6f7cc2784de19f.bindPopup(&quot;Paris&quot;);
#
#
#
#             var web_gl_earth_marker_43f1cd0e3e589ffeec222be2d53107ec = WE.marker(
#                 [35.6762, 139.6503]
#             ).addTo(web_gl_earth_fbec9fd08e4db497c7d77284e3c81840);
#
#             web_gl_earth_marker_43f1cd0e3e589ffeec222be2d53107ec.bindPopup(&quot;Tokyo&quot;);
#
#
#
#             var web_gl_earth_marker_d3ad0ba3f85750057f24791401380988 = WE.marker(
#                 [40.7128, -74.006]
#             ).addTo(web_gl_earth_fbec9fd08e4db497c7d77284e3c81840);
#
#             web_gl_earth_marker_d3ad0ba3f85750057f24791401380988.bindPopup(&quot;New York&quot;);

# %% [markdown]
# ## Custom tile layer
#
# Add an additional tile overlay on top of the default OpenStreetMap tiles.

# %%
import folium
from folium.plugins import WebGLEarth, WebGLEarthTileLayer

m = folium.Map()

globe = WebGLEarth(center=[20, 0], zoom=2)
globe.add_to(m)

WebGLEarthTileLayer(
    url="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
    attribution="© OpenStreetMap contributors",
    opacity=0.5,
).add_to(globe)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54edaa2575c7a17687309b4f2d51d919 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://www.webglearth.com/v2/api.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt;
#                 #map_54edaa2575c7a17687309b4f2d51d919 {
#                     display: none !important;
#                 }
#                 #webgl-earth-web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b {
#                     height: 600px;
#                     width: 100%;
#                     position: relative;
#                     z-index: 9999;
#                 }
#                 .webgl-earth-reset-btn {
#                     position: absolute;
#                     top: 10px;
#                     right: 10px;
#                     z-index: 10000;
#                     background: white;
#                     border: 1px solid #ccc;
#                     padding: 6px 12px;
#                     border-radius: 4px;
#                     cursor: pointer;
#                     font-size: 13px;
#                 }
#                 .webgl-earth-reset-btn:hover {
#                     background: #f0f0f0;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54edaa2575c7a17687309b4f2d51d919&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div style=&quot;position: relative;&quot;&gt;
#                 &lt;div id=&quot;webgl-earth-web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b&quot;&gt;&lt;/div&gt;
#                 &lt;button
#                     class=&quot;webgl-earth-reset-btn&quot;
#                     onclick=&quot;web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b.setView(
#                         [20.0, 0.0],
#                         2
#                     )&quot;
#                 &gt;
#                     &amp;#8679; Reset View
#                 &lt;/button&gt;
#             &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54edaa2575c7a17687309b4f2d51d919 = L.map(
#                 &quot;map_54edaa2575c7a17687309b4f2d51d919&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8960afd6c8cce80d36c1e08906a33bbd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8960afd6c8cce80d36c1e08906a33bbd.addTo(map_54edaa2575c7a17687309b4f2d51d919);
#
#
#             var web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b = WE.map(
#                 &#x27;webgl-earth-web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b&#x27;,
#                 {
#   &quot;center&quot;: [
# 20.0,
# 0.0,
# ],
#   &quot;zoom&quot;: 2,
#   &quot;atmosphere&quot;: true,
# }
#             );
#
#             WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#                     attribution: &#x27;&amp;copy; OpenStreetMap contributors&#x27;,
#                     subdomains: [&quot;a&quot;, &quot;b&quot;, &quot;c&quot;]
#                 }
#             ).addTo(web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b);
#
#             // Block right-click tilt
#             (function() {
#                 var container = document.getElementById(&#x27;webgl-earth-web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b&#x27;);
#                 container.addEventListener(&#x27;contextmenu&#x27;, function(e) {
#                     e.preventDefault();
#                     e.stopPropagation();
#                 });
#                 container.addEventListener(&#x27;mousedown&#x27;, function(e) {
#                     if (e.button === 2) {
#                         e.preventDefault();
#                         e.stopPropagation();
#                     }
#                 });
#             })();
#
#
#             var web_gl_earth_tile_layer_4556ad08a385edbdd28275e5d480a0fe = WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;attribution&quot;: &quot;\u00a9 OpenStreetMap contributors&quot;,
#   &quot;subdomains&quot;: [
# &quot;a&quot;,
# &quot;b&quot;,
# &quot;c&quot;,
# ],
#   &quot;opacity&quot;: 0.5,
# }
#             ).addTo(web_gl_earth_cc3dffee92b374fbfd9261210a0b1a2b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Live ISS tracker
#
# Use `WebGLEarthRealtime` to show live-updating data on the globe.
# In this example we track the International Space Station using a
# public API — the 3D equivalent of the Realtime plugin demo.

# %%
import folium
from folium import JsCode
from folium.plugins import WebGLEarth, WebGLEarthRealtime

m = folium.Map()

globe = WebGLEarth(center=[0, 0], zoom=1.8)
globe.add_to(m)

WebGLEarthRealtime(
    source_url="https://api.wheretheiss.at/v1/satellites/25544",
    interval=3000,
    on_update=JsCode("""
        function(data, earth) {
            if (window._issMarker) window._issMarker.removeFrom(earth);
            window._issMarker = WE.marker(
                [data.latitude, data.longitude]
            ).addTo(earth);
            window._issMarker.bindPopup(
                '<b>ISS</b><br>'
                + 'Lat: ' + data.latitude.toFixed(2)
                + '<br>Lng: ' + data.longitude.toFixed(2)
                + '<br>Alt: ' + data.altitude.toFixed(1) + ' km'
            );
        }
    """),
).add_to(globe)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_345c1101a06c9ea0b9705b9eba9a8cb2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://www.webglearth.com/v2/api.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt;
#                 #map_345c1101a06c9ea0b9705b9eba9a8cb2 {
#                     display: none !important;
#                 }
#                 #webgl-earth-web_gl_earth_c318b2de727cac73f00b81cf7e72e05e {
#                     height: 600px;
#                     width: 100%;
#                     position: relative;
#                     z-index: 9999;
#                 }
#                 .webgl-earth-reset-btn {
#                     position: absolute;
#                     top: 10px;
#                     right: 10px;
#                     z-index: 10000;
#                     background: white;
#                     border: 1px solid #ccc;
#                     padding: 6px 12px;
#                     border-radius: 4px;
#                     cursor: pointer;
#                     font-size: 13px;
#                 }
#                 .webgl-earth-reset-btn:hover {
#                     background: #f0f0f0;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_345c1101a06c9ea0b9705b9eba9a8cb2&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div style=&quot;position: relative;&quot;&gt;
#                 &lt;div id=&quot;webgl-earth-web_gl_earth_c318b2de727cac73f00b81cf7e72e05e&quot;&gt;&lt;/div&gt;
#                 &lt;button
#                     class=&quot;webgl-earth-reset-btn&quot;
#                     onclick=&quot;web_gl_earth_c318b2de727cac73f00b81cf7e72e05e.setView(
#                         [0.0, 0.0],
#                         1.8
#                     )&quot;
#                 &gt;
#                     &amp;#8679; Reset View
#                 &lt;/button&gt;
#             &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_345c1101a06c9ea0b9705b9eba9a8cb2 = L.map(
#                 &quot;map_345c1101a06c9ea0b9705b9eba9a8cb2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ea8ee77fef8dcaf3fabb81f95fb9c9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ea8ee77fef8dcaf3fabb81f95fb9c9f.addTo(map_345c1101a06c9ea0b9705b9eba9a8cb2);
#
#
#             var web_gl_earth_c318b2de727cac73f00b81cf7e72e05e = WE.map(
#                 &#x27;webgl-earth-web_gl_earth_c318b2de727cac73f00b81cf7e72e05e&#x27;,
#                 {
#   &quot;center&quot;: [
# 0.0,
# 0.0,
# ],
#   &quot;zoom&quot;: 1.8,
#   &quot;atmosphere&quot;: true,
# }
#             );
#
#             WE.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#                     attribution: &#x27;&amp;copy; OpenStreetMap contributors&#x27;,
#                     subdomains: [&quot;a&quot;, &quot;b&quot;, &quot;c&quot;]
#                 }
#             ).addTo(web_gl_earth_c318b2de727cac73f00b81cf7e72e05e);
#
#             // Block right-click tilt
#             (function() {
#                 var container = document.getElementById(&#x27;webgl-earth-web_gl_earth_c318b2de727cac73f00b81cf7e72e05e&#x27;);
#                 container.addEventListener(&#x27;contextmenu&#x27;, function(e) {
#                     e.preventDefault();
#                     e.stopPropagation();
#                 });
#                 container.addEventListener(&#x27;mousedown&#x27;, function(e) {
#                     if (e.button === 2) {
#                         e.preventDefault();
#                         e.stopPropagation();
#                     }
#                 });
#             })();
#
#
#             (function() {
#                 var earth = web_gl_earth_c318b2de727cac73f00b81cf7e72e05e;
#                 function web_gl_earth_realtime_92201f43652d1b0d5ea8f97fd54234b6_update() {
#                     fetch(&quot;https://api.wheretheiss.at/v1/satellites/25544&quot;)
#                         .then(function(response) { return response.json(); })
#                         .then(function(data) {
#                             var callback =
#         function(data, earth) {
#             if (window._issMarker) window._issMarker.removeFrom(earth);
#             window._issMarker = WE.marker(
#                 [data.latitude, data.longitude]
#             ).addTo(earth);
#             window._issMarker.bindPopup(
#                 &#x27;&lt;b&gt;ISS&lt;/b&gt;&lt;br&gt;&#x27;
#                 + &#x27;Lat: &#x27; + data.latitude.toFixed(2)
#                 + &#x27;&lt;br&gt;Lng: &#x27; + data.longitude.toFixed(2)
#                 + &#x27;&l
