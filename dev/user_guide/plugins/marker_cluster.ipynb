# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e41ffc457a77e5dc0f17141c6d231941 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e41ffc457a77e5dc0f17141c6d231941&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e41ffc457a77e5dc0f17141c6d231941 = L.map(
#                 &quot;map_e41ffc457a77e5dc0f17141c6d231941&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34b09f8cb416cde05ffa2ba8c9cefc28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34b09f8cb416cde05ffa2ba8c9cefc28.addTo(map_e41ffc457a77e5dc0f17141c6d231941);
#
#
#             var marker_cluster_3ce995fce5a07bdc1eaa733ff1101d49 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_709680e47e8f424e72c48391b325ab8b = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_3ce995fce5a07bdc1eaa733ff1101d49);
#
#
#             var icon_810374ef46eec849f3ab8a4dedae04f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e9ac085167f54433ad269a9de0ecd145 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72dfcf87ae54add18c84f3928202720b = $(`&lt;div id=&quot;html_72dfcf87ae54add18c84f3928202720b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e9ac085167f54433ad269a9de0ecd145.setContent(html_72dfcf87ae54add18c84f3928202720b);
#
#
#
#         marker_709680e47e8f424e72c48391b325ab8b.bindPopup(popup_e9ac085167f54433ad269a9de0ecd145)
#         ;
#
#
#
#
#                 marker_709680e47e8f424e72c48391b325ab8b.setIcon(icon_810374ef46eec849f3ab8a4dedae04f5);
#
#
#             var marker_8a4616ce1443b46b226be164b1c826df = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_3ce995fce5a07bdc1eaa733ff1101d49);
#
#
#             var icon_f392c66a686d8775718f66f3f24ba607 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e9af23026ba0df5533b27d611ea2e151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ec15d5af11bcd9fcb5e820ab27b9fe9 = $(`&lt;div id=&quot;html_3ec15d5af11bcd9fcb5e820ab27b9fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e9af23026ba0df5533b27d611ea2e151.setContent(html_3ec15d5af11bcd9fcb5e820ab27b9fe9);
#
#
#
#         marker_8a4616ce1443b46b226be164b1c826df.bindPopup(popup_e9af23026ba0df5533b27d611ea2e151)
#         ;
#
#
#
#
#                 marker_8a4616ce1443b46b226be164b1c826df.setIcon(icon_f392c66a686d8775718f66f3f24ba607);
#
#
#             var marker_f4e8d3e5d56b937ceee45d9c31ad8346 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_3ce995fce5a07bdc1eaa733ff1101d49);
#
#
#         var popup_f933f05c0854d6d5d5329222513a5a09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ffa6af0786ea77fbe22dca3c08a9bbd = $(`&lt;div id=&quot;html_4ffa6af0786ea77fbe22dca3c08a9bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_f933f05c0854d6d5d5329222513a5a09.setContent(html_4ffa6af0786ea77fbe22dca3c08a9bbd);
#
#
#
#         marker_f4e8d3e5d56b937ceee45d9c31ad8346.bindPopup(popup_f933f05c0854d6d5d5329222513a5a09)
#         ;
#
#
#
#
#             marker_cluster_3ce995fce5a07bdc1eaa733ff1101d49.addTo(map_e41ffc457a77e5dc0f17141c6d231941);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="pos

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ca7ab0707c9f7850332ff87ffc8bace {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ca7ab0707c9f7850332ff87ffc8bace&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ca7ab0707c9f7850332ff87ffc8bace = L.map(
#                 &quot;map_3ca7ab0707c9f7850332ff87ffc8bace&quot;,
#                 {
#                     center: [-6.78, 3.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34c00f676db2b9e5dec2423d0d97d58a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34c00f676db2b9e5dec2423d0d97d58a.addTo(map_3ca7ab0707c9f7850332ff87ffc8bace);
#
#
#             var marker_cluster_b498657d988ebe9a033abb9066b6a5df = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_b498657d988ebe9a033abb9066b6a5df.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_5f2657ab40020804d68a4d3a202a771c = L.marker(
#                 [67.0, -116.0],
#                 {
# }
#             ).addTo(marker_cluster_b498657d988ebe9a033abb9066b6a5df);
#
#
#         var popup_0a39c1bd04a42aa1a6fee95d25b5feb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4418926c81a50f7c5ec52a16779cf0d = $(`&lt;div id=&quot;html_f4418926c81a50f7c5ec52a16779cf0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-116&lt;br&gt;lat:67&lt;/div&gt;`)[0];
#                 popup_0a39c1bd04a42aa1a6fee95d25b5feb0.setContent(html_f4418926c81a50f7c5ec52a16779cf0d);
#
#
#
#         marker_5f2657ab40020804d68a4d3a202a771c.bindPopup(popup_0a39c1bd04a42aa1a6fee95d25b5feb0)
#         ;
#
#
#
#
#             var marker_d6b882e0de6a06f6e9b87a3cf2db419b = L.marker(
#                 [27.0, -16.0],
#                 {
# }
#             ).addTo(marker_cluster_b498657d988ebe9a033abb9066b6a5df);
#
#
#         var popup_250b11ec8fd392b0aaf114cdca9f8af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66e591c48c21dd7f30f870ae2233a721 = $(`&lt;div id=&quot;html_66e591c48c21dd7f30f870ae2233a721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-16&lt;br&gt;lat:27&lt;/div&gt;`)[0];
#                 popup_250b11ec8fd392b0aaf114cdca9f8af7.setContent(html_66e591c48c21dd7f30f870ae2233a721);
#
#
#
#         marker_d6b882e0de6a06f6e9b87a3cf2db419b.bindPopup(popup_250b11ec8fd392b0aaf114cdca9f8af7)
#         ;
#
#
#
#
#             var marker_0330ebcbe214892d11f35d6f05e751a0 = L.marker(
#                 [4.0, -177.0],
#                 {
# }
#             ).addTo(marker_cluster_b498657d988ebe9a033abb9066b6a5df);
#
#
#         var popup_d711cfdc156c7d3ca4f35a04892a9bc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca6a6987055ec1afca7b831ec8f19bcb = $(`&lt;div id=&quot;html_ca6a6987055ec1afca7b831ec8f19bcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-177&lt;br&gt;lat:4&lt;/div&gt;`)[0];
#                 popup_d711cfdc156c7d3ca4f35a04892a9bc7.setContent(html_ca6a6987055ec1afca7b831ec8f19bcb);
#
#
#
#         marker_0330ebcbe214892d11f35d6f05e751a0.bindPopup(popup_d711cfdc156c7d3ca4f35a04892a9bc7)
#         ;
#
#
#
#
#             var marker_05ec716edf6e973d91466b8a4fb86ff1 = L.marker(
#                 [-30.0, 85.0],
#                 {
# }
#             ).addTo(marker_cluster_b498657d988ebe9a033abb9066b6a5df);
#
#
#         var popup_8476fd84223b5a560b2e50255c8910ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75d9ff084da6c50c2c4dbb907327d00d = $(`&lt;div id=&quot;html_75d9ff084da6c50c2c4dbb907327d00d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:85&lt;br&gt;lat:-30&lt;/div&gt;`)[0];
#                 popup_8476fd84223b5a560b2e50255c8910ee.setContent(html_75d9ff084da6c50c2c4dbb907327d00d)

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_286eb71d6ed93f4a31c8fbd2814a8d34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_286eb71d6ed93f4a31c8fbd2814a8d34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_286eb71d6ed93f4a31c8fbd2814a8d34 = L.map(
#                 &quot;map_286eb71d6ed93f4a31c8fbd2814a8d34&quot;,
#                 {
#                     center: [-6.78, 3.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b41acd826ca99afef062943fc834f08b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b41acd826ca99afef062943fc834f08b.addTo(map_286eb71d6ed93f4a31c8fbd2814a8d34);
#
#
#             var marker_cluster_11c69c95b0f665d7394d1f59c940c395 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_9d6b6f2d268fd20040f90566c48f7976 = L.marker(
#                 [67.0, -116.0],
#                 {
# }
#             ).addTo(marker_cluster_11c69c95b0f665d7394d1f59c940c395);
#
#
#         var popup_da9d556b5f288d421be0dcf47d583696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fedf2c1485b9bc134d2475dc38caa85 = $(`&lt;div id=&quot;html_1fedf2c1485b9bc134d2475dc38caa85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-116&lt;br&gt;lat:67&lt;/div&gt;`)[0];
#                 popup_da9d556b5f288d421be0dcf47d583696.setContent(html_1fedf2c1485b9bc134d2475dc38caa85);
#
#
#
#         marker_9d6b6f2d268fd20040f90566c48f7976.bindPopup(popup_da9d556b5f288d421be0dcf47d583696)
#         ;
#
#
#
#
#             var marker_38dec6bd67a0b3f9060b709a4e72559e = L.marker(
#                 [27.0, -16.0],
#                 {
# }
#             ).addTo(marker_cluster_11c69c95b0f665d7394d1f59c940c395);
#
#
#         var popup_7a3d6b1b9d65e60c1f487696d295af83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d64d41de92d290b1c2a00d04d28eb99 = $(`&lt;div id=&quot;html_5d64d41de92d290b1c2a00d04d28eb99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-16&lt;br&gt;lat:27&lt;/div&gt;`)[0];
#                 popup_7a3d6b1b9d65e60c1f487696d295af83.setContent(html_5d64d41de92d290b1c2a00d04d28eb99);
#
#
#
#         marker_38dec6bd67a0b3f9060b709a4e72559e.bindPopup(popup_7a3d6b1b9d65e60c1f487696d295af83)
#         ;
#
#
#
#
#             var marker_44f8ba887336c5bd9cbdb7628b557bec = L.marker(
#                 [4.0, -177.0],
#                 {
# }
#             ).addTo(marker_cluster_11c69c95b0f665d7394d1f59c940c395);
#
#
#         var popup_3debb84bbf775378e0e3e29d0b2cc944 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c4da60fddddcca2ca4efaa0d40ab713 = $(`&lt;div id=&quot;html_5c4da60fddddcca2ca4efaa0d40ab713&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-177&lt;br&gt;lat:4&lt;/div&gt;`)[0];
#                 popup_3debb84bbf775378e0e3e29d0b2cc944.setContent(html_5c4da60fddddcca2ca4efaa0d40ab713);
#
#
#
#         marker_44f8ba887336c5bd9cbdb7628b557bec.bindPopup(popup_3debb84bbf775378e0e3e29d0b2cc944)
#         ;
#
#
#
#
#             var marker_2338af8ca4f9d26b4616f7d0fa263b36 = L.marker(
#                 [-30.0, 85.0],
#                 {
# }
#             ).addTo(marker_cluster_11c69c95b0f665d7394d1f59c940c395);
#
#
#         var popup_8750eba232c22f2b31a2b6399271f2c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50dd4d98d27f906581b5d778503d2c33 = $(`&lt;div id=&quot;html_50dd4d98d27f906581b5d778503d2c33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:85&lt;br&gt;lat:-30&lt;/div&gt;`)[0];
#                 popup_8750eba232c22f2b31a2b6399271f2c3.setContent(html_50dd4d98d27f906581b5d778503d2c33);
#
#
#
#         marker_2338af8ca4f9d26b4616f7d0fa263b36.bindPopup(popup_8750eba232c22f2b31a2b6399271f2c3)
#         ;
#
#
#
#
#             var marker_b70bbafd94831b359393804ab48cc0e2 = L.marker(
#                 [36.0, -149.0],
#                 {
# }
#             ).addTo(marker_cluster_11c69c95b0f665d7394d1f59c940c395)

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c62e69af6d5c6d5a653ba3329dc3cebb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c62e69af6d5c6d5a653ba3329dc3cebb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c62e69af6d5c6d5a653ba3329dc3cebb = L.map(
#                 &quot;map_c62e69af6d5c6d5a653ba3329dc3cebb&quot;,
#                 {
#                     center: [-6.78, 3.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d2d08ea77d839c0598a5e6f9347ddf3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d2d08ea77d839c0598a5e6f9347ddf3.addTo(map_c62e69af6d5c6d5a653ba3329dc3cebb);
#
#
#             var fast_marker_cluster_19716a14c7420f4e15b57d28382e502d = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[67.0, -116.0], [27.0, -16.0], [4.0, -177.0], [-30.0, 85.0], [36.0, -149.0], [45.0, -37.0], [79.0, 178.0], [-4.0, -137.0], [-77.0, 128.0], [28.0, 1.0], [-87.0, 117.0], [-39.0, -91.0], [-7.0, 74.0], [16.0, -52.0], [-89.0, 64.0], [56.0, 71.0], [-3.0, 110.0], [-32.0, -112.0], [-12.0, -137.0], [-27.0, -144.0], [1.0, -50.0], [-70.0, 53.0], [-44.0, -167.0], [38.0, -35.0], [54.0, 45.0], [-12.0, 62.0], [-77.0, 2.0], [67.0, 126.0], [14.0, 163.0], [3.0, 62.0], [-21.0, 38.0], [-39.0, -162.0], [79.0, -136.0], [-53.0, 116.0], [75.0, 169.0], [-84.0, 178.0], [68.0, -43.0], [-39.0, -53.0], [87.0, -43.0], [-6.0, -165.0], [-30.0, 69.0], [-34.0, 68.0], [54.0, -65.0], [27.0, -113.0], [21.0, 159.0], [-1.0, 28.0], [17.0, 138.0], [68.0, -73.0], [-19.0, 46.0], [-28.0, 43.0], [87.0, 157.0], [-84.0, 149.0], [76.0, 135.0], [-19.0, -76.0], [46.0, 142.0], [28.0, 48.0], [-13.0, -144.0], [77.0, -82.0], [-89.0, -64.0], [50.0, 168.0], [32.0, 74.0], [7.0, -158.0], [-72.0, 120.0], [6.0, 73.0], [-79.0, -35.0], [9.0, -38.0], [-57.0, -66.0], [21.0, -90.0], [-34.0, 162.0], [-10.0, -176.0], [10.0, -62.0], [-13.0, 106.0], [-58.0, -70.0], [-80.0, 49.0], [0.0, 141.0], [-88.0, -146.0], [-8.0, -78.0], [-66.0, -33.0], [-36.0, -167.0], [-3.0, 85.0], [-57.0, -127.0], [60.0, 165.0], [-28.0, -130.0], [-66.0, -3.0], [78.0, -138.0], [-70.0, 36.0], [-17.0, 10.0], [56.0, -85.0], [-75.0, -62.0], [74.0, 65.0], [-80.0, -90.0], [-46.0, 155.0], [77.0, -102.0], [-85.0, 167.0], [61.0, 155.0], [-45.0, 32.0], [-26.0, 87.0], [-86.0, -100.0], [-32.0, -30.0], [-78.0, 122.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_c62e69af6d5c6d5a653ba3329dc3cebb);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_19716a14c7420f4e15b57d28382e502d.addTo(map_c62e69af6d5c6d5a653ba3329dc3cebb);
#
#
#             var layer_control_8c6de8ea80d68db119cc1d5a81123faa_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_9d2d08ea77d839c0598a5e6f9347ddf3,
#                 },
#                 overlays :  {
#                     &quot;macro_element_19716a14c7420f4e15b57d28382e502d&quot; : fast_marker_cluster_19716a14c7420f4e15b57d28382e502d,
#                 },
#             };
#             let layer_control_8c6de8ea80d68db119cc1d5a81123faa = L.control.layers(
#                 layer_control_8c6de8ea80d68db119cc1d5a81123faa_layers.base_layers,
#                 layer_control_8c6de8ea80d68db119cc1d5a81123faa_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c62e69af6d5c6d5a653ba3329dc3cebb);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ea2fb009513dece78ef2eafde6c8125 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ea2fb009513dece78ef2eafde6c8125&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ea2fb009513dece78ef2eafde6c8125 = L.map(
#                 &quot;map_4ea2fb009513dece78ef2eafde6c8125&quot;,
#                 {
#                     center: [-6.78, 3.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ea60d6eb20d6fdfb916b98bd6719aa2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ea60d6eb20d6fdfb916b98bd6719aa2.addTo(map_4ea2fb009513dece78ef2eafde6c8125);
#
#
#             var fast_marker_cluster_eaa2e73467f41dc13ddca1664a44516d = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[67.0, -116.0], [27.0, -16.0], [4.0, -177.0], [-30.0, 85.0], [36.0, -149.0], [45.0, -37.0], [79.0, 178.0], [-4.0, -137.0], [-77.0, 128.0], [28.0, 1.0], [-87.0, 117.0], [-39.0, -91.0], [-7.0, 74.0], [16.0, -52.0], [-89.0, 64.0], [56.0, 71.0], [-3.0, 110.0], [-32.0, -112.0], [-12.0, -137.0], [-27.0, -144.0], [1.0, -50.0], [-70.0, 53.0], [-44.0, -167.0], [38.0, -35.0], [54.0, 45.0], [-12.0, 62.0], [-77.0, 2.0], [67.0, 126.0], [14.0, 163.0], [3.0, 62.0], [-21.0, 38.0], [-39.0, -162.0], [79.0, -136.0], [-53.0, 116.0], [75.0, 169.0], [-84.0, 178.0], [68.0, -43.0], [-39.0, -53.0], [87.0, -43.0], [-6.0, -165.0], [-30.0, 69.0], [-34.0, 68.0], [54.0, -65.0], [27.0, -113.0], [21.0, 159.0], [-1.0, 28.0], [17.0, 138.0], [68.0, -73.0], [-19.0, 46.0], [-28.0, 43.0], [87.0, 157.0], [-84.0, 149.0], [76.0, 135.0], [-19.0, -76.0], [46.0, 142.0], [28.0, 48.0], [-13.0, -144.0], [77.0, -82.0], [-89.0, -64.0], [50.0, 168.0], [32.0, 74.0], [7.0, -158.0], [-72.0, 120.0], [6.0, 73.0], [-79.0, -35.0], [9.0, -38.0], [-57.0, -66.0], [21.0, -90.0], [-34.0, 162.0], [-10.0, -176.0], [10.0, -62.0], [-13.0, 106.0], [-58.0, -70.0], [-80.0, 49.0], [0.0, 141.0], [-88.0, -146.0], [-8.0, -78.0], [-66.0, -33.0], [-36.0, -167.0], [-3.0, 85.0], [-57.0, -127.0], [60.0, 165.0], [-28.0, -130.0], [-66.0, -3.0], [78.0, -138.0], [-70.0, 36.0], [-17.0, 10.0], [56.0, -85.0], [-75.0, -62.0], [74.0, 65.0], [-80.0, -90.0], [-46.0, 155.0], [77.0, -102.0], [-85.0, 167.0], [61.0, 155.0], [-45.0, 32.0], [-26.0, 87.0], [-86.0, -100.0], [-32.0, -30.0], [-78.0, 122.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_4ea2fb009513dece78ef2eafde6c8125);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_eaa2e73467f41dc13ddca1664a44516d.addTo(map_4ea2fb009513dece78ef2eafde6c8125);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
