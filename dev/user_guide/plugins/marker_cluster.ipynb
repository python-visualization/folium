# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ed29e8d96f7f091f54f7a3e357c523b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ed29e8d96f7f091f54f7a3e357c523b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ed29e8d96f7f091f54f7a3e357c523b = L.map(
#                 &quot;map_4ed29e8d96f7f091f54f7a3e357c523b&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78ecb0ebfcf3659a5ae969b02bb1aff3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78ecb0ebfcf3659a5ae969b02bb1aff3.addTo(map_4ed29e8d96f7f091f54f7a3e357c523b);
#
#
#             var marker_cluster_d4b2cc74b5147ddd91ca7320f232f478 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_7cea694bcb2fa2a97489b4af7a85d353 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_d4b2cc74b5147ddd91ca7320f232f478);
#
#
#             var icon_6ca0b8155c2d5268c03be085bc732a94 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_672de2ac44c750043ead24df6d5b7639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9867180f3cb69d10ea614116be62ce0f = $(`&lt;div id=&quot;html_9867180f3cb69d10ea614116be62ce0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_672de2ac44c750043ead24df6d5b7639.setContent(html_9867180f3cb69d10ea614116be62ce0f);
#
#
#
#         marker_7cea694bcb2fa2a97489b4af7a85d353.bindPopup(popup_672de2ac44c750043ead24df6d5b7639)
#         ;
#
#
#
#
#                 marker_7cea694bcb2fa2a97489b4af7a85d353.setIcon(icon_6ca0b8155c2d5268c03be085bc732a94);
#
#
#             var marker_8af8ce721c05236c1ef920942b8c40c6 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_d4b2cc74b5147ddd91ca7320f232f478);
#
#
#             var icon_891433ef0b9517c85691aa7a5f62df74 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ac9f99a8bfc8b11808a79116d4c8e06a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17136be7f40b03453db134ed38dbf9c5 = $(`&lt;div id=&quot;html_17136be7f40b03453db134ed38dbf9c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ac9f99a8bfc8b11808a79116d4c8e06a.setContent(html_17136be7f40b03453db134ed38dbf9c5);
#
#
#
#         marker_8af8ce721c05236c1ef920942b8c40c6.bindPopup(popup_ac9f99a8bfc8b11808a79116d4c8e06a)
#         ;
#
#
#
#
#                 marker_8af8ce721c05236c1ef920942b8c40c6.setIcon(icon_891433ef0b9517c85691aa7a5f62df74);
#
#
#             var marker_227159e19371838dd46b52319bc727d5 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_d4b2cc74b5147ddd91ca7320f232f478);
#
#
#         var popup_6f58e82d6d7edcb35fdf2ec1a78dee70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c53a41511f828fce082884cadafafa8d = $(`&lt;div id=&quot;html_c53a41511f828fce082884cadafafa8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6f58e82d6d7edcb35fdf2ec1a78dee70.setContent(html_c53a41511f828fce082884cadafafa8d);
#
#
#
#         marker_227159e19371838dd46b52319bc727d5.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0466f406e4f2268bc776eaf4fc6b654d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0466f406e4f2268bc776eaf4fc6b654d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0466f406e4f2268bc776eaf4fc6b654d = L.map(
#                 &quot;map_0466f406e4f2268bc776eaf4fc6b654d&quot;,
#                 {
#                     center: [-8.06, -12.06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_680b3333eb01596a9bb12cfb37fb47c8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_680b3333eb01596a9bb12cfb37fb47c8.addTo(map_0466f406e4f2268bc776eaf4fc6b654d);
#
#
#             var marker_cluster_bf7ccff98a13196ec3fcb75dcddf01ff = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_bf7ccff98a13196ec3fcb75dcddf01ff.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_45996375fda6effa460a9dfa10afecf2 = L.marker(
#                 [-20.0, -36.0],
#                 {
# }
#             ).addTo(marker_cluster_bf7ccff98a13196ec3fcb75dcddf01ff);
#
#
#         var popup_6732aa66bd8e13df025a0e14f2a350f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe2247c80fa9d7ebd1035cac770a5455 = $(`&lt;div id=&quot;html_fe2247c80fa9d7ebd1035cac770a5455&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-36&lt;br&gt;lat:-20&lt;/div&gt;`)[0];
#                 popup_6732aa66bd8e13df025a0e14f2a350f9.setContent(html_fe2247c80fa9d7ebd1035cac770a5455);
#
#
#
#         marker_45996375fda6effa460a9dfa10afecf2.bindPopup(popup_6732aa66bd8e13df025a0e14f2a350f9)
#         ;
#
#
#
#
#             var marker_cc6a6cb0fe0fee3e1d1ebfcc03e1554e = L.marker(
#                 [36.0, -143.0],
#                 {
# }
#             ).addTo(marker_cluster_bf7ccff98a13196ec3fcb75dcddf01ff);
#
#
#         var popup_24646661552953f99553a102c7435962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96b770d022865b5c553605405c370265 = $(`&lt;div id=&quot;html_96b770d022865b5c553605405c370265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-143&lt;br&gt;lat:36&lt;/div&gt;`)[0];
#                 popup_24646661552953f99553a102c7435962.setContent(html_96b770d022865b5c553605405c370265);
#
#
#
#         marker_cc6a6cb0fe0fee3e1d1ebfcc03e1554e.bindPopup(popup_24646661552953f99553a102c7435962)
#         ;
#
#
#
#
#             var marker_eca56ec45af56b0c7996788fcf40cc91 = L.marker(
#                 [84.0, -97.0],
#                 {
# }
#             ).addTo(marker_cluster_bf7ccff98a13196ec3fcb75dcddf01ff);
#
#
#         var popup_8d1ffe6a6328f6500c9d22a20e59a50d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5535fb7ea3497f5f708b78af471e053 = $(`&lt;div id=&quot;html_a5535fb7ea3497f5f708b78af471e053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-97&lt;br&gt;lat:84&lt;/div&gt;`)[0];
#                 popup_8d1ffe6a6328f6500c9d22a20e59a50d.setContent(html_a5535fb7ea3497f5f708b78af471e053);
#
#
#
#         marker_eca56ec45af56b0c7996788fcf40cc91.bindPopup(popup_8d1ffe6a6328f6500c9d22a20e59a50d)
#         ;
#
#
#
#
#             var marker_4c15904a04cece8a2af18d4fc6d7318b = L.marker(
#                 [-35.0, 86.0],
#                 {
# }
#             ).addTo(marker_cluster_bf7ccff98a13196ec3fcb75dcddf01ff);
#
#
#         var popup_62a75f6daa382dbc584d37470875ad96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c56d22b34fcfcb1f16db12f9754474f = $(`&lt;div id=&quot;htm

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_809666ada87bec57881a37e73f8f59c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_809666ada87bec57881a37e73f8f59c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_809666ada87bec57881a37e73f8f59c6 = L.map(
#                 &quot;map_809666ada87bec57881a37e73f8f59c6&quot;,
#                 {
#                     center: [-8.06, -12.06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b58c730fac13d4c6548a8d5b0b64c39 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b58c730fac13d4c6548a8d5b0b64c39.addTo(map_809666ada87bec57881a37e73f8f59c6);
#
#
#             var marker_cluster_2dccb81a7578b191d1b2ff10318a8816 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_22eec067890255f5c7524a4be76ed32c = L.marker(
#                 [-20.0, -36.0],
#                 {
# }
#             ).addTo(marker_cluster_2dccb81a7578b191d1b2ff10318a8816);
#
#
#         var popup_872c1db69e2288f508f8ca25a717587d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12ab4cf56b90073e6567d850c9298287 = $(`&lt;div id=&quot;html_12ab4cf56b90073e6567d850c9298287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-36&lt;br&gt;lat:-20&lt;/div&gt;`)[0];
#                 popup_872c1db69e2288f508f8ca25a717587d.setContent(html_12ab4cf56b90073e6567d850c9298287);
#
#
#
#         marker_22eec067890255f5c7524a4be76ed32c.bindPopup(popup_872c1db69e2288f508f8ca25a717587d)
#         ;
#
#
#
#
#             var marker_c8cca6e2741fc14b90bae3988d3963b9 = L.marker(
#                 [36.0, -143.0],
#                 {
# }
#             ).addTo(marker_cluster_2dccb81a7578b191d1b2ff10318a8816);
#
#
#         var popup_fca8b313c8f4131ac8cee5ce370b9a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00065788c9bda8dccbabb80bd7ef7c56 = $(`&lt;div id=&quot;html_00065788c9bda8dccbabb80bd7ef7c56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-143&lt;br&gt;lat:36&lt;/div&gt;`)[0];
#                 popup_fca8b313c8f4131ac8cee5ce370b9a9e.setContent(html_00065788c9bda8dccbabb80bd7ef7c56);
#
#
#
#         marker_c8cca6e2741fc14b90bae3988d3963b9.bindPopup(popup_fca8b313c8f4131ac8cee5ce370b9a9e)
#         ;
#
#
#
#
#             var marker_0f1f8ed92b06e5a33e089af4bab6cfae = L.marker(
#                 [84.0, -97.0],
#                 {
# }
#             ).addTo(marker_cluster_2dccb81a7578b191d1b2ff10318a8816);
#
#
#         var popup_b36b95fae5aba3a296d34cc62fc00f9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bcf69c162648b40fe37f1d06162183b = $(`&lt;div id=&quot;html_5bcf69c162648b40fe37f1d06162183b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-97&lt;br&gt;lat:84&lt;/div&gt;`)[0];
#                 popup_b36b95fae5aba3a296d34cc62fc00f9c.setContent(html_5bcf69c162648b40fe37f1d06162183b);
#
#
#
#         marker_0f1f8ed92b06e5a33e089af4bab6cfae.bindPopup(popup_b36b95fae5aba3a296d34cc62fc00f9c)
#         ;
#
#
#
#
#             var marker_0f266826c2976daca402392950ab636f = L.marker(
#                 [-35.0, 86.0],
#                 {
# }
#             ).addTo(marker_cluster_2dccb81a7578b191d1b2ff10318a8816);
#
#
#         var popup_c38fa890b68b0c4de854174524ae9a7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_884758a0a6567318f5aada9a9795e405 = $(`&lt;div id=&quot;html_884758a0a6567318f5aada9a9795e405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:86&lt;br&gt;lat:-35&lt;/div&gt;`)[0];
#                 popup_c38fa890b68b0c4de854174524ae9a7a.setContent(html_884758a0a6567318f5aada9a9795e405);
#
#
#
#         marker_0f266826c2976daca402392950ab636f.bindPopup(popup_c38fa890b68b0

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3a107efffbc2ffb006b9155d30f645f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3a107efffbc2ffb006b9155d30f645f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3a107efffbc2ffb006b9155d30f645f = L.map(
#                 &quot;map_f3a107efffbc2ffb006b9155d30f645f&quot;,
#                 {
#                     center: [-8.06, -12.06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cba68cde310273e6c7766ee5ede6a038 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cba68cde310273e6c7766ee5ede6a038.addTo(map_f3a107efffbc2ffb006b9155d30f645f);
#
#
#             var fast_marker_cluster_8363ee851908867fee7c5303ec4ea7ed = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-20.0, -36.0], [36.0, -143.0], [84.0, -97.0], [-35.0, 86.0], [-77.0, -110.0], [86.0, -139.0], [-1.0, 167.0], [29.0, 13.0], [-63.0, -154.0], [-49.0, -58.0], [80.0, -111.0], [-56.0, 126.0], [49.0, -133.0], [39.0, -151.0], [-72.0, -145.0], [-58.0, 2.0], [-33.0, 39.0], [-63.0, 149.0], [-18.0, -53.0], [-67.0, 26.0], [-36.0, 105.0], [43.0, -83.0], [-46.0, 32.0], [-88.0, -47.0], [5.0, -154.0], [-25.0, 170.0], [-4.0, 7.0], [-62.0, 11.0], [10.0, 30.0], [32.0, 172.0], [68.0, -38.0], [59.0, -48.0], [-87.0, 120.0], [-75.0, -144.0], [18.0, -177.0], [77.0, -4.0], [81.0, 64.0], [2.0, 108.0], [-15.0, -30.0], [-37.0, 141.0], [22.0, -60.0], [81.0, -15.0], [26.0, 61.0], [-30.0, 124.0], [34.0, 142.0], [-62.0, -8.0], [12.0, 110.0], [-5.0, 139.0], [-6.0, -87.0], [-11.0, 72.0], [-20.0, 94.0], [-19.0, 44.0], [-41.0, 1.0], [-31.0, 137.0], [-72.0, 71.0], [-40.0, 145.0], [72.0, 129.0], [-8.0, -166.0], [-79.0, 35.0], [23.0, 2.0], [-19.0, -98.0], [-62.0, -55.0], [17.0, -6.0], [-54.0, -167.0], [-86.0, 106.0], [-5.0, -28.0], [-47.0, 55.0], [37.0, 85.0], [-6.0, -155.0], [-66.0, -14.0], [-64.0, 41.0], [59.0, -59.0], [48.0, -97.0], [89.0, -120.0], [8.0, -172.0], [-72.0, 5.0], [-54.0, 156.0], [-44.0, 63.0], [0.0, 166.0], [-85.0, -139.0], [58.0, -77.0], [50.0, -176.0], [-58.0, -154.0], [-19.0, -14.0], [-61.0, -151.0], [0.0, -152.0], [-1.0, -171.0], [-7.0, 140.0], [-45.0, 119.0], [85.0, -36.0], [42.0, -96.0], [-66.0, -88.0], [59.0, -30.0], [18.0, -174.0], [-71.0, -140.0], [-5.0, 47.0], [-48.0, 76.0], [31.0, -132.0], [82.0, -73.0], [-1.0, 26.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_f3a107efffbc2ffb006b9155d30f645f);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_8363ee851908867fee7c5303ec4ea7ed.addTo(map_f3a107efffbc2ffb006b9155d30f645f);
#
#
#             var layer_control_440ff80cfc66a07ab8ba35130bb5e396_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_cba68cde310273e6c7766ee5ede6a038,
#                 },
#                 overlays :  {
#                     &quot;macro_element_8363ee851908867fee7c5303ec4ea7ed&quot; : fast_marker_cluster_8363ee851908867fee7c5303ec4ea7ed,
#                 },
#             };
#             let layer_control_440ff80cfc66a07ab8ba35130bb5e396 = L.control.layers(
#                 layer_control_440ff80cfc66a07ab8ba35130bb5e396_layers.base_layers,
#                 layer_control_440ff80cfc66a07ab8ba35130bb5e396_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f3a107efffbc2ffb006b9155d30f645f);
#
#
# &lt;/

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ec68ab58f7f193081e73ed76bc85fa4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ec68ab58f7f193081e73ed76bc85fa4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ec68ab58f7f193081e73ed76bc85fa4 = L.map(
#                 &quot;map_3ec68ab58f7f193081e73ed76bc85fa4&quot;,
#                 {
#                     center: [-8.06, -12.06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3040bf02e485c68f170a0e64dd116f16 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3040bf02e485c68f170a0e64dd116f16.addTo(map_3ec68ab58f7f193081e73ed76bc85fa4);
#
#
#             var fast_marker_cluster_d2698d1f36fbbb19b9cd0d55e94a1922 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-20.0, -36.0], [36.0, -143.0], [84.0, -97.0], [-35.0, 86.0], [-77.0, -110.0], [86.0, -139.0], [-1.0, 167.0], [29.0, 13.0], [-63.0, -154.0], [-49.0, -58.0], [80.0, -111.0], [-56.0, 126.0], [49.0, -133.0], [39.0, -151.0], [-72.0, -145.0], [-58.0, 2.0], [-33.0, 39.0], [-63.0, 149.0], [-18.0, -53.0], [-67.0, 26.0], [-36.0, 105.0], [43.0, -83.0], [-46.0, 32.0], [-88.0, -47.0], [5.0, -154.0], [-25.0, 170.0], [-4.0, 7.0], [-62.0, 11.0], [10.0, 30.0], [32.0, 172.0], [68.0, -38.0], [59.0, -48.0], [-87.0, 120.0], [-75.0, -144.0], [18.0, -177.0], [77.0, -4.0], [81.0, 64.0], [2.0, 108.0], [-15.0, -30.0], [-37.0, 141.0], [22.0, -60.0], [81.0, -15.0], [26.0, 61.0], [-30.0, 124.0], [34.0, 142.0], [-62.0, -8.0], [12.0, 110.0], [-5.0, 139.0], [-6.0, -87.0], [-11.0, 72.0], [-20.0, 94.0], [-19.0, 44.0], [-41.0, 1.0], [-31.0, 137.0], [-72.0, 71.0], [-40.0, 145.0], [72.0, 129.0], [-8.0, -166.0], [-79.0, 35.0], [23.0, 2.0], [-19.0, -98.0], [-62.0, -55.0], [17.0, -6.0], [-54.0, -167.0], [-86.0, 106.0], [-5.0, -28.0], [-47.0, 55.0], [37.0, 85.0], [-6.0, -155.0], [-66.0, -14.0], [-64.0, 41.0], [59.0, -59.0], [48.0, -97.0], [89.0, -120.0], [8.0, -172.0], [-72.0, 5.0], [-54.0, 156.0], [-44.0, 63.0], [0.0, 166.0], [-85.0, -139.0], [58.0, -77.0], [50.0, -176.0], [-58.0, -154.0], [-19.0, -14.0], [-61.0, -151.0], [0.0, -152.0], [-1.0, -171.0], [-7.0, 140.0], [-45.0, 119.0], [85.0, -36.0], [42.0, -96.0], [-66.0, -88.0], [59.0, -30.0], [18.0, -174.0], [-71.0, -140.0], [-5.0, 47.0], [-48.0, 76.0], [31.0, -132.0], [82.0, -73.0], [-1.0, 26.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_3ec68ab58f7f193081e73ed76bc85fa4);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_d2698d1f36fbbb19b9cd0d55e94a1922.addTo(map_3ec68ab58f7f193081e73ed76bc85fa4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
