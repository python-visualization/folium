# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49ea458f489000e6dbd4423b5b92014a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49ea458f489000e6dbd4423b5b92014a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49ea458f489000e6dbd4423b5b92014a = L.map(
#                 &quot;map_49ea458f489000e6dbd4423b5b92014a&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_762c7284549ee9a1e137b968ec638a8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_762c7284549ee9a1e137b968ec638a8c.addTo(map_49ea458f489000e6dbd4423b5b92014a);
#
#
#             var marker_cluster_a5decc0937e728c835352dad1bb966cd = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_e4edb678eaffb7bb0617d99e6e94a74b = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_a5decc0937e728c835352dad1bb966cd);
#
#
#             var icon_d967eb42d6bf1b06d276dbb774c174fd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_571ce062b61fe390674353e8860b97d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5f7a29fedbf457a93267a829e687147 = $(`&lt;div id=&quot;html_f5f7a29fedbf457a93267a829e687147&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_571ce062b61fe390674353e8860b97d8.setContent(html_f5f7a29fedbf457a93267a829e687147);
#
#
#
#         marker_e4edb678eaffb7bb0617d99e6e94a74b.bindPopup(popup_571ce062b61fe390674353e8860b97d8)
#         ;
#
#
#
#
#                 marker_e4edb678eaffb7bb0617d99e6e94a74b.setIcon(icon_d967eb42d6bf1b06d276dbb774c174fd);
#
#
#             var marker_dc1e724d7f38f96c20333ab30c488b0e = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_a5decc0937e728c835352dad1bb966cd);
#
#
#             var icon_8ae911265c9a3e0102f61c458788929c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3d20a5a499833e65c0ffb9313c939a54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_182bc010df200b3e169ae5a6d4cb2c95 = $(`&lt;div id=&quot;html_182bc010df200b3e169ae5a6d4cb2c95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_3d20a5a499833e65c0ffb9313c939a54.setContent(html_182bc010df200b3e169ae5a6d4cb2c95);
#
#
#
#         marker_dc1e724d7f38f96c20333ab30c488b0e.bindPopup(popup_3d20a5a499833e65c0ffb9313c939a54)
#         ;
#
#
#
#
#                 marker_dc1e724d7f38f96c20333ab30c488b0e.setIcon(icon_8ae911265c9a3e0102f61c458788929c);
#
#
#             var marker_02e5673f57e797c764a148a6aad3af0c = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_a5decc0937e728c835352dad1bb966cd);
#
#
#         var popup_7156a6b0dd476d2611a5af978a1bc08b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2712cab99b186d0a26fccc9d24301701 = $(`&lt;div id=&quot;html_2712cab99b186d0a26fccc9d24301701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7156a6b0dd476d2611a5af978a1bc08b.setContent(html_2712cab99b186d0a26fccc9d24301701);
#
#
#
#         marker_02e5673f57e797c764a148a6aad3af0c.bindPopup(popup_7156a6b0dd476d2611a5af978a1bc08b)
#         ;
#
#
#
#
#             marker_cluster_a5decc0937e728c835352dad1bb966cd.addTo(map_49ea458f489000e6dbd4423b5b92014a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="pos

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63f2d62cc4a148892f270c4cf5bc1a60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63f2d62cc4a148892f270c4cf5bc1a60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63f2d62cc4a148892f270c4cf5bc1a60 = L.map(
#                 &quot;map_63f2d62cc4a148892f270c4cf5bc1a60&quot;,
#                 {
#                     center: [-4.7, 0.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b031ff5642be5b0200c66de0e98bfcfc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b031ff5642be5b0200c66de0e98bfcfc.addTo(map_63f2d62cc4a148892f270c4cf5bc1a60);
#
#
#             var marker_cluster_e2d5756fe13abad5663239c283520049 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_e2d5756fe13abad5663239c283520049.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_c4a4cb9eb9bab015a7ad91820f4e8a4f = L.marker(
#                 [-44.0, 121.0],
#                 {
# }
#             ).addTo(marker_cluster_e2d5756fe13abad5663239c283520049);
#
#
#         var popup_3050a70259e6092c393839aef835cbf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed6032a2f874152de8cd20fa0d9f42be = $(`&lt;div id=&quot;html_ed6032a2f874152de8cd20fa0d9f42be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:121&lt;br&gt;lat:-44&lt;/div&gt;`)[0];
#                 popup_3050a70259e6092c393839aef835cbf5.setContent(html_ed6032a2f874152de8cd20fa0d9f42be);
#
#
#
#         marker_c4a4cb9eb9bab015a7ad91820f4e8a4f.bindPopup(popup_3050a70259e6092c393839aef835cbf5)
#         ;
#
#
#
#
#             var marker_9704cefb562fa51285781f9dd969164f = L.marker(
#                 [-6.0, -15.0],
#                 {
# }
#             ).addTo(marker_cluster_e2d5756fe13abad5663239c283520049);
#
#
#         var popup_64e23abc9bc7ccd5369d8df72c2ece93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba830ad10b7fa9ecb67fe229805742ee = $(`&lt;div id=&quot;html_ba830ad10b7fa9ecb67fe229805742ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-15&lt;br&gt;lat:-6&lt;/div&gt;`)[0];
#                 popup_64e23abc9bc7ccd5369d8df72c2ece93.setContent(html_ba830ad10b7fa9ecb67fe229805742ee);
#
#
#
#         marker_9704cefb562fa51285781f9dd969164f.bindPopup(popup_64e23abc9bc7ccd5369d8df72c2ece93)
#         ;
#
#
#
#
#             var marker_4c37dff3430af86ae83cb79622f3a6f6 = L.marker(
#                 [-21.0, 3.0],
#                 {
# }
#             ).addTo(marker_cluster_e2d5756fe13abad5663239c283520049);
#
#
#         var popup_41d5189db756bd56d10947d8a2c82b1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bec3f93064c3b6c8a1b0f5a6e8f76c12 = $(`&lt;div id=&quot;html_bec3f93064c3b6c8a1b0f5a6e8f76c12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:3&lt;br&gt;lat:-21&lt;/div&gt;`)[0];
#                 popup_41d5189db756bd56d10947d8a2c82b1e.setContent(html_bec3f93064c3b6c8a1b0f5a6e8f76c12);
#
#
#
#         marker_4c37dff3430af86ae83cb79622f3a6f6.bindPopup(popup_41d5189db756bd56d10947d8a2c82b1e)
#         ;
#
#
#
#
#             var marker_a0ff318417a1239bc813993d523ffda0 = L.marker(
#                 [34.0, 76.0],
#                 {
# }
#             ).addTo(marker_cluster_e2d5756fe13abad5663239c283520049);
#
#
#         var popup_46f2d89310971fe500bc006e983f2084 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_907472d7706f3317552e56f28d34b469 = $(`&lt;div id=&quot;html_907472d7706f3317552e56f28d34b469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:76&lt;br&gt;lat:34&lt;/div&gt;`)[0];
#                 popup_46f2d89310971fe500bc006e983f2084.setContent(html_907472d7706f3317552e56f28d34b469);

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2194633aaa34db48f88ef4a9539f5fc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2194633aaa34db48f88ef4a9539f5fc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2194633aaa34db48f88ef4a9539f5fc3 = L.map(
#                 &quot;map_2194633aaa34db48f88ef4a9539f5fc3&quot;,
#                 {
#                     center: [-4.7, 0.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4db089cb5b359e9e1e4e140c929e15d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4db089cb5b359e9e1e4e140c929e15d.addTo(map_2194633aaa34db48f88ef4a9539f5fc3);
#
#
#             var marker_cluster_3ea7f381e80df75b56ef81beb1fb5c89 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_a467a66a0ba9a2357be580ceb32f58ae = L.marker(
#                 [-44.0, 121.0],
#                 {
# }
#             ).addTo(marker_cluster_3ea7f381e80df75b56ef81beb1fb5c89);
#
#
#         var popup_faf3362332657e869719c900451f0d6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f6f42401233f18b0e8569187aedb885 = $(`&lt;div id=&quot;html_3f6f42401233f18b0e8569187aedb885&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:121&lt;br&gt;lat:-44&lt;/div&gt;`)[0];
#                 popup_faf3362332657e869719c900451f0d6c.setContent(html_3f6f42401233f18b0e8569187aedb885);
#
#
#
#         marker_a467a66a0ba9a2357be580ceb32f58ae.bindPopup(popup_faf3362332657e869719c900451f0d6c)
#         ;
#
#
#
#
#             var marker_078231fff716547962776b8a85ef8ad8 = L.marker(
#                 [-6.0, -15.0],
#                 {
# }
#             ).addTo(marker_cluster_3ea7f381e80df75b56ef81beb1fb5c89);
#
#
#         var popup_0be04eeaaaa2ef9e9ad1626ffba9fa51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cba23b06efe87e7a7889761becf0e5ad = $(`&lt;div id=&quot;html_cba23b06efe87e7a7889761becf0e5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-15&lt;br&gt;lat:-6&lt;/div&gt;`)[0];
#                 popup_0be04eeaaaa2ef9e9ad1626ffba9fa51.setContent(html_cba23b06efe87e7a7889761becf0e5ad);
#
#
#
#         marker_078231fff716547962776b8a85ef8ad8.bindPopup(popup_0be04eeaaaa2ef9e9ad1626ffba9fa51)
#         ;
#
#
#
#
#             var marker_86de2f928e3108a9b6a3da22513c49c6 = L.marker(
#                 [-21.0, 3.0],
#                 {
# }
#             ).addTo(marker_cluster_3ea7f381e80df75b56ef81beb1fb5c89);
#
#
#         var popup_ef5e4a06c225b8c8342a3b3478e23c4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84932f1167409eed8211927de033c9c6 = $(`&lt;div id=&quot;html_84932f1167409eed8211927de033c9c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:3&lt;br&gt;lat:-21&lt;/div&gt;`)[0];
#                 popup_ef5e4a06c225b8c8342a3b3478e23c4c.setContent(html_84932f1167409eed8211927de033c9c6);
#
#
#
#         marker_86de2f928e3108a9b6a3da22513c49c6.bindPopup(popup_ef5e4a06c225b8c8342a3b3478e23c4c)
#         ;
#
#
#
#
#             var marker_4775fcd3c02fd8e5ef670963752d7b4e = L.marker(
#                 [34.0, 76.0],
#                 {
# }
#             ).addTo(marker_cluster_3ea7f381e80df75b56ef81beb1fb5c89);
#
#
#         var popup_cd5ccb103f21b606e1bbf03f38ed07fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d510bf5c4105627c3ba5468c152ee0c = $(`&lt;div id=&quot;html_8d510bf5c4105627c3ba5468c152ee0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:76&lt;br&gt;lat:34&lt;/div&gt;`)[0];
#                 popup_cd5ccb103f21b606e1bbf03f38ed07fe.setContent(html_8d510bf5c4105627c3ba5468c152ee0c);
#
#
#
#         marker_4775fcd3c02fd8e5ef670963752d7b4e.bindPopup(popup_cd5ccb103f21b606e1bbf03f38ed07fe)
#         ;
#
#
#
#
#             var marker_52fcbce226c0465faddc47d72974df7f = L.marker(
#                 [85.0, 163.0],
#                 {
# }
#             ).addTo(marker_cluster_3ea7f381e80df75b56ef81beb1fb5c89);

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_470b9792718c9491c829b4c43c2ec6e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_470b9792718c9491c829b4c43c2ec6e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map