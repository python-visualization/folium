# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87f35efd30a9aba9a901c0d52550cf5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87f35efd30a9aba9a901c0d52550cf5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87f35efd30a9aba9a901c0d52550cf5a = L.map(
#                 &quot;map_87f35efd30a9aba9a901c0d52550cf5a&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa67cbac28adfa3d829bbc62f41abd3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aa67cbac28adfa3d829bbc62f41abd3e.addTo(map_87f35efd30a9aba9a901c0d52550cf5a);
#
#
#             var marker_cluster_675c2a6d1b3b2d1b940fff3a1a25c5cd = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_c59ae39528d7b708935dacc4a62282fb = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_675c2a6d1b3b2d1b940fff3a1a25c5cd);
#
#
#             var icon_b315bf2c5f686ca75a8ddc35a87b8dc0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c59ae39528d7b708935dacc4a62282fb.setIcon(icon_b315bf2c5f686ca75a8ddc35a87b8dc0);
#
#
#         var popup_96c6ff5423d058906d702106ba277f36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b978bfa02a08bf8f84f696f3702a0c9e = $(`&lt;div id=&quot;html_b978bfa02a08bf8f84f696f3702a0c9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_96c6ff5423d058906d702106ba277f36.setContent(html_b978bfa02a08bf8f84f696f3702a0c9e);
#
#
#
#         marker_c59ae39528d7b708935dacc4a62282fb.bindPopup(popup_96c6ff5423d058906d702106ba277f36)
#         ;
#
#
#
#
#             var marker_a66588daa654406fe9cfb07d441c48da = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_675c2a6d1b3b2d1b940fff3a1a25c5cd);
#
#
#             var icon_6c9112ec6ae957bf4167f9f83b08e513 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a66588daa654406fe9cfb07d441c48da.setIcon(icon_6c9112ec6ae957bf4167f9f83b08e513);
#
#
#         var popup_e3530d7b10195c368fb6bede2da191fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b38bfee7bbb3743b326b11225633d28 = $(`&lt;div id=&quot;html_8b38bfee7bbb3743b326b11225633d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e3530d7b10195c368fb6bede2da191fc.setContent(html_8b38bfee7bbb3743b326b11225633d28);
#
#
#
#         marker_a66588daa654406fe9cfb07d441c48da.bindPopup(popup_e3530d7b10195c368fb6bede2da191fc)
#         ;
#
#
#
#
#             var marker_ab7c6f2e270377664ef63d98d911f40c = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_675c2a6d1b3b2d1b940fff3a1a25c5cd);
#
#
#         var popup_f97efb4658ea6a883e5505f3e0757972 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_131affadd0724d40c2aa90d5a4f6214b = $(`&lt;div id=&quot;html_131affadd0724d40c2aa90d5a4f6214b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_f97efb4658ea6a883e5505f3e0757972.setContent(html_131affadd0724d40c2aa90d5a4f6214b);
#
#
#
#         marker_ab7c6f2e270377664ef63d98d911f40c.bindPopup(popup_f97efb4658ea6a883e5505f3e0757972)
#         ;
#
#
#
#
#             marker_cluster_675c2a6d1b3b2d1b940fff3a1a25c5cd.addTo(map_87f35efd30a9aba9a901c0d52550cf5a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f2cfa42d90e080b6e451eea7cdc32aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f2cfa42d90e080b6e451eea7cdc32aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f2cfa42d90e080b6e451eea7cdc32aa = L.map(
#                 &quot;map_9f2cfa42d90e080b6e451eea7cdc32aa&quot;,
#                 {
#                     center: [-7.91, -9.95],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b6c199faa7805564e4aa898cdb13bd6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1b6c199faa7805564e4aa898cdb13bd6.addTo(map_9f2cfa42d90e080b6e451eea7cdc32aa);
#
#
#             var marker_cluster_dd3ec70f6dd885a2d8d480e5e12256d2 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_dd3ec70f6dd885a2d8d480e5e12256d2.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_ca0d9c00436e09174cc82d4f37ae30f7 = L.marker(
#                 [-81.0, 17.0],
#                 {}
#             ).addTo(marker_cluster_dd3ec70f6dd885a2d8d480e5e12256d2);
#
#
#         var popup_41a23177c39f5849b6036c818e8e9f95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e0a9f22d3807739da670d8562d4722a2 = $(`&lt;div id=&quot;html_e0a9f22d3807739da670d8562d4722a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:17&lt;br&gt;lat:-81&lt;/div&gt;`)[0];
#                 popup_41a23177c39f5849b6036c818e8e9f95.setContent(html_e0a9f22d3807739da670d8562d4722a2);
#
#
#
#         marker_ca0d9c00436e09174cc82d4f37ae30f7.bindPopup(popup_41a23177c39f5849b6036c818e8e9f95)
#         ;
#
#
#
#
#             var marker_5e4f6f8d281899a547e5361a6cd47367 = L.marker(
#                 [67.0, -51.0],
#                 {}
#             ).addTo(marker_cluster_dd3ec70f6dd885a2d8d480e5e12256d2);
#
#
#         var popup_dfdf773f8e4ff7b485e21ea4bf5455f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd40142a35f70d3698976640e692836b = $(`&lt;div id=&quot;html_bd40142a35f70d3698976640e692836b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-51&lt;br&gt;lat:67&lt;/div&gt;`)[0];
#                 popup_dfdf773f8e4ff7b485e21ea4bf5455f9.setContent(html_bd40142a35f70d3698976640e692836b);
#
#
#
#         marker_5e4f6f8d281899a547e5361a6cd47367.bindPopup(popup_dfdf773f8e4ff7b485e21ea4bf5455f9)
#         ;
#
#
#
#
#             var marker_3cb6b388c8d1255060e7824f986402bc = L.marker(
#                 [-70.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_dd3ec70f6dd885a2d8d480e5e12256d2);
#
#
#         var popup_4c546f61084db3819b14cb01f8d46cb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed50e186ff17041441809255fe3216d1 = $(`&lt;div id=&quot;html_ed50e186ff17041441809255fe3216d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_4c546f61084db3819b14cb01f8d46cb2.setContent(html_ed50e186ff17041441809255fe3216d1);
#
#
#
#         marker_3cb6b388c8d1255060e7824f986402bc.bindPopup(popup_4c546f61084db3819b14cb01f8d46cb2)
#         ;
#
#
#
#
#             var marker_e59a97ec484a3b5e8436fd7a9936d8e2 = L.marker(
#                 [-75.0, -69.0],
#                 {}
#             ).addTo(marker_cluster_dd3ec70f6dd885a2d8d480e5e12256d2);
#
#
#         var popup_d5c4b817e0c0537c1ebd9702015d633c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f54a83e5e1395dd92128a0ac22cff67 = $(`&lt;div id=&quot;html_8f54a83e5e1395dd92128a0ac22cff67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-69&lt;br&gt;lat:-75&lt;/div&gt;`)[0];
#                 popup_d5c4b817e0c0537c1ebd9702015d633c.setContent(html_8f54a83e5e1395dd92128a0ac22cff67);
#
#
#
#         marker_e59a97ec484a3b

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_140a7ff180f2acf82490bacf52c4e928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_140a7ff180f2acf82490bacf52c4e928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_140a7ff180f2acf82490bacf52c4e928 = L.map(
#                 &quot;map_140a7ff180f2acf82490bacf52c4e928&quot;,
#                 {
#                     center: [-7.91, -9.95],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d6b250ddfa9458332238a298071ec94 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2d6b250ddfa9458332238a298071ec94.addTo(map_140a7ff180f2acf82490bacf52c4e928);
#
#
#             var marker_cluster_741f95aa5bc9ec5d3392bcb2a3afb007 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_2a4d0d5ceb305392fd3cafc510c634b7 = L.marker(
#                 [-81.0, 17.0],
#                 {}
#             ).addTo(marker_cluster_741f95aa5bc9ec5d3392bcb2a3afb007);
#
#
#         var popup_fd1533b29daf2815fd705a33d799ad1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffbc654aff500249af6813235f5ede66 = $(`&lt;div id=&quot;html_ffbc654aff500249af6813235f5ede66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:17&lt;br&gt;lat:-81&lt;/div&gt;`)[0];
#                 popup_fd1533b29daf2815fd705a33d799ad1f.setContent(html_ffbc654aff500249af6813235f5ede66);
#
#
#
#         marker_2a4d0d5ceb305392fd3cafc510c634b7.bindPopup(popup_fd1533b29daf2815fd705a33d799ad1f)
#         ;
#
#
#
#
#             var marker_bf3c3320ae1c85e71f566d013e0d0cec = L.marker(
#                 [67.0, -51.0],
#                 {}
#             ).addTo(marker_cluster_741f95aa5bc9ec5d3392bcb2a3afb007);
#
#
#         var popup_d7071ea7b5f1bf07b3da7e2dedc45976 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b6e75dadc12e597b2ae7cb23a5767ec = $(`&lt;div id=&quot;html_8b6e75dadc12e597b2ae7cb23a5767ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-51&lt;br&gt;lat:67&lt;/div&gt;`)[0];
#                 popup_d7071ea7b5f1bf07b3da7e2dedc45976.setContent(html_8b6e75dadc12e597b2ae7cb23a5767ec);
#
#
#
#         marker_bf3c3320ae1c85e71f566d013e0d0cec.bindPopup(popup_d7071ea7b5f1bf07b3da7e2dedc45976)
#         ;
#
#
#
#
#             var marker_e8d5d9c85438eb7de4ef6dd36c72b7dc = L.marker(
#                 [-70.0, -76.0],
#                 {}
#             ).addTo(marker_cluster_741f95aa5bc9ec5d3392bcb2a3afb007);
#
#
#         var popup_675f1bd07da50e0a8451b98785e4a54f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48e8b12afa34abad2470db56a342c284 = $(`&lt;div id=&quot;html_48e8b12afa34abad2470db56a342c284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-76&lt;br&gt;lat:-70&lt;/div&gt;`)[0];
#                 popup_675f1bd07da50e0a8451b98785e4a54f.setContent(html_48e8b12afa34abad2470db56a342c284);
#
#
#
#         marker_e8d5d9c85438eb7de4ef6dd36c72b7dc.bindPopup(popup_675f1bd07da50e0a8451b98785e4a54f)
#         ;
#
#
#
#
#             var marker_b7a2008f974fabe00046dfe15a90a4b9 = L.marker(
#                 [-75.0, -69.0],
#                 {}
#             ).addTo(marker_cluster_741f95aa5bc9ec5d3392bcb2a3afb007);
#
#
#         var popup_d1333810d8fb8c793a1ad6dec974007a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b51470d0a0c9af6f208644669a0e755f = $(`&lt;div id=&quot;html_b51470d0a0c9af6f208644669a0e755f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-69&lt;br&gt;lat:-75&lt;/div&gt;`)[0];
#                 popup_d1333810d8fb8c793a1ad6dec974007a.setContent(html_b51470d0a0c9af6f208644669a0e755f);
#
#
#
#         marker_b7a2008f974fabe00046dfe15a90a4b9.bindPopup(popup_d1333810d8fb8c793a1ad6dec974007a)
#         ;
#
#
#
#
#             var marker_846f483a32b0d62ca73fde1499817b30 = L.marker(
#                 [37.0, -155.0],
#                 {}
#             ).addTo(marker_cluster_741f95aa5bc9ec5d3392bcb2a3afb007);
#
#
#         var popup_ba812eed5882d01cc3d53

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95cef65d4496df68bc49c323c52767f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95cef65d4496df68bc49c323c52767f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95cef65d4496df68bc49c323c52767f1 = L.map(
#                 &quot;map_95cef65d4496df68bc49c323c52767f1&quot;,
#                 {
#                     center: [-7.91, -9.95],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6ea6abf4a973f83e4c940edb171a9ad = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d6ea6abf4a973f83e4c940edb171a9ad.addTo(map_95cef65d4496df68bc49c323c52767f1);
#
#
#             var fast_marker_cluster_cf7153a21e3a13ea01f0ff15405041c5 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[