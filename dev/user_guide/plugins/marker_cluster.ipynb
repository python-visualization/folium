# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60c3ade1562f61d1c40bc7a8975ebb78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60c3ade1562f61d1c40bc7a8975ebb78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60c3ade1562f61d1c40bc7a8975ebb78 = L.map(
#                 &quot;map_60c3ade1562f61d1c40bc7a8975ebb78&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f1e3a8c4764e8176582c8e4ef0b3e58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f1e3a8c4764e8176582c8e4ef0b3e58.addTo(map_60c3ade1562f61d1c40bc7a8975ebb78);
#
#
#             var marker_cluster_df0644452e938b7c65024b87623f1fac = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_6b1356fa7be407f754fb6045821535ea = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_df0644452e938b7c65024b87623f1fac);
#
#
#             var icon_59bf0dbc779f8596eef129a68a882031 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d301ee2e777b27ece0032f1c68b6727e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe47b213f2642a10b3fbae17bcff58c8 = $(`&lt;div id=&quot;html_fe47b213f2642a10b3fbae17bcff58c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_d301ee2e777b27ece0032f1c68b6727e.setContent(html_fe47b213f2642a10b3fbae17bcff58c8);
#
#
#
#         marker_6b1356fa7be407f754fb6045821535ea.bindPopup(popup_d301ee2e777b27ece0032f1c68b6727e)
#         ;
#
#
#
#
#                 marker_6b1356fa7be407f754fb6045821535ea.setIcon(icon_59bf0dbc779f8596eef129a68a882031);
#
#
#             var marker_f5c59685928e2eef49cf95c10d77c2b3 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_df0644452e938b7c65024b87623f1fac);
#
#
#             var icon_55b78cfa97c30cdd8e7390d08bdbb87e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3e21f242d3b9401405b65161501a5cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d19962382c9033ff553b55f64bde516c = $(`&lt;div id=&quot;html_d19962382c9033ff553b55f64bde516c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_a3e21f242d3b9401405b65161501a5cf.setContent(html_d19962382c9033ff553b55f64bde516c);
#
#
#
#         marker_f5c59685928e2eef49cf95c10d77c2b3.bindPopup(popup_a3e21f242d3b9401405b65161501a5cf)
#         ;
#
#
#
#
#                 marker_f5c59685928e2eef49cf95c10d77c2b3.setIcon(icon_55b78cfa97c30cdd8e7390d08bdbb87e);
#
#
#             var marker_1bb814c572260401489ab241c1f48bae = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_df0644452e938b7c65024b87623f1fac);
#
#
#         var popup_20c70a402dbdbb8dc475bce7357849d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d1a14112eac15673721405676b58cb3 = $(`&lt;div id=&quot;html_5d1a14112eac15673721405676b58cb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_20c70a402dbdbb8dc475bce7357849d1.setContent(html_5d1a14112eac15673721405676b58cb3);
#
#
#
#         marker_1bb814c572260401489ab241c1f48bae.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1da731092decbd5294dd94baa6f027a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1da731092decbd5294dd94baa6f027a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1da731092decbd5294dd94baa6f027a = L.map(
#                 &quot;map_c1da731092decbd5294dd94baa6f027a&quot;,
#                 {
#                     center: [-11.05, 8.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98fa4eb0e06cc115f8a6f84ebed593fe = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98fa4eb0e06cc115f8a6f84ebed593fe.addTo(map_c1da731092decbd5294dd94baa6f027a);
#
#
#             var marker_cluster_a4cef0f7ce30c2f53cef292258883b93 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_a4cef0f7ce30c2f53cef292258883b93.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_fc629d6be71612fd130d2b5e803f72a5 = L.marker(
#                 [74.0, 45.0],
#                 {
# }
#             ).addTo(marker_cluster_a4cef0f7ce30c2f53cef292258883b93);
#
#
#         var popup_a102d7f8dac463fb6dbad3fb7e66fc87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b410d4a8451bf5e2317b70b409f4ae2 = $(`&lt;div id=&quot;html_2b410d4a8451bf5e2317b70b409f4ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:45&lt;br&gt;lat:74&lt;/div&gt;`)[0];
#                 popup_a102d7f8dac463fb6dbad3fb7e66fc87.setContent(html_2b410d4a8451bf5e2317b70b409f4ae2);
#
#
#
#         marker_fc629d6be71612fd130d2b5e803f72a5.bindPopup(popup_a102d7f8dac463fb6dbad3fb7e66fc87)
#         ;
#
#
#
#
#             var marker_e41f69accd277aebf43a4eed8057ac7a = L.marker(
#                 [-78.0, 42.0],
#                 {
# }
#             ).addTo(marker_cluster_a4cef0f7ce30c2f53cef292258883b93);
#
#
#         var popup_a75ddc0436d469951c07ff45fcd8d841 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49af0fdc1a9fdccbdb4b1c6047e9413c = $(`&lt;div id=&quot;html_49af0fdc1a9fdccbdb4b1c6047e9413c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:42&lt;br&gt;lat:-78&lt;/div&gt;`)[0];
#                 popup_a75ddc0436d469951c07ff45fcd8d841.setContent(html_49af0fdc1a9fdccbdb4b1c6047e9413c);
#
#
#
#         marker_e41f69accd277aebf43a4eed8057ac7a.bindPopup(popup_a75ddc0436d469951c07ff45fcd8d841)
#         ;
#
#
#
#
#             var marker_1fce14ea2b571fae0fdd6faf47c21b19 = L.marker(
#                 [16.0, -129.0],
#                 {
# }
#             ).addTo(marker_cluster_a4cef0f7ce30c2f53cef292258883b93);
#
#
#         var popup_3ca652fb1d18ce1e9a3d0c54768ad642 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_962766123df57e4e8fd35520bcd43e3f = $(`&lt;div id=&quot;html_962766123df57e4e8fd35520bcd43e3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-129&lt;br&gt;lat:16&lt;/div&gt;`)[0];
#                 popup_3ca652fb1d18ce1e9a3d0c54768ad642.setContent(html_962766123df57e4e8fd35520bcd43e3f);
#
#
#
#         marker_1fce14ea2b571fae0fdd6faf47c21b19.bindPopup(popup_3ca652fb1d18ce1e9a3d0c54768ad642)
#         ;
#
#
#
#
#             var marker_eb10aad2ac599d745e6336a4ad23c6b7 = L.marker(
#                 [-58.0, 96.0],
#                 {
# }
#             ).addTo(marker_cluster_a4cef0f7ce30c2f53cef292258883b93);
#
#
#         var popup_0bb692849c1860ae4085e75ce20c2f7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_210141274c36faaaf2b67f3107d6bc33 = $(`&lt;div id=&quot;html_210

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8caeeee004bee67d01cd594abb80bc05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8caeeee004bee67d01cd594abb80bc05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8caeeee004bee67d01cd594abb80bc05 = L.map(
#                 &quot;map_8caeeee004bee67d01cd594abb80bc05&quot;,
#                 {
#                     center: [-11.05, 8.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27bbcd022e62daea70a9f02ef701391f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27bbcd022e62daea70a9f02ef701391f.addTo(map_8caeeee004bee67d01cd594abb80bc05);
#
#
#             var marker_cluster_6699c3104d6493dd394925c8d590c629 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_f0f5cd414e31eb93c6eb62ecc3f9a1aa = L.marker(
#                 [74.0, 45.0],
#                 {
# }
#             ).addTo(marker_cluster_6699c3104d6493dd394925c8d590c629);
#
#
#         var popup_8b454f200d053db0013370a8ad5338e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17c7b95e3f81ae8f701bbc8cd540b6d9 = $(`&lt;div id=&quot;html_17c7b95e3f81ae8f701bbc8cd540b6d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:45&lt;br&gt;lat:74&lt;/div&gt;`)[0];
#                 popup_8b454f200d053db0013370a8ad5338e5.setContent(html_17c7b95e3f81ae8f701bbc8cd540b6d9);
#
#
#
#         marker_f0f5cd414e31eb93c6eb62ecc3f9a1aa.bindPopup(popup_8b454f200d053db0013370a8ad5338e5)
#         ;
#
#
#
#
#             var marker_1f791bfea4a7e888da76262f1c0b5675 = L.marker(
#                 [-78.0, 42.0],
#                 {
# }
#             ).addTo(marker_cluster_6699c3104d6493dd394925c8d590c629);
#
#
#         var popup_e01cf5bd00a8a42989f3960b7a755461 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b003a1f933d7341c2f4a68366055cceb = $(`&lt;div id=&quot;html_b003a1f933d7341c2f4a68366055cceb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:42&lt;br&gt;lat:-78&lt;/div&gt;`)[0];
#                 popup_e01cf5bd00a8a42989f3960b7a755461.setContent(html_b003a1f933d7341c2f4a68366055cceb);
#
#
#
#         marker_1f791bfea4a7e888da76262f1c0b5675.bindPopup(popup_e01cf5bd00a8a42989f3960b7a755461)
#         ;
#
#
#
#
#             var marker_ad672bc5168e246234af47b8372b1ae1 = L.marker(
#                 [16.0, -129.0],
#                 {
# }
#             ).addTo(marker_cluster_6699c3104d6493dd394925c8d590c629);
#
#
#         var popup_d57f95292c75083c4ddecf2d45c352d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0ea8233ecdee4298afdab202742e95a = $(`&lt;div id=&quot;html_f0ea8233ecdee4298afdab202742e95a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-129&lt;br&gt;lat:16&lt;/div&gt;`)[0];
#                 popup_d57f95292c75083c4ddecf2d45c352d4.setContent(html_f0ea8233ecdee4298afdab202742e95a);
#
#
#
#         marker_ad672bc5168e246234af47b8372b1ae1.bindPopup(popup_d57f95292c75083c4ddecf2d45c352d4)
#         ;
#
#
#
#
#             var marker_f2dd49ec9ed3178ac8a46b6367cdbad8 = L.marker(
#                 [-58.0, 96.0],
#                 {
# }
#             ).addTo(marker_cluster_6699c3104d6493dd394925c8d590c629);
#
#
#         var popup_a34e1e6be4758ff6a9b283d30d530da5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd90798f264b199cf22138ec508fbc12 = $(`&lt;div id=&quot;html_dd90798f264b199cf22138ec508fbc12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:96&lt;br&gt;lat:-58&lt;/div&gt;`)[0];
#                 popup_a34e1e6be4758ff6a9b283d30d530da5.setContent(html_dd90798f264b199cf22138ec508fbc12);
#
#
#
#         marker_f2dd49ec9ed3178ac8a46b6367cdbad8.bindPopup(popup_a34e1e6be4758ff6a9

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_209ec6b5c5f04340187f88d411a564a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_209ec6b5c5f04340187f88d411a564a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_209ec6b5c5f04340187f88d411a564a3 = L.map(
#                 &quot;map_209ec6b5c5f04340187f88d411a564a3&quot;,
#                 {
#                     center: [-11.05, 8.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1733bd7b1429cfa462e01a6410cf3adc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1733bd7b1429cfa462e01a6410cf3adc.addTo(map_209ec6b5c5f04340187f88d411a564a3);
#
#
#             var fast_marker_cluster_6534bb62bddfb0ec71f2193637495c15 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[74.0, 45.0], [-78.0, 42.0], [16.0, -129.0], [-58.0, 96.0], [86.0, 53.0], [34.0, -18.0], [-1.0, -35.0], [16.0, 132.0], [-25.0, -2.0], [46.0, 111.0], [19.0, -42.0], [29.0, -91.0], [33.0, 99.0], [71.0, -37.0], [-48.0, -120.0], [-87.0, 32.0], [-77.0, 115.0], [-59.0, 169.0], [58.0, 100.0], [-51.0, -75.0], [-84.0, 29.0], [-80.0, 61.0], [-57.0, 76.0], [-51.0, -144.0], [-22.0, 50.0], [60.0, -117.0], [-75.0, 34.0], [83.0, 128.0], [-82.0, 64.0], [28.0, -109.0], [59.0, 51.0], [-13.0, -125.0], [54.0, 29.0], [-41.0, -73.0], [-52.0, 42.0], [-66.0, 94.0], [-36.0, -5.0], [-8.0, 80.0], [-65.0, 111.0], [-30.0, 60.0], [-15.0, 162.0], [-71.0, -128.0], [10.0, 73.0], [9.0, 146.0], [-61.0, 29.0], [-58.0, -90.0], [66.0, -126.0], [44.0, 108.0], [-73.0, -118.0], [29.0, -120.0], [-44.0, -91.0], [-28.0, 169.0], [-21.0, 104.0], [-11.0, -92.0], [-69.0, 85.0], [-22.0, -9.0], [75.0, -145.0], [-51.0, -133.0], [-68.0, 31.0], [-37.0, 40.0], [-17.0, -98.0], [-40.0, -84.0], [-64.0, -103.0], [-74.0, 24.0], [51.0, -66.0], [30.0, -131.0], [-64.0, 87.0], [67.0, 75.0], [70.0, 59.0], [-22.0, 81.0], [-2.0, -35.0], [-20.0, -49.0], [54.0, 96.0], [10.0, 165.0], [26.0, 97.0], [-65.0, -145.0], [63.0, 38.0], [-88.0, 117.0], [-53.0, -79.0], [-69.0, -49.0], [-90.0, 126.0], [33.0, -117.0], [-74.0, -167.0], [44.0, 42.0], [72.0, 143.0], [86.0, -25.0], [-40.0, 102.0], [-1.0, 137.0], [-40.0, -104.0], [3.0, -132.0], [-8.0, -113.0], [-26.0, 118.0], [-69.0, 143.0], [57.0, -78.0], [-20.0, 176.0], [63.0, -94.0], [-34.0, 170.0], [-34.0, -42.0], [19.0, 8.0], [37.0, -134.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_209ec6b5c5f04340187f88d411a564a3);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_6534bb62bddfb0ec71f2193637495c15.addTo(map_209ec6b5c5f04340187f88d411a564a3);
#
#
#             var layer_control_50cd36fb28a28a0602f4efc84ba38eaf_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_1733bd7b1429cfa462e01a6410cf3adc,
#                 },
#                 overlays :  {
#                     &quot;macro_element_6534bb62bddfb0ec71f2193637495c15&quot; : fast_marker_cluster_6534bb62bddfb0ec71f2193637495c15,
#                 },
#             };
#             let layer_control_50cd36fb28a28a0602f4efc84ba38eaf = L.control.layers(
#                 layer_control_50cd36fb28a28a0602f4efc84ba38eaf_layers.base_layers,
#                 layer_control_50cd36fb28a28a0602f4efc84ba38eaf_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_209ec6b5c5f04340187f88d411a564a3);
#
#
# &lt

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfcded03651de72c668fe198c57c7bd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfcded03651de72c668fe198c57c7bd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfcded03651de72c668fe198c57c7bd1 = L.map(
#                 &quot;map_cfcded03651de72c668fe198c57c7bd1&quot;,
#                 {
#                     center: [-11.05, 8.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffd8a5e1925b7a05e325009fee3248e1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ffd8a5e1925b7a05e325009fee3248e1.addTo(map_cfcded03651de72c668fe198c57c7bd1);
#
#
#             var fast_marker_cluster_2fa620f5cf612d2cf0334fb5ea8e4a88 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[74.0, 45.0], [-78.0, 42.0], [16.0, -129.0], [-58.0, 96.0], [86.0, 53.0], [34.0, -18.0], [-1.0, -35.0], [16.0, 132.0], [-25.0, -2.0], [46.0, 111.0], [19.0, -42.0], [29.0, -91.0], [33.0, 99.0], [71.0, -37.0], [-48.0, -120.0], [-87.0, 32.0], [-77.0, 115.0], [-59.0, 169.0], [58.0, 100.0], [-51.0, -75.0], [-84.0, 29.0], [-80.0, 61.0], [-57.0, 76.0], [-51.0, -144.0], [-22.0, 50.0], [60.0, -117.0], [-75.0, 34.0], [83.0, 128.0], [-82.0, 64.0], [28.0, -109.0], [59.0, 51.0], [-13.0, -125.0], [54.0, 29.0], [-41.0, -73.0], [-52.0, 42.0], [-66.0, 94.0], [-36.0, -5.0], [-8.0, 80.0], [-65.0, 111.0], [-30.0, 60.0], [-15.0, 162.0], [-71.0, -128.0], [10.0, 73.0], [9.0, 146.0], [-61.0, 29.0], [-58.0, -90.0], [66.0, -126.0], [44.0, 108.0], [-73.0, -118.0], [29.0, -120.0], [-44.0, -91.0], [-28.0, 169.0], [-21.0, 104.0], [-11.0, -92.0], [-69.0, 85.0], [-22.0, -9.0], [75.0, -145.0], [-51.0, -133.0], [-68.0, 31.0], [-37.0, 40.0], [-17.0, -98.0], [-40.0, -84.0], [-64.0, -103.0], [-74.0, 24.0], [51.0, -66.0], [30.0, -131.0], [-64.0, 87.0], [67.0, 75.0], [70.0, 59.0], [-22.0, 81.0], [-2.0, -35.0], [-20.0, -49.0], [54.0, 96.0], [10.0, 165.0], [26.0, 97.0], [-65.0, -145.0], [63.0, 38.0], [-88.0, 117.0], [-53.0, -79.0], [-69.0, -49.0], [-90.0, 126.0], [33.0, -117.0], [-74.0, -167.0], [44.0, 42.0], [72.0, 143.0], [86.0, -25.0], [-40.0, 102.0], [-1.0, 137.0], [-40.0, -104.0], [3.0, -132.0], [-8.0, -113.0], [-26.0, 118.0], [-69.0, 143.0], [57.0, -78.0], [-20.0, 176.0], [63.0, -94.0], [-34.0, 170.0], [-34.0, -42.0], [19.0, 8.0], [37.0, -134.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_cfcded03651de72c668fe198c57c7bd1);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_2fa620f5cf612d2cf0334fb5ea8e4a88.addTo(map_cfcded03651de72c668fe198c57c7bd1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
