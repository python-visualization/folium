# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d28d3ea449219b8cfe0dcbe5a8634a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#
#
#
#
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d28d3ea449219b8cfe0dcbe5a8634a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d28d3ea449219b8cfe0dcbe5a8634a4 = L.map(
#                 &quot;map_9d28d3ea449219b8cfe0dcbe5a8634a4&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_549c369adae72be8ee58ee51fbe41c11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_549c369adae72be8ee58ee51fbe41c11.addTo(map_9d28d3ea449219b8cfe0dcbe5a8634a4);
#
#
#             var marker_cluster_38e9d1cc434e0d46cc5c2c45b34bb324 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_a0edc41def98b9ea833d669b7a966f48 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_38e9d1cc434e0d46cc5c2c45b34bb324);
#
#
#             var icon_688998f33f40ab1553b0d4668e3df6c9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9e4c6e32b4d9aa60fe5072b480177eea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a392c666b008789566af5925411a889 = $(`&lt;div id=&quot;html_4a392c666b008789566af5925411a889&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_9e4c6e32b4d9aa60fe5072b480177eea.setContent(html_4a392c666b008789566af5925411a889);
#
#
#
#         marker_a0edc41def98b9ea833d669b7a966f48.bindPopup(popup_9e4c6e32b4d9aa60fe5072b480177eea)
#         ;
#
#
#
#
#                 marker_a0edc41def98b9ea833d669b7a966f48.setIcon(icon_688998f33f40ab1553b0d4668e3df6c9);
#
#
#             var marker_2e8f96aa189e933ac2e8b1b62301a7c1 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_38e9d1cc434e0d46cc5c2c45b34bb324);
#
#
#             var icon_08b0d7c505e3e51b6ee32b8dc3e7fe43 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c28f66ed45e0395622a8bc03d8c5fd4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_088115afeeb56a609a021f7fe350ff94 = $(`&lt;div id=&quot;html_088115afeeb56a609a021f7fe350ff94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c28f66ed45e0395622a8bc03d8c5fd4a.setContent(html_088115afeeb56a609a021f7fe350ff94);
#
#
#
#         marker_2e8f96aa189e933ac2e8b1b62301a7c1.bindPopup(popup_c28f66ed45e0395622a8bc03d8c5fd4a)
#         ;
#
#
#
#
#                 marker_2e8f96aa189e933ac2e8b1b62301a7c1.setIcon(icon_08b0d7c505e3e51b6ee32b8dc3e7fe43);
#
#
#             var marker_4636acb3c6c7ac382790622ccfca139d = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_38e9d1cc434e0d46cc5c2c45b34bb324);
#
#
#         var popup_54504b617ea76f1c9198e020f19198d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f761e1b9c227f8d01ec487a27287a67 = $(`&lt;div id=&quot;html_8f761e1b9c227f8d01ec487a27287a67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_54504b617ea76f1c9198e020f19198d2.setContent(html_8f761e1b9c227f8d01ec487a27287a67);

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14a9e90962473c4709d8e8e41fc559b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14a9e90962473c4709d8e8e41fc559b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14a9e90962473c4709d8e8e41fc559b0 = L.map(
#                 &quot;map_14a9e90962473c4709d8e8e41fc559b0&quot;,
#                 {
#                     center: [8.19, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d21a23c07e7ead21246388cacf835e1c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d21a23c07e7ead21246388cacf835e1c.addTo(map_14a9e90962473c4709d8e8e41fc559b0);
#
#
#             var marker_cluster_2e8ed25f0ade2436445d22023128937b = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_2e8ed25f0ade2436445d22023128937b.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_c5841c2ad0b686f165a2edc47b85bd5c = L.marker(
#                 [-5.0, -153.0],
#                 {
# }
#             ).addTo(marker_cluster_2e8ed25f0ade2436445d22023128937b);
#
#
#         var popup_7b4dbabaa3453fec90d0d4226129b429 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcff71fa96216292caaf355888b7164b = $(`&lt;div id=&quot;html_dcff71fa96216292caaf355888b7164b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-153&lt;br&gt;lat:-5&lt;/div&gt;`)[0];
#                 popup_7b4dbabaa3453fec90d0d4226129b429.setContent(html_dcff71fa96216292caaf355888b7164b);
#
#
#
#         marker_c5841c2ad0b686f165a2edc47b85bd5c.bindPopup(popup_7b4dbabaa3453fec90d0d4226129b429)
#         ;
#
#
#
#
#             var marker_6b9db7269e4ee8640b7ef7d52db06a3b = L.marker(
#                 [89.0, -153.0],
#                 {
# }
#             ).addTo(marker_cluster_2e8ed25f0ade2436445d22023128937b);
#
#
#         var popup_d95bb79ccf467f899fa87ef8000b4918 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed01c50cd8ce457cbb42fb0e766a638a = $(`&lt;div id=&quot;html_ed01c50cd8ce457cbb42fb0e766a638a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-153&lt;br&gt;lat:89&lt;/div&gt;`)[0];
#                 popup_d95bb79ccf467f899fa87ef8000b4918.setContent(html_ed01c50cd8ce457cbb42fb0e766a638a);
#
#
#
#         marker_6b9db7269e4ee8640b7ef7d52db06a3b.bindPopup(popup_d95bb79ccf467f899fa87ef8000b4918)
#         ;
#
#
#
#
#             var marker_8b762e5e67b1b86caf898050933187c7 = L.marker(
#                 [-43.0, 107.0],
#                 {
# }
#             ).addTo(marker_cluster_2e8ed25f0ade2436445d22023128937b);
#
#
#         var popup_6da737cb41d4cb2b3b866113c802a58b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_089cde8269d8667c9f98b6245968bc49 = $(`&lt;div id=&quot;html_089cde8269d8667c9f98b6245968bc49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:107&lt;br&gt;lat:-43&lt;/div&gt;`)[0];
#                 popup_6da737cb41d4cb2b3b866113c802a58b.setContent(html_089cde8269d8667c9f98b6245968bc49);
#
#
#
#         marker_8b762e5e67b1b86caf898050933187c7.bindPopup(popup_6da737cb41d4cb2b3b866113c802a58b)
#         ;
#
#
#
#
#             var marker_e3ba9835f5c52094f1a1e78ef2d89489 = L.marker(
#                 [25.0, 51.0],
#                 {
# }
#             ).addTo(marker_cluster_2e8ed25f0ade2436445d22023128937b);
#
#
#         var popup_79cf4de508ac01d8823500d431f2952e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e893e9a3a468a1f4a4eeb62f3729a68 = $(`&lt;div id=&quot;html_5

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a5c76b4b13123e8163c46846a27cccf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a5c76b4b13123e8163c46846a27cccf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a5c76b4b13123e8163c46846a27cccf = L.map(
#                 &quot;map_9a5c76b4b13123e8163c46846a27cccf&quot;,
#                 {
#                     center: [8.19, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_743f4cadf0534e4d6c9693307fef0700 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_743f4cadf0534e4d6c9693307fef0700.addTo(map_9a5c76b4b13123e8163c46846a27cccf);
#
#
#             var marker_cluster_3163c3ee3f958e77b7d25332ed974056 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_d66b4c06f1821a3acfde78a8e8ff743e = L.marker(
#                 [-5.0, -153.0],
#                 {
# }
#             ).addTo(marker_cluster_3163c3ee3f958e77b7d25332ed974056);
#
#
#         var popup_d3c04810790efc6d75d3b9e50b9fb054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807a05ff93845b8ed4d42a9aa2accda4 = $(`&lt;div id=&quot;html_807a05ff93845b8ed4d42a9aa2accda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-153&lt;br&gt;lat:-5&lt;/div&gt;`)[0];
#                 popup_d3c04810790efc6d75d3b9e50b9fb054.setContent(html_807a05ff93845b8ed4d42a9aa2accda4);
#
#
#
#         marker_d66b4c06f1821a3acfde78a8e8ff743e.bindPopup(popup_d3c04810790efc6d75d3b9e50b9fb054)
#         ;
#
#
#
#
#             var marker_a4dbf17f6bc92e90cc9f95e5280963e9 = L.marker(
#                 [89.0, -153.0],
#                 {
# }
#             ).addTo(marker_cluster_3163c3ee3f958e77b7d25332ed974056);
#
#
#         var popup_58e21da1f8052b9a2ee4fddaa21470b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_145e51c7ab41db12412e38084d992fd8 = $(`&lt;div id=&quot;html_145e51c7ab41db12412e38084d992fd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-153&lt;br&gt;lat:89&lt;/div&gt;`)[0];
#                 popup_58e21da1f8052b9a2ee4fddaa21470b2.setContent(html_145e51c7ab41db12412e38084d992fd8);
#
#
#
#         marker_a4dbf17f6bc92e90cc9f95e5280963e9.bindPopup(popup_58e21da1f8052b9a2ee4fddaa21470b2)
#         ;
#
#
#
#
#             var marker_8c4c5a1ae08bf0f91d03be6bb50d469d = L.marker(
#                 [-43.0, 107.0],
#                 {
# }
#             ).addTo(marker_cluster_3163c3ee3f958e77b7d25332ed974056);
#
#
#         var popup_dd0faf1383f2bc361fcf77f873afb7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea5286912bc3aff2a373d2d451061049 = $(`&lt;div id=&quot;html_ea5286912bc3aff2a373d2d451061049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:107&lt;br&gt;lat:-43&lt;/div&gt;`)[0];
#                 popup_dd0faf1383f2bc361fcf77f873afb7fb.setContent(html_ea5286912bc3aff2a373d2d451061049);
#
#
#
#         marker_8c4c5a1ae08bf0f91d03be6bb50d469d.bindPopup(popup_dd0faf1383f2bc361fcf77f873afb7fb)
#         ;
#
#
#
#
#             var marker_9a9e417882c168ef0ce3599f83baec9c = L.marker(
#                 [25.0, 51.0],
#                 {
# }
#             ).addTo(marker_cluster_3163c3ee3f958e77b7d25332ed974056);
#
#
#         var popup_dc9bfd1b5777453e4db85b33dc5532c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25cb92ffb91e6154f55b58e30047b3d4 = $(`&lt;div id=&quot;html_25cb92ffb91e6154f55b58e30047b3d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:51&lt;br&gt;lat:25&lt;/div&gt;`)[0];
#                 popup_dc9bfd1b5777453e4db85b33dc5532c3.setContent(html_25cb92ffb91e6154f55b58e30047b3d4);
#
#
#
#         marker_9a9e417882c168ef0ce3599f83baec9c.bindPopup(popup_dc9bfd1b5777453e4

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f719fd86611246c5b4998220038a675 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f719fd86611246c5b4998220038a675&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f719fd86611246c5b4998220038a675 = L.map(
#                 &quot;map_7f719fd86611246c5b4998220038a675&quot;,
#                 {
#                     center: [8.19, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aedb409db3079bfe450d849cfcbb63ae = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aedb409db3079bfe450d849cfcbb63ae.addTo(map_7f719fd86611246c5b4998220038a675);
#
#
#             var fast_marker_cluster_e58ba3fc533b50df951b32ad6cae4713 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-5.0, -153.0], [89.0, -153.0], [-43.0, 107.0], [25.0, 51.0], [33.0, 47.0], [-78.0, -9.0], [36.0, -100.0], [77.0, 91.0], [27.0, -20.0], [13.0, -102.0], [74.0, 41.0], [35.0, -118.0], [76.0, 72.0], [1.0, -133.0], [-31.0, 118.0], [67.0, 92.0], [-85.0, -175.0], [70.0, -44.0], [64.0, 65.0], [67.0, 120.0], [75.0, -42.0], [86.0, -76.0], [-25.0, 16.0], [14.0, 66.0], [60.0, -65.0], [-25.0, 11.0], [58.0, -33.0], [-54.0, 70.0], [1.0, -177.0], [85.0, 72.0], [30.0, 64.0], [-89.0, 108.0], [38.0, 149.0], [-46.0, -41.0], [76.0, -25.0], [1.0, 47.0], [-4.0, -38.0], [16.0, 149.0], [17.0, -114.0], [-72.0, -26.0], [86.0, 75.0], [63.0, -4.0], [-9.0, -165.0], [-50.0, 71.0], [-28.0, 116.0], [-3.0, -119.0], [77.0, 128.0], [51.0, -111.0], [3.0, 49.0], [23.0, 52.0], [-29.0, 36.0], [73.0, 0.0], [-16.0, 91.0], [-48.0, 60.0], [20.0, -17.0], [-67.0, -164.0], [39.0, 109.0], [-62.0, 136.0], [12.0, -169.0], [-24.0, -11.0], [-74.0, 69.0], [33.0, 40.0], [10.0, 82.0], [-42.0, 44.0], [48.0, -61.0], [-85.0, -91.0], [79.0, -153.0], [25.0, 165.0], [25.0, -158.0], [-24.0, 72.0], [-57.0, -104.0], [-54.0, 113.0], [-81.0, -115.0], [-84.0, 69.0], [-64.0, -130.0], [71.0, 97.0], [63.0, 102.0], [20.0, 139.0], [-71.0, 95.0], [-51.0, 41.0], [73.0, 121.0], [58.0, 155.0], [76.0, -101.0], [13.0, 40.0], [39.0, 110.0], [-37.0, 112.0], [29.0, -171.0], [-68.0, -40.0], [18.0, -48.0], [43.0, -20.0], [31.0, -151.0], [89.0, -156.0], [49.0, 42.0], [66.0, 24.0], [-26.0, -145.0], [-90.0, 24.0], [-52.0, 80.0], [19.0, 32.0], [-40.0, 96.0], [-23.0, -95.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_7f719fd86611246c5b4998220038a675);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_e58ba3fc533b50df951b32ad6cae4713.addTo(map_7f719fd86611246c5b4998220038a675);
#
#
#             var layer_control_1d058c9077198507ea4c7a662ccc2017_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_aedb409db3079bfe450d849cfcbb63ae,
#                 },
#                 overlays :  {
#                     &quot;macro_element_e58ba3fc533b50df951b32ad6cae4713&quot; : fast_marker_cluster_e58ba3fc533b50df951b32ad6cae4713,
#                 },
#             };
#             let layer_control_1d058c9077198507ea4c7a662ccc2017 = L.control.layers(
#                 layer_control_1d058c9077198507ea4c7a662ccc2017_layers.base_layers,
#                 layer_control_1d058c9077198507ea4c7a662ccc2017_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_7f719fd86611246c5b4998220038a675);
#
#
# &lt;/script&gt;
# &lt;/html&gt;

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a15366360dedaa7e5691ffd21d767413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a15366360dedaa7e5691ffd21d767413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a15366360dedaa7e5691ffd21d767413 = L.map(
#                 &quot;map_a15366360dedaa7e5691ffd21d767413&quot;,
#                 {
#                     center: [8.19, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9df4e5a75748e2c5365b6a38681bfdf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9df4e5a75748e2c5365b6a38681bfdf.addTo(map_a15366360dedaa7e5691ffd21d767413);
#
#
#             var fast_marker_cluster_e0740dfbeb42f3ca42f5707b2d6c4ee1 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-5.0, -153.0], [89.0, -153.0], [-43.0, 107.0], [25.0, 51.0], [33.0, 47.0], [-78.0, -9.0], [36.0, -100.0], [77.0, 91.0], [27.0, -20.0], [13.0, -102.0], [74.0, 41.0], [35.0, -118.0], [76.0, 72.0], [1.0, -133.0], [-31.0, 118.0], [67.0, 92.0], [-85.0, -175.0], [70.0, -44.0], [64.0, 65.0], [67.0, 120.0], [75.0, -42.0], [86.0, -76.0], [-25.0, 16.0], [14.0, 66.0], [60.0, -65.0], [-25.0, 11.0], [58.0, -33.0], [-54.0, 70.0], [1.0, -177.0], [85.0, 72.0], [30.0, 64.0], [-89.0, 108.0], [38.0, 149.0], [-46.0, -41.0], [76.0, -25.0], [1.0, 47.0], [-4.0, -38.0], [16.0, 149.0], [17.0, -114.0], [-72.0, -26.0], [86.0, 75.0], [63.0, -4.0], [-9.0, -165.0], [-50.0, 71.0], [-28.0, 116.0], [-3.0, -119.0], [77.0, 128.0], [51.0, -111.0], [3.0, 49.0], [23.0, 52.0], [-29.0, 36.0], [73.0, 0.0], [-16.0, 91.0], [-48.0, 60.0], [20.0, -17.0], [-67.0, -164.0], [39.0, 109.0], [-62.0, 136.0], [12.0, -169.0], [-24.0, -11.0], [-74.0, 69.0], [33.0, 40.0], [10.0, 82.0], [-42.0, 44.0], [48.0, -61.0], [-85.0, -91.0], [79.0, -153.0], [25.0, 165.0], [25.0, -158.0], [-24.0, 72.0], [-57.0, -104.0], [-54.0, 113.0], [-81.0, -115.0], [-84.0, 69.0], [-64.0, -130.0], [71.0, 97.0], [63.0, 102.0], [20.0, 139.0], [-71.0, 95.0], [-51.0, 41.0], [73.0, 121.0], [58.0, 155.0], [76.0, -101.0], [13.0, 40.0], [39.0, 110.0], [-37.0, 112.0], [29.0, -171.0], [-68.0, -40.0], [18.0, -48.0], [43.0, -20.0], [31.0, -151.0], [89.0, -156.0], [49.0, 42.0], [66.0, 24.0], [-26.0, -145.0], [-90.0, 24.0], [-52.0, 80.0], [19.0, 32.0], [-40.0, 96.0], [-23.0, -95.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_a15366360dedaa7e5691ffd21d767413);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_e0740dfbeb42f3ca42f5707b2d6c4ee1.addTo(map_a15366360dedaa7e5691ffd21d767413);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
