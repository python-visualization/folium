# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92f93b2aaf627e14d183d7c1f7e19b9d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#
#
#
#
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92f93b2aaf627e14d183d7c1f7e19b9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92f93b2aaf627e14d183d7c1f7e19b9d = L.map(
#                 &quot;map_92f93b2aaf627e14d183d7c1f7e19b9d&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0972c50d10f67d8c758ac45b3d2f872 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0972c50d10f67d8c758ac45b3d2f872.addTo(map_92f93b2aaf627e14d183d7c1f7e19b9d);
#
#
#             var marker_cluster_c1f7d619f6ee2e37c0c991e215fdddbf = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_afaa3caf83d26e6767182f090f84e366 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_c1f7d619f6ee2e37c0c991e215fdddbf);
#
#
#             var icon_87674332147024ff1a0c1b9c7eab864a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_01315dadcf6ae6f4466cc744c806d09b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac649e509be67dd83f4bf4877008eaab = $(`&lt;div id=&quot;html_ac649e509be67dd83f4bf4877008eaab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_01315dadcf6ae6f4466cc744c806d09b.setContent(html_ac649e509be67dd83f4bf4877008eaab);
#
#
#
#         marker_afaa3caf83d26e6767182f090f84e366.bindPopup(popup_01315dadcf6ae6f4466cc744c806d09b)
#         ;
#
#
#
#
#                 marker_afaa3caf83d26e6767182f090f84e366.setIcon(icon_87674332147024ff1a0c1b9c7eab864a);
#
#
#             var marker_8883d2fc1fcf3760b7e834f8ccf1036a = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_c1f7d619f6ee2e37c0c991e215fdddbf);
#
#
#             var icon_e993845e6c6c963db330bdf1104543ff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3744f3495f0c2740dd35167bfb02d4cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f3002d1a0bbf942e9bccd30bb5eed4d = $(`&lt;div id=&quot;html_4f3002d1a0bbf942e9bccd30bb5eed4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_3744f3495f0c2740dd35167bfb02d4cc.setContent(html_4f3002d1a0bbf942e9bccd30bb5eed4d);
#
#
#
#         marker_8883d2fc1fcf3760b7e834f8ccf1036a.bindPopup(popup_3744f3495f0c2740dd35167bfb02d4cc)
#         ;
#
#
#
#
#                 marker_8883d2fc1fcf3760b7e834f8ccf1036a.setIcon(icon_e993845e6c6c963db330bdf1104543ff);
#
#
#             var marker_e9368204b1bc40db5265523fa2f2007b = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_c1f7d619f6ee2e37c0c991e215fdddbf);
#
#
#         var popup_481ef0cc553097a6ec6ca6fe8ffc6206 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f35295cadfd790006cc404235916708 = $(`&lt;div id=&quot;html_4f35295cadfd790006cc404235916708&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_481ef0cc553097a6ec6ca6fe8ffc6206.setContent(html_4f35295cadfd790006cc404235916708);

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e93e05b71e3a208b31fa76e771e318a7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e93e05b71e3a208b31fa76e771e318a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e93e05b71e3a208b31fa76e771e318a7 = L.map(
#                 &quot;map_e93e05b71e3a208b31fa76e771e318a7&quot;,
#                 {
#                     center: [-5.57, 4.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76bd402854c0f145d5007bcc6fee549e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76bd402854c0f145d5007bcc6fee549e.addTo(map_e93e05b71e3a208b31fa76e771e318a7);
#
#
#             var marker_cluster_9715b5caf771bfe8497e3d060d903f65 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_9715b5caf771bfe8497e3d060d903f65.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_f3c99209f81905c58bfa4d952a3a0be8 = L.marker(
#                 [42.0, -102.0],
#                 {
# }
#             ).addTo(marker_cluster_9715b5caf771bfe8497e3d060d903f65);
#
#
#         var popup_d058691c52566b89dc236ad91322b8df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_193e969aebd9410d29473e9b5d9ef86d = $(`&lt;div id=&quot;html_193e969aebd9410d29473e9b5d9ef86d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-102&lt;br&gt;lat:42&lt;/div&gt;`)[0];
#                 popup_d058691c52566b89dc236ad91322b8df.setContent(html_193e969aebd9410d29473e9b5d9ef86d);
#
#
#
#         marker_f3c99209f81905c58bfa4d952a3a0be8.bindPopup(popup_d058691c52566b89dc236ad91322b8df)
#         ;
#
#
#
#
#             var marker_8514751d4c1c01cb4caae8446cfb925a = L.marker(
#                 [-47.0, 6.0],
#                 {
# }
#             ).addTo(marker_cluster_9715b5caf771bfe8497e3d060d903f65);
#
#
#         var popup_83958abbfa0b3e73cee4865da8ba32d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05048934f72d248ce9274bf51f4e211c = $(`&lt;div id=&quot;html_05048934f72d248ce9274bf51f4e211c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:6&lt;br&gt;lat:-47&lt;/div&gt;`)[0];
#                 popup_83958abbfa0b3e73cee4865da8ba32d1.setContent(html_05048934f72d248ce9274bf51f4e211c);
#
#
#
#         marker_8514751d4c1c01cb4caae8446cfb925a.bindPopup(popup_83958abbfa0b3e73cee4865da8ba32d1)
#         ;
#
#
#
#
#             var marker_00f7c467c611daa668db0b5119950fdf = L.marker(
#                 [-51.0, 113.0],
#                 {
# }
#             ).addTo(marker_cluster_9715b5caf771bfe8497e3d060d903f65);
#
#
#         var popup_0ea21d7b7ffe36701ba24a3d4a8eb3ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_269a3198c53a9d66ae826e2b7a2c1b31 = $(`&lt;div id=&quot;html_269a3198c53a9d66ae826e2b7a2c1b31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:113&lt;br&gt;lat:-51&lt;/div&gt;`)[0];
#                 popup_0ea21d7b7ffe36701ba24a3d4a8eb3ea.setContent(html_269a3198c53a9d66ae826e2b7a2c1b31);
#
#
#
#         marker_00f7c467c611daa668db0b5119950fdf.bindPopup(popup_0ea21d7b7ffe36701ba24a3d4a8eb3ea)
#         ;
#
#
#
#
#             var marker_c198ae856626c408d5919958724a2060 = L.marker(
#                 [-48.0, 49.0],
#                 {
# }
#             ).addTo(marker_cluster_9715b5caf771bfe8497e3d060d903f65);
#
#
#         var popup_d0c3fdd55231ab0500e5fee157662518 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf38bb6c465e010cc722bd4bd051249f = $(`&lt;div id=&quot;html

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_352aab23bfb57ad568cbd07214c8f64f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_352aab23bfb57ad568cbd07214c8f64f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_352aab23bfb57ad568cbd07214c8f64f = L.map(
#                 &quot;map_352aab23bfb57ad568cbd07214c8f64f&quot;,
#                 {
#                     center: [-5.57, 4.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a5a86e3a0131453973be0c0261d450d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a5a86e3a0131453973be0c0261d450d.addTo(map_352aab23bfb57ad568cbd07214c8f64f);
#
#
#             var marker_cluster_1f49c05c82b65c0f4ae7e7c77b62c3da = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_e17c57196e2047d18748923d3ff6a85a = L.marker(
#                 [42.0, -102.0],
#                 {
# }
#             ).addTo(marker_cluster_1f49c05c82b65c0f4ae7e7c77b62c3da);
#
#
#         var popup_7ed2f0058047b04906c10fd399555412 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1833639f4e3d9106fc18327fe2730e76 = $(`&lt;div id=&quot;html_1833639f4e3d9106fc18327fe2730e76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-102&lt;br&gt;lat:42&lt;/div&gt;`)[0];
#                 popup_7ed2f0058047b04906c10fd399555412.setContent(html_1833639f4e3d9106fc18327fe2730e76);
#
#
#
#         marker_e17c57196e2047d18748923d3ff6a85a.bindPopup(popup_7ed2f0058047b04906c10fd399555412)
#         ;
#
#
#
#
#             var marker_c3c7bcacde85dc092238b4e99faa97a2 = L.marker(
#                 [-47.0, 6.0],
#                 {
# }
#             ).addTo(marker_cluster_1f49c05c82b65c0f4ae7e7c77b62c3da);
#
#
#         var popup_cff28c2bfbc8cacb37dcd0f2f56c0d06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76b1c1aca018fb6e873efe93899460d4 = $(`&lt;div id=&quot;html_76b1c1aca018fb6e873efe93899460d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:6&lt;br&gt;lat:-47&lt;/div&gt;`)[0];
#                 popup_cff28c2bfbc8cacb37dcd0f2f56c0d06.setContent(html_76b1c1aca018fb6e873efe93899460d4);
#
#
#
#         marker_c3c7bcacde85dc092238b4e99faa97a2.bindPopup(popup_cff28c2bfbc8cacb37dcd0f2f56c0d06)
#         ;
#
#
#
#
#             var marker_ebca49526032c36dac26397795a16c18 = L.marker(
#                 [-51.0, 113.0],
#                 {
# }
#             ).addTo(marker_cluster_1f49c05c82b65c0f4ae7e7c77b62c3da);
#
#
#         var popup_0441f9b38a8ce1df02a8a8b8f3e78f37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2e7958c3dfb354195c7747abfc02c96 = $(`&lt;div id=&quot;html_e2e7958c3dfb354195c7747abfc02c96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:113&lt;br&gt;lat:-51&lt;/div&gt;`)[0];
#                 popup_0441f9b38a8ce1df02a8a8b8f3e78f37.setContent(html_e2e7958c3dfb354195c7747abfc02c96);
#
#
#
#         marker_ebca49526032c36dac26397795a16c18.bindPopup(popup_0441f9b38a8ce1df02a8a8b8f3e78f37)
#         ;
#
#
#
#
#             var marker_8727729065d69df45fba2ee65777f34b = L.marker(
#                 [-48.0, 49.0],
#                 {
# }
#             ).addTo(marker_cluster_1f49c05c82b65c0f4ae7e7c77b62c3da);
#
#
#         var popup_aa83bfbd7f1d29cc55bd0532fa889287 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e774cead12d2be056b5a65e36ed04a4 = $(`&lt;div id=&quot;html_5e774cead12d2be056b5a65e36ed04a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:-48&lt;/div&gt;`)[0];
#                 popup_aa83bfbd7f1d29cc55bd0532fa889287.setContent(html_5e774cead12d2be056b5a65e36ed04a4);
#
#
#
#         marker_8727729065d69df45fba2ee65777f34b.bindPopup(popup_aa83bfbd7f1d29

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfc78ff750a9357d9aac500cb37baf66 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfc78ff750a9357d9aac500cb37baf66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfc78ff750a9357d9aac500cb37baf66 = L.map(
#                 &quot;map_dfc78ff750a9357d9aac500cb37baf66&quot;,
#                 {
#                     center: [-5.57, 4.71],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49cf48c0df2079a68d851b3f4ce31c90 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49cf48c0df2079a68d851b3f4ce31c90.addTo(map_dfc78ff750a9357d9aac500cb37baf66);
#
#
#             var fast_marker_cluster_cf9e11a9a62bb79db6c1e85ee92faa11 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [