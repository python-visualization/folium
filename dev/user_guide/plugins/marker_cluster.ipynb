# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f260759367fbefcc41b1df20480caa91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f260759367fbefcc41b1df20480caa91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f260759367fbefcc41b1df20480caa91 = L.map(
#                 &quot;map_f260759367fbefcc41b1df20480caa91&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_395e3238db0166d4d254e3e6ceb7d86b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_395e3238db0166d4d254e3e6ceb7d86b.addTo(map_f260759367fbefcc41b1df20480caa91);
#
#
#             var marker_cluster_3f26a30903a1e8f68d9e0a69aa8f8506 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_e637edab6942437dcb110a9fed035fb4 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_3f26a30903a1e8f68d9e0a69aa8f8506);
#
#
#             var icon_e735a0a8004c316efbbcf722a863ff6c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8afcd0f76b7bec56addbb28e81ce066d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca001b92ac8843c486ce8f4eb4f4a902 = $(`&lt;div id=&quot;html_ca001b92ac8843c486ce8f4eb4f4a902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8afcd0f76b7bec56addbb28e81ce066d.setContent(html_ca001b92ac8843c486ce8f4eb4f4a902);
#
#
#
#         marker_e637edab6942437dcb110a9fed035fb4.bindPopup(popup_8afcd0f76b7bec56addbb28e81ce066d)
#         ;
#
#
#
#
#                 marker_e637edab6942437dcb110a9fed035fb4.setIcon(icon_e735a0a8004c316efbbcf722a863ff6c);
#
#
#             var marker_e386bf77200b7ecef6599a429712a13c = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_3f26a30903a1e8f68d9e0a69aa8f8506);
#
#
#             var icon_1198ca10eefcc79074baa3aaf3f87816 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6ea5e63c6bbc1acfa4c0098de436c83e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc74106e06402df238671d5814f2d157 = $(`&lt;div id=&quot;html_bc74106e06402df238671d5814f2d157&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6ea5e63c6bbc1acfa4c0098de436c83e.setContent(html_bc74106e06402df238671d5814f2d157);
#
#
#
#         marker_e386bf77200b7ecef6599a429712a13c.bindPopup(popup_6ea5e63c6bbc1acfa4c0098de436c83e)
#         ;
#
#
#
#
#                 marker_e386bf77200b7ecef6599a429712a13c.setIcon(icon_1198ca10eefcc79074baa3aaf3f87816);
#
#
#             var marker_81a2324caefa4fada71b9ebc1900dfcb = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_3f26a30903a1e8f68d9e0a69aa8f8506);
#
#
#         var popup_1c4735214c99b47ea1b5cda95ad54bd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06e780606ee55d3a0473899d943f65e8 = $(`&lt;div id=&quot;html_06e780606ee55d3a0473899d943f65e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_1c4735214c99b47ea1b5cda95ad54bd9.setContent(html_06e780606ee55d3a0473899d943f65e8);
#
#
#
#         marker_81a2324caefa4fada71b9ebc1900dfcb.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd3d80f3bc0200cb3cce9103a33ad23d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd3d80f3bc0200cb3cce9103a33ad23d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd3d80f3bc0200cb3cce9103a33ad23d = L.map(
#                 &quot;map_fd3d80f3bc0200cb3cce9103a33ad23d&quot;,
#                 {
#                     center: [9.78, -4.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_214b956341ddc5b1ee4b556ec3ce61b9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_214b956341ddc5b1ee4b556ec3ce61b9.addTo(map_fd3d80f3bc0200cb3cce9103a33ad23d);
#
#
#             var marker_cluster_afad18473044b2a4c3c3697e47658047 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_afad18473044b2a4c3c3697e47658047.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_a73d763081cbf94c45f70c20fac07a4c = L.marker(
#                 [23.0, -161.0],
#                 {
# }
#             ).addTo(marker_cluster_afad18473044b2a4c3c3697e47658047);
#
#
#         var popup_0529458d7669e5b705cd294824e5e045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc01fd247b7d1ce7443c0db67c078e8b = $(`&lt;div id=&quot;html_bc01fd247b7d1ce7443c0db67c078e8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-161&lt;br&gt;lat:23&lt;/div&gt;`)[0];
#                 popup_0529458d7669e5b705cd294824e5e045.setContent(html_bc01fd247b7d1ce7443c0db67c078e8b);
#
#
#
#         marker_a73d763081cbf94c45f70c20fac07a4c.bindPopup(popup_0529458d7669e5b705cd294824e5e045)
#         ;
#
#
#
#
#             var marker_81f988bcde67712f2471e926a66173b9 = L.marker(
#                 [-23.0, -97.0],
#                 {
# }
#             ).addTo(marker_cluster_afad18473044b2a4c3c3697e47658047);
#
#
#         var popup_dbb1acef4cb2cb941db024771d39a279 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e062df92961477c9b677f8d618b59f92 = $(`&lt;div id=&quot;html_e062df92961477c9b677f8d618b59f92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-97&lt;br&gt;lat:-23&lt;/div&gt;`)[0];
#                 popup_dbb1acef4cb2cb941db024771d39a279.setContent(html_e062df92961477c9b677f8d618b59f92);
#
#
#
#         marker_81f988bcde67712f2471e926a66173b9.bindPopup(popup_dbb1acef4cb2cb941db024771d39a279)
#         ;
#
#
#
#
#             var marker_c8cdaa52ad6eff62957b5c7218d3a6a6 = L.marker(
#                 [82.0, -118.0],
#                 {
# }
#             ).addTo(marker_cluster_afad18473044b2a4c3c3697e47658047);
#
#
#         var popup_e0d1576681a246f281b91a12643e0dcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1455de053098ffb45a6d4c0916aa31fb = $(`&lt;div id=&quot;html_1455de053098ffb45a6d4c0916aa31fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-118&lt;br&gt;lat:82&lt;/div&gt;`)[0];
#                 popup_e0d1576681a246f281b91a12643e0dcf.setContent(html_1455de053098ffb45a6d4c0916aa31fb);
#
#
#
#         marker_c8cdaa52ad6eff62957b5c7218d3a6a6.bindPopup(popup_e0d1576681a246f281b91a12643e0dcf)
#         ;
#
#
#
#
#             var marker_6dd76cd89401f60cd623ff5ef55b41d8 = L.marker(
#                 [64.0, 51.0],
#                 {
# }
#             ).addTo(marker_cluster_afad18473044b2a4c3c3697e47658047);
#
#
#         var popup_cdea388242c46807c9b416d6e1273584 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_978e30ed16acd02d597ed23c4c27525a = $(`&lt;div id=&quot;html

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9de19c2be99af882e7bc47a7cc656ad0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9de19c2be99af882e7bc47a7cc656ad0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9de19c2be99af882e7bc47a7cc656ad0 = L.map(
#                 &quot;map_9de19c2be99af882e7bc47a7cc656ad0&quot;,
#                 {
#                     center: [9.78, -4.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6b69c1d3b567d9490541885780aac3d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6b69c1d3b567d9490541885780aac3d.addTo(map_9de19c2be99af882e7bc47a7cc656ad0);
#
#
#             var marker_cluster_71cb4bb24f9f8db0c719d872ca9720f7 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_94818639fd51603208d2abc0f5ec28c7 = L.marker(
#                 [23.0, -161.0],
#                 {
# }
#             ).addTo(marker_cluster_71cb4bb24f9f8db0c719d872ca9720f7);
#
#
#         var popup_1cd8625147a9cb263de7cdc0b947a0bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7492a7e9a70d937f255ef8ecec47ec3 = $(`&lt;div id=&quot;html_d7492a7e9a70d937f255ef8ecec47ec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-161&lt;br&gt;lat:23&lt;/div&gt;`)[0];
#                 popup_1cd8625147a9cb263de7cdc0b947a0bd.setContent(html_d7492a7e9a70d937f255ef8ecec47ec3);
#
#
#
#         marker_94818639fd51603208d2abc0f5ec28c7.bindPopup(popup_1cd8625147a9cb263de7cdc0b947a0bd)
#         ;
#
#
#
#
#             var marker_293a6639e1140c599750cdb6ef84a525 = L.marker(
#                 [-23.0, -97.0],
#                 {
# }
#             ).addTo(marker_cluster_71cb4bb24f9f8db0c719d872ca9720f7);
#
#
#         var popup_f973219859856b1121510ddeba0fd729 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edaaf89494e1cf049b3e8466de6cf1be = $(`&lt;div id=&quot;html_edaaf89494e1cf049b3e8466de6cf1be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-97&lt;br&gt;lat:-23&lt;/div&gt;`)[0];
#                 popup_f973219859856b1121510ddeba0fd729.setContent(html_edaaf89494e1cf049b3e8466de6cf1be);
#
#
#
#         marker_293a6639e1140c599750cdb6ef84a525.bindPopup(popup_f973219859856b1121510ddeba0fd729)
#         ;
#
#
#
#
#             var marker_96bbd42acfcd17f90aa34630e4336c97 = L.marker(
#                 [82.0, -118.0],
#                 {
# }
#             ).addTo(marker_cluster_71cb4bb24f9f8db0c719d872ca9720f7);
#
#
#         var popup_2111e9235ca237cbc512d7056920a43a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cb6d52abe0107b02b1ee0be94f8c67b = $(`&lt;div id=&quot;html_0cb6d52abe0107b02b1ee0be94f8c67b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-118&lt;br&gt;lat:82&lt;/div&gt;`)[0];
#                 popup_2111e9235ca237cbc512d7056920a43a.setContent(html_0cb6d52abe0107b02b1ee0be94f8c67b);
#
#
#
#         marker_96bbd42acfcd17f90aa34630e4336c97.bindPopup(popup_2111e9235ca237cbc512d7056920a43a)
#         ;
#
#
#
#
#             var marker_84f3a305a37affbcda9f20de78b14dae = L.marker(
#                 [64.0, 51.0],
#                 {
# }
#             ).addTo(marker_cluster_71cb4bb24f9f8db0c719d872ca9720f7);
#
#
#         var popup_44222b41371ade6fc618da38dae470a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e3969c0965f6daa96745fa50eb78268 = $(`&lt;div id=&quot;html_2e3969c0965f6daa96745fa50eb78268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:51&lt;br&gt;lat:64&lt;/div&gt;`)[0];
#                 popup_44222b41371ade6fc618da38dae470a9.setContent(html_2e3969c0965f6daa96745fa50eb78268);
#
#
#
#         marker_84f3a305a37affbcda9f20de78b14dae.bindPopup(popup_44222b41371ade6

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b19aee7b284068fb46fbe3edfa9864d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b19aee7b284068fb46fbe3edfa9864d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b19aee7b284068fb46fbe3edfa9864d3 = L.map(
#                 &quot;map_b19aee7b284068fb46fbe3edfa9864d3&quot;,
#                 {
#                     center: [9.78, -4.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af14a4e8ba1e91bccbac3cf499130517 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af14a4e8ba1e91bccbac3cf499130517.addTo(map_b19aee7b284068fb46fbe3edfa9864d3);
#
#
#             var fast_marker_cluster_35bd81b01dd8f4962d6bac79f2e5c0ea = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[23.0, -161.0], [-23.0, -97.0], [82.0, -118.0], [64.0, 51.0], [88.0, -175.0], [25.0, -162.0], [-79.0, 61.0], [54.0, 153.0], [27.0, -62.0], [75.0, 61.0], [50.0, -111.0], [4.0, -21.0], [22.0, -54.0], [48.0, -23.0], [-6.0, 122.0], [6.0, -133.0], [-5.0, -150.0], [67.0, 31.0], [-3.0, 46.0], [31.0, 150.0], [63.0, 158.0], [67.0, -43.0], [-20.0, -95.0], [-34.0, 15.0], [-50.0, 121.0], [61.0, 169.0], [-21.0, 105.0], [0.0, -53.0], [1.0, 103.0], [11.0, 90.0], [-2.0, 55.0], [20.0, -149.0], [-69.0, 177.0], [61.0, 104.0], [30.0, -103.0], [-33.0, -126.0], [23.0, 89.0], [-78.0, -138.0], [89.0, 66.0], [-28.0, 152.0], [40.0, 169.0], [48.0, 145.0], [81.0, -4.0], [69.0, 123.0], [-23.0, -96.0], [15.0, 0.0], [27.0, 116.0], [-31.0, 18.0], [82.0, 102.0], [-61.0, -136.0], [-7.0, -56.0], [-58.0, 72.0], [66.0, -176.0], [-24.0, 50.0], [70.0, 154.0], [-7.0, 142.0], [-23.0, -101.0], [34.0, 65.0], [14.0, -164.0], [-73.0, -7.0], [8.0, 20.0], [44.0, 161.0], [-30.0, -72.0], [-39.0, -28.0], [57.0, 41.0], [-26.0, 35.0], [34.0, 107.0], [-13.0, 80.0], [-31.0, 45.0], [33.0, -10.0], [-23.0, -121.0], [66.0, 69.0], [31.0, -89.0], [-34.0, -177.0], [-24.0, -172.0], [32.0, -145.0], [-69.0, 84.0], [-67.0, -79.0], [-39.0, 141.0], [38.0, 153.0], [29.0, -32.0], [25.0, -165.0], [37.0, 128.0], [46.0, -134.0], [-49.0, -101.0], [34.0, 99.0], [37.0, -54.0], [44.0, 35.0], [-25.0, -100.0], [89.0, -101.0], [25.0, -22.0], [-39.0, -37.0], [44.0, -160.0], [-84.0, -141.0], [84.0, 45.0], [-16.0, 140.0], [72.0, -91.0], [-86.0, -57.0], [-48.0, -172.0], [-69.0, -103.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_b19aee7b284068fb46fbe3edfa9864d3);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_35bd81b01dd8f4962d6bac79f2e5c0ea.addTo(map_b19aee7b284068fb46fbe3edfa9864d3);
#
#
#             var layer_control_a0b66128ad792f80c65bdf2ef37c0fa2_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_af14a4e8ba1e91bccbac3cf499130517,
#                 },
#                 overlays :  {
#                     &quot;macro_element_35bd81b01dd8f4962d6bac79f2e5c0ea&quot; : fast_marker_cluster_35bd81b01dd8f4962d6bac79f2e5c0ea,
#                 },
#             };
#             let layer_control_a0b66128ad792f80c65bdf2ef37c0fa2 = L.control.layers(
#                 layer_control_a0b66128ad792f80c65bdf2ef37c0fa2_layers.base_layers,
#                 layer_control_a0b66128ad792f80c65bdf2ef37c0fa2_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_b19aee7b284068fb46fbe3edfa9864d3);
#
#
# &lt;/script

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_291ee36077e77297177b7bcd32bbadef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_291ee36077e77297177b7bcd32bbadef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_291ee36077e77297177b7bcd32bbadef = L.map(
#                 &quot;map_291ee36077e77297177b7bcd32bbadef&quot;,
#                 {
#                     center: [9.78, -4.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d0adfd9947e5cdcb8fe6ff8be6138db = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d0adfd9947e5cdcb8fe6ff8be6138db.addTo(map_291ee36077e77297177b7bcd32bbadef);
#
#
#             var fast_marker_cluster_9d377e0bdbe8026bdbace252e6656207 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[23.0, -161.0], [-23.0, -97.0], [82.0, -118.0], [64.0, 51.0], [88.0, -175.0], [25.0, -162.0], [-79.0, 61.0], [54.0, 153.0], [27.0, -62.0], [75.0, 61.0], [50.0, -111.0], [4.0, -21.0], [22.0, -54.0], [48.0, -23.0], [-6.0, 122.0], [6.0, -133.0], [-5.0, -150.0], [67.0, 31.0], [-3.0, 46.0], [31.0, 150.0], [63.0, 158.0], [67.0, -43.0], [-20.0, -95.0], [-34.0, 15.0], [-50.0, 121.0], [61.0, 169.0], [-21.0, 105.0], [0.0, -53.0], [1.0, 103.0], [11.0, 90.0], [-2.0, 55.0], [20.0, -149.0], [-69.0, 177.0], [61.0, 104.0], [30.0, -103.0], [-33.0, -126.0], [23.0, 89.0], [-78.0, -138.0], [89.0, 66.0], [-28.0, 152.0], [40.0, 169.0], [48.0, 145.0], [81.0, -4.0], [69.0, 123.0], [-23.0, -96.0], [15.0, 0.0], [27.0, 116.0], [-31.0, 18.0], [82.0, 102.0], [-61.0, -136.0], [-7.0, -56.0], [-58.0, 72.0], [66.0, -176.0], [-24.0, 50.0], [70.0, 154.0], [-7.0, 142.0], [-23.0, -101.0], [34.0, 65.0], [14.0, -164.0], [-73.0, -7.0], [8.0, 20.0], [44.0, 161.0], [-30.0, -72.0], [-39.0, -28.0], [57.0, 41.0], [-26.0, 35.0], [34.0, 107.0], [-13.0, 80.0], [-31.0, 45.0], [33.0, -10.0], [-23.0, -121.0], [66.0, 69.0], [31.0, -89.0], [-34.0, -177.0], [-24.0, -172.0], [32.0, -145.0], [-69.0, 84.0], [-67.0, -79.0], [-39.0, 141.0], [38.0, 153.0], [29.0, -32.0], [25.0, -165.0], [37.0, 128.0], [46.0, -134.0], [-49.0, -101.0], [34.0, 99.0], [37.0, -54.0], [44.0, 35.0], [-25.0, -100.0], [89.0, -101.0], [25.0, -22.0], [-39.0, -37.0], [44.0, -160.0], [-84.0, -141.0], [84.0, 45.0], [-16.0, 140.0], [72.0, -91.0], [-86.0, -57.0], [-48.0, -172.0], [-69.0, -103.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_291ee36077e77297177b7bcd32bbadef);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_9d377e0bdbe8026bdbace252e6656207.addTo(map_291ee36077e77297177b7bcd32bbadef);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
