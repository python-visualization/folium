# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ce69f0f5a05dbc30fa611593cb7499d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ce69f0f5a05dbc30fa611593cb7499d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ce69f0f5a05dbc30fa611593cb7499d = L.map(
#                 &quot;map_3ce69f0f5a05dbc30fa611593cb7499d&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b181591fb7018c6a99e3e3eb9e4c634 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b181591fb7018c6a99e3e3eb9e4c634.addTo(map_3ce69f0f5a05dbc30fa611593cb7499d);
#
#
#             var marker_cluster_231dac6ffcc32daf261a097150f086ae = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_cc22982cf77935f63453acf542349d23 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_231dac6ffcc32daf261a097150f086ae);
#
#
#             var icon_b93edeffb58f3a4a84bf8b46511f962e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a474d997898c12c69a2c78ed2dd0c6d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6dc02b9b15e26b3a80f41d7c9531ec8 = $(`&lt;div id=&quot;html_c6dc02b9b15e26b3a80f41d7c9531ec8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_a474d997898c12c69a2c78ed2dd0c6d1.setContent(html_c6dc02b9b15e26b3a80f41d7c9531ec8);
#
#
#
#         marker_cc22982cf77935f63453acf542349d23.bindPopup(popup_a474d997898c12c69a2c78ed2dd0c6d1)
#         ;
#
#
#
#
#                 marker_cc22982cf77935f63453acf542349d23.setIcon(icon_b93edeffb58f3a4a84bf8b46511f962e);
#
#
#             var marker_b2d50ceb32ed05c98bf6b16ce8c18a70 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_231dac6ffcc32daf261a097150f086ae);
#
#
#             var icon_3d6438d337988f0fd0bf069b2da4031b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_25d4159396a84152bb1d2e8f346df72e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa6544131d05ba64acc22c9b3fd93c53 = $(`&lt;div id=&quot;html_fa6544131d05ba64acc22c9b3fd93c53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_25d4159396a84152bb1d2e8f346df72e.setContent(html_fa6544131d05ba64acc22c9b3fd93c53);
#
#
#
#         marker_b2d50ceb32ed05c98bf6b16ce8c18a70.bindPopup(popup_25d4159396a84152bb1d2e8f346df72e)
#         ;
#
#
#
#
#                 marker_b2d50ceb32ed05c98bf6b16ce8c18a70.setIcon(icon_3d6438d337988f0fd0bf069b2da4031b);
#
#
#             var marker_9ecf57936f298ac8b440154046c4f499 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_231dac6ffcc32daf261a097150f086ae);
#
#
#         var popup_3b07efe3a90b8a59bca5af3f0d752ef6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4e9e02175e2f6cb1aa7bdc693210dd1 = $(`&lt;div id=&quot;html_d4e9e02175e2f6cb1aa7bdc693210dd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_3b07efe3a90b8a59bca5af3f0d752ef6.setContent(html_d4e9e02175e2f6cb1aa7bdc693210dd1);
#
#
#
#         marker_9ecf57936f298ac8b440154046c4f499.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92da06a4cbadd418349fcd8366babe8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92da06a4cbadd418349fcd8366babe8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92da06a4cbadd418349fcd8366babe8a = L.map(
#                 &quot;map_92da06a4cbadd418349fcd8366babe8a&quot;,
#                 {
#                     center: [8.4, -5.48],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_347de9e5ec4ddb2d0c19ffa4754c5152 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_347de9e5ec4ddb2d0c19ffa4754c5152.addTo(map_92da06a4cbadd418349fcd8366babe8a);
#
#
#             var marker_cluster_00baed645e4785a66e64c05f0ff1657e = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_00baed645e4785a66e64c05f0ff1657e.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_ec11e39f845e560f8ead034d93dfe95f = L.marker(
#                 [7.0, -17.0],
#                 {
# }
#             ).addTo(marker_cluster_00baed645e4785a66e64c05f0ff1657e);
#
#
#         var popup_025473249b000815b01b311f04fe6d1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8146f954e3e69c7a4d32ed9bafd46c0a = $(`&lt;div id=&quot;html_8146f954e3e69c7a4d32ed9bafd46c0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-17&lt;br&gt;lat:7&lt;/div&gt;`)[0];
#                 popup_025473249b000815b01b311f04fe6d1d.setContent(html_8146f954e3e69c7a4d32ed9bafd46c0a);
#
#
#
#         marker_ec11e39f845e560f8ead034d93dfe95f.bindPopup(popup_025473249b000815b01b311f04fe6d1d)
#         ;
#
#
#
#
#             var marker_58d38a6cd291fc08fd9985cdcfbaf4f6 = L.marker(
#                 [-22.0, -132.0],
#                 {
# }
#             ).addTo(marker_cluster_00baed645e4785a66e64c05f0ff1657e);
#
#
#         var popup_571f63c34af144ec037c49a6769aad2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db46d7fd8041419bf0b2d519ca3d3c15 = $(`&lt;div id=&quot;html_db46d7fd8041419bf0b2d519ca3d3c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-132&lt;br&gt;lat:-22&lt;/div&gt;`)[0];
#                 popup_571f63c34af144ec037c49a6769aad2b.setContent(html_db46d7fd8041419bf0b2d519ca3d3c15);
#
#
#
#         marker_58d38a6cd291fc08fd9985cdcfbaf4f6.bindPopup(popup_571f63c34af144ec037c49a6769aad2b)
#         ;
#
#
#
#
#             var marker_2b59f319d73e2736b30d7c975aab332f = L.marker(
#                 [48.0, 93.0],
#                 {
# }
#             ).addTo(marker_cluster_00baed645e4785a66e64c05f0ff1657e);
#
#
#         var popup_1d877a43ec2ff851a432cd234552eccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50385df03125964500b02b88451b91ce = $(`&lt;div id=&quot;html_50385df03125964500b02b88451b91ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:93&lt;br&gt;lat:48&lt;/div&gt;`)[0];
#                 popup_1d877a43ec2ff851a432cd234552eccf.setContent(html_50385df03125964500b02b88451b91ce);
#
#
#
#         marker_2b59f319d73e2736b30d7c975aab332f.bindPopup(popup_1d877a43ec2ff851a432cd234552eccf)
#         ;
#
#
#
#
#             var marker_b1081f90b97c767eeff125cb32eb6e49 = L.marker(
#                 [17.0, -66.0],
#                 {
# }
#             ).addTo(marker_cluster_00baed645e4785a66e64c05f0ff1657e);
#
#
#         var popup_25799d2c5bbf4edd0d380ad889464d3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6067ee9868280c4f1c5722a43c8f7570 = $(`&lt;div id=&quot;html_6067e

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25acbff6edce69273084471a73600413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25acbff6edce69273084471a73600413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25acbff6edce69273084471a73600413 = L.map(
#                 &quot;map_25acbff6edce69273084471a73600413&quot;,
#                 {
#                     center: [8.4, -5.48],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db9cba5bde1f5b658b1778f8fcbfac26 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db9cba5bde1f5b658b1778f8fcbfac26.addTo(map_25acbff6edce69273084471a73600413);
#
#
#             var marker_cluster_79371dd8c0e17bc3fcc88681167ee95e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_51e77aa79633591ff510e791f2d47939 = L.marker(
#                 [7.0, -17.0],
#                 {
# }
#             ).addTo(marker_cluster_79371dd8c0e17bc3fcc88681167ee95e);
#
#
#         var popup_4908d021d04c8211be8bc1b9515e3f46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8ca9151aec2d6024154fcd671ca2cd2 = $(`&lt;div id=&quot;html_a8ca9151aec2d6024154fcd671ca2cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-17&lt;br&gt;lat:7&lt;/div&gt;`)[0];
#                 popup_4908d021d04c8211be8bc1b9515e3f46.setContent(html_a8ca9151aec2d6024154fcd671ca2cd2);
#
#
#
#         marker_51e77aa79633591ff510e791f2d47939.bindPopup(popup_4908d021d04c8211be8bc1b9515e3f46)
#         ;
#
#
#
#
#             var marker_28ee241b24bf879aa1b93b18f4a01064 = L.marker(
#                 [-22.0, -132.0],
#                 {
# }
#             ).addTo(marker_cluster_79371dd8c0e17bc3fcc88681167ee95e);
#
#
#         var popup_d93eb6eaa3ef1b2f90d4c9f0d7906efe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27e820c18a8472b1df3debe552d4325c = $(`&lt;div id=&quot;html_27e820c18a8472b1df3debe552d4325c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-132&lt;br&gt;lat:-22&lt;/div&gt;`)[0];
#                 popup_d93eb6eaa3ef1b2f90d4c9f0d7906efe.setContent(html_27e820c18a8472b1df3debe552d4325c);
#
#
#
#         marker_28ee241b24bf879aa1b93b18f4a01064.bindPopup(popup_d93eb6eaa3ef1b2f90d4c9f0d7906efe)
#         ;
#
#
#
#
#             var marker_b6b4b338e99e72e7b5e6cb3774ca974d = L.marker(
#                 [48.0, 93.0],
#                 {
# }
#             ).addTo(marker_cluster_79371dd8c0e17bc3fcc88681167ee95e);
#
#
#         var popup_ab239f71665c4ddbe8178139fd065806 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_020a197e0d325eccad368c84a80b9bec = $(`&lt;div id=&quot;html_020a197e0d325eccad368c84a80b9bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:93&lt;br&gt;lat:48&lt;/div&gt;`)[0];
#                 popup_ab239f71665c4ddbe8178139fd065806.setContent(html_020a197e0d325eccad368c84a80b9bec);
#
#
#
#         marker_b6b4b338e99e72e7b5e6cb3774ca974d.bindPopup(popup_ab239f71665c4ddbe8178139fd065806)
#         ;
#
#
#
#
#             var marker_78a6161f91be711e0a438bf16b2deb57 = L.marker(
#                 [17.0, -66.0],
#                 {
# }
#             ).addTo(marker_cluster_79371dd8c0e17bc3fcc88681167ee95e);
#
#
#         var popup_adb85c07be8d5ce03cd12ef128afe3f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee623b23cd9fa75c4d6be4909e135ceb = $(`&lt;div id=&quot;html_ee623b23cd9fa75c4d6be4909e135ceb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-66&lt;br&gt;lat:17&lt;/div&gt;`)[0];
#                 popup_adb85c07be8d5ce03cd12ef128afe3f7.setContent(html_ee623b23cd9fa75c4d6be4909e135ceb);
#
#
#
#         marker_78a6161f91be711e0a438bf16b2deb57.bindPopup(popup_adb85c07be8d5ce03cd1

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a044795542e7393c225f9cfd6d3797d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a044795542e7393c225f9cfd6d3797d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a044795542e7393c225f9cfd6d3797d = L.map(
#                 &quot;map_6a044795542e7393c225f9cfd6d3797d&quot;,
#                 {
#                     center: [8.4, -5.48],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8d2f47c1dcbea7f06f4f958360f56ed = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8d2f47c1dcbea7f06f4f958360f56ed.addTo(map_6a044795542e7393c225f9cfd6d3797d);
#
#
#             var fast_marker_cluster_51a71f398db98de99f3cb113fafcc393 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[7.0, -17.0], [-22.0, -132.0], [48.0, 93.0], [17.0, -66.0], [46.0, 159.0], [-25.0, 144.0], [-63.0, -42.0], [-34.0, 172.0], [-20.0, 53.0], [60.0, -29.0], [78.0, -161.0], [49.0, -44.0], [-15.0, 67.0], [55.0, 148.0], [-82.0, -71.0], [32.0, -17.0], [-5.0, 42.0], [-19.0, -112.0], [87.0, -38.0], [53.0, -99.0], [-20.0, -122.0], [44.0, 172.0], [77.0, -69.0], [-85.0, -110.0], [-49.0, -152.0], [71.0, -20.0], [86.0, 110.0], [-47.0, 105.0], [-27.0, 45.0], [-30.0, 8.0], [70.0, 52.0], [29.0, 155.0], [-57.0, -47.0], [77.0, -8.0], [87.0, -53.0], [51.0, 90.0], [65.0, 58.0], [-57.0, 86.0], [37.0, -15.0], [52.0, 150.0], [10.0, 80.0], [43.0, -100.0], [-49.0, -13.0], [40.0, 85.0], [-86.0, 83.0], [-17.0, -108.0], [-18.0, -131.0], [-47.0, -143.0], [-63.0, -70.0], [70.0, -144.0], [-20.0, 80.0], [21.0, 78.0], [-46.0, -110.0], [53.0, -157.0], [66.0, -83.0], [83.0, 54.0], [65.0, -48.0], [-10.0, -109.0], [-12.0, -32.0], [-70.0, -44.0], [2.0, -143.0], [-42.0, -154.0], [-67.0, 56.0], [46.0, 110.0], [-64.0, 156.0], [32.0, 13.0], [-16.0, 131.0], [9.0, 99.0], [-12.0, -58.0], [-49.0, 6.0], [0.0, -28.0], [-73.0, 82.0], [88.0, -135.0], [52.0, -72.0], [-5.0, -105.0], [-46.0, 133.0], [-30.0, -162.0], [-18.0, -113.0], [68.0, -51.0], [55.0, 49.0], [80.0, 59.0], [21.0, -42.0], [-39.0, 47.0], [-1.0, 130.0], [71.0, -73.0], [74.0, 114.0], [53.0, -42.0], [87.0, -51.0], [-23.0, -5.0], [50.0, 99.0], [61.0, -37.0], [11.0, 52.0], [-29.0, 164.0], [-30.0, -55.0], [-67.0, -26.0], [-37.0, -164.0], [-31.0, -55.0], [40.0, -40.0], [-65.0, -5.0], [50.0, -85.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_6a044795542e7393c225f9cfd6d3797d);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_51a71f398db98de99f3cb113fafcc393.addTo(map_6a044795542e7393c225f9cfd6d3797d);
#
#
#             var layer_control_fd5b371fc11885600ece35603e2e191c_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_d8d2f47c1dcbea7f06f4f958360f56ed,
#                 },
#                 overlays :  {
#                     &quot;macro_element_51a71f398db98de99f3cb113fafcc393&quot; : fast_marker_cluster_51a71f398db98de99f3cb113fafcc393,
#                 },
#             };
#             let layer_control_fd5b371fc11885600ece35603e2e191c = L.control.layers(
#                 layer_control_fd5b371fc11885600ece35603e2e191c_layers.base_layers,
#                 layer_control_fd5b371fc11885600ece35603e2e191c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_6a044795542e7393c225f9cfd6d3797d);
#
#
# &lt;/script&

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fcd37f73a14653b7dfbe0fb8ad29ca3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fcd37f73a14653b7dfbe0fb8ad29ca3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fcd37f73a14653b7dfbe0fb8ad29ca3 = L.map(
#                 &quot;map_6fcd37f73a14653b7dfbe0fb8ad29ca3&quot;,
#                 {
#                     center: [8.4, -5.48],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20cc8664ceaadec16228280a924bd944 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20cc8664ceaadec16228280a924bd944.addTo(map_6fcd37f73a14653b7dfbe0fb8ad29ca3);
#
#
#             var fast_marker_cluster_78f865cba904c407579838002d60e8ca = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[7.0, -17.0], [-22.0, -132.0], [48.0, 93.0], [17.0, -66.0], [46.0, 159.0], [-25.0, 144.0], [-63.0, -42.0], [-34.0, 172.0], [-20.0, 53.0], [60.0, -29.0], [78.0, -161.0], [49.0, -44.0], [-15.0, 67.0], [55.0, 148.0], [-82.0, -71.0], [32.0, -17.0], [-5.0, 42.0], [-19.0, -112.0], [87.0, -38.0], [53.0, -99.0], [-20.0, -122.0], [44.0, 172.0], [77.0, -69.0], [-85.0, -110.0], [-49.0, -152.0], [71.0, -20.0], [86.0, 110.0], [-47.0, 105.0], [-27.0, 45.0], [-30.0, 8.0], [70.0, 52.0], [29.0, 155.0], [-57.0, -47.0], [77.0, -8.0], [87.0, -53.0], [51.0, 90.0], [65.0, 58.0], [-57.0, 86.0], [37.0, -15.0], [52.0, 150.0], [10.0, 80.0], [43.0, -100.0], [-49.0, -13.0], [40.0, 85.0], [-86.0, 83.0], [-17.0, -108.0], [-18.0, -131.0], [-47.0, -143.0], [-63.0, -70.0], [70.0, -144.0], [-20.0, 80.0], [21.0, 78.0], [-46.0, -110.0], [53.0, -157.0], [66.0, -83.0], [83.0, 54.0], [65.0, -48.0], [-10.0, -109.0], [-12.0, -32.0], [-70.0, -44.0], [2.0, -143.0], [-42.0, -154.0], [-67.0, 56.0], [46.0, 110.0], [-64.0, 156.0], [32.0, 13.0], [-16.0, 131.0], [9.0, 99.0], [-12.0, -58.0], [-49.0, 6.0], [0.0, -28.0], [-73.0, 82.0], [88.0, -135.0], [52.0, -72.0], [-5.0, -105.0], [-46.0, 133.0], [-30.0, -162.0], [-18.0, -113.0], [68.0, -51.0], [55.0, 49.0], [80.0, 59.0], [21.0, -42.0], [-39.0, 47.0], [-1.0, 130.0], [71.0, -73.0], [74.0, 114.0], [53.0, -42.0], [87.0, -51.0], [-23.0, -5.0], [50.0, 99.0], [61.0, -37.0], [11.0, 52.0], [-29.0, 164.0], [-30.0, -55.0], [-67.0, -26.0], [-37.0, -164.0], [-31.0, -55.0], [40.0, -40.0], [-65.0, -5.0], [50.0, -85.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_6fcd37f73a14653b7dfbe0fb8ad29ca3);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_78f865cba904c407579838002d60e8ca.addTo(map_6fcd37f73a14653b7dfbe0fb8ad29ca3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
