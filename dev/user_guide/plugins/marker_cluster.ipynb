# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60905acbed8cb208a18265d02c54d7eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60905acbed8cb208a18265d02c54d7eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60905acbed8cb208a18265d02c54d7eb = L.map(
#                 &quot;map_60905acbed8cb208a18265d02c54d7eb&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f4238ba9677d2bb3550aa5d03b5747e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f4238ba9677d2bb3550aa5d03b5747e.addTo(map_60905acbed8cb208a18265d02c54d7eb);
#
#
#             var marker_cluster_5e8326034f8d5c8028e83e0510f21312 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_a71a3550c5f8b6fa709296b61d521fc6 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_5e8326034f8d5c8028e83e0510f21312);
#
#
#             var icon_f0a1ab3bc87c5d70a6b8932504f74d02 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_60a319eaaeba790f0891e5921e802278 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1baf916f37952ff2b84ac5474945fc65 = $(`&lt;div id=&quot;html_1baf916f37952ff2b84ac5474945fc65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_60a319eaaeba790f0891e5921e802278.setContent(html_1baf916f37952ff2b84ac5474945fc65);
#
#
#
#         marker_a71a3550c5f8b6fa709296b61d521fc6.bindPopup(popup_60a319eaaeba790f0891e5921e802278)
#         ;
#
#
#
#
#                 marker_a71a3550c5f8b6fa709296b61d521fc6.setIcon(icon_f0a1ab3bc87c5d70a6b8932504f74d02);
#
#
#             var marker_c688dd4adae1094ae1465f80a49f8a2f = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_5e8326034f8d5c8028e83e0510f21312);
#
#
#             var icon_1514df4972d0e759fae39aec7b5ea93e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7ed76af5477ff8532847f9769962c88b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b09d2e4cb1c04bbabf4e465747abdc84 = $(`&lt;div id=&quot;html_b09d2e4cb1c04bbabf4e465747abdc84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7ed76af5477ff8532847f9769962c88b.setContent(html_b09d2e4cb1c04bbabf4e465747abdc84);
#
#
#
#         marker_c688dd4adae1094ae1465f80a49f8a2f.bindPopup(popup_7ed76af5477ff8532847f9769962c88b)
#         ;
#
#
#
#
#                 marker_c688dd4adae1094ae1465f80a49f8a2f.setIcon(icon_1514df4972d0e759fae39aec7b5ea93e);
#
#
#             var marker_dc0a48e3fed7e0def0494b31cea79dec = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_5e8326034f8d5c8028e83e0510f21312);
#
#
#         var popup_2bcb6921f8c5e9a55e09385f84c42bec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc3cf6455a78e6094c0136b30d0c6e28 = $(`&lt;div id=&quot;html_dc3cf6455a78e6094c0136b30d0c6e28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_2bcb6921f8c5e9a55e09385f84c42bec.setContent(html_dc3cf6455a78e6094c0136b30d0c6e28);
#
#
#
#         marker_dc0a48e3fed7e0def0494b31cea79dec.bindPopup(popup_2bcb6921f8c5e9a55e09385f84c42bec)
#         ;
#
#
#
#
#             marker_cluster_5e8326034f8d5c8028e83e0510f21312.addTo(map_60905acbed8cb208a18265d02c54d7eb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="pos

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e242b545ca952d02ee761639ed59eb5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e242b545ca952d02ee761639ed59eb5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e242b545ca952d02ee761639ed59eb5b = L.map(
#                 &quot;map_e242b545ca952d02ee761639ed59eb5b&quot;,
#                 {
#                     center: [-1.1, -2.82],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b5cfab0157c7b7e491f054629bb8536 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b5cfab0157c7b7e491f054629bb8536.addTo(map_e242b545ca952d02ee761639ed59eb5b);
#
#
#             var marker_cluster_e16b2c1eb4c63433e7e93b72599fcbb5 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_e16b2c1eb4c63433e7e93b72599fcbb5.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_436202b5ab5afaa24a5763334e49aa58 = L.marker(
#                 [-50.0, -1.0],
#                 {
# }
#             ).addTo(marker_cluster_e16b2c1eb4c63433e7e93b72599fcbb5);
#
#
#         var popup_f9973d982ddd73a6a93084c219a5c76c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a050a8884411a0263815a30a34102c0c = $(`&lt;div id=&quot;html_a050a8884411a0263815a30a34102c0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-1&lt;br&gt;lat:-50&lt;/div&gt;`)[0];
#                 popup_f9973d982ddd73a6a93084c219a5c76c.setContent(html_a050a8884411a0263815a30a34102c0c);
#
#
#
#         marker_436202b5ab5afaa24a5763334e49aa58.bindPopup(popup_f9973d982ddd73a6a93084c219a5c76c)
#         ;
#
#
#
#
#             var marker_83704975814d4db48da20cbe9045c3c2 = L.marker(
#                 [-1.0, -166.0],
#                 {
# }
#             ).addTo(marker_cluster_e16b2c1eb4c63433e7e93b72599fcbb5);
#
#
#         var popup_63d795ee052ae6ff7ea472792fa94fa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe00dff47fefeb4e01396c6420cfed5a = $(`&lt;div id=&quot;html_fe00dff47fefeb4e01396c6420cfed5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-166&lt;br&gt;lat:-1&lt;/div&gt;`)[0];
#                 popup_63d795ee052ae6ff7ea472792fa94fa8.setContent(html_fe00dff47fefeb4e01396c6420cfed5a);
#
#
#
#         marker_83704975814d4db48da20cbe9045c3c2.bindPopup(popup_63d795ee052ae6ff7ea472792fa94fa8)
#         ;
#
#
#
#
#             var marker_ee90cb9191380b8428ef832911875265 = L.marker(
#                 [53.0, 62.0],
#                 {
# }
#             ).addTo(marker_cluster_e16b2c1eb4c63433e7e93b72599fcbb5);
#
#
#         var popup_19ec03764a2cd4b5f3c76630a01e4a16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50df10cd03df840587e686226a7a428e = $(`&lt;div id=&quot;html_50df10cd03df840587e686226a7a428e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:62&lt;br&gt;lat:53&lt;/div&gt;`)[0];
#                 popup_19ec03764a2cd4b5f3c76630a01e4a16.setContent(html_50df10cd03df840587e686226a7a428e);
#
#
#
#         marker_ee90cb9191380b8428ef832911875265.bindPopup(popup_19ec03764a2cd4b5f3c76630a01e4a16)
#         ;
#
#
#
#
#             var marker_776f1a1cf5ce7a623b65741457e3dc31 = L.marker(
#                 [38.0, -26.0],
#                 {
# }
#             ).addTo(marker_cluster_e16b2c1eb4c63433e7e93b72599fcbb5);
#
#
#         var popup_5ffb6eb83c7425b9e0854c982ad1fc09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95f0f3a414e19c180d175e82b6f4d92f = $(`&lt;div id=&quot;html_95f0f3a414e19c180d175e82b6f4d92f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-26&lt;br&gt;lat:38&lt;/div&gt;`)[0];
#                 popup_5ffb6eb83c7425b9e0854c982ad1fc09.setContent(html_95f0f3a414e19c180d175e82b6f4d92f);

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20ee9587254fee1c3a38433b186ba578 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20ee9587254fee1c3a38433b186ba578&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20ee9587254fee1c3a38433b186ba578 = L.map(
#                 &quot;map_20ee9587254fee1c3a38433b186ba578&quot;,
#                 {
#                     center: [-1.1, -2.82],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f13a4713ff1d1dc297959b8e5949148a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f13a4713ff1d1dc297959b8e5949148a.addTo(map_20ee9587254fee1c3a38433b186ba578);
#
#
#             var marker_cluster_b11df13862ecf2eccd6cd2b93734b9cd = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_9e9be23114e1b4aeb7760fa2585d33ea = L.marker(
#                 [-50.0, -1.0],
#                 {
# }
#             ).addTo(marker_cluster_b11df13862ecf2eccd6cd2b93734b9cd);
#
#
#         var popup_88a3afd6091734ab57e9b0dec79f8043 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55db007ba3c737b4311a98c2943ece14 = $(`&lt;div id=&quot;html_55db007ba3c737b4311a98c2943ece14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-1&lt;br&gt;lat:-50&lt;/div&gt;`)[0];
#                 popup_88a3afd6091734ab57e9b0dec79f8043.setContent(html_55db007ba3c737b4311a98c2943ece14);
#
#
#
#         marker_9e9be23114e1b4aeb7760fa2585d33ea.bindPopup(popup_88a3afd6091734ab57e9b0dec79f8043)
#         ;
#
#
#
#
#             var marker_45d705d95469dc58dd26cea827af1e1a = L.marker(
#                 [-1.0, -166.0],
#                 {
# }
#             ).addTo(marker_cluster_b11df13862ecf2eccd6cd2b93734b9cd);
#
#
#         var popup_458551e1c53cead372fa0260b4d2722c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66e3f3148049e40411d99cde5adc9ab4 = $(`&lt;div id=&quot;html_66e3f3148049e40411d99cde5adc9ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-166&lt;br&gt;lat:-1&lt;/div&gt;`)[0];
#                 popup_458551e1c53cead372fa0260b4d2722c.setContent(html_66e3f3148049e40411d99cde5adc9ab4);
#
#
#
#         marker_45d705d95469dc58dd26cea827af1e1a.bindPopup(popup_458551e1c53cead372fa0260b4d2722c)
#         ;
#
#
#
#
#             var marker_3af170f70680c975795fafe7b8026d2d = L.marker(
#                 [53.0, 62.0],
#                 {
# }
#             ).addTo(marker_cluster_b11df13862ecf2eccd6cd2b93734b9cd);
#
#
#         var popup_7f7e036bf7f19d5366b22b495cfd3c1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc8d1b77596a27db0b18e6d4cb28b2a5 = $(`&lt;div id=&quot;html_dc8d1b77596a27db0b18e6d4cb28b2a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:62&lt;br&gt;lat:53&lt;/div&gt;`)[0];
#                 popup_7f7e036bf7f19d5366b22b495cfd3c1a.setContent(html_dc8d1b77596a27db0b18e6d4cb28b2a5);
#
#
#
#         marker_3af170f70680c975795fafe7b8026d2d.bindPopup(popup_7f7e036bf7f19d5366b22b495cfd3c1a)
#         ;
#
#
#
#
#             var marker_70f60fc1e899907e70f9a3b0be88c4ca = L.marker(
#                 [38.0, -26.0],
#                 {
# }
#             ).addTo(marker_cluster_b11df13862ecf2eccd6cd2b93734b9cd);
#
#
#         var popup_fc044394594cc21c81625b5ae977f8f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9519780a5ba5e115c60920bfecc8629 = $(`&lt;div id=&quot;html_d9519780a5ba5e115c60920bfecc8629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-26&lt;br&gt;lat:38&lt;/div&gt;`)[0];
#                 popup_fc044394594cc21c81625b5ae977f8f8.setContent(html_d9519780a5ba5e115c60920bfecc8629);
#
#
#
#         marker_70f60fc1e899907e70f9a3b0be88c4ca.bindPopup(popup_fc044394594cc21c81625b5ae977f8f8)
#         ;
#
#
#
#
#             var marker_999cc3dbe6eeec62a0aa5b4f3cd91802 = L.marker(
#                 [25.0, 129.0],
#                 {
# }
#             ).addTo(marker_cluster_b11df13862ecf2eccd6cd2b93734b9cd);

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f340513a002d4cc12798b5b1ffca808 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f340513a002d4cc12798b5b1ffca808&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f340513a002d4cc12798b5b1ffca808 = L.map(
#                 &quot;map_4f340513a002d4cc12798b5b1ffca808&quot;,
#                 {
#                     center: [-1.1, -2.82],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e12169ceb08105a6ab9f511cecaf0608 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_