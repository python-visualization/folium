# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdbe56ff5120693e672d8ada19e82b73 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#
#
#
#
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdbe56ff5120693e672d8ada19e82b73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdbe56ff5120693e672d8ada19e82b73 = L.map(
#                 &quot;map_fdbe56ff5120693e672d8ada19e82b73&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c20a7646e60de5cb94ed92ded51cbc5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c20a7646e60de5cb94ed92ded51cbc5a.addTo(map_fdbe56ff5120693e672d8ada19e82b73);
#
#
#             var marker_cluster_32c099ced110d394935eccb13313add3 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_9d02a3a0ff7dc3b4d7c8bfc6810ddc4b = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_32c099ced110d394935eccb13313add3);
#
#
#             var icon_b7e73dee3e5bc2494994a5c26e4b5907 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_272c0db39d18d893d8c7cc562c576f12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c6ae62c661a4e3ceabedb67b993f3e6 = $(`&lt;div id=&quot;html_0c6ae62c661a4e3ceabedb67b993f3e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_272c0db39d18d893d8c7cc562c576f12.setContent(html_0c6ae62c661a4e3ceabedb67b993f3e6);
#
#
#
#         marker_9d02a3a0ff7dc3b4d7c8bfc6810ddc4b.bindPopup(popup_272c0db39d18d893d8c7cc562c576f12)
#         ;
#
#
#
#
#                 marker_9d02a3a0ff7dc3b4d7c8bfc6810ddc4b.setIcon(icon_b7e73dee3e5bc2494994a5c26e4b5907);
#
#
#             var marker_73fcf26545b8bc88bf7880189b4a2835 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_32c099ced110d394935eccb13313add3);
#
#
#             var icon_0b819309e8d669841ca2d124a34f1364 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ee05b8893bb99adcaa30bbad651669b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fab5c890fb61812490a6e3e00a1b8a0 = $(`&lt;div id=&quot;html_6fab5c890fb61812490a6e3e00a1b8a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ee05b8893bb99adcaa30bbad651669b0.setContent(html_6fab5c890fb61812490a6e3e00a1b8a0);
#
#
#
#         marker_73fcf26545b8bc88bf7880189b4a2835.bindPopup(popup_ee05b8893bb99adcaa30bbad651669b0)
#         ;
#
#
#
#
#                 marker_73fcf26545b8bc88bf7880189b4a2835.setIcon(icon_0b819309e8d669841ca2d124a34f1364);
#
#
#             var marker_27c4deccaf15c64bf52200df6f53cfd4 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_32c099ced110d394935eccb13313add3);
#
#
#         var popup_ead34758f511fa04f65daadeadbfa9d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71627f86b7ca2b1b3226fabb13294753 = $(`&lt;div id=&quot;html_71627f86b7ca2b1b3226fabb13294753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ead34758f511fa04f65daadeadbfa9d5.setContent(html_71627f86b7ca2b1b3226fabb13294753);
#
#
#
#         marker_27c4deccaf15c64bf52200df6f53cfd4.bindPopup(popup_ead34758f511fa04f65daadeadbfa9d5)
#         ;
#
#
#
#
#             marker_cluster_32c099ced110d394935eccb13313add3.addTo(map_fdbe

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f669200d7366d8884283e71ac8a628a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f669200d7366d8884283e71ac8a628a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f669200d7366d8884283e71ac8a628a = L.map(
#                 &quot;map_0f669200d7366d8884283e71ac8a628a&quot;,
#                 {
#                     center: [-13.68, -14.74],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1589616c1a1537555ca1c36a034191db = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1589616c1a1537555ca1c36a034191db.addTo(map_0f669200d7366d8884283e71ac8a628a);
#
#
#             var marker_cluster_ef776a721ab1c1a63ad792a66a39a1df = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_ef776a721ab1c1a63ad792a66a39a1df.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_695e173eba364bd7109a4a7aa5741546 = L.marker(
#                 [-3.0, -14.0],
#                 {
# }
#             ).addTo(marker_cluster_ef776a721ab1c1a63ad792a66a39a1df);
#
#
#         var popup_3be20894bc9a50472442d0ea34a49385 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7447faccc3e462694a44fed2b96252c3 = $(`&lt;div id=&quot;html_7447faccc3e462694a44fed2b96252c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-14&lt;br&gt;lat:-3&lt;/div&gt;`)[0];
#                 popup_3be20894bc9a50472442d0ea34a49385.setContent(html_7447faccc3e462694a44fed2b96252c3);
#
#
#
#         marker_695e173eba364bd7109a4a7aa5741546.bindPopup(popup_3be20894bc9a50472442d0ea34a49385)
#         ;
#
#
#
#
#             var marker_1cfc8e3a240bf30956b1fb9de180c484 = L.marker(
#                 [67.0, 21.0],
#                 {
# }
#             ).addTo(marker_cluster_ef776a721ab1c1a63ad792a66a39a1df);
#
#
#         var popup_3a3a65be76cfc1ce006904f9a3564d73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_392393f09d8d69691f3eac1097e8f5fd = $(`&lt;div id=&quot;html_392393f09d8d69691f3eac1097e8f5fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:21&lt;br&gt;lat:67&lt;/div&gt;`)[0];
#                 popup_3a3a65be76cfc1ce006904f9a3564d73.setContent(html_392393f09d8d69691f3eac1097e8f5fd);
#
#
#
#         marker_1cfc8e3a240bf30956b1fb9de180c484.bindPopup(popup_3a3a65be76cfc1ce006904f9a3564d73)
#         ;
#
#
#
#
#             var marker_10ab73270552513313c4a16132de4d70 = L.marker(
#                 [1.0, 17.0],
#                 {
# }
#             ).addTo(marker_cluster_ef776a721ab1c1a63ad792a66a39a1df);
#
#
#         var popup_e20ca83d105a265702893b41ad0d6d69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cda5f30dd3212e625a36cfe19abc56ee = $(`&lt;div id=&quot;html_cda5f30dd3212e625a36cfe19abc56ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:17&lt;br&gt;lat:1&lt;/div&gt;`)[0];
#                 popup_e20ca83d105a265702893b41ad0d6d69.setContent(html_cda5f30dd3212e625a36cfe19abc56ee);
#
#
#
#         marker_10ab73270552513313c4a16132de4d70.bindPopup(popup_e20ca83d105a265702893b41ad0d6d69)
#         ;
#
#
#
#
#             var marker_443825870c882de75bd48bf6921a599c = L.marker(
#                 [-15.0, -30.0],
#                 {
# }
#             ).addTo(marker_cluster_ef776a721ab1c1a63ad792a66a39a1df);
#
#
#         var popup_86bf6289f38ec49233ed21a0a164a56e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da52211c6e58e3d728943a77c5e00457 = $(`&lt;div id=&quot;html_da52211c6e58e3d728943a77c5e00457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-30&lt;br&gt;lat:-15&lt;/div&gt;`)[0];
#                 popup_86bf6289f38ec49233ed21a0a164a56e.setContent(html_da52211c6

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7e164493202efe5956c002c5cb63a1b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7e164493202efe5956c002c5cb63a1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7e164493202efe5956c002c5cb63a1b = L.map(
#                 &quot;map_e7e164493202efe5956c002c5cb63a1b&quot;,
#                 {
#                     center: [-13.68, -14.74],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a0598b790edfab4a536e0af005b0701 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a0598b790edfab4a536e0af005b0701.addTo(map_e7e164493202efe5956c002c5cb63a1b);
#
#
#             var marker_cluster_bc34b5bb21a28ba1ecef5788888ec9dd = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_9e1928f14fa94652432972d51241d5f6 = L.marker(
#                 [-3.0, -14.0],
#                 {
# }
#             ).addTo(marker_cluster_bc34b5bb21a28ba1ecef5788888ec9dd);
#
#
#         var popup_52f2992eba53f5f0f27b92bf8fcddc47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9818dc089e5703c11d331888faad3534 = $(`&lt;div id=&quot;html_9818dc089e5703c11d331888faad3534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-14&lt;br&gt;lat:-3&lt;/div&gt;`)[0];
#                 popup_52f2992eba53f5f0f27b92bf8fcddc47.setContent(html_9818dc089e5703c11d331888faad3534);
#
#
#
#         marker_9e1928f14fa94652432972d51241d5f6.bindPopup(popup_52f2992eba53f5f0f27b92bf8fcddc47)
#         ;
#
#
#
#
#             var marker_9ede74b7cd381da7b85749d9d0bc0964 = L.marker(
#                 [67.0, 21.0],
#                 {
# }
#             ).addTo(marker_cluster_bc34b5bb21a28ba1ecef5788888ec9dd);
#
#
#         var popup_2a5be38c1e0a705571322dad2a3167b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_598938a7f360f1b8fa7e20ceeb877fa3 = $(`&lt;div id=&quot;html_598938a7f360f1b8fa7e20ceeb877fa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:21&lt;br&gt;lat:67&lt;/div&gt;`)[0];
#                 popup_2a5be38c1e0a705571322dad2a3167b9.setContent(html_598938a7f360f1b8fa7e20ceeb877fa3);
#
#
#
#         marker_9ede74b7cd381da7b85749d9d0bc0964.bindPopup(popup_2a5be38c1e0a705571322dad2a3167b9)
#         ;
#
#
#
#
#             var marker_040b3f5a99bdfd5a56ef5845024b00f8 = L.marker(
#                 [1.0, 17.0],
#                 {
# }
#             ).addTo(marker_cluster_bc34b5bb21a28ba1ecef5788888ec9dd);
#
#
#         var popup_29a3f6896955fce9e76101095c557c06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80c397cf86eb69fec07caa6239caa4c5 = $(`&lt;div id=&quot;html_80c397cf86eb69fec07caa6239caa4c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:17&lt;br&gt;lat:1&lt;/div&gt;`)[0];
#                 popup_29a3f6896955fce9e76101095c557c06.setContent(html_80c397cf86eb69fec07caa6239caa4c5);
#
#
#
#         marker_040b3f5a99bdfd5a56ef5845024b00f8.bindPopup(popup_29a3f6896955fce9e76101095c557c06)
#         ;
#
#
#
#
#             var marker_ef3e4909ed099d59737904fa12570378 = L.marker(
#                 [-15.0, -30.0],
#                 {
# }
#             ).addTo(marker_cluster_bc34b5bb21a28ba1ecef5788888ec9dd);
#
#
#         var popup_f1ddf52d07c4ee40e93bf4731a565eb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6919b0e0f833386cac2c208665e8e731 = $(`&lt;div id=&quot;html_6919b0e0f833386cac2c208665e8e731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-30&lt;br&gt;lat:-15&lt;/div&gt;`)[0];
#                 popup_f1ddf52d07c4ee40e93bf4731a565eb7.setContent(html_6919b0e0f833386cac2c208665e8e731);
#
#
#
#         marker_ef3e4909ed099d59737904fa12570378.bindPopup(popup_f1ddf52d07c4ee40e93bf4731a565eb7)
#         ;
#
#
#
#
#             var marker_4c580bccf6e544e8cb38ecb2c6862707 = L.marker(
#                 [-68.0, -124.0],
#                 {
# }
#             ).addTo(marker_cluster_bc34b5bb

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e585491c077cbafc796b458049359822 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e585491c077cbafc796b458049359822&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_