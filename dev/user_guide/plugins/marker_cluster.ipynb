# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d6cc9c5682c6f68b7395e35de7c1b3d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#
#
#
#
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d6cc9c5682c6f68b7395e35de7c1b3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d6cc9c5682c6f68b7395e35de7c1b3d = L.map(
#                 &quot;map_2d6cc9c5682c6f68b7395e35de7c1b3d&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e895bcf30aa7a9942ab270c3810e4ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e895bcf30aa7a9942ab270c3810e4ee.addTo(map_2d6cc9c5682c6f68b7395e35de7c1b3d);
#
#
#             var marker_cluster_ceaae0fcaa4cebfadbaa91776a7c7ce8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b26419d70b5553db4833f601cbe0702f = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_ceaae0fcaa4cebfadbaa91776a7c7ce8);
#
#
#             var icon_e29234b33fb57d3296adecfac38cc2e4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c9e417f1adcdb0e0200f3ba1c032cb2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf05f6305b01d842a4d51bec50089e1e = $(`&lt;div id=&quot;html_cf05f6305b01d842a4d51bec50089e1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_c9e417f1adcdb0e0200f3ba1c032cb2a.setContent(html_cf05f6305b01d842a4d51bec50089e1e);
#
#
#
#         marker_b26419d70b5553db4833f601cbe0702f.bindPopup(popup_c9e417f1adcdb0e0200f3ba1c032cb2a)
#         ;
#
#
#
#
#                 marker_b26419d70b5553db4833f601cbe0702f.setIcon(icon_e29234b33fb57d3296adecfac38cc2e4);
#
#
#             var marker_9420fd384c72a9195a9b7a6bc3da64f9 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_ceaae0fcaa4cebfadbaa91776a7c7ce8);
#
#
#             var icon_4db90217a4351bb3a5f9a896201cae25 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a0d4ab84e0424883e6663edc07535c1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9475546a10142702ec90c9f6718f0aa = $(`&lt;div id=&quot;html_a9475546a10142702ec90c9f6718f0aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_a0d4ab84e0424883e6663edc07535c1b.setContent(html_a9475546a10142702ec90c9f6718f0aa);
#
#
#
#         marker_9420fd384c72a9195a9b7a6bc3da64f9.bindPopup(popup_a0d4ab84e0424883e6663edc07535c1b)
#         ;
#
#
#
#
#                 marker_9420fd384c72a9195a9b7a6bc3da64f9.setIcon(icon_4db90217a4351bb3a5f9a896201cae25);
#
#
#             var marker_3429722c6b82edc3a945bc49b415c221 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_ceaae0fcaa4cebfadbaa91776a7c7ce8);
#
#
#         var popup_07ce4dc8cf262cceb2ff70265657249f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c836d77afa3e692df08e14710c34e279 = $(`&lt;div id=&quot;html_c836d77afa3e692df08e14710c34e279&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_07ce4dc8cf262cceb2ff70265657249f.setContent(html_c836d77afa3e692df08e14710c34e279);
#
#
#
#         marker_3429722c6b82edc3a945bc49b415c221.bindPopup(popup_07ce4dc8cf262cceb2ff70265657249f)
#         ;
#
#
#
#
#             marker_cluster_ceaae0fcaa4cebfadbaa91776a7c7ce8.addTo(map_2d6c

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# /home/runner/work/folium/folium/folium/raster_layers.py:128: UserWarning: CartoDB tiles now require an API key. Please provide one to continue using the tiles. You can request the key at https://carto.com/basemaps/apikey/.
#   tiles = tiles.build_url(fill_subdomain=False, scale_factor="{r}")  # type: ignore
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fa8f2f58c97a340a055319e2595007c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fa8f2f58c97a340a055319e2595007c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fa8f2f58c97a340a055319e2595007c = L.map(
#                 &quot;map_2fa8f2f58c97a340a055319e2595007c&quot;,
#                 {
#                     center: [1.42, -14.46],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5aa63da03b3e93e7b082ac0503f045a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5aa63da03b3e93e7b082ac0503f045a.addTo(map_2fa8f2f58c97a340a055319e2595007c);
#
#
#             var marker_cluster_48527e64da8da5c7bbd68dd498c30511 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_48527e64da8da5c7bbd68dd498c30511.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_a7eb6af77bf7c107959f097afe0f2a5f = L.marker(
#                 [-55.0, -164.0],
#                 {
# }
#             ).addTo(marker_cluster_48527e64da8da5c7bbd68dd498c30511);
#
#
#         var popup_4a7786c7fb07209b0c254ccc4e55de43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f5c896b065b97da21f8116a626ce403 = $(`&lt;div id=&quot;html_6f5c896b065b97da21f8116a626ce403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-164&lt;br&gt;lat:-55&lt;/div&gt;`)[0];
#                 popup_4a7786c7fb07209b0c254ccc4e55de43.setContent(html_6f5c896b065b97da21f8116a626ce403);
#
#
#
#         marker_a7eb6af77bf7c107959f097afe0f2a5f.bindPopup(popup_4a7786c7fb07209b0c254ccc4e55de43)
#         ;
#
#
#
#
#             var marker_5b21accd6e7a6e40fe973263bb19b5b3 = L.marker(
#                 [0.0, -148.0],
#                 {
# }
#             ).addTo(marker_cluster_48527e64da8da5c7bbd68dd498c30511);
#
#
#         var popup_9b6b942dfed92cdee888b256d8da4731 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e38cc15c33c54dcbe5d46e560761d31 = $(`&lt;div id=&quot;html_1e38cc15c33c54dcbe5d46e560761d31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-148&lt;br&gt;lat:0&lt;/div&gt;`)[0];
#                 popup_9b6b942dfed92cdee888b256d8da4731.setContent(html_1e38cc15c33c54dcbe5d46e560761d31);
#
#
#
#         marker_5b21accd6e7a6e40fe973263bb19b5b3.bindPopup(popup_9b6b942dfed92cdee888b256d8da4731)
#         ;
#
#
#
#
#             var marker_db95338b57d15272801a1e4ea15b62c5 = L.marker(
#                 [-21.0, 11.0],
#                 {
# }
#             ).addTo(marker_cluster_48527e64da8da5c7bbd68dd498c30511);
#
#
#         var popup_275300545417edc059bd3d7ea6d294e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_679ad4008c8baeaed5ae61a22889fd42 = $(`&lt;div id=&quot;html_679ad4008c8baeaed5ae61a22889fd42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:11&lt;br&gt;lat:-21&lt;/div&gt;`)[0];
#                 popup_275300545417edc059bd3d7ea6d294e3.setContent(html_679ad4008c8baeaed5ae61a22889fd42);
#
#
#
#         marker_db95338b57d15272801a1e4ea15b62c5.bindPopup(popup_275300545417edc059bd3d7ea6d294e3)
#         ;
#
#
#
#
#             var marker_a9ed4f4b32e0c7db0c8a79892acf0b79 = L.marker(
#                 [-37.0, -171.0],
#                 {
# }
#             ).addTo(marker_cluster_48527e64da8da5c7bbd68dd498c30511);
#
#
#         var popup_0aa92dc5f83d5d63cea2b6ba05fa291b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d590d615dd0173fbe598010f26197e0f = $(`&lt;div id=&quot;html_d590d615dd0173fbe598010f26197e0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-171&lt;br&gt;lat:-37&lt;/div&gt;`)[0];
#                 popup_0aa92dc5f83d5d63cea2b6ba05fa291b.setContent(html

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e53942381d5a15b5d754513330d867d0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e53942381d5a15b5d754513330d867d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e53942381d5a15b5d754513330d867d0 = L.map(
#                 &quot;map_e53942381d5a15b5d754513330d867d0&quot;,
#                 {
#                     center: [1.42, -14.46],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cefd57fb570b90d1503d727859abe9fb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cefd57fb570b90d1503d727859abe9fb.addTo(map_e53942381d5a15b5d754513330d867d0);
#
#
#             var marker_cluster_a7af36524455924b07e4f1a1d0b14bdb = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_549b57bf3d8c6f4f5a1cf5f347fe0fd7 = L.marker(
#                 [-55.0, -164.0],
#                 {
# }
#             ).addTo(marker_cluster_a7af36524455924b07e4f1a1d0b14bdb);
#
#
#         var popup_929c6ca385863dc8a99742ed794d0ffd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7c8c1a3a4f76cb7572c97dd52d8b014 = $(`&lt;div id=&quot;html_e7c8c1a3a4f76cb7572c97dd52d8b014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-164&lt;br&gt;lat:-55&lt;/div&gt;`)[0];
#                 popup_929c6ca385863dc8a99742ed794d0ffd.setContent(html_e7c8c1a3a4f76cb7572c97dd52d8b014);
#
#
#
#         marker_549b57bf3d8c6f4f5a1cf5f347fe0fd7.bindPopup(popup_929c6ca385863dc8a99742ed794d0ffd)
#         ;
#
#
#
#
#             var marker_5912ebf8b6b65d27710660d3c092ccb3 = L.marker(
#                 [0.0, -148.0],
#                 {
# }
#             ).addTo(marker_cluster_a7af36524455924b07e4f1a1d0b14bdb);
#
#
#         var popup_f9f8edb2ff26acc42eb8522f51505411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd8cc8be8bfba99ebebe3f05fdb52541 = $(`&lt;div id=&quot;html_fd8cc8be8bfba99ebebe3f05fdb52541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-148&lt;br&gt;lat:0&lt;/div&gt;`)[0];
#                 popup_f9f8edb2ff26acc42eb8522f51505411.setContent(html_fd8cc8be8bfba99ebebe3f05fdb52541);
#
#
#
#         marker_5912ebf8b6b65d27710660d3c092ccb3.bindPopup(popup_f9f8edb2ff26acc42eb8522f51505411)
#         ;
#
#
#
#
#             var marker_80854c0f73119950803cc2e8f7b56d9e = L.marker(
#                 [-21.0, 11.0],
#                 {
# }
#             ).addTo(marker_cluster_a7af36524455924b07e4f1a1d0b14bdb);
#
#
#         var popup_df41d7b604310adf5733ce5332ca3008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb488687991fccfe9e0ece1d4d0614bd = $(`&lt;div id=&quot;html_fb488687991fccfe9e0ece1d4d0614bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:11&lt;br&gt;lat:-21&lt;/div&gt;`)[0];
#                 popup_df41d7b604310adf5733ce5332ca3008.setContent(html_fb488687991fccfe9e0ece1d4d0614bd);
#
#
#
#         marker_80854c0f73119950803cc2e8f7b56d9e.bindPopup(popup_df41d7b604310adf5733ce5332ca3008)
#         ;
#
#
#
#
#             var marker_9e4ed9afc91638bff7e8bd7d225a05d9 = L.marker(
#                 [-37.0, -171.0],
#                 {
# }
#             ).addTo(marker_cluster_a7af36524455924b07e4f1a1d0b14bdb);
#
#
#         var popup_e4d8f53cc69346393ac823f46e799189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15824a4cf367051ca59d6d09c2a22fc9 = $(`&lt;div id=&quot;html_15824a4cf367051ca59d6d09c2a22fc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-171&lt;br&gt;lat:-37&lt;/div&gt;`)[0];
#                 popup_e4d8f53cc69346393ac823f46e799189.setContent(html_15824a4cf367051ca59d6d09c2a22fc9);
#
#
#
#         marker_9e4ed9afc91638bff7e8bd7d225a05d9.bindPopup(popup_e4d8f53cc69346393ac823f46e799189)
#         ;
#
#
#
#
#             var marker_f5c2ac09b433332907ace2837d78ee7f = L.marker(
#                 [-82.0, 78.0],
#                 {
# }
#             ).addTo(marker_cluster_

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efecfcbdd6121ff68d74a5c5d64d1cd0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efecfcbdd6121ff68d74a5c5d64d1cd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efecfcbdd6121ff68d74a5c5d64d1cd0 = L.map(
#                 &quot;map_efecfcbdd6121ff68d74a5c5d64d1cd0&quot;,
#                 {
#                     center: [1.42, -14.46],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90d0c22f02789efc13e0459c312ec6cd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_