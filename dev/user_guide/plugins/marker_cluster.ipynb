# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73a98f25cbcb5e9f5dca308c849b7b0b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#
#
#
#
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73a98f25cbcb5e9f5dca308c849b7b0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73a98f25cbcb5e9f5dca308c849b7b0b = L.map(
#                 &quot;map_73a98f25cbcb5e9f5dca308c849b7b0b&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95bc5f95934e52c5735e140366d362d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95bc5f95934e52c5735e140366d362d1.addTo(map_73a98f25cbcb5e9f5dca308c849b7b0b);
#
#
#             var marker_cluster_d2abc969250bd414562335dbfb6b6cdd = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_dc4ee15097c6188a6adbde10b087fb18 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_d2abc969250bd414562335dbfb6b6cdd);
#
#
#             var icon_64e564fb8b729998b66172d7778aa2dc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_210d8ccb8086da2aa366f69dc65d0f97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c11d64140d32a2247c24edf04b0e89d3 = $(`&lt;div id=&quot;html_c11d64140d32a2247c24edf04b0e89d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_210d8ccb8086da2aa366f69dc65d0f97.setContent(html_c11d64140d32a2247c24edf04b0e89d3);
#
#
#
#         marker_dc4ee15097c6188a6adbde10b087fb18.bindPopup(popup_210d8ccb8086da2aa366f69dc65d0f97)
#         ;
#
#
#
#
#                 marker_dc4ee15097c6188a6adbde10b087fb18.setIcon(icon_64e564fb8b729998b66172d7778aa2dc);
#
#
#             var marker_5eb0194d5ddcbd57a716be36b20dbc31 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_d2abc969250bd414562335dbfb6b6cdd);
#
#
#             var icon_47d4fd6e115c30bfb013476010d964aa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9351b82bcbfde19b5485b0b0540b6b0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce1cfa57d285f5483f9325e49953835d = $(`&lt;div id=&quot;html_ce1cfa57d285f5483f9325e49953835d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_9351b82bcbfde19b5485b0b0540b6b0e.setContent(html_ce1cfa57d285f5483f9325e49953835d);
#
#
#
#         marker_5eb0194d5ddcbd57a716be36b20dbc31.bindPopup(popup_9351b82bcbfde19b5485b0b0540b6b0e)
#         ;
#
#
#
#
#                 marker_5eb0194d5ddcbd57a716be36b20dbc31.setIcon(icon_47d4fd6e115c30bfb013476010d964aa);
#
#
#             var marker_7aa4e2a4bc221414a58518a66cf61ea3 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_d2abc969250bd414562335dbfb6b6cdd);
#
#
#         var popup_b8ece5dec289073c34c95097b4fb43d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cded16f74cc568207364f3cade871f3 = $(`&lt;div id=&quot;html_4cded16f74cc568207364f3cade871f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_b8ece5dec289073c34c95097b4fb43d6.setContent(html_4cded16f74cc568207364f3cade871f3);

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a335bc2c14981c0fa573d25bbcc9fc1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a335bc2c14981c0fa573d25bbcc9fc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a335bc2c14981c0fa573d25bbcc9fc1 = L.map(
#                 &quot;map_4a335bc2c14981c0fa573d25bbcc9fc1&quot;,
#                 {
#                     center: [3.78, 6.24],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d1560ac9c247c111e7eb8c981af472c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d1560ac9c247c111e7eb8c981af472c.addTo(map_4a335bc2c14981c0fa573d25bbcc9fc1);
#
#
#             var marker_cluster_789ebd8c5dde4746a329c219cd99a69f = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_789ebd8c5dde4746a329c219cd99a69f.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_7e69b43765428033707668a7c2298eb2 = L.marker(
#                 [-40.0, 28.0],
#                 {
# }
#             ).addTo(marker_cluster_789ebd8c5dde4746a329c219cd99a69f);
#
#
#         var popup_64aa09001f3341ca509a9e0293a085c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d95f5bcb9cfe830125b1ca018ea284fc = $(`&lt;div id=&quot;html_d95f5bcb9cfe830125b1ca018ea284fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:28&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_64aa09001f3341ca509a9e0293a085c1.setContent(html_d95f5bcb9cfe830125b1ca018ea284fc);
#
#
#
#         marker_7e69b43765428033707668a7c2298eb2.bindPopup(popup_64aa09001f3341ca509a9e0293a085c1)
#         ;
#
#
#
#
#             var marker_a186859c0ccb7ea4f2d92e9582ce168c = L.marker(
#                 [-37.0, 100.0],
#                 {
# }
#             ).addTo(marker_cluster_789ebd8c5dde4746a329c219cd99a69f);
#
#
#         var popup_f5b2f044250cc5deb3c488ea462ec6ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a660c8a13d363cee85c009e3c7f07e1c = $(`&lt;div id=&quot;html_a660c8a13d363cee85c009e3c7f07e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:100&lt;br&gt;lat:-37&lt;/div&gt;`)[0];
#                 popup_f5b2f044250cc5deb3c488ea462ec6ca.setContent(html_a660c8a13d363cee85c009e3c7f07e1c);
#
#
#
#         marker_a186859c0ccb7ea4f2d92e9582ce168c.bindPopup(popup_f5b2f044250cc5deb3c488ea462ec6ca)
#         ;
#
#
#
#
#             var marker_2d94f2e47120ce3bd74c065061421bfc = L.marker(
#                 [66.0, 140.0],
#                 {
# }
#             ).addTo(marker_cluster_789ebd8c5dde4746a329c219cd99a69f);
#
#
#         var popup_7bdb63f108d5dc387399981a6f8afdce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2443f98e8335e64e77e4f0c6db9592c = $(`&lt;div id=&quot;html_f2443f98e8335e64e77e4f0c6db9592c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:140&lt;br&gt;lat:66&lt;/div&gt;`)[0];
#                 popup_7bdb63f108d5dc387399981a6f8afdce.setContent(html_f2443f98e8335e64e77e4f0c6db9592c);
#
#
#
#         marker_2d94f2e47120ce3bd74c065061421bfc.bindPopup(popup_7bdb63f108d5dc387399981a6f8afdce)
#         ;
#
#
#
#
#             var marker_2600870fa48e38ffd972d0146b2565c7 = L.marker(
#                 [-66.0, 38.0],
#                 {
# }
#             ).addTo(marker_cluster_789ebd8c5dde4746a329c219cd99a69f);
#
#
#         var popup_48ac71d1752a6e4a0a8673e9f78b943b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b63dff0f659b5c1a46b4bfc86b0d3e8 = $(`&lt;div id=&quot;html_

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_840781d8977984c657f09bf4776f8e10 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_840781d8977984c657f09bf4776f8e10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_840781d8977984c657f09bf4776f8e10 = L.map(
#                 &quot;map_840781d8977984c657f09bf4776f8e10&quot;,
#                 {
#                     center: [3.78, 6.24],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74198126deb4a286496a11fd896bc4d7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74198126deb4a286496a11fd896bc4d7.addTo(map_840781d8977984c657f09bf4776f8e10);
#
#
#             var marker_cluster_ac691cdceba472bceaa5ad3250fcee34 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_911b262ea12caff0f3d5f43d08dd4685 = L.marker(
#                 [-40.0, 28.0],
#                 {
# }
#             ).addTo(marker_cluster_ac691cdceba472bceaa5ad3250fcee34);
#
#
#         var popup_f1d7e03d6d0cd64b129d7c4ab5573776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9da381527f4b0b9ebae833a43fa3c11a = $(`&lt;div id=&quot;html_9da381527f4b0b9ebae833a43fa3c11a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:28&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_f1d7e03d6d0cd64b129d7c4ab5573776.setContent(html_9da381527f4b0b9ebae833a43fa3c11a);
#
#
#
#         marker_911b262ea12caff0f3d5f43d08dd4685.bindPopup(popup_f1d7e03d6d0cd64b129d7c4ab5573776)
#         ;
#
#
#
#
#             var marker_513266cc965952e3178069d5e6e838a1 = L.marker(
#                 [-37.0, 100.0],
#                 {
# }
#             ).addTo(marker_cluster_ac691cdceba472bceaa5ad3250fcee34);
#
#
#         var popup_f50f0de56f2cef4bff2a24c8f1e827e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62ed696dc83eef0131474bb3f527efb5 = $(`&lt;div id=&quot;html_62ed696dc83eef0131474bb3f527efb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:100&lt;br&gt;lat:-37&lt;/div&gt;`)[0];
#                 popup_f50f0de56f2cef4bff2a24c8f1e827e1.setContent(html_62ed696dc83eef0131474bb3f527efb5);
#
#
#
#         marker_513266cc965952e3178069d5e6e838a1.bindPopup(popup_f50f0de56f2cef4bff2a24c8f1e827e1)
#         ;
#
#
#
#
#             var marker_a373ffc94e33541cf28d3dae580abfc2 = L.marker(
#                 [66.0, 140.0],
#                 {
# }
#             ).addTo(marker_cluster_ac691cdceba472bceaa5ad3250fcee34);
#
#
#         var popup_27db48581b1af3cd6d94f226203ad45c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b0dd45703e67fe38dd7df0185f2018d = $(`&lt;div id=&quot;html_5b0dd45703e67fe38dd7df0185f2018d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:140&lt;br&gt;lat:66&lt;/div&gt;`)[0];
#                 popup_27db48581b1af3cd6d94f226203ad45c.setContent(html_5b0dd45703e67fe38dd7df0185f2018d);
#
#
#
#         marker_a373ffc94e33541cf28d3dae580abfc2.bindPopup(popup_27db48581b1af3cd6d94f226203ad45c)
#         ;
#
#
#
#
#             var marker_c27520db3e77e50a1edcbf07acb3ae47 = L.marker(
#                 [-66.0, 38.0],
#                 {
# }
#             ).addTo(marker_cluster_ac691cdceba472bceaa5ad3250fcee34);
#
#
#         var popup_be84b73df18aa8e4dac5802f36f69393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74b5a33e4e6534de7da264538c659453 = $(`&lt;div id=&quot;html_74b5a33e4e6534de7da264538c659453&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:38&lt;br&gt;lat:-66&lt;/div&gt;`)[0];
#                 popup_be84b73df18aa8e4dac5802f36f69393.setContent(html_74b5a33e4e6534de7da264538c659453);
#
#
#
#         marker_c27520db3e77e50a1edcbf07acb3ae47.bindPopup(popup_be84b73df18aa8e

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbd337840b2bc7bc16aaa27f879c5036 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbd337840b2bc7bc16aaa27f879c5036&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbd337840b2bc7bc16aaa27f879c5036 = L.map(
#                 &quot;map_bbd337840b2bc7bc16aaa27f879c5036&quot;,
#                 {
#                     center: [3.78, 6.24],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2c12dd5f33bc24126a08840bf7f6818 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2c12dd5f33bc24126a08840bf7f6818.addTo(map_bbd337840b2bc7bc16aaa27f879c5036);
#
#
#             var fast_marker_cluster_0cb2618c8b57f87ebf0e8f060bdf4364 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-40.0, 28.0], [-37.0, 100.0], [66.0, 140.0], [-66.0, 38.0], [-35.0, -21.0], [-35.0, 145.0], [-72.0, 45.0], [-74.0, 101.0], [-81.0, 53.0], [-14.0, 83.0], [73.0, 71.0], [21.0, 93.0], [-72.0, 40.0], [21.0, -62.0], [9.0, -141.0], [80.0, -152.0], [-27.0, -58.0], [41.0, 113.0], [-18.0, 172.0], [3.0, -64.0], [-57.0, 64.0], [58.0, -70.0], [71.0, 69.0], [-72.0, 77.0], [81.0, 71.0], [51.0, -60.0], [7.0, 126.0], [-15.0, 176.0], [23.0, -162.0], [45.0, -4.0], [26.0, 79.0], [2.0, -111.0], [29.0, 70.0], [12.0, -109.0], [31.0, 52.0], [53.0, -154.0], [-49.0, -111.0], [-35.0, 44.0], [2.0, 97.0], [-32.0, 109.0], [-44.0, -164.0], [78.0, 177.0], [38.0, 28.0], [89.0, -160.0], [-72.0, -168.0], [-83.0, -102.0], [-71.0, 2.0], [-32.0, -6.0], [23.0, -154.0], [36.0, 122.0], [45.0, -1.0], [46.0, 179.0], [-24.0, 179.0], [4.0, 177.0], [-62.0, -114.0], [78.0, -39.0], [63.0, -5.0], [-6.0, 68.0], [-75.0, 88.0], [-84.0, -44.0], [39.0, -168.0], [30.0, -61.0], [59.0, 2.0], [5.0, -3.0], [79.0, -58.0], [89.0, 74.0], [-69.0, -73.0], [-3.0, 6.0], [41.0, -19.0], [-7.0, 146.0], [18.0, 48.0], [-20.0, 64.0], [52.0, -115.0], [-26.0, 144.0], [87.0, 63.0], [62.0, 59.0], [18.0, -70.0], [-64.0, -161.0], [20.0, 62.0], [61.0, 60.0], [66.0, -47.0], [-75.0, -57.0], [37.0, -106.0], [-70.0, -3.0], [82.0, -57.0], [49.0, 90.0], [74.0, -50.0], [71.0, -10.0], [-13.0, -179.0], [-74.0, -20.0], [63.0, -17.0], [-55.0, 98.0], [-17.0, 98.0], [-33.0, -90.0], [16.0, 150.0], [5.0, 50.0], [16.0, 124.0], [-28.0, -109.0], [-82.0, -150.0], [-46.0, -131.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_bbd337840b2bc7bc16aaa27f879c5036);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_0cb2618c8b57f87ebf0e8f060bdf4364.addTo(map_bbd337840b2bc7bc16aaa27f879c5036);
#
#
#             var layer_control_431e2b3cf9edf84285ab459d367c5aef_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_f2c12dd5f33bc24126a08840bf7f6818,
#                 },
#                 overlays :  {
#                     &quot;macro_element_0cb2618c8b57f87ebf0e8f060bdf4364&quot; : fast_marker_cluster_0cb2618c8b57f87ebf0e8f060bdf4364,
#                 },
#             };
#             let layer_control_431e2b3cf9edf84285ab459d367c5aef = L.control.layers(
#                 layer_control_431e2b3cf9edf84285ab459d367c5aef_layers.base_layers,
#                 layer_control_431e2b3cf9edf84285ab459d367c5aef_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_bbd337840b2bc7bc16aaa27f879c5036);
#
#
# &lt;/script&gt;
# &lt;/html&gt;

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dbe049620248716680f42f641b9b503 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dbe049620248716680f42f641b9b503&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dbe049620248716680f42f641b9b503 = L.map(
#                 &quot;map_9dbe049620248716680f42f641b9b503&quot;,
#                 {
#                     center: [3.78, 6.24],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89fa4aa88c868310c666146628b6c709 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_89fa4aa88c868310c666146628b6c709.addTo(map_9dbe049620248716680f42f641b9b503);
#
#
#             var fast_marker_cluster_9d26d81afa5d6ae255109cc3a788b0a4 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-40.0, 28.0], [-37.0, 100.0], [66.0, 140.0], [-66.0, 38.0], [-35.0, -21.0], [-35.0, 145.0], [-72.0, 45.0], [-74.0, 101.0], [-81.0, 53.0], [-14.0, 83.0], [73.0, 71.0], [21.0, 93.0], [-72.0, 40.0], [21.0, -62.0], [9.0, -141.0], [80.0, -152.0], [-27.0, -58.0], [41.0, 113.0], [-18.0, 172.0], [3.0, -64.0], [-57.0, 64.0], [58.0, -70.0], [71.0, 69.0], [-72.0, 77.0], [81.0, 71.0], [51.0, -60.0], [7.0, 126.0], [-15.0, 176.0], [23.0, -162.0], [45.0, -4.0], [26.0, 79.0], [2.0, -111.0], [29.0, 70.0], [12.0, -109.0], [31.0, 52.0], [53.0, -154.0], [-49.0, -111.0], [-35.0, 44.0], [2.0, 97.0], [-32.0, 109.0], [-44.0, -164.0], [78.0, 177.0], [38.0, 28.0], [89.0, -160.0], [-72.0, -168.0], [-83.0, -102.0], [-71.0, 2.0], [-32.0, -6.0], [23.0, -154.0], [36.0, 122.0], [45.0, -1.0], [46.0, 179.0], [-24.0, 179.0], [4.0, 177.0], [-62.0, -114.0], [78.0, -39.0], [63.0, -5.0], [-6.0, 68.0], [-75.0, 88.0], [-84.0, -44.0], [39.0, -168.0], [30.0, -61.0], [59.0, 2.0], [5.0, -3.0], [79.0, -58.0], [89.0, 74.0], [-69.0, -73.0], [-3.0, 6.0], [41.0, -19.0], [-7.0, 146.0], [18.0, 48.0], [-20.0, 64.0], [52.0, -115.0], [-26.0, 144.0], [87.0, 63.0], [62.0, 59.0], [18.0, -70.0], [-64.0, -161.0], [20.0, 62.0], [61.0, 60.0], [66.0, -47.0], [-75.0, -57.0], [37.0, -106.0], [-70.0, -3.0], [82.0, -57.0], [49.0, 90.0], [74.0, -50.0], [71.0, -10.0], [-13.0, -179.0], [-74.0, -20.0], [63.0, -17.0], [-55.0, 98.0], [-17.0, 98.0], [-33.0, -90.0], [16.0, 150.0], [5.0, 50.0], [16.0, 124.0], [-28.0, -109.0], [-82.0, -150.0], [-46.0, -131.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_9dbe049620248716680f42f641b9b503);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_9d26d81afa5d6ae255109cc3a788b0a4.addTo(map_9dbe049620248716680f42f641b9b503);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
