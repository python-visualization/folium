# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a081155c39afda5afd6b2d265fcca440 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
#
#             &lt;style&gt;
#                 .easy-button-button {
#                   display: block !important;
#                 }
#
#                 .tag-filter-tags-container {
#                   left: 30px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a081155c39afda5afd6b2d265fcca440&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a081155c39afda5afd6b2d265fcca440 = L.map(
#                 &quot;map_a081155c39afda5afd6b2d265fcca440&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b95f1442a3983d75f32fd21be88adaf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b95f1442a3983d75f32fd21be88adaf.addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_8c716b3b092273abc26b535bc46bebbd = L.marker(
#                 [49.74823322927579, 6.0993021166763555],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_e67ba12be17a3010dd56faa5ed36f5ef = L.marker(
#                 [47.13928735167181, 4.511851266254711],
#                 {
#   &quot;tags&quot;: [
# &quot;category1&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_c24aa9aab3691e14e1d6f254eefbe4bc = L.marker(
#                 [46.6503402559455, 5.622776869637983],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_83dc67f4450dfddb129d45b39619e77f = L.marker(
#                 [49.267153036547555, 4.671037674340411],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_d375d9ddeb4dc8a9cf4cb708ee5954b7 = L.marker(
#                 [49.41862412634747, 4.267408189544668],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_8a0af8fb80872e6d5c684bc7be5595fe = L.marker(
#                 [47.57717219030643, 5.3021235357922185],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_5efdd85422bd0e3f485042705b35bbba = L.marker(
#                 [48.6025906797155, 5.372889700813041],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_fcd176d6f5dd6a8371ee57455e72884d = L.marker(
#                 [46.67707432166985, 5.990809505445705],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_370868ec023a33d563a958bda461248e = L.marker(
#                 [48.44844245756807, 6.812804488990707],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_bdfcbf682e679537fe1694cab1674d57 = L.marker(
#                 [45.77517184884027, 5.235579547378612],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_0f380140258a02750c443a435decea18 = L.marker(
#                 [49.220543466049286, 5.363631718663974],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_a081155c39afda5afd6b2d265fcca440);
#
#
#             var marker_fbf1045c9a9be
