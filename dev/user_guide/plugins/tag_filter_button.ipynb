# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfca2b95be8547c728750f463bcbab6a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
#
#             &lt;style&gt;
#                 .easy-button-button {
#                   display: block !important;
#                 }
#
#                 .tag-filter-tags-container {
#                   left: 30px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfca2b95be8547c728750f463bcbab6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfca2b95be8547c728750f463bcbab6a = L.map(
#                 &quot;map_dfca2b95be8547c728750f463bcbab6a&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b77bfbb62ac2baaa252823ae08311f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b77bfbb62ac2baaa252823ae08311f8.addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_9c600c36ed24876825a0b3bdff146f79 = L.marker(
#                 [48.79613770450033, 4.834693516145185],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_67059570b555ab3384fe4b3e94403145 = L.marker(
#                 [46.10978290675806, 3.9645617952293053],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_9f0e12a08b18557f1f282e79aa9db13b = L.marker(
#                 [46.515678700598954, 4.119827468588056],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_9eb577fabb0f1327fc4372d5410fa72c = L.marker(
#                 [47.92407590203231, 3.909584514679699],
#                 {
#   &quot;tags&quot;: [
# &quot;category4&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_c7b099189aec9fb3bf112212005bcbf4 = L.marker(
#                 [49.18033234156361, 4.183467482955877],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_5fac90b252863a330d9063f11e5c3638 = L.marker(
#                 [49.400710603353815, 5.781684348650382],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_a1039d4adda09357b29dfd6d516f2005 = L.marker(
#                 [46.0851269064936, 4.5905418531823186],
#                 {
#   &quot;tags&quot;: [
# &quot;category4&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_518c43bc8e94adbc483b9121e0380e3b = L.marker(
#                 [46.603576847993764, 5.464841147812489],
#                 {
#   &quot;tags&quot;: [
# &quot;category1&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_87dff37a5123618ab81653d3d7687060 = L.marker(
#                 [47.2388204886307, 4.442215992638519],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_9fc09c2d8121d3ef20e47e852cf24705 = L.marker(
#                 [48.38031466920506, 4.40296663210153],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_c4c7023fb8f1788eefe8ffccf6e74815 = L.marker(
#                 [47.37144101851707, 4.886957697550238],
#                 {
#   &quot;tags&quot;: [
# &quot;category1&quot;,
# ],
# }
#             ).addTo(map_dfca2b95be8547c728750f463bcbab6a);
#
#
#             var marker_82e432c6be
