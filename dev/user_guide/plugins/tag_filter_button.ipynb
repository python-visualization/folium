# %% [markdown]
# # TagFilterButton

# %%
import os
import folium

# %%
import numpy as np
import random

# Generate base data
data = (np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
                np.array([[48, 5]]))
# Generate the data to segment by (levels of another pandas column in practical usage)
categories = ['category{}'.format(i+1) for i in range(5)]
category_column = [random.choice(categories) for i in range(len(data))]

# %% [markdown]
# Create markers, and add tags to each marker. There can be multiple tags per marker, but in this example we add just one.
#
# Then, create the `TagFilterButton` object and let it know which tags you want to filter on.

# %%
from folium.plugins import TagFilterButton

# Create map and add the data with additional parameter tags as the segmentation
m = folium.Map([48., 5.], zoom_start=7)
for i, latlng in enumerate(data):
    category = category_column[i]
    folium.Marker(
        tuple(latlng),
        tags=[category]
    ).add_to(m)

TagFilterButton(categories).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48ee18fee892fe52f28977aca7c573f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-tag-filter-button/src/leaflet-tag-filter-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-easybutton@2/src/easy-button.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/css-ripple-effect@1.0.5/dist/ripple.min.css&quot;/&gt;
#
#             &lt;style&gt;
#                 .easy-button-button {
#                   display: block !important;
#                 }
#
#                 .tag-filter-tags-container {
#                   left: 30px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48ee18fee892fe52f28977aca7c573f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48ee18fee892fe52f28977aca7c573f8 = L.map(
#                 &quot;map_48ee18fee892fe52f28977aca7c573f8&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f785217595eddcd7558fbd219143e4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f785217595eddcd7558fbd219143e4d.addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_901bb9bf75ad696efcfccfe6a68bb11d = L.marker(
#                 [48.23858228491878, 4.542187551722885],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_1796f2ef4bbb839a53dc59799031843f = L.marker(
#                 [48.134410987936775, 4.863466569164702],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_232cb313ad6f70d0490ca28fd796ef0e = L.marker(
#                 [46.64970284258704, 6.996730780283018],
#                 {
#   &quot;tags&quot;: [
# &quot;category5&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_cb1fcebbb3b49e457dd8e7aeb17caeb5 = L.marker(
#                 [46.17234277950645, 4.864656363017506],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_a4ff0db1503a8d1185def729bae8363e = L.marker(
#                 [48.07488003125319, 6.034522396466318],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_2200357ba33ea8e1b2246cb19975f9ba = L.marker(
#                 [47.23817053513571, 5.507118053835947],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_2787831a598f419f352692ef8b240172 = L.marker(
#                 [46.80771103757699, 4.306922852350617],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_eb9f2b360c15d01abf828e4e4a0e22fb = L.marker(
#                 [49.25377821794857, 3.8705275446743714],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_50e03db74ab520ca276adef9dad6d179 = L.marker(
#                 [47.63800964824101, 5.252250008004155],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_d5f971a2793d1e52421cb7cb27515fe1 = L.marker(
#                 [48.276253574208965, 6.361054154532118],
#                 {
#   &quot;tags&quot;: [
# &quot;category2&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_9b587304f2656a270edd48b3ce9573b1 = L.marker(
#                 [47.85458143869014, 5.618505914243866],
#                 {
#   &quot;tags&quot;: [
# &quot;category3&quot;,
# ],
# }
#             ).addTo(map_48ee18fee892fe52f28977aca7c573f8);
#
#
#             var marker_21b99190be58
