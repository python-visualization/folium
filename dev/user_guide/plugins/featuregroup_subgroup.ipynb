# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4e5ff4510ec241200ddbdb7140aaa77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4e5ff4510ec241200ddbdb7140aaa77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4e5ff4510ec241200ddbdb7140aaa77 = L.map(
#                 &quot;map_b4e5ff4510ec241200ddbdb7140aaa77&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a086da38cf0ff26eca1ae159fcaa151a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a086da38cf0ff26eca1ae159fcaa151a.addTo(map_b4e5ff4510ec241200ddbdb7140aaa77);
#
#
#             var feature_group_70afa1b3c0f157b55c74d5dfeb3b09c1 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_70afa1b3c0f157b55c74d5dfeb3b09c1.addTo(map_b4e5ff4510ec241200ddbdb7140aaa77);
#
#
#             var feature_group_sub_group_251b19c81a18713789a734c393d39dcd = L.featureGroup.subGroup(
#                 feature_group_70afa1b3c0f157b55c74d5dfeb3b09c1
#             );
#
#
#             var marker_31ba672f8a657e96169883f7e8bb68d7 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_251b19c81a18713789a734c393d39dcd);
#
#
#             var marker_273e97a853c7751fe6ab9141ec3dcb41 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_251b19c81a18713789a734c393d39dcd);
#
#
#             feature_group_sub_group_251b19c81a18713789a734c393d39dcd.addTo(map_b4e5ff4510ec241200ddbdb7140aaa77);
#
#
#             var feature_group_sub_group_434e204e1d65e5b0294efa7df75c0418 = L.featureGroup.subGroup(
#                 feature_group_70afa1b3c0f157b55c74d5dfeb3b09c1
#             );
#
#
#             var marker_06645bb9f7130c789ea192f442da1a87 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_434e204e1d65e5b0294efa7df75c0418);
#
#
#             var marker_3ca52d57ee8b3e1fcb3d65809daa8921 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_434e204e1d65e5b0294efa7df75c0418);
#
#
#             feature_group_sub_group_434e204e1d65e5b0294efa7df75c0418.addTo(map_b4e5ff4510ec241200ddbdb7140aaa77);
#
#
#             var layer_control_034513d58d1da06f1859a4732be1240b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a086da38cf0ff26eca1ae159fcaa151a,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_70afa1b3c0f157b55c74d5dfeb3b09c1,
#                     &quot;group1&quot; : feature_group_sub_group_251b19c81a18713789a734c393d39dcd,
#                     &quot;group2&quot; : feature_group_sub_group_434e204e1d65e5b0294efa7df75c0418,
#                 },
#             };
#             let layer_control_034513d58d1da06f1859a4732be1240b = L.control.layers(
#                 layer_control_034513d58d1da06f1859a4732be1240b_layers.base_layers,
#                 layer_control_034513d58d1da06f1859a4732be1240b_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b4e5ff4510ec241200ddbdb7140aaa77);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83f1892d0c351b5cdce5f63a4ea27b61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83f1892d0c351b5cdce5f63a4ea27b61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83f1892d0c351b5cdce5f63a4ea27b61 = L.map(
#                 &quot;map_83f1892d0c351b5cdce5f63a4ea27b61&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5aa988c188f39879c5fb6d14dda4c1e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5aa988c188f39879c5fb6d14dda4c1e9.addTo(map_83f1892d0c351b5cdce5f63a4ea27b61);
#
#
#             var marker_cluster_89a7b497510232d0b42676ba2b22be7e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_89a7b497510232d0b42676ba2b22be7e.addTo(map_83f1892d0c351b5cdce5f63a4ea27b61);
#
#
#             var feature_group_sub_group_8f12b4f1721590f9b6a29d0bcc62c541 = L.featureGroup.subGroup(
#                 marker_cluster_89a7b497510232d0b42676ba2b22be7e
#             );
#
#
#             var marker_495bfe53fb52402d7ed68c659204025b = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_8f12b4f1721590f9b6a29d0bcc62c541);
#
#
#             var marker_1ae00371aade640699fa32dd5ae7dd73 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_8f12b4f1721590f9b6a29d0bcc62c541);
#
#
#             feature_group_sub_group_8f12b4f1721590f9b6a29d0bcc62c541.addTo(map_83f1892d0c351b5cdce5f63a4ea27b61);
#
#
#             var feature_group_sub_group_40c1cf1bf79d26c59e203453a268a6cc = L.featureGroup.subGroup(
#                 marker_cluster_89a7b497510232d0b42676ba2b22be7e
#             );
#
#
#             var marker_5d32355d43575c85369c14325bb83dfd = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_40c1cf1bf79d26c59e203453a268a6cc);
#
#
#             var marker_4253bac15bb59a889ade967bf7759e37 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_40c1cf1bf79d26c59e203453a268a6cc);
#
#
#             feature_group_sub_group_40c1cf1bf79d26c59e203453a268a6cc.addTo(map_83f1892d0c351b5cdce5f63a4ea27b61);
#
#
#             var layer_control_08a910351badf09da5aac08e8d03aa49_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5aa988c188f39879c5fb6d14dda4c1e9,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_8f12b4f1721590f9b6a29d0bcc62c541,
#                     &quot;group2&quot; : feature_group_sub_group_40c1cf1bf79d26c59e203453a268a6cc,
#                 },
#             };
#             let layer_control_08a910351badf09da5aac08e8d03aa49 = L.control.layers(
#                 layer_control_08a910351badf09da5aac08e8d03aa49_layers.base_layers,
#                 layer_control_08a910351badf09da5aac08e8d03aa49_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_83f1892d0c351b5cdce5f63a4ea27b61);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
