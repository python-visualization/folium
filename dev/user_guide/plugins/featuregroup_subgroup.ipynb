# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_883127035ace7c4d90bba7dc0fbebc22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_883127035ace7c4d90bba7dc0fbebc22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_883127035ace7c4d90bba7dc0fbebc22 = L.map(
#                 &quot;map_883127035ace7c4d90bba7dc0fbebc22&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_307f3e7a01174dda4334e78e1094943c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_307f3e7a01174dda4334e78e1094943c.addTo(map_883127035ace7c4d90bba7dc0fbebc22);
#
#
#             var feature_group_0494bdfa277441eaa975df566f2bad8b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0494bdfa277441eaa975df566f2bad8b.addTo(map_883127035ace7c4d90bba7dc0fbebc22);
#
#
#             var feature_group_sub_group_270603718446c21ccbd4264f074db974 = L.featureGroup.subGroup(
#                 feature_group_0494bdfa277441eaa975df566f2bad8b
#             );
#
#
#             var marker_6f62278e57d77026e9c397a415d10c07 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_270603718446c21ccbd4264f074db974);
#
#
#             var marker_d89bfdba9c288ead71623295614683b7 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_270603718446c21ccbd4264f074db974);
#
#
#             feature_group_sub_group_270603718446c21ccbd4264f074db974.addTo(map_883127035ace7c4d90bba7dc0fbebc22);
#
#
#             var feature_group_sub_group_466b4e4d1333b32d64447f93f6406761 = L.featureGroup.subGroup(
#                 feature_group_0494bdfa277441eaa975df566f2bad8b
#             );
#
#
#             var marker_131bc2b5c5a87adac263d7f730e21fad = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_466b4e4d1333b32d64447f93f6406761);
#
#
#             var marker_4572c4cb6adabb52a4116bc3eef41088 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_466b4e4d1333b32d64447f93f6406761);
#
#
#             feature_group_sub_group_466b4e4d1333b32d64447f93f6406761.addTo(map_883127035ace7c4d90bba7dc0fbebc22);
#
#
#             var layer_control_4591be807760a8c4ec1d574350681cac_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_307f3e7a01174dda4334e78e1094943c,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_0494bdfa277441eaa975df566f2bad8b,
#                     &quot;group1&quot; : feature_group_sub_group_270603718446c21ccbd4264f074db974,
#                     &quot;group2&quot; : feature_group_sub_group_466b4e4d1333b32d64447f93f6406761,
#                 },
#             };
#             let layer_control_4591be807760a8c4ec1d574350681cac = L.control.layers(
#                 layer_control_4591be807760a8c4ec1d574350681cac_layers.base_layers,
#                 layer_control_4591be807760a8c4ec1d574350681cac_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_883127035ace7c4d90bba7dc0fbebc22);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_896196e81cafedaf9a4ba188a3d777d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_896196e81cafedaf9a4ba188a3d777d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_896196e81cafedaf9a4ba188a3d777d2 = L.map(
#                 &quot;map_896196e81cafedaf9a4ba188a3d777d2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b89a23e61a5e2e32f5084cb7e2d9e7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b89a23e61a5e2e32f5084cb7e2d9e7d.addTo(map_896196e81cafedaf9a4ba188a3d777d2);
#
#
#             var marker_cluster_740bb93dd2272e1dc4ee57bf5631e9e9 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_740bb93dd2272e1dc4ee57bf5631e9e9.addTo(map_896196e81cafedaf9a4ba188a3d777d2);
#
#
#             var feature_group_sub_group_98921e548687c1d1523f7833940c1db3 = L.featureGroup.subGroup(
#                 marker_cluster_740bb93dd2272e1dc4ee57bf5631e9e9
#             );
#
#
#             var marker_589397b6a329f69c4cec12cb13d00e27 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_98921e548687c1d1523f7833940c1db3);
#
#
#             var marker_40bbd9ed4d5cac03525f9520b3cdab3e = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_98921e548687c1d1523f7833940c1db3);
#
#
#             feature_group_sub_group_98921e548687c1d1523f7833940c1db3.addTo(map_896196e81cafedaf9a4ba188a3d777d2);
#
#
#             var feature_group_sub_group_ae3088734f2846ef1cf8154a1e3be228 = L.featureGroup.subGroup(
#                 marker_cluster_740bb93dd2272e1dc4ee57bf5631e9e9
#             );
#
#
#             var marker_1e089fcbb83d496fba555d4224fee373 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae3088734f2846ef1cf8154a1e3be228);
#
#
#             var marker_df01d51c28d26cc0b765207b1d688973 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae3088734f2846ef1cf8154a1e3be228);
#
#
#             feature_group_sub_group_ae3088734f2846ef1cf8154a1e3be228.addTo(map_896196e81cafedaf9a4ba188a3d777d2);
#
#
#             var layer_control_b7f53de557dc3870e650f9538bad9b1f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3b89a23e61a5e2e32f5084cb7e2d9e7d,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_98921e548687c1d1523f7833940c1db3,
#                     &quot;group2&quot; : feature_group_sub_group_ae3088734f2846ef1cf8154a1e3be228,
#                 },
#             };
#             let layer_control_b7f53de557dc3870e650f9538bad9b1f = L.control.layers(
#                 layer_control_b7f53de557dc3870e650f9538bad9b1f_layers.base_layers,
#                 layer_control_b7f53de557dc3870e650f9538bad9b1f_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_896196e81cafedaf9a4ba188a3d777d2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
