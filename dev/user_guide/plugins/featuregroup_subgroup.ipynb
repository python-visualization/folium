# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8d25a773975c45c67eeb403ca5fa5e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8d25a773975c45c67eeb403ca5fa5e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8d25a773975c45c67eeb403ca5fa5e5 = L.map(
#                 &quot;map_a8d25a773975c45c67eeb403ca5fa5e5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bb422cb054d71c65b44dc742dbd6905 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4bb422cb054d71c65b44dc742dbd6905.addTo(map_a8d25a773975c45c67eeb403ca5fa5e5);
#
#
#             var feature_group_b6f25b9229395fad943d930b593a1ca5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b6f25b9229395fad943d930b593a1ca5.addTo(map_a8d25a773975c45c67eeb403ca5fa5e5);
#
#
#             var feature_group_sub_group_dacc9ece643f604bca209031243461d8 = L.featureGroup.subGroup(
#                 feature_group_b6f25b9229395fad943d930b593a1ca5
#             );
#
#
#             var marker_7dabc16085ac8b7ba8398720bfc8b1e9 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_dacc9ece643f604bca209031243461d8);
#
#
#             var marker_3985511230e468b9e986264d361c2c82 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_dacc9ece643f604bca209031243461d8);
#
#
#             feature_group_sub_group_dacc9ece643f604bca209031243461d8.addTo(map_a8d25a773975c45c67eeb403ca5fa5e5);
#
#
#             var feature_group_sub_group_b86f7ae9e1a10cfe8abf24ad08038b0b = L.featureGroup.subGroup(
#                 feature_group_b6f25b9229395fad943d930b593a1ca5
#             );
#
#
#             var marker_c5fd9ffabf8f6574e544014dc60d949e = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b86f7ae9e1a10cfe8abf24ad08038b0b);
#
#
#             var marker_4f10f373688eb482d002ea1465333752 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b86f7ae9e1a10cfe8abf24ad08038b0b);
#
#
#             feature_group_sub_group_b86f7ae9e1a10cfe8abf24ad08038b0b.addTo(map_a8d25a773975c45c67eeb403ca5fa5e5);
#
#
#             var layer_control_388fadb4872e2dc5c26af0193521639b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_4bb422cb054d71c65b44dc742dbd6905,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_b6f25b9229395fad943d930b593a1ca5,
#                     &quot;group1&quot; : feature_group_sub_group_dacc9ece643f604bca209031243461d8,
#                     &quot;group2&quot; : feature_group_sub_group_b86f7ae9e1a10cfe8abf24ad08038b0b,
#                 },
#             };
#             let layer_control_388fadb4872e2dc5c26af0193521639b = L.control.layers(
#                 layer_control_388fadb4872e2dc5c26af0193521639b_layers.base_layers,
#                 layer_control_388fadb4872e2dc5c26af0193521639b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_a8d25a773975c45c67eeb403ca5fa5e5);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dcbb4f4c9be38180c6c58b0c473f90e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dcbb4f4c9be38180c6c58b0c473f90e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dcbb4f4c9be38180c6c58b0c473f90e = L.map(
#                 &quot;map_5dcbb4f4c9be38180c6c58b0c473f90e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d016183cd2eaa98daba6b6cb31e61081 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d016183cd2eaa98daba6b6cb31e61081.addTo(map_5dcbb4f4c9be38180c6c58b0c473f90e);
#
#
#             var marker_cluster_616786fe2102d014425f4a2c2bafa60f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_616786fe2102d014425f4a2c2bafa60f.addTo(map_5dcbb4f4c9be38180c6c58b0c473f90e);
#
#
#             var feature_group_sub_group_4e199690ee0951fa1e43a57630593024 = L.featureGroup.subGroup(
#                 marker_cluster_616786fe2102d014425f4a2c2bafa60f
#             );
#
#
#             var marker_58433acf160fc9c5bd07a5354b198bf4 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e199690ee0951fa1e43a57630593024);
#
#
#             var marker_07a5f3a75ec45bdf93ddd60bf6297d72 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e199690ee0951fa1e43a57630593024);
#
#
#             feature_group_sub_group_4e199690ee0951fa1e43a57630593024.addTo(map_5dcbb4f4c9be38180c6c58b0c473f90e);
#
#
#             var feature_group_sub_group_70698e63291e5f3e4031ba9407960e97 = L.featureGroup.subGroup(
#                 marker_cluster_616786fe2102d014425f4a2c2bafa60f
#             );
#
#
#             var marker_0a99ac9a144bd3bed4d336f4ee671576 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_70698e63291e5f3e4031ba9407960e97);
#
#
#             var marker_41393cc260bea1385d61d8244e932205 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_70698e63291e5f3e4031ba9407960e97);
#
#
#             feature_group_sub_group_70698e63291e5f3e4031ba9407960e97.addTo(map_5dcbb4f4c9be38180c6c58b0c473f90e);
#
#
#             var layer_control_56ecc19fc62e06911871336c153d0f83_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d016183cd2eaa98daba6b6cb31e61081,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_4e199690ee0951fa1e43a57630593024,
#                     &quot;group2&quot; : feature_group_sub_group_70698e63291e5f3e4031ba9407960e97,
#                 },
#             };
#             let layer_control_56ecc19fc62e06911871336c153d0f83 = L.control.layers(
#                 layer_control_56ecc19fc62e06911871336c153d0f83_layers.base_layers,
#                 layer_control_56ecc19fc62e06911871336c153d0f83_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_5dcbb4f4c9be38180c6c58b0c473f90e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
