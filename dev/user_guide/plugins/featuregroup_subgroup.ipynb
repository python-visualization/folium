# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07d4b2d7e4a1fabda36d01331a8eafa5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07d4b2d7e4a1fabda36d01331a8eafa5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07d4b2d7e4a1fabda36d01331a8eafa5 = L.map(
#                 &quot;map_07d4b2d7e4a1fabda36d01331a8eafa5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1632afe0ac27c0957b56119416e1b906 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1632afe0ac27c0957b56119416e1b906.addTo(map_07d4b2d7e4a1fabda36d01331a8eafa5);
#
#
#             var feature_group_7be59732ed5d23cdee6f30b2000d2c8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7be59732ed5d23cdee6f30b2000d2c8e.addTo(map_07d4b2d7e4a1fabda36d01331a8eafa5);
#
#
#             var feature_group_sub_group_1f7f4ffa3dfcd689853dff53403a022b = L.featureGroup.subGroup(
#                 feature_group_7be59732ed5d23cdee6f30b2000d2c8e
#             );
#
#
#             var marker_030f285088f9d48500fc9d93e0aa40dd = L.marker(
#                 [-1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_1f7f4ffa3dfcd689853dff53403a022b);
#
#
#             var marker_c5f821d1af525eec97374d10e3b39600 = L.marker(
#                 [1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_1f7f4ffa3dfcd689853dff53403a022b);
#
#
#             feature_group_sub_group_1f7f4ffa3dfcd689853dff53403a022b.addTo(map_07d4b2d7e4a1fabda36d01331a8eafa5);
#
#
#             var feature_group_sub_group_0605a1e3fa95b9b704f743a1c806be7d = L.featureGroup.subGroup(
#                 feature_group_7be59732ed5d23cdee6f30b2000d2c8e
#             );
#
#
#             var marker_8317919fbb929c2107b6c555cd0b67d0 = L.marker(
#                 [-1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_0605a1e3fa95b9b704f743a1c806be7d);
#
#
#             var marker_01482f1528677732a8d0929132b2fe6b = L.marker(
#                 [1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_0605a1e3fa95b9b704f743a1c806be7d);
#
#
#             feature_group_sub_group_0605a1e3fa95b9b704f743a1c806be7d.addTo(map_07d4b2d7e4a1fabda36d01331a8eafa5);
#
#
#             var layer_control_6ce974df78e7d7bb7fd8f8c5d0bf548c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1632afe0ac27c0957b56119416e1b906,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_7be59732ed5d23cdee6f30b2000d2c8e,
#                     &quot;group1&quot; : feature_group_sub_group_1f7f4ffa3dfcd689853dff53403a022b,
#                     &quot;group2&quot; : feature_group_sub_group_0605a1e3fa95b9b704f743a1c806be7d,
#                 },
#             };
#             let layer_control_6ce974df78e7d7bb7fd8f8c5d0bf548c = L.control.layers(
#                 layer_control_6ce974df78e7d7bb7fd8f8c5d0bf548c_layers.base_layers,
#                 layer_control_6ce974df78e7d7bb7fd8f8c5d0bf548c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_07d4b2d7e4a1fabda36d01331a8eafa5);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8940a1cbe567632bbb00c04d07cbc512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8940a1cbe567632bbb00c04d07cbc512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8940a1cbe567632bbb00c04d07cbc512 = L.map(
#                 &quot;map_8940a1cbe567632bbb00c04d07cbc512&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97655c6e2777432938904595059b68ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97655c6e2777432938904595059b68ca.addTo(map_8940a1cbe567632bbb00c04d07cbc512);
#
#
#             var marker_cluster_6d7b2363eaca98e2e95db927a7c953c8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_6d7b2363eaca98e2e95db927a7c953c8.addTo(map_8940a1cbe567632bbb00c04d07cbc512);
#
#
#             var feature_group_sub_group_fd06c1902b522ed0d1d78919b64f8647 = L.featureGroup.subGroup(
#                 marker_cluster_6d7b2363eaca98e2e95db927a7c953c8
#             );
#
#
#             var marker_7f64a0e6b29f98cc84386ad2e03299b0 = L.marker(
#                 [-1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_fd06c1902b522ed0d1d78919b64f8647);
#
#
#             var marker_90017ba26abe3291e31400a139181b60 = L.marker(
#                 [1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_fd06c1902b522ed0d1d78919b64f8647);
#
#
#             feature_group_sub_group_fd06c1902b522ed0d1d78919b64f8647.addTo(map_8940a1cbe567632bbb00c04d07cbc512);
#
#
#             var feature_group_sub_group_0aea7bfbe3d0ff668e14367caf7903dd = L.featureGroup.subGroup(
#                 marker_cluster_6d7b2363eaca98e2e95db927a7c953c8
#             );
#
#
#             var marker_407ddc5aa9acb1a5e0fdaa0f8ee69e98 = L.marker(
#                 [-1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_0aea7bfbe3d0ff668e14367caf7903dd);
#
#
#             var marker_981a1ea3fe3def7e84e520e8e3b222cc = L.marker(
#                 [1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_0aea7bfbe3d0ff668e14367caf7903dd);
#
#
#             feature_group_sub_group_0aea7bfbe3d0ff668e14367caf7903dd.addTo(map_8940a1cbe567632bbb00c04d07cbc512);
#
#
#             var layer_control_bd91366b6c5176dd60ab9ccb9eba3d1e_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_97655c6e2777432938904595059b68ca,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_fd06c1902b522ed0d1d78919b64f8647,
#                     &quot;group2&quot; : feature_group_sub_group_0aea7bfbe3d0ff668e14367caf7903dd,
#                 },
#             };
#             let layer_control_bd91366b6c5176dd60ab9ccb9eba3d1e = L.control.layers(
#                 layer_control_bd91366b6c5176dd60ab9ccb9eba3d1e_layers.base_layers,
#                 layer_control_bd91366b6c5176dd60ab9ccb9eba3d1e_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_8940a1cbe567632bbb00c04d07cbc512);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
