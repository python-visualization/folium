# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f00e1f1cd9b5dee3e211a8f50a10d8ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f00e1f1cd9b5dee3e211a8f50a10d8ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f00e1f1cd9b5dee3e211a8f50a10d8ab = L.map(
#                 &quot;map_f00e1f1cd9b5dee3e211a8f50a10d8ab&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ee8d2a3fc2f8d7c25db08c506c5fb9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ee8d2a3fc2f8d7c25db08c506c5fb9f.addTo(map_f00e1f1cd9b5dee3e211a8f50a10d8ab);
#
#
#             var feature_group_0f9520f9d87dcb7cdc1ea0f04f9874c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0f9520f9d87dcb7cdc1ea0f04f9874c7.addTo(map_f00e1f1cd9b5dee3e211a8f50a10d8ab);
#
#
#             var feature_group_sub_group_0448f18773a61c612de86fac59a5436f = L.featureGroup.subGroup(
#                 feature_group_0f9520f9d87dcb7cdc1ea0f04f9874c7
#             );
#
#
#             var marker_a8ee140d90ee88a36a7b43b5a31c00d9 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_0448f18773a61c612de86fac59a5436f);
#
#
#             var marker_6e44331ecd6311aef7b4795d92333672 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_0448f18773a61c612de86fac59a5436f);
#
#
#             feature_group_sub_group_0448f18773a61c612de86fac59a5436f.addTo(map_f00e1f1cd9b5dee3e211a8f50a10d8ab);
#
#
#             var feature_group_sub_group_4e18f9f73357ae331cc6dd59b2e3ca71 = L.featureGroup.subGroup(
#                 feature_group_0f9520f9d87dcb7cdc1ea0f04f9874c7
#             );
#
#
#             var marker_ed1a71025e0a8bc6d3a49bce4694600f = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e18f9f73357ae331cc6dd59b2e3ca71);
#
#
#             var marker_1572c00e2deb672d73e9470c987a2bd9 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e18f9f73357ae331cc6dd59b2e3ca71);
#
#
#             feature_group_sub_group_4e18f9f73357ae331cc6dd59b2e3ca71.addTo(map_f00e1f1cd9b5dee3e211a8f50a10d8ab);
#
#
#             var layer_control_ee673a641197d06ea6dc591c2a2b9ea5_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_6ee8d2a3fc2f8d7c25db08c506c5fb9f,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_0f9520f9d87dcb7cdc1ea0f04f9874c7,
#                     &quot;group1&quot; : feature_group_sub_group_0448f18773a61c612de86fac59a5436f,
#                     &quot;group2&quot; : feature_group_sub_group_4e18f9f73357ae331cc6dd59b2e3ca71,
#                 },
#             };
#             let layer_control_ee673a641197d06ea6dc591c2a2b9ea5 = L.control.layers(
#                 layer_control_ee673a641197d06ea6dc591c2a2b9ea5_layers.base_layers,
#                 layer_control_ee673a641197d06ea6dc591c2a2b9ea5_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f00e1f1cd9b5dee3e211a8f50a10d8ab);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_693fe5593e11133dd8fd470ad11ec152 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_693fe5593e11133dd8fd470ad11ec152&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_693fe5593e11133dd8fd470ad11ec152 = L.map(
#                 &quot;map_693fe5593e11133dd8fd470ad11ec152&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f1bfa32b0991d5bcd1acf531224dd7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f1bfa32b0991d5bcd1acf531224dd7d.addTo(map_693fe5593e11133dd8fd470ad11ec152);
#
#
#             var marker_cluster_49bb8dd9cbf7b6e25cdeb45773722ec5 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_49bb8dd9cbf7b6e25cdeb45773722ec5.addTo(map_693fe5593e11133dd8fd470ad11ec152);
#
#
#             var feature_group_sub_group_b371b7daa28344b81eb23f4a7c1e45f7 = L.featureGroup.subGroup(
#                 marker_cluster_49bb8dd9cbf7b6e25cdeb45773722ec5
#             );
#
#
#             var marker_7659192ab3b04c04c0abd126739dce6c = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b371b7daa28344b81eb23f4a7c1e45f7);
#
#
#             var marker_ad06089c853b4e14c14d0c1eb643741c = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b371b7daa28344b81eb23f4a7c1e45f7);
#
#
#             feature_group_sub_group_b371b7daa28344b81eb23f4a7c1e45f7.addTo(map_693fe5593e11133dd8fd470ad11ec152);
#
#
#             var feature_group_sub_group_cd89c6fabe0bd97eb0b082549d62c8b9 = L.featureGroup.subGroup(
#                 marker_cluster_49bb8dd9cbf7b6e25cdeb45773722ec5
#             );
#
#
#             var marker_bb28fc66bb804180a182c315b0884cf7 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd89c6fabe0bd97eb0b082549d62c8b9);
#
#
#             var marker_e20d46f1e028ba2ae2fb0fcad7bffa1d = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd89c6fabe0bd97eb0b082549d62c8b9);
#
#
#             feature_group_sub_group_cd89c6fabe0bd97eb0b082549d62c8b9.addTo(map_693fe5593e11133dd8fd470ad11ec152);
#
#
#             var layer_control_39cd044c241f2085f3d87e3b868e6c76_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3f1bfa32b0991d5bcd1acf531224dd7d,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_b371b7daa28344b81eb23f4a7c1e45f7,
#                     &quot;group2&quot; : feature_group_sub_group_cd89c6fabe0bd97eb0b082549d62c8b9,
#                 },
#             };
#             let layer_control_39cd044c241f2085f3d87e3b868e6c76 = L.control.layers(
#                 layer_control_39cd044c241f2085f3d87e3b868e6c76_layers.base_layers,
#                 layer_control_39cd044c241f2085f3d87e3b868e6c76_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_693fe5593e11133dd8fd470ad11ec152);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
