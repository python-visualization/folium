# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f17d3b6983f4051d8f2e2c75d0cbf45e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f17d3b6983f4051d8f2e2c75d0cbf45e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f17d3b6983f4051d8f2e2c75d0cbf45e = L.map(
#                 &quot;map_f17d3b6983f4051d8f2e2c75d0cbf45e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f7c89f430c57f8797efd1246fe020b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f7c89f430c57f8797efd1246fe020b5.addTo(map_f17d3b6983f4051d8f2e2c75d0cbf45e);
#
#
#             var feature_group_e09bb7ced0560bdd4f091438955a5ba4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e09bb7ced0560bdd4f091438955a5ba4.addTo(map_f17d3b6983f4051d8f2e2c75d0cbf45e);
#
#
#             var feature_group_sub_group_f927238c2ce2d141ac77439b31cf146c = L.featureGroup.subGroup(
#                 feature_group_e09bb7ced0560bdd4f091438955a5ba4
#             );
#
#
#             var marker_710238e9e4bfe3f1898d2ec032825e8e = L.marker(
#                 [-1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_f927238c2ce2d141ac77439b31cf146c);
#
#
#             var marker_06441d6dbda90a510edfbcd6998a4bda = L.marker(
#                 [1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_f927238c2ce2d141ac77439b31cf146c);
#
#
#             feature_group_sub_group_f927238c2ce2d141ac77439b31cf146c.addTo(map_f17d3b6983f4051d8f2e2c75d0cbf45e);
#
#
#             var feature_group_sub_group_4fb9b5830423ed1e40f24ccd99db6e23 = L.featureGroup.subGroup(
#                 feature_group_e09bb7ced0560bdd4f091438955a5ba4
#             );
#
#
#             var marker_f66558c297ab4cd785f14749c0d0dfdf = L.marker(
#                 [-1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_4fb9b5830423ed1e40f24ccd99db6e23);
#
#
#             var marker_04c61ebf9baf520bbcbc8a15e222fa47 = L.marker(
#                 [1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_4fb9b5830423ed1e40f24ccd99db6e23);
#
#
#             feature_group_sub_group_4fb9b5830423ed1e40f24ccd99db6e23.addTo(map_f17d3b6983f4051d8f2e2c75d0cbf45e);
#
#
#             var layer_control_3f465c6508f44fcbb4910e336c860960_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7f7c89f430c57f8797efd1246fe020b5,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_e09bb7ced0560bdd4f091438955a5ba4,
#                     &quot;group1&quot; : feature_group_sub_group_f927238c2ce2d141ac77439b31cf146c,
#                     &quot;group2&quot; : feature_group_sub_group_4fb9b5830423ed1e40f24ccd99db6e23,
#                 },
#             };
#             let layer_control_3f465c6508f44fcbb4910e336c860960 = L.control.layers(
#                 layer_control_3f465c6508f44fcbb4910e336c860960_layers.base_layers,
#                 layer_control_3f465c6508f44fcbb4910e336c860960_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f17d3b6983f4051d8f2e2c75d0cbf45e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e83b35345d7d674c007d8ac53511849e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e83b35345d7d674c007d8ac53511849e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e83b35345d7d674c007d8ac53511849e = L.map(
#                 &quot;map_e83b35345d7d674c007d8ac53511849e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c6055f2b0775c27bbdfb02e13cfea12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c6055f2b0775c27bbdfb02e13cfea12.addTo(map_e83b35345d7d674c007d8ac53511849e);
#
#
#             var marker_cluster_8a5c92e84c554db4853eb0b67fd1163b = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_8a5c92e84c554db4853eb0b67fd1163b.addTo(map_e83b35345d7d674c007d8ac53511849e);
#
#
#             var feature_group_sub_group_30ea8e5916c867919fae59316a113658 = L.featureGroup.subGroup(
#                 marker_cluster_8a5c92e84c554db4853eb0b67fd1163b
#             );
#
#
#             var marker_4ce0c4d845a3c015b38bde2ff747f98a = L.marker(
#                 [-1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_30ea8e5916c867919fae59316a113658);
#
#
#             var marker_a9614ceaaa20a9aad6468a7efbc98e9a = L.marker(
#                 [1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_30ea8e5916c867919fae59316a113658);
#
#
#             feature_group_sub_group_30ea8e5916c867919fae59316a113658.addTo(map_e83b35345d7d674c007d8ac53511849e);
#
#
#             var feature_group_sub_group_298273cd3c341cb68c2a6d8d743a3ffc = L.featureGroup.subGroup(
#                 marker_cluster_8a5c92e84c554db4853eb0b67fd1163b
#             );
#
#
#             var marker_722dd290f541b56cfe7a498b877a2e54 = L.marker(
#                 [-1.0, 1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_298273cd3c341cb68c2a6d8d743a3ffc);
#
#
#             var marker_60b3cbb81dda9f2df089182ccd00a540 = L.marker(
#                 [1.0, -1.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_298273cd3c341cb68c2a6d8d743a3ffc);
#
#
#             feature_group_sub_group_298273cd3c341cb68c2a6d8d743a3ffc.addTo(map_e83b35345d7d674c007d8ac53511849e);
#
#
#             var layer_control_e08a9e8f9c66a675597555b1bcb33059_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_9c6055f2b0775c27bbdfb02e13cfea12,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_30ea8e5916c867919fae59316a113658,
#                     &quot;group2&quot; : feature_group_sub_group_298273cd3c341cb68c2a6d8d743a3ffc,
#                 },
#             };
#             let layer_control_e08a9e8f9c66a675597555b1bcb33059 = L.control.layers(
#                 layer_control_e08a9e8f9c66a675597555b1bcb33059_layers.base_layers,
#                 layer_control_e08a9e8f9c66a675597555b1bcb33059_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_e83b35345d7d674c007d8ac53511849e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
