# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c385c67161d91e130d92ba9ad4437053 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c385c67161d91e130d92ba9ad4437053&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c385c67161d91e130d92ba9ad4437053 = L.map(
#                 &quot;map_c385c67161d91e130d92ba9ad4437053&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57c5b05c8c0c4e6b4fcbd320ee69735b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57c5b05c8c0c4e6b4fcbd320ee69735b.addTo(map_c385c67161d91e130d92ba9ad4437053);
#
#
#             var feature_group_22589d0809df0d1aaffd2e620b8bad05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_22589d0809df0d1aaffd2e620b8bad05.addTo(map_c385c67161d91e130d92ba9ad4437053);
#
#
#             var feature_group_sub_group_2fe648a54271996c3cb942df5cafb98b = L.featureGroup.subGroup(
#                 feature_group_22589d0809df0d1aaffd2e620b8bad05
#             );
#
#
#             var marker_78f56c7d5a8186ea36e318f681d67410 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_2fe648a54271996c3cb942df5cafb98b);
#
#
#             var marker_da3d5a366c84e49e9ea3204c71c90a93 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_2fe648a54271996c3cb942df5cafb98b);
#
#
#             feature_group_sub_group_2fe648a54271996c3cb942df5cafb98b.addTo(map_c385c67161d91e130d92ba9ad4437053);
#
#
#             var feature_group_sub_group_ac1169e373511beb281ef5d2a7cecc5a = L.featureGroup.subGroup(
#                 feature_group_22589d0809df0d1aaffd2e620b8bad05
#             );
#
#
#             var marker_5a93e6fb2b7ea2cabcbad3e170569337 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_ac1169e373511beb281ef5d2a7cecc5a);
#
#
#             var marker_e8b06a97fe9928215cca21b336400f35 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_ac1169e373511beb281ef5d2a7cecc5a);
#
#
#             feature_group_sub_group_ac1169e373511beb281ef5d2a7cecc5a.addTo(map_c385c67161d91e130d92ba9ad4437053);
#
#
#             var layer_control_6c0a401511c838b0a1e19a769e80ffb0_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_57c5b05c8c0c4e6b4fcbd320ee69735b,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_22589d0809df0d1aaffd2e620b8bad05,
#                     &quot;group1&quot; : feature_group_sub_group_2fe648a54271996c3cb942df5cafb98b,
#                     &quot;group2&quot; : feature_group_sub_group_ac1169e373511beb281ef5d2a7cecc5a,
#                 },
#             };
#             let layer_control_6c0a401511c838b0a1e19a769e80ffb0 = L.control.layers(
#                 layer_control_6c0a401511c838b0a1e19a769e80ffb0_layers.base_layers,
#                 layer_control_6c0a401511c838b0a1e19a769e80ffb0_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c385c67161d91e130d92ba9ad4437053);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cbb8c1a26811fdb5d5a8e9dd826613e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cbb8c1a26811fdb5d5a8e9dd826613e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cbb8c1a26811fdb5d5a8e9dd826613e = L.map(
#                 &quot;map_5cbb8c1a26811fdb5d5a8e9dd826613e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcc3d710477a2016dd865bd7b071c94f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fcc3d710477a2016dd865bd7b071c94f.addTo(map_5cbb8c1a26811fdb5d5a8e9dd826613e);
#
#
#             var marker_cluster_b8f88c7d747cf8090d7bc133c7fa7b82 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_b8f88c7d747cf8090d7bc133c7fa7b82.addTo(map_5cbb8c1a26811fdb5d5a8e9dd826613e);
#
#
#             var feature_group_sub_group_b85cdc6c8cfd7592f65edd1a539d9cb9 = L.featureGroup.subGroup(
#                 marker_cluster_b8f88c7d747cf8090d7bc133c7fa7b82
#             );
#
#
#             var marker_8d0d06fad96b0302e75f5c8b969e1c71 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b85cdc6c8cfd7592f65edd1a539d9cb9);
#
#
#             var marker_1037992986d56a25296214ce7fa6e180 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b85cdc6c8cfd7592f65edd1a539d9cb9);
#
#
#             feature_group_sub_group_b85cdc6c8cfd7592f65edd1a539d9cb9.addTo(map_5cbb8c1a26811fdb5d5a8e9dd826613e);
#
#
#             var feature_group_sub_group_afa7e80708dcf11a5ff43fbf05bdb8f0 = L.featureGroup.subGroup(
#                 marker_cluster_b8f88c7d747cf8090d7bc133c7fa7b82
#             );
#
#
#             var marker_c94d6cd116e61354a800520f9e378bbe = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_afa7e80708dcf11a5ff43fbf05bdb8f0);
#
#
#             var marker_1f4fdb1c60d563c2945b299b117af2d7 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_afa7e80708dcf11a5ff43fbf05bdb8f0);
#
#
#             feature_group_sub_group_afa7e80708dcf11a5ff43fbf05bdb8f0.addTo(map_5cbb8c1a26811fdb5d5a8e9dd826613e);
#
#
#             var layer_control_74f3b58fe937200687d4e9687fc9ae30_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_fcc3d710477a2016dd865bd7b071c94f,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_b85cdc6c8cfd7592f65edd1a539d9cb9,
#                     &quot;group2&quot; : feature_group_sub_group_afa7e80708dcf11a5ff43fbf05bdb8f0,
#                 },
#             };
#             let layer_control_74f3b58fe937200687d4e9687fc9ae30 = L.control.layers(
#                 layer_control_74f3b58fe937200687d4e9687fc9ae30_layers.base_layers,
#                 layer_control_74f3b58fe937200687d4e9687fc9ae30_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_5cbb8c1a26811fdb5d5a8e9dd826613e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
