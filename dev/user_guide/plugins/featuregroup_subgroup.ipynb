# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf7b7de06c2d4cb90facc4d64c8451c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf7b7de06c2d4cb90facc4d64c8451c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf7b7de06c2d4cb90facc4d64c8451c7 = L.map(
#                 &quot;map_cf7b7de06c2d4cb90facc4d64c8451c7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8c2a360600f1156d4d5e185ecb19bdc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8c2a360600f1156d4d5e185ecb19bdc.addTo(map_cf7b7de06c2d4cb90facc4d64c8451c7);
#
#
#             var feature_group_f1d89c8dd7fde1d4cd3a4483e10781e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f1d89c8dd7fde1d4cd3a4483e10781e2.addTo(map_cf7b7de06c2d4cb90facc4d64c8451c7);
#
#
#             var feature_group_sub_group_277529b198531608738f592d1d45ad80 = L.featureGroup.subGroup(
#                 feature_group_f1d89c8dd7fde1d4cd3a4483e10781e2
#             );
#
#
#             var marker_73be8dc52a870dba5d8fb6b278813e0d = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_277529b198531608738f592d1d45ad80);
#
#
#             var marker_e6a0d5bd271cc091dfebce0e7fa4daaa = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_277529b198531608738f592d1d45ad80);
#
#
#             feature_group_sub_group_277529b198531608738f592d1d45ad80.addTo(map_cf7b7de06c2d4cb90facc4d64c8451c7);
#
#
#             var feature_group_sub_group_03796708b54512ab57d63c02fec3fd29 = L.featureGroup.subGroup(
#                 feature_group_f1d89c8dd7fde1d4cd3a4483e10781e2
#             );
#
#
#             var marker_6078fec29f82f0b6ccc4fb55cd5b3ad8 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_03796708b54512ab57d63c02fec3fd29);
#
#
#             var marker_f480412eae33abff7ea39c17c3350c76 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_03796708b54512ab57d63c02fec3fd29);
#
#
#             feature_group_sub_group_03796708b54512ab57d63c02fec3fd29.addTo(map_cf7b7de06c2d4cb90facc4d64c8451c7);
#
#
#             var layer_control_52b00e1f3fec536bebccba39257429da_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a8c2a360600f1156d4d5e185ecb19bdc,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_f1d89c8dd7fde1d4cd3a4483e10781e2,
#                     &quot;group1&quot; : feature_group_sub_group_277529b198531608738f592d1d45ad80,
#                     &quot;group2&quot; : feature_group_sub_group_03796708b54512ab57d63c02fec3fd29,
#                 },
#             };
#             let layer_control_52b00e1f3fec536bebccba39257429da = L.control.layers(
#                 layer_control_52b00e1f3fec536bebccba39257429da_layers.base_layers,
#                 layer_control_52b00e1f3fec536bebccba39257429da_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_cf7b7de06c2d4cb90facc4d64c8451c7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bdbc74b588210522faf9cb74652f366 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bdbc74b588210522faf9cb74652f366&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bdbc74b588210522faf9cb74652f366 = L.map(
#                 &quot;map_1bdbc74b588210522faf9cb74652f366&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_349e790f464370b28f0bca8d9a6fb21d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_349e790f464370b28f0bca8d9a6fb21d.addTo(map_1bdbc74b588210522faf9cb74652f366);
#
#
#             var marker_cluster_67958e6b2b985de513e88417f2b6edb8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_67958e6b2b985de513e88417f2b6edb8.addTo(map_1bdbc74b588210522faf9cb74652f366);
#
#
#             var feature_group_sub_group_b8ae1d5650925ca4a8d2a6a1f6b43437 = L.featureGroup.subGroup(
#                 marker_cluster_67958e6b2b985de513e88417f2b6edb8
#             );
#
#
#             var marker_43801298e1e23db37daf22a8ced617fa = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b8ae1d5650925ca4a8d2a6a1f6b43437);
#
#
#             var marker_8eff41778997f9fe6bb81cbe6bb2323e = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_b8ae1d5650925ca4a8d2a6a1f6b43437);
#
#
#             feature_group_sub_group_b8ae1d5650925ca4a8d2a6a1f6b43437.addTo(map_1bdbc74b588210522faf9cb74652f366);
#
#
#             var feature_group_sub_group_84a7fb7330d88ff7476ed5e51380a0a7 = L.featureGroup.subGroup(
#                 marker_cluster_67958e6b2b985de513e88417f2b6edb8
#             );
#
#
#             var marker_1df87f0157afb69c25811f7c3a8ae792 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_84a7fb7330d88ff7476ed5e51380a0a7);
#
#
#             var marker_b2a14fc93ac0966f7a4a39af7782af77 = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_84a7fb7330d88ff7476ed5e51380a0a7);
#
#
#             feature_group_sub_group_84a7fb7330d88ff7476ed5e51380a0a7.addTo(map_1bdbc74b588210522faf9cb74652f366);
#
#
#             var layer_control_06c5839a2123805d76cb1a5a7b9750c6_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_349e790f464370b28f0bca8d9a6fb21d,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_b8ae1d5650925ca4a8d2a6a1f6b43437,
#                     &quot;group2&quot; : feature_group_sub_group_84a7fb7330d88ff7476ed5e51380a0a7,
#                 },
#             };
#             let layer_control_06c5839a2123805d76cb1a5a7b9750c6 = L.control.layers(
#                 layer_control_06c5839a2123805d76cb1a5a7b9750c6_layers.base_layers,
#                 layer_control_06c5839a2123805d76cb1a5a7b9750c6_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_1bdbc74b588210522faf9cb74652f366);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
