# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66730c2e6f1ef4d246ff2e610984f76e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66730c2e6f1ef4d246ff2e610984f76e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66730c2e6f1ef4d246ff2e610984f76e = L.map(
#                 &quot;map_66730c2e6f1ef4d246ff2e610984f76e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a63a3a5baeb8631999d37c402db57e36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a63a3a5baeb8631999d37c402db57e36.addTo(map_66730c2e6f1ef4d246ff2e610984f76e);
#
#
#             var feature_group_fa03065a069e6e2f6569b86fb271f565 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fa03065a069e6e2f6569b86fb271f565.addTo(map_66730c2e6f1ef4d246ff2e610984f76e);
#
#
#             var feature_group_sub_group_edcde8044de8a6179c890c0eaaedf406 = L.featureGroup.subGroup(
#                 feature_group_fa03065a069e6e2f6569b86fb271f565
#             );
#
#
#             var marker_8a4daa0140c7e00ee53e7911d16cfa41 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_edcde8044de8a6179c890c0eaaedf406);
#
#
#             var marker_3d06cd8cc615db9b81cf0efc6cc61e85 = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_edcde8044de8a6179c890c0eaaedf406);
#
#
#             feature_group_sub_group_edcde8044de8a6179c890c0eaaedf406.addTo(map_66730c2e6f1ef4d246ff2e610984f76e);
#
#
#             var feature_group_sub_group_448d586b2407f47976819dc8c0819703 = L.featureGroup.subGroup(
#                 feature_group_fa03065a069e6e2f6569b86fb271f565
#             );
#
#
#             var marker_5e91333e723e50c0e6bbdf2f02c2bef1 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_448d586b2407f47976819dc8c0819703);
#
#
#             var marker_0fa7c4e38722051e04925b7fa5b1a2cf = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_448d586b2407f47976819dc8c0819703);
#
#
#             feature_group_sub_group_448d586b2407f47976819dc8c0819703.addTo(map_66730c2e6f1ef4d246ff2e610984f76e);
#
#
#             var layer_control_dc0197c4a4d70f51ad90b1382d8236d9_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a63a3a5baeb8631999d37c402db57e36,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_fa03065a069e6e2f6569b86fb271f565,
#                     &quot;group1&quot; : feature_group_sub_group_edcde8044de8a6179c890c0eaaedf406,
#                     &quot;group2&quot; : feature_group_sub_group_448d586b2407f47976819dc8c0819703,
#                 },
#             };
#             let layer_control_dc0197c4a4d70f51ad90b1382d8236d9 = L.control.layers(
#                 layer_control_dc0197c4a4d70f51ad90b1382d8236d9_layers.base_layers,
#                 layer_control_dc0197c4a4d70f51ad90b1382d8236d9_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_66730c2e6f1ef4d246ff2e610984f76e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a84edc2fba3b41b0f9683201cf13c5e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a84edc2fba3b41b0f9683201cf13c5e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a84edc2fba3b41b0f9683201cf13c5e7 = L.map(
#                 &quot;map_a84edc2fba3b41b0f9683201cf13c5e7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c215c4d2e2e08325f9588098ea1cc66c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c215c4d2e2e08325f9588098ea1cc66c.addTo(map_a84edc2fba3b41b0f9683201cf13c5e7);
#
#
#             var marker_cluster_64e5051be8d84fcdc40ed16eeb749f06 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_64e5051be8d84fcdc40ed16eeb749f06.addTo(map_a84edc2fba3b41b0f9683201cf13c5e7);
#
#
#             var feature_group_sub_group_bd8ca84f8f1970687f69f40aa4c9724a = L.featureGroup.subGroup(
#                 marker_cluster_64e5051be8d84fcdc40ed16eeb749f06
#             );
#
#
#             var marker_13a18d0b5f19b7e12861de72b6396391 = L.marker(
#                 [-1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd8ca84f8f1970687f69f40aa4c9724a);
#
#
#             var marker_9b68f73e173e374c28bf60be2c4a07ec = L.marker(
#                 [1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd8ca84f8f1970687f69f40aa4c9724a);
#
#
#             feature_group_sub_group_bd8ca84f8f1970687f69f40aa4c9724a.addTo(map_a84edc2fba3b41b0f9683201cf13c5e7);
#
#
#             var feature_group_sub_group_1f65ea1c160c9e87e32724b06818ddaa = L.featureGroup.subGroup(
#                 marker_cluster_64e5051be8d84fcdc40ed16eeb749f06
#             );
#
#
#             var marker_7a7276b544a522437ceb451ec7cb00e4 = L.marker(
#                 [-1.0, 1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f65ea1c160c9e87e32724b06818ddaa);
#
#
#             var marker_fc8e6ee113e04cc490e3c2235d0bf0aa = L.marker(
#                 [1.0, -1.0],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f65ea1c160c9e87e32724b06818ddaa);
#
#
#             feature_group_sub_group_1f65ea1c160c9e87e32724b06818ddaa.addTo(map_a84edc2fba3b41b0f9683201cf13c5e7);
#
#
#             var layer_control_c2ce328bdc81a8fa88c0f8a7ddd16ad8_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c215c4d2e2e08325f9588098ea1cc66c,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_bd8ca84f8f1970687f69f40aa4c9724a,
#                     &quot;group2&quot; : feature_group_sub_group_1f65ea1c160c9e87e32724b06818ddaa,
#                 },
#             };
#             let layer_control_c2ce328bdc81a8fa88c0f8a7ddd16ad8 = L.control.layers(
#                 layer_control_c2ce328bdc81a8fa88c0f8a7ddd16ad8_layers.base_layers,
#                 layer_control_c2ce328bdc81a8fa88c0f8a7ddd16ad8_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_a84edc2fba3b41b0f9683201cf13c5e7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
