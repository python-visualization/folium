# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa077781a1ef50abdcc8db29321cf226 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa077781a1ef50abdcc8db29321cf226&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa077781a1ef50abdcc8db29321cf226 = L.map(
#                 &quot;map_fa077781a1ef50abdcc8db29321cf226&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bb1b174e5de6ca4e813727d4e645639 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bb1b174e5de6ca4e813727d4e645639.addTo(map_fa077781a1ef50abdcc8db29321cf226);
#
#
#             var marker_45c994408272371b44c43998a9af57ca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fa077781a1ef50abdcc8db29321cf226);
#
#
#         var popup_3c641c1a24bbbd32b6cdef0f981eb9b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d854fade78dd2c0ee606be2cdf5db481 = $(`&lt;div id=&quot;html_d854fade78dd2c0ee606be2cdf5db481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c641c1a24bbbd32b6cdef0f981eb9b3.setContent(html_d854fade78dd2c0ee606be2cdf5db481);
#
#
#
#         marker_45c994408272371b44c43998a9af57ca.bindPopup(popup_3c641c1a24bbbd32b6cdef0f981eb9b3)
#         ;
#
#
#
#
#             var marker_709409cd5f3ad9f25b86410c7c5c5df8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fa077781a1ef50abdcc8db29321cf226);
#
#
#         var popup_2622cd816ea7c24ee88ce910a4c872f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4f337df76808f193e19c75a341b4a7c = $(`&lt;div id=&quot;html_f4f337df76808f193e19c75a341b4a7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2622cd816ea7c24ee88ce910a4c872f1.setContent(html_f4f337df76808f193e19c75a341b4a7c);
#
#
#
#         marker_709409cd5f3ad9f25b86410c7c5c5df8.bindPopup(popup_2622cd816ea7c24ee88ce910a4c872f1)
#         ;
#
#
#
#
#             var marker_a3aa61bdab1fd54e7e7f51f6491b1fd2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fa077781a1ef50abdcc8db29321cf226);
#
#
#         var popup_5959674ac73f32e0e2358949635d47c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_034e50914610c7ce88e18237475c885f = $(`&lt;div id=&quot;html_034e50914610c7ce88e18237475c885f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5959674ac73f32e0e2358949635d47c6.setContent(html_034e50914610c7ce88e18237475c885f);
#
#
#
#         marker_a3aa61bdab1fd54e7e7f51f6491b1fd2.bindPopup(popup_5959674ac73f32e0e2358949635d47c6)
#         ;
#
#
#
#
#             var marker_b8c46fd6f3d389cb2182b6cc86a11d5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fa077781a1ef50abdcc8db29321cf226);
#
#
#         var popup_562d72a1e5fb19641e43e40844a09552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90513851730cb004a5874aea4b5f0e43 = $(`&lt;div id=&quot;html_90513851730cb004a5874aea4b5f0e43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_562d72a1e5fb19641e43e40844a09552.setContent(html_90513851730cb004a5874aea4b5f0e43);
#
#
#
#         marker_b8c46fd6f3d389cb2182b6cc86a11d5e.bindPopup(popup_562d72a1e5fb19641e43e40844a09552)
#         ;
#
#
#
#
#             var marker_b9145144d6cf0df9fbaf187851be574a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fa077781a1ef50abdcc8db29321cf226);
#
#
#         var popup_25bd0d22eda65dac70b684a7135f8d63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_175c45e600c06f52a274c2f0ab046bf3 = $(`&lt;div id=&quot;html_175c45e600c06f52a274c2f0ab046bf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_25bd0d22eda65dac70b684a7135f8d63.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81d5b80a3412fc630f692569d3e6a709 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81d5b80a3412fc630f692569d3e6a709&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81d5b80a3412fc630f692569d3e6a709 = L.map(
#                 &quot;map_81d5b80a3412fc630f692569d3e6a709&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a2e9251e65050d88969a9f23fa3fbbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a2e9251e65050d88969a9f23fa3fbbc.addTo(map_81d5b80a3412fc630f692569d3e6a709);
#
#
#             var feature_group_7ba6ff43ae2c34889006ddd86a2c6209 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3751f72c8abdb47d560d8316a9b9ef1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7ba6ff43ae2c34889006ddd86a2c6209);
#
#
#         var popup_1a1bb344bb9271c053e6a3bbae68654c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_009c03d27ea9d7fc1f62701273ed8771 = $(`&lt;div id=&quot;html_009c03d27ea9d7fc1f62701273ed8771&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1a1bb344bb9271c053e6a3bbae68654c.setContent(html_009c03d27ea9d7fc1f62701273ed8771);
#
#
#
#         marker_3751f72c8abdb47d560d8316a9b9ef1f.bindPopup(popup_1a1bb344bb9271c053e6a3bbae68654c)
#         ;
#
#
#
#
#             var marker_aa1d7875f7838af318cd6d3da9a1d502 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7ba6ff43ae2c34889006ddd86a2c6209);
#
#
#         var popup_348652a87dacd489db6798d36f12cf8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3c8563fa0fc4845f5f1a713540fa393 = $(`&lt;div id=&quot;html_e3c8563fa0fc4845f5f1a713540fa393&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_348652a87dacd489db6798d36f12cf8b.setContent(html_e3c8563fa0fc4845f5f1a713540fa393);
#
#
#
#         marker_aa1d7875f7838af318cd6d3da9a1d502.bindPopup(popup_348652a87dacd489db6798d36f12cf8b)
#         ;
#
#
#
#
#             var marker_a2acc153123197c3a3e081e6532bb471 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7ba6ff43ae2c34889006ddd86a2c6209);
#
#
#         var popup_88d71d184463663a9bc4c025f1ddc2ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bc893a2a7854aa3ac7e447e2124e693 = $(`&lt;div id=&quot;html_0bc893a2a7854aa3ac7e447e2124e693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_88d71d184463663a9bc4c025f1ddc2ca.setContent(html_0bc893a2a7854aa3ac7e447e2124e693);
#
#
#
#         marker_a2acc153123197c3a3e081e6532bb471.bindPopup(popup_88d71d184463663a9bc4c025f1ddc2ca)
#         ;
#
#
#
#
#             var marker_c08bae533156ad9b621a4ac0141d52a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7ba6ff43ae2c34889006ddd86a2c6209);
#
#
#         var popup_cc32c3ee754bf9a1479d2880aeb3baea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a63d4d0ee4d60cd5e09512a3df955bfd = $(`&lt;div id=&quot;html_a63d4d0ee4d60cd5e09512a3df955bfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc32c3ee754bf9a1479d2880aeb3baea.setContent(html_a63d4d0ee4d60cd5e09512a3df955bfd);
#
#
#
#         marker_c08bae533156ad9b621a4ac0141d52a3.bindPopup(popup_cc32c3ee754bf9a1479d2880aeb3baea)
#         ;
#
#
#
#
#             var marker_2ebd7a4664ba030f6c44b93976e22811 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7ba6ff43ae2c34889006ddd86a2c6209);
#
#
#         var popup_34e531fc29390bc355d441e6135be080 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_236cb876c4aed91e3679268894755c90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_236cb876c4aed91e3679268894755c90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_236cb876c4aed91e3679268894755c90 = L.map(
#                 &quot;map_236cb876c4aed91e3679268894755c90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e180bdbf9cfacf0f2ea7247a94c2af5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5e180bdbf9cfacf0f2ea7247a94c2af5.addTo(map_236cb876c4aed91e3679268894755c90);
#
#
#             var feature_group_8066f4cfd4c4103c80d716b7f0eb4c90 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8066f4cfd4c4103c80d716b7f0eb4c90.addTo(map_236cb876c4aed91e3679268894755c90);
#
#
#             var feature_group_sub_group_4659a804ec5dc13bc21476880cd36758 = L.featureGroup.subGroup(
#                 feature_group_8066f4cfd4c4103c80d716b7f0eb4c90
#             );
#
#
#             var marker_845bc12fde1fd5f13bb6633f93697a3a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4659a804ec5dc13bc21476880cd36758);
#
#
#         var popup_c6dcfd77d9ab9bf84daea4172da4ca2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7e322e95972276f9b06d67e79e93e6e = $(`&lt;div id=&quot;html_b7e322e95972276f9b06d67e79e93e6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c6dcfd77d9ab9bf84daea4172da4ca2b.setContent(html_b7e322e95972276f9b06d67e79e93e6e);
#
#
#
#         marker_845bc12fde1fd5f13bb6633f93697a3a.bindPopup(popup_c6dcfd77d9ab9bf84daea4172da4ca2b)
#         ;
#
#
#
#
#             var marker_456dd604c11655766607817b8affff91 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4659a804ec5dc13bc21476880cd36758);
#
#
#         var popup_0465d94675f542f7f728ce3e237303f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9adde1a1ccf522a5e07741d5c67485ea = $(`&lt;div id=&quot;html_9adde1a1ccf522a5e07741d5c67485ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0465d94675f542f7f728ce3e237303f6.setContent(html_9adde1a1ccf522a5e07741d5c67485ea);
#
#
#
#         marker_456dd604c11655766607817b8affff91.bindPopup(popup_0465d94675f542f7f728ce3e237303f6)
#         ;
#
#
#
#
#             var marker_7b905464a93d5ab813d625bcd05528d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4659a804ec5dc13bc21476880cd36758);
#
#
#         var popup_240bca0d24745d5c0c7bb56878598084 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10ba0b189268a593b51082aa87614aef = $(`&lt;div id=&quot;html_10ba0b189268a593b51082aa87614aef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_240bca0d24745d5c0c7bb56878598084.setContent(html_10ba0b189268a593b51082aa87614aef);
#
#
#
#         marker_7b905464a93d5ab813d625bcd05528d3.bindPopup(popup_240bca0d24745d5c0c7bb56878598084)
#         ;
#
#
#
#
#             var marker_114a1ae235340401788a765fe2a1c047 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4659a804ec5dc13bc21476880cd36758);
#
#
#         var popup_2ace14cabb419fbf11aa61506990ed4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c8933918dc30256fc5e6a5069d344fa = $(`&lt;div id=&quot;html_4c8933918dc30256fc5e6a5069d344fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2ace14cabb419fbf11aa61506990ed4d.setContent(html_4c8933918dc30256fc5e6a5069d344fa);
#
#
#
#         marker_
