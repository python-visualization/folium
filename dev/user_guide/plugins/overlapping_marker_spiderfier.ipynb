# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c35dc88409dfa446c452c1f176cc4ffc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c35dc88409dfa446c452c1f176cc4ffc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c35dc88409dfa446c452c1f176cc4ffc = L.map(
#                 &quot;map_c35dc88409dfa446c452c1f176cc4ffc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b33ecbaffddf326f9f0a62822ebca6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b33ecbaffddf326f9f0a62822ebca6f.addTo(map_c35dc88409dfa446c452c1f176cc4ffc);
#
#
#             var marker_1c8623ac8eebe3b0aaf178e347cca220 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c35dc88409dfa446c452c1f176cc4ffc);
#
#
#         var popup_d073dadd659bedaff3ed4dda9dbbb6e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b27fc214b69b6f4c9cf3beae778bd0a = $(`&lt;div id=&quot;html_4b27fc214b69b6f4c9cf3beae778bd0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d073dadd659bedaff3ed4dda9dbbb6e5.setContent(html_4b27fc214b69b6f4c9cf3beae778bd0a);
#
#
#
#         marker_1c8623ac8eebe3b0aaf178e347cca220.bindPopup(popup_d073dadd659bedaff3ed4dda9dbbb6e5)
#         ;
#
#
#
#
#             var marker_20ab51d8062984118c980a7547cfd753 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c35dc88409dfa446c452c1f176cc4ffc);
#
#
#         var popup_32daeadb4c7f7cc74bd9c4c908c8e966 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_659efad69888d05a63307af4ddd124db = $(`&lt;div id=&quot;html_659efad69888d05a63307af4ddd124db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_32daeadb4c7f7cc74bd9c4c908c8e966.setContent(html_659efad69888d05a63307af4ddd124db);
#
#
#
#         marker_20ab51d8062984118c980a7547cfd753.bindPopup(popup_32daeadb4c7f7cc74bd9c4c908c8e966)
#         ;
#
#
#
#
#             var marker_df683b60b649bee205e204bc1aefd418 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c35dc88409dfa446c452c1f176cc4ffc);
#
#
#         var popup_a9dde0c32b6c6650c0f82f9d1ac6a0e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31f1fc8181fc610119148b236db156f0 = $(`&lt;div id=&quot;html_31f1fc8181fc610119148b236db156f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a9dde0c32b6c6650c0f82f9d1ac6a0e1.setContent(html_31f1fc8181fc610119148b236db156f0);
#
#
#
#         marker_df683b60b649bee205e204bc1aefd418.bindPopup(popup_a9dde0c32b6c6650c0f82f9d1ac6a0e1)
#         ;
#
#
#
#
#             var marker_3400ea2040a57f211a9e9919cdecc31f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c35dc88409dfa446c452c1f176cc4ffc);
#
#
#         var popup_33cb22ece4e5cc127d80ed54b20bf9d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20fc2a7b78cb8ebfe37d580f581560f7 = $(`&lt;div id=&quot;html_20fc2a7b78cb8ebfe37d580f581560f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_33cb22ece4e5cc127d80ed54b20bf9d0.setContent(html_20fc2a7b78cb8ebfe37d580f581560f7);
#
#
#
#         marker_3400ea2040a57f211a9e9919cdecc31f.bindPopup(popup_33cb22ece4e5cc127d80ed54b20bf9d0)
#         ;
#
#
#
#
#             var marker_b9f289c7a8763c40d06ffc2daf1a2fb0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c35dc88409dfa446c452c1f176cc4ffc);
#
#
#         var popup_a83e2408d0793d57a32566502336b1ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67baa211ffdc3dbaa4125f498be41ad8 = $(`&lt;div id=&quot;html_67baa211ffdc3dbaa4125f498be41ad8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a83e2408d0793d57a32566502336b1ac.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0657ef7fe0bda7be81c396c50ef974eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0657ef7fe0bda7be81c396c50ef974eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0657ef7fe0bda7be81c396c50ef974eb = L.map(
#                 &quot;map_0657ef7fe0bda7be81c396c50ef974eb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_317d02d1796be5909df87f8845a8ca8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_317d02d1796be5909df87f8845a8ca8f.addTo(map_0657ef7fe0bda7be81c396c50ef974eb);
#
#
#             var feature_group_1be7386e2081272fb54e4547e0b513a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ac2ba1a98b1b667a083d77e6577d505b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1be7386e2081272fb54e4547e0b513a3);
#
#
#         var popup_1521d232ba0cb2d9aedc46dd4add56c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05a9f8bccd8b7ef22470a33d67938f0c = $(`&lt;div id=&quot;html_05a9f8bccd8b7ef22470a33d67938f0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1521d232ba0cb2d9aedc46dd4add56c0.setContent(html_05a9f8bccd8b7ef22470a33d67938f0c);
#
#
#
#         marker_ac2ba1a98b1b667a083d77e6577d505b.bindPopup(popup_1521d232ba0cb2d9aedc46dd4add56c0)
#         ;
#
#
#
#
#             var marker_8902bf8cbe432e3beff4e9f4ae9601ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1be7386e2081272fb54e4547e0b513a3);
#
#
#         var popup_acd76e35e75d92806d9d4154a2279804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec0facb465b11320a9fb4e695f76e758 = $(`&lt;div id=&quot;html_ec0facb465b11320a9fb4e695f76e758&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_acd76e35e75d92806d9d4154a2279804.setContent(html_ec0facb465b11320a9fb4e695f76e758);
#
#
#
#         marker_8902bf8cbe432e3beff4e9f4ae9601ee.bindPopup(popup_acd76e35e75d92806d9d4154a2279804)
#         ;
#
#
#
#
#             var marker_700aa0e5a90f51489be5a1cf31a7edde = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1be7386e2081272fb54e4547e0b513a3);
#
#
#         var popup_4c1b98f8dc7146cd5e6e09b7ee8bc6c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad9c61635535b1572091f8d47f92cf8b = $(`&lt;div id=&quot;html_ad9c61635535b1572091f8d47f92cf8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4c1b98f8dc7146cd5e6e09b7ee8bc6c9.setContent(html_ad9c61635535b1572091f8d47f92cf8b);
#
#
#
#         marker_700aa0e5a90f51489be5a1cf31a7edde.bindPopup(popup_4c1b98f8dc7146cd5e6e09b7ee8bc6c9)
#         ;
#
#
#
#
#             var marker_2af280acbc4bf6f6d314f9367d2c3022 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1be7386e2081272fb54e4547e0b513a3);
#
#
#         var popup_7a8643f7e389ac572741a17ec2aaba0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b49ceb14251cad81f818a26a1e37dfb2 = $(`&lt;div id=&quot;html_b49ceb14251cad81f818a26a1e37dfb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7a8643f7e389ac572741a17ec2aaba0b.setContent(html_b49ceb14251cad81f818a26a1e37dfb2);
#
#
#
#         marker_2af280acbc4bf6f6d314f9367d2c3022.bindPopup(popup_7a8643f7e389ac572741a17ec2aaba0b)
#         ;
#
#
#
#
#             var marker_d6283fbddf99b20e5bca5f5a9b3769fd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1be7386e2081272fb54e4547e0b513a3);
#
#
#         var popup_055aa659ea4dbc59e93485b5fd6d9cfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea87fbd19ba42e9520d05c0e17b1ae14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea87fbd19ba42e9520d05c0e17b1ae14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea87fbd19ba42e9520d05c0e17b1ae14 = L.map(
#                 &quot;map_ea87fbd19ba42e9520d05c0e17b1ae14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2d68a3624d04b71f8a9f36b76dac7a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2d68a3624d04b71f8a9f36b76dac7a8.addTo(map_ea87fbd19ba42e9520d05c0e17b1ae14);
#
#
#             var feature_group_cf026f16edbfa2ac67b8908f507111df = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cf026f16edbfa2ac67b8908f507111df.addTo(map_ea87fbd19ba42e9520d05c0e17b1ae14);
#
#
#             var feature_group_sub_group_fb57602414fd503b37e110653bdaee7e = L.featureGroup.subGroup(
#                 feature_group_cf026f16edbfa2ac67b8908f507111df
#             );
#
#
#             var marker_535190ee8edaf5a4abe7d7400d1bc6bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb57602414fd503b37e110653bdaee7e);
#
#
#         var popup_6c3b1e73ef6f791c6866764e7218f66c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_176c7e2a24576a1172c111022df261f8 = $(`&lt;div id=&quot;html_176c7e2a24576a1172c111022df261f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6c3b1e73ef6f791c6866764e7218f66c.setContent(html_176c7e2a24576a1172c111022df261f8);
#
#
#
#         marker_535190ee8edaf5a4abe7d7400d1bc6bc.bindPopup(popup_6c3b1e73ef6f791c6866764e7218f66c)
#         ;
#
#
#
#
#             var marker_22ec0cdd13f1158193744e24c236acfe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb57602414fd503b37e110653bdaee7e);
#
#
#         var popup_5bec83ccbe66dadc0629e5c90129fc6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60e0c375e6f4ec5463e4bb4088ae6235 = $(`&lt;div id=&quot;html_60e0c375e6f4ec5463e4bb4088ae6235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5bec83ccbe66dadc0629e5c90129fc6c.setContent(html_60e0c375e6f4ec5463e4bb4088ae6235);
#
#
#
#         marker_22ec0cdd13f1158193744e24c236acfe.bindPopup(popup_5bec83ccbe66dadc0629e5c90129fc6c)
#         ;
#
#
#
#
#             var marker_893450151e6282a9764b0d10ac27d9a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb57602414fd503b37e110653bdaee7e);
#
#
#         var popup_43bc52999c9359811e5badd01f7b5e70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b62b1e582d923c27a9d83baca3cdc5c6 = $(`&lt;div id=&quot;html_b62b1e582d923c27a9d83baca3cdc5c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_43bc52999c9359811e5badd01f7b5e70.setContent(html_b62b1e582d923c27a9d83baca3cdc5c6);
#
#
#
#         marker_893450151e6282a9764b0d10ac27d9a3.bindPopup(popup_43bc52999c9359811e5badd01f7b5e70)
#         ;
#
#
#
#
#             var marker_280b20f40a85de84bdee91e1fcb20dff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb57602414fd503b37e110653bdaee7e);
#
#
#         var popup_79f24ff505f238065b4b03402f034cee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f9374838a69cb9801783e842393cec6 = $(`&lt;div id=&quot;html_8f9374838a69cb9801783e842393cec6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_79f24ff505f238065b4b03402f034cee.setContent(html_8f9374838a69cb9801783e842393cec6);
#
#
#
#         marker_
