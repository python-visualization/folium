# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a21973ff4490ed46ddb72e9ebe77ab2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a21973ff4490ed46ddb72e9ebe77ab2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a21973ff4490ed46ddb72e9ebe77ab2 = L.map(
#                 &quot;map_1a21973ff4490ed46ddb72e9ebe77ab2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c89191ed42c04c6da94e4a9418e8f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6c89191ed42c04c6da94e4a9418e8f0.addTo(map_1a21973ff4490ed46ddb72e9ebe77ab2);
#
#
#             var marker_621a0ddbb2bc3bba2f80c274ed5b879c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1a21973ff4490ed46ddb72e9ebe77ab2);
#
#
#         var popup_34f6a5f8e0530f7b8917bae793b7cc46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3e33278a8e4923452f8c0b1d7d37837 = $(`&lt;div id=&quot;html_a3e33278a8e4923452f8c0b1d7d37837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_34f6a5f8e0530f7b8917bae793b7cc46.setContent(html_a3e33278a8e4923452f8c0b1d7d37837);
#
#
#
#         marker_621a0ddbb2bc3bba2f80c274ed5b879c.bindPopup(popup_34f6a5f8e0530f7b8917bae793b7cc46)
#         ;
#
#
#
#
#             var marker_79e73b5a997f76998afc19dc769447f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1a21973ff4490ed46ddb72e9ebe77ab2);
#
#
#         var popup_81847d7daef62d1362e4e535f13c6434 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd3111bc62efead46ef3efef6e07b664 = $(`&lt;div id=&quot;html_bd3111bc62efead46ef3efef6e07b664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_81847d7daef62d1362e4e535f13c6434.setContent(html_bd3111bc62efead46ef3efef6e07b664);
#
#
#
#         marker_79e73b5a997f76998afc19dc769447f6.bindPopup(popup_81847d7daef62d1362e4e535f13c6434)
#         ;
#
#
#
#
#             var marker_815bb8dc6bfee8cb451d51173658b1d8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1a21973ff4490ed46ddb72e9ebe77ab2);
#
#
#         var popup_e278245efadfee0a526157e87393bc8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a48fd5898b68b306b8b72bdea9e8b64a = $(`&lt;div id=&quot;html_a48fd5898b68b306b8b72bdea9e8b64a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e278245efadfee0a526157e87393bc8e.setContent(html_a48fd5898b68b306b8b72bdea9e8b64a);
#
#
#
#         marker_815bb8dc6bfee8cb451d51173658b1d8.bindPopup(popup_e278245efadfee0a526157e87393bc8e)
#         ;
#
#
#
#
#             var marker_61e6411537361e7b3527222ea5b8d330 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1a21973ff4490ed46ddb72e9ebe77ab2);
#
#
#         var popup_f04cd0bbd4374afee9b1dd10457cbf0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f464f350c8269056784abb5dd2e7edf7 = $(`&lt;div id=&quot;html_f464f350c8269056784abb5dd2e7edf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f04cd0bbd4374afee9b1dd10457cbf0f.setContent(html_f464f350c8269056784abb5dd2e7edf7);
#
#
#
#         marker_61e6411537361e7b3527222ea5b8d330.bindPopup(popup_f04cd0bbd4374afee9b1dd10457cbf0f)
#         ;
#
#
#
#
#             var marker_7bc032f8c9d42cb2d135d83fc18aa1fd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1a21973ff4490ed46ddb72e9ebe77ab2);
#
#
#         var popup_f4b3a6104f49c9ad6989329cdb4f1ec7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a43ee983d5fe542dcdaa000c382df86b = $(`&lt;div id=&quot;html_a43ee983d5fe542dcdaa000c382df86b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f4b3a6104f49c9ad6989329cdb4f1ec7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e5b422a88f52a37ddd63d159ceebc85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e5b422a88f52a37ddd63d159ceebc85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e5b422a88f52a37ddd63d159ceebc85 = L.map(
#                 &quot;map_5e5b422a88f52a37ddd63d159ceebc85&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ab325033565187fb85f78056e1f2271 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ab325033565187fb85f78056e1f2271.addTo(map_5e5b422a88f52a37ddd63d159ceebc85);
#
#
#             var feature_group_bdca03cfdd781838576f16311a3f0c12 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2617be2611808e8f6952cdb3ed589886 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bdca03cfdd781838576f16311a3f0c12);
#
#
#         var popup_c02281ab36eed44b785fb7bc3904cfcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d67bc6b3fb80ad1ee097e666f7919824 = $(`&lt;div id=&quot;html_d67bc6b3fb80ad1ee097e666f7919824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c02281ab36eed44b785fb7bc3904cfcd.setContent(html_d67bc6b3fb80ad1ee097e666f7919824);
#
#
#
#         marker_2617be2611808e8f6952cdb3ed589886.bindPopup(popup_c02281ab36eed44b785fb7bc3904cfcd)
#         ;
#
#
#
#
#             var marker_e4338b69236b2ba9f16a2df3319cf4eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bdca03cfdd781838576f16311a3f0c12);
#
#
#         var popup_d0c60401baad2a249effac0bf79cd7aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e577bba51d5f119155fd9349539b6a8a = $(`&lt;div id=&quot;html_e577bba51d5f119155fd9349539b6a8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d0c60401baad2a249effac0bf79cd7aa.setContent(html_e577bba51d5f119155fd9349539b6a8a);
#
#
#
#         marker_e4338b69236b2ba9f16a2df3319cf4eb.bindPopup(popup_d0c60401baad2a249effac0bf79cd7aa)
#         ;
#
#
#
#
#             var marker_543f5e85cb3ae00d2f7ac9d4c5a7f2fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bdca03cfdd781838576f16311a3f0c12);
#
#
#         var popup_d1bfcb71f074ebdaaf68cf2580924d83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a46ce699a88cca64f30f7a82a9c2ee5d = $(`&lt;div id=&quot;html_a46ce699a88cca64f30f7a82a9c2ee5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d1bfcb71f074ebdaaf68cf2580924d83.setContent(html_a46ce699a88cca64f30f7a82a9c2ee5d);
#
#
#
#         marker_543f5e85cb3ae00d2f7ac9d4c5a7f2fa.bindPopup(popup_d1bfcb71f074ebdaaf68cf2580924d83)
#         ;
#
#
#
#
#             var marker_ac702ffec0e3258c9b8b41689adcb900 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bdca03cfdd781838576f16311a3f0c12);
#
#
#         var popup_4ae77967c832a70ef22836c3b41458a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0105b3f73c8a798acd386c77e8ccc59f = $(`&lt;div id=&quot;html_0105b3f73c8a798acd386c77e8ccc59f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4ae77967c832a70ef22836c3b41458a2.setContent(html_0105b3f73c8a798acd386c77e8ccc59f);
#
#
#
#         marker_ac702ffec0e3258c9b8b41689adcb900.bindPopup(popup_4ae77967c832a70ef22836c3b41458a2)
#         ;
#
#
#
#
#             var marker_07bdcdb1b2e8e93704c60ccf9b97be32 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bdca03cfdd781838576f16311a3f0c12);
#
#
#         var popup_2af641c795b1075a795a21f2a80f8a7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d154c5da1d0384d1ae64ae598b7ceb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d154c5da1d0384d1ae64ae598b7ceb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d154c5da1d0384d1ae64ae598b7ceb7 = L.map(
#                 &quot;map_4d154c5da1d0384d1ae64ae598b7ceb7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fca4c71c0acef48077ebb02e8359cea8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fca4c71c0acef48077ebb02e8359cea8.addTo(map_4d154c5da1d0384d1ae64ae598b7ceb7);
#
#
#             var feature_group_07d6b59cfc8c0d37d860f43130f68cdc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_07d6b59cfc8c0d37d860f43130f68cdc.addTo(map_4d154c5da1d0384d1ae64ae598b7ceb7);
#
#
#             var feature_group_sub_group_88dc86a778720d67a805e2e0b0343022 = L.featureGroup.subGroup(
#                 feature_group_07d6b59cfc8c0d37d860f43130f68cdc
#             );
#
#
#             var marker_eddbc2522a15d8152efcbf4c56add721 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_88dc86a778720d67a805e2e0b0343022);
#
#
#         var popup_0b4e56d62d8c74d945e9d1b3c3c202a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2df77b2288a358893ac1bdc8b0ab124 = $(`&lt;div id=&quot;html_c2df77b2288a358893ac1bdc8b0ab124&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0b4e56d62d8c74d945e9d1b3c3c202a3.setContent(html_c2df77b2288a358893ac1bdc8b0ab124);
#
#
#
#         marker_eddbc2522a15d8152efcbf4c56add721.bindPopup(popup_0b4e56d62d8c74d945e9d1b3c3c202a3)
#         ;
#
#
#
#
#             var marker_e90dfca8be13f481cc718e080394edca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_88dc86a778720d67a805e2e0b0343022);
#
#
#         var popup_6cef21feecce34279643cf75fc1b0791 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e59b47f908af2f70b0f4b59898c7ec9 = $(`&lt;div id=&quot;html_3e59b47f908af2f70b0f4b59898c7ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6cef21feecce34279643cf75fc1b0791.setContent(html_3e59b47f908af2f70b0f4b59898c7ec9);
#
#
#
#         marker_e90dfca8be13f481cc718e080394edca.bindPopup(popup_6cef21feecce34279643cf75fc1b0791)
#         ;
#
#
#
#
#             var marker_b6309506c5682bb895a481711f893649 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_88dc86a778720d67a805e2e0b0343022);
#
#
#         var popup_d617ea61a6d4ecc4935e4fa857d7e9a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a4d6bc6fad00193d5be476b16f0b158 = $(`&lt;div id=&quot;html_5a4d6bc6fad00193d5be476b16f0b158&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d617ea61a6d4ecc4935e4fa857d7e9a4.setContent(html_5a4d6bc6fad00193d5be476b16f0b158);
#
#
#
#         marker_b6309506c5682bb895a481711f893649.bindPopup(popup_d617ea61a6d4ecc4935e4fa857d7e9a4)
#         ;
#
#
#
#
#             var marker_36226a54b00042960396c1e42a7fc414 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_88dc86a778720d67a805e2e0b0343022);
#
#
#         var popup_758422f2a7efb4e6448c693f06379374 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4232c584c393597c264a24da9761759e = $(`&lt;div id=&quot;html_4232c584c393597c264a24da9761759e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_758422f2a7efb4e6448c693f06379374.setContent(html_4232c584c393597c264a24da9761759e);
#
#
#
#         marker_
