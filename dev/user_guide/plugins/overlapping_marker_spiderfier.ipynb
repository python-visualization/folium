# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bec468342021967271ec17e44602b047 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bec468342021967271ec17e44602b047&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bec468342021967271ec17e44602b047 = L.map(
#                 &quot;map_bec468342021967271ec17e44602b047&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9cf76133400277b8d3f2095b5237adc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9cf76133400277b8d3f2095b5237adc.addTo(map_bec468342021967271ec17e44602b047);
#
#
#             var marker_ea432c934fce9e1e154b44b1fd65a7d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bec468342021967271ec17e44602b047);
#
#
#         var popup_6b4254063e6e3f25b1169a1457007519 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c9009be9893b310cda49f2f3f085a9c = $(`&lt;div id=&quot;html_3c9009be9893b310cda49f2f3f085a9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6b4254063e6e3f25b1169a1457007519.setContent(html_3c9009be9893b310cda49f2f3f085a9c);
#
#
#
#         marker_ea432c934fce9e1e154b44b1fd65a7d7.bindPopup(popup_6b4254063e6e3f25b1169a1457007519)
#         ;
#
#
#
#
#             var marker_0b7580efac9a376cea9d9d8bb0d6779f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bec468342021967271ec17e44602b047);
#
#
#         var popup_43de13f3c8abca512ec436d4cfa545c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bea580023105b0da65ff7c0a5860bdc = $(`&lt;div id=&quot;html_6bea580023105b0da65ff7c0a5860bdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_43de13f3c8abca512ec436d4cfa545c1.setContent(html_6bea580023105b0da65ff7c0a5860bdc);
#
#
#
#         marker_0b7580efac9a376cea9d9d8bb0d6779f.bindPopup(popup_43de13f3c8abca512ec436d4cfa545c1)
#         ;
#
#
#
#
#             var marker_f4131ece1776c691427804be2708721a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bec468342021967271ec17e44602b047);
#
#
#         var popup_7f0c98f75363840874b86091ad47cd83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7157b2599f37cdeac914fd5f3ed6cc34 = $(`&lt;div id=&quot;html_7157b2599f37cdeac914fd5f3ed6cc34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7f0c98f75363840874b86091ad47cd83.setContent(html_7157b2599f37cdeac914fd5f3ed6cc34);
#
#
#
#         marker_f4131ece1776c691427804be2708721a.bindPopup(popup_7f0c98f75363840874b86091ad47cd83)
#         ;
#
#
#
#
#             var marker_dac109017435f0b95395cbe3a92682b8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bec468342021967271ec17e44602b047);
#
#
#         var popup_c854c0e22273f567707bf57a592897c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0db0b5fdcf148b726966aaafe11ddc8 = $(`&lt;div id=&quot;html_b0db0b5fdcf148b726966aaafe11ddc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c854c0e22273f567707bf57a592897c5.setContent(html_b0db0b5fdcf148b726966aaafe11ddc8);
#
#
#
#         marker_dac109017435f0b95395cbe3a92682b8.bindPopup(popup_c854c0e22273f567707bf57a592897c5)
#         ;
#
#
#
#
#             var marker_2fbe2cac414ba95531ffb62456b1877a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bec468342021967271ec17e44602b047);
#
#
#         var popup_41eed353bad3cb61b6a6d3feefcd766c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3d796f68a3606eae521ae72a61e9211 = $(`&lt;div id=&quot;html_d3d796f68a3606eae521ae72a61e9211&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_41eed353bad3cb61b6a6d3feefcd766c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bea3e23741b4de4cfc658d2add7b9b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bea3e23741b4de4cfc658d2add7b9b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bea3e23741b4de4cfc658d2add7b9b1 = L.map(
#                 &quot;map_3bea3e23741b4de4cfc658d2add7b9b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4096a556c7c5f148b2a4556cc7341440 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4096a556c7c5f148b2a4556cc7341440.addTo(map_3bea3e23741b4de4cfc658d2add7b9b1);
#
#
#             var feature_group_363c33b74bed7dfa204e80a55d0f354b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0bb1440ad8b9f5d1e4660ee24972c831 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_363c33b74bed7dfa204e80a55d0f354b);
#
#
#         var popup_8e74954f7e7c9ff1039a77772c94d176 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14ed1e057ff57f9c2ca29d5eb35eab1f = $(`&lt;div id=&quot;html_14ed1e057ff57f9c2ca29d5eb35eab1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8e74954f7e7c9ff1039a77772c94d176.setContent(html_14ed1e057ff57f9c2ca29d5eb35eab1f);
#
#
#
#         marker_0bb1440ad8b9f5d1e4660ee24972c831.bindPopup(popup_8e74954f7e7c9ff1039a77772c94d176)
#         ;
#
#
#
#
#             var marker_f541bc9a71772da2d387d621b409a27e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_363c33b74bed7dfa204e80a55d0f354b);
#
#
#         var popup_a4274e921abec68752550989ad076f60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_518a521a39fa5fac3c23e85f5811e072 = $(`&lt;div id=&quot;html_518a521a39fa5fac3c23e85f5811e072&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a4274e921abec68752550989ad076f60.setContent(html_518a521a39fa5fac3c23e85f5811e072);
#
#
#
#         marker_f541bc9a71772da2d387d621b409a27e.bindPopup(popup_a4274e921abec68752550989ad076f60)
#         ;
#
#
#
#
#             var marker_ea07df3fd395d7fa48cddb376d7360ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_363c33b74bed7dfa204e80a55d0f354b);
#
#
#         var popup_67f7148777cb5933358035aa98c55f7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78f0c899a9bddbb49b81a085778253f5 = $(`&lt;div id=&quot;html_78f0c899a9bddbb49b81a085778253f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_67f7148777cb5933358035aa98c55f7d.setContent(html_78f0c899a9bddbb49b81a085778253f5);
#
#
#
#         marker_ea07df3fd395d7fa48cddb376d7360ef.bindPopup(popup_67f7148777cb5933358035aa98c55f7d)
#         ;
#
#
#
#
#             var marker_97ecb6a4b5de851663006554ec4df4fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_363c33b74bed7dfa204e80a55d0f354b);
#
#
#         var popup_59c284f909d298f03c42d6435b29c5bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3895a0a9ac4f3549e8a8fa5ac803ca6d = $(`&lt;div id=&quot;html_3895a0a9ac4f3549e8a8fa5ac803ca6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_59c284f909d298f03c42d6435b29c5bf.setContent(html_3895a0a9ac4f3549e8a8fa5ac803ca6d);
#
#
#
#         marker_97ecb6a4b5de851663006554ec4df4fc.bindPopup(popup_59c284f909d298f03c42d6435b29c5bf)
#         ;
#
#
#
#
#             var marker_97c043e606f14bbd27c126c69c6ad927 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_363c33b74bed7dfa204e80a55d0f354b);
#
#
#         var popup_f6a433677b4cf68ef078ea861bf3f2d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac8813c05a86ebf6d84db54d018a93c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac8813c05a86ebf6d84db54d018a93c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac8813c05a86ebf6d84db54d018a93c4 = L.map(
#                 &quot;map_ac8813c05a86ebf6d84db54d018a93c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86309e9ffbbf5fbcb3819007dbc1b04f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86309e9ffbbf5fbcb3819007dbc1b04f.addTo(map_ac8813c05a86ebf6d84db54d018a93c4);
#
#
#             var feature_group_66845b5cfcd6f3931696a1ba9f3a810a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_66845b5cfcd6f3931696a1ba9f3a810a.addTo(map_ac8813c05a86ebf6d84db54d018a93c4);
#
#
#             var feature_group_sub_group_6b0471033ffaa38233722b6576a8d99b = L.featureGroup.subGroup(
#                 feature_group_66845b5cfcd6f3931696a1ba9f3a810a
#             );
#
#
#             var marker_4b242b5879d3f64d7e6a5a716d9b543b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b0471033ffaa38233722b6576a8d99b);
#
#
#         var popup_7e8b732041d90cf7a55c0613554cc80d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0cb2a6a4a8318e8ea86e54d58b57537 = $(`&lt;div id=&quot;html_a0cb2a6a4a8318e8ea86e54d58b57537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7e8b732041d90cf7a55c0613554cc80d.setContent(html_a0cb2a6a4a8318e8ea86e54d58b57537);
#
#
#
#         marker_4b242b5879d3f64d7e6a5a716d9b543b.bindPopup(popup_7e8b732041d90cf7a55c0613554cc80d)
#         ;
#
#
#
#
#             var marker_882ae1e2c88ab306968e040f5a992f9c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b0471033ffaa38233722b6576a8d99b);
#
#
#         var popup_957f35a54b4d8bb1e4b1b24cc6c6f276 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5fd1a92452ad6ef50d663e3ced071b = $(`&lt;div id=&quot;html_4a5fd1a92452ad6ef50d663e3ced071b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_957f35a54b4d8bb1e4b1b24cc6c6f276.setContent(html_4a5fd1a92452ad6ef50d663e3ced071b);
#
#
#
#         marker_882ae1e2c88ab306968e040f5a992f9c.bindPopup(popup_957f35a54b4d8bb1e4b1b24cc6c6f276)
#         ;
#
#
#
#
#             var marker_f7962766cab232a2151672b2ca7c8a82 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b0471033ffaa38233722b6576a8d99b);
#
#
#         var popup_b7bb68da0934c9f138ea134706ee7197 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e06de4a38a83a1061a3c52336465a9a = $(`&lt;div id=&quot;html_3e06de4a38a83a1061a3c52336465a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b7bb68da0934c9f138ea134706ee7197.setContent(html_3e06de4a38a83a1061a3c52336465a9a);
#
#
#
#         marker_f7962766cab232a2151672b2ca7c8a82.bindPopup(popup_b7bb68da0934c9f138ea134706ee7197)
#         ;
#
#
#
#
#             var marker_37b9257a7c197c163a448763c07f789b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b0471033ffaa38233722b6576a8d99b);
#
#
#         var popup_0c4bcb993cddd9493261db755520860f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_555d7119607e1642b5faed167662b698 = $(`&lt;div id=&quot;html_555d7119607e1642b5faed167662b698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0c4bcb993cddd9493261db755520860f.setContent(html_555d7119607e1642b5faed167662b698);
#
#
#
#         marker_
