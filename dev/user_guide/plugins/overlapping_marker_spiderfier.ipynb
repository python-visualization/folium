# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ae240aef404ffcede9b32ade2d2c542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ae240aef404ffcede9b32ade2d2c542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ae240aef404ffcede9b32ade2d2c542 = L.map(
#                 &quot;map_7ae240aef404ffcede9b32ade2d2c542&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c879016c6b55fe42f9e45f186f1417af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c879016c6b55fe42f9e45f186f1417af.addTo(map_7ae240aef404ffcede9b32ade2d2c542);
#
#
#             var marker_ef87a20f31348fe742720061270483c9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7ae240aef404ffcede9b32ade2d2c542);
#
#
#         var popup_4fb4b96c71338d7a13237b83e09fdac6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_162b484385226a647cb75cd8a1003115 = $(`&lt;div id=&quot;html_162b484385226a647cb75cd8a1003115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4fb4b96c71338d7a13237b83e09fdac6.setContent(html_162b484385226a647cb75cd8a1003115);
#
#
#
#         marker_ef87a20f31348fe742720061270483c9.bindPopup(popup_4fb4b96c71338d7a13237b83e09fdac6)
#         ;
#
#
#
#
#             var marker_a564c6fe96058b00f732f724f883bb55 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7ae240aef404ffcede9b32ade2d2c542);
#
#
#         var popup_a23c53cdecadcf582db87501527e398a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_badab143050f6627c32e07d804fe590c = $(`&lt;div id=&quot;html_badab143050f6627c32e07d804fe590c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a23c53cdecadcf582db87501527e398a.setContent(html_badab143050f6627c32e07d804fe590c);
#
#
#
#         marker_a564c6fe96058b00f732f724f883bb55.bindPopup(popup_a23c53cdecadcf582db87501527e398a)
#         ;
#
#
#
#
#             var marker_15c0e8e91e948a8502b4ef300138ada6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7ae240aef404ffcede9b32ade2d2c542);
#
#
#         var popup_2e32b76a913ec3b77eae69fc1845c4ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ba7cd8822a0f3cc3c9d99b8f7c8c58d = $(`&lt;div id=&quot;html_7ba7cd8822a0f3cc3c9d99b8f7c8c58d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2e32b76a913ec3b77eae69fc1845c4ac.setContent(html_7ba7cd8822a0f3cc3c9d99b8f7c8c58d);
#
#
#
#         marker_15c0e8e91e948a8502b4ef300138ada6.bindPopup(popup_2e32b76a913ec3b77eae69fc1845c4ac)
#         ;
#
#
#
#
#             var marker_705a210e23a8f731722319552afd5851 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7ae240aef404ffcede9b32ade2d2c542);
#
#
#         var popup_63e7192ced0ff4fd9ef3496ca9353198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64d3ff4e0f58438c9a3bd3714c0c0bef = $(`&lt;div id=&quot;html_64d3ff4e0f58438c9a3bd3714c0c0bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_63e7192ced0ff4fd9ef3496ca9353198.setContent(html_64d3ff4e0f58438c9a3bd3714c0c0bef);
#
#
#
#         marker_705a210e23a8f731722319552afd5851.bindPopup(popup_63e7192ced0ff4fd9ef3496ca9353198)
#         ;
#
#
#
#
#             var marker_0f678e6d40a6bfe5162c697b277460a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7ae240aef404ffcede9b32ade2d2c542);
#
#
#         var popup_16f22c1242335bfaf42ae4cdbeb30daf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc60cc769285d62ef7e874b7e2dcbdad = $(`&lt;div id=&quot;html_dc60cc769285d62ef7e874b7e2dcbdad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_16f22c1242335bfaf42ae4cdbeb30daf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc6be0df5dd0d6dbb9ff4415a2debc16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc6be0df5dd0d6dbb9ff4415a2debc16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc6be0df5dd0d6dbb9ff4415a2debc16 = L.map(
#                 &quot;map_fc6be0df5dd0d6dbb9ff4415a2debc16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3350bd5e2e85723929f2cfb897ca171b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3350bd5e2e85723929f2cfb897ca171b.addTo(map_fc6be0df5dd0d6dbb9ff4415a2debc16);
#
#
#             var feature_group_ca17d4ee4d03fc3a70291344a4f1e104 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_38c8bf51e426f20c3e343343bb7ba652 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ca17d4ee4d03fc3a70291344a4f1e104);
#
#
#         var popup_2e46548eaddf33a05f65ad12a2ed0a66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f97e33f2b58b88b4ef8d7fa713d6b40 = $(`&lt;div id=&quot;html_7f97e33f2b58b88b4ef8d7fa713d6b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2e46548eaddf33a05f65ad12a2ed0a66.setContent(html_7f97e33f2b58b88b4ef8d7fa713d6b40);
#
#
#
#         marker_38c8bf51e426f20c3e343343bb7ba652.bindPopup(popup_2e46548eaddf33a05f65ad12a2ed0a66)
#         ;
#
#
#
#
#             var marker_5c2e25ace0c4bed21b8df97780f719e3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ca17d4ee4d03fc3a70291344a4f1e104);
#
#
#         var popup_349e1bb536c638144103bc3f21bb5a22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0751edf2f871033a9e415a5a31914f74 = $(`&lt;div id=&quot;html_0751edf2f871033a9e415a5a31914f74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_349e1bb536c638144103bc3f21bb5a22.setContent(html_0751edf2f871033a9e415a5a31914f74);
#
#
#
#         marker_5c2e25ace0c4bed21b8df97780f719e3.bindPopup(popup_349e1bb536c638144103bc3f21bb5a22)
#         ;
#
#
#
#
#             var marker_d743c781c95098606ce81239de95c77f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ca17d4ee4d03fc3a70291344a4f1e104);
#
#
#         var popup_9d08ccfeb9e799e2328f878b65f869f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_995c737e1ae2b4b708add47f54ab1bdd = $(`&lt;div id=&quot;html_995c737e1ae2b4b708add47f54ab1bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9d08ccfeb9e799e2328f878b65f869f6.setContent(html_995c737e1ae2b4b708add47f54ab1bdd);
#
#
#
#         marker_d743c781c95098606ce81239de95c77f.bindPopup(popup_9d08ccfeb9e799e2328f878b65f869f6)
#         ;
#
#
#
#
#             var marker_8753aec4a01d350ca37acc647722e772 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ca17d4ee4d03fc3a70291344a4f1e104);
#
#
#         var popup_9b5e7ae869416300d88b4ca9e81fb6cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_819804c3de36907355bb7b19083106bb = $(`&lt;div id=&quot;html_819804c3de36907355bb7b19083106bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9b5e7ae869416300d88b4ca9e81fb6cd.setContent(html_819804c3de36907355bb7b19083106bb);
#
#
#
#         marker_8753aec4a01d350ca37acc647722e772.bindPopup(popup_9b5e7ae869416300d88b4ca9e81fb6cd)
#         ;
#
#
#
#
#             var marker_17018770321a29a84bb24745fc235b53 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ca17d4ee4d03fc3a70291344a4f1e104);
#
#
#         var popup_76e53c68ebbfbb91227ec5af69c407c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89fd7778a59afa7b115c8ba129158e5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89fd7778a59afa7b115c8ba129158e5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89fd7778a59afa7b115c8ba129158e5b = L.map(
#                 &quot;map_89fd7778a59afa7b115c8ba129158e5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aacfd0f94384f508102f8af5dd97510b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aacfd0f94384f508102f8af5dd97510b.addTo(map_89fd7778a59afa7b115c8ba129158e5b);
#
#
#             var feature_group_661baf69885eee46b9de23c2bb7e3a5e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_661baf69885eee46b9de23c2bb7e3a5e.addTo(map_89fd7778a59afa7b115c8ba129158e5b);
#
#
#             var feature_group_sub_group_113fba2a44e1012887a0c332ec14415e = L.featureGroup.subGroup(
#                 feature_group_661baf69885eee46b9de23c2bb7e3a5e
#             );
#
#
#             var marker_e3f992b4596b8973e361785294d9d704 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_113fba2a44e1012887a0c332ec14415e);
#
#
#         var popup_5885195b6f6af8f63d1f5debce824faf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e6cba062fc1b2d7776ac6d40604c01c = $(`&lt;div id=&quot;html_4e6cba062fc1b2d7776ac6d40604c01c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5885195b6f6af8f63d1f5debce824faf.setContent(html_4e6cba062fc1b2d7776ac6d40604c01c);
#
#
#
#         marker_e3f992b4596b8973e361785294d9d704.bindPopup(popup_5885195b6f6af8f63d1f5debce824faf)
#         ;
#
#
#
#
#             var marker_ba9132f37e70743dd344e0b3b18060e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_113fba2a44e1012887a0c332ec14415e);
#
#
#         var popup_8c95a8e8ec7a393121856c57c3a407a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03d6087882e17d751435e338643edbd9 = $(`&lt;div id=&quot;html_03d6087882e17d751435e338643edbd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8c95a8e8ec7a393121856c57c3a407a5.setContent(html_03d6087882e17d751435e338643edbd9);
#
#
#
#         marker_ba9132f37e70743dd344e0b3b18060e6.bindPopup(popup_8c95a8e8ec7a393121856c57c3a407a5)
#         ;
#
#
#
#
#             var marker_ad65de574e67a33df7e88f9bd563240f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_113fba2a44e1012887a0c332ec14415e);
#
#
#         var popup_ec5f4995047d4eb22191cb7950e9750c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f598834c13ad0b2462baabd6a5dcddc1 = $(`&lt;div id=&quot;html_f598834c13ad0b2462baabd6a5dcddc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ec5f4995047d4eb22191cb7950e9750c.setContent(html_f598834c13ad0b2462baabd6a5dcddc1);
#
#
#
#         marker_ad65de574e67a33df7e88f9bd563240f.bindPopup(popup_ec5f4995047d4eb22191cb7950e9750c)
#         ;
#
#
#
#
#             var marker_5ca7938d90b2f1067b53d9b2eb486500 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_113fba2a44e1012887a0c332ec14415e);
#
#
#         var popup_f02b227088cecf0cde237f84237a3aa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60b3dd9616e9b5d8f75c9a8b79e6e50b = $(`&lt;div id=&quot;html_60b3dd9616e9b5d8f75c9a8b79e6e50b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f02b227088cecf0cde237f84237a3aa8.setContent(html_60b3dd9616e9b5d8f75c9a8b79e6e50b);
#
#
#
#         marker_
