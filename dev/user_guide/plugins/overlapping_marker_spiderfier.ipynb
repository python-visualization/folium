# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38209a4496aa6eb225188b01d052f8f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38209a4496aa6eb225188b01d052f8f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38209a4496aa6eb225188b01d052f8f8 = L.map(
#                 &quot;map_38209a4496aa6eb225188b01d052f8f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1849bdf3395c5ab40c46e142a651a230 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1849bdf3395c5ab40c46e142a651a230.addTo(map_38209a4496aa6eb225188b01d052f8f8);
#
#
#             var marker_9558d00ce1d906086df6c0838c86a377 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_38209a4496aa6eb225188b01d052f8f8);
#
#
#         var popup_0d62571f050b334d7ccdedb0749a52c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0145af8c617a837bf12d0982756abae9 = $(`&lt;div id=&quot;html_0145af8c617a837bf12d0982756abae9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0d62571f050b334d7ccdedb0749a52c7.setContent(html_0145af8c617a837bf12d0982756abae9);
#
#
#
#         marker_9558d00ce1d906086df6c0838c86a377.bindPopup(popup_0d62571f050b334d7ccdedb0749a52c7)
#         ;
#
#
#
#
#             var marker_9e51f6b7c4dcdeb5a4dac61cd4db8a0d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_38209a4496aa6eb225188b01d052f8f8);
#
#
#         var popup_5a4c7cfb90aa0da2f2ffed0f77b76b9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7989380797f3cd5162647a7caf655a5b = $(`&lt;div id=&quot;html_7989380797f3cd5162647a7caf655a5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5a4c7cfb90aa0da2f2ffed0f77b76b9e.setContent(html_7989380797f3cd5162647a7caf655a5b);
#
#
#
#         marker_9e51f6b7c4dcdeb5a4dac61cd4db8a0d.bindPopup(popup_5a4c7cfb90aa0da2f2ffed0f77b76b9e)
#         ;
#
#
#
#
#             var marker_7ac4322b819737efc6ca52d3d7b7a5aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_38209a4496aa6eb225188b01d052f8f8);
#
#
#         var popup_f595c95660dae0f71b00127a0bbff362 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61fcfeb9af2ee63c2065db19a98987cb = $(`&lt;div id=&quot;html_61fcfeb9af2ee63c2065db19a98987cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f595c95660dae0f71b00127a0bbff362.setContent(html_61fcfeb9af2ee63c2065db19a98987cb);
#
#
#
#         marker_7ac4322b819737efc6ca52d3d7b7a5aa.bindPopup(popup_f595c95660dae0f71b00127a0bbff362)
#         ;
#
#
#
#
#             var marker_048b23f0a4465a595f4808b4bef2d2a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_38209a4496aa6eb225188b01d052f8f8);
#
#
#         var popup_eba06829e3f78149315f1e2e9643c3ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1918a1044a33725e2a7febb08a4dcb2 = $(`&lt;div id=&quot;html_a1918a1044a33725e2a7febb08a4dcb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eba06829e3f78149315f1e2e9643c3ee.setContent(html_a1918a1044a33725e2a7febb08a4dcb2);
#
#
#
#         marker_048b23f0a4465a595f4808b4bef2d2a4.bindPopup(popup_eba06829e3f78149315f1e2e9643c3ee)
#         ;
#
#
#
#
#             var marker_e3cb271ff314b9ace981646a56a3de78 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_38209a4496aa6eb225188b01d052f8f8);
#
#
#         var popup_2ce8c7c712682530df9942b6d5683e7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b15e29250a4523b799c359f947ad99e = $(`&lt;div id=&quot;html_3b15e29250a4523b799c359f947ad99e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2ce8c7c712682530df9942b6d5683e7a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67da000ce83c2a57027d6ad570d70387 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67da000ce83c2a57027d6ad570d70387&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67da000ce83c2a57027d6ad570d70387 = L.map(
#                 &quot;map_67da000ce83c2a57027d6ad570d70387&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7543e4fabb4619c5dbde59390b89696f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7543e4fabb4619c5dbde59390b89696f.addTo(map_67da000ce83c2a57027d6ad570d70387);
#
#
#             var feature_group_aa9546ff7aa91087d5827e8c374c25a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4349dc4cf136bd64472b7a254680f8c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_aa9546ff7aa91087d5827e8c374c25a3);
#
#
#         var popup_70183c199e9fb23ede6f86f512054c3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_966edb91df10a8616bf1e75470f8efd0 = $(`&lt;div id=&quot;html_966edb91df10a8616bf1e75470f8efd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_70183c199e9fb23ede6f86f512054c3a.setContent(html_966edb91df10a8616bf1e75470f8efd0);
#
#
#
#         marker_4349dc4cf136bd64472b7a254680f8c5.bindPopup(popup_70183c199e9fb23ede6f86f512054c3a)
#         ;
#
#
#
#
#             var marker_a819ee9bd67af9cb6b6865d79ded6003 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_aa9546ff7aa91087d5827e8c374c25a3);
#
#
#         var popup_4171c238bb655b7076e746ac04dc2495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_988b0b8276c90179d0988bd4baf9d1eb = $(`&lt;div id=&quot;html_988b0b8276c90179d0988bd4baf9d1eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4171c238bb655b7076e746ac04dc2495.setContent(html_988b0b8276c90179d0988bd4baf9d1eb);
#
#
#
#         marker_a819ee9bd67af9cb6b6865d79ded6003.bindPopup(popup_4171c238bb655b7076e746ac04dc2495)
#         ;
#
#
#
#
#             var marker_eab1f298c3eb72b3be0ccb97190256d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_aa9546ff7aa91087d5827e8c374c25a3);
#
#
#         var popup_e75244d3c451c9af751c6bafa46eb6a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0e524317b41f7caf623f984f67abd91 = $(`&lt;div id=&quot;html_c0e524317b41f7caf623f984f67abd91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e75244d3c451c9af751c6bafa46eb6a1.setContent(html_c0e524317b41f7caf623f984f67abd91);
#
#
#
#         marker_eab1f298c3eb72b3be0ccb97190256d0.bindPopup(popup_e75244d3c451c9af751c6bafa46eb6a1)
#         ;
#
#
#
#
#             var marker_6e8cd69ec5218abf38ff104e0adc03be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_aa9546ff7aa91087d5827e8c374c25a3);
#
#
#         var popup_0ae92a228e87efe5c329499dfc3ee27e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c1af9eebc12989cac2283087035de0c = $(`&lt;div id=&quot;html_8c1af9eebc12989cac2283087035de0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0ae92a228e87efe5c329499dfc3ee27e.setContent(html_8c1af9eebc12989cac2283087035de0c);
#
#
#
#         marker_6e8cd69ec5218abf38ff104e0adc03be.bindPopup(popup_0ae92a228e87efe5c329499dfc3ee27e)
#         ;
#
#
#
#
#             var marker_693f0003feedf7828cfbd18b1d58fcf9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_aa9546ff7aa91087d5827e8c374c25a3);
#
#
#         var popup_840286eed0b0b2b471cfca1d0cf58373 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d809088e0fc8059b3eb270283c81bbda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d809088e0fc8059b3eb270283c81bbda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d809088e0fc8059b3eb270283c81bbda = L.map(
#                 &quot;map_d809088e0fc8059b3eb270283c81bbda&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52aec985f4bfe0d022159c3a9a44eb6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52aec985f4bfe0d022159c3a9a44eb6c.addTo(map_d809088e0fc8059b3eb270283c81bbda);
#
#
#             var feature_group_10dac73d4d3515d447b08a76b8df39b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_10dac73d4d3515d447b08a76b8df39b4.addTo(map_d809088e0fc8059b3eb270283c81bbda);
#
#
#             var feature_group_sub_group_16e9d288aaf750a8234c0437c23a6283 = L.featureGroup.subGroup(
#                 feature_group_10dac73d4d3515d447b08a76b8df39b4
#             );
#
#
#             var marker_575d3f5799432afcdf1cefca44793740 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_16e9d288aaf750a8234c0437c23a6283);
#
#
#         var popup_3d03fbf6b502fac66a0f712b9fd16552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b45fd830fb5e77309c60d13e0cdc1f90 = $(`&lt;div id=&quot;html_b45fd830fb5e77309c60d13e0cdc1f90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3d03fbf6b502fac66a0f712b9fd16552.setContent(html_b45fd830fb5e77309c60d13e0cdc1f90);
#
#
#
#         marker_575d3f5799432afcdf1cefca44793740.bindPopup(popup_3d03fbf6b502fac66a0f712b9fd16552)
#         ;
#
#
#
#
#             var marker_1e266e377e7b618053786af9f37cbcc3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_16e9d288aaf750a8234c0437c23a6283);
#
#
#         var popup_1106c515bd6e8108ac25d62b03578f94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4a1ed7b3fd482af03d2f9a2a09eefc9 = $(`&lt;div id=&quot;html_c4a1ed7b3fd482af03d2f9a2a09eefc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1106c515bd6e8108ac25d62b03578f94.setContent(html_c4a1ed7b3fd482af03d2f9a2a09eefc9);
#
#
#
#         marker_1e266e377e7b618053786af9f37cbcc3.bindPopup(popup_1106c515bd6e8108ac25d62b03578f94)
#         ;
#
#
#
#
#             var marker_5b3de9b46dd60ebff7d7591e397c2104 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_16e9d288aaf750a8234c0437c23a6283);
#
#
#         var popup_85bab41e0c6bb790b480cc3439373fde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3849dc3564684d75ecf3d5988193199f = $(`&lt;div id=&quot;html_3849dc3564684d75ecf3d5988193199f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_85bab41e0c6bb790b480cc3439373fde.setContent(html_3849dc3564684d75ecf3d5988193199f);
#
#
#
#         marker_5b3de9b46dd60ebff7d7591e397c2104.bindPopup(popup_85bab41e0c6bb790b480cc3439373fde)
#         ;
#
#
#
#
#             var marker_c0369b24cef6a5b08c5756f6f46e5cee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_16e9d288aaf750a8234c0437c23a6283);
#
#
#         var popup_7d925aa1debbf25fe8ec52502aaf5d7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_284f161f37561d23fc3097af8527da38 = $(`&lt;div id=&quot;html_284f161f37561d23fc3097af8527da38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7d925aa1debbf25fe8ec52502aaf5d7c.setContent(html_284f161f37561d23fc3097af8527da38);
#
#
#
#         marker_
