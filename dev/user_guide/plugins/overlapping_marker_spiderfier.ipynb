# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcc49cea8cc07e19f91c70add2feb0de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcc49cea8cc07e19f91c70add2feb0de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcc49cea8cc07e19f91c70add2feb0de = L.map(
#                 &quot;map_dcc49cea8cc07e19f91c70add2feb0de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e222e0e5abcffb5690db0169c6805c0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e222e0e5abcffb5690db0169c6805c0a.addTo(map_dcc49cea8cc07e19f91c70add2feb0de);
#
#
#             var marker_4dc4347de57b2e1a8c2de0aceecf6c61 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dcc49cea8cc07e19f91c70add2feb0de);
#
#
#         var popup_6884216c2a34ddc7ea2d1aaa9258a50c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2682db0784f0d2e78048d68c2f37fcbe = $(`&lt;div id=&quot;html_2682db0784f0d2e78048d68c2f37fcbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6884216c2a34ddc7ea2d1aaa9258a50c.setContent(html_2682db0784f0d2e78048d68c2f37fcbe);
#
#
#
#         marker_4dc4347de57b2e1a8c2de0aceecf6c61.bindPopup(popup_6884216c2a34ddc7ea2d1aaa9258a50c)
#         ;
#
#
#
#
#             var marker_e87e6d3ca0d873f0dac503f8064943af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dcc49cea8cc07e19f91c70add2feb0de);
#
#
#         var popup_2c3442030d0fe4f529915f5a83fa2092 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55465f89fda101da88b1864c8aacb608 = $(`&lt;div id=&quot;html_55465f89fda101da88b1864c8aacb608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2c3442030d0fe4f529915f5a83fa2092.setContent(html_55465f89fda101da88b1864c8aacb608);
#
#
#
#         marker_e87e6d3ca0d873f0dac503f8064943af.bindPopup(popup_2c3442030d0fe4f529915f5a83fa2092)
#         ;
#
#
#
#
#             var marker_c28423f50a24f073948103c11a3ccf63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dcc49cea8cc07e19f91c70add2feb0de);
#
#
#         var popup_df2d9f1b1c00fed42c13757ddf523413 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4137b4c96c9a951735512402c557ab13 = $(`&lt;div id=&quot;html_4137b4c96c9a951735512402c557ab13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_df2d9f1b1c00fed42c13757ddf523413.setContent(html_4137b4c96c9a951735512402c557ab13);
#
#
#
#         marker_c28423f50a24f073948103c11a3ccf63.bindPopup(popup_df2d9f1b1c00fed42c13757ddf523413)
#         ;
#
#
#
#
#             var marker_e8d8fcc0f141b3785b4c7ae04cddf215 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dcc49cea8cc07e19f91c70add2feb0de);
#
#
#         var popup_954e2759cd39204815e70fa007a7c293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccd8e9fbb8b554aeb8e6e0f833a438af = $(`&lt;div id=&quot;html_ccd8e9fbb8b554aeb8e6e0f833a438af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_954e2759cd39204815e70fa007a7c293.setContent(html_ccd8e9fbb8b554aeb8e6e0f833a438af);
#
#
#
#         marker_e8d8fcc0f141b3785b4c7ae04cddf215.bindPopup(popup_954e2759cd39204815e70fa007a7c293)
#         ;
#
#
#
#
#             var marker_0bd76622494dc9e185d3cf16d56ef588 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dcc49cea8cc07e19f91c70add2feb0de);
#
#
#         var popup_a4a9839d1ab00ba62712d052edead156 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d5c52e6814310814f1c1ad25143b1d2 = $(`&lt;div id=&quot;html_7d5c52e6814310814f1c1ad25143b1d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a4a9839d1ab00ba62712d052edead156.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f313506741ca2f8a20438c65cddc1506 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f313506741ca2f8a20438c65cddc1506&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f313506741ca2f8a20438c65cddc1506 = L.map(
#                 &quot;map_f313506741ca2f8a20438c65cddc1506&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39708fc857237440b6d61fde7a507efc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39708fc857237440b6d61fde7a507efc.addTo(map_f313506741ca2f8a20438c65cddc1506);
#
#
#             var feature_group_1f00d2d7c2354875770add2e78e54346 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ce7e821166b8c2a25c0ed2047c84c7f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1f00d2d7c2354875770add2e78e54346);
#
#
#         var popup_e8c692db2d9497945969130abe8456f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4263ff5ca6e42c9a04282f931d1de18 = $(`&lt;div id=&quot;html_a4263ff5ca6e42c9a04282f931d1de18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e8c692db2d9497945969130abe8456f2.setContent(html_a4263ff5ca6e42c9a04282f931d1de18);
#
#
#
#         marker_ce7e821166b8c2a25c0ed2047c84c7f0.bindPopup(popup_e8c692db2d9497945969130abe8456f2)
#         ;
#
#
#
#
#             var marker_f8042fb8f08a5315228be6b6c2372526 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1f00d2d7c2354875770add2e78e54346);
#
#
#         var popup_0a6847e711e20207db8ec20cebf38bf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a16131174195c765acd9685251705e4 = $(`&lt;div id=&quot;html_4a16131174195c765acd9685251705e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0a6847e711e20207db8ec20cebf38bf0.setContent(html_4a16131174195c765acd9685251705e4);
#
#
#
#         marker_f8042fb8f08a5315228be6b6c2372526.bindPopup(popup_0a6847e711e20207db8ec20cebf38bf0)
#         ;
#
#
#
#
#             var marker_fd6a2e71a6d13cefac8e833b5fab351d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1f00d2d7c2354875770add2e78e54346);
#
#
#         var popup_2a3e3696607feaf717f0e1b46416e44f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_293871ed39279a5849fdcd7577b02fe6 = $(`&lt;div id=&quot;html_293871ed39279a5849fdcd7577b02fe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2a3e3696607feaf717f0e1b46416e44f.setContent(html_293871ed39279a5849fdcd7577b02fe6);
#
#
#
#         marker_fd6a2e71a6d13cefac8e833b5fab351d.bindPopup(popup_2a3e3696607feaf717f0e1b46416e44f)
#         ;
#
#
#
#
#             var marker_dfe36dfd0bdb3c3a825a3e4d826a1525 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1f00d2d7c2354875770add2e78e54346);
#
#
#         var popup_9fd43aa3dfddff6a642fc9fa1a938643 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59d0cb52384763ea79dfc50b8c39a5f2 = $(`&lt;div id=&quot;html_59d0cb52384763ea79dfc50b8c39a5f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9fd43aa3dfddff6a642fc9fa1a938643.setContent(html_59d0cb52384763ea79dfc50b8c39a5f2);
#
#
#
#         marker_dfe36dfd0bdb3c3a825a3e4d826a1525.bindPopup(popup_9fd43aa3dfddff6a642fc9fa1a938643)
#         ;
#
#
#
#
#             var marker_587678243271819edeca45a6f49f1af6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1f00d2d7c2354875770add2e78e54346);
#
#
#         var popup_0ce4f18016cc43fd455941ccb82676a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8d57109c135fc9a4444304ed4d40f1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8d57109c135fc9a4444304ed4d40f1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8d57109c135fc9a4444304ed4d40f1d = L.map(
#                 &quot;map_b8d57109c135fc9a4444304ed4d40f1d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb45fd8c242a912722f0f9689f3a0a39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb45fd8c242a912722f0f9689f3a0a39.addTo(map_b8d57109c135fc9a4444304ed4d40f1d);
#
#
#             var feature_group_c1529347325b3f0756d1df94f04a39b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c1529347325b3f0756d1df94f04a39b5.addTo(map_b8d57109c135fc9a4444304ed4d40f1d);
#
#
#             var feature_group_sub_group_8cfc1d51a2cbc2a7aedeffc6075fbd8f = L.featureGroup.subGroup(
#                 feature_group_c1529347325b3f0756d1df94f04a39b5
#             );
#
#
#             var marker_1cec26ccdac2e3e191fc24eb2fe9e76b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cfc1d51a2cbc2a7aedeffc6075fbd8f);
#
#
#         var popup_1d50af287809926ec8e6e2a4e5fd8fa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a6987dad15d0dff6212f3a37f9802f8 = $(`&lt;div id=&quot;html_5a6987dad15d0dff6212f3a37f9802f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1d50af287809926ec8e6e2a4e5fd8fa1.setContent(html_5a6987dad15d0dff6212f3a37f9802f8);
#
#
#
#         marker_1cec26ccdac2e3e191fc24eb2fe9e76b.bindPopup(popup_1d50af287809926ec8e6e2a4e5fd8fa1)
#         ;
#
#
#
#
#             var marker_500ea69e01af275c05e20fb58a832420 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cfc1d51a2cbc2a7aedeffc6075fbd8f);
#
#
#         var popup_79fff42a08bd863cf8eb8c76cc0c06c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_255397ed454388461c83701d458c09a1 = $(`&lt;div id=&quot;html_255397ed454388461c83701d458c09a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_79fff42a08bd863cf8eb8c76cc0c06c5.setContent(html_255397ed454388461c83701d458c09a1);
#
#
#
#         marker_500ea69e01af275c05e20fb58a832420.bindPopup(popup_79fff42a08bd863cf8eb8c76cc0c06c5)
#         ;
#
#
#
#
#             var marker_b24244b4d3f45136c282b1067a1cfca8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cfc1d51a2cbc2a7aedeffc6075fbd8f);
#
#
#         var popup_5e89a29d1e3bbe97da00fcc09c9b4c9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48c5a7fd905689bb419a7f5671961b79 = $(`&lt;div id=&quot;html_48c5a7fd905689bb419a7f5671961b79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5e89a29d1e3bbe97da00fcc09c9b4c9b.setContent(html_48c5a7fd905689bb419a7f5671961b79);
#
#
#
#         marker_b24244b4d3f45136c282b1067a1cfca8.bindPopup(popup_5e89a29d1e3bbe97da00fcc09c9b4c9b)
#         ;
#
#
#
#
#             var marker_669931f5f5b02b12f7468f43af79f940 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cfc1d51a2cbc2a7aedeffc6075fbd8f);
#
#
#         var popup_577620739375e27d46d7a148f72e2f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ef96765974192f2313935f982e7de88 = $(`&lt;div id=&quot;html_7ef96765974192f2313935f982e7de88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_577620739375e27d46d7a148f72e2f8b.setContent(html_7ef96765974192f2313935f982e7de88);
#
#
#
#         marker_
