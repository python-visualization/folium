# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6aed5973117711b3bf2f254dbfbeaab2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6aed5973117711b3bf2f254dbfbeaab2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6aed5973117711b3bf2f254dbfbeaab2 = L.map(
#                 &quot;map_6aed5973117711b3bf2f254dbfbeaab2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21b67e43da9cd588c48774ac65362171 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21b67e43da9cd588c48774ac65362171.addTo(map_6aed5973117711b3bf2f254dbfbeaab2);
#
#
#             var marker_10abcd92194dfa7e53920cc8cc6b1efa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6aed5973117711b3bf2f254dbfbeaab2);
#
#
#         var popup_a9b82a84fa9d4379dd76c94ac7ba41ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbb6405449cc26c890e734c43d88abad = $(`&lt;div id=&quot;html_dbb6405449cc26c890e734c43d88abad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a9b82a84fa9d4379dd76c94ac7ba41ad.setContent(html_dbb6405449cc26c890e734c43d88abad);
#
#
#
#         marker_10abcd92194dfa7e53920cc8cc6b1efa.bindPopup(popup_a9b82a84fa9d4379dd76c94ac7ba41ad)
#         ;
#
#
#
#
#             var marker_ccfe6d54a1ce23f83bec2e885f26a879 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6aed5973117711b3bf2f254dbfbeaab2);
#
#
#         var popup_f10b0a1021b1b25fb6355bba7c921e80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1efd70e4f3eb92b36b1247fdb58f597 = $(`&lt;div id=&quot;html_f1efd70e4f3eb92b36b1247fdb58f597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f10b0a1021b1b25fb6355bba7c921e80.setContent(html_f1efd70e4f3eb92b36b1247fdb58f597);
#
#
#
#         marker_ccfe6d54a1ce23f83bec2e885f26a879.bindPopup(popup_f10b0a1021b1b25fb6355bba7c921e80)
#         ;
#
#
#
#
#             var marker_816a09b28a5a17f4006e82d50324b26c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6aed5973117711b3bf2f254dbfbeaab2);
#
#
#         var popup_8ac772ee2a1b677f991e54ef358f6fb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f044b383460948dafd955ac82cfe8ba = $(`&lt;div id=&quot;html_3f044b383460948dafd955ac82cfe8ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ac772ee2a1b677f991e54ef358f6fb9.setContent(html_3f044b383460948dafd955ac82cfe8ba);
#
#
#
#         marker_816a09b28a5a17f4006e82d50324b26c.bindPopup(popup_8ac772ee2a1b677f991e54ef358f6fb9)
#         ;
#
#
#
#
#             var marker_206e5b903e9d5a2a225913549c34fe3b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6aed5973117711b3bf2f254dbfbeaab2);
#
#
#         var popup_ca5bc08d2890cc7bb4a917713e6d9ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a32d44c7d467a788e22368ea71795e5 = $(`&lt;div id=&quot;html_3a32d44c7d467a788e22368ea71795e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ca5bc08d2890cc7bb4a917713e6d9ede.setContent(html_3a32d44c7d467a788e22368ea71795e5);
#
#
#
#         marker_206e5b903e9d5a2a225913549c34fe3b.bindPopup(popup_ca5bc08d2890cc7bb4a917713e6d9ede)
#         ;
#
#
#
#
#             var marker_52214f35940b61a7a07e7ed6861ef49c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6aed5973117711b3bf2f254dbfbeaab2);
#
#
#         var popup_5586ddfb54f2e486d9588fec150967a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be608878a4f900d36878ea006c238b32 = $(`&lt;div id=&quot;html_be608878a4f900d36878ea006c238b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5586ddfb54f2e486d9588fec150967a1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f0fafb9b9fec6764f3b25e7ac4c1198 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f0fafb9b9fec6764f3b25e7ac4c1198&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f0fafb9b9fec6764f3b25e7ac4c1198 = L.map(
#                 &quot;map_9f0fafb9b9fec6764f3b25e7ac4c1198&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d0341cee383ee0ffb7699242bfeebe5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d0341cee383ee0ffb7699242bfeebe5.addTo(map_9f0fafb9b9fec6764f3b25e7ac4c1198);
#
#
#             var feature_group_ca8c1bc9cb4fb5c6aee54306675950a4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_955c0fd1cdf32c523c78a9c37ba91d58 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ca8c1bc9cb4fb5c6aee54306675950a4);
#
#
#         var popup_4bbc9f70ccd9d88534302e6e68246f3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25c8b96e93895fd53c8fbedf12c3bd1e = $(`&lt;div id=&quot;html_25c8b96e93895fd53c8fbedf12c3bd1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4bbc9f70ccd9d88534302e6e68246f3c.setContent(html_25c8b96e93895fd53c8fbedf12c3bd1e);
#
#
#
#         marker_955c0fd1cdf32c523c78a9c37ba91d58.bindPopup(popup_4bbc9f70ccd9d88534302e6e68246f3c)
#         ;
#
#
#
#
#             var marker_8aee717c6cc8b4dc82cfea5b33a1db51 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ca8c1bc9cb4fb5c6aee54306675950a4);
#
#
#         var popup_9cc7ebd79db1317e9df6960a2165db4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3efffbe8d23ff705603eff0cfea0cd2f = $(`&lt;div id=&quot;html_3efffbe8d23ff705603eff0cfea0cd2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9cc7ebd79db1317e9df6960a2165db4f.setContent(html_3efffbe8d23ff705603eff0cfea0cd2f);
#
#
#
#         marker_8aee717c6cc8b4dc82cfea5b33a1db51.bindPopup(popup_9cc7ebd79db1317e9df6960a2165db4f)
#         ;
#
#
#
#
#             var marker_6fc7562566fa822d17e48b5e05cd5215 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ca8c1bc9cb4fb5c6aee54306675950a4);
#
#
#         var popup_007e3a205ba854624b87ec629e70e47f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e35d54e6580231737c7fdedcde76eb2d = $(`&lt;div id=&quot;html_e35d54e6580231737c7fdedcde76eb2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_007e3a205ba854624b87ec629e70e47f.setContent(html_e35d54e6580231737c7fdedcde76eb2d);
#
#
#
#         marker_6fc7562566fa822d17e48b5e05cd5215.bindPopup(popup_007e3a205ba854624b87ec629e70e47f)
#         ;
#
#
#
#
#             var marker_768b693983f6d11a3cf0529e103b6cc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ca8c1bc9cb4fb5c6aee54306675950a4);
#
#
#         var popup_cd020f62209376222380e8caf156bdcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0ae2fdaa017e050ed88e79fac28fc0f = $(`&lt;div id=&quot;html_a0ae2fdaa017e050ed88e79fac28fc0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cd020f62209376222380e8caf156bdcc.setContent(html_a0ae2fdaa017e050ed88e79fac28fc0f);
#
#
#
#         marker_768b693983f6d11a3cf0529e103b6cc2.bindPopup(popup_cd020f62209376222380e8caf156bdcc)
#         ;
#
#
#
#
#             var marker_f90a55898e605f2ad0ba45e77ca36820 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ca8c1bc9cb4fb5c6aee54306675950a4);
#
#
#         var popup_6f121101b464a6508b7b25da7113eeb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_398f253e76cda9f8ab9c87c0527ec81b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_398f253e76cda9f8ab9c87c0527ec81b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_398f253e76cda9f8ab9c87c0527ec81b = L.map(
#                 &quot;map_398f253e76cda9f8ab9c87c0527ec81b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d0d80ae85dc0372b9a4370858a1f4b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d0d80ae85dc0372b9a4370858a1f4b4.addTo(map_398f253e76cda9f8ab9c87c0527ec81b);
#
#
#             var feature_group_1e1a65d8f6dc17de58f9aba06b4fc0f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1e1a65d8f6dc17de58f9aba06b4fc0f1.addTo(map_398f253e76cda9f8ab9c87c0527ec81b);
#
#
#             var feature_group_sub_group_19d117883e20fcc8f66541b1f7a31402 = L.featureGroup.subGroup(
#                 feature_group_1e1a65d8f6dc17de58f9aba06b4fc0f1
#             );
#
#
#             var marker_b51211e95bc51ec1449712901f4a7be7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_19d117883e20fcc8f66541b1f7a31402);
#
#
#         var popup_aa1bfacb503b918b6ebce56cfdfda21c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3567fe19854e58b0288217bf302a3be5 = $(`&lt;div id=&quot;html_3567fe19854e58b0288217bf302a3be5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_aa1bfacb503b918b6ebce56cfdfda21c.setContent(html_3567fe19854e58b0288217bf302a3be5);
#
#
#
#         marker_b51211e95bc51ec1449712901f4a7be7.bindPopup(popup_aa1bfacb503b918b6ebce56cfdfda21c)
#         ;
#
#
#
#
#             var marker_06199163e3346b342d68f7860a31ae2b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_19d117883e20fcc8f66541b1f7a31402);
#
#
#         var popup_52d66c279b181d663f3001744e76a68f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97a5f610b17ea865565164fb52fc2baa = $(`&lt;div id=&quot;html_97a5f610b17ea865565164fb52fc2baa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_52d66c279b181d663f3001744e76a68f.setContent(html_97a5f610b17ea865565164fb52fc2baa);
#
#
#
#         marker_06199163e3346b342d68f7860a31ae2b.bindPopup(popup_52d66c279b181d663f3001744e76a68f)
#         ;
#
#
#
#
#             var marker_e787bb14a6d43f34cac8e778fecfd544 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_19d117883e20fcc8f66541b1f7a31402);
#
#
#         var popup_b743a3082cdb9ead2e26ef172f9ceb76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86c28c10eec3b1baf8ac2e1e5c1e4ac5 = $(`&lt;div id=&quot;html_86c28c10eec3b1baf8ac2e1e5c1e4ac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b743a3082cdb9ead2e26ef172f9ceb76.setContent(html_86c28c10eec3b1baf8ac2e1e5c1e4ac5);
#
#
#
#         marker_e787bb14a6d43f34cac8e778fecfd544.bindPopup(popup_b743a3082cdb9ead2e26ef172f9ceb76)
#         ;
#
#
#
#
#             var marker_15c6054ae25002a1db7afb7f35104b64 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_19d117883e20fcc8f66541b1f7a31402);
#
#
#         var popup_ae5388e96d98f342e1d5f97bd1eafb52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b308b706dcfa2623f16c5beec9cfb66 = $(`&lt;div id=&quot;html_8b308b706dcfa2623f16c5beec9cfb66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ae5388e96d98f342e1d5f97bd1eafb52.setContent(html_8b308b706dcfa2623f16c5beec9cfb66);
#
#
#
#         marker_
