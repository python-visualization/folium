# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54bc447ede541886efff4f04974f66ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54bc447ede541886efff4f04974f66ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54bc447ede541886efff4f04974f66ea = L.map(
#                 &quot;map_54bc447ede541886efff4f04974f66ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a993da5296b168879b70c6729a7ddc42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a993da5296b168879b70c6729a7ddc42.addTo(map_54bc447ede541886efff4f04974f66ea);
#
#
#             var marker_9da891f7ee18b4ea3e242a81ea535c7c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_54bc447ede541886efff4f04974f66ea);
#
#
#         var popup_6e8a19d273073374673c4a8ab6432837 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1ab51b59adeadf17cc30cd7d62173aa = $(`&lt;div id=&quot;html_c1ab51b59adeadf17cc30cd7d62173aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6e8a19d273073374673c4a8ab6432837.setContent(html_c1ab51b59adeadf17cc30cd7d62173aa);
#
#
#
#         marker_9da891f7ee18b4ea3e242a81ea535c7c.bindPopup(popup_6e8a19d273073374673c4a8ab6432837)
#         ;
#
#
#
#
#             var marker_1cbfe61ba6d1135e6da113fda3e82082 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_54bc447ede541886efff4f04974f66ea);
#
#
#         var popup_10a490060a11f95e4c895c0c958f9f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7268e160ac9921285aa9b017f9e5d98 = $(`&lt;div id=&quot;html_d7268e160ac9921285aa9b017f9e5d98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_10a490060a11f95e4c895c0c958f9f7a.setContent(html_d7268e160ac9921285aa9b017f9e5d98);
#
#
#
#         marker_1cbfe61ba6d1135e6da113fda3e82082.bindPopup(popup_10a490060a11f95e4c895c0c958f9f7a)
#         ;
#
#
#
#
#             var marker_f69e93e14a91317c2d60a96b626ec4ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_54bc447ede541886efff4f04974f66ea);
#
#
#         var popup_2b938d80692b89f843915a8fd0def5a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d90e20a0e16b0397e2aa36203461b08 = $(`&lt;div id=&quot;html_6d90e20a0e16b0397e2aa36203461b08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2b938d80692b89f843915a8fd0def5a0.setContent(html_6d90e20a0e16b0397e2aa36203461b08);
#
#
#
#         marker_f69e93e14a91317c2d60a96b626ec4ea.bindPopup(popup_2b938d80692b89f843915a8fd0def5a0)
#         ;
#
#
#
#
#             var marker_2f009f0733da0ff6a522376d766139cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_54bc447ede541886efff4f04974f66ea);
#
#
#         var popup_bed7b22f5db19ff817267786629bcb6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac51463c21a4b464a74c63fc1eaca37c = $(`&lt;div id=&quot;html_ac51463c21a4b464a74c63fc1eaca37c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bed7b22f5db19ff817267786629bcb6b.setContent(html_ac51463c21a4b464a74c63fc1eaca37c);
#
#
#
#         marker_2f009f0733da0ff6a522376d766139cd.bindPopup(popup_bed7b22f5db19ff817267786629bcb6b)
#         ;
#
#
#
#
#             var marker_97f4253bea92258678c75a5e26b8125f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_54bc447ede541886efff4f04974f66ea);
#
#
#         var popup_30dbc748a7adf2f6107f2f943d335616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c057a870af926f14ea5966550019fd1c = $(`&lt;div id=&quot;html_c057a870af926f14ea5966550019fd1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_30dbc748a7adf2f6107f2f943d335616.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7137ba3575b6f34bbd84ee969abe6512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7137ba3575b6f34bbd84ee969abe6512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7137ba3575b6f34bbd84ee969abe6512 = L.map(
#                 &quot;map_7137ba3575b6f34bbd84ee969abe6512&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23b6b9160db60e3d94d738dbf9bfd420 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23b6b9160db60e3d94d738dbf9bfd420.addTo(map_7137ba3575b6f34bbd84ee969abe6512);
#
#
#             var feature_group_c67436bd10dfc678342f2991992245d1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7d03d98e9111c98de8cf8749c14472b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c67436bd10dfc678342f2991992245d1);
#
#
#         var popup_cde33eb1d0f77f3c21d9db9e63ec7f19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a535228bf1029598fef0b831e591287c = $(`&lt;div id=&quot;html_a535228bf1029598fef0b831e591287c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cde33eb1d0f77f3c21d9db9e63ec7f19.setContent(html_a535228bf1029598fef0b831e591287c);
#
#
#
#         marker_7d03d98e9111c98de8cf8749c14472b7.bindPopup(popup_cde33eb1d0f77f3c21d9db9e63ec7f19)
#         ;
#
#
#
#
#             var marker_2a7af4251bda87328b4ab7919229f32e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c67436bd10dfc678342f2991992245d1);
#
#
#         var popup_7fe60056acad8ecebf6a5ad595409d13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eafe156fbfa4d656828cfd1b76f9b32 = $(`&lt;div id=&quot;html_2eafe156fbfa4d656828cfd1b76f9b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7fe60056acad8ecebf6a5ad595409d13.setContent(html_2eafe156fbfa4d656828cfd1b76f9b32);
#
#
#
#         marker_2a7af4251bda87328b4ab7919229f32e.bindPopup(popup_7fe60056acad8ecebf6a5ad595409d13)
#         ;
#
#
#
#
#             var marker_5c69dc8991bdd54f42f8fc23801663cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c67436bd10dfc678342f2991992245d1);
#
#
#         var popup_799cd23f88191c0f56d14112491469fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7866a69c962a28aa71c37601742a612 = $(`&lt;div id=&quot;html_f7866a69c962a28aa71c37601742a612&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_799cd23f88191c0f56d14112491469fb.setContent(html_f7866a69c962a28aa71c37601742a612);
#
#
#
#         marker_5c69dc8991bdd54f42f8fc23801663cc.bindPopup(popup_799cd23f88191c0f56d14112491469fb)
#         ;
#
#
#
#
#             var marker_6a2e336993899efd2550a7835c8b01d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c67436bd10dfc678342f2991992245d1);
#
#
#         var popup_0af77a2c83c789334555f9e893d459a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e99a282e947f6fe79e1f8ef1f41fd426 = $(`&lt;div id=&quot;html_e99a282e947f6fe79e1f8ef1f41fd426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0af77a2c83c789334555f9e893d459a5.setContent(html_e99a282e947f6fe79e1f8ef1f41fd426);
#
#
#
#         marker_6a2e336993899efd2550a7835c8b01d6.bindPopup(popup_0af77a2c83c789334555f9e893d459a5)
#         ;
#
#
#
#
#             var marker_71dc522b2a90b4bb18a1076d2604cf5d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c67436bd10dfc678342f2991992245d1);
#
#
#         var popup_8415af0b769891884165d81be5a2fe09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75dedf169c00a3e016d8a18efaa0db26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75dedf169c00a3e016d8a18efaa0db26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75dedf169c00a3e016d8a18efaa0db26 = L.map(
#                 &quot;map_75dedf169c00a3e016d8a18efaa0db26&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08df18b411826e0a9af3113874ac3e33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08df18b411826e0a9af3113874ac3e33.addTo(map_75dedf169c00a3e016d8a18efaa0db26);
#
#
#             var feature_group_a487d9ebf081cbc361ff6587400d9d11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a487d9ebf081cbc361ff6587400d9d11.addTo(map_75dedf169c00a3e016d8a18efaa0db26);
#
#
#             var feature_group_sub_group_a03e1e90a3fb67b54361e85c68fa03bb = L.featureGroup.subGroup(
#                 feature_group_a487d9ebf081cbc361ff6587400d9d11
#             );
#
#
#             var marker_7e8726cce5540695e0aedc3b0408a327 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a03e1e90a3fb67b54361e85c68fa03bb);
#
#
#         var popup_0023e2a1b48e4ab9026d0b2e28f345d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73a95127a6df3485ad1be955db4c18f3 = $(`&lt;div id=&quot;html_73a95127a6df3485ad1be955db4c18f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0023e2a1b48e4ab9026d0b2e28f345d7.setContent(html_73a95127a6df3485ad1be955db4c18f3);
#
#
#
#         marker_7e8726cce5540695e0aedc3b0408a327.bindPopup(popup_0023e2a1b48e4ab9026d0b2e28f345d7)
#         ;
#
#
#
#
#             var marker_998049f13d9f692d4769db4bc85d38f2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a03e1e90a3fb67b54361e85c68fa03bb);
#
#
#         var popup_4bc82a411e9f2d7cd5d72a570dc9093a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cebca2bc699a3b50815b9850278006f = $(`&lt;div id=&quot;html_3cebca2bc699a3b50815b9850278006f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4bc82a411e9f2d7cd5d72a570dc9093a.setContent(html_3cebca2bc699a3b50815b9850278006f);
#
#
#
#         marker_998049f13d9f692d4769db4bc85d38f2.bindPopup(popup_4bc82a411e9f2d7cd5d72a570dc9093a)
#         ;
#
#
#
#
#             var marker_7599d4992086d77dcf7f65ea48c10475 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a03e1e90a3fb67b54361e85c68fa03bb);
#
#
#         var popup_46a30064d49dc0e2c013351eb7475968 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be629294103eac6a349840fae1e229ca = $(`&lt;div id=&quot;html_be629294103eac6a349840fae1e229ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_46a30064d49dc0e2c013351eb7475968.setContent(html_be629294103eac6a349840fae1e229ca);
#
#
#
#         marker_7599d4992086d77dcf7f65ea48c10475.bindPopup(popup_46a30064d49dc0e2c013351eb7475968)
#         ;
#
#
#
#
#             var marker_649e0aa6a02d824b143852790cfc1da3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a03e1e90a3fb67b54361e85c68fa03bb);
#
#
#         var popup_6f13c91a16130ee0c33f5bc7b5a4151a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a16ddc8eb5c83df18c015aecdb1e1152 = $(`&lt;div id=&quot;html_a16ddc8eb5c83df18c015aecdb1e1152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6f13c91a16130ee0c33f5bc7b5a4151a.setContent(html_a16ddc8eb5c83df18c015aecdb1e1152);
#
#
#
#         marker_
