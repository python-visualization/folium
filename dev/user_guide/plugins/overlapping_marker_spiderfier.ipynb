# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b42d52a4e5ac276f332fd52dfc0fbd4f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b42d52a4e5ac276f332fd52dfc0fbd4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b42d52a4e5ac276f332fd52dfc0fbd4f = L.map(
#                 &quot;map_b42d52a4e5ac276f332fd52dfc0fbd4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a246323728df50d28584510968a3246 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a246323728df50d28584510968a3246.addTo(map_b42d52a4e5ac276f332fd52dfc0fbd4f);
#
#
#             var marker_713a968ad5b36581a5e14c45c1a6f007 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b42d52a4e5ac276f332fd52dfc0fbd4f);
#
#
#         var popup_ce622c3f59b7fe2625031d838b84dc64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dee2fd7979540b98f8952cfa40887ab = $(`&lt;div id=&quot;html_3dee2fd7979540b98f8952cfa40887ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ce622c3f59b7fe2625031d838b84dc64.setContent(html_3dee2fd7979540b98f8952cfa40887ab);
#
#
#
#         marker_713a968ad5b36581a5e14c45c1a6f007.bindPopup(popup_ce622c3f59b7fe2625031d838b84dc64)
#         ;
#
#
#
#
#             var marker_0cbbfc75ee8143614a72be6136b79491 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b42d52a4e5ac276f332fd52dfc0fbd4f);
#
#
#         var popup_d30f71096269b59fc79077d0519718c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bae5dae388266259fe3ef3a4ad720c0 = $(`&lt;div id=&quot;html_4bae5dae388266259fe3ef3a4ad720c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d30f71096269b59fc79077d0519718c4.setContent(html_4bae5dae388266259fe3ef3a4ad720c0);
#
#
#
#         marker_0cbbfc75ee8143614a72be6136b79491.bindPopup(popup_d30f71096269b59fc79077d0519718c4)
#         ;
#
#
#
#
#             var marker_981561a77f8836c3e7607ffae8c43749 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b42d52a4e5ac276f332fd52dfc0fbd4f);
#
#
#         var popup_dd806ab753c4b72025496b9e8a3578c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ecf1ddcbe774f5a11fdefc90111e368 = $(`&lt;div id=&quot;html_7ecf1ddcbe774f5a11fdefc90111e368&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dd806ab753c4b72025496b9e8a3578c3.setContent(html_7ecf1ddcbe774f5a11fdefc90111e368);
#
#
#
#         marker_981561a77f8836c3e7607ffae8c43749.bindPopup(popup_dd806ab753c4b72025496b9e8a3578c3)
#         ;
#
#
#
#
#             var marker_cdf76745f4027bebd2df2add4537636e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b42d52a4e5ac276f332fd52dfc0fbd4f);
#
#
#         var popup_91fc1ad3ce1172103cfd68488175322f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3efc19edaecacb2b13df217443bb100d = $(`&lt;div id=&quot;html_3efc19edaecacb2b13df217443bb100d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_91fc1ad3ce1172103cfd68488175322f.setContent(html_3efc19edaecacb2b13df217443bb100d);
#
#
#
#         marker_cdf76745f4027bebd2df2add4537636e.bindPopup(popup_91fc1ad3ce1172103cfd68488175322f)
#         ;
#
#
#
#
#             var marker_1df777cad949053d260cea9d1672b051 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b42d52a4e5ac276f332fd52dfc0fbd4f);
#
#
#         var popup_6eb8b06532b39cedd95d3b6baf9473cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a33575b7b0305d31cb2c8e4f5c8aeac = $(`&lt;div id=&quot;html_6a33575b7b0305d31cb2c8e4f5c8aeac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6eb8b06532b39cedd95d3b6baf9473

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0471f7665ed47474747fa73489bbb93 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0471f7665ed47474747fa73489bbb93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0471f7665ed47474747fa73489bbb93 = L.map(
#                 &quot;map_c0471f7665ed47474747fa73489bbb93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1164228b93789b04bee4c00707a15a0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1164228b93789b04bee4c00707a15a0f.addTo(map_c0471f7665ed47474747fa73489bbb93);
#
#
#             var feature_group_2e3ac19441f7d4ef1b29a6699cf97614 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7c63cde2dd1661d73bfb2cb13363926e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2e3ac19441f7d4ef1b29a6699cf97614);
#
#
#         var popup_47b83189d8a202a258451627d5a7b0ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_beba7e8cfda8d4841a5e33df50f84c39 = $(`&lt;div id=&quot;html_beba7e8cfda8d4841a5e33df50f84c39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_47b83189d8a202a258451627d5a7b0ac.setContent(html_beba7e8cfda8d4841a5e33df50f84c39);
#
#
#
#         marker_7c63cde2dd1661d73bfb2cb13363926e.bindPopup(popup_47b83189d8a202a258451627d5a7b0ac)
#         ;
#
#
#
#
#             var marker_ea9763a30606a9b87f01de389b73ace4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2e3ac19441f7d4ef1b29a6699cf97614);
#
#
#         var popup_61f9e408832a641050289c1aa4399b9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78861969fb76f6d7f17bdc457e4da5c7 = $(`&lt;div id=&quot;html_78861969fb76f6d7f17bdc457e4da5c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_61f9e408832a641050289c1aa4399b9b.setContent(html_78861969fb76f6d7f17bdc457e4da5c7);
#
#
#
#         marker_ea9763a30606a9b87f01de389b73ace4.bindPopup(popup_61f9e408832a641050289c1aa4399b9b)
#         ;
#
#
#
#
#             var marker_d4509b9141c780e895416e95fe5e4f0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2e3ac19441f7d4ef1b29a6699cf97614);
#
#
#         var popup_2909ecd0a45a1e944426f48beac8b8e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54869bfaef1f5321602db86869e15d98 = $(`&lt;div id=&quot;html_54869bfaef1f5321602db86869e15d98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2909ecd0a45a1e944426f48beac8b8e0.setContent(html_54869bfaef1f5321602db86869e15d98);
#
#
#
#         marker_d4509b9141c780e895416e95fe5e4f0e.bindPopup(popup_2909ecd0a45a1e944426f48beac8b8e0)
#         ;
#
#
#
#
#             var marker_a84c7a6afb07ebbecc94e0e8a9c82c5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2e3ac19441f7d4ef1b29a6699cf97614);
#
#
#         var popup_bdf2b0b255e4d75c2ff615702cacfe48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a08588c59c176179049b18097447cebb = $(`&lt;div id=&quot;html_a08588c59c176179049b18097447cebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bdf2b0b255e4d75c2ff615702cacfe48.setContent(html_a08588c59c176179049b18097447cebb);
#
#
#
#         marker_a84c7a6afb07ebbecc94e0e8a9c82c5d.bindPopup(popup_bdf2b0b255e4d75c2ff615702cacfe48)
#         ;
#
#
#
#
#             var marker_edfc4649cc609f8a7ebdaea70cacc825 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2e3ac19441f7d4ef1b29a6699cf97614);
#
#
#         var popup_85c9401bcd0738325f85c8b5b5993d2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea55cf88f2d6d736a0c9b13693a3873c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea55cf88f2d6d736a0c9b13693a3873c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea55cf88f2d6d736a0c9b13693a3873c = L.map(
#                 &quot;map_ea55cf88f2d6d736a0c9b13693a3873c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72b6f73d37993d571011922a382fb03a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72b6f73d37993d571011922a382fb03a.addTo(map_ea55cf88f2d6d736a0c9b13693a3873c);
#
#
#             var feature_group_8b6fc88f288c0c39ac25cd31c008492a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8b6fc88f288c0c39ac25cd31c008492a.addTo(map_ea55cf88f2d6d736a0c9b13693a3873c);
#
#
#             var feature_group_sub_group_3b49554352cd4fb651f32830f10c112b = L.featureGroup.subGroup(
#                 feature_group_8b6fc88f288c0c39ac25cd31c008492a
#             );
#
#
#             var marker_8bbbeac9f2f27d02cd660db24408aa8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b49554352cd4fb651f32830f10c112b);
#
#
#         var popup_280967ab37f61ee066e219358f8a6d4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41050b2ef5b1229e361c4456f648dd0c = $(`&lt;div id=&quot;html_41050b2ef5b1229e361c4456f648dd0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_280967ab37f61ee066e219358f8a6d4d.setContent(html_41050b2ef5b1229e361c4456f648dd0c);
#
#
#
#         marker_8bbbeac9f2f27d02cd660db24408aa8e.bindPopup(popup_280967ab37f61ee066e219358f8a6d4d)
#         ;
#
#
#
#
#             var marker_7d454ab8e329076fcfcbfd862a23456d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b49554352cd4fb651f32830f10c112b);
#
#
#         var popup_a9ff9e24d06ee1402019ea9fe9858d97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_633e87f3d109817502b517b22c160161 = $(`&lt;div id=&quot;html_633e87f3d109817502b517b22c160161&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a9ff9e24d06ee1402019ea9fe9858d97.setContent(html_633e87f3d109817502b517b22c160161);
#
#
#
#         marker_7d454ab8e329076fcfcbfd862a23456d.bindPopup(popup_a9ff9e24d06ee1402019ea9fe9858d97)
#         ;
#
#
#
#
#             var marker_49edf8a33e9450a1c4aa3a985c9ddbc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b49554352cd4fb651f32830f10c112b);
#
#
#         var popup_163f989330f70f76436dfdb40a1e824b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0ce7e238c64fc629cb66ea342c5d956 = $(`&lt;div id=&quot;html_f0ce7e238c64fc629cb66ea342c5d956&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_163f989330f70f76436dfdb40a1e824b.setContent(html_f0ce7e238c64fc629cb66ea342c5d956);
#
#
#
#         marker_49edf8a33e9450a1c4aa3a985c9ddbc2.bindPopup(popup_163f989330f70f76436dfdb40a1e824b)
#         ;
#
#
#
#
#             var marker_005b08dd6a31da584cdc2ee2cb8a28c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b49554352cd4fb651f32830f10c112b);
#
#
#         var popup_1fc40a89fc7fe354645c982a6ccceabd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_751145c5528f600b9cb92c6a72c5fed2 = $(`&lt;div id=&quot;html_751145c5528f600b9cb92c6a72c5fed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1fc40a89fc7fe354645c982a6ccceabd.setContent(html_751145c5528f600b9cb92c6a72c5fed2);
#
#
#
#         mark
