# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fb1221e35f328709be6e9daa540d5a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fb1221e35f328709be6e9daa540d5a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fb1221e35f328709be6e9daa540d5a2 = L.map(
#                 &quot;map_2fb1221e35f328709be6e9daa540d5a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4df0c2edac331e0a7cdfcc0e04b74ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4df0c2edac331e0a7cdfcc0e04b74ab.addTo(map_2fb1221e35f328709be6e9daa540d5a2);
#
#
#             var marker_39739804e89e6743ef90184b814d02a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2fb1221e35f328709be6e9daa540d5a2);
#
#
#         var popup_65730d1d090a44933ba5a43c8347ec64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c22fa358fbbe63c18c98218442a2b1bc = $(`&lt;div id=&quot;html_c22fa358fbbe63c18c98218442a2b1bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_65730d1d090a44933ba5a43c8347ec64.setContent(html_c22fa358fbbe63c18c98218442a2b1bc);
#
#
#
#         marker_39739804e89e6743ef90184b814d02a3.bindPopup(popup_65730d1d090a44933ba5a43c8347ec64)
#         ;
#
#
#
#
#             var marker_3aa0932c56c4cd7f8f562c16a93f26c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2fb1221e35f328709be6e9daa540d5a2);
#
#
#         var popup_a89ffef8e587b2510aaef0c276af3536 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eee3e92629fbb396bf86161347df5946 = $(`&lt;div id=&quot;html_eee3e92629fbb396bf86161347df5946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a89ffef8e587b2510aaef0c276af3536.setContent(html_eee3e92629fbb396bf86161347df5946);
#
#
#
#         marker_3aa0932c56c4cd7f8f562c16a93f26c5.bindPopup(popup_a89ffef8e587b2510aaef0c276af3536)
#         ;
#
#
#
#
#             var marker_38f5ec33ce92409187c55d494fce3c59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2fb1221e35f328709be6e9daa540d5a2);
#
#
#         var popup_bbe13fbe84d3d6c8ce863532b256f8e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d570cd02b26323d7d6199c6754ce18db = $(`&lt;div id=&quot;html_d570cd02b26323d7d6199c6754ce18db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bbe13fbe84d3d6c8ce863532b256f8e6.setContent(html_d570cd02b26323d7d6199c6754ce18db);
#
#
#
#         marker_38f5ec33ce92409187c55d494fce3c59.bindPopup(popup_bbe13fbe84d3d6c8ce863532b256f8e6)
#         ;
#
#
#
#
#             var marker_9176f4a24524231abe372e27b1041509 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2fb1221e35f328709be6e9daa540d5a2);
#
#
#         var popup_606a309db5de436836369b16b229b223 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e4b4cf087a91b39096e3eb3adf8c42a = $(`&lt;div id=&quot;html_8e4b4cf087a91b39096e3eb3adf8c42a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_606a309db5de436836369b16b229b223.setContent(html_8e4b4cf087a91b39096e3eb3adf8c42a);
#
#
#
#         marker_9176f4a24524231abe372e27b1041509.bindPopup(popup_606a309db5de436836369b16b229b223)
#         ;
#
#
#
#
#             var marker_be0b3ca59f7066b11f1d340946480b9a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2fb1221e35f328709be6e9daa540d5a2);
#
#
#         var popup_1d8675a34a441058a5052b5ffd4683cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63915350df9c5cb79093dd49b85c6d39 = $(`&lt;div id=&quot;html_63915350df9c5cb79093dd49b85c6d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1d8675a34a441058a5052b5ffd4683cd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5d232860cddc40d047e8b9a02271668 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5d232860cddc40d047e8b9a02271668&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5d232860cddc40d047e8b9a02271668 = L.map(
#                 &quot;map_f5d232860cddc40d047e8b9a02271668&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59c9ccf8d0ff0c46c54bbab55e1598fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59c9ccf8d0ff0c46c54bbab55e1598fa.addTo(map_f5d232860cddc40d047e8b9a02271668);
#
#
#             var feature_group_aa43206329fe437a38ff8405f4dac6f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2b58e1319b3204e1a6eb05f0b254ad95 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_aa43206329fe437a38ff8405f4dac6f2);
#
#
#         var popup_629bc4cbf27237f0e3568cfac4d286cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_401861947d1f042468e7af1f0840b91e = $(`&lt;div id=&quot;html_401861947d1f042468e7af1f0840b91e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_629bc4cbf27237f0e3568cfac4d286cc.setContent(html_401861947d1f042468e7af1f0840b91e);
#
#
#
#         marker_2b58e1319b3204e1a6eb05f0b254ad95.bindPopup(popup_629bc4cbf27237f0e3568cfac4d286cc)
#         ;
#
#
#
#
#             var marker_0e0945f48924cb8fea16ee5db7ff6fbe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_aa43206329fe437a38ff8405f4dac6f2);
#
#
#         var popup_b94e52529575c1304696755a74a98b18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be18a08dea18f1d0a6f4d840ab863e75 = $(`&lt;div id=&quot;html_be18a08dea18f1d0a6f4d840ab863e75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b94e52529575c1304696755a74a98b18.setContent(html_be18a08dea18f1d0a6f4d840ab863e75);
#
#
#
#         marker_0e0945f48924cb8fea16ee5db7ff6fbe.bindPopup(popup_b94e52529575c1304696755a74a98b18)
#         ;
#
#
#
#
#             var marker_a7e52dd0198f492d7cb89ae1fbba23ce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_aa43206329fe437a38ff8405f4dac6f2);
#
#
#         var popup_2a2b3c0a7a267f3610bdab961cdc4b4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5429b8de2254021b8e1f4e460dab75b4 = $(`&lt;div id=&quot;html_5429b8de2254021b8e1f4e460dab75b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2a2b3c0a7a267f3610bdab961cdc4b4c.setContent(html_5429b8de2254021b8e1f4e460dab75b4);
#
#
#
#         marker_a7e52dd0198f492d7cb89ae1fbba23ce.bindPopup(popup_2a2b3c0a7a267f3610bdab961cdc4b4c)
#         ;
#
#
#
#
#             var marker_fb6c04e7c5db3f97e960f2c77dc15cab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_aa43206329fe437a38ff8405f4dac6f2);
#
#
#         var popup_a4426fba1cd1fe4d8778159cbc6087bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50ba52fa9eb33d8fce0845cb77c6d8ac = $(`&lt;div id=&quot;html_50ba52fa9eb33d8fce0845cb77c6d8ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a4426fba1cd1fe4d8778159cbc6087bf.setContent(html_50ba52fa9eb33d8fce0845cb77c6d8ac);
#
#
#
#         marker_fb6c04e7c5db3f97e960f2c77dc15cab.bindPopup(popup_a4426fba1cd1fe4d8778159cbc6087bf)
#         ;
#
#
#
#
#             var marker_6bc49af6b7ae84308e7f155339f74f70 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_aa43206329fe437a38ff8405f4dac6f2);
#
#
#         var popup_c8382b1ce6ea7eb9e9be5141e3dda70b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5fb2123d4b35a5f69da0cbb8b46ee4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5fb2123d4b35a5f69da0cbb8b46ee4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5fb2123d4b35a5f69da0cbb8b46ee4b = L.map(
#                 &quot;map_f5fb2123d4b35a5f69da0cbb8b46ee4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48b30a021822ec6c46cbb752d73f61e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48b30a021822ec6c46cbb752d73f61e3.addTo(map_f5fb2123d4b35a5f69da0cbb8b46ee4b);
#
#
#             var feature_group_0daf4f65be28e10814dca4a377499cc4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0daf4f65be28e10814dca4a377499cc4.addTo(map_f5fb2123d4b35a5f69da0cbb8b46ee4b);
#
#
#             var feature_group_sub_group_e65df61a067495d52676288e104e6d4a = L.featureGroup.subGroup(
#                 feature_group_0daf4f65be28e10814dca4a377499cc4
#             );
#
#
#             var marker_5a2c3009760370888dd21ed18432f554 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e65df61a067495d52676288e104e6d4a);
#
#
#         var popup_cab0139b1a0afd9454da3470783fe171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fe75df0041870a9c10fc7f073a180b2 = $(`&lt;div id=&quot;html_6fe75df0041870a9c10fc7f073a180b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cab0139b1a0afd9454da3470783fe171.setContent(html_6fe75df0041870a9c10fc7f073a180b2);
#
#
#
#         marker_5a2c3009760370888dd21ed18432f554.bindPopup(popup_cab0139b1a0afd9454da3470783fe171)
#         ;
#
#
#
#
#             var marker_636d6505448151c6a2263d079e92f1d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e65df61a067495d52676288e104e6d4a);
#
#
#         var popup_adf2bbccbaf21304b7d0cd36bfb5279c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e75a6f498aa1ee72cfdf43a6f78f8ba = $(`&lt;div id=&quot;html_1e75a6f498aa1ee72cfdf43a6f78f8ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_adf2bbccbaf21304b7d0cd36bfb5279c.setContent(html_1e75a6f498aa1ee72cfdf43a6f78f8ba);
#
#
#
#         marker_636d6505448151c6a2263d079e92f1d4.bindPopup(popup_adf2bbccbaf21304b7d0cd36bfb5279c)
#         ;
#
#
#
#
#             var marker_bd8b8ffc81be77af5be674389ffee40b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e65df61a067495d52676288e104e6d4a);
#
#
#         var popup_d875e0409d21644cb15ae11cf8e100c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e334a6bee24f4fb01b9bcb88402f9a3e = $(`&lt;div id=&quot;html_e334a6bee24f4fb01b9bcb88402f9a3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d875e0409d21644cb15ae11cf8e100c9.setContent(html_e334a6bee24f4fb01b9bcb88402f9a3e);
#
#
#
#         marker_bd8b8ffc81be77af5be674389ffee40b.bindPopup(popup_d875e0409d21644cb15ae11cf8e100c9)
#         ;
#
#
#
#
#             var marker_67d928cbf24a6b9883008fd6a48a4dbd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e65df61a067495d52676288e104e6d4a);
#
#
#         var popup_fde9d631a19d39797c803f94cc425558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5539ad2e0ed70e975a56ad5a4f1ccc44 = $(`&lt;div id=&quot;html_5539ad2e0ed70e975a56ad5a4f1ccc44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fde9d631a19d39797c803f94cc425558.setContent(html_5539ad2e0ed70e975a56ad5a4f1ccc44);
#
#
#
#         marker_
