# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1126238e0815509a1f02aef308888f51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1126238e0815509a1f02aef308888f51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1126238e0815509a1f02aef308888f51 = L.map(
#                 &quot;map_1126238e0815509a1f02aef308888f51&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9755df19b1e3b79fd7e7e3aaf5a3ace = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9755df19b1e3b79fd7e7e3aaf5a3ace.addTo(map_1126238e0815509a1f02aef308888f51);
#
#
#             var marker_54ca7429b17e28fc82043b939e9ecae0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1126238e0815509a1f02aef308888f51);
#
#
#         var popup_b371a82c34dd3d3f000bae53e0e81b18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d81dfc551f32d0db3f140c12a6565394 = $(`&lt;div id=&quot;html_d81dfc551f32d0db3f140c12a6565394&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b371a82c34dd3d3f000bae53e0e81b18.setContent(html_d81dfc551f32d0db3f140c12a6565394);
#
#
#
#         marker_54ca7429b17e28fc82043b939e9ecae0.bindPopup(popup_b371a82c34dd3d3f000bae53e0e81b18)
#         ;
#
#
#
#
#             var marker_5792324c673b5b5629cfa461278b535c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1126238e0815509a1f02aef308888f51);
#
#
#         var popup_108cae58d1d1cd7ba810a9cc1b1e80f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_967aeab161afd8aa9801bbbb49dbd4d1 = $(`&lt;div id=&quot;html_967aeab161afd8aa9801bbbb49dbd4d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_108cae58d1d1cd7ba810a9cc1b1e80f0.setContent(html_967aeab161afd8aa9801bbbb49dbd4d1);
#
#
#
#         marker_5792324c673b5b5629cfa461278b535c.bindPopup(popup_108cae58d1d1cd7ba810a9cc1b1e80f0)
#         ;
#
#
#
#
#             var marker_cbec63f732c3290708f32a90187bf10f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1126238e0815509a1f02aef308888f51);
#
#
#         var popup_d3dbcdb8c996765f59db9df5988c7b93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68ff0d2887c0f5ca2eb30e83e06752a8 = $(`&lt;div id=&quot;html_68ff0d2887c0f5ca2eb30e83e06752a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d3dbcdb8c996765f59db9df5988c7b93.setContent(html_68ff0d2887c0f5ca2eb30e83e06752a8);
#
#
#
#         marker_cbec63f732c3290708f32a90187bf10f.bindPopup(popup_d3dbcdb8c996765f59db9df5988c7b93)
#         ;
#
#
#
#
#             var marker_92da71482b425e6b6d0d1e4e421185f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1126238e0815509a1f02aef308888f51);
#
#
#         var popup_080e436b1c5e1c37bde82e498243e79d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab69adb4a6bb60fae85f3cd687f584a3 = $(`&lt;div id=&quot;html_ab69adb4a6bb60fae85f3cd687f584a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_080e436b1c5e1c37bde82e498243e79d.setContent(html_ab69adb4a6bb60fae85f3cd687f584a3);
#
#
#
#         marker_92da71482b425e6b6d0d1e4e421185f0.bindPopup(popup_080e436b1c5e1c37bde82e498243e79d)
#         ;
#
#
#
#
#             var marker_96dfbadce4038386fcb3766a492d1378 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1126238e0815509a1f02aef308888f51);
#
#
#         var popup_3057a274f7ee9f6e492b3562f963d046 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ee3647939b319495bda5dd9d572c391 = $(`&lt;div id=&quot;html_1ee3647939b319495bda5dd9d572c391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3057a274f7ee9f6e492b3562f963d046.setContent(html_1ee3647939b319495bda5dd9d572c391);
#
#
#
#         marker_96dfbadce4038386fcb3766a492d1378.bindPopup(popup_3057a274f7ee9f6e492b3562f963d046)
#         ;
#
#
#
#
#             var marker_94a6972719

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea70893767c4e32c566ab442cd6033a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea70893767c4e32c566ab442cd6033a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea70893767c4e32c566ab442cd6033a3 = L.map(
#                 &quot;map_ea70893767c4e32c566ab442cd6033a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53f4e12d6a9a80c46d4105b70ccd150e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53f4e12d6a9a80c46d4105b70ccd150e.addTo(map_ea70893767c4e32c566ab442cd6033a3);
#
#
#             var feature_group_46bbf2ed5343009bf87c20376f4deb0c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_614434ed7426bd8b7a0ca71ff06585fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_46bbf2ed5343009bf87c20376f4deb0c);
#
#
#         var popup_ba8936c46fdf67fecadac320a953900f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05534b9ff147b81502a5d38da763b4c8 = $(`&lt;div id=&quot;html_05534b9ff147b81502a5d38da763b4c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ba8936c46fdf67fecadac320a953900f.setContent(html_05534b9ff147b81502a5d38da763b4c8);
#
#
#
#         marker_614434ed7426bd8b7a0ca71ff06585fa.bindPopup(popup_ba8936c46fdf67fecadac320a953900f)
#         ;
#
#
#
#
#             var marker_b8bb00577194cffc1b1eb46a0f9cb9e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_46bbf2ed5343009bf87c20376f4deb0c);
#
#
#         var popup_4c6c2725117f0917b6d3875f807cc495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_511715a7bbd5b6da8ba5ac8104603b1f = $(`&lt;div id=&quot;html_511715a7bbd5b6da8ba5ac8104603b1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4c6c2725117f0917b6d3875f807cc495.setContent(html_511715a7bbd5b6da8ba5ac8104603b1f);
#
#
#
#         marker_b8bb00577194cffc1b1eb46a0f9cb9e8.bindPopup(popup_4c6c2725117f0917b6d3875f807cc495)
#         ;
#
#
#
#
#             var marker_756bcc2c913da6b39c5530b36283a77a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_46bbf2ed5343009bf87c20376f4deb0c);
#
#
#         var popup_33f61bdbb408db93b2abaa9d8cef26a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_348e4377388ce5a1a067cbb2194e3eaf = $(`&lt;div id=&quot;html_348e4377388ce5a1a067cbb2194e3eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_33f61bdbb408db93b2abaa9d8cef26a6.setContent(html_348e4377388ce5a1a067cbb2194e3eaf);
#
#
#
#         marker_756bcc2c913da6b39c5530b36283a77a.bindPopup(popup_33f61bdbb408db93b2abaa9d8cef26a6)
#         ;
#
#
#
#
#             var marker_28434c2435edc9bb0bd2be06913ea4fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_46bbf2ed5343009bf87c20376f4deb0c);
#
#
#         var popup_9f885d9e0be3e8e546022a9e68b5c0c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b50e68e760fbcf80009710ad7df1739a = $(`&lt;div id=&quot;html_b50e68e760fbcf80009710ad7df1739a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9f885d9e0be3e8e546022a9e68b5c0c0.setContent(html_b50e68e760fbcf80009710ad7df1739a);
#
#
#
#         marker_28434c2435edc9bb0bd2be06913ea4fa.bindPopup(popup_9f885d9e0be3e8e546022a9e68b5c0c0)
#         ;
#
#
#
#
#             var marker_cceef0d5e5494f182fba5f43945530fc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_46bbf2ed5343009bf87c20376f4deb0c);
#
#
#         var popup_f4df53bb5bf18d5240427747329415dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ae8374e63e3ea93956d03101679bcb1 = $(`&lt;div id=&quot;html_1ae8374e63e3ea93956d03101679bcb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_f4df53bb5bf18d5240

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebf8394e2cb6a9ab53e8bcef8144d389 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebf8394e2cb6a9ab53e8bcef8144d389&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebf8394e2cb6a9ab53e8bcef8144d389 = L.map(
#                 &quot;map_ebf8394e2cb6a9ab53e8bcef8144d389&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4aa3e093e15d92fa1e11c9bbbe30e0b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4aa3e093e15d92fa1e11c9bbbe30e0b3.addTo(map_ebf8394e2cb6a9ab53e8bcef8144d389);
#
#
#             var feature_group_89a732b66a5240c15924689dda31b4ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_89a732b66a5240c15924689dda31b4ed.addTo(map_ebf8394e2cb6a9ab53e8bcef8144d389);
#
#
#             var feature_group_sub_group_eb045714ceae400a08fe411ff9f38e8f = L.featureGroup.subGroup(
#                 feature_group_89a732b66a5240c15924689dda31b4ed
#             );
#
#
#             var marker_d29618552f54936890799cc970463e57 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_eb045714ceae400a08fe411ff9f38e8f);
#
#
#         var popup_289cc28f001f48ba04dbfe87cdf65a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f587d840241f398c5782f7b38ede2f6 = $(`&lt;div id=&quot;html_9f587d840241f398c5782f7b38ede2f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_289cc28f001f48ba04dbfe87cdf65a62.setContent(html_9f587d840241f398c5782f7b38ede2f6);
#
#
#
#         marker_d29618552f54936890799cc970463e57.bindPopup(popup_289cc28f001f48ba04dbfe87cdf65a62)
#         ;
#
#
#
#
#             var marker_5e90a1bca09fee4d20c410071c7e5f64 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_eb045714ceae400a08fe411ff9f38e8f);
#
#
#         var popup_1bb8911c901ac77505332a462a605a9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6f0074ac32e86f8721a46d49808af4e = $(`&lt;div id=&quot;html_f6f0074ac32e86f8721a46d49808af4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1bb8911c901ac77505332a462a605a9d.setContent(html_f6f0074ac32e86f8721a46d49808af4e);
#
#
#
#         marker_5e90a1bca09fee4d20c410071c7e5f64.bindPopup(popup_1bb8911c901ac77505332a462a605a9d)
#         ;
#
#
#
#
#             var marker_5daf1a037061fec715c453f58a04f379 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_eb045714ceae400a08fe411ff9f38e8f);
#
#
#         var popup_126cfbfef8b5600785dbb40c0773bfc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7451386f786edd74f37f2f000793a90e = $(`&lt;div id=&quot;html_7451386f786edd74f37f2f000793a90e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_126cfbfef8b5600785dbb40c0773bfc8.setContent(html_7451386f786edd74f37f2f000793a90e);
#
#
#
#         marker_5daf1a037061fec715c453f58a04f379.bindPopup(popup_126cfbfef8b5600785dbb40c0773bfc8)
#         ;
#
#
#
#
#             var marker_c5440725896e494a0e4839885df68d17 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_eb045714ceae400a08fe411ff9f38e8f);
#
#
#         var popup_71b2204f2e94c2a1ff9ea72f3be31d72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6b88384a229227e7cadf10ba61a9d80 = $(`&lt;div id=&quot;html_b6b88384a229227e7cadf10ba61a9d80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_71b2204f2e94c2a1ff9ea72f3be31d72.setContent(html_b6b88384a229227e7cadf10ba61a9d80);
#
#
#
#         marker_c5440725896e494a0e4839885df68d17.bindPopup(popup_71b2204f2e94c2a1ff9ea72f3be31d72)
#         ;
#
#
#
#
#             var marker_6b72acee655a36944b204fc0d1a00bba = L.marker(
#                 [45.050399999999996, 3.0504],
