# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba0ec6d7b60568bd03f678fd80f77414 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba0ec6d7b60568bd03f678fd80f77414&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba0ec6d7b60568bd03f678fd80f77414 = L.map(
#                 &quot;map_ba0ec6d7b60568bd03f678fd80f77414&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f462615928dbd13ee55d0e68d00357d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f462615928dbd13ee55d0e68d00357d.addTo(map_ba0ec6d7b60568bd03f678fd80f77414);
#
#
#             var marker_22efebc7f09272da4d4eebcf6209d5ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ba0ec6d7b60568bd03f678fd80f77414);
#
#
#         var popup_7fa4b1191f850ea61ce8dfe35859f602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_028de976eb49da68044c4827ab351019 = $(`&lt;div id=&quot;html_028de976eb49da68044c4827ab351019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7fa4b1191f850ea61ce8dfe35859f602.setContent(html_028de976eb49da68044c4827ab351019);
#
#
#
#         marker_22efebc7f09272da4d4eebcf6209d5ec.bindPopup(popup_7fa4b1191f850ea61ce8dfe35859f602)
#         ;
#
#
#
#
#             var marker_4c80f3cf812fee4997d05731050fa9a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ba0ec6d7b60568bd03f678fd80f77414);
#
#
#         var popup_14480982032303e41ef2845fcac4a182 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bfec5469e0e4b3f3158f5bd88dd3481 = $(`&lt;div id=&quot;html_8bfec5469e0e4b3f3158f5bd88dd3481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_14480982032303e41ef2845fcac4a182.setContent(html_8bfec5469e0e4b3f3158f5bd88dd3481);
#
#
#
#         marker_4c80f3cf812fee4997d05731050fa9a0.bindPopup(popup_14480982032303e41ef2845fcac4a182)
#         ;
#
#
#
#
#             var marker_a6dd171a5b96cb5dfa8caa771f60db26 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ba0ec6d7b60568bd03f678fd80f77414);
#
#
#         var popup_0c842d5773d22caaef955e364f228409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4df7cbb766e03b9ec7b84b3eedbc5135 = $(`&lt;div id=&quot;html_4df7cbb766e03b9ec7b84b3eedbc5135&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0c842d5773d22caaef955e364f228409.setContent(html_4df7cbb766e03b9ec7b84b3eedbc5135);
#
#
#
#         marker_a6dd171a5b96cb5dfa8caa771f60db26.bindPopup(popup_0c842d5773d22caaef955e364f228409)
#         ;
#
#
#
#
#             var marker_adaae56e6399dcea3d4a5073f243e8b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ba0ec6d7b60568bd03f678fd80f77414);
#
#
#         var popup_436b8cad758ed9c4f1252e5ab71da29f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1084e4f83de0ae4c0ac24061d6a7e6a5 = $(`&lt;div id=&quot;html_1084e4f83de0ae4c0ac24061d6a7e6a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_436b8cad758ed9c4f1252e5ab71da29f.setContent(html_1084e4f83de0ae4c0ac24061d6a7e6a5);
#
#
#
#         marker_adaae56e6399dcea3d4a5073f243e8b6.bindPopup(popup_436b8cad758ed9c4f1252e5ab71da29f)
#         ;
#
#
#
#
#             var marker_34176a1ea3f9547fdd77e16a857ccdfd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ba0ec6d7b60568bd03f678fd80f77414);
#
#
#         var popup_4f1c9b747c4bf15900dc17392c1bfe89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb03585a28a52d29061546ef8eef8e79 = $(`&lt;div id=&quot;html_fb03585a28a52d29061546ef8eef8e79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4f1c9b747c4bf15900dc17392c1bfe

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e90bbf2eadffab79ab0bc08c169074d9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e90bbf2eadffab79ab0bc08c169074d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e90bbf2eadffab79ab0bc08c169074d9 = L.map(
#                 &quot;map_e90bbf2eadffab79ab0bc08c169074d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c258943188a79605348bb5c343310b95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c258943188a79605348bb5c343310b95.addTo(map_e90bbf2eadffab79ab0bc08c169074d9);
#
#
#             var feature_group_6d5a180eae2f7d4634252f4fe3dcba2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c7a35246f0f7b94eaeb48cebfd2f30b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6d5a180eae2f7d4634252f4fe3dcba2d);
#
#
#         var popup_c9d3bc90eeaabc6e6cb27356336b0aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c755dec0aba634696689e2606090a00 = $(`&lt;div id=&quot;html_3c755dec0aba634696689e2606090a00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c9d3bc90eeaabc6e6cb27356336b0aed.setContent(html_3c755dec0aba634696689e2606090a00);
#
#
#
#         marker_2c7a35246f0f7b94eaeb48cebfd2f30b.bindPopup(popup_c9d3bc90eeaabc6e6cb27356336b0aed)
#         ;
#
#
#
#
#             var marker_3f6dbbe45a55ef7dec73474bf716b8e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6d5a180eae2f7d4634252f4fe3dcba2d);
#
#
#         var popup_97719dd8cb5e24cc94e144300d7cdf06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c426e62330e726d0fe9bd3aeb1c34a79 = $(`&lt;div id=&quot;html_c426e62330e726d0fe9bd3aeb1c34a79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_97719dd8cb5e24cc94e144300d7cdf06.setContent(html_c426e62330e726d0fe9bd3aeb1c34a79);
#
#
#
#         marker_3f6dbbe45a55ef7dec73474bf716b8e4.bindPopup(popup_97719dd8cb5e24cc94e144300d7cdf06)
#         ;
#
#
#
#
#             var marker_00448a9ee6a27af4ea81f6ffb53f8fd0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6d5a180eae2f7d4634252f4fe3dcba2d);
#
#
#         var popup_25a9ab16cba8e210d69e70486083beb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e53a416272f9eb343bb2776186a2ecca = $(`&lt;div id=&quot;html_e53a416272f9eb343bb2776186a2ecca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_25a9ab16cba8e210d69e70486083beb2.setContent(html_e53a416272f9eb343bb2776186a2ecca);
#
#
#
#         marker_00448a9ee6a27af4ea81f6ffb53f8fd0.bindPopup(popup_25a9ab16cba8e210d69e70486083beb2)
#         ;
#
#
#
#
#             var marker_989195a1a7c2ebd1b142886655aa6d9a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6d5a180eae2f7d4634252f4fe3dcba2d);
#
#
#         var popup_338c33a346250f7a06483adf1ffc352c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c7f563c80ffb41a00082cb7211f65f1 = $(`&lt;div id=&quot;html_9c7f563c80ffb41a00082cb7211f65f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_338c33a346250f7a06483adf1ffc352c.setContent(html_9c7f563c80ffb41a00082cb7211f65f1);
#
#
#
#         marker_989195a1a7c2ebd1b142886655aa6d9a.bindPopup(popup_338c33a346250f7a06483adf1ffc352c)
#         ;
#
#
#
#
#             var marker_7f8e2be399df3457b5198376947237d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6d5a180eae2f7d4634252f4fe3dcba2d);
#
#
#         var popup_929d2870c6dfe4dec8a05cf9bbd43f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_238de2bd090d01d2ccd0109acb79c899 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_238de2bd090d01d2ccd0109acb79c899&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_238de2bd090d01d2ccd0109acb79c899 = L.map(
#                 &quot;map_238de2bd090d01d2ccd0109acb79c899&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_269df791d69d226c701949f034e64f1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_269df791d69d226c701949f034e64f1a.addTo(map_238de2bd090d01d2ccd0109acb79c899);
#
#
#             var feature_group_0e054af80e3c8f34af32e26df3a95c38 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0e054af80e3c8f34af32e26df3a95c38.addTo(map_238de2bd090d01d2ccd0109acb79c899);
#
#
#             var feature_group_sub_group_90bba47e0abfcc8a70ecdcb70e6c5390 = L.featureGroup.subGroup(
#                 feature_group_0e054af80e3c8f34af32e26df3a95c38
#             );
#
#
#             var marker_66fe12eb4b99dacc3c202bc11ffc3cea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_90bba47e0abfcc8a70ecdcb70e6c5390);
#
#
#         var popup_a4ecc6377785c2b2e832c9dec1778299 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae4959c084991cad25b4ca84eb2942db = $(`&lt;div id=&quot;html_ae4959c084991cad25b4ca84eb2942db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a4ecc6377785c2b2e832c9dec1778299.setContent(html_ae4959c084991cad25b4ca84eb2942db);
#
#
#
#         marker_66fe12eb4b99dacc3c202bc11ffc3cea.bindPopup(popup_a4ecc6377785c2b2e832c9dec1778299)
#         ;
#
#
#
#
#             var marker_dade28ffd5fb82d9995af413e901195c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_90bba47e0abfcc8a70ecdcb70e6c5390);
#
#
#         var popup_d67c97ae7847f094d2f04c026718d1ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab91137e0771be4401fd0a1c5ec7c8ca = $(`&lt;div id=&quot;html_ab91137e0771be4401fd0a1c5ec7c8ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d67c97ae7847f094d2f04c026718d1ce.setContent(html_ab91137e0771be4401fd0a1c5ec7c8ca);
#
#
#
#         marker_dade28ffd5fb82d9995af413e901195c.bindPopup(popup_d67c97ae7847f094d2f04c026718d1ce)
#         ;
#
#
#
#
#             var marker_86330c2c90da152a33b6d7c5eacdb8de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_90bba47e0abfcc8a70ecdcb70e6c5390);
#
#
#         var popup_0d36520320a1c5f5283d2cd57b88c302 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0e162d8259d7ab242664ea8cfc2d39a = $(`&lt;div id=&quot;html_e0e162d8259d7ab242664ea8cfc2d39a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0d36520320a1c5f5283d2cd57b88c302.setContent(html_e0e162d8259d7ab242664ea8cfc2d39a);
#
#
#
#         marker_86330c2c90da152a33b6d7c5eacdb8de.bindPopup(popup_0d36520320a1c5f5283d2cd57b88c302)
#         ;
#
#
#
#
#             var marker_83ece640682bd57a0721bd1b07c410b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_90bba47e0abfcc8a70ecdcb70e6c5390);
#
#
#         var popup_f1385003710e913e7e9509e0b99fdc56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1761eaea4997062f3dcda57f220b0975 = $(`&lt;div id=&quot;html_1761eaea4997062f3dcda57f220b0975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f1385003710e913e7e9509e0b99fdc56.setContent(html_1761eaea4997062f3dcda57f220b0975);
#
#
#
#         mark
