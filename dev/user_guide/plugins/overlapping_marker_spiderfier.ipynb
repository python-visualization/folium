# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_feac733add4018ccaddcc53b58d6c42b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_feac733add4018ccaddcc53b58d6c42b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_feac733add4018ccaddcc53b58d6c42b = L.map(
#                 &quot;map_feac733add4018ccaddcc53b58d6c42b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2451341f86857eedaebbd8c409fac027 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2451341f86857eedaebbd8c409fac027.addTo(map_feac733add4018ccaddcc53b58d6c42b);
#
#
#             var marker_5b5608319247708a1f62a597ad28f6ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_feac733add4018ccaddcc53b58d6c42b);
#
#
#         var popup_8aa767ea197955cff7303e0b4ae3d587 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_681af89e2af687e87db3078c09ff9333 = $(`&lt;div id=&quot;html_681af89e2af687e87db3078c09ff9333&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8aa767ea197955cff7303e0b4ae3d587.setContent(html_681af89e2af687e87db3078c09ff9333);
#
#
#
#         marker_5b5608319247708a1f62a597ad28f6ab.bindPopup(popup_8aa767ea197955cff7303e0b4ae3d587)
#         ;
#
#
#
#
#             var marker_5b096f0f135199217d4578eba3f7762a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_feac733add4018ccaddcc53b58d6c42b);
#
#
#         var popup_e718f1579fcc45eb5717b3608500fbaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e47507834408c80178cffb93ba4167ac = $(`&lt;div id=&quot;html_e47507834408c80178cffb93ba4167ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e718f1579fcc45eb5717b3608500fbaa.setContent(html_e47507834408c80178cffb93ba4167ac);
#
#
#
#         marker_5b096f0f135199217d4578eba3f7762a.bindPopup(popup_e718f1579fcc45eb5717b3608500fbaa)
#         ;
#
#
#
#
#             var marker_ffd32d5b6c348d18a5e3094718b62966 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_feac733add4018ccaddcc53b58d6c42b);
#
#
#         var popup_53985209111999c8903d8e29c462c062 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a40f8f69e2204f1fbb3e96e7e0395b82 = $(`&lt;div id=&quot;html_a40f8f69e2204f1fbb3e96e7e0395b82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_53985209111999c8903d8e29c462c062.setContent(html_a40f8f69e2204f1fbb3e96e7e0395b82);
#
#
#
#         marker_ffd32d5b6c348d18a5e3094718b62966.bindPopup(popup_53985209111999c8903d8e29c462c062)
#         ;
#
#
#
#
#             var marker_f42fb0e1fd56a1119c05b99b1a705309 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_feac733add4018ccaddcc53b58d6c42b);
#
#
#         var popup_e1a1c1c88ecc719e2ab27a6169bab7f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f75c1f9eacad7fdb5e7c7796c6788214 = $(`&lt;div id=&quot;html_f75c1f9eacad7fdb5e7c7796c6788214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e1a1c1c88ecc719e2ab27a6169bab7f2.setContent(html_f75c1f9eacad7fdb5e7c7796c6788214);
#
#
#
#         marker_f42fb0e1fd56a1119c05b99b1a705309.bindPopup(popup_e1a1c1c88ecc719e2ab27a6169bab7f2)
#         ;
#
#
#
#
#             var marker_308000865d24a38eadfb7f01850d462f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_feac733add4018ccaddcc53b58d6c42b);
#
#
#         var popup_4448b941365b694723a55cd7b0373aa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_482ef5a79de9bc1431194251aee4605d = $(`&lt;div id=&quot;html_482ef5a79de9bc1431194251aee4605d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4448b941365b694723a55cd7b0373aa0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bb6111f458a27d90c79213d7317d1aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bb6111f458a27d90c79213d7317d1aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bb6111f458a27d90c79213d7317d1aa = L.map(
#                 &quot;map_8bb6111f458a27d90c79213d7317d1aa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18ad831a78978690d8e317f96474d4d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18ad831a78978690d8e317f96474d4d6.addTo(map_8bb6111f458a27d90c79213d7317d1aa);
#
#
#             var feature_group_6e5f8138a0cfd64f092b3ceb54aa30cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f94e16b0aedbee97a24dc06785565b8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6e5f8138a0cfd64f092b3ceb54aa30cf);
#
#
#         var popup_d31e55305700de94204d25a54bb884f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccc47a3a6d18c0db4ae44ced1ee9c90d = $(`&lt;div id=&quot;html_ccc47a3a6d18c0db4ae44ced1ee9c90d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d31e55305700de94204d25a54bb884f4.setContent(html_ccc47a3a6d18c0db4ae44ced1ee9c90d);
#
#
#
#         marker_f94e16b0aedbee97a24dc06785565b8e.bindPopup(popup_d31e55305700de94204d25a54bb884f4)
#         ;
#
#
#
#
#             var marker_30d5900664dd806974c752cefc2223e7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6e5f8138a0cfd64f092b3ceb54aa30cf);
#
#
#         var popup_a83f38425449ad63487f3eb108c43c3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c8782fe058f5ef5858678b44295c498 = $(`&lt;div id=&quot;html_0c8782fe058f5ef5858678b44295c498&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a83f38425449ad63487f3eb108c43c3f.setContent(html_0c8782fe058f5ef5858678b44295c498);
#
#
#
#         marker_30d5900664dd806974c752cefc2223e7.bindPopup(popup_a83f38425449ad63487f3eb108c43c3f)
#         ;
#
#
#
#
#             var marker_bc9e6751a62926ae313ece06f4ec2819 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6e5f8138a0cfd64f092b3ceb54aa30cf);
#
#
#         var popup_a3119506153665b39d790ca10686e4db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e2b2a71a31b7f2ed21cf0dd504f98c9 = $(`&lt;div id=&quot;html_6e2b2a71a31b7f2ed21cf0dd504f98c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a3119506153665b39d790ca10686e4db.setContent(html_6e2b2a71a31b7f2ed21cf0dd504f98c9);
#
#
#
#         marker_bc9e6751a62926ae313ece06f4ec2819.bindPopup(popup_a3119506153665b39d790ca10686e4db)
#         ;
#
#
#
#
#             var marker_11de00ea31610be93e90ad32da50dd56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6e5f8138a0cfd64f092b3ceb54aa30cf);
#
#
#         var popup_2ea6f4f707622416907fcc7464a3d8f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8b8eb5fd0b0d9f7e9a6a9b1671d5d84 = $(`&lt;div id=&quot;html_f8b8eb5fd0b0d9f7e9a6a9b1671d5d84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2ea6f4f707622416907fcc7464a3d8f2.setContent(html_f8b8eb5fd0b0d9f7e9a6a9b1671d5d84);
#
#
#
#         marker_11de00ea31610be93e90ad32da50dd56.bindPopup(popup_2ea6f4f707622416907fcc7464a3d8f2)
#         ;
#
#
#
#
#             var marker_0292b1581a6c06879e790fcf789647ba = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6e5f8138a0cfd64f092b3ceb54aa30cf);
#
#
#         var popup_df815824f60aa30d68e6e9d35ab92b9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96cabbd519439c8fc6dfd2aa7dc2d437 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96cabbd519439c8fc6dfd2aa7dc2d437&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96cabbd519439c8fc6dfd2aa7dc2d437 = L.map(
#                 &quot;map_96cabbd519439c8fc6dfd2aa7dc2d437&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c5a9566b70e6341ef21bfa54bc87f6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c5a9566b70e6341ef21bfa54bc87f6a.addTo(map_96cabbd519439c8fc6dfd2aa7dc2d437);
#
#
#             var feature_group_41300e8d1314db735aa21e47b8f1c7df = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_41300e8d1314db735aa21e47b8f1c7df.addTo(map_96cabbd519439c8fc6dfd2aa7dc2d437);
#
#
#             var feature_group_sub_group_f16ffcf068f7bfac256587db695c9f88 = L.featureGroup.subGroup(
#                 feature_group_41300e8d1314db735aa21e47b8f1c7df
#             );
#
#
#             var marker_ca93e398e3da504565cdfdaa4db7589e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f16ffcf068f7bfac256587db695c9f88);
#
#
#         var popup_d61a71314abc65523fe7814bba1efb0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b30d0bd6e9a0b5be0a1d143adc60b7f9 = $(`&lt;div id=&quot;html_b30d0bd6e9a0b5be0a1d143adc60b7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d61a71314abc65523fe7814bba1efb0c.setContent(html_b30d0bd6e9a0b5be0a1d143adc60b7f9);
#
#
#
#         marker_ca93e398e3da504565cdfdaa4db7589e.bindPopup(popup_d61a71314abc65523fe7814bba1efb0c)
#         ;
#
#
#
#
#             var marker_d1db459fd0974071e6a99a3352c2b1cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f16ffcf068f7bfac256587db695c9f88);
#
#
#         var popup_694352adc3194b53aafbdf0056af5d41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32602d52e8c61018f4c8e5b9cb8f4685 = $(`&lt;div id=&quot;html_32602d52e8c61018f4c8e5b9cb8f4685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_694352adc3194b53aafbdf0056af5d41.setContent(html_32602d52e8c61018f4c8e5b9cb8f4685);
#
#
#
#         marker_d1db459fd0974071e6a99a3352c2b1cc.bindPopup(popup_694352adc3194b53aafbdf0056af5d41)
#         ;
#
#
#
#
#             var marker_0cac3bb13a243ee17487e6e67bd281f7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f16ffcf068f7bfac256587db695c9f88);
#
#
#         var popup_89591029e3d5dc136ff0b4d65dae21e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18a7f63a4c91e0e241a96cf4134d0a7b = $(`&lt;div id=&quot;html_18a7f63a4c91e0e241a96cf4134d0a7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_89591029e3d5dc136ff0b4d65dae21e7.setContent(html_18a7f63a4c91e0e241a96cf4134d0a7b);
#
#
#
#         marker_0cac3bb13a243ee17487e6e67bd281f7.bindPopup(popup_89591029e3d5dc136ff0b4d65dae21e7)
#         ;
#
#
#
#
#             var marker_9e4631ce41b4c815ebc3196131df980e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f16ffcf068f7bfac256587db695c9f88);
#
#
#         var popup_b3706d80d77c1a00e851b394223515a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c43597eadcf233bac75613fbbd584fb0 = $(`&lt;div id=&quot;html_c43597eadcf233bac75613fbbd584fb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b3706d80d77c1a00e851b394223515a1.setContent(html_c43597eadcf233bac75613fbbd584fb0);
#
#
#
#         marker_
