# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea4eb05420df1e5ebfabf2ec8c89b958 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea4eb05420df1e5ebfabf2ec8c89b958&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea4eb05420df1e5ebfabf2ec8c89b958 = L.map(
#                 &quot;map_ea4eb05420df1e5ebfabf2ec8c89b958&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7957dbb1b4e66cf8dc2f9af13473142e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7957dbb1b4e66cf8dc2f9af13473142e.addTo(map_ea4eb05420df1e5ebfabf2ec8c89b958);
#
#
#             var marker_9e827d1ad20171217cb7fcd8d15f04cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ea4eb05420df1e5ebfabf2ec8c89b958);
#
#
#         var popup_f697a7df3e9bcfc7fff98d3c93e9293b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a343174062589b19834420a9c864a71c = $(`&lt;div id=&quot;html_a343174062589b19834420a9c864a71c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f697a7df3e9bcfc7fff98d3c93e9293b.setContent(html_a343174062589b19834420a9c864a71c);
#
#
#
#         marker_9e827d1ad20171217cb7fcd8d15f04cc.bindPopup(popup_f697a7df3e9bcfc7fff98d3c93e9293b)
#         ;
#
#
#
#
#             var marker_6813d33ed1bd5e5005a77cb49e06ed70 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ea4eb05420df1e5ebfabf2ec8c89b958);
#
#
#         var popup_573c108b58961c7e1ffeb4e892a2cb19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5edad4631734cccb1a76dd6eecb9e1a = $(`&lt;div id=&quot;html_c5edad4631734cccb1a76dd6eecb9e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_573c108b58961c7e1ffeb4e892a2cb19.setContent(html_c5edad4631734cccb1a76dd6eecb9e1a);
#
#
#
#         marker_6813d33ed1bd5e5005a77cb49e06ed70.bindPopup(popup_573c108b58961c7e1ffeb4e892a2cb19)
#         ;
#
#
#
#
#             var marker_a0d86cdaaef88b4207a42fe96303fb18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ea4eb05420df1e5ebfabf2ec8c89b958);
#
#
#         var popup_ee221a08991cfa5299099d8b242a7929 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bbd9f8001bd377e3f43cf8a3c6af53d = $(`&lt;div id=&quot;html_2bbd9f8001bd377e3f43cf8a3c6af53d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee221a08991cfa5299099d8b242a7929.setContent(html_2bbd9f8001bd377e3f43cf8a3c6af53d);
#
#
#
#         marker_a0d86cdaaef88b4207a42fe96303fb18.bindPopup(popup_ee221a08991cfa5299099d8b242a7929)
#         ;
#
#
#
#
#             var marker_42992dc82a9df1039acbfa340dc7f464 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ea4eb05420df1e5ebfabf2ec8c89b958);
#
#
#         var popup_2549d44b8570fa6f51c6a689ebfa6fe9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68e493ef8caed19e9fa5c792b205c250 = $(`&lt;div id=&quot;html_68e493ef8caed19e9fa5c792b205c250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2549d44b8570fa6f51c6a689ebfa6fe9.setContent(html_68e493ef8caed19e9fa5c792b205c250);
#
#
#
#         marker_42992dc82a9df1039acbfa340dc7f464.bindPopup(popup_2549d44b8570fa6f51c6a689ebfa6fe9)
#         ;
#
#
#
#
#             var marker_0476d9d96d9e271783825d0038bfd31e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ea4eb05420df1e5ebfabf2ec8c89b958);
#
#
#         var popup_7566208071026e21b13680048cd2ac92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6add7e1b0fe1b754ab95ed6c0f52a5d = $(`&lt;div id=&quot;html_d6add7e1b0fe1b754ab95ed6c0f52a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7566208071026e21b13680048cd2ac

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09b1c0ab3087ab9bdffd92b46ba5f6d1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09b1c0ab3087ab9bdffd92b46ba5f6d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09b1c0ab3087ab9bdffd92b46ba5f6d1 = L.map(
#                 &quot;map_09b1c0ab3087ab9bdffd92b46ba5f6d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe0b6b7fadd9b29bcb50cd5bdbf2838e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe0b6b7fadd9b29bcb50cd5bdbf2838e.addTo(map_09b1c0ab3087ab9bdffd92b46ba5f6d1);
#
#
#             var feature_group_e157971e84fbd52ce59008e33549915c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3c9356e11b71dae48a7cb86be50b61f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e157971e84fbd52ce59008e33549915c);
#
#
#         var popup_0288f2031fa29bfc2fd898629a0121c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30a00d74094d97a73f93d112e10b44f1 = $(`&lt;div id=&quot;html_30a00d74094d97a73f93d112e10b44f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0288f2031fa29bfc2fd898629a0121c0.setContent(html_30a00d74094d97a73f93d112e10b44f1);
#
#
#
#         marker_3c9356e11b71dae48a7cb86be50b61f1.bindPopup(popup_0288f2031fa29bfc2fd898629a0121c0)
#         ;
#
#
#
#
#             var marker_c0006811ab915167032e9c9cbbe996a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e157971e84fbd52ce59008e33549915c);
#
#
#         var popup_a7d87f2af02080f5213afb6057635861 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5880adfb74fbbec7d3eaa06bec5389ab = $(`&lt;div id=&quot;html_5880adfb74fbbec7d3eaa06bec5389ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a7d87f2af02080f5213afb6057635861.setContent(html_5880adfb74fbbec7d3eaa06bec5389ab);
#
#
#
#         marker_c0006811ab915167032e9c9cbbe996a5.bindPopup(popup_a7d87f2af02080f5213afb6057635861)
#         ;
#
#
#
#
#             var marker_f11bf6e7a1588e28e6579fe7c391a35c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e157971e84fbd52ce59008e33549915c);
#
#
#         var popup_bc843241d5a0d4f33d285b56b6db7ead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4db37265d45b9cc65ec17178524a4b9 = $(`&lt;div id=&quot;html_f4db37265d45b9cc65ec17178524a4b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bc843241d5a0d4f33d285b56b6db7ead.setContent(html_f4db37265d45b9cc65ec17178524a4b9);
#
#
#
#         marker_f11bf6e7a1588e28e6579fe7c391a35c.bindPopup(popup_bc843241d5a0d4f33d285b56b6db7ead)
#         ;
#
#
#
#
#             var marker_4a93b947f25aa3996424c4de962564ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e157971e84fbd52ce59008e33549915c);
#
#
#         var popup_6fb6391e3aac74a08e28f9461f65c79f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d273385a57ef16eede30a50253a3825f = $(`&lt;div id=&quot;html_d273385a57ef16eede30a50253a3825f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6fb6391e3aac74a08e28f9461f65c79f.setContent(html_d273385a57ef16eede30a50253a3825f);
#
#
#
#         marker_4a93b947f25aa3996424c4de962564ac.bindPopup(popup_6fb6391e3aac74a08e28f9461f65c79f)
#         ;
#
#
#
#
#             var marker_b8f0aa5b85bdd75b1d46040d8e631cbf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e157971e84fbd52ce59008e33549915c);
#
#
#         var popup_2906475fe466ade72e6736bbb21d6a3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82b9f347a99773e4e1ecf36713fb84de {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82b9f347a99773e4e1ecf36713fb84de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82b9f347a99773e4e1ecf36713fb84de = L.map(
#                 &quot;map_82b9f347a99773e4e1ecf36713fb84de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3df86b071236cf190eddc1acdc90b9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3df86b071236cf190eddc1acdc90b9c.addTo(map_82b9f347a99773e4e1ecf36713fb84de);
#
#
#             var feature_group_b0486eb460f093987c1b272d7e154f2e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b0486eb460f093987c1b272d7e154f2e.addTo(map_82b9f347a99773e4e1ecf36713fb84de);
#
#
#             var feature_group_sub_group_d9a570895472e4ce90a0c77923cf8e2c = L.featureGroup.subGroup(
#                 feature_group_b0486eb460f093987c1b272d7e154f2e
#             );
#
#
#             var marker_f03cefd92a155a088d57ec83e290c47f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9a570895472e4ce90a0c77923cf8e2c);
#
#
#         var popup_4068fdfb5d64a84db4382853bee58ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c1ead50f79f3fb00f1148e21e552fdb = $(`&lt;div id=&quot;html_0c1ead50f79f3fb00f1148e21e552fdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4068fdfb5d64a84db4382853bee58ede.setContent(html_0c1ead50f79f3fb00f1148e21e552fdb);
#
#
#
#         marker_f03cefd92a155a088d57ec83e290c47f.bindPopup(popup_4068fdfb5d64a84db4382853bee58ede)
#         ;
#
#
#
#
#             var marker_1985ac5c68032c3a23410cad64d1c187 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9a570895472e4ce90a0c77923cf8e2c);
#
#
#         var popup_9b6df7e2d9624f8dd4473e0155b2f84f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f58047c78a5f5ac7fd8d7b07ed9b895b = $(`&lt;div id=&quot;html_f58047c78a5f5ac7fd8d7b07ed9b895b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9b6df7e2d9624f8dd4473e0155b2f84f.setContent(html_f58047c78a5f5ac7fd8d7b07ed9b895b);
#
#
#
#         marker_1985ac5c68032c3a23410cad64d1c187.bindPopup(popup_9b6df7e2d9624f8dd4473e0155b2f84f)
#         ;
#
#
#
#
#             var marker_07fb18d132ce261c38f2db86378afb7d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9a570895472e4ce90a0c77923cf8e2c);
#
#
#         var popup_4de30f2dfe4cafc6106ac74eb848867d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0158884eff754a3a71f73053c96cfcc9 = $(`&lt;div id=&quot;html_0158884eff754a3a71f73053c96cfcc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4de30f2dfe4cafc6106ac74eb848867d.setContent(html_0158884eff754a3a71f73053c96cfcc9);
#
#
#
#         marker_07fb18d132ce261c38f2db86378afb7d.bindPopup(popup_4de30f2dfe4cafc6106ac74eb848867d)
#         ;
#
#
#
#
#             var marker_fa1f5fe398ef8ed270edccaae332df72 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9a570895472e4ce90a0c77923cf8e2c);
#
#
#         var popup_0d4d3bbb342496488cc20a90c6545adb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_619f3a18e7e9f7d000d8c314118029d6 = $(`&lt;div id=&quot;html_619f3a18e7e9f7d000d8c314118029d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0d4d3bbb342496488cc20a90c6545adb.setContent(html_619f3a18e7e9f7d000d8c314118029d6);
#
#
#
#         mark
