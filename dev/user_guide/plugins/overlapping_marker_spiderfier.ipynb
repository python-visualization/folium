# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54e42cafaa6a0cdebe1ce89105295e23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54e42cafaa6a0cdebe1ce89105295e23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54e42cafaa6a0cdebe1ce89105295e23 = L.map(
#                 &quot;map_54e42cafaa6a0cdebe1ce89105295e23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42c40c11336e9305145c8a9547daaf50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42c40c11336e9305145c8a9547daaf50.addTo(map_54e42cafaa6a0cdebe1ce89105295e23);
#
#
#             var marker_6d1067209cfd920aaaef5cd3527bd05b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_54e42cafaa6a0cdebe1ce89105295e23);
#
#
#         var popup_0fbd1c66c75ad866dc627655bb347228 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b484b7bdf9c56c4a06c364d8149179e1 = $(`&lt;div id=&quot;html_b484b7bdf9c56c4a06c364d8149179e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0fbd1c66c75ad866dc627655bb347228.setContent(html_b484b7bdf9c56c4a06c364d8149179e1);
#
#
#
#         marker_6d1067209cfd920aaaef5cd3527bd05b.bindPopup(popup_0fbd1c66c75ad866dc627655bb347228)
#         ;
#
#
#
#
#             var marker_b3e24365dded252c36b9e6454a122b30 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_54e42cafaa6a0cdebe1ce89105295e23);
#
#
#         var popup_0b87ec5d5b9e2f994528333ec65326ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da450d019ee79546f608f59e5cc68b33 = $(`&lt;div id=&quot;html_da450d019ee79546f608f59e5cc68b33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b87ec5d5b9e2f994528333ec65326ee.setContent(html_da450d019ee79546f608f59e5cc68b33);
#
#
#
#         marker_b3e24365dded252c36b9e6454a122b30.bindPopup(popup_0b87ec5d5b9e2f994528333ec65326ee)
#         ;
#
#
#
#
#             var marker_e0a4d307da511bc6e215b61804563b63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_54e42cafaa6a0cdebe1ce89105295e23);
#
#
#         var popup_1658fe3bd89e8574b153340412bdc6f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37c222cb844acfa3cc7673da4e40fd94 = $(`&lt;div id=&quot;html_37c222cb844acfa3cc7673da4e40fd94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1658fe3bd89e8574b153340412bdc6f0.setContent(html_37c222cb844acfa3cc7673da4e40fd94);
#
#
#
#         marker_e0a4d307da511bc6e215b61804563b63.bindPopup(popup_1658fe3bd89e8574b153340412bdc6f0)
#         ;
#
#
#
#
#             var marker_9b8acbba160b55730d8a7c616c6b9431 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_54e42cafaa6a0cdebe1ce89105295e23);
#
#
#         var popup_d6b3dda9e7f2f6c6b80a8792ff1b608d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbf1225f7df02b4d94b2e82ca46b55b5 = $(`&lt;div id=&quot;html_cbf1225f7df02b4d94b2e82ca46b55b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d6b3dda9e7f2f6c6b80a8792ff1b608d.setContent(html_cbf1225f7df02b4d94b2e82ca46b55b5);
#
#
#
#         marker_9b8acbba160b55730d8a7c616c6b9431.bindPopup(popup_d6b3dda9e7f2f6c6b80a8792ff1b608d)
#         ;
#
#
#
#
#             var marker_583bd2dfc469d19e1f0663dd58216198 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_54e42cafaa6a0cdebe1ce89105295e23);
#
#
#         var popup_a15c75490b50e2a0cbe547f18da4f27f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8dd1947afb541734b50c9bba2d0bccc = $(`&lt;div id=&quot;html_b8dd1947afb541734b50c9bba2d0bccc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a15c75490b50e2a0cbe547f18da4f27f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b26ae36dcc16c8d9b624bb5cc29d7b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b26ae36dcc16c8d9b624bb5cc29d7b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b26ae36dcc16c8d9b624bb5cc29d7b5 = L.map(
#                 &quot;map_8b26ae36dcc16c8d9b624bb5cc29d7b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_221532fea6841a1b488cc18b3cba6b9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_221532fea6841a1b488cc18b3cba6b9c.addTo(map_8b26ae36dcc16c8d9b624bb5cc29d7b5);
#
#
#             var feature_group_196cd43cb501552dd755ea3c02648402 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_03508ca4bb503ea08f40c76a729e7f84 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_196cd43cb501552dd755ea3c02648402);
#
#
#         var popup_59b33b8bd72aa074d53710fbc8ca4f73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f05b39b138b48f226ff5e18fcc6d56aa = $(`&lt;div id=&quot;html_f05b39b138b48f226ff5e18fcc6d56aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_59b33b8bd72aa074d53710fbc8ca4f73.setContent(html_f05b39b138b48f226ff5e18fcc6d56aa);
#
#
#
#         marker_03508ca4bb503ea08f40c76a729e7f84.bindPopup(popup_59b33b8bd72aa074d53710fbc8ca4f73)
#         ;
#
#
#
#
#             var marker_7de6fa7d046e1616538efc1cfc893574 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_196cd43cb501552dd755ea3c02648402);
#
#
#         var popup_e100812a0c2ce4b865591d7239663db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9007b349c3e73ea80db91a73d517e931 = $(`&lt;div id=&quot;html_9007b349c3e73ea80db91a73d517e931&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e100812a0c2ce4b865591d7239663db2.setContent(html_9007b349c3e73ea80db91a73d517e931);
#
#
#
#         marker_7de6fa7d046e1616538efc1cfc893574.bindPopup(popup_e100812a0c2ce4b865591d7239663db2)
#         ;
#
#
#
#
#             var marker_7b174e26d609e7ff4568493b2e808a92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_196cd43cb501552dd755ea3c02648402);
#
#
#         var popup_6c0889db9782ed7d7dd9f2d685fc009a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51f29857d126b9978e620de1f054ca94 = $(`&lt;div id=&quot;html_51f29857d126b9978e620de1f054ca94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6c0889db9782ed7d7dd9f2d685fc009a.setContent(html_51f29857d126b9978e620de1f054ca94);
#
#
#
#         marker_7b174e26d609e7ff4568493b2e808a92.bindPopup(popup_6c0889db9782ed7d7dd9f2d685fc009a)
#         ;
#
#
#
#
#             var marker_6a5b6a76092ae8edda761b80f6c1fd0e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_196cd43cb501552dd755ea3c02648402);
#
#
#         var popup_1199f60612fda5d6fbc865ecaec1bdc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c4b3bffd6efebec50c81fd3c2bd7bc2 = $(`&lt;div id=&quot;html_3c4b3bffd6efebec50c81fd3c2bd7bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1199f60612fda5d6fbc865ecaec1bdc2.setContent(html_3c4b3bffd6efebec50c81fd3c2bd7bc2);
#
#
#
#         marker_6a5b6a76092ae8edda761b80f6c1fd0e.bindPopup(popup_1199f60612fda5d6fbc865ecaec1bdc2)
#         ;
#
#
#
#
#             var marker_d30c32beb27ae24eeb37a880c86260b1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_196cd43cb501552dd755ea3c02648402);
#
#
#         var popup_70aa9b1197921f9125813edc1a71f0b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb7c2311aedfb4a754f4c7fe1c99529f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb7c2311aedfb4a754f4c7fe1c99529f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb7c2311aedfb4a754f4c7fe1c99529f = L.map(
#                 &quot;map_bb7c2311aedfb4a754f4c7fe1c99529f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2a321db87a655b62f422c6011300c92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2a321db87a655b62f422c6011300c92.addTo(map_bb7c2311aedfb4a754f4c7fe1c99529f);
#
#
#             var feature_group_60c14139177ccc160206cdb295e087d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_60c14139177ccc160206cdb295e087d9.addTo(map_bb7c2311aedfb4a754f4c7fe1c99529f);
#
#
#             var feature_group_sub_group_32c7a1524d086f10a7883682c95b6017 = L.featureGroup.subGroup(
#                 feature_group_60c14139177ccc160206cdb295e087d9
#             );
#
#
#             var marker_5a79e09ba2d3e84567e9a1744b7ce087 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_32c7a1524d086f10a7883682c95b6017);
#
#
#         var popup_ac0df7eb8620412e21a608e69d46c3eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dc82dbdad31ec4de727c8175f46b209 = $(`&lt;div id=&quot;html_4dc82dbdad31ec4de727c8175f46b209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ac0df7eb8620412e21a608e69d46c3eb.setContent(html_4dc82dbdad31ec4de727c8175f46b209);
#
#
#
#         marker_5a79e09ba2d3e84567e9a1744b7ce087.bindPopup(popup_ac0df7eb8620412e21a608e69d46c3eb)
#         ;
#
#
#
#
#             var marker_a84966c1bb591144b9edd44efcdec340 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_32c7a1524d086f10a7883682c95b6017);
#
#
#         var popup_4aff5216221a66aff5a016d9a10a479c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d9a0b8acbb0b7941f2d9710ea30b27b = $(`&lt;div id=&quot;html_8d9a0b8acbb0b7941f2d9710ea30b27b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4aff5216221a66aff5a016d9a10a479c.setContent(html_8d9a0b8acbb0b7941f2d9710ea30b27b);
#
#
#
#         marker_a84966c1bb591144b9edd44efcdec340.bindPopup(popup_4aff5216221a66aff5a016d9a10a479c)
#         ;
#
#
#
#
#             var marker_613dc35a6c8324517f3fe882b40f5c37 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_32c7a1524d086f10a7883682c95b6017);
#
#
#         var popup_2222b224ebdf2a075fd18409fc146bfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4936371fd6120738d4efe7273d2b88 = $(`&lt;div id=&quot;html_6e4936371fd6120738d4efe7273d2b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2222b224ebdf2a075fd18409fc146bfa.setContent(html_6e4936371fd6120738d4efe7273d2b88);
#
#
#
#         marker_613dc35a6c8324517f3fe882b40f5c37.bindPopup(popup_2222b224ebdf2a075fd18409fc146bfa)
#         ;
#
#
#
#
#             var marker_fac83bf7d3060e866b254ebd3bc41a0e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_32c7a1524d086f10a7883682c95b6017);
#
#
#         var popup_11f39c7caef350fc241c4be7db27d8a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2c7ff6608a4a829d9aa499d06ccc0cf = $(`&lt;div id=&quot;html_a2c7ff6608a4a829d9aa499d06ccc0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_11f39c7caef350fc241c4be7db27d8a6.setContent(html_a2c7ff6608a4a829d9aa499d06ccc0cf);
#
#
#
#         marker_
