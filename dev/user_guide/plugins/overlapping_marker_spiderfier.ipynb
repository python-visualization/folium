# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b26e3203ac8c84327c6a6384a82fd2e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b26e3203ac8c84327c6a6384a82fd2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b26e3203ac8c84327c6a6384a82fd2e = L.map(
#                 &quot;map_9b26e3203ac8c84327c6a6384a82fd2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da1ff2d7d66977addb6f73c6befb0820 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da1ff2d7d66977addb6f73c6befb0820.addTo(map_9b26e3203ac8c84327c6a6384a82fd2e);
#
#
#             var marker_8fa46962d5d8bea1a75dc8ecdea6b9e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9b26e3203ac8c84327c6a6384a82fd2e);
#
#
#         var popup_cdb8ce7464173615f181695c827f7f03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95e637a55094213b2650449ad5448f4b = $(`&lt;div id=&quot;html_95e637a55094213b2650449ad5448f4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cdb8ce7464173615f181695c827f7f03.setContent(html_95e637a55094213b2650449ad5448f4b);
#
#
#
#         marker_8fa46962d5d8bea1a75dc8ecdea6b9e6.bindPopup(popup_cdb8ce7464173615f181695c827f7f03)
#         ;
#
#
#
#
#             var marker_1eccde73827600c19336ab752b8034de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9b26e3203ac8c84327c6a6384a82fd2e);
#
#
#         var popup_bcb61554d29e8dc57c33493c0a8fddd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52e3ed5edf0ea98511e9bd08d1d9ad5d = $(`&lt;div id=&quot;html_52e3ed5edf0ea98511e9bd08d1d9ad5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bcb61554d29e8dc57c33493c0a8fddd5.setContent(html_52e3ed5edf0ea98511e9bd08d1d9ad5d);
#
#
#
#         marker_1eccde73827600c19336ab752b8034de.bindPopup(popup_bcb61554d29e8dc57c33493c0a8fddd5)
#         ;
#
#
#
#
#             var marker_fe4a97330d1943f4c9bb606db77aba93 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9b26e3203ac8c84327c6a6384a82fd2e);
#
#
#         var popup_6fa8e2f2e4003f06bf58db3e9403b25d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65bfd21607f1cd610398f30410320d6f = $(`&lt;div id=&quot;html_65bfd21607f1cd610398f30410320d6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6fa8e2f2e4003f06bf58db3e9403b25d.setContent(html_65bfd21607f1cd610398f30410320d6f);
#
#
#
#         marker_fe4a97330d1943f4c9bb606db77aba93.bindPopup(popup_6fa8e2f2e4003f06bf58db3e9403b25d)
#         ;
#
#
#
#
#             var marker_e663620467b36a71f651badfadda3f6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9b26e3203ac8c84327c6a6384a82fd2e);
#
#
#         var popup_171358f2c1214291af8f62dbe04d9a43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65ed36d33bfb56209149b02ac97fd5c8 = $(`&lt;div id=&quot;html_65ed36d33bfb56209149b02ac97fd5c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_171358f2c1214291af8f62dbe04d9a43.setContent(html_65ed36d33bfb56209149b02ac97fd5c8);
#
#
#
#         marker_e663620467b36a71f651badfadda3f6d.bindPopup(popup_171358f2c1214291af8f62dbe04d9a43)
#         ;
#
#
#
#
#             var marker_837749435c353da25bf864960ffb703c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9b26e3203ac8c84327c6a6384a82fd2e);
#
#
#         var popup_508c73a2d3c3a1ee2002ec562df4206a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc9126b3cf33a9eef065941a130887ef = $(`&lt;div id=&quot;html_fc9126b3cf33a9eef065941a130887ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_508c73a2d3c3a1ee2002ec562df420

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b96b3e4be0c1c81a8a5b11de8ddac5f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b96b3e4be0c1c81a8a5b11de8ddac5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b96b3e4be0c1c81a8a5b11de8ddac5f = L.map(
#                 &quot;map_3b96b3e4be0c1c81a8a5b11de8ddac5f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cbd645bc9b9a69be51934cf33655dff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cbd645bc9b9a69be51934cf33655dff.addTo(map_3b96b3e4be0c1c81a8a5b11de8ddac5f);
#
#
#             var feature_group_b26757a6de318418d59e6f8c9cb431c1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_54e30495af212765719e6174a92586ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b26757a6de318418d59e6f8c9cb431c1);
#
#
#         var popup_50aab7547b7d98e38b6ff084b859685b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6f044c3adbd2ffae9514bbf58166fc3 = $(`&lt;div id=&quot;html_d6f044c3adbd2ffae9514bbf58166fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_50aab7547b7d98e38b6ff084b859685b.setContent(html_d6f044c3adbd2ffae9514bbf58166fc3);
#
#
#
#         marker_54e30495af212765719e6174a92586ce.bindPopup(popup_50aab7547b7d98e38b6ff084b859685b)
#         ;
#
#
#
#
#             var marker_dbac0efceb710200a6a1fd03e2ce9171 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b26757a6de318418d59e6f8c9cb431c1);
#
#
#         var popup_8424d78f143419ccd2005b5e445724da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cef76baae57f7a26c23faddeb596b24d = $(`&lt;div id=&quot;html_cef76baae57f7a26c23faddeb596b24d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8424d78f143419ccd2005b5e445724da.setContent(html_cef76baae57f7a26c23faddeb596b24d);
#
#
#
#         marker_dbac0efceb710200a6a1fd03e2ce9171.bindPopup(popup_8424d78f143419ccd2005b5e445724da)
#         ;
#
#
#
#
#             var marker_68cf2b2c379cb64b59755321a7cc84ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b26757a6de318418d59e6f8c9cb431c1);
#
#
#         var popup_65baa94a8c93f986544de29a7864ff44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ac8ecd32bfe87797807710f6d604919 = $(`&lt;div id=&quot;html_5ac8ecd32bfe87797807710f6d604919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_65baa94a8c93f986544de29a7864ff44.setContent(html_5ac8ecd32bfe87797807710f6d604919);
#
#
#
#         marker_68cf2b2c379cb64b59755321a7cc84ef.bindPopup(popup_65baa94a8c93f986544de29a7864ff44)
#         ;
#
#
#
#
#             var marker_d73fc00ee60e2a9866fa2ef247383b33 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b26757a6de318418d59e6f8c9cb431c1);
#
#
#         var popup_aae8e39d7eb98b75f1a6614d71515ffa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3b0e2e7907581a424b1a5ed44e98b8e = $(`&lt;div id=&quot;html_b3b0e2e7907581a424b1a5ed44e98b8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aae8e39d7eb98b75f1a6614d71515ffa.setContent(html_b3b0e2e7907581a424b1a5ed44e98b8e);
#
#
#
#         marker_d73fc00ee60e2a9866fa2ef247383b33.bindPopup(popup_aae8e39d7eb98b75f1a6614d71515ffa)
#         ;
#
#
#
#
#             var marker_1f28a30acbe656ab4dfcd71bef9eee96 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b26757a6de318418d59e6f8c9cb431c1);
#
#
#         var popup_19ca250aa12c0a2b834f997080b46318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a0cadc8064c90f1e6bc819aa13eacb0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a0cadc8064c90f1e6bc819aa13eacb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a0cadc8064c90f1e6bc819aa13eacb0 = L.map(
#                 &quot;map_0a0cadc8064c90f1e6bc819aa13eacb0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_744b158e0706ea998fb6d01b161e6071 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_744b158e0706ea998fb6d01b161e6071.addTo(map_0a0cadc8064c90f1e6bc819aa13eacb0);
#
#
#             var feature_group_c3176640e3bf553631a30ba6f75eb06a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c3176640e3bf553631a30ba6f75eb06a.addTo(map_0a0cadc8064c90f1e6bc819aa13eacb0);
#
#
#             var feature_group_sub_group_ce14db73956f8703bf3fa60d013707f6 = L.featureGroup.subGroup(
#                 feature_group_c3176640e3bf553631a30ba6f75eb06a
#             );
#
#
#             var marker_895702cb9a999411d023b5d55e9d3f76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce14db73956f8703bf3fa60d013707f6);
#
#
#         var popup_88d8601b16c94c1687caaf37bf895817 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_752c6183690da139da329905f3ec571e = $(`&lt;div id=&quot;html_752c6183690da139da329905f3ec571e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_88d8601b16c94c1687caaf37bf895817.setContent(html_752c6183690da139da329905f3ec571e);
#
#
#
#         marker_895702cb9a999411d023b5d55e9d3f76.bindPopup(popup_88d8601b16c94c1687caaf37bf895817)
#         ;
#
#
#
#
#             var marker_26a45cf76e1afacf988a9a6d1da61a16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce14db73956f8703bf3fa60d013707f6);
#
#
#         var popup_1a06c3fdc50480f2583d0af3217f105d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d80b8fb687cc31893e63ba8c4733ed0b = $(`&lt;div id=&quot;html_d80b8fb687cc31893e63ba8c4733ed0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1a06c3fdc50480f2583d0af3217f105d.setContent(html_d80b8fb687cc31893e63ba8c4733ed0b);
#
#
#
#         marker_26a45cf76e1afacf988a9a6d1da61a16.bindPopup(popup_1a06c3fdc50480f2583d0af3217f105d)
#         ;
#
#
#
#
#             var marker_59d6331efa52fd54dd672d76a2742527 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce14db73956f8703bf3fa60d013707f6);
#
#
#         var popup_dd2d9e629d126ca95ab28fc60b644cf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e0544772e7b3e4d91451b28b571825b = $(`&lt;div id=&quot;html_4e0544772e7b3e4d91451b28b571825b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dd2d9e629d126ca95ab28fc60b644cf0.setContent(html_4e0544772e7b3e4d91451b28b571825b);
#
#
#
#         marker_59d6331efa52fd54dd672d76a2742527.bindPopup(popup_dd2d9e629d126ca95ab28fc60b644cf0)
#         ;
#
#
#
#
#             var marker_237a83ef63d17dfa1e90d8cf1552d641 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce14db73956f8703bf3fa60d013707f6);
#
#
#         var popup_e291b7c91d7de3d390754b23ddf03905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06c6554b8a32c8dc6289e309e345b9e2 = $(`&lt;div id=&quot;html_06c6554b8a32c8dc6289e309e345b9e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e291b7c91d7de3d390754b23ddf03905.setContent(html_06c6554b8a32c8dc6289e309e345b9e2);
#
#
#
#         mark
