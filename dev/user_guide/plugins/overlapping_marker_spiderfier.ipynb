# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_115458fc8ed3d8c1e3311c1a0aa34f53 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_115458fc8ed3d8c1e3311c1a0aa34f53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_115458fc8ed3d8c1e3311c1a0aa34f53 = L.map(
#                 &quot;map_115458fc8ed3d8c1e3311c1a0aa34f53&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b324384be81a2b933429ddbd006a9d31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b324384be81a2b933429ddbd006a9d31.addTo(map_115458fc8ed3d8c1e3311c1a0aa34f53);
#
#
#             var marker_49d1aef37e4ef5383af160f6c8044a49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_115458fc8ed3d8c1e3311c1a0aa34f53);
#
#
#         var popup_652ca7c6716114f158cf00cdafcefab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc84a5a88a7cfb6cdcc0da4a8003396a = $(`&lt;div id=&quot;html_dc84a5a88a7cfb6cdcc0da4a8003396a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_652ca7c6716114f158cf00cdafcefab1.setContent(html_dc84a5a88a7cfb6cdcc0da4a8003396a);
#
#
#
#         marker_49d1aef37e4ef5383af160f6c8044a49.bindPopup(popup_652ca7c6716114f158cf00cdafcefab1)
#         ;
#
#
#
#
#             var marker_eecdcf5689ec33090e765e237b1de7ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_115458fc8ed3d8c1e3311c1a0aa34f53);
#
#
#         var popup_d408709e6185f39822ed8a4c7f6a8e03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dbe78dc8be020a66a086341141b2dee = $(`&lt;div id=&quot;html_8dbe78dc8be020a66a086341141b2dee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d408709e6185f39822ed8a4c7f6a8e03.setContent(html_8dbe78dc8be020a66a086341141b2dee);
#
#
#
#         marker_eecdcf5689ec33090e765e237b1de7ca.bindPopup(popup_d408709e6185f39822ed8a4c7f6a8e03)
#         ;
#
#
#
#
#             var marker_870b20c0267818c3219f64ea235c0e02 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_115458fc8ed3d8c1e3311c1a0aa34f53);
#
#
#         var popup_c26bbeab663fea35eca3519f545b14bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3baa31eb965d49c042c16d3a59d01bd2 = $(`&lt;div id=&quot;html_3baa31eb965d49c042c16d3a59d01bd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c26bbeab663fea35eca3519f545b14bf.setContent(html_3baa31eb965d49c042c16d3a59d01bd2);
#
#
#
#         marker_870b20c0267818c3219f64ea235c0e02.bindPopup(popup_c26bbeab663fea35eca3519f545b14bf)
#         ;
#
#
#
#
#             var marker_bbdb47ea5f43a606b41c683ab038b893 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_115458fc8ed3d8c1e3311c1a0aa34f53);
#
#
#         var popup_782b1ddc91ae8b1d90af2f854da9e8e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33d41712d9ad58ab5d9d64a7013d6363 = $(`&lt;div id=&quot;html_33d41712d9ad58ab5d9d64a7013d6363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_782b1ddc91ae8b1d90af2f854da9e8e9.setContent(html_33d41712d9ad58ab5d9d64a7013d6363);
#
#
#
#         marker_bbdb47ea5f43a606b41c683ab038b893.bindPopup(popup_782b1ddc91ae8b1d90af2f854da9e8e9)
#         ;
#
#
#
#
#             var marker_fce2c0d467f43f50d06bc96cd57247f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_115458fc8ed3d8c1e3311c1a0aa34f53);
#
#
#         var popup_8956fe198e89b9b527afc5991cb4a900 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7e6c810b1473ff972410a50ac3e4a2d = $(`&lt;div id=&quot;html_a7e6c810b1473ff972410a50ac3e4a2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8956fe198e89b9b527afc5991cb4a900.setContent(html_a7e6c810b1473ff972410a50ac3e4a2d);
#
#
#
#         marker_fce2c0d467f43f50d06bc96cd57247f5.bindPopup(popup_8956fe198e89b9b527afc5991cb4a900)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bc1e958978345b89c5b179b7a13f369 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bc1e958978345b89c5b179b7a13f369&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bc1e958978345b89c5b179b7a13f369 = L.map(
#                 &quot;map_4bc1e958978345b89c5b179b7a13f369&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_feb7607020172cf1a3c051122bb6df4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_feb7607020172cf1a3c051122bb6df4d.addTo(map_4bc1e958978345b89c5b179b7a13f369);
#
#
#             var feature_group_793a80100b13ef4f8654d47aeab1590d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bfb93930bee311004eb6506cd0e22b4e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_793a80100b13ef4f8654d47aeab1590d);
#
#
#         var popup_377664ee8de0ef69d21bf8c034aeaa9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe4d0d0a16a35a080aa0db42b0e36433 = $(`&lt;div id=&quot;html_fe4d0d0a16a35a080aa0db42b0e36433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_377664ee8de0ef69d21bf8c034aeaa9e.setContent(html_fe4d0d0a16a35a080aa0db42b0e36433);
#
#
#
#         marker_bfb93930bee311004eb6506cd0e22b4e.bindPopup(popup_377664ee8de0ef69d21bf8c034aeaa9e)
#         ;
#
#
#
#
#             var marker_09b8fa730953455b4480345f4c2b16aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_793a80100b13ef4f8654d47aeab1590d);
#
#
#         var popup_d6a76a07f7bafce659a9d729b2e61cac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29652ca51ef048b166626dd2d283103c = $(`&lt;div id=&quot;html_29652ca51ef048b166626dd2d283103c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d6a76a07f7bafce659a9d729b2e61cac.setContent(html_29652ca51ef048b166626dd2d283103c);
#
#
#
#         marker_09b8fa730953455b4480345f4c2b16aa.bindPopup(popup_d6a76a07f7bafce659a9d729b2e61cac)
#         ;
#
#
#
#
#             var marker_0c7c30bf584c8db048d9d6fb21cde126 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_793a80100b13ef4f8654d47aeab1590d);
#
#
#         var popup_2cd44db2361a67bfcb43fbabfde130d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d0a5d63b05703578eb832e1a38baca6 = $(`&lt;div id=&quot;html_6d0a5d63b05703578eb832e1a38baca6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2cd44db2361a67bfcb43fbabfde130d4.setContent(html_6d0a5d63b05703578eb832e1a38baca6);
#
#
#
#         marker_0c7c30bf584c8db048d9d6fb21cde126.bindPopup(popup_2cd44db2361a67bfcb43fbabfde130d4)
#         ;
#
#
#
#
#             var marker_e8e9bf654f70b810717fe6c5dcfb401a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_793a80100b13ef4f8654d47aeab1590d);
#
#
#         var popup_91072332b64f388a269bd1944a28ba7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90bfbdb12aedc530d47a182b6b2b7fc7 = $(`&lt;div id=&quot;html_90bfbdb12aedc530d47a182b6b2b7fc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_91072332b64f388a269bd1944a28ba7d.setContent(html_90bfbdb12aedc530d47a182b6b2b7fc7);
#
#
#
#         marker_e8e9bf654f70b810717fe6c5dcfb401a.bindPopup(popup_91072332b64f388a269bd1944a28ba7d)
#         ;
#
#
#
#
#             var marker_70f50645f6ea92c7c501352fe7b1dc8d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_793a80100b13ef4f8654d47aeab1590d);
#
#
#         var popup_494267c58a7a77a06a5b4501267766d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c342c62c4542bb1989ce287d27afa5e4 = $(`&lt;div id=&quot;html_c342c62c4542bb1989ce287d27afa5e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9ab9be15b9445a789f7f4dc80491bf9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9ab9be15b9445a789f7f4dc80491bf9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9ab9be15b9445a789f7f4dc80491bf9 = L.map(
#                 &quot;map_c9ab9be15b9445a789f7f4dc80491bf9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f80cca4eb3772d0742f758ff6ef8ed2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f80cca4eb3772d0742f758ff6ef8ed2.addTo(map_c9ab9be15b9445a789f7f4dc80491bf9);
#
#
#             var feature_group_e5eb3b514489c00db59bd2597c161cdf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e5eb3b514489c00db59bd2597c161cdf.addTo(map_c9ab9be15b9445a789f7f4dc80491bf9);
#
#
#             var feature_group_sub_group_b1163e0960897d3453855dcda3e97ab2 = L.featureGroup.subGroup(
#                 feature_group_e5eb3b514489c00db59bd2597c161cdf
#             );
#
#
#             var marker_feaf9bc211e3fdd5e140d422dd13dcc9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1163e0960897d3453855dcda3e97ab2);
#
#
#         var popup_afaace80b832a3ec3866641a5629852d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd7e7e52e225b0062f8efc92f9fc9853 = $(`&lt;div id=&quot;html_fd7e7e52e225b0062f8efc92f9fc9853&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_afaace80b832a3ec3866641a5629852d.setContent(html_fd7e7e52e225b0062f8efc92f9fc9853);
#
#
#
#         marker_feaf9bc211e3fdd5e140d422dd13dcc9.bindPopup(popup_afaace80b832a3ec3866641a5629852d)
#         ;
#
#
#
#
#             var marker_2bd4ac9516d0d2862d3f3db4255b1c00 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1163e0960897d3453855dcda3e97ab2);
#
#
#         var popup_86876860b762db6790919a9044daef7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f03fcf0da872c3e203d57be0a0b7b521 = $(`&lt;div id=&quot;html_f03fcf0da872c3e203d57be0a0b7b521&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_86876860b762db6790919a9044daef7c.setContent(html_f03fcf0da872c3e203d57be0a0b7b521);
#
#
#
#         marker_2bd4ac9516d0d2862d3f3db4255b1c00.bindPopup(popup_86876860b762db6790919a9044daef7c)
#         ;
#
#
#
#
#             var marker_c4515d2f79ea90b8992344f0a9ad8b7b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1163e0960897d3453855dcda3e97ab2);
#
#
#         var popup_09c96af446269c3477c6a10b34595cad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f39cdba27101da7163f4d1b7dad7b396 = $(`&lt;div id=&quot;html_f39cdba27101da7163f4d1b7dad7b396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09c96af446269c3477c6a10b34595cad.setContent(html_f39cdba27101da7163f4d1b7dad7b396);
#
#
#
#         marker_c4515d2f79ea90b8992344f0a9ad8b7b.bindPopup(popup_09c96af446269c3477c6a10b34595cad)
#         ;
#
#
#
#
#             var marker_d026962ba623bd1d0f5889c655fb3cc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1163e0960897d3453855dcda3e97ab2);
#
#
#         var popup_e30f4084b86b31e8431a6823f6bd17ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e331d1e7bff7361ebc0bf0e3f442c34 = $(`&lt;div id=&quot;html_1e331d1e7bff7361ebc0bf0e3f442c34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e30f4084b86b31e8431a6823f6bd17ef.setContent(html_1e331d1e7bff7361ebc0bf0e3f442c34);
#
#
#
#         marker_d026962ba623bd1d0f5889c655fb3cc2.bindPopup(popup_e30f4084b86b31e8431a6823f6bd17ef)
#         ;
#
#
#
#
#             var marker_9f78f309730f2d3d10ad2a559fd879e9 = L.marker(
#                 [45.0503999
