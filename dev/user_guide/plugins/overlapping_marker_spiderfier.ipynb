# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1805f8929889f2bf65aa231bae6b8f8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1805f8929889f2bf65aa231bae6b8f8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1805f8929889f2bf65aa231bae6b8f8a = L.map(
#                 &quot;map_1805f8929889f2bf65aa231bae6b8f8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efc9b77142dcd4954091470eff50e1b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efc9b77142dcd4954091470eff50e1b0.addTo(map_1805f8929889f2bf65aa231bae6b8f8a);
#
#
#             var marker_0061632051603f63cb234fd4c030339e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1805f8929889f2bf65aa231bae6b8f8a);
#
#
#         var popup_36f065abf41e3bd564a522acf9b4f879 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8349b6f618caab8015a5b3a9ec4f5a86 = $(`&lt;div id=&quot;html_8349b6f618caab8015a5b3a9ec4f5a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_36f065abf41e3bd564a522acf9b4f879.setContent(html_8349b6f618caab8015a5b3a9ec4f5a86);
#
#
#
#         marker_0061632051603f63cb234fd4c030339e.bindPopup(popup_36f065abf41e3bd564a522acf9b4f879)
#         ;
#
#
#
#
#             var marker_3131af7b58a4bd58eb917122800044c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1805f8929889f2bf65aa231bae6b8f8a);
#
#
#         var popup_574d0898f758b54743cf983905ba4a06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_127ce05986b422e9202d2956dd59571e = $(`&lt;div id=&quot;html_127ce05986b422e9202d2956dd59571e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_574d0898f758b54743cf983905ba4a06.setContent(html_127ce05986b422e9202d2956dd59571e);
#
#
#
#         marker_3131af7b58a4bd58eb917122800044c1.bindPopup(popup_574d0898f758b54743cf983905ba4a06)
#         ;
#
#
#
#
#             var marker_61ca3f4fbb3027fd04adb188d7197e87 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1805f8929889f2bf65aa231bae6b8f8a);
#
#
#         var popup_070f382a6236bfa062583bf63d4c20a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faf0a70e588c9566fb9496169b742409 = $(`&lt;div id=&quot;html_faf0a70e588c9566fb9496169b742409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_070f382a6236bfa062583bf63d4c20a6.setContent(html_faf0a70e588c9566fb9496169b742409);
#
#
#
#         marker_61ca3f4fbb3027fd04adb188d7197e87.bindPopup(popup_070f382a6236bfa062583bf63d4c20a6)
#         ;
#
#
#
#
#             var marker_9eb7c4f9560d22ff9be2c1a1e342fdcd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1805f8929889f2bf65aa231bae6b8f8a);
#
#
#         var popup_b9b10a910662d3b8d5ea77ad990e3278 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6643ac79b20d5c51b06122849eedf8fa = $(`&lt;div id=&quot;html_6643ac79b20d5c51b06122849eedf8fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b9b10a910662d3b8d5ea77ad990e3278.setContent(html_6643ac79b20d5c51b06122849eedf8fa);
#
#
#
#         marker_9eb7c4f9560d22ff9be2c1a1e342fdcd.bindPopup(popup_b9b10a910662d3b8d5ea77ad990e3278)
#         ;
#
#
#
#
#             var marker_25870371594852183e8e910c129ae3a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1805f8929889f2bf65aa231bae6b8f8a);
#
#
#         var popup_6448b4acd07c4fe6b93c1bee5c06dadf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2636393b220c3a2e82bbd6c1f551cca2 = $(`&lt;div id=&quot;html_2636393b220c3a2e82bbd6c1f551cca2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6448b4acd07c4fe6b93c1bee5c06dadf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59daf99f92a6e4d5756cd4cba153da5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59daf99f92a6e4d5756cd4cba153da5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59daf99f92a6e4d5756cd4cba153da5c = L.map(
#                 &quot;map_59daf99f92a6e4d5756cd4cba153da5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f1fb5dcf7fb7878af15de18f1ba1a4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f1fb5dcf7fb7878af15de18f1ba1a4d.addTo(map_59daf99f92a6e4d5756cd4cba153da5c);
#
#
#             var feature_group_1e32e2e05d40b16adaf0f7940dff9eb8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_641d6f609ea1dd03a6205afb0284d872 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1e32e2e05d40b16adaf0f7940dff9eb8);
#
#
#         var popup_413dafceed4919bcfb71de27b03655f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_020139a88f91169c89a939b9a710ecb8 = $(`&lt;div id=&quot;html_020139a88f91169c89a939b9a710ecb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_413dafceed4919bcfb71de27b03655f5.setContent(html_020139a88f91169c89a939b9a710ecb8);
#
#
#
#         marker_641d6f609ea1dd03a6205afb0284d872.bindPopup(popup_413dafceed4919bcfb71de27b03655f5)
#         ;
#
#
#
#
#             var marker_efa6ce801d7d376e02d64cf2d51d8841 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1e32e2e05d40b16adaf0f7940dff9eb8);
#
#
#         var popup_2812bcffd57b41bd9b6fa370874a8c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d1d0c3436ad18b21bea93cd8ab05584 = $(`&lt;div id=&quot;html_9d1d0c3436ad18b21bea93cd8ab05584&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2812bcffd57b41bd9b6fa370874a8c83.setContent(html_9d1d0c3436ad18b21bea93cd8ab05584);
#
#
#
#         marker_efa6ce801d7d376e02d64cf2d51d8841.bindPopup(popup_2812bcffd57b41bd9b6fa370874a8c83)
#         ;
#
#
#
#
#             var marker_fb78fcff272f7cd1971ea4b9e3dfe31a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1e32e2e05d40b16adaf0f7940dff9eb8);
#
#
#         var popup_35b6626c3a1a550f5bc0f7e966c27018 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72ec2a2e025c4ad9ba9e2a4aae14b3db = $(`&lt;div id=&quot;html_72ec2a2e025c4ad9ba9e2a4aae14b3db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_35b6626c3a1a550f5bc0f7e966c27018.setContent(html_72ec2a2e025c4ad9ba9e2a4aae14b3db);
#
#
#
#         marker_fb78fcff272f7cd1971ea4b9e3dfe31a.bindPopup(popup_35b6626c3a1a550f5bc0f7e966c27018)
#         ;
#
#
#
#
#             var marker_81ba7ef75d3199a563c67f07998dec36 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1e32e2e05d40b16adaf0f7940dff9eb8);
#
#
#         var popup_f1f840d86cb9abc2a8b3860c6273fbe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fad8e4c502fc117c0c64b33602e62e0 = $(`&lt;div id=&quot;html_5fad8e4c502fc117c0c64b33602e62e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f1f840d86cb9abc2a8b3860c6273fbe7.setContent(html_5fad8e4c502fc117c0c64b33602e62e0);
#
#
#
#         marker_81ba7ef75d3199a563c67f07998dec36.bindPopup(popup_f1f840d86cb9abc2a8b3860c6273fbe7)
#         ;
#
#
#
#
#             var marker_deacaa22a630341095d4191b603bbf9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1e32e2e05d40b16adaf0f7940dff9eb8);
#
#
#         var popup_6cad6e78ce9c54ca6d63cceb140357ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccc3c8458dd259e4cc1b002d154c89f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccc3c8458dd259e4cc1b002d154c89f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccc3c8458dd259e4cc1b002d154c89f4 = L.map(
#                 &quot;map_ccc3c8458dd259e4cc1b002d154c89f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24489bafd0ae0548521346befbd2fe17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24489bafd0ae0548521346befbd2fe17.addTo(map_ccc3c8458dd259e4cc1b002d154c89f4);
#
#
#             var feature_group_c94606dcf911905cc2acfd71db66501f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c94606dcf911905cc2acfd71db66501f.addTo(map_ccc3c8458dd259e4cc1b002d154c89f4);
#
#
#             var feature_group_sub_group_035f624f887d1c5df69e212d1adae315 = L.featureGroup.subGroup(
#                 feature_group_c94606dcf911905cc2acfd71db66501f
#             );
#
#
#             var marker_eda681eba69267e6f773a7d83b61ef0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_035f624f887d1c5df69e212d1adae315);
#
#
#         var popup_57a0ae7828706a38acd8979e170d75b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6329a62c87f2f8ec7e9e6fa1badc9af6 = $(`&lt;div id=&quot;html_6329a62c87f2f8ec7e9e6fa1badc9af6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_57a0ae7828706a38acd8979e170d75b8.setContent(html_6329a62c87f2f8ec7e9e6fa1badc9af6);
#
#
#
#         marker_eda681eba69267e6f773a7d83b61ef0f.bindPopup(popup_57a0ae7828706a38acd8979e170d75b8)
#         ;
#
#
#
#
#             var marker_4eb2e6d12380b6f8b7238db651ab7340 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_035f624f887d1c5df69e212d1adae315);
#
#
#         var popup_678258fc3d35a4d47931f1fb4da42b10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5694cdc6fad7c0d0a1b7e113f8dfe479 = $(`&lt;div id=&quot;html_5694cdc6fad7c0d0a1b7e113f8dfe479&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_678258fc3d35a4d47931f1fb4da42b10.setContent(html_5694cdc6fad7c0d0a1b7e113f8dfe479);
#
#
#
#         marker_4eb2e6d12380b6f8b7238db651ab7340.bindPopup(popup_678258fc3d35a4d47931f1fb4da42b10)
#         ;
#
#
#
#
#             var marker_fc90d5471100b9e15f1bde212deda15f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_035f624f887d1c5df69e212d1adae315);
#
#
#         var popup_2425de192d64031891fc4d2f3e4c7888 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09d6121c6b451627be68904e82bd0d16 = $(`&lt;div id=&quot;html_09d6121c6b451627be68904e82bd0d16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2425de192d64031891fc4d2f3e4c7888.setContent(html_09d6121c6b451627be68904e82bd0d16);
#
#
#
#         marker_fc90d5471100b9e15f1bde212deda15f.bindPopup(popup_2425de192d64031891fc4d2f3e4c7888)
#         ;
#
#
#
#
#             var marker_c2780acf8c74d3ae01887b7e0f17d179 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_035f624f887d1c5df69e212d1adae315);
#
#
#         var popup_d90500ba4d14283999dd41009e8132f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_462d1b1cb5d8165704419ad4ec0ecc15 = $(`&lt;div id=&quot;html_462d1b1cb5d8165704419ad4ec0ecc15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d90500ba4d14283999dd41009e8132f2.setContent(html_462d1b1cb5d8165704419ad4ec0ecc15);
#
#
#
#         marker_
