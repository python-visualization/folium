# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f153cced6815ff642d91da99cc871bea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f153cced6815ff642d91da99cc871bea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f153cced6815ff642d91da99cc871bea = L.map(
#                 &quot;map_f153cced6815ff642d91da99cc871bea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9413eea6d15d9b3022e9f4f597adecf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9413eea6d15d9b3022e9f4f597adecf.addTo(map_f153cced6815ff642d91da99cc871bea);
#
#
#             var marker_c293bfc7527625d17d343ad9dec345b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f153cced6815ff642d91da99cc871bea);
#
#
#         var popup_dbe8ea6b3c2be3ddbad756b21a9e77f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7c876a047d398cb3e2a68b8b9f36c94 = $(`&lt;div id=&quot;html_f7c876a047d398cb3e2a68b8b9f36c94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dbe8ea6b3c2be3ddbad756b21a9e77f6.setContent(html_f7c876a047d398cb3e2a68b8b9f36c94);
#
#
#
#         marker_c293bfc7527625d17d343ad9dec345b9.bindPopup(popup_dbe8ea6b3c2be3ddbad756b21a9e77f6)
#         ;
#
#
#
#
#             var marker_1a1f0dcaf4f55eef043bc9e42fdc521f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f153cced6815ff642d91da99cc871bea);
#
#
#         var popup_c38fb37f6bcb7fc552715ea40c52066d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6680257ebc29bf1b3dcf700a88c9ec12 = $(`&lt;div id=&quot;html_6680257ebc29bf1b3dcf700a88c9ec12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c38fb37f6bcb7fc552715ea40c52066d.setContent(html_6680257ebc29bf1b3dcf700a88c9ec12);
#
#
#
#         marker_1a1f0dcaf4f55eef043bc9e42fdc521f.bindPopup(popup_c38fb37f6bcb7fc552715ea40c52066d)
#         ;
#
#
#
#
#             var marker_57324a17832444b5663819a1515000ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f153cced6815ff642d91da99cc871bea);
#
#
#         var popup_3f6debff11bf78203f05eb75a2761e89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8261958d9476ac36531d8edae7a4a42a = $(`&lt;div id=&quot;html_8261958d9476ac36531d8edae7a4a42a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3f6debff11bf78203f05eb75a2761e89.setContent(html_8261958d9476ac36531d8edae7a4a42a);
#
#
#
#         marker_57324a17832444b5663819a1515000ae.bindPopup(popup_3f6debff11bf78203f05eb75a2761e89)
#         ;
#
#
#
#
#             var marker_b2fe8a190b1dbefdc40d2082498bacad = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f153cced6815ff642d91da99cc871bea);
#
#
#         var popup_481cdd036a8cf6a658713cb66021f7ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d51f703a31bad6fe36c3998b5597b326 = $(`&lt;div id=&quot;html_d51f703a31bad6fe36c3998b5597b326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_481cdd036a8cf6a658713cb66021f7ec.setContent(html_d51f703a31bad6fe36c3998b5597b326);
#
#
#
#         marker_b2fe8a190b1dbefdc40d2082498bacad.bindPopup(popup_481cdd036a8cf6a658713cb66021f7ec)
#         ;
#
#
#
#
#             var marker_033fdfba2a6cd24581d8a53de12627f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f153cced6815ff642d91da99cc871bea);
#
#
#         var popup_eab123dce617c94a66ce9c6f11878233 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01ac40d95461861b9773c1b97e789a86 = $(`&lt;div id=&quot;html_01ac40d95461861b9773c1b97e789a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eab123dce617c94a66ce9c6f11878233.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ea39d70011e3c9ea61111864b844182 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ea39d70011e3c9ea61111864b844182&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ea39d70011e3c9ea61111864b844182 = L.map(
#                 &quot;map_7ea39d70011e3c9ea61111864b844182&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_702a24be2b85daa06aaecf323c27b24d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_702a24be2b85daa06aaecf323c27b24d.addTo(map_7ea39d70011e3c9ea61111864b844182);
#
#
#             var feature_group_a6d3245f0183c0ce6e7c464e11c1ebe2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e1f05b30686ec064ed922997808a6e72 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a6d3245f0183c0ce6e7c464e11c1ebe2);
#
#
#         var popup_80e937fb3a7a5a08605c6b9b9284be6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f00ad76d9fb898a3acbad2b7b1e799c = $(`&lt;div id=&quot;html_7f00ad76d9fb898a3acbad2b7b1e799c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_80e937fb3a7a5a08605c6b9b9284be6d.setContent(html_7f00ad76d9fb898a3acbad2b7b1e799c);
#
#
#
#         marker_e1f05b30686ec064ed922997808a6e72.bindPopup(popup_80e937fb3a7a5a08605c6b9b9284be6d)
#         ;
#
#
#
#
#             var marker_c7d15ba50670520309938ac30f26c58e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a6d3245f0183c0ce6e7c464e11c1ebe2);
#
#
#         var popup_324d7de852fc09c89c2c2915526fbdb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f02f6badc0d68e1dfa1908d89d60207 = $(`&lt;div id=&quot;html_4f02f6badc0d68e1dfa1908d89d60207&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_324d7de852fc09c89c2c2915526fbdb5.setContent(html_4f02f6badc0d68e1dfa1908d89d60207);
#
#
#
#         marker_c7d15ba50670520309938ac30f26c58e.bindPopup(popup_324d7de852fc09c89c2c2915526fbdb5)
#         ;
#
#
#
#
#             var marker_9e6e553a934ad728f6502c9c741b4644 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a6d3245f0183c0ce6e7c464e11c1ebe2);
#
#
#         var popup_214fda2c04bee580a94e7ba520cebbf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e5d0d7ad594b7f1bddd30f6e7d3521c = $(`&lt;div id=&quot;html_8e5d0d7ad594b7f1bddd30f6e7d3521c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_214fda2c04bee580a94e7ba520cebbf0.setContent(html_8e5d0d7ad594b7f1bddd30f6e7d3521c);
#
#
#
#         marker_9e6e553a934ad728f6502c9c741b4644.bindPopup(popup_214fda2c04bee580a94e7ba520cebbf0)
#         ;
#
#
#
#
#             var marker_3a56b9a633ea4118fd31a6bed4729d5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a6d3245f0183c0ce6e7c464e11c1ebe2);
#
#
#         var popup_3eb9bc3fef14045e151a9911f3b48e15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_873d75e8d60c5b480a2840eaa534d35c = $(`&lt;div id=&quot;html_873d75e8d60c5b480a2840eaa534d35c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3eb9bc3fef14045e151a9911f3b48e15.setContent(html_873d75e8d60c5b480a2840eaa534d35c);
#
#
#
#         marker_3a56b9a633ea4118fd31a6bed4729d5d.bindPopup(popup_3eb9bc3fef14045e151a9911f3b48e15)
#         ;
#
#
#
#
#             var marker_d07018f479a7bdb64aed0904d63099d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a6d3245f0183c0ce6e7c464e11c1ebe2);
#
#
#         var popup_c77771b4b61dac25aa0173a1be21af25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4493f0673fb11ff66d79bc2118045a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4493f0673fb11ff66d79bc2118045a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4493f0673fb11ff66d79bc2118045a1 = L.map(
#                 &quot;map_a4493f0673fb11ff66d79bc2118045a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52971e1543eb47f6490f4aba98cd0d8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52971e1543eb47f6490f4aba98cd0d8d.addTo(map_a4493f0673fb11ff66d79bc2118045a1);
#
#
#             var feature_group_5ac48abd7612973f70269226b2ac40ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5ac48abd7612973f70269226b2ac40ee.addTo(map_a4493f0673fb11ff66d79bc2118045a1);
#
#
#             var feature_group_sub_group_597de0b6ce63820f840b316efd78ec07 = L.featureGroup.subGroup(
#                 feature_group_5ac48abd7612973f70269226b2ac40ee
#             );
#
#
#             var marker_924d5959c6994009ab378af532fa2dc6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_597de0b6ce63820f840b316efd78ec07);
#
#
#         var popup_e9fb7216dc6920f434d8ad77bf8f87f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d6a3d5b1e21ee55c67f039ef490fc67 = $(`&lt;div id=&quot;html_3d6a3d5b1e21ee55c67f039ef490fc67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e9fb7216dc6920f434d8ad77bf8f87f4.setContent(html_3d6a3d5b1e21ee55c67f039ef490fc67);
#
#
#
#         marker_924d5959c6994009ab378af532fa2dc6.bindPopup(popup_e9fb7216dc6920f434d8ad77bf8f87f4)
#         ;
#
#
#
#
#             var marker_b592c1ae29f948281b9d097d40440fea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_597de0b6ce63820f840b316efd78ec07);
#
#
#         var popup_e380a941c41f9337ab27ec7e130b8723 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddb7c4d6700a36d31d1527641b2b1b25 = $(`&lt;div id=&quot;html_ddb7c4d6700a36d31d1527641b2b1b25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e380a941c41f9337ab27ec7e130b8723.setContent(html_ddb7c4d6700a36d31d1527641b2b1b25);
#
#
#
#         marker_b592c1ae29f948281b9d097d40440fea.bindPopup(popup_e380a941c41f9337ab27ec7e130b8723)
#         ;
#
#
#
#
#             var marker_a9c74713a8928b9ba95ae72e4ba78c8d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_597de0b6ce63820f840b316efd78ec07);
#
#
#         var popup_4d9c25620da7d5a4b6b47d1d65c5376d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec80a71f7d41e88d163c60ad84c2cfac = $(`&lt;div id=&quot;html_ec80a71f7d41e88d163c60ad84c2cfac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4d9c25620da7d5a4b6b47d1d65c5376d.setContent(html_ec80a71f7d41e88d163c60ad84c2cfac);
#
#
#
#         marker_a9c74713a8928b9ba95ae72e4ba78c8d.bindPopup(popup_4d9c25620da7d5a4b6b47d1d65c5376d)
#         ;
#
#
#
#
#             var marker_50be3ecb733b0241d3060c3d1dbf5e43 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_597de0b6ce63820f840b316efd78ec07);
#
#
#         var popup_a6505ec88da1729c1e6e8c7e65e41dc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_764849d251b55acf3570d32dd774ae06 = $(`&lt;div id=&quot;html_764849d251b55acf3570d32dd774ae06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a6505ec88da1729c1e6e8c7e65e41dc8.setContent(html_764849d251b55acf3570d32dd774ae06);
#
#
#
#         marker_
