# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d44051385a5aab71a4dd47124c500488 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d44051385a5aab71a4dd47124c500488&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d44051385a5aab71a4dd47124c500488 = L.map(
#                 &quot;map_d44051385a5aab71a4dd47124c500488&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a8dd686c07c07a8214720422adf0971 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a8dd686c07c07a8214720422adf0971.addTo(map_d44051385a5aab71a4dd47124c500488);
#
#
#             var marker_d5089651657012acf66d157e1e2c9d3c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d44051385a5aab71a4dd47124c500488);
#
#
#         var popup_8ff1596580ddae01cba6a721870e6b75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_572eedeed407806d44433444b99e03d3 = $(`&lt;div id=&quot;html_572eedeed407806d44433444b99e03d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8ff1596580ddae01cba6a721870e6b75.setContent(html_572eedeed407806d44433444b99e03d3);
#
#
#
#         marker_d5089651657012acf66d157e1e2c9d3c.bindPopup(popup_8ff1596580ddae01cba6a721870e6b75)
#         ;
#
#
#
#
#             var marker_a2c8030bd838b391f77ec5ee48dcd8be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d44051385a5aab71a4dd47124c500488);
#
#
#         var popup_da39f7b91ab4088138a8628500440cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bc3b11b7d6dd11f52bcfb43fb0de3eb = $(`&lt;div id=&quot;html_8bc3b11b7d6dd11f52bcfb43fb0de3eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_da39f7b91ab4088138a8628500440cb7.setContent(html_8bc3b11b7d6dd11f52bcfb43fb0de3eb);
#
#
#
#         marker_a2c8030bd838b391f77ec5ee48dcd8be.bindPopup(popup_da39f7b91ab4088138a8628500440cb7)
#         ;
#
#
#
#
#             var marker_3bdbbf4c7320e6f86dbea2caf3b925ab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d44051385a5aab71a4dd47124c500488);
#
#
#         var popup_74dd40aebee6338881574d07fa8d433c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54d82b23f95bd42cd2b64d2ad8721a64 = $(`&lt;div id=&quot;html_54d82b23f95bd42cd2b64d2ad8721a64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_74dd40aebee6338881574d07fa8d433c.setContent(html_54d82b23f95bd42cd2b64d2ad8721a64);
#
#
#
#         marker_3bdbbf4c7320e6f86dbea2caf3b925ab.bindPopup(popup_74dd40aebee6338881574d07fa8d433c)
#         ;
#
#
#
#
#             var marker_30e4444a9b88d4003a642d15628e8574 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d44051385a5aab71a4dd47124c500488);
#
#
#         var popup_907cb796c5e6e68a6dab829a55f47b9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ec81847e8db3ddabd7451eea8ccb236 = $(`&lt;div id=&quot;html_1ec81847e8db3ddabd7451eea8ccb236&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_907cb796c5e6e68a6dab829a55f47b9b.setContent(html_1ec81847e8db3ddabd7451eea8ccb236);
#
#
#
#         marker_30e4444a9b88d4003a642d15628e8574.bindPopup(popup_907cb796c5e6e68a6dab829a55f47b9b)
#         ;
#
#
#
#
#             var marker_d5af0e43c2e930a2f7ce5821f6fef8b4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d44051385a5aab71a4dd47124c500488);
#
#
#         var popup_d5793ccf425a90704ec8dd8eb971343f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eb23839552bf31a383a6f3a09fd8f33 = $(`&lt;div id=&quot;html_2eb23839552bf31a383a6f3a09fd8f33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d5793ccf425a90704ec8dd8eb971343f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3933fa6b95d979ec571a6e354e84c277 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3933fa6b95d979ec571a6e354e84c277&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3933fa6b95d979ec571a6e354e84c277 = L.map(
#                 &quot;map_3933fa6b95d979ec571a6e354e84c277&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddd649bb4eeda42e35be356cb653ac30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ddd649bb4eeda42e35be356cb653ac30.addTo(map_3933fa6b95d979ec571a6e354e84c277);
#
#
#             var feature_group_d18138723c6dcee1c05627a0725255ce = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e3298274651e53adde6de9e8df40c33b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d18138723c6dcee1c05627a0725255ce);
#
#
#         var popup_da4b30ab8e8fc109e7a8302358fb72f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494e5b8b7779d6ac2452d983e13517ac = $(`&lt;div id=&quot;html_494e5b8b7779d6ac2452d983e13517ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_da4b30ab8e8fc109e7a8302358fb72f5.setContent(html_494e5b8b7779d6ac2452d983e13517ac);
#
#
#
#         marker_e3298274651e53adde6de9e8df40c33b.bindPopup(popup_da4b30ab8e8fc109e7a8302358fb72f5)
#         ;
#
#
#
#
#             var marker_e697edff2c5b08e3cb78ba97361ff068 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d18138723c6dcee1c05627a0725255ce);
#
#
#         var popup_f77b961d8f17382354ba9bc1d2cf0257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08eae32965a60bd87bdf2def4633e538 = $(`&lt;div id=&quot;html_08eae32965a60bd87bdf2def4633e538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f77b961d8f17382354ba9bc1d2cf0257.setContent(html_08eae32965a60bd87bdf2def4633e538);
#
#
#
#         marker_e697edff2c5b08e3cb78ba97361ff068.bindPopup(popup_f77b961d8f17382354ba9bc1d2cf0257)
#         ;
#
#
#
#
#             var marker_e0b43130ad8eab77f07bd40a9ac3a101 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d18138723c6dcee1c05627a0725255ce);
#
#
#         var popup_2cbe1d56f313dac85d0a6d5e1c8b216b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d50d97402f43d1096fbddb834e7b141f = $(`&lt;div id=&quot;html_d50d97402f43d1096fbddb834e7b141f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2cbe1d56f313dac85d0a6d5e1c8b216b.setContent(html_d50d97402f43d1096fbddb834e7b141f);
#
#
#
#         marker_e0b43130ad8eab77f07bd40a9ac3a101.bindPopup(popup_2cbe1d56f313dac85d0a6d5e1c8b216b)
#         ;
#
#
#
#
#             var marker_70f3d3f73df36e36f454dcbde937cd31 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d18138723c6dcee1c05627a0725255ce);
#
#
#         var popup_059e77535956ae719c373f016d9b263c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ffbcab07e0eec2b152e35bc0e3e0814 = $(`&lt;div id=&quot;html_6ffbcab07e0eec2b152e35bc0e3e0814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_059e77535956ae719c373f016d9b263c.setContent(html_6ffbcab07e0eec2b152e35bc0e3e0814);
#
#
#
#         marker_70f3d3f73df36e36f454dcbde937cd31.bindPopup(popup_059e77535956ae719c373f016d9b263c)
#         ;
#
#
#
#
#             var marker_ee3e751e089e40967f35667df248ec82 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d18138723c6dcee1c05627a0725255ce);
#
#
#         var popup_d0482e3988758c01841c9ebb686c1920 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65e99eb8ac637fe9d11a884415cb9f70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65e99eb8ac637fe9d11a884415cb9f70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65e99eb8ac637fe9d11a884415cb9f70 = L.map(
#                 &quot;map_65e99eb8ac637fe9d11a884415cb9f70&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7361e909449ce0b956d04219cd53afd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a7361e909449ce0b956d04219cd53afd.addTo(map_65e99eb8ac637fe9d11a884415cb9f70);
#
#
#             var feature_group_9247a76536ce4ceec1cfc2ce9f5191dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9247a76536ce4ceec1cfc2ce9f5191dc.addTo(map_65e99eb8ac637fe9d11a884415cb9f70);
#
#
#             var feature_group_sub_group_9a6143472e4d1433eb0af0b35cb55321 = L.featureGroup.subGroup(
#                 feature_group_9247a76536ce4ceec1cfc2ce9f5191dc
#             );
#
#
#             var marker_3e4eabea30ce687ee428323e0b69ba00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6143472e4d1433eb0af0b35cb55321);
#
#
#         var popup_ebb75c04562297cee265cc6bb18e307b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e3986695225e999c97e7ec6292276c4 = $(`&lt;div id=&quot;html_7e3986695225e999c97e7ec6292276c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ebb75c04562297cee265cc6bb18e307b.setContent(html_7e3986695225e999c97e7ec6292276c4);
#
#
#
#         marker_3e4eabea30ce687ee428323e0b69ba00.bindPopup(popup_ebb75c04562297cee265cc6bb18e307b)
#         ;
#
#
#
#
#             var marker_cb53b73c65be8a0b91802ed255870941 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6143472e4d1433eb0af0b35cb55321);
#
#
#         var popup_e37618bec87fb27a7b4053a60d297de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06e6f018dc9fbcc042326087ca896bf4 = $(`&lt;div id=&quot;html_06e6f018dc9fbcc042326087ca896bf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e37618bec87fb27a7b4053a60d297de3.setContent(html_06e6f018dc9fbcc042326087ca896bf4);
#
#
#
#         marker_cb53b73c65be8a0b91802ed255870941.bindPopup(popup_e37618bec87fb27a7b4053a60d297de3)
#         ;
#
#
#
#
#             var marker_f07f189e63d05ff747af982213b25a6f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6143472e4d1433eb0af0b35cb55321);
#
#
#         var popup_b47be54ae09893ae4c137276dd8a4738 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a19d1b24deb48db1ab90af1d9a2b373 = $(`&lt;div id=&quot;html_4a19d1b24deb48db1ab90af1d9a2b373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b47be54ae09893ae4c137276dd8a4738.setContent(html_4a19d1b24deb48db1ab90af1d9a2b373);
#
#
#
#         marker_f07f189e63d05ff747af982213b25a6f.bindPopup(popup_b47be54ae09893ae4c137276dd8a4738)
#         ;
#
#
#
#
#             var marker_31d480ec0f422a88b65c922d665f6c21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a6143472e4d1433eb0af0b35cb55321);
#
#
#         var popup_47c77e76436397edfaa038b48250931f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef04070a37ab992fa9f9024e957e7bd5 = $(`&lt;div id=&quot;html_ef04070a37ab992fa9f9024e957e7bd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_47c77e76436397edfaa038b48250931f.setContent(html_ef04070a37ab992fa9f9024e957e7bd5);
#
#
#
#         marker_
