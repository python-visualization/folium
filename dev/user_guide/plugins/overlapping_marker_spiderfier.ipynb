# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c842383de65d4d940dbf9c08ebf60310 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c842383de65d4d940dbf9c08ebf60310&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c842383de65d4d940dbf9c08ebf60310 = L.map(
#                 &quot;map_c842383de65d4d940dbf9c08ebf60310&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c6a714655f41cb7e23f8b2f8ff80e4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c6a714655f41cb7e23f8b2f8ff80e4a.addTo(map_c842383de65d4d940dbf9c08ebf60310);
#
#
#             var marker_c6ddd8fd803bc639e0de793a6cbd487c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c842383de65d4d940dbf9c08ebf60310);
#
#
#         var popup_8dc3e3e1ecd3bf06972719e62e23226a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afd73fa05e0cd4c5b855ab3d928de099 = $(`&lt;div id=&quot;html_afd73fa05e0cd4c5b855ab3d928de099&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8dc3e3e1ecd3bf06972719e62e23226a.setContent(html_afd73fa05e0cd4c5b855ab3d928de099);
#
#
#
#         marker_c6ddd8fd803bc639e0de793a6cbd487c.bindPopup(popup_8dc3e3e1ecd3bf06972719e62e23226a)
#         ;
#
#
#
#
#             var marker_d550f1735d50dd305ce1acccb5263aff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c842383de65d4d940dbf9c08ebf60310);
#
#
#         var popup_702f6a0fa215498f938c887e3b45a69b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_207873ef7d96847d992848d9de1203ef = $(`&lt;div id=&quot;html_207873ef7d96847d992848d9de1203ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_702f6a0fa215498f938c887e3b45a69b.setContent(html_207873ef7d96847d992848d9de1203ef);
#
#
#
#         marker_d550f1735d50dd305ce1acccb5263aff.bindPopup(popup_702f6a0fa215498f938c887e3b45a69b)
#         ;
#
#
#
#
#             var marker_66bfe9e43e0de31250ce7a6992de304d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c842383de65d4d940dbf9c08ebf60310);
#
#
#         var popup_3726868f5a4596a8f53802746081d800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3aebbdb897afd3de166805a1ac6deba2 = $(`&lt;div id=&quot;html_3aebbdb897afd3de166805a1ac6deba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3726868f5a4596a8f53802746081d800.setContent(html_3aebbdb897afd3de166805a1ac6deba2);
#
#
#
#         marker_66bfe9e43e0de31250ce7a6992de304d.bindPopup(popup_3726868f5a4596a8f53802746081d800)
#         ;
#
#
#
#
#             var marker_fa20215c23881923614170919e7b8cbc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c842383de65d4d940dbf9c08ebf60310);
#
#
#         var popup_9f7d6117f568a2d40d1f3fd2154aa281 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a650e0f35adfa5bb75a4c6130221196 = $(`&lt;div id=&quot;html_7a650e0f35adfa5bb75a4c6130221196&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9f7d6117f568a2d40d1f3fd2154aa281.setContent(html_7a650e0f35adfa5bb75a4c6130221196);
#
#
#
#         marker_fa20215c23881923614170919e7b8cbc.bindPopup(popup_9f7d6117f568a2d40d1f3fd2154aa281)
#         ;
#
#
#
#
#             var marker_6691643848ee7843426650880237bc02 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c842383de65d4d940dbf9c08ebf60310);
#
#
#         var popup_9753e40f726ead97cd0acc5c073c29bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5d07441fa17cc8f814caeb14ce5bcce = $(`&lt;div id=&quot;html_d5d07441fa17cc8f814caeb14ce5bcce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9753e40f726ead97cd0acc5c073c29bc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3b10bb435d8641f90308f3e2eccec96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3b10bb435d8641f90308f3e2eccec96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3b10bb435d8641f90308f3e2eccec96 = L.map(
#                 &quot;map_b3b10bb435d8641f90308f3e2eccec96&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c8968994e7825a64a81b79df3567ce1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c8968994e7825a64a81b79df3567ce1.addTo(map_b3b10bb435d8641f90308f3e2eccec96);
#
#
#             var feature_group_3d47e8d652ab1cfd35be3b497de989cd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fbaac2df78b7ff000b2ec5add676a0d0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d47e8d652ab1cfd35be3b497de989cd);
#
#
#         var popup_b593781ad0c6c5ca17c3f54628b99007 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e11ec9988f2d26cf5adfe78e8e662f83 = $(`&lt;div id=&quot;html_e11ec9988f2d26cf5adfe78e8e662f83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b593781ad0c6c5ca17c3f54628b99007.setContent(html_e11ec9988f2d26cf5adfe78e8e662f83);
#
#
#
#         marker_fbaac2df78b7ff000b2ec5add676a0d0.bindPopup(popup_b593781ad0c6c5ca17c3f54628b99007)
#         ;
#
#
#
#
#             var marker_dcfaa08b2dfb1bc40dc5d0166b8f5b2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d47e8d652ab1cfd35be3b497de989cd);
#
#
#         var popup_ca87466163252f79e46454f383c5a768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcd4f9f25737c59df887de861ffe7f35 = $(`&lt;div id=&quot;html_bcd4f9f25737c59df887de861ffe7f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ca87466163252f79e46454f383c5a768.setContent(html_bcd4f9f25737c59df887de861ffe7f35);
#
#
#
#         marker_dcfaa08b2dfb1bc40dc5d0166b8f5b2a.bindPopup(popup_ca87466163252f79e46454f383c5a768)
#         ;
#
#
#
#
#             var marker_2e767957c46708afcd6159f8cd645df2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d47e8d652ab1cfd35be3b497de989cd);
#
#
#         var popup_25be32f2aa02a4f2e56e1c4cc33eaa4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48ada01f04822a7ac2d55aa35113c3b9 = $(`&lt;div id=&quot;html_48ada01f04822a7ac2d55aa35113c3b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_25be32f2aa02a4f2e56e1c4cc33eaa4a.setContent(html_48ada01f04822a7ac2d55aa35113c3b9);
#
#
#
#         marker_2e767957c46708afcd6159f8cd645df2.bindPopup(popup_25be32f2aa02a4f2e56e1c4cc33eaa4a)
#         ;
#
#
#
#
#             var marker_868c0f02136c2d7a9deb462d9e2c78d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d47e8d652ab1cfd35be3b497de989cd);
#
#
#         var popup_c94bb5082502d37e022e7b1c5afbfe49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60cff5a6263a203789293135b683cc08 = $(`&lt;div id=&quot;html_60cff5a6263a203789293135b683cc08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c94bb5082502d37e022e7b1c5afbfe49.setContent(html_60cff5a6263a203789293135b683cc08);
#
#
#
#         marker_868c0f02136c2d7a9deb462d9e2c78d2.bindPopup(popup_c94bb5082502d37e022e7b1c5afbfe49)
#         ;
#
#
#
#
#             var marker_ab846efde0215f06aa2927b11537e09f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d47e8d652ab1cfd35be3b497de989cd);
#
#
#         var popup_22d3a3e899c20fb7ec239c345659e202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f23c501aa9a63b5269fe209df7b1510 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f23c501aa9a63b5269fe209df7b1510&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f23c501aa9a63b5269fe209df7b1510 = L.map(
#                 &quot;map_3f23c501aa9a63b5269fe209df7b1510&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_784dbd75ccac0e36364a0e1cc34fa906 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_784dbd75ccac0e36364a0e1cc34fa906.addTo(map_3f23c501aa9a63b5269fe209df7b1510);
#
#
#             var feature_group_af831054d359b443fe3a83a77c1a320e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_af831054d359b443fe3a83a77c1a320e.addTo(map_3f23c501aa9a63b5269fe209df7b1510);
#
#
#             var feature_group_sub_group_66aad743c21192450754525cd74a0934 = L.featureGroup.subGroup(
#                 feature_group_af831054d359b443fe3a83a77c1a320e
#             );
#
#
#             var marker_bf58fb695600b83b4346826470ffcace = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_66aad743c21192450754525cd74a0934);
#
#
#         var popup_db3fd654a0f13388a37a44dbdbfd5c1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2431b38c31a64056d76a3a4aca338aa3 = $(`&lt;div id=&quot;html_2431b38c31a64056d76a3a4aca338aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_db3fd654a0f13388a37a44dbdbfd5c1d.setContent(html_2431b38c31a64056d76a3a4aca338aa3);
#
#
#
#         marker_bf58fb695600b83b4346826470ffcace.bindPopup(popup_db3fd654a0f13388a37a44dbdbfd5c1d)
#         ;
#
#
#
#
#             var marker_d0c82335437338cf63f6a7e65055aea1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_66aad743c21192450754525cd74a0934);
#
#
#         var popup_b6801383344135d720984b99c5abd309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e507a04227749f00e7121283399d27b3 = $(`&lt;div id=&quot;html_e507a04227749f00e7121283399d27b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b6801383344135d720984b99c5abd309.setContent(html_e507a04227749f00e7121283399d27b3);
#
#
#
#         marker_d0c82335437338cf63f6a7e65055aea1.bindPopup(popup_b6801383344135d720984b99c5abd309)
#         ;
#
#
#
#
#             var marker_fee7123f88a484b8b10209d96d884c10 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_66aad743c21192450754525cd74a0934);
#
#
#         var popup_573c3b7521a471abef1152132b942435 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da56710e2f36378a42042dd3037707bb = $(`&lt;div id=&quot;html_da56710e2f36378a42042dd3037707bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_573c3b7521a471abef1152132b942435.setContent(html_da56710e2f36378a42042dd3037707bb);
#
#
#
#         marker_fee7123f88a484b8b10209d96d884c10.bindPopup(popup_573c3b7521a471abef1152132b942435)
#         ;
#
#
#
#
#             var marker_48bfe3ff5c0c4facc36c8daaba6faddb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_66aad743c21192450754525cd74a0934);
#
#
#         var popup_de67706934eb1f63b2813a4c76a07015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0870a41b9fe6c4f208b7e69c377c23a9 = $(`&lt;div id=&quot;html_0870a41b9fe6c4f208b7e69c377c23a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_de67706934eb1f63b2813a4c76a07015.setContent(html_0870a41b9fe6c4f208b7e69c377c23a9);
#
#
#
#         marker_
