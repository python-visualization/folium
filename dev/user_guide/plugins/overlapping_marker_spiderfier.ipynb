# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5efa738917c31d1569563bb5f9c2ef0d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5efa738917c31d1569563bb5f9c2ef0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5efa738917c31d1569563bb5f9c2ef0d = L.map(
#                 &quot;map_5efa738917c31d1569563bb5f9c2ef0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73fa6a1fd049bf6ff9dcfd4a0f3d8b47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73fa6a1fd049bf6ff9dcfd4a0f3d8b47.addTo(map_5efa738917c31d1569563bb5f9c2ef0d);
#
#
#             var marker_70b48709cdbc507b6dfe79ff3e9c915c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5efa738917c31d1569563bb5f9c2ef0d);
#
#
#         var popup_ed74035af0b20d669ef244ed068e1a34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b9703880748330c251a4b0fb968505f = $(`&lt;div id=&quot;html_6b9703880748330c251a4b0fb968505f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ed74035af0b20d669ef244ed068e1a34.setContent(html_6b9703880748330c251a4b0fb968505f);
#
#
#
#         marker_70b48709cdbc507b6dfe79ff3e9c915c.bindPopup(popup_ed74035af0b20d669ef244ed068e1a34)
#         ;
#
#
#
#
#             var marker_f5f2a4caeb255713d1aae788a70b5c98 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5efa738917c31d1569563bb5f9c2ef0d);
#
#
#         var popup_98e206b6ad486523eb13515cfe056978 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c80f28cd48286e26610ca4fa526da5cc = $(`&lt;div id=&quot;html_c80f28cd48286e26610ca4fa526da5cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_98e206b6ad486523eb13515cfe056978.setContent(html_c80f28cd48286e26610ca4fa526da5cc);
#
#
#
#         marker_f5f2a4caeb255713d1aae788a70b5c98.bindPopup(popup_98e206b6ad486523eb13515cfe056978)
#         ;
#
#
#
#
#             var marker_272fdbe3d8fd58d72dc3977f9415e422 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5efa738917c31d1569563bb5f9c2ef0d);
#
#
#         var popup_c72fd328befbcb21f37985434a66b2cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed59be5350334f1eba654e3c4d576f06 = $(`&lt;div id=&quot;html_ed59be5350334f1eba654e3c4d576f06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c72fd328befbcb21f37985434a66b2cb.setContent(html_ed59be5350334f1eba654e3c4d576f06);
#
#
#
#         marker_272fdbe3d8fd58d72dc3977f9415e422.bindPopup(popup_c72fd328befbcb21f37985434a66b2cb)
#         ;
#
#
#
#
#             var marker_7a4b9df5258eed7904796f009747191c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5efa738917c31d1569563bb5f9c2ef0d);
#
#
#         var popup_d7d524456acf5b8e9bb685755e33ca3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_415a0946cd0048664c680fcc08e7ab59 = $(`&lt;div id=&quot;html_415a0946cd0048664c680fcc08e7ab59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d7d524456acf5b8e9bb685755e33ca3b.setContent(html_415a0946cd0048664c680fcc08e7ab59);
#
#
#
#         marker_7a4b9df5258eed7904796f009747191c.bindPopup(popup_d7d524456acf5b8e9bb685755e33ca3b)
#         ;
#
#
#
#
#             var marker_763c7c80b923f1737888263fb47094bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5efa738917c31d1569563bb5f9c2ef0d);
#
#
#         var popup_aabb09ab2aa73c6ee83b1f210820c4e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_631d3427a8fb57d0db4a94dcb9081ee8 = $(`&lt;div id=&quot;html_631d3427a8fb57d0db4a94dcb9081ee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aabb09ab2aa73c6ee83b1f210820c4e6.setContent(html_631d3427a8fb57d0db4a94dcb9081ee8);
#
#
#
#         marker_763c7c80b923f1737888263fb47094bc.bindPopup(popup_aabb09ab2aa73c6ee83b1f210820c4e6)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e34cf561a0826e8b3c8b0132a6e999ac {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e34cf561a0826e8b3c8b0132a6e999ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e34cf561a0826e8b3c8b0132a6e999ac = L.map(
#                 &quot;map_e34cf561a0826e8b3c8b0132a6e999ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1550d7a9a2d0cdc8695f9a04d359b2f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1550d7a9a2d0cdc8695f9a04d359b2f2.addTo(map_e34cf561a0826e8b3c8b0132a6e999ac);
#
#
#             var feature_group_a2868d1688486e54292ad565b79549b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c9e3d0beb603612e99cf4d0cbfa49f97 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a2868d1688486e54292ad565b79549b1);
#
#
#         var popup_b0291915a8d83b708557843ae9a1483c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32f0e3a27fe17894113ecbe14166ca65 = $(`&lt;div id=&quot;html_32f0e3a27fe17894113ecbe14166ca65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b0291915a8d83b708557843ae9a1483c.setContent(html_32f0e3a27fe17894113ecbe14166ca65);
#
#
#
#         marker_c9e3d0beb603612e99cf4d0cbfa49f97.bindPopup(popup_b0291915a8d83b708557843ae9a1483c)
#         ;
#
#
#
#
#             var marker_c5d9ab64cd8bd90ead62d3545bfee7de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a2868d1688486e54292ad565b79549b1);
#
#
#         var popup_0ab4551ca4c750fa92876fbc324f6812 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e30d9dcfde4a887c8b4b727b3419c36 = $(`&lt;div id=&quot;html_6e30d9dcfde4a887c8b4b727b3419c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0ab4551ca4c750fa92876fbc324f6812.setContent(html_6e30d9dcfde4a887c8b4b727b3419c36);
#
#
#
#         marker_c5d9ab64cd8bd90ead62d3545bfee7de.bindPopup(popup_0ab4551ca4c750fa92876fbc324f6812)
#         ;
#
#
#
#
#             var marker_db9a2c3f59427bd415ab253bd1a5f807 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a2868d1688486e54292ad565b79549b1);
#
#
#         var popup_2d9a64e1513ff7405ee021d7825558c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e451217ac49f20470876d5a42d8c1a86 = $(`&lt;div id=&quot;html_e451217ac49f20470876d5a42d8c1a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2d9a64e1513ff7405ee021d7825558c8.setContent(html_e451217ac49f20470876d5a42d8c1a86);
#
#
#
#         marker_db9a2c3f59427bd415ab253bd1a5f807.bindPopup(popup_2d9a64e1513ff7405ee021d7825558c8)
#         ;
#
#
#
#
#             var marker_78cfadd19853084dcfbcb78239828a17 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a2868d1688486e54292ad565b79549b1);
#
#
#         var popup_12cf5b1149a9ea06424b56197ab4df02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b697a9c15c4d89a4a00094e85a37922b = $(`&lt;div id=&quot;html_b697a9c15c4d89a4a00094e85a37922b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_12cf5b1149a9ea06424b56197ab4df02.setContent(html_b697a9c15c4d89a4a00094e85a37922b);
#
#
#
#         marker_78cfadd19853084dcfbcb78239828a17.bindPopup(popup_12cf5b1149a9ea06424b56197ab4df02)
#         ;
#
#
#
#
#             var marker_e08f368859e3a27302753b4e88f82d2b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a2868d1688486e54292ad565b79549b1);
#
#
#         var popup_bf1a3335b856d039e6c1603d3ec65bbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ad8a8cccd218ec47da397685a1da5ad = $(`&lt;div id=&quot;html_1ad8a8cccd218ec47da397685a1da5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15b56c89e1df038c361fa70ffd645d00 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15b56c89e1df038c361fa70ffd645d00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15b56c89e1df038c361fa70ffd645d00 = L.map(
#                 &quot;map_15b56c89e1df038c361fa70ffd645d00&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1bf665783785f42a08fa2ab4c33d562 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1bf665783785f42a08fa2ab4c33d562.addTo(map_15b56c89e1df038c361fa70ffd645d00);
#
#
#             var feature_group_81987d0d43246e12142cfa2ba1f7ebf5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_81987d0d43246e12142cfa2ba1f7ebf5.addTo(map_15b56c89e1df038c361fa70ffd645d00);
#
#
#             var feature_group_sub_group_0a341ce98e843027c856e184415baa81 = L.featureGroup.subGroup(
#                 feature_group_81987d0d43246e12142cfa2ba1f7ebf5
#             );
#
#
#             var marker_8f46a2234f5dfebbff0ce1566273591b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0a341ce98e843027c856e184415baa81);
#
#
#         var popup_1094857794e0ccd32dbba0e225ca3c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20f9caf8e8b56a2a03e203d8a07aa8a2 = $(`&lt;div id=&quot;html_20f9caf8e8b56a2a03e203d8a07aa8a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1094857794e0ccd32dbba0e225ca3c01.setContent(html_20f9caf8e8b56a2a03e203d8a07aa8a2);
#
#
#
#         marker_8f46a2234f5dfebbff0ce1566273591b.bindPopup(popup_1094857794e0ccd32dbba0e225ca3c01)
#         ;
#
#
#
#
#             var marker_2c049c1019383e7aacf4610654794602 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0a341ce98e843027c856e184415baa81);
#
#
#         var popup_4e8cc432a1d0f6cc94315f1573a58add = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5346e36a1ffc3983c3c329c2c0900f86 = $(`&lt;div id=&quot;html_5346e36a1ffc3983c3c329c2c0900f86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4e8cc432a1d0f6cc94315f1573a58add.setContent(html_5346e36a1ffc3983c3c329c2c0900f86);
#
#
#
#         marker_2c049c1019383e7aacf4610654794602.bindPopup(popup_4e8cc432a1d0f6cc94315f1573a58add)
#         ;
#
#
#
#
#             var marker_342923d144999024195a3e1b86a5c750 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0a341ce98e843027c856e184415baa81);
#
#
#         var popup_a89becdacdb2099d56326ee4a903f107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5822cd0dd8c01eb57abcb6597776d1a = $(`&lt;div id=&quot;html_f5822cd0dd8c01eb57abcb6597776d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a89becdacdb2099d56326ee4a903f107.setContent(html_f5822cd0dd8c01eb57abcb6597776d1a);
#
#
#
#         marker_342923d144999024195a3e1b86a5c750.bindPopup(popup_a89becdacdb2099d56326ee4a903f107)
#         ;
#
#
#
#
#             var marker_97ce82cf1c281b2a8b8438b2b77c56e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0a341ce98e843027c856e184415baa81);
#
#
#         var popup_e06d5ac393a428e47c06b3a576c6220f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21bc9a3fee2b9a0c793bc947a8ddd62e = $(`&lt;div id=&quot;html_21bc9a3fee2b9a0c793bc947a8ddd62e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e06d5ac393a428e47c06b3a576c6220f.setContent(html_21bc9a3fee2b9a0c793bc947a8ddd62e);
#
#
#
#         marker_97ce82cf1c281b2a8b8438b2b77c56e0.bindPopup(popup_e06d5ac393a428e47c06b3a576c6220f)
#         ;
#
#
#
#
#             var marker_810a4fec5de5723ae1ab37c7f866eece = L.marker(
#                 [45.0503999
