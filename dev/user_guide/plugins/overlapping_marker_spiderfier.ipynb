# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_999775dc4c1ec81f099b1f42c3d792b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_999775dc4c1ec81f099b1f42c3d792b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_999775dc4c1ec81f099b1f42c3d792b8 = L.map(
#                 &quot;map_999775dc4c1ec81f099b1f42c3d792b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6621c0e26d748e2d90d153cfbc43dae0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6621c0e26d748e2d90d153cfbc43dae0.addTo(map_999775dc4c1ec81f099b1f42c3d792b8);
#
#
#             var marker_0c979395b5d70e27964782ce357d706a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_999775dc4c1ec81f099b1f42c3d792b8);
#
#
#         var popup_0fd690212f1311e2b1de5c2518b94651 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be2fd52d876c9b12b374c1957804b523 = $(`&lt;div id=&quot;html_be2fd52d876c9b12b374c1957804b523&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0fd690212f1311e2b1de5c2518b94651.setContent(html_be2fd52d876c9b12b374c1957804b523);
#
#
#
#         marker_0c979395b5d70e27964782ce357d706a.bindPopup(popup_0fd690212f1311e2b1de5c2518b94651)
#         ;
#
#
#
#
#             var marker_571f49981d17493de15a56af94480195 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_999775dc4c1ec81f099b1f42c3d792b8);
#
#
#         var popup_e1fe43cdf1aeda83104cbb0c559199b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29eca0c840828c26f42b0d9613a694fd = $(`&lt;div id=&quot;html_29eca0c840828c26f42b0d9613a694fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e1fe43cdf1aeda83104cbb0c559199b9.setContent(html_29eca0c840828c26f42b0d9613a694fd);
#
#
#
#         marker_571f49981d17493de15a56af94480195.bindPopup(popup_e1fe43cdf1aeda83104cbb0c559199b9)
#         ;
#
#
#
#
#             var marker_d8cb41da14493886e693dac40c108963 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_999775dc4c1ec81f099b1f42c3d792b8);
#
#
#         var popup_6d98c334031e06a366846d58fd558008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fac681ba853791fbc75f5e1b7ca34efd = $(`&lt;div id=&quot;html_fac681ba853791fbc75f5e1b7ca34efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6d98c334031e06a366846d58fd558008.setContent(html_fac681ba853791fbc75f5e1b7ca34efd);
#
#
#
#         marker_d8cb41da14493886e693dac40c108963.bindPopup(popup_6d98c334031e06a366846d58fd558008)
#         ;
#
#
#
#
#             var marker_4af7e383ef7fb6ab2e274a3ca34ec7d1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_999775dc4c1ec81f099b1f42c3d792b8);
#
#
#         var popup_1b5f5bdb74ee4267946f8b51bd85fa94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_063c6cf91129dcc659d8cb7cc56bc9d8 = $(`&lt;div id=&quot;html_063c6cf91129dcc659d8cb7cc56bc9d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1b5f5bdb74ee4267946f8b51bd85fa94.setContent(html_063c6cf91129dcc659d8cb7cc56bc9d8);
#
#
#
#         marker_4af7e383ef7fb6ab2e274a3ca34ec7d1.bindPopup(popup_1b5f5bdb74ee4267946f8b51bd85fa94)
#         ;
#
#
#
#
#             var marker_b3f0bb56d74181b86ded0a5abd2b4d7f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_999775dc4c1ec81f099b1f42c3d792b8);
#
#
#         var popup_f496e88c94e5ba4ce1115f674260b727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0730b5c3e81c2b71487276e795b8e09 = $(`&lt;div id=&quot;html_d0730b5c3e81c2b71487276e795b8e09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f496e88c94e5ba4ce1115f674260b727.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bde6d00da08bcaa43c74d859d43b6efd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bde6d00da08bcaa43c74d859d43b6efd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bde6d00da08bcaa43c74d859d43b6efd = L.map(
#                 &quot;map_bde6d00da08bcaa43c74d859d43b6efd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_740ba3fa9fa2adeb77231bd2a9d4f8ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_740ba3fa9fa2adeb77231bd2a9d4f8ca.addTo(map_bde6d00da08bcaa43c74d859d43b6efd);
#
#
#             var feature_group_2d787006758a90f911dd2b067f0d790c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6c537e2921e98e5dec119d61095fe7fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2d787006758a90f911dd2b067f0d790c);
#
#
#         var popup_905c98ad134d4569870cfe811e5147c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb8448c06d131106ccd533162c78bd93 = $(`&lt;div id=&quot;html_fb8448c06d131106ccd533162c78bd93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_905c98ad134d4569870cfe811e5147c9.setContent(html_fb8448c06d131106ccd533162c78bd93);
#
#
#
#         marker_6c537e2921e98e5dec119d61095fe7fe.bindPopup(popup_905c98ad134d4569870cfe811e5147c9)
#         ;
#
#
#
#
#             var marker_41fdc5749593af90440d1a60f74f5560 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2d787006758a90f911dd2b067f0d790c);
#
#
#         var popup_896a60379fbea22a4e0e940865bc778e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_196bcb932df6b14bb76ae0b16f3ea91a = $(`&lt;div id=&quot;html_196bcb932df6b14bb76ae0b16f3ea91a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_896a60379fbea22a4e0e940865bc778e.setContent(html_196bcb932df6b14bb76ae0b16f3ea91a);
#
#
#
#         marker_41fdc5749593af90440d1a60f74f5560.bindPopup(popup_896a60379fbea22a4e0e940865bc778e)
#         ;
#
#
#
#
#             var marker_9cc2f77d23ac029e5c1bb0bf253e8a73 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2d787006758a90f911dd2b067f0d790c);
#
#
#         var popup_803a07228e5960d7ee076086023da6b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2922ccaa793642e3af99909dc41113e9 = $(`&lt;div id=&quot;html_2922ccaa793642e3af99909dc41113e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_803a07228e5960d7ee076086023da6b9.setContent(html_2922ccaa793642e3af99909dc41113e9);
#
#
#
#         marker_9cc2f77d23ac029e5c1bb0bf253e8a73.bindPopup(popup_803a07228e5960d7ee076086023da6b9)
#         ;
#
#
#
#
#             var marker_918e2a5009f3a681077cdc5499b89b5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2d787006758a90f911dd2b067f0d790c);
#
#
#         var popup_820e1df4882d5a0a131a5bb7c7c1b0fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c7ab0e8e978a0b730dd9af71c416868 = $(`&lt;div id=&quot;html_3c7ab0e8e978a0b730dd9af71c416868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_820e1df4882d5a0a131a5bb7c7c1b0fd.setContent(html_3c7ab0e8e978a0b730dd9af71c416868);
#
#
#
#         marker_918e2a5009f3a681077cdc5499b89b5e.bindPopup(popup_820e1df4882d5a0a131a5bb7c7c1b0fd)
#         ;
#
#
#
#
#             var marker_474ed3be23183a0ad55a3c5bfb63d365 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2d787006758a90f911dd2b067f0d790c);
#
#
#         var popup_7f53b489958d0fd2246f77ad20915cfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_710754e8cba3978694870e8f5446d57e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_710754e8cba3978694870e8f5446d57e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_710754e8cba3978694870e8f5446d57e = L.map(
#                 &quot;map_710754e8cba3978694870e8f5446d57e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86a6b57047dc77f0b2a796e12c77e198 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86a6b57047dc77f0b2a796e12c77e198.addTo(map_710754e8cba3978694870e8f5446d57e);
#
#
#             var feature_group_16518b93ea301719dedb960b57bd321f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_16518b93ea301719dedb960b57bd321f.addTo(map_710754e8cba3978694870e8f5446d57e);
#
#
#             var feature_group_sub_group_16a7cacec7ba8743753ed686e3b0647f = L.featureGroup.subGroup(
#                 feature_group_16518b93ea301719dedb960b57bd321f
#             );
#
#
#             var marker_5e69cab5f77bf19f4dcb24c45ce7242f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_16a7cacec7ba8743753ed686e3b0647f);
#
#
#         var popup_7d7da5f6891f811120d64a41a7c96780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ffd329f40a9e931970fe87d2b816e5f = $(`&lt;div id=&quot;html_0ffd329f40a9e931970fe87d2b816e5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7d7da5f6891f811120d64a41a7c96780.setContent(html_0ffd329f40a9e931970fe87d2b816e5f);
#
#
#
#         marker_5e69cab5f77bf19f4dcb24c45ce7242f.bindPopup(popup_7d7da5f6891f811120d64a41a7c96780)
#         ;
#
#
#
#
#             var marker_c71ddaa913c065bc8aae829bdcd43a67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_16a7cacec7ba8743753ed686e3b0647f);
#
#
#         var popup_ffda24feefb6b701fa8a50f7eb9dc4a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6438c9e522a9c94ae483d5ff444a63e = $(`&lt;div id=&quot;html_f6438c9e522a9c94ae483d5ff444a63e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ffda24feefb6b701fa8a50f7eb9dc4a0.setContent(html_f6438c9e522a9c94ae483d5ff444a63e);
#
#
#
#         marker_c71ddaa913c065bc8aae829bdcd43a67.bindPopup(popup_ffda24feefb6b701fa8a50f7eb9dc4a0)
#         ;
#
#
#
#
#             var marker_6b4dd98023b3266362ecbdacd324ae54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_16a7cacec7ba8743753ed686e3b0647f);
#
#
#         var popup_fff61514988e5a65d884c75d86375183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7c0e261f3bb5fc7ddeae6fb9a0f9ea4 = $(`&lt;div id=&quot;html_a7c0e261f3bb5fc7ddeae6fb9a0f9ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fff61514988e5a65d884c75d86375183.setContent(html_a7c0e261f3bb5fc7ddeae6fb9a0f9ea4);
#
#
#
#         marker_6b4dd98023b3266362ecbdacd324ae54.bindPopup(popup_fff61514988e5a65d884c75d86375183)
#         ;
#
#
#
#
#             var marker_f9dab0947fc92415cc365a486fda66af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_16a7cacec7ba8743753ed686e3b0647f);
#
#
#         var popup_2a38ab34985e59ed2dbf52d355015ca2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3789920a0345310378d59f52a956c747 = $(`&lt;div id=&quot;html_3789920a0345310378d59f52a956c747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2a38ab34985e59ed2dbf52d355015ca2.setContent(html_3789920a0345310378d59f52a956c747);
#
#
#
#         marker_
