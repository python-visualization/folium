# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c1ff53695506daaae265994f5487772 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c1ff53695506daaae265994f5487772&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c1ff53695506daaae265994f5487772 = L.map(
#                 &quot;map_8c1ff53695506daaae265994f5487772&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c6e8b44e16fd5a08db0a5211fac9b3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c6e8b44e16fd5a08db0a5211fac9b3f.addTo(map_8c1ff53695506daaae265994f5487772);
#
#
#             var marker_79400add1805412392a0d13b9add664a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8c1ff53695506daaae265994f5487772);
#
#
#         var popup_e25b7f32c3d1c3e6c6ee946532cdfbb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6daaa5c003582f0e03dbc91b79995bcc = $(`&lt;div id=&quot;html_6daaa5c003582f0e03dbc91b79995bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e25b7f32c3d1c3e6c6ee946532cdfbb4.setContent(html_6daaa5c003582f0e03dbc91b79995bcc);
#
#
#
#         marker_79400add1805412392a0d13b9add664a.bindPopup(popup_e25b7f32c3d1c3e6c6ee946532cdfbb4)
#         ;
#
#
#
#
#             var marker_0ba1814eb758c2452eb18d584fb5dc1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8c1ff53695506daaae265994f5487772);
#
#
#         var popup_83f064578624951021e43c6703eae6ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c0b56ec4d53e22ee3ec825fcfa72399 = $(`&lt;div id=&quot;html_1c0b56ec4d53e22ee3ec825fcfa72399&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_83f064578624951021e43c6703eae6ef.setContent(html_1c0b56ec4d53e22ee3ec825fcfa72399);
#
#
#
#         marker_0ba1814eb758c2452eb18d584fb5dc1f.bindPopup(popup_83f064578624951021e43c6703eae6ef)
#         ;
#
#
#
#
#             var marker_fcc60f5d95ad77e86b0bfd83a5e29bfc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8c1ff53695506daaae265994f5487772);
#
#
#         var popup_16e932f30b1ab413c6c89ee119fbd984 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79d96f64e8e015908d45ab4cc35340a6 = $(`&lt;div id=&quot;html_79d96f64e8e015908d45ab4cc35340a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_16e932f30b1ab413c6c89ee119fbd984.setContent(html_79d96f64e8e015908d45ab4cc35340a6);
#
#
#
#         marker_fcc60f5d95ad77e86b0bfd83a5e29bfc.bindPopup(popup_16e932f30b1ab413c6c89ee119fbd984)
#         ;
#
#
#
#
#             var marker_1819c019142691b3d3f67b8256373830 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8c1ff53695506daaae265994f5487772);
#
#
#         var popup_612e6c31219dfa630f9b33eae8e04093 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e50bfe768cac20d336fcb5b5a85a19a = $(`&lt;div id=&quot;html_9e50bfe768cac20d336fcb5b5a85a19a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_612e6c31219dfa630f9b33eae8e04093.setContent(html_9e50bfe768cac20d336fcb5b5a85a19a);
#
#
#
#         marker_1819c019142691b3d3f67b8256373830.bindPopup(popup_612e6c31219dfa630f9b33eae8e04093)
#         ;
#
#
#
#
#             var marker_3ded933c1c6e1bea3c327ce1bda5d88b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8c1ff53695506daaae265994f5487772);
#
#
#         var popup_9bdc61ef416220df1793c529de8cdfe0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_137061a248a55310fd3cf6759faeecf8 = $(`&lt;div id=&quot;html_137061a248a55310fd3cf6759faeecf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9bdc61ef416220df1793c529de8cdfe0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b9fe6fe46fc1def81e4ea50425c2c69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b9fe6fe46fc1def81e4ea50425c2c69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b9fe6fe46fc1def81e4ea50425c2c69 = L.map(
#                 &quot;map_2b9fe6fe46fc1def81e4ea50425c2c69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a77fcc74c777661286d4c3872e578d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a77fcc74c777661286d4c3872e578d8.addTo(map_2b9fe6fe46fc1def81e4ea50425c2c69);
#
#
#             var feature_group_271292a60ce142cd59712cafd5452982 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_348e61fd521951e8f3ece42eebb7ea39 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_271292a60ce142cd59712cafd5452982);
#
#
#         var popup_738a4332652111fb7fa5656a0bbb7ebd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f023379f234b7e386c597dc19747ffc = $(`&lt;div id=&quot;html_4f023379f234b7e386c597dc19747ffc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_738a4332652111fb7fa5656a0bbb7ebd.setContent(html_4f023379f234b7e386c597dc19747ffc);
#
#
#
#         marker_348e61fd521951e8f3ece42eebb7ea39.bindPopup(popup_738a4332652111fb7fa5656a0bbb7ebd)
#         ;
#
#
#
#
#             var marker_a25e46ecede41d220ceea3048139fd6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_271292a60ce142cd59712cafd5452982);
#
#
#         var popup_e3427cac525ac06a90ac382a024f24fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8df4ef505086fec4e52815fb5c5bb6fe = $(`&lt;div id=&quot;html_8df4ef505086fec4e52815fb5c5bb6fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e3427cac525ac06a90ac382a024f24fc.setContent(html_8df4ef505086fec4e52815fb5c5bb6fe);
#
#
#
#         marker_a25e46ecede41d220ceea3048139fd6a.bindPopup(popup_e3427cac525ac06a90ac382a024f24fc)
#         ;
#
#
#
#
#             var marker_9d42483964fc4462f598c63aff5c1932 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_271292a60ce142cd59712cafd5452982);
#
#
#         var popup_edddff245e71c55f7d02bc46ecb499f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c56061c61306cce609a85c8ff26f90d = $(`&lt;div id=&quot;html_7c56061c61306cce609a85c8ff26f90d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_edddff245e71c55f7d02bc46ecb499f4.setContent(html_7c56061c61306cce609a85c8ff26f90d);
#
#
#
#         marker_9d42483964fc4462f598c63aff5c1932.bindPopup(popup_edddff245e71c55f7d02bc46ecb499f4)
#         ;
#
#
#
#
#             var marker_96ed02db3dcbf8c430585e48fe0389cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_271292a60ce142cd59712cafd5452982);
#
#
#         var popup_b31f9bb19473625d5b3b3675dbc38ca0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e10b7cd031448517d17d07797963632e = $(`&lt;div id=&quot;html_e10b7cd031448517d17d07797963632e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b31f9bb19473625d5b3b3675dbc38ca0.setContent(html_e10b7cd031448517d17d07797963632e);
#
#
#
#         marker_96ed02db3dcbf8c430585e48fe0389cd.bindPopup(popup_b31f9bb19473625d5b3b3675dbc38ca0)
#         ;
#
#
#
#
#             var marker_f35aa6e57f303817b1ac974a6f0ad2f4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_271292a60ce142cd59712cafd5452982);
#
#
#         var popup_53cdcf784192ebb63efb94df6f16ead9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fdd9a10413e3811055495124f97a46e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fdd9a10413e3811055495124f97a46e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fdd9a10413e3811055495124f97a46e = L.map(
#                 &quot;map_8fdd9a10413e3811055495124f97a46e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0bdeb9409360c379f5e6121b5560603 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0bdeb9409360c379f5e6121b5560603.addTo(map_8fdd9a10413e3811055495124f97a46e);
#
#
#             var feature_group_581ee129ccc27b9cf216906042b8c7b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_581ee129ccc27b9cf216906042b8c7b7.addTo(map_8fdd9a10413e3811055495124f97a46e);
#
#
#             var feature_group_sub_group_59105c12052f51f79e2f88e168e82f02 = L.featureGroup.subGroup(
#                 feature_group_581ee129ccc27b9cf216906042b8c7b7
#             );
#
#
#             var marker_2294384b4cb1281a29b811499b470f74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_59105c12052f51f79e2f88e168e82f02);
#
#
#         var popup_241213f354e29c485701d5d8ebaca764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba0fe9af24b1936ed52e87d7ab78b98e = $(`&lt;div id=&quot;html_ba0fe9af24b1936ed52e87d7ab78b98e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_241213f354e29c485701d5d8ebaca764.setContent(html_ba0fe9af24b1936ed52e87d7ab78b98e);
#
#
#
#         marker_2294384b4cb1281a29b811499b470f74.bindPopup(popup_241213f354e29c485701d5d8ebaca764)
#         ;
#
#
#
#
#             var marker_28a6ad3c29e9c97af2903009ff3e8440 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_59105c12052f51f79e2f88e168e82f02);
#
#
#         var popup_d63c96115b0dd05ccf4254140c055ff6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41d0e64203b46398e5c69de2fd43dfda = $(`&lt;div id=&quot;html_41d0e64203b46398e5c69de2fd43dfda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d63c96115b0dd05ccf4254140c055ff6.setContent(html_41d0e64203b46398e5c69de2fd43dfda);
#
#
#
#         marker_28a6ad3c29e9c97af2903009ff3e8440.bindPopup(popup_d63c96115b0dd05ccf4254140c055ff6)
#         ;
#
#
#
#
#             var marker_ce70b28a9c0843229e1294e1aa05fcfb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_59105c12052f51f79e2f88e168e82f02);
#
#
#         var popup_db3249830ffc752914e20aced281c6a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_499a5c61da3b1851dfc50ea18a656333 = $(`&lt;div id=&quot;html_499a5c61da3b1851dfc50ea18a656333&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_db3249830ffc752914e20aced281c6a1.setContent(html_499a5c61da3b1851dfc50ea18a656333);
#
#
#
#         marker_ce70b28a9c0843229e1294e1aa05fcfb.bindPopup(popup_db3249830ffc752914e20aced281c6a1)
#         ;
#
#
#
#
#             var marker_7b9ce245bb54262c9e361b49fe093946 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_59105c12052f51f79e2f88e168e82f02);
#
#
#         var popup_d4aab5db5630c1e0ebee63b5b96062af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_707c4da13cf160f84d26dcbfec13f2ee = $(`&lt;div id=&quot;html_707c4da13cf160f84d26dcbfec13f2ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d4aab5db5630c1e0ebee63b5b96062af.setContent(html_707c4da13cf160f84d26dcbfec13f2ee);
#
#
#
#         marker_
