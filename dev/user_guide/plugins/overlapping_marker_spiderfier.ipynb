# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d908f1fb6da40ca662136f166ba72073 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d908f1fb6da40ca662136f166ba72073&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d908f1fb6da40ca662136f166ba72073 = L.map(
#                 &quot;map_d908f1fb6da40ca662136f166ba72073&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5da9286274a7a9ebf5275df5adc366c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5da9286274a7a9ebf5275df5adc366c.addTo(map_d908f1fb6da40ca662136f166ba72073);
#
#
#             var marker_9f30a20f3cbf3f5858e7b17f05d19985 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d908f1fb6da40ca662136f166ba72073);
#
#
#         var popup_5dc86adfcbb8117eb48d2e05490fc8a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01a617ea077d8fec69627fd69a2d7c5c = $(`&lt;div id=&quot;html_01a617ea077d8fec69627fd69a2d7c5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5dc86adfcbb8117eb48d2e05490fc8a2.setContent(html_01a617ea077d8fec69627fd69a2d7c5c);
#
#
#
#         marker_9f30a20f3cbf3f5858e7b17f05d19985.bindPopup(popup_5dc86adfcbb8117eb48d2e05490fc8a2)
#         ;
#
#
#
#
#             var marker_f3534d5ca901272d08d720e66b36f43d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d908f1fb6da40ca662136f166ba72073);
#
#
#         var popup_34f29fd85fd74f0875cd196b14fe1178 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffec39bda6a79b1be99fbee30b33fbf4 = $(`&lt;div id=&quot;html_ffec39bda6a79b1be99fbee30b33fbf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_34f29fd85fd74f0875cd196b14fe1178.setContent(html_ffec39bda6a79b1be99fbee30b33fbf4);
#
#
#
#         marker_f3534d5ca901272d08d720e66b36f43d.bindPopup(popup_34f29fd85fd74f0875cd196b14fe1178)
#         ;
#
#
#
#
#             var marker_6f872f08639d893b239ee75a7f8af97e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d908f1fb6da40ca662136f166ba72073);
#
#
#         var popup_88ce76d5a303b1b0d78bd06057d2b035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f15a8f18caad7fd7cd6d76118ab5bb9 = $(`&lt;div id=&quot;html_3f15a8f18caad7fd7cd6d76118ab5bb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_88ce76d5a303b1b0d78bd06057d2b035.setContent(html_3f15a8f18caad7fd7cd6d76118ab5bb9);
#
#
#
#         marker_6f872f08639d893b239ee75a7f8af97e.bindPopup(popup_88ce76d5a303b1b0d78bd06057d2b035)
#         ;
#
#
#
#
#             var marker_683623632019810f93562608e8e6c690 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d908f1fb6da40ca662136f166ba72073);
#
#
#         var popup_65433a8a45beac6f4b1981250a58b643 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b493ca207d8ecc235ce3e5f711af1519 = $(`&lt;div id=&quot;html_b493ca207d8ecc235ce3e5f711af1519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_65433a8a45beac6f4b1981250a58b643.setContent(html_b493ca207d8ecc235ce3e5f711af1519);
#
#
#
#         marker_683623632019810f93562608e8e6c690.bindPopup(popup_65433a8a45beac6f4b1981250a58b643)
#         ;
#
#
#
#
#             var marker_574394efcb4139d61444e686e1f02328 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d908f1fb6da40ca662136f166ba72073);
#
#
#         var popup_85c51bfd559212c1c3413de3e50b065d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_135818bd5a683a653b36a5ed05010260 = $(`&lt;div id=&quot;html_135818bd5a683a653b36a5ed05010260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_85c51bfd559212c1c3413de3e50b065d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40b6574355e182dfccf84968e8be3505 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40b6574355e182dfccf84968e8be3505&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40b6574355e182dfccf84968e8be3505 = L.map(
#                 &quot;map_40b6574355e182dfccf84968e8be3505&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ca8844ca0f2ae27c04c2f0527e03361 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ca8844ca0f2ae27c04c2f0527e03361.addTo(map_40b6574355e182dfccf84968e8be3505);
#
#
#             var feature_group_37d3805265896b6505c1b9948983c3e0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1fb69fb6d8430df49e6f5f9d7099a96c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_37d3805265896b6505c1b9948983c3e0);
#
#
#         var popup_37b94d549329918b4847139ca9a95f10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_286bb0194b09bc5d174117ca846553ef = $(`&lt;div id=&quot;html_286bb0194b09bc5d174117ca846553ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_37b94d549329918b4847139ca9a95f10.setContent(html_286bb0194b09bc5d174117ca846553ef);
#
#
#
#         marker_1fb69fb6d8430df49e6f5f9d7099a96c.bindPopup(popup_37b94d549329918b4847139ca9a95f10)
#         ;
#
#
#
#
#             var marker_87a103737ee60afcc49385d00b7f3a74 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_37d3805265896b6505c1b9948983c3e0);
#
#
#         var popup_0bd39b3ee9109240a012e1b99cf51d4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d26acd010711dd4ea1e9991cd1c51d3 = $(`&lt;div id=&quot;html_7d26acd010711dd4ea1e9991cd1c51d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0bd39b3ee9109240a012e1b99cf51d4b.setContent(html_7d26acd010711dd4ea1e9991cd1c51d3);
#
#
#
#         marker_87a103737ee60afcc49385d00b7f3a74.bindPopup(popup_0bd39b3ee9109240a012e1b99cf51d4b)
#         ;
#
#
#
#
#             var marker_2b145dd632e61f67a5466bc7abf7f9f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_37d3805265896b6505c1b9948983c3e0);
#
#
#         var popup_6929ce3b766878b7c8d762b661c21325 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5267d3d6cdbf49fb03492295a2c0bf = $(`&lt;div id=&quot;html_4a5267d3d6cdbf49fb03492295a2c0bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6929ce3b766878b7c8d762b661c21325.setContent(html_4a5267d3d6cdbf49fb03492295a2c0bf);
#
#
#
#         marker_2b145dd632e61f67a5466bc7abf7f9f2.bindPopup(popup_6929ce3b766878b7c8d762b661c21325)
#         ;
#
#
#
#
#             var marker_2cd7a1483df584ebd6485d78ec6f7182 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_37d3805265896b6505c1b9948983c3e0);
#
#
#         var popup_6f10014415c1c4c508b67cc9365de757 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7106a8dc7102b8d703bf46606c1a344 = $(`&lt;div id=&quot;html_d7106a8dc7102b8d703bf46606c1a344&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6f10014415c1c4c508b67cc9365de757.setContent(html_d7106a8dc7102b8d703bf46606c1a344);
#
#
#
#         marker_2cd7a1483df584ebd6485d78ec6f7182.bindPopup(popup_6f10014415c1c4c508b67cc9365de757)
#         ;
#
#
#
#
#             var marker_1970e1109d898d15872c36ed9834473f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_37d3805265896b6505c1b9948983c3e0);
#
#
#         var popup_39642f76e8da5deff4f3657ea6abdc30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc6c537b5c20067df54cff5664cf0eaf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc6c537b5c20067df54cff5664cf0eaf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc6c537b5c20067df54cff5664cf0eaf = L.map(
#                 &quot;map_fc6c537b5c20067df54cff5664cf0eaf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7383e5eb5420bb20dd78ad4db6715f40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7383e5eb5420bb20dd78ad4db6715f40.addTo(map_fc6c537b5c20067df54cff5664cf0eaf);
#
#
#             var feature_group_ce3e3cc9b6200c54619fede8c10a77aa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ce3e3cc9b6200c54619fede8c10a77aa.addTo(map_fc6c537b5c20067df54cff5664cf0eaf);
#
#
#             var feature_group_sub_group_b3de0dde2e428ca59e083f6e244f7c26 = L.featureGroup.subGroup(
#                 feature_group_ce3e3cc9b6200c54619fede8c10a77aa
#             );
#
#
#             var marker_dd06b4e55a41182e7979cb12f35486c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3de0dde2e428ca59e083f6e244f7c26);
#
#
#         var popup_2f0bcdf99f89d036e984f28bbf2a051f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8a8439163cda0ca08a791479ac04894 = $(`&lt;div id=&quot;html_b8a8439163cda0ca08a791479ac04894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2f0bcdf99f89d036e984f28bbf2a051f.setContent(html_b8a8439163cda0ca08a791479ac04894);
#
#
#
#         marker_dd06b4e55a41182e7979cb12f35486c8.bindPopup(popup_2f0bcdf99f89d036e984f28bbf2a051f)
#         ;
#
#
#
#
#             var marker_db508eb973994fa5f9506585b37eb131 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3de0dde2e428ca59e083f6e244f7c26);
#
#
#         var popup_0dba7a5c480cda48802317afc973ef50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dea2c53d96be2672466b1b11677af289 = $(`&lt;div id=&quot;html_dea2c53d96be2672466b1b11677af289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0dba7a5c480cda48802317afc973ef50.setContent(html_dea2c53d96be2672466b1b11677af289);
#
#
#
#         marker_db508eb973994fa5f9506585b37eb131.bindPopup(popup_0dba7a5c480cda48802317afc973ef50)
#         ;
#
#
#
#
#             var marker_234caded26bb3ef354894b10e00fafab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3de0dde2e428ca59e083f6e244f7c26);
#
#
#         var popup_6b99c73acf459cbc9488d3b799331a1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c7fa5aaf8c5c5709a199d79339e02a8 = $(`&lt;div id=&quot;html_0c7fa5aaf8c5c5709a199d79339e02a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6b99c73acf459cbc9488d3b799331a1e.setContent(html_0c7fa5aaf8c5c5709a199d79339e02a8);
#
#
#
#         marker_234caded26bb3ef354894b10e00fafab.bindPopup(popup_6b99c73acf459cbc9488d3b799331a1e)
#         ;
#
#
#
#
#             var marker_16c6086d9cb8f2714757993c1f0b81b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3de0dde2e428ca59e083f6e244f7c26);
#
#
#         var popup_174ffd08d4ae9561ea64b55b95e6444f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f02a1ddff8cd47ab14332600439eb98d = $(`&lt;div id=&quot;html_f02a1ddff8cd47ab14332600439eb98d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_174ffd08d4ae9561ea64b55b95e6444f.setContent(html_f02a1ddff8cd47ab14332600439eb98d);
#
#
#
#         marker_
