# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6abff5f18e1e79fbc54e884ac6a0796b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6abff5f18e1e79fbc54e884ac6a0796b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6abff5f18e1e79fbc54e884ac6a0796b = L.map(
#                 &quot;map_6abff5f18e1e79fbc54e884ac6a0796b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfe5b6c3ceb7492679eda64602f2c41a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cfe5b6c3ceb7492679eda64602f2c41a.addTo(map_6abff5f18e1e79fbc54e884ac6a0796b);
#
#
#             var marker_544065000644f8558cc6c06de20e2f46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6abff5f18e1e79fbc54e884ac6a0796b);
#
#
#         var popup_25f95eedd37eef798231e9a515ee2c2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebf71f9dc1c8ba184203b009b67e3712 = $(`&lt;div id=&quot;html_ebf71f9dc1c8ba184203b009b67e3712&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_25f95eedd37eef798231e9a515ee2c2e.setContent(html_ebf71f9dc1c8ba184203b009b67e3712);
#
#
#
#         marker_544065000644f8558cc6c06de20e2f46.bindPopup(popup_25f95eedd37eef798231e9a515ee2c2e)
#         ;
#
#
#
#
#             var marker_7cdc096004642d940ddaa1d8493432df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6abff5f18e1e79fbc54e884ac6a0796b);
#
#
#         var popup_2b702a3cbb4b0bf753b1d6291842b3e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_881c024cc0a6a4cf08d22c2f2c786a7d = $(`&lt;div id=&quot;html_881c024cc0a6a4cf08d22c2f2c786a7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2b702a3cbb4b0bf753b1d6291842b3e6.setContent(html_881c024cc0a6a4cf08d22c2f2c786a7d);
#
#
#
#         marker_7cdc096004642d940ddaa1d8493432df.bindPopup(popup_2b702a3cbb4b0bf753b1d6291842b3e6)
#         ;
#
#
#
#
#             var marker_120d05c04ff07b3b97e6e5c9ef72bc75 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6abff5f18e1e79fbc54e884ac6a0796b);
#
#
#         var popup_c2219baa987044e77d3ce3fb5720fe49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94ba4c162b711d0cf8603c340f59dda3 = $(`&lt;div id=&quot;html_94ba4c162b711d0cf8603c340f59dda3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c2219baa987044e77d3ce3fb5720fe49.setContent(html_94ba4c162b711d0cf8603c340f59dda3);
#
#
#
#         marker_120d05c04ff07b3b97e6e5c9ef72bc75.bindPopup(popup_c2219baa987044e77d3ce3fb5720fe49)
#         ;
#
#
#
#
#             var marker_32e1eb90b6c9bca8f018ac5cf6c055e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6abff5f18e1e79fbc54e884ac6a0796b);
#
#
#         var popup_2a95c00c002997175bc7573973eebd73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c69ec5c5d5ae2de42fb8c68d1e00d07d = $(`&lt;div id=&quot;html_c69ec5c5d5ae2de42fb8c68d1e00d07d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2a95c00c002997175bc7573973eebd73.setContent(html_c69ec5c5d5ae2de42fb8c68d1e00d07d);
#
#
#
#         marker_32e1eb90b6c9bca8f018ac5cf6c055e7.bindPopup(popup_2a95c00c002997175bc7573973eebd73)
#         ;
#
#
#
#
#             var marker_4b2cc78bdf2631dd3a862197fc35dcf6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6abff5f18e1e79fbc54e884ac6a0796b);
#
#
#         var popup_f0386103eebb0f249f9e33664449b60f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8f4addb403a96509a7d510dc5c213f4 = $(`&lt;div id=&quot;html_d8f4addb403a96509a7d510dc5c213f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f0386103eebb0f249f9e33664449b60f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa56d51242ee858d6e5f4e12f5b555b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa56d51242ee858d6e5f4e12f5b555b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa56d51242ee858d6e5f4e12f5b555b0 = L.map(
#                 &quot;map_fa56d51242ee858d6e5f4e12f5b555b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb8a416f7c2a91ac88a4b738899f9ddd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb8a416f7c2a91ac88a4b738899f9ddd.addTo(map_fa56d51242ee858d6e5f4e12f5b555b0);
#
#
#             var feature_group_49403e42efd23821360eb69789947326 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_162faf7068a7994153c75153c3526033 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_49403e42efd23821360eb69789947326);
#
#
#         var popup_7bae16b03fe7397f70ece61c7079ed5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b74fc2f401e13882e0321f41458069bb = $(`&lt;div id=&quot;html_b74fc2f401e13882e0321f41458069bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7bae16b03fe7397f70ece61c7079ed5f.setContent(html_b74fc2f401e13882e0321f41458069bb);
#
#
#
#         marker_162faf7068a7994153c75153c3526033.bindPopup(popup_7bae16b03fe7397f70ece61c7079ed5f)
#         ;
#
#
#
#
#             var marker_430213fa3a387ed0f56c59bd32943417 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_49403e42efd23821360eb69789947326);
#
#
#         var popup_be98f6769ac318ca0bca1672ca588597 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_958f4ab434e733d5c1a9126b000d8bf1 = $(`&lt;div id=&quot;html_958f4ab434e733d5c1a9126b000d8bf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_be98f6769ac318ca0bca1672ca588597.setContent(html_958f4ab434e733d5c1a9126b000d8bf1);
#
#
#
#         marker_430213fa3a387ed0f56c59bd32943417.bindPopup(popup_be98f6769ac318ca0bca1672ca588597)
#         ;
#
#
#
#
#             var marker_fc1ed269e08683939051d32eaa0cc671 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_49403e42efd23821360eb69789947326);
#
#
#         var popup_3d6fbb358f9271779ef5ce831eb6d770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87ddbecb802ba519e2300f3cbaa06129 = $(`&lt;div id=&quot;html_87ddbecb802ba519e2300f3cbaa06129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3d6fbb358f9271779ef5ce831eb6d770.setContent(html_87ddbecb802ba519e2300f3cbaa06129);
#
#
#
#         marker_fc1ed269e08683939051d32eaa0cc671.bindPopup(popup_3d6fbb358f9271779ef5ce831eb6d770)
#         ;
#
#
#
#
#             var marker_8e48971907010ec43186f9302ce05044 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_49403e42efd23821360eb69789947326);
#
#
#         var popup_90ec9590a69b68f2b74550201a81942d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_976290b2c7cfe793a94be1286342b85b = $(`&lt;div id=&quot;html_976290b2c7cfe793a94be1286342b85b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_90ec9590a69b68f2b74550201a81942d.setContent(html_976290b2c7cfe793a94be1286342b85b);
#
#
#
#         marker_8e48971907010ec43186f9302ce05044.bindPopup(popup_90ec9590a69b68f2b74550201a81942d)
#         ;
#
#
#
#
#             var marker_3cd3aee91024745740a2b1922020eeea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_49403e42efd23821360eb69789947326);
#
#
#         var popup_54a0d337258f22e6e785055ba0660d08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b2835e5bb4660dd425d19d7afaa813a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b2835e5bb4660dd425d19d7afaa813a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b2835e5bb4660dd425d19d7afaa813a = L.map(
#                 &quot;map_0b2835e5bb4660dd425d19d7afaa813a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a1efab720b4046fa829bd05c970f961 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a1efab720b4046fa829bd05c970f961.addTo(map_0b2835e5bb4660dd425d19d7afaa813a);
#
#
#             var feature_group_7d9baef35c1bc6dc3440313d3fe9e440 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7d9baef35c1bc6dc3440313d3fe9e440.addTo(map_0b2835e5bb4660dd425d19d7afaa813a);
#
#
#             var feature_group_sub_group_add252f9929f98fe1dfc5bd570f8ea39 = L.featureGroup.subGroup(
#                 feature_group_7d9baef35c1bc6dc3440313d3fe9e440
#             );
#
#
#             var marker_969074f4d7378f013b4b27a714be5005 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_add252f9929f98fe1dfc5bd570f8ea39);
#
#
#         var popup_1787d9a64ef46e2ec821de671dc5d0ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_340127980bda9c041e1a457f4b654860 = $(`&lt;div id=&quot;html_340127980bda9c041e1a457f4b654860&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1787d9a64ef46e2ec821de671dc5d0ac.setContent(html_340127980bda9c041e1a457f4b654860);
#
#
#
#         marker_969074f4d7378f013b4b27a714be5005.bindPopup(popup_1787d9a64ef46e2ec821de671dc5d0ac)
#         ;
#
#
#
#
#             var marker_d4e04116e78259e79f89190253fc1574 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_add252f9929f98fe1dfc5bd570f8ea39);
#
#
#         var popup_c3d672bc2f06498b0bf30f05e301a17e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad28f3e19db0441bca1bf00bb18753e8 = $(`&lt;div id=&quot;html_ad28f3e19db0441bca1bf00bb18753e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3d672bc2f06498b0bf30f05e301a17e.setContent(html_ad28f3e19db0441bca1bf00bb18753e8);
#
#
#
#         marker_d4e04116e78259e79f89190253fc1574.bindPopup(popup_c3d672bc2f06498b0bf30f05e301a17e)
#         ;
#
#
#
#
#             var marker_a4d53cf142c7d8dbfa053b7357572c27 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_add252f9929f98fe1dfc5bd570f8ea39);
#
#
#         var popup_ff6c7b567ceae6df64522d71e312b5b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0581d3be7302ca770780ac84799c026c = $(`&lt;div id=&quot;html_0581d3be7302ca770780ac84799c026c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ff6c7b567ceae6df64522d71e312b5b4.setContent(html_0581d3be7302ca770780ac84799c026c);
#
#
#
#         marker_a4d53cf142c7d8dbfa053b7357572c27.bindPopup(popup_ff6c7b567ceae6df64522d71e312b5b4)
#         ;
#
#
#
#
#             var marker_ffcc1f4c970405c6c3b6f1bf231d6659 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_add252f9929f98fe1dfc5bd570f8ea39);
#
#
#         var popup_e067df780620f37b0d173dd725392b81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec2b7c7bd5b34324dab0ff01b3c9c466 = $(`&lt;div id=&quot;html_ec2b7c7bd5b34324dab0ff01b3c9c466&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e067df780620f37b0d173dd725392b81.setContent(html_ec2b7c7bd5b34324dab0ff01b3c9c466);
#
#
#
#         marker_
