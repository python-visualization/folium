# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab2c5603fd0aa80c0c504395c5efd5dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab2c5603fd0aa80c0c504395c5efd5dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab2c5603fd0aa80c0c504395c5efd5dc = L.map(
#                 &quot;map_ab2c5603fd0aa80c0c504395c5efd5dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13a8e4ed0eec9315cb1839cad96941b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13a8e4ed0eec9315cb1839cad96941b7.addTo(map_ab2c5603fd0aa80c0c504395c5efd5dc);
#
#
#             var marker_d2ca6e8ed8cb0cce7f4e88ad894319b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ab2c5603fd0aa80c0c504395c5efd5dc);
#
#
#         var popup_c097e85ff418e8b3588665d866c78def = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57b6421828d9ef5b849ce0a92a5dda57 = $(`&lt;div id=&quot;html_57b6421828d9ef5b849ce0a92a5dda57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c097e85ff418e8b3588665d866c78def.setContent(html_57b6421828d9ef5b849ce0a92a5dda57);
#
#
#
#         marker_d2ca6e8ed8cb0cce7f4e88ad894319b8.bindPopup(popup_c097e85ff418e8b3588665d866c78def)
#         ;
#
#
#
#
#             var marker_4324d9507206ae3950a38e0d55fd7391 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ab2c5603fd0aa80c0c504395c5efd5dc);
#
#
#         var popup_847efe14ff844b48b228f3d9997fc694 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f04206db50280c6f6cd6a0e48657037b = $(`&lt;div id=&quot;html_f04206db50280c6f6cd6a0e48657037b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_847efe14ff844b48b228f3d9997fc694.setContent(html_f04206db50280c6f6cd6a0e48657037b);
#
#
#
#         marker_4324d9507206ae3950a38e0d55fd7391.bindPopup(popup_847efe14ff844b48b228f3d9997fc694)
#         ;
#
#
#
#
#             var marker_11325805da967709d6f92b9f2e408dab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ab2c5603fd0aa80c0c504395c5efd5dc);
#
#
#         var popup_e247687399570661b565f47ac66b6d57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d616a0d657818436205b16a12165cc6 = $(`&lt;div id=&quot;html_2d616a0d657818436205b16a12165cc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e247687399570661b565f47ac66b6d57.setContent(html_2d616a0d657818436205b16a12165cc6);
#
#
#
#         marker_11325805da967709d6f92b9f2e408dab.bindPopup(popup_e247687399570661b565f47ac66b6d57)
#         ;
#
#
#
#
#             var marker_3b26f9462f5a04c005c82ea5af3b4737 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ab2c5603fd0aa80c0c504395c5efd5dc);
#
#
#         var popup_8b2f0e4a22b2a82b8f45ce30933d3f85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e95e2157acdde068e20d74f027810e0 = $(`&lt;div id=&quot;html_9e95e2157acdde068e20d74f027810e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8b2f0e4a22b2a82b8f45ce30933d3f85.setContent(html_9e95e2157acdde068e20d74f027810e0);
#
#
#
#         marker_3b26f9462f5a04c005c82ea5af3b4737.bindPopup(popup_8b2f0e4a22b2a82b8f45ce30933d3f85)
#         ;
#
#
#
#
#             var marker_8dcc1476f34f16e223cf43ef55eaec1d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ab2c5603fd0aa80c0c504395c5efd5dc);
#
#
#         var popup_b1dbb53799120997dbfb0e7e4cccef3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18ff13bdd06c0c3351d596e197ee261d = $(`&lt;div id=&quot;html_18ff13bdd06c0c3351d596e197ee261d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b1dbb53799120997dbfb0e7e4cccef3e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f69650a3b994254c57db87c601295f16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f69650a3b994254c57db87c601295f16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f69650a3b994254c57db87c601295f16 = L.map(
#                 &quot;map_f69650a3b994254c57db87c601295f16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76fa47a02743f0f5f773a96e9f8bf160 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76fa47a02743f0f5f773a96e9f8bf160.addTo(map_f69650a3b994254c57db87c601295f16);
#
#
#             var feature_group_ed64c944e2c9014fb6808d4c1ede6d06 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f70f0e21be0a944985601a2cbae49521 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ed64c944e2c9014fb6808d4c1ede6d06);
#
#
#         var popup_e30b8267206dd20dbaf3b7b562e47d2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19d8fa9a86e36e9bd8406f8b9dac95da = $(`&lt;div id=&quot;html_19d8fa9a86e36e9bd8406f8b9dac95da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e30b8267206dd20dbaf3b7b562e47d2a.setContent(html_19d8fa9a86e36e9bd8406f8b9dac95da);
#
#
#
#         marker_f70f0e21be0a944985601a2cbae49521.bindPopup(popup_e30b8267206dd20dbaf3b7b562e47d2a)
#         ;
#
#
#
#
#             var marker_c8fa03b1293b12dc9e74f8d4c80e8617 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ed64c944e2c9014fb6808d4c1ede6d06);
#
#
#         var popup_c73408488df6035a70016d6bf483c4dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a86c87cc722d96568770112f012d5649 = $(`&lt;div id=&quot;html_a86c87cc722d96568770112f012d5649&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c73408488df6035a70016d6bf483c4dd.setContent(html_a86c87cc722d96568770112f012d5649);
#
#
#
#         marker_c8fa03b1293b12dc9e74f8d4c80e8617.bindPopup(popup_c73408488df6035a70016d6bf483c4dd)
#         ;
#
#
#
#
#             var marker_9b784e50cc67f03555052e9b0f93f667 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ed64c944e2c9014fb6808d4c1ede6d06);
#
#
#         var popup_170d8b86236ad1b405cc87cb33e24799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bc783dde265f0c7a7133d9e8563ca18 = $(`&lt;div id=&quot;html_5bc783dde265f0c7a7133d9e8563ca18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_170d8b86236ad1b405cc87cb33e24799.setContent(html_5bc783dde265f0c7a7133d9e8563ca18);
#
#
#
#         marker_9b784e50cc67f03555052e9b0f93f667.bindPopup(popup_170d8b86236ad1b405cc87cb33e24799)
#         ;
#
#
#
#
#             var marker_d6d5d97b7fc2c31924c12579d5ebe536 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ed64c944e2c9014fb6808d4c1ede6d06);
#
#
#         var popup_19f5c036e6a0b032d4863bc1c09f29ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a112cc847b84dbea99765a7e314cabb = $(`&lt;div id=&quot;html_3a112cc847b84dbea99765a7e314cabb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_19f5c036e6a0b032d4863bc1c09f29ff.setContent(html_3a112cc847b84dbea99765a7e314cabb);
#
#
#
#         marker_d6d5d97b7fc2c31924c12579d5ebe536.bindPopup(popup_19f5c036e6a0b032d4863bc1c09f29ff)
#         ;
#
#
#
#
#             var marker_7ec2acc2bc7a33d354cd2522d0d2a154 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ed64c944e2c9014fb6808d4c1ede6d06);
#
#
#         var popup_d651616ccd95432a9ae99c4dfc75c496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4eb4ccce5c9fc7b50b893a6ffaac368 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4eb4ccce5c9fc7b50b893a6ffaac368&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4eb4ccce5c9fc7b50b893a6ffaac368 = L.map(
#                 &quot;map_a4eb4ccce5c9fc7b50b893a6ffaac368&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac4dc2a349facf42dda3f8f0bc1cb573 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac4dc2a349facf42dda3f8f0bc1cb573.addTo(map_a4eb4ccce5c9fc7b50b893a6ffaac368);
#
#
#             var feature_group_5e824281cee7ffb18c50fd4dbe434efb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5e824281cee7ffb18c50fd4dbe434efb.addTo(map_a4eb4ccce5c9fc7b50b893a6ffaac368);
#
#
#             var feature_group_sub_group_49ec1e9eb4068de38375233b08716482 = L.featureGroup.subGroup(
#                 feature_group_5e824281cee7ffb18c50fd4dbe434efb
#             );
#
#
#             var marker_c1f7a4477db370f1fbd47496153ba160 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_49ec1e9eb4068de38375233b08716482);
#
#
#         var popup_dbfb7a243eb6df6e11e23564691a0d12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_988691486b898e679e6bd72a264b34a0 = $(`&lt;div id=&quot;html_988691486b898e679e6bd72a264b34a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dbfb7a243eb6df6e11e23564691a0d12.setContent(html_988691486b898e679e6bd72a264b34a0);
#
#
#
#         marker_c1f7a4477db370f1fbd47496153ba160.bindPopup(popup_dbfb7a243eb6df6e11e23564691a0d12)
#         ;
#
#
#
#
#             var marker_25416870429f94d73f2d940924b2631e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_49ec1e9eb4068de38375233b08716482);
#
#
#         var popup_b8ff10e9c465c5675a8e51fa784e6fcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31167adb935a8f8b610047a5e501deb9 = $(`&lt;div id=&quot;html_31167adb935a8f8b610047a5e501deb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b8ff10e9c465c5675a8e51fa784e6fcd.setContent(html_31167adb935a8f8b610047a5e501deb9);
#
#
#
#         marker_25416870429f94d73f2d940924b2631e.bindPopup(popup_b8ff10e9c465c5675a8e51fa784e6fcd)
#         ;
#
#
#
#
#             var marker_78761d26f4a6dd684dae57a1ac202e3a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_49ec1e9eb4068de38375233b08716482);
#
#
#         var popup_991c79b549360baca84c347d566e4fb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5896b932dd3ca763199025779792f43 = $(`&lt;div id=&quot;html_e5896b932dd3ca763199025779792f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_991c79b549360baca84c347d566e4fb2.setContent(html_e5896b932dd3ca763199025779792f43);
#
#
#
#         marker_78761d26f4a6dd684dae57a1ac202e3a.bindPopup(popup_991c79b549360baca84c347d566e4fb2)
#         ;
#
#
#
#
#             var marker_1658934e0b8ef97c265650551dbf492c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_49ec1e9eb4068de38375233b08716482);
#
#
#         var popup_42f2318d4846b7e432e310bd94f554c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50a0263e91d468556ab2500a26502a18 = $(`&lt;div id=&quot;html_50a0263e91d468556ab2500a26502a18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_42f2318d4846b7e432e310bd94f554c5.setContent(html_50a0263e91d468556ab2500a26502a18);
#
#
#
#         marker_
