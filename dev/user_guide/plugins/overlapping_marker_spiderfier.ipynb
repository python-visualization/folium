# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f436212757356c7127400afbe6198ad5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f436212757356c7127400afbe6198ad5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f436212757356c7127400afbe6198ad5 = L.map(
#                 &quot;map_f436212757356c7127400afbe6198ad5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6558fd4ce0a1185fee01b40bf0ded79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6558fd4ce0a1185fee01b40bf0ded79.addTo(map_f436212757356c7127400afbe6198ad5);
#
#
#             var marker_7d94ae002b50a0da22134a67414ca6cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f436212757356c7127400afbe6198ad5);
#
#
#         var popup_f46277985647873d3602e198c7d60756 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9294cccddc9e140ca48891704f391e6 = $(`&lt;div id=&quot;html_b9294cccddc9e140ca48891704f391e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f46277985647873d3602e198c7d60756.setContent(html_b9294cccddc9e140ca48891704f391e6);
#
#
#
#         marker_7d94ae002b50a0da22134a67414ca6cf.bindPopup(popup_f46277985647873d3602e198c7d60756)
#         ;
#
#
#
#
#             var marker_2c35e40e7ccb697f2ebf48168f0511c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f436212757356c7127400afbe6198ad5);
#
#
#         var popup_7ade82c3c6e4999426439f0394b8f17a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45fd14506233cbef0de76bd73e8e001d = $(`&lt;div id=&quot;html_45fd14506233cbef0de76bd73e8e001d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7ade82c3c6e4999426439f0394b8f17a.setContent(html_45fd14506233cbef0de76bd73e8e001d);
#
#
#
#         marker_2c35e40e7ccb697f2ebf48168f0511c3.bindPopup(popup_7ade82c3c6e4999426439f0394b8f17a)
#         ;
#
#
#
#
#             var marker_0e112ff6e1aa59f47afa2fb18560942e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f436212757356c7127400afbe6198ad5);
#
#
#         var popup_fa53130e83d639cbc300ded3aa90ca31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e18f93f24e285016755e7dfbacdc7881 = $(`&lt;div id=&quot;html_e18f93f24e285016755e7dfbacdc7881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fa53130e83d639cbc300ded3aa90ca31.setContent(html_e18f93f24e285016755e7dfbacdc7881);
#
#
#
#         marker_0e112ff6e1aa59f47afa2fb18560942e.bindPopup(popup_fa53130e83d639cbc300ded3aa90ca31)
#         ;
#
#
#
#
#             var marker_84304326a58b1f459eeab0116b16d6fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f436212757356c7127400afbe6198ad5);
#
#
#         var popup_dff8789d8326700c8bf19674c29097d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe010ead57e11d2fcb005b4437394f02 = $(`&lt;div id=&quot;html_fe010ead57e11d2fcb005b4437394f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dff8789d8326700c8bf19674c29097d8.setContent(html_fe010ead57e11d2fcb005b4437394f02);
#
#
#
#         marker_84304326a58b1f459eeab0116b16d6fc.bindPopup(popup_dff8789d8326700c8bf19674c29097d8)
#         ;
#
#
#
#
#             var marker_13ac814c4888da6c192b4a34f87f14a8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f436212757356c7127400afbe6198ad5);
#
#
#         var popup_596a742a7b267b3c9b6067654c6c7214 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee523658d0f3c9250fe574ee87cfbd6a = $(`&lt;div id=&quot;html_ee523658d0f3c9250fe574ee87cfbd6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_596a742a7b267b3c9b6067654c6c72

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fd7f6cb6439d905dac65b4011644736 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fd7f6cb6439d905dac65b4011644736&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fd7f6cb6439d905dac65b4011644736 = L.map(
#                 &quot;map_1fd7f6cb6439d905dac65b4011644736&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6cc4ecc80566759ca26d4c57ed7699f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6cc4ecc80566759ca26d4c57ed7699f.addTo(map_1fd7f6cb6439d905dac65b4011644736);
#
#
#             var feature_group_b038c4897f0274fcb464e0dcc1008db4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b439e76589305bf56f485eb03acb99e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b038c4897f0274fcb464e0dcc1008db4);
#
#
#         var popup_34eb37ac2136a11dfa89045eac1212d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16d14695f835fb0b2585ef83d576af94 = $(`&lt;div id=&quot;html_16d14695f835fb0b2585ef83d576af94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_34eb37ac2136a11dfa89045eac1212d4.setContent(html_16d14695f835fb0b2585ef83d576af94);
#
#
#
#         marker_b439e76589305bf56f485eb03acb99e0.bindPopup(popup_34eb37ac2136a11dfa89045eac1212d4)
#         ;
#
#
#
#
#             var marker_8de212c5f575325c0b39705cdfbfdda1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b038c4897f0274fcb464e0dcc1008db4);
#
#
#         var popup_04e8a3e9bc15be746f86e83b0ab00939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be6ee84623fb78390016a37f9f52477f = $(`&lt;div id=&quot;html_be6ee84623fb78390016a37f9f52477f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_04e8a3e9bc15be746f86e83b0ab00939.setContent(html_be6ee84623fb78390016a37f9f52477f);
#
#
#
#         marker_8de212c5f575325c0b39705cdfbfdda1.bindPopup(popup_04e8a3e9bc15be746f86e83b0ab00939)
#         ;
#
#
#
#
#             var marker_acdde37361b697fc72f85a39acd1ed97 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b038c4897f0274fcb464e0dcc1008db4);
#
#
#         var popup_adbc57629a2a5eb58a0f7d6b436dc273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3ef85bb6df11c6dba276a7718a1f2e7 = $(`&lt;div id=&quot;html_c3ef85bb6df11c6dba276a7718a1f2e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_adbc57629a2a5eb58a0f7d6b436dc273.setContent(html_c3ef85bb6df11c6dba276a7718a1f2e7);
#
#
#
#         marker_acdde37361b697fc72f85a39acd1ed97.bindPopup(popup_adbc57629a2a5eb58a0f7d6b436dc273)
#         ;
#
#
#
#
#             var marker_2be1ea93faad1e4502306b183806dba2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b038c4897f0274fcb464e0dcc1008db4);
#
#
#         var popup_5dd7c043147d0dca65b01ba5170f63c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e6907678f9865e7ff72367f2aeb44be = $(`&lt;div id=&quot;html_7e6907678f9865e7ff72367f2aeb44be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5dd7c043147d0dca65b01ba5170f63c0.setContent(html_7e6907678f9865e7ff72367f2aeb44be);
#
#
#
#         marker_2be1ea93faad1e4502306b183806dba2.bindPopup(popup_5dd7c043147d0dca65b01ba5170f63c0)
#         ;
#
#
#
#
#             var marker_70ce2412d73adb9afba1dc2a03424aad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b038c4897f0274fcb464e0dcc1008db4);
#
#
#         var popup_52ed505ffc5f320246ae32620c8bd1be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbe2ed97e0c620bbe17a30242db731d5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbe2ed97e0c620bbe17a30242db731d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbe2ed97e0c620bbe17a30242db731d5 = L.map(
#                 &quot;map_fbe2ed97e0c620bbe17a30242db731d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bf7dc3e6f2364d544d6d26d7bf698be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8bf7dc3e6f2364d544d6d26d7bf698be.addTo(map_fbe2ed97e0c620bbe17a30242db731d5);
#
#
#             var feature_group_3e0af0eecbe6ea54a1e426a1a07227ae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3e0af0eecbe6ea54a1e426a1a07227ae.addTo(map_fbe2ed97e0c620bbe17a30242db731d5);
#
#
#             var feature_group_sub_group_2cc016cfda0f8548e4207d5804c6c46e = L.featureGroup.subGroup(
#                 feature_group_3e0af0eecbe6ea54a1e426a1a07227ae
#             );
#
#
#             var marker_c266cd031ab95d3c415efdf50adb0083 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc016cfda0f8548e4207d5804c6c46e);
#
#
#         var popup_cdc73970fb13d3d10030748c8a22316d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69e44b4e054b213e8b171e6b2d53da3b = $(`&lt;div id=&quot;html_69e44b4e054b213e8b171e6b2d53da3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cdc73970fb13d3d10030748c8a22316d.setContent(html_69e44b4e054b213e8b171e6b2d53da3b);
#
#
#
#         marker_c266cd031ab95d3c415efdf50adb0083.bindPopup(popup_cdc73970fb13d3d10030748c8a22316d)
#         ;
#
#
#
#
#             var marker_9ea31eb2f54b7e4283742b475e46029c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc016cfda0f8548e4207d5804c6c46e);
#
#
#         var popup_5f13367ae2bde62a8666272fe5cf2580 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bf2453f518b69cffb44041f5188ca6a = $(`&lt;div id=&quot;html_0bf2453f518b69cffb44041f5188ca6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5f13367ae2bde62a8666272fe5cf2580.setContent(html_0bf2453f518b69cffb44041f5188ca6a);
#
#
#
#         marker_9ea31eb2f54b7e4283742b475e46029c.bindPopup(popup_5f13367ae2bde62a8666272fe5cf2580)
#         ;
#
#
#
#
#             var marker_57b0eedbdc77bfbaaff9c669782aa2c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc016cfda0f8548e4207d5804c6c46e);
#
#
#         var popup_f2d82814b58c5e882187dd84d0042f01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbaa9e372d828596f8b79f3a007b1902 = $(`&lt;div id=&quot;html_bbaa9e372d828596f8b79f3a007b1902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f2d82814b58c5e882187dd84d0042f01.setContent(html_bbaa9e372d828596f8b79f3a007b1902);
#
#
#
#         marker_57b0eedbdc77bfbaaff9c669782aa2c7.bindPopup(popup_f2d82814b58c5e882187dd84d0042f01)
#         ;
#
#
#
#
#             var marker_8f2b76125b13d36614ecbdc381c7d8c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc016cfda0f8548e4207d5804c6c46e);
#
#
#         var popup_d40828d0c70109f83eede16ac7010cab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7697c8d33b38738f5c6011b1960cacec = $(`&lt;div id=&quot;html_7697c8d33b38738f5c6011b1960cacec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d40828d0c70109f83eede16ac7010cab.setContent(html_7697c8d33b38738f5c6011b1960cacec);
#
#
#
#         mark
