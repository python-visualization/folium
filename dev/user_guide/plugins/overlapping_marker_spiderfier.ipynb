# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3430b719dae7c98996c6e3253ab99dd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3430b719dae7c98996c6e3253ab99dd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3430b719dae7c98996c6e3253ab99dd7 = L.map(
#                 &quot;map_3430b719dae7c98996c6e3253ab99dd7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd6a59579a589a9f88b7ca0fc6601a8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd6a59579a589a9f88b7ca0fc6601a8f.addTo(map_3430b719dae7c98996c6e3253ab99dd7);
#
#
#             var marker_2f617233b1ec4875973dddbb8f37cdb2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3430b719dae7c98996c6e3253ab99dd7);
#
#
#         var popup_de0bf52ddf2a800a428013716b6b1f25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_480659844762e2d0c536990f9cbecbe4 = $(`&lt;div id=&quot;html_480659844762e2d0c536990f9cbecbe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_de0bf52ddf2a800a428013716b6b1f25.setContent(html_480659844762e2d0c536990f9cbecbe4);
#
#
#
#         marker_2f617233b1ec4875973dddbb8f37cdb2.bindPopup(popup_de0bf52ddf2a800a428013716b6b1f25)
#         ;
#
#
#
#
#             var marker_44313002687f5809249dfce77a530520 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3430b719dae7c98996c6e3253ab99dd7);
#
#
#         var popup_d2152a2594787b450021e73e8aded7a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b2d14e0e3dad3b226538fcb85ad8654 = $(`&lt;div id=&quot;html_4b2d14e0e3dad3b226538fcb85ad8654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d2152a2594787b450021e73e8aded7a8.setContent(html_4b2d14e0e3dad3b226538fcb85ad8654);
#
#
#
#         marker_44313002687f5809249dfce77a530520.bindPopup(popup_d2152a2594787b450021e73e8aded7a8)
#         ;
#
#
#
#
#             var marker_38e9199bbbf5d410ee46e0762668ac05 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3430b719dae7c98996c6e3253ab99dd7);
#
#
#         var popup_32cb6f9d20fbb4140b0bb545be811cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcb8705c13652d83b18280f771624680 = $(`&lt;div id=&quot;html_bcb8705c13652d83b18280f771624680&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_32cb6f9d20fbb4140b0bb545be811cbf.setContent(html_bcb8705c13652d83b18280f771624680);
#
#
#
#         marker_38e9199bbbf5d410ee46e0762668ac05.bindPopup(popup_32cb6f9d20fbb4140b0bb545be811cbf)
#         ;
#
#
#
#
#             var marker_f340d05e9e6e21fb93cb59208316ae40 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3430b719dae7c98996c6e3253ab99dd7);
#
#
#         var popup_6ec0fefa1084795eab33764a0f122cdd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b17752ad34f7f42774352a8a411f4895 = $(`&lt;div id=&quot;html_b17752ad34f7f42774352a8a411f4895&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6ec0fefa1084795eab33764a0f122cdd.setContent(html_b17752ad34f7f42774352a8a411f4895);
#
#
#
#         marker_f340d05e9e6e21fb93cb59208316ae40.bindPopup(popup_6ec0fefa1084795eab33764a0f122cdd)
#         ;
#
#
#
#
#             var marker_77ec7691ea37078b8dd966ad455454f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3430b719dae7c98996c6e3253ab99dd7);
#
#
#         var popup_bab64231e71cc0fab9297ae1b8fa5f0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5813ab980e595723da3d7915ace42bcf = $(`&lt;div id=&quot;html_5813ab980e595723da3d7915ace42bcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bab64231e71cc0fab9297ae1b8fa5f0e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6efc367829a18c9b72f4e3d182e00f59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6efc367829a18c9b72f4e3d182e00f59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6efc367829a18c9b72f4e3d182e00f59 = L.map(
#                 &quot;map_6efc367829a18c9b72f4e3d182e00f59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57f78e846086213027a3ae08619c4887 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57f78e846086213027a3ae08619c4887.addTo(map_6efc367829a18c9b72f4e3d182e00f59);
#
#
#             var feature_group_b93a35c32a9e6755371bb0f4c33d9b62 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17850b2810168d30e955e0f291f3f74a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b93a35c32a9e6755371bb0f4c33d9b62);
#
#
#         var popup_1bd2bcb3310fb439b5ef93ba5f3af7f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a318201af8342f2d9c6a56cbeae0f91 = $(`&lt;div id=&quot;html_9a318201af8342f2d9c6a56cbeae0f91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1bd2bcb3310fb439b5ef93ba5f3af7f7.setContent(html_9a318201af8342f2d9c6a56cbeae0f91);
#
#
#
#         marker_17850b2810168d30e955e0f291f3f74a.bindPopup(popup_1bd2bcb3310fb439b5ef93ba5f3af7f7)
#         ;
#
#
#
#
#             var marker_eec85e04fe3e954cde2c87ab1561e4c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b93a35c32a9e6755371bb0f4c33d9b62);
#
#
#         var popup_e6bc94ff045681f415161280110e1dce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03920a65c500c160076c7b7f6d5f9583 = $(`&lt;div id=&quot;html_03920a65c500c160076c7b7f6d5f9583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e6bc94ff045681f415161280110e1dce.setContent(html_03920a65c500c160076c7b7f6d5f9583);
#
#
#
#         marker_eec85e04fe3e954cde2c87ab1561e4c6.bindPopup(popup_e6bc94ff045681f415161280110e1dce)
#         ;
#
#
#
#
#             var marker_184334884dcaeb9b3003beeca586a59b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b93a35c32a9e6755371bb0f4c33d9b62);
#
#
#         var popup_269b320122b83f6cae1bd6e58dd881c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c335979542b557136847c404e44d9a8f = $(`&lt;div id=&quot;html_c335979542b557136847c404e44d9a8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_269b320122b83f6cae1bd6e58dd881c2.setContent(html_c335979542b557136847c404e44d9a8f);
#
#
#
#         marker_184334884dcaeb9b3003beeca586a59b.bindPopup(popup_269b320122b83f6cae1bd6e58dd881c2)
#         ;
#
#
#
#
#             var marker_611a89c0e19286553b3d053bd918a888 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b93a35c32a9e6755371bb0f4c33d9b62);
#
#
#         var popup_b028387765a18fc960a18aabbb268a4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fadf0f2cbf01eaec8b951f961c945633 = $(`&lt;div id=&quot;html_fadf0f2cbf01eaec8b951f961c945633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b028387765a18fc960a18aabbb268a4b.setContent(html_fadf0f2cbf01eaec8b951f961c945633);
#
#
#
#         marker_611a89c0e19286553b3d053bd918a888.bindPopup(popup_b028387765a18fc960a18aabbb268a4b)
#         ;
#
#
#
#
#             var marker_c94a93a88e08a292a540b51ac46ec46b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b93a35c32a9e6755371bb0f4c33d9b62);
#
#
#         var popup_20dada432db60598c07142a836edcf71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8218c99194827f1b56d1a6ebd4b7b8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8218c99194827f1b56d1a6ebd4b7b8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8218c99194827f1b56d1a6ebd4b7b8a = L.map(
#                 &quot;map_a8218c99194827f1b56d1a6ebd4b7b8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3ad2d4614275f3e4232d13c40cde89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff3ad2d4614275f3e4232d13c40cde89.addTo(map_a8218c99194827f1b56d1a6ebd4b7b8a);
#
#
#             var feature_group_ae16da0eedeca5f01670ddb77145aeb0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ae16da0eedeca5f01670ddb77145aeb0.addTo(map_a8218c99194827f1b56d1a6ebd4b7b8a);
#
#
#             var feature_group_sub_group_94dc244e0e6e0c57b7d0e7bcb75db03b = L.featureGroup.subGroup(
#                 feature_group_ae16da0eedeca5f01670ddb77145aeb0
#             );
#
#
#             var marker_b9efa8582b6f42ada58c8465043a2e23 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_94dc244e0e6e0c57b7d0e7bcb75db03b);
#
#
#         var popup_998c386f5215acb6253699bef36ea4e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30ab417ce16aad759941b98d39954468 = $(`&lt;div id=&quot;html_30ab417ce16aad759941b98d39954468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_998c386f5215acb6253699bef36ea4e0.setContent(html_30ab417ce16aad759941b98d39954468);
#
#
#
#         marker_b9efa8582b6f42ada58c8465043a2e23.bindPopup(popup_998c386f5215acb6253699bef36ea4e0)
#         ;
#
#
#
#
#             var marker_f21339f8f78147c44b38e00d6ecc1e84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_94dc244e0e6e0c57b7d0e7bcb75db03b);
#
#
#         var popup_01ed8cda510aa6e33e36887afc8fa848 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff2f6aad07e3d4220e45a22bcfba76bf = $(`&lt;div id=&quot;html_ff2f6aad07e3d4220e45a22bcfba76bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_01ed8cda510aa6e33e36887afc8fa848.setContent(html_ff2f6aad07e3d4220e45a22bcfba76bf);
#
#
#
#         marker_f21339f8f78147c44b38e00d6ecc1e84.bindPopup(popup_01ed8cda510aa6e33e36887afc8fa848)
#         ;
#
#
#
#
#             var marker_3cdb807cf55f156d4069c96a80d27ad6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_94dc244e0e6e0c57b7d0e7bcb75db03b);
#
#
#         var popup_7337f236b2cd54ec495167338a3b5c53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c05969f51cc77c9f677e7a6654420288 = $(`&lt;div id=&quot;html_c05969f51cc77c9f677e7a6654420288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7337f236b2cd54ec495167338a3b5c53.setContent(html_c05969f51cc77c9f677e7a6654420288);
#
#
#
#         marker_3cdb807cf55f156d4069c96a80d27ad6.bindPopup(popup_7337f236b2cd54ec495167338a3b5c53)
#         ;
#
#
#
#
#             var marker_047d35e4549d0cb556b8551bc00b977b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_94dc244e0e6e0c57b7d0e7bcb75db03b);
#
#
#         var popup_bbe76f7901014ead694cb64130caa237 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9f9e7a52c0abec0305d9aec278c1da2 = $(`&lt;div id=&quot;html_c9f9e7a52c0abec0305d9aec278c1da2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bbe76f7901014ead694cb64130caa237.setContent(html_c9f9e7a52c0abec0305d9aec278c1da2);
#
#
#
#         marker_
