# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f853cf0c85be50c470c8b7ec82f064e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f853cf0c85be50c470c8b7ec82f064e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f853cf0c85be50c470c8b7ec82f064e8 = L.map(
#                 &quot;map_f853cf0c85be50c470c8b7ec82f064e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_264d2a08cf4c286377dd068edde9ed3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_264d2a08cf4c286377dd068edde9ed3d.addTo(map_f853cf0c85be50c470c8b7ec82f064e8);
#
#
#             var marker_a2ffc85d0eaf382be73bc4c1cc9e9fb5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f853cf0c85be50c470c8b7ec82f064e8);
#
#
#         var popup_c66af235c0f890f419e5fa02dd157f31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a62361f32d5fd013c6ff54b879f4676 = $(`&lt;div id=&quot;html_1a62361f32d5fd013c6ff54b879f4676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c66af235c0f890f419e5fa02dd157f31.setContent(html_1a62361f32d5fd013c6ff54b879f4676);
#
#
#
#         marker_a2ffc85d0eaf382be73bc4c1cc9e9fb5.bindPopup(popup_c66af235c0f890f419e5fa02dd157f31)
#         ;
#
#
#
#
#             var marker_863acf6747b4c86f4b3df71dfca7e914 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f853cf0c85be50c470c8b7ec82f064e8);
#
#
#         var popup_c48aa745f572fe9da31263f2b823e2fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f989b9e21c8c061d3a4781f9eb1d5441 = $(`&lt;div id=&quot;html_f989b9e21c8c061d3a4781f9eb1d5441&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c48aa745f572fe9da31263f2b823e2fa.setContent(html_f989b9e21c8c061d3a4781f9eb1d5441);
#
#
#
#         marker_863acf6747b4c86f4b3df71dfca7e914.bindPopup(popup_c48aa745f572fe9da31263f2b823e2fa)
#         ;
#
#
#
#
#             var marker_2f208f4102ca2a0f7f6a81ee05bbfca3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f853cf0c85be50c470c8b7ec82f064e8);
#
#
#         var popup_0048d68e02e4e68ce5cc39892b3e808a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_884f3734fbedb8e7c79c90c95fbc74c0 = $(`&lt;div id=&quot;html_884f3734fbedb8e7c79c90c95fbc74c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0048d68e02e4e68ce5cc39892b3e808a.setContent(html_884f3734fbedb8e7c79c90c95fbc74c0);
#
#
#
#         marker_2f208f4102ca2a0f7f6a81ee05bbfca3.bindPopup(popup_0048d68e02e4e68ce5cc39892b3e808a)
#         ;
#
#
#
#
#             var marker_1bab61a712270873b95662c46503fa5f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f853cf0c85be50c470c8b7ec82f064e8);
#
#
#         var popup_b69710a4cee9ec86e8f8721e714a9b67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b660c908429bb34757d7d24a535fb03 = $(`&lt;div id=&quot;html_1b660c908429bb34757d7d24a535fb03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b69710a4cee9ec86e8f8721e714a9b67.setContent(html_1b660c908429bb34757d7d24a535fb03);
#
#
#
#         marker_1bab61a712270873b95662c46503fa5f.bindPopup(popup_b69710a4cee9ec86e8f8721e714a9b67)
#         ;
#
#
#
#
#             var marker_15cacb30cf3b72d1f79c8e2a6755bf1c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f853cf0c85be50c470c8b7ec82f064e8);
#
#
#         var popup_6863838f7dd9cffadc9a699e76866ffb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_817a93b5648ec99686acd597466b3913 = $(`&lt;div id=&quot;html_817a93b5648ec99686acd597466b3913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6863838f7dd9cffadc9a699e76866ffb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93b941a6ec013087bfc62ce01cfa498b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93b941a6ec013087bfc62ce01cfa498b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93b941a6ec013087bfc62ce01cfa498b = L.map(
#                 &quot;map_93b941a6ec013087bfc62ce01cfa498b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3dfeffc3402b1fdc10f45ee0918d95e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3dfeffc3402b1fdc10f45ee0918d95e3.addTo(map_93b941a6ec013087bfc62ce01cfa498b);
#
#
#             var feature_group_599339fbbceb01aa3212109604f5747e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3052f3dcfeb076c3aa45364dc002b088 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_599339fbbceb01aa3212109604f5747e);
#
#
#         var popup_51123d7f8eebf441395af8adb64b04f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a00bd099cf4d82a3ced3eae37c6364ea = $(`&lt;div id=&quot;html_a00bd099cf4d82a3ced3eae37c6364ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_51123d7f8eebf441395af8adb64b04f4.setContent(html_a00bd099cf4d82a3ced3eae37c6364ea);
#
#
#
#         marker_3052f3dcfeb076c3aa45364dc002b088.bindPopup(popup_51123d7f8eebf441395af8adb64b04f4)
#         ;
#
#
#
#
#             var marker_9a3060900dbdc38cd6b1934cb345b3b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_599339fbbceb01aa3212109604f5747e);
#
#
#         var popup_e6f19fe6560258b65eb0d6f426681a97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce7111e7b9e842af9ff5bec762eab5b7 = $(`&lt;div id=&quot;html_ce7111e7b9e842af9ff5bec762eab5b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e6f19fe6560258b65eb0d6f426681a97.setContent(html_ce7111e7b9e842af9ff5bec762eab5b7);
#
#
#
#         marker_9a3060900dbdc38cd6b1934cb345b3b9.bindPopup(popup_e6f19fe6560258b65eb0d6f426681a97)
#         ;
#
#
#
#
#             var marker_ea0268a9e1a7a8fe8cc36c8b2205ce7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_599339fbbceb01aa3212109604f5747e);
#
#
#         var popup_c72efbde553148271fdc2f7a17cb47ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaec0dd3649d9d88ea9605d2c5d99208 = $(`&lt;div id=&quot;html_eaec0dd3649d9d88ea9605d2c5d99208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c72efbde553148271fdc2f7a17cb47ae.setContent(html_eaec0dd3649d9d88ea9605d2c5d99208);
#
#
#
#         marker_ea0268a9e1a7a8fe8cc36c8b2205ce7c.bindPopup(popup_c72efbde553148271fdc2f7a17cb47ae)
#         ;
#
#
#
#
#             var marker_35bb8f0620081380006b1576e1df5e65 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_599339fbbceb01aa3212109604f5747e);
#
#
#         var popup_205dd57933b803dcbb339af97d4475da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb0a7b5c1f15a7be3d7416a1d5f484dd = $(`&lt;div id=&quot;html_fb0a7b5c1f15a7be3d7416a1d5f484dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_205dd57933b803dcbb339af97d4475da.setContent(html_fb0a7b5c1f15a7be3d7416a1d5f484dd);
#
#
#
#         marker_35bb8f0620081380006b1576e1df5e65.bindPopup(popup_205dd57933b803dcbb339af97d4475da)
#         ;
#
#
#
#
#             var marker_b81f3dddeca942feef2ba18c34abce93 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_599339fbbceb01aa3212109604f5747e);
#
#
#         var popup_82df05578d726e8134d05a38a7cf5f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fca9df8b3363959cb36142b7967e057 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fca9df8b3363959cb36142b7967e057&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fca9df8b3363959cb36142b7967e057 = L.map(
#                 &quot;map_4fca9df8b3363959cb36142b7967e057&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad22e00f36826dbf4cf3fda168f971f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad22e00f36826dbf4cf3fda168f971f0.addTo(map_4fca9df8b3363959cb36142b7967e057);
#
#
#             var feature_group_c24374785f0899ed5023de610ff8ab1d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c24374785f0899ed5023de610ff8ab1d.addTo(map_4fca9df8b3363959cb36142b7967e057);
#
#
#             var feature_group_sub_group_1eedae406395f7421f8da20bc926f5c7 = L.featureGroup.subGroup(
#                 feature_group_c24374785f0899ed5023de610ff8ab1d
#             );
#
#
#             var marker_b075f9cd68ba521e1972ff356deda143 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eedae406395f7421f8da20bc926f5c7);
#
#
#         var popup_9c7e7cea7908a0dad6fa5b3e70eaddb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5987137696a2b241c924fc4dae38dad1 = $(`&lt;div id=&quot;html_5987137696a2b241c924fc4dae38dad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9c7e7cea7908a0dad6fa5b3e70eaddb3.setContent(html_5987137696a2b241c924fc4dae38dad1);
#
#
#
#         marker_b075f9cd68ba521e1972ff356deda143.bindPopup(popup_9c7e7cea7908a0dad6fa5b3e70eaddb3)
#         ;
#
#
#
#
#             var marker_7728147d21cd880d97ceb3c537116d75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eedae406395f7421f8da20bc926f5c7);
#
#
#         var popup_999fd96b0cc0bb075880013433de9b5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be762c61b3776f92b36b932c75f5a870 = $(`&lt;div id=&quot;html_be762c61b3776f92b36b932c75f5a870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_999fd96b0cc0bb075880013433de9b5e.setContent(html_be762c61b3776f92b36b932c75f5a870);
#
#
#
#         marker_7728147d21cd880d97ceb3c537116d75.bindPopup(popup_999fd96b0cc0bb075880013433de9b5e)
#         ;
#
#
#
#
#             var marker_c923153b6458a7289b072dcf278a5977 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eedae406395f7421f8da20bc926f5c7);
#
#
#         var popup_0111027ed5874d6d3ba0bd4fac18bd47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c65ed876c94cb1f9867845f03165606 = $(`&lt;div id=&quot;html_1c65ed876c94cb1f9867845f03165606&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0111027ed5874d6d3ba0bd4fac18bd47.setContent(html_1c65ed876c94cb1f9867845f03165606);
#
#
#
#         marker_c923153b6458a7289b072dcf278a5977.bindPopup(popup_0111027ed5874d6d3ba0bd4fac18bd47)
#         ;
#
#
#
#
#             var marker_3e233cf467a670a1e28eb6ec70317b46 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eedae406395f7421f8da20bc926f5c7);
#
#
#         var popup_2302339198deffa66f4c41f5896e7689 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08c0fa05a875518eafe43faedb14d850 = $(`&lt;div id=&quot;html_08c0fa05a875518eafe43faedb14d850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2302339198deffa66f4c41f5896e7689.setContent(html_08c0fa05a875518eafe43faedb14d850);
#
#
#
#         marker_
