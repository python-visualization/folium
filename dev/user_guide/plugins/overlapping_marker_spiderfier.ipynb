# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7e0d2a4984baf74a8ace445fdbd5f62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7e0d2a4984baf74a8ace445fdbd5f62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7e0d2a4984baf74a8ace445fdbd5f62 = L.map(
#                 &quot;map_c7e0d2a4984baf74a8ace445fdbd5f62&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abf27975573f31907f5dc681511ca547 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abf27975573f31907f5dc681511ca547.addTo(map_c7e0d2a4984baf74a8ace445fdbd5f62);
#
#
#             var marker_5f8ea9a8637ffc3b61aec452b98c6e87 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c7e0d2a4984baf74a8ace445fdbd5f62);
#
#
#         var popup_224fecbd8a2ffbbf3a0626477831e552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d337a474fc4d4166fd10dd0cdb1b7ee5 = $(`&lt;div id=&quot;html_d337a474fc4d4166fd10dd0cdb1b7ee5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_224fecbd8a2ffbbf3a0626477831e552.setContent(html_d337a474fc4d4166fd10dd0cdb1b7ee5);
#
#
#
#         marker_5f8ea9a8637ffc3b61aec452b98c6e87.bindPopup(popup_224fecbd8a2ffbbf3a0626477831e552)
#         ;
#
#
#
#
#             var marker_9d5e4e8b72259fce83acacf038e17039 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c7e0d2a4984baf74a8ace445fdbd5f62);
#
#
#         var popup_4c7c3c8b406baf734ee0fb842f154922 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b35369fbe16453ff7bed192821186be5 = $(`&lt;div id=&quot;html_b35369fbe16453ff7bed192821186be5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4c7c3c8b406baf734ee0fb842f154922.setContent(html_b35369fbe16453ff7bed192821186be5);
#
#
#
#         marker_9d5e4e8b72259fce83acacf038e17039.bindPopup(popup_4c7c3c8b406baf734ee0fb842f154922)
#         ;
#
#
#
#
#             var marker_9040813d94234d1e5bd37be92d7b5272 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c7e0d2a4984baf74a8ace445fdbd5f62);
#
#
#         var popup_cb948e8621436720a83eac0fb32d0cff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac5b06914611f74a2d98034f80b69154 = $(`&lt;div id=&quot;html_ac5b06914611f74a2d98034f80b69154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cb948e8621436720a83eac0fb32d0cff.setContent(html_ac5b06914611f74a2d98034f80b69154);
#
#
#
#         marker_9040813d94234d1e5bd37be92d7b5272.bindPopup(popup_cb948e8621436720a83eac0fb32d0cff)
#         ;
#
#
#
#
#             var marker_c425b38066f9975975a78d91d6713b75 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c7e0d2a4984baf74a8ace445fdbd5f62);
#
#
#         var popup_5839377d5c01763a9063b75c93d34e68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9942a9a91621f6bf60a935787f1665f = $(`&lt;div id=&quot;html_e9942a9a91621f6bf60a935787f1665f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5839377d5c01763a9063b75c93d34e68.setContent(html_e9942a9a91621f6bf60a935787f1665f);
#
#
#
#         marker_c425b38066f9975975a78d91d6713b75.bindPopup(popup_5839377d5c01763a9063b75c93d34e68)
#         ;
#
#
#
#
#             var marker_b00dfb75929538b11ff55ba9f63278b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c7e0d2a4984baf74a8ace445fdbd5f62);
#
#
#         var popup_1ab0acdc410933612afd9ff3f9d4df87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d150f273de1a17b6205246b3f85713d = $(`&lt;div id=&quot;html_4d150f273de1a17b6205246b3f85713d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1ab0acdc410933612afd9ff3f9d4df87.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a870f5246f3b5bcc5af3d8e5f72bdff5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a870f5246f3b5bcc5af3d8e5f72bdff5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a870f5246f3b5bcc5af3d8e5f72bdff5 = L.map(
#                 &quot;map_a870f5246f3b5bcc5af3d8e5f72bdff5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3f1fdff84093c2371afaa4da0140f1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3f1fdff84093c2371afaa4da0140f1a.addTo(map_a870f5246f3b5bcc5af3d8e5f72bdff5);
#
#
#             var feature_group_6b8d95253bc917fe766bf38a689fd3b8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d27e2ce4edf488a8951ff65fb96658ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6b8d95253bc917fe766bf38a689fd3b8);
#
#
#         var popup_1cb34d66f9ed4c7aebae5b722729ec14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd9d357052fe1c33bb9a327a829f065a = $(`&lt;div id=&quot;html_fd9d357052fe1c33bb9a327a829f065a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1cb34d66f9ed4c7aebae5b722729ec14.setContent(html_fd9d357052fe1c33bb9a327a829f065a);
#
#
#
#         marker_d27e2ce4edf488a8951ff65fb96658ef.bindPopup(popup_1cb34d66f9ed4c7aebae5b722729ec14)
#         ;
#
#
#
#
#             var marker_ef6f185af569a38de6967404c9680444 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6b8d95253bc917fe766bf38a689fd3b8);
#
#
#         var popup_c150d2044bf72d0e0a19564de9d6958f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29515c3f45127a096af97dfc7d91ae8f = $(`&lt;div id=&quot;html_29515c3f45127a096af97dfc7d91ae8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c150d2044bf72d0e0a19564de9d6958f.setContent(html_29515c3f45127a096af97dfc7d91ae8f);
#
#
#
#         marker_ef6f185af569a38de6967404c9680444.bindPopup(popup_c150d2044bf72d0e0a19564de9d6958f)
#         ;
#
#
#
#
#             var marker_53a6f8170e39f05ba49c132e0a1984cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6b8d95253bc917fe766bf38a689fd3b8);
#
#
#         var popup_c66da15c68b4af03f01742e837eb4dff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baeb90027aec89a819afc62692697f42 = $(`&lt;div id=&quot;html_baeb90027aec89a819afc62692697f42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c66da15c68b4af03f01742e837eb4dff.setContent(html_baeb90027aec89a819afc62692697f42);
#
#
#
#         marker_53a6f8170e39f05ba49c132e0a1984cd.bindPopup(popup_c66da15c68b4af03f01742e837eb4dff)
#         ;
#
#
#
#
#             var marker_c55557e95cb7c5e13ed5565b51a6ba6f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6b8d95253bc917fe766bf38a689fd3b8);
#
#
#         var popup_026e8a63e7e8bd6068cb5b3ac678666d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dfe5ece52a8c13f2906aaffc25488ba = $(`&lt;div id=&quot;html_9dfe5ece52a8c13f2906aaffc25488ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_026e8a63e7e8bd6068cb5b3ac678666d.setContent(html_9dfe5ece52a8c13f2906aaffc25488ba);
#
#
#
#         marker_c55557e95cb7c5e13ed5565b51a6ba6f.bindPopup(popup_026e8a63e7e8bd6068cb5b3ac678666d)
#         ;
#
#
#
#
#             var marker_cfbdef1af4a58e39b2aac03f20deb07a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6b8d95253bc917fe766bf38a689fd3b8);
#
#
#         var popup_3a355d8933b98726c2d7b573935fe0de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee2c8d057fc1fa42016647385c0b1aae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee2c8d057fc1fa42016647385c0b1aae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee2c8d057fc1fa42016647385c0b1aae = L.map(
#                 &quot;map_ee2c8d057fc1fa42016647385c0b1aae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b1648271e3123f51067443bb8b28fbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b1648271e3123f51067443bb8b28fbf.addTo(map_ee2c8d057fc1fa42016647385c0b1aae);
#
#
#             var feature_group_63ec8e1ebd26f92cc33f77fa21664f61 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_63ec8e1ebd26f92cc33f77fa21664f61.addTo(map_ee2c8d057fc1fa42016647385c0b1aae);
#
#
#             var feature_group_sub_group_4abd294d02390a56ad2abacc2264ea6b = L.featureGroup.subGroup(
#                 feature_group_63ec8e1ebd26f92cc33f77fa21664f61
#             );
#
#
#             var marker_69574f6db148254b195115ea6c9dcb35 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4abd294d02390a56ad2abacc2264ea6b);
#
#
#         var popup_2f46a25b02a27e1dd7f41f92aef84c71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa0b636c973b90b27f9152d698b19dd5 = $(`&lt;div id=&quot;html_fa0b636c973b90b27f9152d698b19dd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2f46a25b02a27e1dd7f41f92aef84c71.setContent(html_fa0b636c973b90b27f9152d698b19dd5);
#
#
#
#         marker_69574f6db148254b195115ea6c9dcb35.bindPopup(popup_2f46a25b02a27e1dd7f41f92aef84c71)
#         ;
#
#
#
#
#             var marker_d206f0a00fea4110e973021a5ce655ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4abd294d02390a56ad2abacc2264ea6b);
#
#
#         var popup_ae48ef1fe73a58e15c9675f5c2611bec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f91357a4cdb9f6ffa19ff14b1d9f6ba = $(`&lt;div id=&quot;html_9f91357a4cdb9f6ffa19ff14b1d9f6ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ae48ef1fe73a58e15c9675f5c2611bec.setContent(html_9f91357a4cdb9f6ffa19ff14b1d9f6ba);
#
#
#
#         marker_d206f0a00fea4110e973021a5ce655ea.bindPopup(popup_ae48ef1fe73a58e15c9675f5c2611bec)
#         ;
#
#
#
#
#             var marker_1ac0281bda7d285497b5778604d08a9b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4abd294d02390a56ad2abacc2264ea6b);
#
#
#         var popup_502271574df0d598e99212911ba6c879 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29d6e3fa68df7467322b53756eb67220 = $(`&lt;div id=&quot;html_29d6e3fa68df7467322b53756eb67220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_502271574df0d598e99212911ba6c879.setContent(html_29d6e3fa68df7467322b53756eb67220);
#
#
#
#         marker_1ac0281bda7d285497b5778604d08a9b.bindPopup(popup_502271574df0d598e99212911ba6c879)
#         ;
#
#
#
#
#             var marker_e687f232ceb3704d12e14cd32c21c6bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4abd294d02390a56ad2abacc2264ea6b);
#
#
#         var popup_942e1b329dd4e3967a2f14cea55823df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63d1c91210d1631e906a99613c2f5983 = $(`&lt;div id=&quot;html_63d1c91210d1631e906a99613c2f5983&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_942e1b329dd4e3967a2f14cea55823df.setContent(html_63d1c91210d1631e906a99613c2f5983);
#
#
#
#         marker_
