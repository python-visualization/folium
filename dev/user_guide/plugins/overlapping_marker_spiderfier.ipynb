# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e78af6afae973cb350e58512756bc79 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e78af6afae973cb350e58512756bc79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e78af6afae973cb350e58512756bc79 = L.map(
#                 &quot;map_4e78af6afae973cb350e58512756bc79&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b50aa7b0230619dbbf559b7024f2dc66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b50aa7b0230619dbbf559b7024f2dc66.addTo(map_4e78af6afae973cb350e58512756bc79);
#
#
#             var marker_ded6bc496ce3214dd6b14bf7ababd301 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4e78af6afae973cb350e58512756bc79);
#
#
#         var popup_13cd693b65375e987f048c74a401e188 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e3ad955435db136002d3239c01394c2 = $(`&lt;div id=&quot;html_2e3ad955435db136002d3239c01394c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_13cd693b65375e987f048c74a401e188.setContent(html_2e3ad955435db136002d3239c01394c2);
#
#
#
#         marker_ded6bc496ce3214dd6b14bf7ababd301.bindPopup(popup_13cd693b65375e987f048c74a401e188)
#         ;
#
#
#
#
#             var marker_ba4170b89ca6cde825ac7189284db99b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4e78af6afae973cb350e58512756bc79);
#
#
#         var popup_dd571e1e00925ba6f565f6a35b503110 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42b1cacdaa792fb5bdab3b0148ee5392 = $(`&lt;div id=&quot;html_42b1cacdaa792fb5bdab3b0148ee5392&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dd571e1e00925ba6f565f6a35b503110.setContent(html_42b1cacdaa792fb5bdab3b0148ee5392);
#
#
#
#         marker_ba4170b89ca6cde825ac7189284db99b.bindPopup(popup_dd571e1e00925ba6f565f6a35b503110)
#         ;
#
#
#
#
#             var marker_eae01beab572a34273460c147d48e0d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4e78af6afae973cb350e58512756bc79);
#
#
#         var popup_ad7e9e699357d544f4dcb18880994346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abdd9a4c6750f8334218c76d5946ab47 = $(`&lt;div id=&quot;html_abdd9a4c6750f8334218c76d5946ab47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ad7e9e699357d544f4dcb18880994346.setContent(html_abdd9a4c6750f8334218c76d5946ab47);
#
#
#
#         marker_eae01beab572a34273460c147d48e0d0.bindPopup(popup_ad7e9e699357d544f4dcb18880994346)
#         ;
#
#
#
#
#             var marker_b7855391f9ae39b5af4cd49f27eb1cff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4e78af6afae973cb350e58512756bc79);
#
#
#         var popup_ea99f62f26213e3716cc16c4dc74aeeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bbe40c54bbdd70ef206c907ee201b12 = $(`&lt;div id=&quot;html_5bbe40c54bbdd70ef206c907ee201b12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ea99f62f26213e3716cc16c4dc74aeeb.setContent(html_5bbe40c54bbdd70ef206c907ee201b12);
#
#
#
#         marker_b7855391f9ae39b5af4cd49f27eb1cff.bindPopup(popup_ea99f62f26213e3716cc16c4dc74aeeb)
#         ;
#
#
#
#
#             var marker_e2793af8f056f6f523dc28c2c886b21e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4e78af6afae973cb350e58512756bc79);
#
#
#         var popup_b563eb823cfcb4685cbb7dc68c48b5ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31f1ae7f6a67ea29c8623fc96dcfc3bc = $(`&lt;div id=&quot;html_31f1ae7f6a67ea29c8623fc96dcfc3bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b563eb823cfcb4685cbb7dc68c48b5ae.setContent(html_31f1ae7f6a67ea29c8623fc96dcfc3bc);
#
#
#
#         marker_e2793af8f056f6f523dc28c2c886b21e.bindPopup(popup_b563eb823cfcb4685cbb7dc68c48b5ae)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c81a3494e27e2296cb44d29c56836f3b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c81a3494e27e2296cb44d29c56836f3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c81a3494e27e2296cb44d29c56836f3b = L.map(
#                 &quot;map_c81a3494e27e2296cb44d29c56836f3b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_715e617251f84ac183883386dd13dbe3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_715e617251f84ac183883386dd13dbe3.addTo(map_c81a3494e27e2296cb44d29c56836f3b);
#
#
#             var feature_group_69db46ee1ca3a6e9535797328755bd2b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4250187df433f2d6cf20f9d8aca64d6d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_69db46ee1ca3a6e9535797328755bd2b);
#
#
#         var popup_cf068a86f2289551e0fbc2baa22109d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49617415c4564abc73f6047aa25bb1c5 = $(`&lt;div id=&quot;html_49617415c4564abc73f6047aa25bb1c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cf068a86f2289551e0fbc2baa22109d7.setContent(html_49617415c4564abc73f6047aa25bb1c5);
#
#
#
#         marker_4250187df433f2d6cf20f9d8aca64d6d.bindPopup(popup_cf068a86f2289551e0fbc2baa22109d7)
#         ;
#
#
#
#
#             var marker_20757e4efe8b7b01e6f46e8c575b8ecd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_69db46ee1ca3a6e9535797328755bd2b);
#
#
#         var popup_bd9f735e0f14d6806ff75c3b65b8911a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f5eba253e0c9917100570bf6e7bb8f3 = $(`&lt;div id=&quot;html_5f5eba253e0c9917100570bf6e7bb8f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bd9f735e0f14d6806ff75c3b65b8911a.setContent(html_5f5eba253e0c9917100570bf6e7bb8f3);
#
#
#
#         marker_20757e4efe8b7b01e6f46e8c575b8ecd.bindPopup(popup_bd9f735e0f14d6806ff75c3b65b8911a)
#         ;
#
#
#
#
#             var marker_26c287ff1112b96a4dba444ae86bc4ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_69db46ee1ca3a6e9535797328755bd2b);
#
#
#         var popup_5beed2aecdf7374581395945a3a3925f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f2d522159fe5e27f69962c6737e0e8e = $(`&lt;div id=&quot;html_2f2d522159fe5e27f69962c6737e0e8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5beed2aecdf7374581395945a3a3925f.setContent(html_2f2d522159fe5e27f69962c6737e0e8e);
#
#
#
#         marker_26c287ff1112b96a4dba444ae86bc4ed.bindPopup(popup_5beed2aecdf7374581395945a3a3925f)
#         ;
#
#
#
#
#             var marker_fbbc44d6c46522aac67f0ec73a117a87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_69db46ee1ca3a6e9535797328755bd2b);
#
#
#         var popup_bf48738b77f4c3830164e0e77e3a4d8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c792bf74aa138ef777b5949b5a7f48 = $(`&lt;div id=&quot;html_f5c792bf74aa138ef777b5949b5a7f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bf48738b77f4c3830164e0e77e3a4d8c.setContent(html_f5c792bf74aa138ef777b5949b5a7f48);
#
#
#
#         marker_fbbc44d6c46522aac67f0ec73a117a87.bindPopup(popup_bf48738b77f4c3830164e0e77e3a4d8c)
#         ;
#
#
#
#
#             var marker_16b0dc10c3aea1675630b8e1960b0c25 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_69db46ee1ca3a6e9535797328755bd2b);
#
#
#         var popup_aa74e9e1cb64a95a74e5d3b978a05c94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62e5508beca38c71d9585a95a88f38c3 = $(`&lt;div id=&quot;html_62e5508beca38c71d9585a95a88f38c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e443a23ac08592ecc1e94c0d1db9f3ab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e443a23ac08592ecc1e94c0d1db9f3ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e443a23ac08592ecc1e94c0d1db9f3ab = L.map(
#                 &quot;map_e443a23ac08592ecc1e94c0d1db9f3ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_924f97085ba96111302e73bf3921a94c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_924f97085ba96111302e73bf3921a94c.addTo(map_e443a23ac08592ecc1e94c0d1db9f3ab);
#
#
#             var feature_group_864ed934a4fbeb2eba7c33b7edd986fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_864ed934a4fbeb2eba7c33b7edd986fe.addTo(map_e443a23ac08592ecc1e94c0d1db9f3ab);
#
#
#             var feature_group_sub_group_9b7b9c407c219d43a63c3c461f2b2f5e = L.featureGroup.subGroup(
#                 feature_group_864ed934a4fbeb2eba7c33b7edd986fe
#             );
#
#
#             var marker_8937b366ba5a4d4154540cd933957367 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9b7b9c407c219d43a63c3c461f2b2f5e);
#
#
#         var popup_5b41c31d3b7a407c6db22f4c066cb280 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b40ec851423390a4839b8c1df19be446 = $(`&lt;div id=&quot;html_b40ec851423390a4839b8c1df19be446&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5b41c31d3b7a407c6db22f4c066cb280.setContent(html_b40ec851423390a4839b8c1df19be446);
#
#
#
#         marker_8937b366ba5a4d4154540cd933957367.bindPopup(popup_5b41c31d3b7a407c6db22f4c066cb280)
#         ;
#
#
#
#
#             var marker_3fc69ac6f29dc833986d8a9a1d45a445 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9b7b9c407c219d43a63c3c461f2b2f5e);
#
#
#         var popup_e196b43b2d4ecf59bcc67159ecacb508 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f5698110fcf5f2c980ef24590f72575 = $(`&lt;div id=&quot;html_1f5698110fcf5f2c980ef24590f72575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e196b43b2d4ecf59bcc67159ecacb508.setContent(html_1f5698110fcf5f2c980ef24590f72575);
#
#
#
#         marker_3fc69ac6f29dc833986d8a9a1d45a445.bindPopup(popup_e196b43b2d4ecf59bcc67159ecacb508)
#         ;
#
#
#
#
#             var marker_b8784135a737e4b24f2dd0cd95e0ef62 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9b7b9c407c219d43a63c3c461f2b2f5e);
#
#
#         var popup_c294d61835bfc4cd94b2ec0cc4a4ec59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d88ba67b7f753882ac6c6c625e45263 = $(`&lt;div id=&quot;html_9d88ba67b7f753882ac6c6c625e45263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c294d61835bfc4cd94b2ec0cc4a4ec59.setContent(html_9d88ba67b7f753882ac6c6c625e45263);
#
#
#
#         marker_b8784135a737e4b24f2dd0cd95e0ef62.bindPopup(popup_c294d61835bfc4cd94b2ec0cc4a4ec59)
#         ;
#
#
#
#
#             var marker_1f00c3ea5f06bd5f86f01a760a1987b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9b7b9c407c219d43a63c3c461f2b2f5e);
#
#
#         var popup_dbf0403097e0d1987c6cbec43f561af5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16dc35f158f7ffba1d23de25e3021424 = $(`&lt;div id=&quot;html_16dc35f158f7ffba1d23de25e3021424&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dbf0403097e0d1987c6cbec43f561af5.setContent(html_16dc35f158f7ffba1d23de25e3021424);
#
#
#
#         marker_1f00c3ea5f06bd5f86f01a760a1987b3.bindPopup(popup_dbf0403097e0d1987c6cbec43f561af5)
#         ;
#
#
#
#
#             var marker_6df184b852aeb32d0c019c4fb939d67a = L.marker(
#                 [45.0503999
