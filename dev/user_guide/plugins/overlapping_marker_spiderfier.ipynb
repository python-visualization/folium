# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52b8760924fdd0230595b0be89b670d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52b8760924fdd0230595b0be89b670d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52b8760924fdd0230595b0be89b670d9 = L.map(
#                 &quot;map_52b8760924fdd0230595b0be89b670d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c120389de8238c7559c3cc34de9f69ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c120389de8238c7559c3cc34de9f69ca.addTo(map_52b8760924fdd0230595b0be89b670d9);
#
#
#             var marker_c6c27fd9c6826ccd0c6de20bc0b86c02 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_52b8760924fdd0230595b0be89b670d9);
#
#
#         var popup_a5e8ed933faab6f5a6ecb1f372c97fb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbd3b82334c4019b3a422761e584fd22 = $(`&lt;div id=&quot;html_dbd3b82334c4019b3a422761e584fd22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a5e8ed933faab6f5a6ecb1f372c97fb0.setContent(html_dbd3b82334c4019b3a422761e584fd22);
#
#
#
#         marker_c6c27fd9c6826ccd0c6de20bc0b86c02.bindPopup(popup_a5e8ed933faab6f5a6ecb1f372c97fb0)
#         ;
#
#
#
#
#             var marker_ad0c8a0dc99a10afa813ac1091ef6e80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_52b8760924fdd0230595b0be89b670d9);
#
#
#         var popup_e83ea9a949bfc32f6628869a1bdff01a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9403ce2db150a60ff5beed1616aabedd = $(`&lt;div id=&quot;html_9403ce2db150a60ff5beed1616aabedd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e83ea9a949bfc32f6628869a1bdff01a.setContent(html_9403ce2db150a60ff5beed1616aabedd);
#
#
#
#         marker_ad0c8a0dc99a10afa813ac1091ef6e80.bindPopup(popup_e83ea9a949bfc32f6628869a1bdff01a)
#         ;
#
#
#
#
#             var marker_8281bfe48ad32f447ca9f9183223bcbf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_52b8760924fdd0230595b0be89b670d9);
#
#
#         var popup_33c5c736c50cd619c0dca71acabc30ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f55332283db0cf0353d16433b6f19343 = $(`&lt;div id=&quot;html_f55332283db0cf0353d16433b6f19343&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_33c5c736c50cd619c0dca71acabc30ca.setContent(html_f55332283db0cf0353d16433b6f19343);
#
#
#
#         marker_8281bfe48ad32f447ca9f9183223bcbf.bindPopup(popup_33c5c736c50cd619c0dca71acabc30ca)
#         ;
#
#
#
#
#             var marker_80f5bff8a551833362abb0fb79a29888 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_52b8760924fdd0230595b0be89b670d9);
#
#
#         var popup_7a69b89c78bb2a3e845f246d9f248ba8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5366e6ad1e9d59194ab91979d1aa29a8 = $(`&lt;div id=&quot;html_5366e6ad1e9d59194ab91979d1aa29a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7a69b89c78bb2a3e845f246d9f248ba8.setContent(html_5366e6ad1e9d59194ab91979d1aa29a8);
#
#
#
#         marker_80f5bff8a551833362abb0fb79a29888.bindPopup(popup_7a69b89c78bb2a3e845f246d9f248ba8)
#         ;
#
#
#
#
#             var marker_50dcf7e09d906cc236a721032ca10428 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_52b8760924fdd0230595b0be89b670d9);
#
#
#         var popup_c4ccf6e7edfb1dfa3ef883cc994f2505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ed5324ceae2cd1297a81e284f8230d0 = $(`&lt;div id=&quot;html_0ed5324ceae2cd1297a81e284f8230d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c4ccf6e7edfb1dfa3ef883cc994f2505.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26e21f48fa10d2e6c37d4d51e5b1a7d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26e21f48fa10d2e6c37d4d51e5b1a7d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26e21f48fa10d2e6c37d4d51e5b1a7d0 = L.map(
#                 &quot;map_26e21f48fa10d2e6c37d4d51e5b1a7d0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39345935c9d938435616e4d0f8daa08d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39345935c9d938435616e4d0f8daa08d.addTo(map_26e21f48fa10d2e6c37d4d51e5b1a7d0);
#
#
#             var feature_group_c542f03c5bd989e4fe96a5f38de1eee7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c91088a1d5d7bac0d594331c7c427c34 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c542f03c5bd989e4fe96a5f38de1eee7);
#
#
#         var popup_d1a8aa49457cf74060f981543b0a20fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e008b5378918bf7c27e8dec0347d446e = $(`&lt;div id=&quot;html_e008b5378918bf7c27e8dec0347d446e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d1a8aa49457cf74060f981543b0a20fa.setContent(html_e008b5378918bf7c27e8dec0347d446e);
#
#
#
#         marker_c91088a1d5d7bac0d594331c7c427c34.bindPopup(popup_d1a8aa49457cf74060f981543b0a20fa)
#         ;
#
#
#
#
#             var marker_1acc6902ac4813fe84da83b9457fd179 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c542f03c5bd989e4fe96a5f38de1eee7);
#
#
#         var popup_fc4d09d15b595bed3ab65138992e2f95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e914064934e4d7a93d57b0242dc2a559 = $(`&lt;div id=&quot;html_e914064934e4d7a93d57b0242dc2a559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fc4d09d15b595bed3ab65138992e2f95.setContent(html_e914064934e4d7a93d57b0242dc2a559);
#
#
#
#         marker_1acc6902ac4813fe84da83b9457fd179.bindPopup(popup_fc4d09d15b595bed3ab65138992e2f95)
#         ;
#
#
#
#
#             var marker_586889c0113a72a474814090321ed832 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c542f03c5bd989e4fe96a5f38de1eee7);
#
#
#         var popup_e168cb2e2f820f8b6dc857cf815bb1b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc38ed6eb24db9bf34da15f65372ffc9 = $(`&lt;div id=&quot;html_bc38ed6eb24db9bf34da15f65372ffc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e168cb2e2f820f8b6dc857cf815bb1b1.setContent(html_bc38ed6eb24db9bf34da15f65372ffc9);
#
#
#
#         marker_586889c0113a72a474814090321ed832.bindPopup(popup_e168cb2e2f820f8b6dc857cf815bb1b1)
#         ;
#
#
#
#
#             var marker_6a46418456f1ec142863391ac93a3dc8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c542f03c5bd989e4fe96a5f38de1eee7);
#
#
#         var popup_47dcfd60ef1cc6ce1af32b09d778a9c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af35f4f1179ee3e33576fcf15327b2fa = $(`&lt;div id=&quot;html_af35f4f1179ee3e33576fcf15327b2fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_47dcfd60ef1cc6ce1af32b09d778a9c8.setContent(html_af35f4f1179ee3e33576fcf15327b2fa);
#
#
#
#         marker_6a46418456f1ec142863391ac93a3dc8.bindPopup(popup_47dcfd60ef1cc6ce1af32b09d778a9c8)
#         ;
#
#
#
#
#             var marker_6c527352b9886d9dc0bd645eb3af96af = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c542f03c5bd989e4fe96a5f38de1eee7);
#
#
#         var popup_c0e40965ccf6f238e6802c1fe68c84a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ca1c277d84d14ef31b324f5264b391b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ca1c277d84d14ef31b324f5264b391b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ca1c277d84d14ef31b324f5264b391b = L.map(
#                 &quot;map_2ca1c277d84d14ef31b324f5264b391b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b840359351e1dbf94d9d7cc6b3977d27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b840359351e1dbf94d9d7cc6b3977d27.addTo(map_2ca1c277d84d14ef31b324f5264b391b);
#
#
#             var feature_group_2db01d495fa326f4bf3bcad3865ffdf3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2db01d495fa326f4bf3bcad3865ffdf3.addTo(map_2ca1c277d84d14ef31b324f5264b391b);
#
#
#             var feature_group_sub_group_5746922b995f54b438a1cd55f06accd9 = L.featureGroup.subGroup(
#                 feature_group_2db01d495fa326f4bf3bcad3865ffdf3
#             );
#
#
#             var marker_ed9dbfb39c1e4464c135391849eb52f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5746922b995f54b438a1cd55f06accd9);
#
#
#         var popup_ac9b93fc09630290ce28637bed2cdbf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a18de456ae4d758a6f891a6a9dbb1a2 = $(`&lt;div id=&quot;html_5a18de456ae4d758a6f891a6a9dbb1a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ac9b93fc09630290ce28637bed2cdbf3.setContent(html_5a18de456ae4d758a6f891a6a9dbb1a2);
#
#
#
#         marker_ed9dbfb39c1e4464c135391849eb52f0.bindPopup(popup_ac9b93fc09630290ce28637bed2cdbf3)
#         ;
#
#
#
#
#             var marker_c9b2f8302efdc6c3c2257a3c9e400dbc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5746922b995f54b438a1cd55f06accd9);
#
#
#         var popup_836d680dbc64a314410b42ca9beaab70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60b60bbd5dac0c7b36ecff84a56df7ea = $(`&lt;div id=&quot;html_60b60bbd5dac0c7b36ecff84a56df7ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_836d680dbc64a314410b42ca9beaab70.setContent(html_60b60bbd5dac0c7b36ecff84a56df7ea);
#
#
#
#         marker_c9b2f8302efdc6c3c2257a3c9e400dbc.bindPopup(popup_836d680dbc64a314410b42ca9beaab70)
#         ;
#
#
#
#
#             var marker_9ddf8d05182a434d402d5f659b20370e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5746922b995f54b438a1cd55f06accd9);
#
#
#         var popup_eec8e465a164c3e431355a1ccd458f26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_106f10f81e806f86f470066b4c3aadc2 = $(`&lt;div id=&quot;html_106f10f81e806f86f470066b4c3aadc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eec8e465a164c3e431355a1ccd458f26.setContent(html_106f10f81e806f86f470066b4c3aadc2);
#
#
#
#         marker_9ddf8d05182a434d402d5f659b20370e.bindPopup(popup_eec8e465a164c3e431355a1ccd458f26)
#         ;
#
#
#
#
#             var marker_ae5acc2dc049962ae9ad8360f9d991cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5746922b995f54b438a1cd55f06accd9);
#
#
#         var popup_b2b8bf420b734d2f69b0be35c9c405bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf097d3d1b0213899546d1b68a779f0d = $(`&lt;div id=&quot;html_bf097d3d1b0213899546d1b68a779f0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b2b8bf420b734d2f69b0be35c9c405bb.setContent(html_bf097d3d1b0213899546d1b68a779f0d);
#
#
#
#         marker_
