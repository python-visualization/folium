# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63d4334aeb76af1a0f41071ed2bbab73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63d4334aeb76af1a0f41071ed2bbab73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63d4334aeb76af1a0f41071ed2bbab73 = L.map(
#                 &quot;map_63d4334aeb76af1a0f41071ed2bbab73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec84b383eb0cc8f7bc01a721e8cbc090 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec84b383eb0cc8f7bc01a721e8cbc090.addTo(map_63d4334aeb76af1a0f41071ed2bbab73);
#
#
#             var marker_47fbffe8af03d5fcc84fcbb255829774 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_63d4334aeb76af1a0f41071ed2bbab73);
#
#
#         var popup_34e8c7cd3d6c0b117920d8b1f27d5746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_191503a068f52a8fca53913b42e77227 = $(`&lt;div id=&quot;html_191503a068f52a8fca53913b42e77227&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_34e8c7cd3d6c0b117920d8b1f27d5746.setContent(html_191503a068f52a8fca53913b42e77227);
#
#
#
#         marker_47fbffe8af03d5fcc84fcbb255829774.bindPopup(popup_34e8c7cd3d6c0b117920d8b1f27d5746)
#         ;
#
#
#
#
#             var marker_404305bdb4b9fa4ee22130e84f020c9f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_63d4334aeb76af1a0f41071ed2bbab73);
#
#
#         var popup_4d022a33b11a3fb62c549ee410cdc794 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bb65f5c45eb14dc74637e05a1090ac7 = $(`&lt;div id=&quot;html_5bb65f5c45eb14dc74637e05a1090ac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4d022a33b11a3fb62c549ee410cdc794.setContent(html_5bb65f5c45eb14dc74637e05a1090ac7);
#
#
#
#         marker_404305bdb4b9fa4ee22130e84f020c9f.bindPopup(popup_4d022a33b11a3fb62c549ee410cdc794)
#         ;
#
#
#
#
#             var marker_b0d948de32710f4a3bf615f20bdf62f8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_63d4334aeb76af1a0f41071ed2bbab73);
#
#
#         var popup_8463e03eeb2669ea93e258376b9971d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddab50814e17ccf721b4d2299bb542cc = $(`&lt;div id=&quot;html_ddab50814e17ccf721b4d2299bb542cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8463e03eeb2669ea93e258376b9971d8.setContent(html_ddab50814e17ccf721b4d2299bb542cc);
#
#
#
#         marker_b0d948de32710f4a3bf615f20bdf62f8.bindPopup(popup_8463e03eeb2669ea93e258376b9971d8)
#         ;
#
#
#
#
#             var marker_ebecec9d8c06b8a3fa068d570475d2b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_63d4334aeb76af1a0f41071ed2bbab73);
#
#
#         var popup_6a0480f46e6081206c2d2687d1f008e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7989e36c64c44af6b9d3b4a471e6ee50 = $(`&lt;div id=&quot;html_7989e36c64c44af6b9d3b4a471e6ee50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6a0480f46e6081206c2d2687d1f008e9.setContent(html_7989e36c64c44af6b9d3b4a471e6ee50);
#
#
#
#         marker_ebecec9d8c06b8a3fa068d570475d2b0.bindPopup(popup_6a0480f46e6081206c2d2687d1f008e9)
#         ;
#
#
#
#
#             var marker_bae2fc883bf0e4d5f5be6c2039875b6a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_63d4334aeb76af1a0f41071ed2bbab73);
#
#
#         var popup_c76eb1d47d5f9caee0c51018a63bc144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b5c1aa5dba76e5090d8f85bff52c160 = $(`&lt;div id=&quot;html_4b5c1aa5dba76e5090d8f85bff52c160&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c76eb1d47d5f9caee0c51018a63bc144.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c34bc86cf036001d91a1d02df1ed2fe4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c34bc86cf036001d91a1d02df1ed2fe4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c34bc86cf036001d91a1d02df1ed2fe4 = L.map(
#                 &quot;map_c34bc86cf036001d91a1d02df1ed2fe4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce8c4eb72eee47f85cfbb9a5a39eaf94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce8c4eb72eee47f85cfbb9a5a39eaf94.addTo(map_c34bc86cf036001d91a1d02df1ed2fe4);
#
#
#             var feature_group_c4511c1b8480c7cef34df7c916b1efd6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fcf66edc9dc067ebfa2029ed1e5f69ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c4511c1b8480c7cef34df7c916b1efd6);
#
#
#         var popup_efa223f72e6ca7f969805b789d62c02f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88876f1d16ca809589dc7584bea3ec46 = $(`&lt;div id=&quot;html_88876f1d16ca809589dc7584bea3ec46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_efa223f72e6ca7f969805b789d62c02f.setContent(html_88876f1d16ca809589dc7584bea3ec46);
#
#
#
#         marker_fcf66edc9dc067ebfa2029ed1e5f69ab.bindPopup(popup_efa223f72e6ca7f969805b789d62c02f)
#         ;
#
#
#
#
#             var marker_72928f01d1f66de5ae6945d81149bc49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c4511c1b8480c7cef34df7c916b1efd6);
#
#
#         var popup_e5e90fad7be9b67b0085ef671f146379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c98557cecebbab10cef2fb9249f7541 = $(`&lt;div id=&quot;html_3c98557cecebbab10cef2fb9249f7541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e5e90fad7be9b67b0085ef671f146379.setContent(html_3c98557cecebbab10cef2fb9249f7541);
#
#
#
#         marker_72928f01d1f66de5ae6945d81149bc49.bindPopup(popup_e5e90fad7be9b67b0085ef671f146379)
#         ;
#
#
#
#
#             var marker_df5e1124e6f579f0694668ee219523f7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c4511c1b8480c7cef34df7c916b1efd6);
#
#
#         var popup_bf3c025b44c0f5876e67c34e9eb1f11a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6a16e3233d8b13b33837748d3a126a0 = $(`&lt;div id=&quot;html_d6a16e3233d8b13b33837748d3a126a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bf3c025b44c0f5876e67c34e9eb1f11a.setContent(html_d6a16e3233d8b13b33837748d3a126a0);
#
#
#
#         marker_df5e1124e6f579f0694668ee219523f7.bindPopup(popup_bf3c025b44c0f5876e67c34e9eb1f11a)
#         ;
#
#
#
#
#             var marker_7118aa80bbb125bbd1daa2151eeee6de = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c4511c1b8480c7cef34df7c916b1efd6);
#
#
#         var popup_e860ebaf5ce575fa2078ea8c29c0157e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ec33c2fc0cdb1377546f6b3e52f2fb2 = $(`&lt;div id=&quot;html_3ec33c2fc0cdb1377546f6b3e52f2fb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e860ebaf5ce575fa2078ea8c29c0157e.setContent(html_3ec33c2fc0cdb1377546f6b3e52f2fb2);
#
#
#
#         marker_7118aa80bbb125bbd1daa2151eeee6de.bindPopup(popup_e860ebaf5ce575fa2078ea8c29c0157e)
#         ;
#
#
#
#
#             var marker_9497107432dedc40bca0b84756292cbb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c4511c1b8480c7cef34df7c916b1efd6);
#
#
#         var popup_8d8c3cedc1027a4a3cbfaeffa45131e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_566baa81ee90cc1208389f4f3e02a816 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_566baa81ee90cc1208389f4f3e02a816&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_566baa81ee90cc1208389f4f3e02a816 = L.map(
#                 &quot;map_566baa81ee90cc1208389f4f3e02a816&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58256d3c6abed38c8a837de84858cab0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58256d3c6abed38c8a837de84858cab0.addTo(map_566baa81ee90cc1208389f4f3e02a816);
#
#
#             var feature_group_85be90f0b1151ed259633b09abcca467 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_85be90f0b1151ed259633b09abcca467.addTo(map_566baa81ee90cc1208389f4f3e02a816);
#
#
#             var feature_group_sub_group_f8ae71f683eebd76b40fef876a91ad89 = L.featureGroup.subGroup(
#                 feature_group_85be90f0b1151ed259633b09abcca467
#             );
#
#
#             var marker_f9395c05b280730e28894db20d4527f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8ae71f683eebd76b40fef876a91ad89);
#
#
#         var popup_be31e8cd4b2c50f1a86db8c04582304e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d391832fb5b30e61cac9ce8319c4a7d6 = $(`&lt;div id=&quot;html_d391832fb5b30e61cac9ce8319c4a7d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_be31e8cd4b2c50f1a86db8c04582304e.setContent(html_d391832fb5b30e61cac9ce8319c4a7d6);
#
#
#
#         marker_f9395c05b280730e28894db20d4527f7.bindPopup(popup_be31e8cd4b2c50f1a86db8c04582304e)
#         ;
#
#
#
#
#             var marker_b4ceb344c3c01f3e170e9b92d30c615d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8ae71f683eebd76b40fef876a91ad89);
#
#
#         var popup_4608cdba1a93c8823fa90cc108cd1956 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aeb34e72d6b2abe8f88acf2986044008 = $(`&lt;div id=&quot;html_aeb34e72d6b2abe8f88acf2986044008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4608cdba1a93c8823fa90cc108cd1956.setContent(html_aeb34e72d6b2abe8f88acf2986044008);
#
#
#
#         marker_b4ceb344c3c01f3e170e9b92d30c615d.bindPopup(popup_4608cdba1a93c8823fa90cc108cd1956)
#         ;
#
#
#
#
#             var marker_a3187be915141946da5bf1394917f9cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8ae71f683eebd76b40fef876a91ad89);
#
#
#         var popup_4c30ae7e161db9ebe5ea1d3ef514b623 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01d9b14f93c1139bc6cba85d086b0da2 = $(`&lt;div id=&quot;html_01d9b14f93c1139bc6cba85d086b0da2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4c30ae7e161db9ebe5ea1d3ef514b623.setContent(html_01d9b14f93c1139bc6cba85d086b0da2);
#
#
#
#         marker_a3187be915141946da5bf1394917f9cc.bindPopup(popup_4c30ae7e161db9ebe5ea1d3ef514b623)
#         ;
#
#
#
#
#             var marker_b76a8abd070e70d49d11d49dc20fc10f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8ae71f683eebd76b40fef876a91ad89);
#
#
#         var popup_c42473bce1e648943408ffab278bd032 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59e7cbfd01cc275ed66686e44ad8223d = $(`&lt;div id=&quot;html_59e7cbfd01cc275ed66686e44ad8223d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c42473bce1e648943408ffab278bd032.setContent(html_59e7cbfd01cc275ed66686e44ad8223d);
#
#
#
#         marker_
