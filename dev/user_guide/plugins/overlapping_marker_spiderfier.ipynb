# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21c31896e65d90489ff93c7a90b6fc4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21c31896e65d90489ff93c7a90b6fc4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21c31896e65d90489ff93c7a90b6fc4e = L.map(
#                 &quot;map_21c31896e65d90489ff93c7a90b6fc4e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81ac7440e44b0b76dcdb331890666d75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81ac7440e44b0b76dcdb331890666d75.addTo(map_21c31896e65d90489ff93c7a90b6fc4e);
#
#
#             var marker_c776881aad517bd3336242274f26cf6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_21c31896e65d90489ff93c7a90b6fc4e);
#
#
#         var popup_72c4266164f9c732e7243e8ac35855c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76f3bb51beaa44e71f52b506be5c376b = $(`&lt;div id=&quot;html_76f3bb51beaa44e71f52b506be5c376b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_72c4266164f9c732e7243e8ac35855c6.setContent(html_76f3bb51beaa44e71f52b506be5c376b);
#
#
#
#         marker_c776881aad517bd3336242274f26cf6a.bindPopup(popup_72c4266164f9c732e7243e8ac35855c6)
#         ;
#
#
#
#
#             var marker_fcb78c96ed4671aa0d2db285a17617a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_21c31896e65d90489ff93c7a90b6fc4e);
#
#
#         var popup_62827ebafbf0e19cf92f2f057edf54db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baba9c10cbd4bde305289ce2b0c8738c = $(`&lt;div id=&quot;html_baba9c10cbd4bde305289ce2b0c8738c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_62827ebafbf0e19cf92f2f057edf54db.setContent(html_baba9c10cbd4bde305289ce2b0c8738c);
#
#
#
#         marker_fcb78c96ed4671aa0d2db285a17617a6.bindPopup(popup_62827ebafbf0e19cf92f2f057edf54db)
#         ;
#
#
#
#
#             var marker_b455bfb2c59385082e7e4fd2e48461d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_21c31896e65d90489ff93c7a90b6fc4e);
#
#
#         var popup_3c65f6323703bd86c2c1cb658ebade29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0faaf8a3934e77d87aa4ae0199f353e = $(`&lt;div id=&quot;html_e0faaf8a3934e77d87aa4ae0199f353e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3c65f6323703bd86c2c1cb658ebade29.setContent(html_e0faaf8a3934e77d87aa4ae0199f353e);
#
#
#
#         marker_b455bfb2c59385082e7e4fd2e48461d9.bindPopup(popup_3c65f6323703bd86c2c1cb658ebade29)
#         ;
#
#
#
#
#             var marker_6131fdb526c8c9c5b1f759755d21c914 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_21c31896e65d90489ff93c7a90b6fc4e);
#
#
#         var popup_6ad08e558a5fe88a0267b0abf0d0dd2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea74a20077f2890f8f6a6c9f681a8d7b = $(`&lt;div id=&quot;html_ea74a20077f2890f8f6a6c9f681a8d7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6ad08e558a5fe88a0267b0abf0d0dd2a.setContent(html_ea74a20077f2890f8f6a6c9f681a8d7b);
#
#
#
#         marker_6131fdb526c8c9c5b1f759755d21c914.bindPopup(popup_6ad08e558a5fe88a0267b0abf0d0dd2a)
#         ;
#
#
#
#
#             var marker_4e1ee9ce164939001f5b1efd4b7a8a95 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_21c31896e65d90489ff93c7a90b6fc4e);
#
#
#         var popup_190a9378e410cdc7f1f95bdf12d4e156 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_064757c24ccf6499f6ef6b36b9c17341 = $(`&lt;div id=&quot;html_064757c24ccf6499f6ef6b36b9c17341&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_190a9378e410cdc7f1f95bdf12d4e156.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73c038e7a96a8bf286267f322a620792 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73c038e7a96a8bf286267f322a620792&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73c038e7a96a8bf286267f322a620792 = L.map(
#                 &quot;map_73c038e7a96a8bf286267f322a620792&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e15434294800be6d25a9e9e612dd6f01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e15434294800be6d25a9e9e612dd6f01.addTo(map_73c038e7a96a8bf286267f322a620792);
#
#
#             var feature_group_d21693bc286abad082b9d670a5f7dfe7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cd62e339f86ab1f1aadfd76f86267ce5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d21693bc286abad082b9d670a5f7dfe7);
#
#
#         var popup_a47cf9f685fb62b2518c18ad1428189e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84e12ac67a9906ece968cb4c1709035d = $(`&lt;div id=&quot;html_84e12ac67a9906ece968cb4c1709035d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a47cf9f685fb62b2518c18ad1428189e.setContent(html_84e12ac67a9906ece968cb4c1709035d);
#
#
#
#         marker_cd62e339f86ab1f1aadfd76f86267ce5.bindPopup(popup_a47cf9f685fb62b2518c18ad1428189e)
#         ;
#
#
#
#
#             var marker_2cc139a8f22cde3ece77922c1623f937 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d21693bc286abad082b9d670a5f7dfe7);
#
#
#         var popup_6e700216ace903997d7864b6962cb6d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7714e451d67ae74984b57bd2bded6396 = $(`&lt;div id=&quot;html_7714e451d67ae74984b57bd2bded6396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6e700216ace903997d7864b6962cb6d9.setContent(html_7714e451d67ae74984b57bd2bded6396);
#
#
#
#         marker_2cc139a8f22cde3ece77922c1623f937.bindPopup(popup_6e700216ace903997d7864b6962cb6d9)
#         ;
#
#
#
#
#             var marker_4c69ba16c208958194757a78810d4a07 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d21693bc286abad082b9d670a5f7dfe7);
#
#
#         var popup_75855584d7cc3839cab72529195c8d5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf597de2b836f86115902692f5f38b42 = $(`&lt;div id=&quot;html_bf597de2b836f86115902692f5f38b42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_75855584d7cc3839cab72529195c8d5e.setContent(html_bf597de2b836f86115902692f5f38b42);
#
#
#
#         marker_4c69ba16c208958194757a78810d4a07.bindPopup(popup_75855584d7cc3839cab72529195c8d5e)
#         ;
#
#
#
#
#             var marker_20a9412ac53d0db85df91237fbd453db = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d21693bc286abad082b9d670a5f7dfe7);
#
#
#         var popup_da2faedecbc199e846893da7ba3e0591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ad5c06c6f77c70ad588ee8e291870ed = $(`&lt;div id=&quot;html_0ad5c06c6f77c70ad588ee8e291870ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_da2faedecbc199e846893da7ba3e0591.setContent(html_0ad5c06c6f77c70ad588ee8e291870ed);
#
#
#
#         marker_20a9412ac53d0db85df91237fbd453db.bindPopup(popup_da2faedecbc199e846893da7ba3e0591)
#         ;
#
#
#
#
#             var marker_f0767689e6e9d41c05e6eed2ffc2c3e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d21693bc286abad082b9d670a5f7dfe7);
#
#
#         var popup_77943d5ab7102df45b7903011bcdcb30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ad86bd805026ba549936ce3062ad76e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ad86bd805026ba549936ce3062ad76e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ad86bd805026ba549936ce3062ad76e = L.map(
#                 &quot;map_0ad86bd805026ba549936ce3062ad76e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be4ba823d45846e918b3539048137188 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be4ba823d45846e918b3539048137188.addTo(map_0ad86bd805026ba549936ce3062ad76e);
#
#
#             var feature_group_5d170558b00ac7df0cb5b0df77dd52c1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5d170558b00ac7df0cb5b0df77dd52c1.addTo(map_0ad86bd805026ba549936ce3062ad76e);
#
#
#             var feature_group_sub_group_86a8f66dd8adf83c712307f6c46cde99 = L.featureGroup.subGroup(
#                 feature_group_5d170558b00ac7df0cb5b0df77dd52c1
#             );
#
#
#             var marker_4420ac55c38985d4a50a3811beb649e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_86a8f66dd8adf83c712307f6c46cde99);
#
#
#         var popup_f3986d105cd464824aa85b88b6a0362e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc911a3c5389c3d4bf049412eea769d9 = $(`&lt;div id=&quot;html_cc911a3c5389c3d4bf049412eea769d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f3986d105cd464824aa85b88b6a0362e.setContent(html_cc911a3c5389c3d4bf049412eea769d9);
#
#
#
#         marker_4420ac55c38985d4a50a3811beb649e5.bindPopup(popup_f3986d105cd464824aa85b88b6a0362e)
#         ;
#
#
#
#
#             var marker_240f59311ae3b41126fa61d912c66050 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_86a8f66dd8adf83c712307f6c46cde99);
#
#
#         var popup_46cc7ee085d20c4098f2e28de20d2a6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff10d0ff0522de509b0a580e9f4095d4 = $(`&lt;div id=&quot;html_ff10d0ff0522de509b0a580e9f4095d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_46cc7ee085d20c4098f2e28de20d2a6d.setContent(html_ff10d0ff0522de509b0a580e9f4095d4);
#
#
#
#         marker_240f59311ae3b41126fa61d912c66050.bindPopup(popup_46cc7ee085d20c4098f2e28de20d2a6d)
#         ;
#
#
#
#
#             var marker_38fbf0dd006afe69ea6595733488ac8b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_86a8f66dd8adf83c712307f6c46cde99);
#
#
#         var popup_d5cea0c39fc341dd49877a1d0c41cfde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36a8c69c273575c02b432582df555742 = $(`&lt;div id=&quot;html_36a8c69c273575c02b432582df555742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d5cea0c39fc341dd49877a1d0c41cfde.setContent(html_36a8c69c273575c02b432582df555742);
#
#
#
#         marker_38fbf0dd006afe69ea6595733488ac8b.bindPopup(popup_d5cea0c39fc341dd49877a1d0c41cfde)
#         ;
#
#
#
#
#             var marker_42c29649cb1a6d54edd1c81c629a4203 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_86a8f66dd8adf83c712307f6c46cde99);
#
#
#         var popup_dd8c54775376960fa47c67fab3484b18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4db6d44a1c906252728fd34618b898d7 = $(`&lt;div id=&quot;html_4db6d44a1c906252728fd34618b898d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dd8c54775376960fa47c67fab3484b18.setContent(html_4db6d44a1c906252728fd34618b898d7);
#
#
#
#         marker_
