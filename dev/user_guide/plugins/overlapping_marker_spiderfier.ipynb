# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81af7a499690b81d75bfa9880eda3871 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81af7a499690b81d75bfa9880eda3871&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81af7a499690b81d75bfa9880eda3871 = L.map(
#                 &quot;map_81af7a499690b81d75bfa9880eda3871&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac2207d570134d8f602f1a6042da3e4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac2207d570134d8f602f1a6042da3e4a.addTo(map_81af7a499690b81d75bfa9880eda3871);
#
#
#             var marker_a26d4b0f279b331eebe81593e415fab7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_81af7a499690b81d75bfa9880eda3871);
#
#
#         var popup_222776d075b6a9298da86a4798b4b001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9354f0090b67e1d8697f62460f2379be = $(`&lt;div id=&quot;html_9354f0090b67e1d8697f62460f2379be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_222776d075b6a9298da86a4798b4b001.setContent(html_9354f0090b67e1d8697f62460f2379be);
#
#
#
#         marker_a26d4b0f279b331eebe81593e415fab7.bindPopup(popup_222776d075b6a9298da86a4798b4b001)
#         ;
#
#
#
#
#             var marker_5543b6c1b09867520d92148218c211a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_81af7a499690b81d75bfa9880eda3871);
#
#
#         var popup_179940d129f3238bb4cf8727ffdee25c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2c29460d6f18e2f9bdb20eb741bb435 = $(`&lt;div id=&quot;html_d2c29460d6f18e2f9bdb20eb741bb435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_179940d129f3238bb4cf8727ffdee25c.setContent(html_d2c29460d6f18e2f9bdb20eb741bb435);
#
#
#
#         marker_5543b6c1b09867520d92148218c211a5.bindPopup(popup_179940d129f3238bb4cf8727ffdee25c)
#         ;
#
#
#
#
#             var marker_a6332cc75c74e4d5d2dfe22ec4e8b6ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_81af7a499690b81d75bfa9880eda3871);
#
#
#         var popup_4f7e93296ca127d4e65b21a9908f3345 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07a7a288bc2be7338cfd9372d434871a = $(`&lt;div id=&quot;html_07a7a288bc2be7338cfd9372d434871a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4f7e93296ca127d4e65b21a9908f3345.setContent(html_07a7a288bc2be7338cfd9372d434871a);
#
#
#
#         marker_a6332cc75c74e4d5d2dfe22ec4e8b6ad.bindPopup(popup_4f7e93296ca127d4e65b21a9908f3345)
#         ;
#
#
#
#
#             var marker_9a6c4e8cae2d5f38c03c52a6c1e83d2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_81af7a499690b81d75bfa9880eda3871);
#
#
#         var popup_60af9b021f70d398e9fa32f24b3fe7b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f52b0f6d9adf926b97d08d2e879ee1a = $(`&lt;div id=&quot;html_0f52b0f6d9adf926b97d08d2e879ee1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60af9b021f70d398e9fa32f24b3fe7b4.setContent(html_0f52b0f6d9adf926b97d08d2e879ee1a);
#
#
#
#         marker_9a6c4e8cae2d5f38c03c52a6c1e83d2e.bindPopup(popup_60af9b021f70d398e9fa32f24b3fe7b4)
#         ;
#
#
#
#
#             var marker_3bd65a3df8a0f8827847af7891423595 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_81af7a499690b81d75bfa9880eda3871);
#
#
#         var popup_c0e9d616033d9429d7498a9b69bde75c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f43c7478ea470e84679d6fb960f3d131 = $(`&lt;div id=&quot;html_f43c7478ea470e84679d6fb960f3d131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c0e9d616033d9429d7498a9b69bde75c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52f92d5d26e1bce39d26f5f1c7eec59f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52f92d5d26e1bce39d26f5f1c7eec59f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52f92d5d26e1bce39d26f5f1c7eec59f = L.map(
#                 &quot;map_52f92d5d26e1bce39d26f5f1c7eec59f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a060f2b921ffc2d72add15e4a9102a79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a060f2b921ffc2d72add15e4a9102a79.addTo(map_52f92d5d26e1bce39d26f5f1c7eec59f);
#
#
#             var feature_group_ca5402c7383009914b61d81c6216f75f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2302239e4ade0450a8cfcd4c22a9be5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ca5402c7383009914b61d81c6216f75f);
#
#
#         var popup_f8f9ffa2d3128c43ac9f729c44830350 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ffa5d75a57e8f45abf31361f03df9f4 = $(`&lt;div id=&quot;html_4ffa5d75a57e8f45abf31361f03df9f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f8f9ffa2d3128c43ac9f729c44830350.setContent(html_4ffa5d75a57e8f45abf31361f03df9f4);
#
#
#
#         marker_b2302239e4ade0450a8cfcd4c22a9be5.bindPopup(popup_f8f9ffa2d3128c43ac9f729c44830350)
#         ;
#
#
#
#
#             var marker_bf04291c4df8f992f0b279fe17ae667e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ca5402c7383009914b61d81c6216f75f);
#
#
#         var popup_4870a581ee52b0055a2ff25b0cf6e35d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e1c374cffd02883e554f0ec1459d45b = $(`&lt;div id=&quot;html_3e1c374cffd02883e554f0ec1459d45b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4870a581ee52b0055a2ff25b0cf6e35d.setContent(html_3e1c374cffd02883e554f0ec1459d45b);
#
#
#
#         marker_bf04291c4df8f992f0b279fe17ae667e.bindPopup(popup_4870a581ee52b0055a2ff25b0cf6e35d)
#         ;
#
#
#
#
#             var marker_2b4f707575ae199052e485778306e8fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ca5402c7383009914b61d81c6216f75f);
#
#
#         var popup_b110f8f7ad157cf2dd2c0d452778d274 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f33116a610bb999828adb7f5b9638bf = $(`&lt;div id=&quot;html_0f33116a610bb999828adb7f5b9638bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b110f8f7ad157cf2dd2c0d452778d274.setContent(html_0f33116a610bb999828adb7f5b9638bf);
#
#
#
#         marker_2b4f707575ae199052e485778306e8fa.bindPopup(popup_b110f8f7ad157cf2dd2c0d452778d274)
#         ;
#
#
#
#
#             var marker_063ee4940933b1248a31483910633e04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ca5402c7383009914b61d81c6216f75f);
#
#
#         var popup_1b495d985b8e8c66dbbc193c9643c00e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_712bfe5724c386ba52efefcb03c575d9 = $(`&lt;div id=&quot;html_712bfe5724c386ba52efefcb03c575d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1b495d985b8e8c66dbbc193c9643c00e.setContent(html_712bfe5724c386ba52efefcb03c575d9);
#
#
#
#         marker_063ee4940933b1248a31483910633e04.bindPopup(popup_1b495d985b8e8c66dbbc193c9643c00e)
#         ;
#
#
#
#
#             var marker_a080bc6f7e06439d091c13d94776dbff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ca5402c7383009914b61d81c6216f75f);
#
#
#         var popup_3d13b08d517342edd0ffb06fc84b0130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e96bdc5f405d3da412cdce138034967 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e96bdc5f405d3da412cdce138034967&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e96bdc5f405d3da412cdce138034967 = L.map(
#                 &quot;map_0e96bdc5f405d3da412cdce138034967&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f174d0d5ec43e438df47e85c7c958f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f174d0d5ec43e438df47e85c7c958f0.addTo(map_0e96bdc5f405d3da412cdce138034967);
#
#
#             var feature_group_ae4340cbc70ca2e1b493c47eb3892ed8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ae4340cbc70ca2e1b493c47eb3892ed8.addTo(map_0e96bdc5f405d3da412cdce138034967);
#
#
#             var feature_group_sub_group_de32015ffa690c200b752d5ae775debe = L.featureGroup.subGroup(
#                 feature_group_ae4340cbc70ca2e1b493c47eb3892ed8
#             );
#
#
#             var marker_7ad435c525b2ea69eb8a4ff507daff86 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_de32015ffa690c200b752d5ae775debe);
#
#
#         var popup_210921596075b565f9516eb25d2ae4bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27f5ad357879222b585ae0c74fe9f772 = $(`&lt;div id=&quot;html_27f5ad357879222b585ae0c74fe9f772&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_210921596075b565f9516eb25d2ae4bd.setContent(html_27f5ad357879222b585ae0c74fe9f772);
#
#
#
#         marker_7ad435c525b2ea69eb8a4ff507daff86.bindPopup(popup_210921596075b565f9516eb25d2ae4bd)
#         ;
#
#
#
#
#             var marker_38d943a2159702a4e4e67f219786fa91 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_de32015ffa690c200b752d5ae775debe);
#
#
#         var popup_56034fc55349b4408d2b56bf8a325d9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5378261e9f329c85341e19fb645fff1b = $(`&lt;div id=&quot;html_5378261e9f329c85341e19fb645fff1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_56034fc55349b4408d2b56bf8a325d9f.setContent(html_5378261e9f329c85341e19fb645fff1b);
#
#
#
#         marker_38d943a2159702a4e4e67f219786fa91.bindPopup(popup_56034fc55349b4408d2b56bf8a325d9f)
#         ;
#
#
#
#
#             var marker_308f4ea11c308725b283cd2078ad4636 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_de32015ffa690c200b752d5ae775debe);
#
#
#         var popup_2c4dde847b64d47d105ee898a50d893a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c036a0d9d521d586516ea0bafd2dcfc = $(`&lt;div id=&quot;html_8c036a0d9d521d586516ea0bafd2dcfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2c4dde847b64d47d105ee898a50d893a.setContent(html_8c036a0d9d521d586516ea0bafd2dcfc);
#
#
#
#         marker_308f4ea11c308725b283cd2078ad4636.bindPopup(popup_2c4dde847b64d47d105ee898a50d893a)
#         ;
#
#
#
#
#             var marker_ed032486aa793a615c77828b00bce54c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_de32015ffa690c200b752d5ae775debe);
#
#
#         var popup_c2f0a563f9853dda31727f151e0484e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd8151e617c4b0ac24c45e35d12e4256 = $(`&lt;div id=&quot;html_bd8151e617c4b0ac24c45e35d12e4256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c2f0a563f9853dda31727f151e0484e9.setContent(html_bd8151e617c4b0ac24c45e35d12e4256);
#
#
#
#         marker_
