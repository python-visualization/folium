# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f420f7a16dc2d7206c27312775d5d15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f420f7a16dc2d7206c27312775d5d15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f420f7a16dc2d7206c27312775d5d15 = L.map(
#                 &quot;map_5f420f7a16dc2d7206c27312775d5d15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82c4bc958eb76b28671e17a0eae0bb3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82c4bc958eb76b28671e17a0eae0bb3d.addTo(map_5f420f7a16dc2d7206c27312775d5d15);
#
#
#             var marker_ffd1ece8815877afed7e5aa0560b40c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5f420f7a16dc2d7206c27312775d5d15);
#
#
#         var popup_005a62904a686b3bf56e5aa4b2faf98c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6fe545c4d10b999a0c785996052d265 = $(`&lt;div id=&quot;html_b6fe545c4d10b999a0c785996052d265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_005a62904a686b3bf56e5aa4b2faf98c.setContent(html_b6fe545c4d10b999a0c785996052d265);
#
#
#
#         marker_ffd1ece8815877afed7e5aa0560b40c6.bindPopup(popup_005a62904a686b3bf56e5aa4b2faf98c)
#         ;
#
#
#
#
#             var marker_4293ad81c26a13292dded435f5cf6791 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5f420f7a16dc2d7206c27312775d5d15);
#
#
#         var popup_b31f445476bf5fb40a55ca70cd8b095d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_788315b45ed853c314762409e3f3a7fc = $(`&lt;div id=&quot;html_788315b45ed853c314762409e3f3a7fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b31f445476bf5fb40a55ca70cd8b095d.setContent(html_788315b45ed853c314762409e3f3a7fc);
#
#
#
#         marker_4293ad81c26a13292dded435f5cf6791.bindPopup(popup_b31f445476bf5fb40a55ca70cd8b095d)
#         ;
#
#
#
#
#             var marker_0e95977a910dca0ab4551bc77243f7c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5f420f7a16dc2d7206c27312775d5d15);
#
#
#         var popup_d982ee7811671228ffc9b683d683a653 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57365d68bc583049c4ade828828cf83d = $(`&lt;div id=&quot;html_57365d68bc583049c4ade828828cf83d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d982ee7811671228ffc9b683d683a653.setContent(html_57365d68bc583049c4ade828828cf83d);
#
#
#
#         marker_0e95977a910dca0ab4551bc77243f7c3.bindPopup(popup_d982ee7811671228ffc9b683d683a653)
#         ;
#
#
#
#
#             var marker_b1e74edff5d8fd9f35599c50bd68bc4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5f420f7a16dc2d7206c27312775d5d15);
#
#
#         var popup_73afda24c9a19338f7e343b736945bfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bb96cdd65044d7ceaa051b85912632f = $(`&lt;div id=&quot;html_7bb96cdd65044d7ceaa051b85912632f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_73afda24c9a19338f7e343b736945bfe.setContent(html_7bb96cdd65044d7ceaa051b85912632f);
#
#
#
#         marker_b1e74edff5d8fd9f35599c50bd68bc4f.bindPopup(popup_73afda24c9a19338f7e343b736945bfe)
#         ;
#
#
#
#
#             var marker_64667ee3535553082f2ee115f3b0520d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5f420f7a16dc2d7206c27312775d5d15);
#
#
#         var popup_fa6e8f9c3c8083ffb1cb14a2267801af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09ee8b3f610e3200b9549437b66f9cd0 = $(`&lt;div id=&quot;html_09ee8b3f610e3200b9549437b66f9cd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fa6e8f9c3c8083ffb1cb14a2267801af.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae4441fd5eadd359d07e09de3929bc57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae4441fd5eadd359d07e09de3929bc57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae4441fd5eadd359d07e09de3929bc57 = L.map(
#                 &quot;map_ae4441fd5eadd359d07e09de3929bc57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f09bb4e90d1b407cc09ff2e2c8a6072 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f09bb4e90d1b407cc09ff2e2c8a6072.addTo(map_ae4441fd5eadd359d07e09de3929bc57);
#
#
#             var feature_group_70b919c75e5f83ebb72b46b072961664 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7167eb9011bc85163c90cb31af70be3a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_70b919c75e5f83ebb72b46b072961664);
#
#
#         var popup_139949b355313e33ace178e7b1ffbd7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a3ab47c0072b200420b2b1f60fa19a7 = $(`&lt;div id=&quot;html_0a3ab47c0072b200420b2b1f60fa19a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_139949b355313e33ace178e7b1ffbd7f.setContent(html_0a3ab47c0072b200420b2b1f60fa19a7);
#
#
#
#         marker_7167eb9011bc85163c90cb31af70be3a.bindPopup(popup_139949b355313e33ace178e7b1ffbd7f)
#         ;
#
#
#
#
#             var marker_8e2b4958b387ee86d01d6ac69b396f08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_70b919c75e5f83ebb72b46b072961664);
#
#
#         var popup_153c86ad7ba31949b143b34c269b1c6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0d8dcc0e47820591d49fb3e02fecd5a = $(`&lt;div id=&quot;html_b0d8dcc0e47820591d49fb3e02fecd5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_153c86ad7ba31949b143b34c269b1c6f.setContent(html_b0d8dcc0e47820591d49fb3e02fecd5a);
#
#
#
#         marker_8e2b4958b387ee86d01d6ac69b396f08.bindPopup(popup_153c86ad7ba31949b143b34c269b1c6f)
#         ;
#
#
#
#
#             var marker_23c9ad739086f8eaa371b84750f63db5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_70b919c75e5f83ebb72b46b072961664);
#
#
#         var popup_5649c4d10f7649c15abe7cc18d09465e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15478f4d414787bf5dfa1dc93e9880c7 = $(`&lt;div id=&quot;html_15478f4d414787bf5dfa1dc93e9880c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5649c4d10f7649c15abe7cc18d09465e.setContent(html_15478f4d414787bf5dfa1dc93e9880c7);
#
#
#
#         marker_23c9ad739086f8eaa371b84750f63db5.bindPopup(popup_5649c4d10f7649c15abe7cc18d09465e)
#         ;
#
#
#
#
#             var marker_adcb46f7a881d02632b84778bd560542 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_70b919c75e5f83ebb72b46b072961664);
#
#
#         var popup_856e91472cc317957737000ef802cfc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4422ce5bce6cd11d9635917a187c4e7d = $(`&lt;div id=&quot;html_4422ce5bce6cd11d9635917a187c4e7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_856e91472cc317957737000ef802cfc8.setContent(html_4422ce5bce6cd11d9635917a187c4e7d);
#
#
#
#         marker_adcb46f7a881d02632b84778bd560542.bindPopup(popup_856e91472cc317957737000ef802cfc8)
#         ;
#
#
#
#
#             var marker_9b4634980a3bbdc14cc2c98098fd5f09 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_70b919c75e5f83ebb72b46b072961664);
#
#
#         var popup_3a760365a08205075c84a494fb810595 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c82f6187f5783f117ad87d6b7acc9e48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c82f6187f5783f117ad87d6b7acc9e48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c82f6187f5783f117ad87d6b7acc9e48 = L.map(
#                 &quot;map_c82f6187f5783f117ad87d6b7acc9e48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a50b3ee153cb5e82de7e74afd7aa37b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a50b3ee153cb5e82de7e74afd7aa37b.addTo(map_c82f6187f5783f117ad87d6b7acc9e48);
#
#
#             var feature_group_302a14734d089c5855c08d9a5122c680 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_302a14734d089c5855c08d9a5122c680.addTo(map_c82f6187f5783f117ad87d6b7acc9e48);
#
#
#             var feature_group_sub_group_e3a69973f470e6c7093e7efa5269e733 = L.featureGroup.subGroup(
#                 feature_group_302a14734d089c5855c08d9a5122c680
#             );
#
#
#             var marker_d338192fbf1cf97bb3caab9a53163fe0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3a69973f470e6c7093e7efa5269e733);
#
#
#         var popup_0aae2b0b5e292eae4a812cd137625894 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a7416b0746695bfdbe04332f07c695d = $(`&lt;div id=&quot;html_1a7416b0746695bfdbe04332f07c695d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0aae2b0b5e292eae4a812cd137625894.setContent(html_1a7416b0746695bfdbe04332f07c695d);
#
#
#
#         marker_d338192fbf1cf97bb3caab9a53163fe0.bindPopup(popup_0aae2b0b5e292eae4a812cd137625894)
#         ;
#
#
#
#
#             var marker_e83b2f95cc7aefea4edfe874967934f8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3a69973f470e6c7093e7efa5269e733);
#
#
#         var popup_3518a42d727f7825a9018d5fcb8725a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9124b8c9a68ac2e32ddf06cfe382734 = $(`&lt;div id=&quot;html_a9124b8c9a68ac2e32ddf06cfe382734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3518a42d727f7825a9018d5fcb8725a5.setContent(html_a9124b8c9a68ac2e32ddf06cfe382734);
#
#
#
#         marker_e83b2f95cc7aefea4edfe874967934f8.bindPopup(popup_3518a42d727f7825a9018d5fcb8725a5)
#         ;
#
#
#
#
#             var marker_791145779c253f133166283d5f75eeb7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3a69973f470e6c7093e7efa5269e733);
#
#
#         var popup_848dd7fdd47e8369c3f97b785dea2bd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cfe2413a78312e7e6d9bab524694d51 = $(`&lt;div id=&quot;html_9cfe2413a78312e7e6d9bab524694d51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_848dd7fdd47e8369c3f97b785dea2bd1.setContent(html_9cfe2413a78312e7e6d9bab524694d51);
#
#
#
#         marker_791145779c253f133166283d5f75eeb7.bindPopup(popup_848dd7fdd47e8369c3f97b785dea2bd1)
#         ;
#
#
#
#
#             var marker_cc8373e40b0e9d54d056f4ca314fadc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3a69973f470e6c7093e7efa5269e733);
#
#
#         var popup_897062519aaef1ee5699e35e2164fb90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4a71418891a23dfcefd9b2a73ea0f21 = $(`&lt;div id=&quot;html_b4a71418891a23dfcefd9b2a73ea0f21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_897062519aaef1ee5699e35e2164fb90.setContent(html_b4a71418891a23dfcefd9b2a73ea0f21);
#
#
#
#         marker_
