# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cdd9ad6536aa3d8d5666d20b8bfc0ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cdd9ad6536aa3d8d5666d20b8bfc0ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cdd9ad6536aa3d8d5666d20b8bfc0ff = L.map(
#                 &quot;map_3cdd9ad6536aa3d8d5666d20b8bfc0ff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a75c0f7f89ce3f74f162bf75e82b2d37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a75c0f7f89ce3f74f162bf75e82b2d37.addTo(map_3cdd9ad6536aa3d8d5666d20b8bfc0ff);
#
#
#             var marker_e7765e23e3ba798f66fac77ec2cb4346 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3cdd9ad6536aa3d8d5666d20b8bfc0ff);
#
#
#         var popup_becd59553d15047ee314493619a280ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80f791686718a43f7d29aa7bc36962c1 = $(`&lt;div id=&quot;html_80f791686718a43f7d29aa7bc36962c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_becd59553d15047ee314493619a280ca.setContent(html_80f791686718a43f7d29aa7bc36962c1);
#
#
#
#         marker_e7765e23e3ba798f66fac77ec2cb4346.bindPopup(popup_becd59553d15047ee314493619a280ca)
#         ;
#
#
#
#
#             var marker_71d021b09d099bc46d2b60d525134c01 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3cdd9ad6536aa3d8d5666d20b8bfc0ff);
#
#
#         var popup_c595ad02209c3971eca2365b71d87571 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a5df5b6c3b5a5377c83a1100990c7c = $(`&lt;div id=&quot;html_06a5df5b6c3b5a5377c83a1100990c7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c595ad02209c3971eca2365b71d87571.setContent(html_06a5df5b6c3b5a5377c83a1100990c7c);
#
#
#
#         marker_71d021b09d099bc46d2b60d525134c01.bindPopup(popup_c595ad02209c3971eca2365b71d87571)
#         ;
#
#
#
#
#             var marker_0da7e37b01e2b981a1b9192aa29d98ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3cdd9ad6536aa3d8d5666d20b8bfc0ff);
#
#
#         var popup_c45b5a06e5ff5a8c34dd720cdcee1b14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_913fc98e3d313d4b4d514972b0d9cce3 = $(`&lt;div id=&quot;html_913fc98e3d313d4b4d514972b0d9cce3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c45b5a06e5ff5a8c34dd720cdcee1b14.setContent(html_913fc98e3d313d4b4d514972b0d9cce3);
#
#
#
#         marker_0da7e37b01e2b981a1b9192aa29d98ed.bindPopup(popup_c45b5a06e5ff5a8c34dd720cdcee1b14)
#         ;
#
#
#
#
#             var marker_9788cad43caee2635eb97f4dadcc0651 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3cdd9ad6536aa3d8d5666d20b8bfc0ff);
#
#
#         var popup_0be467ea4845d7e0032122b8d95cc210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a81b7ea7ce7ff1ec33a5d3746de2d2c2 = $(`&lt;div id=&quot;html_a81b7ea7ce7ff1ec33a5d3746de2d2c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0be467ea4845d7e0032122b8d95cc210.setContent(html_a81b7ea7ce7ff1ec33a5d3746de2d2c2);
#
#
#
#         marker_9788cad43caee2635eb97f4dadcc0651.bindPopup(popup_0be467ea4845d7e0032122b8d95cc210)
#         ;
#
#
#
#
#             var marker_d95619c250671458172439c6091b6831 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3cdd9ad6536aa3d8d5666d20b8bfc0ff);
#
#
#         var popup_e99ddb5ba82d805b64868c8cb88b3eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_016199efab61992fa55f68843e871a7b = $(`&lt;div id=&quot;html_016199efab61992fa55f68843e871a7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e99ddb5ba82d805b64868c8cb88b3eb9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_471915a40bfab11e35cb3af0d4281f52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_471915a40bfab11e35cb3af0d4281f52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_471915a40bfab11e35cb3af0d4281f52 = L.map(
#                 &quot;map_471915a40bfab11e35cb3af0d4281f52&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cc79b24c7d9bcc32b7e3c03feaea4fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cc79b24c7d9bcc32b7e3c03feaea4fe.addTo(map_471915a40bfab11e35cb3af0d4281f52);
#
#
#             var feature_group_cba6f7263595049da4125aa423d3281f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b8cb236d686448acddebcd2f70640a3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cba6f7263595049da4125aa423d3281f);
#
#
#         var popup_54cb47bbf465cb1f43f835ecf9c417bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de2a74419f30968f1beb70c32319acb9 = $(`&lt;div id=&quot;html_de2a74419f30968f1beb70c32319acb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_54cb47bbf465cb1f43f835ecf9c417bb.setContent(html_de2a74419f30968f1beb70c32319acb9);
#
#
#
#         marker_b8cb236d686448acddebcd2f70640a3d.bindPopup(popup_54cb47bbf465cb1f43f835ecf9c417bb)
#         ;
#
#
#
#
#             var marker_8c7749b999a609b6cb474ca7c4b3e7fc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cba6f7263595049da4125aa423d3281f);
#
#
#         var popup_843357632521eab220da2e45353664a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94e7852d11e58aed5e84310bc424c8ed = $(`&lt;div id=&quot;html_94e7852d11e58aed5e84310bc424c8ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_843357632521eab220da2e45353664a1.setContent(html_94e7852d11e58aed5e84310bc424c8ed);
#
#
#
#         marker_8c7749b999a609b6cb474ca7c4b3e7fc.bindPopup(popup_843357632521eab220da2e45353664a1)
#         ;
#
#
#
#
#             var marker_a6c82f2e16c5d64008d8bb7c8f2b8886 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cba6f7263595049da4125aa423d3281f);
#
#
#         var popup_dd983575d9cf7e33c72825ace41ec483 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b01b68219998370ef87b92aed0db5637 = $(`&lt;div id=&quot;html_b01b68219998370ef87b92aed0db5637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dd983575d9cf7e33c72825ace41ec483.setContent(html_b01b68219998370ef87b92aed0db5637);
#
#
#
#         marker_a6c82f2e16c5d64008d8bb7c8f2b8886.bindPopup(popup_dd983575d9cf7e33c72825ace41ec483)
#         ;
#
#
#
#
#             var marker_75d0a641dd4fadc736c12819407bbac6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cba6f7263595049da4125aa423d3281f);
#
#
#         var popup_2c673deb1aa86a0b98cca4bb833665e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b12f1c1cb8df92b6926237671e0f3240 = $(`&lt;div id=&quot;html_b12f1c1cb8df92b6926237671e0f3240&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c673deb1aa86a0b98cca4bb833665e6.setContent(html_b12f1c1cb8df92b6926237671e0f3240);
#
#
#
#         marker_75d0a641dd4fadc736c12819407bbac6.bindPopup(popup_2c673deb1aa86a0b98cca4bb833665e6)
#         ;
#
#
#
#
#             var marker_edde4504daf5d6bd1c6f98b5cbbd8614 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cba6f7263595049da4125aa423d3281f);
#
#
#         var popup_b678d8a1a9c506986b876d0a9563d8ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07517ae8b0f427540006270b151e3770 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07517ae8b0f427540006270b151e3770&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07517ae8b0f427540006270b151e3770 = L.map(
#                 &quot;map_07517ae8b0f427540006270b151e3770&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d2a4d0a65226c318606d6bc7e0be350 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d2a4d0a65226c318606d6bc7e0be350.addTo(map_07517ae8b0f427540006270b151e3770);
#
#
#             var feature_group_7bda3a1da6944a14357943cb0d41fc08 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7bda3a1da6944a14357943cb0d41fc08.addTo(map_07517ae8b0f427540006270b151e3770);
#
#
#             var feature_group_sub_group_e1f73b5d0217779d880726197b6d5d2a = L.featureGroup.subGroup(
#                 feature_group_7bda3a1da6944a14357943cb0d41fc08
#             );
#
#
#             var marker_b29d03e486a3f5baecd43dcd8e7e78c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e1f73b5d0217779d880726197b6d5d2a);
#
#
#         var popup_3c1a29b606a654a7508bd2456b542270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2eb186da21d3aa3cdacb2fe9ae0de12 = $(`&lt;div id=&quot;html_f2eb186da21d3aa3cdacb2fe9ae0de12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3c1a29b606a654a7508bd2456b542270.setContent(html_f2eb186da21d3aa3cdacb2fe9ae0de12);
#
#
#
#         marker_b29d03e486a3f5baecd43dcd8e7e78c6.bindPopup(popup_3c1a29b606a654a7508bd2456b542270)
#         ;
#
#
#
#
#             var marker_e83f2ae282ee2efe4521d6d5ee25c80b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e1f73b5d0217779d880726197b6d5d2a);
#
#
#         var popup_3f4cbe48826bf93ce6eba8e91a1843a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb569173c61a068da628de441aa9e9bf = $(`&lt;div id=&quot;html_bb569173c61a068da628de441aa9e9bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3f4cbe48826bf93ce6eba8e91a1843a5.setContent(html_bb569173c61a068da628de441aa9e9bf);
#
#
#
#         marker_e83f2ae282ee2efe4521d6d5ee25c80b.bindPopup(popup_3f4cbe48826bf93ce6eba8e91a1843a5)
#         ;
#
#
#
#
#             var marker_ef69aef47c7b3e3f1884738460f7b68e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e1f73b5d0217779d880726197b6d5d2a);
#
#
#         var popup_b78684c71df93e417a713c2443bc66c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3aafa87189367c1ca05276ece2ecbe9c = $(`&lt;div id=&quot;html_3aafa87189367c1ca05276ece2ecbe9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b78684c71df93e417a713c2443bc66c7.setContent(html_3aafa87189367c1ca05276ece2ecbe9c);
#
#
#
#         marker_ef69aef47c7b3e3f1884738460f7b68e.bindPopup(popup_b78684c71df93e417a713c2443bc66c7)
#         ;
#
#
#
#
#             var marker_b63926fae1f715c1ee45daa10c342534 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e1f73b5d0217779d880726197b6d5d2a);
#
#
#         var popup_0fa9e4c9edcece43deeecd8be268de8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ea7b7bf19620a6cc00c0fc0bd568b1 = $(`&lt;div id=&quot;html_e2ea7b7bf19620a6cc00c0fc0bd568b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0fa9e4c9edcece43deeecd8be268de8d.setContent(html_e2ea7b7bf19620a6cc00c0fc0bd568b1);
#
#
#
#         marker_
