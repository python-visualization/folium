# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9f1ca023b3364f39d5bddcf132d323f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9f1ca023b3364f39d5bddcf132d323f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9f1ca023b3364f39d5bddcf132d323f = L.map(
#                 &quot;map_a9f1ca023b3364f39d5bddcf132d323f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8952731d6051f5d0c10e7540f0ce2e58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8952731d6051f5d0c10e7540f0ce2e58.addTo(map_a9f1ca023b3364f39d5bddcf132d323f);
#
#
#             var marker_a97d0a307db7c7d549019f54ace99bce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a9f1ca023b3364f39d5bddcf132d323f);
#
#
#         var popup_2c5cf74138bfe2b5883fb5c6a6b5d19d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_083ec47293a57628b45847d169b1a21a = $(`&lt;div id=&quot;html_083ec47293a57628b45847d169b1a21a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2c5cf74138bfe2b5883fb5c6a6b5d19d.setContent(html_083ec47293a57628b45847d169b1a21a);
#
#
#
#         marker_a97d0a307db7c7d549019f54ace99bce.bindPopup(popup_2c5cf74138bfe2b5883fb5c6a6b5d19d)
#         ;
#
#
#
#
#             var marker_fa9b0e80c6d7c2035b1ca9d4af76dd2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a9f1ca023b3364f39d5bddcf132d323f);
#
#
#         var popup_e81ec77502f47ca44591e738cb25b2b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61b94596b51f03e401190f01812bdef2 = $(`&lt;div id=&quot;html_61b94596b51f03e401190f01812bdef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e81ec77502f47ca44591e738cb25b2b7.setContent(html_61b94596b51f03e401190f01812bdef2);
#
#
#
#         marker_fa9b0e80c6d7c2035b1ca9d4af76dd2d.bindPopup(popup_e81ec77502f47ca44591e738cb25b2b7)
#         ;
#
#
#
#
#             var marker_c8641bfe147662231ad405efc43d6315 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a9f1ca023b3364f39d5bddcf132d323f);
#
#
#         var popup_0ded7bd8525666339bd195806929b758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c38ea4f3dc375c468c0572e32615cdac = $(`&lt;div id=&quot;html_c38ea4f3dc375c468c0572e32615cdac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0ded7bd8525666339bd195806929b758.setContent(html_c38ea4f3dc375c468c0572e32615cdac);
#
#
#
#         marker_c8641bfe147662231ad405efc43d6315.bindPopup(popup_0ded7bd8525666339bd195806929b758)
#         ;
#
#
#
#
#             var marker_dc5d0d0e8a82104d6ab3684bca6a7f45 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a9f1ca023b3364f39d5bddcf132d323f);
#
#
#         var popup_bbee13218e95e336b5e26185be243410 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42027a4adda9fedf63fc19c7623abb85 = $(`&lt;div id=&quot;html_42027a4adda9fedf63fc19c7623abb85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bbee13218e95e336b5e26185be243410.setContent(html_42027a4adda9fedf63fc19c7623abb85);
#
#
#
#         marker_dc5d0d0e8a82104d6ab3684bca6a7f45.bindPopup(popup_bbee13218e95e336b5e26185be243410)
#         ;
#
#
#
#
#             var marker_6751c163eb28245bf4d6f11310e21f1f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a9f1ca023b3364f39d5bddcf132d323f);
#
#
#         var popup_b0bbf8d91a90f093a6be58b5871e62fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50697380436fd15b4882656706764c98 = $(`&lt;div id=&quot;html_50697380436fd15b4882656706764c98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b0bbf8d91a90f093a6be58b5871e62fc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_522f09efce37d9564b4164c284367267 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_522f09efce37d9564b4164c284367267&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_522f09efce37d9564b4164c284367267 = L.map(
#                 &quot;map_522f09efce37d9564b4164c284367267&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b8b3be4de881a8a37c3267302640ebc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b8b3be4de881a8a37c3267302640ebc.addTo(map_522f09efce37d9564b4164c284367267);
#
#
#             var feature_group_c10d49fbdc8724e62f737c7de263cbd5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_543dff7c0df3914aaec567a3299dc3f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c10d49fbdc8724e62f737c7de263cbd5);
#
#
#         var popup_9f7af10f3ef6852c394c6ec0a8682808 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_554e4b0c3c3f31f2fb84597738193540 = $(`&lt;div id=&quot;html_554e4b0c3c3f31f2fb84597738193540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9f7af10f3ef6852c394c6ec0a8682808.setContent(html_554e4b0c3c3f31f2fb84597738193540);
#
#
#
#         marker_543dff7c0df3914aaec567a3299dc3f3.bindPopup(popup_9f7af10f3ef6852c394c6ec0a8682808)
#         ;
#
#
#
#
#             var marker_33b1f433d576e253ce049a4620425a3c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c10d49fbdc8724e62f737c7de263cbd5);
#
#
#         var popup_71c4cc7417d7e54284b2993217689fe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_154612576617f295d9953fbd1941878b = $(`&lt;div id=&quot;html_154612576617f295d9953fbd1941878b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_71c4cc7417d7e54284b2993217689fe5.setContent(html_154612576617f295d9953fbd1941878b);
#
#
#
#         marker_33b1f433d576e253ce049a4620425a3c.bindPopup(popup_71c4cc7417d7e54284b2993217689fe5)
#         ;
#
#
#
#
#             var marker_f0d9e6cb6639acd9e3458b27fada723e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c10d49fbdc8724e62f737c7de263cbd5);
#
#
#         var popup_aa111f83d62a2f2fe7fbfbbf92aac96f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24e43b05fa87705c081971a4cc28e94b = $(`&lt;div id=&quot;html_24e43b05fa87705c081971a4cc28e94b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aa111f83d62a2f2fe7fbfbbf92aac96f.setContent(html_24e43b05fa87705c081971a4cc28e94b);
#
#
#
#         marker_f0d9e6cb6639acd9e3458b27fada723e.bindPopup(popup_aa111f83d62a2f2fe7fbfbbf92aac96f)
#         ;
#
#
#
#
#             var marker_f1136f7507cc66d38c56f53f21af79ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c10d49fbdc8724e62f737c7de263cbd5);
#
#
#         var popup_1c1eb6f13dcd2c4a000b48454ee18e50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96520cc46ba6d4cfe8d8f38971924cdd = $(`&lt;div id=&quot;html_96520cc46ba6d4cfe8d8f38971924cdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1c1eb6f13dcd2c4a000b48454ee18e50.setContent(html_96520cc46ba6d4cfe8d8f38971924cdd);
#
#
#
#         marker_f1136f7507cc66d38c56f53f21af79ea.bindPopup(popup_1c1eb6f13dcd2c4a000b48454ee18e50)
#         ;
#
#
#
#
#             var marker_f7053ecc788ef33f05f1676ab9c3a09e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c10d49fbdc8724e62f737c7de263cbd5);
#
#
#         var popup_29fde074a67a414f661bed212f38e89c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7091243826e0e85eb6683e06e87280d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7091243826e0e85eb6683e06e87280d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7091243826e0e85eb6683e06e87280d5 = L.map(
#                 &quot;map_7091243826e0e85eb6683e06e87280d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cd186c4af74dca864af7cf28055b93d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cd186c4af74dca864af7cf28055b93d.addTo(map_7091243826e0e85eb6683e06e87280d5);
#
#
#             var feature_group_0ac6058b2a05d1dbe8980ffc2d3673f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0ac6058b2a05d1dbe8980ffc2d3673f1.addTo(map_7091243826e0e85eb6683e06e87280d5);
#
#
#             var feature_group_sub_group_842ae7755b86af44d5f6d5b87a91aac7 = L.featureGroup.subGroup(
#                 feature_group_0ac6058b2a05d1dbe8980ffc2d3673f1
#             );
#
#
#             var marker_b5297bc2294558a442a5403069343813 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_842ae7755b86af44d5f6d5b87a91aac7);
#
#
#         var popup_b1eef11a40bdb9bcc942f1a2a02f7c3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b181ccd1b99abae56755ec825bc1a083 = $(`&lt;div id=&quot;html_b181ccd1b99abae56755ec825bc1a083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b1eef11a40bdb9bcc942f1a2a02f7c3a.setContent(html_b181ccd1b99abae56755ec825bc1a083);
#
#
#
#         marker_b5297bc2294558a442a5403069343813.bindPopup(popup_b1eef11a40bdb9bcc942f1a2a02f7c3a)
#         ;
#
#
#
#
#             var marker_a0afa9cf745458f314d297a35671345c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_842ae7755b86af44d5f6d5b87a91aac7);
#
#
#         var popup_41efa36d893636204002eb833b76c88b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a9521ba02e4f24cc89f8134384244d3 = $(`&lt;div id=&quot;html_8a9521ba02e4f24cc89f8134384244d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_41efa36d893636204002eb833b76c88b.setContent(html_8a9521ba02e4f24cc89f8134384244d3);
#
#
#
#         marker_a0afa9cf745458f314d297a35671345c.bindPopup(popup_41efa36d893636204002eb833b76c88b)
#         ;
#
#
#
#
#             var marker_d49355a265026b9620528f4d3660f57e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_842ae7755b86af44d5f6d5b87a91aac7);
#
#
#         var popup_baab36ccc5bf0fecb86a60f9c6061205 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e5c04ce8921841d735473e8a6626d5d = $(`&lt;div id=&quot;html_2e5c04ce8921841d735473e8a6626d5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_baab36ccc5bf0fecb86a60f9c6061205.setContent(html_2e5c04ce8921841d735473e8a6626d5d);
#
#
#
#         marker_d49355a265026b9620528f4d3660f57e.bindPopup(popup_baab36ccc5bf0fecb86a60f9c6061205)
#         ;
#
#
#
#
#             var marker_b829de5264c9efac3564f4c745780aec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_842ae7755b86af44d5f6d5b87a91aac7);
#
#
#         var popup_7a3e4ac84531841df3ac2685247c1833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d696f76040b5b77bf9458374773dea98 = $(`&lt;div id=&quot;html_d696f76040b5b77bf9458374773dea98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7a3e4ac84531841df3ac2685247c1833.setContent(html_d696f76040b5b77bf9458374773dea98);
#
#
#
#         marker_
