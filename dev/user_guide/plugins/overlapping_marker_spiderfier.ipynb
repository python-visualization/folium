# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a391052abbfc8fa11cd187705cb2ddfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a391052abbfc8fa11cd187705cb2ddfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a391052abbfc8fa11cd187705cb2ddfc = L.map(
#                 &quot;map_a391052abbfc8fa11cd187705cb2ddfc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e8f92a36c5e948a223bc7b149c358d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e8f92a36c5e948a223bc7b149c358d6.addTo(map_a391052abbfc8fa11cd187705cb2ddfc);
#
#
#             var marker_49b8a9ecf69e96a03934a2570897f591 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a391052abbfc8fa11cd187705cb2ddfc);
#
#
#         var popup_7618bb89d45b20c2fcc430cc5d9f28bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaeeb9c6cac4d1e4fbac0314beed5290 = $(`&lt;div id=&quot;html_eaeeb9c6cac4d1e4fbac0314beed5290&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7618bb89d45b20c2fcc430cc5d9f28bc.setContent(html_eaeeb9c6cac4d1e4fbac0314beed5290);
#
#
#
#         marker_49b8a9ecf69e96a03934a2570897f591.bindPopup(popup_7618bb89d45b20c2fcc430cc5d9f28bc)
#         ;
#
#
#
#
#             var marker_1a63b59e93a28847f03be68626434325 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a391052abbfc8fa11cd187705cb2ddfc);
#
#
#         var popup_959871c631f64bdc0309b9dfccff956f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_433dbf21f3721534ee307e7b5b7f3a13 = $(`&lt;div id=&quot;html_433dbf21f3721534ee307e7b5b7f3a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_959871c631f64bdc0309b9dfccff956f.setContent(html_433dbf21f3721534ee307e7b5b7f3a13);
#
#
#
#         marker_1a63b59e93a28847f03be68626434325.bindPopup(popup_959871c631f64bdc0309b9dfccff956f)
#         ;
#
#
#
#
#             var marker_5a068754e70e7a2b15d25cbebbebdb80 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a391052abbfc8fa11cd187705cb2ddfc);
#
#
#         var popup_1d42d1ff6af7bb25ee915f7fc9c01a54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47974bf7afb9a7e7084c85170cd0996e = $(`&lt;div id=&quot;html_47974bf7afb9a7e7084c85170cd0996e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d42d1ff6af7bb25ee915f7fc9c01a54.setContent(html_47974bf7afb9a7e7084c85170cd0996e);
#
#
#
#         marker_5a068754e70e7a2b15d25cbebbebdb80.bindPopup(popup_1d42d1ff6af7bb25ee915f7fc9c01a54)
#         ;
#
#
#
#
#             var marker_bd6793c9500c9bd742060e3668f4138f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a391052abbfc8fa11cd187705cb2ddfc);
#
#
#         var popup_c039f99e7ce5860eef9d61d090daf023 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41102f15c3baeb532d3cce724620d821 = $(`&lt;div id=&quot;html_41102f15c3baeb532d3cce724620d821&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c039f99e7ce5860eef9d61d090daf023.setContent(html_41102f15c3baeb532d3cce724620d821);
#
#
#
#         marker_bd6793c9500c9bd742060e3668f4138f.bindPopup(popup_c039f99e7ce5860eef9d61d090daf023)
#         ;
#
#
#
#
#             var marker_e9242d7fd1617ff4bce5f7b2e7a434b1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a391052abbfc8fa11cd187705cb2ddfc);
#
#
#         var popup_d52e67b023cd94478028c79f27433bc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f707f200894f82b3808545ecc291c6d3 = $(`&lt;div id=&quot;html_f707f200894f82b3808545ecc291c6d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d52e67b023cd94478028c79f27433bc6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_819568c79175d6c8ec95e25e5679afc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_819568c79175d6c8ec95e25e5679afc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_819568c79175d6c8ec95e25e5679afc1 = L.map(
#                 &quot;map_819568c79175d6c8ec95e25e5679afc1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cffebc33302d18f438a42441d213973a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cffebc33302d18f438a42441d213973a.addTo(map_819568c79175d6c8ec95e25e5679afc1);
#
#
#             var feature_group_967350a56965ba9f0c4523827e15b42c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9a652577b0bee9635ff590cfe16bdcbf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_967350a56965ba9f0c4523827e15b42c);
#
#
#         var popup_4adb5cad69d0bf6ce4bee8dad5a46daa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f121c6a3467c2a162ba247656e30b8e = $(`&lt;div id=&quot;html_7f121c6a3467c2a162ba247656e30b8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4adb5cad69d0bf6ce4bee8dad5a46daa.setContent(html_7f121c6a3467c2a162ba247656e30b8e);
#
#
#
#         marker_9a652577b0bee9635ff590cfe16bdcbf.bindPopup(popup_4adb5cad69d0bf6ce4bee8dad5a46daa)
#         ;
#
#
#
#
#             var marker_72d12e1c1bbb9b0a7f0cb8d28ad89aae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_967350a56965ba9f0c4523827e15b42c);
#
#
#         var popup_169436a246c9b0dc704bb743f81ecd27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6e747c479da1dc6d804156c11fe9a03 = $(`&lt;div id=&quot;html_b6e747c479da1dc6d804156c11fe9a03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_169436a246c9b0dc704bb743f81ecd27.setContent(html_b6e747c479da1dc6d804156c11fe9a03);
#
#
#
#         marker_72d12e1c1bbb9b0a7f0cb8d28ad89aae.bindPopup(popup_169436a246c9b0dc704bb743f81ecd27)
#         ;
#
#
#
#
#             var marker_c1f0239440373d8cae7999801938cf74 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_967350a56965ba9f0c4523827e15b42c);
#
#
#         var popup_bc6b32e758d7374c64e604b0781e4ad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08a80a1b3d84859cdfae091bd1b359d1 = $(`&lt;div id=&quot;html_08a80a1b3d84859cdfae091bd1b359d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bc6b32e758d7374c64e604b0781e4ad4.setContent(html_08a80a1b3d84859cdfae091bd1b359d1);
#
#
#
#         marker_c1f0239440373d8cae7999801938cf74.bindPopup(popup_bc6b32e758d7374c64e604b0781e4ad4)
#         ;
#
#
#
#
#             var marker_ca69b21510ad5c60b3afce92cef2b0e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_967350a56965ba9f0c4523827e15b42c);
#
#
#         var popup_ebb9a72358269e345b7b95b4b1f38949 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e1e08c28dbba12ce12779c72413a016 = $(`&lt;div id=&quot;html_8e1e08c28dbba12ce12779c72413a016&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ebb9a72358269e345b7b95b4b1f38949.setContent(html_8e1e08c28dbba12ce12779c72413a016);
#
#
#
#         marker_ca69b21510ad5c60b3afce92cef2b0e4.bindPopup(popup_ebb9a72358269e345b7b95b4b1f38949)
#         ;
#
#
#
#
#             var marker_be077ad3232669a6bc7c5ccb260773aa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_967350a56965ba9f0c4523827e15b42c);
#
#
#         var popup_47503bf51f7edfbbd505a265169e91f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd22dd7e02861275883e00c3da9922c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd22dd7e02861275883e00c3da9922c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd22dd7e02861275883e00c3da9922c9 = L.map(
#                 &quot;map_bd22dd7e02861275883e00c3da9922c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_537bf2bf2c4399abe610eb4caa2f0ff3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_537bf2bf2c4399abe610eb4caa2f0ff3.addTo(map_bd22dd7e02861275883e00c3da9922c9);
#
#
#             var feature_group_3638fd602ad53c0cd74c3c1081d396e1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3638fd602ad53c0cd74c3c1081d396e1.addTo(map_bd22dd7e02861275883e00c3da9922c9);
#
#
#             var feature_group_sub_group_f564c601f09ad1a17fddbe63fcff2aac = L.featureGroup.subGroup(
#                 feature_group_3638fd602ad53c0cd74c3c1081d396e1
#             );
#
#
#             var marker_429b94427c01bcd2df838536ed99292e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f564c601f09ad1a17fddbe63fcff2aac);
#
#
#         var popup_8e57c7a3bec3495d083b13f9ca01e321 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7de0c9cc35c79863a934efef208e3f16 = $(`&lt;div id=&quot;html_7de0c9cc35c79863a934efef208e3f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8e57c7a3bec3495d083b13f9ca01e321.setContent(html_7de0c9cc35c79863a934efef208e3f16);
#
#
#
#         marker_429b94427c01bcd2df838536ed99292e.bindPopup(popup_8e57c7a3bec3495d083b13f9ca01e321)
#         ;
#
#
#
#
#             var marker_f72c179d05c9864a9d5d29e1eb490a58 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f564c601f09ad1a17fddbe63fcff2aac);
#
#
#         var popup_1e1aa9cf1d92284d3040e019fe575086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88a968f6df37c34daedf6c17b5e74e29 = $(`&lt;div id=&quot;html_88a968f6df37c34daedf6c17b5e74e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1e1aa9cf1d92284d3040e019fe575086.setContent(html_88a968f6df37c34daedf6c17b5e74e29);
#
#
#
#         marker_f72c179d05c9864a9d5d29e1eb490a58.bindPopup(popup_1e1aa9cf1d92284d3040e019fe575086)
#         ;
#
#
#
#
#             var marker_99d16dbc32dbffdd7293b6612ea2f00f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f564c601f09ad1a17fddbe63fcff2aac);
#
#
#         var popup_50259a389e07e94f32df82f5b1a031fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c54d514235f448a0523f8555843c63bb = $(`&lt;div id=&quot;html_c54d514235f448a0523f8555843c63bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_50259a389e07e94f32df82f5b1a031fc.setContent(html_c54d514235f448a0523f8555843c63bb);
#
#
#
#         marker_99d16dbc32dbffdd7293b6612ea2f00f.bindPopup(popup_50259a389e07e94f32df82f5b1a031fc)
#         ;
#
#
#
#
#             var marker_00bb7b25335f84c6199b462e30c1229d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f564c601f09ad1a17fddbe63fcff2aac);
#
#
#         var popup_474cb99ac4d9092ffdc33d678438b642 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24a50003928d05db9757d2e93d4ac705 = $(`&lt;div id=&quot;html_24a50003928d05db9757d2e93d4ac705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_474cb99ac4d9092ffdc33d678438b642.setContent(html_24a50003928d05db9757d2e93d4ac705);
#
#
#
#         marker_
