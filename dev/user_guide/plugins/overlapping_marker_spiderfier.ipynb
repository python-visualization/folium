# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e1f56c8165fa4081ed8d3eb30a9253a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e1f56c8165fa4081ed8d3eb30a9253a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e1f56c8165fa4081ed8d3eb30a9253a = L.map(
#                 &quot;map_3e1f56c8165fa4081ed8d3eb30a9253a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84bc983ac7e6c56ac9cd497cfdca83d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84bc983ac7e6c56ac9cd497cfdca83d8.addTo(map_3e1f56c8165fa4081ed8d3eb30a9253a);
#
#
#             var marker_8895d841140a4cd2275bbc0767309cb3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3e1f56c8165fa4081ed8d3eb30a9253a);
#
#
#         var popup_55eeef57dd22c93394a081cd360c8882 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35dcc515a6629edde4ee428cdb1cf344 = $(`&lt;div id=&quot;html_35dcc515a6629edde4ee428cdb1cf344&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_55eeef57dd22c93394a081cd360c8882.setContent(html_35dcc515a6629edde4ee428cdb1cf344);
#
#
#
#         marker_8895d841140a4cd2275bbc0767309cb3.bindPopup(popup_55eeef57dd22c93394a081cd360c8882)
#         ;
#
#
#
#
#             var marker_15bdd96fa60cd1f194158af76b52bf09 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3e1f56c8165fa4081ed8d3eb30a9253a);
#
#
#         var popup_57cbad633e95304898798de81d94385f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7670545dfa95a81ce046e99dac251f73 = $(`&lt;div id=&quot;html_7670545dfa95a81ce046e99dac251f73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_57cbad633e95304898798de81d94385f.setContent(html_7670545dfa95a81ce046e99dac251f73);
#
#
#
#         marker_15bdd96fa60cd1f194158af76b52bf09.bindPopup(popup_57cbad633e95304898798de81d94385f)
#         ;
#
#
#
#
#             var marker_5a392ca65e3aab83929f4897ae591f5f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3e1f56c8165fa4081ed8d3eb30a9253a);
#
#
#         var popup_be09bc917b6080b9a2e0f45ae56a1ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9ddae0125e8ff9b331639a0a352312d = $(`&lt;div id=&quot;html_b9ddae0125e8ff9b331639a0a352312d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_be09bc917b6080b9a2e0f45ae56a1ee5.setContent(html_b9ddae0125e8ff9b331639a0a352312d);
#
#
#
#         marker_5a392ca65e3aab83929f4897ae591f5f.bindPopup(popup_be09bc917b6080b9a2e0f45ae56a1ee5)
#         ;
#
#
#
#
#             var marker_518bcf092cf3d9743f55c26c79d0280d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3e1f56c8165fa4081ed8d3eb30a9253a);
#
#
#         var popup_2edbea8fac55fb8c9100962c88c66b50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_945d85681cdd82d1f7ffa5615bb6efa3 = $(`&lt;div id=&quot;html_945d85681cdd82d1f7ffa5615bb6efa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2edbea8fac55fb8c9100962c88c66b50.setContent(html_945d85681cdd82d1f7ffa5615bb6efa3);
#
#
#
#         marker_518bcf092cf3d9743f55c26c79d0280d.bindPopup(popup_2edbea8fac55fb8c9100962c88c66b50)
#         ;
#
#
#
#
#             var marker_48933b8a355741c5fd0bbae4e9c787f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3e1f56c8165fa4081ed8d3eb30a9253a);
#
#
#         var popup_c913e1b06c9b75ab01762a51a841eb97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12572ad7e57cd5b5fae2f42cafc74ba4 = $(`&lt;div id=&quot;html_12572ad7e57cd5b5fae2f42cafc74ba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c913e1b06c9b75ab01762a51a841eb97.setContent(html_12572ad7e57cd5b5fae2f42cafc74ba4);
#
#
#
#         marker_48933b8a355741c5fd0bbae4e9c787f5.bindPopup(popup_c913e1b06c9b75ab01762a51a841eb97)
#         ;
#
#
#
#
#             var marker_a02c551655

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9db30aa29de44cc138c2e6d8c10890af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9db30aa29de44cc138c2e6d8c10890af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9db30aa29de44cc138c2e6d8c10890af = L.map(
#                 &quot;map_9db30aa29de44cc138c2e6d8c10890af&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b42f4410a329b4cb0874f4e94e16b827 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b42f4410a329b4cb0874f4e94e16b827.addTo(map_9db30aa29de44cc138c2e6d8c10890af);
#
#
#             var feature_group_842408fbc797e81ad98952b8e71d0d3b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_47d14363f6f665790ac5bd77d5e0206e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_842408fbc797e81ad98952b8e71d0d3b);
#
#
#         var popup_1e2a5c7430c2e19a5ecaa218326858e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6be0dd5847510a03b7ee5eb2a4c5bc1e = $(`&lt;div id=&quot;html_6be0dd5847510a03b7ee5eb2a4c5bc1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1e2a5c7430c2e19a5ecaa218326858e1.setContent(html_6be0dd5847510a03b7ee5eb2a4c5bc1e);
#
#
#
#         marker_47d14363f6f665790ac5bd77d5e0206e.bindPopup(popup_1e2a5c7430c2e19a5ecaa218326858e1)
#         ;
#
#
#
#
#             var marker_0308270162784f9da5c390e3a23359c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_842408fbc797e81ad98952b8e71d0d3b);
#
#
#         var popup_9f44d0b5182d9e09a2cc1cfbdd02297f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b52ba4cefb6e7de32e62e8abb6e6c3e9 = $(`&lt;div id=&quot;html_b52ba4cefb6e7de32e62e8abb6e6c3e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9f44d0b5182d9e09a2cc1cfbdd02297f.setContent(html_b52ba4cefb6e7de32e62e8abb6e6c3e9);
#
#
#
#         marker_0308270162784f9da5c390e3a23359c3.bindPopup(popup_9f44d0b5182d9e09a2cc1cfbdd02297f)
#         ;
#
#
#
#
#             var marker_7d6e162044a38ca56b15c6345fefeead = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_842408fbc797e81ad98952b8e71d0d3b);
#
#
#         var popup_5992bc0fe81cca3c3eba06b9c6f1cf22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0dc2fb1950e37ffe809c1f53689b3ec = $(`&lt;div id=&quot;html_d0dc2fb1950e37ffe809c1f53689b3ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5992bc0fe81cca3c3eba06b9c6f1cf22.setContent(html_d0dc2fb1950e37ffe809c1f53689b3ec);
#
#
#
#         marker_7d6e162044a38ca56b15c6345fefeead.bindPopup(popup_5992bc0fe81cca3c3eba06b9c6f1cf22)
#         ;
#
#
#
#
#             var marker_9d7c794df9d436f5292a7052004a61ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_842408fbc797e81ad98952b8e71d0d3b);
#
#
#         var popup_fae682036417ec1c792c7bc86c50a853 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6c0d389e8a773ca48b3aedd74840cee = $(`&lt;div id=&quot;html_c6c0d389e8a773ca48b3aedd74840cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fae682036417ec1c792c7bc86c50a853.setContent(html_c6c0d389e8a773ca48b3aedd74840cee);
#
#
#
#         marker_9d7c794df9d436f5292a7052004a61ed.bindPopup(popup_fae682036417ec1c792c7bc86c50a853)
#         ;
#
#
#
#
#             var marker_cfd33e0af57499265dbf1229d69a51f4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_842408fbc797e81ad98952b8e71d0d3b);
#
#
#         var popup_2315a1b3398f0af9bb47a7d103fce3cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7315017fb8b504787502415f092be19d = $(`&lt;div id=&quot;html_7315017fb8b504787502415f092be19d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_2315a1b3398f0af9bb

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4eb3caaababf990cd8c283b08e1ac63f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4eb3caaababf990cd8c283b08e1ac63f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4eb3caaababf990cd8c283b08e1ac63f = L.map(
#                 &quot;map_4eb3caaababf990cd8c283b08e1ac63f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_958731d717b87e2aa138f3b1799fdf67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_958731d717b87e2aa138f3b1799fdf67.addTo(map_4eb3caaababf990cd8c283b08e1ac63f);
#
#
#             var feature_group_97fd2b46a93b8065d7d737e4bbeba7f3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_97fd2b46a93b8065d7d737e4bbeba7f3.addTo(map_4eb3caaababf990cd8c283b08e1ac63f);
#
#
#             var feature_group_sub_group_b57bf227ba11bfbeaa5cf4fc1c05092c = L.featureGroup.subGroup(
#                 feature_group_97fd2b46a93b8065d7d737e4bbeba7f3
#             );
#
#
#             var marker_3f9d4a695461823a362ad6f5785da8e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57bf227ba11bfbeaa5cf4fc1c05092c);
#
#
#         var popup_b0450c72aef0657b4ca344fdf4dca1a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7562fd109a4ee2a3daab180403e6b84 = $(`&lt;div id=&quot;html_c7562fd109a4ee2a3daab180403e6b84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b0450c72aef0657b4ca344fdf4dca1a5.setContent(html_c7562fd109a4ee2a3daab180403e6b84);
#
#
#
#         marker_3f9d4a695461823a362ad6f5785da8e4.bindPopup(popup_b0450c72aef0657b4ca344fdf4dca1a5)
#         ;
#
#
#
#
#             var marker_e0c30965b2ebb1af17c90ef10b6f5d3a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57bf227ba11bfbeaa5cf4fc1c05092c);
#
#
#         var popup_f4eb99f1381f5ac26723dac0349ed673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2206110c3f8ff9abd2ff158b1377aed8 = $(`&lt;div id=&quot;html_2206110c3f8ff9abd2ff158b1377aed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f4eb99f1381f5ac26723dac0349ed673.setContent(html_2206110c3f8ff9abd2ff158b1377aed8);
#
#
#
#         marker_e0c30965b2ebb1af17c90ef10b6f5d3a.bindPopup(popup_f4eb99f1381f5ac26723dac0349ed673)
#         ;
#
#
#
#
#             var marker_08bde2906b89331a5196b267084c323c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57bf227ba11bfbeaa5cf4fc1c05092c);
#
#
#         var popup_8e0be756eb9c65a11467e301b9746c9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3e9c0d559601fcc4db24591733a7663 = $(`&lt;div id=&quot;html_e3e9c0d559601fcc4db24591733a7663&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8e0be756eb9c65a11467e301b9746c9d.setContent(html_e3e9c0d559601fcc4db24591733a7663);
#
#
#
#         marker_08bde2906b89331a5196b267084c323c.bindPopup(popup_8e0be756eb9c65a11467e301b9746c9d)
#         ;
#
#
#
#
#             var marker_5fd53ebdba2edf2b9d558c501666bcb7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57bf227ba11bfbeaa5cf4fc1c05092c);
#
#
#         var popup_27825d0344ae0316fdda9f042ee66d32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20096d3282d90763aef9be649875d42f = $(`&lt;div id=&quot;html_20096d3282d90763aef9be649875d42f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_27825d0344ae0316fdda9f042ee66d32.setContent(html_20096d3282d90763aef9be649875d42f);
#
#
#
#         marker_5fd53ebdba2edf2b9d558c501666bcb7.bindPopup(popup_27825d0344ae0316fdda9f042ee66d32)
#         ;
#
#
#
#
#             var marker_d806944205e73b12ab3604145ff585f7 = L.marker(
#                 [45.050399999999996, 3.0504],
