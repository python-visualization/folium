# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1c0a0f3d66bfb4930dd48f67c199f73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1c0a0f3d66bfb4930dd48f67c199f73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1c0a0f3d66bfb4930dd48f67c199f73 = L.map(
#                 &quot;map_a1c0a0f3d66bfb4930dd48f67c199f73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b422f3e96901a24a6373df3dbff244e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b422f3e96901a24a6373df3dbff244e.addTo(map_a1c0a0f3d66bfb4930dd48f67c199f73);
#
#
#             var marker_41dc061839a1d0c5c40fc9e290b9f3ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a1c0a0f3d66bfb4930dd48f67c199f73);
#
#
#         var popup_d74ffe86848f8e06eb421ff1b2044133 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2986f8ae67f75e7f5268de5fdd719caa = $(`&lt;div id=&quot;html_2986f8ae67f75e7f5268de5fdd719caa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d74ffe86848f8e06eb421ff1b2044133.setContent(html_2986f8ae67f75e7f5268de5fdd719caa);
#
#
#
#         marker_41dc061839a1d0c5c40fc9e290b9f3ea.bindPopup(popup_d74ffe86848f8e06eb421ff1b2044133)
#         ;
#
#
#
#
#             var marker_f6e1a90357488e19c8114e40f44146a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a1c0a0f3d66bfb4930dd48f67c199f73);
#
#
#         var popup_0babc237bf59a32d761b5591210b8fa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61ea49592c1c53d52f5cf47d84e9814f = $(`&lt;div id=&quot;html_61ea49592c1c53d52f5cf47d84e9814f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0babc237bf59a32d761b5591210b8fa0.setContent(html_61ea49592c1c53d52f5cf47d84e9814f);
#
#
#
#         marker_f6e1a90357488e19c8114e40f44146a1.bindPopup(popup_0babc237bf59a32d761b5591210b8fa0)
#         ;
#
#
#
#
#             var marker_f7027e6b8712c8da984f5b7a3d0bb145 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a1c0a0f3d66bfb4930dd48f67c199f73);
#
#
#         var popup_d4dc018bd704940885fc42da15cf0da9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_050d81269fe79d379a3a3df6e90a0d47 = $(`&lt;div id=&quot;html_050d81269fe79d379a3a3df6e90a0d47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d4dc018bd704940885fc42da15cf0da9.setContent(html_050d81269fe79d379a3a3df6e90a0d47);
#
#
#
#         marker_f7027e6b8712c8da984f5b7a3d0bb145.bindPopup(popup_d4dc018bd704940885fc42da15cf0da9)
#         ;
#
#
#
#
#             var marker_261e36949dca9e4364b06068c59bd01d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a1c0a0f3d66bfb4930dd48f67c199f73);
#
#
#         var popup_86809ae0aee8f68f032ad90cbae28a79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_243dd8408855413582f99cd1233a3539 = $(`&lt;div id=&quot;html_243dd8408855413582f99cd1233a3539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_86809ae0aee8f68f032ad90cbae28a79.setContent(html_243dd8408855413582f99cd1233a3539);
#
#
#
#         marker_261e36949dca9e4364b06068c59bd01d.bindPopup(popup_86809ae0aee8f68f032ad90cbae28a79)
#         ;
#
#
#
#
#             var marker_2a3f894f3e11181af3e002a6327e0950 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a1c0a0f3d66bfb4930dd48f67c199f73);
#
#
#         var popup_f61535b1c94500408074b916f1e6d74b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15211bc968ab1439388569f7bbb5d66f = $(`&lt;div id=&quot;html_15211bc968ab1439388569f7bbb5d66f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f61535b1c94500408074b916f1e6d74b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3cfdd4ba49c86994f45130d1e6c02d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3cfdd4ba49c86994f45130d1e6c02d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3cfdd4ba49c86994f45130d1e6c02d3 = L.map(
#                 &quot;map_b3cfdd4ba49c86994f45130d1e6c02d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54af589d8df41475ac999fe739e42689 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54af589d8df41475ac999fe739e42689.addTo(map_b3cfdd4ba49c86994f45130d1e6c02d3);
#
#
#             var feature_group_eec2e87ed64d82307e6fc9aa54b2eec5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ee421046e5756731612b34539fcae467 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eec2e87ed64d82307e6fc9aa54b2eec5);
#
#
#         var popup_58bd525e15ff16606dbead1afcb3db45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41e16757605cab2507f2eac0b6ec5e71 = $(`&lt;div id=&quot;html_41e16757605cab2507f2eac0b6ec5e71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_58bd525e15ff16606dbead1afcb3db45.setContent(html_41e16757605cab2507f2eac0b6ec5e71);
#
#
#
#         marker_ee421046e5756731612b34539fcae467.bindPopup(popup_58bd525e15ff16606dbead1afcb3db45)
#         ;
#
#
#
#
#             var marker_6a115b3c4ce4059ff494736c6eb85c20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eec2e87ed64d82307e6fc9aa54b2eec5);
#
#
#         var popup_500a4d7730ad09818c5a158ac078d700 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e7c0cec06a9172655176ba63d1e8c89 = $(`&lt;div id=&quot;html_5e7c0cec06a9172655176ba63d1e8c89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_500a4d7730ad09818c5a158ac078d700.setContent(html_5e7c0cec06a9172655176ba63d1e8c89);
#
#
#
#         marker_6a115b3c4ce4059ff494736c6eb85c20.bindPopup(popup_500a4d7730ad09818c5a158ac078d700)
#         ;
#
#
#
#
#             var marker_43583d11b6e03b810194b3554bddcd96 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eec2e87ed64d82307e6fc9aa54b2eec5);
#
#
#         var popup_0415beb3636a6394a3cda0e5f85a0b4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21aa7903ce3897d06294eb560ff520e0 = $(`&lt;div id=&quot;html_21aa7903ce3897d06294eb560ff520e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0415beb3636a6394a3cda0e5f85a0b4e.setContent(html_21aa7903ce3897d06294eb560ff520e0);
#
#
#
#         marker_43583d11b6e03b810194b3554bddcd96.bindPopup(popup_0415beb3636a6394a3cda0e5f85a0b4e)
#         ;
#
#
#
#
#             var marker_0a5facd3a40dcdbd1bd36727fdf09fa2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eec2e87ed64d82307e6fc9aa54b2eec5);
#
#
#         var popup_8aa9423e3d0c9ada1ff834b9b201738c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eb3e7180a98bc689fccde02ba30ff77 = $(`&lt;div id=&quot;html_6eb3e7180a98bc689fccde02ba30ff77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8aa9423e3d0c9ada1ff834b9b201738c.setContent(html_6eb3e7180a98bc689fccde02ba30ff77);
#
#
#
#         marker_0a5facd3a40dcdbd1bd36727fdf09fa2.bindPopup(popup_8aa9423e3d0c9ada1ff834b9b201738c)
#         ;
#
#
#
#
#             var marker_7f03139e2c8047098fe914edc5dc1d15 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eec2e87ed64d82307e6fc9aa54b2eec5);
#
#
#         var popup_68f5a906d1cde5d10b1fb2acc5fff58c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0c0e8054acb1a7b59a5d00427204424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0c0e8054acb1a7b59a5d00427204424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0c0e8054acb1a7b59a5d00427204424 = L.map(
#                 &quot;map_c0c0e8054acb1a7b59a5d00427204424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dffed2d0b87dce1831a0a9b065bcd9d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dffed2d0b87dce1831a0a9b065bcd9d0.addTo(map_c0c0e8054acb1a7b59a5d00427204424);
#
#
#             var feature_group_a83cef64465b95e8c9745df67b382057 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a83cef64465b95e8c9745df67b382057.addTo(map_c0c0e8054acb1a7b59a5d00427204424);
#
#
#             var feature_group_sub_group_a8294670f32c45b79be7a93f3e3b3a89 = L.featureGroup.subGroup(
#                 feature_group_a83cef64465b95e8c9745df67b382057
#             );
#
#
#             var marker_1c604b3f15b796f0b9776bdc64e90a93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8294670f32c45b79be7a93f3e3b3a89);
#
#
#         var popup_6d46755fc097d171bbcbf6f61e6f2481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9684ec938ecd672ffb9d35ae5d00565 = $(`&lt;div id=&quot;html_b9684ec938ecd672ffb9d35ae5d00565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6d46755fc097d171bbcbf6f61e6f2481.setContent(html_b9684ec938ecd672ffb9d35ae5d00565);
#
#
#
#         marker_1c604b3f15b796f0b9776bdc64e90a93.bindPopup(popup_6d46755fc097d171bbcbf6f61e6f2481)
#         ;
#
#
#
#
#             var marker_f544f46f8dcf6726d1aa87b96a84cda3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8294670f32c45b79be7a93f3e3b3a89);
#
#
#         var popup_d0d25f90fe21af054afe55739db9e961 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d96c596384de63ce1f7abdfe3dc09627 = $(`&lt;div id=&quot;html_d96c596384de63ce1f7abdfe3dc09627&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d0d25f90fe21af054afe55739db9e961.setContent(html_d96c596384de63ce1f7abdfe3dc09627);
#
#
#
#         marker_f544f46f8dcf6726d1aa87b96a84cda3.bindPopup(popup_d0d25f90fe21af054afe55739db9e961)
#         ;
#
#
#
#
#             var marker_699841661087110b5811ec1d13aa1f56 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8294670f32c45b79be7a93f3e3b3a89);
#
#
#         var popup_20971a5883bb5edee12b7093fc517d58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7611213f427f6ff1abfdfdcfb27e9731 = $(`&lt;div id=&quot;html_7611213f427f6ff1abfdfdcfb27e9731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_20971a5883bb5edee12b7093fc517d58.setContent(html_7611213f427f6ff1abfdfdcfb27e9731);
#
#
#
#         marker_699841661087110b5811ec1d13aa1f56.bindPopup(popup_20971a5883bb5edee12b7093fc517d58)
#         ;
#
#
#
#
#             var marker_76098bafb21af91b19c001d27e829743 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8294670f32c45b79be7a93f3e3b3a89);
#
#
#         var popup_d569e97d0e0a4bf5fcbc953d978c19cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64e33ec593f4eea8abf04e57a8dcb44c = $(`&lt;div id=&quot;html_64e33ec593f4eea8abf04e57a8dcb44c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d569e97d0e0a4bf5fcbc953d978c19cc.setContent(html_64e33ec593f4eea8abf04e57a8dcb44c);
#
#
#
#         marker_
