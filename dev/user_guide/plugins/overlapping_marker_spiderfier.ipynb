# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01b55200d4368a4c333bc38d290d7c6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01b55200d4368a4c333bc38d290d7c6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01b55200d4368a4c333bc38d290d7c6f = L.map(
#                 &quot;map_01b55200d4368a4c333bc38d290d7c6f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76fdeb7cc8299df28662f51100c4c446 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76fdeb7cc8299df28662f51100c4c446.addTo(map_01b55200d4368a4c333bc38d290d7c6f);
#
#
#             var marker_a0ab37037f72fbbfbd888c91dad5f0de = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_01b55200d4368a4c333bc38d290d7c6f);
#
#
#         var popup_337f2e6e3753b8f1da15013811a01d80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29a460f41e86c76c9b5a8689519c5e61 = $(`&lt;div id=&quot;html_29a460f41e86c76c9b5a8689519c5e61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_337f2e6e3753b8f1da15013811a01d80.setContent(html_29a460f41e86c76c9b5a8689519c5e61);
#
#
#
#         marker_a0ab37037f72fbbfbd888c91dad5f0de.bindPopup(popup_337f2e6e3753b8f1da15013811a01d80)
#         ;
#
#
#
#
#             var marker_7581ca6792c8239ffdae1fc82a7d7bcd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_01b55200d4368a4c333bc38d290d7c6f);
#
#
#         var popup_7100e2031ea29dbbf64d4b4ed0d8305b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb7a36dcd2930afe076ca40d094f487d = $(`&lt;div id=&quot;html_fb7a36dcd2930afe076ca40d094f487d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7100e2031ea29dbbf64d4b4ed0d8305b.setContent(html_fb7a36dcd2930afe076ca40d094f487d);
#
#
#
#         marker_7581ca6792c8239ffdae1fc82a7d7bcd.bindPopup(popup_7100e2031ea29dbbf64d4b4ed0d8305b)
#         ;
#
#
#
#
#             var marker_d8fc2b5c2c6276a84ab00540815f8e4a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_01b55200d4368a4c333bc38d290d7c6f);
#
#
#         var popup_d0f014cb68f372d9320ad2974624e225 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17be3bfc45a368e9d93c628336e7e425 = $(`&lt;div id=&quot;html_17be3bfc45a368e9d93c628336e7e425&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d0f014cb68f372d9320ad2974624e225.setContent(html_17be3bfc45a368e9d93c628336e7e425);
#
#
#
#         marker_d8fc2b5c2c6276a84ab00540815f8e4a.bindPopup(popup_d0f014cb68f372d9320ad2974624e225)
#         ;
#
#
#
#
#             var marker_50445885e55a785eecad656d95ccaf33 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_01b55200d4368a4c333bc38d290d7c6f);
#
#
#         var popup_807c4fe55fdd83d86231c913754da990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4ee26506ece9fa04b47ab1003b5d6d3 = $(`&lt;div id=&quot;html_f4ee26506ece9fa04b47ab1003b5d6d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_807c4fe55fdd83d86231c913754da990.setContent(html_f4ee26506ece9fa04b47ab1003b5d6d3);
#
#
#
#         marker_50445885e55a785eecad656d95ccaf33.bindPopup(popup_807c4fe55fdd83d86231c913754da990)
#         ;
#
#
#
#
#             var marker_0a59cb4c3488965cbcfb4db4236d8ca8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_01b55200d4368a4c333bc38d290d7c6f);
#
#
#         var popup_2f77e44012eac909e97b4296130ab11c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fa4079c00e3df30dbba05fb1abf40f9 = $(`&lt;div id=&quot;html_2fa4079c00e3df30dbba05fb1abf40f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2f77e44012eac909e97b4296130ab11c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85cb5d7f335bb93177778dc699a5e2a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85cb5d7f335bb93177778dc699a5e2a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85cb5d7f335bb93177778dc699a5e2a9 = L.map(
#                 &quot;map_85cb5d7f335bb93177778dc699a5e2a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd2ad4d7c2b189c1efcc0d944bfb3678 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd2ad4d7c2b189c1efcc0d944bfb3678.addTo(map_85cb5d7f335bb93177778dc699a5e2a9);
#
#
#             var feature_group_8cf65c79c0bda4de02478b6c7a9f9161 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_346a3ded488ac19a5809fa2d0fd9f638 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8cf65c79c0bda4de02478b6c7a9f9161);
#
#
#         var popup_c0b8c9174ffc0e94f8b833890ca728ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07646b7d8fd4bad1f1c9ddb76f3d25cb = $(`&lt;div id=&quot;html_07646b7d8fd4bad1f1c9ddb76f3d25cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c0b8c9174ffc0e94f8b833890ca728ab.setContent(html_07646b7d8fd4bad1f1c9ddb76f3d25cb);
#
#
#
#         marker_346a3ded488ac19a5809fa2d0fd9f638.bindPopup(popup_c0b8c9174ffc0e94f8b833890ca728ab)
#         ;
#
#
#
#
#             var marker_1d276637b0118c9c7705bdedaa3cf751 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8cf65c79c0bda4de02478b6c7a9f9161);
#
#
#         var popup_4892d561812242cff275ab3e4150bf75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12aee94e4aa85020d62855fff1dc0d48 = $(`&lt;div id=&quot;html_12aee94e4aa85020d62855fff1dc0d48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4892d561812242cff275ab3e4150bf75.setContent(html_12aee94e4aa85020d62855fff1dc0d48);
#
#
#
#         marker_1d276637b0118c9c7705bdedaa3cf751.bindPopup(popup_4892d561812242cff275ab3e4150bf75)
#         ;
#
#
#
#
#             var marker_73d00980c5c5f69baab3ded73761331f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8cf65c79c0bda4de02478b6c7a9f9161);
#
#
#         var popup_d9a397b0ab8cd313135481f18a44c2ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd57c32de3d42a508541cdbbc0fc0bab = $(`&lt;div id=&quot;html_bd57c32de3d42a508541cdbbc0fc0bab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d9a397b0ab8cd313135481f18a44c2ea.setContent(html_bd57c32de3d42a508541cdbbc0fc0bab);
#
#
#
#         marker_73d00980c5c5f69baab3ded73761331f.bindPopup(popup_d9a397b0ab8cd313135481f18a44c2ea)
#         ;
#
#
#
#
#             var marker_c28fa8124be4efeec229f0f5d711767a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8cf65c79c0bda4de02478b6c7a9f9161);
#
#
#         var popup_f6d020818f2c092b5c45939a14ab5208 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e9e0190f1b045ec90d6e4d608c4ef0d = $(`&lt;div id=&quot;html_3e9e0190f1b045ec90d6e4d608c4ef0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f6d020818f2c092b5c45939a14ab5208.setContent(html_3e9e0190f1b045ec90d6e4d608c4ef0d);
#
#
#
#         marker_c28fa8124be4efeec229f0f5d711767a.bindPopup(popup_f6d020818f2c092b5c45939a14ab5208)
#         ;
#
#
#
#
#             var marker_3e90097c4d691ad96415fbcdb2bce44e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8cf65c79c0bda4de02478b6c7a9f9161);
#
#
#         var popup_62b468a9d902f1b9dd07f2ab628df517 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db82406df53f2bfc2b612b059e74e766 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db82406df53f2bfc2b612b059e74e766&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db82406df53f2bfc2b612b059e74e766 = L.map(
#                 &quot;map_db82406df53f2bfc2b612b059e74e766&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05a16876d3cd512821679176d15a6505 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05a16876d3cd512821679176d15a6505.addTo(map_db82406df53f2bfc2b612b059e74e766);
#
#
#             var feature_group_9150c499b872d224a14ce6348d26109f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9150c499b872d224a14ce6348d26109f.addTo(map_db82406df53f2bfc2b612b059e74e766);
#
#
#             var feature_group_sub_group_bd0d665907069ecc4f03e821a95ab51a = L.featureGroup.subGroup(
#                 feature_group_9150c499b872d224a14ce6348d26109f
#             );
#
#
#             var marker_aeb64d6334205efc3a49cbf6f824396a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0d665907069ecc4f03e821a95ab51a);
#
#
#         var popup_8ff375c18c2b5bf76a625e441474f8b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5c3cec74bf1b3c3d0c2c76b62aafaea = $(`&lt;div id=&quot;html_b5c3cec74bf1b3c3d0c2c76b62aafaea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8ff375c18c2b5bf76a625e441474f8b3.setContent(html_b5c3cec74bf1b3c3d0c2c76b62aafaea);
#
#
#
#         marker_aeb64d6334205efc3a49cbf6f824396a.bindPopup(popup_8ff375c18c2b5bf76a625e441474f8b3)
#         ;
#
#
#
#
#             var marker_a118aec087e60905bc2a278b1ce9f3c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0d665907069ecc4f03e821a95ab51a);
#
#
#         var popup_7f2f67c78ebfb2e18454948f12a763d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db48bf3253dcc91d213c15d519f39cc0 = $(`&lt;div id=&quot;html_db48bf3253dcc91d213c15d519f39cc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f2f67c78ebfb2e18454948f12a763d1.setContent(html_db48bf3253dcc91d213c15d519f39cc0);
#
#
#
#         marker_a118aec087e60905bc2a278b1ce9f3c3.bindPopup(popup_7f2f67c78ebfb2e18454948f12a763d1)
#         ;
#
#
#
#
#             var marker_1f1ae8a194d18fa733bad6aa37d76d74 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0d665907069ecc4f03e821a95ab51a);
#
#
#         var popup_5b9a6b7c805765224bc8e4fafa6e9e57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74344d43ccd5958d0a555c4763953ce4 = $(`&lt;div id=&quot;html_74344d43ccd5958d0a555c4763953ce4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5b9a6b7c805765224bc8e4fafa6e9e57.setContent(html_74344d43ccd5958d0a555c4763953ce4);
#
#
#
#         marker_1f1ae8a194d18fa733bad6aa37d76d74.bindPopup(popup_5b9a6b7c805765224bc8e4fafa6e9e57)
#         ;
#
#
#
#
#             var marker_70312cacb20035895bfee1066e892caa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0d665907069ecc4f03e821a95ab51a);
#
#
#         var popup_c057a335f42e10ce128863011c6bdb4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e7893d1f68cd108ff413b4f5ddf24f3 = $(`&lt;div id=&quot;html_1e7893d1f68cd108ff413b4f5ddf24f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c057a335f42e10ce128863011c6bdb4c.setContent(html_1e7893d1f68cd108ff413b4f5ddf24f3);
#
#
#
#         marker_
