# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_057fc9de43f3c1c223617cc851f4feb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_057fc9de43f3c1c223617cc851f4feb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_057fc9de43f3c1c223617cc851f4feb9 = L.map(
#                 &quot;map_057fc9de43f3c1c223617cc851f4feb9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bf0046301246667860f846d7dff1fbd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4bf0046301246667860f846d7dff1fbd.addTo(map_057fc9de43f3c1c223617cc851f4feb9);
#
#
#             var marker_f1e202f25846fdd75f09801b10f2ef19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_057fc9de43f3c1c223617cc851f4feb9);
#
#
#         var popup_3ff3b8fada3fe148932ff3519a5c4dbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c98c0520702f3c68aca30ed24bf0340 = $(`&lt;div id=&quot;html_4c98c0520702f3c68aca30ed24bf0340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3ff3b8fada3fe148932ff3519a5c4dbf.setContent(html_4c98c0520702f3c68aca30ed24bf0340);
#
#
#
#         marker_f1e202f25846fdd75f09801b10f2ef19.bindPopup(popup_3ff3b8fada3fe148932ff3519a5c4dbf)
#         ;
#
#
#
#
#             var marker_aa0effe3b97f3529791f8aff6d884a0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_057fc9de43f3c1c223617cc851f4feb9);
#
#
#         var popup_ea71ecc37c37b0da94ba82177f6a624f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5d7847207c11426b4bd8a0a015598b9 = $(`&lt;div id=&quot;html_a5d7847207c11426b4bd8a0a015598b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ea71ecc37c37b0da94ba82177f6a624f.setContent(html_a5d7847207c11426b4bd8a0a015598b9);
#
#
#
#         marker_aa0effe3b97f3529791f8aff6d884a0f.bindPopup(popup_ea71ecc37c37b0da94ba82177f6a624f)
#         ;
#
#
#
#
#             var marker_2b4ed2eb3019404751de21a8b3934960 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_057fc9de43f3c1c223617cc851f4feb9);
#
#
#         var popup_bce687e82962d2f5ecc1667744668947 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52351d5c9038ec94805b49e65afe4935 = $(`&lt;div id=&quot;html_52351d5c9038ec94805b49e65afe4935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bce687e82962d2f5ecc1667744668947.setContent(html_52351d5c9038ec94805b49e65afe4935);
#
#
#
#         marker_2b4ed2eb3019404751de21a8b3934960.bindPopup(popup_bce687e82962d2f5ecc1667744668947)
#         ;
#
#
#
#
#             var marker_70a3c34653cf3f7ccd4ed2a954903b78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_057fc9de43f3c1c223617cc851f4feb9);
#
#
#         var popup_6cbaa078cea796a97a09228c6187e4b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f1e9a8efb172ea6876a8e76a6878151 = $(`&lt;div id=&quot;html_4f1e9a8efb172ea6876a8e76a6878151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6cbaa078cea796a97a09228c6187e4b1.setContent(html_4f1e9a8efb172ea6876a8e76a6878151);
#
#
#
#         marker_70a3c34653cf3f7ccd4ed2a954903b78.bindPopup(popup_6cbaa078cea796a97a09228c6187e4b1)
#         ;
#
#
#
#
#             var marker_fd6d0ebf0be0f8a9ea458247b70b6013 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_057fc9de43f3c1c223617cc851f4feb9);
#
#
#         var popup_2107313de28bddcaab51edc9c5b296d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eabfceb65cc9b3f8e0615b59bea8293 = $(`&lt;div id=&quot;html_7eabfceb65cc9b3f8e0615b59bea8293&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2107313de28bddcaab51edc9c5b296d3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3540b53ef1aacf126ecb92336ba1646 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3540b53ef1aacf126ecb92336ba1646&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3540b53ef1aacf126ecb92336ba1646 = L.map(
#                 &quot;map_c3540b53ef1aacf126ecb92336ba1646&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c520b5d6bd3a27bf9ec1ccdb8a574b75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c520b5d6bd3a27bf9ec1ccdb8a574b75.addTo(map_c3540b53ef1aacf126ecb92336ba1646);
#
#
#             var feature_group_c9a7fc25f133f130507b58f660ac8da6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_03b2e003aa88ccb8002b2f98a2eaa8d3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c9a7fc25f133f130507b58f660ac8da6);
#
#
#         var popup_1c8047d10c39229136994ac9971fe0f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1275629537b06d99ea4a4f1dbd4d114f = $(`&lt;div id=&quot;html_1275629537b06d99ea4a4f1dbd4d114f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1c8047d10c39229136994ac9971fe0f7.setContent(html_1275629537b06d99ea4a4f1dbd4d114f);
#
#
#
#         marker_03b2e003aa88ccb8002b2f98a2eaa8d3.bindPopup(popup_1c8047d10c39229136994ac9971fe0f7)
#         ;
#
#
#
#
#             var marker_90fbd27ec59982a5fb93c3f7cbe2dd73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c9a7fc25f133f130507b58f660ac8da6);
#
#
#         var popup_325883a6ec6a6835269a835b4740a90a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1df3bda7ccf29f6e81f36b60ed6e9eed = $(`&lt;div id=&quot;html_1df3bda7ccf29f6e81f36b60ed6e9eed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_325883a6ec6a6835269a835b4740a90a.setContent(html_1df3bda7ccf29f6e81f36b60ed6e9eed);
#
#
#
#         marker_90fbd27ec59982a5fb93c3f7cbe2dd73.bindPopup(popup_325883a6ec6a6835269a835b4740a90a)
#         ;
#
#
#
#
#             var marker_dd411c3079e23749e411b5ab1ca55174 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c9a7fc25f133f130507b58f660ac8da6);
#
#
#         var popup_286dcf015eb38b75298ffb62d74caa2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b764f642ce8ef660e2043d2f693b4c35 = $(`&lt;div id=&quot;html_b764f642ce8ef660e2043d2f693b4c35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_286dcf015eb38b75298ffb62d74caa2b.setContent(html_b764f642ce8ef660e2043d2f693b4c35);
#
#
#
#         marker_dd411c3079e23749e411b5ab1ca55174.bindPopup(popup_286dcf015eb38b75298ffb62d74caa2b)
#         ;
#
#
#
#
#             var marker_0162d79ba6cf5d0dbf6b4a5a409071a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c9a7fc25f133f130507b58f660ac8da6);
#
#
#         var popup_b4769fb4f29d7dc8ea23d7bd2f1994a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e284eb2a0f5fc188e21d656deef4e8f6 = $(`&lt;div id=&quot;html_e284eb2a0f5fc188e21d656deef4e8f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b4769fb4f29d7dc8ea23d7bd2f1994a6.setContent(html_e284eb2a0f5fc188e21d656deef4e8f6);
#
#
#
#         marker_0162d79ba6cf5d0dbf6b4a5a409071a4.bindPopup(popup_b4769fb4f29d7dc8ea23d7bd2f1994a6)
#         ;
#
#
#
#
#             var marker_8a3123813ed0f335e67b8021eb4cc673 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c9a7fc25f133f130507b58f660ac8da6);
#
#
#         var popup_0e02478765addf1690d650be129a8870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a4e44c1714744779917178ca9dd89d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a4e44c1714744779917178ca9dd89d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a4e44c1714744779917178ca9dd89d7 = L.map(
#                 &quot;map_5a4e44c1714744779917178ca9dd89d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b63287017846b65f1c4da20bc03b11e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b63287017846b65f1c4da20bc03b11e.addTo(map_5a4e44c1714744779917178ca9dd89d7);
#
#
#             var feature_group_8f0a9b691c041b1975210451fc9cffd8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8f0a9b691c041b1975210451fc9cffd8.addTo(map_5a4e44c1714744779917178ca9dd89d7);
#
#
#             var feature_group_sub_group_0f35885cd891a41cf68b4d505c07a1e3 = L.featureGroup.subGroup(
#                 feature_group_8f0a9b691c041b1975210451fc9cffd8
#             );
#
#
#             var marker_2975781ae10246f0bbc868edac04fa17 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f35885cd891a41cf68b4d505c07a1e3);
#
#
#         var popup_ef1d7539bf39f9f533a29a6cb6ae3a28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ddd5538b4b319a28bf59474993465e8 = $(`&lt;div id=&quot;html_7ddd5538b4b319a28bf59474993465e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ef1d7539bf39f9f533a29a6cb6ae3a28.setContent(html_7ddd5538b4b319a28bf59474993465e8);
#
#
#
#         marker_2975781ae10246f0bbc868edac04fa17.bindPopup(popup_ef1d7539bf39f9f533a29a6cb6ae3a28)
#         ;
#
#
#
#
#             var marker_58538695ee4a1aed0995173e6ff8abe8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f35885cd891a41cf68b4d505c07a1e3);
#
#
#         var popup_23566244ba18b102eceeb2561499da4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f27373c8a21dcac72bfa0cff625bf788 = $(`&lt;div id=&quot;html_f27373c8a21dcac72bfa0cff625bf788&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_23566244ba18b102eceeb2561499da4e.setContent(html_f27373c8a21dcac72bfa0cff625bf788);
#
#
#
#         marker_58538695ee4a1aed0995173e6ff8abe8.bindPopup(popup_23566244ba18b102eceeb2561499da4e)
#         ;
#
#
#
#
#             var marker_75210bbb461f5258f8df121ca72b0e52 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f35885cd891a41cf68b4d505c07a1e3);
#
#
#         var popup_c2cd0be2960fdb19c63af08206dceadd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7358b55abaf07376a94fa7ef924c98b8 = $(`&lt;div id=&quot;html_7358b55abaf07376a94fa7ef924c98b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c2cd0be2960fdb19c63af08206dceadd.setContent(html_7358b55abaf07376a94fa7ef924c98b8);
#
#
#
#         marker_75210bbb461f5258f8df121ca72b0e52.bindPopup(popup_c2cd0be2960fdb19c63af08206dceadd)
#         ;
#
#
#
#
#             var marker_3b0cfb8341e65eee0cfb16e161b868fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f35885cd891a41cf68b4d505c07a1e3);
#
#
#         var popup_4eb04c9f66793ce9516b44ef40158e3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f82a6a0b9989bf1d77a33a10fb9c07c = $(`&lt;div id=&quot;html_8f82a6a0b9989bf1d77a33a10fb9c07c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4eb04c9f66793ce9516b44ef40158e3d.setContent(html_8f82a6a0b9989bf1d77a33a10fb9c07c);
#
#
#
#         marker_
