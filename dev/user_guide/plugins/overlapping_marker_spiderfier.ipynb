# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca6662b8e9264c6b43a52be4938ba368 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca6662b8e9264c6b43a52be4938ba368&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca6662b8e9264c6b43a52be4938ba368 = L.map(
#                 &quot;map_ca6662b8e9264c6b43a52be4938ba368&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_579c89d132fb7e97e86b9104b5b17b34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_579c89d132fb7e97e86b9104b5b17b34.addTo(map_ca6662b8e9264c6b43a52be4938ba368);
#
#
#             var marker_c61b789b2e069ed1253e6a2f7e342f15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ca6662b8e9264c6b43a52be4938ba368);
#
#
#         var popup_0ed9ccdcd1cfb70d6450a81c0d370623 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d43ea28a81fabd5d5dd3789afc6a7a7 = $(`&lt;div id=&quot;html_0d43ea28a81fabd5d5dd3789afc6a7a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0ed9ccdcd1cfb70d6450a81c0d370623.setContent(html_0d43ea28a81fabd5d5dd3789afc6a7a7);
#
#
#
#         marker_c61b789b2e069ed1253e6a2f7e342f15.bindPopup(popup_0ed9ccdcd1cfb70d6450a81c0d370623)
#         ;
#
#
#
#
#             var marker_ebc9ce9edb22cbcd3b836e18176ff433 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ca6662b8e9264c6b43a52be4938ba368);
#
#
#         var popup_6d67640d840f6b15fc67f753f156d087 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7152cd092ab8196ad372ce86189216b = $(`&lt;div id=&quot;html_f7152cd092ab8196ad372ce86189216b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6d67640d840f6b15fc67f753f156d087.setContent(html_f7152cd092ab8196ad372ce86189216b);
#
#
#
#         marker_ebc9ce9edb22cbcd3b836e18176ff433.bindPopup(popup_6d67640d840f6b15fc67f753f156d087)
#         ;
#
#
#
#
#             var marker_38caa608a5f5fc74e9967fa03d830c0b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ca6662b8e9264c6b43a52be4938ba368);
#
#
#         var popup_4165df6f7159580356bcab6bc59c8c84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11179b9c2d1595a8101dbc761be0dc6d = $(`&lt;div id=&quot;html_11179b9c2d1595a8101dbc761be0dc6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4165df6f7159580356bcab6bc59c8c84.setContent(html_11179b9c2d1595a8101dbc761be0dc6d);
#
#
#
#         marker_38caa608a5f5fc74e9967fa03d830c0b.bindPopup(popup_4165df6f7159580356bcab6bc59c8c84)
#         ;
#
#
#
#
#             var marker_a8ae2cce0364890aa3f7013a4c4279cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ca6662b8e9264c6b43a52be4938ba368);
#
#
#         var popup_23e347ff783a0552ad6a39cc5d3bc393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5d7293578bcee8d83f583e0c2d02101 = $(`&lt;div id=&quot;html_a5d7293578bcee8d83f583e0c2d02101&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_23e347ff783a0552ad6a39cc5d3bc393.setContent(html_a5d7293578bcee8d83f583e0c2d02101);
#
#
#
#         marker_a8ae2cce0364890aa3f7013a4c4279cf.bindPopup(popup_23e347ff783a0552ad6a39cc5d3bc393)
#         ;
#
#
#
#
#             var marker_76b09ae53d34ddcc3b9ce78d3b52f42a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ca6662b8e9264c6b43a52be4938ba368);
#
#
#         var popup_0e72ff6398509198c63dd03a47260c4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f90df24cc3aea60e6eb0a65fcdd60b6 = $(`&lt;div id=&quot;html_3f90df24cc3aea60e6eb0a65fcdd60b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0e72ff6398509198c63dd03a47260c4d.setContent(html_3f90df24cc3aea60e6eb0a65fcdd60b6);
#
#
#
#         marker_76b09ae53d34ddcc3b9ce78d3b52f42a.bindPopup(popup_0e72ff6398509198c63dd03a47260c4d)
#         ;
#
#
#
#
#             var marker_1f39b83fce

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d79031d45fdc73ba027eb5cdd6269468 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d79031d45fdc73ba027eb5cdd6269468&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d79031d45fdc73ba027eb5cdd6269468 = L.map(
#                 &quot;map_d79031d45fdc73ba027eb5cdd6269468&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5bff96894ee8b2519f398006a1fdb52 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5bff96894ee8b2519f398006a1fdb52.addTo(map_d79031d45fdc73ba027eb5cdd6269468);
#
#
#             var feature_group_824a86b88693a7692faff8b4136b2c27 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5e4913d9ca8319011c4f4cc88e83ac1b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_824a86b88693a7692faff8b4136b2c27);
#
#
#         var popup_6825046f5d9f90ea5ba71f305336d7d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15c62af658837608aef26cbd7645ce62 = $(`&lt;div id=&quot;html_15c62af658837608aef26cbd7645ce62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6825046f5d9f90ea5ba71f305336d7d3.setContent(html_15c62af658837608aef26cbd7645ce62);
#
#
#
#         marker_5e4913d9ca8319011c4f4cc88e83ac1b.bindPopup(popup_6825046f5d9f90ea5ba71f305336d7d3)
#         ;
#
#
#
#
#             var marker_2d0052f8f50419cea97ba185e077ccab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_824a86b88693a7692faff8b4136b2c27);
#
#
#         var popup_8c8960cfe3be018fea30f1dbcd108f7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_370e66b02e08090f363f5ace384f09d1 = $(`&lt;div id=&quot;html_370e66b02e08090f363f5ace384f09d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8c8960cfe3be018fea30f1dbcd108f7b.setContent(html_370e66b02e08090f363f5ace384f09d1);
#
#
#
#         marker_2d0052f8f50419cea97ba185e077ccab.bindPopup(popup_8c8960cfe3be018fea30f1dbcd108f7b)
#         ;
#
#
#
#
#             var marker_3470bf99b86d7a1d8f1ef3eaf89162fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_824a86b88693a7692faff8b4136b2c27);
#
#
#         var popup_8d389242d3da3a01e309bd2a0f5b6f5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d404a4cb9d7b1e3b18d8ee76953bbae = $(`&lt;div id=&quot;html_3d404a4cb9d7b1e3b18d8ee76953bbae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8d389242d3da3a01e309bd2a0f5b6f5d.setContent(html_3d404a4cb9d7b1e3b18d8ee76953bbae);
#
#
#
#         marker_3470bf99b86d7a1d8f1ef3eaf89162fd.bindPopup(popup_8d389242d3da3a01e309bd2a0f5b6f5d)
#         ;
#
#
#
#
#             var marker_dcfcc6c5a8a6792e13cca17b86a9f159 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_824a86b88693a7692faff8b4136b2c27);
#
#
#         var popup_970a7b97f6acfcb7801c43d0a26be16f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b00621c309a38a3c7158be78f83e0de3 = $(`&lt;div id=&quot;html_b00621c309a38a3c7158be78f83e0de3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_970a7b97f6acfcb7801c43d0a26be16f.setContent(html_b00621c309a38a3c7158be78f83e0de3);
#
#
#
#         marker_dcfcc6c5a8a6792e13cca17b86a9f159.bindPopup(popup_970a7b97f6acfcb7801c43d0a26be16f)
#         ;
#
#
#
#
#             var marker_ea50d9ea6a75628ca24a24eb833719d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_824a86b88693a7692faff8b4136b2c27);
#
#
#         var popup_cfd592aad6bed396027679e63939c275 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c1788a3915e6fb546385d0117eae38d = $(`&lt;div id=&quot;html_6c1788a3915e6fb546385d0117eae38d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_cfd592aad6bed39602

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdfb90fe55262d840383ea1efa0f5051 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdfb90fe55262d840383ea1efa0f5051&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdfb90fe55262d840383ea1efa0f5051 = L.map(
#                 &quot;map_fdfb90fe55262d840383ea1efa0f5051&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_720805c9c36742385c8076cd4eccf5e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_720805c9c36742385c8076cd4eccf5e8.addTo(map_fdfb90fe55262d840383ea1efa0f5051);
#
#
#             var feature_group_27b40ea405078effad30775a4e48c7dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_27b40ea405078effad30775a4e48c7dc.addTo(map_fdfb90fe55262d840383ea1efa0f5051);
#
#
#             var feature_group_sub_group_f05192fc3b36aed61244dd50e061b942 = L.featureGroup.subGroup(
#                 feature_group_27b40ea405078effad30775a4e48c7dc
#             );
#
#
#             var marker_5de5870422f15c7712ac372df1f413e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f05192fc3b36aed61244dd50e061b942);
#
#
#         var popup_b8125279177889e459222a6d9945287d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab0c260965880f9f7a5074446e784ca2 = $(`&lt;div id=&quot;html_ab0c260965880f9f7a5074446e784ca2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b8125279177889e459222a6d9945287d.setContent(html_ab0c260965880f9f7a5074446e784ca2);
#
#
#
#         marker_5de5870422f15c7712ac372df1f413e1.bindPopup(popup_b8125279177889e459222a6d9945287d)
#         ;
#
#
#
#
#             var marker_e0251db901f09928ab8ac0851daf8156 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f05192fc3b36aed61244dd50e061b942);
#
#
#         var popup_979db563d3d2c90137b12ae1285a4c9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a09dd42f33452838b6c233bf745cf350 = $(`&lt;div id=&quot;html_a09dd42f33452838b6c233bf745cf350&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_979db563d3d2c90137b12ae1285a4c9a.setContent(html_a09dd42f33452838b6c233bf745cf350);
#
#
#
#         marker_e0251db901f09928ab8ac0851daf8156.bindPopup(popup_979db563d3d2c90137b12ae1285a4c9a)
#         ;
#
#
#
#
#             var marker_f417b0bf09c02faaad1b7f12faf2dfaf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f05192fc3b36aed61244dd50e061b942);
#
#
#         var popup_cbe21d7c033764edb8a63c630c328f0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4c552c9b8ea83ed1c76098966eb5e7d = $(`&lt;div id=&quot;html_e4c552c9b8ea83ed1c76098966eb5e7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cbe21d7c033764edb8a63c630c328f0b.setContent(html_e4c552c9b8ea83ed1c76098966eb5e7d);
#
#
#
#         marker_f417b0bf09c02faaad1b7f12faf2dfaf.bindPopup(popup_cbe21d7c033764edb8a63c630c328f0b)
#         ;
#
#
#
#
#             var marker_b0e55322cf194880b3869f6bf8610f77 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f05192fc3b36aed61244dd50e061b942);
#
#
#         var popup_442a841b3a9f58e867ca2d3c19b943a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7771dae70158646921c359a648a829ea = $(`&lt;div id=&quot;html_7771dae70158646921c359a648a829ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_442a841b3a9f58e867ca2d3c19b943a2.setContent(html_7771dae70158646921c359a648a829ea);
#
#
#
#         marker_b0e55322cf194880b3869f6bf8610f77.bindPopup(popup_442a841b3a9f58e867ca2d3c19b943a2)
#         ;
#
#
#
#
#             var marker_ec40ce9b16347481cdf492a7ece3c60a = L.marker(
#                 [45.050399999999996, 3.0504],
