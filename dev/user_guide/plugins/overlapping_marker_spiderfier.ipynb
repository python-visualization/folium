# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7179cfea418bb66c7499bd7fce132a3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7179cfea418bb66c7499bd7fce132a3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7179cfea418bb66c7499bd7fce132a3e = L.map(
#                 &quot;map_7179cfea418bb66c7499bd7fce132a3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3198700a8ca65fb8469ff7e633412141 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3198700a8ca65fb8469ff7e633412141.addTo(map_7179cfea418bb66c7499bd7fce132a3e);
#
#
#             var marker_346ae2e4b851acbc6657f531ed0d41b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7179cfea418bb66c7499bd7fce132a3e);
#
#
#         var popup_8f4ae254d3236f89c2b807029813d9ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfd53ecf937c28991004252b07bf1f67 = $(`&lt;div id=&quot;html_bfd53ecf937c28991004252b07bf1f67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8f4ae254d3236f89c2b807029813d9ac.setContent(html_bfd53ecf937c28991004252b07bf1f67);
#
#
#
#         marker_346ae2e4b851acbc6657f531ed0d41b9.bindPopup(popup_8f4ae254d3236f89c2b807029813d9ac)
#         ;
#
#
#
#
#             var marker_d2d4aa68654835c94a82d63581b00843 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7179cfea418bb66c7499bd7fce132a3e);
#
#
#         var popup_59db3494443dc7f73d44245b3330b7b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e62b37cde950bdf1e04f6f2d17625ee = $(`&lt;div id=&quot;html_9e62b37cde950bdf1e04f6f2d17625ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_59db3494443dc7f73d44245b3330b7b3.setContent(html_9e62b37cde950bdf1e04f6f2d17625ee);
#
#
#
#         marker_d2d4aa68654835c94a82d63581b00843.bindPopup(popup_59db3494443dc7f73d44245b3330b7b3)
#         ;
#
#
#
#
#             var marker_c29372f465f9cb74f1095ee978cbe863 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7179cfea418bb66c7499bd7fce132a3e);
#
#
#         var popup_dfea7674e86e58b938ebce20154e7bfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61373677a71f776734138f5bd56d0ff9 = $(`&lt;div id=&quot;html_61373677a71f776734138f5bd56d0ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dfea7674e86e58b938ebce20154e7bfb.setContent(html_61373677a71f776734138f5bd56d0ff9);
#
#
#
#         marker_c29372f465f9cb74f1095ee978cbe863.bindPopup(popup_dfea7674e86e58b938ebce20154e7bfb)
#         ;
#
#
#
#
#             var marker_1f6da174a88a75cfde76a74ee95ca77e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7179cfea418bb66c7499bd7fce132a3e);
#
#
#         var popup_ebfb32e3f6c38ed03bed1804c593339f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbc0f9989b6322e6d24c1edeb8d9c854 = $(`&lt;div id=&quot;html_fbc0f9989b6322e6d24c1edeb8d9c854&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ebfb32e3f6c38ed03bed1804c593339f.setContent(html_fbc0f9989b6322e6d24c1edeb8d9c854);
#
#
#
#         marker_1f6da174a88a75cfde76a74ee95ca77e.bindPopup(popup_ebfb32e3f6c38ed03bed1804c593339f)
#         ;
#
#
#
#
#             var marker_adc23e6a14992fbfe837a5297856a874 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7179cfea418bb66c7499bd7fce132a3e);
#
#
#         var popup_48be15d6265c6f33cc839121e73c2fa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1b52e0f04c876ed650318fe07372350 = $(`&lt;div id=&quot;html_d1b52e0f04c876ed650318fe07372350&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_48be15d6265c6f33cc839121e73c2fa9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b41a7c221bc5cd734ebd4e76c969aac9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b41a7c221bc5cd734ebd4e76c969aac9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b41a7c221bc5cd734ebd4e76c969aac9 = L.map(
#                 &quot;map_b41a7c221bc5cd734ebd4e76c969aac9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a05c519a730393a314467ce7007046ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a05c519a730393a314467ce7007046ee.addTo(map_b41a7c221bc5cd734ebd4e76c969aac9);
#
#
#             var feature_group_9128c02d0841a4d1a8e13a6ac8ce61d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b3048f48fd0fa859cc1f2855f0ca0360 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9128c02d0841a4d1a8e13a6ac8ce61d6);
#
#
#         var popup_7d92f23643c802fe9d70130c84da7908 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da7c0bc42dcbb812a44731e02e1f7f66 = $(`&lt;div id=&quot;html_da7c0bc42dcbb812a44731e02e1f7f66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7d92f23643c802fe9d70130c84da7908.setContent(html_da7c0bc42dcbb812a44731e02e1f7f66);
#
#
#
#         marker_b3048f48fd0fa859cc1f2855f0ca0360.bindPopup(popup_7d92f23643c802fe9d70130c84da7908)
#         ;
#
#
#
#
#             var marker_b35e0eb0d851ce6bb2d2cdf86041f4db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9128c02d0841a4d1a8e13a6ac8ce61d6);
#
#
#         var popup_bb7a35a7f13608b1b339b42b8c40b056 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ab11d9380a2921455291b8b663482aa = $(`&lt;div id=&quot;html_1ab11d9380a2921455291b8b663482aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bb7a35a7f13608b1b339b42b8c40b056.setContent(html_1ab11d9380a2921455291b8b663482aa);
#
#
#
#         marker_b35e0eb0d851ce6bb2d2cdf86041f4db.bindPopup(popup_bb7a35a7f13608b1b339b42b8c40b056)
#         ;
#
#
#
#
#             var marker_f626c600952d5bba98dc39940e646d05 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9128c02d0841a4d1a8e13a6ac8ce61d6);
#
#
#         var popup_a0c4d2e83a30f5ceb6eb49add1f91e24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04b6995c66b4e86ebb8409e3351f6610 = $(`&lt;div id=&quot;html_04b6995c66b4e86ebb8409e3351f6610&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a0c4d2e83a30f5ceb6eb49add1f91e24.setContent(html_04b6995c66b4e86ebb8409e3351f6610);
#
#
#
#         marker_f626c600952d5bba98dc39940e646d05.bindPopup(popup_a0c4d2e83a30f5ceb6eb49add1f91e24)
#         ;
#
#
#
#
#             var marker_516b0fa66143d449d0f6b3c647f50f96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9128c02d0841a4d1a8e13a6ac8ce61d6);
#
#
#         var popup_dd006f8917730942b97a113d260633f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9379f189b2b72e3b3dcd1e632a0de6a = $(`&lt;div id=&quot;html_b9379f189b2b72e3b3dcd1e632a0de6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dd006f8917730942b97a113d260633f9.setContent(html_b9379f189b2b72e3b3dcd1e632a0de6a);
#
#
#
#         marker_516b0fa66143d449d0f6b3c647f50f96.bindPopup(popup_dd006f8917730942b97a113d260633f9)
#         ;
#
#
#
#
#             var marker_0eeac1dbb35ff051bd91bb9733c2056c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9128c02d0841a4d1a8e13a6ac8ce61d6);
#
#
#         var popup_d565cb50ae6f2c2b6238e2d8031e3ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42663cf95ff0ac1c553295ef04dbcf0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42663cf95ff0ac1c553295ef04dbcf0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42663cf95ff0ac1c553295ef04dbcf0c = L.map(
#                 &quot;map_42663cf95ff0ac1c553295ef04dbcf0c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2061b105822692b10de199bc9aa823be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2061b105822692b10de199bc9aa823be.addTo(map_42663cf95ff0ac1c553295ef04dbcf0c);
#
#
#             var feature_group_92812c29fab187a56288177056fc8c4b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_92812c29fab187a56288177056fc8c4b.addTo(map_42663cf95ff0ac1c553295ef04dbcf0c);
#
#
#             var feature_group_sub_group_8031e6d1e5f3b597f810fac88eb5d497 = L.featureGroup.subGroup(
#                 feature_group_92812c29fab187a56288177056fc8c4b
#             );
#
#
#             var marker_48cafa1d8b3ac9854c645242171193da = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8031e6d1e5f3b597f810fac88eb5d497);
#
#
#         var popup_119c33a9f515c47a1c2e879726322012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f1df59fc2b7410972f7b623cd22dbcc = $(`&lt;div id=&quot;html_9f1df59fc2b7410972f7b623cd22dbcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_119c33a9f515c47a1c2e879726322012.setContent(html_9f1df59fc2b7410972f7b623cd22dbcc);
#
#
#
#         marker_48cafa1d8b3ac9854c645242171193da.bindPopup(popup_119c33a9f515c47a1c2e879726322012)
#         ;
#
#
#
#
#             var marker_55426db7e7836f89451252678a18492e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8031e6d1e5f3b597f810fac88eb5d497);
#
#
#         var popup_ea831d6d3d9e8b17661786c824da5aec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc42d97c0e3b1b6f787a55ea00d994b9 = $(`&lt;div id=&quot;html_bc42d97c0e3b1b6f787a55ea00d994b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ea831d6d3d9e8b17661786c824da5aec.setContent(html_bc42d97c0e3b1b6f787a55ea00d994b9);
#
#
#
#         marker_55426db7e7836f89451252678a18492e.bindPopup(popup_ea831d6d3d9e8b17661786c824da5aec)
#         ;
#
#
#
#
#             var marker_48f90e8f84966fac293b90397127a002 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8031e6d1e5f3b597f810fac88eb5d497);
#
#
#         var popup_71d71b22608b0199914f8de609fc8e36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0960d621d3999c1f26d9de48cabf343e = $(`&lt;div id=&quot;html_0960d621d3999c1f26d9de48cabf343e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_71d71b22608b0199914f8de609fc8e36.setContent(html_0960d621d3999c1f26d9de48cabf343e);
#
#
#
#         marker_48f90e8f84966fac293b90397127a002.bindPopup(popup_71d71b22608b0199914f8de609fc8e36)
#         ;
#
#
#
#
#             var marker_29003b20b1cc79e04f1ebb3c96845986 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8031e6d1e5f3b597f810fac88eb5d497);
#
#
#         var popup_67778cbaa217afbcb98b11e6b33ac5b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c5adf52263cdfd37a65f928dc4308ce = $(`&lt;div id=&quot;html_1c5adf52263cdfd37a65f928dc4308ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_67778cbaa217afbcb98b11e6b33ac5b5.setContent(html_1c5adf52263cdfd37a65f928dc4308ce);
#
#
#
#         marker_
