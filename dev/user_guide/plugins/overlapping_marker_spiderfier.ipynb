# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ed4b64d70f2d13949ef550a0155087a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ed4b64d70f2d13949ef550a0155087a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ed4b64d70f2d13949ef550a0155087a = L.map(
#                 &quot;map_7ed4b64d70f2d13949ef550a0155087a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba4bcccb194b6bb443d6feddb81dbdb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba4bcccb194b6bb443d6feddb81dbdb2.addTo(map_7ed4b64d70f2d13949ef550a0155087a);
#
#
#             var marker_7344c71e44340c6bd654615828237195 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7ed4b64d70f2d13949ef550a0155087a);
#
#
#         var popup_29bfd58186f203c65aada6072207f66b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7f1af457ad7a71aa8c332bcd23f3966 = $(`&lt;div id=&quot;html_a7f1af457ad7a71aa8c332bcd23f3966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_29bfd58186f203c65aada6072207f66b.setContent(html_a7f1af457ad7a71aa8c332bcd23f3966);
#
#
#
#         marker_7344c71e44340c6bd654615828237195.bindPopup(popup_29bfd58186f203c65aada6072207f66b)
#         ;
#
#
#
#
#             var marker_71f14fe14a5bb0eae32a096ffeb4530b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7ed4b64d70f2d13949ef550a0155087a);
#
#
#         var popup_73af9ddf9d25cec80dc1e90b378eaef7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d634ccaf1ea463df237eba417e211c11 = $(`&lt;div id=&quot;html_d634ccaf1ea463df237eba417e211c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_73af9ddf9d25cec80dc1e90b378eaef7.setContent(html_d634ccaf1ea463df237eba417e211c11);
#
#
#
#         marker_71f14fe14a5bb0eae32a096ffeb4530b.bindPopup(popup_73af9ddf9d25cec80dc1e90b378eaef7)
#         ;
#
#
#
#
#             var marker_66e314b7e7d916768005f1a97014003d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7ed4b64d70f2d13949ef550a0155087a);
#
#
#         var popup_ee624e092e63c6b7c785bc7a34e8fb20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_103149103360fae96bc855db2578552f = $(`&lt;div id=&quot;html_103149103360fae96bc855db2578552f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee624e092e63c6b7c785bc7a34e8fb20.setContent(html_103149103360fae96bc855db2578552f);
#
#
#
#         marker_66e314b7e7d916768005f1a97014003d.bindPopup(popup_ee624e092e63c6b7c785bc7a34e8fb20)
#         ;
#
#
#
#
#             var marker_cda8664a2152806f93bcb9cb7fc1d7b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7ed4b64d70f2d13949ef550a0155087a);
#
#
#         var popup_2231a5fb998b2cfe737c5dec31ac1669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_675994b3473febcf8a245d09e6d3dc68 = $(`&lt;div id=&quot;html_675994b3473febcf8a245d09e6d3dc68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2231a5fb998b2cfe737c5dec31ac1669.setContent(html_675994b3473febcf8a245d09e6d3dc68);
#
#
#
#         marker_cda8664a2152806f93bcb9cb7fc1d7b4.bindPopup(popup_2231a5fb998b2cfe737c5dec31ac1669)
#         ;
#
#
#
#
#             var marker_446995e1522939063810aced3c97773e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7ed4b64d70f2d13949ef550a0155087a);
#
#
#         var popup_a89bc4c38f8caf9614509e29ed8c88a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df6f0d9c7f69b65351bfff1ac77b6b51 = $(`&lt;div id=&quot;html_df6f0d9c7f69b65351bfff1ac77b6b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a89bc4c38f8caf9614509e29ed8c88a0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0268af3d98b4f45aee66572bc7f18c27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0268af3d98b4f45aee66572bc7f18c27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0268af3d98b4f45aee66572bc7f18c27 = L.map(
#                 &quot;map_0268af3d98b4f45aee66572bc7f18c27&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e45bfd3a233af0c3d3b84eb63c2cf069 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e45bfd3a233af0c3d3b84eb63c2cf069.addTo(map_0268af3d98b4f45aee66572bc7f18c27);
#
#
#             var feature_group_99713d4cf0694bae910cbb9567e765dd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a0720058ebdef23c68b456036b3216cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_99713d4cf0694bae910cbb9567e765dd);
#
#
#         var popup_51a3a68b56d59fd0f3713ffd3dcd5ed0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_028b99ade5e18de27bcc09e0aab8aadd = $(`&lt;div id=&quot;html_028b99ade5e18de27bcc09e0aab8aadd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_51a3a68b56d59fd0f3713ffd3dcd5ed0.setContent(html_028b99ade5e18de27bcc09e0aab8aadd);
#
#
#
#         marker_a0720058ebdef23c68b456036b3216cc.bindPopup(popup_51a3a68b56d59fd0f3713ffd3dcd5ed0)
#         ;
#
#
#
#
#             var marker_473aeec2b576514ec76c237439135325 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_99713d4cf0694bae910cbb9567e765dd);
#
#
#         var popup_0788695a121d4daba3aa268aaf6969aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7714a2747ee4dd6b795fac139814ccb5 = $(`&lt;div id=&quot;html_7714a2747ee4dd6b795fac139814ccb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0788695a121d4daba3aa268aaf6969aa.setContent(html_7714a2747ee4dd6b795fac139814ccb5);
#
#
#
#         marker_473aeec2b576514ec76c237439135325.bindPopup(popup_0788695a121d4daba3aa268aaf6969aa)
#         ;
#
#
#
#
#             var marker_e5919a7639ad7ca0d2ba9d86f9566beb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_99713d4cf0694bae910cbb9567e765dd);
#
#
#         var popup_7c7a2c38fbfaf65b299306bc2fb151c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a76db78a1e70ec570fca43fd51e70a9 = $(`&lt;div id=&quot;html_3a76db78a1e70ec570fca43fd51e70a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7c7a2c38fbfaf65b299306bc2fb151c2.setContent(html_3a76db78a1e70ec570fca43fd51e70a9);
#
#
#
#         marker_e5919a7639ad7ca0d2ba9d86f9566beb.bindPopup(popup_7c7a2c38fbfaf65b299306bc2fb151c2)
#         ;
#
#
#
#
#             var marker_e439d351b28a46b7687966c8cdfa6b6a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_99713d4cf0694bae910cbb9567e765dd);
#
#
#         var popup_dd16debc97489149799b315edd96b69c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7aca3c8ae8ea7a67f249ea6832d38e93 = $(`&lt;div id=&quot;html_7aca3c8ae8ea7a67f249ea6832d38e93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dd16debc97489149799b315edd96b69c.setContent(html_7aca3c8ae8ea7a67f249ea6832d38e93);
#
#
#
#         marker_e439d351b28a46b7687966c8cdfa6b6a.bindPopup(popup_dd16debc97489149799b315edd96b69c)
#         ;
#
#
#
#
#             var marker_a9d405965c78eac3b896a19157a07924 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_99713d4cf0694bae910cbb9567e765dd);
#
#
#         var popup_cb7182b264d74000b3690d3020a247a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d1197d48b94d790ef2222f7e1dff8de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d1197d48b94d790ef2222f7e1dff8de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d1197d48b94d790ef2222f7e1dff8de = L.map(
#                 &quot;map_1d1197d48b94d790ef2222f7e1dff8de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1af2ded6bb4908c046d780099120c1f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1af2ded6bb4908c046d780099120c1f9.addTo(map_1d1197d48b94d790ef2222f7e1dff8de);
#
#
#             var feature_group_3e2e0aa1b008721e9d0c2aa85b7db013 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3e2e0aa1b008721e9d0c2aa85b7db013.addTo(map_1d1197d48b94d790ef2222f7e1dff8de);
#
#
#             var feature_group_sub_group_ff11304bcebd20bbf1ce47eb18190470 = L.featureGroup.subGroup(
#                 feature_group_3e2e0aa1b008721e9d0c2aa85b7db013
#             );
#
#
#             var marker_287098ef9c09421bc8ce427aebc3fb56 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11304bcebd20bbf1ce47eb18190470);
#
#
#         var popup_8f8a1c986c35a71c7252ca6cb0af809d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd731ac771f4e60ab23cdf070c57c690 = $(`&lt;div id=&quot;html_cd731ac771f4e60ab23cdf070c57c690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8f8a1c986c35a71c7252ca6cb0af809d.setContent(html_cd731ac771f4e60ab23cdf070c57c690);
#
#
#
#         marker_287098ef9c09421bc8ce427aebc3fb56.bindPopup(popup_8f8a1c986c35a71c7252ca6cb0af809d)
#         ;
#
#
#
#
#             var marker_78cb5d3e67f252650e97452f7475718a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11304bcebd20bbf1ce47eb18190470);
#
#
#         var popup_61afb14a92fa06e8687b2b56e57227bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c88abfc5f8a0441e0288144225851bbd = $(`&lt;div id=&quot;html_c88abfc5f8a0441e0288144225851bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_61afb14a92fa06e8687b2b56e57227bd.setContent(html_c88abfc5f8a0441e0288144225851bbd);
#
#
#
#         marker_78cb5d3e67f252650e97452f7475718a.bindPopup(popup_61afb14a92fa06e8687b2b56e57227bd)
#         ;
#
#
#
#
#             var marker_1eeaf5bc533092bc635cb17b80ac4b7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11304bcebd20bbf1ce47eb18190470);
#
#
#         var popup_7670a71e321537ea159fc02d4795e686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0457354fa0e27e045b4d7b92c34de60 = $(`&lt;div id=&quot;html_d0457354fa0e27e045b4d7b92c34de60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7670a71e321537ea159fc02d4795e686.setContent(html_d0457354fa0e27e045b4d7b92c34de60);
#
#
#
#         marker_1eeaf5bc533092bc635cb17b80ac4b7f.bindPopup(popup_7670a71e321537ea159fc02d4795e686)
#         ;
#
#
#
#
#             var marker_fa6910f1781369a428f0ee8cfd94a2ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11304bcebd20bbf1ce47eb18190470);
#
#
#         var popup_4f8433da18b7fd1ce8dfa7ccb99305ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_386d012b67f202dc330e182f2ef730da = $(`&lt;div id=&quot;html_386d012b67f202dc330e182f2ef730da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4f8433da18b7fd1ce8dfa7ccb99305ec.setContent(html_386d012b67f202dc330e182f2ef730da);
#
#
#
#         marker_
