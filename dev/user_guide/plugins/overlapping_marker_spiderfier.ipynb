# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05f3d8261b18f396185cc747007fc83f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05f3d8261b18f396185cc747007fc83f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05f3d8261b18f396185cc747007fc83f = L.map(
#                 &quot;map_05f3d8261b18f396185cc747007fc83f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5ce859ff00b176b6f4dd5a11d2e5d1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5ce859ff00b176b6f4dd5a11d2e5d1a.addTo(map_05f3d8261b18f396185cc747007fc83f);
#
#
#             var marker_11cf39b2486783288d7d31aa7c06a0f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_05f3d8261b18f396185cc747007fc83f);
#
#
#         var popup_b4777a687e5a41f6d4e5d5f0950d7b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80757c14837a890817ad58300027249d = $(`&lt;div id=&quot;html_80757c14837a890817ad58300027249d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b4777a687e5a41f6d4e5d5f0950d7b57.setContent(html_80757c14837a890817ad58300027249d);
#
#
#
#         marker_11cf39b2486783288d7d31aa7c06a0f2.bindPopup(popup_b4777a687e5a41f6d4e5d5f0950d7b57)
#         ;
#
#
#
#
#             var marker_40aa889630e85c7d96b48f002b03919a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_05f3d8261b18f396185cc747007fc83f);
#
#
#         var popup_b76bd914fcd305752fbdbebe4d08b771 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e75365fddc197585d163e8c16edf8f23 = $(`&lt;div id=&quot;html_e75365fddc197585d163e8c16edf8f23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b76bd914fcd305752fbdbebe4d08b771.setContent(html_e75365fddc197585d163e8c16edf8f23);
#
#
#
#         marker_40aa889630e85c7d96b48f002b03919a.bindPopup(popup_b76bd914fcd305752fbdbebe4d08b771)
#         ;
#
#
#
#
#             var marker_b71a0fe8af818d481688058dbcffecdf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_05f3d8261b18f396185cc747007fc83f);
#
#
#         var popup_c705d3a1ab3d3d4ed86a279b4cc3c82b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_601b6a7952eea6a383486786a7a47f6a = $(`&lt;div id=&quot;html_601b6a7952eea6a383486786a7a47f6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c705d3a1ab3d3d4ed86a279b4cc3c82b.setContent(html_601b6a7952eea6a383486786a7a47f6a);
#
#
#
#         marker_b71a0fe8af818d481688058dbcffecdf.bindPopup(popup_c705d3a1ab3d3d4ed86a279b4cc3c82b)
#         ;
#
#
#
#
#             var marker_a44a87203f20b1e41630a25aebc96778 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_05f3d8261b18f396185cc747007fc83f);
#
#
#         var popup_9465de82d9fb814ab0cde844ed4f17b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c20a2765c60b112f4e417b4fb2f66f2f = $(`&lt;div id=&quot;html_c20a2765c60b112f4e417b4fb2f66f2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9465de82d9fb814ab0cde844ed4f17b2.setContent(html_c20a2765c60b112f4e417b4fb2f66f2f);
#
#
#
#         marker_a44a87203f20b1e41630a25aebc96778.bindPopup(popup_9465de82d9fb814ab0cde844ed4f17b2)
#         ;
#
#
#
#
#             var marker_5316f904f3dc7652af17054d6ae5a0de = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_05f3d8261b18f396185cc747007fc83f);
#
#
#         var popup_4ce81dbb52fa28a30b016ed45533078c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96f5a46112602923b8d551a3d3bbf812 = $(`&lt;div id=&quot;html_96f5a46112602923b8d551a3d3bbf812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4ce81dbb52fa28a30b016ed45533078c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7219c0d12891a35095df593945e9e219 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7219c0d12891a35095df593945e9e219&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7219c0d12891a35095df593945e9e219 = L.map(
#                 &quot;map_7219c0d12891a35095df593945e9e219&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fb4430094748f6b0837ab04574ab829 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fb4430094748f6b0837ab04574ab829.addTo(map_7219c0d12891a35095df593945e9e219);
#
#
#             var feature_group_de86e73f998a68403cbee23656d24e32 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7cba4c78324efbe405487c839481f905 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_de86e73f998a68403cbee23656d24e32);
#
#
#         var popup_3366020a557b5d812ce594394b827fcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d6bad04f92fb24bcd407e5e20fae642 = $(`&lt;div id=&quot;html_2d6bad04f92fb24bcd407e5e20fae642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3366020a557b5d812ce594394b827fcb.setContent(html_2d6bad04f92fb24bcd407e5e20fae642);
#
#
#
#         marker_7cba4c78324efbe405487c839481f905.bindPopup(popup_3366020a557b5d812ce594394b827fcb)
#         ;
#
#
#
#
#             var marker_7a0d91db89f0dd49978a1cf91c875a02 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_de86e73f998a68403cbee23656d24e32);
#
#
#         var popup_59f60c3ab110943747b5786dc51e49c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ee5ced50d8e98a3a142e6b6b92c2ef = $(`&lt;div id=&quot;html_c9ee5ced50d8e98a3a142e6b6b92c2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_59f60c3ab110943747b5786dc51e49c5.setContent(html_c9ee5ced50d8e98a3a142e6b6b92c2ef);
#
#
#
#         marker_7a0d91db89f0dd49978a1cf91c875a02.bindPopup(popup_59f60c3ab110943747b5786dc51e49c5)
#         ;
#
#
#
#
#             var marker_dd5ce8bb51da88d05385c64b969fd3a1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_de86e73f998a68403cbee23656d24e32);
#
#
#         var popup_e5726be09bcade6407b50979ecf7c147 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34dade56ddd742d3e6c5df7888d91e2e = $(`&lt;div id=&quot;html_34dade56ddd742d3e6c5df7888d91e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e5726be09bcade6407b50979ecf7c147.setContent(html_34dade56ddd742d3e6c5df7888d91e2e);
#
#
#
#         marker_dd5ce8bb51da88d05385c64b969fd3a1.bindPopup(popup_e5726be09bcade6407b50979ecf7c147)
#         ;
#
#
#
#
#             var marker_e0a72f8538ae90ef642dcb75f2c91337 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_de86e73f998a68403cbee23656d24e32);
#
#
#         var popup_de2f1536d46b8b09b625cda6994fdadd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc6741a44ca3e724282799061db3ba11 = $(`&lt;div id=&quot;html_cc6741a44ca3e724282799061db3ba11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_de2f1536d46b8b09b625cda6994fdadd.setContent(html_cc6741a44ca3e724282799061db3ba11);
#
#
#
#         marker_e0a72f8538ae90ef642dcb75f2c91337.bindPopup(popup_de2f1536d46b8b09b625cda6994fdadd)
#         ;
#
#
#
#
#             var marker_3357fe3fadd00e0c4b346e42bc8b50c3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_de86e73f998a68403cbee23656d24e32);
#
#
#         var popup_3c42484adaea2c1234c6fcbfe65be1ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f8f72bb74dabb27943873940b329d05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f8f72bb74dabb27943873940b329d05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f8f72bb74dabb27943873940b329d05 = L.map(
#                 &quot;map_1f8f72bb74dabb27943873940b329d05&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e77530f0abd258c03c6109d7fc05fce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e77530f0abd258c03c6109d7fc05fce.addTo(map_1f8f72bb74dabb27943873940b329d05);
#
#
#             var feature_group_f2c2e25bfbcd0abeaa23931dee035cfe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f2c2e25bfbcd0abeaa23931dee035cfe.addTo(map_1f8f72bb74dabb27943873940b329d05);
#
#
#             var feature_group_sub_group_2df3e7f11f9c7373d9b1015f54c789c5 = L.featureGroup.subGroup(
#                 feature_group_f2c2e25bfbcd0abeaa23931dee035cfe
#             );
#
#
#             var marker_06f570efe790c61a9f1cdfb5eca4a6bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2df3e7f11f9c7373d9b1015f54c789c5);
#
#
#         var popup_755ba093cbe673b8991fb5d71be097a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ca079efeb5a744af32da353fdebbb2f = $(`&lt;div id=&quot;html_5ca079efeb5a744af32da353fdebbb2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_755ba093cbe673b8991fb5d71be097a0.setContent(html_5ca079efeb5a744af32da353fdebbb2f);
#
#
#
#         marker_06f570efe790c61a9f1cdfb5eca4a6bb.bindPopup(popup_755ba093cbe673b8991fb5d71be097a0)
#         ;
#
#
#
#
#             var marker_238980e09573c8fc555b9899b896d62c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2df3e7f11f9c7373d9b1015f54c789c5);
#
#
#         var popup_2bf846631f6b738d764344e2a5510e1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8809c51a9b867d1f2f444d57733313b5 = $(`&lt;div id=&quot;html_8809c51a9b867d1f2f444d57733313b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2bf846631f6b738d764344e2a5510e1b.setContent(html_8809c51a9b867d1f2f444d57733313b5);
#
#
#
#         marker_238980e09573c8fc555b9899b896d62c.bindPopup(popup_2bf846631f6b738d764344e2a5510e1b)
#         ;
#
#
#
#
#             var marker_74ed03dff1bb76bb307f47716c04ecae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2df3e7f11f9c7373d9b1015f54c789c5);
#
#
#         var popup_d4384a0208ba26fde31815a8ba3f7ed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a1a6519718e1abc09306a959ffb82e = $(`&lt;div id=&quot;html_90a1a6519718e1abc09306a959ffb82e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d4384a0208ba26fde31815a8ba3f7ed3.setContent(html_90a1a6519718e1abc09306a959ffb82e);
#
#
#
#         marker_74ed03dff1bb76bb307f47716c04ecae.bindPopup(popup_d4384a0208ba26fde31815a8ba3f7ed3)
#         ;
#
#
#
#
#             var marker_15d83954e3bff1ca73964e07212b9fc9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2df3e7f11f9c7373d9b1015f54c789c5);
#
#
#         var popup_8c8417d1fec40681da9ec3a8f47ef34c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0d83d16c0d5d6017b722884b8c5b740 = $(`&lt;div id=&quot;html_e0d83d16c0d5d6017b722884b8c5b740&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8c8417d1fec40681da9ec3a8f47ef34c.setContent(html_e0d83d16c0d5d6017b722884b8c5b740);
#
#
#
#         marker_
