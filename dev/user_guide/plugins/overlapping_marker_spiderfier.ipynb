# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8f3e8de763960520f8a2a33bbb21e6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8f3e8de763960520f8a2a33bbb21e6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8f3e8de763960520f8a2a33bbb21e6d = L.map(
#                 &quot;map_a8f3e8de763960520f8a2a33bbb21e6d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c354137afa86d974c5c8b51c0806e665 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c354137afa86d974c5c8b51c0806e665.addTo(map_a8f3e8de763960520f8a2a33bbb21e6d);
#
#
#             var marker_59f3d70bb3f0503becac87d901c1e992 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a8f3e8de763960520f8a2a33bbb21e6d);
#
#
#         var popup_3fa3f6e325c17e99c557d1445a21e582 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39c626b13a11e6d614150d5233fd183d = $(`&lt;div id=&quot;html_39c626b13a11e6d614150d5233fd183d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3fa3f6e325c17e99c557d1445a21e582.setContent(html_39c626b13a11e6d614150d5233fd183d);
#
#
#
#         marker_59f3d70bb3f0503becac87d901c1e992.bindPopup(popup_3fa3f6e325c17e99c557d1445a21e582)
#         ;
#
#
#
#
#             var marker_09ad21fc1fa36e7a8151618a35e238a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a8f3e8de763960520f8a2a33bbb21e6d);
#
#
#         var popup_e3afba60cd96a333bbdde2f013dcc029 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9030e3c7e2a5fdcccdbabb9d5d261c = $(`&lt;div id=&quot;html_dc9030e3c7e2a5fdcccdbabb9d5d261c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e3afba60cd96a333bbdde2f013dcc029.setContent(html_dc9030e3c7e2a5fdcccdbabb9d5d261c);
#
#
#
#         marker_09ad21fc1fa36e7a8151618a35e238a1.bindPopup(popup_e3afba60cd96a333bbdde2f013dcc029)
#         ;
#
#
#
#
#             var marker_4e2fb2ffd0bf19cc80688105bd71a2f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a8f3e8de763960520f8a2a33bbb21e6d);
#
#
#         var popup_278bb39fc9cfde8319961fbae384a91f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cc7fbe3485c61b9e5efdb2d99df8502 = $(`&lt;div id=&quot;html_3cc7fbe3485c61b9e5efdb2d99df8502&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_278bb39fc9cfde8319961fbae384a91f.setContent(html_3cc7fbe3485c61b9e5efdb2d99df8502);
#
#
#
#         marker_4e2fb2ffd0bf19cc80688105bd71a2f4.bindPopup(popup_278bb39fc9cfde8319961fbae384a91f)
#         ;
#
#
#
#
#             var marker_9c00367bb481ed98be78439c5aca68f6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a8f3e8de763960520f8a2a33bbb21e6d);
#
#
#         var popup_978536821d95df45ebe7634af51de0e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c0236a77c05ec598d9013b6153afd63 = $(`&lt;div id=&quot;html_0c0236a77c05ec598d9013b6153afd63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_978536821d95df45ebe7634af51de0e0.setContent(html_0c0236a77c05ec598d9013b6153afd63);
#
#
#
#         marker_9c00367bb481ed98be78439c5aca68f6.bindPopup(popup_978536821d95df45ebe7634af51de0e0)
#         ;
#
#
#
#
#             var marker_63d898ef14395ab8b0d0211e442f2672 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a8f3e8de763960520f8a2a33bbb21e6d);
#
#
#         var popup_e77c817f4d40c854082b5f9039881f9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a4654ba9ecae23edbf0b8865e0779b3 = $(`&lt;div id=&quot;html_7a4654ba9ecae23edbf0b8865e0779b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e77c817f4d40c854082b5f9039881f9a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85ab4c6fd465d2f62582e3e420c9bb3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85ab4c6fd465d2f62582e3e420c9bb3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85ab4c6fd465d2f62582e3e420c9bb3e = L.map(
#                 &quot;map_85ab4c6fd465d2f62582e3e420c9bb3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c377933314f9352aa889f125999e2a8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c377933314f9352aa889f125999e2a8a.addTo(map_85ab4c6fd465d2f62582e3e420c9bb3e);
#
#
#             var feature_group_c8c90068aa3ce2d6d386eada4b438580 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e60a680b071f2632d519519381cefa0a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c8c90068aa3ce2d6d386eada4b438580);
#
#
#         var popup_5508b27e119699573ac15ec9e55a63a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1654afec8d4e4205b649fb29ff94755 = $(`&lt;div id=&quot;html_b1654afec8d4e4205b649fb29ff94755&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5508b27e119699573ac15ec9e55a63a7.setContent(html_b1654afec8d4e4205b649fb29ff94755);
#
#
#
#         marker_e60a680b071f2632d519519381cefa0a.bindPopup(popup_5508b27e119699573ac15ec9e55a63a7)
#         ;
#
#
#
#
#             var marker_c6bd4049e4af44a1946fc639e572bc7b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c8c90068aa3ce2d6d386eada4b438580);
#
#
#         var popup_bd4433e8fce86327135caaf5290f8da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e1e78eea2ce5a577c49382d51682e19 = $(`&lt;div id=&quot;html_4e1e78eea2ce5a577c49382d51682e19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bd4433e8fce86327135caaf5290f8da4.setContent(html_4e1e78eea2ce5a577c49382d51682e19);
#
#
#
#         marker_c6bd4049e4af44a1946fc639e572bc7b.bindPopup(popup_bd4433e8fce86327135caaf5290f8da4)
#         ;
#
#
#
#
#             var marker_4338d5e15e12265beacb008759a125f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c8c90068aa3ce2d6d386eada4b438580);
#
#
#         var popup_a001cc052a444267d3f83caabab7b5f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cf0e2839c755f60331d7b30eb858c06 = $(`&lt;div id=&quot;html_4cf0e2839c755f60331d7b30eb858c06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a001cc052a444267d3f83caabab7b5f8.setContent(html_4cf0e2839c755f60331d7b30eb858c06);
#
#
#
#         marker_4338d5e15e12265beacb008759a125f2.bindPopup(popup_a001cc052a444267d3f83caabab7b5f8)
#         ;
#
#
#
#
#             var marker_3bb06e59b58d080310934d87d9108d13 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c8c90068aa3ce2d6d386eada4b438580);
#
#
#         var popup_ded005f22e1f06cdf775515d0699b16a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2349f67c664338c4791b294499b6e29 = $(`&lt;div id=&quot;html_f2349f67c664338c4791b294499b6e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ded005f22e1f06cdf775515d0699b16a.setContent(html_f2349f67c664338c4791b294499b6e29);
#
#
#
#         marker_3bb06e59b58d080310934d87d9108d13.bindPopup(popup_ded005f22e1f06cdf775515d0699b16a)
#         ;
#
#
#
#
#             var marker_c890711d713dbf1d8680e83a66795f0e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c8c90068aa3ce2d6d386eada4b438580);
#
#
#         var popup_6493a49bd17d23bf282527418a443fc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f257b3e271b1e101619b1cfe25eac39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f257b3e271b1e101619b1cfe25eac39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f257b3e271b1e101619b1cfe25eac39 = L.map(
#                 &quot;map_9f257b3e271b1e101619b1cfe25eac39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e2a277c7f9ef98926a4e3bdabd7f4c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e2a277c7f9ef98926a4e3bdabd7f4c6.addTo(map_9f257b3e271b1e101619b1cfe25eac39);
#
#
#             var feature_group_f1edd2cc004212fda41c73ea9a185098 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f1edd2cc004212fda41c73ea9a185098.addTo(map_9f257b3e271b1e101619b1cfe25eac39);
#
#
#             var feature_group_sub_group_aea350b86b1d825e9d9fa082a5aa657a = L.featureGroup.subGroup(
#                 feature_group_f1edd2cc004212fda41c73ea9a185098
#             );
#
#
#             var marker_650aa720b6d649ff70ad01772feef4da = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aea350b86b1d825e9d9fa082a5aa657a);
#
#
#         var popup_72654ac4e072a1d49297deec6703be94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e67ebe800511aa3f0753a625dd3ef995 = $(`&lt;div id=&quot;html_e67ebe800511aa3f0753a625dd3ef995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_72654ac4e072a1d49297deec6703be94.setContent(html_e67ebe800511aa3f0753a625dd3ef995);
#
#
#
#         marker_650aa720b6d649ff70ad01772feef4da.bindPopup(popup_72654ac4e072a1d49297deec6703be94)
#         ;
#
#
#
#
#             var marker_3eb4407ac1e08847e0e70368f4be7eee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aea350b86b1d825e9d9fa082a5aa657a);
#
#
#         var popup_bf349b2b21be527dd85943a03217e322 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ddbb5cc493232a0ab2ce1f46d11f03 = $(`&lt;div id=&quot;html_e2ddbb5cc493232a0ab2ce1f46d11f03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bf349b2b21be527dd85943a03217e322.setContent(html_e2ddbb5cc493232a0ab2ce1f46d11f03);
#
#
#
#         marker_3eb4407ac1e08847e0e70368f4be7eee.bindPopup(popup_bf349b2b21be527dd85943a03217e322)
#         ;
#
#
#
#
#             var marker_bc969396060d65a6d848cfeba645bf40 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aea350b86b1d825e9d9fa082a5aa657a);
#
#
#         var popup_f046560ea5d36681f7d5e81326aa6bac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58bef9c21dc2db6e4653f2f2727d6500 = $(`&lt;div id=&quot;html_58bef9c21dc2db6e4653f2f2727d6500&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f046560ea5d36681f7d5e81326aa6bac.setContent(html_58bef9c21dc2db6e4653f2f2727d6500);
#
#
#
#         marker_bc969396060d65a6d848cfeba645bf40.bindPopup(popup_f046560ea5d36681f7d5e81326aa6bac)
#         ;
#
#
#
#
#             var marker_9cf3b56643b3292a6935ee0f7e75532b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aea350b86b1d825e9d9fa082a5aa657a);
#
#
#         var popup_f61b66018223fe502a34f110256205e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_063fc0401baa003a651cc9ceee6c7556 = $(`&lt;div id=&quot;html_063fc0401baa003a651cc9ceee6c7556&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f61b66018223fe502a34f110256205e8.setContent(html_063fc0401baa003a651cc9ceee6c7556);
#
#
#
#         marker_
