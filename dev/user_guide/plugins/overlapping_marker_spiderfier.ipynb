# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c76a65320e7f8ae1a75c88d28f8ec8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c76a65320e7f8ae1a75c88d28f8ec8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c76a65320e7f8ae1a75c88d28f8ec8f = L.map(
#                 &quot;map_7c76a65320e7f8ae1a75c88d28f8ec8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e371a228ab18400c79f77dede6d41ff3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e371a228ab18400c79f77dede6d41ff3.addTo(map_7c76a65320e7f8ae1a75c88d28f8ec8f);
#
#
#             var marker_1f30b64378e4498ab09519edda196857 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7c76a65320e7f8ae1a75c88d28f8ec8f);
#
#
#         var popup_39c7d34efee460ba732da45f27b9463a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6d1de6cf0bbf07e1208bdaa29b1daff = $(`&lt;div id=&quot;html_a6d1de6cf0bbf07e1208bdaa29b1daff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_39c7d34efee460ba732da45f27b9463a.setContent(html_a6d1de6cf0bbf07e1208bdaa29b1daff);
#
#
#
#         marker_1f30b64378e4498ab09519edda196857.bindPopup(popup_39c7d34efee460ba732da45f27b9463a)
#         ;
#
#
#
#
#             var marker_b664abf4610acbdf0f40fbe3d97be681 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7c76a65320e7f8ae1a75c88d28f8ec8f);
#
#
#         var popup_131b0bc095f880698a6f6eb2023afddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e870f106768efc7192e61d866ec7c078 = $(`&lt;div id=&quot;html_e870f106768efc7192e61d866ec7c078&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_131b0bc095f880698a6f6eb2023afddd.setContent(html_e870f106768efc7192e61d866ec7c078);
#
#
#
#         marker_b664abf4610acbdf0f40fbe3d97be681.bindPopup(popup_131b0bc095f880698a6f6eb2023afddd)
#         ;
#
#
#
#
#             var marker_b3bc0083a25be982c22c496d7217cca1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7c76a65320e7f8ae1a75c88d28f8ec8f);
#
#
#         var popup_7dad168d113320206d9961cf12526a7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9fa697c2a18c219bb3090b6c0e3e6e0 = $(`&lt;div id=&quot;html_c9fa697c2a18c219bb3090b6c0e3e6e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7dad168d113320206d9961cf12526a7c.setContent(html_c9fa697c2a18c219bb3090b6c0e3e6e0);
#
#
#
#         marker_b3bc0083a25be982c22c496d7217cca1.bindPopup(popup_7dad168d113320206d9961cf12526a7c)
#         ;
#
#
#
#
#             var marker_4eb3533957bf86c1f7b8ddd5068aac68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7c76a65320e7f8ae1a75c88d28f8ec8f);
#
#
#         var popup_f03bfe2c99ec7b74fae8eec8dcd996b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02167c789e430ed31933943d109a1897 = $(`&lt;div id=&quot;html_02167c789e430ed31933943d109a1897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f03bfe2c99ec7b74fae8eec8dcd996b8.setContent(html_02167c789e430ed31933943d109a1897);
#
#
#
#         marker_4eb3533957bf86c1f7b8ddd5068aac68.bindPopup(popup_f03bfe2c99ec7b74fae8eec8dcd996b8)
#         ;
#
#
#
#
#             var marker_fdcf76cfa3775032a8fde19fe970e577 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7c76a65320e7f8ae1a75c88d28f8ec8f);
#
#
#         var popup_c49f796b95296aa87bec932bf9de695d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83e122b3a8e72c747463e763e2116fb7 = $(`&lt;div id=&quot;html_83e122b3a8e72c747463e763e2116fb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c49f796b95296aa87bec932bf9de695d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e844d0880a242dbfb8c0ee1f97b68119 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e844d0880a242dbfb8c0ee1f97b68119&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e844d0880a242dbfb8c0ee1f97b68119 = L.map(
#                 &quot;map_e844d0880a242dbfb8c0ee1f97b68119&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2641400eda57058d87e1aeb78b8ef7a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2641400eda57058d87e1aeb78b8ef7a8.addTo(map_e844d0880a242dbfb8c0ee1f97b68119);
#
#
#             var feature_group_512a63c27750e3b8da0824f2a957cb12 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_49fb9ab1e6252de38163657b238fce7f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_512a63c27750e3b8da0824f2a957cb12);
#
#
#         var popup_c6744ab609f11af4b0e027bfc4dd9b37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3857b373a85a4f1b71eb6ad2d8dba08 = $(`&lt;div id=&quot;html_e3857b373a85a4f1b71eb6ad2d8dba08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c6744ab609f11af4b0e027bfc4dd9b37.setContent(html_e3857b373a85a4f1b71eb6ad2d8dba08);
#
#
#
#         marker_49fb9ab1e6252de38163657b238fce7f.bindPopup(popup_c6744ab609f11af4b0e027bfc4dd9b37)
#         ;
#
#
#
#
#             var marker_2e12532c27044aaeb8d67140a1e27738 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_512a63c27750e3b8da0824f2a957cb12);
#
#
#         var popup_30da0a03f8ae464f7b3d62638f666c70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cc90034ba68a6005878922b9358525f = $(`&lt;div id=&quot;html_1cc90034ba68a6005878922b9358525f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_30da0a03f8ae464f7b3d62638f666c70.setContent(html_1cc90034ba68a6005878922b9358525f);
#
#
#
#         marker_2e12532c27044aaeb8d67140a1e27738.bindPopup(popup_30da0a03f8ae464f7b3d62638f666c70)
#         ;
#
#
#
#
#             var marker_a5f66a1f889a6c4298cc146d8199d5b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_512a63c27750e3b8da0824f2a957cb12);
#
#
#         var popup_4baaac2909732e3a8ff233c24ae2163b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d69186dbc99fe35e70ac766f8f087122 = $(`&lt;div id=&quot;html_d69186dbc99fe35e70ac766f8f087122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4baaac2909732e3a8ff233c24ae2163b.setContent(html_d69186dbc99fe35e70ac766f8f087122);
#
#
#
#         marker_a5f66a1f889a6c4298cc146d8199d5b2.bindPopup(popup_4baaac2909732e3a8ff233c24ae2163b)
#         ;
#
#
#
#
#             var marker_d6288b92ee18125ff5a441e77daf8473 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_512a63c27750e3b8da0824f2a957cb12);
#
#
#         var popup_b143aba62b45297f7bf551edfdb830bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b689d4296cc9ce5a7cc8c638bf8bea52 = $(`&lt;div id=&quot;html_b689d4296cc9ce5a7cc8c638bf8bea52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b143aba62b45297f7bf551edfdb830bb.setContent(html_b689d4296cc9ce5a7cc8c638bf8bea52);
#
#
#
#         marker_d6288b92ee18125ff5a441e77daf8473.bindPopup(popup_b143aba62b45297f7bf551edfdb830bb)
#         ;
#
#
#
#
#             var marker_eb3847c7d7d656c52a9a27c2decb9c6b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_512a63c27750e3b8da0824f2a957cb12);
#
#
#         var popup_52f2fa47a1ac5159d18b94821348e5e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47e397119a644b00d62b73d222d3f1db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47e397119a644b00d62b73d222d3f1db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47e397119a644b00d62b73d222d3f1db = L.map(
#                 &quot;map_47e397119a644b00d62b73d222d3f1db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b498c4d34b08ed8b50377bdeb51bb05e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b498c4d34b08ed8b50377bdeb51bb05e.addTo(map_47e397119a644b00d62b73d222d3f1db);
#
#
#             var feature_group_4aa363b463d6892a142ac5132fe1aa4d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4aa363b463d6892a142ac5132fe1aa4d.addTo(map_47e397119a644b00d62b73d222d3f1db);
#
#
#             var feature_group_sub_group_405d6381d5bc2216840463160df57bd2 = L.featureGroup.subGroup(
#                 feature_group_4aa363b463d6892a142ac5132fe1aa4d
#             );
#
#
#             var marker_5b4a93bf5a3d742490fcb62df5d701ba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_405d6381d5bc2216840463160df57bd2);
#
#
#         var popup_83aed3a8fd6218ec586d435c5edce300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e16f1ce2a9d26e294bf2d6c4a532b127 = $(`&lt;div id=&quot;html_e16f1ce2a9d26e294bf2d6c4a532b127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_83aed3a8fd6218ec586d435c5edce300.setContent(html_e16f1ce2a9d26e294bf2d6c4a532b127);
#
#
#
#         marker_5b4a93bf5a3d742490fcb62df5d701ba.bindPopup(popup_83aed3a8fd6218ec586d435c5edce300)
#         ;
#
#
#
#
#             var marker_748ede0b6650b7326152186f1565c313 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_405d6381d5bc2216840463160df57bd2);
#
#
#         var popup_a60efb0084db941c6e807e4033bb418d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a3388655b5643d6c2a3942194e092ea = $(`&lt;div id=&quot;html_4a3388655b5643d6c2a3942194e092ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a60efb0084db941c6e807e4033bb418d.setContent(html_4a3388655b5643d6c2a3942194e092ea);
#
#
#
#         marker_748ede0b6650b7326152186f1565c313.bindPopup(popup_a60efb0084db941c6e807e4033bb418d)
#         ;
#
#
#
#
#             var marker_729439858eef1a7b0e4605ea1ca75daf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_405d6381d5bc2216840463160df57bd2);
#
#
#         var popup_b7fd05f8e3de4d0a527897b9cc7f28d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_978a930e98e1062898643951ec3eb628 = $(`&lt;div id=&quot;html_978a930e98e1062898643951ec3eb628&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b7fd05f8e3de4d0a527897b9cc7f28d2.setContent(html_978a930e98e1062898643951ec3eb628);
#
#
#
#         marker_729439858eef1a7b0e4605ea1ca75daf.bindPopup(popup_b7fd05f8e3de4d0a527897b9cc7f28d2)
#         ;
#
#
#
#
#             var marker_41168b3e1d8a6b4cd7815c07fe3d24b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_405d6381d5bc2216840463160df57bd2);
#
#
#         var popup_5407fd122f8815ac261b22e77e567b87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31d8111f94464956340438be608d6fbe = $(`&lt;div id=&quot;html_31d8111f94464956340438be608d6fbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5407fd122f8815ac261b22e77e567b87.setContent(html_31d8111f94464956340438be608d6fbe);
#
#
#
#         marker_
