# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a5076431cf8ff0a50040d14d0696430 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a5076431cf8ff0a50040d14d0696430&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a5076431cf8ff0a50040d14d0696430 = L.map(
#                 &quot;map_5a5076431cf8ff0a50040d14d0696430&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b342b809d225a3f3ae692f695616b7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b342b809d225a3f3ae692f695616b7c.addTo(map_5a5076431cf8ff0a50040d14d0696430);
#
#
#             var marker_3d026c25d80a1792191e4bf172f196c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5a5076431cf8ff0a50040d14d0696430);
#
#
#         var popup_27c82467f53fc8dff7025785be89ceb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b273b102112f7fb50aeefcd14475f9a = $(`&lt;div id=&quot;html_4b273b102112f7fb50aeefcd14475f9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_27c82467f53fc8dff7025785be89ceb4.setContent(html_4b273b102112f7fb50aeefcd14475f9a);
#
#
#
#         marker_3d026c25d80a1792191e4bf172f196c8.bindPopup(popup_27c82467f53fc8dff7025785be89ceb4)
#         ;
#
#
#
#
#             var marker_0a58eb40cdd43ab85c780077885984bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5a5076431cf8ff0a50040d14d0696430);
#
#
#         var popup_dd548fdcd556e33cd2304a7e7bad65ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baec05b369ff1a3eb293034f1bf3885e = $(`&lt;div id=&quot;html_baec05b369ff1a3eb293034f1bf3885e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dd548fdcd556e33cd2304a7e7bad65ad.setContent(html_baec05b369ff1a3eb293034f1bf3885e);
#
#
#
#         marker_0a58eb40cdd43ab85c780077885984bb.bindPopup(popup_dd548fdcd556e33cd2304a7e7bad65ad)
#         ;
#
#
#
#
#             var marker_bc8badaed95e219ac4bbbde4108dfe65 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5a5076431cf8ff0a50040d14d0696430);
#
#
#         var popup_13078e0039e60ef76d1910c482a7989f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcaf5c0f7b3f40faf9b8ca7a37154608 = $(`&lt;div id=&quot;html_bcaf5c0f7b3f40faf9b8ca7a37154608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_13078e0039e60ef76d1910c482a7989f.setContent(html_bcaf5c0f7b3f40faf9b8ca7a37154608);
#
#
#
#         marker_bc8badaed95e219ac4bbbde4108dfe65.bindPopup(popup_13078e0039e60ef76d1910c482a7989f)
#         ;
#
#
#
#
#             var marker_2ad631d8454d26da20574bee428ed47b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5a5076431cf8ff0a50040d14d0696430);
#
#
#         var popup_298e3f22d46973bf01e4b278d5ff32ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8e05d63eb44eaecb73f3afd3222b28f = $(`&lt;div id=&quot;html_f8e05d63eb44eaecb73f3afd3222b28f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_298e3f22d46973bf01e4b278d5ff32ad.setContent(html_f8e05d63eb44eaecb73f3afd3222b28f);
#
#
#
#         marker_2ad631d8454d26da20574bee428ed47b.bindPopup(popup_298e3f22d46973bf01e4b278d5ff32ad)
#         ;
#
#
#
#
#             var marker_f9fedea050d362c47ef8eca5ac2e1803 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5a5076431cf8ff0a50040d14d0696430);
#
#
#         var popup_25f348f6cc61b138e22f5f79a3296aa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17f55bc0aa328779f89c8cd07205c9be = $(`&lt;div id=&quot;html_17f55bc0aa328779f89c8cd07205c9be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_25f348f6cc61b138e22f5f79a3296aa0.setContent(html_17f55bc0aa328779f89c8cd07205c9be);
#
#
#
#         marker_f9fedea050d362c47ef8eca5ac2e1803.bindPopup(popup_25f348f6cc61b138e22f5f79a3296aa0)
#         ;
#
#
#
#
#             var marker_ae89bd1981

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8d0e44f1e1b575a1be146e1c0c69f75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8d0e44f1e1b575a1be146e1c0c69f75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8d0e44f1e1b575a1be146e1c0c69f75 = L.map(
#                 &quot;map_b8d0e44f1e1b575a1be146e1c0c69f75&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_444f6fae6dce40864c91e8672f26de82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_444f6fae6dce40864c91e8672f26de82.addTo(map_b8d0e44f1e1b575a1be146e1c0c69f75);
#
#
#             var feature_group_8a088cb150dd0115a6e9a206b94c25c3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a3587efa89033209e71c5c6eda669890 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8a088cb150dd0115a6e9a206b94c25c3);
#
#
#         var popup_285e3d474314764e861b4bd1dbc0614c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95cbe4d679e1f0b5f37e5a37a328d756 = $(`&lt;div id=&quot;html_95cbe4d679e1f0b5f37e5a37a328d756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_285e3d474314764e861b4bd1dbc0614c.setContent(html_95cbe4d679e1f0b5f37e5a37a328d756);
#
#
#
#         marker_a3587efa89033209e71c5c6eda669890.bindPopup(popup_285e3d474314764e861b4bd1dbc0614c)
#         ;
#
#
#
#
#             var marker_d1a9eb0e87af25bb2827885055ee3b7b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8a088cb150dd0115a6e9a206b94c25c3);
#
#
#         var popup_f503c354a4e4be57965850f22942d300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f2b71667ec5b7f9f5fc621669cabc6d = $(`&lt;div id=&quot;html_6f2b71667ec5b7f9f5fc621669cabc6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f503c354a4e4be57965850f22942d300.setContent(html_6f2b71667ec5b7f9f5fc621669cabc6d);
#
#
#
#         marker_d1a9eb0e87af25bb2827885055ee3b7b.bindPopup(popup_f503c354a4e4be57965850f22942d300)
#         ;
#
#
#
#
#             var marker_fd52d3f338d22d9e8b2e61330ad9248e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8a088cb150dd0115a6e9a206b94c25c3);
#
#
#         var popup_a6500f8758074a5e403c3e88978c2379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbe3591b5545da44766de45d81699802 = $(`&lt;div id=&quot;html_bbe3591b5545da44766de45d81699802&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a6500f8758074a5e403c3e88978c2379.setContent(html_bbe3591b5545da44766de45d81699802);
#
#
#
#         marker_fd52d3f338d22d9e8b2e61330ad9248e.bindPopup(popup_a6500f8758074a5e403c3e88978c2379)
#         ;
#
#
#
#
#             var marker_b33032bae1425e75fcaaf7fb25cb786e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8a088cb150dd0115a6e9a206b94c25c3);
#
#
#         var popup_d6d42af299c66b5e2810be19b88625a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe13ab65b673c3d0b0c07725aedd4ecc = $(`&lt;div id=&quot;html_fe13ab65b673c3d0b0c07725aedd4ecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d6d42af299c66b5e2810be19b88625a3.setContent(html_fe13ab65b673c3d0b0c07725aedd4ecc);
#
#
#
#         marker_b33032bae1425e75fcaaf7fb25cb786e.bindPopup(popup_d6d42af299c66b5e2810be19b88625a3)
#         ;
#
#
#
#
#             var marker_9156b7f9e6496e07f7c1932c79d5b8c8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8a088cb150dd0115a6e9a206b94c25c3);
#
#
#         var popup_2c9897db7f1b2e936ff213ab3f40d360 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_842b23c509443ca1b0b6b8414534aff7 = $(`&lt;div id=&quot;html_842b23c509443ca1b0b6b8414534aff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_2c9897db7f1b2e936f

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3eb6e678f5d5d068b1e8f0a5901f9394 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3eb6e678f5d5d068b1e8f0a5901f9394&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3eb6e678f5d5d068b1e8f0a5901f9394 = L.map(
#                 &quot;map_3eb6e678f5d5d068b1e8f0a5901f9394&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c28d5a3bb510fca164b5bd1cad4b78e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c28d5a3bb510fca164b5bd1cad4b78e7.addTo(map_3eb6e678f5d5d068b1e8f0a5901f9394);
#
#
#             var feature_group_e361b0177dcc540c8cf521437a080a5f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e361b0177dcc540c8cf521437a080a5f.addTo(map_3eb6e678f5d5d068b1e8f0a5901f9394);
#
#
#             var feature_group_sub_group_ffcde2d16408ffe38f73ed846b4f0970 = L.featureGroup.subGroup(
#                 feature_group_e361b0177dcc540c8cf521437a080a5f
#             );
#
#
#             var marker_ff14c7f45b875fbfecc939434d2896b6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffcde2d16408ffe38f73ed846b4f0970);
#
#
#         var popup_ce331cba60a51f676b1f145724831665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_037cfefd76d3beb06201e821f09af410 = $(`&lt;div id=&quot;html_037cfefd76d3beb06201e821f09af410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ce331cba60a51f676b1f145724831665.setContent(html_037cfefd76d3beb06201e821f09af410);
#
#
#
#         marker_ff14c7f45b875fbfecc939434d2896b6.bindPopup(popup_ce331cba60a51f676b1f145724831665)
#         ;
#
#
#
#
#             var marker_b0ffccffdfb3dc10c24314dfe8eb256f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffcde2d16408ffe38f73ed846b4f0970);
#
#
#         var popup_6759b194a6faf418f2ba748acd07ec3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f143b8016bf14599754f427404b52599 = $(`&lt;div id=&quot;html_f143b8016bf14599754f427404b52599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6759b194a6faf418f2ba748acd07ec3e.setContent(html_f143b8016bf14599754f427404b52599);
#
#
#
#         marker_b0ffccffdfb3dc10c24314dfe8eb256f.bindPopup(popup_6759b194a6faf418f2ba748acd07ec3e)
#         ;
#
#
#
#
#             var marker_99337d0939616e03e835a07043e01e30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffcde2d16408ffe38f73ed846b4f0970);
#
#
#         var popup_4331cf268c776f84dc1dcc6f33af380d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5fbfe72b26fda35e19fe1fee5f2333d = $(`&lt;div id=&quot;html_f5fbfe72b26fda35e19fe1fee5f2333d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4331cf268c776f84dc1dcc6f33af380d.setContent(html_f5fbfe72b26fda35e19fe1fee5f2333d);
#
#
#
#         marker_99337d0939616e03e835a07043e01e30.bindPopup(popup_4331cf268c776f84dc1dcc6f33af380d)
#         ;
#
#
#
#
#             var marker_d621fb8ceef062245e369a381a5d079f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffcde2d16408ffe38f73ed846b4f0970);
#
#
#         var popup_dec4c30279e652c7b114a365c34dc941 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45920fb85e8ba3e26c4b284cd4daf19c = $(`&lt;div id=&quot;html_45920fb85e8ba3e26c4b284cd4daf19c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dec4c30279e652c7b114a365c34dc941.setContent(html_45920fb85e8ba3e26c4b284cd4daf19c);
#
#
#
#         marker_d621fb8ceef062245e369a381a5d079f.bindPopup(popup_dec4c30279e652c7b114a365c34dc941)
#         ;
#
#
#
#
#             var marker_d0f4231e73e0adc55ad0b5cfb76a6d45 = L.marker(
#                 [45.050399999999996, 3.0504],
