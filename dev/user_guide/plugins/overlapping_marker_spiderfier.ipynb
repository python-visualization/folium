# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a4cd449f189b413f9c6ddf0d1ad6f13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a4cd449f189b413f9c6ddf0d1ad6f13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a4cd449f189b413f9c6ddf0d1ad6f13 = L.map(
#                 &quot;map_2a4cd449f189b413f9c6ddf0d1ad6f13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77e237706e895b811084f2d877be768e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77e237706e895b811084f2d877be768e.addTo(map_2a4cd449f189b413f9c6ddf0d1ad6f13);
#
#
#             var marker_29a76422647c9c0a020403bec43e40af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2a4cd449f189b413f9c6ddf0d1ad6f13);
#
#
#         var popup_911efa98e0f09659f28d86c0b5c3af1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1aa2558fa93d495875981c185fedd9b9 = $(`&lt;div id=&quot;html_1aa2558fa93d495875981c185fedd9b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_911efa98e0f09659f28d86c0b5c3af1e.setContent(html_1aa2558fa93d495875981c185fedd9b9);
#
#
#
#         marker_29a76422647c9c0a020403bec43e40af.bindPopup(popup_911efa98e0f09659f28d86c0b5c3af1e)
#         ;
#
#
#
#
#             var marker_3fed798bf89b93d4bd974d4526ecc65e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2a4cd449f189b413f9c6ddf0d1ad6f13);
#
#
#         var popup_d84adb94c942f4aa53dde66ce65cce1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b6b67bd08f43c7301dfa6bebd03d5b6 = $(`&lt;div id=&quot;html_3b6b67bd08f43c7301dfa6bebd03d5b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d84adb94c942f4aa53dde66ce65cce1c.setContent(html_3b6b67bd08f43c7301dfa6bebd03d5b6);
#
#
#
#         marker_3fed798bf89b93d4bd974d4526ecc65e.bindPopup(popup_d84adb94c942f4aa53dde66ce65cce1c)
#         ;
#
#
#
#
#             var marker_50e5984a6e3759d8770df94d464a3ef5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2a4cd449f189b413f9c6ddf0d1ad6f13);
#
#
#         var popup_3d9475c568438d3906ae512f0ce035e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9d4d92581c5bafa6461457263b90ac1 = $(`&lt;div id=&quot;html_b9d4d92581c5bafa6461457263b90ac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3d9475c568438d3906ae512f0ce035e6.setContent(html_b9d4d92581c5bafa6461457263b90ac1);
#
#
#
#         marker_50e5984a6e3759d8770df94d464a3ef5.bindPopup(popup_3d9475c568438d3906ae512f0ce035e6)
#         ;
#
#
#
#
#             var marker_2f6cfdf826c970b596fa3c01bce65a6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2a4cd449f189b413f9c6ddf0d1ad6f13);
#
#
#         var popup_767560052e5453a23076f7de4503dddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a4a84ce00d2516cc8f12d3cdc4e521f = $(`&lt;div id=&quot;html_3a4a84ce00d2516cc8f12d3cdc4e521f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_767560052e5453a23076f7de4503dddc.setContent(html_3a4a84ce00d2516cc8f12d3cdc4e521f);
#
#
#
#         marker_2f6cfdf826c970b596fa3c01bce65a6e.bindPopup(popup_767560052e5453a23076f7de4503dddc)
#         ;
#
#
#
#
#             var marker_e05e9a823deada3366080a7958c98f2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2a4cd449f189b413f9c6ddf0d1ad6f13);
#
#
#         var popup_e47e67b05e9e7ec9e4f5f75e11fb3806 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eeee79faffd74fc6cdeca5be9793b86 = $(`&lt;div id=&quot;html_5eeee79faffd74fc6cdeca5be9793b86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e47e67b05e9e7ec9e4f5f75e11fb3806.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38b5cbb26f34e575688608ad1c296522 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38b5cbb26f34e575688608ad1c296522&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38b5cbb26f34e575688608ad1c296522 = L.map(
#                 &quot;map_38b5cbb26f34e575688608ad1c296522&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e3a932ea22d5e0f52312a9bb0944d77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e3a932ea22d5e0f52312a9bb0944d77.addTo(map_38b5cbb26f34e575688608ad1c296522);
#
#
#             var feature_group_1d9c7d5c77115e69cb8a1fe76bcd77a1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2a6677e09987938694ce1bea21e745c9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1d9c7d5c77115e69cb8a1fe76bcd77a1);
#
#
#         var popup_7b72a3bf705dd095072332aa6c43f64e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ee292f7f2db54b7f4a33b2f8938705c = $(`&lt;div id=&quot;html_9ee292f7f2db54b7f4a33b2f8938705c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7b72a3bf705dd095072332aa6c43f64e.setContent(html_9ee292f7f2db54b7f4a33b2f8938705c);
#
#
#
#         marker_2a6677e09987938694ce1bea21e745c9.bindPopup(popup_7b72a3bf705dd095072332aa6c43f64e)
#         ;
#
#
#
#
#             var marker_35f992b2caf92fa8af1cd301717ab652 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1d9c7d5c77115e69cb8a1fe76bcd77a1);
#
#
#         var popup_89843cf289446aafa8d261ade6a420f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39b8cbe95738e4a2f2bc56a45a415dd6 = $(`&lt;div id=&quot;html_39b8cbe95738e4a2f2bc56a45a415dd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_89843cf289446aafa8d261ade6a420f0.setContent(html_39b8cbe95738e4a2f2bc56a45a415dd6);
#
#
#
#         marker_35f992b2caf92fa8af1cd301717ab652.bindPopup(popup_89843cf289446aafa8d261ade6a420f0)
#         ;
#
#
#
#
#             var marker_33a5713842adf54c525569bfed348006 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1d9c7d5c77115e69cb8a1fe76bcd77a1);
#
#
#         var popup_66a9fe66998d2efcd2140cd1352eff42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa31cd3f08f2d34c213b4c49b5e25e23 = $(`&lt;div id=&quot;html_fa31cd3f08f2d34c213b4c49b5e25e23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_66a9fe66998d2efcd2140cd1352eff42.setContent(html_fa31cd3f08f2d34c213b4c49b5e25e23);
#
#
#
#         marker_33a5713842adf54c525569bfed348006.bindPopup(popup_66a9fe66998d2efcd2140cd1352eff42)
#         ;
#
#
#
#
#             var marker_425f54516f3844f858bbc4a9a5d66310 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1d9c7d5c77115e69cb8a1fe76bcd77a1);
#
#
#         var popup_208c2f41a80e0c83057ea784501d51b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d18458512e91494d5b5f63a1618aa9 = $(`&lt;div id=&quot;html_20d18458512e91494d5b5f63a1618aa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_208c2f41a80e0c83057ea784501d51b1.setContent(html_20d18458512e91494d5b5f63a1618aa9);
#
#
#
#         marker_425f54516f3844f858bbc4a9a5d66310.bindPopup(popup_208c2f41a80e0c83057ea784501d51b1)
#         ;
#
#
#
#
#             var marker_e45fafcece4bd144f61308c6165bd87b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1d9c7d5c77115e69cb8a1fe76bcd77a1);
#
#
#         var popup_76a8fbf62e0bff7f95c2a271b814841d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb2557896d895ac21ff5ba34399f9e67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb2557896d895ac21ff5ba34399f9e67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb2557896d895ac21ff5ba34399f9e67 = L.map(
#                 &quot;map_fb2557896d895ac21ff5ba34399f9e67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_203c7f26d79a0b9ade9db46137f9e6c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_203c7f26d79a0b9ade9db46137f9e6c7.addTo(map_fb2557896d895ac21ff5ba34399f9e67);
#
#
#             var feature_group_5e86f359a19364de2e2c6c8e807a9b1f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5e86f359a19364de2e2c6c8e807a9b1f.addTo(map_fb2557896d895ac21ff5ba34399f9e67);
#
#
#             var feature_group_sub_group_be303bd0b2468e8877d826dfcfb3249d = L.featureGroup.subGroup(
#                 feature_group_5e86f359a19364de2e2c6c8e807a9b1f
#             );
#
#
#             var marker_ed7c6a96e6cc004c9a4290dfa074650c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_be303bd0b2468e8877d826dfcfb3249d);
#
#
#         var popup_c691659903ee49069a93c5336583595f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42f326b97b9c7c2ba0277bf00b110ca1 = $(`&lt;div id=&quot;html_42f326b97b9c7c2ba0277bf00b110ca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c691659903ee49069a93c5336583595f.setContent(html_42f326b97b9c7c2ba0277bf00b110ca1);
#
#
#
#         marker_ed7c6a96e6cc004c9a4290dfa074650c.bindPopup(popup_c691659903ee49069a93c5336583595f)
#         ;
#
#
#
#
#             var marker_35a80385ef84fe12c4e6dc20ef4baf75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_be303bd0b2468e8877d826dfcfb3249d);
#
#
#         var popup_e26b7a1b2fbefb174bd00ed5364cf500 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfe4f964aa96c0bdddecb167d5896d84 = $(`&lt;div id=&quot;html_dfe4f964aa96c0bdddecb167d5896d84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e26b7a1b2fbefb174bd00ed5364cf500.setContent(html_dfe4f964aa96c0bdddecb167d5896d84);
#
#
#
#         marker_35a80385ef84fe12c4e6dc20ef4baf75.bindPopup(popup_e26b7a1b2fbefb174bd00ed5364cf500)
#         ;
#
#
#
#
#             var marker_daadbc9775f5b75b5eab248cdf2cc31e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_be303bd0b2468e8877d826dfcfb3249d);
#
#
#         var popup_e1fa5c1182388aed46f5e42589d318b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6dcf768c3fb130bc61ce10fa68d01ff = $(`&lt;div id=&quot;html_d6dcf768c3fb130bc61ce10fa68d01ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e1fa5c1182388aed46f5e42589d318b9.setContent(html_d6dcf768c3fb130bc61ce10fa68d01ff);
#
#
#
#         marker_daadbc9775f5b75b5eab248cdf2cc31e.bindPopup(popup_e1fa5c1182388aed46f5e42589d318b9)
#         ;
#
#
#
#
#             var marker_7d120bae9c56917f9735e2bcc6299dd2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_be303bd0b2468e8877d826dfcfb3249d);
#
#
#         var popup_45d243fe303a510a448ba3ef8865d7fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ffd1f024bc92336391bd85a5e449f48 = $(`&lt;div id=&quot;html_7ffd1f024bc92336391bd85a5e449f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_45d243fe303a510a448ba3ef8865d7fc.setContent(html_7ffd1f024bc92336391bd85a5e449f48);
#
#
#
#         marker_
