# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4eeee940e92da02a73b1dffa0126337 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4eeee940e92da02a73b1dffa0126337&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4eeee940e92da02a73b1dffa0126337 = L.map(
#                 &quot;map_e4eeee940e92da02a73b1dffa0126337&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16956f72f9f9882c750f5fc6ca505128 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_16956f72f9f9882c750f5fc6ca505128.addTo(map_e4eeee940e92da02a73b1dffa0126337);
#
#
#             var marker_e2c1df4e44ae7460e0c88a4a50c2dee3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e4eeee940e92da02a73b1dffa0126337);
#
#
#         var popup_1cebb1091f14f272128f46550a2ec675 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69f161af16ab3e343596876dbafd637b = $(`&lt;div id=&quot;html_69f161af16ab3e343596876dbafd637b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1cebb1091f14f272128f46550a2ec675.setContent(html_69f161af16ab3e343596876dbafd637b);
#
#
#
#         marker_e2c1df4e44ae7460e0c88a4a50c2dee3.bindPopup(popup_1cebb1091f14f272128f46550a2ec675)
#         ;
#
#
#
#
#             var marker_8d887350be45533d5ce8dd2c34a7bf53 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e4eeee940e92da02a73b1dffa0126337);
#
#
#         var popup_c885067d4b88d8d818a023433494af3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_907c34325122161bab7b2d0077a14001 = $(`&lt;div id=&quot;html_907c34325122161bab7b2d0077a14001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c885067d4b88d8d818a023433494af3e.setContent(html_907c34325122161bab7b2d0077a14001);
#
#
#
#         marker_8d887350be45533d5ce8dd2c34a7bf53.bindPopup(popup_c885067d4b88d8d818a023433494af3e)
#         ;
#
#
#
#
#             var marker_cac484a4f67e9bfc477422e2bb9ed687 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e4eeee940e92da02a73b1dffa0126337);
#
#
#         var popup_70f2d566cb9a0402546aa37265ce89f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_041deb40f25467a9aef4e0b6ef27eba0 = $(`&lt;div id=&quot;html_041deb40f25467a9aef4e0b6ef27eba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_70f2d566cb9a0402546aa37265ce89f9.setContent(html_041deb40f25467a9aef4e0b6ef27eba0);
#
#
#
#         marker_cac484a4f67e9bfc477422e2bb9ed687.bindPopup(popup_70f2d566cb9a0402546aa37265ce89f9)
#         ;
#
#
#
#
#             var marker_de2dafdcb9acd0770de8739a38ec7897 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e4eeee940e92da02a73b1dffa0126337);
#
#
#         var popup_d498bf1e8ac4f94f03e5c716f6e193bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46d9be93dfd4b69600f5ce145efa182d = $(`&lt;div id=&quot;html_46d9be93dfd4b69600f5ce145efa182d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d498bf1e8ac4f94f03e5c716f6e193bc.setContent(html_46d9be93dfd4b69600f5ce145efa182d);
#
#
#
#         marker_de2dafdcb9acd0770de8739a38ec7897.bindPopup(popup_d498bf1e8ac4f94f03e5c716f6e193bc)
#         ;
#
#
#
#
#             var marker_fae6d0f3fe1110dd1c1c9211ec8a75e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e4eeee940e92da02a73b1dffa0126337);
#
#
#         var popup_db614cabe43588f8ab8ac6f1d70f5231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1badcd07ca50ceb8c737e0d880c2360d = $(`&lt;div id=&quot;html_1badcd07ca50ceb8c737e0d880c2360d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_db614cabe43588f8ab8ac6f1d70f5231.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1681d07029572a41fb8057980e55d0ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1681d07029572a41fb8057980e55d0ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1681d07029572a41fb8057980e55d0ed = L.map(
#                 &quot;map_1681d07029572a41fb8057980e55d0ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf9c4cc29040e93d0ebeeaaeed0cd6cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf9c4cc29040e93d0ebeeaaeed0cd6cf.addTo(map_1681d07029572a41fb8057980e55d0ed);
#
#
#             var feature_group_8e86858712705ebbf490235ebb03f110 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6ff24d2a02ee300a34f48a6feeb68bde = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8e86858712705ebbf490235ebb03f110);
#
#
#         var popup_04d9a1addc121d426537e43ead764867 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de012b38e615a6225e78f4300f9bd8f8 = $(`&lt;div id=&quot;html_de012b38e615a6225e78f4300f9bd8f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_04d9a1addc121d426537e43ead764867.setContent(html_de012b38e615a6225e78f4300f9bd8f8);
#
#
#
#         marker_6ff24d2a02ee300a34f48a6feeb68bde.bindPopup(popup_04d9a1addc121d426537e43ead764867)
#         ;
#
#
#
#
#             var marker_856b899aec0a9ac16c0866b70030edd1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8e86858712705ebbf490235ebb03f110);
#
#
#         var popup_7163bb95a52c7b5c3364acd7f9646324 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dbdf5182b50f3d6f60c5b6d9a9fe305 = $(`&lt;div id=&quot;html_0dbdf5182b50f3d6f60c5b6d9a9fe305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7163bb95a52c7b5c3364acd7f9646324.setContent(html_0dbdf5182b50f3d6f60c5b6d9a9fe305);
#
#
#
#         marker_856b899aec0a9ac16c0866b70030edd1.bindPopup(popup_7163bb95a52c7b5c3364acd7f9646324)
#         ;
#
#
#
#
#             var marker_2872ed8279419035bbc7728d739318dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8e86858712705ebbf490235ebb03f110);
#
#
#         var popup_610604b42501abedb6d352de032fc46f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_922ba22c72364298d8b3079c1fa339bc = $(`&lt;div id=&quot;html_922ba22c72364298d8b3079c1fa339bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_610604b42501abedb6d352de032fc46f.setContent(html_922ba22c72364298d8b3079c1fa339bc);
#
#
#
#         marker_2872ed8279419035bbc7728d739318dc.bindPopup(popup_610604b42501abedb6d352de032fc46f)
#         ;
#
#
#
#
#             var marker_ca1ffe7dd86e64f2750c23c822b5069d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8e86858712705ebbf490235ebb03f110);
#
#
#         var popup_9a4a9d9b064208d5df8794310953fa5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_594218bd5ea3b448caa4e6b4deb0bb41 = $(`&lt;div id=&quot;html_594218bd5ea3b448caa4e6b4deb0bb41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9a4a9d9b064208d5df8794310953fa5d.setContent(html_594218bd5ea3b448caa4e6b4deb0bb41);
#
#
#
#         marker_ca1ffe7dd86e64f2750c23c822b5069d.bindPopup(popup_9a4a9d9b064208d5df8794310953fa5d)
#         ;
#
#
#
#
#             var marker_924ea500063ef6d7e6e0e78363823910 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8e86858712705ebbf490235ebb03f110);
#
#
#         var popup_9723f1ff9ed0eb3c699a5c2636bf57bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9d4c06f7e508ebd79aa08e9f913cff8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9d4c06f7e508ebd79aa08e9f913cff8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9d4c06f7e508ebd79aa08e9f913cff8 = L.map(
#                 &quot;map_e9d4c06f7e508ebd79aa08e9f913cff8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9def66a8500c3679e82459022196cb11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9def66a8500c3679e82459022196cb11.addTo(map_e9d4c06f7e508ebd79aa08e9f913cff8);
#
#
#             var feature_group_c22f8b5927c28626659b7a8db78829af = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c22f8b5927c28626659b7a8db78829af.addTo(map_e9d4c06f7e508ebd79aa08e9f913cff8);
#
#
#             var feature_group_sub_group_866fcd61a6961c74abf9bfa90153f9f9 = L.featureGroup.subGroup(
#                 feature_group_c22f8b5927c28626659b7a8db78829af
#             );
#
#
#             var marker_fee440dbbb97edee94fb45c60e6d36c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_866fcd61a6961c74abf9bfa90153f9f9);
#
#
#         var popup_28277bd478ab5799425bdf3bc6c4ca75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d0c2a84d6e367354de3ac88e3074d6a = $(`&lt;div id=&quot;html_5d0c2a84d6e367354de3ac88e3074d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_28277bd478ab5799425bdf3bc6c4ca75.setContent(html_5d0c2a84d6e367354de3ac88e3074d6a);
#
#
#
#         marker_fee440dbbb97edee94fb45c60e6d36c5.bindPopup(popup_28277bd478ab5799425bdf3bc6c4ca75)
#         ;
#
#
#
#
#             var marker_48c2f4becc7ad625780203f05a09e94b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_866fcd61a6961c74abf9bfa90153f9f9);
#
#
#         var popup_75108c82379fcd8630aee635936dbed7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cc0371f5ddad1fedd6a144d51a32eef = $(`&lt;div id=&quot;html_4cc0371f5ddad1fedd6a144d51a32eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_75108c82379fcd8630aee635936dbed7.setContent(html_4cc0371f5ddad1fedd6a144d51a32eef);
#
#
#
#         marker_48c2f4becc7ad625780203f05a09e94b.bindPopup(popup_75108c82379fcd8630aee635936dbed7)
#         ;
#
#
#
#
#             var marker_62dbba96028b17ca482884f6fe1a3108 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_866fcd61a6961c74abf9bfa90153f9f9);
#
#
#         var popup_04467561dfc5d480a90f4a63fb830a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e54a750af8ac98a5d2640b7d64b0760 = $(`&lt;div id=&quot;html_4e54a750af8ac98a5d2640b7d64b0760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_04467561dfc5d480a90f4a63fb830a99.setContent(html_4e54a750af8ac98a5d2640b7d64b0760);
#
#
#
#         marker_62dbba96028b17ca482884f6fe1a3108.bindPopup(popup_04467561dfc5d480a90f4a63fb830a99)
#         ;
#
#
#
#
#             var marker_bb80944560273852f9801ea498a99c01 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_866fcd61a6961c74abf9bfa90153f9f9);
#
#
#         var popup_516dfd4d84405d6e00732080fe0a00e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd7603ca859687fe4257ad0b30970cf = $(`&lt;div id=&quot;html_9bd7603ca859687fe4257ad0b30970cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_516dfd4d84405d6e00732080fe0a00e4.setContent(html_9bd7603ca859687fe4257ad0b30970cf);
#
#
#
#         marker_
