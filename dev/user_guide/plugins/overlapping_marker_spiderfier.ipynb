# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0334c93c3ad9efb9e91bf03ede2a0736 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0334c93c3ad9efb9e91bf03ede2a0736&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0334c93c3ad9efb9e91bf03ede2a0736 = L.map(
#                 &quot;map_0334c93c3ad9efb9e91bf03ede2a0736&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56744aa8891e766c9e36e01a11dc8f40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56744aa8891e766c9e36e01a11dc8f40.addTo(map_0334c93c3ad9efb9e91bf03ede2a0736);
#
#
#             var marker_2511569d79a8819c146b54f16310ed03 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0334c93c3ad9efb9e91bf03ede2a0736);
#
#
#         var popup_52c2794b85e9748fb45b168ec5eca1cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1b097233e8e50057dcdbc68f2479337 = $(`&lt;div id=&quot;html_e1b097233e8e50057dcdbc68f2479337&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_52c2794b85e9748fb45b168ec5eca1cd.setContent(html_e1b097233e8e50057dcdbc68f2479337);
#
#
#
#         marker_2511569d79a8819c146b54f16310ed03.bindPopup(popup_52c2794b85e9748fb45b168ec5eca1cd)
#         ;
#
#
#
#
#             var marker_19d57c4ff9d3aec72ca233e3b2033a40 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0334c93c3ad9efb9e91bf03ede2a0736);
#
#
#         var popup_107bf226444b9286975ec7baaa6aadfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c51cd8b8979fae12bb6679457cd43e5e = $(`&lt;div id=&quot;html_c51cd8b8979fae12bb6679457cd43e5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_107bf226444b9286975ec7baaa6aadfc.setContent(html_c51cd8b8979fae12bb6679457cd43e5e);
#
#
#
#         marker_19d57c4ff9d3aec72ca233e3b2033a40.bindPopup(popup_107bf226444b9286975ec7baaa6aadfc)
#         ;
#
#
#
#
#             var marker_2d435b773356082dc11242760ae582bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0334c93c3ad9efb9e91bf03ede2a0736);
#
#
#         var popup_405e657fba8194b63c09dc68a571885e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5448b9021a4c5b7e244c3cdff356e497 = $(`&lt;div id=&quot;html_5448b9021a4c5b7e244c3cdff356e497&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_405e657fba8194b63c09dc68a571885e.setContent(html_5448b9021a4c5b7e244c3cdff356e497);
#
#
#
#         marker_2d435b773356082dc11242760ae582bc.bindPopup(popup_405e657fba8194b63c09dc68a571885e)
#         ;
#
#
#
#
#             var marker_983747a0bb8ca1dbb828f1a21d043881 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0334c93c3ad9efb9e91bf03ede2a0736);
#
#
#         var popup_901fb4e9c524a9a4f3b74fc715ea6e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bd8599b4606733b8f6839313defc2a1 = $(`&lt;div id=&quot;html_0bd8599b4606733b8f6839313defc2a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_901fb4e9c524a9a4f3b74fc715ea6e6f.setContent(html_0bd8599b4606733b8f6839313defc2a1);
#
#
#
#         marker_983747a0bb8ca1dbb828f1a21d043881.bindPopup(popup_901fb4e9c524a9a4f3b74fc715ea6e6f)
#         ;
#
#
#
#
#             var marker_55bcab7ebe104b8ed5214cef8f41109d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0334c93c3ad9efb9e91bf03ede2a0736);
#
#
#         var popup_10ae4fd9f62c05af9d0df39618522572 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05845aa27ce92db9960f735eb1999a8a = $(`&lt;div id=&quot;html_05845aa27ce92db9960f735eb1999a8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_10ae4fd9f62c05af9d0df39618522572.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f28613bb157b63cda6716d14f095e0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f28613bb157b63cda6716d14f095e0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f28613bb157b63cda6716d14f095e0e = L.map(
#                 &quot;map_2f28613bb157b63cda6716d14f095e0e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1bf7a0ba0e6cc0e739de33ad691c34b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1bf7a0ba0e6cc0e739de33ad691c34b.addTo(map_2f28613bb157b63cda6716d14f095e0e);
#
#
#             var feature_group_04571f546d74bc28a34cd2f623d90341 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_39bcaa6e81c9ba7315a4af12e3b64d00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_04571f546d74bc28a34cd2f623d90341);
#
#
#         var popup_fff8c88c8d0ed571f7faea0b8d13f90d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf545bd2efb23953a6f16a950ea5e5ff = $(`&lt;div id=&quot;html_cf545bd2efb23953a6f16a950ea5e5ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fff8c88c8d0ed571f7faea0b8d13f90d.setContent(html_cf545bd2efb23953a6f16a950ea5e5ff);
#
#
#
#         marker_39bcaa6e81c9ba7315a4af12e3b64d00.bindPopup(popup_fff8c88c8d0ed571f7faea0b8d13f90d)
#         ;
#
#
#
#
#             var marker_6dc011d08f15662754607139361cf746 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_04571f546d74bc28a34cd2f623d90341);
#
#
#         var popup_e9bfc4ed0cfe70e0d325a93a7675e4c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d283254df775e908728145b12986ed10 = $(`&lt;div id=&quot;html_d283254df775e908728145b12986ed10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e9bfc4ed0cfe70e0d325a93a7675e4c0.setContent(html_d283254df775e908728145b12986ed10);
#
#
#
#         marker_6dc011d08f15662754607139361cf746.bindPopup(popup_e9bfc4ed0cfe70e0d325a93a7675e4c0)
#         ;
#
#
#
#
#             var marker_7fe211dc8eb16f9db3cee97d9987f8de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_04571f546d74bc28a34cd2f623d90341);
#
#
#         var popup_caf9dcbefb46df155d525d8d39da7952 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9cb9af49415b6a8da7cc8e3b3678faa = $(`&lt;div id=&quot;html_a9cb9af49415b6a8da7cc8e3b3678faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_caf9dcbefb46df155d525d8d39da7952.setContent(html_a9cb9af49415b6a8da7cc8e3b3678faa);
#
#
#
#         marker_7fe211dc8eb16f9db3cee97d9987f8de.bindPopup(popup_caf9dcbefb46df155d525d8d39da7952)
#         ;
#
#
#
#
#             var marker_3213c206bc647199c6e602bf273769aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_04571f546d74bc28a34cd2f623d90341);
#
#
#         var popup_b4e8e5e534bdde722afffe8db08f7f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ced63fc685cec971cd436520f9a6aba = $(`&lt;div id=&quot;html_3ced63fc685cec971cd436520f9a6aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b4e8e5e534bdde722afffe8db08f7f8b.setContent(html_3ced63fc685cec971cd436520f9a6aba);
#
#
#
#         marker_3213c206bc647199c6e602bf273769aa.bindPopup(popup_b4e8e5e534bdde722afffe8db08f7f8b)
#         ;
#
#
#
#
#             var marker_92347541381c83baf023aad80997d475 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_04571f546d74bc28a34cd2f623d90341);
#
#
#         var popup_2f7901d42d392f0aa5fe680b6eb60144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fcba9c660dfa1b6f2d047ff17277e7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fcba9c660dfa1b6f2d047ff17277e7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fcba9c660dfa1b6f2d047ff17277e7c = L.map(
#                 &quot;map_1fcba9c660dfa1b6f2d047ff17277e7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb047a25e809fb870923173685d34a71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb047a25e809fb870923173685d34a71.addTo(map_1fcba9c660dfa1b6f2d047ff17277e7c);
#
#
#             var feature_group_5488653b6602846c6a0ba9070e1810cd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5488653b6602846c6a0ba9070e1810cd.addTo(map_1fcba9c660dfa1b6f2d047ff17277e7c);
#
#
#             var feature_group_sub_group_c370aa9616359ed6351a0399ea87ef06 = L.featureGroup.subGroup(
#                 feature_group_5488653b6602846c6a0ba9070e1810cd
#             );
#
#
#             var marker_db5237460cf1e2d737632f8fa3093c1e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c370aa9616359ed6351a0399ea87ef06);
#
#
#         var popup_8fe50a5844c59feb95e415b2257f17cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1438d47b619ac1f7913b69922a599b37 = $(`&lt;div id=&quot;html_1438d47b619ac1f7913b69922a599b37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8fe50a5844c59feb95e415b2257f17cc.setContent(html_1438d47b619ac1f7913b69922a599b37);
#
#
#
#         marker_db5237460cf1e2d737632f8fa3093c1e.bindPopup(popup_8fe50a5844c59feb95e415b2257f17cc)
#         ;
#
#
#
#
#             var marker_b511aa297099dcadb238439a5c44618b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c370aa9616359ed6351a0399ea87ef06);
#
#
#         var popup_b6d89ff428b10b50674374d2e1c9dc03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_147b9f45af852630013e7607e0bc412b = $(`&lt;div id=&quot;html_147b9f45af852630013e7607e0bc412b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b6d89ff428b10b50674374d2e1c9dc03.setContent(html_147b9f45af852630013e7607e0bc412b);
#
#
#
#         marker_b511aa297099dcadb238439a5c44618b.bindPopup(popup_b6d89ff428b10b50674374d2e1c9dc03)
#         ;
#
#
#
#
#             var marker_5b863006a6742a9860fc884bdebf17c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c370aa9616359ed6351a0399ea87ef06);
#
#
#         var popup_7a37d5360cfb032a74a0bda8eb97bda7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13fc30ee48ec87a98e2594f2c0991fd9 = $(`&lt;div id=&quot;html_13fc30ee48ec87a98e2594f2c0991fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7a37d5360cfb032a74a0bda8eb97bda7.setContent(html_13fc30ee48ec87a98e2594f2c0991fd9);
#
#
#
#         marker_5b863006a6742a9860fc884bdebf17c3.bindPopup(popup_7a37d5360cfb032a74a0bda8eb97bda7)
#         ;
#
#
#
#
#             var marker_edbb8fa4d28bbc7642712331c8ce8697 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c370aa9616359ed6351a0399ea87ef06);
#
#
#         var popup_1b63d5c6fbe202cfc96a199e1b54887f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36874cc217fdf97593dc387a85606516 = $(`&lt;div id=&quot;html_36874cc217fdf97593dc387a85606516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1b63d5c6fbe202cfc96a199e1b54887f.setContent(html_36874cc217fdf97593dc387a85606516);
#
#
#
#         marker_
