# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2f29741a434de5744772f612c7868d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2f29741a434de5744772f612c7868d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2f29741a434de5744772f612c7868d9 = L.map(
#                 &quot;map_f2f29741a434de5744772f612c7868d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a32c1976d9d084fa9c6c5e3b21ad19ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a32c1976d9d084fa9c6c5e3b21ad19ed.addTo(map_f2f29741a434de5744772f612c7868d9);
#
#
#             var marker_e25bf2450d56afd5414413d570b704ba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f2f29741a434de5744772f612c7868d9);
#
#
#         var popup_21a4526c405c47a39b161e2bf6d4060b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b7b731ba5e4f5cd997253254e3ea8b7 = $(`&lt;div id=&quot;html_9b7b731ba5e4f5cd997253254e3ea8b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_21a4526c405c47a39b161e2bf6d4060b.setContent(html_9b7b731ba5e4f5cd997253254e3ea8b7);
#
#
#
#         marker_e25bf2450d56afd5414413d570b704ba.bindPopup(popup_21a4526c405c47a39b161e2bf6d4060b)
#         ;
#
#
#
#
#             var marker_7521d2d146495e4b66227658cfaff805 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f2f29741a434de5744772f612c7868d9);
#
#
#         var popup_6dc1d12bef402ab5eda37586d3ee2ae4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_928b0a9e9270005fdc6685efdb0843a6 = $(`&lt;div id=&quot;html_928b0a9e9270005fdc6685efdb0843a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6dc1d12bef402ab5eda37586d3ee2ae4.setContent(html_928b0a9e9270005fdc6685efdb0843a6);
#
#
#
#         marker_7521d2d146495e4b66227658cfaff805.bindPopup(popup_6dc1d12bef402ab5eda37586d3ee2ae4)
#         ;
#
#
#
#
#             var marker_1b7f5ffd5ae6b7d1dd8690960ea8318a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f2f29741a434de5744772f612c7868d9);
#
#
#         var popup_de44286503cbedef41b0bd9a3521a87c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0832afd12d92950a28301c2fd61ade9d = $(`&lt;div id=&quot;html_0832afd12d92950a28301c2fd61ade9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_de44286503cbedef41b0bd9a3521a87c.setContent(html_0832afd12d92950a28301c2fd61ade9d);
#
#
#
#         marker_1b7f5ffd5ae6b7d1dd8690960ea8318a.bindPopup(popup_de44286503cbedef41b0bd9a3521a87c)
#         ;
#
#
#
#
#             var marker_34954b6f5d0787381c1241cf9a401c63 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f2f29741a434de5744772f612c7868d9);
#
#
#         var popup_b74f946f876a5cd07e2d1f7dc7516bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98dce047062da8b34762084d6867a71d = $(`&lt;div id=&quot;html_98dce047062da8b34762084d6867a71d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b74f946f876a5cd07e2d1f7dc7516bb5.setContent(html_98dce047062da8b34762084d6867a71d);
#
#
#
#         marker_34954b6f5d0787381c1241cf9a401c63.bindPopup(popup_b74f946f876a5cd07e2d1f7dc7516bb5)
#         ;
#
#
#
#
#             var marker_7c01deb2a7369fd4d873186264680fc6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f2f29741a434de5744772f612c7868d9);
#
#
#         var popup_006452524296102d7aa99b7778e7244f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bfed87e9b133e109f24fd11c2b27ab4 = $(`&lt;div id=&quot;html_3bfed87e9b133e109f24fd11c2b27ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_006452524296102d7aa99b7778e7244f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b428c9f6f331d4f69136d0b755c07839 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b428c9f6f331d4f69136d0b755c07839&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b428c9f6f331d4f69136d0b755c07839 = L.map(
#                 &quot;map_b428c9f6f331d4f69136d0b755c07839&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8005652643677e37d4f78dfa72cecebf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8005652643677e37d4f78dfa72cecebf.addTo(map_b428c9f6f331d4f69136d0b755c07839);
#
#
#             var feature_group_fd6c8c6da817d4a8aac6c33aebee2dd7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f555a822eab24ee4d64252b5e8423035 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fd6c8c6da817d4a8aac6c33aebee2dd7);
#
#
#         var popup_986b6f51b79f0ff8b2dbd915eb5618cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f1705b854e66ee77f8944c28802ded6 = $(`&lt;div id=&quot;html_2f1705b854e66ee77f8944c28802ded6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_986b6f51b79f0ff8b2dbd915eb5618cf.setContent(html_2f1705b854e66ee77f8944c28802ded6);
#
#
#
#         marker_f555a822eab24ee4d64252b5e8423035.bindPopup(popup_986b6f51b79f0ff8b2dbd915eb5618cf)
#         ;
#
#
#
#
#             var marker_5735aaf5e50db7fab8fa4731e0406e7c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fd6c8c6da817d4a8aac6c33aebee2dd7);
#
#
#         var popup_3de828618c33031310a8d76202dda65a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ee15f1ad9649f2e5facb637124a4742 = $(`&lt;div id=&quot;html_3ee15f1ad9649f2e5facb637124a4742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3de828618c33031310a8d76202dda65a.setContent(html_3ee15f1ad9649f2e5facb637124a4742);
#
#
#
#         marker_5735aaf5e50db7fab8fa4731e0406e7c.bindPopup(popup_3de828618c33031310a8d76202dda65a)
#         ;
#
#
#
#
#             var marker_d6fe4bea46189b3bbfcade5de92c7d24 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fd6c8c6da817d4a8aac6c33aebee2dd7);
#
#
#         var popup_7321204714402c6d3c23c2711ef9d487 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_179f0439edfef1f46210fcbeb6be68e7 = $(`&lt;div id=&quot;html_179f0439edfef1f46210fcbeb6be68e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7321204714402c6d3c23c2711ef9d487.setContent(html_179f0439edfef1f46210fcbeb6be68e7);
#
#
#
#         marker_d6fe4bea46189b3bbfcade5de92c7d24.bindPopup(popup_7321204714402c6d3c23c2711ef9d487)
#         ;
#
#
#
#
#             var marker_0c666c46ec272181ea836a63ec7697e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fd6c8c6da817d4a8aac6c33aebee2dd7);
#
#
#         var popup_73c17382c34aad94b418504fa4dd826f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d143535c81d3d564aa0201636f366bf = $(`&lt;div id=&quot;html_2d143535c81d3d564aa0201636f366bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_73c17382c34aad94b418504fa4dd826f.setContent(html_2d143535c81d3d564aa0201636f366bf);
#
#
#
#         marker_0c666c46ec272181ea836a63ec7697e3.bindPopup(popup_73c17382c34aad94b418504fa4dd826f)
#         ;
#
#
#
#
#             var marker_a7f9a138942f37a7187eac42c86cabcd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fd6c8c6da817d4a8aac6c33aebee2dd7);
#
#
#         var popup_8c8c54994f9b3672dc805133f7b20a88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7afb81402d93feac8fcb2ea9c0a2acaf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7afb81402d93feac8fcb2ea9c0a2acaf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7afb81402d93feac8fcb2ea9c0a2acaf = L.map(
#                 &quot;map_7afb81402d93feac8fcb2ea9c0a2acaf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63096847e31cad621c3f5d32a1ebb300 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63096847e31cad621c3f5d32a1ebb300.addTo(map_7afb81402d93feac8fcb2ea9c0a2acaf);
#
#
#             var feature_group_dc77c4477c47ac948952ee8aeda9e48e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dc77c4477c47ac948952ee8aeda9e48e.addTo(map_7afb81402d93feac8fcb2ea9c0a2acaf);
#
#
#             var feature_group_sub_group_487b602e0595da61c9d4223233ad7ccb = L.featureGroup.subGroup(
#                 feature_group_dc77c4477c47ac948952ee8aeda9e48e
#             );
#
#
#             var marker_a7482f764bd5e782cdf22e21a79eaba1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_487b602e0595da61c9d4223233ad7ccb);
#
#
#         var popup_ebd4eb35d2b6d507ebae5115ebac18ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e28eb8788ab937d86a38f58a314b063 = $(`&lt;div id=&quot;html_2e28eb8788ab937d86a38f58a314b063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ebd4eb35d2b6d507ebae5115ebac18ed.setContent(html_2e28eb8788ab937d86a38f58a314b063);
#
#
#
#         marker_a7482f764bd5e782cdf22e21a79eaba1.bindPopup(popup_ebd4eb35d2b6d507ebae5115ebac18ed)
#         ;
#
#
#
#
#             var marker_1695bde66ef29540d22600cf9f58715c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_487b602e0595da61c9d4223233ad7ccb);
#
#
#         var popup_417e62ba88eb53d217103db47411f6f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfaef01abe3a85119c10c34f5000d8b6 = $(`&lt;div id=&quot;html_cfaef01abe3a85119c10c34f5000d8b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_417e62ba88eb53d217103db47411f6f1.setContent(html_cfaef01abe3a85119c10c34f5000d8b6);
#
#
#
#         marker_1695bde66ef29540d22600cf9f58715c.bindPopup(popup_417e62ba88eb53d217103db47411f6f1)
#         ;
#
#
#
#
#             var marker_26e514ba3d5c4c6142729e5621b0e2b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_487b602e0595da61c9d4223233ad7ccb);
#
#
#         var popup_4a0f0860f77b1dcb515861cfaf09db76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abdf87f5700986265b9913e9ed821291 = $(`&lt;div id=&quot;html_abdf87f5700986265b9913e9ed821291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4a0f0860f77b1dcb515861cfaf09db76.setContent(html_abdf87f5700986265b9913e9ed821291);
#
#
#
#         marker_26e514ba3d5c4c6142729e5621b0e2b3.bindPopup(popup_4a0f0860f77b1dcb515861cfaf09db76)
#         ;
#
#
#
#
#             var marker_13a36c4b82a1d0572fba61f9345849d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_487b602e0595da61c9d4223233ad7ccb);
#
#
#         var popup_f4879f2a38d10afb6e8a94d716a4442d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e31a02225dd90fdc0d2e1c0f6c0b3b8e = $(`&lt;div id=&quot;html_e31a02225dd90fdc0d2e1c0f6c0b3b8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f4879f2a38d10afb6e8a94d716a4442d.setContent(html_e31a02225dd90fdc0d2e1c0f6c0b3b8e);
#
#
#
#         marker_
