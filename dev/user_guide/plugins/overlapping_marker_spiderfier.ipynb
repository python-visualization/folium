# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef217a894c86154b70c036fc75214ca6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef217a894c86154b70c036fc75214ca6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef217a894c86154b70c036fc75214ca6 = L.map(
#                 &quot;map_ef217a894c86154b70c036fc75214ca6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35163cb1b2a602b578de372e316d1828 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35163cb1b2a602b578de372e316d1828.addTo(map_ef217a894c86154b70c036fc75214ca6);
#
#
#             var marker_e1c117a4e047d82de75f333a62d8c611 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ef217a894c86154b70c036fc75214ca6);
#
#
#         var popup_bf72f9320e34671631ed75b611bec740 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_800744fd99a3e67ead09a8948648c77a = $(`&lt;div id=&quot;html_800744fd99a3e67ead09a8948648c77a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bf72f9320e34671631ed75b611bec740.setContent(html_800744fd99a3e67ead09a8948648c77a);
#
#
#
#         marker_e1c117a4e047d82de75f333a62d8c611.bindPopup(popup_bf72f9320e34671631ed75b611bec740)
#         ;
#
#
#
#
#             var marker_10fdfe389724cdf25ccd7f8d3baf4edf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ef217a894c86154b70c036fc75214ca6);
#
#
#         var popup_61d63b214470200ab96c54f33eaf6c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_055d853550dfefb468c7b56377c0f981 = $(`&lt;div id=&quot;html_055d853550dfefb468c7b56377c0f981&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_61d63b214470200ab96c54f33eaf6c9f.setContent(html_055d853550dfefb468c7b56377c0f981);
#
#
#
#         marker_10fdfe389724cdf25ccd7f8d3baf4edf.bindPopup(popup_61d63b214470200ab96c54f33eaf6c9f)
#         ;
#
#
#
#
#             var marker_5024cd117639d1297535fc301fc350f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ef217a894c86154b70c036fc75214ca6);
#
#
#         var popup_d103e9ab0a96c955eadbf7723d12c4ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_562e33c11d03970aa73c118757aa03ce = $(`&lt;div id=&quot;html_562e33c11d03970aa73c118757aa03ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d103e9ab0a96c955eadbf7723d12c4ed.setContent(html_562e33c11d03970aa73c118757aa03ce);
#
#
#
#         marker_5024cd117639d1297535fc301fc350f0.bindPopup(popup_d103e9ab0a96c955eadbf7723d12c4ed)
#         ;
#
#
#
#
#             var marker_387b567bb0b0a45ea0fd29f00a678c24 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ef217a894c86154b70c036fc75214ca6);
#
#
#         var popup_a8e4278a1d757c8c524f931bd03dd81d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d515c802d8aa762a64c39c98d4e4efa = $(`&lt;div id=&quot;html_0d515c802d8aa762a64c39c98d4e4efa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a8e4278a1d757c8c524f931bd03dd81d.setContent(html_0d515c802d8aa762a64c39c98d4e4efa);
#
#
#
#         marker_387b567bb0b0a45ea0fd29f00a678c24.bindPopup(popup_a8e4278a1d757c8c524f931bd03dd81d)
#         ;
#
#
#
#
#             var marker_a727b10c6477a939b800d9e363ec989c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ef217a894c86154b70c036fc75214ca6);
#
#
#         var popup_9ea3b2f45d53352ea546cddad8006ec9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab93b74e1d9e3a788728b04cda58924a = $(`&lt;div id=&quot;html_ab93b74e1d9e3a788728b04cda58924a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9ea3b2f45d53352ea546cddad8006ec9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_773203c5688272f6ab17171b19a2a90e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_773203c5688272f6ab17171b19a2a90e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_773203c5688272f6ab17171b19a2a90e = L.map(
#                 &quot;map_773203c5688272f6ab17171b19a2a90e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4895494aeae5ef78043f1b1c4a2a7a2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4895494aeae5ef78043f1b1c4a2a7a2b.addTo(map_773203c5688272f6ab17171b19a2a90e);
#
#
#             var feature_group_03395c68161077adc7553a5424fcbe4b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b9dc7497641b5121651c1fb97a3a54e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_03395c68161077adc7553a5424fcbe4b);
#
#
#         var popup_3dd28fc26992c2a8f3a5fc7d8e7bb58f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7b7d24aad4b733140aa29bcccbd05c0 = $(`&lt;div id=&quot;html_b7b7d24aad4b733140aa29bcccbd05c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3dd28fc26992c2a8f3a5fc7d8e7bb58f.setContent(html_b7b7d24aad4b733140aa29bcccbd05c0);
#
#
#
#         marker_b9dc7497641b5121651c1fb97a3a54e9.bindPopup(popup_3dd28fc26992c2a8f3a5fc7d8e7bb58f)
#         ;
#
#
#
#
#             var marker_0f878fed95ee3a197d062aa96728ecab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_03395c68161077adc7553a5424fcbe4b);
#
#
#         var popup_ab6e01fcda7991c3569c15e440239b61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40ea9a25c18f1998763a6e153bebd72c = $(`&lt;div id=&quot;html_40ea9a25c18f1998763a6e153bebd72c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ab6e01fcda7991c3569c15e440239b61.setContent(html_40ea9a25c18f1998763a6e153bebd72c);
#
#
#
#         marker_0f878fed95ee3a197d062aa96728ecab.bindPopup(popup_ab6e01fcda7991c3569c15e440239b61)
#         ;
#
#
#
#
#             var marker_1e50368bba20bf3eb886f10679ce4a1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_03395c68161077adc7553a5424fcbe4b);
#
#
#         var popup_523758b39d85538670df064ab3c94844 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60ca025387059c57eb86f536dcff73ae = $(`&lt;div id=&quot;html_60ca025387059c57eb86f536dcff73ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_523758b39d85538670df064ab3c94844.setContent(html_60ca025387059c57eb86f536dcff73ae);
#
#
#
#         marker_1e50368bba20bf3eb886f10679ce4a1b.bindPopup(popup_523758b39d85538670df064ab3c94844)
#         ;
#
#
#
#
#             var marker_9e2b613895514ecb35430cd2c864101c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_03395c68161077adc7553a5424fcbe4b);
#
#
#         var popup_fe3a4d75cbfe5ba97cea04524d119dee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a98785f4186c950d717cacbc5fd69c5 = $(`&lt;div id=&quot;html_0a98785f4186c950d717cacbc5fd69c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fe3a4d75cbfe5ba97cea04524d119dee.setContent(html_0a98785f4186c950d717cacbc5fd69c5);
#
#
#
#         marker_9e2b613895514ecb35430cd2c864101c.bindPopup(popup_fe3a4d75cbfe5ba97cea04524d119dee)
#         ;
#
#
#
#
#             var marker_100d1ce6570715e12813dbf50fb45b88 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_03395c68161077adc7553a5424fcbe4b);
#
#
#         var popup_80a63031b83c350e9dedb5d1c593cd8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57f5b6799f63364811b17939008ee770 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57f5b6799f63364811b17939008ee770&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57f5b6799f63364811b17939008ee770 = L.map(
#                 &quot;map_57f5b6799f63364811b17939008ee770&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3dbe46b6ac31c573ba96581d4c45dda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3dbe46b6ac31c573ba96581d4c45dda.addTo(map_57f5b6799f63364811b17939008ee770);
#
#
#             var feature_group_0b66f92ae86c5d995c635cf7219e9c15 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0b66f92ae86c5d995c635cf7219e9c15.addTo(map_57f5b6799f63364811b17939008ee770);
#
#
#             var feature_group_sub_group_0cd8a844a810a1cb8f3dc020ec83b4fa = L.featureGroup.subGroup(
#                 feature_group_0b66f92ae86c5d995c635cf7219e9c15
#             );
#
#
#             var marker_be29ad6b7802d23db1316fc262861dbf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0cd8a844a810a1cb8f3dc020ec83b4fa);
#
#
#         var popup_f17f876b84174b91f3d26a4b6a1e3c45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_486a3d980ec70f0fa8c8327652a63989 = $(`&lt;div id=&quot;html_486a3d980ec70f0fa8c8327652a63989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f17f876b84174b91f3d26a4b6a1e3c45.setContent(html_486a3d980ec70f0fa8c8327652a63989);
#
#
#
#         marker_be29ad6b7802d23db1316fc262861dbf.bindPopup(popup_f17f876b84174b91f3d26a4b6a1e3c45)
#         ;
#
#
#
#
#             var marker_9093b56136e662541e3d41665c4d16c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0cd8a844a810a1cb8f3dc020ec83b4fa);
#
#
#         var popup_88bcc7a05c0f04aa8ed96375517ed55f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_286040f0b5a14675634f937f2af885f3 = $(`&lt;div id=&quot;html_286040f0b5a14675634f937f2af885f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_88bcc7a05c0f04aa8ed96375517ed55f.setContent(html_286040f0b5a14675634f937f2af885f3);
#
#
#
#         marker_9093b56136e662541e3d41665c4d16c1.bindPopup(popup_88bcc7a05c0f04aa8ed96375517ed55f)
#         ;
#
#
#
#
#             var marker_0fe27a43b1ce51b9fecf502ae49f9846 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0cd8a844a810a1cb8f3dc020ec83b4fa);
#
#
#         var popup_5e569e850b53a222149068953f92d6e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7aa78ce5d95bc946d027417d8e8615a = $(`&lt;div id=&quot;html_b7aa78ce5d95bc946d027417d8e8615a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5e569e850b53a222149068953f92d6e7.setContent(html_b7aa78ce5d95bc946d027417d8e8615a);
#
#
#
#         marker_0fe27a43b1ce51b9fecf502ae49f9846.bindPopup(popup_5e569e850b53a222149068953f92d6e7)
#         ;
#
#
#
#
#             var marker_757cf773dfd07adfb7b4ded753f26567 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0cd8a844a810a1cb8f3dc020ec83b4fa);
#
#
#         var popup_efa9579ce82e9138bc523e420ea5af7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f5d7127bd84add8f2c5868f9d945ccb = $(`&lt;div id=&quot;html_9f5d7127bd84add8f2c5868f9d945ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_efa9579ce82e9138bc523e420ea5af7e.setContent(html_9f5d7127bd84add8f2c5868f9d945ccb);
#
#
#
#         marker_
