# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a087a89d4e4e832196a592f1dd8892d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a087a89d4e4e832196a592f1dd8892d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a087a89d4e4e832196a592f1dd8892d8 = L.map(
#                 &quot;map_a087a89d4e4e832196a592f1dd8892d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e003f7c5c3446a26f098f8b5123b63db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e003f7c5c3446a26f098f8b5123b63db.addTo(map_a087a89d4e4e832196a592f1dd8892d8);
#
#
#             var marker_1e4f4229d9c3b7d04d3f26b608b9ffbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a087a89d4e4e832196a592f1dd8892d8);
#
#
#         var popup_3c808004f4104987a50601976a895447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7bb10995b5d3fa49f68f7f5dacbac32 = $(`&lt;div id=&quot;html_e7bb10995b5d3fa49f68f7f5dacbac32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c808004f4104987a50601976a895447.setContent(html_e7bb10995b5d3fa49f68f7f5dacbac32);
#
#
#
#         marker_1e4f4229d9c3b7d04d3f26b608b9ffbd.bindPopup(popup_3c808004f4104987a50601976a895447)
#         ;
#
#
#
#
#             var marker_34099d62cc6410c9c58310b7923cf71d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a087a89d4e4e832196a592f1dd8892d8);
#
#
#         var popup_113c1d86f22fbed28f8b788ea38cc5d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96c13d99d5e1d9c7e9a778cf5365d079 = $(`&lt;div id=&quot;html_96c13d99d5e1d9c7e9a778cf5365d079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_113c1d86f22fbed28f8b788ea38cc5d5.setContent(html_96c13d99d5e1d9c7e9a778cf5365d079);
#
#
#
#         marker_34099d62cc6410c9c58310b7923cf71d.bindPopup(popup_113c1d86f22fbed28f8b788ea38cc5d5)
#         ;
#
#
#
#
#             var marker_f8ff6369eae95e522beb4e3f8dc92ea9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a087a89d4e4e832196a592f1dd8892d8);
#
#
#         var popup_9b7d7adda073f3056e2f337bdfc1a173 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d3ab58d854139e9dbef571111fa587 = $(`&lt;div id=&quot;html_c7d3ab58d854139e9dbef571111fa587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9b7d7adda073f3056e2f337bdfc1a173.setContent(html_c7d3ab58d854139e9dbef571111fa587);
#
#
#
#         marker_f8ff6369eae95e522beb4e3f8dc92ea9.bindPopup(popup_9b7d7adda073f3056e2f337bdfc1a173)
#         ;
#
#
#
#
#             var marker_56f0ab5274df0554de3226ac889a5bbc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a087a89d4e4e832196a592f1dd8892d8);
#
#
#         var popup_1078ca093378256dccc858127f79820d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f041ca65b0418bc51abf65137ae9e460 = $(`&lt;div id=&quot;html_f041ca65b0418bc51abf65137ae9e460&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1078ca093378256dccc858127f79820d.setContent(html_f041ca65b0418bc51abf65137ae9e460);
#
#
#
#         marker_56f0ab5274df0554de3226ac889a5bbc.bindPopup(popup_1078ca093378256dccc858127f79820d)
#         ;
#
#
#
#
#             var marker_74c7b8fc0485f7547ea1f4cf0e96aa64 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a087a89d4e4e832196a592f1dd8892d8);
#
#
#         var popup_ed08ab44675565c5156ec944d4e05aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf58650b1e411cce2f9fb283523402ad = $(`&lt;div id=&quot;html_bf58650b1e411cce2f9fb283523402ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ed08ab44675565c5156ec944d4e05aee.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6702978c08122dfbf79f4e17ca35162 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6702978c08122dfbf79f4e17ca35162&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6702978c08122dfbf79f4e17ca35162 = L.map(
#                 &quot;map_c6702978c08122dfbf79f4e17ca35162&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_328d7ce224bf8060ddf30fb886ebaf8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_328d7ce224bf8060ddf30fb886ebaf8d.addTo(map_c6702978c08122dfbf79f4e17ca35162);
#
#
#             var feature_group_96947604657d9eff02a8d4d582339c2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d209eb933514b2b1788a3d8417dc707a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_96947604657d9eff02a8d4d582339c2d);
#
#
#         var popup_3ac4d8e53e103c2fb0226d071ca529f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_631429811b536dde8f0833f53eb61e2a = $(`&lt;div id=&quot;html_631429811b536dde8f0833f53eb61e2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3ac4d8e53e103c2fb0226d071ca529f4.setContent(html_631429811b536dde8f0833f53eb61e2a);
#
#
#
#         marker_d209eb933514b2b1788a3d8417dc707a.bindPopup(popup_3ac4d8e53e103c2fb0226d071ca529f4)
#         ;
#
#
#
#
#             var marker_e9c5d2d9dd377fc4a6f724e88100c06f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_96947604657d9eff02a8d4d582339c2d);
#
#
#         var popup_825d5ac690e4a9cf57567617a355a05f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74362cafdfd7037cdbfc124ebf9926f1 = $(`&lt;div id=&quot;html_74362cafdfd7037cdbfc124ebf9926f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_825d5ac690e4a9cf57567617a355a05f.setContent(html_74362cafdfd7037cdbfc124ebf9926f1);
#
#
#
#         marker_e9c5d2d9dd377fc4a6f724e88100c06f.bindPopup(popup_825d5ac690e4a9cf57567617a355a05f)
#         ;
#
#
#
#
#             var marker_2c1d49397800d031164618b4b1c55adf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_96947604657d9eff02a8d4d582339c2d);
#
#
#         var popup_acbc1bac234f6aafda3a165106fa8234 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5daac4a7239b19eed4f0aae5331de38a = $(`&lt;div id=&quot;html_5daac4a7239b19eed4f0aae5331de38a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_acbc1bac234f6aafda3a165106fa8234.setContent(html_5daac4a7239b19eed4f0aae5331de38a);
#
#
#
#         marker_2c1d49397800d031164618b4b1c55adf.bindPopup(popup_acbc1bac234f6aafda3a165106fa8234)
#         ;
#
#
#
#
#             var marker_7506f4d6a6d901bbceb2d0cd27eaaf76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_96947604657d9eff02a8d4d582339c2d);
#
#
#         var popup_af89494e8deb38f625b9a9b72d888f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bf0a41afc0a7d98c61ea7a2bbf8e702 = $(`&lt;div id=&quot;html_3bf0a41afc0a7d98c61ea7a2bbf8e702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_af89494e8deb38f625b9a9b72d888f45.setContent(html_3bf0a41afc0a7d98c61ea7a2bbf8e702);
#
#
#
#         marker_7506f4d6a6d901bbceb2d0cd27eaaf76.bindPopup(popup_af89494e8deb38f625b9a9b72d888f45)
#         ;
#
#
#
#
#             var marker_d890ab1a727a041b7fb190610d4e2a27 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_96947604657d9eff02a8d4d582339c2d);
#
#
#         var popup_f5146379233dd4433dc43fc4ec053976 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33d74f27ca905d01bfb392cdde4cdc04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33d74f27ca905d01bfb392cdde4cdc04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33d74f27ca905d01bfb392cdde4cdc04 = L.map(
#                 &quot;map_33d74f27ca905d01bfb392cdde4cdc04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a74652e2f33843ea64dc4e4d12576d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a74652e2f33843ea64dc4e4d12576d1.addTo(map_33d74f27ca905d01bfb392cdde4cdc04);
#
#
#             var feature_group_31524a89b8f7d6007867f572246f0b9b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_31524a89b8f7d6007867f572246f0b9b.addTo(map_33d74f27ca905d01bfb392cdde4cdc04);
#
#
#             var feature_group_sub_group_c7bb48036145a62a5fee16977b80af46 = L.featureGroup.subGroup(
#                 feature_group_31524a89b8f7d6007867f572246f0b9b
#             );
#
#
#             var marker_0c272234c29edcc1016f2f65ac56cf11 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7bb48036145a62a5fee16977b80af46);
#
#
#         var popup_0f7f2aebb7ee78cce2c43174fe499180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4a7307ffd66961acc9fc126960189fb = $(`&lt;div id=&quot;html_f4a7307ffd66961acc9fc126960189fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0f7f2aebb7ee78cce2c43174fe499180.setContent(html_f4a7307ffd66961acc9fc126960189fb);
#
#
#
#         marker_0c272234c29edcc1016f2f65ac56cf11.bindPopup(popup_0f7f2aebb7ee78cce2c43174fe499180)
#         ;
#
#
#
#
#             var marker_f741c66c4920c1ad2579dd29d8e6c5b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7bb48036145a62a5fee16977b80af46);
#
#
#         var popup_08f9c07e39ad3da93e6ae6948c68c627 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b31c6cda18313cccb9c546d09aa796d8 = $(`&lt;div id=&quot;html_b31c6cda18313cccb9c546d09aa796d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_08f9c07e39ad3da93e6ae6948c68c627.setContent(html_b31c6cda18313cccb9c546d09aa796d8);
#
#
#
#         marker_f741c66c4920c1ad2579dd29d8e6c5b9.bindPopup(popup_08f9c07e39ad3da93e6ae6948c68c627)
#         ;
#
#
#
#
#             var marker_203ef44f13177a7b1d2fbbed691871ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7bb48036145a62a5fee16977b80af46);
#
#
#         var popup_f4c65b7d44a524bf158724322c36d27f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_931efa96de2e0c0f356086b02ffd69d2 = $(`&lt;div id=&quot;html_931efa96de2e0c0f356086b02ffd69d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f4c65b7d44a524bf158724322c36d27f.setContent(html_931efa96de2e0c0f356086b02ffd69d2);
#
#
#
#         marker_203ef44f13177a7b1d2fbbed691871ad.bindPopup(popup_f4c65b7d44a524bf158724322c36d27f)
#         ;
#
#
#
#
#             var marker_33ba4520fb464cc5f52c8cef33452fa7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7bb48036145a62a5fee16977b80af46);
#
#
#         var popup_06f8a7a35fd095a78d2c2672672a8311 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b552da4905b2b9bd88bfae505521c7f1 = $(`&lt;div id=&quot;html_b552da4905b2b9bd88bfae505521c7f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_06f8a7a35fd095a78d2c2672672a8311.setContent(html_b552da4905b2b9bd88bfae505521c7f1);
#
#
#
#         marker_
