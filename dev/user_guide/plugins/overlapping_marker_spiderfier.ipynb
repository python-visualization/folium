# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65153f73da4014e3b97fcfbe0c75bb94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65153f73da4014e3b97fcfbe0c75bb94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65153f73da4014e3b97fcfbe0c75bb94 = L.map(
#                 &quot;map_65153f73da4014e3b97fcfbe0c75bb94&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b316f0ff662dc85c3ebf717bdf4b9f8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b316f0ff662dc85c3ebf717bdf4b9f8d.addTo(map_65153f73da4014e3b97fcfbe0c75bb94);
#
#
#             var marker_2db19f63dfabf9791e3109eb2edf9d43 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_65153f73da4014e3b97fcfbe0c75bb94);
#
#
#         var popup_d6c23c292e865532b6323b3b86a43efc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_908bfece37f95959f2159adaac6ce03e = $(`&lt;div id=&quot;html_908bfece37f95959f2159adaac6ce03e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d6c23c292e865532b6323b3b86a43efc.setContent(html_908bfece37f95959f2159adaac6ce03e);
#
#
#
#         marker_2db19f63dfabf9791e3109eb2edf9d43.bindPopup(popup_d6c23c292e865532b6323b3b86a43efc)
#         ;
#
#
#
#
#             var marker_36adeb36369bda11e5fcec1fdf7e1df4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_65153f73da4014e3b97fcfbe0c75bb94);
#
#
#         var popup_7cf8b1c3bcb3188c5a84e4d4ace7bc61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d85f406c2d85e7d4f950d4e64b7e4ff7 = $(`&lt;div id=&quot;html_d85f406c2d85e7d4f950d4e64b7e4ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7cf8b1c3bcb3188c5a84e4d4ace7bc61.setContent(html_d85f406c2d85e7d4f950d4e64b7e4ff7);
#
#
#
#         marker_36adeb36369bda11e5fcec1fdf7e1df4.bindPopup(popup_7cf8b1c3bcb3188c5a84e4d4ace7bc61)
#         ;
#
#
#
#
#             var marker_24c396ced41e695379bfc2150af1d290 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_65153f73da4014e3b97fcfbe0c75bb94);
#
#
#         var popup_68134f2742545cefeb27d82230dc5ea2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95f3dceda78b5ef909355e3195771f8a = $(`&lt;div id=&quot;html_95f3dceda78b5ef909355e3195771f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_68134f2742545cefeb27d82230dc5ea2.setContent(html_95f3dceda78b5ef909355e3195771f8a);
#
#
#
#         marker_24c396ced41e695379bfc2150af1d290.bindPopup(popup_68134f2742545cefeb27d82230dc5ea2)
#         ;
#
#
#
#
#             var marker_3ee0aae99df5ae4068946717f61c2dce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_65153f73da4014e3b97fcfbe0c75bb94);
#
#
#         var popup_a6238d704bf8656a884f4318c88c4b5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acbb0905d8f93531f70dbbea17c365bc = $(`&lt;div id=&quot;html_acbb0905d8f93531f70dbbea17c365bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a6238d704bf8656a884f4318c88c4b5d.setContent(html_acbb0905d8f93531f70dbbea17c365bc);
#
#
#
#         marker_3ee0aae99df5ae4068946717f61c2dce.bindPopup(popup_a6238d704bf8656a884f4318c88c4b5d)
#         ;
#
#
#
#
#             var marker_76d86fad04104333ec1aece5ecd2e0b1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_65153f73da4014e3b97fcfbe0c75bb94);
#
#
#         var popup_1208cb591296f481f2e602865a76b01d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cf2dd75c6740e7934a64aea6608b19d = $(`&lt;div id=&quot;html_8cf2dd75c6740e7934a64aea6608b19d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1208cb591296f481f2e602865a76b01d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e477bce9d5e49796efa39e7618b4381 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e477bce9d5e49796efa39e7618b4381&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e477bce9d5e49796efa39e7618b4381 = L.map(
#                 &quot;map_4e477bce9d5e49796efa39e7618b4381&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ab8d4bc193bc31b1dd867451d5dc265 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ab8d4bc193bc31b1dd867451d5dc265.addTo(map_4e477bce9d5e49796efa39e7618b4381);
#
#
#             var feature_group_92bf80ba278c6c1bba987111658b7175 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7bc3abae79d281eaaa1c4c3b4ddfeb01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_92bf80ba278c6c1bba987111658b7175);
#
#
#         var popup_8f3116a20085ea9c2ad2c95b2a6abddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbb47c9df93edef5cc29537672a1d683 = $(`&lt;div id=&quot;html_bbb47c9df93edef5cc29537672a1d683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8f3116a20085ea9c2ad2c95b2a6abddd.setContent(html_bbb47c9df93edef5cc29537672a1d683);
#
#
#
#         marker_7bc3abae79d281eaaa1c4c3b4ddfeb01.bindPopup(popup_8f3116a20085ea9c2ad2c95b2a6abddd)
#         ;
#
#
#
#
#             var marker_4d9e7a0d2e043f13eca44ce9480f8ed3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_92bf80ba278c6c1bba987111658b7175);
#
#
#         var popup_39b6aeb5efc0c49a70a6196f95ca0aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87645a07330e6ea1f2b48a658b1a8b4c = $(`&lt;div id=&quot;html_87645a07330e6ea1f2b48a658b1a8b4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_39b6aeb5efc0c49a70a6196f95ca0aed.setContent(html_87645a07330e6ea1f2b48a658b1a8b4c);
#
#
#
#         marker_4d9e7a0d2e043f13eca44ce9480f8ed3.bindPopup(popup_39b6aeb5efc0c49a70a6196f95ca0aed)
#         ;
#
#
#
#
#             var marker_d328543c8f14e7efb4c2e54b5d91a28b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_92bf80ba278c6c1bba987111658b7175);
#
#
#         var popup_0a8ad4af7b3fb902916e5d7f7fd8a9dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7be456ba85d70a5a6e8856d3fb83b53 = $(`&lt;div id=&quot;html_d7be456ba85d70a5a6e8856d3fb83b53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0a8ad4af7b3fb902916e5d7f7fd8a9dd.setContent(html_d7be456ba85d70a5a6e8856d3fb83b53);
#
#
#
#         marker_d328543c8f14e7efb4c2e54b5d91a28b.bindPopup(popup_0a8ad4af7b3fb902916e5d7f7fd8a9dd)
#         ;
#
#
#
#
#             var marker_f3862d3ac9b33bb02a58e95367a2963a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_92bf80ba278c6c1bba987111658b7175);
#
#
#         var popup_9e26e392d116062d87f4bd25f4942fb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce14dd2613fe0eb050bd2be67e53e4d2 = $(`&lt;div id=&quot;html_ce14dd2613fe0eb050bd2be67e53e4d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9e26e392d116062d87f4bd25f4942fb9.setContent(html_ce14dd2613fe0eb050bd2be67e53e4d2);
#
#
#
#         marker_f3862d3ac9b33bb02a58e95367a2963a.bindPopup(popup_9e26e392d116062d87f4bd25f4942fb9)
#         ;
#
#
#
#
#             var marker_3088b71657a9dfdaab00eb61e3b1a361 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_92bf80ba278c6c1bba987111658b7175);
#
#
#         var popup_afbf86778dba2423e2e7d6261146c81b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57f79012e04e47c7fa71327bedb7d042 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57f79012e04e47c7fa71327bedb7d042&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57f79012e04e47c7fa71327bedb7d042 = L.map(
#                 &quot;map_57f79012e04e47c7fa71327bedb7d042&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_775ab05a86a86d606beaf92cfb7ce37e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_775ab05a86a86d606beaf92cfb7ce37e.addTo(map_57f79012e04e47c7fa71327bedb7d042);
#
#
#             var feature_group_84bbdb6ee431b6d4dfdd77129c4ccfc2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_84bbdb6ee431b6d4dfdd77129c4ccfc2.addTo(map_57f79012e04e47c7fa71327bedb7d042);
#
#
#             var feature_group_sub_group_85bb1edf5ec7a8f0f9e1d15cd399a65c = L.featureGroup.subGroup(
#                 feature_group_84bbdb6ee431b6d4dfdd77129c4ccfc2
#             );
#
#
#             var marker_a9143e3d8bf048c84d24def0fb08fc52 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_85bb1edf5ec7a8f0f9e1d15cd399a65c);
#
#
#         var popup_feb3348304f4f0839ba18864753240de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edfed6638dc0ed715fc53203a5362310 = $(`&lt;div id=&quot;html_edfed6638dc0ed715fc53203a5362310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_feb3348304f4f0839ba18864753240de.setContent(html_edfed6638dc0ed715fc53203a5362310);
#
#
#
#         marker_a9143e3d8bf048c84d24def0fb08fc52.bindPopup(popup_feb3348304f4f0839ba18864753240de)
#         ;
#
#
#
#
#             var marker_a2d32ce6b7c31f06693efc91f49bbf88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_85bb1edf5ec7a8f0f9e1d15cd399a65c);
#
#
#         var popup_733a8a6f32e005b0dc1ab579b1239ee6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3da3aaccbd281db806ae9c31ddeb1c4 = $(`&lt;div id=&quot;html_f3da3aaccbd281db806ae9c31ddeb1c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_733a8a6f32e005b0dc1ab579b1239ee6.setContent(html_f3da3aaccbd281db806ae9c31ddeb1c4);
#
#
#
#         marker_a2d32ce6b7c31f06693efc91f49bbf88.bindPopup(popup_733a8a6f32e005b0dc1ab579b1239ee6)
#         ;
#
#
#
#
#             var marker_2bd69de120fb37de74e4d586635bffe4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_85bb1edf5ec7a8f0f9e1d15cd399a65c);
#
#
#         var popup_6d0d74a9d2aa58cec7b33c17f5d72b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ac46836431f86d79748297dcbb0a553 = $(`&lt;div id=&quot;html_9ac46836431f86d79748297dcbb0a553&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6d0d74a9d2aa58cec7b33c17f5d72b7e.setContent(html_9ac46836431f86d79748297dcbb0a553);
#
#
#
#         marker_2bd69de120fb37de74e4d586635bffe4.bindPopup(popup_6d0d74a9d2aa58cec7b33c17f5d72b7e)
#         ;
#
#
#
#
#             var marker_4f8fe46541794d2a9406136a9724479d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_85bb1edf5ec7a8f0f9e1d15cd399a65c);
#
#
#         var popup_d9e6b6eea819c8519c783601a5e38d06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c908dc5984c68e46272d58e1f692c66b = $(`&lt;div id=&quot;html_c908dc5984c68e46272d58e1f692c66b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d9e6b6eea819c8519c783601a5e38d06.setContent(html_c908dc5984c68e46272d58e1f692c66b);
#
#
#
#         marker_
