# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03fa3cc35b2ccabe07e3ed999f2c643b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03fa3cc35b2ccabe07e3ed999f2c643b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03fa3cc35b2ccabe07e3ed999f2c643b = L.map(
#                 &quot;map_03fa3cc35b2ccabe07e3ed999f2c643b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_429ded02a770637dddb8bc9a65cef522 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_429ded02a770637dddb8bc9a65cef522.addTo(map_03fa3cc35b2ccabe07e3ed999f2c643b);
#
#
#             var marker_9760ed9e8cb6d727de1f2bb404e45e7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_03fa3cc35b2ccabe07e3ed999f2c643b);
#
#
#         var popup_a428df8ac1e7578709c1353419ff96f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09db8acb01e9665933b8147570c02369 = $(`&lt;div id=&quot;html_09db8acb01e9665933b8147570c02369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a428df8ac1e7578709c1353419ff96f8.setContent(html_09db8acb01e9665933b8147570c02369);
#
#
#
#         marker_9760ed9e8cb6d727de1f2bb404e45e7d.bindPopup(popup_a428df8ac1e7578709c1353419ff96f8)
#         ;
#
#
#
#
#             var marker_ee42cbccf7bb1fcd5873afa8a759032c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_03fa3cc35b2ccabe07e3ed999f2c643b);
#
#
#         var popup_153bf6e4d23e93ea6ed0a5f840fafcbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e4f33f5e2e872ce48a6fee744d7666 = $(`&lt;div id=&quot;html_b0e4f33f5e2e872ce48a6fee744d7666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_153bf6e4d23e93ea6ed0a5f840fafcbc.setContent(html_b0e4f33f5e2e872ce48a6fee744d7666);
#
#
#
#         marker_ee42cbccf7bb1fcd5873afa8a759032c.bindPopup(popup_153bf6e4d23e93ea6ed0a5f840fafcbc)
#         ;
#
#
#
#
#             var marker_b38b1803f3ce673aed0940a31c4efe2f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_03fa3cc35b2ccabe07e3ed999f2c643b);
#
#
#         var popup_c607863115321a2991b7dc33c34ac5cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c93fa28db7d57e19e96e26751655cac6 = $(`&lt;div id=&quot;html_c93fa28db7d57e19e96e26751655cac6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c607863115321a2991b7dc33c34ac5cf.setContent(html_c93fa28db7d57e19e96e26751655cac6);
#
#
#
#         marker_b38b1803f3ce673aed0940a31c4efe2f.bindPopup(popup_c607863115321a2991b7dc33c34ac5cf)
#         ;
#
#
#
#
#             var marker_a96624ed30c4433c528def618f71f725 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_03fa3cc35b2ccabe07e3ed999f2c643b);
#
#
#         var popup_b0cd9017d43cce478a93bf7947612d9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01c4a1ad4584baadb8e16488f130add5 = $(`&lt;div id=&quot;html_01c4a1ad4584baadb8e16488f130add5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b0cd9017d43cce478a93bf7947612d9f.setContent(html_01c4a1ad4584baadb8e16488f130add5);
#
#
#
#         marker_a96624ed30c4433c528def618f71f725.bindPopup(popup_b0cd9017d43cce478a93bf7947612d9f)
#         ;
#
#
#
#
#             var marker_1624048ba6a82e6723fc15bb870c44e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_03fa3cc35b2ccabe07e3ed999f2c643b);
#
#
#         var popup_4ba621007eba762138d9e06a291d0348 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5da3ceac77f8ebab724f3c3e421f270 = $(`&lt;div id=&quot;html_c5da3ceac77f8ebab724f3c3e421f270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4ba621007eba762138d9e06a291d0348.setContent(html_c5da3ceac77f8ebab724f3c3e421f270);
#
#
#
#         marker_1624048ba6a82e6723fc15bb870c44e7.bindPopup(popup_4ba621007eba762138d9e06a291d0348)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dc6e17ea30d01128ccbab535e2201c7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dc6e17ea30d01128ccbab535e2201c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dc6e17ea30d01128ccbab535e2201c7 = L.map(
#                 &quot;map_5dc6e17ea30d01128ccbab535e2201c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dda5e95351809afdf38fe52031f156a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6dda5e95351809afdf38fe52031f156a.addTo(map_5dc6e17ea30d01128ccbab535e2201c7);
#
#
#             var feature_group_58ed97b8206825c9d9c2dedbffd78a7c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0b970158d9124b7c98e53ae0e08aaf03 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_58ed97b8206825c9d9c2dedbffd78a7c);
#
#
#         var popup_25ecd8d4bf7f67964f2db2f3799ef351 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ff81dc69254e423ca7551644c5cd04b = $(`&lt;div id=&quot;html_9ff81dc69254e423ca7551644c5cd04b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_25ecd8d4bf7f67964f2db2f3799ef351.setContent(html_9ff81dc69254e423ca7551644c5cd04b);
#
#
#
#         marker_0b970158d9124b7c98e53ae0e08aaf03.bindPopup(popup_25ecd8d4bf7f67964f2db2f3799ef351)
#         ;
#
#
#
#
#             var marker_612247fda19cc14a9af26687c37f50cf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_58ed97b8206825c9d9c2dedbffd78a7c);
#
#
#         var popup_93a76ca5ecf6c5b4a9c252e99b7b2205 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0346513d186a435ffa25617853b67914 = $(`&lt;div id=&quot;html_0346513d186a435ffa25617853b67914&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_93a76ca5ecf6c5b4a9c252e99b7b2205.setContent(html_0346513d186a435ffa25617853b67914);
#
#
#
#         marker_612247fda19cc14a9af26687c37f50cf.bindPopup(popup_93a76ca5ecf6c5b4a9c252e99b7b2205)
#         ;
#
#
#
#
#             var marker_1997ee447d1b539f22bba83cc04b97bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_58ed97b8206825c9d9c2dedbffd78a7c);
#
#
#         var popup_ab018cb66fa2b7f2cc62610ad24defb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e483c07f0352bfb7eefb88c6617b97df = $(`&lt;div id=&quot;html_e483c07f0352bfb7eefb88c6617b97df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ab018cb66fa2b7f2cc62610ad24defb5.setContent(html_e483c07f0352bfb7eefb88c6617b97df);
#
#
#
#         marker_1997ee447d1b539f22bba83cc04b97bf.bindPopup(popup_ab018cb66fa2b7f2cc62610ad24defb5)
#         ;
#
#
#
#
#             var marker_de161d896fa36f7ba98f60cb6e892cb1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_58ed97b8206825c9d9c2dedbffd78a7c);
#
#
#         var popup_4ece70401385ea5df8e41d7fdfc51a6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98ec75d4f144b87cc35afe0ba86bc5da = $(`&lt;div id=&quot;html_98ec75d4f144b87cc35afe0ba86bc5da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4ece70401385ea5df8e41d7fdfc51a6d.setContent(html_98ec75d4f144b87cc35afe0ba86bc5da);
#
#
#
#         marker_de161d896fa36f7ba98f60cb6e892cb1.bindPopup(popup_4ece70401385ea5df8e41d7fdfc51a6d)
#         ;
#
#
#
#
#             var marker_691bfd46df17aa9ac538f2beb2f493f1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_58ed97b8206825c9d9c2dedbffd78a7c);
#
#
#         var popup_bf65d6d531ae30caf1972f292a24732b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ade951862c0d690955b2ad353f9c9262 = $(`&lt;div id=&quot;html_ade951862c0d690955b2ad353f9c9262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78d6bf63e13a832abc430a133dac9e64 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78d6bf63e13a832abc430a133dac9e64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78d6bf63e13a832abc430a133dac9e64 = L.map(
#                 &quot;map_78d6bf63e13a832abc430a133dac9e64&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e37fa15a62a4bd173bae5a578e4b016 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e37fa15a62a4bd173bae5a578e4b016.addTo(map_78d6bf63e13a832abc430a133dac9e64);
#
#
#             var feature_group_b59e6e33dbf28403ce4b7820bea85449 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b59e6e33dbf28403ce4b7820bea85449.addTo(map_78d6bf63e13a832abc430a133dac9e64);
#
#
#             var feature_group_sub_group_436d721aef3134f7529351c52bb9d006 = L.featureGroup.subGroup(
#                 feature_group_b59e6e33dbf28403ce4b7820bea85449
#             );
#
#
#             var marker_d71cfb966d7df9d0ab4ed8fbcf4d8823 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_436d721aef3134f7529351c52bb9d006);
#
#
#         var popup_645cd1021928da3b7ef2165a3526c441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c64380047732213ca7bcd612e35f7cf9 = $(`&lt;div id=&quot;html_c64380047732213ca7bcd612e35f7cf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_645cd1021928da3b7ef2165a3526c441.setContent(html_c64380047732213ca7bcd612e35f7cf9);
#
#
#
#         marker_d71cfb966d7df9d0ab4ed8fbcf4d8823.bindPopup(popup_645cd1021928da3b7ef2165a3526c441)
#         ;
#
#
#
#
#             var marker_61f52decbca3df393e417c5da30f748d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_436d721aef3134f7529351c52bb9d006);
#
#
#         var popup_0bd7a1715adfcfbd147964fd5991ff2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c2e3f623705893ec1552a936531fb51 = $(`&lt;div id=&quot;html_2c2e3f623705893ec1552a936531fb51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0bd7a1715adfcfbd147964fd5991ff2a.setContent(html_2c2e3f623705893ec1552a936531fb51);
#
#
#
#         marker_61f52decbca3df393e417c5da30f748d.bindPopup(popup_0bd7a1715adfcfbd147964fd5991ff2a)
#         ;
#
#
#
#
#             var marker_a7569a89be4c1b32944c259e743c2f23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_436d721aef3134f7529351c52bb9d006);
#
#
#         var popup_92c9a317d9b0546e1684443428e57962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d082e57f58f8e5da0d3a2dd4817f35de = $(`&lt;div id=&quot;html_d082e57f58f8e5da0d3a2dd4817f35de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_92c9a317d9b0546e1684443428e57962.setContent(html_d082e57f58f8e5da0d3a2dd4817f35de);
#
#
#
#         marker_a7569a89be4c1b32944c259e743c2f23.bindPopup(popup_92c9a317d9b0546e1684443428e57962)
#         ;
#
#
#
#
#             var marker_21e2d02f77e13e13c6be15d42a296eb6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_436d721aef3134f7529351c52bb9d006);
#
#
#         var popup_9be62d0a9a8efe664575113d14113844 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e8c46fbaca8fdd53a7aecf6ea49dc94 = $(`&lt;div id=&quot;html_7e8c46fbaca8fdd53a7aecf6ea49dc94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9be62d0a9a8efe664575113d14113844.setContent(html_7e8c46fbaca8fdd53a7aecf6ea49dc94);
#
#
#
#         marker_21e2d02f77e13e13c6be15d42a296eb6.bindPopup(popup_9be62d0a9a8efe664575113d14113844)
#         ;
#
#
#
#
#             var marker_872213fa87343182e1a101ffafca1b60 = L.marker(
#                 [45.0503999
