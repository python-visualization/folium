# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_469f63ab68cc89ed71197485ae0c1aed {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_469f63ab68cc89ed71197485ae0c1aed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_469f63ab68cc89ed71197485ae0c1aed = L.map(
#                 &quot;map_469f63ab68cc89ed71197485ae0c1aed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b3a15cb328cb8573b14bd2b0798139b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b3a15cb328cb8573b14bd2b0798139b.addTo(map_469f63ab68cc89ed71197485ae0c1aed);
#
#
#             var marker_1499862c035b38bf7f00b51dfd70ef6f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_469f63ab68cc89ed71197485ae0c1aed);
#
#
#         var popup_b5086224fa4db8c68d9921e772f0f3a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dccc0e1cbe8db773cdf10b25bb93c2b5 = $(`&lt;div id=&quot;html_dccc0e1cbe8db773cdf10b25bb93c2b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b5086224fa4db8c68d9921e772f0f3a6.setContent(html_dccc0e1cbe8db773cdf10b25bb93c2b5);
#
#
#
#         marker_1499862c035b38bf7f00b51dfd70ef6f.bindPopup(popup_b5086224fa4db8c68d9921e772f0f3a6)
#         ;
#
#
#
#
#             var marker_cb63a52bcc463316c5dd482250eb1c84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_469f63ab68cc89ed71197485ae0c1aed);
#
#
#         var popup_ee1f036bf173a07c4133c257376e10d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d692beb216c3a2f2ba688b6236556db = $(`&lt;div id=&quot;html_5d692beb216c3a2f2ba688b6236556db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ee1f036bf173a07c4133c257376e10d9.setContent(html_5d692beb216c3a2f2ba688b6236556db);
#
#
#
#         marker_cb63a52bcc463316c5dd482250eb1c84.bindPopup(popup_ee1f036bf173a07c4133c257376e10d9)
#         ;
#
#
#
#
#             var marker_30e52ea55d03c93bf9cc9d5e29050bd2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_469f63ab68cc89ed71197485ae0c1aed);
#
#
#         var popup_841ce57ed4506f4bf036dc1c280ec96d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32e5714ad8e4c81272e4c9cc1afefb40 = $(`&lt;div id=&quot;html_32e5714ad8e4c81272e4c9cc1afefb40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_841ce57ed4506f4bf036dc1c280ec96d.setContent(html_32e5714ad8e4c81272e4c9cc1afefb40);
#
#
#
#         marker_30e52ea55d03c93bf9cc9d5e29050bd2.bindPopup(popup_841ce57ed4506f4bf036dc1c280ec96d)
#         ;
#
#
#
#
#             var marker_60280782aa0787bbbf6a09f37d250830 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_469f63ab68cc89ed71197485ae0c1aed);
#
#
#         var popup_aff8c8f94c787c95b925857036ac4b3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecdbff6fed7651a74881d609913f445d = $(`&lt;div id=&quot;html_ecdbff6fed7651a74881d609913f445d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aff8c8f94c787c95b925857036ac4b3c.setContent(html_ecdbff6fed7651a74881d609913f445d);
#
#
#
#         marker_60280782aa0787bbbf6a09f37d250830.bindPopup(popup_aff8c8f94c787c95b925857036ac4b3c)
#         ;
#
#
#
#
#             var marker_aefa84d2aaa167ad777c9faca03ba054 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_469f63ab68cc89ed71197485ae0c1aed);
#
#
#         var popup_c83650006a3932a861875bcf90144522 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7809b176c46f05b29a95320f47ba16c = $(`&lt;div id=&quot;html_b7809b176c46f05b29a95320f47ba16c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c83650006a3932a861875bcf90144522.setContent(html_b7809b176c46f05b29a95320f47ba16c);
#
#
#
#         marker_aefa84d2aaa167ad777c9faca03ba054.bindPopup(popup_c83650006a3932a861875bcf90144522)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f7b120656e488b90f780a071770d7f1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f7b120656e488b90f780a071770d7f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f7b120656e488b90f780a071770d7f1 = L.map(
#                 &quot;map_8f7b120656e488b90f780a071770d7f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b959240ca7d010e944158689873dc9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b959240ca7d010e944158689873dc9f.addTo(map_8f7b120656e488b90f780a071770d7f1);
#
#
#             var feature_group_942f1018da9ef3db7a2c232023815619 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ed653cefe076dc825d6eeb481be2b55b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_942f1018da9ef3db7a2c232023815619);
#
#
#         var popup_abbe6fc5881ae9e4ca9ce656d1e88dc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1f274bca934e157c8d1cc0a31431f16 = $(`&lt;div id=&quot;html_c1f274bca934e157c8d1cc0a31431f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_abbe6fc5881ae9e4ca9ce656d1e88dc8.setContent(html_c1f274bca934e157c8d1cc0a31431f16);
#
#
#
#         marker_ed653cefe076dc825d6eeb481be2b55b.bindPopup(popup_abbe6fc5881ae9e4ca9ce656d1e88dc8)
#         ;
#
#
#
#
#             var marker_5dfeb0a8c55579726ea7e3aa7e252404 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_942f1018da9ef3db7a2c232023815619);
#
#
#         var popup_c953f672ea5a877ab8cf2d5f61694d03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5c177210306527cd8c25243d047ad76 = $(`&lt;div id=&quot;html_e5c177210306527cd8c25243d047ad76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c953f672ea5a877ab8cf2d5f61694d03.setContent(html_e5c177210306527cd8c25243d047ad76);
#
#
#
#         marker_5dfeb0a8c55579726ea7e3aa7e252404.bindPopup(popup_c953f672ea5a877ab8cf2d5f61694d03)
#         ;
#
#
#
#
#             var marker_b488e82bbc41f533500eb1d12dca37ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_942f1018da9ef3db7a2c232023815619);
#
#
#         var popup_453c7c53dd8c32ef8044c9a1644b70c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76e02855f4ce3188159a8927aa1a9046 = $(`&lt;div id=&quot;html_76e02855f4ce3188159a8927aa1a9046&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_453c7c53dd8c32ef8044c9a1644b70c5.setContent(html_76e02855f4ce3188159a8927aa1a9046);
#
#
#
#         marker_b488e82bbc41f533500eb1d12dca37ee.bindPopup(popup_453c7c53dd8c32ef8044c9a1644b70c5)
#         ;
#
#
#
#
#             var marker_7c2a0aa7102ee0148ae832ccf7bfc687 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_942f1018da9ef3db7a2c232023815619);
#
#
#         var popup_b603a90d8a877306006d4c0f654397f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89536e7cca3e603d99dcb96599d37cd6 = $(`&lt;div id=&quot;html_89536e7cca3e603d99dcb96599d37cd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b603a90d8a877306006d4c0f654397f2.setContent(html_89536e7cca3e603d99dcb96599d37cd6);
#
#
#
#         marker_7c2a0aa7102ee0148ae832ccf7bfc687.bindPopup(popup_b603a90d8a877306006d4c0f654397f2)
#         ;
#
#
#
#
#             var marker_38367bc7781ba05612018954b89478ad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_942f1018da9ef3db7a2c232023815619);
#
#
#         var popup_d77cd8ad748093a025b62a2b8280adfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_130ec6e31ed30e79d48d04b636a2c7c9 = $(`&lt;div id=&quot;html_130ec6e31ed30e79d48d04b636a2c7c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07cabb68fe82b6d6464b16d76363453c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07cabb68fe82b6d6464b16d76363453c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07cabb68fe82b6d6464b16d76363453c = L.map(
#                 &quot;map_07cabb68fe82b6d6464b16d76363453c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_945b53095c1762b76389525763b2f7f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_945b53095c1762b76389525763b2f7f9.addTo(map_07cabb68fe82b6d6464b16d76363453c);
#
#
#             var feature_group_1f8e1880e334664e65748f807b5fbce7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1f8e1880e334664e65748f807b5fbce7.addTo(map_07cabb68fe82b6d6464b16d76363453c);
#
#
#             var feature_group_sub_group_3b128eb6c2bf33ad95af490bf3fb4ad6 = L.featureGroup.subGroup(
#                 feature_group_1f8e1880e334664e65748f807b5fbce7
#             );
#
#
#             var marker_bc4cdef9fcd41eb6f00352e0f4207c7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b128eb6c2bf33ad95af490bf3fb4ad6);
#
#
#         var popup_03251ab9dfb1d330180a2791888cbc42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34732bf81fb23c8f759c55b33446937b = $(`&lt;div id=&quot;html_34732bf81fb23c8f759c55b33446937b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_03251ab9dfb1d330180a2791888cbc42.setContent(html_34732bf81fb23c8f759c55b33446937b);
#
#
#
#         marker_bc4cdef9fcd41eb6f00352e0f4207c7b.bindPopup(popup_03251ab9dfb1d330180a2791888cbc42)
#         ;
#
#
#
#
#             var marker_4751cf7f711cc929c296bb3bfff08710 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b128eb6c2bf33ad95af490bf3fb4ad6);
#
#
#         var popup_bdc9992eeb03e4e408095f7affe63d4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93b8d9bbd1b72d759268330e3c81ca55 = $(`&lt;div id=&quot;html_93b8d9bbd1b72d759268330e3c81ca55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bdc9992eeb03e4e408095f7affe63d4a.setContent(html_93b8d9bbd1b72d759268330e3c81ca55);
#
#
#
#         marker_4751cf7f711cc929c296bb3bfff08710.bindPopup(popup_bdc9992eeb03e4e408095f7affe63d4a)
#         ;
#
#
#
#
#             var marker_dcb0ea95e1df91219298dfe88e981a56 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b128eb6c2bf33ad95af490bf3fb4ad6);
#
#
#         var popup_88ed245d8d4949c9fd60ffe8fba70922 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c05ada731b4a7a2947e59b97f851f7bb = $(`&lt;div id=&quot;html_c05ada731b4a7a2947e59b97f851f7bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88ed245d8d4949c9fd60ffe8fba70922.setContent(html_c05ada731b4a7a2947e59b97f851f7bb);
#
#
#
#         marker_dcb0ea95e1df91219298dfe88e981a56.bindPopup(popup_88ed245d8d4949c9fd60ffe8fba70922)
#         ;
#
#
#
#
#             var marker_ca1941f7049e86ceb7fb72631437b8ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b128eb6c2bf33ad95af490bf3fb4ad6);
#
#
#         var popup_f6515cca2bb1a4fef1c538e8e0dfeb60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b72777841e6988b603f91849ca4c60a = $(`&lt;div id=&quot;html_6b72777841e6988b603f91849ca4c60a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f6515cca2bb1a4fef1c538e8e0dfeb60.setContent(html_6b72777841e6988b603f91849ca4c60a);
#
#
#
#         marker_ca1941f7049e86ceb7fb72631437b8ca.bindPopup(popup_f6515cca2bb1a4fef1c538e8e0dfeb60)
#         ;
#
#
#
#
#             var marker_f56ee5b9d9113adeaee382f928dde3ca = L.marker(
#                 [45.0503999
