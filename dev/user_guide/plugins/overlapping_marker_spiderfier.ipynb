# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16a933b9c5e297121f2bcfbc47b93493 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16a933b9c5e297121f2bcfbc47b93493&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16a933b9c5e297121f2bcfbc47b93493 = L.map(
#                 &quot;map_16a933b9c5e297121f2bcfbc47b93493&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf247484363303f49cd4cc56549f31b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf247484363303f49cd4cc56549f31b3.addTo(map_16a933b9c5e297121f2bcfbc47b93493);
#
#
#             var marker_bca965541a63889bfaca362c282011f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_16a933b9c5e297121f2bcfbc47b93493);
#
#
#         var popup_fb56474faa111e3b451cdc0fecd5baad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5438bdcd6f3e27b85e8b36f208213e6 = $(`&lt;div id=&quot;html_a5438bdcd6f3e27b85e8b36f208213e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fb56474faa111e3b451cdc0fecd5baad.setContent(html_a5438bdcd6f3e27b85e8b36f208213e6);
#
#
#
#         marker_bca965541a63889bfaca362c282011f0.bindPopup(popup_fb56474faa111e3b451cdc0fecd5baad)
#         ;
#
#
#
#
#             var marker_15b63ef85455a505955ad81971366e84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_16a933b9c5e297121f2bcfbc47b93493);
#
#
#         var popup_1e945c772630d13c0ce592d9fe4d1d5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bb51a40c726c66715c66f06d69f8963 = $(`&lt;div id=&quot;html_4bb51a40c726c66715c66f06d69f8963&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e945c772630d13c0ce592d9fe4d1d5d.setContent(html_4bb51a40c726c66715c66f06d69f8963);
#
#
#
#         marker_15b63ef85455a505955ad81971366e84.bindPopup(popup_1e945c772630d13c0ce592d9fe4d1d5d)
#         ;
#
#
#
#
#             var marker_58934f9f505d3d8070da4f1b12b30f8e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_16a933b9c5e297121f2bcfbc47b93493);
#
#
#         var popup_393d98859de884005ca9fc0fb472e521 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9e1bf0db8d4f22b9aaa8353e99c6360 = $(`&lt;div id=&quot;html_d9e1bf0db8d4f22b9aaa8353e99c6360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_393d98859de884005ca9fc0fb472e521.setContent(html_d9e1bf0db8d4f22b9aaa8353e99c6360);
#
#
#
#         marker_58934f9f505d3d8070da4f1b12b30f8e.bindPopup(popup_393d98859de884005ca9fc0fb472e521)
#         ;
#
#
#
#
#             var marker_321940ac299ab6af9973ed6c8ffd2f21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_16a933b9c5e297121f2bcfbc47b93493);
#
#
#         var popup_e7ae4f56f261169c6db9c5efd70e9ff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_585b1751cd41d3d50d799e3785f12d9b = $(`&lt;div id=&quot;html_585b1751cd41d3d50d799e3785f12d9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e7ae4f56f261169c6db9c5efd70e9ff4.setContent(html_585b1751cd41d3d50d799e3785f12d9b);
#
#
#
#         marker_321940ac299ab6af9973ed6c8ffd2f21.bindPopup(popup_e7ae4f56f261169c6db9c5efd70e9ff4)
#         ;
#
#
#
#
#             var marker_605cc0196e8834ea4be2d5902fa3a3f0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_16a933b9c5e297121f2bcfbc47b93493);
#
#
#         var popup_e4d99ec92036514f89b178f85877366d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b584fec88f67933aa491a2d77ae7f386 = $(`&lt;div id=&quot;html_b584fec88f67933aa491a2d77ae7f386&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e4d99ec92036514f89b178f85877366d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c609991a58c376166cdee0748c7993f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c609991a58c376166cdee0748c7993f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c609991a58c376166cdee0748c7993f = L.map(
#                 &quot;map_7c609991a58c376166cdee0748c7993f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b71c9c177ca3c4ee87d337c53b5b697f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b71c9c177ca3c4ee87d337c53b5b697f.addTo(map_7c609991a58c376166cdee0748c7993f);
#
#
#             var feature_group_586b49177e0564aab4d28bcacba1f9bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_68b819bb8abd4cb074bfe406feebc3a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_586b49177e0564aab4d28bcacba1f9bd);
#
#
#         var popup_a161184588e52664baf0bf378dfe8970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f5503ab0846d39163a188fe74dbf235 = $(`&lt;div id=&quot;html_8f5503ab0846d39163a188fe74dbf235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a161184588e52664baf0bf378dfe8970.setContent(html_8f5503ab0846d39163a188fe74dbf235);
#
#
#
#         marker_68b819bb8abd4cb074bfe406feebc3a9.bindPopup(popup_a161184588e52664baf0bf378dfe8970)
#         ;
#
#
#
#
#             var marker_1e1cffaa3da245a5818c10c1da449d62 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_586b49177e0564aab4d28bcacba1f9bd);
#
#
#         var popup_27f35059326debe539c9fb2dc8a1da8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5110e0b127d672f656d94b271d2f1072 = $(`&lt;div id=&quot;html_5110e0b127d672f656d94b271d2f1072&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_27f35059326debe539c9fb2dc8a1da8b.setContent(html_5110e0b127d672f656d94b271d2f1072);
#
#
#
#         marker_1e1cffaa3da245a5818c10c1da449d62.bindPopup(popup_27f35059326debe539c9fb2dc8a1da8b)
#         ;
#
#
#
#
#             var marker_62060f4af46d07f85ed39617a1036e75 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_586b49177e0564aab4d28bcacba1f9bd);
#
#
#         var popup_8613f0adcadd6a8ad8c2fa7992ce6ed2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b78eaf14f3a2eabb52c0e4faeb247a58 = $(`&lt;div id=&quot;html_b78eaf14f3a2eabb52c0e4faeb247a58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8613f0adcadd6a8ad8c2fa7992ce6ed2.setContent(html_b78eaf14f3a2eabb52c0e4faeb247a58);
#
#
#
#         marker_62060f4af46d07f85ed39617a1036e75.bindPopup(popup_8613f0adcadd6a8ad8c2fa7992ce6ed2)
#         ;
#
#
#
#
#             var marker_9b049763dae2b2b9a138fd3cf1941097 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_586b49177e0564aab4d28bcacba1f9bd);
#
#
#         var popup_2c1523c6fa583ceab412414b208f99eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d020864fa8fb0fe8b4e8f32612742d6e = $(`&lt;div id=&quot;html_d020864fa8fb0fe8b4e8f32612742d6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c1523c6fa583ceab412414b208f99eb.setContent(html_d020864fa8fb0fe8b4e8f32612742d6e);
#
#
#
#         marker_9b049763dae2b2b9a138fd3cf1941097.bindPopup(popup_2c1523c6fa583ceab412414b208f99eb)
#         ;
#
#
#
#
#             var marker_8131518ae058015f5547e2c8786ff250 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_586b49177e0564aab4d28bcacba1f9bd);
#
#
#         var popup_f09a4aedd4cb992a3c1c8ec3811b48be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_717c4686ba7864ae35495fe720c4de5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_717c4686ba7864ae35495fe720c4de5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_717c4686ba7864ae35495fe720c4de5b = L.map(
#                 &quot;map_717c4686ba7864ae35495fe720c4de5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55926e654643651b837b507326e21a43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55926e654643651b837b507326e21a43.addTo(map_717c4686ba7864ae35495fe720c4de5b);
#
#
#             var feature_group_a3df5f1cf113b1625bf78c68bf921654 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a3df5f1cf113b1625bf78c68bf921654.addTo(map_717c4686ba7864ae35495fe720c4de5b);
#
#
#             var feature_group_sub_group_c20934e9403e7a706b43077b4d018a7d = L.featureGroup.subGroup(
#                 feature_group_a3df5f1cf113b1625bf78c68bf921654
#             );
#
#
#             var marker_fd75d9a4f3771123228523a2f254f89b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c20934e9403e7a706b43077b4d018a7d);
#
#
#         var popup_179d8b0f31923d6235cf055e27fd6e42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19dd8fd0f2de8e9674df1451c7625828 = $(`&lt;div id=&quot;html_19dd8fd0f2de8e9674df1451c7625828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_179d8b0f31923d6235cf055e27fd6e42.setContent(html_19dd8fd0f2de8e9674df1451c7625828);
#
#
#
#         marker_fd75d9a4f3771123228523a2f254f89b.bindPopup(popup_179d8b0f31923d6235cf055e27fd6e42)
#         ;
#
#
#
#
#             var marker_13e7ea30c7a686da102de909b2d29910 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c20934e9403e7a706b43077b4d018a7d);
#
#
#         var popup_0fc4a2bcf5cf12b9d3cf29c287c0c941 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fee5f25ff2ecaef2f2b08dea30f8b839 = $(`&lt;div id=&quot;html_fee5f25ff2ecaef2f2b08dea30f8b839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0fc4a2bcf5cf12b9d3cf29c287c0c941.setContent(html_fee5f25ff2ecaef2f2b08dea30f8b839);
#
#
#
#         marker_13e7ea30c7a686da102de909b2d29910.bindPopup(popup_0fc4a2bcf5cf12b9d3cf29c287c0c941)
#         ;
#
#
#
#
#             var marker_8e5f436e51229877ddf2086633ff022e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c20934e9403e7a706b43077b4d018a7d);
#
#
#         var popup_b5f1ada6f784e3df92b1b953d150df09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_741e004316ea83f77d79753d3bede669 = $(`&lt;div id=&quot;html_741e004316ea83f77d79753d3bede669&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b5f1ada6f784e3df92b1b953d150df09.setContent(html_741e004316ea83f77d79753d3bede669);
#
#
#
#         marker_8e5f436e51229877ddf2086633ff022e.bindPopup(popup_b5f1ada6f784e3df92b1b953d150df09)
#         ;
#
#
#
#
#             var marker_b994834980161a0080325f1abc603ab1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c20934e9403e7a706b43077b4d018a7d);
#
#
#         var popup_15b57a838c28c99f2967fb609daa8f12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c78c29ff44810300a4d682ec476ce5c = $(`&lt;div id=&quot;html_6c78c29ff44810300a4d682ec476ce5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_15b57a838c28c99f2967fb609daa8f12.setContent(html_6c78c29ff44810300a4d682ec476ce5c);
#
#
#
#         marker_
