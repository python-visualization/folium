# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_797842f062912da45c61e52386866139 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_797842f062912da45c61e52386866139&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_797842f062912da45c61e52386866139 = L.map(
#                 &quot;map_797842f062912da45c61e52386866139&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bc27ea44b56a62f82abcc0a02bacc60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bc27ea44b56a62f82abcc0a02bacc60.addTo(map_797842f062912da45c61e52386866139);
#
#
#             var marker_a08354075d27c5d0cdca13bfb262dada = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_797842f062912da45c61e52386866139);
#
#
#         var popup_7d3d24442279cecac03483b34b69f836 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a77343621ba19c13c095c72fc9fb9e1 = $(`&lt;div id=&quot;html_7a77343621ba19c13c095c72fc9fb9e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7d3d24442279cecac03483b34b69f836.setContent(html_7a77343621ba19c13c095c72fc9fb9e1);
#
#
#
#         marker_a08354075d27c5d0cdca13bfb262dada.bindPopup(popup_7d3d24442279cecac03483b34b69f836)
#         ;
#
#
#
#
#             var marker_c729c0c7b41a95f5d9711956c0d7e710 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_797842f062912da45c61e52386866139);
#
#
#         var popup_17252720722d19093803d2fb5afc7882 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2636c0aab1c5ae7cf424874229903e9 = $(`&lt;div id=&quot;html_c2636c0aab1c5ae7cf424874229903e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_17252720722d19093803d2fb5afc7882.setContent(html_c2636c0aab1c5ae7cf424874229903e9);
#
#
#
#         marker_c729c0c7b41a95f5d9711956c0d7e710.bindPopup(popup_17252720722d19093803d2fb5afc7882)
#         ;
#
#
#
#
#             var marker_553b935c73de8088e09fdc4e70dd8651 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_797842f062912da45c61e52386866139);
#
#
#         var popup_81c4298af419fca3e89eb9038a0c06f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37649d3ea62133afbe8c3b72afb323b3 = $(`&lt;div id=&quot;html_37649d3ea62133afbe8c3b72afb323b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_81c4298af419fca3e89eb9038a0c06f1.setContent(html_37649d3ea62133afbe8c3b72afb323b3);
#
#
#
#         marker_553b935c73de8088e09fdc4e70dd8651.bindPopup(popup_81c4298af419fca3e89eb9038a0c06f1)
#         ;
#
#
#
#
#             var marker_820c79c9e73156bba4af0e7e20b01520 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_797842f062912da45c61e52386866139);
#
#
#         var popup_60d428d2ad45486eb39ea6e05a48d955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_153da5e1e89a8cb03e153c65dfd4f82c = $(`&lt;div id=&quot;html_153da5e1e89a8cb03e153c65dfd4f82c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60d428d2ad45486eb39ea6e05a48d955.setContent(html_153da5e1e89a8cb03e153c65dfd4f82c);
#
#
#
#         marker_820c79c9e73156bba4af0e7e20b01520.bindPopup(popup_60d428d2ad45486eb39ea6e05a48d955)
#         ;
#
#
#
#
#             var marker_d3cf136b9995b9f712685761d8cd82ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_797842f062912da45c61e52386866139);
#
#
#         var popup_ea67785f04b631cf713ac46b4d73487e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f627cbeb9f89f4c5d73577b50d143bb = $(`&lt;div id=&quot;html_1f627cbeb9f89f4c5d73577b50d143bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ea67785f04b631cf713ac46b4d73487e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59ed90bc82a3c954b9aad659378132bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59ed90bc82a3c954b9aad659378132bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59ed90bc82a3c954b9aad659378132bb = L.map(
#                 &quot;map_59ed90bc82a3c954b9aad659378132bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b45b6198340cbd821f56ca0e2dce4c80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b45b6198340cbd821f56ca0e2dce4c80.addTo(map_59ed90bc82a3c954b9aad659378132bb);
#
#
#             var feature_group_c00ae944c806b75d82c8236db3784c24 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_204c4786a68e37501c83bb522e093767 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c00ae944c806b75d82c8236db3784c24);
#
#
#         var popup_0186c65f84692c845d0df7a82393907a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08d37f644e8a081c9922c6826e73cba9 = $(`&lt;div id=&quot;html_08d37f644e8a081c9922c6826e73cba9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0186c65f84692c845d0df7a82393907a.setContent(html_08d37f644e8a081c9922c6826e73cba9);
#
#
#
#         marker_204c4786a68e37501c83bb522e093767.bindPopup(popup_0186c65f84692c845d0df7a82393907a)
#         ;
#
#
#
#
#             var marker_8392f917d8d3b4ab835260bb20eac56c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c00ae944c806b75d82c8236db3784c24);
#
#
#         var popup_6c8cdbb157c2352030e6526ac492989e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dcb2be0356c12dd3f1109a6acb71cad = $(`&lt;div id=&quot;html_3dcb2be0356c12dd3f1109a6acb71cad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6c8cdbb157c2352030e6526ac492989e.setContent(html_3dcb2be0356c12dd3f1109a6acb71cad);
#
#
#
#         marker_8392f917d8d3b4ab835260bb20eac56c.bindPopup(popup_6c8cdbb157c2352030e6526ac492989e)
#         ;
#
#
#
#
#             var marker_b58a3eb097feffb2341b7cd2dfeb004e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c00ae944c806b75d82c8236db3784c24);
#
#
#         var popup_a22a1617af7fe039e64ae23443738d38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc397353d02454b13532f7ce43d80c72 = $(`&lt;div id=&quot;html_bc397353d02454b13532f7ce43d80c72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a22a1617af7fe039e64ae23443738d38.setContent(html_bc397353d02454b13532f7ce43d80c72);
#
#
#
#         marker_b58a3eb097feffb2341b7cd2dfeb004e.bindPopup(popup_a22a1617af7fe039e64ae23443738d38)
#         ;
#
#
#
#
#             var marker_02e39a7745b49ba67e0214f6c9f16bf0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c00ae944c806b75d82c8236db3784c24);
#
#
#         var popup_de8c1fef6da50b8104bdada247343fe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d6bc620a96c9683fed97b7a72ed8d63 = $(`&lt;div id=&quot;html_0d6bc620a96c9683fed97b7a72ed8d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_de8c1fef6da50b8104bdada247343fe4.setContent(html_0d6bc620a96c9683fed97b7a72ed8d63);
#
#
#
#         marker_02e39a7745b49ba67e0214f6c9f16bf0.bindPopup(popup_de8c1fef6da50b8104bdada247343fe4)
#         ;
#
#
#
#
#             var marker_2ab0346b1e3384662f0c4c1ad594bb9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c00ae944c806b75d82c8236db3784c24);
#
#
#         var popup_f18b11dc3e9b70b32f2a5fb6327038f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5172c29a802ab303c692b01f90265ea5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5172c29a802ab303c692b01f90265ea5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5172c29a802ab303c692b01f90265ea5 = L.map(
#                 &quot;map_5172c29a802ab303c692b01f90265ea5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a41a53e460c9a3c6c854f832f76ad47f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a41a53e460c9a3c6c854f832f76ad47f.addTo(map_5172c29a802ab303c692b01f90265ea5);
#
#
#             var feature_group_f74b2998a113002277a211ec3ff9c23d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f74b2998a113002277a211ec3ff9c23d.addTo(map_5172c29a802ab303c692b01f90265ea5);
#
#
#             var feature_group_sub_group_f6ab464787dac9485935eb166018e787 = L.featureGroup.subGroup(
#                 feature_group_f74b2998a113002277a211ec3ff9c23d
#             );
#
#
#             var marker_949acf5cc495f41589b0ee8562c74d6d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6ab464787dac9485935eb166018e787);
#
#
#         var popup_3e14de7333d984576269d170089d0fa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1ba54948c126d41c9f3c226c660f53e = $(`&lt;div id=&quot;html_d1ba54948c126d41c9f3c226c660f53e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3e14de7333d984576269d170089d0fa9.setContent(html_d1ba54948c126d41c9f3c226c660f53e);
#
#
#
#         marker_949acf5cc495f41589b0ee8562c74d6d.bindPopup(popup_3e14de7333d984576269d170089d0fa9)
#         ;
#
#
#
#
#             var marker_cf2de9d1adefbd8566b8e7c3bfdf99f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6ab464787dac9485935eb166018e787);
#
#
#         var popup_0c85eb7c826c3a65506b8d6e36278fe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72928fc64e6fde696a2bb0090b096a60 = $(`&lt;div id=&quot;html_72928fc64e6fde696a2bb0090b096a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0c85eb7c826c3a65506b8d6e36278fe1.setContent(html_72928fc64e6fde696a2bb0090b096a60);
#
#
#
#         marker_cf2de9d1adefbd8566b8e7c3bfdf99f9.bindPopup(popup_0c85eb7c826c3a65506b8d6e36278fe1)
#         ;
#
#
#
#
#             var marker_f516fa55d85cf9009ce06786973d631e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6ab464787dac9485935eb166018e787);
#
#
#         var popup_c7df89d210880ff25ae955b4b6b42231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_934c09553a4da6504f751eeec7e6d7d6 = $(`&lt;div id=&quot;html_934c09553a4da6504f751eeec7e6d7d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c7df89d210880ff25ae955b4b6b42231.setContent(html_934c09553a4da6504f751eeec7e6d7d6);
#
#
#
#         marker_f516fa55d85cf9009ce06786973d631e.bindPopup(popup_c7df89d210880ff25ae955b4b6b42231)
#         ;
#
#
#
#
#             var marker_42a75b3421d7a6db77b226e32367f107 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6ab464787dac9485935eb166018e787);
#
#
#         var popup_6b21aaa43ad12bb57fc39c5cfa52bfa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_694f39756042ead9ff335a851a0e34d3 = $(`&lt;div id=&quot;html_694f39756042ead9ff335a851a0e34d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6b21aaa43ad12bb57fc39c5cfa52bfa4.setContent(html_694f39756042ead9ff335a851a0e34d3);
#
#
#
#         marker_
