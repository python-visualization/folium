# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e1fe0a9f5c38a87e254ea9068e14461 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e1fe0a9f5c38a87e254ea9068e14461&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e1fe0a9f5c38a87e254ea9068e14461 = L.map(
#                 &quot;map_7e1fe0a9f5c38a87e254ea9068e14461&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78ab5f993be77939ea6bcc23618dcc1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78ab5f993be77939ea6bcc23618dcc1a.addTo(map_7e1fe0a9f5c38a87e254ea9068e14461);
#
#
#             var marker_31f0a9c69e84b74f991a254e22482c92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7e1fe0a9f5c38a87e254ea9068e14461);
#
#
#         var popup_6f28bbd99d1d66cdb808538ac4264481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0dfeb05d6980361328f01e2582cfb8d = $(`&lt;div id=&quot;html_e0dfeb05d6980361328f01e2582cfb8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6f28bbd99d1d66cdb808538ac4264481.setContent(html_e0dfeb05d6980361328f01e2582cfb8d);
#
#
#
#         marker_31f0a9c69e84b74f991a254e22482c92.bindPopup(popup_6f28bbd99d1d66cdb808538ac4264481)
#         ;
#
#
#
#
#             var marker_75302ba7cbc3a3c1fe13db1c2fcb3939 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7e1fe0a9f5c38a87e254ea9068e14461);
#
#
#         var popup_a56141b7219797f5ded7be9de59aaf03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46f8afc7bf971ce85fac1ec305811141 = $(`&lt;div id=&quot;html_46f8afc7bf971ce85fac1ec305811141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a56141b7219797f5ded7be9de59aaf03.setContent(html_46f8afc7bf971ce85fac1ec305811141);
#
#
#
#         marker_75302ba7cbc3a3c1fe13db1c2fcb3939.bindPopup(popup_a56141b7219797f5ded7be9de59aaf03)
#         ;
#
#
#
#
#             var marker_58df3fd2c64dd42623bddfa43d335079 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7e1fe0a9f5c38a87e254ea9068e14461);
#
#
#         var popup_2d2ba6f0d5900aab973a34000cf8cced = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9588b27856fb843bf51937f71c042453 = $(`&lt;div id=&quot;html_9588b27856fb843bf51937f71c042453&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2d2ba6f0d5900aab973a34000cf8cced.setContent(html_9588b27856fb843bf51937f71c042453);
#
#
#
#         marker_58df3fd2c64dd42623bddfa43d335079.bindPopup(popup_2d2ba6f0d5900aab973a34000cf8cced)
#         ;
#
#
#
#
#             var marker_a551c6ff4d9b222b5c45ce129e8d4f8c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7e1fe0a9f5c38a87e254ea9068e14461);
#
#
#         var popup_ddc1f9e69e7a3a6018ac190c22d5ad56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e39135efe3420ab9a8ef23727f4cdf5 = $(`&lt;div id=&quot;html_9e39135efe3420ab9a8ef23727f4cdf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ddc1f9e69e7a3a6018ac190c22d5ad56.setContent(html_9e39135efe3420ab9a8ef23727f4cdf5);
#
#
#
#         marker_a551c6ff4d9b222b5c45ce129e8d4f8c.bindPopup(popup_ddc1f9e69e7a3a6018ac190c22d5ad56)
#         ;
#
#
#
#
#             var marker_426a9d6c77155462c1de478c4446b363 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7e1fe0a9f5c38a87e254ea9068e14461);
#
#
#         var popup_9c61f64c171ecd212ae87df1538bdabb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0082b100041d46521cacfb5e0ea4273 = $(`&lt;div id=&quot;html_e0082b100041d46521cacfb5e0ea4273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9c61f64c171ecd212ae87df1538bda

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35a37c93bba2ebf9e5a8adc027892a15 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35a37c93bba2ebf9e5a8adc027892a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35a37c93bba2ebf9e5a8adc027892a15 = L.map(
#                 &quot;map_35a37c93bba2ebf9e5a8adc027892a15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a22cd6af77f3394f8863be01fa40c9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a22cd6af77f3394f8863be01fa40c9b.addTo(map_35a37c93bba2ebf9e5a8adc027892a15);
#
#
#             var feature_group_9ceb4232435adba97a7119769dbcc330 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1843d700f48ae393f3eb36e5a19ea750 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9ceb4232435adba97a7119769dbcc330);
#
#
#         var popup_816b4244bf78cbfe2646bd4c6e26aead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_627127a2faf9ac3df902efc1cda10c08 = $(`&lt;div id=&quot;html_627127a2faf9ac3df902efc1cda10c08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_816b4244bf78cbfe2646bd4c6e26aead.setContent(html_627127a2faf9ac3df902efc1cda10c08);
#
#
#
#         marker_1843d700f48ae393f3eb36e5a19ea750.bindPopup(popup_816b4244bf78cbfe2646bd4c6e26aead)
#         ;
#
#
#
#
#             var marker_0d5bbd83db4495821ff00d813725b44b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9ceb4232435adba97a7119769dbcc330);
#
#
#         var popup_398ce462d3f1f504c0ab4519777db88e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98c5dc089e481d83bf4bea78bc9b2b96 = $(`&lt;div id=&quot;html_98c5dc089e481d83bf4bea78bc9b2b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_398ce462d3f1f504c0ab4519777db88e.setContent(html_98c5dc089e481d83bf4bea78bc9b2b96);
#
#
#
#         marker_0d5bbd83db4495821ff00d813725b44b.bindPopup(popup_398ce462d3f1f504c0ab4519777db88e)
#         ;
#
#
#
#
#             var marker_14e12c03ef6251fd004e498fdacea835 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9ceb4232435adba97a7119769dbcc330);
#
#
#         var popup_84e7da45db0df23f09108a72ea13dfc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f41458e80f60be347b699498d17ed77b = $(`&lt;div id=&quot;html_f41458e80f60be347b699498d17ed77b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_84e7da45db0df23f09108a72ea13dfc3.setContent(html_f41458e80f60be347b699498d17ed77b);
#
#
#
#         marker_14e12c03ef6251fd004e498fdacea835.bindPopup(popup_84e7da45db0df23f09108a72ea13dfc3)
#         ;
#
#
#
#
#             var marker_1e153bb9af7f780732eb5b40f3946cd5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9ceb4232435adba97a7119769dbcc330);
#
#
#         var popup_0cd98613fd20bb2bfe5cdfcc5d08ce0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57e2e4d72b7302f2fa471abbad33fdaa = $(`&lt;div id=&quot;html_57e2e4d72b7302f2fa471abbad33fdaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0cd98613fd20bb2bfe5cdfcc5d08ce0c.setContent(html_57e2e4d72b7302f2fa471abbad33fdaa);
#
#
#
#         marker_1e153bb9af7f780732eb5b40f3946cd5.bindPopup(popup_0cd98613fd20bb2bfe5cdfcc5d08ce0c)
#         ;
#
#
#
#
#             var marker_f48a1e4fea867d779be618480b2d297f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9ceb4232435adba97a7119769dbcc330);
#
#
#         var popup_9b3476f72a4bc37b6116bdd144c32cac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84d65f30220dfdf22468e401b24661fe {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84d65f30220dfdf22468e401b24661fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84d65f30220dfdf22468e401b24661fe = L.map(
#                 &quot;map_84d65f30220dfdf22468e401b24661fe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_046659d2a15bbcb6c1f98f5bfd8a5535 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_046659d2a15bbcb6c1f98f5bfd8a5535.addTo(map_84d65f30220dfdf22468e401b24661fe);
#
#
#             var feature_group_7597eb7350f9c4445ac0071cadec74ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7597eb7350f9c4445ac0071cadec74ac.addTo(map_84d65f30220dfdf22468e401b24661fe);
#
#
#             var feature_group_sub_group_9e2ec01aff819047eaa1b107583b6ca6 = L.featureGroup.subGroup(
#                 feature_group_7597eb7350f9c4445ac0071cadec74ac
#             );
#
#
#             var marker_a44c045d74b872fc2303b186b9015446 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e2ec01aff819047eaa1b107583b6ca6);
#
#
#         var popup_f25e302a115fc433b2e5a66e2b4c0d22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3004615de713b7e2b1edfc52f03b1fa4 = $(`&lt;div id=&quot;html_3004615de713b7e2b1edfc52f03b1fa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f25e302a115fc433b2e5a66e2b4c0d22.setContent(html_3004615de713b7e2b1edfc52f03b1fa4);
#
#
#
#         marker_a44c045d74b872fc2303b186b9015446.bindPopup(popup_f25e302a115fc433b2e5a66e2b4c0d22)
#         ;
#
#
#
#
#             var marker_ce7266a068a2f6cb1e38277956095584 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e2ec01aff819047eaa1b107583b6ca6);
#
#
#         var popup_7abb4d6ae1cc0c8797b15ac709af1905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9b0553aa44464d2cf10d00a603a59c6 = $(`&lt;div id=&quot;html_b9b0553aa44464d2cf10d00a603a59c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7abb4d6ae1cc0c8797b15ac709af1905.setContent(html_b9b0553aa44464d2cf10d00a603a59c6);
#
#
#
#         marker_ce7266a068a2f6cb1e38277956095584.bindPopup(popup_7abb4d6ae1cc0c8797b15ac709af1905)
#         ;
#
#
#
#
#             var marker_ddb2f9bbad94f03f16cfd43411e74c95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e2ec01aff819047eaa1b107583b6ca6);
#
#
#         var popup_0a3ef81830d594f20a7ece679febbb82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb05f9fb76dc367491cc71310fbf3350 = $(`&lt;div id=&quot;html_bb05f9fb76dc367491cc71310fbf3350&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0a3ef81830d594f20a7ece679febbb82.setContent(html_bb05f9fb76dc367491cc71310fbf3350);
#
#
#
#         marker_ddb2f9bbad94f03f16cfd43411e74c95.bindPopup(popup_0a3ef81830d594f20a7ece679febbb82)
#         ;
#
#
#
#
#             var marker_8397c68c7d3894c7ceedb6411bd6e201 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e2ec01aff819047eaa1b107583b6ca6);
#
#
#         var popup_a28d01ea96e6f4910873e1ccd0494fd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a78aea42d3815f51085030b472cf7635 = $(`&lt;div id=&quot;html_a78aea42d3815f51085030b472cf7635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a28d01ea96e6f4910873e1ccd0494fd5.setContent(html_a78aea42d3815f51085030b472cf7635);
#
#
#
#         mark
