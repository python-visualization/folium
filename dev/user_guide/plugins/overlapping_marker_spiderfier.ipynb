# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5b0e64e9f799a0c76e399d2b07a08d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5b0e64e9f799a0c76e399d2b07a08d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5b0e64e9f799a0c76e399d2b07a08d7 = L.map(
#                 &quot;map_c5b0e64e9f799a0c76e399d2b07a08d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ce3fb24d93c4b7e147c9bbaa0c3022f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ce3fb24d93c4b7e147c9bbaa0c3022f.addTo(map_c5b0e64e9f799a0c76e399d2b07a08d7);
#
#
#             var marker_00f92a78100c62b7bd3d49256bd1e182 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c5b0e64e9f799a0c76e399d2b07a08d7);
#
#
#         var popup_cdbdcf694e9266b64e7f1db3703da00a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e7a7776b567d61a4bba6db3d8211475 = $(`&lt;div id=&quot;html_5e7a7776b567d61a4bba6db3d8211475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cdbdcf694e9266b64e7f1db3703da00a.setContent(html_5e7a7776b567d61a4bba6db3d8211475);
#
#
#
#         marker_00f92a78100c62b7bd3d49256bd1e182.bindPopup(popup_cdbdcf694e9266b64e7f1db3703da00a)
#         ;
#
#
#
#
#             var marker_a743f51ccaa61e519d3eae0fc3df21b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c5b0e64e9f799a0c76e399d2b07a08d7);
#
#
#         var popup_eaa72a34efb74983d26ff347500af98c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5861ed57047172ad7b9e391a9c03410a = $(`&lt;div id=&quot;html_5861ed57047172ad7b9e391a9c03410a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eaa72a34efb74983d26ff347500af98c.setContent(html_5861ed57047172ad7b9e391a9c03410a);
#
#
#
#         marker_a743f51ccaa61e519d3eae0fc3df21b9.bindPopup(popup_eaa72a34efb74983d26ff347500af98c)
#         ;
#
#
#
#
#             var marker_d212920ce734e2fc7a17427c48614aab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c5b0e64e9f799a0c76e399d2b07a08d7);
#
#
#         var popup_1ca64464c41c37daff0864b04b1bce0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_870bd4ab3105e79de37d074fa32e4f79 = $(`&lt;div id=&quot;html_870bd4ab3105e79de37d074fa32e4f79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1ca64464c41c37daff0864b04b1bce0f.setContent(html_870bd4ab3105e79de37d074fa32e4f79);
#
#
#
#         marker_d212920ce734e2fc7a17427c48614aab.bindPopup(popup_1ca64464c41c37daff0864b04b1bce0f)
#         ;
#
#
#
#
#             var marker_ea8a006c68d59a62a878c09c180def34 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c5b0e64e9f799a0c76e399d2b07a08d7);
#
#
#         var popup_57259db1b983e2ec929f2d7fd3ac85bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_323ba279c3815f60601d3fd9c4d9bcda = $(`&lt;div id=&quot;html_323ba279c3815f60601d3fd9c4d9bcda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_57259db1b983e2ec929f2d7fd3ac85bb.setContent(html_323ba279c3815f60601d3fd9c4d9bcda);
#
#
#
#         marker_ea8a006c68d59a62a878c09c180def34.bindPopup(popup_57259db1b983e2ec929f2d7fd3ac85bb)
#         ;
#
#
#
#
#             var marker_2adec6bca9d9d9b38fa22c73400cd079 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c5b0e64e9f799a0c76e399d2b07a08d7);
#
#
#         var popup_8144173ec909fd8aeb58ae70217c0dc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c24e2a1b96751484cc2b23bc313fa46a = $(`&lt;div id=&quot;html_c24e2a1b96751484cc2b23bc313fa46a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8144173ec909fd8aeb58ae70217c0dc0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49cb40a63424906113e5ddebdbd72dc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49cb40a63424906113e5ddebdbd72dc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49cb40a63424906113e5ddebdbd72dc0 = L.map(
#                 &quot;map_49cb40a63424906113e5ddebdbd72dc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c1036c753593d40ba361afccf50b394 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c1036c753593d40ba361afccf50b394.addTo(map_49cb40a63424906113e5ddebdbd72dc0);
#
#
#             var feature_group_b209563fe69dddd7371da581c361b54d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ac804e4b62af7363fde564150db98be0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b209563fe69dddd7371da581c361b54d);
#
#
#         var popup_3cb860055a1a2b1d8656cba93c523ffd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f725d861ef0606f02a3e81493bd84220 = $(`&lt;div id=&quot;html_f725d861ef0606f02a3e81493bd84220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3cb860055a1a2b1d8656cba93c523ffd.setContent(html_f725d861ef0606f02a3e81493bd84220);
#
#
#
#         marker_ac804e4b62af7363fde564150db98be0.bindPopup(popup_3cb860055a1a2b1d8656cba93c523ffd)
#         ;
#
#
#
#
#             var marker_fb94d5e8ea1bcfb79a6431ebfad91845 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b209563fe69dddd7371da581c361b54d);
#
#
#         var popup_6be807a1fa69100c183cc445e85ac7db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59aedf4cad934f3b6613eeb68cea88fd = $(`&lt;div id=&quot;html_59aedf4cad934f3b6613eeb68cea88fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6be807a1fa69100c183cc445e85ac7db.setContent(html_59aedf4cad934f3b6613eeb68cea88fd);
#
#
#
#         marker_fb94d5e8ea1bcfb79a6431ebfad91845.bindPopup(popup_6be807a1fa69100c183cc445e85ac7db)
#         ;
#
#
#
#
#             var marker_c2eb35d8d2d3de944e78b28a2f640903 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b209563fe69dddd7371da581c361b54d);
#
#
#         var popup_0ed60b11947e4387a8e0cfc1a76287ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de29f1806dd6eb943cab17739bc09442 = $(`&lt;div id=&quot;html_de29f1806dd6eb943cab17739bc09442&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0ed60b11947e4387a8e0cfc1a76287ad.setContent(html_de29f1806dd6eb943cab17739bc09442);
#
#
#
#         marker_c2eb35d8d2d3de944e78b28a2f640903.bindPopup(popup_0ed60b11947e4387a8e0cfc1a76287ad)
#         ;
#
#
#
#
#             var marker_fcc17cd709c9f77e915ae3ba26ad8a8e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b209563fe69dddd7371da581c361b54d);
#
#
#         var popup_c85fbb427e89b7769b4c7da59a9c08d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27ba74cefe2de9a21012e1d340ea57a1 = $(`&lt;div id=&quot;html_27ba74cefe2de9a21012e1d340ea57a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c85fbb427e89b7769b4c7da59a9c08d2.setContent(html_27ba74cefe2de9a21012e1d340ea57a1);
#
#
#
#         marker_fcc17cd709c9f77e915ae3ba26ad8a8e.bindPopup(popup_c85fbb427e89b7769b4c7da59a9c08d2)
#         ;
#
#
#
#
#             var marker_2d2d7f40a36151bc675dc2a0b013561c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b209563fe69dddd7371da581c361b54d);
#
#
#         var popup_8b7bbb620f55484a5b34b6297894eeeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4552629c1638d1c001282d5e5f0d7824 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4552629c1638d1c001282d5e5f0d7824&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4552629c1638d1c001282d5e5f0d7824 = L.map(
#                 &quot;map_4552629c1638d1c001282d5e5f0d7824&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f30b2b733e3b11abde12425ab1691b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f30b2b733e3b11abde12425ab1691b0.addTo(map_4552629c1638d1c001282d5e5f0d7824);
#
#
#             var feature_group_a716cefd7243865747a58c83123bd7e5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a716cefd7243865747a58c83123bd7e5.addTo(map_4552629c1638d1c001282d5e5f0d7824);
#
#
#             var feature_group_sub_group_90f95f2312616a7c34f35a4ee699d4a9 = L.featureGroup.subGroup(
#                 feature_group_a716cefd7243865747a58c83123bd7e5
#             );
#
#
#             var marker_965ab6eb07f5b649ac5f861bd44a5b4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_90f95f2312616a7c34f35a4ee699d4a9);
#
#
#         var popup_b9a5937f44ecf41ea27a85e961d30f88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e816c424b5a6c3dcb82ca1a259f30ffe = $(`&lt;div id=&quot;html_e816c424b5a6c3dcb82ca1a259f30ffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b9a5937f44ecf41ea27a85e961d30f88.setContent(html_e816c424b5a6c3dcb82ca1a259f30ffe);
#
#
#
#         marker_965ab6eb07f5b649ac5f861bd44a5b4d.bindPopup(popup_b9a5937f44ecf41ea27a85e961d30f88)
#         ;
#
#
#
#
#             var marker_ce9f972bd6e86130e2d23fb166caf8a2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_90f95f2312616a7c34f35a4ee699d4a9);
#
#
#         var popup_0d7fbb7c15df25e4f83f1f2486bbe5df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2906fda89bb91bf79653fd77d7bab539 = $(`&lt;div id=&quot;html_2906fda89bb91bf79653fd77d7bab539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0d7fbb7c15df25e4f83f1f2486bbe5df.setContent(html_2906fda89bb91bf79653fd77d7bab539);
#
#
#
#         marker_ce9f972bd6e86130e2d23fb166caf8a2.bindPopup(popup_0d7fbb7c15df25e4f83f1f2486bbe5df)
#         ;
#
#
#
#
#             var marker_abaf23acd5392de7ebe6e596f3ade7d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_90f95f2312616a7c34f35a4ee699d4a9);
#
#
#         var popup_3731f4d4054fa9e0f3ec2426908d6637 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b099cd23ba5f7d3f702db86abf77c3a = $(`&lt;div id=&quot;html_6b099cd23ba5f7d3f702db86abf77c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3731f4d4054fa9e0f3ec2426908d6637.setContent(html_6b099cd23ba5f7d3f702db86abf77c3a);
#
#
#
#         marker_abaf23acd5392de7ebe6e596f3ade7d3.bindPopup(popup_3731f4d4054fa9e0f3ec2426908d6637)
#         ;
#
#
#
#
#             var marker_4d1719c3abec6584c32a91257ce4d988 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_90f95f2312616a7c34f35a4ee699d4a9);
#
#
#         var popup_adbafe2c7dbaab190abe3378bec22d38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be81c82ac30a64edeced517ad82edf3d = $(`&lt;div id=&quot;html_be81c82ac30a64edeced517ad82edf3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_adbafe2c7dbaab190abe3378bec22d38.setContent(html_be81c82ac30a64edeced517ad82edf3d);
#
#
#
#         marker_
