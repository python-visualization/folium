# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6ffd9b027cd54315e8cc2a4e29405f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6ffd9b027cd54315e8cc2a4e29405f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6ffd9b027cd54315e8cc2a4e29405f1 = L.map(
#                 &quot;map_b6ffd9b027cd54315e8cc2a4e29405f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df69bc8e8740382344cda20b4b9d58a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df69bc8e8740382344cda20b4b9d58a5.addTo(map_b6ffd9b027cd54315e8cc2a4e29405f1);
#
#
#             var marker_f546304a181b4c973f093c26b85294f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b6ffd9b027cd54315e8cc2a4e29405f1);
#
#
#         var popup_049cb39aacbac8c4d8cbf1c2735da37c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68dd89040c6abf475bba29249da82da0 = $(`&lt;div id=&quot;html_68dd89040c6abf475bba29249da82da0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_049cb39aacbac8c4d8cbf1c2735da37c.setContent(html_68dd89040c6abf475bba29249da82da0);
#
#
#
#         marker_f546304a181b4c973f093c26b85294f3.bindPopup(popup_049cb39aacbac8c4d8cbf1c2735da37c)
#         ;
#
#
#
#
#             var marker_c765b7d1b262c4ed3a5e466c91477f7b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b6ffd9b027cd54315e8cc2a4e29405f1);
#
#
#         var popup_9fcebc502c35f4967418669fb0658df1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93a42d834d4225bab7940c384a0e07c3 = $(`&lt;div id=&quot;html_93a42d834d4225bab7940c384a0e07c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9fcebc502c35f4967418669fb0658df1.setContent(html_93a42d834d4225bab7940c384a0e07c3);
#
#
#
#         marker_c765b7d1b262c4ed3a5e466c91477f7b.bindPopup(popup_9fcebc502c35f4967418669fb0658df1)
#         ;
#
#
#
#
#             var marker_8ad6349d692262925d7a6d4324ad167d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b6ffd9b027cd54315e8cc2a4e29405f1);
#
#
#         var popup_f72c881b9db7e026172f2b2fc433f0da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b99e7a797736bf3373bb1f68fe9f13bf = $(`&lt;div id=&quot;html_b99e7a797736bf3373bb1f68fe9f13bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f72c881b9db7e026172f2b2fc433f0da.setContent(html_b99e7a797736bf3373bb1f68fe9f13bf);
#
#
#
#         marker_8ad6349d692262925d7a6d4324ad167d.bindPopup(popup_f72c881b9db7e026172f2b2fc433f0da)
#         ;
#
#
#
#
#             var marker_88cd35050dbe5d759689bb63db9ad684 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b6ffd9b027cd54315e8cc2a4e29405f1);
#
#
#         var popup_820173dde374ec68c34dd1a66378794b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd489a4e5436ea399c6a219121f3ad7a = $(`&lt;div id=&quot;html_fd489a4e5436ea399c6a219121f3ad7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_820173dde374ec68c34dd1a66378794b.setContent(html_fd489a4e5436ea399c6a219121f3ad7a);
#
#
#
#         marker_88cd35050dbe5d759689bb63db9ad684.bindPopup(popup_820173dde374ec68c34dd1a66378794b)
#         ;
#
#
#
#
#             var marker_ce81b956f54cbd679c839adc2b279b0e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b6ffd9b027cd54315e8cc2a4e29405f1);
#
#
#         var popup_eb21e49716f66d741dc0e87b482635e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_466cecf275de709ba59febb253c4671d = $(`&lt;div id=&quot;html_466cecf275de709ba59febb253c4671d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eb21e49716f66d741dc0e87b482635e8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50e318f48ca1bda6b040281f90136435 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50e318f48ca1bda6b040281f90136435&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50e318f48ca1bda6b040281f90136435 = L.map(
#                 &quot;map_50e318f48ca1bda6b040281f90136435&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a3acd3152a82b62dd6a49c2d7403e4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a3acd3152a82b62dd6a49c2d7403e4c.addTo(map_50e318f48ca1bda6b040281f90136435);
#
#
#             var feature_group_da6441fe0dc9102c07ae8e161ab36962 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_93eae01eafa9a8aa72e044a1d802e719 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_da6441fe0dc9102c07ae8e161ab36962);
#
#
#         var popup_1a62a57a4987341e801e105e95148698 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fac7239de107b04b5a971bf97bc2585a = $(`&lt;div id=&quot;html_fac7239de107b04b5a971bf97bc2585a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1a62a57a4987341e801e105e95148698.setContent(html_fac7239de107b04b5a971bf97bc2585a);
#
#
#
#         marker_93eae01eafa9a8aa72e044a1d802e719.bindPopup(popup_1a62a57a4987341e801e105e95148698)
#         ;
#
#
#
#
#             var marker_87baf449533cd81492d59a4ab02faa42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_da6441fe0dc9102c07ae8e161ab36962);
#
#
#         var popup_b8b10ded4429f6c4d8a4049857bf9762 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f2042a6964355749d36c82d31e7e47d = $(`&lt;div id=&quot;html_7f2042a6964355749d36c82d31e7e47d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b8b10ded4429f6c4d8a4049857bf9762.setContent(html_7f2042a6964355749d36c82d31e7e47d);
#
#
#
#         marker_87baf449533cd81492d59a4ab02faa42.bindPopup(popup_b8b10ded4429f6c4d8a4049857bf9762)
#         ;
#
#
#
#
#             var marker_ba43446a067950f7951c20d110cb4519 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_da6441fe0dc9102c07ae8e161ab36962);
#
#
#         var popup_babcde1c7e3b75ceb8042ee866dcf1ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b775a216d78e348ad32c2dcdf112fa3b = $(`&lt;div id=&quot;html_b775a216d78e348ad32c2dcdf112fa3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_babcde1c7e3b75ceb8042ee866dcf1ab.setContent(html_b775a216d78e348ad32c2dcdf112fa3b);
#
#
#
#         marker_ba43446a067950f7951c20d110cb4519.bindPopup(popup_babcde1c7e3b75ceb8042ee866dcf1ab)
#         ;
#
#
#
#
#             var marker_f5f97150a0b5c67fde4b186a25a834b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_da6441fe0dc9102c07ae8e161ab36962);
#
#
#         var popup_f9aad67ba9e882bb05ec9aed4d798999 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e3ebfa6212950e74cf3a7e0a5639d3e = $(`&lt;div id=&quot;html_9e3ebfa6212950e74cf3a7e0a5639d3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f9aad67ba9e882bb05ec9aed4d798999.setContent(html_9e3ebfa6212950e74cf3a7e0a5639d3e);
#
#
#
#         marker_f5f97150a0b5c67fde4b186a25a834b4.bindPopup(popup_f9aad67ba9e882bb05ec9aed4d798999)
#         ;
#
#
#
#
#             var marker_45b53b089f75ab54392e9773e1180151 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_da6441fe0dc9102c07ae8e161ab36962);
#
#
#         var popup_780751be7c1c21e65ac77f4c04e29116 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d30f4aa2483d9fb859d5eeaabeec6d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d30f4aa2483d9fb859d5eeaabeec6d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d30f4aa2483d9fb859d5eeaabeec6d6 = L.map(
#                 &quot;map_5d30f4aa2483d9fb859d5eeaabeec6d6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c28573688bc3891f0460dfb259861aea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c28573688bc3891f0460dfb259861aea.addTo(map_5d30f4aa2483d9fb859d5eeaabeec6d6);
#
#
#             var feature_group_478e65b7eccd15c5a0fb0627c1870806 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_478e65b7eccd15c5a0fb0627c1870806.addTo(map_5d30f4aa2483d9fb859d5eeaabeec6d6);
#
#
#             var feature_group_sub_group_21dd11092bef709089a6a30d107ce4b1 = L.featureGroup.subGroup(
#                 feature_group_478e65b7eccd15c5a0fb0627c1870806
#             );
#
#
#             var marker_651f2102293db95e70107a6b57eef8f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_21dd11092bef709089a6a30d107ce4b1);
#
#
#         var popup_f0860a29318601f448c43fc30130149d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccf59c5fc5cbd325c930cda47a50a436 = $(`&lt;div id=&quot;html_ccf59c5fc5cbd325c930cda47a50a436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f0860a29318601f448c43fc30130149d.setContent(html_ccf59c5fc5cbd325c930cda47a50a436);
#
#
#
#         marker_651f2102293db95e70107a6b57eef8f0.bindPopup(popup_f0860a29318601f448c43fc30130149d)
#         ;
#
#
#
#
#             var marker_1f9961099d571442bced2486542772f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_21dd11092bef709089a6a30d107ce4b1);
#
#
#         var popup_ba7a0c6f9feb8fc4979e9651667f5480 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f73e7ff35cd05123f8b5229f75ea6cfe = $(`&lt;div id=&quot;html_f73e7ff35cd05123f8b5229f75ea6cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ba7a0c6f9feb8fc4979e9651667f5480.setContent(html_f73e7ff35cd05123f8b5229f75ea6cfe);
#
#
#
#         marker_1f9961099d571442bced2486542772f6.bindPopup(popup_ba7a0c6f9feb8fc4979e9651667f5480)
#         ;
#
#
#
#
#             var marker_3783042f6df1bb6a95e18a40b4778154 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_21dd11092bef709089a6a30d107ce4b1);
#
#
#         var popup_23e18d9b61e40a041a24545de12161f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69c919dde66213b76f821be0a5bd95c3 = $(`&lt;div id=&quot;html_69c919dde66213b76f821be0a5bd95c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_23e18d9b61e40a041a24545de12161f7.setContent(html_69c919dde66213b76f821be0a5bd95c3);
#
#
#
#         marker_3783042f6df1bb6a95e18a40b4778154.bindPopup(popup_23e18d9b61e40a041a24545de12161f7)
#         ;
#
#
#
#
#             var marker_cd8a118bebdfc445a7e0f30a07985f23 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_21dd11092bef709089a6a30d107ce4b1);
#
#
#         var popup_78771f14ec31f311e88df95b72690e6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ac276d0641625a430745ee09fa5192f = $(`&lt;div id=&quot;html_3ac276d0641625a430745ee09fa5192f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_78771f14ec31f311e88df95b72690e6c.setContent(html_3ac276d0641625a430745ee09fa5192f);
#
#
#
#         marker_
