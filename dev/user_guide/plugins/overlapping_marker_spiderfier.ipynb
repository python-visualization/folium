# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c22f32b3ebde3c4b645e939ae9dc67d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c22f32b3ebde3c4b645e939ae9dc67d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c22f32b3ebde3c4b645e939ae9dc67d8 = L.map(
#                 &quot;map_c22f32b3ebde3c4b645e939ae9dc67d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04086f389a9173b2bc16a578a32053f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04086f389a9173b2bc16a578a32053f9.addTo(map_c22f32b3ebde3c4b645e939ae9dc67d8);
#
#
#             var marker_fc53c46d0e8086f7e849033e172c49ad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c22f32b3ebde3c4b645e939ae9dc67d8);
#
#
#         var popup_8e391566b0370e8e8477380301adf0d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15bfd3fa82603eab718269d73473b9c3 = $(`&lt;div id=&quot;html_15bfd3fa82603eab718269d73473b9c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8e391566b0370e8e8477380301adf0d5.setContent(html_15bfd3fa82603eab718269d73473b9c3);
#
#
#
#         marker_fc53c46d0e8086f7e849033e172c49ad.bindPopup(popup_8e391566b0370e8e8477380301adf0d5)
#         ;
#
#
#
#
#             var marker_91e0b63c815096d4e73804c7c9914146 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c22f32b3ebde3c4b645e939ae9dc67d8);
#
#
#         var popup_6141f2cdf7e9207886778ea4bd4fb766 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29ce9312026b96537db1cb4020a19db3 = $(`&lt;div id=&quot;html_29ce9312026b96537db1cb4020a19db3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6141f2cdf7e9207886778ea4bd4fb766.setContent(html_29ce9312026b96537db1cb4020a19db3);
#
#
#
#         marker_91e0b63c815096d4e73804c7c9914146.bindPopup(popup_6141f2cdf7e9207886778ea4bd4fb766)
#         ;
#
#
#
#
#             var marker_933edfd407c757247ef024cc47ff64a7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c22f32b3ebde3c4b645e939ae9dc67d8);
#
#
#         var popup_d7135cd1f082e4bfa0e375358a668a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_611b3e7c4ad24b158b1bfe8fbb74fd42 = $(`&lt;div id=&quot;html_611b3e7c4ad24b158b1bfe8fbb74fd42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d7135cd1f082e4bfa0e375358a668a99.setContent(html_611b3e7c4ad24b158b1bfe8fbb74fd42);
#
#
#
#         marker_933edfd407c757247ef024cc47ff64a7.bindPopup(popup_d7135cd1f082e4bfa0e375358a668a99)
#         ;
#
#
#
#
#             var marker_882217082208374ff441eb557bb3ef6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c22f32b3ebde3c4b645e939ae9dc67d8);
#
#
#         var popup_911cc870f2a6dc2910eedd1aa6384908 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_573173a866da00f246cef9e35838a4ec = $(`&lt;div id=&quot;html_573173a866da00f246cef9e35838a4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_911cc870f2a6dc2910eedd1aa6384908.setContent(html_573173a866da00f246cef9e35838a4ec);
#
#
#
#         marker_882217082208374ff441eb557bb3ef6e.bindPopup(popup_911cc870f2a6dc2910eedd1aa6384908)
#         ;
#
#
#
#
#             var marker_3e81dd362f768ecf23dfa475cdc3ac63 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c22f32b3ebde3c4b645e939ae9dc67d8);
#
#
#         var popup_d8e751df76802a2aaff8e6de85d25dde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0be9feac43e5cab3312f7ac1e02f6658 = $(`&lt;div id=&quot;html_0be9feac43e5cab3312f7ac1e02f6658&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d8e751df76802a2aaff8e6de85d25dde.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da49456e89f8cfc6e4ad12f2f4717759 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da49456e89f8cfc6e4ad12f2f4717759&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da49456e89f8cfc6e4ad12f2f4717759 = L.map(
#                 &quot;map_da49456e89f8cfc6e4ad12f2f4717759&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38b0103f60570f9440645f5161b98e5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38b0103f60570f9440645f5161b98e5b.addTo(map_da49456e89f8cfc6e4ad12f2f4717759);
#
#
#             var feature_group_9a18b1d9e9fca4352bba61712976a26a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_90edd54666cccb49a439847d4e26e6e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9a18b1d9e9fca4352bba61712976a26a);
#
#
#         var popup_0f52136e220983cacad8145ab41d2f1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_001e29cf0a015287862add2df8b99a93 = $(`&lt;div id=&quot;html_001e29cf0a015287862add2df8b99a93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0f52136e220983cacad8145ab41d2f1a.setContent(html_001e29cf0a015287862add2df8b99a93);
#
#
#
#         marker_90edd54666cccb49a439847d4e26e6e8.bindPopup(popup_0f52136e220983cacad8145ab41d2f1a)
#         ;
#
#
#
#
#             var marker_6936cacd2c739d5e44a43eb30e15d654 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9a18b1d9e9fca4352bba61712976a26a);
#
#
#         var popup_51fd0869d335a11937aece8a1b8dd7e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f974e3b37234eabd0a37ec9ed119a7a2 = $(`&lt;div id=&quot;html_f974e3b37234eabd0a37ec9ed119a7a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_51fd0869d335a11937aece8a1b8dd7e6.setContent(html_f974e3b37234eabd0a37ec9ed119a7a2);
#
#
#
#         marker_6936cacd2c739d5e44a43eb30e15d654.bindPopup(popup_51fd0869d335a11937aece8a1b8dd7e6)
#         ;
#
#
#
#
#             var marker_d42fb137137ff822cfbadb3450ce9fed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9a18b1d9e9fca4352bba61712976a26a);
#
#
#         var popup_3aa1413b62246f09a988a66ecc1d7f0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3750dbd97a1a3385612cfdfea9251f1c = $(`&lt;div id=&quot;html_3750dbd97a1a3385612cfdfea9251f1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3aa1413b62246f09a988a66ecc1d7f0d.setContent(html_3750dbd97a1a3385612cfdfea9251f1c);
#
#
#
#         marker_d42fb137137ff822cfbadb3450ce9fed.bindPopup(popup_3aa1413b62246f09a988a66ecc1d7f0d)
#         ;
#
#
#
#
#             var marker_fedd18ce19d98bdc390d58d8beeec53f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9a18b1d9e9fca4352bba61712976a26a);
#
#
#         var popup_6d261031a451987861a82b40aaa5dd43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26bce0abdeb8a13e9e6a32fd2fa7eaf5 = $(`&lt;div id=&quot;html_26bce0abdeb8a13e9e6a32fd2fa7eaf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6d261031a451987861a82b40aaa5dd43.setContent(html_26bce0abdeb8a13e9e6a32fd2fa7eaf5);
#
#
#
#         marker_fedd18ce19d98bdc390d58d8beeec53f.bindPopup(popup_6d261031a451987861a82b40aaa5dd43)
#         ;
#
#
#
#
#             var marker_87f33a0886908ae6d9a2cd85a8d02ad2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9a18b1d9e9fca4352bba61712976a26a);
#
#
#         var popup_f995b7f1f306ad0cf55b9ee2ce31a345 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d48306d87de9847f776dd7e1774dd43f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d48306d87de9847f776dd7e1774dd43f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d48306d87de9847f776dd7e1774dd43f = L.map(
#                 &quot;map_d48306d87de9847f776dd7e1774dd43f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_377673c603923a27a50fb57e9bce9d66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_377673c603923a27a50fb57e9bce9d66.addTo(map_d48306d87de9847f776dd7e1774dd43f);
#
#
#             var feature_group_7ec0f91a61c8e11d4157e544c1e7bf3f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7ec0f91a61c8e11d4157e544c1e7bf3f.addTo(map_d48306d87de9847f776dd7e1774dd43f);
#
#
#             var feature_group_sub_group_47091b0571168de53ea81d340b54f50c = L.featureGroup.subGroup(
#                 feature_group_7ec0f91a61c8e11d4157e544c1e7bf3f
#             );
#
#
#             var marker_9814c353b52dfb4966db8349672258ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_47091b0571168de53ea81d340b54f50c);
#
#
#         var popup_2b0082beacaf0db161f74ac3621c4236 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84905c09db755e347f359f3eda7eee35 = $(`&lt;div id=&quot;html_84905c09db755e347f359f3eda7eee35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2b0082beacaf0db161f74ac3621c4236.setContent(html_84905c09db755e347f359f3eda7eee35);
#
#
#
#         marker_9814c353b52dfb4966db8349672258ea.bindPopup(popup_2b0082beacaf0db161f74ac3621c4236)
#         ;
#
#
#
#
#             var marker_59a3ac245f57bd727a0b56917e6d7d7b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_47091b0571168de53ea81d340b54f50c);
#
#
#         var popup_71299addbcb47919af49e19e202ddd00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8c3f4e5aa0911ef5b559b9eed99eb5 = $(`&lt;div id=&quot;html_fc8c3f4e5aa0911ef5b559b9eed99eb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_71299addbcb47919af49e19e202ddd00.setContent(html_fc8c3f4e5aa0911ef5b559b9eed99eb5);
#
#
#
#         marker_59a3ac245f57bd727a0b56917e6d7d7b.bindPopup(popup_71299addbcb47919af49e19e202ddd00)
#         ;
#
#
#
#
#             var marker_ea12a139c14c5bebbd747161c629f6c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_47091b0571168de53ea81d340b54f50c);
#
#
#         var popup_2bc39c6195fe7fa6d55637d0badbd5a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84c10de5551557d1b74fd0f7ff120b6c = $(`&lt;div id=&quot;html_84c10de5551557d1b74fd0f7ff120b6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2bc39c6195fe7fa6d55637d0badbd5a2.setContent(html_84c10de5551557d1b74fd0f7ff120b6c);
#
#
#
#         marker_ea12a139c14c5bebbd747161c629f6c1.bindPopup(popup_2bc39c6195fe7fa6d55637d0badbd5a2)
#         ;
#
#
#
#
#             var marker_5f251ffed94bbeb30b96d87886b6deb8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_47091b0571168de53ea81d340b54f50c);
#
#
#         var popup_67e704883a94077e8f2bb3351d978f51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_077ebee77ab0c534d8af110bf8dfb97f = $(`&lt;div id=&quot;html_077ebee77ab0c534d8af110bf8dfb97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_67e704883a94077e8f2bb3351d978f51.setContent(html_077ebee77ab0c534d8af110bf8dfb97f);
#
#
#
#         marker_
