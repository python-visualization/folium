# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59755322ea4c9ca74ae174afd8ac414f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59755322ea4c9ca74ae174afd8ac414f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59755322ea4c9ca74ae174afd8ac414f = L.map(
#                 &quot;map_59755322ea4c9ca74ae174afd8ac414f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2930a16cb8999185bf5f29d2f0a7125b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2930a16cb8999185bf5f29d2f0a7125b.addTo(map_59755322ea4c9ca74ae174afd8ac414f);
#
#
#             var marker_edf75aef2a1c2c223aece9130b1e2d2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_59755322ea4c9ca74ae174afd8ac414f);
#
#
#         var popup_bf01279087fa0a8c679c89913be9ff18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf11e6f2ac4c5019ba7da8cb63dd6ecc = $(`&lt;div id=&quot;html_bf11e6f2ac4c5019ba7da8cb63dd6ecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bf01279087fa0a8c679c89913be9ff18.setContent(html_bf11e6f2ac4c5019ba7da8cb63dd6ecc);
#
#
#
#         marker_edf75aef2a1c2c223aece9130b1e2d2d.bindPopup(popup_bf01279087fa0a8c679c89913be9ff18)
#         ;
#
#
#
#
#             var marker_77c58a2a616cf7f6f6fe2164833b406b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_59755322ea4c9ca74ae174afd8ac414f);
#
#
#         var popup_6fb1d68d4b3755268d6aba0495c5dc40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f4a1453b6de1a20c63d6b6ef7ff1b5c = $(`&lt;div id=&quot;html_2f4a1453b6de1a20c63d6b6ef7ff1b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6fb1d68d4b3755268d6aba0495c5dc40.setContent(html_2f4a1453b6de1a20c63d6b6ef7ff1b5c);
#
#
#
#         marker_77c58a2a616cf7f6f6fe2164833b406b.bindPopup(popup_6fb1d68d4b3755268d6aba0495c5dc40)
#         ;
#
#
#
#
#             var marker_d8753b8805cd1ec242ac2800fc52ac0b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_59755322ea4c9ca74ae174afd8ac414f);
#
#
#         var popup_9331854cf10d7bb3a9c54fbc153564a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f53a7852b73c6dea73b85936e5325f = $(`&lt;div id=&quot;html_85f53a7852b73c6dea73b85936e5325f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9331854cf10d7bb3a9c54fbc153564a0.setContent(html_85f53a7852b73c6dea73b85936e5325f);
#
#
#
#         marker_d8753b8805cd1ec242ac2800fc52ac0b.bindPopup(popup_9331854cf10d7bb3a9c54fbc153564a0)
#         ;
#
#
#
#
#             var marker_f5de796f52f04e41682221cbe4904f79 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_59755322ea4c9ca74ae174afd8ac414f);
#
#
#         var popup_de32abbce908f0ed86399f541dba7f3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_add19fbbe513f9ce3a503c0d2964b8e8 = $(`&lt;div id=&quot;html_add19fbbe513f9ce3a503c0d2964b8e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_de32abbce908f0ed86399f541dba7f3e.setContent(html_add19fbbe513f9ce3a503c0d2964b8e8);
#
#
#
#         marker_f5de796f52f04e41682221cbe4904f79.bindPopup(popup_de32abbce908f0ed86399f541dba7f3e)
#         ;
#
#
#
#
#             var marker_101f404ac8f9fc0212933336ee3c479a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_59755322ea4c9ca74ae174afd8ac414f);
#
#
#         var popup_fb67e2ab8f65fb048cdbf45df4427cb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_949eaef3035bef2dff631c55480cffca = $(`&lt;div id=&quot;html_949eaef3035bef2dff631c55480cffca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fb67e2ab8f65fb048cdbf45df4427cb8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcff1bf3e2fc39ecf7067ece4977e895 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcff1bf3e2fc39ecf7067ece4977e895&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcff1bf3e2fc39ecf7067ece4977e895 = L.map(
#                 &quot;map_bcff1bf3e2fc39ecf7067ece4977e895&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9232396628f9fa42b8f69bd273ec948d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9232396628f9fa42b8f69bd273ec948d.addTo(map_bcff1bf3e2fc39ecf7067ece4977e895);
#
#
#             var feature_group_a9957a9e4408fd1bb7a64577370bfbfe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e532fbe416572d4baaf75746a2dcd511 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a9957a9e4408fd1bb7a64577370bfbfe);
#
#
#         var popup_2e4f2dd52efb8026322222918d6d053c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac5a786a1d83bef5c5a7a590a51b4dde = $(`&lt;div id=&quot;html_ac5a786a1d83bef5c5a7a590a51b4dde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2e4f2dd52efb8026322222918d6d053c.setContent(html_ac5a786a1d83bef5c5a7a590a51b4dde);
#
#
#
#         marker_e532fbe416572d4baaf75746a2dcd511.bindPopup(popup_2e4f2dd52efb8026322222918d6d053c)
#         ;
#
#
#
#
#             var marker_f866786d0b3f33f613fcc2424a266116 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a9957a9e4408fd1bb7a64577370bfbfe);
#
#
#         var popup_7924dba0d7a6db8702bec2748a653d08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57f931ee0f5c60b5328410b6071d82bf = $(`&lt;div id=&quot;html_57f931ee0f5c60b5328410b6071d82bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7924dba0d7a6db8702bec2748a653d08.setContent(html_57f931ee0f5c60b5328410b6071d82bf);
#
#
#
#         marker_f866786d0b3f33f613fcc2424a266116.bindPopup(popup_7924dba0d7a6db8702bec2748a653d08)
#         ;
#
#
#
#
#             var marker_ec1db1fd2590b2ce882beb4eeacd37a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a9957a9e4408fd1bb7a64577370bfbfe);
#
#
#         var popup_bcffc955115b669cbdaf8986d3897749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e8a58fb71aee16f49fcea777874e4ef = $(`&lt;div id=&quot;html_3e8a58fb71aee16f49fcea777874e4ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bcffc955115b669cbdaf8986d3897749.setContent(html_3e8a58fb71aee16f49fcea777874e4ef);
#
#
#
#         marker_ec1db1fd2590b2ce882beb4eeacd37a6.bindPopup(popup_bcffc955115b669cbdaf8986d3897749)
#         ;
#
#
#
#
#             var marker_89dddc8742cbfd3a94609bead71745eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a9957a9e4408fd1bb7a64577370bfbfe);
#
#
#         var popup_52c3713e5b2f28404e021e693e69971e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db2ecd265024e67339b66a142721dc39 = $(`&lt;div id=&quot;html_db2ecd265024e67339b66a142721dc39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_52c3713e5b2f28404e021e693e69971e.setContent(html_db2ecd265024e67339b66a142721dc39);
#
#
#
#         marker_89dddc8742cbfd3a94609bead71745eb.bindPopup(popup_52c3713e5b2f28404e021e693e69971e)
#         ;
#
#
#
#
#             var marker_d117c3ed0d85f912517837cabda63da5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a9957a9e4408fd1bb7a64577370bfbfe);
#
#
#         var popup_c3c753f79071e095d86f27a1e3fd1b56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ceb3efcec0dbda4b41ddc4f9bdcf928d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ceb3efcec0dbda4b41ddc4f9bdcf928d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ceb3efcec0dbda4b41ddc4f9bdcf928d = L.map(
#                 &quot;map_ceb3efcec0dbda4b41ddc4f9bdcf928d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef20afdd2de0d278bdc2df3a9dee33ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef20afdd2de0d278bdc2df3a9dee33ea.addTo(map_ceb3efcec0dbda4b41ddc4f9bdcf928d);
#
#
#             var feature_group_ceec40a9f9d106258e0319f2fc709ba7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ceec40a9f9d106258e0319f2fc709ba7.addTo(map_ceb3efcec0dbda4b41ddc4f9bdcf928d);
#
#
#             var feature_group_sub_group_d8f56b1e3592218d0f41a6d0ce6f8eb4 = L.featureGroup.subGroup(
#                 feature_group_ceec40a9f9d106258e0319f2fc709ba7
#             );
#
#
#             var marker_2d36f3e970ec698610c6e99cc0932aaf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8f56b1e3592218d0f41a6d0ce6f8eb4);
#
#
#         var popup_a6a64f84461108de49250b7091c787a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddbb39ecd0a6004ae080d3371c33f843 = $(`&lt;div id=&quot;html_ddbb39ecd0a6004ae080d3371c33f843&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a6a64f84461108de49250b7091c787a2.setContent(html_ddbb39ecd0a6004ae080d3371c33f843);
#
#
#
#         marker_2d36f3e970ec698610c6e99cc0932aaf.bindPopup(popup_a6a64f84461108de49250b7091c787a2)
#         ;
#
#
#
#
#             var marker_ea7036654d99cddef723beec89c942c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8f56b1e3592218d0f41a6d0ce6f8eb4);
#
#
#         var popup_1e453a901296aef822eec343a614e105 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d89613744c8f8775457873fd0dbd8409 = $(`&lt;div id=&quot;html_d89613744c8f8775457873fd0dbd8409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1e453a901296aef822eec343a614e105.setContent(html_d89613744c8f8775457873fd0dbd8409);
#
#
#
#         marker_ea7036654d99cddef723beec89c942c3.bindPopup(popup_1e453a901296aef822eec343a614e105)
#         ;
#
#
#
#
#             var marker_e9989296d47dba941efed0934fbfefc8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8f56b1e3592218d0f41a6d0ce6f8eb4);
#
#
#         var popup_fc845dbd54e87da5aea3f0cad135f230 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8eb262099db0ac31f8943d4f0457c97 = $(`&lt;div id=&quot;html_a8eb262099db0ac31f8943d4f0457c97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fc845dbd54e87da5aea3f0cad135f230.setContent(html_a8eb262099db0ac31f8943d4f0457c97);
#
#
#
#         marker_e9989296d47dba941efed0934fbfefc8.bindPopup(popup_fc845dbd54e87da5aea3f0cad135f230)
#         ;
#
#
#
#
#             var marker_387b93199e15b12c91c203c7adbdd853 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8f56b1e3592218d0f41a6d0ce6f8eb4);
#
#
#         var popup_806d66c94d737644e443809acc9a7b1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56719fde4c4a343a72810292697d5dbc = $(`&lt;div id=&quot;html_56719fde4c4a343a72810292697d5dbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_806d66c94d737644e443809acc9a7b1e.setContent(html_56719fde4c4a343a72810292697d5dbc);
#
#
#
#         marker_
