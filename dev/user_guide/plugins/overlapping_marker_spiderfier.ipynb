# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfa9770fe03f81254cff20046209b81d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfa9770fe03f81254cff20046209b81d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfa9770fe03f81254cff20046209b81d = L.map(
#                 &quot;map_bfa9770fe03f81254cff20046209b81d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20d160e7b5136d4a9ea36b281dea613e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20d160e7b5136d4a9ea36b281dea613e.addTo(map_bfa9770fe03f81254cff20046209b81d);
#
#
#             var marker_ce447015fa221d268052c53841c79296 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bfa9770fe03f81254cff20046209b81d);
#
#
#         var popup_dab4e9d47dcf95dcc2206461218bd43a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_316a7349306361944bc38ecc5142b3a6 = $(`&lt;div id=&quot;html_316a7349306361944bc38ecc5142b3a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dab4e9d47dcf95dcc2206461218bd43a.setContent(html_316a7349306361944bc38ecc5142b3a6);
#
#
#
#         marker_ce447015fa221d268052c53841c79296.bindPopup(popup_dab4e9d47dcf95dcc2206461218bd43a)
#         ;
#
#
#
#
#             var marker_b03928f41c828624206c0ee77506074a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bfa9770fe03f81254cff20046209b81d);
#
#
#         var popup_b6bcd1c46bc2fe291c3c93423b0fd749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a372f5e402ac3bef24a6a6ac09f6a520 = $(`&lt;div id=&quot;html_a372f5e402ac3bef24a6a6ac09f6a520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b6bcd1c46bc2fe291c3c93423b0fd749.setContent(html_a372f5e402ac3bef24a6a6ac09f6a520);
#
#
#
#         marker_b03928f41c828624206c0ee77506074a.bindPopup(popup_b6bcd1c46bc2fe291c3c93423b0fd749)
#         ;
#
#
#
#
#             var marker_1cb824eb96c278cedcc107e5f8519734 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bfa9770fe03f81254cff20046209b81d);
#
#
#         var popup_4ef5b95fdbee0ac66cd56121d24c08ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d402aa9e6bd1d7411bdda30d1b62ea41 = $(`&lt;div id=&quot;html_d402aa9e6bd1d7411bdda30d1b62ea41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4ef5b95fdbee0ac66cd56121d24c08ed.setContent(html_d402aa9e6bd1d7411bdda30d1b62ea41);
#
#
#
#         marker_1cb824eb96c278cedcc107e5f8519734.bindPopup(popup_4ef5b95fdbee0ac66cd56121d24c08ed)
#         ;
#
#
#
#
#             var marker_655c690e097d2dbd84f42d7cc17268d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bfa9770fe03f81254cff20046209b81d);
#
#
#         var popup_77b5a40444dc78aba100d2e0957254c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93b3327a86d511c78ff3c83b9c5172b8 = $(`&lt;div id=&quot;html_93b3327a86d511c78ff3c83b9c5172b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_77b5a40444dc78aba100d2e0957254c7.setContent(html_93b3327a86d511c78ff3c83b9c5172b8);
#
#
#
#         marker_655c690e097d2dbd84f42d7cc17268d7.bindPopup(popup_77b5a40444dc78aba100d2e0957254c7)
#         ;
#
#
#
#
#             var marker_7c4a4fa33620e43cd12ac756e4306bf8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bfa9770fe03f81254cff20046209b81d);
#
#
#         var popup_2ff4bc18ec10aa1917a030eb2e64d650 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b056033aae43046ff2a4119b9d08a2df = $(`&lt;div id=&quot;html_b056033aae43046ff2a4119b9d08a2df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2ff4bc18ec10aa1917a030eb2e64d650.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a41d28e0e504fd234f8a9fff84ab63c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a41d28e0e504fd234f8a9fff84ab63c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a41d28e0e504fd234f8a9fff84ab63c = L.map(
#                 &quot;map_2a41d28e0e504fd234f8a9fff84ab63c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_444aab0e3f35e8d347eef5ffbbb75cb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_444aab0e3f35e8d347eef5ffbbb75cb7.addTo(map_2a41d28e0e504fd234f8a9fff84ab63c);
#
#
#             var feature_group_a9d56cdb4723ddfd858bcc28ee3f79f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fc267ca964014793de665761026e7734 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a9d56cdb4723ddfd858bcc28ee3f79f1);
#
#
#         var popup_bf1b8e52a03b84d33b2e4f1089f74600 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9e40fa83bae210b2b9e573bb2963ac1 = $(`&lt;div id=&quot;html_e9e40fa83bae210b2b9e573bb2963ac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bf1b8e52a03b84d33b2e4f1089f74600.setContent(html_e9e40fa83bae210b2b9e573bb2963ac1);
#
#
#
#         marker_fc267ca964014793de665761026e7734.bindPopup(popup_bf1b8e52a03b84d33b2e4f1089f74600)
#         ;
#
#
#
#
#             var marker_e1182df79292f9cb988e489bf7b8c7d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a9d56cdb4723ddfd858bcc28ee3f79f1);
#
#
#         var popup_1b43719129564756ee680018e7154073 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2154eb4ddc46b59386d8f27741b06365 = $(`&lt;div id=&quot;html_2154eb4ddc46b59386d8f27741b06365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1b43719129564756ee680018e7154073.setContent(html_2154eb4ddc46b59386d8f27741b06365);
#
#
#
#         marker_e1182df79292f9cb988e489bf7b8c7d1.bindPopup(popup_1b43719129564756ee680018e7154073)
#         ;
#
#
#
#
#             var marker_cf601250ee812dde26020445af01f3fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a9d56cdb4723ddfd858bcc28ee3f79f1);
#
#
#         var popup_51c0cf02e45b41316c4280adba4e85dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e13267bea271cf2e0aac7dbff36f3f76 = $(`&lt;div id=&quot;html_e13267bea271cf2e0aac7dbff36f3f76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_51c0cf02e45b41316c4280adba4e85dd.setContent(html_e13267bea271cf2e0aac7dbff36f3f76);
#
#
#
#         marker_cf601250ee812dde26020445af01f3fb.bindPopup(popup_51c0cf02e45b41316c4280adba4e85dd)
#         ;
#
#
#
#
#             var marker_9c4c43e0b645e2b1fbaa2390432582c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a9d56cdb4723ddfd858bcc28ee3f79f1);
#
#
#         var popup_3856474637ad2e128b9e9458253d9a5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19cf5921010e567f22741dba2c35da16 = $(`&lt;div id=&quot;html_19cf5921010e567f22741dba2c35da16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3856474637ad2e128b9e9458253d9a5a.setContent(html_19cf5921010e567f22741dba2c35da16);
#
#
#
#         marker_9c4c43e0b645e2b1fbaa2390432582c5.bindPopup(popup_3856474637ad2e128b9e9458253d9a5a)
#         ;
#
#
#
#
#             var marker_2a241c3ccbb3f5e4cb729e9510784bd7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a9d56cdb4723ddfd858bcc28ee3f79f1);
#
#
#         var popup_bf926153ecb4a42aa84b02c2dfeb8faa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b999ccf0ff2fdedc5a1fcbd55dc60f8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b999ccf0ff2fdedc5a1fcbd55dc60f8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b999ccf0ff2fdedc5a1fcbd55dc60f8f = L.map(
#                 &quot;map_b999ccf0ff2fdedc5a1fcbd55dc60f8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a82dbfa55ebdf25b62c29ecba113aac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a82dbfa55ebdf25b62c29ecba113aac.addTo(map_b999ccf0ff2fdedc5a1fcbd55dc60f8f);
#
#
#             var feature_group_aa5b970ddb6049efd056882465cd7c20 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_aa5b970ddb6049efd056882465cd7c20.addTo(map_b999ccf0ff2fdedc5a1fcbd55dc60f8f);
#
#
#             var feature_group_sub_group_7b27faaac1bef14e57b81f40b8ecd8fd = L.featureGroup.subGroup(
#                 feature_group_aa5b970ddb6049efd056882465cd7c20
#             );
#
#
#             var marker_a639df5f2fbe8c685e080459a74dcb00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b27faaac1bef14e57b81f40b8ecd8fd);
#
#
#         var popup_2ea59cd68f84da152d42a792dcfd11c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1da4181e0ea8fa9fdbec74fede1a2e0f = $(`&lt;div id=&quot;html_1da4181e0ea8fa9fdbec74fede1a2e0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2ea59cd68f84da152d42a792dcfd11c4.setContent(html_1da4181e0ea8fa9fdbec74fede1a2e0f);
#
#
#
#         marker_a639df5f2fbe8c685e080459a74dcb00.bindPopup(popup_2ea59cd68f84da152d42a792dcfd11c4)
#         ;
#
#
#
#
#             var marker_eb05d990c230b340e4f4eb65c091ca9d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b27faaac1bef14e57b81f40b8ecd8fd);
#
#
#         var popup_f02e7c8496492cd14f2f2efa3b9a0b61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6188ca6e06cefee8a0ac2bc90dda9ec9 = $(`&lt;div id=&quot;html_6188ca6e06cefee8a0ac2bc90dda9ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f02e7c8496492cd14f2f2efa3b9a0b61.setContent(html_6188ca6e06cefee8a0ac2bc90dda9ec9);
#
#
#
#         marker_eb05d990c230b340e4f4eb65c091ca9d.bindPopup(popup_f02e7c8496492cd14f2f2efa3b9a0b61)
#         ;
#
#
#
#
#             var marker_fae629bee63a50880c59afb84113d920 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b27faaac1bef14e57b81f40b8ecd8fd);
#
#
#         var popup_5ff8fcf72de189dfc4010d2e0476a190 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf34e4f858dd4395c9723669ebc6900f = $(`&lt;div id=&quot;html_bf34e4f858dd4395c9723669ebc6900f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5ff8fcf72de189dfc4010d2e0476a190.setContent(html_bf34e4f858dd4395c9723669ebc6900f);
#
#
#
#         marker_fae629bee63a50880c59afb84113d920.bindPopup(popup_5ff8fcf72de189dfc4010d2e0476a190)
#         ;
#
#
#
#
#             var marker_ae6fdb9a4b4bcb639b81fd92a840074a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b27faaac1bef14e57b81f40b8ecd8fd);
#
#
#         var popup_b7218ba1574a6cd064be005d54510570 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3d7055433243c6a3d8b49871ea5c168 = $(`&lt;div id=&quot;html_e3d7055433243c6a3d8b49871ea5c168&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b7218ba1574a6cd064be005d54510570.setContent(html_e3d7055433243c6a3d8b49871ea5c168);
#
#
#
#         marker_
