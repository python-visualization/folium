# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6282dfda2aa0c02b4d4bba7bd2f48969 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6282dfda2aa0c02b4d4bba7bd2f48969&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6282dfda2aa0c02b4d4bba7bd2f48969 = L.map(
#                 &quot;map_6282dfda2aa0c02b4d4bba7bd2f48969&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f78553cc06e61e99f20407c1af2d8d4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f78553cc06e61e99f20407c1af2d8d4c.addTo(map_6282dfda2aa0c02b4d4bba7bd2f48969);
#
#
#             var marker_8159ba5d9a78cfeef9ebd3ef91da4d47 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6282dfda2aa0c02b4d4bba7bd2f48969);
#
#
#         var popup_6f8435540c79f3340d76ab2bdc08a456 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed555203516b6cd4efa087b36f363967 = $(`&lt;div id=&quot;html_ed555203516b6cd4efa087b36f363967&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6f8435540c79f3340d76ab2bdc08a456.setContent(html_ed555203516b6cd4efa087b36f363967);
#
#
#
#         marker_8159ba5d9a78cfeef9ebd3ef91da4d47.bindPopup(popup_6f8435540c79f3340d76ab2bdc08a456)
#         ;
#
#
#
#
#             var marker_bb501e9434c977a0460379a367d6fb48 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6282dfda2aa0c02b4d4bba7bd2f48969);
#
#
#         var popup_0820f118ff88fc160e85c41603cf3b51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaeee51f51badd5706e91bd26e8d582f = $(`&lt;div id=&quot;html_aaeee51f51badd5706e91bd26e8d582f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0820f118ff88fc160e85c41603cf3b51.setContent(html_aaeee51f51badd5706e91bd26e8d582f);
#
#
#
#         marker_bb501e9434c977a0460379a367d6fb48.bindPopup(popup_0820f118ff88fc160e85c41603cf3b51)
#         ;
#
#
#
#
#             var marker_a5efb79bd73378657b640662ad661853 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6282dfda2aa0c02b4d4bba7bd2f48969);
#
#
#         var popup_708b97856bac8356ed80654942757e31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d63eb0d1429d51b7aff9f70ff58d0693 = $(`&lt;div id=&quot;html_d63eb0d1429d51b7aff9f70ff58d0693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_708b97856bac8356ed80654942757e31.setContent(html_d63eb0d1429d51b7aff9f70ff58d0693);
#
#
#
#         marker_a5efb79bd73378657b640662ad661853.bindPopup(popup_708b97856bac8356ed80654942757e31)
#         ;
#
#
#
#
#             var marker_6596ed2fbfc8a778787e017721ecb4e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6282dfda2aa0c02b4d4bba7bd2f48969);
#
#
#         var popup_6ff3f209303c7789a5bc5278edb48a94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e79816872079fa1757ba563c8ae7fa09 = $(`&lt;div id=&quot;html_e79816872079fa1757ba563c8ae7fa09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6ff3f209303c7789a5bc5278edb48a94.setContent(html_e79816872079fa1757ba563c8ae7fa09);
#
#
#
#         marker_6596ed2fbfc8a778787e017721ecb4e4.bindPopup(popup_6ff3f209303c7789a5bc5278edb48a94)
#         ;
#
#
#
#
#             var marker_9cf7ee0e127ee060b25d831c503758a4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6282dfda2aa0c02b4d4bba7bd2f48969);
#
#
#         var popup_05dbf9655cf2462db53d0d9ebb16f599 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6189bf2f3afbf32a5b35cccd8c31d10e = $(`&lt;div id=&quot;html_6189bf2f3afbf32a5b35cccd8c31d10e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05dbf9655cf2462db53d0d9ebb16f599.setContent(html_6189bf2f3afbf32a5b35cccd8c31d10e);
#
#
#
#         marker_9cf7ee0e127ee060b25d831c503758a4.bindPopup(popup_05dbf9655cf2462db53d0d9ebb16f599)
#         ;
#
#
#
#
#             var marker_395cfcad69

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71a83d79b7f0e7c30bfdc7f0ec844acd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71a83d79b7f0e7c30bfdc7f0ec844acd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71a83d79b7f0e7c30bfdc7f0ec844acd = L.map(
#                 &quot;map_71a83d79b7f0e7c30bfdc7f0ec844acd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0be6073d4dd5aa9d85c6b3a212c000a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0be6073d4dd5aa9d85c6b3a212c000a.addTo(map_71a83d79b7f0e7c30bfdc7f0ec844acd);
#
#
#             var feature_group_8db69f65207012b2fc7d9db707350833 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1632804ccd18aa14fcb5f369b84dc974 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8db69f65207012b2fc7d9db707350833);
#
#
#         var popup_d5c6ca85549f6d0f8d270499127f6726 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_901cbe4d21b572a3ebe397bf6fee29fe = $(`&lt;div id=&quot;html_901cbe4d21b572a3ebe397bf6fee29fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d5c6ca85549f6d0f8d270499127f6726.setContent(html_901cbe4d21b572a3ebe397bf6fee29fe);
#
#
#
#         marker_1632804ccd18aa14fcb5f369b84dc974.bindPopup(popup_d5c6ca85549f6d0f8d270499127f6726)
#         ;
#
#
#
#
#             var marker_e3bafadf9fb6b06a155a2e028757d091 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8db69f65207012b2fc7d9db707350833);
#
#
#         var popup_b9553aa20484e7c7e1419f573dda2733 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b794b3ca096514fd58d611b18545fb4 = $(`&lt;div id=&quot;html_3b794b3ca096514fd58d611b18545fb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b9553aa20484e7c7e1419f573dda2733.setContent(html_3b794b3ca096514fd58d611b18545fb4);
#
#
#
#         marker_e3bafadf9fb6b06a155a2e028757d091.bindPopup(popup_b9553aa20484e7c7e1419f573dda2733)
#         ;
#
#
#
#
#             var marker_02d79c274ab74942e3adc143b83dbe78 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8db69f65207012b2fc7d9db707350833);
#
#
#         var popup_e45dce483e9f7d2f24878e1c55383412 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b95ebfd18fd9b947902f7f58a35b478c = $(`&lt;div id=&quot;html_b95ebfd18fd9b947902f7f58a35b478c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e45dce483e9f7d2f24878e1c55383412.setContent(html_b95ebfd18fd9b947902f7f58a35b478c);
#
#
#
#         marker_02d79c274ab74942e3adc143b83dbe78.bindPopup(popup_e45dce483e9f7d2f24878e1c55383412)
#         ;
#
#
#
#
#             var marker_36495266fc97ab75750a21feebfcd4b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8db69f65207012b2fc7d9db707350833);
#
#
#         var popup_3a363bd35d93baa797adc53b2cd3686e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d4c175e3704d9efcc6666213861ea6e = $(`&lt;div id=&quot;html_8d4c175e3704d9efcc6666213861ea6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3a363bd35d93baa797adc53b2cd3686e.setContent(html_8d4c175e3704d9efcc6666213861ea6e);
#
#
#
#         marker_36495266fc97ab75750a21feebfcd4b0.bindPopup(popup_3a363bd35d93baa797adc53b2cd3686e)
#         ;
#
#
#
#
#             var marker_ddd36f39af312ba9d76798636dc28f4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8db69f65207012b2fc7d9db707350833);
#
#
#         var popup_1c2665c239bc592fb43cc7cc7af87c80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a92a482e2d6243a50220c583fca11adb = $(`&lt;div id=&quot;html_a92a482e2d6243a50220c583fca11adb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_1c2665c239bc592fb4

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c32c2828139402b3d861b68af421901 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c32c2828139402b3d861b68af421901&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c32c2828139402b3d861b68af421901 = L.map(
#                 &quot;map_4c32c2828139402b3d861b68af421901&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7000e41f6e6d65d08d4f4a9e1c861953 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7000e41f6e6d65d08d4f4a9e1c861953.addTo(map_4c32c2828139402b3d861b68af421901);
#
#
#             var feature_group_487d3ba827b97d6dec82b9aac8de6d36 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_487d3ba827b97d6dec82b9aac8de6d36.addTo(map_4c32c2828139402b3d861b68af421901);
#
#
#             var feature_group_sub_group_d76cfd0cc2363c7f2808198ef52ee6f0 = L.featureGroup.subGroup(
#                 feature_group_487d3ba827b97d6dec82b9aac8de6d36
#             );
#
#
#             var marker_b82c66cfd11a9b98b19954bf240c336b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d76cfd0cc2363c7f2808198ef52ee6f0);
#
#
#         var popup_7dba488f3e4919d4e254981df89a7c46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69413e9a1ad233793633d8dfe368c5c0 = $(`&lt;div id=&quot;html_69413e9a1ad233793633d8dfe368c5c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7dba488f3e4919d4e254981df89a7c46.setContent(html_69413e9a1ad233793633d8dfe368c5c0);
#
#
#
#         marker_b82c66cfd11a9b98b19954bf240c336b.bindPopup(popup_7dba488f3e4919d4e254981df89a7c46)
#         ;
#
#
#
#
#             var marker_61d17a19fd55fcb85e481b6cca19810e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d76cfd0cc2363c7f2808198ef52ee6f0);
#
#
#         var popup_7775eeabb319925acb27bf239ddc167d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70321ed003ade873640e55ba47baedd3 = $(`&lt;div id=&quot;html_70321ed003ade873640e55ba47baedd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7775eeabb319925acb27bf239ddc167d.setContent(html_70321ed003ade873640e55ba47baedd3);
#
#
#
#         marker_61d17a19fd55fcb85e481b6cca19810e.bindPopup(popup_7775eeabb319925acb27bf239ddc167d)
#         ;
#
#
#
#
#             var marker_5e33e765f09237f4a52e7bfe8f94f71c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d76cfd0cc2363c7f2808198ef52ee6f0);
#
#
#         var popup_ba9dd739592b33436544379e9f9c7ddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8b63a83fe5f9bddfb1c9b5776c00bd6 = $(`&lt;div id=&quot;html_c8b63a83fe5f9bddfb1c9b5776c00bd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ba9dd739592b33436544379e9f9c7ddd.setContent(html_c8b63a83fe5f9bddfb1c9b5776c00bd6);
#
#
#
#         marker_5e33e765f09237f4a52e7bfe8f94f71c.bindPopup(popup_ba9dd739592b33436544379e9f9c7ddd)
#         ;
#
#
#
#
#             var marker_64886a23cfbdf169ae25ea37a11cc39a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d76cfd0cc2363c7f2808198ef52ee6f0);
#
#
#         var popup_c73a97fb468e2de06f5a67bfb23632dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06ea50a0c9caf94fd7bc76df2de29ec3 = $(`&lt;div id=&quot;html_06ea50a0c9caf94fd7bc76df2de29ec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c73a97fb468e2de06f5a67bfb23632dd.setContent(html_06ea50a0c9caf94fd7bc76df2de29ec3);
#
#
#
#         marker_64886a23cfbdf169ae25ea37a11cc39a.bindPopup(popup_c73a97fb468e2de06f5a67bfb23632dd)
#         ;
#
#
#
#
#             var marker_0174eb8d607f54f6f8e18a48013d6e9c = L.marker(
#                 [45.050399999999996, 3.0504],
