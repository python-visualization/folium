# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_563449eb3a9077b773d9a0b458023498 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_563449eb3a9077b773d9a0b458023498&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_563449eb3a9077b773d9a0b458023498 = L.map(
#                 &quot;map_563449eb3a9077b773d9a0b458023498&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ce010dad44806bffa052afcbfe8a003 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ce010dad44806bffa052afcbfe8a003.addTo(map_563449eb3a9077b773d9a0b458023498);
#
#
#             var marker_7eda35526e26965c12092c55bc112b49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_563449eb3a9077b773d9a0b458023498);
#
#
#         var popup_bff560cdc4f49710ca2e58aea4b02422 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a43bf23ef73eba3c7b69b43501503676 = $(`&lt;div id=&quot;html_a43bf23ef73eba3c7b69b43501503676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bff560cdc4f49710ca2e58aea4b02422.setContent(html_a43bf23ef73eba3c7b69b43501503676);
#
#
#
#         marker_7eda35526e26965c12092c55bc112b49.bindPopup(popup_bff560cdc4f49710ca2e58aea4b02422)
#         ;
#
#
#
#
#             var marker_26f0e6c20a251ca116f2cbb09bcd4959 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_563449eb3a9077b773d9a0b458023498);
#
#
#         var popup_3ceb34ffe41778663aa6f9f5fe61f72a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bad4d3de4c6886eb0d7ff3c46c8434d0 = $(`&lt;div id=&quot;html_bad4d3de4c6886eb0d7ff3c46c8434d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3ceb34ffe41778663aa6f9f5fe61f72a.setContent(html_bad4d3de4c6886eb0d7ff3c46c8434d0);
#
#
#
#         marker_26f0e6c20a251ca116f2cbb09bcd4959.bindPopup(popup_3ceb34ffe41778663aa6f9f5fe61f72a)
#         ;
#
#
#
#
#             var marker_5b69af1018b54ace3c2a41f5e72548e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_563449eb3a9077b773d9a0b458023498);
#
#
#         var popup_8d646eb11c5c41d1827a458c7f0d884d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f6eed18865968458dd5d4bfeb525d56 = $(`&lt;div id=&quot;html_9f6eed18865968458dd5d4bfeb525d56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8d646eb11c5c41d1827a458c7f0d884d.setContent(html_9f6eed18865968458dd5d4bfeb525d56);
#
#
#
#         marker_5b69af1018b54ace3c2a41f5e72548e5.bindPopup(popup_8d646eb11c5c41d1827a458c7f0d884d)
#         ;
#
#
#
#
#             var marker_c75e03c33aabbfab66133047918ef21f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_563449eb3a9077b773d9a0b458023498);
#
#
#         var popup_d87d285b71fc0cf953d75272340d5e27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f342e889d2cf4f24ad2f6219839fc18d = $(`&lt;div id=&quot;html_f342e889d2cf4f24ad2f6219839fc18d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d87d285b71fc0cf953d75272340d5e27.setContent(html_f342e889d2cf4f24ad2f6219839fc18d);
#
#
#
#         marker_c75e03c33aabbfab66133047918ef21f.bindPopup(popup_d87d285b71fc0cf953d75272340d5e27)
#         ;
#
#
#
#
#             var marker_62e4fb747a5ce6633e72b820b345e4d5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_563449eb3a9077b773d9a0b458023498);
#
#
#         var popup_1ce645a519f9a109fc5d699f7a9df7f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d51e22b463e912c0ac321b61274ba74 = $(`&lt;div id=&quot;html_4d51e22b463e912c0ac321b61274ba74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1ce645a519f9a109fc5d699f7a9df7f0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e29618df4bcc37c8495784469c4f3ddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e29618df4bcc37c8495784469c4f3ddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e29618df4bcc37c8495784469c4f3ddd = L.map(
#                 &quot;map_e29618df4bcc37c8495784469c4f3ddd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70941cffc5d45ebae2690e6300cf9c53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70941cffc5d45ebae2690e6300cf9c53.addTo(map_e29618df4bcc37c8495784469c4f3ddd);
#
#
#             var feature_group_c3abaea486b4ea9f500a5c4ac3207c23 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b80de516b1964cb2c0481e40d645d979 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c3abaea486b4ea9f500a5c4ac3207c23);
#
#
#         var popup_463cf50cb9cde4fd6b1e883c1df0dc62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ce71a8e8b08db2d645f66545bf0e18a = $(`&lt;div id=&quot;html_8ce71a8e8b08db2d645f66545bf0e18a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_463cf50cb9cde4fd6b1e883c1df0dc62.setContent(html_8ce71a8e8b08db2d645f66545bf0e18a);
#
#
#
#         marker_b80de516b1964cb2c0481e40d645d979.bindPopup(popup_463cf50cb9cde4fd6b1e883c1df0dc62)
#         ;
#
#
#
#
#             var marker_806fe18d7dbbd1f40c4d8aec03f48a57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c3abaea486b4ea9f500a5c4ac3207c23);
#
#
#         var popup_103ab89021e7e730e04f47446e87840d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8a4e3da1e0fa3979d6e6f565424e28c = $(`&lt;div id=&quot;html_e8a4e3da1e0fa3979d6e6f565424e28c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_103ab89021e7e730e04f47446e87840d.setContent(html_e8a4e3da1e0fa3979d6e6f565424e28c);
#
#
#
#         marker_806fe18d7dbbd1f40c4d8aec03f48a57.bindPopup(popup_103ab89021e7e730e04f47446e87840d)
#         ;
#
#
#
#
#             var marker_4b3192c418adccb38ff0aa8057dd594e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c3abaea486b4ea9f500a5c4ac3207c23);
#
#
#         var popup_bad1e3515f99e08f2daf87e28f61a271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cabaced13787089c6ff051fc8115f8a4 = $(`&lt;div id=&quot;html_cabaced13787089c6ff051fc8115f8a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bad1e3515f99e08f2daf87e28f61a271.setContent(html_cabaced13787089c6ff051fc8115f8a4);
#
#
#
#         marker_4b3192c418adccb38ff0aa8057dd594e.bindPopup(popup_bad1e3515f99e08f2daf87e28f61a271)
#         ;
#
#
#
#
#             var marker_065b58be242f7c1af5e1b6c76520db6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c3abaea486b4ea9f500a5c4ac3207c23);
#
#
#         var popup_70d14b8aba0a08491ea70eee1888b259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e81bb9c2b7387f7e41f4bcbbe158b0ea = $(`&lt;div id=&quot;html_e81bb9c2b7387f7e41f4bcbbe158b0ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_70d14b8aba0a08491ea70eee1888b259.setContent(html_e81bb9c2b7387f7e41f4bcbbe158b0ea);
#
#
#
#         marker_065b58be242f7c1af5e1b6c76520db6e.bindPopup(popup_70d14b8aba0a08491ea70eee1888b259)
#         ;
#
#
#
#
#             var marker_c2f42dcd92c394e042cf330d5127abe2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c3abaea486b4ea9f500a5c4ac3207c23);
#
#
#         var popup_bebc37d3f203c277a60a0495425ecfbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0bad57caa90e37ea3ee604f1005deb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0bad57caa90e37ea3ee604f1005deb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0bad57caa90e37ea3ee604f1005deb3 = L.map(
#                 &quot;map_a0bad57caa90e37ea3ee604f1005deb3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c537001e69488310739b17e559e6a31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c537001e69488310739b17e559e6a31.addTo(map_a0bad57caa90e37ea3ee604f1005deb3);
#
#
#             var feature_group_d718bc8d2d1a81ef7628fc56d3bed058 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d718bc8d2d1a81ef7628fc56d3bed058.addTo(map_a0bad57caa90e37ea3ee604f1005deb3);
#
#
#             var feature_group_sub_group_478ea150c8e6dad506bccb7a76205782 = L.featureGroup.subGroup(
#                 feature_group_d718bc8d2d1a81ef7628fc56d3bed058
#             );
#
#
#             var marker_582cea5e4f90e34f1ad8d640bcc5a84a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_478ea150c8e6dad506bccb7a76205782);
#
#
#         var popup_cc14f1e884f423fe5103c9a3e06faeec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcdfed6e81cf7d3e3e9ec75a5492e076 = $(`&lt;div id=&quot;html_dcdfed6e81cf7d3e3e9ec75a5492e076&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cc14f1e884f423fe5103c9a3e06faeec.setContent(html_dcdfed6e81cf7d3e3e9ec75a5492e076);
#
#
#
#         marker_582cea5e4f90e34f1ad8d640bcc5a84a.bindPopup(popup_cc14f1e884f423fe5103c9a3e06faeec)
#         ;
#
#
#
#
#             var marker_ae78dd2ea9be56e03bbf4db2a7db87a2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_478ea150c8e6dad506bccb7a76205782);
#
#
#         var popup_ae7eb9e8e08912ad52c2b68963844175 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7af1b6bc8e38c725ae192e7dc958d4a4 = $(`&lt;div id=&quot;html_7af1b6bc8e38c725ae192e7dc958d4a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ae7eb9e8e08912ad52c2b68963844175.setContent(html_7af1b6bc8e38c725ae192e7dc958d4a4);
#
#
#
#         marker_ae78dd2ea9be56e03bbf4db2a7db87a2.bindPopup(popup_ae7eb9e8e08912ad52c2b68963844175)
#         ;
#
#
#
#
#             var marker_311d15adbe7310027d2682eb1d250056 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_478ea150c8e6dad506bccb7a76205782);
#
#
#         var popup_d2f299fb3cd88eba74d570d397b82f75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f2858aba7830ecff6a1414674fef5df = $(`&lt;div id=&quot;html_4f2858aba7830ecff6a1414674fef5df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d2f299fb3cd88eba74d570d397b82f75.setContent(html_4f2858aba7830ecff6a1414674fef5df);
#
#
#
#         marker_311d15adbe7310027d2682eb1d250056.bindPopup(popup_d2f299fb3cd88eba74d570d397b82f75)
#         ;
#
#
#
#
#             var marker_8c816a6b73a8f972cf7a2f1e5efbf61a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_478ea150c8e6dad506bccb7a76205782);
#
#
#         var popup_4f1840daad0e8a77639031dc2d4701f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56ef92eec22af07972e6f2c5742572ae = $(`&lt;div id=&quot;html_56ef92eec22af07972e6f2c5742572ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4f1840daad0e8a77639031dc2d4701f3.setContent(html_56ef92eec22af07972e6f2c5742572ae);
#
#
#
#         marker_
