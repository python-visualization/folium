# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4855202d25ac64df968a6ae91114d0b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4855202d25ac64df968a6ae91114d0b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4855202d25ac64df968a6ae91114d0b8 = L.map(
#                 &quot;map_4855202d25ac64df968a6ae91114d0b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61a90b0a2d4e4424618d31326b1609be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61a90b0a2d4e4424618d31326b1609be.addTo(map_4855202d25ac64df968a6ae91114d0b8);
#
#
#             var marker_69a6f2686bdc67c47f49c3c015a32c6e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4855202d25ac64df968a6ae91114d0b8);
#
#
#         var popup_b0053f6e373be309953340a11606f865 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18d41aba7ed72d2e5667e18105cb60e5 = $(`&lt;div id=&quot;html_18d41aba7ed72d2e5667e18105cb60e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b0053f6e373be309953340a11606f865.setContent(html_18d41aba7ed72d2e5667e18105cb60e5);
#
#
#
#         marker_69a6f2686bdc67c47f49c3c015a32c6e.bindPopup(popup_b0053f6e373be309953340a11606f865)
#         ;
#
#
#
#
#             var marker_bba867d3b92839887759777f49d38b21 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4855202d25ac64df968a6ae91114d0b8);
#
#
#         var popup_186e9507de2612c3a6f01ce5457215b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f9541e1ce21aaa4a4676acade27f887 = $(`&lt;div id=&quot;html_4f9541e1ce21aaa4a4676acade27f887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_186e9507de2612c3a6f01ce5457215b2.setContent(html_4f9541e1ce21aaa4a4676acade27f887);
#
#
#
#         marker_bba867d3b92839887759777f49d38b21.bindPopup(popup_186e9507de2612c3a6f01ce5457215b2)
#         ;
#
#
#
#
#             var marker_e06527de505bd312e65777f7a215b4dd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4855202d25ac64df968a6ae91114d0b8);
#
#
#         var popup_23f1c637d9da30c05d8a8699966434fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e1c71dd08d49c236348cf5c1909f2d4 = $(`&lt;div id=&quot;html_8e1c71dd08d49c236348cf5c1909f2d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_23f1c637d9da30c05d8a8699966434fd.setContent(html_8e1c71dd08d49c236348cf5c1909f2d4);
#
#
#
#         marker_e06527de505bd312e65777f7a215b4dd.bindPopup(popup_23f1c637d9da30c05d8a8699966434fd)
#         ;
#
#
#
#
#             var marker_0262d7e0d9f5835e91a4f40e4721c623 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4855202d25ac64df968a6ae91114d0b8);
#
#
#         var popup_8fadc4288ffe7d0a4c4911f77967263d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57e8b8cf12053fcf219b563abcd37fed = $(`&lt;div id=&quot;html_57e8b8cf12053fcf219b563abcd37fed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8fadc4288ffe7d0a4c4911f77967263d.setContent(html_57e8b8cf12053fcf219b563abcd37fed);
#
#
#
#         marker_0262d7e0d9f5835e91a4f40e4721c623.bindPopup(popup_8fadc4288ffe7d0a4c4911f77967263d)
#         ;
#
#
#
#
#             var marker_e86a71434fa8a256d605035a6aa8a444 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4855202d25ac64df968a6ae91114d0b8);
#
#
#         var popup_c74e7e9cb2486484e8e5afa779b2508c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1f30686541b1c1e356c24ed33cd68d9 = $(`&lt;div id=&quot;html_b1f30686541b1c1e356c24ed33cd68d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c74e7e9cb2486484e8e5afa779b2508c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7984ee5db07f8b8af69096955f4a5b8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7984ee5db07f8b8af69096955f4a5b8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7984ee5db07f8b8af69096955f4a5b8d = L.map(
#                 &quot;map_7984ee5db07f8b8af69096955f4a5b8d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1a07247218f0bf31c7571157cdb41d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1a07247218f0bf31c7571157cdb41d1.addTo(map_7984ee5db07f8b8af69096955f4a5b8d);
#
#
#             var feature_group_4b56367a2069b5c19eb0309d130e209a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_98fe3fe0d8db0640123e5b9eafce7d2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4b56367a2069b5c19eb0309d130e209a);
#
#
#         var popup_3f76928dc293e0553443644ef599129e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c8688decc5d73bd3757f78908a4520f = $(`&lt;div id=&quot;html_7c8688decc5d73bd3757f78908a4520f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3f76928dc293e0553443644ef599129e.setContent(html_7c8688decc5d73bd3757f78908a4520f);
#
#
#
#         marker_98fe3fe0d8db0640123e5b9eafce7d2d.bindPopup(popup_3f76928dc293e0553443644ef599129e)
#         ;
#
#
#
#
#             var marker_66d0deeffb25fc2dadc619c263006319 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4b56367a2069b5c19eb0309d130e209a);
#
#
#         var popup_e5bfe66cd9fa6198c1f1568d1b3a1b8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e722f5b61f7ea640d09734040164d46 = $(`&lt;div id=&quot;html_8e722f5b61f7ea640d09734040164d46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e5bfe66cd9fa6198c1f1568d1b3a1b8f.setContent(html_8e722f5b61f7ea640d09734040164d46);
#
#
#
#         marker_66d0deeffb25fc2dadc619c263006319.bindPopup(popup_e5bfe66cd9fa6198c1f1568d1b3a1b8f)
#         ;
#
#
#
#
#             var marker_181f28f950ca7b309e72093b448d3b30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4b56367a2069b5c19eb0309d130e209a);
#
#
#         var popup_3789597677c90ace4a3b101d7afc0675 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a03d789917cd5804e117868fd6b005a = $(`&lt;div id=&quot;html_0a03d789917cd5804e117868fd6b005a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3789597677c90ace4a3b101d7afc0675.setContent(html_0a03d789917cd5804e117868fd6b005a);
#
#
#
#         marker_181f28f950ca7b309e72093b448d3b30.bindPopup(popup_3789597677c90ace4a3b101d7afc0675)
#         ;
#
#
#
#
#             var marker_ad300d5efab59857ac0e90735bf8df06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4b56367a2069b5c19eb0309d130e209a);
#
#
#         var popup_b82790eb8d41dddf80a25eb849cb1067 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_137af064b2474b9697f7de352c46f452 = $(`&lt;div id=&quot;html_137af064b2474b9697f7de352c46f452&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b82790eb8d41dddf80a25eb849cb1067.setContent(html_137af064b2474b9697f7de352c46f452);
#
#
#
#         marker_ad300d5efab59857ac0e90735bf8df06.bindPopup(popup_b82790eb8d41dddf80a25eb849cb1067)
#         ;
#
#
#
#
#             var marker_077c78226475bf23698aef7f9d62538c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4b56367a2069b5c19eb0309d130e209a);
#
#
#         var popup_b80f01824aa0b97e11de8baa5107c228 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb12e7a2c16060339ae4654942a21509 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb12e7a2c16060339ae4654942a21509&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb12e7a2c16060339ae4654942a21509 = L.map(
#                 &quot;map_bb12e7a2c16060339ae4654942a21509&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_092317127e62f8d981c5bef4846e7935 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_092317127e62f8d981c5bef4846e7935.addTo(map_bb12e7a2c16060339ae4654942a21509);
#
#
#             var feature_group_4fc1113970400a09bc5ad3ef938c6312 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4fc1113970400a09bc5ad3ef938c6312.addTo(map_bb12e7a2c16060339ae4654942a21509);
#
#
#             var feature_group_sub_group_de36f3dbae09d3139021507a83922dfb = L.featureGroup.subGroup(
#                 feature_group_4fc1113970400a09bc5ad3ef938c6312
#             );
#
#
#             var marker_295b73f588c10f1ec3b6c47f08e012eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_de36f3dbae09d3139021507a83922dfb);
#
#
#         var popup_e493defc1bc32e717084dcadf7d13ea9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da356e360102eb35cbed2ceb18801302 = $(`&lt;div id=&quot;html_da356e360102eb35cbed2ceb18801302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e493defc1bc32e717084dcadf7d13ea9.setContent(html_da356e360102eb35cbed2ceb18801302);
#
#
#
#         marker_295b73f588c10f1ec3b6c47f08e012eb.bindPopup(popup_e493defc1bc32e717084dcadf7d13ea9)
#         ;
#
#
#
#
#             var marker_13f7a6d33fffbf6372a0009e505b7793 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_de36f3dbae09d3139021507a83922dfb);
#
#
#         var popup_31a39595a6653f77d513f51aa0a32a4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_575c5461385d39c13e0f58194c04723a = $(`&lt;div id=&quot;html_575c5461385d39c13e0f58194c04723a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_31a39595a6653f77d513f51aa0a32a4d.setContent(html_575c5461385d39c13e0f58194c04723a);
#
#
#
#         marker_13f7a6d33fffbf6372a0009e505b7793.bindPopup(popup_31a39595a6653f77d513f51aa0a32a4d)
#         ;
#
#
#
#
#             var marker_5e1b481f34fde550f217ad8ae20e7441 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_de36f3dbae09d3139021507a83922dfb);
#
#
#         var popup_37856b5684d1f57817985e1854094bb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c2e57241c92ec296f6bbf5c09b1a3c6 = $(`&lt;div id=&quot;html_4c2e57241c92ec296f6bbf5c09b1a3c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_37856b5684d1f57817985e1854094bb0.setContent(html_4c2e57241c92ec296f6bbf5c09b1a3c6);
#
#
#
#         marker_5e1b481f34fde550f217ad8ae20e7441.bindPopup(popup_37856b5684d1f57817985e1854094bb0)
#         ;
#
#
#
#
#             var marker_0b7b0e4f27c6d1162f82749055902e98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_de36f3dbae09d3139021507a83922dfb);
#
#
#         var popup_cfea7443a019575cd9f2f7aea6a7d2fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_930afbd9b732c48d7882f63bb3871d80 = $(`&lt;div id=&quot;html_930afbd9b732c48d7882f63bb3871d80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cfea7443a019575cd9f2f7aea6a7d2fb.setContent(html_930afbd9b732c48d7882f63bb3871d80);
#
#
#
#         marker_
