# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c3054b3a85a1e789941dde195b7f280 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c3054b3a85a1e789941dde195b7f280&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c3054b3a85a1e789941dde195b7f280 = L.map(
#                 &quot;map_0c3054b3a85a1e789941dde195b7f280&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea84f7f9eefeb8d81cc4a9dbbeb39810 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea84f7f9eefeb8d81cc4a9dbbeb39810.addTo(map_0c3054b3a85a1e789941dde195b7f280);
#
#
#             var marker_1bd9ca75f1a2c662fb59edd97a637b00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0c3054b3a85a1e789941dde195b7f280);
#
#
#         var popup_bc4ef16920e25af0db8451032a3ca0e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a59e99a51e17cebfabffc4150553004e = $(`&lt;div id=&quot;html_a59e99a51e17cebfabffc4150553004e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bc4ef16920e25af0db8451032a3ca0e0.setContent(html_a59e99a51e17cebfabffc4150553004e);
#
#
#
#         marker_1bd9ca75f1a2c662fb59edd97a637b00.bindPopup(popup_bc4ef16920e25af0db8451032a3ca0e0)
#         ;
#
#
#
#
#             var marker_d7e08bc039aee7f3fce836c27c656928 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0c3054b3a85a1e789941dde195b7f280);
#
#
#         var popup_6bc21e317165467309d7f9b4cad51669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_674732ae544575e32a4e009bccb8bc70 = $(`&lt;div id=&quot;html_674732ae544575e32a4e009bccb8bc70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6bc21e317165467309d7f9b4cad51669.setContent(html_674732ae544575e32a4e009bccb8bc70);
#
#
#
#         marker_d7e08bc039aee7f3fce836c27c656928.bindPopup(popup_6bc21e317165467309d7f9b4cad51669)
#         ;
#
#
#
#
#             var marker_d72733865b2893fcb721c29b4d6f59bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0c3054b3a85a1e789941dde195b7f280);
#
#
#         var popup_8ced8e4fbb8aff8178e3ca7c12cbf068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4da58e0bc41809b42705fe95ffc36b2b = $(`&lt;div id=&quot;html_4da58e0bc41809b42705fe95ffc36b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ced8e4fbb8aff8178e3ca7c12cbf068.setContent(html_4da58e0bc41809b42705fe95ffc36b2b);
#
#
#
#         marker_d72733865b2893fcb721c29b4d6f59bf.bindPopup(popup_8ced8e4fbb8aff8178e3ca7c12cbf068)
#         ;
#
#
#
#
#             var marker_8b16ab2725ffc203f652bf53627bfc10 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0c3054b3a85a1e789941dde195b7f280);
#
#
#         var popup_6780cff7aa70b02aab89aa1cb1f56291 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8d64287e048fdd01138107e19e37629 = $(`&lt;div id=&quot;html_f8d64287e048fdd01138107e19e37629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6780cff7aa70b02aab89aa1cb1f56291.setContent(html_f8d64287e048fdd01138107e19e37629);
#
#
#
#         marker_8b16ab2725ffc203f652bf53627bfc10.bindPopup(popup_6780cff7aa70b02aab89aa1cb1f56291)
#         ;
#
#
#
#
#             var marker_e9186a5f15e3b87de70445ac62325683 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0c3054b3a85a1e789941dde195b7f280);
#
#
#         var popup_112abfbf86cc308433e930eef7ff527d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80ff0439a236c02d5a3781fc9607f955 = $(`&lt;div id=&quot;html_80ff0439a236c02d5a3781fc9607f955&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_112abfbf86cc308433e930eef7ff527d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_608606a48986219a7eed820a8037847b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_608606a48986219a7eed820a8037847b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_608606a48986219a7eed820a8037847b = L.map(
#                 &quot;map_608606a48986219a7eed820a8037847b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63624276302dc129430952f26ce8cf99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63624276302dc129430952f26ce8cf99.addTo(map_608606a48986219a7eed820a8037847b);
#
#
#             var feature_group_fa1eaab0fb14829ec2c1bc149934c68d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5d4f2429b4608cd60bd81075b14c385 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fa1eaab0fb14829ec2c1bc149934c68d);
#
#
#         var popup_625597eead3adae078ff68aac50a3340 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68cdfea804250e8c1a3a6f0f54ebdd6d = $(`&lt;div id=&quot;html_68cdfea804250e8c1a3a6f0f54ebdd6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_625597eead3adae078ff68aac50a3340.setContent(html_68cdfea804250e8c1a3a6f0f54ebdd6d);
#
#
#
#         marker_d5d4f2429b4608cd60bd81075b14c385.bindPopup(popup_625597eead3adae078ff68aac50a3340)
#         ;
#
#
#
#
#             var marker_5ce44fb9edb8da8be76fb985e0601b06 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fa1eaab0fb14829ec2c1bc149934c68d);
#
#
#         var popup_2e8b16d0e63496286063d6765772a546 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07bde31c588d3dd9b11b76209b8e24f5 = $(`&lt;div id=&quot;html_07bde31c588d3dd9b11b76209b8e24f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2e8b16d0e63496286063d6765772a546.setContent(html_07bde31c588d3dd9b11b76209b8e24f5);
#
#
#
#         marker_5ce44fb9edb8da8be76fb985e0601b06.bindPopup(popup_2e8b16d0e63496286063d6765772a546)
#         ;
#
#
#
#
#             var marker_a1f7d199d9dcd756e851071fe40246a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fa1eaab0fb14829ec2c1bc149934c68d);
#
#
#         var popup_5d878331a46cff7e915c3006c82598c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6212dc7728a231c42346d7e18c4e82fc = $(`&lt;div id=&quot;html_6212dc7728a231c42346d7e18c4e82fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5d878331a46cff7e915c3006c82598c6.setContent(html_6212dc7728a231c42346d7e18c4e82fc);
#
#
#
#         marker_a1f7d199d9dcd756e851071fe40246a0.bindPopup(popup_5d878331a46cff7e915c3006c82598c6)
#         ;
#
#
#
#
#             var marker_26ca0ebc7f3942df9bdb3f1f176d5178 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fa1eaab0fb14829ec2c1bc149934c68d);
#
#
#         var popup_9d874be1bcc6331c59f4aae9cfff1e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ccb3fdc6a20f0d1e1bca5dc91f3f10d = $(`&lt;div id=&quot;html_1ccb3fdc6a20f0d1e1bca5dc91f3f10d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9d874be1bcc6331c59f4aae9cfff1e6f.setContent(html_1ccb3fdc6a20f0d1e1bca5dc91f3f10d);
#
#
#
#         marker_26ca0ebc7f3942df9bdb3f1f176d5178.bindPopup(popup_9d874be1bcc6331c59f4aae9cfff1e6f)
#         ;
#
#
#
#
#             var marker_6edabc032b8567a0f4497b74069851a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fa1eaab0fb14829ec2c1bc149934c68d);
#
#
#         var popup_0a9776027a49dfd355948ffe0ee8b266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74040add598ac25abf426ae40b12bb09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74040add598ac25abf426ae40b12bb09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74040add598ac25abf426ae40b12bb09 = L.map(
#                 &quot;map_74040add598ac25abf426ae40b12bb09&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3c754f94561edd309255b6845ba8ed4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3c754f94561edd309255b6845ba8ed4.addTo(map_74040add598ac25abf426ae40b12bb09);
#
#
#             var feature_group_d3ec2653c37a1a992b6b7f3c09bf4d21 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d3ec2653c37a1a992b6b7f3c09bf4d21.addTo(map_74040add598ac25abf426ae40b12bb09);
#
#
#             var feature_group_sub_group_1a2a4d13cfc4f152594415caa7708913 = L.featureGroup.subGroup(
#                 feature_group_d3ec2653c37a1a992b6b7f3c09bf4d21
#             );
#
#
#             var marker_ca8bf70169ba7932ca1eccfcdc609437 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a2a4d13cfc4f152594415caa7708913);
#
#
#         var popup_d7feed1b5119cabacfccac53a7c379d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_024adfbab731eb70c73c593d461efa95 = $(`&lt;div id=&quot;html_024adfbab731eb70c73c593d461efa95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d7feed1b5119cabacfccac53a7c379d4.setContent(html_024adfbab731eb70c73c593d461efa95);
#
#
#
#         marker_ca8bf70169ba7932ca1eccfcdc609437.bindPopup(popup_d7feed1b5119cabacfccac53a7c379d4)
#         ;
#
#
#
#
#             var marker_33e9465f27918cb011412c7cf10c2694 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a2a4d13cfc4f152594415caa7708913);
#
#
#         var popup_07bb91b2eea7ad42a355e1c2803f01e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85d3514a22a596194ad089516ccf9bb9 = $(`&lt;div id=&quot;html_85d3514a22a596194ad089516ccf9bb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_07bb91b2eea7ad42a355e1c2803f01e3.setContent(html_85d3514a22a596194ad089516ccf9bb9);
#
#
#
#         marker_33e9465f27918cb011412c7cf10c2694.bindPopup(popup_07bb91b2eea7ad42a355e1c2803f01e3)
#         ;
#
#
#
#
#             var marker_37cbccf027a80f67424322577902e51a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a2a4d13cfc4f152594415caa7708913);
#
#
#         var popup_540d6f1d70b639769542d5153c77b6a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ce2ba7445f5ee9f17ff72a605472117 = $(`&lt;div id=&quot;html_6ce2ba7445f5ee9f17ff72a605472117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_540d6f1d70b639769542d5153c77b6a3.setContent(html_6ce2ba7445f5ee9f17ff72a605472117);
#
#
#
#         marker_37cbccf027a80f67424322577902e51a.bindPopup(popup_540d6f1d70b639769542d5153c77b6a3)
#         ;
#
#
#
#
#             var marker_bee5c87edd2848487efbc56a7b9f7416 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a2a4d13cfc4f152594415caa7708913);
#
#
#         var popup_b3771db5d109dab45e662eb0ad2cd65e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fd69822b51ea212b52b7d1fba5334b3 = $(`&lt;div id=&quot;html_2fd69822b51ea212b52b7d1fba5334b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b3771db5d109dab45e662eb0ad2cd65e.setContent(html_2fd69822b51ea212b52b7d1fba5334b3);
#
#
#
#         marker_
