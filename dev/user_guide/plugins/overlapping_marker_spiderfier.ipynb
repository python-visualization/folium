# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8adb0b0014c3159ca3475c2a273e3384 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8adb0b0014c3159ca3475c2a273e3384&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8adb0b0014c3159ca3475c2a273e3384 = L.map(
#                 &quot;map_8adb0b0014c3159ca3475c2a273e3384&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d2c34be6e54ffb81a5fc52bf7aff515 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d2c34be6e54ffb81a5fc52bf7aff515.addTo(map_8adb0b0014c3159ca3475c2a273e3384);
#
#
#             var marker_82075461323dcfcd5e603348e07da9e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8adb0b0014c3159ca3475c2a273e3384);
#
#
#         var popup_1d7466bdd5b90189081cbdc8c72733b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f7b71e44c2573bd49ad471a66f23877 = $(`&lt;div id=&quot;html_3f7b71e44c2573bd49ad471a66f23877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d7466bdd5b90189081cbdc8c72733b6.setContent(html_3f7b71e44c2573bd49ad471a66f23877);
#
#
#
#         marker_82075461323dcfcd5e603348e07da9e9.bindPopup(popup_1d7466bdd5b90189081cbdc8c72733b6)
#         ;
#
#
#
#
#             var marker_395324407a9d95eabace3cd389708cba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8adb0b0014c3159ca3475c2a273e3384);
#
#
#         var popup_7c565654c29edf2206d12175f27c332f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8094d93e014da47996afdd89218aa767 = $(`&lt;div id=&quot;html_8094d93e014da47996afdd89218aa767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7c565654c29edf2206d12175f27c332f.setContent(html_8094d93e014da47996afdd89218aa767);
#
#
#
#         marker_395324407a9d95eabace3cd389708cba.bindPopup(popup_7c565654c29edf2206d12175f27c332f)
#         ;
#
#
#
#
#             var marker_24f5a31c04be1c20d52b1dd77d604404 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8adb0b0014c3159ca3475c2a273e3384);
#
#
#         var popup_6b106dbf0510048347717b715a5a3f75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7091c815669a4d7506ccd47b68c61b0 = $(`&lt;div id=&quot;html_f7091c815669a4d7506ccd47b68c61b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6b106dbf0510048347717b715a5a3f75.setContent(html_f7091c815669a4d7506ccd47b68c61b0);
#
#
#
#         marker_24f5a31c04be1c20d52b1dd77d604404.bindPopup(popup_6b106dbf0510048347717b715a5a3f75)
#         ;
#
#
#
#
#             var marker_f3916392b34f5b0f10c762a3907fcb93 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8adb0b0014c3159ca3475c2a273e3384);
#
#
#         var popup_87985e31e10ccea1ccf031e89da8bd62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea64e5ef41d37d88e5e3d6865d9fbb75 = $(`&lt;div id=&quot;html_ea64e5ef41d37d88e5e3d6865d9fbb75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_87985e31e10ccea1ccf031e89da8bd62.setContent(html_ea64e5ef41d37d88e5e3d6865d9fbb75);
#
#
#
#         marker_f3916392b34f5b0f10c762a3907fcb93.bindPopup(popup_87985e31e10ccea1ccf031e89da8bd62)
#         ;
#
#
#
#
#             var marker_6a7f1ea1c4f27bae11be3b37fbbe5669 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8adb0b0014c3159ca3475c2a273e3384);
#
#
#         var popup_03ea6234ba7c39cd7696dc918a8d5014 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06b163737716df9ed6b995b73c77d13f = $(`&lt;div id=&quot;html_06b163737716df9ed6b995b73c77d13f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_03ea6234ba7c39cd7696dc918a8d5014.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_505077cb6340fef7c3fd930809dc443e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_505077cb6340fef7c3fd930809dc443e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_505077cb6340fef7c3fd930809dc443e = L.map(
#                 &quot;map_505077cb6340fef7c3fd930809dc443e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bb4170768c5cd5a999be91ebeb51f5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bb4170768c5cd5a999be91ebeb51f5d.addTo(map_505077cb6340fef7c3fd930809dc443e);
#
#
#             var feature_group_07ec10b0ff9a342a0b75d49cb4ec81bc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6045bed5786ba4732bd6a20f1f7953bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_07ec10b0ff9a342a0b75d49cb4ec81bc);
#
#
#         var popup_29fa8aacb0e276ded053edba1cb83572 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ea9b4ed44267cc56327179d97f0bdfa = $(`&lt;div id=&quot;html_8ea9b4ed44267cc56327179d97f0bdfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_29fa8aacb0e276ded053edba1cb83572.setContent(html_8ea9b4ed44267cc56327179d97f0bdfa);
#
#
#
#         marker_6045bed5786ba4732bd6a20f1f7953bb.bindPopup(popup_29fa8aacb0e276ded053edba1cb83572)
#         ;
#
#
#
#
#             var marker_e155c7e1fcf871380182615f3b71cad9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_07ec10b0ff9a342a0b75d49cb4ec81bc);
#
#
#         var popup_d4ac59060d416d762a864c52759cf559 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3db89c5f0c82e40ce97ec4f340ec1791 = $(`&lt;div id=&quot;html_3db89c5f0c82e40ce97ec4f340ec1791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d4ac59060d416d762a864c52759cf559.setContent(html_3db89c5f0c82e40ce97ec4f340ec1791);
#
#
#
#         marker_e155c7e1fcf871380182615f3b71cad9.bindPopup(popup_d4ac59060d416d762a864c52759cf559)
#         ;
#
#
#
#
#             var marker_9088e3ba2199fdd22f3b13a0289a0b9b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_07ec10b0ff9a342a0b75d49cb4ec81bc);
#
#
#         var popup_cdf29a85503afc59aaf2a8dfc3d67e14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bfd57603b22627d75dcc9d81122f14f = $(`&lt;div id=&quot;html_7bfd57603b22627d75dcc9d81122f14f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cdf29a85503afc59aaf2a8dfc3d67e14.setContent(html_7bfd57603b22627d75dcc9d81122f14f);
#
#
#
#         marker_9088e3ba2199fdd22f3b13a0289a0b9b.bindPopup(popup_cdf29a85503afc59aaf2a8dfc3d67e14)
#         ;
#
#
#
#
#             var marker_4d663f8271f47aec43931c63da7af06b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_07ec10b0ff9a342a0b75d49cb4ec81bc);
#
#
#         var popup_d66640515c2f553d8ff885a20a8d3f85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc6420340e814e9465bdfe39c10ad11c = $(`&lt;div id=&quot;html_cc6420340e814e9465bdfe39c10ad11c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d66640515c2f553d8ff885a20a8d3f85.setContent(html_cc6420340e814e9465bdfe39c10ad11c);
#
#
#
#         marker_4d663f8271f47aec43931c63da7af06b.bindPopup(popup_d66640515c2f553d8ff885a20a8d3f85)
#         ;
#
#
#
#
#             var marker_f9bf0d38ad0e771d5b2ce44ef22f2cd2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_07ec10b0ff9a342a0b75d49cb4ec81bc);
#
#
#         var popup_ff1bfa10791c9e45e85941456f559701 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dad3d2beb5a88b037d9f1b129ab81d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dad3d2beb5a88b037d9f1b129ab81d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dad3d2beb5a88b037d9f1b129ab81d8 = L.map(
#                 &quot;map_9dad3d2beb5a88b037d9f1b129ab81d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0140e6862b64649ee8c25089866b499 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0140e6862b64649ee8c25089866b499.addTo(map_9dad3d2beb5a88b037d9f1b129ab81d8);
#
#
#             var feature_group_a04f538ea4b261f14f1b66c788c242ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a04f538ea4b261f14f1b66c788c242ba.addTo(map_9dad3d2beb5a88b037d9f1b129ab81d8);
#
#
#             var feature_group_sub_group_ad30eb40e4875138d9ea1957d5934f7c = L.featureGroup.subGroup(
#                 feature_group_a04f538ea4b261f14f1b66c788c242ba
#             );
#
#
#             var marker_7d54a86398b51973e5427a3aae917303 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad30eb40e4875138d9ea1957d5934f7c);
#
#
#         var popup_5a4556d921fe8a4c8e177d4396f652bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca2ad7f9266120dbdc1fd0d04b372688 = $(`&lt;div id=&quot;html_ca2ad7f9266120dbdc1fd0d04b372688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5a4556d921fe8a4c8e177d4396f652bb.setContent(html_ca2ad7f9266120dbdc1fd0d04b372688);
#
#
#
#         marker_7d54a86398b51973e5427a3aae917303.bindPopup(popup_5a4556d921fe8a4c8e177d4396f652bb)
#         ;
#
#
#
#
#             var marker_9614ddd7f936dd72c91daf7a4bb8f4bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad30eb40e4875138d9ea1957d5934f7c);
#
#
#         var popup_67d2bda0c19cb4f57664a173f3b77d2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_443d1c681984bfe38256adb34c53bc08 = $(`&lt;div id=&quot;html_443d1c681984bfe38256adb34c53bc08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_67d2bda0c19cb4f57664a173f3b77d2b.setContent(html_443d1c681984bfe38256adb34c53bc08);
#
#
#
#         marker_9614ddd7f936dd72c91daf7a4bb8f4bf.bindPopup(popup_67d2bda0c19cb4f57664a173f3b77d2b)
#         ;
#
#
#
#
#             var marker_e5467a13a0164106e428156622aca3b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad30eb40e4875138d9ea1957d5934f7c);
#
#
#         var popup_88dc6d973a1d438b9d80ea89d3f0f2bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee0b37be5dca76bc5d665428c4c50b5e = $(`&lt;div id=&quot;html_ee0b37be5dca76bc5d665428c4c50b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88dc6d973a1d438b9d80ea89d3f0f2bc.setContent(html_ee0b37be5dca76bc5d665428c4c50b5e);
#
#
#
#         marker_e5467a13a0164106e428156622aca3b7.bindPopup(popup_88dc6d973a1d438b9d80ea89d3f0f2bc)
#         ;
#
#
#
#
#             var marker_87ace4c87da6b91d7e34c886c42b8be9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad30eb40e4875138d9ea1957d5934f7c);
#
#
#         var popup_6d1943ab95e6efa21ae6f965bb5b1058 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f494a59284d696859577d44ea4cdf174 = $(`&lt;div id=&quot;html_f494a59284d696859577d44ea4cdf174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6d1943ab95e6efa21ae6f965bb5b1058.setContent(html_f494a59284d696859577d44ea4cdf174);
#
#
#
#         marker_
