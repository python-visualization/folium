# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca61539bb268ebcd461ce78ac26d891b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca61539bb268ebcd461ce78ac26d891b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca61539bb268ebcd461ce78ac26d891b = L.map(
#                 &quot;map_ca61539bb268ebcd461ce78ac26d891b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f020028d2440451f8ed1ea26a163709 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f020028d2440451f8ed1ea26a163709.addTo(map_ca61539bb268ebcd461ce78ac26d891b);
#
#
#             var marker_7ebcecae6b9e23867d52177fad8bc6d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ca61539bb268ebcd461ce78ac26d891b);
#
#
#         var popup_2fb241b1b5f3468ed0e9360ad7576b94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbfd8d59956c43148d578ed78596e275 = $(`&lt;div id=&quot;html_dbfd8d59956c43148d578ed78596e275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2fb241b1b5f3468ed0e9360ad7576b94.setContent(html_dbfd8d59956c43148d578ed78596e275);
#
#
#
#         marker_7ebcecae6b9e23867d52177fad8bc6d4.bindPopup(popup_2fb241b1b5f3468ed0e9360ad7576b94)
#         ;
#
#
#
#
#             var marker_a5b1a82d0c202592864f2e62ed6fa1a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ca61539bb268ebcd461ce78ac26d891b);
#
#
#         var popup_5f1f2451255b578aadb8dbbb3772d158 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5819fff151c72c79475f22bb775bac67 = $(`&lt;div id=&quot;html_5819fff151c72c79475f22bb775bac67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5f1f2451255b578aadb8dbbb3772d158.setContent(html_5819fff151c72c79475f22bb775bac67);
#
#
#
#         marker_a5b1a82d0c202592864f2e62ed6fa1a1.bindPopup(popup_5f1f2451255b578aadb8dbbb3772d158)
#         ;
#
#
#
#
#             var marker_3fd524066a8545d6e862b38f7b8b9514 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ca61539bb268ebcd461ce78ac26d891b);
#
#
#         var popup_836cb487c86777e296508be7fdf91665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e62ad874967c227530d3f54031b49bd = $(`&lt;div id=&quot;html_6e62ad874967c227530d3f54031b49bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_836cb487c86777e296508be7fdf91665.setContent(html_6e62ad874967c227530d3f54031b49bd);
#
#
#
#         marker_3fd524066a8545d6e862b38f7b8b9514.bindPopup(popup_836cb487c86777e296508be7fdf91665)
#         ;
#
#
#
#
#             var marker_ad907ed5f3c0d57040a6d3f86f3b363e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ca61539bb268ebcd461ce78ac26d891b);
#
#
#         var popup_e29172e3c863069f21578a5fe8e38780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_313827a7af540803922a5050db29c4f2 = $(`&lt;div id=&quot;html_313827a7af540803922a5050db29c4f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e29172e3c863069f21578a5fe8e38780.setContent(html_313827a7af540803922a5050db29c4f2);
#
#
#
#         marker_ad907ed5f3c0d57040a6d3f86f3b363e.bindPopup(popup_e29172e3c863069f21578a5fe8e38780)
#         ;
#
#
#
#
#             var marker_598b407d13940aae0102db90cfb030dd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ca61539bb268ebcd461ce78ac26d891b);
#
#
#         var popup_ea31b7463fe3f6271eaaf99015299546 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37564612fb6c30ae13612c1cb7b2e233 = $(`&lt;div id=&quot;html_37564612fb6c30ae13612c1cb7b2e233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ea31b7463fe3f6271eaaf990152995

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d875d3765c7eba91a9862ce7bf6cd1e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d875d3765c7eba91a9862ce7bf6cd1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d875d3765c7eba91a9862ce7bf6cd1e = L.map(
#                 &quot;map_8d875d3765c7eba91a9862ce7bf6cd1e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1009740bacd73a5b989069c76737abda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1009740bacd73a5b989069c76737abda.addTo(map_8d875d3765c7eba91a9862ce7bf6cd1e);
#
#
#             var feature_group_264511c099b007fb2e52e298666b338f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_13dab0e9d1bc69fb55555e34ae92e552 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_264511c099b007fb2e52e298666b338f);
#
#
#         var popup_9b0bf61fcb732c683ade00bba26c54cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_019b0b827fbccc3f17fd645db7119296 = $(`&lt;div id=&quot;html_019b0b827fbccc3f17fd645db7119296&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9b0bf61fcb732c683ade00bba26c54cf.setContent(html_019b0b827fbccc3f17fd645db7119296);
#
#
#
#         marker_13dab0e9d1bc69fb55555e34ae92e552.bindPopup(popup_9b0bf61fcb732c683ade00bba26c54cf)
#         ;
#
#
#
#
#             var marker_118fdbe520fd649693a7b5657fe7ae2c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_264511c099b007fb2e52e298666b338f);
#
#
#         var popup_0f58e3903a6bc89a4602cf6b481c19e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18af1fad403895136749a1e330097857 = $(`&lt;div id=&quot;html_18af1fad403895136749a1e330097857&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0f58e3903a6bc89a4602cf6b481c19e9.setContent(html_18af1fad403895136749a1e330097857);
#
#
#
#         marker_118fdbe520fd649693a7b5657fe7ae2c.bindPopup(popup_0f58e3903a6bc89a4602cf6b481c19e9)
#         ;
#
#
#
#
#             var marker_57676abb946ba6b76997fb73deaf97ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_264511c099b007fb2e52e298666b338f);
#
#
#         var popup_ab4b44422371a6866c3233d0329442eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14320621e785e1b35dc642110c536b4f = $(`&lt;div id=&quot;html_14320621e785e1b35dc642110c536b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ab4b44422371a6866c3233d0329442eb.setContent(html_14320621e785e1b35dc642110c536b4f);
#
#
#
#         marker_57676abb946ba6b76997fb73deaf97ec.bindPopup(popup_ab4b44422371a6866c3233d0329442eb)
#         ;
#
#
#
#
#             var marker_d5ebea953d4e0279b188ffcf8dcee256 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_264511c099b007fb2e52e298666b338f);
#
#
#         var popup_045aaedc19d4b6a546b072561620d81f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a265e98ddf4a10cae68693ce9a6933da = $(`&lt;div id=&quot;html_a265e98ddf4a10cae68693ce9a6933da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_045aaedc19d4b6a546b072561620d81f.setContent(html_a265e98ddf4a10cae68693ce9a6933da);
#
#
#
#         marker_d5ebea953d4e0279b188ffcf8dcee256.bindPopup(popup_045aaedc19d4b6a546b072561620d81f)
#         ;
#
#
#
#
#             var marker_18a6b0eb8d4ee362aa159d2f70874055 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_264511c099b007fb2e52e298666b338f);
#
#
#         var popup_d1ca9bd0412a66c6374e196e98759c41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a260a3eef4b527455f552ccf89fafab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a260a3eef4b527455f552ccf89fafab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a260a3eef4b527455f552ccf89fafab = L.map(
#                 &quot;map_2a260a3eef4b527455f552ccf89fafab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f30e777df96d2562479cf8f63bdca0b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f30e777df96d2562479cf8f63bdca0b4.addTo(map_2a260a3eef4b527455f552ccf89fafab);
#
#
#             var feature_group_1ce58afb5a838913cb07f1e15bb6d6b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1ce58afb5a838913cb07f1e15bb6d6b7.addTo(map_2a260a3eef4b527455f552ccf89fafab);
#
#
#             var feature_group_sub_group_814e580f8733e31f1ad904d06eb43a0b = L.featureGroup.subGroup(
#                 feature_group_1ce58afb5a838913cb07f1e15bb6d6b7
#             );
#
#
#             var marker_c89c7ef86235d0f2a913dfbf5f0b69ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_814e580f8733e31f1ad904d06eb43a0b);
#
#
#         var popup_ac174f1185c8d6fe7abc74b191b3b10a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_970d0a3c8c87a712d7bf7ad163b84374 = $(`&lt;div id=&quot;html_970d0a3c8c87a712d7bf7ad163b84374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ac174f1185c8d6fe7abc74b191b3b10a.setContent(html_970d0a3c8c87a712d7bf7ad163b84374);
#
#
#
#         marker_c89c7ef86235d0f2a913dfbf5f0b69ee.bindPopup(popup_ac174f1185c8d6fe7abc74b191b3b10a)
#         ;
#
#
#
#
#             var marker_a58ed9a4503a1d736f86ac47e71e1b21 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_814e580f8733e31f1ad904d06eb43a0b);
#
#
#         var popup_19dde337a997473fd3b8814d60a93a69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e20d5a78e7d1c7b09169978ecfc88f07 = $(`&lt;div id=&quot;html_e20d5a78e7d1c7b09169978ecfc88f07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_19dde337a997473fd3b8814d60a93a69.setContent(html_e20d5a78e7d1c7b09169978ecfc88f07);
#
#
#
#         marker_a58ed9a4503a1d736f86ac47e71e1b21.bindPopup(popup_19dde337a997473fd3b8814d60a93a69)
#         ;
#
#
#
#
#             var marker_6a06007b2c900465631a60fc2f4f1540 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_814e580f8733e31f1ad904d06eb43a0b);
#
#
#         var popup_83f69ee1074dbb558120fa30b27c17c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1b2ba7f863769a66cfda3d652b45ae0 = $(`&lt;div id=&quot;html_e1b2ba7f863769a66cfda3d652b45ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_83f69ee1074dbb558120fa30b27c17c9.setContent(html_e1b2ba7f863769a66cfda3d652b45ae0);
#
#
#
#         marker_6a06007b2c900465631a60fc2f4f1540.bindPopup(popup_83f69ee1074dbb558120fa30b27c17c9)
#         ;
#
#
#
#
#             var marker_313e8511a997fff3a2e13dc87785a560 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_814e580f8733e31f1ad904d06eb43a0b);
#
#
#         var popup_274978fd6bd665766d8de6fa6b20faa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ae02678b5f8eda9b4e248caaaff9add = $(`&lt;div id=&quot;html_6ae02678b5f8eda9b4e248caaaff9add&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_274978fd6bd665766d8de6fa6b20faa0.setContent(html_6ae02678b5f8eda9b4e248caaaff9add);
#
#
#
#         mark
