# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3117cd8969dffe87a0f550f8f966c935 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3117cd8969dffe87a0f550f8f966c935&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3117cd8969dffe87a0f550f8f966c935 = L.map(
#                 &quot;map_3117cd8969dffe87a0f550f8f966c935&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a958f3d72c10fee12cd0e2c2ca08570 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a958f3d72c10fee12cd0e2c2ca08570.addTo(map_3117cd8969dffe87a0f550f8f966c935);
#
#
#             var marker_144bc6eaf49ee9d01244c6f505bfa1ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3117cd8969dffe87a0f550f8f966c935);
#
#
#         var popup_a3c2ed144c27ed48fa6e91aabfef6c03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8006d2b88917d24e14291e35ffc77e6f = $(`&lt;div id=&quot;html_8006d2b88917d24e14291e35ffc77e6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a3c2ed144c27ed48fa6e91aabfef6c03.setContent(html_8006d2b88917d24e14291e35ffc77e6f);
#
#
#
#         marker_144bc6eaf49ee9d01244c6f505bfa1ff.bindPopup(popup_a3c2ed144c27ed48fa6e91aabfef6c03)
#         ;
#
#
#
#
#             var marker_22b31c5d26c8e403fd3ecff14faa2597 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3117cd8969dffe87a0f550f8f966c935);
#
#
#         var popup_3074584058501e0040dfd908ad2d03c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a300aa7b0fdf72af488fb3c0becc76fd = $(`&lt;div id=&quot;html_a300aa7b0fdf72af488fb3c0becc76fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3074584058501e0040dfd908ad2d03c4.setContent(html_a300aa7b0fdf72af488fb3c0becc76fd);
#
#
#
#         marker_22b31c5d26c8e403fd3ecff14faa2597.bindPopup(popup_3074584058501e0040dfd908ad2d03c4)
#         ;
#
#
#
#
#             var marker_68c762d9ef06fe962d04ef4db5db4b4d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3117cd8969dffe87a0f550f8f966c935);
#
#
#         var popup_aec2ac8aa309c32385a41a456208cf22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afc47bab5f98012ced180994bcf6adc9 = $(`&lt;div id=&quot;html_afc47bab5f98012ced180994bcf6adc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_aec2ac8aa309c32385a41a456208cf22.setContent(html_afc47bab5f98012ced180994bcf6adc9);
#
#
#
#         marker_68c762d9ef06fe962d04ef4db5db4b4d.bindPopup(popup_aec2ac8aa309c32385a41a456208cf22)
#         ;
#
#
#
#
#             var marker_fbbb9f0fbc08237c61fa6cae2c003109 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3117cd8969dffe87a0f550f8f966c935);
#
#
#         var popup_80ded917ca8f657a9dd68fd114798f06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_739387d2dcd06c8c5624ca47784c7b82 = $(`&lt;div id=&quot;html_739387d2dcd06c8c5624ca47784c7b82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_80ded917ca8f657a9dd68fd114798f06.setContent(html_739387d2dcd06c8c5624ca47784c7b82);
#
#
#
#         marker_fbbb9f0fbc08237c61fa6cae2c003109.bindPopup(popup_80ded917ca8f657a9dd68fd114798f06)
#         ;
#
#
#
#
#             var marker_0cd0a2477832a6f67ef03770e5202f29 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3117cd8969dffe87a0f550f8f966c935);
#
#
#         var popup_2e7eeceb1e76b1d0a3bbf9a2845f0a73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbf08d5f6e55fbbd873f49de05733678 = $(`&lt;div id=&quot;html_bbf08d5f6e55fbbd873f49de05733678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2e7eeceb1e76b1d0a3bbf9a2845f0a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_909e2b10b990efad8653431ddc5c3ea2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_909e2b10b990efad8653431ddc5c3ea2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_909e2b10b990efad8653431ddc5c3ea2 = L.map(
#                 &quot;map_909e2b10b990efad8653431ddc5c3ea2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f02414d148afb28f88a497dc5c16ae9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f02414d148afb28f88a497dc5c16ae9d.addTo(map_909e2b10b990efad8653431ddc5c3ea2);
#
#
#             var feature_group_743db47eb7101dac106b5fb19156487c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_af7d84888de2d929bff96c3428fecedb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_743db47eb7101dac106b5fb19156487c);
#
#
#         var popup_b8ccb4b99aa07bde1bbddf35d93554dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4efa661c9929c75b9e79e2c345b864fc = $(`&lt;div id=&quot;html_4efa661c9929c75b9e79e2c345b864fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b8ccb4b99aa07bde1bbddf35d93554dc.setContent(html_4efa661c9929c75b9e79e2c345b864fc);
#
#
#
#         marker_af7d84888de2d929bff96c3428fecedb.bindPopup(popup_b8ccb4b99aa07bde1bbddf35d93554dc)
#         ;
#
#
#
#
#             var marker_664a4e4ea2f5dc819748e18cc769aaee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_743db47eb7101dac106b5fb19156487c);
#
#
#         var popup_69fda57fec633d23c7b2f5cef940d98c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_701075a438a32637932a59f3a33b881a = $(`&lt;div id=&quot;html_701075a438a32637932a59f3a33b881a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_69fda57fec633d23c7b2f5cef940d98c.setContent(html_701075a438a32637932a59f3a33b881a);
#
#
#
#         marker_664a4e4ea2f5dc819748e18cc769aaee.bindPopup(popup_69fda57fec633d23c7b2f5cef940d98c)
#         ;
#
#
#
#
#             var marker_c1b564f7a493189a0f771097bad28990 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_743db47eb7101dac106b5fb19156487c);
#
#
#         var popup_f076c6d195560c906a6a729242e9f4b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_468fe633022eb1f0021dbc139e918cf5 = $(`&lt;div id=&quot;html_468fe633022eb1f0021dbc139e918cf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f076c6d195560c906a6a729242e9f4b6.setContent(html_468fe633022eb1f0021dbc139e918cf5);
#
#
#
#         marker_c1b564f7a493189a0f771097bad28990.bindPopup(popup_f076c6d195560c906a6a729242e9f4b6)
#         ;
#
#
#
#
#             var marker_ef6517aae74df3ee3924b8b395442d18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_743db47eb7101dac106b5fb19156487c);
#
#
#         var popup_b2555c43a5471f728789e43fe0d99ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c04ef6cede88bd2a799f27bb808456d = $(`&lt;div id=&quot;html_8c04ef6cede88bd2a799f27bb808456d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b2555c43a5471f728789e43fe0d99ce2.setContent(html_8c04ef6cede88bd2a799f27bb808456d);
#
#
#
#         marker_ef6517aae74df3ee3924b8b395442d18.bindPopup(popup_b2555c43a5471f728789e43fe0d99ce2)
#         ;
#
#
#
#
#             var marker_76115582ff196e579cd68d4b8907a8e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_743db47eb7101dac106b5fb19156487c);
#
#
#         var popup_a0a614a73f08c15549b2e2d0270fcd3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cf4aa32d2262cf96fe0c4968d909fcb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cf4aa32d2262cf96fe0c4968d909fcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7cf4aa32d2262cf96fe0c4968d909fcb = L.map(
#                 &quot;map_7cf4aa32d2262cf96fe0c4968d909fcb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61630fc505a54faa6663195b23278d55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61630fc505a54faa6663195b23278d55.addTo(map_7cf4aa32d2262cf96fe0c4968d909fcb);
#
#
#             var feature_group_67da29d0014656fb7477009b6c6c4874 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_67da29d0014656fb7477009b6c6c4874.addTo(map_7cf4aa32d2262cf96fe0c4968d909fcb);
#
#
#             var feature_group_sub_group_16915cb7d62241b75f98aede4237beb9 = L.featureGroup.subGroup(
#                 feature_group_67da29d0014656fb7477009b6c6c4874
#             );
#
#
#             var marker_355cad6a6dd6373ee33c5258b5d7db82 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_16915cb7d62241b75f98aede4237beb9);
#
#
#         var popup_74de6c136f061c6350c61922b8a5425d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5536e5906276bb605514bb7f1fea0b0a = $(`&lt;div id=&quot;html_5536e5906276bb605514bb7f1fea0b0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_74de6c136f061c6350c61922b8a5425d.setContent(html_5536e5906276bb605514bb7f1fea0b0a);
#
#
#
#         marker_355cad6a6dd6373ee33c5258b5d7db82.bindPopup(popup_74de6c136f061c6350c61922b8a5425d)
#         ;
#
#
#
#
#             var marker_97dd870db8cd10fdfa5689422ff9038e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_16915cb7d62241b75f98aede4237beb9);
#
#
#         var popup_996bfeb307036ac39705a3d09ef5bd94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_970cdc1bc42b86c2d7a4a8ea277f2077 = $(`&lt;div id=&quot;html_970cdc1bc42b86c2d7a4a8ea277f2077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_996bfeb307036ac39705a3d09ef5bd94.setContent(html_970cdc1bc42b86c2d7a4a8ea277f2077);
#
#
#
#         marker_97dd870db8cd10fdfa5689422ff9038e.bindPopup(popup_996bfeb307036ac39705a3d09ef5bd94)
#         ;
#
#
#
#
#             var marker_c139f377ad31c3943c8525022f050e6d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_16915cb7d62241b75f98aede4237beb9);
#
#
#         var popup_02cada264fc7dd28b01c03ced3d2bff5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d8b2a6dd7ea24c8b475b9eadc7adba0 = $(`&lt;div id=&quot;html_3d8b2a6dd7ea24c8b475b9eadc7adba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_02cada264fc7dd28b01c03ced3d2bff5.setContent(html_3d8b2a6dd7ea24c8b475b9eadc7adba0);
#
#
#
#         marker_c139f377ad31c3943c8525022f050e6d.bindPopup(popup_02cada264fc7dd28b01c03ced3d2bff5)
#         ;
#
#
#
#
#             var marker_e0054fb4ee7f566645585bf7ee5c2a8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_16915cb7d62241b75f98aede4237beb9);
#
#
#         var popup_f77b45ecacbcaa25f5ac84f9ad16c0d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70ce24f9b75ef19910ee6cf3c9d4a2ec = $(`&lt;div id=&quot;html_70ce24f9b75ef19910ee6cf3c9d4a2ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f77b45ecacbcaa25f5ac84f9ad16c0d4.setContent(html_70ce24f9b75ef19910ee6cf3c9d4a2ec);
#
#
#
#         mark
