# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_180fd1e8ad7fbe8894e1379e78cbbadf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_180fd1e8ad7fbe8894e1379e78cbbadf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_180fd1e8ad7fbe8894e1379e78cbbadf = L.map(
#                 &quot;map_180fd1e8ad7fbe8894e1379e78cbbadf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f06acd6fd4356cd4f5491ad47f07e47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f06acd6fd4356cd4f5491ad47f07e47.addTo(map_180fd1e8ad7fbe8894e1379e78cbbadf);
#
#
#             var marker_443b7fe6fe517d87d5b90f571f91a373 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_180fd1e8ad7fbe8894e1379e78cbbadf);
#
#
#         var popup_a8188f9182bebb44344a32e6e7cf2f1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf456bd0c16a83770a700837ef361cd9 = $(`&lt;div id=&quot;html_cf456bd0c16a83770a700837ef361cd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a8188f9182bebb44344a32e6e7cf2f1f.setContent(html_cf456bd0c16a83770a700837ef361cd9);
#
#
#
#         marker_443b7fe6fe517d87d5b90f571f91a373.bindPopup(popup_a8188f9182bebb44344a32e6e7cf2f1f)
#         ;
#
#
#
#
#             var marker_c7098c744dd971dd5b5223605d570e60 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_180fd1e8ad7fbe8894e1379e78cbbadf);
#
#
#         var popup_b3a1a9be42059604595414d92860757b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d93ef1f7376f699edafc64f7834c8470 = $(`&lt;div id=&quot;html_d93ef1f7376f699edafc64f7834c8470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b3a1a9be42059604595414d92860757b.setContent(html_d93ef1f7376f699edafc64f7834c8470);
#
#
#
#         marker_c7098c744dd971dd5b5223605d570e60.bindPopup(popup_b3a1a9be42059604595414d92860757b)
#         ;
#
#
#
#
#             var marker_4371f2d76f82b96bca8aa0b03da90a5e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_180fd1e8ad7fbe8894e1379e78cbbadf);
#
#
#         var popup_6f52645ebea8c7779da8d0bd8b1e3b08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_263f136d46efe77d41dc142b3b9ffeb4 = $(`&lt;div id=&quot;html_263f136d46efe77d41dc142b3b9ffeb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6f52645ebea8c7779da8d0bd8b1e3b08.setContent(html_263f136d46efe77d41dc142b3b9ffeb4);
#
#
#
#         marker_4371f2d76f82b96bca8aa0b03da90a5e.bindPopup(popup_6f52645ebea8c7779da8d0bd8b1e3b08)
#         ;
#
#
#
#
#             var marker_962b1871acee378a5c9afe67d8264ab6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_180fd1e8ad7fbe8894e1379e78cbbadf);
#
#
#         var popup_c28d09a75f9feaf687e1814cef700123 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e480162b333f1a893a0b17ae8da0639 = $(`&lt;div id=&quot;html_8e480162b333f1a893a0b17ae8da0639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c28d09a75f9feaf687e1814cef700123.setContent(html_8e480162b333f1a893a0b17ae8da0639);
#
#
#
#         marker_962b1871acee378a5c9afe67d8264ab6.bindPopup(popup_c28d09a75f9feaf687e1814cef700123)
#         ;
#
#
#
#
#             var marker_f5ef166f4eb1de6045fe686729b9adf7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_180fd1e8ad7fbe8894e1379e78cbbadf);
#
#
#         var popup_52c3663a426aaa064dc53c3a94f88a2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36413f75bcfbc977e95bde4eff2ebdbb = $(`&lt;div id=&quot;html_36413f75bcfbc977e95bde4eff2ebdbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_52c3663a426aaa064dc53c3a94f88a2d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a27c7b0525ef617c907533d8b192de1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a27c7b0525ef617c907533d8b192de1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a27c7b0525ef617c907533d8b192de1c = L.map(
#                 &quot;map_a27c7b0525ef617c907533d8b192de1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a228cb0ba75d1e8d265487572bc85732 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a228cb0ba75d1e8d265487572bc85732.addTo(map_a27c7b0525ef617c907533d8b192de1c);
#
#
#             var feature_group_421a19e50c74af6c38b47e5032c855d8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3037b3e6bbcfafc700aeeeb36126ea9c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_421a19e50c74af6c38b47e5032c855d8);
#
#
#         var popup_34df022772df5e4d6c0f3bfceeb06a3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cde1359500011112b6913442bdc24a3 = $(`&lt;div id=&quot;html_1cde1359500011112b6913442bdc24a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_34df022772df5e4d6c0f3bfceeb06a3d.setContent(html_1cde1359500011112b6913442bdc24a3);
#
#
#
#         marker_3037b3e6bbcfafc700aeeeb36126ea9c.bindPopup(popup_34df022772df5e4d6c0f3bfceeb06a3d)
#         ;
#
#
#
#
#             var marker_fd7ec3c7f6e17de1a4689f2e9ff88700 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_421a19e50c74af6c38b47e5032c855d8);
#
#
#         var popup_8867e5885728aba47ad2a4464e6947eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b1dbf940b1394290192f9e2b7831e27 = $(`&lt;div id=&quot;html_4b1dbf940b1394290192f9e2b7831e27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8867e5885728aba47ad2a4464e6947eb.setContent(html_4b1dbf940b1394290192f9e2b7831e27);
#
#
#
#         marker_fd7ec3c7f6e17de1a4689f2e9ff88700.bindPopup(popup_8867e5885728aba47ad2a4464e6947eb)
#         ;
#
#
#
#
#             var marker_20a8cedd860d80fbd9696e3808d2e1c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_421a19e50c74af6c38b47e5032c855d8);
#
#
#         var popup_6de631f88a871ba4990819edc7e1e880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95af99a390c4b287fe9cb310e0228299 = $(`&lt;div id=&quot;html_95af99a390c4b287fe9cb310e0228299&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6de631f88a871ba4990819edc7e1e880.setContent(html_95af99a390c4b287fe9cb310e0228299);
#
#
#
#         marker_20a8cedd860d80fbd9696e3808d2e1c0.bindPopup(popup_6de631f88a871ba4990819edc7e1e880)
#         ;
#
#
#
#
#             var marker_b4c2e3ec163f98ea3db4f164ecff4d54 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_421a19e50c74af6c38b47e5032c855d8);
#
#
#         var popup_f1f35d7ac6fc7ddb28f4765cc7561f55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_722de33a09cb17aebd590b635b39a42e = $(`&lt;div id=&quot;html_722de33a09cb17aebd590b635b39a42e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f1f35d7ac6fc7ddb28f4765cc7561f55.setContent(html_722de33a09cb17aebd590b635b39a42e);
#
#
#
#         marker_b4c2e3ec163f98ea3db4f164ecff4d54.bindPopup(popup_f1f35d7ac6fc7ddb28f4765cc7561f55)
#         ;
#
#
#
#
#             var marker_e4c5c5bde3e6bb8206f2d5453da2d191 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_421a19e50c74af6c38b47e5032c855d8);
#
#
#         var popup_b081e6b670991f5a735da09554fb3155 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57bc44e4da23b4af09444e68e9cb0740 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57bc44e4da23b4af09444e68e9cb0740&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57bc44e4da23b4af09444e68e9cb0740 = L.map(
#                 &quot;map_57bc44e4da23b4af09444e68e9cb0740&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8bdb609fcf2159d7c7c5689cff6ebab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8bdb609fcf2159d7c7c5689cff6ebab.addTo(map_57bc44e4da23b4af09444e68e9cb0740);
#
#
#             var feature_group_4c8ad100b35e9a01589c20d30f626769 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4c8ad100b35e9a01589c20d30f626769.addTo(map_57bc44e4da23b4af09444e68e9cb0740);
#
#
#             var feature_group_sub_group_b9afa3b71faeb5077b157e2019683dff = L.featureGroup.subGroup(
#                 feature_group_4c8ad100b35e9a01589c20d30f626769
#             );
#
#
#             var marker_ae525df33287329a08c0ee46f3f055df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b9afa3b71faeb5077b157e2019683dff);
#
#
#         var popup_86150ce84a397ceb68d35afdb2d2341d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6161a085f1b3c10d10ee8d7788bfb8f6 = $(`&lt;div id=&quot;html_6161a085f1b3c10d10ee8d7788bfb8f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_86150ce84a397ceb68d35afdb2d2341d.setContent(html_6161a085f1b3c10d10ee8d7788bfb8f6);
#
#
#
#         marker_ae525df33287329a08c0ee46f3f055df.bindPopup(popup_86150ce84a397ceb68d35afdb2d2341d)
#         ;
#
#
#
#
#             var marker_b10d58adadd214a193c2dfd07539b721 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b9afa3b71faeb5077b157e2019683dff);
#
#
#         var popup_f002a523972a84ecaea447c391e6f0f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb5bacfb099a42a4a79587cf82828f0e = $(`&lt;div id=&quot;html_eb5bacfb099a42a4a79587cf82828f0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f002a523972a84ecaea447c391e6f0f8.setContent(html_eb5bacfb099a42a4a79587cf82828f0e);
#
#
#
#         marker_b10d58adadd214a193c2dfd07539b721.bindPopup(popup_f002a523972a84ecaea447c391e6f0f8)
#         ;
#
#
#
#
#             var marker_e5251e5c64b300f570f07a60c4b9a54c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b9afa3b71faeb5077b157e2019683dff);
#
#
#         var popup_36376a5439f33a6d9fb1d28017a72f7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12092fd4bdf403aaaf37a28b9572475a = $(`&lt;div id=&quot;html_12092fd4bdf403aaaf37a28b9572475a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_36376a5439f33a6d9fb1d28017a72f7c.setContent(html_12092fd4bdf403aaaf37a28b9572475a);
#
#
#
#         marker_e5251e5c64b300f570f07a60c4b9a54c.bindPopup(popup_36376a5439f33a6d9fb1d28017a72f7c)
#         ;
#
#
#
#
#             var marker_c8f4c31e344e04327c28be5cfe1c69a0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b9afa3b71faeb5077b157e2019683dff);
#
#
#         var popup_6053c8a4aebdb76bab23b07dcf8c6a87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93d966f0dc7a8e9efdf8c53c96dac35 = $(`&lt;div id=&quot;html_f93d966f0dc7a8e9efdf8c53c96dac35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6053c8a4aebdb76bab23b07dcf8c6a87.setContent(html_f93d966f0dc7a8e9efdf8c53c96dac35);
#
#
#
#         marker_
