# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_498e34eadb4d7f8d2b975563a075ff29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_498e34eadb4d7f8d2b975563a075ff29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_498e34eadb4d7f8d2b975563a075ff29 = L.map(
#                 &quot;map_498e34eadb4d7f8d2b975563a075ff29&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8fd9a8288a8adcfcb394ccbc679c539 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8fd9a8288a8adcfcb394ccbc679c539.addTo(map_498e34eadb4d7f8d2b975563a075ff29);
#
#
#             var marker_5729d4f58c0815363aba743218d817bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_498e34eadb4d7f8d2b975563a075ff29);
#
#
#         var popup_60f6b92af51edcadf569dbacc7541356 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68a2f871ba9f5cdfc1325021eeab92d9 = $(`&lt;div id=&quot;html_68a2f871ba9f5cdfc1325021eeab92d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_60f6b92af51edcadf569dbacc7541356.setContent(html_68a2f871ba9f5cdfc1325021eeab92d9);
#
#
#
#         marker_5729d4f58c0815363aba743218d817bb.bindPopup(popup_60f6b92af51edcadf569dbacc7541356)
#         ;
#
#
#
#
#             var marker_8f17b2055ead4edb0bb9d2d2472e2e16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_498e34eadb4d7f8d2b975563a075ff29);
#
#
#         var popup_de4056435b0aa00c17fd7f7ce1c19273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_845b1becd000e5b00408455d52276041 = $(`&lt;div id=&quot;html_845b1becd000e5b00408455d52276041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_de4056435b0aa00c17fd7f7ce1c19273.setContent(html_845b1becd000e5b00408455d52276041);
#
#
#
#         marker_8f17b2055ead4edb0bb9d2d2472e2e16.bindPopup(popup_de4056435b0aa00c17fd7f7ce1c19273)
#         ;
#
#
#
#
#             var marker_d6a7da8a005b9dc5b1477c5aec7e07b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_498e34eadb4d7f8d2b975563a075ff29);
#
#
#         var popup_f1af071ffcc1cbcf29196add3db39063 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b22b3d08ff4d485ef91ecc22252b2c4 = $(`&lt;div id=&quot;html_8b22b3d08ff4d485ef91ecc22252b2c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f1af071ffcc1cbcf29196add3db39063.setContent(html_8b22b3d08ff4d485ef91ecc22252b2c4);
#
#
#
#         marker_d6a7da8a005b9dc5b1477c5aec7e07b7.bindPopup(popup_f1af071ffcc1cbcf29196add3db39063)
#         ;
#
#
#
#
#             var marker_1e878aa75e6e31d49433ff3d9608c28b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_498e34eadb4d7f8d2b975563a075ff29);
#
#
#         var popup_d6873092094259e1c2f59571f99d3612 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1ba07038f86b9a1ecedfc0633c8a755 = $(`&lt;div id=&quot;html_d1ba07038f86b9a1ecedfc0633c8a755&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d6873092094259e1c2f59571f99d3612.setContent(html_d1ba07038f86b9a1ecedfc0633c8a755);
#
#
#
#         marker_1e878aa75e6e31d49433ff3d9608c28b.bindPopup(popup_d6873092094259e1c2f59571f99d3612)
#         ;
#
#
#
#
#             var marker_6ebd006061a23de2160b99141bf2be58 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_498e34eadb4d7f8d2b975563a075ff29);
#
#
#         var popup_1cc2735b3da15dc08c029e4cf68cf70e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb9ea6309e138471e24d76dfc2d7782e = $(`&lt;div id=&quot;html_cb9ea6309e138471e24d76dfc2d7782e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1cc2735b3da15dc08c029e4cf68cf70e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4f10881b768f9fda000ca22dfd9c401 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4f10881b768f9fda000ca22dfd9c401&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4f10881b768f9fda000ca22dfd9c401 = L.map(
#                 &quot;map_a4f10881b768f9fda000ca22dfd9c401&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb79c1c5e1b70d010f5eab727f277cde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb79c1c5e1b70d010f5eab727f277cde.addTo(map_a4f10881b768f9fda000ca22dfd9c401);
#
#
#             var feature_group_672312f3c2706aab955aabea2aeb0745 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_364aa0c75be0b45ea4c016a606bfedf8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_672312f3c2706aab955aabea2aeb0745);
#
#
#         var popup_4b9024dce5d066af6ac513e527a11394 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c20a83df40f71df92534228513972fb = $(`&lt;div id=&quot;html_1c20a83df40f71df92534228513972fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4b9024dce5d066af6ac513e527a11394.setContent(html_1c20a83df40f71df92534228513972fb);
#
#
#
#         marker_364aa0c75be0b45ea4c016a606bfedf8.bindPopup(popup_4b9024dce5d066af6ac513e527a11394)
#         ;
#
#
#
#
#             var marker_ca89fc53ff882250913d9230723f0305 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_672312f3c2706aab955aabea2aeb0745);
#
#
#         var popup_cb51554ae3fc4e579faeaba61bedca9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_294cbc37f79579643ea9461160eac25b = $(`&lt;div id=&quot;html_294cbc37f79579643ea9461160eac25b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cb51554ae3fc4e579faeaba61bedca9d.setContent(html_294cbc37f79579643ea9461160eac25b);
#
#
#
#         marker_ca89fc53ff882250913d9230723f0305.bindPopup(popup_cb51554ae3fc4e579faeaba61bedca9d)
#         ;
#
#
#
#
#             var marker_1e06addf095051d2898088a5baa71a5c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_672312f3c2706aab955aabea2aeb0745);
#
#
#         var popup_63ec3c6987ceabf207f74428095f488f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18d178b074d465c77576b039edd88e32 = $(`&lt;div id=&quot;html_18d178b074d465c77576b039edd88e32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_63ec3c6987ceabf207f74428095f488f.setContent(html_18d178b074d465c77576b039edd88e32);
#
#
#
#         marker_1e06addf095051d2898088a5baa71a5c.bindPopup(popup_63ec3c6987ceabf207f74428095f488f)
#         ;
#
#
#
#
#             var marker_52d7817c33eeed6147bce3ade9f14595 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_672312f3c2706aab955aabea2aeb0745);
#
#
#         var popup_1d00b39328f7a1e832a427fe2cc3e02f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eccfda37040c0b414a60ebfe40bd3cac = $(`&lt;div id=&quot;html_eccfda37040c0b414a60ebfe40bd3cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1d00b39328f7a1e832a427fe2cc3e02f.setContent(html_eccfda37040c0b414a60ebfe40bd3cac);
#
#
#
#         marker_52d7817c33eeed6147bce3ade9f14595.bindPopup(popup_1d00b39328f7a1e832a427fe2cc3e02f)
#         ;
#
#
#
#
#             var marker_ccc3f56d983de5116f5cd4a25ec8391e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_672312f3c2706aab955aabea2aeb0745);
#
#
#         var popup_bc95f856efe52c1d0fcb4bd828158157 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef29f2bafa8cde027877609570887792 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef29f2bafa8cde027877609570887792&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef29f2bafa8cde027877609570887792 = L.map(
#                 &quot;map_ef29f2bafa8cde027877609570887792&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf4c72aac3448f84ad66eda5af90547e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf4c72aac3448f84ad66eda5af90547e.addTo(map_ef29f2bafa8cde027877609570887792);
#
#
#             var feature_group_57688e442f1bd563f66b164fd39329cc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_57688e442f1bd563f66b164fd39329cc.addTo(map_ef29f2bafa8cde027877609570887792);
#
#
#             var feature_group_sub_group_5023732ff21ee922da917d7c88566cb7 = L.featureGroup.subGroup(
#                 feature_group_57688e442f1bd563f66b164fd39329cc
#             );
#
#
#             var marker_430c539a9f83fd704082ede5c0aacbf2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5023732ff21ee922da917d7c88566cb7);
#
#
#         var popup_3f812dec179a78e2e72ed5feced01207 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_381ca888de148e1e401dc125c61ed541 = $(`&lt;div id=&quot;html_381ca888de148e1e401dc125c61ed541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3f812dec179a78e2e72ed5feced01207.setContent(html_381ca888de148e1e401dc125c61ed541);
#
#
#
#         marker_430c539a9f83fd704082ede5c0aacbf2.bindPopup(popup_3f812dec179a78e2e72ed5feced01207)
#         ;
#
#
#
#
#             var marker_e942a7391fc3e32003b5254f4171965e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5023732ff21ee922da917d7c88566cb7);
#
#
#         var popup_d3739b29c17144aec1242dc9cebe00df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07c63afa539b4957bc1e86f45d18414c = $(`&lt;div id=&quot;html_07c63afa539b4957bc1e86f45d18414c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d3739b29c17144aec1242dc9cebe00df.setContent(html_07c63afa539b4957bc1e86f45d18414c);
#
#
#
#         marker_e942a7391fc3e32003b5254f4171965e.bindPopup(popup_d3739b29c17144aec1242dc9cebe00df)
#         ;
#
#
#
#
#             var marker_5825cdd0fa61e3967bd6e231c9742bcc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5023732ff21ee922da917d7c88566cb7);
#
#
#         var popup_f031e2c9b2e83f698e6dc314c383496f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4124030f3e0a73b342a42e49430af00a = $(`&lt;div id=&quot;html_4124030f3e0a73b342a42e49430af00a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f031e2c9b2e83f698e6dc314c383496f.setContent(html_4124030f3e0a73b342a42e49430af00a);
#
#
#
#         marker_5825cdd0fa61e3967bd6e231c9742bcc.bindPopup(popup_f031e2c9b2e83f698e6dc314c383496f)
#         ;
#
#
#
#
#             var marker_a1548155d45e7749045f9b0a1e3c8c52 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5023732ff21ee922da917d7c88566cb7);
#
#
#         var popup_79f3442e5f61f2cb6b7dddf5d9ee7039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbb3ebcba0c20e39d2be21cba9ea3f01 = $(`&lt;div id=&quot;html_fbb3ebcba0c20e39d2be21cba9ea3f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_79f3442e5f61f2cb6b7dddf5d9ee7039.setContent(html_fbb3ebcba0c20e39d2be21cba9ea3f01);
#
#
#
#         marker_
