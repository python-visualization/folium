# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02209621430c109ac7a234c336649000 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02209621430c109ac7a234c336649000&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02209621430c109ac7a234c336649000 = L.map(
#                 &quot;map_02209621430c109ac7a234c336649000&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb5e99710a9fa9dffbeb9c9519e06389 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb5e99710a9fa9dffbeb9c9519e06389.addTo(map_02209621430c109ac7a234c336649000);
#
#
#             var marker_fd6548a6c6f75d6047414ec2ab3620e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_02209621430c109ac7a234c336649000);
#
#
#         var popup_36758372ca6b0132b4b3a38b0999c620 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_084de90980252b279a3bf469bc0f2f72 = $(`&lt;div id=&quot;html_084de90980252b279a3bf469bc0f2f72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_36758372ca6b0132b4b3a38b0999c620.setContent(html_084de90980252b279a3bf469bc0f2f72);
#
#
#
#         marker_fd6548a6c6f75d6047414ec2ab3620e4.bindPopup(popup_36758372ca6b0132b4b3a38b0999c620)
#         ;
#
#
#
#
#             var marker_d7b6ded8789991c90c20a3d414885513 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_02209621430c109ac7a234c336649000);
#
#
#         var popup_0b7f0d3ee86c756a21fe4e6c12dbc552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23480400e7062c938c07dd547446db3b = $(`&lt;div id=&quot;html_23480400e7062c938c07dd547446db3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b7f0d3ee86c756a21fe4e6c12dbc552.setContent(html_23480400e7062c938c07dd547446db3b);
#
#
#
#         marker_d7b6ded8789991c90c20a3d414885513.bindPopup(popup_0b7f0d3ee86c756a21fe4e6c12dbc552)
#         ;
#
#
#
#
#             var marker_35489a4677b6693609381b2a8346f771 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_02209621430c109ac7a234c336649000);
#
#
#         var popup_9685b94c123d68f6d5deb16224016366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f12012e4c5f99ae63998c2722dd3d66f = $(`&lt;div id=&quot;html_f12012e4c5f99ae63998c2722dd3d66f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9685b94c123d68f6d5deb16224016366.setContent(html_f12012e4c5f99ae63998c2722dd3d66f);
#
#
#
#         marker_35489a4677b6693609381b2a8346f771.bindPopup(popup_9685b94c123d68f6d5deb16224016366)
#         ;
#
#
#
#
#             var marker_ddb6ed01b997655c42971640a54bc11c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_02209621430c109ac7a234c336649000);
#
#
#         var popup_fb6d99b7a98886c74afd9c5da74ebdd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47e6d9ab087cadb4e9a2decaccbd03bd = $(`&lt;div id=&quot;html_47e6d9ab087cadb4e9a2decaccbd03bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fb6d99b7a98886c74afd9c5da74ebdd1.setContent(html_47e6d9ab087cadb4e9a2decaccbd03bd);
#
#
#
#         marker_ddb6ed01b997655c42971640a54bc11c.bindPopup(popup_fb6d99b7a98886c74afd9c5da74ebdd1)
#         ;
#
#
#
#
#             var marker_8aeb038e22df5e2d5f82677c53dad2d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_02209621430c109ac7a234c336649000);
#
#
#         var popup_76eea51bb5ea884aa9a13b5a9626f5d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d543fa06a2b68d52936dd1885ae87f68 = $(`&lt;div id=&quot;html_d543fa06a2b68d52936dd1885ae87f68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_76eea51bb5ea884aa9a13b5a9626f5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f49b0223cf19a0129f294408d31317b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f49b0223cf19a0129f294408d31317b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f49b0223cf19a0129f294408d31317b = L.map(
#                 &quot;map_4f49b0223cf19a0129f294408d31317b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce35c96bc42bd7861540271749bd29b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce35c96bc42bd7861540271749bd29b2.addTo(map_4f49b0223cf19a0129f294408d31317b);
#
#
#             var feature_group_afbd4b3f8b87dac93d48a88f71d35b29 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1ce84ee69619825f545b05216e60b79e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_afbd4b3f8b87dac93d48a88f71d35b29);
#
#
#         var popup_845d08a82d9d9f36036427fc7a96dea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_397e62a5bfdd9d952fa82f4baa9f4bbf = $(`&lt;div id=&quot;html_397e62a5bfdd9d952fa82f4baa9f4bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_845d08a82d9d9f36036427fc7a96dea3.setContent(html_397e62a5bfdd9d952fa82f4baa9f4bbf);
#
#
#
#         marker_1ce84ee69619825f545b05216e60b79e.bindPopup(popup_845d08a82d9d9f36036427fc7a96dea3)
#         ;
#
#
#
#
#             var marker_6357977ac1e537a69af1199be4ededa3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_afbd4b3f8b87dac93d48a88f71d35b29);
#
#
#         var popup_f324ca4a90d1b9075e02458f0d007794 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551932f8c1f28078ea4d5f720ac68468 = $(`&lt;div id=&quot;html_551932f8c1f28078ea4d5f720ac68468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f324ca4a90d1b9075e02458f0d007794.setContent(html_551932f8c1f28078ea4d5f720ac68468);
#
#
#
#         marker_6357977ac1e537a69af1199be4ededa3.bindPopup(popup_f324ca4a90d1b9075e02458f0d007794)
#         ;
#
#
#
#
#             var marker_46a2e48f7ca2838b7bbfa7e3e98994fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_afbd4b3f8b87dac93d48a88f71d35b29);
#
#
#         var popup_639698f5f2dd70ca1af3f4a645b5ac34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1baf8ce337cbef83d94d310d527a6504 = $(`&lt;div id=&quot;html_1baf8ce337cbef83d94d310d527a6504&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_639698f5f2dd70ca1af3f4a645b5ac34.setContent(html_1baf8ce337cbef83d94d310d527a6504);
#
#
#
#         marker_46a2e48f7ca2838b7bbfa7e3e98994fb.bindPopup(popup_639698f5f2dd70ca1af3f4a645b5ac34)
#         ;
#
#
#
#
#             var marker_b031bca46db1774a43ae10e64ff065ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_afbd4b3f8b87dac93d48a88f71d35b29);
#
#
#         var popup_60f85771f2ecc5db1348d920c7ee204f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c74da2f55bb65624dfd917976e6e77bc = $(`&lt;div id=&quot;html_c74da2f55bb65624dfd917976e6e77bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_60f85771f2ecc5db1348d920c7ee204f.setContent(html_c74da2f55bb65624dfd917976e6e77bc);
#
#
#
#         marker_b031bca46db1774a43ae10e64ff065ac.bindPopup(popup_60f85771f2ecc5db1348d920c7ee204f)
#         ;
#
#
#
#
#             var marker_cf8c988792bbf3ab3af63405a6ee9add = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_afbd4b3f8b87dac93d48a88f71d35b29);
#
#
#         var popup_541e1a24f37bbecfbe11fc694e3a5b97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7806288eae2f31d531a2e7d1e1dfaf0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7806288eae2f31d531a2e7d1e1dfaf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7806288eae2f31d531a2e7d1e1dfaf0 = L.map(
#                 &quot;map_f7806288eae2f31d531a2e7d1e1dfaf0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abc6861f90c8b89ef5e79351a4cc08ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abc6861f90c8b89ef5e79351a4cc08ce.addTo(map_f7806288eae2f31d531a2e7d1e1dfaf0);
#
#
#             var feature_group_db1d48d54dc0f69d300d8b5a0bbbb434 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_db1d48d54dc0f69d300d8b5a0bbbb434.addTo(map_f7806288eae2f31d531a2e7d1e1dfaf0);
#
#
#             var feature_group_sub_group_19013ec3f93b5414cdea7229f81a48fa = L.featureGroup.subGroup(
#                 feature_group_db1d48d54dc0f69d300d8b5a0bbbb434
#             );
#
#
#             var marker_fb64384bc0d206b42f10bbc36b2c7aa9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_19013ec3f93b5414cdea7229f81a48fa);
#
#
#         var popup_e7296beb01c98b65b8da6f920d587257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cab32ee87b0039132852959be135231 = $(`&lt;div id=&quot;html_7cab32ee87b0039132852959be135231&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e7296beb01c98b65b8da6f920d587257.setContent(html_7cab32ee87b0039132852959be135231);
#
#
#
#         marker_fb64384bc0d206b42f10bbc36b2c7aa9.bindPopup(popup_e7296beb01c98b65b8da6f920d587257)
#         ;
#
#
#
#
#             var marker_58337617dc487190ad712d2919385b0d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_19013ec3f93b5414cdea7229f81a48fa);
#
#
#         var popup_d9f3ab5842e0abb351f9ac3cbc504eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4765421f62cb82be40dd890f64b1f96b = $(`&lt;div id=&quot;html_4765421f62cb82be40dd890f64b1f96b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d9f3ab5842e0abb351f9ac3cbc504eb9.setContent(html_4765421f62cb82be40dd890f64b1f96b);
#
#
#
#         marker_58337617dc487190ad712d2919385b0d.bindPopup(popup_d9f3ab5842e0abb351f9ac3cbc504eb9)
#         ;
#
#
#
#
#             var marker_0af32d36435670061db45d6408a64e7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_19013ec3f93b5414cdea7229f81a48fa);
#
#
#         var popup_daf990c416b5e9a9cc65bafc9d6f2e43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4d0bb6e4f23fd7ee2d8f5ad19d206e5 = $(`&lt;div id=&quot;html_a4d0bb6e4f23fd7ee2d8f5ad19d206e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_daf990c416b5e9a9cc65bafc9d6f2e43.setContent(html_a4d0bb6e4f23fd7ee2d8f5ad19d206e5);
#
#
#
#         marker_0af32d36435670061db45d6408a64e7e.bindPopup(popup_daf990c416b5e9a9cc65bafc9d6f2e43)
#         ;
#
#
#
#
#             var marker_af1110b057101dc796e041b64896e203 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_19013ec3f93b5414cdea7229f81a48fa);
#
#
#         var popup_d9c9dfd2bcdd04046bad48500e8c090f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdc5a3a1593ddecc99932199a18d56db = $(`&lt;div id=&quot;html_cdc5a3a1593ddecc99932199a18d56db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d9c9dfd2bcdd04046bad48500e8c090f.setContent(html_cdc5a3a1593ddecc99932199a18d56db);
#
#
#
#         mark
