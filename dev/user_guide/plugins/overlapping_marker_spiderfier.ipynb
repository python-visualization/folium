# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cea8c25fd45f8b2f7d29de311b52334b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cea8c25fd45f8b2f7d29de311b52334b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cea8c25fd45f8b2f7d29de311b52334b = L.map(
#                 &quot;map_cea8c25fd45f8b2f7d29de311b52334b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb5820ba518fec47d5ded7d51436a143 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb5820ba518fec47d5ded7d51436a143.addTo(map_cea8c25fd45f8b2f7d29de311b52334b);
#
#
#             var marker_a42e521466ad6b142771dcc57b9a3fe5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cea8c25fd45f8b2f7d29de311b52334b);
#
#
#         var popup_d349db4884388779bae8dde26d627ca4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7b37fcfb7f0a83795d9c87491ed3210 = $(`&lt;div id=&quot;html_c7b37fcfb7f0a83795d9c87491ed3210&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d349db4884388779bae8dde26d627ca4.setContent(html_c7b37fcfb7f0a83795d9c87491ed3210);
#
#
#
#         marker_a42e521466ad6b142771dcc57b9a3fe5.bindPopup(popup_d349db4884388779bae8dde26d627ca4)
#         ;
#
#
#
#
#             var marker_086eaf553eb7cc7b84ddcd4b4c050529 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cea8c25fd45f8b2f7d29de311b52334b);
#
#
#         var popup_24c22f29a71557e155a0018ad46443e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a2134fe9bbeef76d6ddfbcb7aec76bc = $(`&lt;div id=&quot;html_3a2134fe9bbeef76d6ddfbcb7aec76bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_24c22f29a71557e155a0018ad46443e7.setContent(html_3a2134fe9bbeef76d6ddfbcb7aec76bc);
#
#
#
#         marker_086eaf553eb7cc7b84ddcd4b4c050529.bindPopup(popup_24c22f29a71557e155a0018ad46443e7)
#         ;
#
#
#
#
#             var marker_33d79dd60bcaa47de7904dccf43e768a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cea8c25fd45f8b2f7d29de311b52334b);
#
#
#         var popup_0459f2f1ebad486104df85666dd79b5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ea425ace4edbe45944b3250a86f2b90 = $(`&lt;div id=&quot;html_4ea425ace4edbe45944b3250a86f2b90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0459f2f1ebad486104df85666dd79b5f.setContent(html_4ea425ace4edbe45944b3250a86f2b90);
#
#
#
#         marker_33d79dd60bcaa47de7904dccf43e768a.bindPopup(popup_0459f2f1ebad486104df85666dd79b5f)
#         ;
#
#
#
#
#             var marker_90e25d828f6f794bceec3d6e18a9c3f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cea8c25fd45f8b2f7d29de311b52334b);
#
#
#         var popup_e9b964590f26b1c48fb918278d758686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f617c4dc3288fb35f466183b115b9ff = $(`&lt;div id=&quot;html_2f617c4dc3288fb35f466183b115b9ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e9b964590f26b1c48fb918278d758686.setContent(html_2f617c4dc3288fb35f466183b115b9ff);
#
#
#
#         marker_90e25d828f6f794bceec3d6e18a9c3f9.bindPopup(popup_e9b964590f26b1c48fb918278d758686)
#         ;
#
#
#
#
#             var marker_a02e745b17a0f3df63d4f273707076f6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cea8c25fd45f8b2f7d29de311b52334b);
#
#
#         var popup_d0274b62cee85f4beefc6ea8ae88d259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34a9957cd3fdc1e9e6e2eb2d30067d7c = $(`&lt;div id=&quot;html_34a9957cd3fdc1e9e6e2eb2d30067d7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d0274b62cee85f4beefc6ea8ae88d2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f4120ac24a54596b79c13f59871482c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f4120ac24a54596b79c13f59871482c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f4120ac24a54596b79c13f59871482c = L.map(
#                 &quot;map_5f4120ac24a54596b79c13f59871482c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8190aea349d3c66de0cefa38b6cc6ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8190aea349d3c66de0cefa38b6cc6ed.addTo(map_5f4120ac24a54596b79c13f59871482c);
#
#
#             var feature_group_bdb8f31955dc20e15f65e45afcdc0309 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dd0a801cba3352bf783dd7b120823e34 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bdb8f31955dc20e15f65e45afcdc0309);
#
#
#         var popup_0b7517df451e3bd7b42d8944284bf7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5949e78b4093a5be0e2def182d16893e = $(`&lt;div id=&quot;html_5949e78b4093a5be0e2def182d16893e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0b7517df451e3bd7b42d8944284bf7fb.setContent(html_5949e78b4093a5be0e2def182d16893e);
#
#
#
#         marker_dd0a801cba3352bf783dd7b120823e34.bindPopup(popup_0b7517df451e3bd7b42d8944284bf7fb)
#         ;
#
#
#
#
#             var marker_890ad8aced65722e00de009653bc6624 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bdb8f31955dc20e15f65e45afcdc0309);
#
#
#         var popup_b90142031f6b389e50ef15bb7e2b15cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942f666c88e21385ea7ca2630110cc58 = $(`&lt;div id=&quot;html_942f666c88e21385ea7ca2630110cc58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b90142031f6b389e50ef15bb7e2b15cb.setContent(html_942f666c88e21385ea7ca2630110cc58);
#
#
#
#         marker_890ad8aced65722e00de009653bc6624.bindPopup(popup_b90142031f6b389e50ef15bb7e2b15cb)
#         ;
#
#
#
#
#             var marker_af659209c2f59f876b29e29e8f78509f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bdb8f31955dc20e15f65e45afcdc0309);
#
#
#         var popup_9f43f1666ec2199ac42c6d62a6491e28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0472992fd2631e90c4290c1b9ccc08af = $(`&lt;div id=&quot;html_0472992fd2631e90c4290c1b9ccc08af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9f43f1666ec2199ac42c6d62a6491e28.setContent(html_0472992fd2631e90c4290c1b9ccc08af);
#
#
#
#         marker_af659209c2f59f876b29e29e8f78509f.bindPopup(popup_9f43f1666ec2199ac42c6d62a6491e28)
#         ;
#
#
#
#
#             var marker_b9367c7d87ccb7cf89fd78afcdb7f8b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bdb8f31955dc20e15f65e45afcdc0309);
#
#
#         var popup_0f242f87498ef09b754f7377b7aad9f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece057d6f34f66c70248d57d0c5a10c3 = $(`&lt;div id=&quot;html_ece057d6f34f66c70248d57d0c5a10c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0f242f87498ef09b754f7377b7aad9f5.setContent(html_ece057d6f34f66c70248d57d0c5a10c3);
#
#
#
#         marker_b9367c7d87ccb7cf89fd78afcdb7f8b2.bindPopup(popup_0f242f87498ef09b754f7377b7aad9f5)
#         ;
#
#
#
#
#             var marker_6169d600238442f3afe3285dbc41ec1c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bdb8f31955dc20e15f65e45afcdc0309);
#
#
#         var popup_cd8b6967435ee38291e9e7cafad74684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce594aec162d3c398b7562ccfc4436af {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce594aec162d3c398b7562ccfc4436af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce594aec162d3c398b7562ccfc4436af = L.map(
#                 &quot;map_ce594aec162d3c398b7562ccfc4436af&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13e26e6ab7afdfdf825290d6ac94b53b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13e26e6ab7afdfdf825290d6ac94b53b.addTo(map_ce594aec162d3c398b7562ccfc4436af);
#
#
#             var feature_group_505e361985c99b1a5e65bfbb885fa8dd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_505e361985c99b1a5e65bfbb885fa8dd.addTo(map_ce594aec162d3c398b7562ccfc4436af);
#
#
#             var feature_group_sub_group_d5cae7466b521d0dab5f053b78df2ac6 = L.featureGroup.subGroup(
#                 feature_group_505e361985c99b1a5e65bfbb885fa8dd
#             );
#
#
#             var marker_b80a21778e14033a66ce958993f0c347 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5cae7466b521d0dab5f053b78df2ac6);
#
#
#         var popup_5596882437bc852f346d17e871686a2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b9a7e7617b18bc627c89888c4ff0170 = $(`&lt;div id=&quot;html_6b9a7e7617b18bc627c89888c4ff0170&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5596882437bc852f346d17e871686a2d.setContent(html_6b9a7e7617b18bc627c89888c4ff0170);
#
#
#
#         marker_b80a21778e14033a66ce958993f0c347.bindPopup(popup_5596882437bc852f346d17e871686a2d)
#         ;
#
#
#
#
#             var marker_cfa29ac52a470617e36fd7e8e32732f2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5cae7466b521d0dab5f053b78df2ac6);
#
#
#         var popup_93ea9c04afa7d948bf49c1664c5716dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77cb84d5f045c20fea72888d63f7976e = $(`&lt;div id=&quot;html_77cb84d5f045c20fea72888d63f7976e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_93ea9c04afa7d948bf49c1664c5716dd.setContent(html_77cb84d5f045c20fea72888d63f7976e);
#
#
#
#         marker_cfa29ac52a470617e36fd7e8e32732f2.bindPopup(popup_93ea9c04afa7d948bf49c1664c5716dd)
#         ;
#
#
#
#
#             var marker_9b65ce9de921c8a910a8f8abedd75f7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5cae7466b521d0dab5f053b78df2ac6);
#
#
#         var popup_e83967722c82151f954a04930e8f8602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_690b9f7a7788c7b541b3cd4b730ff8ed = $(`&lt;div id=&quot;html_690b9f7a7788c7b541b3cd4b730ff8ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e83967722c82151f954a04930e8f8602.setContent(html_690b9f7a7788c7b541b3cd4b730ff8ed);
#
#
#
#         marker_9b65ce9de921c8a910a8f8abedd75f7f.bindPopup(popup_e83967722c82151f954a04930e8f8602)
#         ;
#
#
#
#
#             var marker_043dc1a4f3eb9acf9002abde094a32b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5cae7466b521d0dab5f053b78df2ac6);
#
#
#         var popup_ecc6f8d80960a81896a62101964d370f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00c018bf6124ad2b4d5925c122786894 = $(`&lt;div id=&quot;html_00c018bf6124ad2b4d5925c122786894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ecc6f8d80960a81896a62101964d370f.setContent(html_00c018bf6124ad2b4d5925c122786894);
#
#
#
#         mark
