# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74a38fce520d3ab4c0911a580075a9a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74a38fce520d3ab4c0911a580075a9a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74a38fce520d3ab4c0911a580075a9a0 = L.map(
#                 &quot;map_74a38fce520d3ab4c0911a580075a9a0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f707af18c7da99402a839870ae43ffa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f707af18c7da99402a839870ae43ffa.addTo(map_74a38fce520d3ab4c0911a580075a9a0);
#
#
#             var marker_e7bfcc8df34c6ac3702ffc332907cb65 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_74a38fce520d3ab4c0911a580075a9a0);
#
#
#         var popup_15611768b884d3b59b52ae5fea776ef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_846b248eaa162a76f116f2ac6f0e8842 = $(`&lt;div id=&quot;html_846b248eaa162a76f116f2ac6f0e8842&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_15611768b884d3b59b52ae5fea776ef2.setContent(html_846b248eaa162a76f116f2ac6f0e8842);
#
#
#
#         marker_e7bfcc8df34c6ac3702ffc332907cb65.bindPopup(popup_15611768b884d3b59b52ae5fea776ef2)
#         ;
#
#
#
#
#             var marker_47fa18a49d1bb0f586ce1dcebfd3fa72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_74a38fce520d3ab4c0911a580075a9a0);
#
#
#         var popup_c35929c4854fe3d405b612b945b3afb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b1b54d238c9ccc0d87a2b29ffb19571 = $(`&lt;div id=&quot;html_7b1b54d238c9ccc0d87a2b29ffb19571&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c35929c4854fe3d405b612b945b3afb9.setContent(html_7b1b54d238c9ccc0d87a2b29ffb19571);
#
#
#
#         marker_47fa18a49d1bb0f586ce1dcebfd3fa72.bindPopup(popup_c35929c4854fe3d405b612b945b3afb9)
#         ;
#
#
#
#
#             var marker_9567e8d6c667eebb24975a27d7448111 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_74a38fce520d3ab4c0911a580075a9a0);
#
#
#         var popup_64a5816f079ab7228625477c16dc51bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b26ff5496adc9c422b6944fe1ac9dabc = $(`&lt;div id=&quot;html_b26ff5496adc9c422b6944fe1ac9dabc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_64a5816f079ab7228625477c16dc51bb.setContent(html_b26ff5496adc9c422b6944fe1ac9dabc);
#
#
#
#         marker_9567e8d6c667eebb24975a27d7448111.bindPopup(popup_64a5816f079ab7228625477c16dc51bb)
#         ;
#
#
#
#
#             var marker_31767d5dbb32237bff72aa056049f4b9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_74a38fce520d3ab4c0911a580075a9a0);
#
#
#         var popup_ad4d26c8d794707f53d6099d5d74d2b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31b58a35b2368691c97ce8751eb44962 = $(`&lt;div id=&quot;html_31b58a35b2368691c97ce8751eb44962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ad4d26c8d794707f53d6099d5d74d2b2.setContent(html_31b58a35b2368691c97ce8751eb44962);
#
#
#
#         marker_31767d5dbb32237bff72aa056049f4b9.bindPopup(popup_ad4d26c8d794707f53d6099d5d74d2b2)
#         ;
#
#
#
#
#             var marker_a4f23f94b3c7dc176eacce8285fa070d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_74a38fce520d3ab4c0911a580075a9a0);
#
#
#         var popup_a53c339affb999410db8bffcdf4c0198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8eb144db8f7e62b9174351481ec26d6b = $(`&lt;div id=&quot;html_8eb144db8f7e62b9174351481ec26d6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a53c339affb999410db8bffcdf4c0198.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e30663598843cb389046c4226d36725 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e30663598843cb389046c4226d36725&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e30663598843cb389046c4226d36725 = L.map(
#                 &quot;map_5e30663598843cb389046c4226d36725&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bf1b6e7becff5b9c560e272871322e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6bf1b6e7becff5b9c560e272871322e8.addTo(map_5e30663598843cb389046c4226d36725);
#
#
#             var feature_group_45951aa220da6cc8925f278cbfc3d015 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b33ffa35fb5795df98156b485d6e0b3e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_45951aa220da6cc8925f278cbfc3d015);
#
#
#         var popup_233519434bab0365fdd906c16dfbfc67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4f72dd807791dddafe3572ee1302b3f = $(`&lt;div id=&quot;html_b4f72dd807791dddafe3572ee1302b3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_233519434bab0365fdd906c16dfbfc67.setContent(html_b4f72dd807791dddafe3572ee1302b3f);
#
#
#
#         marker_b33ffa35fb5795df98156b485d6e0b3e.bindPopup(popup_233519434bab0365fdd906c16dfbfc67)
#         ;
#
#
#
#
#             var marker_9ff448a4cc473e956cfabebd60e346d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_45951aa220da6cc8925f278cbfc3d015);
#
#
#         var popup_bbff91fc7d5d8d7639a53205533b1270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee57feb5fb3e5ce692da6a601353d7f7 = $(`&lt;div id=&quot;html_ee57feb5fb3e5ce692da6a601353d7f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bbff91fc7d5d8d7639a53205533b1270.setContent(html_ee57feb5fb3e5ce692da6a601353d7f7);
#
#
#
#         marker_9ff448a4cc473e956cfabebd60e346d2.bindPopup(popup_bbff91fc7d5d8d7639a53205533b1270)
#         ;
#
#
#
#
#             var marker_8f50e28f2a8db6f8951e3585ba4f5f8f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_45951aa220da6cc8925f278cbfc3d015);
#
#
#         var popup_97b6a0437699278a23c9df4f12d7ccd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad43141b86c782f9a79ed11ef22b3d1f = $(`&lt;div id=&quot;html_ad43141b86c782f9a79ed11ef22b3d1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_97b6a0437699278a23c9df4f12d7ccd0.setContent(html_ad43141b86c782f9a79ed11ef22b3d1f);
#
#
#
#         marker_8f50e28f2a8db6f8951e3585ba4f5f8f.bindPopup(popup_97b6a0437699278a23c9df4f12d7ccd0)
#         ;
#
#
#
#
#             var marker_ba70805f702a3a0f41f61bf7785fdf1b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_45951aa220da6cc8925f278cbfc3d015);
#
#
#         var popup_a57e609b38f1da9fe01be335de2b64c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d93fd49f6be80345b429e82517c817b = $(`&lt;div id=&quot;html_1d93fd49f6be80345b429e82517c817b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a57e609b38f1da9fe01be335de2b64c8.setContent(html_1d93fd49f6be80345b429e82517c817b);
#
#
#
#         marker_ba70805f702a3a0f41f61bf7785fdf1b.bindPopup(popup_a57e609b38f1da9fe01be335de2b64c8)
#         ;
#
#
#
#
#             var marker_d8c811d8ce7ea122513864526df8ad10 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_45951aa220da6cc8925f278cbfc3d015);
#
#
#         var popup_2ec361be08195711b79d04ff8ff0accf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66a70636d1ff2f0cf85e37661b3275e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66a70636d1ff2f0cf85e37661b3275e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66a70636d1ff2f0cf85e37661b3275e4 = L.map(
#                 &quot;map_66a70636d1ff2f0cf85e37661b3275e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d25668e58cdc54039cd8c9a2bf51ce22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d25668e58cdc54039cd8c9a2bf51ce22.addTo(map_66a70636d1ff2f0cf85e37661b3275e4);
#
#
#             var feature_group_b35f51a450fe937b70ebf19fa1b97da0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b35f51a450fe937b70ebf19fa1b97da0.addTo(map_66a70636d1ff2f0cf85e37661b3275e4);
#
#
#             var feature_group_sub_group_6c479fdf83602f336a7b60f3443bb399 = L.featureGroup.subGroup(
#                 feature_group_b35f51a450fe937b70ebf19fa1b97da0
#             );
#
#
#             var marker_ef61415bd749991032669db57bd18357 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c479fdf83602f336a7b60f3443bb399);
#
#
#         var popup_435346e8d875c64a58087a94a63ca4eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28f5aa8d2c7ce2667437b48ce8a10d06 = $(`&lt;div id=&quot;html_28f5aa8d2c7ce2667437b48ce8a10d06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_435346e8d875c64a58087a94a63ca4eb.setContent(html_28f5aa8d2c7ce2667437b48ce8a10d06);
#
#
#
#         marker_ef61415bd749991032669db57bd18357.bindPopup(popup_435346e8d875c64a58087a94a63ca4eb)
#         ;
#
#
#
#
#             var marker_707e08bcdc922c874dee3d820c41864b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c479fdf83602f336a7b60f3443bb399);
#
#
#         var popup_67e6ea0b2cfd170ed279b1515528c57d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f44486d2cf44d381e985063bc91f6760 = $(`&lt;div id=&quot;html_f44486d2cf44d381e985063bc91f6760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_67e6ea0b2cfd170ed279b1515528c57d.setContent(html_f44486d2cf44d381e985063bc91f6760);
#
#
#
#         marker_707e08bcdc922c874dee3d820c41864b.bindPopup(popup_67e6ea0b2cfd170ed279b1515528c57d)
#         ;
#
#
#
#
#             var marker_28e6d1c54a03344e17530dfa0988e2cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c479fdf83602f336a7b60f3443bb399);
#
#
#         var popup_35431ddc82fd5feaea29c81692ef460f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3361a7ec39725bee94ad9d2217fa50cf = $(`&lt;div id=&quot;html_3361a7ec39725bee94ad9d2217fa50cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_35431ddc82fd5feaea29c81692ef460f.setContent(html_3361a7ec39725bee94ad9d2217fa50cf);
#
#
#
#         marker_28e6d1c54a03344e17530dfa0988e2cc.bindPopup(popup_35431ddc82fd5feaea29c81692ef460f)
#         ;
#
#
#
#
#             var marker_7cf507294f75873e1ef2634f90c2a753 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c479fdf83602f336a7b60f3443bb399);
#
#
#         var popup_5ab4d4223a59806720a88115a24f10b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b230a3657e18937e4a634c2f1e38bee = $(`&lt;div id=&quot;html_0b230a3657e18937e4a634c2f1e38bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5ab4d4223a59806720a88115a24f10b4.setContent(html_0b230a3657e18937e4a634c2f1e38bee);
#
#
#
#         marker_
