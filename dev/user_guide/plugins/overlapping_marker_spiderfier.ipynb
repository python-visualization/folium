# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1241b53119c0539889358be5640bf2c3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1241b53119c0539889358be5640bf2c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1241b53119c0539889358be5640bf2c3 = L.map(
#                 &quot;map_1241b53119c0539889358be5640bf2c3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48622b78dfc150c70eb195457e019f8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48622b78dfc150c70eb195457e019f8d.addTo(map_1241b53119c0539889358be5640bf2c3);
#
#
#             var marker_18ed19062d7bd887acc2f6ee3bcfcda9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1241b53119c0539889358be5640bf2c3);
#
#
#         var popup_4171c58270be73356818410424fca902 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db51d5077c69c5a92e9cf281c7a8d379 = $(`&lt;div id=&quot;html_db51d5077c69c5a92e9cf281c7a8d379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4171c58270be73356818410424fca902.setContent(html_db51d5077c69c5a92e9cf281c7a8d379);
#
#
#
#         marker_18ed19062d7bd887acc2f6ee3bcfcda9.bindPopup(popup_4171c58270be73356818410424fca902)
#         ;
#
#
#
#
#             var marker_e0fd76197754d6f8273a55e1c09732d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1241b53119c0539889358be5640bf2c3);
#
#
#         var popup_3d57666cfe192a6b361462e2be5c9f8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c45f7bebf3774d3c3fa2b8db714df58a = $(`&lt;div id=&quot;html_c45f7bebf3774d3c3fa2b8db714df58a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3d57666cfe192a6b361462e2be5c9f8e.setContent(html_c45f7bebf3774d3c3fa2b8db714df58a);
#
#
#
#         marker_e0fd76197754d6f8273a55e1c09732d4.bindPopup(popup_3d57666cfe192a6b361462e2be5c9f8e)
#         ;
#
#
#
#
#             var marker_f0af0ff6ec86c9c2eb74298ec68da206 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1241b53119c0539889358be5640bf2c3);
#
#
#         var popup_26380afa32de3a4688a9b3ccca917e3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61ee402058789d1851ae5349f03bf42e = $(`&lt;div id=&quot;html_61ee402058789d1851ae5349f03bf42e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_26380afa32de3a4688a9b3ccca917e3c.setContent(html_61ee402058789d1851ae5349f03bf42e);
#
#
#
#         marker_f0af0ff6ec86c9c2eb74298ec68da206.bindPopup(popup_26380afa32de3a4688a9b3ccca917e3c)
#         ;
#
#
#
#
#             var marker_2be0d08befbd7cef8edb565222d7703c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1241b53119c0539889358be5640bf2c3);
#
#
#         var popup_940e48d898c5e51eb9837aad806d2303 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_403c1e2f22e566ff4369e9b79dd3a48b = $(`&lt;div id=&quot;html_403c1e2f22e566ff4369e9b79dd3a48b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_940e48d898c5e51eb9837aad806d2303.setContent(html_403c1e2f22e566ff4369e9b79dd3a48b);
#
#
#
#         marker_2be0d08befbd7cef8edb565222d7703c.bindPopup(popup_940e48d898c5e51eb9837aad806d2303)
#         ;
#
#
#
#
#             var marker_43196cdd6ec8b5694036ba6191a64fa3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1241b53119c0539889358be5640bf2c3);
#
#
#         var popup_985b84c399594dba22e163552eb92a33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c034c6874b4eb0b218aba1c57426c4f = $(`&lt;div id=&quot;html_1c034c6874b4eb0b218aba1c57426c4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_985b84c399594dba22e163552eb92a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66aedc1b0f8af132b48e0d2407899ed2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66aedc1b0f8af132b48e0d2407899ed2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66aedc1b0f8af132b48e0d2407899ed2 = L.map(
#                 &quot;map_66aedc1b0f8af132b48e0d2407899ed2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5810bf10c865bd2915ca8957cd993c9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5810bf10c865bd2915ca8957cd993c9f.addTo(map_66aedc1b0f8af132b48e0d2407899ed2);
#
#
#             var feature_group_83a342ff7e9d7bcac13dc59a3f12aa0d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4459a326c1ca2985434cb7cf68db5b3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_83a342ff7e9d7bcac13dc59a3f12aa0d);
#
#
#         var popup_9acd57039a10634bbfff4397d76bdf8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e234f9d064776d97b6bda367278d4a4c = $(`&lt;div id=&quot;html_e234f9d064776d97b6bda367278d4a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9acd57039a10634bbfff4397d76bdf8a.setContent(html_e234f9d064776d97b6bda367278d4a4c);
#
#
#
#         marker_4459a326c1ca2985434cb7cf68db5b3b.bindPopup(popup_9acd57039a10634bbfff4397d76bdf8a)
#         ;
#
#
#
#
#             var marker_7f95879c1d4e53c01b407367885af309 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_83a342ff7e9d7bcac13dc59a3f12aa0d);
#
#
#         var popup_4ac22f5e8e02519cf575bb1d37116696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81bf9fa1924bc999163428d73ff9b4d6 = $(`&lt;div id=&quot;html_81bf9fa1924bc999163428d73ff9b4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4ac22f5e8e02519cf575bb1d37116696.setContent(html_81bf9fa1924bc999163428d73ff9b4d6);
#
#
#
#         marker_7f95879c1d4e53c01b407367885af309.bindPopup(popup_4ac22f5e8e02519cf575bb1d37116696)
#         ;
#
#
#
#
#             var marker_ac4d4ebcfe5daf2282353411cfd4d193 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_83a342ff7e9d7bcac13dc59a3f12aa0d);
#
#
#         var popup_5b39f83b56dcaeb28b9e2d1dddd9daf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97b1bf32b11432349673ced279bb8bb0 = $(`&lt;div id=&quot;html_97b1bf32b11432349673ced279bb8bb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5b39f83b56dcaeb28b9e2d1dddd9daf7.setContent(html_97b1bf32b11432349673ced279bb8bb0);
#
#
#
#         marker_ac4d4ebcfe5daf2282353411cfd4d193.bindPopup(popup_5b39f83b56dcaeb28b9e2d1dddd9daf7)
#         ;
#
#
#
#
#             var marker_5ba2e347275bd0cf0d141621c2da9b53 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_83a342ff7e9d7bcac13dc59a3f12aa0d);
#
#
#         var popup_161a201b67fefbc2d1d71d287d6b9d7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdb4af92f376bdb82486cbc7aaf260de = $(`&lt;div id=&quot;html_fdb4af92f376bdb82486cbc7aaf260de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_161a201b67fefbc2d1d71d287d6b9d7b.setContent(html_fdb4af92f376bdb82486cbc7aaf260de);
#
#
#
#         marker_5ba2e347275bd0cf0d141621c2da9b53.bindPopup(popup_161a201b67fefbc2d1d71d287d6b9d7b)
#         ;
#
#
#
#
#             var marker_1f8942eec38259322a96c536996187de = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_83a342ff7e9d7bcac13dc59a3f12aa0d);
#
#
#         var popup_1245241cfe35ba38de9cc81495308d4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_892c874a1993a5b161c2cf277f44cab4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_892c874a1993a5b161c2cf277f44cab4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_892c874a1993a5b161c2cf277f44cab4 = L.map(
#                 &quot;map_892c874a1993a5b161c2cf277f44cab4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75a283bcb6302aca9e7b665bd735a6f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75a283bcb6302aca9e7b665bd735a6f0.addTo(map_892c874a1993a5b161c2cf277f44cab4);
#
#
#             var feature_group_8c63deae3c2cc61febdedf262eea8233 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8c63deae3c2cc61febdedf262eea8233.addTo(map_892c874a1993a5b161c2cf277f44cab4);
#
#
#             var feature_group_sub_group_cf25c269bbe918d1dd8b481fecf76a26 = L.featureGroup.subGroup(
#                 feature_group_8c63deae3c2cc61febdedf262eea8233
#             );
#
#
#             var marker_0ea24244b7f67cf34f69baa41a5fe022 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf25c269bbe918d1dd8b481fecf76a26);
#
#
#         var popup_323234f6b85abc2640cd6576dbf9b974 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b749f6a7be139c8aad37db2ad708219a = $(`&lt;div id=&quot;html_b749f6a7be139c8aad37db2ad708219a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_323234f6b85abc2640cd6576dbf9b974.setContent(html_b749f6a7be139c8aad37db2ad708219a);
#
#
#
#         marker_0ea24244b7f67cf34f69baa41a5fe022.bindPopup(popup_323234f6b85abc2640cd6576dbf9b974)
#         ;
#
#
#
#
#             var marker_bb82a965acae09191e00ec12b2eee980 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf25c269bbe918d1dd8b481fecf76a26);
#
#
#         var popup_7a4997b0772f921c5fc8c97e91509be4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d420432d4960aac45cd603ee7991f16a = $(`&lt;div id=&quot;html_d420432d4960aac45cd603ee7991f16a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7a4997b0772f921c5fc8c97e91509be4.setContent(html_d420432d4960aac45cd603ee7991f16a);
#
#
#
#         marker_bb82a965acae09191e00ec12b2eee980.bindPopup(popup_7a4997b0772f921c5fc8c97e91509be4)
#         ;
#
#
#
#
#             var marker_92d615bf5c2e06dafe6efe9a64903d80 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf25c269bbe918d1dd8b481fecf76a26);
#
#
#         var popup_de9e5dea79ba351bbfb8faa0d365b975 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3448552eb34c6aab62a0ddcf63b29153 = $(`&lt;div id=&quot;html_3448552eb34c6aab62a0ddcf63b29153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_de9e5dea79ba351bbfb8faa0d365b975.setContent(html_3448552eb34c6aab62a0ddcf63b29153);
#
#
#
#         marker_92d615bf5c2e06dafe6efe9a64903d80.bindPopup(popup_de9e5dea79ba351bbfb8faa0d365b975)
#         ;
#
#
#
#
#             var marker_fa5b3d8a52fd81146e3ec787371a70d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf25c269bbe918d1dd8b481fecf76a26);
#
#
#         var popup_f6d6e682adeb9256449ae3e3ce436a68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ad10c0f31328660ef85086506c76f05 = $(`&lt;div id=&quot;html_4ad10c0f31328660ef85086506c76f05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f6d6e682adeb9256449ae3e3ce436a68.setContent(html_4ad10c0f31328660ef85086506c76f05);
#
#
#
#         mark
