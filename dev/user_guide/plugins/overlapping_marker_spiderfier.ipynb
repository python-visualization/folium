# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f9121499cc6a7149956444eba6bc33d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f9121499cc6a7149956444eba6bc33d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f9121499cc6a7149956444eba6bc33d = L.map(
#                 &quot;map_0f9121499cc6a7149956444eba6bc33d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf3fade53eb8ae6ce9acb5f83409a36b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf3fade53eb8ae6ce9acb5f83409a36b.addTo(map_0f9121499cc6a7149956444eba6bc33d);
#
#
#             var marker_aaa7158e00fa4f4ccfc5a72645ac3c00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0f9121499cc6a7149956444eba6bc33d);
#
#
#         var popup_10c6d1a5e800032189a9b505be288f04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de4c442148e554c57b5c05e16be82e86 = $(`&lt;div id=&quot;html_de4c442148e554c57b5c05e16be82e86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_10c6d1a5e800032189a9b505be288f04.setContent(html_de4c442148e554c57b5c05e16be82e86);
#
#
#
#         marker_aaa7158e00fa4f4ccfc5a72645ac3c00.bindPopup(popup_10c6d1a5e800032189a9b505be288f04)
#         ;
#
#
#
#
#             var marker_a0597b8f37721d66438b24b052a2e426 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0f9121499cc6a7149956444eba6bc33d);
#
#
#         var popup_7ecfbca110e9dc83a83e154fa0847a4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f15bb5ed5cc6b4275189893c7ce6296 = $(`&lt;div id=&quot;html_3f15bb5ed5cc6b4275189893c7ce6296&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7ecfbca110e9dc83a83e154fa0847a4e.setContent(html_3f15bb5ed5cc6b4275189893c7ce6296);
#
#
#
#         marker_a0597b8f37721d66438b24b052a2e426.bindPopup(popup_7ecfbca110e9dc83a83e154fa0847a4e)
#         ;
#
#
#
#
#             var marker_2c421671668642789869891c61109d93 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0f9121499cc6a7149956444eba6bc33d);
#
#
#         var popup_d9c39f5d9fa13d200ea888f1bd09dcf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8da7cdacf45e0c0c9fc17dce2726b263 = $(`&lt;div id=&quot;html_8da7cdacf45e0c0c9fc17dce2726b263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d9c39f5d9fa13d200ea888f1bd09dcf2.setContent(html_8da7cdacf45e0c0c9fc17dce2726b263);
#
#
#
#         marker_2c421671668642789869891c61109d93.bindPopup(popup_d9c39f5d9fa13d200ea888f1bd09dcf2)
#         ;
#
#
#
#
#             var marker_cebcfa0f26e3924c52b112b325473d89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0f9121499cc6a7149956444eba6bc33d);
#
#
#         var popup_18681748a2a93288da716338968c59ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_931b78c59788b8e7839c3b76ce585a82 = $(`&lt;div id=&quot;html_931b78c59788b8e7839c3b76ce585a82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18681748a2a93288da716338968c59ce.setContent(html_931b78c59788b8e7839c3b76ce585a82);
#
#
#
#         marker_cebcfa0f26e3924c52b112b325473d89.bindPopup(popup_18681748a2a93288da716338968c59ce)
#         ;
#
#
#
#
#             var marker_7e644d6083bb9ea2b7302c6c52aca4b9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0f9121499cc6a7149956444eba6bc33d);
#
#
#         var popup_d5a71b01ef8cfc367c786998053255a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_316375fdb4071ab9775acb9adf9eac75 = $(`&lt;div id=&quot;html_316375fdb4071ab9775acb9adf9eac75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d5a71b01ef8cfc367c786998053255a6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90f401f298a1e3835729a4b167386e9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90f401f298a1e3835729a4b167386e9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90f401f298a1e3835729a4b167386e9f = L.map(
#                 &quot;map_90f401f298a1e3835729a4b167386e9f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a365e4728f350b5ed1c8fe1835805f30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a365e4728f350b5ed1c8fe1835805f30.addTo(map_90f401f298a1e3835729a4b167386e9f);
#
#
#             var feature_group_0fdb83b1e5d177eecc65d47d0410388f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_547e4e9b346b8c1ca0d5fae0e9e781e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0fdb83b1e5d177eecc65d47d0410388f);
#
#
#         var popup_6051c8c3663c952c913d075d37240345 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4255f74d56bbf52143de42b8ca35cfb = $(`&lt;div id=&quot;html_f4255f74d56bbf52143de42b8ca35cfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6051c8c3663c952c913d075d37240345.setContent(html_f4255f74d56bbf52143de42b8ca35cfb);
#
#
#
#         marker_547e4e9b346b8c1ca0d5fae0e9e781e8.bindPopup(popup_6051c8c3663c952c913d075d37240345)
#         ;
#
#
#
#
#             var marker_1bdb7be18844d8693503c0c853fa63f0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0fdb83b1e5d177eecc65d47d0410388f);
#
#
#         var popup_95a5e281515d0dc2208390c3e45d8a88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd6bf1fa6cbe75735546946569c8c769 = $(`&lt;div id=&quot;html_fd6bf1fa6cbe75735546946569c8c769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_95a5e281515d0dc2208390c3e45d8a88.setContent(html_fd6bf1fa6cbe75735546946569c8c769);
#
#
#
#         marker_1bdb7be18844d8693503c0c853fa63f0.bindPopup(popup_95a5e281515d0dc2208390c3e45d8a88)
#         ;
#
#
#
#
#             var marker_dc9fde822885121f7009e307a95b104d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0fdb83b1e5d177eecc65d47d0410388f);
#
#
#         var popup_7418b2de75489f2862f3cb6169c78bff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f91d9fa0e15867250aec91b6fe50d86f = $(`&lt;div id=&quot;html_f91d9fa0e15867250aec91b6fe50d86f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7418b2de75489f2862f3cb6169c78bff.setContent(html_f91d9fa0e15867250aec91b6fe50d86f);
#
#
#
#         marker_dc9fde822885121f7009e307a95b104d.bindPopup(popup_7418b2de75489f2862f3cb6169c78bff)
#         ;
#
#
#
#
#             var marker_254a17eceb111e55ada504b7b2eb6014 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0fdb83b1e5d177eecc65d47d0410388f);
#
#
#         var popup_33076ca07a642400288aed8ec8cda6e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af0d5cf4e25833c9b76a85206b77c4bb = $(`&lt;div id=&quot;html_af0d5cf4e25833c9b76a85206b77c4bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_33076ca07a642400288aed8ec8cda6e9.setContent(html_af0d5cf4e25833c9b76a85206b77c4bb);
#
#
#
#         marker_254a17eceb111e55ada504b7b2eb6014.bindPopup(popup_33076ca07a642400288aed8ec8cda6e9)
#         ;
#
#
#
#
#             var marker_eed7240ed0be3fd1d356273d494d5759 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0fdb83b1e5d177eecc65d47d0410388f);
#
#
#         var popup_99a4526ba65ae112298d8d28bae89bb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dab8029ad4fe55f28732b3d506ed73d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dab8029ad4fe55f28732b3d506ed73d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dab8029ad4fe55f28732b3d506ed73d0 = L.map(
#                 &quot;map_dab8029ad4fe55f28732b3d506ed73d0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c487264944cb19f8ba7d180ca4d11f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c487264944cb19f8ba7d180ca4d11f4.addTo(map_dab8029ad4fe55f28732b3d506ed73d0);
#
#
#             var feature_group_43eb2c3d1192f66c6d791e278899179d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_43eb2c3d1192f66c6d791e278899179d.addTo(map_dab8029ad4fe55f28732b3d506ed73d0);
#
#
#             var feature_group_sub_group_5130a908461aa730d379b59636b3cdf1 = L.featureGroup.subGroup(
#                 feature_group_43eb2c3d1192f66c6d791e278899179d
#             );
#
#
#             var marker_c7b202c974468e32002db1deaea6d062 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5130a908461aa730d379b59636b3cdf1);
#
#
#         var popup_2d84ee9db1f1b26fa3c76a52ae5b2497 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3255ef46199285474b4468acd1ae1a1 = $(`&lt;div id=&quot;html_a3255ef46199285474b4468acd1ae1a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2d84ee9db1f1b26fa3c76a52ae5b2497.setContent(html_a3255ef46199285474b4468acd1ae1a1);
#
#
#
#         marker_c7b202c974468e32002db1deaea6d062.bindPopup(popup_2d84ee9db1f1b26fa3c76a52ae5b2497)
#         ;
#
#
#
#
#             var marker_6f284c81adf1cdad3eda7bd6ff53b8d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5130a908461aa730d379b59636b3cdf1);
#
#
#         var popup_75aae3bc0b7c3ccedb71df4031e8f723 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f13f0c7c42ab07f4300a03418f806f60 = $(`&lt;div id=&quot;html_f13f0c7c42ab07f4300a03418f806f60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_75aae3bc0b7c3ccedb71df4031e8f723.setContent(html_f13f0c7c42ab07f4300a03418f806f60);
#
#
#
#         marker_6f284c81adf1cdad3eda7bd6ff53b8d5.bindPopup(popup_75aae3bc0b7c3ccedb71df4031e8f723)
#         ;
#
#
#
#
#             var marker_f99b375f0b53d3d0bdbb907be31e6d71 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5130a908461aa730d379b59636b3cdf1);
#
#
#         var popup_70048cd2d7837eb89f7dd23575aa7ca4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5590afef7c49e3f1e86702ed3ca8b9d = $(`&lt;div id=&quot;html_e5590afef7c49e3f1e86702ed3ca8b9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_70048cd2d7837eb89f7dd23575aa7ca4.setContent(html_e5590afef7c49e3f1e86702ed3ca8b9d);
#
#
#
#         marker_f99b375f0b53d3d0bdbb907be31e6d71.bindPopup(popup_70048cd2d7837eb89f7dd23575aa7ca4)
#         ;
#
#
#
#
#             var marker_58804dde7af5b311e4ce327c5172bfd8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5130a908461aa730d379b59636b3cdf1);
#
#
#         var popup_258c3ee8e35f357bdea65e473fe4249c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76e0a68213cbdfbf535d4ec7a2b4391e = $(`&lt;div id=&quot;html_76e0a68213cbdfbf535d4ec7a2b4391e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_258c3ee8e35f357bdea65e473fe4249c.setContent(html_76e0a68213cbdfbf535d4ec7a2b4391e);
#
#
#
#         marker_
