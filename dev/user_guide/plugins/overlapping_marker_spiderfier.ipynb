# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6999a79878a2c7a8ff387949c1af3e26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6999a79878a2c7a8ff387949c1af3e26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6999a79878a2c7a8ff387949c1af3e26 = L.map(
#                 &quot;map_6999a79878a2c7a8ff387949c1af3e26&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34eaab7d11e3f1e0fe0d4ee0711d0d58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34eaab7d11e3f1e0fe0d4ee0711d0d58.addTo(map_6999a79878a2c7a8ff387949c1af3e26);
#
#
#             var marker_d90fdae714be2407dbf4a5a93ef46d9a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6999a79878a2c7a8ff387949c1af3e26);
#
#
#         var popup_2f7d0881f264c419ce8bc99bffffd8b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5e6e7c29a356f89b5789bcd0e2879ea = $(`&lt;div id=&quot;html_c5e6e7c29a356f89b5789bcd0e2879ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2f7d0881f264c419ce8bc99bffffd8b6.setContent(html_c5e6e7c29a356f89b5789bcd0e2879ea);
#
#
#
#         marker_d90fdae714be2407dbf4a5a93ef46d9a.bindPopup(popup_2f7d0881f264c419ce8bc99bffffd8b6)
#         ;
#
#
#
#
#             var marker_d94ebb4e69d86df4595980c339670692 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6999a79878a2c7a8ff387949c1af3e26);
#
#
#         var popup_64e439896dc501a54fcb8d46ba65881c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a58287d689f8c244482e63ae2296628 = $(`&lt;div id=&quot;html_9a58287d689f8c244482e63ae2296628&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_64e439896dc501a54fcb8d46ba65881c.setContent(html_9a58287d689f8c244482e63ae2296628);
#
#
#
#         marker_d94ebb4e69d86df4595980c339670692.bindPopup(popup_64e439896dc501a54fcb8d46ba65881c)
#         ;
#
#
#
#
#             var marker_9f2871d65bc6c74ef7f14667c9e271a5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6999a79878a2c7a8ff387949c1af3e26);
#
#
#         var popup_b171f1f354d57bd049d786817aa2234c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f99e1dab80a8f39edfd3bafb3b6d1dd5 = $(`&lt;div id=&quot;html_f99e1dab80a8f39edfd3bafb3b6d1dd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b171f1f354d57bd049d786817aa2234c.setContent(html_f99e1dab80a8f39edfd3bafb3b6d1dd5);
#
#
#
#         marker_9f2871d65bc6c74ef7f14667c9e271a5.bindPopup(popup_b171f1f354d57bd049d786817aa2234c)
#         ;
#
#
#
#
#             var marker_4932bebf064a89dfc34de430fa10f354 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6999a79878a2c7a8ff387949c1af3e26);
#
#
#         var popup_678eb9181886f9a40c8789436ef736e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_629353793009c36ca437fe49bc25a317 = $(`&lt;div id=&quot;html_629353793009c36ca437fe49bc25a317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_678eb9181886f9a40c8789436ef736e8.setContent(html_629353793009c36ca437fe49bc25a317);
#
#
#
#         marker_4932bebf064a89dfc34de430fa10f354.bindPopup(popup_678eb9181886f9a40c8789436ef736e8)
#         ;
#
#
#
#
#             var marker_0b7d459088ab92e7bfdcad26d503eca6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6999a79878a2c7a8ff387949c1af3e26);
#
#
#         var popup_3148a17ee9b45f9a5a0f97af2adc7562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_609da9a632cc78a47b5a4f2fa9307df0 = $(`&lt;div id=&quot;html_609da9a632cc78a47b5a4f2fa9307df0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3148a17ee9b45f9a5a0f97af2adc7562.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ad3e3ebc9a0f775602aa240bfaf7ef8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ad3e3ebc9a0f775602aa240bfaf7ef8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ad3e3ebc9a0f775602aa240bfaf7ef8 = L.map(
#                 &quot;map_8ad3e3ebc9a0f775602aa240bfaf7ef8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60735904cd84077108e6cebc11c8205f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60735904cd84077108e6cebc11c8205f.addTo(map_8ad3e3ebc9a0f775602aa240bfaf7ef8);
#
#
#             var feature_group_410235990be66ac357575ef726d6c55b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b8d862a0ccb0a5b6489678490ee72342 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_410235990be66ac357575ef726d6c55b);
#
#
#         var popup_309b9fe7c169a11eeb5fadb3d71d84a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12a3cfebf8895e29b1693cfefb7500e8 = $(`&lt;div id=&quot;html_12a3cfebf8895e29b1693cfefb7500e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_309b9fe7c169a11eeb5fadb3d71d84a3.setContent(html_12a3cfebf8895e29b1693cfefb7500e8);
#
#
#
#         marker_b8d862a0ccb0a5b6489678490ee72342.bindPopup(popup_309b9fe7c169a11eeb5fadb3d71d84a3)
#         ;
#
#
#
#
#             var marker_efe37bad5ca6f11be8ab27ba8acf4b32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_410235990be66ac357575ef726d6c55b);
#
#
#         var popup_9ade83a68bab0774a9c887b7f4e90956 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_413953ead76c6b799d4299eb38dcf62e = $(`&lt;div id=&quot;html_413953ead76c6b799d4299eb38dcf62e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9ade83a68bab0774a9c887b7f4e90956.setContent(html_413953ead76c6b799d4299eb38dcf62e);
#
#
#
#         marker_efe37bad5ca6f11be8ab27ba8acf4b32.bindPopup(popup_9ade83a68bab0774a9c887b7f4e90956)
#         ;
#
#
#
#
#             var marker_0e51ff4ed8ca9c99ae96e35aecfa9d99 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_410235990be66ac357575ef726d6c55b);
#
#
#         var popup_5b0a8c31020a660c9132e16b1c921f8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcd5b40c0ed3d283891d0ba309a57829 = $(`&lt;div id=&quot;html_dcd5b40c0ed3d283891d0ba309a57829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5b0a8c31020a660c9132e16b1c921f8a.setContent(html_dcd5b40c0ed3d283891d0ba309a57829);
#
#
#
#         marker_0e51ff4ed8ca9c99ae96e35aecfa9d99.bindPopup(popup_5b0a8c31020a660c9132e16b1c921f8a)
#         ;
#
#
#
#
#             var marker_ff83a9c42cdde95299dbb7caadaf93e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_410235990be66ac357575ef726d6c55b);
#
#
#         var popup_d4e992ec32e48ebef31ca5817290874e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3c003eaa544da99df5dee89f67711b5 = $(`&lt;div id=&quot;html_a3c003eaa544da99df5dee89f67711b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d4e992ec32e48ebef31ca5817290874e.setContent(html_a3c003eaa544da99df5dee89f67711b5);
#
#
#
#         marker_ff83a9c42cdde95299dbb7caadaf93e2.bindPopup(popup_d4e992ec32e48ebef31ca5817290874e)
#         ;
#
#
#
#
#             var marker_36c617d2f816d75a4d54080065b30bd4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_410235990be66ac357575ef726d6c55b);
#
#
#         var popup_c378ced5b583eceb7e9fd3ee75782b80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c45681df5727738d3401110afbed4bf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c45681df5727738d3401110afbed4bf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c45681df5727738d3401110afbed4bf8 = L.map(
#                 &quot;map_c45681df5727738d3401110afbed4bf8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_466f0ead0f9166509312c9a881fe17af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_466f0ead0f9166509312c9a881fe17af.addTo(map_c45681df5727738d3401110afbed4bf8);
#
#
#             var feature_group_56dfd2ecae05d65fff25e22749f5a8f4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_56dfd2ecae05d65fff25e22749f5a8f4.addTo(map_c45681df5727738d3401110afbed4bf8);
#
#
#             var feature_group_sub_group_9400d2dc82cddcc7ff3694b5b47a8557 = L.featureGroup.subGroup(
#                 feature_group_56dfd2ecae05d65fff25e22749f5a8f4
#             );
#
#
#             var marker_8974c0647a32eee12057be6ee60ffeb7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9400d2dc82cddcc7ff3694b5b47a8557);
#
#
#         var popup_7ac670647d590c9948d6d8514229c6ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b995342ca6fd0e70ef73dc9e59749a4d = $(`&lt;div id=&quot;html_b995342ca6fd0e70ef73dc9e59749a4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7ac670647d590c9948d6d8514229c6ca.setContent(html_b995342ca6fd0e70ef73dc9e59749a4d);
#
#
#
#         marker_8974c0647a32eee12057be6ee60ffeb7.bindPopup(popup_7ac670647d590c9948d6d8514229c6ca)
#         ;
#
#
#
#
#             var marker_718c358e298db12f50cea6c645669c57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9400d2dc82cddcc7ff3694b5b47a8557);
#
#
#         var popup_6b042c075d9236fea96ff605b61ab8cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c55ef03b6f3b3e0880a9462c100659ee = $(`&lt;div id=&quot;html_c55ef03b6f3b3e0880a9462c100659ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6b042c075d9236fea96ff605b61ab8cb.setContent(html_c55ef03b6f3b3e0880a9462c100659ee);
#
#
#
#         marker_718c358e298db12f50cea6c645669c57.bindPopup(popup_6b042c075d9236fea96ff605b61ab8cb)
#         ;
#
#
#
#
#             var marker_66cc2990422cb736944a9e6122d47d46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9400d2dc82cddcc7ff3694b5b47a8557);
#
#
#         var popup_dd136e5ff1836676c1ff23fe23b550b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59b90f02744bfffa3cec9014e9652c11 = $(`&lt;div id=&quot;html_59b90f02744bfffa3cec9014e9652c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dd136e5ff1836676c1ff23fe23b550b3.setContent(html_59b90f02744bfffa3cec9014e9652c11);
#
#
#
#         marker_66cc2990422cb736944a9e6122d47d46.bindPopup(popup_dd136e5ff1836676c1ff23fe23b550b3)
#         ;
#
#
#
#
#             var marker_59ac7542d5f1c4b849b8a5a7a9302894 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9400d2dc82cddcc7ff3694b5b47a8557);
#
#
#         var popup_98e786f85a694f6b8f1893ece310ab4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a9af88721c0e5cfe5048dd29a410ad7 = $(`&lt;div id=&quot;html_7a9af88721c0e5cfe5048dd29a410ad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_98e786f85a694f6b8f1893ece310ab4d.setContent(html_7a9af88721c0e5cfe5048dd29a410ad7);
#
#
#
#         marker_
