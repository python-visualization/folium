# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a059983f15254caefc92dabe6938fd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a059983f15254caefc92dabe6938fd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a059983f15254caefc92dabe6938fd1 = L.map(
#                 &quot;map_8a059983f15254caefc92dabe6938fd1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6149bb6c6b0dbf81847d5ffd26a98ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6149bb6c6b0dbf81847d5ffd26a98ef.addTo(map_8a059983f15254caefc92dabe6938fd1);
#
#
#             var marker_897f3553564595673244b548604ba0d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8a059983f15254caefc92dabe6938fd1);
#
#
#         var popup_95f3103b938e41ae8afb56e06191a23f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6c302372773c9ab23c2940168e00258 = $(`&lt;div id=&quot;html_a6c302372773c9ab23c2940168e00258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_95f3103b938e41ae8afb56e06191a23f.setContent(html_a6c302372773c9ab23c2940168e00258);
#
#
#
#         marker_897f3553564595673244b548604ba0d6.bindPopup(popup_95f3103b938e41ae8afb56e06191a23f)
#         ;
#
#
#
#
#             var marker_2c55a6c8a19b958f391b0f75c8f204b2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8a059983f15254caefc92dabe6938fd1);
#
#
#         var popup_7e2c0d1d1cc9cdbe9cd56d9811be87af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6edb6efd536232e0a3309946c8de414 = $(`&lt;div id=&quot;html_d6edb6efd536232e0a3309946c8de414&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7e2c0d1d1cc9cdbe9cd56d9811be87af.setContent(html_d6edb6efd536232e0a3309946c8de414);
#
#
#
#         marker_2c55a6c8a19b958f391b0f75c8f204b2.bindPopup(popup_7e2c0d1d1cc9cdbe9cd56d9811be87af)
#         ;
#
#
#
#
#             var marker_aa02ed662f677cb39b47934de10a5640 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8a059983f15254caefc92dabe6938fd1);
#
#
#         var popup_8ea2ea1bb5d41c066fb65d0aef45e3aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af8ca6131450bedf58d919fb81652c2b = $(`&lt;div id=&quot;html_af8ca6131450bedf58d919fb81652c2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ea2ea1bb5d41c066fb65d0aef45e3aa.setContent(html_af8ca6131450bedf58d919fb81652c2b);
#
#
#
#         marker_aa02ed662f677cb39b47934de10a5640.bindPopup(popup_8ea2ea1bb5d41c066fb65d0aef45e3aa)
#         ;
#
#
#
#
#             var marker_c42b688d9ef3b0c477489f5885b6de7d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8a059983f15254caefc92dabe6938fd1);
#
#
#         var popup_5641a3119f032e44f213bce71c6c35ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8179af31852fe6aa1f5e2a5171b51668 = $(`&lt;div id=&quot;html_8179af31852fe6aa1f5e2a5171b51668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5641a3119f032e44f213bce71c6c35ec.setContent(html_8179af31852fe6aa1f5e2a5171b51668);
#
#
#
#         marker_c42b688d9ef3b0c477489f5885b6de7d.bindPopup(popup_5641a3119f032e44f213bce71c6c35ec)
#         ;
#
#
#
#
#             var marker_9ad82f235d7b92749a4a4ce0e8e30025 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8a059983f15254caefc92dabe6938fd1);
#
#
#         var popup_0f7747f0dd155c26e45592df68b9e693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ed50181a73168920e97707134113673 = $(`&lt;div id=&quot;html_9ed50181a73168920e97707134113673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0f7747f0dd155c26e45592df68b9e693.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0264753b183e38f22b16b5c68995dc9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0264753b183e38f22b16b5c68995dc9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0264753b183e38f22b16b5c68995dc9e = L.map(
#                 &quot;map_0264753b183e38f22b16b5c68995dc9e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb3338995682e6aabd943ec2b6031c74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb3338995682e6aabd943ec2b6031c74.addTo(map_0264753b183e38f22b16b5c68995dc9e);
#
#
#             var feature_group_79477d00c58f84247005e5b4a6e58c7d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_79dabe78277c746e1bfcd7b078bdf6c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_79477d00c58f84247005e5b4a6e58c7d);
#
#
#         var popup_c02367218bdd79a76bb5ca1812a51f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_416ab193127d653b03bb9fb2c1440e33 = $(`&lt;div id=&quot;html_416ab193127d653b03bb9fb2c1440e33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c02367218bdd79a76bb5ca1812a51f11.setContent(html_416ab193127d653b03bb9fb2c1440e33);
#
#
#
#         marker_79dabe78277c746e1bfcd7b078bdf6c5.bindPopup(popup_c02367218bdd79a76bb5ca1812a51f11)
#         ;
#
#
#
#
#             var marker_87e7a92c34d93013b9ae41b31a86548c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_79477d00c58f84247005e5b4a6e58c7d);
#
#
#         var popup_3849c3f8c37732a62cac873a57adb9f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_285de3f37b767d870572c66c70a00118 = $(`&lt;div id=&quot;html_285de3f37b767d870572c66c70a00118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3849c3f8c37732a62cac873a57adb9f9.setContent(html_285de3f37b767d870572c66c70a00118);
#
#
#
#         marker_87e7a92c34d93013b9ae41b31a86548c.bindPopup(popup_3849c3f8c37732a62cac873a57adb9f9)
#         ;
#
#
#
#
#             var marker_320eef1e0483fbcf7ce31325fb2439a1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_79477d00c58f84247005e5b4a6e58c7d);
#
#
#         var popup_2c9a510bd6feef21f4616d363a133655 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a38cb29f6e73ede19540c3b686e0adfa = $(`&lt;div id=&quot;html_a38cb29f6e73ede19540c3b686e0adfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2c9a510bd6feef21f4616d363a133655.setContent(html_a38cb29f6e73ede19540c3b686e0adfa);
#
#
#
#         marker_320eef1e0483fbcf7ce31325fb2439a1.bindPopup(popup_2c9a510bd6feef21f4616d363a133655)
#         ;
#
#
#
#
#             var marker_ce3b285c8d0b3b846d80e3a2e8cbf1b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_79477d00c58f84247005e5b4a6e58c7d);
#
#
#         var popup_bf3d938019f9dee26cf857ce746e3e0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eb2a4dcb18f73b1bffca31c4f00ab4b = $(`&lt;div id=&quot;html_6eb2a4dcb18f73b1bffca31c4f00ab4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bf3d938019f9dee26cf857ce746e3e0c.setContent(html_6eb2a4dcb18f73b1bffca31c4f00ab4b);
#
#
#
#         marker_ce3b285c8d0b3b846d80e3a2e8cbf1b5.bindPopup(popup_bf3d938019f9dee26cf857ce746e3e0c)
#         ;
#
#
#
#
#             var marker_36d5764a65518c9e6385b7eb5c908ee0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_79477d00c58f84247005e5b4a6e58c7d);
#
#
#         var popup_ae4357a0ffdadc9d8186abd7a1eef0a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b9dba2be4150d49ff4940cd7f724f51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b9dba2be4150d49ff4940cd7f724f51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b9dba2be4150d49ff4940cd7f724f51 = L.map(
#                 &quot;map_1b9dba2be4150d49ff4940cd7f724f51&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49d475f2e813e8e54d6fbf21133c8569 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49d475f2e813e8e54d6fbf21133c8569.addTo(map_1b9dba2be4150d49ff4940cd7f724f51);
#
#
#             var feature_group_cb948b581fc80f5cb101280c3d6c4127 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cb948b581fc80f5cb101280c3d6c4127.addTo(map_1b9dba2be4150d49ff4940cd7f724f51);
#
#
#             var feature_group_sub_group_f65957d7d8ebf421fcb43ec4af53fba3 = L.featureGroup.subGroup(
#                 feature_group_cb948b581fc80f5cb101280c3d6c4127
#             );
#
#
#             var marker_2aa8d08feaee7020ef4b670efa61bb19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65957d7d8ebf421fcb43ec4af53fba3);
#
#
#         var popup_403f6ecf3d9e0f120bccaeacac137631 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6389dd4757c8df08c6f3468ff88ac258 = $(`&lt;div id=&quot;html_6389dd4757c8df08c6f3468ff88ac258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_403f6ecf3d9e0f120bccaeacac137631.setContent(html_6389dd4757c8df08c6f3468ff88ac258);
#
#
#
#         marker_2aa8d08feaee7020ef4b670efa61bb19.bindPopup(popup_403f6ecf3d9e0f120bccaeacac137631)
#         ;
#
#
#
#
#             var marker_a2c5f110d8d81a3d03ddc2fe792ea65f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65957d7d8ebf421fcb43ec4af53fba3);
#
#
#         var popup_c99b77dd5a0cf966976117f63e48af92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f296ca83e01a754b66482a75123d33d = $(`&lt;div id=&quot;html_8f296ca83e01a754b66482a75123d33d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c99b77dd5a0cf966976117f63e48af92.setContent(html_8f296ca83e01a754b66482a75123d33d);
#
#
#
#         marker_a2c5f110d8d81a3d03ddc2fe792ea65f.bindPopup(popup_c99b77dd5a0cf966976117f63e48af92)
#         ;
#
#
#
#
#             var marker_fa6e63d944d161aa979ed729a2096f22 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65957d7d8ebf421fcb43ec4af53fba3);
#
#
#         var popup_d20e9202480b034e78fa47e1972ed26a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab64bfd2cfb98c4cda4baab8b11cc4a8 = $(`&lt;div id=&quot;html_ab64bfd2cfb98c4cda4baab8b11cc4a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d20e9202480b034e78fa47e1972ed26a.setContent(html_ab64bfd2cfb98c4cda4baab8b11cc4a8);
#
#
#
#         marker_fa6e63d944d161aa979ed729a2096f22.bindPopup(popup_d20e9202480b034e78fa47e1972ed26a)
#         ;
#
#
#
#
#             var marker_b3fa54ad4861e8db648c923543a60dcd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65957d7d8ebf421fcb43ec4af53fba3);
#
#
#         var popup_3972dda4c6c7e00ea6cce247380a2d4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b32275366af6a922e3d5be62781133ba = $(`&lt;div id=&quot;html_b32275366af6a922e3d5be62781133ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3972dda4c6c7e00ea6cce247380a2d4f.setContent(html_b32275366af6a922e3d5be62781133ba);
#
#
#
#         marker_
