# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f55774439ceb066e8488ec33ecdaaa75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f55774439ceb066e8488ec33ecdaaa75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f55774439ceb066e8488ec33ecdaaa75 = L.map(
#                 &quot;map_f55774439ceb066e8488ec33ecdaaa75&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ba91c5cf3ca28ed7da0643e391a5476 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ba91c5cf3ca28ed7da0643e391a5476.addTo(map_f55774439ceb066e8488ec33ecdaaa75);
#
#
#             var marker_a06648de54cccc11753f308f2fba25bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f55774439ceb066e8488ec33ecdaaa75);
#
#
#         var popup_7029e8b377cf64659d008dcf4ea6dc9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bac431debd97d343eb94272cf091b0b = $(`&lt;div id=&quot;html_2bac431debd97d343eb94272cf091b0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7029e8b377cf64659d008dcf4ea6dc9b.setContent(html_2bac431debd97d343eb94272cf091b0b);
#
#
#
#         marker_a06648de54cccc11753f308f2fba25bb.bindPopup(popup_7029e8b377cf64659d008dcf4ea6dc9b)
#         ;
#
#
#
#
#             var marker_7a39be1c32ffd06694d3b29f45f1f97f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f55774439ceb066e8488ec33ecdaaa75);
#
#
#         var popup_f1f67003044102e92f09176a1b484a72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_389b6e498247d4ef261e2caa26cd4d72 = $(`&lt;div id=&quot;html_389b6e498247d4ef261e2caa26cd4d72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f1f67003044102e92f09176a1b484a72.setContent(html_389b6e498247d4ef261e2caa26cd4d72);
#
#
#
#         marker_7a39be1c32ffd06694d3b29f45f1f97f.bindPopup(popup_f1f67003044102e92f09176a1b484a72)
#         ;
#
#
#
#
#             var marker_fda5eb08f8480a2dabc4bf8976973a3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f55774439ceb066e8488ec33ecdaaa75);
#
#
#         var popup_1f0a54b6ceee5d80f9995d223f4a0017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b044debd4d29a851670b425334f5bf4f = $(`&lt;div id=&quot;html_b044debd4d29a851670b425334f5bf4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1f0a54b6ceee5d80f9995d223f4a0017.setContent(html_b044debd4d29a851670b425334f5bf4f);
#
#
#
#         marker_fda5eb08f8480a2dabc4bf8976973a3f.bindPopup(popup_1f0a54b6ceee5d80f9995d223f4a0017)
#         ;
#
#
#
#
#             var marker_effb2123c4f470f6a3428240060fbcac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f55774439ceb066e8488ec33ecdaaa75);
#
#
#         var popup_56646e10458b7b9b2017c6e234ebc8b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ac25d8f0e55a88c8a5602a83e19a08b = $(`&lt;div id=&quot;html_9ac25d8f0e55a88c8a5602a83e19a08b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_56646e10458b7b9b2017c6e234ebc8b2.setContent(html_9ac25d8f0e55a88c8a5602a83e19a08b);
#
#
#
#         marker_effb2123c4f470f6a3428240060fbcac.bindPopup(popup_56646e10458b7b9b2017c6e234ebc8b2)
#         ;
#
#
#
#
#             var marker_8ce8fb356f0e1041f8bf316d2e6acce5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f55774439ceb066e8488ec33ecdaaa75);
#
#
#         var popup_6c8a4c86c5287f2c985b75320893cafc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_157c0631120ea693f9806461b009d19a = $(`&lt;div id=&quot;html_157c0631120ea693f9806461b009d19a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6c8a4c86c5287f2c985b75320893cafc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba26a7e524d8c6832ddd8f82a0639bad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba26a7e524d8c6832ddd8f82a0639bad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba26a7e524d8c6832ddd8f82a0639bad = L.map(
#                 &quot;map_ba26a7e524d8c6832ddd8f82a0639bad&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_367f18c65ff866341a4349826e653b78 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_367f18c65ff866341a4349826e653b78.addTo(map_ba26a7e524d8c6832ddd8f82a0639bad);
#
#
#             var feature_group_2356c0aca0f9e3582693cf4ff1d1af45 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c5eb9af97245666e5f5c9f98fd38a652 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2356c0aca0f9e3582693cf4ff1d1af45);
#
#
#         var popup_1aff5529067639202bf55470d9d97c7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e25a6483218f5dcef279c842da050ee8 = $(`&lt;div id=&quot;html_e25a6483218f5dcef279c842da050ee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1aff5529067639202bf55470d9d97c7d.setContent(html_e25a6483218f5dcef279c842da050ee8);
#
#
#
#         marker_c5eb9af97245666e5f5c9f98fd38a652.bindPopup(popup_1aff5529067639202bf55470d9d97c7d)
#         ;
#
#
#
#
#             var marker_b1c2118d55e302d7c6a538593232210b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2356c0aca0f9e3582693cf4ff1d1af45);
#
#
#         var popup_9f7857fa6c8c4a18df5d96098c03870c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08ad8c9131ea28d5d300acdafba1e5cb = $(`&lt;div id=&quot;html_08ad8c9131ea28d5d300acdafba1e5cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9f7857fa6c8c4a18df5d96098c03870c.setContent(html_08ad8c9131ea28d5d300acdafba1e5cb);
#
#
#
#         marker_b1c2118d55e302d7c6a538593232210b.bindPopup(popup_9f7857fa6c8c4a18df5d96098c03870c)
#         ;
#
#
#
#
#             var marker_0a4ddc2027fec34447aa31e9b23273c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2356c0aca0f9e3582693cf4ff1d1af45);
#
#
#         var popup_461a4ce8b475fb25eaaf8ad4ef188de7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea162e9211b477fbf462f080d3c68d6 = $(`&lt;div id=&quot;html_bea162e9211b477fbf462f080d3c68d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_461a4ce8b475fb25eaaf8ad4ef188de7.setContent(html_bea162e9211b477fbf462f080d3c68d6);
#
#
#
#         marker_0a4ddc2027fec34447aa31e9b23273c0.bindPopup(popup_461a4ce8b475fb25eaaf8ad4ef188de7)
#         ;
#
#
#
#
#             var marker_869210cb836b5e5b5e826008301cb82e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2356c0aca0f9e3582693cf4ff1d1af45);
#
#
#         var popup_d4b7dcd9805e4691d988057b09b6b4b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ce332dc0d91bab0c3f0b1da947a9b24 = $(`&lt;div id=&quot;html_4ce332dc0d91bab0c3f0b1da947a9b24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d4b7dcd9805e4691d988057b09b6b4b4.setContent(html_4ce332dc0d91bab0c3f0b1da947a9b24);
#
#
#
#         marker_869210cb836b5e5b5e826008301cb82e.bindPopup(popup_d4b7dcd9805e4691d988057b09b6b4b4)
#         ;
#
#
#
#
#             var marker_faa11952f898cd51ecdbf50f09847a21 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2356c0aca0f9e3582693cf4ff1d1af45);
#
#
#         var popup_b59f6397800301b8371a606253922402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1720fa15390748c75504d4a252a1c86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1720fa15390748c75504d4a252a1c86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1720fa15390748c75504d4a252a1c86 = L.map(
#                 &quot;map_a1720fa15390748c75504d4a252a1c86&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86f527163dcaee464715cf753011cd9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86f527163dcaee464715cf753011cd9a.addTo(map_a1720fa15390748c75504d4a252a1c86);
#
#
#             var feature_group_9a8b41d07bdb27bea66f410dd36b4b1f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9a8b41d07bdb27bea66f410dd36b4b1f.addTo(map_a1720fa15390748c75504d4a252a1c86);
#
#
#             var feature_group_sub_group_4944ad59b766d8ab5174354722199347 = L.featureGroup.subGroup(
#                 feature_group_9a8b41d07bdb27bea66f410dd36b4b1f
#             );
#
#
#             var marker_8343a9bbaf7aec73ae0f50a607ce5631 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4944ad59b766d8ab5174354722199347);
#
#
#         var popup_4066d1af90a1380f5acb595a2f05d93a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1b47c971bad272009ccbd1035ad60df = $(`&lt;div id=&quot;html_b1b47c971bad272009ccbd1035ad60df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4066d1af90a1380f5acb595a2f05d93a.setContent(html_b1b47c971bad272009ccbd1035ad60df);
#
#
#
#         marker_8343a9bbaf7aec73ae0f50a607ce5631.bindPopup(popup_4066d1af90a1380f5acb595a2f05d93a)
#         ;
#
#
#
#
#             var marker_56a97231eacd7f39332e2bcfeb48430d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4944ad59b766d8ab5174354722199347);
#
#
#         var popup_c28631fdf47fe39c67fdb9461226c404 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a7eec9e2af6cba029f9895d5a81629c = $(`&lt;div id=&quot;html_4a7eec9e2af6cba029f9895d5a81629c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c28631fdf47fe39c67fdb9461226c404.setContent(html_4a7eec9e2af6cba029f9895d5a81629c);
#
#
#
#         marker_56a97231eacd7f39332e2bcfeb48430d.bindPopup(popup_c28631fdf47fe39c67fdb9461226c404)
#         ;
#
#
#
#
#             var marker_26b97d91ff2c517d013f0e972de03035 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4944ad59b766d8ab5174354722199347);
#
#
#         var popup_ca1aac209d76f41d941c1e8100bf0c1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e4ced550bbd9c5a585c26fee4d319b1 = $(`&lt;div id=&quot;html_2e4ced550bbd9c5a585c26fee4d319b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ca1aac209d76f41d941c1e8100bf0c1a.setContent(html_2e4ced550bbd9c5a585c26fee4d319b1);
#
#
#
#         marker_26b97d91ff2c517d013f0e972de03035.bindPopup(popup_ca1aac209d76f41d941c1e8100bf0c1a)
#         ;
#
#
#
#
#             var marker_41c80ab0e9703fb738c01568825422b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4944ad59b766d8ab5174354722199347);
#
#
#         var popup_80292d854043df91c645ff8768de23e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b9a83f5593e5d46ccad90003f3aa875 = $(`&lt;div id=&quot;html_0b9a83f5593e5d46ccad90003f3aa875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_80292d854043df91c645ff8768de23e1.setContent(html_0b9a83f5593e5d46ccad90003f3aa875);
#
#
#
#         marker_
