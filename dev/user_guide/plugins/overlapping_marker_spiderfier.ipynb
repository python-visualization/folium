# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b846ccbe9a0a8a1891e36d0f09e93adb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b846ccbe9a0a8a1891e36d0f09e93adb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b846ccbe9a0a8a1891e36d0f09e93adb = L.map(
#                 &quot;map_b846ccbe9a0a8a1891e36d0f09e93adb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd6919d97939a4b88bc2a958885e6640 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd6919d97939a4b88bc2a958885e6640.addTo(map_b846ccbe9a0a8a1891e36d0f09e93adb);
#
#
#             var marker_7301814de29b7de7f810adc0cdf66058 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b846ccbe9a0a8a1891e36d0f09e93adb);
#
#
#         var popup_105bbefbb911c1b5da81df5f803ddc10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0eeac224b8830956d0db24ee52fe0f7f = $(`&lt;div id=&quot;html_0eeac224b8830956d0db24ee52fe0f7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_105bbefbb911c1b5da81df5f803ddc10.setContent(html_0eeac224b8830956d0db24ee52fe0f7f);
#
#
#
#         marker_7301814de29b7de7f810adc0cdf66058.bindPopup(popup_105bbefbb911c1b5da81df5f803ddc10)
#         ;
#
#
#
#
#             var marker_2b013fe51b1527b9073a3d32edd03fd9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b846ccbe9a0a8a1891e36d0f09e93adb);
#
#
#         var popup_fc9e73d1ee474b0e7173812516803f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8811e465f40ed19ecd83055b2b4c6644 = $(`&lt;div id=&quot;html_8811e465f40ed19ecd83055b2b4c6644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fc9e73d1ee474b0e7173812516803f71.setContent(html_8811e465f40ed19ecd83055b2b4c6644);
#
#
#
#         marker_2b013fe51b1527b9073a3d32edd03fd9.bindPopup(popup_fc9e73d1ee474b0e7173812516803f71)
#         ;
#
#
#
#
#             var marker_2733631499dbbedb16a2401192df2a40 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b846ccbe9a0a8a1891e36d0f09e93adb);
#
#
#         var popup_a14099269bd23b238a24357fa87dfdab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19110def03eadc1e4207d5ad21afb027 = $(`&lt;div id=&quot;html_19110def03eadc1e4207d5ad21afb027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a14099269bd23b238a24357fa87dfdab.setContent(html_19110def03eadc1e4207d5ad21afb027);
#
#
#
#         marker_2733631499dbbedb16a2401192df2a40.bindPopup(popup_a14099269bd23b238a24357fa87dfdab)
#         ;
#
#
#
#
#             var marker_b7e9f56ca81599d2b545bd791b1fe764 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b846ccbe9a0a8a1891e36d0f09e93adb);
#
#
#         var popup_4fe067dbc36dd22363a4bca73104563a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02bf4995bc98c8f7d0861410d0fa81b0 = $(`&lt;div id=&quot;html_02bf4995bc98c8f7d0861410d0fa81b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4fe067dbc36dd22363a4bca73104563a.setContent(html_02bf4995bc98c8f7d0861410d0fa81b0);
#
#
#
#         marker_b7e9f56ca81599d2b545bd791b1fe764.bindPopup(popup_4fe067dbc36dd22363a4bca73104563a)
#         ;
#
#
#
#
#             var marker_27cfdd5f73b2a4a34f41c4b8e9e2558c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b846ccbe9a0a8a1891e36d0f09e93adb);
#
#
#         var popup_f906cf2bdec90c83835cd44ff4a1b53d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dadd3c7546c284a97a5b3e82995811be = $(`&lt;div id=&quot;html_dadd3c7546c284a97a5b3e82995811be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f906cf2bdec90c83835cd44ff4a1b53d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12797d603c3a480fc764499516027ce4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12797d603c3a480fc764499516027ce4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12797d603c3a480fc764499516027ce4 = L.map(
#                 &quot;map_12797d603c3a480fc764499516027ce4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3ff4ac261e79ac454bce82d8f0573c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a3ff4ac261e79ac454bce82d8f0573c8.addTo(map_12797d603c3a480fc764499516027ce4);
#
#
#             var feature_group_d11121015ff990a317d3359954d5c5d2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_14f09532c71cb0fe72e148799079f0f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d11121015ff990a317d3359954d5c5d2);
#
#
#         var popup_dadbb11688729b430969e4f920faf697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43bbe77521996a93cdac483426fd3855 = $(`&lt;div id=&quot;html_43bbe77521996a93cdac483426fd3855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dadbb11688729b430969e4f920faf697.setContent(html_43bbe77521996a93cdac483426fd3855);
#
#
#
#         marker_14f09532c71cb0fe72e148799079f0f7.bindPopup(popup_dadbb11688729b430969e4f920faf697)
#         ;
#
#
#
#
#             var marker_d4a949834736ba56583a4957e92187f2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d11121015ff990a317d3359954d5c5d2);
#
#
#         var popup_2c0aa3dc352005ddbbd7a9798eed9c4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2a23e1f33f8aca9a1b258500b55090d = $(`&lt;div id=&quot;html_c2a23e1f33f8aca9a1b258500b55090d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2c0aa3dc352005ddbbd7a9798eed9c4f.setContent(html_c2a23e1f33f8aca9a1b258500b55090d);
#
#
#
#         marker_d4a949834736ba56583a4957e92187f2.bindPopup(popup_2c0aa3dc352005ddbbd7a9798eed9c4f)
#         ;
#
#
#
#
#             var marker_5675da79f28db3fcdb67fe9cf88772f7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d11121015ff990a317d3359954d5c5d2);
#
#
#         var popup_698b4a23353e75ed83a84e97b0bf65dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31f9de47dbef8ab1cb285b85ddec2d28 = $(`&lt;div id=&quot;html_31f9de47dbef8ab1cb285b85ddec2d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_698b4a23353e75ed83a84e97b0bf65dd.setContent(html_31f9de47dbef8ab1cb285b85ddec2d28);
#
#
#
#         marker_5675da79f28db3fcdb67fe9cf88772f7.bindPopup(popup_698b4a23353e75ed83a84e97b0bf65dd)
#         ;
#
#
#
#
#             var marker_5fd7d5e1d935a6b88a9e2f9dc8ec06a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d11121015ff990a317d3359954d5c5d2);
#
#
#         var popup_1762fe7159c9fe5a808ba4da8ef269bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30c1ad718d904c61f9fad3849c869ac0 = $(`&lt;div id=&quot;html_30c1ad718d904c61f9fad3849c869ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1762fe7159c9fe5a808ba4da8ef269bf.setContent(html_30c1ad718d904c61f9fad3849c869ac0);
#
#
#
#         marker_5fd7d5e1d935a6b88a9e2f9dc8ec06a3.bindPopup(popup_1762fe7159c9fe5a808ba4da8ef269bf)
#         ;
#
#
#
#
#             var marker_9fdaa0959ed20d9577f5e610cd4ffa4d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d11121015ff990a317d3359954d5c5d2);
#
#
#         var popup_bab74044145cceafc0497aa092108f3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a169a0ecd9c629f38ac1ef70c5519b67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a169a0ecd9c629f38ac1ef70c5519b67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a169a0ecd9c629f38ac1ef70c5519b67 = L.map(
#                 &quot;map_a169a0ecd9c629f38ac1ef70c5519b67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_067105ceae906a61338b3156a06ae9e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_067105ceae906a61338b3156a06ae9e4.addTo(map_a169a0ecd9c629f38ac1ef70c5519b67);
#
#
#             var feature_group_3448794a7f12c8f2ec66f8963e14b6a9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3448794a7f12c8f2ec66f8963e14b6a9.addTo(map_a169a0ecd9c629f38ac1ef70c5519b67);
#
#
#             var feature_group_sub_group_1c7121a762680582478a935372153a21 = L.featureGroup.subGroup(
#                 feature_group_3448794a7f12c8f2ec66f8963e14b6a9
#             );
#
#
#             var marker_2458863c0ad4d736f22b2d7067c70d9b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c7121a762680582478a935372153a21);
#
#
#         var popup_52b70c89e085adb08473b1e9fa3cd200 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f84c050021901c737ea9579d5921e01 = $(`&lt;div id=&quot;html_7f84c050021901c737ea9579d5921e01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_52b70c89e085adb08473b1e9fa3cd200.setContent(html_7f84c050021901c737ea9579d5921e01);
#
#
#
#         marker_2458863c0ad4d736f22b2d7067c70d9b.bindPopup(popup_52b70c89e085adb08473b1e9fa3cd200)
#         ;
#
#
#
#
#             var marker_8b99b3d2cc9d30ac57dd1d114f1d4ccc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c7121a762680582478a935372153a21);
#
#
#         var popup_d4c5cc17acb48400d9240028e41e589c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_478e24315c4a78c6b0330137534df66c = $(`&lt;div id=&quot;html_478e24315c4a78c6b0330137534df66c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d4c5cc17acb48400d9240028e41e589c.setContent(html_478e24315c4a78c6b0330137534df66c);
#
#
#
#         marker_8b99b3d2cc9d30ac57dd1d114f1d4ccc.bindPopup(popup_d4c5cc17acb48400d9240028e41e589c)
#         ;
#
#
#
#
#             var marker_52e42beb3a48b499ef53a0a10cf93cbb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c7121a762680582478a935372153a21);
#
#
#         var popup_d98f34611373db9fce36b5e634c66e01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6e644e4781fc3aa79bac6379ffdc309 = $(`&lt;div id=&quot;html_a6e644e4781fc3aa79bac6379ffdc309&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d98f34611373db9fce36b5e634c66e01.setContent(html_a6e644e4781fc3aa79bac6379ffdc309);
#
#
#
#         marker_52e42beb3a48b499ef53a0a10cf93cbb.bindPopup(popup_d98f34611373db9fce36b5e634c66e01)
#         ;
#
#
#
#
#             var marker_741dcd2dfd22ed29133b71d0759b509f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c7121a762680582478a935372153a21);
#
#
#         var popup_45d68ba696492582fef868b7d529f625 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_507d292e70a76bda74953fa08f79c5f6 = $(`&lt;div id=&quot;html_507d292e70a76bda74953fa08f79c5f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_45d68ba696492582fef868b7d529f625.setContent(html_507d292e70a76bda74953fa08f79c5f6);
#
#
#
#         marker_
