# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ae15816bb6ade42d315a0466972637a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ae15816bb6ade42d315a0466972637a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ae15816bb6ade42d315a0466972637a = L.map(
#                 &quot;map_2ae15816bb6ade42d315a0466972637a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecc19fd9665a9151ec2d7a247db0e98b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ecc19fd9665a9151ec2d7a247db0e98b.addTo(map_2ae15816bb6ade42d315a0466972637a);
#
#
#             var marker_b76514133d8ae6a1db3e197729845612 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2ae15816bb6ade42d315a0466972637a);
#
#
#         var popup_fdcb671d70f1c3cb426b422263ee85fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10816644ad7aabcca7aaca02344288ed = $(`&lt;div id=&quot;html_10816644ad7aabcca7aaca02344288ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fdcb671d70f1c3cb426b422263ee85fc.setContent(html_10816644ad7aabcca7aaca02344288ed);
#
#
#
#         marker_b76514133d8ae6a1db3e197729845612.bindPopup(popup_fdcb671d70f1c3cb426b422263ee85fc)
#         ;
#
#
#
#
#             var marker_fdb431912a34c427cba2eb41c0026666 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2ae15816bb6ade42d315a0466972637a);
#
#
#         var popup_52f4ea34af6ecf8428a5d0e6e8a47ee8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82d43ddb2146630f9cd4748628ede99d = $(`&lt;div id=&quot;html_82d43ddb2146630f9cd4748628ede99d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52f4ea34af6ecf8428a5d0e6e8a47ee8.setContent(html_82d43ddb2146630f9cd4748628ede99d);
#
#
#
#         marker_fdb431912a34c427cba2eb41c0026666.bindPopup(popup_52f4ea34af6ecf8428a5d0e6e8a47ee8)
#         ;
#
#
#
#
#             var marker_982989daae3a9bc39c6a75eeb9b371be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2ae15816bb6ade42d315a0466972637a);
#
#
#         var popup_97385b343e4fad24203f2106c8c47b3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a54d48aaa6f52c590d5f1312b2d858a = $(`&lt;div id=&quot;html_8a54d48aaa6f52c590d5f1312b2d858a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_97385b343e4fad24203f2106c8c47b3a.setContent(html_8a54d48aaa6f52c590d5f1312b2d858a);
#
#
#
#         marker_982989daae3a9bc39c6a75eeb9b371be.bindPopup(popup_97385b343e4fad24203f2106c8c47b3a)
#         ;
#
#
#
#
#             var marker_478e3f72b4979195cacd561e139dc5f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2ae15816bb6ade42d315a0466972637a);
#
#
#         var popup_3bda38e30400883523324f3c990022d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fd24b8e72dc4ce5fdb3ae49a6bdb6d7 = $(`&lt;div id=&quot;html_7fd24b8e72dc4ce5fdb3ae49a6bdb6d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3bda38e30400883523324f3c990022d0.setContent(html_7fd24b8e72dc4ce5fdb3ae49a6bdb6d7);
#
#
#
#         marker_478e3f72b4979195cacd561e139dc5f2.bindPopup(popup_3bda38e30400883523324f3c990022d0)
#         ;
#
#
#
#
#             var marker_02dca493112feb2d1494c5d826ebe9e1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2ae15816bb6ade42d315a0466972637a);
#
#
#         var popup_944acc032794a6ee495f352f301bea35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5368c2e970ea4743ec49413153e236ba = $(`&lt;div id=&quot;html_5368c2e970ea4743ec49413153e236ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_944acc032794a6ee495f352f301bea35.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65192eec35c27ded89ab043b27e0842d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65192eec35c27ded89ab043b27e0842d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65192eec35c27ded89ab043b27e0842d = L.map(
#                 &quot;map_65192eec35c27ded89ab043b27e0842d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11f553ebeb1346389fdbf08c30f33982 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11f553ebeb1346389fdbf08c30f33982.addTo(map_65192eec35c27ded89ab043b27e0842d);
#
#
#             var feature_group_f0d9cfafd9e7e5a168af6893521bf413 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8246f84f67ca4dfb54d4d821a1c9bca6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f0d9cfafd9e7e5a168af6893521bf413);
#
#
#         var popup_d78cb755b4399b37832b01d803063811 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5dc694671e35310bae5bf9ee029954f = $(`&lt;div id=&quot;html_c5dc694671e35310bae5bf9ee029954f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d78cb755b4399b37832b01d803063811.setContent(html_c5dc694671e35310bae5bf9ee029954f);
#
#
#
#         marker_8246f84f67ca4dfb54d4d821a1c9bca6.bindPopup(popup_d78cb755b4399b37832b01d803063811)
#         ;
#
#
#
#
#             var marker_91057f07d04c280f0be40e4a9a0ffc20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f0d9cfafd9e7e5a168af6893521bf413);
#
#
#         var popup_140b8b78d7ec799a033852ef9e6d21eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57cda6d70d915f037c804577d6a08f49 = $(`&lt;div id=&quot;html_57cda6d70d915f037c804577d6a08f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_140b8b78d7ec799a033852ef9e6d21eb.setContent(html_57cda6d70d915f037c804577d6a08f49);
#
#
#
#         marker_91057f07d04c280f0be40e4a9a0ffc20.bindPopup(popup_140b8b78d7ec799a033852ef9e6d21eb)
#         ;
#
#
#
#
#             var marker_197ae771d23c3576d28564e4904eb64b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f0d9cfafd9e7e5a168af6893521bf413);
#
#
#         var popup_cc86ffd57b52ab83d6c6d09862ed0cc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_657bd0e1d3a8396b02194e61d50c0f93 = $(`&lt;div id=&quot;html_657bd0e1d3a8396b02194e61d50c0f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cc86ffd57b52ab83d6c6d09862ed0cc8.setContent(html_657bd0e1d3a8396b02194e61d50c0f93);
#
#
#
#         marker_197ae771d23c3576d28564e4904eb64b.bindPopup(popup_cc86ffd57b52ab83d6c6d09862ed0cc8)
#         ;
#
#
#
#
#             var marker_22492cbabf11a1a8c6e43c80ba69e5f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f0d9cfafd9e7e5a168af6893521bf413);
#
#
#         var popup_ea433c298cae49ea2b2a28d619421e07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7da309796b2527fe813cb10dfdf0ce43 = $(`&lt;div id=&quot;html_7da309796b2527fe813cb10dfdf0ce43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ea433c298cae49ea2b2a28d619421e07.setContent(html_7da309796b2527fe813cb10dfdf0ce43);
#
#
#
#         marker_22492cbabf11a1a8c6e43c80ba69e5f3.bindPopup(popup_ea433c298cae49ea2b2a28d619421e07)
#         ;
#
#
#
#
#             var marker_3da2e4430cadd39f92970823b5a72953 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f0d9cfafd9e7e5a168af6893521bf413);
#
#
#         var popup_8c0a1b47006996e33a339496b898d88d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be660460299bedf41cc2a2512f9e6165 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be660460299bedf41cc2a2512f9e6165&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be660460299bedf41cc2a2512f9e6165 = L.map(
#                 &quot;map_be660460299bedf41cc2a2512f9e6165&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12177a4e20cb03df947f07eb09642a42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12177a4e20cb03df947f07eb09642a42.addTo(map_be660460299bedf41cc2a2512f9e6165);
#
#
#             var feature_group_bd6f3b607029cc7b61079f770aae0947 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bd6f3b607029cc7b61079f770aae0947.addTo(map_be660460299bedf41cc2a2512f9e6165);
#
#
#             var feature_group_sub_group_14cdf7eb946f5722ba45e7e07ba2a008 = L.featureGroup.subGroup(
#                 feature_group_bd6f3b607029cc7b61079f770aae0947
#             );
#
#
#             var marker_d4cdf76fd803639de38a432dfdf16dc1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_14cdf7eb946f5722ba45e7e07ba2a008);
#
#
#         var popup_e96e768d76f925fd64c7a0c0ae971720 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99f692c7d784e95522833ace50477b84 = $(`&lt;div id=&quot;html_99f692c7d784e95522833ace50477b84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e96e768d76f925fd64c7a0c0ae971720.setContent(html_99f692c7d784e95522833ace50477b84);
#
#
#
#         marker_d4cdf76fd803639de38a432dfdf16dc1.bindPopup(popup_e96e768d76f925fd64c7a0c0ae971720)
#         ;
#
#
#
#
#             var marker_2806326eb5117ff58f480f0fd83514e9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_14cdf7eb946f5722ba45e7e07ba2a008);
#
#
#         var popup_5c2edc9fbb1172b6df3ad3ce35b1766b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecb4ba47a73fe7f9458b28456bfdfe90 = $(`&lt;div id=&quot;html_ecb4ba47a73fe7f9458b28456bfdfe90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5c2edc9fbb1172b6df3ad3ce35b1766b.setContent(html_ecb4ba47a73fe7f9458b28456bfdfe90);
#
#
#
#         marker_2806326eb5117ff58f480f0fd83514e9.bindPopup(popup_5c2edc9fbb1172b6df3ad3ce35b1766b)
#         ;
#
#
#
#
#             var marker_c8c20b52556d1a3dab1cceb2ec0cb131 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_14cdf7eb946f5722ba45e7e07ba2a008);
#
#
#         var popup_3a6809e41dfc417860f634bc3ae145d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_993126e25a97374a8d8db4bc93d1f3df = $(`&lt;div id=&quot;html_993126e25a97374a8d8db4bc93d1f3df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3a6809e41dfc417860f634bc3ae145d6.setContent(html_993126e25a97374a8d8db4bc93d1f3df);
#
#
#
#         marker_c8c20b52556d1a3dab1cceb2ec0cb131.bindPopup(popup_3a6809e41dfc417860f634bc3ae145d6)
#         ;
#
#
#
#
#             var marker_ac3fb4ae4538d96dd87a2c90f160aa87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_14cdf7eb946f5722ba45e7e07ba2a008);
#
#
#         var popup_ddbf40df5d45928bd24f1939f44df6ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_766c724b897ff6ef87e705cbbb068408 = $(`&lt;div id=&quot;html_766c724b897ff6ef87e705cbbb068408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ddbf40df5d45928bd24f1939f44df6ff.setContent(html_766c724b897ff6ef87e705cbbb068408);
#
#
#
#         marker_
