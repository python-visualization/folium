# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef1ef68748a7b6e9965e6fb9e31bb311 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef1ef68748a7b6e9965e6fb9e31bb311&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef1ef68748a7b6e9965e6fb9e31bb311 = L.map(
#                 &quot;map_ef1ef68748a7b6e9965e6fb9e31bb311&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae48d55c0a6dbf18e6930fe17fa3619a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae48d55c0a6dbf18e6930fe17fa3619a.addTo(map_ef1ef68748a7b6e9965e6fb9e31bb311);
#
#
#             var marker_e165f27b28913090b691be6dd1816bc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ef1ef68748a7b6e9965e6fb9e31bb311);
#
#
#         var popup_860cadeb70251f18bace8b08cf4d6687 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c80f75ceb143a22c5e42e16fe5b0cee = $(`&lt;div id=&quot;html_4c80f75ceb143a22c5e42e16fe5b0cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_860cadeb70251f18bace8b08cf4d6687.setContent(html_4c80f75ceb143a22c5e42e16fe5b0cee);
#
#
#
#         marker_e165f27b28913090b691be6dd1816bc7.bindPopup(popup_860cadeb70251f18bace8b08cf4d6687)
#         ;
#
#
#
#
#             var marker_52ad3747caaa0ba31bee7d86e7816293 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ef1ef68748a7b6e9965e6fb9e31bb311);
#
#
#         var popup_01e892f7180336b76fc6eda8607f90f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dd7a1e2bef0304ac40249aab564460b = $(`&lt;div id=&quot;html_8dd7a1e2bef0304ac40249aab564460b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_01e892f7180336b76fc6eda8607f90f5.setContent(html_8dd7a1e2bef0304ac40249aab564460b);
#
#
#
#         marker_52ad3747caaa0ba31bee7d86e7816293.bindPopup(popup_01e892f7180336b76fc6eda8607f90f5)
#         ;
#
#
#
#
#             var marker_3683be5c112f10fdae4208e07e4bec6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ef1ef68748a7b6e9965e6fb9e31bb311);
#
#
#         var popup_a68a9dd170c96c2a5740e4f4c59c2743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_185a960ec2c5d204c048ca79097394f2 = $(`&lt;div id=&quot;html_185a960ec2c5d204c048ca79097394f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a68a9dd170c96c2a5740e4f4c59c2743.setContent(html_185a960ec2c5d204c048ca79097394f2);
#
#
#
#         marker_3683be5c112f10fdae4208e07e4bec6a.bindPopup(popup_a68a9dd170c96c2a5740e4f4c59c2743)
#         ;
#
#
#
#
#             var marker_574012e5b12fc3f91bdd943b1b4e338e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ef1ef68748a7b6e9965e6fb9e31bb311);
#
#
#         var popup_f596e1de3c84e9f30de6827d879a1153 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_692993f9aee69dbaa329ee68825adba8 = $(`&lt;div id=&quot;html_692993f9aee69dbaa329ee68825adba8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f596e1de3c84e9f30de6827d879a1153.setContent(html_692993f9aee69dbaa329ee68825adba8);
#
#
#
#         marker_574012e5b12fc3f91bdd943b1b4e338e.bindPopup(popup_f596e1de3c84e9f30de6827d879a1153)
#         ;
#
#
#
#
#             var marker_964d44a14098f5595161320a381f7deb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ef1ef68748a7b6e9965e6fb9e31bb311);
#
#
#         var popup_78918a7888225262f40bb91a8dde9030 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62082477238a5f2efc2bf346fd659598 = $(`&lt;div id=&quot;html_62082477238a5f2efc2bf346fd659598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_78918a7888225262f40bb91a8dde9030.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85d22a436dcaa8a84c650665a824a61b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85d22a436dcaa8a84c650665a824a61b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85d22a436dcaa8a84c650665a824a61b = L.map(
#                 &quot;map_85d22a436dcaa8a84c650665a824a61b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_964178f2f762a91cd165be247825fa98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_964178f2f762a91cd165be247825fa98.addTo(map_85d22a436dcaa8a84c650665a824a61b);
#
#
#             var feature_group_0ab9efa0b01b193ab2b01a2bcdd26588 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1ad029cba61247198598828827e21344 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0ab9efa0b01b193ab2b01a2bcdd26588);
#
#
#         var popup_d149d04599067a7dd9502dbf2d6fbd2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57a8ab75678988ca753fd390f875e576 = $(`&lt;div id=&quot;html_57a8ab75678988ca753fd390f875e576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d149d04599067a7dd9502dbf2d6fbd2a.setContent(html_57a8ab75678988ca753fd390f875e576);
#
#
#
#         marker_1ad029cba61247198598828827e21344.bindPopup(popup_d149d04599067a7dd9502dbf2d6fbd2a)
#         ;
#
#
#
#
#             var marker_2570c4988e447bc86b42a5a3059b6644 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0ab9efa0b01b193ab2b01a2bcdd26588);
#
#
#         var popup_af954166eaa231497e207861c967d429 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00da4c16d53b337d7234295848d2bc3c = $(`&lt;div id=&quot;html_00da4c16d53b337d7234295848d2bc3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_af954166eaa231497e207861c967d429.setContent(html_00da4c16d53b337d7234295848d2bc3c);
#
#
#
#         marker_2570c4988e447bc86b42a5a3059b6644.bindPopup(popup_af954166eaa231497e207861c967d429)
#         ;
#
#
#
#
#             var marker_0868934f55efb68016a054f4dfb8e0af = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0ab9efa0b01b193ab2b01a2bcdd26588);
#
#
#         var popup_80517f1306edb0b747a75dbf6bdd55ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a8a62f1c8c51da110d3a52fd05069ab = $(`&lt;div id=&quot;html_9a8a62f1c8c51da110d3a52fd05069ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_80517f1306edb0b747a75dbf6bdd55ad.setContent(html_9a8a62f1c8c51da110d3a52fd05069ab);
#
#
#
#         marker_0868934f55efb68016a054f4dfb8e0af.bindPopup(popup_80517f1306edb0b747a75dbf6bdd55ad)
#         ;
#
#
#
#
#             var marker_181ec08abfaec91ff57fe7122d67815c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0ab9efa0b01b193ab2b01a2bcdd26588);
#
#
#         var popup_a3d74629936a9f70799a160c34705a88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91e4a45ba2e058dae573967015d31f3e = $(`&lt;div id=&quot;html_91e4a45ba2e058dae573967015d31f3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a3d74629936a9f70799a160c34705a88.setContent(html_91e4a45ba2e058dae573967015d31f3e);
#
#
#
#         marker_181ec08abfaec91ff57fe7122d67815c.bindPopup(popup_a3d74629936a9f70799a160c34705a88)
#         ;
#
#
#
#
#             var marker_e98ea1490e2ad1d85e5512612aafb18b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0ab9efa0b01b193ab2b01a2bcdd26588);
#
#
#         var popup_8352576a1f94f8f5e371c95eae13097e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_def13ddd036f36ad9a2668a2ed46d1a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_def13ddd036f36ad9a2668a2ed46d1a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_def13ddd036f36ad9a2668a2ed46d1a2 = L.map(
#                 &quot;map_def13ddd036f36ad9a2668a2ed46d1a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8b3bc94ee5ea376d04604a4cbf005fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8b3bc94ee5ea376d04604a4cbf005fa.addTo(map_def13ddd036f36ad9a2668a2ed46d1a2);
#
#
#             var feature_group_da23fb51761190193f3d66c23b16658e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_da23fb51761190193f3d66c23b16658e.addTo(map_def13ddd036f36ad9a2668a2ed46d1a2);
#
#
#             var feature_group_sub_group_15b3ecd1ac19e73f2c73c49491e62e44 = L.featureGroup.subGroup(
#                 feature_group_da23fb51761190193f3d66c23b16658e
#             );
#
#
#             var marker_909c746e08efeff29050278423b83db0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_15b3ecd1ac19e73f2c73c49491e62e44);
#
#
#         var popup_98b2385a15efa7c3fc3a9346ba010248 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e01dc99f41ace309dab2c8969b39372b = $(`&lt;div id=&quot;html_e01dc99f41ace309dab2c8969b39372b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_98b2385a15efa7c3fc3a9346ba010248.setContent(html_e01dc99f41ace309dab2c8969b39372b);
#
#
#
#         marker_909c746e08efeff29050278423b83db0.bindPopup(popup_98b2385a15efa7c3fc3a9346ba010248)
#         ;
#
#
#
#
#             var marker_42d722a0f98055dbe2ff7d715d6c035e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_15b3ecd1ac19e73f2c73c49491e62e44);
#
#
#         var popup_85ffd0f7d7ba6ddd23c192606db94c31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0de99d1dd1bc6cea47983e88624f84f7 = $(`&lt;div id=&quot;html_0de99d1dd1bc6cea47983e88624f84f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_85ffd0f7d7ba6ddd23c192606db94c31.setContent(html_0de99d1dd1bc6cea47983e88624f84f7);
#
#
#
#         marker_42d722a0f98055dbe2ff7d715d6c035e.bindPopup(popup_85ffd0f7d7ba6ddd23c192606db94c31)
#         ;
#
#
#
#
#             var marker_d91125609a9438381b3aaa995a5da481 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_15b3ecd1ac19e73f2c73c49491e62e44);
#
#
#         var popup_8641b2ca24dd07b4529c4782ee06a46e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f898fcf27dfcf995146ff97aefbba5f = $(`&lt;div id=&quot;html_8f898fcf27dfcf995146ff97aefbba5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8641b2ca24dd07b4529c4782ee06a46e.setContent(html_8f898fcf27dfcf995146ff97aefbba5f);
#
#
#
#         marker_d91125609a9438381b3aaa995a5da481.bindPopup(popup_8641b2ca24dd07b4529c4782ee06a46e)
#         ;
#
#
#
#
#             var marker_8cbd7c5c75abaab6b965d0a484b76fac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_15b3ecd1ac19e73f2c73c49491e62e44);
#
#
#         var popup_fb54c79074326d2f43a9423561d1ca3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf04fa39feec65a10029c60b42346dc4 = $(`&lt;div id=&quot;html_bf04fa39feec65a10029c60b42346dc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fb54c79074326d2f43a9423561d1ca3a.setContent(html_bf04fa39feec65a10029c60b42346dc4);
#
#
#
#         marker_
