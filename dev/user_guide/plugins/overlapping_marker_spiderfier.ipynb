# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abdfc8b11dcba8370c732d231af9dae5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abdfc8b11dcba8370c732d231af9dae5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abdfc8b11dcba8370c732d231af9dae5 = L.map(
#                 &quot;map_abdfc8b11dcba8370c732d231af9dae5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2da5fdb946bc31bd6083ee14929d36d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2da5fdb946bc31bd6083ee14929d36d7.addTo(map_abdfc8b11dcba8370c732d231af9dae5);
#
#
#             var marker_6480129e02f499f430f9ee7dbf1a7605 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_abdfc8b11dcba8370c732d231af9dae5);
#
#
#         var popup_b2132e46d79123f405b86e4d2e52c54a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aac8d08d9ffb14ddb79c5f5f5c9f5db5 = $(`&lt;div id=&quot;html_aac8d08d9ffb14ddb79c5f5f5c9f5db5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b2132e46d79123f405b86e4d2e52c54a.setContent(html_aac8d08d9ffb14ddb79c5f5f5c9f5db5);
#
#
#
#         marker_6480129e02f499f430f9ee7dbf1a7605.bindPopup(popup_b2132e46d79123f405b86e4d2e52c54a)
#         ;
#
#
#
#
#             var marker_c8eea1862769f8097844c1f97cc88f20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_abdfc8b11dcba8370c732d231af9dae5);
#
#
#         var popup_439117043b13f29c2cde4ccda9a39e8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62975eb4072245f064af35f4c7715ae6 = $(`&lt;div id=&quot;html_62975eb4072245f064af35f4c7715ae6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_439117043b13f29c2cde4ccda9a39e8b.setContent(html_62975eb4072245f064af35f4c7715ae6);
#
#
#
#         marker_c8eea1862769f8097844c1f97cc88f20.bindPopup(popup_439117043b13f29c2cde4ccda9a39e8b)
#         ;
#
#
#
#
#             var marker_fe3cb3410db80cc04939ecdd16701585 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_abdfc8b11dcba8370c732d231af9dae5);
#
#
#         var popup_6b91edcd2b4d929fe4ba30f40cde5d02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_502fe2ae80d815cc5fc4b96f54862c82 = $(`&lt;div id=&quot;html_502fe2ae80d815cc5fc4b96f54862c82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6b91edcd2b4d929fe4ba30f40cde5d02.setContent(html_502fe2ae80d815cc5fc4b96f54862c82);
#
#
#
#         marker_fe3cb3410db80cc04939ecdd16701585.bindPopup(popup_6b91edcd2b4d929fe4ba30f40cde5d02)
#         ;
#
#
#
#
#             var marker_30fa3d15794e061af8eab8cd73feaec9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_abdfc8b11dcba8370c732d231af9dae5);
#
#
#         var popup_a6acb34cc1759166ef24ec46da6e4d67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93ca8560ff35723ca352b27eadc9813 = $(`&lt;div id=&quot;html_f93ca8560ff35723ca352b27eadc9813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a6acb34cc1759166ef24ec46da6e4d67.setContent(html_f93ca8560ff35723ca352b27eadc9813);
#
#
#
#         marker_30fa3d15794e061af8eab8cd73feaec9.bindPopup(popup_a6acb34cc1759166ef24ec46da6e4d67)
#         ;
#
#
#
#
#             var marker_d154051202a28609b7f42bbe527e7588 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_abdfc8b11dcba8370c732d231af9dae5);
#
#
#         var popup_ac954233b5e0d53dfba8b651fbd3c8f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f24df4cd88bca06f47879198ee4f4dce = $(`&lt;div id=&quot;html_f24df4cd88bca06f47879198ee4f4dce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ac954233b5e0d53dfba8b651fbd3c8f0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e8236cb44b4969ff69706db5eddd18d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e8236cb44b4969ff69706db5eddd18d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e8236cb44b4969ff69706db5eddd18d = L.map(
#                 &quot;map_2e8236cb44b4969ff69706db5eddd18d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1322466d666b425f4e9ee1120331035c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1322466d666b425f4e9ee1120331035c.addTo(map_2e8236cb44b4969ff69706db5eddd18d);
#
#
#             var feature_group_2f94fe6f4935c10a356e99e69e94fe85 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bbe1e6a52fef22a8b85d593a39e19a53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2f94fe6f4935c10a356e99e69e94fe85);
#
#
#         var popup_2686389d6d7bb3ff00990f65d28c5b68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adf6fd2f426374498ec8dbf17d03978d = $(`&lt;div id=&quot;html_adf6fd2f426374498ec8dbf17d03978d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2686389d6d7bb3ff00990f65d28c5b68.setContent(html_adf6fd2f426374498ec8dbf17d03978d);
#
#
#
#         marker_bbe1e6a52fef22a8b85d593a39e19a53.bindPopup(popup_2686389d6d7bb3ff00990f65d28c5b68)
#         ;
#
#
#
#
#             var marker_7255f24e7989c3143cecb2bdb87c61af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2f94fe6f4935c10a356e99e69e94fe85);
#
#
#         var popup_5996c5020cc355d9ed6ab60a92550ee7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1696c3c06b139f2822efc8460c16d457 = $(`&lt;div id=&quot;html_1696c3c06b139f2822efc8460c16d457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5996c5020cc355d9ed6ab60a92550ee7.setContent(html_1696c3c06b139f2822efc8460c16d457);
#
#
#
#         marker_7255f24e7989c3143cecb2bdb87c61af.bindPopup(popup_5996c5020cc355d9ed6ab60a92550ee7)
#         ;
#
#
#
#
#             var marker_a8bb4f9dfe740732698b53cf6fac655a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2f94fe6f4935c10a356e99e69e94fe85);
#
#
#         var popup_7119f7219ec1692de5cb1e7b0f91e308 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e1ba9732677d86d367dafc116572c78 = $(`&lt;div id=&quot;html_2e1ba9732677d86d367dafc116572c78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7119f7219ec1692de5cb1e7b0f91e308.setContent(html_2e1ba9732677d86d367dafc116572c78);
#
#
#
#         marker_a8bb4f9dfe740732698b53cf6fac655a.bindPopup(popup_7119f7219ec1692de5cb1e7b0f91e308)
#         ;
#
#
#
#
#             var marker_6aa58a3f785e2eef733c41c5d2d960bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2f94fe6f4935c10a356e99e69e94fe85);
#
#
#         var popup_c9d0e1238ccc931cfd3146f8dbe70cf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a7d4c536ddfdef72f73778bc52e6ac2 = $(`&lt;div id=&quot;html_9a7d4c536ddfdef72f73778bc52e6ac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c9d0e1238ccc931cfd3146f8dbe70cf3.setContent(html_9a7d4c536ddfdef72f73778bc52e6ac2);
#
#
#
#         marker_6aa58a3f785e2eef733c41c5d2d960bf.bindPopup(popup_c9d0e1238ccc931cfd3146f8dbe70cf3)
#         ;
#
#
#
#
#             var marker_cb397f9beacff40ac0285a22658661a2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2f94fe6f4935c10a356e99e69e94fe85);
#
#
#         var popup_42304088d2adf0d3d19da8fe1a5760ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de210ad30251be8bcf133a6cf2237760 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de210ad30251be8bcf133a6cf2237760&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de210ad30251be8bcf133a6cf2237760 = L.map(
#                 &quot;map_de210ad30251be8bcf133a6cf2237760&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a1f07b6cf66b6e9a025a292faf22725 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a1f07b6cf66b6e9a025a292faf22725.addTo(map_de210ad30251be8bcf133a6cf2237760);
#
#
#             var feature_group_369a1ad2617cce95823cbd6947ee51a9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_369a1ad2617cce95823cbd6947ee51a9.addTo(map_de210ad30251be8bcf133a6cf2237760);
#
#
#             var feature_group_sub_group_c00aff4a6718214590217dddc3404b7c = L.featureGroup.subGroup(
#                 feature_group_369a1ad2617cce95823cbd6947ee51a9
#             );
#
#
#             var marker_8dcfa15bf4149dde2e09087e707c3267 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c00aff4a6718214590217dddc3404b7c);
#
#
#         var popup_3cb411ad0cf5f71526940ce08fc026ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a60458eb6e9ac026a08cd1e534b93098 = $(`&lt;div id=&quot;html_a60458eb6e9ac026a08cd1e534b93098&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3cb411ad0cf5f71526940ce08fc026ae.setContent(html_a60458eb6e9ac026a08cd1e534b93098);
#
#
#
#         marker_8dcfa15bf4149dde2e09087e707c3267.bindPopup(popup_3cb411ad0cf5f71526940ce08fc026ae)
#         ;
#
#
#
#
#             var marker_cf6367236b31908de148634613d260ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c00aff4a6718214590217dddc3404b7c);
#
#
#         var popup_cb6a91f485cf0946acf7be6768dc4c12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_549ce3d6a653afd463af2f52240faa09 = $(`&lt;div id=&quot;html_549ce3d6a653afd463af2f52240faa09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cb6a91f485cf0946acf7be6768dc4c12.setContent(html_549ce3d6a653afd463af2f52240faa09);
#
#
#
#         marker_cf6367236b31908de148634613d260ff.bindPopup(popup_cb6a91f485cf0946acf7be6768dc4c12)
#         ;
#
#
#
#
#             var marker_58d94f42b8ca7455ed3d4c852e99129e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c00aff4a6718214590217dddc3404b7c);
#
#
#         var popup_c2cfaeefdbae29f6b2053e59104ff83b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa0ee155e416e17e056e6d3c503c2d64 = $(`&lt;div id=&quot;html_aa0ee155e416e17e056e6d3c503c2d64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c2cfaeefdbae29f6b2053e59104ff83b.setContent(html_aa0ee155e416e17e056e6d3c503c2d64);
#
#
#
#         marker_58d94f42b8ca7455ed3d4c852e99129e.bindPopup(popup_c2cfaeefdbae29f6b2053e59104ff83b)
#         ;
#
#
#
#
#             var marker_cc2ec27a636146db8a3a21819516276d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c00aff4a6718214590217dddc3404b7c);
#
#
#         var popup_8801976ba62cc9519e594b310e4c01e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d10a33bf5ddc9ea6e5f2dae3d30fe5d = $(`&lt;div id=&quot;html_1d10a33bf5ddc9ea6e5f2dae3d30fe5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8801976ba62cc9519e594b310e4c01e3.setContent(html_1d10a33bf5ddc9ea6e5f2dae3d30fe5d);
#
#
#
#         marker_
