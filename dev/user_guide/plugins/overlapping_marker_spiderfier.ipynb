# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88897ae584e2cc5bb7e4d8f5dafd485b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88897ae584e2cc5bb7e4d8f5dafd485b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88897ae584e2cc5bb7e4d8f5dafd485b = L.map(
#                 &quot;map_88897ae584e2cc5bb7e4d8f5dafd485b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb0697bf8f979fbf76dd4a8c19363151 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb0697bf8f979fbf76dd4a8c19363151.addTo(map_88897ae584e2cc5bb7e4d8f5dafd485b);
#
#
#             var marker_1460916cdd944d36ff51d0c0192a73bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_88897ae584e2cc5bb7e4d8f5dafd485b);
#
#
#         var popup_886b8b9a67c7b6a0366ab0310c1d28d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7174f8b933fb7c0a8cfc6c884070ff13 = $(`&lt;div id=&quot;html_7174f8b933fb7c0a8cfc6c884070ff13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_886b8b9a67c7b6a0366ab0310c1d28d2.setContent(html_7174f8b933fb7c0a8cfc6c884070ff13);
#
#
#
#         marker_1460916cdd944d36ff51d0c0192a73bb.bindPopup(popup_886b8b9a67c7b6a0366ab0310c1d28d2)
#         ;
#
#
#
#
#             var marker_190e4fd58a66b7fa36ca09854e0f9fda = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_88897ae584e2cc5bb7e4d8f5dafd485b);
#
#
#         var popup_04839bab6e00d2381d396b0df91ec0f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9e2cee010631efd8e0e9c040f2c3627 = $(`&lt;div id=&quot;html_d9e2cee010631efd8e0e9c040f2c3627&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_04839bab6e00d2381d396b0df91ec0f0.setContent(html_d9e2cee010631efd8e0e9c040f2c3627);
#
#
#
#         marker_190e4fd58a66b7fa36ca09854e0f9fda.bindPopup(popup_04839bab6e00d2381d396b0df91ec0f0)
#         ;
#
#
#
#
#             var marker_08fd0ba9bcb3939db5cc3489828edca3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_88897ae584e2cc5bb7e4d8f5dafd485b);
#
#
#         var popup_15028688c1cb97dd64d4a21d164e2502 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d8631d13aa7ea9656bfef2ed372894e = $(`&lt;div id=&quot;html_7d8631d13aa7ea9656bfef2ed372894e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_15028688c1cb97dd64d4a21d164e2502.setContent(html_7d8631d13aa7ea9656bfef2ed372894e);
#
#
#
#         marker_08fd0ba9bcb3939db5cc3489828edca3.bindPopup(popup_15028688c1cb97dd64d4a21d164e2502)
#         ;
#
#
#
#
#             var marker_dce6dc32911d26a33b2456baabf38690 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_88897ae584e2cc5bb7e4d8f5dafd485b);
#
#
#         var popup_8e89793eeb5794b3ef35d9624b03f621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45e03e82f2ca9f3cbf7fb44ae391d6b5 = $(`&lt;div id=&quot;html_45e03e82f2ca9f3cbf7fb44ae391d6b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8e89793eeb5794b3ef35d9624b03f621.setContent(html_45e03e82f2ca9f3cbf7fb44ae391d6b5);
#
#
#
#         marker_dce6dc32911d26a33b2456baabf38690.bindPopup(popup_8e89793eeb5794b3ef35d9624b03f621)
#         ;
#
#
#
#
#             var marker_a6df837aff5e255e50eeb4caab5682b2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_88897ae584e2cc5bb7e4d8f5dafd485b);
#
#
#         var popup_d00662b634875648310e2126d2264a72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e49b61612203312649f4ddd3298b12c4 = $(`&lt;div id=&quot;html_e49b61612203312649f4ddd3298b12c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d00662b634875648310e2126d2264a72.setContent(html_e49b61612203312649f4ddd3298b12c4);
#
#
#
#         marker_a6df837aff5e255e50eeb4caab5682b2.bindPopup(popup_d00662b634875648310e2126d2264a72)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0722805d6042f7dffe28ede9c1487d51 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0722805d6042f7dffe28ede9c1487d51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0722805d6042f7dffe28ede9c1487d51 = L.map(
#                 &quot;map_0722805d6042f7dffe28ede9c1487d51&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bad6ae0f145d298aed3922227f55f38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8bad6ae0f145d298aed3922227f55f38.addTo(map_0722805d6042f7dffe28ede9c1487d51);
#
#
#             var feature_group_86d536b69f52dfc2ffde23cec4ea2d1e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_02bacbb31c4651c73602476444c19206 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_86d536b69f52dfc2ffde23cec4ea2d1e);
#
#
#         var popup_507659e8641dc04b3ff07549e23e21c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a31273c3eff0f1dbde53ca9c1ee8c849 = $(`&lt;div id=&quot;html_a31273c3eff0f1dbde53ca9c1ee8c849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_507659e8641dc04b3ff07549e23e21c5.setContent(html_a31273c3eff0f1dbde53ca9c1ee8c849);
#
#
#
#         marker_02bacbb31c4651c73602476444c19206.bindPopup(popup_507659e8641dc04b3ff07549e23e21c5)
#         ;
#
#
#
#
#             var marker_aa517a005d9c3a372ba01ca64947a99e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_86d536b69f52dfc2ffde23cec4ea2d1e);
#
#
#         var popup_45af632ed908260fd6e782c31eef5491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3ca3561a6b2895eb9d59d304b496667 = $(`&lt;div id=&quot;html_b3ca3561a6b2895eb9d59d304b496667&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_45af632ed908260fd6e782c31eef5491.setContent(html_b3ca3561a6b2895eb9d59d304b496667);
#
#
#
#         marker_aa517a005d9c3a372ba01ca64947a99e.bindPopup(popup_45af632ed908260fd6e782c31eef5491)
#         ;
#
#
#
#
#             var marker_ff8b0ee97843c0a14973a896396f2c10 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_86d536b69f52dfc2ffde23cec4ea2d1e);
#
#
#         var popup_ac84bde436177b30f1d000d93b1a89fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9244bde1996917beef67c8e9d629385a = $(`&lt;div id=&quot;html_9244bde1996917beef67c8e9d629385a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ac84bde436177b30f1d000d93b1a89fe.setContent(html_9244bde1996917beef67c8e9d629385a);
#
#
#
#         marker_ff8b0ee97843c0a14973a896396f2c10.bindPopup(popup_ac84bde436177b30f1d000d93b1a89fe)
#         ;
#
#
#
#
#             var marker_ad16e6b846cf46af6a403900e7ad9fca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_86d536b69f52dfc2ffde23cec4ea2d1e);
#
#
#         var popup_ec46b5d4d2a373c63f7a9df8b304d622 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab0bc7d7bc95b52a17c4e8f86c56c512 = $(`&lt;div id=&quot;html_ab0bc7d7bc95b52a17c4e8f86c56c512&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ec46b5d4d2a373c63f7a9df8b304d622.setContent(html_ab0bc7d7bc95b52a17c4e8f86c56c512);
#
#
#
#         marker_ad16e6b846cf46af6a403900e7ad9fca.bindPopup(popup_ec46b5d4d2a373c63f7a9df8b304d622)
#         ;
#
#
#
#
#             var marker_fcf48103b1d974ef44b685a063ffc2bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_86d536b69f52dfc2ffde23cec4ea2d1e);
#
#
#         var popup_48b997751e61175df81488558ba3d28a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02524a6302c68b09bca85e2e5105d6c7 = $(`&lt;div id=&quot;html_02524a6302c68b09bca85e2e5105d6c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f6b558d35bb69d05f171fd1008a100c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f6b558d35bb69d05f171fd1008a100c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f6b558d35bb69d05f171fd1008a100c = L.map(
#                 &quot;map_7f6b558d35bb69d05f171fd1008a100c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_706e9b394e4c51e2de00b63eaeb55eb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_706e9b394e4c51e2de00b63eaeb55eb6.addTo(map_7f6b558d35bb69d05f171fd1008a100c);
#
#
#             var feature_group_1d4efe1521d5ad45d052d336fa669a9b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1d4efe1521d5ad45d052d336fa669a9b.addTo(map_7f6b558d35bb69d05f171fd1008a100c);
#
#
#             var feature_group_sub_group_6740a971bd7fad8768d153b506138725 = L.featureGroup.subGroup(
#                 feature_group_1d4efe1521d5ad45d052d336fa669a9b
#             );
#
#
#             var marker_5e539e4ec51e42ab93e31e06b210da1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6740a971bd7fad8768d153b506138725);
#
#
#         var popup_c3f405fd4b41e0afb376451c6246a9ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_713d43ec1aa529009913d044798aaad3 = $(`&lt;div id=&quot;html_713d43ec1aa529009913d044798aaad3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c3f405fd4b41e0afb376451c6246a9ca.setContent(html_713d43ec1aa529009913d044798aaad3);
#
#
#
#         marker_5e539e4ec51e42ab93e31e06b210da1f.bindPopup(popup_c3f405fd4b41e0afb376451c6246a9ca)
#         ;
#
#
#
#
#             var marker_50a2a9f2d075238b2a487c2ab5b063b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6740a971bd7fad8768d153b506138725);
#
#
#         var popup_719f2d96454c4c3d00d7c6620b5025c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fb086e3aca1af4527767725a0d01775 = $(`&lt;div id=&quot;html_7fb086e3aca1af4527767725a0d01775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_719f2d96454c4c3d00d7c6620b5025c7.setContent(html_7fb086e3aca1af4527767725a0d01775);
#
#
#
#         marker_50a2a9f2d075238b2a487c2ab5b063b3.bindPopup(popup_719f2d96454c4c3d00d7c6620b5025c7)
#         ;
#
#
#
#
#             var marker_7e4d647ed0f17ba7fc1ac292c20bd2b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6740a971bd7fad8768d153b506138725);
#
#
#         var popup_e9ac8b05677f3c6fa9df76caeb842f89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c10e3244f78162da71731562d0d8b863 = $(`&lt;div id=&quot;html_c10e3244f78162da71731562d0d8b863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e9ac8b05677f3c6fa9df76caeb842f89.setContent(html_c10e3244f78162da71731562d0d8b863);
#
#
#
#         marker_7e4d647ed0f17ba7fc1ac292c20bd2b1.bindPopup(popup_e9ac8b05677f3c6fa9df76caeb842f89)
#         ;
#
#
#
#
#             var marker_0f3ea85656ab8a507637318e1cdd61b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6740a971bd7fad8768d153b506138725);
#
#
#         var popup_6c4dd36605376a20c12dedfeabc2e31e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7f8941d0f731df0d3964c2ce9c3363f = $(`&lt;div id=&quot;html_a7f8941d0f731df0d3964c2ce9c3363f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6c4dd36605376a20c12dedfeabc2e31e.setContent(html_a7f8941d0f731df0d3964c2ce9c3363f);
#
#
#
#         marker_0f3ea85656ab8a507637318e1cdd61b5.bindPopup(popup_6c4dd36605376a20c12dedfeabc2e31e)
#         ;
#
#
#
#
#             var marker_311523d44c1e9195ce72a383bdd989c9 = L.marker(
#                 [45.0503999
