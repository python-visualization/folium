# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3943f674a143b77588ca4ff18414cd4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3943f674a143b77588ca4ff18414cd4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3943f674a143b77588ca4ff18414cd4d = L.map(
#                 &quot;map_3943f674a143b77588ca4ff18414cd4d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c2ed20b7f428e37ca7a198f4fdfa29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6c2ed20b7f428e37ca7a198f4fdfa29.addTo(map_3943f674a143b77588ca4ff18414cd4d);
#
#
#             var marker_82a9502933578cbb6043193088b7808c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3943f674a143b77588ca4ff18414cd4d);
#
#
#         var popup_cede5880287c8c4a427f42385ebe5a67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86b5cc6353a1331a27c060fc8b32fd1a = $(`&lt;div id=&quot;html_86b5cc6353a1331a27c060fc8b32fd1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cede5880287c8c4a427f42385ebe5a67.setContent(html_86b5cc6353a1331a27c060fc8b32fd1a);
#
#
#
#         marker_82a9502933578cbb6043193088b7808c.bindPopup(popup_cede5880287c8c4a427f42385ebe5a67)
#         ;
#
#
#
#
#             var marker_4f32cffe4c768a18e81bd7f93d815b8b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3943f674a143b77588ca4ff18414cd4d);
#
#
#         var popup_c9babb13d440af69e1a398da8d976812 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c852942e452a187156ce383e98563be9 = $(`&lt;div id=&quot;html_c852942e452a187156ce383e98563be9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c9babb13d440af69e1a398da8d976812.setContent(html_c852942e452a187156ce383e98563be9);
#
#
#
#         marker_4f32cffe4c768a18e81bd7f93d815b8b.bindPopup(popup_c9babb13d440af69e1a398da8d976812)
#         ;
#
#
#
#
#             var marker_ccd13a94cc60730875548bae814e8cfd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3943f674a143b77588ca4ff18414cd4d);
#
#
#         var popup_e46551d1f7ea6dccfee6dc01d5165eab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ec7abef21e0d81a3ef53d0787432d5f = $(`&lt;div id=&quot;html_1ec7abef21e0d81a3ef53d0787432d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e46551d1f7ea6dccfee6dc01d5165eab.setContent(html_1ec7abef21e0d81a3ef53d0787432d5f);
#
#
#
#         marker_ccd13a94cc60730875548bae814e8cfd.bindPopup(popup_e46551d1f7ea6dccfee6dc01d5165eab)
#         ;
#
#
#
#
#             var marker_bf44490de5cf58726c3b728cd51e715f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3943f674a143b77588ca4ff18414cd4d);
#
#
#         var popup_30e1846d4f4a9aeae69bcd6903b72f87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68add33f851078fcc04e3af5491853fc = $(`&lt;div id=&quot;html_68add33f851078fcc04e3af5491853fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_30e1846d4f4a9aeae69bcd6903b72f87.setContent(html_68add33f851078fcc04e3af5491853fc);
#
#
#
#         marker_bf44490de5cf58726c3b728cd51e715f.bindPopup(popup_30e1846d4f4a9aeae69bcd6903b72f87)
#         ;
#
#
#
#
#             var marker_b9865b3916c4e128ea364299a665dd8a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3943f674a143b77588ca4ff18414cd4d);
#
#
#         var popup_fdcfabb8995d76691fbd9a20cee145a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca078152dd0590f4a3df6a7b632c6bfe = $(`&lt;div id=&quot;html_ca078152dd0590f4a3df6a7b632c6bfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fdcfabb8995d76691fbd9a20cee145a8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8411d37c533194fbdfc881c09601de02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8411d37c533194fbdfc881c09601de02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8411d37c533194fbdfc881c09601de02 = L.map(
#                 &quot;map_8411d37c533194fbdfc881c09601de02&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c0e141cbd8f9c4049d83c1e826d02c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c0e141cbd8f9c4049d83c1e826d02c3.addTo(map_8411d37c533194fbdfc881c09601de02);
#
#
#             var feature_group_9ef42d4e315cd520ce72cbc1a472f79a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ccd1af172ef4d5eddab89309168588b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9ef42d4e315cd520ce72cbc1a472f79a);
#
#
#         var popup_ea20e8a2d03a9ca785ee4456dc61a0b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc88d12773eabf54ba018bccb3edd93e = $(`&lt;div id=&quot;html_bc88d12773eabf54ba018bccb3edd93e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ea20e8a2d03a9ca785ee4456dc61a0b8.setContent(html_bc88d12773eabf54ba018bccb3edd93e);
#
#
#
#         marker_9ccd1af172ef4d5eddab89309168588b.bindPopup(popup_ea20e8a2d03a9ca785ee4456dc61a0b8)
#         ;
#
#
#
#
#             var marker_10b4e42a7bd2f2511ce65781c30cebea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9ef42d4e315cd520ce72cbc1a472f79a);
#
#
#         var popup_623f661f5421db1bf35bfb9e56af6487 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec9f6254daf64cc9c9524d1e29a77210 = $(`&lt;div id=&quot;html_ec9f6254daf64cc9c9524d1e29a77210&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_623f661f5421db1bf35bfb9e56af6487.setContent(html_ec9f6254daf64cc9c9524d1e29a77210);
#
#
#
#         marker_10b4e42a7bd2f2511ce65781c30cebea.bindPopup(popup_623f661f5421db1bf35bfb9e56af6487)
#         ;
#
#
#
#
#             var marker_1a854a83717e6f4502f96a3edeb2eb4a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9ef42d4e315cd520ce72cbc1a472f79a);
#
#
#         var popup_a03073118ef9364e1d49b55fdf25f36e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_674c58e42d85f574e7d24888062fb3a9 = $(`&lt;div id=&quot;html_674c58e42d85f574e7d24888062fb3a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a03073118ef9364e1d49b55fdf25f36e.setContent(html_674c58e42d85f574e7d24888062fb3a9);
#
#
#
#         marker_1a854a83717e6f4502f96a3edeb2eb4a.bindPopup(popup_a03073118ef9364e1d49b55fdf25f36e)
#         ;
#
#
#
#
#             var marker_daaccd02eb01591110642d44420104b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9ef42d4e315cd520ce72cbc1a472f79a);
#
#
#         var popup_72553ced74f92d6429f00a2d2e3dc184 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea606b05a7901d7f070718846b0ac318 = $(`&lt;div id=&quot;html_ea606b05a7901d7f070718846b0ac318&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_72553ced74f92d6429f00a2d2e3dc184.setContent(html_ea606b05a7901d7f070718846b0ac318);
#
#
#
#         marker_daaccd02eb01591110642d44420104b6.bindPopup(popup_72553ced74f92d6429f00a2d2e3dc184)
#         ;
#
#
#
#
#             var marker_8fc19f150e7ff95ca56dc2dc3d0f1bfe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9ef42d4e315cd520ce72cbc1a472f79a);
#
#
#         var popup_2dede41bb50c596c8c81e093ba5a9ea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc48e5944b477134419f6dfd88ca7c30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc48e5944b477134419f6dfd88ca7c30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc48e5944b477134419f6dfd88ca7c30 = L.map(
#                 &quot;map_bc48e5944b477134419f6dfd88ca7c30&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c8e890891f7bfec963b9a0d894fdc1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c8e890891f7bfec963b9a0d894fdc1f.addTo(map_bc48e5944b477134419f6dfd88ca7c30);
#
#
#             var feature_group_7752bf9e65491906d7aa226856876e36 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7752bf9e65491906d7aa226856876e36.addTo(map_bc48e5944b477134419f6dfd88ca7c30);
#
#
#             var feature_group_sub_group_9f867593a8cc965aa070319baf95c86a = L.featureGroup.subGroup(
#                 feature_group_7752bf9e65491906d7aa226856876e36
#             );
#
#
#             var marker_a7819afd4c843fc0fd7b212d18a46d18 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f867593a8cc965aa070319baf95c86a);
#
#
#         var popup_1f74d5cf10a10c9c68b65ee70f8d8b5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71e3fa00c795b5d8b5a3f3b06d99089c = $(`&lt;div id=&quot;html_71e3fa00c795b5d8b5a3f3b06d99089c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1f74d5cf10a10c9c68b65ee70f8d8b5c.setContent(html_71e3fa00c795b5d8b5a3f3b06d99089c);
#
#
#
#         marker_a7819afd4c843fc0fd7b212d18a46d18.bindPopup(popup_1f74d5cf10a10c9c68b65ee70f8d8b5c)
#         ;
#
#
#
#
#             var marker_ea6d17e7bb8894bc7f479186e9a9f8c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f867593a8cc965aa070319baf95c86a);
#
#
#         var popup_721abcd014f1484624a61def349189d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f8f163fd1ae5dc849bc62d77b12f924 = $(`&lt;div id=&quot;html_3f8f163fd1ae5dc849bc62d77b12f924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_721abcd014f1484624a61def349189d1.setContent(html_3f8f163fd1ae5dc849bc62d77b12f924);
#
#
#
#         marker_ea6d17e7bb8894bc7f479186e9a9f8c5.bindPopup(popup_721abcd014f1484624a61def349189d1)
#         ;
#
#
#
#
#             var marker_445f7c72d8c7a4961e7ae23cb0958957 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f867593a8cc965aa070319baf95c86a);
#
#
#         var popup_f9044758ffcdeea7fd4a8ad07e40ce01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bae85d776fcb36fdb713da3b482b2640 = $(`&lt;div id=&quot;html_bae85d776fcb36fdb713da3b482b2640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f9044758ffcdeea7fd4a8ad07e40ce01.setContent(html_bae85d776fcb36fdb713da3b482b2640);
#
#
#
#         marker_445f7c72d8c7a4961e7ae23cb0958957.bindPopup(popup_f9044758ffcdeea7fd4a8ad07e40ce01)
#         ;
#
#
#
#
#             var marker_b4306c726b74265f6ef22202423128a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9f867593a8cc965aa070319baf95c86a);
#
#
#         var popup_1f8eb1fffef85f412d1a3e42c2e8e4ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dd9b613e1d8011d7d3a669efdbaa133 = $(`&lt;div id=&quot;html_8dd9b613e1d8011d7d3a669efdbaa133&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1f8eb1fffef85f412d1a3e42c2e8e4ee.setContent(html_8dd9b613e1d8011d7d3a669efdbaa133);
#
#
#
#         marker_
