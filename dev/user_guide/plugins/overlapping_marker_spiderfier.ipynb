# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65bca0a5c739464cba2e9cb5aa95bdd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65bca0a5c739464cba2e9cb5aa95bdd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65bca0a5c739464cba2e9cb5aa95bdd0 = L.map(
#                 &quot;map_65bca0a5c739464cba2e9cb5aa95bdd0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76716a102d6e42dc7e37a5e98647c0ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76716a102d6e42dc7e37a5e98647c0ad.addTo(map_65bca0a5c739464cba2e9cb5aa95bdd0);
#
#
#             var marker_4b45340a7674213556bdc407dc039888 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_65bca0a5c739464cba2e9cb5aa95bdd0);
#
#
#         var popup_a40b89c9f6f3c1f892c3241332404aa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a68e501719424158ed7468bb5984e281 = $(`&lt;div id=&quot;html_a68e501719424158ed7468bb5984e281&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a40b89c9f6f3c1f892c3241332404aa1.setContent(html_a68e501719424158ed7468bb5984e281);
#
#
#
#         marker_4b45340a7674213556bdc407dc039888.bindPopup(popup_a40b89c9f6f3c1f892c3241332404aa1)
#         ;
#
#
#
#
#             var marker_39cd4e9c7dbcf6ee2024ed8d2335263c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_65bca0a5c739464cba2e9cb5aa95bdd0);
#
#
#         var popup_f73fa298eafd26d94631cc68f9e99222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f882d0813b92d3bf4a8a114cbe9b22b5 = $(`&lt;div id=&quot;html_f882d0813b92d3bf4a8a114cbe9b22b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f73fa298eafd26d94631cc68f9e99222.setContent(html_f882d0813b92d3bf4a8a114cbe9b22b5);
#
#
#
#         marker_39cd4e9c7dbcf6ee2024ed8d2335263c.bindPopup(popup_f73fa298eafd26d94631cc68f9e99222)
#         ;
#
#
#
#
#             var marker_d3abecf6d27ffb398c4aecaba2a7188d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_65bca0a5c739464cba2e9cb5aa95bdd0);
#
#
#         var popup_931218ea7706fbc685ffbf9e63bbfb52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc9604913f07e31ad8153337762c4fde = $(`&lt;div id=&quot;html_fc9604913f07e31ad8153337762c4fde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_931218ea7706fbc685ffbf9e63bbfb52.setContent(html_fc9604913f07e31ad8153337762c4fde);
#
#
#
#         marker_d3abecf6d27ffb398c4aecaba2a7188d.bindPopup(popup_931218ea7706fbc685ffbf9e63bbfb52)
#         ;
#
#
#
#
#             var marker_317d5e99ec0f7d120ac9f94714dfcc8c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_65bca0a5c739464cba2e9cb5aa95bdd0);
#
#
#         var popup_a2be378def340270009e2ec61e406fe9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d174a1bb89d9bafd7248faf77a499ea2 = $(`&lt;div id=&quot;html_d174a1bb89d9bafd7248faf77a499ea2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a2be378def340270009e2ec61e406fe9.setContent(html_d174a1bb89d9bafd7248faf77a499ea2);
#
#
#
#         marker_317d5e99ec0f7d120ac9f94714dfcc8c.bindPopup(popup_a2be378def340270009e2ec61e406fe9)
#         ;
#
#
#
#
#             var marker_5daa6953cb9eee52a6c4c5eaa8479e48 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_65bca0a5c739464cba2e9cb5aa95bdd0);
#
#
#         var popup_997be13ec29a7d27607959621a450a04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2f42762690b0a9cb753191df4ee2d53 = $(`&lt;div id=&quot;html_e2f42762690b0a9cb753191df4ee2d53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_997be13ec29a7d27607959621a450a04.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a21253f78b0b48b675a5b8789e3ceb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a21253f78b0b48b675a5b8789e3ceb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a21253f78b0b48b675a5b8789e3ceb1 = L.map(
#                 &quot;map_5a21253f78b0b48b675a5b8789e3ceb1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_067769bdb871b7b1b1470b1ff1be01a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_067769bdb871b7b1b1470b1ff1be01a1.addTo(map_5a21253f78b0b48b675a5b8789e3ceb1);
#
#
#             var feature_group_624f5b664a771844cb16664cbd3081e9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b06b9115c016d003ff3b96dbb1b47bf8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_624f5b664a771844cb16664cbd3081e9);
#
#
#         var popup_3a3fb49604cbf837b4e55637122e881d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe7f8d466e54f533c166dec033185a0d = $(`&lt;div id=&quot;html_fe7f8d466e54f533c166dec033185a0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3a3fb49604cbf837b4e55637122e881d.setContent(html_fe7f8d466e54f533c166dec033185a0d);
#
#
#
#         marker_b06b9115c016d003ff3b96dbb1b47bf8.bindPopup(popup_3a3fb49604cbf837b4e55637122e881d)
#         ;
#
#
#
#
#             var marker_d4c77c56face158e947aa3b8d2897eed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_624f5b664a771844cb16664cbd3081e9);
#
#
#         var popup_7ca8c9a22cfd225547d308cbc50d58a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_329709b88bde05a84ace533b88872c4a = $(`&lt;div id=&quot;html_329709b88bde05a84ace533b88872c4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7ca8c9a22cfd225547d308cbc50d58a7.setContent(html_329709b88bde05a84ace533b88872c4a);
#
#
#
#         marker_d4c77c56face158e947aa3b8d2897eed.bindPopup(popup_7ca8c9a22cfd225547d308cbc50d58a7)
#         ;
#
#
#
#
#             var marker_99b01264bfe587dae9dd7902de12777c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_624f5b664a771844cb16664cbd3081e9);
#
#
#         var popup_6e6577deca527c78574f57229bf33218 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48b27a53a55b8a0acd52a9c340ea5afd = $(`&lt;div id=&quot;html_48b27a53a55b8a0acd52a9c340ea5afd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6e6577deca527c78574f57229bf33218.setContent(html_48b27a53a55b8a0acd52a9c340ea5afd);
#
#
#
#         marker_99b01264bfe587dae9dd7902de12777c.bindPopup(popup_6e6577deca527c78574f57229bf33218)
#         ;
#
#
#
#
#             var marker_b107ea09865f8e1bf0a94ac7d1c4a800 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_624f5b664a771844cb16664cbd3081e9);
#
#
#         var popup_5ae8828176c24ad2add7dc4dae1b3199 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5975ad0a966f2a3b26932382b4951433 = $(`&lt;div id=&quot;html_5975ad0a966f2a3b26932382b4951433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ae8828176c24ad2add7dc4dae1b3199.setContent(html_5975ad0a966f2a3b26932382b4951433);
#
#
#
#         marker_b107ea09865f8e1bf0a94ac7d1c4a800.bindPopup(popup_5ae8828176c24ad2add7dc4dae1b3199)
#         ;
#
#
#
#
#             var marker_80fbc0431cfc5725949c87491be4fa30 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_624f5b664a771844cb16664cbd3081e9);
#
#
#         var popup_300b0c2ea8dbb8b7e19f63641b3fc79c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac3befd8a80e9b4a6a9503382e184303 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac3befd8a80e9b4a6a9503382e184303&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac3befd8a80e9b4a6a9503382e184303 = L.map(
#                 &quot;map_ac3befd8a80e9b4a6a9503382e184303&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f588812c0cab56fe30408cf375a128a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f588812c0cab56fe30408cf375a128a.addTo(map_ac3befd8a80e9b4a6a9503382e184303);
#
#
#             var feature_group_68047f6b1dd5b5b6ca515159ed67394b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_68047f6b1dd5b5b6ca515159ed67394b.addTo(map_ac3befd8a80e9b4a6a9503382e184303);
#
#
#             var feature_group_sub_group_2f82c575030dc33fbc2b8d51652f1967 = L.featureGroup.subGroup(
#                 feature_group_68047f6b1dd5b5b6ca515159ed67394b
#             );
#
#
#             var marker_17517a069939d8e8d8718f79b0be9cde = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f82c575030dc33fbc2b8d51652f1967);
#
#
#         var popup_1a14a37370b6addf878aad3e4697e03b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52d05b0be1808c88d11976ed22b036cf = $(`&lt;div id=&quot;html_52d05b0be1808c88d11976ed22b036cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1a14a37370b6addf878aad3e4697e03b.setContent(html_52d05b0be1808c88d11976ed22b036cf);
#
#
#
#         marker_17517a069939d8e8d8718f79b0be9cde.bindPopup(popup_1a14a37370b6addf878aad3e4697e03b)
#         ;
#
#
#
#
#             var marker_a13fd058d1d24af78305bb4132963f4b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f82c575030dc33fbc2b8d51652f1967);
#
#
#         var popup_50baa71c209cdc7ba6c332e2e3732d10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9e112a2ddd35eeed4f7c8914cc96c12 = $(`&lt;div id=&quot;html_b9e112a2ddd35eeed4f7c8914cc96c12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_50baa71c209cdc7ba6c332e2e3732d10.setContent(html_b9e112a2ddd35eeed4f7c8914cc96c12);
#
#
#
#         marker_a13fd058d1d24af78305bb4132963f4b.bindPopup(popup_50baa71c209cdc7ba6c332e2e3732d10)
#         ;
#
#
#
#
#             var marker_66f8d53e5d480a38f746f55084b34c6f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f82c575030dc33fbc2b8d51652f1967);
#
#
#         var popup_9f02761883972b4ff1ab73879fba7f08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be2f043970fe889f7c4be030445eb0bc = $(`&lt;div id=&quot;html_be2f043970fe889f7c4be030445eb0bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9f02761883972b4ff1ab73879fba7f08.setContent(html_be2f043970fe889f7c4be030445eb0bc);
#
#
#
#         marker_66f8d53e5d480a38f746f55084b34c6f.bindPopup(popup_9f02761883972b4ff1ab73879fba7f08)
#         ;
#
#
#
#
#             var marker_c29ba113e24b97930edf45210099d837 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f82c575030dc33fbc2b8d51652f1967);
#
#
#         var popup_c9e44c70a663fbdd6553b474ead7cf72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ed3607ba6a97bdaab626d658622f727 = $(`&lt;div id=&quot;html_8ed3607ba6a97bdaab626d658622f727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c9e44c70a663fbdd6553b474ead7cf72.setContent(html_8ed3607ba6a97bdaab626d658622f727);
#
#
#
#         marker_
