# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41f6c9654bb8a17c2a4749abd7325024 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41f6c9654bb8a17c2a4749abd7325024&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41f6c9654bb8a17c2a4749abd7325024 = L.map(
#                 &quot;map_41f6c9654bb8a17c2a4749abd7325024&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_798b270c3dd7b65f3ee15c0edda47e81 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_798b270c3dd7b65f3ee15c0edda47e81.addTo(map_41f6c9654bb8a17c2a4749abd7325024);
#
#
#             var marker_3f54a4f2daed58da8096bc0689b3ae06 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_41f6c9654bb8a17c2a4749abd7325024);
#
#
#         var popup_d8727f420fc6ab7647ea81935c6c2667 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9dea6f381b9c1c6bb442d91185ae1c7 = $(`&lt;div id=&quot;html_e9dea6f381b9c1c6bb442d91185ae1c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d8727f420fc6ab7647ea81935c6c2667.setContent(html_e9dea6f381b9c1c6bb442d91185ae1c7);
#
#
#
#         marker_3f54a4f2daed58da8096bc0689b3ae06.bindPopup(popup_d8727f420fc6ab7647ea81935c6c2667)
#         ;
#
#
#
#
#             var marker_fe7f840b9c1707ddf464945ded35b362 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_41f6c9654bb8a17c2a4749abd7325024);
#
#
#         var popup_92ff2a1f2752c76c93e67e3616c54d4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02c7ec47a62ea6925e932b8c4c53828f = $(`&lt;div id=&quot;html_02c7ec47a62ea6925e932b8c4c53828f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_92ff2a1f2752c76c93e67e3616c54d4b.setContent(html_02c7ec47a62ea6925e932b8c4c53828f);
#
#
#
#         marker_fe7f840b9c1707ddf464945ded35b362.bindPopup(popup_92ff2a1f2752c76c93e67e3616c54d4b)
#         ;
#
#
#
#
#             var marker_7f236a4e1cad8bf93f41ea0b3e390456 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_41f6c9654bb8a17c2a4749abd7325024);
#
#
#         var popup_9e1e5ffb9d86adbf7dff668d221a3811 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72471fefa9efd6582a4da8f9d39ddd01 = $(`&lt;div id=&quot;html_72471fefa9efd6582a4da8f9d39ddd01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9e1e5ffb9d86adbf7dff668d221a3811.setContent(html_72471fefa9efd6582a4da8f9d39ddd01);
#
#
#
#         marker_7f236a4e1cad8bf93f41ea0b3e390456.bindPopup(popup_9e1e5ffb9d86adbf7dff668d221a3811)
#         ;
#
#
#
#
#             var marker_ea68b0bef16c67216ee40e021df5bbca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_41f6c9654bb8a17c2a4749abd7325024);
#
#
#         var popup_f80c4a7fc075945b171c65cf8453c166 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1d0d9d5b45eb394045e7a9cf9945042 = $(`&lt;div id=&quot;html_d1d0d9d5b45eb394045e7a9cf9945042&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f80c4a7fc075945b171c65cf8453c166.setContent(html_d1d0d9d5b45eb394045e7a9cf9945042);
#
#
#
#         marker_ea68b0bef16c67216ee40e021df5bbca.bindPopup(popup_f80c4a7fc075945b171c65cf8453c166)
#         ;
#
#
#
#
#             var marker_346fa8100f31ba6ef08a709d652b3b71 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_41f6c9654bb8a17c2a4749abd7325024);
#
#
#         var popup_d2194531ce1756906e585fd7368f9fc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c109ee5fee3c5f7cf4131240699eb009 = $(`&lt;div id=&quot;html_c109ee5fee3c5f7cf4131240699eb009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d2194531ce1756906e585fd7368f9fc7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_596bf79780c0cac1a0fb8c35da80f7ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_596bf79780c0cac1a0fb8c35da80f7ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_596bf79780c0cac1a0fb8c35da80f7ac = L.map(
#                 &quot;map_596bf79780c0cac1a0fb8c35da80f7ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eaa5edf6d0935e6441b7b0a3838df2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8eaa5edf6d0935e6441b7b0a3838df2f.addTo(map_596bf79780c0cac1a0fb8c35da80f7ac);
#
#
#             var feature_group_774942aef044b848b1d351b05eb82904 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a4d65e5a9d64a4f36499b7d9037251a5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_774942aef044b848b1d351b05eb82904);
#
#
#         var popup_ed7465e959bf011923e48bedfed1fe42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23c416ec9d3d689bf3fd3b5f86e230c3 = $(`&lt;div id=&quot;html_23c416ec9d3d689bf3fd3b5f86e230c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ed7465e959bf011923e48bedfed1fe42.setContent(html_23c416ec9d3d689bf3fd3b5f86e230c3);
#
#
#
#         marker_a4d65e5a9d64a4f36499b7d9037251a5.bindPopup(popup_ed7465e959bf011923e48bedfed1fe42)
#         ;
#
#
#
#
#             var marker_40bee9e354c17c1ba0986c933fdbad5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_774942aef044b848b1d351b05eb82904);
#
#
#         var popup_50f46c244e4a2e22e74fbf8350fed842 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f141b5f08d3d014c4b47c5a7c9b43861 = $(`&lt;div id=&quot;html_f141b5f08d3d014c4b47c5a7c9b43861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_50f46c244e4a2e22e74fbf8350fed842.setContent(html_f141b5f08d3d014c4b47c5a7c9b43861);
#
#
#
#         marker_40bee9e354c17c1ba0986c933fdbad5d.bindPopup(popup_50f46c244e4a2e22e74fbf8350fed842)
#         ;
#
#
#
#
#             var marker_5f2d82b728aae51e0800cafee1a46a2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_774942aef044b848b1d351b05eb82904);
#
#
#         var popup_b8f71838c7d04a1fb40d4d2f7dc36d95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e1981b5713c1b4ba3f774d75f523cbe = $(`&lt;div id=&quot;html_1e1981b5713c1b4ba3f774d75f523cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b8f71838c7d04a1fb40d4d2f7dc36d95.setContent(html_1e1981b5713c1b4ba3f774d75f523cbe);
#
#
#
#         marker_5f2d82b728aae51e0800cafee1a46a2d.bindPopup(popup_b8f71838c7d04a1fb40d4d2f7dc36d95)
#         ;
#
#
#
#
#             var marker_7c95a7172eb303953e2f4ecd2a6b3025 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_774942aef044b848b1d351b05eb82904);
#
#
#         var popup_ce4e8b1d475be159c166e6ab1ad88535 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_862e9e23437f3750ad867b3a9bac4aa2 = $(`&lt;div id=&quot;html_862e9e23437f3750ad867b3a9bac4aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ce4e8b1d475be159c166e6ab1ad88535.setContent(html_862e9e23437f3750ad867b3a9bac4aa2);
#
#
#
#         marker_7c95a7172eb303953e2f4ecd2a6b3025.bindPopup(popup_ce4e8b1d475be159c166e6ab1ad88535)
#         ;
#
#
#
#
#             var marker_3dd9e52ee135ba0c5d8addc2d90b9fb0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_774942aef044b848b1d351b05eb82904);
#
#
#         var popup_2a67cf6be5a1b0dd047ad3ed3d523568 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf7b5792fe2c3bad6c4eb7264e22d63f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf7b5792fe2c3bad6c4eb7264e22d63f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf7b5792fe2c3bad6c4eb7264e22d63f = L.map(
#                 &quot;map_cf7b5792fe2c3bad6c4eb7264e22d63f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca3f70464281b20240fcb7f2e4a3b0d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca3f70464281b20240fcb7f2e4a3b0d0.addTo(map_cf7b5792fe2c3bad6c4eb7264e22d63f);
#
#
#             var feature_group_5fc448dbab7d27829bc3b26b4da9e4eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5fc448dbab7d27829bc3b26b4da9e4eb.addTo(map_cf7b5792fe2c3bad6c4eb7264e22d63f);
#
#
#             var feature_group_sub_group_1c95f574204b060cfc8b9971f39bb320 = L.featureGroup.subGroup(
#                 feature_group_5fc448dbab7d27829bc3b26b4da9e4eb
#             );
#
#
#             var marker_8e59d7cb8499a7a740a8168b00375a71 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c95f574204b060cfc8b9971f39bb320);
#
#
#         var popup_5a6b6a0f83b239cceb8cdf36a46be9ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f2b84421a38b7c3b31fa3820d13dd6f = $(`&lt;div id=&quot;html_1f2b84421a38b7c3b31fa3820d13dd6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5a6b6a0f83b239cceb8cdf36a46be9ef.setContent(html_1f2b84421a38b7c3b31fa3820d13dd6f);
#
#
#
#         marker_8e59d7cb8499a7a740a8168b00375a71.bindPopup(popup_5a6b6a0f83b239cceb8cdf36a46be9ef)
#         ;
#
#
#
#
#             var marker_84844deb18b2769c8cb795ec6174173b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c95f574204b060cfc8b9971f39bb320);
#
#
#         var popup_ccf2b79cbeb5ca1dcddda9ee80fb26ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d1576b27b1d3d3e70db33c3c3edf9f = $(`&lt;div id=&quot;html_c7d1576b27b1d3d3e70db33c3c3edf9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ccf2b79cbeb5ca1dcddda9ee80fb26ae.setContent(html_c7d1576b27b1d3d3e70db33c3c3edf9f);
#
#
#
#         marker_84844deb18b2769c8cb795ec6174173b.bindPopup(popup_ccf2b79cbeb5ca1dcddda9ee80fb26ae)
#         ;
#
#
#
#
#             var marker_3e77ed8a473dff3aef34fe503aad3ee5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c95f574204b060cfc8b9971f39bb320);
#
#
#         var popup_53d483689be4fd74df82ffa403e627b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b63e8e9a4f4193031a21a54253bbf377 = $(`&lt;div id=&quot;html_b63e8e9a4f4193031a21a54253bbf377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_53d483689be4fd74df82ffa403e627b7.setContent(html_b63e8e9a4f4193031a21a54253bbf377);
#
#
#
#         marker_3e77ed8a473dff3aef34fe503aad3ee5.bindPopup(popup_53d483689be4fd74df82ffa403e627b7)
#         ;
#
#
#
#
#             var marker_04858a8d7724504a204481722765ff05 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c95f574204b060cfc8b9971f39bb320);
#
#
#         var popup_df126f8c878c2d3bcf10da1bf950b229 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca45f67a6fd3b8a7aa83eec535a87693 = $(`&lt;div id=&quot;html_ca45f67a6fd3b8a7aa83eec535a87693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_df126f8c878c2d3bcf10da1bf950b229.setContent(html_ca45f67a6fd3b8a7aa83eec535a87693);
#
#
#
#         marker_
