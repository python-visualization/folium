# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8233df67df87f5ae024e23d30f2e2615 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8233df67df87f5ae024e23d30f2e2615&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8233df67df87f5ae024e23d30f2e2615 = L.map(
#                 &quot;map_8233df67df87f5ae024e23d30f2e2615&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b346033c5e0a102a357be3c9f938902 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b346033c5e0a102a357be3c9f938902.addTo(map_8233df67df87f5ae024e23d30f2e2615);
#
#
#             var marker_4b025a63b6d39142899662abe6782b19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8233df67df87f5ae024e23d30f2e2615);
#
#
#         var popup_4ac07359a560dd04c5bb35a635772949 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1500dd0b4812a632866e64faf213889 = $(`&lt;div id=&quot;html_e1500dd0b4812a632866e64faf213889&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4ac07359a560dd04c5bb35a635772949.setContent(html_e1500dd0b4812a632866e64faf213889);
#
#
#
#         marker_4b025a63b6d39142899662abe6782b19.bindPopup(popup_4ac07359a560dd04c5bb35a635772949)
#         ;
#
#
#
#
#             var marker_065256c4ee03b04a30c34ecd5d4d5fbc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8233df67df87f5ae024e23d30f2e2615);
#
#
#         var popup_5a6112c4ec42a822eda3a8bde2401632 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76dae5c1817503f2e40d20184b14fe46 = $(`&lt;div id=&quot;html_76dae5c1817503f2e40d20184b14fe46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5a6112c4ec42a822eda3a8bde2401632.setContent(html_76dae5c1817503f2e40d20184b14fe46);
#
#
#
#         marker_065256c4ee03b04a30c34ecd5d4d5fbc.bindPopup(popup_5a6112c4ec42a822eda3a8bde2401632)
#         ;
#
#
#
#
#             var marker_fbd4a9f06912eb9689e731cbdb562910 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8233df67df87f5ae024e23d30f2e2615);
#
#
#         var popup_8ec4492480537ecdd06dd1f975c49a9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_016c4c2f857ef4f9bc3d2d87f2d09568 = $(`&lt;div id=&quot;html_016c4c2f857ef4f9bc3d2d87f2d09568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ec4492480537ecdd06dd1f975c49a9d.setContent(html_016c4c2f857ef4f9bc3d2d87f2d09568);
#
#
#
#         marker_fbd4a9f06912eb9689e731cbdb562910.bindPopup(popup_8ec4492480537ecdd06dd1f975c49a9d)
#         ;
#
#
#
#
#             var marker_fc144eae89d47657c334b2f4e16e265a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8233df67df87f5ae024e23d30f2e2615);
#
#
#         var popup_c76e0255fba71b883a50a1aa9a6645a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_972e00397f60d529281c0614c1ef6d27 = $(`&lt;div id=&quot;html_972e00397f60d529281c0614c1ef6d27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c76e0255fba71b883a50a1aa9a6645a9.setContent(html_972e00397f60d529281c0614c1ef6d27);
#
#
#
#         marker_fc144eae89d47657c334b2f4e16e265a.bindPopup(popup_c76e0255fba71b883a50a1aa9a6645a9)
#         ;
#
#
#
#
#             var marker_5a7ec58725c1d0338b89336028f81a29 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8233df67df87f5ae024e23d30f2e2615);
#
#
#         var popup_7f27d7d9333662b6f86e95c4ab67290f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_094a8ebd088b74522238b2bbb656374b = $(`&lt;div id=&quot;html_094a8ebd088b74522238b2bbb656374b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7f27d7d9333662b6f86e95c4ab67290f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_567fa72b52a2db22d8b4a722fa894c47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_567fa72b52a2db22d8b4a722fa894c47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_567fa72b52a2db22d8b4a722fa894c47 = L.map(
#                 &quot;map_567fa72b52a2db22d8b4a722fa894c47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0297631ea2ab30c93d025f57eb7c164d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0297631ea2ab30c93d025f57eb7c164d.addTo(map_567fa72b52a2db22d8b4a722fa894c47);
#
#
#             var feature_group_a196059b61bc081edc5ee1f20acf2f20 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_365a1188f3d95d54a889bf921df91ae9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a196059b61bc081edc5ee1f20acf2f20);
#
#
#         var popup_6c61993cfda03a4b4b2b98d62b9e416b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8512d6d9a9c7fa84ac4ca0809a40e437 = $(`&lt;div id=&quot;html_8512d6d9a9c7fa84ac4ca0809a40e437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6c61993cfda03a4b4b2b98d62b9e416b.setContent(html_8512d6d9a9c7fa84ac4ca0809a40e437);
#
#
#
#         marker_365a1188f3d95d54a889bf921df91ae9.bindPopup(popup_6c61993cfda03a4b4b2b98d62b9e416b)
#         ;
#
#
#
#
#             var marker_1295b60043d23697fa615d72b19f7bc8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a196059b61bc081edc5ee1f20acf2f20);
#
#
#         var popup_588331fb245ee3cde271dbcbe56cdb6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eae243b0ecf4069df0ea03f6ce4b3613 = $(`&lt;div id=&quot;html_eae243b0ecf4069df0ea03f6ce4b3613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_588331fb245ee3cde271dbcbe56cdb6a.setContent(html_eae243b0ecf4069df0ea03f6ce4b3613);
#
#
#
#         marker_1295b60043d23697fa615d72b19f7bc8.bindPopup(popup_588331fb245ee3cde271dbcbe56cdb6a)
#         ;
#
#
#
#
#             var marker_172fd40f0a5f98b0b76a1b26edd68546 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a196059b61bc081edc5ee1f20acf2f20);
#
#
#         var popup_cdbda04bd41e740c9e604b6ccfb50b29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a854b104fcab8cd7790f4be675a25bde = $(`&lt;div id=&quot;html_a854b104fcab8cd7790f4be675a25bde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cdbda04bd41e740c9e604b6ccfb50b29.setContent(html_a854b104fcab8cd7790f4be675a25bde);
#
#
#
#         marker_172fd40f0a5f98b0b76a1b26edd68546.bindPopup(popup_cdbda04bd41e740c9e604b6ccfb50b29)
#         ;
#
#
#
#
#             var marker_bd4001804748e30dece5a275c60f3050 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a196059b61bc081edc5ee1f20acf2f20);
#
#
#         var popup_e456720b6c6295ae73b698e53e67ff26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caea7652536685f8874c427c3ffb958d = $(`&lt;div id=&quot;html_caea7652536685f8874c427c3ffb958d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e456720b6c6295ae73b698e53e67ff26.setContent(html_caea7652536685f8874c427c3ffb958d);
#
#
#
#         marker_bd4001804748e30dece5a275c60f3050.bindPopup(popup_e456720b6c6295ae73b698e53e67ff26)
#         ;
#
#
#
#
#             var marker_02a140ba8b7e5c2d3257c1c045177774 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a196059b61bc081edc5ee1f20acf2f20);
#
#
#         var popup_f7bddc4de9e6fe955415d429235f1850 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40d1bb886f67aa4b5b5264d394c79797 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40d1bb886f67aa4b5b5264d394c79797&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40d1bb886f67aa4b5b5264d394c79797 = L.map(
#                 &quot;map_40d1bb886f67aa4b5b5264d394c79797&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11a6908530dd84e723496836d502477f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11a6908530dd84e723496836d502477f.addTo(map_40d1bb886f67aa4b5b5264d394c79797);
#
#
#             var feature_group_e561a8bba678359bdfe8360006b4792a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e561a8bba678359bdfe8360006b4792a.addTo(map_40d1bb886f67aa4b5b5264d394c79797);
#
#
#             var feature_group_sub_group_6b65773584575de2f281d60ca93722b1 = L.featureGroup.subGroup(
#                 feature_group_e561a8bba678359bdfe8360006b4792a
#             );
#
#
#             var marker_c7829721ebea89f198e2bc4335ec6ea9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b65773584575de2f281d60ca93722b1);
#
#
#         var popup_e20e9077fa8170d5c029897c837108b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce6cfecd51d7d59780c9176a1beaafee = $(`&lt;div id=&quot;html_ce6cfecd51d7d59780c9176a1beaafee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e20e9077fa8170d5c029897c837108b6.setContent(html_ce6cfecd51d7d59780c9176a1beaafee);
#
#
#
#         marker_c7829721ebea89f198e2bc4335ec6ea9.bindPopup(popup_e20e9077fa8170d5c029897c837108b6)
#         ;
#
#
#
#
#             var marker_a43ecfb8280a91c118e6652a5440deb2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b65773584575de2f281d60ca93722b1);
#
#
#         var popup_70c620b6def6a361f48ded4703382ad0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7003e28edc7567448fc13543e471de2b = $(`&lt;div id=&quot;html_7003e28edc7567448fc13543e471de2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_70c620b6def6a361f48ded4703382ad0.setContent(html_7003e28edc7567448fc13543e471de2b);
#
#
#
#         marker_a43ecfb8280a91c118e6652a5440deb2.bindPopup(popup_70c620b6def6a361f48ded4703382ad0)
#         ;
#
#
#
#
#             var marker_db3d2d5a5087de5f6fcd32435a21e912 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b65773584575de2f281d60ca93722b1);
#
#
#         var popup_5c0517a9e8071216333addcc134ac089 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94b31f83dd5d947f46baf4d8f5939864 = $(`&lt;div id=&quot;html_94b31f83dd5d947f46baf4d8f5939864&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5c0517a9e8071216333addcc134ac089.setContent(html_94b31f83dd5d947f46baf4d8f5939864);
#
#
#
#         marker_db3d2d5a5087de5f6fcd32435a21e912.bindPopup(popup_5c0517a9e8071216333addcc134ac089)
#         ;
#
#
#
#
#             var marker_818bb1f15734fa75353cf4f170766bf7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b65773584575de2f281d60ca93722b1);
#
#
#         var popup_df0a0a0f714613e4e24cb58c09531927 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67a85820ea99c8be99513ee42acdcb16 = $(`&lt;div id=&quot;html_67a85820ea99c8be99513ee42acdcb16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_df0a0a0f714613e4e24cb58c09531927.setContent(html_67a85820ea99c8be99513ee42acdcb16);
#
#
#
#         marker_
