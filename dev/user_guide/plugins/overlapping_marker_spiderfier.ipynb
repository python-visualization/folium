# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0806f8d5b6652c86d71f316f5b9629db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0806f8d5b6652c86d71f316f5b9629db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0806f8d5b6652c86d71f316f5b9629db = L.map(
#                 &quot;map_0806f8d5b6652c86d71f316f5b9629db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dd5c6db3eadb18d4d7d923dae9a5f36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1dd5c6db3eadb18d4d7d923dae9a5f36.addTo(map_0806f8d5b6652c86d71f316f5b9629db);
#
#
#             var marker_4b5f26071c5d0a645ae79cb14c42d1ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0806f8d5b6652c86d71f316f5b9629db);
#
#
#         var popup_9fb93984b33d326d10b9cbe998859a3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d4a74dde488dda02eadfd8423634c7a = $(`&lt;div id=&quot;html_0d4a74dde488dda02eadfd8423634c7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9fb93984b33d326d10b9cbe998859a3b.setContent(html_0d4a74dde488dda02eadfd8423634c7a);
#
#
#
#         marker_4b5f26071c5d0a645ae79cb14c42d1ce.bindPopup(popup_9fb93984b33d326d10b9cbe998859a3b)
#         ;
#
#
#
#
#             var marker_a0943844fa4e021a447d1d5c28035845 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0806f8d5b6652c86d71f316f5b9629db);
#
#
#         var popup_4a9211d98554d8ed4bd3155aad344482 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_621bc429665f741da6564eca152d3b6d = $(`&lt;div id=&quot;html_621bc429665f741da6564eca152d3b6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4a9211d98554d8ed4bd3155aad344482.setContent(html_621bc429665f741da6564eca152d3b6d);
#
#
#
#         marker_a0943844fa4e021a447d1d5c28035845.bindPopup(popup_4a9211d98554d8ed4bd3155aad344482)
#         ;
#
#
#
#
#             var marker_c75a16655dc45acaba63d6c9b6c945a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0806f8d5b6652c86d71f316f5b9629db);
#
#
#         var popup_41202fd9c02153cfadeade7850c8a98d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b47e18e8cf74f71f3d6a317f36941d05 = $(`&lt;div id=&quot;html_b47e18e8cf74f71f3d6a317f36941d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_41202fd9c02153cfadeade7850c8a98d.setContent(html_b47e18e8cf74f71f3d6a317f36941d05);
#
#
#
#         marker_c75a16655dc45acaba63d6c9b6c945a4.bindPopup(popup_41202fd9c02153cfadeade7850c8a98d)
#         ;
#
#
#
#
#             var marker_3c8c75632fbaaac7215ecc96b250df7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0806f8d5b6652c86d71f316f5b9629db);
#
#
#         var popup_aa2d73db6db5830556ed1eb320d96c34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ec0071e81a9c5cc0e40cc7f0d6a29f0 = $(`&lt;div id=&quot;html_9ec0071e81a9c5cc0e40cc7f0d6a29f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aa2d73db6db5830556ed1eb320d96c34.setContent(html_9ec0071e81a9c5cc0e40cc7f0d6a29f0);
#
#
#
#         marker_3c8c75632fbaaac7215ecc96b250df7c.bindPopup(popup_aa2d73db6db5830556ed1eb320d96c34)
#         ;
#
#
#
#
#             var marker_2270b1814ca792dcaa3bc6eb142d2527 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0806f8d5b6652c86d71f316f5b9629db);
#
#
#         var popup_d7d2012813e341f675e1158ad136a2ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78e6b47e50b09e9528e6c98118b4a898 = $(`&lt;div id=&quot;html_78e6b47e50b09e9528e6c98118b4a898&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d7d2012813e341f675e1158ad136a2ca.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1956c7591735b6d60f6c3cf2a66a956a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1956c7591735b6d60f6c3cf2a66a956a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1956c7591735b6d60f6c3cf2a66a956a = L.map(
#                 &quot;map_1956c7591735b6d60f6c3cf2a66a956a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c61efb13f64298aaa5707510920b173 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c61efb13f64298aaa5707510920b173.addTo(map_1956c7591735b6d60f6c3cf2a66a956a);
#
#
#             var feature_group_60dac835a327e9d2b8f05e0c66165450 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b563ceed8b71b4c0574ed21f80cd78dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_60dac835a327e9d2b8f05e0c66165450);
#
#
#         var popup_f94cb1f8f214a0aa5114c84d86a7f761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4ccb4238c20ff4da5603c6d79f2f49c = $(`&lt;div id=&quot;html_c4ccb4238c20ff4da5603c6d79f2f49c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f94cb1f8f214a0aa5114c84d86a7f761.setContent(html_c4ccb4238c20ff4da5603c6d79f2f49c);
#
#
#
#         marker_b563ceed8b71b4c0574ed21f80cd78dc.bindPopup(popup_f94cb1f8f214a0aa5114c84d86a7f761)
#         ;
#
#
#
#
#             var marker_4bdca5d57c3b471fd6d676d6f4fe0ce4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_60dac835a327e9d2b8f05e0c66165450);
#
#
#         var popup_0b84e0a9c5dee9c3cefdd41c08e073f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4695ad524065dd2bb55579a7e176d0c8 = $(`&lt;div id=&quot;html_4695ad524065dd2bb55579a7e176d0c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0b84e0a9c5dee9c3cefdd41c08e073f9.setContent(html_4695ad524065dd2bb55579a7e176d0c8);
#
#
#
#         marker_4bdca5d57c3b471fd6d676d6f4fe0ce4.bindPopup(popup_0b84e0a9c5dee9c3cefdd41c08e073f9)
#         ;
#
#
#
#
#             var marker_0e40a75c2faf816a4a2f0a064c817be7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_60dac835a327e9d2b8f05e0c66165450);
#
#
#         var popup_f1880947125f2a3a30604972b58e48fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ce94f8ba7e920a09aa8b986a1066b50 = $(`&lt;div id=&quot;html_9ce94f8ba7e920a09aa8b986a1066b50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f1880947125f2a3a30604972b58e48fd.setContent(html_9ce94f8ba7e920a09aa8b986a1066b50);
#
#
#
#         marker_0e40a75c2faf816a4a2f0a064c817be7.bindPopup(popup_f1880947125f2a3a30604972b58e48fd)
#         ;
#
#
#
#
#             var marker_edf19497f6090a8fd4410b45f6a0d039 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_60dac835a327e9d2b8f05e0c66165450);
#
#
#         var popup_75c7614cefc0ae2e95bd78b5fae7f886 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6224bd1ce3d137abd7e7e2e039520309 = $(`&lt;div id=&quot;html_6224bd1ce3d137abd7e7e2e039520309&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_75c7614cefc0ae2e95bd78b5fae7f886.setContent(html_6224bd1ce3d137abd7e7e2e039520309);
#
#
#
#         marker_edf19497f6090a8fd4410b45f6a0d039.bindPopup(popup_75c7614cefc0ae2e95bd78b5fae7f886)
#         ;
#
#
#
#
#             var marker_7e9b9b4f70dade8e70dff31013d3ca50 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_60dac835a327e9d2b8f05e0c66165450);
#
#
#         var popup_fbe47ce35e666d820e2a52b7789e2472 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33e40faf83ec8b7e7d99afc75dbf8d44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33e40faf83ec8b7e7d99afc75dbf8d44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33e40faf83ec8b7e7d99afc75dbf8d44 = L.map(
#                 &quot;map_33e40faf83ec8b7e7d99afc75dbf8d44&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d48d8161fd2b4e77d03325fe85895e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d48d8161fd2b4e77d03325fe85895e7.addTo(map_33e40faf83ec8b7e7d99afc75dbf8d44);
#
#
#             var feature_group_b5dbaa325687460af2312d5a360619f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b5dbaa325687460af2312d5a360619f9.addTo(map_33e40faf83ec8b7e7d99afc75dbf8d44);
#
#
#             var feature_group_sub_group_2be26348c8a9e45444fa6d7f13ecfa9a = L.featureGroup.subGroup(
#                 feature_group_b5dbaa325687460af2312d5a360619f9
#             );
#
#
#             var marker_deadf67cd1863521b5c3c2e4e964bcc5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2be26348c8a9e45444fa6d7f13ecfa9a);
#
#
#         var popup_7f73653ec03b4ebbac5dec25f1b658bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d5024acd040bffabadaf5d7525651f5 = $(`&lt;div id=&quot;html_0d5024acd040bffabadaf5d7525651f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7f73653ec03b4ebbac5dec25f1b658bf.setContent(html_0d5024acd040bffabadaf5d7525651f5);
#
#
#
#         marker_deadf67cd1863521b5c3c2e4e964bcc5.bindPopup(popup_7f73653ec03b4ebbac5dec25f1b658bf)
#         ;
#
#
#
#
#             var marker_b0cc5349e725b555a5a9bd7961fe3c48 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2be26348c8a9e45444fa6d7f13ecfa9a);
#
#
#         var popup_1baa036b2c80173262b1ce19dfa59873 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cf8d6f9822e12710b2c015264baaa2a = $(`&lt;div id=&quot;html_4cf8d6f9822e12710b2c015264baaa2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1baa036b2c80173262b1ce19dfa59873.setContent(html_4cf8d6f9822e12710b2c015264baaa2a);
#
#
#
#         marker_b0cc5349e725b555a5a9bd7961fe3c48.bindPopup(popup_1baa036b2c80173262b1ce19dfa59873)
#         ;
#
#
#
#
#             var marker_4defe1e82de1c49746fb95786cbb64b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2be26348c8a9e45444fa6d7f13ecfa9a);
#
#
#         var popup_d6b237d82da31b5c02f404fd4042c773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cde37a78b94f24993dd01c624f71ee67 = $(`&lt;div id=&quot;html_cde37a78b94f24993dd01c624f71ee67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d6b237d82da31b5c02f404fd4042c773.setContent(html_cde37a78b94f24993dd01c624f71ee67);
#
#
#
#         marker_4defe1e82de1c49746fb95786cbb64b2.bindPopup(popup_d6b237d82da31b5c02f404fd4042c773)
#         ;
#
#
#
#
#             var marker_f55045414e9ec9777152d8df81f148fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2be26348c8a9e45444fa6d7f13ecfa9a);
#
#
#         var popup_c22ae9303a99384124a1e490a6215c88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd8776203f47b3247b365c6f5a5776c8 = $(`&lt;div id=&quot;html_bd8776203f47b3247b365c6f5a5776c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c22ae9303a99384124a1e490a6215c88.setContent(html_bd8776203f47b3247b365c6f5a5776c8);
#
#
#
#         marker_
