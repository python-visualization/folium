# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_924be0c4425423a33667afac064287f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_924be0c4425423a33667afac064287f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_924be0c4425423a33667afac064287f0 = L.map(
#                 &quot;map_924be0c4425423a33667afac064287f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4141e6a3876770d5d9a8b57ae3cc23e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4141e6a3876770d5d9a8b57ae3cc23e0.addTo(map_924be0c4425423a33667afac064287f0);
#
#
#             var marker_fa16fb537af4ae1908bbea6c482c9854 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_924be0c4425423a33667afac064287f0);
#
#
#         var popup_edb88e7a328cdadf7dce0223c5f66d05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df02a4e35364585cf8df1fdcb510f0b2 = $(`&lt;div id=&quot;html_df02a4e35364585cf8df1fdcb510f0b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_edb88e7a328cdadf7dce0223c5f66d05.setContent(html_df02a4e35364585cf8df1fdcb510f0b2);
#
#
#
#         marker_fa16fb537af4ae1908bbea6c482c9854.bindPopup(popup_edb88e7a328cdadf7dce0223c5f66d05)
#         ;
#
#
#
#
#             var marker_c252a691905478283b3636e6e4b24970 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_924be0c4425423a33667afac064287f0);
#
#
#         var popup_bf13668034aab8b5728fb1a205cfbdad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04ce3057c62b1f9f967c39638eabdaa0 = $(`&lt;div id=&quot;html_04ce3057c62b1f9f967c39638eabdaa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bf13668034aab8b5728fb1a205cfbdad.setContent(html_04ce3057c62b1f9f967c39638eabdaa0);
#
#
#
#         marker_c252a691905478283b3636e6e4b24970.bindPopup(popup_bf13668034aab8b5728fb1a205cfbdad)
#         ;
#
#
#
#
#             var marker_cb070ce34cb06ea38d9520410276f38b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_924be0c4425423a33667afac064287f0);
#
#
#         var popup_365eb49783df7de143818efc43c627a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38eeed00e1951040a05824f52aad5e06 = $(`&lt;div id=&quot;html_38eeed00e1951040a05824f52aad5e06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_365eb49783df7de143818efc43c627a7.setContent(html_38eeed00e1951040a05824f52aad5e06);
#
#
#
#         marker_cb070ce34cb06ea38d9520410276f38b.bindPopup(popup_365eb49783df7de143818efc43c627a7)
#         ;
#
#
#
#
#             var marker_6be5bb0abfa0d2833e6d2aacf393b9ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_924be0c4425423a33667afac064287f0);
#
#
#         var popup_a17b63c9a513de7c9346a307c22b3866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8901f66b03a8331f20cc60be4fa2a651 = $(`&lt;div id=&quot;html_8901f66b03a8331f20cc60be4fa2a651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a17b63c9a513de7c9346a307c22b3866.setContent(html_8901f66b03a8331f20cc60be4fa2a651);
#
#
#
#         marker_6be5bb0abfa0d2833e6d2aacf393b9ea.bindPopup(popup_a17b63c9a513de7c9346a307c22b3866)
#         ;
#
#
#
#
#             var marker_11cce1e7991c472b7e746595761d2c0d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_924be0c4425423a33667afac064287f0);
#
#
#         var popup_8bc8a6ac971c3f65c257c4139d30774d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_366ffa777a96b5ea0010fde0d5550fbc = $(`&lt;div id=&quot;html_366ffa777a96b5ea0010fde0d5550fbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8bc8a6ac971c3f65c257c4139d30774d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b60fb69c42783200b70296db5712bd6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b60fb69c42783200b70296db5712bd6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b60fb69c42783200b70296db5712bd6a = L.map(
#                 &quot;map_b60fb69c42783200b70296db5712bd6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56e6c82116fb96d4d660d567383a6db4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56e6c82116fb96d4d660d567383a6db4.addTo(map_b60fb69c42783200b70296db5712bd6a);
#
#
#             var feature_group_5ff71e111a45afa2cc9fb20960d63ec6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_281215dbaf641114d5404da816a7e44e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5ff71e111a45afa2cc9fb20960d63ec6);
#
#
#         var popup_cb25b4fd9c65959569c3e86fa73cd040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4f353ae77bf81eeb217aa305e58cec8 = $(`&lt;div id=&quot;html_e4f353ae77bf81eeb217aa305e58cec8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cb25b4fd9c65959569c3e86fa73cd040.setContent(html_e4f353ae77bf81eeb217aa305e58cec8);
#
#
#
#         marker_281215dbaf641114d5404da816a7e44e.bindPopup(popup_cb25b4fd9c65959569c3e86fa73cd040)
#         ;
#
#
#
#
#             var marker_4c5bc362cf8292723a730a5722fa8f5e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5ff71e111a45afa2cc9fb20960d63ec6);
#
#
#         var popup_59143542cc108b5a178cff187e192272 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2bb49d97cc32be5e7db7976bff6a8a2 = $(`&lt;div id=&quot;html_c2bb49d97cc32be5e7db7976bff6a8a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_59143542cc108b5a178cff187e192272.setContent(html_c2bb49d97cc32be5e7db7976bff6a8a2);
#
#
#
#         marker_4c5bc362cf8292723a730a5722fa8f5e.bindPopup(popup_59143542cc108b5a178cff187e192272)
#         ;
#
#
#
#
#             var marker_6e46f12bbbd5d9cfe4c2ea93098d72e3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5ff71e111a45afa2cc9fb20960d63ec6);
#
#
#         var popup_2922455791fc29df7e1a0292914927c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a7c329b27339fab2b2aade6e879c50d = $(`&lt;div id=&quot;html_0a7c329b27339fab2b2aade6e879c50d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2922455791fc29df7e1a0292914927c2.setContent(html_0a7c329b27339fab2b2aade6e879c50d);
#
#
#
#         marker_6e46f12bbbd5d9cfe4c2ea93098d72e3.bindPopup(popup_2922455791fc29df7e1a0292914927c2)
#         ;
#
#
#
#
#             var marker_fb77a6b4a065e0ff5e46aa93e022884a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5ff71e111a45afa2cc9fb20960d63ec6);
#
#
#         var popup_8ffff4b50c08410917be5a788ccb5423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f28582eec514ddd48c51265f321357a0 = $(`&lt;div id=&quot;html_f28582eec514ddd48c51265f321357a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8ffff4b50c08410917be5a788ccb5423.setContent(html_f28582eec514ddd48c51265f321357a0);
#
#
#
#         marker_fb77a6b4a065e0ff5e46aa93e022884a.bindPopup(popup_8ffff4b50c08410917be5a788ccb5423)
#         ;
#
#
#
#
#             var marker_d56cbc12a307e707d299c8909890a281 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5ff71e111a45afa2cc9fb20960d63ec6);
#
#
#         var popup_1e31d6243e0df4311b69bde38fa819f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db690195ca2b1b97d188667f84f527cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db690195ca2b1b97d188667f84f527cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db690195ca2b1b97d188667f84f527cb = L.map(
#                 &quot;map_db690195ca2b1b97d188667f84f527cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6086d483deb53d3ee18100ce4bb18803 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6086d483deb53d3ee18100ce4bb18803.addTo(map_db690195ca2b1b97d188667f84f527cb);
#
#
#             var feature_group_05a04cdf5563e362146d7faf35342ca8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_05a04cdf5563e362146d7faf35342ca8.addTo(map_db690195ca2b1b97d188667f84f527cb);
#
#
#             var feature_group_sub_group_c5492903d9d406aa1837a3c57ead7570 = L.featureGroup.subGroup(
#                 feature_group_05a04cdf5563e362146d7faf35342ca8
#             );
#
#
#             var marker_84c76677e082140d0006ef4209140e1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5492903d9d406aa1837a3c57ead7570);
#
#
#         var popup_d68c34d4b33e965ffbf3507ffe192044 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f53173e14aafdb23450ffc41b139174 = $(`&lt;div id=&quot;html_5f53173e14aafdb23450ffc41b139174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d68c34d4b33e965ffbf3507ffe192044.setContent(html_5f53173e14aafdb23450ffc41b139174);
#
#
#
#         marker_84c76677e082140d0006ef4209140e1f.bindPopup(popup_d68c34d4b33e965ffbf3507ffe192044)
#         ;
#
#
#
#
#             var marker_969b06af3f6661c2ba4623f3abf7387a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5492903d9d406aa1837a3c57ead7570);
#
#
#         var popup_12d36534cba61b3953be839978f6ed96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec5deaa2bb6713a4874d2f97da0c54d3 = $(`&lt;div id=&quot;html_ec5deaa2bb6713a4874d2f97da0c54d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_12d36534cba61b3953be839978f6ed96.setContent(html_ec5deaa2bb6713a4874d2f97da0c54d3);
#
#
#
#         marker_969b06af3f6661c2ba4623f3abf7387a.bindPopup(popup_12d36534cba61b3953be839978f6ed96)
#         ;
#
#
#
#
#             var marker_5cbbc631bc1f35ca8f8797b7f97f2958 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5492903d9d406aa1837a3c57ead7570);
#
#
#         var popup_a222bcd91571fcf455a05db895a20216 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb5fd2a571ba520940a6d16c50630bd2 = $(`&lt;div id=&quot;html_fb5fd2a571ba520940a6d16c50630bd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a222bcd91571fcf455a05db895a20216.setContent(html_fb5fd2a571ba520940a6d16c50630bd2);
#
#
#
#         marker_5cbbc631bc1f35ca8f8797b7f97f2958.bindPopup(popup_a222bcd91571fcf455a05db895a20216)
#         ;
#
#
#
#
#             var marker_effa8b92f51fcaa64851964028593118 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5492903d9d406aa1837a3c57ead7570);
#
#
#         var popup_0a38b7687fc4c90852dc567b3ac22696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77638db5a794bbc1b74d226f120917e4 = $(`&lt;div id=&quot;html_77638db5a794bbc1b74d226f120917e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0a38b7687fc4c90852dc567b3ac22696.setContent(html_77638db5a794bbc1b74d226f120917e4);
#
#
#
#         marker_
