# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb1018ffb3db5459cc30877b0e3bc242 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb1018ffb3db5459cc30877b0e3bc242&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb1018ffb3db5459cc30877b0e3bc242 = L.map(
#                 &quot;map_cb1018ffb3db5459cc30877b0e3bc242&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95ded6bcf3fe4cc5518f64620bb3d319 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95ded6bcf3fe4cc5518f64620bb3d319.addTo(map_cb1018ffb3db5459cc30877b0e3bc242);
#
#
#             var marker_d4a837cd6045185a4378f2f3a8f88cd7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cb1018ffb3db5459cc30877b0e3bc242);
#
#
#         var popup_f18583b1681664d075177e62ce2dbdb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3659f5ac00f276bfca0204d4e3dcf44 = $(`&lt;div id=&quot;html_b3659f5ac00f276bfca0204d4e3dcf44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f18583b1681664d075177e62ce2dbdb6.setContent(html_b3659f5ac00f276bfca0204d4e3dcf44);
#
#
#
#         marker_d4a837cd6045185a4378f2f3a8f88cd7.bindPopup(popup_f18583b1681664d075177e62ce2dbdb6)
#         ;
#
#
#
#
#             var marker_eeeab03806301d410a5375a20ced4d5c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cb1018ffb3db5459cc30877b0e3bc242);
#
#
#         var popup_90004b76605b65120ffeb11867d25970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c84e906d6aac3d391248064f7395b4c1 = $(`&lt;div id=&quot;html_c84e906d6aac3d391248064f7395b4c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_90004b76605b65120ffeb11867d25970.setContent(html_c84e906d6aac3d391248064f7395b4c1);
#
#
#
#         marker_eeeab03806301d410a5375a20ced4d5c.bindPopup(popup_90004b76605b65120ffeb11867d25970)
#         ;
#
#
#
#
#             var marker_6f73ca0f7b1e53a873d19b8f74c89066 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cb1018ffb3db5459cc30877b0e3bc242);
#
#
#         var popup_9bff8dc613e8a0d251cd184f906e74e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7f544687218d2b8025bcf0079471182 = $(`&lt;div id=&quot;html_c7f544687218d2b8025bcf0079471182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9bff8dc613e8a0d251cd184f906e74e6.setContent(html_c7f544687218d2b8025bcf0079471182);
#
#
#
#         marker_6f73ca0f7b1e53a873d19b8f74c89066.bindPopup(popup_9bff8dc613e8a0d251cd184f906e74e6)
#         ;
#
#
#
#
#             var marker_fdd34b854436979c9251c66b0818df8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cb1018ffb3db5459cc30877b0e3bc242);
#
#
#         var popup_c6f10bce7fa97ff2ddf14ee2f05b41d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e3282ac27db0bf34695ea7396cdc6a7 = $(`&lt;div id=&quot;html_5e3282ac27db0bf34695ea7396cdc6a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c6f10bce7fa97ff2ddf14ee2f05b41d9.setContent(html_5e3282ac27db0bf34695ea7396cdc6a7);
#
#
#
#         marker_fdd34b854436979c9251c66b0818df8b.bindPopup(popup_c6f10bce7fa97ff2ddf14ee2f05b41d9)
#         ;
#
#
#
#
#             var marker_29634138cdd7c5e07770c016a3392039 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cb1018ffb3db5459cc30877b0e3bc242);
#
#
#         var popup_436fa27091a5a9514617e537448b89d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81a260130f7ce5f2b7142c9b318395cb = $(`&lt;div id=&quot;html_81a260130f7ce5f2b7142c9b318395cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_436fa27091a5a9514617e537448b89d5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_adaa8ddf42b5c7307880151fb40d68cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_adaa8ddf42b5c7307880151fb40d68cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_adaa8ddf42b5c7307880151fb40d68cb = L.map(
#                 &quot;map_adaa8ddf42b5c7307880151fb40d68cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b160fa60393149b100350e53b203d8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b160fa60393149b100350e53b203d8c.addTo(map_adaa8ddf42b5c7307880151fb40d68cb);
#
#
#             var feature_group_eb1a9a2c3393949f9d8e72472363187e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_94e80a1106111742fb2bd0258726796d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eb1a9a2c3393949f9d8e72472363187e);
#
#
#         var popup_5f4084a6fbff5a86079b053c44639fed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4e482fdd8244f8d784c822398c5fdb8 = $(`&lt;div id=&quot;html_b4e482fdd8244f8d784c822398c5fdb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5f4084a6fbff5a86079b053c44639fed.setContent(html_b4e482fdd8244f8d784c822398c5fdb8);
#
#
#
#         marker_94e80a1106111742fb2bd0258726796d.bindPopup(popup_5f4084a6fbff5a86079b053c44639fed)
#         ;
#
#
#
#
#             var marker_0dd91a85e0bb4e8af9816b4fa060a23d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eb1a9a2c3393949f9d8e72472363187e);
#
#
#         var popup_e1bac30f3935b59cadcf396ca73a58c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1b86358e8f369521412dfbbd8ec87ba = $(`&lt;div id=&quot;html_d1b86358e8f369521412dfbbd8ec87ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e1bac30f3935b59cadcf396ca73a58c5.setContent(html_d1b86358e8f369521412dfbbd8ec87ba);
#
#
#
#         marker_0dd91a85e0bb4e8af9816b4fa060a23d.bindPopup(popup_e1bac30f3935b59cadcf396ca73a58c5)
#         ;
#
#
#
#
#             var marker_5cd9308f02e2529d7499872774114313 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eb1a9a2c3393949f9d8e72472363187e);
#
#
#         var popup_2c1c7121580c17b6b6de69f7426adf3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf82889be38a4265d5d0e7c8b9f47c0a = $(`&lt;div id=&quot;html_cf82889be38a4265d5d0e7c8b9f47c0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2c1c7121580c17b6b6de69f7426adf3a.setContent(html_cf82889be38a4265d5d0e7c8b9f47c0a);
#
#
#
#         marker_5cd9308f02e2529d7499872774114313.bindPopup(popup_2c1c7121580c17b6b6de69f7426adf3a)
#         ;
#
#
#
#
#             var marker_96b7b861a9dcb011b535e53f654a2895 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eb1a9a2c3393949f9d8e72472363187e);
#
#
#         var popup_d1c22968bdb8b5a93a3989ac927ea862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1956134bb8db2dec787c3024c6381bfb = $(`&lt;div id=&quot;html_1956134bb8db2dec787c3024c6381bfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d1c22968bdb8b5a93a3989ac927ea862.setContent(html_1956134bb8db2dec787c3024c6381bfb);
#
#
#
#         marker_96b7b861a9dcb011b535e53f654a2895.bindPopup(popup_d1c22968bdb8b5a93a3989ac927ea862)
#         ;
#
#
#
#
#             var marker_eea9e558338f3175258305457e6966eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eb1a9a2c3393949f9d8e72472363187e);
#
#
#         var popup_d055d99b37f38bfb1272d8f2b23788f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a029f589439341499042ff526962004 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a029f589439341499042ff526962004&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a029f589439341499042ff526962004 = L.map(
#                 &quot;map_5a029f589439341499042ff526962004&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ab001511de53d298ce2d0c17b457538 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ab001511de53d298ce2d0c17b457538.addTo(map_5a029f589439341499042ff526962004);
#
#
#             var feature_group_4cde7b1d495b469f0a10df01493ab738 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4cde7b1d495b469f0a10df01493ab738.addTo(map_5a029f589439341499042ff526962004);
#
#
#             var feature_group_sub_group_b89e8b142207e0e09174e8bba248f078 = L.featureGroup.subGroup(
#                 feature_group_4cde7b1d495b469f0a10df01493ab738
#             );
#
#
#             var marker_96fb4de51d814cc132d2ff7c0ce1c456 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b89e8b142207e0e09174e8bba248f078);
#
#
#         var popup_af2b5cda56adc2dfd3a75ea8ee66054b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_624d1e6da7029d5022705494682cf736 = $(`&lt;div id=&quot;html_624d1e6da7029d5022705494682cf736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_af2b5cda56adc2dfd3a75ea8ee66054b.setContent(html_624d1e6da7029d5022705494682cf736);
#
#
#
#         marker_96fb4de51d814cc132d2ff7c0ce1c456.bindPopup(popup_af2b5cda56adc2dfd3a75ea8ee66054b)
#         ;
#
#
#
#
#             var marker_5396ee6202a75c2776aba97c31c646b1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b89e8b142207e0e09174e8bba248f078);
#
#
#         var popup_f19393ce34e5e476ce030cc24e06f224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8eb0daa873d336123afea284a576886d = $(`&lt;div id=&quot;html_8eb0daa873d336123afea284a576886d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f19393ce34e5e476ce030cc24e06f224.setContent(html_8eb0daa873d336123afea284a576886d);
#
#
#
#         marker_5396ee6202a75c2776aba97c31c646b1.bindPopup(popup_f19393ce34e5e476ce030cc24e06f224)
#         ;
#
#
#
#
#             var marker_d8458c47bf7a06a85643c4649af7d93e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b89e8b142207e0e09174e8bba248f078);
#
#
#         var popup_08342753009edc423942aa02b34181c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11a0edfdb5b5dc9dff38d9f7338d1500 = $(`&lt;div id=&quot;html_11a0edfdb5b5dc9dff38d9f7338d1500&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_08342753009edc423942aa02b34181c6.setContent(html_11a0edfdb5b5dc9dff38d9f7338d1500);
#
#
#
#         marker_d8458c47bf7a06a85643c4649af7d93e.bindPopup(popup_08342753009edc423942aa02b34181c6)
#         ;
#
#
#
#
#             var marker_4f8c536bf80dd32a6b3b518a28ab6d09 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b89e8b142207e0e09174e8bba248f078);
#
#
#         var popup_4f4e09b699a51b87c20b86832c94bfea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3aac128a2c32c29a05608bd9976e70e5 = $(`&lt;div id=&quot;html_3aac128a2c32c29a05608bd9976e70e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4f4e09b699a51b87c20b86832c94bfea.setContent(html_3aac128a2c32c29a05608bd9976e70e5);
#
#
#
#         marker_
