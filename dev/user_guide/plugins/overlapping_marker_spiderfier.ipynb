# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c596584230ff432431db159f84c9a78f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c596584230ff432431db159f84c9a78f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c596584230ff432431db159f84c9a78f = L.map(
#                 &quot;map_c596584230ff432431db159f84c9a78f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57abb4d3d985f4e5a4fba25f4834b869 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57abb4d3d985f4e5a4fba25f4834b869.addTo(map_c596584230ff432431db159f84c9a78f);
#
#
#             var marker_6a58ab812c069eca8a4df9229d5e44c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c596584230ff432431db159f84c9a78f);
#
#
#         var popup_21af3ec13e1eda57a3507c4d6e4e3864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_122be4f5650c2351752fff4ae3fe184c = $(`&lt;div id=&quot;html_122be4f5650c2351752fff4ae3fe184c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_21af3ec13e1eda57a3507c4d6e4e3864.setContent(html_122be4f5650c2351752fff4ae3fe184c);
#
#
#
#         marker_6a58ab812c069eca8a4df9229d5e44c3.bindPopup(popup_21af3ec13e1eda57a3507c4d6e4e3864)
#         ;
#
#
#
#
#             var marker_ec39a9144e9b704a194dbe5fc2f41c6e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c596584230ff432431db159f84c9a78f);
#
#
#         var popup_2b14c0b098c880212c7fb81760a63914 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ebe2219a9d8828a44a36e8eb926d4d = $(`&lt;div id=&quot;html_52ebe2219a9d8828a44a36e8eb926d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2b14c0b098c880212c7fb81760a63914.setContent(html_52ebe2219a9d8828a44a36e8eb926d4d);
#
#
#
#         marker_ec39a9144e9b704a194dbe5fc2f41c6e.bindPopup(popup_2b14c0b098c880212c7fb81760a63914)
#         ;
#
#
#
#
#             var marker_f58eb3091c72f2a29a726f57ded370b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c596584230ff432431db159f84c9a78f);
#
#
#         var popup_9038a563c5d4d3d3a7ed34c51b093bad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e84a518fee1e372d15ec301f4464e7a2 = $(`&lt;div id=&quot;html_e84a518fee1e372d15ec301f4464e7a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9038a563c5d4d3d3a7ed34c51b093bad.setContent(html_e84a518fee1e372d15ec301f4464e7a2);
#
#
#
#         marker_f58eb3091c72f2a29a726f57ded370b1.bindPopup(popup_9038a563c5d4d3d3a7ed34c51b093bad)
#         ;
#
#
#
#
#             var marker_1384e5a90fd8c805bd0324cec6e600d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c596584230ff432431db159f84c9a78f);
#
#
#         var popup_5026def61ac0813708dea4ceba6e2949 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d12dda1f1ef333d419c98bcb1dc622a3 = $(`&lt;div id=&quot;html_d12dda1f1ef333d419c98bcb1dc622a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5026def61ac0813708dea4ceba6e2949.setContent(html_d12dda1f1ef333d419c98bcb1dc622a3);
#
#
#
#         marker_1384e5a90fd8c805bd0324cec6e600d6.bindPopup(popup_5026def61ac0813708dea4ceba6e2949)
#         ;
#
#
#
#
#             var marker_de9226fd1bc07fa72ef118a525519980 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c596584230ff432431db159f84c9a78f);
#
#
#         var popup_f5a179cbe52f3a58e756d264e15d248f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af83159a2c441206a6a95107efb01ce8 = $(`&lt;div id=&quot;html_af83159a2c441206a6a95107efb01ce8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f5a179cbe52f3a58e756d264e15d248f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c707c66c84e32b41307edd58bfcbc7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c707c66c84e32b41307edd58bfcbc7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c707c66c84e32b41307edd58bfcbc7d = L.map(
#                 &quot;map_9c707c66c84e32b41307edd58bfcbc7d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98807704ac717e733d9d6ffad5f817fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98807704ac717e733d9d6ffad5f817fb.addTo(map_9c707c66c84e32b41307edd58bfcbc7d);
#
#
#             var feature_group_d611ac79adf0f060f9be012527fc762d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3f3d2203bd2077ea8bfbbaed5b800fad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d611ac79adf0f060f9be012527fc762d);
#
#
#         var popup_d4789b80dfc5b1f361c8cb14c3d70f21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_870be4990f1b96fa2f4678f366bb2ebe = $(`&lt;div id=&quot;html_870be4990f1b96fa2f4678f366bb2ebe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d4789b80dfc5b1f361c8cb14c3d70f21.setContent(html_870be4990f1b96fa2f4678f366bb2ebe);
#
#
#
#         marker_3f3d2203bd2077ea8bfbbaed5b800fad.bindPopup(popup_d4789b80dfc5b1f361c8cb14c3d70f21)
#         ;
#
#
#
#
#             var marker_c2b0d4463c8bfbc196e60b14af5885cf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d611ac79adf0f060f9be012527fc762d);
#
#
#         var popup_dfa36f0862cba3f5dfeb64ccc76180e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49cd4cde6f2605aac1ba60a2c10af9c9 = $(`&lt;div id=&quot;html_49cd4cde6f2605aac1ba60a2c10af9c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dfa36f0862cba3f5dfeb64ccc76180e1.setContent(html_49cd4cde6f2605aac1ba60a2c10af9c9);
#
#
#
#         marker_c2b0d4463c8bfbc196e60b14af5885cf.bindPopup(popup_dfa36f0862cba3f5dfeb64ccc76180e1)
#         ;
#
#
#
#
#             var marker_9d672758871dd1b020a372d716e91cd2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d611ac79adf0f060f9be012527fc762d);
#
#
#         var popup_78ac2e7130759e03ba5145fed76f59e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_035f476c8e3d3db9ae136f45de09d254 = $(`&lt;div id=&quot;html_035f476c8e3d3db9ae136f45de09d254&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_78ac2e7130759e03ba5145fed76f59e5.setContent(html_035f476c8e3d3db9ae136f45de09d254);
#
#
#
#         marker_9d672758871dd1b020a372d716e91cd2.bindPopup(popup_78ac2e7130759e03ba5145fed76f59e5)
#         ;
#
#
#
#
#             var marker_1d755b0c7670e8ca3f902394c1a606e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d611ac79adf0f060f9be012527fc762d);
#
#
#         var popup_a436c54aac5a841cfbb946b04ab9b84f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341df1827ee1ea74566e7232c037aad9 = $(`&lt;div id=&quot;html_341df1827ee1ea74566e7232c037aad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a436c54aac5a841cfbb946b04ab9b84f.setContent(html_341df1827ee1ea74566e7232c037aad9);
#
#
#
#         marker_1d755b0c7670e8ca3f902394c1a606e6.bindPopup(popup_a436c54aac5a841cfbb946b04ab9b84f)
#         ;
#
#
#
#
#             var marker_e8c918db34a46ac2167a77bb2dd97b4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d611ac79adf0f060f9be012527fc762d);
#
#
#         var popup_fbe0860a360895aae9a0fdb4016351b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdf809a7147cb4c12fa5aead371a59f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdf809a7147cb4c12fa5aead371a59f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdf809a7147cb4c12fa5aead371a59f2 = L.map(
#                 &quot;map_fdf809a7147cb4c12fa5aead371a59f2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2d518a50d7964394b50786a100af91d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2d518a50d7964394b50786a100af91d.addTo(map_fdf809a7147cb4c12fa5aead371a59f2);
#
#
#             var feature_group_e74f716e5906a3c50c4ed36bb543c061 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e74f716e5906a3c50c4ed36bb543c061.addTo(map_fdf809a7147cb4c12fa5aead371a59f2);
#
#
#             var feature_group_sub_group_05e24f61bc7f241b9f051e5e348b7a7b = L.featureGroup.subGroup(
#                 feature_group_e74f716e5906a3c50c4ed36bb543c061
#             );
#
#
#             var marker_318a637d3fba8ed22821ef1ce7848997 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_05e24f61bc7f241b9f051e5e348b7a7b);
#
#
#         var popup_f46c284229409825565e6e5cf4db3470 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72a8edc31b82c9c18fb59d967dd3da38 = $(`&lt;div id=&quot;html_72a8edc31b82c9c18fb59d967dd3da38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f46c284229409825565e6e5cf4db3470.setContent(html_72a8edc31b82c9c18fb59d967dd3da38);
#
#
#
#         marker_318a637d3fba8ed22821ef1ce7848997.bindPopup(popup_f46c284229409825565e6e5cf4db3470)
#         ;
#
#
#
#
#             var marker_af448888d7dd56db1f1061ba706493e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_05e24f61bc7f241b9f051e5e348b7a7b);
#
#
#         var popup_49fc71636b1f46e043d548fb31330b52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f96e5d894fe0364df89a8e0a78f1684 = $(`&lt;div id=&quot;html_2f96e5d894fe0364df89a8e0a78f1684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_49fc71636b1f46e043d548fb31330b52.setContent(html_2f96e5d894fe0364df89a8e0a78f1684);
#
#
#
#         marker_af448888d7dd56db1f1061ba706493e4.bindPopup(popup_49fc71636b1f46e043d548fb31330b52)
#         ;
#
#
#
#
#             var marker_b5f031bc2e8ce40208fc32fc9ea34031 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_05e24f61bc7f241b9f051e5e348b7a7b);
#
#
#         var popup_10b1df35df79b8c2098797cd321269e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb587199fdc05fc6838a38558951e42f = $(`&lt;div id=&quot;html_bb587199fdc05fc6838a38558951e42f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_10b1df35df79b8c2098797cd321269e1.setContent(html_bb587199fdc05fc6838a38558951e42f);
#
#
#
#         marker_b5f031bc2e8ce40208fc32fc9ea34031.bindPopup(popup_10b1df35df79b8c2098797cd321269e1)
#         ;
#
#
#
#
#             var marker_309817592db68ba8632ab7a67230edc8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_05e24f61bc7f241b9f051e5e348b7a7b);
#
#
#         var popup_412cd7fa30502c0c0387bdf9219fe9b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c611748140b08714e037f935791fba62 = $(`&lt;div id=&quot;html_c611748140b08714e037f935791fba62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_412cd7fa30502c0c0387bdf9219fe9b6.setContent(html_c611748140b08714e037f935791fba62);
#
#
#
#         marker_
