# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2785257d7702b777f92e4bee6bfd5e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2785257d7702b777f92e4bee6bfd5e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2785257d7702b777f92e4bee6bfd5e3 = L.map(
#                 &quot;map_d2785257d7702b777f92e4bee6bfd5e3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c85d073e72b928eb77ce0873dbd07f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c85d073e72b928eb77ce0873dbd07f9.addTo(map_d2785257d7702b777f92e4bee6bfd5e3);
#
#
#             var marker_24f4884fd3bc4bc795eb6e155fa7546f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d2785257d7702b777f92e4bee6bfd5e3);
#
#
#         var popup_7294bf9829bf320845fa8e91dcfe65c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55071c307d60769693d24388c404fc9b = $(`&lt;div id=&quot;html_55071c307d60769693d24388c404fc9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7294bf9829bf320845fa8e91dcfe65c1.setContent(html_55071c307d60769693d24388c404fc9b);
#
#
#
#         marker_24f4884fd3bc4bc795eb6e155fa7546f.bindPopup(popup_7294bf9829bf320845fa8e91dcfe65c1)
#         ;
#
#
#
#
#             var marker_6e3faa31cc9d4fe29c8d58920fe3201c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d2785257d7702b777f92e4bee6bfd5e3);
#
#
#         var popup_f91004177a486e61eed67b7f46f3b2af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64101b2aedbea9453a628ff812eb654b = $(`&lt;div id=&quot;html_64101b2aedbea9453a628ff812eb654b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f91004177a486e61eed67b7f46f3b2af.setContent(html_64101b2aedbea9453a628ff812eb654b);
#
#
#
#         marker_6e3faa31cc9d4fe29c8d58920fe3201c.bindPopup(popup_f91004177a486e61eed67b7f46f3b2af)
#         ;
#
#
#
#
#             var marker_22534c05f9055d250738203376042689 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d2785257d7702b777f92e4bee6bfd5e3);
#
#
#         var popup_6320f8344818afc2dd57b2a07927af75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcac605f4fd360a65ecbc537fe1251d9 = $(`&lt;div id=&quot;html_dcac605f4fd360a65ecbc537fe1251d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6320f8344818afc2dd57b2a07927af75.setContent(html_dcac605f4fd360a65ecbc537fe1251d9);
#
#
#
#         marker_22534c05f9055d250738203376042689.bindPopup(popup_6320f8344818afc2dd57b2a07927af75)
#         ;
#
#
#
#
#             var marker_0ba3527bf9fa550136e94453d3a3cec4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d2785257d7702b777f92e4bee6bfd5e3);
#
#
#         var popup_b235465413f1e7f4f8eaa08dbca0b541 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b527ebcc52d183404cca9ad7a8b9f28 = $(`&lt;div id=&quot;html_0b527ebcc52d183404cca9ad7a8b9f28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b235465413f1e7f4f8eaa08dbca0b541.setContent(html_0b527ebcc52d183404cca9ad7a8b9f28);
#
#
#
#         marker_0ba3527bf9fa550136e94453d3a3cec4.bindPopup(popup_b235465413f1e7f4f8eaa08dbca0b541)
#         ;
#
#
#
#
#             var marker_acbb4287bb3486d193d03aca41c3e7d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d2785257d7702b777f92e4bee6bfd5e3);
#
#
#         var popup_ceeb3e9292f70b6fd087e3a1296b5999 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afa3e72138269d0bb9ff904d830384be = $(`&lt;div id=&quot;html_afa3e72138269d0bb9ff904d830384be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ceeb3e9292f70b6fd087e3a1296b5999.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b48238b6441690ed5a37abefac8f82d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b48238b6441690ed5a37abefac8f82d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b48238b6441690ed5a37abefac8f82d2 = L.map(
#                 &quot;map_b48238b6441690ed5a37abefac8f82d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86a66e6e1a7d4cff8120d50c55bc7739 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86a66e6e1a7d4cff8120d50c55bc7739.addTo(map_b48238b6441690ed5a37abefac8f82d2);
#
#
#             var feature_group_8d09658f7a8d17ccc733dcef14908e3b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2cfe85ff07516d02777aade67b380b0a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8d09658f7a8d17ccc733dcef14908e3b);
#
#
#         var popup_20b8edf8411eee323b04287de10d4a42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d340fa0c358b68b21d5a69aeaea3588e = $(`&lt;div id=&quot;html_d340fa0c358b68b21d5a69aeaea3588e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_20b8edf8411eee323b04287de10d4a42.setContent(html_d340fa0c358b68b21d5a69aeaea3588e);
#
#
#
#         marker_2cfe85ff07516d02777aade67b380b0a.bindPopup(popup_20b8edf8411eee323b04287de10d4a42)
#         ;
#
#
#
#
#             var marker_764fe1023e32a1228a62180071442eb4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8d09658f7a8d17ccc733dcef14908e3b);
#
#
#         var popup_fb8b87494d023bd4584727d3f516af96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4afacf405756efd2d22a387a715405cc = $(`&lt;div id=&quot;html_4afacf405756efd2d22a387a715405cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fb8b87494d023bd4584727d3f516af96.setContent(html_4afacf405756efd2d22a387a715405cc);
#
#
#
#         marker_764fe1023e32a1228a62180071442eb4.bindPopup(popup_fb8b87494d023bd4584727d3f516af96)
#         ;
#
#
#
#
#             var marker_422a0a2a9c1397b3bff9284eb41a3b9b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8d09658f7a8d17ccc733dcef14908e3b);
#
#
#         var popup_5e7b454cfa5fa0891ae01baea17b6398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3f32eef13c124f25f7801422d4d8a9 = $(`&lt;div id=&quot;html_7f3f32eef13c124f25f7801422d4d8a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5e7b454cfa5fa0891ae01baea17b6398.setContent(html_7f3f32eef13c124f25f7801422d4d8a9);
#
#
#
#         marker_422a0a2a9c1397b3bff9284eb41a3b9b.bindPopup(popup_5e7b454cfa5fa0891ae01baea17b6398)
#         ;
#
#
#
#
#             var marker_ae4651d1bd1cd8ec90955d99d19ca9e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8d09658f7a8d17ccc733dcef14908e3b);
#
#
#         var popup_638aad95968d06c2bb344dc4a904eef7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c0ebdac3dc838ccbcef1f1456fab5d2 = $(`&lt;div id=&quot;html_2c0ebdac3dc838ccbcef1f1456fab5d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_638aad95968d06c2bb344dc4a904eef7.setContent(html_2c0ebdac3dc838ccbcef1f1456fab5d2);
#
#
#
#         marker_ae4651d1bd1cd8ec90955d99d19ca9e3.bindPopup(popup_638aad95968d06c2bb344dc4a904eef7)
#         ;
#
#
#
#
#             var marker_ef286b65207cd19b83e728b42650ce65 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8d09658f7a8d17ccc733dcef14908e3b);
#
#
#         var popup_09247e750974ada2b5f2a6694cf14baa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40aae7d09a94f198aad54d3890ab9a20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40aae7d09a94f198aad54d3890ab9a20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40aae7d09a94f198aad54d3890ab9a20 = L.map(
#                 &quot;map_40aae7d09a94f198aad54d3890ab9a20&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b34eed75070f1d88216f507487cd68d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b34eed75070f1d88216f507487cd68d6.addTo(map_40aae7d09a94f198aad54d3890ab9a20);
#
#
#             var feature_group_ce4999f2fd12dc9c4d3a8ae1fa26dea0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ce4999f2fd12dc9c4d3a8ae1fa26dea0.addTo(map_40aae7d09a94f198aad54d3890ab9a20);
#
#
#             var feature_group_sub_group_424ece9264d1eb6195a1994678c477c1 = L.featureGroup.subGroup(
#                 feature_group_ce4999f2fd12dc9c4d3a8ae1fa26dea0
#             );
#
#
#             var marker_b52396e1f2161c71609a85e06f0f1ddb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_424ece9264d1eb6195a1994678c477c1);
#
#
#         var popup_07aac43272e32d4506dfbd5024692ac7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b01dc142ee122230fa36852b52e06376 = $(`&lt;div id=&quot;html_b01dc142ee122230fa36852b52e06376&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_07aac43272e32d4506dfbd5024692ac7.setContent(html_b01dc142ee122230fa36852b52e06376);
#
#
#
#         marker_b52396e1f2161c71609a85e06f0f1ddb.bindPopup(popup_07aac43272e32d4506dfbd5024692ac7)
#         ;
#
#
#
#
#             var marker_545d8c4f9653d59cd5cbc2f87a94e881 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_424ece9264d1eb6195a1994678c477c1);
#
#
#         var popup_bb1fb5b1e50ad609d364e46978e7571a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7946daaf612822d61298a2aa02092fd5 = $(`&lt;div id=&quot;html_7946daaf612822d61298a2aa02092fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bb1fb5b1e50ad609d364e46978e7571a.setContent(html_7946daaf612822d61298a2aa02092fd5);
#
#
#
#         marker_545d8c4f9653d59cd5cbc2f87a94e881.bindPopup(popup_bb1fb5b1e50ad609d364e46978e7571a)
#         ;
#
#
#
#
#             var marker_a753c712b424ea50bac479f3059645ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_424ece9264d1eb6195a1994678c477c1);
#
#
#         var popup_074e85f878d73c537212244f5861f931 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bb2c8488cb35fcd1812e8c871586b79 = $(`&lt;div id=&quot;html_3bb2c8488cb35fcd1812e8c871586b79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_074e85f878d73c537212244f5861f931.setContent(html_3bb2c8488cb35fcd1812e8c871586b79);
#
#
#
#         marker_a753c712b424ea50bac479f3059645ad.bindPopup(popup_074e85f878d73c537212244f5861f931)
#         ;
#
#
#
#
#             var marker_c7cf8e4e3885bb7bd60db4f3842a9ff4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_424ece9264d1eb6195a1994678c477c1);
#
#
#         var popup_5bac9af7081602cedaccaa08651e52e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce2ec970ab92b0bef382686bbcade24b = $(`&lt;div id=&quot;html_ce2ec970ab92b0bef382686bbcade24b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5bac9af7081602cedaccaa08651e52e4.setContent(html_ce2ec970ab92b0bef382686bbcade24b);
#
#
#
#         marker_
