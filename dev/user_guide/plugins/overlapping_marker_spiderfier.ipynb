# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16f61095c4adff212be455c581a74488 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16f61095c4adff212be455c581a74488&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16f61095c4adff212be455c581a74488 = L.map(
#                 &quot;map_16f61095c4adff212be455c581a74488&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ab835f4115705ed717d8c1f1f5523a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ab835f4115705ed717d8c1f1f5523a6.addTo(map_16f61095c4adff212be455c581a74488);
#
#
#             var marker_8d49ad5b230f3799561395b4cfb185db = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_16f61095c4adff212be455c581a74488);
#
#
#         var popup_42f4b625222a4a37d734ae64b2574644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42d1aa72de380ca40757cb3a8b0ca58c = $(`&lt;div id=&quot;html_42d1aa72de380ca40757cb3a8b0ca58c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_42f4b625222a4a37d734ae64b2574644.setContent(html_42d1aa72de380ca40757cb3a8b0ca58c);
#
#
#
#         marker_8d49ad5b230f3799561395b4cfb185db.bindPopup(popup_42f4b625222a4a37d734ae64b2574644)
#         ;
#
#
#
#
#             var marker_d500cd4214e18f74c4b34a84871bc8ba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_16f61095c4adff212be455c581a74488);
#
#
#         var popup_b4f33b53740eeba8447d7fab5786d67d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50fbc6d64ef8a59f6ebeaffb0c059daa = $(`&lt;div id=&quot;html_50fbc6d64ef8a59f6ebeaffb0c059daa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b4f33b53740eeba8447d7fab5786d67d.setContent(html_50fbc6d64ef8a59f6ebeaffb0c059daa);
#
#
#
#         marker_d500cd4214e18f74c4b34a84871bc8ba.bindPopup(popup_b4f33b53740eeba8447d7fab5786d67d)
#         ;
#
#
#
#
#             var marker_ca94f8f819fa269f30690f83315d29db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_16f61095c4adff212be455c581a74488);
#
#
#         var popup_936fb47a0e5477685c236d557494ad3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b823e93349360aac8c91d2cbee14c6f = $(`&lt;div id=&quot;html_1b823e93349360aac8c91d2cbee14c6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_936fb47a0e5477685c236d557494ad3a.setContent(html_1b823e93349360aac8c91d2cbee14c6f);
#
#
#
#         marker_ca94f8f819fa269f30690f83315d29db.bindPopup(popup_936fb47a0e5477685c236d557494ad3a)
#         ;
#
#
#
#
#             var marker_5bdb46493899b150a06d2f4ca4797f15 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_16f61095c4adff212be455c581a74488);
#
#
#         var popup_5231c2337ece7303847ca518a6b6596f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30d08707b4e2f7991bb362313c45e5f7 = $(`&lt;div id=&quot;html_30d08707b4e2f7991bb362313c45e5f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5231c2337ece7303847ca518a6b6596f.setContent(html_30d08707b4e2f7991bb362313c45e5f7);
#
#
#
#         marker_5bdb46493899b150a06d2f4ca4797f15.bindPopup(popup_5231c2337ece7303847ca518a6b6596f)
#         ;
#
#
#
#
#             var marker_809cf0e6c709f843e720cc6876ddbdac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_16f61095c4adff212be455c581a74488);
#
#
#         var popup_2a7981298792c17a19a04067bd9cdb55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ea4d9728d94b8f60769bd5abf293a09 = $(`&lt;div id=&quot;html_1ea4d9728d94b8f60769bd5abf293a09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2a7981298792c17a19a04067bd9cdb55.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c04607fe4f1bdc006245e03e1ba688e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c04607fe4f1bdc006245e03e1ba688e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c04607fe4f1bdc006245e03e1ba688e = L.map(
#                 &quot;map_6c04607fe4f1bdc006245e03e1ba688e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4eee74121fbce70a84506dbe33d95798 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4eee74121fbce70a84506dbe33d95798.addTo(map_6c04607fe4f1bdc006245e03e1ba688e);
#
#
#             var feature_group_5aca4205752818dd6c3ab4495a530131 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d37dd2cb532c6fe7d12e6d9996e947d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5aca4205752818dd6c3ab4495a530131);
#
#
#         var popup_ea2652822e7aac863483b616fc20b9b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_473ec3072f084f162e53025cac0835bd = $(`&lt;div id=&quot;html_473ec3072f084f162e53025cac0835bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ea2652822e7aac863483b616fc20b9b6.setContent(html_473ec3072f084f162e53025cac0835bd);
#
#
#
#         marker_d37dd2cb532c6fe7d12e6d9996e947d2.bindPopup(popup_ea2652822e7aac863483b616fc20b9b6)
#         ;
#
#
#
#
#             var marker_31cf9a091202408e8c4054c2c4bed4ec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5aca4205752818dd6c3ab4495a530131);
#
#
#         var popup_90539d85d7464a446aa8ff40e2c6baf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23005bb614c5da9544b12c4ce093c0e9 = $(`&lt;div id=&quot;html_23005bb614c5da9544b12c4ce093c0e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_90539d85d7464a446aa8ff40e2c6baf6.setContent(html_23005bb614c5da9544b12c4ce093c0e9);
#
#
#
#         marker_31cf9a091202408e8c4054c2c4bed4ec.bindPopup(popup_90539d85d7464a446aa8ff40e2c6baf6)
#         ;
#
#
#
#
#             var marker_fe1942e25f0170304ee91a8657f64f59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5aca4205752818dd6c3ab4495a530131);
#
#
#         var popup_eb52a656ff795709545701bc596cc36d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d5f21eada837a00e4bc8d6db70d90aa = $(`&lt;div id=&quot;html_1d5f21eada837a00e4bc8d6db70d90aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_eb52a656ff795709545701bc596cc36d.setContent(html_1d5f21eada837a00e4bc8d6db70d90aa);
#
#
#
#         marker_fe1942e25f0170304ee91a8657f64f59.bindPopup(popup_eb52a656ff795709545701bc596cc36d)
#         ;
#
#
#
#
#             var marker_51476bcbdaf97752a32d003a89c822b8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5aca4205752818dd6c3ab4495a530131);
#
#
#         var popup_dfdb746c7448ca2192492fb9eaa3b392 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f69c6b711d67f6b9fcf043f9ba314211 = $(`&lt;div id=&quot;html_f69c6b711d67f6b9fcf043f9ba314211&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dfdb746c7448ca2192492fb9eaa3b392.setContent(html_f69c6b711d67f6b9fcf043f9ba314211);
#
#
#
#         marker_51476bcbdaf97752a32d003a89c822b8.bindPopup(popup_dfdb746c7448ca2192492fb9eaa3b392)
#         ;
#
#
#
#
#             var marker_1f051af718eea1dc1bdddd6f4ce3182c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5aca4205752818dd6c3ab4495a530131);
#
#
#         var popup_401d7a32c5294f2d85a77bf13401bc1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbfd78de84c7d859ba04f2b11ad0d114 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbfd78de84c7d859ba04f2b11ad0d114&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbfd78de84c7d859ba04f2b11ad0d114 = L.map(
#                 &quot;map_dbfd78de84c7d859ba04f2b11ad0d114&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa86a46717ff7530431e25eefff51a8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa86a46717ff7530431e25eefff51a8b.addTo(map_dbfd78de84c7d859ba04f2b11ad0d114);
#
#
#             var feature_group_dc1d215defa7019f5e85e6849f9d1dd8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dc1d215defa7019f5e85e6849f9d1dd8.addTo(map_dbfd78de84c7d859ba04f2b11ad0d114);
#
#
#             var feature_group_sub_group_b46bf9b909b5438beb49903c94e674fd = L.featureGroup.subGroup(
#                 feature_group_dc1d215defa7019f5e85e6849f9d1dd8
#             );
#
#
#             var marker_c7f481b38c225e3eded3784bb11ad808 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b46bf9b909b5438beb49903c94e674fd);
#
#
#         var popup_48dd50c0c9d0d33df828400a38c160e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4b56f90a82f22db796d9d9df212a0fe = $(`&lt;div id=&quot;html_c4b56f90a82f22db796d9d9df212a0fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_48dd50c0c9d0d33df828400a38c160e8.setContent(html_c4b56f90a82f22db796d9d9df212a0fe);
#
#
#
#         marker_c7f481b38c225e3eded3784bb11ad808.bindPopup(popup_48dd50c0c9d0d33df828400a38c160e8)
#         ;
#
#
#
#
#             var marker_76030cdebf88db057d89ebbbcf446a5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b46bf9b909b5438beb49903c94e674fd);
#
#
#         var popup_7fc16c965b7c1fbc6bf59f7a4774d64c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_857f8e118badfb978dddf6ac4e6e422d = $(`&lt;div id=&quot;html_857f8e118badfb978dddf6ac4e6e422d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7fc16c965b7c1fbc6bf59f7a4774d64c.setContent(html_857f8e118badfb978dddf6ac4e6e422d);
#
#
#
#         marker_76030cdebf88db057d89ebbbcf446a5d.bindPopup(popup_7fc16c965b7c1fbc6bf59f7a4774d64c)
#         ;
#
#
#
#
#             var marker_84dc3fb56e20c6a22d13199e9760d033 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b46bf9b909b5438beb49903c94e674fd);
#
#
#         var popup_1edd3f53a8bedc92d29862eeb090f684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddfa28ffc5dbe08409493655b48cfc20 = $(`&lt;div id=&quot;html_ddfa28ffc5dbe08409493655b48cfc20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1edd3f53a8bedc92d29862eeb090f684.setContent(html_ddfa28ffc5dbe08409493655b48cfc20);
#
#
#
#         marker_84dc3fb56e20c6a22d13199e9760d033.bindPopup(popup_1edd3f53a8bedc92d29862eeb090f684)
#         ;
#
#
#
#
#             var marker_2fef5c7555beb98ea4e5579a53f2f227 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b46bf9b909b5438beb49903c94e674fd);
#
#
#         var popup_d8a8a0b17bef83cc2a5f31a29f7f4826 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab7ef8c5788f77212f73a3426971b226 = $(`&lt;div id=&quot;html_ab7ef8c5788f77212f73a3426971b226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d8a8a0b17bef83cc2a5f31a29f7f4826.setContent(html_ab7ef8c5788f77212f73a3426971b226);
#
#
#
#         marker_
