# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7f3b5203e385f4c68d42db641f636fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7f3b5203e385f4c68d42db641f636fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7f3b5203e385f4c68d42db641f636fa = L.map(
#                 &quot;map_e7f3b5203e385f4c68d42db641f636fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e821c5896680a1898eb83202f06cf7bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e821c5896680a1898eb83202f06cf7bc.addTo(map_e7f3b5203e385f4c68d42db641f636fa);
#
#
#             var marker_11271ea6a09e422c004c345259282ddf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e7f3b5203e385f4c68d42db641f636fa);
#
#
#         var popup_e04707e0e4ea3569e0de204c1dc1f80d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9d4d9bee37bda344c5cae464ab89718 = $(`&lt;div id=&quot;html_e9d4d9bee37bda344c5cae464ab89718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e04707e0e4ea3569e0de204c1dc1f80d.setContent(html_e9d4d9bee37bda344c5cae464ab89718);
#
#
#
#         marker_11271ea6a09e422c004c345259282ddf.bindPopup(popup_e04707e0e4ea3569e0de204c1dc1f80d)
#         ;
#
#
#
#
#             var marker_7813babc430160ece34b1c24b3688d08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e7f3b5203e385f4c68d42db641f636fa);
#
#
#         var popup_e533ec67ccbfa50ba56853098e859042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8da1bf6dfa9a628ebecd4fbbfb9f1d96 = $(`&lt;div id=&quot;html_8da1bf6dfa9a628ebecd4fbbfb9f1d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e533ec67ccbfa50ba56853098e859042.setContent(html_8da1bf6dfa9a628ebecd4fbbfb9f1d96);
#
#
#
#         marker_7813babc430160ece34b1c24b3688d08.bindPopup(popup_e533ec67ccbfa50ba56853098e859042)
#         ;
#
#
#
#
#             var marker_14a70937daf54454e43f3fa977116fd8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e7f3b5203e385f4c68d42db641f636fa);
#
#
#         var popup_e3a55ef4120503d268ca8486507135dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a5fd3b8088557fea9d4ec24c95d6272 = $(`&lt;div id=&quot;html_5a5fd3b8088557fea9d4ec24c95d6272&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e3a55ef4120503d268ca8486507135dd.setContent(html_5a5fd3b8088557fea9d4ec24c95d6272);
#
#
#
#         marker_14a70937daf54454e43f3fa977116fd8.bindPopup(popup_e3a55ef4120503d268ca8486507135dd)
#         ;
#
#
#
#
#             var marker_654f7e80a2060c1151601b621ac0980e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e7f3b5203e385f4c68d42db641f636fa);
#
#
#         var popup_332a542417321f7a1a99ee4b634029f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ce0dcec43b6c383e0eb625d2281f653 = $(`&lt;div id=&quot;html_4ce0dcec43b6c383e0eb625d2281f653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_332a542417321f7a1a99ee4b634029f6.setContent(html_4ce0dcec43b6c383e0eb625d2281f653);
#
#
#
#         marker_654f7e80a2060c1151601b621ac0980e.bindPopup(popup_332a542417321f7a1a99ee4b634029f6)
#         ;
#
#
#
#
#             var marker_1265a941bd6e6c7ad78e6f2593180bc9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e7f3b5203e385f4c68d42db641f636fa);
#
#
#         var popup_7c82c8221812512e11d93b9f9a6452a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4060d8d3f5d89ee218bda3cde5b3a4b = $(`&lt;div id=&quot;html_f4060d8d3f5d89ee218bda3cde5b3a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c82c8221812512e11d93b9f9a6452a1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9dca0f9b106d7af6725d62873346929 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9dca0f9b106d7af6725d62873346929&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9dca0f9b106d7af6725d62873346929 = L.map(
#                 &quot;map_f9dca0f9b106d7af6725d62873346929&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8570e4e2d55863b6d29e80bdfba7660 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8570e4e2d55863b6d29e80bdfba7660.addTo(map_f9dca0f9b106d7af6725d62873346929);
#
#
#             var feature_group_455770fccce4be7748b16bc2ad5dec60 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_36a430396a206a19434cf99ce7711902 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_455770fccce4be7748b16bc2ad5dec60);
#
#
#         var popup_5af3bd50061729162898566a4cf716b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28392919b58ae01064a502f38de4ee1b = $(`&lt;div id=&quot;html_28392919b58ae01064a502f38de4ee1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5af3bd50061729162898566a4cf716b4.setContent(html_28392919b58ae01064a502f38de4ee1b);
#
#
#
#         marker_36a430396a206a19434cf99ce7711902.bindPopup(popup_5af3bd50061729162898566a4cf716b4)
#         ;
#
#
#
#
#             var marker_9dce2cf2d6c352bc1de0c5ea4b34a8ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_455770fccce4be7748b16bc2ad5dec60);
#
#
#         var popup_0c43cb9da924e305c1d3f2d1f1f109d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3c0d1cf654ca8ed2ba6178d7b6e4d4a = $(`&lt;div id=&quot;html_e3c0d1cf654ca8ed2ba6178d7b6e4d4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0c43cb9da924e305c1d3f2d1f1f109d6.setContent(html_e3c0d1cf654ca8ed2ba6178d7b6e4d4a);
#
#
#
#         marker_9dce2cf2d6c352bc1de0c5ea4b34a8ac.bindPopup(popup_0c43cb9da924e305c1d3f2d1f1f109d6)
#         ;
#
#
#
#
#             var marker_b135ebb506d3f9d778975e10294b2645 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_455770fccce4be7748b16bc2ad5dec60);
#
#
#         var popup_ec84f22640a723d4434ec32842bb27e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa6fe8243eb8fbfcd267c8bd40a882dd = $(`&lt;div id=&quot;html_aa6fe8243eb8fbfcd267c8bd40a882dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ec84f22640a723d4434ec32842bb27e2.setContent(html_aa6fe8243eb8fbfcd267c8bd40a882dd);
#
#
#
#         marker_b135ebb506d3f9d778975e10294b2645.bindPopup(popup_ec84f22640a723d4434ec32842bb27e2)
#         ;
#
#
#
#
#             var marker_29fd88b2c2cbb74abe0df4c28128232a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_455770fccce4be7748b16bc2ad5dec60);
#
#
#         var popup_86c64aecb406ca92fbbf8dfa36402629 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ede29181827c35e6fed7da1ee27ee3e = $(`&lt;div id=&quot;html_7ede29181827c35e6fed7da1ee27ee3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_86c64aecb406ca92fbbf8dfa36402629.setContent(html_7ede29181827c35e6fed7da1ee27ee3e);
#
#
#
#         marker_29fd88b2c2cbb74abe0df4c28128232a.bindPopup(popup_86c64aecb406ca92fbbf8dfa36402629)
#         ;
#
#
#
#
#             var marker_d79c0e1470b781cc4e2cb865e4d17432 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_455770fccce4be7748b16bc2ad5dec60);
#
#
#         var popup_43b73da52341e124d43f477269d098d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_711b13ced2485f14c4d44884aef0783d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_711b13ced2485f14c4d44884aef0783d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_711b13ced2485f14c4d44884aef0783d = L.map(
#                 &quot;map_711b13ced2485f14c4d44884aef0783d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3a2a4e2ea916dc962f67ea3826c3a0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3a2a4e2ea916dc962f67ea3826c3a0f.addTo(map_711b13ced2485f14c4d44884aef0783d);
#
#
#             var feature_group_859371549da6277a17c8d202a87d9572 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_859371549da6277a17c8d202a87d9572.addTo(map_711b13ced2485f14c4d44884aef0783d);
#
#
#             var feature_group_sub_group_76075ab50d71af9778bacc3f58b1dc34 = L.featureGroup.subGroup(
#                 feature_group_859371549da6277a17c8d202a87d9572
#             );
#
#
#             var marker_5d5ff0bd88569be6f39198838d2ba8a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_76075ab50d71af9778bacc3f58b1dc34);
#
#
#         var popup_5616eb8c38eb064accecaa53ce804af5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f72a993bafb679c86e545c78e4dfcfe = $(`&lt;div id=&quot;html_5f72a993bafb679c86e545c78e4dfcfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5616eb8c38eb064accecaa53ce804af5.setContent(html_5f72a993bafb679c86e545c78e4dfcfe);
#
#
#
#         marker_5d5ff0bd88569be6f39198838d2ba8a9.bindPopup(popup_5616eb8c38eb064accecaa53ce804af5)
#         ;
#
#
#
#
#             var marker_03111916d86806474ebf3d341d2ee60d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_76075ab50d71af9778bacc3f58b1dc34);
#
#
#         var popup_6e1946dc1f65fd7ba908c60d80f94f0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43e96fa7426d70ecb9c1dfe4253c7779 = $(`&lt;div id=&quot;html_43e96fa7426d70ecb9c1dfe4253c7779&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6e1946dc1f65fd7ba908c60d80f94f0d.setContent(html_43e96fa7426d70ecb9c1dfe4253c7779);
#
#
#
#         marker_03111916d86806474ebf3d341d2ee60d.bindPopup(popup_6e1946dc1f65fd7ba908c60d80f94f0d)
#         ;
#
#
#
#
#             var marker_531dc69d12eb411015a6f4d9e1c2d719 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_76075ab50d71af9778bacc3f58b1dc34);
#
#
#         var popup_3c777c9b07d46dfee9c82883b84bd95f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_585e17d1d51a180abee7cc53cee3b4a1 = $(`&lt;div id=&quot;html_585e17d1d51a180abee7cc53cee3b4a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3c777c9b07d46dfee9c82883b84bd95f.setContent(html_585e17d1d51a180abee7cc53cee3b4a1);
#
#
#
#         marker_531dc69d12eb411015a6f4d9e1c2d719.bindPopup(popup_3c777c9b07d46dfee9c82883b84bd95f)
#         ;
#
#
#
#
#             var marker_114a76aaa0185d1b4303e229de7ff895 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_76075ab50d71af9778bacc3f58b1dc34);
#
#
#         var popup_d739e188e3611f3bbf9751f05ce92aa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb8af92708a0106c5c795d72b6a36a2d = $(`&lt;div id=&quot;html_bb8af92708a0106c5c795d72b6a36a2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d739e188e3611f3bbf9751f05ce92aa6.setContent(html_bb8af92708a0106c5c795d72b6a36a2d);
#
#
#
#         marker_
