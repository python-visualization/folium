# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9238a2d72eef75ed959715278bf67e6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9238a2d72eef75ed959715278bf67e6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9238a2d72eef75ed959715278bf67e6d = L.map(
#                 &quot;map_9238a2d72eef75ed959715278bf67e6d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f09bb2ea0945a969576abb08b11bfad4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f09bb2ea0945a969576abb08b11bfad4.addTo(map_9238a2d72eef75ed959715278bf67e6d);
#
#
#             var marker_5569c7b933c4e3a3adc33001f2b9a3bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9238a2d72eef75ed959715278bf67e6d);
#
#
#         var popup_64c8af17030c26fba6ef8d412b3f8aae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10bc84b5823511b5e338c3745a5435ca = $(`&lt;div id=&quot;html_10bc84b5823511b5e338c3745a5435ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_64c8af17030c26fba6ef8d412b3f8aae.setContent(html_10bc84b5823511b5e338c3745a5435ca);
#
#
#
#         marker_5569c7b933c4e3a3adc33001f2b9a3bf.bindPopup(popup_64c8af17030c26fba6ef8d412b3f8aae)
#         ;
#
#
#
#
#             var marker_31198a3351fd2112a33ee840857aff2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9238a2d72eef75ed959715278bf67e6d);
#
#
#         var popup_28303cb6433ac4449ecf9c686f7d3a9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c7ff4053e244568a249159bcf5fbbbf = $(`&lt;div id=&quot;html_6c7ff4053e244568a249159bcf5fbbbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_28303cb6433ac4449ecf9c686f7d3a9f.setContent(html_6c7ff4053e244568a249159bcf5fbbbf);
#
#
#
#         marker_31198a3351fd2112a33ee840857aff2f.bindPopup(popup_28303cb6433ac4449ecf9c686f7d3a9f)
#         ;
#
#
#
#
#             var marker_767302ea1931a2c7b666d5c4737f13be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9238a2d72eef75ed959715278bf67e6d);
#
#
#         var popup_091df6f6f0c75cef27eaaa069c6f5336 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5ffb1a23b21180c6079a3a2b8251890 = $(`&lt;div id=&quot;html_e5ffb1a23b21180c6079a3a2b8251890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_091df6f6f0c75cef27eaaa069c6f5336.setContent(html_e5ffb1a23b21180c6079a3a2b8251890);
#
#
#
#         marker_767302ea1931a2c7b666d5c4737f13be.bindPopup(popup_091df6f6f0c75cef27eaaa069c6f5336)
#         ;
#
#
#
#
#             var marker_0a2ce9b8cadb20a3058cce8b67ddee6f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9238a2d72eef75ed959715278bf67e6d);
#
#
#         var popup_06a93552555ce171486219303c988b34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f0ca787319def3a8219dda810abcb08 = $(`&lt;div id=&quot;html_0f0ca787319def3a8219dda810abcb08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_06a93552555ce171486219303c988b34.setContent(html_0f0ca787319def3a8219dda810abcb08);
#
#
#
#         marker_0a2ce9b8cadb20a3058cce8b67ddee6f.bindPopup(popup_06a93552555ce171486219303c988b34)
#         ;
#
#
#
#
#             var marker_b75e2d1f5f65ba7abf0da7ef6935d4d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9238a2d72eef75ed959715278bf67e6d);
#
#
#         var popup_6a81f9c5e3e37a2c6f3a5a40686a4764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaba7af14f9ad23af8a2f3690bcf6951 = $(`&lt;div id=&quot;html_aaba7af14f9ad23af8a2f3690bcf6951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6a81f9c5e3e37a2c6f3a5a40686a4764.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd163090e53ac7985cfbc001b4862cbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd163090e53ac7985cfbc001b4862cbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd163090e53ac7985cfbc001b4862cbb = L.map(
#                 &quot;map_cd163090e53ac7985cfbc001b4862cbb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_364ae59c549b12c8de766cd3ddd2273c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_364ae59c549b12c8de766cd3ddd2273c.addTo(map_cd163090e53ac7985cfbc001b4862cbb);
#
#
#             var feature_group_29c1ef6dec28f21ec517b1ec23a7ea4f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f623c4115acb237621ebc494c7a0fcfb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_29c1ef6dec28f21ec517b1ec23a7ea4f);
#
#
#         var popup_f58d3926bcb43d4dae234d009392ef49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6149cd201e6728d25b67f2230b5dace8 = $(`&lt;div id=&quot;html_6149cd201e6728d25b67f2230b5dace8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f58d3926bcb43d4dae234d009392ef49.setContent(html_6149cd201e6728d25b67f2230b5dace8);
#
#
#
#         marker_f623c4115acb237621ebc494c7a0fcfb.bindPopup(popup_f58d3926bcb43d4dae234d009392ef49)
#         ;
#
#
#
#
#             var marker_8acc290d1198c77b5f61947987344457 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_29c1ef6dec28f21ec517b1ec23a7ea4f);
#
#
#         var popup_31b8d9ae7b9515bcd878e8b402d2f1eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b435e698cc8749942b5444192b05b17d = $(`&lt;div id=&quot;html_b435e698cc8749942b5444192b05b17d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_31b8d9ae7b9515bcd878e8b402d2f1eb.setContent(html_b435e698cc8749942b5444192b05b17d);
#
#
#
#         marker_8acc290d1198c77b5f61947987344457.bindPopup(popup_31b8d9ae7b9515bcd878e8b402d2f1eb)
#         ;
#
#
#
#
#             var marker_ebdbfc384e8ca803aa2cc3f6d2ffdfee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_29c1ef6dec28f21ec517b1ec23a7ea4f);
#
#
#         var popup_93ee3a6dc427c25f84d4aa375c0ca25f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52aa37fa51a60bf3b912cc056c748c13 = $(`&lt;div id=&quot;html_52aa37fa51a60bf3b912cc056c748c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_93ee3a6dc427c25f84d4aa375c0ca25f.setContent(html_52aa37fa51a60bf3b912cc056c748c13);
#
#
#
#         marker_ebdbfc384e8ca803aa2cc3f6d2ffdfee.bindPopup(popup_93ee3a6dc427c25f84d4aa375c0ca25f)
#         ;
#
#
#
#
#             var marker_a4f937ff152c043f552f2c9b374e2f19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_29c1ef6dec28f21ec517b1ec23a7ea4f);
#
#
#         var popup_46a50e56f7ca84083ba5b8be91609e20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ff8e4838e0517fa107d8a9c7b948a05 = $(`&lt;div id=&quot;html_5ff8e4838e0517fa107d8a9c7b948a05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_46a50e56f7ca84083ba5b8be91609e20.setContent(html_5ff8e4838e0517fa107d8a9c7b948a05);
#
#
#
#         marker_a4f937ff152c043f552f2c9b374e2f19.bindPopup(popup_46a50e56f7ca84083ba5b8be91609e20)
#         ;
#
#
#
#
#             var marker_e0c07cfabb4758813140941e7d764e85 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_29c1ef6dec28f21ec517b1ec23a7ea4f);
#
#
#         var popup_33b8a6f4edb64c5a04d08424b0a8e331 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_199df30650f7ef77435412d5c3b2e27b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_199df30650f7ef77435412d5c3b2e27b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_199df30650f7ef77435412d5c3b2e27b = L.map(
#                 &quot;map_199df30650f7ef77435412d5c3b2e27b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da49679c9a6d0103c85ab8e9bb6eac8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da49679c9a6d0103c85ab8e9bb6eac8d.addTo(map_199df30650f7ef77435412d5c3b2e27b);
#
#
#             var feature_group_f6ac966fd840921d3463786c5fa13f43 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f6ac966fd840921d3463786c5fa13f43.addTo(map_199df30650f7ef77435412d5c3b2e27b);
#
#
#             var feature_group_sub_group_cbcd85e6e2b648530e97767d6bc7de8c = L.featureGroup.subGroup(
#                 feature_group_f6ac966fd840921d3463786c5fa13f43
#             );
#
#
#             var marker_bfc35930d3a8fb8bb7ff622f04dc36a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbcd85e6e2b648530e97767d6bc7de8c);
#
#
#         var popup_5151be372c85b8832020ca00ace7c226 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c41e02a6e0a3df324369e50e0dc3f7c5 = $(`&lt;div id=&quot;html_c41e02a6e0a3df324369e50e0dc3f7c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5151be372c85b8832020ca00ace7c226.setContent(html_c41e02a6e0a3df324369e50e0dc3f7c5);
#
#
#
#         marker_bfc35930d3a8fb8bb7ff622f04dc36a6.bindPopup(popup_5151be372c85b8832020ca00ace7c226)
#         ;
#
#
#
#
#             var marker_abbedae463045ed40419d1e0bdeb70b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbcd85e6e2b648530e97767d6bc7de8c);
#
#
#         var popup_5e720e6feaad5a68683017f38cfcb03e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df1b9fd643128114746ec390a682e02b = $(`&lt;div id=&quot;html_df1b9fd643128114746ec390a682e02b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5e720e6feaad5a68683017f38cfcb03e.setContent(html_df1b9fd643128114746ec390a682e02b);
#
#
#
#         marker_abbedae463045ed40419d1e0bdeb70b5.bindPopup(popup_5e720e6feaad5a68683017f38cfcb03e)
#         ;
#
#
#
#
#             var marker_abb0240e54ea5a849e0fe940a95d78db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbcd85e6e2b648530e97767d6bc7de8c);
#
#
#         var popup_2e25167be984184b99ece6a0b730faa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_781820d39bd3acbcba1d24472c53fd5e = $(`&lt;div id=&quot;html_781820d39bd3acbcba1d24472c53fd5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2e25167be984184b99ece6a0b730faa5.setContent(html_781820d39bd3acbcba1d24472c53fd5e);
#
#
#
#         marker_abb0240e54ea5a849e0fe940a95d78db.bindPopup(popup_2e25167be984184b99ece6a0b730faa5)
#         ;
#
#
#
#
#             var marker_15a93fea35c9a03a352ffc4709a864ad = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbcd85e6e2b648530e97767d6bc7de8c);
#
#
#         var popup_099807f2397571f2eb6b570cb71aa98c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82565653494133b5580f27827613a51c = $(`&lt;div id=&quot;html_82565653494133b5580f27827613a51c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_099807f2397571f2eb6b570cb71aa98c.setContent(html_82565653494133b5580f27827613a51c);
#
#
#
#         marker_
