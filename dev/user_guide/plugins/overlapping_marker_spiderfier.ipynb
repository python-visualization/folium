# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_230481e31e46a93696a067df036afb67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_230481e31e46a93696a067df036afb67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_230481e31e46a93696a067df036afb67 = L.map(
#                 &quot;map_230481e31e46a93696a067df036afb67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1755688b234fc712858f87517e60526 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1755688b234fc712858f87517e60526.addTo(map_230481e31e46a93696a067df036afb67);
#
#
#             var marker_eabe6a0ac51a4fbdf27ef5ef7c45bc5f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_230481e31e46a93696a067df036afb67);
#
#
#         var popup_d41843997143fe6938a3f73dc90864e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b75b36ff2f18e0ea69c8eb50f941328b = $(`&lt;div id=&quot;html_b75b36ff2f18e0ea69c8eb50f941328b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d41843997143fe6938a3f73dc90864e0.setContent(html_b75b36ff2f18e0ea69c8eb50f941328b);
#
#
#
#         marker_eabe6a0ac51a4fbdf27ef5ef7c45bc5f.bindPopup(popup_d41843997143fe6938a3f73dc90864e0)
#         ;
#
#
#
#
#             var marker_42663aaa1ee7e46e1c194ffe249ee557 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_230481e31e46a93696a067df036afb67);
#
#
#         var popup_5b9dc70ee136246c24e70a62739b95f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b572f005905936c83160903ee0c1faaf = $(`&lt;div id=&quot;html_b572f005905936c83160903ee0c1faaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5b9dc70ee136246c24e70a62739b95f4.setContent(html_b572f005905936c83160903ee0c1faaf);
#
#
#
#         marker_42663aaa1ee7e46e1c194ffe249ee557.bindPopup(popup_5b9dc70ee136246c24e70a62739b95f4)
#         ;
#
#
#
#
#             var marker_93055ffd4ebcd554aafeb365e67858f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_230481e31e46a93696a067df036afb67);
#
#
#         var popup_bcfc873ff1871291da5e5b8d2359f951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b4226c56a57596c4458b05e9709edbd = $(`&lt;div id=&quot;html_8b4226c56a57596c4458b05e9709edbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bcfc873ff1871291da5e5b8d2359f951.setContent(html_8b4226c56a57596c4458b05e9709edbd);
#
#
#
#         marker_93055ffd4ebcd554aafeb365e67858f0.bindPopup(popup_bcfc873ff1871291da5e5b8d2359f951)
#         ;
#
#
#
#
#             var marker_48ac9bca9542d2803329f6080cc053f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_230481e31e46a93696a067df036afb67);
#
#
#         var popup_b6c6c877c15cf880800a17d1e9fa35c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04b9db5b637fb4bdbb34aece74d1706f = $(`&lt;div id=&quot;html_04b9db5b637fb4bdbb34aece74d1706f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b6c6c877c15cf880800a17d1e9fa35c2.setContent(html_04b9db5b637fb4bdbb34aece74d1706f);
#
#
#
#         marker_48ac9bca9542d2803329f6080cc053f1.bindPopup(popup_b6c6c877c15cf880800a17d1e9fa35c2)
#         ;
#
#
#
#
#             var marker_3b0c7176bf5a06e3c052233a1490e966 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_230481e31e46a93696a067df036afb67);
#
#
#         var popup_e43f41bf7d9d6a44db643dee07692505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a19a4411a92b28983f6eab42a4249288 = $(`&lt;div id=&quot;html_a19a4411a92b28983f6eab42a4249288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e43f41bf7d9d6a44db643dee07692505.setContent(html_a19a4411a92b28983f6eab42a4249288);
#
#
#
#         marker_3b0c7176bf5a06e3c052233a1490e966.bindPopup(popup_e43f41bf7d9d6a44db643dee07692505)
#         ;
#
#
#
#
#             var marker_bc55886b55

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23fdd6989b4bddc65097a5657a83e034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23fdd6989b4bddc65097a5657a83e034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23fdd6989b4bddc65097a5657a83e034 = L.map(
#                 &quot;map_23fdd6989b4bddc65097a5657a83e034&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44c09e6d51a6dbec85caa3cd135f266e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44c09e6d51a6dbec85caa3cd135f266e.addTo(map_23fdd6989b4bddc65097a5657a83e034);
#
#
#             var feature_group_3d773ddd0d7434129b6969fece12093d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a9a7e7ce8f80793c3422b409c0a19a09 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d773ddd0d7434129b6969fece12093d);
#
#
#         var popup_0a80217436af293156ded1e8b00be006 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34ff609fbadf32b047dcf2ecb537f0e4 = $(`&lt;div id=&quot;html_34ff609fbadf32b047dcf2ecb537f0e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0a80217436af293156ded1e8b00be006.setContent(html_34ff609fbadf32b047dcf2ecb537f0e4);
#
#
#
#         marker_a9a7e7ce8f80793c3422b409c0a19a09.bindPopup(popup_0a80217436af293156ded1e8b00be006)
#         ;
#
#
#
#
#             var marker_bf7dead7a7136ed38177988445128392 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d773ddd0d7434129b6969fece12093d);
#
#
#         var popup_80d3c0b4f9dbdacc6b4d6f13027d8745 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341e503b4ebda315b1c14015e991391a = $(`&lt;div id=&quot;html_341e503b4ebda315b1c14015e991391a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_80d3c0b4f9dbdacc6b4d6f13027d8745.setContent(html_341e503b4ebda315b1c14015e991391a);
#
#
#
#         marker_bf7dead7a7136ed38177988445128392.bindPopup(popup_80d3c0b4f9dbdacc6b4d6f13027d8745)
#         ;
#
#
#
#
#             var marker_a3cca3645af72990f8a41fa6a3d60bec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d773ddd0d7434129b6969fece12093d);
#
#
#         var popup_2c617676100e7c8718aad27dff95e7a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e38285e4e969eae84d9b2f972f5ee46f = $(`&lt;div id=&quot;html_e38285e4e969eae84d9b2f972f5ee46f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2c617676100e7c8718aad27dff95e7a8.setContent(html_e38285e4e969eae84d9b2f972f5ee46f);
#
#
#
#         marker_a3cca3645af72990f8a41fa6a3d60bec.bindPopup(popup_2c617676100e7c8718aad27dff95e7a8)
#         ;
#
#
#
#
#             var marker_5bdc9c8d18602224db9eeb43beb7e260 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d773ddd0d7434129b6969fece12093d);
#
#
#         var popup_b177c3834cf7f294a7c5e167ee303548 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13317bff5be2fa82b21ee1020c1b9988 = $(`&lt;div id=&quot;html_13317bff5be2fa82b21ee1020c1b9988&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b177c3834cf7f294a7c5e167ee303548.setContent(html_13317bff5be2fa82b21ee1020c1b9988);
#
#
#
#         marker_5bdc9c8d18602224db9eeb43beb7e260.bindPopup(popup_b177c3834cf7f294a7c5e167ee303548)
#         ;
#
#
#
#
#             var marker_7c0de43f78595f25fbe7b61f3f0ba21d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d773ddd0d7434129b6969fece12093d);
#
#
#         var popup_92a43dab81cbed5f502b25d182197d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_830e94be721b126dacb8a9f49b7c5cbb = $(`&lt;div id=&quot;html_830e94be721b126dacb8a9f49b7c5cbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_92a43dab81cbed5f50

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_919a213ca001abe5285d71f0ea1ddad4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_919a213ca001abe5285d71f0ea1ddad4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_919a213ca001abe5285d71f0ea1ddad4 = L.map(
#                 &quot;map_919a213ca001abe5285d71f0ea1ddad4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c90056bd3bd04d4912a8991b71b71f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c90056bd3bd04d4912a8991b71b71f4.addTo(map_919a213ca001abe5285d71f0ea1ddad4);
#
#
#             var feature_group_c88bb0333816b53fc02688819adb88f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c88bb0333816b53fc02688819adb88f2.addTo(map_919a213ca001abe5285d71f0ea1ddad4);
#
#
#             var feature_group_sub_group_96049335f0edc190e16c25f0a5acd1d0 = L.featureGroup.subGroup(
#                 feature_group_c88bb0333816b53fc02688819adb88f2
#             );
#
#
#             var marker_277461923b1f45ccfbdb08fc643c35f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_96049335f0edc190e16c25f0a5acd1d0);
#
#
#         var popup_5d3f23cec836b3de13fce9ad27a4c73e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ce9ed3b72b931f41263a5daa7898f2a = $(`&lt;div id=&quot;html_8ce9ed3b72b931f41263a5daa7898f2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5d3f23cec836b3de13fce9ad27a4c73e.setContent(html_8ce9ed3b72b931f41263a5daa7898f2a);
#
#
#
#         marker_277461923b1f45ccfbdb08fc643c35f7.bindPopup(popup_5d3f23cec836b3de13fce9ad27a4c73e)
#         ;
#
#
#
#
#             var marker_107aec52632fa21874b8337dbdc76ea3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_96049335f0edc190e16c25f0a5acd1d0);
#
#
#         var popup_fc590586a36a07ffd5d4147e15529714 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_633d21d7602e54e4fc45648a85b9fc61 = $(`&lt;div id=&quot;html_633d21d7602e54e4fc45648a85b9fc61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fc590586a36a07ffd5d4147e15529714.setContent(html_633d21d7602e54e4fc45648a85b9fc61);
#
#
#
#         marker_107aec52632fa21874b8337dbdc76ea3.bindPopup(popup_fc590586a36a07ffd5d4147e15529714)
#         ;
#
#
#
#
#             var marker_0223932e850fcbcc62702d43956280dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_96049335f0edc190e16c25f0a5acd1d0);
#
#
#         var popup_7081aa1462d0d4110ed73cd156665136 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c44d7901744404afec8ede8867a21e9 = $(`&lt;div id=&quot;html_2c44d7901744404afec8ede8867a21e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7081aa1462d0d4110ed73cd156665136.setContent(html_2c44d7901744404afec8ede8867a21e9);
#
#
#
#         marker_0223932e850fcbcc62702d43956280dc.bindPopup(popup_7081aa1462d0d4110ed73cd156665136)
#         ;
#
#
#
#
#             var marker_f1291d4eb912bf58b6e41662e8e14dbf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_96049335f0edc190e16c25f0a5acd1d0);
#
#
#         var popup_5546730581688a9f442308bd238f32da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59ef590f6944d57d294e12641df95c2d = $(`&lt;div id=&quot;html_59ef590f6944d57d294e12641df95c2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5546730581688a9f442308bd238f32da.setContent(html_59ef590f6944d57d294e12641df95c2d);
#
#
#
#         marker_f1291d4eb912bf58b6e41662e8e14dbf.bindPopup(popup_5546730581688a9f442308bd238f32da)
#         ;
#
#
#
#
#             var marker_bb2b83e6c4ab55b1a6dcc7e5997c0dbe = L.marker(
#                 [45.050399999999996, 3.0504],
