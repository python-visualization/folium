# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdd070467a1d039e71f73ca51cf57f48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdd070467a1d039e71f73ca51cf57f48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cdd070467a1d039e71f73ca51cf57f48 = L.map(
#                 &quot;map_cdd070467a1d039e71f73ca51cf57f48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02f66e16e51341d1ba0289c6fda1ad14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02f66e16e51341d1ba0289c6fda1ad14.addTo(map_cdd070467a1d039e71f73ca51cf57f48);
#
#
#             var marker_060113b9661d4594d1f5969eb93ab802 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cdd070467a1d039e71f73ca51cf57f48);
#
#
#         var popup_d12f29ccb3946df000b790b26c23e288 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a031292fa89b83650a0f76a92e29ea = $(`&lt;div id=&quot;html_b2a031292fa89b83650a0f76a92e29ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d12f29ccb3946df000b790b26c23e288.setContent(html_b2a031292fa89b83650a0f76a92e29ea);
#
#
#
#         marker_060113b9661d4594d1f5969eb93ab802.bindPopup(popup_d12f29ccb3946df000b790b26c23e288)
#         ;
#
#
#
#
#             var marker_26543410dadc86308732ac0ba0b2d69d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cdd070467a1d039e71f73ca51cf57f48);
#
#
#         var popup_ddaac30fc21f5495b240e03e5426a2d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4f5d7e2058446994f532f8ba287d929 = $(`&lt;div id=&quot;html_e4f5d7e2058446994f532f8ba287d929&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ddaac30fc21f5495b240e03e5426a2d9.setContent(html_e4f5d7e2058446994f532f8ba287d929);
#
#
#
#         marker_26543410dadc86308732ac0ba0b2d69d.bindPopup(popup_ddaac30fc21f5495b240e03e5426a2d9)
#         ;
#
#
#
#
#             var marker_96ba1d75e771666ce28731b457cf3358 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cdd070467a1d039e71f73ca51cf57f48);
#
#
#         var popup_26623c373a417d6687ad06f6b1ea3841 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73ddb5c28175d5d7e288f3417c4690c1 = $(`&lt;div id=&quot;html_73ddb5c28175d5d7e288f3417c4690c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_26623c373a417d6687ad06f6b1ea3841.setContent(html_73ddb5c28175d5d7e288f3417c4690c1);
#
#
#
#         marker_96ba1d75e771666ce28731b457cf3358.bindPopup(popup_26623c373a417d6687ad06f6b1ea3841)
#         ;
#
#
#
#
#             var marker_7fcdc9520fbde7a9c4c61a1284bc1892 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cdd070467a1d039e71f73ca51cf57f48);
#
#
#         var popup_4d0ff7423d2e7c4dde29497d53ffde62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b9b9e2a7247db55c0997497508ed0ec = $(`&lt;div id=&quot;html_2b9b9e2a7247db55c0997497508ed0ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4d0ff7423d2e7c4dde29497d53ffde62.setContent(html_2b9b9e2a7247db55c0997497508ed0ec);
#
#
#
#         marker_7fcdc9520fbde7a9c4c61a1284bc1892.bindPopup(popup_4d0ff7423d2e7c4dde29497d53ffde62)
#         ;
#
#
#
#
#             var marker_f714dcf62979e5b940f0349d04a4b3e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cdd070467a1d039e71f73ca51cf57f48);
#
#
#         var popup_ab0d78ffdee0da110696d850a6d44a7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60c2724b7bde3a5058f8ba0c67ef94a2 = $(`&lt;div id=&quot;html_60c2724b7bde3a5058f8ba0c67ef94a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ab0d78ffdee0da110696d850a6d44a7d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b0ca29d40b44854083d5db931e3bddc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b0ca29d40b44854083d5db931e3bddc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b0ca29d40b44854083d5db931e3bddc = L.map(
#                 &quot;map_9b0ca29d40b44854083d5db931e3bddc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3628ed871946ec128730849e936c0b41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3628ed871946ec128730849e936c0b41.addTo(map_9b0ca29d40b44854083d5db931e3bddc);
#
#
#             var feature_group_b663b515b90e03301cd40eb2e60ef044 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c1118cc59962948015fa12ca677b8568 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b663b515b90e03301cd40eb2e60ef044);
#
#
#         var popup_24ff6f0f15cc8207271a1b4a88a7dc13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e8a61bcbc9dab1a775b67ddf2da1407 = $(`&lt;div id=&quot;html_0e8a61bcbc9dab1a775b67ddf2da1407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_24ff6f0f15cc8207271a1b4a88a7dc13.setContent(html_0e8a61bcbc9dab1a775b67ddf2da1407);
#
#
#
#         marker_c1118cc59962948015fa12ca677b8568.bindPopup(popup_24ff6f0f15cc8207271a1b4a88a7dc13)
#         ;
#
#
#
#
#             var marker_66e89f1ca6516818319caa59600fe3ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b663b515b90e03301cd40eb2e60ef044);
#
#
#         var popup_1145db3a7541d8c1144499f353d41757 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33e612dccd983b87bae5d58bf954a0cf = $(`&lt;div id=&quot;html_33e612dccd983b87bae5d58bf954a0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1145db3a7541d8c1144499f353d41757.setContent(html_33e612dccd983b87bae5d58bf954a0cf);
#
#
#
#         marker_66e89f1ca6516818319caa59600fe3ca.bindPopup(popup_1145db3a7541d8c1144499f353d41757)
#         ;
#
#
#
#
#             var marker_5e3d5913a2d2b2a5b796425284ca6938 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b663b515b90e03301cd40eb2e60ef044);
#
#
#         var popup_1b481316ddfc02bacdffea8085b84ac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0628a113080ae46c73162cce5e0a43dc = $(`&lt;div id=&quot;html_0628a113080ae46c73162cce5e0a43dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1b481316ddfc02bacdffea8085b84ac4.setContent(html_0628a113080ae46c73162cce5e0a43dc);
#
#
#
#         marker_5e3d5913a2d2b2a5b796425284ca6938.bindPopup(popup_1b481316ddfc02bacdffea8085b84ac4)
#         ;
#
#
#
#
#             var marker_97cb3f4a29bb51b1f7d412424c2146d1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b663b515b90e03301cd40eb2e60ef044);
#
#
#         var popup_460a7708d01189ee8ee17385390db1f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_700ed3832136e5455353f1da77e4e9d2 = $(`&lt;div id=&quot;html_700ed3832136e5455353f1da77e4e9d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_460a7708d01189ee8ee17385390db1f3.setContent(html_700ed3832136e5455353f1da77e4e9d2);
#
#
#
#         marker_97cb3f4a29bb51b1f7d412424c2146d1.bindPopup(popup_460a7708d01189ee8ee17385390db1f3)
#         ;
#
#
#
#
#             var marker_d5c0dd78509cc6d2ae41ab1745917e4f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b663b515b90e03301cd40eb2e60ef044);
#
#
#         var popup_6ec8a7d2771658d6e4482ad524b96478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bccae72f9dd16b2ac09617ee755b213c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bccae72f9dd16b2ac09617ee755b213c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bccae72f9dd16b2ac09617ee755b213c = L.map(
#                 &quot;map_bccae72f9dd16b2ac09617ee755b213c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b614217740bf74851367a1444211fd2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b614217740bf74851367a1444211fd2.addTo(map_bccae72f9dd16b2ac09617ee755b213c);
#
#
#             var feature_group_ed7a4f913136e55b0bca03b1463454c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ed7a4f913136e55b0bca03b1463454c9.addTo(map_bccae72f9dd16b2ac09617ee755b213c);
#
#
#             var feature_group_sub_group_1dc13079059f190cf75821379e81068e = L.featureGroup.subGroup(
#                 feature_group_ed7a4f913136e55b0bca03b1463454c9
#             );
#
#
#             var marker_6a307dd8f535ccaef4ff2bb2a246f783 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1dc13079059f190cf75821379e81068e);
#
#
#         var popup_638d09aa4c5e48fbe9a8ac1575f4b4e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80c4b5b7b48e45d2a29f8b67848a4fff = $(`&lt;div id=&quot;html_80c4b5b7b48e45d2a29f8b67848a4fff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_638d09aa4c5e48fbe9a8ac1575f4b4e2.setContent(html_80c4b5b7b48e45d2a29f8b67848a4fff);
#
#
#
#         marker_6a307dd8f535ccaef4ff2bb2a246f783.bindPopup(popup_638d09aa4c5e48fbe9a8ac1575f4b4e2)
#         ;
#
#
#
#
#             var marker_816741e305f14f17e9a68e5d5eb12f04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1dc13079059f190cf75821379e81068e);
#
#
#         var popup_5dae39cd751a3403c68070a17c7a46b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb1327acb6557cb4743dd4261a53df30 = $(`&lt;div id=&quot;html_cb1327acb6557cb4743dd4261a53df30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5dae39cd751a3403c68070a17c7a46b4.setContent(html_cb1327acb6557cb4743dd4261a53df30);
#
#
#
#         marker_816741e305f14f17e9a68e5d5eb12f04.bindPopup(popup_5dae39cd751a3403c68070a17c7a46b4)
#         ;
#
#
#
#
#             var marker_be4d453bcebd9101c64f48784efa6a31 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1dc13079059f190cf75821379e81068e);
#
#
#         var popup_33b519bd776feb38cbd26606ae367bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86ca8774909c53408d99dc63c90f7486 = $(`&lt;div id=&quot;html_86ca8774909c53408d99dc63c90f7486&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_33b519bd776feb38cbd26606ae367bf6.setContent(html_86ca8774909c53408d99dc63c90f7486);
#
#
#
#         marker_be4d453bcebd9101c64f48784efa6a31.bindPopup(popup_33b519bd776feb38cbd26606ae367bf6)
#         ;
#
#
#
#
#             var marker_964ff07c6ca73c59145d6d1473710700 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1dc13079059f190cf75821379e81068e);
#
#
#         var popup_eac6265c4ff46dfbfb28d5b659a558fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a8fde9d732be3f60b149988509d5cc4 = $(`&lt;div id=&quot;html_9a8fde9d732be3f60b149988509d5cc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eac6265c4ff46dfbfb28d5b659a558fa.setContent(html_9a8fde9d732be3f60b149988509d5cc4);
#
#
#
#         marker_
