# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b11770ddb0ce85636e288f2dfff7dce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b11770ddb0ce85636e288f2dfff7dce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b11770ddb0ce85636e288f2dfff7dce = L.map(
#                 &quot;map_5b11770ddb0ce85636e288f2dfff7dce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a355e97a0b4fa05efa7193262efd91d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a355e97a0b4fa05efa7193262efd91d4.addTo(map_5b11770ddb0ce85636e288f2dfff7dce);
#
#
#             var marker_ab5417536b13194a34ace4e6421803cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5b11770ddb0ce85636e288f2dfff7dce);
#
#
#         var popup_5cf57db7eb6fb2bbbaa70ed3e4a3092c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ca574c2af4fedef9e1d2277a2e68077 = $(`&lt;div id=&quot;html_6ca574c2af4fedef9e1d2277a2e68077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5cf57db7eb6fb2bbbaa70ed3e4a3092c.setContent(html_6ca574c2af4fedef9e1d2277a2e68077);
#
#
#
#         marker_ab5417536b13194a34ace4e6421803cf.bindPopup(popup_5cf57db7eb6fb2bbbaa70ed3e4a3092c)
#         ;
#
#
#
#
#             var marker_9850c33b3b0f32b11c6845f4338cfdbb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5b11770ddb0ce85636e288f2dfff7dce);
#
#
#         var popup_45c241a5b186097f5faaccf0d76e481b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c19e3df0b0695ac85d7e0d9213395917 = $(`&lt;div id=&quot;html_c19e3df0b0695ac85d7e0d9213395917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_45c241a5b186097f5faaccf0d76e481b.setContent(html_c19e3df0b0695ac85d7e0d9213395917);
#
#
#
#         marker_9850c33b3b0f32b11c6845f4338cfdbb.bindPopup(popup_45c241a5b186097f5faaccf0d76e481b)
#         ;
#
#
#
#
#             var marker_ffec5acc7bb2d1df5cf6a1ba188cf075 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5b11770ddb0ce85636e288f2dfff7dce);
#
#
#         var popup_49473502c2aafee3b009204ef6848aaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a2ab740b4a1dd1ad6d1423956d59b8f = $(`&lt;div id=&quot;html_7a2ab740b4a1dd1ad6d1423956d59b8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_49473502c2aafee3b009204ef6848aaf.setContent(html_7a2ab740b4a1dd1ad6d1423956d59b8f);
#
#
#
#         marker_ffec5acc7bb2d1df5cf6a1ba188cf075.bindPopup(popup_49473502c2aafee3b009204ef6848aaf)
#         ;
#
#
#
#
#             var marker_618cac79ff386b2e9001de4ec5ea83da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5b11770ddb0ce85636e288f2dfff7dce);
#
#
#         var popup_9b73cc281549b42080529a0837b304c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0e712cbc99cb8d10b8fd05e224fce76 = $(`&lt;div id=&quot;html_f0e712cbc99cb8d10b8fd05e224fce76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9b73cc281549b42080529a0837b304c9.setContent(html_f0e712cbc99cb8d10b8fd05e224fce76);
#
#
#
#         marker_618cac79ff386b2e9001de4ec5ea83da.bindPopup(popup_9b73cc281549b42080529a0837b304c9)
#         ;
#
#
#
#
#             var marker_26f3bb3585967d30c9ca187f05035435 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5b11770ddb0ce85636e288f2dfff7dce);
#
#
#         var popup_184dcfc5952a8e7cd30ef78cf20b73e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_828ba003308bcee59d7adc625b5ee5da = $(`&lt;div id=&quot;html_828ba003308bcee59d7adc625b5ee5da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_184dcfc5952a8e7cd30ef78cf20b73e7.setContent(html_828ba003308bcee59d7adc625b5ee5da);
#
#
#
#         marker_26f3bb3585967d30c9ca187f05035435.bindPopup(popup_184dcfc5952a8e7cd30ef78cf20b73e7)
#         ;
#
#
#
#
#             var marker_140de18d7c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14f89d41029c9291b96ab961f212f14d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14f89d41029c9291b96ab961f212f14d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14f89d41029c9291b96ab961f212f14d = L.map(
#                 &quot;map_14f89d41029c9291b96ab961f212f14d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c828f59823591606f342533dd5359f7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c828f59823591606f342533dd5359f7b.addTo(map_14f89d41029c9291b96ab961f212f14d);
#
#
#             var feature_group_fb367bc1c5cad7adbb8901850c50761f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_206ae788612e2403d630fd19d07af2fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fb367bc1c5cad7adbb8901850c50761f);
#
#
#         var popup_1f45182ba5afd280a0eb753bde4b279e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9a6afc332938fdcfb9b4e0764f8677d = $(`&lt;div id=&quot;html_c9a6afc332938fdcfb9b4e0764f8677d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1f45182ba5afd280a0eb753bde4b279e.setContent(html_c9a6afc332938fdcfb9b4e0764f8677d);
#
#
#
#         marker_206ae788612e2403d630fd19d07af2fa.bindPopup(popup_1f45182ba5afd280a0eb753bde4b279e)
#         ;
#
#
#
#
#             var marker_f1de24a7ccac733e319217001a4a72be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fb367bc1c5cad7adbb8901850c50761f);
#
#
#         var popup_05a9cdf661c111657b28c7c51160ded1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0df02d3789ae3277f97bb638dc8d214 = $(`&lt;div id=&quot;html_d0df02d3789ae3277f97bb638dc8d214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_05a9cdf661c111657b28c7c51160ded1.setContent(html_d0df02d3789ae3277f97bb638dc8d214);
#
#
#
#         marker_f1de24a7ccac733e319217001a4a72be.bindPopup(popup_05a9cdf661c111657b28c7c51160ded1)
#         ;
#
#
#
#
#             var marker_38d4fae1fcc67a62809d9368ad4ed146 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fb367bc1c5cad7adbb8901850c50761f);
#
#
#         var popup_b4d1e7e95b0fb2116716c499e4d45481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d72a617ef8224872dda6d2496715767 = $(`&lt;div id=&quot;html_6d72a617ef8224872dda6d2496715767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b4d1e7e95b0fb2116716c499e4d45481.setContent(html_6d72a617ef8224872dda6d2496715767);
#
#
#
#         marker_38d4fae1fcc67a62809d9368ad4ed146.bindPopup(popup_b4d1e7e95b0fb2116716c499e4d45481)
#         ;
#
#
#
#
#             var marker_aecdc1773e24e17ffaa9143678350dc9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fb367bc1c5cad7adbb8901850c50761f);
#
#
#         var popup_e7e97cc8b292f3b1ea12e2f8f43f7ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_289f2a4d8bd03dc4e82ec1ab5c29379d = $(`&lt;div id=&quot;html_289f2a4d8bd03dc4e82ec1ab5c29379d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e7e97cc8b292f3b1ea12e2f8f43f7ca5.setContent(html_289f2a4d8bd03dc4e82ec1ab5c29379d);
#
#
#
#         marker_aecdc1773e24e17ffaa9143678350dc9.bindPopup(popup_e7e97cc8b292f3b1ea12e2f8f43f7ca5)
#         ;
#
#
#
#
#             var marker_4f89fb12a2ea14101125bb3588c44f73 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fb367bc1c5cad7adbb8901850c50761f);
#
#
#         var popup_3d920d0a637adcb3858464b9e5386be7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1eab9c520f7d20e427548617673b66b6 = $(`&lt;div id=&quot;html_1eab9c520f7d20e427548617673b66b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_3d920d0a637adcb385

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbb360d29cce3bb6a1a7dc5563ab5422 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbb360d29cce3bb6a1a7dc5563ab5422&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbb360d29cce3bb6a1a7dc5563ab5422 = L.map(
#                 &quot;map_fbb360d29cce3bb6a1a7dc5563ab5422&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f83c03a361c7a99951f5d36d42e48772 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f83c03a361c7a99951f5d36d42e48772.addTo(map_fbb360d29cce3bb6a1a7dc5563ab5422);
#
#
#             var feature_group_08a38e1cd9293d16d41a963465375d0e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_08a38e1cd9293d16d41a963465375d0e.addTo(map_fbb360d29cce3bb6a1a7dc5563ab5422);
#
#
#             var feature_group_sub_group_ae5ce31e400bbc9224138b3daba01ff7 = L.featureGroup.subGroup(
#                 feature_group_08a38e1cd9293d16d41a963465375d0e
#             );
#
#
#             var marker_60b21d17bbaff9d9677c37ab20aae835 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae5ce31e400bbc9224138b3daba01ff7);
#
#
#         var popup_af256c3342cfbc04ed597d0eec223f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71daf80fb4a8e4274420a43275fa6850 = $(`&lt;div id=&quot;html_71daf80fb4a8e4274420a43275fa6850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_af256c3342cfbc04ed597d0eec223f71.setContent(html_71daf80fb4a8e4274420a43275fa6850);
#
#
#
#         marker_60b21d17bbaff9d9677c37ab20aae835.bindPopup(popup_af256c3342cfbc04ed597d0eec223f71)
#         ;
#
#
#
#
#             var marker_c39cebfd589e9ad733caaf400b9c7366 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae5ce31e400bbc9224138b3daba01ff7);
#
#
#         var popup_7d08ab0f7f5de0e5257fb14af725c69c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4c970afe24658f20523ec84ea41597c = $(`&lt;div id=&quot;html_b4c970afe24658f20523ec84ea41597c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7d08ab0f7f5de0e5257fb14af725c69c.setContent(html_b4c970afe24658f20523ec84ea41597c);
#
#
#
#         marker_c39cebfd589e9ad733caaf400b9c7366.bindPopup(popup_7d08ab0f7f5de0e5257fb14af725c69c)
#         ;
#
#
#
#
#             var marker_883ec8deff51d9e7f4734db38b093753 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae5ce31e400bbc9224138b3daba01ff7);
#
#
#         var popup_3669fd0a1728d7d8b0056da2b7622cf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82edf74e752fb8e366f9851e83c13d96 = $(`&lt;div id=&quot;html_82edf74e752fb8e366f9851e83c13d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3669fd0a1728d7d8b0056da2b7622cf8.setContent(html_82edf74e752fb8e366f9851e83c13d96);
#
#
#
#         marker_883ec8deff51d9e7f4734db38b093753.bindPopup(popup_3669fd0a1728d7d8b0056da2b7622cf8)
#         ;
#
#
#
#
#             var marker_b2fd96ed4520327abe27dc30d8ff0b5c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae5ce31e400bbc9224138b3daba01ff7);
#
#
#         var popup_0c9e6155be7ee9f1a52f0717af5e369b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdf3e1940f534c228349f58408455c22 = $(`&lt;div id=&quot;html_bdf3e1940f534c228349f58408455c22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0c9e6155be7ee9f1a52f0717af5e369b.setContent(html_bdf3e1940f534c228349f58408455c22);
#
#
#
#         marker_b2fd96ed4520327abe27dc30d8ff0b5c.bindPopup(popup_0c9e6155be7ee9f1a52f0717af5e369b)
#         ;
#
#
#
#
#             var marker_24d2a489b47a62279b48ea66ba1bcbc7 = L.marker(
#                 [45.050399999999996, 3.0504],
