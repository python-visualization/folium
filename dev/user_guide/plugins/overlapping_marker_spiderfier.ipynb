# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8075110b3dbdc52fd85a672cf78f1f6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8075110b3dbdc52fd85a672cf78f1f6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8075110b3dbdc52fd85a672cf78f1f6c = L.map(
#                 &quot;map_8075110b3dbdc52fd85a672cf78f1f6c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cf8069e61477d49e7c35919e87b423d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cf8069e61477d49e7c35919e87b423d.addTo(map_8075110b3dbdc52fd85a672cf78f1f6c);
#
#
#             var marker_dff1473048a6541bb394cb5a64028aef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8075110b3dbdc52fd85a672cf78f1f6c);
#
#
#         var popup_9213ae2e9067c11cd4c004c7ceb00d26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d90ab4160308a66a2b17d60fd7483f3d = $(`&lt;div id=&quot;html_d90ab4160308a66a2b17d60fd7483f3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9213ae2e9067c11cd4c004c7ceb00d26.setContent(html_d90ab4160308a66a2b17d60fd7483f3d);
#
#
#
#         marker_dff1473048a6541bb394cb5a64028aef.bindPopup(popup_9213ae2e9067c11cd4c004c7ceb00d26)
#         ;
#
#
#
#
#             var marker_706ad20621dbe8718ea515c40c7dec00 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8075110b3dbdc52fd85a672cf78f1f6c);
#
#
#         var popup_378375221a37baa71f1139882e98d40e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d35e619457392f2fb1b04f97e155e48 = $(`&lt;div id=&quot;html_5d35e619457392f2fb1b04f97e155e48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_378375221a37baa71f1139882e98d40e.setContent(html_5d35e619457392f2fb1b04f97e155e48);
#
#
#
#         marker_706ad20621dbe8718ea515c40c7dec00.bindPopup(popup_378375221a37baa71f1139882e98d40e)
#         ;
#
#
#
#
#             var marker_accbb004b8b92fd2740dd138e7f29b49 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8075110b3dbdc52fd85a672cf78f1f6c);
#
#
#         var popup_3175a0720b3d3433c5e06ec337ed85c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7163bdb4f690e82f810abc54037810e7 = $(`&lt;div id=&quot;html_7163bdb4f690e82f810abc54037810e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3175a0720b3d3433c5e06ec337ed85c4.setContent(html_7163bdb4f690e82f810abc54037810e7);
#
#
#
#         marker_accbb004b8b92fd2740dd138e7f29b49.bindPopup(popup_3175a0720b3d3433c5e06ec337ed85c4)
#         ;
#
#
#
#
#             var marker_e664d259f57d804bb7b08a766cf66649 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8075110b3dbdc52fd85a672cf78f1f6c);
#
#
#         var popup_34b4463ec0d11c8d6f9cc8203aba966f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74d2655e878bcbc5e3bee0b4bd50fd85 = $(`&lt;div id=&quot;html_74d2655e878bcbc5e3bee0b4bd50fd85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_34b4463ec0d11c8d6f9cc8203aba966f.setContent(html_74d2655e878bcbc5e3bee0b4bd50fd85);
#
#
#
#         marker_e664d259f57d804bb7b08a766cf66649.bindPopup(popup_34b4463ec0d11c8d6f9cc8203aba966f)
#         ;
#
#
#
#
#             var marker_de59d728300f716a6232d1565abeb34a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8075110b3dbdc52fd85a672cf78f1f6c);
#
#
#         var popup_ebcc2f95b7a6283ab2bd47f92a12e60f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d929125e31bad7b7a661a2e42658da64 = $(`&lt;div id=&quot;html_d929125e31bad7b7a661a2e42658da64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ebcc2f95b7a6283ab2bd47f92a12e60f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a87c32420d64ea18a9dcc0e49d3d87f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a87c32420d64ea18a9dcc0e49d3d87f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a87c32420d64ea18a9dcc0e49d3d87f = L.map(
#                 &quot;map_0a87c32420d64ea18a9dcc0e49d3d87f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df31f44aa99ae132da9ab7c0106926b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df31f44aa99ae132da9ab7c0106926b1.addTo(map_0a87c32420d64ea18a9dcc0e49d3d87f);
#
#
#             var feature_group_dac6cd6dbcc3da198c3dec71d444980c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6f0629154058238fb3825830f56178d0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dac6cd6dbcc3da198c3dec71d444980c);
#
#
#         var popup_4f02efaa1e15aedbeca2a37904f170a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ff0acc4f8e6443fd69f9dafbaa0926a = $(`&lt;div id=&quot;html_6ff0acc4f8e6443fd69f9dafbaa0926a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4f02efaa1e15aedbeca2a37904f170a1.setContent(html_6ff0acc4f8e6443fd69f9dafbaa0926a);
#
#
#
#         marker_6f0629154058238fb3825830f56178d0.bindPopup(popup_4f02efaa1e15aedbeca2a37904f170a1)
#         ;
#
#
#
#
#             var marker_02dd413e98a5fe1d570db6fb91216cae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dac6cd6dbcc3da198c3dec71d444980c);
#
#
#         var popup_8733cdfe671aed7c2eb9495dd61c465f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c108f3f2a033471dd50b6c37f7155f7b = $(`&lt;div id=&quot;html_c108f3f2a033471dd50b6c37f7155f7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8733cdfe671aed7c2eb9495dd61c465f.setContent(html_c108f3f2a033471dd50b6c37f7155f7b);
#
#
#
#         marker_02dd413e98a5fe1d570db6fb91216cae.bindPopup(popup_8733cdfe671aed7c2eb9495dd61c465f)
#         ;
#
#
#
#
#             var marker_e07446f4dbcd5a95fa1adb643fa4636d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dac6cd6dbcc3da198c3dec71d444980c);
#
#
#         var popup_1219eab7e8c286bd9f30ba21894e6ed8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0845cd66641b8fc86f3dbdc0cc07d78 = $(`&lt;div id=&quot;html_f0845cd66641b8fc86f3dbdc0cc07d78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1219eab7e8c286bd9f30ba21894e6ed8.setContent(html_f0845cd66641b8fc86f3dbdc0cc07d78);
#
#
#
#         marker_e07446f4dbcd5a95fa1adb643fa4636d.bindPopup(popup_1219eab7e8c286bd9f30ba21894e6ed8)
#         ;
#
#
#
#
#             var marker_7dec1a7614d80c4bbf26062f914e4546 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dac6cd6dbcc3da198c3dec71d444980c);
#
#
#         var popup_8b27a64e45039fe4f444323966ccc1b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60081fcb0fc7a005cbf2f337a9959dad = $(`&lt;div id=&quot;html_60081fcb0fc7a005cbf2f337a9959dad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8b27a64e45039fe4f444323966ccc1b3.setContent(html_60081fcb0fc7a005cbf2f337a9959dad);
#
#
#
#         marker_7dec1a7614d80c4bbf26062f914e4546.bindPopup(popup_8b27a64e45039fe4f444323966ccc1b3)
#         ;
#
#
#
#
#             var marker_8cfe7a7ca9290b6f8975dce2892db7a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dac6cd6dbcc3da198c3dec71d444980c);
#
#
#         var popup_46aa85519e3698857b0c9f58bbaedcfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f772cfe409ef1463c93b82f9d8dff48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f772cfe409ef1463c93b82f9d8dff48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f772cfe409ef1463c93b82f9d8dff48 = L.map(
#                 &quot;map_8f772cfe409ef1463c93b82f9d8dff48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36e4af6a0aa80d2ed97b972b98552d9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36e4af6a0aa80d2ed97b972b98552d9f.addTo(map_8f772cfe409ef1463c93b82f9d8dff48);
#
#
#             var feature_group_4d4cbe520c94e2b75fd163d8c88f470c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4d4cbe520c94e2b75fd163d8c88f470c.addTo(map_8f772cfe409ef1463c93b82f9d8dff48);
#
#
#             var feature_group_sub_group_1a591cd668ef1bd9315475f7c15706e4 = L.featureGroup.subGroup(
#                 feature_group_4d4cbe520c94e2b75fd163d8c88f470c
#             );
#
#
#             var marker_bcd6a4f0ea60215609030f01f3949bf1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a591cd668ef1bd9315475f7c15706e4);
#
#
#         var popup_233b5059329393afc386f0f8ebb1b964 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24658002b6afc731b2a203bd88e9c2f1 = $(`&lt;div id=&quot;html_24658002b6afc731b2a203bd88e9c2f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_233b5059329393afc386f0f8ebb1b964.setContent(html_24658002b6afc731b2a203bd88e9c2f1);
#
#
#
#         marker_bcd6a4f0ea60215609030f01f3949bf1.bindPopup(popup_233b5059329393afc386f0f8ebb1b964)
#         ;
#
#
#
#
#             var marker_6c92d8d41b89ea8f040d5f15bc73a865 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a591cd668ef1bd9315475f7c15706e4);
#
#
#         var popup_7ab31926ecead960c324a13bbf447bdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10117ff4b3158b3433e0ff61c90f5663 = $(`&lt;div id=&quot;html_10117ff4b3158b3433e0ff61c90f5663&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7ab31926ecead960c324a13bbf447bdb.setContent(html_10117ff4b3158b3433e0ff61c90f5663);
#
#
#
#         marker_6c92d8d41b89ea8f040d5f15bc73a865.bindPopup(popup_7ab31926ecead960c324a13bbf447bdb)
#         ;
#
#
#
#
#             var marker_1ad57aaeda85123a832d95564c8c52c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a591cd668ef1bd9315475f7c15706e4);
#
#
#         var popup_765cd41e93785ea2396e8659d0c0730f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39487162dfc15d435196c6b3a805a4d3 = $(`&lt;div id=&quot;html_39487162dfc15d435196c6b3a805a4d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_765cd41e93785ea2396e8659d0c0730f.setContent(html_39487162dfc15d435196c6b3a805a4d3);
#
#
#
#         marker_1ad57aaeda85123a832d95564c8c52c8.bindPopup(popup_765cd41e93785ea2396e8659d0c0730f)
#         ;
#
#
#
#
#             var marker_19801317b7d722a42e710a7e4dc6d4c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a591cd668ef1bd9315475f7c15706e4);
#
#
#         var popup_f40277ce354ecc2cea8c40c569a4e016 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_432308972f3441328d58b3397eeb3259 = $(`&lt;div id=&quot;html_432308972f3441328d58b3397eeb3259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f40277ce354ecc2cea8c40c569a4e016.setContent(html_432308972f3441328d58b3397eeb3259);
#
#
#
#         marker_
