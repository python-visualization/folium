# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_523fdce6d8f24419dccf5f95cdde313c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_523fdce6d8f24419dccf5f95cdde313c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_523fdce6d8f24419dccf5f95cdde313c = L.map(
#                 &quot;map_523fdce6d8f24419dccf5f95cdde313c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_871170fe6a8c5a9f00bfd596b5ec09b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_871170fe6a8c5a9f00bfd596b5ec09b0.addTo(map_523fdce6d8f24419dccf5f95cdde313c);
#
#
#             var marker_bbc61af9d33c28f432aa21494e7b6384 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_523fdce6d8f24419dccf5f95cdde313c);
#
#
#         var popup_d55b458249f07a9240cf6bb0254e4bc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c14e27c532682034f592283049ca4dce = $(`&lt;div id=&quot;html_c14e27c532682034f592283049ca4dce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d55b458249f07a9240cf6bb0254e4bc0.setContent(html_c14e27c532682034f592283049ca4dce);
#
#
#
#         marker_bbc61af9d33c28f432aa21494e7b6384.bindPopup(popup_d55b458249f07a9240cf6bb0254e4bc0)
#         ;
#
#
#
#
#             var marker_59e417688a4bd064363afc8aebdbf8c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_523fdce6d8f24419dccf5f95cdde313c);
#
#
#         var popup_753b20de708de9465fd0d47cb7067ec8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07096a59d04a162d2fc28e94f34a398b = $(`&lt;div id=&quot;html_07096a59d04a162d2fc28e94f34a398b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_753b20de708de9465fd0d47cb7067ec8.setContent(html_07096a59d04a162d2fc28e94f34a398b);
#
#
#
#         marker_59e417688a4bd064363afc8aebdbf8c5.bindPopup(popup_753b20de708de9465fd0d47cb7067ec8)
#         ;
#
#
#
#
#             var marker_f0589e8bd5adf12cc5dc49b04fa1d190 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_523fdce6d8f24419dccf5f95cdde313c);
#
#
#         var popup_ae7c2a86e6581640c665fb85d866cb3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed288acaabd235ade659a60a15725ea9 = $(`&lt;div id=&quot;html_ed288acaabd235ade659a60a15725ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ae7c2a86e6581640c665fb85d866cb3c.setContent(html_ed288acaabd235ade659a60a15725ea9);
#
#
#
#         marker_f0589e8bd5adf12cc5dc49b04fa1d190.bindPopup(popup_ae7c2a86e6581640c665fb85d866cb3c)
#         ;
#
#
#
#
#             var marker_ee568bc36718cd276f668701474a87c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_523fdce6d8f24419dccf5f95cdde313c);
#
#
#         var popup_b51dd9fb7db40771e57510842f085954 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a8a8bf8b627dbf3d9378fea7d113c8c = $(`&lt;div id=&quot;html_5a8a8bf8b627dbf3d9378fea7d113c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b51dd9fb7db40771e57510842f085954.setContent(html_5a8a8bf8b627dbf3d9378fea7d113c8c);
#
#
#
#         marker_ee568bc36718cd276f668701474a87c8.bindPopup(popup_b51dd9fb7db40771e57510842f085954)
#         ;
#
#
#
#
#             var marker_13cbf340397706222cc00c1998bd0201 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_523fdce6d8f24419dccf5f95cdde313c);
#
#
#         var popup_52e9bc338083cbf4c6bd10555461fce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8264f5c6ed6071f8d7e53488ad10f92f = $(`&lt;div id=&quot;html_8264f5c6ed6071f8d7e53488ad10f92f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_52e9bc338083cbf4c6bd10555461fce5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d7d7e37af40a68e700564bd6ed29d0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d7d7e37af40a68e700564bd6ed29d0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d7d7e37af40a68e700564bd6ed29d0d = L.map(
#                 &quot;map_6d7d7e37af40a68e700564bd6ed29d0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f28916d5fd005fcdd10a75657038352 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f28916d5fd005fcdd10a75657038352.addTo(map_6d7d7e37af40a68e700564bd6ed29d0d);
#
#
#             var feature_group_67e8e1d9085158be8aba57a8fa878342 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4f11086de6245f7ac6fa42d7d89e6435 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_67e8e1d9085158be8aba57a8fa878342);
#
#
#         var popup_2d6a6898cca959b9baf217875de5df32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3849ddd2a38cb8ae99990c7cd897e4ba = $(`&lt;div id=&quot;html_3849ddd2a38cb8ae99990c7cd897e4ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2d6a6898cca959b9baf217875de5df32.setContent(html_3849ddd2a38cb8ae99990c7cd897e4ba);
#
#
#
#         marker_4f11086de6245f7ac6fa42d7d89e6435.bindPopup(popup_2d6a6898cca959b9baf217875de5df32)
#         ;
#
#
#
#
#             var marker_5b2803556dc772f1cd2a37e0bfb67fb8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_67e8e1d9085158be8aba57a8fa878342);
#
#
#         var popup_6aac711bfc07e53e546a1e5e096ac50d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6436183410e918fde04c1d1c5926be8 = $(`&lt;div id=&quot;html_a6436183410e918fde04c1d1c5926be8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6aac711bfc07e53e546a1e5e096ac50d.setContent(html_a6436183410e918fde04c1d1c5926be8);
#
#
#
#         marker_5b2803556dc772f1cd2a37e0bfb67fb8.bindPopup(popup_6aac711bfc07e53e546a1e5e096ac50d)
#         ;
#
#
#
#
#             var marker_e6890348f229f3bed86c55c615de5288 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_67e8e1d9085158be8aba57a8fa878342);
#
#
#         var popup_964be5f2860003db2f5f180fec11e435 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49f09ec713265b7dbe344e81ddfb3e48 = $(`&lt;div id=&quot;html_49f09ec713265b7dbe344e81ddfb3e48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_964be5f2860003db2f5f180fec11e435.setContent(html_49f09ec713265b7dbe344e81ddfb3e48);
#
#
#
#         marker_e6890348f229f3bed86c55c615de5288.bindPopup(popup_964be5f2860003db2f5f180fec11e435)
#         ;
#
#
#
#
#             var marker_570801574b490d7762c955f0965c28db = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_67e8e1d9085158be8aba57a8fa878342);
#
#
#         var popup_8c2491bd74275e4486157956b321b89a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a65bbf27a867b09f5642ffbe38eeb4ca = $(`&lt;div id=&quot;html_a65bbf27a867b09f5642ffbe38eeb4ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8c2491bd74275e4486157956b321b89a.setContent(html_a65bbf27a867b09f5642ffbe38eeb4ca);
#
#
#
#         marker_570801574b490d7762c955f0965c28db.bindPopup(popup_8c2491bd74275e4486157956b321b89a)
#         ;
#
#
#
#
#             var marker_cd7a5e7b55d349a9b9bd97c2b5c87509 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_67e8e1d9085158be8aba57a8fa878342);
#
#
#         var popup_73531e03f47aa1e904f5f067f369deda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3234ff354a9b3b27694d8ee2c9d13b96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3234ff354a9b3b27694d8ee2c9d13b96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3234ff354a9b3b27694d8ee2c9d13b96 = L.map(
#                 &quot;map_3234ff354a9b3b27694d8ee2c9d13b96&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1d3a5727019fa151e4c4ab00c377be0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1d3a5727019fa151e4c4ab00c377be0.addTo(map_3234ff354a9b3b27694d8ee2c9d13b96);
#
#
#             var feature_group_6fc14350e78db6f47f277ca428b127d4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6fc14350e78db6f47f277ca428b127d4.addTo(map_3234ff354a9b3b27694d8ee2c9d13b96);
#
#
#             var feature_group_sub_group_14a6f040abc1727dbbe25155f32bf102 = L.featureGroup.subGroup(
#                 feature_group_6fc14350e78db6f47f277ca428b127d4
#             );
#
#
#             var marker_089824648d082a1026b1fa148290c24d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_14a6f040abc1727dbbe25155f32bf102);
#
#
#         var popup_76e83af5b141d2b940e868c61642e776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa2b0d00d9d4a4b4ff0c5797a12ad147 = $(`&lt;div id=&quot;html_fa2b0d00d9d4a4b4ff0c5797a12ad147&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_76e83af5b141d2b940e868c61642e776.setContent(html_fa2b0d00d9d4a4b4ff0c5797a12ad147);
#
#
#
#         marker_089824648d082a1026b1fa148290c24d.bindPopup(popup_76e83af5b141d2b940e868c61642e776)
#         ;
#
#
#
#
#             var marker_750e48b5b01a6fa1fc684035466ed7b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_14a6f040abc1727dbbe25155f32bf102);
#
#
#         var popup_77732afd785789ace169f4fcc8f7c6a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e119b92fcef1507683113940bf19bdcc = $(`&lt;div id=&quot;html_e119b92fcef1507683113940bf19bdcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_77732afd785789ace169f4fcc8f7c6a1.setContent(html_e119b92fcef1507683113940bf19bdcc);
#
#
#
#         marker_750e48b5b01a6fa1fc684035466ed7b9.bindPopup(popup_77732afd785789ace169f4fcc8f7c6a1)
#         ;
#
#
#
#
#             var marker_5fbc8786d5b8d70a2f93fb2849f5ae0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_14a6f040abc1727dbbe25155f32bf102);
#
#
#         var popup_a09bf4b788a87350e91abea41bc088fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15228049f2f29363b5b0a11531b3017e = $(`&lt;div id=&quot;html_15228049f2f29363b5b0a11531b3017e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a09bf4b788a87350e91abea41bc088fe.setContent(html_15228049f2f29363b5b0a11531b3017e);
#
#
#
#         marker_5fbc8786d5b8d70a2f93fb2849f5ae0f.bindPopup(popup_a09bf4b788a87350e91abea41bc088fe)
#         ;
#
#
#
#
#             var marker_04c58acf45626a7bb8cd4249bc6b9d71 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_14a6f040abc1727dbbe25155f32bf102);
#
#
#         var popup_a283c17800e3dba87c29a42030db560e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ab0521b22b9d77c1fd3afb1baefcb3b = $(`&lt;div id=&quot;html_2ab0521b22b9d77c1fd3afb1baefcb3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a283c17800e3dba87c29a42030db560e.setContent(html_2ab0521b22b9d77c1fd3afb1baefcb3b);
#
#
#
#         marker_
