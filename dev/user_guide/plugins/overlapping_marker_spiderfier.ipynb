# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_565677c7b96878faaa5ee8c1ddb2df0d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_565677c7b96878faaa5ee8c1ddb2df0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_565677c7b96878faaa5ee8c1ddb2df0d = L.map(
#                 &quot;map_565677c7b96878faaa5ee8c1ddb2df0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e396217ddb5d88cb6086735cf1428f3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e396217ddb5d88cb6086735cf1428f3b.addTo(map_565677c7b96878faaa5ee8c1ddb2df0d);
#
#
#             var marker_b538932d94027060006971ca4998063c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_565677c7b96878faaa5ee8c1ddb2df0d);
#
#
#         var popup_36697b9cab1253734a74fc5d1b865a7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bbfd0e578105ded3f867b4d182e813d = $(`&lt;div id=&quot;html_1bbfd0e578105ded3f867b4d182e813d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_36697b9cab1253734a74fc5d1b865a7b.setContent(html_1bbfd0e578105ded3f867b4d182e813d);
#
#
#
#         marker_b538932d94027060006971ca4998063c.bindPopup(popup_36697b9cab1253734a74fc5d1b865a7b)
#         ;
#
#
#
#
#             var marker_3583d5cb00019b9839669b9ea92ee060 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_565677c7b96878faaa5ee8c1ddb2df0d);
#
#
#         var popup_5b1cc9f7a7c51d0b4b2a7a17e6b33eec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90dcb8295926d9db370d1950b5bef637 = $(`&lt;div id=&quot;html_90dcb8295926d9db370d1950b5bef637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5b1cc9f7a7c51d0b4b2a7a17e6b33eec.setContent(html_90dcb8295926d9db370d1950b5bef637);
#
#
#
#         marker_3583d5cb00019b9839669b9ea92ee060.bindPopup(popup_5b1cc9f7a7c51d0b4b2a7a17e6b33eec)
#         ;
#
#
#
#
#             var marker_ef704d7ff693fec2a99a48ce19639ace = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_565677c7b96878faaa5ee8c1ddb2df0d);
#
#
#         var popup_3efe02e48cbe319b61e987f3d2d1db2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d09faacf9272eb5037ea0cf4922b80e3 = $(`&lt;div id=&quot;html_d09faacf9272eb5037ea0cf4922b80e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3efe02e48cbe319b61e987f3d2d1db2d.setContent(html_d09faacf9272eb5037ea0cf4922b80e3);
#
#
#
#         marker_ef704d7ff693fec2a99a48ce19639ace.bindPopup(popup_3efe02e48cbe319b61e987f3d2d1db2d)
#         ;
#
#
#
#
#             var marker_f8f11fbd4d5177e5f22e22d789e89b7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_565677c7b96878faaa5ee8c1ddb2df0d);
#
#
#         var popup_698600e6f6562b8b53a7aad398d6954f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d61f6536b8343c9c9355f917144a21fa = $(`&lt;div id=&quot;html_d61f6536b8343c9c9355f917144a21fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_698600e6f6562b8b53a7aad398d6954f.setContent(html_d61f6536b8343c9c9355f917144a21fa);
#
#
#
#         marker_f8f11fbd4d5177e5f22e22d789e89b7c.bindPopup(popup_698600e6f6562b8b53a7aad398d6954f)
#         ;
#
#
#
#
#             var marker_8e0f2944fd4b08e9921b55ff2ee5bbaa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_565677c7b96878faaa5ee8c1ddb2df0d);
#
#
#         var popup_79871a8872153a22cf0c9a12334a5ba2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54f9f46320b75440811cd9f3b742f807 = $(`&lt;div id=&quot;html_54f9f46320b75440811cd9f3b742f807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_79871a8872153a22cf0c9a12334a5b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ace73176e68ec2a2f665dc717ca2731d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ace73176e68ec2a2f665dc717ca2731d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ace73176e68ec2a2f665dc717ca2731d = L.map(
#                 &quot;map_ace73176e68ec2a2f665dc717ca2731d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea03e90ed6df1611f3398fe158f57b53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea03e90ed6df1611f3398fe158f57b53.addTo(map_ace73176e68ec2a2f665dc717ca2731d);
#
#
#             var feature_group_0191aff56e431649e14d9cdaf59390fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_019f38610f2eb6a1633f4b371f55ca34 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0191aff56e431649e14d9cdaf59390fe);
#
#
#         var popup_bc8464051ab4da244db8ad213d57d1aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e481dd8fa44dab0b9cdb3761b85b04d0 = $(`&lt;div id=&quot;html_e481dd8fa44dab0b9cdb3761b85b04d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bc8464051ab4da244db8ad213d57d1aa.setContent(html_e481dd8fa44dab0b9cdb3761b85b04d0);
#
#
#
#         marker_019f38610f2eb6a1633f4b371f55ca34.bindPopup(popup_bc8464051ab4da244db8ad213d57d1aa)
#         ;
#
#
#
#
#             var marker_620eb2247591a52d8a56dc514caa8b37 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0191aff56e431649e14d9cdaf59390fe);
#
#
#         var popup_52917815fe5813e541688f3ce810660e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c0d684b90450e5b988f9ea9349af6c = $(`&lt;div id=&quot;html_50c0d684b90450e5b988f9ea9349af6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52917815fe5813e541688f3ce810660e.setContent(html_50c0d684b90450e5b988f9ea9349af6c);
#
#
#
#         marker_620eb2247591a52d8a56dc514caa8b37.bindPopup(popup_52917815fe5813e541688f3ce810660e)
#         ;
#
#
#
#
#             var marker_2d0ae87d41fd4cce2dbb47ba8026d67c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0191aff56e431649e14d9cdaf59390fe);
#
#
#         var popup_f7b724977df23686f2293adbd3572a8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00b66400fc7ea9aa447614b95e72383c = $(`&lt;div id=&quot;html_00b66400fc7ea9aa447614b95e72383c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f7b724977df23686f2293adbd3572a8f.setContent(html_00b66400fc7ea9aa447614b95e72383c);
#
#
#
#         marker_2d0ae87d41fd4cce2dbb47ba8026d67c.bindPopup(popup_f7b724977df23686f2293adbd3572a8f)
#         ;
#
#
#
#
#             var marker_d68c630e479440683e86b7e65fbe874b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0191aff56e431649e14d9cdaf59390fe);
#
#
#         var popup_b38b952f72f7e7b114c0ea03fce35d4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_121c6b07d8c793aaedbdae0ada916c2f = $(`&lt;div id=&quot;html_121c6b07d8c793aaedbdae0ada916c2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b38b952f72f7e7b114c0ea03fce35d4f.setContent(html_121c6b07d8c793aaedbdae0ada916c2f);
#
#
#
#         marker_d68c630e479440683e86b7e65fbe874b.bindPopup(popup_b38b952f72f7e7b114c0ea03fce35d4f)
#         ;
#
#
#
#
#             var marker_f277c6f727070357acce17e942a4824d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0191aff56e431649e14d9cdaf59390fe);
#
#
#         var popup_3a1bd037bea6ba7c0f33b41b7ad60059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cbd54f3aea3091943c5a4780b670fe1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cbd54f3aea3091943c5a4780b670fe1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cbd54f3aea3091943c5a4780b670fe1 = L.map(
#                 &quot;map_0cbd54f3aea3091943c5a4780b670fe1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80cd695f7eac2922482dc6005dba4505 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80cd695f7eac2922482dc6005dba4505.addTo(map_0cbd54f3aea3091943c5a4780b670fe1);
#
#
#             var feature_group_1cd2257ac7d849de6f3c4dfd1b2e325b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1cd2257ac7d849de6f3c4dfd1b2e325b.addTo(map_0cbd54f3aea3091943c5a4780b670fe1);
#
#
#             var feature_group_sub_group_e983f3469cb5341829c906766412c6e3 = L.featureGroup.subGroup(
#                 feature_group_1cd2257ac7d849de6f3c4dfd1b2e325b
#             );
#
#
#             var marker_1530491ef0c728558983261798724817 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e983f3469cb5341829c906766412c6e3);
#
#
#         var popup_908ea7d1697428c2861e4990115eafef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_573ad6bf3185bdd50b7251c861aeeaff = $(`&lt;div id=&quot;html_573ad6bf3185bdd50b7251c861aeeaff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_908ea7d1697428c2861e4990115eafef.setContent(html_573ad6bf3185bdd50b7251c861aeeaff);
#
#
#
#         marker_1530491ef0c728558983261798724817.bindPopup(popup_908ea7d1697428c2861e4990115eafef)
#         ;
#
#
#
#
#             var marker_ebe11dcad766d38b816d69643484fcc8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e983f3469cb5341829c906766412c6e3);
#
#
#         var popup_8b11a6d025663e092503f791bac6c85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44b16d8d13b42263474cede0c34147df = $(`&lt;div id=&quot;html_44b16d8d13b42263474cede0c34147df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8b11a6d025663e092503f791bac6c85b.setContent(html_44b16d8d13b42263474cede0c34147df);
#
#
#
#         marker_ebe11dcad766d38b816d69643484fcc8.bindPopup(popup_8b11a6d025663e092503f791bac6c85b)
#         ;
#
#
#
#
#             var marker_8732357acb42b04de5f34a4f2934b876 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e983f3469cb5341829c906766412c6e3);
#
#
#         var popup_05cb46639e6ab06991e3fec4737ab7f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29f90dcd38cbcd391debbc3f3bb8a255 = $(`&lt;div id=&quot;html_29f90dcd38cbcd391debbc3f3bb8a255&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_05cb46639e6ab06991e3fec4737ab7f2.setContent(html_29f90dcd38cbcd391debbc3f3bb8a255);
#
#
#
#         marker_8732357acb42b04de5f34a4f2934b876.bindPopup(popup_05cb46639e6ab06991e3fec4737ab7f2)
#         ;
#
#
#
#
#             var marker_3ee6373abdc8e62da6c0aab612e27250 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e983f3469cb5341829c906766412c6e3);
#
#
#         var popup_c75056d89ca7e583b8b7760bf3298756 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd15cf62ce1ceee3f64f7d744d1385c9 = $(`&lt;div id=&quot;html_cd15cf62ce1ceee3f64f7d744d1385c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c75056d89ca7e583b8b7760bf3298756.setContent(html_cd15cf62ce1ceee3f64f7d744d1385c9);
#
#
#
#         mark
