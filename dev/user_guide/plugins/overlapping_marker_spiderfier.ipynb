# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb7c17cbd9a59007ea2cc3fb836df491 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb7c17cbd9a59007ea2cc3fb836df491&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb7c17cbd9a59007ea2cc3fb836df491 = L.map(
#                 &quot;map_fb7c17cbd9a59007ea2cc3fb836df491&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52a7f522cbe4540407e62b4942af18ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52a7f522cbe4540407e62b4942af18ea.addTo(map_fb7c17cbd9a59007ea2cc3fb836df491);
#
#
#             var marker_41b73c37651b0cf36fc4e2e298a50c91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fb7c17cbd9a59007ea2cc3fb836df491);
#
#
#         var popup_84efc39d27729516588c512bbd1b7441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a602e0662dd6d1e1e45beca18b592376 = $(`&lt;div id=&quot;html_a602e0662dd6d1e1e45beca18b592376&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_84efc39d27729516588c512bbd1b7441.setContent(html_a602e0662dd6d1e1e45beca18b592376);
#
#
#
#         marker_41b73c37651b0cf36fc4e2e298a50c91.bindPopup(popup_84efc39d27729516588c512bbd1b7441)
#         ;
#
#
#
#
#             var marker_6c3f994b913642d337421c8b3a63a942 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fb7c17cbd9a59007ea2cc3fb836df491);
#
#
#         var popup_58445f61a0b91188bc612f5b4662ec2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_774b6ac1b0121085fb44da5d0fb5a1e3 = $(`&lt;div id=&quot;html_774b6ac1b0121085fb44da5d0fb5a1e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_58445f61a0b91188bc612f5b4662ec2d.setContent(html_774b6ac1b0121085fb44da5d0fb5a1e3);
#
#
#
#         marker_6c3f994b913642d337421c8b3a63a942.bindPopup(popup_58445f61a0b91188bc612f5b4662ec2d)
#         ;
#
#
#
#
#             var marker_f64f23b386ca12e8d3b4fea1d190c43d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fb7c17cbd9a59007ea2cc3fb836df491);
#
#
#         var popup_75b8f19ea055f0def8eab1be7aa43757 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eff1430c1928465cb72f70ddfcf75648 = $(`&lt;div id=&quot;html_eff1430c1928465cb72f70ddfcf75648&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_75b8f19ea055f0def8eab1be7aa43757.setContent(html_eff1430c1928465cb72f70ddfcf75648);
#
#
#
#         marker_f64f23b386ca12e8d3b4fea1d190c43d.bindPopup(popup_75b8f19ea055f0def8eab1be7aa43757)
#         ;
#
#
#
#
#             var marker_09951cb278a42635f6e1d158fd19df0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fb7c17cbd9a59007ea2cc3fb836df491);
#
#
#         var popup_f38c8855b762f51da091a681c6412242 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69a2ec5e8a781aab25afbe93cb17323c = $(`&lt;div id=&quot;html_69a2ec5e8a781aab25afbe93cb17323c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f38c8855b762f51da091a681c6412242.setContent(html_69a2ec5e8a781aab25afbe93cb17323c);
#
#
#
#         marker_09951cb278a42635f6e1d158fd19df0d.bindPopup(popup_f38c8855b762f51da091a681c6412242)
#         ;
#
#
#
#
#             var marker_2cf5c90355959afd4cef3d560eb6ea5b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fb7c17cbd9a59007ea2cc3fb836df491);
#
#
#         var popup_f77337277a3d705e726b7704198bcd66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d22f020b2e0a84913fe94c694bc8cf9 = $(`&lt;div id=&quot;html_5d22f020b2e0a84913fe94c694bc8cf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f77337277a3d705e726b7704198bcd

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a57013be1abed5422e4744820cfaa36 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a57013be1abed5422e4744820cfaa36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a57013be1abed5422e4744820cfaa36 = L.map(
#                 &quot;map_3a57013be1abed5422e4744820cfaa36&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e62f455390e0195099a3b14bb80ccc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e62f455390e0195099a3b14bb80ccc4.addTo(map_3a57013be1abed5422e4744820cfaa36);
#
#
#             var feature_group_813ab5bb46dfdf99a22e2f7ae28793e6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f657f73b7592135fa867a3e3bdbd59c1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_813ab5bb46dfdf99a22e2f7ae28793e6);
#
#
#         var popup_145909fbba113173daa2656085584443 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_655224713d4fd079d13e928b01773b52 = $(`&lt;div id=&quot;html_655224713d4fd079d13e928b01773b52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_145909fbba113173daa2656085584443.setContent(html_655224713d4fd079d13e928b01773b52);
#
#
#
#         marker_f657f73b7592135fa867a3e3bdbd59c1.bindPopup(popup_145909fbba113173daa2656085584443)
#         ;
#
#
#
#
#             var marker_95a99a37a6ab714f03e23493bd977f16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_813ab5bb46dfdf99a22e2f7ae28793e6);
#
#
#         var popup_ffec6f572a6a4c89e13c62e55f68a770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba45e6541ad9b693a3b1061e3b58a7a0 = $(`&lt;div id=&quot;html_ba45e6541ad9b693a3b1061e3b58a7a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ffec6f572a6a4c89e13c62e55f68a770.setContent(html_ba45e6541ad9b693a3b1061e3b58a7a0);
#
#
#
#         marker_95a99a37a6ab714f03e23493bd977f16.bindPopup(popup_ffec6f572a6a4c89e13c62e55f68a770)
#         ;
#
#
#
#
#             var marker_2a08e85a1d8f1cbc5e657e50809a4ff2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_813ab5bb46dfdf99a22e2f7ae28793e6);
#
#
#         var popup_58fe3d7e5b1a07aa3b1612653980a738 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44bb755a1f187b7eed2a79f91d3200a9 = $(`&lt;div id=&quot;html_44bb755a1f187b7eed2a79f91d3200a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_58fe3d7e5b1a07aa3b1612653980a738.setContent(html_44bb755a1f187b7eed2a79f91d3200a9);
#
#
#
#         marker_2a08e85a1d8f1cbc5e657e50809a4ff2.bindPopup(popup_58fe3d7e5b1a07aa3b1612653980a738)
#         ;
#
#
#
#
#             var marker_5036dc34feb47afa8dd68c7922b98e7b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_813ab5bb46dfdf99a22e2f7ae28793e6);
#
#
#         var popup_04902de4cc6ca2125d0a37333f32bcee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_989c6ef59df808aacd780f92eccbdc48 = $(`&lt;div id=&quot;html_989c6ef59df808aacd780f92eccbdc48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_04902de4cc6ca2125d0a37333f32bcee.setContent(html_989c6ef59df808aacd780f92eccbdc48);
#
#
#
#         marker_5036dc34feb47afa8dd68c7922b98e7b.bindPopup(popup_04902de4cc6ca2125d0a37333f32bcee)
#         ;
#
#
#
#
#             var marker_9aa40511e4aeb99fd0507299d7504c4c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_813ab5bb46dfdf99a22e2f7ae28793e6);
#
#
#         var popup_409a61093913676d1a6cd238299d9bf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63118d99b55e0f5df8750ee00783c83c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63118d99b55e0f5df8750ee00783c83c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63118d99b55e0f5df8750ee00783c83c = L.map(
#                 &quot;map_63118d99b55e0f5df8750ee00783c83c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d98d68c61c220e82f0e0348b4c2f8f27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d98d68c61c220e82f0e0348b4c2f8f27.addTo(map_63118d99b55e0f5df8750ee00783c83c);
#
#
#             var feature_group_c648357de53794961a111c85a1e09b7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c648357de53794961a111c85a1e09b7b.addTo(map_63118d99b55e0f5df8750ee00783c83c);
#
#
#             var feature_group_sub_group_a15eda47d05aebc914ea64960cac4fbc = L.featureGroup.subGroup(
#                 feature_group_c648357de53794961a111c85a1e09b7b
#             );
#
#
#             var marker_a4d687760cb10c4a19cb140a1b1fc237 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a15eda47d05aebc914ea64960cac4fbc);
#
#
#         var popup_2989e24c8ef69daaf9f024a1960b8aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10457ddc8a585cb8096b7349bac5ee1f = $(`&lt;div id=&quot;html_10457ddc8a585cb8096b7349bac5ee1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2989e24c8ef69daaf9f024a1960b8aee.setContent(html_10457ddc8a585cb8096b7349bac5ee1f);
#
#
#
#         marker_a4d687760cb10c4a19cb140a1b1fc237.bindPopup(popup_2989e24c8ef69daaf9f024a1960b8aee)
#         ;
#
#
#
#
#             var marker_aa10a6be1673e56abf8ee6a01b4f3178 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a15eda47d05aebc914ea64960cac4fbc);
#
#
#         var popup_14f71504e1c7561b565eaa4af55897dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d622a839fc6c3685d909d874149c91 = $(`&lt;div id=&quot;html_c7d622a839fc6c3685d909d874149c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_14f71504e1c7561b565eaa4af55897dd.setContent(html_c7d622a839fc6c3685d909d874149c91);
#
#
#
#         marker_aa10a6be1673e56abf8ee6a01b4f3178.bindPopup(popup_14f71504e1c7561b565eaa4af55897dd)
#         ;
#
#
#
#
#             var marker_3bd255c7bb609919f24973937c8fdcff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a15eda47d05aebc914ea64960cac4fbc);
#
#
#         var popup_8c8ffaef28fac11ce1bfd9c6f2dbc158 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_033106b97b91b6b3065b2e892b770b32 = $(`&lt;div id=&quot;html_033106b97b91b6b3065b2e892b770b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8c8ffaef28fac11ce1bfd9c6f2dbc158.setContent(html_033106b97b91b6b3065b2e892b770b32);
#
#
#
#         marker_3bd255c7bb609919f24973937c8fdcff.bindPopup(popup_8c8ffaef28fac11ce1bfd9c6f2dbc158)
#         ;
#
#
#
#
#             var marker_5dcdc37347bbab853daa45cdee4db515 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a15eda47d05aebc914ea64960cac4fbc);
#
#
#         var popup_c0322b058e719bc1508fbf6e5c39e23f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d09cce396d147964a37368dbe99634e8 = $(`&lt;div id=&quot;html_d09cce396d147964a37368dbe99634e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c0322b058e719bc1508fbf6e5c39e23f.setContent(html_d09cce396d147964a37368dbe99634e8);
#
#
#
#         mark
