# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32d346c37cee94d6421327d1bf78bc7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32d346c37cee94d6421327d1bf78bc7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32d346c37cee94d6421327d1bf78bc7b = L.map(
#                 &quot;map_32d346c37cee94d6421327d1bf78bc7b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_084d3a434e8482b14ff3c1e73e70c2ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_084d3a434e8482b14ff3c1e73e70c2ae.addTo(map_32d346c37cee94d6421327d1bf78bc7b);
#
#
#             var marker_cbf76d95c98de872caeecf772aceb2f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_32d346c37cee94d6421327d1bf78bc7b);
#
#
#         var popup_e6bb44fc0d29d3829a32483d284e3d24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45194f99ad5a05f6f01a7e63ffb5accb = $(`&lt;div id=&quot;html_45194f99ad5a05f6f01a7e63ffb5accb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e6bb44fc0d29d3829a32483d284e3d24.setContent(html_45194f99ad5a05f6f01a7e63ffb5accb);
#
#
#
#         marker_cbf76d95c98de872caeecf772aceb2f8.bindPopup(popup_e6bb44fc0d29d3829a32483d284e3d24)
#         ;
#
#
#
#
#             var marker_57e92442aa0101f4b0874725fdacb342 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_32d346c37cee94d6421327d1bf78bc7b);
#
#
#         var popup_fcd4652aae7d7bfaac068e1e2962b301 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7d2a0c3d502e3c6cd52b40bf6d2d5f6 = $(`&lt;div id=&quot;html_b7d2a0c3d502e3c6cd52b40bf6d2d5f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fcd4652aae7d7bfaac068e1e2962b301.setContent(html_b7d2a0c3d502e3c6cd52b40bf6d2d5f6);
#
#
#
#         marker_57e92442aa0101f4b0874725fdacb342.bindPopup(popup_fcd4652aae7d7bfaac068e1e2962b301)
#         ;
#
#
#
#
#             var marker_40fac48d59c5717a4422b52622919b40 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_32d346c37cee94d6421327d1bf78bc7b);
#
#
#         var popup_74681a1382f5b85464f76827ae4ea700 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc38f436d79156cc534e6f30431dbad = $(`&lt;div id=&quot;html_ddc38f436d79156cc534e6f30431dbad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_74681a1382f5b85464f76827ae4ea700.setContent(html_ddc38f436d79156cc534e6f30431dbad);
#
#
#
#         marker_40fac48d59c5717a4422b52622919b40.bindPopup(popup_74681a1382f5b85464f76827ae4ea700)
#         ;
#
#
#
#
#             var marker_6faf7c534497ac09ed1a473cb155dccc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_32d346c37cee94d6421327d1bf78bc7b);
#
#
#         var popup_d3aeff65a55ba98d3e2fc8f49ba56a7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0edeb93346467c2be6ebaf99d9b612a9 = $(`&lt;div id=&quot;html_0edeb93346467c2be6ebaf99d9b612a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d3aeff65a55ba98d3e2fc8f49ba56a7b.setContent(html_0edeb93346467c2be6ebaf99d9b612a9);
#
#
#
#         marker_6faf7c534497ac09ed1a473cb155dccc.bindPopup(popup_d3aeff65a55ba98d3e2fc8f49ba56a7b)
#         ;
#
#
#
#
#             var marker_27655154bf35dfd68efd629a21353f83 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_32d346c37cee94d6421327d1bf78bc7b);
#
#
#         var popup_15ef8aa8e52e5363c1a0feb353ec9d16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a12ace6cec4a213f4cec315eb4ef5a5 = $(`&lt;div id=&quot;html_6a12ace6cec4a213f4cec315eb4ef5a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_15ef8aa8e52e5363c1a0feb353ec9d16.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_747a13261e54540a11d1b8d1a07c6896 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_747a13261e54540a11d1b8d1a07c6896&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_747a13261e54540a11d1b8d1a07c6896 = L.map(
#                 &quot;map_747a13261e54540a11d1b8d1a07c6896&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0be4a2fbe6efc6c302e811c919cb09c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0be4a2fbe6efc6c302e811c919cb09c.addTo(map_747a13261e54540a11d1b8d1a07c6896);
#
#
#             var feature_group_bae962bd07181a2b247e99665a1a3f20 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ec579c881c7b313c65b0b1c568a69e89 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bae962bd07181a2b247e99665a1a3f20);
#
#
#         var popup_d93c18da30223aac2169cd19e09b3154 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c0b24922116195cb9a52d2c1b63120a = $(`&lt;div id=&quot;html_6c0b24922116195cb9a52d2c1b63120a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d93c18da30223aac2169cd19e09b3154.setContent(html_6c0b24922116195cb9a52d2c1b63120a);
#
#
#
#         marker_ec579c881c7b313c65b0b1c568a69e89.bindPopup(popup_d93c18da30223aac2169cd19e09b3154)
#         ;
#
#
#
#
#             var marker_975403c51d7c6195dde002c2e176d075 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bae962bd07181a2b247e99665a1a3f20);
#
#
#         var popup_5c59d9b21fec3763ccb56e4447f00924 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dde595f35c0ee12c027e6ab1d6a06e9e = $(`&lt;div id=&quot;html_dde595f35c0ee12c027e6ab1d6a06e9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5c59d9b21fec3763ccb56e4447f00924.setContent(html_dde595f35c0ee12c027e6ab1d6a06e9e);
#
#
#
#         marker_975403c51d7c6195dde002c2e176d075.bindPopup(popup_5c59d9b21fec3763ccb56e4447f00924)
#         ;
#
#
#
#
#             var marker_34855cd33805e4012f401989a6e304ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bae962bd07181a2b247e99665a1a3f20);
#
#
#         var popup_b6429b90b934e3a81b1980039b5bfb48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac581553b0b0290834a01340844e8a94 = $(`&lt;div id=&quot;html_ac581553b0b0290834a01340844e8a94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b6429b90b934e3a81b1980039b5bfb48.setContent(html_ac581553b0b0290834a01340844e8a94);
#
#
#
#         marker_34855cd33805e4012f401989a6e304ae.bindPopup(popup_b6429b90b934e3a81b1980039b5bfb48)
#         ;
#
#
#
#
#             var marker_c5bfacb401bec133cd7bad7160b5909d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bae962bd07181a2b247e99665a1a3f20);
#
#
#         var popup_93a13e91e1bab1b2def589030ffdee0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2aa57ef0c97f65602ce83ec9d56fcd92 = $(`&lt;div id=&quot;html_2aa57ef0c97f65602ce83ec9d56fcd92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_93a13e91e1bab1b2def589030ffdee0d.setContent(html_2aa57ef0c97f65602ce83ec9d56fcd92);
#
#
#
#         marker_c5bfacb401bec133cd7bad7160b5909d.bindPopup(popup_93a13e91e1bab1b2def589030ffdee0d)
#         ;
#
#
#
#
#             var marker_da1e1b072b925f0a9e3dcd8ce557312b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bae962bd07181a2b247e99665a1a3f20);
#
#
#         var popup_b7c7c4ea286fadcee9a289d63167fccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d0581c0821a3460d0e8db6849861988 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d0581c0821a3460d0e8db6849861988&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d0581c0821a3460d0e8db6849861988 = L.map(
#                 &quot;map_2d0581c0821a3460d0e8db6849861988&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed1b5ad456ef8dd2f663e6c9fa4cbff7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed1b5ad456ef8dd2f663e6c9fa4cbff7.addTo(map_2d0581c0821a3460d0e8db6849861988);
#
#
#             var feature_group_88700067739e1bc7b774d4f12aefc9c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_88700067739e1bc7b774d4f12aefc9c6.addTo(map_2d0581c0821a3460d0e8db6849861988);
#
#
#             var feature_group_sub_group_3df2a1229d696c6c3894d3746a9c7f5d = L.featureGroup.subGroup(
#                 feature_group_88700067739e1bc7b774d4f12aefc9c6
#             );
#
#
#             var marker_3a31542c242a0b16cb219d436828c000 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3df2a1229d696c6c3894d3746a9c7f5d);
#
#
#         var popup_ebe5bbf1aae922718e940a88b18dac37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_219d6341ea2b1f08fc89383a1e852bd9 = $(`&lt;div id=&quot;html_219d6341ea2b1f08fc89383a1e852bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ebe5bbf1aae922718e940a88b18dac37.setContent(html_219d6341ea2b1f08fc89383a1e852bd9);
#
#
#
#         marker_3a31542c242a0b16cb219d436828c000.bindPopup(popup_ebe5bbf1aae922718e940a88b18dac37)
#         ;
#
#
#
#
#             var marker_fc05465c5c76957d612a196aa247be57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3df2a1229d696c6c3894d3746a9c7f5d);
#
#
#         var popup_6400a6c252e5d0fe7902e657cba1a77d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77764f5a8fd47fbd1b2c54888acb2fad = $(`&lt;div id=&quot;html_77764f5a8fd47fbd1b2c54888acb2fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6400a6c252e5d0fe7902e657cba1a77d.setContent(html_77764f5a8fd47fbd1b2c54888acb2fad);
#
#
#
#         marker_fc05465c5c76957d612a196aa247be57.bindPopup(popup_6400a6c252e5d0fe7902e657cba1a77d)
#         ;
#
#
#
#
#             var marker_2f0e7af0b6e22f7094d057bbb6bc99fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3df2a1229d696c6c3894d3746a9c7f5d);
#
#
#         var popup_ec4ee48affc36613f5f68ae48137f6a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e66e13a9d9737decadfd7fd90e39b2ef = $(`&lt;div id=&quot;html_e66e13a9d9737decadfd7fd90e39b2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ec4ee48affc36613f5f68ae48137f6a0.setContent(html_e66e13a9d9737decadfd7fd90e39b2ef);
#
#
#
#         marker_2f0e7af0b6e22f7094d057bbb6bc99fb.bindPopup(popup_ec4ee48affc36613f5f68ae48137f6a0)
#         ;
#
#
#
#
#             var marker_2cef6171e24b547596fc27dbe2f549f6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3df2a1229d696c6c3894d3746a9c7f5d);
#
#
#         var popup_6f4bb8b33d22a753b01f313ae8710744 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fe58a7a86295891a83404757690eda9 = $(`&lt;div id=&quot;html_3fe58a7a86295891a83404757690eda9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6f4bb8b33d22a753b01f313ae8710744.setContent(html_3fe58a7a86295891a83404757690eda9);
#
#
#
#         marker_
