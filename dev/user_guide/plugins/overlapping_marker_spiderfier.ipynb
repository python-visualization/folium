# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_164c99d09e6a0b26534ec9bb68e325c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_164c99d09e6a0b26534ec9bb68e325c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_164c99d09e6a0b26534ec9bb68e325c5 = L.map(
#                 &quot;map_164c99d09e6a0b26534ec9bb68e325c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62370764c588659a560403b7ecfa90f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62370764c588659a560403b7ecfa90f8.addTo(map_164c99d09e6a0b26534ec9bb68e325c5);
#
#
#             var marker_bcd4bd5c5a26054afbf80213842b5810 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_164c99d09e6a0b26534ec9bb68e325c5);
#
#
#         var popup_2f479c67ae023cd5e24b0e1a0d3f4153 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc3996c996ec3995a4beefcda8ad312a = $(`&lt;div id=&quot;html_bc3996c996ec3995a4beefcda8ad312a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2f479c67ae023cd5e24b0e1a0d3f4153.setContent(html_bc3996c996ec3995a4beefcda8ad312a);
#
#
#
#         marker_bcd4bd5c5a26054afbf80213842b5810.bindPopup(popup_2f479c67ae023cd5e24b0e1a0d3f4153)
#         ;
#
#
#
#
#             var marker_05e4c20b00f6f7ab2c8b56376ef1ce5e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_164c99d09e6a0b26534ec9bb68e325c5);
#
#
#         var popup_02600a4208ca4cebba5884eae57ec846 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b87edd9193ba8e0e82d0b736412b225 = $(`&lt;div id=&quot;html_3b87edd9193ba8e0e82d0b736412b225&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_02600a4208ca4cebba5884eae57ec846.setContent(html_3b87edd9193ba8e0e82d0b736412b225);
#
#
#
#         marker_05e4c20b00f6f7ab2c8b56376ef1ce5e.bindPopup(popup_02600a4208ca4cebba5884eae57ec846)
#         ;
#
#
#
#
#             var marker_c019c0b2e8c0a3eb477da99734ff3a8c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_164c99d09e6a0b26534ec9bb68e325c5);
#
#
#         var popup_726ce6712500be8e2151bb81760854d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8546279aa6804847d6fdc58df7311016 = $(`&lt;div id=&quot;html_8546279aa6804847d6fdc58df7311016&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_726ce6712500be8e2151bb81760854d2.setContent(html_8546279aa6804847d6fdc58df7311016);
#
#
#
#         marker_c019c0b2e8c0a3eb477da99734ff3a8c.bindPopup(popup_726ce6712500be8e2151bb81760854d2)
#         ;
#
#
#
#
#             var marker_7539adb65012a55ca4e41c0fdadcda5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_164c99d09e6a0b26534ec9bb68e325c5);
#
#
#         var popup_a756c534c224101ef83babbd273eb9ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc9715ccb471feaa58c4d8e11267bad7 = $(`&lt;div id=&quot;html_bc9715ccb471feaa58c4d8e11267bad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a756c534c224101ef83babbd273eb9ee.setContent(html_bc9715ccb471feaa58c4d8e11267bad7);
#
#
#
#         marker_7539adb65012a55ca4e41c0fdadcda5d.bindPopup(popup_a756c534c224101ef83babbd273eb9ee)
#         ;
#
#
#
#
#             var marker_1fb3ad88eef699cb55742931b5782b86 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_164c99d09e6a0b26534ec9bb68e325c5);
#
#
#         var popup_887a298c3897a991a19a9e9cbc058a50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb512eaac6d8d3d4486a449485faf278 = $(`&lt;div id=&quot;html_fb512eaac6d8d3d4486a449485faf278&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_887a298c3897a991a19a9e9cbc058a50.setContent(html_fb512eaac6d8d3d4486a449485faf278);
#
#
#
#         marker_1fb3ad88eef699cb55742931b5782b86.bindPopup(popup_887a298c3897a991a19a9e9cbc058a50)
#         ;
#
#
#
#
#             var marker_0c0be6e170

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6def7769ce4030059e099d63a2d7c23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6def7769ce4030059e099d63a2d7c23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6def7769ce4030059e099d63a2d7c23 = L.map(
#                 &quot;map_c6def7769ce4030059e099d63a2d7c23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e48da6b3a1aff256342cde93c236b92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e48da6b3a1aff256342cde93c236b92.addTo(map_c6def7769ce4030059e099d63a2d7c23);
#
#
#             var feature_group_cf5bc28437d5d394ec45e4c8fab057a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fbf0a393ac2522d46ea43b6217d7a1b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cf5bc28437d5d394ec45e4c8fab057a3);
#
#
#         var popup_569fedd9fa2ba04283849a8e05d5e4f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f3cbdf9346e1574b0edf1ffc01b7bc0 = $(`&lt;div id=&quot;html_2f3cbdf9346e1574b0edf1ffc01b7bc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_569fedd9fa2ba04283849a8e05d5e4f5.setContent(html_2f3cbdf9346e1574b0edf1ffc01b7bc0);
#
#
#
#         marker_fbf0a393ac2522d46ea43b6217d7a1b3.bindPopup(popup_569fedd9fa2ba04283849a8e05d5e4f5)
#         ;
#
#
#
#
#             var marker_ff26034d8c7408257112417b3fa71c7e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cf5bc28437d5d394ec45e4c8fab057a3);
#
#
#         var popup_5c2c95477e8cd533d21bddd90dfe4523 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_204fda6ca6c1d10eb56bc57c365d13b9 = $(`&lt;div id=&quot;html_204fda6ca6c1d10eb56bc57c365d13b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5c2c95477e8cd533d21bddd90dfe4523.setContent(html_204fda6ca6c1d10eb56bc57c365d13b9);
#
#
#
#         marker_ff26034d8c7408257112417b3fa71c7e.bindPopup(popup_5c2c95477e8cd533d21bddd90dfe4523)
#         ;
#
#
#
#
#             var marker_a1b8d26b56dcb042ffc16948c48e970f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cf5bc28437d5d394ec45e4c8fab057a3);
#
#
#         var popup_d1331ebe7006064ecce16cd831cc1b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_288e0a24fe1f735e6885bdbb5589cf23 = $(`&lt;div id=&quot;html_288e0a24fe1f735e6885bdbb5589cf23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d1331ebe7006064ecce16cd831cc1b24.setContent(html_288e0a24fe1f735e6885bdbb5589cf23);
#
#
#
#         marker_a1b8d26b56dcb042ffc16948c48e970f.bindPopup(popup_d1331ebe7006064ecce16cd831cc1b24)
#         ;
#
#
#
#
#             var marker_7381654c4b54b3c775a56eec7d3f54be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cf5bc28437d5d394ec45e4c8fab057a3);
#
#
#         var popup_2b8dad2e4d49f18f189a25d30a9f7b0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551bff1c709333577234f93267f85e13 = $(`&lt;div id=&quot;html_551bff1c709333577234f93267f85e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2b8dad2e4d49f18f189a25d30a9f7b0e.setContent(html_551bff1c709333577234f93267f85e13);
#
#
#
#         marker_7381654c4b54b3c775a56eec7d3f54be.bindPopup(popup_2b8dad2e4d49f18f189a25d30a9f7b0e)
#         ;
#
#
#
#
#             var marker_9e85b603ce769629be336ac364f0c9a3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cf5bc28437d5d394ec45e4c8fab057a3);
#
#
#         var popup_2e04b704e783bb41d9a19389e9e1e393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5c7ef47f5a5bd01c182a96ae9c52aba = $(`&lt;div id=&quot;html_a5c7ef47f5a5bd01c182a96ae9c52aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_2e04b704e783bb41d9

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d256cf612b733072ee43bf3cc047cc52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d256cf612b733072ee43bf3cc047cc52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d256cf612b733072ee43bf3cc047cc52 = L.map(
#                 &quot;map_d256cf612b733072ee43bf3cc047cc52&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2cc30c43ec829cb3c8efabc2ab8a6ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2cc30c43ec829cb3c8efabc2ab8a6ad.addTo(map_d256cf612b733072ee43bf3cc047cc52);
#
#
#             var feature_group_1d0f6dcb4cb57ad4f90d677a7017886b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1d0f6dcb4cb57ad4f90d677a7017886b.addTo(map_d256cf612b733072ee43bf3cc047cc52);
#
#
#             var feature_group_sub_group_74c8291f98f59e55206949706d61478b = L.featureGroup.subGroup(
#                 feature_group_1d0f6dcb4cb57ad4f90d677a7017886b
#             );
#
#
#             var marker_4850bb0a646c8c4e17c545d810671e7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c8291f98f59e55206949706d61478b);
#
#
#         var popup_5f9299b0bf72c66c940e6018df22fd43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cdef9b00c2636659510c93269227a13 = $(`&lt;div id=&quot;html_4cdef9b00c2636659510c93269227a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5f9299b0bf72c66c940e6018df22fd43.setContent(html_4cdef9b00c2636659510c93269227a13);
#
#
#
#         marker_4850bb0a646c8c4e17c545d810671e7d.bindPopup(popup_5f9299b0bf72c66c940e6018df22fd43)
#         ;
#
#
#
#
#             var marker_946f3e619f0a54795d54fa460f1b2ceb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c8291f98f59e55206949706d61478b);
#
#
#         var popup_93da029ec1eef70d01f2cd2d04175525 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44f5c7d0f2f63c1bea767a80e6c000fa = $(`&lt;div id=&quot;html_44f5c7d0f2f63c1bea767a80e6c000fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_93da029ec1eef70d01f2cd2d04175525.setContent(html_44f5c7d0f2f63c1bea767a80e6c000fa);
#
#
#
#         marker_946f3e619f0a54795d54fa460f1b2ceb.bindPopup(popup_93da029ec1eef70d01f2cd2d04175525)
#         ;
#
#
#
#
#             var marker_d0b3a0104cc82c74a0402b88c40ce4fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c8291f98f59e55206949706d61478b);
#
#
#         var popup_5ca1d52823c058df88f07fdfb8c6c01c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8f568d8b12f4292f078eca7c9e22587 = $(`&lt;div id=&quot;html_f8f568d8b12f4292f078eca7c9e22587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5ca1d52823c058df88f07fdfb8c6c01c.setContent(html_f8f568d8b12f4292f078eca7c9e22587);
#
#
#
#         marker_d0b3a0104cc82c74a0402b88c40ce4fd.bindPopup(popup_5ca1d52823c058df88f07fdfb8c6c01c)
#         ;
#
#
#
#
#             var marker_617b56af1ae2767472abd9b87340ef28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c8291f98f59e55206949706d61478b);
#
#
#         var popup_ba3f54c6331b1ad4d625a2fa3a35a066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_321418a561f197a515f6abaeb69ce7d6 = $(`&lt;div id=&quot;html_321418a561f197a515f6abaeb69ce7d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ba3f54c6331b1ad4d625a2fa3a35a066.setContent(html_321418a561f197a515f6abaeb69ce7d6);
#
#
#
#         marker_617b56af1ae2767472abd9b87340ef28.bindPopup(popup_ba3f54c6331b1ad4d625a2fa3a35a066)
#         ;
#
#
#
#
#             var marker_63516eecccf7ab1347d8b07d7b3d349d = L.marker(
#                 [45.050399999999996, 3.0504],
