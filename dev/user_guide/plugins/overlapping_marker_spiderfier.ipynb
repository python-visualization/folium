# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21165d07b7f534fe13eb8f3ea21c2f77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21165d07b7f534fe13eb8f3ea21c2f77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21165d07b7f534fe13eb8f3ea21c2f77 = L.map(
#                 &quot;map_21165d07b7f534fe13eb8f3ea21c2f77&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a5f77ea39181cf9a003698fbf2cde7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a5f77ea39181cf9a003698fbf2cde7c.addTo(map_21165d07b7f534fe13eb8f3ea21c2f77);
#
#
#             var marker_848401dfeb2ea1a982629c694252d390 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_21165d07b7f534fe13eb8f3ea21c2f77);
#
#
#         var popup_f1d86746116dedda407f72b208487296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5fe49972924750fbfe150ffc7e1a555 = $(`&lt;div id=&quot;html_d5fe49972924750fbfe150ffc7e1a555&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f1d86746116dedda407f72b208487296.setContent(html_d5fe49972924750fbfe150ffc7e1a555);
#
#
#
#         marker_848401dfeb2ea1a982629c694252d390.bindPopup(popup_f1d86746116dedda407f72b208487296)
#         ;
#
#
#
#
#             var marker_4cad051d768436f062c722725295e04c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_21165d07b7f534fe13eb8f3ea21c2f77);
#
#
#         var popup_803823aee99e7a01bb4b266da30a84be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35cda9a6b078d113597e49139549ec53 = $(`&lt;div id=&quot;html_35cda9a6b078d113597e49139549ec53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_803823aee99e7a01bb4b266da30a84be.setContent(html_35cda9a6b078d113597e49139549ec53);
#
#
#
#         marker_4cad051d768436f062c722725295e04c.bindPopup(popup_803823aee99e7a01bb4b266da30a84be)
#         ;
#
#
#
#
#             var marker_d6def6860db3378f1910d72577045829 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_21165d07b7f534fe13eb8f3ea21c2f77);
#
#
#         var popup_4c8c98ae64e58736c997f7102326933e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a117b452cd1dffe6140a5e9d53e3fe4d = $(`&lt;div id=&quot;html_a117b452cd1dffe6140a5e9d53e3fe4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4c8c98ae64e58736c997f7102326933e.setContent(html_a117b452cd1dffe6140a5e9d53e3fe4d);
#
#
#
#         marker_d6def6860db3378f1910d72577045829.bindPopup(popup_4c8c98ae64e58736c997f7102326933e)
#         ;
#
#
#
#
#             var marker_4560916efb9c6d78af68fa585612cac0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_21165d07b7f534fe13eb8f3ea21c2f77);
#
#
#         var popup_a338043b5e8fd43ac7b98dc3abe3439e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44cd18ca226e735b7273bc1a9e630ae9 = $(`&lt;div id=&quot;html_44cd18ca226e735b7273bc1a9e630ae9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a338043b5e8fd43ac7b98dc3abe3439e.setContent(html_44cd18ca226e735b7273bc1a9e630ae9);
#
#
#
#         marker_4560916efb9c6d78af68fa585612cac0.bindPopup(popup_a338043b5e8fd43ac7b98dc3abe3439e)
#         ;
#
#
#
#
#             var marker_e82a50d25d70de5e6961265f779bd7f4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_21165d07b7f534fe13eb8f3ea21c2f77);
#
#
#         var popup_8f8c2a804827fd09ba24f5816d38c181 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f94d7aaad83d8b472447f46772099713 = $(`&lt;div id=&quot;html_f94d7aaad83d8b472447f46772099713&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8f8c2a804827fd09ba24f5816d38c181.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bb653cc130982108ec953ae1f9a11cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bb653cc130982108ec953ae1f9a11cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bb653cc130982108ec953ae1f9a11cc = L.map(
#                 &quot;map_8bb653cc130982108ec953ae1f9a11cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f08a291c49b6a61088a7787b9b12c37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f08a291c49b6a61088a7787b9b12c37.addTo(map_8bb653cc130982108ec953ae1f9a11cc);
#
#
#             var feature_group_e2f11d97292c22e36ed85f458cde9ffc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_166468aa4e43129576261e11a3c5d8bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e2f11d97292c22e36ed85f458cde9ffc);
#
#
#         var popup_8a7021f86170561b3a7a468249f572cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6259b14523d37bd9f89e965e25e4cfba = $(`&lt;div id=&quot;html_6259b14523d37bd9f89e965e25e4cfba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8a7021f86170561b3a7a468249f572cb.setContent(html_6259b14523d37bd9f89e965e25e4cfba);
#
#
#
#         marker_166468aa4e43129576261e11a3c5d8bc.bindPopup(popup_8a7021f86170561b3a7a468249f572cb)
#         ;
#
#
#
#
#             var marker_12440bb06e2e4adda736ec162c189c2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e2f11d97292c22e36ed85f458cde9ffc);
#
#
#         var popup_6b9bc485bd2b12b5e76ef29501fc86e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cbff0800a26b40b5a39abde5b32172c = $(`&lt;div id=&quot;html_7cbff0800a26b40b5a39abde5b32172c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6b9bc485bd2b12b5e76ef29501fc86e6.setContent(html_7cbff0800a26b40b5a39abde5b32172c);
#
#
#
#         marker_12440bb06e2e4adda736ec162c189c2d.bindPopup(popup_6b9bc485bd2b12b5e76ef29501fc86e6)
#         ;
#
#
#
#
#             var marker_0e973fc610aea7f581bab698b07ea5fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e2f11d97292c22e36ed85f458cde9ffc);
#
#
#         var popup_efd858a84a2ad94d5443a30996324124 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8b40ff42b3b513cdba06f8f3455bb0d = $(`&lt;div id=&quot;html_e8b40ff42b3b513cdba06f8f3455bb0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_efd858a84a2ad94d5443a30996324124.setContent(html_e8b40ff42b3b513cdba06f8f3455bb0d);
#
#
#
#         marker_0e973fc610aea7f581bab698b07ea5fd.bindPopup(popup_efd858a84a2ad94d5443a30996324124)
#         ;
#
#
#
#
#             var marker_1cad286856b9cc963a6bb9b5fc4cf848 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e2f11d97292c22e36ed85f458cde9ffc);
#
#
#         var popup_9443acc8b0ef4430ec70ff38c58e3b8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58c9a7bdfb53fcbb199340756814c579 = $(`&lt;div id=&quot;html_58c9a7bdfb53fcbb199340756814c579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9443acc8b0ef4430ec70ff38c58e3b8d.setContent(html_58c9a7bdfb53fcbb199340756814c579);
#
#
#
#         marker_1cad286856b9cc963a6bb9b5fc4cf848.bindPopup(popup_9443acc8b0ef4430ec70ff38c58e3b8d)
#         ;
#
#
#
#
#             var marker_5c52290c993c958061c8e9a505c6d7aa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e2f11d97292c22e36ed85f458cde9ffc);
#
#
#         var popup_2247ea8846230a135aed796a6f789f37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09a1b88cb8461595791a80f935811f8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09a1b88cb8461595791a80f935811f8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09a1b88cb8461595791a80f935811f8f = L.map(
#                 &quot;map_09a1b88cb8461595791a80f935811f8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4da1b6589b2125e19a31b3b983e5e9b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4da1b6589b2125e19a31b3b983e5e9b8.addTo(map_09a1b88cb8461595791a80f935811f8f);
#
#
#             var feature_group_bd6f55f22666f6942644b88801839ed8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bd6f55f22666f6942644b88801839ed8.addTo(map_09a1b88cb8461595791a80f935811f8f);
#
#
#             var feature_group_sub_group_946256967ea651270c2cf6e3eab53ac6 = L.featureGroup.subGroup(
#                 feature_group_bd6f55f22666f6942644b88801839ed8
#             );
#
#
#             var marker_abc76d230b7fb010b6c6ae9103f0b0d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_946256967ea651270c2cf6e3eab53ac6);
#
#
#         var popup_212df61f6c3079f3c16d18a8921799a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bdd24b87d61810bfbc64a87e1f72c8f = $(`&lt;div id=&quot;html_7bdd24b87d61810bfbc64a87e1f72c8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_212df61f6c3079f3c16d18a8921799a5.setContent(html_7bdd24b87d61810bfbc64a87e1f72c8f);
#
#
#
#         marker_abc76d230b7fb010b6c6ae9103f0b0d4.bindPopup(popup_212df61f6c3079f3c16d18a8921799a5)
#         ;
#
#
#
#
#             var marker_6cd5e159912b293992b4303a3799f99c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_946256967ea651270c2cf6e3eab53ac6);
#
#
#         var popup_3858e3e4174f923da0792f03f098f79d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae12f10a35d43a7f978f2a5e942a846b = $(`&lt;div id=&quot;html_ae12f10a35d43a7f978f2a5e942a846b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3858e3e4174f923da0792f03f098f79d.setContent(html_ae12f10a35d43a7f978f2a5e942a846b);
#
#
#
#         marker_6cd5e159912b293992b4303a3799f99c.bindPopup(popup_3858e3e4174f923da0792f03f098f79d)
#         ;
#
#
#
#
#             var marker_053c11dbd632d6206c2203c84ca39f5e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_946256967ea651270c2cf6e3eab53ac6);
#
#
#         var popup_3ccf29b721e6bba7efe6b22a924e6104 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07a21b661a00d5ed1f1d9b586d812174 = $(`&lt;div id=&quot;html_07a21b661a00d5ed1f1d9b586d812174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3ccf29b721e6bba7efe6b22a924e6104.setContent(html_07a21b661a00d5ed1f1d9b586d812174);
#
#
#
#         marker_053c11dbd632d6206c2203c84ca39f5e.bindPopup(popup_3ccf29b721e6bba7efe6b22a924e6104)
#         ;
#
#
#
#
#             var marker_bc4db76c7ce3ed576fc5ad7f5d7072c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_946256967ea651270c2cf6e3eab53ac6);
#
#
#         var popup_79401a2673fbc9fb81a2d215e1600681 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6a294708fe39be6ce9ff6a8abdecea9 = $(`&lt;div id=&quot;html_b6a294708fe39be6ce9ff6a8abdecea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_79401a2673fbc9fb81a2d215e1600681.setContent(html_b6a294708fe39be6ce9ff6a8abdecea9);
#
#
#
#         marker_
