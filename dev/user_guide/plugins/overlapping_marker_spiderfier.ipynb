# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32724fe600e0222402a20d062b0bcdaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32724fe600e0222402a20d062b0bcdaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32724fe600e0222402a20d062b0bcdaa = L.map(
#                 &quot;map_32724fe600e0222402a20d062b0bcdaa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61fa8a15b2446548457b49d4cae8e300 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61fa8a15b2446548457b49d4cae8e300.addTo(map_32724fe600e0222402a20d062b0bcdaa);
#
#
#             var marker_b1ccc69db6a6e5a236afd4c8831807d8 = L.marker(
#                 [45.05, 3.05],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_32724fe600e0222402a20d062b0bcdaa);
#
#
#         var popup_48b8ece9a92b9be0d9b32aa1f89f9c4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_694ba89f4acf068d096eb74776575062 = $(`&lt;div id=&quot;html_694ba89f4acf068d096eb74776575062&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_48b8ece9a92b9be0d9b32aa1f89f9c4e.setContent(html_694ba89f4acf068d096eb74776575062);
#
#
#
#         marker_b1ccc69db6a6e5a236afd4c8831807d8.bindPopup(popup_48b8ece9a92b9be0d9b32aa1f89f9c4e)
#         ;
#
#
#
#
#             var marker_ba47144b2cd572740342be39b7090615 = L.marker(
#                 [45.0501, 3.0501],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_32724fe600e0222402a20d062b0bcdaa);
#
#
#         var popup_02ac41ff166577b4acbc812a625bdfab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_edc497ea6aaffa8b8786502ee06f5ca3 = $(`&lt;div id=&quot;html_edc497ea6aaffa8b8786502ee06f5ca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_02ac41ff166577b4acbc812a625bdfab.setContent(html_edc497ea6aaffa8b8786502ee06f5ca3);
#
#
#
#         marker_ba47144b2cd572740342be39b7090615.bindPopup(popup_02ac41ff166577b4acbc812a625bdfab)
#         ;
#
#
#
#
#             var marker_4c7701ab0367ef9bf72a2d05bc88ccb7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_32724fe600e0222402a20d062b0bcdaa);
#
#
#         var popup_4e68dba52519cff3922e2c4e2973e4c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_f26971ddeefcceca2f3273eab7d8b1f6 = $(`&lt;div id=&quot;html_f26971ddeefcceca2f3273eab7d8b1f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4e68dba52519cff3922e2c4e2973e4c5.setContent(html_f26971ddeefcceca2f3273eab7d8b1f6);
#
#
#
#         marker_4c7701ab0367ef9bf72a2d05bc88ccb7.bindPopup(popup_4e68dba52519cff3922e2c4e2973e4c5)
#         ;
#
#
#
#
#             var marker_36d74196681f9122ffa2b73a4785de11 = L.marker(
#                 [45.0503, 3.0503],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_32724fe600e0222402a20d062b0bcdaa);
#
#
#         var popup_219c100f6c2e7c124e5ba3bc14771400 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_85e36774b168b77ea59caed5c510399e = $(`&lt;div id=&quot;html_85e36774b168b77ea59caed5c510399e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_219c100f6c2e7c124e5ba3bc14771400.setContent(html_85e36774b168b77ea59caed5c510399e);
#
#
#
#         marker_36d74196681f9122ffa2b73a4785de11.bindPopup(popup_219c100f6c2e7c124e5ba3bc14771400)
#         ;
#
#
#
#
#             var marker_455459e43dcfb0c1883593c67b962e7b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_32724fe600e0222402a20d062b0bcdaa);
#
#
#         var popup_490fc6d0cf4fae3e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3ebe5ce3d47008ca57d281625e7536b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3ebe5ce3d47008ca57d281625e7536b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3ebe5ce3d47008ca57d281625e7536b = L.map(
#                 &quot;map_f3ebe5ce3d47008ca57d281625e7536b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e65a7fe603b5b0fbb7e36c9258d8354b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e65a7fe603b5b0fbb7e36c9258d8354b.addTo(map_f3ebe5ce3d47008ca57d281625e7536b);
#
#
#             var feature_group_5ea5d0022a30328bd0d143ea0e192b97 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f8907a44bc59266b0d015d4f6d86bfe0 = L.marker(
#                 [45.05, 3.05],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_5ea5d0022a30328bd0d143ea0e192b97);
#
#
#         var popup_370aa6bc89113e97a7cf26ed15edc933 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_358d5445a9ce231637cf8307dc43a92d = $(`&lt;div id=&quot;html_358d5445a9ce231637cf8307dc43a92d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_370aa6bc89113e97a7cf26ed15edc933.setContent(html_358d5445a9ce231637cf8307dc43a92d);
#
#
#
#         marker_f8907a44bc59266b0d015d4f6d86bfe0.bindPopup(popup_370aa6bc89113e97a7cf26ed15edc933)
#         ;
#
#
#
#
#             var marker_a784fc381c3d29a7cb6f70dcc79aca52 = L.marker(
#                 [45.0501, 3.0501],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_5ea5d0022a30328bd0d143ea0e192b97);
#
#
#         var popup_ec739440c0baa8c585fa6e505e823548 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_5a084fe2496c976c270afa1674a94f7c = $(`&lt;div id=&quot;html_5a084fe2496c976c270afa1674a94f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ec739440c0baa8c585fa6e505e823548.setContent(html_5a084fe2496c976c270afa1674a94f7c);
#
#
#
#         marker_a784fc381c3d29a7cb6f70dcc79aca52.bindPopup(popup_ec739440c0baa8c585fa6e505e823548)
#         ;
#
#
#
#
#             var marker_75b1800c63d0f12fe66ab25f58592efa = L.marker(
#                 [45.0502, 3.0502],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_5ea5d0022a30328bd0d143ea0e192b97);
#
#
#         var popup_80753ffa4a002a11dc813b4542da8463 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_c0e75eb94437ea09bed7febdd526bdf5 = $(`&lt;div id=&quot;html_c0e75eb94437ea09bed7febdd526bdf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_80753ffa4a002a11dc813b4542da8463.setContent(html_c0e75eb94437ea09bed7febdd526bdf5);
#
#
#
#         marker_75b1800c63d0f12fe66ab25f58592efa.bindPopup(popup_80753ffa4a002a11dc813b4542da8463)
#         ;
#
#
#
#
#             var marker_91c156c9eea02b86cacad67c0569a4f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_5ea5d0022a30328bd0d143ea0e192b97);
#
#
#         var popup_6163ee3c02c125a63c861a22ef5c630e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_0e0b0ba1b67318dfbdc821b4cf12c3bd = $(`&lt;div id=&quot;html_0e0b0ba1b67318dfbdc821b4cf12c3bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6163ee3c02c125a63c861a22ef5c630e.setContent(html_0e0b0ba1b67318dfbdc821b4cf12c3bd);
#
#
#
#         marker_91c156c9eea02b86cacad67c0569a4f8.bindPopup(popup_6163ee3c02c125a63c861a22ef5c630e)
#         ;
#
#
#
#
#             var marker_d65448a64a1dc847368693a0a9d4a74d = L.marker(

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd2672d6fa6d17e37a09e4b52a411edc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd2672d6fa6d17e37a09e4b52a411edc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd2672d6fa6d17e37a09e4b52a411edc = L.map(
#                 &quot;map_dd2672d6fa6d17e37a09e4b52a411edc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f66adb5659b2ac78681cf3de2ffe4f70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f66adb5659b2ac78681cf3de2ffe4f70.addTo(map_dd2672d6fa6d17e37a09e4b52a411edc);
#
#
#             var feature_group_70d205c1a891063c38d28f706b1db411 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_70d205c1a891063c38d28f706b1db411.addTo(map_dd2672d6fa6d17e37a09e4b52a411edc);
#
#
#             var feature_group_sub_group_dfbd5dba5c4b98536faba0e1364a6e27 = L.featureGroup.subGroup(
#                 feature_group_70d205c1a891063c38d28f706b1db411
#             );
#
#
#             var marker_eff7ad46c8120f68edbd8ecf328ca112 = L.marker(
#                 [45.05, 3.05],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_dfbd5dba5c4b98536faba0e1364a6e27);
#
#
#         var popup_ddcbdbd25078abfc45131b91871c4bf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_2dfea5201bdc8a7b51532226ccba9930 = $(`&lt;div id=&quot;html_2dfea5201bdc8a7b51532226ccba9930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ddcbdbd25078abfc45131b91871c4bf4.setContent(html_2dfea5201bdc8a7b51532226ccba9930);
#
#
#
#         marker_eff7ad46c8120f68edbd8ecf328ca112.bindPopup(popup_ddcbdbd25078abfc45131b91871c4bf4)
#         ;
#
#
#
#
#             var marker_0f3851a1156c72a13ed248b4f9060d66 = L.marker(
#                 [45.0501, 3.0501],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_dfbd5dba5c4b98536faba0e1364a6e27);
#
#
#         var popup_4a27ac8e9603c93cd0f73a29bf1146fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_947f3c7022c581d3ff1ea4cec7717ca6 = $(`&lt;div id=&quot;html_947f3c7022c581d3ff1ea4cec7717ca6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4a27ac8e9603c93cd0f73a29bf1146fe.setContent(html_947f3c7022c581d3ff1ea4cec7717ca6);
#
#
#
#         marker_0f3851a1156c72a13ed248b4f9060d66.bindPopup(popup_4a27ac8e9603c93cd0f73a29bf1146fe)
#         ;
#
#
#
#
#             var marker_7bb765f66641229e44917ff6cc54ac6f = L.marker(
#                 [45.0502, 3.0502],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_dfbd5dba5c4b98536faba0e1364a6e27);
#
#
#         var popup_303f19b31c1de8cd9a1b7eb05651f00f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_285bd75bb8232ccdb6c482042465e9e0 = $(`&lt;div id=&quot;html_285bd75bb8232ccdb6c482042465e9e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_303f19b31c1de8cd9a1b7eb05651f00f.setContent(html_285bd75bb8232ccdb6c482042465e9e0);
#
#
#
#         marker_7bb765f66641229e44917ff6cc54ac6f.bindPopup(popup_303f19b31c1de8cd9a1b7eb05651f00f)
#         ;
#
#
#
#
#             var marker_1e462714ab36059131a3ec36fa19a833 = L.marker(
#                 [45.0503, 3.0503],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_sub_group_dfbd5dba5c4b98536faba0e1364a6e27);
#
#
#         var popup_fe5bce1ce91ae3f7aaabf36649c8972a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_bdd6fc5ab8d054805476b63996e00c8f = $(`
