# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c8c3ca77d031e58b867a7c507e95df1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c8c3ca77d031e58b867a7c507e95df1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c8c3ca77d031e58b867a7c507e95df1 = L.map(
#                 &quot;map_1c8c3ca77d031e58b867a7c507e95df1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee6873112dd0c9fecf4239268c360fc6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee6873112dd0c9fecf4239268c360fc6.addTo(map_1c8c3ca77d031e58b867a7c507e95df1);
#
#
#             var marker_2f25c33aa80bac6899f00d64363c34f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1c8c3ca77d031e58b867a7c507e95df1);
#
#
#         var popup_c9a3d551e420e8faca4f42fc0aa8abd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_892f62dfb7bff8dd6d94d5514557e174 = $(`&lt;div id=&quot;html_892f62dfb7bff8dd6d94d5514557e174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c9a3d551e420e8faca4f42fc0aa8abd2.setContent(html_892f62dfb7bff8dd6d94d5514557e174);
#
#
#
#         marker_2f25c33aa80bac6899f00d64363c34f7.bindPopup(popup_c9a3d551e420e8faca4f42fc0aa8abd2)
#         ;
#
#
#
#
#             var marker_e4d429a9ce2081ae5764dccaa1ac7469 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1c8c3ca77d031e58b867a7c507e95df1);
#
#
#         var popup_cd0d9d811630a8c022eedbdc94f81b90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ab46fffa6e1c996e7b769bc51b38d11 = $(`&lt;div id=&quot;html_4ab46fffa6e1c996e7b769bc51b38d11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cd0d9d811630a8c022eedbdc94f81b90.setContent(html_4ab46fffa6e1c996e7b769bc51b38d11);
#
#
#
#         marker_e4d429a9ce2081ae5764dccaa1ac7469.bindPopup(popup_cd0d9d811630a8c022eedbdc94f81b90)
#         ;
#
#
#
#
#             var marker_ca813bfc318106cc71f9974c7d520e6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1c8c3ca77d031e58b867a7c507e95df1);
#
#
#         var popup_2db69836333e3e86ed91ec39b7fdc2f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_543bc371457843cd6e624fbbcf27ba4f = $(`&lt;div id=&quot;html_543bc371457843cd6e624fbbcf27ba4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2db69836333e3e86ed91ec39b7fdc2f8.setContent(html_543bc371457843cd6e624fbbcf27ba4f);
#
#
#
#         marker_ca813bfc318106cc71f9974c7d520e6a.bindPopup(popup_2db69836333e3e86ed91ec39b7fdc2f8)
#         ;
#
#
#
#
#             var marker_4d840b8136535a57a31054b68344132f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1c8c3ca77d031e58b867a7c507e95df1);
#
#
#         var popup_f798ace259a8342959204df0841a6dc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78bbab6683df741cd316c1a48a294e87 = $(`&lt;div id=&quot;html_78bbab6683df741cd316c1a48a294e87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f798ace259a8342959204df0841a6dc1.setContent(html_78bbab6683df741cd316c1a48a294e87);
#
#
#
#         marker_4d840b8136535a57a31054b68344132f.bindPopup(popup_f798ace259a8342959204df0841a6dc1)
#         ;
#
#
#
#
#             var marker_d7afac4a05ee6ff6719f8d21310f49ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1c8c3ca77d031e58b867a7c507e95df1);
#
#
#         var popup_1c1ae045a3848eb6f6f954ba494681b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1b17f88622a9049db94f2c78b05ec7d = $(`&lt;div id=&quot;html_d1b17f88622a9049db94f2c78b05ec7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1c1ae045a3848eb6f6f954ba494681b7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c9deb74f684c5754b78db91eca5c23e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c9deb74f684c5754b78db91eca5c23e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c9deb74f684c5754b78db91eca5c23e = L.map(
#                 &quot;map_7c9deb74f684c5754b78db91eca5c23e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5edd8986770f1ae40872c0e4f3d80b6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5edd8986770f1ae40872c0e4f3d80b6c.addTo(map_7c9deb74f684c5754b78db91eca5c23e);
#
#
#             var feature_group_6e55591ec0799cd5bccddc444fec5acc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3d3d1489c2fd212a3a3a981b0adb0d54 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6e55591ec0799cd5bccddc444fec5acc);
#
#
#         var popup_7dadac9e6111df2b73cc5eed127554db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_221f324d9d6ca41e13eb0b1e3b2a1033 = $(`&lt;div id=&quot;html_221f324d9d6ca41e13eb0b1e3b2a1033&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7dadac9e6111df2b73cc5eed127554db.setContent(html_221f324d9d6ca41e13eb0b1e3b2a1033);
#
#
#
#         marker_3d3d1489c2fd212a3a3a981b0adb0d54.bindPopup(popup_7dadac9e6111df2b73cc5eed127554db)
#         ;
#
#
#
#
#             var marker_940cdf8666d22c96c32a6878c36e7a43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6e55591ec0799cd5bccddc444fec5acc);
#
#
#         var popup_c52ef556eb0b0b04f000466e8377332b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fa00dff7cf09d579d9ec95776b666fd = $(`&lt;div id=&quot;html_3fa00dff7cf09d579d9ec95776b666fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c52ef556eb0b0b04f000466e8377332b.setContent(html_3fa00dff7cf09d579d9ec95776b666fd);
#
#
#
#         marker_940cdf8666d22c96c32a6878c36e7a43.bindPopup(popup_c52ef556eb0b0b04f000466e8377332b)
#         ;
#
#
#
#
#             var marker_e33775c2a88cd1db036b033093601369 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6e55591ec0799cd5bccddc444fec5acc);
#
#
#         var popup_43acc3ad736f316b007db81bbe82b85e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91b9e21b6585edc234cb9854df68bb3e = $(`&lt;div id=&quot;html_91b9e21b6585edc234cb9854df68bb3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_43acc3ad736f316b007db81bbe82b85e.setContent(html_91b9e21b6585edc234cb9854df68bb3e);
#
#
#
#         marker_e33775c2a88cd1db036b033093601369.bindPopup(popup_43acc3ad736f316b007db81bbe82b85e)
#         ;
#
#
#
#
#             var marker_abb7a451817b4a3e3c6a3b0456c94f6b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6e55591ec0799cd5bccddc444fec5acc);
#
#
#         var popup_fea344bca8d6a7a3127b73c7811c7eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f5070018c06b085f60a92ccebc9772c = $(`&lt;div id=&quot;html_0f5070018c06b085f60a92ccebc9772c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fea344bca8d6a7a3127b73c7811c7eb9.setContent(html_0f5070018c06b085f60a92ccebc9772c);
#
#
#
#         marker_abb7a451817b4a3e3c6a3b0456c94f6b.bindPopup(popup_fea344bca8d6a7a3127b73c7811c7eb9)
#         ;
#
#
#
#
#             var marker_db7cadff5ebf68f178e144f730cd6d4e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6e55591ec0799cd5bccddc444fec5acc);
#
#
#         var popup_4678a3382eb822846f1028231dee004f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1b552540ef52094fd7b8f9430ceefb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1b552540ef52094fd7b8f9430ceefb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1b552540ef52094fd7b8f9430ceefb2 = L.map(
#                 &quot;map_c1b552540ef52094fd7b8f9430ceefb2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce272ccba33c41b3aed80b2bdd1c6f21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce272ccba33c41b3aed80b2bdd1c6f21.addTo(map_c1b552540ef52094fd7b8f9430ceefb2);
#
#
#             var feature_group_ebe3c61d9b2d1f4727e83ad3c5eee042 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ebe3c61d9b2d1f4727e83ad3c5eee042.addTo(map_c1b552540ef52094fd7b8f9430ceefb2);
#
#
#             var feature_group_sub_group_df56dbfd26f9011bfcfa1334fd384f3c = L.featureGroup.subGroup(
#                 feature_group_ebe3c61d9b2d1f4727e83ad3c5eee042
#             );
#
#
#             var marker_661da269db81adff9c4cdce4d5fdc625 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_df56dbfd26f9011bfcfa1334fd384f3c);
#
#
#         var popup_6a2e469fc58dc502cb20b43218610838 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b689d83bc67c9b0003827bb96925f0b1 = $(`&lt;div id=&quot;html_b689d83bc67c9b0003827bb96925f0b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6a2e469fc58dc502cb20b43218610838.setContent(html_b689d83bc67c9b0003827bb96925f0b1);
#
#
#
#         marker_661da269db81adff9c4cdce4d5fdc625.bindPopup(popup_6a2e469fc58dc502cb20b43218610838)
#         ;
#
#
#
#
#             var marker_8700703431ce244c6d4f6a7ae5b9c46b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_df56dbfd26f9011bfcfa1334fd384f3c);
#
#
#         var popup_a3ad411856717ed6ec3df1a0051193aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da0a2ca93d127b862e4ec95d5fa9dc68 = $(`&lt;div id=&quot;html_da0a2ca93d127b862e4ec95d5fa9dc68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a3ad411856717ed6ec3df1a0051193aa.setContent(html_da0a2ca93d127b862e4ec95d5fa9dc68);
#
#
#
#         marker_8700703431ce244c6d4f6a7ae5b9c46b.bindPopup(popup_a3ad411856717ed6ec3df1a0051193aa)
#         ;
#
#
#
#
#             var marker_fd81c11415fe3532289448a6e7fb6997 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_df56dbfd26f9011bfcfa1334fd384f3c);
#
#
#         var popup_600bff143ebcbb1f6414e9f6b2cba00a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70ff841561071db0da331c9d5d33079a = $(`&lt;div id=&quot;html_70ff841561071db0da331c9d5d33079a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_600bff143ebcbb1f6414e9f6b2cba00a.setContent(html_70ff841561071db0da331c9d5d33079a);
#
#
#
#         marker_fd81c11415fe3532289448a6e7fb6997.bindPopup(popup_600bff143ebcbb1f6414e9f6b2cba00a)
#         ;
#
#
#
#
#             var marker_ce1032f423b661e098cedf35f61fc037 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_df56dbfd26f9011bfcfa1334fd384f3c);
#
#
#         var popup_8f61c650ccab8a6fa1d031a948eddc04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec73648fff5d255c0eb853a72835629b = $(`&lt;div id=&quot;html_ec73648fff5d255c0eb853a72835629b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8f61c650ccab8a6fa1d031a948eddc04.setContent(html_ec73648fff5d255c0eb853a72835629b);
#
#
#
#         marker_
