# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88b382ff89881c839c1b20bfdc90d54b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88b382ff89881c839c1b20bfdc90d54b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88b382ff89881c839c1b20bfdc90d54b = L.map(
#                 &quot;map_88b382ff89881c839c1b20bfdc90d54b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d6ee17d29cfd2cbafc475399ebbbf28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d6ee17d29cfd2cbafc475399ebbbf28.addTo(map_88b382ff89881c839c1b20bfdc90d54b);
#
#
#             var marker_10593c84b293c4d924efe123ef7d2304 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_88b382ff89881c839c1b20bfdc90d54b);
#
#
#         var popup_449c023b4c3e6b13f39ad662db34962d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34bb95c05a0b14516b3ebb4126931f82 = $(`&lt;div id=&quot;html_34bb95c05a0b14516b3ebb4126931f82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_449c023b4c3e6b13f39ad662db34962d.setContent(html_34bb95c05a0b14516b3ebb4126931f82);
#
#
#
#         marker_10593c84b293c4d924efe123ef7d2304.bindPopup(popup_449c023b4c3e6b13f39ad662db34962d)
#         ;
#
#
#
#
#             var marker_d5f33cbc9cf243c8be28a0a887e03928 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_88b382ff89881c839c1b20bfdc90d54b);
#
#
#         var popup_410eb30ea67c4eb81493b300efbfd63f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07836b078eabbce2bd64ced637d651e0 = $(`&lt;div id=&quot;html_07836b078eabbce2bd64ced637d651e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_410eb30ea67c4eb81493b300efbfd63f.setContent(html_07836b078eabbce2bd64ced637d651e0);
#
#
#
#         marker_d5f33cbc9cf243c8be28a0a887e03928.bindPopup(popup_410eb30ea67c4eb81493b300efbfd63f)
#         ;
#
#
#
#
#             var marker_be14bec22b81347ef70185ca464bd23d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_88b382ff89881c839c1b20bfdc90d54b);
#
#
#         var popup_cd77680fd9f8cbd917707367bbeb07a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90cab19817c848e4193e09b6736962cb = $(`&lt;div id=&quot;html_90cab19817c848e4193e09b6736962cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cd77680fd9f8cbd917707367bbeb07a8.setContent(html_90cab19817c848e4193e09b6736962cb);
#
#
#
#         marker_be14bec22b81347ef70185ca464bd23d.bindPopup(popup_cd77680fd9f8cbd917707367bbeb07a8)
#         ;
#
#
#
#
#             var marker_21eb610eab07ddd7b097b9c7757fcffe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_88b382ff89881c839c1b20bfdc90d54b);
#
#
#         var popup_6150b1b5684bd2a9a5bf0796b5101f90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_684a015877c35ddb769f332ac0ed10e4 = $(`&lt;div id=&quot;html_684a015877c35ddb769f332ac0ed10e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6150b1b5684bd2a9a5bf0796b5101f90.setContent(html_684a015877c35ddb769f332ac0ed10e4);
#
#
#
#         marker_21eb610eab07ddd7b097b9c7757fcffe.bindPopup(popup_6150b1b5684bd2a9a5bf0796b5101f90)
#         ;
#
#
#
#
#             var marker_d323a7f07d7accc61868af874c0a99fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_88b382ff89881c839c1b20bfdc90d54b);
#
#
#         var popup_bdedfc52119d8672805563c9155a8313 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8891c7f863ec2c2a7807adf9d670178 = $(`&lt;div id=&quot;html_b8891c7f863ec2c2a7807adf9d670178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bdedfc52119d8672805563c9155a8313.setContent(html_b8891c7f863ec2c2a7807adf9d670178);
#
#
#
#         marker_d323a7f07d7accc61868af874c0a99fe.bindPopup(popup_bdedfc52119d8672805563c9155a8313)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71bac4e3fe89564d563a13817757df1c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71bac4e3fe89564d563a13817757df1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71bac4e3fe89564d563a13817757df1c = L.map(
#                 &quot;map_71bac4e3fe89564d563a13817757df1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75eb28d5d655ea6c9f6834d0c4e3720c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75eb28d5d655ea6c9f6834d0c4e3720c.addTo(map_71bac4e3fe89564d563a13817757df1c);
#
#
#             var feature_group_ec5f2ba9a5fee92b2751e888b3f1f018 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a9e1247b36b7d3901ff50e3a7d077642 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ec5f2ba9a5fee92b2751e888b3f1f018);
#
#
#         var popup_425ddd7a12acbfd62ab40a6afe68226d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2bc476e5ee6688025dc15a03ea101c4 = $(`&lt;div id=&quot;html_a2bc476e5ee6688025dc15a03ea101c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_425ddd7a12acbfd62ab40a6afe68226d.setContent(html_a2bc476e5ee6688025dc15a03ea101c4);
#
#
#
#         marker_a9e1247b36b7d3901ff50e3a7d077642.bindPopup(popup_425ddd7a12acbfd62ab40a6afe68226d)
#         ;
#
#
#
#
#             var marker_39437394f2accf9e1a5dd9fd6208126e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ec5f2ba9a5fee92b2751e888b3f1f018);
#
#
#         var popup_84020c94d3f45fcafd34a3818001741f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdf93036b70b28bfabacf39616d1bfbf = $(`&lt;div id=&quot;html_fdf93036b70b28bfabacf39616d1bfbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_84020c94d3f45fcafd34a3818001741f.setContent(html_fdf93036b70b28bfabacf39616d1bfbf);
#
#
#
#         marker_39437394f2accf9e1a5dd9fd6208126e.bindPopup(popup_84020c94d3f45fcafd34a3818001741f)
#         ;
#
#
#
#
#             var marker_f932037a954a0f6929ca42ce28df5989 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ec5f2ba9a5fee92b2751e888b3f1f018);
#
#
#         var popup_d557ea8813ad788488f3018584d964a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22c13e3b81341f8122ce411cfd158a8c = $(`&lt;div id=&quot;html_22c13e3b81341f8122ce411cfd158a8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d557ea8813ad788488f3018584d964a9.setContent(html_22c13e3b81341f8122ce411cfd158a8c);
#
#
#
#         marker_f932037a954a0f6929ca42ce28df5989.bindPopup(popup_d557ea8813ad788488f3018584d964a9)
#         ;
#
#
#
#
#             var marker_f1586f44da0c84a6667dadd9acaac9ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ec5f2ba9a5fee92b2751e888b3f1f018);
#
#
#         var popup_a0ea2c728ff051e251409de7c5343135 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd720a9a7cd01e276d5c2d29a0d9a1ab = $(`&lt;div id=&quot;html_bd720a9a7cd01e276d5c2d29a0d9a1ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a0ea2c728ff051e251409de7c5343135.setContent(html_bd720a9a7cd01e276d5c2d29a0d9a1ab);
#
#
#
#         marker_f1586f44da0c84a6667dadd9acaac9ba.bindPopup(popup_a0ea2c728ff051e251409de7c5343135)
#         ;
#
#
#
#
#             var marker_0fad14d9ccc6a21ede613b3955a50b9f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ec5f2ba9a5fee92b2751e888b3f1f018);
#
#
#         var popup_62a33e177994a2f8c8fb8549be9080f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0b39a31ae9e3df499201f5483ba2c69 = $(`&lt;div id=&quot;html_a0b39a31ae9e3df499201f5483ba2c69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3add8aa18ede2e3292a1bbd1d46f2268 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3add8aa18ede2e3292a1bbd1d46f2268&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3add8aa18ede2e3292a1bbd1d46f2268 = L.map(
#                 &quot;map_3add8aa18ede2e3292a1bbd1d46f2268&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_faa74e0f728ea78f4151458cd327f09c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_faa74e0f728ea78f4151458cd327f09c.addTo(map_3add8aa18ede2e3292a1bbd1d46f2268);
#
#
#             var feature_group_143fd90b80df9d13ff73686d264d0ec9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_143fd90b80df9d13ff73686d264d0ec9.addTo(map_3add8aa18ede2e3292a1bbd1d46f2268);
#
#
#             var feature_group_sub_group_1ac001a4bcf312ad2e3368f20a187a79 = L.featureGroup.subGroup(
#                 feature_group_143fd90b80df9d13ff73686d264d0ec9
#             );
#
#
#             var marker_3588a1aef5095c7c737e431b5026ff81 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ac001a4bcf312ad2e3368f20a187a79);
#
#
#         var popup_2ec56ae4beb17b839feceb5ec842e45b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe138a7eb1517d7ca2de8a17bfa02f8f = $(`&lt;div id=&quot;html_fe138a7eb1517d7ca2de8a17bfa02f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2ec56ae4beb17b839feceb5ec842e45b.setContent(html_fe138a7eb1517d7ca2de8a17bfa02f8f);
#
#
#
#         marker_3588a1aef5095c7c737e431b5026ff81.bindPopup(popup_2ec56ae4beb17b839feceb5ec842e45b)
#         ;
#
#
#
#
#             var marker_0261957b74cf7ccdcbdcc06c04748233 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ac001a4bcf312ad2e3368f20a187a79);
#
#
#         var popup_907298df8a174dfd2564d28f42229e75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75117dea05407a85f15e8b4b0d71eedf = $(`&lt;div id=&quot;html_75117dea05407a85f15e8b4b0d71eedf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_907298df8a174dfd2564d28f42229e75.setContent(html_75117dea05407a85f15e8b4b0d71eedf);
#
#
#
#         marker_0261957b74cf7ccdcbdcc06c04748233.bindPopup(popup_907298df8a174dfd2564d28f42229e75)
#         ;
#
#
#
#
#             var marker_dd53f13933be7469e8b423d1a1e0b88c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ac001a4bcf312ad2e3368f20a187a79);
#
#
#         var popup_a7c86edc6bebdbcd66e08c5cc148f660 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fa7281afce2001a4c024430b7109d44 = $(`&lt;div id=&quot;html_8fa7281afce2001a4c024430b7109d44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a7c86edc6bebdbcd66e08c5cc148f660.setContent(html_8fa7281afce2001a4c024430b7109d44);
#
#
#
#         marker_dd53f13933be7469e8b423d1a1e0b88c.bindPopup(popup_a7c86edc6bebdbcd66e08c5cc148f660)
#         ;
#
#
#
#
#             var marker_eb920121fc0789b2074caba1a40e9dab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ac001a4bcf312ad2e3368f20a187a79);
#
#
#         var popup_a5891378697d728ce10b11eae6662d3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c57588e9740c9c73cb8ada6eb1b2558 = $(`&lt;div id=&quot;html_1c57588e9740c9c73cb8ada6eb1b2558&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a5891378697d728ce10b11eae6662d3a.setContent(html_1c57588e9740c9c73cb8ada6eb1b2558);
#
#
#
#         marker_eb920121fc0789b2074caba1a40e9dab.bindPopup(popup_a5891378697d728ce10b11eae6662d3a)
#         ;
#
#
#
#
#             var marker_ea37e1936ebb538224d6e3e5531e48cb = L.marker(
#                 [45.0503999
