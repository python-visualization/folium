# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89c50d08a7d61695f75457df1f31e415 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89c50d08a7d61695f75457df1f31e415&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89c50d08a7d61695f75457df1f31e415 = L.map(
#                 &quot;map_89c50d08a7d61695f75457df1f31e415&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6176a3a00c7738a06d650e8a54f222c9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6176a3a00c7738a06d650e8a54f222c9.addTo(map_89c50d08a7d61695f75457df1f31e415);
#
#
#             var marker_be0e12f446baf716484650581e255cb4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_89c50d08a7d61695f75457df1f31e415);
#
#
#         var popup_0c52f9a9088cdd09b05cc856a94fb6ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3c2a437166f3e4798c3badb0d898ea9 = $(`&lt;div id=&quot;html_e3c2a437166f3e4798c3badb0d898ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0c52f9a9088cdd09b05cc856a94fb6ef.setContent(html_e3c2a437166f3e4798c3badb0d898ea9);
#
#
#
#         marker_be0e12f446baf716484650581e255cb4.bindPopup(popup_0c52f9a9088cdd09b05cc856a94fb6ef)
#         ;
#
#
#
#
#             var marker_9ed876579eb6dc1fc1b43ea884b2e3d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_89c50d08a7d61695f75457df1f31e415);
#
#
#         var popup_694ef12c93b9afac02815f79d3f662e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f16b2239d4ff380472c29355227fd4d = $(`&lt;div id=&quot;html_2f16b2239d4ff380472c29355227fd4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_694ef12c93b9afac02815f79d3f662e5.setContent(html_2f16b2239d4ff380472c29355227fd4d);
#
#
#
#         marker_9ed876579eb6dc1fc1b43ea884b2e3d1.bindPopup(popup_694ef12c93b9afac02815f79d3f662e5)
#         ;
#
#
#
#
#             var marker_3befc8c0294f39a00ce89a04ef0fb91b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_89c50d08a7d61695f75457df1f31e415);
#
#
#         var popup_989fbc3b76491475ad9dd6abd461fb15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aab4e5fee77cc47b64cbaeb7a8f53843 = $(`&lt;div id=&quot;html_aab4e5fee77cc47b64cbaeb7a8f53843&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_989fbc3b76491475ad9dd6abd461fb15.setContent(html_aab4e5fee77cc47b64cbaeb7a8f53843);
#
#
#
#         marker_3befc8c0294f39a00ce89a04ef0fb91b.bindPopup(popup_989fbc3b76491475ad9dd6abd461fb15)
#         ;
#
#
#
#
#             var marker_b54a76e40c167694a4c5f41fb1da24d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_89c50d08a7d61695f75457df1f31e415);
#
#
#         var popup_eb2352a74446827152ee9901119df829 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_969d466a0fa51a91e8e42f3d07444ff7 = $(`&lt;div id=&quot;html_969d466a0fa51a91e8e42f3d07444ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eb2352a74446827152ee9901119df829.setContent(html_969d466a0fa51a91e8e42f3d07444ff7);
#
#
#
#         marker_b54a76e40c167694a4c5f41fb1da24d7.bindPopup(popup_eb2352a74446827152ee9901119df829)
#         ;
#
#
#
#
#             var marker_9a187b5e3c6d3d2eabc7fb06c752777e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_89c50d08a7d61695f75457df1f31e415);
#
#
#         var popup_e8be28a15795167a363b2f5f4f2718e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bb40a3f948e0b516324f01e66180c3c = $(`&lt;div id=&quot;html_4bb40a3f948e0b516324f01e66180c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e8be28a15795167a363b2f5f4f2718e5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f732640d1761a49bd1f5f43af1f221c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f732640d1761a49bd1f5f43af1f221c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f732640d1761a49bd1f5f43af1f221c7 = L.map(
#                 &quot;map_f732640d1761a49bd1f5f43af1f221c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1953cc5f87e93ae3adc59d96cdbacf67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1953cc5f87e93ae3adc59d96cdbacf67.addTo(map_f732640d1761a49bd1f5f43af1f221c7);
#
#
#             var feature_group_0f7dd13cfba644851f2c1c3e73ddc433 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a5a73c37f79579d92f2840bc1e7f1cf9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0f7dd13cfba644851f2c1c3e73ddc433);
#
#
#         var popup_670f4edfc94cd797e447d01e6527f5dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcb27ac2eac3399aa4addbd097638810 = $(`&lt;div id=&quot;html_bcb27ac2eac3399aa4addbd097638810&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_670f4edfc94cd797e447d01e6527f5dc.setContent(html_bcb27ac2eac3399aa4addbd097638810);
#
#
#
#         marker_a5a73c37f79579d92f2840bc1e7f1cf9.bindPopup(popup_670f4edfc94cd797e447d01e6527f5dc)
#         ;
#
#
#
#
#             var marker_83cbf4d0b28956148715c21b2132a9f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0f7dd13cfba644851f2c1c3e73ddc433);
#
#
#         var popup_0725df3ad31d4f14b45f20b7e9374911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f4ac430cd9bd8c348ded4d29a5a8964 = $(`&lt;div id=&quot;html_6f4ac430cd9bd8c348ded4d29a5a8964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0725df3ad31d4f14b45f20b7e9374911.setContent(html_6f4ac430cd9bd8c348ded4d29a5a8964);
#
#
#
#         marker_83cbf4d0b28956148715c21b2132a9f1.bindPopup(popup_0725df3ad31d4f14b45f20b7e9374911)
#         ;
#
#
#
#
#             var marker_d6ff4309943fb5d5f592e929bbd1f99e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0f7dd13cfba644851f2c1c3e73ddc433);
#
#
#         var popup_3686936b3ee7bc4143a31849f26f3a70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_835bc645adb16f8442a7e8187343543c = $(`&lt;div id=&quot;html_835bc645adb16f8442a7e8187343543c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3686936b3ee7bc4143a31849f26f3a70.setContent(html_835bc645adb16f8442a7e8187343543c);
#
#
#
#         marker_d6ff4309943fb5d5f592e929bbd1f99e.bindPopup(popup_3686936b3ee7bc4143a31849f26f3a70)
#         ;
#
#
#
#
#             var marker_765895ce04013760641975962b79b8a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0f7dd13cfba644851f2c1c3e73ddc433);
#
#
#         var popup_66091d631805e7b0f53fbdccea110b2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25cf33710e2f53cd72a682a42b83cbd4 = $(`&lt;div id=&quot;html_25cf33710e2f53cd72a682a42b83cbd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_66091d631805e7b0f53fbdccea110b2e.setContent(html_25cf33710e2f53cd72a682a42b83cbd4);
#
#
#
#         marker_765895ce04013760641975962b79b8a5.bindPopup(popup_66091d631805e7b0f53fbdccea110b2e)
#         ;
#
#
#
#
#             var marker_cbb0af11841e15ed6c40f86e5905cf00 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0f7dd13cfba644851f2c1c3e73ddc433);
#
#
#         var popup_a0c0972cb77f07af449073d160644d42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_093efa02091f7b46e05b4e08568a0441 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_093efa02091f7b46e05b4e08568a0441&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_093efa02091f7b46e05b4e08568a0441 = L.map(
#                 &quot;map_093efa02091f7b46e05b4e08568a0441&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6767a05ad4458db4d6c34d5d503e7d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6767a05ad4458db4d6c34d5d503e7d8.addTo(map_093efa02091f7b46e05b4e08568a0441);
#
#
#             var feature_group_cc04c4678dc5becfb174844dd733a553 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cc04c4678dc5becfb174844dd733a553.addTo(map_093efa02091f7b46e05b4e08568a0441);
#
#
#             var feature_group_sub_group_77273bfd0ed3194553ca31431ef31438 = L.featureGroup.subGroup(
#                 feature_group_cc04c4678dc5becfb174844dd733a553
#             );
#
#
#             var marker_a57f9bb1c83f4c92d9bd3939354de38d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_77273bfd0ed3194553ca31431ef31438);
#
#
#         var popup_fddc8eb72ea1682bee8a1e16299a7c52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5882ab3b92baf6af83c05119dcc4f24d = $(`&lt;div id=&quot;html_5882ab3b92baf6af83c05119dcc4f24d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fddc8eb72ea1682bee8a1e16299a7c52.setContent(html_5882ab3b92baf6af83c05119dcc4f24d);
#
#
#
#         marker_a57f9bb1c83f4c92d9bd3939354de38d.bindPopup(popup_fddc8eb72ea1682bee8a1e16299a7c52)
#         ;
#
#
#
#
#             var marker_4722574219d26c0dcf94e7af9e0dcd0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_77273bfd0ed3194553ca31431ef31438);
#
#
#         var popup_3e6460f8808d7a4d0a7959a7e77c1caa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60bb514ae6f4c0331492da2f0cd58ba3 = $(`&lt;div id=&quot;html_60bb514ae6f4c0331492da2f0cd58ba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3e6460f8808d7a4d0a7959a7e77c1caa.setContent(html_60bb514ae6f4c0331492da2f0cd58ba3);
#
#
#
#         marker_4722574219d26c0dcf94e7af9e0dcd0f.bindPopup(popup_3e6460f8808d7a4d0a7959a7e77c1caa)
#         ;
#
#
#
#
#             var marker_a3d31f481a896391594fdd933078e528 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_77273bfd0ed3194553ca31431ef31438);
#
#
#         var popup_9eadf2b7a7521398692889f5f9cfecd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8d10a61049259b4f0cb3da7a4afbb9a = $(`&lt;div id=&quot;html_b8d10a61049259b4f0cb3da7a4afbb9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9eadf2b7a7521398692889f5f9cfecd8.setContent(html_b8d10a61049259b4f0cb3da7a4afbb9a);
#
#
#
#         marker_a3d31f481a896391594fdd933078e528.bindPopup(popup_9eadf2b7a7521398692889f5f9cfecd8)
#         ;
#
#
#
#
#             var marker_8782a83b03ad25e3efc8b351fb87346b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_77273bfd0ed3194553ca31431ef31438);
#
#
#         var popup_50d9684ac3b433c429942d0763758dc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c143193ef515a1c17cec1e9d776f7d6 = $(`&lt;div id=&quot;html_0c143193ef515a1c17cec1e9d776f7d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_50d9684ac3b433c429942d0763758dc0.setContent(html_0c143193ef515a1c17cec1e9d776f7d6);
#
#
#
#         marker_
