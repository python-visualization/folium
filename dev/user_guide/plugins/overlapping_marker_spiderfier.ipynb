# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f82f7661009c4ff1d94e4856fecc323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f82f7661009c4ff1d94e4856fecc323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f82f7661009c4ff1d94e4856fecc323 = L.map(
#                 &quot;map_6f82f7661009c4ff1d94e4856fecc323&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_457fa85d905d36c29b9f383a25ecf313 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_457fa85d905d36c29b9f383a25ecf313.addTo(map_6f82f7661009c4ff1d94e4856fecc323);
#
#
#             var marker_5f637031d8b478e54c61c6620dc5d563 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6f82f7661009c4ff1d94e4856fecc323);
#
#
#         var popup_4f051e4752ff9e195d7253377292f4ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bb19bb45011100ad2b7654e02f91ad6 = $(`&lt;div id=&quot;html_9bb19bb45011100ad2b7654e02f91ad6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4f051e4752ff9e195d7253377292f4ad.setContent(html_9bb19bb45011100ad2b7654e02f91ad6);
#
#
#
#         marker_5f637031d8b478e54c61c6620dc5d563.bindPopup(popup_4f051e4752ff9e195d7253377292f4ad)
#         ;
#
#
#
#
#             var marker_a69b2d457571880cc6f68a45b5a07599 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6f82f7661009c4ff1d94e4856fecc323);
#
#
#         var popup_0ebbc8d567e3d560d88f1ec7369e9e70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_111d2238032c7c4473e5d8b1843c774e = $(`&lt;div id=&quot;html_111d2238032c7c4473e5d8b1843c774e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0ebbc8d567e3d560d88f1ec7369e9e70.setContent(html_111d2238032c7c4473e5d8b1843c774e);
#
#
#
#         marker_a69b2d457571880cc6f68a45b5a07599.bindPopup(popup_0ebbc8d567e3d560d88f1ec7369e9e70)
#         ;
#
#
#
#
#             var marker_da78decf622c020707311d4b26813e05 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6f82f7661009c4ff1d94e4856fecc323);
#
#
#         var popup_47fff4e6d27d5ce8e614804727e1b86e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c02fe1145c8a6b1213a5cccd4bc6101b = $(`&lt;div id=&quot;html_c02fe1145c8a6b1213a5cccd4bc6101b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_47fff4e6d27d5ce8e614804727e1b86e.setContent(html_c02fe1145c8a6b1213a5cccd4bc6101b);
#
#
#
#         marker_da78decf622c020707311d4b26813e05.bindPopup(popup_47fff4e6d27d5ce8e614804727e1b86e)
#         ;
#
#
#
#
#             var marker_28f95ca99ca131dc49cb56e46905160d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6f82f7661009c4ff1d94e4856fecc323);
#
#
#         var popup_0ce5a6299983c6722a3ad8e006cba683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef7fe6aac74ee8960603872722b6555 = $(`&lt;div id=&quot;html_eef7fe6aac74ee8960603872722b6555&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0ce5a6299983c6722a3ad8e006cba683.setContent(html_eef7fe6aac74ee8960603872722b6555);
#
#
#
#         marker_28f95ca99ca131dc49cb56e46905160d.bindPopup(popup_0ce5a6299983c6722a3ad8e006cba683)
#         ;
#
#
#
#
#             var marker_ce3ccf9a96599e16298588afe8078c41 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6f82f7661009c4ff1d94e4856fecc323);
#
#
#         var popup_98a48dfe74fae28d84c11d22a96254a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b3f7ca86e34bc9880a2b5dbe6310908 = $(`&lt;div id=&quot;html_6b3f7ca86e34bc9880a2b5dbe6310908&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_98a48dfe74fae28d84c11d22a96254a8.setContent(html_6b3f7ca86e34bc9880a2b5dbe6310908);
#
#
#
#         marker_ce3ccf9a96599e16298588afe8078c41.bindPopup(popup_98a48dfe74fae28d84c11d22a96254a8)
#         ;
#
#
#
#
#             var marker_6c4870a4b5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_586a444f87542e9f7ad0daa10e2f341c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_586a444f87542e9f7ad0daa10e2f341c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_586a444f87542e9f7ad0daa10e2f341c = L.map(
#                 &quot;map_586a444f87542e9f7ad0daa10e2f341c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebd1b3c964f4165fd0174692f969b6b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebd1b3c964f4165fd0174692f969b6b3.addTo(map_586a444f87542e9f7ad0daa10e2f341c);
#
#
#             var feature_group_7e2eccb4f4d07ecd6d5c8a1e9f2999a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5f8da6b7dd09bf26e93a60f01881988 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7e2eccb4f4d07ecd6d5c8a1e9f2999a8);
#
#
#         var popup_0934e4c1224debcaa09d7f0b6b649573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c337585126450555d89cfc30d1721588 = $(`&lt;div id=&quot;html_c337585126450555d89cfc30d1721588&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0934e4c1224debcaa09d7f0b6b649573.setContent(html_c337585126450555d89cfc30d1721588);
#
#
#
#         marker_d5f8da6b7dd09bf26e93a60f01881988.bindPopup(popup_0934e4c1224debcaa09d7f0b6b649573)
#         ;
#
#
#
#
#             var marker_cb00a37271251a1d7689b9e37cd8ecbe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7e2eccb4f4d07ecd6d5c8a1e9f2999a8);
#
#
#         var popup_b2183e3ef737d60691205d93ded55ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f000a1a59ceda9a0284b06ba9e4d0a6 = $(`&lt;div id=&quot;html_0f000a1a59ceda9a0284b06ba9e4d0a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b2183e3ef737d60691205d93ded55ac1.setContent(html_0f000a1a59ceda9a0284b06ba9e4d0a6);
#
#
#
#         marker_cb00a37271251a1d7689b9e37cd8ecbe.bindPopup(popup_b2183e3ef737d60691205d93ded55ac1)
#         ;
#
#
#
#
#             var marker_57c5a94dc065f5ce41a4ac99882c876e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7e2eccb4f4d07ecd6d5c8a1e9f2999a8);
#
#
#         var popup_682fca1eeb3982c8184b1f7567c844bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2194e3017b3b82694a0fd4d2f3cd4e00 = $(`&lt;div id=&quot;html_2194e3017b3b82694a0fd4d2f3cd4e00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_682fca1eeb3982c8184b1f7567c844bc.setContent(html_2194e3017b3b82694a0fd4d2f3cd4e00);
#
#
#
#         marker_57c5a94dc065f5ce41a4ac99882c876e.bindPopup(popup_682fca1eeb3982c8184b1f7567c844bc)
#         ;
#
#
#
#
#             var marker_a5dc8cdb0c1cd16020aab8727fea03ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7e2eccb4f4d07ecd6d5c8a1e9f2999a8);
#
#
#         var popup_b65d1fd892d19ebfd4991f10eee70f28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813591766cd2a16b85758ee697848619 = $(`&lt;div id=&quot;html_813591766cd2a16b85758ee697848619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b65d1fd892d19ebfd4991f10eee70f28.setContent(html_813591766cd2a16b85758ee697848619);
#
#
#
#         marker_a5dc8cdb0c1cd16020aab8727fea03ab.bindPopup(popup_b65d1fd892d19ebfd4991f10eee70f28)
#         ;
#
#
#
#
#             var marker_def4d32e49f1b255e53a2a5d9db72e45 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7e2eccb4f4d07ecd6d5c8a1e9f2999a8);
#
#
#         var popup_1e292ec1c54666c59640efd3a8082c56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_438f6ad28e4d474f1f6f0513a48db56e = $(`&lt;div id=&quot;html_438f6ad28e4d474f1f6f0513a48db56e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_1e292ec1c54666c596

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f4af9b6c9687b27dcb558eb27409f4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f4af9b6c9687b27dcb558eb27409f4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f4af9b6c9687b27dcb558eb27409f4f = L.map(
#                 &quot;map_1f4af9b6c9687b27dcb558eb27409f4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59c4aea7d3c0a85ace833f0286ccc8fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59c4aea7d3c0a85ace833f0286ccc8fd.addTo(map_1f4af9b6c9687b27dcb558eb27409f4f);
#
#
#             var feature_group_2fa3c44f4671c309c6a1f65971fea8c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2fa3c44f4671c309c6a1f65971fea8c4.addTo(map_1f4af9b6c9687b27dcb558eb27409f4f);
#
#
#             var feature_group_sub_group_1c14bbb1e20179b27b9dfd6436dbebe8 = L.featureGroup.subGroup(
#                 feature_group_2fa3c44f4671c309c6a1f65971fea8c4
#             );
#
#
#             var marker_ca62b8aa9d3e30b9894122a69f015dce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c14bbb1e20179b27b9dfd6436dbebe8);
#
#
#         var popup_a221fd31eec71234c76039166bec99c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6612d0093c35de555393fb8185af88cd = $(`&lt;div id=&quot;html_6612d0093c35de555393fb8185af88cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a221fd31eec71234c76039166bec99c4.setContent(html_6612d0093c35de555393fb8185af88cd);
#
#
#
#         marker_ca62b8aa9d3e30b9894122a69f015dce.bindPopup(popup_a221fd31eec71234c76039166bec99c4)
#         ;
#
#
#
#
#             var marker_75f72c8df324e1e6686399bbdf8d2d0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c14bbb1e20179b27b9dfd6436dbebe8);
#
#
#         var popup_e0181cba8727f6d32015978439ec5277 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c8f982d1dd1f3feff255dd2f43edc3 = $(`&lt;div id=&quot;html_50c8f982d1dd1f3feff255dd2f43edc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0181cba8727f6d32015978439ec5277.setContent(html_50c8f982d1dd1f3feff255dd2f43edc3);
#
#
#
#         marker_75f72c8df324e1e6686399bbdf8d2d0e.bindPopup(popup_e0181cba8727f6d32015978439ec5277)
#         ;
#
#
#
#
#             var marker_d43f27e279c253c4e3bacb0cbbbedf10 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c14bbb1e20179b27b9dfd6436dbebe8);
#
#
#         var popup_84cf5e67c8ee1e9208fd98e0dda9d30c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f2493d7ee4e77005fb3f74ed2f07f40 = $(`&lt;div id=&quot;html_5f2493d7ee4e77005fb3f74ed2f07f40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_84cf5e67c8ee1e9208fd98e0dda9d30c.setContent(html_5f2493d7ee4e77005fb3f74ed2f07f40);
#
#
#
#         marker_d43f27e279c253c4e3bacb0cbbbedf10.bindPopup(popup_84cf5e67c8ee1e9208fd98e0dda9d30c)
#         ;
#
#
#
#
#             var marker_1df88c5d1551d6f3206bf224816c7ca8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1c14bbb1e20179b27b9dfd6436dbebe8);
#
#
#         var popup_722d5696f234b45b3341f9b43c7490b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b64b955fc1010e162c1b0915a9b075d6 = $(`&lt;div id=&quot;html_b64b955fc1010e162c1b0915a9b075d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_722d5696f234b45b3341f9b43c7490b1.setContent(html_b64b955fc1010e162c1b0915a9b075d6);
#
#
#
#         marker_1df88c5d1551d6f3206bf224816c7ca8.bindPopup(popup_722d5696f234b45b3341f9b43c7490b1)
#         ;
#
#
#
#
#             var marker_781c0cc6c279851d781cdd456815a8a0 = L.marker(
#                 [45.050399999999996, 3.0504],
