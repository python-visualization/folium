# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_870a91eafd070c55d79807ddf81bfa30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_870a91eafd070c55d79807ddf81bfa30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_870a91eafd070c55d79807ddf81bfa30 = L.map(
#                 &quot;map_870a91eafd070c55d79807ddf81bfa30&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b20f6ba636e4d363e33b5662b57782a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b20f6ba636e4d363e33b5662b57782a.addTo(map_870a91eafd070c55d79807ddf81bfa30);
#
#
#             var marker_9652f29b886eb865b0c6ec17850cd00b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_870a91eafd070c55d79807ddf81bfa30);
#
#
#         var popup_2a94a7a505d2499e5e8403ca571da7f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dca8178fd6db391535c2dcd98c214a9c = $(`&lt;div id=&quot;html_dca8178fd6db391535c2dcd98c214a9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2a94a7a505d2499e5e8403ca571da7f6.setContent(html_dca8178fd6db391535c2dcd98c214a9c);
#
#
#
#         marker_9652f29b886eb865b0c6ec17850cd00b.bindPopup(popup_2a94a7a505d2499e5e8403ca571da7f6)
#         ;
#
#
#
#
#             var marker_268d706810c603e2fe5df7d18288be05 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_870a91eafd070c55d79807ddf81bfa30);
#
#
#         var popup_92ab8194825ee731c150f010b123a7d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03542a521c2fffbc4ec47bb74600c0bc = $(`&lt;div id=&quot;html_03542a521c2fffbc4ec47bb74600c0bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_92ab8194825ee731c150f010b123a7d9.setContent(html_03542a521c2fffbc4ec47bb74600c0bc);
#
#
#
#         marker_268d706810c603e2fe5df7d18288be05.bindPopup(popup_92ab8194825ee731c150f010b123a7d9)
#         ;
#
#
#
#
#             var marker_56bd12bd576cc20a3ce78e51900bc923 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_870a91eafd070c55d79807ddf81bfa30);
#
#
#         var popup_a7b96af1fdc725bc20558d8a571b05ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87a3c9d4f2e91da7e49a294003c3dd7b = $(`&lt;div id=&quot;html_87a3c9d4f2e91da7e49a294003c3dd7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a7b96af1fdc725bc20558d8a571b05ac.setContent(html_87a3c9d4f2e91da7e49a294003c3dd7b);
#
#
#
#         marker_56bd12bd576cc20a3ce78e51900bc923.bindPopup(popup_a7b96af1fdc725bc20558d8a571b05ac)
#         ;
#
#
#
#
#             var marker_498383c23b9516aabc2c5ea7819902a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_870a91eafd070c55d79807ddf81bfa30);
#
#
#         var popup_c8ba26d9d0c79ae2de70a7fa67f7c5e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e55770f70f139d754bef268ba5b787bd = $(`&lt;div id=&quot;html_e55770f70f139d754bef268ba5b787bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c8ba26d9d0c79ae2de70a7fa67f7c5e0.setContent(html_e55770f70f139d754bef268ba5b787bd);
#
#
#
#         marker_498383c23b9516aabc2c5ea7819902a2.bindPopup(popup_c8ba26d9d0c79ae2de70a7fa67f7c5e0)
#         ;
#
#
#
#
#             var marker_3535361853ad32073fa13e53387adb18 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_870a91eafd070c55d79807ddf81bfa30);
#
#
#         var popup_65b5c42caa21159ccc94c08927b05676 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9ead6792bb483a8008f60177e276cdb = $(`&lt;div id=&quot;html_b9ead6792bb483a8008f60177e276cdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_65b5c42caa21159ccc94c08927b05676.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0002845540b5e877ff0f1c8a31f8c901 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0002845540b5e877ff0f1c8a31f8c901&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0002845540b5e877ff0f1c8a31f8c901 = L.map(
#                 &quot;map_0002845540b5e877ff0f1c8a31f8c901&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ca3e03720d95ef015dc9e027f539c22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ca3e03720d95ef015dc9e027f539c22.addTo(map_0002845540b5e877ff0f1c8a31f8c901);
#
#
#             var feature_group_4a4a27e4958269aa6a7f305943374aed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6bb4bc2d9a0021ffb275e340b51b74a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4a4a27e4958269aa6a7f305943374aed);
#
#
#         var popup_c558bab8d2ff593a311ea9d41fe15f5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fbf57ec097de0275b2f2ebc86296ea2 = $(`&lt;div id=&quot;html_8fbf57ec097de0275b2f2ebc86296ea2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c558bab8d2ff593a311ea9d41fe15f5d.setContent(html_8fbf57ec097de0275b2f2ebc86296ea2);
#
#
#
#         marker_6bb4bc2d9a0021ffb275e340b51b74a2.bindPopup(popup_c558bab8d2ff593a311ea9d41fe15f5d)
#         ;
#
#
#
#
#             var marker_accc6043f178070ac4a681ba559f9ad2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4a4a27e4958269aa6a7f305943374aed);
#
#
#         var popup_212b593b8b99b4b23942391d2d42566f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d2593c9ff90fa25c9375358f5285292 = $(`&lt;div id=&quot;html_4d2593c9ff90fa25c9375358f5285292&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_212b593b8b99b4b23942391d2d42566f.setContent(html_4d2593c9ff90fa25c9375358f5285292);
#
#
#
#         marker_accc6043f178070ac4a681ba559f9ad2.bindPopup(popup_212b593b8b99b4b23942391d2d42566f)
#         ;
#
#
#
#
#             var marker_711d8e6ae31884a117bacf3a8d6076b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4a4a27e4958269aa6a7f305943374aed);
#
#
#         var popup_aa53a0ff5679e40272fa55462cf20979 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_917be7790003df762753623d83ee6cc9 = $(`&lt;div id=&quot;html_917be7790003df762753623d83ee6cc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aa53a0ff5679e40272fa55462cf20979.setContent(html_917be7790003df762753623d83ee6cc9);
#
#
#
#         marker_711d8e6ae31884a117bacf3a8d6076b6.bindPopup(popup_aa53a0ff5679e40272fa55462cf20979)
#         ;
#
#
#
#
#             var marker_a20dfc15cbd35c4a234bb655dbff88c3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4a4a27e4958269aa6a7f305943374aed);
#
#
#         var popup_1f61f1afc055e0c2004e46a70bc1e06a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0627553986f1a33cfa876a8f34f106c = $(`&lt;div id=&quot;html_e0627553986f1a33cfa876a8f34f106c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1f61f1afc055e0c2004e46a70bc1e06a.setContent(html_e0627553986f1a33cfa876a8f34f106c);
#
#
#
#         marker_a20dfc15cbd35c4a234bb655dbff88c3.bindPopup(popup_1f61f1afc055e0c2004e46a70bc1e06a)
#         ;
#
#
#
#
#             var marker_cd1ba6e59c7e30d3f2ebf2d3bb78bc0a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4a4a27e4958269aa6a7f305943374aed);
#
#
#         var popup_70e38092c8dd3cb55f76e3dd09cb5ddb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b3df2bbd8576ab352af91679aadeaeb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b3df2bbd8576ab352af91679aadeaeb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b3df2bbd8576ab352af91679aadeaeb = L.map(
#                 &quot;map_2b3df2bbd8576ab352af91679aadeaeb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cdf117a821563f3249da563df530399 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0cdf117a821563f3249da563df530399.addTo(map_2b3df2bbd8576ab352af91679aadeaeb);
#
#
#             var feature_group_f337af4b8a58040f0881a570ab8f1753 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f337af4b8a58040f0881a570ab8f1753.addTo(map_2b3df2bbd8576ab352af91679aadeaeb);
#
#
#             var feature_group_sub_group_7d0de9223c66328f76ac30b5fc43de59 = L.featureGroup.subGroup(
#                 feature_group_f337af4b8a58040f0881a570ab8f1753
#             );
#
#
#             var marker_796c53099089fb030b2978e727a7f4f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d0de9223c66328f76ac30b5fc43de59);
#
#
#         var popup_c478f2abdcad363f486d49023b7b80af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db41b08eeff1b1db2e9a494ccf637c91 = $(`&lt;div id=&quot;html_db41b08eeff1b1db2e9a494ccf637c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c478f2abdcad363f486d49023b7b80af.setContent(html_db41b08eeff1b1db2e9a494ccf637c91);
#
#
#
#         marker_796c53099089fb030b2978e727a7f4f4.bindPopup(popup_c478f2abdcad363f486d49023b7b80af)
#         ;
#
#
#
#
#             var marker_76f55c944f0a8c600173162e6ef8f569 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d0de9223c66328f76ac30b5fc43de59);
#
#
#         var popup_bcf8384d2621bf27485616adedd84996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_062a9a18345a518c1562d942af2c069d = $(`&lt;div id=&quot;html_062a9a18345a518c1562d942af2c069d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bcf8384d2621bf27485616adedd84996.setContent(html_062a9a18345a518c1562d942af2c069d);
#
#
#
#         marker_76f55c944f0a8c600173162e6ef8f569.bindPopup(popup_bcf8384d2621bf27485616adedd84996)
#         ;
#
#
#
#
#             var marker_8c687a14eb55474c999f699fc2167644 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d0de9223c66328f76ac30b5fc43de59);
#
#
#         var popup_336ff90ca397ebec030ab3170255230a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c29d0ae044ee58341476b65c78ab05c = $(`&lt;div id=&quot;html_7c29d0ae044ee58341476b65c78ab05c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_336ff90ca397ebec030ab3170255230a.setContent(html_7c29d0ae044ee58341476b65c78ab05c);
#
#
#
#         marker_8c687a14eb55474c999f699fc2167644.bindPopup(popup_336ff90ca397ebec030ab3170255230a)
#         ;
#
#
#
#
#             var marker_b27ac1820428d6c278f0c454c428b381 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d0de9223c66328f76ac30b5fc43de59);
#
#
#         var popup_f3dac89aa88797dd060f6d33d84d95d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3736bb66d715828350d3d6e2a3dbaef2 = $(`&lt;div id=&quot;html_3736bb66d715828350d3d6e2a3dbaef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f3dac89aa88797dd060f6d33d84d95d3.setContent(html_3736bb66d715828350d3d6e2a3dbaef2);
#
#
#
#         marker_
