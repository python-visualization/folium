# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fcee9514cf8a8a16d784b427e8185a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fcee9514cf8a8a16d784b427e8185a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fcee9514cf8a8a16d784b427e8185a7 = L.map(
#                 &quot;map_7fcee9514cf8a8a16d784b427e8185a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2a8257003641f91531f88cdee042c50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2a8257003641f91531f88cdee042c50.addTo(map_7fcee9514cf8a8a16d784b427e8185a7);
#
#
#             var marker_edeca9e12b9d9cb021b35be2a806d53f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7fcee9514cf8a8a16d784b427e8185a7);
#
#
#         var popup_5337d2d123eb37f918f60ee77a948601 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d546bdb936115c1276a785964d6b1fb = $(`&lt;div id=&quot;html_8d546bdb936115c1276a785964d6b1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5337d2d123eb37f918f60ee77a948601.setContent(html_8d546bdb936115c1276a785964d6b1fb);
#
#
#
#         marker_edeca9e12b9d9cb021b35be2a806d53f.bindPopup(popup_5337d2d123eb37f918f60ee77a948601)
#         ;
#
#
#
#
#             var marker_688c69e6b512ea13e98fe9bf41361bb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7fcee9514cf8a8a16d784b427e8185a7);
#
#
#         var popup_90325dee35e469e9a98b36f593aed9c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea9a9dac58e9c6ea7d6cbba32ecc527e = $(`&lt;div id=&quot;html_ea9a9dac58e9c6ea7d6cbba32ecc527e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_90325dee35e469e9a98b36f593aed9c0.setContent(html_ea9a9dac58e9c6ea7d6cbba32ecc527e);
#
#
#
#         marker_688c69e6b512ea13e98fe9bf41361bb9.bindPopup(popup_90325dee35e469e9a98b36f593aed9c0)
#         ;
#
#
#
#
#             var marker_9686dc28fb7d63c92610cf071dce4d81 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7fcee9514cf8a8a16d784b427e8185a7);
#
#
#         var popup_1889f519845e2ce4bc4acf80b867e6d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_596721e5f1cfc3dcb71b79bf94a6c1a9 = $(`&lt;div id=&quot;html_596721e5f1cfc3dcb71b79bf94a6c1a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1889f519845e2ce4bc4acf80b867e6d0.setContent(html_596721e5f1cfc3dcb71b79bf94a6c1a9);
#
#
#
#         marker_9686dc28fb7d63c92610cf071dce4d81.bindPopup(popup_1889f519845e2ce4bc4acf80b867e6d0)
#         ;
#
#
#
#
#             var marker_6d692349d92e65f1b525a5e08b497e0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7fcee9514cf8a8a16d784b427e8185a7);
#
#
#         var popup_ea8af948a80f0fda25274c976ee2e69d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1c9d4937032ae677e7594f7a39bddb8 = $(`&lt;div id=&quot;html_d1c9d4937032ae677e7594f7a39bddb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ea8af948a80f0fda25274c976ee2e69d.setContent(html_d1c9d4937032ae677e7594f7a39bddb8);
#
#
#
#         marker_6d692349d92e65f1b525a5e08b497e0d.bindPopup(popup_ea8af948a80f0fda25274c976ee2e69d)
#         ;
#
#
#
#
#             var marker_cc82cf49f66f988c158fdb5e0564aa8e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7fcee9514cf8a8a16d784b427e8185a7);
#
#
#         var popup_0ec8578cf6e65bcd80898b2bfff2199e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b658bd46e71925581cb7611573b24b2 = $(`&lt;div id=&quot;html_5b658bd46e71925581cb7611573b24b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0ec8578cf6e65bcd80898b2bfff2199e.setContent(html_5b658bd46e71925581cb7611573b24b2);
#
#
#
#         marker_cc82cf49f66f988c158fdb5e0564aa8e.bindPopup(popup_0ec8578cf6e65bcd80898b2bfff2199e)
#         ;
#
#
#
#
#             var marker_9b2e4260c6

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3ed98f53ab767fe704223044050300e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3ed98f53ab767fe704223044050300e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3ed98f53ab767fe704223044050300e = L.map(
#                 &quot;map_a3ed98f53ab767fe704223044050300e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9e64c3b89e837f8612863f94cf07a57 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9e64c3b89e837f8612863f94cf07a57.addTo(map_a3ed98f53ab767fe704223044050300e);
#
#
#             var feature_group_7c57e3092a1d9fb93a8dc42800e0e5ec = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f312daffd7c4b587ffe6e6fd605d7bce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7c57e3092a1d9fb93a8dc42800e0e5ec);
#
#
#         var popup_05dd7ce9d30e7828af549bea60d8b65c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea849fb8d466aaa767e497667bd9d415 = $(`&lt;div id=&quot;html_ea849fb8d466aaa767e497667bd9d415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_05dd7ce9d30e7828af549bea60d8b65c.setContent(html_ea849fb8d466aaa767e497667bd9d415);
#
#
#
#         marker_f312daffd7c4b587ffe6e6fd605d7bce.bindPopup(popup_05dd7ce9d30e7828af549bea60d8b65c)
#         ;
#
#
#
#
#             var marker_ab4f7aae3b90311e239b500833bc8322 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7c57e3092a1d9fb93a8dc42800e0e5ec);
#
#
#         var popup_073c9c7a2078355d4645e1c6874ef28d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_108fd47192ee04d3a544558ef9fa797e = $(`&lt;div id=&quot;html_108fd47192ee04d3a544558ef9fa797e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_073c9c7a2078355d4645e1c6874ef28d.setContent(html_108fd47192ee04d3a544558ef9fa797e);
#
#
#
#         marker_ab4f7aae3b90311e239b500833bc8322.bindPopup(popup_073c9c7a2078355d4645e1c6874ef28d)
#         ;
#
#
#
#
#             var marker_feb9e08545f14169a9c6e0ec5f6fdc09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7c57e3092a1d9fb93a8dc42800e0e5ec);
#
#
#         var popup_a77b3a009b9daff0d069223f67c61cd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bdac0ad1b797be4c5688dbddda3802e = $(`&lt;div id=&quot;html_9bdac0ad1b797be4c5688dbddda3802e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a77b3a009b9daff0d069223f67c61cd4.setContent(html_9bdac0ad1b797be4c5688dbddda3802e);
#
#
#
#         marker_feb9e08545f14169a9c6e0ec5f6fdc09.bindPopup(popup_a77b3a009b9daff0d069223f67c61cd4)
#         ;
#
#
#
#
#             var marker_f0347dd6996b7523860625ed93a4cdc9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7c57e3092a1d9fb93a8dc42800e0e5ec);
#
#
#         var popup_68819f6188cff975140b58bb53242151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7afdaa4cc53a27722d0937440a6748af = $(`&lt;div id=&quot;html_7afdaa4cc53a27722d0937440a6748af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_68819f6188cff975140b58bb53242151.setContent(html_7afdaa4cc53a27722d0937440a6748af);
#
#
#
#         marker_f0347dd6996b7523860625ed93a4cdc9.bindPopup(popup_68819f6188cff975140b58bb53242151)
#         ;
#
#
#
#
#             var marker_ad8a2640d4e70c8ad101d644a415d975 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7c57e3092a1d9fb93a8dc42800e0e5ec);
#
#
#         var popup_460831be2e021d0c9b7cae54f17dd9f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_513c9ed0a0ae9744d2d311e09c916daa = $(`&lt;div id=&quot;html_513c9ed0a0ae9744d2d311e09c916daa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_460831be2e021d0c9b

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dd9217b3c43a78a06a5a7ce5c900a78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dd9217b3c43a78a06a5a7ce5c900a78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dd9217b3c43a78a06a5a7ce5c900a78 = L.map(
#                 &quot;map_5dd9217b3c43a78a06a5a7ce5c900a78&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54d9b5deb89fb7b9f739836fb711e281 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54d9b5deb89fb7b9f739836fb711e281.addTo(map_5dd9217b3c43a78a06a5a7ce5c900a78);
#
#
#             var feature_group_35265ffdb0600210828f9f8397c7082a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_35265ffdb0600210828f9f8397c7082a.addTo(map_5dd9217b3c43a78a06a5a7ce5c900a78);
#
#
#             var feature_group_sub_group_25d3ba4a711738a71bacaa2f681bb215 = L.featureGroup.subGroup(
#                 feature_group_35265ffdb0600210828f9f8397c7082a
#             );
#
#
#             var marker_63e59624fc4a5da5c1a6fc5cc48e6eb3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_25d3ba4a711738a71bacaa2f681bb215);
#
#
#         var popup_214e4818ae0534b6d8f8c6a5724efc40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87c805d5503ca9a971cef0b3d5933321 = $(`&lt;div id=&quot;html_87c805d5503ca9a971cef0b3d5933321&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_214e4818ae0534b6d8f8c6a5724efc40.setContent(html_87c805d5503ca9a971cef0b3d5933321);
#
#
#
#         marker_63e59624fc4a5da5c1a6fc5cc48e6eb3.bindPopup(popup_214e4818ae0534b6d8f8c6a5724efc40)
#         ;
#
#
#
#
#             var marker_ab9cd872b478a184c218b8177188c65f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_25d3ba4a711738a71bacaa2f681bb215);
#
#
#         var popup_cf275b86b2652f24024d85bd346fcee3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34cd8921eeb9fdd8a3208595737d03a9 = $(`&lt;div id=&quot;html_34cd8921eeb9fdd8a3208595737d03a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cf275b86b2652f24024d85bd346fcee3.setContent(html_34cd8921eeb9fdd8a3208595737d03a9);
#
#
#
#         marker_ab9cd872b478a184c218b8177188c65f.bindPopup(popup_cf275b86b2652f24024d85bd346fcee3)
#         ;
#
#
#
#
#             var marker_32eb29fa6ac6eb52271c6cfb76e39a26 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_25d3ba4a711738a71bacaa2f681bb215);
#
#
#         var popup_f29b9c0471324f53c79d010d6ff6d9ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e60d8ee5c7ee0427f4b3e2d41ea27e2 = $(`&lt;div id=&quot;html_3e60d8ee5c7ee0427f4b3e2d41ea27e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f29b9c0471324f53c79d010d6ff6d9ee.setContent(html_3e60d8ee5c7ee0427f4b3e2d41ea27e2);
#
#
#
#         marker_32eb29fa6ac6eb52271c6cfb76e39a26.bindPopup(popup_f29b9c0471324f53c79d010d6ff6d9ee)
#         ;
#
#
#
#
#             var marker_b40c4af7523d3c1281b3ed3e5a455e33 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_25d3ba4a711738a71bacaa2f681bb215);
#
#
#         var popup_7f5eda13e5bad6495166a75dacee9c99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c90b9c49dafb67abe064db6298a86a3 = $(`&lt;div id=&quot;html_7c90b9c49dafb67abe064db6298a86a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7f5eda13e5bad6495166a75dacee9c99.setContent(html_7c90b9c49dafb67abe064db6298a86a3);
#
#
#
#         marker_b40c4af7523d3c1281b3ed3e5a455e33.bindPopup(popup_7f5eda13e5bad6495166a75dacee9c99)
#         ;
#
#
#
#
#             var marker_ad2910cb3f5ae8ce9fbd0c0f48c3607d = L.marker(
#                 [45.050399999999996, 3.0504],
