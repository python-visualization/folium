# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f80ddfd47353f360576d611eee70dbbf {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f80ddfd47353f360576d611eee70dbbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f80ddfd47353f360576d611eee70dbbf = L.map(
#                 &quot;map_f80ddfd47353f360576d611eee70dbbf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_115af79cc29df71cb55a10c12f90b502 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_115af79cc29df71cb55a10c12f90b502.addTo(map_f80ddfd47353f360576d611eee70dbbf);
#
#
#             var marker_9a02f63cc3e6179b3a1f9b6f315a8b4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f80ddfd47353f360576d611eee70dbbf);
#
#
#         var popup_ed7450c2e6a8de0de1153d16fd4b68e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ffe8cd034fd94eca7879060a31bfbc6 = $(`&lt;div id=&quot;html_7ffe8cd034fd94eca7879060a31bfbc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ed7450c2e6a8de0de1153d16fd4b68e8.setContent(html_7ffe8cd034fd94eca7879060a31bfbc6);
#
#
#
#         marker_9a02f63cc3e6179b3a1f9b6f315a8b4d.bindPopup(popup_ed7450c2e6a8de0de1153d16fd4b68e8)
#         ;
#
#
#
#
#             var marker_3b4d926644a3ea17521cffb57a17c824 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f80ddfd47353f360576d611eee70dbbf);
#
#
#         var popup_6104773f4ca22e718fefbee33d7c1bec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4b9247bdc01c93d9ff5f1b0474458d1 = $(`&lt;div id=&quot;html_c4b9247bdc01c93d9ff5f1b0474458d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6104773f4ca22e718fefbee33d7c1bec.setContent(html_c4b9247bdc01c93d9ff5f1b0474458d1);
#
#
#
#         marker_3b4d926644a3ea17521cffb57a17c824.bindPopup(popup_6104773f4ca22e718fefbee33d7c1bec)
#         ;
#
#
#
#
#             var marker_aabc8bca2b334ce3a560fd099dab4e63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f80ddfd47353f360576d611eee70dbbf);
#
#
#         var popup_307f74f97963f5991cd8b8005706f08c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_096910bbd669bfb36bf2aad6761f982f = $(`&lt;div id=&quot;html_096910bbd669bfb36bf2aad6761f982f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_307f74f97963f5991cd8b8005706f08c.setContent(html_096910bbd669bfb36bf2aad6761f982f);
#
#
#
#         marker_aabc8bca2b334ce3a560fd099dab4e63.bindPopup(popup_307f74f97963f5991cd8b8005706f08c)
#         ;
#
#
#
#
#             var marker_472969008e405742fd831c4a72581fc5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f80ddfd47353f360576d611eee70dbbf);
#
#
#         var popup_85372e95a121da13d7633e5e38a6b6ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77c574283b92e786fc432e20bff96b43 = $(`&lt;div id=&quot;html_77c574283b92e786fc432e20bff96b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_85372e95a121da13d7633e5e38a6b6ad.setContent(html_77c574283b92e786fc432e20bff96b43);
#
#
#
#         marker_472969008e405742fd831c4a72581fc5.bindPopup(popup_85372e95a121da13d7633e5e38a6b6ad)
#         ;
#
#
#
#
#             var marker_e36fe0baa3dfe626565bd963be89ca1e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f80ddfd47353f360576d611eee70dbbf);
#
#
#         var popup_b96585ce5da8f5ca779bc29d3869b99f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5622a55247a9eb971e808aa087b5c37 = $(`&lt;div id=&quot;html_b5622a55247a9eb971e808aa087b5c37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b96585ce5da8f5ca779bc29d3869b9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1af39247a779dc12ca7082b1e1d1e2ce {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1af39247a779dc12ca7082b1e1d1e2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1af39247a779dc12ca7082b1e1d1e2ce = L.map(
#                 &quot;map_1af39247a779dc12ca7082b1e1d1e2ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a69c4890c7d31c89b6a34194ccd59699 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a69c4890c7d31c89b6a34194ccd59699.addTo(map_1af39247a779dc12ca7082b1e1d1e2ce);
#
#
#             var feature_group_ff4b62bf9075018a864c73f4121fcb43 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c8726871b07effbaab62078b9ffe371a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ff4b62bf9075018a864c73f4121fcb43);
#
#
#         var popup_13ec4d24634643f5710c38082ae1c8b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93854953f8d49ab8e8a4a5e05db0ca85 = $(`&lt;div id=&quot;html_93854953f8d49ab8e8a4a5e05db0ca85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_13ec4d24634643f5710c38082ae1c8b6.setContent(html_93854953f8d49ab8e8a4a5e05db0ca85);
#
#
#
#         marker_c8726871b07effbaab62078b9ffe371a.bindPopup(popup_13ec4d24634643f5710c38082ae1c8b6)
#         ;
#
#
#
#
#             var marker_d8e096778810c726dc5bebee88d4edc5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ff4b62bf9075018a864c73f4121fcb43);
#
#
#         var popup_c988ecdcdf9ef787e19554576970a385 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40f4863ba8dddb68f6eb0889756a9778 = $(`&lt;div id=&quot;html_40f4863ba8dddb68f6eb0889756a9778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c988ecdcdf9ef787e19554576970a385.setContent(html_40f4863ba8dddb68f6eb0889756a9778);
#
#
#
#         marker_d8e096778810c726dc5bebee88d4edc5.bindPopup(popup_c988ecdcdf9ef787e19554576970a385)
#         ;
#
#
#
#
#             var marker_aa09a983d20cfc2847dc1d722122eae0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ff4b62bf9075018a864c73f4121fcb43);
#
#
#         var popup_ba45a248caaba59432e3e2ba6b998f35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23e520b6d2a197402b02ec197eeac427 = $(`&lt;div id=&quot;html_23e520b6d2a197402b02ec197eeac427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ba45a248caaba59432e3e2ba6b998f35.setContent(html_23e520b6d2a197402b02ec197eeac427);
#
#
#
#         marker_aa09a983d20cfc2847dc1d722122eae0.bindPopup(popup_ba45a248caaba59432e3e2ba6b998f35)
#         ;
#
#
#
#
#             var marker_3692c001c1d3e947b53650e2c4b5cd66 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ff4b62bf9075018a864c73f4121fcb43);
#
#
#         var popup_9df32885012322a7c1ff937658c70b43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16eca6d99faa9f25631fe1e7359e460b = $(`&lt;div id=&quot;html_16eca6d99faa9f25631fe1e7359e460b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9df32885012322a7c1ff937658c70b43.setContent(html_16eca6d99faa9f25631fe1e7359e460b);
#
#
#
#         marker_3692c001c1d3e947b53650e2c4b5cd66.bindPopup(popup_9df32885012322a7c1ff937658c70b43)
#         ;
#
#
#
#
#             var marker_c244d40d5167f891aab6ce03262eccc0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ff4b62bf9075018a864c73f4121fcb43);
#
#
#         var popup_ba7ce67206574a27f6d5962aa5cf3126 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9de7910c2a7044c1a7a77012e772c031 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9de7910c2a7044c1a7a77012e772c031&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9de7910c2a7044c1a7a77012e772c031 = L.map(
#                 &quot;map_9de7910c2a7044c1a7a77012e772c031&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ed80b2a08a5688b99946eb4f1c1e251 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ed80b2a08a5688b99946eb4f1c1e251.addTo(map_9de7910c2a7044c1a7a77012e772c031);
#
#
#             var feature_group_c09faff8df81e5eb4d0c1af526c56819 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c09faff8df81e5eb4d0c1af526c56819.addTo(map_9de7910c2a7044c1a7a77012e772c031);
#
#
#             var feature_group_sub_group_d71d70e49cc5aef481108f5313ea6174 = L.featureGroup.subGroup(
#                 feature_group_c09faff8df81e5eb4d0c1af526c56819
#             );
#
#
#             var marker_838c64a9f926d8ed95d86d08b9d62ed3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d71d70e49cc5aef481108f5313ea6174);
#
#
#         var popup_63b92c7ac8080c0001d563c667da87e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b23dd54a7cae4e6ef80d6a60a25207b = $(`&lt;div id=&quot;html_8b23dd54a7cae4e6ef80d6a60a25207b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_63b92c7ac8080c0001d563c667da87e7.setContent(html_8b23dd54a7cae4e6ef80d6a60a25207b);
#
#
#
#         marker_838c64a9f926d8ed95d86d08b9d62ed3.bindPopup(popup_63b92c7ac8080c0001d563c667da87e7)
#         ;
#
#
#
#
#             var marker_21d3b150548c2c7defda0909d6bb2fb8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d71d70e49cc5aef481108f5313ea6174);
#
#
#         var popup_7a238bc631d7094d57b18dcd079d4c91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_418eeec236d388743d687366dfe9364a = $(`&lt;div id=&quot;html_418eeec236d388743d687366dfe9364a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7a238bc631d7094d57b18dcd079d4c91.setContent(html_418eeec236d388743d687366dfe9364a);
#
#
#
#         marker_21d3b150548c2c7defda0909d6bb2fb8.bindPopup(popup_7a238bc631d7094d57b18dcd079d4c91)
#         ;
#
#
#
#
#             var marker_9428f81e412f9238ce694580e5aab947 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d71d70e49cc5aef481108f5313ea6174);
#
#
#         var popup_905c11c9bb4ee1cf1dee574b184e9f3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc1cc85384d7b5a31a8760debc49674 = $(`&lt;div id=&quot;html_ddc1cc85384d7b5a31a8760debc49674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_905c11c9bb4ee1cf1dee574b184e9f3f.setContent(html_ddc1cc85384d7b5a31a8760debc49674);
#
#
#
#         marker_9428f81e412f9238ce694580e5aab947.bindPopup(popup_905c11c9bb4ee1cf1dee574b184e9f3f)
#         ;
#
#
#
#
#             var marker_0e984942cbfa19d63abef90551a56569 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d71d70e49cc5aef481108f5313ea6174);
#
#
#         var popup_d1198d33b6985731fb67e0a3da47d7ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ad231dbc747e855a58a31b51174da46 = $(`&lt;div id=&quot;html_3ad231dbc747e855a58a31b51174da46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d1198d33b6985731fb67e0a3da47d7ac.setContent(html_3ad231dbc747e855a58a31b51174da46);
#
#
#
#         mark
