# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d090b56cfe93c231cccc9ea0441adb5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d090b56cfe93c231cccc9ea0441adb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d090b56cfe93c231cccc9ea0441adb5 = L.map(
#                 &quot;map_1d090b56cfe93c231cccc9ea0441adb5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f7089a119a2248b71627cccc02d97c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f7089a119a2248b71627cccc02d97c8.addTo(map_1d090b56cfe93c231cccc9ea0441adb5);
#
#
#             var marker_859bb77dc1cd7e21dcfcc06856c29c6e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1d090b56cfe93c231cccc9ea0441adb5);
#
#
#         var popup_4b09f55830f1cf2d582fbf5d43f994ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee91574928892e7a3e86beac208a4298 = $(`&lt;div id=&quot;html_ee91574928892e7a3e86beac208a4298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4b09f55830f1cf2d582fbf5d43f994ac.setContent(html_ee91574928892e7a3e86beac208a4298);
#
#
#
#         marker_859bb77dc1cd7e21dcfcc06856c29c6e.bindPopup(popup_4b09f55830f1cf2d582fbf5d43f994ac)
#         ;
#
#
#
#
#             var marker_bab8de33637e92b951841d0328335ef5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1d090b56cfe93c231cccc9ea0441adb5);
#
#
#         var popup_3850eecbe1e74b3391efcd2e2ea716ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bb2d36a9ff70a991840f967cc3e141f = $(`&lt;div id=&quot;html_2bb2d36a9ff70a991840f967cc3e141f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3850eecbe1e74b3391efcd2e2ea716ce.setContent(html_2bb2d36a9ff70a991840f967cc3e141f);
#
#
#
#         marker_bab8de33637e92b951841d0328335ef5.bindPopup(popup_3850eecbe1e74b3391efcd2e2ea716ce)
#         ;
#
#
#
#
#             var marker_b8a08a14db5e7a601154cee64e96febf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1d090b56cfe93c231cccc9ea0441adb5);
#
#
#         var popup_997626e8143ef4ddd0256d226704e0a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a391293073565650189b6aa2756d58 = $(`&lt;div id=&quot;html_f9a391293073565650189b6aa2756d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_997626e8143ef4ddd0256d226704e0a2.setContent(html_f9a391293073565650189b6aa2756d58);
#
#
#
#         marker_b8a08a14db5e7a601154cee64e96febf.bindPopup(popup_997626e8143ef4ddd0256d226704e0a2)
#         ;
#
#
#
#
#             var marker_a0b2215145b93669b4dafbb5c593a093 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1d090b56cfe93c231cccc9ea0441adb5);
#
#
#         var popup_ff52949475c3cb86a7f2d035ccb336af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3d92e1019ac5683933721d7c53c76a5 = $(`&lt;div id=&quot;html_c3d92e1019ac5683933721d7c53c76a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ff52949475c3cb86a7f2d035ccb336af.setContent(html_c3d92e1019ac5683933721d7c53c76a5);
#
#
#
#         marker_a0b2215145b93669b4dafbb5c593a093.bindPopup(popup_ff52949475c3cb86a7f2d035ccb336af)
#         ;
#
#
#
#
#             var marker_252875491c4f1ab9f3f8484e4872c5b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1d090b56cfe93c231cccc9ea0441adb5);
#
#
#         var popup_c488df47e16a0a13ae855223638314f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56b725fe594af4718aa376c9244826db = $(`&lt;div id=&quot;html_56b725fe594af4718aa376c9244826db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c488df47e16a0a13ae855223638314f7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b556f83eae91d2cf3dd14f8b3d444017 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b556f83eae91d2cf3dd14f8b3d444017&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b556f83eae91d2cf3dd14f8b3d444017 = L.map(
#                 &quot;map_b556f83eae91d2cf3dd14f8b3d444017&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cc147ec53d4634cc3db15de0d12b741 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cc147ec53d4634cc3db15de0d12b741.addTo(map_b556f83eae91d2cf3dd14f8b3d444017);
#
#
#             var feature_group_5656613974754bfad5fa420ff51a508f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_abab7647af6377ee11189b7480459e97 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5656613974754bfad5fa420ff51a508f);
#
#
#         var popup_149975b975472f62cb77b10711b3a7f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66515c924b76feef3f53f0e51c3a27e2 = $(`&lt;div id=&quot;html_66515c924b76feef3f53f0e51c3a27e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_149975b975472f62cb77b10711b3a7f3.setContent(html_66515c924b76feef3f53f0e51c3a27e2);
#
#
#
#         marker_abab7647af6377ee11189b7480459e97.bindPopup(popup_149975b975472f62cb77b10711b3a7f3)
#         ;
#
#
#
#
#             var marker_510c1b82ccfb9b1edd958a25f82724f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5656613974754bfad5fa420ff51a508f);
#
#
#         var popup_bf3f6b32457bf8417b7132c001dd07d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b184f35a03bd5cd64f2f5f81ee8885d1 = $(`&lt;div id=&quot;html_b184f35a03bd5cd64f2f5f81ee8885d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bf3f6b32457bf8417b7132c001dd07d3.setContent(html_b184f35a03bd5cd64f2f5f81ee8885d1);
#
#
#
#         marker_510c1b82ccfb9b1edd958a25f82724f9.bindPopup(popup_bf3f6b32457bf8417b7132c001dd07d3)
#         ;
#
#
#
#
#             var marker_0d7aa095282ca0f0a38fd8d49f686b34 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5656613974754bfad5fa420ff51a508f);
#
#
#         var popup_09e7ca05370cdcf3c33d444cc8c63ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1b8097612841ad426288a69c33f26d0 = $(`&lt;div id=&quot;html_b1b8097612841ad426288a69c33f26d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_09e7ca05370cdcf3c33d444cc8c63ddf.setContent(html_b1b8097612841ad426288a69c33f26d0);
#
#
#
#         marker_0d7aa095282ca0f0a38fd8d49f686b34.bindPopup(popup_09e7ca05370cdcf3c33d444cc8c63ddf)
#         ;
#
#
#
#
#             var marker_ddd8df10a28679816290e1169b76eb98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5656613974754bfad5fa420ff51a508f);
#
#
#         var popup_7f0c9ff0f8d07001bc89f83ebf784e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6983c21d752d89574d40b9f94f0c6e5d = $(`&lt;div id=&quot;html_6983c21d752d89574d40b9f94f0c6e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7f0c9ff0f8d07001bc89f83ebf784e0f.setContent(html_6983c21d752d89574d40b9f94f0c6e5d);
#
#
#
#         marker_ddd8df10a28679816290e1169b76eb98.bindPopup(popup_7f0c9ff0f8d07001bc89f83ebf784e0f)
#         ;
#
#
#
#
#             var marker_9873cfef9424a4eaed112cc03125dabd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5656613974754bfad5fa420ff51a508f);
#
#
#         var popup_bd19dfdedf958932f37bc08dc76d62b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7eb72884745530e26fc1ecdb5919782a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7eb72884745530e26fc1ecdb5919782a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7eb72884745530e26fc1ecdb5919782a = L.map(
#                 &quot;map_7eb72884745530e26fc1ecdb5919782a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9aa81b6d00c0116012b9d594b181a763 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9aa81b6d00c0116012b9d594b181a763.addTo(map_7eb72884745530e26fc1ecdb5919782a);
#
#
#             var feature_group_c1ea79f946ec23afdcc338094d5a2da0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c1ea79f946ec23afdcc338094d5a2da0.addTo(map_7eb72884745530e26fc1ecdb5919782a);
#
#
#             var feature_group_sub_group_5cefdb76fa6d1285b2fe83138fd3d576 = L.featureGroup.subGroup(
#                 feature_group_c1ea79f946ec23afdcc338094d5a2da0
#             );
#
#
#             var marker_271004fbfde1d908a01d7e0ac7fa6b21 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5cefdb76fa6d1285b2fe83138fd3d576);
#
#
#         var popup_02d29642011d241764592ccb69a85548 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0c376a6bc4b83c6777eb302d08d58c3 = $(`&lt;div id=&quot;html_c0c376a6bc4b83c6777eb302d08d58c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_02d29642011d241764592ccb69a85548.setContent(html_c0c376a6bc4b83c6777eb302d08d58c3);
#
#
#
#         marker_271004fbfde1d908a01d7e0ac7fa6b21.bindPopup(popup_02d29642011d241764592ccb69a85548)
#         ;
#
#
#
#
#             var marker_d55236ffc93f8e5869e1252152af1880 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5cefdb76fa6d1285b2fe83138fd3d576);
#
#
#         var popup_0cf43e6285ee101d39d046853b89da2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8a30ec01ea31dfe7420ce2ce0fe1173 = $(`&lt;div id=&quot;html_b8a30ec01ea31dfe7420ce2ce0fe1173&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0cf43e6285ee101d39d046853b89da2e.setContent(html_b8a30ec01ea31dfe7420ce2ce0fe1173);
#
#
#
#         marker_d55236ffc93f8e5869e1252152af1880.bindPopup(popup_0cf43e6285ee101d39d046853b89da2e)
#         ;
#
#
#
#
#             var marker_f2ffb43cf6af6a699afabb2a8ae1a6f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5cefdb76fa6d1285b2fe83138fd3d576);
#
#
#         var popup_a940d3391dbd4e9f1e5ba4f8bd762f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76b51732f761b41dec0e1775cc94ebb7 = $(`&lt;div id=&quot;html_76b51732f761b41dec0e1775cc94ebb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a940d3391dbd4e9f1e5ba4f8bd762f1b.setContent(html_76b51732f761b41dec0e1775cc94ebb7);
#
#
#
#         marker_f2ffb43cf6af6a699afabb2a8ae1a6f6.bindPopup(popup_a940d3391dbd4e9f1e5ba4f8bd762f1b)
#         ;
#
#
#
#
#             var marker_e119226a638097889cd1e78bf1b4cf91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5cefdb76fa6d1285b2fe83138fd3d576);
#
#
#         var popup_820fa10b8fc946eefaed1455d36d31a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77bf90c7a399a79ca9600c3ce4d13a5f = $(`&lt;div id=&quot;html_77bf90c7a399a79ca9600c3ce4d13a5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_820fa10b8fc946eefaed1455d36d31a9.setContent(html_77bf90c7a399a79ca9600c3ce4d13a5f);
#
#
#
#         marker_
