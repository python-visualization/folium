# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_deb8207c398b324c3c123f65ac342fe9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_deb8207c398b324c3c123f65ac342fe9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_deb8207c398b324c3c123f65ac342fe9 = L.map(
#                 &quot;map_deb8207c398b324c3c123f65ac342fe9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6823cf84c9fbbe82e6ca6d847a4f409 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b6823cf84c9fbbe82e6ca6d847a4f409.addTo(map_deb8207c398b324c3c123f65ac342fe9);
#
#
#             var marker_ec03e0c31eee9e4402b3861031dd5cf7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_deb8207c398b324c3c123f65ac342fe9);
#
#
#         var popup_12418ef1d47faeb8a8fb06a626f12729 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92912cfb1c13b70bd215b05b7841a4ab = $(`&lt;div id=&quot;html_92912cfb1c13b70bd215b05b7841a4ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_12418ef1d47faeb8a8fb06a626f12729.setContent(html_92912cfb1c13b70bd215b05b7841a4ab);
#
#
#
#         marker_ec03e0c31eee9e4402b3861031dd5cf7.bindPopup(popup_12418ef1d47faeb8a8fb06a626f12729)
#         ;
#
#
#
#
#             var marker_50aa7c6971a513ce86cc36cb4e4dca95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_deb8207c398b324c3c123f65ac342fe9);
#
#
#         var popup_e6e347d5517d29e014105177571428dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a22a365a9b4a6811bc8d6e4648550c02 = $(`&lt;div id=&quot;html_a22a365a9b4a6811bc8d6e4648550c02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e6e347d5517d29e014105177571428dc.setContent(html_a22a365a9b4a6811bc8d6e4648550c02);
#
#
#
#         marker_50aa7c6971a513ce86cc36cb4e4dca95.bindPopup(popup_e6e347d5517d29e014105177571428dc)
#         ;
#
#
#
#
#             var marker_d09f7ff42d3beddaeb662b4a9656efe0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_deb8207c398b324c3c123f65ac342fe9);
#
#
#         var popup_0287c8414efc218a52ba5ebafd606232 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcadb03063c38514c1d3006bb3978d38 = $(`&lt;div id=&quot;html_dcadb03063c38514c1d3006bb3978d38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0287c8414efc218a52ba5ebafd606232.setContent(html_dcadb03063c38514c1d3006bb3978d38);
#
#
#
#         marker_d09f7ff42d3beddaeb662b4a9656efe0.bindPopup(popup_0287c8414efc218a52ba5ebafd606232)
#         ;
#
#
#
#
#             var marker_8ed8f00f15063fac4199bc3c674784ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_deb8207c398b324c3c123f65ac342fe9);
#
#
#         var popup_aeeb98326ee44e71d1b758bf9ce313ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adab371842891d641c13ad363cb82c0d = $(`&lt;div id=&quot;html_adab371842891d641c13ad363cb82c0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aeeb98326ee44e71d1b758bf9ce313ec.setContent(html_adab371842891d641c13ad363cb82c0d);
#
#
#
#         marker_8ed8f00f15063fac4199bc3c674784ca.bindPopup(popup_aeeb98326ee44e71d1b758bf9ce313ec)
#         ;
#
#
#
#
#             var marker_f6340a84142c1377eee3dfb1d9a44968 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_deb8207c398b324c3c123f65ac342fe9);
#
#
#         var popup_188e9f49c928fbb0d2d722d492784513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_362b0a1398d805cf6fdaebdd6856ccd2 = $(`&lt;div id=&quot;html_362b0a1398d805cf6fdaebdd6856ccd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_188e9f49c928fbb0d2d722d492784513.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92cf0056f6696cc7e10965afa312e557 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92cf0056f6696cc7e10965afa312e557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92cf0056f6696cc7e10965afa312e557 = L.map(
#                 &quot;map_92cf0056f6696cc7e10965afa312e557&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad9c5fac08fb85413bcb600b1ef4cf1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad9c5fac08fb85413bcb600b1ef4cf1d.addTo(map_92cf0056f6696cc7e10965afa312e557);
#
#
#             var feature_group_c031997fa73f32a39b7daf4d164ea6cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8fbf98c6b8c825ba996d04c32d99cedf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c031997fa73f32a39b7daf4d164ea6cf);
#
#
#         var popup_e84215c9a8885f7acb9c2b1086fdbe67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b008b94b818091eebeb3a630c7fdf74 = $(`&lt;div id=&quot;html_3b008b94b818091eebeb3a630c7fdf74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e84215c9a8885f7acb9c2b1086fdbe67.setContent(html_3b008b94b818091eebeb3a630c7fdf74);
#
#
#
#         marker_8fbf98c6b8c825ba996d04c32d99cedf.bindPopup(popup_e84215c9a8885f7acb9c2b1086fdbe67)
#         ;
#
#
#
#
#             var marker_0ec2af47aebfe52d4312a2d6e89c7543 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c031997fa73f32a39b7daf4d164ea6cf);
#
#
#         var popup_31000b74842734aab1c3b25ff21c69f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79bc6a43eaef8358dab15590fd3ba24e = $(`&lt;div id=&quot;html_79bc6a43eaef8358dab15590fd3ba24e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_31000b74842734aab1c3b25ff21c69f9.setContent(html_79bc6a43eaef8358dab15590fd3ba24e);
#
#
#
#         marker_0ec2af47aebfe52d4312a2d6e89c7543.bindPopup(popup_31000b74842734aab1c3b25ff21c69f9)
#         ;
#
#
#
#
#             var marker_644ff393c25e5034dbd8c7b9542852df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c031997fa73f32a39b7daf4d164ea6cf);
#
#
#         var popup_c7c42322c4ee0ad039b251b6c02b7ca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64ef643fe513df9ab134bdc8ca9d0e4d = $(`&lt;div id=&quot;html_64ef643fe513df9ab134bdc8ca9d0e4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c7c42322c4ee0ad039b251b6c02b7ca9.setContent(html_64ef643fe513df9ab134bdc8ca9d0e4d);
#
#
#
#         marker_644ff393c25e5034dbd8c7b9542852df.bindPopup(popup_c7c42322c4ee0ad039b251b6c02b7ca9)
#         ;
#
#
#
#
#             var marker_85736f03ef4c47e6f66edd385050e7a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c031997fa73f32a39b7daf4d164ea6cf);
#
#
#         var popup_da7b8dc3481ceed405d6c25a26384198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68fc82334f26d7e3d52260f87307c0b1 = $(`&lt;div id=&quot;html_68fc82334f26d7e3d52260f87307c0b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_da7b8dc3481ceed405d6c25a26384198.setContent(html_68fc82334f26d7e3d52260f87307c0b1);
#
#
#
#         marker_85736f03ef4c47e6f66edd385050e7a9.bindPopup(popup_da7b8dc3481ceed405d6c25a26384198)
#         ;
#
#
#
#
#             var marker_64c44d0642c943d1b65b0d62a7f5e21b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c031997fa73f32a39b7daf4d164ea6cf);
#
#
#         var popup_8827f2abe443366fd0d9598029ebcbbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc4ec42aac28bfdd832c02f0bad47c97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc4ec42aac28bfdd832c02f0bad47c97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc4ec42aac28bfdd832c02f0bad47c97 = L.map(
#                 &quot;map_cc4ec42aac28bfdd832c02f0bad47c97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3dccfcbc79d00a28d560b1e44322e44e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3dccfcbc79d00a28d560b1e44322e44e.addTo(map_cc4ec42aac28bfdd832c02f0bad47c97);
#
#
#             var feature_group_fa3d62affd379d5cac6c0d063d736086 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fa3d62affd379d5cac6c0d063d736086.addTo(map_cc4ec42aac28bfdd832c02f0bad47c97);
#
#
#             var feature_group_sub_group_d6591505e9014b059a69777d4009495d = L.featureGroup.subGroup(
#                 feature_group_fa3d62affd379d5cac6c0d063d736086
#             );
#
#
#             var marker_3238c04a744be2e673b81d733a0ce316 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6591505e9014b059a69777d4009495d);
#
#
#         var popup_a8f1f30e5504a38c5ba5827a7efe003c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53f9787ae52fcfc4064cea049de5c433 = $(`&lt;div id=&quot;html_53f9787ae52fcfc4064cea049de5c433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a8f1f30e5504a38c5ba5827a7efe003c.setContent(html_53f9787ae52fcfc4064cea049de5c433);
#
#
#
#         marker_3238c04a744be2e673b81d733a0ce316.bindPopup(popup_a8f1f30e5504a38c5ba5827a7efe003c)
#         ;
#
#
#
#
#             var marker_7f1d3afd132f3fb67e4d89afc0b15ad1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6591505e9014b059a69777d4009495d);
#
#
#         var popup_974b8d68b11f07f04c19b9727c5e05bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_132832fa5c4eda8ed24247f3accf28ad = $(`&lt;div id=&quot;html_132832fa5c4eda8ed24247f3accf28ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_974b8d68b11f07f04c19b9727c5e05bd.setContent(html_132832fa5c4eda8ed24247f3accf28ad);
#
#
#
#         marker_7f1d3afd132f3fb67e4d89afc0b15ad1.bindPopup(popup_974b8d68b11f07f04c19b9727c5e05bd)
#         ;
#
#
#
#
#             var marker_1897d2822065820d533ad2658d8bc3ba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6591505e9014b059a69777d4009495d);
#
#
#         var popup_c43aca175a8f69a41dc2634ad57d0f4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b37da3971b5ec533659f5c73defb1e0f = $(`&lt;div id=&quot;html_b37da3971b5ec533659f5c73defb1e0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c43aca175a8f69a41dc2634ad57d0f4c.setContent(html_b37da3971b5ec533659f5c73defb1e0f);
#
#
#
#         marker_1897d2822065820d533ad2658d8bc3ba.bindPopup(popup_c43aca175a8f69a41dc2634ad57d0f4c)
#         ;
#
#
#
#
#             var marker_c64c037b1221fb70398d67cab6e7e651 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d6591505e9014b059a69777d4009495d);
#
#
#         var popup_5a23320a95a1ae9d3e7c4c0e42efe01b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f0c52207ed975b25fc88c22e180cc07 = $(`&lt;div id=&quot;html_1f0c52207ed975b25fc88c22e180cc07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5a23320a95a1ae9d3e7c4c0e42efe01b.setContent(html_1f0c52207ed975b25fc88c22e180cc07);
#
#
#
#         marker_
