# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c4badca9eaf4997b366f0c5a518fdad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c4badca9eaf4997b366f0c5a518fdad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c4badca9eaf4997b366f0c5a518fdad = L.map(
#                 &quot;map_9c4badca9eaf4997b366f0c5a518fdad&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6544cce2cfd7cdd762f1871d49ab87b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6544cce2cfd7cdd762f1871d49ab87b6.addTo(map_9c4badca9eaf4997b366f0c5a518fdad);
#
#
#             var marker_78cec8951cff32046ef835ed04bf11ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9c4badca9eaf4997b366f0c5a518fdad);
#
#
#         var popup_3c8193ad218242440156d4e48913922c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b34b3c2e17e48d8a4a9f31ef02592bdd = $(`&lt;div id=&quot;html_b34b3c2e17e48d8a4a9f31ef02592bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c8193ad218242440156d4e48913922c.setContent(html_b34b3c2e17e48d8a4a9f31ef02592bdd);
#
#
#
#         marker_78cec8951cff32046ef835ed04bf11ea.bindPopup(popup_3c8193ad218242440156d4e48913922c)
#         ;
#
#
#
#
#             var marker_cf721fa723711fe23199e770a6ee2b1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9c4badca9eaf4997b366f0c5a518fdad);
#
#
#         var popup_8f1bf45f0465bc2756d27f94d2a674be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_857ac3dfa7d2e3bdd74dd0fa7ffa9683 = $(`&lt;div id=&quot;html_857ac3dfa7d2e3bdd74dd0fa7ffa9683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8f1bf45f0465bc2756d27f94d2a674be.setContent(html_857ac3dfa7d2e3bdd74dd0fa7ffa9683);
#
#
#
#         marker_cf721fa723711fe23199e770a6ee2b1f.bindPopup(popup_8f1bf45f0465bc2756d27f94d2a674be)
#         ;
#
#
#
#
#             var marker_7e859fe5223f92f08fc38e537def87e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9c4badca9eaf4997b366f0c5a518fdad);
#
#
#         var popup_6db13b331e94e686a4862fa7786f6bc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b8771d5c6dbecc36a90ce88155eb0c9 = $(`&lt;div id=&quot;html_1b8771d5c6dbecc36a90ce88155eb0c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6db13b331e94e686a4862fa7786f6bc8.setContent(html_1b8771d5c6dbecc36a90ce88155eb0c9);
#
#
#
#         marker_7e859fe5223f92f08fc38e537def87e5.bindPopup(popup_6db13b331e94e686a4862fa7786f6bc8)
#         ;
#
#
#
#
#             var marker_e40317e87764503f26b1884f3fd94a91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9c4badca9eaf4997b366f0c5a518fdad);
#
#
#         var popup_f47a6b506c1cb2628585f413ec06b1f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_223b26619e35f8098f976ddce9f29c08 = $(`&lt;div id=&quot;html_223b26619e35f8098f976ddce9f29c08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f47a6b506c1cb2628585f413ec06b1f0.setContent(html_223b26619e35f8098f976ddce9f29c08);
#
#
#
#         marker_e40317e87764503f26b1884f3fd94a91.bindPopup(popup_f47a6b506c1cb2628585f413ec06b1f0)
#         ;
#
#
#
#
#             var marker_ba5c7b6c1a5278859f62288c2cff81a8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9c4badca9eaf4997b366f0c5a518fdad);
#
#
#         var popup_8ecb77e78df1ddad91efbf11696c7284 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aafef1d82a3e7306c57b68311dff9f80 = $(`&lt;div id=&quot;html_aafef1d82a3e7306c57b68311dff9f80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8ecb77e78df1ddad91efbf11696c7284.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58722aca8816749d8d624317f4e51717 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58722aca8816749d8d624317f4e51717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58722aca8816749d8d624317f4e51717 = L.map(
#                 &quot;map_58722aca8816749d8d624317f4e51717&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_122c30cb39947b635380452559b37b36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_122c30cb39947b635380452559b37b36.addTo(map_58722aca8816749d8d624317f4e51717);
#
#
#             var feature_group_0e30097b43f2d9eebd576784470dd69e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c644e79401d8bf1c8d8f495eb508136 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0e30097b43f2d9eebd576784470dd69e);
#
#
#         var popup_59666d282c8e1c2d6ebb44a87d4cbf06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e77bac74494b041168b87133fa414aba = $(`&lt;div id=&quot;html_e77bac74494b041168b87133fa414aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_59666d282c8e1c2d6ebb44a87d4cbf06.setContent(html_e77bac74494b041168b87133fa414aba);
#
#
#
#         marker_2c644e79401d8bf1c8d8f495eb508136.bindPopup(popup_59666d282c8e1c2d6ebb44a87d4cbf06)
#         ;
#
#
#
#
#             var marker_ba26256bd63861be1cdf6307dab23c63 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0e30097b43f2d9eebd576784470dd69e);
#
#
#         var popup_0b056e3374817a38fa00adb1244be79f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11b76ac63a3239385d505a514804aec7 = $(`&lt;div id=&quot;html_11b76ac63a3239385d505a514804aec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0b056e3374817a38fa00adb1244be79f.setContent(html_11b76ac63a3239385d505a514804aec7);
#
#
#
#         marker_ba26256bd63861be1cdf6307dab23c63.bindPopup(popup_0b056e3374817a38fa00adb1244be79f)
#         ;
#
#
#
#
#             var marker_68baa16e65d58f5e1bf4c4d411fffa63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0e30097b43f2d9eebd576784470dd69e);
#
#
#         var popup_d8016b7156bf4a3a14bc874a29deac86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9879325b71e98bf538ac05813c52e083 = $(`&lt;div id=&quot;html_9879325b71e98bf538ac05813c52e083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d8016b7156bf4a3a14bc874a29deac86.setContent(html_9879325b71e98bf538ac05813c52e083);
#
#
#
#         marker_68baa16e65d58f5e1bf4c4d411fffa63.bindPopup(popup_d8016b7156bf4a3a14bc874a29deac86)
#         ;
#
#
#
#
#             var marker_b2d7a7f32c9d506649142a03a3028099 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0e30097b43f2d9eebd576784470dd69e);
#
#
#         var popup_3ed8c7fcf0ad7b0ca15c2d9f03dacd2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d64c8bd9c3f9f0785658a9d9e5570fe = $(`&lt;div id=&quot;html_4d64c8bd9c3f9f0785658a9d9e5570fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3ed8c7fcf0ad7b0ca15c2d9f03dacd2e.setContent(html_4d64c8bd9c3f9f0785658a9d9e5570fe);
#
#
#
#         marker_b2d7a7f32c9d506649142a03a3028099.bindPopup(popup_3ed8c7fcf0ad7b0ca15c2d9f03dacd2e)
#         ;
#
#
#
#
#             var marker_8fd1e7d977207871a8ddcd729f6201d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0e30097b43f2d9eebd576784470dd69e);
#
#
#         var popup_3f910ab89cad38fae0f54306d6ce9f69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d716b5bbc036c5cdb55da245057fab16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d716b5bbc036c5cdb55da245057fab16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d716b5bbc036c5cdb55da245057fab16 = L.map(
#                 &quot;map_d716b5bbc036c5cdb55da245057fab16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e6ab8a0ed67bbb46b1870997304cb7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e6ab8a0ed67bbb46b1870997304cb7b.addTo(map_d716b5bbc036c5cdb55da245057fab16);
#
#
#             var feature_group_f3971f1fe224f5e941671c185188b8e9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f3971f1fe224f5e941671c185188b8e9.addTo(map_d716b5bbc036c5cdb55da245057fab16);
#
#
#             var feature_group_sub_group_a665d79dc607f25c1b7ba718c0b4f673 = L.featureGroup.subGroup(
#                 feature_group_f3971f1fe224f5e941671c185188b8e9
#             );
#
#
#             var marker_051dbfb32ffe74e0fbb13c81077676d5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a665d79dc607f25c1b7ba718c0b4f673);
#
#
#         var popup_43c74405b34533d7330216a94e6dc04d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_168847ea092ff37d35a88b9b29b61706 = $(`&lt;div id=&quot;html_168847ea092ff37d35a88b9b29b61706&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_43c74405b34533d7330216a94e6dc04d.setContent(html_168847ea092ff37d35a88b9b29b61706);
#
#
#
#         marker_051dbfb32ffe74e0fbb13c81077676d5.bindPopup(popup_43c74405b34533d7330216a94e6dc04d)
#         ;
#
#
#
#
#             var marker_2347726410b87c37c09608723d8d3a1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a665d79dc607f25c1b7ba718c0b4f673);
#
#
#         var popup_df0fff05d3fda50bbf71adc9d7f7e090 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_117c325dbd9827935a692ea54b11a9d7 = $(`&lt;div id=&quot;html_117c325dbd9827935a692ea54b11a9d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_df0fff05d3fda50bbf71adc9d7f7e090.setContent(html_117c325dbd9827935a692ea54b11a9d7);
#
#
#
#         marker_2347726410b87c37c09608723d8d3a1d.bindPopup(popup_df0fff05d3fda50bbf71adc9d7f7e090)
#         ;
#
#
#
#
#             var marker_1be62bdc923382461df7cdb8058c1382 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a665d79dc607f25c1b7ba718c0b4f673);
#
#
#         var popup_45692dfa2798cb77631e1627fa37357e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b9a1564d4a083c774540cc80e66e3a2 = $(`&lt;div id=&quot;html_0b9a1564d4a083c774540cc80e66e3a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_45692dfa2798cb77631e1627fa37357e.setContent(html_0b9a1564d4a083c774540cc80e66e3a2);
#
#
#
#         marker_1be62bdc923382461df7cdb8058c1382.bindPopup(popup_45692dfa2798cb77631e1627fa37357e)
#         ;
#
#
#
#
#             var marker_8f2fd22a478b25402b19823a89c6e820 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a665d79dc607f25c1b7ba718c0b4f673);
#
#
#         var popup_9aea732a5ecb423e8968661a66672776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d96a5def36cdcf44fd20142c1fabb1ac = $(`&lt;div id=&quot;html_d96a5def36cdcf44fd20142c1fabb1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9aea732a5ecb423e8968661a66672776.setContent(html_d96a5def36cdcf44fd20142c1fabb1ac);
#
#
#
#         marker_
