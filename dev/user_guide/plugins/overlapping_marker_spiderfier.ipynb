# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55f68bfc0ad5ae5f7d62e4dcb0be5789 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55f68bfc0ad5ae5f7d62e4dcb0be5789&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55f68bfc0ad5ae5f7d62e4dcb0be5789 = L.map(
#                 &quot;map_55f68bfc0ad5ae5f7d62e4dcb0be5789&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1662ce418929baed6a54093ecbbd1b58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1662ce418929baed6a54093ecbbd1b58.addTo(map_55f68bfc0ad5ae5f7d62e4dcb0be5789);
#
#
#             var marker_e8bb42b2ad78a722bcfc460c89b50b16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_55f68bfc0ad5ae5f7d62e4dcb0be5789);
#
#
#         var popup_69c89809298b0b942135f6e93f18e73d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17fef4779f71f3a4e584648159c7a945 = $(`&lt;div id=&quot;html_17fef4779f71f3a4e584648159c7a945&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_69c89809298b0b942135f6e93f18e73d.setContent(html_17fef4779f71f3a4e584648159c7a945);
#
#
#
#         marker_e8bb42b2ad78a722bcfc460c89b50b16.bindPopup(popup_69c89809298b0b942135f6e93f18e73d)
#         ;
#
#
#
#
#             var marker_e2ca9618245a84c5e96fe2bc4fbb4330 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_55f68bfc0ad5ae5f7d62e4dcb0be5789);
#
#
#         var popup_dc7c3c77c967b9e7abfb607efc5ed3e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef9b23bc1d9ad0bb33f76df0147bb2ae = $(`&lt;div id=&quot;html_ef9b23bc1d9ad0bb33f76df0147bb2ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dc7c3c77c967b9e7abfb607efc5ed3e7.setContent(html_ef9b23bc1d9ad0bb33f76df0147bb2ae);
#
#
#
#         marker_e2ca9618245a84c5e96fe2bc4fbb4330.bindPopup(popup_dc7c3c77c967b9e7abfb607efc5ed3e7)
#         ;
#
#
#
#
#             var marker_a1eaff7f323433a08446f9ae1ad630d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_55f68bfc0ad5ae5f7d62e4dcb0be5789);
#
#
#         var popup_158ed4219b4685c325e0ea557ee5373e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b995bcae1fc9f11e694663155b33d094 = $(`&lt;div id=&quot;html_b995bcae1fc9f11e694663155b33d094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_158ed4219b4685c325e0ea557ee5373e.setContent(html_b995bcae1fc9f11e694663155b33d094);
#
#
#
#         marker_a1eaff7f323433a08446f9ae1ad630d7.bindPopup(popup_158ed4219b4685c325e0ea557ee5373e)
#         ;
#
#
#
#
#             var marker_f691eac365f4da055690b158863a97ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_55f68bfc0ad5ae5f7d62e4dcb0be5789);
#
#
#         var popup_ffcd794bc34a64487f3779af7fa1e2b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1479c7217f3e2cb484c383e260e89cea = $(`&lt;div id=&quot;html_1479c7217f3e2cb484c383e260e89cea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ffcd794bc34a64487f3779af7fa1e2b8.setContent(html_1479c7217f3e2cb484c383e260e89cea);
#
#
#
#         marker_f691eac365f4da055690b158863a97ce.bindPopup(popup_ffcd794bc34a64487f3779af7fa1e2b8)
#         ;
#
#
#
#
#             var marker_bc3592ca5c33eed36af41ef0a0afbfa4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_55f68bfc0ad5ae5f7d62e4dcb0be5789);
#
#
#         var popup_178ce4eb617df275b9feed2583707e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2ee2128e64c5e59de84100a248f5bf6 = $(`&lt;div id=&quot;html_a2ee2128e64c5e59de84100a248f5bf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_178ce4eb617df275b9feed2583707e6f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6c2d744793e6787fab30acd18b28a1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6c2d744793e6787fab30acd18b28a1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6c2d744793e6787fab30acd18b28a1e = L.map(
#                 &quot;map_d6c2d744793e6787fab30acd18b28a1e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e72d77df14badd6c3d23a60195523cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e72d77df14badd6c3d23a60195523cb.addTo(map_d6c2d744793e6787fab30acd18b28a1e);
#
#
#             var feature_group_ded213ec4a7a6f78ee4504af4f9dd9ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_01c46c031331148db826b03121b86bf6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ded213ec4a7a6f78ee4504af4f9dd9ed);
#
#
#         var popup_6e1ade7539b6f9e49b2748a15454da87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32a16373ce8020abfeaf36d104f629b = $(`&lt;div id=&quot;html_a32a16373ce8020abfeaf36d104f629b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6e1ade7539b6f9e49b2748a15454da87.setContent(html_a32a16373ce8020abfeaf36d104f629b);
#
#
#
#         marker_01c46c031331148db826b03121b86bf6.bindPopup(popup_6e1ade7539b6f9e49b2748a15454da87)
#         ;
#
#
#
#
#             var marker_220bb9cf9db4bb06935b7ba46c7b8922 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ded213ec4a7a6f78ee4504af4f9dd9ed);
#
#
#         var popup_08e351a25e2d704288b00d0968125b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc509d3bb13903e20673ad2536e97f47 = $(`&lt;div id=&quot;html_bc509d3bb13903e20673ad2536e97f47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_08e351a25e2d704288b00d0968125b4b.setContent(html_bc509d3bb13903e20673ad2536e97f47);
#
#
#
#         marker_220bb9cf9db4bb06935b7ba46c7b8922.bindPopup(popup_08e351a25e2d704288b00d0968125b4b)
#         ;
#
#
#
#
#             var marker_9085e102a8b3f90c34616caf0846010f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ded213ec4a7a6f78ee4504af4f9dd9ed);
#
#
#         var popup_031370c1ce064446ee2cf70d7483d080 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce05af82183967a8838b772b2b489b40 = $(`&lt;div id=&quot;html_ce05af82183967a8838b772b2b489b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_031370c1ce064446ee2cf70d7483d080.setContent(html_ce05af82183967a8838b772b2b489b40);
#
#
#
#         marker_9085e102a8b3f90c34616caf0846010f.bindPopup(popup_031370c1ce064446ee2cf70d7483d080)
#         ;
#
#
#
#
#             var marker_b6b1a87295973388c8e92b4ac47e22ef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ded213ec4a7a6f78ee4504af4f9dd9ed);
#
#
#         var popup_249cae3884cf5a149a59c5627b5d692d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d31308af7f5f95f78c539b56c38ac00 = $(`&lt;div id=&quot;html_5d31308af7f5f95f78c539b56c38ac00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_249cae3884cf5a149a59c5627b5d692d.setContent(html_5d31308af7f5f95f78c539b56c38ac00);
#
#
#
#         marker_b6b1a87295973388c8e92b4ac47e22ef.bindPopup(popup_249cae3884cf5a149a59c5627b5d692d)
#         ;
#
#
#
#
#             var marker_5a7152609a64d66906be4a3a80b42f47 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ded213ec4a7a6f78ee4504af4f9dd9ed);
#
#
#         var popup_7239592d8bd09c1c0c4507cc9af05fb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abf871cb109f5f66f1cbdebfccb9834b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abf871cb109f5f66f1cbdebfccb9834b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abf871cb109f5f66f1cbdebfccb9834b = L.map(
#                 &quot;map_abf871cb109f5f66f1cbdebfccb9834b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05b69ece1612966107481275d29be349 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05b69ece1612966107481275d29be349.addTo(map_abf871cb109f5f66f1cbdebfccb9834b);
#
#
#             var feature_group_8076957756a0404982be607ddd721950 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8076957756a0404982be607ddd721950.addTo(map_abf871cb109f5f66f1cbdebfccb9834b);
#
#
#             var feature_group_sub_group_2111605591b7bc44d6ec5dfc16c87ba1 = L.featureGroup.subGroup(
#                 feature_group_8076957756a0404982be607ddd721950
#             );
#
#
#             var marker_cebce9960b718a3ac0358f0354675441 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2111605591b7bc44d6ec5dfc16c87ba1);
#
#
#         var popup_e51431eae6d1daf6a7f99a7a8cc576dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df3434e573c5bd470eb80ae47b6f0b98 = $(`&lt;div id=&quot;html_df3434e573c5bd470eb80ae47b6f0b98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e51431eae6d1daf6a7f99a7a8cc576dc.setContent(html_df3434e573c5bd470eb80ae47b6f0b98);
#
#
#
#         marker_cebce9960b718a3ac0358f0354675441.bindPopup(popup_e51431eae6d1daf6a7f99a7a8cc576dc)
#         ;
#
#
#
#
#             var marker_ad3d7eb5b6c9c9d5e7ab96329c6f1896 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2111605591b7bc44d6ec5dfc16c87ba1);
#
#
#         var popup_6418f48106e9e1e4750ec2f051e352eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faa46eb871733b69c2f4913c9bc5d7d3 = $(`&lt;div id=&quot;html_faa46eb871733b69c2f4913c9bc5d7d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6418f48106e9e1e4750ec2f051e352eb.setContent(html_faa46eb871733b69c2f4913c9bc5d7d3);
#
#
#
#         marker_ad3d7eb5b6c9c9d5e7ab96329c6f1896.bindPopup(popup_6418f48106e9e1e4750ec2f051e352eb)
#         ;
#
#
#
#
#             var marker_ee1262afb0077d812db6063fd5b5425a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2111605591b7bc44d6ec5dfc16c87ba1);
#
#
#         var popup_bef805534ba326ac92530fd67984debc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e769509cd3a29aaf4b4257bf73fe7dd3 = $(`&lt;div id=&quot;html_e769509cd3a29aaf4b4257bf73fe7dd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bef805534ba326ac92530fd67984debc.setContent(html_e769509cd3a29aaf4b4257bf73fe7dd3);
#
#
#
#         marker_ee1262afb0077d812db6063fd5b5425a.bindPopup(popup_bef805534ba326ac92530fd67984debc)
#         ;
#
#
#
#
#             var marker_7d6c402c88a91f099ec8f10ff9b87c0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2111605591b7bc44d6ec5dfc16c87ba1);
#
#
#         var popup_1d39c7a09c275cbd44059fd53b937b07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bc1aa3e32e4e902bd03e521c2c5bd1e = $(`&lt;div id=&quot;html_1bc1aa3e32e4e902bd03e521c2c5bd1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1d39c7a09c275cbd44059fd53b937b07.setContent(html_1bc1aa3e32e4e902bd03e521c2c5bd1e);
#
#
#
#         marker_
