# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1478b4094ccc87ea1a695060d3808a39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1478b4094ccc87ea1a695060d3808a39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1478b4094ccc87ea1a695060d3808a39 = L.map(
#                 &quot;map_1478b4094ccc87ea1a695060d3808a39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e61eb1274c34f24e571ac28f9ab95f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e61eb1274c34f24e571ac28f9ab95f3.addTo(map_1478b4094ccc87ea1a695060d3808a39);
#
#
#             var marker_075f34c1385368a96ad1bb1baaedbd5e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1478b4094ccc87ea1a695060d3808a39);
#
#
#         var popup_e1954d07b7f06dd4a25eaf2911b664d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77cd999d28e1a68901c114f43a58f59a = $(`&lt;div id=&quot;html_77cd999d28e1a68901c114f43a58f59a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e1954d07b7f06dd4a25eaf2911b664d5.setContent(html_77cd999d28e1a68901c114f43a58f59a);
#
#
#
#         marker_075f34c1385368a96ad1bb1baaedbd5e.bindPopup(popup_e1954d07b7f06dd4a25eaf2911b664d5)
#         ;
#
#
#
#
#             var marker_6b4f3de483d80dab2e6d168e94b1c6f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1478b4094ccc87ea1a695060d3808a39);
#
#
#         var popup_63ca0efd3680210a6a3d77a7f508119a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b266c1eb6237a048ce9993fe01222ac6 = $(`&lt;div id=&quot;html_b266c1eb6237a048ce9993fe01222ac6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_63ca0efd3680210a6a3d77a7f508119a.setContent(html_b266c1eb6237a048ce9993fe01222ac6);
#
#
#
#         marker_6b4f3de483d80dab2e6d168e94b1c6f7.bindPopup(popup_63ca0efd3680210a6a3d77a7f508119a)
#         ;
#
#
#
#
#             var marker_f3f0d9cb41734cab42b0322f2fe73c93 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1478b4094ccc87ea1a695060d3808a39);
#
#
#         var popup_810558cead0301f77eb53f30f9df3abe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_743c087d0b3826ca3da9bb7b3fdad81f = $(`&lt;div id=&quot;html_743c087d0b3826ca3da9bb7b3fdad81f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_810558cead0301f77eb53f30f9df3abe.setContent(html_743c087d0b3826ca3da9bb7b3fdad81f);
#
#
#
#         marker_f3f0d9cb41734cab42b0322f2fe73c93.bindPopup(popup_810558cead0301f77eb53f30f9df3abe)
#         ;
#
#
#
#
#             var marker_91a52c5d5952223d50594075c6f48983 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1478b4094ccc87ea1a695060d3808a39);
#
#
#         var popup_54e850abb2d827b2f35bd3e560519719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_776d7db32629d3aa3f89d13ae777367f = $(`&lt;div id=&quot;html_776d7db32629d3aa3f89d13ae777367f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_54e850abb2d827b2f35bd3e560519719.setContent(html_776d7db32629d3aa3f89d13ae777367f);
#
#
#
#         marker_91a52c5d5952223d50594075c6f48983.bindPopup(popup_54e850abb2d827b2f35bd3e560519719)
#         ;
#
#
#
#
#             var marker_27b2970c6d6dd4fa525be602cdf79900 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1478b4094ccc87ea1a695060d3808a39);
#
#
#         var popup_267ec53f2ddf728186d5e0f054310fdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62097ff4e2588e0d3a634e23ddc241b9 = $(`&lt;div id=&quot;html_62097ff4e2588e0d3a634e23ddc241b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_267ec53f2ddf728186d5e0f054310fdf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9565f1b7b799baf84baf9b57bafabbc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9565f1b7b799baf84baf9b57bafabbc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9565f1b7b799baf84baf9b57bafabbc4 = L.map(
#                 &quot;map_9565f1b7b799baf84baf9b57bafabbc4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f6ae00121fcddb5f1ca25ea041bb33a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f6ae00121fcddb5f1ca25ea041bb33a.addTo(map_9565f1b7b799baf84baf9b57bafabbc4);
#
#
#             var feature_group_e852e11b7cd55edd2a9f268bdd21fcd7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f8b9e0f0b6789c4f0ddf7d3389f3104e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e852e11b7cd55edd2a9f268bdd21fcd7);
#
#
#         var popup_d793b909dd1f997ea48b08fdbe77d859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_614665bf85456e43223f988dc4f2b8f3 = $(`&lt;div id=&quot;html_614665bf85456e43223f988dc4f2b8f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d793b909dd1f997ea48b08fdbe77d859.setContent(html_614665bf85456e43223f988dc4f2b8f3);
#
#
#
#         marker_f8b9e0f0b6789c4f0ddf7d3389f3104e.bindPopup(popup_d793b909dd1f997ea48b08fdbe77d859)
#         ;
#
#
#
#
#             var marker_9964e7dd38deeb57b23e0a9989a7418a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e852e11b7cd55edd2a9f268bdd21fcd7);
#
#
#         var popup_977c8ec5d57d3d6c6e77afb0f34777f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32fbe69592d8e02b1e4a82a3c38c9a60 = $(`&lt;div id=&quot;html_32fbe69592d8e02b1e4a82a3c38c9a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_977c8ec5d57d3d6c6e77afb0f34777f6.setContent(html_32fbe69592d8e02b1e4a82a3c38c9a60);
#
#
#
#         marker_9964e7dd38deeb57b23e0a9989a7418a.bindPopup(popup_977c8ec5d57d3d6c6e77afb0f34777f6)
#         ;
#
#
#
#
#             var marker_e7553eb465e29ce4a9674318e5088433 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e852e11b7cd55edd2a9f268bdd21fcd7);
#
#
#         var popup_9b0568c24c8d510c9a700636f40b1cc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7da3030d941f41329f3387e1e993250a = $(`&lt;div id=&quot;html_7da3030d941f41329f3387e1e993250a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b0568c24c8d510c9a700636f40b1cc5.setContent(html_7da3030d941f41329f3387e1e993250a);
#
#
#
#         marker_e7553eb465e29ce4a9674318e5088433.bindPopup(popup_9b0568c24c8d510c9a700636f40b1cc5)
#         ;
#
#
#
#
#             var marker_7fcee766150fa96cddc4c75a25643385 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e852e11b7cd55edd2a9f268bdd21fcd7);
#
#
#         var popup_02c9934bd7a1a235171a2be0b87b90a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59624813aea22247db5295d19511a722 = $(`&lt;div id=&quot;html_59624813aea22247db5295d19511a722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_02c9934bd7a1a235171a2be0b87b90a1.setContent(html_59624813aea22247db5295d19511a722);
#
#
#
#         marker_7fcee766150fa96cddc4c75a25643385.bindPopup(popup_02c9934bd7a1a235171a2be0b87b90a1)
#         ;
#
#
#
#
#             var marker_c761b5afa523fc546a3dbc0c1eba293a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e852e11b7cd55edd2a9f268bdd21fcd7);
#
#
#         var popup_99e1fd855c27938f147c4c22aad688cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e2b04f6928e5bb3536ab59e6a8cd451 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e2b04f6928e5bb3536ab59e6a8cd451&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e2b04f6928e5bb3536ab59e6a8cd451 = L.map(
#                 &quot;map_9e2b04f6928e5bb3536ab59e6a8cd451&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1910fd56672137a0ef9920e54c7cf8ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1910fd56672137a0ef9920e54c7cf8ad.addTo(map_9e2b04f6928e5bb3536ab59e6a8cd451);
#
#
#             var feature_group_89c60023455e492de5ef0899143aff80 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_89c60023455e492de5ef0899143aff80.addTo(map_9e2b04f6928e5bb3536ab59e6a8cd451);
#
#
#             var feature_group_sub_group_2cc83eeda5478e86e5fc5d19afba4f91 = L.featureGroup.subGroup(
#                 feature_group_89c60023455e492de5ef0899143aff80
#             );
#
#
#             var marker_391066abef9fa281eaed7f2af87ff555 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc83eeda5478e86e5fc5d19afba4f91);
#
#
#         var popup_6a0f2381406c6c9b78cf685267f89824 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2c53c8cba01f89083924a2e3c3d57e2 = $(`&lt;div id=&quot;html_a2c53c8cba01f89083924a2e3c3d57e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6a0f2381406c6c9b78cf685267f89824.setContent(html_a2c53c8cba01f89083924a2e3c3d57e2);
#
#
#
#         marker_391066abef9fa281eaed7f2af87ff555.bindPopup(popup_6a0f2381406c6c9b78cf685267f89824)
#         ;
#
#
#
#
#             var marker_31a6f7620d366661318253d7c691a0df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc83eeda5478e86e5fc5d19afba4f91);
#
#
#         var popup_6f283b42e34225bfb6c9e25b73a77dfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32b7e630eaa34972f05ecd20be7870bc = $(`&lt;div id=&quot;html_32b7e630eaa34972f05ecd20be7870bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6f283b42e34225bfb6c9e25b73a77dfb.setContent(html_32b7e630eaa34972f05ecd20be7870bc);
#
#
#
#         marker_31a6f7620d366661318253d7c691a0df.bindPopup(popup_6f283b42e34225bfb6c9e25b73a77dfb)
#         ;
#
#
#
#
#             var marker_0f23aa3293d672e5457d7064d2181fd7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc83eeda5478e86e5fc5d19afba4f91);
#
#
#         var popup_a128c50acb14d605c5dce8f7a39a325c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf44be039c3ffdd9d41f03c37b3ecb0f = $(`&lt;div id=&quot;html_cf44be039c3ffdd9d41f03c37b3ecb0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a128c50acb14d605c5dce8f7a39a325c.setContent(html_cf44be039c3ffdd9d41f03c37b3ecb0f);
#
#
#
#         marker_0f23aa3293d672e5457d7064d2181fd7.bindPopup(popup_a128c50acb14d605c5dce8f7a39a325c)
#         ;
#
#
#
#
#             var marker_33be0678fd1400e0b68668dcb468d8a7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cc83eeda5478e86e5fc5d19afba4f91);
#
#
#         var popup_94015f6f5c4dcb69761295f0c3a1b51d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd5bee5b7e901c6cbca5d878562bfb3 = $(`&lt;div id=&quot;html_9bd5bee5b7e901c6cbca5d878562bfb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_94015f6f5c4dcb69761295f0c3a1b51d.setContent(html_9bd5bee5b7e901c6cbca5d878562bfb3);
#
#
#
#         marker_
