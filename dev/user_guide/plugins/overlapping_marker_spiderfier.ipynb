# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4886c1fe66e0626be80859294398ec80 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4886c1fe66e0626be80859294398ec80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4886c1fe66e0626be80859294398ec80 = L.map(
#                 &quot;map_4886c1fe66e0626be80859294398ec80&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd308adc4ed355d91ab240a9602cad2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd308adc4ed355d91ab240a9602cad2d.addTo(map_4886c1fe66e0626be80859294398ec80);
#
#
#             var marker_af4b5d2ef179fbb7703826b1f4fe3cf5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4886c1fe66e0626be80859294398ec80);
#
#
#         var popup_c06ab7196242543b33b217a57bcb661a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8707e94403c86566ca7b779b39c17a27 = $(`&lt;div id=&quot;html_8707e94403c86566ca7b779b39c17a27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c06ab7196242543b33b217a57bcb661a.setContent(html_8707e94403c86566ca7b779b39c17a27);
#
#
#
#         marker_af4b5d2ef179fbb7703826b1f4fe3cf5.bindPopup(popup_c06ab7196242543b33b217a57bcb661a)
#         ;
#
#
#
#
#             var marker_4f5ed6fd59e9bbcc473bf796e8f74be6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4886c1fe66e0626be80859294398ec80);
#
#
#         var popup_449e4654cf851479cc53d30bcff59f40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2314ea57a27b11718411586532febc9e = $(`&lt;div id=&quot;html_2314ea57a27b11718411586532febc9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_449e4654cf851479cc53d30bcff59f40.setContent(html_2314ea57a27b11718411586532febc9e);
#
#
#
#         marker_4f5ed6fd59e9bbcc473bf796e8f74be6.bindPopup(popup_449e4654cf851479cc53d30bcff59f40)
#         ;
#
#
#
#
#             var marker_b06e47f1d8a5c5e52ac445bf7453ab19 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4886c1fe66e0626be80859294398ec80);
#
#
#         var popup_c9b4285d04cee83c222bc80c8205301a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ddbd682d3e5ab5c6756d659f957d635 = $(`&lt;div id=&quot;html_5ddbd682d3e5ab5c6756d659f957d635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c9b4285d04cee83c222bc80c8205301a.setContent(html_5ddbd682d3e5ab5c6756d659f957d635);
#
#
#
#         marker_b06e47f1d8a5c5e52ac445bf7453ab19.bindPopup(popup_c9b4285d04cee83c222bc80c8205301a)
#         ;
#
#
#
#
#             var marker_597681a2838fbedac4193428afa29b5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4886c1fe66e0626be80859294398ec80);
#
#
#         var popup_0e05ba442f7527067cf1431bfa1aa3a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_643c413d402d063da070d1e8ff98f582 = $(`&lt;div id=&quot;html_643c413d402d063da070d1e8ff98f582&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0e05ba442f7527067cf1431bfa1aa3a9.setContent(html_643c413d402d063da070d1e8ff98f582);
#
#
#
#         marker_597681a2838fbedac4193428afa29b5b.bindPopup(popup_0e05ba442f7527067cf1431bfa1aa3a9)
#         ;
#
#
#
#
#             var marker_13c1278789329b34f08d88cae1384211 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4886c1fe66e0626be80859294398ec80);
#
#
#         var popup_26ddf4751809f59dee3f0ac21c06f649 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8461f0c970398e8507cabb915cdb3964 = $(`&lt;div id=&quot;html_8461f0c970398e8507cabb915cdb3964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_26ddf4751809f59dee3f0ac21c06f6

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c602ab487bf345ac5cb7545bc8604a7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c602ab487bf345ac5cb7545bc8604a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c602ab487bf345ac5cb7545bc8604a7 = L.map(
#                 &quot;map_9c602ab487bf345ac5cb7545bc8604a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18be1512050e2cc1e210a3c6459656ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18be1512050e2cc1e210a3c6459656ee.addTo(map_9c602ab487bf345ac5cb7545bc8604a7);
#
#
#             var feature_group_6a9fcae702f7696d85a6311c1e5c3716 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6e0d493b25a5e2a4c9d10e1c73814d48 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6a9fcae702f7696d85a6311c1e5c3716);
#
#
#         var popup_035bdbe2a25d4b1727fadf0f6a3a384a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aca56df6ffd28ef38ca9f7b3b4b7ea00 = $(`&lt;div id=&quot;html_aca56df6ffd28ef38ca9f7b3b4b7ea00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_035bdbe2a25d4b1727fadf0f6a3a384a.setContent(html_aca56df6ffd28ef38ca9f7b3b4b7ea00);
#
#
#
#         marker_6e0d493b25a5e2a4c9d10e1c73814d48.bindPopup(popup_035bdbe2a25d4b1727fadf0f6a3a384a)
#         ;
#
#
#
#
#             var marker_d6acdec343468b14b60d00e420f09c1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6a9fcae702f7696d85a6311c1e5c3716);
#
#
#         var popup_2f6e13436c677a224ea13a94e67d0ffb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aeacb8fca115e38e088c3cc69611053c = $(`&lt;div id=&quot;html_aeacb8fca115e38e088c3cc69611053c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2f6e13436c677a224ea13a94e67d0ffb.setContent(html_aeacb8fca115e38e088c3cc69611053c);
#
#
#
#         marker_d6acdec343468b14b60d00e420f09c1f.bindPopup(popup_2f6e13436c677a224ea13a94e67d0ffb)
#         ;
#
#
#
#
#             var marker_39102b5704e60d20d2dc38e0e948c106 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6a9fcae702f7696d85a6311c1e5c3716);
#
#
#         var popup_6de36730ed94456928551adf6882029c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdf4008ab84db955f87e94163c2840d5 = $(`&lt;div id=&quot;html_cdf4008ab84db955f87e94163c2840d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6de36730ed94456928551adf6882029c.setContent(html_cdf4008ab84db955f87e94163c2840d5);
#
#
#
#         marker_39102b5704e60d20d2dc38e0e948c106.bindPopup(popup_6de36730ed94456928551adf6882029c)
#         ;
#
#
#
#
#             var marker_5dbf13654ff3739179ee314880ec9684 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6a9fcae702f7696d85a6311c1e5c3716);
#
#
#         var popup_8ed3d8877ece86b0d960846acf064eb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80341a39edef8cd86ff892fb6de249cd = $(`&lt;div id=&quot;html_80341a39edef8cd86ff892fb6de249cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8ed3d8877ece86b0d960846acf064eb2.setContent(html_80341a39edef8cd86ff892fb6de249cd);
#
#
#
#         marker_5dbf13654ff3739179ee314880ec9684.bindPopup(popup_8ed3d8877ece86b0d960846acf064eb2)
#         ;
#
#
#
#
#             var marker_b3f137fc35496781ed190cbdaa87a5a0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6a9fcae702f7696d85a6311c1e5c3716);
#
#
#         var popup_946b41de06a4d30a50733d793720841d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70c3f6b0af30df93c4b23b87d3bff5fe {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70c3f6b0af30df93c4b23b87d3bff5fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70c3f6b0af30df93c4b23b87d3bff5fe = L.map(
#                 &quot;map_70c3f6b0af30df93c4b23b87d3bff5fe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e72285be37defe2df63983671d1bd62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e72285be37defe2df63983671d1bd62.addTo(map_70c3f6b0af30df93c4b23b87d3bff5fe);
#
#
#             var feature_group_972d47d2a738c4600f661b100f864cf8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_972d47d2a738c4600f661b100f864cf8.addTo(map_70c3f6b0af30df93c4b23b87d3bff5fe);
#
#
#             var feature_group_sub_group_ca2922daeb0ab349ab890fbb48ba4ca9 = L.featureGroup.subGroup(
#                 feature_group_972d47d2a738c4600f661b100f864cf8
#             );
#
#
#             var marker_b6a595eb2ec7714f49999a6468ec3179 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca2922daeb0ab349ab890fbb48ba4ca9);
#
#
#         var popup_a5a530c4abe4cc183867f414ba16d08f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_491126596052a0bb08ea8c9a404e4093 = $(`&lt;div id=&quot;html_491126596052a0bb08ea8c9a404e4093&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a5a530c4abe4cc183867f414ba16d08f.setContent(html_491126596052a0bb08ea8c9a404e4093);
#
#
#
#         marker_b6a595eb2ec7714f49999a6468ec3179.bindPopup(popup_a5a530c4abe4cc183867f414ba16d08f)
#         ;
#
#
#
#
#             var marker_91868f339495768c1e3f3809869af0f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca2922daeb0ab349ab890fbb48ba4ca9);
#
#
#         var popup_e5a1917f73973f563e2f005ae1496a14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3be0c78d370bebaf3ee93fecdf32f78 = $(`&lt;div id=&quot;html_a3be0c78d370bebaf3ee93fecdf32f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e5a1917f73973f563e2f005ae1496a14.setContent(html_a3be0c78d370bebaf3ee93fecdf32f78);
#
#
#
#         marker_91868f339495768c1e3f3809869af0f5.bindPopup(popup_e5a1917f73973f563e2f005ae1496a14)
#         ;
#
#
#
#
#             var marker_6a0f94c5970099a1bb64ad2cd76faa59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca2922daeb0ab349ab890fbb48ba4ca9);
#
#
#         var popup_cf3c560066f17956c7856c92e4c4e72c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24212dcc23455053b2918a0abfe1fd16 = $(`&lt;div id=&quot;html_24212dcc23455053b2918a0abfe1fd16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cf3c560066f17956c7856c92e4c4e72c.setContent(html_24212dcc23455053b2918a0abfe1fd16);
#
#
#
#         marker_6a0f94c5970099a1bb64ad2cd76faa59.bindPopup(popup_cf3c560066f17956c7856c92e4c4e72c)
#         ;
#
#
#
#
#             var marker_9aca68c668f8ff91652be37d304c71bd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca2922daeb0ab349ab890fbb48ba4ca9);
#
#
#         var popup_162fc0ecf7507f33ddbba2ec2a34600e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c161e88297d29ef3061541684252d9a5 = $(`&lt;div id=&quot;html_c161e88297d29ef3061541684252d9a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_162fc0ecf7507f33ddbba2ec2a34600e.setContent(html_c161e88297d29ef3061541684252d9a5);
#
#
#
#         mark
