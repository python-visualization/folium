# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7104d42aaadabd842a9038c761acc958 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7104d42aaadabd842a9038c761acc958&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7104d42aaadabd842a9038c761acc958 = L.map(
#                 &quot;map_7104d42aaadabd842a9038c761acc958&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99fed55ce9dc0b68db852cda86ec53d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99fed55ce9dc0b68db852cda86ec53d9.addTo(map_7104d42aaadabd842a9038c761acc958);
#
#
#             var marker_11da62ab75a9016e738764abbccba493 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7104d42aaadabd842a9038c761acc958);
#
#
#         var popup_3f39bef8ed685c152675f205b90445e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37a9efede1446795535b3a9141320d9e = $(`&lt;div id=&quot;html_37a9efede1446795535b3a9141320d9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3f39bef8ed685c152675f205b90445e8.setContent(html_37a9efede1446795535b3a9141320d9e);
#
#
#
#         marker_11da62ab75a9016e738764abbccba493.bindPopup(popup_3f39bef8ed685c152675f205b90445e8)
#         ;
#
#
#
#
#             var marker_f9783191047edf4c334c6115bc73e976 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7104d42aaadabd842a9038c761acc958);
#
#
#         var popup_6bd56da76499505800c7a9e30fb3c6b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcd99a72d30473e68d1ce23c0c6b5739 = $(`&lt;div id=&quot;html_dcd99a72d30473e68d1ce23c0c6b5739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6bd56da76499505800c7a9e30fb3c6b1.setContent(html_dcd99a72d30473e68d1ce23c0c6b5739);
#
#
#
#         marker_f9783191047edf4c334c6115bc73e976.bindPopup(popup_6bd56da76499505800c7a9e30fb3c6b1)
#         ;
#
#
#
#
#             var marker_0d6299387cdb17c28339dead8970d5a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7104d42aaadabd842a9038c761acc958);
#
#
#         var popup_4b8d1609abd94559d65606395f1029ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00fdea3bdf13e2c04c09e826d226e798 = $(`&lt;div id=&quot;html_00fdea3bdf13e2c04c09e826d226e798&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4b8d1609abd94559d65606395f1029ce.setContent(html_00fdea3bdf13e2c04c09e826d226e798);
#
#
#
#         marker_0d6299387cdb17c28339dead8970d5a0.bindPopup(popup_4b8d1609abd94559d65606395f1029ce)
#         ;
#
#
#
#
#             var marker_df975e4ffcc7cdcd67b7bc0986ecb4bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7104d42aaadabd842a9038c761acc958);
#
#
#         var popup_fef8e4125761834520fb143f91ff7228 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47aef5dd263177059e633c1a635cc993 = $(`&lt;div id=&quot;html_47aef5dd263177059e633c1a635cc993&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fef8e4125761834520fb143f91ff7228.setContent(html_47aef5dd263177059e633c1a635cc993);
#
#
#
#         marker_df975e4ffcc7cdcd67b7bc0986ecb4bc.bindPopup(popup_fef8e4125761834520fb143f91ff7228)
#         ;
#
#
#
#
#             var marker_7e3e48d1f423ce5611657cf47a746120 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7104d42aaadabd842a9038c761acc958);
#
#
#         var popup_0a86559c639cca790d58c6f5865aef4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f6cbb037c2fe0db3336fa72d70503a9 = $(`&lt;div id=&quot;html_6f6cbb037c2fe0db3336fa72d70503a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0a86559c639cca790d58c6f5865aef4b.setContent(html_6f6cbb037c2fe0db3336fa72d70503a9);
#
#
#
#         marker_7e3e48d1f423ce5611657cf47a746120.bindPopup(popup_0a86559c639cca790d58c6f5865aef4b)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c59cd1e1ac4c1a554bbe5473106788c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c59cd1e1ac4c1a554bbe5473106788c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c59cd1e1ac4c1a554bbe5473106788c = L.map(
#                 &quot;map_4c59cd1e1ac4c1a554bbe5473106788c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8252e2787e96d6819d46d078b1a88a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8252e2787e96d6819d46d078b1a88a8.addTo(map_4c59cd1e1ac4c1a554bbe5473106788c);
#
#
#             var feature_group_0ca34e893d4a319462c8b0c6d4dd5185 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a0960e9cf2ba436a12d48c3876d59715 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0ca34e893d4a319462c8b0c6d4dd5185);
#
#
#         var popup_9bfcae122f159c609737e4374e4cc316 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f538edb744d4649576d73835665e305 = $(`&lt;div id=&quot;html_3f538edb744d4649576d73835665e305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9bfcae122f159c609737e4374e4cc316.setContent(html_3f538edb744d4649576d73835665e305);
#
#
#
#         marker_a0960e9cf2ba436a12d48c3876d59715.bindPopup(popup_9bfcae122f159c609737e4374e4cc316)
#         ;
#
#
#
#
#             var marker_185b01b4f22a4b072decb579f0a5d402 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0ca34e893d4a319462c8b0c6d4dd5185);
#
#
#         var popup_639c476cbeb6046516fd548b0eb06a8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26080788a654540ac861fb255eb77fb9 = $(`&lt;div id=&quot;html_26080788a654540ac861fb255eb77fb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_639c476cbeb6046516fd548b0eb06a8a.setContent(html_26080788a654540ac861fb255eb77fb9);
#
#
#
#         marker_185b01b4f22a4b072decb579f0a5d402.bindPopup(popup_639c476cbeb6046516fd548b0eb06a8a)
#         ;
#
#
#
#
#             var marker_656a5813df1977c67d3de7ebbb950a5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0ca34e893d4a319462c8b0c6d4dd5185);
#
#
#         var popup_bd3bacca9f66d6c51d828ccd386e185e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_115f8ba7d69b6fb18f3bdb86a083d6c5 = $(`&lt;div id=&quot;html_115f8ba7d69b6fb18f3bdb86a083d6c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bd3bacca9f66d6c51d828ccd386e185e.setContent(html_115f8ba7d69b6fb18f3bdb86a083d6c5);
#
#
#
#         marker_656a5813df1977c67d3de7ebbb950a5a.bindPopup(popup_bd3bacca9f66d6c51d828ccd386e185e)
#         ;
#
#
#
#
#             var marker_f5827363256cf81d6d7d15dbb3051309 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0ca34e893d4a319462c8b0c6d4dd5185);
#
#
#         var popup_6cfe7f9535fab25674320bc5831f0854 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d6e496f1c944883bd1a0b978ff00af = $(`&lt;div id=&quot;html_20d6e496f1c944883bd1a0b978ff00af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6cfe7f9535fab25674320bc5831f0854.setContent(html_20d6e496f1c944883bd1a0b978ff00af);
#
#
#
#         marker_f5827363256cf81d6d7d15dbb3051309.bindPopup(popup_6cfe7f9535fab25674320bc5831f0854)
#         ;
#
#
#
#
#             var marker_a847021c928405249a910b86a436c447 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0ca34e893d4a319462c8b0c6d4dd5185);
#
#
#         var popup_79fec1b9279fe7903b471df691888606 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5688f8c1685e1d80ed3f961152c38a96 = $(`&lt;div id=&quot;html_5688f8c1685e1d80ed3f961152c38a96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03b5c9d1c15087e8c91738b4f1371bfa {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03b5c9d1c15087e8c91738b4f1371bfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03b5c9d1c15087e8c91738b4f1371bfa = L.map(
#                 &quot;map_03b5c9d1c15087e8c91738b4f1371bfa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fa9bc2dfa901a6a4a342eedf1d5143c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fa9bc2dfa901a6a4a342eedf1d5143c.addTo(map_03b5c9d1c15087e8c91738b4f1371bfa);
#
#
#             var feature_group_a9740bae9be722fa3a1a3d7d7ac38775 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a9740bae9be722fa3a1a3d7d7ac38775.addTo(map_03b5c9d1c15087e8c91738b4f1371bfa);
#
#
#             var feature_group_sub_group_971eec25e30106c327d9ae51aeb25fa0 = L.featureGroup.subGroup(
#                 feature_group_a9740bae9be722fa3a1a3d7d7ac38775
#             );
#
#
#             var marker_fe0239811df777dbddf5f473f202f4f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_971eec25e30106c327d9ae51aeb25fa0);
#
#
#         var popup_0d45e3ee8d24b9368ca43f68789f5879 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2db6db845fb6a39c09b4f7616cd81fe = $(`&lt;div id=&quot;html_b2db6db845fb6a39c09b4f7616cd81fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0d45e3ee8d24b9368ca43f68789f5879.setContent(html_b2db6db845fb6a39c09b4f7616cd81fe);
#
#
#
#         marker_fe0239811df777dbddf5f473f202f4f4.bindPopup(popup_0d45e3ee8d24b9368ca43f68789f5879)
#         ;
#
#
#
#
#             var marker_57ea5c55c3c1ffc1046e74e9c5c13d18 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_971eec25e30106c327d9ae51aeb25fa0);
#
#
#         var popup_2cfbf3b4621a9046db7a79f238c2680b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d0e7d81a633a7ef33f0e40733d47c68 = $(`&lt;div id=&quot;html_2d0e7d81a633a7ef33f0e40733d47c68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2cfbf3b4621a9046db7a79f238c2680b.setContent(html_2d0e7d81a633a7ef33f0e40733d47c68);
#
#
#
#         marker_57ea5c55c3c1ffc1046e74e9c5c13d18.bindPopup(popup_2cfbf3b4621a9046db7a79f238c2680b)
#         ;
#
#
#
#
#             var marker_cdb42d2abbcdf15e8524b1e9f67a20c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_971eec25e30106c327d9ae51aeb25fa0);
#
#
#         var popup_6bcd6b07d6d6f5904766608df9eb26e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7213384cfb0421bc29143eb1a8c0f169 = $(`&lt;div id=&quot;html_7213384cfb0421bc29143eb1a8c0f169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6bcd6b07d6d6f5904766608df9eb26e5.setContent(html_7213384cfb0421bc29143eb1a8c0f169);
#
#
#
#         marker_cdb42d2abbcdf15e8524b1e9f67a20c5.bindPopup(popup_6bcd6b07d6d6f5904766608df9eb26e5)
#         ;
#
#
#
#
#             var marker_668b240ae50191181db7169843aba7e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_971eec25e30106c327d9ae51aeb25fa0);
#
#
#         var popup_91a739ce9f198b5cba3256123770f472 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84fa75c2d051751ae8979151b631477d = $(`&lt;div id=&quot;html_84fa75c2d051751ae8979151b631477d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_91a739ce9f198b5cba3256123770f472.setContent(html_84fa75c2d051751ae8979151b631477d);
#
#
#
#         marker_668b240ae50191181db7169843aba7e8.bindPopup(popup_91a739ce9f198b5cba3256123770f472)
#         ;
#
#
#
#
#             var marker_6f287c437bf09ade159bc502dcac40db = L.marker(
#                 [45.0503999
