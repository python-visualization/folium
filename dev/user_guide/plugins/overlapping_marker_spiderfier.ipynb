# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_696cf390ddadb7c22ed88b5a78d2ac17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_696cf390ddadb7c22ed88b5a78d2ac17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_696cf390ddadb7c22ed88b5a78d2ac17 = L.map(
#                 &quot;map_696cf390ddadb7c22ed88b5a78d2ac17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd36c176bfa012aeeb83f990a79b083 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afd36c176bfa012aeeb83f990a79b083.addTo(map_696cf390ddadb7c22ed88b5a78d2ac17);
#
#
#             var marker_e07a097e30969599bfdbd1f1b3bbac74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_696cf390ddadb7c22ed88b5a78d2ac17);
#
#
#         var popup_459589b8e99a5146f422857bb1619792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34a1e9f8eec3e6cb8e0d29507b7e0436 = $(`&lt;div id=&quot;html_34a1e9f8eec3e6cb8e0d29507b7e0436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_459589b8e99a5146f422857bb1619792.setContent(html_34a1e9f8eec3e6cb8e0d29507b7e0436);
#
#
#
#         marker_e07a097e30969599bfdbd1f1b3bbac74.bindPopup(popup_459589b8e99a5146f422857bb1619792)
#         ;
#
#
#
#
#             var marker_359853dd5afecb542a02acb6bb693b37 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_696cf390ddadb7c22ed88b5a78d2ac17);
#
#
#         var popup_e67edb047fa4a7c173204ebb9a92c743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_756440c815a0cfce82a5f1d22461dee3 = $(`&lt;div id=&quot;html_756440c815a0cfce82a5f1d22461dee3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e67edb047fa4a7c173204ebb9a92c743.setContent(html_756440c815a0cfce82a5f1d22461dee3);
#
#
#
#         marker_359853dd5afecb542a02acb6bb693b37.bindPopup(popup_e67edb047fa4a7c173204ebb9a92c743)
#         ;
#
#
#
#
#             var marker_ac39fe195d53917d287b54031e9ed366 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_696cf390ddadb7c22ed88b5a78d2ac17);
#
#
#         var popup_d9fafe9e3edac2552b118f96069a928f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1a415d5dd180db5c81dbb876f846b7d = $(`&lt;div id=&quot;html_f1a415d5dd180db5c81dbb876f846b7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d9fafe9e3edac2552b118f96069a928f.setContent(html_f1a415d5dd180db5c81dbb876f846b7d);
#
#
#
#         marker_ac39fe195d53917d287b54031e9ed366.bindPopup(popup_d9fafe9e3edac2552b118f96069a928f)
#         ;
#
#
#
#
#             var marker_97ac566409f9a988ccae93bd6614b1d0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_696cf390ddadb7c22ed88b5a78d2ac17);
#
#
#         var popup_51f188cda5acb79b11fab7fe55db902c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d63d19986ba8391151feed540b2bf1f = $(`&lt;div id=&quot;html_7d63d19986ba8391151feed540b2bf1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_51f188cda5acb79b11fab7fe55db902c.setContent(html_7d63d19986ba8391151feed540b2bf1f);
#
#
#
#         marker_97ac566409f9a988ccae93bd6614b1d0.bindPopup(popup_51f188cda5acb79b11fab7fe55db902c)
#         ;
#
#
#
#
#             var marker_9fec111593e0bc26a64cd46c7a9ad17b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_696cf390ddadb7c22ed88b5a78d2ac17);
#
#
#         var popup_3748f26bfa10a4ba5b013f5e9a9fa206 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42ff7316da8633ab6204d26620dcd1f8 = $(`&lt;div id=&quot;html_42ff7316da8633ab6204d26620dcd1f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3748f26bfa10a4ba5b013f5e9a9fa206.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c9d6560c709c63f451250718ce39ad8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c9d6560c709c63f451250718ce39ad8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c9d6560c709c63f451250718ce39ad8 = L.map(
#                 &quot;map_7c9d6560c709c63f451250718ce39ad8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_523b923298984ed636ec1dbada8eaea0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_523b923298984ed636ec1dbada8eaea0.addTo(map_7c9d6560c709c63f451250718ce39ad8);
#
#
#             var feature_group_2abd16f486f83c37c78beb7079c747e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4ad7d60dbb55ac6d85c9aa912799c066 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2abd16f486f83c37c78beb7079c747e2);
#
#
#         var popup_7cba1188d8bce7047257786bf4ff9bd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70faf7eb8bc144f2c9ebbf65cd637a9a = $(`&lt;div id=&quot;html_70faf7eb8bc144f2c9ebbf65cd637a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7cba1188d8bce7047257786bf4ff9bd2.setContent(html_70faf7eb8bc144f2c9ebbf65cd637a9a);
#
#
#
#         marker_4ad7d60dbb55ac6d85c9aa912799c066.bindPopup(popup_7cba1188d8bce7047257786bf4ff9bd2)
#         ;
#
#
#
#
#             var marker_43a56362da95119ed4feda40955eee3f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2abd16f486f83c37c78beb7079c747e2);
#
#
#         var popup_687013faa55ffa7dc30b26bcfa3b4311 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_345e8ee18d7ebc85414be1ec51feecd5 = $(`&lt;div id=&quot;html_345e8ee18d7ebc85414be1ec51feecd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_687013faa55ffa7dc30b26bcfa3b4311.setContent(html_345e8ee18d7ebc85414be1ec51feecd5);
#
#
#
#         marker_43a56362da95119ed4feda40955eee3f.bindPopup(popup_687013faa55ffa7dc30b26bcfa3b4311)
#         ;
#
#
#
#
#             var marker_215e86de322ff57424bc5c063290bb1c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2abd16f486f83c37c78beb7079c747e2);
#
#
#         var popup_47d3242c16689681b0a1a9f776b39099 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_429b42edda5c4d3598050973fb175fc2 = $(`&lt;div id=&quot;html_429b42edda5c4d3598050973fb175fc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_47d3242c16689681b0a1a9f776b39099.setContent(html_429b42edda5c4d3598050973fb175fc2);
#
#
#
#         marker_215e86de322ff57424bc5c063290bb1c.bindPopup(popup_47d3242c16689681b0a1a9f776b39099)
#         ;
#
#
#
#
#             var marker_50da8917bdbf3e6cb045cda29ed8e7fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2abd16f486f83c37c78beb7079c747e2);
#
#
#         var popup_e97084dc5a935f376ef355e3fb047b62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67af63036ccfe3871ab75fd8445b1acb = $(`&lt;div id=&quot;html_67af63036ccfe3871ab75fd8445b1acb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e97084dc5a935f376ef355e3fb047b62.setContent(html_67af63036ccfe3871ab75fd8445b1acb);
#
#
#
#         marker_50da8917bdbf3e6cb045cda29ed8e7fc.bindPopup(popup_e97084dc5a935f376ef355e3fb047b62)
#         ;
#
#
#
#
#             var marker_372c9fe72d81c02fad9828f5526bd1e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2abd16f486f83c37c78beb7079c747e2);
#
#
#         var popup_a8dc680f270150b8ebc62f0abadd2455 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8503e9bbe4e93ac97a5b2ade299dc624 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8503e9bbe4e93ac97a5b2ade299dc624&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8503e9bbe4e93ac97a5b2ade299dc624 = L.map(
#                 &quot;map_8503e9bbe4e93ac97a5b2ade299dc624&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_856a24eac7b6b8f18bee1a9ec07bbd03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_856a24eac7b6b8f18bee1a9ec07bbd03.addTo(map_8503e9bbe4e93ac97a5b2ade299dc624);
#
#
#             var feature_group_acf29c28f1e9e2a6c5e9095b5f077d54 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_acf29c28f1e9e2a6c5e9095b5f077d54.addTo(map_8503e9bbe4e93ac97a5b2ade299dc624);
#
#
#             var feature_group_sub_group_bf10c4e3977d62cae9f852736439d363 = L.featureGroup.subGroup(
#                 feature_group_acf29c28f1e9e2a6c5e9095b5f077d54
#             );
#
#
#             var marker_07945e695115b80f91d9fe91183c51e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf10c4e3977d62cae9f852736439d363);
#
#
#         var popup_8d2d7868744b7800d4e0095dcc35397b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4da0a91a90881c70630f5c125223d768 = $(`&lt;div id=&quot;html_4da0a91a90881c70630f5c125223d768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8d2d7868744b7800d4e0095dcc35397b.setContent(html_4da0a91a90881c70630f5c125223d768);
#
#
#
#         marker_07945e695115b80f91d9fe91183c51e7.bindPopup(popup_8d2d7868744b7800d4e0095dcc35397b)
#         ;
#
#
#
#
#             var marker_572fca1867edcdb13121452032c1e3bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf10c4e3977d62cae9f852736439d363);
#
#
#         var popup_e9490cbb283ea4efbb1443ede257ef8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_435d26d86da7edad00f35d0866573de7 = $(`&lt;div id=&quot;html_435d26d86da7edad00f35d0866573de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e9490cbb283ea4efbb1443ede257ef8b.setContent(html_435d26d86da7edad00f35d0866573de7);
#
#
#
#         marker_572fca1867edcdb13121452032c1e3bb.bindPopup(popup_e9490cbb283ea4efbb1443ede257ef8b)
#         ;
#
#
#
#
#             var marker_63d0c62838261af37f321e7743b3e510 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf10c4e3977d62cae9f852736439d363);
#
#
#         var popup_059941b7396e622360799e0f15840e23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e14446bd938fb84d6d240f9e31fb070e = $(`&lt;div id=&quot;html_e14446bd938fb84d6d240f9e31fb070e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_059941b7396e622360799e0f15840e23.setContent(html_e14446bd938fb84d6d240f9e31fb070e);
#
#
#
#         marker_63d0c62838261af37f321e7743b3e510.bindPopup(popup_059941b7396e622360799e0f15840e23)
#         ;
#
#
#
#
#             var marker_0a3725783e852a54ddaa456a8d759813 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf10c4e3977d62cae9f852736439d363);
#
#
#         var popup_e2084d0fdec404ed2c9d5c8762f34f4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b672ef9a7d2143ab232ca94efd1d34ce = $(`&lt;div id=&quot;html_b672ef9a7d2143ab232ca94efd1d34ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e2084d0fdec404ed2c9d5c8762f34f4e.setContent(html_b672ef9a7d2143ab232ca94efd1d34ce);
#
#
#
#         marker_
