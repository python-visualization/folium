# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0638517460bd1afa79922a9e90329d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0638517460bd1afa79922a9e90329d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0638517460bd1afa79922a9e90329d3 = L.map(
#                 &quot;map_b0638517460bd1afa79922a9e90329d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ccdc082ee179d289e340966588401a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ccdc082ee179d289e340966588401a2.addTo(map_b0638517460bd1afa79922a9e90329d3);
#
#
#             var marker_5a604120b0f4b77b215220cdc9c52ab3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b0638517460bd1afa79922a9e90329d3);
#
#
#         var popup_a972e02b872cd7cf6057e69237e6d0c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4b34e9f52d6791002283d111243fcb = $(`&lt;div id=&quot;html_6e4b34e9f52d6791002283d111243fcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a972e02b872cd7cf6057e69237e6d0c1.setContent(html_6e4b34e9f52d6791002283d111243fcb);
#
#
#
#         marker_5a604120b0f4b77b215220cdc9c52ab3.bindPopup(popup_a972e02b872cd7cf6057e69237e6d0c1)
#         ;
#
#
#
#
#             var marker_5033f141d2c37bbf5fc6e0d43a745a72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b0638517460bd1afa79922a9e90329d3);
#
#
#         var popup_743496579036ac6a09036da901f90a54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79807f89fea06b581e361004f26ac38c = $(`&lt;div id=&quot;html_79807f89fea06b581e361004f26ac38c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_743496579036ac6a09036da901f90a54.setContent(html_79807f89fea06b581e361004f26ac38c);
#
#
#
#         marker_5033f141d2c37bbf5fc6e0d43a745a72.bindPopup(popup_743496579036ac6a09036da901f90a54)
#         ;
#
#
#
#
#             var marker_0058c7a12141cfd66456f80b90d8c232 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b0638517460bd1afa79922a9e90329d3);
#
#
#         var popup_0ba7aa5bc2d4ee919d02b32197d0545c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_854f1ce94f71df2366d4b7b9cefbee3b = $(`&lt;div id=&quot;html_854f1ce94f71df2366d4b7b9cefbee3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0ba7aa5bc2d4ee919d02b32197d0545c.setContent(html_854f1ce94f71df2366d4b7b9cefbee3b);
#
#
#
#         marker_0058c7a12141cfd66456f80b90d8c232.bindPopup(popup_0ba7aa5bc2d4ee919d02b32197d0545c)
#         ;
#
#
#
#
#             var marker_62a7baee942017ed80c941bad7d15fa4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b0638517460bd1afa79922a9e90329d3);
#
#
#         var popup_8924882421304d2d9927f5d93a28698a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5399ce38e4a11579caca2b5c119329a9 = $(`&lt;div id=&quot;html_5399ce38e4a11579caca2b5c119329a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8924882421304d2d9927f5d93a28698a.setContent(html_5399ce38e4a11579caca2b5c119329a9);
#
#
#
#         marker_62a7baee942017ed80c941bad7d15fa4.bindPopup(popup_8924882421304d2d9927f5d93a28698a)
#         ;
#
#
#
#
#             var marker_f78c69d12780a9327b590bcb523a5f73 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b0638517460bd1afa79922a9e90329d3);
#
#
#         var popup_f784263d56153c818b7a8b3a765bb5c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61afb67250f290761d23a12e8f3180df = $(`&lt;div id=&quot;html_61afb67250f290761d23a12e8f3180df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f784263d56153c818b7a8b3a765bb5c9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6df447a7ad86f634dd8040dd7cd18f59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6df447a7ad86f634dd8040dd7cd18f59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6df447a7ad86f634dd8040dd7cd18f59 = L.map(
#                 &quot;map_6df447a7ad86f634dd8040dd7cd18f59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40d946d527b8c970bd097be596fc3e5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40d946d527b8c970bd097be596fc3e5c.addTo(map_6df447a7ad86f634dd8040dd7cd18f59);
#
#
#             var feature_group_ccebc327f6cba3144ba56b6bbbdd372d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2a9b75542493b5d077424d30b23ff01d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ccebc327f6cba3144ba56b6bbbdd372d);
#
#
#         var popup_b86052f1a2b5761ea74c129e51a5b429 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3eeffb14b8cf72982e07d5739f08881 = $(`&lt;div id=&quot;html_d3eeffb14b8cf72982e07d5739f08881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b86052f1a2b5761ea74c129e51a5b429.setContent(html_d3eeffb14b8cf72982e07d5739f08881);
#
#
#
#         marker_2a9b75542493b5d077424d30b23ff01d.bindPopup(popup_b86052f1a2b5761ea74c129e51a5b429)
#         ;
#
#
#
#
#             var marker_6347e85bc6c014de1a59d7bc47e31407 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ccebc327f6cba3144ba56b6bbbdd372d);
#
#
#         var popup_e367a634b376dba62d4baed804956629 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48c84e8772c353a1bbcc58f7031470e7 = $(`&lt;div id=&quot;html_48c84e8772c353a1bbcc58f7031470e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e367a634b376dba62d4baed804956629.setContent(html_48c84e8772c353a1bbcc58f7031470e7);
#
#
#
#         marker_6347e85bc6c014de1a59d7bc47e31407.bindPopup(popup_e367a634b376dba62d4baed804956629)
#         ;
#
#
#
#
#             var marker_ef3d4c9c1befbb9252f86ad5decf9eab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ccebc327f6cba3144ba56b6bbbdd372d);
#
#
#         var popup_4849d94556ecb52320dc4c4e79c0cbab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c9218cb95a15543b7b958fefbba420e = $(`&lt;div id=&quot;html_0c9218cb95a15543b7b958fefbba420e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4849d94556ecb52320dc4c4e79c0cbab.setContent(html_0c9218cb95a15543b7b958fefbba420e);
#
#
#
#         marker_ef3d4c9c1befbb9252f86ad5decf9eab.bindPopup(popup_4849d94556ecb52320dc4c4e79c0cbab)
#         ;
#
#
#
#
#             var marker_55e8a4a09c886820cbe8741f303b183c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ccebc327f6cba3144ba56b6bbbdd372d);
#
#
#         var popup_bd94a3e1ba415a536e0bc04e4a2221d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65e864beea3f2816523f584e0bec167c = $(`&lt;div id=&quot;html_65e864beea3f2816523f584e0bec167c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bd94a3e1ba415a536e0bc04e4a2221d6.setContent(html_65e864beea3f2816523f584e0bec167c);
#
#
#
#         marker_55e8a4a09c886820cbe8741f303b183c.bindPopup(popup_bd94a3e1ba415a536e0bc04e4a2221d6)
#         ;
#
#
#
#
#             var marker_af42c4c91e80106484f86ba2dd8ec580 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ccebc327f6cba3144ba56b6bbbdd372d);
#
#
#         var popup_19afc5386a69a3a6d1751c685b296683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9768ba7f7896467a6bf3a025c0bba0e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9768ba7f7896467a6bf3a025c0bba0e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9768ba7f7896467a6bf3a025c0bba0e0 = L.map(
#                 &quot;map_9768ba7f7896467a6bf3a025c0bba0e0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaab583fc6d4921046f5ff48d84205a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aaab583fc6d4921046f5ff48d84205a1.addTo(map_9768ba7f7896467a6bf3a025c0bba0e0);
#
#
#             var feature_group_2c4db63c736b440a9b8e9ee0f73ebb68 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2c4db63c736b440a9b8e9ee0f73ebb68.addTo(map_9768ba7f7896467a6bf3a025c0bba0e0);
#
#
#             var feature_group_sub_group_5706ef31761c2e117de08f5095dc0815 = L.featureGroup.subGroup(
#                 feature_group_2c4db63c736b440a9b8e9ee0f73ebb68
#             );
#
#
#             var marker_744b88ba286147c680933dd9b26f0f40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5706ef31761c2e117de08f5095dc0815);
#
#
#         var popup_7ddfc939f461af28751204cac0087a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0412137fc8f3a991eb89401adbd93298 = $(`&lt;div id=&quot;html_0412137fc8f3a991eb89401adbd93298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7ddfc939f461af28751204cac0087a9e.setContent(html_0412137fc8f3a991eb89401adbd93298);
#
#
#
#         marker_744b88ba286147c680933dd9b26f0f40.bindPopup(popup_7ddfc939f461af28751204cac0087a9e)
#         ;
#
#
#
#
#             var marker_da6a386493f824f086dbf94556ec1f2c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5706ef31761c2e117de08f5095dc0815);
#
#
#         var popup_d0170e8ee0eb5f67c87d3b9ae228ed51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72be975343f64b5550814d193f56d6bc = $(`&lt;div id=&quot;html_72be975343f64b5550814d193f56d6bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d0170e8ee0eb5f67c87d3b9ae228ed51.setContent(html_72be975343f64b5550814d193f56d6bc);
#
#
#
#         marker_da6a386493f824f086dbf94556ec1f2c.bindPopup(popup_d0170e8ee0eb5f67c87d3b9ae228ed51)
#         ;
#
#
#
#
#             var marker_1397ce11ab4527a46b36fcfade73f017 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5706ef31761c2e117de08f5095dc0815);
#
#
#         var popup_b7a2c6e5fd10f162cf994c79e745a05a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e48f9c0558b082f22b9bb9d8ddbda155 = $(`&lt;div id=&quot;html_e48f9c0558b082f22b9bb9d8ddbda155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b7a2c6e5fd10f162cf994c79e745a05a.setContent(html_e48f9c0558b082f22b9bb9d8ddbda155);
#
#
#
#         marker_1397ce11ab4527a46b36fcfade73f017.bindPopup(popup_b7a2c6e5fd10f162cf994c79e745a05a)
#         ;
#
#
#
#
#             var marker_d580de4cc84657fdec813dc9feda85f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5706ef31761c2e117de08f5095dc0815);
#
#
#         var popup_14c4836749a2d8d419c02bdde1c1d797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc057c4a5ed2d5908712c198a2398975 = $(`&lt;div id=&quot;html_bc057c4a5ed2d5908712c198a2398975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_14c4836749a2d8d419c02bdde1c1d797.setContent(html_bc057c4a5ed2d5908712c198a2398975);
#
#
#
#         marker_
