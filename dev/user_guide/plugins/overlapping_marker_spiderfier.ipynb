# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13ba4bac976cd4db936d716b5e6f6cef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13ba4bac976cd4db936d716b5e6f6cef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13ba4bac976cd4db936d716b5e6f6cef = L.map(
#                 &quot;map_13ba4bac976cd4db936d716b5e6f6cef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bd5eada93d8529c5f3d5e5965d51bdc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bd5eada93d8529c5f3d5e5965d51bdc.addTo(map_13ba4bac976cd4db936d716b5e6f6cef);
#
#
#             var marker_c20d8b35003ded4d9e91c03229fe2b3c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_13ba4bac976cd4db936d716b5e6f6cef);
#
#
#         var popup_d5811bf6a1dfc6292b233c10acc1e29d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea40cc756a9b6a70ba74b34e1b86d402 = $(`&lt;div id=&quot;html_ea40cc756a9b6a70ba74b34e1b86d402&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d5811bf6a1dfc6292b233c10acc1e29d.setContent(html_ea40cc756a9b6a70ba74b34e1b86d402);
#
#
#
#         marker_c20d8b35003ded4d9e91c03229fe2b3c.bindPopup(popup_d5811bf6a1dfc6292b233c10acc1e29d)
#         ;
#
#
#
#
#             var marker_2317e84cb177dd4931aaf30e2fe92462 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_13ba4bac976cd4db936d716b5e6f6cef);
#
#
#         var popup_265edd97b1555200c41520bb7d838740 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58c380f3b95111f7d22303f7084870ad = $(`&lt;div id=&quot;html_58c380f3b95111f7d22303f7084870ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_265edd97b1555200c41520bb7d838740.setContent(html_58c380f3b95111f7d22303f7084870ad);
#
#
#
#         marker_2317e84cb177dd4931aaf30e2fe92462.bindPopup(popup_265edd97b1555200c41520bb7d838740)
#         ;
#
#
#
#
#             var marker_90bbdc0053449d6bc3bbcf398fdcb71b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_13ba4bac976cd4db936d716b5e6f6cef);
#
#
#         var popup_6605dbb20299afc22fb12ca214b2db13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f0d142dc3a932612cb8aac134eb3aad = $(`&lt;div id=&quot;html_5f0d142dc3a932612cb8aac134eb3aad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6605dbb20299afc22fb12ca214b2db13.setContent(html_5f0d142dc3a932612cb8aac134eb3aad);
#
#
#
#         marker_90bbdc0053449d6bc3bbcf398fdcb71b.bindPopup(popup_6605dbb20299afc22fb12ca214b2db13)
#         ;
#
#
#
#
#             var marker_d024ff14a0f7d640adc969a27ecfe64f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_13ba4bac976cd4db936d716b5e6f6cef);
#
#
#         var popup_f400ac10871f15fb1b0881b14f2153bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f2aad75fb7194c4c295688b79e8b3f0 = $(`&lt;div id=&quot;html_9f2aad75fb7194c4c295688b79e8b3f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f400ac10871f15fb1b0881b14f2153bf.setContent(html_9f2aad75fb7194c4c295688b79e8b3f0);
#
#
#
#         marker_d024ff14a0f7d640adc969a27ecfe64f.bindPopup(popup_f400ac10871f15fb1b0881b14f2153bf)
#         ;
#
#
#
#
#             var marker_c38b598af00cc9371fbf42e8febd6f27 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_13ba4bac976cd4db936d716b5e6f6cef);
#
#
#         var popup_a6d0cd538e05c543a6d2cc61378fb215 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a502f7303f442df5e372e3c898ffb84c = $(`&lt;div id=&quot;html_a502f7303f442df5e372e3c898ffb84c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a6d0cd538e05c543a6d2cc61378fb215.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_372938d3da6ca6bc31a1063d05c9b287 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_372938d3da6ca6bc31a1063d05c9b287&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_372938d3da6ca6bc31a1063d05c9b287 = L.map(
#                 &quot;map_372938d3da6ca6bc31a1063d05c9b287&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f3aa7f54bad64977207bbf5bc9db9be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f3aa7f54bad64977207bbf5bc9db9be.addTo(map_372938d3da6ca6bc31a1063d05c9b287);
#
#
#             var feature_group_c87a2bc04aa2ccc8e17bf41a0951218c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3470fcdd11023d8574e528b6d7d1c0f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c87a2bc04aa2ccc8e17bf41a0951218c);
#
#
#         var popup_bf051e9cabe2d3aada3c539fa0b464d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4984a985134351bae63b9f2c885a2c5 = $(`&lt;div id=&quot;html_d4984a985134351bae63b9f2c885a2c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bf051e9cabe2d3aada3c539fa0b464d6.setContent(html_d4984a985134351bae63b9f2c885a2c5);
#
#
#
#         marker_3470fcdd11023d8574e528b6d7d1c0f9.bindPopup(popup_bf051e9cabe2d3aada3c539fa0b464d6)
#         ;
#
#
#
#
#             var marker_3cb010680a41ed28b913a35f2a829cbe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c87a2bc04aa2ccc8e17bf41a0951218c);
#
#
#         var popup_9ca0cc3d4ef4bedb9f18b50a59ad4c49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fb9ecd3cb88a5ff4ff4e4584d03496d = $(`&lt;div id=&quot;html_4fb9ecd3cb88a5ff4ff4e4584d03496d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9ca0cc3d4ef4bedb9f18b50a59ad4c49.setContent(html_4fb9ecd3cb88a5ff4ff4e4584d03496d);
#
#
#
#         marker_3cb010680a41ed28b913a35f2a829cbe.bindPopup(popup_9ca0cc3d4ef4bedb9f18b50a59ad4c49)
#         ;
#
#
#
#
#             var marker_b34608af71841d14c3722adfb4b8ee12 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c87a2bc04aa2ccc8e17bf41a0951218c);
#
#
#         var popup_5bdb5fd2b76e67f8e3e9af975ae0961b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02c0981d9ed4fd07ada73edbd7f25f28 = $(`&lt;div id=&quot;html_02c0981d9ed4fd07ada73edbd7f25f28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5bdb5fd2b76e67f8e3e9af975ae0961b.setContent(html_02c0981d9ed4fd07ada73edbd7f25f28);
#
#
#
#         marker_b34608af71841d14c3722adfb4b8ee12.bindPopup(popup_5bdb5fd2b76e67f8e3e9af975ae0961b)
#         ;
#
#
#
#
#             var marker_9276d260c59f0872daaf23ccd8f8a151 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c87a2bc04aa2ccc8e17bf41a0951218c);
#
#
#         var popup_e9991200f608bca9c50db21345961340 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a591e46ded4699c21449be39ddd5e0a = $(`&lt;div id=&quot;html_1a591e46ded4699c21449be39ddd5e0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e9991200f608bca9c50db21345961340.setContent(html_1a591e46ded4699c21449be39ddd5e0a);
#
#
#
#         marker_9276d260c59f0872daaf23ccd8f8a151.bindPopup(popup_e9991200f608bca9c50db21345961340)
#         ;
#
#
#
#
#             var marker_6b028c25afe27375c3ec79e7b2bb6932 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c87a2bc04aa2ccc8e17bf41a0951218c);
#
#
#         var popup_c3d8a0c5565bcdd120788e8732330ffd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e588c127c204349ce7b007fe2809898 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e588c127c204349ce7b007fe2809898&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e588c127c204349ce7b007fe2809898 = L.map(
#                 &quot;map_5e588c127c204349ce7b007fe2809898&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76267e2a4405d4aa2955e9c1c403233d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76267e2a4405d4aa2955e9c1c403233d.addTo(map_5e588c127c204349ce7b007fe2809898);
#
#
#             var feature_group_fcf673b6385348079d4d9abee8f7ca7e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fcf673b6385348079d4d9abee8f7ca7e.addTo(map_5e588c127c204349ce7b007fe2809898);
#
#
#             var feature_group_sub_group_a3cd632372f6290b06db869d93f04d9c = L.featureGroup.subGroup(
#                 feature_group_fcf673b6385348079d4d9abee8f7ca7e
#             );
#
#
#             var marker_3f63dec674d666db77b276de7092e8e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3cd632372f6290b06db869d93f04d9c);
#
#
#         var popup_cd7b3311c9e113e3d85ef37017709198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a811aae329692060df468332517ca70 = $(`&lt;div id=&quot;html_4a811aae329692060df468332517ca70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cd7b3311c9e113e3d85ef37017709198.setContent(html_4a811aae329692060df468332517ca70);
#
#
#
#         marker_3f63dec674d666db77b276de7092e8e0.bindPopup(popup_cd7b3311c9e113e3d85ef37017709198)
#         ;
#
#
#
#
#             var marker_001359fa77d870ec863264f77d8f3a39 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3cd632372f6290b06db869d93f04d9c);
#
#
#         var popup_fb3008b4d247637c8be3d9b82f3a0bee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e754ddad6b03010390aa0a166726fe1b = $(`&lt;div id=&quot;html_e754ddad6b03010390aa0a166726fe1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fb3008b4d247637c8be3d9b82f3a0bee.setContent(html_e754ddad6b03010390aa0a166726fe1b);
#
#
#
#         marker_001359fa77d870ec863264f77d8f3a39.bindPopup(popup_fb3008b4d247637c8be3d9b82f3a0bee)
#         ;
#
#
#
#
#             var marker_2255211db408f4a841753d99f9d21728 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3cd632372f6290b06db869d93f04d9c);
#
#
#         var popup_6ab2acaf6ef4d17e346a17737953686b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63f665c1fd2d7e07d82021689e999813 = $(`&lt;div id=&quot;html_63f665c1fd2d7e07d82021689e999813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6ab2acaf6ef4d17e346a17737953686b.setContent(html_63f665c1fd2d7e07d82021689e999813);
#
#
#
#         marker_2255211db408f4a841753d99f9d21728.bindPopup(popup_6ab2acaf6ef4d17e346a17737953686b)
#         ;
#
#
#
#
#             var marker_bfd931d9e75941d79ed2e1a75db1f85e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3cd632372f6290b06db869d93f04d9c);
#
#
#         var popup_69f9072af77a1b8307aff304ff11378d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1eb7fa686afa8d951a3ca74b1d95622 = $(`&lt;div id=&quot;html_a1eb7fa686afa8d951a3ca74b1d95622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_69f9072af77a1b8307aff304ff11378d.setContent(html_a1eb7fa686afa8d951a3ca74b1d95622);
#
#
#
#         marker_
