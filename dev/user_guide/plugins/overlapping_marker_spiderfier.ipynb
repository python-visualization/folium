# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d538faa371b43528d54f43eb1b0ca25d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d538faa371b43528d54f43eb1b0ca25d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d538faa371b43528d54f43eb1b0ca25d = L.map(
#                 &quot;map_d538faa371b43528d54f43eb1b0ca25d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d153778ee40bc6e7ba8e150059423e20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d153778ee40bc6e7ba8e150059423e20.addTo(map_d538faa371b43528d54f43eb1b0ca25d);
#
#
#             var marker_304a4d9588d4235fb88c96e976fca54c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d538faa371b43528d54f43eb1b0ca25d);
#
#
#         var popup_06a96cb156b6707315a63b1e9240e781 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cce84d6fffc2761207ccbbed332f95ef = $(`&lt;div id=&quot;html_cce84d6fffc2761207ccbbed332f95ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_06a96cb156b6707315a63b1e9240e781.setContent(html_cce84d6fffc2761207ccbbed332f95ef);
#
#
#
#         marker_304a4d9588d4235fb88c96e976fca54c.bindPopup(popup_06a96cb156b6707315a63b1e9240e781)
#         ;
#
#
#
#
#             var marker_431d7c2b546f33f59309e48f9c2fb90c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d538faa371b43528d54f43eb1b0ca25d);
#
#
#         var popup_eabbe3835914eb911f2ff41bcf631752 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a6da2b55adab19b8835c4be9e94b673 = $(`&lt;div id=&quot;html_2a6da2b55adab19b8835c4be9e94b673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eabbe3835914eb911f2ff41bcf631752.setContent(html_2a6da2b55adab19b8835c4be9e94b673);
#
#
#
#         marker_431d7c2b546f33f59309e48f9c2fb90c.bindPopup(popup_eabbe3835914eb911f2ff41bcf631752)
#         ;
#
#
#
#
#             var marker_170664c51c60da4e73df88428ba9c9d4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d538faa371b43528d54f43eb1b0ca25d);
#
#
#         var popup_1699c6fd6cb8e2a9a715b2796e21b543 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec59f8822018961ac8885a7ecc9007fd = $(`&lt;div id=&quot;html_ec59f8822018961ac8885a7ecc9007fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1699c6fd6cb8e2a9a715b2796e21b543.setContent(html_ec59f8822018961ac8885a7ecc9007fd);
#
#
#
#         marker_170664c51c60da4e73df88428ba9c9d4.bindPopup(popup_1699c6fd6cb8e2a9a715b2796e21b543)
#         ;
#
#
#
#
#             var marker_68535da28fb28668554831117bdd08a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d538faa371b43528d54f43eb1b0ca25d);
#
#
#         var popup_0a227442602b6bb147e61e2fba468898 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11b72553245c22dfb7af748559582fab = $(`&lt;div id=&quot;html_11b72553245c22dfb7af748559582fab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0a227442602b6bb147e61e2fba468898.setContent(html_11b72553245c22dfb7af748559582fab);
#
#
#
#         marker_68535da28fb28668554831117bdd08a3.bindPopup(popup_0a227442602b6bb147e61e2fba468898)
#         ;
#
#
#
#
#             var marker_d134728562999c5e0fa3de5443b3f06c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d538faa371b43528d54f43eb1b0ca25d);
#
#
#         var popup_a938f23528d59db4fc128db34f7ba8b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_951691ad3c559d5b8d1ec07f447550ab = $(`&lt;div id=&quot;html_951691ad3c559d5b8d1ec07f447550ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a938f23528d59db4fc128db34f7ba8b3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec3818619e72b4f6d8952d18d89a863c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec3818619e72b4f6d8952d18d89a863c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec3818619e72b4f6d8952d18d89a863c = L.map(
#                 &quot;map_ec3818619e72b4f6d8952d18d89a863c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c972f06c743897876c02191d65fe7ee7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c972f06c743897876c02191d65fe7ee7.addTo(map_ec3818619e72b4f6d8952d18d89a863c);
#
#
#             var feature_group_2c17d79bdc35aeefb97dd3bb1e58522f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aa9c64c1b721e8809e1d692bfaca3802 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2c17d79bdc35aeefb97dd3bb1e58522f);
#
#
#         var popup_786baae901777f1ce5458c98229f65a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7770a860b8031c97133c6e612aef9e8e = $(`&lt;div id=&quot;html_7770a860b8031c97133c6e612aef9e8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_786baae901777f1ce5458c98229f65a6.setContent(html_7770a860b8031c97133c6e612aef9e8e);
#
#
#
#         marker_aa9c64c1b721e8809e1d692bfaca3802.bindPopup(popup_786baae901777f1ce5458c98229f65a6)
#         ;
#
#
#
#
#             var marker_99b2c955fc531d72f6694060f248b57c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2c17d79bdc35aeefb97dd3bb1e58522f);
#
#
#         var popup_6e90bc13ea04e3f198af060c8c67c46e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71454de7e8c7c8c938a09757c55fe7c7 = $(`&lt;div id=&quot;html_71454de7e8c7c8c938a09757c55fe7c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6e90bc13ea04e3f198af060c8c67c46e.setContent(html_71454de7e8c7c8c938a09757c55fe7c7);
#
#
#
#         marker_99b2c955fc531d72f6694060f248b57c.bindPopup(popup_6e90bc13ea04e3f198af060c8c67c46e)
#         ;
#
#
#
#
#             var marker_08500455ae71a658e5b73b75cfbdf422 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2c17d79bdc35aeefb97dd3bb1e58522f);
#
#
#         var popup_e9e0731e77d393297b91ac71b796d884 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4f7c4ad1ccae755c8d3b9aa804f3601 = $(`&lt;div id=&quot;html_e4f7c4ad1ccae755c8d3b9aa804f3601&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e9e0731e77d393297b91ac71b796d884.setContent(html_e4f7c4ad1ccae755c8d3b9aa804f3601);
#
#
#
#         marker_08500455ae71a658e5b73b75cfbdf422.bindPopup(popup_e9e0731e77d393297b91ac71b796d884)
#         ;
#
#
#
#
#             var marker_cee252be21092ea0966069831c4d4675 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2c17d79bdc35aeefb97dd3bb1e58522f);
#
#
#         var popup_64f3599b62e7730cb60adcc0714fe9c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5006a31500a43586389b9e75294048e0 = $(`&lt;div id=&quot;html_5006a31500a43586389b9e75294048e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_64f3599b62e7730cb60adcc0714fe9c6.setContent(html_5006a31500a43586389b9e75294048e0);
#
#
#
#         marker_cee252be21092ea0966069831c4d4675.bindPopup(popup_64f3599b62e7730cb60adcc0714fe9c6)
#         ;
#
#
#
#
#             var marker_65054f49cb106fe82379ba8754cb9188 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2c17d79bdc35aeefb97dd3bb1e58522f);
#
#
#         var popup_bca0eaa768d8478039bba527d11c615f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28df736e49be2c4e9252c87020ff45cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28df736e49be2c4e9252c87020ff45cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28df736e49be2c4e9252c87020ff45cf = L.map(
#                 &quot;map_28df736e49be2c4e9252c87020ff45cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b028244ea9c3a2deecbfc3550157c5ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b028244ea9c3a2deecbfc3550157c5ca.addTo(map_28df736e49be2c4e9252c87020ff45cf);
#
#
#             var feature_group_4b761492b4d0db7d0ff4fb827202c04f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4b761492b4d0db7d0ff4fb827202c04f.addTo(map_28df736e49be2c4e9252c87020ff45cf);
#
#
#             var feature_group_sub_group_9199895d1c9242a23339605c482993b4 = L.featureGroup.subGroup(
#                 feature_group_4b761492b4d0db7d0ff4fb827202c04f
#             );
#
#
#             var marker_72ba779a3e0f914211d03087448ebeed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9199895d1c9242a23339605c482993b4);
#
#
#         var popup_f4b0637c1acbe3618b1398660655d2e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6523fdf94a389b375b6a276931bea7c = $(`&lt;div id=&quot;html_f6523fdf94a389b375b6a276931bea7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f4b0637c1acbe3618b1398660655d2e0.setContent(html_f6523fdf94a389b375b6a276931bea7c);
#
#
#
#         marker_72ba779a3e0f914211d03087448ebeed.bindPopup(popup_f4b0637c1acbe3618b1398660655d2e0)
#         ;
#
#
#
#
#             var marker_ce3782b318a80ce036dd1adc56e09e41 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9199895d1c9242a23339605c482993b4);
#
#
#         var popup_e31694bbb198ced0e5f4df786ce21fc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaeddbd83b1e71e5f0f38d1b0c3eb2c0 = $(`&lt;div id=&quot;html_aaeddbd83b1e71e5f0f38d1b0c3eb2c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e31694bbb198ced0e5f4df786ce21fc7.setContent(html_aaeddbd83b1e71e5f0f38d1b0c3eb2c0);
#
#
#
#         marker_ce3782b318a80ce036dd1adc56e09e41.bindPopup(popup_e31694bbb198ced0e5f4df786ce21fc7)
#         ;
#
#
#
#
#             var marker_a511966872f2a2f4a6d7c92d8116a904 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9199895d1c9242a23339605c482993b4);
#
#
#         var popup_5e564d6c3d752fcf85c8341d531ac0aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0639fa3a7d66a76c837600d5c6aabf1 = $(`&lt;div id=&quot;html_a0639fa3a7d66a76c837600d5c6aabf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5e564d6c3d752fcf85c8341d531ac0aa.setContent(html_a0639fa3a7d66a76c837600d5c6aabf1);
#
#
#
#         marker_a511966872f2a2f4a6d7c92d8116a904.bindPopup(popup_5e564d6c3d752fcf85c8341d531ac0aa)
#         ;
#
#
#
#
#             var marker_c30d406a6f2f2b2b519e8ba2639e0785 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9199895d1c9242a23339605c482993b4);
#
#
#         var popup_91ff7506bbdd3744fd018f29482c9955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f741c0d9c400d904f306dd8af2510c2f = $(`&lt;div id=&quot;html_f741c0d9c400d904f306dd8af2510c2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_91ff7506bbdd3744fd018f29482c9955.setContent(html_f741c0d9c400d904f306dd8af2510c2f);
#
#
#
#         marker_
