# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cdc79d90234cde5e70eea9c3f455655 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cdc79d90234cde5e70eea9c3f455655&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cdc79d90234cde5e70eea9c3f455655 = L.map(
#                 &quot;map_3cdc79d90234cde5e70eea9c3f455655&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6af3ac5c7f63387b29281f4a201749ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6af3ac5c7f63387b29281f4a201749ed.addTo(map_3cdc79d90234cde5e70eea9c3f455655);
#
#
#             var marker_6a3c9323bdcba1cea5f7172a4badb6de = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3cdc79d90234cde5e70eea9c3f455655);
#
#
#         var popup_ac3c9ae30ea82852bfe268074503dd02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32dd884457e533d5ef7364838df07e0c = $(`&lt;div id=&quot;html_32dd884457e533d5ef7364838df07e0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ac3c9ae30ea82852bfe268074503dd02.setContent(html_32dd884457e533d5ef7364838df07e0c);
#
#
#
#         marker_6a3c9323bdcba1cea5f7172a4badb6de.bindPopup(popup_ac3c9ae30ea82852bfe268074503dd02)
#         ;
#
#
#
#
#             var marker_d791801a4bb00c6ea2ba86b71024225a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3cdc79d90234cde5e70eea9c3f455655);
#
#
#         var popup_cbd40f28cdc62113485f2f882bae9669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c22b45ae48bdd9006229315de6ccb557 = $(`&lt;div id=&quot;html_c22b45ae48bdd9006229315de6ccb557&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cbd40f28cdc62113485f2f882bae9669.setContent(html_c22b45ae48bdd9006229315de6ccb557);
#
#
#
#         marker_d791801a4bb00c6ea2ba86b71024225a.bindPopup(popup_cbd40f28cdc62113485f2f882bae9669)
#         ;
#
#
#
#
#             var marker_124590cd717ab4a36d91c0f8d333017a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3cdc79d90234cde5e70eea9c3f455655);
#
#
#         var popup_7dde7fa064d7f021f6ea09b6a7d91acd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15fe602787b17a7a23f298f69ece381a = $(`&lt;div id=&quot;html_15fe602787b17a7a23f298f69ece381a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7dde7fa064d7f021f6ea09b6a7d91acd.setContent(html_15fe602787b17a7a23f298f69ece381a);
#
#
#
#         marker_124590cd717ab4a36d91c0f8d333017a.bindPopup(popup_7dde7fa064d7f021f6ea09b6a7d91acd)
#         ;
#
#
#
#
#             var marker_4e141dc336d9c324af8a8ad4088e178d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3cdc79d90234cde5e70eea9c3f455655);
#
#
#         var popup_695e5fb17200ab5bb80102feb3cc4238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13e53b3e5c7fcbfd36831147eadd1d26 = $(`&lt;div id=&quot;html_13e53b3e5c7fcbfd36831147eadd1d26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_695e5fb17200ab5bb80102feb3cc4238.setContent(html_13e53b3e5c7fcbfd36831147eadd1d26);
#
#
#
#         marker_4e141dc336d9c324af8a8ad4088e178d.bindPopup(popup_695e5fb17200ab5bb80102feb3cc4238)
#         ;
#
#
#
#
#             var marker_13b8568404e5f9a911019465e7549661 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3cdc79d90234cde5e70eea9c3f455655);
#
#
#         var popup_79c43d4ed46838cf546e8b0ccbfe2609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed63494cf1d1015207b0c9b725db3735 = $(`&lt;div id=&quot;html_ed63494cf1d1015207b0c9b725db3735&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_79c43d4ed46838cf546e8b0ccbfe2609.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86985f8e9ee4add7e2237d9ed3017b0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86985f8e9ee4add7e2237d9ed3017b0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86985f8e9ee4add7e2237d9ed3017b0d = L.map(
#                 &quot;map_86985f8e9ee4add7e2237d9ed3017b0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7518aa75ec7559cfcd567369f53229bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7518aa75ec7559cfcd567369f53229bb.addTo(map_86985f8e9ee4add7e2237d9ed3017b0d);
#
#
#             var feature_group_c156804bd2fc6b30e80df2d762877591 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e8912aa24d020ab3dcbf49e9f2cf5210 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c156804bd2fc6b30e80df2d762877591);
#
#
#         var popup_8c8af14fc8e289706fd0ee47aad048f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa20a6f0124b8e5f3bbe11038acee6e2 = $(`&lt;div id=&quot;html_aa20a6f0124b8e5f3bbe11038acee6e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8c8af14fc8e289706fd0ee47aad048f5.setContent(html_aa20a6f0124b8e5f3bbe11038acee6e2);
#
#
#
#         marker_e8912aa24d020ab3dcbf49e9f2cf5210.bindPopup(popup_8c8af14fc8e289706fd0ee47aad048f5)
#         ;
#
#
#
#
#             var marker_dbebfd6fbca6e9fb12d419613b7d6470 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c156804bd2fc6b30e80df2d762877591);
#
#
#         var popup_ca6d1a3d87bdc60094230e8bf35d1592 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c7a5bd914bfa72b78bd816dd8d53726 = $(`&lt;div id=&quot;html_9c7a5bd914bfa72b78bd816dd8d53726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ca6d1a3d87bdc60094230e8bf35d1592.setContent(html_9c7a5bd914bfa72b78bd816dd8d53726);
#
#
#
#         marker_dbebfd6fbca6e9fb12d419613b7d6470.bindPopup(popup_ca6d1a3d87bdc60094230e8bf35d1592)
#         ;
#
#
#
#
#             var marker_a2c47944c6bf2973bf9663576a353642 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c156804bd2fc6b30e80df2d762877591);
#
#
#         var popup_91be5de68a4fdc3a184f5e8f50a2dfb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64047a5c340e9c6bcc2cccd7ea15cc31 = $(`&lt;div id=&quot;html_64047a5c340e9c6bcc2cccd7ea15cc31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_91be5de68a4fdc3a184f5e8f50a2dfb1.setContent(html_64047a5c340e9c6bcc2cccd7ea15cc31);
#
#
#
#         marker_a2c47944c6bf2973bf9663576a353642.bindPopup(popup_91be5de68a4fdc3a184f5e8f50a2dfb1)
#         ;
#
#
#
#
#             var marker_73bf7c8fccb40223ccc4775448327939 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c156804bd2fc6b30e80df2d762877591);
#
#
#         var popup_a627d8e88b8c4fb02a09508f99996438 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c7224185c9e2ea01c6776ba8513432c = $(`&lt;div id=&quot;html_8c7224185c9e2ea01c6776ba8513432c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a627d8e88b8c4fb02a09508f99996438.setContent(html_8c7224185c9e2ea01c6776ba8513432c);
#
#
#
#         marker_73bf7c8fccb40223ccc4775448327939.bindPopup(popup_a627d8e88b8c4fb02a09508f99996438)
#         ;
#
#
#
#
#             var marker_51299e574b572ecbed3ea0e5e945077e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c156804bd2fc6b30e80df2d762877591);
#
#
#         var popup_43e44ac666a46e7baf32406ef2f7d21d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3334810bd7576e59bee30191b9dea90c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3334810bd7576e59bee30191b9dea90c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3334810bd7576e59bee30191b9dea90c = L.map(
#                 &quot;map_3334810bd7576e59bee30191b9dea90c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afbea33d125fa9fbee9687d753dea72b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afbea33d125fa9fbee9687d753dea72b.addTo(map_3334810bd7576e59bee30191b9dea90c);
#
#
#             var feature_group_e455bef56d86a9e0d5b8696b6f8d6555 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e455bef56d86a9e0d5b8696b6f8d6555.addTo(map_3334810bd7576e59bee30191b9dea90c);
#
#
#             var feature_group_sub_group_9e20c7e2ade7b6e3c8a121cc0801ced3 = L.featureGroup.subGroup(
#                 feature_group_e455bef56d86a9e0d5b8696b6f8d6555
#             );
#
#
#             var marker_b6c472b5c8a077a9aa23330b7f3cb184 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e20c7e2ade7b6e3c8a121cc0801ced3);
#
#
#         var popup_422998fd17703076408229c511ac1149 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0364db4c200018faeeb1bca5daa39fbd = $(`&lt;div id=&quot;html_0364db4c200018faeeb1bca5daa39fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_422998fd17703076408229c511ac1149.setContent(html_0364db4c200018faeeb1bca5daa39fbd);
#
#
#
#         marker_b6c472b5c8a077a9aa23330b7f3cb184.bindPopup(popup_422998fd17703076408229c511ac1149)
#         ;
#
#
#
#
#             var marker_6f49d368ea024620ceeec5e4b543ca15 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e20c7e2ade7b6e3c8a121cc0801ced3);
#
#
#         var popup_f19974110dd85eadb4584f951cf81475 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5fb7ab690f6890e4f36ce8328e8c6c7 = $(`&lt;div id=&quot;html_c5fb7ab690f6890e4f36ce8328e8c6c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f19974110dd85eadb4584f951cf81475.setContent(html_c5fb7ab690f6890e4f36ce8328e8c6c7);
#
#
#
#         marker_6f49d368ea024620ceeec5e4b543ca15.bindPopup(popup_f19974110dd85eadb4584f951cf81475)
#         ;
#
#
#
#
#             var marker_aeb66ede9f783a6387f9b8d7fd4cc9b0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e20c7e2ade7b6e3c8a121cc0801ced3);
#
#
#         var popup_2820c95ca517d2ceb1795b3ffa1a9e09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_954748082d05606512b9ffece78577a3 = $(`&lt;div id=&quot;html_954748082d05606512b9ffece78577a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2820c95ca517d2ceb1795b3ffa1a9e09.setContent(html_954748082d05606512b9ffece78577a3);
#
#
#
#         marker_aeb66ede9f783a6387f9b8d7fd4cc9b0.bindPopup(popup_2820c95ca517d2ceb1795b3ffa1a9e09)
#         ;
#
#
#
#
#             var marker_9b0ff444db76489938512efbcfdf9db4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9e20c7e2ade7b6e3c8a121cc0801ced3);
#
#
#         var popup_2c74a02d2a48aa691513b9a67e67c4e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2cea1046eebcbfd24707544b379f0e7 = $(`&lt;div id=&quot;html_a2cea1046eebcbfd24707544b379f0e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2c74a02d2a48aa691513b9a67e67c4e9.setContent(html_a2cea1046eebcbfd24707544b379f0e7);
#
#
#
#         marker_
