# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da75a1c070e9bd9a2c4a4023bc3d104e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da75a1c070e9bd9a2c4a4023bc3d104e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da75a1c070e9bd9a2c4a4023bc3d104e = L.map(
#                 &quot;map_da75a1c070e9bd9a2c4a4023bc3d104e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22bfa85c29efb044ecaa4107a43000a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22bfa85c29efb044ecaa4107a43000a5.addTo(map_da75a1c070e9bd9a2c4a4023bc3d104e);
#
#
#             var marker_1687ba3b1e2a92699345b5938f57709e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_da75a1c070e9bd9a2c4a4023bc3d104e);
#
#
#         var popup_643c71580a65f4cb87d0768d752c036a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7df1e2f28ebe3ea46623edae6d8e1fb = $(`&lt;div id=&quot;html_f7df1e2f28ebe3ea46623edae6d8e1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_643c71580a65f4cb87d0768d752c036a.setContent(html_f7df1e2f28ebe3ea46623edae6d8e1fb);
#
#
#
#         marker_1687ba3b1e2a92699345b5938f57709e.bindPopup(popup_643c71580a65f4cb87d0768d752c036a)
#         ;
#
#
#
#
#             var marker_597f220cc9338bec630cfb0cc61d3846 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_da75a1c070e9bd9a2c4a4023bc3d104e);
#
#
#         var popup_84e7ae0e73c1e1965fd4ff12e6c7591b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6044ea4b62948cf897967d00bd05b30 = $(`&lt;div id=&quot;html_c6044ea4b62948cf897967d00bd05b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_84e7ae0e73c1e1965fd4ff12e6c7591b.setContent(html_c6044ea4b62948cf897967d00bd05b30);
#
#
#
#         marker_597f220cc9338bec630cfb0cc61d3846.bindPopup(popup_84e7ae0e73c1e1965fd4ff12e6c7591b)
#         ;
#
#
#
#
#             var marker_3ea1e74b7780465b18e69902c3c43250 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_da75a1c070e9bd9a2c4a4023bc3d104e);
#
#
#         var popup_384fe832f386d13a67a3ec93f112c465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_061702667810eb71b6971a09bf31dffd = $(`&lt;div id=&quot;html_061702667810eb71b6971a09bf31dffd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_384fe832f386d13a67a3ec93f112c465.setContent(html_061702667810eb71b6971a09bf31dffd);
#
#
#
#         marker_3ea1e74b7780465b18e69902c3c43250.bindPopup(popup_384fe832f386d13a67a3ec93f112c465)
#         ;
#
#
#
#
#             var marker_065ca4cdb2e623677a1948211d7089e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_da75a1c070e9bd9a2c4a4023bc3d104e);
#
#
#         var popup_eeaf0a0cb7fa5c271edbdf1202aad85d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_017e97a2cbdc6fe82ba638940f462222 = $(`&lt;div id=&quot;html_017e97a2cbdc6fe82ba638940f462222&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eeaf0a0cb7fa5c271edbdf1202aad85d.setContent(html_017e97a2cbdc6fe82ba638940f462222);
#
#
#
#         marker_065ca4cdb2e623677a1948211d7089e6.bindPopup(popup_eeaf0a0cb7fa5c271edbdf1202aad85d)
#         ;
#
#
#
#
#             var marker_c63afeb05c7bd1bc5971ebff48cdbb5d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_da75a1c070e9bd9a2c4a4023bc3d104e);
#
#
#         var popup_eb127cbf593e12c3925ead2b64dc6fb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1c3b307eee072760efb0c182ca05cae = $(`&lt;div id=&quot;html_a1c3b307eee072760efb0c182ca05cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eb127cbf593e12c3925ead2b64dc6fb3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff0d85a900a81193bb9ec2c4bdc38e34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff0d85a900a81193bb9ec2c4bdc38e34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff0d85a900a81193bb9ec2c4bdc38e34 = L.map(
#                 &quot;map_ff0d85a900a81193bb9ec2c4bdc38e34&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5ae8da064b6dff4966ecaada32a348b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5ae8da064b6dff4966ecaada32a348b.addTo(map_ff0d85a900a81193bb9ec2c4bdc38e34);
#
#
#             var feature_group_808474cff7dd5a6e7a929795d5c62b4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f245fed8eba8b6d7f1b5c4860d5ad89 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_808474cff7dd5a6e7a929795d5c62b4c);
#
#
#         var popup_5097574cc708ef6bed4c471febf2fd48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d8c66845e6d41f8e7cc82a67bb9626a = $(`&lt;div id=&quot;html_2d8c66845e6d41f8e7cc82a67bb9626a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5097574cc708ef6bed4c471febf2fd48.setContent(html_2d8c66845e6d41f8e7cc82a67bb9626a);
#
#
#
#         marker_8f245fed8eba8b6d7f1b5c4860d5ad89.bindPopup(popup_5097574cc708ef6bed4c471febf2fd48)
#         ;
#
#
#
#
#             var marker_c1fe651694ce25cb3d95cf1a7c1d7ad2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_808474cff7dd5a6e7a929795d5c62b4c);
#
#
#         var popup_9221a9c648e58304a41c6e432d6a2589 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a64a5fed3938499ce4dd65eccd22583 = $(`&lt;div id=&quot;html_5a64a5fed3938499ce4dd65eccd22583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9221a9c648e58304a41c6e432d6a2589.setContent(html_5a64a5fed3938499ce4dd65eccd22583);
#
#
#
#         marker_c1fe651694ce25cb3d95cf1a7c1d7ad2.bindPopup(popup_9221a9c648e58304a41c6e432d6a2589)
#         ;
#
#
#
#
#             var marker_51672b15b63370d8d14b19172194584a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_808474cff7dd5a6e7a929795d5c62b4c);
#
#
#         var popup_8b108a10e4b0a5b891d27ffe2fb344c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da566ced1f6a7f84a1f755fbdd491174 = $(`&lt;div id=&quot;html_da566ced1f6a7f84a1f755fbdd491174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8b108a10e4b0a5b891d27ffe2fb344c6.setContent(html_da566ced1f6a7f84a1f755fbdd491174);
#
#
#
#         marker_51672b15b63370d8d14b19172194584a.bindPopup(popup_8b108a10e4b0a5b891d27ffe2fb344c6)
#         ;
#
#
#
#
#             var marker_e8069d4ed0d8b820456861e85cfbe93d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_808474cff7dd5a6e7a929795d5c62b4c);
#
#
#         var popup_8cba2252de110e0b7d3891c16f792e25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_907df85c21cbd1ddaf9b4af6cd3e6234 = $(`&lt;div id=&quot;html_907df85c21cbd1ddaf9b4af6cd3e6234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8cba2252de110e0b7d3891c16f792e25.setContent(html_907df85c21cbd1ddaf9b4af6cd3e6234);
#
#
#
#         marker_e8069d4ed0d8b820456861e85cfbe93d.bindPopup(popup_8cba2252de110e0b7d3891c16f792e25)
#         ;
#
#
#
#
#             var marker_06f02483c6aa557989706ffb7720d6de = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_808474cff7dd5a6e7a929795d5c62b4c);
#
#
#         var popup_087a90c12bd05975ef3e063f0c74d7d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c418e7c70726ae7e7857a4316416761c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c418e7c70726ae7e7857a4316416761c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c418e7c70726ae7e7857a4316416761c = L.map(
#                 &quot;map_c418e7c70726ae7e7857a4316416761c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a849e3c68ac17a059dea45a0510a6c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a849e3c68ac17a059dea45a0510a6c8.addTo(map_c418e7c70726ae7e7857a4316416761c);
#
#
#             var feature_group_56b3b65114170238ca68b9c47104e9e6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_56b3b65114170238ca68b9c47104e9e6.addTo(map_c418e7c70726ae7e7857a4316416761c);
#
#
#             var feature_group_sub_group_01309300c67cfefc7f895e4f708aec94 = L.featureGroup.subGroup(
#                 feature_group_56b3b65114170238ca68b9c47104e9e6
#             );
#
#
#             var marker_68856f87d30778ad56da17f458088fd5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_01309300c67cfefc7f895e4f708aec94);
#
#
#         var popup_e886a8802735fb224a06699aa5cb5aa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6f2cd33ae8f6074316c78c6b060b711 = $(`&lt;div id=&quot;html_e6f2cd33ae8f6074316c78c6b060b711&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e886a8802735fb224a06699aa5cb5aa0.setContent(html_e6f2cd33ae8f6074316c78c6b060b711);
#
#
#
#         marker_68856f87d30778ad56da17f458088fd5.bindPopup(popup_e886a8802735fb224a06699aa5cb5aa0)
#         ;
#
#
#
#
#             var marker_8f5fe5c97bf1c918cc00108a0f027fdd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_01309300c67cfefc7f895e4f708aec94);
#
#
#         var popup_ac2b61b59e5e17dda7cb58cbc10ead45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0888e2e509f973d47630e8ada524c7b = $(`&lt;div id=&quot;html_c0888e2e509f973d47630e8ada524c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ac2b61b59e5e17dda7cb58cbc10ead45.setContent(html_c0888e2e509f973d47630e8ada524c7b);
#
#
#
#         marker_8f5fe5c97bf1c918cc00108a0f027fdd.bindPopup(popup_ac2b61b59e5e17dda7cb58cbc10ead45)
#         ;
#
#
#
#
#             var marker_cfb727e214c6f717a2b28d3fc5a884ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_01309300c67cfefc7f895e4f708aec94);
#
#
#         var popup_56edcca78e1634842cbd6c7d4c7f6290 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0beff109aa818f95326a811b8f83de0d = $(`&lt;div id=&quot;html_0beff109aa818f95326a811b8f83de0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_56edcca78e1634842cbd6c7d4c7f6290.setContent(html_0beff109aa818f95326a811b8f83de0d);
#
#
#
#         marker_cfb727e214c6f717a2b28d3fc5a884ff.bindPopup(popup_56edcca78e1634842cbd6c7d4c7f6290)
#         ;
#
#
#
#
#             var marker_e9c81d1d2d7f177ea9d3375498fa2352 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_01309300c67cfefc7f895e4f708aec94);
#
#
#         var popup_77690bb97ff2fa3c02384368073c7a61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c11aa2fac0a6c3bc5ffd349826b9f08 = $(`&lt;div id=&quot;html_0c11aa2fac0a6c3bc5ffd349826b9f08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_77690bb97ff2fa3c02384368073c7a61.setContent(html_0c11aa2fac0a6c3bc5ffd349826b9f08);
#
#
#
#         marker_
