# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ec633c6a48f93e984d71d35f4ab180e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ec633c6a48f93e984d71d35f4ab180e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ec633c6a48f93e984d71d35f4ab180e = L.map(
#                 &quot;map_4ec633c6a48f93e984d71d35f4ab180e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5eccf1d7b7dd8c21f3853568b7df555 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5eccf1d7b7dd8c21f3853568b7df555.addTo(map_4ec633c6a48f93e984d71d35f4ab180e);
#
#
#             var marker_359c78e815c628541a2b9a7ed4da4f17 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4ec633c6a48f93e984d71d35f4ab180e);
#
#
#         var popup_af6389d166afa74a86ed6932bbefcf48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e84be2fe5f7840ba47af022b5256baa = $(`&lt;div id=&quot;html_4e84be2fe5f7840ba47af022b5256baa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_af6389d166afa74a86ed6932bbefcf48.setContent(html_4e84be2fe5f7840ba47af022b5256baa);
#
#
#
#         marker_359c78e815c628541a2b9a7ed4da4f17.bindPopup(popup_af6389d166afa74a86ed6932bbefcf48)
#         ;
#
#
#
#
#             var marker_6833d349c87953739ba70ad2f3cad1c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4ec633c6a48f93e984d71d35f4ab180e);
#
#
#         var popup_27aaac976040f1134acbc8ef7d985de0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96778bfa9c7a614627be69ba7a03144c = $(`&lt;div id=&quot;html_96778bfa9c7a614627be69ba7a03144c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_27aaac976040f1134acbc8ef7d985de0.setContent(html_96778bfa9c7a614627be69ba7a03144c);
#
#
#
#         marker_6833d349c87953739ba70ad2f3cad1c2.bindPopup(popup_27aaac976040f1134acbc8ef7d985de0)
#         ;
#
#
#
#
#             var marker_de2d6212708af7fde45a9a25f0dbdafa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4ec633c6a48f93e984d71d35f4ab180e);
#
#
#         var popup_3619202e3ebdecfc205147e899268848 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf22315e23b6e98e8d45b186242bbdf6 = $(`&lt;div id=&quot;html_cf22315e23b6e98e8d45b186242bbdf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3619202e3ebdecfc205147e899268848.setContent(html_cf22315e23b6e98e8d45b186242bbdf6);
#
#
#
#         marker_de2d6212708af7fde45a9a25f0dbdafa.bindPopup(popup_3619202e3ebdecfc205147e899268848)
#         ;
#
#
#
#
#             var marker_902f887505116e7a625abe65f29c2067 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4ec633c6a48f93e984d71d35f4ab180e);
#
#
#         var popup_24b793266919480185240645c11cbd7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5fa0e17dce416d207d5ef8d067cad3f = $(`&lt;div id=&quot;html_e5fa0e17dce416d207d5ef8d067cad3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_24b793266919480185240645c11cbd7c.setContent(html_e5fa0e17dce416d207d5ef8d067cad3f);
#
#
#
#         marker_902f887505116e7a625abe65f29c2067.bindPopup(popup_24b793266919480185240645c11cbd7c)
#         ;
#
#
#
#
#             var marker_97cb58874103dcc184adce532b165eff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4ec633c6a48f93e984d71d35f4ab180e);
#
#
#         var popup_7c57f4c21433c1df2189453e18869bbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cdff7553eb54792d73f8110a3bb8a4d = $(`&lt;div id=&quot;html_9cdff7553eb54792d73f8110a3bb8a4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c57f4c21433c1df2189453e18869b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f12027b9b727f86b0467e44a3cd171 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f12027b9b727f86b0467e44a3cd171&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f12027b9b727f86b0467e44a3cd171 = L.map(
#                 &quot;map_29f12027b9b727f86b0467e44a3cd171&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6379da732de14b7f41ba672f4cb68daa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6379da732de14b7f41ba672f4cb68daa.addTo(map_29f12027b9b727f86b0467e44a3cd171);
#
#
#             var feature_group_b35bf337c1b0f2f5c2bb6f9fa35d460e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4316b8d1c4d624d6e743b38fc689798b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b35bf337c1b0f2f5c2bb6f9fa35d460e);
#
#
#         var popup_a38c6873ea4f086f6720083dab89c9d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6ebf0ad8ea0c695c17c6eb232836d30 = $(`&lt;div id=&quot;html_e6ebf0ad8ea0c695c17c6eb232836d30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a38c6873ea4f086f6720083dab89c9d4.setContent(html_e6ebf0ad8ea0c695c17c6eb232836d30);
#
#
#
#         marker_4316b8d1c4d624d6e743b38fc689798b.bindPopup(popup_a38c6873ea4f086f6720083dab89c9d4)
#         ;
#
#
#
#
#             var marker_2b02af214be2a0b1cfc103e46f668c0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b35bf337c1b0f2f5c2bb6f9fa35d460e);
#
#
#         var popup_bdf693de6426275a1c1c5cd343eab68e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71243a2f568966900a68fbcb888fb4e6 = $(`&lt;div id=&quot;html_71243a2f568966900a68fbcb888fb4e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bdf693de6426275a1c1c5cd343eab68e.setContent(html_71243a2f568966900a68fbcb888fb4e6);
#
#
#
#         marker_2b02af214be2a0b1cfc103e46f668c0b.bindPopup(popup_bdf693de6426275a1c1c5cd343eab68e)
#         ;
#
#
#
#
#             var marker_f2d8eda4f2c66dcdc531af4a3c84681c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b35bf337c1b0f2f5c2bb6f9fa35d460e);
#
#
#         var popup_608d0f93b8a4d835d26cfd81b6b5c333 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49c79032a96f581a0ef7ba4158406cc1 = $(`&lt;div id=&quot;html_49c79032a96f581a0ef7ba4158406cc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_608d0f93b8a4d835d26cfd81b6b5c333.setContent(html_49c79032a96f581a0ef7ba4158406cc1);
#
#
#
#         marker_f2d8eda4f2c66dcdc531af4a3c84681c.bindPopup(popup_608d0f93b8a4d835d26cfd81b6b5c333)
#         ;
#
#
#
#
#             var marker_70af0fb0e17df89138b361b443507144 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b35bf337c1b0f2f5c2bb6f9fa35d460e);
#
#
#         var popup_75c6bd7098d7c835727a0b45bc3d307c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc13d4e68b4433d3d68e6543d1ce6aaa = $(`&lt;div id=&quot;html_dc13d4e68b4433d3d68e6543d1ce6aaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_75c6bd7098d7c835727a0b45bc3d307c.setContent(html_dc13d4e68b4433d3d68e6543d1ce6aaa);
#
#
#
#         marker_70af0fb0e17df89138b361b443507144.bindPopup(popup_75c6bd7098d7c835727a0b45bc3d307c)
#         ;
#
#
#
#
#             var marker_5fc1650aa0b03f079d0f8b79101a3ae5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b35bf337c1b0f2f5c2bb6f9fa35d460e);
#
#
#         var popup_89a06af97066307c349449a933c9b259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c4dad5b0722dce3e1c4f4b9fe17a48b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c4dad5b0722dce3e1c4f4b9fe17a48b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c4dad5b0722dce3e1c4f4b9fe17a48b = L.map(
#                 &quot;map_2c4dad5b0722dce3e1c4f4b9fe17a48b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61c48b881f0ae869ab5d81c576c3edd6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61c48b881f0ae869ab5d81c576c3edd6.addTo(map_2c4dad5b0722dce3e1c4f4b9fe17a48b);
#
#
#             var feature_group_efaa245fc0cb766075a8d78024cf61c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_efaa245fc0cb766075a8d78024cf61c8.addTo(map_2c4dad5b0722dce3e1c4f4b9fe17a48b);
#
#
#             var feature_group_sub_group_fa84a32bd08b114041971b155a44b1ab = L.featureGroup.subGroup(
#                 feature_group_efaa245fc0cb766075a8d78024cf61c8
#             );
#
#
#             var marker_98f5ac07754bf5152c306698e777d695 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa84a32bd08b114041971b155a44b1ab);
#
#
#         var popup_1874d19d3adafeb6a68633711e360213 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2201194d7d43fdce5cc4ee832bdd739 = $(`&lt;div id=&quot;html_c2201194d7d43fdce5cc4ee832bdd739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1874d19d3adafeb6a68633711e360213.setContent(html_c2201194d7d43fdce5cc4ee832bdd739);
#
#
#
#         marker_98f5ac07754bf5152c306698e777d695.bindPopup(popup_1874d19d3adafeb6a68633711e360213)
#         ;
#
#
#
#
#             var marker_37a81841d16a721e1cf88dad0486e6a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa84a32bd08b114041971b155a44b1ab);
#
#
#         var popup_20bb90efaee6e9b20dc88c673fd0b683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71efb6ff63d5f8fb9eaab120615dd60e = $(`&lt;div id=&quot;html_71efb6ff63d5f8fb9eaab120615dd60e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_20bb90efaee6e9b20dc88c673fd0b683.setContent(html_71efb6ff63d5f8fb9eaab120615dd60e);
#
#
#
#         marker_37a81841d16a721e1cf88dad0486e6a1.bindPopup(popup_20bb90efaee6e9b20dc88c673fd0b683)
#         ;
#
#
#
#
#             var marker_ceaf25a61f37c61158cb86fa1a2622bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa84a32bd08b114041971b155a44b1ab);
#
#
#         var popup_a8f0f93e2c2c2cb00b3cad465c260b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e0242cda2424c67c8e08bcd2360199 = $(`&lt;div id=&quot;html_b0e0242cda2424c67c8e08bcd2360199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a8f0f93e2c2c2cb00b3cad465c260b1d.setContent(html_b0e0242cda2424c67c8e08bcd2360199);
#
#
#
#         marker_ceaf25a61f37c61158cb86fa1a2622bc.bindPopup(popup_a8f0f93e2c2c2cb00b3cad465c260b1d)
#         ;
#
#
#
#
#             var marker_8ddf3f1472ecde5a05d4339db99319b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa84a32bd08b114041971b155a44b1ab);
#
#
#         var popup_b0d5d0e6d84365387331b38a8d701fdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32e5af46e69bcf80a1d8d635b707d20a = $(`&lt;div id=&quot;html_32e5af46e69bcf80a1d8d635b707d20a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b0d5d0e6d84365387331b38a8d701fdb.setContent(html_32e5af46e69bcf80a1d8d635b707d20a);
#
#
#
#         mark
