# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fa718be45bf4a4c6bb24518161f6df2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fa718be45bf4a4c6bb24518161f6df2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fa718be45bf4a4c6bb24518161f6df2 = L.map(
#                 &quot;map_1fa718be45bf4a4c6bb24518161f6df2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_968b182f608682961a09d1d3abe00007 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_968b182f608682961a09d1d3abe00007.addTo(map_1fa718be45bf4a4c6bb24518161f6df2);
#
#
#             var marker_c0361f6ff2fcca4a7b42e45d3ff6923f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1fa718be45bf4a4c6bb24518161f6df2);
#
#
#         var popup_f1806d9fe4d46e115f50fda22e99f64f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97e3512054b92a59f75b6f845569bbba = $(`&lt;div id=&quot;html_97e3512054b92a59f75b6f845569bbba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f1806d9fe4d46e115f50fda22e99f64f.setContent(html_97e3512054b92a59f75b6f845569bbba);
#
#
#
#         marker_c0361f6ff2fcca4a7b42e45d3ff6923f.bindPopup(popup_f1806d9fe4d46e115f50fda22e99f64f)
#         ;
#
#
#
#
#             var marker_f8239f0b84f7acc0fa5eaac0b7f42388 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1fa718be45bf4a4c6bb24518161f6df2);
#
#
#         var popup_3155586b296a848cdd4eb17462b3f858 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b2e90ee91d53bd417df84b1c99d18c5 = $(`&lt;div id=&quot;html_1b2e90ee91d53bd417df84b1c99d18c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3155586b296a848cdd4eb17462b3f858.setContent(html_1b2e90ee91d53bd417df84b1c99d18c5);
#
#
#
#         marker_f8239f0b84f7acc0fa5eaac0b7f42388.bindPopup(popup_3155586b296a848cdd4eb17462b3f858)
#         ;
#
#
#
#
#             var marker_825b3b2018ca651a5ba2923bd9c33992 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1fa718be45bf4a4c6bb24518161f6df2);
#
#
#         var popup_899c1a88a0e5bb674b6894275e8dc922 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d911c09bcf85e55b2e0f610ba515353 = $(`&lt;div id=&quot;html_4d911c09bcf85e55b2e0f610ba515353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_899c1a88a0e5bb674b6894275e8dc922.setContent(html_4d911c09bcf85e55b2e0f610ba515353);
#
#
#
#         marker_825b3b2018ca651a5ba2923bd9c33992.bindPopup(popup_899c1a88a0e5bb674b6894275e8dc922)
#         ;
#
#
#
#
#             var marker_6fd3d2c850d7926ec5b80dd3f12b6c57 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1fa718be45bf4a4c6bb24518161f6df2);
#
#
#         var popup_f3266fa83f688aa6cdc67bf2534fbc50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_805257455da9188fc6c85bcae234a5ea = $(`&lt;div id=&quot;html_805257455da9188fc6c85bcae234a5ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f3266fa83f688aa6cdc67bf2534fbc50.setContent(html_805257455da9188fc6c85bcae234a5ea);
#
#
#
#         marker_6fd3d2c850d7926ec5b80dd3f12b6c57.bindPopup(popup_f3266fa83f688aa6cdc67bf2534fbc50)
#         ;
#
#
#
#
#             var marker_c94359f194a8b23c9500f3f39b41ee59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1fa718be45bf4a4c6bb24518161f6df2);
#
#
#         var popup_5d05fe3c667f92fb27de67ae0de557e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e4bdad1d1096b80ee9ca948e4c0ad6d = $(`&lt;div id=&quot;html_7e4bdad1d1096b80ee9ca948e4c0ad6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5d05fe3c667f92fb27de67ae0de557e0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06b972c142184df6c751d0896e9e6480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06b972c142184df6c751d0896e9e6480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06b972c142184df6c751d0896e9e6480 = L.map(
#                 &quot;map_06b972c142184df6c751d0896e9e6480&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9818d2269d2d5b385f07d89bd66ad810 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9818d2269d2d5b385f07d89bd66ad810.addTo(map_06b972c142184df6c751d0896e9e6480);
#
#
#             var feature_group_c02245182d19a495efec291f9e141a6d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b1f39e0dc49bca899b138316a5d489ed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c02245182d19a495efec291f9e141a6d);
#
#
#         var popup_cfa4193dbbeae84b8452db7ef97a2a53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bfc631d1513ce4b7d570462ed7919fd = $(`&lt;div id=&quot;html_3bfc631d1513ce4b7d570462ed7919fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cfa4193dbbeae84b8452db7ef97a2a53.setContent(html_3bfc631d1513ce4b7d570462ed7919fd);
#
#
#
#         marker_b1f39e0dc49bca899b138316a5d489ed.bindPopup(popup_cfa4193dbbeae84b8452db7ef97a2a53)
#         ;
#
#
#
#
#             var marker_0d89569a85d7387dcbf7f314e2001dbf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c02245182d19a495efec291f9e141a6d);
#
#
#         var popup_711586711a7afb7ee26127fb4e43a434 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77cbff0a19a027a55d9d204ac37bafc5 = $(`&lt;div id=&quot;html_77cbff0a19a027a55d9d204ac37bafc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_711586711a7afb7ee26127fb4e43a434.setContent(html_77cbff0a19a027a55d9d204ac37bafc5);
#
#
#
#         marker_0d89569a85d7387dcbf7f314e2001dbf.bindPopup(popup_711586711a7afb7ee26127fb4e43a434)
#         ;
#
#
#
#
#             var marker_4b09f298cf9a677a292ecfe0599b341f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c02245182d19a495efec291f9e141a6d);
#
#
#         var popup_12ead00bd932c1d99fd5acc04506b57d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47a282786e8b543c7a1ec0a4e73a02ff = $(`&lt;div id=&quot;html_47a282786e8b543c7a1ec0a4e73a02ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_12ead00bd932c1d99fd5acc04506b57d.setContent(html_47a282786e8b543c7a1ec0a4e73a02ff);
#
#
#
#         marker_4b09f298cf9a677a292ecfe0599b341f.bindPopup(popup_12ead00bd932c1d99fd5acc04506b57d)
#         ;
#
#
#
#
#             var marker_a2c60d2cc7274a233db9ac103b6e5bf7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c02245182d19a495efec291f9e141a6d);
#
#
#         var popup_01e949255f35772e84f2cc93640bcd4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_711d27a7c620894d7f967854a2dac182 = $(`&lt;div id=&quot;html_711d27a7c620894d7f967854a2dac182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_01e949255f35772e84f2cc93640bcd4f.setContent(html_711d27a7c620894d7f967854a2dac182);
#
#
#
#         marker_a2c60d2cc7274a233db9ac103b6e5bf7.bindPopup(popup_01e949255f35772e84f2cc93640bcd4f)
#         ;
#
#
#
#
#             var marker_e398b4c0bbfe5705257228d593351ac5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c02245182d19a495efec291f9e141a6d);
#
#
#         var popup_d36f25e2707271a27d9b76f259b02600 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a473517d4f678dc0ee8e627cc28f4b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a473517d4f678dc0ee8e627cc28f4b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a473517d4f678dc0ee8e627cc28f4b3 = L.map(
#                 &quot;map_0a473517d4f678dc0ee8e627cc28f4b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5c5eb8d26d12bf0a5c31d67e582ada7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5c5eb8d26d12bf0a5c31d67e582ada7.addTo(map_0a473517d4f678dc0ee8e627cc28f4b3);
#
#
#             var feature_group_2070116989434f847a92cfdceaef2dfa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2070116989434f847a92cfdceaef2dfa.addTo(map_0a473517d4f678dc0ee8e627cc28f4b3);
#
#
#             var feature_group_sub_group_83b930f1dc91e121a306e30df2db1b1e = L.featureGroup.subGroup(
#                 feature_group_2070116989434f847a92cfdceaef2dfa
#             );
#
#
#             var marker_6ee6dfc2c188091a69a500d1c7d0964f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_83b930f1dc91e121a306e30df2db1b1e);
#
#
#         var popup_e04ffc2d50371cf07780be624f6c720e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b830482cebcbff9da54195bcaa626cb3 = $(`&lt;div id=&quot;html_b830482cebcbff9da54195bcaa626cb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e04ffc2d50371cf07780be624f6c720e.setContent(html_b830482cebcbff9da54195bcaa626cb3);
#
#
#
#         marker_6ee6dfc2c188091a69a500d1c7d0964f.bindPopup(popup_e04ffc2d50371cf07780be624f6c720e)
#         ;
#
#
#
#
#             var marker_ecf9f6562fde6b7c0e873ab12d9c683c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_83b930f1dc91e121a306e30df2db1b1e);
#
#
#         var popup_784bb5e40ba335b855fdb39e34e1a5a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b0052dfdbd36df88f3f05d0a71c26c7 = $(`&lt;div id=&quot;html_6b0052dfdbd36df88f3f05d0a71c26c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_784bb5e40ba335b855fdb39e34e1a5a9.setContent(html_6b0052dfdbd36df88f3f05d0a71c26c7);
#
#
#
#         marker_ecf9f6562fde6b7c0e873ab12d9c683c.bindPopup(popup_784bb5e40ba335b855fdb39e34e1a5a9)
#         ;
#
#
#
#
#             var marker_0732d5daa466e1e44271166940934eaf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_83b930f1dc91e121a306e30df2db1b1e);
#
#
#         var popup_19945530332598c9a7a9067c533cea31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7b6c1078002a966790e94035d0384e8 = $(`&lt;div id=&quot;html_f7b6c1078002a966790e94035d0384e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_19945530332598c9a7a9067c533cea31.setContent(html_f7b6c1078002a966790e94035d0384e8);
#
#
#
#         marker_0732d5daa466e1e44271166940934eaf.bindPopup(popup_19945530332598c9a7a9067c533cea31)
#         ;
#
#
#
#
#             var marker_d71069b69f15435ca44c0b59e902c9a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_83b930f1dc91e121a306e30df2db1b1e);
#
#
#         var popup_68d7457deaf9d8c8935f49f979a7ee2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f36a8c900b61dd9b99ffd1ebbe00366 = $(`&lt;div id=&quot;html_2f36a8c900b61dd9b99ffd1ebbe00366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_68d7457deaf9d8c8935f49f979a7ee2c.setContent(html_2f36a8c900b61dd9b99ffd1ebbe00366);
#
#
#
#         marker_
