# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ae7cd8eb754e2257420cef3af5db5f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ae7cd8eb754e2257420cef3af5db5f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ae7cd8eb754e2257420cef3af5db5f5 = L.map(
#                 &quot;map_3ae7cd8eb754e2257420cef3af5db5f5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f3376aa25e52dba36d4e6a193556cfa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f3376aa25e52dba36d4e6a193556cfa.addTo(map_3ae7cd8eb754e2257420cef3af5db5f5);
#
#
#             var marker_a9cd00ae529316ab6380f65a077d7485 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3ae7cd8eb754e2257420cef3af5db5f5);
#
#
#         var popup_e8784cc9fbb2ae596423c39f21e192ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a86adb088bf4188461399d04b191e93 = $(`&lt;div id=&quot;html_5a86adb088bf4188461399d04b191e93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e8784cc9fbb2ae596423c39f21e192ec.setContent(html_5a86adb088bf4188461399d04b191e93);
#
#
#
#         marker_a9cd00ae529316ab6380f65a077d7485.bindPopup(popup_e8784cc9fbb2ae596423c39f21e192ec)
#         ;
#
#
#
#
#             var marker_8b1de2838a53b6dc885587c4f7666ae6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3ae7cd8eb754e2257420cef3af5db5f5);
#
#
#         var popup_189b79260116385a54d83d0ccc059492 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00a0f6d735e100f1463beeb607fd6d1b = $(`&lt;div id=&quot;html_00a0f6d735e100f1463beeb607fd6d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_189b79260116385a54d83d0ccc059492.setContent(html_00a0f6d735e100f1463beeb607fd6d1b);
#
#
#
#         marker_8b1de2838a53b6dc885587c4f7666ae6.bindPopup(popup_189b79260116385a54d83d0ccc059492)
#         ;
#
#
#
#
#             var marker_536af438ad0770ea5f871885fcabac51 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3ae7cd8eb754e2257420cef3af5db5f5);
#
#
#         var popup_7b7401923caced6aae13fa09c0faef00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_405676dfeebad83047e8bdcacb618291 = $(`&lt;div id=&quot;html_405676dfeebad83047e8bdcacb618291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7b7401923caced6aae13fa09c0faef00.setContent(html_405676dfeebad83047e8bdcacb618291);
#
#
#
#         marker_536af438ad0770ea5f871885fcabac51.bindPopup(popup_7b7401923caced6aae13fa09c0faef00)
#         ;
#
#
#
#
#             var marker_4a7f5e89ad26c73b2688eb35df3274b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3ae7cd8eb754e2257420cef3af5db5f5);
#
#
#         var popup_9ecd9f675b286c8e520832197abdc95e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8691def263d460dd163b095af8982a5 = $(`&lt;div id=&quot;html_e8691def263d460dd163b095af8982a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9ecd9f675b286c8e520832197abdc95e.setContent(html_e8691def263d460dd163b095af8982a5);
#
#
#
#         marker_4a7f5e89ad26c73b2688eb35df3274b1.bindPopup(popup_9ecd9f675b286c8e520832197abdc95e)
#         ;
#
#
#
#
#             var marker_81622ac9bfd075ea20daa0ee976aa6e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3ae7cd8eb754e2257420cef3af5db5f5);
#
#
#         var popup_22bdf3ac55891646913c7e1b84c9f05e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ba678bed8e037fb6dd9d71df27bd7ea = $(`&lt;div id=&quot;html_9ba678bed8e037fb6dd9d71df27bd7ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_22bdf3ac55891646913c7e1b84c9f05e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdfbc93215c63ef12b0a195fcf2c8737 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdfbc93215c63ef12b0a195fcf2c8737&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdfbc93215c63ef12b0a195fcf2c8737 = L.map(
#                 &quot;map_bdfbc93215c63ef12b0a195fcf2c8737&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e0d7d4dda4119ce3b9cd249633f0ff1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e0d7d4dda4119ce3b9cd249633f0ff1.addTo(map_bdfbc93215c63ef12b0a195fcf2c8737);
#
#
#             var feature_group_0730d665a57858841acb37df9138aad7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4cf537f29dc9cb2fb7ac50faac62b6d3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0730d665a57858841acb37df9138aad7);
#
#
#         var popup_f40ab17a6fbef875b140a7cdf9963c19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b407c7d32f320de6b53bb7db8d280d1 = $(`&lt;div id=&quot;html_5b407c7d32f320de6b53bb7db8d280d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f40ab17a6fbef875b140a7cdf9963c19.setContent(html_5b407c7d32f320de6b53bb7db8d280d1);
#
#
#
#         marker_4cf537f29dc9cb2fb7ac50faac62b6d3.bindPopup(popup_f40ab17a6fbef875b140a7cdf9963c19)
#         ;
#
#
#
#
#             var marker_235822f4ed3f18143ba9c4066b8f755c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0730d665a57858841acb37df9138aad7);
#
#
#         var popup_ae72fca7c9dcef1283406164f6a0c90d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43ed0c3b5d752d13bf57a6648cb20c32 = $(`&lt;div id=&quot;html_43ed0c3b5d752d13bf57a6648cb20c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ae72fca7c9dcef1283406164f6a0c90d.setContent(html_43ed0c3b5d752d13bf57a6648cb20c32);
#
#
#
#         marker_235822f4ed3f18143ba9c4066b8f755c.bindPopup(popup_ae72fca7c9dcef1283406164f6a0c90d)
#         ;
#
#
#
#
#             var marker_9361e3ddf59b1d62bbb1ac4fe188b938 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0730d665a57858841acb37df9138aad7);
#
#
#         var popup_63d93fc751ff608c3c6be8b93264c8d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80a9ebef365f7cba3bf32202b431a544 = $(`&lt;div id=&quot;html_80a9ebef365f7cba3bf32202b431a544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_63d93fc751ff608c3c6be8b93264c8d4.setContent(html_80a9ebef365f7cba3bf32202b431a544);
#
#
#
#         marker_9361e3ddf59b1d62bbb1ac4fe188b938.bindPopup(popup_63d93fc751ff608c3c6be8b93264c8d4)
#         ;
#
#
#
#
#             var marker_ffd85328430c665ddbf1caa47692bd80 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0730d665a57858841acb37df9138aad7);
#
#
#         var popup_2d65b3854c142f64d7419ef1346ff904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a1d481b8b96b37685d5df110e706d78 = $(`&lt;div id=&quot;html_6a1d481b8b96b37685d5df110e706d78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2d65b3854c142f64d7419ef1346ff904.setContent(html_6a1d481b8b96b37685d5df110e706d78);
#
#
#
#         marker_ffd85328430c665ddbf1caa47692bd80.bindPopup(popup_2d65b3854c142f64d7419ef1346ff904)
#         ;
#
#
#
#
#             var marker_8608c7334dcf0268f56ee5b5a523d268 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0730d665a57858841acb37df9138aad7);
#
#
#         var popup_e9177ef35c8e5db75d4ebb4c5abbf54e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68de8712b03e471f6b4af8360500997d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68de8712b03e471f6b4af8360500997d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68de8712b03e471f6b4af8360500997d = L.map(
#                 &quot;map_68de8712b03e471f6b4af8360500997d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7396e285061726624645bdf59cc775fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7396e285061726624645bdf59cc775fb.addTo(map_68de8712b03e471f6b4af8360500997d);
#
#
#             var feature_group_f39946948063075e53c9c66fbc937cdd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f39946948063075e53c9c66fbc937cdd.addTo(map_68de8712b03e471f6b4af8360500997d);
#
#
#             var feature_group_sub_group_7e5cff0f69ac3051a3e1e49fb665b804 = L.featureGroup.subGroup(
#                 feature_group_f39946948063075e53c9c66fbc937cdd
#             );
#
#
#             var marker_63f2fffc594a2e8a6b34b4adf62c5e93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e5cff0f69ac3051a3e1e49fb665b804);
#
#
#         var popup_d462b5c775b7ba0c1dbe426defa3ff7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3ed0b7a91e15833aac28d513492dbb6 = $(`&lt;div id=&quot;html_e3ed0b7a91e15833aac28d513492dbb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d462b5c775b7ba0c1dbe426defa3ff7f.setContent(html_e3ed0b7a91e15833aac28d513492dbb6);
#
#
#
#         marker_63f2fffc594a2e8a6b34b4adf62c5e93.bindPopup(popup_d462b5c775b7ba0c1dbe426defa3ff7f)
#         ;
#
#
#
#
#             var marker_929b6d1487d00b2bbcff26255a65c355 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e5cff0f69ac3051a3e1e49fb665b804);
#
#
#         var popup_12bc6b0f481163485e2b609c262e4092 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b85bc5156b2bd0e0953e718d44a038f9 = $(`&lt;div id=&quot;html_b85bc5156b2bd0e0953e718d44a038f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_12bc6b0f481163485e2b609c262e4092.setContent(html_b85bc5156b2bd0e0953e718d44a038f9);
#
#
#
#         marker_929b6d1487d00b2bbcff26255a65c355.bindPopup(popup_12bc6b0f481163485e2b609c262e4092)
#         ;
#
#
#
#
#             var marker_2d0dc420c76918115fc6c5a06f700175 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e5cff0f69ac3051a3e1e49fb665b804);
#
#
#         var popup_a66a95496ddc0471a951f77319af69de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_850924c02b5bfd689a3a9e2fa1875e4a = $(`&lt;div id=&quot;html_850924c02b5bfd689a3a9e2fa1875e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a66a95496ddc0471a951f77319af69de.setContent(html_850924c02b5bfd689a3a9e2fa1875e4a);
#
#
#
#         marker_2d0dc420c76918115fc6c5a06f700175.bindPopup(popup_a66a95496ddc0471a951f77319af69de)
#         ;
#
#
#
#
#             var marker_a0105ab2e38e91785b3a21c84578013b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e5cff0f69ac3051a3e1e49fb665b804);
#
#
#         var popup_d26833714abf682b35137bf13b854dc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b24befa393c8be0af920ee2dfa89d79 = $(`&lt;div id=&quot;html_4b24befa393c8be0af920ee2dfa89d79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d26833714abf682b35137bf13b854dc3.setContent(html_4b24befa393c8be0af920ee2dfa89d79);
#
#
#
#         marker_
