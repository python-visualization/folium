# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d118f413ff09c8d493e3ccc22bd04089 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d118f413ff09c8d493e3ccc22bd04089&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d118f413ff09c8d493e3ccc22bd04089 = L.map(
#                 &quot;map_d118f413ff09c8d493e3ccc22bd04089&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_871eb46835cff0e52e6836139a175632 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_871eb46835cff0e52e6836139a175632.addTo(map_d118f413ff09c8d493e3ccc22bd04089);
#
#
#             var marker_c38655fba2933757dc37d958f3bb037a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d118f413ff09c8d493e3ccc22bd04089);
#
#
#         var popup_c072dda95063e95d68e24a7a8fc1ae58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_371a84e194df32f1137ff39208cea4a0 = $(`&lt;div id=&quot;html_371a84e194df32f1137ff39208cea4a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c072dda95063e95d68e24a7a8fc1ae58.setContent(html_371a84e194df32f1137ff39208cea4a0);
#
#
#
#         marker_c38655fba2933757dc37d958f3bb037a.bindPopup(popup_c072dda95063e95d68e24a7a8fc1ae58)
#         ;
#
#
#
#
#             var marker_6b4404acdd2b13c62e5c71e7a39caa0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d118f413ff09c8d493e3ccc22bd04089);
#
#
#         var popup_3e92fdd9ecf4d0c9ac051c81f2882920 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bcc07b5fad18efac3d59676159515d5 = $(`&lt;div id=&quot;html_4bcc07b5fad18efac3d59676159515d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3e92fdd9ecf4d0c9ac051c81f2882920.setContent(html_4bcc07b5fad18efac3d59676159515d5);
#
#
#
#         marker_6b4404acdd2b13c62e5c71e7a39caa0b.bindPopup(popup_3e92fdd9ecf4d0c9ac051c81f2882920)
#         ;
#
#
#
#
#             var marker_a18c1c621b12b023aa7fd7815826bfb6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d118f413ff09c8d493e3ccc22bd04089);
#
#
#         var popup_047553472fdddd0f3b5aab50722f02a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_597d328b00ac2bb158780f9bdd7d9aac = $(`&lt;div id=&quot;html_597d328b00ac2bb158780f9bdd7d9aac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_047553472fdddd0f3b5aab50722f02a6.setContent(html_597d328b00ac2bb158780f9bdd7d9aac);
#
#
#
#         marker_a18c1c621b12b023aa7fd7815826bfb6.bindPopup(popup_047553472fdddd0f3b5aab50722f02a6)
#         ;
#
#
#
#
#             var marker_dfdadbef909a7f6c865d3a464cd073e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d118f413ff09c8d493e3ccc22bd04089);
#
#
#         var popup_3e708877b6d218f0bc92f26c65c0483c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_303c6b5ca25039d8a896ffad0d5c4517 = $(`&lt;div id=&quot;html_303c6b5ca25039d8a896ffad0d5c4517&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3e708877b6d218f0bc92f26c65c0483c.setContent(html_303c6b5ca25039d8a896ffad0d5c4517);
#
#
#
#         marker_dfdadbef909a7f6c865d3a464cd073e4.bindPopup(popup_3e708877b6d218f0bc92f26c65c0483c)
#         ;
#
#
#
#
#             var marker_c7085aae423ed2254504cae7bed847e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d118f413ff09c8d493e3ccc22bd04089);
#
#
#         var popup_475cfc9e28a303404a7c218c7de589d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_035500418052b97183f02a76a84f5ac6 = $(`&lt;div id=&quot;html_035500418052b97183f02a76a84f5ac6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_475cfc9e28a303404a7c218c7de589

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a431eacfd9012549a1d2df5e522ba3d7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a431eacfd9012549a1d2df5e522ba3d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a431eacfd9012549a1d2df5e522ba3d7 = L.map(
#                 &quot;map_a431eacfd9012549a1d2df5e522ba3d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_424ecbcb7a939667369f57e92fb4e8ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_424ecbcb7a939667369f57e92fb4e8ef.addTo(map_a431eacfd9012549a1d2df5e522ba3d7);
#
#
#             var feature_group_52d6188d812e60811f995bccde93ddb0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_84bd0ff2eba0fbb55cbcacadf53c2c2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_52d6188d812e60811f995bccde93ddb0);
#
#
#         var popup_b8e0f7174dad8550591d14bc2e5afe35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ad888d37484df8b45ad3d9ca1fffac4 = $(`&lt;div id=&quot;html_4ad888d37484df8b45ad3d9ca1fffac4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b8e0f7174dad8550591d14bc2e5afe35.setContent(html_4ad888d37484df8b45ad3d9ca1fffac4);
#
#
#
#         marker_84bd0ff2eba0fbb55cbcacadf53c2c2a.bindPopup(popup_b8e0f7174dad8550591d14bc2e5afe35)
#         ;
#
#
#
#
#             var marker_95401ea4394e17f7702eea213e66bf50 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_52d6188d812e60811f995bccde93ddb0);
#
#
#         var popup_9a9153577e474388be2b9b0b4fe366a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48ac8f5cf91d21fa6b08488616d2cbdd = $(`&lt;div id=&quot;html_48ac8f5cf91d21fa6b08488616d2cbdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9a9153577e474388be2b9b0b4fe366a9.setContent(html_48ac8f5cf91d21fa6b08488616d2cbdd);
#
#
#
#         marker_95401ea4394e17f7702eea213e66bf50.bindPopup(popup_9a9153577e474388be2b9b0b4fe366a9)
#         ;
#
#
#
#
#             var marker_34337451023fbec58c8be698acd7f037 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_52d6188d812e60811f995bccde93ddb0);
#
#
#         var popup_3c27e7256181670deb98290c5b82d445 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b58d24587c52573055fb2613ac68f2e1 = $(`&lt;div id=&quot;html_b58d24587c52573055fb2613ac68f2e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3c27e7256181670deb98290c5b82d445.setContent(html_b58d24587c52573055fb2613ac68f2e1);
#
#
#
#         marker_34337451023fbec58c8be698acd7f037.bindPopup(popup_3c27e7256181670deb98290c5b82d445)
#         ;
#
#
#
#
#             var marker_2dd58361e569c7cfe087820dc9a973bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_52d6188d812e60811f995bccde93ddb0);
#
#
#         var popup_870be3cfa1c7e9bdbc1638656ec07dea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ae37c2789622a9a0a98f62dd90db641 = $(`&lt;div id=&quot;html_0ae37c2789622a9a0a98f62dd90db641&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_870be3cfa1c7e9bdbc1638656ec07dea.setContent(html_0ae37c2789622a9a0a98f62dd90db641);
#
#
#
#         marker_2dd58361e569c7cfe087820dc9a973bc.bindPopup(popup_870be3cfa1c7e9bdbc1638656ec07dea)
#         ;
#
#
#
#
#             var marker_7f66625620b6d2c4a2c132c2628d715e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_52d6188d812e60811f995bccde93ddb0);
#
#
#         var popup_1d4b20b2334efb449df2ed90a0bec2a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d199e87aa2beb88280b6c3e0a3e12d4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d199e87aa2beb88280b6c3e0a3e12d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d199e87aa2beb88280b6c3e0a3e12d4 = L.map(
#                 &quot;map_3d199e87aa2beb88280b6c3e0a3e12d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aeb3dc2eb2eaa352776fee9e91dc33dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aeb3dc2eb2eaa352776fee9e91dc33dc.addTo(map_3d199e87aa2beb88280b6c3e0a3e12d4);
#
#
#             var feature_group_0712c7d6aca3fce56228b0ea94cce704 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0712c7d6aca3fce56228b0ea94cce704.addTo(map_3d199e87aa2beb88280b6c3e0a3e12d4);
#
#
#             var feature_group_sub_group_6a6da87cec0ee2ca7a41fe92c0d0406c = L.featureGroup.subGroup(
#                 feature_group_0712c7d6aca3fce56228b0ea94cce704
#             );
#
#
#             var marker_f5ac7dbb005ac3bd6344a079f58e2819 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6da87cec0ee2ca7a41fe92c0d0406c);
#
#
#         var popup_60019bc4891e6ef1ea91b01ea88abfab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2af76ff26b797b9e46cd5b87606504f = $(`&lt;div id=&quot;html_d2af76ff26b797b9e46cd5b87606504f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_60019bc4891e6ef1ea91b01ea88abfab.setContent(html_d2af76ff26b797b9e46cd5b87606504f);
#
#
#
#         marker_f5ac7dbb005ac3bd6344a079f58e2819.bindPopup(popup_60019bc4891e6ef1ea91b01ea88abfab)
#         ;
#
#
#
#
#             var marker_3381095d8292276c9c170380b13e5765 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6da87cec0ee2ca7a41fe92c0d0406c);
#
#
#         var popup_f046dad52d4354e9a2537e8dbbd44c19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36f2bbca0e316132802158d467933f35 = $(`&lt;div id=&quot;html_36f2bbca0e316132802158d467933f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f046dad52d4354e9a2537e8dbbd44c19.setContent(html_36f2bbca0e316132802158d467933f35);
#
#
#
#         marker_3381095d8292276c9c170380b13e5765.bindPopup(popup_f046dad52d4354e9a2537e8dbbd44c19)
#         ;
#
#
#
#
#             var marker_294e191ec12a58c0fc37732467d1074a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6da87cec0ee2ca7a41fe92c0d0406c);
#
#
#         var popup_5d15ee583a2bb0c38e66481d29a0265b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df683c6bf7150448f5ff25464b3a0533 = $(`&lt;div id=&quot;html_df683c6bf7150448f5ff25464b3a0533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5d15ee583a2bb0c38e66481d29a0265b.setContent(html_df683c6bf7150448f5ff25464b3a0533);
#
#
#
#         marker_294e191ec12a58c0fc37732467d1074a.bindPopup(popup_5d15ee583a2bb0c38e66481d29a0265b)
#         ;
#
#
#
#
#             var marker_0e104c0b24788913a476ca199d019746 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6da87cec0ee2ca7a41fe92c0d0406c);
#
#
#         var popup_aca9791dd7d1a8fb992225aae10a2fae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_402f2cac8ece125d041b6f4e9dc4b129 = $(`&lt;div id=&quot;html_402f2cac8ece125d041b6f4e9dc4b129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aca9791dd7d1a8fb992225aae10a2fae.setContent(html_402f2cac8ece125d041b6f4e9dc4b129);
#
#
#
#         mark
