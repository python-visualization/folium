# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3cb6a6d797d9bcaa3398bcd4b9f4db6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3cb6a6d797d9bcaa3398bcd4b9f4db6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3cb6a6d797d9bcaa3398bcd4b9f4db6 = L.map(
#                 &quot;map_f3cb6a6d797d9bcaa3398bcd4b9f4db6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c8be5b3a16c5a4a5519d25b6fcb5b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6c8be5b3a16c5a4a5519d25b6fcb5b7.addTo(map_f3cb6a6d797d9bcaa3398bcd4b9f4db6);
#
#
#             var marker_aba93d8b178aee5c12052c52a8c07187 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f3cb6a6d797d9bcaa3398bcd4b9f4db6);
#
#
#         var popup_4227bb6ec4cf39235a4c3cd36c34108c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d38e3f88a55e554492fad46b06e52b92 = $(`&lt;div id=&quot;html_d38e3f88a55e554492fad46b06e52b92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4227bb6ec4cf39235a4c3cd36c34108c.setContent(html_d38e3f88a55e554492fad46b06e52b92);
#
#
#
#         marker_aba93d8b178aee5c12052c52a8c07187.bindPopup(popup_4227bb6ec4cf39235a4c3cd36c34108c)
#         ;
#
#
#
#
#             var marker_8390600b0c327290317ebf760b770c42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f3cb6a6d797d9bcaa3398bcd4b9f4db6);
#
#
#         var popup_e27f275106f19e13b376b04fdf0d0609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26894fadf52fdbcaeb7d2302f75f2407 = $(`&lt;div id=&quot;html_26894fadf52fdbcaeb7d2302f75f2407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e27f275106f19e13b376b04fdf0d0609.setContent(html_26894fadf52fdbcaeb7d2302f75f2407);
#
#
#
#         marker_8390600b0c327290317ebf760b770c42.bindPopup(popup_e27f275106f19e13b376b04fdf0d0609)
#         ;
#
#
#
#
#             var marker_8ace15bf91b59a7a7ac2d91814a8d12f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f3cb6a6d797d9bcaa3398bcd4b9f4db6);
#
#
#         var popup_b4ff114dfb8082078d60fbd08ccff6b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5eaa7432e68de5162f71c92d92f8e94 = $(`&lt;div id=&quot;html_b5eaa7432e68de5162f71c92d92f8e94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b4ff114dfb8082078d60fbd08ccff6b3.setContent(html_b5eaa7432e68de5162f71c92d92f8e94);
#
#
#
#         marker_8ace15bf91b59a7a7ac2d91814a8d12f.bindPopup(popup_b4ff114dfb8082078d60fbd08ccff6b3)
#         ;
#
#
#
#
#             var marker_2925151ab99faef7c6953f1e61b3e8cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f3cb6a6d797d9bcaa3398bcd4b9f4db6);
#
#
#         var popup_a51043e35e3d4f20067fc134ed4722b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf7f348e71a9c571ccaf44cb1ff3812f = $(`&lt;div id=&quot;html_bf7f348e71a9c571ccaf44cb1ff3812f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a51043e35e3d4f20067fc134ed4722b1.setContent(html_bf7f348e71a9c571ccaf44cb1ff3812f);
#
#
#
#         marker_2925151ab99faef7c6953f1e61b3e8cc.bindPopup(popup_a51043e35e3d4f20067fc134ed4722b1)
#         ;
#
#
#
#
#             var marker_c4589012cd0591dd2eebc2f38611537f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f3cb6a6d797d9bcaa3398bcd4b9f4db6);
#
#
#         var popup_2b450f2625fb54a83b94064d6e82e2f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4f36586ec97239acfa35b6a8efc2b29 = $(`&lt;div id=&quot;html_a4f36586ec97239acfa35b6a8efc2b29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2b450f2625fb54a83b94064d6e82e2f1.setContent(html_a4f36586ec97239acfa35b6a8efc2b29);
#
#
#
#         marker_c4589012cd0591dd2eebc2f38611537f.bindPopup(popup_2b450f2625fb54a83b94064d6e82e2f1)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f2368d2d82ee93657c2d14a38be0720 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f2368d2d82ee93657c2d14a38be0720&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f2368d2d82ee93657c2d14a38be0720 = L.map(
#                 &quot;map_6f2368d2d82ee93657c2d14a38be0720&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e05cd2584fac64bf676c889c48e5ee2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e05cd2584fac64bf676c889c48e5ee2e.addTo(map_6f2368d2d82ee93657c2d14a38be0720);
#
#
#             var feature_group_57b9676b9c720aacc18c02580c6eb92c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_24cde44cab95dd4a89fb997a1adc20e3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_57b9676b9c720aacc18c02580c6eb92c);
#
#
#         var popup_73ca9a419bffe5b6ce2b1c9bae2a46c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da6b2a719fe2ab21d9b3d410621b488c = $(`&lt;div id=&quot;html_da6b2a719fe2ab21d9b3d410621b488c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_73ca9a419bffe5b6ce2b1c9bae2a46c1.setContent(html_da6b2a719fe2ab21d9b3d410621b488c);
#
#
#
#         marker_24cde44cab95dd4a89fb997a1adc20e3.bindPopup(popup_73ca9a419bffe5b6ce2b1c9bae2a46c1)
#         ;
#
#
#
#
#             var marker_0a0db59f9c1e33e3ae6c788c9a1531bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_57b9676b9c720aacc18c02580c6eb92c);
#
#
#         var popup_0958db9d3f16ab405f8923fa91f6bce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ed0dc36d777916bb8d885046f44b7b2 = $(`&lt;div id=&quot;html_4ed0dc36d777916bb8d885046f44b7b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0958db9d3f16ab405f8923fa91f6bce5.setContent(html_4ed0dc36d777916bb8d885046f44b7b2);
#
#
#
#         marker_0a0db59f9c1e33e3ae6c788c9a1531bb.bindPopup(popup_0958db9d3f16ab405f8923fa91f6bce5)
#         ;
#
#
#
#
#             var marker_ab01771d2a2f28f4e451ad6b4afa66c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_57b9676b9c720aacc18c02580c6eb92c);
#
#
#         var popup_3306a9eb50aa5116ee83eb5d12b7d6e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ff0fc636bcb4e2def6d33bb0c9ada09 = $(`&lt;div id=&quot;html_8ff0fc636bcb4e2def6d33bb0c9ada09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3306a9eb50aa5116ee83eb5d12b7d6e8.setContent(html_8ff0fc636bcb4e2def6d33bb0c9ada09);
#
#
#
#         marker_ab01771d2a2f28f4e451ad6b4afa66c8.bindPopup(popup_3306a9eb50aa5116ee83eb5d12b7d6e8)
#         ;
#
#
#
#
#             var marker_667d2dd87f3e55303e5b436752abe0eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_57b9676b9c720aacc18c02580c6eb92c);
#
#
#         var popup_c4a6e71bfb1f09fb73dbe7f2338fc734 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f00b18d2d8d25f083fd910298bdb77b7 = $(`&lt;div id=&quot;html_f00b18d2d8d25f083fd910298bdb77b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c4a6e71bfb1f09fb73dbe7f2338fc734.setContent(html_f00b18d2d8d25f083fd910298bdb77b7);
#
#
#
#         marker_667d2dd87f3e55303e5b436752abe0eb.bindPopup(popup_c4a6e71bfb1f09fb73dbe7f2338fc734)
#         ;
#
#
#
#
#             var marker_e8b160796b9999f9ebacf661c28c673d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_57b9676b9c720aacc18c02580c6eb92c);
#
#
#         var popup_e2a99980a59c929b6cabf48511096b4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a4a5037dfd1810c1c16643c213d8010 = $(`&lt;div id=&quot;html_6a4a5037dfd1810c1c16643c213d8010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b455faf1bf6df41a538c1fe77d1841d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b455faf1bf6df41a538c1fe77d1841d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b455faf1bf6df41a538c1fe77d1841d = L.map(
#                 &quot;map_1b455faf1bf6df41a538c1fe77d1841d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0ebaabff8ad98219d04c4f19988b3fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0ebaabff8ad98219d04c4f19988b3fd.addTo(map_1b455faf1bf6df41a538c1fe77d1841d);
#
#
#             var feature_group_de5580c4fab01f376163cdfbb7220782 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_de5580c4fab01f376163cdfbb7220782.addTo(map_1b455faf1bf6df41a538c1fe77d1841d);
#
#
#             var feature_group_sub_group_5b93a4e058fabc1704f85cf67eb2af1f = L.featureGroup.subGroup(
#                 feature_group_de5580c4fab01f376163cdfbb7220782
#             );
#
#
#             var marker_e222c8a2fcf4800f59af4b996cbd4590 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b93a4e058fabc1704f85cf67eb2af1f);
#
#
#         var popup_eb5edcebbbcd87707a39a000217df83b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30d273c7ddc4b63811a29a8805e7ded6 = $(`&lt;div id=&quot;html_30d273c7ddc4b63811a29a8805e7ded6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eb5edcebbbcd87707a39a000217df83b.setContent(html_30d273c7ddc4b63811a29a8805e7ded6);
#
#
#
#         marker_e222c8a2fcf4800f59af4b996cbd4590.bindPopup(popup_eb5edcebbbcd87707a39a000217df83b)
#         ;
#
#
#
#
#             var marker_7cd3c9f976b8cd4f16c093199e80d0b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b93a4e058fabc1704f85cf67eb2af1f);
#
#
#         var popup_c09ba7fc265b3754a7c371e40062fe90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc65b6c5b3a7ac0d7a1ee95ef2b2b5b8 = $(`&lt;div id=&quot;html_dc65b6c5b3a7ac0d7a1ee95ef2b2b5b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c09ba7fc265b3754a7c371e40062fe90.setContent(html_dc65b6c5b3a7ac0d7a1ee95ef2b2b5b8);
#
#
#
#         marker_7cd3c9f976b8cd4f16c093199e80d0b6.bindPopup(popup_c09ba7fc265b3754a7c371e40062fe90)
#         ;
#
#
#
#
#             var marker_27a1b8eca561a142baffae21cf0e81b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b93a4e058fabc1704f85cf67eb2af1f);
#
#
#         var popup_2e1cb2fcba53ca85297e5ee0469ddaa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8e27b03370243c1f2d3c2a12e376572 = $(`&lt;div id=&quot;html_e8e27b03370243c1f2d3c2a12e376572&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2e1cb2fcba53ca85297e5ee0469ddaa7.setContent(html_e8e27b03370243c1f2d3c2a12e376572);
#
#
#
#         marker_27a1b8eca561a142baffae21cf0e81b7.bindPopup(popup_2e1cb2fcba53ca85297e5ee0469ddaa7)
#         ;
#
#
#
#
#             var marker_f5f4766df21f46d05c7d08ed4ba9df87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b93a4e058fabc1704f85cf67eb2af1f);
#
#
#         var popup_49a8ec682111225dc6ccea1b46dabe05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_275a24c3992e736872721a51d0a63569 = $(`&lt;div id=&quot;html_275a24c3992e736872721a51d0a63569&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_49a8ec682111225dc6ccea1b46dabe05.setContent(html_275a24c3992e736872721a51d0a63569);
#
#
#
#         marker_f5f4766df21f46d05c7d08ed4ba9df87.bindPopup(popup_49a8ec682111225dc6ccea1b46dabe05)
#         ;
#
#
#
#
#             var marker_66b1e6ba0e2fb85ed603d60344e1e523 = L.marker(
#                 [45.0503999
