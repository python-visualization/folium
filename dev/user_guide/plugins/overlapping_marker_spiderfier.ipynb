# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbb04a509eec4cc4e2d70bd65655f76e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbb04a509eec4cc4e2d70bd65655f76e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbb04a509eec4cc4e2d70bd65655f76e = L.map(
#                 &quot;map_bbb04a509eec4cc4e2d70bd65655f76e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_952f6fa0076d668aa7dad21a2f988959 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_952f6fa0076d668aa7dad21a2f988959.addTo(map_bbb04a509eec4cc4e2d70bd65655f76e);
#
#
#             var marker_d6a6dfbec363f7a46e091d62ccfa2c43 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bbb04a509eec4cc4e2d70bd65655f76e);
#
#
#         var popup_9781887ee04014c30493edc5eb63741f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d31c5e915ce69ea4369ae0a31999d31 = $(`&lt;div id=&quot;html_4d31c5e915ce69ea4369ae0a31999d31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9781887ee04014c30493edc5eb63741f.setContent(html_4d31c5e915ce69ea4369ae0a31999d31);
#
#
#
#         marker_d6a6dfbec363f7a46e091d62ccfa2c43.bindPopup(popup_9781887ee04014c30493edc5eb63741f)
#         ;
#
#
#
#
#             var marker_622c7a153843a0899e17aff8f330d016 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bbb04a509eec4cc4e2d70bd65655f76e);
#
#
#         var popup_774f0b323a750492b433be54bedadbca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ef7fde0dca27ff8120d2bf29a420c4c = $(`&lt;div id=&quot;html_8ef7fde0dca27ff8120d2bf29a420c4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_774f0b323a750492b433be54bedadbca.setContent(html_8ef7fde0dca27ff8120d2bf29a420c4c);
#
#
#
#         marker_622c7a153843a0899e17aff8f330d016.bindPopup(popup_774f0b323a750492b433be54bedadbca)
#         ;
#
#
#
#
#             var marker_040a5a2e0af3c569d1cbf683f833b8de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bbb04a509eec4cc4e2d70bd65655f76e);
#
#
#         var popup_4571daf91af5f2c2e74739702cd6968b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c63039060145e563beac9e5489c9ae0 = $(`&lt;div id=&quot;html_8c63039060145e563beac9e5489c9ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4571daf91af5f2c2e74739702cd6968b.setContent(html_8c63039060145e563beac9e5489c9ae0);
#
#
#
#         marker_040a5a2e0af3c569d1cbf683f833b8de.bindPopup(popup_4571daf91af5f2c2e74739702cd6968b)
#         ;
#
#
#
#
#             var marker_eb4070c57c1f305851d516625baf56a0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bbb04a509eec4cc4e2d70bd65655f76e);
#
#
#         var popup_5f5e5fa3983b28aa6eb6eaf7c94905b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1f568fca4b6e1dd95d01ba17b6523f0 = $(`&lt;div id=&quot;html_c1f568fca4b6e1dd95d01ba17b6523f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5f5e5fa3983b28aa6eb6eaf7c94905b5.setContent(html_c1f568fca4b6e1dd95d01ba17b6523f0);
#
#
#
#         marker_eb4070c57c1f305851d516625baf56a0.bindPopup(popup_5f5e5fa3983b28aa6eb6eaf7c94905b5)
#         ;
#
#
#
#
#             var marker_4fc37b5991258168b0699c05106589a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bbb04a509eec4cc4e2d70bd65655f76e);
#
#
#         var popup_fcc0b092191a1cfd6733c96992d47491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_003bbaa21fa30d757270b600f6652159 = $(`&lt;div id=&quot;html_003bbaa21fa30d757270b600f6652159&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fcc0b092191a1cfd6733c96992d47491.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85ffe4a2974d307c6ffda7bb85f915e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85ffe4a2974d307c6ffda7bb85f915e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85ffe4a2974d307c6ffda7bb85f915e6 = L.map(
#                 &quot;map_85ffe4a2974d307c6ffda7bb85f915e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e25763502128ca218e7215a1d38ef6d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e25763502128ca218e7215a1d38ef6d6.addTo(map_85ffe4a2974d307c6ffda7bb85f915e6);
#
#
#             var feature_group_870c9b98186c662927e6033e9d5fcb1d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2ab049bf0f2bc4d3595f6a6116ee6db4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_870c9b98186c662927e6033e9d5fcb1d);
#
#
#         var popup_15efe9ffc2b8b7ef49295b74a8462e46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50a86ac8ef721cff4485685c4aa3899e = $(`&lt;div id=&quot;html_50a86ac8ef721cff4485685c4aa3899e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_15efe9ffc2b8b7ef49295b74a8462e46.setContent(html_50a86ac8ef721cff4485685c4aa3899e);
#
#
#
#         marker_2ab049bf0f2bc4d3595f6a6116ee6db4.bindPopup(popup_15efe9ffc2b8b7ef49295b74a8462e46)
#         ;
#
#
#
#
#             var marker_52d4d1b717e7e1ca108f50e6d4e3aabc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_870c9b98186c662927e6033e9d5fcb1d);
#
#
#         var popup_1f186cdb7350afcf631061ac4e6d5d5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32002086072fad795cabf237d09f0163 = $(`&lt;div id=&quot;html_32002086072fad795cabf237d09f0163&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1f186cdb7350afcf631061ac4e6d5d5a.setContent(html_32002086072fad795cabf237d09f0163);
#
#
#
#         marker_52d4d1b717e7e1ca108f50e6d4e3aabc.bindPopup(popup_1f186cdb7350afcf631061ac4e6d5d5a)
#         ;
#
#
#
#
#             var marker_54af03d0f389000bcae428b32c6f93f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_870c9b98186c662927e6033e9d5fcb1d);
#
#
#         var popup_6c5747c9cb8dfbc2bb7ef6b1b2d58f5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86837d3a1713f8677c2534c2ad28fc09 = $(`&lt;div id=&quot;html_86837d3a1713f8677c2534c2ad28fc09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6c5747c9cb8dfbc2bb7ef6b1b2d58f5b.setContent(html_86837d3a1713f8677c2534c2ad28fc09);
#
#
#
#         marker_54af03d0f389000bcae428b32c6f93f0.bindPopup(popup_6c5747c9cb8dfbc2bb7ef6b1b2d58f5b)
#         ;
#
#
#
#
#             var marker_e2a410e1b51d9d9d5ad58a1b8525a6ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_870c9b98186c662927e6033e9d5fcb1d);
#
#
#         var popup_0a117feac68ee46acd5d66ed1bf7c5b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd11e917436b090308dafb8fb5db9605 = $(`&lt;div id=&quot;html_cd11e917436b090308dafb8fb5db9605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0a117feac68ee46acd5d66ed1bf7c5b4.setContent(html_cd11e917436b090308dafb8fb5db9605);
#
#
#
#         marker_e2a410e1b51d9d9d5ad58a1b8525a6ee.bindPopup(popup_0a117feac68ee46acd5d66ed1bf7c5b4)
#         ;
#
#
#
#
#             var marker_6a2958cda415024760578a5fc708ec7c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_870c9b98186c662927e6033e9d5fcb1d);
#
#
#         var popup_f4b178baaae0b3ab713d80d49f232912 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab6ba867f269c79ea256493cd395efbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab6ba867f269c79ea256493cd395efbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab6ba867f269c79ea256493cd395efbf = L.map(
#                 &quot;map_ab6ba867f269c79ea256493cd395efbf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ec90caa3e5b83e9613ff5be0cd8811a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ec90caa3e5b83e9613ff5be0cd8811a.addTo(map_ab6ba867f269c79ea256493cd395efbf);
#
#
#             var feature_group_20f01125687fb8775f7a20e6b51d5586 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_20f01125687fb8775f7a20e6b51d5586.addTo(map_ab6ba867f269c79ea256493cd395efbf);
#
#
#             var feature_group_sub_group_b371de9c31ea3faccf2039a61076bc21 = L.featureGroup.subGroup(
#                 feature_group_20f01125687fb8775f7a20e6b51d5586
#             );
#
#
#             var marker_efd3cb377d6e0644ea005899001024f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b371de9c31ea3faccf2039a61076bc21);
#
#
#         var popup_b20de322cbeee8ef22fd3499789292aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09d606a10b48a7fa9feed5bbd62e72fd = $(`&lt;div id=&quot;html_09d606a10b48a7fa9feed5bbd62e72fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b20de322cbeee8ef22fd3499789292aa.setContent(html_09d606a10b48a7fa9feed5bbd62e72fd);
#
#
#
#         marker_efd3cb377d6e0644ea005899001024f9.bindPopup(popup_b20de322cbeee8ef22fd3499789292aa)
#         ;
#
#
#
#
#             var marker_ccaeccb5e25e9be7b7a1ed3228d55d5a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b371de9c31ea3faccf2039a61076bc21);
#
#
#         var popup_8796deb50ae96e9766cfbcf4e7d3c72e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09c39a15f41d7f7c1436887d8e7b403e = $(`&lt;div id=&quot;html_09c39a15f41d7f7c1436887d8e7b403e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8796deb50ae96e9766cfbcf4e7d3c72e.setContent(html_09c39a15f41d7f7c1436887d8e7b403e);
#
#
#
#         marker_ccaeccb5e25e9be7b7a1ed3228d55d5a.bindPopup(popup_8796deb50ae96e9766cfbcf4e7d3c72e)
#         ;
#
#
#
#
#             var marker_56295bd898419abb43076f3f1a612d48 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b371de9c31ea3faccf2039a61076bc21);
#
#
#         var popup_7379b98d9ac3956fc4497a9fa715f603 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8df523d3d28bcd4db8983ad750781763 = $(`&lt;div id=&quot;html_8df523d3d28bcd4db8983ad750781763&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7379b98d9ac3956fc4497a9fa715f603.setContent(html_8df523d3d28bcd4db8983ad750781763);
#
#
#
#         marker_56295bd898419abb43076f3f1a612d48.bindPopup(popup_7379b98d9ac3956fc4497a9fa715f603)
#         ;
#
#
#
#
#             var marker_b6e461ccd44c848de5a904ba156e9704 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b371de9c31ea3faccf2039a61076bc21);
#
#
#         var popup_1ce86608d8ff038dd1eb04e490324e3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63871c801cceb3cda8abe8bc5cd3b3ce = $(`&lt;div id=&quot;html_63871c801cceb3cda8abe8bc5cd3b3ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1ce86608d8ff038dd1eb04e490324e3b.setContent(html_63871c801cceb3cda8abe8bc5cd3b3ce);
#
#
#
#         marker_
