# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e724e9fe758e52e78535b6630ba717a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e724e9fe758e52e78535b6630ba717a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e724e9fe758e52e78535b6630ba717a = L.map(
#                 &quot;map_2e724e9fe758e52e78535b6630ba717a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_344ac9f76abc816fdcc27c94aa6ce8f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_344ac9f76abc816fdcc27c94aa6ce8f5.addTo(map_2e724e9fe758e52e78535b6630ba717a);
#
#
#             var marker_bb37497ebe64051930b9fc88e8d01d1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2e724e9fe758e52e78535b6630ba717a);
#
#
#         var popup_759cd2efaff7fd2cbc91316e7d2c55f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb9a04b28bc4fe90ead869b12bf2bafd = $(`&lt;div id=&quot;html_eb9a04b28bc4fe90ead869b12bf2bafd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_759cd2efaff7fd2cbc91316e7d2c55f1.setContent(html_eb9a04b28bc4fe90ead869b12bf2bafd);
#
#
#
#         marker_bb37497ebe64051930b9fc88e8d01d1f.bindPopup(popup_759cd2efaff7fd2cbc91316e7d2c55f1)
#         ;
#
#
#
#
#             var marker_e664173943e9b464e016418cf167830f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2e724e9fe758e52e78535b6630ba717a);
#
#
#         var popup_5328d6befd4901253264b694175cffcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28ba234903e2ffe89aaf88bdaa3d9611 = $(`&lt;div id=&quot;html_28ba234903e2ffe89aaf88bdaa3d9611&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5328d6befd4901253264b694175cffcf.setContent(html_28ba234903e2ffe89aaf88bdaa3d9611);
#
#
#
#         marker_e664173943e9b464e016418cf167830f.bindPopup(popup_5328d6befd4901253264b694175cffcf)
#         ;
#
#
#
#
#             var marker_080dde6c1d4af383561334c096e52818 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2e724e9fe758e52e78535b6630ba717a);
#
#
#         var popup_f19383cf336d3636831e2ec903153571 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a98200fe1e8b918926410d658d9ddb3 = $(`&lt;div id=&quot;html_2a98200fe1e8b918926410d658d9ddb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f19383cf336d3636831e2ec903153571.setContent(html_2a98200fe1e8b918926410d658d9ddb3);
#
#
#
#         marker_080dde6c1d4af383561334c096e52818.bindPopup(popup_f19383cf336d3636831e2ec903153571)
#         ;
#
#
#
#
#             var marker_55ca872a2efba052312d093f9c5ff622 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2e724e9fe758e52e78535b6630ba717a);
#
#
#         var popup_8a1bea17b94ede704bb26d26ccb6bfd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e438f1019cf208e7b68caecbe8c98dfd = $(`&lt;div id=&quot;html_e438f1019cf208e7b68caecbe8c98dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8a1bea17b94ede704bb26d26ccb6bfd2.setContent(html_e438f1019cf208e7b68caecbe8c98dfd);
#
#
#
#         marker_55ca872a2efba052312d093f9c5ff622.bindPopup(popup_8a1bea17b94ede704bb26d26ccb6bfd2)
#         ;
#
#
#
#
#             var marker_f165be7737af33b61992843dd716bd4f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2e724e9fe758e52e78535b6630ba717a);
#
#
#         var popup_c8b8367fe25522583f3ce1f246561941 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_818688221dcc86c6295e8e4c2a180bfb = $(`&lt;div id=&quot;html_818688221dcc86c6295e8e4c2a180bfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c8b8367fe25522583f3ce1f246561941.setContent(html_818688221dcc86c6295e8e4c2a180bfb);
#
#
#
#         marker_f165be7737af33b61992843dd716bd4f.bindPopup(popup_c8b8367fe25522583f3ce1f246561941)
#         ;
#
#
#
#
#             var marker_83e92fb168

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_557d9bb029ed4a850a3552d81da48da8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_557d9bb029ed4a850a3552d81da48da8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_557d9bb029ed4a850a3552d81da48da8 = L.map(
#                 &quot;map_557d9bb029ed4a850a3552d81da48da8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5aee66dd2cf321215d9bda07f62f1a13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5aee66dd2cf321215d9bda07f62f1a13.addTo(map_557d9bb029ed4a850a3552d81da48da8);
#
#
#             var feature_group_83870bc226a174ffdc7ffb35340b397a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_467125dc778013e5c151b7717906c0a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_83870bc226a174ffdc7ffb35340b397a);
#
#
#         var popup_655870872ceeafcf6a1fedc0bef22fc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b95fc6e91e1eb35d7f3c11121131e97 = $(`&lt;div id=&quot;html_9b95fc6e91e1eb35d7f3c11121131e97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_655870872ceeafcf6a1fedc0bef22fc8.setContent(html_9b95fc6e91e1eb35d7f3c11121131e97);
#
#
#
#         marker_467125dc778013e5c151b7717906c0a6.bindPopup(popup_655870872ceeafcf6a1fedc0bef22fc8)
#         ;
#
#
#
#
#             var marker_619ec19dca710adb9f78200338ae5090 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_83870bc226a174ffdc7ffb35340b397a);
#
#
#         var popup_3e74f1777ec8c6de9a6097067d2d7af5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa5972bedee37ff349e403492d9b0228 = $(`&lt;div id=&quot;html_fa5972bedee37ff349e403492d9b0228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3e74f1777ec8c6de9a6097067d2d7af5.setContent(html_fa5972bedee37ff349e403492d9b0228);
#
#
#
#         marker_619ec19dca710adb9f78200338ae5090.bindPopup(popup_3e74f1777ec8c6de9a6097067d2d7af5)
#         ;
#
#
#
#
#             var marker_1113c15d181743bff3d42f63750643ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_83870bc226a174ffdc7ffb35340b397a);
#
#
#         var popup_01ed9238d173ca6cd540844c3e9efa72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83d3805669075dc3c323f4992cdfc277 = $(`&lt;div id=&quot;html_83d3805669075dc3c323f4992cdfc277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_01ed9238d173ca6cd540844c3e9efa72.setContent(html_83d3805669075dc3c323f4992cdfc277);
#
#
#
#         marker_1113c15d181743bff3d42f63750643ff.bindPopup(popup_01ed9238d173ca6cd540844c3e9efa72)
#         ;
#
#
#
#
#             var marker_3f2baaf996b9a08b1c07ddf5f5bd7ba8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_83870bc226a174ffdc7ffb35340b397a);
#
#
#         var popup_d3cece6a2666b7417e5e18b5a9eb6976 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551612f3a02376f15b2a8d9a40a81b2f = $(`&lt;div id=&quot;html_551612f3a02376f15b2a8d9a40a81b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d3cece6a2666b7417e5e18b5a9eb6976.setContent(html_551612f3a02376f15b2a8d9a40a81b2f);
#
#
#
#         marker_3f2baaf996b9a08b1c07ddf5f5bd7ba8.bindPopup(popup_d3cece6a2666b7417e5e18b5a9eb6976)
#         ;
#
#
#
#
#             var marker_0dc253a659038038b7522e6f2361cd6d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_83870bc226a174ffdc7ffb35340b397a);
#
#
#         var popup_785be36c86031ffd65889c2c889dbd61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00be794da6c552a4901241d462f898ce = $(`&lt;div id=&quot;html_00be794da6c552a4901241d462f898ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_785be36c86031ffd65

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fef76f9a80f00339a81e8267327448b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fef76f9a80f00339a81e8267327448b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fef76f9a80f00339a81e8267327448b = L.map(
#                 &quot;map_2fef76f9a80f00339a81e8267327448b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_249bae3698db2c042d0c4bcd410e5261 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_249bae3698db2c042d0c4bcd410e5261.addTo(map_2fef76f9a80f00339a81e8267327448b);
#
#
#             var feature_group_d9ea6185316367c1514edcdc8840fde0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d9ea6185316367c1514edcdc8840fde0.addTo(map_2fef76f9a80f00339a81e8267327448b);
#
#
#             var feature_group_sub_group_f3529e7c556b003f595d98824e31aa0d = L.featureGroup.subGroup(
#                 feature_group_d9ea6185316367c1514edcdc8840fde0
#             );
#
#
#             var marker_a83880a0100a7887d4d4fa30bae32bc3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3529e7c556b003f595d98824e31aa0d);
#
#
#         var popup_84a9a9e4614a4cecf9751ec9f22e1766 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f81a3c75878a9a17c942afc2c372f46c = $(`&lt;div id=&quot;html_f81a3c75878a9a17c942afc2c372f46c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_84a9a9e4614a4cecf9751ec9f22e1766.setContent(html_f81a3c75878a9a17c942afc2c372f46c);
#
#
#
#         marker_a83880a0100a7887d4d4fa30bae32bc3.bindPopup(popup_84a9a9e4614a4cecf9751ec9f22e1766)
#         ;
#
#
#
#
#             var marker_3c65e00c37c1e429158551e0544836aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3529e7c556b003f595d98824e31aa0d);
#
#
#         var popup_58e5b647b3795d67bac7d4e0f474936e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cf3848fded385d654157569eccbfe8b = $(`&lt;div id=&quot;html_4cf3848fded385d654157569eccbfe8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_58e5b647b3795d67bac7d4e0f474936e.setContent(html_4cf3848fded385d654157569eccbfe8b);
#
#
#
#         marker_3c65e00c37c1e429158551e0544836aa.bindPopup(popup_58e5b647b3795d67bac7d4e0f474936e)
#         ;
#
#
#
#
#             var marker_02e65fd9522934db7f77c29fb753ecbf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3529e7c556b003f595d98824e31aa0d);
#
#
#         var popup_ed4f922b37c876e0af4bf1e1cf5b53cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea2ca2cfe3692de06b02c4200fccf3f4 = $(`&lt;div id=&quot;html_ea2ca2cfe3692de06b02c4200fccf3f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed4f922b37c876e0af4bf1e1cf5b53cf.setContent(html_ea2ca2cfe3692de06b02c4200fccf3f4);
#
#
#
#         marker_02e65fd9522934db7f77c29fb753ecbf.bindPopup(popup_ed4f922b37c876e0af4bf1e1cf5b53cf)
#         ;
#
#
#
#
#             var marker_ccffbb83c39c876824c2e35f81eec887 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f3529e7c556b003f595d98824e31aa0d);
#
#
#         var popup_5ec17440354d80104c09748ede01c342 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1916b077cdf314c1bb315cf436ec214 = $(`&lt;div id=&quot;html_c1916b077cdf314c1bb315cf436ec214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5ec17440354d80104c09748ede01c342.setContent(html_c1916b077cdf314c1bb315cf436ec214);
#
#
#
#         marker_ccffbb83c39c876824c2e35f81eec887.bindPopup(popup_5ec17440354d80104c09748ede01c342)
#         ;
#
#
#
#
#             var marker_1076f7d2132309707fcaaf8d53681dcd = L.marker(
#                 [45.050399999999996, 3.0504],
