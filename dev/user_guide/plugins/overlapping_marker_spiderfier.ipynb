# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cb08f5854616d743ee161aed4c34fd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cb08f5854616d743ee161aed4c34fd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cb08f5854616d743ee161aed4c34fd2 = L.map(
#                 &quot;map_6cb08f5854616d743ee161aed4c34fd2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47982bbb2c3ed0f910b034a6343dd789 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_47982bbb2c3ed0f910b034a6343dd789.addTo(map_6cb08f5854616d743ee161aed4c34fd2);
#
#
#             var marker_14501240b6c9be7e5f96956d43f6f1b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6cb08f5854616d743ee161aed4c34fd2);
#
#
#         var popup_8f57b98cb01c2b2dab8a6c8bef96cbce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99778638300637223d88bb695df6381f = $(`&lt;div id=&quot;html_99778638300637223d88bb695df6381f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8f57b98cb01c2b2dab8a6c8bef96cbce.setContent(html_99778638300637223d88bb695df6381f);
#
#
#
#         marker_14501240b6c9be7e5f96956d43f6f1b3.bindPopup(popup_8f57b98cb01c2b2dab8a6c8bef96cbce)
#         ;
#
#
#
#
#             var marker_e1f243dde5d70a270d52677e408b9bf9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6cb08f5854616d743ee161aed4c34fd2);
#
#
#         var popup_1666871be7e4ed2a8103aa34d1e3ae03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58cb284eed70c6b4bc2cf8ad8dff3332 = $(`&lt;div id=&quot;html_58cb284eed70c6b4bc2cf8ad8dff3332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1666871be7e4ed2a8103aa34d1e3ae03.setContent(html_58cb284eed70c6b4bc2cf8ad8dff3332);
#
#
#
#         marker_e1f243dde5d70a270d52677e408b9bf9.bindPopup(popup_1666871be7e4ed2a8103aa34d1e3ae03)
#         ;
#
#
#
#
#             var marker_999f182bccdd88ad701baf57789548bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6cb08f5854616d743ee161aed4c34fd2);
#
#
#         var popup_0a7d473e12da226aaafe9063098fa792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_541795a4a63fb8fef439ce9c1f31eaa3 = $(`&lt;div id=&quot;html_541795a4a63fb8fef439ce9c1f31eaa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0a7d473e12da226aaafe9063098fa792.setContent(html_541795a4a63fb8fef439ce9c1f31eaa3);
#
#
#
#         marker_999f182bccdd88ad701baf57789548bf.bindPopup(popup_0a7d473e12da226aaafe9063098fa792)
#         ;
#
#
#
#
#             var marker_e9a964fb9b11a632177b17581128ad9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6cb08f5854616d743ee161aed4c34fd2);
#
#
#         var popup_51365e09b2ae8362dad0ea6a9c15781f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc9c5500a2118001269b865e092ef6ef = $(`&lt;div id=&quot;html_cc9c5500a2118001269b865e092ef6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_51365e09b2ae8362dad0ea6a9c15781f.setContent(html_cc9c5500a2118001269b865e092ef6ef);
#
#
#
#         marker_e9a964fb9b11a632177b17581128ad9d.bindPopup(popup_51365e09b2ae8362dad0ea6a9c15781f)
#         ;
#
#
#
#
#             var marker_b7817d504e5e61cfcd2300af6771f4f8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6cb08f5854616d743ee161aed4c34fd2);
#
#
#         var popup_04842dac49c4409657b0e751f69ecbe6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6d541c6d39fe7ac6fe62fcc2959c5cb = $(`&lt;div id=&quot;html_e6d541c6d39fe7ac6fe62fcc2959c5cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_04842dac49c4409657b0e751f69ecbe6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05b733f3c9467eb1ccfd7ba20a208223 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05b733f3c9467eb1ccfd7ba20a208223&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05b733f3c9467eb1ccfd7ba20a208223 = L.map(
#                 &quot;map_05b733f3c9467eb1ccfd7ba20a208223&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_339a0581dc1b90952a1f24abcf6b5c27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_339a0581dc1b90952a1f24abcf6b5c27.addTo(map_05b733f3c9467eb1ccfd7ba20a208223);
#
#
#             var feature_group_4c265e48200572b404ce8c6293ba6706 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4cfb5801ca9dc72130aabe1c26000ae0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4c265e48200572b404ce8c6293ba6706);
#
#
#         var popup_6983ecd7e5237d6729a745ca500ed63b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22d0709b642bdc439902dd2303e3e9ad = $(`&lt;div id=&quot;html_22d0709b642bdc439902dd2303e3e9ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6983ecd7e5237d6729a745ca500ed63b.setContent(html_22d0709b642bdc439902dd2303e3e9ad);
#
#
#
#         marker_4cfb5801ca9dc72130aabe1c26000ae0.bindPopup(popup_6983ecd7e5237d6729a745ca500ed63b)
#         ;
#
#
#
#
#             var marker_ade7ea5bc893f2a1d84dfa67a8b0b4dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4c265e48200572b404ce8c6293ba6706);
#
#
#         var popup_f9f1740cecfa1e60e684b4a05f6dbba3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d18437adf111a47fd813a86b913070b = $(`&lt;div id=&quot;html_6d18437adf111a47fd813a86b913070b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f9f1740cecfa1e60e684b4a05f6dbba3.setContent(html_6d18437adf111a47fd813a86b913070b);
#
#
#
#         marker_ade7ea5bc893f2a1d84dfa67a8b0b4dc.bindPopup(popup_f9f1740cecfa1e60e684b4a05f6dbba3)
#         ;
#
#
#
#
#             var marker_eb4e074ab18ac3e440f14fc73289be2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4c265e48200572b404ce8c6293ba6706);
#
#
#         var popup_fd854365c0c0317c7e3878ab92e48c44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f8b3fca804c24061d617cf6b38c4981 = $(`&lt;div id=&quot;html_7f8b3fca804c24061d617cf6b38c4981&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fd854365c0c0317c7e3878ab92e48c44.setContent(html_7f8b3fca804c24061d617cf6b38c4981);
#
#
#
#         marker_eb4e074ab18ac3e440f14fc73289be2d.bindPopup(popup_fd854365c0c0317c7e3878ab92e48c44)
#         ;
#
#
#
#
#             var marker_843d9c495848561fde0c1c6e634828c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4c265e48200572b404ce8c6293ba6706);
#
#
#         var popup_f7940aedd8e467d6aa9b6e04f0e5c6d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fa9b8cfc0c25e4876cd526a21779118 = $(`&lt;div id=&quot;html_8fa9b8cfc0c25e4876cd526a21779118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f7940aedd8e467d6aa9b6e04f0e5c6d5.setContent(html_8fa9b8cfc0c25e4876cd526a21779118);
#
#
#
#         marker_843d9c495848561fde0c1c6e634828c6.bindPopup(popup_f7940aedd8e467d6aa9b6e04f0e5c6d5)
#         ;
#
#
#
#
#             var marker_30beb56a0f0b961aaafa478dbb9a2d1a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4c265e48200572b404ce8c6293ba6706);
#
#
#         var popup_87d8152b134a574e44beb16b0d91bc2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26a9a0fe8b24fcd227c88e69e54d280b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26a9a0fe8b24fcd227c88e69e54d280b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26a9a0fe8b24fcd227c88e69e54d280b = L.map(
#                 &quot;map_26a9a0fe8b24fcd227c88e69e54d280b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d0ae4f7c348ba469223b0f467b58ac1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d0ae4f7c348ba469223b0f467b58ac1.addTo(map_26a9a0fe8b24fcd227c88e69e54d280b);
#
#
#             var feature_group_a0c3778088eb89d8b5b3c780d4b4300e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a0c3778088eb89d8b5b3c780d4b4300e.addTo(map_26a9a0fe8b24fcd227c88e69e54d280b);
#
#
#             var feature_group_sub_group_537b34ec96327c08b0842a199e1a2c3b = L.featureGroup.subGroup(
#                 feature_group_a0c3778088eb89d8b5b3c780d4b4300e
#             );
#
#
#             var marker_9663b344fbfba9cb48286c9ef1c3ed0b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_537b34ec96327c08b0842a199e1a2c3b);
#
#
#         var popup_8e9bcc3d936f4867c23f9ced6e0db5b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e21fe10f7b0d1419bf685af185c5ce34 = $(`&lt;div id=&quot;html_e21fe10f7b0d1419bf685af185c5ce34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8e9bcc3d936f4867c23f9ced6e0db5b6.setContent(html_e21fe10f7b0d1419bf685af185c5ce34);
#
#
#
#         marker_9663b344fbfba9cb48286c9ef1c3ed0b.bindPopup(popup_8e9bcc3d936f4867c23f9ced6e0db5b6)
#         ;
#
#
#
#
#             var marker_76072dae17942f8986763da49a3d41f0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_537b34ec96327c08b0842a199e1a2c3b);
#
#
#         var popup_db77fba4532e35e8b732dfc3955eb053 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b55ead8d3ac8a96ae9bcdee31a1b3956 = $(`&lt;div id=&quot;html_b55ead8d3ac8a96ae9bcdee31a1b3956&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_db77fba4532e35e8b732dfc3955eb053.setContent(html_b55ead8d3ac8a96ae9bcdee31a1b3956);
#
#
#
#         marker_76072dae17942f8986763da49a3d41f0.bindPopup(popup_db77fba4532e35e8b732dfc3955eb053)
#         ;
#
#
#
#
#             var marker_b9a8df7e54e0de008b0cb661665c63bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_537b34ec96327c08b0842a199e1a2c3b);
#
#
#         var popup_149d9c2fda788cfd73c30a474cf84e5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_575f61318d4be3e6d67731e9d591e935 = $(`&lt;div id=&quot;html_575f61318d4be3e6d67731e9d591e935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_149d9c2fda788cfd73c30a474cf84e5a.setContent(html_575f61318d4be3e6d67731e9d591e935);
#
#
#
#         marker_b9a8df7e54e0de008b0cb661665c63bf.bindPopup(popup_149d9c2fda788cfd73c30a474cf84e5a)
#         ;
#
#
#
#
#             var marker_16f1955d3ab82cd93e7ea70e7c949bd2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_537b34ec96327c08b0842a199e1a2c3b);
#
#
#         var popup_e1533b02ac0947eace5c7cc3efaf8bbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54f3941fd1b6be425636f90bbd60e30c = $(`&lt;div id=&quot;html_54f3941fd1b6be425636f90bbd60e30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e1533b02ac0947eace5c7cc3efaf8bbf.setContent(html_54f3941fd1b6be425636f90bbd60e30c);
#
#
#
#         marker_
