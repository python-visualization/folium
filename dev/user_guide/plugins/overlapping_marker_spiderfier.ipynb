# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20496c0e8e2284019a813f9c8768b146 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20496c0e8e2284019a813f9c8768b146&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20496c0e8e2284019a813f9c8768b146 = L.map(
#                 &quot;map_20496c0e8e2284019a813f9c8768b146&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e8c53ecc63a7d2a53a0a571bf61b2eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e8c53ecc63a7d2a53a0a571bf61b2eb.addTo(map_20496c0e8e2284019a813f9c8768b146);
#
#
#             var marker_26cb3dae3398486a1f3a4fd2d6926dca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_20496c0e8e2284019a813f9c8768b146);
#
#
#         var popup_38d44f903a867594b8dd8e3f00a0a719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0abc9b5a49564dbab3c4cffc2ba1ac90 = $(`&lt;div id=&quot;html_0abc9b5a49564dbab3c4cffc2ba1ac90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_38d44f903a867594b8dd8e3f00a0a719.setContent(html_0abc9b5a49564dbab3c4cffc2ba1ac90);
#
#
#
#         marker_26cb3dae3398486a1f3a4fd2d6926dca.bindPopup(popup_38d44f903a867594b8dd8e3f00a0a719)
#         ;
#
#
#
#
#             var marker_0267e1c0e248166b6718395d05f326c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_20496c0e8e2284019a813f9c8768b146);
#
#
#         var popup_cd1cfa8a626b0bbfe2eec6306ec534dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcb81c93ef4c8248ecf8a9643bd59662 = $(`&lt;div id=&quot;html_fcb81c93ef4c8248ecf8a9643bd59662&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cd1cfa8a626b0bbfe2eec6306ec534dc.setContent(html_fcb81c93ef4c8248ecf8a9643bd59662);
#
#
#
#         marker_0267e1c0e248166b6718395d05f326c9.bindPopup(popup_cd1cfa8a626b0bbfe2eec6306ec534dc)
#         ;
#
#
#
#
#             var marker_b313caebcd30b607f2e4bfebd0f3993f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_20496c0e8e2284019a813f9c8768b146);
#
#
#         var popup_c080695bd2ffc26e42f79958163bc522 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_455665047e1ea99395c80d2fe7fed082 = $(`&lt;div id=&quot;html_455665047e1ea99395c80d2fe7fed082&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c080695bd2ffc26e42f79958163bc522.setContent(html_455665047e1ea99395c80d2fe7fed082);
#
#
#
#         marker_b313caebcd30b607f2e4bfebd0f3993f.bindPopup(popup_c080695bd2ffc26e42f79958163bc522)
#         ;
#
#
#
#
#             var marker_4f8d920c62210eb726418b22784d7907 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_20496c0e8e2284019a813f9c8768b146);
#
#
#         var popup_e119164484eaabc96f32d052febde26f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0fe4232ef63005fa3b1e4f58d5bbe0f = $(`&lt;div id=&quot;html_b0fe4232ef63005fa3b1e4f58d5bbe0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e119164484eaabc96f32d052febde26f.setContent(html_b0fe4232ef63005fa3b1e4f58d5bbe0f);
#
#
#
#         marker_4f8d920c62210eb726418b22784d7907.bindPopup(popup_e119164484eaabc96f32d052febde26f)
#         ;
#
#
#
#
#             var marker_cbc3ad910d6a1e36f3d809fa499bfba0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_20496c0e8e2284019a813f9c8768b146);
#
#
#         var popup_f8cd39bc3e2f3d7e3cf623b06ea58de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f745c70f8d32078af16c5ec5760d51d = $(`&lt;div id=&quot;html_0f745c70f8d32078af16c5ec5760d51d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f8cd39bc3e2f3d7e3cf623b06ea58de3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb895e44003f3a2af186dc9d2aa0d45b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb895e44003f3a2af186dc9d2aa0d45b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb895e44003f3a2af186dc9d2aa0d45b = L.map(
#                 &quot;map_bb895e44003f3a2af186dc9d2aa0d45b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d46cbf4507eae294320bf09b9f2743b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d46cbf4507eae294320bf09b9f2743b.addTo(map_bb895e44003f3a2af186dc9d2aa0d45b);
#
#
#             var feature_group_d1046848fb4bd597d22974b682fe1d4b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6653cc82768f40fb3bff8172bdbe86f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d1046848fb4bd597d22974b682fe1d4b);
#
#
#         var popup_644d04173fa130cbc2637144bbc95f04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4710f6d484a4a1ff5d610715e18fbefd = $(`&lt;div id=&quot;html_4710f6d484a4a1ff5d610715e18fbefd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_644d04173fa130cbc2637144bbc95f04.setContent(html_4710f6d484a4a1ff5d610715e18fbefd);
#
#
#
#         marker_6653cc82768f40fb3bff8172bdbe86f9.bindPopup(popup_644d04173fa130cbc2637144bbc95f04)
#         ;
#
#
#
#
#             var marker_21d322cec2465d6764f767d69cceef5f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d1046848fb4bd597d22974b682fe1d4b);
#
#
#         var popup_d876702f2a0baa16010d143ee15658fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5cc1fdd0c514e38dd288625d858d157d = $(`&lt;div id=&quot;html_5cc1fdd0c514e38dd288625d858d157d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d876702f2a0baa16010d143ee15658fd.setContent(html_5cc1fdd0c514e38dd288625d858d157d);
#
#
#
#         marker_21d322cec2465d6764f767d69cceef5f.bindPopup(popup_d876702f2a0baa16010d143ee15658fd)
#         ;
#
#
#
#
#             var marker_075c539338b89475849dd20beb8e6270 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d1046848fb4bd597d22974b682fe1d4b);
#
#
#         var popup_d4928fefc3a17836e46577bacc8ad216 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc6046cb04c0b9c133239761b957440d = $(`&lt;div id=&quot;html_bc6046cb04c0b9c133239761b957440d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d4928fefc3a17836e46577bacc8ad216.setContent(html_bc6046cb04c0b9c133239761b957440d);
#
#
#
#         marker_075c539338b89475849dd20beb8e6270.bindPopup(popup_d4928fefc3a17836e46577bacc8ad216)
#         ;
#
#
#
#
#             var marker_1cab53e11e032bac0c0a1ec06f45d88a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d1046848fb4bd597d22974b682fe1d4b);
#
#
#         var popup_9cf5716998ff47b99740ee3c821a3d21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67187765bc996c1e863c94aab8f77064 = $(`&lt;div id=&quot;html_67187765bc996c1e863c94aab8f77064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9cf5716998ff47b99740ee3c821a3d21.setContent(html_67187765bc996c1e863c94aab8f77064);
#
#
#
#         marker_1cab53e11e032bac0c0a1ec06f45d88a.bindPopup(popup_9cf5716998ff47b99740ee3c821a3d21)
#         ;
#
#
#
#
#             var marker_e6216a7cd742f18e05c81887ad6de3a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d1046848fb4bd597d22974b682fe1d4b);
#
#
#         var popup_2c0f42249d270a1f13c61f1a369e2fe0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaa2f072133cf7249c6d7f8895ea6891 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaa2f072133cf7249c6d7f8895ea6891&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eaa2f072133cf7249c6d7f8895ea6891 = L.map(
#                 &quot;map_eaa2f072133cf7249c6d7f8895ea6891&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ede8b715c1ba6c12db115dfe5c35eff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ede8b715c1ba6c12db115dfe5c35eff.addTo(map_eaa2f072133cf7249c6d7f8895ea6891);
#
#
#             var feature_group_901af0ea75a94e7a9230394f26192eeb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_901af0ea75a94e7a9230394f26192eeb.addTo(map_eaa2f072133cf7249c6d7f8895ea6891);
#
#
#             var feature_group_sub_group_ed04a7da14ec3e27d8556e6a6d9446fa = L.featureGroup.subGroup(
#                 feature_group_901af0ea75a94e7a9230394f26192eeb
#             );
#
#
#             var marker_9fa9ba041f4b2764f868b966424bf3d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed04a7da14ec3e27d8556e6a6d9446fa);
#
#
#         var popup_91e5cd71495acaa1da9dcee863fec373 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42ea364fa7ee146bd83063285249c704 = $(`&lt;div id=&quot;html_42ea364fa7ee146bd83063285249c704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_91e5cd71495acaa1da9dcee863fec373.setContent(html_42ea364fa7ee146bd83063285249c704);
#
#
#
#         marker_9fa9ba041f4b2764f868b966424bf3d8.bindPopup(popup_91e5cd71495acaa1da9dcee863fec373)
#         ;
#
#
#
#
#             var marker_cdcb197208f9cd68b7ab35487daf8848 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed04a7da14ec3e27d8556e6a6d9446fa);
#
#
#         var popup_fb2dd09d804d2655fb66c050efd8c765 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_828b972975918a0a754323e41214ffb0 = $(`&lt;div id=&quot;html_828b972975918a0a754323e41214ffb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fb2dd09d804d2655fb66c050efd8c765.setContent(html_828b972975918a0a754323e41214ffb0);
#
#
#
#         marker_cdcb197208f9cd68b7ab35487daf8848.bindPopup(popup_fb2dd09d804d2655fb66c050efd8c765)
#         ;
#
#
#
#
#             var marker_71ea8fbaaefe469a34b67a2c6e4efee5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed04a7da14ec3e27d8556e6a6d9446fa);
#
#
#         var popup_03d31de423209cf60d27a3d01687eb07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8384d5865f95d2eed12244945cb4b0a = $(`&lt;div id=&quot;html_f8384d5865f95d2eed12244945cb4b0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_03d31de423209cf60d27a3d01687eb07.setContent(html_f8384d5865f95d2eed12244945cb4b0a);
#
#
#
#         marker_71ea8fbaaefe469a34b67a2c6e4efee5.bindPopup(popup_03d31de423209cf60d27a3d01687eb07)
#         ;
#
#
#
#
#             var marker_1951ebdc8aff967058f5f280d14a7f2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed04a7da14ec3e27d8556e6a6d9446fa);
#
#
#         var popup_d8cd581662836043dbb44a514b41205f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c9f95c6cede6f46587f56d54e4edda4 = $(`&lt;div id=&quot;html_0c9f95c6cede6f46587f56d54e4edda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d8cd581662836043dbb44a514b41205f.setContent(html_0c9f95c6cede6f46587f56d54e4edda4);
#
#
#
#         marker_
