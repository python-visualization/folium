# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1ad5afb24fc4ada82076b59e094c622 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1ad5afb24fc4ada82076b59e094c622&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1ad5afb24fc4ada82076b59e094c622 = L.map(
#                 &quot;map_c1ad5afb24fc4ada82076b59e094c622&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8938c89595f1a2e76ac2ef5d3ec7ccd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8938c89595f1a2e76ac2ef5d3ec7ccd1.addTo(map_c1ad5afb24fc4ada82076b59e094c622);
#
#
#             var marker_70fa1eaa5497264264d468394cf0545a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c1ad5afb24fc4ada82076b59e094c622);
#
#
#         var popup_68340ea1cb94f4cf2e5b16b1f8345154 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2627b9ba0d20b6327deacb97cb743a9d = $(`&lt;div id=&quot;html_2627b9ba0d20b6327deacb97cb743a9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_68340ea1cb94f4cf2e5b16b1f8345154.setContent(html_2627b9ba0d20b6327deacb97cb743a9d);
#
#
#
#         marker_70fa1eaa5497264264d468394cf0545a.bindPopup(popup_68340ea1cb94f4cf2e5b16b1f8345154)
#         ;
#
#
#
#
#             var marker_4bcd2764a2d217b6981f92aa996422a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c1ad5afb24fc4ada82076b59e094c622);
#
#
#         var popup_aef45760b6d8dd25662c8efff9c01bf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de586c6cfaeffa37ed128f65ff4b54b7 = $(`&lt;div id=&quot;html_de586c6cfaeffa37ed128f65ff4b54b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aef45760b6d8dd25662c8efff9c01bf7.setContent(html_de586c6cfaeffa37ed128f65ff4b54b7);
#
#
#
#         marker_4bcd2764a2d217b6981f92aa996422a8.bindPopup(popup_aef45760b6d8dd25662c8efff9c01bf7)
#         ;
#
#
#
#
#             var marker_246d421c3d76742dc7f64229f1f50d3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c1ad5afb24fc4ada82076b59e094c622);
#
#
#         var popup_159f9627dfc3434741350738501d96c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_867fc6c7ef7c2676a90edaecd711aa05 = $(`&lt;div id=&quot;html_867fc6c7ef7c2676a90edaecd711aa05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_159f9627dfc3434741350738501d96c3.setContent(html_867fc6c7ef7c2676a90edaecd711aa05);
#
#
#
#         marker_246d421c3d76742dc7f64229f1f50d3e.bindPopup(popup_159f9627dfc3434741350738501d96c3)
#         ;
#
#
#
#
#             var marker_bd788e7b1d62eeb87843e3c06c5866da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c1ad5afb24fc4ada82076b59e094c622);
#
#
#         var popup_655095d01bf5e0493b60cb77a1629f5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_263cf9367abad4f2270381ef1161f604 = $(`&lt;div id=&quot;html_263cf9367abad4f2270381ef1161f604&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_655095d01bf5e0493b60cb77a1629f5c.setContent(html_263cf9367abad4f2270381ef1161f604);
#
#
#
#         marker_bd788e7b1d62eeb87843e3c06c5866da.bindPopup(popup_655095d01bf5e0493b60cb77a1629f5c)
#         ;
#
#
#
#
#             var marker_2177002e9173493600d7dd7a8fb39be1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c1ad5afb24fc4ada82076b59e094c622);
#
#
#         var popup_7fa244261df743f7726fd1b2663ae896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e88c2a502c10def0ce2179ed1fa6404 = $(`&lt;div id=&quot;html_2e88c2a502c10def0ce2179ed1fa6404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7fa244261df743f7726fd1b2663ae896.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af746a1e163ad00ed71c8af721a81605 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af746a1e163ad00ed71c8af721a81605&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af746a1e163ad00ed71c8af721a81605 = L.map(
#                 &quot;map_af746a1e163ad00ed71c8af721a81605&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99b4f17b3b4018d8fee3620ea5ccb613 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99b4f17b3b4018d8fee3620ea5ccb613.addTo(map_af746a1e163ad00ed71c8af721a81605);
#
#
#             var feature_group_454c4823ecb0b518b6f2e76c8e0d0be6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6d045f41cf44451e4f97be9fb55f1f9e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_454c4823ecb0b518b6f2e76c8e0d0be6);
#
#
#         var popup_03cbeaee23c49421d8a0943e74361402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_590412584ba59e3678a0b5946c1a5fb6 = $(`&lt;div id=&quot;html_590412584ba59e3678a0b5946c1a5fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_03cbeaee23c49421d8a0943e74361402.setContent(html_590412584ba59e3678a0b5946c1a5fb6);
#
#
#
#         marker_6d045f41cf44451e4f97be9fb55f1f9e.bindPopup(popup_03cbeaee23c49421d8a0943e74361402)
#         ;
#
#
#
#
#             var marker_9a8abae19d08e6939dbea6f8cc7bc79a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_454c4823ecb0b518b6f2e76c8e0d0be6);
#
#
#         var popup_1e9cd54130ba8cb957940dcd93f93352 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92b225de7ef70518422a15470746ff12 = $(`&lt;div id=&quot;html_92b225de7ef70518422a15470746ff12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1e9cd54130ba8cb957940dcd93f93352.setContent(html_92b225de7ef70518422a15470746ff12);
#
#
#
#         marker_9a8abae19d08e6939dbea6f8cc7bc79a.bindPopup(popup_1e9cd54130ba8cb957940dcd93f93352)
#         ;
#
#
#
#
#             var marker_4850d074a1964ecc92c17313a77e0e95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_454c4823ecb0b518b6f2e76c8e0d0be6);
#
#
#         var popup_43a2423ceae340490e0140b39fb5de42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bcf10afac30b810a57a447118f6f9ea = $(`&lt;div id=&quot;html_5bcf10afac30b810a57a447118f6f9ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_43a2423ceae340490e0140b39fb5de42.setContent(html_5bcf10afac30b810a57a447118f6f9ea);
#
#
#
#         marker_4850d074a1964ecc92c17313a77e0e95.bindPopup(popup_43a2423ceae340490e0140b39fb5de42)
#         ;
#
#
#
#
#             var marker_fc2574eb2877725f2c031b52868629db = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_454c4823ecb0b518b6f2e76c8e0d0be6);
#
#
#         var popup_441708edbdc2fcaf9b3219fcc54e9c44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_394027610368b97aa35e84c97c1440e7 = $(`&lt;div id=&quot;html_394027610368b97aa35e84c97c1440e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_441708edbdc2fcaf9b3219fcc54e9c44.setContent(html_394027610368b97aa35e84c97c1440e7);
#
#
#
#         marker_fc2574eb2877725f2c031b52868629db.bindPopup(popup_441708edbdc2fcaf9b3219fcc54e9c44)
#         ;
#
#
#
#
#             var marker_6b662f2a0ac798bd20aa399184630fbe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_454c4823ecb0b518b6f2e76c8e0d0be6);
#
#
#         var popup_2e8ff8d9d7b18c5ac362f45bf64c8527 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e46a030ab594801e1a6ff2d9e4140b26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e46a030ab594801e1a6ff2d9e4140b26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e46a030ab594801e1a6ff2d9e4140b26 = L.map(
#                 &quot;map_e46a030ab594801e1a6ff2d9e4140b26&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ab5cc8003a0b1e87076fd2c2ce202be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ab5cc8003a0b1e87076fd2c2ce202be.addTo(map_e46a030ab594801e1a6ff2d9e4140b26);
#
#
#             var feature_group_63863f0994aefc7e3d203e75ba31a571 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_63863f0994aefc7e3d203e75ba31a571.addTo(map_e46a030ab594801e1a6ff2d9e4140b26);
#
#
#             var feature_group_sub_group_549e4db8003ff4f688bd59340b626c5f = L.featureGroup.subGroup(
#                 feature_group_63863f0994aefc7e3d203e75ba31a571
#             );
#
#
#             var marker_8a349b9c6031d62232e6f40776762a5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_549e4db8003ff4f688bd59340b626c5f);
#
#
#         var popup_883ff2d620a896cc11b8a0f8823c196f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ced90cc64bed5914611523e5f0c3e54 = $(`&lt;div id=&quot;html_2ced90cc64bed5914611523e5f0c3e54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_883ff2d620a896cc11b8a0f8823c196f.setContent(html_2ced90cc64bed5914611523e5f0c3e54);
#
#
#
#         marker_8a349b9c6031d62232e6f40776762a5c.bindPopup(popup_883ff2d620a896cc11b8a0f8823c196f)
#         ;
#
#
#
#
#             var marker_6967ed709a455f8f1b94ce700c91005a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_549e4db8003ff4f688bd59340b626c5f);
#
#
#         var popup_ae2b4d6df0233e63528694b55e2fe0e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b72276c286272997ce70e153f8d2c10c = $(`&lt;div id=&quot;html_b72276c286272997ce70e153f8d2c10c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ae2b4d6df0233e63528694b55e2fe0e3.setContent(html_b72276c286272997ce70e153f8d2c10c);
#
#
#
#         marker_6967ed709a455f8f1b94ce700c91005a.bindPopup(popup_ae2b4d6df0233e63528694b55e2fe0e3)
#         ;
#
#
#
#
#             var marker_90fd21d6ae119a84bf30696706170b84 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_549e4db8003ff4f688bd59340b626c5f);
#
#
#         var popup_df8956adea77d951c6ebc78f545d8763 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2a3ca5fc762e80ba4ad97fe71f6a8a1 = $(`&lt;div id=&quot;html_d2a3ca5fc762e80ba4ad97fe71f6a8a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_df8956adea77d951c6ebc78f545d8763.setContent(html_d2a3ca5fc762e80ba4ad97fe71f6a8a1);
#
#
#
#         marker_90fd21d6ae119a84bf30696706170b84.bindPopup(popup_df8956adea77d951c6ebc78f545d8763)
#         ;
#
#
#
#
#             var marker_12c9648ecf04a6891483d5e161e08422 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_549e4db8003ff4f688bd59340b626c5f);
#
#
#         var popup_f9fe18c80dab4151111875a777d72020 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc221ebff0aab810500561c4e441b5f0 = $(`&lt;div id=&quot;html_bc221ebff0aab810500561c4e441b5f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f9fe18c80dab4151111875a777d72020.setContent(html_bc221ebff0aab810500561c4e441b5f0);
#
#
#
#         marker_
