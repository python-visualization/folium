# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb2130e4877ad08738638c4a0747f43e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb2130e4877ad08738638c4a0747f43e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb2130e4877ad08738638c4a0747f43e = L.map(
#                 &quot;map_bb2130e4877ad08738638c4a0747f43e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db14d967375652aa5d851d998a363eb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db14d967375652aa5d851d998a363eb6.addTo(map_bb2130e4877ad08738638c4a0747f43e);
#
#
#             var marker_889b8ba2f7fefe07f0f9e5dcc3bf58b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bb2130e4877ad08738638c4a0747f43e);
#
#
#         var popup_c53906afb670674b57f2efbe4b409355 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_776a4a36d93a6773356809fa40a2d400 = $(`&lt;div id=&quot;html_776a4a36d93a6773356809fa40a2d400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c53906afb670674b57f2efbe4b409355.setContent(html_776a4a36d93a6773356809fa40a2d400);
#
#
#
#         marker_889b8ba2f7fefe07f0f9e5dcc3bf58b5.bindPopup(popup_c53906afb670674b57f2efbe4b409355)
#         ;
#
#
#
#
#             var marker_50b41f028ed0bc73bd5aada0b9558528 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bb2130e4877ad08738638c4a0747f43e);
#
#
#         var popup_eaaf6447442e2872fbe198bcb2449edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11079c8ed9241c6370c38f1373ad21d1 = $(`&lt;div id=&quot;html_11079c8ed9241c6370c38f1373ad21d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eaaf6447442e2872fbe198bcb2449edc.setContent(html_11079c8ed9241c6370c38f1373ad21d1);
#
#
#
#         marker_50b41f028ed0bc73bd5aada0b9558528.bindPopup(popup_eaaf6447442e2872fbe198bcb2449edc)
#         ;
#
#
#
#
#             var marker_b2d4675e7c9258bb58e2c959a1575f34 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bb2130e4877ad08738638c4a0747f43e);
#
#
#         var popup_27d7455d4a551e157a93be4b38946b97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a725d3f9865167f0c80ff7742c06993f = $(`&lt;div id=&quot;html_a725d3f9865167f0c80ff7742c06993f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_27d7455d4a551e157a93be4b38946b97.setContent(html_a725d3f9865167f0c80ff7742c06993f);
#
#
#
#         marker_b2d4675e7c9258bb58e2c959a1575f34.bindPopup(popup_27d7455d4a551e157a93be4b38946b97)
#         ;
#
#
#
#
#             var marker_7478f842e5b9ae4f58fb701f304ab3e9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bb2130e4877ad08738638c4a0747f43e);
#
#
#         var popup_6e9946198aa0a8cf24aaaa0c8f3a8d07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51cc758f612963b1df5735cfc94bdbfb = $(`&lt;div id=&quot;html_51cc758f612963b1df5735cfc94bdbfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e9946198aa0a8cf24aaaa0c8f3a8d07.setContent(html_51cc758f612963b1df5735cfc94bdbfb);
#
#
#
#         marker_7478f842e5b9ae4f58fb701f304ab3e9.bindPopup(popup_6e9946198aa0a8cf24aaaa0c8f3a8d07)
#         ;
#
#
#
#
#             var marker_598e72117f7d217a0912f469d152afcd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bb2130e4877ad08738638c4a0747f43e);
#
#
#         var popup_184cb57dfee59b8cf05598dcb89dc823 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca04f9b569e7d493c6afe5f2fd0391e3 = $(`&lt;div id=&quot;html_ca04f9b569e7d493c6afe5f2fd0391e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_184cb57dfee59b8cf05598dcb89dc823.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47f5cb957f9a560de94505d1f9a934e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47f5cb957f9a560de94505d1f9a934e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47f5cb957f9a560de94505d1f9a934e6 = L.map(
#                 &quot;map_47f5cb957f9a560de94505d1f9a934e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb3867ce699253ead99a2d4b66aa7a3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb3867ce699253ead99a2d4b66aa7a3e.addTo(map_47f5cb957f9a560de94505d1f9a934e6);
#
#
#             var feature_group_579cd4037cedf5db6efb326dd123d09d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_de3b96a4bb06694cd83cd78f0729b987 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_579cd4037cedf5db6efb326dd123d09d);
#
#
#         var popup_b12648e5a26e112f0f503d3888280777 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ae8e8f4342ce1d35046c05a752d6bf5 = $(`&lt;div id=&quot;html_1ae8e8f4342ce1d35046c05a752d6bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b12648e5a26e112f0f503d3888280777.setContent(html_1ae8e8f4342ce1d35046c05a752d6bf5);
#
#
#
#         marker_de3b96a4bb06694cd83cd78f0729b987.bindPopup(popup_b12648e5a26e112f0f503d3888280777)
#         ;
#
#
#
#
#             var marker_a4fd5eecb2ac6bd785adf09cdaf86953 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_579cd4037cedf5db6efb326dd123d09d);
#
#
#         var popup_511a8fa81423c708177c21cd665d9135 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86dcfe4f37bb484f9cfd8fa46c9cd979 = $(`&lt;div id=&quot;html_86dcfe4f37bb484f9cfd8fa46c9cd979&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_511a8fa81423c708177c21cd665d9135.setContent(html_86dcfe4f37bb484f9cfd8fa46c9cd979);
#
#
#
#         marker_a4fd5eecb2ac6bd785adf09cdaf86953.bindPopup(popup_511a8fa81423c708177c21cd665d9135)
#         ;
#
#
#
#
#             var marker_0bd07f530c00866798ee9bfcc5b49e3b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_579cd4037cedf5db6efb326dd123d09d);
#
#
#         var popup_88bdeb78f396e20247fc689f5040dfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8faa12064eff44188056b946097f633f = $(`&lt;div id=&quot;html_8faa12064eff44188056b946097f633f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_88bdeb78f396e20247fc689f5040dfc5.setContent(html_8faa12064eff44188056b946097f633f);
#
#
#
#         marker_0bd07f530c00866798ee9bfcc5b49e3b.bindPopup(popup_88bdeb78f396e20247fc689f5040dfc5)
#         ;
#
#
#
#
#             var marker_964070c82dcbb3e995bfd6680397b0d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_579cd4037cedf5db6efb326dd123d09d);
#
#
#         var popup_f40f49f455d34e5a379e27a8e07bbad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ccdf254b8ec1d3d3219cd3c67f068f7 = $(`&lt;div id=&quot;html_5ccdf254b8ec1d3d3219cd3c67f068f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f40f49f455d34e5a379e27a8e07bbad1.setContent(html_5ccdf254b8ec1d3d3219cd3c67f068f7);
#
#
#
#         marker_964070c82dcbb3e995bfd6680397b0d9.bindPopup(popup_f40f49f455d34e5a379e27a8e07bbad1)
#         ;
#
#
#
#
#             var marker_00f1ea489e3c828910b0a13c6f1c8662 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_579cd4037cedf5db6efb326dd123d09d);
#
#
#         var popup_afd7e69e8554e1cc9c83bb69b7a21d8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b28aab5ab628070bca1ab61b4ddfe45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b28aab5ab628070bca1ab61b4ddfe45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b28aab5ab628070bca1ab61b4ddfe45 = L.map(
#                 &quot;map_2b28aab5ab628070bca1ab61b4ddfe45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e164a806048896f5ca56a62cfd77680 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e164a806048896f5ca56a62cfd77680.addTo(map_2b28aab5ab628070bca1ab61b4ddfe45);
#
#
#             var feature_group_64a68621be19fe30817f1c4f9a3f1641 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_64a68621be19fe30817f1c4f9a3f1641.addTo(map_2b28aab5ab628070bca1ab61b4ddfe45);
#
#
#             var feature_group_sub_group_cd5c64be779f8cbe353af605469951f2 = L.featureGroup.subGroup(
#                 feature_group_64a68621be19fe30817f1c4f9a3f1641
#             );
#
#
#             var marker_c105b1c9cdf40297200f0d4b16134fd9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd5c64be779f8cbe353af605469951f2);
#
#
#         var popup_47bdf08c9f5180f61e0b24a4cbeb93fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d1ec238c294f273852db52cb6d0d28d = $(`&lt;div id=&quot;html_5d1ec238c294f273852db52cb6d0d28d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_47bdf08c9f5180f61e0b24a4cbeb93fd.setContent(html_5d1ec238c294f273852db52cb6d0d28d);
#
#
#
#         marker_c105b1c9cdf40297200f0d4b16134fd9.bindPopup(popup_47bdf08c9f5180f61e0b24a4cbeb93fd)
#         ;
#
#
#
#
#             var marker_0c6e6b2d048f852cb20a58e4d984dec7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd5c64be779f8cbe353af605469951f2);
#
#
#         var popup_169ccb4f18a18805643a86940d0c4e2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7fd2157231033dc0213e407711ee084 = $(`&lt;div id=&quot;html_a7fd2157231033dc0213e407711ee084&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_169ccb4f18a18805643a86940d0c4e2d.setContent(html_a7fd2157231033dc0213e407711ee084);
#
#
#
#         marker_0c6e6b2d048f852cb20a58e4d984dec7.bindPopup(popup_169ccb4f18a18805643a86940d0c4e2d)
#         ;
#
#
#
#
#             var marker_57f6c03ee957135499b72eef0dec67bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd5c64be779f8cbe353af605469951f2);
#
#
#         var popup_65c90e93944c321a9647bf076f942a26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7419bc5f7ef7015388bd9d2dd22ddb86 = $(`&lt;div id=&quot;html_7419bc5f7ef7015388bd9d2dd22ddb86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_65c90e93944c321a9647bf076f942a26.setContent(html_7419bc5f7ef7015388bd9d2dd22ddb86);
#
#
#
#         marker_57f6c03ee957135499b72eef0dec67bd.bindPopup(popup_65c90e93944c321a9647bf076f942a26)
#         ;
#
#
#
#
#             var marker_a3c2c5898a31d18ebda864deeb48dad5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd5c64be779f8cbe353af605469951f2);
#
#
#         var popup_2a7de14c58c3e013fd1ce35ae3bf1b42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed2be0ca9b22abd584b05502e5b3d10a = $(`&lt;div id=&quot;html_ed2be0ca9b22abd584b05502e5b3d10a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2a7de14c58c3e013fd1ce35ae3bf1b42.setContent(html_ed2be0ca9b22abd584b05502e5b3d10a);
#
#
#
#         marker_
