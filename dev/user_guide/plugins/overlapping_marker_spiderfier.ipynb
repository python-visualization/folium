# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccaf516e15fa1250beb69640d7a730d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccaf516e15fa1250beb69640d7a730d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccaf516e15fa1250beb69640d7a730d1 = L.map(
#                 &quot;map_ccaf516e15fa1250beb69640d7a730d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8ff704c82fbe6648708ef35ccd0883a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8ff704c82fbe6648708ef35ccd0883a.addTo(map_ccaf516e15fa1250beb69640d7a730d1);
#
#
#             var marker_94517c20780cd5f9709fcc3b6d6012f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ccaf516e15fa1250beb69640d7a730d1);
#
#
#         var popup_224a44d5490b55a57ddf6db65620f53e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3350fe0021afc1501d926d69c654027 = $(`&lt;div id=&quot;html_d3350fe0021afc1501d926d69c654027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_224a44d5490b55a57ddf6db65620f53e.setContent(html_d3350fe0021afc1501d926d69c654027);
#
#
#
#         marker_94517c20780cd5f9709fcc3b6d6012f7.bindPopup(popup_224a44d5490b55a57ddf6db65620f53e)
#         ;
#
#
#
#
#             var marker_386eec8f21a766832e6a5a84e8c29e63 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ccaf516e15fa1250beb69640d7a730d1);
#
#
#         var popup_bfece3418b444700da5de8063c88ae21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_349a825d25951bcb2e3eec052a398e51 = $(`&lt;div id=&quot;html_349a825d25951bcb2e3eec052a398e51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bfece3418b444700da5de8063c88ae21.setContent(html_349a825d25951bcb2e3eec052a398e51);
#
#
#
#         marker_386eec8f21a766832e6a5a84e8c29e63.bindPopup(popup_bfece3418b444700da5de8063c88ae21)
#         ;
#
#
#
#
#             var marker_2c969ba69b74ad38d0873517b4729da1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ccaf516e15fa1250beb69640d7a730d1);
#
#
#         var popup_0af80257a951d6babcad943947070e96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eeb0d6e57e4eee29a97c1cc77963ffd = $(`&lt;div id=&quot;html_9eeb0d6e57e4eee29a97c1cc77963ffd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0af80257a951d6babcad943947070e96.setContent(html_9eeb0d6e57e4eee29a97c1cc77963ffd);
#
#
#
#         marker_2c969ba69b74ad38d0873517b4729da1.bindPopup(popup_0af80257a951d6babcad943947070e96)
#         ;
#
#
#
#
#             var marker_2d797b7b270d82d080a8a522e1a3dbb5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ccaf516e15fa1250beb69640d7a730d1);
#
#
#         var popup_133587412272381845facfc506e2d9e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_382d928d00f42c2d017d22548b10eecd = $(`&lt;div id=&quot;html_382d928d00f42c2d017d22548b10eecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_133587412272381845facfc506e2d9e9.setContent(html_382d928d00f42c2d017d22548b10eecd);
#
#
#
#         marker_2d797b7b270d82d080a8a522e1a3dbb5.bindPopup(popup_133587412272381845facfc506e2d9e9)
#         ;
#
#
#
#
#             var marker_ff973251cd47a5d8b12c81c8ef9a9bd2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ccaf516e15fa1250beb69640d7a730d1);
#
#
#         var popup_dfadc2c71b6870d2eef40735549924f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed18c4e045b904ad68fa7a0ec8c2ca92 = $(`&lt;div id=&quot;html_ed18c4e045b904ad68fa7a0ec8c2ca92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dfadc2c71b6870d2eef40735549924f5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09af1d8fd5e0b6e59ee83601c5c4aab9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09af1d8fd5e0b6e59ee83601c5c4aab9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09af1d8fd5e0b6e59ee83601c5c4aab9 = L.map(
#                 &quot;map_09af1d8fd5e0b6e59ee83601c5c4aab9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5f2883aca36ca78e057873284665638 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5f2883aca36ca78e057873284665638.addTo(map_09af1d8fd5e0b6e59ee83601c5c4aab9);
#
#
#             var feature_group_597f75c8f701a84b2e8c129497e2edd7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0e121189fbe0ddb092c73a7e4aed5e65 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_597f75c8f701a84b2e8c129497e2edd7);
#
#
#         var popup_66c31dc02edae4036c7fce70ec3607ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdd57ad833206974fb7a8d1651b7b053 = $(`&lt;div id=&quot;html_cdd57ad833206974fb7a8d1651b7b053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_66c31dc02edae4036c7fce70ec3607ca.setContent(html_cdd57ad833206974fb7a8d1651b7b053);
#
#
#
#         marker_0e121189fbe0ddb092c73a7e4aed5e65.bindPopup(popup_66c31dc02edae4036c7fce70ec3607ca)
#         ;
#
#
#
#
#             var marker_50390fdf9921bfc9a34fd5bb9ee3fbc8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_597f75c8f701a84b2e8c129497e2edd7);
#
#
#         var popup_94aed45858ddab28335e443fa3803e68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e886e99718d47da70b37d02640c15dd7 = $(`&lt;div id=&quot;html_e886e99718d47da70b37d02640c15dd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_94aed45858ddab28335e443fa3803e68.setContent(html_e886e99718d47da70b37d02640c15dd7);
#
#
#
#         marker_50390fdf9921bfc9a34fd5bb9ee3fbc8.bindPopup(popup_94aed45858ddab28335e443fa3803e68)
#         ;
#
#
#
#
#             var marker_dddf11eb27c119d6323907f883b63e76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_597f75c8f701a84b2e8c129497e2edd7);
#
#
#         var popup_78f01103f46be5fa47905863b2a24fd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c11e46d117442433d964c071076c27e = $(`&lt;div id=&quot;html_3c11e46d117442433d964c071076c27e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_78f01103f46be5fa47905863b2a24fd4.setContent(html_3c11e46d117442433d964c071076c27e);
#
#
#
#         marker_dddf11eb27c119d6323907f883b63e76.bindPopup(popup_78f01103f46be5fa47905863b2a24fd4)
#         ;
#
#
#
#
#             var marker_a11dc9d2e1daeaa2c3849a9b2fdc5055 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_597f75c8f701a84b2e8c129497e2edd7);
#
#
#         var popup_117db79ab372a256f2c02688173db186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa89122d9f5bdad37a59e06c63be091e = $(`&lt;div id=&quot;html_aa89122d9f5bdad37a59e06c63be091e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_117db79ab372a256f2c02688173db186.setContent(html_aa89122d9f5bdad37a59e06c63be091e);
#
#
#
#         marker_a11dc9d2e1daeaa2c3849a9b2fdc5055.bindPopup(popup_117db79ab372a256f2c02688173db186)
#         ;
#
#
#
#
#             var marker_9972611a581b8597aa831e44d23d85bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_597f75c8f701a84b2e8c129497e2edd7);
#
#
#         var popup_ac7736d2e09b9a235c77710351bc7ed0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6000738e9fce46f47c409fc472d1c6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6000738e9fce46f47c409fc472d1c6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6000738e9fce46f47c409fc472d1c6f = L.map(
#                 &quot;map_a6000738e9fce46f47c409fc472d1c6f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f340ee217bae3eb97830cd68af36c360 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f340ee217bae3eb97830cd68af36c360.addTo(map_a6000738e9fce46f47c409fc472d1c6f);
#
#
#             var feature_group_c7cf628b3f192f75cd2830785702c883 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c7cf628b3f192f75cd2830785702c883.addTo(map_a6000738e9fce46f47c409fc472d1c6f);
#
#
#             var feature_group_sub_group_17c20b3fc4aa1e1cf74d9e8a67a7d222 = L.featureGroup.subGroup(
#                 feature_group_c7cf628b3f192f75cd2830785702c883
#             );
#
#
#             var marker_bb93d4b8950393d4f678b3668b070ca2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_17c20b3fc4aa1e1cf74d9e8a67a7d222);
#
#
#         var popup_3baa6475320d706369cbd63d8d7f83c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a62429a55cb6f0e34eb0a35ac8bd6024 = $(`&lt;div id=&quot;html_a62429a55cb6f0e34eb0a35ac8bd6024&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3baa6475320d706369cbd63d8d7f83c8.setContent(html_a62429a55cb6f0e34eb0a35ac8bd6024);
#
#
#
#         marker_bb93d4b8950393d4f678b3668b070ca2.bindPopup(popup_3baa6475320d706369cbd63d8d7f83c8)
#         ;
#
#
#
#
#             var marker_0e19fcb9175a08e09e42f287379b000d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_17c20b3fc4aa1e1cf74d9e8a67a7d222);
#
#
#         var popup_e631232a353507001ebaab25c351e421 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7083705eafe998a2eec1eb1a2c7fc546 = $(`&lt;div id=&quot;html_7083705eafe998a2eec1eb1a2c7fc546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e631232a353507001ebaab25c351e421.setContent(html_7083705eafe998a2eec1eb1a2c7fc546);
#
#
#
#         marker_0e19fcb9175a08e09e42f287379b000d.bindPopup(popup_e631232a353507001ebaab25c351e421)
#         ;
#
#
#
#
#             var marker_7e0d483b31117326a33c58ff884506c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_17c20b3fc4aa1e1cf74d9e8a67a7d222);
#
#
#         var popup_06d451a1cbbef77cd1ba71312a701b08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05411080f2c24a27e2160ed3a0fe56e9 = $(`&lt;div id=&quot;html_05411080f2c24a27e2160ed3a0fe56e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_06d451a1cbbef77cd1ba71312a701b08.setContent(html_05411080f2c24a27e2160ed3a0fe56e9);
#
#
#
#         marker_7e0d483b31117326a33c58ff884506c2.bindPopup(popup_06d451a1cbbef77cd1ba71312a701b08)
#         ;
#
#
#
#
#             var marker_5ac8a66f9cf31a9c6255b7403841eb44 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_17c20b3fc4aa1e1cf74d9e8a67a7d222);
#
#
#         var popup_e89331818f464698d5f6726dc6a005b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_076285345914c3a42310efbffb127715 = $(`&lt;div id=&quot;html_076285345914c3a42310efbffb127715&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e89331818f464698d5f6726dc6a005b6.setContent(html_076285345914c3a42310efbffb127715);
#
#
#
#         marker_
