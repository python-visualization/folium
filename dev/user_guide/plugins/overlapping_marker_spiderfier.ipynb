# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16a9a29f67f98d8f92f8836703c69719 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16a9a29f67f98d8f92f8836703c69719&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16a9a29f67f98d8f92f8836703c69719 = L.map(
#                 &quot;map_16a9a29f67f98d8f92f8836703c69719&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92ac912c00e364fdbdca57b3529d3563 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92ac912c00e364fdbdca57b3529d3563.addTo(map_16a9a29f67f98d8f92f8836703c69719);
#
#
#             var marker_be090ef0a1551e1ad8ca8b1b18731c00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_16a9a29f67f98d8f92f8836703c69719);
#
#
#         var popup_e0cb53c9dd306f987cf40684521f377b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e7d4b49049859416005e55cf4bc03f3 = $(`&lt;div id=&quot;html_2e7d4b49049859416005e55cf4bc03f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e0cb53c9dd306f987cf40684521f377b.setContent(html_2e7d4b49049859416005e55cf4bc03f3);
#
#
#
#         marker_be090ef0a1551e1ad8ca8b1b18731c00.bindPopup(popup_e0cb53c9dd306f987cf40684521f377b)
#         ;
#
#
#
#
#             var marker_67c31842c3011cf90420b8c0ba23b20d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_16a9a29f67f98d8f92f8836703c69719);
#
#
#         var popup_815e49710c6ac3267c29486fdb2c5fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_138a0da5a56a615bbb78b32e6bcd2559 = $(`&lt;div id=&quot;html_138a0da5a56a615bbb78b32e6bcd2559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_815e49710c6ac3267c29486fdb2c5fcf.setContent(html_138a0da5a56a615bbb78b32e6bcd2559);
#
#
#
#         marker_67c31842c3011cf90420b8c0ba23b20d.bindPopup(popup_815e49710c6ac3267c29486fdb2c5fcf)
#         ;
#
#
#
#
#             var marker_e6609abc1c4ad863d0abb6dad8e6d80d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_16a9a29f67f98d8f92f8836703c69719);
#
#
#         var popup_f44717d0b75ee7f5e8345d5a201005d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8ac5c663e928d387c2c242b5fccfd37 = $(`&lt;div id=&quot;html_a8ac5c663e928d387c2c242b5fccfd37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f44717d0b75ee7f5e8345d5a201005d6.setContent(html_a8ac5c663e928d387c2c242b5fccfd37);
#
#
#
#         marker_e6609abc1c4ad863d0abb6dad8e6d80d.bindPopup(popup_f44717d0b75ee7f5e8345d5a201005d6)
#         ;
#
#
#
#
#             var marker_7641a67167207f8b504ae995f9989784 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_16a9a29f67f98d8f92f8836703c69719);
#
#
#         var popup_dff6cd926105936f979c792dd8821c70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2288deff8b6e2ced2918e87d3cf299f = $(`&lt;div id=&quot;html_b2288deff8b6e2ced2918e87d3cf299f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dff6cd926105936f979c792dd8821c70.setContent(html_b2288deff8b6e2ced2918e87d3cf299f);
#
#
#
#         marker_7641a67167207f8b504ae995f9989784.bindPopup(popup_dff6cd926105936f979c792dd8821c70)
#         ;
#
#
#
#
#             var marker_f03fdc29469892013c2a979c6dd52f27 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_16a9a29f67f98d8f92f8836703c69719);
#
#
#         var popup_b357f1434b13d99e9683f8a4d7fd57ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d5f428a88109b887df2107c2469262b = $(`&lt;div id=&quot;html_5d5f428a88109b887df2107c2469262b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b357f1434b13d99e9683f8a4d7fd57ea.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d5a88f0b7047d16b040a6eeeee7e83f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d5a88f0b7047d16b040a6eeeee7e83f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d5a88f0b7047d16b040a6eeeee7e83f = L.map(
#                 &quot;map_3d5a88f0b7047d16b040a6eeeee7e83f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a243518d2ff5262206a446032101d8ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a243518d2ff5262206a446032101d8ef.addTo(map_3d5a88f0b7047d16b040a6eeeee7e83f);
#
#
#             var feature_group_7f92935e6e64c1526f7b84590af1d94c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e192bc2a68ea0194f25433e60e66a64d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f92935e6e64c1526f7b84590af1d94c);
#
#
#         var popup_59feb0a925d14a904fc36f5979747c55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e78eb47e4c318c5c007a011121ce07bc = $(`&lt;div id=&quot;html_e78eb47e4c318c5c007a011121ce07bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_59feb0a925d14a904fc36f5979747c55.setContent(html_e78eb47e4c318c5c007a011121ce07bc);
#
#
#
#         marker_e192bc2a68ea0194f25433e60e66a64d.bindPopup(popup_59feb0a925d14a904fc36f5979747c55)
#         ;
#
#
#
#
#             var marker_899971412ca4ff249588f17b1e6cfbdc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f92935e6e64c1526f7b84590af1d94c);
#
#
#         var popup_8c4c88e7ca5cc3019aded34a2b5de429 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d523a221df03e41c319b69e99e5a7900 = $(`&lt;div id=&quot;html_d523a221df03e41c319b69e99e5a7900&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8c4c88e7ca5cc3019aded34a2b5de429.setContent(html_d523a221df03e41c319b69e99e5a7900);
#
#
#
#         marker_899971412ca4ff249588f17b1e6cfbdc.bindPopup(popup_8c4c88e7ca5cc3019aded34a2b5de429)
#         ;
#
#
#
#
#             var marker_92e12ef1ec06e59a04cf6f0f7df53256 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f92935e6e64c1526f7b84590af1d94c);
#
#
#         var popup_3747922d3c9bd88290a998905822d562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_661b6061c201619e7f96b78db5623598 = $(`&lt;div id=&quot;html_661b6061c201619e7f96b78db5623598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3747922d3c9bd88290a998905822d562.setContent(html_661b6061c201619e7f96b78db5623598);
#
#
#
#         marker_92e12ef1ec06e59a04cf6f0f7df53256.bindPopup(popup_3747922d3c9bd88290a998905822d562)
#         ;
#
#
#
#
#             var marker_14293ffdc4d77fb9583523bb8faa525c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f92935e6e64c1526f7b84590af1d94c);
#
#
#         var popup_d99f113b290136096affb35445859b14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6284bb2dc032b4f99393ae07a0969677 = $(`&lt;div id=&quot;html_6284bb2dc032b4f99393ae07a0969677&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d99f113b290136096affb35445859b14.setContent(html_6284bb2dc032b4f99393ae07a0969677);
#
#
#
#         marker_14293ffdc4d77fb9583523bb8faa525c.bindPopup(popup_d99f113b290136096affb35445859b14)
#         ;
#
#
#
#
#             var marker_0204eb0d2ae5a881b4b9a3bbb82e501e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f92935e6e64c1526f7b84590af1d94c);
#
#
#         var popup_0d1bc78ed3cf161f4e2cfc7fd3e21f20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28d48f6e5164acbcf4954a7509b6bd00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28d48f6e5164acbcf4954a7509b6bd00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28d48f6e5164acbcf4954a7509b6bd00 = L.map(
#                 &quot;map_28d48f6e5164acbcf4954a7509b6bd00&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8693c196e0468c725c581754b1cf52bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8693c196e0468c725c581754b1cf52bc.addTo(map_28d48f6e5164acbcf4954a7509b6bd00);
#
#
#             var feature_group_21f68f5dea3bbdae65b47c214b15e488 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_21f68f5dea3bbdae65b47c214b15e488.addTo(map_28d48f6e5164acbcf4954a7509b6bd00);
#
#
#             var feature_group_sub_group_90171be82dbe2be7c90233509c2ccd94 = L.featureGroup.subGroup(
#                 feature_group_21f68f5dea3bbdae65b47c214b15e488
#             );
#
#
#             var marker_364c353075721fdca07831968d008a16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_90171be82dbe2be7c90233509c2ccd94);
#
#
#         var popup_f02ca02e4f5f8e934bd9ee8293244b83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e63474f97b52ced6e2a9a94646b19a8d = $(`&lt;div id=&quot;html_e63474f97b52ced6e2a9a94646b19a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f02ca02e4f5f8e934bd9ee8293244b83.setContent(html_e63474f97b52ced6e2a9a94646b19a8d);
#
#
#
#         marker_364c353075721fdca07831968d008a16.bindPopup(popup_f02ca02e4f5f8e934bd9ee8293244b83)
#         ;
#
#
#
#
#             var marker_441a406700e0edce5a7ee919d825fab3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_90171be82dbe2be7c90233509c2ccd94);
#
#
#         var popup_968bb0b460d297eb90221a508da6a178 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a2599a9f32a191a1de6d5e94868b494 = $(`&lt;div id=&quot;html_1a2599a9f32a191a1de6d5e94868b494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_968bb0b460d297eb90221a508da6a178.setContent(html_1a2599a9f32a191a1de6d5e94868b494);
#
#
#
#         marker_441a406700e0edce5a7ee919d825fab3.bindPopup(popup_968bb0b460d297eb90221a508da6a178)
#         ;
#
#
#
#
#             var marker_a7f3b65eb8178003c271acdfb2c33e2f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_90171be82dbe2be7c90233509c2ccd94);
#
#
#         var popup_bad8d955f897282c0c99bde3a31b7e07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3c0b52160b52d3297bf29020362edf3 = $(`&lt;div id=&quot;html_f3c0b52160b52d3297bf29020362edf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bad8d955f897282c0c99bde3a31b7e07.setContent(html_f3c0b52160b52d3297bf29020362edf3);
#
#
#
#         marker_a7f3b65eb8178003c271acdfb2c33e2f.bindPopup(popup_bad8d955f897282c0c99bde3a31b7e07)
#         ;
#
#
#
#
#             var marker_e71facf01e99517b82286a1d33ad07f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_90171be82dbe2be7c90233509c2ccd94);
#
#
#         var popup_257c09b65320ee81ed4759c9dd0b6a18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f793309f321cf6e3409d3fb8d265122e = $(`&lt;div id=&quot;html_f793309f321cf6e3409d3fb8d265122e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_257c09b65320ee81ed4759c9dd0b6a18.setContent(html_f793309f321cf6e3409d3fb8d265122e);
#
#
#
#         marker_
