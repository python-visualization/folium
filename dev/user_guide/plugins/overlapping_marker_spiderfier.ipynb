# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_803cbbb6d28e276b2ef67d2b34e4bfab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_803cbbb6d28e276b2ef67d2b34e4bfab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_803cbbb6d28e276b2ef67d2b34e4bfab = L.map(
#                 &quot;map_803cbbb6d28e276b2ef67d2b34e4bfab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48e410f7dae2a24adbed137350feeb24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48e410f7dae2a24adbed137350feeb24.addTo(map_803cbbb6d28e276b2ef67d2b34e4bfab);
#
#
#             var marker_28e9f594def9ceaf028333c30e439981 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_803cbbb6d28e276b2ef67d2b34e4bfab);
#
#
#         var popup_48aa73ef0d3727b2aebceaba2cc4b1dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10172fa21d9ff2d25a2c6e7c77c3a209 = $(`&lt;div id=&quot;html_10172fa21d9ff2d25a2c6e7c77c3a209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_48aa73ef0d3727b2aebceaba2cc4b1dc.setContent(html_10172fa21d9ff2d25a2c6e7c77c3a209);
#
#
#
#         marker_28e9f594def9ceaf028333c30e439981.bindPopup(popup_48aa73ef0d3727b2aebceaba2cc4b1dc)
#         ;
#
#
#
#
#             var marker_122284a824994d1cfd0fa84296b1dca7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_803cbbb6d28e276b2ef67d2b34e4bfab);
#
#
#         var popup_31161aaab1682e93d40de7044d815f5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84211c33eb0ffeb411b8a811cbbe5a48 = $(`&lt;div id=&quot;html_84211c33eb0ffeb411b8a811cbbe5a48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_31161aaab1682e93d40de7044d815f5b.setContent(html_84211c33eb0ffeb411b8a811cbbe5a48);
#
#
#
#         marker_122284a824994d1cfd0fa84296b1dca7.bindPopup(popup_31161aaab1682e93d40de7044d815f5b)
#         ;
#
#
#
#
#             var marker_6c2050aaa879de1ef72d4f2c8500e168 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_803cbbb6d28e276b2ef67d2b34e4bfab);
#
#
#         var popup_283c1173794237cbfffa2cd1f52ece4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6b2e9b57304d10905817577a8c71e2c = $(`&lt;div id=&quot;html_b6b2e9b57304d10905817577a8c71e2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_283c1173794237cbfffa2cd1f52ece4c.setContent(html_b6b2e9b57304d10905817577a8c71e2c);
#
#
#
#         marker_6c2050aaa879de1ef72d4f2c8500e168.bindPopup(popup_283c1173794237cbfffa2cd1f52ece4c)
#         ;
#
#
#
#
#             var marker_599c4068689f615e9e5e3a819eb92a06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_803cbbb6d28e276b2ef67d2b34e4bfab);
#
#
#         var popup_71738f76cd750c9b7b3acc5a56bb1d3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_088c3098c65048c77aaa00336538758b = $(`&lt;div id=&quot;html_088c3098c65048c77aaa00336538758b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_71738f76cd750c9b7b3acc5a56bb1d3c.setContent(html_088c3098c65048c77aaa00336538758b);
#
#
#
#         marker_599c4068689f615e9e5e3a819eb92a06.bindPopup(popup_71738f76cd750c9b7b3acc5a56bb1d3c)
#         ;
#
#
#
#
#             var marker_0a1108aff8055543561a2705fe00cfef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_803cbbb6d28e276b2ef67d2b34e4bfab);
#
#
#         var popup_89671930987a82ec1f4622491d543e23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb980d061d6fea342a59575dcb77700b = $(`&lt;div id=&quot;html_bb980d061d6fea342a59575dcb77700b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_89671930987a82ec1f4622491d543e23.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac4202584528cfe56d3edd11dbfff3d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac4202584528cfe56d3edd11dbfff3d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac4202584528cfe56d3edd11dbfff3d3 = L.map(
#                 &quot;map_ac4202584528cfe56d3edd11dbfff3d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_069bbe6d1dde0576137a7f9b58b073ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_069bbe6d1dde0576137a7f9b58b073ab.addTo(map_ac4202584528cfe56d3edd11dbfff3d3);
#
#
#             var feature_group_451a2456c2913a5efc843a341dcaa65f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_510902855d11f6198fb33c99136ebf78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_451a2456c2913a5efc843a341dcaa65f);
#
#
#         var popup_458843d18d40e71482512935006d9aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecda86135597c7ff7839028c6b916baa = $(`&lt;div id=&quot;html_ecda86135597c7ff7839028c6b916baa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_458843d18d40e71482512935006d9aed.setContent(html_ecda86135597c7ff7839028c6b916baa);
#
#
#
#         marker_510902855d11f6198fb33c99136ebf78.bindPopup(popup_458843d18d40e71482512935006d9aed)
#         ;
#
#
#
#
#             var marker_2002d76a690a0f137f1311bbc615a788 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_451a2456c2913a5efc843a341dcaa65f);
#
#
#         var popup_dbbeb971c111bef7de968c557b6938d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_579b3f821ba0f7e12ea1c1e211990599 = $(`&lt;div id=&quot;html_579b3f821ba0f7e12ea1c1e211990599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dbbeb971c111bef7de968c557b6938d9.setContent(html_579b3f821ba0f7e12ea1c1e211990599);
#
#
#
#         marker_2002d76a690a0f137f1311bbc615a788.bindPopup(popup_dbbeb971c111bef7de968c557b6938d9)
#         ;
#
#
#
#
#             var marker_e0cd3160f1051840f45e1823be4fc716 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_451a2456c2913a5efc843a341dcaa65f);
#
#
#         var popup_3ebf5dbe07a4b9eb1ac69d65e8153d66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89fa5cf4033a1ac478deb355ff8a927a = $(`&lt;div id=&quot;html_89fa5cf4033a1ac478deb355ff8a927a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3ebf5dbe07a4b9eb1ac69d65e8153d66.setContent(html_89fa5cf4033a1ac478deb355ff8a927a);
#
#
#
#         marker_e0cd3160f1051840f45e1823be4fc716.bindPopup(popup_3ebf5dbe07a4b9eb1ac69d65e8153d66)
#         ;
#
#
#
#
#             var marker_aeb67499bd97e23fe736ee32c1779b89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_451a2456c2913a5efc843a341dcaa65f);
#
#
#         var popup_19be6d4eba044f9ffd3a2b004be80467 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_138033f20dc91b4b9a92e4d00749fb45 = $(`&lt;div id=&quot;html_138033f20dc91b4b9a92e4d00749fb45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_19be6d4eba044f9ffd3a2b004be80467.setContent(html_138033f20dc91b4b9a92e4d00749fb45);
#
#
#
#         marker_aeb67499bd97e23fe736ee32c1779b89.bindPopup(popup_19be6d4eba044f9ffd3a2b004be80467)
#         ;
#
#
#
#
#             var marker_e31e5ae141e3d0693d577dfc491ca181 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_451a2456c2913a5efc843a341dcaa65f);
#
#
#         var popup_bf7a06027745c49b2682f0351fa08883 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08a17bed5f48daa5fd4dbf22189e68a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08a17bed5f48daa5fd4dbf22189e68a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08a17bed5f48daa5fd4dbf22189e68a4 = L.map(
#                 &quot;map_08a17bed5f48daa5fd4dbf22189e68a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bece7d31bab376c28d2e2978082d7d1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bece7d31bab376c28d2e2978082d7d1a.addTo(map_08a17bed5f48daa5fd4dbf22189e68a4);
#
#
#             var feature_group_e13e26e2c11472a992972a7ef08ffb9b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e13e26e2c11472a992972a7ef08ffb9b.addTo(map_08a17bed5f48daa5fd4dbf22189e68a4);
#
#
#             var feature_group_sub_group_f34c78d95221de7528fa1396b13acd33 = L.featureGroup.subGroup(
#                 feature_group_e13e26e2c11472a992972a7ef08ffb9b
#             );
#
#
#             var marker_0fc2410fba4d05e37d8f981520173e5a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f34c78d95221de7528fa1396b13acd33);
#
#
#         var popup_fd74b7401eec394648070c68f109dbfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c3cf31c38f566b2f217ffd3451cb86d = $(`&lt;div id=&quot;html_4c3cf31c38f566b2f217ffd3451cb86d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fd74b7401eec394648070c68f109dbfd.setContent(html_4c3cf31c38f566b2f217ffd3451cb86d);
#
#
#
#         marker_0fc2410fba4d05e37d8f981520173e5a.bindPopup(popup_fd74b7401eec394648070c68f109dbfd)
#         ;
#
#
#
#
#             var marker_5d0210763584cdb0cee9ad3a5d0ed404 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f34c78d95221de7528fa1396b13acd33);
#
#
#         var popup_2453955d61d628206500d327c8c81858 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87b8240e610afdfa36e832a02cbf44cc = $(`&lt;div id=&quot;html_87b8240e610afdfa36e832a02cbf44cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2453955d61d628206500d327c8c81858.setContent(html_87b8240e610afdfa36e832a02cbf44cc);
#
#
#
#         marker_5d0210763584cdb0cee9ad3a5d0ed404.bindPopup(popup_2453955d61d628206500d327c8c81858)
#         ;
#
#
#
#
#             var marker_1b22c47f6e3c2977c3ea3ce2d9d7e806 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f34c78d95221de7528fa1396b13acd33);
#
#
#         var popup_23fcc6b052e12e375038ddaa68297067 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1efbb072013f71e11e2323df9c5bc9c = $(`&lt;div id=&quot;html_e1efbb072013f71e11e2323df9c5bc9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_23fcc6b052e12e375038ddaa68297067.setContent(html_e1efbb072013f71e11e2323df9c5bc9c);
#
#
#
#         marker_1b22c47f6e3c2977c3ea3ce2d9d7e806.bindPopup(popup_23fcc6b052e12e375038ddaa68297067)
#         ;
#
#
#
#
#             var marker_d3d0b48fbfe162f0e2ac29e7adcdb1d1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f34c78d95221de7528fa1396b13acd33);
#
#
#         var popup_9b589516a10b166dff2d7cf684362226 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bdbfcf9a23291a48e3c82e743521c17 = $(`&lt;div id=&quot;html_6bdbfcf9a23291a48e3c82e743521c17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9b589516a10b166dff2d7cf684362226.setContent(html_6bdbfcf9a23291a48e3c82e743521c17);
#
#
#
#         marker_
