# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_081eed5e61896ef60d2c1535fcafb881 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_081eed5e61896ef60d2c1535fcafb881&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_081eed5e61896ef60d2c1535fcafb881 = L.map(
#                 &quot;map_081eed5e61896ef60d2c1535fcafb881&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ff1ece9703deaf2da68e72b56bb0515 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ff1ece9703deaf2da68e72b56bb0515.addTo(map_081eed5e61896ef60d2c1535fcafb881);
#
#
#             var marker_7a3e7e4996cacfde32e3aff1b4cb420f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_081eed5e61896ef60d2c1535fcafb881);
#
#
#         var popup_2ae059a38d1b1135c16a5092be25a5eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b41bda2b216804cf7d232d30a506d3cc = $(`&lt;div id=&quot;html_b41bda2b216804cf7d232d30a506d3cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2ae059a38d1b1135c16a5092be25a5eb.setContent(html_b41bda2b216804cf7d232d30a506d3cc);
#
#
#
#         marker_7a3e7e4996cacfde32e3aff1b4cb420f.bindPopup(popup_2ae059a38d1b1135c16a5092be25a5eb)
#         ;
#
#
#
#
#             var marker_9400268d22f141d8ce783c4f4f5d2b7b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_081eed5e61896ef60d2c1535fcafb881);
#
#
#         var popup_60bf69755db20f7549371ef2c6bbc1f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bcf3ca68323ab4c4602dc6190c1ce03 = $(`&lt;div id=&quot;html_3bcf3ca68323ab4c4602dc6190c1ce03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_60bf69755db20f7549371ef2c6bbc1f5.setContent(html_3bcf3ca68323ab4c4602dc6190c1ce03);
#
#
#
#         marker_9400268d22f141d8ce783c4f4f5d2b7b.bindPopup(popup_60bf69755db20f7549371ef2c6bbc1f5)
#         ;
#
#
#
#
#             var marker_172d3f5323acc8f6b6a59788b690fc4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_081eed5e61896ef60d2c1535fcafb881);
#
#
#         var popup_87833de682ee16c25d96dfa22a2dcde8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e27c33b4aa8efce6b905ee2254085080 = $(`&lt;div id=&quot;html_e27c33b4aa8efce6b905ee2254085080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_87833de682ee16c25d96dfa22a2dcde8.setContent(html_e27c33b4aa8efce6b905ee2254085080);
#
#
#
#         marker_172d3f5323acc8f6b6a59788b690fc4e.bindPopup(popup_87833de682ee16c25d96dfa22a2dcde8)
#         ;
#
#
#
#
#             var marker_aebed6222d29514090446aef62570e92 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_081eed5e61896ef60d2c1535fcafb881);
#
#
#         var popup_f0e9947a67a5c1f6998c399171a8f78e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1e3c42bcc20cf6211b47bf5732accc0 = $(`&lt;div id=&quot;html_c1e3c42bcc20cf6211b47bf5732accc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f0e9947a67a5c1f6998c399171a8f78e.setContent(html_c1e3c42bcc20cf6211b47bf5732accc0);
#
#
#
#         marker_aebed6222d29514090446aef62570e92.bindPopup(popup_f0e9947a67a5c1f6998c399171a8f78e)
#         ;
#
#
#
#
#             var marker_ab9fe04cfc0c8aa0b8b213df91034d37 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_081eed5e61896ef60d2c1535fcafb881);
#
#
#         var popup_fc9e243456b206a6976f7fc302cd1f77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d49e0d2320b18b8551494fa661ef69a = $(`&lt;div id=&quot;html_7d49e0d2320b18b8551494fa661ef69a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fc9e243456b206a6976f7fc302cd1f77.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9ec6be06e28542bbadf1d66eb861346 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9ec6be06e28542bbadf1d66eb861346&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9ec6be06e28542bbadf1d66eb861346 = L.map(
#                 &quot;map_c9ec6be06e28542bbadf1d66eb861346&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_773082943be421ac99bba5ac75838d6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_773082943be421ac99bba5ac75838d6e.addTo(map_c9ec6be06e28542bbadf1d66eb861346);
#
#
#             var feature_group_09d49be22424e93713467a3730ee89fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b0c46fb0137f35d5d56a40a6530f73bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_09d49be22424e93713467a3730ee89fa);
#
#
#         var popup_1d1ee49739c128d582b8fd9053066946 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33b74d128f91dc85150dda9dad19613c = $(`&lt;div id=&quot;html_33b74d128f91dc85150dda9dad19613c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1d1ee49739c128d582b8fd9053066946.setContent(html_33b74d128f91dc85150dda9dad19613c);
#
#
#
#         marker_b0c46fb0137f35d5d56a40a6530f73bf.bindPopup(popup_1d1ee49739c128d582b8fd9053066946)
#         ;
#
#
#
#
#             var marker_63bac7ba4af05a06e152527004c922ba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_09d49be22424e93713467a3730ee89fa);
#
#
#         var popup_9a023823b55ae28e9583a3baa323452a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d06bbbd69a58ee746623d0b076af7351 = $(`&lt;div id=&quot;html_d06bbbd69a58ee746623d0b076af7351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9a023823b55ae28e9583a3baa323452a.setContent(html_d06bbbd69a58ee746623d0b076af7351);
#
#
#
#         marker_63bac7ba4af05a06e152527004c922ba.bindPopup(popup_9a023823b55ae28e9583a3baa323452a)
#         ;
#
#
#
#
#             var marker_4170bc09a1d7533f231b51cc4c9c0840 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_09d49be22424e93713467a3730ee89fa);
#
#
#         var popup_a7d2fe367e717459af22d944289c1aaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26ca956d1a65a3fcc545993ca71a5549 = $(`&lt;div id=&quot;html_26ca956d1a65a3fcc545993ca71a5549&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a7d2fe367e717459af22d944289c1aaf.setContent(html_26ca956d1a65a3fcc545993ca71a5549);
#
#
#
#         marker_4170bc09a1d7533f231b51cc4c9c0840.bindPopup(popup_a7d2fe367e717459af22d944289c1aaf)
#         ;
#
#
#
#
#             var marker_e239fb5c6e6db0d0044a3541f3e187a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_09d49be22424e93713467a3730ee89fa);
#
#
#         var popup_0cd8350aaa5b2f4e05bd29dc72ab4f57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_583a52f0e24686f91690d62f6f856090 = $(`&lt;div id=&quot;html_583a52f0e24686f91690d62f6f856090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0cd8350aaa5b2f4e05bd29dc72ab4f57.setContent(html_583a52f0e24686f91690d62f6f856090);
#
#
#
#         marker_e239fb5c6e6db0d0044a3541f3e187a4.bindPopup(popup_0cd8350aaa5b2f4e05bd29dc72ab4f57)
#         ;
#
#
#
#
#             var marker_2d2e9660f50d058e74d6b063ae72deb6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_09d49be22424e93713467a3730ee89fa);
#
#
#         var popup_7a434f83e074ba9b9a9fc1c550a1b271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f293e1d90aa2066fb2be8ab1ea860a0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f293e1d90aa2066fb2be8ab1ea860a0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f293e1d90aa2066fb2be8ab1ea860a0f = L.map(
#                 &quot;map_f293e1d90aa2066fb2be8ab1ea860a0f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30a717d3b50836c5a9a4c467dce53e42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30a717d3b50836c5a9a4c467dce53e42.addTo(map_f293e1d90aa2066fb2be8ab1ea860a0f);
#
#
#             var feature_group_66fccd3321cf838faa0571b7e152a1c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_66fccd3321cf838faa0571b7e152a1c2.addTo(map_f293e1d90aa2066fb2be8ab1ea860a0f);
#
#
#             var feature_group_sub_group_13a820c8c3eaebfef3348f50f26226fb = L.featureGroup.subGroup(
#                 feature_group_66fccd3321cf838faa0571b7e152a1c2
#             );
#
#
#             var marker_060796615730e240b06c6cdb787b4b5d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_13a820c8c3eaebfef3348f50f26226fb);
#
#
#         var popup_dee120e636de55352844c464baadbdc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a33465bfeae2dfc2b3c5db3c03ec0a4c = $(`&lt;div id=&quot;html_a33465bfeae2dfc2b3c5db3c03ec0a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dee120e636de55352844c464baadbdc1.setContent(html_a33465bfeae2dfc2b3c5db3c03ec0a4c);
#
#
#
#         marker_060796615730e240b06c6cdb787b4b5d.bindPopup(popup_dee120e636de55352844c464baadbdc1)
#         ;
#
#
#
#
#             var marker_2f3aec7405932214e8dcdb10b9121c04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_13a820c8c3eaebfef3348f50f26226fb);
#
#
#         var popup_975a0b26e8b8a8258ba8311192dc62c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04a106cf0f8ef4135bbae3c840302468 = $(`&lt;div id=&quot;html_04a106cf0f8ef4135bbae3c840302468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_975a0b26e8b8a8258ba8311192dc62c6.setContent(html_04a106cf0f8ef4135bbae3c840302468);
#
#
#
#         marker_2f3aec7405932214e8dcdb10b9121c04.bindPopup(popup_975a0b26e8b8a8258ba8311192dc62c6)
#         ;
#
#
#
#
#             var marker_d8c7cb4f934ce33b8010de9cb094640a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_13a820c8c3eaebfef3348f50f26226fb);
#
#
#         var popup_473f0d5f5d7e3179c41fa2093be186bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1958c5e7c92061cdfa811983ad26051 = $(`&lt;div id=&quot;html_b1958c5e7c92061cdfa811983ad26051&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_473f0d5f5d7e3179c41fa2093be186bf.setContent(html_b1958c5e7c92061cdfa811983ad26051);
#
#
#
#         marker_d8c7cb4f934ce33b8010de9cb094640a.bindPopup(popup_473f0d5f5d7e3179c41fa2093be186bf)
#         ;
#
#
#
#
#             var marker_0e738b0180c3307d7848b141b2e46f2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_13a820c8c3eaebfef3348f50f26226fb);
#
#
#         var popup_f546d380acb42f6267c801e42fdcf177 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f84fda686124e74609b47c6a2334df6a = $(`&lt;div id=&quot;html_f84fda686124e74609b47c6a2334df6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f546d380acb42f6267c801e42fdcf177.setContent(html_f84fda686124e74609b47c6a2334df6a);
#
#
#
#         marker_
