# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_825d393585078f06c6e5cc7c4da3ad29 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_825d393585078f06c6e5cc7c4da3ad29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_825d393585078f06c6e5cc7c4da3ad29 = L.map(
#                 &quot;map_825d393585078f06c6e5cc7c4da3ad29&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0ce91d30d0062e539f1af311873528f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0ce91d30d0062e539f1af311873528f.addTo(map_825d393585078f06c6e5cc7c4da3ad29);
#
#
#             var marker_e56ea8e6340858c93e669e77a371b89a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_825d393585078f06c6e5cc7c4da3ad29);
#
#
#         var popup_4ce02f1354c190d058c247bf8fde32fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_575cb222af7659958e1498845733ff58 = $(`&lt;div id=&quot;html_575cb222af7659958e1498845733ff58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4ce02f1354c190d058c247bf8fde32fa.setContent(html_575cb222af7659958e1498845733ff58);
#
#
#
#         marker_e56ea8e6340858c93e669e77a371b89a.bindPopup(popup_4ce02f1354c190d058c247bf8fde32fa)
#         ;
#
#
#
#
#             var marker_2cf5b49639ed00f80e019f04945c49f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_825d393585078f06c6e5cc7c4da3ad29);
#
#
#         var popup_6db9485b8bb6fc513084f187decc6e08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_900f25bc37b4b45da4d4c0b463a1c8b0 = $(`&lt;div id=&quot;html_900f25bc37b4b45da4d4c0b463a1c8b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6db9485b8bb6fc513084f187decc6e08.setContent(html_900f25bc37b4b45da4d4c0b463a1c8b0);
#
#
#
#         marker_2cf5b49639ed00f80e019f04945c49f5.bindPopup(popup_6db9485b8bb6fc513084f187decc6e08)
#         ;
#
#
#
#
#             var marker_27d0e08cab66f84a2623f4c92e438899 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_825d393585078f06c6e5cc7c4da3ad29);
#
#
#         var popup_2f5b9524767839d27e0dee502fedde85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd855b051b274f5d6e138ba202acd574 = $(`&lt;div id=&quot;html_dd855b051b274f5d6e138ba202acd574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2f5b9524767839d27e0dee502fedde85.setContent(html_dd855b051b274f5d6e138ba202acd574);
#
#
#
#         marker_27d0e08cab66f84a2623f4c92e438899.bindPopup(popup_2f5b9524767839d27e0dee502fedde85)
#         ;
#
#
#
#
#             var marker_0df48426fac84ed17a84af37a71a7d53 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_825d393585078f06c6e5cc7c4da3ad29);
#
#
#         var popup_2e638d7f6a0d473907685aab831ed8ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ab98ab2a32f70b475dc2ab5aeccbc04 = $(`&lt;div id=&quot;html_2ab98ab2a32f70b475dc2ab5aeccbc04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2e638d7f6a0d473907685aab831ed8ed.setContent(html_2ab98ab2a32f70b475dc2ab5aeccbc04);
#
#
#
#         marker_0df48426fac84ed17a84af37a71a7d53.bindPopup(popup_2e638d7f6a0d473907685aab831ed8ed)
#         ;
#
#
#
#
#             var marker_e17882f03b9734b9b5ff1224be77ab8a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_825d393585078f06c6e5cc7c4da3ad29);
#
#
#         var popup_b32d6962468fb74859408935f36e3eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f02e84ada0be792f42c758302ac7d29 = $(`&lt;div id=&quot;html_8f02e84ada0be792f42c758302ac7d29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b32d6962468fb74859408935f36e3eb9.setContent(html_8f02e84ada0be792f42c758302ac7d29);
#
#
#
#         marker_e17882f03b9734b9b5ff1224be77ab8a.bindPopup(popup_b32d6962468fb74859408935f36e3eb9)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e380465b926bd1ca0f89e1f43d64d49a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e380465b926bd1ca0f89e1f43d64d49a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e380465b926bd1ca0f89e1f43d64d49a = L.map(
#                 &quot;map_e380465b926bd1ca0f89e1f43d64d49a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f47023c64c15321532b3cfc81730f15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f47023c64c15321532b3cfc81730f15.addTo(map_e380465b926bd1ca0f89e1f43d64d49a);
#
#
#             var feature_group_37329f96b4c0b1a7ed1c109058dd39f7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1e366d920cd9e83cca6e386da1c86fd9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_37329f96b4c0b1a7ed1c109058dd39f7);
#
#
#         var popup_1c798cb312f2290e8f409a2d32a9f8b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ee71f3bedeeebf2c72a6aa1b78dc312 = $(`&lt;div id=&quot;html_4ee71f3bedeeebf2c72a6aa1b78dc312&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1c798cb312f2290e8f409a2d32a9f8b1.setContent(html_4ee71f3bedeeebf2c72a6aa1b78dc312);
#
#
#
#         marker_1e366d920cd9e83cca6e386da1c86fd9.bindPopup(popup_1c798cb312f2290e8f409a2d32a9f8b1)
#         ;
#
#
#
#
#             var marker_5ca881c34afdfe9fad4b1f1554d4f810 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_37329f96b4c0b1a7ed1c109058dd39f7);
#
#
#         var popup_3f6b081010fb076eab13105ead0f5b53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bc9ab254b6a8aee50b8ec55a36cc594 = $(`&lt;div id=&quot;html_1bc9ab254b6a8aee50b8ec55a36cc594&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3f6b081010fb076eab13105ead0f5b53.setContent(html_1bc9ab254b6a8aee50b8ec55a36cc594);
#
#
#
#         marker_5ca881c34afdfe9fad4b1f1554d4f810.bindPopup(popup_3f6b081010fb076eab13105ead0f5b53)
#         ;
#
#
#
#
#             var marker_90c5860365173add20c960eb0af66fe4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_37329f96b4c0b1a7ed1c109058dd39f7);
#
#
#         var popup_c5ce01316a60e86018eaa503586f1874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d80c2be11d8f804056e6f918dd5231fc = $(`&lt;div id=&quot;html_d80c2be11d8f804056e6f918dd5231fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c5ce01316a60e86018eaa503586f1874.setContent(html_d80c2be11d8f804056e6f918dd5231fc);
#
#
#
#         marker_90c5860365173add20c960eb0af66fe4.bindPopup(popup_c5ce01316a60e86018eaa503586f1874)
#         ;
#
#
#
#
#             var marker_449b165bc6038b31ae297d7a4f7e835e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_37329f96b4c0b1a7ed1c109058dd39f7);
#
#
#         var popup_c3edb3ca67690127cd78f87f4328063f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbc1e26f7e281d40241c480be842c3fc = $(`&lt;div id=&quot;html_bbc1e26f7e281d40241c480be842c3fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c3edb3ca67690127cd78f87f4328063f.setContent(html_bbc1e26f7e281d40241c480be842c3fc);
#
#
#
#         marker_449b165bc6038b31ae297d7a4f7e835e.bindPopup(popup_c3edb3ca67690127cd78f87f4328063f)
#         ;
#
#
#
#
#             var marker_36f0e862bf05db42a3808e63ec7cf7c3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_37329f96b4c0b1a7ed1c109058dd39f7);
#
#
#         var popup_0df1d4cbc61d1b238911d4fa0343621c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ac8485db54ac433e5c5b555b7b3b8b3 = $(`&lt;div id=&quot;html_6ac8485db54ac433e5c5b555b7b3b8b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2a23e4a2384da4d8f4dc54a9bcbbc90 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2a23e4a2384da4d8f4dc54a9bcbbc90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2a23e4a2384da4d8f4dc54a9bcbbc90 = L.map(
#                 &quot;map_c2a23e4a2384da4d8f4dc54a9bcbbc90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e7ceee5c7449aa779f0e2a4b049e570 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e7ceee5c7449aa779f0e2a4b049e570.addTo(map_c2a23e4a2384da4d8f4dc54a9bcbbc90);
#
#
#             var feature_group_f441217c9b4b9b58b7f39e8dbbdaac7f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f441217c9b4b9b58b7f39e8dbbdaac7f.addTo(map_c2a23e4a2384da4d8f4dc54a9bcbbc90);
#
#
#             var feature_group_sub_group_26e3d402b7a8e4715d099d3fc3049d85 = L.featureGroup.subGroup(
#                 feature_group_f441217c9b4b9b58b7f39e8dbbdaac7f
#             );
#
#
#             var marker_fe881a9492e8731286e8ab9e9f4a2994 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e3d402b7a8e4715d099d3fc3049d85);
#
#
#         var popup_042519602eea6b4dfa2012db53cd68b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9e4371c66f11150f7ff76d05b6f7227 = $(`&lt;div id=&quot;html_a9e4371c66f11150f7ff76d05b6f7227&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_042519602eea6b4dfa2012db53cd68b2.setContent(html_a9e4371c66f11150f7ff76d05b6f7227);
#
#
#
#         marker_fe881a9492e8731286e8ab9e9f4a2994.bindPopup(popup_042519602eea6b4dfa2012db53cd68b2)
#         ;
#
#
#
#
#             var marker_a01028dfc3534ed3100856ea6c505405 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e3d402b7a8e4715d099d3fc3049d85);
#
#
#         var popup_21081d6f4b355411fcdecbb43ff359c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a43cc591cb79afb02d697ee6ba3ae20d = $(`&lt;div id=&quot;html_a43cc591cb79afb02d697ee6ba3ae20d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_21081d6f4b355411fcdecbb43ff359c3.setContent(html_a43cc591cb79afb02d697ee6ba3ae20d);
#
#
#
#         marker_a01028dfc3534ed3100856ea6c505405.bindPopup(popup_21081d6f4b355411fcdecbb43ff359c3)
#         ;
#
#
#
#
#             var marker_3aaf21664f245dfa7dcc1cf4b7785421 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e3d402b7a8e4715d099d3fc3049d85);
#
#
#         var popup_2e7eb007019b88c77e0d1be93722bd35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a52d31692430b8728264f67dd4f439f = $(`&lt;div id=&quot;html_7a52d31692430b8728264f67dd4f439f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2e7eb007019b88c77e0d1be93722bd35.setContent(html_7a52d31692430b8728264f67dd4f439f);
#
#
#
#         marker_3aaf21664f245dfa7dcc1cf4b7785421.bindPopup(popup_2e7eb007019b88c77e0d1be93722bd35)
#         ;
#
#
#
#
#             var marker_aecf81cf1afd7e7cd00e9550ce7eb023 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e3d402b7a8e4715d099d3fc3049d85);
#
#
#         var popup_582c25d426fbb934be3bd4a068a958bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed64fd20e219c3ae99abaf62bd5bba68 = $(`&lt;div id=&quot;html_ed64fd20e219c3ae99abaf62bd5bba68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_582c25d426fbb934be3bd4a068a958bc.setContent(html_ed64fd20e219c3ae99abaf62bd5bba68);
#
#
#
#         marker_aecf81cf1afd7e7cd00e9550ce7eb023.bindPopup(popup_582c25d426fbb934be3bd4a068a958bc)
#         ;
#
#
#
#
#             var marker_444b878fc0377843699d8de48046ad3d = L.marker(
#                 [45.0503999
