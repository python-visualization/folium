# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6008e6fa9c915327b051b632940c582 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6008e6fa9c915327b051b632940c582&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6008e6fa9c915327b051b632940c582 = L.map(
#                 &quot;map_c6008e6fa9c915327b051b632940c582&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de3394a5b4ee3bd5ccee5a1eb426976f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de3394a5b4ee3bd5ccee5a1eb426976f.addTo(map_c6008e6fa9c915327b051b632940c582);
#
#
#             var marker_28cc72810c51e283a3f86367d890f0bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c6008e6fa9c915327b051b632940c582);
#
#
#         var popup_0eb334be67a730294c5183a333d52150 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a38a1ac041fd38d7e8ce412ef5e8dfc2 = $(`&lt;div id=&quot;html_a38a1ac041fd38d7e8ce412ef5e8dfc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0eb334be67a730294c5183a333d52150.setContent(html_a38a1ac041fd38d7e8ce412ef5e8dfc2);
#
#
#
#         marker_28cc72810c51e283a3f86367d890f0bc.bindPopup(popup_0eb334be67a730294c5183a333d52150)
#         ;
#
#
#
#
#             var marker_ca8e10896046187d705877815b8b368d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c6008e6fa9c915327b051b632940c582);
#
#
#         var popup_03031cb3df50378a19181421d44e40ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f7bac0beb774184cb085a3678213c89 = $(`&lt;div id=&quot;html_2f7bac0beb774184cb085a3678213c89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_03031cb3df50378a19181421d44e40ea.setContent(html_2f7bac0beb774184cb085a3678213c89);
#
#
#
#         marker_ca8e10896046187d705877815b8b368d.bindPopup(popup_03031cb3df50378a19181421d44e40ea)
#         ;
#
#
#
#
#             var marker_b1ba3d3f2b6eaa175a30b868f4b9ec8c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c6008e6fa9c915327b051b632940c582);
#
#
#         var popup_c881ab194f66fdc17daa168ecfee9d5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40f687ca25ef63da228971da9c28fd00 = $(`&lt;div id=&quot;html_40f687ca25ef63da228971da9c28fd00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c881ab194f66fdc17daa168ecfee9d5c.setContent(html_40f687ca25ef63da228971da9c28fd00);
#
#
#
#         marker_b1ba3d3f2b6eaa175a30b868f4b9ec8c.bindPopup(popup_c881ab194f66fdc17daa168ecfee9d5c)
#         ;
#
#
#
#
#             var marker_00c553339d1ea6045e5cffcedbedd20d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c6008e6fa9c915327b051b632940c582);
#
#
#         var popup_107ef38668a23eb87da3c5d965de7255 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ebd8c8365f1a21ae665edb72cce79c5 = $(`&lt;div id=&quot;html_6ebd8c8365f1a21ae665edb72cce79c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_107ef38668a23eb87da3c5d965de7255.setContent(html_6ebd8c8365f1a21ae665edb72cce79c5);
#
#
#
#         marker_00c553339d1ea6045e5cffcedbedd20d.bindPopup(popup_107ef38668a23eb87da3c5d965de7255)
#         ;
#
#
#
#
#             var marker_e3acd1efe92038e3a5c173581543e827 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c6008e6fa9c915327b051b632940c582);
#
#
#         var popup_ca7420c0de9a1090d95ed4a400c8b3ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62d8c9b83747e203a62e939dd00a0551 = $(`&lt;div id=&quot;html_62d8c9b83747e203a62e939dd00a0551&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ca7420c0de9a1090d95ed4a400c8b3ef.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11f090cc725f6a910b855a13e974a887 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11f090cc725f6a910b855a13e974a887&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11f090cc725f6a910b855a13e974a887 = L.map(
#                 &quot;map_11f090cc725f6a910b855a13e974a887&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_522cac1966d141b95c1f544143f20fba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_522cac1966d141b95c1f544143f20fba.addTo(map_11f090cc725f6a910b855a13e974a887);
#
#
#             var feature_group_ce1747c49c82a026995286400e90be89 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7468f2bcf41a84b64b1f92f6156bc1cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce1747c49c82a026995286400e90be89);
#
#
#         var popup_af4d52685bbe98e3828f7fcedfc10427 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a38c2efc95087aff5183b5c22b0c82f = $(`&lt;div id=&quot;html_9a38c2efc95087aff5183b5c22b0c82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_af4d52685bbe98e3828f7fcedfc10427.setContent(html_9a38c2efc95087aff5183b5c22b0c82f);
#
#
#
#         marker_7468f2bcf41a84b64b1f92f6156bc1cf.bindPopup(popup_af4d52685bbe98e3828f7fcedfc10427)
#         ;
#
#
#
#
#             var marker_a9340f07cf019ab3e800dde373a43bb8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce1747c49c82a026995286400e90be89);
#
#
#         var popup_1c3eb41d62aadf59c23c1ffa11a83bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ff3b83b72fb720781d8e30d7757cf9f = $(`&lt;div id=&quot;html_5ff3b83b72fb720781d8e30d7757cf9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c3eb41d62aadf59c23c1ffa11a83bb5.setContent(html_5ff3b83b72fb720781d8e30d7757cf9f);
#
#
#
#         marker_a9340f07cf019ab3e800dde373a43bb8.bindPopup(popup_1c3eb41d62aadf59c23c1ffa11a83bb5)
#         ;
#
#
#
#
#             var marker_6ee5e76eb4b2291f3dfd0b6d811294ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce1747c49c82a026995286400e90be89);
#
#
#         var popup_c610f354bdc4c066500688e74f01bb06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abdf7758ad375c58762f9a8b712c6ac8 = $(`&lt;div id=&quot;html_abdf7758ad375c58762f9a8b712c6ac8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c610f354bdc4c066500688e74f01bb06.setContent(html_abdf7758ad375c58762f9a8b712c6ac8);
#
#
#
#         marker_6ee5e76eb4b2291f3dfd0b6d811294ea.bindPopup(popup_c610f354bdc4c066500688e74f01bb06)
#         ;
#
#
#
#
#             var marker_73540a85a03e62169251aa6e276998b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce1747c49c82a026995286400e90be89);
#
#
#         var popup_b76c97e9fa384e12912a244d84dd41d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ec14e8bc36cf13abbccbed13209bdcd = $(`&lt;div id=&quot;html_9ec14e8bc36cf13abbccbed13209bdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b76c97e9fa384e12912a244d84dd41d6.setContent(html_9ec14e8bc36cf13abbccbed13209bdcd);
#
#
#
#         marker_73540a85a03e62169251aa6e276998b0.bindPopup(popup_b76c97e9fa384e12912a244d84dd41d6)
#         ;
#
#
#
#
#             var marker_90792a43d74395a6835afc481d6d53e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce1747c49c82a026995286400e90be89);
#
#
#         var popup_719dc9c18edb038c2c9b9b5ebc63b230 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2475f9fa8ec4571c33454e922088d185 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2475f9fa8ec4571c33454e922088d185&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2475f9fa8ec4571c33454e922088d185 = L.map(
#                 &quot;map_2475f9fa8ec4571c33454e922088d185&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77dd3a604a61b57ba868df99a60a1777 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77dd3a604a61b57ba868df99a60a1777.addTo(map_2475f9fa8ec4571c33454e922088d185);
#
#
#             var feature_group_0f5cb933d3810e5e1bd0730f54cb4235 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0f5cb933d3810e5e1bd0730f54cb4235.addTo(map_2475f9fa8ec4571c33454e922088d185);
#
#
#             var feature_group_sub_group_7d87155e7ed958988dbe7c95c941370a = L.featureGroup.subGroup(
#                 feature_group_0f5cb933d3810e5e1bd0730f54cb4235
#             );
#
#
#             var marker_e04d653f93536998b8ee2032fb87cd15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d87155e7ed958988dbe7c95c941370a);
#
#
#         var popup_696537ddb53cbc21ee964df517e67df1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6067e413ad34c31119f0f5ca0276679 = $(`&lt;div id=&quot;html_e6067e413ad34c31119f0f5ca0276679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_696537ddb53cbc21ee964df517e67df1.setContent(html_e6067e413ad34c31119f0f5ca0276679);
#
#
#
#         marker_e04d653f93536998b8ee2032fb87cd15.bindPopup(popup_696537ddb53cbc21ee964df517e67df1)
#         ;
#
#
#
#
#             var marker_9d56446667e5054f9afac6ca33fa69ce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d87155e7ed958988dbe7c95c941370a);
#
#
#         var popup_8509cea46d357641f37e135af0113960 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ecb1152063fa5d2626c3903ee0224ea = $(`&lt;div id=&quot;html_2ecb1152063fa5d2626c3903ee0224ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8509cea46d357641f37e135af0113960.setContent(html_2ecb1152063fa5d2626c3903ee0224ea);
#
#
#
#         marker_9d56446667e5054f9afac6ca33fa69ce.bindPopup(popup_8509cea46d357641f37e135af0113960)
#         ;
#
#
#
#
#             var marker_2b78a8f292d2b2429dbe8081be249549 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d87155e7ed958988dbe7c95c941370a);
#
#
#         var popup_9e4ec1df5acc35d40775e65c0a9a3967 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f36d2ab480dd1f370f57938ad5255ebf = $(`&lt;div id=&quot;html_f36d2ab480dd1f370f57938ad5255ebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9e4ec1df5acc35d40775e65c0a9a3967.setContent(html_f36d2ab480dd1f370f57938ad5255ebf);
#
#
#
#         marker_2b78a8f292d2b2429dbe8081be249549.bindPopup(popup_9e4ec1df5acc35d40775e65c0a9a3967)
#         ;
#
#
#
#
#             var marker_813939381d54400626ccb112a82793e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d87155e7ed958988dbe7c95c941370a);
#
#
#         var popup_5e8497002c56903f674ae47cb2bdccc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_392c008887c4d0be77ba59f18f90c6b3 = $(`&lt;div id=&quot;html_392c008887c4d0be77ba59f18f90c6b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e8497002c56903f674ae47cb2bdccc7.setContent(html_392c008887c4d0be77ba59f18f90c6b3);
#
#
#
#         marker_
