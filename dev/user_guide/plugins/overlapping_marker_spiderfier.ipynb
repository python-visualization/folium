# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c20295d92dfa395557b72e5976b1b377 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c20295d92dfa395557b72e5976b1b377&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c20295d92dfa395557b72e5976b1b377 = L.map(
#                 &quot;map_c20295d92dfa395557b72e5976b1b377&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9d426be8afb22d9ee30954767646bf3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9d426be8afb22d9ee30954767646bf3.addTo(map_c20295d92dfa395557b72e5976b1b377);
#
#
#             var marker_37a4353e35f95e8266559644de70cd3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c20295d92dfa395557b72e5976b1b377);
#
#
#         var popup_f89cb54e6afbe53e6e4c0d3963991336 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b65e9bb5e55d76d9bef7e7e9cf097d07 = $(`&lt;div id=&quot;html_b65e9bb5e55d76d9bef7e7e9cf097d07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f89cb54e6afbe53e6e4c0d3963991336.setContent(html_b65e9bb5e55d76d9bef7e7e9cf097d07);
#
#
#
#         marker_37a4353e35f95e8266559644de70cd3d.bindPopup(popup_f89cb54e6afbe53e6e4c0d3963991336)
#         ;
#
#
#
#
#             var marker_4b68e222a81c1bdba4982ab55520145e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c20295d92dfa395557b72e5976b1b377);
#
#
#         var popup_d3f68b7f8d097b7c1ca52c5d013e0013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dccfca25334fd67cb03d49c8afb299f = $(`&lt;div id=&quot;html_0dccfca25334fd67cb03d49c8afb299f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d3f68b7f8d097b7c1ca52c5d013e0013.setContent(html_0dccfca25334fd67cb03d49c8afb299f);
#
#
#
#         marker_4b68e222a81c1bdba4982ab55520145e.bindPopup(popup_d3f68b7f8d097b7c1ca52c5d013e0013)
#         ;
#
#
#
#
#             var marker_57ff587199fdf894a6709fbb128d8461 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c20295d92dfa395557b72e5976b1b377);
#
#
#         var popup_e5cb30720c72b63890a447b32266bbc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f247409484b6c905a217a48c2e98b52 = $(`&lt;div id=&quot;html_9f247409484b6c905a217a48c2e98b52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e5cb30720c72b63890a447b32266bbc5.setContent(html_9f247409484b6c905a217a48c2e98b52);
#
#
#
#         marker_57ff587199fdf894a6709fbb128d8461.bindPopup(popup_e5cb30720c72b63890a447b32266bbc5)
#         ;
#
#
#
#
#             var marker_01cd440ecc18341e60e51f70a60142d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c20295d92dfa395557b72e5976b1b377);
#
#
#         var popup_09ed7927867dfe2155086260c861f260 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bab6acf79143ac363becdf64a51f3357 = $(`&lt;div id=&quot;html_bab6acf79143ac363becdf64a51f3357&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_09ed7927867dfe2155086260c861f260.setContent(html_bab6acf79143ac363becdf64a51f3357);
#
#
#
#         marker_01cd440ecc18341e60e51f70a60142d8.bindPopup(popup_09ed7927867dfe2155086260c861f260)
#         ;
#
#
#
#
#             var marker_0f670f6811ea1f578f85f576e34106d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c20295d92dfa395557b72e5976b1b377);
#
#
#         var popup_70094a0b3284c13dc766fb285484d5f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01b984ebd7ca6abd33ac48267e3381f2 = $(`&lt;div id=&quot;html_01b984ebd7ca6abd33ac48267e3381f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_70094a0b3284c13dc766fb285484d5f4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ff31004a5218f351a3531741e4682b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ff31004a5218f351a3531741e4682b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ff31004a5218f351a3531741e4682b3 = L.map(
#                 &quot;map_7ff31004a5218f351a3531741e4682b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75bdde57807f92bbb0e81b39827aba48 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75bdde57807f92bbb0e81b39827aba48.addTo(map_7ff31004a5218f351a3531741e4682b3);
#
#
#             var feature_group_543e17638888cbc1f58ae2f03cf909b8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b9527ae15995a0eaaaf8b053af89a12e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_543e17638888cbc1f58ae2f03cf909b8);
#
#
#         var popup_2f95a8a05d44f0bd78f2bb010f496009 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0114ae61905b9ec67871264e6a20fc93 = $(`&lt;div id=&quot;html_0114ae61905b9ec67871264e6a20fc93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2f95a8a05d44f0bd78f2bb010f496009.setContent(html_0114ae61905b9ec67871264e6a20fc93);
#
#
#
#         marker_b9527ae15995a0eaaaf8b053af89a12e.bindPopup(popup_2f95a8a05d44f0bd78f2bb010f496009)
#         ;
#
#
#
#
#             var marker_6413e36f9dfec152f218c194d473ccf6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_543e17638888cbc1f58ae2f03cf909b8);
#
#
#         var popup_184990a7739116917399989d10fe883c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3b3253fa0c5af5861d63b7ab3cee5f5 = $(`&lt;div id=&quot;html_b3b3253fa0c5af5861d63b7ab3cee5f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_184990a7739116917399989d10fe883c.setContent(html_b3b3253fa0c5af5861d63b7ab3cee5f5);
#
#
#
#         marker_6413e36f9dfec152f218c194d473ccf6.bindPopup(popup_184990a7739116917399989d10fe883c)
#         ;
#
#
#
#
#             var marker_511955c93a60ab97a9bddf293130a2ce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_543e17638888cbc1f58ae2f03cf909b8);
#
#
#         var popup_faf64d5b76872e24005e20f819bb10ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c056bc661042b0f4c60208bb1e7fef = $(`&lt;div id=&quot;html_f5c056bc661042b0f4c60208bb1e7fef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_faf64d5b76872e24005e20f819bb10ac.setContent(html_f5c056bc661042b0f4c60208bb1e7fef);
#
#
#
#         marker_511955c93a60ab97a9bddf293130a2ce.bindPopup(popup_faf64d5b76872e24005e20f819bb10ac)
#         ;
#
#
#
#
#             var marker_96ef9f34b42b41d5d2b3b1b0ed319be0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_543e17638888cbc1f58ae2f03cf909b8);
#
#
#         var popup_cac6b716e868a0b57f3b848981e028ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70864608d4876db435086c18ee127f00 = $(`&lt;div id=&quot;html_70864608d4876db435086c18ee127f00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cac6b716e868a0b57f3b848981e028ab.setContent(html_70864608d4876db435086c18ee127f00);
#
#
#
#         marker_96ef9f34b42b41d5d2b3b1b0ed319be0.bindPopup(popup_cac6b716e868a0b57f3b848981e028ab)
#         ;
#
#
#
#
#             var marker_c7655aa70c18ce1c22f9085c80f00b33 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_543e17638888cbc1f58ae2f03cf909b8);
#
#
#         var popup_cb26ad856fba6650a7e5ead9f9c469cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_183454e47e744c480cd94dfe982a08b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_183454e47e744c480cd94dfe982a08b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_183454e47e744c480cd94dfe982a08b9 = L.map(
#                 &quot;map_183454e47e744c480cd94dfe982a08b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edf10412dd3223e75bee1fc85af29706 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_edf10412dd3223e75bee1fc85af29706.addTo(map_183454e47e744c480cd94dfe982a08b9);
#
#
#             var feature_group_46c845d11f95b30d9e0e18ee7d147e1f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_46c845d11f95b30d9e0e18ee7d147e1f.addTo(map_183454e47e744c480cd94dfe982a08b9);
#
#
#             var feature_group_sub_group_84beb786df9137288cc85a891e77ce57 = L.featureGroup.subGroup(
#                 feature_group_46c845d11f95b30d9e0e18ee7d147e1f
#             );
#
#
#             var marker_0cb37102d0c0528ea78ad8e43d0c7931 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_84beb786df9137288cc85a891e77ce57);
#
#
#         var popup_a0b9e90bc9da6978b5a7f007e4390844 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_679e2f81e84f37412b82577bda254b78 = $(`&lt;div id=&quot;html_679e2f81e84f37412b82577bda254b78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a0b9e90bc9da6978b5a7f007e4390844.setContent(html_679e2f81e84f37412b82577bda254b78);
#
#
#
#         marker_0cb37102d0c0528ea78ad8e43d0c7931.bindPopup(popup_a0b9e90bc9da6978b5a7f007e4390844)
#         ;
#
#
#
#
#             var marker_f9e1b56c29ce4982cbe16871fc5c58db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_84beb786df9137288cc85a891e77ce57);
#
#
#         var popup_e492a4a3f0b84f94b533c4c43518bd6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b28d01263749220719ea52b82a2a82b = $(`&lt;div id=&quot;html_8b28d01263749220719ea52b82a2a82b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e492a4a3f0b84f94b533c4c43518bd6a.setContent(html_8b28d01263749220719ea52b82a2a82b);
#
#
#
#         marker_f9e1b56c29ce4982cbe16871fc5c58db.bindPopup(popup_e492a4a3f0b84f94b533c4c43518bd6a)
#         ;
#
#
#
#
#             var marker_8bf892ef73337e7f22006d0f0f8f74f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_84beb786df9137288cc85a891e77ce57);
#
#
#         var popup_2aa575a4deb10eb96449d31ec540b1f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0378470f9b89fda8d230decc5891729 = $(`&lt;div id=&quot;html_b0378470f9b89fda8d230decc5891729&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2aa575a4deb10eb96449d31ec540b1f5.setContent(html_b0378470f9b89fda8d230decc5891729);
#
#
#
#         marker_8bf892ef73337e7f22006d0f0f8f74f4.bindPopup(popup_2aa575a4deb10eb96449d31ec540b1f5)
#         ;
#
#
#
#
#             var marker_d3c157e4ad65e89bea04cf1f9d522241 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_84beb786df9137288cc85a891e77ce57);
#
#
#         var popup_1dab8b182ff8dbee6fd596e39a40c6ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7f61790347095a98d75d0ccc6bd373c = $(`&lt;div id=&quot;html_e7f61790347095a98d75d0ccc6bd373c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1dab8b182ff8dbee6fd596e39a40c6ca.setContent(html_e7f61790347095a98d75d0ccc6bd373c);
#
#
#
#         marker_
