# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7eac20612ae1bf31de17c9193a48a7b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7eac20612ae1bf31de17c9193a48a7b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7eac20612ae1bf31de17c9193a48a7b5 = L.map(
#                 &quot;map_7eac20612ae1bf31de17c9193a48a7b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db016a310ec447942bb049d77705601e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db016a310ec447942bb049d77705601e.addTo(map_7eac20612ae1bf31de17c9193a48a7b5);
#
#
#             var marker_fa50d8cf2e4b1c2b80f74f2dc52653fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7eac20612ae1bf31de17c9193a48a7b5);
#
#
#         var popup_18ca9105951d6e4d410d8620dc61b0ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa18c1c31add7fd5b34e103001c32c2e = $(`&lt;div id=&quot;html_fa18c1c31add7fd5b34e103001c32c2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_18ca9105951d6e4d410d8620dc61b0ec.setContent(html_fa18c1c31add7fd5b34e103001c32c2e);
#
#
#
#         marker_fa50d8cf2e4b1c2b80f74f2dc52653fa.bindPopup(popup_18ca9105951d6e4d410d8620dc61b0ec)
#         ;
#
#
#
#
#             var marker_18b71b1dca035e8139cf805d10c78ad9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7eac20612ae1bf31de17c9193a48a7b5);
#
#
#         var popup_e9bf2d3cd085f3b34a75a0b0436f47ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dbd6dfd1c82fa2d4d06cf87bc90087e = $(`&lt;div id=&quot;html_8dbd6dfd1c82fa2d4d06cf87bc90087e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e9bf2d3cd085f3b34a75a0b0436f47ef.setContent(html_8dbd6dfd1c82fa2d4d06cf87bc90087e);
#
#
#
#         marker_18b71b1dca035e8139cf805d10c78ad9.bindPopup(popup_e9bf2d3cd085f3b34a75a0b0436f47ef)
#         ;
#
#
#
#
#             var marker_ea9d318507691686fc5a6f9e148cb8c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7eac20612ae1bf31de17c9193a48a7b5);
#
#
#         var popup_9788f747f42d2b75df41db95557b934b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82386b65f1670fa34b33767b1f0411b2 = $(`&lt;div id=&quot;html_82386b65f1670fa34b33767b1f0411b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9788f747f42d2b75df41db95557b934b.setContent(html_82386b65f1670fa34b33767b1f0411b2);
#
#
#
#         marker_ea9d318507691686fc5a6f9e148cb8c8.bindPopup(popup_9788f747f42d2b75df41db95557b934b)
#         ;
#
#
#
#
#             var marker_ba3b008928f8286b024dfdb65073c531 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7eac20612ae1bf31de17c9193a48a7b5);
#
#
#         var popup_02ea223f8d5ef1dcc317d571ef77a39a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbac815665a56eb5140adbe0f1b7c17a = $(`&lt;div id=&quot;html_dbac815665a56eb5140adbe0f1b7c17a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_02ea223f8d5ef1dcc317d571ef77a39a.setContent(html_dbac815665a56eb5140adbe0f1b7c17a);
#
#
#
#         marker_ba3b008928f8286b024dfdb65073c531.bindPopup(popup_02ea223f8d5ef1dcc317d571ef77a39a)
#         ;
#
#
#
#
#             var marker_032c8232e3d1d21aaab245136d80f765 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7eac20612ae1bf31de17c9193a48a7b5);
#
#
#         var popup_b8c4fcaefa6eec3e8d508693532ef2c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25fa4f3a46fb4f5636157dc2ba8d9231 = $(`&lt;div id=&quot;html_25fa4f3a46fb4f5636157dc2ba8d9231&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b8c4fcaefa6eec3e8d508693532ef2c5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af65d8b32d97fb032562cd476d1812ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af65d8b32d97fb032562cd476d1812ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af65d8b32d97fb032562cd476d1812ec = L.map(
#                 &quot;map_af65d8b32d97fb032562cd476d1812ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d30b93d45c2dbcca04e00af4a1a3668 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d30b93d45c2dbcca04e00af4a1a3668.addTo(map_af65d8b32d97fb032562cd476d1812ec);
#
#
#             var feature_group_072da1239f07fd7f43c7060cd8b2c83b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_422e08d4edbdfd20aca36c5fe014c028 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_072da1239f07fd7f43c7060cd8b2c83b);
#
#
#         var popup_13dd87f9c04cc166c43dc97bdb1f8b4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4858faaa08b6ea6ed6b115761ff99b04 = $(`&lt;div id=&quot;html_4858faaa08b6ea6ed6b115761ff99b04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_13dd87f9c04cc166c43dc97bdb1f8b4d.setContent(html_4858faaa08b6ea6ed6b115761ff99b04);
#
#
#
#         marker_422e08d4edbdfd20aca36c5fe014c028.bindPopup(popup_13dd87f9c04cc166c43dc97bdb1f8b4d)
#         ;
#
#
#
#
#             var marker_f3d4b90f3e826fb8e65ac3c5429757a3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_072da1239f07fd7f43c7060cd8b2c83b);
#
#
#         var popup_5137798d78e23c69407b2387079329f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_107cacafa2ba52fc1d758480e263e741 = $(`&lt;div id=&quot;html_107cacafa2ba52fc1d758480e263e741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5137798d78e23c69407b2387079329f4.setContent(html_107cacafa2ba52fc1d758480e263e741);
#
#
#
#         marker_f3d4b90f3e826fb8e65ac3c5429757a3.bindPopup(popup_5137798d78e23c69407b2387079329f4)
#         ;
#
#
#
#
#             var marker_57e6913c0e8b797d9c31cf608958d952 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_072da1239f07fd7f43c7060cd8b2c83b);
#
#
#         var popup_7907e4680d7cf25c6f1b4f9bd6ae60df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c57205b525368a6744d03cf2f93524dc = $(`&lt;div id=&quot;html_c57205b525368a6744d03cf2f93524dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7907e4680d7cf25c6f1b4f9bd6ae60df.setContent(html_c57205b525368a6744d03cf2f93524dc);
#
#
#
#         marker_57e6913c0e8b797d9c31cf608958d952.bindPopup(popup_7907e4680d7cf25c6f1b4f9bd6ae60df)
#         ;
#
#
#
#
#             var marker_5d5495b69219a39919665922432dee6b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_072da1239f07fd7f43c7060cd8b2c83b);
#
#
#         var popup_3e0075fbedc19fec9a4094177d496cff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87aa6cce2824fc299d27af9a007a9a93 = $(`&lt;div id=&quot;html_87aa6cce2824fc299d27af9a007a9a93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3e0075fbedc19fec9a4094177d496cff.setContent(html_87aa6cce2824fc299d27af9a007a9a93);
#
#
#
#         marker_5d5495b69219a39919665922432dee6b.bindPopup(popup_3e0075fbedc19fec9a4094177d496cff)
#         ;
#
#
#
#
#             var marker_45906a207456abd26848a59632f40c9b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_072da1239f07fd7f43c7060cd8b2c83b);
#
#
#         var popup_4df4731fdcf5a9216cc3c0ae532789b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3db1b66f378f66bd1ee41b5765dcce8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3db1b66f378f66bd1ee41b5765dcce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3db1b66f378f66bd1ee41b5765dcce8 = L.map(
#                 &quot;map_c3db1b66f378f66bd1ee41b5765dcce8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cffbb21e45fc91aaf9a38eaa5f1b93a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cffbb21e45fc91aaf9a38eaa5f1b93a8.addTo(map_c3db1b66f378f66bd1ee41b5765dcce8);
#
#
#             var feature_group_1b10f6b8d22a241cb858b7e7f6cdbc15 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1b10f6b8d22a241cb858b7e7f6cdbc15.addTo(map_c3db1b66f378f66bd1ee41b5765dcce8);
#
#
#             var feature_group_sub_group_c75faef62ef60d6573eaa01b3bee878e = L.featureGroup.subGroup(
#                 feature_group_1b10f6b8d22a241cb858b7e7f6cdbc15
#             );
#
#
#             var marker_89bb9a9cd30cb76b73ef0686324cb6eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c75faef62ef60d6573eaa01b3bee878e);
#
#
#         var popup_3059455d551226083e7e81697cf1aeb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0ff558520518ce265b4ff9685fccf61 = $(`&lt;div id=&quot;html_f0ff558520518ce265b4ff9685fccf61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3059455d551226083e7e81697cf1aeb8.setContent(html_f0ff558520518ce265b4ff9685fccf61);
#
#
#
#         marker_89bb9a9cd30cb76b73ef0686324cb6eb.bindPopup(popup_3059455d551226083e7e81697cf1aeb8)
#         ;
#
#
#
#
#             var marker_5ea6de93a7823033a23669b38167d0d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c75faef62ef60d6573eaa01b3bee878e);
#
#
#         var popup_6a3b09189a744ac31852d8e3a06d3eb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f51746539d17bcc0ca5a7901c92b2579 = $(`&lt;div id=&quot;html_f51746539d17bcc0ca5a7901c92b2579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6a3b09189a744ac31852d8e3a06d3eb0.setContent(html_f51746539d17bcc0ca5a7901c92b2579);
#
#
#
#         marker_5ea6de93a7823033a23669b38167d0d6.bindPopup(popup_6a3b09189a744ac31852d8e3a06d3eb0)
#         ;
#
#
#
#
#             var marker_ad1571fe0cff62944e51eeecbd08df1c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c75faef62ef60d6573eaa01b3bee878e);
#
#
#         var popup_92eae72be5b01d673873cbff2b12f743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba227db03d10a117bda162a12da168a1 = $(`&lt;div id=&quot;html_ba227db03d10a117bda162a12da168a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_92eae72be5b01d673873cbff2b12f743.setContent(html_ba227db03d10a117bda162a12da168a1);
#
#
#
#         marker_ad1571fe0cff62944e51eeecbd08df1c.bindPopup(popup_92eae72be5b01d673873cbff2b12f743)
#         ;
#
#
#
#
#             var marker_31b0f782ed7622cb7621db5d0d293c89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c75faef62ef60d6573eaa01b3bee878e);
#
#
#         var popup_852bd39972a9f8661f15eb9cdd23e714 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_867d4d6f0c599fbab50d647fb111ebdc = $(`&lt;div id=&quot;html_867d4d6f0c599fbab50d647fb111ebdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_852bd39972a9f8661f15eb9cdd23e714.setContent(html_867d4d6f0c599fbab50d647fb111ebdc);
#
#
#
#         marker_
