# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eeadd63ecb8ff8c25ae25d36d2028b35 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eeadd63ecb8ff8c25ae25d36d2028b35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eeadd63ecb8ff8c25ae25d36d2028b35 = L.map(
#                 &quot;map_eeadd63ecb8ff8c25ae25d36d2028b35&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_358d379b9ecdc8408d0805611f9f646a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_358d379b9ecdc8408d0805611f9f646a.addTo(map_eeadd63ecb8ff8c25ae25d36d2028b35);
#
#
#             var marker_6aabcb77bc4eb46042f6d4adca276401 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_eeadd63ecb8ff8c25ae25d36d2028b35);
#
#
#         var popup_db7cfbc5be15ce03e13cbf53d019b828 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c81abe75c3eb323969ed1f32cd06b0cc = $(`&lt;div id=&quot;html_c81abe75c3eb323969ed1f32cd06b0cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_db7cfbc5be15ce03e13cbf53d019b828.setContent(html_c81abe75c3eb323969ed1f32cd06b0cc);
#
#
#
#         marker_6aabcb77bc4eb46042f6d4adca276401.bindPopup(popup_db7cfbc5be15ce03e13cbf53d019b828)
#         ;
#
#
#
#
#             var marker_cf3ccb8059fca06212d2a8c33ca81e55 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_eeadd63ecb8ff8c25ae25d36d2028b35);
#
#
#         var popup_f305889e7c041a81cea79b0f351aaa37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8711a803f56322487473906385fd1bda = $(`&lt;div id=&quot;html_8711a803f56322487473906385fd1bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f305889e7c041a81cea79b0f351aaa37.setContent(html_8711a803f56322487473906385fd1bda);
#
#
#
#         marker_cf3ccb8059fca06212d2a8c33ca81e55.bindPopup(popup_f305889e7c041a81cea79b0f351aaa37)
#         ;
#
#
#
#
#             var marker_7e8cd20562ff37bb158a0a61799026f5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_eeadd63ecb8ff8c25ae25d36d2028b35);
#
#
#         var popup_6a7899ef07a8b9690a9fa96cab592515 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bc0075c6117409d3b1a6150ac4f1911 = $(`&lt;div id=&quot;html_3bc0075c6117409d3b1a6150ac4f1911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6a7899ef07a8b9690a9fa96cab592515.setContent(html_3bc0075c6117409d3b1a6150ac4f1911);
#
#
#
#         marker_7e8cd20562ff37bb158a0a61799026f5.bindPopup(popup_6a7899ef07a8b9690a9fa96cab592515)
#         ;
#
#
#
#
#             var marker_0ec03f210123d71b4f8a00a7b9e3d74a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_eeadd63ecb8ff8c25ae25d36d2028b35);
#
#
#         var popup_5449379e61df8366ca0c189328c351a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d5b83f90ec1746f2ac48985e8fa8745 = $(`&lt;div id=&quot;html_0d5b83f90ec1746f2ac48985e8fa8745&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5449379e61df8366ca0c189328c351a6.setContent(html_0d5b83f90ec1746f2ac48985e8fa8745);
#
#
#
#         marker_0ec03f210123d71b4f8a00a7b9e3d74a.bindPopup(popup_5449379e61df8366ca0c189328c351a6)
#         ;
#
#
#
#
#             var marker_6df6156621747a8961d7b06437a9259d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_eeadd63ecb8ff8c25ae25d36d2028b35);
#
#
#         var popup_4bb8b70a7ea918d6ea290047ac93ed5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5259d2e8f81f9f325039f5c977757dd4 = $(`&lt;div id=&quot;html_5259d2e8f81f9f325039f5c977757dd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4bb8b70a7ea918d6ea290047ac93ed5d.setContent(html_5259d2e8f81f9f325039f5c977757dd4);
#
#
#
#         marker_6df6156621747a8961d7b06437a9259d.bindPopup(popup_4bb8b70a7ea918d6ea290047ac93ed5d)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_667020cdb28d2fb6c519b82d2c5ff10c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_667020cdb28d2fb6c519b82d2c5ff10c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_667020cdb28d2fb6c519b82d2c5ff10c = L.map(
#                 &quot;map_667020cdb28d2fb6c519b82d2c5ff10c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59c16a0cd5fb5476bf9a88bde60aba58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59c16a0cd5fb5476bf9a88bde60aba58.addTo(map_667020cdb28d2fb6c519b82d2c5ff10c);
#
#
#             var feature_group_5d82b8725c22fb101509711c7a828967 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2afb7c565de48275138387b29c680141 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5d82b8725c22fb101509711c7a828967);
#
#
#         var popup_4a1f611cfacfe2d037f3107373d49e2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87752db3a1d957ba2d9e1df206a73c19 = $(`&lt;div id=&quot;html_87752db3a1d957ba2d9e1df206a73c19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4a1f611cfacfe2d037f3107373d49e2d.setContent(html_87752db3a1d957ba2d9e1df206a73c19);
#
#
#
#         marker_2afb7c565de48275138387b29c680141.bindPopup(popup_4a1f611cfacfe2d037f3107373d49e2d)
#         ;
#
#
#
#
#             var marker_787a721a397131f65e9dfd46491b5dd8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5d82b8725c22fb101509711c7a828967);
#
#
#         var popup_5d7640fe2e94ebb951b9350a33fb33b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2939c0f692eeed4a9836f062de2f0120 = $(`&lt;div id=&quot;html_2939c0f692eeed4a9836f062de2f0120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5d7640fe2e94ebb951b9350a33fb33b7.setContent(html_2939c0f692eeed4a9836f062de2f0120);
#
#
#
#         marker_787a721a397131f65e9dfd46491b5dd8.bindPopup(popup_5d7640fe2e94ebb951b9350a33fb33b7)
#         ;
#
#
#
#
#             var marker_ade10dd8cb1ed53c63570bbad16e980f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5d82b8725c22fb101509711c7a828967);
#
#
#         var popup_354c035791f3bdb11de27425af35ce4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85df02c98c6b17dffb31c3e5597ec9fa = $(`&lt;div id=&quot;html_85df02c98c6b17dffb31c3e5597ec9fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_354c035791f3bdb11de27425af35ce4e.setContent(html_85df02c98c6b17dffb31c3e5597ec9fa);
#
#
#
#         marker_ade10dd8cb1ed53c63570bbad16e980f.bindPopup(popup_354c035791f3bdb11de27425af35ce4e)
#         ;
#
#
#
#
#             var marker_8b6253af3601342991a62f0615dafcd3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5d82b8725c22fb101509711c7a828967);
#
#
#         var popup_12fa789d88d83caa12bccc2dae478dba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e86963bff6ae40faaae825c01f1a449c = $(`&lt;div id=&quot;html_e86963bff6ae40faaae825c01f1a449c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_12fa789d88d83caa12bccc2dae478dba.setContent(html_e86963bff6ae40faaae825c01f1a449c);
#
#
#
#         marker_8b6253af3601342991a62f0615dafcd3.bindPopup(popup_12fa789d88d83caa12bccc2dae478dba)
#         ;
#
#
#
#
#             var marker_732c2640f31a8206f5dac3a57a66d260 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5d82b8725c22fb101509711c7a828967);
#
#
#         var popup_811ecad29674cae2ee99c17508dc3107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06732c02d9e3159dae8a8947fa9e30e8 = $(`&lt;div id=&quot;html_06732c02d9e3159dae8a8947fa9e30e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb899b9bcc3f0969b1ca2c27662334b1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb899b9bcc3f0969b1ca2c27662334b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb899b9bcc3f0969b1ca2c27662334b1 = L.map(
#                 &quot;map_cb899b9bcc3f0969b1ca2c27662334b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff5d892b945472100ed53de9f3a877e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff5d892b945472100ed53de9f3a877e5.addTo(map_cb899b9bcc3f0969b1ca2c27662334b1);
#
#
#             var feature_group_897d3cc29aeab3ec4d3f11d444d2aa71 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_897d3cc29aeab3ec4d3f11d444d2aa71.addTo(map_cb899b9bcc3f0969b1ca2c27662334b1);
#
#
#             var feature_group_sub_group_93cfd50821ffee4f92b5d99761e36220 = L.featureGroup.subGroup(
#                 feature_group_897d3cc29aeab3ec4d3f11d444d2aa71
#             );
#
#
#             var marker_103a3b98da7db0fe7713904475101b40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_93cfd50821ffee4f92b5d99761e36220);
#
#
#         var popup_4a09892ad4ec98f2d05685a14337194f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b02c622bf8c6ee8c4407733c1d8cd9b2 = $(`&lt;div id=&quot;html_b02c622bf8c6ee8c4407733c1d8cd9b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4a09892ad4ec98f2d05685a14337194f.setContent(html_b02c622bf8c6ee8c4407733c1d8cd9b2);
#
#
#
#         marker_103a3b98da7db0fe7713904475101b40.bindPopup(popup_4a09892ad4ec98f2d05685a14337194f)
#         ;
#
#
#
#
#             var marker_7abaffed6cbbeb5367446408d458f181 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_93cfd50821ffee4f92b5d99761e36220);
#
#
#         var popup_2b84151c0e7e609ea7b5182ac866d128 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7af3d085c4df4e2754cc9f78acbbdaa = $(`&lt;div id=&quot;html_a7af3d085c4df4e2754cc9f78acbbdaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2b84151c0e7e609ea7b5182ac866d128.setContent(html_a7af3d085c4df4e2754cc9f78acbbdaa);
#
#
#
#         marker_7abaffed6cbbeb5367446408d458f181.bindPopup(popup_2b84151c0e7e609ea7b5182ac866d128)
#         ;
#
#
#
#
#             var marker_97246f5ccd7fc77c12b9b5c2716b196f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_93cfd50821ffee4f92b5d99761e36220);
#
#
#         var popup_eb1e3eed840a28068b8a268d1e88ee1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1172a8405fc22ba1d4b481240943ac9d = $(`&lt;div id=&quot;html_1172a8405fc22ba1d4b481240943ac9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eb1e3eed840a28068b8a268d1e88ee1f.setContent(html_1172a8405fc22ba1d4b481240943ac9d);
#
#
#
#         marker_97246f5ccd7fc77c12b9b5c2716b196f.bindPopup(popup_eb1e3eed840a28068b8a268d1e88ee1f)
#         ;
#
#
#
#
#             var marker_2d8ed48aa643337ef9ce47fd66f7b145 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_93cfd50821ffee4f92b5d99761e36220);
#
#
#         var popup_4d10749d51c6f8c4b126c0f5617acd5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8141053bb239a120fb5961d4b132bd9 = $(`&lt;div id=&quot;html_e8141053bb239a120fb5961d4b132bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4d10749d51c6f8c4b126c0f5617acd5e.setContent(html_e8141053bb239a120fb5961d4b132bd9);
#
#
#
#         marker_2d8ed48aa643337ef9ce47fd66f7b145.bindPopup(popup_4d10749d51c6f8c4b126c0f5617acd5e)
#         ;
#
#
#
#
#             var marker_de77aca3b524681ba8baaf7e1a269db0 = L.marker(
#                 [45.0503999
