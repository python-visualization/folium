# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cad5c85b6228dc95c0b6b03d8fa2424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cad5c85b6228dc95c0b6b03d8fa2424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cad5c85b6228dc95c0b6b03d8fa2424 = L.map(
#                 &quot;map_2cad5c85b6228dc95c0b6b03d8fa2424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f038991e62361b1b1b986ecfc4e11177 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f038991e62361b1b1b986ecfc4e11177.addTo(map_2cad5c85b6228dc95c0b6b03d8fa2424);
#
#
#             var marker_d7237302e848847ce9e45cf6b610df94 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2cad5c85b6228dc95c0b6b03d8fa2424);
#
#
#         var popup_3fa10b20008bb95c439d994ccb877c04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c44aa355fd9d0228119d7e7126a5ec4 = $(`&lt;div id=&quot;html_0c44aa355fd9d0228119d7e7126a5ec4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3fa10b20008bb95c439d994ccb877c04.setContent(html_0c44aa355fd9d0228119d7e7126a5ec4);
#
#
#
#         marker_d7237302e848847ce9e45cf6b610df94.bindPopup(popup_3fa10b20008bb95c439d994ccb877c04)
#         ;
#
#
#
#
#             var marker_513306f1d01fb5f0ae81bed73934b386 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2cad5c85b6228dc95c0b6b03d8fa2424);
#
#
#         var popup_123ed75b9681c060209352b79788bcde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b82bbe5c6d4967117e871ca6e44edad = $(`&lt;div id=&quot;html_7b82bbe5c6d4967117e871ca6e44edad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_123ed75b9681c060209352b79788bcde.setContent(html_7b82bbe5c6d4967117e871ca6e44edad);
#
#
#
#         marker_513306f1d01fb5f0ae81bed73934b386.bindPopup(popup_123ed75b9681c060209352b79788bcde)
#         ;
#
#
#
#
#             var marker_cab8e6aaf4b8a442fd18b1e9db57a2ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2cad5c85b6228dc95c0b6b03d8fa2424);
#
#
#         var popup_eeae6a70a1e346bf0424d61090313ba5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_698cd1ce8de7ab42283b8a85f9bf4511 = $(`&lt;div id=&quot;html_698cd1ce8de7ab42283b8a85f9bf4511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_eeae6a70a1e346bf0424d61090313ba5.setContent(html_698cd1ce8de7ab42283b8a85f9bf4511);
#
#
#
#         marker_cab8e6aaf4b8a442fd18b1e9db57a2ae.bindPopup(popup_eeae6a70a1e346bf0424d61090313ba5)
#         ;
#
#
#
#
#             var marker_b067f1875c3093c486695264f448faf2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2cad5c85b6228dc95c0b6b03d8fa2424);
#
#
#         var popup_0d84acd5f85225f3241115f49a7ab302 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa8047eb86c59b3aeee3a90ec0c882a0 = $(`&lt;div id=&quot;html_fa8047eb86c59b3aeee3a90ec0c882a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d84acd5f85225f3241115f49a7ab302.setContent(html_fa8047eb86c59b3aeee3a90ec0c882a0);
#
#
#
#         marker_b067f1875c3093c486695264f448faf2.bindPopup(popup_0d84acd5f85225f3241115f49a7ab302)
#         ;
#
#
#
#
#             var marker_9cc2f4f61cad926e6419046cccbee8d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2cad5c85b6228dc95c0b6b03d8fa2424);
#
#
#         var popup_e148bbf75e66c30f1163365b382f44cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f55c4edf44cdd9baa5959422d1d023b = $(`&lt;div id=&quot;html_6f55c4edf44cdd9baa5959422d1d023b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e148bbf75e66c30f1163365b382f44cb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92331189e09629db95e3fc75daadc2f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92331189e09629db95e3fc75daadc2f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92331189e09629db95e3fc75daadc2f5 = L.map(
#                 &quot;map_92331189e09629db95e3fc75daadc2f5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18b815f516b55f70ec2ac7e3a4213d21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18b815f516b55f70ec2ac7e3a4213d21.addTo(map_92331189e09629db95e3fc75daadc2f5);
#
#
#             var feature_group_ba1a8ce60962f37ab6d9aba2e9f918a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_87ac5011d08cbb9ab7e102c90d49be04 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ba1a8ce60962f37ab6d9aba2e9f918a0);
#
#
#         var popup_74ff75bc49e113222de24da2e0425bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba64b953001c3aef9b19aba9f390f59c = $(`&lt;div id=&quot;html_ba64b953001c3aef9b19aba9f390f59c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_74ff75bc49e113222de24da2e0425bd4.setContent(html_ba64b953001c3aef9b19aba9f390f59c);
#
#
#
#         marker_87ac5011d08cbb9ab7e102c90d49be04.bindPopup(popup_74ff75bc49e113222de24da2e0425bd4)
#         ;
#
#
#
#
#             var marker_5b132e006a5124ee27ca6ad472a3cfa4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ba1a8ce60962f37ab6d9aba2e9f918a0);
#
#
#         var popup_617f9485ff9093fb12c6b32c2e404786 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f8168c9493198a1d7bcfa9f61558ac3 = $(`&lt;div id=&quot;html_2f8168c9493198a1d7bcfa9f61558ac3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_617f9485ff9093fb12c6b32c2e404786.setContent(html_2f8168c9493198a1d7bcfa9f61558ac3);
#
#
#
#         marker_5b132e006a5124ee27ca6ad472a3cfa4.bindPopup(popup_617f9485ff9093fb12c6b32c2e404786)
#         ;
#
#
#
#
#             var marker_be23f8fdc9796529c1c05507bb8b986b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ba1a8ce60962f37ab6d9aba2e9f918a0);
#
#
#         var popup_397970cdef0c1d13308602d75833a9d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90b402d51de278437b1d14cb5774cef6 = $(`&lt;div id=&quot;html_90b402d51de278437b1d14cb5774cef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_397970cdef0c1d13308602d75833a9d0.setContent(html_90b402d51de278437b1d14cb5774cef6);
#
#
#
#         marker_be23f8fdc9796529c1c05507bb8b986b.bindPopup(popup_397970cdef0c1d13308602d75833a9d0)
#         ;
#
#
#
#
#             var marker_eae8988fa19bbf9c10319f6899c36208 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ba1a8ce60962f37ab6d9aba2e9f918a0);
#
#
#         var popup_24b994ea45c281bd739851be9e03b119 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cba3b89ef1b5ea92c63cc6b0a0faefb6 = $(`&lt;div id=&quot;html_cba3b89ef1b5ea92c63cc6b0a0faefb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_24b994ea45c281bd739851be9e03b119.setContent(html_cba3b89ef1b5ea92c63cc6b0a0faefb6);
#
#
#
#         marker_eae8988fa19bbf9c10319f6899c36208.bindPopup(popup_24b994ea45c281bd739851be9e03b119)
#         ;
#
#
#
#
#             var marker_afe0f03910a89342a19acea117e79a0d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ba1a8ce60962f37ab6d9aba2e9f918a0);
#
#
#         var popup_e9d5447e61dba89d40d1f48b5a40a4c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9683d753c58c12cd099461a08eb3df1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9683d753c58c12cd099461a08eb3df1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9683d753c58c12cd099461a08eb3df1 = L.map(
#                 &quot;map_f9683d753c58c12cd099461a08eb3df1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30ec6e3466f6e7c663c8c7c6d104663f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30ec6e3466f6e7c663c8c7c6d104663f.addTo(map_f9683d753c58c12cd099461a08eb3df1);
#
#
#             var feature_group_ac7f82dfb061d433729ae695ed196913 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ac7f82dfb061d433729ae695ed196913.addTo(map_f9683d753c58c12cd099461a08eb3df1);
#
#
#             var feature_group_sub_group_d84d9903926cbdc1ffedcbe8a97c4531 = L.featureGroup.subGroup(
#                 feature_group_ac7f82dfb061d433729ae695ed196913
#             );
#
#
#             var marker_e61d318c62c52c349f9031a0f202cd4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d84d9903926cbdc1ffedcbe8a97c4531);
#
#
#         var popup_c6632196ff8f935fe488648b4a676a90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d8265d5652338afc15389b865cee47 = $(`&lt;div id=&quot;html_89d8265d5652338afc15389b865cee47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c6632196ff8f935fe488648b4a676a90.setContent(html_89d8265d5652338afc15389b865cee47);
#
#
#
#         marker_e61d318c62c52c349f9031a0f202cd4d.bindPopup(popup_c6632196ff8f935fe488648b4a676a90)
#         ;
#
#
#
#
#             var marker_545eba03fd11581486bd2a9897fb9545 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d84d9903926cbdc1ffedcbe8a97c4531);
#
#
#         var popup_d057942da34646e751abc7a18bde0a11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a74b544544c2b62a5ac3d4ebcbfe0715 = $(`&lt;div id=&quot;html_a74b544544c2b62a5ac3d4ebcbfe0715&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d057942da34646e751abc7a18bde0a11.setContent(html_a74b544544c2b62a5ac3d4ebcbfe0715);
#
#
#
#         marker_545eba03fd11581486bd2a9897fb9545.bindPopup(popup_d057942da34646e751abc7a18bde0a11)
#         ;
#
#
#
#
#             var marker_e611fa1ef669fda3f0292e5628b76591 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d84d9903926cbdc1ffedcbe8a97c4531);
#
#
#         var popup_c73d9e0fc8461594db25c943f03f8a67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_557da109281b4160f106007145086f7c = $(`&lt;div id=&quot;html_557da109281b4160f106007145086f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c73d9e0fc8461594db25c943f03f8a67.setContent(html_557da109281b4160f106007145086f7c);
#
#
#
#         marker_e611fa1ef669fda3f0292e5628b76591.bindPopup(popup_c73d9e0fc8461594db25c943f03f8a67)
#         ;
#
#
#
#
#             var marker_d698e3b4604e98721751722f9356f399 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d84d9903926cbdc1ffedcbe8a97c4531);
#
#
#         var popup_094d34ad35abb8815dd0fb4e66c1b753 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b787c4c79a4ef88f277076e51c605fd9 = $(`&lt;div id=&quot;html_b787c4c79a4ef88f277076e51c605fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_094d34ad35abb8815dd0fb4e66c1b753.setContent(html_b787c4c79a4ef88f277076e51c605fd9);
#
#
#
#         marker_
