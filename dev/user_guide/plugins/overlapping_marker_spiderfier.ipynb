# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d61e4f6f54ff4d0d25112a5d98d787d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d61e4f6f54ff4d0d25112a5d98d787d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d61e4f6f54ff4d0d25112a5d98d787d7 = L.map(
#                 &quot;map_d61e4f6f54ff4d0d25112a5d98d787d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbb59eab9b7f247d5706f4f753055573 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbb59eab9b7f247d5706f4f753055573.addTo(map_d61e4f6f54ff4d0d25112a5d98d787d7);
#
#
#             var marker_5e2ebad33d894d1e8b4204c52c33efc9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d61e4f6f54ff4d0d25112a5d98d787d7);
#
#
#         var popup_1510df90bb1ffa83ba76879705fe41a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df4dbec726910162f3d035dca65546cb = $(`&lt;div id=&quot;html_df4dbec726910162f3d035dca65546cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1510df90bb1ffa83ba76879705fe41a4.setContent(html_df4dbec726910162f3d035dca65546cb);
#
#
#
#         marker_5e2ebad33d894d1e8b4204c52c33efc9.bindPopup(popup_1510df90bb1ffa83ba76879705fe41a4)
#         ;
#
#
#
#
#             var marker_57af9ceab01a195805fa44af6fa34671 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d61e4f6f54ff4d0d25112a5d98d787d7);
#
#
#         var popup_fb15009a51431a5c8594e0df78dd4140 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89c324c21ab22301846e202a48602cbf = $(`&lt;div id=&quot;html_89c324c21ab22301846e202a48602cbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fb15009a51431a5c8594e0df78dd4140.setContent(html_89c324c21ab22301846e202a48602cbf);
#
#
#
#         marker_57af9ceab01a195805fa44af6fa34671.bindPopup(popup_fb15009a51431a5c8594e0df78dd4140)
#         ;
#
#
#
#
#             var marker_996dce6d6fbba7f681f1f28c9894c72a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d61e4f6f54ff4d0d25112a5d98d787d7);
#
#
#         var popup_5c85407eb075af1f89456d7ada77454a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f77b55ff04572d7a9670988162d08737 = $(`&lt;div id=&quot;html_f77b55ff04572d7a9670988162d08737&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5c85407eb075af1f89456d7ada77454a.setContent(html_f77b55ff04572d7a9670988162d08737);
#
#
#
#         marker_996dce6d6fbba7f681f1f28c9894c72a.bindPopup(popup_5c85407eb075af1f89456d7ada77454a)
#         ;
#
#
#
#
#             var marker_c022a7da3c27b1414fa0511cdca950d4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d61e4f6f54ff4d0d25112a5d98d787d7);
#
#
#         var popup_ec79a2ab4c093c7bc5f50306a8e77bb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ff8ef40f9eff1a56566f935aeb772ea = $(`&lt;div id=&quot;html_0ff8ef40f9eff1a56566f935aeb772ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ec79a2ab4c093c7bc5f50306a8e77bb6.setContent(html_0ff8ef40f9eff1a56566f935aeb772ea);
#
#
#
#         marker_c022a7da3c27b1414fa0511cdca950d4.bindPopup(popup_ec79a2ab4c093c7bc5f50306a8e77bb6)
#         ;
#
#
#
#
#             var marker_c40ffa3ab6dded5c170a9f41ee667710 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d61e4f6f54ff4d0d25112a5d98d787d7);
#
#
#         var popup_ec29fadb4680797ce9fcfcecedec34a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbcb10dc3300e353af69a1c6ef11f339 = $(`&lt;div id=&quot;html_fbcb10dc3300e353af69a1c6ef11f339&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ec29fadb4680797ce9fcfcecedec34a7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30ef43de33644332c29421f0f572f96a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30ef43de33644332c29421f0f572f96a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30ef43de33644332c29421f0f572f96a = L.map(
#                 &quot;map_30ef43de33644332c29421f0f572f96a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7ca4437949d305baf08bc815002d3f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7ca4437949d305baf08bc815002d3f6.addTo(map_30ef43de33644332c29421f0f572f96a);
#
#
#             var feature_group_8e5cbc8faa26ffdf8f6e28c6ab65fce9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6fef8ad47d199748a9177fbd692017bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8e5cbc8faa26ffdf8f6e28c6ab65fce9);
#
#
#         var popup_0091971772ee516072c835eb410a9187 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_886f79c7aeba3ad4b38d322ffb36d9dc = $(`&lt;div id=&quot;html_886f79c7aeba3ad4b38d322ffb36d9dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0091971772ee516072c835eb410a9187.setContent(html_886f79c7aeba3ad4b38d322ffb36d9dc);
#
#
#
#         marker_6fef8ad47d199748a9177fbd692017bf.bindPopup(popup_0091971772ee516072c835eb410a9187)
#         ;
#
#
#
#
#             var marker_ce57ba19b536a68c7fee56117176fd32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8e5cbc8faa26ffdf8f6e28c6ab65fce9);
#
#
#         var popup_74430f39f46a9e15df7485dbb9993a77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76eae0b4f36acc3ef5a9724693c4e8e6 = $(`&lt;div id=&quot;html_76eae0b4f36acc3ef5a9724693c4e8e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_74430f39f46a9e15df7485dbb9993a77.setContent(html_76eae0b4f36acc3ef5a9724693c4e8e6);
#
#
#
#         marker_ce57ba19b536a68c7fee56117176fd32.bindPopup(popup_74430f39f46a9e15df7485dbb9993a77)
#         ;
#
#
#
#
#             var marker_688fee20d3e5ecdb0a72fe051f5703d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8e5cbc8faa26ffdf8f6e28c6ab65fce9);
#
#
#         var popup_dd2ad450a2d62c566be87dbadfdbc194 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_854b74607ead00fe65b1f3024a301ec3 = $(`&lt;div id=&quot;html_854b74607ead00fe65b1f3024a301ec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dd2ad450a2d62c566be87dbadfdbc194.setContent(html_854b74607ead00fe65b1f3024a301ec3);
#
#
#
#         marker_688fee20d3e5ecdb0a72fe051f5703d5.bindPopup(popup_dd2ad450a2d62c566be87dbadfdbc194)
#         ;
#
#
#
#
#             var marker_4c2c9a4b73c4412022122c97c6df74c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8e5cbc8faa26ffdf8f6e28c6ab65fce9);
#
#
#         var popup_74304c69deb82df6bb18853038932a5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9bd4706b53f071b3927dc011e0b10e7 = $(`&lt;div id=&quot;html_a9bd4706b53f071b3927dc011e0b10e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_74304c69deb82df6bb18853038932a5b.setContent(html_a9bd4706b53f071b3927dc011e0b10e7);
#
#
#
#         marker_4c2c9a4b73c4412022122c97c6df74c2.bindPopup(popup_74304c69deb82df6bb18853038932a5b)
#         ;
#
#
#
#
#             var marker_670b9f4bb0049d46896f95392f631c3f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8e5cbc8faa26ffdf8f6e28c6ab65fce9);
#
#
#         var popup_c5944c59c59947355ba0c82b74516d46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bec5981a4e351b06f99bb5ee269ce56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bec5981a4e351b06f99bb5ee269ce56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bec5981a4e351b06f99bb5ee269ce56 = L.map(
#                 &quot;map_2bec5981a4e351b06f99bb5ee269ce56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e118f6cfb4244ad27562542d9e311312 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e118f6cfb4244ad27562542d9e311312.addTo(map_2bec5981a4e351b06f99bb5ee269ce56);
#
#
#             var feature_group_ae7958b05177027b0f545912053361aa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ae7958b05177027b0f545912053361aa.addTo(map_2bec5981a4e351b06f99bb5ee269ce56);
#
#
#             var feature_group_sub_group_29b1c8fb66fc9cfdade6cc16d75b30bc = L.featureGroup.subGroup(
#                 feature_group_ae7958b05177027b0f545912053361aa
#             );
#
#
#             var marker_86e2a0a5fbc9fda337c260a6ff77a62f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_29b1c8fb66fc9cfdade6cc16d75b30bc);
#
#
#         var popup_6a8e6aca73fecbf3ef9bffb54e46baac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6d02b274e4918131d93450c15601a13 = $(`&lt;div id=&quot;html_a6d02b274e4918131d93450c15601a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6a8e6aca73fecbf3ef9bffb54e46baac.setContent(html_a6d02b274e4918131d93450c15601a13);
#
#
#
#         marker_86e2a0a5fbc9fda337c260a6ff77a62f.bindPopup(popup_6a8e6aca73fecbf3ef9bffb54e46baac)
#         ;
#
#
#
#
#             var marker_a1e362bf0679530b05fc61f5b87a7dfb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_29b1c8fb66fc9cfdade6cc16d75b30bc);
#
#
#         var popup_55ad2c9fdb1de8c29f8d0cfb7481392c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35ae53800f5965031d371cdc8d8bad9f = $(`&lt;div id=&quot;html_35ae53800f5965031d371cdc8d8bad9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_55ad2c9fdb1de8c29f8d0cfb7481392c.setContent(html_35ae53800f5965031d371cdc8d8bad9f);
#
#
#
#         marker_a1e362bf0679530b05fc61f5b87a7dfb.bindPopup(popup_55ad2c9fdb1de8c29f8d0cfb7481392c)
#         ;
#
#
#
#
#             var marker_1ebeb624ec750d8ed431ea9acaaaee53 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_29b1c8fb66fc9cfdade6cc16d75b30bc);
#
#
#         var popup_9962c5b8baca789c1843a02e235ded62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a3c869b727b57c06eb6c2b18fa227ca = $(`&lt;div id=&quot;html_4a3c869b727b57c06eb6c2b18fa227ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9962c5b8baca789c1843a02e235ded62.setContent(html_4a3c869b727b57c06eb6c2b18fa227ca);
#
#
#
#         marker_1ebeb624ec750d8ed431ea9acaaaee53.bindPopup(popup_9962c5b8baca789c1843a02e235ded62)
#         ;
#
#
#
#
#             var marker_300ebbf6e028fba607c71f566d0fd6c3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_29b1c8fb66fc9cfdade6cc16d75b30bc);
#
#
#         var popup_b4943a3dd01fdc42ba45d5705a6b5111 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29e5e1eecce9185765b2b79331ad1d2e = $(`&lt;div id=&quot;html_29e5e1eecce9185765b2b79331ad1d2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b4943a3dd01fdc42ba45d5705a6b5111.setContent(html_29e5e1eecce9185765b2b79331ad1d2e);
#
#
#
#         marker_
