# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_557ee1e08d6fa06eca17b9e2996e91b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_557ee1e08d6fa06eca17b9e2996e91b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_557ee1e08d6fa06eca17b9e2996e91b6 = L.map(
#                 &quot;map_557ee1e08d6fa06eca17b9e2996e91b6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdf8e1da4b5be5cbb8f967ee9e1ef508 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdf8e1da4b5be5cbb8f967ee9e1ef508.addTo(map_557ee1e08d6fa06eca17b9e2996e91b6);
#
#
#             var marker_f33376e7b680d8a09363817f5844004d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_557ee1e08d6fa06eca17b9e2996e91b6);
#
#
#         var popup_0c0037ec77eb3dbbf9901e5c437d18ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8605360f1558d0de18c44fc838e8c645 = $(`&lt;div id=&quot;html_8605360f1558d0de18c44fc838e8c645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0c0037ec77eb3dbbf9901e5c437d18ff.setContent(html_8605360f1558d0de18c44fc838e8c645);
#
#
#
#         marker_f33376e7b680d8a09363817f5844004d.bindPopup(popup_0c0037ec77eb3dbbf9901e5c437d18ff)
#         ;
#
#
#
#
#             var marker_db0c9ae8fef70321c118e6b04a8c14bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_557ee1e08d6fa06eca17b9e2996e91b6);
#
#
#         var popup_c6e38d7b8b2b99e10f8e446d60ba7830 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_debb028d589538936d1e3c7ef45bb138 = $(`&lt;div id=&quot;html_debb028d589538936d1e3c7ef45bb138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c6e38d7b8b2b99e10f8e446d60ba7830.setContent(html_debb028d589538936d1e3c7ef45bb138);
#
#
#
#         marker_db0c9ae8fef70321c118e6b04a8c14bb.bindPopup(popup_c6e38d7b8b2b99e10f8e446d60ba7830)
#         ;
#
#
#
#
#             var marker_89c15d85d1e84c0f762d588a3d1b11f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_557ee1e08d6fa06eca17b9e2996e91b6);
#
#
#         var popup_d1d2614c8537c084984cefdbf4331011 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adfd358e8065946da0b78b52a364e56e = $(`&lt;div id=&quot;html_adfd358e8065946da0b78b52a364e56e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d1d2614c8537c084984cefdbf4331011.setContent(html_adfd358e8065946da0b78b52a364e56e);
#
#
#
#         marker_89c15d85d1e84c0f762d588a3d1b11f0.bindPopup(popup_d1d2614c8537c084984cefdbf4331011)
#         ;
#
#
#
#
#             var marker_a2e20724c124c9cf08ba4002ea4dc6a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_557ee1e08d6fa06eca17b9e2996e91b6);
#
#
#         var popup_41097f6d82aef590e2e6ef1521b5a065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed78ceb1e770d566218015ef3d77edd6 = $(`&lt;div id=&quot;html_ed78ceb1e770d566218015ef3d77edd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_41097f6d82aef590e2e6ef1521b5a065.setContent(html_ed78ceb1e770d566218015ef3d77edd6);
#
#
#
#         marker_a2e20724c124c9cf08ba4002ea4dc6a4.bindPopup(popup_41097f6d82aef590e2e6ef1521b5a065)
#         ;
#
#
#
#
#             var marker_fdcd9d12a98daa9afed515517e230f84 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_557ee1e08d6fa06eca17b9e2996e91b6);
#
#
#         var popup_1958d89e43b55665f48348c21a97e2bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b7c04199ae3957838e376e1197ba8ce = $(`&lt;div id=&quot;html_8b7c04199ae3957838e376e1197ba8ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1958d89e43b55665f48348c21a97e2bd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f679ffdad51060a88f294ad5b0520880 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f679ffdad51060a88f294ad5b0520880&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f679ffdad51060a88f294ad5b0520880 = L.map(
#                 &quot;map_f679ffdad51060a88f294ad5b0520880&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36eb10be006a3121853a083717bafd99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36eb10be006a3121853a083717bafd99.addTo(map_f679ffdad51060a88f294ad5b0520880);
#
#
#             var feature_group_083a3b6d7432415e0356d50882266b91 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f910d9a52f659b5ef2f54fa5da0b9317 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_083a3b6d7432415e0356d50882266b91);
#
#
#         var popup_e8b61dfb464be1d61e2a4efb57b2288f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6697f1b0df325f17a9bede0a0c7cf746 = $(`&lt;div id=&quot;html_6697f1b0df325f17a9bede0a0c7cf746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e8b61dfb464be1d61e2a4efb57b2288f.setContent(html_6697f1b0df325f17a9bede0a0c7cf746);
#
#
#
#         marker_f910d9a52f659b5ef2f54fa5da0b9317.bindPopup(popup_e8b61dfb464be1d61e2a4efb57b2288f)
#         ;
#
#
#
#
#             var marker_0b438663dbf8cfcbe8a273e24f288989 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_083a3b6d7432415e0356d50882266b91);
#
#
#         var popup_4823f9a40ee0cc58ba4b9e78a26416b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ebdea9c976902603c492b75c942877 = $(`&lt;div id=&quot;html_c9ebdea9c976902603c492b75c942877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4823f9a40ee0cc58ba4b9e78a26416b7.setContent(html_c9ebdea9c976902603c492b75c942877);
#
#
#
#         marker_0b438663dbf8cfcbe8a273e24f288989.bindPopup(popup_4823f9a40ee0cc58ba4b9e78a26416b7)
#         ;
#
#
#
#
#             var marker_af194485ee8ee2d88b03b69693597780 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_083a3b6d7432415e0356d50882266b91);
#
#
#         var popup_19a179f1b1ff770f57648094fbb4577c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e081577e6d42fa134aca3b2a52b21a8e = $(`&lt;div id=&quot;html_e081577e6d42fa134aca3b2a52b21a8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_19a179f1b1ff770f57648094fbb4577c.setContent(html_e081577e6d42fa134aca3b2a52b21a8e);
#
#
#
#         marker_af194485ee8ee2d88b03b69693597780.bindPopup(popup_19a179f1b1ff770f57648094fbb4577c)
#         ;
#
#
#
#
#             var marker_983357922bb6757f8ae5f4c48e5178eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_083a3b6d7432415e0356d50882266b91);
#
#
#         var popup_aa6ba2a73353e6c38663b31d3e5d70ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce07949a5c40caf73f449092927ebed8 = $(`&lt;div id=&quot;html_ce07949a5c40caf73f449092927ebed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aa6ba2a73353e6c38663b31d3e5d70ed.setContent(html_ce07949a5c40caf73f449092927ebed8);
#
#
#
#         marker_983357922bb6757f8ae5f4c48e5178eb.bindPopup(popup_aa6ba2a73353e6c38663b31d3e5d70ed)
#         ;
#
#
#
#
#             var marker_e7eeb47e3c3a49a83590b999e51803c7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_083a3b6d7432415e0356d50882266b91);
#
#
#         var popup_faefef1addf83c02d392652b02822188 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb4b31141998cc2e7d60c353d0c91912 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb4b31141998cc2e7d60c353d0c91912&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb4b31141998cc2e7d60c353d0c91912 = L.map(
#                 &quot;map_bb4b31141998cc2e7d60c353d0c91912&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1091695a25b98fba7b88b5f0d47251cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1091695a25b98fba7b88b5f0d47251cb.addTo(map_bb4b31141998cc2e7d60c353d0c91912);
#
#
#             var feature_group_876fe0c6215159f610cfc7c2d7d45ecd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_876fe0c6215159f610cfc7c2d7d45ecd.addTo(map_bb4b31141998cc2e7d60c353d0c91912);
#
#
#             var feature_group_sub_group_206de5b2343861a8813c1749bac72aad = L.featureGroup.subGroup(
#                 feature_group_876fe0c6215159f610cfc7c2d7d45ecd
#             );
#
#
#             var marker_45b597e77f9381c608144dc7732add2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_206de5b2343861a8813c1749bac72aad);
#
#
#         var popup_86cc2709d39cd47d2ede3add8942a188 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_644e08c26feb5b1c5012943816a1e950 = $(`&lt;div id=&quot;html_644e08c26feb5b1c5012943816a1e950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_86cc2709d39cd47d2ede3add8942a188.setContent(html_644e08c26feb5b1c5012943816a1e950);
#
#
#
#         marker_45b597e77f9381c608144dc7732add2d.bindPopup(popup_86cc2709d39cd47d2ede3add8942a188)
#         ;
#
#
#
#
#             var marker_e4a7c478a8ffa93fd1d19c706b3edf74 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_206de5b2343861a8813c1749bac72aad);
#
#
#         var popup_edbf7b19a7d8007e0902b553a2ac15f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_627b2ab6d2c59735188d021556d0bcdf = $(`&lt;div id=&quot;html_627b2ab6d2c59735188d021556d0bcdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_edbf7b19a7d8007e0902b553a2ac15f5.setContent(html_627b2ab6d2c59735188d021556d0bcdf);
#
#
#
#         marker_e4a7c478a8ffa93fd1d19c706b3edf74.bindPopup(popup_edbf7b19a7d8007e0902b553a2ac15f5)
#         ;
#
#
#
#
#             var marker_bf6431ecb73e27f017c0f9268c410f7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_206de5b2343861a8813c1749bac72aad);
#
#
#         var popup_aeb7bb7dd15d9aef67f422823fbabcbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2d861ff4454790865888918a2b2b081 = $(`&lt;div id=&quot;html_f2d861ff4454790865888918a2b2b081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_aeb7bb7dd15d9aef67f422823fbabcbc.setContent(html_f2d861ff4454790865888918a2b2b081);
#
#
#
#         marker_bf6431ecb73e27f017c0f9268c410f7c.bindPopup(popup_aeb7bb7dd15d9aef67f422823fbabcbc)
#         ;
#
#
#
#
#             var marker_96ed32cef7ce6c0335553de01e8f93aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_206de5b2343861a8813c1749bac72aad);
#
#
#         var popup_3ab57e14457dcb1a90b3eccb2c758186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73641efb0efb749846068ccc4dc6647e = $(`&lt;div id=&quot;html_73641efb0efb749846068ccc4dc6647e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3ab57e14457dcb1a90b3eccb2c758186.setContent(html_73641efb0efb749846068ccc4dc6647e);
#
#
#
#         marker_
