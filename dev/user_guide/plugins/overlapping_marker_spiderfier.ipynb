# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d4d62f936e18a80785abfbfb6be786c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d4d62f936e18a80785abfbfb6be786c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d4d62f936e18a80785abfbfb6be786c = L.map(
#                 &quot;map_1d4d62f936e18a80785abfbfb6be786c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba1b41a26ef4570519691d574d648a76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba1b41a26ef4570519691d574d648a76.addTo(map_1d4d62f936e18a80785abfbfb6be786c);
#
#
#             var marker_3c984accb14950d9dfc7084b2a8850cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1d4d62f936e18a80785abfbfb6be786c);
#
#
#         var popup_6b363dc77bd4f2fae6a89cb24cb91a35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_431f0a9a1c4a14797a28dfc28e82e1d0 = $(`&lt;div id=&quot;html_431f0a9a1c4a14797a28dfc28e82e1d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6b363dc77bd4f2fae6a89cb24cb91a35.setContent(html_431f0a9a1c4a14797a28dfc28e82e1d0);
#
#
#
#         marker_3c984accb14950d9dfc7084b2a8850cd.bindPopup(popup_6b363dc77bd4f2fae6a89cb24cb91a35)
#         ;
#
#
#
#
#             var marker_eef887ab5d6cd13105304986e7cc7383 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1d4d62f936e18a80785abfbfb6be786c);
#
#
#         var popup_2db09ad608c6d7c996813e43cf491640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fee6d5f39da6c93285d2c757bdc7702 = $(`&lt;div id=&quot;html_9fee6d5f39da6c93285d2c757bdc7702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2db09ad608c6d7c996813e43cf491640.setContent(html_9fee6d5f39da6c93285d2c757bdc7702);
#
#
#
#         marker_eef887ab5d6cd13105304986e7cc7383.bindPopup(popup_2db09ad608c6d7c996813e43cf491640)
#         ;
#
#
#
#
#             var marker_f27ec88d0d70e1dbb104649ccdfae7eb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1d4d62f936e18a80785abfbfb6be786c);
#
#
#         var popup_1d33d357ec346fac0fee68b878c6bd60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2beeec23480e6d71600055c9841c8be7 = $(`&lt;div id=&quot;html_2beeec23480e6d71600055c9841c8be7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d33d357ec346fac0fee68b878c6bd60.setContent(html_2beeec23480e6d71600055c9841c8be7);
#
#
#
#         marker_f27ec88d0d70e1dbb104649ccdfae7eb.bindPopup(popup_1d33d357ec346fac0fee68b878c6bd60)
#         ;
#
#
#
#
#             var marker_6aaa3f685cbeba0f55e5ae4bc03ca808 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1d4d62f936e18a80785abfbfb6be786c);
#
#
#         var popup_c5b9986f73298c69ecbe529a791938c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70e6a2efd44573811f4af6b9593328d6 = $(`&lt;div id=&quot;html_70e6a2efd44573811f4af6b9593328d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c5b9986f73298c69ecbe529a791938c4.setContent(html_70e6a2efd44573811f4af6b9593328d6);
#
#
#
#         marker_6aaa3f685cbeba0f55e5ae4bc03ca808.bindPopup(popup_c5b9986f73298c69ecbe529a791938c4)
#         ;
#
#
#
#
#             var marker_13f4070e7841cef896fe0c65a34725f2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1d4d62f936e18a80785abfbfb6be786c);
#
#
#         var popup_4d22ce5287ae2f0d828f815b7a10c923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f35f6c8bee822686a3985229990254d = $(`&lt;div id=&quot;html_7f35f6c8bee822686a3985229990254d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4d22ce5287ae2f0d828f815b7a10c923.setContent(html_7f35f6c8bee822686a3985229990254d);
#
#
#
#         marker_13f4070e7841cef896fe0c65a34725f2.bindPopup(popup_4d22ce5287ae2f0d828f815b7a10c923)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba7f8b9ae5a5ad1b5d2ba24ddc8ac855 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba7f8b9ae5a5ad1b5d2ba24ddc8ac855&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba7f8b9ae5a5ad1b5d2ba24ddc8ac855 = L.map(
#                 &quot;map_ba7f8b9ae5a5ad1b5d2ba24ddc8ac855&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5059977f1bf516606204aeb01f064ee2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5059977f1bf516606204aeb01f064ee2.addTo(map_ba7f8b9ae5a5ad1b5d2ba24ddc8ac855);
#
#
#             var feature_group_041ae9d62a6e40cc20714602f53d94b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_85e0fd8e29ef17507a0cbf7bd26e8a62 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_041ae9d62a6e40cc20714602f53d94b4);
#
#
#         var popup_bac03fa031c826c531f5ea837a277b9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_843475a02661500c50d9f879385c974b = $(`&lt;div id=&quot;html_843475a02661500c50d9f879385c974b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bac03fa031c826c531f5ea837a277b9a.setContent(html_843475a02661500c50d9f879385c974b);
#
#
#
#         marker_85e0fd8e29ef17507a0cbf7bd26e8a62.bindPopup(popup_bac03fa031c826c531f5ea837a277b9a)
#         ;
#
#
#
#
#             var marker_c828232788953308a3fb5fade1a2d715 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_041ae9d62a6e40cc20714602f53d94b4);
#
#
#         var popup_6f553ab25d088907145d9f85172b2d53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3de4b28c29af69866227ad684e144933 = $(`&lt;div id=&quot;html_3de4b28c29af69866227ad684e144933&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6f553ab25d088907145d9f85172b2d53.setContent(html_3de4b28c29af69866227ad684e144933);
#
#
#
#         marker_c828232788953308a3fb5fade1a2d715.bindPopup(popup_6f553ab25d088907145d9f85172b2d53)
#         ;
#
#
#
#
#             var marker_4b720993653f9fb1d6d4e53b215c20ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_041ae9d62a6e40cc20714602f53d94b4);
#
#
#         var popup_d09296b463e510779809b09e6b8975f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c329d9cdefc825a6a484e5a496dfa0f5 = $(`&lt;div id=&quot;html_c329d9cdefc825a6a484e5a496dfa0f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d09296b463e510779809b09e6b8975f5.setContent(html_c329d9cdefc825a6a484e5a496dfa0f5);
#
#
#
#         marker_4b720993653f9fb1d6d4e53b215c20ee.bindPopup(popup_d09296b463e510779809b09e6b8975f5)
#         ;
#
#
#
#
#             var marker_b741934b5535412cb7aba90ac1f67085 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_041ae9d62a6e40cc20714602f53d94b4);
#
#
#         var popup_594769ecae7ee59acbf7a4087839c4fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1daa0019219613d80887bfa2d664c4dc = $(`&lt;div id=&quot;html_1daa0019219613d80887bfa2d664c4dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_594769ecae7ee59acbf7a4087839c4fb.setContent(html_1daa0019219613d80887bfa2d664c4dc);
#
#
#
#         marker_b741934b5535412cb7aba90ac1f67085.bindPopup(popup_594769ecae7ee59acbf7a4087839c4fb)
#         ;
#
#
#
#
#             var marker_00afdfdf4aa48abd8accc53fd8fdb37f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_041ae9d62a6e40cc20714602f53d94b4);
#
#
#         var popup_de3ba2dab5b2b15dcd2af9ee19f831b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14d35432939366d84c33b475acc7bf43 = $(`&lt;div id=&quot;html_14d35432939366d84c33b475acc7bf43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e7b3f298c3257b5593e5cac0a84add7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e7b3f298c3257b5593e5cac0a84add7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e7b3f298c3257b5593e5cac0a84add7 = L.map(
#                 &quot;map_2e7b3f298c3257b5593e5cac0a84add7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_970a64e7aae0dcab8c83c4cb78c61e8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_970a64e7aae0dcab8c83c4cb78c61e8a.addTo(map_2e7b3f298c3257b5593e5cac0a84add7);
#
#
#             var feature_group_08f73763412f3cd1d2157a80a70e4c89 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_08f73763412f3cd1d2157a80a70e4c89.addTo(map_2e7b3f298c3257b5593e5cac0a84add7);
#
#
#             var feature_group_sub_group_8be3db11c349871c7ca51c9722ad20a1 = L.featureGroup.subGroup(
#                 feature_group_08f73763412f3cd1d2157a80a70e4c89
#             );
#
#
#             var marker_e0c8da0df6767816ca3ee8c001b4beba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be3db11c349871c7ca51c9722ad20a1);
#
#
#         var popup_230a2e9c99c83cabd7f51a92fc8d845a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4361e39497405aed89b30fa1f514b29e = $(`&lt;div id=&quot;html_4361e39497405aed89b30fa1f514b29e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_230a2e9c99c83cabd7f51a92fc8d845a.setContent(html_4361e39497405aed89b30fa1f514b29e);
#
#
#
#         marker_e0c8da0df6767816ca3ee8c001b4beba.bindPopup(popup_230a2e9c99c83cabd7f51a92fc8d845a)
#         ;
#
#
#
#
#             var marker_b7912f40d1c48ec7f10f63832129c0a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be3db11c349871c7ca51c9722ad20a1);
#
#
#         var popup_7ecf531af171d1c36ff74902fe14a9b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0056a3d700486e31992a465a67c230c2 = $(`&lt;div id=&quot;html_0056a3d700486e31992a465a67c230c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7ecf531af171d1c36ff74902fe14a9b5.setContent(html_0056a3d700486e31992a465a67c230c2);
#
#
#
#         marker_b7912f40d1c48ec7f10f63832129c0a0.bindPopup(popup_7ecf531af171d1c36ff74902fe14a9b5)
#         ;
#
#
#
#
#             var marker_b1d1c69a04970980604e19a1ec1200e4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be3db11c349871c7ca51c9722ad20a1);
#
#
#         var popup_93f32bfde0af500c4989593e1d04b0bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b9a38eac9a5f47d7b8ac1f4cf6c3a55 = $(`&lt;div id=&quot;html_3b9a38eac9a5f47d7b8ac1f4cf6c3a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_93f32bfde0af500c4989593e1d04b0bd.setContent(html_3b9a38eac9a5f47d7b8ac1f4cf6c3a55);
#
#
#
#         marker_b1d1c69a04970980604e19a1ec1200e4.bindPopup(popup_93f32bfde0af500c4989593e1d04b0bd)
#         ;
#
#
#
#
#             var marker_470c7685ba2cb0d26f024e34b6027f32 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be3db11c349871c7ca51c9722ad20a1);
#
#
#         var popup_69740b7e1f9858ade599ba99ac98d329 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a877bd74c8241c44ea87586b1a49b0a4 = $(`&lt;div id=&quot;html_a877bd74c8241c44ea87586b1a49b0a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_69740b7e1f9858ade599ba99ac98d329.setContent(html_a877bd74c8241c44ea87586b1a49b0a4);
#
#
#
#         marker_470c7685ba2cb0d26f024e34b6027f32.bindPopup(popup_69740b7e1f9858ade599ba99ac98d329)
#         ;
#
#
#
#
#             var marker_ed90b2f0417faa3b8df11084d5aab19c = L.marker(
#                 [45.0503999
