# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49326558b3ad38bc3cb727910a108367 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49326558b3ad38bc3cb727910a108367&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49326558b3ad38bc3cb727910a108367 = L.map(
#                 &quot;map_49326558b3ad38bc3cb727910a108367&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4671a11b8cc07ee3ea856d290fce664f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4671a11b8cc07ee3ea856d290fce664f.addTo(map_49326558b3ad38bc3cb727910a108367);
#
#
#             var marker_47c3fe91ea76e075c4717d354b71e5a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_49326558b3ad38bc3cb727910a108367);
#
#
#         var popup_f35228a2d9ee26d3c4fb5a57de3ec16d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d2b0ec2e32d45deaf5c730f7e25db96 = $(`&lt;div id=&quot;html_1d2b0ec2e32d45deaf5c730f7e25db96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f35228a2d9ee26d3c4fb5a57de3ec16d.setContent(html_1d2b0ec2e32d45deaf5c730f7e25db96);
#
#
#
#         marker_47c3fe91ea76e075c4717d354b71e5a6.bindPopup(popup_f35228a2d9ee26d3c4fb5a57de3ec16d)
#         ;
#
#
#
#
#             var marker_dc818039b7fa4c36c7b0d9a43929a7f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_49326558b3ad38bc3cb727910a108367);
#
#
#         var popup_f5d305a9e1a8637df5b8eb0f5292e7cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f815a5967d67f95993e5e84137ac139f = $(`&lt;div id=&quot;html_f815a5967d67f95993e5e84137ac139f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f5d305a9e1a8637df5b8eb0f5292e7cb.setContent(html_f815a5967d67f95993e5e84137ac139f);
#
#
#
#         marker_dc818039b7fa4c36c7b0d9a43929a7f7.bindPopup(popup_f5d305a9e1a8637df5b8eb0f5292e7cb)
#         ;
#
#
#
#
#             var marker_7982ff1d4f018ff6737c20587f5bf30a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_49326558b3ad38bc3cb727910a108367);
#
#
#         var popup_5a118396fafef636269f90af4c6392ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da4a10a862842cce06bb87c8543d4962 = $(`&lt;div id=&quot;html_da4a10a862842cce06bb87c8543d4962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5a118396fafef636269f90af4c6392ff.setContent(html_da4a10a862842cce06bb87c8543d4962);
#
#
#
#         marker_7982ff1d4f018ff6737c20587f5bf30a.bindPopup(popup_5a118396fafef636269f90af4c6392ff)
#         ;
#
#
#
#
#             var marker_3e16146b12f1b05c436e474a4742e1be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_49326558b3ad38bc3cb727910a108367);
#
#
#         var popup_c44bb9eb431c9a73b87adb2d3b822bb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2a97e2f197d5ddd5d773cdbe838b396 = $(`&lt;div id=&quot;html_a2a97e2f197d5ddd5d773cdbe838b396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c44bb9eb431c9a73b87adb2d3b822bb8.setContent(html_a2a97e2f197d5ddd5d773cdbe838b396);
#
#
#
#         marker_3e16146b12f1b05c436e474a4742e1be.bindPopup(popup_c44bb9eb431c9a73b87adb2d3b822bb8)
#         ;
#
#
#
#
#             var marker_3da30bddc3a5b17bf3b2603748752c2b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_49326558b3ad38bc3cb727910a108367);
#
#
#         var popup_98025dfed2ede801ee9bbfecc64ddbcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49026f0607375d13ae502ef9c671f9de = $(`&lt;div id=&quot;html_49026f0607375d13ae502ef9c671f9de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_98025dfed2ede801ee9bbfecc64ddbcf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a000ef770325caad40de9c338509f2bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a000ef770325caad40de9c338509f2bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a000ef770325caad40de9c338509f2bf = L.map(
#                 &quot;map_a000ef770325caad40de9c338509f2bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a07f00e3a508b1a8794b558ba809aafc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a07f00e3a508b1a8794b558ba809aafc.addTo(map_a000ef770325caad40de9c338509f2bf);
#
#
#             var feature_group_3414e52b51445e6b24f407d368756151 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4ffb172a8d24eacfa43cdf78fff51c7a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3414e52b51445e6b24f407d368756151);
#
#
#         var popup_8710353a5590d0f0c6f527631dd37321 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_697933f80da1c76fd0a649649a2fbc21 = $(`&lt;div id=&quot;html_697933f80da1c76fd0a649649a2fbc21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8710353a5590d0f0c6f527631dd37321.setContent(html_697933f80da1c76fd0a649649a2fbc21);
#
#
#
#         marker_4ffb172a8d24eacfa43cdf78fff51c7a.bindPopup(popup_8710353a5590d0f0c6f527631dd37321)
#         ;
#
#
#
#
#             var marker_9af44ed04f2ef135c146cfa105d06bd5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3414e52b51445e6b24f407d368756151);
#
#
#         var popup_028b32f9029ad687bae0b1379d5c7d4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fca7f84b275ac421a2ae319f38a6f81 = $(`&lt;div id=&quot;html_2fca7f84b275ac421a2ae319f38a6f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_028b32f9029ad687bae0b1379d5c7d4f.setContent(html_2fca7f84b275ac421a2ae319f38a6f81);
#
#
#
#         marker_9af44ed04f2ef135c146cfa105d06bd5.bindPopup(popup_028b32f9029ad687bae0b1379d5c7d4f)
#         ;
#
#
#
#
#             var marker_f3a68879fddc4a9f89c4f1afea95537d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3414e52b51445e6b24f407d368756151);
#
#
#         var popup_6936809e99111165318a10b15bd60ff7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50603363df30b75887318d2f0230c97c = $(`&lt;div id=&quot;html_50603363df30b75887318d2f0230c97c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6936809e99111165318a10b15bd60ff7.setContent(html_50603363df30b75887318d2f0230c97c);
#
#
#
#         marker_f3a68879fddc4a9f89c4f1afea95537d.bindPopup(popup_6936809e99111165318a10b15bd60ff7)
#         ;
#
#
#
#
#             var marker_925360cb3eed04582877e708b4e7b691 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3414e52b51445e6b24f407d368756151);
#
#
#         var popup_c4e5e54fd20b67b01694398ca311cd63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a12264fbc0435bfe62c2b900b53ff89d = $(`&lt;div id=&quot;html_a12264fbc0435bfe62c2b900b53ff89d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c4e5e54fd20b67b01694398ca311cd63.setContent(html_a12264fbc0435bfe62c2b900b53ff89d);
#
#
#
#         marker_925360cb3eed04582877e708b4e7b691.bindPopup(popup_c4e5e54fd20b67b01694398ca311cd63)
#         ;
#
#
#
#
#             var marker_2800685d2d7377c35c75248252e561f8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3414e52b51445e6b24f407d368756151);
#
#
#         var popup_7a99037bda64c08fc4aa2754096a994f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6b41278bd7a4805fd15677f1a08d783 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6b41278bd7a4805fd15677f1a08d783&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6b41278bd7a4805fd15677f1a08d783 = L.map(
#                 &quot;map_a6b41278bd7a4805fd15677f1a08d783&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb6cb56251eff9e1dfe9a58b330a9285 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb6cb56251eff9e1dfe9a58b330a9285.addTo(map_a6b41278bd7a4805fd15677f1a08d783);
#
#
#             var feature_group_07811a305c5ef07f9d0d55ca6fe2cbd1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_07811a305c5ef07f9d0d55ca6fe2cbd1.addTo(map_a6b41278bd7a4805fd15677f1a08d783);
#
#
#             var feature_group_sub_group_620de0f6164cc120bcb17f2ddea5aa49 = L.featureGroup.subGroup(
#                 feature_group_07811a305c5ef07f9d0d55ca6fe2cbd1
#             );
#
#
#             var marker_1a8684d806867253c455311f95ecce44 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_620de0f6164cc120bcb17f2ddea5aa49);
#
#
#         var popup_a0bb43fcfb67753184e0f3edc8258b8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_317335fb40ace5e9cc54f0c15212d46a = $(`&lt;div id=&quot;html_317335fb40ace5e9cc54f0c15212d46a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a0bb43fcfb67753184e0f3edc8258b8d.setContent(html_317335fb40ace5e9cc54f0c15212d46a);
#
#
#
#         marker_1a8684d806867253c455311f95ecce44.bindPopup(popup_a0bb43fcfb67753184e0f3edc8258b8d)
#         ;
#
#
#
#
#             var marker_97ced37adf4b82f7defe5a6e73115387 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_620de0f6164cc120bcb17f2ddea5aa49);
#
#
#         var popup_fdabac37252585ba73206c31a031c22b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06c590758722e898a5ccde440d1a0a82 = $(`&lt;div id=&quot;html_06c590758722e898a5ccde440d1a0a82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fdabac37252585ba73206c31a031c22b.setContent(html_06c590758722e898a5ccde440d1a0a82);
#
#
#
#         marker_97ced37adf4b82f7defe5a6e73115387.bindPopup(popup_fdabac37252585ba73206c31a031c22b)
#         ;
#
#
#
#
#             var marker_80ac42ce26de3781a980910905ec7650 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_620de0f6164cc120bcb17f2ddea5aa49);
#
#
#         var popup_158207f4529bd201302a2532afb655da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e52de5f81236fa1e60912cced4b58b19 = $(`&lt;div id=&quot;html_e52de5f81236fa1e60912cced4b58b19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_158207f4529bd201302a2532afb655da.setContent(html_e52de5f81236fa1e60912cced4b58b19);
#
#
#
#         marker_80ac42ce26de3781a980910905ec7650.bindPopup(popup_158207f4529bd201302a2532afb655da)
#         ;
#
#
#
#
#             var marker_85a4a503bc60e5155c5c5b97114a06ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_620de0f6164cc120bcb17f2ddea5aa49);
#
#
#         var popup_afe7a59ed07d60d4fdc0d92fcb5f804f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c3f8e7501171b7ec94a728f0fbea0ad = $(`&lt;div id=&quot;html_9c3f8e7501171b7ec94a728f0fbea0ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_afe7a59ed07d60d4fdc0d92fcb5f804f.setContent(html_9c3f8e7501171b7ec94a728f0fbea0ad);
#
#
#
#         marker_
