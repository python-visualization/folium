# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_630ef5486a8f95bbc567a775aa397835 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_630ef5486a8f95bbc567a775aa397835&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_630ef5486a8f95bbc567a775aa397835 = L.map(
#                 &quot;map_630ef5486a8f95bbc567a775aa397835&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3fb9ba9648fc22d52d09305bb9448fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3fb9ba9648fc22d52d09305bb9448fa.addTo(map_630ef5486a8f95bbc567a775aa397835);
#
#
#             var marker_6dbe9e833abbd71d337fe38a51b0b281 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_630ef5486a8f95bbc567a775aa397835);
#
#
#         var popup_2f0011f787896b96d88599bb537ba4a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bf1c586ebb696e2c667618ce5d056a1 = $(`&lt;div id=&quot;html_3bf1c586ebb696e2c667618ce5d056a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2f0011f787896b96d88599bb537ba4a3.setContent(html_3bf1c586ebb696e2c667618ce5d056a1);
#
#
#
#         marker_6dbe9e833abbd71d337fe38a51b0b281.bindPopup(popup_2f0011f787896b96d88599bb537ba4a3)
#         ;
#
#
#
#
#             var marker_3e6b881cf5286afe4bc2799c0551c507 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_630ef5486a8f95bbc567a775aa397835);
#
#
#         var popup_4a458dc13736cfcf28e97fe423f8a912 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85c808303fed2f3f2b0b3025b2af37b0 = $(`&lt;div id=&quot;html_85c808303fed2f3f2b0b3025b2af37b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4a458dc13736cfcf28e97fe423f8a912.setContent(html_85c808303fed2f3f2b0b3025b2af37b0);
#
#
#
#         marker_3e6b881cf5286afe4bc2799c0551c507.bindPopup(popup_4a458dc13736cfcf28e97fe423f8a912)
#         ;
#
#
#
#
#             var marker_18e4b4c477e1a710ae71c611f26c49de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_630ef5486a8f95bbc567a775aa397835);
#
#
#         var popup_7812b8ad9f8c037805251e7ee21b9513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c1e073a15bbc68a9899af5c27a522f = $(`&lt;div id=&quot;html_90c1e073a15bbc68a9899af5c27a522f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7812b8ad9f8c037805251e7ee21b9513.setContent(html_90c1e073a15bbc68a9899af5c27a522f);
#
#
#
#         marker_18e4b4c477e1a710ae71c611f26c49de.bindPopup(popup_7812b8ad9f8c037805251e7ee21b9513)
#         ;
#
#
#
#
#             var marker_81dec40b3d47bd11037d63e95aa7dfc6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_630ef5486a8f95bbc567a775aa397835);
#
#
#         var popup_df0884dfc1fac58b0984c3191bc347e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0114c17948178860f3666663f37c9bee = $(`&lt;div id=&quot;html_0114c17948178860f3666663f37c9bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_df0884dfc1fac58b0984c3191bc347e5.setContent(html_0114c17948178860f3666663f37c9bee);
#
#
#
#         marker_81dec40b3d47bd11037d63e95aa7dfc6.bindPopup(popup_df0884dfc1fac58b0984c3191bc347e5)
#         ;
#
#
#
#
#             var marker_dcb40c9f328a4d624d880a8bf7716043 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_630ef5486a8f95bbc567a775aa397835);
#
#
#         var popup_659bc55111060dbfb76e621bc778ae8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b12c810e56497efe4daece2b50172f5f = $(`&lt;div id=&quot;html_b12c810e56497efe4daece2b50172f5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_659bc55111060dbfb76e621bc778ae8d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc7e29886e6a5c3213e211dcb8e1ef23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc7e29886e6a5c3213e211dcb8e1ef23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc7e29886e6a5c3213e211dcb8e1ef23 = L.map(
#                 &quot;map_bc7e29886e6a5c3213e211dcb8e1ef23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4df24e0957e8d41d31fb35d516e12dbd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4df24e0957e8d41d31fb35d516e12dbd.addTo(map_bc7e29886e6a5c3213e211dcb8e1ef23);
#
#
#             var feature_group_349589325eeb7a7b321e792ad8c6f39e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7531ee5eae9bac9bf9a699f06d3f90c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_349589325eeb7a7b321e792ad8c6f39e);
#
#
#         var popup_e1ca5f5da857a1e48571da19ca5b3e50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c010f0ca064fe64a4fe4b22aabcea60d = $(`&lt;div id=&quot;html_c010f0ca064fe64a4fe4b22aabcea60d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e1ca5f5da857a1e48571da19ca5b3e50.setContent(html_c010f0ca064fe64a4fe4b22aabcea60d);
#
#
#
#         marker_7531ee5eae9bac9bf9a699f06d3f90c4.bindPopup(popup_e1ca5f5da857a1e48571da19ca5b3e50)
#         ;
#
#
#
#
#             var marker_7bdbc38706ee55c5c015b91ab89a9214 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_349589325eeb7a7b321e792ad8c6f39e);
#
#
#         var popup_a96075e1d7074f4e245705f5a2e67c3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c138acf0483fdffd1bb1fffdf96ec45c = $(`&lt;div id=&quot;html_c138acf0483fdffd1bb1fffdf96ec45c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a96075e1d7074f4e245705f5a2e67c3c.setContent(html_c138acf0483fdffd1bb1fffdf96ec45c);
#
#
#
#         marker_7bdbc38706ee55c5c015b91ab89a9214.bindPopup(popup_a96075e1d7074f4e245705f5a2e67c3c)
#         ;
#
#
#
#
#             var marker_374c40e00816b61de02618c811480d3d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_349589325eeb7a7b321e792ad8c6f39e);
#
#
#         var popup_f9889104a963a665bf3e9117bf6dc776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b2ab058c348dfe9f6ac6cbcbdec3fbe = $(`&lt;div id=&quot;html_2b2ab058c348dfe9f6ac6cbcbdec3fbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f9889104a963a665bf3e9117bf6dc776.setContent(html_2b2ab058c348dfe9f6ac6cbcbdec3fbe);
#
#
#
#         marker_374c40e00816b61de02618c811480d3d.bindPopup(popup_f9889104a963a665bf3e9117bf6dc776)
#         ;
#
#
#
#
#             var marker_cedf39d08a472c6ed27fe81f73021805 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_349589325eeb7a7b321e792ad8c6f39e);
#
#
#         var popup_d7d4c09496ab5cdd2f09f495dd9f0ca6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf651b9a76de58cfc428a732cf631595 = $(`&lt;div id=&quot;html_bf651b9a76de58cfc428a732cf631595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d7d4c09496ab5cdd2f09f495dd9f0ca6.setContent(html_bf651b9a76de58cfc428a732cf631595);
#
#
#
#         marker_cedf39d08a472c6ed27fe81f73021805.bindPopup(popup_d7d4c09496ab5cdd2f09f495dd9f0ca6)
#         ;
#
#
#
#
#             var marker_525f8fe55e4a982e1b334004c4a2c421 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_349589325eeb7a7b321e792ad8c6f39e);
#
#
#         var popup_97fb188fcb006ddea3e647aef0781aa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9326da53fb78ed67e28213580922e199 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9326da53fb78ed67e28213580922e199&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9326da53fb78ed67e28213580922e199 = L.map(
#                 &quot;map_9326da53fb78ed67e28213580922e199&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46a4026cc8637cd61752855c371d2005 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46a4026cc8637cd61752855c371d2005.addTo(map_9326da53fb78ed67e28213580922e199);
#
#
#             var feature_group_fe029e7745f562081b5d8d8539d6f9f7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fe029e7745f562081b5d8d8539d6f9f7.addTo(map_9326da53fb78ed67e28213580922e199);
#
#
#             var feature_group_sub_group_d94c3e4572d472897d61534e88357cd4 = L.featureGroup.subGroup(
#                 feature_group_fe029e7745f562081b5d8d8539d6f9f7
#             );
#
#
#             var marker_6be12a6244d907005c3dc882ac99bb8c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94c3e4572d472897d61534e88357cd4);
#
#
#         var popup_d27fec7e5bd00bf9ba466294c50c7f74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_301a6eeba6aadf62480a32e57bb07509 = $(`&lt;div id=&quot;html_301a6eeba6aadf62480a32e57bb07509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d27fec7e5bd00bf9ba466294c50c7f74.setContent(html_301a6eeba6aadf62480a32e57bb07509);
#
#
#
#         marker_6be12a6244d907005c3dc882ac99bb8c.bindPopup(popup_d27fec7e5bd00bf9ba466294c50c7f74)
#         ;
#
#
#
#
#             var marker_2780e54c1da37d34cfaa3ef072487ffa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94c3e4572d472897d61534e88357cd4);
#
#
#         var popup_12bff5d3f352f352fb9e83fa6bdc4a8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e2b18d875401b39d1d233f12a1fcf6d = $(`&lt;div id=&quot;html_3e2b18d875401b39d1d233f12a1fcf6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_12bff5d3f352f352fb9e83fa6bdc4a8b.setContent(html_3e2b18d875401b39d1d233f12a1fcf6d);
#
#
#
#         marker_2780e54c1da37d34cfaa3ef072487ffa.bindPopup(popup_12bff5d3f352f352fb9e83fa6bdc4a8b)
#         ;
#
#
#
#
#             var marker_7690a42fb273695be58bf2b2516a70b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94c3e4572d472897d61534e88357cd4);
#
#
#         var popup_c014ac51ad21afb0af3a1e30ce304441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b130bc02f9da2563c8d3b565a7e4a6b6 = $(`&lt;div id=&quot;html_b130bc02f9da2563c8d3b565a7e4a6b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c014ac51ad21afb0af3a1e30ce304441.setContent(html_b130bc02f9da2563c8d3b565a7e4a6b6);
#
#
#
#         marker_7690a42fb273695be58bf2b2516a70b1.bindPopup(popup_c014ac51ad21afb0af3a1e30ce304441)
#         ;
#
#
#
#
#             var marker_631bca6b7032c4e9992a2b1fcd73234d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94c3e4572d472897d61534e88357cd4);
#
#
#         var popup_267fbda00ef6e4395ab3c23360da0263 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39f9b8ae6ed910d6b2f8de5ddddb22d9 = $(`&lt;div id=&quot;html_39f9b8ae6ed910d6b2f8de5ddddb22d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_267fbda00ef6e4395ab3c23360da0263.setContent(html_39f9b8ae6ed910d6b2f8de5ddddb22d9);
#
#
#
#         marker_
