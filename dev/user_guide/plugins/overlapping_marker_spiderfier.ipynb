# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc1ca14626b8c83ec666eeaf19794cb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc1ca14626b8c83ec666eeaf19794cb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc1ca14626b8c83ec666eeaf19794cb4 = L.map(
#                 &quot;map_bc1ca14626b8c83ec666eeaf19794cb4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21baa125c84111809cea3aff19a6e4db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21baa125c84111809cea3aff19a6e4db.addTo(map_bc1ca14626b8c83ec666eeaf19794cb4);
#
#
#             var marker_fa4e29d9869068a0ef2c1c6939cfd028 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bc1ca14626b8c83ec666eeaf19794cb4);
#
#
#         var popup_a536275eb59e8e66bac119896a1c844f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e76f2450a9008bd0914be8a59cba653 = $(`&lt;div id=&quot;html_2e76f2450a9008bd0914be8a59cba653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a536275eb59e8e66bac119896a1c844f.setContent(html_2e76f2450a9008bd0914be8a59cba653);
#
#
#
#         marker_fa4e29d9869068a0ef2c1c6939cfd028.bindPopup(popup_a536275eb59e8e66bac119896a1c844f)
#         ;
#
#
#
#
#             var marker_3ef0bcf5bca36939ee24cf6eed34c7de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bc1ca14626b8c83ec666eeaf19794cb4);
#
#
#         var popup_3cf11e2384a3823e507abcb922879866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9740080f6dbd24c6b607ea713ec6ebff = $(`&lt;div id=&quot;html_9740080f6dbd24c6b607ea713ec6ebff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3cf11e2384a3823e507abcb922879866.setContent(html_9740080f6dbd24c6b607ea713ec6ebff);
#
#
#
#         marker_3ef0bcf5bca36939ee24cf6eed34c7de.bindPopup(popup_3cf11e2384a3823e507abcb922879866)
#         ;
#
#
#
#
#             var marker_b358a9386aeef7bf850e762783ffdcbf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bc1ca14626b8c83ec666eeaf19794cb4);
#
#
#         var popup_8557e8216f1647e2e663acae7786c9ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7668090d58982a12dc8980918d6c50e9 = $(`&lt;div id=&quot;html_7668090d58982a12dc8980918d6c50e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8557e8216f1647e2e663acae7786c9ce.setContent(html_7668090d58982a12dc8980918d6c50e9);
#
#
#
#         marker_b358a9386aeef7bf850e762783ffdcbf.bindPopup(popup_8557e8216f1647e2e663acae7786c9ce)
#         ;
#
#
#
#
#             var marker_57732ba8b40454dd14684055d8fbade8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bc1ca14626b8c83ec666eeaf19794cb4);
#
#
#         var popup_c17aa31d80463d08d131e01546539a27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a71038208340174cc714654dbcbeed4e = $(`&lt;div id=&quot;html_a71038208340174cc714654dbcbeed4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c17aa31d80463d08d131e01546539a27.setContent(html_a71038208340174cc714654dbcbeed4e);
#
#
#
#         marker_57732ba8b40454dd14684055d8fbade8.bindPopup(popup_c17aa31d80463d08d131e01546539a27)
#         ;
#
#
#
#
#             var marker_7ba0b85e5c6ef87e0a7a85d36fb8b8ea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bc1ca14626b8c83ec666eeaf19794cb4);
#
#
#         var popup_1309ff4f58d122855ebaa4548bb44d88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_914d0778122a1d45721cb7da80bb880f = $(`&lt;div id=&quot;html_914d0778122a1d45721cb7da80bb880f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1309ff4f58d122855ebaa4548bb44d88.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd130fe29273670e0e5e655586901b4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd130fe29273670e0e5e655586901b4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd130fe29273670e0e5e655586901b4b = L.map(
#                 &quot;map_cd130fe29273670e0e5e655586901b4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08b8fc8c239d626d07b6e89371c0f038 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08b8fc8c239d626d07b6e89371c0f038.addTo(map_cd130fe29273670e0e5e655586901b4b);
#
#
#             var feature_group_9bb259583da6313ea84eea030e30d8a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c525b0b552d731f4b6adb2fc32c2979f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9bb259583da6313ea84eea030e30d8a6);
#
#
#         var popup_c1542b57f704c3a2cf0d0fc9de544d16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fad0fd152bff162dd39c08e9193d624d = $(`&lt;div id=&quot;html_fad0fd152bff162dd39c08e9193d624d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c1542b57f704c3a2cf0d0fc9de544d16.setContent(html_fad0fd152bff162dd39c08e9193d624d);
#
#
#
#         marker_c525b0b552d731f4b6adb2fc32c2979f.bindPopup(popup_c1542b57f704c3a2cf0d0fc9de544d16)
#         ;
#
#
#
#
#             var marker_e6bbc865f8cdcfd195af1d5279b5ed74 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9bb259583da6313ea84eea030e30d8a6);
#
#
#         var popup_c1c88caceeb1136dccabfb8a4d084c08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494f945a3f6474ab88ff617ef843444b = $(`&lt;div id=&quot;html_494f945a3f6474ab88ff617ef843444b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c1c88caceeb1136dccabfb8a4d084c08.setContent(html_494f945a3f6474ab88ff617ef843444b);
#
#
#
#         marker_e6bbc865f8cdcfd195af1d5279b5ed74.bindPopup(popup_c1c88caceeb1136dccabfb8a4d084c08)
#         ;
#
#
#
#
#             var marker_0b8217afa318737c0d4801f47e50dec8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9bb259583da6313ea84eea030e30d8a6);
#
#
#         var popup_316748b71c469e84d28316ebc06fe3b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feb875f99918e4a4cede7964572e692c = $(`&lt;div id=&quot;html_feb875f99918e4a4cede7964572e692c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_316748b71c469e84d28316ebc06fe3b8.setContent(html_feb875f99918e4a4cede7964572e692c);
#
#
#
#         marker_0b8217afa318737c0d4801f47e50dec8.bindPopup(popup_316748b71c469e84d28316ebc06fe3b8)
#         ;
#
#
#
#
#             var marker_3bc5df4f494210b763a2c24fcbbd5091 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9bb259583da6313ea84eea030e30d8a6);
#
#
#         var popup_61e2ed690e05892af6e2623705d12e2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3899285b31d09e6e66eeebd71cddb7dd = $(`&lt;div id=&quot;html_3899285b31d09e6e66eeebd71cddb7dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_61e2ed690e05892af6e2623705d12e2b.setContent(html_3899285b31d09e6e66eeebd71cddb7dd);
#
#
#
#         marker_3bc5df4f494210b763a2c24fcbbd5091.bindPopup(popup_61e2ed690e05892af6e2623705d12e2b)
#         ;
#
#
#
#
#             var marker_843e8aeb7c722b330735289de6445c9f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9bb259583da6313ea84eea030e30d8a6);
#
#
#         var popup_53d59e022a3a83185eb124ff07bb89fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a55c1b14c6f61bc5ca773f6e9bf94c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a55c1b14c6f61bc5ca773f6e9bf94c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a55c1b14c6f61bc5ca773f6e9bf94c9 = L.map(
#                 &quot;map_5a55c1b14c6f61bc5ca773f6e9bf94c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e73132200c2d331782683e3f1edcb9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5e73132200c2d331782683e3f1edcb9c.addTo(map_5a55c1b14c6f61bc5ca773f6e9bf94c9);
#
#
#             var feature_group_b4fd2e6246f137859ca4c6f8098c5bd7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b4fd2e6246f137859ca4c6f8098c5bd7.addTo(map_5a55c1b14c6f61bc5ca773f6e9bf94c9);
#
#
#             var feature_group_sub_group_74e7bbaaeadac217f6b5e89d4c821ec5 = L.featureGroup.subGroup(
#                 feature_group_b4fd2e6246f137859ca4c6f8098c5bd7
#             );
#
#
#             var marker_0b2de8691461ebff232ecebec0389c85 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e7bbaaeadac217f6b5e89d4c821ec5);
#
#
#         var popup_cb91c0fdf815780dd8d5542c5fa262f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86fcd14ccac2e869f100d3cc9245b608 = $(`&lt;div id=&quot;html_86fcd14ccac2e869f100d3cc9245b608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb91c0fdf815780dd8d5542c5fa262f4.setContent(html_86fcd14ccac2e869f100d3cc9245b608);
#
#
#
#         marker_0b2de8691461ebff232ecebec0389c85.bindPopup(popup_cb91c0fdf815780dd8d5542c5fa262f4)
#         ;
#
#
#
#
#             var marker_2a9d76ab2d0fd2d3a69f5de2a059ea6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e7bbaaeadac217f6b5e89d4c821ec5);
#
#
#         var popup_48cd6379f635d08e57d6c5fee530625e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68db0a0770a9c5340f63f0392a54773d = $(`&lt;div id=&quot;html_68db0a0770a9c5340f63f0392a54773d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_48cd6379f635d08e57d6c5fee530625e.setContent(html_68db0a0770a9c5340f63f0392a54773d);
#
#
#
#         marker_2a9d76ab2d0fd2d3a69f5de2a059ea6d.bindPopup(popup_48cd6379f635d08e57d6c5fee530625e)
#         ;
#
#
#
#
#             var marker_e27eb88ba90c582f51ba38a8bdbddb26 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e7bbaaeadac217f6b5e89d4c821ec5);
#
#
#         var popup_ab1a3cfec47eec1bbbb79e197fbf6419 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f938f185f7b353ea171618e97961565 = $(`&lt;div id=&quot;html_2f938f185f7b353ea171618e97961565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ab1a3cfec47eec1bbbb79e197fbf6419.setContent(html_2f938f185f7b353ea171618e97961565);
#
#
#
#         marker_e27eb88ba90c582f51ba38a8bdbddb26.bindPopup(popup_ab1a3cfec47eec1bbbb79e197fbf6419)
#         ;
#
#
#
#
#             var marker_0974da698ccaa6005714d0836f12d6c3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e7bbaaeadac217f6b5e89d4c821ec5);
#
#
#         var popup_5a24e8198be3df96780d503fa2da7219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac3d9c2c1c474ce4a2ce26da7b39e5bc = $(`&lt;div id=&quot;html_ac3d9c2c1c474ce4a2ce26da7b39e5bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5a24e8198be3df96780d503fa2da7219.setContent(html_ac3d9c2c1c474ce4a2ce26da7b39e5bc);
#
#
#
#         marker_
