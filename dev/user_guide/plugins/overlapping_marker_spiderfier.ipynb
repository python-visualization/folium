# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_456081627c120227fc901f3b7fb1b855 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_456081627c120227fc901f3b7fb1b855&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_456081627c120227fc901f3b7fb1b855 = L.map(
#                 &quot;map_456081627c120227fc901f3b7fb1b855&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_222cf506faaca847685371902ee4ec41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_222cf506faaca847685371902ee4ec41.addTo(map_456081627c120227fc901f3b7fb1b855);
#
#
#             var marker_ac28843e630f9f24fe80f8f0c5f4c20f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_456081627c120227fc901f3b7fb1b855);
#
#
#         var popup_5a0378e1aa7112155c918f7852d816cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de92b4266529111e5d8fcfdb573b001a = $(`&lt;div id=&quot;html_de92b4266529111e5d8fcfdb573b001a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5a0378e1aa7112155c918f7852d816cb.setContent(html_de92b4266529111e5d8fcfdb573b001a);
#
#
#
#         marker_ac28843e630f9f24fe80f8f0c5f4c20f.bindPopup(popup_5a0378e1aa7112155c918f7852d816cb)
#         ;
#
#
#
#
#             var marker_d22f4145e1deb817bc5a5db70187264b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_456081627c120227fc901f3b7fb1b855);
#
#
#         var popup_880877c45b6855be75476e6c58ae79a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65bf5bfd5edc3839d907823760b9f178 = $(`&lt;div id=&quot;html_65bf5bfd5edc3839d907823760b9f178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_880877c45b6855be75476e6c58ae79a1.setContent(html_65bf5bfd5edc3839d907823760b9f178);
#
#
#
#         marker_d22f4145e1deb817bc5a5db70187264b.bindPopup(popup_880877c45b6855be75476e6c58ae79a1)
#         ;
#
#
#
#
#             var marker_3e5b69a96038ba184611201f1c602fcf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_456081627c120227fc901f3b7fb1b855);
#
#
#         var popup_506543db5c289fb04518a64c9f818bd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34c271ddd0854d595320fe15ccbb7366 = $(`&lt;div id=&quot;html_34c271ddd0854d595320fe15ccbb7366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_506543db5c289fb04518a64c9f818bd9.setContent(html_34c271ddd0854d595320fe15ccbb7366);
#
#
#
#         marker_3e5b69a96038ba184611201f1c602fcf.bindPopup(popup_506543db5c289fb04518a64c9f818bd9)
#         ;
#
#
#
#
#             var marker_600a935a57a160e6adff0aa01da1409b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_456081627c120227fc901f3b7fb1b855);
#
#
#         var popup_87870d99ca1b1e0a52d102bad0c42a76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9b3c1d46c7a13f115abb78c17a0ac41 = $(`&lt;div id=&quot;html_b9b3c1d46c7a13f115abb78c17a0ac41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_87870d99ca1b1e0a52d102bad0c42a76.setContent(html_b9b3c1d46c7a13f115abb78c17a0ac41);
#
#
#
#         marker_600a935a57a160e6adff0aa01da1409b.bindPopup(popup_87870d99ca1b1e0a52d102bad0c42a76)
#         ;
#
#
#
#
#             var marker_b9e96a8dc123210b0f87affbf015857e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_456081627c120227fc901f3b7fb1b855);
#
#
#         var popup_748661f8af8cb45ab2445b983f4fa6f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_216fec7e079a8d29ba831feee8304686 = $(`&lt;div id=&quot;html_216fec7e079a8d29ba831feee8304686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_748661f8af8cb45ab2445b983f4fa6f1.setContent(html_216fec7e079a8d29ba831feee8304686);
#
#
#
#         marker_b9e96a8dc123210b0f87affbf015857e.bindPopup(popup_748661f8af8cb45ab2445b983f4fa6f1)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dc9e368de7268ec0bcea1f42e591d5f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dc9e368de7268ec0bcea1f42e591d5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dc9e368de7268ec0bcea1f42e591d5f = L.map(
#                 &quot;map_4dc9e368de7268ec0bcea1f42e591d5f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ba6c41dc934667b4ef6df1299a719c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ba6c41dc934667b4ef6df1299a719c6.addTo(map_4dc9e368de7268ec0bcea1f42e591d5f);
#
#
#             var feature_group_b6f648e819a99e85ebf3bc3ea3999361 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f19d9db8c8ee1fe7fbbf367a97e2dc21 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b6f648e819a99e85ebf3bc3ea3999361);
#
#
#         var popup_e4f75190a782f686003305a732d254ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bfb0c762b6f8bde9751c98fddc6f6ba = $(`&lt;div id=&quot;html_5bfb0c762b6f8bde9751c98fddc6f6ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e4f75190a782f686003305a732d254ba.setContent(html_5bfb0c762b6f8bde9751c98fddc6f6ba);
#
#
#
#         marker_f19d9db8c8ee1fe7fbbf367a97e2dc21.bindPopup(popup_e4f75190a782f686003305a732d254ba)
#         ;
#
#
#
#
#             var marker_ab7b83af90609bb0598fecb07ee1e142 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b6f648e819a99e85ebf3bc3ea3999361);
#
#
#         var popup_fb86f08fec14cab6b9dc6dffdbc1cc17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ae805f1ee4ab6553ceb5b92a71cf9e4 = $(`&lt;div id=&quot;html_6ae805f1ee4ab6553ceb5b92a71cf9e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fb86f08fec14cab6b9dc6dffdbc1cc17.setContent(html_6ae805f1ee4ab6553ceb5b92a71cf9e4);
#
#
#
#         marker_ab7b83af90609bb0598fecb07ee1e142.bindPopup(popup_fb86f08fec14cab6b9dc6dffdbc1cc17)
#         ;
#
#
#
#
#             var marker_352908360f781c870d37b5e8e9d2a115 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b6f648e819a99e85ebf3bc3ea3999361);
#
#
#         var popup_a99b2054b10f360ccb9955859788170c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f86775c89154d652a189269076f76e4 = $(`&lt;div id=&quot;html_4f86775c89154d652a189269076f76e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a99b2054b10f360ccb9955859788170c.setContent(html_4f86775c89154d652a189269076f76e4);
#
#
#
#         marker_352908360f781c870d37b5e8e9d2a115.bindPopup(popup_a99b2054b10f360ccb9955859788170c)
#         ;
#
#
#
#
#             var marker_8841e93185e1bbe936cabaacfb2ff2e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b6f648e819a99e85ebf3bc3ea3999361);
#
#
#         var popup_1ecdf6f0997aca502847290f69577ed8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fcab1e4efb66057b099746f575f85ee = $(`&lt;div id=&quot;html_4fcab1e4efb66057b099746f575f85ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1ecdf6f0997aca502847290f69577ed8.setContent(html_4fcab1e4efb66057b099746f575f85ee);
#
#
#
#         marker_8841e93185e1bbe936cabaacfb2ff2e0.bindPopup(popup_1ecdf6f0997aca502847290f69577ed8)
#         ;
#
#
#
#
#             var marker_93507c57c982c373895b896650c2dbd8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b6f648e819a99e85ebf3bc3ea3999361);
#
#
#         var popup_4d95b099298f70f695bae8cc44fe1ef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38040554acac9b9c1f9dfbad962ba230 = $(`&lt;div id=&quot;html_38040554acac9b9c1f9dfbad962ba230&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5038195451a646331dc03924f7189ce {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5038195451a646331dc03924f7189ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5038195451a646331dc03924f7189ce = L.map(
#                 &quot;map_d5038195451a646331dc03924f7189ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d27a152ff70c456f210488d8a1871ea7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d27a152ff70c456f210488d8a1871ea7.addTo(map_d5038195451a646331dc03924f7189ce);
#
#
#             var feature_group_0fd1eecac366c9e4bfa2a92b11cda37a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0fd1eecac366c9e4bfa2a92b11cda37a.addTo(map_d5038195451a646331dc03924f7189ce);
#
#
#             var feature_group_sub_group_35af1cb2e83fe24e809e46b376b7e0df = L.featureGroup.subGroup(
#                 feature_group_0fd1eecac366c9e4bfa2a92b11cda37a
#             );
#
#
#             var marker_b7a364ee7a37664e4389a1da2e60ef16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_35af1cb2e83fe24e809e46b376b7e0df);
#
#
#         var popup_7e345ee5209265c0108d5d48faae1979 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d187943925e37eba21874c34f391bfb8 = $(`&lt;div id=&quot;html_d187943925e37eba21874c34f391bfb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7e345ee5209265c0108d5d48faae1979.setContent(html_d187943925e37eba21874c34f391bfb8);
#
#
#
#         marker_b7a364ee7a37664e4389a1da2e60ef16.bindPopup(popup_7e345ee5209265c0108d5d48faae1979)
#         ;
#
#
#
#
#             var marker_9d816b9b43b7c2405d7eea89a5d6d470 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_35af1cb2e83fe24e809e46b376b7e0df);
#
#
#         var popup_f5c499091373e1074759368384aab745 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc56a62bb3e08eecb307e2c16acc3f8e = $(`&lt;div id=&quot;html_fc56a62bb3e08eecb307e2c16acc3f8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f5c499091373e1074759368384aab745.setContent(html_fc56a62bb3e08eecb307e2c16acc3f8e);
#
#
#
#         marker_9d816b9b43b7c2405d7eea89a5d6d470.bindPopup(popup_f5c499091373e1074759368384aab745)
#         ;
#
#
#
#
#             var marker_802d47f5372de4646ab9eeafc86f0758 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_35af1cb2e83fe24e809e46b376b7e0df);
#
#
#         var popup_0a5cf78cca6367154f03fea55d7070c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551852f25d0e1df28178317281796563 = $(`&lt;div id=&quot;html_551852f25d0e1df28178317281796563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0a5cf78cca6367154f03fea55d7070c4.setContent(html_551852f25d0e1df28178317281796563);
#
#
#
#         marker_802d47f5372de4646ab9eeafc86f0758.bindPopup(popup_0a5cf78cca6367154f03fea55d7070c4)
#         ;
#
#
#
#
#             var marker_afb9a8f3f65f8306d81c63ff36d7c52d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_35af1cb2e83fe24e809e46b376b7e0df);
#
#
#         var popup_1e176f4aba1d9a925aaaf87f708d0ed0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1a8642f66c4a01991e5282c201e8998 = $(`&lt;div id=&quot;html_a1a8642f66c4a01991e5282c201e8998&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1e176f4aba1d9a925aaaf87f708d0ed0.setContent(html_a1a8642f66c4a01991e5282c201e8998);
#
#
#
#         marker_afb9a8f3f65f8306d81c63ff36d7c52d.bindPopup(popup_1e176f4aba1d9a925aaaf87f708d0ed0)
#         ;
#
#
#
#
#             var marker_24734492e3d3580345d8cb883225490a = L.marker(
#                 [45.0503999
