# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44fc2386b8bf4c1f0942ad83e814371d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44fc2386b8bf4c1f0942ad83e814371d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44fc2386b8bf4c1f0942ad83e814371d = L.map(
#                 &quot;map_44fc2386b8bf4c1f0942ad83e814371d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be59e644cb2529e822ef14f0ab8b52a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be59e644cb2529e822ef14f0ab8b52a5.addTo(map_44fc2386b8bf4c1f0942ad83e814371d);
#
#
#             var marker_021445801047d0e3ccf824c2663a4c0d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_44fc2386b8bf4c1f0942ad83e814371d);
#
#
#         var popup_797bbb6fe5a294564caae0013f2058a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19654f450a8e07b320d36e912dede3e4 = $(`&lt;div id=&quot;html_19654f450a8e07b320d36e912dede3e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_797bbb6fe5a294564caae0013f2058a9.setContent(html_19654f450a8e07b320d36e912dede3e4);
#
#
#
#         marker_021445801047d0e3ccf824c2663a4c0d.bindPopup(popup_797bbb6fe5a294564caae0013f2058a9)
#         ;
#
#
#
#
#             var marker_0649e0d34c8b744ec754788479ff55ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_44fc2386b8bf4c1f0942ad83e814371d);
#
#
#         var popup_68b9267963a27a78bea079b93c22619b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2effb55310f8d616a087f7468b96e424 = $(`&lt;div id=&quot;html_2effb55310f8d616a087f7468b96e424&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_68b9267963a27a78bea079b93c22619b.setContent(html_2effb55310f8d616a087f7468b96e424);
#
#
#
#         marker_0649e0d34c8b744ec754788479ff55ea.bindPopup(popup_68b9267963a27a78bea079b93c22619b)
#         ;
#
#
#
#
#             var marker_89018521943bb6c0cb6f110b22a6c2cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_44fc2386b8bf4c1f0942ad83e814371d);
#
#
#         var popup_29784dc3f224dcaf1bf76f2b2779963c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0bb6964e00678f49614ccf5ebc4fb0 = $(`&lt;div id=&quot;html_3d0bb6964e00678f49614ccf5ebc4fb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_29784dc3f224dcaf1bf76f2b2779963c.setContent(html_3d0bb6964e00678f49614ccf5ebc4fb0);
#
#
#
#         marker_89018521943bb6c0cb6f110b22a6c2cf.bindPopup(popup_29784dc3f224dcaf1bf76f2b2779963c)
#         ;
#
#
#
#
#             var marker_b434e7c56b42a4850c0bfb4cb16a213a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_44fc2386b8bf4c1f0942ad83e814371d);
#
#
#         var popup_3b876aab5ed06a48b33870208fd53041 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e0e7c6fef5c5fbb9b94d5992fcce72a = $(`&lt;div id=&quot;html_5e0e7c6fef5c5fbb9b94d5992fcce72a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3b876aab5ed06a48b33870208fd53041.setContent(html_5e0e7c6fef5c5fbb9b94d5992fcce72a);
#
#
#
#         marker_b434e7c56b42a4850c0bfb4cb16a213a.bindPopup(popup_3b876aab5ed06a48b33870208fd53041)
#         ;
#
#
#
#
#             var marker_135f685627d13466e90bf8344d75160f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_44fc2386b8bf4c1f0942ad83e814371d);
#
#
#         var popup_c76fd9848efc0140ec6c7f21216645d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cb7b5061b6b4a3fac90ea4a3b6273bf = $(`&lt;div id=&quot;html_1cb7b5061b6b4a3fac90ea4a3b6273bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c76fd9848efc0140ec6c7f21216645d2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31a496f90c4f9159ff7171366d93dbdf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31a496f90c4f9159ff7171366d93dbdf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31a496f90c4f9159ff7171366d93dbdf = L.map(
#                 &quot;map_31a496f90c4f9159ff7171366d93dbdf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37f5ddbed97fd77d90fd6d2c0be36719 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_37f5ddbed97fd77d90fd6d2c0be36719.addTo(map_31a496f90c4f9159ff7171366d93dbdf);
#
#
#             var feature_group_de02924e32a2a0aa8862911c542adbcf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9e7cdc8ce23095f22a76fd2859bd34b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_de02924e32a2a0aa8862911c542adbcf);
#
#
#         var popup_81e023e11c92bbb41f9622ceb5bd433b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47f605df61711fd20e14a1b78f469a14 = $(`&lt;div id=&quot;html_47f605df61711fd20e14a1b78f469a14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_81e023e11c92bbb41f9622ceb5bd433b.setContent(html_47f605df61711fd20e14a1b78f469a14);
#
#
#
#         marker_9e7cdc8ce23095f22a76fd2859bd34b0.bindPopup(popup_81e023e11c92bbb41f9622ceb5bd433b)
#         ;
#
#
#
#
#             var marker_c08e12db721815b65f816914cff4eb2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_de02924e32a2a0aa8862911c542adbcf);
#
#
#         var popup_6e4d87f64ba297b4fd86ddd4cd577c38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_948cb0a488c67c850b2e4d50834b9c03 = $(`&lt;div id=&quot;html_948cb0a488c67c850b2e4d50834b9c03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6e4d87f64ba297b4fd86ddd4cd577c38.setContent(html_948cb0a488c67c850b2e4d50834b9c03);
#
#
#
#         marker_c08e12db721815b65f816914cff4eb2d.bindPopup(popup_6e4d87f64ba297b4fd86ddd4cd577c38)
#         ;
#
#
#
#
#             var marker_20426f51f6478cef55bf2509c4e60316 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_de02924e32a2a0aa8862911c542adbcf);
#
#
#         var popup_ff758b48aff0f19c198f2761510dbf3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f005163d7bc0b0d1776322a37e4996f = $(`&lt;div id=&quot;html_2f005163d7bc0b0d1776322a37e4996f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ff758b48aff0f19c198f2761510dbf3d.setContent(html_2f005163d7bc0b0d1776322a37e4996f);
#
#
#
#         marker_20426f51f6478cef55bf2509c4e60316.bindPopup(popup_ff758b48aff0f19c198f2761510dbf3d)
#         ;
#
#
#
#
#             var marker_b8c05d1f3179f0f5b9c4ade1ba43cee0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_de02924e32a2a0aa8862911c542adbcf);
#
#
#         var popup_93d3a4a1f1511b4c43bf550431e282e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fdf2a567e45371f3fba80dfc5877e3e = $(`&lt;div id=&quot;html_0fdf2a567e45371f3fba80dfc5877e3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_93d3a4a1f1511b4c43bf550431e282e7.setContent(html_0fdf2a567e45371f3fba80dfc5877e3e);
#
#
#
#         marker_b8c05d1f3179f0f5b9c4ade1ba43cee0.bindPopup(popup_93d3a4a1f1511b4c43bf550431e282e7)
#         ;
#
#
#
#
#             var marker_736fe5c3f133f5575a9c66672e89cf62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_de02924e32a2a0aa8862911c542adbcf);
#
#
#         var popup_59ed645558d8ecff92bfb6701ab78686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4a062d29c9fd10b4d531437981b2b3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4a062d29c9fd10b4d531437981b2b3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4a062d29c9fd10b4d531437981b2b3c = L.map(
#                 &quot;map_d4a062d29c9fd10b4d531437981b2b3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa2788e1688a5169ebc3152fa84070a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa2788e1688a5169ebc3152fa84070a4.addTo(map_d4a062d29c9fd10b4d531437981b2b3c);
#
#
#             var feature_group_1de4fee7907ff188062ce56105006221 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1de4fee7907ff188062ce56105006221.addTo(map_d4a062d29c9fd10b4d531437981b2b3c);
#
#
#             var feature_group_sub_group_416e323009247615ff039605f97cd992 = L.featureGroup.subGroup(
#                 feature_group_1de4fee7907ff188062ce56105006221
#             );
#
#
#             var marker_015731daecb8847ea25e952bc3ffbd1a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_416e323009247615ff039605f97cd992);
#
#
#         var popup_2ea84a8c77e76b1837fd153193103f89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af33b5770578642d1866f0aaddb8db0e = $(`&lt;div id=&quot;html_af33b5770578642d1866f0aaddb8db0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2ea84a8c77e76b1837fd153193103f89.setContent(html_af33b5770578642d1866f0aaddb8db0e);
#
#
#
#         marker_015731daecb8847ea25e952bc3ffbd1a.bindPopup(popup_2ea84a8c77e76b1837fd153193103f89)
#         ;
#
#
#
#
#             var marker_2b17dda8a4793847e1dc092c733f6611 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_416e323009247615ff039605f97cd992);
#
#
#         var popup_0dc574c0c1e8e6e5d99aa8b9590e62c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_664af47552b997ac219062a4851051f6 = $(`&lt;div id=&quot;html_664af47552b997ac219062a4851051f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0dc574c0c1e8e6e5d99aa8b9590e62c5.setContent(html_664af47552b997ac219062a4851051f6);
#
#
#
#         marker_2b17dda8a4793847e1dc092c733f6611.bindPopup(popup_0dc574c0c1e8e6e5d99aa8b9590e62c5)
#         ;
#
#
#
#
#             var marker_5f0bcf46e2d129b298806c33539a9dd3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_416e323009247615ff039605f97cd992);
#
#
#         var popup_d2eb69175032b9ed6c5c147f463377b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b9a133ac0412794d0ab1f9ed8ac9571 = $(`&lt;div id=&quot;html_8b9a133ac0412794d0ab1f9ed8ac9571&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d2eb69175032b9ed6c5c147f463377b7.setContent(html_8b9a133ac0412794d0ab1f9ed8ac9571);
#
#
#
#         marker_5f0bcf46e2d129b298806c33539a9dd3.bindPopup(popup_d2eb69175032b9ed6c5c147f463377b7)
#         ;
#
#
#
#
#             var marker_3f66f8f79f3b4a42a26091d2cdd8feab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_416e323009247615ff039605f97cd992);
#
#
#         var popup_181facb17912d040e4cd4bacba13539d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f447d996cebd72c763eed68d7ce9433 = $(`&lt;div id=&quot;html_7f447d996cebd72c763eed68d7ce9433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_181facb17912d040e4cd4bacba13539d.setContent(html_7f447d996cebd72c763eed68d7ce9433);
#
#
#
#         marker_
