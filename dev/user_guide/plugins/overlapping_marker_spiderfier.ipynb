# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3d90e8582f3d8fad3a32e23f14f9580 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3d90e8582f3d8fad3a32e23f14f9580&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3d90e8582f3d8fad3a32e23f14f9580 = L.map(
#                 &quot;map_a3d90e8582f3d8fad3a32e23f14f9580&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c3790f52b88be0071cd39f5fdee940b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c3790f52b88be0071cd39f5fdee940b.addTo(map_a3d90e8582f3d8fad3a32e23f14f9580);
#
#
#             var marker_9caffbc45eff957b2105ebd1180fe93d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a3d90e8582f3d8fad3a32e23f14f9580);
#
#
#         var popup_a4b016a853367a23292b78e4fef6b692 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e07b3bd80837c2e382f47d30105f0669 = $(`&lt;div id=&quot;html_e07b3bd80837c2e382f47d30105f0669&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a4b016a853367a23292b78e4fef6b692.setContent(html_e07b3bd80837c2e382f47d30105f0669);
#
#
#
#         marker_9caffbc45eff957b2105ebd1180fe93d.bindPopup(popup_a4b016a853367a23292b78e4fef6b692)
#         ;
#
#
#
#
#             var marker_d26f748cfe0c203cbe696652ec8d8434 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a3d90e8582f3d8fad3a32e23f14f9580);
#
#
#         var popup_ae2f30350b0a128be2c16aebdaa2cb4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81424f79dcf5241435492bd936f6fba3 = $(`&lt;div id=&quot;html_81424f79dcf5241435492bd936f6fba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ae2f30350b0a128be2c16aebdaa2cb4b.setContent(html_81424f79dcf5241435492bd936f6fba3);
#
#
#
#         marker_d26f748cfe0c203cbe696652ec8d8434.bindPopup(popup_ae2f30350b0a128be2c16aebdaa2cb4b)
#         ;
#
#
#
#
#             var marker_d361a22013dc6ca31416cf787a46687f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a3d90e8582f3d8fad3a32e23f14f9580);
#
#
#         var popup_c9eed9d44be66319159c8c99a8b5173c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce05a8aeca73f42e03a0a56e46dda6ce = $(`&lt;div id=&quot;html_ce05a8aeca73f42e03a0a56e46dda6ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c9eed9d44be66319159c8c99a8b5173c.setContent(html_ce05a8aeca73f42e03a0a56e46dda6ce);
#
#
#
#         marker_d361a22013dc6ca31416cf787a46687f.bindPopup(popup_c9eed9d44be66319159c8c99a8b5173c)
#         ;
#
#
#
#
#             var marker_969d533942c10bfb77d62e24be3cf9ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a3d90e8582f3d8fad3a32e23f14f9580);
#
#
#         var popup_912636739b28a06fcfe030c4ff815824 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7c9217eb98d28aa74d16508d79e51fb = $(`&lt;div id=&quot;html_a7c9217eb98d28aa74d16508d79e51fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_912636739b28a06fcfe030c4ff815824.setContent(html_a7c9217eb98d28aa74d16508d79e51fb);
#
#
#
#         marker_969d533942c10bfb77d62e24be3cf9ea.bindPopup(popup_912636739b28a06fcfe030c4ff815824)
#         ;
#
#
#
#
#             var marker_39a7108f2b8bf7d329b2d66d69d98058 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a3d90e8582f3d8fad3a32e23f14f9580);
#
#
#         var popup_c292567b4c00f8c59549b5a7c2d378db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5ec6f484229aaf96389545b48727d44 = $(`&lt;div id=&quot;html_e5ec6f484229aaf96389545b48727d44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c292567b4c00f8c59549b5a7c2d378db.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68ccfa9648d492ee627c0daeb35f2c65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68ccfa9648d492ee627c0daeb35f2c65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68ccfa9648d492ee627c0daeb35f2c65 = L.map(
#                 &quot;map_68ccfa9648d492ee627c0daeb35f2c65&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e04789b32232f4cc018b1c925002c5b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e04789b32232f4cc018b1c925002c5b9.addTo(map_68ccfa9648d492ee627c0daeb35f2c65);
#
#
#             var feature_group_ea0cc89672899e6cb59fa2ebeb9d9693 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_97eee389594ff3106482004c262a59cb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ea0cc89672899e6cb59fa2ebeb9d9693);
#
#
#         var popup_15adc9edf7af2aea198099cc2fe209d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aec5a30acdcdb212ebc888902f8996c6 = $(`&lt;div id=&quot;html_aec5a30acdcdb212ebc888902f8996c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_15adc9edf7af2aea198099cc2fe209d4.setContent(html_aec5a30acdcdb212ebc888902f8996c6);
#
#
#
#         marker_97eee389594ff3106482004c262a59cb.bindPopup(popup_15adc9edf7af2aea198099cc2fe209d4)
#         ;
#
#
#
#
#             var marker_9d19370b79f4ba7b2555ebb9eda23a03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ea0cc89672899e6cb59fa2ebeb9d9693);
#
#
#         var popup_5f2a5b90199ba88cf44bcb900a5f46b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80580b81a23c50cae31a5be7f5f82fa6 = $(`&lt;div id=&quot;html_80580b81a23c50cae31a5be7f5f82fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5f2a5b90199ba88cf44bcb900a5f46b3.setContent(html_80580b81a23c50cae31a5be7f5f82fa6);
#
#
#
#         marker_9d19370b79f4ba7b2555ebb9eda23a03.bindPopup(popup_5f2a5b90199ba88cf44bcb900a5f46b3)
#         ;
#
#
#
#
#             var marker_3ae8c70ef75038c9dd1aeb1332c91150 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ea0cc89672899e6cb59fa2ebeb9d9693);
#
#
#         var popup_47745cc641f7a528d2e273f00964d1ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67edfbd738ee9c9a44403b8fca27f572 = $(`&lt;div id=&quot;html_67edfbd738ee9c9a44403b8fca27f572&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_47745cc641f7a528d2e273f00964d1ef.setContent(html_67edfbd738ee9c9a44403b8fca27f572);
#
#
#
#         marker_3ae8c70ef75038c9dd1aeb1332c91150.bindPopup(popup_47745cc641f7a528d2e273f00964d1ef)
#         ;
#
#
#
#
#             var marker_3ab6acee5623c040d26d5062528668ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ea0cc89672899e6cb59fa2ebeb9d9693);
#
#
#         var popup_a998a3e6cd763fee80da9a9553f558f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1e4e51f050aff257bac2cef69525f51 = $(`&lt;div id=&quot;html_b1e4e51f050aff257bac2cef69525f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a998a3e6cd763fee80da9a9553f558f2.setContent(html_b1e4e51f050aff257bac2cef69525f51);
#
#
#
#         marker_3ab6acee5623c040d26d5062528668ac.bindPopup(popup_a998a3e6cd763fee80da9a9553f558f2)
#         ;
#
#
#
#
#             var marker_216734a99d2dc718a763c2095616ea2d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ea0cc89672899e6cb59fa2ebeb9d9693);
#
#
#         var popup_7a8efb92e453f7a5ec6ef7bc00321c24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa5833ef25f8702b2467da8ea641dedf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa5833ef25f8702b2467da8ea641dedf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa5833ef25f8702b2467da8ea641dedf = L.map(
#                 &quot;map_fa5833ef25f8702b2467da8ea641dedf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_188a296187a07d44b2a5dbbb6c53daa4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_188a296187a07d44b2a5dbbb6c53daa4.addTo(map_fa5833ef25f8702b2467da8ea641dedf);
#
#
#             var feature_group_9e38ac7379b7e16d9e9d538276740a30 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9e38ac7379b7e16d9e9d538276740a30.addTo(map_fa5833ef25f8702b2467da8ea641dedf);
#
#
#             var feature_group_sub_group_795111aa1282e52cb43e0f212ece82d0 = L.featureGroup.subGroup(
#                 feature_group_9e38ac7379b7e16d9e9d538276740a30
#             );
#
#
#             var marker_38c66c7bba97fb0ae6ce46848afa2e7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_795111aa1282e52cb43e0f212ece82d0);
#
#
#         var popup_8c09941f36b1b423af2538aab7f7ad30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494cf77a6e3b8db75a7f292696dbb793 = $(`&lt;div id=&quot;html_494cf77a6e3b8db75a7f292696dbb793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8c09941f36b1b423af2538aab7f7ad30.setContent(html_494cf77a6e3b8db75a7f292696dbb793);
#
#
#
#         marker_38c66c7bba97fb0ae6ce46848afa2e7d.bindPopup(popup_8c09941f36b1b423af2538aab7f7ad30)
#         ;
#
#
#
#
#             var marker_ce5c2841556e05fe6274ba9121693248 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_795111aa1282e52cb43e0f212ece82d0);
#
#
#         var popup_4bc911c8da70f191a64a77c1f8faf73f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e68235206a0a382502b4435275a67e93 = $(`&lt;div id=&quot;html_e68235206a0a382502b4435275a67e93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4bc911c8da70f191a64a77c1f8faf73f.setContent(html_e68235206a0a382502b4435275a67e93);
#
#
#
#         marker_ce5c2841556e05fe6274ba9121693248.bindPopup(popup_4bc911c8da70f191a64a77c1f8faf73f)
#         ;
#
#
#
#
#             var marker_7c05059bc856ebcddcbe1e67e8420079 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_795111aa1282e52cb43e0f212ece82d0);
#
#
#         var popup_0091c0e6ee9c98eadd905260c75626b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7430b065d6dc65a5b0198dedaf8df71b = $(`&lt;div id=&quot;html_7430b065d6dc65a5b0198dedaf8df71b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0091c0e6ee9c98eadd905260c75626b7.setContent(html_7430b065d6dc65a5b0198dedaf8df71b);
#
#
#
#         marker_7c05059bc856ebcddcbe1e67e8420079.bindPopup(popup_0091c0e6ee9c98eadd905260c75626b7)
#         ;
#
#
#
#
#             var marker_9436056f1094646f12060496c7741469 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_795111aa1282e52cb43e0f212ece82d0);
#
#
#         var popup_3133479fdbaa8222e6b7bf0cfc0c116a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a212415f64fcae49bffadb6534412e = $(`&lt;div id=&quot;html_f9a212415f64fcae49bffadb6534412e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3133479fdbaa8222e6b7bf0cfc0c116a.setContent(html_f9a212415f64fcae49bffadb6534412e);
#
#
#
#         marker_
