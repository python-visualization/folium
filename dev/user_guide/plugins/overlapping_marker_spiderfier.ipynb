# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a03a572152db527851850dbf018a8e44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a03a572152db527851850dbf018a8e44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a03a572152db527851850dbf018a8e44 = L.map(
#                 &quot;map_a03a572152db527851850dbf018a8e44&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7b7c8a04988b896344db94a2d55df9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7b7c8a04988b896344db94a2d55df9e.addTo(map_a03a572152db527851850dbf018a8e44);
#
#
#             var marker_5b716a9907cecc02f747bfca56f26297 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a03a572152db527851850dbf018a8e44);
#
#
#         var popup_90dfed8ea0c345970e14e93ac30ccec4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faef5f51640f5ebc79b5e79625fd92ac = $(`&lt;div id=&quot;html_faef5f51640f5ebc79b5e79625fd92ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_90dfed8ea0c345970e14e93ac30ccec4.setContent(html_faef5f51640f5ebc79b5e79625fd92ac);
#
#
#
#         marker_5b716a9907cecc02f747bfca56f26297.bindPopup(popup_90dfed8ea0c345970e14e93ac30ccec4)
#         ;
#
#
#
#
#             var marker_3a37f62c5a427543493f0e16d19e3226 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a03a572152db527851850dbf018a8e44);
#
#
#         var popup_6879a55626b58f024f8bf5369c39292c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd1edec3db5a30bbe50655cda598ab43 = $(`&lt;div id=&quot;html_cd1edec3db5a30bbe50655cda598ab43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6879a55626b58f024f8bf5369c39292c.setContent(html_cd1edec3db5a30bbe50655cda598ab43);
#
#
#
#         marker_3a37f62c5a427543493f0e16d19e3226.bindPopup(popup_6879a55626b58f024f8bf5369c39292c)
#         ;
#
#
#
#
#             var marker_3cc38b50fe892ada76a8a99cc800dfaf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a03a572152db527851850dbf018a8e44);
#
#
#         var popup_0b5d95a029b7a41b0e38418788fb7126 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbb8bd812bfe83927fb610c9e17ea938 = $(`&lt;div id=&quot;html_bbb8bd812bfe83927fb610c9e17ea938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0b5d95a029b7a41b0e38418788fb7126.setContent(html_bbb8bd812bfe83927fb610c9e17ea938);
#
#
#
#         marker_3cc38b50fe892ada76a8a99cc800dfaf.bindPopup(popup_0b5d95a029b7a41b0e38418788fb7126)
#         ;
#
#
#
#
#             var marker_5891d192bde431e7513b5bea34cf0f8a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a03a572152db527851850dbf018a8e44);
#
#
#         var popup_c63830864f854a744db9a98b6daced25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f710d5019b549edb3205ea3d65c8d93 = $(`&lt;div id=&quot;html_0f710d5019b549edb3205ea3d65c8d93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c63830864f854a744db9a98b6daced25.setContent(html_0f710d5019b549edb3205ea3d65c8d93);
#
#
#
#         marker_5891d192bde431e7513b5bea34cf0f8a.bindPopup(popup_c63830864f854a744db9a98b6daced25)
#         ;
#
#
#
#
#             var marker_db16635d7cc7a52f9fb6c74d47366101 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a03a572152db527851850dbf018a8e44);
#
#
#         var popup_27a3d8ef9bb76a6ea9addf488b8f27d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32d535029f45666eed55117349b624c6 = $(`&lt;div id=&quot;html_32d535029f45666eed55117349b624c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_27a3d8ef9bb76a6ea9addf488b8f27d3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b519f37d654ab995d2d1b9c0f184dcd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b519f37d654ab995d2d1b9c0f184dcd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b519f37d654ab995d2d1b9c0f184dcd9 = L.map(
#                 &quot;map_b519f37d654ab995d2d1b9c0f184dcd9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e47449ca8a87ad84e32696bde3c76b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e47449ca8a87ad84e32696bde3c76b6.addTo(map_b519f37d654ab995d2d1b9c0f184dcd9);
#
#
#             var feature_group_4a53e4bd62ffb40bbeb1eaebcb29e291 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f4a7e8001ee365d4ad73d400547f61d1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4a53e4bd62ffb40bbeb1eaebcb29e291);
#
#
#         var popup_18d5c7feda969f8c8872247e3cefd154 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f76fa365819c0b14e8e3e56643b54ae = $(`&lt;div id=&quot;html_9f76fa365819c0b14e8e3e56643b54ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_18d5c7feda969f8c8872247e3cefd154.setContent(html_9f76fa365819c0b14e8e3e56643b54ae);
#
#
#
#         marker_f4a7e8001ee365d4ad73d400547f61d1.bindPopup(popup_18d5c7feda969f8c8872247e3cefd154)
#         ;
#
#
#
#
#             var marker_f902f89053d7ba063db2a742a030e9f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4a53e4bd62ffb40bbeb1eaebcb29e291);
#
#
#         var popup_d4a4e98e542924d750106947fbb3715d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_591ef9fa6485e62a9eecc0b9fbfb43f4 = $(`&lt;div id=&quot;html_591ef9fa6485e62a9eecc0b9fbfb43f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d4a4e98e542924d750106947fbb3715d.setContent(html_591ef9fa6485e62a9eecc0b9fbfb43f4);
#
#
#
#         marker_f902f89053d7ba063db2a742a030e9f5.bindPopup(popup_d4a4e98e542924d750106947fbb3715d)
#         ;
#
#
#
#
#             var marker_1ffde2abf6cdb974ca13c0083199d05e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4a53e4bd62ffb40bbeb1eaebcb29e291);
#
#
#         var popup_9b05ccb59d8560e75c0b4c20c943eb76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ff7f18016796b566077fd81e7d1395a = $(`&lt;div id=&quot;html_2ff7f18016796b566077fd81e7d1395a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b05ccb59d8560e75c0b4c20c943eb76.setContent(html_2ff7f18016796b566077fd81e7d1395a);
#
#
#
#         marker_1ffde2abf6cdb974ca13c0083199d05e.bindPopup(popup_9b05ccb59d8560e75c0b4c20c943eb76)
#         ;
#
#
#
#
#             var marker_775ce65d309acb6c74f44c99b1e8c923 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4a53e4bd62ffb40bbeb1eaebcb29e291);
#
#
#         var popup_5f62b205bb2973eadb442c75cc93ee37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86f668d83a24603845b4056083b8242c = $(`&lt;div id=&quot;html_86f668d83a24603845b4056083b8242c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5f62b205bb2973eadb442c75cc93ee37.setContent(html_86f668d83a24603845b4056083b8242c);
#
#
#
#         marker_775ce65d309acb6c74f44c99b1e8c923.bindPopup(popup_5f62b205bb2973eadb442c75cc93ee37)
#         ;
#
#
#
#
#             var marker_d7759a18eb59d1c1ee2f526247524681 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4a53e4bd62ffb40bbeb1eaebcb29e291);
#
#
#         var popup_694b7b2599a3920856231e381e44c17c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf8f850d18e73f7281aaf3d7644448d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf8f850d18e73f7281aaf3d7644448d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf8f850d18e73f7281aaf3d7644448d7 = L.map(
#                 &quot;map_cf8f850d18e73f7281aaf3d7644448d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f31da397f34b0ab3386fd7267b733974 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f31da397f34b0ab3386fd7267b733974.addTo(map_cf8f850d18e73f7281aaf3d7644448d7);
#
#
#             var feature_group_69e336f710e442e83cbaadd4010eb395 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_69e336f710e442e83cbaadd4010eb395.addTo(map_cf8f850d18e73f7281aaf3d7644448d7);
#
#
#             var feature_group_sub_group_e5b9d281e9af32f2e75c74de686ad16d = L.featureGroup.subGroup(
#                 feature_group_69e336f710e442e83cbaadd4010eb395
#             );
#
#
#             var marker_687286800e63595c04fb6b00b46d8781 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5b9d281e9af32f2e75c74de686ad16d);
#
#
#         var popup_e282e16de1cdce1e7c92e92643d5a7d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf2e150bf110acd74083cd9218a0a445 = $(`&lt;div id=&quot;html_cf2e150bf110acd74083cd9218a0a445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e282e16de1cdce1e7c92e92643d5a7d3.setContent(html_cf2e150bf110acd74083cd9218a0a445);
#
#
#
#         marker_687286800e63595c04fb6b00b46d8781.bindPopup(popup_e282e16de1cdce1e7c92e92643d5a7d3)
#         ;
#
#
#
#
#             var marker_9fc17b5f63eee2d29fb4c3c482c8c0cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5b9d281e9af32f2e75c74de686ad16d);
#
#
#         var popup_377133dea5b7ba10d223317dd485b04b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986f83dcfaae59f05a2c4d65c501a110 = $(`&lt;div id=&quot;html_986f83dcfaae59f05a2c4d65c501a110&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_377133dea5b7ba10d223317dd485b04b.setContent(html_986f83dcfaae59f05a2c4d65c501a110);
#
#
#
#         marker_9fc17b5f63eee2d29fb4c3c482c8c0cc.bindPopup(popup_377133dea5b7ba10d223317dd485b04b)
#         ;
#
#
#
#
#             var marker_81effd6ab6814e6e54be5f912d7cd699 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5b9d281e9af32f2e75c74de686ad16d);
#
#
#         var popup_278dd136487facc7f6b76c1e6dec92e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d49c7bda2a0d16521ff1766e4aa63c7 = $(`&lt;div id=&quot;html_7d49c7bda2a0d16521ff1766e4aa63c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_278dd136487facc7f6b76c1e6dec92e9.setContent(html_7d49c7bda2a0d16521ff1766e4aa63c7);
#
#
#
#         marker_81effd6ab6814e6e54be5f912d7cd699.bindPopup(popup_278dd136487facc7f6b76c1e6dec92e9)
#         ;
#
#
#
#
#             var marker_93ad789f2f4a5741d91fddbd10a74a17 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5b9d281e9af32f2e75c74de686ad16d);
#
#
#         var popup_3b6ec5fb9099c12e03c9c9210b590bba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_600729db70fd2abf7474f5f2b1b7954c = $(`&lt;div id=&quot;html_600729db70fd2abf7474f5f2b1b7954c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3b6ec5fb9099c12e03c9c9210b590bba.setContent(html_600729db70fd2abf7474f5f2b1b7954c);
#
#
#
#         marker_
