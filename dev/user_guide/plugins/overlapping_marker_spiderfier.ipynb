# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00df8b24ec1a734ac401850c8e4aa87a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00df8b24ec1a734ac401850c8e4aa87a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00df8b24ec1a734ac401850c8e4aa87a = L.map(
#                 &quot;map_00df8b24ec1a734ac401850c8e4aa87a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14a85c156ba37e271bf446f5d594b52a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14a85c156ba37e271bf446f5d594b52a.addTo(map_00df8b24ec1a734ac401850c8e4aa87a);
#
#
#             var marker_c58c6bf49dce71ee00434727e30fe961 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_00df8b24ec1a734ac401850c8e4aa87a);
#
#
#         var popup_1b564d03a6fbd28aa86483bdd827ce95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a7ffbbabf9a6a7ce1bb817b43376c4e = $(`&lt;div id=&quot;html_5a7ffbbabf9a6a7ce1bb817b43376c4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1b564d03a6fbd28aa86483bdd827ce95.setContent(html_5a7ffbbabf9a6a7ce1bb817b43376c4e);
#
#
#
#         marker_c58c6bf49dce71ee00434727e30fe961.bindPopup(popup_1b564d03a6fbd28aa86483bdd827ce95)
#         ;
#
#
#
#
#             var marker_e7578c8ca9b0ebacc7224a2efbefa1a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_00df8b24ec1a734ac401850c8e4aa87a);
#
#
#         var popup_e4c5e8aeb72a8f7e87e1a2fdee139b7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8eecece4278407b0ebc709170c5af0ee = $(`&lt;div id=&quot;html_8eecece4278407b0ebc709170c5af0ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e4c5e8aeb72a8f7e87e1a2fdee139b7d.setContent(html_8eecece4278407b0ebc709170c5af0ee);
#
#
#
#         marker_e7578c8ca9b0ebacc7224a2efbefa1a0.bindPopup(popup_e4c5e8aeb72a8f7e87e1a2fdee139b7d)
#         ;
#
#
#
#
#             var marker_0b8a90667c260e2f1f0e4162271909b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_00df8b24ec1a734ac401850c8e4aa87a);
#
#
#         var popup_fe62d77e146686886cc53ed66ea76c13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f1213f124c2511d669cf65c94349083 = $(`&lt;div id=&quot;html_5f1213f124c2511d669cf65c94349083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fe62d77e146686886cc53ed66ea76c13.setContent(html_5f1213f124c2511d669cf65c94349083);
#
#
#
#         marker_0b8a90667c260e2f1f0e4162271909b4.bindPopup(popup_fe62d77e146686886cc53ed66ea76c13)
#         ;
#
#
#
#
#             var marker_d74b5ce6d0abc6a97c4eeee3180e9f5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_00df8b24ec1a734ac401850c8e4aa87a);
#
#
#         var popup_df4b140ba6976a2ee994d154e6b2f323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e968804b51414e8c86bab4d5fc80f3a = $(`&lt;div id=&quot;html_3e968804b51414e8c86bab4d5fc80f3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_df4b140ba6976a2ee994d154e6b2f323.setContent(html_3e968804b51414e8c86bab4d5fc80f3a);
#
#
#
#         marker_d74b5ce6d0abc6a97c4eeee3180e9f5e.bindPopup(popup_df4b140ba6976a2ee994d154e6b2f323)
#         ;
#
#
#
#
#             var marker_1aa316babad45b48cc055d9d833369c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_00df8b24ec1a734ac401850c8e4aa87a);
#
#
#         var popup_1af2c48c9d924dbaeb382eea0ef69b0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d939f12f5e5b3fa2f3e72895c6afca = $(`&lt;div id=&quot;html_89d939f12f5e5b3fa2f3e72895c6afca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1af2c48c9d924dbaeb382eea0ef69b0a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f550bbaa9bc8c681086aaf6bee1be90b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f550bbaa9bc8c681086aaf6bee1be90b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f550bbaa9bc8c681086aaf6bee1be90b = L.map(
#                 &quot;map_f550bbaa9bc8c681086aaf6bee1be90b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d30b0773322102eb64ab41e4f1fa6b03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d30b0773322102eb64ab41e4f1fa6b03.addTo(map_f550bbaa9bc8c681086aaf6bee1be90b);
#
#
#             var feature_group_4394e5a72319430187c0edda02cf59ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fff3079a7ca40d3244e1d04144efd014 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4394e5a72319430187c0edda02cf59ac);
#
#
#         var popup_9ca53bcf8256496766d92935e0666688 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e51b75c7b82ef544817f7b4b8e286fbb = $(`&lt;div id=&quot;html_e51b75c7b82ef544817f7b4b8e286fbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9ca53bcf8256496766d92935e0666688.setContent(html_e51b75c7b82ef544817f7b4b8e286fbb);
#
#
#
#         marker_fff3079a7ca40d3244e1d04144efd014.bindPopup(popup_9ca53bcf8256496766d92935e0666688)
#         ;
#
#
#
#
#             var marker_144858a135c337d9f9ad01205cd6c354 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4394e5a72319430187c0edda02cf59ac);
#
#
#         var popup_f05d0f231e0624f3dcfba5440faeede7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06896fc48286132614d606b016e3b5ce = $(`&lt;div id=&quot;html_06896fc48286132614d606b016e3b5ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f05d0f231e0624f3dcfba5440faeede7.setContent(html_06896fc48286132614d606b016e3b5ce);
#
#
#
#         marker_144858a135c337d9f9ad01205cd6c354.bindPopup(popup_f05d0f231e0624f3dcfba5440faeede7)
#         ;
#
#
#
#
#             var marker_07acb695fb0d8ee3aa28e23073c1b0c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4394e5a72319430187c0edda02cf59ac);
#
#
#         var popup_932f5f3653dd15e623a0cb9774d01181 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2609b060ef825e7fc7a39768c458d61 = $(`&lt;div id=&quot;html_b2609b060ef825e7fc7a39768c458d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_932f5f3653dd15e623a0cb9774d01181.setContent(html_b2609b060ef825e7fc7a39768c458d61);
#
#
#
#         marker_07acb695fb0d8ee3aa28e23073c1b0c2.bindPopup(popup_932f5f3653dd15e623a0cb9774d01181)
#         ;
#
#
#
#
#             var marker_b5a8c5f5f17e787d2d9022281887b579 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4394e5a72319430187c0edda02cf59ac);
#
#
#         var popup_ee1f0ce32492332c6e2213bedf7d5917 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0aa5a9d8dfb226df4afe1a8f05fb7eef = $(`&lt;div id=&quot;html_0aa5a9d8dfb226df4afe1a8f05fb7eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee1f0ce32492332c6e2213bedf7d5917.setContent(html_0aa5a9d8dfb226df4afe1a8f05fb7eef);
#
#
#
#         marker_b5a8c5f5f17e787d2d9022281887b579.bindPopup(popup_ee1f0ce32492332c6e2213bedf7d5917)
#         ;
#
#
#
#
#             var marker_248c1473de8d30d8718ceca01a71af17 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4394e5a72319430187c0edda02cf59ac);
#
#
#         var popup_b82cc844308077f67fc3c2c93fcaa99f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b3bb9d762a427e593dc8334f8afd75c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b3bb9d762a427e593dc8334f8afd75c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b3bb9d762a427e593dc8334f8afd75c = L.map(
#                 &quot;map_8b3bb9d762a427e593dc8334f8afd75c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10a96b0a0ef1ed7be12bdd5dbdae2168 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10a96b0a0ef1ed7be12bdd5dbdae2168.addTo(map_8b3bb9d762a427e593dc8334f8afd75c);
#
#
#             var feature_group_abe382395214729c081ce8cbc98b76ec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_abe382395214729c081ce8cbc98b76ec.addTo(map_8b3bb9d762a427e593dc8334f8afd75c);
#
#
#             var feature_group_sub_group_f848a6a6785f7e07d4599d752a930d11 = L.featureGroup.subGroup(
#                 feature_group_abe382395214729c081ce8cbc98b76ec
#             );
#
#
#             var marker_7a7719b77bcdbf362aaf413d6fe8d3c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f848a6a6785f7e07d4599d752a930d11);
#
#
#         var popup_217f568516ba31d20a027cf08d94004b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e9b8a364aa3da707ac26f412893cd97 = $(`&lt;div id=&quot;html_3e9b8a364aa3da707ac26f412893cd97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_217f568516ba31d20a027cf08d94004b.setContent(html_3e9b8a364aa3da707ac26f412893cd97);
#
#
#
#         marker_7a7719b77bcdbf362aaf413d6fe8d3c8.bindPopup(popup_217f568516ba31d20a027cf08d94004b)
#         ;
#
#
#
#
#             var marker_ec36f012f9170cebdf54574fbce80388 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f848a6a6785f7e07d4599d752a930d11);
#
#
#         var popup_4a90ab6a7e6bea152d6f28b4d0ff5dee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_162ba116e9804f177457338f1598cf7f = $(`&lt;div id=&quot;html_162ba116e9804f177457338f1598cf7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4a90ab6a7e6bea152d6f28b4d0ff5dee.setContent(html_162ba116e9804f177457338f1598cf7f);
#
#
#
#         marker_ec36f012f9170cebdf54574fbce80388.bindPopup(popup_4a90ab6a7e6bea152d6f28b4d0ff5dee)
#         ;
#
#
#
#
#             var marker_2395d60a72de549a6aa06f4e89f57fc5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f848a6a6785f7e07d4599d752a930d11);
#
#
#         var popup_30d405981c9637fa53c4ec9945dc943e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a06f8c27cf2ff4f37ee24c7f176671ff = $(`&lt;div id=&quot;html_a06f8c27cf2ff4f37ee24c7f176671ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_30d405981c9637fa53c4ec9945dc943e.setContent(html_a06f8c27cf2ff4f37ee24c7f176671ff);
#
#
#
#         marker_2395d60a72de549a6aa06f4e89f57fc5.bindPopup(popup_30d405981c9637fa53c4ec9945dc943e)
#         ;
#
#
#
#
#             var marker_b39a506e8e558059ca8165a1932cdfac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f848a6a6785f7e07d4599d752a930d11);
#
#
#         var popup_b94e06b8590f4c0ee00a0fc3aebae880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fc73b78394188de78140d80c9cfeae7 = $(`&lt;div id=&quot;html_4fc73b78394188de78140d80c9cfeae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b94e06b8590f4c0ee00a0fc3aebae880.setContent(html_4fc73b78394188de78140d80c9cfeae7);
#
#
#
#         marker_
