# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7144cb51875c25fcdae1597b86ad7a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7144cb51875c25fcdae1597b86ad7a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7144cb51875c25fcdae1597b86ad7a5 = L.map(
#                 &quot;map_c7144cb51875c25fcdae1597b86ad7a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95b3c9ebafb4af55243a55ea979cbcfc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95b3c9ebafb4af55243a55ea979cbcfc.addTo(map_c7144cb51875c25fcdae1597b86ad7a5);
#
#
#             var marker_94548d99a554bc48ab111ca3a42df525 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c7144cb51875c25fcdae1597b86ad7a5);
#
#
#         var popup_a2ed236e739f029322b4d8a4ab4641f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d9ebf72fd55803297103e624493f645 = $(`&lt;div id=&quot;html_2d9ebf72fd55803297103e624493f645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a2ed236e739f029322b4d8a4ab4641f4.setContent(html_2d9ebf72fd55803297103e624493f645);
#
#
#
#         marker_94548d99a554bc48ab111ca3a42df525.bindPopup(popup_a2ed236e739f029322b4d8a4ab4641f4)
#         ;
#
#
#
#
#             var marker_36a2bbbca05a766e09588f9e3c2041a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c7144cb51875c25fcdae1597b86ad7a5);
#
#
#         var popup_affafb32407ea1e01774e59ba4696e30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18a09f7ff6d5e2f64eae5436f282142d = $(`&lt;div id=&quot;html_18a09f7ff6d5e2f64eae5436f282142d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_affafb32407ea1e01774e59ba4696e30.setContent(html_18a09f7ff6d5e2f64eae5436f282142d);
#
#
#
#         marker_36a2bbbca05a766e09588f9e3c2041a0.bindPopup(popup_affafb32407ea1e01774e59ba4696e30)
#         ;
#
#
#
#
#             var marker_3245417144e632c16bf8cc3ba57aca95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c7144cb51875c25fcdae1597b86ad7a5);
#
#
#         var popup_7c2fde6de446180588203d4e3343ed0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e87ad3a14079aa8088f0be818e7e1de4 = $(`&lt;div id=&quot;html_e87ad3a14079aa8088f0be818e7e1de4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7c2fde6de446180588203d4e3343ed0d.setContent(html_e87ad3a14079aa8088f0be818e7e1de4);
#
#
#
#         marker_3245417144e632c16bf8cc3ba57aca95.bindPopup(popup_7c2fde6de446180588203d4e3343ed0d)
#         ;
#
#
#
#
#             var marker_eeed8ea67abda476fa3c4e77e85e8063 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c7144cb51875c25fcdae1597b86ad7a5);
#
#
#         var popup_72cf4830a12c6f112bf94c0832b0f50a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_413cc2746c36408fa188597c79b46517 = $(`&lt;div id=&quot;html_413cc2746c36408fa188597c79b46517&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_72cf4830a12c6f112bf94c0832b0f50a.setContent(html_413cc2746c36408fa188597c79b46517);
#
#
#
#         marker_eeed8ea67abda476fa3c4e77e85e8063.bindPopup(popup_72cf4830a12c6f112bf94c0832b0f50a)
#         ;
#
#
#
#
#             var marker_53561161e617b9cd514f6afcc47b2ff4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c7144cb51875c25fcdae1597b86ad7a5);
#
#
#         var popup_f26dde5e3cc4673ef82f0501d1b3ee9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b40600e91d77ee5eed567563e9bac19 = $(`&lt;div id=&quot;html_8b40600e91d77ee5eed567563e9bac19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f26dde5e3cc4673ef82f0501d1b3ee9e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55dcda3c5aa0698a7e21c0cb15f3cda8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55dcda3c5aa0698a7e21c0cb15f3cda8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55dcda3c5aa0698a7e21c0cb15f3cda8 = L.map(
#                 &quot;map_55dcda3c5aa0698a7e21c0cb15f3cda8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b54b694ede6ed53ca471616fc99120b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b54b694ede6ed53ca471616fc99120b.addTo(map_55dcda3c5aa0698a7e21c0cb15f3cda8);
#
#
#             var feature_group_065b2ef0e1f27583330c58c9b3bfeb4b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_50328aafcbbb32333d660f522f21e425 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_065b2ef0e1f27583330c58c9b3bfeb4b);
#
#
#         var popup_08d15513307b13f788547e98fd2eb11d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b0bd2a9afc97af9d829077a7b228f2c = $(`&lt;div id=&quot;html_9b0bd2a9afc97af9d829077a7b228f2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_08d15513307b13f788547e98fd2eb11d.setContent(html_9b0bd2a9afc97af9d829077a7b228f2c);
#
#
#
#         marker_50328aafcbbb32333d660f522f21e425.bindPopup(popup_08d15513307b13f788547e98fd2eb11d)
#         ;
#
#
#
#
#             var marker_fd7b38783f28568e7a693f641ca31964 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_065b2ef0e1f27583330c58c9b3bfeb4b);
#
#
#         var popup_d751dfb5ff9418c6f39563fcdd03e1ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93e8b4414c797789c40f1ab28649f242 = $(`&lt;div id=&quot;html_93e8b4414c797789c40f1ab28649f242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d751dfb5ff9418c6f39563fcdd03e1ed.setContent(html_93e8b4414c797789c40f1ab28649f242);
#
#
#
#         marker_fd7b38783f28568e7a693f641ca31964.bindPopup(popup_d751dfb5ff9418c6f39563fcdd03e1ed)
#         ;
#
#
#
#
#             var marker_043733e31a3586ae795759a3c3836f5d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_065b2ef0e1f27583330c58c9b3bfeb4b);
#
#
#         var popup_3088c8044cc236b4927ec7d44b29de7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9174071d0c7704bf4b29ae794898ab3b = $(`&lt;div id=&quot;html_9174071d0c7704bf4b29ae794898ab3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3088c8044cc236b4927ec7d44b29de7d.setContent(html_9174071d0c7704bf4b29ae794898ab3b);
#
#
#
#         marker_043733e31a3586ae795759a3c3836f5d.bindPopup(popup_3088c8044cc236b4927ec7d44b29de7d)
#         ;
#
#
#
#
#             var marker_7d6993401ef42766f9799dad76b803fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_065b2ef0e1f27583330c58c9b3bfeb4b);
#
#
#         var popup_2e6a3ea571f6e6fe7e906cf96ea5480a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9ecd41a58618988497f91b154e7c7b = $(`&lt;div id=&quot;html_dc9ecd41a58618988497f91b154e7c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2e6a3ea571f6e6fe7e906cf96ea5480a.setContent(html_dc9ecd41a58618988497f91b154e7c7b);
#
#
#
#         marker_7d6993401ef42766f9799dad76b803fa.bindPopup(popup_2e6a3ea571f6e6fe7e906cf96ea5480a)
#         ;
#
#
#
#
#             var marker_26dbd715091d36837b13c285e565e2dc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_065b2ef0e1f27583330c58c9b3bfeb4b);
#
#
#         var popup_3f2bd4b32ddba3e1244857596fa74157 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59462c0df859a0e24d665dc586a97f47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59462c0df859a0e24d665dc586a97f47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59462c0df859a0e24d665dc586a97f47 = L.map(
#                 &quot;map_59462c0df859a0e24d665dc586a97f47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3856a1213107e185b4169e3b5024a86b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3856a1213107e185b4169e3b5024a86b.addTo(map_59462c0df859a0e24d665dc586a97f47);
#
#
#             var feature_group_3be30b7504808058df0582979d0d68c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3be30b7504808058df0582979d0d68c7.addTo(map_59462c0df859a0e24d665dc586a97f47);
#
#
#             var feature_group_sub_group_25a8daf7147ee5bee0f31e900c3de923 = L.featureGroup.subGroup(
#                 feature_group_3be30b7504808058df0582979d0d68c7
#             );
#
#
#             var marker_d255e5f9bb8b83e1ac9a3a528976cbfa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_25a8daf7147ee5bee0f31e900c3de923);
#
#
#         var popup_dc6d71954666c7f4ef2556dce36dc9d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986c020e6b0511c8583613f66e46d21b = $(`&lt;div id=&quot;html_986c020e6b0511c8583613f66e46d21b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dc6d71954666c7f4ef2556dce36dc9d7.setContent(html_986c020e6b0511c8583613f66e46d21b);
#
#
#
#         marker_d255e5f9bb8b83e1ac9a3a528976cbfa.bindPopup(popup_dc6d71954666c7f4ef2556dce36dc9d7)
#         ;
#
#
#
#
#             var marker_060492cd5e40fa02491f361500b6e956 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_25a8daf7147ee5bee0f31e900c3de923);
#
#
#         var popup_3ae77300a67305b1980a3586493a5e22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_416f391d71a5cdcf78b2a2dcba203111 = $(`&lt;div id=&quot;html_416f391d71a5cdcf78b2a2dcba203111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3ae77300a67305b1980a3586493a5e22.setContent(html_416f391d71a5cdcf78b2a2dcba203111);
#
#
#
#         marker_060492cd5e40fa02491f361500b6e956.bindPopup(popup_3ae77300a67305b1980a3586493a5e22)
#         ;
#
#
#
#
#             var marker_09a56bbe58f79332eb2fd51243c6cad1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_25a8daf7147ee5bee0f31e900c3de923);
#
#
#         var popup_a67b357d1b654e02247d03a43e269393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_192013e7edfb95d7275fd56006620f8e = $(`&lt;div id=&quot;html_192013e7edfb95d7275fd56006620f8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a67b357d1b654e02247d03a43e269393.setContent(html_192013e7edfb95d7275fd56006620f8e);
#
#
#
#         marker_09a56bbe58f79332eb2fd51243c6cad1.bindPopup(popup_a67b357d1b654e02247d03a43e269393)
#         ;
#
#
#
#
#             var marker_3e17d06dfa8006e3cc63237f989dbffb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_25a8daf7147ee5bee0f31e900c3de923);
#
#
#         var popup_952172f6307a4f4a2c8d11f389a0e503 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af95a987e69e863327e6b8b539eb513a = $(`&lt;div id=&quot;html_af95a987e69e863327e6b8b539eb513a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_952172f6307a4f4a2c8d11f389a0e503.setContent(html_af95a987e69e863327e6b8b539eb513a);
#
#
#
#         marker_
