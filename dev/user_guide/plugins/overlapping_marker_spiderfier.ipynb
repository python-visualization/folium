# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_117c6f3c9c65ba1a773f9cc63c75c3f6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_117c6f3c9c65ba1a773f9cc63c75c3f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_117c6f3c9c65ba1a773f9cc63c75c3f6 = L.map(
#                 &quot;map_117c6f3c9c65ba1a773f9cc63c75c3f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b56f7ec6a5b35ad1cf3e74120022b83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b56f7ec6a5b35ad1cf3e74120022b83.addTo(map_117c6f3c9c65ba1a773f9cc63c75c3f6);
#
#
#             var marker_5bcbb24706b7f67e93c4bba8d16086f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_117c6f3c9c65ba1a773f9cc63c75c3f6);
#
#
#         var popup_bd6cd89260a08b8cf9fb89fa7767e8a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9b86a6e614c628be9c39545ed0065a5 = $(`&lt;div id=&quot;html_b9b86a6e614c628be9c39545ed0065a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bd6cd89260a08b8cf9fb89fa7767e8a4.setContent(html_b9b86a6e614c628be9c39545ed0065a5);
#
#
#
#         marker_5bcbb24706b7f67e93c4bba8d16086f1.bindPopup(popup_bd6cd89260a08b8cf9fb89fa7767e8a4)
#         ;
#
#
#
#
#             var marker_b4ab8e1f16fd4d37f970ddc2a11930f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_117c6f3c9c65ba1a773f9cc63c75c3f6);
#
#
#         var popup_78297a7a4bfd22c7f6db9a0cc98f9fac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f36a46b0e445307df0bda2fe9a213ab9 = $(`&lt;div id=&quot;html_f36a46b0e445307df0bda2fe9a213ab9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_78297a7a4bfd22c7f6db9a0cc98f9fac.setContent(html_f36a46b0e445307df0bda2fe9a213ab9);
#
#
#
#         marker_b4ab8e1f16fd4d37f970ddc2a11930f7.bindPopup(popup_78297a7a4bfd22c7f6db9a0cc98f9fac)
#         ;
#
#
#
#
#             var marker_5ca8a6cab60114cecb9622b21ba7bd15 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_117c6f3c9c65ba1a773f9cc63c75c3f6);
#
#
#         var popup_d2a473a6661ba46c93acd8a59a1cd14f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_396c13db42095b54852ee5a31fd500e3 = $(`&lt;div id=&quot;html_396c13db42095b54852ee5a31fd500e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d2a473a6661ba46c93acd8a59a1cd14f.setContent(html_396c13db42095b54852ee5a31fd500e3);
#
#
#
#         marker_5ca8a6cab60114cecb9622b21ba7bd15.bindPopup(popup_d2a473a6661ba46c93acd8a59a1cd14f)
#         ;
#
#
#
#
#             var marker_db9a7235709c68969cde9b7386f8486f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_117c6f3c9c65ba1a773f9cc63c75c3f6);
#
#
#         var popup_f2ac2a5c31f3ca2170adc42fcf4d7f40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de32522e7040f8680145d88f321aa6cc = $(`&lt;div id=&quot;html_de32522e7040f8680145d88f321aa6cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f2ac2a5c31f3ca2170adc42fcf4d7f40.setContent(html_de32522e7040f8680145d88f321aa6cc);
#
#
#
#         marker_db9a7235709c68969cde9b7386f8486f.bindPopup(popup_f2ac2a5c31f3ca2170adc42fcf4d7f40)
#         ;
#
#
#
#
#             var marker_c7fd9d6818f97942d6f83ded7a7037cb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_117c6f3c9c65ba1a773f9cc63c75c3f6);
#
#
#         var popup_0820087c3da522b59d049c5bdd04ce87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a7b739c321d4d1002c44742a4930d92 = $(`&lt;div id=&quot;html_7a7b739c321d4d1002c44742a4930d92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0820087c3da522b59d049c5bdd04ce87.setContent(html_7a7b739c321d4d1002c44742a4930d92);
#
#
#
#         marker_c7fd9d6818f97942d6f83ded7a7037cb.bindPopup(popup_0820087c3da522b59d049c5bdd04ce87)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_564b17df43b021b954cde73a7c961243 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_564b17df43b021b954cde73a7c961243&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_564b17df43b021b954cde73a7c961243 = L.map(
#                 &quot;map_564b17df43b021b954cde73a7c961243&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dec20e242fc1221e82cfc15f0b65b40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2dec20e242fc1221e82cfc15f0b65b40.addTo(map_564b17df43b021b954cde73a7c961243);
#
#
#             var feature_group_6545493a5d8ee3cd77fedd7c2d66f54d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d0c6827de57d0cf6d185d68ab16969cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6545493a5d8ee3cd77fedd7c2d66f54d);
#
#
#         var popup_406c5b05a255d40c35c8c061d46e3e8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5348f2ed1f4d401b208ea52d4566e158 = $(`&lt;div id=&quot;html_5348f2ed1f4d401b208ea52d4566e158&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_406c5b05a255d40c35c8c061d46e3e8a.setContent(html_5348f2ed1f4d401b208ea52d4566e158);
#
#
#
#         marker_d0c6827de57d0cf6d185d68ab16969cd.bindPopup(popup_406c5b05a255d40c35c8c061d46e3e8a)
#         ;
#
#
#
#
#             var marker_ef219b515728fd763b66a8d45cac356b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6545493a5d8ee3cd77fedd7c2d66f54d);
#
#
#         var popup_320c7a899496e865f32d8d64da560f4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f8ace3b35ed34f3b8927fb709f63620 = $(`&lt;div id=&quot;html_4f8ace3b35ed34f3b8927fb709f63620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_320c7a899496e865f32d8d64da560f4b.setContent(html_4f8ace3b35ed34f3b8927fb709f63620);
#
#
#
#         marker_ef219b515728fd763b66a8d45cac356b.bindPopup(popup_320c7a899496e865f32d8d64da560f4b)
#         ;
#
#
#
#
#             var marker_c33ae707e3db7c739cf6b7667622cca9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6545493a5d8ee3cd77fedd7c2d66f54d);
#
#
#         var popup_c6a8ec96769f1f322f08e3fb60c26438 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b42308d0079c1cfd2b0e95d5918e101 = $(`&lt;div id=&quot;html_8b42308d0079c1cfd2b0e95d5918e101&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c6a8ec96769f1f322f08e3fb60c26438.setContent(html_8b42308d0079c1cfd2b0e95d5918e101);
#
#
#
#         marker_c33ae707e3db7c739cf6b7667622cca9.bindPopup(popup_c6a8ec96769f1f322f08e3fb60c26438)
#         ;
#
#
#
#
#             var marker_3f6608f6e7560da110d9e79bab6cd838 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6545493a5d8ee3cd77fedd7c2d66f54d);
#
#
#         var popup_415b4d85791dcd98c1a66daa1aa7bdfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2ee2994d4236cc6728f8d75154d8cfe = $(`&lt;div id=&quot;html_b2ee2994d4236cc6728f8d75154d8cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_415b4d85791dcd98c1a66daa1aa7bdfc.setContent(html_b2ee2994d4236cc6728f8d75154d8cfe);
#
#
#
#         marker_3f6608f6e7560da110d9e79bab6cd838.bindPopup(popup_415b4d85791dcd98c1a66daa1aa7bdfc)
#         ;
#
#
#
#
#             var marker_738432337999b982b0b083a388aa4676 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6545493a5d8ee3cd77fedd7c2d66f54d);
#
#
#         var popup_c7f4659492e1d2d930c79b004cff2bce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7846b0400c4df24911156f84b7b10b5e = $(`&lt;div id=&quot;html_7846b0400c4df24911156f84b7b10b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc6df0aaa7b6fbe1e1c995aa2062b97b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc6df0aaa7b6fbe1e1c995aa2062b97b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc6df0aaa7b6fbe1e1c995aa2062b97b = L.map(
#                 &quot;map_cc6df0aaa7b6fbe1e1c995aa2062b97b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3b746aa51ccd4b22c611d406c3e2518 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a3b746aa51ccd4b22c611d406c3e2518.addTo(map_cc6df0aaa7b6fbe1e1c995aa2062b97b);
#
#
#             var feature_group_8a86f2f3278f55c022caacdfc5c00a58 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8a86f2f3278f55c022caacdfc5c00a58.addTo(map_cc6df0aaa7b6fbe1e1c995aa2062b97b);
#
#
#             var feature_group_sub_group_93b3599134603be7aeadbdcedc22ac68 = L.featureGroup.subGroup(
#                 feature_group_8a86f2f3278f55c022caacdfc5c00a58
#             );
#
#
#             var marker_36b9bb3a72e689281054a1d0c066cc16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_93b3599134603be7aeadbdcedc22ac68);
#
#
#         var popup_1c4af779b85c1a3a54bc021e0bcf08eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4952638e987af51300dd7744e6ba6e6f = $(`&lt;div id=&quot;html_4952638e987af51300dd7744e6ba6e6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1c4af779b85c1a3a54bc021e0bcf08eb.setContent(html_4952638e987af51300dd7744e6ba6e6f);
#
#
#
#         marker_36b9bb3a72e689281054a1d0c066cc16.bindPopup(popup_1c4af779b85c1a3a54bc021e0bcf08eb)
#         ;
#
#
#
#
#             var marker_165b800360003bf5d4014899e11736c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_93b3599134603be7aeadbdcedc22ac68);
#
#
#         var popup_ab949815d7c43dd812793f4d103b56a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a30e458bd8b97fa7d4faf04ef7267fa = $(`&lt;div id=&quot;html_5a30e458bd8b97fa7d4faf04ef7267fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ab949815d7c43dd812793f4d103b56a8.setContent(html_5a30e458bd8b97fa7d4faf04ef7267fa);
#
#
#
#         marker_165b800360003bf5d4014899e11736c2.bindPopup(popup_ab949815d7c43dd812793f4d103b56a8)
#         ;
#
#
#
#
#             var marker_c68da1b1eb135589a04818bd19133221 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_93b3599134603be7aeadbdcedc22ac68);
#
#
#         var popup_8464273dc8ddd686d273fbf042e60442 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a110abc35737d3cea35db03cd1a2af86 = $(`&lt;div id=&quot;html_a110abc35737d3cea35db03cd1a2af86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8464273dc8ddd686d273fbf042e60442.setContent(html_a110abc35737d3cea35db03cd1a2af86);
#
#
#
#         marker_c68da1b1eb135589a04818bd19133221.bindPopup(popup_8464273dc8ddd686d273fbf042e60442)
#         ;
#
#
#
#
#             var marker_596ab15c735f0675c1ac10f3b4b99a82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_93b3599134603be7aeadbdcedc22ac68);
#
#
#         var popup_3e7afc0875d59aa4a1bef8dcf50da914 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1066a8dd2ad6cf7d132f14f6d789b49d = $(`&lt;div id=&quot;html_1066a8dd2ad6cf7d132f14f6d789b49d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3e7afc0875d59aa4a1bef8dcf50da914.setContent(html_1066a8dd2ad6cf7d132f14f6d789b49d);
#
#
#
#         marker_596ab15c735f0675c1ac10f3b4b99a82.bindPopup(popup_3e7afc0875d59aa4a1bef8dcf50da914)
#         ;
#
#
#
#
#             var marker_82c54d4d3ded01ba1f6351b4abc89d5c = L.marker(
#                 [45.0503999
