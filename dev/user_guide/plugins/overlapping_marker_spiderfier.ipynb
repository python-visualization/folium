# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8924a5e1bb1b487c94dc9e3cf82ef85f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8924a5e1bb1b487c94dc9e3cf82ef85f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8924a5e1bb1b487c94dc9e3cf82ef85f = L.map(
#                 &quot;map_8924a5e1bb1b487c94dc9e3cf82ef85f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15e98772b792f257e8349e9ea43c1699 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15e98772b792f257e8349e9ea43c1699.addTo(map_8924a5e1bb1b487c94dc9e3cf82ef85f);
#
#
#             var marker_aa20e78e817fedf8fced4bae981cc34b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8924a5e1bb1b487c94dc9e3cf82ef85f);
#
#
#         var popup_6f6bc7a6d32cfa7b524950babfcf6857 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60a769fa1fb0694c04078d8051e7cf92 = $(`&lt;div id=&quot;html_60a769fa1fb0694c04078d8051e7cf92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6f6bc7a6d32cfa7b524950babfcf6857.setContent(html_60a769fa1fb0694c04078d8051e7cf92);
#
#
#
#         marker_aa20e78e817fedf8fced4bae981cc34b.bindPopup(popup_6f6bc7a6d32cfa7b524950babfcf6857)
#         ;
#
#
#
#
#             var marker_87248dc90dc83ca4d00980a89be3579f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8924a5e1bb1b487c94dc9e3cf82ef85f);
#
#
#         var popup_16a07750a6e2613379be821d6369202e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02c89b48c53ca902753cb957b33c3506 = $(`&lt;div id=&quot;html_02c89b48c53ca902753cb957b33c3506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_16a07750a6e2613379be821d6369202e.setContent(html_02c89b48c53ca902753cb957b33c3506);
#
#
#
#         marker_87248dc90dc83ca4d00980a89be3579f.bindPopup(popup_16a07750a6e2613379be821d6369202e)
#         ;
#
#
#
#
#             var marker_d029385e0951896837a4c70e147e1f89 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8924a5e1bb1b487c94dc9e3cf82ef85f);
#
#
#         var popup_2552d550d5b19730f9af22a4090b1bb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f1aba42f0c49e0be4ab975b7a9d75e4 = $(`&lt;div id=&quot;html_2f1aba42f0c49e0be4ab975b7a9d75e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2552d550d5b19730f9af22a4090b1bb3.setContent(html_2f1aba42f0c49e0be4ab975b7a9d75e4);
#
#
#
#         marker_d029385e0951896837a4c70e147e1f89.bindPopup(popup_2552d550d5b19730f9af22a4090b1bb3)
#         ;
#
#
#
#
#             var marker_b97f505665d2b990e38c6de32a5d425a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8924a5e1bb1b487c94dc9e3cf82ef85f);
#
#
#         var popup_0a6604530bfc602a577b3578314abfe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3d77545ee0b13fb7d5e2e7abfc03ddd = $(`&lt;div id=&quot;html_e3d77545ee0b13fb7d5e2e7abfc03ddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0a6604530bfc602a577b3578314abfe8.setContent(html_e3d77545ee0b13fb7d5e2e7abfc03ddd);
#
#
#
#         marker_b97f505665d2b990e38c6de32a5d425a.bindPopup(popup_0a6604530bfc602a577b3578314abfe8)
#         ;
#
#
#
#
#             var marker_7ca6bd0be519cf469045317bb79b7cf5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8924a5e1bb1b487c94dc9e3cf82ef85f);
#
#
#         var popup_e7a82e99860220156b43552552354364 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e091fe68b9134d38019dbd64b32e935 = $(`&lt;div id=&quot;html_8e091fe68b9134d38019dbd64b32e935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e7a82e99860220156b43552552354364.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_447f3de14d1a61f7dbe53d3115d783a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_447f3de14d1a61f7dbe53d3115d783a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_447f3de14d1a61f7dbe53d3115d783a5 = L.map(
#                 &quot;map_447f3de14d1a61f7dbe53d3115d783a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2f725b3866d146748c20adad7656a95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2f725b3866d146748c20adad7656a95.addTo(map_447f3de14d1a61f7dbe53d3115d783a5);
#
#
#             var feature_group_6dce3f5d464bfc44e206083984bea60e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_851df7b49ddd2ea1c4a10bdc0c19fe26 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6dce3f5d464bfc44e206083984bea60e);
#
#
#         var popup_0a62a7a8f508fcba3f0e272408dc1f27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_babcae9d422c524c70be74fde013bbbe = $(`&lt;div id=&quot;html_babcae9d422c524c70be74fde013bbbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0a62a7a8f508fcba3f0e272408dc1f27.setContent(html_babcae9d422c524c70be74fde013bbbe);
#
#
#
#         marker_851df7b49ddd2ea1c4a10bdc0c19fe26.bindPopup(popup_0a62a7a8f508fcba3f0e272408dc1f27)
#         ;
#
#
#
#
#             var marker_33dedbe85297bf8cf8e0825ddebe193c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6dce3f5d464bfc44e206083984bea60e);
#
#
#         var popup_f7d91fa1aee8e0dcc40af085119ab7b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb352b2be6ecbff299d27180b0adee04 = $(`&lt;div id=&quot;html_cb352b2be6ecbff299d27180b0adee04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f7d91fa1aee8e0dcc40af085119ab7b7.setContent(html_cb352b2be6ecbff299d27180b0adee04);
#
#
#
#         marker_33dedbe85297bf8cf8e0825ddebe193c.bindPopup(popup_f7d91fa1aee8e0dcc40af085119ab7b7)
#         ;
#
#
#
#
#             var marker_66e7a77a463a620c934d9de08460893a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6dce3f5d464bfc44e206083984bea60e);
#
#
#         var popup_fa6478a895ca857fbfc81be318e3d460 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91acdd8f55bd1430350c3d84db323c26 = $(`&lt;div id=&quot;html_91acdd8f55bd1430350c3d84db323c26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fa6478a895ca857fbfc81be318e3d460.setContent(html_91acdd8f55bd1430350c3d84db323c26);
#
#
#
#         marker_66e7a77a463a620c934d9de08460893a.bindPopup(popup_fa6478a895ca857fbfc81be318e3d460)
#         ;
#
#
#
#
#             var marker_d8575c9eb007213b40d075fdf257c6e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6dce3f5d464bfc44e206083984bea60e);
#
#
#         var popup_0ed02495a68256ec97bd2da1d987ee4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fa989737bfc6ba28ccacaa3357ff2fc = $(`&lt;div id=&quot;html_2fa989737bfc6ba28ccacaa3357ff2fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0ed02495a68256ec97bd2da1d987ee4c.setContent(html_2fa989737bfc6ba28ccacaa3357ff2fc);
#
#
#
#         marker_d8575c9eb007213b40d075fdf257c6e2.bindPopup(popup_0ed02495a68256ec97bd2da1d987ee4c)
#         ;
#
#
#
#
#             var marker_f142914706208d09afddb3308c2a0784 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6dce3f5d464bfc44e206083984bea60e);
#
#
#         var popup_74d21c909ba9978e9c9cdb57728578a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed00b13771e41177d5792785f6401b06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed00b13771e41177d5792785f6401b06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed00b13771e41177d5792785f6401b06 = L.map(
#                 &quot;map_ed00b13771e41177d5792785f6401b06&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcbf4dfcec916d6970104677ff2154f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcbf4dfcec916d6970104677ff2154f2.addTo(map_ed00b13771e41177d5792785f6401b06);
#
#
#             var feature_group_5540ef51a486efa7cf05680cf7614552 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5540ef51a486efa7cf05680cf7614552.addTo(map_ed00b13771e41177d5792785f6401b06);
#
#
#             var feature_group_sub_group_aa2d0ae7761d1ead48758349b6215ce9 = L.featureGroup.subGroup(
#                 feature_group_5540ef51a486efa7cf05680cf7614552
#             );
#
#
#             var marker_a66ab59f5aeb8aa592174e6fdf4f0d7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa2d0ae7761d1ead48758349b6215ce9);
#
#
#         var popup_c42ef2567e6d5b2515e141373e298705 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b65c308e3040b6a7e3c49a945c02e3cd = $(`&lt;div id=&quot;html_b65c308e3040b6a7e3c49a945c02e3cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c42ef2567e6d5b2515e141373e298705.setContent(html_b65c308e3040b6a7e3c49a945c02e3cd);
#
#
#
#         marker_a66ab59f5aeb8aa592174e6fdf4f0d7e.bindPopup(popup_c42ef2567e6d5b2515e141373e298705)
#         ;
#
#
#
#
#             var marker_cf7f8270a400ef8489fa41f1a8934810 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa2d0ae7761d1ead48758349b6215ce9);
#
#
#         var popup_9ac5918996ed94ecbd5de459389f9a67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a61c60d0e09bc175d1a28b165d4283a9 = $(`&lt;div id=&quot;html_a61c60d0e09bc175d1a28b165d4283a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9ac5918996ed94ecbd5de459389f9a67.setContent(html_a61c60d0e09bc175d1a28b165d4283a9);
#
#
#
#         marker_cf7f8270a400ef8489fa41f1a8934810.bindPopup(popup_9ac5918996ed94ecbd5de459389f9a67)
#         ;
#
#
#
#
#             var marker_e37bfee21eea493ac35360f93ce78fca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa2d0ae7761d1ead48758349b6215ce9);
#
#
#         var popup_f5579d6ead9aaf3fc772000b0e45d03a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e045861e9900f2cb23f2238535aab51a = $(`&lt;div id=&quot;html_e045861e9900f2cb23f2238535aab51a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f5579d6ead9aaf3fc772000b0e45d03a.setContent(html_e045861e9900f2cb23f2238535aab51a);
#
#
#
#         marker_e37bfee21eea493ac35360f93ce78fca.bindPopup(popup_f5579d6ead9aaf3fc772000b0e45d03a)
#         ;
#
#
#
#
#             var marker_9e110730eb733f639657ab6f95890489 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa2d0ae7761d1ead48758349b6215ce9);
#
#
#         var popup_a1d12bda5e1690bd40929cd22fc42e42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ce64b0a3c7313ce0d588287b00a89ad = $(`&lt;div id=&quot;html_2ce64b0a3c7313ce0d588287b00a89ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a1d12bda5e1690bd40929cd22fc42e42.setContent(html_2ce64b0a3c7313ce0d588287b00a89ad);
#
#
#
#         marker_
