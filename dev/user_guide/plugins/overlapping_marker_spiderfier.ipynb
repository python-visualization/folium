# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19d3d5e0e7829f5d67b34b23f58d0079 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19d3d5e0e7829f5d67b34b23f58d0079&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19d3d5e0e7829f5d67b34b23f58d0079 = L.map(
#                 &quot;map_19d3d5e0e7829f5d67b34b23f58d0079&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a3a287e321aa3631fe5eac7fbb9079d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a3a287e321aa3631fe5eac7fbb9079d.addTo(map_19d3d5e0e7829f5d67b34b23f58d0079);
#
#
#             var marker_e2f22ef0966a24a1bb2a754d904203b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_19d3d5e0e7829f5d67b34b23f58d0079);
#
#
#         var popup_06ad4fbc2918992998938c74f4a7abcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39345ed0a0e82d980e01d1d48fdb0ea9 = $(`&lt;div id=&quot;html_39345ed0a0e82d980e01d1d48fdb0ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_06ad4fbc2918992998938c74f4a7abcf.setContent(html_39345ed0a0e82d980e01d1d48fdb0ea9);
#
#
#
#         marker_e2f22ef0966a24a1bb2a754d904203b4.bindPopup(popup_06ad4fbc2918992998938c74f4a7abcf)
#         ;
#
#
#
#
#             var marker_3550e3a37be08cfda3e19962e1847395 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_19d3d5e0e7829f5d67b34b23f58d0079);
#
#
#         var popup_d273ce4122e205452c67c9d41a5def29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f69ba250ea5899d6aee9dd00f808177 = $(`&lt;div id=&quot;html_1f69ba250ea5899d6aee9dd00f808177&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d273ce4122e205452c67c9d41a5def29.setContent(html_1f69ba250ea5899d6aee9dd00f808177);
#
#
#
#         marker_3550e3a37be08cfda3e19962e1847395.bindPopup(popup_d273ce4122e205452c67c9d41a5def29)
#         ;
#
#
#
#
#             var marker_86834d4ee386be93184cc1132a07171e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_19d3d5e0e7829f5d67b34b23f58d0079);
#
#
#         var popup_e85e55140e88112144aa17c4cb0fdff9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e049683bfc546781de8161f9c1d55a1c = $(`&lt;div id=&quot;html_e049683bfc546781de8161f9c1d55a1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e85e55140e88112144aa17c4cb0fdff9.setContent(html_e049683bfc546781de8161f9c1d55a1c);
#
#
#
#         marker_86834d4ee386be93184cc1132a07171e.bindPopup(popup_e85e55140e88112144aa17c4cb0fdff9)
#         ;
#
#
#
#
#             var marker_8031b41f31ade2ed2784b5af8be121d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_19d3d5e0e7829f5d67b34b23f58d0079);
#
#
#         var popup_32d6f3ee6733317bcde7cdf4aaf57dbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5783fc4d3c28b0ba5682c5fa64e69400 = $(`&lt;div id=&quot;html_5783fc4d3c28b0ba5682c5fa64e69400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_32d6f3ee6733317bcde7cdf4aaf57dbd.setContent(html_5783fc4d3c28b0ba5682c5fa64e69400);
#
#
#
#         marker_8031b41f31ade2ed2784b5af8be121d7.bindPopup(popup_32d6f3ee6733317bcde7cdf4aaf57dbd)
#         ;
#
#
#
#
#             var marker_5e028fad4b601dea4b4327d2c778d916 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_19d3d5e0e7829f5d67b34b23f58d0079);
#
#
#         var popup_a32bc57ab2a1ef5a8298b62823a45f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a192e89e559d091bd7026874ac996193 = $(`&lt;div id=&quot;html_a192e89e559d091bd7026874ac996193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a32bc57ab2a1ef5a8298b62823a45f8b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a4e10ad906d8ca4386d9806566e0756 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a4e10ad906d8ca4386d9806566e0756&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a4e10ad906d8ca4386d9806566e0756 = L.map(
#                 &quot;map_9a4e10ad906d8ca4386d9806566e0756&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de6d55ea5726e21d5d580fdda8a3d390 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de6d55ea5726e21d5d580fdda8a3d390.addTo(map_9a4e10ad906d8ca4386d9806566e0756);
#
#
#             var feature_group_4a510c1898a13b07f5cd66e0caaeb4fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_990ff781e9658079570aa14f7328f54f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4a510c1898a13b07f5cd66e0caaeb4fe);
#
#
#         var popup_ee22fb40c5d7ea699e8d54ae431cfdbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d46dc94f5ef5d29dbb62cc9375e28779 = $(`&lt;div id=&quot;html_d46dc94f5ef5d29dbb62cc9375e28779&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ee22fb40c5d7ea699e8d54ae431cfdbb.setContent(html_d46dc94f5ef5d29dbb62cc9375e28779);
#
#
#
#         marker_990ff781e9658079570aa14f7328f54f.bindPopup(popup_ee22fb40c5d7ea699e8d54ae431cfdbb)
#         ;
#
#
#
#
#             var marker_5c63225f572f93a61f4b0844e36661f8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4a510c1898a13b07f5cd66e0caaeb4fe);
#
#
#         var popup_102dd2aef13e94d59b10a777587283d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ed09c7d06e16731612cb3a9a8db1a0b = $(`&lt;div id=&quot;html_3ed09c7d06e16731612cb3a9a8db1a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_102dd2aef13e94d59b10a777587283d6.setContent(html_3ed09c7d06e16731612cb3a9a8db1a0b);
#
#
#
#         marker_5c63225f572f93a61f4b0844e36661f8.bindPopup(popup_102dd2aef13e94d59b10a777587283d6)
#         ;
#
#
#
#
#             var marker_21340fdf6de368ced8a4d48269498cf2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4a510c1898a13b07f5cd66e0caaeb4fe);
#
#
#         var popup_beca8c02927efbb971f88d88bac2418f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c673ceabfb6f1abfdf1536e4fb898c1 = $(`&lt;div id=&quot;html_5c673ceabfb6f1abfdf1536e4fb898c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_beca8c02927efbb971f88d88bac2418f.setContent(html_5c673ceabfb6f1abfdf1536e4fb898c1);
#
#
#
#         marker_21340fdf6de368ced8a4d48269498cf2.bindPopup(popup_beca8c02927efbb971f88d88bac2418f)
#         ;
#
#
#
#
#             var marker_9d668c5cd9a0dc5632e89e1057932935 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4a510c1898a13b07f5cd66e0caaeb4fe);
#
#
#         var popup_c8529715b926ce1a2e090545acb801a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69f33717663520d0a5f427f367906308 = $(`&lt;div id=&quot;html_69f33717663520d0a5f427f367906308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c8529715b926ce1a2e090545acb801a5.setContent(html_69f33717663520d0a5f427f367906308);
#
#
#
#         marker_9d668c5cd9a0dc5632e89e1057932935.bindPopup(popup_c8529715b926ce1a2e090545acb801a5)
#         ;
#
#
#
#
#             var marker_acb3ccdb9193840eac3f4177b13da2e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4a510c1898a13b07f5cd66e0caaeb4fe);
#
#
#         var popup_5d0a2a9d7a398816780b5719600effff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6298f42e297ee08b41f8e4883b6583f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6298f42e297ee08b41f8e4883b6583f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6298f42e297ee08b41f8e4883b6583f4 = L.map(
#                 &quot;map_6298f42e297ee08b41f8e4883b6583f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5a5dc0d45671352839dbf983277eb75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5a5dc0d45671352839dbf983277eb75.addTo(map_6298f42e297ee08b41f8e4883b6583f4);
#
#
#             var feature_group_d20225297786e3a82c561bbdfa6a1a0e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d20225297786e3a82c561bbdfa6a1a0e.addTo(map_6298f42e297ee08b41f8e4883b6583f4);
#
#
#             var feature_group_sub_group_5b2ba07056d03480c5f9231bc84eb841 = L.featureGroup.subGroup(
#                 feature_group_d20225297786e3a82c561bbdfa6a1a0e
#             );
#
#
#             var marker_f6a8136b9cbcecfee4ef66114d6c1277 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2ba07056d03480c5f9231bc84eb841);
#
#
#         var popup_a44230507854a9476c394d48ddbcce1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97080d8b79ef1d3938b47fd8bf7934cd = $(`&lt;div id=&quot;html_97080d8b79ef1d3938b47fd8bf7934cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a44230507854a9476c394d48ddbcce1d.setContent(html_97080d8b79ef1d3938b47fd8bf7934cd);
#
#
#
#         marker_f6a8136b9cbcecfee4ef66114d6c1277.bindPopup(popup_a44230507854a9476c394d48ddbcce1d)
#         ;
#
#
#
#
#             var marker_e2c11080dc1a7c4bef4af09291444a7d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2ba07056d03480c5f9231bc84eb841);
#
#
#         var popup_e125f79cf8131758676bbbce30838335 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f61e182e8a874eb0e504670ca6f7994d = $(`&lt;div id=&quot;html_f61e182e8a874eb0e504670ca6f7994d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e125f79cf8131758676bbbce30838335.setContent(html_f61e182e8a874eb0e504670ca6f7994d);
#
#
#
#         marker_e2c11080dc1a7c4bef4af09291444a7d.bindPopup(popup_e125f79cf8131758676bbbce30838335)
#         ;
#
#
#
#
#             var marker_dfc5666a657d19f195266c920877417e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2ba07056d03480c5f9231bc84eb841);
#
#
#         var popup_5d1ad8622588a31fb532c0006b508764 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92c72f66403ec2b49f8f93e44f9c0817 = $(`&lt;div id=&quot;html_92c72f66403ec2b49f8f93e44f9c0817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5d1ad8622588a31fb532c0006b508764.setContent(html_92c72f66403ec2b49f8f93e44f9c0817);
#
#
#
#         marker_dfc5666a657d19f195266c920877417e.bindPopup(popup_5d1ad8622588a31fb532c0006b508764)
#         ;
#
#
#
#
#             var marker_681c465a00e3ac25e37a1cfded9296b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2ba07056d03480c5f9231bc84eb841);
#
#
#         var popup_f5a3a1f608f9049a134fb4e624cbffca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db192d729f3b9aec1fdb55c0f13fdabe = $(`&lt;div id=&quot;html_db192d729f3b9aec1fdb55c0f13fdabe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f5a3a1f608f9049a134fb4e624cbffca.setContent(html_db192d729f3b9aec1fdb55c0f13fdabe);
#
#
#
#         marker_
