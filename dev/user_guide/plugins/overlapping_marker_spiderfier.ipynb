# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b415b74f79b32a76c236e7688b941f3e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b415b74f79b32a76c236e7688b941f3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b415b74f79b32a76c236e7688b941f3e = L.map(
#                 &quot;map_b415b74f79b32a76c236e7688b941f3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09fc8ac3973d719103a553fbae8f51b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09fc8ac3973d719103a553fbae8f51b1.addTo(map_b415b74f79b32a76c236e7688b941f3e);
#
#
#             var marker_7aa86289b6cd863b956339f9314cf43f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b415b74f79b32a76c236e7688b941f3e);
#
#
#         var popup_88e7fca7682b35141b57ca0d749f53bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80114d15d795ee080b7f212e832c92d7 = $(`&lt;div id=&quot;html_80114d15d795ee080b7f212e832c92d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_88e7fca7682b35141b57ca0d749f53bd.setContent(html_80114d15d795ee080b7f212e832c92d7);
#
#
#
#         marker_7aa86289b6cd863b956339f9314cf43f.bindPopup(popup_88e7fca7682b35141b57ca0d749f53bd)
#         ;
#
#
#
#
#             var marker_7cbc693f124a418bc28b3b4b170ed8bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b415b74f79b32a76c236e7688b941f3e);
#
#
#         var popup_2212e9dd4f380de0678d541f99946b72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee3fc527447d09c66c0cbec2cd42a7c = $(`&lt;div id=&quot;html_cee3fc527447d09c66c0cbec2cd42a7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2212e9dd4f380de0678d541f99946b72.setContent(html_cee3fc527447d09c66c0cbec2cd42a7c);
#
#
#
#         marker_7cbc693f124a418bc28b3b4b170ed8bb.bindPopup(popup_2212e9dd4f380de0678d541f99946b72)
#         ;
#
#
#
#
#             var marker_bc3927b56f688aedb742b53b9e27df76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b415b74f79b32a76c236e7688b941f3e);
#
#
#         var popup_6aa953831f8c33f0123e433372d2d4d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afae3d0b5e59e7748013cedb08d2ad65 = $(`&lt;div id=&quot;html_afae3d0b5e59e7748013cedb08d2ad65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6aa953831f8c33f0123e433372d2d4d1.setContent(html_afae3d0b5e59e7748013cedb08d2ad65);
#
#
#
#         marker_bc3927b56f688aedb742b53b9e27df76.bindPopup(popup_6aa953831f8c33f0123e433372d2d4d1)
#         ;
#
#
#
#
#             var marker_8d2920ce5cfe236f9e509363d4f5342b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b415b74f79b32a76c236e7688b941f3e);
#
#
#         var popup_8e655d4f0a84e259d1e92bd9c113e222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c18bd5a6eef57b88a5477e5912b41429 = $(`&lt;div id=&quot;html_c18bd5a6eef57b88a5477e5912b41429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8e655d4f0a84e259d1e92bd9c113e222.setContent(html_c18bd5a6eef57b88a5477e5912b41429);
#
#
#
#         marker_8d2920ce5cfe236f9e509363d4f5342b.bindPopup(popup_8e655d4f0a84e259d1e92bd9c113e222)
#         ;
#
#
#
#
#             var marker_64eab2732ddc52d8311a02590809f9fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b415b74f79b32a76c236e7688b941f3e);
#
#
#         var popup_51207f54b659a31e7a28126e3f6f9e18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e4fbd085b4f452dbd6272031344e11 = $(`&lt;div id=&quot;html_04e4fbd085b4f452dbd6272031344e11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_51207f54b659a31e7a28126e3f6f9e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4021ad95e07dd59917dac35f80529ed2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4021ad95e07dd59917dac35f80529ed2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4021ad95e07dd59917dac35f80529ed2 = L.map(
#                 &quot;map_4021ad95e07dd59917dac35f80529ed2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee8eb18ff62eeb5cb49eaf8f5539b99d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee8eb18ff62eeb5cb49eaf8f5539b99d.addTo(map_4021ad95e07dd59917dac35f80529ed2);
#
#
#             var feature_group_18ea26bf1e78516c5f1490d4913734c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a0626feaf18fb5b8ba9fbfe47cd9f6ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_18ea26bf1e78516c5f1490d4913734c6);
#
#
#         var popup_8e7f33132dc1a4824402e90b09fc3259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d91f49d52a6fc8b9728d3cd79497d4e9 = $(`&lt;div id=&quot;html_d91f49d52a6fc8b9728d3cd79497d4e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8e7f33132dc1a4824402e90b09fc3259.setContent(html_d91f49d52a6fc8b9728d3cd79497d4e9);
#
#
#
#         marker_a0626feaf18fb5b8ba9fbfe47cd9f6ea.bindPopup(popup_8e7f33132dc1a4824402e90b09fc3259)
#         ;
#
#
#
#
#             var marker_881ce82e05ef720e9f6fde1ac41962d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_18ea26bf1e78516c5f1490d4913734c6);
#
#
#         var popup_762ace4e8bd6d8cb8556e4bc4040c79d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d62c783f00b689d462e879d7648694b8 = $(`&lt;div id=&quot;html_d62c783f00b689d462e879d7648694b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_762ace4e8bd6d8cb8556e4bc4040c79d.setContent(html_d62c783f00b689d462e879d7648694b8);
#
#
#
#         marker_881ce82e05ef720e9f6fde1ac41962d5.bindPopup(popup_762ace4e8bd6d8cb8556e4bc4040c79d)
#         ;
#
#
#
#
#             var marker_fc5018e4db336e76989f2056276bdc42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_18ea26bf1e78516c5f1490d4913734c6);
#
#
#         var popup_349d38853645b24ee270f18627a255af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67653e97deaf7f426c06432ad1732fb4 = $(`&lt;div id=&quot;html_67653e97deaf7f426c06432ad1732fb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_349d38853645b24ee270f18627a255af.setContent(html_67653e97deaf7f426c06432ad1732fb4);
#
#
#
#         marker_fc5018e4db336e76989f2056276bdc42.bindPopup(popup_349d38853645b24ee270f18627a255af)
#         ;
#
#
#
#
#             var marker_7052763517bb01c522360d52c5ad5671 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_18ea26bf1e78516c5f1490d4913734c6);
#
#
#         var popup_4626badc828d7a516584ff52aa6f121b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87d3217d8b0a25945762addd1f9d492b = $(`&lt;div id=&quot;html_87d3217d8b0a25945762addd1f9d492b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4626badc828d7a516584ff52aa6f121b.setContent(html_87d3217d8b0a25945762addd1f9d492b);
#
#
#
#         marker_7052763517bb01c522360d52c5ad5671.bindPopup(popup_4626badc828d7a516584ff52aa6f121b)
#         ;
#
#
#
#
#             var marker_3c53a4865b81897b484139843ec9b082 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_18ea26bf1e78516c5f1490d4913734c6);
#
#
#         var popup_adfbe624ec4e15ea07f3297bfa359d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06d76a740486ba785733c4db736c8a83 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06d76a740486ba785733c4db736c8a83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06d76a740486ba785733c4db736c8a83 = L.map(
#                 &quot;map_06d76a740486ba785733c4db736c8a83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39bf2091f4c944a8a5f9f019e54fc038 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39bf2091f4c944a8a5f9f019e54fc038.addTo(map_06d76a740486ba785733c4db736c8a83);
#
#
#             var feature_group_63a786cee708072e7f2e85f5de5dc340 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_63a786cee708072e7f2e85f5de5dc340.addTo(map_06d76a740486ba785733c4db736c8a83);
#
#
#             var feature_group_sub_group_03c58415c4c40beda61c561716dd35cd = L.featureGroup.subGroup(
#                 feature_group_63a786cee708072e7f2e85f5de5dc340
#             );
#
#
#             var marker_09747fce4cb7d86e37719d2b02171812 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_03c58415c4c40beda61c561716dd35cd);
#
#
#         var popup_271603bfb657747519f16cc82118dbcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3beb5c34f95863b86158c4f81b3c4096 = $(`&lt;div id=&quot;html_3beb5c34f95863b86158c4f81b3c4096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_271603bfb657747519f16cc82118dbcf.setContent(html_3beb5c34f95863b86158c4f81b3c4096);
#
#
#
#         marker_09747fce4cb7d86e37719d2b02171812.bindPopup(popup_271603bfb657747519f16cc82118dbcf)
#         ;
#
#
#
#
#             var marker_8f2766819138183aa988729d0645a77b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_03c58415c4c40beda61c561716dd35cd);
#
#
#         var popup_7962e24b343e54be403ccd5842a7fb8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c5d35cf8d5346234802398fa5b8aa51 = $(`&lt;div id=&quot;html_0c5d35cf8d5346234802398fa5b8aa51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7962e24b343e54be403ccd5842a7fb8e.setContent(html_0c5d35cf8d5346234802398fa5b8aa51);
#
#
#
#         marker_8f2766819138183aa988729d0645a77b.bindPopup(popup_7962e24b343e54be403ccd5842a7fb8e)
#         ;
#
#
#
#
#             var marker_846ea236092f5ba73123be78a852c5c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_03c58415c4c40beda61c561716dd35cd);
#
#
#         var popup_aebddcaf01668cdc4991dbbffae9b66f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_824b90f50b921afa9127b28a0f3d13f8 = $(`&lt;div id=&quot;html_824b90f50b921afa9127b28a0f3d13f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_aebddcaf01668cdc4991dbbffae9b66f.setContent(html_824b90f50b921afa9127b28a0f3d13f8);
#
#
#
#         marker_846ea236092f5ba73123be78a852c5c6.bindPopup(popup_aebddcaf01668cdc4991dbbffae9b66f)
#         ;
#
#
#
#
#             var marker_ccd015fcdacabc6a7742cedb68625b4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_03c58415c4c40beda61c561716dd35cd);
#
#
#         var popup_6d03a4978114452caeb5b09328ec44eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bec406797e100c5787c88615fb0a0586 = $(`&lt;div id=&quot;html_bec406797e100c5787c88615fb0a0586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6d03a4978114452caeb5b09328ec44eb.setContent(html_bec406797e100c5787c88615fb0a0586);
#
#
#
#         mark
