# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3dcca4283e76c49d8fe49487ab690586 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3dcca4283e76c49d8fe49487ab690586&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3dcca4283e76c49d8fe49487ab690586 = L.map(
#                 &quot;map_3dcca4283e76c49d8fe49487ab690586&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_162074d9cb54f20c0cccc45b3e754f5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_162074d9cb54f20c0cccc45b3e754f5b.addTo(map_3dcca4283e76c49d8fe49487ab690586);
#
#
#             var marker_5bdbc315b9002f6db16db5ee14bc4002 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3dcca4283e76c49d8fe49487ab690586);
#
#
#         var popup_001343fc551564fc447c454011f8f280 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40f0632c6997c5dda6e889f53a73b287 = $(`&lt;div id=&quot;html_40f0632c6997c5dda6e889f53a73b287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_001343fc551564fc447c454011f8f280.setContent(html_40f0632c6997c5dda6e889f53a73b287);
#
#
#
#         marker_5bdbc315b9002f6db16db5ee14bc4002.bindPopup(popup_001343fc551564fc447c454011f8f280)
#         ;
#
#
#
#
#             var marker_f7854b9138b932ee66a856119e1557c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3dcca4283e76c49d8fe49487ab690586);
#
#
#         var popup_874ab46121d87f5c2e179c0d55ec00c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e0b82560ac5c51cca13aaacd4e65c2d = $(`&lt;div id=&quot;html_9e0b82560ac5c51cca13aaacd4e65c2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_874ab46121d87f5c2e179c0d55ec00c9.setContent(html_9e0b82560ac5c51cca13aaacd4e65c2d);
#
#
#
#         marker_f7854b9138b932ee66a856119e1557c7.bindPopup(popup_874ab46121d87f5c2e179c0d55ec00c9)
#         ;
#
#
#
#
#             var marker_0ed015743a4ee6542d9797b48a7e633d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3dcca4283e76c49d8fe49487ab690586);
#
#
#         var popup_65b83f3ffea9360c59d9af50838d4f27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fd1a72e0491d0db745c7bfe9f5962ac = $(`&lt;div id=&quot;html_3fd1a72e0491d0db745c7bfe9f5962ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_65b83f3ffea9360c59d9af50838d4f27.setContent(html_3fd1a72e0491d0db745c7bfe9f5962ac);
#
#
#
#         marker_0ed015743a4ee6542d9797b48a7e633d.bindPopup(popup_65b83f3ffea9360c59d9af50838d4f27)
#         ;
#
#
#
#
#             var marker_ac64f482e2cfff31f74fdd68b0bf523b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3dcca4283e76c49d8fe49487ab690586);
#
#
#         var popup_a9fcbfd5d1185580c75435e0ff254e93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afcd23bb6176b44981b0d3b317b94808 = $(`&lt;div id=&quot;html_afcd23bb6176b44981b0d3b317b94808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a9fcbfd5d1185580c75435e0ff254e93.setContent(html_afcd23bb6176b44981b0d3b317b94808);
#
#
#
#         marker_ac64f482e2cfff31f74fdd68b0bf523b.bindPopup(popup_a9fcbfd5d1185580c75435e0ff254e93)
#         ;
#
#
#
#
#             var marker_28fce64c01d8bafde2be564f27834fc5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3dcca4283e76c49d8fe49487ab690586);
#
#
#         var popup_42ddd1e3a35ffdb6ccdce5a44b5d6f05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9332fb109dfacd8cf195a9a8d654dbf = $(`&lt;div id=&quot;html_d9332fb109dfacd8cf195a9a8d654dbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_42ddd1e3a35ffdb6ccdce5a44b5d6f05.setContent(html_d9332fb109dfacd8cf195a9a8d654dbf);
#
#
#
#         marker_28fce64c01d8bafde2be564f27834fc5.bindPopup(popup_42ddd1e3a35ffdb6ccdce5a44b5d6f05)
#         ;
#
#
#
#
#             var marker_5df3f0ed31

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c0dee008e66e10f570ac8104fb464a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c0dee008e66e10f570ac8104fb464a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c0dee008e66e10f570ac8104fb464a1 = L.map(
#                 &quot;map_3c0dee008e66e10f570ac8104fb464a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ddecb92228f9f45cd0f3b1bf7b765aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ddecb92228f9f45cd0f3b1bf7b765aa.addTo(map_3c0dee008e66e10f570ac8104fb464a1);
#
#
#             var feature_group_ac5038b8c1a03554234c79bb283ad4fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d07eda9891a23e5a9db3ce1de5559140 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ac5038b8c1a03554234c79bb283ad4fb);
#
#
#         var popup_ea97df2341b6b9755f2f61eecb61fe43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbbc1c19896a42b92e9f792883476ef5 = $(`&lt;div id=&quot;html_fbbc1c19896a42b92e9f792883476ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ea97df2341b6b9755f2f61eecb61fe43.setContent(html_fbbc1c19896a42b92e9f792883476ef5);
#
#
#
#         marker_d07eda9891a23e5a9db3ce1de5559140.bindPopup(popup_ea97df2341b6b9755f2f61eecb61fe43)
#         ;
#
#
#
#
#             var marker_1b82c680f5e37601b2b765a9bf4a052b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ac5038b8c1a03554234c79bb283ad4fb);
#
#
#         var popup_e59906abd149ea2e609f1892cd11d53e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9759e22ea929d4bca0aa2b97a43e451b = $(`&lt;div id=&quot;html_9759e22ea929d4bca0aa2b97a43e451b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e59906abd149ea2e609f1892cd11d53e.setContent(html_9759e22ea929d4bca0aa2b97a43e451b);
#
#
#
#         marker_1b82c680f5e37601b2b765a9bf4a052b.bindPopup(popup_e59906abd149ea2e609f1892cd11d53e)
#         ;
#
#
#
#
#             var marker_9320c57cdcd7eb472913ceb76bb13a61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ac5038b8c1a03554234c79bb283ad4fb);
#
#
#         var popup_afafb46d3b0ad82f5e9ac852b0eb3d31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40b5d9076796b199730c95f1ac9a16fe = $(`&lt;div id=&quot;html_40b5d9076796b199730c95f1ac9a16fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_afafb46d3b0ad82f5e9ac852b0eb3d31.setContent(html_40b5d9076796b199730c95f1ac9a16fe);
#
#
#
#         marker_9320c57cdcd7eb472913ceb76bb13a61.bindPopup(popup_afafb46d3b0ad82f5e9ac852b0eb3d31)
#         ;
#
#
#
#
#             var marker_0dd8d6a4e871e6153972eb53d72ae8af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ac5038b8c1a03554234c79bb283ad4fb);
#
#
#         var popup_d70700d5453a4db9961e0d55fdc198c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f6c0632e06f7f8ee797c8a97db69ec2 = $(`&lt;div id=&quot;html_1f6c0632e06f7f8ee797c8a97db69ec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d70700d5453a4db9961e0d55fdc198c3.setContent(html_1f6c0632e06f7f8ee797c8a97db69ec2);
#
#
#
#         marker_0dd8d6a4e871e6153972eb53d72ae8af.bindPopup(popup_d70700d5453a4db9961e0d55fdc198c3)
#         ;
#
#
#
#
#             var marker_239658df80ddd6cfedc20d00b4853c7f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ac5038b8c1a03554234c79bb283ad4fb);
#
#
#         var popup_9b4335011eef3e607b6fd4d3c6c52b7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91b81c4b58c8e81523e1cc495dff3c9c = $(`&lt;div id=&quot;html_91b81c4b58c8e81523e1cc495dff3c9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_9b4335011eef3e607b

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a722d682492932f935fd129244db83bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a722d682492932f935fd129244db83bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a722d682492932f935fd129244db83bc = L.map(
#                 &quot;map_a722d682492932f935fd129244db83bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e150f2b77337b0f5f053e9bf42a591e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e150f2b77337b0f5f053e9bf42a591e.addTo(map_a722d682492932f935fd129244db83bc);
#
#
#             var feature_group_fdda39c224c213fe1ccb3469f1a44c8a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fdda39c224c213fe1ccb3469f1a44c8a.addTo(map_a722d682492932f935fd129244db83bc);
#
#
#             var feature_group_sub_group_f217e670385d5de6dbcb8ec3986c5eaf = L.featureGroup.subGroup(
#                 feature_group_fdda39c224c213fe1ccb3469f1a44c8a
#             );
#
#
#             var marker_c58b736d36f2b819789daaa31234bea7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f217e670385d5de6dbcb8ec3986c5eaf);
#
#
#         var popup_0f75c12196eb350b1761f88c0e7e261d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_725e918ab42543c221f283b5e5e8b950 = $(`&lt;div id=&quot;html_725e918ab42543c221f283b5e5e8b950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0f75c12196eb350b1761f88c0e7e261d.setContent(html_725e918ab42543c221f283b5e5e8b950);
#
#
#
#         marker_c58b736d36f2b819789daaa31234bea7.bindPopup(popup_0f75c12196eb350b1761f88c0e7e261d)
#         ;
#
#
#
#
#             var marker_7a3cd386837279b61de0ab168a0c9e71 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f217e670385d5de6dbcb8ec3986c5eaf);
#
#
#         var popup_61ae23a3a20704f0e167c5781766e788 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c11516474a6603ba03023a725f714008 = $(`&lt;div id=&quot;html_c11516474a6603ba03023a725f714008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_61ae23a3a20704f0e167c5781766e788.setContent(html_c11516474a6603ba03023a725f714008);
#
#
#
#         marker_7a3cd386837279b61de0ab168a0c9e71.bindPopup(popup_61ae23a3a20704f0e167c5781766e788)
#         ;
#
#
#
#
#             var marker_7d72483dfe72ab7f7904c34e81a38c36 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f217e670385d5de6dbcb8ec3986c5eaf);
#
#
#         var popup_b1dc929958af907bfcab8c2085cfbad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4c438751e07b73782da9384a5e6e388 = $(`&lt;div id=&quot;html_e4c438751e07b73782da9384a5e6e388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b1dc929958af907bfcab8c2085cfbad1.setContent(html_e4c438751e07b73782da9384a5e6e388);
#
#
#
#         marker_7d72483dfe72ab7f7904c34e81a38c36.bindPopup(popup_b1dc929958af907bfcab8c2085cfbad1)
#         ;
#
#
#
#
#             var marker_21097b05f33e291cab2f7c472d847423 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f217e670385d5de6dbcb8ec3986c5eaf);
#
#
#         var popup_a77e2b00af21023f5983cf8ce428d700 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6175473d53e804ad5ea90fc2ada9da2e = $(`&lt;div id=&quot;html_6175473d53e804ad5ea90fc2ada9da2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a77e2b00af21023f5983cf8ce428d700.setContent(html_6175473d53e804ad5ea90fc2ada9da2e);
#
#
#
#         marker_21097b05f33e291cab2f7c472d847423.bindPopup(popup_a77e2b00af21023f5983cf8ce428d700)
#         ;
#
#
#
#
#             var marker_e9ebae66652685fe24ce7563e0009c54 = L.marker(
#                 [45.050399999999996, 3.0504],
