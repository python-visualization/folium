# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02c710648b61d0297c866113a32869fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02c710648b61d0297c866113a32869fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02c710648b61d0297c866113a32869fd = L.map(
#                 &quot;map_02c710648b61d0297c866113a32869fd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeb39a895588caf6d00efc39fe7c3553 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eeb39a895588caf6d00efc39fe7c3553.addTo(map_02c710648b61d0297c866113a32869fd);
#
#
#             var marker_dbac9018aa95e90bd8efe7533916d47e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_02c710648b61d0297c866113a32869fd);
#
#
#         var popup_992ea3ada60302c412f89eaa0fa3b9f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d26dd049692019643cf556d0660937be = $(`&lt;div id=&quot;html_d26dd049692019643cf556d0660937be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_992ea3ada60302c412f89eaa0fa3b9f3.setContent(html_d26dd049692019643cf556d0660937be);
#
#
#
#         marker_dbac9018aa95e90bd8efe7533916d47e.bindPopup(popup_992ea3ada60302c412f89eaa0fa3b9f3)
#         ;
#
#
#
#
#             var marker_595e4e2c235a40b1e8438f8f489c6edd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_02c710648b61d0297c866113a32869fd);
#
#
#         var popup_9bb5bc20f327c7c23f080d28cdf93aa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2040f7e1f9ad5c37b84b08edb5988117 = $(`&lt;div id=&quot;html_2040f7e1f9ad5c37b84b08edb5988117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9bb5bc20f327c7c23f080d28cdf93aa9.setContent(html_2040f7e1f9ad5c37b84b08edb5988117);
#
#
#
#         marker_595e4e2c235a40b1e8438f8f489c6edd.bindPopup(popup_9bb5bc20f327c7c23f080d28cdf93aa9)
#         ;
#
#
#
#
#             var marker_65183553294adda2ae2da2b200b6e447 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_02c710648b61d0297c866113a32869fd);
#
#
#         var popup_2354c25f6846596cad7d36cc57f25bc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d42006bb8920590a88752214d977a10 = $(`&lt;div id=&quot;html_6d42006bb8920590a88752214d977a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2354c25f6846596cad7d36cc57f25bc6.setContent(html_6d42006bb8920590a88752214d977a10);
#
#
#
#         marker_65183553294adda2ae2da2b200b6e447.bindPopup(popup_2354c25f6846596cad7d36cc57f25bc6)
#         ;
#
#
#
#
#             var marker_5ebdbd970dd73338e59df0bc3f8a238d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_02c710648b61d0297c866113a32869fd);
#
#
#         var popup_8f88715c516848ec4c60f00de2141e46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad37433ffa7120c0f57a9cf9639d9426 = $(`&lt;div id=&quot;html_ad37433ffa7120c0f57a9cf9639d9426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8f88715c516848ec4c60f00de2141e46.setContent(html_ad37433ffa7120c0f57a9cf9639d9426);
#
#
#
#         marker_5ebdbd970dd73338e59df0bc3f8a238d.bindPopup(popup_8f88715c516848ec4c60f00de2141e46)
#         ;
#
#
#
#
#             var marker_ada2e0cb054f8b18e9d82ebef8222d00 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_02c710648b61d0297c866113a32869fd);
#
#
#         var popup_954170d0f7795c5abdb17db89fae709d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_935d41ee145363376945155c22b583df = $(`&lt;div id=&quot;html_935d41ee145363376945155c22b583df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_954170d0f7795c5abdb17db89fae709d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3deac77b1cbbae29fefe6ac19f31ffa8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3deac77b1cbbae29fefe6ac19f31ffa8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3deac77b1cbbae29fefe6ac19f31ffa8 = L.map(
#                 &quot;map_3deac77b1cbbae29fefe6ac19f31ffa8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5930e6ab3587b1752df754fa30084eae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5930e6ab3587b1752df754fa30084eae.addTo(map_3deac77b1cbbae29fefe6ac19f31ffa8);
#
#
#             var feature_group_69ef5b252cab6e563cf8f74df515ae2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ab84ee376a8464caa3edb5f4e5455733 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_69ef5b252cab6e563cf8f74df515ae2d);
#
#
#         var popup_52e0e5d6aaa40a3b1e285946b9e4dd97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a49b721d9dc05ffb18cf88687cf1c30e = $(`&lt;div id=&quot;html_a49b721d9dc05ffb18cf88687cf1c30e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_52e0e5d6aaa40a3b1e285946b9e4dd97.setContent(html_a49b721d9dc05ffb18cf88687cf1c30e);
#
#
#
#         marker_ab84ee376a8464caa3edb5f4e5455733.bindPopup(popup_52e0e5d6aaa40a3b1e285946b9e4dd97)
#         ;
#
#
#
#
#             var marker_d6f83e319a607b808910d95799b5e4f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_69ef5b252cab6e563cf8f74df515ae2d);
#
#
#         var popup_5177c928b65b7ce34b458c880e1ae368 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21f0e6e9173453f5162a6d0fcd9c92f2 = $(`&lt;div id=&quot;html_21f0e6e9173453f5162a6d0fcd9c92f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5177c928b65b7ce34b458c880e1ae368.setContent(html_21f0e6e9173453f5162a6d0fcd9c92f2);
#
#
#
#         marker_d6f83e319a607b808910d95799b5e4f6.bindPopup(popup_5177c928b65b7ce34b458c880e1ae368)
#         ;
#
#
#
#
#             var marker_8af2054a7524fdb622d658224c0d7f42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_69ef5b252cab6e563cf8f74df515ae2d);
#
#
#         var popup_9b144ac849f9bd2a23e1db40b2ea974b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ef74b305d7f2ecd7f8cc1df76adb7e2 = $(`&lt;div id=&quot;html_1ef74b305d7f2ecd7f8cc1df76adb7e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b144ac849f9bd2a23e1db40b2ea974b.setContent(html_1ef74b305d7f2ecd7f8cc1df76adb7e2);
#
#
#
#         marker_8af2054a7524fdb622d658224c0d7f42.bindPopup(popup_9b144ac849f9bd2a23e1db40b2ea974b)
#         ;
#
#
#
#
#             var marker_1b8612cf03bc5b16cdb84921f637398e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_69ef5b252cab6e563cf8f74df515ae2d);
#
#
#         var popup_a3a0985e9fb7e41239445d591c37e4b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_657f1f79f1de3fda59862ab691997a97 = $(`&lt;div id=&quot;html_657f1f79f1de3fda59862ab691997a97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a3a0985e9fb7e41239445d591c37e4b1.setContent(html_657f1f79f1de3fda59862ab691997a97);
#
#
#
#         marker_1b8612cf03bc5b16cdb84921f637398e.bindPopup(popup_a3a0985e9fb7e41239445d591c37e4b1)
#         ;
#
#
#
#
#             var marker_153bc907536884ea8f9df906d74c39a1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_69ef5b252cab6e563cf8f74df515ae2d);
#
#
#         var popup_d259478671e42b90f91b9b7066543623 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_960f6cd185bf02f03eb42a85d95e8174 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_960f6cd185bf02f03eb42a85d95e8174&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_960f6cd185bf02f03eb42a85d95e8174 = L.map(
#                 &quot;map_960f6cd185bf02f03eb42a85d95e8174&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11084b35acbfa490622490e41e274e42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11084b35acbfa490622490e41e274e42.addTo(map_960f6cd185bf02f03eb42a85d95e8174);
#
#
#             var feature_group_d84b61d837d7eabc79598757ecb9f05f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d84b61d837d7eabc79598757ecb9f05f.addTo(map_960f6cd185bf02f03eb42a85d95e8174);
#
#
#             var feature_group_sub_group_c445ada3a1c49c5b98e108559eb7b91c = L.featureGroup.subGroup(
#                 feature_group_d84b61d837d7eabc79598757ecb9f05f
#             );
#
#
#             var marker_686f25a2dec4016615c179f2a8f4a206 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c445ada3a1c49c5b98e108559eb7b91c);
#
#
#         var popup_ca0d3ad7fb8a6a9e88d49c943c2b7896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be97ec5b5bb376fd6bc63486a7df7f28 = $(`&lt;div id=&quot;html_be97ec5b5bb376fd6bc63486a7df7f28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ca0d3ad7fb8a6a9e88d49c943c2b7896.setContent(html_be97ec5b5bb376fd6bc63486a7df7f28);
#
#
#
#         marker_686f25a2dec4016615c179f2a8f4a206.bindPopup(popup_ca0d3ad7fb8a6a9e88d49c943c2b7896)
#         ;
#
#
#
#
#             var marker_c6f55554b1bd3e0b4d082b599e8556b1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c445ada3a1c49c5b98e108559eb7b91c);
#
#
#         var popup_be89c16db83d02a0c9f8d8a318fcdd80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82a1c39f438ca9ae59869d233675c4ac = $(`&lt;div id=&quot;html_82a1c39f438ca9ae59869d233675c4ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_be89c16db83d02a0c9f8d8a318fcdd80.setContent(html_82a1c39f438ca9ae59869d233675c4ac);
#
#
#
#         marker_c6f55554b1bd3e0b4d082b599e8556b1.bindPopup(popup_be89c16db83d02a0c9f8d8a318fcdd80)
#         ;
#
#
#
#
#             var marker_a25f1bbe4982c14fc7e98067b40e36ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c445ada3a1c49c5b98e108559eb7b91c);
#
#
#         var popup_56a73f5705297ccd44622888eb73ebb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e13b6c1005b82dc7475958aae667a06 = $(`&lt;div id=&quot;html_5e13b6c1005b82dc7475958aae667a06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_56a73f5705297ccd44622888eb73ebb0.setContent(html_5e13b6c1005b82dc7475958aae667a06);
#
#
#
#         marker_a25f1bbe4982c14fc7e98067b40e36ac.bindPopup(popup_56a73f5705297ccd44622888eb73ebb0)
#         ;
#
#
#
#
#             var marker_1e932f9af6e2a766fc6b8ed370bc69c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c445ada3a1c49c5b98e108559eb7b91c);
#
#
#         var popup_23abd064d9007ab194d2ae15bcc9cb53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f489618af3891f1014b5eadc612d494d = $(`&lt;div id=&quot;html_f489618af3891f1014b5eadc612d494d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_23abd064d9007ab194d2ae15bcc9cb53.setContent(html_f489618af3891f1014b5eadc612d494d);
#
#
#
#         marker_
