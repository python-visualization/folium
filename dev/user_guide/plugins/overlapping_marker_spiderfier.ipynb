# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f742f1e829aec9be3bfd5bec22f7369e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f742f1e829aec9be3bfd5bec22f7369e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f742f1e829aec9be3bfd5bec22f7369e = L.map(
#                 &quot;map_f742f1e829aec9be3bfd5bec22f7369e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f66b75e645c8a20039ea3e07454fc50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f66b75e645c8a20039ea3e07454fc50.addTo(map_f742f1e829aec9be3bfd5bec22f7369e);
#
#
#             var marker_826312c44e52452add40a6a42ca3d25d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f742f1e829aec9be3bfd5bec22f7369e);
#
#
#         var popup_e8c4781bb24db7ffec466513988e1941 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eee787df5f8230aa153c0f305a583a03 = $(`&lt;div id=&quot;html_eee787df5f8230aa153c0f305a583a03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e8c4781bb24db7ffec466513988e1941.setContent(html_eee787df5f8230aa153c0f305a583a03);
#
#
#
#         marker_826312c44e52452add40a6a42ca3d25d.bindPopup(popup_e8c4781bb24db7ffec466513988e1941)
#         ;
#
#
#
#
#             var marker_edd74e01f1af29ea93a9022af0646d75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f742f1e829aec9be3bfd5bec22f7369e);
#
#
#         var popup_7c4173f4ae9e0eef7f9c74cca320cf6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed31f56de6713518acc4bb963fad2cbc = $(`&lt;div id=&quot;html_ed31f56de6713518acc4bb963fad2cbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7c4173f4ae9e0eef7f9c74cca320cf6e.setContent(html_ed31f56de6713518acc4bb963fad2cbc);
#
#
#
#         marker_edd74e01f1af29ea93a9022af0646d75.bindPopup(popup_7c4173f4ae9e0eef7f9c74cca320cf6e)
#         ;
#
#
#
#
#             var marker_0107ea31c8b67edab2a438855dee1915 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f742f1e829aec9be3bfd5bec22f7369e);
#
#
#         var popup_d98a5d0f099d3f6a4e8663768a588eab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_216c286980a0a5838f594508f381db0a = $(`&lt;div id=&quot;html_216c286980a0a5838f594508f381db0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d98a5d0f099d3f6a4e8663768a588eab.setContent(html_216c286980a0a5838f594508f381db0a);
#
#
#
#         marker_0107ea31c8b67edab2a438855dee1915.bindPopup(popup_d98a5d0f099d3f6a4e8663768a588eab)
#         ;
#
#
#
#
#             var marker_b564fdbc4a955511e24145ea6a269f68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f742f1e829aec9be3bfd5bec22f7369e);
#
#
#         var popup_6e2bbc811a442526ace7ee0d3f314bf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a0c5c8ce4604f05b2aa9010ad9de7e3 = $(`&lt;div id=&quot;html_8a0c5c8ce4604f05b2aa9010ad9de7e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e2bbc811a442526ace7ee0d3f314bf9.setContent(html_8a0c5c8ce4604f05b2aa9010ad9de7e3);
#
#
#
#         marker_b564fdbc4a955511e24145ea6a269f68.bindPopup(popup_6e2bbc811a442526ace7ee0d3f314bf9)
#         ;
#
#
#
#
#             var marker_f250bee4f6960826b3da7edf2fade2ef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f742f1e829aec9be3bfd5bec22f7369e);
#
#
#         var popup_0eb4860abb361e207dfde3c40763cbce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78d74c79f95c9d3fa5c169d645a472e2 = $(`&lt;div id=&quot;html_78d74c79f95c9d3fa5c169d645a472e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0eb4860abb361e207dfde3c40763cbce.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98ab526726228ccbfaf285a14cdf14e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98ab526726228ccbfaf285a14cdf14e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98ab526726228ccbfaf285a14cdf14e5 = L.map(
#                 &quot;map_98ab526726228ccbfaf285a14cdf14e5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_588c6b76f6ad18299f5e992694cf43c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_588c6b76f6ad18299f5e992694cf43c6.addTo(map_98ab526726228ccbfaf285a14cdf14e5);
#
#
#             var feature_group_eb1ab1f4274dba68abf0111ce24833d4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e92c5350e48678c380146b34a06e9fb4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eb1ab1f4274dba68abf0111ce24833d4);
#
#
#         var popup_e96397bf5cfeffffc42ab9f0ad51224d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ecbd1e1022cc7b015da3c2a2d96abd = $(`&lt;div id=&quot;html_38ecbd1e1022cc7b015da3c2a2d96abd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e96397bf5cfeffffc42ab9f0ad51224d.setContent(html_38ecbd1e1022cc7b015da3c2a2d96abd);
#
#
#
#         marker_e92c5350e48678c380146b34a06e9fb4.bindPopup(popup_e96397bf5cfeffffc42ab9f0ad51224d)
#         ;
#
#
#
#
#             var marker_cd3ed15a3211218bf4af85ceaf12e425 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eb1ab1f4274dba68abf0111ce24833d4);
#
#
#         var popup_de2637b17da2294e44735bbc1f9b8be1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_755721b201a122b56e7b511e21a2aa18 = $(`&lt;div id=&quot;html_755721b201a122b56e7b511e21a2aa18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_de2637b17da2294e44735bbc1f9b8be1.setContent(html_755721b201a122b56e7b511e21a2aa18);
#
#
#
#         marker_cd3ed15a3211218bf4af85ceaf12e425.bindPopup(popup_de2637b17da2294e44735bbc1f9b8be1)
#         ;
#
#
#
#
#             var marker_e1e7a1ddef125360895edbcd5ace4109 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eb1ab1f4274dba68abf0111ce24833d4);
#
#
#         var popup_8850613a4ad1669123bf727271eada1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff98fdeb7d94b0145363b33a2b4b48c1 = $(`&lt;div id=&quot;html_ff98fdeb7d94b0145363b33a2b4b48c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8850613a4ad1669123bf727271eada1b.setContent(html_ff98fdeb7d94b0145363b33a2b4b48c1);
#
#
#
#         marker_e1e7a1ddef125360895edbcd5ace4109.bindPopup(popup_8850613a4ad1669123bf727271eada1b)
#         ;
#
#
#
#
#             var marker_ac2f4b5ad33612022409aef531648912 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eb1ab1f4274dba68abf0111ce24833d4);
#
#
#         var popup_8776acb1850fe573e08da8a657eaf8aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe9fe9568223aac18d0c46d2bc648193 = $(`&lt;div id=&quot;html_fe9fe9568223aac18d0c46d2bc648193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8776acb1850fe573e08da8a657eaf8aa.setContent(html_fe9fe9568223aac18d0c46d2bc648193);
#
#
#
#         marker_ac2f4b5ad33612022409aef531648912.bindPopup(popup_8776acb1850fe573e08da8a657eaf8aa)
#         ;
#
#
#
#
#             var marker_a23be57e9ad312c21a008122999c7102 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eb1ab1f4274dba68abf0111ce24833d4);
#
#
#         var popup_96927679dcff6b68ab28655196b99b5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce9495f90db89b7d42536779b106fb66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce9495f90db89b7d42536779b106fb66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce9495f90db89b7d42536779b106fb66 = L.map(
#                 &quot;map_ce9495f90db89b7d42536779b106fb66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e1d6dba0bd110426ce6a3bacd8d8d57 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e1d6dba0bd110426ce6a3bacd8d8d57.addTo(map_ce9495f90db89b7d42536779b106fb66);
#
#
#             var feature_group_b334ec07ce27b5b8ced0ccc6c276b0cc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b334ec07ce27b5b8ced0ccc6c276b0cc.addTo(map_ce9495f90db89b7d42536779b106fb66);
#
#
#             var feature_group_sub_group_cf7387c11e5621dfc87f643e58ddf66c = L.featureGroup.subGroup(
#                 feature_group_b334ec07ce27b5b8ced0ccc6c276b0cc
#             );
#
#
#             var marker_878ce6abc3a9eeab117e095295d19a00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf7387c11e5621dfc87f643e58ddf66c);
#
#
#         var popup_fea9b1641b8204e5eea36fe75a6c3f19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43afd7e7d3b0ce1621f2c24559c618ae = $(`&lt;div id=&quot;html_43afd7e7d3b0ce1621f2c24559c618ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fea9b1641b8204e5eea36fe75a6c3f19.setContent(html_43afd7e7d3b0ce1621f2c24559c618ae);
#
#
#
#         marker_878ce6abc3a9eeab117e095295d19a00.bindPopup(popup_fea9b1641b8204e5eea36fe75a6c3f19)
#         ;
#
#
#
#
#             var marker_6406a5e0226c53dea5dd01632a64f78d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf7387c11e5621dfc87f643e58ddf66c);
#
#
#         var popup_9de4cf98e925ef3fc4b511b999a93c3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00af351d4b9e01862115f4f6c841586d = $(`&lt;div id=&quot;html_00af351d4b9e01862115f4f6c841586d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9de4cf98e925ef3fc4b511b999a93c3d.setContent(html_00af351d4b9e01862115f4f6c841586d);
#
#
#
#         marker_6406a5e0226c53dea5dd01632a64f78d.bindPopup(popup_9de4cf98e925ef3fc4b511b999a93c3d)
#         ;
#
#
#
#
#             var marker_6e3b27d660a6f4312c0ec6341e1afb4f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf7387c11e5621dfc87f643e58ddf66c);
#
#
#         var popup_ed9b04dafdfcea320db8d50b6cadfe24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3640456b549facb91b85bfa5144d217c = $(`&lt;div id=&quot;html_3640456b549facb91b85bfa5144d217c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed9b04dafdfcea320db8d50b6cadfe24.setContent(html_3640456b549facb91b85bfa5144d217c);
#
#
#
#         marker_6e3b27d660a6f4312c0ec6341e1afb4f.bindPopup(popup_ed9b04dafdfcea320db8d50b6cadfe24)
#         ;
#
#
#
#
#             var marker_3703a14cbc4655eb64e4b538e1509645 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf7387c11e5621dfc87f643e58ddf66c);
#
#
#         var popup_87ef6de73fd337e6af51c254d4a48868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3fb51b0b7c7d01688644e6fe6fa9928 = $(`&lt;div id=&quot;html_b3fb51b0b7c7d01688644e6fe6fa9928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_87ef6de73fd337e6af51c254d4a48868.setContent(html_b3fb51b0b7c7d01688644e6fe6fa9928);
#
#
#
#         marker_
