# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c498646f7667396322a00e3eb856ed04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c498646f7667396322a00e3eb856ed04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c498646f7667396322a00e3eb856ed04 = L.map(
#                 &quot;map_c498646f7667396322a00e3eb856ed04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67e10b4b18218bb3b91c36067bd91bad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67e10b4b18218bb3b91c36067bd91bad.addTo(map_c498646f7667396322a00e3eb856ed04);
#
#
#             var marker_51c848831bf4fef0c6ccc7b646018e93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c498646f7667396322a00e3eb856ed04);
#
#
#         var popup_122d4c38e8b7809cdf3f3c6a6118a46c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a337a10dbfdfa9162ff984537b5bdc30 = $(`&lt;div id=&quot;html_a337a10dbfdfa9162ff984537b5bdc30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_122d4c38e8b7809cdf3f3c6a6118a46c.setContent(html_a337a10dbfdfa9162ff984537b5bdc30);
#
#
#
#         marker_51c848831bf4fef0c6ccc7b646018e93.bindPopup(popup_122d4c38e8b7809cdf3f3c6a6118a46c)
#         ;
#
#
#
#
#             var marker_d4a85bf2c142354514247a8c32b0e27c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c498646f7667396322a00e3eb856ed04);
#
#
#         var popup_f107aeebc1ce8cf41c65a986f8c55601 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33925748b9aae0a9818ef1d135a33946 = $(`&lt;div id=&quot;html_33925748b9aae0a9818ef1d135a33946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f107aeebc1ce8cf41c65a986f8c55601.setContent(html_33925748b9aae0a9818ef1d135a33946);
#
#
#
#         marker_d4a85bf2c142354514247a8c32b0e27c.bindPopup(popup_f107aeebc1ce8cf41c65a986f8c55601)
#         ;
#
#
#
#
#             var marker_b631cda465f26fd5c1b9fb1f8d628dc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c498646f7667396322a00e3eb856ed04);
#
#
#         var popup_a184157160185f663799d5e14f80c554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e9109899b974c8c2972cfcacf33ea77 = $(`&lt;div id=&quot;html_3e9109899b974c8c2972cfcacf33ea77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a184157160185f663799d5e14f80c554.setContent(html_3e9109899b974c8c2972cfcacf33ea77);
#
#
#
#         marker_b631cda465f26fd5c1b9fb1f8d628dc2.bindPopup(popup_a184157160185f663799d5e14f80c554)
#         ;
#
#
#
#
#             var marker_905835eeed49b6d62e22fabae9afe0ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c498646f7667396322a00e3eb856ed04);
#
#
#         var popup_8570365950122323155d3cba58cf03f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e7bc3408b02adbd5722fe1697b64341 = $(`&lt;div id=&quot;html_0e7bc3408b02adbd5722fe1697b64341&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8570365950122323155d3cba58cf03f1.setContent(html_0e7bc3408b02adbd5722fe1697b64341);
#
#
#
#         marker_905835eeed49b6d62e22fabae9afe0ca.bindPopup(popup_8570365950122323155d3cba58cf03f1)
#         ;
#
#
#
#
#             var marker_acf2eb263d5c0f4ef1be1e113fcb7989 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c498646f7667396322a00e3eb856ed04);
#
#
#         var popup_a51c147a3d548e8b4b56808b0dc19746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb55c0505a4be2ca6befe55676f21977 = $(`&lt;div id=&quot;html_cb55c0505a4be2ca6befe55676f21977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a51c147a3d548e8b4b56808b0dc19746.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d09a9a0c94d22d5bf5a94933cfe2750 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d09a9a0c94d22d5bf5a94933cfe2750&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d09a9a0c94d22d5bf5a94933cfe2750 = L.map(
#                 &quot;map_1d09a9a0c94d22d5bf5a94933cfe2750&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba5f276bd6ab918dc468f750729e06dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba5f276bd6ab918dc468f750729e06dd.addTo(map_1d09a9a0c94d22d5bf5a94933cfe2750);
#
#
#             var feature_group_17fcc16649dcc9e5f70b44177cc5ffc6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0c3dbc7bfa6eab718d2a9d41f8ccd678 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_17fcc16649dcc9e5f70b44177cc5ffc6);
#
#
#         var popup_b17d4999d76d4a3de513e7fe166db48b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74575a3d086b2f3b433cfc50133bd09e = $(`&lt;div id=&quot;html_74575a3d086b2f3b433cfc50133bd09e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b17d4999d76d4a3de513e7fe166db48b.setContent(html_74575a3d086b2f3b433cfc50133bd09e);
#
#
#
#         marker_0c3dbc7bfa6eab718d2a9d41f8ccd678.bindPopup(popup_b17d4999d76d4a3de513e7fe166db48b)
#         ;
#
#
#
#
#             var marker_78fb64e1355c16b84b7a6cad4b0f459e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_17fcc16649dcc9e5f70b44177cc5ffc6);
#
#
#         var popup_70d2e9bb39b7c74774195436e3a1da06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38e7f643df4266f7562776df7077049b = $(`&lt;div id=&quot;html_38e7f643df4266f7562776df7077049b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_70d2e9bb39b7c74774195436e3a1da06.setContent(html_38e7f643df4266f7562776df7077049b);
#
#
#
#         marker_78fb64e1355c16b84b7a6cad4b0f459e.bindPopup(popup_70d2e9bb39b7c74774195436e3a1da06)
#         ;
#
#
#
#
#             var marker_e5ade1f6847b5f93276f0e141c087f1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_17fcc16649dcc9e5f70b44177cc5ffc6);
#
#
#         var popup_bba76c349180bc21871b3d1e4048eb0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_090a4bb0f70fa76c9c81e5c6ffc528c2 = $(`&lt;div id=&quot;html_090a4bb0f70fa76c9c81e5c6ffc528c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bba76c349180bc21871b3d1e4048eb0b.setContent(html_090a4bb0f70fa76c9c81e5c6ffc528c2);
#
#
#
#         marker_e5ade1f6847b5f93276f0e141c087f1e.bindPopup(popup_bba76c349180bc21871b3d1e4048eb0b)
#         ;
#
#
#
#
#             var marker_0de1894152c30f75c211b17f300c03c7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_17fcc16649dcc9e5f70b44177cc5ffc6);
#
#
#         var popup_5c9585a70005ecb5f5b55d0adfc4e341 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd3de680ed874c8f7cbbc14d00d948fa = $(`&lt;div id=&quot;html_dd3de680ed874c8f7cbbc14d00d948fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5c9585a70005ecb5f5b55d0adfc4e341.setContent(html_dd3de680ed874c8f7cbbc14d00d948fa);
#
#
#
#         marker_0de1894152c30f75c211b17f300c03c7.bindPopup(popup_5c9585a70005ecb5f5b55d0adfc4e341)
#         ;
#
#
#
#
#             var marker_050510ca0e0a80d0879dbc976bd3bfe9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_17fcc16649dcc9e5f70b44177cc5ffc6);
#
#
#         var popup_8b89953309648533f305bb7a215b7bcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7823db3fc42f067fa69842ef5028696 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7823db3fc42f067fa69842ef5028696&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7823db3fc42f067fa69842ef5028696 = L.map(
#                 &quot;map_f7823db3fc42f067fa69842ef5028696&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2740ca324eefb7381241144354e8d22a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2740ca324eefb7381241144354e8d22a.addTo(map_f7823db3fc42f067fa69842ef5028696);
#
#
#             var feature_group_16fd4281b85beac69f268481ca6d44dd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_16fd4281b85beac69f268481ca6d44dd.addTo(map_f7823db3fc42f067fa69842ef5028696);
#
#
#             var feature_group_sub_group_f33518fae74ce5b56668ff8cb4d42a1f = L.featureGroup.subGroup(
#                 feature_group_16fd4281b85beac69f268481ca6d44dd
#             );
#
#
#             var marker_92fa2ca497936b0c88af78033d169e09 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f33518fae74ce5b56668ff8cb4d42a1f);
#
#
#         var popup_72b65aa877dd68327f5f6efa77b07aa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00475c8b34830ada412dff0a62bf9d0e = $(`&lt;div id=&quot;html_00475c8b34830ada412dff0a62bf9d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_72b65aa877dd68327f5f6efa77b07aa5.setContent(html_00475c8b34830ada412dff0a62bf9d0e);
#
#
#
#         marker_92fa2ca497936b0c88af78033d169e09.bindPopup(popup_72b65aa877dd68327f5f6efa77b07aa5)
#         ;
#
#
#
#
#             var marker_80cd1d5ce07f94a1f8c4c986cd532f10 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f33518fae74ce5b56668ff8cb4d42a1f);
#
#
#         var popup_0fd0ff97d233b4f6040b5d5f79a6d44f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efbd836916123033362ae3c5d5d01426 = $(`&lt;div id=&quot;html_efbd836916123033362ae3c5d5d01426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0fd0ff97d233b4f6040b5d5f79a6d44f.setContent(html_efbd836916123033362ae3c5d5d01426);
#
#
#
#         marker_80cd1d5ce07f94a1f8c4c986cd532f10.bindPopup(popup_0fd0ff97d233b4f6040b5d5f79a6d44f)
#         ;
#
#
#
#
#             var marker_324984558c2325efb029c9612cc2694d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f33518fae74ce5b56668ff8cb4d42a1f);
#
#
#         var popup_633df082560c442063233f75fb86eccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00b53b2ca19ff77ca16f8f2ab0797474 = $(`&lt;div id=&quot;html_00b53b2ca19ff77ca16f8f2ab0797474&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_633df082560c442063233f75fb86eccc.setContent(html_00b53b2ca19ff77ca16f8f2ab0797474);
#
#
#
#         marker_324984558c2325efb029c9612cc2694d.bindPopup(popup_633df082560c442063233f75fb86eccc)
#         ;
#
#
#
#
#             var marker_7fabd6c37c974f60dd031ac18bf16c2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f33518fae74ce5b56668ff8cb4d42a1f);
#
#
#         var popup_9f2f886ea191082896750f941c9fb432 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_312261f53bbd38cb7d03ed649c27073a = $(`&lt;div id=&quot;html_312261f53bbd38cb7d03ed649c27073a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9f2f886ea191082896750f941c9fb432.setContent(html_312261f53bbd38cb7d03ed649c27073a);
#
#
#
#         marker_
