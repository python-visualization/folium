# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5352744b80fadf2257501d787f1de13a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5352744b80fadf2257501d787f1de13a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5352744b80fadf2257501d787f1de13a = L.map(
#                 &quot;map_5352744b80fadf2257501d787f1de13a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d07ccff9e7a8dc7b8b5e5d71e35bcb3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d07ccff9e7a8dc7b8b5e5d71e35bcb3b.addTo(map_5352744b80fadf2257501d787f1de13a);
#
#
#             var marker_2d48d616bb22f7d0dff07ceb5b381e93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5352744b80fadf2257501d787f1de13a);
#
#
#         var popup_8313383a480db36d1306435af79ce2d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a8e036308592539445389e06b159f82 = $(`&lt;div id=&quot;html_5a8e036308592539445389e06b159f82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8313383a480db36d1306435af79ce2d0.setContent(html_5a8e036308592539445389e06b159f82);
#
#
#
#         marker_2d48d616bb22f7d0dff07ceb5b381e93.bindPopup(popup_8313383a480db36d1306435af79ce2d0)
#         ;
#
#
#
#
#             var marker_4fc11463d75794fdfff10659af588f6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5352744b80fadf2257501d787f1de13a);
#
#
#         var popup_cc02fb4d63b8e073dcd385c51011f41b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_038f366b52c1feeb02ac76883d5c8dd3 = $(`&lt;div id=&quot;html_038f366b52c1feeb02ac76883d5c8dd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cc02fb4d63b8e073dcd385c51011f41b.setContent(html_038f366b52c1feeb02ac76883d5c8dd3);
#
#
#
#         marker_4fc11463d75794fdfff10659af588f6a.bindPopup(popup_cc02fb4d63b8e073dcd385c51011f41b)
#         ;
#
#
#
#
#             var marker_eef195332eefcc6558d1d4a94eb9572d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5352744b80fadf2257501d787f1de13a);
#
#
#         var popup_1dd370647fbeed01e7bf0bcfe5c6d70f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_378cccf0a270d5f9e84fc3e20317621d = $(`&lt;div id=&quot;html_378cccf0a270d5f9e84fc3e20317621d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1dd370647fbeed01e7bf0bcfe5c6d70f.setContent(html_378cccf0a270d5f9e84fc3e20317621d);
#
#
#
#         marker_eef195332eefcc6558d1d4a94eb9572d.bindPopup(popup_1dd370647fbeed01e7bf0bcfe5c6d70f)
#         ;
#
#
#
#
#             var marker_c21d165428581e88991eceedf27dd3cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5352744b80fadf2257501d787f1de13a);
#
#
#         var popup_b118695c0094282c6ecd4c80c2b639c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bda0d7b2bb86d529ba69b66be4af4ff = $(`&lt;div id=&quot;html_8bda0d7b2bb86d529ba69b66be4af4ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b118695c0094282c6ecd4c80c2b639c5.setContent(html_8bda0d7b2bb86d529ba69b66be4af4ff);
#
#
#
#         marker_c21d165428581e88991eceedf27dd3cf.bindPopup(popup_b118695c0094282c6ecd4c80c2b639c5)
#         ;
#
#
#
#
#             var marker_3bd75c79ca661171a1a216e43bfbf02b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5352744b80fadf2257501d787f1de13a);
#
#
#         var popup_67f23bc63318100382bfe6f6d3f9d0e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab8a6c418955bd2d56a495ec6c3de72b = $(`&lt;div id=&quot;html_ab8a6c418955bd2d56a495ec6c3de72b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_67f23bc63318100382bfe6f6d3f9d0e7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3265d3f4b0df3ded6977d019edb98264 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3265d3f4b0df3ded6977d019edb98264&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3265d3f4b0df3ded6977d019edb98264 = L.map(
#                 &quot;map_3265d3f4b0df3ded6977d019edb98264&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0e3a9b651c3e78e90a3fcf1f9231781 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0e3a9b651c3e78e90a3fcf1f9231781.addTo(map_3265d3f4b0df3ded6977d019edb98264);
#
#
#             var feature_group_7e51c195ab68dcc4355fc3ab84e47f81 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a222ccad99f8a0860dc37ec5b2acff4f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7e51c195ab68dcc4355fc3ab84e47f81);
#
#
#         var popup_294ad9204c6ef109c6cb0c5672b91e8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_480ef478ab366d7ae5934e8e26f7073e = $(`&lt;div id=&quot;html_480ef478ab366d7ae5934e8e26f7073e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_294ad9204c6ef109c6cb0c5672b91e8f.setContent(html_480ef478ab366d7ae5934e8e26f7073e);
#
#
#
#         marker_a222ccad99f8a0860dc37ec5b2acff4f.bindPopup(popup_294ad9204c6ef109c6cb0c5672b91e8f)
#         ;
#
#
#
#
#             var marker_004a226819a47ed2cc8a052790e44850 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7e51c195ab68dcc4355fc3ab84e47f81);
#
#
#         var popup_bab0257ac0fbe2efcddeb54356ec33af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3900ac53e8bc68d2bbdfe738d382ec7c = $(`&lt;div id=&quot;html_3900ac53e8bc68d2bbdfe738d382ec7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bab0257ac0fbe2efcddeb54356ec33af.setContent(html_3900ac53e8bc68d2bbdfe738d382ec7c);
#
#
#
#         marker_004a226819a47ed2cc8a052790e44850.bindPopup(popup_bab0257ac0fbe2efcddeb54356ec33af)
#         ;
#
#
#
#
#             var marker_6e679854eca774932d33929e075d7332 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7e51c195ab68dcc4355fc3ab84e47f81);
#
#
#         var popup_6d1486312ee7ecd6640c8877179b6b0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c72619a1ece6bb44eb34598de59b94dd = $(`&lt;div id=&quot;html_c72619a1ece6bb44eb34598de59b94dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6d1486312ee7ecd6640c8877179b6b0d.setContent(html_c72619a1ece6bb44eb34598de59b94dd);
#
#
#
#         marker_6e679854eca774932d33929e075d7332.bindPopup(popup_6d1486312ee7ecd6640c8877179b6b0d)
#         ;
#
#
#
#
#             var marker_779ff63b277fdb0f668465fac5af70fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7e51c195ab68dcc4355fc3ab84e47f81);
#
#
#         var popup_7e0fdacdb22bb0bd774770c8bc361eec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c26b571846492e1cbc108dc69ed63619 = $(`&lt;div id=&quot;html_c26b571846492e1cbc108dc69ed63619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7e0fdacdb22bb0bd774770c8bc361eec.setContent(html_c26b571846492e1cbc108dc69ed63619);
#
#
#
#         marker_779ff63b277fdb0f668465fac5af70fc.bindPopup(popup_7e0fdacdb22bb0bd774770c8bc361eec)
#         ;
#
#
#
#
#             var marker_20f8ae3fdd3c57beb7c00c1bd153f899 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7e51c195ab68dcc4355fc3ab84e47f81);
#
#
#         var popup_ea7aaa5644837461855c0fcb5a08786e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b84891d99bbfb4650e7d4ae54254880 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b84891d99bbfb4650e7d4ae54254880&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b84891d99bbfb4650e7d4ae54254880 = L.map(
#                 &quot;map_2b84891d99bbfb4650e7d4ae54254880&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5530a720b55c257fb182a1b0c83a42bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5530a720b55c257fb182a1b0c83a42bf.addTo(map_2b84891d99bbfb4650e7d4ae54254880);
#
#
#             var feature_group_23609d6551fa1c6c7d93df290d7c8dbb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_23609d6551fa1c6c7d93df290d7c8dbb.addTo(map_2b84891d99bbfb4650e7d4ae54254880);
#
#
#             var feature_group_sub_group_5d1fe1e16349c2fe24323e064b907e6f = L.featureGroup.subGroup(
#                 feature_group_23609d6551fa1c6c7d93df290d7c8dbb
#             );
#
#
#             var marker_ae80bd7c975cf1745c460ca5f60d59c2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fe1e16349c2fe24323e064b907e6f);
#
#
#         var popup_e61db96f1036100ca9d35da1bbd09ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d6322a75a2979a9f104d51ed0dd518 = $(`&lt;div id=&quot;html_12d6322a75a2979a9f104d51ed0dd518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e61db96f1036100ca9d35da1bbd09ae1.setContent(html_12d6322a75a2979a9f104d51ed0dd518);
#
#
#
#         marker_ae80bd7c975cf1745c460ca5f60d59c2.bindPopup(popup_e61db96f1036100ca9d35da1bbd09ae1)
#         ;
#
#
#
#
#             var marker_d3a61b747082ba5544c203df2097fde5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fe1e16349c2fe24323e064b907e6f);
#
#
#         var popup_defeffa2e96597941cd6bf52d7f5319b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26aaa543664698173ad81b53116d1ec2 = $(`&lt;div id=&quot;html_26aaa543664698173ad81b53116d1ec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_defeffa2e96597941cd6bf52d7f5319b.setContent(html_26aaa543664698173ad81b53116d1ec2);
#
#
#
#         marker_d3a61b747082ba5544c203df2097fde5.bindPopup(popup_defeffa2e96597941cd6bf52d7f5319b)
#         ;
#
#
#
#
#             var marker_6feef6e806e2a5184022b64948dbd12f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fe1e16349c2fe24323e064b907e6f);
#
#
#         var popup_f826b508e51568dda2d05ba7dc713a0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_880afa1fdae8185dc6f958401f0debd0 = $(`&lt;div id=&quot;html_880afa1fdae8185dc6f958401f0debd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f826b508e51568dda2d05ba7dc713a0c.setContent(html_880afa1fdae8185dc6f958401f0debd0);
#
#
#
#         marker_6feef6e806e2a5184022b64948dbd12f.bindPopup(popup_f826b508e51568dda2d05ba7dc713a0c)
#         ;
#
#
#
#
#             var marker_4399ecfeac3702b27697d76d68b91874 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fe1e16349c2fe24323e064b907e6f);
#
#
#         var popup_eead410d5dea85b44b806564cf18f511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3b0c86b67817501d875253097a2eab6 = $(`&lt;div id=&quot;html_e3b0c86b67817501d875253097a2eab6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eead410d5dea85b44b806564cf18f511.setContent(html_e3b0c86b67817501d875253097a2eab6);
#
#
#
#         marker_
