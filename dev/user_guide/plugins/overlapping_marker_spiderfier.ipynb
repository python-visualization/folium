# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5fa3332b3f73d35b084956c7bd09ed4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5fa3332b3f73d35b084956c7bd09ed4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5fa3332b3f73d35b084956c7bd09ed4 = L.map(
#                 &quot;map_d5fa3332b3f73d35b084956c7bd09ed4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_225ca4338c174d9ba1ba1270bef7c2fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_225ca4338c174d9ba1ba1270bef7c2fc.addTo(map_d5fa3332b3f73d35b084956c7bd09ed4);
#
#
#             var marker_de543318b88783cbf7e859ff216b8b01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d5fa3332b3f73d35b084956c7bd09ed4);
#
#
#         var popup_e1943f1492288423283ebd69e1099583 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1497d65a66ea9232b7871c98fac1273f = $(`&lt;div id=&quot;html_1497d65a66ea9232b7871c98fac1273f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e1943f1492288423283ebd69e1099583.setContent(html_1497d65a66ea9232b7871c98fac1273f);
#
#
#
#         marker_de543318b88783cbf7e859ff216b8b01.bindPopup(popup_e1943f1492288423283ebd69e1099583)
#         ;
#
#
#
#
#             var marker_fdb11cb47995b965ad5a82670a50083e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d5fa3332b3f73d35b084956c7bd09ed4);
#
#
#         var popup_66b37584a375f5399c97e2250cb70203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8952ebd561a1db0ca92947def73ef71 = $(`&lt;div id=&quot;html_a8952ebd561a1db0ca92947def73ef71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_66b37584a375f5399c97e2250cb70203.setContent(html_a8952ebd561a1db0ca92947def73ef71);
#
#
#
#         marker_fdb11cb47995b965ad5a82670a50083e.bindPopup(popup_66b37584a375f5399c97e2250cb70203)
#         ;
#
#
#
#
#             var marker_f9d65cc7f304a261b64fb6b494b3012e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d5fa3332b3f73d35b084956c7bd09ed4);
#
#
#         var popup_083c4c132ff1fa7cbd5bff91db065130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef81274c57654b97a5f9f5933fdd96e0 = $(`&lt;div id=&quot;html_ef81274c57654b97a5f9f5933fdd96e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_083c4c132ff1fa7cbd5bff91db065130.setContent(html_ef81274c57654b97a5f9f5933fdd96e0);
#
#
#
#         marker_f9d65cc7f304a261b64fb6b494b3012e.bindPopup(popup_083c4c132ff1fa7cbd5bff91db065130)
#         ;
#
#
#
#
#             var marker_6b958a9f051f6db6bf4f553478db68f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d5fa3332b3f73d35b084956c7bd09ed4);
#
#
#         var popup_18a4391561819f414360773caaaedaaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_390ab171c04d36f9b85658475f604825 = $(`&lt;div id=&quot;html_390ab171c04d36f9b85658475f604825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18a4391561819f414360773caaaedaaa.setContent(html_390ab171c04d36f9b85658475f604825);
#
#
#
#         marker_6b958a9f051f6db6bf4f553478db68f0.bindPopup(popup_18a4391561819f414360773caaaedaaa)
#         ;
#
#
#
#
#             var marker_63e6c12a2895d03592372499ca12e8d8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d5fa3332b3f73d35b084956c7bd09ed4);
#
#
#         var popup_ef6675d9f147f35d97026f972b378ff6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_863b69aca004d893f1268c730654223f = $(`&lt;div id=&quot;html_863b69aca004d893f1268c730654223f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ef6675d9f147f35d97026f972b378ff6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_232712a6771236f9625436aa9d02a66d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_232712a6771236f9625436aa9d02a66d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_232712a6771236f9625436aa9d02a66d = L.map(
#                 &quot;map_232712a6771236f9625436aa9d02a66d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4314ff88dca94129023683c65af64e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4314ff88dca94129023683c65af64e3.addTo(map_232712a6771236f9625436aa9d02a66d);
#
#
#             var feature_group_3ac4a06d34fb4d3825930b7243bcbe92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_00baaaca95e18a4a188d309d4bb5bcd0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3ac4a06d34fb4d3825930b7243bcbe92);
#
#
#         var popup_ae3ab04e2639b89f539bbf536e4b8422 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a2a07c310cb0c8487879a63138405ea = $(`&lt;div id=&quot;html_2a2a07c310cb0c8487879a63138405ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ae3ab04e2639b89f539bbf536e4b8422.setContent(html_2a2a07c310cb0c8487879a63138405ea);
#
#
#
#         marker_00baaaca95e18a4a188d309d4bb5bcd0.bindPopup(popup_ae3ab04e2639b89f539bbf536e4b8422)
#         ;
#
#
#
#
#             var marker_d495953ce9a41dd45419713574f2c1a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3ac4a06d34fb4d3825930b7243bcbe92);
#
#
#         var popup_eaa678a1c0137f59d62f6a029539adfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9fd974a5138f0bc87d3966145642bf8 = $(`&lt;div id=&quot;html_c9fd974a5138f0bc87d3966145642bf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eaa678a1c0137f59d62f6a029539adfd.setContent(html_c9fd974a5138f0bc87d3966145642bf8);
#
#
#
#         marker_d495953ce9a41dd45419713574f2c1a5.bindPopup(popup_eaa678a1c0137f59d62f6a029539adfd)
#         ;
#
#
#
#
#             var marker_f3a166c42cf2410c5a1caf5390f18a13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3ac4a06d34fb4d3825930b7243bcbe92);
#
#
#         var popup_561c9014441ad931c3cf8fc579eca3ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78a3ce9ad7f6b0ea92f36bf30e0dd48a = $(`&lt;div id=&quot;html_78a3ce9ad7f6b0ea92f36bf30e0dd48a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_561c9014441ad931c3cf8fc579eca3ca.setContent(html_78a3ce9ad7f6b0ea92f36bf30e0dd48a);
#
#
#
#         marker_f3a166c42cf2410c5a1caf5390f18a13.bindPopup(popup_561c9014441ad931c3cf8fc579eca3ca)
#         ;
#
#
#
#
#             var marker_c9e0cb2d1dc1c53d5a993a10abc71a08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3ac4a06d34fb4d3825930b7243bcbe92);
#
#
#         var popup_626a14edc72e4533af5aacd92dd6f2b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c703fe003040a8dbd30c405f643cb720 = $(`&lt;div id=&quot;html_c703fe003040a8dbd30c405f643cb720&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_626a14edc72e4533af5aacd92dd6f2b6.setContent(html_c703fe003040a8dbd30c405f643cb720);
#
#
#
#         marker_c9e0cb2d1dc1c53d5a993a10abc71a08.bindPopup(popup_626a14edc72e4533af5aacd92dd6f2b6)
#         ;
#
#
#
#
#             var marker_f618983c6aad9d50aaaa7abe23cae66b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3ac4a06d34fb4d3825930b7243bcbe92);
#
#
#         var popup_71d4abe603a41a8943e17efc9c8c25d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd277da19a9d3a6b2112470ae8112247 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd277da19a9d3a6b2112470ae8112247&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd277da19a9d3a6b2112470ae8112247 = L.map(
#                 &quot;map_fd277da19a9d3a6b2112470ae8112247&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a89368ad4e2e098f5158d5e2209c726 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a89368ad4e2e098f5158d5e2209c726.addTo(map_fd277da19a9d3a6b2112470ae8112247);
#
#
#             var feature_group_af1acee5fba385bf8f52dd792df356b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_af1acee5fba385bf8f52dd792df356b4.addTo(map_fd277da19a9d3a6b2112470ae8112247);
#
#
#             var feature_group_sub_group_4f79c312db079ff8e0df98a4bd1cb56b = L.featureGroup.subGroup(
#                 feature_group_af1acee5fba385bf8f52dd792df356b4
#             );
#
#
#             var marker_9701eaba9eafa417f35aa4efab37b7f5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f79c312db079ff8e0df98a4bd1cb56b);
#
#
#         var popup_7468bbf8b580ebde081f0394bdd83031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23134dedf204631455ce308d3e8cc523 = $(`&lt;div id=&quot;html_23134dedf204631455ce308d3e8cc523&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7468bbf8b580ebde081f0394bdd83031.setContent(html_23134dedf204631455ce308d3e8cc523);
#
#
#
#         marker_9701eaba9eafa417f35aa4efab37b7f5.bindPopup(popup_7468bbf8b580ebde081f0394bdd83031)
#         ;
#
#
#
#
#             var marker_c85d96830a2d945aa82a9683b5095ba5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f79c312db079ff8e0df98a4bd1cb56b);
#
#
#         var popup_47a0afe99d520da0f39afce3909ead99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e9cadbeadbff2017a43910276263a7 = $(`&lt;div id=&quot;html_04e9cadbeadbff2017a43910276263a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_47a0afe99d520da0f39afce3909ead99.setContent(html_04e9cadbeadbff2017a43910276263a7);
#
#
#
#         marker_c85d96830a2d945aa82a9683b5095ba5.bindPopup(popup_47a0afe99d520da0f39afce3909ead99)
#         ;
#
#
#
#
#             var marker_b70584ae10db12e321ba7812f3c025b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f79c312db079ff8e0df98a4bd1cb56b);
#
#
#         var popup_fb0b1ee1c416bb19b3b8a4759b7cc7b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92303aa40f3d62ec97e8f9c6ba6a3988 = $(`&lt;div id=&quot;html_92303aa40f3d62ec97e8f9c6ba6a3988&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fb0b1ee1c416bb19b3b8a4759b7cc7b5.setContent(html_92303aa40f3d62ec97e8f9c6ba6a3988);
#
#
#
#         marker_b70584ae10db12e321ba7812f3c025b4.bindPopup(popup_fb0b1ee1c416bb19b3b8a4759b7cc7b5)
#         ;
#
#
#
#
#             var marker_6a92438952cd5771a2d91089694822f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f79c312db079ff8e0df98a4bd1cb56b);
#
#
#         var popup_d40c1f1abad517459bf9baf6a1a158fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f73fe55ac39c2e4a63bc270cd94076e2 = $(`&lt;div id=&quot;html_f73fe55ac39c2e4a63bc270cd94076e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d40c1f1abad517459bf9baf6a1a158fe.setContent(html_f73fe55ac39c2e4a63bc270cd94076e2);
#
#
#
#         marker_
