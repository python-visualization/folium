# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dd77e0ba6c13b75a2ebaadf0aa2882f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dd77e0ba6c13b75a2ebaadf0aa2882f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dd77e0ba6c13b75a2ebaadf0aa2882f = L.map(
#                 &quot;map_0dd77e0ba6c13b75a2ebaadf0aa2882f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28abde49a0ac44dd808e6f70baa8c8a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28abde49a0ac44dd808e6f70baa8c8a8.addTo(map_0dd77e0ba6c13b75a2ebaadf0aa2882f);
#
#
#             var marker_7e2560667addac4c8a2bacf5050473c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0dd77e0ba6c13b75a2ebaadf0aa2882f);
#
#
#         var popup_e35311c731573356a63de029d649813d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98975e15cd3b2d2046cb59cd5169cf38 = $(`&lt;div id=&quot;html_98975e15cd3b2d2046cb59cd5169cf38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e35311c731573356a63de029d649813d.setContent(html_98975e15cd3b2d2046cb59cd5169cf38);
#
#
#
#         marker_7e2560667addac4c8a2bacf5050473c7.bindPopup(popup_e35311c731573356a63de029d649813d)
#         ;
#
#
#
#
#             var marker_b5b31e260be618bc938b3fc730bfa949 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0dd77e0ba6c13b75a2ebaadf0aa2882f);
#
#
#         var popup_97be1a0ef830cee35940b0018d931f6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99a325f321ed6cb9eeeacb44a30b633f = $(`&lt;div id=&quot;html_99a325f321ed6cb9eeeacb44a30b633f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_97be1a0ef830cee35940b0018d931f6a.setContent(html_99a325f321ed6cb9eeeacb44a30b633f);
#
#
#
#         marker_b5b31e260be618bc938b3fc730bfa949.bindPopup(popup_97be1a0ef830cee35940b0018d931f6a)
#         ;
#
#
#
#
#             var marker_c5ae2d53bf612832673c91751d66d6fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0dd77e0ba6c13b75a2ebaadf0aa2882f);
#
#
#         var popup_80ca330605e68b8ae20a72056eedbbcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_644fc0e2b9275bad33eeb17efac56144 = $(`&lt;div id=&quot;html_644fc0e2b9275bad33eeb17efac56144&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_80ca330605e68b8ae20a72056eedbbcb.setContent(html_644fc0e2b9275bad33eeb17efac56144);
#
#
#
#         marker_c5ae2d53bf612832673c91751d66d6fb.bindPopup(popup_80ca330605e68b8ae20a72056eedbbcb)
#         ;
#
#
#
#
#             var marker_bd3cd83b13ed830dd0a39953af037840 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0dd77e0ba6c13b75a2ebaadf0aa2882f);
#
#
#         var popup_8ea289b2ca242aa3ba2fc979c28dd520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c925ede905d12be9d16733e4bc51b86 = $(`&lt;div id=&quot;html_5c925ede905d12be9d16733e4bc51b86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8ea289b2ca242aa3ba2fc979c28dd520.setContent(html_5c925ede905d12be9d16733e4bc51b86);
#
#
#
#         marker_bd3cd83b13ed830dd0a39953af037840.bindPopup(popup_8ea289b2ca242aa3ba2fc979c28dd520)
#         ;
#
#
#
#
#             var marker_f6b011f3975be3af38e0fc15fb95c730 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0dd77e0ba6c13b75a2ebaadf0aa2882f);
#
#
#         var popup_230da379a4756a27429584507967a54b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca3be67b6219b791bc426bd273ffa338 = $(`&lt;div id=&quot;html_ca3be67b6219b791bc426bd273ffa338&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_230da379a4756a27429584507967a54b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7703e198adb568955d717573bd90f6f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7703e198adb568955d717573bd90f6f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7703e198adb568955d717573bd90f6f8 = L.map(
#                 &quot;map_7703e198adb568955d717573bd90f6f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48aad18262578bdfc589da6a0275f5ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48aad18262578bdfc589da6a0275f5ee.addTo(map_7703e198adb568955d717573bd90f6f8);
#
#
#             var feature_group_4519c8f8ce54ddc907f24d519677effe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4e9a6816efcd87c53e4ffacc1b442ea4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4519c8f8ce54ddc907f24d519677effe);
#
#
#         var popup_2fe2c4f3e0710d2659b3ee89d38bb2a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b944cd422f3a6a48ac4c3626b8cee3f5 = $(`&lt;div id=&quot;html_b944cd422f3a6a48ac4c3626b8cee3f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2fe2c4f3e0710d2659b3ee89d38bb2a0.setContent(html_b944cd422f3a6a48ac4c3626b8cee3f5);
#
#
#
#         marker_4e9a6816efcd87c53e4ffacc1b442ea4.bindPopup(popup_2fe2c4f3e0710d2659b3ee89d38bb2a0)
#         ;
#
#
#
#
#             var marker_ae44ef410a66225bd113d44611258f5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4519c8f8ce54ddc907f24d519677effe);
#
#
#         var popup_c06eee0bd69ab9a2cf3e3c21f3ea1cf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ad68c1703ca356138cde3ba98197e59 = $(`&lt;div id=&quot;html_5ad68c1703ca356138cde3ba98197e59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c06eee0bd69ab9a2cf3e3c21f3ea1cf9.setContent(html_5ad68c1703ca356138cde3ba98197e59);
#
#
#
#         marker_ae44ef410a66225bd113d44611258f5d.bindPopup(popup_c06eee0bd69ab9a2cf3e3c21f3ea1cf9)
#         ;
#
#
#
#
#             var marker_c73c3b7ac963bb489ea6199d6fbe8b1a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4519c8f8ce54ddc907f24d519677effe);
#
#
#         var popup_500902a22f0dc34fe62d39a7dee04456 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4a03a205e3b7907fb08f47ed80348ae = $(`&lt;div id=&quot;html_c4a03a205e3b7907fb08f47ed80348ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_500902a22f0dc34fe62d39a7dee04456.setContent(html_c4a03a205e3b7907fb08f47ed80348ae);
#
#
#
#         marker_c73c3b7ac963bb489ea6199d6fbe8b1a.bindPopup(popup_500902a22f0dc34fe62d39a7dee04456)
#         ;
#
#
#
#
#             var marker_9302ce0e6d7853bea4f5c5cf35321498 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4519c8f8ce54ddc907f24d519677effe);
#
#
#         var popup_3c5645737ccc92b61e2038b87f781755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d5b9ca8538c8328b1c77b648e5c3f77 = $(`&lt;div id=&quot;html_9d5b9ca8538c8328b1c77b648e5c3f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c5645737ccc92b61e2038b87f781755.setContent(html_9d5b9ca8538c8328b1c77b648e5c3f77);
#
#
#
#         marker_9302ce0e6d7853bea4f5c5cf35321498.bindPopup(popup_3c5645737ccc92b61e2038b87f781755)
#         ;
#
#
#
#
#             var marker_16801bc43d79b99ac580ebb9f80cefa6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4519c8f8ce54ddc907f24d519677effe);
#
#
#         var popup_1c0161a2741b0f5c9565fc121e6718f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ef3ee90749be2702e6b9f9949503ddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ef3ee90749be2702e6b9f9949503ddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ef3ee90749be2702e6b9f9949503ddd = L.map(
#                 &quot;map_1ef3ee90749be2702e6b9f9949503ddd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83404bf48c3543a370c30437d7843ac8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83404bf48c3543a370c30437d7843ac8.addTo(map_1ef3ee90749be2702e6b9f9949503ddd);
#
#
#             var feature_group_b5e547c36b69c48607a79943d9c580a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b5e547c36b69c48607a79943d9c580a2.addTo(map_1ef3ee90749be2702e6b9f9949503ddd);
#
#
#             var feature_group_sub_group_623a2c1ba65063df0e8922632692287c = L.featureGroup.subGroup(
#                 feature_group_b5e547c36b69c48607a79943d9c580a2
#             );
#
#
#             var marker_c128c18b7b96098153c377be3c17e0c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_623a2c1ba65063df0e8922632692287c);
#
#
#         var popup_0b70cd01b84d27dbf2e0d6be37d59041 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73d32beeef34eab5312a64a038834dbc = $(`&lt;div id=&quot;html_73d32beeef34eab5312a64a038834dbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0b70cd01b84d27dbf2e0d6be37d59041.setContent(html_73d32beeef34eab5312a64a038834dbc);
#
#
#
#         marker_c128c18b7b96098153c377be3c17e0c3.bindPopup(popup_0b70cd01b84d27dbf2e0d6be37d59041)
#         ;
#
#
#
#
#             var marker_6b60b49137c38727c7e2f56349183854 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_623a2c1ba65063df0e8922632692287c);
#
#
#         var popup_49614fe9c40158d6243405bf41eb6575 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbbfe73101cc369359c6641653eeadd1 = $(`&lt;div id=&quot;html_bbbfe73101cc369359c6641653eeadd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_49614fe9c40158d6243405bf41eb6575.setContent(html_bbbfe73101cc369359c6641653eeadd1);
#
#
#
#         marker_6b60b49137c38727c7e2f56349183854.bindPopup(popup_49614fe9c40158d6243405bf41eb6575)
#         ;
#
#
#
#
#             var marker_d8d9f49d88d2109dc8eddba04acb3eb1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_623a2c1ba65063df0e8922632692287c);
#
#
#         var popup_376a8369c157db7e9fcbb3811ca12ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70546e7ba557ceaf9fe30a207c66d1ef = $(`&lt;div id=&quot;html_70546e7ba557ceaf9fe30a207c66d1ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_376a8369c157db7e9fcbb3811ca12ac1.setContent(html_70546e7ba557ceaf9fe30a207c66d1ef);
#
#
#
#         marker_d8d9f49d88d2109dc8eddba04acb3eb1.bindPopup(popup_376a8369c157db7e9fcbb3811ca12ac1)
#         ;
#
#
#
#
#             var marker_4df878005b3ffdebc685c57288c3369b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_623a2c1ba65063df0e8922632692287c);
#
#
#         var popup_dd65f33c685bab106b2d91e939dfbb75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27794ef0f70f500ca434ec61a5ac1ebd = $(`&lt;div id=&quot;html_27794ef0f70f500ca434ec61a5ac1ebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dd65f33c685bab106b2d91e939dfbb75.setContent(html_27794ef0f70f500ca434ec61a5ac1ebd);
#
#
#
#         marker_
