# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3ed4dca514ce12ca4134b8d281c930e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3ed4dca514ce12ca4134b8d281c930e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3ed4dca514ce12ca4134b8d281c930e = L.map(
#                 &quot;map_a3ed4dca514ce12ca4134b8d281c930e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8aa66e785f5c7027d6f95ec113226df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8aa66e785f5c7027d6f95ec113226df.addTo(map_a3ed4dca514ce12ca4134b8d281c930e);
#
#
#             var marker_1025a3eeacfdc3c3a85cd9aea920dba1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a3ed4dca514ce12ca4134b8d281c930e);
#
#
#         var popup_c76f26f8b70f252c651b6ba2e18291f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a00855ba9023d302cf67dbc981f26c4 = $(`&lt;div id=&quot;html_8a00855ba9023d302cf67dbc981f26c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c76f26f8b70f252c651b6ba2e18291f8.setContent(html_8a00855ba9023d302cf67dbc981f26c4);
#
#
#
#         marker_1025a3eeacfdc3c3a85cd9aea920dba1.bindPopup(popup_c76f26f8b70f252c651b6ba2e18291f8)
#         ;
#
#
#
#
#             var marker_70090ce4e20cb6c43e713370dc7cc363 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a3ed4dca514ce12ca4134b8d281c930e);
#
#
#         var popup_073b2c4432fe4723713e0d6b0a4241fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_746111485287c7ef4b078371b2567095 = $(`&lt;div id=&quot;html_746111485287c7ef4b078371b2567095&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_073b2c4432fe4723713e0d6b0a4241fe.setContent(html_746111485287c7ef4b078371b2567095);
#
#
#
#         marker_70090ce4e20cb6c43e713370dc7cc363.bindPopup(popup_073b2c4432fe4723713e0d6b0a4241fe)
#         ;
#
#
#
#
#             var marker_bde1f889d736036992099bb9d23b5e46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a3ed4dca514ce12ca4134b8d281c930e);
#
#
#         var popup_2387f151ddd23aaafd1189360beccc96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36075c6a66e47c310819033afc63ccb4 = $(`&lt;div id=&quot;html_36075c6a66e47c310819033afc63ccb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2387f151ddd23aaafd1189360beccc96.setContent(html_36075c6a66e47c310819033afc63ccb4);
#
#
#
#         marker_bde1f889d736036992099bb9d23b5e46.bindPopup(popup_2387f151ddd23aaafd1189360beccc96)
#         ;
#
#
#
#
#             var marker_c0f338b11db5b28cc42b90f4850cdcaf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a3ed4dca514ce12ca4134b8d281c930e);
#
#
#         var popup_18936fb706b1e95b8500357328a7841d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33b18c06cf67aa1ac97bcb2c775fcf32 = $(`&lt;div id=&quot;html_33b18c06cf67aa1ac97bcb2c775fcf32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18936fb706b1e95b8500357328a7841d.setContent(html_33b18c06cf67aa1ac97bcb2c775fcf32);
#
#
#
#         marker_c0f338b11db5b28cc42b90f4850cdcaf.bindPopup(popup_18936fb706b1e95b8500357328a7841d)
#         ;
#
#
#
#
#             var marker_f600ee2e5e8dd8053d785cd7b3a179af = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a3ed4dca514ce12ca4134b8d281c930e);
#
#
#         var popup_8d7da0fff52061c46f9e5130fa9e33de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89481490d22d6c87828121c97815973c = $(`&lt;div id=&quot;html_89481490d22d6c87828121c97815973c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8d7da0fff52061c46f9e5130fa9e33de.setContent(html_89481490d22d6c87828121c97815973c);
#
#
#
#         marker_f600ee2e5e8dd8053d785cd7b3a179af.bindPopup(popup_8d7da0fff52061c46f9e5130fa9e33de)
#         ;
#
#
#
#
#             var marker_044542627c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2cf900efae4797d9a63079bee9e0e59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2cf900efae4797d9a63079bee9e0e59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2cf900efae4797d9a63079bee9e0e59 = L.map(
#                 &quot;map_e2cf900efae4797d9a63079bee9e0e59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed58ef4e1d96b67af41c71642a552abf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed58ef4e1d96b67af41c71642a552abf.addTo(map_e2cf900efae4797d9a63079bee9e0e59);
#
#
#             var feature_group_4e8f07e27fbf45e8b982cb9d643124b9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ce0764e5067fe245e4791cbf54bc608b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4e8f07e27fbf45e8b982cb9d643124b9);
#
#
#         var popup_74ef60aed7926f249b19ef003650722d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_795497df66365c267448831d8fdf58f3 = $(`&lt;div id=&quot;html_795497df66365c267448831d8fdf58f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_74ef60aed7926f249b19ef003650722d.setContent(html_795497df66365c267448831d8fdf58f3);
#
#
#
#         marker_ce0764e5067fe245e4791cbf54bc608b.bindPopup(popup_74ef60aed7926f249b19ef003650722d)
#         ;
#
#
#
#
#             var marker_64d9c31a47da7da9d63fd99785f4d43b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4e8f07e27fbf45e8b982cb9d643124b9);
#
#
#         var popup_c410896c0faaef8be82a0eab5d4c1402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1fd75cec8ec867a465b2ffbcfde7b21 = $(`&lt;div id=&quot;html_c1fd75cec8ec867a465b2ffbcfde7b21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c410896c0faaef8be82a0eab5d4c1402.setContent(html_c1fd75cec8ec867a465b2ffbcfde7b21);
#
#
#
#         marker_64d9c31a47da7da9d63fd99785f4d43b.bindPopup(popup_c410896c0faaef8be82a0eab5d4c1402)
#         ;
#
#
#
#
#             var marker_f2fad86513620600fadc4ef2c9e5db98 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4e8f07e27fbf45e8b982cb9d643124b9);
#
#
#         var popup_f95ca5e081eefbe4991b80b72e9e26b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a69bf50a33da107d909edb5415e81308 = $(`&lt;div id=&quot;html_a69bf50a33da107d909edb5415e81308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f95ca5e081eefbe4991b80b72e9e26b1.setContent(html_a69bf50a33da107d909edb5415e81308);
#
#
#
#         marker_f2fad86513620600fadc4ef2c9e5db98.bindPopup(popup_f95ca5e081eefbe4991b80b72e9e26b1)
#         ;
#
#
#
#
#             var marker_d7645218fc526bb0d82a577ee29fe35f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4e8f07e27fbf45e8b982cb9d643124b9);
#
#
#         var popup_8a3dfcc0d192540876bb07f94309aac6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6845e4d4b93bc2753e21a2d9a678f1d4 = $(`&lt;div id=&quot;html_6845e4d4b93bc2753e21a2d9a678f1d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8a3dfcc0d192540876bb07f94309aac6.setContent(html_6845e4d4b93bc2753e21a2d9a678f1d4);
#
#
#
#         marker_d7645218fc526bb0d82a577ee29fe35f.bindPopup(popup_8a3dfcc0d192540876bb07f94309aac6)
#         ;
#
#
#
#
#             var marker_499e9c5fc893a50928ae7f365e723d6e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4e8f07e27fbf45e8b982cb9d643124b9);
#
#
#         var popup_ab1f048eae1287715f920743ca6cb037 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5614729582fc31881ed1927babe4f4f7 = $(`&lt;div id=&quot;html_5614729582fc31881ed1927babe4f4f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_ab1f048eae1287715f

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76a293c90fc8059c5afe697620e92751 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76a293c90fc8059c5afe697620e92751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76a293c90fc8059c5afe697620e92751 = L.map(
#                 &quot;map_76a293c90fc8059c5afe697620e92751&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2d02f3b5ebf885ad2cbcd18087f2568 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2d02f3b5ebf885ad2cbcd18087f2568.addTo(map_76a293c90fc8059c5afe697620e92751);
#
#
#             var feature_group_8e300ae5e7faea2dfc7f34229be87cc4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8e300ae5e7faea2dfc7f34229be87cc4.addTo(map_76a293c90fc8059c5afe697620e92751);
#
#
#             var feature_group_sub_group_81c5321e8bd3ac248e3c5ee2b8bec255 = L.featureGroup.subGroup(
#                 feature_group_8e300ae5e7faea2dfc7f34229be87cc4
#             );
#
#
#             var marker_bde5e57c42c676a57c20cd5f92025c00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_81c5321e8bd3ac248e3c5ee2b8bec255);
#
#
#         var popup_74899bfe5df68087aa07fe4195be2af6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e352182439e9d3d5c6e44c3fdb6d543 = $(`&lt;div id=&quot;html_3e352182439e9d3d5c6e44c3fdb6d543&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_74899bfe5df68087aa07fe4195be2af6.setContent(html_3e352182439e9d3d5c6e44c3fdb6d543);
#
#
#
#         marker_bde5e57c42c676a57c20cd5f92025c00.bindPopup(popup_74899bfe5df68087aa07fe4195be2af6)
#         ;
#
#
#
#
#             var marker_b32dad41cb36af7196ee0d9da6c88099 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_81c5321e8bd3ac248e3c5ee2b8bec255);
#
#
#         var popup_7bdc766994055466a60d6f22c74af0f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c6bb62f76d589e88ad572d58a8f1317 = $(`&lt;div id=&quot;html_2c6bb62f76d589e88ad572d58a8f1317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7bdc766994055466a60d6f22c74af0f6.setContent(html_2c6bb62f76d589e88ad572d58a8f1317);
#
#
#
#         marker_b32dad41cb36af7196ee0d9da6c88099.bindPopup(popup_7bdc766994055466a60d6f22c74af0f6)
#         ;
#
#
#
#
#             var marker_98c607f952b2143d95a31e86067fcdca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_81c5321e8bd3ac248e3c5ee2b8bec255);
#
#
#         var popup_10b6f5a306da21899722ad6d09033f49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8041b450cd5b990bf8ce619526501ed6 = $(`&lt;div id=&quot;html_8041b450cd5b990bf8ce619526501ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_10b6f5a306da21899722ad6d09033f49.setContent(html_8041b450cd5b990bf8ce619526501ed6);
#
#
#
#         marker_98c607f952b2143d95a31e86067fcdca.bindPopup(popup_10b6f5a306da21899722ad6d09033f49)
#         ;
#
#
#
#
#             var marker_a0bd3fbe0756c1cda9929690252a1a7b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_81c5321e8bd3ac248e3c5ee2b8bec255);
#
#
#         var popup_458dafc3033f631d8c19897710739a5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a6670d7378b1175a4dff1db9e1cce46 = $(`&lt;div id=&quot;html_8a6670d7378b1175a4dff1db9e1cce46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_458dafc3033f631d8c19897710739a5a.setContent(html_8a6670d7378b1175a4dff1db9e1cce46);
#
#
#
#         marker_a0bd3fbe0756c1cda9929690252a1a7b.bindPopup(popup_458dafc3033f631d8c19897710739a5a)
#         ;
#
#
#
#
#             var marker_ac13ec6845b5bff87211fed87f2a1956 = L.marker(
#                 [45.050399999999996, 3.0504],
