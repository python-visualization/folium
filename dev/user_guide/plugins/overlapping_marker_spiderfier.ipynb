# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f08e6d144469d7a85c54d4c2e81c4da0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f08e6d144469d7a85c54d4c2e81c4da0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f08e6d144469d7a85c54d4c2e81c4da0 = L.map(
#                 &quot;map_f08e6d144469d7a85c54d4c2e81c4da0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e16b1d39981d26e176b3f5d19ad9198 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e16b1d39981d26e176b3f5d19ad9198.addTo(map_f08e6d144469d7a85c54d4c2e81c4da0);
#
#
#             var marker_2c7ce02946d183a87a2358c45cc390db = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f08e6d144469d7a85c54d4c2e81c4da0);
#
#
#         var popup_73db49918d0a398c3fe62101d9f4b236 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ebc5a27772e482fbac049ee75b354e3 = $(`&lt;div id=&quot;html_3ebc5a27772e482fbac049ee75b354e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_73db49918d0a398c3fe62101d9f4b236.setContent(html_3ebc5a27772e482fbac049ee75b354e3);
#
#
#
#         marker_2c7ce02946d183a87a2358c45cc390db.bindPopup(popup_73db49918d0a398c3fe62101d9f4b236)
#         ;
#
#
#
#
#             var marker_f2ffb88cc5b6801e972e14bca29b8c78 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f08e6d144469d7a85c54d4c2e81c4da0);
#
#
#         var popup_ffcae27e7bb8772fb9db21a87af38c73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2a9ee4df7567596e8933bc852a50b43 = $(`&lt;div id=&quot;html_a2a9ee4df7567596e8933bc852a50b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ffcae27e7bb8772fb9db21a87af38c73.setContent(html_a2a9ee4df7567596e8933bc852a50b43);
#
#
#
#         marker_f2ffb88cc5b6801e972e14bca29b8c78.bindPopup(popup_ffcae27e7bb8772fb9db21a87af38c73)
#         ;
#
#
#
#
#             var marker_e4fd70f757cfd2df9f0924bf52cf0dfb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f08e6d144469d7a85c54d4c2e81c4da0);
#
#
#         var popup_6f11275454e2c9b7d7dc9b9e326e0727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb3b441b7ed344c2b4129257f06378ba = $(`&lt;div id=&quot;html_bb3b441b7ed344c2b4129257f06378ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6f11275454e2c9b7d7dc9b9e326e0727.setContent(html_bb3b441b7ed344c2b4129257f06378ba);
#
#
#
#         marker_e4fd70f757cfd2df9f0924bf52cf0dfb.bindPopup(popup_6f11275454e2c9b7d7dc9b9e326e0727)
#         ;
#
#
#
#
#             var marker_352ee71f5c24513ca5519b2fe5c08e0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f08e6d144469d7a85c54d4c2e81c4da0);
#
#
#         var popup_30872c2f8b5085e5d44248d0529933f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_752ed7007c19ea70815f0bef190b7a39 = $(`&lt;div id=&quot;html_752ed7007c19ea70815f0bef190b7a39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_30872c2f8b5085e5d44248d0529933f4.setContent(html_752ed7007c19ea70815f0bef190b7a39);
#
#
#
#         marker_352ee71f5c24513ca5519b2fe5c08e0a.bindPopup(popup_30872c2f8b5085e5d44248d0529933f4)
#         ;
#
#
#
#
#             var marker_726c0691d7690acbacdb8f264f0971f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f08e6d144469d7a85c54d4c2e81c4da0);
#
#
#         var popup_b31823f615436c30b7a5fece72809637 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94bec627a7174be5b204a6e30ed5257b = $(`&lt;div id=&quot;html_94bec627a7174be5b204a6e30ed5257b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b31823f615436c30b7a5fece728096

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d2c442492fbe14e395bfa8e5b6b06ff {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d2c442492fbe14e395bfa8e5b6b06ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d2c442492fbe14e395bfa8e5b6b06ff = L.map(
#                 &quot;map_7d2c442492fbe14e395bfa8e5b6b06ff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d80c8ed18d458167a103a03643e8d640 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d80c8ed18d458167a103a03643e8d640.addTo(map_7d2c442492fbe14e395bfa8e5b6b06ff);
#
#
#             var feature_group_3722523dc5472ffcb9b44f1cce469cc0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_84638e19fad454d79f50c73062b5eb24 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3722523dc5472ffcb9b44f1cce469cc0);
#
#
#         var popup_2e91cfb1d231dc94ecf204ea03bf85a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdb6fc0111e15b0ebb034ab7757efe6e = $(`&lt;div id=&quot;html_bdb6fc0111e15b0ebb034ab7757efe6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2e91cfb1d231dc94ecf204ea03bf85a9.setContent(html_bdb6fc0111e15b0ebb034ab7757efe6e);
#
#
#
#         marker_84638e19fad454d79f50c73062b5eb24.bindPopup(popup_2e91cfb1d231dc94ecf204ea03bf85a9)
#         ;
#
#
#
#
#             var marker_10632c9d62afe0625026398892fce820 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3722523dc5472ffcb9b44f1cce469cc0);
#
#
#         var popup_69505cb292e860399d062f84502923b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1c22e05be43900a0233a24cbffb32ac = $(`&lt;div id=&quot;html_b1c22e05be43900a0233a24cbffb32ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_69505cb292e860399d062f84502923b9.setContent(html_b1c22e05be43900a0233a24cbffb32ac);
#
#
#
#         marker_10632c9d62afe0625026398892fce820.bindPopup(popup_69505cb292e860399d062f84502923b9)
#         ;
#
#
#
#
#             var marker_27bdeb1735369f3e5c231b080278ee75 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3722523dc5472ffcb9b44f1cce469cc0);
#
#
#         var popup_06d02786f02a015c63b18fd0df6b0a0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df379fb5d5ea45fe8e7509d6dc9e8d3f = $(`&lt;div id=&quot;html_df379fb5d5ea45fe8e7509d6dc9e8d3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_06d02786f02a015c63b18fd0df6b0a0a.setContent(html_df379fb5d5ea45fe8e7509d6dc9e8d3f);
#
#
#
#         marker_27bdeb1735369f3e5c231b080278ee75.bindPopup(popup_06d02786f02a015c63b18fd0df6b0a0a)
#         ;
#
#
#
#
#             var marker_b832df45a8015f27ce3f7fe6381d655c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3722523dc5472ffcb9b44f1cce469cc0);
#
#
#         var popup_e69d591a0f211b7f9102ad4f7ede3b03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c922cd0c979ce6bf9b82afdcc7268200 = $(`&lt;div id=&quot;html_c922cd0c979ce6bf9b82afdcc7268200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e69d591a0f211b7f9102ad4f7ede3b03.setContent(html_c922cd0c979ce6bf9b82afdcc7268200);
#
#
#
#         marker_b832df45a8015f27ce3f7fe6381d655c.bindPopup(popup_e69d591a0f211b7f9102ad4f7ede3b03)
#         ;
#
#
#
#
#             var marker_63dddee737c28ac7f8eb3e7a2e40b1e6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3722523dc5472ffcb9b44f1cce469cc0);
#
#
#         var popup_c071387c442ae61fc6cc611bbaf9b2d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fba25ce53c920edc8fcc9ce1c3d57f1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fba25ce53c920edc8fcc9ce1c3d57f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fba25ce53c920edc8fcc9ce1c3d57f1 = L.map(
#                 &quot;map_0fba25ce53c920edc8fcc9ce1c3d57f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_488a112fb39e316def456720be425ec5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_488a112fb39e316def456720be425ec5.addTo(map_0fba25ce53c920edc8fcc9ce1c3d57f1);
#
#
#             var feature_group_b180d51f5c668dde8e27c688efb371c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b180d51f5c668dde8e27c688efb371c7.addTo(map_0fba25ce53c920edc8fcc9ce1c3d57f1);
#
#
#             var feature_group_sub_group_dc37d70aca6ec58bee1ad39a29b65476 = L.featureGroup.subGroup(
#                 feature_group_b180d51f5c668dde8e27c688efb371c7
#             );
#
#
#             var marker_e06e06ab2ad6e4fb3ec817cb7c99bf68 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc37d70aca6ec58bee1ad39a29b65476);
#
#
#         var popup_578a3c2ea136f49d2dc96a4d215aaaf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c545a25b8fe9554be316bfb079fb7339 = $(`&lt;div id=&quot;html_c545a25b8fe9554be316bfb079fb7339&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_578a3c2ea136f49d2dc96a4d215aaaf9.setContent(html_c545a25b8fe9554be316bfb079fb7339);
#
#
#
#         marker_e06e06ab2ad6e4fb3ec817cb7c99bf68.bindPopup(popup_578a3c2ea136f49d2dc96a4d215aaaf9)
#         ;
#
#
#
#
#             var marker_03161f16ad67d29ad749b4c450892890 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc37d70aca6ec58bee1ad39a29b65476);
#
#
#         var popup_9b58a7c0f3d65ffe1ef9775ab1724512 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ba0b2a025a7f04c073d284de0e07bc3 = $(`&lt;div id=&quot;html_0ba0b2a025a7f04c073d284de0e07bc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9b58a7c0f3d65ffe1ef9775ab1724512.setContent(html_0ba0b2a025a7f04c073d284de0e07bc3);
#
#
#
#         marker_03161f16ad67d29ad749b4c450892890.bindPopup(popup_9b58a7c0f3d65ffe1ef9775ab1724512)
#         ;
#
#
#
#
#             var marker_4951b6e2db8422cc5a7ea9aa3c2a8340 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc37d70aca6ec58bee1ad39a29b65476);
#
#
#         var popup_87a80effd481a159f56758f845eb820f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4300a8bc4ec3b66e6e5cf4b448d59403 = $(`&lt;div id=&quot;html_4300a8bc4ec3b66e6e5cf4b448d59403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_87a80effd481a159f56758f845eb820f.setContent(html_4300a8bc4ec3b66e6e5cf4b448d59403);
#
#
#
#         marker_4951b6e2db8422cc5a7ea9aa3c2a8340.bindPopup(popup_87a80effd481a159f56758f845eb820f)
#         ;
#
#
#
#
#             var marker_020d9040fcf9488daa4fbe39eef66751 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc37d70aca6ec58bee1ad39a29b65476);
#
#
#         var popup_8ef3158d7ef3ad0d92ec59652d4a6afc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0769baf0e17a001ec423b9bb7fed075 = $(`&lt;div id=&quot;html_d0769baf0e17a001ec423b9bb7fed075&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8ef3158d7ef3ad0d92ec59652d4a6afc.setContent(html_d0769baf0e17a001ec423b9bb7fed075);
#
#
#
#         mark
