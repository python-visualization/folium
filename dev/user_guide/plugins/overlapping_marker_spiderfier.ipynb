# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75427efe46f2820441a24cd64699979d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75427efe46f2820441a24cd64699979d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75427efe46f2820441a24cd64699979d = L.map(
#                 &quot;map_75427efe46f2820441a24cd64699979d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03187b3de6b59644636ad38640474c20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03187b3de6b59644636ad38640474c20.addTo(map_75427efe46f2820441a24cd64699979d);
#
#
#             var marker_a52f703a9a05093e0a813637b58ca20b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_75427efe46f2820441a24cd64699979d);
#
#
#         var popup_ced9a6131d8a385497776d7c3b410061 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f643a731d2cf8dec3cfdeab24c4d627d = $(`&lt;div id=&quot;html_f643a731d2cf8dec3cfdeab24c4d627d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ced9a6131d8a385497776d7c3b410061.setContent(html_f643a731d2cf8dec3cfdeab24c4d627d);
#
#
#
#         marker_a52f703a9a05093e0a813637b58ca20b.bindPopup(popup_ced9a6131d8a385497776d7c3b410061)
#         ;
#
#
#
#
#             var marker_174627f5fee3efc926842acded8cc7b1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_75427efe46f2820441a24cd64699979d);
#
#
#         var popup_8a6a5d1be634907560dcbed4d4a57abe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4991ad0233799597bcbd2a0008af52e = $(`&lt;div id=&quot;html_e4991ad0233799597bcbd2a0008af52e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8a6a5d1be634907560dcbed4d4a57abe.setContent(html_e4991ad0233799597bcbd2a0008af52e);
#
#
#
#         marker_174627f5fee3efc926842acded8cc7b1.bindPopup(popup_8a6a5d1be634907560dcbed4d4a57abe)
#         ;
#
#
#
#
#             var marker_0aefcd39f56ac7048ff0955efd0a009b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_75427efe46f2820441a24cd64699979d);
#
#
#         var popup_cfdc5b8b44d9400c7100c7258df922de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b379e81688bac819867b35f5d2693687 = $(`&lt;div id=&quot;html_b379e81688bac819867b35f5d2693687&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cfdc5b8b44d9400c7100c7258df922de.setContent(html_b379e81688bac819867b35f5d2693687);
#
#
#
#         marker_0aefcd39f56ac7048ff0955efd0a009b.bindPopup(popup_cfdc5b8b44d9400c7100c7258df922de)
#         ;
#
#
#
#
#             var marker_ef2e47a746613f33082688757e26c423 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_75427efe46f2820441a24cd64699979d);
#
#
#         var popup_902aa871ee5eab95e4cb273e1f7c4837 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55ee058e415245da3d191a857469ce22 = $(`&lt;div id=&quot;html_55ee058e415245da3d191a857469ce22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_902aa871ee5eab95e4cb273e1f7c4837.setContent(html_55ee058e415245da3d191a857469ce22);
#
#
#
#         marker_ef2e47a746613f33082688757e26c423.bindPopup(popup_902aa871ee5eab95e4cb273e1f7c4837)
#         ;
#
#
#
#
#             var marker_cf11a9548c4eb59047788f55632183c9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_75427efe46f2820441a24cd64699979d);
#
#
#         var popup_81f6764103e63fd1c48dc62a71cbdd8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0813c79921e69337a104ce9a2e5d2377 = $(`&lt;div id=&quot;html_0813c79921e69337a104ce9a2e5d2377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_81f6764103e63fd1c48dc62a71cbdd8d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff857ddde6b1f30c4e72b6f0d0648306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff857ddde6b1f30c4e72b6f0d0648306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff857ddde6b1f30c4e72b6f0d0648306 = L.map(
#                 &quot;map_ff857ddde6b1f30c4e72b6f0d0648306&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe96c6088a485e186c37acd4cade074b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe96c6088a485e186c37acd4cade074b.addTo(map_ff857ddde6b1f30c4e72b6f0d0648306);
#
#
#             var feature_group_8a0e8d716b0149714f820f44323ffb89 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_56a587a7bcf7f5d1cde09787d8d58b96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8a0e8d716b0149714f820f44323ffb89);
#
#
#         var popup_16185a2520afd04ac8fa015aaf96d739 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f1d76dad9c5dbe45b9f016427de96db = $(`&lt;div id=&quot;html_1f1d76dad9c5dbe45b9f016427de96db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_16185a2520afd04ac8fa015aaf96d739.setContent(html_1f1d76dad9c5dbe45b9f016427de96db);
#
#
#
#         marker_56a587a7bcf7f5d1cde09787d8d58b96.bindPopup(popup_16185a2520afd04ac8fa015aaf96d739)
#         ;
#
#
#
#
#             var marker_c2e2fb6cacc087d36e0fea3932a5596b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8a0e8d716b0149714f820f44323ffb89);
#
#
#         var popup_f28643482217b6c65796a1491825e6a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7ba15c9cd3065c30f0a15976362660b = $(`&lt;div id=&quot;html_c7ba15c9cd3065c30f0a15976362660b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f28643482217b6c65796a1491825e6a8.setContent(html_c7ba15c9cd3065c30f0a15976362660b);
#
#
#
#         marker_c2e2fb6cacc087d36e0fea3932a5596b.bindPopup(popup_f28643482217b6c65796a1491825e6a8)
#         ;
#
#
#
#
#             var marker_152271e5b50307a2562804ac0210585d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8a0e8d716b0149714f820f44323ffb89);
#
#
#         var popup_04d239639995f1531fe04b09caf36ae4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b02f51ee553afdf5dfce97747338a20d = $(`&lt;div id=&quot;html_b02f51ee553afdf5dfce97747338a20d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_04d239639995f1531fe04b09caf36ae4.setContent(html_b02f51ee553afdf5dfce97747338a20d);
#
#
#
#         marker_152271e5b50307a2562804ac0210585d.bindPopup(popup_04d239639995f1531fe04b09caf36ae4)
#         ;
#
#
#
#
#             var marker_f3fe6d2ab7de0880a9429f933c32afc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8a0e8d716b0149714f820f44323ffb89);
#
#
#         var popup_567dc15d091c31483dbcadc75dccee86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38b272a2e5b31977af5787a1e41fbe3b = $(`&lt;div id=&quot;html_38b272a2e5b31977af5787a1e41fbe3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_567dc15d091c31483dbcadc75dccee86.setContent(html_38b272a2e5b31977af5787a1e41fbe3b);
#
#
#
#         marker_f3fe6d2ab7de0880a9429f933c32afc2.bindPopup(popup_567dc15d091c31483dbcadc75dccee86)
#         ;
#
#
#
#
#             var marker_3d72e3a41c70dc08a9ee913f1fa2fa62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8a0e8d716b0149714f820f44323ffb89);
#
#
#         var popup_483f06f0edf99da2137b8e7a8ef64d7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_222aaf96bd95b0c031db7da08f61073f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_222aaf96bd95b0c031db7da08f61073f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_222aaf96bd95b0c031db7da08f61073f = L.map(
#                 &quot;map_222aaf96bd95b0c031db7da08f61073f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5879182ebdba40b9cb0b53a8f09589d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5879182ebdba40b9cb0b53a8f09589d.addTo(map_222aaf96bd95b0c031db7da08f61073f);
#
#
#             var feature_group_1d0d3327f1bf8e9b73d048e68ee065d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1d0d3327f1bf8e9b73d048e68ee065d9.addTo(map_222aaf96bd95b0c031db7da08f61073f);
#
#
#             var feature_group_sub_group_0ef2b4fcba3bafe3b88746450770f6bf = L.featureGroup.subGroup(
#                 feature_group_1d0d3327f1bf8e9b73d048e68ee065d9
#             );
#
#
#             var marker_e9e910b17211d2c9ad44c278ed5a5f00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ef2b4fcba3bafe3b88746450770f6bf);
#
#
#         var popup_5e01f8da12bd4ec2f2306ae0f93ef267 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc762d0d867d56f32103f8ea98f129f4 = $(`&lt;div id=&quot;html_fc762d0d867d56f32103f8ea98f129f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5e01f8da12bd4ec2f2306ae0f93ef267.setContent(html_fc762d0d867d56f32103f8ea98f129f4);
#
#
#
#         marker_e9e910b17211d2c9ad44c278ed5a5f00.bindPopup(popup_5e01f8da12bd4ec2f2306ae0f93ef267)
#         ;
#
#
#
#
#             var marker_2fc58ac197661886d47943937fe4723d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ef2b4fcba3bafe3b88746450770f6bf);
#
#
#         var popup_5c5ef3474c7a21bed3ca48834ce10ecd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9ff59db786ddc16b18b5c2e5095ca57 = $(`&lt;div id=&quot;html_b9ff59db786ddc16b18b5c2e5095ca57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5c5ef3474c7a21bed3ca48834ce10ecd.setContent(html_b9ff59db786ddc16b18b5c2e5095ca57);
#
#
#
#         marker_2fc58ac197661886d47943937fe4723d.bindPopup(popup_5c5ef3474c7a21bed3ca48834ce10ecd)
#         ;
#
#
#
#
#             var marker_1d22f294fd240a6c4c530cad0772a774 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ef2b4fcba3bafe3b88746450770f6bf);
#
#
#         var popup_3a1b56efba81b61627660b1b94b769ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34cf698a648b1ad8f1fcf97b46e3d494 = $(`&lt;div id=&quot;html_34cf698a648b1ad8f1fcf97b46e3d494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3a1b56efba81b61627660b1b94b769ca.setContent(html_34cf698a648b1ad8f1fcf97b46e3d494);
#
#
#
#         marker_1d22f294fd240a6c4c530cad0772a774.bindPopup(popup_3a1b56efba81b61627660b1b94b769ca)
#         ;
#
#
#
#
#             var marker_7215bd901cec3cc00c18e6aaf78d416d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ef2b4fcba3bafe3b88746450770f6bf);
#
#
#         var popup_d6c33324123e29417e5dc4d98ff6220a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae715560a909fdfd1803f54ba0cca2d3 = $(`&lt;div id=&quot;html_ae715560a909fdfd1803f54ba0cca2d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d6c33324123e29417e5dc4d98ff6220a.setContent(html_ae715560a909fdfd1803f54ba0cca2d3);
#
#
#
#         marker_
