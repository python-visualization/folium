# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59d9731856c1f871f74832c49f43e1dc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59d9731856c1f871f74832c49f43e1dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59d9731856c1f871f74832c49f43e1dc = L.map(
#                 &quot;map_59d9731856c1f871f74832c49f43e1dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f57e4ba04c207c8e7978f3b80f5e8073 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f57e4ba04c207c8e7978f3b80f5e8073.addTo(map_59d9731856c1f871f74832c49f43e1dc);
#
#
#             var marker_c887d1c60af3304884172fa11967f7b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_59d9731856c1f871f74832c49f43e1dc);
#
#
#         var popup_cd15661a83a7e733692e98d0296e85be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f72052942bd21565fda82dd8df2f736 = $(`&lt;div id=&quot;html_3f72052942bd21565fda82dd8df2f736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cd15661a83a7e733692e98d0296e85be.setContent(html_3f72052942bd21565fda82dd8df2f736);
#
#
#
#         marker_c887d1c60af3304884172fa11967f7b9.bindPopup(popup_cd15661a83a7e733692e98d0296e85be)
#         ;
#
#
#
#
#             var marker_6c713bbe4be0ff645cc076830faa7223 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_59d9731856c1f871f74832c49f43e1dc);
#
#
#         var popup_273a6a8400b086de0475a3198910a527 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54e3c596c9c57888aa52555a08d9c807 = $(`&lt;div id=&quot;html_54e3c596c9c57888aa52555a08d9c807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_273a6a8400b086de0475a3198910a527.setContent(html_54e3c596c9c57888aa52555a08d9c807);
#
#
#
#         marker_6c713bbe4be0ff645cc076830faa7223.bindPopup(popup_273a6a8400b086de0475a3198910a527)
#         ;
#
#
#
#
#             var marker_b0882c72b731ba02ca580223d113adc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_59d9731856c1f871f74832c49f43e1dc);
#
#
#         var popup_15534232b709cae1e69130a2a7ca8998 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfa2f11486b1ec626e24e7525be4ff60 = $(`&lt;div id=&quot;html_dfa2f11486b1ec626e24e7525be4ff60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_15534232b709cae1e69130a2a7ca8998.setContent(html_dfa2f11486b1ec626e24e7525be4ff60);
#
#
#
#         marker_b0882c72b731ba02ca580223d113adc2.bindPopup(popup_15534232b709cae1e69130a2a7ca8998)
#         ;
#
#
#
#
#             var marker_908b6911d747f33c76686ff1c7d48677 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_59d9731856c1f871f74832c49f43e1dc);
#
#
#         var popup_10b6579dc171d41eddd35ed2d6b128c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b582b43c3678899aa844dce30cde92f2 = $(`&lt;div id=&quot;html_b582b43c3678899aa844dce30cde92f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_10b6579dc171d41eddd35ed2d6b128c8.setContent(html_b582b43c3678899aa844dce30cde92f2);
#
#
#
#         marker_908b6911d747f33c76686ff1c7d48677.bindPopup(popup_10b6579dc171d41eddd35ed2d6b128c8)
#         ;
#
#
#
#
#             var marker_197b9409e38312482dbb30cf01a0a5ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_59d9731856c1f871f74832c49f43e1dc);
#
#
#         var popup_80c2e0ce8dde9cf1fd68c3c81ecbb34b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54f99e5d88ffdad230fe1a91ba6bee99 = $(`&lt;div id=&quot;html_54f99e5d88ffdad230fe1a91ba6bee99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_80c2e0ce8dde9cf1fd68c3c81ecbb3

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a79b24a63356b8dbba99a2c371ea564 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a79b24a63356b8dbba99a2c371ea564&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a79b24a63356b8dbba99a2c371ea564 = L.map(
#                 &quot;map_4a79b24a63356b8dbba99a2c371ea564&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80a2352447d229ff1171a06db313d37c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80a2352447d229ff1171a06db313d37c.addTo(map_4a79b24a63356b8dbba99a2c371ea564);
#
#
#             var feature_group_82d52662ecd29451a8e3b2a4d0275ba1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_445222a80b0b08d8520749c37a6e7476 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_82d52662ecd29451a8e3b2a4d0275ba1);
#
#
#         var popup_1aa676fe85e66fc11b83d54b190c256b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5f8a8fe7a50cbd5869c5f648e3f52e5 = $(`&lt;div id=&quot;html_c5f8a8fe7a50cbd5869c5f648e3f52e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1aa676fe85e66fc11b83d54b190c256b.setContent(html_c5f8a8fe7a50cbd5869c5f648e3f52e5);
#
#
#
#         marker_445222a80b0b08d8520749c37a6e7476.bindPopup(popup_1aa676fe85e66fc11b83d54b190c256b)
#         ;
#
#
#
#
#             var marker_072816b05746f8e0c9d442e8971449d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_82d52662ecd29451a8e3b2a4d0275ba1);
#
#
#         var popup_1b12013cc58bc58d4c64a85c667fa3e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9cce40cbe1cb00e22fb7f6eba77ac83 = $(`&lt;div id=&quot;html_d9cce40cbe1cb00e22fb7f6eba77ac83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1b12013cc58bc58d4c64a85c667fa3e2.setContent(html_d9cce40cbe1cb00e22fb7f6eba77ac83);
#
#
#
#         marker_072816b05746f8e0c9d442e8971449d1.bindPopup(popup_1b12013cc58bc58d4c64a85c667fa3e2)
#         ;
#
#
#
#
#             var marker_2cc5d5174b2ffbf1d594c7f5e2710afc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_82d52662ecd29451a8e3b2a4d0275ba1);
#
#
#         var popup_fc3460bc398269ead8c251a39d485ca7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8de059d3a297d0e23248cefba484dc96 = $(`&lt;div id=&quot;html_8de059d3a297d0e23248cefba484dc96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fc3460bc398269ead8c251a39d485ca7.setContent(html_8de059d3a297d0e23248cefba484dc96);
#
#
#
#         marker_2cc5d5174b2ffbf1d594c7f5e2710afc.bindPopup(popup_fc3460bc398269ead8c251a39d485ca7)
#         ;
#
#
#
#
#             var marker_dbe44b9098338f2b2f18bd503a35892c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_82d52662ecd29451a8e3b2a4d0275ba1);
#
#
#         var popup_920dce7afe45079a44352029da285fa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d62218d247ed933f94225e2f8a505269 = $(`&lt;div id=&quot;html_d62218d247ed933f94225e2f8a505269&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_920dce7afe45079a44352029da285fa5.setContent(html_d62218d247ed933f94225e2f8a505269);
#
#
#
#         marker_dbe44b9098338f2b2f18bd503a35892c.bindPopup(popup_920dce7afe45079a44352029da285fa5)
#         ;
#
#
#
#
#             var marker_e24bb64d842ec5d050662e9db3585f56 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_82d52662ecd29451a8e3b2a4d0275ba1);
#
#
#         var popup_f44b6417e6cc2fb54187ca3280c213d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84362d68608983ae12587ca385c26505 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84362d68608983ae12587ca385c26505&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84362d68608983ae12587ca385c26505 = L.map(
#                 &quot;map_84362d68608983ae12587ca385c26505&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_706060b9e1f445b7a8fe99aae1ffda96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_706060b9e1f445b7a8fe99aae1ffda96.addTo(map_84362d68608983ae12587ca385c26505);
#
#
#             var feature_group_53354949626bcea868628e90eb509a5a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_53354949626bcea868628e90eb509a5a.addTo(map_84362d68608983ae12587ca385c26505);
#
#
#             var feature_group_sub_group_92e845edb2fc0c0e0c27561456428c53 = L.featureGroup.subGroup(
#                 feature_group_53354949626bcea868628e90eb509a5a
#             );
#
#
#             var marker_7c3c23222640769bbbc8b373e1998a99 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92e845edb2fc0c0e0c27561456428c53);
#
#
#         var popup_a1b574f4427f96043e5fb9a531dd6e42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1903f2fc8b2b0f73f67e8596eeccf47 = $(`&lt;div id=&quot;html_a1903f2fc8b2b0f73f67e8596eeccf47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a1b574f4427f96043e5fb9a531dd6e42.setContent(html_a1903f2fc8b2b0f73f67e8596eeccf47);
#
#
#
#         marker_7c3c23222640769bbbc8b373e1998a99.bindPopup(popup_a1b574f4427f96043e5fb9a531dd6e42)
#         ;
#
#
#
#
#             var marker_a4c18d058555406d867cdf73c857a382 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92e845edb2fc0c0e0c27561456428c53);
#
#
#         var popup_5b911384c2a92e4351ab9cad6b1105c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a586405bd6cbfe213e0a0a0aba13b673 = $(`&lt;div id=&quot;html_a586405bd6cbfe213e0a0a0aba13b673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5b911384c2a92e4351ab9cad6b1105c6.setContent(html_a586405bd6cbfe213e0a0a0aba13b673);
#
#
#
#         marker_a4c18d058555406d867cdf73c857a382.bindPopup(popup_5b911384c2a92e4351ab9cad6b1105c6)
#         ;
#
#
#
#
#             var marker_6051fd1bba4da7995c837dc008ce660b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92e845edb2fc0c0e0c27561456428c53);
#
#
#         var popup_26e76460200f50730c3d889fa8669b6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a26e7c3434544f85a464d6e87e745e4 = $(`&lt;div id=&quot;html_8a26e7c3434544f85a464d6e87e745e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_26e76460200f50730c3d889fa8669b6a.setContent(html_8a26e7c3434544f85a464d6e87e745e4);
#
#
#
#         marker_6051fd1bba4da7995c837dc008ce660b.bindPopup(popup_26e76460200f50730c3d889fa8669b6a)
#         ;
#
#
#
#
#             var marker_6216133c1ab5386043a84dd79480c453 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92e845edb2fc0c0e0c27561456428c53);
#
#
#         var popup_671e869a7927b05d9fe0e8ef6deaad1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aeb41e10a48e49838915cd662e406fdd = $(`&lt;div id=&quot;html_aeb41e10a48e49838915cd662e406fdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_671e869a7927b05d9fe0e8ef6deaad1b.setContent(html_aeb41e10a48e49838915cd662e406fdd);
#
#
#
#         mark
