# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d465cc718cafba640f5a211a6df0e0fc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d465cc718cafba640f5a211a6df0e0fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d465cc718cafba640f5a211a6df0e0fc = L.map(
#                 &quot;map_d465cc718cafba640f5a211a6df0e0fc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf7199ab086a50b55862076b7be38c08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf7199ab086a50b55862076b7be38c08.addTo(map_d465cc718cafba640f5a211a6df0e0fc);
#
#
#             var marker_dc8f5d2073ea37666c75aa6de1ecc66a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d465cc718cafba640f5a211a6df0e0fc);
#
#
#         var popup_75b9b051f9e00a51e6310b5f7610ec39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813c0fc46286ef7004e0846fca93b602 = $(`&lt;div id=&quot;html_813c0fc46286ef7004e0846fca93b602&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_75b9b051f9e00a51e6310b5f7610ec39.setContent(html_813c0fc46286ef7004e0846fca93b602);
#
#
#
#         marker_dc8f5d2073ea37666c75aa6de1ecc66a.bindPopup(popup_75b9b051f9e00a51e6310b5f7610ec39)
#         ;
#
#
#
#
#             var marker_46e7ca6e546e5267c4d91b72bcbcd47d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d465cc718cafba640f5a211a6df0e0fc);
#
#
#         var popup_10645a359850edb218e75d64d36bac01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b29eae1a037229bc49337487721e1be1 = $(`&lt;div id=&quot;html_b29eae1a037229bc49337487721e1be1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_10645a359850edb218e75d64d36bac01.setContent(html_b29eae1a037229bc49337487721e1be1);
#
#
#
#         marker_46e7ca6e546e5267c4d91b72bcbcd47d.bindPopup(popup_10645a359850edb218e75d64d36bac01)
#         ;
#
#
#
#
#             var marker_d0eff7172ede4fff898b4af5448ac2b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d465cc718cafba640f5a211a6df0e0fc);
#
#
#         var popup_553329a4854b066a2d82aada07bf6384 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c794e199265d8ae6d9d7f8b33b4b13e3 = $(`&lt;div id=&quot;html_c794e199265d8ae6d9d7f8b33b4b13e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_553329a4854b066a2d82aada07bf6384.setContent(html_c794e199265d8ae6d9d7f8b33b4b13e3);
#
#
#
#         marker_d0eff7172ede4fff898b4af5448ac2b1.bindPopup(popup_553329a4854b066a2d82aada07bf6384)
#         ;
#
#
#
#
#             var marker_35ba90d7b41d6bfe0672a76e241375f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d465cc718cafba640f5a211a6df0e0fc);
#
#
#         var popup_c1b9313dabf79cc14499604851183a6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57fd87baafd548c58914e6d333f575b9 = $(`&lt;div id=&quot;html_57fd87baafd548c58914e6d333f575b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c1b9313dabf79cc14499604851183a6c.setContent(html_57fd87baafd548c58914e6d333f575b9);
#
#
#
#         marker_35ba90d7b41d6bfe0672a76e241375f1.bindPopup(popup_c1b9313dabf79cc14499604851183a6c)
#         ;
#
#
#
#
#             var marker_64105d26b79d192f1d22e31736abf609 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d465cc718cafba640f5a211a6df0e0fc);
#
#
#         var popup_ca37ebf4ea52b6a5c359fc3275a83189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cc43679372e16394327bd1d4b79857d = $(`&lt;div id=&quot;html_6cc43679372e16394327bd1d4b79857d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ca37ebf4ea52b6a5c359fc3275a831

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8ace46aa480f0137e4413de8af2caab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8ace46aa480f0137e4413de8af2caab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8ace46aa480f0137e4413de8af2caab = L.map(
#                 &quot;map_f8ace46aa480f0137e4413de8af2caab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09f703db727a75ccf02249bd85dc06e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09f703db727a75ccf02249bd85dc06e6.addTo(map_f8ace46aa480f0137e4413de8af2caab);
#
#
#             var feature_group_5886255134209e6a9f1ad1bc2879a9d1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_796069866a26b524096a2a0f3f45a903 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5886255134209e6a9f1ad1bc2879a9d1);
#
#
#         var popup_be7c5c9286682711dfba77a479756a3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d980a4406526ede9b9a354fecefb74ba = $(`&lt;div id=&quot;html_d980a4406526ede9b9a354fecefb74ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_be7c5c9286682711dfba77a479756a3e.setContent(html_d980a4406526ede9b9a354fecefb74ba);
#
#
#
#         marker_796069866a26b524096a2a0f3f45a903.bindPopup(popup_be7c5c9286682711dfba77a479756a3e)
#         ;
#
#
#
#
#             var marker_855aa8e4d913d2d5ffd1571becd9c202 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5886255134209e6a9f1ad1bc2879a9d1);
#
#
#         var popup_a296ddd04e02b485c847714c2762bf03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8f354db0e8bcd057032cf9de543c041 = $(`&lt;div id=&quot;html_d8f354db0e8bcd057032cf9de543c041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a296ddd04e02b485c847714c2762bf03.setContent(html_d8f354db0e8bcd057032cf9de543c041);
#
#
#
#         marker_855aa8e4d913d2d5ffd1571becd9c202.bindPopup(popup_a296ddd04e02b485c847714c2762bf03)
#         ;
#
#
#
#
#             var marker_5f9a2f6dd5c5239aa62fc77ec3744d94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5886255134209e6a9f1ad1bc2879a9d1);
#
#
#         var popup_bc1b8a45ab545d19098079eda0c391a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3997c09b364ef766c49ece33262c39e3 = $(`&lt;div id=&quot;html_3997c09b364ef766c49ece33262c39e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bc1b8a45ab545d19098079eda0c391a0.setContent(html_3997c09b364ef766c49ece33262c39e3);
#
#
#
#         marker_5f9a2f6dd5c5239aa62fc77ec3744d94.bindPopup(popup_bc1b8a45ab545d19098079eda0c391a0)
#         ;
#
#
#
#
#             var marker_fce2341d030776727027f5e51bf1d5f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5886255134209e6a9f1ad1bc2879a9d1);
#
#
#         var popup_e835bc721113ea4106386d63f896235b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0160e2638d65dc644aee63e8b6d44714 = $(`&lt;div id=&quot;html_0160e2638d65dc644aee63e8b6d44714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e835bc721113ea4106386d63f896235b.setContent(html_0160e2638d65dc644aee63e8b6d44714);
#
#
#
#         marker_fce2341d030776727027f5e51bf1d5f1.bindPopup(popup_e835bc721113ea4106386d63f896235b)
#         ;
#
#
#
#
#             var marker_dcae4c60f0c4b7b6f903e8a779e8b1fc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5886255134209e6a9f1ad1bc2879a9d1);
#
#
#         var popup_41d36a66bd1bb639b6c869587bfbd458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90ce238d88c50b04bcdb1b0b768f5157 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90ce238d88c50b04bcdb1b0b768f5157&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90ce238d88c50b04bcdb1b0b768f5157 = L.map(
#                 &quot;map_90ce238d88c50b04bcdb1b0b768f5157&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f407427bfe0811228e006a02ea4d08ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f407427bfe0811228e006a02ea4d08ce.addTo(map_90ce238d88c50b04bcdb1b0b768f5157);
#
#
#             var feature_group_36e1c0706595b8193df1eb348a3b7f1c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_36e1c0706595b8193df1eb348a3b7f1c.addTo(map_90ce238d88c50b04bcdb1b0b768f5157);
#
#
#             var feature_group_sub_group_92afb57fdb854708938f50720c3c69f7 = L.featureGroup.subGroup(
#                 feature_group_36e1c0706595b8193df1eb348a3b7f1c
#             );
#
#
#             var marker_8d51cee39407a879b0ca478bacc9627e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92afb57fdb854708938f50720c3c69f7);
#
#
#         var popup_da4f0d3d5a42b07540fe7a27d8a9ade9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09aef61de17c646080de8841de5e13bf = $(`&lt;div id=&quot;html_09aef61de17c646080de8841de5e13bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_da4f0d3d5a42b07540fe7a27d8a9ade9.setContent(html_09aef61de17c646080de8841de5e13bf);
#
#
#
#         marker_8d51cee39407a879b0ca478bacc9627e.bindPopup(popup_da4f0d3d5a42b07540fe7a27d8a9ade9)
#         ;
#
#
#
#
#             var marker_02be1f31f34b20112dc3345696c9e47d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92afb57fdb854708938f50720c3c69f7);
#
#
#         var popup_864aa5ebca90685d899ab5ee18e52761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee090db24858ff2572be0e9af109de7 = $(`&lt;div id=&quot;html_cee090db24858ff2572be0e9af109de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_864aa5ebca90685d899ab5ee18e52761.setContent(html_cee090db24858ff2572be0e9af109de7);
#
#
#
#         marker_02be1f31f34b20112dc3345696c9e47d.bindPopup(popup_864aa5ebca90685d899ab5ee18e52761)
#         ;
#
#
#
#
#             var marker_7e78073c9f9a41e31bbb1a59dc30bb32 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92afb57fdb854708938f50720c3c69f7);
#
#
#         var popup_9e9e2c7617caab7a53ee0cdd17663f9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d892d8a66403c5c511e68b433591f57 = $(`&lt;div id=&quot;html_1d892d8a66403c5c511e68b433591f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9e9e2c7617caab7a53ee0cdd17663f9b.setContent(html_1d892d8a66403c5c511e68b433591f57);
#
#
#
#         marker_7e78073c9f9a41e31bbb1a59dc30bb32.bindPopup(popup_9e9e2c7617caab7a53ee0cdd17663f9b)
#         ;
#
#
#
#
#             var marker_d43f022c5a10eb769a7dda3056495ccf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92afb57fdb854708938f50720c3c69f7);
#
#
#         var popup_8044db9654cadabff9e20c4a5dac0082 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_657d3f36da2454e271f6949bcfea6eb9 = $(`&lt;div id=&quot;html_657d3f36da2454e271f6949bcfea6eb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8044db9654cadabff9e20c4a5dac0082.setContent(html_657d3f36da2454e271f6949bcfea6eb9);
#
#
#
#         mark
