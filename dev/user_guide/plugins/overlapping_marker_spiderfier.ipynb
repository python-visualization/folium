# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03c53607f04b7dda6755b0620e0db10d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03c53607f04b7dda6755b0620e0db10d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03c53607f04b7dda6755b0620e0db10d = L.map(
#                 &quot;map_03c53607f04b7dda6755b0620e0db10d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34cf1e422dd7cfe05f3542343e495263 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34cf1e422dd7cfe05f3542343e495263.addTo(map_03c53607f04b7dda6755b0620e0db10d);
#
#
#             var marker_8538347fd91eae64626f97a4d03b6201 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_03c53607f04b7dda6755b0620e0db10d);
#
#
#         var popup_1d14e61f6d565596127f1f2cae5a920b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45fac05c86edc7fccfcdc9704d3da1a8 = $(`&lt;div id=&quot;html_45fac05c86edc7fccfcdc9704d3da1a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d14e61f6d565596127f1f2cae5a920b.setContent(html_45fac05c86edc7fccfcdc9704d3da1a8);
#
#
#
#         marker_8538347fd91eae64626f97a4d03b6201.bindPopup(popup_1d14e61f6d565596127f1f2cae5a920b)
#         ;
#
#
#
#
#             var marker_a53dca9fd7780bc07dbc2d9ca303fcef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_03c53607f04b7dda6755b0620e0db10d);
#
#
#         var popup_9546978b35692e2b0e398e7beaa40461 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dd4f97baa75b0347bccd53d50d2a0fb = $(`&lt;div id=&quot;html_7dd4f97baa75b0347bccd53d50d2a0fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9546978b35692e2b0e398e7beaa40461.setContent(html_7dd4f97baa75b0347bccd53d50d2a0fb);
#
#
#
#         marker_a53dca9fd7780bc07dbc2d9ca303fcef.bindPopup(popup_9546978b35692e2b0e398e7beaa40461)
#         ;
#
#
#
#
#             var marker_7d89d467f2eabe78ed08cde8f4061c38 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_03c53607f04b7dda6755b0620e0db10d);
#
#
#         var popup_773ac30a3915abd0fbedb43a129c3c3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_482c13e8bc36053b758c0854ed8d3496 = $(`&lt;div id=&quot;html_482c13e8bc36053b758c0854ed8d3496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_773ac30a3915abd0fbedb43a129c3c3a.setContent(html_482c13e8bc36053b758c0854ed8d3496);
#
#
#
#         marker_7d89d467f2eabe78ed08cde8f4061c38.bindPopup(popup_773ac30a3915abd0fbedb43a129c3c3a)
#         ;
#
#
#
#
#             var marker_6f6e7956035d860fda52da997c2954d3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_03c53607f04b7dda6755b0620e0db10d);
#
#
#         var popup_f498a0db42c9d6c4e0718c1a1b2858b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a149e60319e56addddb04f3ad8cceb32 = $(`&lt;div id=&quot;html_a149e60319e56addddb04f3ad8cceb32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f498a0db42c9d6c4e0718c1a1b2858b4.setContent(html_a149e60319e56addddb04f3ad8cceb32);
#
#
#
#         marker_6f6e7956035d860fda52da997c2954d3.bindPopup(popup_f498a0db42c9d6c4e0718c1a1b2858b4)
#         ;
#
#
#
#
#             var marker_ed5d0cd9bd9c5243bfdb6b8061206c3c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_03c53607f04b7dda6755b0620e0db10d);
#
#
#         var popup_bf6baa039122c94b70d8b5f27d1cc401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8a81339a3c082dc18e65258a9c3b86a = $(`&lt;div id=&quot;html_e8a81339a3c082dc18e65258a9c3b86a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bf6baa039122c94b70d8b5f27d1cc4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb2b69daf0619ce9801f73d867d20f3a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb2b69daf0619ce9801f73d867d20f3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb2b69daf0619ce9801f73d867d20f3a = L.map(
#                 &quot;map_fb2b69daf0619ce9801f73d867d20f3a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40e03649911bf3c116ffc76b51e2e7d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40e03649911bf3c116ffc76b51e2e7d2.addTo(map_fb2b69daf0619ce9801f73d867d20f3a);
#
#
#             var feature_group_dc362be6d975e4ca3e20a20f0021e0ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7684be15d92959ee090a7014e12b3f63 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dc362be6d975e4ca3e20a20f0021e0ed);
#
#
#         var popup_c4237c199e7354360298acde873db82a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b6b97f291e06120fd4e230bd78790f6 = $(`&lt;div id=&quot;html_1b6b97f291e06120fd4e230bd78790f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c4237c199e7354360298acde873db82a.setContent(html_1b6b97f291e06120fd4e230bd78790f6);
#
#
#
#         marker_7684be15d92959ee090a7014e12b3f63.bindPopup(popup_c4237c199e7354360298acde873db82a)
#         ;
#
#
#
#
#             var marker_04ed3e0dacce32924da62bc074a01184 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dc362be6d975e4ca3e20a20f0021e0ed);
#
#
#         var popup_307977816bc27504c9561cc35f33ffec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45632ac8ec9b7000a266f83915a4ebb7 = $(`&lt;div id=&quot;html_45632ac8ec9b7000a266f83915a4ebb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_307977816bc27504c9561cc35f33ffec.setContent(html_45632ac8ec9b7000a266f83915a4ebb7);
#
#
#
#         marker_04ed3e0dacce32924da62bc074a01184.bindPopup(popup_307977816bc27504c9561cc35f33ffec)
#         ;
#
#
#
#
#             var marker_9968bc4221d690be8900b9b1951e09b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dc362be6d975e4ca3e20a20f0021e0ed);
#
#
#         var popup_7f46c1daedb595f556f32ed8acfd76ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5f54c46ed429400c43f6aefd71c3fc2 = $(`&lt;div id=&quot;html_e5f54c46ed429400c43f6aefd71c3fc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7f46c1daedb595f556f32ed8acfd76ee.setContent(html_e5f54c46ed429400c43f6aefd71c3fc2);
#
#
#
#         marker_9968bc4221d690be8900b9b1951e09b1.bindPopup(popup_7f46c1daedb595f556f32ed8acfd76ee)
#         ;
#
#
#
#
#             var marker_3ffceb650cf6358942448e6152c8cea7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dc362be6d975e4ca3e20a20f0021e0ed);
#
#
#         var popup_027fa4ff7ed72eddc34367bd1b34a6e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c58df34a9c34fa765304bbb82a054fb1 = $(`&lt;div id=&quot;html_c58df34a9c34fa765304bbb82a054fb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_027fa4ff7ed72eddc34367bd1b34a6e8.setContent(html_c58df34a9c34fa765304bbb82a054fb1);
#
#
#
#         marker_3ffceb650cf6358942448e6152c8cea7.bindPopup(popup_027fa4ff7ed72eddc34367bd1b34a6e8)
#         ;
#
#
#
#
#             var marker_4673f8908301614957d3082ab550583d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dc362be6d975e4ca3e20a20f0021e0ed);
#
#
#         var popup_2543b9b25686247d6a94b0f132dc7b8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9238e254204a98ff0f46617f402479f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9238e254204a98ff0f46617f402479f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9238e254204a98ff0f46617f402479f = L.map(
#                 &quot;map_d9238e254204a98ff0f46617f402479f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fdff6dbe1952ae480cb0fdfddd77cc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5fdff6dbe1952ae480cb0fdfddd77cc4.addTo(map_d9238e254204a98ff0f46617f402479f);
#
#
#             var feature_group_b01d4975ed96671769c62741cba8e5d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b01d4975ed96671769c62741cba8e5d0.addTo(map_d9238e254204a98ff0f46617f402479f);
#
#
#             var feature_group_sub_group_8570597a446af9f721f5632793a1ca3b = L.featureGroup.subGroup(
#                 feature_group_b01d4975ed96671769c62741cba8e5d0
#             );
#
#
#             var marker_51a57e4fe11f7e5a2ecd6e2815988452 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8570597a446af9f721f5632793a1ca3b);
#
#
#         var popup_20e86b5d7dc045e4e50dc20c9f6257c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d83f03de24cc28d0c704117def9430e = $(`&lt;div id=&quot;html_0d83f03de24cc28d0c704117def9430e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_20e86b5d7dc045e4e50dc20c9f6257c1.setContent(html_0d83f03de24cc28d0c704117def9430e);
#
#
#
#         marker_51a57e4fe11f7e5a2ecd6e2815988452.bindPopup(popup_20e86b5d7dc045e4e50dc20c9f6257c1)
#         ;
#
#
#
#
#             var marker_537fa28b01817fc19b6267bc807970e2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8570597a446af9f721f5632793a1ca3b);
#
#
#         var popup_ddbcedbad5a2294808f4002237436428 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6d46cf986987020dd6a006d3079dbf7 = $(`&lt;div id=&quot;html_e6d46cf986987020dd6a006d3079dbf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ddbcedbad5a2294808f4002237436428.setContent(html_e6d46cf986987020dd6a006d3079dbf7);
#
#
#
#         marker_537fa28b01817fc19b6267bc807970e2.bindPopup(popup_ddbcedbad5a2294808f4002237436428)
#         ;
#
#
#
#
#             var marker_7b39af27ba6d6797a077d379263397e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8570597a446af9f721f5632793a1ca3b);
#
#
#         var popup_e5311115601a346dcaad4c29735d846c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32a14237fd4a9baf7bb5329ade20cbb0 = $(`&lt;div id=&quot;html_32a14237fd4a9baf7bb5329ade20cbb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e5311115601a346dcaad4c29735d846c.setContent(html_32a14237fd4a9baf7bb5329ade20cbb0);
#
#
#
#         marker_7b39af27ba6d6797a077d379263397e8.bindPopup(popup_e5311115601a346dcaad4c29735d846c)
#         ;
#
#
#
#
#             var marker_d524e4ef40fbf918504d640098a5e60b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8570597a446af9f721f5632793a1ca3b);
#
#
#         var popup_d8845538999b341cc64a742304e639c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3440d5fa3e07a2f7ceb06f7767396dc2 = $(`&lt;div id=&quot;html_3440d5fa3e07a2f7ceb06f7767396dc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d8845538999b341cc64a742304e639c9.setContent(html_3440d5fa3e07a2f7ceb06f7767396dc2);
#
#
#
#         mark
