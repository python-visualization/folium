# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e66cb8d69fdf7a1b197b3a6af34ab701 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e66cb8d69fdf7a1b197b3a6af34ab701&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e66cb8d69fdf7a1b197b3a6af34ab701 = L.map(
#                 &quot;map_e66cb8d69fdf7a1b197b3a6af34ab701&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1700d29226ca0f27c01a0abf26335890 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1700d29226ca0f27c01a0abf26335890.addTo(map_e66cb8d69fdf7a1b197b3a6af34ab701);
#
#
#             var marker_d49cfd313e9858d231557b85347b3087 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e66cb8d69fdf7a1b197b3a6af34ab701);
#
#
#         var popup_11fdf8489c2a3ac6b965d4d895cbc69f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_213ca7500ecaee2257428e9053ba3d95 = $(`&lt;div id=&quot;html_213ca7500ecaee2257428e9053ba3d95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_11fdf8489c2a3ac6b965d4d895cbc69f.setContent(html_213ca7500ecaee2257428e9053ba3d95);
#
#
#
#         marker_d49cfd313e9858d231557b85347b3087.bindPopup(popup_11fdf8489c2a3ac6b965d4d895cbc69f)
#         ;
#
#
#
#
#             var marker_707014f3e26f06659c4007a96c4f4833 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e66cb8d69fdf7a1b197b3a6af34ab701);
#
#
#         var popup_464188505ee1c35f7980508a791158f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19c0c9012bbad29a608926aeca63dc7a = $(`&lt;div id=&quot;html_19c0c9012bbad29a608926aeca63dc7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_464188505ee1c35f7980508a791158f3.setContent(html_19c0c9012bbad29a608926aeca63dc7a);
#
#
#
#         marker_707014f3e26f06659c4007a96c4f4833.bindPopup(popup_464188505ee1c35f7980508a791158f3)
#         ;
#
#
#
#
#             var marker_507a0f4581b21db6303db91ee141888c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e66cb8d69fdf7a1b197b3a6af34ab701);
#
#
#         var popup_232e808f6e7e67a4690654b7b0444bda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a43a0651bbdf2f164b79b0e85bb68d46 = $(`&lt;div id=&quot;html_a43a0651bbdf2f164b79b0e85bb68d46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_232e808f6e7e67a4690654b7b0444bda.setContent(html_a43a0651bbdf2f164b79b0e85bb68d46);
#
#
#
#         marker_507a0f4581b21db6303db91ee141888c.bindPopup(popup_232e808f6e7e67a4690654b7b0444bda)
#         ;
#
#
#
#
#             var marker_3e916cee3607749e0681a7e64052a172 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e66cb8d69fdf7a1b197b3a6af34ab701);
#
#
#         var popup_ab5927a6390e0c9977c0538f928e163a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1bfb3515401822cbc15e7080885ad8d = $(`&lt;div id=&quot;html_f1bfb3515401822cbc15e7080885ad8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ab5927a6390e0c9977c0538f928e163a.setContent(html_f1bfb3515401822cbc15e7080885ad8d);
#
#
#
#         marker_3e916cee3607749e0681a7e64052a172.bindPopup(popup_ab5927a6390e0c9977c0538f928e163a)
#         ;
#
#
#
#
#             var marker_4cc254077fbacb4f3fdbaa3590c773b2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e66cb8d69fdf7a1b197b3a6af34ab701);
#
#
#         var popup_2b19f20f79641553b3c8d7f2cdbcb264 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc60d0140973b58b257bd4e8372d3ccd = $(`&lt;div id=&quot;html_cc60d0140973b58b257bd4e8372d3ccd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2b19f20f79641553b3c8d7f2cdbcb264.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16f7a5f0b95206f1d5bf5240e7c2c3f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16f7a5f0b95206f1d5bf5240e7c2c3f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16f7a5f0b95206f1d5bf5240e7c2c3f0 = L.map(
#                 &quot;map_16f7a5f0b95206f1d5bf5240e7c2c3f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0858c4bffe3fccfa408c30897a19b3bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0858c4bffe3fccfa408c30897a19b3bb.addTo(map_16f7a5f0b95206f1d5bf5240e7c2c3f0);
#
#
#             var feature_group_6656464d3b99609603e91bfe36117b11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_308b8f9659f3e558887054c96070e1b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6656464d3b99609603e91bfe36117b11);
#
#
#         var popup_79f4d38889b4db4d510facd4c911aef5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adcac29c95ea11da8c51d7d42abeeff3 = $(`&lt;div id=&quot;html_adcac29c95ea11da8c51d7d42abeeff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_79f4d38889b4db4d510facd4c911aef5.setContent(html_adcac29c95ea11da8c51d7d42abeeff3);
#
#
#
#         marker_308b8f9659f3e558887054c96070e1b0.bindPopup(popup_79f4d38889b4db4d510facd4c911aef5)
#         ;
#
#
#
#
#             var marker_9d70e0954253beef2a9628da8bdb8a56 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6656464d3b99609603e91bfe36117b11);
#
#
#         var popup_86f53092258082b3a1d3e2941fce5312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84269c30e177da521ab42b70cdfeec55 = $(`&lt;div id=&quot;html_84269c30e177da521ab42b70cdfeec55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_86f53092258082b3a1d3e2941fce5312.setContent(html_84269c30e177da521ab42b70cdfeec55);
#
#
#
#         marker_9d70e0954253beef2a9628da8bdb8a56.bindPopup(popup_86f53092258082b3a1d3e2941fce5312)
#         ;
#
#
#
#
#             var marker_f5451d29f797bc5a659d2f7705de1199 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6656464d3b99609603e91bfe36117b11);
#
#
#         var popup_39834942a6a163af847e9249fc6feb98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_486b636b0f7ba606b131d1a9bc43c044 = $(`&lt;div id=&quot;html_486b636b0f7ba606b131d1a9bc43c044&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_39834942a6a163af847e9249fc6feb98.setContent(html_486b636b0f7ba606b131d1a9bc43c044);
#
#
#
#         marker_f5451d29f797bc5a659d2f7705de1199.bindPopup(popup_39834942a6a163af847e9249fc6feb98)
#         ;
#
#
#
#
#             var marker_21d5df7808d6bba6f80ea9b8a6d3bcac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6656464d3b99609603e91bfe36117b11);
#
#
#         var popup_b00e06023062d1c8b5fc3a6fba33d654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_012561d864710972f4b024fa6d7de1bb = $(`&lt;div id=&quot;html_012561d864710972f4b024fa6d7de1bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b00e06023062d1c8b5fc3a6fba33d654.setContent(html_012561d864710972f4b024fa6d7de1bb);
#
#
#
#         marker_21d5df7808d6bba6f80ea9b8a6d3bcac.bindPopup(popup_b00e06023062d1c8b5fc3a6fba33d654)
#         ;
#
#
#
#
#             var marker_4f95476dd1b493c1f63a9651bbb51588 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6656464d3b99609603e91bfe36117b11);
#
#
#         var popup_98812568f90988bce79664d54cfbb826 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea602486dcfc6f4f73eb9c216d0cdc54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea602486dcfc6f4f73eb9c216d0cdc54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea602486dcfc6f4f73eb9c216d0cdc54 = L.map(
#                 &quot;map_ea602486dcfc6f4f73eb9c216d0cdc54&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c18150592cadf7b7c242e52887890e03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c18150592cadf7b7c242e52887890e03.addTo(map_ea602486dcfc6f4f73eb9c216d0cdc54);
#
#
#             var feature_group_e652abaa28772347323032e8611655fd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e652abaa28772347323032e8611655fd.addTo(map_ea602486dcfc6f4f73eb9c216d0cdc54);
#
#
#             var feature_group_sub_group_7d2b1a842516284d91c9386e0da2b48a = L.featureGroup.subGroup(
#                 feature_group_e652abaa28772347323032e8611655fd
#             );
#
#
#             var marker_2ef30143ccdc2738d16094e30d81a4ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d2b1a842516284d91c9386e0da2b48a);
#
#
#         var popup_dc3f87cbbd2ceee89551a34c25792aa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8d5a52b8c560ad7a657ec173ba6187b = $(`&lt;div id=&quot;html_d8d5a52b8c560ad7a657ec173ba6187b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dc3f87cbbd2ceee89551a34c25792aa5.setContent(html_d8d5a52b8c560ad7a657ec173ba6187b);
#
#
#
#         marker_2ef30143ccdc2738d16094e30d81a4ec.bindPopup(popup_dc3f87cbbd2ceee89551a34c25792aa5)
#         ;
#
#
#
#
#             var marker_15edd584571f7b990f8b6903d7f41858 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d2b1a842516284d91c9386e0da2b48a);
#
#
#         var popup_7c42d8661cc064cf55c66cb5381a8f90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3ca72b79f1552d15c78136a78a800ef = $(`&lt;div id=&quot;html_e3ca72b79f1552d15c78136a78a800ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7c42d8661cc064cf55c66cb5381a8f90.setContent(html_e3ca72b79f1552d15c78136a78a800ef);
#
#
#
#         marker_15edd584571f7b990f8b6903d7f41858.bindPopup(popup_7c42d8661cc064cf55c66cb5381a8f90)
#         ;
#
#
#
#
#             var marker_531725b1138d8c0b7bf87dd925b1b401 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d2b1a842516284d91c9386e0da2b48a);
#
#
#         var popup_4e69f5e4e4124e7e6043fda1cef28257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecfe1386e4ea9be6b784b2816058b0e4 = $(`&lt;div id=&quot;html_ecfe1386e4ea9be6b784b2816058b0e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4e69f5e4e4124e7e6043fda1cef28257.setContent(html_ecfe1386e4ea9be6b784b2816058b0e4);
#
#
#
#         marker_531725b1138d8c0b7bf87dd925b1b401.bindPopup(popup_4e69f5e4e4124e7e6043fda1cef28257)
#         ;
#
#
#
#
#             var marker_43b05a0f4988de9fb119349ccf73f322 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d2b1a842516284d91c9386e0da2b48a);
#
#
#         var popup_2afca81efff9aa22f5cdc118ce6ebada = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d43198c9d06bf289d9c9aa4b3f0f825 = $(`&lt;div id=&quot;html_2d43198c9d06bf289d9c9aa4b3f0f825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2afca81efff9aa22f5cdc118ce6ebada.setContent(html_2d43198c9d06bf289d9c9aa4b3f0f825);
#
#
#
#         marker_
