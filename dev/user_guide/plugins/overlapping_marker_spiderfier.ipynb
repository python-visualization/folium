# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_095440d5793e447bfe478cc8724079dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_095440d5793e447bfe478cc8724079dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_095440d5793e447bfe478cc8724079dc = L.map(
#                 &quot;map_095440d5793e447bfe478cc8724079dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a107f272040ef0fc6e290ed56aee0a81 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a107f272040ef0fc6e290ed56aee0a81.addTo(map_095440d5793e447bfe478cc8724079dc);
#
#
#             var marker_d09fe930366e53916bea9dcc9ea92eac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_095440d5793e447bfe478cc8724079dc);
#
#
#         var popup_fb7152387553cf655189e26f94c30c55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eea8ebdf9cc12134bc4cb4ca5008788 = $(`&lt;div id=&quot;html_5eea8ebdf9cc12134bc4cb4ca5008788&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fb7152387553cf655189e26f94c30c55.setContent(html_5eea8ebdf9cc12134bc4cb4ca5008788);
#
#
#
#         marker_d09fe930366e53916bea9dcc9ea92eac.bindPopup(popup_fb7152387553cf655189e26f94c30c55)
#         ;
#
#
#
#
#             var marker_54f8b19bab8bc08a0da02c5351e15330 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_095440d5793e447bfe478cc8724079dc);
#
#
#         var popup_e7781eae029ec2254c69515e18e262f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8ab95eb3ab0ae96f996e7380b23e3d0 = $(`&lt;div id=&quot;html_c8ab95eb3ab0ae96f996e7380b23e3d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e7781eae029ec2254c69515e18e262f6.setContent(html_c8ab95eb3ab0ae96f996e7380b23e3d0);
#
#
#
#         marker_54f8b19bab8bc08a0da02c5351e15330.bindPopup(popup_e7781eae029ec2254c69515e18e262f6)
#         ;
#
#
#
#
#             var marker_14861db6709862845d4e49182476650f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_095440d5793e447bfe478cc8724079dc);
#
#
#         var popup_089a55f3494081a0146a4f847c990772 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e5127dd0a53cfcc96d87c1524107dcd = $(`&lt;div id=&quot;html_8e5127dd0a53cfcc96d87c1524107dcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_089a55f3494081a0146a4f847c990772.setContent(html_8e5127dd0a53cfcc96d87c1524107dcd);
#
#
#
#         marker_14861db6709862845d4e49182476650f.bindPopup(popup_089a55f3494081a0146a4f847c990772)
#         ;
#
#
#
#
#             var marker_8bdc076f08cf981c7c5e1afb414bceeb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_095440d5793e447bfe478cc8724079dc);
#
#
#         var popup_b5f863975a7892201a2b32c8a1f4b558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f07f3673127b7ea016d13fbd36c10293 = $(`&lt;div id=&quot;html_f07f3673127b7ea016d13fbd36c10293&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b5f863975a7892201a2b32c8a1f4b558.setContent(html_f07f3673127b7ea016d13fbd36c10293);
#
#
#
#         marker_8bdc076f08cf981c7c5e1afb414bceeb.bindPopup(popup_b5f863975a7892201a2b32c8a1f4b558)
#         ;
#
#
#
#
#             var marker_46c169caf7c5781078f1258a911b8b69 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_095440d5793e447bfe478cc8724079dc);
#
#
#         var popup_89ec638b0c22a67bff29aeaff4328355 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e3ae0b42c0765b105e7771b79902b7b = $(`&lt;div id=&quot;html_9e3ae0b42c0765b105e7771b79902b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_89ec638b0c22a67bff29aeaff4328355.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2593ef1ea898f8cc184ce3f7ee7265fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2593ef1ea898f8cc184ce3f7ee7265fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2593ef1ea898f8cc184ce3f7ee7265fb = L.map(
#                 &quot;map_2593ef1ea898f8cc184ce3f7ee7265fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5df36592336253550e1abbcfe8e87e51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5df36592336253550e1abbcfe8e87e51.addTo(map_2593ef1ea898f8cc184ce3f7ee7265fb);
#
#
#             var feature_group_e1d2ab9172ff97974d66a0ca8de154b9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_09ee4c65f0d6a62757ece4483e31a510 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e1d2ab9172ff97974d66a0ca8de154b9);
#
#
#         var popup_d76362cce116cb5f03860eef5c61db99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898d3f40fd7472ec70a9c024ee87137c = $(`&lt;div id=&quot;html_898d3f40fd7472ec70a9c024ee87137c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d76362cce116cb5f03860eef5c61db99.setContent(html_898d3f40fd7472ec70a9c024ee87137c);
#
#
#
#         marker_09ee4c65f0d6a62757ece4483e31a510.bindPopup(popup_d76362cce116cb5f03860eef5c61db99)
#         ;
#
#
#
#
#             var marker_0f41eaf3460e05037f419ae0759ce2fc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e1d2ab9172ff97974d66a0ca8de154b9);
#
#
#         var popup_f622c59e19547681afbbec85f8ca7107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ac3f846a92c56e4d7bfb3c35a859c32 = $(`&lt;div id=&quot;html_2ac3f846a92c56e4d7bfb3c35a859c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f622c59e19547681afbbec85f8ca7107.setContent(html_2ac3f846a92c56e4d7bfb3c35a859c32);
#
#
#
#         marker_0f41eaf3460e05037f419ae0759ce2fc.bindPopup(popup_f622c59e19547681afbbec85f8ca7107)
#         ;
#
#
#
#
#             var marker_82e8a6560ab3c4dd5c3723e4f285b16f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e1d2ab9172ff97974d66a0ca8de154b9);
#
#
#         var popup_b7aead91f7c9359d12e4a607766a5f01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5a7bdeeea415bff85a56649f99e76cf = $(`&lt;div id=&quot;html_b5a7bdeeea415bff85a56649f99e76cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b7aead91f7c9359d12e4a607766a5f01.setContent(html_b5a7bdeeea415bff85a56649f99e76cf);
#
#
#
#         marker_82e8a6560ab3c4dd5c3723e4f285b16f.bindPopup(popup_b7aead91f7c9359d12e4a607766a5f01)
#         ;
#
#
#
#
#             var marker_fd9e5345678c8163fd22a6c7301386cb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e1d2ab9172ff97974d66a0ca8de154b9);
#
#
#         var popup_ad9645123b32893da93f36585daf9fdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68e70217c87032c1e7d8a8b35b5df42b = $(`&lt;div id=&quot;html_68e70217c87032c1e7d8a8b35b5df42b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ad9645123b32893da93f36585daf9fdc.setContent(html_68e70217c87032c1e7d8a8b35b5df42b);
#
#
#
#         marker_fd9e5345678c8163fd22a6c7301386cb.bindPopup(popup_ad9645123b32893da93f36585daf9fdc)
#         ;
#
#
#
#
#             var marker_3899eaa8e3db6a5002839502e40348b1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e1d2ab9172ff97974d66a0ca8de154b9);
#
#
#         var popup_f30390a2e373b6a135481dca5b18f5fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db7177ecd56894d2f700f20ed183b898 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db7177ecd56894d2f700f20ed183b898&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db7177ecd56894d2f700f20ed183b898 = L.map(
#                 &quot;map_db7177ecd56894d2f700f20ed183b898&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f19c0cb38f9107d1d91fe692e14690d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f19c0cb38f9107d1d91fe692e14690d.addTo(map_db7177ecd56894d2f700f20ed183b898);
#
#
#             var feature_group_ffd4703349292f18f38b344adca3f9b3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ffd4703349292f18f38b344adca3f9b3.addTo(map_db7177ecd56894d2f700f20ed183b898);
#
#
#             var feature_group_sub_group_cdfeb2a51caeb2efb4e1b08a913d81cf = L.featureGroup.subGroup(
#                 feature_group_ffd4703349292f18f38b344adca3f9b3
#             );
#
#
#             var marker_f2adb6b11d6d4d95bf9067a6ac4563c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdfeb2a51caeb2efb4e1b08a913d81cf);
#
#
#         var popup_7434d725b4268c52faa39ba5d63d1dfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b058bc4661c7b3e05c9e3b5eeb1040f = $(`&lt;div id=&quot;html_1b058bc4661c7b3e05c9e3b5eeb1040f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7434d725b4268c52faa39ba5d63d1dfe.setContent(html_1b058bc4661c7b3e05c9e3b5eeb1040f);
#
#
#
#         marker_f2adb6b11d6d4d95bf9067a6ac4563c7.bindPopup(popup_7434d725b4268c52faa39ba5d63d1dfe)
#         ;
#
#
#
#
#             var marker_0bce110e2cae5df4c3c97dd2085b8db7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdfeb2a51caeb2efb4e1b08a913d81cf);
#
#
#         var popup_938e206725e72b6cef8ed13842d055c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3a8090276e5aa800cf7b344b56b0100 = $(`&lt;div id=&quot;html_f3a8090276e5aa800cf7b344b56b0100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_938e206725e72b6cef8ed13842d055c1.setContent(html_f3a8090276e5aa800cf7b344b56b0100);
#
#
#
#         marker_0bce110e2cae5df4c3c97dd2085b8db7.bindPopup(popup_938e206725e72b6cef8ed13842d055c1)
#         ;
#
#
#
#
#             var marker_f602d627bb96d5d5af001de8f02de212 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdfeb2a51caeb2efb4e1b08a913d81cf);
#
#
#         var popup_13669479bccb1ff9b78637a6260ff162 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f210c54d0442dbec5dd24f7cd146a83 = $(`&lt;div id=&quot;html_2f210c54d0442dbec5dd24f7cd146a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_13669479bccb1ff9b78637a6260ff162.setContent(html_2f210c54d0442dbec5dd24f7cd146a83);
#
#
#
#         marker_f602d627bb96d5d5af001de8f02de212.bindPopup(popup_13669479bccb1ff9b78637a6260ff162)
#         ;
#
#
#
#
#             var marker_4876b2972730db1b032ece4d25ec0fc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdfeb2a51caeb2efb4e1b08a913d81cf);
#
#
#         var popup_f79d817761c994f20e1d296c0964980a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ace361efe3b097cd4095e43cb90685 = $(`&lt;div id=&quot;html_38ace361efe3b097cd4095e43cb90685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f79d817761c994f20e1d296c0964980a.setContent(html_38ace361efe3b097cd4095e43cb90685);
#
#
#
#         marker_
