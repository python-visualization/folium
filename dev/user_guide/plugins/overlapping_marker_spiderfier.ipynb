# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09adaf927f1311c0d5974ba17cf0200d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09adaf927f1311c0d5974ba17cf0200d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09adaf927f1311c0d5974ba17cf0200d = L.map(
#                 &quot;map_09adaf927f1311c0d5974ba17cf0200d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20f58c8016bd100ddd353018d18f1747 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20f58c8016bd100ddd353018d18f1747.addTo(map_09adaf927f1311c0d5974ba17cf0200d);
#
#
#             var marker_fa8424d88df821c4b47aa2af3336ca46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_09adaf927f1311c0d5974ba17cf0200d);
#
#
#         var popup_f93a58986ea83a8f22dc97e2c553fa83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1201194325362950617a023d177095f9 = $(`&lt;div id=&quot;html_1201194325362950617a023d177095f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f93a58986ea83a8f22dc97e2c553fa83.setContent(html_1201194325362950617a023d177095f9);
#
#
#
#         marker_fa8424d88df821c4b47aa2af3336ca46.bindPopup(popup_f93a58986ea83a8f22dc97e2c553fa83)
#         ;
#
#
#
#
#             var marker_8c6563c9afac73788daf971b1a19e4eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_09adaf927f1311c0d5974ba17cf0200d);
#
#
#         var popup_0882acb11d49683ea386a6a6d794ff6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebb81d6a35143fc951563b650730e4e3 = $(`&lt;div id=&quot;html_ebb81d6a35143fc951563b650730e4e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0882acb11d49683ea386a6a6d794ff6c.setContent(html_ebb81d6a35143fc951563b650730e4e3);
#
#
#
#         marker_8c6563c9afac73788daf971b1a19e4eb.bindPopup(popup_0882acb11d49683ea386a6a6d794ff6c)
#         ;
#
#
#
#
#             var marker_cf29f00ab912758d96434cf964475eab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_09adaf927f1311c0d5974ba17cf0200d);
#
#
#         var popup_f67b036ae846bf4d35c07cf6af034f2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e86e1fad8d0f8657b44a090b57b5a519 = $(`&lt;div id=&quot;html_e86e1fad8d0f8657b44a090b57b5a519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f67b036ae846bf4d35c07cf6af034f2f.setContent(html_e86e1fad8d0f8657b44a090b57b5a519);
#
#
#
#         marker_cf29f00ab912758d96434cf964475eab.bindPopup(popup_f67b036ae846bf4d35c07cf6af034f2f)
#         ;
#
#
#
#
#             var marker_e4e2b35fb41bde83109e4e95176198f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_09adaf927f1311c0d5974ba17cf0200d);
#
#
#         var popup_6627b98fbaaca0f8594532b7248fba1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_811bdc2065c8195f254fe85dab4112ca = $(`&lt;div id=&quot;html_811bdc2065c8195f254fe85dab4112ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6627b98fbaaca0f8594532b7248fba1c.setContent(html_811bdc2065c8195f254fe85dab4112ca);
#
#
#
#         marker_e4e2b35fb41bde83109e4e95176198f0.bindPopup(popup_6627b98fbaaca0f8594532b7248fba1c)
#         ;
#
#
#
#
#             var marker_4bc30039f35d5f6e10a0e291fd224fe4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_09adaf927f1311c0d5974ba17cf0200d);
#
#
#         var popup_42959e78ee147096b6d83e559d00f0e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0500dddf32c5fd8fe7bbadee837365a5 = $(`&lt;div id=&quot;html_0500dddf32c5fd8fe7bbadee837365a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_42959e78ee147096b6d83e559d00f0e7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74638a9e1fe8525ca470645f55f9c753 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74638a9e1fe8525ca470645f55f9c753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74638a9e1fe8525ca470645f55f9c753 = L.map(
#                 &quot;map_74638a9e1fe8525ca470645f55f9c753&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a7168c18f8860ded21f62dcbaa6ec64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a7168c18f8860ded21f62dcbaa6ec64.addTo(map_74638a9e1fe8525ca470645f55f9c753);
#
#
#             var feature_group_fdca80a8386a6a1e7e8eb8ae7b3c8715 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9eb6a75d8d4a4751bce08337fcb20b44 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fdca80a8386a6a1e7e8eb8ae7b3c8715);
#
#
#         var popup_8cd99d8d98f1b8035a4f5231c9aa5ca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46bdc6cfccaa550fed86a941bbf5a883 = $(`&lt;div id=&quot;html_46bdc6cfccaa550fed86a941bbf5a883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8cd99d8d98f1b8035a4f5231c9aa5ca9.setContent(html_46bdc6cfccaa550fed86a941bbf5a883);
#
#
#
#         marker_9eb6a75d8d4a4751bce08337fcb20b44.bindPopup(popup_8cd99d8d98f1b8035a4f5231c9aa5ca9)
#         ;
#
#
#
#
#             var marker_d0129adaf5aba02cd705d3b0b17962aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fdca80a8386a6a1e7e8eb8ae7b3c8715);
#
#
#         var popup_36da57d4ebf5e92c6ae076dae3729f74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bda0933cbdce56cd7fe8e8ad045a0c0 = $(`&lt;div id=&quot;html_6bda0933cbdce56cd7fe8e8ad045a0c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_36da57d4ebf5e92c6ae076dae3729f74.setContent(html_6bda0933cbdce56cd7fe8e8ad045a0c0);
#
#
#
#         marker_d0129adaf5aba02cd705d3b0b17962aa.bindPopup(popup_36da57d4ebf5e92c6ae076dae3729f74)
#         ;
#
#
#
#
#             var marker_f7ea22d09e2ee82d1bfa60d679f1bdfb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fdca80a8386a6a1e7e8eb8ae7b3c8715);
#
#
#         var popup_b4dbaa366acd6380af7f1378dcf30ef8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e83a192d61feb707a19ff058edc7659 = $(`&lt;div id=&quot;html_4e83a192d61feb707a19ff058edc7659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b4dbaa366acd6380af7f1378dcf30ef8.setContent(html_4e83a192d61feb707a19ff058edc7659);
#
#
#
#         marker_f7ea22d09e2ee82d1bfa60d679f1bdfb.bindPopup(popup_b4dbaa366acd6380af7f1378dcf30ef8)
#         ;
#
#
#
#
#             var marker_34ae77d606699f379d8064c38717d1bd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fdca80a8386a6a1e7e8eb8ae7b3c8715);
#
#
#         var popup_50aae1e3d44ef4e0166caa2e8dd36026 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52fbe557c87afe61b14e426405b59d69 = $(`&lt;div id=&quot;html_52fbe557c87afe61b14e426405b59d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_50aae1e3d44ef4e0166caa2e8dd36026.setContent(html_52fbe557c87afe61b14e426405b59d69);
#
#
#
#         marker_34ae77d606699f379d8064c38717d1bd.bindPopup(popup_50aae1e3d44ef4e0166caa2e8dd36026)
#         ;
#
#
#
#
#             var marker_2fa3013963ac51aac047323d2f7b56da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fdca80a8386a6a1e7e8eb8ae7b3c8715);
#
#
#         var popup_11e9d601cfeaf1f05e06cb1178774aa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30ef3fde9b3f16bb49487d8739f5220f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30ef3fde9b3f16bb49487d8739f5220f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30ef3fde9b3f16bb49487d8739f5220f = L.map(
#                 &quot;map_30ef3fde9b3f16bb49487d8739f5220f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7eca79a0e0128a918e609ef8516ac422 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7eca79a0e0128a918e609ef8516ac422.addTo(map_30ef3fde9b3f16bb49487d8739f5220f);
#
#
#             var feature_group_adc0fb707d0294efdfaa22186e704f13 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_adc0fb707d0294efdfaa22186e704f13.addTo(map_30ef3fde9b3f16bb49487d8739f5220f);
#
#
#             var feature_group_sub_group_2148459cb02a15f3226afe0ee4cc63d1 = L.featureGroup.subGroup(
#                 feature_group_adc0fb707d0294efdfaa22186e704f13
#             );
#
#
#             var marker_2e1247fcdd2738a6e4a4bea4a17e9a60 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2148459cb02a15f3226afe0ee4cc63d1);
#
#
#         var popup_7f01694282ab9e381780c69e36dd1221 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e42c92973998a0c3cd6acb4e130552e1 = $(`&lt;div id=&quot;html_e42c92973998a0c3cd6acb4e130552e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7f01694282ab9e381780c69e36dd1221.setContent(html_e42c92973998a0c3cd6acb4e130552e1);
#
#
#
#         marker_2e1247fcdd2738a6e4a4bea4a17e9a60.bindPopup(popup_7f01694282ab9e381780c69e36dd1221)
#         ;
#
#
#
#
#             var marker_eccc427104b13f63ed91c65bbe13ceea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2148459cb02a15f3226afe0ee4cc63d1);
#
#
#         var popup_878b64c57c624101f5ae1acf123002d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_919732c5584c75905b59e78f6b5b3a31 = $(`&lt;div id=&quot;html_919732c5584c75905b59e78f6b5b3a31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_878b64c57c624101f5ae1acf123002d1.setContent(html_919732c5584c75905b59e78f6b5b3a31);
#
#
#
#         marker_eccc427104b13f63ed91c65bbe13ceea.bindPopup(popup_878b64c57c624101f5ae1acf123002d1)
#         ;
#
#
#
#
#             var marker_6244c1a819d371abfff65a1b2b9e1815 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2148459cb02a15f3226afe0ee4cc63d1);
#
#
#         var popup_02f5c1c040ae75bd939cf2d92a63e862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75172efcc3b137f056b15c5fba7d2f48 = $(`&lt;div id=&quot;html_75172efcc3b137f056b15c5fba7d2f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_02f5c1c040ae75bd939cf2d92a63e862.setContent(html_75172efcc3b137f056b15c5fba7d2f48);
#
#
#
#         marker_6244c1a819d371abfff65a1b2b9e1815.bindPopup(popup_02f5c1c040ae75bd939cf2d92a63e862)
#         ;
#
#
#
#
#             var marker_ed076522a735d4540b5c79e34574278a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2148459cb02a15f3226afe0ee4cc63d1);
#
#
#         var popup_f40d8d8efb10eb7ef5fddcc5955b77f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3459bb8b1f469b846506cdb6e55d4726 = $(`&lt;div id=&quot;html_3459bb8b1f469b846506cdb6e55d4726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f40d8d8efb10eb7ef5fddcc5955b77f4.setContent(html_3459bb8b1f469b846506cdb6e55d4726);
#
#
#
#         marker_
