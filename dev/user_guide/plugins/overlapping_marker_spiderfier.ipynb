# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d297c699225c22f7d93020602ba7cee8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d297c699225c22f7d93020602ba7cee8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d297c699225c22f7d93020602ba7cee8 = L.map(
#                 &quot;map_d297c699225c22f7d93020602ba7cee8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd90255c3cce696a333e4bfc1a3ea644 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd90255c3cce696a333e4bfc1a3ea644.addTo(map_d297c699225c22f7d93020602ba7cee8);
#
#
#             var marker_49f754ddba4db0acf3ada47d7bfd8f96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d297c699225c22f7d93020602ba7cee8);
#
#
#         var popup_16fdfdf87deff9fa559ac2900337565b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_115d1a7a55f934fa316b2afd60f9a915 = $(`&lt;div id=&quot;html_115d1a7a55f934fa316b2afd60f9a915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_16fdfdf87deff9fa559ac2900337565b.setContent(html_115d1a7a55f934fa316b2afd60f9a915);
#
#
#
#         marker_49f754ddba4db0acf3ada47d7bfd8f96.bindPopup(popup_16fdfdf87deff9fa559ac2900337565b)
#         ;
#
#
#
#
#             var marker_36a574bb0b1e92a3be25b5dce2b43406 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d297c699225c22f7d93020602ba7cee8);
#
#
#         var popup_f717227121e7c2187d82a65f4f4cd409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_994627733da3908601e069e548420e15 = $(`&lt;div id=&quot;html_994627733da3908601e069e548420e15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f717227121e7c2187d82a65f4f4cd409.setContent(html_994627733da3908601e069e548420e15);
#
#
#
#         marker_36a574bb0b1e92a3be25b5dce2b43406.bindPopup(popup_f717227121e7c2187d82a65f4f4cd409)
#         ;
#
#
#
#
#             var marker_2ce2f880ee4b5a9515646509e6b2a78a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d297c699225c22f7d93020602ba7cee8);
#
#
#         var popup_0254a09b2e5a3c7ea9d81b86ef9569e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04b507e64926f443c7a790fabc0e39ac = $(`&lt;div id=&quot;html_04b507e64926f443c7a790fabc0e39ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0254a09b2e5a3c7ea9d81b86ef9569e2.setContent(html_04b507e64926f443c7a790fabc0e39ac);
#
#
#
#         marker_2ce2f880ee4b5a9515646509e6b2a78a.bindPopup(popup_0254a09b2e5a3c7ea9d81b86ef9569e2)
#         ;
#
#
#
#
#             var marker_b4e787e5076741d30cab454783904acc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d297c699225c22f7d93020602ba7cee8);
#
#
#         var popup_636c9392856ebfee94fc9fc78eb9e8f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64078eda15f503245c624320597934bf = $(`&lt;div id=&quot;html_64078eda15f503245c624320597934bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_636c9392856ebfee94fc9fc78eb9e8f2.setContent(html_64078eda15f503245c624320597934bf);
#
#
#
#         marker_b4e787e5076741d30cab454783904acc.bindPopup(popup_636c9392856ebfee94fc9fc78eb9e8f2)
#         ;
#
#
#
#
#             var marker_6f4b51068c3a909de5b037c1cd62e34b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d297c699225c22f7d93020602ba7cee8);
#
#
#         var popup_de837c994f897fd0831c5e7c5e18e5e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82f5551d6d7afefd6ad3fb113f465d4e = $(`&lt;div id=&quot;html_82f5551d6d7afefd6ad3fb113f465d4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_de837c994f897fd0831c5e7c5e18e5e9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e0d2c74e7c93d72995568db44b32166 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e0d2c74e7c93d72995568db44b32166&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e0d2c74e7c93d72995568db44b32166 = L.map(
#                 &quot;map_2e0d2c74e7c93d72995568db44b32166&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60278d580a5ecae5774acdeecafe6bd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60278d580a5ecae5774acdeecafe6bd4.addTo(map_2e0d2c74e7c93d72995568db44b32166);
#
#
#             var feature_group_2ddaad532f28c2f9fb0bdee7ffd8034f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e4d84dbcef1339b7d68facfc7ea6e5d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2ddaad532f28c2f9fb0bdee7ffd8034f);
#
#
#         var popup_1055f157212b08af8c3588e5ed02cb85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11275712e094dc3a0efa0e5befb44101 = $(`&lt;div id=&quot;html_11275712e094dc3a0efa0e5befb44101&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1055f157212b08af8c3588e5ed02cb85.setContent(html_11275712e094dc3a0efa0e5befb44101);
#
#
#
#         marker_e4d84dbcef1339b7d68facfc7ea6e5d6.bindPopup(popup_1055f157212b08af8c3588e5ed02cb85)
#         ;
#
#
#
#
#             var marker_aae62067580348034c98fc33fbba1a46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2ddaad532f28c2f9fb0bdee7ffd8034f);
#
#
#         var popup_3bf5d68691abe186b6c005743738ed7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2e91e80f0261c1f06d42c9301dfe39d = $(`&lt;div id=&quot;html_c2e91e80f0261c1f06d42c9301dfe39d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3bf5d68691abe186b6c005743738ed7d.setContent(html_c2e91e80f0261c1f06d42c9301dfe39d);
#
#
#
#         marker_aae62067580348034c98fc33fbba1a46.bindPopup(popup_3bf5d68691abe186b6c005743738ed7d)
#         ;
#
#
#
#
#             var marker_29c43db5dbbf4121d8aeb2a1041c6f06 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2ddaad532f28c2f9fb0bdee7ffd8034f);
#
#
#         var popup_9b168941555bda60ceba2edc564f6bc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edfa5cdb35b38f9afd8c4613f9c9e48b = $(`&lt;div id=&quot;html_edfa5cdb35b38f9afd8c4613f9c9e48b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b168941555bda60ceba2edc564f6bc0.setContent(html_edfa5cdb35b38f9afd8c4613f9c9e48b);
#
#
#
#         marker_29c43db5dbbf4121d8aeb2a1041c6f06.bindPopup(popup_9b168941555bda60ceba2edc564f6bc0)
#         ;
#
#
#
#
#             var marker_503644aa67a6cb2810dd7332a81f9f62 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2ddaad532f28c2f9fb0bdee7ffd8034f);
#
#
#         var popup_000587d4ff519ad1f3414f5af178e96e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3ff057eb2ada2ed4f4c9ff30b494140 = $(`&lt;div id=&quot;html_d3ff057eb2ada2ed4f4c9ff30b494140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_000587d4ff519ad1f3414f5af178e96e.setContent(html_d3ff057eb2ada2ed4f4c9ff30b494140);
#
#
#
#         marker_503644aa67a6cb2810dd7332a81f9f62.bindPopup(popup_000587d4ff519ad1f3414f5af178e96e)
#         ;
#
#
#
#
#             var marker_88ff232a5c340864e5738faade4c11e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2ddaad532f28c2f9fb0bdee7ffd8034f);
#
#
#         var popup_0ad07f374e3ee17bfe0dd390dd854196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d20b32708936f3481ef116c2463612d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d20b32708936f3481ef116c2463612d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d20b32708936f3481ef116c2463612d = L.map(
#                 &quot;map_1d20b32708936f3481ef116c2463612d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f46474a66fb6ea229c2db62d355d1c0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f46474a66fb6ea229c2db62d355d1c0d.addTo(map_1d20b32708936f3481ef116c2463612d);
#
#
#             var feature_group_e2c61ab8c30958b4610fa703b4e5a24b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e2c61ab8c30958b4610fa703b4e5a24b.addTo(map_1d20b32708936f3481ef116c2463612d);
#
#
#             var feature_group_sub_group_c25cd4b79dc888928a74dfd755d70747 = L.featureGroup.subGroup(
#                 feature_group_e2c61ab8c30958b4610fa703b4e5a24b
#             );
#
#
#             var marker_fab2e811b62b190691cf04f34a52a684 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c25cd4b79dc888928a74dfd755d70747);
#
#
#         var popup_fb01ba404e528f3275d18fe8dcc42e78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_862a7d855862d2b84cf499650b716802 = $(`&lt;div id=&quot;html_862a7d855862d2b84cf499650b716802&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fb01ba404e528f3275d18fe8dcc42e78.setContent(html_862a7d855862d2b84cf499650b716802);
#
#
#
#         marker_fab2e811b62b190691cf04f34a52a684.bindPopup(popup_fb01ba404e528f3275d18fe8dcc42e78)
#         ;
#
#
#
#
#             var marker_13787faf37d8bd217a499e31bd3f133e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c25cd4b79dc888928a74dfd755d70747);
#
#
#         var popup_d57e30b1c799541da27eb706af887621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb7197ca9b78396f85e87a1454032c3c = $(`&lt;div id=&quot;html_bb7197ca9b78396f85e87a1454032c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d57e30b1c799541da27eb706af887621.setContent(html_bb7197ca9b78396f85e87a1454032c3c);
#
#
#
#         marker_13787faf37d8bd217a499e31bd3f133e.bindPopup(popup_d57e30b1c799541da27eb706af887621)
#         ;
#
#
#
#
#             var marker_b53071ebd08653bb21bbacaab040ab44 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c25cd4b79dc888928a74dfd755d70747);
#
#
#         var popup_cfaef055fc098cacdf4dd87a53db0252 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b83fdbee6f41e53231313f54fc4907d9 = $(`&lt;div id=&quot;html_b83fdbee6f41e53231313f54fc4907d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cfaef055fc098cacdf4dd87a53db0252.setContent(html_b83fdbee6f41e53231313f54fc4907d9);
#
#
#
#         marker_b53071ebd08653bb21bbacaab040ab44.bindPopup(popup_cfaef055fc098cacdf4dd87a53db0252)
#         ;
#
#
#
#
#             var marker_64ac08e4eab31d8d041edcc00eb39096 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c25cd4b79dc888928a74dfd755d70747);
#
#
#         var popup_e7377882acc2e84d1a93d3ac978cb30e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48890cddb50f3e2342755c99cee837e8 = $(`&lt;div id=&quot;html_48890cddb50f3e2342755c99cee837e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e7377882acc2e84d1a93d3ac978cb30e.setContent(html_48890cddb50f3e2342755c99cee837e8);
#
#
#
#         marker_
