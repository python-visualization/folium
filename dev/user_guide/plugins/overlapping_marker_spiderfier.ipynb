# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_880ee5c8d5ae8b5d2e69bd41b0eac7a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_880ee5c8d5ae8b5d2e69bd41b0eac7a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_880ee5c8d5ae8b5d2e69bd41b0eac7a8 = L.map(
#                 &quot;map_880ee5c8d5ae8b5d2e69bd41b0eac7a8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_faca1746de6b9c2793a95c1253dfc7b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_faca1746de6b9c2793a95c1253dfc7b3.addTo(map_880ee5c8d5ae8b5d2e69bd41b0eac7a8);
#
#
#             var marker_c1da0b922d3bad7ee2ebd6d0840b024b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_880ee5c8d5ae8b5d2e69bd41b0eac7a8);
#
#
#         var popup_3ff4ac4be3d020897f4abff043f56808 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_739266e13f6c5c333dc7ab7d5d8b6097 = $(`&lt;div id=&quot;html_739266e13f6c5c333dc7ab7d5d8b6097&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3ff4ac4be3d020897f4abff043f56808.setContent(html_739266e13f6c5c333dc7ab7d5d8b6097);
#
#
#
#         marker_c1da0b922d3bad7ee2ebd6d0840b024b.bindPopup(popup_3ff4ac4be3d020897f4abff043f56808)
#         ;
#
#
#
#
#             var marker_0bb45ccc834582567655ce78acfeb1ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_880ee5c8d5ae8b5d2e69bd41b0eac7a8);
#
#
#         var popup_853b65855b410f6976c8da93e0d1ab5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba86e1d38aba3c0e4a283745041173b7 = $(`&lt;div id=&quot;html_ba86e1d38aba3c0e4a283745041173b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_853b65855b410f6976c8da93e0d1ab5f.setContent(html_ba86e1d38aba3c0e4a283745041173b7);
#
#
#
#         marker_0bb45ccc834582567655ce78acfeb1ea.bindPopup(popup_853b65855b410f6976c8da93e0d1ab5f)
#         ;
#
#
#
#
#             var marker_49aa7ff2faf07461211dcda469e0c32a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_880ee5c8d5ae8b5d2e69bd41b0eac7a8);
#
#
#         var popup_53e48e2ac138b7c08b23c72c8a75d761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bba89c2cca756cd84ce27798ccf28d59 = $(`&lt;div id=&quot;html_bba89c2cca756cd84ce27798ccf28d59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_53e48e2ac138b7c08b23c72c8a75d761.setContent(html_bba89c2cca756cd84ce27798ccf28d59);
#
#
#
#         marker_49aa7ff2faf07461211dcda469e0c32a.bindPopup(popup_53e48e2ac138b7c08b23c72c8a75d761)
#         ;
#
#
#
#
#             var marker_e429aa63a334be08986636a1ac9a11b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_880ee5c8d5ae8b5d2e69bd41b0eac7a8);
#
#
#         var popup_7417e96be89fb2dc6e762ecef9060e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96723b94d7dd75a9e5fae488e9b8dfdd = $(`&lt;div id=&quot;html_96723b94d7dd75a9e5fae488e9b8dfdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7417e96be89fb2dc6e762ecef9060e66.setContent(html_96723b94d7dd75a9e5fae488e9b8dfdd);
#
#
#
#         marker_e429aa63a334be08986636a1ac9a11b0.bindPopup(popup_7417e96be89fb2dc6e762ecef9060e66)
#         ;
#
#
#
#
#             var marker_84e301e5354292fd3d075fc33d2aef8c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_880ee5c8d5ae8b5d2e69bd41b0eac7a8);
#
#
#         var popup_0be1306bee1ee109d14d6b20c4af8402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63a1e8a95fb540cad2e43659b5c41268 = $(`&lt;div id=&quot;html_63a1e8a95fb540cad2e43659b5c41268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0be1306bee1ee109d14d6b20c4af8402.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24746a7b7342be195ce5c541e95afeb5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24746a7b7342be195ce5c541e95afeb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24746a7b7342be195ce5c541e95afeb5 = L.map(
#                 &quot;map_24746a7b7342be195ce5c541e95afeb5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12f9846365dca095f864e889f0fba113 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12f9846365dca095f864e889f0fba113.addTo(map_24746a7b7342be195ce5c541e95afeb5);
#
#
#             var feature_group_df8048742f5234998071a3549c720a6b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_58c2bf9f5d407971a2ded43209e2f2d0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_df8048742f5234998071a3549c720a6b);
#
#
#         var popup_fd32de9da1fa0ce5f8deaccaf11f2eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cab72c3f7084a4efdfc6027cb79bfd05 = $(`&lt;div id=&quot;html_cab72c3f7084a4efdfc6027cb79bfd05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fd32de9da1fa0ce5f8deaccaf11f2eb1.setContent(html_cab72c3f7084a4efdfc6027cb79bfd05);
#
#
#
#         marker_58c2bf9f5d407971a2ded43209e2f2d0.bindPopup(popup_fd32de9da1fa0ce5f8deaccaf11f2eb1)
#         ;
#
#
#
#
#             var marker_8a318528da777fde89c96d1496402068 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_df8048742f5234998071a3549c720a6b);
#
#
#         var popup_31a2df70f86e5a6bfa0879f191b015fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc2c78801cc6f758ff33e495f765405 = $(`&lt;div id=&quot;html_ddc2c78801cc6f758ff33e495f765405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_31a2df70f86e5a6bfa0879f191b015fb.setContent(html_ddc2c78801cc6f758ff33e495f765405);
#
#
#
#         marker_8a318528da777fde89c96d1496402068.bindPopup(popup_31a2df70f86e5a6bfa0879f191b015fb)
#         ;
#
#
#
#
#             var marker_5c6d108d0f63651ab7de16db696a7010 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_df8048742f5234998071a3549c720a6b);
#
#
#         var popup_7d122f6de7745add4da7dab64ea4adf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e79f076c987cec58a674b035c0f588dc = $(`&lt;div id=&quot;html_e79f076c987cec58a674b035c0f588dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7d122f6de7745add4da7dab64ea4adf6.setContent(html_e79f076c987cec58a674b035c0f588dc);
#
#
#
#         marker_5c6d108d0f63651ab7de16db696a7010.bindPopup(popup_7d122f6de7745add4da7dab64ea4adf6)
#         ;
#
#
#
#
#             var marker_1b51b1ae2739869cbeaaa4190b877d06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_df8048742f5234998071a3549c720a6b);
#
#
#         var popup_5a368fcad257409f798fd49b35ed108c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a477174383d6cb405aea4161dc1ce97e = $(`&lt;div id=&quot;html_a477174383d6cb405aea4161dc1ce97e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5a368fcad257409f798fd49b35ed108c.setContent(html_a477174383d6cb405aea4161dc1ce97e);
#
#
#
#         marker_1b51b1ae2739869cbeaaa4190b877d06.bindPopup(popup_5a368fcad257409f798fd49b35ed108c)
#         ;
#
#
#
#
#             var marker_af34512ce867184fba4de92924b3e6c8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_df8048742f5234998071a3549c720a6b);
#
#
#         var popup_466cb3afaa0b76912e9d8e7b316eb39d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ad1c3a81c7278a08bfba0f7308006bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ad1c3a81c7278a08bfba0f7308006bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ad1c3a81c7278a08bfba0f7308006bb = L.map(
#                 &quot;map_3ad1c3a81c7278a08bfba0f7308006bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd406715cc688471d563498a1e3cd54a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd406715cc688471d563498a1e3cd54a.addTo(map_3ad1c3a81c7278a08bfba0f7308006bb);
#
#
#             var feature_group_48d8a54a0bbf566523de780a5235f533 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_48d8a54a0bbf566523de780a5235f533.addTo(map_3ad1c3a81c7278a08bfba0f7308006bb);
#
#
#             var feature_group_sub_group_ec57c759363d47fc1f365baba03fa30b = L.featureGroup.subGroup(
#                 feature_group_48d8a54a0bbf566523de780a5235f533
#             );
#
#
#             var marker_47995621ff23a120887e697c3e4e5ff3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec57c759363d47fc1f365baba03fa30b);
#
#
#         var popup_69150795f72b0c055a45ffd5493c2754 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64f9a9b0014a87375bf9cd5420b28ecf = $(`&lt;div id=&quot;html_64f9a9b0014a87375bf9cd5420b28ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_69150795f72b0c055a45ffd5493c2754.setContent(html_64f9a9b0014a87375bf9cd5420b28ecf);
#
#
#
#         marker_47995621ff23a120887e697c3e4e5ff3.bindPopup(popup_69150795f72b0c055a45ffd5493c2754)
#         ;
#
#
#
#
#             var marker_eb2e907ce5515ed3962e7b9760d0701e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec57c759363d47fc1f365baba03fa30b);
#
#
#         var popup_aa0ba9b20ba41cba95f6be49b66db180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b558ad05db7c63e89b999ce0c0d6bb4 = $(`&lt;div id=&quot;html_0b558ad05db7c63e89b999ce0c0d6bb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aa0ba9b20ba41cba95f6be49b66db180.setContent(html_0b558ad05db7c63e89b999ce0c0d6bb4);
#
#
#
#         marker_eb2e907ce5515ed3962e7b9760d0701e.bindPopup(popup_aa0ba9b20ba41cba95f6be49b66db180)
#         ;
#
#
#
#
#             var marker_4706de6d3f147f9537d4b1cd1d22c37e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec57c759363d47fc1f365baba03fa30b);
#
#
#         var popup_00ce01e0ea226bdcf69d5d5d28b9c4cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7158a6adaf0c53209646dc4e4deb3b89 = $(`&lt;div id=&quot;html_7158a6adaf0c53209646dc4e4deb3b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_00ce01e0ea226bdcf69d5d5d28b9c4cc.setContent(html_7158a6adaf0c53209646dc4e4deb3b89);
#
#
#
#         marker_4706de6d3f147f9537d4b1cd1d22c37e.bindPopup(popup_00ce01e0ea226bdcf69d5d5d28b9c4cc)
#         ;
#
#
#
#
#             var marker_3f8ce1db23dd41bec5a4edad0f946882 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec57c759363d47fc1f365baba03fa30b);
#
#
#         var popup_6293e02446c0f1f2afd666125707f3f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e67a5d827c42b76d0fc3ef5135ccfcbe = $(`&lt;div id=&quot;html_e67a5d827c42b76d0fc3ef5135ccfcbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6293e02446c0f1f2afd666125707f3f0.setContent(html_e67a5d827c42b76d0fc3ef5135ccfcbe);
#
#
#
#         marker_
