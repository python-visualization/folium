# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e1b315e8bb349de472ac6c8caa43eeb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e1b315e8bb349de472ac6c8caa43eeb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e1b315e8bb349de472ac6c8caa43eeb = L.map(
#                 &quot;map_2e1b315e8bb349de472ac6c8caa43eeb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d20887f69aa699eda3ee1c6c7b9e0267 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d20887f69aa699eda3ee1c6c7b9e0267.addTo(map_2e1b315e8bb349de472ac6c8caa43eeb);
#
#
#             var marker_1afde3bed64b61f82f55e242369e290b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2e1b315e8bb349de472ac6c8caa43eeb);
#
#
#         var popup_82767d4b8198ba30374515ecb1de6554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c500e8b901fcc55664888b1b6e083b0 = $(`&lt;div id=&quot;html_6c500e8b901fcc55664888b1b6e083b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_82767d4b8198ba30374515ecb1de6554.setContent(html_6c500e8b901fcc55664888b1b6e083b0);
#
#
#
#         marker_1afde3bed64b61f82f55e242369e290b.bindPopup(popup_82767d4b8198ba30374515ecb1de6554)
#         ;
#
#
#
#
#             var marker_03ac20c28afe285172bd40d453e52ac1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2e1b315e8bb349de472ac6c8caa43eeb);
#
#
#         var popup_851e06906ae5e022f8e5c1df87dbcc3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f5e5a1f8542e9fb2054e12ef16efcae = $(`&lt;div id=&quot;html_6f5e5a1f8542e9fb2054e12ef16efcae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_851e06906ae5e022f8e5c1df87dbcc3f.setContent(html_6f5e5a1f8542e9fb2054e12ef16efcae);
#
#
#
#         marker_03ac20c28afe285172bd40d453e52ac1.bindPopup(popup_851e06906ae5e022f8e5c1df87dbcc3f)
#         ;
#
#
#
#
#             var marker_d0c1c76c94347a4d4620c52bb8127d3b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2e1b315e8bb349de472ac6c8caa43eeb);
#
#
#         var popup_9e6b32e2d020e8fba5b2fba003d7ca94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc4bc97918f1a20085e7dfe90e50084d = $(`&lt;div id=&quot;html_cc4bc97918f1a20085e7dfe90e50084d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9e6b32e2d020e8fba5b2fba003d7ca94.setContent(html_cc4bc97918f1a20085e7dfe90e50084d);
#
#
#
#         marker_d0c1c76c94347a4d4620c52bb8127d3b.bindPopup(popup_9e6b32e2d020e8fba5b2fba003d7ca94)
#         ;
#
#
#
#
#             var marker_6fd656791d8490be89a3769f155f5f3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2e1b315e8bb349de472ac6c8caa43eeb);
#
#
#         var popup_416663f522bc75d61c3dd3d1f80c859c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9d67c4aed233d0c8f50ba87cbaf97ba = $(`&lt;div id=&quot;html_e9d67c4aed233d0c8f50ba87cbaf97ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_416663f522bc75d61c3dd3d1f80c859c.setContent(html_e9d67c4aed233d0c8f50ba87cbaf97ba);
#
#
#
#         marker_6fd656791d8490be89a3769f155f5f3a.bindPopup(popup_416663f522bc75d61c3dd3d1f80c859c)
#         ;
#
#
#
#
#             var marker_647f74a66ace9053da1f4ac86a169256 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2e1b315e8bb349de472ac6c8caa43eeb);
#
#
#         var popup_da0ae7b2ab9ff1eacf01cb1b83ff6faa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88bc376435d884436ac2b547223857b0 = $(`&lt;div id=&quot;html_88bc376435d884436ac2b547223857b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_da0ae7b2ab9ff1eacf01cb1b83ff6faa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d36e04009be5342c56d85d3c200079c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d36e04009be5342c56d85d3c200079c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d36e04009be5342c56d85d3c200079c0 = L.map(
#                 &quot;map_d36e04009be5342c56d85d3c200079c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df90924f2a1c02bf9c37dc79d5bdd803 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df90924f2a1c02bf9c37dc79d5bdd803.addTo(map_d36e04009be5342c56d85d3c200079c0);
#
#
#             var feature_group_fb530b4ae7f2f15cad7893e3580374de = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fd4006cdb82fee69694dabb5f230faf7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fb530b4ae7f2f15cad7893e3580374de);
#
#
#         var popup_3ece392f07d894b10e6f16e748ddf717 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69c401149e86705de94b830015e0c85e = $(`&lt;div id=&quot;html_69c401149e86705de94b830015e0c85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3ece392f07d894b10e6f16e748ddf717.setContent(html_69c401149e86705de94b830015e0c85e);
#
#
#
#         marker_fd4006cdb82fee69694dabb5f230faf7.bindPopup(popup_3ece392f07d894b10e6f16e748ddf717)
#         ;
#
#
#
#
#             var marker_ff0b7f5614be918f090340e190e65b42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fb530b4ae7f2f15cad7893e3580374de);
#
#
#         var popup_2eccafb96582c49f7da8001dd0dd7164 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9909eb64c18e94879dba5fe76138eca = $(`&lt;div id=&quot;html_e9909eb64c18e94879dba5fe76138eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2eccafb96582c49f7da8001dd0dd7164.setContent(html_e9909eb64c18e94879dba5fe76138eca);
#
#
#
#         marker_ff0b7f5614be918f090340e190e65b42.bindPopup(popup_2eccafb96582c49f7da8001dd0dd7164)
#         ;
#
#
#
#
#             var marker_cc35c3dce0a4924f2031dc294392aaef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fb530b4ae7f2f15cad7893e3580374de);
#
#
#         var popup_99e00d203e18f318ad0f4dd00d14be28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f35773bdff697d10bf84e980475b016 = $(`&lt;div id=&quot;html_6f35773bdff697d10bf84e980475b016&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_99e00d203e18f318ad0f4dd00d14be28.setContent(html_6f35773bdff697d10bf84e980475b016);
#
#
#
#         marker_cc35c3dce0a4924f2031dc294392aaef.bindPopup(popup_99e00d203e18f318ad0f4dd00d14be28)
#         ;
#
#
#
#
#             var marker_819861a641f88de03580089dc6604bfd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fb530b4ae7f2f15cad7893e3580374de);
#
#
#         var popup_7960b71c3ccd2771aef1f91298928272 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6a9a59c1fc01afbd44e19759cdc0b20 = $(`&lt;div id=&quot;html_e6a9a59c1fc01afbd44e19759cdc0b20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7960b71c3ccd2771aef1f91298928272.setContent(html_e6a9a59c1fc01afbd44e19759cdc0b20);
#
#
#
#         marker_819861a641f88de03580089dc6604bfd.bindPopup(popup_7960b71c3ccd2771aef1f91298928272)
#         ;
#
#
#
#
#             var marker_f7f6164771084159e770d72ad2e93906 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fb530b4ae7f2f15cad7893e3580374de);
#
#
#         var popup_34379412a21c70c8dd88459fb4b722b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bd11535f1dfc3b80427f5a6cb66dc1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bd11535f1dfc3b80427f5a6cb66dc1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bd11535f1dfc3b80427f5a6cb66dc1f = L.map(
#                 &quot;map_4bd11535f1dfc3b80427f5a6cb66dc1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30530728d56ed1221127f9faf0761131 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30530728d56ed1221127f9faf0761131.addTo(map_4bd11535f1dfc3b80427f5a6cb66dc1f);
#
#
#             var feature_group_06a20884388290fb484c1bfcd3782138 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_06a20884388290fb484c1bfcd3782138.addTo(map_4bd11535f1dfc3b80427f5a6cb66dc1f);
#
#
#             var feature_group_sub_group_20816d6accfe700fcf1f94fddc261d4b = L.featureGroup.subGroup(
#                 feature_group_06a20884388290fb484c1bfcd3782138
#             );
#
#
#             var marker_b44bd2267f48d3a7a4b9a13bbc25fdd2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_20816d6accfe700fcf1f94fddc261d4b);
#
#
#         var popup_47666e1f8ba16a25c3937b9988a3aae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_423a2ae6472d28ef6d891071eddc9683 = $(`&lt;div id=&quot;html_423a2ae6472d28ef6d891071eddc9683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_47666e1f8ba16a25c3937b9988a3aae7.setContent(html_423a2ae6472d28ef6d891071eddc9683);
#
#
#
#         marker_b44bd2267f48d3a7a4b9a13bbc25fdd2.bindPopup(popup_47666e1f8ba16a25c3937b9988a3aae7)
#         ;
#
#
#
#
#             var marker_2f3d06659d4e3125ba3fa46957c1493c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_20816d6accfe700fcf1f94fddc261d4b);
#
#
#         var popup_05a2c76872efd0f498169294703dac37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe88aa22623831f4940247e0aca0f727 = $(`&lt;div id=&quot;html_fe88aa22623831f4940247e0aca0f727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_05a2c76872efd0f498169294703dac37.setContent(html_fe88aa22623831f4940247e0aca0f727);
#
#
#
#         marker_2f3d06659d4e3125ba3fa46957c1493c.bindPopup(popup_05a2c76872efd0f498169294703dac37)
#         ;
#
#
#
#
#             var marker_6da2f943fbbe6656a71d109d83a3add3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_20816d6accfe700fcf1f94fddc261d4b);
#
#
#         var popup_149c5bbc3bd6b5a6a9f295e27ee31827 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a303df2c941e3e254d0c8c25c992ed5 = $(`&lt;div id=&quot;html_9a303df2c941e3e254d0c8c25c992ed5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_149c5bbc3bd6b5a6a9f295e27ee31827.setContent(html_9a303df2c941e3e254d0c8c25c992ed5);
#
#
#
#         marker_6da2f943fbbe6656a71d109d83a3add3.bindPopup(popup_149c5bbc3bd6b5a6a9f295e27ee31827)
#         ;
#
#
#
#
#             var marker_98cfe158382b3a2712ea45c6d4d646ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_20816d6accfe700fcf1f94fddc261d4b);
#
#
#         var popup_67ce0527c4d52417a5e190ed0f5a35e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_310eae7dd4c4aa36b40759d4ed5fe683 = $(`&lt;div id=&quot;html_310eae7dd4c4aa36b40759d4ed5fe683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_67ce0527c4d52417a5e190ed0f5a35e3.setContent(html_310eae7dd4c4aa36b40759d4ed5fe683);
#
#
#
#         marker_
