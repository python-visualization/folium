# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_294afff279c47a656101b4a588e7097f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_294afff279c47a656101b4a588e7097f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_294afff279c47a656101b4a588e7097f = L.map(
#                 &quot;map_294afff279c47a656101b4a588e7097f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ea319a0c38b2780f8d8c4576f8715b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ea319a0c38b2780f8d8c4576f8715b9.addTo(map_294afff279c47a656101b4a588e7097f);
#
#
#             var marker_a78c6a93407f24c68e3d7c1e19b6fbe9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_294afff279c47a656101b4a588e7097f);
#
#
#         var popup_2720300e41140c3ce007a12a8c67936b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf0ce79e552b415dc42dd7ad47b239ef = $(`&lt;div id=&quot;html_cf0ce79e552b415dc42dd7ad47b239ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2720300e41140c3ce007a12a8c67936b.setContent(html_cf0ce79e552b415dc42dd7ad47b239ef);
#
#
#
#         marker_a78c6a93407f24c68e3d7c1e19b6fbe9.bindPopup(popup_2720300e41140c3ce007a12a8c67936b)
#         ;
#
#
#
#
#             var marker_df081ab5013f5713aa64e4cc13f8aa71 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_294afff279c47a656101b4a588e7097f);
#
#
#         var popup_c20f586765ca94a5a5a0146dce1d783d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6f77fe95062262ca49e281d9c870cc3 = $(`&lt;div id=&quot;html_a6f77fe95062262ca49e281d9c870cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c20f586765ca94a5a5a0146dce1d783d.setContent(html_a6f77fe95062262ca49e281d9c870cc3);
#
#
#
#         marker_df081ab5013f5713aa64e4cc13f8aa71.bindPopup(popup_c20f586765ca94a5a5a0146dce1d783d)
#         ;
#
#
#
#
#             var marker_8740fb59e962b95ad4b47be65ca0e947 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_294afff279c47a656101b4a588e7097f);
#
#
#         var popup_4a24e72c42728c66ec6eadecceef2b50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e28fca9034cd2cf52c15fb6cef282d6 = $(`&lt;div id=&quot;html_9e28fca9034cd2cf52c15fb6cef282d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4a24e72c42728c66ec6eadecceef2b50.setContent(html_9e28fca9034cd2cf52c15fb6cef282d6);
#
#
#
#         marker_8740fb59e962b95ad4b47be65ca0e947.bindPopup(popup_4a24e72c42728c66ec6eadecceef2b50)
#         ;
#
#
#
#
#             var marker_bbbb6c43fe5df654286bd01c1edf5aea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_294afff279c47a656101b4a588e7097f);
#
#
#         var popup_1a02b5392451d9e31ec2a0da91b90144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_939a769e717d21e7dec42848f740ac93 = $(`&lt;div id=&quot;html_939a769e717d21e7dec42848f740ac93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1a02b5392451d9e31ec2a0da91b90144.setContent(html_939a769e717d21e7dec42848f740ac93);
#
#
#
#         marker_bbbb6c43fe5df654286bd01c1edf5aea.bindPopup(popup_1a02b5392451d9e31ec2a0da91b90144)
#         ;
#
#
#
#
#             var marker_8ed560c7a948cc7f041fd1d0e9340dd7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_294afff279c47a656101b4a588e7097f);
#
#
#         var popup_e7b5cf0123b6baff84dd1ba0c210a106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f06f0ea73040d5673e75b95d871cca6 = $(`&lt;div id=&quot;html_7f06f0ea73040d5673e75b95d871cca6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e7b5cf0123b6baff84dd1ba0c210a106.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3c98377e8cd2a222ed3f59e1fbe2f0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3c98377e8cd2a222ed3f59e1fbe2f0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3c98377e8cd2a222ed3f59e1fbe2f0f = L.map(
#                 &quot;map_d3c98377e8cd2a222ed3f59e1fbe2f0f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22709c906baff1ed09fea9371522efe6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22709c906baff1ed09fea9371522efe6.addTo(map_d3c98377e8cd2a222ed3f59e1fbe2f0f);
#
#
#             var feature_group_0d957b0fbb2f5312f3321780e9bfd196 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0653de759369e3f46be9c26b007df199 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0d957b0fbb2f5312f3321780e9bfd196);
#
#
#         var popup_a6449c461fcacd49629831f3c9b3332d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_293f44174f6bb026049a9a61891164ef = $(`&lt;div id=&quot;html_293f44174f6bb026049a9a61891164ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a6449c461fcacd49629831f3c9b3332d.setContent(html_293f44174f6bb026049a9a61891164ef);
#
#
#
#         marker_0653de759369e3f46be9c26b007df199.bindPopup(popup_a6449c461fcacd49629831f3c9b3332d)
#         ;
#
#
#
#
#             var marker_2879746405b1bf24e62e49bea957744b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0d957b0fbb2f5312f3321780e9bfd196);
#
#
#         var popup_2c57b631536f01711723522218111656 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3247a7229198fe1de9e678a1acb9cc96 = $(`&lt;div id=&quot;html_3247a7229198fe1de9e678a1acb9cc96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2c57b631536f01711723522218111656.setContent(html_3247a7229198fe1de9e678a1acb9cc96);
#
#
#
#         marker_2879746405b1bf24e62e49bea957744b.bindPopup(popup_2c57b631536f01711723522218111656)
#         ;
#
#
#
#
#             var marker_caf06a8de54ffb353dbd57475ecd49a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0d957b0fbb2f5312f3321780e9bfd196);
#
#
#         var popup_d6a6eec3858ae5aa68cfb41701142a23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e822257195f79030c2d84e45c99b841a = $(`&lt;div id=&quot;html_e822257195f79030c2d84e45c99b841a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d6a6eec3858ae5aa68cfb41701142a23.setContent(html_e822257195f79030c2d84e45c99b841a);
#
#
#
#         marker_caf06a8de54ffb353dbd57475ecd49a4.bindPopup(popup_d6a6eec3858ae5aa68cfb41701142a23)
#         ;
#
#
#
#
#             var marker_9c73b284212084dabc3463942d953d96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0d957b0fbb2f5312f3321780e9bfd196);
#
#
#         var popup_418b9583af8e58ce0e664a11465f2685 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5894d7dbf72f17894124967a4f5258d6 = $(`&lt;div id=&quot;html_5894d7dbf72f17894124967a4f5258d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_418b9583af8e58ce0e664a11465f2685.setContent(html_5894d7dbf72f17894124967a4f5258d6);
#
#
#
#         marker_9c73b284212084dabc3463942d953d96.bindPopup(popup_418b9583af8e58ce0e664a11465f2685)
#         ;
#
#
#
#
#             var marker_d30c682b49ea32462308a2f25ae81a66 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0d957b0fbb2f5312f3321780e9bfd196);
#
#
#         var popup_08593f006405159b54f2ffd884452d82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91394c599f612b64422f07521c5ed67b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91394c599f612b64422f07521c5ed67b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91394c599f612b64422f07521c5ed67b = L.map(
#                 &quot;map_91394c599f612b64422f07521c5ed67b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17e6b41a0623f0fcbfac2d02a6285cc9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17e6b41a0623f0fcbfac2d02a6285cc9.addTo(map_91394c599f612b64422f07521c5ed67b);
#
#
#             var feature_group_0fdfda394f85d892b214e6e7f9c958bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0fdfda394f85d892b214e6e7f9c958bd.addTo(map_91394c599f612b64422f07521c5ed67b);
#
#
#             var feature_group_sub_group_2033d1c62e60cfe3e8e79a5a11cd8fa2 = L.featureGroup.subGroup(
#                 feature_group_0fdfda394f85d892b214e6e7f9c958bd
#             );
#
#
#             var marker_34ee8f8d9421d9dbdaa2792fa90a20f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2033d1c62e60cfe3e8e79a5a11cd8fa2);
#
#
#         var popup_0eca9bfe4c7f954781721763de122cf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_defe289760379ae668420661c8ca6ecb = $(`&lt;div id=&quot;html_defe289760379ae668420661c8ca6ecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0eca9bfe4c7f954781721763de122cf7.setContent(html_defe289760379ae668420661c8ca6ecb);
#
#
#
#         marker_34ee8f8d9421d9dbdaa2792fa90a20f3.bindPopup(popup_0eca9bfe4c7f954781721763de122cf7)
#         ;
#
#
#
#
#             var marker_69ca7a2f3ac74db50406d94bbb07ed65 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2033d1c62e60cfe3e8e79a5a11cd8fa2);
#
#
#         var popup_95d63e03cedc16517e7cd3cab83a8ef9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f32f97e02dbd5aab8e7bd4400221689a = $(`&lt;div id=&quot;html_f32f97e02dbd5aab8e7bd4400221689a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_95d63e03cedc16517e7cd3cab83a8ef9.setContent(html_f32f97e02dbd5aab8e7bd4400221689a);
#
#
#
#         marker_69ca7a2f3ac74db50406d94bbb07ed65.bindPopup(popup_95d63e03cedc16517e7cd3cab83a8ef9)
#         ;
#
#
#
#
#             var marker_ad32f674094ae6b3f97658d3992490ca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2033d1c62e60cfe3e8e79a5a11cd8fa2);
#
#
#         var popup_60de3e04446b9be2f9e5c6e0f3731773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b9428e4910eead2d4371eb9e4dc4ac5 = $(`&lt;div id=&quot;html_5b9428e4910eead2d4371eb9e4dc4ac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_60de3e04446b9be2f9e5c6e0f3731773.setContent(html_5b9428e4910eead2d4371eb9e4dc4ac5);
#
#
#
#         marker_ad32f674094ae6b3f97658d3992490ca.bindPopup(popup_60de3e04446b9be2f9e5c6e0f3731773)
#         ;
#
#
#
#
#             var marker_ee59976bd081c44179b3787799218bf4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2033d1c62e60cfe3e8e79a5a11cd8fa2);
#
#
#         var popup_3fc537fcbdf16ac446486e543c412596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1464d6760f83ec78efe29cbb995ad9d1 = $(`&lt;div id=&quot;html_1464d6760f83ec78efe29cbb995ad9d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3fc537fcbdf16ac446486e543c412596.setContent(html_1464d6760f83ec78efe29cbb995ad9d1);
#
#
#
#         marker_
