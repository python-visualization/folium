# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a149419cb95a61b31cd7bdf8af560c66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a149419cb95a61b31cd7bdf8af560c66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a149419cb95a61b31cd7bdf8af560c66 = L.map(
#                 &quot;map_a149419cb95a61b31cd7bdf8af560c66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b9326b8742df10047ace6ec6643e32d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b9326b8742df10047ace6ec6643e32d.addTo(map_a149419cb95a61b31cd7bdf8af560c66);
#
#
#             var marker_c1a2e56a915d81e30b70afc5b36514a1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a149419cb95a61b31cd7bdf8af560c66);
#
#
#         var popup_a96a96fed6abce4b4fe9cbbe68774791 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03660ccd4b9a2c54a6e211b6a4d49131 = $(`&lt;div id=&quot;html_03660ccd4b9a2c54a6e211b6a4d49131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a96a96fed6abce4b4fe9cbbe68774791.setContent(html_03660ccd4b9a2c54a6e211b6a4d49131);
#
#
#
#         marker_c1a2e56a915d81e30b70afc5b36514a1.bindPopup(popup_a96a96fed6abce4b4fe9cbbe68774791)
#         ;
#
#
#
#
#             var marker_39c4818bc33865e9c6db9c6b8c6a8fb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a149419cb95a61b31cd7bdf8af560c66);
#
#
#         var popup_33c9f191a0ca2d9bfac779dbb9061a5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6ab55631da1094b152faa9d00b94e8b = $(`&lt;div id=&quot;html_c6ab55631da1094b152faa9d00b94e8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_33c9f191a0ca2d9bfac779dbb9061a5c.setContent(html_c6ab55631da1094b152faa9d00b94e8b);
#
#
#
#         marker_39c4818bc33865e9c6db9c6b8c6a8fb9.bindPopup(popup_33c9f191a0ca2d9bfac779dbb9061a5c)
#         ;
#
#
#
#
#             var marker_e87d923f8c1c8a45fa37d8c824a2b7c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a149419cb95a61b31cd7bdf8af560c66);
#
#
#         var popup_1aaa1ef377cca9bd7a44deed6714c238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3867319de5d64bd1a245c91c69a4ed74 = $(`&lt;div id=&quot;html_3867319de5d64bd1a245c91c69a4ed74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1aaa1ef377cca9bd7a44deed6714c238.setContent(html_3867319de5d64bd1a245c91c69a4ed74);
#
#
#
#         marker_e87d923f8c1c8a45fa37d8c824a2b7c7.bindPopup(popup_1aaa1ef377cca9bd7a44deed6714c238)
#         ;
#
#
#
#
#             var marker_814815c13226878aa845bd9b871361e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a149419cb95a61b31cd7bdf8af560c66);
#
#
#         var popup_d08e494d49b5f14d4286dcdbc64a8382 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_524259b00a74d4d1a9a2ac3bdffdedf1 = $(`&lt;div id=&quot;html_524259b00a74d4d1a9a2ac3bdffdedf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d08e494d49b5f14d4286dcdbc64a8382.setContent(html_524259b00a74d4d1a9a2ac3bdffdedf1);
#
#
#
#         marker_814815c13226878aa845bd9b871361e5.bindPopup(popup_d08e494d49b5f14d4286dcdbc64a8382)
#         ;
#
#
#
#
#             var marker_008d4267fa41a54c1edd74b0933e4f8d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a149419cb95a61b31cd7bdf8af560c66);
#
#
#         var popup_61fe5d81b9967b80724f44cba2eb4155 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0fa3daa6d1a1cfa9a7b1bdccdb6e867 = $(`&lt;div id=&quot;html_f0fa3daa6d1a1cfa9a7b1bdccdb6e867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_61fe5d81b9967b80724f44cba2eb4155.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bebbc5db40b43d9dcfe64d1ee0e3c985 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bebbc5db40b43d9dcfe64d1ee0e3c985&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bebbc5db40b43d9dcfe64d1ee0e3c985 = L.map(
#                 &quot;map_bebbc5db40b43d9dcfe64d1ee0e3c985&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_178503f3e0e3500dd1fe5b9f9919ab68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_178503f3e0e3500dd1fe5b9f9919ab68.addTo(map_bebbc5db40b43d9dcfe64d1ee0e3c985);
#
#
#             var feature_group_5617b71f4178dc1cea19dd59c9c4d6ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7ce6bc82a8693e834e09c9d17950d3a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5617b71f4178dc1cea19dd59c9c4d6ba);
#
#
#         var popup_94811f77220748bb7b9570ab751da23c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8df47f7917895cfc114cb4df8464e58d = $(`&lt;div id=&quot;html_8df47f7917895cfc114cb4df8464e58d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_94811f77220748bb7b9570ab751da23c.setContent(html_8df47f7917895cfc114cb4df8464e58d);
#
#
#
#         marker_7ce6bc82a8693e834e09c9d17950d3a3.bindPopup(popup_94811f77220748bb7b9570ab751da23c)
#         ;
#
#
#
#
#             var marker_fb047afc9cf58a24e7a4b5d3aa5a46dd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5617b71f4178dc1cea19dd59c9c4d6ba);
#
#
#         var popup_b869ea0571777fd0fb1de1aff170c5e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b1cd10b9d6f884869fd7004806c0e5c = $(`&lt;div id=&quot;html_3b1cd10b9d6f884869fd7004806c0e5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b869ea0571777fd0fb1de1aff170c5e6.setContent(html_3b1cd10b9d6f884869fd7004806c0e5c);
#
#
#
#         marker_fb047afc9cf58a24e7a4b5d3aa5a46dd.bindPopup(popup_b869ea0571777fd0fb1de1aff170c5e6)
#         ;
#
#
#
#
#             var marker_716b20ed8b5074f375b4a82ee5aa0bcb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5617b71f4178dc1cea19dd59c9c4d6ba);
#
#
#         var popup_a0b6494f4ed21666a8e4e6e6c65d92eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c39b7a67c28c573a02de294619cc630e = $(`&lt;div id=&quot;html_c39b7a67c28c573a02de294619cc630e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a0b6494f4ed21666a8e4e6e6c65d92eb.setContent(html_c39b7a67c28c573a02de294619cc630e);
#
#
#
#         marker_716b20ed8b5074f375b4a82ee5aa0bcb.bindPopup(popup_a0b6494f4ed21666a8e4e6e6c65d92eb)
#         ;
#
#
#
#
#             var marker_5d833d55d4dd3eb03959c6770bba34e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5617b71f4178dc1cea19dd59c9c4d6ba);
#
#
#         var popup_e0087222f0d29f8d95278ea718814769 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b399fea82665cb96d62963cdd42fc3ad = $(`&lt;div id=&quot;html_b399fea82665cb96d62963cdd42fc3ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e0087222f0d29f8d95278ea718814769.setContent(html_b399fea82665cb96d62963cdd42fc3ad);
#
#
#
#         marker_5d833d55d4dd3eb03959c6770bba34e8.bindPopup(popup_e0087222f0d29f8d95278ea718814769)
#         ;
#
#
#
#
#             var marker_cdeb07273ae4281c623db9ea6f76e2d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5617b71f4178dc1cea19dd59c9c4d6ba);
#
#
#         var popup_3b28eb050ea1f980bf6418b6012c34a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d467b5747ba247808caf09fbf95c5b4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d467b5747ba247808caf09fbf95c5b4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d467b5747ba247808caf09fbf95c5b4c = L.map(
#                 &quot;map_d467b5747ba247808caf09fbf95c5b4c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4cbf75ce257f5b2d86cca7dc3bd6082 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4cbf75ce257f5b2d86cca7dc3bd6082.addTo(map_d467b5747ba247808caf09fbf95c5b4c);
#
#
#             var feature_group_2cd5113a58f8d204e63de86e1501d42a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2cd5113a58f8d204e63de86e1501d42a.addTo(map_d467b5747ba247808caf09fbf95c5b4c);
#
#
#             var feature_group_sub_group_ba43869e56f154d2806ac9ea51301a1b = L.featureGroup.subGroup(
#                 feature_group_2cd5113a58f8d204e63de86e1501d42a
#             );
#
#
#             var marker_bd8b61dcce2f4313fd68ad11dd86a912 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba43869e56f154d2806ac9ea51301a1b);
#
#
#         var popup_d5f88bfb0661f55b86245eda87ab7dba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3d12029c4e3002e375b85a44988d049 = $(`&lt;div id=&quot;html_e3d12029c4e3002e375b85a44988d049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d5f88bfb0661f55b86245eda87ab7dba.setContent(html_e3d12029c4e3002e375b85a44988d049);
#
#
#
#         marker_bd8b61dcce2f4313fd68ad11dd86a912.bindPopup(popup_d5f88bfb0661f55b86245eda87ab7dba)
#         ;
#
#
#
#
#             var marker_3f4dc409c08885b1a8ccb3dc108703af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba43869e56f154d2806ac9ea51301a1b);
#
#
#         var popup_461273e1bdc6087faaff50ab7e3d5d83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d85caeb8ac1400997263fc2de79d6ae = $(`&lt;div id=&quot;html_6d85caeb8ac1400997263fc2de79d6ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_461273e1bdc6087faaff50ab7e3d5d83.setContent(html_6d85caeb8ac1400997263fc2de79d6ae);
#
#
#
#         marker_3f4dc409c08885b1a8ccb3dc108703af.bindPopup(popup_461273e1bdc6087faaff50ab7e3d5d83)
#         ;
#
#
#
#
#             var marker_2ec5a6a118b173b7b0c2c8876d9ed4c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba43869e56f154d2806ac9ea51301a1b);
#
#
#         var popup_ddb88e00eb77cc18dd1874ebf2833e78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4120a1058471dac2a4ed0b4511b4b2ad = $(`&lt;div id=&quot;html_4120a1058471dac2a4ed0b4511b4b2ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ddb88e00eb77cc18dd1874ebf2833e78.setContent(html_4120a1058471dac2a4ed0b4511b4b2ad);
#
#
#
#         marker_2ec5a6a118b173b7b0c2c8876d9ed4c8.bindPopup(popup_ddb88e00eb77cc18dd1874ebf2833e78)
#         ;
#
#
#
#
#             var marker_fec075f53881b44e8a0c5ce5ea6fad86 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba43869e56f154d2806ac9ea51301a1b);
#
#
#         var popup_82cd0748c33b218b9d89d4311dfcbb35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3763019bdc2a753f72fdaaddcfc2e645 = $(`&lt;div id=&quot;html_3763019bdc2a753f72fdaaddcfc2e645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_82cd0748c33b218b9d89d4311dfcbb35.setContent(html_3763019bdc2a753f72fdaaddcfc2e645);
#
#
#
#         marker_
