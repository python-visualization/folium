# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a129273543c48e5b2e327b2bcc7b385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a129273543c48e5b2e327b2bcc7b385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a129273543c48e5b2e327b2bcc7b385 = L.map(
#                 &quot;map_0a129273543c48e5b2e327b2bcc7b385&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77a4b95190c6ffc1f794588b26cc81d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77a4b95190c6ffc1f794588b26cc81d7.addTo(map_0a129273543c48e5b2e327b2bcc7b385);
#
#
#             var marker_25c1adc1145a201890f6d00a53d60bb6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0a129273543c48e5b2e327b2bcc7b385);
#
#
#         var popup_55fc63e392970eedd59b59b3effa8b80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e390e5d082daba47e1e59bd64ec7067b = $(`&lt;div id=&quot;html_e390e5d082daba47e1e59bd64ec7067b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_55fc63e392970eedd59b59b3effa8b80.setContent(html_e390e5d082daba47e1e59bd64ec7067b);
#
#
#
#         marker_25c1adc1145a201890f6d00a53d60bb6.bindPopup(popup_55fc63e392970eedd59b59b3effa8b80)
#         ;
#
#
#
#
#             var marker_55e769ff99c9dafb3907f18e5528364c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0a129273543c48e5b2e327b2bcc7b385);
#
#
#         var popup_09e442ebb7a888f89a902016ac8e31af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_689e645ae0b321663e25349a71a53e2a = $(`&lt;div id=&quot;html_689e645ae0b321663e25349a71a53e2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_09e442ebb7a888f89a902016ac8e31af.setContent(html_689e645ae0b321663e25349a71a53e2a);
#
#
#
#         marker_55e769ff99c9dafb3907f18e5528364c.bindPopup(popup_09e442ebb7a888f89a902016ac8e31af)
#         ;
#
#
#
#
#             var marker_5545c2f57519a0ce8cd0777e2c1714d6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0a129273543c48e5b2e327b2bcc7b385);
#
#
#         var popup_57615584581b99b04852f1ca4c98a91c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7b3344fce6dc839dd363c3c5c0b321d = $(`&lt;div id=&quot;html_b7b3344fce6dc839dd363c3c5c0b321d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_57615584581b99b04852f1ca4c98a91c.setContent(html_b7b3344fce6dc839dd363c3c5c0b321d);
#
#
#
#         marker_5545c2f57519a0ce8cd0777e2c1714d6.bindPopup(popup_57615584581b99b04852f1ca4c98a91c)
#         ;
#
#
#
#
#             var marker_de8be32296b1a623bc1f12501916f986 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0a129273543c48e5b2e327b2bcc7b385);
#
#
#         var popup_aa1410a47adafff1614814376eebd72d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9695f7bac0637e516794eb9bd65ba6 = $(`&lt;div id=&quot;html_dc9695f7bac0637e516794eb9bd65ba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aa1410a47adafff1614814376eebd72d.setContent(html_dc9695f7bac0637e516794eb9bd65ba6);
#
#
#
#         marker_de8be32296b1a623bc1f12501916f986.bindPopup(popup_aa1410a47adafff1614814376eebd72d)
#         ;
#
#
#
#
#             var marker_95c2f96d86846831cc6210e20eae5a75 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0a129273543c48e5b2e327b2bcc7b385);
#
#
#         var popup_846e178b761cea137639b793456b0ad7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91276d6ac5198d35bee6deecdbd9ce95 = $(`&lt;div id=&quot;html_91276d6ac5198d35bee6deecdbd9ce95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_846e178b761cea137639b793456b0ad7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_275d98a6bfb73cd5e2daef34de14be69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_275d98a6bfb73cd5e2daef34de14be69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_275d98a6bfb73cd5e2daef34de14be69 = L.map(
#                 &quot;map_275d98a6bfb73cd5e2daef34de14be69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dc8aa19b78dae2ed2d44f5dbbf4a1f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9dc8aa19b78dae2ed2d44f5dbbf4a1f9.addTo(map_275d98a6bfb73cd5e2daef34de14be69);
#
#
#             var feature_group_1dc2fd362bc5447162277d7437f67001 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a92bdcc608874a5472deaa9101d7fe54 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1dc2fd362bc5447162277d7437f67001);
#
#
#         var popup_173c2078763245353f5497ba2f273d0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_461e0c1e50a59c61c4adf9a577c027fd = $(`&lt;div id=&quot;html_461e0c1e50a59c61c4adf9a577c027fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_173c2078763245353f5497ba2f273d0f.setContent(html_461e0c1e50a59c61c4adf9a577c027fd);
#
#
#
#         marker_a92bdcc608874a5472deaa9101d7fe54.bindPopup(popup_173c2078763245353f5497ba2f273d0f)
#         ;
#
#
#
#
#             var marker_f9ad0e36e2a025a219a714ecd90633b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1dc2fd362bc5447162277d7437f67001);
#
#
#         var popup_1b792b8f219788e580550a10b4d41c3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a0dcdbd5a5c38dc65b38926a4265ba7 = $(`&lt;div id=&quot;html_0a0dcdbd5a5c38dc65b38926a4265ba7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1b792b8f219788e580550a10b4d41c3b.setContent(html_0a0dcdbd5a5c38dc65b38926a4265ba7);
#
#
#
#         marker_f9ad0e36e2a025a219a714ecd90633b9.bindPopup(popup_1b792b8f219788e580550a10b4d41c3b)
#         ;
#
#
#
#
#             var marker_ce2c8818e92f3623dd6eb447c7cabda3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1dc2fd362bc5447162277d7437f67001);
#
#
#         var popup_6bbd8ff3d6cae0831d178eba752bec1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e85ca873ee70e986bcd980ee69d2641 = $(`&lt;div id=&quot;html_9e85ca873ee70e986bcd980ee69d2641&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6bbd8ff3d6cae0831d178eba752bec1d.setContent(html_9e85ca873ee70e986bcd980ee69d2641);
#
#
#
#         marker_ce2c8818e92f3623dd6eb447c7cabda3.bindPopup(popup_6bbd8ff3d6cae0831d178eba752bec1d)
#         ;
#
#
#
#
#             var marker_46c44e1dd9f8e8d1ee5d48c8db61f896 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1dc2fd362bc5447162277d7437f67001);
#
#
#         var popup_80bb153e9a1b50f304a506cd9da2ed09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e28adadc8320d268934a3ceab4640ab7 = $(`&lt;div id=&quot;html_e28adadc8320d268934a3ceab4640ab7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_80bb153e9a1b50f304a506cd9da2ed09.setContent(html_e28adadc8320d268934a3ceab4640ab7);
#
#
#
#         marker_46c44e1dd9f8e8d1ee5d48c8db61f896.bindPopup(popup_80bb153e9a1b50f304a506cd9da2ed09)
#         ;
#
#
#
#
#             var marker_e08ed0253bf88e54fd485b434d22471f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1dc2fd362bc5447162277d7437f67001);
#
#
#         var popup_fe1796f3040735ad89b3f7b04b8120dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e6f1519476b12a26553238e912dad2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e6f1519476b12a26553238e912dad2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e6f1519476b12a26553238e912dad2b = L.map(
#                 &quot;map_8e6f1519476b12a26553238e912dad2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77ef0b1671c3d822b0a26496e12ecc9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77ef0b1671c3d822b0a26496e12ecc9b.addTo(map_8e6f1519476b12a26553238e912dad2b);
#
#
#             var feature_group_ca1a606b319b31d190d0eaac58ecfa0c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ca1a606b319b31d190d0eaac58ecfa0c.addTo(map_8e6f1519476b12a26553238e912dad2b);
#
#
#             var feature_group_sub_group_da5d44edd033d6115e8a8c81ff46483f = L.featureGroup.subGroup(
#                 feature_group_ca1a606b319b31d190d0eaac58ecfa0c
#             );
#
#
#             var marker_ad9b59c5ca9dea7a1e7f57ee4274a17a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5d44edd033d6115e8a8c81ff46483f);
#
#
#         var popup_798bded14e80aa3bb899809b6b99f4c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f9e2aff4a8a6f9511a6a36c4c7bab23 = $(`&lt;div id=&quot;html_9f9e2aff4a8a6f9511a6a36c4c7bab23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_798bded14e80aa3bb899809b6b99f4c6.setContent(html_9f9e2aff4a8a6f9511a6a36c4c7bab23);
#
#
#
#         marker_ad9b59c5ca9dea7a1e7f57ee4274a17a.bindPopup(popup_798bded14e80aa3bb899809b6b99f4c6)
#         ;
#
#
#
#
#             var marker_b81027000ea47ef78d2681ab87ed2a7f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5d44edd033d6115e8a8c81ff46483f);
#
#
#         var popup_478d55780eed0ea467ea8b3ed8919ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_915ba7da2a2f5eaf1f8c6b89c8b1e101 = $(`&lt;div id=&quot;html_915ba7da2a2f5eaf1f8c6b89c8b1e101&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_478d55780eed0ea467ea8b3ed8919ee5.setContent(html_915ba7da2a2f5eaf1f8c6b89c8b1e101);
#
#
#
#         marker_b81027000ea47ef78d2681ab87ed2a7f.bindPopup(popup_478d55780eed0ea467ea8b3ed8919ee5)
#         ;
#
#
#
#
#             var marker_ef1b4f2fbf6662dc8cf08b6abc2150ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5d44edd033d6115e8a8c81ff46483f);
#
#
#         var popup_f2c6bd4d3dc01b1b31ef56a603813782 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf2ed9424fd996b2a8e1aa053e296938 = $(`&lt;div id=&quot;html_bf2ed9424fd996b2a8e1aa053e296938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f2c6bd4d3dc01b1b31ef56a603813782.setContent(html_bf2ed9424fd996b2a8e1aa053e296938);
#
#
#
#         marker_ef1b4f2fbf6662dc8cf08b6abc2150ac.bindPopup(popup_f2c6bd4d3dc01b1b31ef56a603813782)
#         ;
#
#
#
#
#             var marker_62837138833d03328a0f51474c6933b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5d44edd033d6115e8a8c81ff46483f);
#
#
#         var popup_1101b8e89f57ced7e79b68e3e0c4f477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cd872ca3c3113987eca10076fd6c128 = $(`&lt;div id=&quot;html_9cd872ca3c3113987eca10076fd6c128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1101b8e89f57ced7e79b68e3e0c4f477.setContent(html_9cd872ca3c3113987eca10076fd6c128);
#
#
#
#         marker_
