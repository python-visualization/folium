# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c338ef7f67395f6ebdfd3ec1c7c17895 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c338ef7f67395f6ebdfd3ec1c7c17895&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c338ef7f67395f6ebdfd3ec1c7c17895 = L.map(
#                 &quot;map_c338ef7f67395f6ebdfd3ec1c7c17895&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23859c54ec2ba97cf3d2655df0764f37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23859c54ec2ba97cf3d2655df0764f37.addTo(map_c338ef7f67395f6ebdfd3ec1c7c17895);
#
#
#             var marker_94cf157cbe9f6cb73b8c4e1791753f11 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c338ef7f67395f6ebdfd3ec1c7c17895);
#
#
#         var popup_ab304bca67fc306099f9bd7da098d6ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7a8919e9342a6bf68dceb0cbcac73b3 = $(`&lt;div id=&quot;html_b7a8919e9342a6bf68dceb0cbcac73b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ab304bca67fc306099f9bd7da098d6ac.setContent(html_b7a8919e9342a6bf68dceb0cbcac73b3);
#
#
#
#         marker_94cf157cbe9f6cb73b8c4e1791753f11.bindPopup(popup_ab304bca67fc306099f9bd7da098d6ac)
#         ;
#
#
#
#
#             var marker_1b4bc4e194654c2908a06a4e6d928beb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c338ef7f67395f6ebdfd3ec1c7c17895);
#
#
#         var popup_a85e9c622b17ce24944f7d2afaa21afe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7398187ada48f46fcf413ad2ed370e3a = $(`&lt;div id=&quot;html_7398187ada48f46fcf413ad2ed370e3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a85e9c622b17ce24944f7d2afaa21afe.setContent(html_7398187ada48f46fcf413ad2ed370e3a);
#
#
#
#         marker_1b4bc4e194654c2908a06a4e6d928beb.bindPopup(popup_a85e9c622b17ce24944f7d2afaa21afe)
#         ;
#
#
#
#
#             var marker_e033d8919a51e8a2bb82267da7ce22da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c338ef7f67395f6ebdfd3ec1c7c17895);
#
#
#         var popup_ffb2eb8594b3d3bbb26da9f11fd843bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0aac37d16146417ac816e35cab11f1b5 = $(`&lt;div id=&quot;html_0aac37d16146417ac816e35cab11f1b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ffb2eb8594b3d3bbb26da9f11fd843bf.setContent(html_0aac37d16146417ac816e35cab11f1b5);
#
#
#
#         marker_e033d8919a51e8a2bb82267da7ce22da.bindPopup(popup_ffb2eb8594b3d3bbb26da9f11fd843bf)
#         ;
#
#
#
#
#             var marker_eb1f06f49a905e2a3b347fbdecc2d8ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c338ef7f67395f6ebdfd3ec1c7c17895);
#
#
#         var popup_bf66fad09ada06b8a3ca3de4ced374f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f0cacc621c90eca3e14b5a5379acb76 = $(`&lt;div id=&quot;html_9f0cacc621c90eca3e14b5a5379acb76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf66fad09ada06b8a3ca3de4ced374f2.setContent(html_9f0cacc621c90eca3e14b5a5379acb76);
#
#
#
#         marker_eb1f06f49a905e2a3b347fbdecc2d8ff.bindPopup(popup_bf66fad09ada06b8a3ca3de4ced374f2)
#         ;
#
#
#
#
#             var marker_d158df9baf01913590a320d7da80e560 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c338ef7f67395f6ebdfd3ec1c7c17895);
#
#
#         var popup_1a2af1130c08b833f70b1d5fb63a2cb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60af36c31951a1ac74552132915a7a74 = $(`&lt;div id=&quot;html_60af36c31951a1ac74552132915a7a74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1a2af1130c08b833f70b1d5fb63a2cb5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01e016aa871a3674e5c05baef545886d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01e016aa871a3674e5c05baef545886d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01e016aa871a3674e5c05baef545886d = L.map(
#                 &quot;map_01e016aa871a3674e5c05baef545886d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8caa93934087a84d4d2a3a546f4b494 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8caa93934087a84d4d2a3a546f4b494.addTo(map_01e016aa871a3674e5c05baef545886d);
#
#
#             var feature_group_ad840a8cf69cbeadec0ec260a0641052 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f33e73c7c40c347371c089a17d553869 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ad840a8cf69cbeadec0ec260a0641052);
#
#
#         var popup_141c1530bca84f15f8e36d23012818a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db480a0667cd37514ee940fc9bfc43e4 = $(`&lt;div id=&quot;html_db480a0667cd37514ee940fc9bfc43e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_141c1530bca84f15f8e36d23012818a6.setContent(html_db480a0667cd37514ee940fc9bfc43e4);
#
#
#
#         marker_f33e73c7c40c347371c089a17d553869.bindPopup(popup_141c1530bca84f15f8e36d23012818a6)
#         ;
#
#
#
#
#             var marker_cecfb66c9c28d24388544c741e1a513e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ad840a8cf69cbeadec0ec260a0641052);
#
#
#         var popup_be084ce1d6b682610e6864f85a266e3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c07a4e86221b3ab23e3c967153937cee = $(`&lt;div id=&quot;html_c07a4e86221b3ab23e3c967153937cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_be084ce1d6b682610e6864f85a266e3f.setContent(html_c07a4e86221b3ab23e3c967153937cee);
#
#
#
#         marker_cecfb66c9c28d24388544c741e1a513e.bindPopup(popup_be084ce1d6b682610e6864f85a266e3f)
#         ;
#
#
#
#
#             var marker_8f14f3730ec3621a4c86d012182a2211 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ad840a8cf69cbeadec0ec260a0641052);
#
#
#         var popup_01cb0858a4e5d1b791a6f65618bca910 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a01d17daa47eef57b9e375d9bc912f1 = $(`&lt;div id=&quot;html_8a01d17daa47eef57b9e375d9bc912f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_01cb0858a4e5d1b791a6f65618bca910.setContent(html_8a01d17daa47eef57b9e375d9bc912f1);
#
#
#
#         marker_8f14f3730ec3621a4c86d012182a2211.bindPopup(popup_01cb0858a4e5d1b791a6f65618bca910)
#         ;
#
#
#
#
#             var marker_deec726b90bb6974d8eba68632223023 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ad840a8cf69cbeadec0ec260a0641052);
#
#
#         var popup_1cbee0ae609aa960e95304939c7421f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1159eface80a7fe374020eac25af893a = $(`&lt;div id=&quot;html_1159eface80a7fe374020eac25af893a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1cbee0ae609aa960e95304939c7421f8.setContent(html_1159eface80a7fe374020eac25af893a);
#
#
#
#         marker_deec726b90bb6974d8eba68632223023.bindPopup(popup_1cbee0ae609aa960e95304939c7421f8)
#         ;
#
#
#
#
#             var marker_2fe28ee0f0750a325c1ac805995d0429 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ad840a8cf69cbeadec0ec260a0641052);
#
#
#         var popup_b7b314e6ae49e386ebedd36aa9162a08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a998a858e454ab389ddc11ccfcf5565 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a998a858e454ab389ddc11ccfcf5565&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a998a858e454ab389ddc11ccfcf5565 = L.map(
#                 &quot;map_2a998a858e454ab389ddc11ccfcf5565&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc353e15ecca04612a03167a7fc6a655 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc353e15ecca04612a03167a7fc6a655.addTo(map_2a998a858e454ab389ddc11ccfcf5565);
#
#
#             var feature_group_2d89794c7dd3dae67a02ad9acae44009 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2d89794c7dd3dae67a02ad9acae44009.addTo(map_2a998a858e454ab389ddc11ccfcf5565);
#
#
#             var feature_group_sub_group_837e9de680ef3c4cca3bf608c31d8b0a = L.featureGroup.subGroup(
#                 feature_group_2d89794c7dd3dae67a02ad9acae44009
#             );
#
#
#             var marker_8e765dd65f5212e98d408f5b52f3a93b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_837e9de680ef3c4cca3bf608c31d8b0a);
#
#
#         var popup_10fb56f40ad1bfa5f14433942ea17f7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_282da664a6b7af3228133b57df018412 = $(`&lt;div id=&quot;html_282da664a6b7af3228133b57df018412&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_10fb56f40ad1bfa5f14433942ea17f7d.setContent(html_282da664a6b7af3228133b57df018412);
#
#
#
#         marker_8e765dd65f5212e98d408f5b52f3a93b.bindPopup(popup_10fb56f40ad1bfa5f14433942ea17f7d)
#         ;
#
#
#
#
#             var marker_d507472f1b81a02e3e9f4da5e8d93049 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_837e9de680ef3c4cca3bf608c31d8b0a);
#
#
#         var popup_2f88edef27d72ab671bab4d0db58901b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16958e185b0a051d3aeb384bdedd9863 = $(`&lt;div id=&quot;html_16958e185b0a051d3aeb384bdedd9863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2f88edef27d72ab671bab4d0db58901b.setContent(html_16958e185b0a051d3aeb384bdedd9863);
#
#
#
#         marker_d507472f1b81a02e3e9f4da5e8d93049.bindPopup(popup_2f88edef27d72ab671bab4d0db58901b)
#         ;
#
#
#
#
#             var marker_c2fab9fc951db3e15676f490bae19117 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_837e9de680ef3c4cca3bf608c31d8b0a);
#
#
#         var popup_a6e5efcf8dd5f31672d82f57404ca91a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2a20ef3d8bca854417f4665ea22b753 = $(`&lt;div id=&quot;html_e2a20ef3d8bca854417f4665ea22b753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a6e5efcf8dd5f31672d82f57404ca91a.setContent(html_e2a20ef3d8bca854417f4665ea22b753);
#
#
#
#         marker_c2fab9fc951db3e15676f490bae19117.bindPopup(popup_a6e5efcf8dd5f31672d82f57404ca91a)
#         ;
#
#
#
#
#             var marker_62a027c6871951c2895ad6001a4c15bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_837e9de680ef3c4cca3bf608c31d8b0a);
#
#
#         var popup_6034f4b9fb70e87c01f6c6f42424f642 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0081f9c280c0f9a8996d9fa0f8653ece = $(`&lt;div id=&quot;html_0081f9c280c0f9a8996d9fa0f8653ece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6034f4b9fb70e87c01f6c6f42424f642.setContent(html_0081f9c280c0f9a8996d9fa0f8653ece);
#
#
#
#         marker_
