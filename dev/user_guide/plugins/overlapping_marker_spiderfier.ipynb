# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8de420aa48979378a0d0daa7f8315448 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8de420aa48979378a0d0daa7f8315448&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8de420aa48979378a0d0daa7f8315448 = L.map(
#                 &quot;map_8de420aa48979378a0d0daa7f8315448&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e67ce5b4805fc46e953db244c66c6af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e67ce5b4805fc46e953db244c66c6af.addTo(map_8de420aa48979378a0d0daa7f8315448);
#
#
#             var marker_ecc7382a48739f0381f3136451edceab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8de420aa48979378a0d0daa7f8315448);
#
#
#         var popup_7b30ee8d371ae0b93e193336ced17718 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f72df56492dfafab16bcb7ac8fabc917 = $(`&lt;div id=&quot;html_f72df56492dfafab16bcb7ac8fabc917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7b30ee8d371ae0b93e193336ced17718.setContent(html_f72df56492dfafab16bcb7ac8fabc917);
#
#
#
#         marker_ecc7382a48739f0381f3136451edceab.bindPopup(popup_7b30ee8d371ae0b93e193336ced17718)
#         ;
#
#
#
#
#             var marker_4bb12b4ecabb363901cab4ddc24127b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8de420aa48979378a0d0daa7f8315448);
#
#
#         var popup_5c642e242aaf64c3074284385a3d3615 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22f9d1995fe48a62a4dadae8bb1751b5 = $(`&lt;div id=&quot;html_22f9d1995fe48a62a4dadae8bb1751b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5c642e242aaf64c3074284385a3d3615.setContent(html_22f9d1995fe48a62a4dadae8bb1751b5);
#
#
#
#         marker_4bb12b4ecabb363901cab4ddc24127b6.bindPopup(popup_5c642e242aaf64c3074284385a3d3615)
#         ;
#
#
#
#
#             var marker_cdb7a001d255e5ae3e7bc5773beacc90 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8de420aa48979378a0d0daa7f8315448);
#
#
#         var popup_f981bcfb3a234f76ea6070ecf9d980e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9567af2672d35cb8c24fbeb7322d087e = $(`&lt;div id=&quot;html_9567af2672d35cb8c24fbeb7322d087e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f981bcfb3a234f76ea6070ecf9d980e1.setContent(html_9567af2672d35cb8c24fbeb7322d087e);
#
#
#
#         marker_cdb7a001d255e5ae3e7bc5773beacc90.bindPopup(popup_f981bcfb3a234f76ea6070ecf9d980e1)
#         ;
#
#
#
#
#             var marker_17bc41b2608c939702efc393930eecdc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8de420aa48979378a0d0daa7f8315448);
#
#
#         var popup_b526b3ca9a56060a3b348c29e45e932c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ae58d801c03f483fa8d4391dd8c480 = $(`&lt;div id=&quot;html_38ae58d801c03f483fa8d4391dd8c480&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b526b3ca9a56060a3b348c29e45e932c.setContent(html_38ae58d801c03f483fa8d4391dd8c480);
#
#
#
#         marker_17bc41b2608c939702efc393930eecdc.bindPopup(popup_b526b3ca9a56060a3b348c29e45e932c)
#         ;
#
#
#
#
#             var marker_1501308d3b1794a8c1cd0ac65712aa60 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8de420aa48979378a0d0daa7f8315448);
#
#
#         var popup_f5a0b6c0405c56cf5f9e3ef5d6261aca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb9e10ab5db99df6685afa726054608d = $(`&lt;div id=&quot;html_cb9e10ab5db99df6685afa726054608d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f5a0b6c0405c56cf5f9e3ef5d6261aca.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce03bc3e16d4d9f96ba74c3551c6fa82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce03bc3e16d4d9f96ba74c3551c6fa82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce03bc3e16d4d9f96ba74c3551c6fa82 = L.map(
#                 &quot;map_ce03bc3e16d4d9f96ba74c3551c6fa82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bc8fe99d88892fbb8e038ed248620c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bc8fe99d88892fbb8e038ed248620c2.addTo(map_ce03bc3e16d4d9f96ba74c3551c6fa82);
#
#
#             var feature_group_ad5b1dffd6ee8d1e67d5f31e78f6bad2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5b5aa03755d1ef17ed8c45bc46ffced9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ad5b1dffd6ee8d1e67d5f31e78f6bad2);
#
#
#         var popup_a47affe1085bcccb3fa5d98cfeed704d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6161fe9b015db5bc64eae5e99bc2eb81 = $(`&lt;div id=&quot;html_6161fe9b015db5bc64eae5e99bc2eb81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a47affe1085bcccb3fa5d98cfeed704d.setContent(html_6161fe9b015db5bc64eae5e99bc2eb81);
#
#
#
#         marker_5b5aa03755d1ef17ed8c45bc46ffced9.bindPopup(popup_a47affe1085bcccb3fa5d98cfeed704d)
#         ;
#
#
#
#
#             var marker_0016c29e01eaa7e99dec41a59f260ed6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ad5b1dffd6ee8d1e67d5f31e78f6bad2);
#
#
#         var popup_0aedc2cfb5bb36cd10251fc5c99c15da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25be75a5710a3f36edfd509f225ea373 = $(`&lt;div id=&quot;html_25be75a5710a3f36edfd509f225ea373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0aedc2cfb5bb36cd10251fc5c99c15da.setContent(html_25be75a5710a3f36edfd509f225ea373);
#
#
#
#         marker_0016c29e01eaa7e99dec41a59f260ed6.bindPopup(popup_0aedc2cfb5bb36cd10251fc5c99c15da)
#         ;
#
#
#
#
#             var marker_29f87ca2ed92e0bc9e5b4662ca226122 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ad5b1dffd6ee8d1e67d5f31e78f6bad2);
#
#
#         var popup_862d2a5131ab332875c796b4e6a586e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8f29d5710f8729d90884c8d692944f8 = $(`&lt;div id=&quot;html_e8f29d5710f8729d90884c8d692944f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_862d2a5131ab332875c796b4e6a586e5.setContent(html_e8f29d5710f8729d90884c8d692944f8);
#
#
#
#         marker_29f87ca2ed92e0bc9e5b4662ca226122.bindPopup(popup_862d2a5131ab332875c796b4e6a586e5)
#         ;
#
#
#
#
#             var marker_a252e5d447c0405e087bb2b2675e0b42 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ad5b1dffd6ee8d1e67d5f31e78f6bad2);
#
#
#         var popup_14f11a3afcc828645b972545e6cbbf55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a837830addc2a170090a263248dc1fb = $(`&lt;div id=&quot;html_9a837830addc2a170090a263248dc1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_14f11a3afcc828645b972545e6cbbf55.setContent(html_9a837830addc2a170090a263248dc1fb);
#
#
#
#         marker_a252e5d447c0405e087bb2b2675e0b42.bindPopup(popup_14f11a3afcc828645b972545e6cbbf55)
#         ;
#
#
#
#
#             var marker_cf7715bc735723bb9ecb4b4ccc4944f6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ad5b1dffd6ee8d1e67d5f31e78f6bad2);
#
#
#         var popup_c9b4aae2c1efef8caeb85bdfccdece26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd88aee998fb905cbd59f365215b6d4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd88aee998fb905cbd59f365215b6d4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd88aee998fb905cbd59f365215b6d4b = L.map(
#                 &quot;map_bd88aee998fb905cbd59f365215b6d4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_826632a33144b6cfd32175e07871513b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_826632a33144b6cfd32175e07871513b.addTo(map_bd88aee998fb905cbd59f365215b6d4b);
#
#
#             var feature_group_b44cbfaad9aca66a6b64ec57cce3edfc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b44cbfaad9aca66a6b64ec57cce3edfc.addTo(map_bd88aee998fb905cbd59f365215b6d4b);
#
#
#             var feature_group_sub_group_5a3a89996bfc612df71c2775a391167e = L.featureGroup.subGroup(
#                 feature_group_b44cbfaad9aca66a6b64ec57cce3edfc
#             );
#
#
#             var marker_4dc7ab89e4fb52e6e62287799247c7cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3a89996bfc612df71c2775a391167e);
#
#
#         var popup_f21c1503f8cf042e7c36be36e407df59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e36ba1329de04f2fb6f3709bae6bef31 = $(`&lt;div id=&quot;html_e36ba1329de04f2fb6f3709bae6bef31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f21c1503f8cf042e7c36be36e407df59.setContent(html_e36ba1329de04f2fb6f3709bae6bef31);
#
#
#
#         marker_4dc7ab89e4fb52e6e62287799247c7cd.bindPopup(popup_f21c1503f8cf042e7c36be36e407df59)
#         ;
#
#
#
#
#             var marker_d66229b2150f3f26a8ba40c181057bca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3a89996bfc612df71c2775a391167e);
#
#
#         var popup_93d7b4c4dce74029aa9fa1caf3668c13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c152d56b777ba2388fe30f0c27d0aa6 = $(`&lt;div id=&quot;html_9c152d56b777ba2388fe30f0c27d0aa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_93d7b4c4dce74029aa9fa1caf3668c13.setContent(html_9c152d56b777ba2388fe30f0c27d0aa6);
#
#
#
#         marker_d66229b2150f3f26a8ba40c181057bca.bindPopup(popup_93d7b4c4dce74029aa9fa1caf3668c13)
#         ;
#
#
#
#
#             var marker_c293860be390f4f6bdb3e3a316119305 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3a89996bfc612df71c2775a391167e);
#
#
#         var popup_0b2b8c9f637ef1ff4e00de536572fa32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1251fcc32c79246f7905d3dee3506ac7 = $(`&lt;div id=&quot;html_1251fcc32c79246f7905d3dee3506ac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0b2b8c9f637ef1ff4e00de536572fa32.setContent(html_1251fcc32c79246f7905d3dee3506ac7);
#
#
#
#         marker_c293860be390f4f6bdb3e3a316119305.bindPopup(popup_0b2b8c9f637ef1ff4e00de536572fa32)
#         ;
#
#
#
#
#             var marker_314f69ff72a6e2cdc7c1cb744730f7cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3a89996bfc612df71c2775a391167e);
#
#
#         var popup_f09685ee34650efc50c168d79ca66513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e08d0bfcfa29bc59eaa89af881367d22 = $(`&lt;div id=&quot;html_e08d0bfcfa29bc59eaa89af881367d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f09685ee34650efc50c168d79ca66513.setContent(html_e08d0bfcfa29bc59eaa89af881367d22);
#
#
#
#         marker_
