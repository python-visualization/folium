# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75d1f3027754d742abd223ddb8418515 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75d1f3027754d742abd223ddb8418515&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75d1f3027754d742abd223ddb8418515 = L.map(
#                 &quot;map_75d1f3027754d742abd223ddb8418515&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c7c4e9be8e6cd63bfc97922a4e02918 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c7c4e9be8e6cd63bfc97922a4e02918.addTo(map_75d1f3027754d742abd223ddb8418515);
#
#
#             var marker_49786ce11e3d0f66be32fad87ec3424d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_75d1f3027754d742abd223ddb8418515);
#
#
#         var popup_653f75f8035d70161265c4094f196776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2ea75b71285aefbe2c00946ab668e5d = $(`&lt;div id=&quot;html_b2ea75b71285aefbe2c00946ab668e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_653f75f8035d70161265c4094f196776.setContent(html_b2ea75b71285aefbe2c00946ab668e5d);
#
#
#
#         marker_49786ce11e3d0f66be32fad87ec3424d.bindPopup(popup_653f75f8035d70161265c4094f196776)
#         ;
#
#
#
#
#             var marker_856d1ec9219c95cdec92ea5bac3b7056 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_75d1f3027754d742abd223ddb8418515);
#
#
#         var popup_b0530365c0ea4a46580f723dc877f5ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7262819ea7ccf4fec237bf2229e57752 = $(`&lt;div id=&quot;html_7262819ea7ccf4fec237bf2229e57752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b0530365c0ea4a46580f723dc877f5ee.setContent(html_7262819ea7ccf4fec237bf2229e57752);
#
#
#
#         marker_856d1ec9219c95cdec92ea5bac3b7056.bindPopup(popup_b0530365c0ea4a46580f723dc877f5ee)
#         ;
#
#
#
#
#             var marker_ff92861e5e7e0c4d8529f21f68b8c301 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_75d1f3027754d742abd223ddb8418515);
#
#
#         var popup_024068b7ce00f5efa96361b3aaa4374c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a2d7c8e02b64e32d794ec410096c449 = $(`&lt;div id=&quot;html_0a2d7c8e02b64e32d794ec410096c449&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_024068b7ce00f5efa96361b3aaa4374c.setContent(html_0a2d7c8e02b64e32d794ec410096c449);
#
#
#
#         marker_ff92861e5e7e0c4d8529f21f68b8c301.bindPopup(popup_024068b7ce00f5efa96361b3aaa4374c)
#         ;
#
#
#
#
#             var marker_dcf3cc415dcbc06a77962fc407690517 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_75d1f3027754d742abd223ddb8418515);
#
#
#         var popup_feffba7b709d9dc7ed1284ddb3d1765b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00294129bc8e4fe1666859f29de3ba32 = $(`&lt;div id=&quot;html_00294129bc8e4fe1666859f29de3ba32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_feffba7b709d9dc7ed1284ddb3d1765b.setContent(html_00294129bc8e4fe1666859f29de3ba32);
#
#
#
#         marker_dcf3cc415dcbc06a77962fc407690517.bindPopup(popup_feffba7b709d9dc7ed1284ddb3d1765b)
#         ;
#
#
#
#
#             var marker_9f6765e1ff06bd34f974742e1626cd4b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_75d1f3027754d742abd223ddb8418515);
#
#
#         var popup_73fad5ca2927aa8cdd7557de424f3155 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7a80dcd6cb591d8a75ec68a1f21762b = $(`&lt;div id=&quot;html_c7a80dcd6cb591d8a75ec68a1f21762b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_73fad5ca2927aa8cdd7557de424f3155.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf6976438f4ce1b7a2a836b81673e6c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf6976438f4ce1b7a2a836b81673e6c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf6976438f4ce1b7a2a836b81673e6c6 = L.map(
#                 &quot;map_cf6976438f4ce1b7a2a836b81673e6c6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67044e561b415a0b4234b9d8fb058109 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67044e561b415a0b4234b9d8fb058109.addTo(map_cf6976438f4ce1b7a2a836b81673e6c6);
#
#
#             var feature_group_7626d52031f8a4dcd8d1bc2d3af8de31 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_50b56fd7ad1f5e324e91b8b8981435a4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7626d52031f8a4dcd8d1bc2d3af8de31);
#
#
#         var popup_398c9ad8477da18c85fc9f2543592bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba00a05cfa6b0e18679754babeedcd63 = $(`&lt;div id=&quot;html_ba00a05cfa6b0e18679754babeedcd63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_398c9ad8477da18c85fc9f2543592bf6.setContent(html_ba00a05cfa6b0e18679754babeedcd63);
#
#
#
#         marker_50b56fd7ad1f5e324e91b8b8981435a4.bindPopup(popup_398c9ad8477da18c85fc9f2543592bf6)
#         ;
#
#
#
#
#             var marker_cd2caa8e7dd46093f8712f016f8403a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7626d52031f8a4dcd8d1bc2d3af8de31);
#
#
#         var popup_e9ee1ea9318973fbe04a01a92fe6570f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21083bc6922f16a0144bea47f8a06923 = $(`&lt;div id=&quot;html_21083bc6922f16a0144bea47f8a06923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e9ee1ea9318973fbe04a01a92fe6570f.setContent(html_21083bc6922f16a0144bea47f8a06923);
#
#
#
#         marker_cd2caa8e7dd46093f8712f016f8403a6.bindPopup(popup_e9ee1ea9318973fbe04a01a92fe6570f)
#         ;
#
#
#
#
#             var marker_22044e588b40eb306b05e7cba807907d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7626d52031f8a4dcd8d1bc2d3af8de31);
#
#
#         var popup_36cd6ed564f62645bc5420943f6887f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44b5c512b7b882c68f584a146f87c927 = $(`&lt;div id=&quot;html_44b5c512b7b882c68f584a146f87c927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_36cd6ed564f62645bc5420943f6887f5.setContent(html_44b5c512b7b882c68f584a146f87c927);
#
#
#
#         marker_22044e588b40eb306b05e7cba807907d.bindPopup(popup_36cd6ed564f62645bc5420943f6887f5)
#         ;
#
#
#
#
#             var marker_b5b2436b9ede60cc9d9f8cdc9fcbeb2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7626d52031f8a4dcd8d1bc2d3af8de31);
#
#
#         var popup_742d7608f6ed5d69a13a3491c1103951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96cb99b1836a123e54222e1186bb17e7 = $(`&lt;div id=&quot;html_96cb99b1836a123e54222e1186bb17e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_742d7608f6ed5d69a13a3491c1103951.setContent(html_96cb99b1836a123e54222e1186bb17e7);
#
#
#
#         marker_b5b2436b9ede60cc9d9f8cdc9fcbeb2f.bindPopup(popup_742d7608f6ed5d69a13a3491c1103951)
#         ;
#
#
#
#
#             var marker_dddcbdad21c677f297749107474ed1a9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7626d52031f8a4dcd8d1bc2d3af8de31);
#
#
#         var popup_eb4a1eea5d974ab04a11b28df90e4d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0e0ef5d99f48b83901019bd8a83052a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0e0ef5d99f48b83901019bd8a83052a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0e0ef5d99f48b83901019bd8a83052a = L.map(
#                 &quot;map_b0e0ef5d99f48b83901019bd8a83052a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4216aeb76ff57e000bfcc04376b21dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4216aeb76ff57e000bfcc04376b21dd.addTo(map_b0e0ef5d99f48b83901019bd8a83052a);
#
#
#             var feature_group_0ccf63ae8353c173c38da55f0efa49c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0ccf63ae8353c173c38da55f0efa49c7.addTo(map_b0e0ef5d99f48b83901019bd8a83052a);
#
#
#             var feature_group_sub_group_8c5115a26e4c0a6136ce98f8f207ad52 = L.featureGroup.subGroup(
#                 feature_group_0ccf63ae8353c173c38da55f0efa49c7
#             );
#
#
#             var marker_03548daf57f85eba221240759466dc64 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c5115a26e4c0a6136ce98f8f207ad52);
#
#
#         var popup_7142d8afadca54d66d7d9beea1a6a0bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f813622616bffeb196c364cf5a3c0f3 = $(`&lt;div id=&quot;html_4f813622616bffeb196c364cf5a3c0f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7142d8afadca54d66d7d9beea1a6a0bb.setContent(html_4f813622616bffeb196c364cf5a3c0f3);
#
#
#
#         marker_03548daf57f85eba221240759466dc64.bindPopup(popup_7142d8afadca54d66d7d9beea1a6a0bb)
#         ;
#
#
#
#
#             var marker_39aad18e59d89382cfdba3e59224b85f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c5115a26e4c0a6136ce98f8f207ad52);
#
#
#         var popup_9d1b1d2b26ca535b87ed5f640aa8c08b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c0e5e7aa0e65b9f914ef9fe2d1a80a1 = $(`&lt;div id=&quot;html_2c0e5e7aa0e65b9f914ef9fe2d1a80a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9d1b1d2b26ca535b87ed5f640aa8c08b.setContent(html_2c0e5e7aa0e65b9f914ef9fe2d1a80a1);
#
#
#
#         marker_39aad18e59d89382cfdba3e59224b85f.bindPopup(popup_9d1b1d2b26ca535b87ed5f640aa8c08b)
#         ;
#
#
#
#
#             var marker_dce5fac410c26e0228a2f7b23e37d144 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c5115a26e4c0a6136ce98f8f207ad52);
#
#
#         var popup_c50842d94af451ac87b6eef497a1bd82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0cd69d85cf838aa43f99f0a2cdcfe80 = $(`&lt;div id=&quot;html_f0cd69d85cf838aa43f99f0a2cdcfe80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c50842d94af451ac87b6eef497a1bd82.setContent(html_f0cd69d85cf838aa43f99f0a2cdcfe80);
#
#
#
#         marker_dce5fac410c26e0228a2f7b23e37d144.bindPopup(popup_c50842d94af451ac87b6eef497a1bd82)
#         ;
#
#
#
#
#             var marker_3bb7c14469891167ce59aca99c9e2c3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c5115a26e4c0a6136ce98f8f207ad52);
#
#
#         var popup_9983a801b6085cf780de01eaed515c63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b39b42ca284f8afcdf3959ca2f5f2430 = $(`&lt;div id=&quot;html_b39b42ca284f8afcdf3959ca2f5f2430&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9983a801b6085cf780de01eaed515c63.setContent(html_b39b42ca284f8afcdf3959ca2f5f2430);
#
#
#
#         marker_
