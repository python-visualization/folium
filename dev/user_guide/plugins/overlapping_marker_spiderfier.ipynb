# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6de7bd3020b6b293542f052372e756d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6de7bd3020b6b293542f052372e756d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6de7bd3020b6b293542f052372e756d = L.map(
#                 &quot;map_d6de7bd3020b6b293542f052372e756d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62eba4bf2468d00aab26173012496871 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62eba4bf2468d00aab26173012496871.addTo(map_d6de7bd3020b6b293542f052372e756d);
#
#
#             var marker_6afef6f45b4c5b050dd9df8090421f68 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d6de7bd3020b6b293542f052372e756d);
#
#
#         var popup_de12908b5ebb3d15876e5b2370fed0fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0bbf651f153361526e95a81dc5c8e37 = $(`&lt;div id=&quot;html_e0bbf651f153361526e95a81dc5c8e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_de12908b5ebb3d15876e5b2370fed0fe.setContent(html_e0bbf651f153361526e95a81dc5c8e37);
#
#
#
#         marker_6afef6f45b4c5b050dd9df8090421f68.bindPopup(popup_de12908b5ebb3d15876e5b2370fed0fe)
#         ;
#
#
#
#
#             var marker_bb5063dac4b62df11451f4bd4df28757 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d6de7bd3020b6b293542f052372e756d);
#
#
#         var popup_52accde5ea973a8c06850d8c89907c79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07013c09ad28a92984d68838e50e4f8a = $(`&lt;div id=&quot;html_07013c09ad28a92984d68838e50e4f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52accde5ea973a8c06850d8c89907c79.setContent(html_07013c09ad28a92984d68838e50e4f8a);
#
#
#
#         marker_bb5063dac4b62df11451f4bd4df28757.bindPopup(popup_52accde5ea973a8c06850d8c89907c79)
#         ;
#
#
#
#
#             var marker_50d5fd4e3f6fa2c91b419690a51a505d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d6de7bd3020b6b293542f052372e756d);
#
#
#         var popup_d3bf6df1aae7f29cb982ce9c12646d95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68a189201d41c234dd93a06b1f68df9e = $(`&lt;div id=&quot;html_68a189201d41c234dd93a06b1f68df9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d3bf6df1aae7f29cb982ce9c12646d95.setContent(html_68a189201d41c234dd93a06b1f68df9e);
#
#
#
#         marker_50d5fd4e3f6fa2c91b419690a51a505d.bindPopup(popup_d3bf6df1aae7f29cb982ce9c12646d95)
#         ;
#
#
#
#
#             var marker_b786a6bf359431175e8a9336cf6d15d4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d6de7bd3020b6b293542f052372e756d);
#
#
#         var popup_270e7ecdcd0d3f1105ea7d3035e96e8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b486659aea678974a386fd2f47df6cf9 = $(`&lt;div id=&quot;html_b486659aea678974a386fd2f47df6cf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_270e7ecdcd0d3f1105ea7d3035e96e8e.setContent(html_b486659aea678974a386fd2f47df6cf9);
#
#
#
#         marker_b786a6bf359431175e8a9336cf6d15d4.bindPopup(popup_270e7ecdcd0d3f1105ea7d3035e96e8e)
#         ;
#
#
#
#
#             var marker_9ae51a6fc88d49939bc418550118d28c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d6de7bd3020b6b293542f052372e756d);
#
#
#         var popup_cae49f2727e5098cdf8b5692d384724a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b87ddc5aac499f2db80610533e203e47 = $(`&lt;div id=&quot;html_b87ddc5aac499f2db80610533e203e47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cae49f2727e5098cdf8b5692d384724a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_403b186546018d5c182dffa42347320c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_403b186546018d5c182dffa42347320c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_403b186546018d5c182dffa42347320c = L.map(
#                 &quot;map_403b186546018d5c182dffa42347320c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e62d888f291dbbb3aac16fa0f053766f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e62d888f291dbbb3aac16fa0f053766f.addTo(map_403b186546018d5c182dffa42347320c);
#
#
#             var feature_group_f637b6164a6a35358781a5343b4ae064 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_44e18a1da41a3f0fd004960b9790c1b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f637b6164a6a35358781a5343b4ae064);
#
#
#         var popup_3fd156bb7f7e0c431b9b27c2795f52d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b15d433626e10ceacb75f1a703af6d0f = $(`&lt;div id=&quot;html_b15d433626e10ceacb75f1a703af6d0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3fd156bb7f7e0c431b9b27c2795f52d5.setContent(html_b15d433626e10ceacb75f1a703af6d0f);
#
#
#
#         marker_44e18a1da41a3f0fd004960b9790c1b2.bindPopup(popup_3fd156bb7f7e0c431b9b27c2795f52d5)
#         ;
#
#
#
#
#             var marker_4b36c304928045a727363608d48a1598 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f637b6164a6a35358781a5343b4ae064);
#
#
#         var popup_4337be593a9bca535408a0635402cf81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40c696267b263e4df9c581e3a21a848f = $(`&lt;div id=&quot;html_40c696267b263e4df9c581e3a21a848f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4337be593a9bca535408a0635402cf81.setContent(html_40c696267b263e4df9c581e3a21a848f);
#
#
#
#         marker_4b36c304928045a727363608d48a1598.bindPopup(popup_4337be593a9bca535408a0635402cf81)
#         ;
#
#
#
#
#             var marker_704086fd7e9be06e425bc4c94b73665c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f637b6164a6a35358781a5343b4ae064);
#
#
#         var popup_9aa8dd66bf371c1c0e5ce96b780ddbbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f42b8e830c370c078fad0b1e57fd3b4d = $(`&lt;div id=&quot;html_f42b8e830c370c078fad0b1e57fd3b4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9aa8dd66bf371c1c0e5ce96b780ddbbf.setContent(html_f42b8e830c370c078fad0b1e57fd3b4d);
#
#
#
#         marker_704086fd7e9be06e425bc4c94b73665c.bindPopup(popup_9aa8dd66bf371c1c0e5ce96b780ddbbf)
#         ;
#
#
#
#
#             var marker_1db65ccb514fa09e2a4c3fb7e0004131 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f637b6164a6a35358781a5343b4ae064);
#
#
#         var popup_2402890f1d5b1d78d1fd6041e613b913 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b8cbb57dfd9cb140bcfb665e185ba7f = $(`&lt;div id=&quot;html_8b8cbb57dfd9cb140bcfb665e185ba7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2402890f1d5b1d78d1fd6041e613b913.setContent(html_8b8cbb57dfd9cb140bcfb665e185ba7f);
#
#
#
#         marker_1db65ccb514fa09e2a4c3fb7e0004131.bindPopup(popup_2402890f1d5b1d78d1fd6041e613b913)
#         ;
#
#
#
#
#             var marker_8c350d657caef9c4e27dc7a9ed5b6965 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f637b6164a6a35358781a5343b4ae064);
#
#
#         var popup_863a33842acf6aa9cf29b5b870c0283e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce3e3e3985424080c5af321e57fbc237 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce3e3e3985424080c5af321e57fbc237&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce3e3e3985424080c5af321e57fbc237 = L.map(
#                 &quot;map_ce3e3e3985424080c5af321e57fbc237&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1108813c393d8a0db0391cb03ad92365 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1108813c393d8a0db0391cb03ad92365.addTo(map_ce3e3e3985424080c5af321e57fbc237);
#
#
#             var feature_group_69429091ea45cb2d74bdb8de5228634a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_69429091ea45cb2d74bdb8de5228634a.addTo(map_ce3e3e3985424080c5af321e57fbc237);
#
#
#             var feature_group_sub_group_d7589df8b1fbfd4754a053a068486a92 = L.featureGroup.subGroup(
#                 feature_group_69429091ea45cb2d74bdb8de5228634a
#             );
#
#
#             var marker_166b4c510d36f31208d78733c8ecc8f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7589df8b1fbfd4754a053a068486a92);
#
#
#         var popup_c4ec13db7deb710dd30c67287127e8a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d82fc3c799db90d23637668c02632de = $(`&lt;div id=&quot;html_6d82fc3c799db90d23637668c02632de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c4ec13db7deb710dd30c67287127e8a9.setContent(html_6d82fc3c799db90d23637668c02632de);
#
#
#
#         marker_166b4c510d36f31208d78733c8ecc8f6.bindPopup(popup_c4ec13db7deb710dd30c67287127e8a9)
#         ;
#
#
#
#
#             var marker_546f2dcdbccb8e7f90e886d14b66eacf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7589df8b1fbfd4754a053a068486a92);
#
#
#         var popup_3ba96e3e5db94e1ac79eff8706d2b973 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_182179addde8df7fa30b68d858e49d8a = $(`&lt;div id=&quot;html_182179addde8df7fa30b68d858e49d8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3ba96e3e5db94e1ac79eff8706d2b973.setContent(html_182179addde8df7fa30b68d858e49d8a);
#
#
#
#         marker_546f2dcdbccb8e7f90e886d14b66eacf.bindPopup(popup_3ba96e3e5db94e1ac79eff8706d2b973)
#         ;
#
#
#
#
#             var marker_a1aef4cf1ab2095a13abd409c14491d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7589df8b1fbfd4754a053a068486a92);
#
#
#         var popup_859f938518250bef6086a36c5a6da55f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f4535f2470f1d2109cdea1121be5657 = $(`&lt;div id=&quot;html_2f4535f2470f1d2109cdea1121be5657&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_859f938518250bef6086a36c5a6da55f.setContent(html_2f4535f2470f1d2109cdea1121be5657);
#
#
#
#         marker_a1aef4cf1ab2095a13abd409c14491d3.bindPopup(popup_859f938518250bef6086a36c5a6da55f)
#         ;
#
#
#
#
#             var marker_b31dae85eaeead3d54668397fbb9765d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7589df8b1fbfd4754a053a068486a92);
#
#
#         var popup_ca168b802c7a4016625b4cda8dc54e85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_577760729635cb8dba7cbda7e38711de = $(`&lt;div id=&quot;html_577760729635cb8dba7cbda7e38711de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ca168b802c7a4016625b4cda8dc54e85.setContent(html_577760729635cb8dba7cbda7e38711de);
#
#
#
#         marker_
