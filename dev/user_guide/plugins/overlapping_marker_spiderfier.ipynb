# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ffb565833cb488d5e066b0cc51f30f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ffb565833cb488d5e066b0cc51f30f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ffb565833cb488d5e066b0cc51f30f4 = L.map(
#                 &quot;map_2ffb565833cb488d5e066b0cc51f30f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e68d89bb94acab698a641bbab1619f1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e68d89bb94acab698a641bbab1619f1e.addTo(map_2ffb565833cb488d5e066b0cc51f30f4);
#
#
#             var marker_422629a2cb8d88020509403d116d8f92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2ffb565833cb488d5e066b0cc51f30f4);
#
#
#         var popup_9039c1102bdd259cc5037de7c4dd6c76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0888bd42c522441a78c5176841e30c46 = $(`&lt;div id=&quot;html_0888bd42c522441a78c5176841e30c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9039c1102bdd259cc5037de7c4dd6c76.setContent(html_0888bd42c522441a78c5176841e30c46);
#
#
#
#         marker_422629a2cb8d88020509403d116d8f92.bindPopup(popup_9039c1102bdd259cc5037de7c4dd6c76)
#         ;
#
#
#
#
#             var marker_97e1c19bffe6d706ed3e43dad240647e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2ffb565833cb488d5e066b0cc51f30f4);
#
#
#         var popup_f609580848a019d7f34baff4e55192a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84015e73f23b7425684885904a876090 = $(`&lt;div id=&quot;html_84015e73f23b7425684885904a876090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f609580848a019d7f34baff4e55192a0.setContent(html_84015e73f23b7425684885904a876090);
#
#
#
#         marker_97e1c19bffe6d706ed3e43dad240647e.bindPopup(popup_f609580848a019d7f34baff4e55192a0)
#         ;
#
#
#
#
#             var marker_84d94f7d5a2a8e5b85a8ca9d79a9832d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2ffb565833cb488d5e066b0cc51f30f4);
#
#
#         var popup_971b6dd86a9d640328193150283eacf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2649197188bfd1ada3bd25d810e5b61a = $(`&lt;div id=&quot;html_2649197188bfd1ada3bd25d810e5b61a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_971b6dd86a9d640328193150283eacf5.setContent(html_2649197188bfd1ada3bd25d810e5b61a);
#
#
#
#         marker_84d94f7d5a2a8e5b85a8ca9d79a9832d.bindPopup(popup_971b6dd86a9d640328193150283eacf5)
#         ;
#
#
#
#
#             var marker_2f6750ad7da69e00d4bae04bfa4d590c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2ffb565833cb488d5e066b0cc51f30f4);
#
#
#         var popup_099484ba3b56a7bfe81c01e2dbbd5736 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e984d9e6b8011ffd8ac4c72950638ae7 = $(`&lt;div id=&quot;html_e984d9e6b8011ffd8ac4c72950638ae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_099484ba3b56a7bfe81c01e2dbbd5736.setContent(html_e984d9e6b8011ffd8ac4c72950638ae7);
#
#
#
#         marker_2f6750ad7da69e00d4bae04bfa4d590c.bindPopup(popup_099484ba3b56a7bfe81c01e2dbbd5736)
#         ;
#
#
#
#
#             var marker_5b31fd5edea3ce7fc2eef46735b173b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2ffb565833cb488d5e066b0cc51f30f4);
#
#
#         var popup_0aca730aaac27910fb4f00b8bfe3cdba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a213648cd0aff2b8ca236942b202965 = $(`&lt;div id=&quot;html_2a213648cd0aff2b8ca236942b202965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0aca730aaac27910fb4f00b8bfe3cdba.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ad5f30809eff6355c4118f95ec7ee40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ad5f30809eff6355c4118f95ec7ee40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ad5f30809eff6355c4118f95ec7ee40 = L.map(
#                 &quot;map_1ad5f30809eff6355c4118f95ec7ee40&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eabbd46a39586a6ed0eeb239260a95b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eabbd46a39586a6ed0eeb239260a95b5.addTo(map_1ad5f30809eff6355c4118f95ec7ee40);
#
#
#             var feature_group_da45fc9d6e6de3aaacbbca55d557bcfc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3873068715f8a221c65eb5a7102ac883 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_da45fc9d6e6de3aaacbbca55d557bcfc);
#
#
#         var popup_5d5f04943a2b82ba41b1dc1b9222a93a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a931746cdcc4eeb40edf5b0f6e0778a7 = $(`&lt;div id=&quot;html_a931746cdcc4eeb40edf5b0f6e0778a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5d5f04943a2b82ba41b1dc1b9222a93a.setContent(html_a931746cdcc4eeb40edf5b0f6e0778a7);
#
#
#
#         marker_3873068715f8a221c65eb5a7102ac883.bindPopup(popup_5d5f04943a2b82ba41b1dc1b9222a93a)
#         ;
#
#
#
#
#             var marker_bcc7c02c3fd970ae312874b8474d09f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_da45fc9d6e6de3aaacbbca55d557bcfc);
#
#
#         var popup_dd70b540331783993952a2f4fdb7a778 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ab22dd3762044907e75504017a65201 = $(`&lt;div id=&quot;html_9ab22dd3762044907e75504017a65201&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dd70b540331783993952a2f4fdb7a778.setContent(html_9ab22dd3762044907e75504017a65201);
#
#
#
#         marker_bcc7c02c3fd970ae312874b8474d09f4.bindPopup(popup_dd70b540331783993952a2f4fdb7a778)
#         ;
#
#
#
#
#             var marker_d854ef3e6247c440b8fc8513a77fbb2e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_da45fc9d6e6de3aaacbbca55d557bcfc);
#
#
#         var popup_01f866345d6274dc735e6ab9d1ae5878 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38c9f81855a88f8622e8c259d05675b2 = $(`&lt;div id=&quot;html_38c9f81855a88f8622e8c259d05675b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_01f866345d6274dc735e6ab9d1ae5878.setContent(html_38c9f81855a88f8622e8c259d05675b2);
#
#
#
#         marker_d854ef3e6247c440b8fc8513a77fbb2e.bindPopup(popup_01f866345d6274dc735e6ab9d1ae5878)
#         ;
#
#
#
#
#             var marker_695c9700276bcc0551dfde7680e9be4a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_da45fc9d6e6de3aaacbbca55d557bcfc);
#
#
#         var popup_85642577fbcf0f9b47d1a03929c51380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00f0f281b19460e6456bbeaea98cd61a = $(`&lt;div id=&quot;html_00f0f281b19460e6456bbeaea98cd61a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_85642577fbcf0f9b47d1a03929c51380.setContent(html_00f0f281b19460e6456bbeaea98cd61a);
#
#
#
#         marker_695c9700276bcc0551dfde7680e9be4a.bindPopup(popup_85642577fbcf0f9b47d1a03929c51380)
#         ;
#
#
#
#
#             var marker_e66ea222617e9014a53d4fa3213afe6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_da45fc9d6e6de3aaacbbca55d557bcfc);
#
#
#         var popup_e14db4a0992e8de615842866411a69e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87bafed8005f1d144115a3819a152b97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87bafed8005f1d144115a3819a152b97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87bafed8005f1d144115a3819a152b97 = L.map(
#                 &quot;map_87bafed8005f1d144115a3819a152b97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa0ed0bfe9dfc43fe2ac54f88df79b43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa0ed0bfe9dfc43fe2ac54f88df79b43.addTo(map_87bafed8005f1d144115a3819a152b97);
#
#
#             var feature_group_6726aaf7af94195c2668af37c8b81450 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6726aaf7af94195c2668af37c8b81450.addTo(map_87bafed8005f1d144115a3819a152b97);
#
#
#             var feature_group_sub_group_9ef9726ff928b1a0189e70bb32f8ff87 = L.featureGroup.subGroup(
#                 feature_group_6726aaf7af94195c2668af37c8b81450
#             );
#
#
#             var marker_ecbae1221402a9e3c77bb0f76debe5a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ef9726ff928b1a0189e70bb32f8ff87);
#
#
#         var popup_98102efd068e1d0cbc55a991e47f152c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_020350159dfb42fa9e6e608a27a29dde = $(`&lt;div id=&quot;html_020350159dfb42fa9e6e608a27a29dde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_98102efd068e1d0cbc55a991e47f152c.setContent(html_020350159dfb42fa9e6e608a27a29dde);
#
#
#
#         marker_ecbae1221402a9e3c77bb0f76debe5a3.bindPopup(popup_98102efd068e1d0cbc55a991e47f152c)
#         ;
#
#
#
#
#             var marker_997caef1da3c5c43e3c3da5ab56cd2a9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ef9726ff928b1a0189e70bb32f8ff87);
#
#
#         var popup_2b83b8524634b3c3e1597920ca8d7ccb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_367cbabba5b4ed8cd3b0792262d1b234 = $(`&lt;div id=&quot;html_367cbabba5b4ed8cd3b0792262d1b234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2b83b8524634b3c3e1597920ca8d7ccb.setContent(html_367cbabba5b4ed8cd3b0792262d1b234);
#
#
#
#         marker_997caef1da3c5c43e3c3da5ab56cd2a9.bindPopup(popup_2b83b8524634b3c3e1597920ca8d7ccb)
#         ;
#
#
#
#
#             var marker_27911eae263ba70f98bcb84b3a9892e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ef9726ff928b1a0189e70bb32f8ff87);
#
#
#         var popup_5160029907782447c10234ae31195bf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c00ce9671efda9614128f037c1209756 = $(`&lt;div id=&quot;html_c00ce9671efda9614128f037c1209756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5160029907782447c10234ae31195bf8.setContent(html_c00ce9671efda9614128f037c1209756);
#
#
#
#         marker_27911eae263ba70f98bcb84b3a9892e6.bindPopup(popup_5160029907782447c10234ae31195bf8)
#         ;
#
#
#
#
#             var marker_3b4c9e2509381e7d28363dabda326779 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ef9726ff928b1a0189e70bb32f8ff87);
#
#
#         var popup_bc663a7cdc72e9d7341c1f841346a1bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38caf4b2f1f61641657acb0010a25caa = $(`&lt;div id=&quot;html_38caf4b2f1f61641657acb0010a25caa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bc663a7cdc72e9d7341c1f841346a1bb.setContent(html_38caf4b2f1f61641657acb0010a25caa);
#
#
#
#         marker_
