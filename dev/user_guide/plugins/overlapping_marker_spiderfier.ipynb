# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec337bce12d269c3bf8b011505d857dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec337bce12d269c3bf8b011505d857dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec337bce12d269c3bf8b011505d857dd = L.map(
#                 &quot;map_ec337bce12d269c3bf8b011505d857dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f89d063477fe4875a0c73995c76e09f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f89d063477fe4875a0c73995c76e09f0.addTo(map_ec337bce12d269c3bf8b011505d857dd);
#
#
#             var marker_4a49de4af5b715fd9c5998cbd5c93271 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ec337bce12d269c3bf8b011505d857dd);
#
#
#         var popup_223d03174eed44e1cf9083a529edd858 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac9e4cf948dd965fc94c2bf9cea35ee1 = $(`&lt;div id=&quot;html_ac9e4cf948dd965fc94c2bf9cea35ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_223d03174eed44e1cf9083a529edd858.setContent(html_ac9e4cf948dd965fc94c2bf9cea35ee1);
#
#
#
#         marker_4a49de4af5b715fd9c5998cbd5c93271.bindPopup(popup_223d03174eed44e1cf9083a529edd858)
#         ;
#
#
#
#
#             var marker_efa0a4b555d3573e3c3d851d6c020572 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ec337bce12d269c3bf8b011505d857dd);
#
#
#         var popup_c69b24d10a176638e87f3e57cc60a232 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_480ddc66457777179bd41d70ad733bc7 = $(`&lt;div id=&quot;html_480ddc66457777179bd41d70ad733bc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c69b24d10a176638e87f3e57cc60a232.setContent(html_480ddc66457777179bd41d70ad733bc7);
#
#
#
#         marker_efa0a4b555d3573e3c3d851d6c020572.bindPopup(popup_c69b24d10a176638e87f3e57cc60a232)
#         ;
#
#
#
#
#             var marker_aafe893af9602749b521dbc79acb9b99 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ec337bce12d269c3bf8b011505d857dd);
#
#
#         var popup_1c25f027e3433c1578161043afccc940 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fbd754992df64bff3edc3bdb47f828c = $(`&lt;div id=&quot;html_4fbd754992df64bff3edc3bdb47f828c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1c25f027e3433c1578161043afccc940.setContent(html_4fbd754992df64bff3edc3bdb47f828c);
#
#
#
#         marker_aafe893af9602749b521dbc79acb9b99.bindPopup(popup_1c25f027e3433c1578161043afccc940)
#         ;
#
#
#
#
#             var marker_107507c3a3ecd300256fe3767b1f4ee1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ec337bce12d269c3bf8b011505d857dd);
#
#
#         var popup_ae4eb2596afcce3051cc6819410cd51a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f9909bf57b49e0d98cd1530a68032ec = $(`&lt;div id=&quot;html_4f9909bf57b49e0d98cd1530a68032ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ae4eb2596afcce3051cc6819410cd51a.setContent(html_4f9909bf57b49e0d98cd1530a68032ec);
#
#
#
#         marker_107507c3a3ecd300256fe3767b1f4ee1.bindPopup(popup_ae4eb2596afcce3051cc6819410cd51a)
#         ;
#
#
#
#
#             var marker_db5735ce2410b6a32ccef5f4f7244d54 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ec337bce12d269c3bf8b011505d857dd);
#
#
#         var popup_86f3116b540c9faa85b3ffdd495d6059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a597a4744c866003bdded71f684e3209 = $(`&lt;div id=&quot;html_a597a4744c866003bdded71f684e3209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_86f3116b540c9faa85b3ffdd495d6059.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a300a7cf847cfd7327a53000bcf2101 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a300a7cf847cfd7327a53000bcf2101&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a300a7cf847cfd7327a53000bcf2101 = L.map(
#                 &quot;map_3a300a7cf847cfd7327a53000bcf2101&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d9a5a02a88fd6bb9d7a088454333f85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d9a5a02a88fd6bb9d7a088454333f85.addTo(map_3a300a7cf847cfd7327a53000bcf2101);
#
#
#             var feature_group_a96cd6d89a31c3185e75e689b80bf7d4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a3ab2ab9586338227def168c1fc5eee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a96cd6d89a31c3185e75e689b80bf7d4);
#
#
#         var popup_21ee54031fdb72657bbf011f087d5d94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63b49ed137f39fbedb17622dad0643cf = $(`&lt;div id=&quot;html_63b49ed137f39fbedb17622dad0643cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_21ee54031fdb72657bbf011f087d5d94.setContent(html_63b49ed137f39fbedb17622dad0643cf);
#
#
#
#         marker_0a3ab2ab9586338227def168c1fc5eee.bindPopup(popup_21ee54031fdb72657bbf011f087d5d94)
#         ;
#
#
#
#
#             var marker_92895ae62c6b1ab4ef9966d59c8feb6e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a96cd6d89a31c3185e75e689b80bf7d4);
#
#
#         var popup_146c812b62dcc196c157d15b44be057f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dca27643176dc54a9e3c464ad3fc5db9 = $(`&lt;div id=&quot;html_dca27643176dc54a9e3c464ad3fc5db9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_146c812b62dcc196c157d15b44be057f.setContent(html_dca27643176dc54a9e3c464ad3fc5db9);
#
#
#
#         marker_92895ae62c6b1ab4ef9966d59c8feb6e.bindPopup(popup_146c812b62dcc196c157d15b44be057f)
#         ;
#
#
#
#
#             var marker_2eb9f6f3366430089bcc9cdd4ca00c93 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a96cd6d89a31c3185e75e689b80bf7d4);
#
#
#         var popup_431104bd1d534bc4406db56824f18acc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bd96d0216c003ab9250e0a966962bad = $(`&lt;div id=&quot;html_4bd96d0216c003ab9250e0a966962bad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_431104bd1d534bc4406db56824f18acc.setContent(html_4bd96d0216c003ab9250e0a966962bad);
#
#
#
#         marker_2eb9f6f3366430089bcc9cdd4ca00c93.bindPopup(popup_431104bd1d534bc4406db56824f18acc)
#         ;
#
#
#
#
#             var marker_2b2cf445a3d1ebfbae72654a34d1dc19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a96cd6d89a31c3185e75e689b80bf7d4);
#
#
#         var popup_e0dbeec66700cc17ccf7c90cff98d3c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece8eb16bae19a8bda953dcbec7a132b = $(`&lt;div id=&quot;html_ece8eb16bae19a8bda953dcbec7a132b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e0dbeec66700cc17ccf7c90cff98d3c7.setContent(html_ece8eb16bae19a8bda953dcbec7a132b);
#
#
#
#         marker_2b2cf445a3d1ebfbae72654a34d1dc19.bindPopup(popup_e0dbeec66700cc17ccf7c90cff98d3c7)
#         ;
#
#
#
#
#             var marker_c5f7a860617ccdca3797051134577d87 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a96cd6d89a31c3185e75e689b80bf7d4);
#
#
#         var popup_455b930f8e56c449ac78cd9ba661ad11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1de8d3c62506b0a9f1f8d680ef928ea9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1de8d3c62506b0a9f1f8d680ef928ea9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1de8d3c62506b0a9f1f8d680ef928ea9 = L.map(
#                 &quot;map_1de8d3c62506b0a9f1f8d680ef928ea9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dc2479448f8a0233ff8cab88e16a36c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9dc2479448f8a0233ff8cab88e16a36c.addTo(map_1de8d3c62506b0a9f1f8d680ef928ea9);
#
#
#             var feature_group_1e6885266aefb944578a052691565270 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1e6885266aefb944578a052691565270.addTo(map_1de8d3c62506b0a9f1f8d680ef928ea9);
#
#
#             var feature_group_sub_group_b5f8636b0cdc3505fcbf7b2b7d31e4d6 = L.featureGroup.subGroup(
#                 feature_group_1e6885266aefb944578a052691565270
#             );
#
#
#             var marker_92a8fd77b4819bfd119a6097caa6c5a7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5f8636b0cdc3505fcbf7b2b7d31e4d6);
#
#
#         var popup_df1ac76a75d6dce54229043e0e2165d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_964fcaae6c1e155426e5d620a37d6683 = $(`&lt;div id=&quot;html_964fcaae6c1e155426e5d620a37d6683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_df1ac76a75d6dce54229043e0e2165d8.setContent(html_964fcaae6c1e155426e5d620a37d6683);
#
#
#
#         marker_92a8fd77b4819bfd119a6097caa6c5a7.bindPopup(popup_df1ac76a75d6dce54229043e0e2165d8)
#         ;
#
#
#
#
#             var marker_af0bb6bcceca249d1e4805672bfa9471 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5f8636b0cdc3505fcbf7b2b7d31e4d6);
#
#
#         var popup_041877f244955871c7abcc64f86f15c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76e3323eb89c3429b4975bee71cf2996 = $(`&lt;div id=&quot;html_76e3323eb89c3429b4975bee71cf2996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_041877f244955871c7abcc64f86f15c8.setContent(html_76e3323eb89c3429b4975bee71cf2996);
#
#
#
#         marker_af0bb6bcceca249d1e4805672bfa9471.bindPopup(popup_041877f244955871c7abcc64f86f15c8)
#         ;
#
#
#
#
#             var marker_f50f3dd376f40019772ebf3191f6baf1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5f8636b0cdc3505fcbf7b2b7d31e4d6);
#
#
#         var popup_c8075f3feb49722b63cd5918ea2b4abe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03ef89f931f6138cf14358879df2bd44 = $(`&lt;div id=&quot;html_03ef89f931f6138cf14358879df2bd44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c8075f3feb49722b63cd5918ea2b4abe.setContent(html_03ef89f931f6138cf14358879df2bd44);
#
#
#
#         marker_f50f3dd376f40019772ebf3191f6baf1.bindPopup(popup_c8075f3feb49722b63cd5918ea2b4abe)
#         ;
#
#
#
#
#             var marker_cefc46ae36e1b9e2e92ff940e669dc80 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5f8636b0cdc3505fcbf7b2b7d31e4d6);
#
#
#         var popup_d5f997587c32c8a19c0d1b0682bb3ced = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f669ec0d06738d31901585a5a825f159 = $(`&lt;div id=&quot;html_f669ec0d06738d31901585a5a825f159&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d5f997587c32c8a19c0d1b0682bb3ced.setContent(html_f669ec0d06738d31901585a5a825f159);
#
#
#
#         marker_
