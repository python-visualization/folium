# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbcc9cdf324e3c4c792af88084d5a5da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbcc9cdf324e3c4c792af88084d5a5da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbcc9cdf324e3c4c792af88084d5a5da = L.map(
#                 &quot;map_dbcc9cdf324e3c4c792af88084d5a5da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e0ee71970ac089a67df5971f9628b3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e0ee71970ac089a67df5971f9628b3f.addTo(map_dbcc9cdf324e3c4c792af88084d5a5da);
#
#
#             var marker_4df169334259a3497a403d4d5f2b31e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dbcc9cdf324e3c4c792af88084d5a5da);
#
#
#         var popup_b7f0fd90565e8e9795d1d85eb161516e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f9f029d7a90e64a119a3eb23a4651b5 = $(`&lt;div id=&quot;html_8f9f029d7a90e64a119a3eb23a4651b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b7f0fd90565e8e9795d1d85eb161516e.setContent(html_8f9f029d7a90e64a119a3eb23a4651b5);
#
#
#
#         marker_4df169334259a3497a403d4d5f2b31e2.bindPopup(popup_b7f0fd90565e8e9795d1d85eb161516e)
#         ;
#
#
#
#
#             var marker_140e9a43583b001a2d949c8a32e2a0ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dbcc9cdf324e3c4c792af88084d5a5da);
#
#
#         var popup_4ecf75eddf3426e2493b3a2762010694 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3a6306963acfeba4c526ff3a969ffe9 = $(`&lt;div id=&quot;html_c3a6306963acfeba4c526ff3a969ffe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4ecf75eddf3426e2493b3a2762010694.setContent(html_c3a6306963acfeba4c526ff3a969ffe9);
#
#
#
#         marker_140e9a43583b001a2d949c8a32e2a0ed.bindPopup(popup_4ecf75eddf3426e2493b3a2762010694)
#         ;
#
#
#
#
#             var marker_0a70cbf4452dc26cf73c46ef1dd8ce1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dbcc9cdf324e3c4c792af88084d5a5da);
#
#
#         var popup_b8eb2ff95ea251ae353f3d15f1cd0000 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edcd9c36f6726a9a13a0f937829ba8f2 = $(`&lt;div id=&quot;html_edcd9c36f6726a9a13a0f937829ba8f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b8eb2ff95ea251ae353f3d15f1cd0000.setContent(html_edcd9c36f6726a9a13a0f937829ba8f2);
#
#
#
#         marker_0a70cbf4452dc26cf73c46ef1dd8ce1b.bindPopup(popup_b8eb2ff95ea251ae353f3d15f1cd0000)
#         ;
#
#
#
#
#             var marker_fe6590ae02e1a2a4c6301be99b8ab87f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dbcc9cdf324e3c4c792af88084d5a5da);
#
#
#         var popup_9f0c0eca550b39d262447c1880f206e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b8cb62caa5cc291af8713df34f79e3d = $(`&lt;div id=&quot;html_6b8cb62caa5cc291af8713df34f79e3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9f0c0eca550b39d262447c1880f206e3.setContent(html_6b8cb62caa5cc291af8713df34f79e3d);
#
#
#
#         marker_fe6590ae02e1a2a4c6301be99b8ab87f.bindPopup(popup_9f0c0eca550b39d262447c1880f206e3)
#         ;
#
#
#
#
#             var marker_3d364049af76547f1e8d578376447c9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dbcc9cdf324e3c4c792af88084d5a5da);
#
#
#         var popup_64ebb87c5062a94219c96822e1c6dbc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8a87acf4768e64e30e2f3c40c68c25 = $(`&lt;div id=&quot;html_fc8a87acf4768e64e30e2f3c40c68c25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_64ebb87c5062a94219c96822e1c6dbc4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e10219385b37a394ebd32988dabe5d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e10219385b37a394ebd32988dabe5d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e10219385b37a394ebd32988dabe5d6 = L.map(
#                 &quot;map_8e10219385b37a394ebd32988dabe5d6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b7bf891cdc43c77802e22d2d82105e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b7bf891cdc43c77802e22d2d82105e1.addTo(map_8e10219385b37a394ebd32988dabe5d6);
#
#
#             var feature_group_79c531e6725e2d31633488a1d7f288fd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2f0ae944648e941947eedb3f1c09ed31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_79c531e6725e2d31633488a1d7f288fd);
#
#
#         var popup_810db5025fb866e058bd14542d6d2e4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dbddb9cc7dfa106e671037f5f68de0d = $(`&lt;div id=&quot;html_8dbddb9cc7dfa106e671037f5f68de0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_810db5025fb866e058bd14542d6d2e4e.setContent(html_8dbddb9cc7dfa106e671037f5f68de0d);
#
#
#
#         marker_2f0ae944648e941947eedb3f1c09ed31.bindPopup(popup_810db5025fb866e058bd14542d6d2e4e)
#         ;
#
#
#
#
#             var marker_937d1b91d75ae433e0db1716be7f6b3b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_79c531e6725e2d31633488a1d7f288fd);
#
#
#         var popup_a95fea6b1ca171a0c9d32ec3faddcf81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7648ee11bf699a8b2cef0fe7a608b6e5 = $(`&lt;div id=&quot;html_7648ee11bf699a8b2cef0fe7a608b6e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a95fea6b1ca171a0c9d32ec3faddcf81.setContent(html_7648ee11bf699a8b2cef0fe7a608b6e5);
#
#
#
#         marker_937d1b91d75ae433e0db1716be7f6b3b.bindPopup(popup_a95fea6b1ca171a0c9d32ec3faddcf81)
#         ;
#
#
#
#
#             var marker_ae90f40b939a60ee766484ecb7478188 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_79c531e6725e2d31633488a1d7f288fd);
#
#
#         var popup_c6d9669dc5bc920ae114f64b8968c185 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bace35be0e04de0ae71457df95bd3f8 = $(`&lt;div id=&quot;html_1bace35be0e04de0ae71457df95bd3f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c6d9669dc5bc920ae114f64b8968c185.setContent(html_1bace35be0e04de0ae71457df95bd3f8);
#
#
#
#         marker_ae90f40b939a60ee766484ecb7478188.bindPopup(popup_c6d9669dc5bc920ae114f64b8968c185)
#         ;
#
#
#
#
#             var marker_6fc27403b70940b41ef2e967fe2d9baf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_79c531e6725e2d31633488a1d7f288fd);
#
#
#         var popup_75b0666b5aebfa14f19f5ca95eb87446 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da7a21d99e5ff6d078ac60f349ca2f85 = $(`&lt;div id=&quot;html_da7a21d99e5ff6d078ac60f349ca2f85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_75b0666b5aebfa14f19f5ca95eb87446.setContent(html_da7a21d99e5ff6d078ac60f349ca2f85);
#
#
#
#         marker_6fc27403b70940b41ef2e967fe2d9baf.bindPopup(popup_75b0666b5aebfa14f19f5ca95eb87446)
#         ;
#
#
#
#
#             var marker_06e6a5c06c4b5dbf8288a125407370dc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_79c531e6725e2d31633488a1d7f288fd);
#
#
#         var popup_1e61a441a57018f79ed16a6952665343 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_239b6b4fdfccd29a81ec7c05e9792f58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_239b6b4fdfccd29a81ec7c05e9792f58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_239b6b4fdfccd29a81ec7c05e9792f58 = L.map(
#                 &quot;map_239b6b4fdfccd29a81ec7c05e9792f58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1102d07af3fa90a56a999ad245b2d415 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1102d07af3fa90a56a999ad245b2d415.addTo(map_239b6b4fdfccd29a81ec7c05e9792f58);
#
#
#             var feature_group_fe127ae53c6a7964ae4148328be0f3e3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fe127ae53c6a7964ae4148328be0f3e3.addTo(map_239b6b4fdfccd29a81ec7c05e9792f58);
#
#
#             var feature_group_sub_group_6ce83e7f528f4eff8789b41be9929644 = L.featureGroup.subGroup(
#                 feature_group_fe127ae53c6a7964ae4148328be0f3e3
#             );
#
#
#             var marker_f649e293db2ac87bce3e3debd9c101a5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ce83e7f528f4eff8789b41be9929644);
#
#
#         var popup_6ac07e299e8f6d01fb6b9f474e4f8c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_391a71507bd7b0f64f4d0a160454ebc5 = $(`&lt;div id=&quot;html_391a71507bd7b0f64f4d0a160454ebc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6ac07e299e8f6d01fb6b9f474e4f8c83.setContent(html_391a71507bd7b0f64f4d0a160454ebc5);
#
#
#
#         marker_f649e293db2ac87bce3e3debd9c101a5.bindPopup(popup_6ac07e299e8f6d01fb6b9f474e4f8c83)
#         ;
#
#
#
#
#             var marker_f5cb2e7befc3edd2a6fcea752db93d00 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ce83e7f528f4eff8789b41be9929644);
#
#
#         var popup_61c7a9e3be43244db05826c063b10aa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0caed973b8b1937052eae732507cf93 = $(`&lt;div id=&quot;html_f0caed973b8b1937052eae732507cf93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_61c7a9e3be43244db05826c063b10aa9.setContent(html_f0caed973b8b1937052eae732507cf93);
#
#
#
#         marker_f5cb2e7befc3edd2a6fcea752db93d00.bindPopup(popup_61c7a9e3be43244db05826c063b10aa9)
#         ;
#
#
#
#
#             var marker_e008b5e68a5e53c9a7febeeec375b66d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ce83e7f528f4eff8789b41be9929644);
#
#
#         var popup_655d82eb0c57d80567cea23d179b020c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4215be017e008345de839b9999a5539 = $(`&lt;div id=&quot;html_c4215be017e008345de839b9999a5539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_655d82eb0c57d80567cea23d179b020c.setContent(html_c4215be017e008345de839b9999a5539);
#
#
#
#         marker_e008b5e68a5e53c9a7febeeec375b66d.bindPopup(popup_655d82eb0c57d80567cea23d179b020c)
#         ;
#
#
#
#
#             var marker_9a48a45e6c4e9920dd64cea917a8a497 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ce83e7f528f4eff8789b41be9929644);
#
#
#         var popup_ba0f7be8bc4869de1801335edf770406 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2069e3d3af84211dfef5b2a4095f50c0 = $(`&lt;div id=&quot;html_2069e3d3af84211dfef5b2a4095f50c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ba0f7be8bc4869de1801335edf770406.setContent(html_2069e3d3af84211dfef5b2a4095f50c0);
#
#
#
#         marker_
