# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5264d7d7ca0a8bad247dee7a595e24a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5264d7d7ca0a8bad247dee7a595e24a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5264d7d7ca0a8bad247dee7a595e24a = L.map(
#                 &quot;map_d5264d7d7ca0a8bad247dee7a595e24a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c3caf4950b165e75c1e26fa6f50393b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c3caf4950b165e75c1e26fa6f50393b.addTo(map_d5264d7d7ca0a8bad247dee7a595e24a);
#
#
#             var marker_3173b8627f23ab6b8dcf38aa701fe10f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d5264d7d7ca0a8bad247dee7a595e24a);
#
#
#         var popup_caeddf3673366f7005a57f8924caea0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_022169894e8c4c894bf43ea25d6b6f59 = $(`&lt;div id=&quot;html_022169894e8c4c894bf43ea25d6b6f59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_caeddf3673366f7005a57f8924caea0b.setContent(html_022169894e8c4c894bf43ea25d6b6f59);
#
#
#
#         marker_3173b8627f23ab6b8dcf38aa701fe10f.bindPopup(popup_caeddf3673366f7005a57f8924caea0b)
#         ;
#
#
#
#
#             var marker_aab9883ab4262a7573e2e82bef58b0c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d5264d7d7ca0a8bad247dee7a595e24a);
#
#
#         var popup_95f77975de5429a9f7b3a01458bacd7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a229f89dda95a955eee8ec8765a5aa84 = $(`&lt;div id=&quot;html_a229f89dda95a955eee8ec8765a5aa84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_95f77975de5429a9f7b3a01458bacd7d.setContent(html_a229f89dda95a955eee8ec8765a5aa84);
#
#
#
#         marker_aab9883ab4262a7573e2e82bef58b0c9.bindPopup(popup_95f77975de5429a9f7b3a01458bacd7d)
#         ;
#
#
#
#
#             var marker_a14faf4715dfe877f6c0f5adb4fbd924 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d5264d7d7ca0a8bad247dee7a595e24a);
#
#
#         var popup_3f26f67a3dc9a5eb534949a6fa1d13f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3936743280674b79db9ae781bc99623f = $(`&lt;div id=&quot;html_3936743280674b79db9ae781bc99623f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3f26f67a3dc9a5eb534949a6fa1d13f2.setContent(html_3936743280674b79db9ae781bc99623f);
#
#
#
#         marker_a14faf4715dfe877f6c0f5adb4fbd924.bindPopup(popup_3f26f67a3dc9a5eb534949a6fa1d13f2)
#         ;
#
#
#
#
#             var marker_1fccc1e2615baa44ec7639e4f8a35438 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d5264d7d7ca0a8bad247dee7a595e24a);
#
#
#         var popup_1f5a28f896a3fbdee387eb80f2cd521b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d79448e87eb0d8730525475357b51f3c = $(`&lt;div id=&quot;html_d79448e87eb0d8730525475357b51f3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1f5a28f896a3fbdee387eb80f2cd521b.setContent(html_d79448e87eb0d8730525475357b51f3c);
#
#
#
#         marker_1fccc1e2615baa44ec7639e4f8a35438.bindPopup(popup_1f5a28f896a3fbdee387eb80f2cd521b)
#         ;
#
#
#
#
#             var marker_7bcc53363a89600e4e06303734292a49 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d5264d7d7ca0a8bad247dee7a595e24a);
#
#
#         var popup_28f43117b1edc8f7f8fbe79ddc5a6abf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45b011d600d5165e78e652bca23b0bfc = $(`&lt;div id=&quot;html_45b011d600d5165e78e652bca23b0bfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_28f43117b1edc8f7f8fbe79ddc5a6abf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d1d2797f68d5a81ee6ca175ff844de5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d1d2797f68d5a81ee6ca175ff844de5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d1d2797f68d5a81ee6ca175ff844de5 = L.map(
#                 &quot;map_2d1d2797f68d5a81ee6ca175ff844de5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1150ae0ebc4260ff5c3b409b392cf35f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1150ae0ebc4260ff5c3b409b392cf35f.addTo(map_2d1d2797f68d5a81ee6ca175ff844de5);
#
#
#             var feature_group_3d74c093798c84c07f875ae08d1593d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2637a6906d80e7b7ae113c183d8d0e05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d74c093798c84c07f875ae08d1593d3);
#
#
#         var popup_897535fe1f26d94359715dff0a0606d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_843d1f8e8ff355fe8f38ee3b3bc962fc = $(`&lt;div id=&quot;html_843d1f8e8ff355fe8f38ee3b3bc962fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_897535fe1f26d94359715dff0a0606d5.setContent(html_843d1f8e8ff355fe8f38ee3b3bc962fc);
#
#
#
#         marker_2637a6906d80e7b7ae113c183d8d0e05.bindPopup(popup_897535fe1f26d94359715dff0a0606d5)
#         ;
#
#
#
#
#             var marker_feba6ec8c43ca7b4e2aa1778dee7a9b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d74c093798c84c07f875ae08d1593d3);
#
#
#         var popup_049c5e71c74c80c10cdec538d7f92c32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9febd696cbad718b288bcaf28981150 = $(`&lt;div id=&quot;html_a9febd696cbad718b288bcaf28981150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_049c5e71c74c80c10cdec538d7f92c32.setContent(html_a9febd696cbad718b288bcaf28981150);
#
#
#
#         marker_feba6ec8c43ca7b4e2aa1778dee7a9b5.bindPopup(popup_049c5e71c74c80c10cdec538d7f92c32)
#         ;
#
#
#
#
#             var marker_c3b8eebdb4199fc386adb348add1d059 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d74c093798c84c07f875ae08d1593d3);
#
#
#         var popup_cf58a96e82d21dd720dd6eb74beeb182 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df472fa558df63628f2e14463b817406 = $(`&lt;div id=&quot;html_df472fa558df63628f2e14463b817406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cf58a96e82d21dd720dd6eb74beeb182.setContent(html_df472fa558df63628f2e14463b817406);
#
#
#
#         marker_c3b8eebdb4199fc386adb348add1d059.bindPopup(popup_cf58a96e82d21dd720dd6eb74beeb182)
#         ;
#
#
#
#
#             var marker_ff505ac336522ac3647b0861172d3b29 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d74c093798c84c07f875ae08d1593d3);
#
#
#         var popup_63086594fec65de291ae45439bf30acc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b3ff32bfff67a627275ad78b9ddc720 = $(`&lt;div id=&quot;html_8b3ff32bfff67a627275ad78b9ddc720&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_63086594fec65de291ae45439bf30acc.setContent(html_8b3ff32bfff67a627275ad78b9ddc720);
#
#
#
#         marker_ff505ac336522ac3647b0861172d3b29.bindPopup(popup_63086594fec65de291ae45439bf30acc)
#         ;
#
#
#
#
#             var marker_3421ba29ed3c4bb5b4a33d7ef6b2f74e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d74c093798c84c07f875ae08d1593d3);
#
#
#         var popup_7130f4e98042869bda4da291c3535e49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc93f9647ab9b8e7e1816139f7a5650e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc93f9647ab9b8e7e1816139f7a5650e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc93f9647ab9b8e7e1816139f7a5650e = L.map(
#                 &quot;map_cc93f9647ab9b8e7e1816139f7a5650e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b37dc9f4c846840cb241f7f39c91b27c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b37dc9f4c846840cb241f7f39c91b27c.addTo(map_cc93f9647ab9b8e7e1816139f7a5650e);
#
#
#             var feature_group_3aec9dce8ecc2e7b7cc56c8ff12b9114 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3aec9dce8ecc2e7b7cc56c8ff12b9114.addTo(map_cc93f9647ab9b8e7e1816139f7a5650e);
#
#
#             var feature_group_sub_group_fd3fc087fc2df22fc84c7cce4a436f15 = L.featureGroup.subGroup(
#                 feature_group_3aec9dce8ecc2e7b7cc56c8ff12b9114
#             );
#
#
#             var marker_f4a563c30abe5c1cc94dd4565b39602c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd3fc087fc2df22fc84c7cce4a436f15);
#
#
#         var popup_1455f5dc9b836abefb245645ea53ffc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64388c4079819b61844762eab7a5aa67 = $(`&lt;div id=&quot;html_64388c4079819b61844762eab7a5aa67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1455f5dc9b836abefb245645ea53ffc1.setContent(html_64388c4079819b61844762eab7a5aa67);
#
#
#
#         marker_f4a563c30abe5c1cc94dd4565b39602c.bindPopup(popup_1455f5dc9b836abefb245645ea53ffc1)
#         ;
#
#
#
#
#             var marker_fc2a10242b4bde0754b503ae54b060c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd3fc087fc2df22fc84c7cce4a436f15);
#
#
#         var popup_7074c96055aaeb2b28a38b5cfa72a903 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02bd77d6eaa39f44578a3d6314295cad = $(`&lt;div id=&quot;html_02bd77d6eaa39f44578a3d6314295cad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7074c96055aaeb2b28a38b5cfa72a903.setContent(html_02bd77d6eaa39f44578a3d6314295cad);
#
#
#
#         marker_fc2a10242b4bde0754b503ae54b060c5.bindPopup(popup_7074c96055aaeb2b28a38b5cfa72a903)
#         ;
#
#
#
#
#             var marker_32a5e5a341e5d17abda68244752dbf1c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd3fc087fc2df22fc84c7cce4a436f15);
#
#
#         var popup_df69100813ed8e3b480222b75ee5f15a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_754f98372220d17859b0d6213cdb42c6 = $(`&lt;div id=&quot;html_754f98372220d17859b0d6213cdb42c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_df69100813ed8e3b480222b75ee5f15a.setContent(html_754f98372220d17859b0d6213cdb42c6);
#
#
#
#         marker_32a5e5a341e5d17abda68244752dbf1c.bindPopup(popup_df69100813ed8e3b480222b75ee5f15a)
#         ;
#
#
#
#
#             var marker_3fa7375a6b67265d70e2410aba217908 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd3fc087fc2df22fc84c7cce4a436f15);
#
#
#         var popup_5e8235467dbcf4c6b4b35073387230ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd648219ef811df1a339cdc404675e60 = $(`&lt;div id=&quot;html_cd648219ef811df1a339cdc404675e60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e8235467dbcf4c6b4b35073387230ed.setContent(html_cd648219ef811df1a339cdc404675e60);
#
#
#
#         marker_
