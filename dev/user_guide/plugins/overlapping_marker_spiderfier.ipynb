# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea06f26026691ef8141f82dff59792b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea06f26026691ef8141f82dff59792b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea06f26026691ef8141f82dff59792b7 = L.map(
#                 &quot;map_ea06f26026691ef8141f82dff59792b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e1715e44375622026c7b445e295edf1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e1715e44375622026c7b445e295edf1.addTo(map_ea06f26026691ef8141f82dff59792b7);
#
#
#             var marker_a007a8594242ee24ae5c2f6d8c1ab2b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ea06f26026691ef8141f82dff59792b7);
#
#
#         var popup_cb135d8bf76e646ca2f5a5a290615968 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fd321967e92e133211aa972092aca48 = $(`&lt;div id=&quot;html_6fd321967e92e133211aa972092aca48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cb135d8bf76e646ca2f5a5a290615968.setContent(html_6fd321967e92e133211aa972092aca48);
#
#
#
#         marker_a007a8594242ee24ae5c2f6d8c1ab2b2.bindPopup(popup_cb135d8bf76e646ca2f5a5a290615968)
#         ;
#
#
#
#
#             var marker_170cbbf75ee5e3a3b4070b49761eec2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ea06f26026691ef8141f82dff59792b7);
#
#
#         var popup_2c1d1aea168bef88255d75bf6c4e3916 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8769e2d9b8a0666a96bae796d5d3e1f = $(`&lt;div id=&quot;html_e8769e2d9b8a0666a96bae796d5d3e1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2c1d1aea168bef88255d75bf6c4e3916.setContent(html_e8769e2d9b8a0666a96bae796d5d3e1f);
#
#
#
#         marker_170cbbf75ee5e3a3b4070b49761eec2a.bindPopup(popup_2c1d1aea168bef88255d75bf6c4e3916)
#         ;
#
#
#
#
#             var marker_cf8909dbcd3c12b285aa99d500cad0bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ea06f26026691ef8141f82dff59792b7);
#
#
#         var popup_0a974512c6dba5dd79dc25d56456c5b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65d4b5206a7a550394f09e5e71eeed6d = $(`&lt;div id=&quot;html_65d4b5206a7a550394f09e5e71eeed6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0a974512c6dba5dd79dc25d56456c5b0.setContent(html_65d4b5206a7a550394f09e5e71eeed6d);
#
#
#
#         marker_cf8909dbcd3c12b285aa99d500cad0bd.bindPopup(popup_0a974512c6dba5dd79dc25d56456c5b0)
#         ;
#
#
#
#
#             var marker_a6b78b68a63dfba829f77f126f318ea1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ea06f26026691ef8141f82dff59792b7);
#
#
#         var popup_387700f4dd5b1f1c3c96744488eafcc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8af701f4ca150f0de89a743414c6b931 = $(`&lt;div id=&quot;html_8af701f4ca150f0de89a743414c6b931&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_387700f4dd5b1f1c3c96744488eafcc6.setContent(html_8af701f4ca150f0de89a743414c6b931);
#
#
#
#         marker_a6b78b68a63dfba829f77f126f318ea1.bindPopup(popup_387700f4dd5b1f1c3c96744488eafcc6)
#         ;
#
#
#
#
#             var marker_1d435b5661d315583d16406e39750abb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ea06f26026691ef8141f82dff59792b7);
#
#
#         var popup_8099cc15a01e7c663b4e05174638a2c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6925a83e66fbe24afe12fe881df29ac1 = $(`&lt;div id=&quot;html_6925a83e66fbe24afe12fe881df29ac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8099cc15a01e7c663b4e05174638a2c3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ad78141fd180f06b0ea64e7a11092bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ad78141fd180f06b0ea64e7a11092bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ad78141fd180f06b0ea64e7a11092bb = L.map(
#                 &quot;map_7ad78141fd180f06b0ea64e7a11092bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e1e91e89a2c4d15fdf9cb0caefeff8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e1e91e89a2c4d15fdf9cb0caefeff8d.addTo(map_7ad78141fd180f06b0ea64e7a11092bb);
#
#
#             var feature_group_6f211f9306dc455818e7ae6a73a1338b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aa8e7d4da262d75b5af718cc053a977f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6f211f9306dc455818e7ae6a73a1338b);
#
#
#         var popup_9475e5f988e892e78ff308bbf635610b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9db15fec2909bb61588fcdc681f07200 = $(`&lt;div id=&quot;html_9db15fec2909bb61588fcdc681f07200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9475e5f988e892e78ff308bbf635610b.setContent(html_9db15fec2909bb61588fcdc681f07200);
#
#
#
#         marker_aa8e7d4da262d75b5af718cc053a977f.bindPopup(popup_9475e5f988e892e78ff308bbf635610b)
#         ;
#
#
#
#
#             var marker_678ae672a0e8409ca8d6f780de935606 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6f211f9306dc455818e7ae6a73a1338b);
#
#
#         var popup_da4d9bcea761078265e41171b2069b29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc40f339d9d7b1a867bfe7aeb347a31f = $(`&lt;div id=&quot;html_cc40f339d9d7b1a867bfe7aeb347a31f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_da4d9bcea761078265e41171b2069b29.setContent(html_cc40f339d9d7b1a867bfe7aeb347a31f);
#
#
#
#         marker_678ae672a0e8409ca8d6f780de935606.bindPopup(popup_da4d9bcea761078265e41171b2069b29)
#         ;
#
#
#
#
#             var marker_7ec1edf5396387a0610c3c5b5927e8a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6f211f9306dc455818e7ae6a73a1338b);
#
#
#         var popup_e62b75e78f3fcb4771506e2ff83606c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a1ccc53baf82231d9155faf968fce1a = $(`&lt;div id=&quot;html_7a1ccc53baf82231d9155faf968fce1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e62b75e78f3fcb4771506e2ff83606c0.setContent(html_7a1ccc53baf82231d9155faf968fce1a);
#
#
#
#         marker_7ec1edf5396387a0610c3c5b5927e8a4.bindPopup(popup_e62b75e78f3fcb4771506e2ff83606c0)
#         ;
#
#
#
#
#             var marker_3403f3b433ad492e117dbe553f055df7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6f211f9306dc455818e7ae6a73a1338b);
#
#
#         var popup_b8b078baa3aa4f6b740c531895354308 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_859c2c4d6697e2e3e41e637f3e89e7b9 = $(`&lt;div id=&quot;html_859c2c4d6697e2e3e41e637f3e89e7b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b8b078baa3aa4f6b740c531895354308.setContent(html_859c2c4d6697e2e3e41e637f3e89e7b9);
#
#
#
#         marker_3403f3b433ad492e117dbe553f055df7.bindPopup(popup_b8b078baa3aa4f6b740c531895354308)
#         ;
#
#
#
#
#             var marker_a329d6bd8c91d1f6ce7782b7278fa5a9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6f211f9306dc455818e7ae6a73a1338b);
#
#
#         var popup_c98fcce812d12a58e21533698e226362 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31832caf5d4ac6308046a0f3c16c3bd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31832caf5d4ac6308046a0f3c16c3bd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31832caf5d4ac6308046a0f3c16c3bd9 = L.map(
#                 &quot;map_31832caf5d4ac6308046a0f3c16c3bd9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddb8a68f3000499f66cee1b9ffc681d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ddb8a68f3000499f66cee1b9ffc681d2.addTo(map_31832caf5d4ac6308046a0f3c16c3bd9);
#
#
#             var feature_group_d1b8ec0bee21b7ce9eced810aabbe032 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1b8ec0bee21b7ce9eced810aabbe032.addTo(map_31832caf5d4ac6308046a0f3c16c3bd9);
#
#
#             var feature_group_sub_group_fe357bfef3cc2dd5f42cd9d38a353eb2 = L.featureGroup.subGroup(
#                 feature_group_d1b8ec0bee21b7ce9eced810aabbe032
#             );
#
#
#             var marker_583df7ffad44247adf128f002ca31d3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe357bfef3cc2dd5f42cd9d38a353eb2);
#
#
#         var popup_6578b9180999dedd09dcf7c96572c33e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abfa5d6eb9dacff8b9ed9ef51d1437b7 = $(`&lt;div id=&quot;html_abfa5d6eb9dacff8b9ed9ef51d1437b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6578b9180999dedd09dcf7c96572c33e.setContent(html_abfa5d6eb9dacff8b9ed9ef51d1437b7);
#
#
#
#         marker_583df7ffad44247adf128f002ca31d3d.bindPopup(popup_6578b9180999dedd09dcf7c96572c33e)
#         ;
#
#
#
#
#             var marker_d68405f3c3d6715a4232d412bbc108f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe357bfef3cc2dd5f42cd9d38a353eb2);
#
#
#         var popup_8f44cc357abd6b18c32b19a933ea00a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3f01bd28e9c1931ce3980ae44be81f4 = $(`&lt;div id=&quot;html_e3f01bd28e9c1931ce3980ae44be81f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8f44cc357abd6b18c32b19a933ea00a5.setContent(html_e3f01bd28e9c1931ce3980ae44be81f4);
#
#
#
#         marker_d68405f3c3d6715a4232d412bbc108f3.bindPopup(popup_8f44cc357abd6b18c32b19a933ea00a5)
#         ;
#
#
#
#
#             var marker_7694bf5eeda8186061e8e8cde928ddb2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe357bfef3cc2dd5f42cd9d38a353eb2);
#
#
#         var popup_1bafad9955fb50ef52953a78e52daedd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d04213c2f68a74f94486e33f5dbdf7e = $(`&lt;div id=&quot;html_3d04213c2f68a74f94486e33f5dbdf7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1bafad9955fb50ef52953a78e52daedd.setContent(html_3d04213c2f68a74f94486e33f5dbdf7e);
#
#
#
#         marker_7694bf5eeda8186061e8e8cde928ddb2.bindPopup(popup_1bafad9955fb50ef52953a78e52daedd)
#         ;
#
#
#
#
#             var marker_d4129d86f404c2232f2a3a779f58b2a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe357bfef3cc2dd5f42cd9d38a353eb2);
#
#
#         var popup_ddc04d7f74794c55ea63eb0e661446ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b219c0f60486c633bc1d45f85a92f26c = $(`&lt;div id=&quot;html_b219c0f60486c633bc1d45f85a92f26c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ddc04d7f74794c55ea63eb0e661446ef.setContent(html_b219c0f60486c633bc1d45f85a92f26c);
#
#
#
#         marker_
