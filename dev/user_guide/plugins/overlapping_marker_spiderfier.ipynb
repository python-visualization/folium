# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc0cc33ae14fd4895de13fd7e44c45fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc0cc33ae14fd4895de13fd7e44c45fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc0cc33ae14fd4895de13fd7e44c45fb = L.map(
#                 &quot;map_bc0cc33ae14fd4895de13fd7e44c45fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e852d93327271ef473d6456bfd48c28b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e852d93327271ef473d6456bfd48c28b.addTo(map_bc0cc33ae14fd4895de13fd7e44c45fb);
#
#
#             var marker_60a8ac48174e6b8340aea8d96be47a29 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bc0cc33ae14fd4895de13fd7e44c45fb);
#
#
#         var popup_23915ff4e8c7fa2f9076ff4a67a077b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3675f70b6b4d1f38de29c0a9ca4efbc = $(`&lt;div id=&quot;html_f3675f70b6b4d1f38de29c0a9ca4efbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_23915ff4e8c7fa2f9076ff4a67a077b6.setContent(html_f3675f70b6b4d1f38de29c0a9ca4efbc);
#
#
#
#         marker_60a8ac48174e6b8340aea8d96be47a29.bindPopup(popup_23915ff4e8c7fa2f9076ff4a67a077b6)
#         ;
#
#
#
#
#             var marker_58e05f460712adbac036558973baa7f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bc0cc33ae14fd4895de13fd7e44c45fb);
#
#
#         var popup_a43e70305294fdbe95509f40714bb788 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a913a2d10664b7d37cd222ad72c011d1 = $(`&lt;div id=&quot;html_a913a2d10664b7d37cd222ad72c011d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a43e70305294fdbe95509f40714bb788.setContent(html_a913a2d10664b7d37cd222ad72c011d1);
#
#
#
#         marker_58e05f460712adbac036558973baa7f3.bindPopup(popup_a43e70305294fdbe95509f40714bb788)
#         ;
#
#
#
#
#             var marker_036aa481f43235708ca9764dcaf0d657 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bc0cc33ae14fd4895de13fd7e44c45fb);
#
#
#         var popup_2d5dd1c03f7cc7cb981be90b5e86b785 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_275e0ef471bd0410f4459c498c0ff761 = $(`&lt;div id=&quot;html_275e0ef471bd0410f4459c498c0ff761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2d5dd1c03f7cc7cb981be90b5e86b785.setContent(html_275e0ef471bd0410f4459c498c0ff761);
#
#
#
#         marker_036aa481f43235708ca9764dcaf0d657.bindPopup(popup_2d5dd1c03f7cc7cb981be90b5e86b785)
#         ;
#
#
#
#
#             var marker_8462b18b4ef4eeb82793b01d421d7141 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bc0cc33ae14fd4895de13fd7e44c45fb);
#
#
#         var popup_1b21cc96d0b40a706abe45a499409967 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b4d83b2ce1686068c9458ed7c061ff7 = $(`&lt;div id=&quot;html_4b4d83b2ce1686068c9458ed7c061ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1b21cc96d0b40a706abe45a499409967.setContent(html_4b4d83b2ce1686068c9458ed7c061ff7);
#
#
#
#         marker_8462b18b4ef4eeb82793b01d421d7141.bindPopup(popup_1b21cc96d0b40a706abe45a499409967)
#         ;
#
#
#
#
#             var marker_60358fae13f65675fffd7021679ee76c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bc0cc33ae14fd4895de13fd7e44c45fb);
#
#
#         var popup_dd3dca07d2df5505c2c5b1f98eb931dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64da86480447f408d3f9fe1d3fe0e716 = $(`&lt;div id=&quot;html_64da86480447f408d3f9fe1d3fe0e716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dd3dca07d2df5505c2c5b1f98eb931dc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c399ebc11a66182cff337a5a744de72a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c399ebc11a66182cff337a5a744de72a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c399ebc11a66182cff337a5a744de72a = L.map(
#                 &quot;map_c399ebc11a66182cff337a5a744de72a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_590310277417506195f9c106ba80aebd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_590310277417506195f9c106ba80aebd.addTo(map_c399ebc11a66182cff337a5a744de72a);
#
#
#             var feature_group_90d9c7699732fe7bfec5bc4e5dac28dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9e533390d7cb28745bb50363579947dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_90d9c7699732fe7bfec5bc4e5dac28dc);
#
#
#         var popup_7c868f5b8ba02ac5b762d74de933ede4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2dd7b40b9e7a6b00861228fa0de4aa5 = $(`&lt;div id=&quot;html_d2dd7b40b9e7a6b00861228fa0de4aa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7c868f5b8ba02ac5b762d74de933ede4.setContent(html_d2dd7b40b9e7a6b00861228fa0de4aa5);
#
#
#
#         marker_9e533390d7cb28745bb50363579947dd.bindPopup(popup_7c868f5b8ba02ac5b762d74de933ede4)
#         ;
#
#
#
#
#             var marker_f648e85de702056f9514757c5382072a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_90d9c7699732fe7bfec5bc4e5dac28dc);
#
#
#         var popup_f1c9a54f734280c606df3483028757f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad762e4b357693c8c635a9ca70b0f4d4 = $(`&lt;div id=&quot;html_ad762e4b357693c8c635a9ca70b0f4d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f1c9a54f734280c606df3483028757f9.setContent(html_ad762e4b357693c8c635a9ca70b0f4d4);
#
#
#
#         marker_f648e85de702056f9514757c5382072a.bindPopup(popup_f1c9a54f734280c606df3483028757f9)
#         ;
#
#
#
#
#             var marker_479a035aa018bca8f6f33d22b3bb9a3a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_90d9c7699732fe7bfec5bc4e5dac28dc);
#
#
#         var popup_f8364327f927059ba2acbf571cefc7c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e217c0dafc9f76cdb6261ff74123735 = $(`&lt;div id=&quot;html_3e217c0dafc9f76cdb6261ff74123735&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f8364327f927059ba2acbf571cefc7c3.setContent(html_3e217c0dafc9f76cdb6261ff74123735);
#
#
#
#         marker_479a035aa018bca8f6f33d22b3bb9a3a.bindPopup(popup_f8364327f927059ba2acbf571cefc7c3)
#         ;
#
#
#
#
#             var marker_750f12fd12384e2c534dd9e51dadc078 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_90d9c7699732fe7bfec5bc4e5dac28dc);
#
#
#         var popup_b3f8611e12a155afc9986ed48d155b3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44830bcd034a44cf516e02366d0b363a = $(`&lt;div id=&quot;html_44830bcd034a44cf516e02366d0b363a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b3f8611e12a155afc9986ed48d155b3a.setContent(html_44830bcd034a44cf516e02366d0b363a);
#
#
#
#         marker_750f12fd12384e2c534dd9e51dadc078.bindPopup(popup_b3f8611e12a155afc9986ed48d155b3a)
#         ;
#
#
#
#
#             var marker_bbf8d9c92c8fda38b38889ae61fb0b9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_90d9c7699732fe7bfec5bc4e5dac28dc);
#
#
#         var popup_054039a0f5d3e71867eb4b2b425ee36f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3010aa427766abedde2cb8232ce6a31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3010aa427766abedde2cb8232ce6a31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3010aa427766abedde2cb8232ce6a31 = L.map(
#                 &quot;map_d3010aa427766abedde2cb8232ce6a31&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b0613b65e28232c4e544ad9dfd2e5eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b0613b65e28232c4e544ad9dfd2e5eb.addTo(map_d3010aa427766abedde2cb8232ce6a31);
#
#
#             var feature_group_98663c37d9df0a318a11b13888458d88 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_98663c37d9df0a318a11b13888458d88.addTo(map_d3010aa427766abedde2cb8232ce6a31);
#
#
#             var feature_group_sub_group_b6d89d6ce3b57d810f6f8ecd7ded7bc3 = L.featureGroup.subGroup(
#                 feature_group_98663c37d9df0a318a11b13888458d88
#             );
#
#
#             var marker_42c90e92bb10bce69afdecbe741c7720 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6d89d6ce3b57d810f6f8ecd7ded7bc3);
#
#
#         var popup_f2ede878a00b86ab9100a03a6f5b61d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19b7ecd0faecf9d5a0e17484155474ae = $(`&lt;div id=&quot;html_19b7ecd0faecf9d5a0e17484155474ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f2ede878a00b86ab9100a03a6f5b61d5.setContent(html_19b7ecd0faecf9d5a0e17484155474ae);
#
#
#
#         marker_42c90e92bb10bce69afdecbe741c7720.bindPopup(popup_f2ede878a00b86ab9100a03a6f5b61d5)
#         ;
#
#
#
#
#             var marker_f54fd0879f77048d49d13494fb685fde = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6d89d6ce3b57d810f6f8ecd7ded7bc3);
#
#
#         var popup_052525514f9ee2bc1bd9cd11f602f140 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c28e0f0601342f32ccc43489ede68af5 = $(`&lt;div id=&quot;html_c28e0f0601342f32ccc43489ede68af5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_052525514f9ee2bc1bd9cd11f602f140.setContent(html_c28e0f0601342f32ccc43489ede68af5);
#
#
#
#         marker_f54fd0879f77048d49d13494fb685fde.bindPopup(popup_052525514f9ee2bc1bd9cd11f602f140)
#         ;
#
#
#
#
#             var marker_288e29e05975721f23ae335fb92aea67 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6d89d6ce3b57d810f6f8ecd7ded7bc3);
#
#
#         var popup_0deec969414b88ee063313edbfbdc371 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82bce817c35d96999b8840f822a8a8bd = $(`&lt;div id=&quot;html_82bce817c35d96999b8840f822a8a8bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0deec969414b88ee063313edbfbdc371.setContent(html_82bce817c35d96999b8840f822a8a8bd);
#
#
#
#         marker_288e29e05975721f23ae335fb92aea67.bindPopup(popup_0deec969414b88ee063313edbfbdc371)
#         ;
#
#
#
#
#             var marker_5343f6ff16dbc103466cfb26c20e514f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6d89d6ce3b57d810f6f8ecd7ded7bc3);
#
#
#         var popup_098b78112361d66ca38aac978914fa12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c9f2101d0a6c01931e0deffe423fe5e = $(`&lt;div id=&quot;html_4c9f2101d0a6c01931e0deffe423fe5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_098b78112361d66ca38aac978914fa12.setContent(html_4c9f2101d0a6c01931e0deffe423fe5e);
#
#
#
#         marker_
