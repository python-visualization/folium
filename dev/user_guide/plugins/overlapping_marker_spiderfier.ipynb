# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6c23f8105d79f740a2dd65a6f5dfdce {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6c23f8105d79f740a2dd65a6f5dfdce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6c23f8105d79f740a2dd65a6f5dfdce = L.map(
#                 &quot;map_f6c23f8105d79f740a2dd65a6f5dfdce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39c34173f4177427700f55f6d107683b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39c34173f4177427700f55f6d107683b.addTo(map_f6c23f8105d79f740a2dd65a6f5dfdce);
#
#
#             var marker_f1a5ff8a691683b193332cedb36ac3cb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f6c23f8105d79f740a2dd65a6f5dfdce);
#
#
#         var popup_f50f54da1941b93791c7f17317499432 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13a0efe840418e770e6cf64be235361d = $(`&lt;div id=&quot;html_13a0efe840418e770e6cf64be235361d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f50f54da1941b93791c7f17317499432.setContent(html_13a0efe840418e770e6cf64be235361d);
#
#
#
#         marker_f1a5ff8a691683b193332cedb36ac3cb.bindPopup(popup_f50f54da1941b93791c7f17317499432)
#         ;
#
#
#
#
#             var marker_f276876f220720fd46496a0d97bed50e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f6c23f8105d79f740a2dd65a6f5dfdce);
#
#
#         var popup_2655d4d5dcb920dfcfdeccb481728129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a622f31b5c2d93df82853f087eb57191 = $(`&lt;div id=&quot;html_a622f31b5c2d93df82853f087eb57191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2655d4d5dcb920dfcfdeccb481728129.setContent(html_a622f31b5c2d93df82853f087eb57191);
#
#
#
#         marker_f276876f220720fd46496a0d97bed50e.bindPopup(popup_2655d4d5dcb920dfcfdeccb481728129)
#         ;
#
#
#
#
#             var marker_9837f0aee2cbe8804099851738675639 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f6c23f8105d79f740a2dd65a6f5dfdce);
#
#
#         var popup_099e24b801b25f76b779800e44abedb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3949ac79e368fd86fb75a6e54d3c32f9 = $(`&lt;div id=&quot;html_3949ac79e368fd86fb75a6e54d3c32f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_099e24b801b25f76b779800e44abedb9.setContent(html_3949ac79e368fd86fb75a6e54d3c32f9);
#
#
#
#         marker_9837f0aee2cbe8804099851738675639.bindPopup(popup_099e24b801b25f76b779800e44abedb9)
#         ;
#
#
#
#
#             var marker_86ddd994824f0da3604d2a2b25bf81ae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f6c23f8105d79f740a2dd65a6f5dfdce);
#
#
#         var popup_f81bb90e1d567db7bfa301841b6cce10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1e6c6f7fc630e3bdd74dbf8ba9a2f22 = $(`&lt;div id=&quot;html_f1e6c6f7fc630e3bdd74dbf8ba9a2f22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f81bb90e1d567db7bfa301841b6cce10.setContent(html_f1e6c6f7fc630e3bdd74dbf8ba9a2f22);
#
#
#
#         marker_86ddd994824f0da3604d2a2b25bf81ae.bindPopup(popup_f81bb90e1d567db7bfa301841b6cce10)
#         ;
#
#
#
#
#             var marker_13797f4a6d637b7a6744be95507fd04c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f6c23f8105d79f740a2dd65a6f5dfdce);
#
#
#         var popup_aad6ac833e3d2a731a59762432e6e8e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6275387e2d1289f40c00c82858bbd79e = $(`&lt;div id=&quot;html_6275387e2d1289f40c00c82858bbd79e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aad6ac833e3d2a731a59762432e6e8e3.setContent(html_6275387e2d1289f40c00c82858bbd79e);
#
#
#
#         marker_13797f4a6d637b7a6744be95507fd04c.bindPopup(popup_aad6ac833e3d2a731a59762432e6e8e3)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85356e514c32937b5d67bff60ab7e557 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85356e514c32937b5d67bff60ab7e557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85356e514c32937b5d67bff60ab7e557 = L.map(
#                 &quot;map_85356e514c32937b5d67bff60ab7e557&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a33bf25c70f1d5e2ad1b34c1c0ea455d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a33bf25c70f1d5e2ad1b34c1c0ea455d.addTo(map_85356e514c32937b5d67bff60ab7e557);
#
#
#             var feature_group_8cf0ec037b7609b0e3e3770a7d041266 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ffe7abdc6c057ed71bd440be16ba5e2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8cf0ec037b7609b0e3e3770a7d041266);
#
#
#         var popup_cb2a05507ca45ccb183d30aa6845f49b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78ed642166c4b1114b6279de3845f60c = $(`&lt;div id=&quot;html_78ed642166c4b1114b6279de3845f60c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cb2a05507ca45ccb183d30aa6845f49b.setContent(html_78ed642166c4b1114b6279de3845f60c);
#
#
#
#         marker_ffe7abdc6c057ed71bd440be16ba5e2d.bindPopup(popup_cb2a05507ca45ccb183d30aa6845f49b)
#         ;
#
#
#
#
#             var marker_d5d2a02acc112e7177144bded7a28607 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8cf0ec037b7609b0e3e3770a7d041266);
#
#
#         var popup_52b42259734253ece1321f421820c3ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72b583162846fcf181f4a765e774c1d6 = $(`&lt;div id=&quot;html_72b583162846fcf181f4a765e774c1d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52b42259734253ece1321f421820c3ff.setContent(html_72b583162846fcf181f4a765e774c1d6);
#
#
#
#         marker_d5d2a02acc112e7177144bded7a28607.bindPopup(popup_52b42259734253ece1321f421820c3ff)
#         ;
#
#
#
#
#             var marker_b1995ffef84418d79dce369c038fc5ba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8cf0ec037b7609b0e3e3770a7d041266);
#
#
#         var popup_91dc5128b8cab7f58cb0bbfc2b55249a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acec08f53fdbe2dc2710a82a7289f109 = $(`&lt;div id=&quot;html_acec08f53fdbe2dc2710a82a7289f109&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_91dc5128b8cab7f58cb0bbfc2b55249a.setContent(html_acec08f53fdbe2dc2710a82a7289f109);
#
#
#
#         marker_b1995ffef84418d79dce369c038fc5ba.bindPopup(popup_91dc5128b8cab7f58cb0bbfc2b55249a)
#         ;
#
#
#
#
#             var marker_ee05ba25e0169c671cc475c81e8334cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8cf0ec037b7609b0e3e3770a7d041266);
#
#
#         var popup_b40b6cfa49857ef08dc6189f2216f533 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18721b144707ac50502476c393d03366 = $(`&lt;div id=&quot;html_18721b144707ac50502476c393d03366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b40b6cfa49857ef08dc6189f2216f533.setContent(html_18721b144707ac50502476c393d03366);
#
#
#
#         marker_ee05ba25e0169c671cc475c81e8334cd.bindPopup(popup_b40b6cfa49857ef08dc6189f2216f533)
#         ;
#
#
#
#
#             var marker_5efab5e4f92c09fcd350183a7a39df94 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8cf0ec037b7609b0e3e3770a7d041266);
#
#
#         var popup_d05c3768254d3e12284990ed61da17fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfd27e66fede22b65a56e03b9595b5ab = $(`&lt;div id=&quot;html_dfd27e66fede22b65a56e03b9595b5ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16428a452d60ae1b938ab72bf18e55f7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16428a452d60ae1b938ab72bf18e55f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16428a452d60ae1b938ab72bf18e55f7 = L.map(
#                 &quot;map_16428a452d60ae1b938ab72bf18e55f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_860ffc763a2b2dbc22421a49f4de480c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_860ffc763a2b2dbc22421a49f4de480c.addTo(map_16428a452d60ae1b938ab72bf18e55f7);
#
#
#             var feature_group_ca7f75d46c715c456e108a46d04b300e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ca7f75d46c715c456e108a46d04b300e.addTo(map_16428a452d60ae1b938ab72bf18e55f7);
#
#
#             var feature_group_sub_group_def297989a8aecc402f7d6718692d361 = L.featureGroup.subGroup(
#                 feature_group_ca7f75d46c715c456e108a46d04b300e
#             );
#
#
#             var marker_9cc633708f9a836190a8705d01d08d2e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_def297989a8aecc402f7d6718692d361);
#
#
#         var popup_6763c60198385e1cc3dea6b9e987400b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f9562a930ddd38c5a1d4f77e1019cd3 = $(`&lt;div id=&quot;html_7f9562a930ddd38c5a1d4f77e1019cd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6763c60198385e1cc3dea6b9e987400b.setContent(html_7f9562a930ddd38c5a1d4f77e1019cd3);
#
#
#
#         marker_9cc633708f9a836190a8705d01d08d2e.bindPopup(popup_6763c60198385e1cc3dea6b9e987400b)
#         ;
#
#
#
#
#             var marker_49548cf1ada6865bb333f48f1069e27e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_def297989a8aecc402f7d6718692d361);
#
#
#         var popup_8010b067f0834b1028682b128b6151da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ff1fde84fec7d36e72661691925e5d1 = $(`&lt;div id=&quot;html_8ff1fde84fec7d36e72661691925e5d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8010b067f0834b1028682b128b6151da.setContent(html_8ff1fde84fec7d36e72661691925e5d1);
#
#
#
#         marker_49548cf1ada6865bb333f48f1069e27e.bindPopup(popup_8010b067f0834b1028682b128b6151da)
#         ;
#
#
#
#
#             var marker_666441a2db436f011870ba2a404fab4d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_def297989a8aecc402f7d6718692d361);
#
#
#         var popup_f1d2e86db6830e7c9f0a94aafcb71194 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d0fcfbfd0565cc4e1a472359b4fcee1 = $(`&lt;div id=&quot;html_4d0fcfbfd0565cc4e1a472359b4fcee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f1d2e86db6830e7c9f0a94aafcb71194.setContent(html_4d0fcfbfd0565cc4e1a472359b4fcee1);
#
#
#
#         marker_666441a2db436f011870ba2a404fab4d.bindPopup(popup_f1d2e86db6830e7c9f0a94aafcb71194)
#         ;
#
#
#
#
#             var marker_b41c6d89092005564a129fc0619fa135 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_def297989a8aecc402f7d6718692d361);
#
#
#         var popup_3491bf1b1e8570023e7302e715a6b42c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9320ed1c341829d1684595c0a29e89b = $(`&lt;div id=&quot;html_f9320ed1c341829d1684595c0a29e89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3491bf1b1e8570023e7302e715a6b42c.setContent(html_f9320ed1c341829d1684595c0a29e89b);
#
#
#
#         marker_b41c6d89092005564a129fc0619fa135.bindPopup(popup_3491bf1b1e8570023e7302e715a6b42c)
#         ;
#
#
#
#
#             var marker_e0b2d34326d39f1c81623132cb4b5d1f = L.marker(
#                 [45.0503999
