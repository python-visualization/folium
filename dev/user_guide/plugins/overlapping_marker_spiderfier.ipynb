# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8037689d74c54e1db3a6f4f77a0a18f6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8037689d74c54e1db3a6f4f77a0a18f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8037689d74c54e1db3a6f4f77a0a18f6 = L.map(
#                 &quot;map_8037689d74c54e1db3a6f4f77a0a18f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72aad69e3863dad3c850c6c8df1c7213 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72aad69e3863dad3c850c6c8df1c7213.addTo(map_8037689d74c54e1db3a6f4f77a0a18f6);
#
#
#             var marker_dbb0f20e05df8dba831ac845d4d01d43 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8037689d74c54e1db3a6f4f77a0a18f6);
#
#
#         var popup_138c9527cbd63dd6982de2c70a76826f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7857b0bbafd216e53a423d619875696e = $(`&lt;div id=&quot;html_7857b0bbafd216e53a423d619875696e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_138c9527cbd63dd6982de2c70a76826f.setContent(html_7857b0bbafd216e53a423d619875696e);
#
#
#
#         marker_dbb0f20e05df8dba831ac845d4d01d43.bindPopup(popup_138c9527cbd63dd6982de2c70a76826f)
#         ;
#
#
#
#
#             var marker_989617d38a26a9a04ccf5b9471a590a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8037689d74c54e1db3a6f4f77a0a18f6);
#
#
#         var popup_a5da3e47ccdad50aaee894c6cdb134bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24a7c95c2d5a56746a24ee3aa4d06a62 = $(`&lt;div id=&quot;html_24a7c95c2d5a56746a24ee3aa4d06a62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a5da3e47ccdad50aaee894c6cdb134bf.setContent(html_24a7c95c2d5a56746a24ee3aa4d06a62);
#
#
#
#         marker_989617d38a26a9a04ccf5b9471a590a6.bindPopup(popup_a5da3e47ccdad50aaee894c6cdb134bf)
#         ;
#
#
#
#
#             var marker_cecf89c0cc0bd7f20979a199b126fa83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8037689d74c54e1db3a6f4f77a0a18f6);
#
#
#         var popup_514443291859050ddfaeb459af91f68d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b01440aa64e5dd83242d6b47410cf6b1 = $(`&lt;div id=&quot;html_b01440aa64e5dd83242d6b47410cf6b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_514443291859050ddfaeb459af91f68d.setContent(html_b01440aa64e5dd83242d6b47410cf6b1);
#
#
#
#         marker_cecf89c0cc0bd7f20979a199b126fa83.bindPopup(popup_514443291859050ddfaeb459af91f68d)
#         ;
#
#
#
#
#             var marker_00df033f27fc1519b7690c2495cbd5e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8037689d74c54e1db3a6f4f77a0a18f6);
#
#
#         var popup_2a7976f49b8de73b9376097deec52be8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d19577d63e7560556bddd2196544dc19 = $(`&lt;div id=&quot;html_d19577d63e7560556bddd2196544dc19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2a7976f49b8de73b9376097deec52be8.setContent(html_d19577d63e7560556bddd2196544dc19);
#
#
#
#         marker_00df033f27fc1519b7690c2495cbd5e0.bindPopup(popup_2a7976f49b8de73b9376097deec52be8)
#         ;
#
#
#
#
#             var marker_13ceb0dd52386adfb969c232b2d7744f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8037689d74c54e1db3a6f4f77a0a18f6);
#
#
#         var popup_eefbfbd0a8a36cd864b23512d6061d2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_905cbed91b367cba686b6f285ccb8418 = $(`&lt;div id=&quot;html_905cbed91b367cba686b6f285ccb8418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eefbfbd0a8a36cd864b23512d6061d

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74db63d4ede430f8f80bd994a5a8ee48 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74db63d4ede430f8f80bd994a5a8ee48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74db63d4ede430f8f80bd994a5a8ee48 = L.map(
#                 &quot;map_74db63d4ede430f8f80bd994a5a8ee48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47a70ab75d212a392eda4989d5eb70df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_47a70ab75d212a392eda4989d5eb70df.addTo(map_74db63d4ede430f8f80bd994a5a8ee48);
#
#
#             var feature_group_eb31361b8e7cfbd4868efe164c5e4410 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7c7f7034de4aae445a874d33af91e06f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eb31361b8e7cfbd4868efe164c5e4410);
#
#
#         var popup_c0a93fdd8dc3eaf9e9795480d6c1dcc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90159fa47fa81f3604abd537e7427295 = $(`&lt;div id=&quot;html_90159fa47fa81f3604abd537e7427295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c0a93fdd8dc3eaf9e9795480d6c1dcc5.setContent(html_90159fa47fa81f3604abd537e7427295);
#
#
#
#         marker_7c7f7034de4aae445a874d33af91e06f.bindPopup(popup_c0a93fdd8dc3eaf9e9795480d6c1dcc5)
#         ;
#
#
#
#
#             var marker_ddc8b5f04fc6801c3ee3e5faf37910af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eb31361b8e7cfbd4868efe164c5e4410);
#
#
#         var popup_b76506d0199af935525caa7829c9c750 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ec8d06f5754cd251163fca03a65f665 = $(`&lt;div id=&quot;html_1ec8d06f5754cd251163fca03a65f665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b76506d0199af935525caa7829c9c750.setContent(html_1ec8d06f5754cd251163fca03a65f665);
#
#
#
#         marker_ddc8b5f04fc6801c3ee3e5faf37910af.bindPopup(popup_b76506d0199af935525caa7829c9c750)
#         ;
#
#
#
#
#             var marker_6559b31a97150a85420cd78da50dda40 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eb31361b8e7cfbd4868efe164c5e4410);
#
#
#         var popup_2a9f704d0dd9961d1c3ce21a9170cb0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba4d93383af80cafe99c6965e3e1fc03 = $(`&lt;div id=&quot;html_ba4d93383af80cafe99c6965e3e1fc03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2a9f704d0dd9961d1c3ce21a9170cb0d.setContent(html_ba4d93383af80cafe99c6965e3e1fc03);
#
#
#
#         marker_6559b31a97150a85420cd78da50dda40.bindPopup(popup_2a9f704d0dd9961d1c3ce21a9170cb0d)
#         ;
#
#
#
#
#             var marker_28d49e08c3b498a4c2ec6241fdba06d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eb31361b8e7cfbd4868efe164c5e4410);
#
#
#         var popup_60b0269d754d55c0b2b217bf6453607d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23dd0d16a2ea10123962685adadeced1 = $(`&lt;div id=&quot;html_23dd0d16a2ea10123962685adadeced1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_60b0269d754d55c0b2b217bf6453607d.setContent(html_23dd0d16a2ea10123962685adadeced1);
#
#
#
#         marker_28d49e08c3b498a4c2ec6241fdba06d2.bindPopup(popup_60b0269d754d55c0b2b217bf6453607d)
#         ;
#
#
#
#
#             var marker_c3a13a1f052a282a6fb73a883b01dccc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eb31361b8e7cfbd4868efe164c5e4410);
#
#
#         var popup_7fd1acea0daf8085e73b27e0dade73f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_997cee78b51282af0c404650bc37d91f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_997cee78b51282af0c404650bc37d91f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_997cee78b51282af0c404650bc37d91f = L.map(
#                 &quot;map_997cee78b51282af0c404650bc37d91f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4229b7bc1b1e9064f80d5c6628150920 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4229b7bc1b1e9064f80d5c6628150920.addTo(map_997cee78b51282af0c404650bc37d91f);
#
#
#             var feature_group_b4a12294ccef5764fa8a10edbfcca696 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b4a12294ccef5764fa8a10edbfcca696.addTo(map_997cee78b51282af0c404650bc37d91f);
#
#
#             var feature_group_sub_group_f56a8dcd9a8437b4504b70ac2bc5e3a4 = L.featureGroup.subGroup(
#                 feature_group_b4a12294ccef5764fa8a10edbfcca696
#             );
#
#
#             var marker_5e2158a847230bfc14eba6d0cfc348e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f56a8dcd9a8437b4504b70ac2bc5e3a4);
#
#
#         var popup_0d48dc7a8a4eaacad10ffe6e9c508918 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52dbcdd42a135107bd6ff6e0383e7fd9 = $(`&lt;div id=&quot;html_52dbcdd42a135107bd6ff6e0383e7fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0d48dc7a8a4eaacad10ffe6e9c508918.setContent(html_52dbcdd42a135107bd6ff6e0383e7fd9);
#
#
#
#         marker_5e2158a847230bfc14eba6d0cfc348e4.bindPopup(popup_0d48dc7a8a4eaacad10ffe6e9c508918)
#         ;
#
#
#
#
#             var marker_9d95f84e95fabe6b3dea6d1d31d4a77a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f56a8dcd9a8437b4504b70ac2bc5e3a4);
#
#
#         var popup_1ab6604dd8d42cf92bd9658251bffb19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68ebde47f2b0068a65d6b1d5f304d89f = $(`&lt;div id=&quot;html_68ebde47f2b0068a65d6b1d5f304d89f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1ab6604dd8d42cf92bd9658251bffb19.setContent(html_68ebde47f2b0068a65d6b1d5f304d89f);
#
#
#
#         marker_9d95f84e95fabe6b3dea6d1d31d4a77a.bindPopup(popup_1ab6604dd8d42cf92bd9658251bffb19)
#         ;
#
#
#
#
#             var marker_09a89ec38ef7bab874829d4f8f9af931 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f56a8dcd9a8437b4504b70ac2bc5e3a4);
#
#
#         var popup_3ff63b6a51b5d85a43cbec1049c4831f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_239a5cd5896fa2f2c921e85fa8a9646f = $(`&lt;div id=&quot;html_239a5cd5896fa2f2c921e85fa8a9646f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3ff63b6a51b5d85a43cbec1049c4831f.setContent(html_239a5cd5896fa2f2c921e85fa8a9646f);
#
#
#
#         marker_09a89ec38ef7bab874829d4f8f9af931.bindPopup(popup_3ff63b6a51b5d85a43cbec1049c4831f)
#         ;
#
#
#
#
#             var marker_ebc1ff574f79a575d28a08fde5ef2354 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f56a8dcd9a8437b4504b70ac2bc5e3a4);
#
#
#         var popup_70dd13f052e3d3f3859d8de26cccadae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a6c49323118da5d0f8d90b8837e93ca = $(`&lt;div id=&quot;html_6a6c49323118da5d0f8d90b8837e93ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_70dd13f052e3d3f3859d8de26cccadae.setContent(html_6a6c49323118da5d0f8d90b8837e93ca);
#
#
#
#         mark
