# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d01458ec4fc2c3484dbcd8960a94252 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d01458ec4fc2c3484dbcd8960a94252&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d01458ec4fc2c3484dbcd8960a94252 = L.map(
#                 &quot;map_2d01458ec4fc2c3484dbcd8960a94252&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8919721aff8b429a8b47a96b34bece3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8919721aff8b429a8b47a96b34bece3d.addTo(map_2d01458ec4fc2c3484dbcd8960a94252);
#
#
#             var marker_9caa77ed45db011eaddd8a3d752d22f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2d01458ec4fc2c3484dbcd8960a94252);
#
#
#         var popup_7951908c2ab206cc0955818207217bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dd6ffdb1fef687c30adb47869ade2a3 = $(`&lt;div id=&quot;html_8dd6ffdb1fef687c30adb47869ade2a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7951908c2ab206cc0955818207217bf6.setContent(html_8dd6ffdb1fef687c30adb47869ade2a3);
#
#
#
#         marker_9caa77ed45db011eaddd8a3d752d22f9.bindPopup(popup_7951908c2ab206cc0955818207217bf6)
#         ;
#
#
#
#
#             var marker_c9723d61a9f686a895499826b0e85485 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2d01458ec4fc2c3484dbcd8960a94252);
#
#
#         var popup_5cd4948b0d24ebfbde07cf950c732e15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fea5bb35bdddd02b8d62d94cad3dcc9a = $(`&lt;div id=&quot;html_fea5bb35bdddd02b8d62d94cad3dcc9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5cd4948b0d24ebfbde07cf950c732e15.setContent(html_fea5bb35bdddd02b8d62d94cad3dcc9a);
#
#
#
#         marker_c9723d61a9f686a895499826b0e85485.bindPopup(popup_5cd4948b0d24ebfbde07cf950c732e15)
#         ;
#
#
#
#
#             var marker_4cffa91555d9dabf1f983a2872355836 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2d01458ec4fc2c3484dbcd8960a94252);
#
#
#         var popup_5db9ff1555c8a6e108fcee2c475282cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a02d80ad24fdc6221ee60368281c2c75 = $(`&lt;div id=&quot;html_a02d80ad24fdc6221ee60368281c2c75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5db9ff1555c8a6e108fcee2c475282cd.setContent(html_a02d80ad24fdc6221ee60368281c2c75);
#
#
#
#         marker_4cffa91555d9dabf1f983a2872355836.bindPopup(popup_5db9ff1555c8a6e108fcee2c475282cd)
#         ;
#
#
#
#
#             var marker_ad77b12add727fc4fe3cbd12fd454bb0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2d01458ec4fc2c3484dbcd8960a94252);
#
#
#         var popup_e484b615d6f83d453f5f7cbd76f66744 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c3b65202b0fc440e4ef9052d6816785 = $(`&lt;div id=&quot;html_5c3b65202b0fc440e4ef9052d6816785&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e484b615d6f83d453f5f7cbd76f66744.setContent(html_5c3b65202b0fc440e4ef9052d6816785);
#
#
#
#         marker_ad77b12add727fc4fe3cbd12fd454bb0.bindPopup(popup_e484b615d6f83d453f5f7cbd76f66744)
#         ;
#
#
#
#
#             var marker_aad728e5da87c06d4b11e3f516bfffc6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2d01458ec4fc2c3484dbcd8960a94252);
#
#
#         var popup_ffa0b29b428e970660efa0a4e77b66b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72c7c14d72ff5002fba19ea1d095c038 = $(`&lt;div id=&quot;html_72c7c14d72ff5002fba19ea1d095c038&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ffa0b29b428e970660efa0a4e77b66b8.setContent(html_72c7c14d72ff5002fba19ea1d095c038);
#
#
#
#         marker_aad728e5da87c06d4b11e3f516bfffc6.bindPopup(popup_ffa0b29b428e970660efa0a4e77b66b8)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf8c8e7db389c4d56d5c5038aec2d0d7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf8c8e7db389c4d56d5c5038aec2d0d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf8c8e7db389c4d56d5c5038aec2d0d7 = L.map(
#                 &quot;map_cf8c8e7db389c4d56d5c5038aec2d0d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e5086afe59ee21248349b4e6761f9a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e5086afe59ee21248349b4e6761f9a3.addTo(map_cf8c8e7db389c4d56d5c5038aec2d0d7);
#
#
#             var feature_group_0a2383fec24eb4cda109b23dcfba135d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c7955e08be5ea1b23f0c64fd6e3300e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0a2383fec24eb4cda109b23dcfba135d);
#
#
#         var popup_15a9dc9a9fb884276cc99009a4c58961 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0d53fb5b34ece3c24b541998e90fea2 = $(`&lt;div id=&quot;html_b0d53fb5b34ece3c24b541998e90fea2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_15a9dc9a9fb884276cc99009a4c58961.setContent(html_b0d53fb5b34ece3c24b541998e90fea2);
#
#
#
#         marker_c7955e08be5ea1b23f0c64fd6e3300e5.bindPopup(popup_15a9dc9a9fb884276cc99009a4c58961)
#         ;
#
#
#
#
#             var marker_67a584198b49f158dfe0c0d7adff39fd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0a2383fec24eb4cda109b23dcfba135d);
#
#
#         var popup_ca46da4bdda2327536d3432b7578df59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d401c50feae5d29dca60e5bdaf222021 = $(`&lt;div id=&quot;html_d401c50feae5d29dca60e5bdaf222021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ca46da4bdda2327536d3432b7578df59.setContent(html_d401c50feae5d29dca60e5bdaf222021);
#
#
#
#         marker_67a584198b49f158dfe0c0d7adff39fd.bindPopup(popup_ca46da4bdda2327536d3432b7578df59)
#         ;
#
#
#
#
#             var marker_5ac21133842b81e721319de22b8c58a7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0a2383fec24eb4cda109b23dcfba135d);
#
#
#         var popup_7b75f389d64ecff5a60befadb02b85b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52baa8ed2b537e44caf48d1c380c8740 = $(`&lt;div id=&quot;html_52baa8ed2b537e44caf48d1c380c8740&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7b75f389d64ecff5a60befadb02b85b5.setContent(html_52baa8ed2b537e44caf48d1c380c8740);
#
#
#
#         marker_5ac21133842b81e721319de22b8c58a7.bindPopup(popup_7b75f389d64ecff5a60befadb02b85b5)
#         ;
#
#
#
#
#             var marker_24e4d6ead35994d617950e447bb797e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0a2383fec24eb4cda109b23dcfba135d);
#
#
#         var popup_2c3996307c50835bd3a6d9a9061014ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92c575dd91e9b0849fb9e35725d5d528 = $(`&lt;div id=&quot;html_92c575dd91e9b0849fb9e35725d5d528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c3996307c50835bd3a6d9a9061014ae.setContent(html_92c575dd91e9b0849fb9e35725d5d528);
#
#
#
#         marker_24e4d6ead35994d617950e447bb797e8.bindPopup(popup_2c3996307c50835bd3a6d9a9061014ae)
#         ;
#
#
#
#
#             var marker_303d7566d6a59c93139f993750b4359a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0a2383fec24eb4cda109b23dcfba135d);
#
#
#         var popup_7d7cee0adc6610c4f2571ca290953f24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6e8e3b27df52b82700d3031a4bc8e30 = $(`&lt;div id=&quot;html_e6e8e3b27df52b82700d3031a4bc8e30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd26f73fa04464b0042e57b676acb409 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd26f73fa04464b0042e57b676acb409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd26f73fa04464b0042e57b676acb409 = L.map(
#                 &quot;map_bd26f73fa04464b0042e57b676acb409&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b4575961aa16599f390d8c30fb13b61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b4575961aa16599f390d8c30fb13b61.addTo(map_bd26f73fa04464b0042e57b676acb409);
#
#
#             var feature_group_ba69314e92441e19799924474b61f3ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ba69314e92441e19799924474b61f3ac.addTo(map_bd26f73fa04464b0042e57b676acb409);
#
#
#             var feature_group_sub_group_cd32e08d6eba6a72a6987a13858351ab = L.featureGroup.subGroup(
#                 feature_group_ba69314e92441e19799924474b61f3ac
#             );
#
#
#             var marker_fbeb6593a332f41a3b5ee734c4e14b3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd32e08d6eba6a72a6987a13858351ab);
#
#
#         var popup_b41327851fad4ee8fa1bd0289f86b595 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0cd43746bb1fd06e8c683eb4f603756 = $(`&lt;div id=&quot;html_a0cd43746bb1fd06e8c683eb4f603756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b41327851fad4ee8fa1bd0289f86b595.setContent(html_a0cd43746bb1fd06e8c683eb4f603756);
#
#
#
#         marker_fbeb6593a332f41a3b5ee734c4e14b3b.bindPopup(popup_b41327851fad4ee8fa1bd0289f86b595)
#         ;
#
#
#
#
#             var marker_dad915d2eef3e710e2761c7d7d188f62 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd32e08d6eba6a72a6987a13858351ab);
#
#
#         var popup_ef6f6b3a913b8eb716dee7b3c02b3d8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d43b23b1bc50f3c990086320ccb433f = $(`&lt;div id=&quot;html_3d43b23b1bc50f3c990086320ccb433f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ef6f6b3a913b8eb716dee7b3c02b3d8b.setContent(html_3d43b23b1bc50f3c990086320ccb433f);
#
#
#
#         marker_dad915d2eef3e710e2761c7d7d188f62.bindPopup(popup_ef6f6b3a913b8eb716dee7b3c02b3d8b)
#         ;
#
#
#
#
#             var marker_4d3416347129bb296cd0728282661094 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd32e08d6eba6a72a6987a13858351ab);
#
#
#         var popup_54e97858d9f7609202ad2677619bc262 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44854af047a867795d65caa7c2d04423 = $(`&lt;div id=&quot;html_44854af047a867795d65caa7c2d04423&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_54e97858d9f7609202ad2677619bc262.setContent(html_44854af047a867795d65caa7c2d04423);
#
#
#
#         marker_4d3416347129bb296cd0728282661094.bindPopup(popup_54e97858d9f7609202ad2677619bc262)
#         ;
#
#
#
#
#             var marker_ce48de3b86d2e672fbb6c8a7eac2ed9a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cd32e08d6eba6a72a6987a13858351ab);
#
#
#         var popup_91a64dcff6b4a39e45fab634193300b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a15296dbb66c08e3f3c504c4f700e42 = $(`&lt;div id=&quot;html_7a15296dbb66c08e3f3c504c4f700e42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_91a64dcff6b4a39e45fab634193300b5.setContent(html_7a15296dbb66c08e3f3c504c4f700e42);
#
#
#
#         marker_ce48de3b86d2e672fbb6c8a7eac2ed9a.bindPopup(popup_91a64dcff6b4a39e45fab634193300b5)
#         ;
#
#
#
#
#             var marker_9a1c1970abccb2c3fa79236297749543 = L.marker(
#                 [45.0503999
