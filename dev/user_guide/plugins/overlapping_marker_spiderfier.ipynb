# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a12a5edb4a4d1b70262b5e51f2d6dbd5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a12a5edb4a4d1b70262b5e51f2d6dbd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a12a5edb4a4d1b70262b5e51f2d6dbd5 = L.map(
#                 &quot;map_a12a5edb4a4d1b70262b5e51f2d6dbd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56700a6b216d4704b2a37ce2da359a43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56700a6b216d4704b2a37ce2da359a43.addTo(map_a12a5edb4a4d1b70262b5e51f2d6dbd5);
#
#
#             var marker_8059390cec233cd2f219632c5cd164e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a12a5edb4a4d1b70262b5e51f2d6dbd5);
#
#
#         var popup_f0f1f056d1ff056133bde9567e6bb640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de9ea6c0f03776303fac260b57b536a4 = $(`&lt;div id=&quot;html_de9ea6c0f03776303fac260b57b536a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f0f1f056d1ff056133bde9567e6bb640.setContent(html_de9ea6c0f03776303fac260b57b536a4);
#
#
#
#         marker_8059390cec233cd2f219632c5cd164e1.bindPopup(popup_f0f1f056d1ff056133bde9567e6bb640)
#         ;
#
#
#
#
#             var marker_9be1b30377129a32cacd1d7a984a1f74 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a12a5edb4a4d1b70262b5e51f2d6dbd5);
#
#
#         var popup_e057926ccc744bd75ce9e2efad832085 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c25375569b2d234bcffd521a3ae0d3a5 = $(`&lt;div id=&quot;html_c25375569b2d234bcffd521a3ae0d3a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e057926ccc744bd75ce9e2efad832085.setContent(html_c25375569b2d234bcffd521a3ae0d3a5);
#
#
#
#         marker_9be1b30377129a32cacd1d7a984a1f74.bindPopup(popup_e057926ccc744bd75ce9e2efad832085)
#         ;
#
#
#
#
#             var marker_39d34da742f73b2290560843a62f3a26 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a12a5edb4a4d1b70262b5e51f2d6dbd5);
#
#
#         var popup_67bc47823179eaf668a08c3cb2a22a05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19dd4405799fb58b8c28c427779b9349 = $(`&lt;div id=&quot;html_19dd4405799fb58b8c28c427779b9349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_67bc47823179eaf668a08c3cb2a22a05.setContent(html_19dd4405799fb58b8c28c427779b9349);
#
#
#
#         marker_39d34da742f73b2290560843a62f3a26.bindPopup(popup_67bc47823179eaf668a08c3cb2a22a05)
#         ;
#
#
#
#
#             var marker_bec89ce4360c018757de96c35a12417f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a12a5edb4a4d1b70262b5e51f2d6dbd5);
#
#
#         var popup_8dac8a21cf692536580d749ec3e9a823 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b45eeb5ef2ad806710f4dbe676884430 = $(`&lt;div id=&quot;html_b45eeb5ef2ad806710f4dbe676884430&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8dac8a21cf692536580d749ec3e9a823.setContent(html_b45eeb5ef2ad806710f4dbe676884430);
#
#
#
#         marker_bec89ce4360c018757de96c35a12417f.bindPopup(popup_8dac8a21cf692536580d749ec3e9a823)
#         ;
#
#
#
#
#             var marker_71350cc6cffb5b16d3967c3ee426f574 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a12a5edb4a4d1b70262b5e51f2d6dbd5);
#
#
#         var popup_7850ba641bed9b0203fe49b46484f4cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_255109af68371fc819f89f7297cc9c62 = $(`&lt;div id=&quot;html_255109af68371fc819f89f7297cc9c62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7850ba641bed9b0203fe49b46484f4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a649dffa155cecbfa9f230adae924d83 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a649dffa155cecbfa9f230adae924d83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a649dffa155cecbfa9f230adae924d83 = L.map(
#                 &quot;map_a649dffa155cecbfa9f230adae924d83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d1134361175eaf5752d77585b55f590 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d1134361175eaf5752d77585b55f590.addTo(map_a649dffa155cecbfa9f230adae924d83);
#
#
#             var feature_group_4460fb640d048a93235965c2abe5349a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_496f8a58a3f219e62875d44da9e34e61 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4460fb640d048a93235965c2abe5349a);
#
#
#         var popup_e18c1af734d6055a255befd882a1429c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4e9b8b61d7409e92cb1fbf084ae6b6a = $(`&lt;div id=&quot;html_d4e9b8b61d7409e92cb1fbf084ae6b6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e18c1af734d6055a255befd882a1429c.setContent(html_d4e9b8b61d7409e92cb1fbf084ae6b6a);
#
#
#
#         marker_496f8a58a3f219e62875d44da9e34e61.bindPopup(popup_e18c1af734d6055a255befd882a1429c)
#         ;
#
#
#
#
#             var marker_b1d65307aee5945241d3c9f84b5ad360 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4460fb640d048a93235965c2abe5349a);
#
#
#         var popup_c5d78e6e1000262dd4c69528e687778a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdefcff36147f6e85f05547f4285ce1d = $(`&lt;div id=&quot;html_bdefcff36147f6e85f05547f4285ce1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c5d78e6e1000262dd4c69528e687778a.setContent(html_bdefcff36147f6e85f05547f4285ce1d);
#
#
#
#         marker_b1d65307aee5945241d3c9f84b5ad360.bindPopup(popup_c5d78e6e1000262dd4c69528e687778a)
#         ;
#
#
#
#
#             var marker_8b01cc6317a91d7993309643859b926e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4460fb640d048a93235965c2abe5349a);
#
#
#         var popup_b50220525fe8663b4104495dab050029 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94050f15e361be1a84b51fbf76123f5a = $(`&lt;div id=&quot;html_94050f15e361be1a84b51fbf76123f5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b50220525fe8663b4104495dab050029.setContent(html_94050f15e361be1a84b51fbf76123f5a);
#
#
#
#         marker_8b01cc6317a91d7993309643859b926e.bindPopup(popup_b50220525fe8663b4104495dab050029)
#         ;
#
#
#
#
#             var marker_de757269a461dd30597bcf83be5b84bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4460fb640d048a93235965c2abe5349a);
#
#
#         var popup_3c708d20ff6c951c7bead4f9b3978822 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b438cc6e27b587990aa472e7d9fa88f = $(`&lt;div id=&quot;html_1b438cc6e27b587990aa472e7d9fa88f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c708d20ff6c951c7bead4f9b3978822.setContent(html_1b438cc6e27b587990aa472e7d9fa88f);
#
#
#
#         marker_de757269a461dd30597bcf83be5b84bc.bindPopup(popup_3c708d20ff6c951c7bead4f9b3978822)
#         ;
#
#
#
#
#             var marker_276295582268b09e879bd3f5300dd987 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4460fb640d048a93235965c2abe5349a);
#
#
#         var popup_3d09aee159e667331aca68f3336ab1fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_740c49e9d3cf42424164064a8175bd9c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_740c49e9d3cf42424164064a8175bd9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_740c49e9d3cf42424164064a8175bd9c = L.map(
#                 &quot;map_740c49e9d3cf42424164064a8175bd9c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71fd067a6c948d29a41a879130b1b48b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71fd067a6c948d29a41a879130b1b48b.addTo(map_740c49e9d3cf42424164064a8175bd9c);
#
#
#             var feature_group_c15b9569fa5e9a522d34bbc3c9792166 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c15b9569fa5e9a522d34bbc3c9792166.addTo(map_740c49e9d3cf42424164064a8175bd9c);
#
#
#             var feature_group_sub_group_3f6907c97f57c2ee84d9ec0c24525b76 = L.featureGroup.subGroup(
#                 feature_group_c15b9569fa5e9a522d34bbc3c9792166
#             );
#
#
#             var marker_f38a2ccf8127cc279bc2bf68c786e36c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f6907c97f57c2ee84d9ec0c24525b76);
#
#
#         var popup_cc05bd5a60c0e3d1d0bbe3abd6512d05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9b2691266143d9ba80c7e6670c72ca4 = $(`&lt;div id=&quot;html_d9b2691266143d9ba80c7e6670c72ca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cc05bd5a60c0e3d1d0bbe3abd6512d05.setContent(html_d9b2691266143d9ba80c7e6670c72ca4);
#
#
#
#         marker_f38a2ccf8127cc279bc2bf68c786e36c.bindPopup(popup_cc05bd5a60c0e3d1d0bbe3abd6512d05)
#         ;
#
#
#
#
#             var marker_24c5d99ece9fe06407c43fff4dc368d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f6907c97f57c2ee84d9ec0c24525b76);
#
#
#         var popup_9d6c25731e89689b5ca27ddb7fd83729 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f36177f9628abe51415a68ae32e0c63 = $(`&lt;div id=&quot;html_0f36177f9628abe51415a68ae32e0c63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9d6c25731e89689b5ca27ddb7fd83729.setContent(html_0f36177f9628abe51415a68ae32e0c63);
#
#
#
#         marker_24c5d99ece9fe06407c43fff4dc368d4.bindPopup(popup_9d6c25731e89689b5ca27ddb7fd83729)
#         ;
#
#
#
#
#             var marker_32aeefb23b940ab6d48ddf521669db10 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f6907c97f57c2ee84d9ec0c24525b76);
#
#
#         var popup_6f44b073a3608b5203d65e0decc13a30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2fca39ef547296811a4fa1bf7bef560 = $(`&lt;div id=&quot;html_f2fca39ef547296811a4fa1bf7bef560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6f44b073a3608b5203d65e0decc13a30.setContent(html_f2fca39ef547296811a4fa1bf7bef560);
#
#
#
#         marker_32aeefb23b940ab6d48ddf521669db10.bindPopup(popup_6f44b073a3608b5203d65e0decc13a30)
#         ;
#
#
#
#
#             var marker_c2f811503202abbf1b028b2868fc6e68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f6907c97f57c2ee84d9ec0c24525b76);
#
#
#         var popup_cc3cdd2d9926ec86b4bd14b018ff0ba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1792eb9eb11155d0c932133b81cda5c5 = $(`&lt;div id=&quot;html_1792eb9eb11155d0c932133b81cda5c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cc3cdd2d9926ec86b4bd14b018ff0ba6.setContent(html_1792eb9eb11155d0c932133b81cda5c5);
#
#
#
#         mark
