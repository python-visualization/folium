# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43b26340054161a95493ebafb765ed9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43b26340054161a95493ebafb765ed9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43b26340054161a95493ebafb765ed9d = L.map(
#                 &quot;map_43b26340054161a95493ebafb765ed9d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_336a2a458beaee3f567e5adc5360a407 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_336a2a458beaee3f567e5adc5360a407.addTo(map_43b26340054161a95493ebafb765ed9d);
#
#
#             var marker_c76e5fa40db3c23299d872cfc9655ae0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_43b26340054161a95493ebafb765ed9d);
#
#
#         var popup_ef24283f02de7f08ac5e67e61145d4e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6189f7e7624b9c09c09762663df761e9 = $(`&lt;div id=&quot;html_6189f7e7624b9c09c09762663df761e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ef24283f02de7f08ac5e67e61145d4e3.setContent(html_6189f7e7624b9c09c09762663df761e9);
#
#
#
#         marker_c76e5fa40db3c23299d872cfc9655ae0.bindPopup(popup_ef24283f02de7f08ac5e67e61145d4e3)
#         ;
#
#
#
#
#             var marker_dec1eba69a1ddbfcf74f56ab92aecd16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_43b26340054161a95493ebafb765ed9d);
#
#
#         var popup_e9963ee17cd8781d27219c0769bec32a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1a09f6f8a0ca7bf773588618602ec6c = $(`&lt;div id=&quot;html_e1a09f6f8a0ca7bf773588618602ec6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e9963ee17cd8781d27219c0769bec32a.setContent(html_e1a09f6f8a0ca7bf773588618602ec6c);
#
#
#
#         marker_dec1eba69a1ddbfcf74f56ab92aecd16.bindPopup(popup_e9963ee17cd8781d27219c0769bec32a)
#         ;
#
#
#
#
#             var marker_f0fdcd5fa1f56ce26d42b0a37f9979a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_43b26340054161a95493ebafb765ed9d);
#
#
#         var popup_e49d5a44da7515b39457b06c1357a6b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46190799165c1db11f2d6c4d4d5ed5eb = $(`&lt;div id=&quot;html_46190799165c1db11f2d6c4d4d5ed5eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e49d5a44da7515b39457b06c1357a6b5.setContent(html_46190799165c1db11f2d6c4d4d5ed5eb);
#
#
#
#         marker_f0fdcd5fa1f56ce26d42b0a37f9979a6.bindPopup(popup_e49d5a44da7515b39457b06c1357a6b5)
#         ;
#
#
#
#
#             var marker_5f7295e47ee318f5ac9385a1d8ff4693 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_43b26340054161a95493ebafb765ed9d);
#
#
#         var popup_13cf988d4d1ae92c2b773a9138c5e586 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_477b31bccfdff61c179c5370a39c9834 = $(`&lt;div id=&quot;html_477b31bccfdff61c179c5370a39c9834&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_13cf988d4d1ae92c2b773a9138c5e586.setContent(html_477b31bccfdff61c179c5370a39c9834);
#
#
#
#         marker_5f7295e47ee318f5ac9385a1d8ff4693.bindPopup(popup_13cf988d4d1ae92c2b773a9138c5e586)
#         ;
#
#
#
#
#             var marker_5884751e5f61d10cecf0feeff50c9397 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_43b26340054161a95493ebafb765ed9d);
#
#
#         var popup_60b1ecd6e30eb50e63bb35a1ba755393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae6a962fef5b4b98d2d6089d4db731bd = $(`&lt;div id=&quot;html_ae6a962fef5b4b98d2d6089d4db731bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_60b1ecd6e30eb50e63bb35a1ba755393.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_642bf77ef6c1f811fd1835bd90f7ec47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_642bf77ef6c1f811fd1835bd90f7ec47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_642bf77ef6c1f811fd1835bd90f7ec47 = L.map(
#                 &quot;map_642bf77ef6c1f811fd1835bd90f7ec47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78c2b5386f0b91ff8b571db337a0346c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78c2b5386f0b91ff8b571db337a0346c.addTo(map_642bf77ef6c1f811fd1835bd90f7ec47);
#
#
#             var feature_group_8c322e2eba32d68461345eac336bdac6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f8c24ff19f5f5d9cbbd4e1619cb455b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8c322e2eba32d68461345eac336bdac6);
#
#
#         var popup_d1ecddea6428a8f780427393d368da42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_083bd09f43f427134b247ccdf7d7e3f5 = $(`&lt;div id=&quot;html_083bd09f43f427134b247ccdf7d7e3f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d1ecddea6428a8f780427393d368da42.setContent(html_083bd09f43f427134b247ccdf7d7e3f5);
#
#
#
#         marker_8f8c24ff19f5f5d9cbbd4e1619cb455b.bindPopup(popup_d1ecddea6428a8f780427393d368da42)
#         ;
#
#
#
#
#             var marker_f2d5fc2615fff1603d358c0b9bafe1a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8c322e2eba32d68461345eac336bdac6);
#
#
#         var popup_527a744df12ec6c6da7b49692c272948 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e540e17ca093685f443d83762701634 = $(`&lt;div id=&quot;html_1e540e17ca093685f443d83762701634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_527a744df12ec6c6da7b49692c272948.setContent(html_1e540e17ca093685f443d83762701634);
#
#
#
#         marker_f2d5fc2615fff1603d358c0b9bafe1a0.bindPopup(popup_527a744df12ec6c6da7b49692c272948)
#         ;
#
#
#
#
#             var marker_b898838209a9181ea66dcdfc2ca3680f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8c322e2eba32d68461345eac336bdac6);
#
#
#         var popup_307aaea95dabd2d660bae7cc7b79b3f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8291eb1c93b31a13ea61b31e7edfc2ab = $(`&lt;div id=&quot;html_8291eb1c93b31a13ea61b31e7edfc2ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_307aaea95dabd2d660bae7cc7b79b3f2.setContent(html_8291eb1c93b31a13ea61b31e7edfc2ab);
#
#
#
#         marker_b898838209a9181ea66dcdfc2ca3680f.bindPopup(popup_307aaea95dabd2d660bae7cc7b79b3f2)
#         ;
#
#
#
#
#             var marker_9789187e28faa950de45d9d44c986e22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8c322e2eba32d68461345eac336bdac6);
#
#
#         var popup_acf5ad27d192e61b2dba5ac3e7e750f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34fb12ff0858728b783fcc7e255053ab = $(`&lt;div id=&quot;html_34fb12ff0858728b783fcc7e255053ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_acf5ad27d192e61b2dba5ac3e7e750f5.setContent(html_34fb12ff0858728b783fcc7e255053ab);
#
#
#
#         marker_9789187e28faa950de45d9d44c986e22.bindPopup(popup_acf5ad27d192e61b2dba5ac3e7e750f5)
#         ;
#
#
#
#
#             var marker_c9b4fc343182377d5b1a52d05e0af757 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8c322e2eba32d68461345eac336bdac6);
#
#
#         var popup_24cfa13bbbaf86de670c96a05d91f10d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edaf04c43fe894e8a3538956640b8c37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edaf04c43fe894e8a3538956640b8c37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edaf04c43fe894e8a3538956640b8c37 = L.map(
#                 &quot;map_edaf04c43fe894e8a3538956640b8c37&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c253e0592912aaf6fff7773f4f22f2d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c253e0592912aaf6fff7773f4f22f2d3.addTo(map_edaf04c43fe894e8a3538956640b8c37);
#
#
#             var feature_group_76d246d9c6190417e20f040311cab68a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_76d246d9c6190417e20f040311cab68a.addTo(map_edaf04c43fe894e8a3538956640b8c37);
#
#
#             var feature_group_sub_group_5367086388b225f0f7676e0ec966e32b = L.featureGroup.subGroup(
#                 feature_group_76d246d9c6190417e20f040311cab68a
#             );
#
#
#             var marker_2ad3bcf1017f5d0ddf21d34305dfc6b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5367086388b225f0f7676e0ec966e32b);
#
#
#         var popup_e0fdf69553fcd5fdd7bbade06be6ddb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7389a02c040ce2c99da8df513cf47e1 = $(`&lt;div id=&quot;html_e7389a02c040ce2c99da8df513cf47e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e0fdf69553fcd5fdd7bbade06be6ddb6.setContent(html_e7389a02c040ce2c99da8df513cf47e1);
#
#
#
#         marker_2ad3bcf1017f5d0ddf21d34305dfc6b8.bindPopup(popup_e0fdf69553fcd5fdd7bbade06be6ddb6)
#         ;
#
#
#
#
#             var marker_5a3ec7dcfeb298d703a5475f3776e923 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5367086388b225f0f7676e0ec966e32b);
#
#
#         var popup_6df42a46d5fd47ff6151efb188080f5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d373e06854de039d1bb3eb4862202f3d = $(`&lt;div id=&quot;html_d373e06854de039d1bb3eb4862202f3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6df42a46d5fd47ff6151efb188080f5e.setContent(html_d373e06854de039d1bb3eb4862202f3d);
#
#
#
#         marker_5a3ec7dcfeb298d703a5475f3776e923.bindPopup(popup_6df42a46d5fd47ff6151efb188080f5e)
#         ;
#
#
#
#
#             var marker_a0699272667f2a8f3a20baa56becdc96 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5367086388b225f0f7676e0ec966e32b);
#
#
#         var popup_7a0dc16c079a0109c264db62da7cfb75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce0f919ed52c8fb463fd8ccc051d36f4 = $(`&lt;div id=&quot;html_ce0f919ed52c8fb463fd8ccc051d36f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7a0dc16c079a0109c264db62da7cfb75.setContent(html_ce0f919ed52c8fb463fd8ccc051d36f4);
#
#
#
#         marker_a0699272667f2a8f3a20baa56becdc96.bindPopup(popup_7a0dc16c079a0109c264db62da7cfb75)
#         ;
#
#
#
#
#             var marker_d8e9ed2e3cf2053b1da8f9435c0d9c9c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5367086388b225f0f7676e0ec966e32b);
#
#
#         var popup_cc0d61ca5358c7abe936f7b5d4924313 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7cdc51df4af4f56d52f70d321244d6d = $(`&lt;div id=&quot;html_f7cdc51df4af4f56d52f70d321244d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cc0d61ca5358c7abe936f7b5d4924313.setContent(html_f7cdc51df4af4f56d52f70d321244d6d);
#
#
#
#         marker_
