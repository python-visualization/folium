# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08e8580bf4ff85e37bbd48890810dba5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08e8580bf4ff85e37bbd48890810dba5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08e8580bf4ff85e37bbd48890810dba5 = L.map(
#                 &quot;map_08e8580bf4ff85e37bbd48890810dba5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ef3d11a3988f7c40046fc54f83c0fb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ef3d11a3988f7c40046fc54f83c0fb1.addTo(map_08e8580bf4ff85e37bbd48890810dba5);
#
#
#             var marker_03c728195acb108d052b3e372a9d1a8b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_08e8580bf4ff85e37bbd48890810dba5);
#
#
#         var popup_e3c20d9a90282989e245decf546f6c05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b753adfa7d90e7f7deac871f461d30f = $(`&lt;div id=&quot;html_3b753adfa7d90e7f7deac871f461d30f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e3c20d9a90282989e245decf546f6c05.setContent(html_3b753adfa7d90e7f7deac871f461d30f);
#
#
#
#         marker_03c728195acb108d052b3e372a9d1a8b.bindPopup(popup_e3c20d9a90282989e245decf546f6c05)
#         ;
#
#
#
#
#             var marker_705f477964c2923b110a440094ac209a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_08e8580bf4ff85e37bbd48890810dba5);
#
#
#         var popup_9883a0bd79eb40f82cab72762c0bfc01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a9608087596611d58607253099bc5d9 = $(`&lt;div id=&quot;html_7a9608087596611d58607253099bc5d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9883a0bd79eb40f82cab72762c0bfc01.setContent(html_7a9608087596611d58607253099bc5d9);
#
#
#
#         marker_705f477964c2923b110a440094ac209a.bindPopup(popup_9883a0bd79eb40f82cab72762c0bfc01)
#         ;
#
#
#
#
#             var marker_c568fb72574a6c68baf8f84c15fb9918 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_08e8580bf4ff85e37bbd48890810dba5);
#
#
#         var popup_4d951833244eda3b2c5edb990e8d3bcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70e3ea2471b9b9e09cb317d9f1617bca = $(`&lt;div id=&quot;html_70e3ea2471b9b9e09cb317d9f1617bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4d951833244eda3b2c5edb990e8d3bcf.setContent(html_70e3ea2471b9b9e09cb317d9f1617bca);
#
#
#
#         marker_c568fb72574a6c68baf8f84c15fb9918.bindPopup(popup_4d951833244eda3b2c5edb990e8d3bcf)
#         ;
#
#
#
#
#             var marker_22f2f8fbd9ae46004cf6ef8b3df296fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_08e8580bf4ff85e37bbd48890810dba5);
#
#
#         var popup_f8848e0bf832b0ff91883e45c02837ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcc60d62103bbe86922b12856cc1fcc6 = $(`&lt;div id=&quot;html_bcc60d62103bbe86922b12856cc1fcc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f8848e0bf832b0ff91883e45c02837ee.setContent(html_bcc60d62103bbe86922b12856cc1fcc6);
#
#
#
#         marker_22f2f8fbd9ae46004cf6ef8b3df296fc.bindPopup(popup_f8848e0bf832b0ff91883e45c02837ee)
#         ;
#
#
#
#
#             var marker_f675e6b403c5c70a99f0a3af1a0e13da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_08e8580bf4ff85e37bbd48890810dba5);
#
#
#         var popup_bb43bd5be1a4c01270b7d24a725fab0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3f30c1e55f87aab2dd81341c3cd19a8 = $(`&lt;div id=&quot;html_c3f30c1e55f87aab2dd81341c3cd19a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bb43bd5be1a4c01270b7d24a725fab0d.setContent(html_c3f30c1e55f87aab2dd81341c3cd19a8);
#
#
#
#         marker_f675e6b403c5c70a99f0a3af1a0e13da.bindPopup(popup_bb43bd5be1a4c01270b7d24a725fab0d)
#         ;
#
#
#
#
#             var marker_2d0c7ca8b0

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c610c776cf846db1af7776322663314 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c610c776cf846db1af7776322663314&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c610c776cf846db1af7776322663314 = L.map(
#                 &quot;map_5c610c776cf846db1af7776322663314&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bba678c3ead511594ce5958d379f98a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bba678c3ead511594ce5958d379f98a.addTo(map_5c610c776cf846db1af7776322663314);
#
#
#             var feature_group_d99f3dba6e3cdbd230e81e80d4747381 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3fc5912a2f6dddbea1cf8e6b17eeff95 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d99f3dba6e3cdbd230e81e80d4747381);
#
#
#         var popup_c47cf6411e3a3c9f4c46ebd73d82bb1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5871e2a430be53a0e3b4c8ba9cccd04b = $(`&lt;div id=&quot;html_5871e2a430be53a0e3b4c8ba9cccd04b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c47cf6411e3a3c9f4c46ebd73d82bb1c.setContent(html_5871e2a430be53a0e3b4c8ba9cccd04b);
#
#
#
#         marker_3fc5912a2f6dddbea1cf8e6b17eeff95.bindPopup(popup_c47cf6411e3a3c9f4c46ebd73d82bb1c)
#         ;
#
#
#
#
#             var marker_f7e89d51822e45a77c84c9d9877bd337 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d99f3dba6e3cdbd230e81e80d4747381);
#
#
#         var popup_6733be4b13af91c9b571c4e45e3773b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6128b3c517ffca30c27e687435c50392 = $(`&lt;div id=&quot;html_6128b3c517ffca30c27e687435c50392&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6733be4b13af91c9b571c4e45e3773b4.setContent(html_6128b3c517ffca30c27e687435c50392);
#
#
#
#         marker_f7e89d51822e45a77c84c9d9877bd337.bindPopup(popup_6733be4b13af91c9b571c4e45e3773b4)
#         ;
#
#
#
#
#             var marker_d41f9fa4cf46ff50f1363b71eccb128e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d99f3dba6e3cdbd230e81e80d4747381);
#
#
#         var popup_e893da8d4019ab6c773dddbdc2f006c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6096d386dcabaaad95db55bc316d7e67 = $(`&lt;div id=&quot;html_6096d386dcabaaad95db55bc316d7e67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e893da8d4019ab6c773dddbdc2f006c9.setContent(html_6096d386dcabaaad95db55bc316d7e67);
#
#
#
#         marker_d41f9fa4cf46ff50f1363b71eccb128e.bindPopup(popup_e893da8d4019ab6c773dddbdc2f006c9)
#         ;
#
#
#
#
#             var marker_bbd12a51be4852d46f656669a0d664f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d99f3dba6e3cdbd230e81e80d4747381);
#
#
#         var popup_c508262234d3893cbf537e674a5614ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7af42ed4a0f5a794cf715f85ed49fe1 = $(`&lt;div id=&quot;html_a7af42ed4a0f5a794cf715f85ed49fe1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c508262234d3893cbf537e674a5614ac.setContent(html_a7af42ed4a0f5a794cf715f85ed49fe1);
#
#
#
#         marker_bbd12a51be4852d46f656669a0d664f8.bindPopup(popup_c508262234d3893cbf537e674a5614ac)
#         ;
#
#
#
#
#             var marker_4da451b31a2c60ce37799a6232cc12a0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d99f3dba6e3cdbd230e81e80d4747381);
#
#
#         var popup_e42a418b9f9957ecf1a04e213bbfdb19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cdb540e640238d7e13fa4a94b299313 = $(`&lt;div id=&quot;html_6cdb540e640238d7e13fa4a94b299313&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_e42a418b9f9957ecf1

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a3f0db6ddce4319b31bddba2772ab8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a3f0db6ddce4319b31bddba2772ab8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a3f0db6ddce4319b31bddba2772ab8a = L.map(
#                 &quot;map_6a3f0db6ddce4319b31bddba2772ab8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3924b18d7214e3af791037ddbc3166f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3924b18d7214e3af791037ddbc3166f1.addTo(map_6a3f0db6ddce4319b31bddba2772ab8a);
#
#
#             var feature_group_38fd584f2247f336b391690537aacb54 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_38fd584f2247f336b391690537aacb54.addTo(map_6a3f0db6ddce4319b31bddba2772ab8a);
#
#
#             var feature_group_sub_group_020bba999edcfa588763e7856ebba65b = L.featureGroup.subGroup(
#                 feature_group_38fd584f2247f336b391690537aacb54
#             );
#
#
#             var marker_433b58d0b077db63c9f7680ecbceebdb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_020bba999edcfa588763e7856ebba65b);
#
#
#         var popup_452e0b14f5d4e0d35f5d8d8536d872fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51a5da8ac00c009c20882be2f2e63733 = $(`&lt;div id=&quot;html_51a5da8ac00c009c20882be2f2e63733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_452e0b14f5d4e0d35f5d8d8536d872fe.setContent(html_51a5da8ac00c009c20882be2f2e63733);
#
#
#
#         marker_433b58d0b077db63c9f7680ecbceebdb.bindPopup(popup_452e0b14f5d4e0d35f5d8d8536d872fe)
#         ;
#
#
#
#
#             var marker_ca6738dc05143edae7233777be8401d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_020bba999edcfa588763e7856ebba65b);
#
#
#         var popup_f2ef063025cb6234967ed0c7aba5785b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dcc6d49c4904ef834dbe14ca4a18656 = $(`&lt;div id=&quot;html_3dcc6d49c4904ef834dbe14ca4a18656&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2ef063025cb6234967ed0c7aba5785b.setContent(html_3dcc6d49c4904ef834dbe14ca4a18656);
#
#
#
#         marker_ca6738dc05143edae7233777be8401d2.bindPopup(popup_f2ef063025cb6234967ed0c7aba5785b)
#         ;
#
#
#
#
#             var marker_81d6272b4e41ed56e191ed846eaac1a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_020bba999edcfa588763e7856ebba65b);
#
#
#         var popup_d2ae7466c2cb145524427d74ee58ec48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe9063b11454085d79dcd11ab9d4ba95 = $(`&lt;div id=&quot;html_fe9063b11454085d79dcd11ab9d4ba95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d2ae7466c2cb145524427d74ee58ec48.setContent(html_fe9063b11454085d79dcd11ab9d4ba95);
#
#
#
#         marker_81d6272b4e41ed56e191ed846eaac1a2.bindPopup(popup_d2ae7466c2cb145524427d74ee58ec48)
#         ;
#
#
#
#
#             var marker_4240086d81bc65edd05019b1c70eacc0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_020bba999edcfa588763e7856ebba65b);
#
#
#         var popup_62afdb3c0eecacbee9dede5c4e87e06f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b545c1029746010cf20e44504c3be229 = $(`&lt;div id=&quot;html_b545c1029746010cf20e44504c3be229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_62afdb3c0eecacbee9dede5c4e87e06f.setContent(html_b545c1029746010cf20e44504c3be229);
#
#
#
#         marker_4240086d81bc65edd05019b1c70eacc0.bindPopup(popup_62afdb3c0eecacbee9dede5c4e87e06f)
#         ;
#
#
#
#
#             var marker_1f06ee9598bff5845f1c4d028d3030f4 = L.marker(
#                 [45.050399999999996, 3.0504],
