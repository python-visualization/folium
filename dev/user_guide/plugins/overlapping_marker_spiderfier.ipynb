# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_403044aa4238fc3fbe339e2d2249f959 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_403044aa4238fc3fbe339e2d2249f959&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_403044aa4238fc3fbe339e2d2249f959 = L.map(
#                 &quot;map_403044aa4238fc3fbe339e2d2249f959&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59df9fe89f955da56bf95695496774fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59df9fe89f955da56bf95695496774fe.addTo(map_403044aa4238fc3fbe339e2d2249f959);
#
#
#             var marker_40d6d2bb11656b35c68a54955c62970d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_403044aa4238fc3fbe339e2d2249f959);
#
#
#         var popup_b42a3def1ee6756b75a8581fa89a0957 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fee5a26db64ef878cb8bd6954d9de829 = $(`&lt;div id=&quot;html_fee5a26db64ef878cb8bd6954d9de829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b42a3def1ee6756b75a8581fa89a0957.setContent(html_fee5a26db64ef878cb8bd6954d9de829);
#
#
#
#         marker_40d6d2bb11656b35c68a54955c62970d.bindPopup(popup_b42a3def1ee6756b75a8581fa89a0957)
#         ;
#
#
#
#
#             var marker_833e33a02a2581191b90d2ae3be685e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_403044aa4238fc3fbe339e2d2249f959);
#
#
#         var popup_3646cc274a06e31156b82e360cf93171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cffb4b411e761f71c57d49ea338f3aa7 = $(`&lt;div id=&quot;html_cffb4b411e761f71c57d49ea338f3aa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3646cc274a06e31156b82e360cf93171.setContent(html_cffb4b411e761f71c57d49ea338f3aa7);
#
#
#
#         marker_833e33a02a2581191b90d2ae3be685e4.bindPopup(popup_3646cc274a06e31156b82e360cf93171)
#         ;
#
#
#
#
#             var marker_876b9750d88849f9b93fe26e0f8f2537 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_403044aa4238fc3fbe339e2d2249f959);
#
#
#         var popup_ac4f0032927b195cd006b38c9dc2f1a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_933e13d2775ea8221846e55dd8d34eb8 = $(`&lt;div id=&quot;html_933e13d2775ea8221846e55dd8d34eb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ac4f0032927b195cd006b38c9dc2f1a3.setContent(html_933e13d2775ea8221846e55dd8d34eb8);
#
#
#
#         marker_876b9750d88849f9b93fe26e0f8f2537.bindPopup(popup_ac4f0032927b195cd006b38c9dc2f1a3)
#         ;
#
#
#
#
#             var marker_f915cb1fdea66f32652fbe6728cf0760 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_403044aa4238fc3fbe339e2d2249f959);
#
#
#         var popup_a5f70d3723dc8ba539f1fbda3fea5568 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68ce3ad3b97d6e006e3c142e178d6f34 = $(`&lt;div id=&quot;html_68ce3ad3b97d6e006e3c142e178d6f34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a5f70d3723dc8ba539f1fbda3fea5568.setContent(html_68ce3ad3b97d6e006e3c142e178d6f34);
#
#
#
#         marker_f915cb1fdea66f32652fbe6728cf0760.bindPopup(popup_a5f70d3723dc8ba539f1fbda3fea5568)
#         ;
#
#
#
#
#             var marker_37ee7a5997ca5e8f26494bb40043a65f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_403044aa4238fc3fbe339e2d2249f959);
#
#
#         var popup_a040e6b658a0f12a7a382a5c87f151e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66ec045d6070723693ea9b718702b247 = $(`&lt;div id=&quot;html_66ec045d6070723693ea9b718702b247&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a040e6b658a0f12a7a382a5c87f151e2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4ad2a7bdc45556876ee94c3f3f38849 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4ad2a7bdc45556876ee94c3f3f38849&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4ad2a7bdc45556876ee94c3f3f38849 = L.map(
#                 &quot;map_f4ad2a7bdc45556876ee94c3f3f38849&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a5956a5345560778e4fc1fc75dc74a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a5956a5345560778e4fc1fc75dc74a2.addTo(map_f4ad2a7bdc45556876ee94c3f3f38849);
#
#
#             var feature_group_e1a7a1ce4d4b346b0081be83acc201ef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_30b144d512b4d6babd0b1ee9bedd4e6c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e1a7a1ce4d4b346b0081be83acc201ef);
#
#
#         var popup_7928840ab920ce32f08ff81644001aae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98eb02e1a2b459be5f201e7a251e7c2a = $(`&lt;div id=&quot;html_98eb02e1a2b459be5f201e7a251e7c2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7928840ab920ce32f08ff81644001aae.setContent(html_98eb02e1a2b459be5f201e7a251e7c2a);
#
#
#
#         marker_30b144d512b4d6babd0b1ee9bedd4e6c.bindPopup(popup_7928840ab920ce32f08ff81644001aae)
#         ;
#
#
#
#
#             var marker_0e654fe0f524c8f099fe4a6554716b6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e1a7a1ce4d4b346b0081be83acc201ef);
#
#
#         var popup_7ea88433afb94549a9b635b4a36d5bf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_203b6f5449fe5a75c4a722bf31343aa7 = $(`&lt;div id=&quot;html_203b6f5449fe5a75c4a722bf31343aa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7ea88433afb94549a9b635b4a36d5bf9.setContent(html_203b6f5449fe5a75c4a722bf31343aa7);
#
#
#
#         marker_0e654fe0f524c8f099fe4a6554716b6a.bindPopup(popup_7ea88433afb94549a9b635b4a36d5bf9)
#         ;
#
#
#
#
#             var marker_38f0b2b193385e0b6c65dc8d8b6a342e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e1a7a1ce4d4b346b0081be83acc201ef);
#
#
#         var popup_cfce4e7d3743392cc105c3a81af3d378 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_566deafee4a943edcd48c05b2258abb7 = $(`&lt;div id=&quot;html_566deafee4a943edcd48c05b2258abb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cfce4e7d3743392cc105c3a81af3d378.setContent(html_566deafee4a943edcd48c05b2258abb7);
#
#
#
#         marker_38f0b2b193385e0b6c65dc8d8b6a342e.bindPopup(popup_cfce4e7d3743392cc105c3a81af3d378)
#         ;
#
#
#
#
#             var marker_01f6566dd328640a1c5402294c869241 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e1a7a1ce4d4b346b0081be83acc201ef);
#
#
#         var popup_16764eff1f627e1fcd7cc253689ba6ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b18b51c30720aac567b6963fe1d62d5a = $(`&lt;div id=&quot;html_b18b51c30720aac567b6963fe1d62d5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_16764eff1f627e1fcd7cc253689ba6ba.setContent(html_b18b51c30720aac567b6963fe1d62d5a);
#
#
#
#         marker_01f6566dd328640a1c5402294c869241.bindPopup(popup_16764eff1f627e1fcd7cc253689ba6ba)
#         ;
#
#
#
#
#             var marker_0ec12f8fd740be83cd2b6954cbe4b29d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e1a7a1ce4d4b346b0081be83acc201ef);
#
#
#         var popup_5d58e7cf5f4db919d48dfd190d3dc95f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f307e2fad1c8bcdc79b17389a81e227 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f307e2fad1c8bcdc79b17389a81e227&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f307e2fad1c8bcdc79b17389a81e227 = L.map(
#                 &quot;map_3f307e2fad1c8bcdc79b17389a81e227&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ad1bc62383e2af2042e310b9d3d1ce5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ad1bc62383e2af2042e310b9d3d1ce5.addTo(map_3f307e2fad1c8bcdc79b17389a81e227);
#
#
#             var feature_group_c7e33ce34d902a9cabda20210c079acb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c7e33ce34d902a9cabda20210c079acb.addTo(map_3f307e2fad1c8bcdc79b17389a81e227);
#
#
#             var feature_group_sub_group_07e9304fe08cc512c0e9e25998cdb56c = L.featureGroup.subGroup(
#                 feature_group_c7e33ce34d902a9cabda20210c079acb
#             );
#
#
#             var marker_fb8ae74e58e22b58c0ec039b06ef3d64 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_07e9304fe08cc512c0e9e25998cdb56c);
#
#
#         var popup_3c62f2924e144bf977796998a6674dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a16547f4e2340348f01a68fba3e9ecb = $(`&lt;div id=&quot;html_7a16547f4e2340348f01a68fba3e9ecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3c62f2924e144bf977796998a6674dcb.setContent(html_7a16547f4e2340348f01a68fba3e9ecb);
#
#
#
#         marker_fb8ae74e58e22b58c0ec039b06ef3d64.bindPopup(popup_3c62f2924e144bf977796998a6674dcb)
#         ;
#
#
#
#
#             var marker_908dd0fc557bcdb259a54d7b66481448 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_07e9304fe08cc512c0e9e25998cdb56c);
#
#
#         var popup_5ff4f0e3f450c2771fca476c8b1ca0fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9321eabda81654b2dd535948c27caee8 = $(`&lt;div id=&quot;html_9321eabda81654b2dd535948c27caee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5ff4f0e3f450c2771fca476c8b1ca0fa.setContent(html_9321eabda81654b2dd535948c27caee8);
#
#
#
#         marker_908dd0fc557bcdb259a54d7b66481448.bindPopup(popup_5ff4f0e3f450c2771fca476c8b1ca0fa)
#         ;
#
#
#
#
#             var marker_379e9748c18dc6d8dfaa9d8965e9bc3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_07e9304fe08cc512c0e9e25998cdb56c);
#
#
#         var popup_637fe0a30394de3bd9713b865e67b625 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f78a280e55c60d4582b4cd2dd8607e8c = $(`&lt;div id=&quot;html_f78a280e55c60d4582b4cd2dd8607e8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_637fe0a30394de3bd9713b865e67b625.setContent(html_f78a280e55c60d4582b4cd2dd8607e8c);
#
#
#
#         marker_379e9748c18dc6d8dfaa9d8965e9bc3e.bindPopup(popup_637fe0a30394de3bd9713b865e67b625)
#         ;
#
#
#
#
#             var marker_7e6cc388066ea38bf963c89e01aaedc5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_07e9304fe08cc512c0e9e25998cdb56c);
#
#
#         var popup_8648973713cbee08eb3fc0179f97514b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8709e148fef58618692042916439c40 = $(`&lt;div id=&quot;html_d8709e148fef58618692042916439c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8648973713cbee08eb3fc0179f97514b.setContent(html_d8709e148fef58618692042916439c40);
#
#
#
#         marker_
