# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_234143f9586ca959d568a4296bd4345f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_234143f9586ca959d568a4296bd4345f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_234143f9586ca959d568a4296bd4345f = L.map(
#                 &quot;map_234143f9586ca959d568a4296bd4345f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_194b7563c7da8d3516f434a7ce0c00bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_194b7563c7da8d3516f434a7ce0c00bb.addTo(map_234143f9586ca959d568a4296bd4345f);
#
#
#             var marker_dd5f3a67022be0f4187e6e4c3cbf26c2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_234143f9586ca959d568a4296bd4345f);
#
#
#         var popup_3feba0103c7ed6d1b191e2d05822538e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a56beefcde3eda9f3a6f30fc6b2202f = $(`&lt;div id=&quot;html_4a56beefcde3eda9f3a6f30fc6b2202f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3feba0103c7ed6d1b191e2d05822538e.setContent(html_4a56beefcde3eda9f3a6f30fc6b2202f);
#
#
#
#         marker_dd5f3a67022be0f4187e6e4c3cbf26c2.bindPopup(popup_3feba0103c7ed6d1b191e2d05822538e)
#         ;
#
#
#
#
#             var marker_abbd1f8fe78e808cdf3c4480f204b995 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_234143f9586ca959d568a4296bd4345f);
#
#
#         var popup_09a7cbb3834efa9990bfedca5b55d725 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76d54b9d6c43d7e130622ce823bd336c = $(`&lt;div id=&quot;html_76d54b9d6c43d7e130622ce823bd336c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_09a7cbb3834efa9990bfedca5b55d725.setContent(html_76d54b9d6c43d7e130622ce823bd336c);
#
#
#
#         marker_abbd1f8fe78e808cdf3c4480f204b995.bindPopup(popup_09a7cbb3834efa9990bfedca5b55d725)
#         ;
#
#
#
#
#             var marker_8c834b75205e1c7ec5b35eb91ab0b6cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_234143f9586ca959d568a4296bd4345f);
#
#
#         var popup_aed0dca94aac7c97e796f41e024d8dbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34eef22aec8f3ab4cfe62ae97d3e6718 = $(`&lt;div id=&quot;html_34eef22aec8f3ab4cfe62ae97d3e6718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_aed0dca94aac7c97e796f41e024d8dbe.setContent(html_34eef22aec8f3ab4cfe62ae97d3e6718);
#
#
#
#         marker_8c834b75205e1c7ec5b35eb91ab0b6cd.bindPopup(popup_aed0dca94aac7c97e796f41e024d8dbe)
#         ;
#
#
#
#
#             var marker_5c79859c143c00bac8435fc1b719818d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_234143f9586ca959d568a4296bd4345f);
#
#
#         var popup_bd3c024b193ac21077b6d9db865bf350 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cb10d4ec858147b7f02457c7bb076bb = $(`&lt;div id=&quot;html_8cb10d4ec858147b7f02457c7bb076bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bd3c024b193ac21077b6d9db865bf350.setContent(html_8cb10d4ec858147b7f02457c7bb076bb);
#
#
#
#         marker_5c79859c143c00bac8435fc1b719818d.bindPopup(popup_bd3c024b193ac21077b6d9db865bf350)
#         ;
#
#
#
#
#             var marker_69abbbb84f6fbd67889e5e4932fee045 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_234143f9586ca959d568a4296bd4345f);
#
#
#         var popup_5eedabd4703a2da5d6ce91a597f9c3d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_183a58691807e448db054602f7cc93da = $(`&lt;div id=&quot;html_183a58691807e448db054602f7cc93da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5eedabd4703a2da5d6ce91a597f9c3d5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05fbb63226c86ba286c5ad9fc1988886 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05fbb63226c86ba286c5ad9fc1988886&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05fbb63226c86ba286c5ad9fc1988886 = L.map(
#                 &quot;map_05fbb63226c86ba286c5ad9fc1988886&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77435b04c1fcfd76a8a51319f83c8070 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77435b04c1fcfd76a8a51319f83c8070.addTo(map_05fbb63226c86ba286c5ad9fc1988886);
#
#
#             var feature_group_61a12e07d9e4239bc8c7c6da4d42098f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3a0b7b2dfbab59998f5a7860102c618e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_61a12e07d9e4239bc8c7c6da4d42098f);
#
#
#         var popup_9302c4a92786ae75d3e9deaab035e81e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebb0c8cac15aa6fcd2eddb3ac259b2a7 = $(`&lt;div id=&quot;html_ebb0c8cac15aa6fcd2eddb3ac259b2a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9302c4a92786ae75d3e9deaab035e81e.setContent(html_ebb0c8cac15aa6fcd2eddb3ac259b2a7);
#
#
#
#         marker_3a0b7b2dfbab59998f5a7860102c618e.bindPopup(popup_9302c4a92786ae75d3e9deaab035e81e)
#         ;
#
#
#
#
#             var marker_d9daf910bad920fc1b4295563d3fd331 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_61a12e07d9e4239bc8c7c6da4d42098f);
#
#
#         var popup_51f4549c7300753f441d78c78d1b69e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7467dc61eca0ff19490e3479424cb43 = $(`&lt;div id=&quot;html_f7467dc61eca0ff19490e3479424cb43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_51f4549c7300753f441d78c78d1b69e0.setContent(html_f7467dc61eca0ff19490e3479424cb43);
#
#
#
#         marker_d9daf910bad920fc1b4295563d3fd331.bindPopup(popup_51f4549c7300753f441d78c78d1b69e0)
#         ;
#
#
#
#
#             var marker_7540cf6112189539e38ef63d1abdc116 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_61a12e07d9e4239bc8c7c6da4d42098f);
#
#
#         var popup_e9d8d02a99a97c90ba13bebd3157a36d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08de39e32430e9b89cfd29d0f5248aa4 = $(`&lt;div id=&quot;html_08de39e32430e9b89cfd29d0f5248aa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e9d8d02a99a97c90ba13bebd3157a36d.setContent(html_08de39e32430e9b89cfd29d0f5248aa4);
#
#
#
#         marker_7540cf6112189539e38ef63d1abdc116.bindPopup(popup_e9d8d02a99a97c90ba13bebd3157a36d)
#         ;
#
#
#
#
#             var marker_454147fe4b4eaaac078d256e61155b02 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_61a12e07d9e4239bc8c7c6da4d42098f);
#
#
#         var popup_aa4a124711c9a3847efefff86059120d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e2a859b3aa45d23f948f3d9e7688de8 = $(`&lt;div id=&quot;html_8e2a859b3aa45d23f948f3d9e7688de8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aa4a124711c9a3847efefff86059120d.setContent(html_8e2a859b3aa45d23f948f3d9e7688de8);
#
#
#
#         marker_454147fe4b4eaaac078d256e61155b02.bindPopup(popup_aa4a124711c9a3847efefff86059120d)
#         ;
#
#
#
#
#             var marker_aeef784844dfd71da606d5c3aeb8bdf8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_61a12e07d9e4239bc8c7c6da4d42098f);
#
#
#         var popup_4aa618e065133a495e0dedd4cc244a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ce1b2d33f999f33d0bde5fb7cd9f2d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ce1b2d33f999f33d0bde5fb7cd9f2d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ce1b2d33f999f33d0bde5fb7cd9f2d7 = L.map(
#                 &quot;map_4ce1b2d33f999f33d0bde5fb7cd9f2d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f640a37fa6866f26e8b70aba61a055ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f640a37fa6866f26e8b70aba61a055ba.addTo(map_4ce1b2d33f999f33d0bde5fb7cd9f2d7);
#
#
#             var feature_group_d34dd8dcb5d8d20fc899f506abaee67a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d34dd8dcb5d8d20fc899f506abaee67a.addTo(map_4ce1b2d33f999f33d0bde5fb7cd9f2d7);
#
#
#             var feature_group_sub_group_747a72242ca6476165e8f3f9bdc560e0 = L.featureGroup.subGroup(
#                 feature_group_d34dd8dcb5d8d20fc899f506abaee67a
#             );
#
#
#             var marker_92f0028435f21e8e427e8a0518f8f33d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_747a72242ca6476165e8f3f9bdc560e0);
#
#
#         var popup_c272438f708339a9d6e728e7f4e312fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_816e82b6230d9f7ec32255baad02c353 = $(`&lt;div id=&quot;html_816e82b6230d9f7ec32255baad02c353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c272438f708339a9d6e728e7f4e312fa.setContent(html_816e82b6230d9f7ec32255baad02c353);
#
#
#
#         marker_92f0028435f21e8e427e8a0518f8f33d.bindPopup(popup_c272438f708339a9d6e728e7f4e312fa)
#         ;
#
#
#
#
#             var marker_492402088f19c5b42eb428a61ecd60f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_747a72242ca6476165e8f3f9bdc560e0);
#
#
#         var popup_240241a70de1c46255d665dccc6f0a39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bcb793bf19c6a61ed573ba9a37e8848 = $(`&lt;div id=&quot;html_6bcb793bf19c6a61ed573ba9a37e8848&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_240241a70de1c46255d665dccc6f0a39.setContent(html_6bcb793bf19c6a61ed573ba9a37e8848);
#
#
#
#         marker_492402088f19c5b42eb428a61ecd60f4.bindPopup(popup_240241a70de1c46255d665dccc6f0a39)
#         ;
#
#
#
#
#             var marker_876110ad5e2013f11d10d779c40d22b0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_747a72242ca6476165e8f3f9bdc560e0);
#
#
#         var popup_ba9b50d12c413bd80630ca3c3d7f6ed1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09e944deb97c214a5596c130a4f07bee = $(`&lt;div id=&quot;html_09e944deb97c214a5596c130a4f07bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ba9b50d12c413bd80630ca3c3d7f6ed1.setContent(html_09e944deb97c214a5596c130a4f07bee);
#
#
#
#         marker_876110ad5e2013f11d10d779c40d22b0.bindPopup(popup_ba9b50d12c413bd80630ca3c3d7f6ed1)
#         ;
#
#
#
#
#             var marker_1f6ad137b43decf65c412e93360f9f97 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_747a72242ca6476165e8f3f9bdc560e0);
#
#
#         var popup_c218c74685cc494d065461ba06f9093b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0e10fd23317fb228c98168e1ac306ff = $(`&lt;div id=&quot;html_f0e10fd23317fb228c98168e1ac306ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c218c74685cc494d065461ba06f9093b.setContent(html_f0e10fd23317fb228c98168e1ac306ff);
#
#
#
#         marker_
