# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18be54ee5d858677651608c8b81198be {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18be54ee5d858677651608c8b81198be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18be54ee5d858677651608c8b81198be = L.map(
#                 &quot;map_18be54ee5d858677651608c8b81198be&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c956cee7a24f87f8b4e9c1e1568271ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c956cee7a24f87f8b4e9c1e1568271ba.addTo(map_18be54ee5d858677651608c8b81198be);
#
#
#             var marker_025aa1d492644bae7e1011d0b648cca9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_18be54ee5d858677651608c8b81198be);
#
#
#         var popup_9085ce333aa8aeb6213b3665ea7dc813 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c2205247b199b0e956b78ca6d9fc93f = $(`&lt;div id=&quot;html_7c2205247b199b0e956b78ca6d9fc93f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9085ce333aa8aeb6213b3665ea7dc813.setContent(html_7c2205247b199b0e956b78ca6d9fc93f);
#
#
#
#         marker_025aa1d492644bae7e1011d0b648cca9.bindPopup(popup_9085ce333aa8aeb6213b3665ea7dc813)
#         ;
#
#
#
#
#             var marker_d3344f6cc29b9dcb04d6b97f7e61fa84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_18be54ee5d858677651608c8b81198be);
#
#
#         var popup_90c4fb3a296705b4df7b45708765fcce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_389d05d8a880febd0c343be0a5d78229 = $(`&lt;div id=&quot;html_389d05d8a880febd0c343be0a5d78229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_90c4fb3a296705b4df7b45708765fcce.setContent(html_389d05d8a880febd0c343be0a5d78229);
#
#
#
#         marker_d3344f6cc29b9dcb04d6b97f7e61fa84.bindPopup(popup_90c4fb3a296705b4df7b45708765fcce)
#         ;
#
#
#
#
#             var marker_8b128eab490af12bd2c3282b7c628a8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_18be54ee5d858677651608c8b81198be);
#
#
#         var popup_1bc79f240a0023b9a0dda3f060348a96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_044030bbbd12743d618cfb7fc4a4c309 = $(`&lt;div id=&quot;html_044030bbbd12743d618cfb7fc4a4c309&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1bc79f240a0023b9a0dda3f060348a96.setContent(html_044030bbbd12743d618cfb7fc4a4c309);
#
#
#
#         marker_8b128eab490af12bd2c3282b7c628a8a.bindPopup(popup_1bc79f240a0023b9a0dda3f060348a96)
#         ;
#
#
#
#
#             var marker_bb25bd3e3490f959e922ada50ef8287e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_18be54ee5d858677651608c8b81198be);
#
#
#         var popup_5be1e18b391917481a64078dd3c7556a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bb81c6a57e92aecef0268dad85a3a8e = $(`&lt;div id=&quot;html_7bb81c6a57e92aecef0268dad85a3a8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5be1e18b391917481a64078dd3c7556a.setContent(html_7bb81c6a57e92aecef0268dad85a3a8e);
#
#
#
#         marker_bb25bd3e3490f959e922ada50ef8287e.bindPopup(popup_5be1e18b391917481a64078dd3c7556a)
#         ;
#
#
#
#
#             var marker_1e3b449bbfea1a2dc582e84e5a09bda3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_18be54ee5d858677651608c8b81198be);
#
#
#         var popup_8661c187ee7311bf86f56835e05a8904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bd2cd26dc4f52fc2f96fdb19e6d5887 = $(`&lt;div id=&quot;html_0bd2cd26dc4f52fc2f96fdb19e6d5887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8661c187ee7311bf86f56835e05a89

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efb207880ff06ade28e8d10a0c08d500 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efb207880ff06ade28e8d10a0c08d500&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efb207880ff06ade28e8d10a0c08d500 = L.map(
#                 &quot;map_efb207880ff06ade28e8d10a0c08d500&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f8e358e951f806b880887c5b27a35fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f8e358e951f806b880887c5b27a35fc.addTo(map_efb207880ff06ade28e8d10a0c08d500);
#
#
#             var feature_group_b46cece5ef2a5246d56961485b16e016 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5d14c3f8c678f4bdc2c6b46ae9ff40a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b46cece5ef2a5246d56961485b16e016);
#
#
#         var popup_9b91871f138ffa113f249e1da767ad2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ea7b1cfe8b0058a67a756de9a58ba61 = $(`&lt;div id=&quot;html_6ea7b1cfe8b0058a67a756de9a58ba61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9b91871f138ffa113f249e1da767ad2b.setContent(html_6ea7b1cfe8b0058a67a756de9a58ba61);
#
#
#
#         marker_d5d14c3f8c678f4bdc2c6b46ae9ff40a.bindPopup(popup_9b91871f138ffa113f249e1da767ad2b)
#         ;
#
#
#
#
#             var marker_4af6296dc652d04cd6d2fa86126c797b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b46cece5ef2a5246d56961485b16e016);
#
#
#         var popup_4dd2266d81b67f4b2d43a66aed371c0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca046ee3e7928a21da89cc2c36f08e4c = $(`&lt;div id=&quot;html_ca046ee3e7928a21da89cc2c36f08e4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4dd2266d81b67f4b2d43a66aed371c0d.setContent(html_ca046ee3e7928a21da89cc2c36f08e4c);
#
#
#
#         marker_4af6296dc652d04cd6d2fa86126c797b.bindPopup(popup_4dd2266d81b67f4b2d43a66aed371c0d)
#         ;
#
#
#
#
#             var marker_019bbdb30e384d058832c51fade03b0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b46cece5ef2a5246d56961485b16e016);
#
#
#         var popup_e44acb8e5134121223624fbe3bc845eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4941739d97cc9bd56dbb43557dd4433c = $(`&lt;div id=&quot;html_4941739d97cc9bd56dbb43557dd4433c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e44acb8e5134121223624fbe3bc845eb.setContent(html_4941739d97cc9bd56dbb43557dd4433c);
#
#
#
#         marker_019bbdb30e384d058832c51fade03b0a.bindPopup(popup_e44acb8e5134121223624fbe3bc845eb)
#         ;
#
#
#
#
#             var marker_a3681f86d35a134630a006eee1c40a8f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b46cece5ef2a5246d56961485b16e016);
#
#
#         var popup_cedcd9d94eb2a28ead903d3752533b30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03f8cac42b69eba706a3305f52e083ba = $(`&lt;div id=&quot;html_03f8cac42b69eba706a3305f52e083ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cedcd9d94eb2a28ead903d3752533b30.setContent(html_03f8cac42b69eba706a3305f52e083ba);
#
#
#
#         marker_a3681f86d35a134630a006eee1c40a8f.bindPopup(popup_cedcd9d94eb2a28ead903d3752533b30)
#         ;
#
#
#
#
#             var marker_f19311846e52c87d759b8f02cd84fc56 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b46cece5ef2a5246d56961485b16e016);
#
#
#         var popup_650eedbdf998f4c416bb92b6c84519a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4270315d29cc7644bec66fcb9404fd2a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4270315d29cc7644bec66fcb9404fd2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4270315d29cc7644bec66fcb9404fd2a = L.map(
#                 &quot;map_4270315d29cc7644bec66fcb9404fd2a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_057723eac6637405f52a3f8b6698eb31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_057723eac6637405f52a3f8b6698eb31.addTo(map_4270315d29cc7644bec66fcb9404fd2a);
#
#
#             var feature_group_fcfeb4a313dc95cef36b05b18773a922 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fcfeb4a313dc95cef36b05b18773a922.addTo(map_4270315d29cc7644bec66fcb9404fd2a);
#
#
#             var feature_group_sub_group_b31dbefaf273f140790684a74527c668 = L.featureGroup.subGroup(
#                 feature_group_fcfeb4a313dc95cef36b05b18773a922
#             );
#
#
#             var marker_a4a445532c0eaedd9ea4c8695b481dc3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31dbefaf273f140790684a74527c668);
#
#
#         var popup_4fca727c2132999a88767aafc5d95e20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8b88d83970651776f128d5ed4f93987 = $(`&lt;div id=&quot;html_d8b88d83970651776f128d5ed4f93987&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4fca727c2132999a88767aafc5d95e20.setContent(html_d8b88d83970651776f128d5ed4f93987);
#
#
#
#         marker_a4a445532c0eaedd9ea4c8695b481dc3.bindPopup(popup_4fca727c2132999a88767aafc5d95e20)
#         ;
#
#
#
#
#             var marker_29a0df7696c82a084bebb7e4bd6f3c95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31dbefaf273f140790684a74527c668);
#
#
#         var popup_3fef6e7369ec7a66f80a30373c4b362e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32337aa9c271d55378f278e5a8365e55 = $(`&lt;div id=&quot;html_32337aa9c271d55378f278e5a8365e55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3fef6e7369ec7a66f80a30373c4b362e.setContent(html_32337aa9c271d55378f278e5a8365e55);
#
#
#
#         marker_29a0df7696c82a084bebb7e4bd6f3c95.bindPopup(popup_3fef6e7369ec7a66f80a30373c4b362e)
#         ;
#
#
#
#
#             var marker_c660fde14c57eb8dfdd9365c9ae9b111 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31dbefaf273f140790684a74527c668);
#
#
#         var popup_12138513a950bfe48fdf64098cf307c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_002aac24699dc1d81495c6d391ed7166 = $(`&lt;div id=&quot;html_002aac24699dc1d81495c6d391ed7166&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_12138513a950bfe48fdf64098cf307c7.setContent(html_002aac24699dc1d81495c6d391ed7166);
#
#
#
#         marker_c660fde14c57eb8dfdd9365c9ae9b111.bindPopup(popup_12138513a950bfe48fdf64098cf307c7)
#         ;
#
#
#
#
#             var marker_e1d3991c7c97903f6aadb3d43470559f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31dbefaf273f140790684a74527c668);
#
#
#         var popup_a93c0ed02e98c70281e27126d28aa199 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0856b996012a7fa8e811168f9694512f = $(`&lt;div id=&quot;html_0856b996012a7fa8e811168f9694512f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a93c0ed02e98c70281e27126d28aa199.setContent(html_0856b996012a7fa8e811168f9694512f);
#
#
#
#         mark
