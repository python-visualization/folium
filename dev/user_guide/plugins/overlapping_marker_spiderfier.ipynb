# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d6863afb394f4daa7d2d37d69817ba1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d6863afb394f4daa7d2d37d69817ba1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d6863afb394f4daa7d2d37d69817ba1 = L.map(
#                 &quot;map_3d6863afb394f4daa7d2d37d69817ba1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9891ce1a13d7f464fd79b23fb86dd779 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9891ce1a13d7f464fd79b23fb86dd779.addTo(map_3d6863afb394f4daa7d2d37d69817ba1);
#
#
#             var marker_4ece58348e3a096edd7b4788b63c600b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d6863afb394f4daa7d2d37d69817ba1);
#
#
#         var popup_d16c5aa1108ddb788c7bc32c056d4dca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9d36b97a36b02c56062b6b77a03faf0 = $(`&lt;div id=&quot;html_b9d36b97a36b02c56062b6b77a03faf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d16c5aa1108ddb788c7bc32c056d4dca.setContent(html_b9d36b97a36b02c56062b6b77a03faf0);
#
#
#
#         marker_4ece58348e3a096edd7b4788b63c600b.bindPopup(popup_d16c5aa1108ddb788c7bc32c056d4dca)
#         ;
#
#
#
#
#             var marker_2183c8108f4b76f8dcb97bc9697936b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d6863afb394f4daa7d2d37d69817ba1);
#
#
#         var popup_a511dbcc634a00c83d900292d2162737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b38ea15c164bd71207d5ced2ad9a070 = $(`&lt;div id=&quot;html_0b38ea15c164bd71207d5ced2ad9a070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a511dbcc634a00c83d900292d2162737.setContent(html_0b38ea15c164bd71207d5ced2ad9a070);
#
#
#
#         marker_2183c8108f4b76f8dcb97bc9697936b4.bindPopup(popup_a511dbcc634a00c83d900292d2162737)
#         ;
#
#
#
#
#             var marker_f2c4ab65bfed3aec37d29727f9671277 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d6863afb394f4daa7d2d37d69817ba1);
#
#
#         var popup_4e0c3ef2ea4838d4a394d0351eab0e58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f556b1603b2ea4700061baab6caf261e = $(`&lt;div id=&quot;html_f556b1603b2ea4700061baab6caf261e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4e0c3ef2ea4838d4a394d0351eab0e58.setContent(html_f556b1603b2ea4700061baab6caf261e);
#
#
#
#         marker_f2c4ab65bfed3aec37d29727f9671277.bindPopup(popup_4e0c3ef2ea4838d4a394d0351eab0e58)
#         ;
#
#
#
#
#             var marker_1f5dea0aa3f834cf118a94e3ea4b2796 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d6863afb394f4daa7d2d37d69817ba1);
#
#
#         var popup_617c44c814a8da12a529530d1541f29e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_841a1b3d273d4b29babc813318f71882 = $(`&lt;div id=&quot;html_841a1b3d273d4b29babc813318f71882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_617c44c814a8da12a529530d1541f29e.setContent(html_841a1b3d273d4b29babc813318f71882);
#
#
#
#         marker_1f5dea0aa3f834cf118a94e3ea4b2796.bindPopup(popup_617c44c814a8da12a529530d1541f29e)
#         ;
#
#
#
#
#             var marker_677642c9c3e25b1c82f6f2f05b3e0335 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d6863afb394f4daa7d2d37d69817ba1);
#
#
#         var popup_e91bd843fe744b826c7ba7918382fc3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d374e9dfa19c96af6fef92768e0ffdf = $(`&lt;div id=&quot;html_4d374e9dfa19c96af6fef92768e0ffdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e91bd843fe744b826c7ba7918382fc3c.setContent(html_4d374e9dfa19c96af6fef92768e0ffdf);
#
#
#
#         marker_677642c9c3e25b1c82f6f2f05b3e0335.bindPopup(popup_e91bd843fe744b826c7ba7918382fc3c)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4255b4a04ad1cff0be4f26d5e3f5c854 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4255b4a04ad1cff0be4f26d5e3f5c854&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4255b4a04ad1cff0be4f26d5e3f5c854 = L.map(
#                 &quot;map_4255b4a04ad1cff0be4f26d5e3f5c854&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b749651588bed3bac55174efe2602c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b749651588bed3bac55174efe2602c7.addTo(map_4255b4a04ad1cff0be4f26d5e3f5c854);
#
#
#             var feature_group_967ea1b83fb4369d51dea92c06baf525 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_098fa5774536eccf2b14e1e0e6bc5249 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_967ea1b83fb4369d51dea92c06baf525);
#
#
#         var popup_c106ba748327554a091b05b1cb655a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_249c18c7a3c822e15e0e5e9cd67defbf = $(`&lt;div id=&quot;html_249c18c7a3c822e15e0e5e9cd67defbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c106ba748327554a091b05b1cb655a4f.setContent(html_249c18c7a3c822e15e0e5e9cd67defbf);
#
#
#
#         marker_098fa5774536eccf2b14e1e0e6bc5249.bindPopup(popup_c106ba748327554a091b05b1cb655a4f)
#         ;
#
#
#
#
#             var marker_42bd51d98f8107beb4591962541d9384 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_967ea1b83fb4369d51dea92c06baf525);
#
#
#         var popup_841f21fbadb2b43b492a54d9f9d97f6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29aee79d9008fa0f3e6c80be5127ef40 = $(`&lt;div id=&quot;html_29aee79d9008fa0f3e6c80be5127ef40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_841f21fbadb2b43b492a54d9f9d97f6c.setContent(html_29aee79d9008fa0f3e6c80be5127ef40);
#
#
#
#         marker_42bd51d98f8107beb4591962541d9384.bindPopup(popup_841f21fbadb2b43b492a54d9f9d97f6c)
#         ;
#
#
#
#
#             var marker_56a23da03bf1539e98122b5ebb60d1e2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_967ea1b83fb4369d51dea92c06baf525);
#
#
#         var popup_232f47058d04317bda5999a4e6519ed4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_126d7d43e029df0d78cd87da1b3b0560 = $(`&lt;div id=&quot;html_126d7d43e029df0d78cd87da1b3b0560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_232f47058d04317bda5999a4e6519ed4.setContent(html_126d7d43e029df0d78cd87da1b3b0560);
#
#
#
#         marker_56a23da03bf1539e98122b5ebb60d1e2.bindPopup(popup_232f47058d04317bda5999a4e6519ed4)
#         ;
#
#
#
#
#             var marker_38500f4874c4d3807d3731f220b26eda = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_967ea1b83fb4369d51dea92c06baf525);
#
#
#         var popup_09b24618c1aa84da949f9bb3646f2d71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_194e193d6ebc95fbf10a66834bc4cb7c = $(`&lt;div id=&quot;html_194e193d6ebc95fbf10a66834bc4cb7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_09b24618c1aa84da949f9bb3646f2d71.setContent(html_194e193d6ebc95fbf10a66834bc4cb7c);
#
#
#
#         marker_38500f4874c4d3807d3731f220b26eda.bindPopup(popup_09b24618c1aa84da949f9bb3646f2d71)
#         ;
#
#
#
#
#             var marker_defcf2bb950135d1c1e69339db97a6e4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_967ea1b83fb4369d51dea92c06baf525);
#
#
#         var popup_1278369041737bc2dbae70c461917d0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_691d18af24f75a00273958d856a53127 = $(`&lt;div id=&quot;html_691d18af24f75a00273958d856a53127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2fbd7285c0cb3d3b955f847486b6778 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2fbd7285c0cb3d3b955f847486b6778&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2fbd7285c0cb3d3b955f847486b6778 = L.map(
#                 &quot;map_b2fbd7285c0cb3d3b955f847486b6778&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0379ec0b56ac9d69b23c586223f94e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0379ec0b56ac9d69b23c586223f94e2.addTo(map_b2fbd7285c0cb3d3b955f847486b6778);
#
#
#             var feature_group_c1cbcaa0996829ca258a2dbedbeb0c99 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c1cbcaa0996829ca258a2dbedbeb0c99.addTo(map_b2fbd7285c0cb3d3b955f847486b6778);
#
#
#             var feature_group_sub_group_e485b9d159edb73d40edbe2cd0a51bef = L.featureGroup.subGroup(
#                 feature_group_c1cbcaa0996829ca258a2dbedbeb0c99
#             );
#
#
#             var marker_50226d2ab0051998b6f61b97ac5842a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e485b9d159edb73d40edbe2cd0a51bef);
#
#
#         var popup_1674d1111d5e5e29b17af9c62dcea51b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54eb0f38087022cd425a0392f4275c96 = $(`&lt;div id=&quot;html_54eb0f38087022cd425a0392f4275c96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1674d1111d5e5e29b17af9c62dcea51b.setContent(html_54eb0f38087022cd425a0392f4275c96);
#
#
#
#         marker_50226d2ab0051998b6f61b97ac5842a3.bindPopup(popup_1674d1111d5e5e29b17af9c62dcea51b)
#         ;
#
#
#
#
#             var marker_41f885c4a58ca2e595903932e108c872 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e485b9d159edb73d40edbe2cd0a51bef);
#
#
#         var popup_484fce4ebad5d48d33e70360d2d3106c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1ef8c731ff90236559269e2e2e9a8b6 = $(`&lt;div id=&quot;html_a1ef8c731ff90236559269e2e2e9a8b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_484fce4ebad5d48d33e70360d2d3106c.setContent(html_a1ef8c731ff90236559269e2e2e9a8b6);
#
#
#
#         marker_41f885c4a58ca2e595903932e108c872.bindPopup(popup_484fce4ebad5d48d33e70360d2d3106c)
#         ;
#
#
#
#
#             var marker_d7d2018fc7c3c64d046e66a0dd69cb92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e485b9d159edb73d40edbe2cd0a51bef);
#
#
#         var popup_2fb71da215c06468c2acda7e2007fd0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_181637847c8da8fa2b1c7d5c3f853813 = $(`&lt;div id=&quot;html_181637847c8da8fa2b1c7d5c3f853813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2fb71da215c06468c2acda7e2007fd0c.setContent(html_181637847c8da8fa2b1c7d5c3f853813);
#
#
#
#         marker_d7d2018fc7c3c64d046e66a0dd69cb92.bindPopup(popup_2fb71da215c06468c2acda7e2007fd0c)
#         ;
#
#
#
#
#             var marker_0ddeb1b4ab31dd018f35df8a62973194 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e485b9d159edb73d40edbe2cd0a51bef);
#
#
#         var popup_7454c71bd81d3cd574ea6f2fec9623a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d011027055f9bbfa97a30e915112a44 = $(`&lt;div id=&quot;html_3d011027055f9bbfa97a30e915112a44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7454c71bd81d3cd574ea6f2fec9623a0.setContent(html_3d011027055f9bbfa97a30e915112a44);
#
#
#
#         marker_0ddeb1b4ab31dd018f35df8a62973194.bindPopup(popup_7454c71bd81d3cd574ea6f2fec9623a0)
#         ;
#
#
#
#
#             var marker_6b86c96807cd6d59ff813146b2453b28 = L.marker(
#                 [45.0503999
