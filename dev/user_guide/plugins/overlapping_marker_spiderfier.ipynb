# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbb11bb9196f2e108b02ef98a36ae8ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbb11bb9196f2e108b02ef98a36ae8ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbb11bb9196f2e108b02ef98a36ae8ab = L.map(
#                 &quot;map_bbb11bb9196f2e108b02ef98a36ae8ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f030eed9aab1e9a716e214c8d78ccb95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f030eed9aab1e9a716e214c8d78ccb95.addTo(map_bbb11bb9196f2e108b02ef98a36ae8ab);
#
#
#             var marker_03ac4d12f18f46eb470f76eb46ac69fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bbb11bb9196f2e108b02ef98a36ae8ab);
#
#
#         var popup_eb6ecf2c674a46a726a8652d2576bd64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_febd6a0fccb1e7d61a77b4fecaa9d470 = $(`&lt;div id=&quot;html_febd6a0fccb1e7d61a77b4fecaa9d470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_eb6ecf2c674a46a726a8652d2576bd64.setContent(html_febd6a0fccb1e7d61a77b4fecaa9d470);
#
#
#
#         marker_03ac4d12f18f46eb470f76eb46ac69fe.bindPopup(popup_eb6ecf2c674a46a726a8652d2576bd64)
#         ;
#
#
#
#
#             var marker_e8c1219e37d6d45dfd1ca143947fa87b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bbb11bb9196f2e108b02ef98a36ae8ab);
#
#
#         var popup_6979e423725be7e845f5a181db37d086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_764e9f08e2cea90170ffd90a044e530b = $(`&lt;div id=&quot;html_764e9f08e2cea90170ffd90a044e530b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6979e423725be7e845f5a181db37d086.setContent(html_764e9f08e2cea90170ffd90a044e530b);
#
#
#
#         marker_e8c1219e37d6d45dfd1ca143947fa87b.bindPopup(popup_6979e423725be7e845f5a181db37d086)
#         ;
#
#
#
#
#             var marker_23a2c374c5c97ba47935cfaf5e881844 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bbb11bb9196f2e108b02ef98a36ae8ab);
#
#
#         var popup_1494d2ea4ae234907d0b7cae1528248b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd708a82faafb34f598eba5490a405c3 = $(`&lt;div id=&quot;html_fd708a82faafb34f598eba5490a405c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1494d2ea4ae234907d0b7cae1528248b.setContent(html_fd708a82faafb34f598eba5490a405c3);
#
#
#
#         marker_23a2c374c5c97ba47935cfaf5e881844.bindPopup(popup_1494d2ea4ae234907d0b7cae1528248b)
#         ;
#
#
#
#
#             var marker_2b7ad040243d7d8a6ece86bcf4cf2399 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bbb11bb9196f2e108b02ef98a36ae8ab);
#
#
#         var popup_b468bd95f63b2025e09f6c7fc31f5e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad10551b4a8e0c71b4325d0f173cbecb = $(`&lt;div id=&quot;html_ad10551b4a8e0c71b4325d0f173cbecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b468bd95f63b2025e09f6c7fc31f5e0f.setContent(html_ad10551b4a8e0c71b4325d0f173cbecb);
#
#
#
#         marker_2b7ad040243d7d8a6ece86bcf4cf2399.bindPopup(popup_b468bd95f63b2025e09f6c7fc31f5e0f)
#         ;
#
#
#
#
#             var marker_3b85e5bcdb2e602f549117bf7fdc8d73 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bbb11bb9196f2e108b02ef98a36ae8ab);
#
#
#         var popup_359d3726b2684162dd1b7d26daac74b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff103554a655e3aca39137cc9e97b36f = $(`&lt;div id=&quot;html_ff103554a655e3aca39137cc9e97b36f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_359d3726b2684162dd1b7d26daac74b4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5122b741528a83579aeb29edba8bb437 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5122b741528a83579aeb29edba8bb437&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5122b741528a83579aeb29edba8bb437 = L.map(
#                 &quot;map_5122b741528a83579aeb29edba8bb437&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1234899dfcfe12e943c280ccae3a7264 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1234899dfcfe12e943c280ccae3a7264.addTo(map_5122b741528a83579aeb29edba8bb437);
#
#
#             var feature_group_e79ecdbad198a36af0e8d606ecf37c39 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_23f68e9e09b1b3ec2c105386cf53fb13 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e79ecdbad198a36af0e8d606ecf37c39);
#
#
#         var popup_73610da856dfe166799d5c003dc02d87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c50c0815519f2f93a8b96d8c4ebd2714 = $(`&lt;div id=&quot;html_c50c0815519f2f93a8b96d8c4ebd2714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_73610da856dfe166799d5c003dc02d87.setContent(html_c50c0815519f2f93a8b96d8c4ebd2714);
#
#
#
#         marker_23f68e9e09b1b3ec2c105386cf53fb13.bindPopup(popup_73610da856dfe166799d5c003dc02d87)
#         ;
#
#
#
#
#             var marker_2ca528784c95b2d4d1d622302bea95a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e79ecdbad198a36af0e8d606ecf37c39);
#
#
#         var popup_c4cea1b4fdaec9361670d73b74c70a11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd6f6d9e4001da4e2b107f8773726f42 = $(`&lt;div id=&quot;html_bd6f6d9e4001da4e2b107f8773726f42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c4cea1b4fdaec9361670d73b74c70a11.setContent(html_bd6f6d9e4001da4e2b107f8773726f42);
#
#
#
#         marker_2ca528784c95b2d4d1d622302bea95a5.bindPopup(popup_c4cea1b4fdaec9361670d73b74c70a11)
#         ;
#
#
#
#
#             var marker_2187eb1946d4eca65dcaa758bfd281c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e79ecdbad198a36af0e8d606ecf37c39);
#
#
#         var popup_906b3b01440f44c18ed60fd3eeb66870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afc1e31e7c5aa4716ffe574296d44b94 = $(`&lt;div id=&quot;html_afc1e31e7c5aa4716ffe574296d44b94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_906b3b01440f44c18ed60fd3eeb66870.setContent(html_afc1e31e7c5aa4716ffe574296d44b94);
#
#
#
#         marker_2187eb1946d4eca65dcaa758bfd281c5.bindPopup(popup_906b3b01440f44c18ed60fd3eeb66870)
#         ;
#
#
#
#
#             var marker_c5189ac28bc5c19eb20bdd7b20c201e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e79ecdbad198a36af0e8d606ecf37c39);
#
#
#         var popup_4a06dcece0bc17e7de0c8281b0d9cf1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4516d81b15e4226087995a65dd9f4b78 = $(`&lt;div id=&quot;html_4516d81b15e4226087995a65dd9f4b78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4a06dcece0bc17e7de0c8281b0d9cf1a.setContent(html_4516d81b15e4226087995a65dd9f4b78);
#
#
#
#         marker_c5189ac28bc5c19eb20bdd7b20c201e7.bindPopup(popup_4a06dcece0bc17e7de0c8281b0d9cf1a)
#         ;
#
#
#
#
#             var marker_fb3c073c687ca9fb37535a5cd45278ff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e79ecdbad198a36af0e8d606ecf37c39);
#
#
#         var popup_c5de6e2bf753ec0d99394bd043e00042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c3b013dca9f972d173e86653e45e8c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c3b013dca9f972d173e86653e45e8c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c3b013dca9f972d173e86653e45e8c8 = L.map(
#                 &quot;map_0c3b013dca9f972d173e86653e45e8c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2433bb54e71fd5d29b925d8c74bdb2dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2433bb54e71fd5d29b925d8c74bdb2dd.addTo(map_0c3b013dca9f972d173e86653e45e8c8);
#
#
#             var feature_group_d8a0230ce42031933b41292f45aa78a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d8a0230ce42031933b41292f45aa78a0.addTo(map_0c3b013dca9f972d173e86653e45e8c8);
#
#
#             var feature_group_sub_group_6eb0b19ae8e543de4d8074709686192d = L.featureGroup.subGroup(
#                 feature_group_d8a0230ce42031933b41292f45aa78a0
#             );
#
#
#             var marker_3412177ee88ace3eb2a1fb6c156f2c07 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eb0b19ae8e543de4d8074709686192d);
#
#
#         var popup_7d9c6e691dbc155d82f232e2d5e6b17c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f79c41be18cb0355083ca8cb03406ba = $(`&lt;div id=&quot;html_2f79c41be18cb0355083ca8cb03406ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7d9c6e691dbc155d82f232e2d5e6b17c.setContent(html_2f79c41be18cb0355083ca8cb03406ba);
#
#
#
#         marker_3412177ee88ace3eb2a1fb6c156f2c07.bindPopup(popup_7d9c6e691dbc155d82f232e2d5e6b17c)
#         ;
#
#
#
#
#             var marker_f89906aa123f75d88403b306ec421b55 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eb0b19ae8e543de4d8074709686192d);
#
#
#         var popup_347611b8712efb0eba89b0531a8a2265 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0f6912df5e95ff95b344966420d212f = $(`&lt;div id=&quot;html_b0f6912df5e95ff95b344966420d212f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_347611b8712efb0eba89b0531a8a2265.setContent(html_b0f6912df5e95ff95b344966420d212f);
#
#
#
#         marker_f89906aa123f75d88403b306ec421b55.bindPopup(popup_347611b8712efb0eba89b0531a8a2265)
#         ;
#
#
#
#
#             var marker_1c5fc3bbd9a1a4745c097f94798e9bbe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eb0b19ae8e543de4d8074709686192d);
#
#
#         var popup_f44941ef674d96d893410b87661c295e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31ffb26c86fbe748e3aa46fde21c4d40 = $(`&lt;div id=&quot;html_31ffb26c86fbe748e3aa46fde21c4d40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f44941ef674d96d893410b87661c295e.setContent(html_31ffb26c86fbe748e3aa46fde21c4d40);
#
#
#
#         marker_1c5fc3bbd9a1a4745c097f94798e9bbe.bindPopup(popup_f44941ef674d96d893410b87661c295e)
#         ;
#
#
#
#
#             var marker_886488f794a9dd42ee6cfba2ee945e08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eb0b19ae8e543de4d8074709686192d);
#
#
#         var popup_6fbabdda1142929ce58b32a459176674 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db61b40eba42ef6c6bc06da382a8cd11 = $(`&lt;div id=&quot;html_db61b40eba42ef6c6bc06da382a8cd11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6fbabdda1142929ce58b32a459176674.setContent(html_db61b40eba42ef6c6bc06da382a8cd11);
#
#
#
#         marker_
