# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f2e256d786dcffd571f77393665b947 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f2e256d786dcffd571f77393665b947&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f2e256d786dcffd571f77393665b947 = L.map(
#                 &quot;map_7f2e256d786dcffd571f77393665b947&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81aeae2d696a50330848baaa7db6805d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81aeae2d696a50330848baaa7db6805d.addTo(map_7f2e256d786dcffd571f77393665b947);
#
#
#             var marker_56df8b9112ae84d4c00cea34e438dfd7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7f2e256d786dcffd571f77393665b947);
#
#
#         var popup_4cc293e3b0a0106757d99c97259f91b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e16947c665c691ac78194e0e36b97001 = $(`&lt;div id=&quot;html_e16947c665c691ac78194e0e36b97001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4cc293e3b0a0106757d99c97259f91b8.setContent(html_e16947c665c691ac78194e0e36b97001);
#
#
#
#         marker_56df8b9112ae84d4c00cea34e438dfd7.bindPopup(popup_4cc293e3b0a0106757d99c97259f91b8)
#         ;
#
#
#
#
#             var marker_b01fa3228a7cae8ab5f4c4c340cdccb6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7f2e256d786dcffd571f77393665b947);
#
#
#         var popup_13db4488095e110c1dbb1df6da6ee6d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2791a06102f22e667c906a851e0c7e5 = $(`&lt;div id=&quot;html_f2791a06102f22e667c906a851e0c7e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_13db4488095e110c1dbb1df6da6ee6d8.setContent(html_f2791a06102f22e667c906a851e0c7e5);
#
#
#
#         marker_b01fa3228a7cae8ab5f4c4c340cdccb6.bindPopup(popup_13db4488095e110c1dbb1df6da6ee6d8)
#         ;
#
#
#
#
#             var marker_0d9b6ca2f6d218d78c720390ee283753 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7f2e256d786dcffd571f77393665b947);
#
#
#         var popup_33c329420fdf2bd3e25e4366087e1b3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b285ba0a16f037167f6ec2261fa678d = $(`&lt;div id=&quot;html_4b285ba0a16f037167f6ec2261fa678d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_33c329420fdf2bd3e25e4366087e1b3b.setContent(html_4b285ba0a16f037167f6ec2261fa678d);
#
#
#
#         marker_0d9b6ca2f6d218d78c720390ee283753.bindPopup(popup_33c329420fdf2bd3e25e4366087e1b3b)
#         ;
#
#
#
#
#             var marker_405c5267311fe8a34ddd284404e03c06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7f2e256d786dcffd571f77393665b947);
#
#
#         var popup_1eb29657fde6727c17a935642db0221f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b89c02731bfd7bb4113f0e673ffef35b = $(`&lt;div id=&quot;html_b89c02731bfd7bb4113f0e673ffef35b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1eb29657fde6727c17a935642db0221f.setContent(html_b89c02731bfd7bb4113f0e673ffef35b);
#
#
#
#         marker_405c5267311fe8a34ddd284404e03c06.bindPopup(popup_1eb29657fde6727c17a935642db0221f)
#         ;
#
#
#
#
#             var marker_0097a4e57cfd31607fa4b83fbbbe95d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7f2e256d786dcffd571f77393665b947);
#
#
#         var popup_e8ec2f73cd44e4f76fbaea08aaa2893b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3fc6bd9788ca706b57aeaed21814b4f = $(`&lt;div id=&quot;html_b3fc6bd9788ca706b57aeaed21814b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e8ec2f73cd44e4f76fbaea08aaa289

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac743d7fe4c02725ec9a79a9da22eaa6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac743d7fe4c02725ec9a79a9da22eaa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac743d7fe4c02725ec9a79a9da22eaa6 = L.map(
#                 &quot;map_ac743d7fe4c02725ec9a79a9da22eaa6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bab5f172d65e44c1c1cc8c0a57f2fc73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bab5f172d65e44c1c1cc8c0a57f2fc73.addTo(map_ac743d7fe4c02725ec9a79a9da22eaa6);
#
#
#             var feature_group_1cc03c2c5caed41371603bcadd5d7069 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ef97e66c0cbd96840808992efaf02f5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1cc03c2c5caed41371603bcadd5d7069);
#
#
#         var popup_9e551b7bd8231fae871ba2f61af428a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5ee6254193dba1fddd62fcd58ffa3da = $(`&lt;div id=&quot;html_e5ee6254193dba1fddd62fcd58ffa3da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9e551b7bd8231fae871ba2f61af428a9.setContent(html_e5ee6254193dba1fddd62fcd58ffa3da);
#
#
#
#         marker_ef97e66c0cbd96840808992efaf02f5c.bindPopup(popup_9e551b7bd8231fae871ba2f61af428a9)
#         ;
#
#
#
#
#             var marker_bfb1d618fb6957020028ac2b41277b57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1cc03c2c5caed41371603bcadd5d7069);
#
#
#         var popup_9d1f52d440bb16efd4eef82e159c4482 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cf531b5ce44d6609cde1f8b36d75aba = $(`&lt;div id=&quot;html_3cf531b5ce44d6609cde1f8b36d75aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9d1f52d440bb16efd4eef82e159c4482.setContent(html_3cf531b5ce44d6609cde1f8b36d75aba);
#
#
#
#         marker_bfb1d618fb6957020028ac2b41277b57.bindPopup(popup_9d1f52d440bb16efd4eef82e159c4482)
#         ;
#
#
#
#
#             var marker_73191d6f09017f5310a58ab82c0e8318 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1cc03c2c5caed41371603bcadd5d7069);
#
#
#         var popup_a559bc285ec214337a8802dce8404222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb8371cd217b48fe7d17b1fb7e807cc8 = $(`&lt;div id=&quot;html_eb8371cd217b48fe7d17b1fb7e807cc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a559bc285ec214337a8802dce8404222.setContent(html_eb8371cd217b48fe7d17b1fb7e807cc8);
#
#
#
#         marker_73191d6f09017f5310a58ab82c0e8318.bindPopup(popup_a559bc285ec214337a8802dce8404222)
#         ;
#
#
#
#
#             var marker_170d08c824d2057ad2f972359a4f808f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1cc03c2c5caed41371603bcadd5d7069);
#
#
#         var popup_434c031ebc7a46f1877404fd951565e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_816b23ef8af78cda5201e0cae9de06ab = $(`&lt;div id=&quot;html_816b23ef8af78cda5201e0cae9de06ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_434c031ebc7a46f1877404fd951565e6.setContent(html_816b23ef8af78cda5201e0cae9de06ab);
#
#
#
#         marker_170d08c824d2057ad2f972359a4f808f.bindPopup(popup_434c031ebc7a46f1877404fd951565e6)
#         ;
#
#
#
#
#             var marker_9c5d60687ee2588e0b45af19ba5baee0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1cc03c2c5caed41371603bcadd5d7069);
#
#
#         var popup_bc0d80a1d7fdbe7d115fdfb69155ecae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35e679f51da41926ce4b40bf597d71ab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35e679f51da41926ce4b40bf597d71ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35e679f51da41926ce4b40bf597d71ab = L.map(
#                 &quot;map_35e679f51da41926ce4b40bf597d71ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acfd2814b4f0f783e92c1be01a43ff44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acfd2814b4f0f783e92c1be01a43ff44.addTo(map_35e679f51da41926ce4b40bf597d71ab);
#
#
#             var feature_group_801186da6ef8ce89eace65d25e2d1165 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_801186da6ef8ce89eace65d25e2d1165.addTo(map_35e679f51da41926ce4b40bf597d71ab);
#
#
#             var feature_group_sub_group_f7961521d235b9f6075f6a2292c3ceba = L.featureGroup.subGroup(
#                 feature_group_801186da6ef8ce89eace65d25e2d1165
#             );
#
#
#             var marker_dae27589a9a1294dc9e998439d2b4cdf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f7961521d235b9f6075f6a2292c3ceba);
#
#
#         var popup_6484404a1b44defe80e2df2b28ed7d4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a99804a4bf30a9e9b8724683e55acd62 = $(`&lt;div id=&quot;html_a99804a4bf30a9e9b8724683e55acd62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6484404a1b44defe80e2df2b28ed7d4c.setContent(html_a99804a4bf30a9e9b8724683e55acd62);
#
#
#
#         marker_dae27589a9a1294dc9e998439d2b4cdf.bindPopup(popup_6484404a1b44defe80e2df2b28ed7d4c)
#         ;
#
#
#
#
#             var marker_ccbb011d0a6a8b21c4c2201d0863a052 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f7961521d235b9f6075f6a2292c3ceba);
#
#
#         var popup_793d4aebe89acf212e479581400eec44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dcf010c4cbc699038e3a73bad2bfd82 = $(`&lt;div id=&quot;html_3dcf010c4cbc699038e3a73bad2bfd82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_793d4aebe89acf212e479581400eec44.setContent(html_3dcf010c4cbc699038e3a73bad2bfd82);
#
#
#
#         marker_ccbb011d0a6a8b21c4c2201d0863a052.bindPopup(popup_793d4aebe89acf212e479581400eec44)
#         ;
#
#
#
#
#             var marker_255f58099bc0c1e9166a1f3e044fa73d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f7961521d235b9f6075f6a2292c3ceba);
#
#
#         var popup_1e23aa52bf9f26dd2485c5f138e38c76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e016a3d5fadbe670c04d073af00c10a0 = $(`&lt;div id=&quot;html_e016a3d5fadbe670c04d073af00c10a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1e23aa52bf9f26dd2485c5f138e38c76.setContent(html_e016a3d5fadbe670c04d073af00c10a0);
#
#
#
#         marker_255f58099bc0c1e9166a1f3e044fa73d.bindPopup(popup_1e23aa52bf9f26dd2485c5f138e38c76)
#         ;
#
#
#
#
#             var marker_aadaa8041ebb8e7566577d4deb9f6a5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f7961521d235b9f6075f6a2292c3ceba);
#
#
#         var popup_304c7bd3af86012d1a614a032a615f6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47ef629c5c9aae11c1c8cfda6beb4212 = $(`&lt;div id=&quot;html_47ef629c5c9aae11c1c8cfda6beb4212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_304c7bd3af86012d1a614a032a615f6a.setContent(html_47ef629c5c9aae11c1c8cfda6beb4212);
#
#
#
#         mark
