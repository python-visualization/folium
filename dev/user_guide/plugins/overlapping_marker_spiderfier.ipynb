# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b89e2b7e49256e620cbc304dd380bed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b89e2b7e49256e620cbc304dd380bed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b89e2b7e49256e620cbc304dd380bed = L.map(
#                 &quot;map_7b89e2b7e49256e620cbc304dd380bed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29884e371e60c219ff6d59ff219c5874 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29884e371e60c219ff6d59ff219c5874.addTo(map_7b89e2b7e49256e620cbc304dd380bed);
#
#
#             var marker_391ffb80c63b359ec4afb86eeb88c6f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7b89e2b7e49256e620cbc304dd380bed);
#
#
#         var popup_89b8541bfd3eca122e459bc053e0866d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaf4e461bec0ce07c7db0a3e7da6f2d5 = $(`&lt;div id=&quot;html_aaf4e461bec0ce07c7db0a3e7da6f2d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_89b8541bfd3eca122e459bc053e0866d.setContent(html_aaf4e461bec0ce07c7db0a3e7da6f2d5);
#
#
#
#         marker_391ffb80c63b359ec4afb86eeb88c6f1.bindPopup(popup_89b8541bfd3eca122e459bc053e0866d)
#         ;
#
#
#
#
#             var marker_c967c1c2065692960e35bb7c3f537387 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7b89e2b7e49256e620cbc304dd380bed);
#
#
#         var popup_1925b25ad075b05c715a573c3b551c2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dedb5643b7043310f9ebabf5413b9310 = $(`&lt;div id=&quot;html_dedb5643b7043310f9ebabf5413b9310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1925b25ad075b05c715a573c3b551c2e.setContent(html_dedb5643b7043310f9ebabf5413b9310);
#
#
#
#         marker_c967c1c2065692960e35bb7c3f537387.bindPopup(popup_1925b25ad075b05c715a573c3b551c2e)
#         ;
#
#
#
#
#             var marker_288470cd39404e74c19750be535abf32 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7b89e2b7e49256e620cbc304dd380bed);
#
#
#         var popup_bd2c7424dceaef56aa56bb318c7fdc77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7422adc23992ab60d62940d38cf69291 = $(`&lt;div id=&quot;html_7422adc23992ab60d62940d38cf69291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bd2c7424dceaef56aa56bb318c7fdc77.setContent(html_7422adc23992ab60d62940d38cf69291);
#
#
#
#         marker_288470cd39404e74c19750be535abf32.bindPopup(popup_bd2c7424dceaef56aa56bb318c7fdc77)
#         ;
#
#
#
#
#             var marker_854ec1f04d862b56e956eabf04d80e9b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7b89e2b7e49256e620cbc304dd380bed);
#
#
#         var popup_4b27e0c41f82cefb0c75c7e37d9b7d38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b011fe90b444491729a3cf397beb196b = $(`&lt;div id=&quot;html_b011fe90b444491729a3cf397beb196b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4b27e0c41f82cefb0c75c7e37d9b7d38.setContent(html_b011fe90b444491729a3cf397beb196b);
#
#
#
#         marker_854ec1f04d862b56e956eabf04d80e9b.bindPopup(popup_4b27e0c41f82cefb0c75c7e37d9b7d38)
#         ;
#
#
#
#
#             var marker_8acf033b998b8d9ea29f673338545548 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7b89e2b7e49256e620cbc304dd380bed);
#
#
#         var popup_5e2fb548bae217da29a41ab0f2fa355e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8305d93d54327d17a0556d2a8ab1eaf = $(`&lt;div id=&quot;html_c8305d93d54327d17a0556d2a8ab1eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e2fb548bae217da29a41ab0f2fa355e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4ef455123f668328feacd1a4ffe0589 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4ef455123f668328feacd1a4ffe0589&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4ef455123f668328feacd1a4ffe0589 = L.map(
#                 &quot;map_e4ef455123f668328feacd1a4ffe0589&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60b6bb60a479fb0a0ee97da1fddfe96d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60b6bb60a479fb0a0ee97da1fddfe96d.addTo(map_e4ef455123f668328feacd1a4ffe0589);
#
#
#             var feature_group_935a6e5523f12455518663b05c8a47a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c7460006ac5029a50019c8111c65999e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_935a6e5523f12455518663b05c8a47a6);
#
#
#         var popup_0b62907c81b3bcdc4b03550f5b0b5310 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_864e07c6a9bc68056f4509581ef98f4c = $(`&lt;div id=&quot;html_864e07c6a9bc68056f4509581ef98f4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0b62907c81b3bcdc4b03550f5b0b5310.setContent(html_864e07c6a9bc68056f4509581ef98f4c);
#
#
#
#         marker_c7460006ac5029a50019c8111c65999e.bindPopup(popup_0b62907c81b3bcdc4b03550f5b0b5310)
#         ;
#
#
#
#
#             var marker_23678ebf9a69b97c01801231b28fa279 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_935a6e5523f12455518663b05c8a47a6);
#
#
#         var popup_06c1b7503c308008bd3ceda4a3e3e0c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8a5835b52f3d8305814786dfb305335 = $(`&lt;div id=&quot;html_b8a5835b52f3d8305814786dfb305335&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_06c1b7503c308008bd3ceda4a3e3e0c1.setContent(html_b8a5835b52f3d8305814786dfb305335);
#
#
#
#         marker_23678ebf9a69b97c01801231b28fa279.bindPopup(popup_06c1b7503c308008bd3ceda4a3e3e0c1)
#         ;
#
#
#
#
#             var marker_dbe51c60947ec3f6b73235bc014a432b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_935a6e5523f12455518663b05c8a47a6);
#
#
#         var popup_ccf9fff85ce6e7105850b4583d59d273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6923e528cdcb45d0c75c689adb34f3a0 = $(`&lt;div id=&quot;html_6923e528cdcb45d0c75c689adb34f3a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ccf9fff85ce6e7105850b4583d59d273.setContent(html_6923e528cdcb45d0c75c689adb34f3a0);
#
#
#
#         marker_dbe51c60947ec3f6b73235bc014a432b.bindPopup(popup_ccf9fff85ce6e7105850b4583d59d273)
#         ;
#
#
#
#
#             var marker_8a60cccf6669b756db9fca8ae0ac322c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_935a6e5523f12455518663b05c8a47a6);
#
#
#         var popup_8425e409a786d5d2d53b230a2c806ef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d31f586ad586f202e0e4ba84ed5691d = $(`&lt;div id=&quot;html_6d31f586ad586f202e0e4ba84ed5691d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8425e409a786d5d2d53b230a2c806ef2.setContent(html_6d31f586ad586f202e0e4ba84ed5691d);
#
#
#
#         marker_8a60cccf6669b756db9fca8ae0ac322c.bindPopup(popup_8425e409a786d5d2d53b230a2c806ef2)
#         ;
#
#
#
#
#             var marker_d4b6d59108ed90fc00897139a3b0b985 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_935a6e5523f12455518663b05c8a47a6);
#
#
#         var popup_8bce3b5f9d6410ee2dc4c674f3008154 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b8b1abb3e7fc9b047686b8cd3f99806 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b8b1abb3e7fc9b047686b8cd3f99806&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b8b1abb3e7fc9b047686b8cd3f99806 = L.map(
#                 &quot;map_3b8b1abb3e7fc9b047686b8cd3f99806&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49ab8876f7f46ecbb444d106765a5df3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49ab8876f7f46ecbb444d106765a5df3.addTo(map_3b8b1abb3e7fc9b047686b8cd3f99806);
#
#
#             var feature_group_c0a703376c30027e81dc96f5d09785dd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c0a703376c30027e81dc96f5d09785dd.addTo(map_3b8b1abb3e7fc9b047686b8cd3f99806);
#
#
#             var feature_group_sub_group_bf1ddfdf669ea013b10a13faf60ad3af = L.featureGroup.subGroup(
#                 feature_group_c0a703376c30027e81dc96f5d09785dd
#             );
#
#
#             var marker_f5828ad57279ac546e109c36c4f92a56 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf1ddfdf669ea013b10a13faf60ad3af);
#
#
#         var popup_1497351fa3d1ea2c6101cae07d73ccb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d93f4844ca95e84dce6f284df56d71f2 = $(`&lt;div id=&quot;html_d93f4844ca95e84dce6f284df56d71f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1497351fa3d1ea2c6101cae07d73ccb9.setContent(html_d93f4844ca95e84dce6f284df56d71f2);
#
#
#
#         marker_f5828ad57279ac546e109c36c4f92a56.bindPopup(popup_1497351fa3d1ea2c6101cae07d73ccb9)
#         ;
#
#
#
#
#             var marker_423994fdd3260a93d73789a502966070 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf1ddfdf669ea013b10a13faf60ad3af);
#
#
#         var popup_033e792300a61aa7a55a892f987b98a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba0700c772c9edab5fd6fb1dec99b59b = $(`&lt;div id=&quot;html_ba0700c772c9edab5fd6fb1dec99b59b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_033e792300a61aa7a55a892f987b98a8.setContent(html_ba0700c772c9edab5fd6fb1dec99b59b);
#
#
#
#         marker_423994fdd3260a93d73789a502966070.bindPopup(popup_033e792300a61aa7a55a892f987b98a8)
#         ;
#
#
#
#
#             var marker_f6df52fc7fb626391382dc87b72d7d3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf1ddfdf669ea013b10a13faf60ad3af);
#
#
#         var popup_4bc081e929b012dcf616b569329abf4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea83c7928e7cab93e781ebea3f1d3686 = $(`&lt;div id=&quot;html_ea83c7928e7cab93e781ebea3f1d3686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4bc081e929b012dcf616b569329abf4b.setContent(html_ea83c7928e7cab93e781ebea3f1d3686);
#
#
#
#         marker_f6df52fc7fb626391382dc87b72d7d3e.bindPopup(popup_4bc081e929b012dcf616b569329abf4b)
#         ;
#
#
#
#
#             var marker_3ff0d5784cf05cc784664e2882560680 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf1ddfdf669ea013b10a13faf60ad3af);
#
#
#         var popup_4fbe2f429ee21940b13d6bf0a1ce145d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d49d246bd59449f21fbcdecc70377f4 = $(`&lt;div id=&quot;html_2d49d246bd59449f21fbcdecc70377f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4fbe2f429ee21940b13d6bf0a1ce145d.setContent(html_2d49d246bd59449f21fbcdecc70377f4);
#
#
#
#         marker_
