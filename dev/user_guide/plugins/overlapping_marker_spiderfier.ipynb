# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd4817d08ca1501c9d5aa007828f8bef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd4817d08ca1501c9d5aa007828f8bef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd4817d08ca1501c9d5aa007828f8bef = L.map(
#                 &quot;map_cd4817d08ca1501c9d5aa007828f8bef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a0a011f33310bee5fefbd04f23a15e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a0a011f33310bee5fefbd04f23a15e0.addTo(map_cd4817d08ca1501c9d5aa007828f8bef);
#
#
#             var marker_a1b7eab3c5a1e35c6351427b8b7677bd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cd4817d08ca1501c9d5aa007828f8bef);
#
#
#         var popup_ec8598a30b214e0a2ad0df6a046054bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26a324a044531ac2ec17b6779f96d5b8 = $(`&lt;div id=&quot;html_26a324a044531ac2ec17b6779f96d5b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ec8598a30b214e0a2ad0df6a046054bb.setContent(html_26a324a044531ac2ec17b6779f96d5b8);
#
#
#
#         marker_a1b7eab3c5a1e35c6351427b8b7677bd.bindPopup(popup_ec8598a30b214e0a2ad0df6a046054bb)
#         ;
#
#
#
#
#             var marker_5ee71326b6aed8aaaf8af43a5f56f731 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cd4817d08ca1501c9d5aa007828f8bef);
#
#
#         var popup_ef376f1f3cba35e89f0c97a86c2e5af4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa01962703661a51d846182f9774780a = $(`&lt;div id=&quot;html_fa01962703661a51d846182f9774780a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ef376f1f3cba35e89f0c97a86c2e5af4.setContent(html_fa01962703661a51d846182f9774780a);
#
#
#
#         marker_5ee71326b6aed8aaaf8af43a5f56f731.bindPopup(popup_ef376f1f3cba35e89f0c97a86c2e5af4)
#         ;
#
#
#
#
#             var marker_4b9a49f70296e97204ecb397704ff7bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cd4817d08ca1501c9d5aa007828f8bef);
#
#
#         var popup_a7eebd978f9591b8fe90a7d19cbdffa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbfc1820f4dfab33c3d65bb9832f9703 = $(`&lt;div id=&quot;html_bbfc1820f4dfab33c3d65bb9832f9703&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a7eebd978f9591b8fe90a7d19cbdffa9.setContent(html_bbfc1820f4dfab33c3d65bb9832f9703);
#
#
#
#         marker_4b9a49f70296e97204ecb397704ff7bf.bindPopup(popup_a7eebd978f9591b8fe90a7d19cbdffa9)
#         ;
#
#
#
#
#             var marker_8386be847c37a9b77b245fb4286c9c0f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cd4817d08ca1501c9d5aa007828f8bef);
#
#
#         var popup_1ce980b194ffe32c7d3773bf85d119a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_322c1a2e562b981522c623e6c63a5f9b = $(`&lt;div id=&quot;html_322c1a2e562b981522c623e6c63a5f9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1ce980b194ffe32c7d3773bf85d119a5.setContent(html_322c1a2e562b981522c623e6c63a5f9b);
#
#
#
#         marker_8386be847c37a9b77b245fb4286c9c0f.bindPopup(popup_1ce980b194ffe32c7d3773bf85d119a5)
#         ;
#
#
#
#
#             var marker_e9fbe8b8cf9cbd5c505d39ebace8df6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cd4817d08ca1501c9d5aa007828f8bef);
#
#
#         var popup_365101c52d3e789f64f45190df13af0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ed9e3b9ebb6b89291b265573c77ce46 = $(`&lt;div id=&quot;html_2ed9e3b9ebb6b89291b265573c77ce46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_365101c52d3e789f64f45190df13af0c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b38ebd7c48dc014229d728cba430bb46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b38ebd7c48dc014229d728cba430bb46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b38ebd7c48dc014229d728cba430bb46 = L.map(
#                 &quot;map_b38ebd7c48dc014229d728cba430bb46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb58171b7494b2ae87f42009f3bfac79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb58171b7494b2ae87f42009f3bfac79.addTo(map_b38ebd7c48dc014229d728cba430bb46);
#
#
#             var feature_group_fb790bc6fbc965d9b18f3f8cef4ee289 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c1bc811956089cd99b034d5988c52e67 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fb790bc6fbc965d9b18f3f8cef4ee289);
#
#
#         var popup_754e75d8110b2dfa7bfb8d92c3c2d862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae436ec3c7074085be69bf9a6c756758 = $(`&lt;div id=&quot;html_ae436ec3c7074085be69bf9a6c756758&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_754e75d8110b2dfa7bfb8d92c3c2d862.setContent(html_ae436ec3c7074085be69bf9a6c756758);
#
#
#
#         marker_c1bc811956089cd99b034d5988c52e67.bindPopup(popup_754e75d8110b2dfa7bfb8d92c3c2d862)
#         ;
#
#
#
#
#             var marker_bacaba27f179f6cb1bb17c92c90527f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fb790bc6fbc965d9b18f3f8cef4ee289);
#
#
#         var popup_9b55c8fc057280acc3f570ba6b345f3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dbff969aa1faa672f01bb80d3c28f76 = $(`&lt;div id=&quot;html_7dbff969aa1faa672f01bb80d3c28f76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9b55c8fc057280acc3f570ba6b345f3b.setContent(html_7dbff969aa1faa672f01bb80d3c28f76);
#
#
#
#         marker_bacaba27f179f6cb1bb17c92c90527f6.bindPopup(popup_9b55c8fc057280acc3f570ba6b345f3b)
#         ;
#
#
#
#
#             var marker_30833237aab5e981b1bc594c551eee98 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fb790bc6fbc965d9b18f3f8cef4ee289);
#
#
#         var popup_0ac1a8360bb51f38f370a729f5f8160a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c25405b75476c17f3120907b5f8e3c50 = $(`&lt;div id=&quot;html_c25405b75476c17f3120907b5f8e3c50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0ac1a8360bb51f38f370a729f5f8160a.setContent(html_c25405b75476c17f3120907b5f8e3c50);
#
#
#
#         marker_30833237aab5e981b1bc594c551eee98.bindPopup(popup_0ac1a8360bb51f38f370a729f5f8160a)
#         ;
#
#
#
#
#             var marker_e5d041b5abd52a6d398f750c8df5ab9c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fb790bc6fbc965d9b18f3f8cef4ee289);
#
#
#         var popup_51e38271bfcb35b905d9fc0e1aaa31d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_374cc314bf4b0ca64d9f6bd0ed0b0aa2 = $(`&lt;div id=&quot;html_374cc314bf4b0ca64d9f6bd0ed0b0aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_51e38271bfcb35b905d9fc0e1aaa31d2.setContent(html_374cc314bf4b0ca64d9f6bd0ed0b0aa2);
#
#
#
#         marker_e5d041b5abd52a6d398f750c8df5ab9c.bindPopup(popup_51e38271bfcb35b905d9fc0e1aaa31d2)
#         ;
#
#
#
#
#             var marker_abd4314b8fd96c87842f7dbd7dffd901 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fb790bc6fbc965d9b18f3f8cef4ee289);
#
#
#         var popup_bdab4d5154212e0d919ecc44838456dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_953227e77c58f9a4ca791ac41f499c76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_953227e77c58f9a4ca791ac41f499c76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_953227e77c58f9a4ca791ac41f499c76 = L.map(
#                 &quot;map_953227e77c58f9a4ca791ac41f499c76&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eca32836d9857ae70e62d957cc4a0c82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eca32836d9857ae70e62d957cc4a0c82.addTo(map_953227e77c58f9a4ca791ac41f499c76);
#
#
#             var feature_group_e488fccc9cb7c4e04a7ddf2bcbc48051 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e488fccc9cb7c4e04a7ddf2bcbc48051.addTo(map_953227e77c58f9a4ca791ac41f499c76);
#
#
#             var feature_group_sub_group_91380a79fae65b4955f1c18ebe7ae433 = L.featureGroup.subGroup(
#                 feature_group_e488fccc9cb7c4e04a7ddf2bcbc48051
#             );
#
#
#             var marker_38e81c2a310385157d482b1961e2fc15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_91380a79fae65b4955f1c18ebe7ae433);
#
#
#         var popup_cb35ea1149fbbd3b91711f5fa9eff93a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b480a2c1898730b5d418311a965b2f33 = $(`&lt;div id=&quot;html_b480a2c1898730b5d418311a965b2f33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb35ea1149fbbd3b91711f5fa9eff93a.setContent(html_b480a2c1898730b5d418311a965b2f33);
#
#
#
#         marker_38e81c2a310385157d482b1961e2fc15.bindPopup(popup_cb35ea1149fbbd3b91711f5fa9eff93a)
#         ;
#
#
#
#
#             var marker_92e286a8b37317987e51b96898b6f507 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_91380a79fae65b4955f1c18ebe7ae433);
#
#
#         var popup_52b0dbf63d7ad35f40775ff0d00fc553 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51a008c4ab06faf0bb0739b342a516d0 = $(`&lt;div id=&quot;html_51a008c4ab06faf0bb0739b342a516d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_52b0dbf63d7ad35f40775ff0d00fc553.setContent(html_51a008c4ab06faf0bb0739b342a516d0);
#
#
#
#         marker_92e286a8b37317987e51b96898b6f507.bindPopup(popup_52b0dbf63d7ad35f40775ff0d00fc553)
#         ;
#
#
#
#
#             var marker_35d65f544266b4b6517c8d31f44ef914 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_91380a79fae65b4955f1c18ebe7ae433);
#
#
#         var popup_ea5c9dd4caa814004887743995677293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72333fde75a546703b75d3b69e8f0ea5 = $(`&lt;div id=&quot;html_72333fde75a546703b75d3b69e8f0ea5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ea5c9dd4caa814004887743995677293.setContent(html_72333fde75a546703b75d3b69e8f0ea5);
#
#
#
#         marker_35d65f544266b4b6517c8d31f44ef914.bindPopup(popup_ea5c9dd4caa814004887743995677293)
#         ;
#
#
#
#
#             var marker_4f821da07cb56c68633cd192a669355d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_91380a79fae65b4955f1c18ebe7ae433);
#
#
#         var popup_24fa38ea42daadd331753aa8c4d72685 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbb479f87534a24b5c1918664d4afe4e = $(`&lt;div id=&quot;html_bbb479f87534a24b5c1918664d4afe4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_24fa38ea42daadd331753aa8c4d72685.setContent(html_bbb479f87534a24b5c1918664d4afe4e);
#
#
#
#         marker_
