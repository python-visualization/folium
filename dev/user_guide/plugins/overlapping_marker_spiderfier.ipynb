# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd3f3f2554898a2a9c39765888020b57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd3f3f2554898a2a9c39765888020b57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd3f3f2554898a2a9c39765888020b57 = L.map(
#                 &quot;map_cd3f3f2554898a2a9c39765888020b57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7f9db4d635b4a95b9af2ddaf5952713 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7f9db4d635b4a95b9af2ddaf5952713.addTo(map_cd3f3f2554898a2a9c39765888020b57);
#
#
#             var marker_91ced845cb34e65a9991a238d3b9d850 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cd3f3f2554898a2a9c39765888020b57);
#
#
#         var popup_3725bcbcffb310621ba9e8294326e511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af2829fd5df733e520cfcc73d32d592c = $(`&lt;div id=&quot;html_af2829fd5df733e520cfcc73d32d592c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3725bcbcffb310621ba9e8294326e511.setContent(html_af2829fd5df733e520cfcc73d32d592c);
#
#
#
#         marker_91ced845cb34e65a9991a238d3b9d850.bindPopup(popup_3725bcbcffb310621ba9e8294326e511)
#         ;
#
#
#
#
#             var marker_8e1550049145ad44df047e0c0278912b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cd3f3f2554898a2a9c39765888020b57);
#
#
#         var popup_3b462bd0dec3858081f298bd0bcc504f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23f318cf41c2c9828288c0db59909ae9 = $(`&lt;div id=&quot;html_23f318cf41c2c9828288c0db59909ae9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3b462bd0dec3858081f298bd0bcc504f.setContent(html_23f318cf41c2c9828288c0db59909ae9);
#
#
#
#         marker_8e1550049145ad44df047e0c0278912b.bindPopup(popup_3b462bd0dec3858081f298bd0bcc504f)
#         ;
#
#
#
#
#             var marker_916f7650afb8f9485f7d6ad24bc0d5f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cd3f3f2554898a2a9c39765888020b57);
#
#
#         var popup_d94934a542fdbd29b489f5491062e913 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c29fc54f24be8928149daa8bb6b1a75 = $(`&lt;div id=&quot;html_0c29fc54f24be8928149daa8bb6b1a75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d94934a542fdbd29b489f5491062e913.setContent(html_0c29fc54f24be8928149daa8bb6b1a75);
#
#
#
#         marker_916f7650afb8f9485f7d6ad24bc0d5f6.bindPopup(popup_d94934a542fdbd29b489f5491062e913)
#         ;
#
#
#
#
#             var marker_50dbc043e91f0db7d3c4660e3a550349 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cd3f3f2554898a2a9c39765888020b57);
#
#
#         var popup_94efc1e0e957ac1c183245c54ca6060b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898042b849d8904ebf0c3ab6ad053921 = $(`&lt;div id=&quot;html_898042b849d8904ebf0c3ab6ad053921&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_94efc1e0e957ac1c183245c54ca6060b.setContent(html_898042b849d8904ebf0c3ab6ad053921);
#
#
#
#         marker_50dbc043e91f0db7d3c4660e3a550349.bindPopup(popup_94efc1e0e957ac1c183245c54ca6060b)
#         ;
#
#
#
#
#             var marker_27a99e6f6b0d936d3e0d6eadbd0c5bb4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cd3f3f2554898a2a9c39765888020b57);
#
#
#         var popup_f28a25b891497c3935d1259823f50ec4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e09b167ca709bd3238d802b5d2cab95a = $(`&lt;div id=&quot;html_e09b167ca709bd3238d802b5d2cab95a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f28a25b891497c3935d1259823f50ec4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b32e37090d28ae83c59844f10097978e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b32e37090d28ae83c59844f10097978e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b32e37090d28ae83c59844f10097978e = L.map(
#                 &quot;map_b32e37090d28ae83c59844f10097978e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cc841aa988c1c589d7fe9521e1225ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cc841aa988c1c589d7fe9521e1225ae.addTo(map_b32e37090d28ae83c59844f10097978e);
#
#
#             var feature_group_2bad1175f39a7eeaa6d5432e8e51c08a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7f25d0431cc81d5809878e305f4b8abf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2bad1175f39a7eeaa6d5432e8e51c08a);
#
#
#         var popup_c30914e7ec6e04aa09d4458114a43857 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c6170d76b025c1e4c6a20dc0abb15f6 = $(`&lt;div id=&quot;html_4c6170d76b025c1e4c6a20dc0abb15f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c30914e7ec6e04aa09d4458114a43857.setContent(html_4c6170d76b025c1e4c6a20dc0abb15f6);
#
#
#
#         marker_7f25d0431cc81d5809878e305f4b8abf.bindPopup(popup_c30914e7ec6e04aa09d4458114a43857)
#         ;
#
#
#
#
#             var marker_4e6eec2c8dc8a44cc7ac66728b76b62f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2bad1175f39a7eeaa6d5432e8e51c08a);
#
#
#         var popup_05fc54687ee06a47ffe10ba603fa1a6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_075352d443cca22f027361c23d4c16cd = $(`&lt;div id=&quot;html_075352d443cca22f027361c23d4c16cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_05fc54687ee06a47ffe10ba603fa1a6a.setContent(html_075352d443cca22f027361c23d4c16cd);
#
#
#
#         marker_4e6eec2c8dc8a44cc7ac66728b76b62f.bindPopup(popup_05fc54687ee06a47ffe10ba603fa1a6a)
#         ;
#
#
#
#
#             var marker_3d6348b52fe9f76756e8e74786b3b889 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2bad1175f39a7eeaa6d5432e8e51c08a);
#
#
#         var popup_d56121599fa5f9bcf2094eadc552be3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8057810d105ef5b12b4adbbe08d74dcf = $(`&lt;div id=&quot;html_8057810d105ef5b12b4adbbe08d74dcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d56121599fa5f9bcf2094eadc552be3d.setContent(html_8057810d105ef5b12b4adbbe08d74dcf);
#
#
#
#         marker_3d6348b52fe9f76756e8e74786b3b889.bindPopup(popup_d56121599fa5f9bcf2094eadc552be3d)
#         ;
#
#
#
#
#             var marker_3d4cc6870b5dafb2a55255196f60de0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2bad1175f39a7eeaa6d5432e8e51c08a);
#
#
#         var popup_ac7c31963cfe8d7e2bad9c8a28955e5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_929e100e0afc0320670e12d5f121d326 = $(`&lt;div id=&quot;html_929e100e0afc0320670e12d5f121d326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ac7c31963cfe8d7e2bad9c8a28955e5a.setContent(html_929e100e0afc0320670e12d5f121d326);
#
#
#
#         marker_3d4cc6870b5dafb2a55255196f60de0a.bindPopup(popup_ac7c31963cfe8d7e2bad9c8a28955e5a)
#         ;
#
#
#
#
#             var marker_c0a2231b32865b81d63fe64341e3ea65 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2bad1175f39a7eeaa6d5432e8e51c08a);
#
#
#         var popup_b821e79f99523a9cca0cc694dfa98d68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba5545dded8f39ebc9bcfc850b405607 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba5545dded8f39ebc9bcfc850b405607&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba5545dded8f39ebc9bcfc850b405607 = L.map(
#                 &quot;map_ba5545dded8f39ebc9bcfc850b405607&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65fa866008047b08bf8ecf8c05f543fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65fa866008047b08bf8ecf8c05f543fc.addTo(map_ba5545dded8f39ebc9bcfc850b405607);
#
#
#             var feature_group_c532f791a5a572ee69ea8710f219ab03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c532f791a5a572ee69ea8710f219ab03.addTo(map_ba5545dded8f39ebc9bcfc850b405607);
#
#
#             var feature_group_sub_group_8503f2dd8bffd4dd68f368a470c83729 = L.featureGroup.subGroup(
#                 feature_group_c532f791a5a572ee69ea8710f219ab03
#             );
#
#
#             var marker_2642e2f34e310121cf628db8004f93d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8503f2dd8bffd4dd68f368a470c83729);
#
#
#         var popup_5638297276bde3ade3da9ebb0f4bc4d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f124941dfe721eb3926754cbb4c0e3a = $(`&lt;div id=&quot;html_6f124941dfe721eb3926754cbb4c0e3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5638297276bde3ade3da9ebb0f4bc4d1.setContent(html_6f124941dfe721eb3926754cbb4c0e3a);
#
#
#
#         marker_2642e2f34e310121cf628db8004f93d9.bindPopup(popup_5638297276bde3ade3da9ebb0f4bc4d1)
#         ;
#
#
#
#
#             var marker_93f60800f1f757ecf2f902c8aea16d79 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8503f2dd8bffd4dd68f368a470c83729);
#
#
#         var popup_2b42b593759586e9df47e9f354ede966 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fa8299d64698fd575535a1fe4eea019 = $(`&lt;div id=&quot;html_0fa8299d64698fd575535a1fe4eea019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2b42b593759586e9df47e9f354ede966.setContent(html_0fa8299d64698fd575535a1fe4eea019);
#
#
#
#         marker_93f60800f1f757ecf2f902c8aea16d79.bindPopup(popup_2b42b593759586e9df47e9f354ede966)
#         ;
#
#
#
#
#             var marker_eefe00286cb9a4b501d19b4263e6f169 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8503f2dd8bffd4dd68f368a470c83729);
#
#
#         var popup_337bc68f4d77bc89c84fd4624752fd8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82dec3968717e3349383addc01b47b08 = $(`&lt;div id=&quot;html_82dec3968717e3349383addc01b47b08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_337bc68f4d77bc89c84fd4624752fd8e.setContent(html_82dec3968717e3349383addc01b47b08);
#
#
#
#         marker_eefe00286cb9a4b501d19b4263e6f169.bindPopup(popup_337bc68f4d77bc89c84fd4624752fd8e)
#         ;
#
#
#
#
#             var marker_68ab7cfe70b67e0b8320e5592199ee1c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8503f2dd8bffd4dd68f368a470c83729);
#
#
#         var popup_6eb2229b0cb9b93f6d0bbd315a997309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e10bc2e62d81b9a17124f71dc711e39a = $(`&lt;div id=&quot;html_e10bc2e62d81b9a17124f71dc711e39a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6eb2229b0cb9b93f6d0bbd315a997309.setContent(html_e10bc2e62d81b9a17124f71dc711e39a);
#
#
#
#         marker_
