# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2f78bd34c140475783a7fbbcaf4bad9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2f78bd34c140475783a7fbbcaf4bad9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2f78bd34c140475783a7fbbcaf4bad9 = L.map(
#                 &quot;map_b2f78bd34c140475783a7fbbcaf4bad9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72929ddccd644a55ece9250167c4cd43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72929ddccd644a55ece9250167c4cd43.addTo(map_b2f78bd34c140475783a7fbbcaf4bad9);
#
#
#             var marker_9de134d6386245e27e82628a3521d34b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b2f78bd34c140475783a7fbbcaf4bad9);
#
#
#         var popup_4bec73ff328b8f5f4b5cb44d3ac468a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb29fc1643570761a05085ed1f4fc682 = $(`&lt;div id=&quot;html_cb29fc1643570761a05085ed1f4fc682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4bec73ff328b8f5f4b5cb44d3ac468a8.setContent(html_cb29fc1643570761a05085ed1f4fc682);
#
#
#
#         marker_9de134d6386245e27e82628a3521d34b.bindPopup(popup_4bec73ff328b8f5f4b5cb44d3ac468a8)
#         ;
#
#
#
#
#             var marker_0fdd108384b4114073a209fc76431c3c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b2f78bd34c140475783a7fbbcaf4bad9);
#
#
#         var popup_3ac878f42fbe4361ef3191e93bb85d48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898c5bf07e6682f1154bc32c3949ff98 = $(`&lt;div id=&quot;html_898c5bf07e6682f1154bc32c3949ff98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3ac878f42fbe4361ef3191e93bb85d48.setContent(html_898c5bf07e6682f1154bc32c3949ff98);
#
#
#
#         marker_0fdd108384b4114073a209fc76431c3c.bindPopup(popup_3ac878f42fbe4361ef3191e93bb85d48)
#         ;
#
#
#
#
#             var marker_164a12c79dc8f5120271448a39c1f106 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b2f78bd34c140475783a7fbbcaf4bad9);
#
#
#         var popup_2880b1558baa9c39a5149203cafa07d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96f0be217117976ae4ea2ed4f7410c9c = $(`&lt;div id=&quot;html_96f0be217117976ae4ea2ed4f7410c9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2880b1558baa9c39a5149203cafa07d9.setContent(html_96f0be217117976ae4ea2ed4f7410c9c);
#
#
#
#         marker_164a12c79dc8f5120271448a39c1f106.bindPopup(popup_2880b1558baa9c39a5149203cafa07d9)
#         ;
#
#
#
#
#             var marker_21bcde7b3862c34d50dbf619fab8c49b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b2f78bd34c140475783a7fbbcaf4bad9);
#
#
#         var popup_d771a051b42f6fb0b0e087c947eaca9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4797437bd542f2f58c8a740762532d77 = $(`&lt;div id=&quot;html_4797437bd542f2f58c8a740762532d77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d771a051b42f6fb0b0e087c947eaca9e.setContent(html_4797437bd542f2f58c8a740762532d77);
#
#
#
#         marker_21bcde7b3862c34d50dbf619fab8c49b.bindPopup(popup_d771a051b42f6fb0b0e087c947eaca9e)
#         ;
#
#
#
#
#             var marker_5725207ba03eb06c44405bc8c7bec948 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b2f78bd34c140475783a7fbbcaf4bad9);
#
#
#         var popup_7676810323528afd124a05707613e4a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6b75613f9f5bd64358b860fe0d092f6 = $(`&lt;div id=&quot;html_e6b75613f9f5bd64358b860fe0d092f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7676810323528afd124a05707613e4a2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30a153ec68c2586242635fd6fbe27293 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30a153ec68c2586242635fd6fbe27293&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30a153ec68c2586242635fd6fbe27293 = L.map(
#                 &quot;map_30a153ec68c2586242635fd6fbe27293&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff5b60c661feb91bd037ffd5387b4b12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff5b60c661feb91bd037ffd5387b4b12.addTo(map_30a153ec68c2586242635fd6fbe27293);
#
#
#             var feature_group_c57432023293656faeba650d7498df52 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5fa158681f6c240fbd25fc1b04589575 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c57432023293656faeba650d7498df52);
#
#
#         var popup_7b60121e92d1453465bcb47ffefe2de6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5596780e8e5b542570ebb7ca08db647a = $(`&lt;div id=&quot;html_5596780e8e5b542570ebb7ca08db647a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7b60121e92d1453465bcb47ffefe2de6.setContent(html_5596780e8e5b542570ebb7ca08db647a);
#
#
#
#         marker_5fa158681f6c240fbd25fc1b04589575.bindPopup(popup_7b60121e92d1453465bcb47ffefe2de6)
#         ;
#
#
#
#
#             var marker_4392191de63294c0eb24b7dda1e3a0d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c57432023293656faeba650d7498df52);
#
#
#         var popup_965c311c46c9a1c8b075e923a04ae8f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1792d38d2cf9f779fd0494b3eabb383 = $(`&lt;div id=&quot;html_f1792d38d2cf9f779fd0494b3eabb383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_965c311c46c9a1c8b075e923a04ae8f0.setContent(html_f1792d38d2cf9f779fd0494b3eabb383);
#
#
#
#         marker_4392191de63294c0eb24b7dda1e3a0d2.bindPopup(popup_965c311c46c9a1c8b075e923a04ae8f0)
#         ;
#
#
#
#
#             var marker_0a2fda0680647d1744de38bc3914cb0b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c57432023293656faeba650d7498df52);
#
#
#         var popup_cff57552f1c112da6a18046817b053e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e3bd353180d05512b00305b3a6404a9 = $(`&lt;div id=&quot;html_6e3bd353180d05512b00305b3a6404a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cff57552f1c112da6a18046817b053e1.setContent(html_6e3bd353180d05512b00305b3a6404a9);
#
#
#
#         marker_0a2fda0680647d1744de38bc3914cb0b.bindPopup(popup_cff57552f1c112da6a18046817b053e1)
#         ;
#
#
#
#
#             var marker_999bedd13cd36ee6b40165b2b61356a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c57432023293656faeba650d7498df52);
#
#
#         var popup_779bffe1272a9310222e4f02529b5d3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41214fd8a49f24a599a01a3910d5915b = $(`&lt;div id=&quot;html_41214fd8a49f24a599a01a3910d5915b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_779bffe1272a9310222e4f02529b5d3b.setContent(html_41214fd8a49f24a599a01a3910d5915b);
#
#
#
#         marker_999bedd13cd36ee6b40165b2b61356a2.bindPopup(popup_779bffe1272a9310222e4f02529b5d3b)
#         ;
#
#
#
#
#             var marker_268072a0372b7d54eca0257a7faae6ed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c57432023293656faeba650d7498df52);
#
#
#         var popup_ce0476a7ba43e678791146bb0b55d523 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59f6bd9908187395656bea5b3286b59a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59f6bd9908187395656bea5b3286b59a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59f6bd9908187395656bea5b3286b59a = L.map(
#                 &quot;map_59f6bd9908187395656bea5b3286b59a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8767cf832c6dec3f7d333210f9ecf7eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8767cf832c6dec3f7d333210f9ecf7eb.addTo(map_59f6bd9908187395656bea5b3286b59a);
#
#
#             var feature_group_b6555021fa1d4f41666d5da557fd139b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b6555021fa1d4f41666d5da557fd139b.addTo(map_59f6bd9908187395656bea5b3286b59a);
#
#
#             var feature_group_sub_group_87e04bfceaa1425d807f56cd90f64708 = L.featureGroup.subGroup(
#                 feature_group_b6555021fa1d4f41666d5da557fd139b
#             );
#
#
#             var marker_1b542d6559d1fc6f3e4974b1a5ff233d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_87e04bfceaa1425d807f56cd90f64708);
#
#
#         var popup_88b980cb8db319575b68851847f2e18f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b29e79382a3118d967c47688f433252 = $(`&lt;div id=&quot;html_8b29e79382a3118d967c47688f433252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_88b980cb8db319575b68851847f2e18f.setContent(html_8b29e79382a3118d967c47688f433252);
#
#
#
#         marker_1b542d6559d1fc6f3e4974b1a5ff233d.bindPopup(popup_88b980cb8db319575b68851847f2e18f)
#         ;
#
#
#
#
#             var marker_c667ce938e45b01bcab82bcacce7bb31 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_87e04bfceaa1425d807f56cd90f64708);
#
#
#         var popup_c0db39c15eb433f1c12e6ccec1f78336 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7515ba13bebc7cc6686facd2c6af9fd = $(`&lt;div id=&quot;html_d7515ba13bebc7cc6686facd2c6af9fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c0db39c15eb433f1c12e6ccec1f78336.setContent(html_d7515ba13bebc7cc6686facd2c6af9fd);
#
#
#
#         marker_c667ce938e45b01bcab82bcacce7bb31.bindPopup(popup_c0db39c15eb433f1c12e6ccec1f78336)
#         ;
#
#
#
#
#             var marker_b76256af05122f56310acdd1d0cc9042 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_87e04bfceaa1425d807f56cd90f64708);
#
#
#         var popup_8be73803b6d0299240dc6b58c1517fd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5225714a226e376e9938d060b5838fd6 = $(`&lt;div id=&quot;html_5225714a226e376e9938d060b5838fd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8be73803b6d0299240dc6b58c1517fd3.setContent(html_5225714a226e376e9938d060b5838fd6);
#
#
#
#         marker_b76256af05122f56310acdd1d0cc9042.bindPopup(popup_8be73803b6d0299240dc6b58c1517fd3)
#         ;
#
#
#
#
#             var marker_37c39bee2e0cd04c13ffd7e079e81c98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_87e04bfceaa1425d807f56cd90f64708);
#
#
#         var popup_818e0022bce14de160182326d7a00331 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef0e29973174b169f173f9d9a3ed16ea = $(`&lt;div id=&quot;html_ef0e29973174b169f173f9d9a3ed16ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_818e0022bce14de160182326d7a00331.setContent(html_ef0e29973174b169f173f9d9a3ed16ea);
#
#
#
#         marker_
