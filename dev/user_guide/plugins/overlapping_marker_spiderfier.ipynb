# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff86e1c4751d2d4e33d9651b1dd1c61e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff86e1c4751d2d4e33d9651b1dd1c61e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff86e1c4751d2d4e33d9651b1dd1c61e = L.map(
#                 &quot;map_ff86e1c4751d2d4e33d9651b1dd1c61e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff13550a95f07babef7e00535ba34e52 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff13550a95f07babef7e00535ba34e52.addTo(map_ff86e1c4751d2d4e33d9651b1dd1c61e);
#
#
#             var marker_58122422fb38ee86d16be7696f829596 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ff86e1c4751d2d4e33d9651b1dd1c61e);
#
#
#         var popup_c882da65691e84a34e7aad19347e1776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_705d49d4a19b11527cbfc6e3b124fd1f = $(`&lt;div id=&quot;html_705d49d4a19b11527cbfc6e3b124fd1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c882da65691e84a34e7aad19347e1776.setContent(html_705d49d4a19b11527cbfc6e3b124fd1f);
#
#
#
#         marker_58122422fb38ee86d16be7696f829596.bindPopup(popup_c882da65691e84a34e7aad19347e1776)
#         ;
#
#
#
#
#             var marker_f8048f53cec9ce4dc1f5e62e395bbada = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ff86e1c4751d2d4e33d9651b1dd1c61e);
#
#
#         var popup_f98bdefb74d8975990f1bc3512f40f12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a2f1311c5102925d7a5e385b8ed8ce9 = $(`&lt;div id=&quot;html_2a2f1311c5102925d7a5e385b8ed8ce9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f98bdefb74d8975990f1bc3512f40f12.setContent(html_2a2f1311c5102925d7a5e385b8ed8ce9);
#
#
#
#         marker_f8048f53cec9ce4dc1f5e62e395bbada.bindPopup(popup_f98bdefb74d8975990f1bc3512f40f12)
#         ;
#
#
#
#
#             var marker_87728e304e3aad6e20f8b5617890ce8c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ff86e1c4751d2d4e33d9651b1dd1c61e);
#
#
#         var popup_d277e6137c72597a4fe41b4d6048c0cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_417955681c443c5a850c410245db53d4 = $(`&lt;div id=&quot;html_417955681c443c5a850c410245db53d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d277e6137c72597a4fe41b4d6048c0cb.setContent(html_417955681c443c5a850c410245db53d4);
#
#
#
#         marker_87728e304e3aad6e20f8b5617890ce8c.bindPopup(popup_d277e6137c72597a4fe41b4d6048c0cb)
#         ;
#
#
#
#
#             var marker_a37df1fb2ca63c3e2086a7b19a95006f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ff86e1c4751d2d4e33d9651b1dd1c61e);
#
#
#         var popup_e489074954cb71c1a4c6f23986533dd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40b1eff9dcaffc2e4d218e5b91cdb6f9 = $(`&lt;div id=&quot;html_40b1eff9dcaffc2e4d218e5b91cdb6f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e489074954cb71c1a4c6f23986533dd5.setContent(html_40b1eff9dcaffc2e4d218e5b91cdb6f9);
#
#
#
#         marker_a37df1fb2ca63c3e2086a7b19a95006f.bindPopup(popup_e489074954cb71c1a4c6f23986533dd5)
#         ;
#
#
#
#
#             var marker_9ab61ab29b65b8114c18b869aba543c0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ff86e1c4751d2d4e33d9651b1dd1c61e);
#
#
#         var popup_c252563d7fba609c95660d5b76318913 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3f130d841e9bc059ef361c48bd3464b = $(`&lt;div id=&quot;html_c3f130d841e9bc059ef361c48bd3464b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c252563d7fba609c95660d5b76318913.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45cb93f6bd17bb54075df83ab31a0f15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45cb93f6bd17bb54075df83ab31a0f15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45cb93f6bd17bb54075df83ab31a0f15 = L.map(
#                 &quot;map_45cb93f6bd17bb54075df83ab31a0f15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87d926b4286ed5b4c7607a0f03175f60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87d926b4286ed5b4c7607a0f03175f60.addTo(map_45cb93f6bd17bb54075df83ab31a0f15);
#
#
#             var feature_group_ed3bfca016a43a3d4bf5673bf6d510a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_39af462c59ddc8f8ae09e8541faf8872 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ed3bfca016a43a3d4bf5673bf6d510a6);
#
#
#         var popup_1db252bf2a51fbb39f0b64920608f015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdfa6dc7e308975ae5eae498db896c50 = $(`&lt;div id=&quot;html_cdfa6dc7e308975ae5eae498db896c50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1db252bf2a51fbb39f0b64920608f015.setContent(html_cdfa6dc7e308975ae5eae498db896c50);
#
#
#
#         marker_39af462c59ddc8f8ae09e8541faf8872.bindPopup(popup_1db252bf2a51fbb39f0b64920608f015)
#         ;
#
#
#
#
#             var marker_4138848c6ec4058b6751e67ab2995c1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ed3bfca016a43a3d4bf5673bf6d510a6);
#
#
#         var popup_46acd556fd853c5cd223e624fe043578 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9acce13d54fe5120d5b4daef69e2f96 = $(`&lt;div id=&quot;html_f9acce13d54fe5120d5b4daef69e2f96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_46acd556fd853c5cd223e624fe043578.setContent(html_f9acce13d54fe5120d5b4daef69e2f96);
#
#
#
#         marker_4138848c6ec4058b6751e67ab2995c1f.bindPopup(popup_46acd556fd853c5cd223e624fe043578)
#         ;
#
#
#
#
#             var marker_1d61ab65b8deeaa847f8760368cfac3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ed3bfca016a43a3d4bf5673bf6d510a6);
#
#
#         var popup_40cc2078b24a4ed7dbb2ac9f749bf5ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c9abd790ee95365b33a4cc1df0f3a69 = $(`&lt;div id=&quot;html_6c9abd790ee95365b33a4cc1df0f3a69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_40cc2078b24a4ed7dbb2ac9f749bf5ee.setContent(html_6c9abd790ee95365b33a4cc1df0f3a69);
#
#
#
#         marker_1d61ab65b8deeaa847f8760368cfac3f.bindPopup(popup_40cc2078b24a4ed7dbb2ac9f749bf5ee)
#         ;
#
#
#
#
#             var marker_9d194aaf1b0abd1e0cfef9cc0978b915 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ed3bfca016a43a3d4bf5673bf6d510a6);
#
#
#         var popup_f3198847935ab8995a9ea63656b7a310 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0edd895e3109ae2f75e29408fa423f51 = $(`&lt;div id=&quot;html_0edd895e3109ae2f75e29408fa423f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f3198847935ab8995a9ea63656b7a310.setContent(html_0edd895e3109ae2f75e29408fa423f51);
#
#
#
#         marker_9d194aaf1b0abd1e0cfef9cc0978b915.bindPopup(popup_f3198847935ab8995a9ea63656b7a310)
#         ;
#
#
#
#
#             var marker_49ddb4125ebd5571d167756d3ca22e3f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ed3bfca016a43a3d4bf5673bf6d510a6);
#
#
#         var popup_e2653e8c0177105492cc930a7f5c9bc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_097a6ecdf234c222ad78cbe3fca3f365 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_097a6ecdf234c222ad78cbe3fca3f365&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_097a6ecdf234c222ad78cbe3fca3f365 = L.map(
#                 &quot;map_097a6ecdf234c222ad78cbe3fca3f365&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcd500677c36bd776eaf9bf19bccd77e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcd500677c36bd776eaf9bf19bccd77e.addTo(map_097a6ecdf234c222ad78cbe3fca3f365);
#
#
#             var feature_group_bb7d1aac4ec9f004cc52915a0f1a7d0e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bb7d1aac4ec9f004cc52915a0f1a7d0e.addTo(map_097a6ecdf234c222ad78cbe3fca3f365);
#
#
#             var feature_group_sub_group_a1e1ecfe7b42d966a606302800bfd1bd = L.featureGroup.subGroup(
#                 feature_group_bb7d1aac4ec9f004cc52915a0f1a7d0e
#             );
#
#
#             var marker_229bf01d91392ccf31f464f51d1471e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1e1ecfe7b42d966a606302800bfd1bd);
#
#
#         var popup_6b3006114035177931092070a85d9f86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1760c821078d7e0868b9630c41a8182 = $(`&lt;div id=&quot;html_b1760c821078d7e0868b9630c41a8182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6b3006114035177931092070a85d9f86.setContent(html_b1760c821078d7e0868b9630c41a8182);
#
#
#
#         marker_229bf01d91392ccf31f464f51d1471e9.bindPopup(popup_6b3006114035177931092070a85d9f86)
#         ;
#
#
#
#
#             var marker_ac191cdd703d06591c59b2372136ed20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1e1ecfe7b42d966a606302800bfd1bd);
#
#
#         var popup_87f5efa385c1321391e968d6c1b18dbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbbb677c6d419ae0ac73acd6958c17ab = $(`&lt;div id=&quot;html_dbbb677c6d419ae0ac73acd6958c17ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_87f5efa385c1321391e968d6c1b18dbd.setContent(html_dbbb677c6d419ae0ac73acd6958c17ab);
#
#
#
#         marker_ac191cdd703d06591c59b2372136ed20.bindPopup(popup_87f5efa385c1321391e968d6c1b18dbd)
#         ;
#
#
#
#
#             var marker_3e1d6b8fd38af9c70a8d065b95337bde = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1e1ecfe7b42d966a606302800bfd1bd);
#
#
#         var popup_5a3a3e8c6373f9d2464309a31fda8f9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e2e8f52718a51816672810e13391783 = $(`&lt;div id=&quot;html_9e2e8f52718a51816672810e13391783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5a3a3e8c6373f9d2464309a31fda8f9b.setContent(html_9e2e8f52718a51816672810e13391783);
#
#
#
#         marker_3e1d6b8fd38af9c70a8d065b95337bde.bindPopup(popup_5a3a3e8c6373f9d2464309a31fda8f9b)
#         ;
#
#
#
#
#             var marker_bca7c812fade6103cdc02c12719dc44c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a1e1ecfe7b42d966a606302800bfd1bd);
#
#
#         var popup_e0ebb0d26814d815a3fd44cf08d6936d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa3a785d9379c0e52082a73a0ce360c3 = $(`&lt;div id=&quot;html_aa3a785d9379c0e52082a73a0ce360c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e0ebb0d26814d815a3fd44cf08d6936d.setContent(html_aa3a785d9379c0e52082a73a0ce360c3);
#
#
#
#         marker_
