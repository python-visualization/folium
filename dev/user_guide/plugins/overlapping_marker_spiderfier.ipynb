# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70fa56bca5f3fb961291d44d7dd76ea3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70fa56bca5f3fb961291d44d7dd76ea3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70fa56bca5f3fb961291d44d7dd76ea3 = L.map(
#                 &quot;map_70fa56bca5f3fb961291d44d7dd76ea3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_952d6cdb88b543fb4fdff6f0bf26f49e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_952d6cdb88b543fb4fdff6f0bf26f49e.addTo(map_70fa56bca5f3fb961291d44d7dd76ea3);
#
#
#             var marker_c73f9a05e461aca3e7287cd2de2b97d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_70fa56bca5f3fb961291d44d7dd76ea3);
#
#
#         var popup_3af32cd3bdae0c69f2939bd7e6cd70d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fa8d9229f2390a3ddf380ab09818057 = $(`&lt;div id=&quot;html_8fa8d9229f2390a3ddf380ab09818057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3af32cd3bdae0c69f2939bd7e6cd70d7.setContent(html_8fa8d9229f2390a3ddf380ab09818057);
#
#
#
#         marker_c73f9a05e461aca3e7287cd2de2b97d7.bindPopup(popup_3af32cd3bdae0c69f2939bd7e6cd70d7)
#         ;
#
#
#
#
#             var marker_88fa86405551b4d6e89514eafbfc1104 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_70fa56bca5f3fb961291d44d7dd76ea3);
#
#
#         var popup_10b19f25a95c5543ab6136abc349c7d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_214f0a6be9899b3fa6e59a818c64aec4 = $(`&lt;div id=&quot;html_214f0a6be9899b3fa6e59a818c64aec4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_10b19f25a95c5543ab6136abc349c7d3.setContent(html_214f0a6be9899b3fa6e59a818c64aec4);
#
#
#
#         marker_88fa86405551b4d6e89514eafbfc1104.bindPopup(popup_10b19f25a95c5543ab6136abc349c7d3)
#         ;
#
#
#
#
#             var marker_6b56e078d81731c855583a19f121e9b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_70fa56bca5f3fb961291d44d7dd76ea3);
#
#
#         var popup_ca4a8da5850f3190bfdfd33e863a6f92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43c9bbc3490ae178be3c77db4043d32f = $(`&lt;div id=&quot;html_43c9bbc3490ae178be3c77db4043d32f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ca4a8da5850f3190bfdfd33e863a6f92.setContent(html_43c9bbc3490ae178be3c77db4043d32f);
#
#
#
#         marker_6b56e078d81731c855583a19f121e9b3.bindPopup(popup_ca4a8da5850f3190bfdfd33e863a6f92)
#         ;
#
#
#
#
#             var marker_d66b6606004d4fbbfe9e2d6d43793f89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_70fa56bca5f3fb961291d44d7dd76ea3);
#
#
#         var popup_63d95788b659b66bbce8c27ca5005b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98d6706fd6357d5c38f0e519450cf2d0 = $(`&lt;div id=&quot;html_98d6706fd6357d5c38f0e519450cf2d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_63d95788b659b66bbce8c27ca5005b4b.setContent(html_98d6706fd6357d5c38f0e519450cf2d0);
#
#
#
#         marker_d66b6606004d4fbbfe9e2d6d43793f89.bindPopup(popup_63d95788b659b66bbce8c27ca5005b4b)
#         ;
#
#
#
#
#             var marker_43957ac28ab2b86ce513aaf42ab30b98 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_70fa56bca5f3fb961291d44d7dd76ea3);
#
#
#         var popup_8599bab19f992796b589535b7d0c1ac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a37d69c19231c2a931a6bf8820c9017 = $(`&lt;div id=&quot;html_8a37d69c19231c2a931a6bf8820c9017&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8599bab19f992796b589535b7d0c1ac4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff730d6a33c1db5b383389f85a4efbdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff730d6a33c1db5b383389f85a4efbdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff730d6a33c1db5b383389f85a4efbdc = L.map(
#                 &quot;map_ff730d6a33c1db5b383389f85a4efbdc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3b605c842cfc0c3606fdc1fa11ac6e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3b605c842cfc0c3606fdc1fa11ac6e6.addTo(map_ff730d6a33c1db5b383389f85a4efbdc);
#
#
#             var feature_group_e4ea03ccdb74d7b764dd13689d3bf792 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5dc0eba5210d11820f7570e489a3007a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e4ea03ccdb74d7b764dd13689d3bf792);
#
#
#         var popup_c47a420aacf43f499c85a0dc52e9ee6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcfc6c35e42adf4c265a6481735815bf = $(`&lt;div id=&quot;html_bcfc6c35e42adf4c265a6481735815bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c47a420aacf43f499c85a0dc52e9ee6d.setContent(html_bcfc6c35e42adf4c265a6481735815bf);
#
#
#
#         marker_5dc0eba5210d11820f7570e489a3007a.bindPopup(popup_c47a420aacf43f499c85a0dc52e9ee6d)
#         ;
#
#
#
#
#             var marker_22068e9cc6f15a2d77b4c527e33a717d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e4ea03ccdb74d7b764dd13689d3bf792);
#
#
#         var popup_06caabc83918957cca1174173aef9d68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad0964b9e5bc2e25da0b0d035f613176 = $(`&lt;div id=&quot;html_ad0964b9e5bc2e25da0b0d035f613176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_06caabc83918957cca1174173aef9d68.setContent(html_ad0964b9e5bc2e25da0b0d035f613176);
#
#
#
#         marker_22068e9cc6f15a2d77b4c527e33a717d.bindPopup(popup_06caabc83918957cca1174173aef9d68)
#         ;
#
#
#
#
#             var marker_429727615cd9121554c2e7db0efec465 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e4ea03ccdb74d7b764dd13689d3bf792);
#
#
#         var popup_9aeecc5fc76133d15be10c2a1cb8db0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac2ef064a72bdd8305f5283e4be76597 = $(`&lt;div id=&quot;html_ac2ef064a72bdd8305f5283e4be76597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9aeecc5fc76133d15be10c2a1cb8db0e.setContent(html_ac2ef064a72bdd8305f5283e4be76597);
#
#
#
#         marker_429727615cd9121554c2e7db0efec465.bindPopup(popup_9aeecc5fc76133d15be10c2a1cb8db0e)
#         ;
#
#
#
#
#             var marker_b2f4eb426e2aa056bdf55777b6e893a0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e4ea03ccdb74d7b764dd13689d3bf792);
#
#
#         var popup_e0e1b538f1836dff5797574db5749d75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76bbaa34777158696fd28fcd34b84f83 = $(`&lt;div id=&quot;html_76bbaa34777158696fd28fcd34b84f83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e0e1b538f1836dff5797574db5749d75.setContent(html_76bbaa34777158696fd28fcd34b84f83);
#
#
#
#         marker_b2f4eb426e2aa056bdf55777b6e893a0.bindPopup(popup_e0e1b538f1836dff5797574db5749d75)
#         ;
#
#
#
#
#             var marker_fa15e3a847bbe7ca4b106d7033fd6aaf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e4ea03ccdb74d7b764dd13689d3bf792);
#
#
#         var popup_51b30964b34ffd25f278de57e5c6a130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d6db4601c90c4672932248a60784181 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d6db4601c90c4672932248a60784181&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d6db4601c90c4672932248a60784181 = L.map(
#                 &quot;map_5d6db4601c90c4672932248a60784181&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85524799e44e29b9bbb52c3b006a08ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85524799e44e29b9bbb52c3b006a08ec.addTo(map_5d6db4601c90c4672932248a60784181);
#
#
#             var feature_group_aea3ef321b1b4abec39e5db97e7d6f95 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_aea3ef321b1b4abec39e5db97e7d6f95.addTo(map_5d6db4601c90c4672932248a60784181);
#
#
#             var feature_group_sub_group_ef607cd829026ee873fb4cc19fd9c981 = L.featureGroup.subGroup(
#                 feature_group_aea3ef321b1b4abec39e5db97e7d6f95
#             );
#
#
#             var marker_60406ce21629c664b45abf3fcb587028 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef607cd829026ee873fb4cc19fd9c981);
#
#
#         var popup_4e9433e7b8a2b15b84601440b36eeb91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1a5e3dbc31d34fd3e8b3ccab656a1a3 = $(`&lt;div id=&quot;html_c1a5e3dbc31d34fd3e8b3ccab656a1a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4e9433e7b8a2b15b84601440b36eeb91.setContent(html_c1a5e3dbc31d34fd3e8b3ccab656a1a3);
#
#
#
#         marker_60406ce21629c664b45abf3fcb587028.bindPopup(popup_4e9433e7b8a2b15b84601440b36eeb91)
#         ;
#
#
#
#
#             var marker_73e7efef8de89c20164bbe406e2990d0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef607cd829026ee873fb4cc19fd9c981);
#
#
#         var popup_d20e58cb44059ea7e6750729b5a1e491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f46e56c40f8c00e3b42a358867f87ae = $(`&lt;div id=&quot;html_9f46e56c40f8c00e3b42a358867f87ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d20e58cb44059ea7e6750729b5a1e491.setContent(html_9f46e56c40f8c00e3b42a358867f87ae);
#
#
#
#         marker_73e7efef8de89c20164bbe406e2990d0.bindPopup(popup_d20e58cb44059ea7e6750729b5a1e491)
#         ;
#
#
#
#
#             var marker_93d14fe64430e2b591f14c9a2750b0ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef607cd829026ee873fb4cc19fd9c981);
#
#
#         var popup_35b1a33cab5c75b7da9f0ed662857496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_185636f77393c55007466c082de74258 = $(`&lt;div id=&quot;html_185636f77393c55007466c082de74258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_35b1a33cab5c75b7da9f0ed662857496.setContent(html_185636f77393c55007466c082de74258);
#
#
#
#         marker_93d14fe64430e2b591f14c9a2750b0ee.bindPopup(popup_35b1a33cab5c75b7da9f0ed662857496)
#         ;
#
#
#
#
#             var marker_bc7ba9133ce4928a66e3791e860874c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef607cd829026ee873fb4cc19fd9c981);
#
#
#         var popup_9538cfd6605d60aed0ad8191c80a9886 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5736565a7387e73619e70b5371895a6f = $(`&lt;div id=&quot;html_5736565a7387e73619e70b5371895a6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9538cfd6605d60aed0ad8191c80a9886.setContent(html_5736565a7387e73619e70b5371895a6f);
#
#
#
#         marker_
