# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dd0292140de18c3a58be577f02419b8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dd0292140de18c3a58be577f02419b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dd0292140de18c3a58be577f02419b8 = L.map(
#                 &quot;map_2dd0292140de18c3a58be577f02419b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd2c88f8ece6edb5da705f8f8b109509 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd2c88f8ece6edb5da705f8f8b109509.addTo(map_2dd0292140de18c3a58be577f02419b8);
#
#
#             var marker_aebf6e1fbbbd9e3ca7ba70d6ae0fb7a7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2dd0292140de18c3a58be577f02419b8);
#
#
#         var popup_6491c160e7e51c7dac3f60d914b64eaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91f5e4c8d34f5114b21682335e9bc868 = $(`&lt;div id=&quot;html_91f5e4c8d34f5114b21682335e9bc868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6491c160e7e51c7dac3f60d914b64eaa.setContent(html_91f5e4c8d34f5114b21682335e9bc868);
#
#
#
#         marker_aebf6e1fbbbd9e3ca7ba70d6ae0fb7a7.bindPopup(popup_6491c160e7e51c7dac3f60d914b64eaa)
#         ;
#
#
#
#
#             var marker_955b9c5a26b3428ecd760760c0d7732a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2dd0292140de18c3a58be577f02419b8);
#
#
#         var popup_82c599b2956a092ec8b2e9f6ebca6e5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aad5af14021ba244628931fc75a6eb82 = $(`&lt;div id=&quot;html_aad5af14021ba244628931fc75a6eb82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_82c599b2956a092ec8b2e9f6ebca6e5c.setContent(html_aad5af14021ba244628931fc75a6eb82);
#
#
#
#         marker_955b9c5a26b3428ecd760760c0d7732a.bindPopup(popup_82c599b2956a092ec8b2e9f6ebca6e5c)
#         ;
#
#
#
#
#             var marker_a8c518ffdcdf3515dab1dfe02af1948a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2dd0292140de18c3a58be577f02419b8);
#
#
#         var popup_396ff66cef4481c2de3308a56aba31ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c47d1a7f0d421130b5c913d578746394 = $(`&lt;div id=&quot;html_c47d1a7f0d421130b5c913d578746394&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_396ff66cef4481c2de3308a56aba31ac.setContent(html_c47d1a7f0d421130b5c913d578746394);
#
#
#
#         marker_a8c518ffdcdf3515dab1dfe02af1948a.bindPopup(popup_396ff66cef4481c2de3308a56aba31ac)
#         ;
#
#
#
#
#             var marker_c8b2adfe810e08f7e4d6270803d8b51c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2dd0292140de18c3a58be577f02419b8);
#
#
#         var popup_0d9bcb3978523959ee12f807dc0716ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08508e702fe9af030e14362e8cfef0f5 = $(`&lt;div id=&quot;html_08508e702fe9af030e14362e8cfef0f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d9bcb3978523959ee12f807dc0716ee.setContent(html_08508e702fe9af030e14362e8cfef0f5);
#
#
#
#         marker_c8b2adfe810e08f7e4d6270803d8b51c.bindPopup(popup_0d9bcb3978523959ee12f807dc0716ee)
#         ;
#
#
#
#
#             var marker_0263bafa92d25abde7bcd324cb7e05c1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2dd0292140de18c3a58be577f02419b8);
#
#
#         var popup_247e6b8845c133acc5878568401b14df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02adb7a4f241e180ddac031de1043de7 = $(`&lt;div id=&quot;html_02adb7a4f241e180ddac031de1043de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_247e6b8845c133acc5878568401b14

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e672da7313697672ac1448de759c3ee7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e672da7313697672ac1448de759c3ee7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e672da7313697672ac1448de759c3ee7 = L.map(
#                 &quot;map_e672da7313697672ac1448de759c3ee7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5859d23ea07835435054b8d112f05804 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5859d23ea07835435054b8d112f05804.addTo(map_e672da7313697672ac1448de759c3ee7);
#
#
#             var feature_group_c062bfc4418574b93bb990c1ceec3e3c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e2f94eaa38ba4695186345438f077382 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c062bfc4418574b93bb990c1ceec3e3c);
#
#
#         var popup_4faed974f7bd193f228f6917dd409281 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4ebfdcba5a5470309143f6d2d45bee4 = $(`&lt;div id=&quot;html_b4ebfdcba5a5470309143f6d2d45bee4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4faed974f7bd193f228f6917dd409281.setContent(html_b4ebfdcba5a5470309143f6d2d45bee4);
#
#
#
#         marker_e2f94eaa38ba4695186345438f077382.bindPopup(popup_4faed974f7bd193f228f6917dd409281)
#         ;
#
#
#
#
#             var marker_c2dc9a8719785bd9bb11b982e6b2fc8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c062bfc4418574b93bb990c1ceec3e3c);
#
#
#         var popup_0fe3164c05c5adf76192689d4f306e77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_790e4bc37df563eaa7ed9842717291f0 = $(`&lt;div id=&quot;html_790e4bc37df563eaa7ed9842717291f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0fe3164c05c5adf76192689d4f306e77.setContent(html_790e4bc37df563eaa7ed9842717291f0);
#
#
#
#         marker_c2dc9a8719785bd9bb11b982e6b2fc8e.bindPopup(popup_0fe3164c05c5adf76192689d4f306e77)
#         ;
#
#
#
#
#             var marker_fb4497e50343c5fe3d60c5c7b8b3b447 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c062bfc4418574b93bb990c1ceec3e3c);
#
#
#         var popup_c8494d70eb596318210645065e70c92f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4f821f1e8137b39b9c42fdc0cbb1d4d = $(`&lt;div id=&quot;html_c4f821f1e8137b39b9c42fdc0cbb1d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c8494d70eb596318210645065e70c92f.setContent(html_c4f821f1e8137b39b9c42fdc0cbb1d4d);
#
#
#
#         marker_fb4497e50343c5fe3d60c5c7b8b3b447.bindPopup(popup_c8494d70eb596318210645065e70c92f)
#         ;
#
#
#
#
#             var marker_7264f609249e265dc11eae2939047eab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c062bfc4418574b93bb990c1ceec3e3c);
#
#
#         var popup_ef25a0b75a803eeb023ce3fdd919954b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_237f2f49c19aceedd90a55be62101411 = $(`&lt;div id=&quot;html_237f2f49c19aceedd90a55be62101411&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef25a0b75a803eeb023ce3fdd919954b.setContent(html_237f2f49c19aceedd90a55be62101411);
#
#
#
#         marker_7264f609249e265dc11eae2939047eab.bindPopup(popup_ef25a0b75a803eeb023ce3fdd919954b)
#         ;
#
#
#
#
#             var marker_0e2c9e621f2a1354deddd4ce1c575997 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c062bfc4418574b93bb990c1ceec3e3c);
#
#
#         var popup_c33933e514d55d36eb50acea0755f4e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8bf898314d125afd0b089db89cb32b7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8bf898314d125afd0b089db89cb32b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8bf898314d125afd0b089db89cb32b7 = L.map(
#                 &quot;map_a8bf898314d125afd0b089db89cb32b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a79c5d838fe7e96891baf9f94b11b76b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a79c5d838fe7e96891baf9f94b11b76b.addTo(map_a8bf898314d125afd0b089db89cb32b7);
#
#
#             var feature_group_a0872cc98065c42a04ed07930ac49eb3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a0872cc98065c42a04ed07930ac49eb3.addTo(map_a8bf898314d125afd0b089db89cb32b7);
#
#
#             var feature_group_sub_group_5386a330d486133c9368c45fbc3b51ed = L.featureGroup.subGroup(
#                 feature_group_a0872cc98065c42a04ed07930ac49eb3
#             );
#
#
#             var marker_c4c7f333bd9a7a895372836b470c6bae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5386a330d486133c9368c45fbc3b51ed);
#
#
#         var popup_7e006820439cc80925d3fc5915f5a2bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdf0ff636c9c25b616b77b32a70ff9be = $(`&lt;div id=&quot;html_cdf0ff636c9c25b616b77b32a70ff9be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7e006820439cc80925d3fc5915f5a2bb.setContent(html_cdf0ff636c9c25b616b77b32a70ff9be);
#
#
#
#         marker_c4c7f333bd9a7a895372836b470c6bae.bindPopup(popup_7e006820439cc80925d3fc5915f5a2bb)
#         ;
#
#
#
#
#             var marker_7d2694d0ad0e4a0a30e73abb25df3358 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5386a330d486133c9368c45fbc3b51ed);
#
#
#         var popup_b001bfc3706b270bc0ec94b03d0b02e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07e7135112871fded95a8ce9711b1857 = $(`&lt;div id=&quot;html_07e7135112871fded95a8ce9711b1857&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b001bfc3706b270bc0ec94b03d0b02e9.setContent(html_07e7135112871fded95a8ce9711b1857);
#
#
#
#         marker_7d2694d0ad0e4a0a30e73abb25df3358.bindPopup(popup_b001bfc3706b270bc0ec94b03d0b02e9)
#         ;
#
#
#
#
#             var marker_1b160c176b47d970371aa9e4eaf3de28 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5386a330d486133c9368c45fbc3b51ed);
#
#
#         var popup_bf6d3002713cb8820835d551d0052b92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9624229eab9c85376d3811f08b2e8ed = $(`&lt;div id=&quot;html_a9624229eab9c85376d3811f08b2e8ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bf6d3002713cb8820835d551d0052b92.setContent(html_a9624229eab9c85376d3811f08b2e8ed);
#
#
#
#         marker_1b160c176b47d970371aa9e4eaf3de28.bindPopup(popup_bf6d3002713cb8820835d551d0052b92)
#         ;
#
#
#
#
#             var marker_1b020e3334454a3a5cf5699c8e9678ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5386a330d486133c9368c45fbc3b51ed);
#
#
#         var popup_12bc549d4e59a1f7bd2d4f7751ce1d73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71f136394ce84bc666f214c2084193fc = $(`&lt;div id=&quot;html_71f136394ce84bc666f214c2084193fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_12bc549d4e59a1f7bd2d4f7751ce1d73.setContent(html_71f136394ce84bc666f214c2084193fc);
#
#
#
#         mark
