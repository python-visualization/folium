# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2d2454dd9b8365d25a3c96c999fa1c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2d2454dd9b8365d25a3c96c999fa1c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2d2454dd9b8365d25a3c96c999fa1c4 = L.map(
#                 &quot;map_c2d2454dd9b8365d25a3c96c999fa1c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b19c5d3bd4b61736c3d56f76615ec2e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b19c5d3bd4b61736c3d56f76615ec2e3.addTo(map_c2d2454dd9b8365d25a3c96c999fa1c4);
#
#
#             var marker_e6543292d6c3411195b79cc10985bb16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c2d2454dd9b8365d25a3c96c999fa1c4);
#
#
#         var popup_88afa4c8ed8d09bf3f211e7bf7d9b91a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_302f08a386aaade8bc265d8ae94919f5 = $(`&lt;div id=&quot;html_302f08a386aaade8bc265d8ae94919f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_88afa4c8ed8d09bf3f211e7bf7d9b91a.setContent(html_302f08a386aaade8bc265d8ae94919f5);
#
#
#
#         marker_e6543292d6c3411195b79cc10985bb16.bindPopup(popup_88afa4c8ed8d09bf3f211e7bf7d9b91a)
#         ;
#
#
#
#
#             var marker_8d40c9a89e1749d6f0ab125e79adae84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c2d2454dd9b8365d25a3c96c999fa1c4);
#
#
#         var popup_62b7392067c33968627763cf809c5923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_734c6479d95f71af189f33f499922d7b = $(`&lt;div id=&quot;html_734c6479d95f71af189f33f499922d7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_62b7392067c33968627763cf809c5923.setContent(html_734c6479d95f71af189f33f499922d7b);
#
#
#
#         marker_8d40c9a89e1749d6f0ab125e79adae84.bindPopup(popup_62b7392067c33968627763cf809c5923)
#         ;
#
#
#
#
#             var marker_68025646444830de5d9884ae575c4838 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c2d2454dd9b8365d25a3c96c999fa1c4);
#
#
#         var popup_6bb87da6aadc7dd59204d86265ccc271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1de70c23ec44b16084ba2ab17a83e49 = $(`&lt;div id=&quot;html_e1de70c23ec44b16084ba2ab17a83e49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6bb87da6aadc7dd59204d86265ccc271.setContent(html_e1de70c23ec44b16084ba2ab17a83e49);
#
#
#
#         marker_68025646444830de5d9884ae575c4838.bindPopup(popup_6bb87da6aadc7dd59204d86265ccc271)
#         ;
#
#
#
#
#             var marker_471715ff7c2c1fc802025655e279d2ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c2d2454dd9b8365d25a3c96c999fa1c4);
#
#
#         var popup_3079a258b3398afe7935d10aa76d9f06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_146820920551013d0ec96317b1e8b57b = $(`&lt;div id=&quot;html_146820920551013d0ec96317b1e8b57b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3079a258b3398afe7935d10aa76d9f06.setContent(html_146820920551013d0ec96317b1e8b57b);
#
#
#
#         marker_471715ff7c2c1fc802025655e279d2ca.bindPopup(popup_3079a258b3398afe7935d10aa76d9f06)
#         ;
#
#
#
#
#             var marker_450f884143a73f23a13cdff3b66e7dd6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c2d2454dd9b8365d25a3c96c999fa1c4);
#
#
#         var popup_bd62c1ed765e25d3425539a9197347de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb32ce9b17dd7019b826cb66e23239e3 = $(`&lt;div id=&quot;html_bb32ce9b17dd7019b826cb66e23239e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bd62c1ed765e25d3425539a9197347de.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32604c330095409d6fd8d625556a0098 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32604c330095409d6fd8d625556a0098&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32604c330095409d6fd8d625556a0098 = L.map(
#                 &quot;map_32604c330095409d6fd8d625556a0098&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1cbb53d5e583cf71d4517f3e366d3a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1cbb53d5e583cf71d4517f3e366d3a1.addTo(map_32604c330095409d6fd8d625556a0098);
#
#
#             var feature_group_645c7f88baea6410d6cd1ecc5897da61 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_342db7f5c9b3cbe6b3c765369935faf4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_645c7f88baea6410d6cd1ecc5897da61);
#
#
#         var popup_dfeb89f1116e0e82074193e4e57d636e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e5f1015a6c2c98ac74623d4575ad131 = $(`&lt;div id=&quot;html_3e5f1015a6c2c98ac74623d4575ad131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dfeb89f1116e0e82074193e4e57d636e.setContent(html_3e5f1015a6c2c98ac74623d4575ad131);
#
#
#
#         marker_342db7f5c9b3cbe6b3c765369935faf4.bindPopup(popup_dfeb89f1116e0e82074193e4e57d636e)
#         ;
#
#
#
#
#             var marker_4ff18ced9e4f5ec4ffa222546e56d9ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_645c7f88baea6410d6cd1ecc5897da61);
#
#
#         var popup_1a2da5229f99ff36814bd29f181c7938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5cf1c2db4d4016570e9326c68aa3afe = $(`&lt;div id=&quot;html_b5cf1c2db4d4016570e9326c68aa3afe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1a2da5229f99ff36814bd29f181c7938.setContent(html_b5cf1c2db4d4016570e9326c68aa3afe);
#
#
#
#         marker_4ff18ced9e4f5ec4ffa222546e56d9ca.bindPopup(popup_1a2da5229f99ff36814bd29f181c7938)
#         ;
#
#
#
#
#             var marker_e305a4799fd637b52bcc7689fceb2b0d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_645c7f88baea6410d6cd1ecc5897da61);
#
#
#         var popup_d1296210170cdbbefb509d9d0324a965 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b3b810697eb64ab435a913bcb074ca5 = $(`&lt;div id=&quot;html_9b3b810697eb64ab435a913bcb074ca5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d1296210170cdbbefb509d9d0324a965.setContent(html_9b3b810697eb64ab435a913bcb074ca5);
#
#
#
#         marker_e305a4799fd637b52bcc7689fceb2b0d.bindPopup(popup_d1296210170cdbbefb509d9d0324a965)
#         ;
#
#
#
#
#             var marker_f660f9c89ffa5232c8044ca630ca5c2d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_645c7f88baea6410d6cd1ecc5897da61);
#
#
#         var popup_a8835810c32165e6f44996336db56441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ee86bfbfe58884d7e396e34410a1cda = $(`&lt;div id=&quot;html_5ee86bfbfe58884d7e396e34410a1cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a8835810c32165e6f44996336db56441.setContent(html_5ee86bfbfe58884d7e396e34410a1cda);
#
#
#
#         marker_f660f9c89ffa5232c8044ca630ca5c2d.bindPopup(popup_a8835810c32165e6f44996336db56441)
#         ;
#
#
#
#
#             var marker_d63f5dfd58aecc38a5dbf77777d648e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_645c7f88baea6410d6cd1ecc5897da61);
#
#
#         var popup_05a75a8624fcebe60e6850a9e231cef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c53020ab9b62c000eb93f2e4d38fb8e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c53020ab9b62c000eb93f2e4d38fb8e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c53020ab9b62c000eb93f2e4d38fb8e2 = L.map(
#                 &quot;map_c53020ab9b62c000eb93f2e4d38fb8e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd78e6992315861636ee8a05bf14a926 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd78e6992315861636ee8a05bf14a926.addTo(map_c53020ab9b62c000eb93f2e4d38fb8e2);
#
#
#             var feature_group_801b16d3e15c29e72229d7dd7ba54d3b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_801b16d3e15c29e72229d7dd7ba54d3b.addTo(map_c53020ab9b62c000eb93f2e4d38fb8e2);
#
#
#             var feature_group_sub_group_51391d59baff94688b22d1babe515955 = L.featureGroup.subGroup(
#                 feature_group_801b16d3e15c29e72229d7dd7ba54d3b
#             );
#
#
#             var marker_82f7b2f73e28605c86e00febf1c131a8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_51391d59baff94688b22d1babe515955);
#
#
#         var popup_8c6b3dd35b5f07e81bfe0213474add26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c7535e6aa9c2f3fad5c78068a2bc6ea = $(`&lt;div id=&quot;html_3c7535e6aa9c2f3fad5c78068a2bc6ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8c6b3dd35b5f07e81bfe0213474add26.setContent(html_3c7535e6aa9c2f3fad5c78068a2bc6ea);
#
#
#
#         marker_82f7b2f73e28605c86e00febf1c131a8.bindPopup(popup_8c6b3dd35b5f07e81bfe0213474add26)
#         ;
#
#
#
#
#             var marker_d8bd98a0599775df67e36f73cd165f98 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_51391d59baff94688b22d1babe515955);
#
#
#         var popup_812eeabb9f33efb237f4b0d1424aa263 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1545b210b0ff15862521a82c95033cb7 = $(`&lt;div id=&quot;html_1545b210b0ff15862521a82c95033cb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_812eeabb9f33efb237f4b0d1424aa263.setContent(html_1545b210b0ff15862521a82c95033cb7);
#
#
#
#         marker_d8bd98a0599775df67e36f73cd165f98.bindPopup(popup_812eeabb9f33efb237f4b0d1424aa263)
#         ;
#
#
#
#
#             var marker_447ee2f4f04438269a00ff28bc90643e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_51391d59baff94688b22d1babe515955);
#
#
#         var popup_0b750f30d354818ebf69433be2404086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92a3140b3f306cc2a9981884a7149511 = $(`&lt;div id=&quot;html_92a3140b3f306cc2a9981884a7149511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0b750f30d354818ebf69433be2404086.setContent(html_92a3140b3f306cc2a9981884a7149511);
#
#
#
#         marker_447ee2f4f04438269a00ff28bc90643e.bindPopup(popup_0b750f30d354818ebf69433be2404086)
#         ;
#
#
#
#
#             var marker_cb6490bf9699433c3a563e673afb04a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_51391d59baff94688b22d1babe515955);
#
#
#         var popup_e822ee5d062dfd5755665551f4b58f09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf56fd2498417fd1c0c1501b5b9ca59c = $(`&lt;div id=&quot;html_cf56fd2498417fd1c0c1501b5b9ca59c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e822ee5d062dfd5755665551f4b58f09.setContent(html_cf56fd2498417fd1c0c1501b5b9ca59c);
#
#
#
#         marker_
