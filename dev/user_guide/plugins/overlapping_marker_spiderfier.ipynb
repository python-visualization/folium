# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f8f167c601e383aa8980e66931dad24 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f8f167c601e383aa8980e66931dad24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f8f167c601e383aa8980e66931dad24 = L.map(
#                 &quot;map_5f8f167c601e383aa8980e66931dad24&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa9e3f9285b3b4d2a6dff97deb75ffa9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa9e3f9285b3b4d2a6dff97deb75ffa9.addTo(map_5f8f167c601e383aa8980e66931dad24);
#
#
#             var marker_145184c57e3d7f88b3f8728a785d7e3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5f8f167c601e383aa8980e66931dad24);
#
#
#         var popup_f419d974ad27935cc8bb230e94e61115 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6db82f76696283adad998fa7d0477d77 = $(`&lt;div id=&quot;html_6db82f76696283adad998fa7d0477d77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f419d974ad27935cc8bb230e94e61115.setContent(html_6db82f76696283adad998fa7d0477d77);
#
#
#
#         marker_145184c57e3d7f88b3f8728a785d7e3d.bindPopup(popup_f419d974ad27935cc8bb230e94e61115)
#         ;
#
#
#
#
#             var marker_71294790bceee3d61ed01e4af5c7b283 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5f8f167c601e383aa8980e66931dad24);
#
#
#         var popup_88467ee14a032620df6b538708ee3240 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d940cb736d895f3650771e409710e66 = $(`&lt;div id=&quot;html_4d940cb736d895f3650771e409710e66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_88467ee14a032620df6b538708ee3240.setContent(html_4d940cb736d895f3650771e409710e66);
#
#
#
#         marker_71294790bceee3d61ed01e4af5c7b283.bindPopup(popup_88467ee14a032620df6b538708ee3240)
#         ;
#
#
#
#
#             var marker_87370c6fff6205d4e9eeca8e59c63ccf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5f8f167c601e383aa8980e66931dad24);
#
#
#         var popup_035165f9d1319bb123c01059bdb74ce3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a926bad66252253af1f058f3dd49b33 = $(`&lt;div id=&quot;html_5a926bad66252253af1f058f3dd49b33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_035165f9d1319bb123c01059bdb74ce3.setContent(html_5a926bad66252253af1f058f3dd49b33);
#
#
#
#         marker_87370c6fff6205d4e9eeca8e59c63ccf.bindPopup(popup_035165f9d1319bb123c01059bdb74ce3)
#         ;
#
#
#
#
#             var marker_4f8dd2d03cb96468c0cb969a31868f78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5f8f167c601e383aa8980e66931dad24);
#
#
#         var popup_b1f278e8af58fc3c6265f0d0174c398d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3906d331f352d92967679da0943ad810 = $(`&lt;div id=&quot;html_3906d331f352d92967679da0943ad810&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b1f278e8af58fc3c6265f0d0174c398d.setContent(html_3906d331f352d92967679da0943ad810);
#
#
#
#         marker_4f8dd2d03cb96468c0cb969a31868f78.bindPopup(popup_b1f278e8af58fc3c6265f0d0174c398d)
#         ;
#
#
#
#
#             var marker_381bbb56ecc5c81d00cf06f67cf872c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5f8f167c601e383aa8980e66931dad24);
#
#
#         var popup_3bafc1a8b59084a8d73430526d5ffc34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec4e373195f097fbda80b27057e6934a = $(`&lt;div id=&quot;html_ec4e373195f097fbda80b27057e6934a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3bafc1a8b59084a8d73430526d5ffc34.setContent(html_ec4e373195f097fbda80b27057e6934a);
#
#
#
#         marker_381bbb56ecc5c81d00cf06f67cf872c5.bindPopup(popup_3bafc1a8b59084a8d73430526d5ffc34)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baf73ef4de95ee1d4015b15c0d92e659 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baf73ef4de95ee1d4015b15c0d92e659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_baf73ef4de95ee1d4015b15c0d92e659 = L.map(
#                 &quot;map_baf73ef4de95ee1d4015b15c0d92e659&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea185dc8470d4c9120f0f1c10de0b469 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea185dc8470d4c9120f0f1c10de0b469.addTo(map_baf73ef4de95ee1d4015b15c0d92e659);
#
#
#             var feature_group_09939ad5005625201a458c6c010b67eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2f026a5d86f138461d72d6449addc7d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_09939ad5005625201a458c6c010b67eb);
#
#
#         var popup_b77037db1918cdf2eafd580587d5f1fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_614871058a1eb78f4f485a681f62c3cb = $(`&lt;div id=&quot;html_614871058a1eb78f4f485a681f62c3cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b77037db1918cdf2eafd580587d5f1fb.setContent(html_614871058a1eb78f4f485a681f62c3cb);
#
#
#
#         marker_2f026a5d86f138461d72d6449addc7d6.bindPopup(popup_b77037db1918cdf2eafd580587d5f1fb)
#         ;
#
#
#
#
#             var marker_9c7dafe7ccd46ed531dabc01657cff5c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_09939ad5005625201a458c6c010b67eb);
#
#
#         var popup_0c9f65661614a3c97ee9e7d9187dc189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d4fa64c91e04d35ba60d9b5d7a7e887 = $(`&lt;div id=&quot;html_1d4fa64c91e04d35ba60d9b5d7a7e887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0c9f65661614a3c97ee9e7d9187dc189.setContent(html_1d4fa64c91e04d35ba60d9b5d7a7e887);
#
#
#
#         marker_9c7dafe7ccd46ed531dabc01657cff5c.bindPopup(popup_0c9f65661614a3c97ee9e7d9187dc189)
#         ;
#
#
#
#
#             var marker_41ebc0e1186891a1b3ab50a60136a3aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_09939ad5005625201a458c6c010b67eb);
#
#
#         var popup_bc2903ac8daa703f79bf240117a8030d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e555bbc9d8c5a3e3f47541b3befba1a7 = $(`&lt;div id=&quot;html_e555bbc9d8c5a3e3f47541b3befba1a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bc2903ac8daa703f79bf240117a8030d.setContent(html_e555bbc9d8c5a3e3f47541b3befba1a7);
#
#
#
#         marker_41ebc0e1186891a1b3ab50a60136a3aa.bindPopup(popup_bc2903ac8daa703f79bf240117a8030d)
#         ;
#
#
#
#
#             var marker_b9c20bb1cffc754827afcf572a4c8e68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_09939ad5005625201a458c6c010b67eb);
#
#
#         var popup_cd5535bb9cef58c4fdf92cc2bfb15d72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4270f0253e58bc2eee100be8434cd096 = $(`&lt;div id=&quot;html_4270f0253e58bc2eee100be8434cd096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cd5535bb9cef58c4fdf92cc2bfb15d72.setContent(html_4270f0253e58bc2eee100be8434cd096);
#
#
#
#         marker_b9c20bb1cffc754827afcf572a4c8e68.bindPopup(popup_cd5535bb9cef58c4fdf92cc2bfb15d72)
#         ;
#
#
#
#
#             var marker_f844a5d75abd3ab76bc31ec96b094919 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_09939ad5005625201a458c6c010b67eb);
#
#
#         var popup_6d6189236650b9641b2d5d4f324f0a81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c71f7ff949106dfc6c2d371db3553d67 = $(`&lt;div id=&quot;html_c71f7ff949106dfc6c2d371db3553d67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46f5a529bf86101ac7bbb35ad56ab3f5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46f5a529bf86101ac7bbb35ad56ab3f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46f5a529bf86101ac7bbb35ad56ab3f5 = L.map(
#                 &quot;map_46f5a529bf86101ac7bbb35ad56ab3f5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f26fe90aeaef2da1f5891063f71b3691 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f26fe90aeaef2da1f5891063f71b3691.addTo(map_46f5a529bf86101ac7bbb35ad56ab3f5);
#
#
#             var feature_group_4536ae60227ca4632e449fc2679b8950 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4536ae60227ca4632e449fc2679b8950.addTo(map_46f5a529bf86101ac7bbb35ad56ab3f5);
#
#
#             var feature_group_sub_group_a06292df495c201da18f72f769c3e497 = L.featureGroup.subGroup(
#                 feature_group_4536ae60227ca4632e449fc2679b8950
#             );
#
#
#             var marker_f18bf0bbf90fedc0f46deb00f91a5c2c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a06292df495c201da18f72f769c3e497);
#
#
#         var popup_eeb2b9692fd3082287263d8f714e1045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_543830890538e1226d176175a8e974bd = $(`&lt;div id=&quot;html_543830890538e1226d176175a8e974bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eeb2b9692fd3082287263d8f714e1045.setContent(html_543830890538e1226d176175a8e974bd);
#
#
#
#         marker_f18bf0bbf90fedc0f46deb00f91a5c2c.bindPopup(popup_eeb2b9692fd3082287263d8f714e1045)
#         ;
#
#
#
#
#             var marker_717a1dde61bc76b65b8243c31b501b0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a06292df495c201da18f72f769c3e497);
#
#
#         var popup_0ef4c55ba36c08ec400b542cf0924c57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65f367cf879d463a922c16a7296d3b3e = $(`&lt;div id=&quot;html_65f367cf879d463a922c16a7296d3b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0ef4c55ba36c08ec400b542cf0924c57.setContent(html_65f367cf879d463a922c16a7296d3b3e);
#
#
#
#         marker_717a1dde61bc76b65b8243c31b501b0b.bindPopup(popup_0ef4c55ba36c08ec400b542cf0924c57)
#         ;
#
#
#
#
#             var marker_406d7bae7813538b8c56d589010e30ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a06292df495c201da18f72f769c3e497);
#
#
#         var popup_1f368ed3f7ca94b792fa4b5787f19e5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5acce03b3709a459906f8753433b8b9 = $(`&lt;div id=&quot;html_c5acce03b3709a459906f8753433b8b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1f368ed3f7ca94b792fa4b5787f19e5c.setContent(html_c5acce03b3709a459906f8753433b8b9);
#
#
#
#         marker_406d7bae7813538b8c56d589010e30ac.bindPopup(popup_1f368ed3f7ca94b792fa4b5787f19e5c)
#         ;
#
#
#
#
#             var marker_65dba3396629a89a0e7e46a09f44b23b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a06292df495c201da18f72f769c3e497);
#
#
#         var popup_2f6e16885e4f693562554c3907dfcbe2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8e8cf54e07e30d7edabb5dce6221dae = $(`&lt;div id=&quot;html_e8e8cf54e07e30d7edabb5dce6221dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2f6e16885e4f693562554c3907dfcbe2.setContent(html_e8e8cf54e07e30d7edabb5dce6221dae);
#
#
#
#         marker_65dba3396629a89a0e7e46a09f44b23b.bindPopup(popup_2f6e16885e4f693562554c3907dfcbe2)
#         ;
#
#
#
#
#             var marker_9d12b91694dd1b22a7e9d0d9cc37e8f1 = L.marker(
#                 [45.0503999
