# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5de9e4f894c0f18198d530f61308e81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5de9e4f894c0f18198d530f61308e81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5de9e4f894c0f18198d530f61308e81 = L.map(
#                 &quot;map_f5de9e4f894c0f18198d530f61308e81&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_501194d765e06e522ed426d33b676940 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_501194d765e06e522ed426d33b676940.addTo(map_f5de9e4f894c0f18198d530f61308e81);
#
#
#             var marker_61fdf38c2cd3d716c7e4c5a5d63c8ed2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f5de9e4f894c0f18198d530f61308e81);
#
#
#         var popup_af9e57a337c1ee80b84665b542cb31f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c3e122fd948ef159746834ad6c2827c = $(`&lt;div id=&quot;html_5c3e122fd948ef159746834ad6c2827c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_af9e57a337c1ee80b84665b542cb31f8.setContent(html_5c3e122fd948ef159746834ad6c2827c);
#
#
#
#         marker_61fdf38c2cd3d716c7e4c5a5d63c8ed2.bindPopup(popup_af9e57a337c1ee80b84665b542cb31f8)
#         ;
#
#
#
#
#             var marker_b4e11d17eea9f735b858cbaaf162cbd3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f5de9e4f894c0f18198d530f61308e81);
#
#
#         var popup_e412790f1d8332787a66148a9d2d82bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eebb07c555e91b89c3a7ada835185fd = $(`&lt;div id=&quot;html_6eebb07c555e91b89c3a7ada835185fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e412790f1d8332787a66148a9d2d82bf.setContent(html_6eebb07c555e91b89c3a7ada835185fd);
#
#
#
#         marker_b4e11d17eea9f735b858cbaaf162cbd3.bindPopup(popup_e412790f1d8332787a66148a9d2d82bf)
#         ;
#
#
#
#
#             var marker_3874192701b81c4839c6919ebd153f7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f5de9e4f894c0f18198d530f61308e81);
#
#
#         var popup_2af8c4713bc985ce7b9f15f96e38efa2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cfd8676e9956f40a414e8832897abe9 = $(`&lt;div id=&quot;html_8cfd8676e9956f40a414e8832897abe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2af8c4713bc985ce7b9f15f96e38efa2.setContent(html_8cfd8676e9956f40a414e8832897abe9);
#
#
#
#         marker_3874192701b81c4839c6919ebd153f7c.bindPopup(popup_2af8c4713bc985ce7b9f15f96e38efa2)
#         ;
#
#
#
#
#             var marker_fcd30bf779c0172acbf2c88b0670a0cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f5de9e4f894c0f18198d530f61308e81);
#
#
#         var popup_205148bab798d79662c8af9973bdb223 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d4c66ee341e5899a27d9489a64fdb9d = $(`&lt;div id=&quot;html_0d4c66ee341e5899a27d9489a64fdb9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_205148bab798d79662c8af9973bdb223.setContent(html_0d4c66ee341e5899a27d9489a64fdb9d);
#
#
#
#         marker_fcd30bf779c0172acbf2c88b0670a0cd.bindPopup(popup_205148bab798d79662c8af9973bdb223)
#         ;
#
#
#
#
#             var marker_98f1f7300092cb7482cb4c49b4c48e37 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f5de9e4f894c0f18198d530f61308e81);
#
#
#         var popup_b180422574072c234846d8544b2a5b65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fea7eb296d8a30acb902dba00aa5cbdf = $(`&lt;div id=&quot;html_fea7eb296d8a30acb902dba00aa5cbdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b180422574072c234846d8544b2a5b65.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e27ef766aeccc6af8b809c575c4fded {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e27ef766aeccc6af8b809c575c4fded&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e27ef766aeccc6af8b809c575c4fded = L.map(
#                 &quot;map_4e27ef766aeccc6af8b809c575c4fded&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c71209c61fe69ca8542ec8623882532 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c71209c61fe69ca8542ec8623882532.addTo(map_4e27ef766aeccc6af8b809c575c4fded);
#
#
#             var feature_group_956a14dc00c42710d31247c1601ae6ff = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4092a44dea3e860aeda0aabc56f7873e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_956a14dc00c42710d31247c1601ae6ff);
#
#
#         var popup_6ea8e64f5f0e6f2ba8e50328ecfa23a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a20dc32805dccd7777215234b7990d2d = $(`&lt;div id=&quot;html_a20dc32805dccd7777215234b7990d2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6ea8e64f5f0e6f2ba8e50328ecfa23a2.setContent(html_a20dc32805dccd7777215234b7990d2d);
#
#
#
#         marker_4092a44dea3e860aeda0aabc56f7873e.bindPopup(popup_6ea8e64f5f0e6f2ba8e50328ecfa23a2)
#         ;
#
#
#
#
#             var marker_7e798a15cb6f9edd2ed6a4600bb1f304 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_956a14dc00c42710d31247c1601ae6ff);
#
#
#         var popup_90225366127639e676535ff26a94be97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6003104cfe31448c843aec08bbcfdc47 = $(`&lt;div id=&quot;html_6003104cfe31448c843aec08bbcfdc47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_90225366127639e676535ff26a94be97.setContent(html_6003104cfe31448c843aec08bbcfdc47);
#
#
#
#         marker_7e798a15cb6f9edd2ed6a4600bb1f304.bindPopup(popup_90225366127639e676535ff26a94be97)
#         ;
#
#
#
#
#             var marker_8d8e9ffa82ba6ac154fd492d27b51a7a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_956a14dc00c42710d31247c1601ae6ff);
#
#
#         var popup_f132a7374de68e6062252a50454f7614 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a7bd68037bc7e4d11047dd93c1e318b = $(`&lt;div id=&quot;html_0a7bd68037bc7e4d11047dd93c1e318b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f132a7374de68e6062252a50454f7614.setContent(html_0a7bd68037bc7e4d11047dd93c1e318b);
#
#
#
#         marker_8d8e9ffa82ba6ac154fd492d27b51a7a.bindPopup(popup_f132a7374de68e6062252a50454f7614)
#         ;
#
#
#
#
#             var marker_a53bde030084fbbd0a8e99a3ad060e41 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_956a14dc00c42710d31247c1601ae6ff);
#
#
#         var popup_1f93a8ac6c539904456a207a153b7833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea7dc8c7ab86396722143a5dc6951679 = $(`&lt;div id=&quot;html_ea7dc8c7ab86396722143a5dc6951679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1f93a8ac6c539904456a207a153b7833.setContent(html_ea7dc8c7ab86396722143a5dc6951679);
#
#
#
#         marker_a53bde030084fbbd0a8e99a3ad060e41.bindPopup(popup_1f93a8ac6c539904456a207a153b7833)
#         ;
#
#
#
#
#             var marker_ae01c1088de2e1b4d965c0c07e02809a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_956a14dc00c42710d31247c1601ae6ff);
#
#
#         var popup_dd754027707b84600cfdc83972e24e2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec6082323d2da1c0abdfd12306ed3992 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec6082323d2da1c0abdfd12306ed3992&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec6082323d2da1c0abdfd12306ed3992 = L.map(
#                 &quot;map_ec6082323d2da1c0abdfd12306ed3992&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ab7ab50ca2da758d4b31e685abe9ca1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ab7ab50ca2da758d4b31e685abe9ca1.addTo(map_ec6082323d2da1c0abdfd12306ed3992);
#
#
#             var feature_group_94a91cd951a4ae5ee9956682a118b122 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_94a91cd951a4ae5ee9956682a118b122.addTo(map_ec6082323d2da1c0abdfd12306ed3992);
#
#
#             var feature_group_sub_group_45f8de805282373aa045dfd9948574fe = L.featureGroup.subGroup(
#                 feature_group_94a91cd951a4ae5ee9956682a118b122
#             );
#
#
#             var marker_f92ec71fea80c438cb0ee5431a9a70eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_45f8de805282373aa045dfd9948574fe);
#
#
#         var popup_acb435c480fdc5d9d99ed60cbcbb6dd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b459c60399cb9a396ed35e4280e954a = $(`&lt;div id=&quot;html_3b459c60399cb9a396ed35e4280e954a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_acb435c480fdc5d9d99ed60cbcbb6dd1.setContent(html_3b459c60399cb9a396ed35e4280e954a);
#
#
#
#         marker_f92ec71fea80c438cb0ee5431a9a70eb.bindPopup(popup_acb435c480fdc5d9d99ed60cbcbb6dd1)
#         ;
#
#
#
#
#             var marker_0b13707efb47616be8bec936234cbc18 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_45f8de805282373aa045dfd9948574fe);
#
#
#         var popup_2353b4a9578073a0470445d927a37e00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bff82ae57a61f1bffbd3a242a239436c = $(`&lt;div id=&quot;html_bff82ae57a61f1bffbd3a242a239436c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2353b4a9578073a0470445d927a37e00.setContent(html_bff82ae57a61f1bffbd3a242a239436c);
#
#
#
#         marker_0b13707efb47616be8bec936234cbc18.bindPopup(popup_2353b4a9578073a0470445d927a37e00)
#         ;
#
#
#
#
#             var marker_ccc5bad947a50c6ac2843a02bbe3d0d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_45f8de805282373aa045dfd9948574fe);
#
#
#         var popup_89e0d2058f4ed600863017291245fd1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f6490aba291b4695f69db2f44071767 = $(`&lt;div id=&quot;html_6f6490aba291b4695f69db2f44071767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_89e0d2058f4ed600863017291245fd1c.setContent(html_6f6490aba291b4695f69db2f44071767);
#
#
#
#         marker_ccc5bad947a50c6ac2843a02bbe3d0d9.bindPopup(popup_89e0d2058f4ed600863017291245fd1c)
#         ;
#
#
#
#
#             var marker_1a078d08e4eb80c3d3627354e06dda40 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_45f8de805282373aa045dfd9948574fe);
#
#
#         var popup_e8245ecd9e599c0a5372fbe166ff0a8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98fb8bd50f20d6b3fa31f7890414e30c = $(`&lt;div id=&quot;html_98fb8bd50f20d6b3fa31f7890414e30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e8245ecd9e599c0a5372fbe166ff0a8c.setContent(html_98fb8bd50f20d6b3fa31f7890414e30c);
#
#
#
#         marker_
