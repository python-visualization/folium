# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_738715adfb622e8d78e1c8fcb65b0147 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_738715adfb622e8d78e1c8fcb65b0147&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_738715adfb622e8d78e1c8fcb65b0147 = L.map(
#                 &quot;map_738715adfb622e8d78e1c8fcb65b0147&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbf650eded4a6ccf570b89190864c3fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fbf650eded4a6ccf570b89190864c3fa.addTo(map_738715adfb622e8d78e1c8fcb65b0147);
#
#
#             var marker_a8fde46332252b17a2d4c72baae8040c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_738715adfb622e8d78e1c8fcb65b0147);
#
#
#         var popup_a7d362c686b5799c4d86903482da6a83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f7b0ee11354ce29a1c658be48ee791 = $(`&lt;div id=&quot;html_85f7b0ee11354ce29a1c658be48ee791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a7d362c686b5799c4d86903482da6a83.setContent(html_85f7b0ee11354ce29a1c658be48ee791);
#
#
#
#         marker_a8fde46332252b17a2d4c72baae8040c.bindPopup(popup_a7d362c686b5799c4d86903482da6a83)
#         ;
#
#
#
#
#             var marker_6f2e82768ad3b7e3dec2f8568e0635c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_738715adfb622e8d78e1c8fcb65b0147);
#
#
#         var popup_ece4ed5aa0a6766b77f9f13b0e65a1af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_542c2181ce65528a7115d38ab267f631 = $(`&lt;div id=&quot;html_542c2181ce65528a7115d38ab267f631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ece4ed5aa0a6766b77f9f13b0e65a1af.setContent(html_542c2181ce65528a7115d38ab267f631);
#
#
#
#         marker_6f2e82768ad3b7e3dec2f8568e0635c9.bindPopup(popup_ece4ed5aa0a6766b77f9f13b0e65a1af)
#         ;
#
#
#
#
#             var marker_082651aeb5fc44c5cd6a7f7d29e4f62f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_738715adfb622e8d78e1c8fcb65b0147);
#
#
#         var popup_73d77114d2311a123378d2ddf798dcc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71428a243c6ef081c5b8483d7eb184eb = $(`&lt;div id=&quot;html_71428a243c6ef081c5b8483d7eb184eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_73d77114d2311a123378d2ddf798dcc0.setContent(html_71428a243c6ef081c5b8483d7eb184eb);
#
#
#
#         marker_082651aeb5fc44c5cd6a7f7d29e4f62f.bindPopup(popup_73d77114d2311a123378d2ddf798dcc0)
#         ;
#
#
#
#
#             var marker_f95570a86f464df05201b8a487e37332 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_738715adfb622e8d78e1c8fcb65b0147);
#
#
#         var popup_c2aff8e4eef19c0e2e3f06247e6189fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ee31efd89b9dd9ee92520b8b9bb7a89 = $(`&lt;div id=&quot;html_1ee31efd89b9dd9ee92520b8b9bb7a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c2aff8e4eef19c0e2e3f06247e6189fa.setContent(html_1ee31efd89b9dd9ee92520b8b9bb7a89);
#
#
#
#         marker_f95570a86f464df05201b8a487e37332.bindPopup(popup_c2aff8e4eef19c0e2e3f06247e6189fa)
#         ;
#
#
#
#
#             var marker_6ca7e11b7e8395c486e4539f37f98054 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_738715adfb622e8d78e1c8fcb65b0147);
#
#
#         var popup_a19e1275be07c9762ab3a2db9b82698d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3285cc0b7bfee190cb6b6f8d51a1f55 = $(`&lt;div id=&quot;html_a3285cc0b7bfee190cb6b6f8d51a1f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a19e1275be07c9762ab3a2db9b82698d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c3c11150d235b6f76704b349cd89de8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c3c11150d235b6f76704b349cd89de8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c3c11150d235b6f76704b349cd89de8 = L.map(
#                 &quot;map_5c3c11150d235b6f76704b349cd89de8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a1f88630c737039321da0d7f2e794d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a1f88630c737039321da0d7f2e794d2.addTo(map_5c3c11150d235b6f76704b349cd89de8);
#
#
#             var feature_group_a62f619d9560a83e2cb7b5d42619e7b2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_18dca059e016adabb83b8bfa9935e7f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a62f619d9560a83e2cb7b5d42619e7b2);
#
#
#         var popup_d6dfd2a66cc8134e3fd4b1c17541ba62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1a45fba2d52b6ba49c4b7afa589384c = $(`&lt;div id=&quot;html_d1a45fba2d52b6ba49c4b7afa589384c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d6dfd2a66cc8134e3fd4b1c17541ba62.setContent(html_d1a45fba2d52b6ba49c4b7afa589384c);
#
#
#
#         marker_18dca059e016adabb83b8bfa9935e7f4.bindPopup(popup_d6dfd2a66cc8134e3fd4b1c17541ba62)
#         ;
#
#
#
#
#             var marker_02d40e9b344bdce9624ad486d40d9ef2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a62f619d9560a83e2cb7b5d42619e7b2);
#
#
#         var popup_6246fb9fab41ef19f0f8c30735b15ac7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d9ccedd1cf44d1ac2cf34af15215599 = $(`&lt;div id=&quot;html_6d9ccedd1cf44d1ac2cf34af15215599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6246fb9fab41ef19f0f8c30735b15ac7.setContent(html_6d9ccedd1cf44d1ac2cf34af15215599);
#
#
#
#         marker_02d40e9b344bdce9624ad486d40d9ef2.bindPopup(popup_6246fb9fab41ef19f0f8c30735b15ac7)
#         ;
#
#
#
#
#             var marker_f0caa52ce87df94528a63ddc7b4ead9c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a62f619d9560a83e2cb7b5d42619e7b2);
#
#
#         var popup_8372b96bf907fbae149f7b187d0ca695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cd9d1aa6712c4e237245befa21d67bd = $(`&lt;div id=&quot;html_7cd9d1aa6712c4e237245befa21d67bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8372b96bf907fbae149f7b187d0ca695.setContent(html_7cd9d1aa6712c4e237245befa21d67bd);
#
#
#
#         marker_f0caa52ce87df94528a63ddc7b4ead9c.bindPopup(popup_8372b96bf907fbae149f7b187d0ca695)
#         ;
#
#
#
#
#             var marker_de86920dd4aa643f8405054a62d57fcd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a62f619d9560a83e2cb7b5d42619e7b2);
#
#
#         var popup_023b24160f3806db2bb938a48f6b1bdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cfeec2c1e5294a4f6a5aee7a0c6cf50 = $(`&lt;div id=&quot;html_6cfeec2c1e5294a4f6a5aee7a0c6cf50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_023b24160f3806db2bb938a48f6b1bdc.setContent(html_6cfeec2c1e5294a4f6a5aee7a0c6cf50);
#
#
#
#         marker_de86920dd4aa643f8405054a62d57fcd.bindPopup(popup_023b24160f3806db2bb938a48f6b1bdc)
#         ;
#
#
#
#
#             var marker_74f86cdd59ace0a7208a6dde062638bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a62f619d9560a83e2cb7b5d42619e7b2);
#
#
#         var popup_cbd26c4c5a25f8f2026ca085a1d5acf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd948a24acf3dcbbb4b29692cbc500bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd948a24acf3dcbbb4b29692cbc500bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd948a24acf3dcbbb4b29692cbc500bf = L.map(
#                 &quot;map_dd948a24acf3dcbbb4b29692cbc500bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_904ffb8f68aa50c978b02fcd2f6d0608 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_904ffb8f68aa50c978b02fcd2f6d0608.addTo(map_dd948a24acf3dcbbb4b29692cbc500bf);
#
#
#             var feature_group_2fe126d0e8acadae54300404edb84fb0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2fe126d0e8acadae54300404edb84fb0.addTo(map_dd948a24acf3dcbbb4b29692cbc500bf);
#
#
#             var feature_group_sub_group_5b6848b625b149e7497be72a36264908 = L.featureGroup.subGroup(
#                 feature_group_2fe126d0e8acadae54300404edb84fb0
#             );
#
#
#             var marker_626e321c3a39fab5461f4656e579fd0a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b6848b625b149e7497be72a36264908);
#
#
#         var popup_478d6f2cebcf4e53ed1c8f271b75becd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_146079a6ec7d83f80d14f1013039682f = $(`&lt;div id=&quot;html_146079a6ec7d83f80d14f1013039682f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_478d6f2cebcf4e53ed1c8f271b75becd.setContent(html_146079a6ec7d83f80d14f1013039682f);
#
#
#
#         marker_626e321c3a39fab5461f4656e579fd0a.bindPopup(popup_478d6f2cebcf4e53ed1c8f271b75becd)
#         ;
#
#
#
#
#             var marker_e1beda938f6b1486852d7f3239f967d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b6848b625b149e7497be72a36264908);
#
#
#         var popup_8142f6f5ce0e4daca95dc11277c0eb0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f6b9aaff996068e6305e9df9e846e12 = $(`&lt;div id=&quot;html_2f6b9aaff996068e6305e9df9e846e12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8142f6f5ce0e4daca95dc11277c0eb0e.setContent(html_2f6b9aaff996068e6305e9df9e846e12);
#
#
#
#         marker_e1beda938f6b1486852d7f3239f967d7.bindPopup(popup_8142f6f5ce0e4daca95dc11277c0eb0e)
#         ;
#
#
#
#
#             var marker_662ac241c68d03a1bcea4ee04fb0f447 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b6848b625b149e7497be72a36264908);
#
#
#         var popup_d23e929119c068f9bdca7f1d637c5050 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d906344e214e0271623e131d30521351 = $(`&lt;div id=&quot;html_d906344e214e0271623e131d30521351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d23e929119c068f9bdca7f1d637c5050.setContent(html_d906344e214e0271623e131d30521351);
#
#
#
#         marker_662ac241c68d03a1bcea4ee04fb0f447.bindPopup(popup_d23e929119c068f9bdca7f1d637c5050)
#         ;
#
#
#
#
#             var marker_b992ec3883bf5cc282c1f93d572643bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b6848b625b149e7497be72a36264908);
#
#
#         var popup_27b682ec2e77ffaf7c11634d9e7b3f91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcbe1c7dad2df39d1ac712bb443003cc = $(`&lt;div id=&quot;html_dcbe1c7dad2df39d1ac712bb443003cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_27b682ec2e77ffaf7c11634d9e7b3f91.setContent(html_dcbe1c7dad2df39d1ac712bb443003cc);
#
#
#
#         marker_
