# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7ece5f399823b1efc90b6ff46918cf9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7ece5f399823b1efc90b6ff46918cf9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7ece5f399823b1efc90b6ff46918cf9 = L.map(
#                 &quot;map_e7ece5f399823b1efc90b6ff46918cf9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1be46b288a6a802c7aeced5c54727a8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1be46b288a6a802c7aeced5c54727a8b.addTo(map_e7ece5f399823b1efc90b6ff46918cf9);
#
#
#             var marker_5162bb17abf69bcc1e39cb3b11087ca1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e7ece5f399823b1efc90b6ff46918cf9);
#
#
#         var popup_f626738a975c2462fe7ab4e552d3d50e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49ffce936e4af7459873d66de5e32ed2 = $(`&lt;div id=&quot;html_49ffce936e4af7459873d66de5e32ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f626738a975c2462fe7ab4e552d3d50e.setContent(html_49ffce936e4af7459873d66de5e32ed2);
#
#
#
#         marker_5162bb17abf69bcc1e39cb3b11087ca1.bindPopup(popup_f626738a975c2462fe7ab4e552d3d50e)
#         ;
#
#
#
#
#             var marker_acb1a17d7d38d9910d5a2a114b586510 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e7ece5f399823b1efc90b6ff46918cf9);
#
#
#         var popup_b4d046c3a64126cf6b3746e84bff33dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cb45c7382d3a9cacba2ca66f2d984d7 = $(`&lt;div id=&quot;html_6cb45c7382d3a9cacba2ca66f2d984d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b4d046c3a64126cf6b3746e84bff33dd.setContent(html_6cb45c7382d3a9cacba2ca66f2d984d7);
#
#
#
#         marker_acb1a17d7d38d9910d5a2a114b586510.bindPopup(popup_b4d046c3a64126cf6b3746e84bff33dd)
#         ;
#
#
#
#
#             var marker_aea75b0db3092db51a0c81ed33139faa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e7ece5f399823b1efc90b6ff46918cf9);
#
#
#         var popup_009826741abb05ad14e0b223f700b3a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ef9a00e671b894f973f870fd8a39297 = $(`&lt;div id=&quot;html_4ef9a00e671b894f973f870fd8a39297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_009826741abb05ad14e0b223f700b3a9.setContent(html_4ef9a00e671b894f973f870fd8a39297);
#
#
#
#         marker_aea75b0db3092db51a0c81ed33139faa.bindPopup(popup_009826741abb05ad14e0b223f700b3a9)
#         ;
#
#
#
#
#             var marker_d795303262b694718d4d7772438b0e76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e7ece5f399823b1efc90b6ff46918cf9);
#
#
#         var popup_8e9e0b88638bed400fcfba752389071e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_983a0491bd615e055e28a4946a8a4deb = $(`&lt;div id=&quot;html_983a0491bd615e055e28a4946a8a4deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8e9e0b88638bed400fcfba752389071e.setContent(html_983a0491bd615e055e28a4946a8a4deb);
#
#
#
#         marker_d795303262b694718d4d7772438b0e76.bindPopup(popup_8e9e0b88638bed400fcfba752389071e)
#         ;
#
#
#
#
#             var marker_ea19f78449eecb53a252bad235fdc2e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e7ece5f399823b1efc90b6ff46918cf9);
#
#
#         var popup_32ba44705138dc82c5c22f180f02e332 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f45b5be3d98e42a1e77b0572a2c2b56 = $(`&lt;div id=&quot;html_9f45b5be3d98e42a1e77b0572a2c2b56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_32ba44705138dc82c5c22f180f02e332.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db537968c055658173066e998258c0e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db537968c055658173066e998258c0e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db537968c055658173066e998258c0e4 = L.map(
#                 &quot;map_db537968c055658173066e998258c0e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efb25a799cc4d2c6a28de58eca8f974d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efb25a799cc4d2c6a28de58eca8f974d.addTo(map_db537968c055658173066e998258c0e4);
#
#
#             var feature_group_88c29cdc373b7eac0cd60c2aa0a5ac91 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1266aede88b2526c2023a0dd15bd6dc6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_88c29cdc373b7eac0cd60c2aa0a5ac91);
#
#
#         var popup_d547063dcbe59d991be08a9741a08395 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aed6383e5bb9044e96e7ddd7d1191499 = $(`&lt;div id=&quot;html_aed6383e5bb9044e96e7ddd7d1191499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d547063dcbe59d991be08a9741a08395.setContent(html_aed6383e5bb9044e96e7ddd7d1191499);
#
#
#
#         marker_1266aede88b2526c2023a0dd15bd6dc6.bindPopup(popup_d547063dcbe59d991be08a9741a08395)
#         ;
#
#
#
#
#             var marker_2e47317d613cf6e2ab81e7bdc9fd48a2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_88c29cdc373b7eac0cd60c2aa0a5ac91);
#
#
#         var popup_386caa33f817ef714b99d8072bad077c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e17fa46497efa529516197065abf621 = $(`&lt;div id=&quot;html_1e17fa46497efa529516197065abf621&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_386caa33f817ef714b99d8072bad077c.setContent(html_1e17fa46497efa529516197065abf621);
#
#
#
#         marker_2e47317d613cf6e2ab81e7bdc9fd48a2.bindPopup(popup_386caa33f817ef714b99d8072bad077c)
#         ;
#
#
#
#
#             var marker_0780613934f3d802eaed252885aeead2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_88c29cdc373b7eac0cd60c2aa0a5ac91);
#
#
#         var popup_97bee7cacceb95f157fe64c20875b8c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7e8cf1c43a76c0eff2ff5684204868c = $(`&lt;div id=&quot;html_c7e8cf1c43a76c0eff2ff5684204868c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_97bee7cacceb95f157fe64c20875b8c5.setContent(html_c7e8cf1c43a76c0eff2ff5684204868c);
#
#
#
#         marker_0780613934f3d802eaed252885aeead2.bindPopup(popup_97bee7cacceb95f157fe64c20875b8c5)
#         ;
#
#
#
#
#             var marker_f5154a9d4813b8d30b0d87a1dd994429 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_88c29cdc373b7eac0cd60c2aa0a5ac91);
#
#
#         var popup_7e6670cf1f11d6883e88d6edee5f272f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a69dd892c1861084562665ca2a582e94 = $(`&lt;div id=&quot;html_a69dd892c1861084562665ca2a582e94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7e6670cf1f11d6883e88d6edee5f272f.setContent(html_a69dd892c1861084562665ca2a582e94);
#
#
#
#         marker_f5154a9d4813b8d30b0d87a1dd994429.bindPopup(popup_7e6670cf1f11d6883e88d6edee5f272f)
#         ;
#
#
#
#
#             var marker_987b572030de669804755f1514450ec6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_88c29cdc373b7eac0cd60c2aa0a5ac91);
#
#
#         var popup_e4dccc82a58b7a7b8477c16250d6ac59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01899430180d1fb0112ebda6431e52cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01899430180d1fb0112ebda6431e52cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01899430180d1fb0112ebda6431e52cd = L.map(
#                 &quot;map_01899430180d1fb0112ebda6431e52cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a0c3535bd1dc1b6edac45fb11f42572 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a0c3535bd1dc1b6edac45fb11f42572.addTo(map_01899430180d1fb0112ebda6431e52cd);
#
#
#             var feature_group_0c8a9778f305e58f3c1d95c5303daf77 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0c8a9778f305e58f3c1d95c5303daf77.addTo(map_01899430180d1fb0112ebda6431e52cd);
#
#
#             var feature_group_sub_group_8b88ac1ed531bc60415f0a89b8ec2d13 = L.featureGroup.subGroup(
#                 feature_group_0c8a9778f305e58f3c1d95c5303daf77
#             );
#
#
#             var marker_c91613edcac2e91003fa7c6fae261e45 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b88ac1ed531bc60415f0a89b8ec2d13);
#
#
#         var popup_cc39b7ffda9f92c22fd5aec031f9de09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f52e79ab1d9f4695a4bf2de0176b0d82 = $(`&lt;div id=&quot;html_f52e79ab1d9f4695a4bf2de0176b0d82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cc39b7ffda9f92c22fd5aec031f9de09.setContent(html_f52e79ab1d9f4695a4bf2de0176b0d82);
#
#
#
#         marker_c91613edcac2e91003fa7c6fae261e45.bindPopup(popup_cc39b7ffda9f92c22fd5aec031f9de09)
#         ;
#
#
#
#
#             var marker_5b725e60665c49ad0f56c443bffb1b72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b88ac1ed531bc60415f0a89b8ec2d13);
#
#
#         var popup_5a95e7959b83a07c17dca26256afda2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82a5f92313f4bca2286bd0048e4dc85e = $(`&lt;div id=&quot;html_82a5f92313f4bca2286bd0048e4dc85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5a95e7959b83a07c17dca26256afda2d.setContent(html_82a5f92313f4bca2286bd0048e4dc85e);
#
#
#
#         marker_5b725e60665c49ad0f56c443bffb1b72.bindPopup(popup_5a95e7959b83a07c17dca26256afda2d)
#         ;
#
#
#
#
#             var marker_a1416f95c5c8dd9d93175454f68c86dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b88ac1ed531bc60415f0a89b8ec2d13);
#
#
#         var popup_af1dfdd41885f8d5f03325eae8972e7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7fc93ff17e0aa6c83d9bd5ba4fce873 = $(`&lt;div id=&quot;html_b7fc93ff17e0aa6c83d9bd5ba4fce873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af1dfdd41885f8d5f03325eae8972e7e.setContent(html_b7fc93ff17e0aa6c83d9bd5ba4fce873);
#
#
#
#         marker_a1416f95c5c8dd9d93175454f68c86dc.bindPopup(popup_af1dfdd41885f8d5f03325eae8972e7e)
#         ;
#
#
#
#
#             var marker_6e420a37120ac4dc81d0270db043fe1e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b88ac1ed531bc60415f0a89b8ec2d13);
#
#
#         var popup_5f699bb77340d4c13b633c7052838672 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f49552cbadc312c4d1519d5e359b8268 = $(`&lt;div id=&quot;html_f49552cbadc312c4d1519d5e359b8268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5f699bb77340d4c13b633c7052838672.setContent(html_f49552cbadc312c4d1519d5e359b8268);
#
#
#
#         marker_
