# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d6f6ca89d39c382ec25cdc84569e9f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d6f6ca89d39c382ec25cdc84569e9f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d6f6ca89d39c382ec25cdc84569e9f0 = L.map(
#                 &quot;map_6d6f6ca89d39c382ec25cdc84569e9f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fcd94a8e377092c834a9f1016b6df7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fcd94a8e377092c834a9f1016b6df7d.addTo(map_6d6f6ca89d39c382ec25cdc84569e9f0);
#
#
#             var marker_999b5c4025e07164e22bf9acae6fe165 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6d6f6ca89d39c382ec25cdc84569e9f0);
#
#
#         var popup_2292278bbd5a0d7963e04da1b22c5ae6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7377517319d210fd7c0ed951812f851 = $(`&lt;div id=&quot;html_d7377517319d210fd7c0ed951812f851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2292278bbd5a0d7963e04da1b22c5ae6.setContent(html_d7377517319d210fd7c0ed951812f851);
#
#
#
#         marker_999b5c4025e07164e22bf9acae6fe165.bindPopup(popup_2292278bbd5a0d7963e04da1b22c5ae6)
#         ;
#
#
#
#
#             var marker_4595d6293f38f1848ddcaa8c7c57b889 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6d6f6ca89d39c382ec25cdc84569e9f0);
#
#
#         var popup_e1c449fa4a88ca115216eb865337843a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1747f4de75a92730af70151bd892a68f = $(`&lt;div id=&quot;html_1747f4de75a92730af70151bd892a68f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e1c449fa4a88ca115216eb865337843a.setContent(html_1747f4de75a92730af70151bd892a68f);
#
#
#
#         marker_4595d6293f38f1848ddcaa8c7c57b889.bindPopup(popup_e1c449fa4a88ca115216eb865337843a)
#         ;
#
#
#
#
#             var marker_30833273b0a140fb03bd5f2cdb4c8541 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6d6f6ca89d39c382ec25cdc84569e9f0);
#
#
#         var popup_8319dc903eca712863b68d846fee7b05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f051f1c35686ef6b7b871ca458b5dc0 = $(`&lt;div id=&quot;html_2f051f1c35686ef6b7b871ca458b5dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8319dc903eca712863b68d846fee7b05.setContent(html_2f051f1c35686ef6b7b871ca458b5dc0);
#
#
#
#         marker_30833273b0a140fb03bd5f2cdb4c8541.bindPopup(popup_8319dc903eca712863b68d846fee7b05)
#         ;
#
#
#
#
#             var marker_12a4faca804e91d60cfaac5a4d2678b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6d6f6ca89d39c382ec25cdc84569e9f0);
#
#
#         var popup_1dca2fd9ccc40e29c28c866e3f2e31b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e6cf872dd3c7d791b595c4ac98a5d47 = $(`&lt;div id=&quot;html_0e6cf872dd3c7d791b595c4ac98a5d47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1dca2fd9ccc40e29c28c866e3f2e31b3.setContent(html_0e6cf872dd3c7d791b595c4ac98a5d47);
#
#
#
#         marker_12a4faca804e91d60cfaac5a4d2678b1.bindPopup(popup_1dca2fd9ccc40e29c28c866e3f2e31b3)
#         ;
#
#
#
#
#             var marker_7efaa1d157878f1a8dfbfd79e2a32c25 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6d6f6ca89d39c382ec25cdc84569e9f0);
#
#
#         var popup_b0476fbb34ce747e8c3aa7fc423d6ab7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0717b98d4b8a51fed9e11f2df5bdc663 = $(`&lt;div id=&quot;html_0717b98d4b8a51fed9e11f2df5bdc663&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b0476fbb34ce747e8c3aa7fc423d6ab7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9815057035439e4a7f6dee5329fd0c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9815057035439e4a7f6dee5329fd0c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9815057035439e4a7f6dee5329fd0c3 = L.map(
#                 &quot;map_b9815057035439e4a7f6dee5329fd0c3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3241a8a0e95fcd95e44aeff42bf9d6b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3241a8a0e95fcd95e44aeff42bf9d6b3.addTo(map_b9815057035439e4a7f6dee5329fd0c3);
#
#
#             var feature_group_d4f84b8d303140f2b11ab169ba9e4175 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_922fda58ce5d8e60895cd87bad62aeaf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d4f84b8d303140f2b11ab169ba9e4175);
#
#
#         var popup_b1de7b4db53a76b859de1e6d2435dbc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cda651e3ab9ea6e1ca623942d1f14d08 = $(`&lt;div id=&quot;html_cda651e3ab9ea6e1ca623942d1f14d08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b1de7b4db53a76b859de1e6d2435dbc8.setContent(html_cda651e3ab9ea6e1ca623942d1f14d08);
#
#
#
#         marker_922fda58ce5d8e60895cd87bad62aeaf.bindPopup(popup_b1de7b4db53a76b859de1e6d2435dbc8)
#         ;
#
#
#
#
#             var marker_7b2fcc1198954e3208ce4eb5d288b2ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d4f84b8d303140f2b11ab169ba9e4175);
#
#
#         var popup_b7ce3dd4cc435baf894dfcd0a136bb60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98f4a949fc78762f207e16e4300f5658 = $(`&lt;div id=&quot;html_98f4a949fc78762f207e16e4300f5658&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b7ce3dd4cc435baf894dfcd0a136bb60.setContent(html_98f4a949fc78762f207e16e4300f5658);
#
#
#
#         marker_7b2fcc1198954e3208ce4eb5d288b2ac.bindPopup(popup_b7ce3dd4cc435baf894dfcd0a136bb60)
#         ;
#
#
#
#
#             var marker_60702c77beb9f4f1a1aad8992298f38b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d4f84b8d303140f2b11ab169ba9e4175);
#
#
#         var popup_5c2371d43f803debf70090635a82b0a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15830b7d4a08ebb636c602c57faea348 = $(`&lt;div id=&quot;html_15830b7d4a08ebb636c602c57faea348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5c2371d43f803debf70090635a82b0a8.setContent(html_15830b7d4a08ebb636c602c57faea348);
#
#
#
#         marker_60702c77beb9f4f1a1aad8992298f38b.bindPopup(popup_5c2371d43f803debf70090635a82b0a8)
#         ;
#
#
#
#
#             var marker_2825e89c9c19f6cb82e2b93846767cb2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d4f84b8d303140f2b11ab169ba9e4175);
#
#
#         var popup_74beb46b4a3939e1a6fdd5a51817e248 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d89858fd4d33e0794aa958219c4c844 = $(`&lt;div id=&quot;html_4d89858fd4d33e0794aa958219c4c844&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_74beb46b4a3939e1a6fdd5a51817e248.setContent(html_4d89858fd4d33e0794aa958219c4c844);
#
#
#
#         marker_2825e89c9c19f6cb82e2b93846767cb2.bindPopup(popup_74beb46b4a3939e1a6fdd5a51817e248)
#         ;
#
#
#
#
#             var marker_bb02125d67ee3fb8bd49022711701ccc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d4f84b8d303140f2b11ab169ba9e4175);
#
#
#         var popup_93b67ecb80087c5136d7bc88af83ba3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d6f49183fa44079ac6ac930b3a20e98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d6f49183fa44079ac6ac930b3a20e98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d6f49183fa44079ac6ac930b3a20e98 = L.map(
#                 &quot;map_5d6f49183fa44079ac6ac930b3a20e98&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65583212bd589bbeaf2fb5315a698384 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65583212bd589bbeaf2fb5315a698384.addTo(map_5d6f49183fa44079ac6ac930b3a20e98);
#
#
#             var feature_group_a2646cc58dac9d8ba494239e03794239 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a2646cc58dac9d8ba494239e03794239.addTo(map_5d6f49183fa44079ac6ac930b3a20e98);
#
#
#             var feature_group_sub_group_2e2dc38c05b1dd656f3608f99d5600af = L.featureGroup.subGroup(
#                 feature_group_a2646cc58dac9d8ba494239e03794239
#             );
#
#
#             var marker_784f102a681fd71e3ee736ff4859c84d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e2dc38c05b1dd656f3608f99d5600af);
#
#
#         var popup_5db423d39685ee147b5a340a1f0a31ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c40ec2646a01249fe5c447e228705ce = $(`&lt;div id=&quot;html_8c40ec2646a01249fe5c447e228705ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5db423d39685ee147b5a340a1f0a31ac.setContent(html_8c40ec2646a01249fe5c447e228705ce);
#
#
#
#         marker_784f102a681fd71e3ee736ff4859c84d.bindPopup(popup_5db423d39685ee147b5a340a1f0a31ac)
#         ;
#
#
#
#
#             var marker_1823e707fdd8fe4c4c84f5762a0d353f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e2dc38c05b1dd656f3608f99d5600af);
#
#
#         var popup_64a6721ec8811efcb19cb7f34e4029d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cada32758e0fb94b8381fb5e800c214 = $(`&lt;div id=&quot;html_6cada32758e0fb94b8381fb5e800c214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_64a6721ec8811efcb19cb7f34e4029d6.setContent(html_6cada32758e0fb94b8381fb5e800c214);
#
#
#
#         marker_1823e707fdd8fe4c4c84f5762a0d353f.bindPopup(popup_64a6721ec8811efcb19cb7f34e4029d6)
#         ;
#
#
#
#
#             var marker_5c63b4f945f6548b0786e31ec58491c4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e2dc38c05b1dd656f3608f99d5600af);
#
#
#         var popup_fccde9f25b401c50d4868ecc73455b94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ac2556db3e35e882ff1d313ec3a73f6 = $(`&lt;div id=&quot;html_5ac2556db3e35e882ff1d313ec3a73f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fccde9f25b401c50d4868ecc73455b94.setContent(html_5ac2556db3e35e882ff1d313ec3a73f6);
#
#
#
#         marker_5c63b4f945f6548b0786e31ec58491c4.bindPopup(popup_fccde9f25b401c50d4868ecc73455b94)
#         ;
#
#
#
#
#             var marker_d9b7beb0ec3f725c4d960e8d4b49ed22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e2dc38c05b1dd656f3608f99d5600af);
#
#
#         var popup_e7426257d43c6d2690e4c9d2f765fcf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b84cefa5342cdf6a0acbf3a4ace670b0 = $(`&lt;div id=&quot;html_b84cefa5342cdf6a0acbf3a4ace670b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e7426257d43c6d2690e4c9d2f765fcf7.setContent(html_b84cefa5342cdf6a0acbf3a4ace670b0);
#
#
#
#         marker_
