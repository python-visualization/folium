# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ce8768680f7952ec9556778b0f179cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ce8768680f7952ec9556778b0f179cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ce8768680f7952ec9556778b0f179cd = L.map(
#                 &quot;map_3ce8768680f7952ec9556778b0f179cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dcc30992f710bf0ad5de929e84b9059 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6dcc30992f710bf0ad5de929e84b9059.addTo(map_3ce8768680f7952ec9556778b0f179cd);
#
#
#             var marker_b9e96236a844700a95bfd8758cf8e26c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3ce8768680f7952ec9556778b0f179cd);
#
#
#         var popup_c28f7f0697b9160f458906462df4fd49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df220067ebca15d91396043d2be92177 = $(`&lt;div id=&quot;html_df220067ebca15d91396043d2be92177&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c28f7f0697b9160f458906462df4fd49.setContent(html_df220067ebca15d91396043d2be92177);
#
#
#
#         marker_b9e96236a844700a95bfd8758cf8e26c.bindPopup(popup_c28f7f0697b9160f458906462df4fd49)
#         ;
#
#
#
#
#             var marker_cee8262f4f9a292d264db4a893c4d306 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3ce8768680f7952ec9556778b0f179cd);
#
#
#         var popup_c801dbce7b16461cd18dbbe2a19bb786 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6544cf9509d3ed083ae82674d7e72378 = $(`&lt;div id=&quot;html_6544cf9509d3ed083ae82674d7e72378&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c801dbce7b16461cd18dbbe2a19bb786.setContent(html_6544cf9509d3ed083ae82674d7e72378);
#
#
#
#         marker_cee8262f4f9a292d264db4a893c4d306.bindPopup(popup_c801dbce7b16461cd18dbbe2a19bb786)
#         ;
#
#
#
#
#             var marker_bfc664951f4d9ecbe69b5268fcce76fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3ce8768680f7952ec9556778b0f179cd);
#
#
#         var popup_2e7e430e7432f8c302d2782f3faf18a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da312761b9785c42ea959e24b44365c0 = $(`&lt;div id=&quot;html_da312761b9785c42ea959e24b44365c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2e7e430e7432f8c302d2782f3faf18a4.setContent(html_da312761b9785c42ea959e24b44365c0);
#
#
#
#         marker_bfc664951f4d9ecbe69b5268fcce76fd.bindPopup(popup_2e7e430e7432f8c302d2782f3faf18a4)
#         ;
#
#
#
#
#             var marker_d93cf3b0103c26be02c2ec26119e8c7d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3ce8768680f7952ec9556778b0f179cd);
#
#
#         var popup_68faf97f345a6583ad30e739c5c9b9c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3d9de46f1636365e13fe5c3c71c89f7 = $(`&lt;div id=&quot;html_e3d9de46f1636365e13fe5c3c71c89f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_68faf97f345a6583ad30e739c5c9b9c7.setContent(html_e3d9de46f1636365e13fe5c3c71c89f7);
#
#
#
#         marker_d93cf3b0103c26be02c2ec26119e8c7d.bindPopup(popup_68faf97f345a6583ad30e739c5c9b9c7)
#         ;
#
#
#
#
#             var marker_e8a3b3c939583873cfe187490c8aa584 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3ce8768680f7952ec9556778b0f179cd);
#
#
#         var popup_06ed54c25c6c39c59872a759e5a61047 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c65bbf77dc92dd3d645d0de72f2710f = $(`&lt;div id=&quot;html_3c65bbf77dc92dd3d645d0de72f2710f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_06ed54c25c6c39c59872a759e5a61047.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_633616e28cecf4864c2f14f5598c44e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_633616e28cecf4864c2f14f5598c44e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_633616e28cecf4864c2f14f5598c44e0 = L.map(
#                 &quot;map_633616e28cecf4864c2f14f5598c44e0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7d23927af0d132149ade1576aec1d60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7d23927af0d132149ade1576aec1d60.addTo(map_633616e28cecf4864c2f14f5598c44e0);
#
#
#             var feature_group_fbefba74e2aca9bab78e1115a8edd90b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_852b674871fa1ac708b685f99f9a937d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fbefba74e2aca9bab78e1115a8edd90b);
#
#
#         var popup_48436312a9e79391b8ccb1e65629303c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a74cd63b0e69594efdd7934cd0f3969e = $(`&lt;div id=&quot;html_a74cd63b0e69594efdd7934cd0f3969e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_48436312a9e79391b8ccb1e65629303c.setContent(html_a74cd63b0e69594efdd7934cd0f3969e);
#
#
#
#         marker_852b674871fa1ac708b685f99f9a937d.bindPopup(popup_48436312a9e79391b8ccb1e65629303c)
#         ;
#
#
#
#
#             var marker_047e9648a26aa797a87387b4e8fed0ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fbefba74e2aca9bab78e1115a8edd90b);
#
#
#         var popup_3b29a5760efd1e742beececd78f919a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341e78a8e5243d4aae6e4b65a5201544 = $(`&lt;div id=&quot;html_341e78a8e5243d4aae6e4b65a5201544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3b29a5760efd1e742beececd78f919a5.setContent(html_341e78a8e5243d4aae6e4b65a5201544);
#
#
#
#         marker_047e9648a26aa797a87387b4e8fed0ee.bindPopup(popup_3b29a5760efd1e742beececd78f919a5)
#         ;
#
#
#
#
#             var marker_815de599da51b91cd1bff538900ca59f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fbefba74e2aca9bab78e1115a8edd90b);
#
#
#         var popup_41194fc8134560a8fb879aaa2c4842e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec746bc926f51e0f937999f61efde2fb = $(`&lt;div id=&quot;html_ec746bc926f51e0f937999f61efde2fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_41194fc8134560a8fb879aaa2c4842e8.setContent(html_ec746bc926f51e0f937999f61efde2fb);
#
#
#
#         marker_815de599da51b91cd1bff538900ca59f.bindPopup(popup_41194fc8134560a8fb879aaa2c4842e8)
#         ;
#
#
#
#
#             var marker_86d79f6d210cd72c5fbaee0c81b734ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fbefba74e2aca9bab78e1115a8edd90b);
#
#
#         var popup_5c843d8918da29f228077c1753f500ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72b3cabfcff5e2d0f183236ca376c1bf = $(`&lt;div id=&quot;html_72b3cabfcff5e2d0f183236ca376c1bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5c843d8918da29f228077c1753f500ce.setContent(html_72b3cabfcff5e2d0f183236ca376c1bf);
#
#
#
#         marker_86d79f6d210cd72c5fbaee0c81b734ed.bindPopup(popup_5c843d8918da29f228077c1753f500ce)
#         ;
#
#
#
#
#             var marker_2f6f634de4383f4192510b69d9536fe2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fbefba74e2aca9bab78e1115a8edd90b);
#
#
#         var popup_a31467f5caf68a5137afd4441559becd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_622e75938b99639394f74d895454ab1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_622e75938b99639394f74d895454ab1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_622e75938b99639394f74d895454ab1c = L.map(
#                 &quot;map_622e75938b99639394f74d895454ab1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cf514d2abc3dbfdfdebf2e332ce0c5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cf514d2abc3dbfdfdebf2e332ce0c5c.addTo(map_622e75938b99639394f74d895454ab1c);
#
#
#             var feature_group_c9f84135781ca0a6a291728c4802eb4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c9f84135781ca0a6a291728c4802eb4c.addTo(map_622e75938b99639394f74d895454ab1c);
#
#
#             var feature_group_sub_group_92fc4a32d7c82aa634800ad586cf99d3 = L.featureGroup.subGroup(
#                 feature_group_c9f84135781ca0a6a291728c4802eb4c
#             );
#
#
#             var marker_57c6387ef1329b0faf8296761327135c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92fc4a32d7c82aa634800ad586cf99d3);
#
#
#         var popup_7af647d892b220d5121893a87cb72acf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a80d284f68722dadaf721c1dc336e47c = $(`&lt;div id=&quot;html_a80d284f68722dadaf721c1dc336e47c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7af647d892b220d5121893a87cb72acf.setContent(html_a80d284f68722dadaf721c1dc336e47c);
#
#
#
#         marker_57c6387ef1329b0faf8296761327135c.bindPopup(popup_7af647d892b220d5121893a87cb72acf)
#         ;
#
#
#
#
#             var marker_edd3d64e680a83c1b1996bef07f6bd97 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92fc4a32d7c82aa634800ad586cf99d3);
#
#
#         var popup_347c80273938189a01db84b50bb4fef3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2090ee15cb9ef2360403f751502ad4c3 = $(`&lt;div id=&quot;html_2090ee15cb9ef2360403f751502ad4c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_347c80273938189a01db84b50bb4fef3.setContent(html_2090ee15cb9ef2360403f751502ad4c3);
#
#
#
#         marker_edd3d64e680a83c1b1996bef07f6bd97.bindPopup(popup_347c80273938189a01db84b50bb4fef3)
#         ;
#
#
#
#
#             var marker_1662cf95100cfe75ddc611ad5fb7711e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92fc4a32d7c82aa634800ad586cf99d3);
#
#
#         var popup_fe1b6a36da4641c5c8925b4e34c2952d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f4417d812272ec7093e202f419eaf72 = $(`&lt;div id=&quot;html_0f4417d812272ec7093e202f419eaf72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fe1b6a36da4641c5c8925b4e34c2952d.setContent(html_0f4417d812272ec7093e202f419eaf72);
#
#
#
#         marker_1662cf95100cfe75ddc611ad5fb7711e.bindPopup(popup_fe1b6a36da4641c5c8925b4e34c2952d)
#         ;
#
#
#
#
#             var marker_f96b90f1098308950d601c105e4605a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92fc4a32d7c82aa634800ad586cf99d3);
#
#
#         var popup_0de043e5a924bd439bd35524b617aa2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d9c4abbf66560f4612087f7cfd3b6e9 = $(`&lt;div id=&quot;html_7d9c4abbf66560f4612087f7cfd3b6e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0de043e5a924bd439bd35524b617aa2e.setContent(html_7d9c4abbf66560f4612087f7cfd3b6e9);
#
#
#
#         marker_
