# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb94668cbd4ce5384be2d6917f4a356e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb94668cbd4ce5384be2d6917f4a356e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb94668cbd4ce5384be2d6917f4a356e = L.map(
#                 &quot;map_cb94668cbd4ce5384be2d6917f4a356e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29e0c54e7b2da9f263de8da11ccb6c6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29e0c54e7b2da9f263de8da11ccb6c6e.addTo(map_cb94668cbd4ce5384be2d6917f4a356e);
#
#
#             var marker_217c713497dcd1d625040fdb92b0dac6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cb94668cbd4ce5384be2d6917f4a356e);
#
#
#         var popup_32afbd3ab8a4962098f5c9cfc09f3d9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f517860fd67b91d6bdd5b45ef46a060e = $(`&lt;div id=&quot;html_f517860fd67b91d6bdd5b45ef46a060e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_32afbd3ab8a4962098f5c9cfc09f3d9c.setContent(html_f517860fd67b91d6bdd5b45ef46a060e);
#
#
#
#         marker_217c713497dcd1d625040fdb92b0dac6.bindPopup(popup_32afbd3ab8a4962098f5c9cfc09f3d9c)
#         ;
#
#
#
#
#             var marker_31eeac44bbe597b67de9e36c659db1b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cb94668cbd4ce5384be2d6917f4a356e);
#
#
#         var popup_3a80dfececedd890f29a3622e3948dbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5c3bbe481abe73e12be726666718275 = $(`&lt;div id=&quot;html_d5c3bbe481abe73e12be726666718275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3a80dfececedd890f29a3622e3948dbf.setContent(html_d5c3bbe481abe73e12be726666718275);
#
#
#
#         marker_31eeac44bbe597b67de9e36c659db1b8.bindPopup(popup_3a80dfececedd890f29a3622e3948dbf)
#         ;
#
#
#
#
#             var marker_dbe0bcfbc60d2b115c881df2bfdf89e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cb94668cbd4ce5384be2d6917f4a356e);
#
#
#         var popup_8aa74f44bf6930455b45ea57ee093d56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07c81401376b1244c9c9a459c1bdb549 = $(`&lt;div id=&quot;html_07c81401376b1244c9c9a459c1bdb549&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8aa74f44bf6930455b45ea57ee093d56.setContent(html_07c81401376b1244c9c9a459c1bdb549);
#
#
#
#         marker_dbe0bcfbc60d2b115c881df2bfdf89e9.bindPopup(popup_8aa74f44bf6930455b45ea57ee093d56)
#         ;
#
#
#
#
#             var marker_71d930e45b6c8adc2cbdba002ac728a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cb94668cbd4ce5384be2d6917f4a356e);
#
#
#         var popup_e6630343c2d89f14fd996796c4d26e41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_137173729da7c794a57388fb09a839d2 = $(`&lt;div id=&quot;html_137173729da7c794a57388fb09a839d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e6630343c2d89f14fd996796c4d26e41.setContent(html_137173729da7c794a57388fb09a839d2);
#
#
#
#         marker_71d930e45b6c8adc2cbdba002ac728a5.bindPopup(popup_e6630343c2d89f14fd996796c4d26e41)
#         ;
#
#
#
#
#             var marker_55ed2320375936bd5544741907715600 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cb94668cbd4ce5384be2d6917f4a356e);
#
#
#         var popup_17da8718574e2ec3861f9fe472f75ee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a1daee17cf1247ec93ce00b2c609255 = $(`&lt;div id=&quot;html_9a1daee17cf1247ec93ce00b2c609255&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_17da8718574e2ec3861f9fe472f75ee4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bab030694bce48a5504f300b18e3aff4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bab030694bce48a5504f300b18e3aff4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bab030694bce48a5504f300b18e3aff4 = L.map(
#                 &quot;map_bab030694bce48a5504f300b18e3aff4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f86461b94018eb7836e4eb8ab824832 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f86461b94018eb7836e4eb8ab824832.addTo(map_bab030694bce48a5504f300b18e3aff4);
#
#
#             var feature_group_849488f864ce7d120a59f775d4258ed2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7024472026f643b203540d8df5e20f0c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_849488f864ce7d120a59f775d4258ed2);
#
#
#         var popup_d327f2a73c19e935e3c315ab9f6cc21e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6c8000d7f9369e96af4e1b7fc14c8b3 = $(`&lt;div id=&quot;html_f6c8000d7f9369e96af4e1b7fc14c8b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d327f2a73c19e935e3c315ab9f6cc21e.setContent(html_f6c8000d7f9369e96af4e1b7fc14c8b3);
#
#
#
#         marker_7024472026f643b203540d8df5e20f0c.bindPopup(popup_d327f2a73c19e935e3c315ab9f6cc21e)
#         ;
#
#
#
#
#             var marker_b27ac1c5b535baf0f4be809ddd9ae503 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_849488f864ce7d120a59f775d4258ed2);
#
#
#         var popup_206ac9752c97a05329b0ca256ef7c55e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6decb85c6861b5f60ae9ea32a07cda9 = $(`&lt;div id=&quot;html_b6decb85c6861b5f60ae9ea32a07cda9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_206ac9752c97a05329b0ca256ef7c55e.setContent(html_b6decb85c6861b5f60ae9ea32a07cda9);
#
#
#
#         marker_b27ac1c5b535baf0f4be809ddd9ae503.bindPopup(popup_206ac9752c97a05329b0ca256ef7c55e)
#         ;
#
#
#
#
#             var marker_cfaa8076484037604f7d22e3b4e1d050 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_849488f864ce7d120a59f775d4258ed2);
#
#
#         var popup_072825a8da72bcd97eb7b36436772b3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb4109a1281893ee0d13adcfc82024ed = $(`&lt;div id=&quot;html_fb4109a1281893ee0d13adcfc82024ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_072825a8da72bcd97eb7b36436772b3b.setContent(html_fb4109a1281893ee0d13adcfc82024ed);
#
#
#
#         marker_cfaa8076484037604f7d22e3b4e1d050.bindPopup(popup_072825a8da72bcd97eb7b36436772b3b)
#         ;
#
#
#
#
#             var marker_857852364625745cc4ef9847920c07ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_849488f864ce7d120a59f775d4258ed2);
#
#
#         var popup_60e1c5beb0f0991c86f230e16034e187 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_082c661800432e201428330b4fb13d66 = $(`&lt;div id=&quot;html_082c661800432e201428330b4fb13d66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_60e1c5beb0f0991c86f230e16034e187.setContent(html_082c661800432e201428330b4fb13d66);
#
#
#
#         marker_857852364625745cc4ef9847920c07ab.bindPopup(popup_60e1c5beb0f0991c86f230e16034e187)
#         ;
#
#
#
#
#             var marker_32cd779c834f91406b252d8eec685b4f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_849488f864ce7d120a59f775d4258ed2);
#
#
#         var popup_2e7f96cdf627f932f8eed87c6d3d206c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92282bc40a11f89e6e909d3be040a853 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92282bc40a11f89e6e909d3be040a853&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92282bc40a11f89e6e909d3be040a853 = L.map(
#                 &quot;map_92282bc40a11f89e6e909d3be040a853&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13fe43c0ee92799ee6318be6a9d865e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13fe43c0ee92799ee6318be6a9d865e1.addTo(map_92282bc40a11f89e6e909d3be040a853);
#
#
#             var feature_group_b722dcca258a5b16ddcb9bb9f660fa6c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b722dcca258a5b16ddcb9bb9f660fa6c.addTo(map_92282bc40a11f89e6e909d3be040a853);
#
#
#             var feature_group_sub_group_b69904c79f75877fad1922dc2987a0c6 = L.featureGroup.subGroup(
#                 feature_group_b722dcca258a5b16ddcb9bb9f660fa6c
#             );
#
#
#             var marker_88b0baea9108e267b0752ad1a0b45793 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b69904c79f75877fad1922dc2987a0c6);
#
#
#         var popup_b0d2438efb0f1aba034971c81c0a28d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e00958f13f46e21a73d7096dffc075de = $(`&lt;div id=&quot;html_e00958f13f46e21a73d7096dffc075de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b0d2438efb0f1aba034971c81c0a28d8.setContent(html_e00958f13f46e21a73d7096dffc075de);
#
#
#
#         marker_88b0baea9108e267b0752ad1a0b45793.bindPopup(popup_b0d2438efb0f1aba034971c81c0a28d8)
#         ;
#
#
#
#
#             var marker_9b0382efbd933dfe433d44c5e392c1f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b69904c79f75877fad1922dc2987a0c6);
#
#
#         var popup_211ba54f34a65e5ba7fb370de4ac3723 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a53c989e4d5303e841b180dd4cecc7e = $(`&lt;div id=&quot;html_7a53c989e4d5303e841b180dd4cecc7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_211ba54f34a65e5ba7fb370de4ac3723.setContent(html_7a53c989e4d5303e841b180dd4cecc7e);
#
#
#
#         marker_9b0382efbd933dfe433d44c5e392c1f1.bindPopup(popup_211ba54f34a65e5ba7fb370de4ac3723)
#         ;
#
#
#
#
#             var marker_324f3d400ee5118d92ee476a7c800b25 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b69904c79f75877fad1922dc2987a0c6);
#
#
#         var popup_fe139820dc460b70d1f65fcce8015d42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66376c4da7f94d5fd3e8b20dafa7808d = $(`&lt;div id=&quot;html_66376c4da7f94d5fd3e8b20dafa7808d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fe139820dc460b70d1f65fcce8015d42.setContent(html_66376c4da7f94d5fd3e8b20dafa7808d);
#
#
#
#         marker_324f3d400ee5118d92ee476a7c800b25.bindPopup(popup_fe139820dc460b70d1f65fcce8015d42)
#         ;
#
#
#
#
#             var marker_5de4316d2bbd60cdc66e60722f41a3b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b69904c79f75877fad1922dc2987a0c6);
#
#
#         var popup_206293d8d58e5009356d03b92f001415 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d72893825a5cbf2d4332da1d1e86fc2b = $(`&lt;div id=&quot;html_d72893825a5cbf2d4332da1d1e86fc2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_206293d8d58e5009356d03b92f001415.setContent(html_d72893825a5cbf2d4332da1d1e86fc2b);
#
#
#
#         marker_
