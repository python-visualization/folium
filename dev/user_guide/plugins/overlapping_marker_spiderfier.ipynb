# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3cf815c71c56b2f787dc1c055881093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3cf815c71c56b2f787dc1c055881093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3cf815c71c56b2f787dc1c055881093 = L.map(
#                 &quot;map_e3cf815c71c56b2f787dc1c055881093&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb19ee7b4736f699e66cd07235beebc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb19ee7b4736f699e66cd07235beebc3.addTo(map_e3cf815c71c56b2f787dc1c055881093);
#
#
#             var marker_db3bbde9de480a9fa6070688b106a54f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e3cf815c71c56b2f787dc1c055881093);
#
#
#         var popup_b835cac5af8f10e62c657a2e9bc16adc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ac27e7dff8c6631b24879b03ab6676e = $(`&lt;div id=&quot;html_7ac27e7dff8c6631b24879b03ab6676e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b835cac5af8f10e62c657a2e9bc16adc.setContent(html_7ac27e7dff8c6631b24879b03ab6676e);
#
#
#
#         marker_db3bbde9de480a9fa6070688b106a54f.bindPopup(popup_b835cac5af8f10e62c657a2e9bc16adc)
#         ;
#
#
#
#
#             var marker_145b18169f64a9044f9627f2ddb2c23c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e3cf815c71c56b2f787dc1c055881093);
#
#
#         var popup_778aad188d7edb84a52fb46bcc44a01a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4564c3cd8d224d6078da6ca67bcc9862 = $(`&lt;div id=&quot;html_4564c3cd8d224d6078da6ca67bcc9862&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_778aad188d7edb84a52fb46bcc44a01a.setContent(html_4564c3cd8d224d6078da6ca67bcc9862);
#
#
#
#         marker_145b18169f64a9044f9627f2ddb2c23c.bindPopup(popup_778aad188d7edb84a52fb46bcc44a01a)
#         ;
#
#
#
#
#             var marker_e9dbd3626dab212579c11d1943dc46ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e3cf815c71c56b2f787dc1c055881093);
#
#
#         var popup_da01296b867fecc87ee22f2b38994eb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e619614ff906d2b2f0da3e7f7fa62a31 = $(`&lt;div id=&quot;html_e619614ff906d2b2f0da3e7f7fa62a31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_da01296b867fecc87ee22f2b38994eb0.setContent(html_e619614ff906d2b2f0da3e7f7fa62a31);
#
#
#
#         marker_e9dbd3626dab212579c11d1943dc46ea.bindPopup(popup_da01296b867fecc87ee22f2b38994eb0)
#         ;
#
#
#
#
#             var marker_eca05a746942f6a3cd281d4e0ed1f8fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e3cf815c71c56b2f787dc1c055881093);
#
#
#         var popup_e72bf00a5f3fdddf436cccd665864a11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4181cb034c2f2a04cb8c6738cb0eb597 = $(`&lt;div id=&quot;html_4181cb034c2f2a04cb8c6738cb0eb597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e72bf00a5f3fdddf436cccd665864a11.setContent(html_4181cb034c2f2a04cb8c6738cb0eb597);
#
#
#
#         marker_eca05a746942f6a3cd281d4e0ed1f8fd.bindPopup(popup_e72bf00a5f3fdddf436cccd665864a11)
#         ;
#
#
#
#
#             var marker_6063d2ca1c48909e745f27426a2bd5c0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e3cf815c71c56b2f787dc1c055881093);
#
#
#         var popup_fc0a282e96ed13c988db66504ccee881 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8a5c5d19d45f15d3dc18d3858f9b613 = $(`&lt;div id=&quot;html_f8a5c5d19d45f15d3dc18d3858f9b613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fc0a282e96ed13c988db66504ccee881.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aedbefcc9abe0d56368c74f8e8d71ae9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aedbefcc9abe0d56368c74f8e8d71ae9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aedbefcc9abe0d56368c74f8e8d71ae9 = L.map(
#                 &quot;map_aedbefcc9abe0d56368c74f8e8d71ae9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_424ff7b21ba6ecb8bdae78976c2f94b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_424ff7b21ba6ecb8bdae78976c2f94b2.addTo(map_aedbefcc9abe0d56368c74f8e8d71ae9);
#
#
#             var feature_group_a691fee2ea8786f103f6e6caa52a18be = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_91fdeee4cac9624c7a973472fe58a100 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a691fee2ea8786f103f6e6caa52a18be);
#
#
#         var popup_465a05e8335539eb3ea228405b26c29d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40b73fd30dc62450c2573b6e2727189f = $(`&lt;div id=&quot;html_40b73fd30dc62450c2573b6e2727189f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_465a05e8335539eb3ea228405b26c29d.setContent(html_40b73fd30dc62450c2573b6e2727189f);
#
#
#
#         marker_91fdeee4cac9624c7a973472fe58a100.bindPopup(popup_465a05e8335539eb3ea228405b26c29d)
#         ;
#
#
#
#
#             var marker_4436e585414ef2f3304f3965ca4c71a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a691fee2ea8786f103f6e6caa52a18be);
#
#
#         var popup_1670f2fd3c59df0be32f95f2923e1b73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30dc0df255abd7c4ee5b7e7f039b1223 = $(`&lt;div id=&quot;html_30dc0df255abd7c4ee5b7e7f039b1223&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1670f2fd3c59df0be32f95f2923e1b73.setContent(html_30dc0df255abd7c4ee5b7e7f039b1223);
#
#
#
#         marker_4436e585414ef2f3304f3965ca4c71a7.bindPopup(popup_1670f2fd3c59df0be32f95f2923e1b73)
#         ;
#
#
#
#
#             var marker_824136d80df9a2b56f65cd5b08b0a486 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a691fee2ea8786f103f6e6caa52a18be);
#
#
#         var popup_e618339627abab9ac1b907bfd4f30df4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b3e2c87f357b803a5a8b1fb72efc445 = $(`&lt;div id=&quot;html_4b3e2c87f357b803a5a8b1fb72efc445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e618339627abab9ac1b907bfd4f30df4.setContent(html_4b3e2c87f357b803a5a8b1fb72efc445);
#
#
#
#         marker_824136d80df9a2b56f65cd5b08b0a486.bindPopup(popup_e618339627abab9ac1b907bfd4f30df4)
#         ;
#
#
#
#
#             var marker_48b0aece2976f1da59a5dedffa394254 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a691fee2ea8786f103f6e6caa52a18be);
#
#
#         var popup_e1c5163ace00de27320a58f429521b94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2127034ea5d17090ff27a26c32b558fd = $(`&lt;div id=&quot;html_2127034ea5d17090ff27a26c32b558fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e1c5163ace00de27320a58f429521b94.setContent(html_2127034ea5d17090ff27a26c32b558fd);
#
#
#
#         marker_48b0aece2976f1da59a5dedffa394254.bindPopup(popup_e1c5163ace00de27320a58f429521b94)
#         ;
#
#
#
#
#             var marker_55938c0af9b5bffbee9da4a36f67f8fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a691fee2ea8786f103f6e6caa52a18be);
#
#
#         var popup_5441b5d571db2f0771995d3bfc845afb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cb61830a09ca306b6ac5a3f3a110c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cb61830a09ca306b6ac5a3f3a110c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cb61830a09ca306b6ac5a3f3a110c16 = L.map(
#                 &quot;map_5cb61830a09ca306b6ac5a3f3a110c16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38968c85dc540538d82b435073920c02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38968c85dc540538d82b435073920c02.addTo(map_5cb61830a09ca306b6ac5a3f3a110c16);
#
#
#             var feature_group_51d85b69c5b9edd806d657ab11baea72 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_51d85b69c5b9edd806d657ab11baea72.addTo(map_5cb61830a09ca306b6ac5a3f3a110c16);
#
#
#             var feature_group_sub_group_c23c578af5e752f0f8821446bd50b15f = L.featureGroup.subGroup(
#                 feature_group_51d85b69c5b9edd806d657ab11baea72
#             );
#
#
#             var marker_503b180db4e1711a105e506b882a80fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c23c578af5e752f0f8821446bd50b15f);
#
#
#         var popup_e9f6fae91006fb69a6c62b3aec23d80f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce052bbecb4da66cbeb16b3f7b47d209 = $(`&lt;div id=&quot;html_ce052bbecb4da66cbeb16b3f7b47d209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e9f6fae91006fb69a6c62b3aec23d80f.setContent(html_ce052bbecb4da66cbeb16b3f7b47d209);
#
#
#
#         marker_503b180db4e1711a105e506b882a80fd.bindPopup(popup_e9f6fae91006fb69a6c62b3aec23d80f)
#         ;
#
#
#
#
#             var marker_943f654e3deb42ed508764d847712348 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c23c578af5e752f0f8821446bd50b15f);
#
#
#         var popup_45ff2126ae13aa24868878bacad4cf43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53e76683d24930d52c91dd2f6747d90a = $(`&lt;div id=&quot;html_53e76683d24930d52c91dd2f6747d90a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_45ff2126ae13aa24868878bacad4cf43.setContent(html_53e76683d24930d52c91dd2f6747d90a);
#
#
#
#         marker_943f654e3deb42ed508764d847712348.bindPopup(popup_45ff2126ae13aa24868878bacad4cf43)
#         ;
#
#
#
#
#             var marker_813c3bcc2ed4b66417562208ca72ac06 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c23c578af5e752f0f8821446bd50b15f);
#
#
#         var popup_624292c7b72f5641e3c95a88e1b64dc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d57794b2fcb573a3db47e3dcfac2118d = $(`&lt;div id=&quot;html_d57794b2fcb573a3db47e3dcfac2118d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_624292c7b72f5641e3c95a88e1b64dc2.setContent(html_d57794b2fcb573a3db47e3dcfac2118d);
#
#
#
#         marker_813c3bcc2ed4b66417562208ca72ac06.bindPopup(popup_624292c7b72f5641e3c95a88e1b64dc2)
#         ;
#
#
#
#
#             var marker_d82181dec409839deb9d8e1b20c96d1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c23c578af5e752f0f8821446bd50b15f);
#
#
#         var popup_c159c936801f1580ea91891f38d7649a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6579a169c187acf57d2b4342533f1511 = $(`&lt;div id=&quot;html_6579a169c187acf57d2b4342533f1511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c159c936801f1580ea91891f38d7649a.setContent(html_6579a169c187acf57d2b4342533f1511);
#
#
#
#         marker_
