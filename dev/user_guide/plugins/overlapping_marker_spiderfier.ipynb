# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83c36d90413363ce57c14a55e37aab0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83c36d90413363ce57c14a55e37aab0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83c36d90413363ce57c14a55e37aab0c = L.map(
#                 &quot;map_83c36d90413363ce57c14a55e37aab0c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a532b97e0fe6699270ba14fbb0bed62a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a532b97e0fe6699270ba14fbb0bed62a.addTo(map_83c36d90413363ce57c14a55e37aab0c);
#
#
#             var marker_3a95fb1e2069e4b59b384129b53f8f28 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_83c36d90413363ce57c14a55e37aab0c);
#
#
#         var popup_2b002662474add1eb140aec423ade25a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7269ce90f4d4c23de12aa42dab13101c = $(`&lt;div id=&quot;html_7269ce90f4d4c23de12aa42dab13101c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2b002662474add1eb140aec423ade25a.setContent(html_7269ce90f4d4c23de12aa42dab13101c);
#
#
#
#         marker_3a95fb1e2069e4b59b384129b53f8f28.bindPopup(popup_2b002662474add1eb140aec423ade25a)
#         ;
#
#
#
#
#             var marker_af9a8bbd3275a62f373ef540aabae345 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_83c36d90413363ce57c14a55e37aab0c);
#
#
#         var popup_565246e3a53471489d944dab7e708ce3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8c46c518db2836ad255fc9c4d92130f = $(`&lt;div id=&quot;html_a8c46c518db2836ad255fc9c4d92130f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_565246e3a53471489d944dab7e708ce3.setContent(html_a8c46c518db2836ad255fc9c4d92130f);
#
#
#
#         marker_af9a8bbd3275a62f373ef540aabae345.bindPopup(popup_565246e3a53471489d944dab7e708ce3)
#         ;
#
#
#
#
#             var marker_3656efc59f975203baf88535a89dc682 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_83c36d90413363ce57c14a55e37aab0c);
#
#
#         var popup_1c22d330bbacf7e39bee3a0c0c81d14e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c3ea64c8335ac8e31b8b5b313305a87 = $(`&lt;div id=&quot;html_1c3ea64c8335ac8e31b8b5b313305a87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1c22d330bbacf7e39bee3a0c0c81d14e.setContent(html_1c3ea64c8335ac8e31b8b5b313305a87);
#
#
#
#         marker_3656efc59f975203baf88535a89dc682.bindPopup(popup_1c22d330bbacf7e39bee3a0c0c81d14e)
#         ;
#
#
#
#
#             var marker_a1d54d051c30b63f23663ba13c658f19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_83c36d90413363ce57c14a55e37aab0c);
#
#
#         var popup_31f23125fb26416b48e163c7b5acfb52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3f5085821d7ecc007b4ab8424581c85 = $(`&lt;div id=&quot;html_f3f5085821d7ecc007b4ab8424581c85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_31f23125fb26416b48e163c7b5acfb52.setContent(html_f3f5085821d7ecc007b4ab8424581c85);
#
#
#
#         marker_a1d54d051c30b63f23663ba13c658f19.bindPopup(popup_31f23125fb26416b48e163c7b5acfb52)
#         ;
#
#
#
#
#             var marker_6e4282994ca35162c1e62d2bc899a812 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_83c36d90413363ce57c14a55e37aab0c);
#
#
#         var popup_a8aa6add9156427fdce57b52d6931bf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06b3863cbd6847b2803ccecdeea5e60b = $(`&lt;div id=&quot;html_06b3863cbd6847b2803ccecdeea5e60b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a8aa6add9156427fdce57b52d6931bf1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61e329ebd61cf9e31a56dd9f54713a11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61e329ebd61cf9e31a56dd9f54713a11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61e329ebd61cf9e31a56dd9f54713a11 = L.map(
#                 &quot;map_61e329ebd61cf9e31a56dd9f54713a11&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ae99f22b94bcacc2a933d3b0fff7ebf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ae99f22b94bcacc2a933d3b0fff7ebf.addTo(map_61e329ebd61cf9e31a56dd9f54713a11);
#
#
#             var feature_group_d3e94e4dc385251f8c9cebb5940d8eb5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_240c041912a9ea25f1b503be4600296d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d3e94e4dc385251f8c9cebb5940d8eb5);
#
#
#         var popup_5d478bb57ac095a41fcee556fb2eecbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b36e69001147eff0d24b38fd6dfa86e = $(`&lt;div id=&quot;html_7b36e69001147eff0d24b38fd6dfa86e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5d478bb57ac095a41fcee556fb2eecbd.setContent(html_7b36e69001147eff0d24b38fd6dfa86e);
#
#
#
#         marker_240c041912a9ea25f1b503be4600296d.bindPopup(popup_5d478bb57ac095a41fcee556fb2eecbd)
#         ;
#
#
#
#
#             var marker_1ce5f4b11d4d980286a41aa007d86d16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d3e94e4dc385251f8c9cebb5940d8eb5);
#
#
#         var popup_e3f9ee741767513728ae1c6b7382c2fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec8e783889b41fb7f3aabe1dc371650 = $(`&lt;div id=&quot;html_eec8e783889b41fb7f3aabe1dc371650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e3f9ee741767513728ae1c6b7382c2fe.setContent(html_eec8e783889b41fb7f3aabe1dc371650);
#
#
#
#         marker_1ce5f4b11d4d980286a41aa007d86d16.bindPopup(popup_e3f9ee741767513728ae1c6b7382c2fe)
#         ;
#
#
#
#
#             var marker_0d3fb22e0f3d5245fc8c120ce3d3639d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d3e94e4dc385251f8c9cebb5940d8eb5);
#
#
#         var popup_fcd414fe39ab43d58f3e6daa3c9b44bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_600ccf27d6883ed7ad812ce7ec481db2 = $(`&lt;div id=&quot;html_600ccf27d6883ed7ad812ce7ec481db2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fcd414fe39ab43d58f3e6daa3c9b44bb.setContent(html_600ccf27d6883ed7ad812ce7ec481db2);
#
#
#
#         marker_0d3fb22e0f3d5245fc8c120ce3d3639d.bindPopup(popup_fcd414fe39ab43d58f3e6daa3c9b44bb)
#         ;
#
#
#
#
#             var marker_bbe16559cbb8e09d16a2e249e52ae5dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d3e94e4dc385251f8c9cebb5940d8eb5);
#
#
#         var popup_b5d6ee6b63265f48f47aa3f22f528c1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c6454a93bbebe938c9e668de6843e81 = $(`&lt;div id=&quot;html_7c6454a93bbebe938c9e668de6843e81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b5d6ee6b63265f48f47aa3f22f528c1d.setContent(html_7c6454a93bbebe938c9e668de6843e81);
#
#
#
#         marker_bbe16559cbb8e09d16a2e249e52ae5dd.bindPopup(popup_b5d6ee6b63265f48f47aa3f22f528c1d)
#         ;
#
#
#
#
#             var marker_647f1a6fc872ac6ffdf69d847722bed8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d3e94e4dc385251f8c9cebb5940d8eb5);
#
#
#         var popup_831f34d74e6311865ffdd5bd42820a7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d041230feebcec7812e235dfb9ddafb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d041230feebcec7812e235dfb9ddafb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d041230feebcec7812e235dfb9ddafb6 = L.map(
#                 &quot;map_d041230feebcec7812e235dfb9ddafb6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7661b85b29ceacd59ae7fa7cbdbbd61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7661b85b29ceacd59ae7fa7cbdbbd61.addTo(map_d041230feebcec7812e235dfb9ddafb6);
#
#
#             var feature_group_6c57b4f6fc261a05243fd37f301811f6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6c57b4f6fc261a05243fd37f301811f6.addTo(map_d041230feebcec7812e235dfb9ddafb6);
#
#
#             var feature_group_sub_group_a55cd1ebdb26b3483b1381ce21a0f1b9 = L.featureGroup.subGroup(
#                 feature_group_6c57b4f6fc261a05243fd37f301811f6
#             );
#
#
#             var marker_b8685b78768b0bfc33d23009847d5ac4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a55cd1ebdb26b3483b1381ce21a0f1b9);
#
#
#         var popup_3587b914bc71e3205dfd26c2e4ec0c39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22c80186b2c4e3ac255b99e908884899 = $(`&lt;div id=&quot;html_22c80186b2c4e3ac255b99e908884899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3587b914bc71e3205dfd26c2e4ec0c39.setContent(html_22c80186b2c4e3ac255b99e908884899);
#
#
#
#         marker_b8685b78768b0bfc33d23009847d5ac4.bindPopup(popup_3587b914bc71e3205dfd26c2e4ec0c39)
#         ;
#
#
#
#
#             var marker_1fd342ddcbf7d76176de418d47113f33 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a55cd1ebdb26b3483b1381ce21a0f1b9);
#
#
#         var popup_25f5ed2f577dc33c186b70e9f117eff9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9474db3f9a174086f584723b6cf8f37f = $(`&lt;div id=&quot;html_9474db3f9a174086f584723b6cf8f37f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_25f5ed2f577dc33c186b70e9f117eff9.setContent(html_9474db3f9a174086f584723b6cf8f37f);
#
#
#
#         marker_1fd342ddcbf7d76176de418d47113f33.bindPopup(popup_25f5ed2f577dc33c186b70e9f117eff9)
#         ;
#
#
#
#
#             var marker_85ed91a971d65bb7549a9cc3b14e3f04 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a55cd1ebdb26b3483b1381ce21a0f1b9);
#
#
#         var popup_3e8fc5c8cb452eef9be44bb907547fe6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b46f7f156c0dd8f26e6594872d1618c1 = $(`&lt;div id=&quot;html_b46f7f156c0dd8f26e6594872d1618c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3e8fc5c8cb452eef9be44bb907547fe6.setContent(html_b46f7f156c0dd8f26e6594872d1618c1);
#
#
#
#         marker_85ed91a971d65bb7549a9cc3b14e3f04.bindPopup(popup_3e8fc5c8cb452eef9be44bb907547fe6)
#         ;
#
#
#
#
#             var marker_a7f2af8508eda60dbaf53f395cebfc24 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a55cd1ebdb26b3483b1381ce21a0f1b9);
#
#
#         var popup_0fc437d0a6e10f1665efa8cfdb732f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06d7723cfe846b5b863231c836aa45d2 = $(`&lt;div id=&quot;html_06d7723cfe846b5b863231c836aa45d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0fc437d0a6e10f1665efa8cfdb732f38.setContent(html_06d7723cfe846b5b863231c836aa45d2);
#
#
#
#         marker_
