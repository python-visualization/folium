# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff64eace548802cdb6f5899fd9ee41bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff64eace548802cdb6f5899fd9ee41bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff64eace548802cdb6f5899fd9ee41bc = L.map(
#                 &quot;map_ff64eace548802cdb6f5899fd9ee41bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f84f09bd4eb97390371629c8ac55f1ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f84f09bd4eb97390371629c8ac55f1ca.addTo(map_ff64eace548802cdb6f5899fd9ee41bc);
#
#
#             var marker_239720d770c8d034605df00fcdeea363 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ff64eace548802cdb6f5899fd9ee41bc);
#
#
#         var popup_5014c9753309a1190b42b1b0cab81206 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a49eb3cbe9f702fe7c63c693e8331c4f = $(`&lt;div id=&quot;html_a49eb3cbe9f702fe7c63c693e8331c4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5014c9753309a1190b42b1b0cab81206.setContent(html_a49eb3cbe9f702fe7c63c693e8331c4f);
#
#
#
#         marker_239720d770c8d034605df00fcdeea363.bindPopup(popup_5014c9753309a1190b42b1b0cab81206)
#         ;
#
#
#
#
#             var marker_7b04bca7cd016159ad14e11d12eefda5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ff64eace548802cdb6f5899fd9ee41bc);
#
#
#         var popup_403e5953a58d01c68baaa58d61b911f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb516e77fbc7bf7a5e943e37f891ffa8 = $(`&lt;div id=&quot;html_cb516e77fbc7bf7a5e943e37f891ffa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_403e5953a58d01c68baaa58d61b911f6.setContent(html_cb516e77fbc7bf7a5e943e37f891ffa8);
#
#
#
#         marker_7b04bca7cd016159ad14e11d12eefda5.bindPopup(popup_403e5953a58d01c68baaa58d61b911f6)
#         ;
#
#
#
#
#             var marker_b1c8e8f2d23520e53aa38ae8380355dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ff64eace548802cdb6f5899fd9ee41bc);
#
#
#         var popup_02a5ce8b6446551067554a29239f0da6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2fab6383782ddfdc0db48a871351dd9 = $(`&lt;div id=&quot;html_d2fab6383782ddfdc0db48a871351dd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_02a5ce8b6446551067554a29239f0da6.setContent(html_d2fab6383782ddfdc0db48a871351dd9);
#
#
#
#         marker_b1c8e8f2d23520e53aa38ae8380355dc.bindPopup(popup_02a5ce8b6446551067554a29239f0da6)
#         ;
#
#
#
#
#             var marker_9891644bea6043847f9206150e478430 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ff64eace548802cdb6f5899fd9ee41bc);
#
#
#         var popup_68d2a9b2f5764410ee94ec38b6ebe5ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_075648c62b3f580a13580d7788772ee3 = $(`&lt;div id=&quot;html_075648c62b3f580a13580d7788772ee3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_68d2a9b2f5764410ee94ec38b6ebe5ac.setContent(html_075648c62b3f580a13580d7788772ee3);
#
#
#
#         marker_9891644bea6043847f9206150e478430.bindPopup(popup_68d2a9b2f5764410ee94ec38b6ebe5ac)
#         ;
#
#
#
#
#             var marker_30449a02aed30f8b65a8ded3726c2970 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ff64eace548802cdb6f5899fd9ee41bc);
#
#
#         var popup_86ecdf4dddd39ea190ece3dcd482d0d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad4e9179506b9e70efafccce123f66d5 = $(`&lt;div id=&quot;html_ad4e9179506b9e70efafccce123f66d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_86ecdf4dddd39ea190ece3dcd482d0d8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d722539f4076b012406e6ade1aa3282 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d722539f4076b012406e6ade1aa3282&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d722539f4076b012406e6ade1aa3282 = L.map(
#                 &quot;map_6d722539f4076b012406e6ade1aa3282&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3211b4fb63e5e5adf9995c32b10a16e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3211b4fb63e5e5adf9995c32b10a16e3.addTo(map_6d722539f4076b012406e6ade1aa3282);
#
#
#             var feature_group_905568fb075c0e136a39d52336f5e53e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e6d90aef32869ea5414ac3cfd11ed6fb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_905568fb075c0e136a39d52336f5e53e);
#
#
#         var popup_414db31f59c6854e4f55d9824a92b355 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da21523081136b0056639f95e9d47730 = $(`&lt;div id=&quot;html_da21523081136b0056639f95e9d47730&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_414db31f59c6854e4f55d9824a92b355.setContent(html_da21523081136b0056639f95e9d47730);
#
#
#
#         marker_e6d90aef32869ea5414ac3cfd11ed6fb.bindPopup(popup_414db31f59c6854e4f55d9824a92b355)
#         ;
#
#
#
#
#             var marker_09b8702e85f4a8881ef2cd5a69c4dcd2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_905568fb075c0e136a39d52336f5e53e);
#
#
#         var popup_9f9f22b2fee04dec03302e1f5c53c834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dadf0a1e8c088eec4a420b947b7f192 = $(`&lt;div id=&quot;html_2dadf0a1e8c088eec4a420b947b7f192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9f9f22b2fee04dec03302e1f5c53c834.setContent(html_2dadf0a1e8c088eec4a420b947b7f192);
#
#
#
#         marker_09b8702e85f4a8881ef2cd5a69c4dcd2.bindPopup(popup_9f9f22b2fee04dec03302e1f5c53c834)
#         ;
#
#
#
#
#             var marker_9a04f98c5273ab860d48fc425ebddfc3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_905568fb075c0e136a39d52336f5e53e);
#
#
#         var popup_382ccf71cff7b9720580a7196849c154 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43d3236c2d1acfcd074a3d45b0d71b14 = $(`&lt;div id=&quot;html_43d3236c2d1acfcd074a3d45b0d71b14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_382ccf71cff7b9720580a7196849c154.setContent(html_43d3236c2d1acfcd074a3d45b0d71b14);
#
#
#
#         marker_9a04f98c5273ab860d48fc425ebddfc3.bindPopup(popup_382ccf71cff7b9720580a7196849c154)
#         ;
#
#
#
#
#             var marker_d595527f93852c8b7665322fead231e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_905568fb075c0e136a39d52336f5e53e);
#
#
#         var popup_306b9a1963cee22be30452b004982ab8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f9f79cbfdbf4cf750fd8c79350cded9 = $(`&lt;div id=&quot;html_0f9f79cbfdbf4cf750fd8c79350cded9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_306b9a1963cee22be30452b004982ab8.setContent(html_0f9f79cbfdbf4cf750fd8c79350cded9);
#
#
#
#         marker_d595527f93852c8b7665322fead231e5.bindPopup(popup_306b9a1963cee22be30452b004982ab8)
#         ;
#
#
#
#
#             var marker_f2bec8b2ff12a533f0a450a6acb005fc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_905568fb075c0e136a39d52336f5e53e);
#
#
#         var popup_cc78d0f2df919c2a81880be6ba56d695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b806e51f2977a301f68ceea87437dc3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b806e51f2977a301f68ceea87437dc3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b806e51f2977a301f68ceea87437dc3e = L.map(
#                 &quot;map_b806e51f2977a301f68ceea87437dc3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71043f2b1a58bab3a8d5b4cf47b35ecc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71043f2b1a58bab3a8d5b4cf47b35ecc.addTo(map_b806e51f2977a301f68ceea87437dc3e);
#
#
#             var feature_group_d27aefc609100d7fce34ef8681b33f7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d27aefc609100d7fce34ef8681b33f7b.addTo(map_b806e51f2977a301f68ceea87437dc3e);
#
#
#             var feature_group_sub_group_04b4b393fc90bdac151aa55f8a03cd07 = L.featureGroup.subGroup(
#                 feature_group_d27aefc609100d7fce34ef8681b33f7b
#             );
#
#
#             var marker_6d9cb157eda4a9dfc6c989c271e4ea96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_04b4b393fc90bdac151aa55f8a03cd07);
#
#
#         var popup_3c5e25d5348f941c2be6346a8cdff8c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68022837944048b3df0892edc010cd76 = $(`&lt;div id=&quot;html_68022837944048b3df0892edc010cd76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3c5e25d5348f941c2be6346a8cdff8c1.setContent(html_68022837944048b3df0892edc010cd76);
#
#
#
#         marker_6d9cb157eda4a9dfc6c989c271e4ea96.bindPopup(popup_3c5e25d5348f941c2be6346a8cdff8c1)
#         ;
#
#
#
#
#             var marker_b4bb8befb0d953fee0f6e041eace1c2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_04b4b393fc90bdac151aa55f8a03cd07);
#
#
#         var popup_1cd43f2f68535ce18bb44453a19ad434 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b35c74788c6e376c0fd71377f08a06c = $(`&lt;div id=&quot;html_5b35c74788c6e376c0fd71377f08a06c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1cd43f2f68535ce18bb44453a19ad434.setContent(html_5b35c74788c6e376c0fd71377f08a06c);
#
#
#
#         marker_b4bb8befb0d953fee0f6e041eace1c2f.bindPopup(popup_1cd43f2f68535ce18bb44453a19ad434)
#         ;
#
#
#
#
#             var marker_7e68e9c4f8a309c1a271e30193aacc83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_04b4b393fc90bdac151aa55f8a03cd07);
#
#
#         var popup_83ef6692402a93401398176ba9b38c7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c41cec26a0f3a80161fd7ecbc575cb72 = $(`&lt;div id=&quot;html_c41cec26a0f3a80161fd7ecbc575cb72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_83ef6692402a93401398176ba9b38c7d.setContent(html_c41cec26a0f3a80161fd7ecbc575cb72);
#
#
#
#         marker_7e68e9c4f8a309c1a271e30193aacc83.bindPopup(popup_83ef6692402a93401398176ba9b38c7d)
#         ;
#
#
#
#
#             var marker_69c3a0cd2240fa31802d5d5e42022176 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_04b4b393fc90bdac151aa55f8a03cd07);
#
#
#         var popup_0c9c64ace1844ebc108cac31e68aef70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e3808271b57b925d277c0db6c58a070 = $(`&lt;div id=&quot;html_9e3808271b57b925d277c0db6c58a070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0c9c64ace1844ebc108cac31e68aef70.setContent(html_9e3808271b57b925d277c0db6c58a070);
#
#
#
#         marker_
