# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66c9e511e7c1bf6fd951ea27e7d1ef44 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66c9e511e7c1bf6fd951ea27e7d1ef44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66c9e511e7c1bf6fd951ea27e7d1ef44 = L.map(
#                 &quot;map_66c9e511e7c1bf6fd951ea27e7d1ef44&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a781158a99116715fc316a8e96f201ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a781158a99116715fc316a8e96f201ee.addTo(map_66c9e511e7c1bf6fd951ea27e7d1ef44);
#
#
#             var marker_80278a3a6eb650ce61ea527fa5f2101a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_66c9e511e7c1bf6fd951ea27e7d1ef44);
#
#
#         var popup_a3d0843693169f0d2d053b2f86207577 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c4a4169769080de398b71767a5d229f = $(`&lt;div id=&quot;html_1c4a4169769080de398b71767a5d229f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a3d0843693169f0d2d053b2f86207577.setContent(html_1c4a4169769080de398b71767a5d229f);
#
#
#
#         marker_80278a3a6eb650ce61ea527fa5f2101a.bindPopup(popup_a3d0843693169f0d2d053b2f86207577)
#         ;
#
#
#
#
#             var marker_070052ada1640ead187ad35c858f3c95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_66c9e511e7c1bf6fd951ea27e7d1ef44);
#
#
#         var popup_52b9493fe9135b3b68e0b8c37e1aee2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea7e2997b29a70a4cd497868dc7c9026 = $(`&lt;div id=&quot;html_ea7e2997b29a70a4cd497868dc7c9026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52b9493fe9135b3b68e0b8c37e1aee2a.setContent(html_ea7e2997b29a70a4cd497868dc7c9026);
#
#
#
#         marker_070052ada1640ead187ad35c858f3c95.bindPopup(popup_52b9493fe9135b3b68e0b8c37e1aee2a)
#         ;
#
#
#
#
#             var marker_02bf1c41cd0741c111534e02f460ede7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_66c9e511e7c1bf6fd951ea27e7d1ef44);
#
#
#         var popup_f34ce3ca2a7277d231d38ef2449b6a9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7723700bb70fffac20d30fe3377fab77 = $(`&lt;div id=&quot;html_7723700bb70fffac20d30fe3377fab77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f34ce3ca2a7277d231d38ef2449b6a9f.setContent(html_7723700bb70fffac20d30fe3377fab77);
#
#
#
#         marker_02bf1c41cd0741c111534e02f460ede7.bindPopup(popup_f34ce3ca2a7277d231d38ef2449b6a9f)
#         ;
#
#
#
#
#             var marker_86abb48cf009ece6dd70e86508ef8ab0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_66c9e511e7c1bf6fd951ea27e7d1ef44);
#
#
#         var popup_285393d723746dc376aa2126af67e43d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0eb246765c8f17a8fb7b7d2942b4880d = $(`&lt;div id=&quot;html_0eb246765c8f17a8fb7b7d2942b4880d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_285393d723746dc376aa2126af67e43d.setContent(html_0eb246765c8f17a8fb7b7d2942b4880d);
#
#
#
#         marker_86abb48cf009ece6dd70e86508ef8ab0.bindPopup(popup_285393d723746dc376aa2126af67e43d)
#         ;
#
#
#
#
#             var marker_7b0f28f673c402d3204863af5bf86144 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_66c9e511e7c1bf6fd951ea27e7d1ef44);
#
#
#         var popup_9a36bad13364e9448d41a66e9e5645b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5dd452c1493ed8d0166240259b0c365 = $(`&lt;div id=&quot;html_b5dd452c1493ed8d0166240259b0c365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9a36bad13364e9448d41a66e9e5645

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5c422f7ee65b321f1571d742a5c93f3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5c422f7ee65b321f1571d742a5c93f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5c422f7ee65b321f1571d742a5c93f3 = L.map(
#                 &quot;map_f5c422f7ee65b321f1571d742a5c93f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c35a9498b38395fda98b3acf2a550178 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c35a9498b38395fda98b3acf2a550178.addTo(map_f5c422f7ee65b321f1571d742a5c93f3);
#
#
#             var feature_group_5bec9feb60066021adc9c2c7fb26a631 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b3ad9f308d02b0a1d374c02dd553c208 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5bec9feb60066021adc9c2c7fb26a631);
#
#
#         var popup_7d54131d846a45ca56aa303b85af3cf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93a49dd5240c77c782644a141d6cd054 = $(`&lt;div id=&quot;html_93a49dd5240c77c782644a141d6cd054&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7d54131d846a45ca56aa303b85af3cf7.setContent(html_93a49dd5240c77c782644a141d6cd054);
#
#
#
#         marker_b3ad9f308d02b0a1d374c02dd553c208.bindPopup(popup_7d54131d846a45ca56aa303b85af3cf7)
#         ;
#
#
#
#
#             var marker_b4f73b0fca9d886a7ffffb6e53b09cb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5bec9feb60066021adc9c2c7fb26a631);
#
#
#         var popup_6730484da3cb93d05c7948d6c42edcfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_815442f3924fdf8261ef8dc941cce4b8 = $(`&lt;div id=&quot;html_815442f3924fdf8261ef8dc941cce4b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6730484da3cb93d05c7948d6c42edcfa.setContent(html_815442f3924fdf8261ef8dc941cce4b8);
#
#
#
#         marker_b4f73b0fca9d886a7ffffb6e53b09cb0.bindPopup(popup_6730484da3cb93d05c7948d6c42edcfa)
#         ;
#
#
#
#
#             var marker_a2f8119dc80d9425eee65d7745f0720d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5bec9feb60066021adc9c2c7fb26a631);
#
#
#         var popup_88450d3bce17b16141b5b097655c4bc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_444b8dcb4d1752a877a9ba2f2c6481d2 = $(`&lt;div id=&quot;html_444b8dcb4d1752a877a9ba2f2c6481d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_88450d3bce17b16141b5b097655c4bc3.setContent(html_444b8dcb4d1752a877a9ba2f2c6481d2);
#
#
#
#         marker_a2f8119dc80d9425eee65d7745f0720d.bindPopup(popup_88450d3bce17b16141b5b097655c4bc3)
#         ;
#
#
#
#
#             var marker_a3eac809c682c0549e07f210f66219fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5bec9feb60066021adc9c2c7fb26a631);
#
#
#         var popup_c6dd0ee3e63b82cbf7e41a08a5b0b43e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9921bc777f12343c54748a8d76c3ede = $(`&lt;div id=&quot;html_b9921bc777f12343c54748a8d76c3ede&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c6dd0ee3e63b82cbf7e41a08a5b0b43e.setContent(html_b9921bc777f12343c54748a8d76c3ede);
#
#
#
#         marker_a3eac809c682c0549e07f210f66219fe.bindPopup(popup_c6dd0ee3e63b82cbf7e41a08a5b0b43e)
#         ;
#
#
#
#
#             var marker_9323b924b93c4685b518e271b4ea736d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5bec9feb60066021adc9c2c7fb26a631);
#
#
#         var popup_843c7826906fb3adffe3bae8cace8261 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37fd33ed3e0ef88b8a4213a9f88dbc75 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37fd33ed3e0ef88b8a4213a9f88dbc75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37fd33ed3e0ef88b8a4213a9f88dbc75 = L.map(
#                 &quot;map_37fd33ed3e0ef88b8a4213a9f88dbc75&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8937921900d4d5ce8a1118c7c91c85bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8937921900d4d5ce8a1118c7c91c85bf.addTo(map_37fd33ed3e0ef88b8a4213a9f88dbc75);
#
#
#             var feature_group_bf9e574752c61cf55cefff80da8f2fbf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bf9e574752c61cf55cefff80da8f2fbf.addTo(map_37fd33ed3e0ef88b8a4213a9f88dbc75);
#
#
#             var feature_group_sub_group_48c9dd9b1e71b36f3f2a3947292d968d = L.featureGroup.subGroup(
#                 feature_group_bf9e574752c61cf55cefff80da8f2fbf
#             );
#
#
#             var marker_9ad0f869e28813c6c12d7e722bcf8a25 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_48c9dd9b1e71b36f3f2a3947292d968d);
#
#
#         var popup_a7060a5896b64b67d1b66fa73420e9fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd5d58836e7651ce243060f41afcc197 = $(`&lt;div id=&quot;html_dd5d58836e7651ce243060f41afcc197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a7060a5896b64b67d1b66fa73420e9fc.setContent(html_dd5d58836e7651ce243060f41afcc197);
#
#
#
#         marker_9ad0f869e28813c6c12d7e722bcf8a25.bindPopup(popup_a7060a5896b64b67d1b66fa73420e9fc)
#         ;
#
#
#
#
#             var marker_c23161e373a301efb7e67edaaa68345e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_48c9dd9b1e71b36f3f2a3947292d968d);
#
#
#         var popup_84a180f76e7d350eef6018fa7832f84e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e523d00d474750091a7fece3b472588 = $(`&lt;div id=&quot;html_3e523d00d474750091a7fece3b472588&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_84a180f76e7d350eef6018fa7832f84e.setContent(html_3e523d00d474750091a7fece3b472588);
#
#
#
#         marker_c23161e373a301efb7e67edaaa68345e.bindPopup(popup_84a180f76e7d350eef6018fa7832f84e)
#         ;
#
#
#
#
#             var marker_b12b5597a1b8fc247c47bbe4d022529d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_48c9dd9b1e71b36f3f2a3947292d968d);
#
#
#         var popup_c63082128aa99dfc5db2690b0b971339 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef42d5f06dae8ba005a2828b66cdf17e = $(`&lt;div id=&quot;html_ef42d5f06dae8ba005a2828b66cdf17e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c63082128aa99dfc5db2690b0b971339.setContent(html_ef42d5f06dae8ba005a2828b66cdf17e);
#
#
#
#         marker_b12b5597a1b8fc247c47bbe4d022529d.bindPopup(popup_c63082128aa99dfc5db2690b0b971339)
#         ;
#
#
#
#
#             var marker_91a6e37e3307e1dc0ddcf05e6a72cc70 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_48c9dd9b1e71b36f3f2a3947292d968d);
#
#
#         var popup_07100da046af77ce5574e9469b21d2e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b030ca59379c201523cf1c0c26487359 = $(`&lt;div id=&quot;html_b030ca59379c201523cf1c0c26487359&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_07100da046af77ce5574e9469b21d2e8.setContent(html_b030ca59379c201523cf1c0c26487359);
#
#
#
#         mark
