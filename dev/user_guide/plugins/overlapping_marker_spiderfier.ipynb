# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdb4e3543d24e0f6296ac759a8db7158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdb4e3543d24e0f6296ac759a8db7158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdb4e3543d24e0f6296ac759a8db7158 = L.map(
#                 &quot;map_bdb4e3543d24e0f6296ac759a8db7158&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec3c2168d49330d84df8916c23ee8d20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec3c2168d49330d84df8916c23ee8d20.addTo(map_bdb4e3543d24e0f6296ac759a8db7158);
#
#
#             var marker_7a764de93b319be9fb3023672121061c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bdb4e3543d24e0f6296ac759a8db7158);
#
#
#         var popup_2b700f486d41e5b305d5d6645bcbcff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cba63ee8667a2466a3b384be3c5954f5 = $(`&lt;div id=&quot;html_cba63ee8667a2466a3b384be3c5954f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2b700f486d41e5b305d5d6645bcbcff4.setContent(html_cba63ee8667a2466a3b384be3c5954f5);
#
#
#
#         marker_7a764de93b319be9fb3023672121061c.bindPopup(popup_2b700f486d41e5b305d5d6645bcbcff4)
#         ;
#
#
#
#
#             var marker_cceeecfc494d1f430586ca1f975611a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bdb4e3543d24e0f6296ac759a8db7158);
#
#
#         var popup_eeb616dcb40f5d6ca403aba643f33487 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0631224172b6134ed85f4bff31286a57 = $(`&lt;div id=&quot;html_0631224172b6134ed85f4bff31286a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eeb616dcb40f5d6ca403aba643f33487.setContent(html_0631224172b6134ed85f4bff31286a57);
#
#
#
#         marker_cceeecfc494d1f430586ca1f975611a6.bindPopup(popup_eeb616dcb40f5d6ca403aba643f33487)
#         ;
#
#
#
#
#             var marker_98fdf49b3c3cbb37ed7b0da4893ad42e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bdb4e3543d24e0f6296ac759a8db7158);
#
#
#         var popup_ae79ac84d6f2b68dbe413a1690c40816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36daa6f9df1f4eefcba370aa45031165 = $(`&lt;div id=&quot;html_36daa6f9df1f4eefcba370aa45031165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ae79ac84d6f2b68dbe413a1690c40816.setContent(html_36daa6f9df1f4eefcba370aa45031165);
#
#
#
#         marker_98fdf49b3c3cbb37ed7b0da4893ad42e.bindPopup(popup_ae79ac84d6f2b68dbe413a1690c40816)
#         ;
#
#
#
#
#             var marker_233cbc49bdebcc696d7b93bb5b4d47c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bdb4e3543d24e0f6296ac759a8db7158);
#
#
#         var popup_fc42fbf3f96af42a91652921a11c0575 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeb1adf470b87de8a3ce86d7e850c913 = $(`&lt;div id=&quot;html_eeb1adf470b87de8a3ce86d7e850c913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fc42fbf3f96af42a91652921a11c0575.setContent(html_eeb1adf470b87de8a3ce86d7e850c913);
#
#
#
#         marker_233cbc49bdebcc696d7b93bb5b4d47c8.bindPopup(popup_fc42fbf3f96af42a91652921a11c0575)
#         ;
#
#
#
#
#             var marker_1e65438fc2ca1ea8c4175af1738c3d9e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bdb4e3543d24e0f6296ac759a8db7158);
#
#
#         var popup_d64e2d3c715a395a2979c58ff9c971e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a67ed370919a2cc8862fa5398e0d7d0 = $(`&lt;div id=&quot;html_4a67ed370919a2cc8862fa5398e0d7d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d64e2d3c715a395a2979c58ff9c971e1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f0e874e9ab46d0da4c87ed67b9ebbd5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f0e874e9ab46d0da4c87ed67b9ebbd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f0e874e9ab46d0da4c87ed67b9ebbd5 = L.map(
#                 &quot;map_8f0e874e9ab46d0da4c87ed67b9ebbd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50174fc8090dcadd8380374a8079233d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50174fc8090dcadd8380374a8079233d.addTo(map_8f0e874e9ab46d0da4c87ed67b9ebbd5);
#
#
#             var feature_group_7bea58850c3d92e473a185f10df1b9a4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_109855239bfa257b8fb0b5efe06f0f59 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7bea58850c3d92e473a185f10df1b9a4);
#
#
#         var popup_fd3b62fc1c632387bf8b93a1f217358a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e0ffa4add65225ee51c7e5e4c074aaf = $(`&lt;div id=&quot;html_7e0ffa4add65225ee51c7e5e4c074aaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fd3b62fc1c632387bf8b93a1f217358a.setContent(html_7e0ffa4add65225ee51c7e5e4c074aaf);
#
#
#
#         marker_109855239bfa257b8fb0b5efe06f0f59.bindPopup(popup_fd3b62fc1c632387bf8b93a1f217358a)
#         ;
#
#
#
#
#             var marker_97ce011fa70dbba9a2901fefaf7c62cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7bea58850c3d92e473a185f10df1b9a4);
#
#
#         var popup_c07dfaedcefc9352f6f7f2fed8a11e88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a72f04a9e1af857437c5930bdb240650 = $(`&lt;div id=&quot;html_a72f04a9e1af857437c5930bdb240650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c07dfaedcefc9352f6f7f2fed8a11e88.setContent(html_a72f04a9e1af857437c5930bdb240650);
#
#
#
#         marker_97ce011fa70dbba9a2901fefaf7c62cd.bindPopup(popup_c07dfaedcefc9352f6f7f2fed8a11e88)
#         ;
#
#
#
#
#             var marker_2bcc31278b0c0f41bb1b9d0e86a94b18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7bea58850c3d92e473a185f10df1b9a4);
#
#
#         var popup_6ff4d71bbf2029b36c53e9c0d3a975e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f057f3ef389cd6ded82faa7007e4ab9 = $(`&lt;div id=&quot;html_0f057f3ef389cd6ded82faa7007e4ab9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6ff4d71bbf2029b36c53e9c0d3a975e1.setContent(html_0f057f3ef389cd6ded82faa7007e4ab9);
#
#
#
#         marker_2bcc31278b0c0f41bb1b9d0e86a94b18.bindPopup(popup_6ff4d71bbf2029b36c53e9c0d3a975e1)
#         ;
#
#
#
#
#             var marker_0f0f5b3a908ed4747101e5a419121bf9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7bea58850c3d92e473a185f10df1b9a4);
#
#
#         var popup_7a1d3037f777a36dad89fb31b0605ccb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36883db4d3429def6f19bf714afb7a15 = $(`&lt;div id=&quot;html_36883db4d3429def6f19bf714afb7a15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7a1d3037f777a36dad89fb31b0605ccb.setContent(html_36883db4d3429def6f19bf714afb7a15);
#
#
#
#         marker_0f0f5b3a908ed4747101e5a419121bf9.bindPopup(popup_7a1d3037f777a36dad89fb31b0605ccb)
#         ;
#
#
#
#
#             var marker_0766eaba344b5ce9e254605a6e67bb42 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7bea58850c3d92e473a185f10df1b9a4);
#
#
#         var popup_761b71d6f0596e13ceb32db5efc77669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68da826af2193ee07c264ca9e331afd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68da826af2193ee07c264ca9e331afd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68da826af2193ee07c264ca9e331afd0 = L.map(
#                 &quot;map_68da826af2193ee07c264ca9e331afd0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bb51f471e0351a3c6510b2153d08401 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bb51f471e0351a3c6510b2153d08401.addTo(map_68da826af2193ee07c264ca9e331afd0);
#
#
#             var feature_group_bb16889b29648dc8e2ec499e16c31334 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bb16889b29648dc8e2ec499e16c31334.addTo(map_68da826af2193ee07c264ca9e331afd0);
#
#
#             var feature_group_sub_group_4342843f0544dda8706de94b448be868 = L.featureGroup.subGroup(
#                 feature_group_bb16889b29648dc8e2ec499e16c31334
#             );
#
#
#             var marker_ae676bd6f0cc611009455ed415e3d976 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4342843f0544dda8706de94b448be868);
#
#
#         var popup_c834e2c52285f73d4d18de8366e69258 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92ef2c132e9b008fb828e109eb1cb9e6 = $(`&lt;div id=&quot;html_92ef2c132e9b008fb828e109eb1cb9e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c834e2c52285f73d4d18de8366e69258.setContent(html_92ef2c132e9b008fb828e109eb1cb9e6);
#
#
#
#         marker_ae676bd6f0cc611009455ed415e3d976.bindPopup(popup_c834e2c52285f73d4d18de8366e69258)
#         ;
#
#
#
#
#             var marker_9caecdac5daaad74f76c6301d7c8cc89 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4342843f0544dda8706de94b448be868);
#
#
#         var popup_f2a2fdeb83b6d56cac83e080c5b1d728 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19c5818f240da918224a80d2c0dd23bf = $(`&lt;div id=&quot;html_19c5818f240da918224a80d2c0dd23bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2a2fdeb83b6d56cac83e080c5b1d728.setContent(html_19c5818f240da918224a80d2c0dd23bf);
#
#
#
#         marker_9caecdac5daaad74f76c6301d7c8cc89.bindPopup(popup_f2a2fdeb83b6d56cac83e080c5b1d728)
#         ;
#
#
#
#
#             var marker_703575d3dc4a09b7f8d38387e943fb49 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4342843f0544dda8706de94b448be868);
#
#
#         var popup_4f1af3d94687352c7f2869c9ce533676 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9860a94ed7143110e0975443218f70b = $(`&lt;div id=&quot;html_c9860a94ed7143110e0975443218f70b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4f1af3d94687352c7f2869c9ce533676.setContent(html_c9860a94ed7143110e0975443218f70b);
#
#
#
#         marker_703575d3dc4a09b7f8d38387e943fb49.bindPopup(popup_4f1af3d94687352c7f2869c9ce533676)
#         ;
#
#
#
#
#             var marker_1783477ff93d59f9aeec308cdf9c8df1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4342843f0544dda8706de94b448be868);
#
#
#         var popup_c50f140d06c7bb570a8a1fabf083b6e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50971276beb2f0a34f30f7429fe1931e = $(`&lt;div id=&quot;html_50971276beb2f0a34f30f7429fe1931e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c50f140d06c7bb570a8a1fabf083b6e6.setContent(html_50971276beb2f0a34f30f7429fe1931e);
#
#
#
#         marker_
