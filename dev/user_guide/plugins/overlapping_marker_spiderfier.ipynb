# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f633d4c81e0f4275c3927adc5884583 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f633d4c81e0f4275c3927adc5884583&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f633d4c81e0f4275c3927adc5884583 = L.map(
#                 &quot;map_5f633d4c81e0f4275c3927adc5884583&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3892b5777dabc00d8b47298938d4a3f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3892b5777dabc00d8b47298938d4a3f5.addTo(map_5f633d4c81e0f4275c3927adc5884583);
#
#
#             var marker_215577662e6955b8a083fe786d97f907 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5f633d4c81e0f4275c3927adc5884583);
#
#
#         var popup_200b2a93db2f3c246d7329efe6375e9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e595d0fb0368fe348bd90b4e6c114633 = $(`&lt;div id=&quot;html_e595d0fb0368fe348bd90b4e6c114633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_200b2a93db2f3c246d7329efe6375e9d.setContent(html_e595d0fb0368fe348bd90b4e6c114633);
#
#
#
#         marker_215577662e6955b8a083fe786d97f907.bindPopup(popup_200b2a93db2f3c246d7329efe6375e9d)
#         ;
#
#
#
#
#             var marker_f1fd424611cc9a9dcc2b8142e32cb405 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5f633d4c81e0f4275c3927adc5884583);
#
#
#         var popup_d61a32536e8b384f916a666d39a97ca7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dccda1f0b3f8541df6297eeb8c1b38e2 = $(`&lt;div id=&quot;html_dccda1f0b3f8541df6297eeb8c1b38e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d61a32536e8b384f916a666d39a97ca7.setContent(html_dccda1f0b3f8541df6297eeb8c1b38e2);
#
#
#
#         marker_f1fd424611cc9a9dcc2b8142e32cb405.bindPopup(popup_d61a32536e8b384f916a666d39a97ca7)
#         ;
#
#
#
#
#             var marker_f8cd3f469f445ee055bc27aca48ee71c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5f633d4c81e0f4275c3927adc5884583);
#
#
#         var popup_b1b3dc5cb604cf10cf7e9a91541ca8d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08a5c901d81ab95ec7911b36b7310ed7 = $(`&lt;div id=&quot;html_08a5c901d81ab95ec7911b36b7310ed7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b1b3dc5cb604cf10cf7e9a91541ca8d7.setContent(html_08a5c901d81ab95ec7911b36b7310ed7);
#
#
#
#         marker_f8cd3f469f445ee055bc27aca48ee71c.bindPopup(popup_b1b3dc5cb604cf10cf7e9a91541ca8d7)
#         ;
#
#
#
#
#             var marker_3a482f2653185c4ef4bdbf57368f134a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5f633d4c81e0f4275c3927adc5884583);
#
#
#         var popup_55ff5db5496a6af3c736aed3a6858dde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd0f53423d5d6dae002e927089323282 = $(`&lt;div id=&quot;html_dd0f53423d5d6dae002e927089323282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_55ff5db5496a6af3c736aed3a6858dde.setContent(html_dd0f53423d5d6dae002e927089323282);
#
#
#
#         marker_3a482f2653185c4ef4bdbf57368f134a.bindPopup(popup_55ff5db5496a6af3c736aed3a6858dde)
#         ;
#
#
#
#
#             var marker_4ecada69889c3f88206662dfddc10deb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5f633d4c81e0f4275c3927adc5884583);
#
#
#         var popup_be265b43fbc206990b874c08f6d18778 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23c6feb207a7073bfeed3a417b248089 = $(`&lt;div id=&quot;html_23c6feb207a7073bfeed3a417b248089&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_be265b43fbc206990b874c08f6d187

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94c33088553fec2f85acdcb4a745ebf5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94c33088553fec2f85acdcb4a745ebf5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94c33088553fec2f85acdcb4a745ebf5 = L.map(
#                 &quot;map_94c33088553fec2f85acdcb4a745ebf5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f4ec51fa8e34d2ed98564d353bd6ac9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f4ec51fa8e34d2ed98564d353bd6ac9.addTo(map_94c33088553fec2f85acdcb4a745ebf5);
#
#
#             var feature_group_76b2e5fa2045f32fc902d1a446544557 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_479f6c565ba7694226cc8daae28be98c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_76b2e5fa2045f32fc902d1a446544557);
#
#
#         var popup_e18dc256bf07d9e17af6076d1207cf88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17d4ee8c365db7fdf0a3406ff1a40ade = $(`&lt;div id=&quot;html_17d4ee8c365db7fdf0a3406ff1a40ade&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e18dc256bf07d9e17af6076d1207cf88.setContent(html_17d4ee8c365db7fdf0a3406ff1a40ade);
#
#
#
#         marker_479f6c565ba7694226cc8daae28be98c.bindPopup(popup_e18dc256bf07d9e17af6076d1207cf88)
#         ;
#
#
#
#
#             var marker_c8765ab3bfe611b196cb81bf760552e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_76b2e5fa2045f32fc902d1a446544557);
#
#
#         var popup_9a5d596fc7a87e8a3f38afd5cdc70f94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bc68ccc36e6a6108f2ac87b4f43cfb2 = $(`&lt;div id=&quot;html_4bc68ccc36e6a6108f2ac87b4f43cfb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9a5d596fc7a87e8a3f38afd5cdc70f94.setContent(html_4bc68ccc36e6a6108f2ac87b4f43cfb2);
#
#
#
#         marker_c8765ab3bfe611b196cb81bf760552e5.bindPopup(popup_9a5d596fc7a87e8a3f38afd5cdc70f94)
#         ;
#
#
#
#
#             var marker_09479a31fb7893e37be13f7c7d9fbc18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_76b2e5fa2045f32fc902d1a446544557);
#
#
#         var popup_3b07ba2126b613d5db6534b724d75208 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b338c880abd32eceed9b4a2a8fe7596 = $(`&lt;div id=&quot;html_1b338c880abd32eceed9b4a2a8fe7596&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3b07ba2126b613d5db6534b724d75208.setContent(html_1b338c880abd32eceed9b4a2a8fe7596);
#
#
#
#         marker_09479a31fb7893e37be13f7c7d9fbc18.bindPopup(popup_3b07ba2126b613d5db6534b724d75208)
#         ;
#
#
#
#
#             var marker_7c78eef70ae619a2af34e2e742ecba5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_76b2e5fa2045f32fc902d1a446544557);
#
#
#         var popup_5594dc81d969f094502c907fd968652d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a24d8a43b047ed9443c5cf458483eba = $(`&lt;div id=&quot;html_6a24d8a43b047ed9443c5cf458483eba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5594dc81d969f094502c907fd968652d.setContent(html_6a24d8a43b047ed9443c5cf458483eba);
#
#
#
#         marker_7c78eef70ae619a2af34e2e742ecba5b.bindPopup(popup_5594dc81d969f094502c907fd968652d)
#         ;
#
#
#
#
#             var marker_1420f607b24f840f127d75a1ae825819 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_76b2e5fa2045f32fc902d1a446544557);
#
#
#         var popup_f148fff3bf7e5ddf86f38eb94d5ea1f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97e19ca15a774bbb5ba31651393c8d3c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97e19ca15a774bbb5ba31651393c8d3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97e19ca15a774bbb5ba31651393c8d3c = L.map(
#                 &quot;map_97e19ca15a774bbb5ba31651393c8d3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d390a5a5683948e87a2dbae79bc5a364 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d390a5a5683948e87a2dbae79bc5a364.addTo(map_97e19ca15a774bbb5ba31651393c8d3c);
#
#
#             var feature_group_0d66efd14b52b500c93c0b33c65658eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0d66efd14b52b500c93c0b33c65658eb.addTo(map_97e19ca15a774bbb5ba31651393c8d3c);
#
#
#             var feature_group_sub_group_be742add84fe4ef92c42ee32cbe29695 = L.featureGroup.subGroup(
#                 feature_group_0d66efd14b52b500c93c0b33c65658eb
#             );
#
#
#             var marker_c5c749d0564a0d8770ef37265a8960e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_be742add84fe4ef92c42ee32cbe29695);
#
#
#         var popup_1276a43fe73dbf1fd2aeeb1da6da9000 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcbaf0f73c756dafb0e91cf137f66ae3 = $(`&lt;div id=&quot;html_bcbaf0f73c756dafb0e91cf137f66ae3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1276a43fe73dbf1fd2aeeb1da6da9000.setContent(html_bcbaf0f73c756dafb0e91cf137f66ae3);
#
#
#
#         marker_c5c749d0564a0d8770ef37265a8960e1.bindPopup(popup_1276a43fe73dbf1fd2aeeb1da6da9000)
#         ;
#
#
#
#
#             var marker_77d715583c7df59b4d32e9c74c22b205 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_be742add84fe4ef92c42ee32cbe29695);
#
#
#         var popup_745cc417453338f049eb0c28eeeba37e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64dd0aa050ca395e4c224478eb15d760 = $(`&lt;div id=&quot;html_64dd0aa050ca395e4c224478eb15d760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_745cc417453338f049eb0c28eeeba37e.setContent(html_64dd0aa050ca395e4c224478eb15d760);
#
#
#
#         marker_77d715583c7df59b4d32e9c74c22b205.bindPopup(popup_745cc417453338f049eb0c28eeeba37e)
#         ;
#
#
#
#
#             var marker_03c7416fef3e1fe4f6348bb6078d6fa0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_be742add84fe4ef92c42ee32cbe29695);
#
#
#         var popup_49398bd0a8cac4563064c44485bd8cf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77956309fa01455da763897436d69966 = $(`&lt;div id=&quot;html_77956309fa01455da763897436d69966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_49398bd0a8cac4563064c44485bd8cf9.setContent(html_77956309fa01455da763897436d69966);
#
#
#
#         marker_03c7416fef3e1fe4f6348bb6078d6fa0.bindPopup(popup_49398bd0a8cac4563064c44485bd8cf9)
#         ;
#
#
#
#
#             var marker_3dd23693617e76923c43a9245c8a35bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_be742add84fe4ef92c42ee32cbe29695);
#
#
#         var popup_51ec53b7b42a56da61f3bc18f5a0d5f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ba161a4ca91d4ef1ddac8d471123024 = $(`&lt;div id=&quot;html_5ba161a4ca91d4ef1ddac8d471123024&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_51ec53b7b42a56da61f3bc18f5a0d5f9.setContent(html_5ba161a4ca91d4ef1ddac8d471123024);
#
#
#
#         mark
