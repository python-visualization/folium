# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bd4afa34da47fda04b5b6702218e9d4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bd4afa34da47fda04b5b6702218e9d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bd4afa34da47fda04b5b6702218e9d4 = L.map(
#                 &quot;map_8bd4afa34da47fda04b5b6702218e9d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ede71042b8eec1fef6deff1a04d38a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ede71042b8eec1fef6deff1a04d38a1.addTo(map_8bd4afa34da47fda04b5b6702218e9d4);
#
#
#             var marker_2a60e5099fe4d41ad153862aeae0428d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8bd4afa34da47fda04b5b6702218e9d4);
#
#
#         var popup_70a58ec24d51349bbdda1a1cd0997ea7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9118f031f1049af4a3315ac9c48c9787 = $(`&lt;div id=&quot;html_9118f031f1049af4a3315ac9c48c9787&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_70a58ec24d51349bbdda1a1cd0997ea7.setContent(html_9118f031f1049af4a3315ac9c48c9787);
#
#
#
#         marker_2a60e5099fe4d41ad153862aeae0428d.bindPopup(popup_70a58ec24d51349bbdda1a1cd0997ea7)
#         ;
#
#
#
#
#             var marker_29adb68a3c5afea2761521b0ce0ee32c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8bd4afa34da47fda04b5b6702218e9d4);
#
#
#         var popup_b62648b0cc1c6c47b1d40a85abe46298 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c75446555f491c038eccbcca104b9d3 = $(`&lt;div id=&quot;html_5c75446555f491c038eccbcca104b9d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b62648b0cc1c6c47b1d40a85abe46298.setContent(html_5c75446555f491c038eccbcca104b9d3);
#
#
#
#         marker_29adb68a3c5afea2761521b0ce0ee32c.bindPopup(popup_b62648b0cc1c6c47b1d40a85abe46298)
#         ;
#
#
#
#
#             var marker_52b3f4706af6d46f113145b2137f2817 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8bd4afa34da47fda04b5b6702218e9d4);
#
#
#         var popup_fccd2d29d47a905837387be9979c8df0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc6b5de950cb016636ceaf56a3696ce1 = $(`&lt;div id=&quot;html_cc6b5de950cb016636ceaf56a3696ce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fccd2d29d47a905837387be9979c8df0.setContent(html_cc6b5de950cb016636ceaf56a3696ce1);
#
#
#
#         marker_52b3f4706af6d46f113145b2137f2817.bindPopup(popup_fccd2d29d47a905837387be9979c8df0)
#         ;
#
#
#
#
#             var marker_b723a413482ce178d61ac2816e5fb6b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8bd4afa34da47fda04b5b6702218e9d4);
#
#
#         var popup_9831d4b387b622ff423274f66772bf4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f980ac35a669cdd0fc994b04e118e8d8 = $(`&lt;div id=&quot;html_f980ac35a669cdd0fc994b04e118e8d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9831d4b387b622ff423274f66772bf4a.setContent(html_f980ac35a669cdd0fc994b04e118e8d8);
#
#
#
#         marker_b723a413482ce178d61ac2816e5fb6b2.bindPopup(popup_9831d4b387b622ff423274f66772bf4a)
#         ;
#
#
#
#
#             var marker_5d85f2564ec9b7446ce7fbae4d3a6ec5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8bd4afa34da47fda04b5b6702218e9d4);
#
#
#         var popup_5e008422058a139cf7e132ea8393c88b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f05f2f2a4a7e349576bb115fac0c23aa = $(`&lt;div id=&quot;html_f05f2f2a4a7e349576bb115fac0c23aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e008422058a139cf7e132ea8393c8

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7aa354d14e81478761c85667c4dd410e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7aa354d14e81478761c85667c4dd410e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7aa354d14e81478761c85667c4dd410e = L.map(
#                 &quot;map_7aa354d14e81478761c85667c4dd410e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d29b44e8e765609c5535251dab28871 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d29b44e8e765609c5535251dab28871.addTo(map_7aa354d14e81478761c85667c4dd410e);
#
#
#             var feature_group_5fdd4d68fff2f85569e1068629d5f888 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5e166f808139652e075ded1fabe79118 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5fdd4d68fff2f85569e1068629d5f888);
#
#
#         var popup_df1406a348551ccd5f33b7807f3a23b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173bd0de85a36cf8f5a5a40ba5b02858 = $(`&lt;div id=&quot;html_173bd0de85a36cf8f5a5a40ba5b02858&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_df1406a348551ccd5f33b7807f3a23b5.setContent(html_173bd0de85a36cf8f5a5a40ba5b02858);
#
#
#
#         marker_5e166f808139652e075ded1fabe79118.bindPopup(popup_df1406a348551ccd5f33b7807f3a23b5)
#         ;
#
#
#
#
#             var marker_b0448ab07c212beb030652d97a6308ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5fdd4d68fff2f85569e1068629d5f888);
#
#
#         var popup_8d50cf60ea6f30cf73ff6c84ca54e897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68b22e2cb30deedc836c9f91b02cdd62 = $(`&lt;div id=&quot;html_68b22e2cb30deedc836c9f91b02cdd62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8d50cf60ea6f30cf73ff6c84ca54e897.setContent(html_68b22e2cb30deedc836c9f91b02cdd62);
#
#
#
#         marker_b0448ab07c212beb030652d97a6308ae.bindPopup(popup_8d50cf60ea6f30cf73ff6c84ca54e897)
#         ;
#
#
#
#
#             var marker_7d3bb05a45ec8a2daf74af73d4887921 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5fdd4d68fff2f85569e1068629d5f888);
#
#
#         var popup_1d4a2cbfe18eb9c45031f5c6e2e00f5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d92347f6673b5564fed6198c4638583e = $(`&lt;div id=&quot;html_d92347f6673b5564fed6198c4638583e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1d4a2cbfe18eb9c45031f5c6e2e00f5c.setContent(html_d92347f6673b5564fed6198c4638583e);
#
#
#
#         marker_7d3bb05a45ec8a2daf74af73d4887921.bindPopup(popup_1d4a2cbfe18eb9c45031f5c6e2e00f5c)
#         ;
#
#
#
#
#             var marker_d91cc792e6db8206927363bd0bb3fa91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5fdd4d68fff2f85569e1068629d5f888);
#
#
#         var popup_de80dd42fd190c3deca1e23daec8b2b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed194209014d52ec272913b9cb88d6ff = $(`&lt;div id=&quot;html_ed194209014d52ec272913b9cb88d6ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_de80dd42fd190c3deca1e23daec8b2b3.setContent(html_ed194209014d52ec272913b9cb88d6ff);
#
#
#
#         marker_d91cc792e6db8206927363bd0bb3fa91.bindPopup(popup_de80dd42fd190c3deca1e23daec8b2b3)
#         ;
#
#
#
#
#             var marker_188df9908eed08dbb1c82754a910da9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5fdd4d68fff2f85569e1068629d5f888);
#
#
#         var popup_e558c8e8510a55fb238347784fc24d26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ee6e0fcca9ed858799a4e3db52eb887 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ee6e0fcca9ed858799a4e3db52eb887&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ee6e0fcca9ed858799a4e3db52eb887 = L.map(
#                 &quot;map_1ee6e0fcca9ed858799a4e3db52eb887&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_435e9224962d7517dfda74e4e087f159 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_435e9224962d7517dfda74e4e087f159.addTo(map_1ee6e0fcca9ed858799a4e3db52eb887);
#
#
#             var feature_group_47974b982897cfdac0258901fc0e8400 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_47974b982897cfdac0258901fc0e8400.addTo(map_1ee6e0fcca9ed858799a4e3db52eb887);
#
#
#             var feature_group_sub_group_c7c4afa9f34a38e16f5dec6267e1ac30 = L.featureGroup.subGroup(
#                 feature_group_47974b982897cfdac0258901fc0e8400
#             );
#
#
#             var marker_7ab5f7c8e202cb17b87de1cd8c023ed7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7c4afa9f34a38e16f5dec6267e1ac30);
#
#
#         var popup_5d6b7d5abb65a3947cd259ccd3f98c9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57b17217a99aec44a6632d567d29ad94 = $(`&lt;div id=&quot;html_57b17217a99aec44a6632d567d29ad94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5d6b7d5abb65a3947cd259ccd3f98c9a.setContent(html_57b17217a99aec44a6632d567d29ad94);
#
#
#
#         marker_7ab5f7c8e202cb17b87de1cd8c023ed7.bindPopup(popup_5d6b7d5abb65a3947cd259ccd3f98c9a)
#         ;
#
#
#
#
#             var marker_8cd48f06e79080ed85b5defa89d3fc51 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7c4afa9f34a38e16f5dec6267e1ac30);
#
#
#         var popup_623b133c7529a0eb5299f35796da7314 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a91b20ac2311bd5d4f0abdb06d9f9d7 = $(`&lt;div id=&quot;html_7a91b20ac2311bd5d4f0abdb06d9f9d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_623b133c7529a0eb5299f35796da7314.setContent(html_7a91b20ac2311bd5d4f0abdb06d9f9d7);
#
#
#
#         marker_8cd48f06e79080ed85b5defa89d3fc51.bindPopup(popup_623b133c7529a0eb5299f35796da7314)
#         ;
#
#
#
#
#             var marker_e7f174858ec42dbb4d31ff4a90ded608 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7c4afa9f34a38e16f5dec6267e1ac30);
#
#
#         var popup_3ec1a4e9b2a472e2d6e24553978e528a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73a038963c42bd872af7592c6d858cf6 = $(`&lt;div id=&quot;html_73a038963c42bd872af7592c6d858cf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3ec1a4e9b2a472e2d6e24553978e528a.setContent(html_73a038963c42bd872af7592c6d858cf6);
#
#
#
#         marker_e7f174858ec42dbb4d31ff4a90ded608.bindPopup(popup_3ec1a4e9b2a472e2d6e24553978e528a)
#         ;
#
#
#
#
#             var marker_59e28cb6a886c63255cb0384eaf9b0e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7c4afa9f34a38e16f5dec6267e1ac30);
#
#
#         var popup_db5bc3d7fb07722e269a5b32a2ca99ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a44a8eb5b797e96173dd50e404bfbe12 = $(`&lt;div id=&quot;html_a44a8eb5b797e96173dd50e404bfbe12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_db5bc3d7fb07722e269a5b32a2ca99ad.setContent(html_a44a8eb5b797e96173dd50e404bfbe12);
#
#
#
#         mark
