# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40a55b14f18371ad859b425f76c66ece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40a55b14f18371ad859b425f76c66ece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40a55b14f18371ad859b425f76c66ece = L.map(
#                 &quot;map_40a55b14f18371ad859b425f76c66ece&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81a9f300284f05e8aa5f3f5bc32e7817 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81a9f300284f05e8aa5f3f5bc32e7817.addTo(map_40a55b14f18371ad859b425f76c66ece);
#
#
#             var marker_748806323ea2735acc87052bdf3e3b94 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_40a55b14f18371ad859b425f76c66ece);
#
#
#         var popup_1204cce4a28ac7e06107c2fd2cc59caf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80eeb35d628fff82c79472dd5052fbfd = $(`&lt;div id=&quot;html_80eeb35d628fff82c79472dd5052fbfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1204cce4a28ac7e06107c2fd2cc59caf.setContent(html_80eeb35d628fff82c79472dd5052fbfd);
#
#
#
#         marker_748806323ea2735acc87052bdf3e3b94.bindPopup(popup_1204cce4a28ac7e06107c2fd2cc59caf)
#         ;
#
#
#
#
#             var marker_92aba76ce813adc4d49cb82789f8511d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_40a55b14f18371ad859b425f76c66ece);
#
#
#         var popup_aa9280eb63779b60646549febf2ec587 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9db5c6768d2b752e5bb71a9106e39a1d = $(`&lt;div id=&quot;html_9db5c6768d2b752e5bb71a9106e39a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aa9280eb63779b60646549febf2ec587.setContent(html_9db5c6768d2b752e5bb71a9106e39a1d);
#
#
#
#         marker_92aba76ce813adc4d49cb82789f8511d.bindPopup(popup_aa9280eb63779b60646549febf2ec587)
#         ;
#
#
#
#
#             var marker_1d057a30c6b92ccbb1403333383ba2c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_40a55b14f18371ad859b425f76c66ece);
#
#
#         var popup_4303d780357197bc261342bf8da25c18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8af79434357c279e24e873ce7712cc47 = $(`&lt;div id=&quot;html_8af79434357c279e24e873ce7712cc47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4303d780357197bc261342bf8da25c18.setContent(html_8af79434357c279e24e873ce7712cc47);
#
#
#
#         marker_1d057a30c6b92ccbb1403333383ba2c6.bindPopup(popup_4303d780357197bc261342bf8da25c18)
#         ;
#
#
#
#
#             var marker_e498a8c743cb119c99e583336c0b9be7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_40a55b14f18371ad859b425f76c66ece);
#
#
#         var popup_ab0d7d93c4b481e52432e87358500c90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09a0046827ad9f07b636d9e3c429a077 = $(`&lt;div id=&quot;html_09a0046827ad9f07b636d9e3c429a077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ab0d7d93c4b481e52432e87358500c90.setContent(html_09a0046827ad9f07b636d9e3c429a077);
#
#
#
#         marker_e498a8c743cb119c99e583336c0b9be7.bindPopup(popup_ab0d7d93c4b481e52432e87358500c90)
#         ;
#
#
#
#
#             var marker_e69298f9a941df2384a5711d2408afd1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_40a55b14f18371ad859b425f76c66ece);
#
#
#         var popup_1d1f9468df92ba3bfce5bb8de63d7b7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14d5ada168a695b4fdab3ef77f736e80 = $(`&lt;div id=&quot;html_14d5ada168a695b4fdab3ef77f736e80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1d1f9468df92ba3bfce5bb8de63d7b7a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79899318e08922257cbf1f7a98b9b122 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79899318e08922257cbf1f7a98b9b122&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79899318e08922257cbf1f7a98b9b122 = L.map(
#                 &quot;map_79899318e08922257cbf1f7a98b9b122&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b986119edb9c4ffa8ff3e53b9bd942b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b986119edb9c4ffa8ff3e53b9bd942b5.addTo(map_79899318e08922257cbf1f7a98b9b122);
#
#
#             var feature_group_9172581d7340c0827b0d72443b64c66d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bf9d216025a6a7ce02731c6d50c8320b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9172581d7340c0827b0d72443b64c66d);
#
#
#         var popup_283ebb8b2dd40a4cfd47ee42e7fd3f57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1519959b5242eb5d88f362cfd08e8bcb = $(`&lt;div id=&quot;html_1519959b5242eb5d88f362cfd08e8bcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_283ebb8b2dd40a4cfd47ee42e7fd3f57.setContent(html_1519959b5242eb5d88f362cfd08e8bcb);
#
#
#
#         marker_bf9d216025a6a7ce02731c6d50c8320b.bindPopup(popup_283ebb8b2dd40a4cfd47ee42e7fd3f57)
#         ;
#
#
#
#
#             var marker_f6e3fe6856b78492a76597ac787195a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9172581d7340c0827b0d72443b64c66d);
#
#
#         var popup_6dfe26e463ec22f678a9c8bf4f2db2fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4f620c3ee4175d3ac35cf89406a7c6e = $(`&lt;div id=&quot;html_b4f620c3ee4175d3ac35cf89406a7c6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6dfe26e463ec22f678a9c8bf4f2db2fc.setContent(html_b4f620c3ee4175d3ac35cf89406a7c6e);
#
#
#
#         marker_f6e3fe6856b78492a76597ac787195a0.bindPopup(popup_6dfe26e463ec22f678a9c8bf4f2db2fc)
#         ;
#
#
#
#
#             var marker_3ba7721fdf85f4a8e03fc3c19f73e9ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9172581d7340c0827b0d72443b64c66d);
#
#
#         var popup_60873586d82d70551d3021204a3a62e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1740571196d9094fb6bf731b088490b3 = $(`&lt;div id=&quot;html_1740571196d9094fb6bf731b088490b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_60873586d82d70551d3021204a3a62e6.setContent(html_1740571196d9094fb6bf731b088490b3);
#
#
#
#         marker_3ba7721fdf85f4a8e03fc3c19f73e9ea.bindPopup(popup_60873586d82d70551d3021204a3a62e6)
#         ;
#
#
#
#
#             var marker_8e2946802d056fd88369023a0e417807 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9172581d7340c0827b0d72443b64c66d);
#
#
#         var popup_8a19dc3f5f9dda2f375c3b489e6276e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1c3660d782341628b20f949619b4cae = $(`&lt;div id=&quot;html_a1c3660d782341628b20f949619b4cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8a19dc3f5f9dda2f375c3b489e6276e3.setContent(html_a1c3660d782341628b20f949619b4cae);
#
#
#
#         marker_8e2946802d056fd88369023a0e417807.bindPopup(popup_8a19dc3f5f9dda2f375c3b489e6276e3)
#         ;
#
#
#
#
#             var marker_bc4737792a3b9be8fc145b4946a672bb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9172581d7340c0827b0d72443b64c66d);
#
#
#         var popup_a97efb7003040a3de499cbb6f517c8c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c2e86b4eb8d086ac71210acd2a2fd18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c2e86b4eb8d086ac71210acd2a2fd18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c2e86b4eb8d086ac71210acd2a2fd18 = L.map(
#                 &quot;map_4c2e86b4eb8d086ac71210acd2a2fd18&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51d8f9b3b0e0b5472bea3a67ba3489f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51d8f9b3b0e0b5472bea3a67ba3489f2.addTo(map_4c2e86b4eb8d086ac71210acd2a2fd18);
#
#
#             var feature_group_727dfcf3f762803f21ccc03bb10e9bfa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_727dfcf3f762803f21ccc03bb10e9bfa.addTo(map_4c2e86b4eb8d086ac71210acd2a2fd18);
#
#
#             var feature_group_sub_group_ca0d271581f44ac5bb3953e9b41eb385 = L.featureGroup.subGroup(
#                 feature_group_727dfcf3f762803f21ccc03bb10e9bfa
#             );
#
#
#             var marker_2c4c65f8cc2651580308ab897011bad7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca0d271581f44ac5bb3953e9b41eb385);
#
#
#         var popup_79bf9dc4016a2abf42d2b1637d699a1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce3aa1ea5603da986a455b05b224028c = $(`&lt;div id=&quot;html_ce3aa1ea5603da986a455b05b224028c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_79bf9dc4016a2abf42d2b1637d699a1b.setContent(html_ce3aa1ea5603da986a455b05b224028c);
#
#
#
#         marker_2c4c65f8cc2651580308ab897011bad7.bindPopup(popup_79bf9dc4016a2abf42d2b1637d699a1b)
#         ;
#
#
#
#
#             var marker_7daecd1a6fd66fada8e93ad9145c8bb3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca0d271581f44ac5bb3953e9b41eb385);
#
#
#         var popup_13251fefbbe407f9db5338a97d52e3a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7d32a119e2a8bf80352f1d15eb6b22d = $(`&lt;div id=&quot;html_a7d32a119e2a8bf80352f1d15eb6b22d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_13251fefbbe407f9db5338a97d52e3a1.setContent(html_a7d32a119e2a8bf80352f1d15eb6b22d);
#
#
#
#         marker_7daecd1a6fd66fada8e93ad9145c8bb3.bindPopup(popup_13251fefbbe407f9db5338a97d52e3a1)
#         ;
#
#
#
#
#             var marker_6ed35741960f8b7b9a8e1b3ae679c5b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca0d271581f44ac5bb3953e9b41eb385);
#
#
#         var popup_9d5f3b0227e9c4c243ede07b2becdc9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19b9bd8649ba27148d26805e2eb2dbe9 = $(`&lt;div id=&quot;html_19b9bd8649ba27148d26805e2eb2dbe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9d5f3b0227e9c4c243ede07b2becdc9d.setContent(html_19b9bd8649ba27148d26805e2eb2dbe9);
#
#
#
#         marker_6ed35741960f8b7b9a8e1b3ae679c5b3.bindPopup(popup_9d5f3b0227e9c4c243ede07b2becdc9d)
#         ;
#
#
#
#
#             var marker_f79ef2ab893ad02b4df2afd56ddac1ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ca0d271581f44ac5bb3953e9b41eb385);
#
#
#         var popup_250501a5a90b96f788d3d59631d89c2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_608a993e17e26a46e7addc70a4cf198e = $(`&lt;div id=&quot;html_608a993e17e26a46e7addc70a4cf198e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_250501a5a90b96f788d3d59631d89c2a.setContent(html_608a993e17e26a46e7addc70a4cf198e);
#
#
#
#         marker_
