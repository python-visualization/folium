# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4a99aecc4fa8121fbf0803f33ccd53e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4a99aecc4fa8121fbf0803f33ccd53e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4a99aecc4fa8121fbf0803f33ccd53e = L.map(
#                 &quot;map_c4a99aecc4fa8121fbf0803f33ccd53e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5bb3175e27c7b7d2110c49c89a14c1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5bb3175e27c7b7d2110c49c89a14c1d.addTo(map_c4a99aecc4fa8121fbf0803f33ccd53e);
#
#
#             var marker_3567f799a5af2be45a8ddab063cddf9b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c4a99aecc4fa8121fbf0803f33ccd53e);
#
#
#         var popup_7bcddb9a7c98ef5797466ce1c506ad7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d13c70fb48a58f8c8c674cf493f2ec6b = $(`&lt;div id=&quot;html_d13c70fb48a58f8c8c674cf493f2ec6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7bcddb9a7c98ef5797466ce1c506ad7b.setContent(html_d13c70fb48a58f8c8c674cf493f2ec6b);
#
#
#
#         marker_3567f799a5af2be45a8ddab063cddf9b.bindPopup(popup_7bcddb9a7c98ef5797466ce1c506ad7b)
#         ;
#
#
#
#
#             var marker_3c47114e2d097c8a97fd458d5c93f20d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c4a99aecc4fa8121fbf0803f33ccd53e);
#
#
#         var popup_54898e7e466fa249ba5a23155d863b06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f9babf2907a1a8cc92f3c28a889a0a3 = $(`&lt;div id=&quot;html_0f9babf2907a1a8cc92f3c28a889a0a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_54898e7e466fa249ba5a23155d863b06.setContent(html_0f9babf2907a1a8cc92f3c28a889a0a3);
#
#
#
#         marker_3c47114e2d097c8a97fd458d5c93f20d.bindPopup(popup_54898e7e466fa249ba5a23155d863b06)
#         ;
#
#
#
#
#             var marker_c75d5ed061c2d98d891727ee5263f8f5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c4a99aecc4fa8121fbf0803f33ccd53e);
#
#
#         var popup_5ab77be818f94ee4917eaddf24084c22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17bfcd6c3f984fe571142ff0ced63f58 = $(`&lt;div id=&quot;html_17bfcd6c3f984fe571142ff0ced63f58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5ab77be818f94ee4917eaddf24084c22.setContent(html_17bfcd6c3f984fe571142ff0ced63f58);
#
#
#
#         marker_c75d5ed061c2d98d891727ee5263f8f5.bindPopup(popup_5ab77be818f94ee4917eaddf24084c22)
#         ;
#
#
#
#
#             var marker_024681f66065184aca9b863c57b68912 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c4a99aecc4fa8121fbf0803f33ccd53e);
#
#
#         var popup_6f2c0740f0db446b66924367afb9c17a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8974360014ff97fbecc1aca67a50bcf = $(`&lt;div id=&quot;html_c8974360014ff97fbecc1aca67a50bcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6f2c0740f0db446b66924367afb9c17a.setContent(html_c8974360014ff97fbecc1aca67a50bcf);
#
#
#
#         marker_024681f66065184aca9b863c57b68912.bindPopup(popup_6f2c0740f0db446b66924367afb9c17a)
#         ;
#
#
#
#
#             var marker_a643d47beb7a812aca6f76e72548ca80 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c4a99aecc4fa8121fbf0803f33ccd53e);
#
#
#         var popup_48e867b2b3bc9ef71bdf474b9f97f20e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_524c6f5e2dfa6a2d4daf6f26e703c014 = $(`&lt;div id=&quot;html_524c6f5e2dfa6a2d4daf6f26e703c014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_48e867b2b3bc9ef71bdf474b9f97f2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70d78841967f96a0bad2217bdfd4d93e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70d78841967f96a0bad2217bdfd4d93e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70d78841967f96a0bad2217bdfd4d93e = L.map(
#                 &quot;map_70d78841967f96a0bad2217bdfd4d93e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_684e3a239a382180b8be540f399d9b70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_684e3a239a382180b8be540f399d9b70.addTo(map_70d78841967f96a0bad2217bdfd4d93e);
#
#
#             var feature_group_90ddaafba50c37f38f973d2327ecf190 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_58a8072b55181e00ed6997264b0750ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_90ddaafba50c37f38f973d2327ecf190);
#
#
#         var popup_e71ddd4b408d4d1dfe4f6b29aea1bcb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7aa942a971c817538227d434382b354f = $(`&lt;div id=&quot;html_7aa942a971c817538227d434382b354f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e71ddd4b408d4d1dfe4f6b29aea1bcb3.setContent(html_7aa942a971c817538227d434382b354f);
#
#
#
#         marker_58a8072b55181e00ed6997264b0750ea.bindPopup(popup_e71ddd4b408d4d1dfe4f6b29aea1bcb3)
#         ;
#
#
#
#
#             var marker_7a425f2d4a81b35a887864f25e96eb87 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_90ddaafba50c37f38f973d2327ecf190);
#
#
#         var popup_d815b6ae06b6907aeb9aa92e29a1a754 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de3adf2bc9b2fa74f1c90070a1d96b99 = $(`&lt;div id=&quot;html_de3adf2bc9b2fa74f1c90070a1d96b99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d815b6ae06b6907aeb9aa92e29a1a754.setContent(html_de3adf2bc9b2fa74f1c90070a1d96b99);
#
#
#
#         marker_7a425f2d4a81b35a887864f25e96eb87.bindPopup(popup_d815b6ae06b6907aeb9aa92e29a1a754)
#         ;
#
#
#
#
#             var marker_084f849f6174f65b455b91b4076ed968 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_90ddaafba50c37f38f973d2327ecf190);
#
#
#         var popup_9593436d60c9289855994322a38a0bdd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d928dcc3da2ef6e10137971554185fae = $(`&lt;div id=&quot;html_d928dcc3da2ef6e10137971554185fae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9593436d60c9289855994322a38a0bdd.setContent(html_d928dcc3da2ef6e10137971554185fae);
#
#
#
#         marker_084f849f6174f65b455b91b4076ed968.bindPopup(popup_9593436d60c9289855994322a38a0bdd)
#         ;
#
#
#
#
#             var marker_df06c08c817a88559b332c18cc9eb510 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_90ddaafba50c37f38f973d2327ecf190);
#
#
#         var popup_9326d6c820b02ea0ce1072e1ad657a7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c2336314a3ddffcfab85ee7988f2e73 = $(`&lt;div id=&quot;html_0c2336314a3ddffcfab85ee7988f2e73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9326d6c820b02ea0ce1072e1ad657a7d.setContent(html_0c2336314a3ddffcfab85ee7988f2e73);
#
#
#
#         marker_df06c08c817a88559b332c18cc9eb510.bindPopup(popup_9326d6c820b02ea0ce1072e1ad657a7d)
#         ;
#
#
#
#
#             var marker_a5760d6d2b581fdc314316ba3ba004ea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_90ddaafba50c37f38f973d2327ecf190);
#
#
#         var popup_a9ef1436637c267c82cafc349b650bd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dcde750e2d691f9c08cafa9f5d88bb4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dcde750e2d691f9c08cafa9f5d88bb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dcde750e2d691f9c08cafa9f5d88bb4 = L.map(
#                 &quot;map_2dcde750e2d691f9c08cafa9f5d88bb4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53c082c9236802909b15b32875a1498b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53c082c9236802909b15b32875a1498b.addTo(map_2dcde750e2d691f9c08cafa9f5d88bb4);
#
#
#             var feature_group_20225ac3daa6821e13f82c5b11f9f051 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_20225ac3daa6821e13f82c5b11f9f051.addTo(map_2dcde750e2d691f9c08cafa9f5d88bb4);
#
#
#             var feature_group_sub_group_b540d66af162bbc3eefff0dde52647f8 = L.featureGroup.subGroup(
#                 feature_group_20225ac3daa6821e13f82c5b11f9f051
#             );
#
#
#             var marker_e8cf3bbc60ab57122f7fa14c7902d6b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b540d66af162bbc3eefff0dde52647f8);
#
#
#         var popup_de9d202c7f62e89e027d10f3d3fcffd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33fb0dda013d1121cc347a184c51d432 = $(`&lt;div id=&quot;html_33fb0dda013d1121cc347a184c51d432&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_de9d202c7f62e89e027d10f3d3fcffd9.setContent(html_33fb0dda013d1121cc347a184c51d432);
#
#
#
#         marker_e8cf3bbc60ab57122f7fa14c7902d6b5.bindPopup(popup_de9d202c7f62e89e027d10f3d3fcffd9)
#         ;
#
#
#
#
#             var marker_ff145b330804585bc9ce0e1f3924c962 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b540d66af162bbc3eefff0dde52647f8);
#
#
#         var popup_0678b5c2c3bf7cb4a833068cfa5de4e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2509f1564cee5aa58d834d7251d1019 = $(`&lt;div id=&quot;html_f2509f1564cee5aa58d834d7251d1019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0678b5c2c3bf7cb4a833068cfa5de4e7.setContent(html_f2509f1564cee5aa58d834d7251d1019);
#
#
#
#         marker_ff145b330804585bc9ce0e1f3924c962.bindPopup(popup_0678b5c2c3bf7cb4a833068cfa5de4e7)
#         ;
#
#
#
#
#             var marker_0487b2109632cf594c46d846bee522bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b540d66af162bbc3eefff0dde52647f8);
#
#
#         var popup_a6a08c411744a633c99bb06bc58c1aaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4652285ad816ea355af6d4031392fe5 = $(`&lt;div id=&quot;html_e4652285ad816ea355af6d4031392fe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a6a08c411744a633c99bb06bc58c1aaf.setContent(html_e4652285ad816ea355af6d4031392fe5);
#
#
#
#         marker_0487b2109632cf594c46d846bee522bd.bindPopup(popup_a6a08c411744a633c99bb06bc58c1aaf)
#         ;
#
#
#
#
#             var marker_74a76452a29033dfdca09b0c78bc0b10 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b540d66af162bbc3eefff0dde52647f8);
#
#
#         var popup_0dec6b2c2aa913032fccfcec6c1b73f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b965c25bf00327272b57f0fb16d0aa0 = $(`&lt;div id=&quot;html_6b965c25bf00327272b57f0fb16d0aa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0dec6b2c2aa913032fccfcec6c1b73f5.setContent(html_6b965c25bf00327272b57f0fb16d0aa0);
#
#
#
#         mark
