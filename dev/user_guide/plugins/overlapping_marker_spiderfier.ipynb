# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89c3cb3be730c30c9008933adf041ecd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89c3cb3be730c30c9008933adf041ecd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89c3cb3be730c30c9008933adf041ecd = L.map(
#                 &quot;map_89c3cb3be730c30c9008933adf041ecd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2f5d57374f1fbffdc472f181cbbf939 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2f5d57374f1fbffdc472f181cbbf939.addTo(map_89c3cb3be730c30c9008933adf041ecd);
#
#
#             var marker_7dbe14f5be503023bd318aa9ae4fd4d3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_89c3cb3be730c30c9008933adf041ecd);
#
#
#         var popup_4fa569f3f3667b11f2a48a478b2d41ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38b2b3e0d7895087796eb19d95b3738c = $(`&lt;div id=&quot;html_38b2b3e0d7895087796eb19d95b3738c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4fa569f3f3667b11f2a48a478b2d41ab.setContent(html_38b2b3e0d7895087796eb19d95b3738c);
#
#
#
#         marker_7dbe14f5be503023bd318aa9ae4fd4d3.bindPopup(popup_4fa569f3f3667b11f2a48a478b2d41ab)
#         ;
#
#
#
#
#             var marker_b804d5af005cdbeb6a9ae34c9d1da90a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_89c3cb3be730c30c9008933adf041ecd);
#
#
#         var popup_330abd19802d10b6f9b31c1bbebb8820 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d642f251cd5e0b35c64dd9ed8d18e766 = $(`&lt;div id=&quot;html_d642f251cd5e0b35c64dd9ed8d18e766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_330abd19802d10b6f9b31c1bbebb8820.setContent(html_d642f251cd5e0b35c64dd9ed8d18e766);
#
#
#
#         marker_b804d5af005cdbeb6a9ae34c9d1da90a.bindPopup(popup_330abd19802d10b6f9b31c1bbebb8820)
#         ;
#
#
#
#
#             var marker_f2aac1ce31f62e9373191c76a3e2d803 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_89c3cb3be730c30c9008933adf041ecd);
#
#
#         var popup_1a081e764312ea0fe01207c6d2007e8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbc52c27981343df8e6b044dcb2fe468 = $(`&lt;div id=&quot;html_fbc52c27981343df8e6b044dcb2fe468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1a081e764312ea0fe01207c6d2007e8a.setContent(html_fbc52c27981343df8e6b044dcb2fe468);
#
#
#
#         marker_f2aac1ce31f62e9373191c76a3e2d803.bindPopup(popup_1a081e764312ea0fe01207c6d2007e8a)
#         ;
#
#
#
#
#             var marker_c9c6f7cf5a4efa1a5b2095cd15bc26f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_89c3cb3be730c30c9008933adf041ecd);
#
#
#         var popup_96038b9900ed84c9cc9bcbc6117b03c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3c7e73cef391183ad3014870f804743 = $(`&lt;div id=&quot;html_e3c7e73cef391183ad3014870f804743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_96038b9900ed84c9cc9bcbc6117b03c1.setContent(html_e3c7e73cef391183ad3014870f804743);
#
#
#
#         marker_c9c6f7cf5a4efa1a5b2095cd15bc26f3.bindPopup(popup_96038b9900ed84c9cc9bcbc6117b03c1)
#         ;
#
#
#
#
#             var marker_3204b8263636a70d4006264beb15f289 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_89c3cb3be730c30c9008933adf041ecd);
#
#
#         var popup_9e0b360a47679f31c6e46b393541231b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1473b49b27e3c005089f442deb3531d = $(`&lt;div id=&quot;html_c1473b49b27e3c005089f442deb3531d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9e0b360a47679f31c6e46b393541231b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef7111a5414aab765529b0fe48709166 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef7111a5414aab765529b0fe48709166&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef7111a5414aab765529b0fe48709166 = L.map(
#                 &quot;map_ef7111a5414aab765529b0fe48709166&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0b886f2daf0c2903f28b6f179f3eef5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0b886f2daf0c2903f28b6f179f3eef5.addTo(map_ef7111a5414aab765529b0fe48709166);
#
#
#             var feature_group_25fc6246181426ba48c1d372c4a1546c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5bdd7d36bc50b424628d297f5c96f614 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_25fc6246181426ba48c1d372c4a1546c);
#
#
#         var popup_a64735157701363f950a1730c753721d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55a60d826885ec139cc39c147c17029e = $(`&lt;div id=&quot;html_55a60d826885ec139cc39c147c17029e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a64735157701363f950a1730c753721d.setContent(html_55a60d826885ec139cc39c147c17029e);
#
#
#
#         marker_5bdd7d36bc50b424628d297f5c96f614.bindPopup(popup_a64735157701363f950a1730c753721d)
#         ;
#
#
#
#
#             var marker_06daaba2311aa67df48ce6c65abf0f0c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_25fc6246181426ba48c1d372c4a1546c);
#
#
#         var popup_759b6c4082292a5f576aecfcaaac748e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_279909f2a9eb211dfaf8d3f15fb9c48b = $(`&lt;div id=&quot;html_279909f2a9eb211dfaf8d3f15fb9c48b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_759b6c4082292a5f576aecfcaaac748e.setContent(html_279909f2a9eb211dfaf8d3f15fb9c48b);
#
#
#
#         marker_06daaba2311aa67df48ce6c65abf0f0c.bindPopup(popup_759b6c4082292a5f576aecfcaaac748e)
#         ;
#
#
#
#
#             var marker_e564ec84d6d59d00b3f0fd29ca28899e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_25fc6246181426ba48c1d372c4a1546c);
#
#
#         var popup_1668d81942f15b7d70b4b84db2552a24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d05b270c66694eee112ac0e1683ed55 = $(`&lt;div id=&quot;html_2d05b270c66694eee112ac0e1683ed55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1668d81942f15b7d70b4b84db2552a24.setContent(html_2d05b270c66694eee112ac0e1683ed55);
#
#
#
#         marker_e564ec84d6d59d00b3f0fd29ca28899e.bindPopup(popup_1668d81942f15b7d70b4b84db2552a24)
#         ;
#
#
#
#
#             var marker_56bcf9bac5ff075137d30350f45b1757 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_25fc6246181426ba48c1d372c4a1546c);
#
#
#         var popup_c026434149facd4514bc867e47b6012c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3053dc5939f70ad478fab865861db407 = $(`&lt;div id=&quot;html_3053dc5939f70ad478fab865861db407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c026434149facd4514bc867e47b6012c.setContent(html_3053dc5939f70ad478fab865861db407);
#
#
#
#         marker_56bcf9bac5ff075137d30350f45b1757.bindPopup(popup_c026434149facd4514bc867e47b6012c)
#         ;
#
#
#
#
#             var marker_fe3a385b6c502d75c79773e8fc42e9e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_25fc6246181426ba48c1d372c4a1546c);
#
#
#         var popup_f1980e47bb4dfe205dbe94117953233c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ece811b2dd903ce94a0b5013fd64d36f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ece811b2dd903ce94a0b5013fd64d36f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ece811b2dd903ce94a0b5013fd64d36f = L.map(
#                 &quot;map_ece811b2dd903ce94a0b5013fd64d36f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be06763bec8cb938d2d34525672c5461 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be06763bec8cb938d2d34525672c5461.addTo(map_ece811b2dd903ce94a0b5013fd64d36f);
#
#
#             var feature_group_98621db0b025aa742a7dc4d648208cb8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_98621db0b025aa742a7dc4d648208cb8.addTo(map_ece811b2dd903ce94a0b5013fd64d36f);
#
#
#             var feature_group_sub_group_879b9949533c42007c946d58807e2ff2 = L.featureGroup.subGroup(
#                 feature_group_98621db0b025aa742a7dc4d648208cb8
#             );
#
#
#             var marker_ff770adfbc6ebf7601c0efc9dc7bcd46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_879b9949533c42007c946d58807e2ff2);
#
#
#         var popup_6ccc62bf1fe734b312e26f60de2ff5f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a85ec8a8373465ceeee5072af4dbf63 = $(`&lt;div id=&quot;html_5a85ec8a8373465ceeee5072af4dbf63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6ccc62bf1fe734b312e26f60de2ff5f8.setContent(html_5a85ec8a8373465ceeee5072af4dbf63);
#
#
#
#         marker_ff770adfbc6ebf7601c0efc9dc7bcd46.bindPopup(popup_6ccc62bf1fe734b312e26f60de2ff5f8)
#         ;
#
#
#
#
#             var marker_4fb24c5e67cd6dc24dd502bacb5a8f1e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_879b9949533c42007c946d58807e2ff2);
#
#
#         var popup_bd31bad50248f6d8b8aca8019bf9f270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_506bd069fb70a0c345bc087381aa47fe = $(`&lt;div id=&quot;html_506bd069fb70a0c345bc087381aa47fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bd31bad50248f6d8b8aca8019bf9f270.setContent(html_506bd069fb70a0c345bc087381aa47fe);
#
#
#
#         marker_4fb24c5e67cd6dc24dd502bacb5a8f1e.bindPopup(popup_bd31bad50248f6d8b8aca8019bf9f270)
#         ;
#
#
#
#
#             var marker_b45e04e5c098f7cd241665a013bd4d47 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_879b9949533c42007c946d58807e2ff2);
#
#
#         var popup_6872be74dfe84575a7b614d4109b2229 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50b2b7f929db244eb79543f246d8bc61 = $(`&lt;div id=&quot;html_50b2b7f929db244eb79543f246d8bc61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6872be74dfe84575a7b614d4109b2229.setContent(html_50b2b7f929db244eb79543f246d8bc61);
#
#
#
#         marker_b45e04e5c098f7cd241665a013bd4d47.bindPopup(popup_6872be74dfe84575a7b614d4109b2229)
#         ;
#
#
#
#
#             var marker_2c61d04c0cd3b476dd76f02d0eab7f87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_879b9949533c42007c946d58807e2ff2);
#
#
#         var popup_c6ddc74ac5db2c8f09f2ed9ef76c663e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b315dbf9d77db6c192d357ec1d0061d = $(`&lt;div id=&quot;html_4b315dbf9d77db6c192d357ec1d0061d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c6ddc74ac5db2c8f09f2ed9ef76c663e.setContent(html_4b315dbf9d77db6c192d357ec1d0061d);
#
#
#
#         marker_
