# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61397d97db7c31292fa36cabef45bcf4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61397d97db7c31292fa36cabef45bcf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61397d97db7c31292fa36cabef45bcf4 = L.map(
#                 &quot;map_61397d97db7c31292fa36cabef45bcf4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70645391913968791691982b32a4c23d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70645391913968791691982b32a4c23d.addTo(map_61397d97db7c31292fa36cabef45bcf4);
#
#
#             var marker_e519809ca0775dd485ea1174356883e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_61397d97db7c31292fa36cabef45bcf4);
#
#
#         var popup_c2c3aed1f158e833c0c1f47234830d3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d46edad81008a7a049ac0f72437ef8 = $(`&lt;div id=&quot;html_12d46edad81008a7a049ac0f72437ef8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c2c3aed1f158e833c0c1f47234830d3d.setContent(html_12d46edad81008a7a049ac0f72437ef8);
#
#
#
#         marker_e519809ca0775dd485ea1174356883e7.bindPopup(popup_c2c3aed1f158e833c0c1f47234830d3d)
#         ;
#
#
#
#
#             var marker_d6b8e34ebfe3a68fe7ff3d2e062e3c0a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_61397d97db7c31292fa36cabef45bcf4);
#
#
#         var popup_3615a1f6720429d107947834eced5268 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9defcde5e4f279d1822d84f76f72e6a8 = $(`&lt;div id=&quot;html_9defcde5e4f279d1822d84f76f72e6a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3615a1f6720429d107947834eced5268.setContent(html_9defcde5e4f279d1822d84f76f72e6a8);
#
#
#
#         marker_d6b8e34ebfe3a68fe7ff3d2e062e3c0a.bindPopup(popup_3615a1f6720429d107947834eced5268)
#         ;
#
#
#
#
#             var marker_dee69cc6d0e7e0676209ca38ca0a6797 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_61397d97db7c31292fa36cabef45bcf4);
#
#
#         var popup_7af248063f3be953c28f23c7e9e334b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3db7a153b1452cef8b67c91ea2c73b3a = $(`&lt;div id=&quot;html_3db7a153b1452cef8b67c91ea2c73b3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7af248063f3be953c28f23c7e9e334b3.setContent(html_3db7a153b1452cef8b67c91ea2c73b3a);
#
#
#
#         marker_dee69cc6d0e7e0676209ca38ca0a6797.bindPopup(popup_7af248063f3be953c28f23c7e9e334b3)
#         ;
#
#
#
#
#             var marker_a8511b766978f77a81944ecb52d2c477 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_61397d97db7c31292fa36cabef45bcf4);
#
#
#         var popup_bd92c8354da917b436f7f18c25651427 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8e57f74f5593ded06c2cf4d5a5fbfc1 = $(`&lt;div id=&quot;html_a8e57f74f5593ded06c2cf4d5a5fbfc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bd92c8354da917b436f7f18c25651427.setContent(html_a8e57f74f5593ded06c2cf4d5a5fbfc1);
#
#
#
#         marker_a8511b766978f77a81944ecb52d2c477.bindPopup(popup_bd92c8354da917b436f7f18c25651427)
#         ;
#
#
#
#
#             var marker_535f2cb6a88eca6f211c5df4407f87e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_61397d97db7c31292fa36cabef45bcf4);
#
#
#         var popup_d5e930049296b5f848575214c663903b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c1aefe6c53d9c4ddef920e7f1c89f7a = $(`&lt;div id=&quot;html_6c1aefe6c53d9c4ddef920e7f1c89f7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d5e930049296b5f848575214c663903b.setContent(html_6c1aefe6c53d9c4ddef920e7f1c89f7a);
#
#
#
#         marker_535f2cb6a88eca6f211c5df4407f87e2.bindPopup(popup_d5e930049296b5f848575214c663903b)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5a2d98170cb37f715a8f60dc20671ea {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5a2d98170cb37f715a8f60dc20671ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5a2d98170cb37f715a8f60dc20671ea = L.map(
#                 &quot;map_d5a2d98170cb37f715a8f60dc20671ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e00249ceec6e281a01ec42627c4d682b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e00249ceec6e281a01ec42627c4d682b.addTo(map_d5a2d98170cb37f715a8f60dc20671ea);
#
#
#             var feature_group_460875514ccf4e9290541cae48abfaf0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7e8321bbe40717f08d0a3b80236aab6f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_460875514ccf4e9290541cae48abfaf0);
#
#
#         var popup_3d63724acca36811c53e7df61047b1f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b275c1dd14400c11b683f5504ae9a27b = $(`&lt;div id=&quot;html_b275c1dd14400c11b683f5504ae9a27b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3d63724acca36811c53e7df61047b1f7.setContent(html_b275c1dd14400c11b683f5504ae9a27b);
#
#
#
#         marker_7e8321bbe40717f08d0a3b80236aab6f.bindPopup(popup_3d63724acca36811c53e7df61047b1f7)
#         ;
#
#
#
#
#             var marker_70ae94e1ef780f9ee44339514959dd3e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_460875514ccf4e9290541cae48abfaf0);
#
#
#         var popup_952a5320007e12ac82dcf79fae1c9419 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c1d9144d1b1e271541e9b3cf5d748b2 = $(`&lt;div id=&quot;html_9c1d9144d1b1e271541e9b3cf5d748b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_952a5320007e12ac82dcf79fae1c9419.setContent(html_9c1d9144d1b1e271541e9b3cf5d748b2);
#
#
#
#         marker_70ae94e1ef780f9ee44339514959dd3e.bindPopup(popup_952a5320007e12ac82dcf79fae1c9419)
#         ;
#
#
#
#
#             var marker_f2b13a527e3b0767b9c129973bac6cce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_460875514ccf4e9290541cae48abfaf0);
#
#
#         var popup_966794140eb52f30c2e00f027e6159cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ceae7f908846d056cdd62eecaed8e80 = $(`&lt;div id=&quot;html_3ceae7f908846d056cdd62eecaed8e80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_966794140eb52f30c2e00f027e6159cc.setContent(html_3ceae7f908846d056cdd62eecaed8e80);
#
#
#
#         marker_f2b13a527e3b0767b9c129973bac6cce.bindPopup(popup_966794140eb52f30c2e00f027e6159cc)
#         ;
#
#
#
#
#             var marker_b04db16642f038c9f5d504c5eb709cbe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_460875514ccf4e9290541cae48abfaf0);
#
#
#         var popup_ab6c36cd9e68ad1be3d02446b3b3c3c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b0159482d490c6d0aa2febc5c4c2861 = $(`&lt;div id=&quot;html_5b0159482d490c6d0aa2febc5c4c2861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ab6c36cd9e68ad1be3d02446b3b3c3c2.setContent(html_5b0159482d490c6d0aa2febc5c4c2861);
#
#
#
#         marker_b04db16642f038c9f5d504c5eb709cbe.bindPopup(popup_ab6c36cd9e68ad1be3d02446b3b3c3c2)
#         ;
#
#
#
#
#             var marker_4ebb04ec34e7b60adb53114ae862eda6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_460875514ccf4e9290541cae48abfaf0);
#
#
#         var popup_88f2aed267eadb78c35c5d287f637f9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b61d887e5dbf83989b1e07b13fe5fb2a = $(`&lt;div id=&quot;html_b61d887e5dbf83989b1e07b13fe5fb2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81a3f603588bd263f84481eb714d26f6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81a3f603588bd263f84481eb714d26f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81a3f603588bd263f84481eb714d26f6 = L.map(
#                 &quot;map_81a3f603588bd263f84481eb714d26f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0ee79a7de594007b50089fb77b911f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0ee79a7de594007b50089fb77b911f0.addTo(map_81a3f603588bd263f84481eb714d26f6);
#
#
#             var feature_group_441987f12bcfc9b4ebd1dc7b75d7d8c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_441987f12bcfc9b4ebd1dc7b75d7d8c4.addTo(map_81a3f603588bd263f84481eb714d26f6);
#
#
#             var feature_group_sub_group_1eea4eaebc60103edd1c027a04a6f219 = L.featureGroup.subGroup(
#                 feature_group_441987f12bcfc9b4ebd1dc7b75d7d8c4
#             );
#
#
#             var marker_0a1fb9e99bd8ff35dd1f8bb0685d7bab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eea4eaebc60103edd1c027a04a6f219);
#
#
#         var popup_19c143a0011e1c406b3ac6f66d18543d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60ca93b04ac3ef140dba6aff9053e454 = $(`&lt;div id=&quot;html_60ca93b04ac3ef140dba6aff9053e454&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_19c143a0011e1c406b3ac6f66d18543d.setContent(html_60ca93b04ac3ef140dba6aff9053e454);
#
#
#
#         marker_0a1fb9e99bd8ff35dd1f8bb0685d7bab.bindPopup(popup_19c143a0011e1c406b3ac6f66d18543d)
#         ;
#
#
#
#
#             var marker_43085e9d3d7a65f3d7d43bea118c48ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eea4eaebc60103edd1c027a04a6f219);
#
#
#         var popup_385ac6a62f7c7572fea24cc08bb51cf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63dea64553d7f3a2a5cbdfd4162e3993 = $(`&lt;div id=&quot;html_63dea64553d7f3a2a5cbdfd4162e3993&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_385ac6a62f7c7572fea24cc08bb51cf5.setContent(html_63dea64553d7f3a2a5cbdfd4162e3993);
#
#
#
#         marker_43085e9d3d7a65f3d7d43bea118c48ab.bindPopup(popup_385ac6a62f7c7572fea24cc08bb51cf5)
#         ;
#
#
#
#
#             var marker_c275d2248866a7231baba50cdc365f0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eea4eaebc60103edd1c027a04a6f219);
#
#
#         var popup_978fd9c6bdce0f09ccd7ff91f4947b8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d79a1e78887d0ea710c190651d2bd67 = $(`&lt;div id=&quot;html_1d79a1e78887d0ea710c190651d2bd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_978fd9c6bdce0f09ccd7ff91f4947b8c.setContent(html_1d79a1e78887d0ea710c190651d2bd67);
#
#
#
#         marker_c275d2248866a7231baba50cdc365f0f.bindPopup(popup_978fd9c6bdce0f09ccd7ff91f4947b8c)
#         ;
#
#
#
#
#             var marker_371949d04a081323ea4c4340ac738729 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eea4eaebc60103edd1c027a04a6f219);
#
#
#         var popup_d094e682a03a33696b6479e57dded3e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_094644058b310effc2144e958fcd003a = $(`&lt;div id=&quot;html_094644058b310effc2144e958fcd003a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d094e682a03a33696b6479e57dded3e8.setContent(html_094644058b310effc2144e958fcd003a);
#
#
#
#         marker_371949d04a081323ea4c4340ac738729.bindPopup(popup_d094e682a03a33696b6479e57dded3e8)
#         ;
#
#
#
#
#             var marker_190405389ce33212ae6702c8f32e7992 = L.marker(
#                 [45.0503999
