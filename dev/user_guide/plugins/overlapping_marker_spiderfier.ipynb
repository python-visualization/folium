# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c5ac8e53543f49ecac622473eca12b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c5ac8e53543f49ecac622473eca12b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c5ac8e53543f49ecac622473eca12b6 = L.map(
#                 &quot;map_7c5ac8e53543f49ecac622473eca12b6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04732898c3cfefbcf422f1603470493b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04732898c3cfefbcf422f1603470493b.addTo(map_7c5ac8e53543f49ecac622473eca12b6);
#
#
#             var marker_1c36c9727319ef74bc03d871300f3ab8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7c5ac8e53543f49ecac622473eca12b6);
#
#
#         var popup_2caee0d15071ed2437d1ed08f95dbadd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e88995f08c066a2ad9f402266e134b54 = $(`&lt;div id=&quot;html_e88995f08c066a2ad9f402266e134b54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2caee0d15071ed2437d1ed08f95dbadd.setContent(html_e88995f08c066a2ad9f402266e134b54);
#
#
#
#         marker_1c36c9727319ef74bc03d871300f3ab8.bindPopup(popup_2caee0d15071ed2437d1ed08f95dbadd)
#         ;
#
#
#
#
#             var marker_bb736a0fddcd2f6b0ce8d407cdeb96f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7c5ac8e53543f49ecac622473eca12b6);
#
#
#         var popup_28570e299f0edc14610691d1f770e118 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a6dc1f1c090dc7c3101c315359dc080 = $(`&lt;div id=&quot;html_1a6dc1f1c090dc7c3101c315359dc080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_28570e299f0edc14610691d1f770e118.setContent(html_1a6dc1f1c090dc7c3101c315359dc080);
#
#
#
#         marker_bb736a0fddcd2f6b0ce8d407cdeb96f1.bindPopup(popup_28570e299f0edc14610691d1f770e118)
#         ;
#
#
#
#
#             var marker_6a8bf095168762e570b300d69ed09a82 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7c5ac8e53543f49ecac622473eca12b6);
#
#
#         var popup_279982d40a767dbd621edc12744b1b05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6fb64c9d449fa2f0930ccb73c3b32d2 = $(`&lt;div id=&quot;html_a6fb64c9d449fa2f0930ccb73c3b32d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_279982d40a767dbd621edc12744b1b05.setContent(html_a6fb64c9d449fa2f0930ccb73c3b32d2);
#
#
#
#         marker_6a8bf095168762e570b300d69ed09a82.bindPopup(popup_279982d40a767dbd621edc12744b1b05)
#         ;
#
#
#
#
#             var marker_6a3888bfd32dc0f907a33c027cf199b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7c5ac8e53543f49ecac622473eca12b6);
#
#
#         var popup_144b57eeafa0d1fbd6237c4987f5f4ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9814e5f9e82869db6e083d35fb2cb830 = $(`&lt;div id=&quot;html_9814e5f9e82869db6e083d35fb2cb830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_144b57eeafa0d1fbd6237c4987f5f4ac.setContent(html_9814e5f9e82869db6e083d35fb2cb830);
#
#
#
#         marker_6a3888bfd32dc0f907a33c027cf199b0.bindPopup(popup_144b57eeafa0d1fbd6237c4987f5f4ac)
#         ;
#
#
#
#
#             var marker_27e0591c1e86fdfb07803f33b6107a67 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7c5ac8e53543f49ecac622473eca12b6);
#
#
#         var popup_8f946dd5c2a7ddd3bb021f2881b17f5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5de0809f9dbe32d4e201d6859d2af35f = $(`&lt;div id=&quot;html_5de0809f9dbe32d4e201d6859d2af35f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8f946dd5c2a7ddd3bb021f2881b17f5d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fbcf3a8bbbe0dc787942d93843e4c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fbcf3a8bbbe0dc787942d93843e4c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fbcf3a8bbbe0dc787942d93843e4c36 = L.map(
#                 &quot;map_0fbcf3a8bbbe0dc787942d93843e4c36&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e3e706a602ec571654b42da042246ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e3e706a602ec571654b42da042246ec.addTo(map_0fbcf3a8bbbe0dc787942d93843e4c36);
#
#
#             var feature_group_d485a98c54e821c84a2a84585e36d7ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4b5749c5ef716bf10570eaf573ab2d2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d485a98c54e821c84a2a84585e36d7ac);
#
#
#         var popup_a07c16c0338f888125c615e07e9ef8f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36b58ab4a541fa87013dc666c30cec00 = $(`&lt;div id=&quot;html_36b58ab4a541fa87013dc666c30cec00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a07c16c0338f888125c615e07e9ef8f5.setContent(html_36b58ab4a541fa87013dc666c30cec00);
#
#
#
#         marker_4b5749c5ef716bf10570eaf573ab2d2a.bindPopup(popup_a07c16c0338f888125c615e07e9ef8f5)
#         ;
#
#
#
#
#             var marker_8a21d851a201c9e94b72ba7e42f8bf23 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d485a98c54e821c84a2a84585e36d7ac);
#
#
#         var popup_049060d332f2129e136fb4db3b93baf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73b7ad435e1c31ee6bca22d738749fb3 = $(`&lt;div id=&quot;html_73b7ad435e1c31ee6bca22d738749fb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_049060d332f2129e136fb4db3b93baf9.setContent(html_73b7ad435e1c31ee6bca22d738749fb3);
#
#
#
#         marker_8a21d851a201c9e94b72ba7e42f8bf23.bindPopup(popup_049060d332f2129e136fb4db3b93baf9)
#         ;
#
#
#
#
#             var marker_46098a92ecbe5d9751db2cd1a8660bdb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d485a98c54e821c84a2a84585e36d7ac);
#
#
#         var popup_c9e7c26ea8c39974976319c5a8cb03c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2c3358818176bd3c8574284b445042a = $(`&lt;div id=&quot;html_a2c3358818176bd3c8574284b445042a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c9e7c26ea8c39974976319c5a8cb03c1.setContent(html_a2c3358818176bd3c8574284b445042a);
#
#
#
#         marker_46098a92ecbe5d9751db2cd1a8660bdb.bindPopup(popup_c9e7c26ea8c39974976319c5a8cb03c1)
#         ;
#
#
#
#
#             var marker_0f8547c791ec8fc2220ee728a8c6ba32 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d485a98c54e821c84a2a84585e36d7ac);
#
#
#         var popup_ea982c36778c25f0934082bbd8c351b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f60048598eb0b0d13f00ef959f88a5d1 = $(`&lt;div id=&quot;html_f60048598eb0b0d13f00ef959f88a5d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ea982c36778c25f0934082bbd8c351b2.setContent(html_f60048598eb0b0d13f00ef959f88a5d1);
#
#
#
#         marker_0f8547c791ec8fc2220ee728a8c6ba32.bindPopup(popup_ea982c36778c25f0934082bbd8c351b2)
#         ;
#
#
#
#
#             var marker_7bc1435f218264dfed74004d42033127 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d485a98c54e821c84a2a84585e36d7ac);
#
#
#         var popup_21e913894240363e6d205ec719488463 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8446c3fb3b5f3f4cc0f3f31688965b51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8446c3fb3b5f3f4cc0f3f31688965b51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8446c3fb3b5f3f4cc0f3f31688965b51 = L.map(
#                 &quot;map_8446c3fb3b5f3f4cc0f3f31688965b51&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ada62ac25555abd0087815651effec4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ada62ac25555abd0087815651effec4.addTo(map_8446c3fb3b5f3f4cc0f3f31688965b51);
#
#
#             var feature_group_522423911a1d7563c12a643ff0c27beb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_522423911a1d7563c12a643ff0c27beb.addTo(map_8446c3fb3b5f3f4cc0f3f31688965b51);
#
#
#             var feature_group_sub_group_644dfc38f40a572c8371c00802d1e334 = L.featureGroup.subGroup(
#                 feature_group_522423911a1d7563c12a643ff0c27beb
#             );
#
#
#             var marker_f52a08aa32680be9eefba4c2b8407586 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_644dfc38f40a572c8371c00802d1e334);
#
#
#         var popup_7d092d2c8d73b1a069ec33847b61f241 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_715a9dc6003e7f5657c4af188e8bedc3 = $(`&lt;div id=&quot;html_715a9dc6003e7f5657c4af188e8bedc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7d092d2c8d73b1a069ec33847b61f241.setContent(html_715a9dc6003e7f5657c4af188e8bedc3);
#
#
#
#         marker_f52a08aa32680be9eefba4c2b8407586.bindPopup(popup_7d092d2c8d73b1a069ec33847b61f241)
#         ;
#
#
#
#
#             var marker_43be48a0c7b251b99ab53c953b57eb24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_644dfc38f40a572c8371c00802d1e334);
#
#
#         var popup_6bde5c1010286a727cd07e04751c754a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a136142ec8e0473c8b04a0ea01198a7d = $(`&lt;div id=&quot;html_a136142ec8e0473c8b04a0ea01198a7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6bde5c1010286a727cd07e04751c754a.setContent(html_a136142ec8e0473c8b04a0ea01198a7d);
#
#
#
#         marker_43be48a0c7b251b99ab53c953b57eb24.bindPopup(popup_6bde5c1010286a727cd07e04751c754a)
#         ;
#
#
#
#
#             var marker_2e51a41e52e9d958c22b60c8bff017b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_644dfc38f40a572c8371c00802d1e334);
#
#
#         var popup_14b519e304c87b6f102a80d6bd455022 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50ee765c154d5f26419a647ffae6cc48 = $(`&lt;div id=&quot;html_50ee765c154d5f26419a647ffae6cc48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14b519e304c87b6f102a80d6bd455022.setContent(html_50ee765c154d5f26419a647ffae6cc48);
#
#
#
#         marker_2e51a41e52e9d958c22b60c8bff017b4.bindPopup(popup_14b519e304c87b6f102a80d6bd455022)
#         ;
#
#
#
#
#             var marker_1f12ab8cd20a91d3c14eaaa2538810fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_644dfc38f40a572c8371c00802d1e334);
#
#
#         var popup_68d838c3cfacfb9ccb35e9159ef610ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b60de04c94095f57337e4f382788bbd5 = $(`&lt;div id=&quot;html_b60de04c94095f57337e4f382788bbd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_68d838c3cfacfb9ccb35e9159ef610ce.setContent(html_b60de04c94095f57337e4f382788bbd5);
#
#
#
#         marker_
