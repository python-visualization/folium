# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab33fb6532aa79adced63b8579659f34 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab33fb6532aa79adced63b8579659f34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab33fb6532aa79adced63b8579659f34 = L.map(
#                 &quot;map_ab33fb6532aa79adced63b8579659f34&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05b7db31170b98b91317bfb5597cb5e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05b7db31170b98b91317bfb5597cb5e0.addTo(map_ab33fb6532aa79adced63b8579659f34);
#
#
#             var marker_b328f874577af50bc8ee0346c102e1f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ab33fb6532aa79adced63b8579659f34);
#
#
#         var popup_9a45049f6b97cb69028b2b21f422c8a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173eaf3e6d0e6909afa4832f15ba0ac0 = $(`&lt;div id=&quot;html_173eaf3e6d0e6909afa4832f15ba0ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9a45049f6b97cb69028b2b21f422c8a7.setContent(html_173eaf3e6d0e6909afa4832f15ba0ac0);
#
#
#
#         marker_b328f874577af50bc8ee0346c102e1f4.bindPopup(popup_9a45049f6b97cb69028b2b21f422c8a7)
#         ;
#
#
#
#
#             var marker_053c0a7f3ed8bc12c2e2dc05879c4867 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ab33fb6532aa79adced63b8579659f34);
#
#
#         var popup_dc0dc5215027041308918ee5f2a9684b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5023e4305b12b727e2f0d197aaae01e = $(`&lt;div id=&quot;html_f5023e4305b12b727e2f0d197aaae01e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dc0dc5215027041308918ee5f2a9684b.setContent(html_f5023e4305b12b727e2f0d197aaae01e);
#
#
#
#         marker_053c0a7f3ed8bc12c2e2dc05879c4867.bindPopup(popup_dc0dc5215027041308918ee5f2a9684b)
#         ;
#
#
#
#
#             var marker_da5e78c80d2036e2453317dc22f233f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ab33fb6532aa79adced63b8579659f34);
#
#
#         var popup_02016ccb8513db2a932bbae204360748 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80bc046661dc6dc00f2df6e4b202692c = $(`&lt;div id=&quot;html_80bc046661dc6dc00f2df6e4b202692c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_02016ccb8513db2a932bbae204360748.setContent(html_80bc046661dc6dc00f2df6e4b202692c);
#
#
#
#         marker_da5e78c80d2036e2453317dc22f233f2.bindPopup(popup_02016ccb8513db2a932bbae204360748)
#         ;
#
#
#
#
#             var marker_ff1e5c0de192f4762cd36ccb936517f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ab33fb6532aa79adced63b8579659f34);
#
#
#         var popup_a85449e72888917485839b89c065a02e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ddbaac71c9bf62bd2d6dece5ba507fa = $(`&lt;div id=&quot;html_1ddbaac71c9bf62bd2d6dece5ba507fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a85449e72888917485839b89c065a02e.setContent(html_1ddbaac71c9bf62bd2d6dece5ba507fa);
#
#
#
#         marker_ff1e5c0de192f4762cd36ccb936517f5.bindPopup(popup_a85449e72888917485839b89c065a02e)
#         ;
#
#
#
#
#             var marker_ade0fbbe23592c6b23c032e47d4d5194 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ab33fb6532aa79adced63b8579659f34);
#
#
#         var popup_c306887af25d2020339b995a1e50e91f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17066525b7ff3e26a85e200e443975e3 = $(`&lt;div id=&quot;html_17066525b7ff3e26a85e200e443975e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c306887af25d2020339b995a1e50e9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61fa3134009ef3ac7cb337f486b20a88 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61fa3134009ef3ac7cb337f486b20a88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61fa3134009ef3ac7cb337f486b20a88 = L.map(
#                 &quot;map_61fa3134009ef3ac7cb337f486b20a88&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80dc3629d33bd3a4fc9973eaa0878412 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80dc3629d33bd3a4fc9973eaa0878412.addTo(map_61fa3134009ef3ac7cb337f486b20a88);
#
#
#             var feature_group_36639a664cc32b63b629b17bd1121be6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6961c05dc4e7d023672a2538712d829f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_36639a664cc32b63b629b17bd1121be6);
#
#
#         var popup_27f688b112f4f81bc349fdd12970aa1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7932f71da244f04e364f836cbe041c8 = $(`&lt;div id=&quot;html_b7932f71da244f04e364f836cbe041c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_27f688b112f4f81bc349fdd12970aa1d.setContent(html_b7932f71da244f04e364f836cbe041c8);
#
#
#
#         marker_6961c05dc4e7d023672a2538712d829f.bindPopup(popup_27f688b112f4f81bc349fdd12970aa1d)
#         ;
#
#
#
#
#             var marker_41df727d6edf13ecf726d59a405ad320 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_36639a664cc32b63b629b17bd1121be6);
#
#
#         var popup_10e19aacef867d0097281528fa03776b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8ef6065ef248952175951964f0729f2 = $(`&lt;div id=&quot;html_d8ef6065ef248952175951964f0729f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_10e19aacef867d0097281528fa03776b.setContent(html_d8ef6065ef248952175951964f0729f2);
#
#
#
#         marker_41df727d6edf13ecf726d59a405ad320.bindPopup(popup_10e19aacef867d0097281528fa03776b)
#         ;
#
#
#
#
#             var marker_077a9c84783aa9f815e97aafa39de6b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_36639a664cc32b63b629b17bd1121be6);
#
#
#         var popup_d8011cd7f98e10abecd1167ab64eaba9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abc299075cf6bede72a9c7f820ad088e = $(`&lt;div id=&quot;html_abc299075cf6bede72a9c7f820ad088e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d8011cd7f98e10abecd1167ab64eaba9.setContent(html_abc299075cf6bede72a9c7f820ad088e);
#
#
#
#         marker_077a9c84783aa9f815e97aafa39de6b4.bindPopup(popup_d8011cd7f98e10abecd1167ab64eaba9)
#         ;
#
#
#
#
#             var marker_2388fdc27123472161eb5559bb6f89e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_36639a664cc32b63b629b17bd1121be6);
#
#
#         var popup_6ca152d847b24cb79120595a9eb1454b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb663a3aff55068f7e02cb417f648601 = $(`&lt;div id=&quot;html_eb663a3aff55068f7e02cb417f648601&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6ca152d847b24cb79120595a9eb1454b.setContent(html_eb663a3aff55068f7e02cb417f648601);
#
#
#
#         marker_2388fdc27123472161eb5559bb6f89e3.bindPopup(popup_6ca152d847b24cb79120595a9eb1454b)
#         ;
#
#
#
#
#             var marker_8f606032d58351323d552d8590012726 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_36639a664cc32b63b629b17bd1121be6);
#
#
#         var popup_a395d71916dd34157aee04fd00cc0531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0bb417c23022b554d0ed5951e05b227 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0bb417c23022b554d0ed5951e05b227&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0bb417c23022b554d0ed5951e05b227 = L.map(
#                 &quot;map_b0bb417c23022b554d0ed5951e05b227&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df85b04b32a7e5feca4b2023e1727a97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df85b04b32a7e5feca4b2023e1727a97.addTo(map_b0bb417c23022b554d0ed5951e05b227);
#
#
#             var feature_group_0cd1ad1882ae03e5262a557fde17da39 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0cd1ad1882ae03e5262a557fde17da39.addTo(map_b0bb417c23022b554d0ed5951e05b227);
#
#
#             var feature_group_sub_group_88105c0fbc6e3a8a41c1ea3fbfe05c86 = L.featureGroup.subGroup(
#                 feature_group_0cd1ad1882ae03e5262a557fde17da39
#             );
#
#
#             var marker_a9081f0fb2cd185409a75ba98216f0b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_88105c0fbc6e3a8a41c1ea3fbfe05c86);
#
#
#         var popup_362cdf5542862752e2c8590a1a383d0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d55d2d57297e0f37b7f6118fe5e1c811 = $(`&lt;div id=&quot;html_d55d2d57297e0f37b7f6118fe5e1c811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_362cdf5542862752e2c8590a1a383d0a.setContent(html_d55d2d57297e0f37b7f6118fe5e1c811);
#
#
#
#         marker_a9081f0fb2cd185409a75ba98216f0b4.bindPopup(popup_362cdf5542862752e2c8590a1a383d0a)
#         ;
#
#
#
#
#             var marker_2addcfc2c4e8122c91f7b9b16e106b95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_88105c0fbc6e3a8a41c1ea3fbfe05c86);
#
#
#         var popup_d4c941e112f45c8da54e667e257362ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f745e4b5041698e178e7530725d75b98 = $(`&lt;div id=&quot;html_f745e4b5041698e178e7530725d75b98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d4c941e112f45c8da54e667e257362ce.setContent(html_f745e4b5041698e178e7530725d75b98);
#
#
#
#         marker_2addcfc2c4e8122c91f7b9b16e106b95.bindPopup(popup_d4c941e112f45c8da54e667e257362ce)
#         ;
#
#
#
#
#             var marker_a42e15fa3327e006d91c3aa6b10c12dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_88105c0fbc6e3a8a41c1ea3fbfe05c86);
#
#
#         var popup_43c443cf26db069ce6244441c18bf0b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d211e94765fd7641af5bc0dd8edc8475 = $(`&lt;div id=&quot;html_d211e94765fd7641af5bc0dd8edc8475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_43c443cf26db069ce6244441c18bf0b8.setContent(html_d211e94765fd7641af5bc0dd8edc8475);
#
#
#
#         marker_a42e15fa3327e006d91c3aa6b10c12dc.bindPopup(popup_43c443cf26db069ce6244441c18bf0b8)
#         ;
#
#
#
#
#             var marker_8259009d444708640746ee35d63b28ef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_88105c0fbc6e3a8a41c1ea3fbfe05c86);
#
#
#         var popup_8ca7bfc773d1464f61ddb21180ded532 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a624113abacde1182761d3ea186db58 = $(`&lt;div id=&quot;html_8a624113abacde1182761d3ea186db58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8ca7bfc773d1464f61ddb21180ded532.setContent(html_8a624113abacde1182761d3ea186db58);
#
#
#
#         mark
