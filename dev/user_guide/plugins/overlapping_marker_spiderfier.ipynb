# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28f4b4f53e0921c4048c2c0e5d3ddc8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28f4b4f53e0921c4048c2c0e5d3ddc8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28f4b4f53e0921c4048c2c0e5d3ddc8f = L.map(
#                 &quot;map_28f4b4f53e0921c4048c2c0e5d3ddc8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1916e7e0f986a4378f459ee51c9cf60a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1916e7e0f986a4378f459ee51c9cf60a.addTo(map_28f4b4f53e0921c4048c2c0e5d3ddc8f);
#
#
#             var marker_98de6bddf304a988e4c8bc8f4c72faa7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_28f4b4f53e0921c4048c2c0e5d3ddc8f);
#
#
#         var popup_e9342b4e04fd2ec0bc77533ce45add6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b479c073ecf08f9538d1970da688fdea = $(`&lt;div id=&quot;html_b479c073ecf08f9538d1970da688fdea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e9342b4e04fd2ec0bc77533ce45add6e.setContent(html_b479c073ecf08f9538d1970da688fdea);
#
#
#
#         marker_98de6bddf304a988e4c8bc8f4c72faa7.bindPopup(popup_e9342b4e04fd2ec0bc77533ce45add6e)
#         ;
#
#
#
#
#             var marker_dadd76a26eca3884f26f0d38d137d210 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_28f4b4f53e0921c4048c2c0e5d3ddc8f);
#
#
#         var popup_1fd06e0582f1485c6fb791d7e80a0cae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3aee3f80e7ffd53ce185e5908ab7b466 = $(`&lt;div id=&quot;html_3aee3f80e7ffd53ce185e5908ab7b466&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1fd06e0582f1485c6fb791d7e80a0cae.setContent(html_3aee3f80e7ffd53ce185e5908ab7b466);
#
#
#
#         marker_dadd76a26eca3884f26f0d38d137d210.bindPopup(popup_1fd06e0582f1485c6fb791d7e80a0cae)
#         ;
#
#
#
#
#             var marker_c0ab89ba64b3aad555449f3b82b8eec3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_28f4b4f53e0921c4048c2c0e5d3ddc8f);
#
#
#         var popup_83f001533f9e391a66061a9bdcb76565 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_befa94fa68950285e757cd89fcbe0590 = $(`&lt;div id=&quot;html_befa94fa68950285e757cd89fcbe0590&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_83f001533f9e391a66061a9bdcb76565.setContent(html_befa94fa68950285e757cd89fcbe0590);
#
#
#
#         marker_c0ab89ba64b3aad555449f3b82b8eec3.bindPopup(popup_83f001533f9e391a66061a9bdcb76565)
#         ;
#
#
#
#
#             var marker_98ccddbfa0c1b9aaa9c46af1c5b501c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_28f4b4f53e0921c4048c2c0e5d3ddc8f);
#
#
#         var popup_d1c90ce70f0ba289f570493f4485ff48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8b1c5448cf10c3707bf6627402e9b78 = $(`&lt;div id=&quot;html_c8b1c5448cf10c3707bf6627402e9b78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d1c90ce70f0ba289f570493f4485ff48.setContent(html_c8b1c5448cf10c3707bf6627402e9b78);
#
#
#
#         marker_98ccddbfa0c1b9aaa9c46af1c5b501c1.bindPopup(popup_d1c90ce70f0ba289f570493f4485ff48)
#         ;
#
#
#
#
#             var marker_efdaf9504acae29eefc0b41fbacf00e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_28f4b4f53e0921c4048c2c0e5d3ddc8f);
#
#
#         var popup_5418fa2e03e177904c3db2985121bfa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0afec150861412d0f351696b5f9efc8 = $(`&lt;div id=&quot;html_c0afec150861412d0f351696b5f9efc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5418fa2e03e177904c3db2985121bfa0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f18cf9866f19545295cb15cf9c7bbbec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f18cf9866f19545295cb15cf9c7bbbec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f18cf9866f19545295cb15cf9c7bbbec = L.map(
#                 &quot;map_f18cf9866f19545295cb15cf9c7bbbec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23ad02b8f6fdd793e7218dca13622633 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23ad02b8f6fdd793e7218dca13622633.addTo(map_f18cf9866f19545295cb15cf9c7bbbec);
#
#
#             var feature_group_308e218b74b7b36d63c75013b64cf3cd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8b6522eb84e2a78215bb6423c8cb425e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_308e218b74b7b36d63c75013b64cf3cd);
#
#
#         var popup_e940a2905f424d9230a20557dbcdf89e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89ec046857ba0bb84ddd03ffd7b1e1d2 = $(`&lt;div id=&quot;html_89ec046857ba0bb84ddd03ffd7b1e1d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e940a2905f424d9230a20557dbcdf89e.setContent(html_89ec046857ba0bb84ddd03ffd7b1e1d2);
#
#
#
#         marker_8b6522eb84e2a78215bb6423c8cb425e.bindPopup(popup_e940a2905f424d9230a20557dbcdf89e)
#         ;
#
#
#
#
#             var marker_099c33d4d76ae78f6cff43d88acdb774 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_308e218b74b7b36d63c75013b64cf3cd);
#
#
#         var popup_afcc2f120681ab0a45fc1c9465db9c88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da91267ea98f96fef819a995acad55c6 = $(`&lt;div id=&quot;html_da91267ea98f96fef819a995acad55c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_afcc2f120681ab0a45fc1c9465db9c88.setContent(html_da91267ea98f96fef819a995acad55c6);
#
#
#
#         marker_099c33d4d76ae78f6cff43d88acdb774.bindPopup(popup_afcc2f120681ab0a45fc1c9465db9c88)
#         ;
#
#
#
#
#             var marker_27f306812e93018fae98b9df237b2a6c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_308e218b74b7b36d63c75013b64cf3cd);
#
#
#         var popup_06f050cbb581cd9f475b922ab820f679 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_976b5eedb238287f32bed0744b6f8d12 = $(`&lt;div id=&quot;html_976b5eedb238287f32bed0744b6f8d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_06f050cbb581cd9f475b922ab820f679.setContent(html_976b5eedb238287f32bed0744b6f8d12);
#
#
#
#         marker_27f306812e93018fae98b9df237b2a6c.bindPopup(popup_06f050cbb581cd9f475b922ab820f679)
#         ;
#
#
#
#
#             var marker_91389d14ee801e6dc907ca7dfc460cd7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_308e218b74b7b36d63c75013b64cf3cd);
#
#
#         var popup_f761df680160ae3b298a115c9cd1b979 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_278eb7060dc978a1d073baed0751e651 = $(`&lt;div id=&quot;html_278eb7060dc978a1d073baed0751e651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f761df680160ae3b298a115c9cd1b979.setContent(html_278eb7060dc978a1d073baed0751e651);
#
#
#
#         marker_91389d14ee801e6dc907ca7dfc460cd7.bindPopup(popup_f761df680160ae3b298a115c9cd1b979)
#         ;
#
#
#
#
#             var marker_7bcba183eb14dfe923879cf9c7a8f2b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_308e218b74b7b36d63c75013b64cf3cd);
#
#
#         var popup_df70ffc7b25380514347e02f577a7306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13e75caef3598ca7c0d275288b9c0c72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13e75caef3598ca7c0d275288b9c0c72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13e75caef3598ca7c0d275288b9c0c72 = L.map(
#                 &quot;map_13e75caef3598ca7c0d275288b9c0c72&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bf794ce7f5cd6255e3d5cf67df6605b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bf794ce7f5cd6255e3d5cf67df6605b.addTo(map_13e75caef3598ca7c0d275288b9c0c72);
#
#
#             var feature_group_941990c0c8d3b2172dccf27421cfde9e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_941990c0c8d3b2172dccf27421cfde9e.addTo(map_13e75caef3598ca7c0d275288b9c0c72);
#
#
#             var feature_group_sub_group_3dc8e41497ed52fce09e6d0eac4b3141 = L.featureGroup.subGroup(
#                 feature_group_941990c0c8d3b2172dccf27421cfde9e
#             );
#
#
#             var marker_dc9a704b0c00bef22f02133cbaabb188 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3dc8e41497ed52fce09e6d0eac4b3141);
#
#
#         var popup_b427d78c33dd6bf65974eae1ae896a74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5de4141cbb30f87218d242f5aad6a791 = $(`&lt;div id=&quot;html_5de4141cbb30f87218d242f5aad6a791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b427d78c33dd6bf65974eae1ae896a74.setContent(html_5de4141cbb30f87218d242f5aad6a791);
#
#
#
#         marker_dc9a704b0c00bef22f02133cbaabb188.bindPopup(popup_b427d78c33dd6bf65974eae1ae896a74)
#         ;
#
#
#
#
#             var marker_de7a05c3f62f09a995ad79a407ce3eea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3dc8e41497ed52fce09e6d0eac4b3141);
#
#
#         var popup_852479c47dda28e4747145c442ef7d22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f76371f4db554bd102744c7d5648ef0d = $(`&lt;div id=&quot;html_f76371f4db554bd102744c7d5648ef0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_852479c47dda28e4747145c442ef7d22.setContent(html_f76371f4db554bd102744c7d5648ef0d);
#
#
#
#         marker_de7a05c3f62f09a995ad79a407ce3eea.bindPopup(popup_852479c47dda28e4747145c442ef7d22)
#         ;
#
#
#
#
#             var marker_add58b538cde2c9da503e00dbef4e990 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3dc8e41497ed52fce09e6d0eac4b3141);
#
#
#         var popup_dc0ff6801803f23aa1079f3eb0393646 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_145882cdee64590b0e42e3d8354bb626 = $(`&lt;div id=&quot;html_145882cdee64590b0e42e3d8354bb626&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dc0ff6801803f23aa1079f3eb0393646.setContent(html_145882cdee64590b0e42e3d8354bb626);
#
#
#
#         marker_add58b538cde2c9da503e00dbef4e990.bindPopup(popup_dc0ff6801803f23aa1079f3eb0393646)
#         ;
#
#
#
#
#             var marker_23d6512e6635e420ed6a2857126e1412 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3dc8e41497ed52fce09e6d0eac4b3141);
#
#
#         var popup_0e721700a9571ea021334c7b26a3fef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_595e5dc81ecda13d2af2e3c502717003 = $(`&lt;div id=&quot;html_595e5dc81ecda13d2af2e3c502717003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0e721700a9571ea021334c7b26a3fef2.setContent(html_595e5dc81ecda13d2af2e3c502717003);
#
#
#
#         marker_
