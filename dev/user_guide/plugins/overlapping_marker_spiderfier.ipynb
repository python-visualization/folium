# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af8b4c59cb421fb97c8331d765d8f187 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af8b4c59cb421fb97c8331d765d8f187&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af8b4c59cb421fb97c8331d765d8f187 = L.map(
#                 &quot;map_af8b4c59cb421fb97c8331d765d8f187&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bec776cf729b7a58b081142c97ccf6b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bec776cf729b7a58b081142c97ccf6b3.addTo(map_af8b4c59cb421fb97c8331d765d8f187);
#
#
#             var marker_013ec2d0e50b0da8fdbadde046f8ac98 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_af8b4c59cb421fb97c8331d765d8f187);
#
#
#         var popup_fda1e30fbc7bf2fac95a3f3fcf0e3c8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee437d36df86c2d6f798fe9e940ae278 = $(`&lt;div id=&quot;html_ee437d36df86c2d6f798fe9e940ae278&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fda1e30fbc7bf2fac95a3f3fcf0e3c8f.setContent(html_ee437d36df86c2d6f798fe9e940ae278);
#
#
#
#         marker_013ec2d0e50b0da8fdbadde046f8ac98.bindPopup(popup_fda1e30fbc7bf2fac95a3f3fcf0e3c8f)
#         ;
#
#
#
#
#             var marker_9ac330181f659a6496397283f44756db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_af8b4c59cb421fb97c8331d765d8f187);
#
#
#         var popup_3d709a8a1d4cbfcd1f83a729aaeb1a88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc7deaedc9c840bc3589926c1a74ed3 = $(`&lt;div id=&quot;html_7cc7deaedc9c840bc3589926c1a74ed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3d709a8a1d4cbfcd1f83a729aaeb1a88.setContent(html_7cc7deaedc9c840bc3589926c1a74ed3);
#
#
#
#         marker_9ac330181f659a6496397283f44756db.bindPopup(popup_3d709a8a1d4cbfcd1f83a729aaeb1a88)
#         ;
#
#
#
#
#             var marker_988d4313f38c65d2ab3a370a8f0e6541 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_af8b4c59cb421fb97c8331d765d8f187);
#
#
#         var popup_b79d2052c3f249a91e73f729aeca6ad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_076c5f333b67131d3d3314859bef3974 = $(`&lt;div id=&quot;html_076c5f333b67131d3d3314859bef3974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b79d2052c3f249a91e73f729aeca6ad1.setContent(html_076c5f333b67131d3d3314859bef3974);
#
#
#
#         marker_988d4313f38c65d2ab3a370a8f0e6541.bindPopup(popup_b79d2052c3f249a91e73f729aeca6ad1)
#         ;
#
#
#
#
#             var marker_009c0ad6c79f511d81abc2d25b05bcb4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_af8b4c59cb421fb97c8331d765d8f187);
#
#
#         var popup_de867974f9efaf20a63769a50fa347cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c71827229740c027751894a5ec29b8e = $(`&lt;div id=&quot;html_2c71827229740c027751894a5ec29b8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_de867974f9efaf20a63769a50fa347cc.setContent(html_2c71827229740c027751894a5ec29b8e);
#
#
#
#         marker_009c0ad6c79f511d81abc2d25b05bcb4.bindPopup(popup_de867974f9efaf20a63769a50fa347cc)
#         ;
#
#
#
#
#             var marker_84394653c94f8708a636da692d4ced04 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_af8b4c59cb421fb97c8331d765d8f187);
#
#
#         var popup_898a3da8ed714f9bd212855d5174b60a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77e658dfdc2ee158b6f2981ede14c5b7 = $(`&lt;div id=&quot;html_77e658dfdc2ee158b6f2981ede14c5b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_898a3da8ed714f9bd212855d5174b60a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e86fcb5a61f3295c9fdb46c8888b5515 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e86fcb5a61f3295c9fdb46c8888b5515&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e86fcb5a61f3295c9fdb46c8888b5515 = L.map(
#                 &quot;map_e86fcb5a61f3295c9fdb46c8888b5515&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a5a29a7adf9bc0450d38868867e40f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a5a29a7adf9bc0450d38868867e40f9.addTo(map_e86fcb5a61f3295c9fdb46c8888b5515);
#
#
#             var feature_group_d5103927c611c002b4b294f043f28969 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ee03d234ff92e922a1ca80a5676abda1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d5103927c611c002b4b294f043f28969);
#
#
#         var popup_02622b4f15089ab72c3f412b4cab8780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b955ce6e3b012266c16e9039c22ec0d9 = $(`&lt;div id=&quot;html_b955ce6e3b012266c16e9039c22ec0d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_02622b4f15089ab72c3f412b4cab8780.setContent(html_b955ce6e3b012266c16e9039c22ec0d9);
#
#
#
#         marker_ee03d234ff92e922a1ca80a5676abda1.bindPopup(popup_02622b4f15089ab72c3f412b4cab8780)
#         ;
#
#
#
#
#             var marker_3c5b7810a52a56e3a49774fab4e7de2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d5103927c611c002b4b294f043f28969);
#
#
#         var popup_95ba7fc79619cda222ca404fe81d3326 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1f3747dc27e965c3d999b9b6a6b33f3 = $(`&lt;div id=&quot;html_d1f3747dc27e965c3d999b9b6a6b33f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_95ba7fc79619cda222ca404fe81d3326.setContent(html_d1f3747dc27e965c3d999b9b6a6b33f3);
#
#
#
#         marker_3c5b7810a52a56e3a49774fab4e7de2d.bindPopup(popup_95ba7fc79619cda222ca404fe81d3326)
#         ;
#
#
#
#
#             var marker_9cb589e72504de506321376389114e2a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d5103927c611c002b4b294f043f28969);
#
#
#         var popup_4d94b685d7f361da5fbc39ecff21fa5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fddb4157c8580834b3413bccc1b06c1 = $(`&lt;div id=&quot;html_5fddb4157c8580834b3413bccc1b06c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4d94b685d7f361da5fbc39ecff21fa5d.setContent(html_5fddb4157c8580834b3413bccc1b06c1);
#
#
#
#         marker_9cb589e72504de506321376389114e2a.bindPopup(popup_4d94b685d7f361da5fbc39ecff21fa5d)
#         ;
#
#
#
#
#             var marker_a6d38b65d50e9080b20592c0400abcc3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d5103927c611c002b4b294f043f28969);
#
#
#         var popup_931a4940e726a10144773bc871131368 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46fc4c3bf76b79d96698d09ee9dcac66 = $(`&lt;div id=&quot;html_46fc4c3bf76b79d96698d09ee9dcac66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_931a4940e726a10144773bc871131368.setContent(html_46fc4c3bf76b79d96698d09ee9dcac66);
#
#
#
#         marker_a6d38b65d50e9080b20592c0400abcc3.bindPopup(popup_931a4940e726a10144773bc871131368)
#         ;
#
#
#
#
#             var marker_7caa9cfa6bac37e4db136d4c84a13405 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d5103927c611c002b4b294f043f28969);
#
#
#         var popup_50a95348631300dfd0137985f32dcd37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7983a98a690fbb7484d5aadb888fe69a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7983a98a690fbb7484d5aadb888fe69a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7983a98a690fbb7484d5aadb888fe69a = L.map(
#                 &quot;map_7983a98a690fbb7484d5aadb888fe69a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a64d1d1e1a08da4904449fd109f6ab0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a64d1d1e1a08da4904449fd109f6ab0.addTo(map_7983a98a690fbb7484d5aadb888fe69a);
#
#
#             var feature_group_cff3bb579ed03e3ff9fabe69bc27a50a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cff3bb579ed03e3ff9fabe69bc27a50a.addTo(map_7983a98a690fbb7484d5aadb888fe69a);
#
#
#             var feature_group_sub_group_475a8b9bc54d0c497a132c74206f0482 = L.featureGroup.subGroup(
#                 feature_group_cff3bb579ed03e3ff9fabe69bc27a50a
#             );
#
#
#             var marker_ab56f921fad4a2808afdfc4c0dfcb635 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_475a8b9bc54d0c497a132c74206f0482);
#
#
#         var popup_d3b7201e3427990eed13097ae08a9e05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a4834d0e5403f89c38a48b1b1ec5b26 = $(`&lt;div id=&quot;html_5a4834d0e5403f89c38a48b1b1ec5b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d3b7201e3427990eed13097ae08a9e05.setContent(html_5a4834d0e5403f89c38a48b1b1ec5b26);
#
#
#
#         marker_ab56f921fad4a2808afdfc4c0dfcb635.bindPopup(popup_d3b7201e3427990eed13097ae08a9e05)
#         ;
#
#
#
#
#             var marker_980cad3d2f62e7945ad46b9182ee3db0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_475a8b9bc54d0c497a132c74206f0482);
#
#
#         var popup_32b47f6d14cdd4e7f0c81c7d5e5fb660 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c0b163674fd7a74531aaadb9c45e642 = $(`&lt;div id=&quot;html_0c0b163674fd7a74531aaadb9c45e642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_32b47f6d14cdd4e7f0c81c7d5e5fb660.setContent(html_0c0b163674fd7a74531aaadb9c45e642);
#
#
#
#         marker_980cad3d2f62e7945ad46b9182ee3db0.bindPopup(popup_32b47f6d14cdd4e7f0c81c7d5e5fb660)
#         ;
#
#
#
#
#             var marker_f5b9dd4cdf98ab17c85e52866ede74f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_475a8b9bc54d0c497a132c74206f0482);
#
#
#         var popup_fea0ce076cda61a25195f5468be9e518 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36c255e61ae8f34f1de3e3dcb006d191 = $(`&lt;div id=&quot;html_36c255e61ae8f34f1de3e3dcb006d191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fea0ce076cda61a25195f5468be9e518.setContent(html_36c255e61ae8f34f1de3e3dcb006d191);
#
#
#
#         marker_f5b9dd4cdf98ab17c85e52866ede74f6.bindPopup(popup_fea0ce076cda61a25195f5468be9e518)
#         ;
#
#
#
#
#             var marker_583eea86ae555a364d8d1929e4b86ab5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_475a8b9bc54d0c497a132c74206f0482);
#
#
#         var popup_961bc208a704efd07368bcfdb72b315c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e78af32a5eabccca2dad2a7bf843818a = $(`&lt;div id=&quot;html_e78af32a5eabccca2dad2a7bf843818a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_961bc208a704efd07368bcfdb72b315c.setContent(html_e78af32a5eabccca2dad2a7bf843818a);
#
#
#
#         marker_
