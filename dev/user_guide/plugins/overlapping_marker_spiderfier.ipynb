# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9746bf18d0935149d42eb38087cb8e33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9746bf18d0935149d42eb38087cb8e33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9746bf18d0935149d42eb38087cb8e33 = L.map(
#                 &quot;map_9746bf18d0935149d42eb38087cb8e33&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff5f70fe46826f9b1e4231ab22b0411d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff5f70fe46826f9b1e4231ab22b0411d.addTo(map_9746bf18d0935149d42eb38087cb8e33);
#
#
#             var marker_9ed6dc4b24d55ba6fb3c2770d3123b78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9746bf18d0935149d42eb38087cb8e33);
#
#
#         var popup_46eba2574c3c1ed5282433061a6eb6b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_708c26b655f98ca6b353a8d116b68a82 = $(`&lt;div id=&quot;html_708c26b655f98ca6b353a8d116b68a82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_46eba2574c3c1ed5282433061a6eb6b7.setContent(html_708c26b655f98ca6b353a8d116b68a82);
#
#
#
#         marker_9ed6dc4b24d55ba6fb3c2770d3123b78.bindPopup(popup_46eba2574c3c1ed5282433061a6eb6b7)
#         ;
#
#
#
#
#             var marker_6f2a6e810077b0dc026050570a50b3d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9746bf18d0935149d42eb38087cb8e33);
#
#
#         var popup_8a5d84917915ba19e42b8ec2979a4b7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5496df953cd20304e5748eb2edab4d93 = $(`&lt;div id=&quot;html_5496df953cd20304e5748eb2edab4d93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8a5d84917915ba19e42b8ec2979a4b7f.setContent(html_5496df953cd20304e5748eb2edab4d93);
#
#
#
#         marker_6f2a6e810077b0dc026050570a50b3d5.bindPopup(popup_8a5d84917915ba19e42b8ec2979a4b7f)
#         ;
#
#
#
#
#             var marker_aea7a555416e15b887624d3dd8035e7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9746bf18d0935149d42eb38087cb8e33);
#
#
#         var popup_205a2bb261872905bfde63431df6a075 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f423aaea29b76d5a20f418fdc759efb0 = $(`&lt;div id=&quot;html_f423aaea29b76d5a20f418fdc759efb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_205a2bb261872905bfde63431df6a075.setContent(html_f423aaea29b76d5a20f418fdc759efb0);
#
#
#
#         marker_aea7a555416e15b887624d3dd8035e7e.bindPopup(popup_205a2bb261872905bfde63431df6a075)
#         ;
#
#
#
#
#             var marker_85db18dd21f9e265ceb7c3c716b264b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9746bf18d0935149d42eb38087cb8e33);
#
#
#         var popup_d40f1bc4a6ef4cade3a0314fc3ff8f13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24108ed83d27222c2fec6e6222a84c29 = $(`&lt;div id=&quot;html_24108ed83d27222c2fec6e6222a84c29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d40f1bc4a6ef4cade3a0314fc3ff8f13.setContent(html_24108ed83d27222c2fec6e6222a84c29);
#
#
#
#         marker_85db18dd21f9e265ceb7c3c716b264b2.bindPopup(popup_d40f1bc4a6ef4cade3a0314fc3ff8f13)
#         ;
#
#
#
#
#             var marker_74c47eea70dcaa8ad97e67561e76eb23 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9746bf18d0935149d42eb38087cb8e33);
#
#
#         var popup_a1e9ada2ba41f12f0a0967829ef40fc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fc9c61f5e3181624552944e315349cf = $(`&lt;div id=&quot;html_0fc9c61f5e3181624552944e315349cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a1e9ada2ba41f12f0a0967829ef40fc2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46f2cd55a488e8b43ac4799f0b95fa49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46f2cd55a488e8b43ac4799f0b95fa49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46f2cd55a488e8b43ac4799f0b95fa49 = L.map(
#                 &quot;map_46f2cd55a488e8b43ac4799f0b95fa49&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b14a0ed35fd9072f14a03265d9738f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b14a0ed35fd9072f14a03265d9738f9.addTo(map_46f2cd55a488e8b43ac4799f0b95fa49);
#
#
#             var feature_group_73f11a4e306fb5cc5dc59dcd0e106a2f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3aa84d8c50436a7108cbff0c55df3353 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_73f11a4e306fb5cc5dc59dcd0e106a2f);
#
#
#         var popup_e2b0b7dc0cb10697744a2e474bbf2131 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba0ca1654da4105062a6f84fb1a87362 = $(`&lt;div id=&quot;html_ba0ca1654da4105062a6f84fb1a87362&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e2b0b7dc0cb10697744a2e474bbf2131.setContent(html_ba0ca1654da4105062a6f84fb1a87362);
#
#
#
#         marker_3aa84d8c50436a7108cbff0c55df3353.bindPopup(popup_e2b0b7dc0cb10697744a2e474bbf2131)
#         ;
#
#
#
#
#             var marker_c85bc6533d55b96cbda7f12771feb137 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_73f11a4e306fb5cc5dc59dcd0e106a2f);
#
#
#         var popup_12b1d28aad34b0e1a2e37b40c22be624 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6afd6d4c1a8827cbedf9a6ce32a978c = $(`&lt;div id=&quot;html_f6afd6d4c1a8827cbedf9a6ce32a978c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_12b1d28aad34b0e1a2e37b40c22be624.setContent(html_f6afd6d4c1a8827cbedf9a6ce32a978c);
#
#
#
#         marker_c85bc6533d55b96cbda7f12771feb137.bindPopup(popup_12b1d28aad34b0e1a2e37b40c22be624)
#         ;
#
#
#
#
#             var marker_813ab5138dd39669af8bb3c406af0389 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_73f11a4e306fb5cc5dc59dcd0e106a2f);
#
#
#         var popup_cc8eae718cf4f9586ad1c96565e67477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e49ae5bf708b0502b5f28add649481 = $(`&lt;div id=&quot;html_58e49ae5bf708b0502b5f28add649481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cc8eae718cf4f9586ad1c96565e67477.setContent(html_58e49ae5bf708b0502b5f28add649481);
#
#
#
#         marker_813ab5138dd39669af8bb3c406af0389.bindPopup(popup_cc8eae718cf4f9586ad1c96565e67477)
#         ;
#
#
#
#
#             var marker_45eec992692f33c29ac72fd2e15f17e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_73f11a4e306fb5cc5dc59dcd0e106a2f);
#
#
#         var popup_a5a8eac6ee0d4c228dd0d18b2256430a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cc65b54913750ad6703337dd68610ba = $(`&lt;div id=&quot;html_4cc65b54913750ad6703337dd68610ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a5a8eac6ee0d4c228dd0d18b2256430a.setContent(html_4cc65b54913750ad6703337dd68610ba);
#
#
#
#         marker_45eec992692f33c29ac72fd2e15f17e4.bindPopup(popup_a5a8eac6ee0d4c228dd0d18b2256430a)
#         ;
#
#
#
#
#             var marker_4cfe5633dcf9d57cddc75ef6458cfb30 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_73f11a4e306fb5cc5dc59dcd0e106a2f);
#
#
#         var popup_7514f427b7bc08e1bf1c874d8b5e86c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b17aca999855dd50cdfc729160099be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b17aca999855dd50cdfc729160099be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b17aca999855dd50cdfc729160099be = L.map(
#                 &quot;map_9b17aca999855dd50cdfc729160099be&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7964952064e68fe9d9cf412dbabcf0e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7964952064e68fe9d9cf412dbabcf0e6.addTo(map_9b17aca999855dd50cdfc729160099be);
#
#
#             var feature_group_f4e7d7d94a95e526c2e9b49138d57b09 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f4e7d7d94a95e526c2e9b49138d57b09.addTo(map_9b17aca999855dd50cdfc729160099be);
#
#
#             var feature_group_sub_group_27bf972b7a47bbfdbe66ec0ee087509b = L.featureGroup.subGroup(
#                 feature_group_f4e7d7d94a95e526c2e9b49138d57b09
#             );
#
#
#             var marker_7897d4b6d1e44c913b0d7c873c195cd8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_27bf972b7a47bbfdbe66ec0ee087509b);
#
#
#         var popup_1c01590e8c2e131f92c0fdae5bdef310 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90e724cae4b153c85691baf6203821c5 = $(`&lt;div id=&quot;html_90e724cae4b153c85691baf6203821c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1c01590e8c2e131f92c0fdae5bdef310.setContent(html_90e724cae4b153c85691baf6203821c5);
#
#
#
#         marker_7897d4b6d1e44c913b0d7c873c195cd8.bindPopup(popup_1c01590e8c2e131f92c0fdae5bdef310)
#         ;
#
#
#
#
#             var marker_dce1e952ad301da82a9d736045d7ed32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_27bf972b7a47bbfdbe66ec0ee087509b);
#
#
#         var popup_6313a6f58d9625a7968c8226cedc1057 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c24331246c15586ee04a94444d1a2f4 = $(`&lt;div id=&quot;html_2c24331246c15586ee04a94444d1a2f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6313a6f58d9625a7968c8226cedc1057.setContent(html_2c24331246c15586ee04a94444d1a2f4);
#
#
#
#         marker_dce1e952ad301da82a9d736045d7ed32.bindPopup(popup_6313a6f58d9625a7968c8226cedc1057)
#         ;
#
#
#
#
#             var marker_20cb757ef251eaba5ec714f0c47c01d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_27bf972b7a47bbfdbe66ec0ee087509b);
#
#
#         var popup_ef659f4f4c2d045cb9a47918f5a24b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b795f970f9dd3ce86721792ece1b7e9 = $(`&lt;div id=&quot;html_2b795f970f9dd3ce86721792ece1b7e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef659f4f4c2d045cb9a47918f5a24b1d.setContent(html_2b795f970f9dd3ce86721792ece1b7e9);
#
#
#
#         marker_20cb757ef251eaba5ec714f0c47c01d5.bindPopup(popup_ef659f4f4c2d045cb9a47918f5a24b1d)
#         ;
#
#
#
#
#             var marker_9d7e0d253c5315e94840dd80ae9b7ccc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_27bf972b7a47bbfdbe66ec0ee087509b);
#
#
#         var popup_ec7c17eacc6c6f1a7e69d489e1b173c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e450435a96137927551d2677db0ca07f = $(`&lt;div id=&quot;html_e450435a96137927551d2677db0ca07f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ec7c17eacc6c6f1a7e69d489e1b173c3.setContent(html_e450435a96137927551d2677db0ca07f);
#
#
#
#         marker_
