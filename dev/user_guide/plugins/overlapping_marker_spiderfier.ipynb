# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee532f450749ef01336348bacfb7a3d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee532f450749ef01336348bacfb7a3d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee532f450749ef01336348bacfb7a3d8 = L.map(
#                 &quot;map_ee532f450749ef01336348bacfb7a3d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_445012140e9a2099e1264a7fb11de53c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_445012140e9a2099e1264a7fb11de53c.addTo(map_ee532f450749ef01336348bacfb7a3d8);
#
#
#             var marker_ccb2cb4988b5144d3bc91b4a0ec3f092 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ee532f450749ef01336348bacfb7a3d8);
#
#
#         var popup_9ef382ed1c85a958f1455fadb1645c99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c74256e9c6214607eca61fe3a600ee0d = $(`&lt;div id=&quot;html_c74256e9c6214607eca61fe3a600ee0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9ef382ed1c85a958f1455fadb1645c99.setContent(html_c74256e9c6214607eca61fe3a600ee0d);
#
#
#
#         marker_ccb2cb4988b5144d3bc91b4a0ec3f092.bindPopup(popup_9ef382ed1c85a958f1455fadb1645c99)
#         ;
#
#
#
#
#             var marker_4310dc602815e5f5d45f85187541a533 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ee532f450749ef01336348bacfb7a3d8);
#
#
#         var popup_efb95819c0c0ddfbda5d4e257a3a0daa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1f9fb333cad2c2146eb323e3c9a640e = $(`&lt;div id=&quot;html_b1f9fb333cad2c2146eb323e3c9a640e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_efb95819c0c0ddfbda5d4e257a3a0daa.setContent(html_b1f9fb333cad2c2146eb323e3c9a640e);
#
#
#
#         marker_4310dc602815e5f5d45f85187541a533.bindPopup(popup_efb95819c0c0ddfbda5d4e257a3a0daa)
#         ;
#
#
#
#
#             var marker_0604205efee8d05c5823dc5f8994c33b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ee532f450749ef01336348bacfb7a3d8);
#
#
#         var popup_d6e382114acfd440ee77d724277daeb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_354422b4cb23b1fbbdfe8b3db7f8bf1f = $(`&lt;div id=&quot;html_354422b4cb23b1fbbdfe8b3db7f8bf1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d6e382114acfd440ee77d724277daeb1.setContent(html_354422b4cb23b1fbbdfe8b3db7f8bf1f);
#
#
#
#         marker_0604205efee8d05c5823dc5f8994c33b.bindPopup(popup_d6e382114acfd440ee77d724277daeb1)
#         ;
#
#
#
#
#             var marker_c7fe899be7d21cfb225a51dcc5603046 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ee532f450749ef01336348bacfb7a3d8);
#
#
#         var popup_f52db757944a88dd4698322bdf739213 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c255542b4984c73b22bf74080176d44d = $(`&lt;div id=&quot;html_c255542b4984c73b22bf74080176d44d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f52db757944a88dd4698322bdf739213.setContent(html_c255542b4984c73b22bf74080176d44d);
#
#
#
#         marker_c7fe899be7d21cfb225a51dcc5603046.bindPopup(popup_f52db757944a88dd4698322bdf739213)
#         ;
#
#
#
#
#             var marker_c4e5600f715c05ad73fa3dcce412d838 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ee532f450749ef01336348bacfb7a3d8);
#
#
#         var popup_6d7b4526502eeb2a4808df0279f12bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6135c950022508106bdd78e6e96e2068 = $(`&lt;div id=&quot;html_6135c950022508106bdd78e6e96e2068&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6d7b4526502eeb2a4808df0279f12bfd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6eb5b0db3a6f3aa013b6a3df50c087c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6eb5b0db3a6f3aa013b6a3df50c087c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6eb5b0db3a6f3aa013b6a3df50c087c3 = L.map(
#                 &quot;map_6eb5b0db3a6f3aa013b6a3df50c087c3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fd14d07b183f69aa857e7d3a31b87de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fd14d07b183f69aa857e7d3a31b87de.addTo(map_6eb5b0db3a6f3aa013b6a3df50c087c3);
#
#
#             var feature_group_f53d59b4ff7ccdbd1feb33a54e9fcaa6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3b3ce3dca055be218bf86ccf4358eab9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f53d59b4ff7ccdbd1feb33a54e9fcaa6);
#
#
#         var popup_c1835277f6094e4e1c2147d48121ad3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a9ec9f9c0eadb45b5f5e45bb4315756 = $(`&lt;div id=&quot;html_6a9ec9f9c0eadb45b5f5e45bb4315756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c1835277f6094e4e1c2147d48121ad3a.setContent(html_6a9ec9f9c0eadb45b5f5e45bb4315756);
#
#
#
#         marker_3b3ce3dca055be218bf86ccf4358eab9.bindPopup(popup_c1835277f6094e4e1c2147d48121ad3a)
#         ;
#
#
#
#
#             var marker_b15ab40386ee761402c543ce0df7bf12 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f53d59b4ff7ccdbd1feb33a54e9fcaa6);
#
#
#         var popup_7bf35c55e9bc0f54fcec57c833bf8b4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35480ec77a5a1667a45968f3ca8559e4 = $(`&lt;div id=&quot;html_35480ec77a5a1667a45968f3ca8559e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7bf35c55e9bc0f54fcec57c833bf8b4a.setContent(html_35480ec77a5a1667a45968f3ca8559e4);
#
#
#
#         marker_b15ab40386ee761402c543ce0df7bf12.bindPopup(popup_7bf35c55e9bc0f54fcec57c833bf8b4a)
#         ;
#
#
#
#
#             var marker_97a2af7d7cac52150b376ec412211c50 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f53d59b4ff7ccdbd1feb33a54e9fcaa6);
#
#
#         var popup_596070239d1733c4712e31a167177755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a20188be6fa72267d939afcb884665 = $(`&lt;div id=&quot;html_94a20188be6fa72267d939afcb884665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_596070239d1733c4712e31a167177755.setContent(html_94a20188be6fa72267d939afcb884665);
#
#
#
#         marker_97a2af7d7cac52150b376ec412211c50.bindPopup(popup_596070239d1733c4712e31a167177755)
#         ;
#
#
#
#
#             var marker_9c4631a872b695ffae84fd4e9db0b055 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f53d59b4ff7ccdbd1feb33a54e9fcaa6);
#
#
#         var popup_405ad4b844b7b82efb065d803dd60ef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d685e710daac2858865c26761ad9e5ee = $(`&lt;div id=&quot;html_d685e710daac2858865c26761ad9e5ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_405ad4b844b7b82efb065d803dd60ef2.setContent(html_d685e710daac2858865c26761ad9e5ee);
#
#
#
#         marker_9c4631a872b695ffae84fd4e9db0b055.bindPopup(popup_405ad4b844b7b82efb065d803dd60ef2)
#         ;
#
#
#
#
#             var marker_06ecbdb3229a29518c90a4956b6f6145 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f53d59b4ff7ccdbd1feb33a54e9fcaa6);
#
#
#         var popup_899780e3087ea6e893f043229aa5f213 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b4d598f386fae262b3c090bbed0a433 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b4d598f386fae262b3c090bbed0a433&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b4d598f386fae262b3c090bbed0a433 = L.map(
#                 &quot;map_9b4d598f386fae262b3c090bbed0a433&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fac982d5260fd3554b7101ae234c72f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1fac982d5260fd3554b7101ae234c72f.addTo(map_9b4d598f386fae262b3c090bbed0a433);
#
#
#             var feature_group_0ffda5914ab13671200684467c713550 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0ffda5914ab13671200684467c713550.addTo(map_9b4d598f386fae262b3c090bbed0a433);
#
#
#             var feature_group_sub_group_3f435723f9dc6c44a6a3f238c0eb5727 = L.featureGroup.subGroup(
#                 feature_group_0ffda5914ab13671200684467c713550
#             );
#
#
#             var marker_48c9c46bea835ab3ced374dbd50986df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f435723f9dc6c44a6a3f238c0eb5727);
#
#
#         var popup_dc9131fec345d0d6fd3184477deb67d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d2f74b962b160febc2537c50e865af6 = $(`&lt;div id=&quot;html_8d2f74b962b160febc2537c50e865af6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dc9131fec345d0d6fd3184477deb67d3.setContent(html_8d2f74b962b160febc2537c50e865af6);
#
#
#
#         marker_48c9c46bea835ab3ced374dbd50986df.bindPopup(popup_dc9131fec345d0d6fd3184477deb67d3)
#         ;
#
#
#
#
#             var marker_eeb436f26ca1cdfc78e37adc6a49a3c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f435723f9dc6c44a6a3f238c0eb5727);
#
#
#         var popup_96dc2f4808a914c73a67bc17b6911765 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a8ea36bf7d574737633e3efa00dfc1 = $(`&lt;div id=&quot;html_90a8ea36bf7d574737633e3efa00dfc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_96dc2f4808a914c73a67bc17b6911765.setContent(html_90a8ea36bf7d574737633e3efa00dfc1);
#
#
#
#         marker_eeb436f26ca1cdfc78e37adc6a49a3c6.bindPopup(popup_96dc2f4808a914c73a67bc17b6911765)
#         ;
#
#
#
#
#             var marker_c0e43af613c7095f918bbc79ae53ee92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f435723f9dc6c44a6a3f238c0eb5727);
#
#
#         var popup_43518abd589841eda64257969aab24a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc70e3c1fc6ce8de20349bc845192c71 = $(`&lt;div id=&quot;html_bc70e3c1fc6ce8de20349bc845192c71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_43518abd589841eda64257969aab24a7.setContent(html_bc70e3c1fc6ce8de20349bc845192c71);
#
#
#
#         marker_c0e43af613c7095f918bbc79ae53ee92.bindPopup(popup_43518abd589841eda64257969aab24a7)
#         ;
#
#
#
#
#             var marker_a2b860073d09d942c03057787375cdb2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f435723f9dc6c44a6a3f238c0eb5727);
#
#
#         var popup_2c42dfbca4188f212998a3c39cf159e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6bee2aef8234b9e667169b4bc26ccf4 = $(`&lt;div id=&quot;html_b6bee2aef8234b9e667169b4bc26ccf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2c42dfbca4188f212998a3c39cf159e1.setContent(html_b6bee2aef8234b9e667169b4bc26ccf4);
#
#
#
#         marker_
