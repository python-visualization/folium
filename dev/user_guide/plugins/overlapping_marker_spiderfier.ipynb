# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78b7897ce4bbf1edc8dbba3b4d83047d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78b7897ce4bbf1edc8dbba3b4d83047d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78b7897ce4bbf1edc8dbba3b4d83047d = L.map(
#                 &quot;map_78b7897ce4bbf1edc8dbba3b4d83047d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ab227ada308f262f6ab39a9750f212b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ab227ada308f262f6ab39a9750f212b.addTo(map_78b7897ce4bbf1edc8dbba3b4d83047d);
#
#
#             var marker_d3e6ac13c9550568d6005be614d155a1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_78b7897ce4bbf1edc8dbba3b4d83047d);
#
#
#         var popup_bebc3b45b0aceeed54fbfa987c846d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e33f0fffd994a08238ae3048459e4f8 = $(`&lt;div id=&quot;html_9e33f0fffd994a08238ae3048459e4f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bebc3b45b0aceeed54fbfa987c846d6a.setContent(html_9e33f0fffd994a08238ae3048459e4f8);
#
#
#
#         marker_d3e6ac13c9550568d6005be614d155a1.bindPopup(popup_bebc3b45b0aceeed54fbfa987c846d6a)
#         ;
#
#
#
#
#             var marker_40312a1d83143712b28710a4156310fc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_78b7897ce4bbf1edc8dbba3b4d83047d);
#
#
#         var popup_3240489490e9d2be3302c0b8c5360427 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cd79efb5dbadf2618463813defbf7ad = $(`&lt;div id=&quot;html_6cd79efb5dbadf2618463813defbf7ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3240489490e9d2be3302c0b8c5360427.setContent(html_6cd79efb5dbadf2618463813defbf7ad);
#
#
#
#         marker_40312a1d83143712b28710a4156310fc.bindPopup(popup_3240489490e9d2be3302c0b8c5360427)
#         ;
#
#
#
#
#             var marker_1a8215d0e29c96af2a1e15bd7b5b7cd5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_78b7897ce4bbf1edc8dbba3b4d83047d);
#
#
#         var popup_2303e8b80b414d24af1559f584266e6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f83972b69cf8c129e846f1bc5ce9bf6c = $(`&lt;div id=&quot;html_f83972b69cf8c129e846f1bc5ce9bf6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2303e8b80b414d24af1559f584266e6d.setContent(html_f83972b69cf8c129e846f1bc5ce9bf6c);
#
#
#
#         marker_1a8215d0e29c96af2a1e15bd7b5b7cd5.bindPopup(popup_2303e8b80b414d24af1559f584266e6d)
#         ;
#
#
#
#
#             var marker_2c2253cc3c531278b50bc0fadbe32044 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_78b7897ce4bbf1edc8dbba3b4d83047d);
#
#
#         var popup_0d9042d4c356fe8578fcdab5c616c21a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_462a43ac88b0eafe24249d738a48998c = $(`&lt;div id=&quot;html_462a43ac88b0eafe24249d738a48998c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d9042d4c356fe8578fcdab5c616c21a.setContent(html_462a43ac88b0eafe24249d738a48998c);
#
#
#
#         marker_2c2253cc3c531278b50bc0fadbe32044.bindPopup(popup_0d9042d4c356fe8578fcdab5c616c21a)
#         ;
#
#
#
#
#             var marker_6b5d2b4b3eaa16fc584c80f7ba4332fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_78b7897ce4bbf1edc8dbba3b4d83047d);
#
#
#         var popup_a999acfccfa8a0cdc3e0e03bf99e3be7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74885103a1d4fcc8e69e7138244c395e = $(`&lt;div id=&quot;html_74885103a1d4fcc8e69e7138244c395e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a999acfccfa8a0cdc3e0e03bf99e3b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_372eeca44be69421c6e88eb276709adc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_372eeca44be69421c6e88eb276709adc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_372eeca44be69421c6e88eb276709adc = L.map(
#                 &quot;map_372eeca44be69421c6e88eb276709adc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61b976bbaa2904364a6ce156e4bd9b83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61b976bbaa2904364a6ce156e4bd9b83.addTo(map_372eeca44be69421c6e88eb276709adc);
#
#
#             var feature_group_303f27deeef39287cb53ab026bbbeb3d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ab891d40aa6f94012e298c35cc5b3e80 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_303f27deeef39287cb53ab026bbbeb3d);
#
#
#         var popup_9d403567cd26eaca16337dff11a128f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbd4955d290573e2977a7414eaa58753 = $(`&lt;div id=&quot;html_dbd4955d290573e2977a7414eaa58753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9d403567cd26eaca16337dff11a128f4.setContent(html_dbd4955d290573e2977a7414eaa58753);
#
#
#
#         marker_ab891d40aa6f94012e298c35cc5b3e80.bindPopup(popup_9d403567cd26eaca16337dff11a128f4)
#         ;
#
#
#
#
#             var marker_27b098ef91ae53f09028d060b98d6141 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_303f27deeef39287cb53ab026bbbeb3d);
#
#
#         var popup_80679f5e864d1a2cf6c007844c344c42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e41fa533ea984b81ed6d425998bafe21 = $(`&lt;div id=&quot;html_e41fa533ea984b81ed6d425998bafe21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_80679f5e864d1a2cf6c007844c344c42.setContent(html_e41fa533ea984b81ed6d425998bafe21);
#
#
#
#         marker_27b098ef91ae53f09028d060b98d6141.bindPopup(popup_80679f5e864d1a2cf6c007844c344c42)
#         ;
#
#
#
#
#             var marker_23256783f31c0ecec70d045fd9878494 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_303f27deeef39287cb53ab026bbbeb3d);
#
#
#         var popup_6590d547362d34ecd55c1837da1f2fea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14bae2888e2d863b598c9836bff720af = $(`&lt;div id=&quot;html_14bae2888e2d863b598c9836bff720af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6590d547362d34ecd55c1837da1f2fea.setContent(html_14bae2888e2d863b598c9836bff720af);
#
#
#
#         marker_23256783f31c0ecec70d045fd9878494.bindPopup(popup_6590d547362d34ecd55c1837da1f2fea)
#         ;
#
#
#
#
#             var marker_3621eddab7861f30f742bd0e451dd217 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_303f27deeef39287cb53ab026bbbeb3d);
#
#
#         var popup_b9d90b93289503936fdd2342bd8f2b71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f89f6fb7576788574e28300ab7edd3c7 = $(`&lt;div id=&quot;html_f89f6fb7576788574e28300ab7edd3c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b9d90b93289503936fdd2342bd8f2b71.setContent(html_f89f6fb7576788574e28300ab7edd3c7);
#
#
#
#         marker_3621eddab7861f30f742bd0e451dd217.bindPopup(popup_b9d90b93289503936fdd2342bd8f2b71)
#         ;
#
#
#
#
#             var marker_6a60844e27324de950f586d20fe683e6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_303f27deeef39287cb53ab026bbbeb3d);
#
#
#         var popup_0b68dc80693aa62bf9fe89062004db9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e26b26d7a73a2b192d6c8023a831d35 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e26b26d7a73a2b192d6c8023a831d35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e26b26d7a73a2b192d6c8023a831d35 = L.map(
#                 &quot;map_4e26b26d7a73a2b192d6c8023a831d35&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74bec692f4a948a458cc6620a9c18202 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74bec692f4a948a458cc6620a9c18202.addTo(map_4e26b26d7a73a2b192d6c8023a831d35);
#
#
#             var feature_group_8926ad4ed9206ff62665c79514c93b85 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8926ad4ed9206ff62665c79514c93b85.addTo(map_4e26b26d7a73a2b192d6c8023a831d35);
#
#
#             var feature_group_sub_group_f820db8c15554c8b84178d8f06a3d345 = L.featureGroup.subGroup(
#                 feature_group_8926ad4ed9206ff62665c79514c93b85
#             );
#
#
#             var marker_1dc1f9dcf7d2021665a0787bdc2c4cdc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f820db8c15554c8b84178d8f06a3d345);
#
#
#         var popup_2bfdec10a73a0602f516341924ddba0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90d52f51bac5ab10c2c9f5226465c9f0 = $(`&lt;div id=&quot;html_90d52f51bac5ab10c2c9f5226465c9f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2bfdec10a73a0602f516341924ddba0d.setContent(html_90d52f51bac5ab10c2c9f5226465c9f0);
#
#
#
#         marker_1dc1f9dcf7d2021665a0787bdc2c4cdc.bindPopup(popup_2bfdec10a73a0602f516341924ddba0d)
#         ;
#
#
#
#
#             var marker_340e096d72daaeb6760531b167d241e7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f820db8c15554c8b84178d8f06a3d345);
#
#
#         var popup_188ce3538ed847a4cec35ab65285e298 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a590b9915571ce91ed1ba89721878406 = $(`&lt;div id=&quot;html_a590b9915571ce91ed1ba89721878406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_188ce3538ed847a4cec35ab65285e298.setContent(html_a590b9915571ce91ed1ba89721878406);
#
#
#
#         marker_340e096d72daaeb6760531b167d241e7.bindPopup(popup_188ce3538ed847a4cec35ab65285e298)
#         ;
#
#
#
#
#             var marker_c93deb8763df3bc683d62ab2e32e9835 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f820db8c15554c8b84178d8f06a3d345);
#
#
#         var popup_cf3fbd36dcfe8212838e00de385130dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0f5113b245b80f78d0ac5bedd3d9033 = $(`&lt;div id=&quot;html_f0f5113b245b80f78d0ac5bedd3d9033&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cf3fbd36dcfe8212838e00de385130dd.setContent(html_f0f5113b245b80f78d0ac5bedd3d9033);
#
#
#
#         marker_c93deb8763df3bc683d62ab2e32e9835.bindPopup(popup_cf3fbd36dcfe8212838e00de385130dd)
#         ;
#
#
#
#
#             var marker_1a61a646f6ef7cc8e84d34ee531082bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f820db8c15554c8b84178d8f06a3d345);
#
#
#         var popup_743ef4f0d6710dac1b189d7bc6b54c2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4da7b6b36ff8e47ed203ad7903d7f247 = $(`&lt;div id=&quot;html_4da7b6b36ff8e47ed203ad7903d7f247&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_743ef4f0d6710dac1b189d7bc6b54c2b.setContent(html_4da7b6b36ff8e47ed203ad7903d7f247);
#
#
#
#         mark
