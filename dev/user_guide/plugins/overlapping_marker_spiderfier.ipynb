# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c79dd1cce764d164cf35bd245beee17 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c79dd1cce764d164cf35bd245beee17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c79dd1cce764d164cf35bd245beee17 = L.map(
#                 &quot;map_3c79dd1cce764d164cf35bd245beee17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac11a695d315e8e11b4d8fa00682ccc6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac11a695d315e8e11b4d8fa00682ccc6.addTo(map_3c79dd1cce764d164cf35bd245beee17);
#
#
#             var marker_f41094c79b88cc8808b098e8b197bdaa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3c79dd1cce764d164cf35bd245beee17);
#
#
#         var popup_34d48153734afef18fa731415d10123b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47f08a444b59bc576aa24c467727f1cb = $(`&lt;div id=&quot;html_47f08a444b59bc576aa24c467727f1cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_34d48153734afef18fa731415d10123b.setContent(html_47f08a444b59bc576aa24c467727f1cb);
#
#
#
#         marker_f41094c79b88cc8808b098e8b197bdaa.bindPopup(popup_34d48153734afef18fa731415d10123b)
#         ;
#
#
#
#
#             var marker_bfb3a0eb3f0f183075a9c780c53ec959 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3c79dd1cce764d164cf35bd245beee17);
#
#
#         var popup_0b6f80e1254510991e71cf91c2c56745 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5368aedb340cdb3f78b6a36bc8776861 = $(`&lt;div id=&quot;html_5368aedb340cdb3f78b6a36bc8776861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b6f80e1254510991e71cf91c2c56745.setContent(html_5368aedb340cdb3f78b6a36bc8776861);
#
#
#
#         marker_bfb3a0eb3f0f183075a9c780c53ec959.bindPopup(popup_0b6f80e1254510991e71cf91c2c56745)
#         ;
#
#
#
#
#             var marker_56d8fd78bfd92e88dc7b53d9cdf77617 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3c79dd1cce764d164cf35bd245beee17);
#
#
#         var popup_5a316e248eba411977f99eb005f0f680 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40d9af6bc5bee293b7c0c327626ac3b8 = $(`&lt;div id=&quot;html_40d9af6bc5bee293b7c0c327626ac3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5a316e248eba411977f99eb005f0f680.setContent(html_40d9af6bc5bee293b7c0c327626ac3b8);
#
#
#
#         marker_56d8fd78bfd92e88dc7b53d9cdf77617.bindPopup(popup_5a316e248eba411977f99eb005f0f680)
#         ;
#
#
#
#
#             var marker_c5a60b9a9fea76106a30513c8a988d94 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3c79dd1cce764d164cf35bd245beee17);
#
#
#         var popup_9eeff0d550021711d3ebbfb0633f3ac5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3a6948cb45e9a53ce8fe4042ad3f715 = $(`&lt;div id=&quot;html_a3a6948cb45e9a53ce8fe4042ad3f715&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9eeff0d550021711d3ebbfb0633f3ac5.setContent(html_a3a6948cb45e9a53ce8fe4042ad3f715);
#
#
#
#         marker_c5a60b9a9fea76106a30513c8a988d94.bindPopup(popup_9eeff0d550021711d3ebbfb0633f3ac5)
#         ;
#
#
#
#
#             var marker_82e98015022a8b4cf40ae9f01a266a89 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3c79dd1cce764d164cf35bd245beee17);
#
#
#         var popup_3a1310c44004fd59933bb19b3f047aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d00f052891a442054236550d73527173 = $(`&lt;div id=&quot;html_d00f052891a442054236550d73527173&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3a1310c44004fd59933bb19b3f047aed.setContent(html_d00f052891a442054236550d73527173);
#
#
#
#         marker_82e98015022a8b4cf40ae9f01a266a89.bindPopup(popup_3a1310c44004fd59933bb19b3f047aed)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e838d132549eb37ad11cdf617d6534e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e838d132549eb37ad11cdf617d6534e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e838d132549eb37ad11cdf617d6534e = L.map(
#                 &quot;map_7e838d132549eb37ad11cdf617d6534e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_891e6b190c84c23e9dc24b6068ba761c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_891e6b190c84c23e9dc24b6068ba761c.addTo(map_7e838d132549eb37ad11cdf617d6534e);
#
#
#             var feature_group_d498556ae446737f20b0b0c150c22f91 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_673e76a8f97f285fac09234576a2ba77 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d498556ae446737f20b0b0c150c22f91);
#
#
#         var popup_17fdf2ba09b7a64e9016b4527f58103b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bf8522512b66e911596209ddfbcd10c = $(`&lt;div id=&quot;html_4bf8522512b66e911596209ddfbcd10c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_17fdf2ba09b7a64e9016b4527f58103b.setContent(html_4bf8522512b66e911596209ddfbcd10c);
#
#
#
#         marker_673e76a8f97f285fac09234576a2ba77.bindPopup(popup_17fdf2ba09b7a64e9016b4527f58103b)
#         ;
#
#
#
#
#             var marker_7640d0c1b08c66c9e1463fc2d5408979 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d498556ae446737f20b0b0c150c22f91);
#
#
#         var popup_8e5782b1eb2c8bf41071a21d6d29fcb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4edf75478bc9f40c27a963611902e497 = $(`&lt;div id=&quot;html_4edf75478bc9f40c27a963611902e497&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8e5782b1eb2c8bf41071a21d6d29fcb0.setContent(html_4edf75478bc9f40c27a963611902e497);
#
#
#
#         marker_7640d0c1b08c66c9e1463fc2d5408979.bindPopup(popup_8e5782b1eb2c8bf41071a21d6d29fcb0)
#         ;
#
#
#
#
#             var marker_7214d14f94856bfb8d2a5dcee64852e4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d498556ae446737f20b0b0c150c22f91);
#
#
#         var popup_7168091bde0887b1bd33480c33abd17e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e7d78b784a2238b539e0b54d2cff4db = $(`&lt;div id=&quot;html_8e7d78b784a2238b539e0b54d2cff4db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7168091bde0887b1bd33480c33abd17e.setContent(html_8e7d78b784a2238b539e0b54d2cff4db);
#
#
#
#         marker_7214d14f94856bfb8d2a5dcee64852e4.bindPopup(popup_7168091bde0887b1bd33480c33abd17e)
#         ;
#
#
#
#
#             var marker_a7421ff99411881a6c5e0a76ea1f928b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d498556ae446737f20b0b0c150c22f91);
#
#
#         var popup_0d109ba45221958b11716f2b645dc9ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5f46d51a89a2e9c0cade0ea62f4d63 = $(`&lt;div id=&quot;html_4a5f46d51a89a2e9c0cade0ea62f4d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0d109ba45221958b11716f2b645dc9ac.setContent(html_4a5f46d51a89a2e9c0cade0ea62f4d63);
#
#
#
#         marker_a7421ff99411881a6c5e0a76ea1f928b.bindPopup(popup_0d109ba45221958b11716f2b645dc9ac)
#         ;
#
#
#
#
#             var marker_8046b8fd0f93d9b7ad2246fb07a436d4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d498556ae446737f20b0b0c150c22f91);
#
#
#         var popup_ffa23e2b02a1c2204864a422a3161058 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf52576b13d6f4bfe58ce8ff5522b6d1 = $(`&lt;div id=&quot;html_cf52576b13d6f4bfe58ce8ff5522b6d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ead55db36db19c7907d52062d8aefff {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ead55db36db19c7907d52062d8aefff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ead55db36db19c7907d52062d8aefff = L.map(
#                 &quot;map_7ead55db36db19c7907d52062d8aefff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cbf73d404bb978cf9a17cbc33aec273 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cbf73d404bb978cf9a17cbc33aec273.addTo(map_7ead55db36db19c7907d52062d8aefff);
#
#
#             var feature_group_38dc89dfe24e9a7410aee08e2d2524b9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_38dc89dfe24e9a7410aee08e2d2524b9.addTo(map_7ead55db36db19c7907d52062d8aefff);
#
#
#             var feature_group_sub_group_76409b7fddaeeff9937dbfbcaf05148e = L.featureGroup.subGroup(
#                 feature_group_38dc89dfe24e9a7410aee08e2d2524b9
#             );
#
#
#             var marker_dd0ccc7c92278dc520cfb4371cd15eb2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_76409b7fddaeeff9937dbfbcaf05148e);
#
#
#         var popup_9787f69547f19c72da2148df869d5b15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daf87d4553a782c9f234fff0cc08652c = $(`&lt;div id=&quot;html_daf87d4553a782c9f234fff0cc08652c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9787f69547f19c72da2148df869d5b15.setContent(html_daf87d4553a782c9f234fff0cc08652c);
#
#
#
#         marker_dd0ccc7c92278dc520cfb4371cd15eb2.bindPopup(popup_9787f69547f19c72da2148df869d5b15)
#         ;
#
#
#
#
#             var marker_47c49979387f893b9d8a6b190d6be804 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_76409b7fddaeeff9937dbfbcaf05148e);
#
#
#         var popup_974033592a4c87cf3d0a915db8eaff3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6fd64cd4f75005e1ff3e84a1b568a0e = $(`&lt;div id=&quot;html_d6fd64cd4f75005e1ff3e84a1b568a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_974033592a4c87cf3d0a915db8eaff3a.setContent(html_d6fd64cd4f75005e1ff3e84a1b568a0e);
#
#
#
#         marker_47c49979387f893b9d8a6b190d6be804.bindPopup(popup_974033592a4c87cf3d0a915db8eaff3a)
#         ;
#
#
#
#
#             var marker_dca324e00b947067a662cdec4248e78c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_76409b7fddaeeff9937dbfbcaf05148e);
#
#
#         var popup_80e0d0006449a718d77acee878470b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27fef97263a8bdc14197797daca42579 = $(`&lt;div id=&quot;html_27fef97263a8bdc14197797daca42579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_80e0d0006449a718d77acee878470b7e.setContent(html_27fef97263a8bdc14197797daca42579);
#
#
#
#         marker_dca324e00b947067a662cdec4248e78c.bindPopup(popup_80e0d0006449a718d77acee878470b7e)
#         ;
#
#
#
#
#             var marker_c53b97a263471da4baf1498497186c6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_76409b7fddaeeff9937dbfbcaf05148e);
#
#
#         var popup_5c9d0bfcd2c186c0da1f070777bc04b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7fa8187c83ea057755a76839a3b97b6 = $(`&lt;div id=&quot;html_b7fa8187c83ea057755a76839a3b97b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5c9d0bfcd2c186c0da1f070777bc04b9.setContent(html_b7fa8187c83ea057755a76839a3b97b6);
#
#
#
#         marker_c53b97a263471da4baf1498497186c6e.bindPopup(popup_5c9d0bfcd2c186c0da1f070777bc04b9)
#         ;
#
#
#
#
#             var marker_c39439acaad5311a2f3a2a9fb8644176 = L.marker(
#                 [45.0503999
