# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e25119a046bf4ac1d395992e955b52b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e25119a046bf4ac1d395992e955b52b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e25119a046bf4ac1d395992e955b52b2 = L.map(
#                 &quot;map_e25119a046bf4ac1d395992e955b52b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2953bb018432e7bf4427301b1e57967c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2953bb018432e7bf4427301b1e57967c.addTo(map_e25119a046bf4ac1d395992e955b52b2);
#
#
#             var marker_83f4fc6d023f5606acad686c3b08fd8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e25119a046bf4ac1d395992e955b52b2);
#
#
#         var popup_1f037da1517bcf7dcf3b1be35ff97db4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c64fa2035cc845720718be2c11cbb62 = $(`&lt;div id=&quot;html_3c64fa2035cc845720718be2c11cbb62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1f037da1517bcf7dcf3b1be35ff97db4.setContent(html_3c64fa2035cc845720718be2c11cbb62);
#
#
#
#         marker_83f4fc6d023f5606acad686c3b08fd8e.bindPopup(popup_1f037da1517bcf7dcf3b1be35ff97db4)
#         ;
#
#
#
#
#             var marker_689ec8e8b403fdf51f26ecf37bc235aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e25119a046bf4ac1d395992e955b52b2);
#
#
#         var popup_82425614366945d3b656ba55c1964b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8db4fa41742c1a8ecda526a4ff69ff83 = $(`&lt;div id=&quot;html_8db4fa41742c1a8ecda526a4ff69ff83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_82425614366945d3b656ba55c1964b28.setContent(html_8db4fa41742c1a8ecda526a4ff69ff83);
#
#
#
#         marker_689ec8e8b403fdf51f26ecf37bc235aa.bindPopup(popup_82425614366945d3b656ba55c1964b28)
#         ;
#
#
#
#
#             var marker_80b529bd2362d6d2b7df17e8128dfcc4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e25119a046bf4ac1d395992e955b52b2);
#
#
#         var popup_70fe1645f1a4b17abf64373c81b8e482 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f2cea8054066cf945e8784de2a76ad1 = $(`&lt;div id=&quot;html_1f2cea8054066cf945e8784de2a76ad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_70fe1645f1a4b17abf64373c81b8e482.setContent(html_1f2cea8054066cf945e8784de2a76ad1);
#
#
#
#         marker_80b529bd2362d6d2b7df17e8128dfcc4.bindPopup(popup_70fe1645f1a4b17abf64373c81b8e482)
#         ;
#
#
#
#
#             var marker_2f6a518579f34520cdc89d3cb4e2d321 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e25119a046bf4ac1d395992e955b52b2);
#
#
#         var popup_c0af97b257a359a12e71ce2f9d9df0aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_267a3ef46b9c9d52b2f8ed28c0b68087 = $(`&lt;div id=&quot;html_267a3ef46b9c9d52b2f8ed28c0b68087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c0af97b257a359a12e71ce2f9d9df0aa.setContent(html_267a3ef46b9c9d52b2f8ed28c0b68087);
#
#
#
#         marker_2f6a518579f34520cdc89d3cb4e2d321.bindPopup(popup_c0af97b257a359a12e71ce2f9d9df0aa)
#         ;
#
#
#
#
#             var marker_6ed2b626436659febefcfd64bf6bb26f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e25119a046bf4ac1d395992e955b52b2);
#
#
#         var popup_b18ff0feff867d9825f47d890283965b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb642c90951c3bf4059d61739dfbcd62 = $(`&lt;div id=&quot;html_eb642c90951c3bf4059d61739dfbcd62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b18ff0feff867d9825f47d890283965b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e61f39be65a7370744dd502f49017f18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e61f39be65a7370744dd502f49017f18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e61f39be65a7370744dd502f49017f18 = L.map(
#                 &quot;map_e61f39be65a7370744dd502f49017f18&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cb7f6aba65393587811d91cac421eac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6cb7f6aba65393587811d91cac421eac.addTo(map_e61f39be65a7370744dd502f49017f18);
#
#
#             var feature_group_2684a613d2265044b9f8c11adf24da5f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_16faf93b954086999d0f4dde9f37aecb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2684a613d2265044b9f8c11adf24da5f);
#
#
#         var popup_72c8d73c038db765c057688a6ac121b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3271ee51d21aca5f8c2cf963b6e37bf = $(`&lt;div id=&quot;html_f3271ee51d21aca5f8c2cf963b6e37bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_72c8d73c038db765c057688a6ac121b6.setContent(html_f3271ee51d21aca5f8c2cf963b6e37bf);
#
#
#
#         marker_16faf93b954086999d0f4dde9f37aecb.bindPopup(popup_72c8d73c038db765c057688a6ac121b6)
#         ;
#
#
#
#
#             var marker_cc6e9f72380c00e0efe36d11086246ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2684a613d2265044b9f8c11adf24da5f);
#
#
#         var popup_83331e26a64b1dd578a0c499b5eb9b1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c293c8a78535de9338ae1bfb6cae3a0e = $(`&lt;div id=&quot;html_c293c8a78535de9338ae1bfb6cae3a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_83331e26a64b1dd578a0c499b5eb9b1e.setContent(html_c293c8a78535de9338ae1bfb6cae3a0e);
#
#
#
#         marker_cc6e9f72380c00e0efe36d11086246ea.bindPopup(popup_83331e26a64b1dd578a0c499b5eb9b1e)
#         ;
#
#
#
#
#             var marker_eec290fce6a6765a76c97d54807e6f20 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2684a613d2265044b9f8c11adf24da5f);
#
#
#         var popup_de7ea9100745d2eb96cac1a38fc39cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00648f9bbb868991b34e2de47291e8c9 = $(`&lt;div id=&quot;html_00648f9bbb868991b34e2de47291e8c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_de7ea9100745d2eb96cac1a38fc39cbf.setContent(html_00648f9bbb868991b34e2de47291e8c9);
#
#
#
#         marker_eec290fce6a6765a76c97d54807e6f20.bindPopup(popup_de7ea9100745d2eb96cac1a38fc39cbf)
#         ;
#
#
#
#
#             var marker_aae07cd232cf021b412e58fb02ab48e9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2684a613d2265044b9f8c11adf24da5f);
#
#
#         var popup_c7df542c6c1f6d81d110f2bb829081b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1c4ae9de7ec8066147a74c0011be3a7 = $(`&lt;div id=&quot;html_c1c4ae9de7ec8066147a74c0011be3a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c7df542c6c1f6d81d110f2bb829081b6.setContent(html_c1c4ae9de7ec8066147a74c0011be3a7);
#
#
#
#         marker_aae07cd232cf021b412e58fb02ab48e9.bindPopup(popup_c7df542c6c1f6d81d110f2bb829081b6)
#         ;
#
#
#
#
#             var marker_eb1328b27d99bf96c7c4afc47a26f8c3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2684a613d2265044b9f8c11adf24da5f);
#
#
#         var popup_a5bcc76024de5e8eebf54d16e06c0dff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c57483fa6a0b2d391e5a9a32f65f296d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c57483fa6a0b2d391e5a9a32f65f296d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c57483fa6a0b2d391e5a9a32f65f296d = L.map(
#                 &quot;map_c57483fa6a0b2d391e5a9a32f65f296d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e2c626f9c2824ea09184ac737c2c097 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e2c626f9c2824ea09184ac737c2c097.addTo(map_c57483fa6a0b2d391e5a9a32f65f296d);
#
#
#             var feature_group_84f72545fda01544e32cd7dd1a10cbfa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_84f72545fda01544e32cd7dd1a10cbfa.addTo(map_c57483fa6a0b2d391e5a9a32f65f296d);
#
#
#             var feature_group_sub_group_32aa5761ef2dc37ca0670af7f75e6d49 = L.featureGroup.subGroup(
#                 feature_group_84f72545fda01544e32cd7dd1a10cbfa
#             );
#
#
#             var marker_80764d873352e6b6a1bac695e6dd7dca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_32aa5761ef2dc37ca0670af7f75e6d49);
#
#
#         var popup_d2b7f67cf0865adf9b6060f3632cc0c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2ce283cd276052815ce172c317ba4b9 = $(`&lt;div id=&quot;html_b2ce283cd276052815ce172c317ba4b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d2b7f67cf0865adf9b6060f3632cc0c5.setContent(html_b2ce283cd276052815ce172c317ba4b9);
#
#
#
#         marker_80764d873352e6b6a1bac695e6dd7dca.bindPopup(popup_d2b7f67cf0865adf9b6060f3632cc0c5)
#         ;
#
#
#
#
#             var marker_8a3fe0b56466c0a2b7a4c91ffadbfebe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_32aa5761ef2dc37ca0670af7f75e6d49);
#
#
#         var popup_285b2cd85af56c906a1b1b51d1b69453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_205fbff6709a3d47c33610b211224fd1 = $(`&lt;div id=&quot;html_205fbff6709a3d47c33610b211224fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_285b2cd85af56c906a1b1b51d1b69453.setContent(html_205fbff6709a3d47c33610b211224fd1);
#
#
#
#         marker_8a3fe0b56466c0a2b7a4c91ffadbfebe.bindPopup(popup_285b2cd85af56c906a1b1b51d1b69453)
#         ;
#
#
#
#
#             var marker_00ea681ace1705accf2e4b0d5f01e97e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_32aa5761ef2dc37ca0670af7f75e6d49);
#
#
#         var popup_562ca7dd206c81d01a3d55d500713348 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7226544b86399043237dcebd1db1b78 = $(`&lt;div id=&quot;html_e7226544b86399043237dcebd1db1b78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_562ca7dd206c81d01a3d55d500713348.setContent(html_e7226544b86399043237dcebd1db1b78);
#
#
#
#         marker_00ea681ace1705accf2e4b0d5f01e97e.bindPopup(popup_562ca7dd206c81d01a3d55d500713348)
#         ;
#
#
#
#
#             var marker_6efc42888781954058dcc0e196c6f9cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_32aa5761ef2dc37ca0670af7f75e6d49);
#
#
#         var popup_d596b7d280a95b389e717774577d4d56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56376a17b3a386705a659797a35020f4 = $(`&lt;div id=&quot;html_56376a17b3a386705a659797a35020f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d596b7d280a95b389e717774577d4d56.setContent(html_56376a17b3a386705a659797a35020f4);
#
#
#
#         marker_
