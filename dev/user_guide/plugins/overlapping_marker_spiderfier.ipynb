# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4ee99590d3908d041f42b19faa1458c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4ee99590d3908d041f42b19faa1458c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4ee99590d3908d041f42b19faa1458c = L.map(
#                 &quot;map_a4ee99590d3908d041f42b19faa1458c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_899b2dde12bd057033382ceb9503d394 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_899b2dde12bd057033382ceb9503d394.addTo(map_a4ee99590d3908d041f42b19faa1458c);
#
#
#             var marker_5a3acf3d5bba800afa063d261c748820 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a4ee99590d3908d041f42b19faa1458c);
#
#
#         var popup_b42d2a8a4322d95bf103e90415359641 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2129323467cb5e8e458087cf776e57a3 = $(`&lt;div id=&quot;html_2129323467cb5e8e458087cf776e57a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b42d2a8a4322d95bf103e90415359641.setContent(html_2129323467cb5e8e458087cf776e57a3);
#
#
#
#         marker_5a3acf3d5bba800afa063d261c748820.bindPopup(popup_b42d2a8a4322d95bf103e90415359641)
#         ;
#
#
#
#
#             var marker_bd584ce2772c15412f7a9455224f8daf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a4ee99590d3908d041f42b19faa1458c);
#
#
#         var popup_f2ef786ab62415d03f986f9e75d90a3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97dd1dfefcefe775d0634dfdb3b48378 = $(`&lt;div id=&quot;html_97dd1dfefcefe775d0634dfdb3b48378&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f2ef786ab62415d03f986f9e75d90a3d.setContent(html_97dd1dfefcefe775d0634dfdb3b48378);
#
#
#
#         marker_bd584ce2772c15412f7a9455224f8daf.bindPopup(popup_f2ef786ab62415d03f986f9e75d90a3d)
#         ;
#
#
#
#
#             var marker_79c9b9d6bb25744e084f067b9359b90f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a4ee99590d3908d041f42b19faa1458c);
#
#
#         var popup_24d9c873314ddae0967daa65d28d0a83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c11c7430cc8145e151dac68dd240bc1 = $(`&lt;div id=&quot;html_4c11c7430cc8145e151dac68dd240bc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_24d9c873314ddae0967daa65d28d0a83.setContent(html_4c11c7430cc8145e151dac68dd240bc1);
#
#
#
#         marker_79c9b9d6bb25744e084f067b9359b90f.bindPopup(popup_24d9c873314ddae0967daa65d28d0a83)
#         ;
#
#
#
#
#             var marker_2b3424524350cf8ef848d734f9781e28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a4ee99590d3908d041f42b19faa1458c);
#
#
#         var popup_e358097c91913fe6e795c85d5d7930ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db1ec682d3d319530264b19e8274a404 = $(`&lt;div id=&quot;html_db1ec682d3d319530264b19e8274a404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e358097c91913fe6e795c85d5d7930ac.setContent(html_db1ec682d3d319530264b19e8274a404);
#
#
#
#         marker_2b3424524350cf8ef848d734f9781e28.bindPopup(popup_e358097c91913fe6e795c85d5d7930ac)
#         ;
#
#
#
#
#             var marker_8b59861e5475fdf5256b6cbd657b6330 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a4ee99590d3908d041f42b19faa1458c);
#
#
#         var popup_1966853842b330437637dc04d0f2aab9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_040a893b8f4d3c8b18e9d8073e87933a = $(`&lt;div id=&quot;html_040a893b8f4d3c8b18e9d8073e87933a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1966853842b330437637dc04d0f2aab9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5d19bcc179044df1dfdd54ac004a4e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5d19bcc179044df1dfdd54ac004a4e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5d19bcc179044df1dfdd54ac004a4e7 = L.map(
#                 &quot;map_d5d19bcc179044df1dfdd54ac004a4e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1a9e46cd0b3fac57cf9c247954c471d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1a9e46cd0b3fac57cf9c247954c471d.addTo(map_d5d19bcc179044df1dfdd54ac004a4e7);
#
#
#             var feature_group_35b5bd4e50f062fba58e6b5f37f40091 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fb69ff38492be0fc7e2bbe619fc8b00a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_35b5bd4e50f062fba58e6b5f37f40091);
#
#
#         var popup_f092c64b24570fbdbf7d7176c4a0f6b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cd4755e38cf7a285d5c173af28b13bc = $(`&lt;div id=&quot;html_8cd4755e38cf7a285d5c173af28b13bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f092c64b24570fbdbf7d7176c4a0f6b3.setContent(html_8cd4755e38cf7a285d5c173af28b13bc);
#
#
#
#         marker_fb69ff38492be0fc7e2bbe619fc8b00a.bindPopup(popup_f092c64b24570fbdbf7d7176c4a0f6b3)
#         ;
#
#
#
#
#             var marker_4c3506154933b82326fb823bb7189db7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_35b5bd4e50f062fba58e6b5f37f40091);
#
#
#         var popup_e908ce6992565fbc3a15441dfbefce25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cbe24547c0297e600296596aa11f633 = $(`&lt;div id=&quot;html_3cbe24547c0297e600296596aa11f633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e908ce6992565fbc3a15441dfbefce25.setContent(html_3cbe24547c0297e600296596aa11f633);
#
#
#
#         marker_4c3506154933b82326fb823bb7189db7.bindPopup(popup_e908ce6992565fbc3a15441dfbefce25)
#         ;
#
#
#
#
#             var marker_a08d6e2c5410ebb6e662aa884308449e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_35b5bd4e50f062fba58e6b5f37f40091);
#
#
#         var popup_768e55593924ac865455dd50ce33189f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0245f582f66c0a31fccf48c6f94e398b = $(`&lt;div id=&quot;html_0245f582f66c0a31fccf48c6f94e398b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_768e55593924ac865455dd50ce33189f.setContent(html_0245f582f66c0a31fccf48c6f94e398b);
#
#
#
#         marker_a08d6e2c5410ebb6e662aa884308449e.bindPopup(popup_768e55593924ac865455dd50ce33189f)
#         ;
#
#
#
#
#             var marker_0c08bcea6596656b9f3feba54888c1ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_35b5bd4e50f062fba58e6b5f37f40091);
#
#
#         var popup_71cea32e16a7d8b8ee25b3410e750ae3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d62fc9e314f8e1bfdd569384dccd16c7 = $(`&lt;div id=&quot;html_d62fc9e314f8e1bfdd569384dccd16c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_71cea32e16a7d8b8ee25b3410e750ae3.setContent(html_d62fc9e314f8e1bfdd569384dccd16c7);
#
#
#
#         marker_0c08bcea6596656b9f3feba54888c1ca.bindPopup(popup_71cea32e16a7d8b8ee25b3410e750ae3)
#         ;
#
#
#
#
#             var marker_d6faf7bb7b1c0f792f147c61e70c4adc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_35b5bd4e50f062fba58e6b5f37f40091);
#
#
#         var popup_2c0d1cdc0dcf559307ca5b326dcc1ff9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16b2e8d1ed92f56b3b982ed9f49890a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16b2e8d1ed92f56b3b982ed9f49890a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16b2e8d1ed92f56b3b982ed9f49890a4 = L.map(
#                 &quot;map_16b2e8d1ed92f56b3b982ed9f49890a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7c25e933d900a9244a5dd2609ba0a17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a7c25e933d900a9244a5dd2609ba0a17.addTo(map_16b2e8d1ed92f56b3b982ed9f49890a4);
#
#
#             var feature_group_8dcc719c1e10e47761004bf1ea0e617f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8dcc719c1e10e47761004bf1ea0e617f.addTo(map_16b2e8d1ed92f56b3b982ed9f49890a4);
#
#
#             var feature_group_sub_group_a75a0a9249492048339fbe67efc198a8 = L.featureGroup.subGroup(
#                 feature_group_8dcc719c1e10e47761004bf1ea0e617f
#             );
#
#
#             var marker_33d4db818f8813db0a79ce1667586d39 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a75a0a9249492048339fbe67efc198a8);
#
#
#         var popup_fd2eb531aba5d63f4198d5360e392a0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42db0b3c1abefc22c7b20cb1cf77387f = $(`&lt;div id=&quot;html_42db0b3c1abefc22c7b20cb1cf77387f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fd2eb531aba5d63f4198d5360e392a0f.setContent(html_42db0b3c1abefc22c7b20cb1cf77387f);
#
#
#
#         marker_33d4db818f8813db0a79ce1667586d39.bindPopup(popup_fd2eb531aba5d63f4198d5360e392a0f)
#         ;
#
#
#
#
#             var marker_9376619c02694ed16b5609f3daee838d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a75a0a9249492048339fbe67efc198a8);
#
#
#         var popup_88572f2a54070772f786f4cfa76f3ff3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_557ab3fcbbef81965624c1f84d2a1d15 = $(`&lt;div id=&quot;html_557ab3fcbbef81965624c1f84d2a1d15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_88572f2a54070772f786f4cfa76f3ff3.setContent(html_557ab3fcbbef81965624c1f84d2a1d15);
#
#
#
#         marker_9376619c02694ed16b5609f3daee838d.bindPopup(popup_88572f2a54070772f786f4cfa76f3ff3)
#         ;
#
#
#
#
#             var marker_8d345d84ea132adb453d0aad54f3334d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a75a0a9249492048339fbe67efc198a8);
#
#
#         var popup_615477f458735d9fb756533a77dbba36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a4a21f7ab5487b035ad7c3b6ee8dfd7 = $(`&lt;div id=&quot;html_8a4a21f7ab5487b035ad7c3b6ee8dfd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_615477f458735d9fb756533a77dbba36.setContent(html_8a4a21f7ab5487b035ad7c3b6ee8dfd7);
#
#
#
#         marker_8d345d84ea132adb453d0aad54f3334d.bindPopup(popup_615477f458735d9fb756533a77dbba36)
#         ;
#
#
#
#
#             var marker_6cad31cfb2f27580dea9ce86d5c7c9b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a75a0a9249492048339fbe67efc198a8);
#
#
#         var popup_9c1ba12bf01a6a39dcac2f58d186b959 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fca76b4b8aecb38ebb1a65826e1a3c00 = $(`&lt;div id=&quot;html_fca76b4b8aecb38ebb1a65826e1a3c00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9c1ba12bf01a6a39dcac2f58d186b959.setContent(html_fca76b4b8aecb38ebb1a65826e1a3c00);
#
#
#
#         marker_
