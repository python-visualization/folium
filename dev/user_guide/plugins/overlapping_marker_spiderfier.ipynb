# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af257250dee6e4bef4a3a2a2996ccef7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af257250dee6e4bef4a3a2a2996ccef7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af257250dee6e4bef4a3a2a2996ccef7 = L.map(
#                 &quot;map_af257250dee6e4bef4a3a2a2996ccef7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1f92a63009962cdfff5daed16420c0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1f92a63009962cdfff5daed16420c0b.addTo(map_af257250dee6e4bef4a3a2a2996ccef7);
#
#
#             var marker_0ad07cd17f89aa50fd3ed8700c06db14 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_af257250dee6e4bef4a3a2a2996ccef7);
#
#
#         var popup_6809e57feecf43a9438385fcad3159fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_474eaf674be23fc2397a8bd8118b52d6 = $(`&lt;div id=&quot;html_474eaf674be23fc2397a8bd8118b52d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6809e57feecf43a9438385fcad3159fc.setContent(html_474eaf674be23fc2397a8bd8118b52d6);
#
#
#
#         marker_0ad07cd17f89aa50fd3ed8700c06db14.bindPopup(popup_6809e57feecf43a9438385fcad3159fc)
#         ;
#
#
#
#
#             var marker_0a725b996512a88a2c2dab8e04dc2aff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_af257250dee6e4bef4a3a2a2996ccef7);
#
#
#         var popup_52ee4cca268d7a9f607156b87160471a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f383bfbeb9d5e5df13d08cb27fdca803 = $(`&lt;div id=&quot;html_f383bfbeb9d5e5df13d08cb27fdca803&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52ee4cca268d7a9f607156b87160471a.setContent(html_f383bfbeb9d5e5df13d08cb27fdca803);
#
#
#
#         marker_0a725b996512a88a2c2dab8e04dc2aff.bindPopup(popup_52ee4cca268d7a9f607156b87160471a)
#         ;
#
#
#
#
#             var marker_89adaaae02ba9ecf6e2dbc8763fcc8da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_af257250dee6e4bef4a3a2a2996ccef7);
#
#
#         var popup_ef98164d4322c82c6aa7d2cb511e255c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9079bef4fec5fc47eb9685cf28fbb57e = $(`&lt;div id=&quot;html_9079bef4fec5fc47eb9685cf28fbb57e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ef98164d4322c82c6aa7d2cb511e255c.setContent(html_9079bef4fec5fc47eb9685cf28fbb57e);
#
#
#
#         marker_89adaaae02ba9ecf6e2dbc8763fcc8da.bindPopup(popup_ef98164d4322c82c6aa7d2cb511e255c)
#         ;
#
#
#
#
#             var marker_ae223ef9ea16ebf5eab27247e776c820 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_af257250dee6e4bef4a3a2a2996ccef7);
#
#
#         var popup_2f4b5ce3f10ec4ff24fc10833bc99147 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf8fb8ec9585d73b1fd9f171d98a30a3 = $(`&lt;div id=&quot;html_bf8fb8ec9585d73b1fd9f171d98a30a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2f4b5ce3f10ec4ff24fc10833bc99147.setContent(html_bf8fb8ec9585d73b1fd9f171d98a30a3);
#
#
#
#         marker_ae223ef9ea16ebf5eab27247e776c820.bindPopup(popup_2f4b5ce3f10ec4ff24fc10833bc99147)
#         ;
#
#
#
#
#             var marker_7ab63fb55eb69a98ec17dec6aac15926 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_af257250dee6e4bef4a3a2a2996ccef7);
#
#
#         var popup_9fab6929874b7349642c7c01dada3f5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0738d191cf5249011ad9432f352e601a = $(`&lt;div id=&quot;html_0738d191cf5249011ad9432f352e601a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9fab6929874b7349642c7c01dada3f5d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c41c162c0c90f8262c699a55ceb58ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c41c162c0c90f8262c699a55ceb58ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c41c162c0c90f8262c699a55ceb58ce = L.map(
#                 &quot;map_8c41c162c0c90f8262c699a55ceb58ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b38ba7160e5b041ed488fba7b77e79a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b38ba7160e5b041ed488fba7b77e79a1.addTo(map_8c41c162c0c90f8262c699a55ceb58ce);
#
#
#             var feature_group_716d525029cd886d7b85ae5d395dccee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3700a747e7e404291d63e026a4cd7fb2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_716d525029cd886d7b85ae5d395dccee);
#
#
#         var popup_574ff61fd4013bee34cf84c337b8211e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_606d56e4e0f3fab310c72d650bc6df51 = $(`&lt;div id=&quot;html_606d56e4e0f3fab310c72d650bc6df51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_574ff61fd4013bee34cf84c337b8211e.setContent(html_606d56e4e0f3fab310c72d650bc6df51);
#
#
#
#         marker_3700a747e7e404291d63e026a4cd7fb2.bindPopup(popup_574ff61fd4013bee34cf84c337b8211e)
#         ;
#
#
#
#
#             var marker_08571a198880bef05cc40b3198f655b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_716d525029cd886d7b85ae5d395dccee);
#
#
#         var popup_f8f127be9b1a00bb97f098fe3bca51b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc02a8cd8909470d488237509eea9448 = $(`&lt;div id=&quot;html_cc02a8cd8909470d488237509eea9448&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f8f127be9b1a00bb97f098fe3bca51b1.setContent(html_cc02a8cd8909470d488237509eea9448);
#
#
#
#         marker_08571a198880bef05cc40b3198f655b8.bindPopup(popup_f8f127be9b1a00bb97f098fe3bca51b1)
#         ;
#
#
#
#
#             var marker_a50ce0493ba4380cb0ed3e62224a43a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_716d525029cd886d7b85ae5d395dccee);
#
#
#         var popup_9780c7aeedd552cbedb90768c52e9b21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0becc21293d1725b0a855a0fa22fb6e6 = $(`&lt;div id=&quot;html_0becc21293d1725b0a855a0fa22fb6e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9780c7aeedd552cbedb90768c52e9b21.setContent(html_0becc21293d1725b0a855a0fa22fb6e6);
#
#
#
#         marker_a50ce0493ba4380cb0ed3e62224a43a6.bindPopup(popup_9780c7aeedd552cbedb90768c52e9b21)
#         ;
#
#
#
#
#             var marker_8f4dbb2fde054f071ce3366c90e7c0d3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_716d525029cd886d7b85ae5d395dccee);
#
#
#         var popup_e3a4b03d558809a924e83d786ef133c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8575abe46b24ed89662e60d1a702979f = $(`&lt;div id=&quot;html_8575abe46b24ed89662e60d1a702979f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e3a4b03d558809a924e83d786ef133c7.setContent(html_8575abe46b24ed89662e60d1a702979f);
#
#
#
#         marker_8f4dbb2fde054f071ce3366c90e7c0d3.bindPopup(popup_e3a4b03d558809a924e83d786ef133c7)
#         ;
#
#
#
#
#             var marker_584767dcefe32a4dd0e516a6e1f03006 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_716d525029cd886d7b85ae5d395dccee);
#
#
#         var popup_26ce64539bb310378754ccef14fd83ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_104899326b50ca1654f48d6e06cb7fc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_104899326b50ca1654f48d6e06cb7fc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_104899326b50ca1654f48d6e06cb7fc1 = L.map(
#                 &quot;map_104899326b50ca1654f48d6e06cb7fc1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_720cd858a0937c7ac504a3c71d3923fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_720cd858a0937c7ac504a3c71d3923fa.addTo(map_104899326b50ca1654f48d6e06cb7fc1);
#
#
#             var feature_group_7441edb771b161e481dfa4c9bfa16483 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7441edb771b161e481dfa4c9bfa16483.addTo(map_104899326b50ca1654f48d6e06cb7fc1);
#
#
#             var feature_group_sub_group_7d59c65d5aa847a181d8f7555a7d3c80 = L.featureGroup.subGroup(
#                 feature_group_7441edb771b161e481dfa4c9bfa16483
#             );
#
#
#             var marker_590a37cc07e5a373b6c80b16fd679e78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d59c65d5aa847a181d8f7555a7d3c80);
#
#
#         var popup_71c67989c2c46a11a892a1b4aa4911b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_285f8f52875d51829c920e03f313c99e = $(`&lt;div id=&quot;html_285f8f52875d51829c920e03f313c99e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_71c67989c2c46a11a892a1b4aa4911b6.setContent(html_285f8f52875d51829c920e03f313c99e);
#
#
#
#         marker_590a37cc07e5a373b6c80b16fd679e78.bindPopup(popup_71c67989c2c46a11a892a1b4aa4911b6)
#         ;
#
#
#
#
#             var marker_2ba27e26496d4f4424b07683875cca15 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d59c65d5aa847a181d8f7555a7d3c80);
#
#
#         var popup_ed2a1d8da8fad9eb825bfe2de5302962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f44c280ccfdd767821a75ee850d2dfe3 = $(`&lt;div id=&quot;html_f44c280ccfdd767821a75ee850d2dfe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ed2a1d8da8fad9eb825bfe2de5302962.setContent(html_f44c280ccfdd767821a75ee850d2dfe3);
#
#
#
#         marker_2ba27e26496d4f4424b07683875cca15.bindPopup(popup_ed2a1d8da8fad9eb825bfe2de5302962)
#         ;
#
#
#
#
#             var marker_719809179e3fe53ef0aafd7a7276116b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d59c65d5aa847a181d8f7555a7d3c80);
#
#
#         var popup_9a96014c7c7c63b1f0896beef54f9c55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11149c39b472e92abae9b23a17d9142d = $(`&lt;div id=&quot;html_11149c39b472e92abae9b23a17d9142d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9a96014c7c7c63b1f0896beef54f9c55.setContent(html_11149c39b472e92abae9b23a17d9142d);
#
#
#
#         marker_719809179e3fe53ef0aafd7a7276116b.bindPopup(popup_9a96014c7c7c63b1f0896beef54f9c55)
#         ;
#
#
#
#
#             var marker_9b821cac0246bead37b8b570c6cd145d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d59c65d5aa847a181d8f7555a7d3c80);
#
#
#         var popup_7fa327fcd82102a3e4230eaf31dde076 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_684b72a0ca95a8760501eb442549c429 = $(`&lt;div id=&quot;html_684b72a0ca95a8760501eb442549c429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7fa327fcd82102a3e4230eaf31dde076.setContent(html_684b72a0ca95a8760501eb442549c429);
#
#
#
#         marker_
