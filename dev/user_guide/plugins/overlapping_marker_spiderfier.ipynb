# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebceba4a726797622fc098e5cbddfbbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebceba4a726797622fc098e5cbddfbbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebceba4a726797622fc098e5cbddfbbc = L.map(
#                 &quot;map_ebceba4a726797622fc098e5cbddfbbc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54216c1506783660b3e35d7e8cacb741 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54216c1506783660b3e35d7e8cacb741.addTo(map_ebceba4a726797622fc098e5cbddfbbc);
#
#
#             var marker_2a480406af16865ea093abb1d4b8b45d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ebceba4a726797622fc098e5cbddfbbc);
#
#
#         var popup_a74d6060a825a9ff6bf468277229daaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c794f7830a6bfb991ebdfb5a11a3323 = $(`&lt;div id=&quot;html_7c794f7830a6bfb991ebdfb5a11a3323&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a74d6060a825a9ff6bf468277229daaf.setContent(html_7c794f7830a6bfb991ebdfb5a11a3323);
#
#
#
#         marker_2a480406af16865ea093abb1d4b8b45d.bindPopup(popup_a74d6060a825a9ff6bf468277229daaf)
#         ;
#
#
#
#
#             var marker_c2a12889e416b8af8feca6ba02bfae2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ebceba4a726797622fc098e5cbddfbbc);
#
#
#         var popup_69db73c377becaf34f50d898c9b1a87b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85b6cabe4763af19ab5d03079009fe57 = $(`&lt;div id=&quot;html_85b6cabe4763af19ab5d03079009fe57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_69db73c377becaf34f50d898c9b1a87b.setContent(html_85b6cabe4763af19ab5d03079009fe57);
#
#
#
#         marker_c2a12889e416b8af8feca6ba02bfae2d.bindPopup(popup_69db73c377becaf34f50d898c9b1a87b)
#         ;
#
#
#
#
#             var marker_176a21c2bbf5a5e30264d957ca2becb6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ebceba4a726797622fc098e5cbddfbbc);
#
#
#         var popup_07815dce341312c4ba096fda92df1bb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_127ce4a92ab677f696c3fcc0ed20181d = $(`&lt;div id=&quot;html_127ce4a92ab677f696c3fcc0ed20181d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_07815dce341312c4ba096fda92df1bb8.setContent(html_127ce4a92ab677f696c3fcc0ed20181d);
#
#
#
#         marker_176a21c2bbf5a5e30264d957ca2becb6.bindPopup(popup_07815dce341312c4ba096fda92df1bb8)
#         ;
#
#
#
#
#             var marker_27847e1238a9a3f5dc9734a7ccc1a4cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ebceba4a726797622fc098e5cbddfbbc);
#
#
#         var popup_8963a3fa20df1261da6667f519230c2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b03901971d8e8fed9c0466aa6dfd3e41 = $(`&lt;div id=&quot;html_b03901971d8e8fed9c0466aa6dfd3e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8963a3fa20df1261da6667f519230c2f.setContent(html_b03901971d8e8fed9c0466aa6dfd3e41);
#
#
#
#         marker_27847e1238a9a3f5dc9734a7ccc1a4cd.bindPopup(popup_8963a3fa20df1261da6667f519230c2f)
#         ;
#
#
#
#
#             var marker_997fedbd714183d8fb95409e13c578d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ebceba4a726797622fc098e5cbddfbbc);
#
#
#         var popup_2a400b932a41243c82254ca9e4915ec4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c70944094df9711ee9153456863498f = $(`&lt;div id=&quot;html_0c70944094df9711ee9153456863498f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2a400b932a41243c82254ca9e4915ec4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9a2d6bbc855729d38dbc6f4e0bcb2e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9a2d6bbc855729d38dbc6f4e0bcb2e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9a2d6bbc855729d38dbc6f4e0bcb2e1 = L.map(
#                 &quot;map_d9a2d6bbc855729d38dbc6f4e0bcb2e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bced263e08e115f88fb1e0ac90792417 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bced263e08e115f88fb1e0ac90792417.addTo(map_d9a2d6bbc855729d38dbc6f4e0bcb2e1);
#
#
#             var feature_group_b91f35144258220b51f96e25624ed1bb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f38113c678eca8714d844614272aa91d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b91f35144258220b51f96e25624ed1bb);
#
#
#         var popup_22c0d861deffaeb9166c865c6ddcdc20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6026ad3fc197bc63f391b4dbae357695 = $(`&lt;div id=&quot;html_6026ad3fc197bc63f391b4dbae357695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_22c0d861deffaeb9166c865c6ddcdc20.setContent(html_6026ad3fc197bc63f391b4dbae357695);
#
#
#
#         marker_f38113c678eca8714d844614272aa91d.bindPopup(popup_22c0d861deffaeb9166c865c6ddcdc20)
#         ;
#
#
#
#
#             var marker_1f1db42dbf526bc5e5751d9604f1b26c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b91f35144258220b51f96e25624ed1bb);
#
#
#         var popup_11ca58baff4aec1860a9bed4a5c12b3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73bdefd6d96088d109ec1cc70e8e02dc = $(`&lt;div id=&quot;html_73bdefd6d96088d109ec1cc70e8e02dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_11ca58baff4aec1860a9bed4a5c12b3c.setContent(html_73bdefd6d96088d109ec1cc70e8e02dc);
#
#
#
#         marker_1f1db42dbf526bc5e5751d9604f1b26c.bindPopup(popup_11ca58baff4aec1860a9bed4a5c12b3c)
#         ;
#
#
#
#
#             var marker_f5186242f48ca082fc61e0a6686eaf46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b91f35144258220b51f96e25624ed1bb);
#
#
#         var popup_6576c698a6522c2dff41a9df495e1dbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a426f829c26fec08838adb1a116f817 = $(`&lt;div id=&quot;html_8a426f829c26fec08838adb1a116f817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6576c698a6522c2dff41a9df495e1dbf.setContent(html_8a426f829c26fec08838adb1a116f817);
#
#
#
#         marker_f5186242f48ca082fc61e0a6686eaf46.bindPopup(popup_6576c698a6522c2dff41a9df495e1dbf)
#         ;
#
#
#
#
#             var marker_da332fcaa199e68c5b286b67bb05739e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b91f35144258220b51f96e25624ed1bb);
#
#
#         var popup_ba8a9be1e2aab7b5826f646dfc734b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f69753414834a87708e0516cd360260 = $(`&lt;div id=&quot;html_0f69753414834a87708e0516cd360260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ba8a9be1e2aab7b5826f646dfc734b28.setContent(html_0f69753414834a87708e0516cd360260);
#
#
#
#         marker_da332fcaa199e68c5b286b67bb05739e.bindPopup(popup_ba8a9be1e2aab7b5826f646dfc734b28)
#         ;
#
#
#
#
#             var marker_5397399ee6092d44f090dc298e81438f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b91f35144258220b51f96e25624ed1bb);
#
#
#         var popup_fad43355ba3f09e77aeaae920200731b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4448a35086721bf60c1d704c36fe586 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4448a35086721bf60c1d704c36fe586&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4448a35086721bf60c1d704c36fe586 = L.map(
#                 &quot;map_e4448a35086721bf60c1d704c36fe586&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_016a79015205a64bc287a4500b48cf59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_016a79015205a64bc287a4500b48cf59.addTo(map_e4448a35086721bf60c1d704c36fe586);
#
#
#             var feature_group_6122c817b03ed0e4e38891d2fff7471a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6122c817b03ed0e4e38891d2fff7471a.addTo(map_e4448a35086721bf60c1d704c36fe586);
#
#
#             var feature_group_sub_group_1a5f2c2e8384fca113e0dabc8d6b7208 = L.featureGroup.subGroup(
#                 feature_group_6122c817b03ed0e4e38891d2fff7471a
#             );
#
#
#             var marker_324b27bae418a77662f16678cc316628 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a5f2c2e8384fca113e0dabc8d6b7208);
#
#
#         var popup_5b5f3be9a11d6a498939ef7713630c9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60f40daf1c10f2e3c7a686cd6414f6cb = $(`&lt;div id=&quot;html_60f40daf1c10f2e3c7a686cd6414f6cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5b5f3be9a11d6a498939ef7713630c9d.setContent(html_60f40daf1c10f2e3c7a686cd6414f6cb);
#
#
#
#         marker_324b27bae418a77662f16678cc316628.bindPopup(popup_5b5f3be9a11d6a498939ef7713630c9d)
#         ;
#
#
#
#
#             var marker_4d923b8ff9dd03f22284bc57630b5209 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a5f2c2e8384fca113e0dabc8d6b7208);
#
#
#         var popup_b20812a43b1480ecedc14040ef278604 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d7394d05486cf3f1b5d671de5d54ef1 = $(`&lt;div id=&quot;html_1d7394d05486cf3f1b5d671de5d54ef1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b20812a43b1480ecedc14040ef278604.setContent(html_1d7394d05486cf3f1b5d671de5d54ef1);
#
#
#
#         marker_4d923b8ff9dd03f22284bc57630b5209.bindPopup(popup_b20812a43b1480ecedc14040ef278604)
#         ;
#
#
#
#
#             var marker_585ee7ed4a390a48bdd0a0ea8d8acec1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a5f2c2e8384fca113e0dabc8d6b7208);
#
#
#         var popup_981029a9b5a822084f6faaf020f4e231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_067f8aa1904594fb972ba79cadf0dca4 = $(`&lt;div id=&quot;html_067f8aa1904594fb972ba79cadf0dca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_981029a9b5a822084f6faaf020f4e231.setContent(html_067f8aa1904594fb972ba79cadf0dca4);
#
#
#
#         marker_585ee7ed4a390a48bdd0a0ea8d8acec1.bindPopup(popup_981029a9b5a822084f6faaf020f4e231)
#         ;
#
#
#
#
#             var marker_4982de60f565e193f67612bc59400abc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a5f2c2e8384fca113e0dabc8d6b7208);
#
#
#         var popup_cef4b287a65b3ac1f934b2319803c399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a922e20ad265f6006597036f195420c9 = $(`&lt;div id=&quot;html_a922e20ad265f6006597036f195420c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cef4b287a65b3ac1f934b2319803c399.setContent(html_a922e20ad265f6006597036f195420c9);
#
#
#
#         marker_
