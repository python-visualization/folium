# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c46742819eccc8ff061ff13b24f3b368 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c46742819eccc8ff061ff13b24f3b368&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c46742819eccc8ff061ff13b24f3b368 = L.map(
#                 &quot;map_c46742819eccc8ff061ff13b24f3b368&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb77d0b361d2d1bd46aa670e66bd31df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb77d0b361d2d1bd46aa670e66bd31df.addTo(map_c46742819eccc8ff061ff13b24f3b368);
#
#
#             var marker_ed04520681182bd5dd611413046b4768 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c46742819eccc8ff061ff13b24f3b368);
#
#
#         var popup_0f8fd4ff9b52d65c963d20af6706bf46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5523ed24f0f905fcd304757870792707 = $(`&lt;div id=&quot;html_5523ed24f0f905fcd304757870792707&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0f8fd4ff9b52d65c963d20af6706bf46.setContent(html_5523ed24f0f905fcd304757870792707);
#
#
#
#         marker_ed04520681182bd5dd611413046b4768.bindPopup(popup_0f8fd4ff9b52d65c963d20af6706bf46)
#         ;
#
#
#
#
#             var marker_f6197b03b6ba35c85824e7c99811834e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c46742819eccc8ff061ff13b24f3b368);
#
#
#         var popup_0a98f940fd746b8a30d08651077e69f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fad571ed9d6e5586c373e2f1b69afd7 = $(`&lt;div id=&quot;html_2fad571ed9d6e5586c373e2f1b69afd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0a98f940fd746b8a30d08651077e69f7.setContent(html_2fad571ed9d6e5586c373e2f1b69afd7);
#
#
#
#         marker_f6197b03b6ba35c85824e7c99811834e.bindPopup(popup_0a98f940fd746b8a30d08651077e69f7)
#         ;
#
#
#
#
#             var marker_666624b1d344bc0bc84083c14cea3073 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c46742819eccc8ff061ff13b24f3b368);
#
#
#         var popup_641308de5d07d031547560d65aaf66ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b903bf0448b69ec6f210e40a54754900 = $(`&lt;div id=&quot;html_b903bf0448b69ec6f210e40a54754900&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_641308de5d07d031547560d65aaf66ba.setContent(html_b903bf0448b69ec6f210e40a54754900);
#
#
#
#         marker_666624b1d344bc0bc84083c14cea3073.bindPopup(popup_641308de5d07d031547560d65aaf66ba)
#         ;
#
#
#
#
#             var marker_6e9266ab73b792413200a3d8be6189dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c46742819eccc8ff061ff13b24f3b368);
#
#
#         var popup_b6af0716a043f9f3605a7ebc95377273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58b93c83b8c3a8011b4071c213662467 = $(`&lt;div id=&quot;html_58b93c83b8c3a8011b4071c213662467&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b6af0716a043f9f3605a7ebc95377273.setContent(html_58b93c83b8c3a8011b4071c213662467);
#
#
#
#         marker_6e9266ab73b792413200a3d8be6189dc.bindPopup(popup_b6af0716a043f9f3605a7ebc95377273)
#         ;
#
#
#
#
#             var marker_9b1fee9306d75aa31f40d301f10bd0a7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c46742819eccc8ff061ff13b24f3b368);
#
#
#         var popup_62130d3afc2b4e2b641129cb03aa1805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54942c5d4279673c1b813c736aa5e7f0 = $(`&lt;div id=&quot;html_54942c5d4279673c1b813c736aa5e7f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_62130d3afc2b4e2b641129cb03aa1805.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0b06558ba6a96830c77fa846b3483d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0b06558ba6a96830c77fa846b3483d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0b06558ba6a96830c77fa846b3483d5 = L.map(
#                 &quot;map_d0b06558ba6a96830c77fa846b3483d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56129e5e29f36684d2a3d44389eadac9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56129e5e29f36684d2a3d44389eadac9.addTo(map_d0b06558ba6a96830c77fa846b3483d5);
#
#
#             var feature_group_914bd2af4a33df110dad020bfa4a4af7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c8a0c63299b2526c5a7d6ca3e5a0c2dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_914bd2af4a33df110dad020bfa4a4af7);
#
#
#         var popup_59289d183d86e49c25fb26acd8288fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_782586cbe184251831145d9f774f2000 = $(`&lt;div id=&quot;html_782586cbe184251831145d9f774f2000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_59289d183d86e49c25fb26acd8288fcf.setContent(html_782586cbe184251831145d9f774f2000);
#
#
#
#         marker_c8a0c63299b2526c5a7d6ca3e5a0c2dd.bindPopup(popup_59289d183d86e49c25fb26acd8288fcf)
#         ;
#
#
#
#
#             var marker_bf98c67c0e08672118069ab5cd801955 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_914bd2af4a33df110dad020bfa4a4af7);
#
#
#         var popup_377e0b99c65ecb0c97c6ca2399c70011 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce4e06946a5bf1b73aadc61fea968366 = $(`&lt;div id=&quot;html_ce4e06946a5bf1b73aadc61fea968366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_377e0b99c65ecb0c97c6ca2399c70011.setContent(html_ce4e06946a5bf1b73aadc61fea968366);
#
#
#
#         marker_bf98c67c0e08672118069ab5cd801955.bindPopup(popup_377e0b99c65ecb0c97c6ca2399c70011)
#         ;
#
#
#
#
#             var marker_2abe9f75cb3f1f1c082ebdcd251b8e34 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_914bd2af4a33df110dad020bfa4a4af7);
#
#
#         var popup_184e7deebba2eea6de5d943dd5afba50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe8325ea14a218e3aca449d883c9752d = $(`&lt;div id=&quot;html_fe8325ea14a218e3aca449d883c9752d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_184e7deebba2eea6de5d943dd5afba50.setContent(html_fe8325ea14a218e3aca449d883c9752d);
#
#
#
#         marker_2abe9f75cb3f1f1c082ebdcd251b8e34.bindPopup(popup_184e7deebba2eea6de5d943dd5afba50)
#         ;
#
#
#
#
#             var marker_54f65d47a505f95d9d3075702d20648d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_914bd2af4a33df110dad020bfa4a4af7);
#
#
#         var popup_af577e56c86cd48e38fb1c7e38e02a9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03141d0666e606c8e40a75fc4a908e91 = $(`&lt;div id=&quot;html_03141d0666e606c8e40a75fc4a908e91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_af577e56c86cd48e38fb1c7e38e02a9c.setContent(html_03141d0666e606c8e40a75fc4a908e91);
#
#
#
#         marker_54f65d47a505f95d9d3075702d20648d.bindPopup(popup_af577e56c86cd48e38fb1c7e38e02a9c)
#         ;
#
#
#
#
#             var marker_406248da6501b3e0f36c45de433bf570 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_914bd2af4a33df110dad020bfa4a4af7);
#
#
#         var popup_46cc55f19fce8690c733e07103ef1e49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dba21d8c3165f3bb2a78ea225cb8db3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dba21d8c3165f3bb2a78ea225cb8db3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dba21d8c3165f3bb2a78ea225cb8db3 = L.map(
#                 &quot;map_4dba21d8c3165f3bb2a78ea225cb8db3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a9f8f4387a618b0e2ef254fcaad9c13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a9f8f4387a618b0e2ef254fcaad9c13.addTo(map_4dba21d8c3165f3bb2a78ea225cb8db3);
#
#
#             var feature_group_575992c7c64706eb343a469f8d25c01a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_575992c7c64706eb343a469f8d25c01a.addTo(map_4dba21d8c3165f3bb2a78ea225cb8db3);
#
#
#             var feature_group_sub_group_5901c8aea1cb5f2e5914d4d80d028aa2 = L.featureGroup.subGroup(
#                 feature_group_575992c7c64706eb343a469f8d25c01a
#             );
#
#
#             var marker_38f77e702e731bae3bcf8937b5eedc71 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5901c8aea1cb5f2e5914d4d80d028aa2);
#
#
#         var popup_282050cce4a0f6ea57565f6fc4c65560 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_583e24c82ebdef3c0085396b469ad526 = $(`&lt;div id=&quot;html_583e24c82ebdef3c0085396b469ad526&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_282050cce4a0f6ea57565f6fc4c65560.setContent(html_583e24c82ebdef3c0085396b469ad526);
#
#
#
#         marker_38f77e702e731bae3bcf8937b5eedc71.bindPopup(popup_282050cce4a0f6ea57565f6fc4c65560)
#         ;
#
#
#
#
#             var marker_30525db6ae4dcce9b5eb08a856654630 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5901c8aea1cb5f2e5914d4d80d028aa2);
#
#
#         var popup_e8a0776374d6ff858544dfa0e3a8d885 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa80b51fd04f22fe9bca9fd708f5d4a4 = $(`&lt;div id=&quot;html_fa80b51fd04f22fe9bca9fd708f5d4a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e8a0776374d6ff858544dfa0e3a8d885.setContent(html_fa80b51fd04f22fe9bca9fd708f5d4a4);
#
#
#
#         marker_30525db6ae4dcce9b5eb08a856654630.bindPopup(popup_e8a0776374d6ff858544dfa0e3a8d885)
#         ;
#
#
#
#
#             var marker_70498d22a12e325aed2628d199aec0dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5901c8aea1cb5f2e5914d4d80d028aa2);
#
#
#         var popup_1bb465a1e2534960d49c89559ac7c3c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a50e1bb260d61ad7945de76639eae40 = $(`&lt;div id=&quot;html_6a50e1bb260d61ad7945de76639eae40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1bb465a1e2534960d49c89559ac7c3c1.setContent(html_6a50e1bb260d61ad7945de76639eae40);
#
#
#
#         marker_70498d22a12e325aed2628d199aec0dc.bindPopup(popup_1bb465a1e2534960d49c89559ac7c3c1)
#         ;
#
#
#
#
#             var marker_d0c8c01af496f89e4178ee0da3ca581e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5901c8aea1cb5f2e5914d4d80d028aa2);
#
#
#         var popup_ecf96bfcee1b738241a82e90acd35e34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03d11e1f860db9b9aa8fcf0abad767bb = $(`&lt;div id=&quot;html_03d11e1f860db9b9aa8fcf0abad767bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ecf96bfcee1b738241a82e90acd35e34.setContent(html_03d11e1f860db9b9aa8fcf0abad767bb);
#
#
#
#         marker_
