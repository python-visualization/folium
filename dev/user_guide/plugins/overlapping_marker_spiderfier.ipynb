# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d6c63133c12960f71e597e18d9737a2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d6c63133c12960f71e597e18d9737a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d6c63133c12960f71e597e18d9737a2 = L.map(
#                 &quot;map_3d6c63133c12960f71e597e18d9737a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e7ee365c5ba8606fbb40d3f2b633ed0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e7ee365c5ba8606fbb40d3f2b633ed0.addTo(map_3d6c63133c12960f71e597e18d9737a2);
#
#
#             var marker_fc2b297ffafaa1126632993355c309d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d6c63133c12960f71e597e18d9737a2);
#
#
#         var popup_a31cbc07ae64f0c68030f8a24ab48cbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d2b3a5d21af9f05c43ce8a4c82c025c = $(`&lt;div id=&quot;html_6d2b3a5d21af9f05c43ce8a4c82c025c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a31cbc07ae64f0c68030f8a24ab48cbb.setContent(html_6d2b3a5d21af9f05c43ce8a4c82c025c);
#
#
#
#         marker_fc2b297ffafaa1126632993355c309d7.bindPopup(popup_a31cbc07ae64f0c68030f8a24ab48cbb)
#         ;
#
#
#
#
#             var marker_d1e4bd9ddcd4239928a9a81d142fc4f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d6c63133c12960f71e597e18d9737a2);
#
#
#         var popup_5fe10c52551277a6cbb128b6589235cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fa1464e0bedb00838cfd76a61ec5319 = $(`&lt;div id=&quot;html_7fa1464e0bedb00838cfd76a61ec5319&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5fe10c52551277a6cbb128b6589235cd.setContent(html_7fa1464e0bedb00838cfd76a61ec5319);
#
#
#
#         marker_d1e4bd9ddcd4239928a9a81d142fc4f7.bindPopup(popup_5fe10c52551277a6cbb128b6589235cd)
#         ;
#
#
#
#
#             var marker_b02053266d2d980705721b8f2acc1558 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d6c63133c12960f71e597e18d9737a2);
#
#
#         var popup_96672ae94ed9f571f808cb55af240e27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1802ed3dd18aac83098b6602027ea3d3 = $(`&lt;div id=&quot;html_1802ed3dd18aac83098b6602027ea3d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_96672ae94ed9f571f808cb55af240e27.setContent(html_1802ed3dd18aac83098b6602027ea3d3);
#
#
#
#         marker_b02053266d2d980705721b8f2acc1558.bindPopup(popup_96672ae94ed9f571f808cb55af240e27)
#         ;
#
#
#
#
#             var marker_d061bbd138e577ec261412b7a97a78be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d6c63133c12960f71e597e18d9737a2);
#
#
#         var popup_a4a7b0afedf7acd08f72e0942fd6ab0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c0cbf8317b124af5d04f70eb98c6cdd = $(`&lt;div id=&quot;html_7c0cbf8317b124af5d04f70eb98c6cdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a4a7b0afedf7acd08f72e0942fd6ab0f.setContent(html_7c0cbf8317b124af5d04f70eb98c6cdd);
#
#
#
#         marker_d061bbd138e577ec261412b7a97a78be.bindPopup(popup_a4a7b0afedf7acd08f72e0942fd6ab0f)
#         ;
#
#
#
#
#             var marker_25b494a93c5c6e14c70dc657827bd22d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d6c63133c12960f71e597e18d9737a2);
#
#
#         var popup_3abb2c11d8a7b2a9c71b8420476c44f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9775fe9977b7acf988606b4460049829 = $(`&lt;div id=&quot;html_9775fe9977b7acf988606b4460049829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3abb2c11d8a7b2a9c71b8420476c44

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe6d24b19e4afda58dfc1ce7660ebd1a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe6d24b19e4afda58dfc1ce7660ebd1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe6d24b19e4afda58dfc1ce7660ebd1a = L.map(
#                 &quot;map_fe6d24b19e4afda58dfc1ce7660ebd1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c332e12530dec92a8cf07e8b52ea9a9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c332e12530dec92a8cf07e8b52ea9a9c.addTo(map_fe6d24b19e4afda58dfc1ce7660ebd1a);
#
#
#             var feature_group_eb3629124e09ed0642d6be1ed144f698 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_48fe2d113c8c3726ff1bab683d1a3361 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eb3629124e09ed0642d6be1ed144f698);
#
#
#         var popup_c08a9157d5db80a8f0ccdfdeb27e5ffc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6665916bb00da3bd778af24cd7ba8db = $(`&lt;div id=&quot;html_c6665916bb00da3bd778af24cd7ba8db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c08a9157d5db80a8f0ccdfdeb27e5ffc.setContent(html_c6665916bb00da3bd778af24cd7ba8db);
#
#
#
#         marker_48fe2d113c8c3726ff1bab683d1a3361.bindPopup(popup_c08a9157d5db80a8f0ccdfdeb27e5ffc)
#         ;
#
#
#
#
#             var marker_20c668bece91c3f8390c4559c6475aa4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eb3629124e09ed0642d6be1ed144f698);
#
#
#         var popup_432253a7956892436029a3e1d2940833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf7b839d8795c2820b0f1dcd31ae82b3 = $(`&lt;div id=&quot;html_cf7b839d8795c2820b0f1dcd31ae82b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_432253a7956892436029a3e1d2940833.setContent(html_cf7b839d8795c2820b0f1dcd31ae82b3);
#
#
#
#         marker_20c668bece91c3f8390c4559c6475aa4.bindPopup(popup_432253a7956892436029a3e1d2940833)
#         ;
#
#
#
#
#             var marker_37a8989690d7255f88f442735d2f556a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eb3629124e09ed0642d6be1ed144f698);
#
#
#         var popup_cdadac2fe896df046df9f5ee00455995 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9887efcf47a1fc9b6e5c1e42c18d5aac = $(`&lt;div id=&quot;html_9887efcf47a1fc9b6e5c1e42c18d5aac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cdadac2fe896df046df9f5ee00455995.setContent(html_9887efcf47a1fc9b6e5c1e42c18d5aac);
#
#
#
#         marker_37a8989690d7255f88f442735d2f556a.bindPopup(popup_cdadac2fe896df046df9f5ee00455995)
#         ;
#
#
#
#
#             var marker_3c58f0363023762e963627f0dcac8e26 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eb3629124e09ed0642d6be1ed144f698);
#
#
#         var popup_0f926638ab9191db4ccbcb5fe30719f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5b8371ab4f4d824a458701f55b72c8d = $(`&lt;div id=&quot;html_e5b8371ab4f4d824a458701f55b72c8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0f926638ab9191db4ccbcb5fe30719f9.setContent(html_e5b8371ab4f4d824a458701f55b72c8d);
#
#
#
#         marker_3c58f0363023762e963627f0dcac8e26.bindPopup(popup_0f926638ab9191db4ccbcb5fe30719f9)
#         ;
#
#
#
#
#             var marker_5dbbd85f0ac50272bea04ab1a2152066 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eb3629124e09ed0642d6be1ed144f698);
#
#
#         var popup_5976e9dbd68af2e9a5414b43d247f2b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5147a10e1124aff0ac3c285ba5a9bf67 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5147a10e1124aff0ac3c285ba5a9bf67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5147a10e1124aff0ac3c285ba5a9bf67 = L.map(
#                 &quot;map_5147a10e1124aff0ac3c285ba5a9bf67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_169f2da206b1e8cc60a4e1263981a74c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_169f2da206b1e8cc60a4e1263981a74c.addTo(map_5147a10e1124aff0ac3c285ba5a9bf67);
#
#
#             var feature_group_75c3eeed19190d9a560e1f93867cde96 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_75c3eeed19190d9a560e1f93867cde96.addTo(map_5147a10e1124aff0ac3c285ba5a9bf67);
#
#
#             var feature_group_sub_group_93ed36b2d9eb4b22c0f75de1b9eefca1 = L.featureGroup.subGroup(
#                 feature_group_75c3eeed19190d9a560e1f93867cde96
#             );
#
#
#             var marker_d13e05a9248be25dee79df294b38c009 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ed36b2d9eb4b22c0f75de1b9eefca1);
#
#
#         var popup_31b955fc1b25dd2dc42c4c413d8c1174 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e1997bed02fdb4af1e740de2c5599bc = $(`&lt;div id=&quot;html_7e1997bed02fdb4af1e740de2c5599bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_31b955fc1b25dd2dc42c4c413d8c1174.setContent(html_7e1997bed02fdb4af1e740de2c5599bc);
#
#
#
#         marker_d13e05a9248be25dee79df294b38c009.bindPopup(popup_31b955fc1b25dd2dc42c4c413d8c1174)
#         ;
#
#
#
#
#             var marker_4fc8bf7693fa62d40c5ad3f44dd8ba14 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ed36b2d9eb4b22c0f75de1b9eefca1);
#
#
#         var popup_af47857c6ea556011018f22c8487290b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3818a1ab3449177debcc506b5a27b97 = $(`&lt;div id=&quot;html_e3818a1ab3449177debcc506b5a27b97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_af47857c6ea556011018f22c8487290b.setContent(html_e3818a1ab3449177debcc506b5a27b97);
#
#
#
#         marker_4fc8bf7693fa62d40c5ad3f44dd8ba14.bindPopup(popup_af47857c6ea556011018f22c8487290b)
#         ;
#
#
#
#
#             var marker_d4331fd30f87fb916b5bfa10a1a57875 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ed36b2d9eb4b22c0f75de1b9eefca1);
#
#
#         var popup_1a3ca4bedf79cb58d78d77e9032d3ac6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59538189b459e5f409e36294b094c7d9 = $(`&lt;div id=&quot;html_59538189b459e5f409e36294b094c7d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1a3ca4bedf79cb58d78d77e9032d3ac6.setContent(html_59538189b459e5f409e36294b094c7d9);
#
#
#
#         marker_d4331fd30f87fb916b5bfa10a1a57875.bindPopup(popup_1a3ca4bedf79cb58d78d77e9032d3ac6)
#         ;
#
#
#
#
#             var marker_1d7f08e6b1c402072ecbda371fbcd44d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_93ed36b2d9eb4b22c0f75de1b9eefca1);
#
#
#         var popup_e68e22a7b088aa7472be0dca169a4af5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f80d4992932b242e55eb28ca7358a73c = $(`&lt;div id=&quot;html_f80d4992932b242e55eb28ca7358a73c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e68e22a7b088aa7472be0dca169a4af5.setContent(html_f80d4992932b242e55eb28ca7358a73c);
#
#
#
#         mark
