# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7d46ef0368bdcf44392dc3e89ffa97e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7d46ef0368bdcf44392dc3e89ffa97e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7d46ef0368bdcf44392dc3e89ffa97e = L.map(
#                 &quot;map_d7d46ef0368bdcf44392dc3e89ffa97e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80b66a6dfd4d022d9dfedceef8334952 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80b66a6dfd4d022d9dfedceef8334952.addTo(map_d7d46ef0368bdcf44392dc3e89ffa97e);
#
#
#             var marker_bb87e3f3253566c4bf78cd8a2f62aba6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d7d46ef0368bdcf44392dc3e89ffa97e);
#
#
#         var popup_91911274e1e4777f0a7fb1ee429a8fe6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2bffc4c5f200f68f8cdf8dbde37c27f = $(`&lt;div id=&quot;html_c2bffc4c5f200f68f8cdf8dbde37c27f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_91911274e1e4777f0a7fb1ee429a8fe6.setContent(html_c2bffc4c5f200f68f8cdf8dbde37c27f);
#
#
#
#         marker_bb87e3f3253566c4bf78cd8a2f62aba6.bindPopup(popup_91911274e1e4777f0a7fb1ee429a8fe6)
#         ;
#
#
#
#
#             var marker_00c30dd574202be9e616e54fa04318ef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d7d46ef0368bdcf44392dc3e89ffa97e);
#
#
#         var popup_835b825bd3013bcc11da5cfc8a10d42b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e55a5b9d1dcc5d810556a7e761ed0633 = $(`&lt;div id=&quot;html_e55a5b9d1dcc5d810556a7e761ed0633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_835b825bd3013bcc11da5cfc8a10d42b.setContent(html_e55a5b9d1dcc5d810556a7e761ed0633);
#
#
#
#         marker_00c30dd574202be9e616e54fa04318ef.bindPopup(popup_835b825bd3013bcc11da5cfc8a10d42b)
#         ;
#
#
#
#
#             var marker_fef330a2a8dbe38a92750d6aa5332637 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d7d46ef0368bdcf44392dc3e89ffa97e);
#
#
#         var popup_d3c08b2dfc6c01b3c842efa9d506f42a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5b754e9f12c687361ae31bfa124655f = $(`&lt;div id=&quot;html_b5b754e9f12c687361ae31bfa124655f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d3c08b2dfc6c01b3c842efa9d506f42a.setContent(html_b5b754e9f12c687361ae31bfa124655f);
#
#
#
#         marker_fef330a2a8dbe38a92750d6aa5332637.bindPopup(popup_d3c08b2dfc6c01b3c842efa9d506f42a)
#         ;
#
#
#
#
#             var marker_bd857f185ddf8a3ca8c8ca2f18ad8797 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d7d46ef0368bdcf44392dc3e89ffa97e);
#
#
#         var popup_80167b5ebd437377daba4c4686eb231b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c6870437b977f52cc6696de17db9323 = $(`&lt;div id=&quot;html_8c6870437b977f52cc6696de17db9323&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_80167b5ebd437377daba4c4686eb231b.setContent(html_8c6870437b977f52cc6696de17db9323);
#
#
#
#         marker_bd857f185ddf8a3ca8c8ca2f18ad8797.bindPopup(popup_80167b5ebd437377daba4c4686eb231b)
#         ;
#
#
#
#
#             var marker_98436cba1840c8ecf9e1175a0a22f374 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d7d46ef0368bdcf44392dc3e89ffa97e);
#
#
#         var popup_8bb1860f3e6007a6d3374870fca24c25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba866146d27d26d0684da93f0fca5fd9 = $(`&lt;div id=&quot;html_ba866146d27d26d0684da93f0fca5fd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8bb1860f3e6007a6d3374870fca24c25.setContent(html_ba866146d27d26d0684da93f0fca5fd9);
#
#
#
#         marker_98436cba1840c8ecf9e1175a0a22f374.bindPopup(popup_8bb1860f3e6007a6d3374870fca24c25)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_590e133fe24fa3dfe8f8b6bab3d0a30a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_590e133fe24fa3dfe8f8b6bab3d0a30a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_590e133fe24fa3dfe8f8b6bab3d0a30a = L.map(
#                 &quot;map_590e133fe24fa3dfe8f8b6bab3d0a30a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c27776f7f0d2ab9696ff5ed2c2b60aec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c27776f7f0d2ab9696ff5ed2c2b60aec.addTo(map_590e133fe24fa3dfe8f8b6bab3d0a30a);
#
#
#             var feature_group_a47febfe85502f87773b204ca95be287 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_62cd42f8c6d6a301a5ced060b0e9dedb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a47febfe85502f87773b204ca95be287);
#
#
#         var popup_b269ac79bb2c39e29e6a72b1cde74b67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38579cd0e23436fdc635c378b098b511 = $(`&lt;div id=&quot;html_38579cd0e23436fdc635c378b098b511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b269ac79bb2c39e29e6a72b1cde74b67.setContent(html_38579cd0e23436fdc635c378b098b511);
#
#
#
#         marker_62cd42f8c6d6a301a5ced060b0e9dedb.bindPopup(popup_b269ac79bb2c39e29e6a72b1cde74b67)
#         ;
#
#
#
#
#             var marker_eab8d6031644db423794540cbccd0adb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a47febfe85502f87773b204ca95be287);
#
#
#         var popup_8538a6711c7d68eebe6ab2a3ed22eacf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bb64f801c0bf78842de7dfb3540da02 = $(`&lt;div id=&quot;html_3bb64f801c0bf78842de7dfb3540da02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8538a6711c7d68eebe6ab2a3ed22eacf.setContent(html_3bb64f801c0bf78842de7dfb3540da02);
#
#
#
#         marker_eab8d6031644db423794540cbccd0adb.bindPopup(popup_8538a6711c7d68eebe6ab2a3ed22eacf)
#         ;
#
#
#
#
#             var marker_75bd04a68811850f49d59cbccd3fa174 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a47febfe85502f87773b204ca95be287);
#
#
#         var popup_14d4592d4b26aa5fdac9808c912a0b9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bc442288e7d355daafca5397b3686f7 = $(`&lt;div id=&quot;html_7bc442288e7d355daafca5397b3686f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_14d4592d4b26aa5fdac9808c912a0b9e.setContent(html_7bc442288e7d355daafca5397b3686f7);
#
#
#
#         marker_75bd04a68811850f49d59cbccd3fa174.bindPopup(popup_14d4592d4b26aa5fdac9808c912a0b9e)
#         ;
#
#
#
#
#             var marker_d10b0ec809e4ad427280b291b30e0d1a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a47febfe85502f87773b204ca95be287);
#
#
#         var popup_da01fafff7554e76ab625d3638f62825 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e603b100824e8f7b5f33a6777ceba4c3 = $(`&lt;div id=&quot;html_e603b100824e8f7b5f33a6777ceba4c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_da01fafff7554e76ab625d3638f62825.setContent(html_e603b100824e8f7b5f33a6777ceba4c3);
#
#
#
#         marker_d10b0ec809e4ad427280b291b30e0d1a.bindPopup(popup_da01fafff7554e76ab625d3638f62825)
#         ;
#
#
#
#
#             var marker_b0725816aa04bcfccd9df30b7231d59d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a47febfe85502f87773b204ca95be287);
#
#
#         var popup_de5f4cd88fe1ec7123276e8c6041213f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c611cd1a4b76699bdb9a696d59c5b5e3 = $(`&lt;div id=&quot;html_c611cd1a4b76699bdb9a696d59c5b5e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84abe605a4018623bf3cdecaf528d09f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84abe605a4018623bf3cdecaf528d09f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84abe605a4018623bf3cdecaf528d09f = L.map(
#                 &quot;map_84abe605a4018623bf3cdecaf528d09f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47e3f105ed8731f0cc4a590eb05ebe63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_47e3f105ed8731f0cc4a590eb05ebe63.addTo(map_84abe605a4018623bf3cdecaf528d09f);
#
#
#             var feature_group_2b79ddfabcd3a0b272272b58f31e2769 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2b79ddfabcd3a0b272272b58f31e2769.addTo(map_84abe605a4018623bf3cdecaf528d09f);
#
#
#             var feature_group_sub_group_d4bf864b32714cd1316ee8a509ed9ed8 = L.featureGroup.subGroup(
#                 feature_group_2b79ddfabcd3a0b272272b58f31e2769
#             );
#
#
#             var marker_092dda1c6bc2a1c1cce2287fca8312dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4bf864b32714cd1316ee8a509ed9ed8);
#
#
#         var popup_18ef7079649080d3fa221db9a4464d30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cd71c65dd1181fb5ca8789f20b1cbd1 = $(`&lt;div id=&quot;html_4cd71c65dd1181fb5ca8789f20b1cbd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_18ef7079649080d3fa221db9a4464d30.setContent(html_4cd71c65dd1181fb5ca8789f20b1cbd1);
#
#
#
#         marker_092dda1c6bc2a1c1cce2287fca8312dd.bindPopup(popup_18ef7079649080d3fa221db9a4464d30)
#         ;
#
#
#
#
#             var marker_d0bf3336c94f58516dc82c168312f3ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4bf864b32714cd1316ee8a509ed9ed8);
#
#
#         var popup_7fad629cc59c5c66fa970393a16e73ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eb615ef7d8554d274a0c0757bd46672 = $(`&lt;div id=&quot;html_2eb615ef7d8554d274a0c0757bd46672&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7fad629cc59c5c66fa970393a16e73ef.setContent(html_2eb615ef7d8554d274a0c0757bd46672);
#
#
#
#         marker_d0bf3336c94f58516dc82c168312f3ab.bindPopup(popup_7fad629cc59c5c66fa970393a16e73ef)
#         ;
#
#
#
#
#             var marker_8620fdf65b1b3e94b391e4f1f02c1bc9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4bf864b32714cd1316ee8a509ed9ed8);
#
#
#         var popup_14560bf3e0b6af11aeca1f135614b1df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4512f1536f4073fa5554169bf120aebe = $(`&lt;div id=&quot;html_4512f1536f4073fa5554169bf120aebe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14560bf3e0b6af11aeca1f135614b1df.setContent(html_4512f1536f4073fa5554169bf120aebe);
#
#
#
#         marker_8620fdf65b1b3e94b391e4f1f02c1bc9.bindPopup(popup_14560bf3e0b6af11aeca1f135614b1df)
#         ;
#
#
#
#
#             var marker_8f2d20453db15b073eb3788ebb7e60e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4bf864b32714cd1316ee8a509ed9ed8);
#
#
#         var popup_e7f9867c1a075b84cecc7dc57471dae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_480a3ae7a358dcd15868ff7b73baa70f = $(`&lt;div id=&quot;html_480a3ae7a358dcd15868ff7b73baa70f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e7f9867c1a075b84cecc7dc57471dae7.setContent(html_480a3ae7a358dcd15868ff7b73baa70f);
#
#
#
#         marker_8f2d20453db15b073eb3788ebb7e60e5.bindPopup(popup_e7f9867c1a075b84cecc7dc57471dae7)
#         ;
#
#
#
#
#             var marker_c936d6d01f37c25fb06d65a0e4db0443 = L.marker(
#                 [45.0503999
