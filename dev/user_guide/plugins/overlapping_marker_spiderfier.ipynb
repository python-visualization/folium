# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b665c55e6631530344f1721bda8425a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b665c55e6631530344f1721bda8425a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b665c55e6631530344f1721bda8425a = L.map(
#                 &quot;map_7b665c55e6631530344f1721bda8425a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c5baadd4e89f2fd6150f4f6a0c44d2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c5baadd4e89f2fd6150f4f6a0c44d2b.addTo(map_7b665c55e6631530344f1721bda8425a);
#
#
#             var marker_bdd8ed54a52945de4dc69e723c3c7b4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7b665c55e6631530344f1721bda8425a);
#
#
#         var popup_ed244cd508fe2b0c18553c2291ffc7a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fa75dc52a2577cf5fc6f3f528ba3dfe = $(`&lt;div id=&quot;html_6fa75dc52a2577cf5fc6f3f528ba3dfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ed244cd508fe2b0c18553c2291ffc7a7.setContent(html_6fa75dc52a2577cf5fc6f3f528ba3dfe);
#
#
#
#         marker_bdd8ed54a52945de4dc69e723c3c7b4d.bindPopup(popup_ed244cd508fe2b0c18553c2291ffc7a7)
#         ;
#
#
#
#
#             var marker_b1e89abae65e7b2243ac5bcaa5ea6385 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7b665c55e6631530344f1721bda8425a);
#
#
#         var popup_f3f40e3347645942d4d33866723f3730 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c68d07178128316b23a4f23a4bd8debf = $(`&lt;div id=&quot;html_c68d07178128316b23a4f23a4bd8debf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f3f40e3347645942d4d33866723f3730.setContent(html_c68d07178128316b23a4f23a4bd8debf);
#
#
#
#         marker_b1e89abae65e7b2243ac5bcaa5ea6385.bindPopup(popup_f3f40e3347645942d4d33866723f3730)
#         ;
#
#
#
#
#             var marker_b1c4cc33a4690af6ec39586909a8919a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7b665c55e6631530344f1721bda8425a);
#
#
#         var popup_6434daea9c2aa6ea062a3d6974dedfbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02b89ca6834c3e8d79fae9b1a02093dc = $(`&lt;div id=&quot;html_02b89ca6834c3e8d79fae9b1a02093dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6434daea9c2aa6ea062a3d6974dedfbe.setContent(html_02b89ca6834c3e8d79fae9b1a02093dc);
#
#
#
#         marker_b1c4cc33a4690af6ec39586909a8919a.bindPopup(popup_6434daea9c2aa6ea062a3d6974dedfbe)
#         ;
#
#
#
#
#             var marker_465deba0aa1f4009a9df72e124fb42d0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7b665c55e6631530344f1721bda8425a);
#
#
#         var popup_c45e5e83e333fbb6833b53ca8cb1caaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24556608165a987fb38f1924abedaaa5 = $(`&lt;div id=&quot;html_24556608165a987fb38f1924abedaaa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c45e5e83e333fbb6833b53ca8cb1caaf.setContent(html_24556608165a987fb38f1924abedaaa5);
#
#
#
#         marker_465deba0aa1f4009a9df72e124fb42d0.bindPopup(popup_c45e5e83e333fbb6833b53ca8cb1caaf)
#         ;
#
#
#
#
#             var marker_22a70ebca3080955df525bacb425a646 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7b665c55e6631530344f1721bda8425a);
#
#
#         var popup_be4d716ee869b74c48b05c6b5151330c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_032de191ebd4b404d8c4ad95ef008340 = $(`&lt;div id=&quot;html_032de191ebd4b404d8c4ad95ef008340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_be4d716ee869b74c48b05c6b5151330c.setContent(html_032de191ebd4b404d8c4ad95ef008340);
#
#
#
#         marker_22a70ebca3080955df525bacb425a646.bindPopup(popup_be4d716ee869b74c48b05c6b5151330c)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_367e04580f79741316ddfffa53b0983b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_367e04580f79741316ddfffa53b0983b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_367e04580f79741316ddfffa53b0983b = L.map(
#                 &quot;map_367e04580f79741316ddfffa53b0983b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e77c8e5a68e17cfb0722f755bef1bb5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e77c8e5a68e17cfb0722f755bef1bb5.addTo(map_367e04580f79741316ddfffa53b0983b);
#
#
#             var feature_group_8afc6ad6b455a25dbbc1b6b954277697 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5c9b4f196b11e85d9cc5ffa7e461bdca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8afc6ad6b455a25dbbc1b6b954277697);
#
#
#         var popup_c05ef0479cb8510cc44da64681924cbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e27d311ae0ba2fd511e6037979db87cc = $(`&lt;div id=&quot;html_e27d311ae0ba2fd511e6037979db87cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c05ef0479cb8510cc44da64681924cbd.setContent(html_e27d311ae0ba2fd511e6037979db87cc);
#
#
#
#         marker_5c9b4f196b11e85d9cc5ffa7e461bdca.bindPopup(popup_c05ef0479cb8510cc44da64681924cbd)
#         ;
#
#
#
#
#             var marker_f5120c325d0a28bbf064a752debb9576 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8afc6ad6b455a25dbbc1b6b954277697);
#
#
#         var popup_d4e64f300f223f287bd0dae410a24fa2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fb9fde7b3100e82781cab203d4f8fc4 = $(`&lt;div id=&quot;html_6fb9fde7b3100e82781cab203d4f8fc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d4e64f300f223f287bd0dae410a24fa2.setContent(html_6fb9fde7b3100e82781cab203d4f8fc4);
#
#
#
#         marker_f5120c325d0a28bbf064a752debb9576.bindPopup(popup_d4e64f300f223f287bd0dae410a24fa2)
#         ;
#
#
#
#
#             var marker_b6eb048b663885ae5a29f34c5f15e409 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8afc6ad6b455a25dbbc1b6b954277697);
#
#
#         var popup_7d3ae93dc06ed68e53dddb437e206e62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06fcaa54beabf76d4630cea353dbd87b = $(`&lt;div id=&quot;html_06fcaa54beabf76d4630cea353dbd87b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7d3ae93dc06ed68e53dddb437e206e62.setContent(html_06fcaa54beabf76d4630cea353dbd87b);
#
#
#
#         marker_b6eb048b663885ae5a29f34c5f15e409.bindPopup(popup_7d3ae93dc06ed68e53dddb437e206e62)
#         ;
#
#
#
#
#             var marker_b887f765e42df2668313853d4858527a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8afc6ad6b455a25dbbc1b6b954277697);
#
#
#         var popup_c685da54f038898ec4570c7f6ae19306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b41783a02ce942353197b438cc1f0cf = $(`&lt;div id=&quot;html_9b41783a02ce942353197b438cc1f0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c685da54f038898ec4570c7f6ae19306.setContent(html_9b41783a02ce942353197b438cc1f0cf);
#
#
#
#         marker_b887f765e42df2668313853d4858527a.bindPopup(popup_c685da54f038898ec4570c7f6ae19306)
#         ;
#
#
#
#
#             var marker_f0b5a9f8db04b5cf61209e3703f24e64 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8afc6ad6b455a25dbbc1b6b954277697);
#
#
#         var popup_348360fa227b3ad400606a87b415b56e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdcf51940c2ac2ba078a03993f25fde7 = $(`&lt;div id=&quot;html_fdcf51940c2ac2ba078a03993f25fde7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f59468849eab141138514c02744fc84f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f59468849eab141138514c02744fc84f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f59468849eab141138514c02744fc84f = L.map(
#                 &quot;map_f59468849eab141138514c02744fc84f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a02b980d1107fdd729d4d2108a706a4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a02b980d1107fdd729d4d2108a706a4f.addTo(map_f59468849eab141138514c02744fc84f);
#
#
#             var feature_group_0108743ba71cd807e7ffa66ec864f68f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0108743ba71cd807e7ffa66ec864f68f.addTo(map_f59468849eab141138514c02744fc84f);
#
#
#             var feature_group_sub_group_7b498b95bb526efc0181018f6bd1ade6 = L.featureGroup.subGroup(
#                 feature_group_0108743ba71cd807e7ffa66ec864f68f
#             );
#
#
#             var marker_b16c6de3e30b6bbbbb6169239dab36fb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b498b95bb526efc0181018f6bd1ade6);
#
#
#         var popup_720e1c4f62d4530062a4307a158cfb2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9f2b192aa64517121f3c3b5a97ccc3e = $(`&lt;div id=&quot;html_e9f2b192aa64517121f3c3b5a97ccc3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_720e1c4f62d4530062a4307a158cfb2f.setContent(html_e9f2b192aa64517121f3c3b5a97ccc3e);
#
#
#
#         marker_b16c6de3e30b6bbbbb6169239dab36fb.bindPopup(popup_720e1c4f62d4530062a4307a158cfb2f)
#         ;
#
#
#
#
#             var marker_96fe1a6b9e1ed6a3e594c878b2bacd9b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b498b95bb526efc0181018f6bd1ade6);
#
#
#         var popup_385b19a0ffe3bd73fca14ea1cbf82dfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c68ad2fc107e114d66364f79dae0983 = $(`&lt;div id=&quot;html_4c68ad2fc107e114d66364f79dae0983&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_385b19a0ffe3bd73fca14ea1cbf82dfb.setContent(html_4c68ad2fc107e114d66364f79dae0983);
#
#
#
#         marker_96fe1a6b9e1ed6a3e594c878b2bacd9b.bindPopup(popup_385b19a0ffe3bd73fca14ea1cbf82dfb)
#         ;
#
#
#
#
#             var marker_9f64971b427e45ddf7c3a1fd779c0313 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b498b95bb526efc0181018f6bd1ade6);
#
#
#         var popup_903e98a142dc3b84d55fd29ec194a2e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eb3b6125a540926d781387c18d6b264 = $(`&lt;div id=&quot;html_7eb3b6125a540926d781387c18d6b264&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_903e98a142dc3b84d55fd29ec194a2e4.setContent(html_7eb3b6125a540926d781387c18d6b264);
#
#
#
#         marker_9f64971b427e45ddf7c3a1fd779c0313.bindPopup(popup_903e98a142dc3b84d55fd29ec194a2e4)
#         ;
#
#
#
#
#             var marker_26efd7c9aa80effc61015258cbf0aa11 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7b498b95bb526efc0181018f6bd1ade6);
#
#
#         var popup_87cf2cd6a9b37e641cdc188c2e2052ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0226177c46700f10aedb0136b9424764 = $(`&lt;div id=&quot;html_0226177c46700f10aedb0136b9424764&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_87cf2cd6a9b37e641cdc188c2e2052ef.setContent(html_0226177c46700f10aedb0136b9424764);
#
#
#
#         marker_26efd7c9aa80effc61015258cbf0aa11.bindPopup(popup_87cf2cd6a9b37e641cdc188c2e2052ef)
#         ;
#
#
#
#
#             var marker_a1f072a701a3383ba3df989a2a798ee9 = L.marker(
#                 [45.0503999
