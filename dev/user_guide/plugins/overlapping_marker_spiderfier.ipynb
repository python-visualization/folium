# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_518004a44677baa8d51d6f306ef98e70 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_518004a44677baa8d51d6f306ef98e70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_518004a44677baa8d51d6f306ef98e70 = L.map(
#                 &quot;map_518004a44677baa8d51d6f306ef98e70&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_299fe9c3174f7b91945a2fd4120c2398 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_299fe9c3174f7b91945a2fd4120c2398.addTo(map_518004a44677baa8d51d6f306ef98e70);
#
#
#             var marker_00846fbbf97d7eb34ec61636c0f8fb26 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_518004a44677baa8d51d6f306ef98e70);
#
#
#         var popup_37eb60301e8de3a1e727f4fdc0dff5e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b730003e9aeb27419b30045a8a0450f = $(`&lt;div id=&quot;html_4b730003e9aeb27419b30045a8a0450f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_37eb60301e8de3a1e727f4fdc0dff5e8.setContent(html_4b730003e9aeb27419b30045a8a0450f);
#
#
#
#         marker_00846fbbf97d7eb34ec61636c0f8fb26.bindPopup(popup_37eb60301e8de3a1e727f4fdc0dff5e8)
#         ;
#
#
#
#
#             var marker_e317c145248d07496f0f885959e4e4c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_518004a44677baa8d51d6f306ef98e70);
#
#
#         var popup_5c439bef156f4131c59881335cdeb3d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_135d25bd2d79535ac1e38582d5c9023b = $(`&lt;div id=&quot;html_135d25bd2d79535ac1e38582d5c9023b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5c439bef156f4131c59881335cdeb3d9.setContent(html_135d25bd2d79535ac1e38582d5c9023b);
#
#
#
#         marker_e317c145248d07496f0f885959e4e4c4.bindPopup(popup_5c439bef156f4131c59881335cdeb3d9)
#         ;
#
#
#
#
#             var marker_5b72e0cff4400a7683703d32163e91c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_518004a44677baa8d51d6f306ef98e70);
#
#
#         var popup_34c24efb407d4e6456fb24934b702907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4dfaba3305f5659b602f997b99d3ff4 = $(`&lt;div id=&quot;html_d4dfaba3305f5659b602f997b99d3ff4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_34c24efb407d4e6456fb24934b702907.setContent(html_d4dfaba3305f5659b602f997b99d3ff4);
#
#
#
#         marker_5b72e0cff4400a7683703d32163e91c8.bindPopup(popup_34c24efb407d4e6456fb24934b702907)
#         ;
#
#
#
#
#             var marker_73036af01fb59d4bbb57be695eeb3baf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_518004a44677baa8d51d6f306ef98e70);
#
#
#         var popup_16ba6285d093065ee7b9a47e784e28a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e22b82b75943d3ed0ecd0b01d4c81558 = $(`&lt;div id=&quot;html_e22b82b75943d3ed0ecd0b01d4c81558&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_16ba6285d093065ee7b9a47e784e28a4.setContent(html_e22b82b75943d3ed0ecd0b01d4c81558);
#
#
#
#         marker_73036af01fb59d4bbb57be695eeb3baf.bindPopup(popup_16ba6285d093065ee7b9a47e784e28a4)
#         ;
#
#
#
#
#             var marker_28aa19241fa43e470431f34908d0fd28 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_518004a44677baa8d51d6f306ef98e70);
#
#
#         var popup_ab35193a295767459b8442f045675904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43e5f38bd85b4f8e45d1572567d1aa5f = $(`&lt;div id=&quot;html_43e5f38bd85b4f8e45d1572567d1aa5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ab35193a295767459b8442f045675904.setContent(html_43e5f38bd85b4f8e45d1572567d1aa5f);
#
#
#
#         marker_28aa19241fa43e470431f34908d0fd28.bindPopup(popup_ab35193a295767459b8442f045675904)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa6346db953f38003351ecfbc6e3c57e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa6346db953f38003351ecfbc6e3c57e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa6346db953f38003351ecfbc6e3c57e = L.map(
#                 &quot;map_fa6346db953f38003351ecfbc6e3c57e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e836236ec8d28e255e71bc5a5a887fb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e836236ec8d28e255e71bc5a5a887fb3.addTo(map_fa6346db953f38003351ecfbc6e3c57e);
#
#
#             var feature_group_516f6c97daabc52270a9da5bb8394122 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_892ff4fca5a34420757227e263b668bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_516f6c97daabc52270a9da5bb8394122);
#
#
#         var popup_d656e4d6205c9a9d8f15ba18ea368c23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76f9dcb40581692ec91e1e0a3a7381ae = $(`&lt;div id=&quot;html_76f9dcb40581692ec91e1e0a3a7381ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d656e4d6205c9a9d8f15ba18ea368c23.setContent(html_76f9dcb40581692ec91e1e0a3a7381ae);
#
#
#
#         marker_892ff4fca5a34420757227e263b668bf.bindPopup(popup_d656e4d6205c9a9d8f15ba18ea368c23)
#         ;
#
#
#
#
#             var marker_f8d3c4d1c3bcd9e81d69df615cf98d0c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_516f6c97daabc52270a9da5bb8394122);
#
#
#         var popup_d58f8cf177122c3382e712996e7f8dc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4adaaa25f623c64e5ced952ed28f30e3 = $(`&lt;div id=&quot;html_4adaaa25f623c64e5ced952ed28f30e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d58f8cf177122c3382e712996e7f8dc9.setContent(html_4adaaa25f623c64e5ced952ed28f30e3);
#
#
#
#         marker_f8d3c4d1c3bcd9e81d69df615cf98d0c.bindPopup(popup_d58f8cf177122c3382e712996e7f8dc9)
#         ;
#
#
#
#
#             var marker_848932952783c9853e62445be7ea262e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_516f6c97daabc52270a9da5bb8394122);
#
#
#         var popup_f7b222cb883b19b2a473a23d792649ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a430fbfa8e30e9ae37748c0b682280d1 = $(`&lt;div id=&quot;html_a430fbfa8e30e9ae37748c0b682280d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f7b222cb883b19b2a473a23d792649ce.setContent(html_a430fbfa8e30e9ae37748c0b682280d1);
#
#
#
#         marker_848932952783c9853e62445be7ea262e.bindPopup(popup_f7b222cb883b19b2a473a23d792649ce)
#         ;
#
#
#
#
#             var marker_2f77b2be3766c4f17108190f20bf4a0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_516f6c97daabc52270a9da5bb8394122);
#
#
#         var popup_297c31994491155eb6d75b99d6a83be5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4274ce93524cec633bc61386652c7695 = $(`&lt;div id=&quot;html_4274ce93524cec633bc61386652c7695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_297c31994491155eb6d75b99d6a83be5.setContent(html_4274ce93524cec633bc61386652c7695);
#
#
#
#         marker_2f77b2be3766c4f17108190f20bf4a0d.bindPopup(popup_297c31994491155eb6d75b99d6a83be5)
#         ;
#
#
#
#
#             var marker_0e5035476e8c6dd161dd7c699cf872d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_516f6c97daabc52270a9da5bb8394122);
#
#
#         var popup_01bd9e44c5f61e86db3680c0f0a32e60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ec33082c618ff12354debc43675e5ae = $(`&lt;div id=&quot;html_4ec33082c618ff12354debc43675e5ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1caf50517fc279a83ff07e673e724d90 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1caf50517fc279a83ff07e673e724d90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1caf50517fc279a83ff07e673e724d90 = L.map(
#                 &quot;map_1caf50517fc279a83ff07e673e724d90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe0f3391c87f82f08491c6736af1ddd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe0f3391c87f82f08491c6736af1ddd1.addTo(map_1caf50517fc279a83ff07e673e724d90);
#
#
#             var feature_group_2780cf4d7e45fda8b82d0e031140fad3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2780cf4d7e45fda8b82d0e031140fad3.addTo(map_1caf50517fc279a83ff07e673e724d90);
#
#
#             var feature_group_sub_group_2cdb9d097a989ebd31cc6b6e017fb08b = L.featureGroup.subGroup(
#                 feature_group_2780cf4d7e45fda8b82d0e031140fad3
#             );
#
#
#             var marker_818cec7360a756ddb165ecb5516611bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cdb9d097a989ebd31cc6b6e017fb08b);
#
#
#         var popup_ffe33a690ea3ed25c4a3f1716ccf28fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9bd7fcba671c712de11dc3e24b4cb7a = $(`&lt;div id=&quot;html_c9bd7fcba671c712de11dc3e24b4cb7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ffe33a690ea3ed25c4a3f1716ccf28fb.setContent(html_c9bd7fcba671c712de11dc3e24b4cb7a);
#
#
#
#         marker_818cec7360a756ddb165ecb5516611bf.bindPopup(popup_ffe33a690ea3ed25c4a3f1716ccf28fb)
#         ;
#
#
#
#
#             var marker_a8d93b48a37603707d5963a88392fac9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cdb9d097a989ebd31cc6b6e017fb08b);
#
#
#         var popup_8f0fd8ddab0c00cbc3377ae66d68b7e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1b4487851ffdd9b370ee20fe2352dd5 = $(`&lt;div id=&quot;html_e1b4487851ffdd9b370ee20fe2352dd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8f0fd8ddab0c00cbc3377ae66d68b7e0.setContent(html_e1b4487851ffdd9b370ee20fe2352dd5);
#
#
#
#         marker_a8d93b48a37603707d5963a88392fac9.bindPopup(popup_8f0fd8ddab0c00cbc3377ae66d68b7e0)
#         ;
#
#
#
#
#             var marker_29b64fe4f782c26f2996718245e54bc0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cdb9d097a989ebd31cc6b6e017fb08b);
#
#
#         var popup_b832a102d6bfc8e9a47c0cebbf918851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2263737aebd0c8cc7af2388589729e6 = $(`&lt;div id=&quot;html_e2263737aebd0c8cc7af2388589729e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b832a102d6bfc8e9a47c0cebbf918851.setContent(html_e2263737aebd0c8cc7af2388589729e6);
#
#
#
#         marker_29b64fe4f782c26f2996718245e54bc0.bindPopup(popup_b832a102d6bfc8e9a47c0cebbf918851)
#         ;
#
#
#
#
#             var marker_1e30d1ee421874c98da13230e5abb61a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2cdb9d097a989ebd31cc6b6e017fb08b);
#
#
#         var popup_91278268a5175615660053fc5e3de68b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2233877bfbcdd5d2d60ede234546d5f8 = $(`&lt;div id=&quot;html_2233877bfbcdd5d2d60ede234546d5f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_91278268a5175615660053fc5e3de68b.setContent(html_2233877bfbcdd5d2d60ede234546d5f8);
#
#
#
#         marker_1e30d1ee421874c98da13230e5abb61a.bindPopup(popup_91278268a5175615660053fc5e3de68b)
#         ;
#
#
#
#
#             var marker_587457f2371900257a035a388ab78813 = L.marker(
#                 [45.0503999
