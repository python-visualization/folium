# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71a32cd6e86350d391c7d257bdaa99d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71a32cd6e86350d391c7d257bdaa99d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71a32cd6e86350d391c7d257bdaa99d2 = L.map(
#                 &quot;map_71a32cd6e86350d391c7d257bdaa99d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aae56420008e5d557a7f1fe1bb0ce7b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aae56420008e5d557a7f1fe1bb0ce7b0.addTo(map_71a32cd6e86350d391c7d257bdaa99d2);
#
#
#             var marker_f14c4a9ca3edc3c8752a1d31b80d0991 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_71a32cd6e86350d391c7d257bdaa99d2);
#
#
#         var popup_a32328dcbbb331ff36175a3e2abc35c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_323b7e0fedfc49f1b3be56c58cecb6d9 = $(`&lt;div id=&quot;html_323b7e0fedfc49f1b3be56c58cecb6d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a32328dcbbb331ff36175a3e2abc35c2.setContent(html_323b7e0fedfc49f1b3be56c58cecb6d9);
#
#
#
#         marker_f14c4a9ca3edc3c8752a1d31b80d0991.bindPopup(popup_a32328dcbbb331ff36175a3e2abc35c2)
#         ;
#
#
#
#
#             var marker_354864b77d9e5edac68637bc8332e9be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_71a32cd6e86350d391c7d257bdaa99d2);
#
#
#         var popup_bde215e0699dead31c62c29b0c16bad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53be862728d126c16e18f0f83b9ca7b2 = $(`&lt;div id=&quot;html_53be862728d126c16e18f0f83b9ca7b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bde215e0699dead31c62c29b0c16bad4.setContent(html_53be862728d126c16e18f0f83b9ca7b2);
#
#
#
#         marker_354864b77d9e5edac68637bc8332e9be.bindPopup(popup_bde215e0699dead31c62c29b0c16bad4)
#         ;
#
#
#
#
#             var marker_0bec562af482490254ac990efea7ffc8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_71a32cd6e86350d391c7d257bdaa99d2);
#
#
#         var popup_2252743c845671b8d9501b720e8e4ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6976a9008a1b301945ee4467e513386f = $(`&lt;div id=&quot;html_6976a9008a1b301945ee4467e513386f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2252743c845671b8d9501b720e8e4ae2.setContent(html_6976a9008a1b301945ee4467e513386f);
#
#
#
#         marker_0bec562af482490254ac990efea7ffc8.bindPopup(popup_2252743c845671b8d9501b720e8e4ae2)
#         ;
#
#
#
#
#             var marker_63d8233915c7972b03a0813db83adc67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_71a32cd6e86350d391c7d257bdaa99d2);
#
#
#         var popup_088ef8a36a544afae5e34f03a8024bef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e3bdc1167c96c9ddd8c3fbef168c216 = $(`&lt;div id=&quot;html_8e3bdc1167c96c9ddd8c3fbef168c216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_088ef8a36a544afae5e34f03a8024bef.setContent(html_8e3bdc1167c96c9ddd8c3fbef168c216);
#
#
#
#         marker_63d8233915c7972b03a0813db83adc67.bindPopup(popup_088ef8a36a544afae5e34f03a8024bef)
#         ;
#
#
#
#
#             var marker_f42aa542ac2d950e6da01fc063c44e3b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_71a32cd6e86350d391c7d257bdaa99d2);
#
#
#         var popup_e4d8733fafd53697cd02f582f165b9cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ff6105066a55f506100a3950a54455e = $(`&lt;div id=&quot;html_8ff6105066a55f506100a3950a54455e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e4d8733fafd53697cd02f582f165b9cb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3863d57c7c705b5f3bc985a9ae2b0a81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3863d57c7c705b5f3bc985a9ae2b0a81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3863d57c7c705b5f3bc985a9ae2b0a81 = L.map(
#                 &quot;map_3863d57c7c705b5f3bc985a9ae2b0a81&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56255b06056a4c198e7eeccb44854a9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56255b06056a4c198e7eeccb44854a9e.addTo(map_3863d57c7c705b5f3bc985a9ae2b0a81);
#
#
#             var feature_group_7f9145a519737c2f49984c03274c279e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2f88eb2c4a295c3cc53af32edb182a6b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f9145a519737c2f49984c03274c279e);
#
#
#         var popup_0bde0c051761f89a45126f6915f070cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed5d02358867903f47badb86273ba406 = $(`&lt;div id=&quot;html_ed5d02358867903f47badb86273ba406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0bde0c051761f89a45126f6915f070cb.setContent(html_ed5d02358867903f47badb86273ba406);
#
#
#
#         marker_2f88eb2c4a295c3cc53af32edb182a6b.bindPopup(popup_0bde0c051761f89a45126f6915f070cb)
#         ;
#
#
#
#
#             var marker_fe42ee670a17f73635e3f9b00959c496 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f9145a519737c2f49984c03274c279e);
#
#
#         var popup_22cb6b629f6a934cf05629ff2fe763be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dedbfd53f70d179a66026e38b56d9fa0 = $(`&lt;div id=&quot;html_dedbfd53f70d179a66026e38b56d9fa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_22cb6b629f6a934cf05629ff2fe763be.setContent(html_dedbfd53f70d179a66026e38b56d9fa0);
#
#
#
#         marker_fe42ee670a17f73635e3f9b00959c496.bindPopup(popup_22cb6b629f6a934cf05629ff2fe763be)
#         ;
#
#
#
#
#             var marker_0c2ea3242f7cc83c5ec28d5d2575bf47 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f9145a519737c2f49984c03274c279e);
#
#
#         var popup_00ed9419bbfebf41e2dfba82d322a236 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6d5820b4a0ee83d3d32d7fc9a4b463d = $(`&lt;div id=&quot;html_a6d5820b4a0ee83d3d32d7fc9a4b463d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_00ed9419bbfebf41e2dfba82d322a236.setContent(html_a6d5820b4a0ee83d3d32d7fc9a4b463d);
#
#
#
#         marker_0c2ea3242f7cc83c5ec28d5d2575bf47.bindPopup(popup_00ed9419bbfebf41e2dfba82d322a236)
#         ;
#
#
#
#
#             var marker_f2dfce44520b9910ca8da8f64c7bfd4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f9145a519737c2f49984c03274c279e);
#
#
#         var popup_8cc585d51f7a9560118d0acd937e44ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b41c6d49589075a7b376bfbef575091 = $(`&lt;div id=&quot;html_9b41c6d49589075a7b376bfbef575091&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8cc585d51f7a9560118d0acd937e44ec.setContent(html_9b41c6d49589075a7b376bfbef575091);
#
#
#
#         marker_f2dfce44520b9910ca8da8f64c7bfd4f.bindPopup(popup_8cc585d51f7a9560118d0acd937e44ec)
#         ;
#
#
#
#
#             var marker_4e7fa2856b1df1fe404fdb4ff39dd988 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f9145a519737c2f49984c03274c279e);
#
#
#         var popup_9c63ba0e34dfe4b6e530b632c9d07974 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f971a991e0afa031b5954b98c693704a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f971a991e0afa031b5954b98c693704a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f971a991e0afa031b5954b98c693704a = L.map(
#                 &quot;map_f971a991e0afa031b5954b98c693704a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dae165f736f29067417f20548c5230b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6dae165f736f29067417f20548c5230b.addTo(map_f971a991e0afa031b5954b98c693704a);
#
#
#             var feature_group_e6c50f6c988aad0ad265545282985a80 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e6c50f6c988aad0ad265545282985a80.addTo(map_f971a991e0afa031b5954b98c693704a);
#
#
#             var feature_group_sub_group_974f683720fbc6212bb204cb1afbf45c = L.featureGroup.subGroup(
#                 feature_group_e6c50f6c988aad0ad265545282985a80
#             );
#
#
#             var marker_47b577a27904a34a33ed47d4e8bce55d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_974f683720fbc6212bb204cb1afbf45c);
#
#
#         var popup_332b01138e36155e7445594ad312f8da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bacefdcfd97af2a33e4bacd80473e6b = $(`&lt;div id=&quot;html_5bacefdcfd97af2a33e4bacd80473e6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_332b01138e36155e7445594ad312f8da.setContent(html_5bacefdcfd97af2a33e4bacd80473e6b);
#
#
#
#         marker_47b577a27904a34a33ed47d4e8bce55d.bindPopup(popup_332b01138e36155e7445594ad312f8da)
#         ;
#
#
#
#
#             var marker_cbce1a7c076b6359e835d6ff11a2c099 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_974f683720fbc6212bb204cb1afbf45c);
#
#
#         var popup_fd95064a8aa93d818b24faa83eb6c415 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2cdb46f85384392f050e42fae2748a55 = $(`&lt;div id=&quot;html_2cdb46f85384392f050e42fae2748a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fd95064a8aa93d818b24faa83eb6c415.setContent(html_2cdb46f85384392f050e42fae2748a55);
#
#
#
#         marker_cbce1a7c076b6359e835d6ff11a2c099.bindPopup(popup_fd95064a8aa93d818b24faa83eb6c415)
#         ;
#
#
#
#
#             var marker_be7545ac1de76cc8b662015aeffa4784 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_974f683720fbc6212bb204cb1afbf45c);
#
#
#         var popup_94dd453c1c29b41f3d387c2088bc87cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_599e79aa5506af864f6702512222dc54 = $(`&lt;div id=&quot;html_599e79aa5506af864f6702512222dc54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_94dd453c1c29b41f3d387c2088bc87cf.setContent(html_599e79aa5506af864f6702512222dc54);
#
#
#
#         marker_be7545ac1de76cc8b662015aeffa4784.bindPopup(popup_94dd453c1c29b41f3d387c2088bc87cf)
#         ;
#
#
#
#
#             var marker_a9093273a9a64a5b643548440b39f6c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_974f683720fbc6212bb204cb1afbf45c);
#
#
#         var popup_ec759f450842f3ac6e9a918129691695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9730721a24732995bf7e5ef584477fc = $(`&lt;div id=&quot;html_a9730721a24732995bf7e5ef584477fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ec759f450842f3ac6e9a918129691695.setContent(html_a9730721a24732995bf7e5ef584477fc);
#
#
#
#         marker_
