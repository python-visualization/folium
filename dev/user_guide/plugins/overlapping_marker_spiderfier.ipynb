# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d09124449a2aa7bb336336e7de1db7fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d09124449a2aa7bb336336e7de1db7fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d09124449a2aa7bb336336e7de1db7fc = L.map(
#                 &quot;map_d09124449a2aa7bb336336e7de1db7fc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59592e883bff92c74b1e0050702a858a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59592e883bff92c74b1e0050702a858a.addTo(map_d09124449a2aa7bb336336e7de1db7fc);
#
#
#             var marker_3ba52eb7a444da9a859eae8a75bf8bc1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d09124449a2aa7bb336336e7de1db7fc);
#
#
#         var popup_40c40f4b6c68f78a291f63ce215c9b46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa5d1d9d7124d680bc0d75df3d4f79e0 = $(`&lt;div id=&quot;html_fa5d1d9d7124d680bc0d75df3d4f79e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_40c40f4b6c68f78a291f63ce215c9b46.setContent(html_fa5d1d9d7124d680bc0d75df3d4f79e0);
#
#
#
#         marker_3ba52eb7a444da9a859eae8a75bf8bc1.bindPopup(popup_40c40f4b6c68f78a291f63ce215c9b46)
#         ;
#
#
#
#
#             var marker_bf8e8b7c8a995af0c3fc3b1556139d9c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d09124449a2aa7bb336336e7de1db7fc);
#
#
#         var popup_d63cb51741f65b8d220226174c10d22b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4add2c5cd913ef00a756fda168cee736 = $(`&lt;div id=&quot;html_4add2c5cd913ef00a756fda168cee736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d63cb51741f65b8d220226174c10d22b.setContent(html_4add2c5cd913ef00a756fda168cee736);
#
#
#
#         marker_bf8e8b7c8a995af0c3fc3b1556139d9c.bindPopup(popup_d63cb51741f65b8d220226174c10d22b)
#         ;
#
#
#
#
#             var marker_a1412f0547f20f1bd0b3a12f8fb04e2a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d09124449a2aa7bb336336e7de1db7fc);
#
#
#         var popup_ee279fe3539b9dd33e43b94367ea299d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9178e3cfbef1805485841421f32c1024 = $(`&lt;div id=&quot;html_9178e3cfbef1805485841421f32c1024&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee279fe3539b9dd33e43b94367ea299d.setContent(html_9178e3cfbef1805485841421f32c1024);
#
#
#
#         marker_a1412f0547f20f1bd0b3a12f8fb04e2a.bindPopup(popup_ee279fe3539b9dd33e43b94367ea299d)
#         ;
#
#
#
#
#             var marker_ef3e9b4975c7bbb8ea802fdd207eb17d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d09124449a2aa7bb336336e7de1db7fc);
#
#
#         var popup_02fe71196a201b5dd32ed0195f7ef67f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ec6c6086bf633a612002cd4b186adea = $(`&lt;div id=&quot;html_3ec6c6086bf633a612002cd4b186adea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_02fe71196a201b5dd32ed0195f7ef67f.setContent(html_3ec6c6086bf633a612002cd4b186adea);
#
#
#
#         marker_ef3e9b4975c7bbb8ea802fdd207eb17d.bindPopup(popup_02fe71196a201b5dd32ed0195f7ef67f)
#         ;
#
#
#
#
#             var marker_6d25732cd58107348f61b86006bab768 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d09124449a2aa7bb336336e7de1db7fc);
#
#
#         var popup_68a33a3abc8f1f68986379fa18c01216 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_927bd6a18f0dea5409f6a4b396381372 = $(`&lt;div id=&quot;html_927bd6a18f0dea5409f6a4b396381372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_68a33a3abc8f1f68986379fa18c01216.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_925fb9ccb8b82bf452704a4c1cc11933 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_925fb9ccb8b82bf452704a4c1cc11933&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_925fb9ccb8b82bf452704a4c1cc11933 = L.map(
#                 &quot;map_925fb9ccb8b82bf452704a4c1cc11933&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9433638707f3880799f61a60f68cb0ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9433638707f3880799f61a60f68cb0ca.addTo(map_925fb9ccb8b82bf452704a4c1cc11933);
#
#
#             var feature_group_4cc44501e537b8e33fc1ed04aeb04f5f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4ab7b449a837f79cc1c7858cdade3eb0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4cc44501e537b8e33fc1ed04aeb04f5f);
#
#
#         var popup_c10d30c31b3a95e63c00886be693c5dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b92e6e968fa04c6a5bdee6e27de0721f = $(`&lt;div id=&quot;html_b92e6e968fa04c6a5bdee6e27de0721f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c10d30c31b3a95e63c00886be693c5dd.setContent(html_b92e6e968fa04c6a5bdee6e27de0721f);
#
#
#
#         marker_4ab7b449a837f79cc1c7858cdade3eb0.bindPopup(popup_c10d30c31b3a95e63c00886be693c5dd)
#         ;
#
#
#
#
#             var marker_e47dca7a017666aa62cabb5e32a1b5c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4cc44501e537b8e33fc1ed04aeb04f5f);
#
#
#         var popup_ae3ffa15e9a1fd2ccee9d53a2f3bc5a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83c662e31f8f7537e6e46e19ba24f1eb = $(`&lt;div id=&quot;html_83c662e31f8f7537e6e46e19ba24f1eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ae3ffa15e9a1fd2ccee9d53a2f3bc5a4.setContent(html_83c662e31f8f7537e6e46e19ba24f1eb);
#
#
#
#         marker_e47dca7a017666aa62cabb5e32a1b5c4.bindPopup(popup_ae3ffa15e9a1fd2ccee9d53a2f3bc5a4)
#         ;
#
#
#
#
#             var marker_0b02907850950f2acd06a91d405cbadf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4cc44501e537b8e33fc1ed04aeb04f5f);
#
#
#         var popup_bf8a7d4748794795d0d8529a595c4354 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acb78ad8835fed3b67d099019ede055e = $(`&lt;div id=&quot;html_acb78ad8835fed3b67d099019ede055e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bf8a7d4748794795d0d8529a595c4354.setContent(html_acb78ad8835fed3b67d099019ede055e);
#
#
#
#         marker_0b02907850950f2acd06a91d405cbadf.bindPopup(popup_bf8a7d4748794795d0d8529a595c4354)
#         ;
#
#
#
#
#             var marker_b355d33b85e9fedb6478e3cfb1011dda = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4cc44501e537b8e33fc1ed04aeb04f5f);
#
#
#         var popup_8ac0e072b8b6bb2edb6f6751340c9059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d8871f91e8c00288c1160db3cd0c5a2 = $(`&lt;div id=&quot;html_7d8871f91e8c00288c1160db3cd0c5a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8ac0e072b8b6bb2edb6f6751340c9059.setContent(html_7d8871f91e8c00288c1160db3cd0c5a2);
#
#
#
#         marker_b355d33b85e9fedb6478e3cfb1011dda.bindPopup(popup_8ac0e072b8b6bb2edb6f6751340c9059)
#         ;
#
#
#
#
#             var marker_560f99fe8a42cdce622fa40a14fe5e13 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4cc44501e537b8e33fc1ed04aeb04f5f);
#
#
#         var popup_20464fc31f470a3205a5a9618e79a340 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7eb2512266a7a5e32c5e14e780183d1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7eb2512266a7a5e32c5e14e780183d1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7eb2512266a7a5e32c5e14e780183d1a = L.map(
#                 &quot;map_7eb2512266a7a5e32c5e14e780183d1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea932c6506753cb0f0e6614ccf01edb4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea932c6506753cb0f0e6614ccf01edb4.addTo(map_7eb2512266a7a5e32c5e14e780183d1a);
#
#
#             var feature_group_314a355b9d47fbdcfe42685c8c96cc33 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_314a355b9d47fbdcfe42685c8c96cc33.addTo(map_7eb2512266a7a5e32c5e14e780183d1a);
#
#
#             var feature_group_sub_group_73e9b2edffd917548da489e0fa6dc2d9 = L.featureGroup.subGroup(
#                 feature_group_314a355b9d47fbdcfe42685c8c96cc33
#             );
#
#
#             var marker_51711780291e973117b64c88c9f7c1eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_73e9b2edffd917548da489e0fa6dc2d9);
#
#
#         var popup_04c1fdee524ce1b41002a2757f9c96e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca5c1a9713872a791ce5af20bca1818a = $(`&lt;div id=&quot;html_ca5c1a9713872a791ce5af20bca1818a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_04c1fdee524ce1b41002a2757f9c96e7.setContent(html_ca5c1a9713872a791ce5af20bca1818a);
#
#
#
#         marker_51711780291e973117b64c88c9f7c1eb.bindPopup(popup_04c1fdee524ce1b41002a2757f9c96e7)
#         ;
#
#
#
#
#             var marker_81fe99db5953ccd1f4cf36458a66fe59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_73e9b2edffd917548da489e0fa6dc2d9);
#
#
#         var popup_5eeedb12b6b4bca7b551fe74d18c2353 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8991274f23b19a9a19c63029d2e93f1c = $(`&lt;div id=&quot;html_8991274f23b19a9a19c63029d2e93f1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5eeedb12b6b4bca7b551fe74d18c2353.setContent(html_8991274f23b19a9a19c63029d2e93f1c);
#
#
#
#         marker_81fe99db5953ccd1f4cf36458a66fe59.bindPopup(popup_5eeedb12b6b4bca7b551fe74d18c2353)
#         ;
#
#
#
#
#             var marker_2a37fe42d36f13d96fe4f423deaccf5f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_73e9b2edffd917548da489e0fa6dc2d9);
#
#
#         var popup_f5e66962c3a93fa9fa5fd4611c7d4035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a20ef01b4c27eea53d87c6df4a2769df = $(`&lt;div id=&quot;html_a20ef01b4c27eea53d87c6df4a2769df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f5e66962c3a93fa9fa5fd4611c7d4035.setContent(html_a20ef01b4c27eea53d87c6df4a2769df);
#
#
#
#         marker_2a37fe42d36f13d96fe4f423deaccf5f.bindPopup(popup_f5e66962c3a93fa9fa5fd4611c7d4035)
#         ;
#
#
#
#
#             var marker_009efc7ca0200289e84b11a221d16df3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_73e9b2edffd917548da489e0fa6dc2d9);
#
#
#         var popup_5c1e21437670239992c41c0aed0ff6a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeb195c49901e5ac9c918f4966fda46b = $(`&lt;div id=&quot;html_eeb195c49901e5ac9c918f4966fda46b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5c1e21437670239992c41c0aed0ff6a6.setContent(html_eeb195c49901e5ac9c918f4966fda46b);
#
#
#
#         marker_
