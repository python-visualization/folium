# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_203622f5240c42a070fd5184183a5ed5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_203622f5240c42a070fd5184183a5ed5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_203622f5240c42a070fd5184183a5ed5 = L.map(
#                 &quot;map_203622f5240c42a070fd5184183a5ed5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55d94e0c42d3612e2722703d1a2b2806 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55d94e0c42d3612e2722703d1a2b2806.addTo(map_203622f5240c42a070fd5184183a5ed5);
#
#
#             var marker_7513a86d7947417a123104514e63a95e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_203622f5240c42a070fd5184183a5ed5);
#
#
#         var popup_a4a24a295b324669e2777bcee750de83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_105330c399c4247d2359a82468c12057 = $(`&lt;div id=&quot;html_105330c399c4247d2359a82468c12057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a4a24a295b324669e2777bcee750de83.setContent(html_105330c399c4247d2359a82468c12057);
#
#
#
#         marker_7513a86d7947417a123104514e63a95e.bindPopup(popup_a4a24a295b324669e2777bcee750de83)
#         ;
#
#
#
#
#             var marker_1041d06d48add541b003040419541d4b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_203622f5240c42a070fd5184183a5ed5);
#
#
#         var popup_9bc38ef8a1b4a739ab9fafa517c7786d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56226d164c2e4fcd7f2888581aa0138a = $(`&lt;div id=&quot;html_56226d164c2e4fcd7f2888581aa0138a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9bc38ef8a1b4a739ab9fafa517c7786d.setContent(html_56226d164c2e4fcd7f2888581aa0138a);
#
#
#
#         marker_1041d06d48add541b003040419541d4b.bindPopup(popup_9bc38ef8a1b4a739ab9fafa517c7786d)
#         ;
#
#
#
#
#             var marker_271e66c4c23ad758af91f3302ea8b6ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_203622f5240c42a070fd5184183a5ed5);
#
#
#         var popup_1424655a36630de3f91ee13df7555e98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2934794ad3c7f3527a78a2378c7add33 = $(`&lt;div id=&quot;html_2934794ad3c7f3527a78a2378c7add33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1424655a36630de3f91ee13df7555e98.setContent(html_2934794ad3c7f3527a78a2378c7add33);
#
#
#
#         marker_271e66c4c23ad758af91f3302ea8b6ae.bindPopup(popup_1424655a36630de3f91ee13df7555e98)
#         ;
#
#
#
#
#             var marker_10920bbb1d3836858b3ac26a2a292d42 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_203622f5240c42a070fd5184183a5ed5);
#
#
#         var popup_8e791dfe5e7138090defb67c9f3bfd3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_357783893ac97ac3ecf91eeff44f7b8a = $(`&lt;div id=&quot;html_357783893ac97ac3ecf91eeff44f7b8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8e791dfe5e7138090defb67c9f3bfd3c.setContent(html_357783893ac97ac3ecf91eeff44f7b8a);
#
#
#
#         marker_10920bbb1d3836858b3ac26a2a292d42.bindPopup(popup_8e791dfe5e7138090defb67c9f3bfd3c)
#         ;
#
#
#
#
#             var marker_20a667364c66a64417aa3f1a48215473 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_203622f5240c42a070fd5184183a5ed5);
#
#
#         var popup_6ba836b96612cfee481da38aa20e67c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f08e3a41438bd1c17560e2de03c4d37f = $(`&lt;div id=&quot;html_f08e3a41438bd1c17560e2de03c4d37f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6ba836b96612cfee481da38aa20e67

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b42b617a23696c7bc5c1ad1d48bd0afe {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b42b617a23696c7bc5c1ad1d48bd0afe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b42b617a23696c7bc5c1ad1d48bd0afe = L.map(
#                 &quot;map_b42b617a23696c7bc5c1ad1d48bd0afe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bb629c2a807a9a4c437c714fe62c2c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5bb629c2a807a9a4c437c714fe62c2c8.addTo(map_b42b617a23696c7bc5c1ad1d48bd0afe);
#
#
#             var feature_group_4c871891dc51bd3c800193c84e6c5d7a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_377091890d2f6cb64567b1b63d54a038 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4c871891dc51bd3c800193c84e6c5d7a);
#
#
#         var popup_dffb57514bc68cd3e785ba259a1da4c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22d1acef45b7872c1d41babecf3dea6b = $(`&lt;div id=&quot;html_22d1acef45b7872c1d41babecf3dea6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dffb57514bc68cd3e785ba259a1da4c5.setContent(html_22d1acef45b7872c1d41babecf3dea6b);
#
#
#
#         marker_377091890d2f6cb64567b1b63d54a038.bindPopup(popup_dffb57514bc68cd3e785ba259a1da4c5)
#         ;
#
#
#
#
#             var marker_617b1c383d495598e8f9253fc4984326 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4c871891dc51bd3c800193c84e6c5d7a);
#
#
#         var popup_c29bdd40f3f2fad214e041963dd1a755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31bed7c96da58f59c780e57869a04709 = $(`&lt;div id=&quot;html_31bed7c96da58f59c780e57869a04709&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c29bdd40f3f2fad214e041963dd1a755.setContent(html_31bed7c96da58f59c780e57869a04709);
#
#
#
#         marker_617b1c383d495598e8f9253fc4984326.bindPopup(popup_c29bdd40f3f2fad214e041963dd1a755)
#         ;
#
#
#
#
#             var marker_25bddec771df9b194bd8369f5006dc34 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4c871891dc51bd3c800193c84e6c5d7a);
#
#
#         var popup_e90f17a8bcfcbdb73aa981b3b05b9108 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb0e01ddb25d4fe8a9eb4278eba4ab63 = $(`&lt;div id=&quot;html_cb0e01ddb25d4fe8a9eb4278eba4ab63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e90f17a8bcfcbdb73aa981b3b05b9108.setContent(html_cb0e01ddb25d4fe8a9eb4278eba4ab63);
#
#
#
#         marker_25bddec771df9b194bd8369f5006dc34.bindPopup(popup_e90f17a8bcfcbdb73aa981b3b05b9108)
#         ;
#
#
#
#
#             var marker_a53471eade00b21570a92161ffe514b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4c871891dc51bd3c800193c84e6c5d7a);
#
#
#         var popup_1f87a8625a911484370208e0bb423e2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef7a5eb31c98130a14b2463256611570 = $(`&lt;div id=&quot;html_ef7a5eb31c98130a14b2463256611570&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1f87a8625a911484370208e0bb423e2f.setContent(html_ef7a5eb31c98130a14b2463256611570);
#
#
#
#         marker_a53471eade00b21570a92161ffe514b5.bindPopup(popup_1f87a8625a911484370208e0bb423e2f)
#         ;
#
#
#
#
#             var marker_011b0ebc27d8f1769aca246933c69d40 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4c871891dc51bd3c800193c84e6c5d7a);
#
#
#         var popup_3295a4a179cc9f182ffd161dd4312296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a4377211e5747fca96650e5770cee83 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a4377211e5747fca96650e5770cee83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a4377211e5747fca96650e5770cee83 = L.map(
#                 &quot;map_5a4377211e5747fca96650e5770cee83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe8fc695903b3958f30e2ff574c40166 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe8fc695903b3958f30e2ff574c40166.addTo(map_5a4377211e5747fca96650e5770cee83);
#
#
#             var feature_group_1a03acac4a0a86a8143951e911f0f3c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1a03acac4a0a86a8143951e911f0f3c7.addTo(map_5a4377211e5747fca96650e5770cee83);
#
#
#             var feature_group_sub_group_b5e2003c39e81a29ddab03347fadfcb4 = L.featureGroup.subGroup(
#                 feature_group_1a03acac4a0a86a8143951e911f0f3c7
#             );
#
#
#             var marker_3f7c31deff8dd3a7eff2ae9c5995b979 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5e2003c39e81a29ddab03347fadfcb4);
#
#
#         var popup_3b0b5fb74cd625ccae7b9bb3fe54e795 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8edf64bcc2f3d4c047d952aba58c6a5e = $(`&lt;div id=&quot;html_8edf64bcc2f3d4c047d952aba58c6a5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3b0b5fb74cd625ccae7b9bb3fe54e795.setContent(html_8edf64bcc2f3d4c047d952aba58c6a5e);
#
#
#
#         marker_3f7c31deff8dd3a7eff2ae9c5995b979.bindPopup(popup_3b0b5fb74cd625ccae7b9bb3fe54e795)
#         ;
#
#
#
#
#             var marker_ce427df8b63ffe8fa1c69f905f52505b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5e2003c39e81a29ddab03347fadfcb4);
#
#
#         var popup_4447f793c7f687e4fe00515acdac8fb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc5258e823180ffb7261166709bba5a2 = $(`&lt;div id=&quot;html_fc5258e823180ffb7261166709bba5a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4447f793c7f687e4fe00515acdac8fb9.setContent(html_fc5258e823180ffb7261166709bba5a2);
#
#
#
#         marker_ce427df8b63ffe8fa1c69f905f52505b.bindPopup(popup_4447f793c7f687e4fe00515acdac8fb9)
#         ;
#
#
#
#
#             var marker_d0fb10a8b1536635fb3d679a2f91f04c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5e2003c39e81a29ddab03347fadfcb4);
#
#
#         var popup_e106cd1cf270875a87dbc6802499671d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2548f3d39f369d93e51c2227eff03b59 = $(`&lt;div id=&quot;html_2548f3d39f369d93e51c2227eff03b59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e106cd1cf270875a87dbc6802499671d.setContent(html_2548f3d39f369d93e51c2227eff03b59);
#
#
#
#         marker_d0fb10a8b1536635fb3d679a2f91f04c.bindPopup(popup_e106cd1cf270875a87dbc6802499671d)
#         ;
#
#
#
#
#             var marker_54329957e4fc40f288b6b6e2c67d8696 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5e2003c39e81a29ddab03347fadfcb4);
#
#
#         var popup_ad740ddc92882ff33763d983609373e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f83f8c68b965cf2a7f82748e76d6b0c = $(`&lt;div id=&quot;html_0f83f8c68b965cf2a7f82748e76d6b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ad740ddc92882ff33763d983609373e0.setContent(html_0f83f8c68b965cf2a7f82748e76d6b0c);
#
#
#
#         mark
