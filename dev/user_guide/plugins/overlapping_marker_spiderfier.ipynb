# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0173c3f875dc5540b24c120fe63b17b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0173c3f875dc5540b24c120fe63b17b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0173c3f875dc5540b24c120fe63b17b = L.map(
#                 &quot;map_c0173c3f875dc5540b24c120fe63b17b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b629b280b995cee2dd51a7f609ff5907 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b629b280b995cee2dd51a7f609ff5907.addTo(map_c0173c3f875dc5540b24c120fe63b17b);
#
#
#             var marker_c3046d0bb3118398d8a26dd273659419 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c0173c3f875dc5540b24c120fe63b17b);
#
#
#         var popup_f2473b3969e7da01b55639d23eff88d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dfa6379d61734b66e4706621cd4ff95 = $(`&lt;div id=&quot;html_9dfa6379d61734b66e4706621cd4ff95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f2473b3969e7da01b55639d23eff88d6.setContent(html_9dfa6379d61734b66e4706621cd4ff95);
#
#
#
#         marker_c3046d0bb3118398d8a26dd273659419.bindPopup(popup_f2473b3969e7da01b55639d23eff88d6)
#         ;
#
#
#
#
#             var marker_d7618c9c93eab64863f542886f0b5673 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c0173c3f875dc5540b24c120fe63b17b);
#
#
#         var popup_bf5b4464d0e7a8de8af9eb2f7f6431cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42a2c5168fbda50cc32bfc77d182d8da = $(`&lt;div id=&quot;html_42a2c5168fbda50cc32bfc77d182d8da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bf5b4464d0e7a8de8af9eb2f7f6431cf.setContent(html_42a2c5168fbda50cc32bfc77d182d8da);
#
#
#
#         marker_d7618c9c93eab64863f542886f0b5673.bindPopup(popup_bf5b4464d0e7a8de8af9eb2f7f6431cf)
#         ;
#
#
#
#
#             var marker_6aa716a9a20ee51bf65184a8ea3ffcd3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c0173c3f875dc5540b24c120fe63b17b);
#
#
#         var popup_3887d22bc7aceda898891e2eaaeeff11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35c692c50d8a82f14c62c629ffd94e9d = $(`&lt;div id=&quot;html_35c692c50d8a82f14c62c629ffd94e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3887d22bc7aceda898891e2eaaeeff11.setContent(html_35c692c50d8a82f14c62c629ffd94e9d);
#
#
#
#         marker_6aa716a9a20ee51bf65184a8ea3ffcd3.bindPopup(popup_3887d22bc7aceda898891e2eaaeeff11)
#         ;
#
#
#
#
#             var marker_3a376aed09941d3caf796a6bb0e4e540 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c0173c3f875dc5540b24c120fe63b17b);
#
#
#         var popup_2a3255ede5b90145d2850c37d8eda552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f73e724005890d4921bfaf7a1ff94966 = $(`&lt;div id=&quot;html_f73e724005890d4921bfaf7a1ff94966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2a3255ede5b90145d2850c37d8eda552.setContent(html_f73e724005890d4921bfaf7a1ff94966);
#
#
#
#         marker_3a376aed09941d3caf796a6bb0e4e540.bindPopup(popup_2a3255ede5b90145d2850c37d8eda552)
#         ;
#
#
#
#
#             var marker_f45825ba16f6a51d92dbd3301b2d4935 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c0173c3f875dc5540b24c120fe63b17b);
#
#
#         var popup_4c1d6f832f3515d2965aaa23cc841e81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1fac826b42c3ef79a154c0a3614447c = $(`&lt;div id=&quot;html_c1fac826b42c3ef79a154c0a3614447c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4c1d6f832f3515d2965aaa23cc841e81.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef710f8544e82d099462f31d57fe91c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef710f8544e82d099462f31d57fe91c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef710f8544e82d099462f31d57fe91c5 = L.map(
#                 &quot;map_ef710f8544e82d099462f31d57fe91c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_015851a0658582864914d59d0d9a1089 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_015851a0658582864914d59d0d9a1089.addTo(map_ef710f8544e82d099462f31d57fe91c5);
#
#
#             var feature_group_1cecef15f071238acffc892be1b1d0dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0d45bfb2ce3d12bf47207b38d0df2136 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1cecef15f071238acffc892be1b1d0dc);
#
#
#         var popup_08cbf65ec51ed0a76a9901a3302a0372 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d46c371fbd21779ce8c4beabd048189 = $(`&lt;div id=&quot;html_8d46c371fbd21779ce8c4beabd048189&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_08cbf65ec51ed0a76a9901a3302a0372.setContent(html_8d46c371fbd21779ce8c4beabd048189);
#
#
#
#         marker_0d45bfb2ce3d12bf47207b38d0df2136.bindPopup(popup_08cbf65ec51ed0a76a9901a3302a0372)
#         ;
#
#
#
#
#             var marker_4860fb9278b6d013f9508cd3d485b8c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1cecef15f071238acffc892be1b1d0dc);
#
#
#         var popup_d3261ff021fd76eadd137a594304a5f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7079965e0d94cc6d5ae497387017a94d = $(`&lt;div id=&quot;html_7079965e0d94cc6d5ae497387017a94d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d3261ff021fd76eadd137a594304a5f8.setContent(html_7079965e0d94cc6d5ae497387017a94d);
#
#
#
#         marker_4860fb9278b6d013f9508cd3d485b8c8.bindPopup(popup_d3261ff021fd76eadd137a594304a5f8)
#         ;
#
#
#
#
#             var marker_365bc91be8440d94adb18a734f6c402a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1cecef15f071238acffc892be1b1d0dc);
#
#
#         var popup_07a605647c08bd8e1967646df0fdc3cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfae85d3b891d820cde2604cdec4f493 = $(`&lt;div id=&quot;html_dfae85d3b891d820cde2604cdec4f493&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_07a605647c08bd8e1967646df0fdc3cc.setContent(html_dfae85d3b891d820cde2604cdec4f493);
#
#
#
#         marker_365bc91be8440d94adb18a734f6c402a.bindPopup(popup_07a605647c08bd8e1967646df0fdc3cc)
#         ;
#
#
#
#
#             var marker_c8fd788c299a5d821cbcc0d5b09801c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1cecef15f071238acffc892be1b1d0dc);
#
#
#         var popup_1aac360a892f01fc10280e68043cdb2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6a32561a105251065df265a43b7ab22 = $(`&lt;div id=&quot;html_d6a32561a105251065df265a43b7ab22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1aac360a892f01fc10280e68043cdb2c.setContent(html_d6a32561a105251065df265a43b7ab22);
#
#
#
#         marker_c8fd788c299a5d821cbcc0d5b09801c6.bindPopup(popup_1aac360a892f01fc10280e68043cdb2c)
#         ;
#
#
#
#
#             var marker_c7d3ac29290c67b871eb7909da8269fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1cecef15f071238acffc892be1b1d0dc);
#
#
#         var popup_fd214dc676f41f94ec1942f06ae3266c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88401c4e735efe7d2dfb046419dc042f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88401c4e735efe7d2dfb046419dc042f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88401c4e735efe7d2dfb046419dc042f = L.map(
#                 &quot;map_88401c4e735efe7d2dfb046419dc042f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb178b9478bd05975778e8a5b42aedd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb178b9478bd05975778e8a5b42aedd8.addTo(map_88401c4e735efe7d2dfb046419dc042f);
#
#
#             var feature_group_8ea5c0ccceabf834a9318439bf9ca55d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8ea5c0ccceabf834a9318439bf9ca55d.addTo(map_88401c4e735efe7d2dfb046419dc042f);
#
#
#             var feature_group_sub_group_3ff420827d2aea69833358c31c6c9c5b = L.featureGroup.subGroup(
#                 feature_group_8ea5c0ccceabf834a9318439bf9ca55d
#             );
#
#
#             var marker_7c42689dde786df289ab206c73a49792 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ff420827d2aea69833358c31c6c9c5b);
#
#
#         var popup_e0b82be1ebc5a1f721fb99b9a3941ba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4daa05bc8b17caa8e332d2320856952 = $(`&lt;div id=&quot;html_f4daa05bc8b17caa8e332d2320856952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e0b82be1ebc5a1f721fb99b9a3941ba6.setContent(html_f4daa05bc8b17caa8e332d2320856952);
#
#
#
#         marker_7c42689dde786df289ab206c73a49792.bindPopup(popup_e0b82be1ebc5a1f721fb99b9a3941ba6)
#         ;
#
#
#
#
#             var marker_32dc990c81045259782ecfe4689fcc93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ff420827d2aea69833358c31c6c9c5b);
#
#
#         var popup_aba926fbcc74cc867387085cb98af06b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af4aff4b7a9b70db85d74a8af49a535a = $(`&lt;div id=&quot;html_af4aff4b7a9b70db85d74a8af49a535a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aba926fbcc74cc867387085cb98af06b.setContent(html_af4aff4b7a9b70db85d74a8af49a535a);
#
#
#
#         marker_32dc990c81045259782ecfe4689fcc93.bindPopup(popup_aba926fbcc74cc867387085cb98af06b)
#         ;
#
#
#
#
#             var marker_7d6fd1d47c50c8a639fe42413e3bc61f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ff420827d2aea69833358c31c6c9c5b);
#
#
#         var popup_d231a60216a9a1434a167df461b2b1de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c5672af5ad398d66bde38946ba19f47 = $(`&lt;div id=&quot;html_9c5672af5ad398d66bde38946ba19f47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d231a60216a9a1434a167df461b2b1de.setContent(html_9c5672af5ad398d66bde38946ba19f47);
#
#
#
#         marker_7d6fd1d47c50c8a639fe42413e3bc61f.bindPopup(popup_d231a60216a9a1434a167df461b2b1de)
#         ;
#
#
#
#
#             var marker_493c2509f18c5bf4221202c552d7de1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ff420827d2aea69833358c31c6c9c5b);
#
#
#         var popup_33c548495e18834d5b21982587ddb3f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcf3a0f9c8b3fae333c512819af14f59 = $(`&lt;div id=&quot;html_bcf3a0f9c8b3fae333c512819af14f59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_33c548495e18834d5b21982587ddb3f7.setContent(html_bcf3a0f9c8b3fae333c512819af14f59);
#
#
#
#         marker_
