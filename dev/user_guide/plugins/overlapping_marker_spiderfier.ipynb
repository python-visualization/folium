# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a121602711d17fa65ef8d185335cc443 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a121602711d17fa65ef8d185335cc443&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a121602711d17fa65ef8d185335cc443 = L.map(
#                 &quot;map_a121602711d17fa65ef8d185335cc443&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cafa01f0a0ed9ed32c348eaaf848802 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cafa01f0a0ed9ed32c348eaaf848802.addTo(map_a121602711d17fa65ef8d185335cc443);
#
#
#             var marker_bab6f5bb1a699f003865236129e2d742 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a121602711d17fa65ef8d185335cc443);
#
#
#         var popup_4a37e5be28d86a0099da1dfe42ab6d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dfb4852ebaf028394b1e6a921e9cde9 = $(`&lt;div id=&quot;html_2dfb4852ebaf028394b1e6a921e9cde9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4a37e5be28d86a0099da1dfe42ab6d6a.setContent(html_2dfb4852ebaf028394b1e6a921e9cde9);
#
#
#
#         marker_bab6f5bb1a699f003865236129e2d742.bindPopup(popup_4a37e5be28d86a0099da1dfe42ab6d6a)
#         ;
#
#
#
#
#             var marker_adcdfe9fc7216169e6e02d5b2acf7b15 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a121602711d17fa65ef8d185335cc443);
#
#
#         var popup_be106ea57e39e1270cd1c5377880dcba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eac9b7159a1bea8092970f1f81190585 = $(`&lt;div id=&quot;html_eac9b7159a1bea8092970f1f81190585&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_be106ea57e39e1270cd1c5377880dcba.setContent(html_eac9b7159a1bea8092970f1f81190585);
#
#
#
#         marker_adcdfe9fc7216169e6e02d5b2acf7b15.bindPopup(popup_be106ea57e39e1270cd1c5377880dcba)
#         ;
#
#
#
#
#             var marker_f0f7b689769611d40d79bbedc0822508 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a121602711d17fa65ef8d185335cc443);
#
#
#         var popup_b82870ca7caeded7807d4631b9ebb67d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cef7539f5b45a3be52f530c756410a46 = $(`&lt;div id=&quot;html_cef7539f5b45a3be52f530c756410a46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b82870ca7caeded7807d4631b9ebb67d.setContent(html_cef7539f5b45a3be52f530c756410a46);
#
#
#
#         marker_f0f7b689769611d40d79bbedc0822508.bindPopup(popup_b82870ca7caeded7807d4631b9ebb67d)
#         ;
#
#
#
#
#             var marker_07131884854d4a47f6d4d303385861d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a121602711d17fa65ef8d185335cc443);
#
#
#         var popup_02b2de08ea3e3179f2f366d73628fc13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e30435b2a08edb8f3b5803c1f58ab54 = $(`&lt;div id=&quot;html_7e30435b2a08edb8f3b5803c1f58ab54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_02b2de08ea3e3179f2f366d73628fc13.setContent(html_7e30435b2a08edb8f3b5803c1f58ab54);
#
#
#
#         marker_07131884854d4a47f6d4d303385861d5.bindPopup(popup_02b2de08ea3e3179f2f366d73628fc13)
#         ;
#
#
#
#
#             var marker_cff83e2ba2f9f6383ecb3cfc4770063d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a121602711d17fa65ef8d185335cc443);
#
#
#         var popup_3dbaae9d341ef2668fdc16fc08137334 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08db1df22d1dba4c8ce894810206416d = $(`&lt;div id=&quot;html_08db1df22d1dba4c8ce894810206416d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3dbaae9d341ef2668fdc16fc08137334.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b1350555a2bcd8276fe2f279fe9891d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b1350555a2bcd8276fe2f279fe9891d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b1350555a2bcd8276fe2f279fe9891d = L.map(
#                 &quot;map_2b1350555a2bcd8276fe2f279fe9891d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2231925c7ddd4d6ec81cc8c3e9ed1626 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2231925c7ddd4d6ec81cc8c3e9ed1626.addTo(map_2b1350555a2bcd8276fe2f279fe9891d);
#
#
#             var feature_group_42c24d1b87f61de6f5f00441f7daaca8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4996d0a286ff601c2e756779914d350a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_42c24d1b87f61de6f5f00441f7daaca8);
#
#
#         var popup_90492bac1249c4b48714811304a131fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa7845b8bf2abd048294a77d30b5f986 = $(`&lt;div id=&quot;html_fa7845b8bf2abd048294a77d30b5f986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_90492bac1249c4b48714811304a131fe.setContent(html_fa7845b8bf2abd048294a77d30b5f986);
#
#
#
#         marker_4996d0a286ff601c2e756779914d350a.bindPopup(popup_90492bac1249c4b48714811304a131fe)
#         ;
#
#
#
#
#             var marker_e21b2c49a627ef6c443cded5f5abdd01 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_42c24d1b87f61de6f5f00441f7daaca8);
#
#
#         var popup_c9291f03f2cb9ac48b79418c2fabbb41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b61e18785385ed982a2963f2addeba2 = $(`&lt;div id=&quot;html_1b61e18785385ed982a2963f2addeba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c9291f03f2cb9ac48b79418c2fabbb41.setContent(html_1b61e18785385ed982a2963f2addeba2);
#
#
#
#         marker_e21b2c49a627ef6c443cded5f5abdd01.bindPopup(popup_c9291f03f2cb9ac48b79418c2fabbb41)
#         ;
#
#
#
#
#             var marker_eb69f3eca4ce74959f84c7fa3582e41c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_42c24d1b87f61de6f5f00441f7daaca8);
#
#
#         var popup_71b7b646d361ca2f18ca4865833a5d87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6840c6024d1d94dfc51685f91144d61 = $(`&lt;div id=&quot;html_f6840c6024d1d94dfc51685f91144d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_71b7b646d361ca2f18ca4865833a5d87.setContent(html_f6840c6024d1d94dfc51685f91144d61);
#
#
#
#         marker_eb69f3eca4ce74959f84c7fa3582e41c.bindPopup(popup_71b7b646d361ca2f18ca4865833a5d87)
#         ;
#
#
#
#
#             var marker_688a40a92f3dbed471bf334e1159c2b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_42c24d1b87f61de6f5f00441f7daaca8);
#
#
#         var popup_4620caed5b9cc055c4b1837092b43e35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77b983525c825ee6bcd84029da2c3204 = $(`&lt;div id=&quot;html_77b983525c825ee6bcd84029da2c3204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4620caed5b9cc055c4b1837092b43e35.setContent(html_77b983525c825ee6bcd84029da2c3204);
#
#
#
#         marker_688a40a92f3dbed471bf334e1159c2b3.bindPopup(popup_4620caed5b9cc055c4b1837092b43e35)
#         ;
#
#
#
#
#             var marker_ff74f16cfec9afe0c63d51a16b8cfc7e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_42c24d1b87f61de6f5f00441f7daaca8);
#
#
#         var popup_147fef49c5b5538d923525a19230653e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8f86422ca6fcd280a33d1521720efa7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8f86422ca6fcd280a33d1521720efa7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8f86422ca6fcd280a33d1521720efa7 = L.map(
#                 &quot;map_b8f86422ca6fcd280a33d1521720efa7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0cba5c51450192a9d54ddbc78f9a943 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0cba5c51450192a9d54ddbc78f9a943.addTo(map_b8f86422ca6fcd280a33d1521720efa7);
#
#
#             var feature_group_352e563e3775836307ecc0e36c9dc9bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_352e563e3775836307ecc0e36c9dc9bf.addTo(map_b8f86422ca6fcd280a33d1521720efa7);
#
#
#             var feature_group_sub_group_680f663b8e03889f2323e5df038d0e1b = L.featureGroup.subGroup(
#                 feature_group_352e563e3775836307ecc0e36c9dc9bf
#             );
#
#
#             var marker_78b268704355df4845f0ba25a9125a76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_680f663b8e03889f2323e5df038d0e1b);
#
#
#         var popup_c6fb1588423568319546a3f1fe467648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2396a1b96aeb73e5dcce3f923e2f6d8b = $(`&lt;div id=&quot;html_2396a1b96aeb73e5dcce3f923e2f6d8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c6fb1588423568319546a3f1fe467648.setContent(html_2396a1b96aeb73e5dcce3f923e2f6d8b);
#
#
#
#         marker_78b268704355df4845f0ba25a9125a76.bindPopup(popup_c6fb1588423568319546a3f1fe467648)
#         ;
#
#
#
#
#             var marker_d29748e83b96e3772d7a2de8c49dbf1e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_680f663b8e03889f2323e5df038d0e1b);
#
#
#         var popup_1a1e71278346ba4a2c7f89c8f3ec1337 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e468a28f74da680c48d4a5ccec481f18 = $(`&lt;div id=&quot;html_e468a28f74da680c48d4a5ccec481f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1a1e71278346ba4a2c7f89c8f3ec1337.setContent(html_e468a28f74da680c48d4a5ccec481f18);
#
#
#
#         marker_d29748e83b96e3772d7a2de8c49dbf1e.bindPopup(popup_1a1e71278346ba4a2c7f89c8f3ec1337)
#         ;
#
#
#
#
#             var marker_6c080983dc3e51265fb7b9cf2effa196 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_680f663b8e03889f2323e5df038d0e1b);
#
#
#         var popup_3732e739c90679375cd55b3c1cf42890 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c10e0ad6cff35b68899d54fd724bf7a5 = $(`&lt;div id=&quot;html_c10e0ad6cff35b68899d54fd724bf7a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3732e739c90679375cd55b3c1cf42890.setContent(html_c10e0ad6cff35b68899d54fd724bf7a5);
#
#
#
#         marker_6c080983dc3e51265fb7b9cf2effa196.bindPopup(popup_3732e739c90679375cd55b3c1cf42890)
#         ;
#
#
#
#
#             var marker_7d2c608f5fe7c491e88f0808e7128a6b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_680f663b8e03889f2323e5df038d0e1b);
#
#
#         var popup_21c895fdb14458024abec386ff4a5d5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82f2f2956162c5bfcdd490b34e7ff19f = $(`&lt;div id=&quot;html_82f2f2956162c5bfcdd490b34e7ff19f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_21c895fdb14458024abec386ff4a5d5f.setContent(html_82f2f2956162c5bfcdd490b34e7ff19f);
#
#
#
#         marker_
