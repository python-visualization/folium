# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1aae36823d01201054937b492967cf9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1aae36823d01201054937b492967cf9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1aae36823d01201054937b492967cf9f = L.map(
#                 &quot;map_1aae36823d01201054937b492967cf9f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bc40a38ffdcb65c313f3c156a96ae88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8bc40a38ffdcb65c313f3c156a96ae88.addTo(map_1aae36823d01201054937b492967cf9f);
#
#
#             var marker_d61183f44f52e9a2915e178df1f40e55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1aae36823d01201054937b492967cf9f);
#
#
#         var popup_2bc34671405f0445b32fbaa808a894ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf93dcc58bfaeedd94869501523eef80 = $(`&lt;div id=&quot;html_bf93dcc58bfaeedd94869501523eef80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2bc34671405f0445b32fbaa808a894ba.setContent(html_bf93dcc58bfaeedd94869501523eef80);
#
#
#
#         marker_d61183f44f52e9a2915e178df1f40e55.bindPopup(popup_2bc34671405f0445b32fbaa808a894ba)
#         ;
#
#
#
#
#             var marker_67a30850a28837490c171462763d497b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1aae36823d01201054937b492967cf9f);
#
#
#         var popup_bf90b5f440fb6e849efa2c0190a76e04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c7385d3f25fec6a461f790f4ec3a7a3 = $(`&lt;div id=&quot;html_0c7385d3f25fec6a461f790f4ec3a7a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bf90b5f440fb6e849efa2c0190a76e04.setContent(html_0c7385d3f25fec6a461f790f4ec3a7a3);
#
#
#
#         marker_67a30850a28837490c171462763d497b.bindPopup(popup_bf90b5f440fb6e849efa2c0190a76e04)
#         ;
#
#
#
#
#             var marker_a08d87c419a4d0fa53603c1faba7a243 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1aae36823d01201054937b492967cf9f);
#
#
#         var popup_30148911ded448c2d18969ca0a70f081 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d084abef7f2a7b0f9d348bdf92e3c0b = $(`&lt;div id=&quot;html_8d084abef7f2a7b0f9d348bdf92e3c0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_30148911ded448c2d18969ca0a70f081.setContent(html_8d084abef7f2a7b0f9d348bdf92e3c0b);
#
#
#
#         marker_a08d87c419a4d0fa53603c1faba7a243.bindPopup(popup_30148911ded448c2d18969ca0a70f081)
#         ;
#
#
#
#
#             var marker_212b91849fbf694f99983657849f07b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1aae36823d01201054937b492967cf9f);
#
#
#         var popup_3126206d9104a92842db23281f06cc1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5a9d409d9e9432a88f5bf1a2faf9714 = $(`&lt;div id=&quot;html_f5a9d409d9e9432a88f5bf1a2faf9714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3126206d9104a92842db23281f06cc1b.setContent(html_f5a9d409d9e9432a88f5bf1a2faf9714);
#
#
#
#         marker_212b91849fbf694f99983657849f07b0.bindPopup(popup_3126206d9104a92842db23281f06cc1b)
#         ;
#
#
#
#
#             var marker_d3ac8111b07261779a21c08cd43181fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1aae36823d01201054937b492967cf9f);
#
#
#         var popup_63d9f635048216fbf59ab76c9308f0ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_537bd5866bc5eeffe80eae990f2e2da9 = $(`&lt;div id=&quot;html_537bd5866bc5eeffe80eae990f2e2da9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_63d9f635048216fbf59ab76c9308f0ed.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4498e9c08b633b6551c9be6955d38424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4498e9c08b633b6551c9be6955d38424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4498e9c08b633b6551c9be6955d38424 = L.map(
#                 &quot;map_4498e9c08b633b6551c9be6955d38424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75c8039e4768a0870c762dac6fb6ee99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75c8039e4768a0870c762dac6fb6ee99.addTo(map_4498e9c08b633b6551c9be6955d38424);
#
#
#             var feature_group_04f5920fcb1911e467c08f81a2994c72 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9eddaa1bdca1b538e6a43cc22676504b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_04f5920fcb1911e467c08f81a2994c72);
#
#
#         var popup_8b6e8320778de6bf4e10177ec302e55b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7d03c69f8f592bf84446a2f6681060d = $(`&lt;div id=&quot;html_f7d03c69f8f592bf84446a2f6681060d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8b6e8320778de6bf4e10177ec302e55b.setContent(html_f7d03c69f8f592bf84446a2f6681060d);
#
#
#
#         marker_9eddaa1bdca1b538e6a43cc22676504b.bindPopup(popup_8b6e8320778de6bf4e10177ec302e55b)
#         ;
#
#
#
#
#             var marker_3ac81e7b7833fe7c0740fa4e7d8ebea9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_04f5920fcb1911e467c08f81a2994c72);
#
#
#         var popup_52aa2350df37d9ea66e44a2d7b7fafb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7f90ea1f2f7773c1bd7a1a07683a7b8 = $(`&lt;div id=&quot;html_b7f90ea1f2f7773c1bd7a1a07683a7b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52aa2350df37d9ea66e44a2d7b7fafb0.setContent(html_b7f90ea1f2f7773c1bd7a1a07683a7b8);
#
#
#
#         marker_3ac81e7b7833fe7c0740fa4e7d8ebea9.bindPopup(popup_52aa2350df37d9ea66e44a2d7b7fafb0)
#         ;
#
#
#
#
#             var marker_3172466b1212c6060b449a2472fdab96 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_04f5920fcb1911e467c08f81a2994c72);
#
#
#         var popup_66b1ce2246d117948614c84e09fcbd97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_189ea35f7d3164b80b6b9e7aefbde353 = $(`&lt;div id=&quot;html_189ea35f7d3164b80b6b9e7aefbde353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_66b1ce2246d117948614c84e09fcbd97.setContent(html_189ea35f7d3164b80b6b9e7aefbde353);
#
#
#
#         marker_3172466b1212c6060b449a2472fdab96.bindPopup(popup_66b1ce2246d117948614c84e09fcbd97)
#         ;
#
#
#
#
#             var marker_7b870f91366df248a731e55afb32f74a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_04f5920fcb1911e467c08f81a2994c72);
#
#
#         var popup_251f909f532411abcf23cec42fef38d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7ea0ac93cf856652d476962db7adeda = $(`&lt;div id=&quot;html_c7ea0ac93cf856652d476962db7adeda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_251f909f532411abcf23cec42fef38d6.setContent(html_c7ea0ac93cf856652d476962db7adeda);
#
#
#
#         marker_7b870f91366df248a731e55afb32f74a.bindPopup(popup_251f909f532411abcf23cec42fef38d6)
#         ;
#
#
#
#
#             var marker_5c3edc61bb3a254482f50466ee78e649 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_04f5920fcb1911e467c08f81a2994c72);
#
#
#         var popup_1a91fc9badd1daad30043caededfa00d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f4375ddb00b480ca93c126d88238cc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f4375ddb00b480ca93c126d88238cc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f4375ddb00b480ca93c126d88238cc5 = L.map(
#                 &quot;map_2f4375ddb00b480ca93c126d88238cc5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a14bc8411ff2880af3f6040beac8061e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a14bc8411ff2880af3f6040beac8061e.addTo(map_2f4375ddb00b480ca93c126d88238cc5);
#
#
#             var feature_group_64d1b270cff4735987f539d70e3619a5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_64d1b270cff4735987f539d70e3619a5.addTo(map_2f4375ddb00b480ca93c126d88238cc5);
#
#
#             var feature_group_sub_group_2642b616bd9322392fd6089f589e9d4a = L.featureGroup.subGroup(
#                 feature_group_64d1b270cff4735987f539d70e3619a5
#             );
#
#
#             var marker_80a7df92f270e2fd39666b0ed8ac6287 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2642b616bd9322392fd6089f589e9d4a);
#
#
#         var popup_b590756c6c5ab688730a4291c4c91bd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4293dbd35304e00dbb25897fd990bd81 = $(`&lt;div id=&quot;html_4293dbd35304e00dbb25897fd990bd81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b590756c6c5ab688730a4291c4c91bd1.setContent(html_4293dbd35304e00dbb25897fd990bd81);
#
#
#
#         marker_80a7df92f270e2fd39666b0ed8ac6287.bindPopup(popup_b590756c6c5ab688730a4291c4c91bd1)
#         ;
#
#
#
#
#             var marker_e27714514bc2dd916f9e5e8472c413a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2642b616bd9322392fd6089f589e9d4a);
#
#
#         var popup_5785c216bf02c04fe4720151def38bf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68bba69b2a98efea25feb0e590a885bd = $(`&lt;div id=&quot;html_68bba69b2a98efea25feb0e590a885bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5785c216bf02c04fe4720151def38bf0.setContent(html_68bba69b2a98efea25feb0e590a885bd);
#
#
#
#         marker_e27714514bc2dd916f9e5e8472c413a6.bindPopup(popup_5785c216bf02c04fe4720151def38bf0)
#         ;
#
#
#
#
#             var marker_d41000c5beacd76d5c2c50f73602f7b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2642b616bd9322392fd6089f589e9d4a);
#
#
#         var popup_cce9fb125e8396f2445fc62864275d93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72f4e837a6164a60de42d0264213a8ee = $(`&lt;div id=&quot;html_72f4e837a6164a60de42d0264213a8ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cce9fb125e8396f2445fc62864275d93.setContent(html_72f4e837a6164a60de42d0264213a8ee);
#
#
#
#         marker_d41000c5beacd76d5c2c50f73602f7b7.bindPopup(popup_cce9fb125e8396f2445fc62864275d93)
#         ;
#
#
#
#
#             var marker_b4b4a470f0698c93e95fb1a3870b2854 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2642b616bd9322392fd6089f589e9d4a);
#
#
#         var popup_fc2185d2b654fa4ec3f3ba1b9ace1bea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3806feb6279b4d180b4b01e6a3064e3 = $(`&lt;div id=&quot;html_f3806feb6279b4d180b4b01e6a3064e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fc2185d2b654fa4ec3f3ba1b9ace1bea.setContent(html_f3806feb6279b4d180b4b01e6a3064e3);
#
#
#
#         marker_
