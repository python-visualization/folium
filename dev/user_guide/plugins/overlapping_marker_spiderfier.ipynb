# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3be4c0efee64c6853894c93323cc110 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3be4c0efee64c6853894c93323cc110&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3be4c0efee64c6853894c93323cc110 = L.map(
#                 &quot;map_e3be4c0efee64c6853894c93323cc110&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b1b5f7a42d592979e9e438dbc131953 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b1b5f7a42d592979e9e438dbc131953.addTo(map_e3be4c0efee64c6853894c93323cc110);
#
#
#             var marker_de94f57007db81f79da0fe78f5d0e932 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e3be4c0efee64c6853894c93323cc110);
#
#
#         var popup_bf6bb8104b22f286e3373a4742835fad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2a67eeba71c5227e480fb9bc759deed = $(`&lt;div id=&quot;html_f2a67eeba71c5227e480fb9bc759deed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bf6bb8104b22f286e3373a4742835fad.setContent(html_f2a67eeba71c5227e480fb9bc759deed);
#
#
#
#         marker_de94f57007db81f79da0fe78f5d0e932.bindPopup(popup_bf6bb8104b22f286e3373a4742835fad)
#         ;
#
#
#
#
#             var marker_f618f836c972c719593f16461e929799 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e3be4c0efee64c6853894c93323cc110);
#
#
#         var popup_fb288d1fb43c03caf22df84cd8250f3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5843e7e9ec7e4d9a49fab46dc8073d97 = $(`&lt;div id=&quot;html_5843e7e9ec7e4d9a49fab46dc8073d97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fb288d1fb43c03caf22df84cd8250f3e.setContent(html_5843e7e9ec7e4d9a49fab46dc8073d97);
#
#
#
#         marker_f618f836c972c719593f16461e929799.bindPopup(popup_fb288d1fb43c03caf22df84cd8250f3e)
#         ;
#
#
#
#
#             var marker_3826b8c3cedaed6eae63487b0822857c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e3be4c0efee64c6853894c93323cc110);
#
#
#         var popup_8e443b9412ddeeb0483745fe525dd52d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e2a8b09a164b8865020d1fba30e76a1 = $(`&lt;div id=&quot;html_2e2a8b09a164b8865020d1fba30e76a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8e443b9412ddeeb0483745fe525dd52d.setContent(html_2e2a8b09a164b8865020d1fba30e76a1);
#
#
#
#         marker_3826b8c3cedaed6eae63487b0822857c.bindPopup(popup_8e443b9412ddeeb0483745fe525dd52d)
#         ;
#
#
#
#
#             var marker_d13a186958980118ebad75d778b0a5c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e3be4c0efee64c6853894c93323cc110);
#
#
#         var popup_f2ac2cb88137a8fcabb0e825c6bbf459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8e4a76e3c21895fc9adbbf0e7e98865 = $(`&lt;div id=&quot;html_e8e4a76e3c21895fc9adbbf0e7e98865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f2ac2cb88137a8fcabb0e825c6bbf459.setContent(html_e8e4a76e3c21895fc9adbbf0e7e98865);
#
#
#
#         marker_d13a186958980118ebad75d778b0a5c5.bindPopup(popup_f2ac2cb88137a8fcabb0e825c6bbf459)
#         ;
#
#
#
#
#             var marker_ce78de0b25a5b47bb5a55d7ff9d45ba2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e3be4c0efee64c6853894c93323cc110);
#
#
#         var popup_6c4491e61656850fb5725b461f2a14a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f49a35b38e99f7e767918bc6880a2f31 = $(`&lt;div id=&quot;html_f49a35b38e99f7e767918bc6880a2f31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6c4491e61656850fb5725b461f2a14a2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06d1545d9414c78d1a3e88733b1316b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06d1545d9414c78d1a3e88733b1316b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06d1545d9414c78d1a3e88733b1316b6 = L.map(
#                 &quot;map_06d1545d9414c78d1a3e88733b1316b6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_663eff44a7760d355061ab06cf87e72e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_663eff44a7760d355061ab06cf87e72e.addTo(map_06d1545d9414c78d1a3e88733b1316b6);
#
#
#             var feature_group_6798e33057a94431256b155990f2a959 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c9d3576a5bbda4395e4817b9dffe7326 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6798e33057a94431256b155990f2a959);
#
#
#         var popup_f1e4cbf1e15827e4fe470c840f461e87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_553326d42c80f5cda1d70306c2876ff1 = $(`&lt;div id=&quot;html_553326d42c80f5cda1d70306c2876ff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f1e4cbf1e15827e4fe470c840f461e87.setContent(html_553326d42c80f5cda1d70306c2876ff1);
#
#
#
#         marker_c9d3576a5bbda4395e4817b9dffe7326.bindPopup(popup_f1e4cbf1e15827e4fe470c840f461e87)
#         ;
#
#
#
#
#             var marker_7158b7c10811cf450dd740919fc92a6f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6798e33057a94431256b155990f2a959);
#
#
#         var popup_0d6402cafd0fd9a8f53c31ca1d429a36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9c98ee09a0d1557b7e15823ec46af91 = $(`&lt;div id=&quot;html_a9c98ee09a0d1557b7e15823ec46af91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0d6402cafd0fd9a8f53c31ca1d429a36.setContent(html_a9c98ee09a0d1557b7e15823ec46af91);
#
#
#
#         marker_7158b7c10811cf450dd740919fc92a6f.bindPopup(popup_0d6402cafd0fd9a8f53c31ca1d429a36)
#         ;
#
#
#
#
#             var marker_4af96496842c250952644ea9ac36347f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6798e33057a94431256b155990f2a959);
#
#
#         var popup_847e45b0c2407147c21e997e195ce199 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_192c5cdb2a453b1f637bbfaa8e87fbc6 = $(`&lt;div id=&quot;html_192c5cdb2a453b1f637bbfaa8e87fbc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_847e45b0c2407147c21e997e195ce199.setContent(html_192c5cdb2a453b1f637bbfaa8e87fbc6);
#
#
#
#         marker_4af96496842c250952644ea9ac36347f.bindPopup(popup_847e45b0c2407147c21e997e195ce199)
#         ;
#
#
#
#
#             var marker_d60bb56b193fcdcb20d680bf79e3c497 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6798e33057a94431256b155990f2a959);
#
#
#         var popup_970e28537fb7898d9ca94851d2521cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04dea75142fd28ccf673faff3c6b5bf1 = $(`&lt;div id=&quot;html_04dea75142fd28ccf673faff3c6b5bf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_970e28537fb7898d9ca94851d2521cbf.setContent(html_04dea75142fd28ccf673faff3c6b5bf1);
#
#
#
#         marker_d60bb56b193fcdcb20d680bf79e3c497.bindPopup(popup_970e28537fb7898d9ca94851d2521cbf)
#         ;
#
#
#
#
#             var marker_130277c464890c5386e5a666124c3989 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6798e33057a94431256b155990f2a959);
#
#
#         var popup_a7cf8755c729906784a65d8994ab800d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77da9f312f8e5a9365971f4acdec5576 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77da9f312f8e5a9365971f4acdec5576&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77da9f312f8e5a9365971f4acdec5576 = L.map(
#                 &quot;map_77da9f312f8e5a9365971f4acdec5576&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2cd62600ad86ec3a4b115a0bd00940a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2cd62600ad86ec3a4b115a0bd00940a.addTo(map_77da9f312f8e5a9365971f4acdec5576);
#
#
#             var feature_group_b7338c1aeac29f0b8497dcfb13511b24 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b7338c1aeac29f0b8497dcfb13511b24.addTo(map_77da9f312f8e5a9365971f4acdec5576);
#
#
#             var feature_group_sub_group_54125056bac40cce92eb4ac69a6eda2f = L.featureGroup.subGroup(
#                 feature_group_b7338c1aeac29f0b8497dcfb13511b24
#             );
#
#
#             var marker_c8084844e44828517477681dbe9d63e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_54125056bac40cce92eb4ac69a6eda2f);
#
#
#         var popup_56cd9c20252a94b59a31c07a3fb83ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d3373d862df388a4386f21ac825eb31 = $(`&lt;div id=&quot;html_4d3373d862df388a4386f21ac825eb31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_56cd9c20252a94b59a31c07a3fb83ac1.setContent(html_4d3373d862df388a4386f21ac825eb31);
#
#
#
#         marker_c8084844e44828517477681dbe9d63e2.bindPopup(popup_56cd9c20252a94b59a31c07a3fb83ac1)
#         ;
#
#
#
#
#             var marker_e54ac8bd809c6b4e913863c90be789f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_54125056bac40cce92eb4ac69a6eda2f);
#
#
#         var popup_d722da4f5d37474bc6ee630cadf431e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b6fc6f80fac5703d5f6e57dcdd46b8b = $(`&lt;div id=&quot;html_4b6fc6f80fac5703d5f6e57dcdd46b8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d722da4f5d37474bc6ee630cadf431e7.setContent(html_4b6fc6f80fac5703d5f6e57dcdd46b8b);
#
#
#
#         marker_e54ac8bd809c6b4e913863c90be789f4.bindPopup(popup_d722da4f5d37474bc6ee630cadf431e7)
#         ;
#
#
#
#
#             var marker_0ea428361ec9a8042cac47c9028bd0ba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_54125056bac40cce92eb4ac69a6eda2f);
#
#
#         var popup_6da977bd66f660f2505f426392faab25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2708b82a7330dd28e5740f36360353f = $(`&lt;div id=&quot;html_d2708b82a7330dd28e5740f36360353f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6da977bd66f660f2505f426392faab25.setContent(html_d2708b82a7330dd28e5740f36360353f);
#
#
#
#         marker_0ea428361ec9a8042cac47c9028bd0ba.bindPopup(popup_6da977bd66f660f2505f426392faab25)
#         ;
#
#
#
#
#             var marker_f4b554dcfbe7e60259513bbb06e2f75b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_54125056bac40cce92eb4ac69a6eda2f);
#
#
#         var popup_3f3af368ab768637bb5b4683c7b23802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03fce823dea1d7b174db0d20202fbed6 = $(`&lt;div id=&quot;html_03fce823dea1d7b174db0d20202fbed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3f3af368ab768637bb5b4683c7b23802.setContent(html_03fce823dea1d7b174db0d20202fbed6);
#
#
#
#         marker_
