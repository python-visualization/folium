# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9800cd0fca96c026bf140b8308be2517 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9800cd0fca96c026bf140b8308be2517&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9800cd0fca96c026bf140b8308be2517 = L.map(
#                 &quot;map_9800cd0fca96c026bf140b8308be2517&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a847beccbc8d3c1810d335c70295e9cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a847beccbc8d3c1810d335c70295e9cb.addTo(map_9800cd0fca96c026bf140b8308be2517);
#
#
#             var marker_d82afa86bbb404f30889e6af970c25f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9800cd0fca96c026bf140b8308be2517);
#
#
#         var popup_504d8c760bbd51915ba43afceda362bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5ef071c44e8dfa211783a0c03ae250 = $(`&lt;div id=&quot;html_4a5ef071c44e8dfa211783a0c03ae250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_504d8c760bbd51915ba43afceda362bd.setContent(html_4a5ef071c44e8dfa211783a0c03ae250);
#
#
#
#         marker_d82afa86bbb404f30889e6af970c25f8.bindPopup(popup_504d8c760bbd51915ba43afceda362bd)
#         ;
#
#
#
#
#             var marker_eb99dc41159c325f20bd5b79241511de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9800cd0fca96c026bf140b8308be2517);
#
#
#         var popup_1e5f4f18bf95cb76dd9843c454cdc47a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89a64ade2bd6eff977dc90240d670648 = $(`&lt;div id=&quot;html_89a64ade2bd6eff977dc90240d670648&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e5f4f18bf95cb76dd9843c454cdc47a.setContent(html_89a64ade2bd6eff977dc90240d670648);
#
#
#
#         marker_eb99dc41159c325f20bd5b79241511de.bindPopup(popup_1e5f4f18bf95cb76dd9843c454cdc47a)
#         ;
#
#
#
#
#             var marker_a25a074a75638968beaa6cbcef8adee5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9800cd0fca96c026bf140b8308be2517);
#
#
#         var popup_ab5939b1de37dc0a79f9f2d432827eb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab5050ed7ad9a9eae7a0fcb5bf43d273 = $(`&lt;div id=&quot;html_ab5050ed7ad9a9eae7a0fcb5bf43d273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ab5939b1de37dc0a79f9f2d432827eb8.setContent(html_ab5050ed7ad9a9eae7a0fcb5bf43d273);
#
#
#
#         marker_a25a074a75638968beaa6cbcef8adee5.bindPopup(popup_ab5939b1de37dc0a79f9f2d432827eb8)
#         ;
#
#
#
#
#             var marker_62ba93ee05d2ccf3a71866e28e9157b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9800cd0fca96c026bf140b8308be2517);
#
#
#         var popup_f4fb841c355587841208031e3b86d833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33f0a3e8c9c22013fae26fd23e4bee1a = $(`&lt;div id=&quot;html_33f0a3e8c9c22013fae26fd23e4bee1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f4fb841c355587841208031e3b86d833.setContent(html_33f0a3e8c9c22013fae26fd23e4bee1a);
#
#
#
#         marker_62ba93ee05d2ccf3a71866e28e9157b4.bindPopup(popup_f4fb841c355587841208031e3b86d833)
#         ;
#
#
#
#
#             var marker_e656b0d38bfe5115a3caa123cda46547 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9800cd0fca96c026bf140b8308be2517);
#
#
#         var popup_fe00cbc751ea2b5ef4794bfd148c2bf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca5d78ed15ff8184d29ba0b3a92cd085 = $(`&lt;div id=&quot;html_ca5d78ed15ff8184d29ba0b3a92cd085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fe00cbc751ea2b5ef4794bfd148c2b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72ea3aa9cd3db01c9cea97b76cc1dbb4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72ea3aa9cd3db01c9cea97b76cc1dbb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72ea3aa9cd3db01c9cea97b76cc1dbb4 = L.map(
#                 &quot;map_72ea3aa9cd3db01c9cea97b76cc1dbb4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e461e680cb2d88111d4fbedc94fdc20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e461e680cb2d88111d4fbedc94fdc20.addTo(map_72ea3aa9cd3db01c9cea97b76cc1dbb4);
#
#
#             var feature_group_1d4d271a28a50feac1106456ab9a85bc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6fbc5fb74ddeec03d62ee501b074becf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1d4d271a28a50feac1106456ab9a85bc);
#
#
#         var popup_78ee1615b58e3294fe535612acd292a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7f53c0a4930f4582c4bb8cd644b0f8b = $(`&lt;div id=&quot;html_f7f53c0a4930f4582c4bb8cd644b0f8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_78ee1615b58e3294fe535612acd292a8.setContent(html_f7f53c0a4930f4582c4bb8cd644b0f8b);
#
#
#
#         marker_6fbc5fb74ddeec03d62ee501b074becf.bindPopup(popup_78ee1615b58e3294fe535612acd292a8)
#         ;
#
#
#
#
#             var marker_ad8fef70cb284b3232137c93e77d9b80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1d4d271a28a50feac1106456ab9a85bc);
#
#
#         var popup_16a82196fdb22519b4277ac527ce6e21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95fd34e964029a3292054a35fd227d2b = $(`&lt;div id=&quot;html_95fd34e964029a3292054a35fd227d2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_16a82196fdb22519b4277ac527ce6e21.setContent(html_95fd34e964029a3292054a35fd227d2b);
#
#
#
#         marker_ad8fef70cb284b3232137c93e77d9b80.bindPopup(popup_16a82196fdb22519b4277ac527ce6e21)
#         ;
#
#
#
#
#             var marker_13afeb1bc57de64c1c9bafb3b2ef00de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1d4d271a28a50feac1106456ab9a85bc);
#
#
#         var popup_7877c802cf83685c32d76a5f617b220b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5f24a03324c3098c9b2c61fa68491fb = $(`&lt;div id=&quot;html_f5f24a03324c3098c9b2c61fa68491fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7877c802cf83685c32d76a5f617b220b.setContent(html_f5f24a03324c3098c9b2c61fa68491fb);
#
#
#
#         marker_13afeb1bc57de64c1c9bafb3b2ef00de.bindPopup(popup_7877c802cf83685c32d76a5f617b220b)
#         ;
#
#
#
#
#             var marker_622faafd4472a58c46254ead8089109f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1d4d271a28a50feac1106456ab9a85bc);
#
#
#         var popup_4068479c9ccaec2f049d90ff72e894cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cd0d477ef0aa52c9d7fb5c6e06c12be = $(`&lt;div id=&quot;html_6cd0d477ef0aa52c9d7fb5c6e06c12be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4068479c9ccaec2f049d90ff72e894cc.setContent(html_6cd0d477ef0aa52c9d7fb5c6e06c12be);
#
#
#
#         marker_622faafd4472a58c46254ead8089109f.bindPopup(popup_4068479c9ccaec2f049d90ff72e894cc)
#         ;
#
#
#
#
#             var marker_f249c6b5485b171c72ce6b2b9fa13ed4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1d4d271a28a50feac1106456ab9a85bc);
#
#
#         var popup_013c0d2030d1f8c7df08238acd416c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f965dd5ebe11f703171827486b9ede57 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f965dd5ebe11f703171827486b9ede57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f965dd5ebe11f703171827486b9ede57 = L.map(
#                 &quot;map_f965dd5ebe11f703171827486b9ede57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32bceb99253702570c23cecaf309a194 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32bceb99253702570c23cecaf309a194.addTo(map_f965dd5ebe11f703171827486b9ede57);
#
#
#             var feature_group_0b03c24e08907b1f8218834412726375 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0b03c24e08907b1f8218834412726375.addTo(map_f965dd5ebe11f703171827486b9ede57);
#
#
#             var feature_group_sub_group_a93f23c57aa5d11da6c66562b66b8ef3 = L.featureGroup.subGroup(
#                 feature_group_0b03c24e08907b1f8218834412726375
#             );
#
#
#             var marker_38ec97285a3fca6c4e3687a5120d1744 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a93f23c57aa5d11da6c66562b66b8ef3);
#
#
#         var popup_d87b73fd804f556751a940599f5f7355 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55cc73a0f784b407ba0485e5d810a437 = $(`&lt;div id=&quot;html_55cc73a0f784b407ba0485e5d810a437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d87b73fd804f556751a940599f5f7355.setContent(html_55cc73a0f784b407ba0485e5d810a437);
#
#
#
#         marker_38ec97285a3fca6c4e3687a5120d1744.bindPopup(popup_d87b73fd804f556751a940599f5f7355)
#         ;
#
#
#
#
#             var marker_f7e7daee021210c8d7f461ccc14b5108 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a93f23c57aa5d11da6c66562b66b8ef3);
#
#
#         var popup_7e50a749e1cc05478a5202bacfc44b39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c68031adccd41ec587c84723e7e3d262 = $(`&lt;div id=&quot;html_c68031adccd41ec587c84723e7e3d262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7e50a749e1cc05478a5202bacfc44b39.setContent(html_c68031adccd41ec587c84723e7e3d262);
#
#
#
#         marker_f7e7daee021210c8d7f461ccc14b5108.bindPopup(popup_7e50a749e1cc05478a5202bacfc44b39)
#         ;
#
#
#
#
#             var marker_64cc293bddf0e050beccce064d59687b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a93f23c57aa5d11da6c66562b66b8ef3);
#
#
#         var popup_8e2c429ad75a1af204dd20c1915ce1f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5e113b2dacace5afc88f199ed53c9eb = $(`&lt;div id=&quot;html_f5e113b2dacace5afc88f199ed53c9eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8e2c429ad75a1af204dd20c1915ce1f5.setContent(html_f5e113b2dacace5afc88f199ed53c9eb);
#
#
#
#         marker_64cc293bddf0e050beccce064d59687b.bindPopup(popup_8e2c429ad75a1af204dd20c1915ce1f5)
#         ;
#
#
#
#
#             var marker_457018bdc5cd1db0c8ca5dbc682bdc48 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a93f23c57aa5d11da6c66562b66b8ef3);
#
#
#         var popup_b9b56d8529bf5d20e2de7a227509e33a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20db23dfad2b0c51843ce3bb81c17738 = $(`&lt;div id=&quot;html_20db23dfad2b0c51843ce3bb81c17738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b9b56d8529bf5d20e2de7a227509e33a.setContent(html_20db23dfad2b0c51843ce3bb81c17738);
#
#
#
#         mark
