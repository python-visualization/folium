# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_290abbb0e59fd6b56bd8aee6459d774c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_290abbb0e59fd6b56bd8aee6459d774c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_290abbb0e59fd6b56bd8aee6459d774c = L.map(
#                 &quot;map_290abbb0e59fd6b56bd8aee6459d774c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11e5bc2e8be7e3f9397f1e5512a1f365 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11e5bc2e8be7e3f9397f1e5512a1f365.addTo(map_290abbb0e59fd6b56bd8aee6459d774c);
#
#
#             var marker_4bd1b984bcfa8e61103a4cbed37c76f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_290abbb0e59fd6b56bd8aee6459d774c);
#
#
#         var popup_556b7eef9e8e5c5f9de6385a1c6c0a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ea6cf0ae1eeaec4fcea487729fb6af0 = $(`&lt;div id=&quot;html_2ea6cf0ae1eeaec4fcea487729fb6af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_556b7eef9e8e5c5f9de6385a1c6c0a62.setContent(html_2ea6cf0ae1eeaec4fcea487729fb6af0);
#
#
#
#         marker_4bd1b984bcfa8e61103a4cbed37c76f7.bindPopup(popup_556b7eef9e8e5c5f9de6385a1c6c0a62)
#         ;
#
#
#
#
#             var marker_a934bd7969e1966dbe739cc365310e75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_290abbb0e59fd6b56bd8aee6459d774c);
#
#
#         var popup_1720f037e14eebedbaad21ee6e3dabaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a759416957810d04b0d26630782cde2d = $(`&lt;div id=&quot;html_a759416957810d04b0d26630782cde2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1720f037e14eebedbaad21ee6e3dabaa.setContent(html_a759416957810d04b0d26630782cde2d);
#
#
#
#         marker_a934bd7969e1966dbe739cc365310e75.bindPopup(popup_1720f037e14eebedbaad21ee6e3dabaa)
#         ;
#
#
#
#
#             var marker_ed6c39a3a2d8d8b944fd99492a089291 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_290abbb0e59fd6b56bd8aee6459d774c);
#
#
#         var popup_8ae219c63a631706053d3c9a5f74e1bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b744401ea203a48e29a66a517ceed93a = $(`&lt;div id=&quot;html_b744401ea203a48e29a66a517ceed93a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ae219c63a631706053d3c9a5f74e1bb.setContent(html_b744401ea203a48e29a66a517ceed93a);
#
#
#
#         marker_ed6c39a3a2d8d8b944fd99492a089291.bindPopup(popup_8ae219c63a631706053d3c9a5f74e1bb)
#         ;
#
#
#
#
#             var marker_36ad1d4188cef648393b2e5119a310bd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_290abbb0e59fd6b56bd8aee6459d774c);
#
#
#         var popup_fdee42a727720de78cb5be6dcacea411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7acb58a7d6a900c6d339845db94a3f53 = $(`&lt;div id=&quot;html_7acb58a7d6a900c6d339845db94a3f53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fdee42a727720de78cb5be6dcacea411.setContent(html_7acb58a7d6a900c6d339845db94a3f53);
#
#
#
#         marker_36ad1d4188cef648393b2e5119a310bd.bindPopup(popup_fdee42a727720de78cb5be6dcacea411)
#         ;
#
#
#
#
#             var marker_11fd87c1373cecdf266213e977c9c4ca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_290abbb0e59fd6b56bd8aee6459d774c);
#
#
#         var popup_29ad69b441da431696a5b44395d47336 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2075efc51c7ddd04ff5080304e847d70 = $(`&lt;div id=&quot;html_2075efc51c7ddd04ff5080304e847d70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_29ad69b441da431696a5b44395d47336.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3eb20a5d4779a9572de45fad13755b10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3eb20a5d4779a9572de45fad13755b10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3eb20a5d4779a9572de45fad13755b10 = L.map(
#                 &quot;map_3eb20a5d4779a9572de45fad13755b10&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae5d6ede08a334949febfceabc18a4fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae5d6ede08a334949febfceabc18a4fc.addTo(map_3eb20a5d4779a9572de45fad13755b10);
#
#
#             var feature_group_08ef15a03f87290b8b3f338eb974c2b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9bbc653b2be53683866aef8c118a09f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_08ef15a03f87290b8b3f338eb974c2b1);
#
#
#         var popup_11096fc77eb7c7d76a8f3ae91235ca5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a474d86c5a904a792a604ab1d1fc755e = $(`&lt;div id=&quot;html_a474d86c5a904a792a604ab1d1fc755e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_11096fc77eb7c7d76a8f3ae91235ca5e.setContent(html_a474d86c5a904a792a604ab1d1fc755e);
#
#
#
#         marker_9bbc653b2be53683866aef8c118a09f8.bindPopup(popup_11096fc77eb7c7d76a8f3ae91235ca5e)
#         ;
#
#
#
#
#             var marker_a75b7431d51fab56331cf9d2491681bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_08ef15a03f87290b8b3f338eb974c2b1);
#
#
#         var popup_5e53f9c59cda7e9fd7d7743b9ba8315d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99a36a843ea163a1cfba916bbedf5018 = $(`&lt;div id=&quot;html_99a36a843ea163a1cfba916bbedf5018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5e53f9c59cda7e9fd7d7743b9ba8315d.setContent(html_99a36a843ea163a1cfba916bbedf5018);
#
#
#
#         marker_a75b7431d51fab56331cf9d2491681bd.bindPopup(popup_5e53f9c59cda7e9fd7d7743b9ba8315d)
#         ;
#
#
#
#
#             var marker_8f8f8ac94909d67f9cac487eb0709a01 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_08ef15a03f87290b8b3f338eb974c2b1);
#
#
#         var popup_67df927f56eb1600a557c7cadead7cec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c1ad0d87b3ab69f13236780878f301 = $(`&lt;div id=&quot;html_50c1ad0d87b3ab69f13236780878f301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_67df927f56eb1600a557c7cadead7cec.setContent(html_50c1ad0d87b3ab69f13236780878f301);
#
#
#
#         marker_8f8f8ac94909d67f9cac487eb0709a01.bindPopup(popup_67df927f56eb1600a557c7cadead7cec)
#         ;
#
#
#
#
#             var marker_d1ffc49482b9387fde02aba1e2d36168 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_08ef15a03f87290b8b3f338eb974c2b1);
#
#
#         var popup_dbd1051be908389b1b719ffbe7df048c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db75efa308cc2201d7edf6ee845d6743 = $(`&lt;div id=&quot;html_db75efa308cc2201d7edf6ee845d6743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dbd1051be908389b1b719ffbe7df048c.setContent(html_db75efa308cc2201d7edf6ee845d6743);
#
#
#
#         marker_d1ffc49482b9387fde02aba1e2d36168.bindPopup(popup_dbd1051be908389b1b719ffbe7df048c)
#         ;
#
#
#
#
#             var marker_377951404ab0baf624934a872d4e4881 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_08ef15a03f87290b8b3f338eb974c2b1);
#
#
#         var popup_7fed987fdf1cb20889312012a98f8d07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bb4c5fdcf7d5099f94d39e42ee1ec7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bb4c5fdcf7d5099f94d39e42ee1ec7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bb4c5fdcf7d5099f94d39e42ee1ec7c = L.map(
#                 &quot;map_5bb4c5fdcf7d5099f94d39e42ee1ec7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e3b004e70f1ed7c542258de59b7d71c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e3b004e70f1ed7c542258de59b7d71c.addTo(map_5bb4c5fdcf7d5099f94d39e42ee1ec7c);
#
#
#             var feature_group_9836fc04bfa3748a9959be7fe97ff718 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9836fc04bfa3748a9959be7fe97ff718.addTo(map_5bb4c5fdcf7d5099f94d39e42ee1ec7c);
#
#
#             var feature_group_sub_group_3bd855cafd5cd985775db3b6f83d904a = L.featureGroup.subGroup(
#                 feature_group_9836fc04bfa3748a9959be7fe97ff718
#             );
#
#
#             var marker_8a530813c8791b2b31f8fcdd5f97a546 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bd855cafd5cd985775db3b6f83d904a);
#
#
#         var popup_cb5b6b614ed4809d7f2bf32a59f99a42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea4be452c242c5ca53649259c72178c8 = $(`&lt;div id=&quot;html_ea4be452c242c5ca53649259c72178c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb5b6b614ed4809d7f2bf32a59f99a42.setContent(html_ea4be452c242c5ca53649259c72178c8);
#
#
#
#         marker_8a530813c8791b2b31f8fcdd5f97a546.bindPopup(popup_cb5b6b614ed4809d7f2bf32a59f99a42)
#         ;
#
#
#
#
#             var marker_707d133263a1f54f69afcf5c91c3add6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bd855cafd5cd985775db3b6f83d904a);
#
#
#         var popup_49b0870c36584432b0f0046e681538e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e5c01690f34b421600bd71585ac849a = $(`&lt;div id=&quot;html_0e5c01690f34b421600bd71585ac849a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_49b0870c36584432b0f0046e681538e9.setContent(html_0e5c01690f34b421600bd71585ac849a);
#
#
#
#         marker_707d133263a1f54f69afcf5c91c3add6.bindPopup(popup_49b0870c36584432b0f0046e681538e9)
#         ;
#
#
#
#
#             var marker_1b12d33a52bcd0b6ca933a9edbc28ad6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bd855cafd5cd985775db3b6f83d904a);
#
#
#         var popup_04703139824a038a5d3afddb8d265984 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_426bd1469d374d34e292cf1c3bd31fb4 = $(`&lt;div id=&quot;html_426bd1469d374d34e292cf1c3bd31fb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_04703139824a038a5d3afddb8d265984.setContent(html_426bd1469d374d34e292cf1c3bd31fb4);
#
#
#
#         marker_1b12d33a52bcd0b6ca933a9edbc28ad6.bindPopup(popup_04703139824a038a5d3afddb8d265984)
#         ;
#
#
#
#
#             var marker_3d506df8edd5b43e7f639efc871a0b67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bd855cafd5cd985775db3b6f83d904a);
#
#
#         var popup_1977b45681d09e9fc0baf601c5c99be0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_614973087b15b994eb7a07e660f91903 = $(`&lt;div id=&quot;html_614973087b15b994eb7a07e660f91903&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1977b45681d09e9fc0baf601c5c99be0.setContent(html_614973087b15b994eb7a07e660f91903);
#
#
#
#         marker_
