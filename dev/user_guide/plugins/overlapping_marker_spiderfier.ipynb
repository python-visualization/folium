# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f1b2eb4c9879cf1a68e92aad5caf97d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f1b2eb4c9879cf1a68e92aad5caf97d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f1b2eb4c9879cf1a68e92aad5caf97d = L.map(
#                 &quot;map_9f1b2eb4c9879cf1a68e92aad5caf97d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e413e1db1939d7b78ca263f39c20ce0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e413e1db1939d7b78ca263f39c20ce0.addTo(map_9f1b2eb4c9879cf1a68e92aad5caf97d);
#
#
#             var marker_5cf1a8280f15a48a18bb7f810f6144a4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9f1b2eb4c9879cf1a68e92aad5caf97d);
#
#
#         var popup_3c01043fe2cdbbd738f9cd872915ca29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f70cba0415c00e3f8880a4848b3a39e6 = $(`&lt;div id=&quot;html_f70cba0415c00e3f8880a4848b3a39e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c01043fe2cdbbd738f9cd872915ca29.setContent(html_f70cba0415c00e3f8880a4848b3a39e6);
#
#
#
#         marker_5cf1a8280f15a48a18bb7f810f6144a4.bindPopup(popup_3c01043fe2cdbbd738f9cd872915ca29)
#         ;
#
#
#
#
#             var marker_584d55f938e900d4bc966d11681ace6e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9f1b2eb4c9879cf1a68e92aad5caf97d);
#
#
#         var popup_02371925151c68e5cb1e83ef279d3132 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d75b95216ed3689031f90526f15495c4 = $(`&lt;div id=&quot;html_d75b95216ed3689031f90526f15495c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_02371925151c68e5cb1e83ef279d3132.setContent(html_d75b95216ed3689031f90526f15495c4);
#
#
#
#         marker_584d55f938e900d4bc966d11681ace6e.bindPopup(popup_02371925151c68e5cb1e83ef279d3132)
#         ;
#
#
#
#
#             var marker_83121985b3c9f6244478db3a5aff28ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9f1b2eb4c9879cf1a68e92aad5caf97d);
#
#
#         var popup_e02f3fe3dd951f705bd8b4e23d30c811 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7b6a8580098922ef6ec20a2beface45 = $(`&lt;div id=&quot;html_e7b6a8580098922ef6ec20a2beface45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e02f3fe3dd951f705bd8b4e23d30c811.setContent(html_e7b6a8580098922ef6ec20a2beface45);
#
#
#
#         marker_83121985b3c9f6244478db3a5aff28ae.bindPopup(popup_e02f3fe3dd951f705bd8b4e23d30c811)
#         ;
#
#
#
#
#             var marker_d6966398fd3c12bc9c0744df4290f270 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9f1b2eb4c9879cf1a68e92aad5caf97d);
#
#
#         var popup_40f55507c83ec201b45ce7dfce72de6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_394489eafddf347fdcddea15751c39e3 = $(`&lt;div id=&quot;html_394489eafddf347fdcddea15751c39e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_40f55507c83ec201b45ce7dfce72de6e.setContent(html_394489eafddf347fdcddea15751c39e3);
#
#
#
#         marker_d6966398fd3c12bc9c0744df4290f270.bindPopup(popup_40f55507c83ec201b45ce7dfce72de6e)
#         ;
#
#
#
#
#             var marker_acdbca3856996248d7f026ea19bbd280 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9f1b2eb4c9879cf1a68e92aad5caf97d);
#
#
#         var popup_3e1724794f15fd54323514ecff3e033a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34ccd20ff4088eb19e23a529ee40ad83 = $(`&lt;div id=&quot;html_34ccd20ff4088eb19e23a529ee40ad83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3e1724794f15fd54323514ecff3e033a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56b3743d4d985c91f72f7c4f90b6520b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56b3743d4d985c91f72f7c4f90b6520b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56b3743d4d985c91f72f7c4f90b6520b = L.map(
#                 &quot;map_56b3743d4d985c91f72f7c4f90b6520b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12bbd6fd1731e93bc5a368a9b40b4f52 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12bbd6fd1731e93bc5a368a9b40b4f52.addTo(map_56b3743d4d985c91f72f7c4f90b6520b);
#
#
#             var feature_group_8a13cc32db59f75e1be5210ec41bab51 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_88907f9a53cbfcafe5ceb32197796855 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8a13cc32db59f75e1be5210ec41bab51);
#
#
#         var popup_263f4cbd2aa4acbccfd174c10c5bbc44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fe0b57a7a6fceb21ea0ac27234f8959 = $(`&lt;div id=&quot;html_4fe0b57a7a6fceb21ea0ac27234f8959&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_263f4cbd2aa4acbccfd174c10c5bbc44.setContent(html_4fe0b57a7a6fceb21ea0ac27234f8959);
#
#
#
#         marker_88907f9a53cbfcafe5ceb32197796855.bindPopup(popup_263f4cbd2aa4acbccfd174c10c5bbc44)
#         ;
#
#
#
#
#             var marker_33c32269d89729a09ed6f81815490424 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8a13cc32db59f75e1be5210ec41bab51);
#
#
#         var popup_868298f04e1345736cd0958d8b050590 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e74f289b3d042e8afa890b49e10fc98 = $(`&lt;div id=&quot;html_9e74f289b3d042e8afa890b49e10fc98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_868298f04e1345736cd0958d8b050590.setContent(html_9e74f289b3d042e8afa890b49e10fc98);
#
#
#
#         marker_33c32269d89729a09ed6f81815490424.bindPopup(popup_868298f04e1345736cd0958d8b050590)
#         ;
#
#
#
#
#             var marker_7d2a34dfd8a1d0469deb867d4fc7a7b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8a13cc32db59f75e1be5210ec41bab51);
#
#
#         var popup_1a1448b4d95186d79a7894fb52751e3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4d1fde3b71dadefebf84371ec351505 = $(`&lt;div id=&quot;html_c4d1fde3b71dadefebf84371ec351505&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1a1448b4d95186d79a7894fb52751e3d.setContent(html_c4d1fde3b71dadefebf84371ec351505);
#
#
#
#         marker_7d2a34dfd8a1d0469deb867d4fc7a7b8.bindPopup(popup_1a1448b4d95186d79a7894fb52751e3d)
#         ;
#
#
#
#
#             var marker_40cbcc7b0438d69d0bd193e31617e907 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8a13cc32db59f75e1be5210ec41bab51);
#
#
#         var popup_7e016247379f98c3a3f1fd5cfe36dc42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15bf810a7a23e7c8fe0df85597500f9f = $(`&lt;div id=&quot;html_15bf810a7a23e7c8fe0df85597500f9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7e016247379f98c3a3f1fd5cfe36dc42.setContent(html_15bf810a7a23e7c8fe0df85597500f9f);
#
#
#
#         marker_40cbcc7b0438d69d0bd193e31617e907.bindPopup(popup_7e016247379f98c3a3f1fd5cfe36dc42)
#         ;
#
#
#
#
#             var marker_c42db038951178998864fe2b863a8a44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8a13cc32db59f75e1be5210ec41bab51);
#
#
#         var popup_57901b0b0a51a077f38a82bf2b94969a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3783f0ef797225068f595427f891bfe5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3783f0ef797225068f595427f891bfe5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3783f0ef797225068f595427f891bfe5 = L.map(
#                 &quot;map_3783f0ef797225068f595427f891bfe5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_073ed2463ff3703e1246e6c275667a3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_073ed2463ff3703e1246e6c275667a3c.addTo(map_3783f0ef797225068f595427f891bfe5);
#
#
#             var feature_group_177200605e308f4458ca712e83aac1e1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_177200605e308f4458ca712e83aac1e1.addTo(map_3783f0ef797225068f595427f891bfe5);
#
#
#             var feature_group_sub_group_fc5042165ecbe57d5a74b6ae026d7cfb = L.featureGroup.subGroup(
#                 feature_group_177200605e308f4458ca712e83aac1e1
#             );
#
#
#             var marker_770a4f1a858161650cb6059f123124d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc5042165ecbe57d5a74b6ae026d7cfb);
#
#
#         var popup_2b29e713de99b35e3355d422ce409db4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_134b1a354330aec9436373dc78e33353 = $(`&lt;div id=&quot;html_134b1a354330aec9436373dc78e33353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2b29e713de99b35e3355d422ce409db4.setContent(html_134b1a354330aec9436373dc78e33353);
#
#
#
#         marker_770a4f1a858161650cb6059f123124d4.bindPopup(popup_2b29e713de99b35e3355d422ce409db4)
#         ;
#
#
#
#
#             var marker_449446b93acb3eaf90cb98a782179fa2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc5042165ecbe57d5a74b6ae026d7cfb);
#
#
#         var popup_71ea5961e681410fbbfcaf004e458572 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90e701f76b26cfcf3ab0cb747badb4ee = $(`&lt;div id=&quot;html_90e701f76b26cfcf3ab0cb747badb4ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_71ea5961e681410fbbfcaf004e458572.setContent(html_90e701f76b26cfcf3ab0cb747badb4ee);
#
#
#
#         marker_449446b93acb3eaf90cb98a782179fa2.bindPopup(popup_71ea5961e681410fbbfcaf004e458572)
#         ;
#
#
#
#
#             var marker_7f30104f86f2b8ecf50879a5ce44182d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc5042165ecbe57d5a74b6ae026d7cfb);
#
#
#         var popup_4bc203b0cbc23a0eaae72d40aafacdb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9002f288e2fa828ed076d288bb2c9752 = $(`&lt;div id=&quot;html_9002f288e2fa828ed076d288bb2c9752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4bc203b0cbc23a0eaae72d40aafacdb6.setContent(html_9002f288e2fa828ed076d288bb2c9752);
#
#
#
#         marker_7f30104f86f2b8ecf50879a5ce44182d.bindPopup(popup_4bc203b0cbc23a0eaae72d40aafacdb6)
#         ;
#
#
#
#
#             var marker_23682b7258d54874b62bece2b3ac4199 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc5042165ecbe57d5a74b6ae026d7cfb);
#
#
#         var popup_088d3e4b02667433ff899a2f85d15a47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53557b16314849cbc44e30e38538d54e = $(`&lt;div id=&quot;html_53557b16314849cbc44e30e38538d54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_088d3e4b02667433ff899a2f85d15a47.setContent(html_53557b16314849cbc44e30e38538d54e);
#
#
#
#         marker_
