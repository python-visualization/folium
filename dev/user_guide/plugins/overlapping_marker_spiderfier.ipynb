# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fa77d7ead223c1b7a655ad362efbc69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fa77d7ead223c1b7a655ad362efbc69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fa77d7ead223c1b7a655ad362efbc69 = L.map(
#                 &quot;map_8fa77d7ead223c1b7a655ad362efbc69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_864f004230836390650386d7d88d3084 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_864f004230836390650386d7d88d3084.addTo(map_8fa77d7ead223c1b7a655ad362efbc69);
#
#
#             var marker_1d52ad5ffc82a5156fbad1da92f4be2e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8fa77d7ead223c1b7a655ad362efbc69);
#
#
#         var popup_f573bb65ffdab28528f82e802d2d970e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de7d3e0a953c78210939c21929fcaa89 = $(`&lt;div id=&quot;html_de7d3e0a953c78210939c21929fcaa89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f573bb65ffdab28528f82e802d2d970e.setContent(html_de7d3e0a953c78210939c21929fcaa89);
#
#
#
#         marker_1d52ad5ffc82a5156fbad1da92f4be2e.bindPopup(popup_f573bb65ffdab28528f82e802d2d970e)
#         ;
#
#
#
#
#             var marker_5c24cc20971becd2c2bf738e76b243e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8fa77d7ead223c1b7a655ad362efbc69);
#
#
#         var popup_56221dddb09181feb7d9b1045914364b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2b768565ca3b7cbddf35a3cae3be3b5 = $(`&lt;div id=&quot;html_a2b768565ca3b7cbddf35a3cae3be3b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_56221dddb09181feb7d9b1045914364b.setContent(html_a2b768565ca3b7cbddf35a3cae3be3b5);
#
#
#
#         marker_5c24cc20971becd2c2bf738e76b243e0.bindPopup(popup_56221dddb09181feb7d9b1045914364b)
#         ;
#
#
#
#
#             var marker_21758cc060e653e19f42532468da8736 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8fa77d7ead223c1b7a655ad362efbc69);
#
#
#         var popup_f869adc718232876a4afcf94d39a79d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30bfaaa9348020948ee65738566f8735 = $(`&lt;div id=&quot;html_30bfaaa9348020948ee65738566f8735&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f869adc718232876a4afcf94d39a79d1.setContent(html_30bfaaa9348020948ee65738566f8735);
#
#
#
#         marker_21758cc060e653e19f42532468da8736.bindPopup(popup_f869adc718232876a4afcf94d39a79d1)
#         ;
#
#
#
#
#             var marker_948ee23e06fba84bcb5b82973142eb92 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8fa77d7ead223c1b7a655ad362efbc69);
#
#
#         var popup_66d72f535413df0e46aa569e238628fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee80e0be49bbfcda938b56bccf6de941 = $(`&lt;div id=&quot;html_ee80e0be49bbfcda938b56bccf6de941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_66d72f535413df0e46aa569e238628fb.setContent(html_ee80e0be49bbfcda938b56bccf6de941);
#
#
#
#         marker_948ee23e06fba84bcb5b82973142eb92.bindPopup(popup_66d72f535413df0e46aa569e238628fb)
#         ;
#
#
#
#
#             var marker_7f15c21f437f92aba7fe26eef7d4d365 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8fa77d7ead223c1b7a655ad362efbc69);
#
#
#         var popup_f08f6535f41e7d6f6953d3ba503ee870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7dfd0470c6f0ca2ab492615a5d317fb = $(`&lt;div id=&quot;html_f7dfd0470c6f0ca2ab492615a5d317fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f08f6535f41e7d6f6953d3ba503ee870.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08e8831e8487406be3ff1c6bf61cd679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08e8831e8487406be3ff1c6bf61cd679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08e8831e8487406be3ff1c6bf61cd679 = L.map(
#                 &quot;map_08e8831e8487406be3ff1c6bf61cd679&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c9fc871ab4063af73807ab88b42678a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c9fc871ab4063af73807ab88b42678a.addTo(map_08e8831e8487406be3ff1c6bf61cd679);
#
#
#             var feature_group_369b84e2700bb79282b879bd8d9ff470 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_377a8c251bf8c096c3560e3dd474b406 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_369b84e2700bb79282b879bd8d9ff470);
#
#
#         var popup_f80da013ff7dee377f4ee29f04040c61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a55f30ed1c462883fed449dbec25397e = $(`&lt;div id=&quot;html_a55f30ed1c462883fed449dbec25397e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f80da013ff7dee377f4ee29f04040c61.setContent(html_a55f30ed1c462883fed449dbec25397e);
#
#
#
#         marker_377a8c251bf8c096c3560e3dd474b406.bindPopup(popup_f80da013ff7dee377f4ee29f04040c61)
#         ;
#
#
#
#
#             var marker_230085d75e45ff4534282f2e9360b030 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_369b84e2700bb79282b879bd8d9ff470);
#
#
#         var popup_407eaf51cdb6f9b8f2075fef78b93676 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39e2644999a5b9e8093b6ddc71749fce = $(`&lt;div id=&quot;html_39e2644999a5b9e8093b6ddc71749fce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_407eaf51cdb6f9b8f2075fef78b93676.setContent(html_39e2644999a5b9e8093b6ddc71749fce);
#
#
#
#         marker_230085d75e45ff4534282f2e9360b030.bindPopup(popup_407eaf51cdb6f9b8f2075fef78b93676)
#         ;
#
#
#
#
#             var marker_3d3d03334ba958c801126b55b1f52530 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_369b84e2700bb79282b879bd8d9ff470);
#
#
#         var popup_dd8b2460e95a3fad21af530ff59ee50a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb0dfc5cb71c7e02ccf59febe7b7d6cd = $(`&lt;div id=&quot;html_cb0dfc5cb71c7e02ccf59febe7b7d6cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dd8b2460e95a3fad21af530ff59ee50a.setContent(html_cb0dfc5cb71c7e02ccf59febe7b7d6cd);
#
#
#
#         marker_3d3d03334ba958c801126b55b1f52530.bindPopup(popup_dd8b2460e95a3fad21af530ff59ee50a)
#         ;
#
#
#
#
#             var marker_3ad675ba42098cb76bddd3a73fa904e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_369b84e2700bb79282b879bd8d9ff470);
#
#
#         var popup_9e7878cb971c7fe81d738cb0b064ecc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a9b9e0ca2d2c8019ca4d532d37869c2 = $(`&lt;div id=&quot;html_5a9b9e0ca2d2c8019ca4d532d37869c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9e7878cb971c7fe81d738cb0b064ecc5.setContent(html_5a9b9e0ca2d2c8019ca4d532d37869c2);
#
#
#
#         marker_3ad675ba42098cb76bddd3a73fa904e1.bindPopup(popup_9e7878cb971c7fe81d738cb0b064ecc5)
#         ;
#
#
#
#
#             var marker_16defbda59f5c48bc8d5d3790933a38e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_369b84e2700bb79282b879bd8d9ff470);
#
#
#         var popup_3c1831e1dbc70e390d221e4aee436b45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa2ad27bcc62f7884b3ea42c7a44e72d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa2ad27bcc62f7884b3ea42c7a44e72d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa2ad27bcc62f7884b3ea42c7a44e72d = L.map(
#                 &quot;map_aa2ad27bcc62f7884b3ea42c7a44e72d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d635bb0dc31600e82fd43fd991f53fc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d635bb0dc31600e82fd43fd991f53fc5.addTo(map_aa2ad27bcc62f7884b3ea42c7a44e72d);
#
#
#             var feature_group_87d6ba9d2fe8c095b3005d5bf543722c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_87d6ba9d2fe8c095b3005d5bf543722c.addTo(map_aa2ad27bcc62f7884b3ea42c7a44e72d);
#
#
#             var feature_group_sub_group_75bf982da9fb571d0743c66bc05bf6f7 = L.featureGroup.subGroup(
#                 feature_group_87d6ba9d2fe8c095b3005d5bf543722c
#             );
#
#
#             var marker_74358c66673a26a898b9ad74686f4026 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_75bf982da9fb571d0743c66bc05bf6f7);
#
#
#         var popup_ac11a386107f8557dc02808b42eabb9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f84a52b1647e90f443756df84d8caa48 = $(`&lt;div id=&quot;html_f84a52b1647e90f443756df84d8caa48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ac11a386107f8557dc02808b42eabb9b.setContent(html_f84a52b1647e90f443756df84d8caa48);
#
#
#
#         marker_74358c66673a26a898b9ad74686f4026.bindPopup(popup_ac11a386107f8557dc02808b42eabb9b)
#         ;
#
#
#
#
#             var marker_4d1a49e3b407daf62ac676d2b1678e7e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_75bf982da9fb571d0743c66bc05bf6f7);
#
#
#         var popup_bd6673980728e2f02159be3a57c35158 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24f51c631c734289ebf1bc9196b5f153 = $(`&lt;div id=&quot;html_24f51c631c734289ebf1bc9196b5f153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bd6673980728e2f02159be3a57c35158.setContent(html_24f51c631c734289ebf1bc9196b5f153);
#
#
#
#         marker_4d1a49e3b407daf62ac676d2b1678e7e.bindPopup(popup_bd6673980728e2f02159be3a57c35158)
#         ;
#
#
#
#
#             var marker_b39325e98495b2da0d00e4b53b8b1ef4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_75bf982da9fb571d0743c66bc05bf6f7);
#
#
#         var popup_46c4e0374d93308b2eb180f2b462588d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb922ba93b386b46fbdcb395b9e04c5a = $(`&lt;div id=&quot;html_eb922ba93b386b46fbdcb395b9e04c5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_46c4e0374d93308b2eb180f2b462588d.setContent(html_eb922ba93b386b46fbdcb395b9e04c5a);
#
#
#
#         marker_b39325e98495b2da0d00e4b53b8b1ef4.bindPopup(popup_46c4e0374d93308b2eb180f2b462588d)
#         ;
#
#
#
#
#             var marker_7523cf1b9aeaf802ebdee9b459b2ba44 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_75bf982da9fb571d0743c66bc05bf6f7);
#
#
#         var popup_4db9b510e94e8638fe4050dce74276c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8854e22c6fffd132882ef1d46469b3a6 = $(`&lt;div id=&quot;html_8854e22c6fffd132882ef1d46469b3a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4db9b510e94e8638fe4050dce74276c8.setContent(html_8854e22c6fffd132882ef1d46469b3a6);
#
#
#
#         marker_
