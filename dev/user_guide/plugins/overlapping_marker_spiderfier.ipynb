# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58eb32a8deeab3d49bd6dd84c3c8e1e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58eb32a8deeab3d49bd6dd84c3c8e1e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58eb32a8deeab3d49bd6dd84c3c8e1e4 = L.map(
#                 &quot;map_58eb32a8deeab3d49bd6dd84c3c8e1e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23953a384abc12e40217d87e8fbe9e6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23953a384abc12e40217d87e8fbe9e6a.addTo(map_58eb32a8deeab3d49bd6dd84c3c8e1e4);
#
#
#             var marker_dd46cfd40f5d7ec65439d47ea9f2f7e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_58eb32a8deeab3d49bd6dd84c3c8e1e4);
#
#
#         var popup_a231af676af864dbc0396350bad5a77c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c39d6c17d5a6456f4400296d9e6defc = $(`&lt;div id=&quot;html_4c39d6c17d5a6456f4400296d9e6defc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a231af676af864dbc0396350bad5a77c.setContent(html_4c39d6c17d5a6456f4400296d9e6defc);
#
#
#
#         marker_dd46cfd40f5d7ec65439d47ea9f2f7e0.bindPopup(popup_a231af676af864dbc0396350bad5a77c)
#         ;
#
#
#
#
#             var marker_58e3549e0912a8bd9d3bc8c83a7a675b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_58eb32a8deeab3d49bd6dd84c3c8e1e4);
#
#
#         var popup_419bce2ce194df1580b8e9af1ca95673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7dce3fa6d71f062b113a30143e85f82 = $(`&lt;div id=&quot;html_f7dce3fa6d71f062b113a30143e85f82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_419bce2ce194df1580b8e9af1ca95673.setContent(html_f7dce3fa6d71f062b113a30143e85f82);
#
#
#
#         marker_58e3549e0912a8bd9d3bc8c83a7a675b.bindPopup(popup_419bce2ce194df1580b8e9af1ca95673)
#         ;
#
#
#
#
#             var marker_dc2f6190176a78bb3f9230bee5a1cd68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_58eb32a8deeab3d49bd6dd84c3c8e1e4);
#
#
#         var popup_10d9651ac931ee313f643394c9af3f6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a8b67a7b9f0bf2712c44a6050bdd0ce = $(`&lt;div id=&quot;html_6a8b67a7b9f0bf2712c44a6050bdd0ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_10d9651ac931ee313f643394c9af3f6c.setContent(html_6a8b67a7b9f0bf2712c44a6050bdd0ce);
#
#
#
#         marker_dc2f6190176a78bb3f9230bee5a1cd68.bindPopup(popup_10d9651ac931ee313f643394c9af3f6c)
#         ;
#
#
#
#
#             var marker_5978b1afd3afc20f225a7e285e86c21e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_58eb32a8deeab3d49bd6dd84c3c8e1e4);
#
#
#         var popup_704887b758bb733e6bbfc8e73c423bde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_576f046db8eddfc25ccc9d3e77e94457 = $(`&lt;div id=&quot;html_576f046db8eddfc25ccc9d3e77e94457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_704887b758bb733e6bbfc8e73c423bde.setContent(html_576f046db8eddfc25ccc9d3e77e94457);
#
#
#
#         marker_5978b1afd3afc20f225a7e285e86c21e.bindPopup(popup_704887b758bb733e6bbfc8e73c423bde)
#         ;
#
#
#
#
#             var marker_2ba91a7c3425b7175ff0610d1e735870 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_58eb32a8deeab3d49bd6dd84c3c8e1e4);
#
#
#         var popup_3a08313672f9ea874f021593ccab69bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8aba0851eae043404e7baaf0acbc6a36 = $(`&lt;div id=&quot;html_8aba0851eae043404e7baaf0acbc6a36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3a08313672f9ea874f021593ccab69bc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_887bd6ea80c81a674d86adb0e6c0d75e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_887bd6ea80c81a674d86adb0e6c0d75e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_887bd6ea80c81a674d86adb0e6c0d75e = L.map(
#                 &quot;map_887bd6ea80c81a674d86adb0e6c0d75e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9081f932fe2d7dbd1c7ffb5e36abbf0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9081f932fe2d7dbd1c7ffb5e36abbf0a.addTo(map_887bd6ea80c81a674d86adb0e6c0d75e);
#
#
#             var feature_group_97f913dc1e4244673b1da5b29752bf07 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_10107073cd73885398b44e4c65c482a5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_97f913dc1e4244673b1da5b29752bf07);
#
#
#         var popup_de86bcc051e770149958213c882e7808 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d36f0580963c502c219def30fed7ce32 = $(`&lt;div id=&quot;html_d36f0580963c502c219def30fed7ce32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_de86bcc051e770149958213c882e7808.setContent(html_d36f0580963c502c219def30fed7ce32);
#
#
#
#         marker_10107073cd73885398b44e4c65c482a5.bindPopup(popup_de86bcc051e770149958213c882e7808)
#         ;
#
#
#
#
#             var marker_3f4cc4d05d24f426fe2754d3a9d7cb2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_97f913dc1e4244673b1da5b29752bf07);
#
#
#         var popup_d47de10906fbbd63c4eb889a1a2ed736 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac7a00bfef3d11f973646aa05653a5c5 = $(`&lt;div id=&quot;html_ac7a00bfef3d11f973646aa05653a5c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d47de10906fbbd63c4eb889a1a2ed736.setContent(html_ac7a00bfef3d11f973646aa05653a5c5);
#
#
#
#         marker_3f4cc4d05d24f426fe2754d3a9d7cb2a.bindPopup(popup_d47de10906fbbd63c4eb889a1a2ed736)
#         ;
#
#
#
#
#             var marker_6aa65b2293d5be3c155fce78ba383e2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_97f913dc1e4244673b1da5b29752bf07);
#
#
#         var popup_4cf8f120820d6954855b8f7817daea73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ff9d46ca9fff58c79a7d8c7bf1b9a15 = $(`&lt;div id=&quot;html_0ff9d46ca9fff58c79a7d8c7bf1b9a15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4cf8f120820d6954855b8f7817daea73.setContent(html_0ff9d46ca9fff58c79a7d8c7bf1b9a15);
#
#
#
#         marker_6aa65b2293d5be3c155fce78ba383e2d.bindPopup(popup_4cf8f120820d6954855b8f7817daea73)
#         ;
#
#
#
#
#             var marker_67a48b75bee812723a5cc1c3a2d69ac2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_97f913dc1e4244673b1da5b29752bf07);
#
#
#         var popup_e74368de9e4a0145d087e1b51e83c11e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad89c926cfae017ac6c49cfa34ade958 = $(`&lt;div id=&quot;html_ad89c926cfae017ac6c49cfa34ade958&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e74368de9e4a0145d087e1b51e83c11e.setContent(html_ad89c926cfae017ac6c49cfa34ade958);
#
#
#
#         marker_67a48b75bee812723a5cc1c3a2d69ac2.bindPopup(popup_e74368de9e4a0145d087e1b51e83c11e)
#         ;
#
#
#
#
#             var marker_0acead8090888e18407b8e1c9e175272 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_97f913dc1e4244673b1da5b29752bf07);
#
#
#         var popup_ecb0d07b246027ed2879ae5606e0aa4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2923d0975e3873e916252b625911a03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2923d0975e3873e916252b625911a03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2923d0975e3873e916252b625911a03 = L.map(
#                 &quot;map_a2923d0975e3873e916252b625911a03&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ecc808a43f487a098d5bf7197e0306b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ecc808a43f487a098d5bf7197e0306b.addTo(map_a2923d0975e3873e916252b625911a03);
#
#
#             var feature_group_32585420069975d49a329cc4601e08fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_32585420069975d49a329cc4601e08fe.addTo(map_a2923d0975e3873e916252b625911a03);
#
#
#             var feature_group_sub_group_f6657c9ea64bd8d3c66f23e93a896c94 = L.featureGroup.subGroup(
#                 feature_group_32585420069975d49a329cc4601e08fe
#             );
#
#
#             var marker_d8849077c84dce792aa5ed550377fdf2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6657c9ea64bd8d3c66f23e93a896c94);
#
#
#         var popup_9219db8924e21b8f5a4512ffc94d583d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc32b849e9cae09193af3b82e3b13838 = $(`&lt;div id=&quot;html_cc32b849e9cae09193af3b82e3b13838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9219db8924e21b8f5a4512ffc94d583d.setContent(html_cc32b849e9cae09193af3b82e3b13838);
#
#
#
#         marker_d8849077c84dce792aa5ed550377fdf2.bindPopup(popup_9219db8924e21b8f5a4512ffc94d583d)
#         ;
#
#
#
#
#             var marker_8f70c39978cad24194efea327c362e54 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6657c9ea64bd8d3c66f23e93a896c94);
#
#
#         var popup_f9a75b0a947fd9ab4da8376532b1e5cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d04f01e34276e5a23a8cea90d1ad31d7 = $(`&lt;div id=&quot;html_d04f01e34276e5a23a8cea90d1ad31d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f9a75b0a947fd9ab4da8376532b1e5cc.setContent(html_d04f01e34276e5a23a8cea90d1ad31d7);
#
#
#
#         marker_8f70c39978cad24194efea327c362e54.bindPopup(popup_f9a75b0a947fd9ab4da8376532b1e5cc)
#         ;
#
#
#
#
#             var marker_8a60c5ca693edab007fdba7b22cbf92a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6657c9ea64bd8d3c66f23e93a896c94);
#
#
#         var popup_8faa8ae5b89a599d3485ac72e2db72f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7da7052c0d1fab8feb0f63a0cc1b099e = $(`&lt;div id=&quot;html_7da7052c0d1fab8feb0f63a0cc1b099e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8faa8ae5b89a599d3485ac72e2db72f6.setContent(html_7da7052c0d1fab8feb0f63a0cc1b099e);
#
#
#
#         marker_8a60c5ca693edab007fdba7b22cbf92a.bindPopup(popup_8faa8ae5b89a599d3485ac72e2db72f6)
#         ;
#
#
#
#
#             var marker_b14793504c35b4ae4c7f0a375846bf84 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6657c9ea64bd8d3c66f23e93a896c94);
#
#
#         var popup_894a5907592a22e745444b059c3ccc5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5afa889fc346b77af0351af37464d176 = $(`&lt;div id=&quot;html_5afa889fc346b77af0351af37464d176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_894a5907592a22e745444b059c3ccc5c.setContent(html_5afa889fc346b77af0351af37464d176);
#
#
#
#         marker_
