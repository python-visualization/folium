# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55cbb8066772cb93ccca919349dd0414 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55cbb8066772cb93ccca919349dd0414&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55cbb8066772cb93ccca919349dd0414 = L.map(
#                 &quot;map_55cbb8066772cb93ccca919349dd0414&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23657f5a75c2252f498c35676945fb2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23657f5a75c2252f498c35676945fb2c.addTo(map_55cbb8066772cb93ccca919349dd0414);
#
#
#             var marker_da5aed6b853d78059e1d6eb53b8eebd0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_55cbb8066772cb93ccca919349dd0414);
#
#
#         var popup_2f47f8787efc5dc0bf14365747e7a7ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a475e5219f1e63cec6d6e5582dfd2efb = $(`&lt;div id=&quot;html_a475e5219f1e63cec6d6e5582dfd2efb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2f47f8787efc5dc0bf14365747e7a7ed.setContent(html_a475e5219f1e63cec6d6e5582dfd2efb);
#
#
#
#         marker_da5aed6b853d78059e1d6eb53b8eebd0.bindPopup(popup_2f47f8787efc5dc0bf14365747e7a7ed)
#         ;
#
#
#
#
#             var marker_644b522474b43cd3b97a5bb0674f4643 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_55cbb8066772cb93ccca919349dd0414);
#
#
#         var popup_a6348f76be14a2aa8aad069551257e77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3430bb4d3e0146729f31f461f34214ef = $(`&lt;div id=&quot;html_3430bb4d3e0146729f31f461f34214ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a6348f76be14a2aa8aad069551257e77.setContent(html_3430bb4d3e0146729f31f461f34214ef);
#
#
#
#         marker_644b522474b43cd3b97a5bb0674f4643.bindPopup(popup_a6348f76be14a2aa8aad069551257e77)
#         ;
#
#
#
#
#             var marker_b558aa9bbe49a85832fe9cafe559df97 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_55cbb8066772cb93ccca919349dd0414);
#
#
#         var popup_5d4d5979c81a30ec7c33acfc19971138 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dee8e737222b90c12d3518f0d647bc56 = $(`&lt;div id=&quot;html_dee8e737222b90c12d3518f0d647bc56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5d4d5979c81a30ec7c33acfc19971138.setContent(html_dee8e737222b90c12d3518f0d647bc56);
#
#
#
#         marker_b558aa9bbe49a85832fe9cafe559df97.bindPopup(popup_5d4d5979c81a30ec7c33acfc19971138)
#         ;
#
#
#
#
#             var marker_9339454cd0a27b42064766515e65dc47 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_55cbb8066772cb93ccca919349dd0414);
#
#
#         var popup_d3d8100138ae457b384290dc9e6c66fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09e69e20a55427fc51148041da62698c = $(`&lt;div id=&quot;html_09e69e20a55427fc51148041da62698c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d3d8100138ae457b384290dc9e6c66fd.setContent(html_09e69e20a55427fc51148041da62698c);
#
#
#
#         marker_9339454cd0a27b42064766515e65dc47.bindPopup(popup_d3d8100138ae457b384290dc9e6c66fd)
#         ;
#
#
#
#
#             var marker_23485d511bd965a15072d6578a6eae98 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_55cbb8066772cb93ccca919349dd0414);
#
#
#         var popup_41cb56c20e65f93c1b69c527ff70286a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c69e1875941670eaae5e8490a82eabe = $(`&lt;div id=&quot;html_5c69e1875941670eaae5e8490a82eabe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_41cb56c20e65f93c1b69c527ff70286a.setContent(html_5c69e1875941670eaae5e8490a82eabe);
#
#
#
#         marker_23485d511bd965a15072d6578a6eae98.bindPopup(popup_41cb56c20e65f93c1b69c527ff70286a)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a94e5df5563386f8da8f7f8b6d7d2a02 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a94e5df5563386f8da8f7f8b6d7d2a02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a94e5df5563386f8da8f7f8b6d7d2a02 = L.map(
#                 &quot;map_a94e5df5563386f8da8f7f8b6d7d2a02&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52bfdf26201d28afad5c574da430401f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52bfdf26201d28afad5c574da430401f.addTo(map_a94e5df5563386f8da8f7f8b6d7d2a02);
#
#
#             var feature_group_7aea477f60885c0684473cf9195abb8a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c38179496f98fac786328c66c10684ad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7aea477f60885c0684473cf9195abb8a);
#
#
#         var popup_ef31d8e6a8bfaedbe74b168b89cd3608 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_841d2e1b852cca929d481a940f1b9c89 = $(`&lt;div id=&quot;html_841d2e1b852cca929d481a940f1b9c89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ef31d8e6a8bfaedbe74b168b89cd3608.setContent(html_841d2e1b852cca929d481a940f1b9c89);
#
#
#
#         marker_c38179496f98fac786328c66c10684ad.bindPopup(popup_ef31d8e6a8bfaedbe74b168b89cd3608)
#         ;
#
#
#
#
#             var marker_6046636958869f5c600951413bf5ff35 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7aea477f60885c0684473cf9195abb8a);
#
#
#         var popup_6b2cd3e34be5e9065d6e7f0dadba6f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_def54bfa159230bfdb7ab1e0bf77c3dd = $(`&lt;div id=&quot;html_def54bfa159230bfdb7ab1e0bf77c3dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6b2cd3e34be5e9065d6e7f0dadba6f38.setContent(html_def54bfa159230bfdb7ab1e0bf77c3dd);
#
#
#
#         marker_6046636958869f5c600951413bf5ff35.bindPopup(popup_6b2cd3e34be5e9065d6e7f0dadba6f38)
#         ;
#
#
#
#
#             var marker_a49f6d4e525d24dfc277803e5b34ef1c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7aea477f60885c0684473cf9195abb8a);
#
#
#         var popup_1a861f6cb29e2c554dcfe773ab97ec79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fde67bafb99847ad443c35b84978d4ef = $(`&lt;div id=&quot;html_fde67bafb99847ad443c35b84978d4ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1a861f6cb29e2c554dcfe773ab97ec79.setContent(html_fde67bafb99847ad443c35b84978d4ef);
#
#
#
#         marker_a49f6d4e525d24dfc277803e5b34ef1c.bindPopup(popup_1a861f6cb29e2c554dcfe773ab97ec79)
#         ;
#
#
#
#
#             var marker_80eba1981fca8c427e3c3d19ac9ade21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7aea477f60885c0684473cf9195abb8a);
#
#
#         var popup_03a6336e7200f38cade76081d6691e97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3442cf7f7021f28f06f47f968e370f6e = $(`&lt;div id=&quot;html_3442cf7f7021f28f06f47f968e370f6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_03a6336e7200f38cade76081d6691e97.setContent(html_3442cf7f7021f28f06f47f968e370f6e);
#
#
#
#         marker_80eba1981fca8c427e3c3d19ac9ade21.bindPopup(popup_03a6336e7200f38cade76081d6691e97)
#         ;
#
#
#
#
#             var marker_fb82ef0956c5e7f4fae2f42fd7068c6b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7aea477f60885c0684473cf9195abb8a);
#
#
#         var popup_6b197d8183498821ce6071bd0425d711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29935d12014d21a5168bd13c28ca8757 = $(`&lt;div id=&quot;html_29935d12014d21a5168bd13c28ca8757&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cad249ce73acbd36ca716f4859e371fb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cad249ce73acbd36ca716f4859e371fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cad249ce73acbd36ca716f4859e371fb = L.map(
#                 &quot;map_cad249ce73acbd36ca716f4859e371fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1e845ef3c1bdd890dbb11f317546431 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1e845ef3c1bdd890dbb11f317546431.addTo(map_cad249ce73acbd36ca716f4859e371fb);
#
#
#             var feature_group_d65763beaa22211694fa73f616746b9b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d65763beaa22211694fa73f616746b9b.addTo(map_cad249ce73acbd36ca716f4859e371fb);
#
#
#             var feature_group_sub_group_9dde093b3e857d6b14a21d8cfbff3068 = L.featureGroup.subGroup(
#                 feature_group_d65763beaa22211694fa73f616746b9b
#             );
#
#
#             var marker_9d7e898f9487230736362b423057a275 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9dde093b3e857d6b14a21d8cfbff3068);
#
#
#         var popup_7f45cebd5498ad0fc26cca3731ea5015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a123b662597b6ba8a7013eedc1d4b22c = $(`&lt;div id=&quot;html_a123b662597b6ba8a7013eedc1d4b22c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7f45cebd5498ad0fc26cca3731ea5015.setContent(html_a123b662597b6ba8a7013eedc1d4b22c);
#
#
#
#         marker_9d7e898f9487230736362b423057a275.bindPopup(popup_7f45cebd5498ad0fc26cca3731ea5015)
#         ;
#
#
#
#
#             var marker_d7a73f7ca03b61656b119a881ad0f3fe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9dde093b3e857d6b14a21d8cfbff3068);
#
#
#         var popup_bbe9fbe5041a3be0e95b81483fc1233c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d4bd39b947da781a48c97c2d5da8401 = $(`&lt;div id=&quot;html_6d4bd39b947da781a48c97c2d5da8401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bbe9fbe5041a3be0e95b81483fc1233c.setContent(html_6d4bd39b947da781a48c97c2d5da8401);
#
#
#
#         marker_d7a73f7ca03b61656b119a881ad0f3fe.bindPopup(popup_bbe9fbe5041a3be0e95b81483fc1233c)
#         ;
#
#
#
#
#             var marker_ffe232310cfb9de287a5ef2f4c47d629 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9dde093b3e857d6b14a21d8cfbff3068);
#
#
#         var popup_a87e86833c4de8ff2f9d0f0c8087acc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3755e0baf99fe2d1a7800d46041b8aa = $(`&lt;div id=&quot;html_d3755e0baf99fe2d1a7800d46041b8aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a87e86833c4de8ff2f9d0f0c8087acc9.setContent(html_d3755e0baf99fe2d1a7800d46041b8aa);
#
#
#
#         marker_ffe232310cfb9de287a5ef2f4c47d629.bindPopup(popup_a87e86833c4de8ff2f9d0f0c8087acc9)
#         ;
#
#
#
#
#             var marker_af9ee16df264f1fc91896036db1fba45 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9dde093b3e857d6b14a21d8cfbff3068);
#
#
#         var popup_45623526cabc613adb8eec887469613a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a15b51034e15b36398ea868cbe26b27 = $(`&lt;div id=&quot;html_4a15b51034e15b36398ea868cbe26b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_45623526cabc613adb8eec887469613a.setContent(html_4a15b51034e15b36398ea868cbe26b27);
#
#
#
#         marker_af9ee16df264f1fc91896036db1fba45.bindPopup(popup_45623526cabc613adb8eec887469613a)
#         ;
#
#
#
#
#             var marker_84c4c36729723a9ee32fd22afc233b7b = L.marker(
#                 [45.0503999
