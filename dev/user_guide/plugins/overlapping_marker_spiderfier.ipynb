# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bdcaa80413f9907d4a94bb8795b1e7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bdcaa80413f9907d4a94bb8795b1e7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bdcaa80413f9907d4a94bb8795b1e7a = L.map(
#                 &quot;map_2bdcaa80413f9907d4a94bb8795b1e7a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cadf2b07e2afc2599f624c38de449e23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cadf2b07e2afc2599f624c38de449e23.addTo(map_2bdcaa80413f9907d4a94bb8795b1e7a);
#
#
#             var marker_f48b2913cde2fbf4503e74437ba663d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2bdcaa80413f9907d4a94bb8795b1e7a);
#
#
#         var popup_e3c8494ebcad116736b07873711968ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab583d63a01be617755d9057185ff284 = $(`&lt;div id=&quot;html_ab583d63a01be617755d9057185ff284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e3c8494ebcad116736b07873711968ae.setContent(html_ab583d63a01be617755d9057185ff284);
#
#
#
#         marker_f48b2913cde2fbf4503e74437ba663d6.bindPopup(popup_e3c8494ebcad116736b07873711968ae)
#         ;
#
#
#
#
#             var marker_e1149ebe170fd73133723d26b82ed02e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2bdcaa80413f9907d4a94bb8795b1e7a);
#
#
#         var popup_6cb1ecde5ea9b58823fa2c07bc9b6551 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2722107cb17189cdd7e7134131e77a55 = $(`&lt;div id=&quot;html_2722107cb17189cdd7e7134131e77a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6cb1ecde5ea9b58823fa2c07bc9b6551.setContent(html_2722107cb17189cdd7e7134131e77a55);
#
#
#
#         marker_e1149ebe170fd73133723d26b82ed02e.bindPopup(popup_6cb1ecde5ea9b58823fa2c07bc9b6551)
#         ;
#
#
#
#
#             var marker_97e8a5058ddc840658aa296d1ea233bb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2bdcaa80413f9907d4a94bb8795b1e7a);
#
#
#         var popup_741c1ce99976c69d5821e697348f132a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e527499129e756c117acaa3a6148a8b8 = $(`&lt;div id=&quot;html_e527499129e756c117acaa3a6148a8b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_741c1ce99976c69d5821e697348f132a.setContent(html_e527499129e756c117acaa3a6148a8b8);
#
#
#
#         marker_97e8a5058ddc840658aa296d1ea233bb.bindPopup(popup_741c1ce99976c69d5821e697348f132a)
#         ;
#
#
#
#
#             var marker_ff3fab1676a2810d78286ea5f64f0e59 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2bdcaa80413f9907d4a94bb8795b1e7a);
#
#
#         var popup_cc8c16d3efadd551e509c8e7c8df6f56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d16df8cdb59353b6343878d12ab47f78 = $(`&lt;div id=&quot;html_d16df8cdb59353b6343878d12ab47f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cc8c16d3efadd551e509c8e7c8df6f56.setContent(html_d16df8cdb59353b6343878d12ab47f78);
#
#
#
#         marker_ff3fab1676a2810d78286ea5f64f0e59.bindPopup(popup_cc8c16d3efadd551e509c8e7c8df6f56)
#         ;
#
#
#
#
#             var marker_8a46b4c211ed251baa2257e29ec89852 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2bdcaa80413f9907d4a94bb8795b1e7a);
#
#
#         var popup_4dce1f5da23edb15242a72120c6cce57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76f81a2c2ecdf9cf8b925ba5749fdb6f = $(`&lt;div id=&quot;html_76f81a2c2ecdf9cf8b925ba5749fdb6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4dce1f5da23edb15242a72120c6cce57.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_412e0a1b7fd41caa76c2cc27745dbae3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_412e0a1b7fd41caa76c2cc27745dbae3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_412e0a1b7fd41caa76c2cc27745dbae3 = L.map(
#                 &quot;map_412e0a1b7fd41caa76c2cc27745dbae3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4faca71c33277b2a00f01546bccca6f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4faca71c33277b2a00f01546bccca6f0.addTo(map_412e0a1b7fd41caa76c2cc27745dbae3);
#
#
#             var feature_group_0d814b9689ace1476ca6ba4bffc075a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_398441e3a9cfc4051930d65d0daa39b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0d814b9689ace1476ca6ba4bffc075a0);
#
#
#         var popup_6e4cc7a96129f06330803a2f9694d5ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dadf060126624ea3a6cc4b1a93a3a45 = $(`&lt;div id=&quot;html_7dadf060126624ea3a6cc4b1a93a3a45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6e4cc7a96129f06330803a2f9694d5ff.setContent(html_7dadf060126624ea3a6cc4b1a93a3a45);
#
#
#
#         marker_398441e3a9cfc4051930d65d0daa39b5.bindPopup(popup_6e4cc7a96129f06330803a2f9694d5ff)
#         ;
#
#
#
#
#             var marker_1e5b564cc64a70a020fe17b4f3f05e97 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0d814b9689ace1476ca6ba4bffc075a0);
#
#
#         var popup_95add6cdc2a74b6f18fbf35e93544f61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f1dd96f0b28cb48c14a68da72943291 = $(`&lt;div id=&quot;html_5f1dd96f0b28cb48c14a68da72943291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_95add6cdc2a74b6f18fbf35e93544f61.setContent(html_5f1dd96f0b28cb48c14a68da72943291);
#
#
#
#         marker_1e5b564cc64a70a020fe17b4f3f05e97.bindPopup(popup_95add6cdc2a74b6f18fbf35e93544f61)
#         ;
#
#
#
#
#             var marker_a42d51b22900994561700d5e065276e0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0d814b9689ace1476ca6ba4bffc075a0);
#
#
#         var popup_3dfdbedcb5c5ac2ace4ad838cbe47bdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74e1a32ef1f6fba2181ebc41b73c30ba = $(`&lt;div id=&quot;html_74e1a32ef1f6fba2181ebc41b73c30ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3dfdbedcb5c5ac2ace4ad838cbe47bdc.setContent(html_74e1a32ef1f6fba2181ebc41b73c30ba);
#
#
#
#         marker_a42d51b22900994561700d5e065276e0.bindPopup(popup_3dfdbedcb5c5ac2ace4ad838cbe47bdc)
#         ;
#
#
#
#
#             var marker_53fc312cf8216d62edd9372e2e206da1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0d814b9689ace1476ca6ba4bffc075a0);
#
#
#         var popup_dd42a66573e8863de567e98459e9cca6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01d5bbde331d748e1bea3e2966d2a65a = $(`&lt;div id=&quot;html_01d5bbde331d748e1bea3e2966d2a65a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dd42a66573e8863de567e98459e9cca6.setContent(html_01d5bbde331d748e1bea3e2966d2a65a);
#
#
#
#         marker_53fc312cf8216d62edd9372e2e206da1.bindPopup(popup_dd42a66573e8863de567e98459e9cca6)
#         ;
#
#
#
#
#             var marker_11690b0543727cad4f3f7c948dd91a12 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0d814b9689ace1476ca6ba4bffc075a0);
#
#
#         var popup_df6f4258376338625177a9a5c6231a42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df228a7d139ef8baafde8dd5966516c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df228a7d139ef8baafde8dd5966516c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df228a7d139ef8baafde8dd5966516c9 = L.map(
#                 &quot;map_df228a7d139ef8baafde8dd5966516c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_965ebde26d77a1a009b09f84af58f6da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_965ebde26d77a1a009b09f84af58f6da.addTo(map_df228a7d139ef8baafde8dd5966516c9);
#
#
#             var feature_group_1c26e6caeaea0a6dcb8e13d6b3adf29d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1c26e6caeaea0a6dcb8e13d6b3adf29d.addTo(map_df228a7d139ef8baafde8dd5966516c9);
#
#
#             var feature_group_sub_group_1165dfc963b12ad18aa3da1baed1c076 = L.featureGroup.subGroup(
#                 feature_group_1c26e6caeaea0a6dcb8e13d6b3adf29d
#             );
#
#
#             var marker_1c5dec254afd55578bfaf4462fa55b71 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1165dfc963b12ad18aa3da1baed1c076);
#
#
#         var popup_ee5bea418d7dbc504676f59ab8987fe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e056e0f2267df7ecf4a3d64ceb3793c = $(`&lt;div id=&quot;html_9e056e0f2267df7ecf4a3d64ceb3793c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ee5bea418d7dbc504676f59ab8987fe8.setContent(html_9e056e0f2267df7ecf4a3d64ceb3793c);
#
#
#
#         marker_1c5dec254afd55578bfaf4462fa55b71.bindPopup(popup_ee5bea418d7dbc504676f59ab8987fe8)
#         ;
#
#
#
#
#             var marker_0c381a0979fdf962917b7e214e0ee548 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1165dfc963b12ad18aa3da1baed1c076);
#
#
#         var popup_7a64662541411a350ce5e7fd83abfea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b40fc0f93cbfd00307a2fe272cfaa39f = $(`&lt;div id=&quot;html_b40fc0f93cbfd00307a2fe272cfaa39f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7a64662541411a350ce5e7fd83abfea3.setContent(html_b40fc0f93cbfd00307a2fe272cfaa39f);
#
#
#
#         marker_0c381a0979fdf962917b7e214e0ee548.bindPopup(popup_7a64662541411a350ce5e7fd83abfea3)
#         ;
#
#
#
#
#             var marker_de8d8e59490fe8765806672aba41e3ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1165dfc963b12ad18aa3da1baed1c076);
#
#
#         var popup_14cb66b0044aeeb8cecc30c8a1382066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2f164ad42644e72b9e5415a5ff46eef = $(`&lt;div id=&quot;html_c2f164ad42644e72b9e5415a5ff46eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14cb66b0044aeeb8cecc30c8a1382066.setContent(html_c2f164ad42644e72b9e5415a5ff46eef);
#
#
#
#         marker_de8d8e59490fe8765806672aba41e3ae.bindPopup(popup_14cb66b0044aeeb8cecc30c8a1382066)
#         ;
#
#
#
#
#             var marker_760be26d56a2536375597707fc07f965 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1165dfc963b12ad18aa3da1baed1c076);
#
#
#         var popup_d2d017c62b802b1633ffdedb271b5beb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b59ee958f7fdb307941b6b5d63d79265 = $(`&lt;div id=&quot;html_b59ee958f7fdb307941b6b5d63d79265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d2d017c62b802b1633ffdedb271b5beb.setContent(html_b59ee958f7fdb307941b6b5d63d79265);
#
#
#
#         marker_
