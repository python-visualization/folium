# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbad75518f7d4dd9a96e00615345aa0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbad75518f7d4dd9a96e00615345aa0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbad75518f7d4dd9a96e00615345aa0b = L.map(
#                 &quot;map_bbad75518f7d4dd9a96e00615345aa0b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42c56b8e85ab19beeee321e57f480e5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42c56b8e85ab19beeee321e57f480e5e.addTo(map_bbad75518f7d4dd9a96e00615345aa0b);
#
#
#             var marker_222d703186a1f2af6d899e6822e0ada6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bbad75518f7d4dd9a96e00615345aa0b);
#
#
#         var popup_609d2c2da1609608f87eed7896abefe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c2cfd997bd7a2d7b525a08b3a63cf73 = $(`&lt;div id=&quot;html_7c2cfd997bd7a2d7b525a08b3a63cf73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_609d2c2da1609608f87eed7896abefe7.setContent(html_7c2cfd997bd7a2d7b525a08b3a63cf73);
#
#
#
#         marker_222d703186a1f2af6d899e6822e0ada6.bindPopup(popup_609d2c2da1609608f87eed7896abefe7)
#         ;
#
#
#
#
#             var marker_72c88478269b177622ada4a98f3f9e03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bbad75518f7d4dd9a96e00615345aa0b);
#
#
#         var popup_fb5f97caabdc670a8fcc03af20a371b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68fc4704548cea2d15be68191f41a23e = $(`&lt;div id=&quot;html_68fc4704548cea2d15be68191f41a23e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fb5f97caabdc670a8fcc03af20a371b2.setContent(html_68fc4704548cea2d15be68191f41a23e);
#
#
#
#         marker_72c88478269b177622ada4a98f3f9e03.bindPopup(popup_fb5f97caabdc670a8fcc03af20a371b2)
#         ;
#
#
#
#
#             var marker_3c80bf0d737024d1d4caf628b21da78f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bbad75518f7d4dd9a96e00615345aa0b);
#
#
#         var popup_a53495900ef5302b99fa0e1763d4d344 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e1fbef0a31fb3ab88d32e432564bf4a = $(`&lt;div id=&quot;html_5e1fbef0a31fb3ab88d32e432564bf4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a53495900ef5302b99fa0e1763d4d344.setContent(html_5e1fbef0a31fb3ab88d32e432564bf4a);
#
#
#
#         marker_3c80bf0d737024d1d4caf628b21da78f.bindPopup(popup_a53495900ef5302b99fa0e1763d4d344)
#         ;
#
#
#
#
#             var marker_1955f43d5a819d946c75eb36eec5d955 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bbad75518f7d4dd9a96e00615345aa0b);
#
#
#         var popup_ef33e36846d28e49f45a41f28395cff2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34425028e982e221cec3fb7782a46958 = $(`&lt;div id=&quot;html_34425028e982e221cec3fb7782a46958&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ef33e36846d28e49f45a41f28395cff2.setContent(html_34425028e982e221cec3fb7782a46958);
#
#
#
#         marker_1955f43d5a819d946c75eb36eec5d955.bindPopup(popup_ef33e36846d28e49f45a41f28395cff2)
#         ;
#
#
#
#
#             var marker_a8a23c8e4d369113c0fccca69a64eea2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bbad75518f7d4dd9a96e00615345aa0b);
#
#
#         var popup_da130fc4404fc476505817756c12cd48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b93a1349e50d53bfb5a11e27f43e51bf = $(`&lt;div id=&quot;html_b93a1349e50d53bfb5a11e27f43e51bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_da130fc4404fc476505817756c12cd48.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_880bd2ebd208b708c6ce4efa52fec424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_880bd2ebd208b708c6ce4efa52fec424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_880bd2ebd208b708c6ce4efa52fec424 = L.map(
#                 &quot;map_880bd2ebd208b708c6ce4efa52fec424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23d17d1abac8fd4a9dbcde4126a5e9a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23d17d1abac8fd4a9dbcde4126a5e9a5.addTo(map_880bd2ebd208b708c6ce4efa52fec424);
#
#
#             var feature_group_e823ba5f3350d334e8b872bb8ab6508d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c8127c41b567169b2e82827777fa505d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e823ba5f3350d334e8b872bb8ab6508d);
#
#
#         var popup_6fe33e776285e3aff88f0ebf6694d939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a35af1a948c84e4c120f23d6e7d84fd4 = $(`&lt;div id=&quot;html_a35af1a948c84e4c120f23d6e7d84fd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6fe33e776285e3aff88f0ebf6694d939.setContent(html_a35af1a948c84e4c120f23d6e7d84fd4);
#
#
#
#         marker_c8127c41b567169b2e82827777fa505d.bindPopup(popup_6fe33e776285e3aff88f0ebf6694d939)
#         ;
#
#
#
#
#             var marker_132dbee2116d7cec89cbcec972c8d94b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e823ba5f3350d334e8b872bb8ab6508d);
#
#
#         var popup_8cf3dae629f8f0a40792dd6bcb539333 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7622ed79fc3543335f1b5b325155d89f = $(`&lt;div id=&quot;html_7622ed79fc3543335f1b5b325155d89f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8cf3dae629f8f0a40792dd6bcb539333.setContent(html_7622ed79fc3543335f1b5b325155d89f);
#
#
#
#         marker_132dbee2116d7cec89cbcec972c8d94b.bindPopup(popup_8cf3dae629f8f0a40792dd6bcb539333)
#         ;
#
#
#
#
#             var marker_0942be8163472d9c969cb07e794431bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e823ba5f3350d334e8b872bb8ab6508d);
#
#
#         var popup_689aeb4d9ec00149ba84266d6432ae39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_204ae8037b264048f5f6ea87bcba047d = $(`&lt;div id=&quot;html_204ae8037b264048f5f6ea87bcba047d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_689aeb4d9ec00149ba84266d6432ae39.setContent(html_204ae8037b264048f5f6ea87bcba047d);
#
#
#
#         marker_0942be8163472d9c969cb07e794431bf.bindPopup(popup_689aeb4d9ec00149ba84266d6432ae39)
#         ;
#
#
#
#
#             var marker_c6987a309fa7003c014f40483d65928b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e823ba5f3350d334e8b872bb8ab6508d);
#
#
#         var popup_b55e7edac843b38335cb6365b85e1b2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcb379d73506cec0323399f76bfa959b = $(`&lt;div id=&quot;html_dcb379d73506cec0323399f76bfa959b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b55e7edac843b38335cb6365b85e1b2d.setContent(html_dcb379d73506cec0323399f76bfa959b);
#
#
#
#         marker_c6987a309fa7003c014f40483d65928b.bindPopup(popup_b55e7edac843b38335cb6365b85e1b2d)
#         ;
#
#
#
#
#             var marker_ad93f35a491aa0175183d899b9ab7050 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e823ba5f3350d334e8b872bb8ab6508d);
#
#
#         var popup_1a33980806a49850e541c42f8f3591ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_540cdf02493e9098f7338962f6026ad9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_540cdf02493e9098f7338962f6026ad9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_540cdf02493e9098f7338962f6026ad9 = L.map(
#                 &quot;map_540cdf02493e9098f7338962f6026ad9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0329e77cf32e095f0844d1c395b98bc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0329e77cf32e095f0844d1c395b98bc4.addTo(map_540cdf02493e9098f7338962f6026ad9);
#
#
#             var feature_group_fb0f2760611f24d3eaf9937104602d0d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fb0f2760611f24d3eaf9937104602d0d.addTo(map_540cdf02493e9098f7338962f6026ad9);
#
#
#             var feature_group_sub_group_c8a23dce7db813e0b4555d9314570064 = L.featureGroup.subGroup(
#                 feature_group_fb0f2760611f24d3eaf9937104602d0d
#             );
#
#
#             var marker_51daa20bd1baa49e2f3ce68a2d286324 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8a23dce7db813e0b4555d9314570064);
#
#
#         var popup_084d9d59e64e1f36de37ba9a5de72637 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f351ea11dc17e30c3d89021d56ca840d = $(`&lt;div id=&quot;html_f351ea11dc17e30c3d89021d56ca840d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_084d9d59e64e1f36de37ba9a5de72637.setContent(html_f351ea11dc17e30c3d89021d56ca840d);
#
#
#
#         marker_51daa20bd1baa49e2f3ce68a2d286324.bindPopup(popup_084d9d59e64e1f36de37ba9a5de72637)
#         ;
#
#
#
#
#             var marker_bee8ade72fc1f9a81f551ada05cf2749 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8a23dce7db813e0b4555d9314570064);
#
#
#         var popup_91b34a31cb84f2617dc2b71cb78bb432 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_156dc92bcb489b7d862ac7fd97be61c3 = $(`&lt;div id=&quot;html_156dc92bcb489b7d862ac7fd97be61c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_91b34a31cb84f2617dc2b71cb78bb432.setContent(html_156dc92bcb489b7d862ac7fd97be61c3);
#
#
#
#         marker_bee8ade72fc1f9a81f551ada05cf2749.bindPopup(popup_91b34a31cb84f2617dc2b71cb78bb432)
#         ;
#
#
#
#
#             var marker_7cd4d4e5cb8b802d0e7467ccffd3f22c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8a23dce7db813e0b4555d9314570064);
#
#
#         var popup_7ea97cc81129430f6584d0a0f10d0656 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0c0c4dce3f87107b2e7b61cf25932cb = $(`&lt;div id=&quot;html_d0c0c4dce3f87107b2e7b61cf25932cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7ea97cc81129430f6584d0a0f10d0656.setContent(html_d0c0c4dce3f87107b2e7b61cf25932cb);
#
#
#
#         marker_7cd4d4e5cb8b802d0e7467ccffd3f22c.bindPopup(popup_7ea97cc81129430f6584d0a0f10d0656)
#         ;
#
#
#
#
#             var marker_a59b3cf92f7404bb36f575d3d342e246 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8a23dce7db813e0b4555d9314570064);
#
#
#         var popup_094ef90869de4963f05d76a9203e5c55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_077241419c60988c66b26198ae7de1e1 = $(`&lt;div id=&quot;html_077241419c60988c66b26198ae7de1e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_094ef90869de4963f05d76a9203e5c55.setContent(html_077241419c60988c66b26198ae7de1e1);
#
#
#
#         marker_
