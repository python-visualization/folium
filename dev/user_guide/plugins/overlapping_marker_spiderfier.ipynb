# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_495b91f9bf2863e353b46aeb68b5ce66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_495b91f9bf2863e353b46aeb68b5ce66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_495b91f9bf2863e353b46aeb68b5ce66 = L.map(
#                 &quot;map_495b91f9bf2863e353b46aeb68b5ce66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fc4f2106c6abdbeb94a2b7c3a5d441b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fc4f2106c6abdbeb94a2b7c3a5d441b.addTo(map_495b91f9bf2863e353b46aeb68b5ce66);
#
#
#             var marker_55afef7e8945420f7d024e3cc79329bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_495b91f9bf2863e353b46aeb68b5ce66);
#
#
#         var popup_98a18cdf43271d591423f2bc388d55e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e5c16b17574d702b48a3155072873fc = $(`&lt;div id=&quot;html_5e5c16b17574d702b48a3155072873fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_98a18cdf43271d591423f2bc388d55e6.setContent(html_5e5c16b17574d702b48a3155072873fc);
#
#
#
#         marker_55afef7e8945420f7d024e3cc79329bf.bindPopup(popup_98a18cdf43271d591423f2bc388d55e6)
#         ;
#
#
#
#
#             var marker_b262d5356e82db531c489a93bd86334b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_495b91f9bf2863e353b46aeb68b5ce66);
#
#
#         var popup_3561aedb35979e6a61c05a1284dbca04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1252a73ebf547ad292f5f1c7996cd39d = $(`&lt;div id=&quot;html_1252a73ebf547ad292f5f1c7996cd39d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3561aedb35979e6a61c05a1284dbca04.setContent(html_1252a73ebf547ad292f5f1c7996cd39d);
#
#
#
#         marker_b262d5356e82db531c489a93bd86334b.bindPopup(popup_3561aedb35979e6a61c05a1284dbca04)
#         ;
#
#
#
#
#             var marker_555ac5098a897a419703c84e9bad000c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_495b91f9bf2863e353b46aeb68b5ce66);
#
#
#         var popup_5c3565b0e0a316251ce39499e0c2f43d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ea56913b4de6f09b2bada1652d6689b = $(`&lt;div id=&quot;html_1ea56913b4de6f09b2bada1652d6689b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5c3565b0e0a316251ce39499e0c2f43d.setContent(html_1ea56913b4de6f09b2bada1652d6689b);
#
#
#
#         marker_555ac5098a897a419703c84e9bad000c.bindPopup(popup_5c3565b0e0a316251ce39499e0c2f43d)
#         ;
#
#
#
#
#             var marker_42cfb857861b5d455f33dad5e20dd8b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_495b91f9bf2863e353b46aeb68b5ce66);
#
#
#         var popup_c30e582903e4eebfc515dfc83b5ec87b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b37c4b8fc997925f82cb12da558b67a1 = $(`&lt;div id=&quot;html_b37c4b8fc997925f82cb12da558b67a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c30e582903e4eebfc515dfc83b5ec87b.setContent(html_b37c4b8fc997925f82cb12da558b67a1);
#
#
#
#         marker_42cfb857861b5d455f33dad5e20dd8b4.bindPopup(popup_c30e582903e4eebfc515dfc83b5ec87b)
#         ;
#
#
#
#
#             var marker_082729ef3d2c8823030f5e18ff1f8737 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_495b91f9bf2863e353b46aeb68b5ce66);
#
#
#         var popup_60c2fd0297eb52ef5f2b3dd88f3d9a3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_629b40986f7b6d6e155ce9777b2cfb9b = $(`&lt;div id=&quot;html_629b40986f7b6d6e155ce9777b2cfb9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_60c2fd0297eb52ef5f2b3dd88f3d9a3a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f24a93ba50d35384b8d7358852db510 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f24a93ba50d35384b8d7358852db510&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f24a93ba50d35384b8d7358852db510 = L.map(
#                 &quot;map_1f24a93ba50d35384b8d7358852db510&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03ed8ce2edc5eff05f9475b940c691af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03ed8ce2edc5eff05f9475b940c691af.addTo(map_1f24a93ba50d35384b8d7358852db510);
#
#
#             var feature_group_d63c645b22c501303825e5084dbf8ad5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_66a35a5857d5ce7f55770f79a679b22b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d63c645b22c501303825e5084dbf8ad5);
#
#
#         var popup_444829c0e44713ef6156165baf80fafe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f6796a44f9c7914d29e311adb102496 = $(`&lt;div id=&quot;html_3f6796a44f9c7914d29e311adb102496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_444829c0e44713ef6156165baf80fafe.setContent(html_3f6796a44f9c7914d29e311adb102496);
#
#
#
#         marker_66a35a5857d5ce7f55770f79a679b22b.bindPopup(popup_444829c0e44713ef6156165baf80fafe)
#         ;
#
#
#
#
#             var marker_39de24f4a49173e5811b76ab32a977fe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d63c645b22c501303825e5084dbf8ad5);
#
#
#         var popup_9e7799041b2a8f1df5157b2a0bad9257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d92857748e17ff4ddbed96c563b9f86b = $(`&lt;div id=&quot;html_d92857748e17ff4ddbed96c563b9f86b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9e7799041b2a8f1df5157b2a0bad9257.setContent(html_d92857748e17ff4ddbed96c563b9f86b);
#
#
#
#         marker_39de24f4a49173e5811b76ab32a977fe.bindPopup(popup_9e7799041b2a8f1df5157b2a0bad9257)
#         ;
#
#
#
#
#             var marker_f7248349a5ee0d08d0c0bd34bcb7424c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d63c645b22c501303825e5084dbf8ad5);
#
#
#         var popup_994aeee4a25d5b7cd0d5a06d6358e1ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0ee427782f8ec65d9843527cb3121dd = $(`&lt;div id=&quot;html_d0ee427782f8ec65d9843527cb3121dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_994aeee4a25d5b7cd0d5a06d6358e1ad.setContent(html_d0ee427782f8ec65d9843527cb3121dd);
#
#
#
#         marker_f7248349a5ee0d08d0c0bd34bcb7424c.bindPopup(popup_994aeee4a25d5b7cd0d5a06d6358e1ad)
#         ;
#
#
#
#
#             var marker_6542cc388b52222a0650f9a97fa984a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d63c645b22c501303825e5084dbf8ad5);
#
#
#         var popup_c610142b30032125f8e188d9c23a5cc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f437468a6cd9dfb3d17c5cbc14f62aab = $(`&lt;div id=&quot;html_f437468a6cd9dfb3d17c5cbc14f62aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c610142b30032125f8e188d9c23a5cc3.setContent(html_f437468a6cd9dfb3d17c5cbc14f62aab);
#
#
#
#         marker_6542cc388b52222a0650f9a97fa984a2.bindPopup(popup_c610142b30032125f8e188d9c23a5cc3)
#         ;
#
#
#
#
#             var marker_464acfeaebc371d4bbd0bffb673a4603 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d63c645b22c501303825e5084dbf8ad5);
#
#
#         var popup_17f870c326ae355c8a29d60e0d96aef0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69f17694295dfcb65f95801f4cb2d0a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69f17694295dfcb65f95801f4cb2d0a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69f17694295dfcb65f95801f4cb2d0a6 = L.map(
#                 &quot;map_69f17694295dfcb65f95801f4cb2d0a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c3f1b3abca6a1d120ead06fd6211ff9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c3f1b3abca6a1d120ead06fd6211ff9.addTo(map_69f17694295dfcb65f95801f4cb2d0a6);
#
#
#             var feature_group_5c362be422dd475c9e64f85d065ca980 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5c362be422dd475c9e64f85d065ca980.addTo(map_69f17694295dfcb65f95801f4cb2d0a6);
#
#
#             var feature_group_sub_group_19ca5997d735980df650e71a5cce69b3 = L.featureGroup.subGroup(
#                 feature_group_5c362be422dd475c9e64f85d065ca980
#             );
#
#
#             var marker_dae6612b2ed4d2322bc00ec97b32f6d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_19ca5997d735980df650e71a5cce69b3);
#
#
#         var popup_c345f4db2ac2b885afffd380e2292f98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6c192f2ee6f6f2605acd463724f336e = $(`&lt;div id=&quot;html_f6c192f2ee6f6f2605acd463724f336e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c345f4db2ac2b885afffd380e2292f98.setContent(html_f6c192f2ee6f6f2605acd463724f336e);
#
#
#
#         marker_dae6612b2ed4d2322bc00ec97b32f6d2.bindPopup(popup_c345f4db2ac2b885afffd380e2292f98)
#         ;
#
#
#
#
#             var marker_940fb951cfa4599de4d8c43c5d34befd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_19ca5997d735980df650e71a5cce69b3);
#
#
#         var popup_c3be87c2cf6bfec95f092dc1955fa0b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7800c86775d2cc3bff81045d544f1883 = $(`&lt;div id=&quot;html_7800c86775d2cc3bff81045d544f1883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3be87c2cf6bfec95f092dc1955fa0b1.setContent(html_7800c86775d2cc3bff81045d544f1883);
#
#
#
#         marker_940fb951cfa4599de4d8c43c5d34befd.bindPopup(popup_c3be87c2cf6bfec95f092dc1955fa0b1)
#         ;
#
#
#
#
#             var marker_56908f1862b59faaa6cd0290c97a40ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_19ca5997d735980df650e71a5cce69b3);
#
#
#         var popup_7ce4f98941261ca3c2f486e01a32d035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a06b4b4b476592422475633c0369c2c6 = $(`&lt;div id=&quot;html_a06b4b4b476592422475633c0369c2c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7ce4f98941261ca3c2f486e01a32d035.setContent(html_a06b4b4b476592422475633c0369c2c6);
#
#
#
#         marker_56908f1862b59faaa6cd0290c97a40ee.bindPopup(popup_7ce4f98941261ca3c2f486e01a32d035)
#         ;
#
#
#
#
#             var marker_4b4f5060c7f36a58432e46a54c39ef04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_19ca5997d735980df650e71a5cce69b3);
#
#
#         var popup_685ea33a4455db2f8ba8d89356c8c568 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ee1ea1d86d96eacdab5665258d47ab6 = $(`&lt;div id=&quot;html_4ee1ea1d86d96eacdab5665258d47ab6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_685ea33a4455db2f8ba8d89356c8c568.setContent(html_4ee1ea1d86d96eacdab5665258d47ab6);
#
#
#
#         marker_
