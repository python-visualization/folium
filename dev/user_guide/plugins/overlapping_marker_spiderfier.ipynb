# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2995d5b13c9868f3b113837db89a62e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2995d5b13c9868f3b113837db89a62e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2995d5b13c9868f3b113837db89a62e = L.map(
#                 &quot;map_b2995d5b13c9868f3b113837db89a62e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_896f1e4fadfa5411fae576df012c3753 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_896f1e4fadfa5411fae576df012c3753.addTo(map_b2995d5b13c9868f3b113837db89a62e);
#
#
#             var marker_bf9eb238157a5c853874c17286d96b5b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b2995d5b13c9868f3b113837db89a62e);
#
#
#         var popup_20b341d430d767536671abf32d8bbf67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f1c75a6a91c36e826b92bf192e69cf7 = $(`&lt;div id=&quot;html_6f1c75a6a91c36e826b92bf192e69cf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_20b341d430d767536671abf32d8bbf67.setContent(html_6f1c75a6a91c36e826b92bf192e69cf7);
#
#
#
#         marker_bf9eb238157a5c853874c17286d96b5b.bindPopup(popup_20b341d430d767536671abf32d8bbf67)
#         ;
#
#
#
#
#             var marker_c5eac8382f7740af64e3c7d366c73fbe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b2995d5b13c9868f3b113837db89a62e);
#
#
#         var popup_00374c0b26742213a978a14973125fa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95d69ac03d2b0425a20e00a3af334e96 = $(`&lt;div id=&quot;html_95d69ac03d2b0425a20e00a3af334e96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_00374c0b26742213a978a14973125fa9.setContent(html_95d69ac03d2b0425a20e00a3af334e96);
#
#
#
#         marker_c5eac8382f7740af64e3c7d366c73fbe.bindPopup(popup_00374c0b26742213a978a14973125fa9)
#         ;
#
#
#
#
#             var marker_ca4fb8f14d75621a09bd125ad9d6e275 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b2995d5b13c9868f3b113837db89a62e);
#
#
#         var popup_83765798f0797b0b6db150d513e2cfea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0a8c9fc465c9c4bb09824ec0b7b4877 = $(`&lt;div id=&quot;html_e0a8c9fc465c9c4bb09824ec0b7b4877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_83765798f0797b0b6db150d513e2cfea.setContent(html_e0a8c9fc465c9c4bb09824ec0b7b4877);
#
#
#
#         marker_ca4fb8f14d75621a09bd125ad9d6e275.bindPopup(popup_83765798f0797b0b6db150d513e2cfea)
#         ;
#
#
#
#
#             var marker_50e47aeee4b67bb86e7838860f6133ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b2995d5b13c9868f3b113837db89a62e);
#
#
#         var popup_9c44db4161179cff37706d3aae85ab3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0ad3cb1658c859c0c371389f86ac77c = $(`&lt;div id=&quot;html_a0ad3cb1658c859c0c371389f86ac77c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9c44db4161179cff37706d3aae85ab3c.setContent(html_a0ad3cb1658c859c0c371389f86ac77c);
#
#
#
#         marker_50e47aeee4b67bb86e7838860f6133ec.bindPopup(popup_9c44db4161179cff37706d3aae85ab3c)
#         ;
#
#
#
#
#             var marker_639d5d2c256e4a7354c123cebacf4c75 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b2995d5b13c9868f3b113837db89a62e);
#
#
#         var popup_37a5a5e2c43cb40b8c6e70238554eeb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_598e99cbab9dd968dc20cf9c6bf787b1 = $(`&lt;div id=&quot;html_598e99cbab9dd968dc20cf9c6bf787b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_37a5a5e2c43cb40b8c6e70238554eeb8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a294ea257eecff88409456a7348e6cbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a294ea257eecff88409456a7348e6cbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a294ea257eecff88409456a7348e6cbd = L.map(
#                 &quot;map_a294ea257eecff88409456a7348e6cbd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b82089030d8c888a5d388abbfe4b1fc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b82089030d8c888a5d388abbfe4b1fc3.addTo(map_a294ea257eecff88409456a7348e6cbd);
#
#
#             var feature_group_601099588cb2857c3fa9f1879e5d3dfe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0f7b65d35e6d93714625be419755db80 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_601099588cb2857c3fa9f1879e5d3dfe);
#
#
#         var popup_01d1c5724075de3c55145e215ad835ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10074144394d978d555cc7b8477cd617 = $(`&lt;div id=&quot;html_10074144394d978d555cc7b8477cd617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_01d1c5724075de3c55145e215ad835ac.setContent(html_10074144394d978d555cc7b8477cd617);
#
#
#
#         marker_0f7b65d35e6d93714625be419755db80.bindPopup(popup_01d1c5724075de3c55145e215ad835ac)
#         ;
#
#
#
#
#             var marker_03613da8ae8c552bbd533ca0f55e357a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_601099588cb2857c3fa9f1879e5d3dfe);
#
#
#         var popup_66ac7a7fa2cecfd921f47a74c00f1106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dcae0ffb09c0b8a5c7541d4d53d3db5 = $(`&lt;div id=&quot;html_7dcae0ffb09c0b8a5c7541d4d53d3db5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_66ac7a7fa2cecfd921f47a74c00f1106.setContent(html_7dcae0ffb09c0b8a5c7541d4d53d3db5);
#
#
#
#         marker_03613da8ae8c552bbd533ca0f55e357a.bindPopup(popup_66ac7a7fa2cecfd921f47a74c00f1106)
#         ;
#
#
#
#
#             var marker_d306ca064d4f9a6b656f3c3367df2b0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_601099588cb2857c3fa9f1879e5d3dfe);
#
#
#         var popup_aa14e86ab125374d4d94717b51298492 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55f5fdf4c788cd58d9710581db97de5d = $(`&lt;div id=&quot;html_55f5fdf4c788cd58d9710581db97de5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aa14e86ab125374d4d94717b51298492.setContent(html_55f5fdf4c788cd58d9710581db97de5d);
#
#
#
#         marker_d306ca064d4f9a6b656f3c3367df2b0f.bindPopup(popup_aa14e86ab125374d4d94717b51298492)
#         ;
#
#
#
#
#             var marker_8d3d5bde8fcfdfb6651f6405c0129bb6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_601099588cb2857c3fa9f1879e5d3dfe);
#
#
#         var popup_815aba0ba52ffa25cede8e4388d1511c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e444e893bd7081adddef42c8b5ffa32 = $(`&lt;div id=&quot;html_9e444e893bd7081adddef42c8b5ffa32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_815aba0ba52ffa25cede8e4388d1511c.setContent(html_9e444e893bd7081adddef42c8b5ffa32);
#
#
#
#         marker_8d3d5bde8fcfdfb6651f6405c0129bb6.bindPopup(popup_815aba0ba52ffa25cede8e4388d1511c)
#         ;
#
#
#
#
#             var marker_569c813e8ce9282f235d4137a2f80052 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_601099588cb2857c3fa9f1879e5d3dfe);
#
#
#         var popup_76ac138569b09c8fa60c7a635b2a4286 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65a026dc16cfbef65ade6af68aee29fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65a026dc16cfbef65ade6af68aee29fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65a026dc16cfbef65ade6af68aee29fb = L.map(
#                 &quot;map_65a026dc16cfbef65ade6af68aee29fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f87101b1a549558ba1298c336329079 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f87101b1a549558ba1298c336329079.addTo(map_65a026dc16cfbef65ade6af68aee29fb);
#
#
#             var feature_group_4e8f24af491e694a0c664a67776aa046 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4e8f24af491e694a0c664a67776aa046.addTo(map_65a026dc16cfbef65ade6af68aee29fb);
#
#
#             var feature_group_sub_group_31564f2d969dca7e5fe7938fa569b1c3 = L.featureGroup.subGroup(
#                 feature_group_4e8f24af491e694a0c664a67776aa046
#             );
#
#
#             var marker_bd431348c6a7fc8c3993979b4e69aa0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_31564f2d969dca7e5fe7938fa569b1c3);
#
#
#         var popup_1430299a4705e10e4095a150d9d81b4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd7835e5adf6d709687689ac88591af6 = $(`&lt;div id=&quot;html_cd7835e5adf6d709687689ac88591af6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1430299a4705e10e4095a150d9d81b4e.setContent(html_cd7835e5adf6d709687689ac88591af6);
#
#
#
#         marker_bd431348c6a7fc8c3993979b4e69aa0f.bindPopup(popup_1430299a4705e10e4095a150d9d81b4e)
#         ;
#
#
#
#
#             var marker_a03c0bae8f60db982eda20da41b730ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_31564f2d969dca7e5fe7938fa569b1c3);
#
#
#         var popup_21e91b89230968a34a50e7a7864dfee2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c53a956761bf970cf526037e4fdd2bb = $(`&lt;div id=&quot;html_5c53a956761bf970cf526037e4fdd2bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_21e91b89230968a34a50e7a7864dfee2.setContent(html_5c53a956761bf970cf526037e4fdd2bb);
#
#
#
#         marker_a03c0bae8f60db982eda20da41b730ee.bindPopup(popup_21e91b89230968a34a50e7a7864dfee2)
#         ;
#
#
#
#
#             var marker_2462abcabe70325f8a107a2939c3cb20 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_31564f2d969dca7e5fe7938fa569b1c3);
#
#
#         var popup_a7c560af97144af657c4bbd37a9d312e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1b7a9dc00334891c463054acd9ffdec = $(`&lt;div id=&quot;html_e1b7a9dc00334891c463054acd9ffdec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a7c560af97144af657c4bbd37a9d312e.setContent(html_e1b7a9dc00334891c463054acd9ffdec);
#
#
#
#         marker_2462abcabe70325f8a107a2939c3cb20.bindPopup(popup_a7c560af97144af657c4bbd37a9d312e)
#         ;
#
#
#
#
#             var marker_41bd144f70fe712f63076c62a8383be7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_31564f2d969dca7e5fe7938fa569b1c3);
#
#
#         var popup_d9812bbc68133f241e19fa786fb220a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_deb1c42132001877bc8cdd1271de5410 = $(`&lt;div id=&quot;html_deb1c42132001877bc8cdd1271de5410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d9812bbc68133f241e19fa786fb220a2.setContent(html_deb1c42132001877bc8cdd1271de5410);
#
#
#
#         marker_
