# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5497b5636c50f9cbaf2fd2ab20092a2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5497b5636c50f9cbaf2fd2ab20092a2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5497b5636c50f9cbaf2fd2ab20092a2d = L.map(
#                 &quot;map_5497b5636c50f9cbaf2fd2ab20092a2d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2400e33952e97f29f95ecaf047711df1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2400e33952e97f29f95ecaf047711df1.addTo(map_5497b5636c50f9cbaf2fd2ab20092a2d);
#
#
#             var marker_b1b3d8a9b62f6586571f961b92002140 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5497b5636c50f9cbaf2fd2ab20092a2d);
#
#
#         var popup_c5f13ae2611ebd4b604f0ac9e0708d22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f21b5633947515e393c1c95311892a60 = $(`&lt;div id=&quot;html_f21b5633947515e393c1c95311892a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c5f13ae2611ebd4b604f0ac9e0708d22.setContent(html_f21b5633947515e393c1c95311892a60);
#
#
#
#         marker_b1b3d8a9b62f6586571f961b92002140.bindPopup(popup_c5f13ae2611ebd4b604f0ac9e0708d22)
#         ;
#
#
#
#
#             var marker_b2b934f8f467dadd28fb2862266b3c28 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5497b5636c50f9cbaf2fd2ab20092a2d);
#
#
#         var popup_b4f0632acd777391a25a5776e5a188a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cce018e64e3b169065d938759921034e = $(`&lt;div id=&quot;html_cce018e64e3b169065d938759921034e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b4f0632acd777391a25a5776e5a188a2.setContent(html_cce018e64e3b169065d938759921034e);
#
#
#
#         marker_b2b934f8f467dadd28fb2862266b3c28.bindPopup(popup_b4f0632acd777391a25a5776e5a188a2)
#         ;
#
#
#
#
#             var marker_a3cd5e88697c4af8e57cf3d3531dab0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5497b5636c50f9cbaf2fd2ab20092a2d);
#
#
#         var popup_241a720266026ede3d5abfde46cfd50a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feddf10e91a2b8954d7c86345482ef8e = $(`&lt;div id=&quot;html_feddf10e91a2b8954d7c86345482ef8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_241a720266026ede3d5abfde46cfd50a.setContent(html_feddf10e91a2b8954d7c86345482ef8e);
#
#
#
#         marker_a3cd5e88697c4af8e57cf3d3531dab0a.bindPopup(popup_241a720266026ede3d5abfde46cfd50a)
#         ;
#
#
#
#
#             var marker_ebb1da91cb2b5f611568f2c6d5654a6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5497b5636c50f9cbaf2fd2ab20092a2d);
#
#
#         var popup_f471b07640ebb946e9b7eb7410f70519 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5207c8da31ce92d5b83b3d8296482bef = $(`&lt;div id=&quot;html_5207c8da31ce92d5b83b3d8296482bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f471b07640ebb946e9b7eb7410f70519.setContent(html_5207c8da31ce92d5b83b3d8296482bef);
#
#
#
#         marker_ebb1da91cb2b5f611568f2c6d5654a6d.bindPopup(popup_f471b07640ebb946e9b7eb7410f70519)
#         ;
#
#
#
#
#             var marker_0748ab3905eb076c77c62aa38e182121 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5497b5636c50f9cbaf2fd2ab20092a2d);
#
#
#         var popup_38b02a8d2f5d78a5da35da3c5dde3e8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abe5ee4d1573c916c7b2b4394dc08745 = $(`&lt;div id=&quot;html_abe5ee4d1573c916c7b2b4394dc08745&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_38b02a8d2f5d78a5da35da3c5dde3e8c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6358a2d64b6347035ccc4a9d2b918c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6358a2d64b6347035ccc4a9d2b918c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6358a2d64b6347035ccc4a9d2b918c8 = L.map(
#                 &quot;map_b6358a2d64b6347035ccc4a9d2b918c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c268f4e48d666a61a0b2960878132d01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c268f4e48d666a61a0b2960878132d01.addTo(map_b6358a2d64b6347035ccc4a9d2b918c8);
#
#
#             var feature_group_1cbf9b4c3187f71eae70e8c95b4d5809 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b814c16c35ca3c1ecf2b15ecc5f3dab4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1cbf9b4c3187f71eae70e8c95b4d5809);
#
#
#         var popup_dab7bdfe491b6c63917ac8132a2fd4fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63568111254bab29c57ec6f8d340c36a = $(`&lt;div id=&quot;html_63568111254bab29c57ec6f8d340c36a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dab7bdfe491b6c63917ac8132a2fd4fa.setContent(html_63568111254bab29c57ec6f8d340c36a);
#
#
#
#         marker_b814c16c35ca3c1ecf2b15ecc5f3dab4.bindPopup(popup_dab7bdfe491b6c63917ac8132a2fd4fa)
#         ;
#
#
#
#
#             var marker_add6692ea3399317a1e5f465daabce4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1cbf9b4c3187f71eae70e8c95b4d5809);
#
#
#         var popup_276f38ec51d584a3c09f63c25faddd88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7adb586497e672e3b5fef4e0b5dc9ce = $(`&lt;div id=&quot;html_a7adb586497e672e3b5fef4e0b5dc9ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_276f38ec51d584a3c09f63c25faddd88.setContent(html_a7adb586497e672e3b5fef4e0b5dc9ce);
#
#
#
#         marker_add6692ea3399317a1e5f465daabce4e.bindPopup(popup_276f38ec51d584a3c09f63c25faddd88)
#         ;
#
#
#
#
#             var marker_c6458d891ab67b3b2363c323603d6a80 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1cbf9b4c3187f71eae70e8c95b4d5809);
#
#
#         var popup_b7fc42062659af8e498f710a47432b68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e949119f1a135c85d5aa1c2747098d4b = $(`&lt;div id=&quot;html_e949119f1a135c85d5aa1c2747098d4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b7fc42062659af8e498f710a47432b68.setContent(html_e949119f1a135c85d5aa1c2747098d4b);
#
#
#
#         marker_c6458d891ab67b3b2363c323603d6a80.bindPopup(popup_b7fc42062659af8e498f710a47432b68)
#         ;
#
#
#
#
#             var marker_a66bee899ea440e08c9ec61e8dc75481 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1cbf9b4c3187f71eae70e8c95b4d5809);
#
#
#         var popup_a3d9a24334950c4d58f90d81cf0aaf44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_596dbd5de1924bedb1c73e082cf59427 = $(`&lt;div id=&quot;html_596dbd5de1924bedb1c73e082cf59427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a3d9a24334950c4d58f90d81cf0aaf44.setContent(html_596dbd5de1924bedb1c73e082cf59427);
#
#
#
#         marker_a66bee899ea440e08c9ec61e8dc75481.bindPopup(popup_a3d9a24334950c4d58f90d81cf0aaf44)
#         ;
#
#
#
#
#             var marker_0d458ed72c04a84ecc56c3f3be5d28da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1cbf9b4c3187f71eae70e8c95b4d5809);
#
#
#         var popup_82c306d0d4c006e4d57f03edb4d6a285 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab11fe02eafc23aa3d920821d5e40c96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab11fe02eafc23aa3d920821d5e40c96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab11fe02eafc23aa3d920821d5e40c96 = L.map(
#                 &quot;map_ab11fe02eafc23aa3d920821d5e40c96&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa1584f4c9e1ac0c5e3821e8920a6871 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa1584f4c9e1ac0c5e3821e8920a6871.addTo(map_ab11fe02eafc23aa3d920821d5e40c96);
#
#
#             var feature_group_c9cd210394591ce0620c195d7d174c47 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c9cd210394591ce0620c195d7d174c47.addTo(map_ab11fe02eafc23aa3d920821d5e40c96);
#
#
#             var feature_group_sub_group_584c31cfcec76295156b715cde2eb968 = L.featureGroup.subGroup(
#                 feature_group_c9cd210394591ce0620c195d7d174c47
#             );
#
#
#             var marker_6d792368a334b28d2d3c09ff0a1f0148 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_584c31cfcec76295156b715cde2eb968);
#
#
#         var popup_0e773f7e9a4b6f0f9f10395a08b78936 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eded4f30687792b049a47565a6cd7082 = $(`&lt;div id=&quot;html_eded4f30687792b049a47565a6cd7082&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0e773f7e9a4b6f0f9f10395a08b78936.setContent(html_eded4f30687792b049a47565a6cd7082);
#
#
#
#         marker_6d792368a334b28d2d3c09ff0a1f0148.bindPopup(popup_0e773f7e9a4b6f0f9f10395a08b78936)
#         ;
#
#
#
#
#             var marker_35d7d4c6beb9779707124c862dc2db4a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_584c31cfcec76295156b715cde2eb968);
#
#
#         var popup_afb7e0020671f2e89123bc27fc559f15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e74c1f25d38e12469cddace7e0834e17 = $(`&lt;div id=&quot;html_e74c1f25d38e12469cddace7e0834e17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_afb7e0020671f2e89123bc27fc559f15.setContent(html_e74c1f25d38e12469cddace7e0834e17);
#
#
#
#         marker_35d7d4c6beb9779707124c862dc2db4a.bindPopup(popup_afb7e0020671f2e89123bc27fc559f15)
#         ;
#
#
#
#
#             var marker_769cb0d217bd30d1c4db1591237966cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_584c31cfcec76295156b715cde2eb968);
#
#
#         var popup_3c0fe2719a19f93f541ef67e36465a53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf3ef5c6c26d0415ca1bb7bac1a4f773 = $(`&lt;div id=&quot;html_cf3ef5c6c26d0415ca1bb7bac1a4f773&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3c0fe2719a19f93f541ef67e36465a53.setContent(html_cf3ef5c6c26d0415ca1bb7bac1a4f773);
#
#
#
#         marker_769cb0d217bd30d1c4db1591237966cf.bindPopup(popup_3c0fe2719a19f93f541ef67e36465a53)
#         ;
#
#
#
#
#             var marker_ee0a41a4e03402e37d89913cec5b6a59 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_584c31cfcec76295156b715cde2eb968);
#
#
#         var popup_43cc88d4be76806eeaf0a4948c7d2dca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c90a9107b50d60ca3342db6946a3237b = $(`&lt;div id=&quot;html_c90a9107b50d60ca3342db6946a3237b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_43cc88d4be76806eeaf0a4948c7d2dca.setContent(html_c90a9107b50d60ca3342db6946a3237b);
#
#
#
#         marker_
