# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_248397d00a42f2437471314077a545e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_248397d00a42f2437471314077a545e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_248397d00a42f2437471314077a545e1 = L.map(
#                 &quot;map_248397d00a42f2437471314077a545e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d7b8c91e96aca6c3f17b9b6dbec9b88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d7b8c91e96aca6c3f17b9b6dbec9b88.addTo(map_248397d00a42f2437471314077a545e1);
#
#
#             var marker_973b7d9c6bb6a46deffbdef6c80b0aa8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_248397d00a42f2437471314077a545e1);
#
#
#         var popup_fc685624af4096db5630b1e1a12b6a25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_095b9ede27cb936c3d0bbbc1b4a46394 = $(`&lt;div id=&quot;html_095b9ede27cb936c3d0bbbc1b4a46394&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fc685624af4096db5630b1e1a12b6a25.setContent(html_095b9ede27cb936c3d0bbbc1b4a46394);
#
#
#
#         marker_973b7d9c6bb6a46deffbdef6c80b0aa8.bindPopup(popup_fc685624af4096db5630b1e1a12b6a25)
#         ;
#
#
#
#
#             var marker_b160c513bf61c72ffd1f179ee7e90acf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_248397d00a42f2437471314077a545e1);
#
#
#         var popup_660477acd5cd3a188defc182795a5149 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a2d8035c0cde2fa0919b81598a86c08 = $(`&lt;div id=&quot;html_5a2d8035c0cde2fa0919b81598a86c08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_660477acd5cd3a188defc182795a5149.setContent(html_5a2d8035c0cde2fa0919b81598a86c08);
#
#
#
#         marker_b160c513bf61c72ffd1f179ee7e90acf.bindPopup(popup_660477acd5cd3a188defc182795a5149)
#         ;
#
#
#
#
#             var marker_2a320a7d7549a6176e55e8ae027cc3db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_248397d00a42f2437471314077a545e1);
#
#
#         var popup_a5a3b3e174170344cc9fe6455e3ac8ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06db284e837a4eae4b3d82548135ca4c = $(`&lt;div id=&quot;html_06db284e837a4eae4b3d82548135ca4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a5a3b3e174170344cc9fe6455e3ac8ff.setContent(html_06db284e837a4eae4b3d82548135ca4c);
#
#
#
#         marker_2a320a7d7549a6176e55e8ae027cc3db.bindPopup(popup_a5a3b3e174170344cc9fe6455e3ac8ff)
#         ;
#
#
#
#
#             var marker_ceb99c50d666cb60563ca415e13a2436 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_248397d00a42f2437471314077a545e1);
#
#
#         var popup_f928c27738dde15cf3b409db3757fd1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ee151b829100c502f8444e206c04ed8 = $(`&lt;div id=&quot;html_9ee151b829100c502f8444e206c04ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f928c27738dde15cf3b409db3757fd1b.setContent(html_9ee151b829100c502f8444e206c04ed8);
#
#
#
#         marker_ceb99c50d666cb60563ca415e13a2436.bindPopup(popup_f928c27738dde15cf3b409db3757fd1b)
#         ;
#
#
#
#
#             var marker_a4ec5e0039a3d53d76e5ee5778474334 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_248397d00a42f2437471314077a545e1);
#
#
#         var popup_1c6ec26a36412b6b6abba2e4249ed81f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab13105df05d21f843f47e707eb851b4 = $(`&lt;div id=&quot;html_ab13105df05d21f843f47e707eb851b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1c6ec26a36412b6b6abba2e4249ed81f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4958b237b2ea334e28496a4c1bcf2b9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4958b237b2ea334e28496a4c1bcf2b9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4958b237b2ea334e28496a4c1bcf2b9d = L.map(
#                 &quot;map_4958b237b2ea334e28496a4c1bcf2b9d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5325623b453d9fc8569de54dbbd25b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5325623b453d9fc8569de54dbbd25b5.addTo(map_4958b237b2ea334e28496a4c1bcf2b9d);
#
#
#             var feature_group_48f9853a057bc0cc8ae44aa0d3759829 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_42fbab0fd836ee19db1f7bc89ba65213 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_48f9853a057bc0cc8ae44aa0d3759829);
#
#
#         var popup_d385e0492383469f20af0668e60abcf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6fa553d58a9469e0e2d61744f1daae1 = $(`&lt;div id=&quot;html_b6fa553d58a9469e0e2d61744f1daae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d385e0492383469f20af0668e60abcf5.setContent(html_b6fa553d58a9469e0e2d61744f1daae1);
#
#
#
#         marker_42fbab0fd836ee19db1f7bc89ba65213.bindPopup(popup_d385e0492383469f20af0668e60abcf5)
#         ;
#
#
#
#
#             var marker_5ac890b5332abaac5a1640d344c771d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_48f9853a057bc0cc8ae44aa0d3759829);
#
#
#         var popup_d7c1029a949834a14efa251e3c0f2428 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd6f212d2bed7bd39b701632b39a02d3 = $(`&lt;div id=&quot;html_fd6f212d2bed7bd39b701632b39a02d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d7c1029a949834a14efa251e3c0f2428.setContent(html_fd6f212d2bed7bd39b701632b39a02d3);
#
#
#
#         marker_5ac890b5332abaac5a1640d344c771d2.bindPopup(popup_d7c1029a949834a14efa251e3c0f2428)
#         ;
#
#
#
#
#             var marker_19577b20b6275c8f478ed7d4069d6ee2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_48f9853a057bc0cc8ae44aa0d3759829);
#
#
#         var popup_c303b5dfe2688ec42fe90aa72da3f859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8813ea1352325d6cbe228590a0334759 = $(`&lt;div id=&quot;html_8813ea1352325d6cbe228590a0334759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c303b5dfe2688ec42fe90aa72da3f859.setContent(html_8813ea1352325d6cbe228590a0334759);
#
#
#
#         marker_19577b20b6275c8f478ed7d4069d6ee2.bindPopup(popup_c303b5dfe2688ec42fe90aa72da3f859)
#         ;
#
#
#
#
#             var marker_5b9f64804a663d68a83ca6a857715270 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_48f9853a057bc0cc8ae44aa0d3759829);
#
#
#         var popup_a6e16ffd44f04a1833263c9b91dce798 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee3a3d2285ac6ffd1318618dee7c9797 = $(`&lt;div id=&quot;html_ee3a3d2285ac6ffd1318618dee7c9797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a6e16ffd44f04a1833263c9b91dce798.setContent(html_ee3a3d2285ac6ffd1318618dee7c9797);
#
#
#
#         marker_5b9f64804a663d68a83ca6a857715270.bindPopup(popup_a6e16ffd44f04a1833263c9b91dce798)
#         ;
#
#
#
#
#             var marker_a627899f29d2933de388b214941309ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_48f9853a057bc0cc8ae44aa0d3759829);
#
#
#         var popup_4caf7fb0341911ad5378c1d1ba50b4e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9639717f5c90a493079f4dcfea3b1f22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9639717f5c90a493079f4dcfea3b1f22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9639717f5c90a493079f4dcfea3b1f22 = L.map(
#                 &quot;map_9639717f5c90a493079f4dcfea3b1f22&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1af4122207e01a1f7f66d1e37a83f051 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1af4122207e01a1f7f66d1e37a83f051.addTo(map_9639717f5c90a493079f4dcfea3b1f22);
#
#
#             var feature_group_14b1574ff63d8e0d1f6cbfc0188ebdec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_14b1574ff63d8e0d1f6cbfc0188ebdec.addTo(map_9639717f5c90a493079f4dcfea3b1f22);
#
#
#             var feature_group_sub_group_24c742de23e74e3a8a904f427f3f4e8a = L.featureGroup.subGroup(
#                 feature_group_14b1574ff63d8e0d1f6cbfc0188ebdec
#             );
#
#
#             var marker_055a5201cd05a8be1f1c19d513c74658 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_24c742de23e74e3a8a904f427f3f4e8a);
#
#
#         var popup_340f19f6f82a4058bd234ea3c0ab2175 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7cb8a5780511c3e26e031f6cda7e0ce = $(`&lt;div id=&quot;html_f7cb8a5780511c3e26e031f6cda7e0ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_340f19f6f82a4058bd234ea3c0ab2175.setContent(html_f7cb8a5780511c3e26e031f6cda7e0ce);
#
#
#
#         marker_055a5201cd05a8be1f1c19d513c74658.bindPopup(popup_340f19f6f82a4058bd234ea3c0ab2175)
#         ;
#
#
#
#
#             var marker_f3273b4fd72f035f4a42d79ed219bcf1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_24c742de23e74e3a8a904f427f3f4e8a);
#
#
#         var popup_48bf79740c8ea53637b3048b7dd756ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccdee059accc5562c70b2e6962e33d76 = $(`&lt;div id=&quot;html_ccdee059accc5562c70b2e6962e33d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_48bf79740c8ea53637b3048b7dd756ee.setContent(html_ccdee059accc5562c70b2e6962e33d76);
#
#
#
#         marker_f3273b4fd72f035f4a42d79ed219bcf1.bindPopup(popup_48bf79740c8ea53637b3048b7dd756ee)
#         ;
#
#
#
#
#             var marker_13a892de5cee0a6773f0d3ea40e66ef9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_24c742de23e74e3a8a904f427f3f4e8a);
#
#
#         var popup_c76711e41555dcc9c2669e85c9ff3cd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12937c79b0f623d80b4ad62efd63ba56 = $(`&lt;div id=&quot;html_12937c79b0f623d80b4ad62efd63ba56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c76711e41555dcc9c2669e85c9ff3cd4.setContent(html_12937c79b0f623d80b4ad62efd63ba56);
#
#
#
#         marker_13a892de5cee0a6773f0d3ea40e66ef9.bindPopup(popup_c76711e41555dcc9c2669e85c9ff3cd4)
#         ;
#
#
#
#
#             var marker_c4f0d0a9c273b40c84c8d2fdf263f03e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_24c742de23e74e3a8a904f427f3f4e8a);
#
#
#         var popup_4ab99ca2d79aa1b1f9b459deaa39a055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4036315297516a51d87f9ee2d692400b = $(`&lt;div id=&quot;html_4036315297516a51d87f9ee2d692400b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4ab99ca2d79aa1b1f9b459deaa39a055.setContent(html_4036315297516a51d87f9ee2d692400b);
#
#
#
#         marker_
