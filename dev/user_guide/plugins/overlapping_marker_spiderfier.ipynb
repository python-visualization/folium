# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af8be7e8b0828887b165084b001cd211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af8be7e8b0828887b165084b001cd211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af8be7e8b0828887b165084b001cd211 = L.map(
#                 &quot;map_af8be7e8b0828887b165084b001cd211&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fae7ca555bec611b034499ba78121bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8fae7ca555bec611b034499ba78121bf.addTo(map_af8be7e8b0828887b165084b001cd211);
#
#
#             var marker_c2e1a6b49bc5fdb6e8b24c61f31a0bbb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_af8be7e8b0828887b165084b001cd211);
#
#
#         var popup_6d080ed30f5841d6ec1ede6b13ba7d32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbf89695633a079bba92b660e7f3c525 = $(`&lt;div id=&quot;html_dbf89695633a079bba92b660e7f3c525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6d080ed30f5841d6ec1ede6b13ba7d32.setContent(html_dbf89695633a079bba92b660e7f3c525);
#
#
#
#         marker_c2e1a6b49bc5fdb6e8b24c61f31a0bbb.bindPopup(popup_6d080ed30f5841d6ec1ede6b13ba7d32)
#         ;
#
#
#
#
#             var marker_3598bb8a1e5f7280d5e0202dc98cb767 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_af8be7e8b0828887b165084b001cd211);
#
#
#         var popup_1b81e2b1f5cdb3d04ab3d560102fdc8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_857a14ba257b3fac1b67728b6d9b23c4 = $(`&lt;div id=&quot;html_857a14ba257b3fac1b67728b6d9b23c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1b81e2b1f5cdb3d04ab3d560102fdc8d.setContent(html_857a14ba257b3fac1b67728b6d9b23c4);
#
#
#
#         marker_3598bb8a1e5f7280d5e0202dc98cb767.bindPopup(popup_1b81e2b1f5cdb3d04ab3d560102fdc8d)
#         ;
#
#
#
#
#             var marker_f023fd19d933ca7bfc073f39bde2854a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_af8be7e8b0828887b165084b001cd211);
#
#
#         var popup_a8fe4d56a5311f240faa8dd9c901a481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc3f31c62ae61eaed362e8997e8ea695 = $(`&lt;div id=&quot;html_fc3f31c62ae61eaed362e8997e8ea695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a8fe4d56a5311f240faa8dd9c901a481.setContent(html_fc3f31c62ae61eaed362e8997e8ea695);
#
#
#
#         marker_f023fd19d933ca7bfc073f39bde2854a.bindPopup(popup_a8fe4d56a5311f240faa8dd9c901a481)
#         ;
#
#
#
#
#             var marker_83d7c80c6f5d28807e918bd1feab027d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_af8be7e8b0828887b165084b001cd211);
#
#
#         var popup_513ece8e3b41025cfbba04c045fe836b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6c4f874326ed99fe54c1771e791f166 = $(`&lt;div id=&quot;html_c6c4f874326ed99fe54c1771e791f166&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_513ece8e3b41025cfbba04c045fe836b.setContent(html_c6c4f874326ed99fe54c1771e791f166);
#
#
#
#         marker_83d7c80c6f5d28807e918bd1feab027d.bindPopup(popup_513ece8e3b41025cfbba04c045fe836b)
#         ;
#
#
#
#
#             var marker_f2415c8da9e4a7572b1ddad3b40bba25 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_af8be7e8b0828887b165084b001cd211);
#
#
#         var popup_d2696c69cff7775033a12118b808677c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_403444e9f04cac2f1b393ed163db177b = $(`&lt;div id=&quot;html_403444e9f04cac2f1b393ed163db177b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d2696c69cff7775033a12118b808677c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fbf5c0e5bd7b08e4c415738e9599e43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fbf5c0e5bd7b08e4c415738e9599e43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fbf5c0e5bd7b08e4c415738e9599e43 = L.map(
#                 &quot;map_9fbf5c0e5bd7b08e4c415738e9599e43&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c277724011f6952597b5bd34cf47c87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c277724011f6952597b5bd34cf47c87.addTo(map_9fbf5c0e5bd7b08e4c415738e9599e43);
#
#
#             var feature_group_26a867573f6474f7cab74ed53681764e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_472dfa68658e47e1663eb124fef1aae2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_26a867573f6474f7cab74ed53681764e);
#
#
#         var popup_ef7f8a9de6a6cab0c72c5ec246a81d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0e99f296d2c1e5edc06703948ca55c9 = $(`&lt;div id=&quot;html_c0e99f296d2c1e5edc06703948ca55c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ef7f8a9de6a6cab0c72c5ec246a81d8e.setContent(html_c0e99f296d2c1e5edc06703948ca55c9);
#
#
#
#         marker_472dfa68658e47e1663eb124fef1aae2.bindPopup(popup_ef7f8a9de6a6cab0c72c5ec246a81d8e)
#         ;
#
#
#
#
#             var marker_54ddcda1fe67891987971cf2680b15d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_26a867573f6474f7cab74ed53681764e);
#
#
#         var popup_f20d2fd3bba5b8a47f8a11a5891ccb6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc517b3072bb528954a39ad32e4dd987 = $(`&lt;div id=&quot;html_dc517b3072bb528954a39ad32e4dd987&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f20d2fd3bba5b8a47f8a11a5891ccb6d.setContent(html_dc517b3072bb528954a39ad32e4dd987);
#
#
#
#         marker_54ddcda1fe67891987971cf2680b15d7.bindPopup(popup_f20d2fd3bba5b8a47f8a11a5891ccb6d)
#         ;
#
#
#
#
#             var marker_b09428cad49b203b6280178502062f98 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_26a867573f6474f7cab74ed53681764e);
#
#
#         var popup_b2811f1f1134a352db3fbf4abcbbbd2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7d7bb9da5aad441de533dada2ea1bbf = $(`&lt;div id=&quot;html_d7d7bb9da5aad441de533dada2ea1bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b2811f1f1134a352db3fbf4abcbbbd2e.setContent(html_d7d7bb9da5aad441de533dada2ea1bbf);
#
#
#
#         marker_b09428cad49b203b6280178502062f98.bindPopup(popup_b2811f1f1134a352db3fbf4abcbbbd2e)
#         ;
#
#
#
#
#             var marker_906d6280bc7f0e3d293860ec295b52a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_26a867573f6474f7cab74ed53681764e);
#
#
#         var popup_366fee6a975140a0a759e4c749cc488d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c4c3965201a36f4a36b6d27a2bcecd0 = $(`&lt;div id=&quot;html_6c4c3965201a36f4a36b6d27a2bcecd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_366fee6a975140a0a759e4c749cc488d.setContent(html_6c4c3965201a36f4a36b6d27a2bcecd0);
#
#
#
#         marker_906d6280bc7f0e3d293860ec295b52a8.bindPopup(popup_366fee6a975140a0a759e4c749cc488d)
#         ;
#
#
#
#
#             var marker_7e7bbb0bb0ecf18fb66b206a38694eb4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_26a867573f6474f7cab74ed53681764e);
#
#
#         var popup_fe63fe4c23ba64392c3c74b2d022dfe2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e16c6ed7ff78c39347df7a33df5c2ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e16c6ed7ff78c39347df7a33df5c2ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e16c6ed7ff78c39347df7a33df5c2ed = L.map(
#                 &quot;map_5e16c6ed7ff78c39347df7a33df5c2ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab806d797b557d8cc28802964d00b030 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab806d797b557d8cc28802964d00b030.addTo(map_5e16c6ed7ff78c39347df7a33df5c2ed);
#
#
#             var feature_group_eb55f26932fe257a973ce7124af593b0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eb55f26932fe257a973ce7124af593b0.addTo(map_5e16c6ed7ff78c39347df7a33df5c2ed);
#
#
#             var feature_group_sub_group_039bce2fca74d781f7d4cdad6a1e65cc = L.featureGroup.subGroup(
#                 feature_group_eb55f26932fe257a973ce7124af593b0
#             );
#
#
#             var marker_3b552c081496c1cc0476fa85e0d87ad4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_039bce2fca74d781f7d4cdad6a1e65cc);
#
#
#         var popup_5339af5355645b2696956435d13b541f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f8fb5df2b1985837211305dfdce802f = $(`&lt;div id=&quot;html_1f8fb5df2b1985837211305dfdce802f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5339af5355645b2696956435d13b541f.setContent(html_1f8fb5df2b1985837211305dfdce802f);
#
#
#
#         marker_3b552c081496c1cc0476fa85e0d87ad4.bindPopup(popup_5339af5355645b2696956435d13b541f)
#         ;
#
#
#
#
#             var marker_46e2f29e2a7d66cb4ca19145453e8a1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_039bce2fca74d781f7d4cdad6a1e65cc);
#
#
#         var popup_2e7d0f4df0ec16b599a7cc74095aac56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37a03f7ba7da139193762d8229acdebb = $(`&lt;div id=&quot;html_37a03f7ba7da139193762d8229acdebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2e7d0f4df0ec16b599a7cc74095aac56.setContent(html_37a03f7ba7da139193762d8229acdebb);
#
#
#
#         marker_46e2f29e2a7d66cb4ca19145453e8a1f.bindPopup(popup_2e7d0f4df0ec16b599a7cc74095aac56)
#         ;
#
#
#
#
#             var marker_1ca6b98e7613f8d08b4cc20345acd511 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_039bce2fca74d781f7d4cdad6a1e65cc);
#
#
#         var popup_88d0b8f7a9e6410c0b4d1a0426f14d9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_409ee6988a3609e63e59efb1046acd0e = $(`&lt;div id=&quot;html_409ee6988a3609e63e59efb1046acd0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88d0b8f7a9e6410c0b4d1a0426f14d9d.setContent(html_409ee6988a3609e63e59efb1046acd0e);
#
#
#
#         marker_1ca6b98e7613f8d08b4cc20345acd511.bindPopup(popup_88d0b8f7a9e6410c0b4d1a0426f14d9d)
#         ;
#
#
#
#
#             var marker_275b106c142521c11186e7b7e0d22d75 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_039bce2fca74d781f7d4cdad6a1e65cc);
#
#
#         var popup_37c1eb27f9b98ff718843a194dd3c609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a1903930b3b14d5cf4554aa01610906 = $(`&lt;div id=&quot;html_3a1903930b3b14d5cf4554aa01610906&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_37c1eb27f9b98ff718843a194dd3c609.setContent(html_3a1903930b3b14d5cf4554aa01610906);
#
#
#
#         marker_
