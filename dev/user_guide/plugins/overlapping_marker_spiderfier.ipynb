# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d980225fdb0c1cde71ebfa00290bcf1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d980225fdb0c1cde71ebfa00290bcf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d980225fdb0c1cde71ebfa00290bcf1 = L.map(
#                 &quot;map_2d980225fdb0c1cde71ebfa00290bcf1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ce26c5921ebb5e5dfca170b511102c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ce26c5921ebb5e5dfca170b511102c4.addTo(map_2d980225fdb0c1cde71ebfa00290bcf1);
#
#
#             var marker_c9d6c14ebd7669e8426a45f36ca4ad2f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2d980225fdb0c1cde71ebfa00290bcf1);
#
#
#         var popup_abd69ac2cdf57ccea9dbe724636757d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f733458e077ed6e09acf6ad26cccae9 = $(`&lt;div id=&quot;html_9f733458e077ed6e09acf6ad26cccae9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_abd69ac2cdf57ccea9dbe724636757d6.setContent(html_9f733458e077ed6e09acf6ad26cccae9);
#
#
#
#         marker_c9d6c14ebd7669e8426a45f36ca4ad2f.bindPopup(popup_abd69ac2cdf57ccea9dbe724636757d6)
#         ;
#
#
#
#
#             var marker_9b68368033b9551731fc3538859d4f6b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2d980225fdb0c1cde71ebfa00290bcf1);
#
#
#         var popup_a3a437c0c19db71243be8b5ef76ac942 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b1a7204fb0fd96acb46301b528457a7 = $(`&lt;div id=&quot;html_9b1a7204fb0fd96acb46301b528457a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a3a437c0c19db71243be8b5ef76ac942.setContent(html_9b1a7204fb0fd96acb46301b528457a7);
#
#
#
#         marker_9b68368033b9551731fc3538859d4f6b.bindPopup(popup_a3a437c0c19db71243be8b5ef76ac942)
#         ;
#
#
#
#
#             var marker_9fb5690a503e1a11513692b4eecdc8ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2d980225fdb0c1cde71ebfa00290bcf1);
#
#
#         var popup_a58393175507e97cd50fd3a514543a3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e4a9dc7e125fe18bfffcf979f1e3333 = $(`&lt;div id=&quot;html_8e4a9dc7e125fe18bfffcf979f1e3333&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a58393175507e97cd50fd3a514543a3c.setContent(html_8e4a9dc7e125fe18bfffcf979f1e3333);
#
#
#
#         marker_9fb5690a503e1a11513692b4eecdc8ef.bindPopup(popup_a58393175507e97cd50fd3a514543a3c)
#         ;
#
#
#
#
#             var marker_4332a9cada7b8dc6af78c1a5b01db209 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2d980225fdb0c1cde71ebfa00290bcf1);
#
#
#         var popup_44d1a463eadfcdfedfccefe908b0e799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20197355874d09e3cee82a05716ac5dd = $(`&lt;div id=&quot;html_20197355874d09e3cee82a05716ac5dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_44d1a463eadfcdfedfccefe908b0e799.setContent(html_20197355874d09e3cee82a05716ac5dd);
#
#
#
#         marker_4332a9cada7b8dc6af78c1a5b01db209.bindPopup(popup_44d1a463eadfcdfedfccefe908b0e799)
#         ;
#
#
#
#
#             var marker_af81e7269a740bea4f08aeb29c734c71 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2d980225fdb0c1cde71ebfa00290bcf1);
#
#
#         var popup_ffd1dbb293d667abab80159ccd4abf32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6158593aad815fd2b1460b4b1271dc9 = $(`&lt;div id=&quot;html_a6158593aad815fd2b1460b4b1271dc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ffd1dbb293d667abab80159ccd4abf

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_968876103570916e0a00e76541fef92a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_968876103570916e0a00e76541fef92a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_968876103570916e0a00e76541fef92a = L.map(
#                 &quot;map_968876103570916e0a00e76541fef92a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4f1dac99778518f1caa8a67effc9cb5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4f1dac99778518f1caa8a67effc9cb5.addTo(map_968876103570916e0a00e76541fef92a);
#
#
#             var feature_group_047e1bf3393313a03e970345b67a15fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17ac331fdea65bacfd5d98136d8c79ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_047e1bf3393313a03e970345b67a15fe);
#
#
#         var popup_7cbcefc54e177fbf96a976dc8537a5ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0097b03a3b7832adc23e6236f2c5d66 = $(`&lt;div id=&quot;html_d0097b03a3b7832adc23e6236f2c5d66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7cbcefc54e177fbf96a976dc8537a5ce.setContent(html_d0097b03a3b7832adc23e6236f2c5d66);
#
#
#
#         marker_17ac331fdea65bacfd5d98136d8c79ef.bindPopup(popup_7cbcefc54e177fbf96a976dc8537a5ce)
#         ;
#
#
#
#
#             var marker_19fa3bd047bc6cfcf6eae726a794df64 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_047e1bf3393313a03e970345b67a15fe);
#
#
#         var popup_eb1c35981be065f9f76c0c54cec9326a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64afba35b6dd3fca510d8a19c7094792 = $(`&lt;div id=&quot;html_64afba35b6dd3fca510d8a19c7094792&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eb1c35981be065f9f76c0c54cec9326a.setContent(html_64afba35b6dd3fca510d8a19c7094792);
#
#
#
#         marker_19fa3bd047bc6cfcf6eae726a794df64.bindPopup(popup_eb1c35981be065f9f76c0c54cec9326a)
#         ;
#
#
#
#
#             var marker_cdcef55439eb40fe9bd716fde1c1e2fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_047e1bf3393313a03e970345b67a15fe);
#
#
#         var popup_2b8b7ad09cc395aa6e0ea132f2a2a43a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_436991d87465eda8bcffab31e3984a73 = $(`&lt;div id=&quot;html_436991d87465eda8bcffab31e3984a73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2b8b7ad09cc395aa6e0ea132f2a2a43a.setContent(html_436991d87465eda8bcffab31e3984a73);
#
#
#
#         marker_cdcef55439eb40fe9bd716fde1c1e2fa.bindPopup(popup_2b8b7ad09cc395aa6e0ea132f2a2a43a)
#         ;
#
#
#
#
#             var marker_aba710aff6e7916a292f89f79785b4d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_047e1bf3393313a03e970345b67a15fe);
#
#
#         var popup_2991048f609be687318a2212bd8b30d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a7e3ebc9a41d7bf49e3c8c4738a8d28 = $(`&lt;div id=&quot;html_6a7e3ebc9a41d7bf49e3c8c4738a8d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2991048f609be687318a2212bd8b30d8.setContent(html_6a7e3ebc9a41d7bf49e3c8c4738a8d28);
#
#
#
#         marker_aba710aff6e7916a292f89f79785b4d6.bindPopup(popup_2991048f609be687318a2212bd8b30d8)
#         ;
#
#
#
#
#             var marker_75511414d0ac14731819cbf87a9d883e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_047e1bf3393313a03e970345b67a15fe);
#
#
#         var popup_730ffdb1d3376bf781aa05a8473abd66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2b1bcbddfc9ceac02a34978e400bd1f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2b1bcbddfc9ceac02a34978e400bd1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2b1bcbddfc9ceac02a34978e400bd1f = L.map(
#                 &quot;map_b2b1bcbddfc9ceac02a34978e400bd1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59e2226b3bd5a32c5dd119a8b801b139 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59e2226b3bd5a32c5dd119a8b801b139.addTo(map_b2b1bcbddfc9ceac02a34978e400bd1f);
#
#
#             var feature_group_9e66f56da9f9eb8f913b825e16b9e1c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9e66f56da9f9eb8f913b825e16b9e1c8.addTo(map_b2b1bcbddfc9ceac02a34978e400bd1f);
#
#
#             var feature_group_sub_group_452aaa7a810639b388981283f3037159 = L.featureGroup.subGroup(
#                 feature_group_9e66f56da9f9eb8f913b825e16b9e1c8
#             );
#
#
#             var marker_d0dc41d6ddd203303a14d93ca8ba4832 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_452aaa7a810639b388981283f3037159);
#
#
#         var popup_49ac98f694108638b0f31e1f88de44d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_020d900abcb22b0a588e9a53ebb0fea7 = $(`&lt;div id=&quot;html_020d900abcb22b0a588e9a53ebb0fea7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_49ac98f694108638b0f31e1f88de44d3.setContent(html_020d900abcb22b0a588e9a53ebb0fea7);
#
#
#
#         marker_d0dc41d6ddd203303a14d93ca8ba4832.bindPopup(popup_49ac98f694108638b0f31e1f88de44d3)
#         ;
#
#
#
#
#             var marker_b797f21fa5443620e4c8bfe5c8ca2008 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_452aaa7a810639b388981283f3037159);
#
#
#         var popup_738f5d6f0b4e5d72fda6b939bbe092c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ab5138a83ead536b128cb33890e92b4 = $(`&lt;div id=&quot;html_4ab5138a83ead536b128cb33890e92b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_738f5d6f0b4e5d72fda6b939bbe092c7.setContent(html_4ab5138a83ead536b128cb33890e92b4);
#
#
#
#         marker_b797f21fa5443620e4c8bfe5c8ca2008.bindPopup(popup_738f5d6f0b4e5d72fda6b939bbe092c7)
#         ;
#
#
#
#
#             var marker_3821d4a55ee300ca98ea28915b58b263 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_452aaa7a810639b388981283f3037159);
#
#
#         var popup_6ffef1dd6d18648eed161b9b999069ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8982765ae40453509ab9f0a558d9ba21 = $(`&lt;div id=&quot;html_8982765ae40453509ab9f0a558d9ba21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6ffef1dd6d18648eed161b9b999069ee.setContent(html_8982765ae40453509ab9f0a558d9ba21);
#
#
#
#         marker_3821d4a55ee300ca98ea28915b58b263.bindPopup(popup_6ffef1dd6d18648eed161b9b999069ee)
#         ;
#
#
#
#
#             var marker_bbae9da1faf49267fba45da872df3b6a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_452aaa7a810639b388981283f3037159);
#
#
#         var popup_3004c8f73f1d904f257ea542988762a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_810316c2c8dd4fbfe50934c5f2a330b9 = $(`&lt;div id=&quot;html_810316c2c8dd4fbfe50934c5f2a330b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3004c8f73f1d904f257ea542988762a7.setContent(html_810316c2c8dd4fbfe50934c5f2a330b9);
#
#
#
#         mark
