# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dce311ddcb8d2dac5e14ff1b5f8d7491 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dce311ddcb8d2dac5e14ff1b5f8d7491&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dce311ddcb8d2dac5e14ff1b5f8d7491 = L.map(
#                 &quot;map_dce311ddcb8d2dac5e14ff1b5f8d7491&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38f641b988b92120e7ae961e3a824cce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38f641b988b92120e7ae961e3a824cce.addTo(map_dce311ddcb8d2dac5e14ff1b5f8d7491);
#
#
#             var marker_2a3570133620622891529a97e1f60958 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dce311ddcb8d2dac5e14ff1b5f8d7491);
#
#
#         var popup_07402a83aee8f43643e460b0fdea79e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72b235d833bc61be9752cc7380a258e2 = $(`&lt;div id=&quot;html_72b235d833bc61be9752cc7380a258e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_07402a83aee8f43643e460b0fdea79e8.setContent(html_72b235d833bc61be9752cc7380a258e2);
#
#
#
#         marker_2a3570133620622891529a97e1f60958.bindPopup(popup_07402a83aee8f43643e460b0fdea79e8)
#         ;
#
#
#
#
#             var marker_6f9027db62d464910d70c8e407391b28 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dce311ddcb8d2dac5e14ff1b5f8d7491);
#
#
#         var popup_c446efe2b69d6ca2fa36bce886a1d854 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0f30038f2b882dd26722ac75c2b53e2 = $(`&lt;div id=&quot;html_f0f30038f2b882dd26722ac75c2b53e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c446efe2b69d6ca2fa36bce886a1d854.setContent(html_f0f30038f2b882dd26722ac75c2b53e2);
#
#
#
#         marker_6f9027db62d464910d70c8e407391b28.bindPopup(popup_c446efe2b69d6ca2fa36bce886a1d854)
#         ;
#
#
#
#
#             var marker_79ac9e340b0722920cd1073e87d325b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dce311ddcb8d2dac5e14ff1b5f8d7491);
#
#
#         var popup_3c94051b918144dae45f355b0b926bdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7da4a7a34fd4be61ff03643d3fd2ce84 = $(`&lt;div id=&quot;html_7da4a7a34fd4be61ff03643d3fd2ce84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3c94051b918144dae45f355b0b926bdb.setContent(html_7da4a7a34fd4be61ff03643d3fd2ce84);
#
#
#
#         marker_79ac9e340b0722920cd1073e87d325b6.bindPopup(popup_3c94051b918144dae45f355b0b926bdb)
#         ;
#
#
#
#
#             var marker_ee6283ea0aa6f91ec839e12c582a1402 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dce311ddcb8d2dac5e14ff1b5f8d7491);
#
#
#         var popup_42cbf6337034a3eed536a607312981aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c83f5b6e5e9cce6334ac3a97d9c75c0 = $(`&lt;div id=&quot;html_6c83f5b6e5e9cce6334ac3a97d9c75c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_42cbf6337034a3eed536a607312981aa.setContent(html_6c83f5b6e5e9cce6334ac3a97d9c75c0);
#
#
#
#         marker_ee6283ea0aa6f91ec839e12c582a1402.bindPopup(popup_42cbf6337034a3eed536a607312981aa)
#         ;
#
#
#
#
#             var marker_caa8b1fe21e881dca0d904b18bdfd49d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dce311ddcb8d2dac5e14ff1b5f8d7491);
#
#
#         var popup_9bcf1531f9471fe7e5ab8b9add56d079 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eaa0674323421fafb5758ed6c5056ce = $(`&lt;div id=&quot;html_2eaa0674323421fafb5758ed6c5056ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9bcf1531f9471fe7e5ab8b9add56d079.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a3891a9ea2b86dd2926f2ea8a7b1f20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a3891a9ea2b86dd2926f2ea8a7b1f20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a3891a9ea2b86dd2926f2ea8a7b1f20 = L.map(
#                 &quot;map_9a3891a9ea2b86dd2926f2ea8a7b1f20&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5ec16df973b3f992b6af4bd250e1bb8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5ec16df973b3f992b6af4bd250e1bb8.addTo(map_9a3891a9ea2b86dd2926f2ea8a7b1f20);
#
#
#             var feature_group_acd3c9429d5bb6f80ddc46aa8c3f7dae = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c223bc8d8cac4103de0a26f7580e2a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_acd3c9429d5bb6f80ddc46aa8c3f7dae);
#
#
#         var popup_0943f43d5ed9b763f3e38333c2ec6bae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca1ee8cd0624370353fc3c494506baa4 = $(`&lt;div id=&quot;html_ca1ee8cd0624370353fc3c494506baa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0943f43d5ed9b763f3e38333c2ec6bae.setContent(html_ca1ee8cd0624370353fc3c494506baa4);
#
#
#
#         marker_2c223bc8d8cac4103de0a26f7580e2a9.bindPopup(popup_0943f43d5ed9b763f3e38333c2ec6bae)
#         ;
#
#
#
#
#             var marker_16f31b06e03d88e44ce9fb294052abea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_acd3c9429d5bb6f80ddc46aa8c3f7dae);
#
#
#         var popup_3d9d2af838c4433b7186ed38ae811697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a832b962a10b213e580bd84523dfc4da = $(`&lt;div id=&quot;html_a832b962a10b213e580bd84523dfc4da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3d9d2af838c4433b7186ed38ae811697.setContent(html_a832b962a10b213e580bd84523dfc4da);
#
#
#
#         marker_16f31b06e03d88e44ce9fb294052abea.bindPopup(popup_3d9d2af838c4433b7186ed38ae811697)
#         ;
#
#
#
#
#             var marker_dd907509115d5a95221dd27dba37a181 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_acd3c9429d5bb6f80ddc46aa8c3f7dae);
#
#
#         var popup_651d3b6b388774a69ec22df83e72b654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01da0bbea7c84266c645282e028bdda4 = $(`&lt;div id=&quot;html_01da0bbea7c84266c645282e028bdda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_651d3b6b388774a69ec22df83e72b654.setContent(html_01da0bbea7c84266c645282e028bdda4);
#
#
#
#         marker_dd907509115d5a95221dd27dba37a181.bindPopup(popup_651d3b6b388774a69ec22df83e72b654)
#         ;
#
#
#
#
#             var marker_b93318c5c784908ca237369a13f12650 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_acd3c9429d5bb6f80ddc46aa8c3f7dae);
#
#
#         var popup_d32474ffc6cc82be10e168acd32ad666 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38f7a0519421d5e1502b955fb5c4213f = $(`&lt;div id=&quot;html_38f7a0519421d5e1502b955fb5c4213f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d32474ffc6cc82be10e168acd32ad666.setContent(html_38f7a0519421d5e1502b955fb5c4213f);
#
#
#
#         marker_b93318c5c784908ca237369a13f12650.bindPopup(popup_d32474ffc6cc82be10e168acd32ad666)
#         ;
#
#
#
#
#             var marker_38699702f87c3fe213b8c952d0c804da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_acd3c9429d5bb6f80ddc46aa8c3f7dae);
#
#
#         var popup_779c8b5f362b91c2a26d189ec972e495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d38c760f8194e6ed8bb0e4d9dc4cd24c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d38c760f8194e6ed8bb0e4d9dc4cd24c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d38c760f8194e6ed8bb0e4d9dc4cd24c = L.map(
#                 &quot;map_d38c760f8194e6ed8bb0e4d9dc4cd24c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b4f6048e29a7e4bd7d7721af1a483dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b4f6048e29a7e4bd7d7721af1a483dd.addTo(map_d38c760f8194e6ed8bb0e4d9dc4cd24c);
#
#
#             var feature_group_1ed664420e38c95777ff4325c890a82a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1ed664420e38c95777ff4325c890a82a.addTo(map_d38c760f8194e6ed8bb0e4d9dc4cd24c);
#
#
#             var feature_group_sub_group_8e6d7569022d9691ced6598cd8cd7ee2 = L.featureGroup.subGroup(
#                 feature_group_1ed664420e38c95777ff4325c890a82a
#             );
#
#
#             var marker_826400cdd61093471ca992ccdb66d3aa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e6d7569022d9691ced6598cd8cd7ee2);
#
#
#         var popup_e885244f70dc521cb2e246f9797cc85c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26c8c02f424feef1859a907461048e4f = $(`&lt;div id=&quot;html_26c8c02f424feef1859a907461048e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e885244f70dc521cb2e246f9797cc85c.setContent(html_26c8c02f424feef1859a907461048e4f);
#
#
#
#         marker_826400cdd61093471ca992ccdb66d3aa.bindPopup(popup_e885244f70dc521cb2e246f9797cc85c)
#         ;
#
#
#
#
#             var marker_f48abe28613d0dc2e33f4bfb936f8c24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e6d7569022d9691ced6598cd8cd7ee2);
#
#
#         var popup_e058f8d8d80d52dee2f6448ac72f8b77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e2d565b3278359a2f80466a0103ec4e = $(`&lt;div id=&quot;html_0e2d565b3278359a2f80466a0103ec4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e058f8d8d80d52dee2f6448ac72f8b77.setContent(html_0e2d565b3278359a2f80466a0103ec4e);
#
#
#
#         marker_f48abe28613d0dc2e33f4bfb936f8c24.bindPopup(popup_e058f8d8d80d52dee2f6448ac72f8b77)
#         ;
#
#
#
#
#             var marker_e72b69936b9ff439a82509cf8aa68f11 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e6d7569022d9691ced6598cd8cd7ee2);
#
#
#         var popup_229ad5fa9bc3a997c563bdfa1185730e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a6011c0d11bec392fdb553185d395dd = $(`&lt;div id=&quot;html_8a6011c0d11bec392fdb553185d395dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_229ad5fa9bc3a997c563bdfa1185730e.setContent(html_8a6011c0d11bec392fdb553185d395dd);
#
#
#
#         marker_e72b69936b9ff439a82509cf8aa68f11.bindPopup(popup_229ad5fa9bc3a997c563bdfa1185730e)
#         ;
#
#
#
#
#             var marker_f8e567e1be2ade7c29927288393d705e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e6d7569022d9691ced6598cd8cd7ee2);
#
#
#         var popup_a680fddc08bd66422face3dfe93b48b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc4b1ddedc7765675f7af6ad7bdd202c = $(`&lt;div id=&quot;html_cc4b1ddedc7765675f7af6ad7bdd202c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a680fddc08bd66422face3dfe93b48b1.setContent(html_cc4b1ddedc7765675f7af6ad7bdd202c);
#
#
#
#         marker_
