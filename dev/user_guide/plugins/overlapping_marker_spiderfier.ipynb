# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d85b3eee9b350b2c91a7cc12f2211df1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d85b3eee9b350b2c91a7cc12f2211df1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d85b3eee9b350b2c91a7cc12f2211df1 = L.map(
#                 &quot;map_d85b3eee9b350b2c91a7cc12f2211df1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7242e6eeafb73da7c7e9356211fee2a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7242e6eeafb73da7c7e9356211fee2a3.addTo(map_d85b3eee9b350b2c91a7cc12f2211df1);
#
#
#             var marker_9058c4a21f57d2b97e4a3ed87c884551 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d85b3eee9b350b2c91a7cc12f2211df1);
#
#
#         var popup_f68e4862dcb073fbc9d08ff78c72831b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e56c139cebdf23c4c5c66e9e99d1468 = $(`&lt;div id=&quot;html_7e56c139cebdf23c4c5c66e9e99d1468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f68e4862dcb073fbc9d08ff78c72831b.setContent(html_7e56c139cebdf23c4c5c66e9e99d1468);
#
#
#
#         marker_9058c4a21f57d2b97e4a3ed87c884551.bindPopup(popup_f68e4862dcb073fbc9d08ff78c72831b)
#         ;
#
#
#
#
#             var marker_e6c351db089b74e27e42db757979649d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d85b3eee9b350b2c91a7cc12f2211df1);
#
#
#         var popup_dcd9a7e066aa7087f46f800cea1d1ff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7983fb9127d3db3e03592b3396292f5d = $(`&lt;div id=&quot;html_7983fb9127d3db3e03592b3396292f5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dcd9a7e066aa7087f46f800cea1d1ff4.setContent(html_7983fb9127d3db3e03592b3396292f5d);
#
#
#
#         marker_e6c351db089b74e27e42db757979649d.bindPopup(popup_dcd9a7e066aa7087f46f800cea1d1ff4)
#         ;
#
#
#
#
#             var marker_7d3f1e6027be8db3e568b19c1fc3fd3d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d85b3eee9b350b2c91a7cc12f2211df1);
#
#
#         var popup_fead3f9d3ee69dd74ec62371ad665ef4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8751920122e3ca8967462d17c4d02f4 = $(`&lt;div id=&quot;html_f8751920122e3ca8967462d17c4d02f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fead3f9d3ee69dd74ec62371ad665ef4.setContent(html_f8751920122e3ca8967462d17c4d02f4);
#
#
#
#         marker_7d3f1e6027be8db3e568b19c1fc3fd3d.bindPopup(popup_fead3f9d3ee69dd74ec62371ad665ef4)
#         ;
#
#
#
#
#             var marker_beca8a6665aef92f0b784995bc645dc0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d85b3eee9b350b2c91a7cc12f2211df1);
#
#
#         var popup_0b4dbe727278bf734f6d8452f7ab869f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a3d7b5f290ebdb7689cf110dfe90164 = $(`&lt;div id=&quot;html_8a3d7b5f290ebdb7689cf110dfe90164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0b4dbe727278bf734f6d8452f7ab869f.setContent(html_8a3d7b5f290ebdb7689cf110dfe90164);
#
#
#
#         marker_beca8a6665aef92f0b784995bc645dc0.bindPopup(popup_0b4dbe727278bf734f6d8452f7ab869f)
#         ;
#
#
#
#
#             var marker_7f136a439d801af7362a34feaabf1b9d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d85b3eee9b350b2c91a7cc12f2211df1);
#
#
#         var popup_aeb6ab68aa408cf253433e606546a557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6ef1c7c3b056c3dec0e1531439dc598 = $(`&lt;div id=&quot;html_a6ef1c7c3b056c3dec0e1531439dc598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aeb6ab68aa408cf253433e606546a557.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef893073c09efcd5d210a127242da734 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef893073c09efcd5d210a127242da734&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef893073c09efcd5d210a127242da734 = L.map(
#                 &quot;map_ef893073c09efcd5d210a127242da734&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1248dccb715176ed79b6eedfaf103d05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1248dccb715176ed79b6eedfaf103d05.addTo(map_ef893073c09efcd5d210a127242da734);
#
#
#             var feature_group_d9d4c96cca95760428c91ca98978fe61 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fa956aa050d040a159fa0631d08e67db = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d9d4c96cca95760428c91ca98978fe61);
#
#
#         var popup_06d0d4762fd6f549e16a4259a39ae280 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60b0da55da1795f0b5767cd4d1807403 = $(`&lt;div id=&quot;html_60b0da55da1795f0b5767cd4d1807403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_06d0d4762fd6f549e16a4259a39ae280.setContent(html_60b0da55da1795f0b5767cd4d1807403);
#
#
#
#         marker_fa956aa050d040a159fa0631d08e67db.bindPopup(popup_06d0d4762fd6f549e16a4259a39ae280)
#         ;
#
#
#
#
#             var marker_742a2c0ec4bcb6ed48d75b0f8a4b62cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d9d4c96cca95760428c91ca98978fe61);
#
#
#         var popup_1ca2d063cd8009d65ff8800a3aad9440 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ed64109f7a4090a94bb88bd12ac87e = $(`&lt;div id=&quot;html_52ed64109f7a4090a94bb88bd12ac87e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1ca2d063cd8009d65ff8800a3aad9440.setContent(html_52ed64109f7a4090a94bb88bd12ac87e);
#
#
#
#         marker_742a2c0ec4bcb6ed48d75b0f8a4b62cd.bindPopup(popup_1ca2d063cd8009d65ff8800a3aad9440)
#         ;
#
#
#
#
#             var marker_63059196e8f07454a01e1c409ca1670b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d9d4c96cca95760428c91ca98978fe61);
#
#
#         var popup_644de993539e4eb248f6df119727aa60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20fc6534e3bf585d167dd9b2c6acde37 = $(`&lt;div id=&quot;html_20fc6534e3bf585d167dd9b2c6acde37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_644de993539e4eb248f6df119727aa60.setContent(html_20fc6534e3bf585d167dd9b2c6acde37);
#
#
#
#         marker_63059196e8f07454a01e1c409ca1670b.bindPopup(popup_644de993539e4eb248f6df119727aa60)
#         ;
#
#
#
#
#             var marker_0ef7536a87ff5c21548e8f047fc994a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d9d4c96cca95760428c91ca98978fe61);
#
#
#         var popup_9198b1cdf83b03a1afd1234c8c1b23c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_612ea29e4d8614863b30bab99e25faa3 = $(`&lt;div id=&quot;html_612ea29e4d8614863b30bab99e25faa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9198b1cdf83b03a1afd1234c8c1b23c2.setContent(html_612ea29e4d8614863b30bab99e25faa3);
#
#
#
#         marker_0ef7536a87ff5c21548e8f047fc994a8.bindPopup(popup_9198b1cdf83b03a1afd1234c8c1b23c2)
#         ;
#
#
#
#
#             var marker_f582f1ce546ef65f948ab9bff54e083f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d9d4c96cca95760428c91ca98978fe61);
#
#
#         var popup_8f42eea35becf3f7ed8a7ab5dc2b7bb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cf532b0bb3b078fa346b40bc8ffb116 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cf532b0bb3b078fa346b40bc8ffb116&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cf532b0bb3b078fa346b40bc8ffb116 = L.map(
#                 &quot;map_3cf532b0bb3b078fa346b40bc8ffb116&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bf64dd2eb8087e3a16df2fdc9ea54b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bf64dd2eb8087e3a16df2fdc9ea54b8.addTo(map_3cf532b0bb3b078fa346b40bc8ffb116);
#
#
#             var feature_group_99a60eababe33e95bc63689a0ac53d2f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_99a60eababe33e95bc63689a0ac53d2f.addTo(map_3cf532b0bb3b078fa346b40bc8ffb116);
#
#
#             var feature_group_sub_group_b516a835f5a235fc298c03c5b322edff = L.featureGroup.subGroup(
#                 feature_group_99a60eababe33e95bc63689a0ac53d2f
#             );
#
#
#             var marker_6de8761914a577f6f5aca214eab6697b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b516a835f5a235fc298c03c5b322edff);
#
#
#         var popup_ded748bb4afdb009ca5ba9f0ad4e9282 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7423104730e45941ae742731ac9e68 = $(`&lt;div id=&quot;html_9e7423104730e45941ae742731ac9e68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ded748bb4afdb009ca5ba9f0ad4e9282.setContent(html_9e7423104730e45941ae742731ac9e68);
#
#
#
#         marker_6de8761914a577f6f5aca214eab6697b.bindPopup(popup_ded748bb4afdb009ca5ba9f0ad4e9282)
#         ;
#
#
#
#
#             var marker_880e9a83ad6dbf92eb95e1292d8f9a90 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b516a835f5a235fc298c03c5b322edff);
#
#
#         var popup_eea6cfb83f4f930c8410b6849c933375 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f481beb33e357809a36cdb3936de9f = $(`&lt;div id=&quot;html_85f481beb33e357809a36cdb3936de9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_eea6cfb83f4f930c8410b6849c933375.setContent(html_85f481beb33e357809a36cdb3936de9f);
#
#
#
#         marker_880e9a83ad6dbf92eb95e1292d8f9a90.bindPopup(popup_eea6cfb83f4f930c8410b6849c933375)
#         ;
#
#
#
#
#             var marker_5977cb63db068fac4fd816d2126e2777 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b516a835f5a235fc298c03c5b322edff);
#
#
#         var popup_a5f9c814d5dba2ec16b99c2f42e48310 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28eaa956ca7509797b31ed961f663ac6 = $(`&lt;div id=&quot;html_28eaa956ca7509797b31ed961f663ac6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a5f9c814d5dba2ec16b99c2f42e48310.setContent(html_28eaa956ca7509797b31ed961f663ac6);
#
#
#
#         marker_5977cb63db068fac4fd816d2126e2777.bindPopup(popup_a5f9c814d5dba2ec16b99c2f42e48310)
#         ;
#
#
#
#
#             var marker_d38008734fc9c3d99a9b2bff49e0de7a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b516a835f5a235fc298c03c5b322edff);
#
#
#         var popup_406509d5eb52dc202823c89de16d4df9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e68b377bf76c352f33dbbe6edcbfecae = $(`&lt;div id=&quot;html_e68b377bf76c352f33dbbe6edcbfecae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_406509d5eb52dc202823c89de16d4df9.setContent(html_e68b377bf76c352f33dbbe6edcbfecae);
#
#
#
#         marker_
