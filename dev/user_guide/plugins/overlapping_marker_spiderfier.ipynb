# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e19f842773ae953045020490cd8caced {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e19f842773ae953045020490cd8caced&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e19f842773ae953045020490cd8caced = L.map(
#                 &quot;map_e19f842773ae953045020490cd8caced&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ec13da48e7e59a6697f216021d0f0c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ec13da48e7e59a6697f216021d0f0c4.addTo(map_e19f842773ae953045020490cd8caced);
#
#
#             var marker_222705b223b516458a74d1cc7c4f0583 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e19f842773ae953045020490cd8caced);
#
#
#         var popup_860ec3e0d03e794f87739092430863fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f727367ca138f1befe4bd7b2439c87be = $(`&lt;div id=&quot;html_f727367ca138f1befe4bd7b2439c87be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_860ec3e0d03e794f87739092430863fd.setContent(html_f727367ca138f1befe4bd7b2439c87be);
#
#
#
#         marker_222705b223b516458a74d1cc7c4f0583.bindPopup(popup_860ec3e0d03e794f87739092430863fd)
#         ;
#
#
#
#
#             var marker_64fed8e8d449041d6a453e67c29d1bf9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e19f842773ae953045020490cd8caced);
#
#
#         var popup_864e8ff4aadc56b73a97d70e7eb95a38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_148151fdcbc04f277a971fa77bf28aab = $(`&lt;div id=&quot;html_148151fdcbc04f277a971fa77bf28aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_864e8ff4aadc56b73a97d70e7eb95a38.setContent(html_148151fdcbc04f277a971fa77bf28aab);
#
#
#
#         marker_64fed8e8d449041d6a453e67c29d1bf9.bindPopup(popup_864e8ff4aadc56b73a97d70e7eb95a38)
#         ;
#
#
#
#
#             var marker_a91464815d9f75da222f085d9c7a6e9a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e19f842773ae953045020490cd8caced);
#
#
#         var popup_d7ba9b0de2bac9e877825eede00e4b33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9b23e8f1b67dfa8feeb9d9eabbfd2f7 = $(`&lt;div id=&quot;html_a9b23e8f1b67dfa8feeb9d9eabbfd2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d7ba9b0de2bac9e877825eede00e4b33.setContent(html_a9b23e8f1b67dfa8feeb9d9eabbfd2f7);
#
#
#
#         marker_a91464815d9f75da222f085d9c7a6e9a.bindPopup(popup_d7ba9b0de2bac9e877825eede00e4b33)
#         ;
#
#
#
#
#             var marker_079173e4dbd1e2648fa71bf38b29d926 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e19f842773ae953045020490cd8caced);
#
#
#         var popup_2a1063af29a3804a18d93c04c333369d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b69b45dced4670b4a1f3d15426bb5664 = $(`&lt;div id=&quot;html_b69b45dced4670b4a1f3d15426bb5664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2a1063af29a3804a18d93c04c333369d.setContent(html_b69b45dced4670b4a1f3d15426bb5664);
#
#
#
#         marker_079173e4dbd1e2648fa71bf38b29d926.bindPopup(popup_2a1063af29a3804a18d93c04c333369d)
#         ;
#
#
#
#
#             var marker_8882b9a41bfd1a302d1826f53304b33c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e19f842773ae953045020490cd8caced);
#
#
#         var popup_ef865cfdc72fdb678e3ef82909425258 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d18ed86e22ad53078756c684f0af3d98 = $(`&lt;div id=&quot;html_d18ed86e22ad53078756c684f0af3d98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ef865cfdc72fdb678e3ef82909425258.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_023efdff3b3c108c5cbbfe40e45fe07f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_023efdff3b3c108c5cbbfe40e45fe07f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_023efdff3b3c108c5cbbfe40e45fe07f = L.map(
#                 &quot;map_023efdff3b3c108c5cbbfe40e45fe07f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cea10ea21b4c3efb595d16fd7b77300 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3cea10ea21b4c3efb595d16fd7b77300.addTo(map_023efdff3b3c108c5cbbfe40e45fe07f);
#
#
#             var feature_group_3654f4c7524e544d2a1f64ecab35cfba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_42fdb007cd15283fcedd992165f61436 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3654f4c7524e544d2a1f64ecab35cfba);
#
#
#         var popup_2d255ad3dabc773ad42af9916807ec1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a7606d54b9ddec2d98318511b66cc98 = $(`&lt;div id=&quot;html_2a7606d54b9ddec2d98318511b66cc98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2d255ad3dabc773ad42af9916807ec1c.setContent(html_2a7606d54b9ddec2d98318511b66cc98);
#
#
#
#         marker_42fdb007cd15283fcedd992165f61436.bindPopup(popup_2d255ad3dabc773ad42af9916807ec1c)
#         ;
#
#
#
#
#             var marker_011430f817c213c51c9830120013cbdb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3654f4c7524e544d2a1f64ecab35cfba);
#
#
#         var popup_9f7c27e4108b5a00bf71fb763e1aaa4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ed52691dd860f93b1b536ee2c3efe18 = $(`&lt;div id=&quot;html_3ed52691dd860f93b1b536ee2c3efe18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9f7c27e4108b5a00bf71fb763e1aaa4c.setContent(html_3ed52691dd860f93b1b536ee2c3efe18);
#
#
#
#         marker_011430f817c213c51c9830120013cbdb.bindPopup(popup_9f7c27e4108b5a00bf71fb763e1aaa4c)
#         ;
#
#
#
#
#             var marker_3242d9d44cf721d361bae59ad4c2114e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3654f4c7524e544d2a1f64ecab35cfba);
#
#
#         var popup_75433d0ec8f3b7eb6c51baa3da7e7288 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7f4d320026237a0abb366248a90f349 = $(`&lt;div id=&quot;html_d7f4d320026237a0abb366248a90f349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_75433d0ec8f3b7eb6c51baa3da7e7288.setContent(html_d7f4d320026237a0abb366248a90f349);
#
#
#
#         marker_3242d9d44cf721d361bae59ad4c2114e.bindPopup(popup_75433d0ec8f3b7eb6c51baa3da7e7288)
#         ;
#
#
#
#
#             var marker_42310c2fa444c2688d2214c8d9b6bd7b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3654f4c7524e544d2a1f64ecab35cfba);
#
#
#         var popup_c21009a260bd75450ddfffa9fa83ee12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74787b8328e9f5aa2154d8548a88f179 = $(`&lt;div id=&quot;html_74787b8328e9f5aa2154d8548a88f179&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c21009a260bd75450ddfffa9fa83ee12.setContent(html_74787b8328e9f5aa2154d8548a88f179);
#
#
#
#         marker_42310c2fa444c2688d2214c8d9b6bd7b.bindPopup(popup_c21009a260bd75450ddfffa9fa83ee12)
#         ;
#
#
#
#
#             var marker_310fe9224e27e4f2789a0821d73d7aa8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3654f4c7524e544d2a1f64ecab35cfba);
#
#
#         var popup_324bd25f83e84d82a48585f3733cc9fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c650c0ec561f8a455a61a5a352d4061 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c650c0ec561f8a455a61a5a352d4061&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c650c0ec561f8a455a61a5a352d4061 = L.map(
#                 &quot;map_3c650c0ec561f8a455a61a5a352d4061&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9af3cf6da27f41fd903ace60a555f92d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9af3cf6da27f41fd903ace60a555f92d.addTo(map_3c650c0ec561f8a455a61a5a352d4061);
#
#
#             var feature_group_c3aedec49210d6749524cc6e0f695f9f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c3aedec49210d6749524cc6e0f695f9f.addTo(map_3c650c0ec561f8a455a61a5a352d4061);
#
#
#             var feature_group_sub_group_670a3f8cae534bfb805c395c98a49f45 = L.featureGroup.subGroup(
#                 feature_group_c3aedec49210d6749524cc6e0f695f9f
#             );
#
#
#             var marker_3c08bb505ab9b95df69203a80bdca0b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_670a3f8cae534bfb805c395c98a49f45);
#
#
#         var popup_1245547045939b7a7c21625f3065fbd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d989282e9fed5375b9a344f0473297aa = $(`&lt;div id=&quot;html_d989282e9fed5375b9a344f0473297aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1245547045939b7a7c21625f3065fbd3.setContent(html_d989282e9fed5375b9a344f0473297aa);
#
#
#
#         marker_3c08bb505ab9b95df69203a80bdca0b8.bindPopup(popup_1245547045939b7a7c21625f3065fbd3)
#         ;
#
#
#
#
#             var marker_df0433dd7c07d539cbcd946c88f3f3c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_670a3f8cae534bfb805c395c98a49f45);
#
#
#         var popup_3842c2f387de6c7d546346ba98519f15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44b29e31d14bdaf37f06a43733db377e = $(`&lt;div id=&quot;html_44b29e31d14bdaf37f06a43733db377e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3842c2f387de6c7d546346ba98519f15.setContent(html_44b29e31d14bdaf37f06a43733db377e);
#
#
#
#         marker_df0433dd7c07d539cbcd946c88f3f3c5.bindPopup(popup_3842c2f387de6c7d546346ba98519f15)
#         ;
#
#
#
#
#             var marker_7421065aac83c1bcfcc030d664348763 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_670a3f8cae534bfb805c395c98a49f45);
#
#
#         var popup_eee57e37421c4b2207f5e98a5225968d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d964f41b21a0478bfb33b97612f1355 = $(`&lt;div id=&quot;html_1d964f41b21a0478bfb33b97612f1355&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eee57e37421c4b2207f5e98a5225968d.setContent(html_1d964f41b21a0478bfb33b97612f1355);
#
#
#
#         marker_7421065aac83c1bcfcc030d664348763.bindPopup(popup_eee57e37421c4b2207f5e98a5225968d)
#         ;
#
#
#
#
#             var marker_b5118ee5ee3c07f1b1df7690661c6647 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_670a3f8cae534bfb805c395c98a49f45);
#
#
#         var popup_903a462c08d293d1dad69f804464ae8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7317a9c427b2fa0d7f8cb70c2202d0e0 = $(`&lt;div id=&quot;html_7317a9c427b2fa0d7f8cb70c2202d0e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_903a462c08d293d1dad69f804464ae8a.setContent(html_7317a9c427b2fa0d7f8cb70c2202d0e0);
#
#
#
#         marker_
