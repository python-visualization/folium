# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d213782cfb5b539918610c9b435f67d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d213782cfb5b539918610c9b435f67d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d213782cfb5b539918610c9b435f67d = L.map(
#                 &quot;map_2d213782cfb5b539918610c9b435f67d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38e4836b623799231abc7a5c02a6d05f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38e4836b623799231abc7a5c02a6d05f.addTo(map_2d213782cfb5b539918610c9b435f67d);
#
#
#             var marker_c80dd1462aaeac69a67cd6ce7bb2894b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2d213782cfb5b539918610c9b435f67d);
#
#
#         var popup_d0fa8c1757cbad19d53507e7f8c97318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c11f278b0fc621d4a0f6d915baca2b6 = $(`&lt;div id=&quot;html_8c11f278b0fc621d4a0f6d915baca2b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d0fa8c1757cbad19d53507e7f8c97318.setContent(html_8c11f278b0fc621d4a0f6d915baca2b6);
#
#
#
#         marker_c80dd1462aaeac69a67cd6ce7bb2894b.bindPopup(popup_d0fa8c1757cbad19d53507e7f8c97318)
#         ;
#
#
#
#
#             var marker_443e3d65445c03dce2295212f2c62c6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2d213782cfb5b539918610c9b435f67d);
#
#
#         var popup_b75433af5a19bd10b216565e60b69a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_351b7c5214c0e29bba3306fe7980407a = $(`&lt;div id=&quot;html_351b7c5214c0e29bba3306fe7980407a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b75433af5a19bd10b216565e60b69a62.setContent(html_351b7c5214c0e29bba3306fe7980407a);
#
#
#
#         marker_443e3d65445c03dce2295212f2c62c6a.bindPopup(popup_b75433af5a19bd10b216565e60b69a62)
#         ;
#
#
#
#
#             var marker_99d89a378897386d2046916a127eb915 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2d213782cfb5b539918610c9b435f67d);
#
#
#         var popup_5831c3b158f6d79bc51ef1c4dac1cefc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fde9ef9d51c364ac0e892658e2d733f0 = $(`&lt;div id=&quot;html_fde9ef9d51c364ac0e892658e2d733f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5831c3b158f6d79bc51ef1c4dac1cefc.setContent(html_fde9ef9d51c364ac0e892658e2d733f0);
#
#
#
#         marker_99d89a378897386d2046916a127eb915.bindPopup(popup_5831c3b158f6d79bc51ef1c4dac1cefc)
#         ;
#
#
#
#
#             var marker_d949ce8b290a84d5e9abd4c6b2b4aaea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2d213782cfb5b539918610c9b435f67d);
#
#
#         var popup_fe7d1322b99408902ceab28bb77cf71e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_627d279764b614a4b9e4a4b33799e62b = $(`&lt;div id=&quot;html_627d279764b614a4b9e4a4b33799e62b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fe7d1322b99408902ceab28bb77cf71e.setContent(html_627d279764b614a4b9e4a4b33799e62b);
#
#
#
#         marker_d949ce8b290a84d5e9abd4c6b2b4aaea.bindPopup(popup_fe7d1322b99408902ceab28bb77cf71e)
#         ;
#
#
#
#
#             var marker_01a9c074742c507465193dcabfd3ef0b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2d213782cfb5b539918610c9b435f67d);
#
#
#         var popup_c6ed6768be0ff7ce0cac3c056b8993eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_166e53252ffe6a593e06b59fd6aa1fca = $(`&lt;div id=&quot;html_166e53252ffe6a593e06b59fd6aa1fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c6ed6768be0ff7ce0cac3c056b8993eb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b3ec8f5fa8b1021e506638b668b79c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b3ec8f5fa8b1021e506638b668b79c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b3ec8f5fa8b1021e506638b668b79c8 = L.map(
#                 &quot;map_9b3ec8f5fa8b1021e506638b668b79c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab1ff50dd7416001fec15acb4635e5ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab1ff50dd7416001fec15acb4635e5ff.addTo(map_9b3ec8f5fa8b1021e506638b668b79c8);
#
#
#             var feature_group_67076dac3129b607de22b6b86257904f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8d5c20ae1f1a6229b90ad420cb467036 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_67076dac3129b607de22b6b86257904f);
#
#
#         var popup_ab8013e7f7f5205c78ad91d0566d7ea4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20e71f77db1194e1b792f943e157a5ea = $(`&lt;div id=&quot;html_20e71f77db1194e1b792f943e157a5ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ab8013e7f7f5205c78ad91d0566d7ea4.setContent(html_20e71f77db1194e1b792f943e157a5ea);
#
#
#
#         marker_8d5c20ae1f1a6229b90ad420cb467036.bindPopup(popup_ab8013e7f7f5205c78ad91d0566d7ea4)
#         ;
#
#
#
#
#             var marker_db941dff39e68510464a106842e758d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_67076dac3129b607de22b6b86257904f);
#
#
#         var popup_4cba5891b04c130538ba343809852f3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3fb37187b90066ab563d1d03f6b2078 = $(`&lt;div id=&quot;html_f3fb37187b90066ab563d1d03f6b2078&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4cba5891b04c130538ba343809852f3d.setContent(html_f3fb37187b90066ab563d1d03f6b2078);
#
#
#
#         marker_db941dff39e68510464a106842e758d4.bindPopup(popup_4cba5891b04c130538ba343809852f3d)
#         ;
#
#
#
#
#             var marker_addffa9f647a93fff2b6761f9375ef8f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_67076dac3129b607de22b6b86257904f);
#
#
#         var popup_761fe4807075410ef8bf024000ba777e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb2569c88edf7b805113b38a9771082a = $(`&lt;div id=&quot;html_cb2569c88edf7b805113b38a9771082a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_761fe4807075410ef8bf024000ba777e.setContent(html_cb2569c88edf7b805113b38a9771082a);
#
#
#
#         marker_addffa9f647a93fff2b6761f9375ef8f.bindPopup(popup_761fe4807075410ef8bf024000ba777e)
#         ;
#
#
#
#
#             var marker_67bf596d7a93a729f0f71ce728ad6912 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_67076dac3129b607de22b6b86257904f);
#
#
#         var popup_aa46bc8c0b2331d3a033dc0993a72c9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db798d45e2e81220263b14c04f91312a = $(`&lt;div id=&quot;html_db798d45e2e81220263b14c04f91312a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aa46bc8c0b2331d3a033dc0993a72c9c.setContent(html_db798d45e2e81220263b14c04f91312a);
#
#
#
#         marker_67bf596d7a93a729f0f71ce728ad6912.bindPopup(popup_aa46bc8c0b2331d3a033dc0993a72c9c)
#         ;
#
#
#
#
#             var marker_b65d8e7620e4f8f5b4411963aaa499ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_67076dac3129b607de22b6b86257904f);
#
#
#         var popup_f1d609f67e6a561a4830d4faca4aa799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_366391ac17bdbcd75d75b42838bcda49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_366391ac17bdbcd75d75b42838bcda49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_366391ac17bdbcd75d75b42838bcda49 = L.map(
#                 &quot;map_366391ac17bdbcd75d75b42838bcda49&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fe69fed323ef800600dc202804c150b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fe69fed323ef800600dc202804c150b.addTo(map_366391ac17bdbcd75d75b42838bcda49);
#
#
#             var feature_group_22078b31ad39d27c8f90dcef39070bdf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_22078b31ad39d27c8f90dcef39070bdf.addTo(map_366391ac17bdbcd75d75b42838bcda49);
#
#
#             var feature_group_sub_group_8ecfc4a5aa808d12ffa9ac7badaea2b3 = L.featureGroup.subGroup(
#                 feature_group_22078b31ad39d27c8f90dcef39070bdf
#             );
#
#
#             var marker_8dd380d3dbd64966e90290374d2fd792 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ecfc4a5aa808d12ffa9ac7badaea2b3);
#
#
#         var popup_39927612579dca3604b4e76ed76180d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29017905ca74af915c792a9052950754 = $(`&lt;div id=&quot;html_29017905ca74af915c792a9052950754&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_39927612579dca3604b4e76ed76180d7.setContent(html_29017905ca74af915c792a9052950754);
#
#
#
#         marker_8dd380d3dbd64966e90290374d2fd792.bindPopup(popup_39927612579dca3604b4e76ed76180d7)
#         ;
#
#
#
#
#             var marker_f584cc22e2827200b5a4c56f8b9f959b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ecfc4a5aa808d12ffa9ac7badaea2b3);
#
#
#         var popup_2933ba9b989a0aae65871543f1f93f73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc24a7ce9d9caf6194de79b91e11ed72 = $(`&lt;div id=&quot;html_bc24a7ce9d9caf6194de79b91e11ed72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2933ba9b989a0aae65871543f1f93f73.setContent(html_bc24a7ce9d9caf6194de79b91e11ed72);
#
#
#
#         marker_f584cc22e2827200b5a4c56f8b9f959b.bindPopup(popup_2933ba9b989a0aae65871543f1f93f73)
#         ;
#
#
#
#
#             var marker_48f059c60dbec92eb574d8a9b0d7f4c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ecfc4a5aa808d12ffa9ac7badaea2b3);
#
#
#         var popup_6ea8c106fc8eafcfc92d7fa7a6a6c5d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_922e6a4153e656f99ac418144bc096c4 = $(`&lt;div id=&quot;html_922e6a4153e656f99ac418144bc096c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6ea8c106fc8eafcfc92d7fa7a6a6c5d3.setContent(html_922e6a4153e656f99ac418144bc096c4);
#
#
#
#         marker_48f059c60dbec92eb574d8a9b0d7f4c5.bindPopup(popup_6ea8c106fc8eafcfc92d7fa7a6a6c5d3)
#         ;
#
#
#
#
#             var marker_79fe73b5a2475e8b7ccbe0043fca6054 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ecfc4a5aa808d12ffa9ac7badaea2b3);
#
#
#         var popup_84e9998ccabab48041d4f4ac16dc41c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afcd7bf09b5c447599a26118de6a5a2c = $(`&lt;div id=&quot;html_afcd7bf09b5c447599a26118de6a5a2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_84e9998ccabab48041d4f4ac16dc41c6.setContent(html_afcd7bf09b5c447599a26118de6a5a2c);
#
#
#
#         marker_
