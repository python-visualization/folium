# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24e0993362d321e2215815a1e553a1cd {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24e0993362d321e2215815a1e553a1cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24e0993362d321e2215815a1e553a1cd = L.map(
#                 &quot;map_24e0993362d321e2215815a1e553a1cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17dc91b26a54266a77153ce80f1d4bc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17dc91b26a54266a77153ce80f1d4bc5.addTo(map_24e0993362d321e2215815a1e553a1cd);
#
#
#             var marker_9dce8ecd57f905c0d31416b0f3c44041 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_24e0993362d321e2215815a1e553a1cd);
#
#
#         var popup_f2b38f84d6d32f585f597784565a6089 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baccae4cc0662f047fa6a2d6e8422b12 = $(`&lt;div id=&quot;html_baccae4cc0662f047fa6a2d6e8422b12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f2b38f84d6d32f585f597784565a6089.setContent(html_baccae4cc0662f047fa6a2d6e8422b12);
#
#
#
#         marker_9dce8ecd57f905c0d31416b0f3c44041.bindPopup(popup_f2b38f84d6d32f585f597784565a6089)
#         ;
#
#
#
#
#             var marker_6a888cf353c437004147675d5397dfb1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_24e0993362d321e2215815a1e553a1cd);
#
#
#         var popup_29e7824fc0b0725087ce54bf9ebbd069 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2db14d670673d86308b81a71ca183b7 = $(`&lt;div id=&quot;html_e2db14d670673d86308b81a71ca183b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_29e7824fc0b0725087ce54bf9ebbd069.setContent(html_e2db14d670673d86308b81a71ca183b7);
#
#
#
#         marker_6a888cf353c437004147675d5397dfb1.bindPopup(popup_29e7824fc0b0725087ce54bf9ebbd069)
#         ;
#
#
#
#
#             var marker_b99e9d67c73885b059d02de0f8d17f41 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_24e0993362d321e2215815a1e553a1cd);
#
#
#         var popup_dd8d8bfaa7f9c6ee507c6f72d4cdbc83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12ac33410d76b9234bf6266a15939d92 = $(`&lt;div id=&quot;html_12ac33410d76b9234bf6266a15939d92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dd8d8bfaa7f9c6ee507c6f72d4cdbc83.setContent(html_12ac33410d76b9234bf6266a15939d92);
#
#
#
#         marker_b99e9d67c73885b059d02de0f8d17f41.bindPopup(popup_dd8d8bfaa7f9c6ee507c6f72d4cdbc83)
#         ;
#
#
#
#
#             var marker_d755c9e1d25a36494508945eccda0ce4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_24e0993362d321e2215815a1e553a1cd);
#
#
#         var popup_3b79838517b951e0880fd8f9cb96cc42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e0edb4ee9a4d7198788efdf44e16824 = $(`&lt;div id=&quot;html_3e0edb4ee9a4d7198788efdf44e16824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3b79838517b951e0880fd8f9cb96cc42.setContent(html_3e0edb4ee9a4d7198788efdf44e16824);
#
#
#
#         marker_d755c9e1d25a36494508945eccda0ce4.bindPopup(popup_3b79838517b951e0880fd8f9cb96cc42)
#         ;
#
#
#
#
#             var marker_6840cd7f55591baf9481046dc57f87e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_24e0993362d321e2215815a1e553a1cd);
#
#
#         var popup_44eb6ae48d83edbfce6f6be66fb8f4e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a641b79f355bd8e9e1dbf6d1aad957b3 = $(`&lt;div id=&quot;html_a641b79f355bd8e9e1dbf6d1aad957b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_44eb6ae48d83edbfce6f6be66fb8f4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae1087d97f28eec39569b471e1828625 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae1087d97f28eec39569b471e1828625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae1087d97f28eec39569b471e1828625 = L.map(
#                 &quot;map_ae1087d97f28eec39569b471e1828625&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d966561634aa55b2ba2a5272c72e1738 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d966561634aa55b2ba2a5272c72e1738.addTo(map_ae1087d97f28eec39569b471e1828625);
#
#
#             var feature_group_a6845764bad023c88d6e167bd3b02e33 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fe40c606d6d80108c7e4efef7bcf8267 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a6845764bad023c88d6e167bd3b02e33);
#
#
#         var popup_48ed6b9e922fac167f94eb511d43b4d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc759ac981e1e77e9dc1fa6b85b527cb = $(`&lt;div id=&quot;html_bc759ac981e1e77e9dc1fa6b85b527cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_48ed6b9e922fac167f94eb511d43b4d5.setContent(html_bc759ac981e1e77e9dc1fa6b85b527cb);
#
#
#
#         marker_fe40c606d6d80108c7e4efef7bcf8267.bindPopup(popup_48ed6b9e922fac167f94eb511d43b4d5)
#         ;
#
#
#
#
#             var marker_6ee68893324884178593822f5950f22f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a6845764bad023c88d6e167bd3b02e33);
#
#
#         var popup_7e9d08da6c8f0a259993874095df0184 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3ff7f15c82311cebf6ba21eee3accde = $(`&lt;div id=&quot;html_e3ff7f15c82311cebf6ba21eee3accde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7e9d08da6c8f0a259993874095df0184.setContent(html_e3ff7f15c82311cebf6ba21eee3accde);
#
#
#
#         marker_6ee68893324884178593822f5950f22f.bindPopup(popup_7e9d08da6c8f0a259993874095df0184)
#         ;
#
#
#
#
#             var marker_1fe26e21d20c83cfb6b2f1e003313467 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a6845764bad023c88d6e167bd3b02e33);
#
#
#         var popup_19cfacdcd19ff49679eccab090dcebde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d03aedb2243735f455248f1ad3c7fbf = $(`&lt;div id=&quot;html_9d03aedb2243735f455248f1ad3c7fbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_19cfacdcd19ff49679eccab090dcebde.setContent(html_9d03aedb2243735f455248f1ad3c7fbf);
#
#
#
#         marker_1fe26e21d20c83cfb6b2f1e003313467.bindPopup(popup_19cfacdcd19ff49679eccab090dcebde)
#         ;
#
#
#
#
#             var marker_0dfa6650aadf90053289d9c54cebebc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a6845764bad023c88d6e167bd3b02e33);
#
#
#         var popup_501f83b6fbbf896476fc5fb6ca167e8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5123f8fa91948af90dc3bc27808ed76b = $(`&lt;div id=&quot;html_5123f8fa91948af90dc3bc27808ed76b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_501f83b6fbbf896476fc5fb6ca167e8a.setContent(html_5123f8fa91948af90dc3bc27808ed76b);
#
#
#
#         marker_0dfa6650aadf90053289d9c54cebebc2.bindPopup(popup_501f83b6fbbf896476fc5fb6ca167e8a)
#         ;
#
#
#
#
#             var marker_d6731eebbf18555dc682f48c494cf11a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a6845764bad023c88d6e167bd3b02e33);
#
#
#         var popup_e7ef38ae0786466842d8983754433347 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad0b3013bcc3be64d4c6f4e7b5712674 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad0b3013bcc3be64d4c6f4e7b5712674&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad0b3013bcc3be64d4c6f4e7b5712674 = L.map(
#                 &quot;map_ad0b3013bcc3be64d4c6f4e7b5712674&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eefb274f006a5631f292c1cda1b3d487 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eefb274f006a5631f292c1cda1b3d487.addTo(map_ad0b3013bcc3be64d4c6f4e7b5712674);
#
#
#             var feature_group_d2606cf2fe7d74d406e67d81b2de0524 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d2606cf2fe7d74d406e67d81b2de0524.addTo(map_ad0b3013bcc3be64d4c6f4e7b5712674);
#
#
#             var feature_group_sub_group_008d0ccfc58630c17973a54a76a47045 = L.featureGroup.subGroup(
#                 feature_group_d2606cf2fe7d74d406e67d81b2de0524
#             );
#
#
#             var marker_a445501a68fad1daabe4fbadfe962944 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_008d0ccfc58630c17973a54a76a47045);
#
#
#         var popup_73ca7276dc2f72b3842d186834f0357e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4e96e648d9ba37e1b46f8b1509a94e5 = $(`&lt;div id=&quot;html_a4e96e648d9ba37e1b46f8b1509a94e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_73ca7276dc2f72b3842d186834f0357e.setContent(html_a4e96e648d9ba37e1b46f8b1509a94e5);
#
#
#
#         marker_a445501a68fad1daabe4fbadfe962944.bindPopup(popup_73ca7276dc2f72b3842d186834f0357e)
#         ;
#
#
#
#
#             var marker_d6db94ca6ffc545727aa55eec9185a5a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_008d0ccfc58630c17973a54a76a47045);
#
#
#         var popup_c709efecf3609d280999747ae4b754b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd077a58555faf888ae129d4e25efd4c = $(`&lt;div id=&quot;html_dd077a58555faf888ae129d4e25efd4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c709efecf3609d280999747ae4b754b3.setContent(html_dd077a58555faf888ae129d4e25efd4c);
#
#
#
#         marker_d6db94ca6ffc545727aa55eec9185a5a.bindPopup(popup_c709efecf3609d280999747ae4b754b3)
#         ;
#
#
#
#
#             var marker_6157e5abae9aec9c400c8f1ffdabd953 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_008d0ccfc58630c17973a54a76a47045);
#
#
#         var popup_950379cecaef1bb347d8783343e38a95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f946a51e6f50c2fd85d9b779975aee12 = $(`&lt;div id=&quot;html_f946a51e6f50c2fd85d9b779975aee12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_950379cecaef1bb347d8783343e38a95.setContent(html_f946a51e6f50c2fd85d9b779975aee12);
#
#
#
#         marker_6157e5abae9aec9c400c8f1ffdabd953.bindPopup(popup_950379cecaef1bb347d8783343e38a95)
#         ;
#
#
#
#
#             var marker_4479b46ea4d37df169700cdf650431c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_008d0ccfc58630c17973a54a76a47045);
#
#
#         var popup_e2a9c7ed25924b799d5e2948c8ab623b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b83546321177e9ad9eb2727ecf78686 = $(`&lt;div id=&quot;html_0b83546321177e9ad9eb2727ecf78686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e2a9c7ed25924b799d5e2948c8ab623b.setContent(html_0b83546321177e9ad9eb2727ecf78686);
#
#
#
#         mark
