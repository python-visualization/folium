# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_251182efba278c239a544ebb704ba59f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_251182efba278c239a544ebb704ba59f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_251182efba278c239a544ebb704ba59f = L.map(
#                 &quot;map_251182efba278c239a544ebb704ba59f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1947ca1f7afa0b0aa82bf559cd0a44d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1947ca1f7afa0b0aa82bf559cd0a44d7.addTo(map_251182efba278c239a544ebb704ba59f);
#
#
#             var marker_afc0dface8ca3ad786c16758a28f73d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_251182efba278c239a544ebb704ba59f);
#
#
#         var popup_fc6ccc34bf7d3068fbbbac63b9648ee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ff58f099a0b3dec3a1027ee5eb02028 = $(`&lt;div id=&quot;html_0ff58f099a0b3dec3a1027ee5eb02028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fc6ccc34bf7d3068fbbbac63b9648ee4.setContent(html_0ff58f099a0b3dec3a1027ee5eb02028);
#
#
#
#         marker_afc0dface8ca3ad786c16758a28f73d6.bindPopup(popup_fc6ccc34bf7d3068fbbbac63b9648ee4)
#         ;
#
#
#
#
#             var marker_d81f52992354cde7063e94d4d14b0203 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_251182efba278c239a544ebb704ba59f);
#
#
#         var popup_07174c576def1ca30ea57d34135221c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e1e02ea998716bde5e2b496056f0332 = $(`&lt;div id=&quot;html_7e1e02ea998716bde5e2b496056f0332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_07174c576def1ca30ea57d34135221c7.setContent(html_7e1e02ea998716bde5e2b496056f0332);
#
#
#
#         marker_d81f52992354cde7063e94d4d14b0203.bindPopup(popup_07174c576def1ca30ea57d34135221c7)
#         ;
#
#
#
#
#             var marker_0b724790cf1b97e183723723e3c2d1a5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_251182efba278c239a544ebb704ba59f);
#
#
#         var popup_da080cd19075117aff0864a703334aca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbdd77fca1dfe7d101e373ca174c9c7a = $(`&lt;div id=&quot;html_cbdd77fca1dfe7d101e373ca174c9c7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_da080cd19075117aff0864a703334aca.setContent(html_cbdd77fca1dfe7d101e373ca174c9c7a);
#
#
#
#         marker_0b724790cf1b97e183723723e3c2d1a5.bindPopup(popup_da080cd19075117aff0864a703334aca)
#         ;
#
#
#
#
#             var marker_fc14ac1df510bb9cf09fa58f55bad5c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_251182efba278c239a544ebb704ba59f);
#
#
#         var popup_9f8d9144e2872d42806d40abc7865b80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e42465d1c820d77fd8f5b36009ca88b = $(`&lt;div id=&quot;html_2e42465d1c820d77fd8f5b36009ca88b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9f8d9144e2872d42806d40abc7865b80.setContent(html_2e42465d1c820d77fd8f5b36009ca88b);
#
#
#
#         marker_fc14ac1df510bb9cf09fa58f55bad5c0.bindPopup(popup_9f8d9144e2872d42806d40abc7865b80)
#         ;
#
#
#
#
#             var marker_b66b090d4b5736a13519f1827fe5b296 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_251182efba278c239a544ebb704ba59f);
#
#
#         var popup_9cd45fb2c953b1873f5671d3656dcc5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_175fa0fd87d1cff584b0891565803c20 = $(`&lt;div id=&quot;html_175fa0fd87d1cff584b0891565803c20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9cd45fb2c953b1873f5671d3656dcc5a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ce59f6eb0f7eab0d7639ad8046009fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ce59f6eb0f7eab0d7639ad8046009fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ce59f6eb0f7eab0d7639ad8046009fc = L.map(
#                 &quot;map_3ce59f6eb0f7eab0d7639ad8046009fc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26c55a164ed0056e400b1d3b72cc2df5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26c55a164ed0056e400b1d3b72cc2df5.addTo(map_3ce59f6eb0f7eab0d7639ad8046009fc);
#
#
#             var feature_group_652c60d44a1f43e00aa809dabd4e89b0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fadbec63df25814727a1a72dd5ef5d8f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_652c60d44a1f43e00aa809dabd4e89b0);
#
#
#         var popup_f9b354ad50c75426759af60366648ae0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c476017c5113bb87fc0019c375da102 = $(`&lt;div id=&quot;html_3c476017c5113bb87fc0019c375da102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f9b354ad50c75426759af60366648ae0.setContent(html_3c476017c5113bb87fc0019c375da102);
#
#
#
#         marker_fadbec63df25814727a1a72dd5ef5d8f.bindPopup(popup_f9b354ad50c75426759af60366648ae0)
#         ;
#
#
#
#
#             var marker_4ef01990c4041182c8fba7ea9040021c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_652c60d44a1f43e00aa809dabd4e89b0);
#
#
#         var popup_92169e182b7fe6344c34acd54c52832b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1dc63e38347f04326005391d61c039ee = $(`&lt;div id=&quot;html_1dc63e38347f04326005391d61c039ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_92169e182b7fe6344c34acd54c52832b.setContent(html_1dc63e38347f04326005391d61c039ee);
#
#
#
#         marker_4ef01990c4041182c8fba7ea9040021c.bindPopup(popup_92169e182b7fe6344c34acd54c52832b)
#         ;
#
#
#
#
#             var marker_f407bb3b9a431335afc6f2c34234c1d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_652c60d44a1f43e00aa809dabd4e89b0);
#
#
#         var popup_5152b6a772a628a85c4153865aa17de8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_671c21508409fbd24625a4b891021b45 = $(`&lt;div id=&quot;html_671c21508409fbd24625a4b891021b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5152b6a772a628a85c4153865aa17de8.setContent(html_671c21508409fbd24625a4b891021b45);
#
#
#
#         marker_f407bb3b9a431335afc6f2c34234c1d0.bindPopup(popup_5152b6a772a628a85c4153865aa17de8)
#         ;
#
#
#
#
#             var marker_a0249393847603a9368d7fecdbc388a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_652c60d44a1f43e00aa809dabd4e89b0);
#
#
#         var popup_f7f18ae768b5c8405fbb7d786a4e6797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bf6a493f0cc1aa8d88ce626ed9748c9 = $(`&lt;div id=&quot;html_3bf6a493f0cc1aa8d88ce626ed9748c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f7f18ae768b5c8405fbb7d786a4e6797.setContent(html_3bf6a493f0cc1aa8d88ce626ed9748c9);
#
#
#
#         marker_a0249393847603a9368d7fecdbc388a4.bindPopup(popup_f7f18ae768b5c8405fbb7d786a4e6797)
#         ;
#
#
#
#
#             var marker_ddd949a8b8c137da3c8cca1655246ad3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_652c60d44a1f43e00aa809dabd4e89b0);
#
#
#         var popup_6b29ebd75380ad3925e76910d8ca0d23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed59d952305f7cff5cd01adeb3f7e757 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed59d952305f7cff5cd01adeb3f7e757&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed59d952305f7cff5cd01adeb3f7e757 = L.map(
#                 &quot;map_ed59d952305f7cff5cd01adeb3f7e757&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc1cf05ae309ff3da8870f064a5b3e92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc1cf05ae309ff3da8870f064a5b3e92.addTo(map_ed59d952305f7cff5cd01adeb3f7e757);
#
#
#             var feature_group_6517f4bb6bb537be8713ba1d4e96f081 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6517f4bb6bb537be8713ba1d4e96f081.addTo(map_ed59d952305f7cff5cd01adeb3f7e757);
#
#
#             var feature_group_sub_group_44561cd842780762b6371da6ae8d73af = L.featureGroup.subGroup(
#                 feature_group_6517f4bb6bb537be8713ba1d4e96f081
#             );
#
#
#             var marker_94f4ca72f01b9dae73e59bc63b496ce6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_44561cd842780762b6371da6ae8d73af);
#
#
#         var popup_8d2ef076b98ff349b2c280f1c616e369 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c044dc96fcabeb30af4b84f868401f9d = $(`&lt;div id=&quot;html_c044dc96fcabeb30af4b84f868401f9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8d2ef076b98ff349b2c280f1c616e369.setContent(html_c044dc96fcabeb30af4b84f868401f9d);
#
#
#
#         marker_94f4ca72f01b9dae73e59bc63b496ce6.bindPopup(popup_8d2ef076b98ff349b2c280f1c616e369)
#         ;
#
#
#
#
#             var marker_2857aa1ece4155c940a61c091f5bfd85 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_44561cd842780762b6371da6ae8d73af);
#
#
#         var popup_56dc61dfb2007b193f101ae0a16a5594 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e8c193bf097d6f363ea9f7045930f3b = $(`&lt;div id=&quot;html_7e8c193bf097d6f363ea9f7045930f3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_56dc61dfb2007b193f101ae0a16a5594.setContent(html_7e8c193bf097d6f363ea9f7045930f3b);
#
#
#
#         marker_2857aa1ece4155c940a61c091f5bfd85.bindPopup(popup_56dc61dfb2007b193f101ae0a16a5594)
#         ;
#
#
#
#
#             var marker_86821e4a5dcf33384d8075b13ed29852 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_44561cd842780762b6371da6ae8d73af);
#
#
#         var popup_9b052d825c3a77ad40f45c3f83902291 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e803217a72a192f626932861e5dcab45 = $(`&lt;div id=&quot;html_e803217a72a192f626932861e5dcab45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9b052d825c3a77ad40f45c3f83902291.setContent(html_e803217a72a192f626932861e5dcab45);
#
#
#
#         marker_86821e4a5dcf33384d8075b13ed29852.bindPopup(popup_9b052d825c3a77ad40f45c3f83902291)
#         ;
#
#
#
#
#             var marker_f2f16975b64f3d9f5c4aff214e19affe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_44561cd842780762b6371da6ae8d73af);
#
#
#         var popup_565db12e9804133f8ee777ad70368788 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4044ac5fb4337bc2a1d0583107b093f9 = $(`&lt;div id=&quot;html_4044ac5fb4337bc2a1d0583107b093f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_565db12e9804133f8ee777ad70368788.setContent(html_4044ac5fb4337bc2a1d0583107b093f9);
#
#
#
#         marker_
