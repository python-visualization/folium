# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ce210dba877780b7c72e49ed1ec3b79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ce210dba877780b7c72e49ed1ec3b79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ce210dba877780b7c72e49ed1ec3b79 = L.map(
#                 &quot;map_1ce210dba877780b7c72e49ed1ec3b79&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b77fc2ac16a9a4841a092e7669325263 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b77fc2ac16a9a4841a092e7669325263.addTo(map_1ce210dba877780b7c72e49ed1ec3b79);
#
#
#             var marker_e388696bd5b853d61ec927d763f61a05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1ce210dba877780b7c72e49ed1ec3b79);
#
#
#         var popup_2fce467fc62a8f1bbbe56dd60656b7cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a29156d5fcf57734f784c25ea002c42 = $(`&lt;div id=&quot;html_4a29156d5fcf57734f784c25ea002c42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2fce467fc62a8f1bbbe56dd60656b7cc.setContent(html_4a29156d5fcf57734f784c25ea002c42);
#
#
#
#         marker_e388696bd5b853d61ec927d763f61a05.bindPopup(popup_2fce467fc62a8f1bbbe56dd60656b7cc)
#         ;
#
#
#
#
#             var marker_31b8f7951e56baf97ac7e078de8cce23 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1ce210dba877780b7c72e49ed1ec3b79);
#
#
#         var popup_aeac8171dcda5421410b7d28acba0cc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61e779ce4ecf0314a1b667989c8a7d21 = $(`&lt;div id=&quot;html_61e779ce4ecf0314a1b667989c8a7d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aeac8171dcda5421410b7d28acba0cc4.setContent(html_61e779ce4ecf0314a1b667989c8a7d21);
#
#
#
#         marker_31b8f7951e56baf97ac7e078de8cce23.bindPopup(popup_aeac8171dcda5421410b7d28acba0cc4)
#         ;
#
#
#
#
#             var marker_c68254513a3b0d20534691c4d0bc8692 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1ce210dba877780b7c72e49ed1ec3b79);
#
#
#         var popup_cceb3d068f7ce88899613b5e67ca1042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c990a1c48a3e3a2ded6f8e862c247a2 = $(`&lt;div id=&quot;html_2c990a1c48a3e3a2ded6f8e862c247a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cceb3d068f7ce88899613b5e67ca1042.setContent(html_2c990a1c48a3e3a2ded6f8e862c247a2);
#
#
#
#         marker_c68254513a3b0d20534691c4d0bc8692.bindPopup(popup_cceb3d068f7ce88899613b5e67ca1042)
#         ;
#
#
#
#
#             var marker_255147891bc4d99f2a406ed4971b6f75 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1ce210dba877780b7c72e49ed1ec3b79);
#
#
#         var popup_e46a6ff30b99dd73dfacf91fc4fbb21c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5531846d70dd7d951be489a206cfdd57 = $(`&lt;div id=&quot;html_5531846d70dd7d951be489a206cfdd57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e46a6ff30b99dd73dfacf91fc4fbb21c.setContent(html_5531846d70dd7d951be489a206cfdd57);
#
#
#
#         marker_255147891bc4d99f2a406ed4971b6f75.bindPopup(popup_e46a6ff30b99dd73dfacf91fc4fbb21c)
#         ;
#
#
#
#
#             var marker_91313501f44fe2bdc43f2d2908f6c9ee = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1ce210dba877780b7c72e49ed1ec3b79);
#
#
#         var popup_07329b5e35ee3854efd11fab1cfd747e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ebcd0b1293c7f173697e0d2556c5052 = $(`&lt;div id=&quot;html_1ebcd0b1293c7f173697e0d2556c5052&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_07329b5e35ee3854efd11fab1cfd747e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac7457a83a1b2d7bedaacd47f966dbca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac7457a83a1b2d7bedaacd47f966dbca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac7457a83a1b2d7bedaacd47f966dbca = L.map(
#                 &quot;map_ac7457a83a1b2d7bedaacd47f966dbca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76e9d7df8aa2a5c663550e0e648598da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76e9d7df8aa2a5c663550e0e648598da.addTo(map_ac7457a83a1b2d7bedaacd47f966dbca);
#
#
#             var feature_group_414908629eb55fa91ee4fc7333421f2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b4e2e8b803af775134ef0bae2612392e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_414908629eb55fa91ee4fc7333421f2d);
#
#
#         var popup_be132570ecfe25b07d8b79a616b30005 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0b6dc0753fa56f8ac19b7aa3e9dceb4 = $(`&lt;div id=&quot;html_d0b6dc0753fa56f8ac19b7aa3e9dceb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_be132570ecfe25b07d8b79a616b30005.setContent(html_d0b6dc0753fa56f8ac19b7aa3e9dceb4);
#
#
#
#         marker_b4e2e8b803af775134ef0bae2612392e.bindPopup(popup_be132570ecfe25b07d8b79a616b30005)
#         ;
#
#
#
#
#             var marker_4a321ea4577f5f65857e10598dbb2bd1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_414908629eb55fa91ee4fc7333421f2d);
#
#
#         var popup_230a6566ef8de0355267bae49cf37da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b86d08d4c84fb1f663178a07f7636910 = $(`&lt;div id=&quot;html_b86d08d4c84fb1f663178a07f7636910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_230a6566ef8de0355267bae49cf37da8.setContent(html_b86d08d4c84fb1f663178a07f7636910);
#
#
#
#         marker_4a321ea4577f5f65857e10598dbb2bd1.bindPopup(popup_230a6566ef8de0355267bae49cf37da8)
#         ;
#
#
#
#
#             var marker_a0a8d0caea80b6aa3594cec6949af57b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_414908629eb55fa91ee4fc7333421f2d);
#
#
#         var popup_de96aa9a82491cdd2dd70594d4e4a6b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d881d90c094e705a07e11f6fccfdb3b3 = $(`&lt;div id=&quot;html_d881d90c094e705a07e11f6fccfdb3b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_de96aa9a82491cdd2dd70594d4e4a6b4.setContent(html_d881d90c094e705a07e11f6fccfdb3b3);
#
#
#
#         marker_a0a8d0caea80b6aa3594cec6949af57b.bindPopup(popup_de96aa9a82491cdd2dd70594d4e4a6b4)
#         ;
#
#
#
#
#             var marker_fc4bfd3a98eb96298c5d096c5c5fe07d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_414908629eb55fa91ee4fc7333421f2d);
#
#
#         var popup_5b4308f7e8a9963bd894848ba6dcbea8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fb3f853b4755f271675bae532b614b1 = $(`&lt;div id=&quot;html_2fb3f853b4755f271675bae532b614b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5b4308f7e8a9963bd894848ba6dcbea8.setContent(html_2fb3f853b4755f271675bae532b614b1);
#
#
#
#         marker_fc4bfd3a98eb96298c5d096c5c5fe07d.bindPopup(popup_5b4308f7e8a9963bd894848ba6dcbea8)
#         ;
#
#
#
#
#             var marker_7b6da6e5c576edc0dedd2e570b5e17e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_414908629eb55fa91ee4fc7333421f2d);
#
#
#         var popup_ffdccf8b41c7c15351d7a3a4932eb0af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7bfeea2fd3442d5275ec59de245000a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7bfeea2fd3442d5275ec59de245000a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7bfeea2fd3442d5275ec59de245000a = L.map(
#                 &quot;map_b7bfeea2fd3442d5275ec59de245000a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5ce7672cc9532d48c53cf61a2f66590 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5ce7672cc9532d48c53cf61a2f66590.addTo(map_b7bfeea2fd3442d5275ec59de245000a);
#
#
#             var feature_group_e81ff8f9c2c72face21cefcf6705eafd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e81ff8f9c2c72face21cefcf6705eafd.addTo(map_b7bfeea2fd3442d5275ec59de245000a);
#
#
#             var feature_group_sub_group_ee01dd5e185fbad0ce43a9105b131da6 = L.featureGroup.subGroup(
#                 feature_group_e81ff8f9c2c72face21cefcf6705eafd
#             );
#
#
#             var marker_72c4ed20b9268a53d986cf3234907750 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee01dd5e185fbad0ce43a9105b131da6);
#
#
#         var popup_d6f0c65517c29eb59a9742c93f4a66c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986cfc11451df379011139b2fbe65a44 = $(`&lt;div id=&quot;html_986cfc11451df379011139b2fbe65a44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d6f0c65517c29eb59a9742c93f4a66c6.setContent(html_986cfc11451df379011139b2fbe65a44);
#
#
#
#         marker_72c4ed20b9268a53d986cf3234907750.bindPopup(popup_d6f0c65517c29eb59a9742c93f4a66c6)
#         ;
#
#
#
#
#             var marker_c5044ce665d40dd4ed26dfe4ce31d42d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee01dd5e185fbad0ce43a9105b131da6);
#
#
#         var popup_06b736df66aef1ec558e293e3419a170 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06dba943c4d5cce191dbdf855625d106 = $(`&lt;div id=&quot;html_06dba943c4d5cce191dbdf855625d106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_06b736df66aef1ec558e293e3419a170.setContent(html_06dba943c4d5cce191dbdf855625d106);
#
#
#
#         marker_c5044ce665d40dd4ed26dfe4ce31d42d.bindPopup(popup_06b736df66aef1ec558e293e3419a170)
#         ;
#
#
#
#
#             var marker_472c5330008327839dba5a5881f2146f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee01dd5e185fbad0ce43a9105b131da6);
#
#
#         var popup_918dde33ba403f54100fccd3a9c6ebd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2890062b5fb5c7cb8c3395e9e3cec59 = $(`&lt;div id=&quot;html_b2890062b5fb5c7cb8c3395e9e3cec59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_918dde33ba403f54100fccd3a9c6ebd5.setContent(html_b2890062b5fb5c7cb8c3395e9e3cec59);
#
#
#
#         marker_472c5330008327839dba5a5881f2146f.bindPopup(popup_918dde33ba403f54100fccd3a9c6ebd5)
#         ;
#
#
#
#
#             var marker_2b7a036254dcb5ca009716114b01d64f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ee01dd5e185fbad0ce43a9105b131da6);
#
#
#         var popup_c9c6e321422e7f33ce98fdc59ddff424 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1421dea907bb88464a169d60a31f41ea = $(`&lt;div id=&quot;html_1421dea907bb88464a169d60a31f41ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c9c6e321422e7f33ce98fdc59ddff424.setContent(html_1421dea907bb88464a169d60a31f41ea);
#
#
#
#         marker_
