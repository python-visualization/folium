# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cd1d229fcac5bf53e5324606f16184d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cd1d229fcac5bf53e5324606f16184d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cd1d229fcac5bf53e5324606f16184d = L.map(
#                 &quot;map_2cd1d229fcac5bf53e5324606f16184d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18e55a1149ed3dd740a05899c0693e13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18e55a1149ed3dd740a05899c0693e13.addTo(map_2cd1d229fcac5bf53e5324606f16184d);
#
#
#             var marker_a763bececa3895cdc68df1971df06584 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2cd1d229fcac5bf53e5324606f16184d);
#
#
#         var popup_0fc87c9d92ce7924186eb0e848770da1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21fbebcfab411a9ba7ad31143d2d389b = $(`&lt;div id=&quot;html_21fbebcfab411a9ba7ad31143d2d389b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0fc87c9d92ce7924186eb0e848770da1.setContent(html_21fbebcfab411a9ba7ad31143d2d389b);
#
#
#
#         marker_a763bececa3895cdc68df1971df06584.bindPopup(popup_0fc87c9d92ce7924186eb0e848770da1)
#         ;
#
#
#
#
#             var marker_95da291b05457b82f5a84e7c8c16faff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2cd1d229fcac5bf53e5324606f16184d);
#
#
#         var popup_0bb5b697e433721b9bc4d48026fa31ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b08ec83db05f24e0a1958a77c9c719ce = $(`&lt;div id=&quot;html_b08ec83db05f24e0a1958a77c9c719ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0bb5b697e433721b9bc4d48026fa31ad.setContent(html_b08ec83db05f24e0a1958a77c9c719ce);
#
#
#
#         marker_95da291b05457b82f5a84e7c8c16faff.bindPopup(popup_0bb5b697e433721b9bc4d48026fa31ad)
#         ;
#
#
#
#
#             var marker_6ffda6d8e45021f397d6c1adf7a4430b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2cd1d229fcac5bf53e5324606f16184d);
#
#
#         var popup_63d7d67a38ddc4de91cb0b08687b58c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed50d3dbc345bba4ea1d919c0898656a = $(`&lt;div id=&quot;html_ed50d3dbc345bba4ea1d919c0898656a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_63d7d67a38ddc4de91cb0b08687b58c6.setContent(html_ed50d3dbc345bba4ea1d919c0898656a);
#
#
#
#         marker_6ffda6d8e45021f397d6c1adf7a4430b.bindPopup(popup_63d7d67a38ddc4de91cb0b08687b58c6)
#         ;
#
#
#
#
#             var marker_cda067e2a813c21c601dffd7e3d6d6c7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2cd1d229fcac5bf53e5324606f16184d);
#
#
#         var popup_365ba8f6e44e3f64cb70500fa457ef6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1795eee622355db1bdb05773dadc581e = $(`&lt;div id=&quot;html_1795eee622355db1bdb05773dadc581e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_365ba8f6e44e3f64cb70500fa457ef6e.setContent(html_1795eee622355db1bdb05773dadc581e);
#
#
#
#         marker_cda067e2a813c21c601dffd7e3d6d6c7.bindPopup(popup_365ba8f6e44e3f64cb70500fa457ef6e)
#         ;
#
#
#
#
#             var marker_80503855fdc6d641818d655c09197791 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2cd1d229fcac5bf53e5324606f16184d);
#
#
#         var popup_69aaa99bbfc9ff356b9cdf364a067bad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eed57359138f2ed0f19722dd9c61abb = $(`&lt;div id=&quot;html_2eed57359138f2ed0f19722dd9c61abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_69aaa99bbfc9ff356b9cdf364a067b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20d4cb720f1d276b68798475ac07aa6e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20d4cb720f1d276b68798475ac07aa6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20d4cb720f1d276b68798475ac07aa6e = L.map(
#                 &quot;map_20d4cb720f1d276b68798475ac07aa6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4c183a7a7075eac7ffd0549e0e3a619 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4c183a7a7075eac7ffd0549e0e3a619.addTo(map_20d4cb720f1d276b68798475ac07aa6e);
#
#
#             var feature_group_091f4aae2667ee808edd947375e4acc9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ae20fcc37c0b8f3b989bc6d3f2982890 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_091f4aae2667ee808edd947375e4acc9);
#
#
#         var popup_46c500538221a790822edb1103cd9621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df27a25085c7f4257c015fe9ae35fa40 = $(`&lt;div id=&quot;html_df27a25085c7f4257c015fe9ae35fa40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_46c500538221a790822edb1103cd9621.setContent(html_df27a25085c7f4257c015fe9ae35fa40);
#
#
#
#         marker_ae20fcc37c0b8f3b989bc6d3f2982890.bindPopup(popup_46c500538221a790822edb1103cd9621)
#         ;
#
#
#
#
#             var marker_76409ef250f373e3f67ce2f2991655e9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_091f4aae2667ee808edd947375e4acc9);
#
#
#         var popup_39ff914c2a63854e2921bf677e768427 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dae01711459e5256e14404f5d580441 = $(`&lt;div id=&quot;html_9dae01711459e5256e14404f5d580441&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_39ff914c2a63854e2921bf677e768427.setContent(html_9dae01711459e5256e14404f5d580441);
#
#
#
#         marker_76409ef250f373e3f67ce2f2991655e9.bindPopup(popup_39ff914c2a63854e2921bf677e768427)
#         ;
#
#
#
#
#             var marker_fb3b0049ca85b279b10eb5d848de0c3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_091f4aae2667ee808edd947375e4acc9);
#
#
#         var popup_9b2ea814ab40ca8c827169d50e91633e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17cdf85df23977cb99d030832648d24b = $(`&lt;div id=&quot;html_17cdf85df23977cb99d030832648d24b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b2ea814ab40ca8c827169d50e91633e.setContent(html_17cdf85df23977cb99d030832648d24b);
#
#
#
#         marker_fb3b0049ca85b279b10eb5d848de0c3f.bindPopup(popup_9b2ea814ab40ca8c827169d50e91633e)
#         ;
#
#
#
#
#             var marker_963acd871a9cfdf70424d5c72b3fb01f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_091f4aae2667ee808edd947375e4acc9);
#
#
#         var popup_b1401562f470d600357b863b71058733 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbb2a91cdb04c30b62e9f5d2e0adf2a7 = $(`&lt;div id=&quot;html_cbb2a91cdb04c30b62e9f5d2e0adf2a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b1401562f470d600357b863b71058733.setContent(html_cbb2a91cdb04c30b62e9f5d2e0adf2a7);
#
#
#
#         marker_963acd871a9cfdf70424d5c72b3fb01f.bindPopup(popup_b1401562f470d600357b863b71058733)
#         ;
#
#
#
#
#             var marker_5d648208915dec1218a2405fa8127988 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_091f4aae2667ee808edd947375e4acc9);
#
#
#         var popup_6e087028eb0851d555698c52d0961945 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ead34f92270daba61d55db0159f109e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ead34f92270daba61d55db0159f109e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ead34f92270daba61d55db0159f109e = L.map(
#                 &quot;map_3ead34f92270daba61d55db0159f109e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcb3a87ec72f2f658ef275abe68f3118 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcb3a87ec72f2f658ef275abe68f3118.addTo(map_3ead34f92270daba61d55db0159f109e);
#
#
#             var feature_group_c9170204aed68d6a471728c4ca546808 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c9170204aed68d6a471728c4ca546808.addTo(map_3ead34f92270daba61d55db0159f109e);
#
#
#             var feature_group_sub_group_74e220e5618cd7779d1786448954edc4 = L.featureGroup.subGroup(
#                 feature_group_c9170204aed68d6a471728c4ca546808
#             );
#
#
#             var marker_8f7bcd64353d213f29788f34f7f9b599 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e220e5618cd7779d1786448954edc4);
#
#
#         var popup_1aeeb828a7e719dce8ab126b87845626 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c10dfb63f23f70bdf017b299c28db10 = $(`&lt;div id=&quot;html_2c10dfb63f23f70bdf017b299c28db10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1aeeb828a7e719dce8ab126b87845626.setContent(html_2c10dfb63f23f70bdf017b299c28db10);
#
#
#
#         marker_8f7bcd64353d213f29788f34f7f9b599.bindPopup(popup_1aeeb828a7e719dce8ab126b87845626)
#         ;
#
#
#
#
#             var marker_48a188494b9666c2b97a34a5b57eab12 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e220e5618cd7779d1786448954edc4);
#
#
#         var popup_ee74222d64ccd0ce4b6eb3e569708b72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72fa1ed0a3f3ecc0d528da04bb3a6cc3 = $(`&lt;div id=&quot;html_72fa1ed0a3f3ecc0d528da04bb3a6cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ee74222d64ccd0ce4b6eb3e569708b72.setContent(html_72fa1ed0a3f3ecc0d528da04bb3a6cc3);
#
#
#
#         marker_48a188494b9666c2b97a34a5b57eab12.bindPopup(popup_ee74222d64ccd0ce4b6eb3e569708b72)
#         ;
#
#
#
#
#             var marker_716f934a2cdaf2186b69739988029e80 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e220e5618cd7779d1786448954edc4);
#
#
#         var popup_379a3ac6b6e5badb6300f1d532976c7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bb89fe8a077f54b9c6d429d2a7fba98 = $(`&lt;div id=&quot;html_2bb89fe8a077f54b9c6d429d2a7fba98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_379a3ac6b6e5badb6300f1d532976c7a.setContent(html_2bb89fe8a077f54b9c6d429d2a7fba98);
#
#
#
#         marker_716f934a2cdaf2186b69739988029e80.bindPopup(popup_379a3ac6b6e5badb6300f1d532976c7a)
#         ;
#
#
#
#
#             var marker_96668cc8100d831cd6b68f5662c44440 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_74e220e5618cd7779d1786448954edc4);
#
#
#         var popup_5b1ea26b9789a83d0d04e22ac2cfbaf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b703ee38a8ae325866e3ec1748f4f37 = $(`&lt;div id=&quot;html_0b703ee38a8ae325866e3ec1748f4f37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5b1ea26b9789a83d0d04e22ac2cfbaf9.setContent(html_0b703ee38a8ae325866e3ec1748f4f37);
#
#
#
#         mark
