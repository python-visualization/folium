# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9db2dcb8e708f5dbedbf6166dcc4038e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9db2dcb8e708f5dbedbf6166dcc4038e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9db2dcb8e708f5dbedbf6166dcc4038e = L.map(
#                 &quot;map_9db2dcb8e708f5dbedbf6166dcc4038e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97305e0cf7e8c29b80c7ece573454a01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97305e0cf7e8c29b80c7ece573454a01.addTo(map_9db2dcb8e708f5dbedbf6166dcc4038e);
#
#
#             var marker_13fca1c488d3ee588fe083c64c7b2fc2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9db2dcb8e708f5dbedbf6166dcc4038e);
#
#
#         var popup_2044f247ed7dc700f3a647dad8cf1e12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14c0cd01e55f14879674a69c0add06e2 = $(`&lt;div id=&quot;html_14c0cd01e55f14879674a69c0add06e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2044f247ed7dc700f3a647dad8cf1e12.setContent(html_14c0cd01e55f14879674a69c0add06e2);
#
#
#
#         marker_13fca1c488d3ee588fe083c64c7b2fc2.bindPopup(popup_2044f247ed7dc700f3a647dad8cf1e12)
#         ;
#
#
#
#
#             var marker_0b467da7b34c1220e6fdde93ef15e2f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9db2dcb8e708f5dbedbf6166dcc4038e);
#
#
#         var popup_9287994bf68eb49edf70c3f3e70ac09b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb082f6915ebfb9ae90f882e89101665 = $(`&lt;div id=&quot;html_bb082f6915ebfb9ae90f882e89101665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9287994bf68eb49edf70c3f3e70ac09b.setContent(html_bb082f6915ebfb9ae90f882e89101665);
#
#
#
#         marker_0b467da7b34c1220e6fdde93ef15e2f5.bindPopup(popup_9287994bf68eb49edf70c3f3e70ac09b)
#         ;
#
#
#
#
#             var marker_7ba551773ef7aa933f8d220d882ab5ce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9db2dcb8e708f5dbedbf6166dcc4038e);
#
#
#         var popup_5b7eb8754ec0b8e88ab5c893a4df80e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_379b87b6890ebf05179746ec2f9b9736 = $(`&lt;div id=&quot;html_379b87b6890ebf05179746ec2f9b9736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5b7eb8754ec0b8e88ab5c893a4df80e2.setContent(html_379b87b6890ebf05179746ec2f9b9736);
#
#
#
#         marker_7ba551773ef7aa933f8d220d882ab5ce.bindPopup(popup_5b7eb8754ec0b8e88ab5c893a4df80e2)
#         ;
#
#
#
#
#             var marker_55fef1ff55d4bc6d316fcd98526f4ed9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9db2dcb8e708f5dbedbf6166dcc4038e);
#
#
#         var popup_4c463fc42398841744337e6dbe906434 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9619ab3bef3174d53a71a3ac562b861 = $(`&lt;div id=&quot;html_d9619ab3bef3174d53a71a3ac562b861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4c463fc42398841744337e6dbe906434.setContent(html_d9619ab3bef3174d53a71a3ac562b861);
#
#
#
#         marker_55fef1ff55d4bc6d316fcd98526f4ed9.bindPopup(popup_4c463fc42398841744337e6dbe906434)
#         ;
#
#
#
#
#             var marker_57b95e9e6afab4422dad3f5bd18c1136 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9db2dcb8e708f5dbedbf6166dcc4038e);
#
#
#         var popup_bb317a09a0c0fcbd6ca3c9f4d9b1af4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ac62111f826f4dffc60812319ae1396 = $(`&lt;div id=&quot;html_6ac62111f826f4dffc60812319ae1396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bb317a09a0c0fcbd6ca3c9f4d9b1af4b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cff4e2c130212db929632d96e858460e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cff4e2c130212db929632d96e858460e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cff4e2c130212db929632d96e858460e = L.map(
#                 &quot;map_cff4e2c130212db929632d96e858460e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f59b209e6e8d44b8138668e68b23a54e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f59b209e6e8d44b8138668e68b23a54e.addTo(map_cff4e2c130212db929632d96e858460e);
#
#
#             var feature_group_76c06ee3f77585ee64f55b758038fa0f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e9c348669d48d089fd0b09306ff4f07a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_76c06ee3f77585ee64f55b758038fa0f);
#
#
#         var popup_c43b063327ae6b4eec55104b712bc1bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81c9deceb0c5290230e661adbf77cf37 = $(`&lt;div id=&quot;html_81c9deceb0c5290230e661adbf77cf37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c43b063327ae6b4eec55104b712bc1bc.setContent(html_81c9deceb0c5290230e661adbf77cf37);
#
#
#
#         marker_e9c348669d48d089fd0b09306ff4f07a.bindPopup(popup_c43b063327ae6b4eec55104b712bc1bc)
#         ;
#
#
#
#
#             var marker_a53005bc88563c0607e80f8030125915 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_76c06ee3f77585ee64f55b758038fa0f);
#
#
#         var popup_6d09d3249230d80b608255658fc39bb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80467e0519de5086555e1b5d08279dc3 = $(`&lt;div id=&quot;html_80467e0519de5086555e1b5d08279dc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6d09d3249230d80b608255658fc39bb7.setContent(html_80467e0519de5086555e1b5d08279dc3);
#
#
#
#         marker_a53005bc88563c0607e80f8030125915.bindPopup(popup_6d09d3249230d80b608255658fc39bb7)
#         ;
#
#
#
#
#             var marker_57f17a9418795593d7fbc78425942603 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_76c06ee3f77585ee64f55b758038fa0f);
#
#
#         var popup_0fd993219d3ecf7b1f484e40beaa49d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a8f40af2f23c081a9f103ce37e73756 = $(`&lt;div id=&quot;html_1a8f40af2f23c081a9f103ce37e73756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0fd993219d3ecf7b1f484e40beaa49d6.setContent(html_1a8f40af2f23c081a9f103ce37e73756);
#
#
#
#         marker_57f17a9418795593d7fbc78425942603.bindPopup(popup_0fd993219d3ecf7b1f484e40beaa49d6)
#         ;
#
#
#
#
#             var marker_a7a76a4b57e3db902e2956d0b93df319 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_76c06ee3f77585ee64f55b758038fa0f);
#
#
#         var popup_a54a0436776c49493af544f211d5b7c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ec3350350d0eb9030c67f299a2e3131 = $(`&lt;div id=&quot;html_5ec3350350d0eb9030c67f299a2e3131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a54a0436776c49493af544f211d5b7c5.setContent(html_5ec3350350d0eb9030c67f299a2e3131);
#
#
#
#         marker_a7a76a4b57e3db902e2956d0b93df319.bindPopup(popup_a54a0436776c49493af544f211d5b7c5)
#         ;
#
#
#
#
#             var marker_3e62f83bf665e9dfac92cb9d9ed0657c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_76c06ee3f77585ee64f55b758038fa0f);
#
#
#         var popup_8b219f68dc36b4c6497d8411b9777063 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61630799dab1d36234a0b718f560c5ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61630799dab1d36234a0b718f560c5ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61630799dab1d36234a0b718f560c5ec = L.map(
#                 &quot;map_61630799dab1d36234a0b718f560c5ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45d51f0f96a681eea727c27c5965fc7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45d51f0f96a681eea727c27c5965fc7d.addTo(map_61630799dab1d36234a0b718f560c5ec);
#
#
#             var feature_group_34883f8b6fc0c9ed13529b7d4dc78317 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_34883f8b6fc0c9ed13529b7d4dc78317.addTo(map_61630799dab1d36234a0b718f560c5ec);
#
#
#             var feature_group_sub_group_aa3d235dab354042c1a01c9cbb8b6017 = L.featureGroup.subGroup(
#                 feature_group_34883f8b6fc0c9ed13529b7d4dc78317
#             );
#
#
#             var marker_ec568c7cfce719aa3257a86d952b1a30 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa3d235dab354042c1a01c9cbb8b6017);
#
#
#         var popup_fa9b65d4757ee3580a42f80ff5f44762 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f15855c0074921fd6593d0f51d95b1e8 = $(`&lt;div id=&quot;html_f15855c0074921fd6593d0f51d95b1e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fa9b65d4757ee3580a42f80ff5f44762.setContent(html_f15855c0074921fd6593d0f51d95b1e8);
#
#
#
#         marker_ec568c7cfce719aa3257a86d952b1a30.bindPopup(popup_fa9b65d4757ee3580a42f80ff5f44762)
#         ;
#
#
#
#
#             var marker_200bb4ae434c8f2bd93189321bfd8750 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa3d235dab354042c1a01c9cbb8b6017);
#
#
#         var popup_c250aefbcdbbc787ce0ceb3d56b94dc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce8f51cc8fe23f2d4e0eacdbd57c4e42 = $(`&lt;div id=&quot;html_ce8f51cc8fe23f2d4e0eacdbd57c4e42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c250aefbcdbbc787ce0ceb3d56b94dc8.setContent(html_ce8f51cc8fe23f2d4e0eacdbd57c4e42);
#
#
#
#         marker_200bb4ae434c8f2bd93189321bfd8750.bindPopup(popup_c250aefbcdbbc787ce0ceb3d56b94dc8)
#         ;
#
#
#
#
#             var marker_109e736cc76b876485e2898cd7899e35 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa3d235dab354042c1a01c9cbb8b6017);
#
#
#         var popup_8cd53ed542a4647d35de4fe776350658 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b69990411f9dbb00624d68049f1cf441 = $(`&lt;div id=&quot;html_b69990411f9dbb00624d68049f1cf441&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8cd53ed542a4647d35de4fe776350658.setContent(html_b69990411f9dbb00624d68049f1cf441);
#
#
#
#         marker_109e736cc76b876485e2898cd7899e35.bindPopup(popup_8cd53ed542a4647d35de4fe776350658)
#         ;
#
#
#
#
#             var marker_de7f4aef91ce70cbb4a180ff4dfece2a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa3d235dab354042c1a01c9cbb8b6017);
#
#
#         var popup_d3c7124b5ba946335b81d018efed0ca7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9677c54eeec2c98466c56504684643de = $(`&lt;div id=&quot;html_9677c54eeec2c98466c56504684643de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d3c7124b5ba946335b81d018efed0ca7.setContent(html_9677c54eeec2c98466c56504684643de);
#
#
#
#         marker_
