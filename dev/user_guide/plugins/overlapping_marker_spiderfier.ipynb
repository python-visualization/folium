# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0b5b749740a9dc376ee6d60dafd35f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0b5b749740a9dc376ee6d60dafd35f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0b5b749740a9dc376ee6d60dafd35f0 = L.map(
#                 &quot;map_b0b5b749740a9dc376ee6d60dafd35f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_255864167d86796581ff9373662a87aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_255864167d86796581ff9373662a87aa.addTo(map_b0b5b749740a9dc376ee6d60dafd35f0);
#
#
#             var marker_2a63059ff31601f4c057d57af1e51d29 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b0b5b749740a9dc376ee6d60dafd35f0);
#
#
#         var popup_95331aad1f1922d638687e21eb14e517 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c64174d1f55ce751db8b9242790f11 = $(`&lt;div id=&quot;html_f5c64174d1f55ce751db8b9242790f11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_95331aad1f1922d638687e21eb14e517.setContent(html_f5c64174d1f55ce751db8b9242790f11);
#
#
#
#         marker_2a63059ff31601f4c057d57af1e51d29.bindPopup(popup_95331aad1f1922d638687e21eb14e517)
#         ;
#
#
#
#
#             var marker_33d67745d422a423b5698d652cc65e78 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b0b5b749740a9dc376ee6d60dafd35f0);
#
#
#         var popup_9b749915d2303014bf8f80a344ae143b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_970642bdec54de8975cf54b56974e1b9 = $(`&lt;div id=&quot;html_970642bdec54de8975cf54b56974e1b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9b749915d2303014bf8f80a344ae143b.setContent(html_970642bdec54de8975cf54b56974e1b9);
#
#
#
#         marker_33d67745d422a423b5698d652cc65e78.bindPopup(popup_9b749915d2303014bf8f80a344ae143b)
#         ;
#
#
#
#
#             var marker_f8517b29e94b6b9a23e2ea0dccad2097 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b0b5b749740a9dc376ee6d60dafd35f0);
#
#
#         var popup_a014ae68b39565fcb6be0ba64759cab2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68f7763cba7649a2f2145a8fc7909790 = $(`&lt;div id=&quot;html_68f7763cba7649a2f2145a8fc7909790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a014ae68b39565fcb6be0ba64759cab2.setContent(html_68f7763cba7649a2f2145a8fc7909790);
#
#
#
#         marker_f8517b29e94b6b9a23e2ea0dccad2097.bindPopup(popup_a014ae68b39565fcb6be0ba64759cab2)
#         ;
#
#
#
#
#             var marker_0e68a4632620b9aa666886a368dd4118 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b0b5b749740a9dc376ee6d60dafd35f0);
#
#
#         var popup_9009b9b9925e75e4d0759ef915ada6b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d59b5aa3566516ab6a88a55c270446ac = $(`&lt;div id=&quot;html_d59b5aa3566516ab6a88a55c270446ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9009b9b9925e75e4d0759ef915ada6b2.setContent(html_d59b5aa3566516ab6a88a55c270446ac);
#
#
#
#         marker_0e68a4632620b9aa666886a368dd4118.bindPopup(popup_9009b9b9925e75e4d0759ef915ada6b2)
#         ;
#
#
#
#
#             var marker_5d30f6786522d1d8269b1d6cb1d6e6fd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b0b5b749740a9dc376ee6d60dafd35f0);
#
#
#         var popup_55d158a0801bd3710e961f9299ffadc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73255a524b1688f63f405598b591f1da = $(`&lt;div id=&quot;html_73255a524b1688f63f405598b591f1da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_55d158a0801bd3710e961f9299ffadc7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e84fce3107bb55b77017c5bfe63e6f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e84fce3107bb55b77017c5bfe63e6f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e84fce3107bb55b77017c5bfe63e6f2 = L.map(
#                 &quot;map_3e84fce3107bb55b77017c5bfe63e6f2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5e154d8414c71147dcd063eb7452ffd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5e154d8414c71147dcd063eb7452ffd.addTo(map_3e84fce3107bb55b77017c5bfe63e6f2);
#
#
#             var feature_group_a4596d08995dca0b5bc890231eee5853 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c2b918787db5923237d1b2dcb16e3929 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a4596d08995dca0b5bc890231eee5853);
#
#
#         var popup_5129126289a8259561edc1a7c35a5802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d7326930da0e8f3787ca5ddda87a7dc = $(`&lt;div id=&quot;html_2d7326930da0e8f3787ca5ddda87a7dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5129126289a8259561edc1a7c35a5802.setContent(html_2d7326930da0e8f3787ca5ddda87a7dc);
#
#
#
#         marker_c2b918787db5923237d1b2dcb16e3929.bindPopup(popup_5129126289a8259561edc1a7c35a5802)
#         ;
#
#
#
#
#             var marker_c21bd5c7afd52ebfcff6f50314ed14ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a4596d08995dca0b5bc890231eee5853);
#
#
#         var popup_4883890d229d4578233a8cfa34e517a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1309e927aa06bec0aa406fbce3aa0e99 = $(`&lt;div id=&quot;html_1309e927aa06bec0aa406fbce3aa0e99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4883890d229d4578233a8cfa34e517a6.setContent(html_1309e927aa06bec0aa406fbce3aa0e99);
#
#
#
#         marker_c21bd5c7afd52ebfcff6f50314ed14ee.bindPopup(popup_4883890d229d4578233a8cfa34e517a6)
#         ;
#
#
#
#
#             var marker_178777d3f517ba4f7dd257c68c2ae3d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a4596d08995dca0b5bc890231eee5853);
#
#
#         var popup_d29d2c5053ce77e0251a556285744411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19f03e78326cdbccf5a1d58466260f31 = $(`&lt;div id=&quot;html_19f03e78326cdbccf5a1d58466260f31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d29d2c5053ce77e0251a556285744411.setContent(html_19f03e78326cdbccf5a1d58466260f31);
#
#
#
#         marker_178777d3f517ba4f7dd257c68c2ae3d7.bindPopup(popup_d29d2c5053ce77e0251a556285744411)
#         ;
#
#
#
#
#             var marker_e18e30a2ead5c33fae18f07e61074e3c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a4596d08995dca0b5bc890231eee5853);
#
#
#         var popup_abeb998d5b153d1700849f15f9390e2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_930ca3f62321619f7d01c19fd0eec752 = $(`&lt;div id=&quot;html_930ca3f62321619f7d01c19fd0eec752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_abeb998d5b153d1700849f15f9390e2a.setContent(html_930ca3f62321619f7d01c19fd0eec752);
#
#
#
#         marker_e18e30a2ead5c33fae18f07e61074e3c.bindPopup(popup_abeb998d5b153d1700849f15f9390e2a)
#         ;
#
#
#
#
#             var marker_c81f6d7818b8e84d25b1da08db8fea60 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a4596d08995dca0b5bc890231eee5853);
#
#
#         var popup_b1289c7ef534e31d62dd1078eab876ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85746731b18543373ebbcc4c02550356 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85746731b18543373ebbcc4c02550356&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85746731b18543373ebbcc4c02550356 = L.map(
#                 &quot;map_85746731b18543373ebbcc4c02550356&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_381e34a552fdaaa0035e6442132398ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_381e34a552fdaaa0035e6442132398ee.addTo(map_85746731b18543373ebbcc4c02550356);
#
#
#             var feature_group_19a9c0bebff01a52ba7a1d336c975c7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_19a9c0bebff01a52ba7a1d336c975c7b.addTo(map_85746731b18543373ebbcc4c02550356);
#
#
#             var feature_group_sub_group_601020f48fd0adfebd26dda02cd2a652 = L.featureGroup.subGroup(
#                 feature_group_19a9c0bebff01a52ba7a1d336c975c7b
#             );
#
#
#             var marker_190a61e9159dfe69e9baf22362a1bbbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_601020f48fd0adfebd26dda02cd2a652);
#
#
#         var popup_fcc02e92844cb03d65ae6ce4d75c138e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ed38c8106786e2fd70c2ceff040841 = $(`&lt;div id=&quot;html_e2ed38c8106786e2fd70c2ceff040841&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fcc02e92844cb03d65ae6ce4d75c138e.setContent(html_e2ed38c8106786e2fd70c2ceff040841);
#
#
#
#         marker_190a61e9159dfe69e9baf22362a1bbbd.bindPopup(popup_fcc02e92844cb03d65ae6ce4d75c138e)
#         ;
#
#
#
#
#             var marker_a8a770be2e04830aed057490b4722d73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_601020f48fd0adfebd26dda02cd2a652);
#
#
#         var popup_75a1689ca33ad3fce99fa12600473575 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d4446c9a12aebbf19d82fdfdd8385b4 = $(`&lt;div id=&quot;html_8d4446c9a12aebbf19d82fdfdd8385b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_75a1689ca33ad3fce99fa12600473575.setContent(html_8d4446c9a12aebbf19d82fdfdd8385b4);
#
#
#
#         marker_a8a770be2e04830aed057490b4722d73.bindPopup(popup_75a1689ca33ad3fce99fa12600473575)
#         ;
#
#
#
#
#             var marker_99147e294be05aa2d4e2d6421aa49105 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_601020f48fd0adfebd26dda02cd2a652);
#
#
#         var popup_51a0750932cbf3e56cd071ce74508dfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0d294d3332b3f562f0dd83af0bc176f = $(`&lt;div id=&quot;html_e0d294d3332b3f562f0dd83af0bc176f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_51a0750932cbf3e56cd071ce74508dfe.setContent(html_e0d294d3332b3f562f0dd83af0bc176f);
#
#
#
#         marker_99147e294be05aa2d4e2d6421aa49105.bindPopup(popup_51a0750932cbf3e56cd071ce74508dfe)
#         ;
#
#
#
#
#             var marker_247f01d907fd757fee543dde5ccb04e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_601020f48fd0adfebd26dda02cd2a652);
#
#
#         var popup_0f161422c3950c676f10d7da88833900 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f0d75a9569166db571c29a48b325963 = $(`&lt;div id=&quot;html_0f0d75a9569166db571c29a48b325963&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0f161422c3950c676f10d7da88833900.setContent(html_0f0d75a9569166db571c29a48b325963);
#
#
#
#         marker_
