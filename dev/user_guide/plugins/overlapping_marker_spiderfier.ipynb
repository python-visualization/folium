# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08d744d87274a5bed6441755c12b8972 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08d744d87274a5bed6441755c12b8972&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08d744d87274a5bed6441755c12b8972 = L.map(
#                 &quot;map_08d744d87274a5bed6441755c12b8972&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91e9c1a00a269c21a981bf39d070f9c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91e9c1a00a269c21a981bf39d070f9c2.addTo(map_08d744d87274a5bed6441755c12b8972);
#
#
#             var marker_fa0ad9d479b33f239718b9cc5af36be4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_08d744d87274a5bed6441755c12b8972);
#
#
#         var popup_b61ad49969ba1ba66afc3f227558debd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f46c7569d9e307ebbd41ef3c8246be48 = $(`&lt;div id=&quot;html_f46c7569d9e307ebbd41ef3c8246be48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b61ad49969ba1ba66afc3f227558debd.setContent(html_f46c7569d9e307ebbd41ef3c8246be48);
#
#
#
#         marker_fa0ad9d479b33f239718b9cc5af36be4.bindPopup(popup_b61ad49969ba1ba66afc3f227558debd)
#         ;
#
#
#
#
#             var marker_ed7846aca15926c7c66795e6d114b24d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_08d744d87274a5bed6441755c12b8972);
#
#
#         var popup_f20de6faa103690a491711024baf3241 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c229fa4b45001cbf868e60e82ded09f1 = $(`&lt;div id=&quot;html_c229fa4b45001cbf868e60e82ded09f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f20de6faa103690a491711024baf3241.setContent(html_c229fa4b45001cbf868e60e82ded09f1);
#
#
#
#         marker_ed7846aca15926c7c66795e6d114b24d.bindPopup(popup_f20de6faa103690a491711024baf3241)
#         ;
#
#
#
#
#             var marker_b50fd77728329267d0b38737ee6a07da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_08d744d87274a5bed6441755c12b8972);
#
#
#         var popup_157bba7cddc0bb723e6220e6912bff61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a88374ce3a6b2006c8e662a952bc6fd = $(`&lt;div id=&quot;html_8a88374ce3a6b2006c8e662a952bc6fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_157bba7cddc0bb723e6220e6912bff61.setContent(html_8a88374ce3a6b2006c8e662a952bc6fd);
#
#
#
#         marker_b50fd77728329267d0b38737ee6a07da.bindPopup(popup_157bba7cddc0bb723e6220e6912bff61)
#         ;
#
#
#
#
#             var marker_f6707052711bdead4b457bd92e709b28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_08d744d87274a5bed6441755c12b8972);
#
#
#         var popup_5684337d03f3ffb6ec9aed83fea6cfa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_176c50221dc1380ce491aed0d8e9aedf = $(`&lt;div id=&quot;html_176c50221dc1380ce491aed0d8e9aedf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5684337d03f3ffb6ec9aed83fea6cfa7.setContent(html_176c50221dc1380ce491aed0d8e9aedf);
#
#
#
#         marker_f6707052711bdead4b457bd92e709b28.bindPopup(popup_5684337d03f3ffb6ec9aed83fea6cfa7)
#         ;
#
#
#
#
#             var marker_67100e62dd4f7c96be0c9520c11c648a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_08d744d87274a5bed6441755c12b8972);
#
#
#         var popup_2168db1368d371f7d3688b8939f8227d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_255fc9aa1c0fe62bad1009e200b54f30 = $(`&lt;div id=&quot;html_255fc9aa1c0fe62bad1009e200b54f30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2168db1368d371f7d3688b8939f8227d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b78e348211d8d2a7d6941dad87d8501 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b78e348211d8d2a7d6941dad87d8501&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b78e348211d8d2a7d6941dad87d8501 = L.map(
#                 &quot;map_4b78e348211d8d2a7d6941dad87d8501&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ea8644a86ec08304c864131d9ffffb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ea8644a86ec08304c864131d9ffffb0.addTo(map_4b78e348211d8d2a7d6941dad87d8501);
#
#
#             var feature_group_8d0604b2b9f2097afaaab1cee4415395 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e71e939c91336ed1a62fb40d729908f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8d0604b2b9f2097afaaab1cee4415395);
#
#
#         var popup_15273d38eb7c6e7b6d5db5e98677abda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d012b137d4887796145527a69a02ece = $(`&lt;div id=&quot;html_0d012b137d4887796145527a69a02ece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_15273d38eb7c6e7b6d5db5e98677abda.setContent(html_0d012b137d4887796145527a69a02ece);
#
#
#
#         marker_e71e939c91336ed1a62fb40d729908f4.bindPopup(popup_15273d38eb7c6e7b6d5db5e98677abda)
#         ;
#
#
#
#
#             var marker_e2b9f728839466daf30ee4e8b44fc288 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8d0604b2b9f2097afaaab1cee4415395);
#
#
#         var popup_94dec06872ab817778b402673bb4634a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3fd8fae9dbdaedfd4e87296c33efff1 = $(`&lt;div id=&quot;html_b3fd8fae9dbdaedfd4e87296c33efff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_94dec06872ab817778b402673bb4634a.setContent(html_b3fd8fae9dbdaedfd4e87296c33efff1);
#
#
#
#         marker_e2b9f728839466daf30ee4e8b44fc288.bindPopup(popup_94dec06872ab817778b402673bb4634a)
#         ;
#
#
#
#
#             var marker_eb7967cb7dd996339ccc023948ea7481 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8d0604b2b9f2097afaaab1cee4415395);
#
#
#         var popup_e879f8a23b268daad3a0033663599b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea33cb1702fe27332130e13e4d935af0 = $(`&lt;div id=&quot;html_ea33cb1702fe27332130e13e4d935af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e879f8a23b268daad3a0033663599b4b.setContent(html_ea33cb1702fe27332130e13e4d935af0);
#
#
#
#         marker_eb7967cb7dd996339ccc023948ea7481.bindPopup(popup_e879f8a23b268daad3a0033663599b4b)
#         ;
#
#
#
#
#             var marker_0f93bc49bf8eabe21e3123a6e6b1e951 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8d0604b2b9f2097afaaab1cee4415395);
#
#
#         var popup_5ede565ad32e5878684423bfb4f340b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56b1000ade9fd7d0032b1933f8a82512 = $(`&lt;div id=&quot;html_56b1000ade9fd7d0032b1933f8a82512&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ede565ad32e5878684423bfb4f340b9.setContent(html_56b1000ade9fd7d0032b1933f8a82512);
#
#
#
#         marker_0f93bc49bf8eabe21e3123a6e6b1e951.bindPopup(popup_5ede565ad32e5878684423bfb4f340b9)
#         ;
#
#
#
#
#             var marker_71058f60fedc6deaa710ea3c590f5eed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8d0604b2b9f2097afaaab1cee4415395);
#
#
#         var popup_b4d6950a2c57ea7e7a745bc78dec2c50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71727273a3177217b926c578dd7b7123 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71727273a3177217b926c578dd7b7123&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71727273a3177217b926c578dd7b7123 = L.map(
#                 &quot;map_71727273a3177217b926c578dd7b7123&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eff23c156499b932055d06cba68e7be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8eff23c156499b932055d06cba68e7be.addTo(map_71727273a3177217b926c578dd7b7123);
#
#
#             var feature_group_0418bf7b9acfb9425e0de763a56c9321 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0418bf7b9acfb9425e0de763a56c9321.addTo(map_71727273a3177217b926c578dd7b7123);
#
#
#             var feature_group_sub_group_8c691aff5ebfe42ebe567a8b7a928f93 = L.featureGroup.subGroup(
#                 feature_group_0418bf7b9acfb9425e0de763a56c9321
#             );
#
#
#             var marker_3632b70ad23812d34aff837fde475529 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c691aff5ebfe42ebe567a8b7a928f93);
#
#
#         var popup_d6e34699c16e7f815b5d9b68b9ca14bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c2ae80a605c9c84daebaec617ee4c3f = $(`&lt;div id=&quot;html_8c2ae80a605c9c84daebaec617ee4c3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d6e34699c16e7f815b5d9b68b9ca14bd.setContent(html_8c2ae80a605c9c84daebaec617ee4c3f);
#
#
#
#         marker_3632b70ad23812d34aff837fde475529.bindPopup(popup_d6e34699c16e7f815b5d9b68b9ca14bd)
#         ;
#
#
#
#
#             var marker_b4c87f792551791e89d0455d6208895a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c691aff5ebfe42ebe567a8b7a928f93);
#
#
#         var popup_1443c7c93bd77861c812a54175ce083a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86a86832edaaf28fd3dab5eec840ee97 = $(`&lt;div id=&quot;html_86a86832edaaf28fd3dab5eec840ee97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1443c7c93bd77861c812a54175ce083a.setContent(html_86a86832edaaf28fd3dab5eec840ee97);
#
#
#
#         marker_b4c87f792551791e89d0455d6208895a.bindPopup(popup_1443c7c93bd77861c812a54175ce083a)
#         ;
#
#
#
#
#             var marker_016b25f4704673d2d7a84cac6cbcbe10 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c691aff5ebfe42ebe567a8b7a928f93);
#
#
#         var popup_13b3959b51125a6095376b946d50ceee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f944057229f90cc6ded9206dee4adbd5 = $(`&lt;div id=&quot;html_f944057229f90cc6ded9206dee4adbd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_13b3959b51125a6095376b946d50ceee.setContent(html_f944057229f90cc6ded9206dee4adbd5);
#
#
#
#         marker_016b25f4704673d2d7a84cac6cbcbe10.bindPopup(popup_13b3959b51125a6095376b946d50ceee)
#         ;
#
#
#
#
#             var marker_048c9c8a0c9eddfd80f23c11324234ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c691aff5ebfe42ebe567a8b7a928f93);
#
#
#         var popup_c0fc1ccafb39515557d8f39c9b2b1915 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9a98bfa0b763836c7fe0b6bdf53a863 = $(`&lt;div id=&quot;html_b9a98bfa0b763836c7fe0b6bdf53a863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c0fc1ccafb39515557d8f39c9b2b1915.setContent(html_b9a98bfa0b763836c7fe0b6bdf53a863);
#
#
#
#         marker_
