# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5ed57d2837848d34525a50a3cc1354f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5ed57d2837848d34525a50a3cc1354f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5ed57d2837848d34525a50a3cc1354f = L.map(
#                 &quot;map_a5ed57d2837848d34525a50a3cc1354f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_904c09113fbc694b9d6e2beaa736c345 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_904c09113fbc694b9d6e2beaa736c345.addTo(map_a5ed57d2837848d34525a50a3cc1354f);
#
#
#             var marker_9c891a8461a42aded5d8409f627646e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a5ed57d2837848d34525a50a3cc1354f);
#
#
#         var popup_fdc59e98a0560bf606a65dca043da71f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eef2653db909a7c77b2574d6c62557c = $(`&lt;div id=&quot;html_6eef2653db909a7c77b2574d6c62557c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fdc59e98a0560bf606a65dca043da71f.setContent(html_6eef2653db909a7c77b2574d6c62557c);
#
#
#
#         marker_9c891a8461a42aded5d8409f627646e6.bindPopup(popup_fdc59e98a0560bf606a65dca043da71f)
#         ;
#
#
#
#
#             var marker_8e97d552d1407a4cb5ff4d8e0e0b893a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a5ed57d2837848d34525a50a3cc1354f);
#
#
#         var popup_9f2a67a875696ebbfc1e0828392b33f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc54acb93e9a760e0139e1039cc32538 = $(`&lt;div id=&quot;html_cc54acb93e9a760e0139e1039cc32538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9f2a67a875696ebbfc1e0828392b33f9.setContent(html_cc54acb93e9a760e0139e1039cc32538);
#
#
#
#         marker_8e97d552d1407a4cb5ff4d8e0e0b893a.bindPopup(popup_9f2a67a875696ebbfc1e0828392b33f9)
#         ;
#
#
#
#
#             var marker_be78f1f8057a723d4433e8337d0f58d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a5ed57d2837848d34525a50a3cc1354f);
#
#
#         var popup_340924b2f2fe1f6a8680a383a81b9c61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fbf9b7a477a411683d9515ef303df8b = $(`&lt;div id=&quot;html_2fbf9b7a477a411683d9515ef303df8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_340924b2f2fe1f6a8680a383a81b9c61.setContent(html_2fbf9b7a477a411683d9515ef303df8b);
#
#
#
#         marker_be78f1f8057a723d4433e8337d0f58d3.bindPopup(popup_340924b2f2fe1f6a8680a383a81b9c61)
#         ;
#
#
#
#
#             var marker_8053293bf90e6ec527785b7063a525b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a5ed57d2837848d34525a50a3cc1354f);
#
#
#         var popup_219675bd87bf145b738e9c08d17d8982 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3b4e8c627f1bdf5eb119be5a854ea6c = $(`&lt;div id=&quot;html_c3b4e8c627f1bdf5eb119be5a854ea6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_219675bd87bf145b738e9c08d17d8982.setContent(html_c3b4e8c627f1bdf5eb119be5a854ea6c);
#
#
#
#         marker_8053293bf90e6ec527785b7063a525b2.bindPopup(popup_219675bd87bf145b738e9c08d17d8982)
#         ;
#
#
#
#
#             var marker_89b6903d962c64c3329268acf81b8bd6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a5ed57d2837848d34525a50a3cc1354f);
#
#
#         var popup_1149305cf544329d75d4fbe26cc6abd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ab6bbb9a3520330bbd592cb5f1f4784 = $(`&lt;div id=&quot;html_5ab6bbb9a3520330bbd592cb5f1f4784&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1149305cf544329d75d4fbe26cc6abd1.setContent(html_5ab6bbb9a3520330bbd592cb5f1f4784);
#
#
#
#         marker_89b6903d962c64c3329268acf81b8bd6.bindPopup(popup_1149305cf544329d75d4fbe26cc6abd1)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b7f73fce0da5457716f5bd420191078 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b7f73fce0da5457716f5bd420191078&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b7f73fce0da5457716f5bd420191078 = L.map(
#                 &quot;map_0b7f73fce0da5457716f5bd420191078&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9751426daeb6102cb5406b1e3d6a0b67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9751426daeb6102cb5406b1e3d6a0b67.addTo(map_0b7f73fce0da5457716f5bd420191078);
#
#
#             var feature_group_3864036471b2acbf63a32559fcbb20f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9cac0112a0529f3aceb2be34be273937 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3864036471b2acbf63a32559fcbb20f1);
#
#
#         var popup_89c214ae6ba5c6d7aba95ff121366f98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aed711a6f037acf47269e08a454f67d6 = $(`&lt;div id=&quot;html_aed711a6f037acf47269e08a454f67d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_89c214ae6ba5c6d7aba95ff121366f98.setContent(html_aed711a6f037acf47269e08a454f67d6);
#
#
#
#         marker_9cac0112a0529f3aceb2be34be273937.bindPopup(popup_89c214ae6ba5c6d7aba95ff121366f98)
#         ;
#
#
#
#
#             var marker_e96b5ea534cdee19c026c41da31eb496 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3864036471b2acbf63a32559fcbb20f1);
#
#
#         var popup_6866b3848a209ccbe94ea6ae6a688bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9b9f522e16a47cc3ec98af8388a22df = $(`&lt;div id=&quot;html_f9b9f522e16a47cc3ec98af8388a22df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6866b3848a209ccbe94ea6ae6a688bc2.setContent(html_f9b9f522e16a47cc3ec98af8388a22df);
#
#
#
#         marker_e96b5ea534cdee19c026c41da31eb496.bindPopup(popup_6866b3848a209ccbe94ea6ae6a688bc2)
#         ;
#
#
#
#
#             var marker_61c35c18906f0fcf83d34df142987642 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3864036471b2acbf63a32559fcbb20f1);
#
#
#         var popup_c41592076ebaf32c8c54bebcb42fb478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_560c42e6f738b99f189d4ebfce88ca5f = $(`&lt;div id=&quot;html_560c42e6f738b99f189d4ebfce88ca5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c41592076ebaf32c8c54bebcb42fb478.setContent(html_560c42e6f738b99f189d4ebfce88ca5f);
#
#
#
#         marker_61c35c18906f0fcf83d34df142987642.bindPopup(popup_c41592076ebaf32c8c54bebcb42fb478)
#         ;
#
#
#
#
#             var marker_be5228406cc98c986c67a078f2174d1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3864036471b2acbf63a32559fcbb20f1);
#
#
#         var popup_6c6b5d543c31062d2129d2ee722de10d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3174e7763b43ac8e7cf25b92929cffd = $(`&lt;div id=&quot;html_c3174e7763b43ac8e7cf25b92929cffd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6c6b5d543c31062d2129d2ee722de10d.setContent(html_c3174e7763b43ac8e7cf25b92929cffd);
#
#
#
#         marker_be5228406cc98c986c67a078f2174d1d.bindPopup(popup_6c6b5d543c31062d2129d2ee722de10d)
#         ;
#
#
#
#
#             var marker_6e74ba1bc097b3351563132544a7c2db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3864036471b2acbf63a32559fcbb20f1);
#
#
#         var popup_dd0c50bdc78f9073f87b99b706d2460c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec21c559f717774efa8ac24f36f00b85 = $(`&lt;div id=&quot;html_ec21c559f717774efa8ac24f36f00b85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a6660aedc8cba5aa504fdb8013915ea {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a6660aedc8cba5aa504fdb8013915ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a6660aedc8cba5aa504fdb8013915ea = L.map(
#                 &quot;map_4a6660aedc8cba5aa504fdb8013915ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd80ec775eee9d5352f0cd1e3855f3ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd80ec775eee9d5352f0cd1e3855f3ee.addTo(map_4a6660aedc8cba5aa504fdb8013915ea);
#
#
#             var feature_group_ad2173f8bb829c92b517ac9b2d63ae64 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ad2173f8bb829c92b517ac9b2d63ae64.addTo(map_4a6660aedc8cba5aa504fdb8013915ea);
#
#
#             var feature_group_sub_group_2a515b9731ec7d61d62bc3546ff0a8f7 = L.featureGroup.subGroup(
#                 feature_group_ad2173f8bb829c92b517ac9b2d63ae64
#             );
#
#
#             var marker_e9fc134087d98939c68b76a98597190d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a515b9731ec7d61d62bc3546ff0a8f7);
#
#
#         var popup_d136346d0caf070299963724d782dbdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_317fc097d7369d13853a105de6690d76 = $(`&lt;div id=&quot;html_317fc097d7369d13853a105de6690d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d136346d0caf070299963724d782dbdb.setContent(html_317fc097d7369d13853a105de6690d76);
#
#
#
#         marker_e9fc134087d98939c68b76a98597190d.bindPopup(popup_d136346d0caf070299963724d782dbdb)
#         ;
#
#
#
#
#             var marker_d93ee24e02b25011319999fb9ceb60b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a515b9731ec7d61d62bc3546ff0a8f7);
#
#
#         var popup_0eee0920c2adb8d53578bb7083f1cbac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e258638d786db0681c44a06be0387438 = $(`&lt;div id=&quot;html_e258638d786db0681c44a06be0387438&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0eee0920c2adb8d53578bb7083f1cbac.setContent(html_e258638d786db0681c44a06be0387438);
#
#
#
#         marker_d93ee24e02b25011319999fb9ceb60b4.bindPopup(popup_0eee0920c2adb8d53578bb7083f1cbac)
#         ;
#
#
#
#
#             var marker_78520ec7b7a9da6863d8c66246a149c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a515b9731ec7d61d62bc3546ff0a8f7);
#
#
#         var popup_58b9411d0f9fe3eb5fbbddce68f492a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c16333dc2a4ca0d8a5af330aa600ae0 = $(`&lt;div id=&quot;html_6c16333dc2a4ca0d8a5af330aa600ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_58b9411d0f9fe3eb5fbbddce68f492a1.setContent(html_6c16333dc2a4ca0d8a5af330aa600ae0);
#
#
#
#         marker_78520ec7b7a9da6863d8c66246a149c3.bindPopup(popup_58b9411d0f9fe3eb5fbbddce68f492a1)
#         ;
#
#
#
#
#             var marker_f43fcf28bbce4887261c3dd78685cc98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a515b9731ec7d61d62bc3546ff0a8f7);
#
#
#         var popup_045b90d42386776ce94991ce2953cc88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4aa5451b7c32302be2407b3ad057976 = $(`&lt;div id=&quot;html_d4aa5451b7c32302be2407b3ad057976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_045b90d42386776ce94991ce2953cc88.setContent(html_d4aa5451b7c32302be2407b3ad057976);
#
#
#
#         marker_f43fcf28bbce4887261c3dd78685cc98.bindPopup(popup_045b90d42386776ce94991ce2953cc88)
#         ;
#
#
#
#
#             var marker_6456767883415be5ad712665ea4c869d = L.marker(
#                 [45.0503999
