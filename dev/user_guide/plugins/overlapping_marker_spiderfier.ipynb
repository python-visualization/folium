# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb889044e49b7a2feb73ea68769ba8f8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb889044e49b7a2feb73ea68769ba8f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb889044e49b7a2feb73ea68769ba8f8 = L.map(
#                 &quot;map_cb889044e49b7a2feb73ea68769ba8f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43f8f38d6d5fc4e7da9e05edccceeb94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43f8f38d6d5fc4e7da9e05edccceeb94.addTo(map_cb889044e49b7a2feb73ea68769ba8f8);
#
#
#             var marker_88d06eb89e32e7a5c5684f3c5d2ac289 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cb889044e49b7a2feb73ea68769ba8f8);
#
#
#         var popup_61099a9630f62a4bd49d2aeef8b2baeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d96c665779b40b20aa5bd7503251072 = $(`&lt;div id=&quot;html_3d96c665779b40b20aa5bd7503251072&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_61099a9630f62a4bd49d2aeef8b2baeb.setContent(html_3d96c665779b40b20aa5bd7503251072);
#
#
#
#         marker_88d06eb89e32e7a5c5684f3c5d2ac289.bindPopup(popup_61099a9630f62a4bd49d2aeef8b2baeb)
#         ;
#
#
#
#
#             var marker_4920cff541931d3eb6fb1a578a606d17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cb889044e49b7a2feb73ea68769ba8f8);
#
#
#         var popup_4f596c41f192eb4046f80d5e574cd21b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ade8eece9be03bc8dcc4dbf2e19ffb6 = $(`&lt;div id=&quot;html_9ade8eece9be03bc8dcc4dbf2e19ffb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4f596c41f192eb4046f80d5e574cd21b.setContent(html_9ade8eece9be03bc8dcc4dbf2e19ffb6);
#
#
#
#         marker_4920cff541931d3eb6fb1a578a606d17.bindPopup(popup_4f596c41f192eb4046f80d5e574cd21b)
#         ;
#
#
#
#
#             var marker_bc196133511d5d41c3f3db30e5f6958f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cb889044e49b7a2feb73ea68769ba8f8);
#
#
#         var popup_49e4d4afe713b42921f87128e7f37175 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9087d43b74d7072e7428873721eb9811 = $(`&lt;div id=&quot;html_9087d43b74d7072e7428873721eb9811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_49e4d4afe713b42921f87128e7f37175.setContent(html_9087d43b74d7072e7428873721eb9811);
#
#
#
#         marker_bc196133511d5d41c3f3db30e5f6958f.bindPopup(popup_49e4d4afe713b42921f87128e7f37175)
#         ;
#
#
#
#
#             var marker_4e6a21c65ebf46d61fdad80081548643 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cb889044e49b7a2feb73ea68769ba8f8);
#
#
#         var popup_0322f3472401f3163918a430261ba561 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_506225031bcfd06b9d90fb9168a84f22 = $(`&lt;div id=&quot;html_506225031bcfd06b9d90fb9168a84f22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0322f3472401f3163918a430261ba561.setContent(html_506225031bcfd06b9d90fb9168a84f22);
#
#
#
#         marker_4e6a21c65ebf46d61fdad80081548643.bindPopup(popup_0322f3472401f3163918a430261ba561)
#         ;
#
#
#
#
#             var marker_aa0b97c0dfb101e8311678fd000d4db7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cb889044e49b7a2feb73ea68769ba8f8);
#
#
#         var popup_8e2797d6b1a55b860a739f597be42efe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a77e2b988fd112ea54a3d371dc09483 = $(`&lt;div id=&quot;html_3a77e2b988fd112ea54a3d371dc09483&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8e2797d6b1a55b860a739f597be42e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_767f5783aa728a2220f0952ecfc2bda4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_767f5783aa728a2220f0952ecfc2bda4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_767f5783aa728a2220f0952ecfc2bda4 = L.map(
#                 &quot;map_767f5783aa728a2220f0952ecfc2bda4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77e85597b7f0c0ef8360fa74873608b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77e85597b7f0c0ef8360fa74873608b6.addTo(map_767f5783aa728a2220f0952ecfc2bda4);
#
#
#             var feature_group_e260aa7ad87e7e44aa768c1b444e6c83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_04f2eb4bc8174f71b3ece18ce1e0d582 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e260aa7ad87e7e44aa768c1b444e6c83);
#
#
#         var popup_f4d08b42d6752c66073344134e1f917c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9cca9a7f8a7f4e763ad29669f83087b = $(`&lt;div id=&quot;html_e9cca9a7f8a7f4e763ad29669f83087b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f4d08b42d6752c66073344134e1f917c.setContent(html_e9cca9a7f8a7f4e763ad29669f83087b);
#
#
#
#         marker_04f2eb4bc8174f71b3ece18ce1e0d582.bindPopup(popup_f4d08b42d6752c66073344134e1f917c)
#         ;
#
#
#
#
#             var marker_0814e6cd7a6bd317da1f25e963b14cb3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e260aa7ad87e7e44aa768c1b444e6c83);
#
#
#         var popup_35d8d418e2bf4475638ba8a9f3cf0810 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_512af6ce3e9d1265a7d984f66580ca6a = $(`&lt;div id=&quot;html_512af6ce3e9d1265a7d984f66580ca6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_35d8d418e2bf4475638ba8a9f3cf0810.setContent(html_512af6ce3e9d1265a7d984f66580ca6a);
#
#
#
#         marker_0814e6cd7a6bd317da1f25e963b14cb3.bindPopup(popup_35d8d418e2bf4475638ba8a9f3cf0810)
#         ;
#
#
#
#
#             var marker_95ceeae7444781bc8a6021c56a796d14 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e260aa7ad87e7e44aa768c1b444e6c83);
#
#
#         var popup_e0fc0c2164dc633133045b7a45be8abb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e58942e6358464c9eab20ff13e56dd9 = $(`&lt;div id=&quot;html_1e58942e6358464c9eab20ff13e56dd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e0fc0c2164dc633133045b7a45be8abb.setContent(html_1e58942e6358464c9eab20ff13e56dd9);
#
#
#
#         marker_95ceeae7444781bc8a6021c56a796d14.bindPopup(popup_e0fc0c2164dc633133045b7a45be8abb)
#         ;
#
#
#
#
#             var marker_a72c525c35a9f5cb033a5be8fe31bf70 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e260aa7ad87e7e44aa768c1b444e6c83);
#
#
#         var popup_7b872fd9b265304f13d92c13b47ffcdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_910ac9998c3326db44ebb54d19143525 = $(`&lt;div id=&quot;html_910ac9998c3326db44ebb54d19143525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7b872fd9b265304f13d92c13b47ffcdf.setContent(html_910ac9998c3326db44ebb54d19143525);
#
#
#
#         marker_a72c525c35a9f5cb033a5be8fe31bf70.bindPopup(popup_7b872fd9b265304f13d92c13b47ffcdf)
#         ;
#
#
#
#
#             var marker_e6d7e7092787f4a9b7174a5e16b497db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e260aa7ad87e7e44aa768c1b444e6c83);
#
#
#         var popup_eeb0d46cdaad18aec81fabc6922be491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1ac167857ca5094fcbf9dc447bf1217 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1ac167857ca5094fcbf9dc447bf1217&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1ac167857ca5094fcbf9dc447bf1217 = L.map(
#                 &quot;map_f1ac167857ca5094fcbf9dc447bf1217&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_872455d9ac00972d5a22ee8fa67b64e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_872455d9ac00972d5a22ee8fa67b64e9.addTo(map_f1ac167857ca5094fcbf9dc447bf1217);
#
#
#             var feature_group_edc31dd2fa0f7c7837209db65ab805bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_edc31dd2fa0f7c7837209db65ab805bd.addTo(map_f1ac167857ca5094fcbf9dc447bf1217);
#
#
#             var feature_group_sub_group_ff19ec0246bc45d19bd9f856ce25a3b2 = L.featureGroup.subGroup(
#                 feature_group_edc31dd2fa0f7c7837209db65ab805bd
#             );
#
#
#             var marker_5969c13acccdfd8acddeec2ab3860e77 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff19ec0246bc45d19bd9f856ce25a3b2);
#
#
#         var popup_61dba6e5ed79bab46be37af81f290bed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80b45bd6c62a919838e6667d8827b499 = $(`&lt;div id=&quot;html_80b45bd6c62a919838e6667d8827b499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_61dba6e5ed79bab46be37af81f290bed.setContent(html_80b45bd6c62a919838e6667d8827b499);
#
#
#
#         marker_5969c13acccdfd8acddeec2ab3860e77.bindPopup(popup_61dba6e5ed79bab46be37af81f290bed)
#         ;
#
#
#
#
#             var marker_31be397f75da0a79023fdd60e996da2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff19ec0246bc45d19bd9f856ce25a3b2);
#
#
#         var popup_afe3bfabd8a6601e53e024e51720f72a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b815cd0080046ce51dd3a4f29ce83e16 = $(`&lt;div id=&quot;html_b815cd0080046ce51dd3a4f29ce83e16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_afe3bfabd8a6601e53e024e51720f72a.setContent(html_b815cd0080046ce51dd3a4f29ce83e16);
#
#
#
#         marker_31be397f75da0a79023fdd60e996da2a.bindPopup(popup_afe3bfabd8a6601e53e024e51720f72a)
#         ;
#
#
#
#
#             var marker_12aef023adbc0a5b5a74bd27ea633536 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff19ec0246bc45d19bd9f856ce25a3b2);
#
#
#         var popup_0f4cb5ca6df3d3287b8ee0507fab2eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_344a49151ea67f70746089da0c62aec5 = $(`&lt;div id=&quot;html_344a49151ea67f70746089da0c62aec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0f4cb5ca6df3d3287b8ee0507fab2eb9.setContent(html_344a49151ea67f70746089da0c62aec5);
#
#
#
#         marker_12aef023adbc0a5b5a74bd27ea633536.bindPopup(popup_0f4cb5ca6df3d3287b8ee0507fab2eb9)
#         ;
#
#
#
#
#             var marker_4a804aec3fc8a58fb4add8bc7f9a1ee0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff19ec0246bc45d19bd9f856ce25a3b2);
#
#
#         var popup_bfa4e7f1ed3486440a00a085845e229d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fec0291bc31dfa69f8737001cb831fc1 = $(`&lt;div id=&quot;html_fec0291bc31dfa69f8737001cb831fc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bfa4e7f1ed3486440a00a085845e229d.setContent(html_fec0291bc31dfa69f8737001cb831fc1);
#
#
#
#         mark
