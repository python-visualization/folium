# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_283317998aa1c4f2e59b01644614060e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_283317998aa1c4f2e59b01644614060e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_283317998aa1c4f2e59b01644614060e = L.map(
#                 &quot;map_283317998aa1c4f2e59b01644614060e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6de952c5003750bdc69d73585e0ca07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6de952c5003750bdc69d73585e0ca07.addTo(map_283317998aa1c4f2e59b01644614060e);
#
#
#             var marker_47c78cb1e68c4a4a9cc3a74b419e73b1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_283317998aa1c4f2e59b01644614060e);
#
#
#         var popup_d89722f3f95346a3cd49d2eec2028776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fd796b14cbe16d0123a01bba5dbadd3 = $(`&lt;div id=&quot;html_4fd796b14cbe16d0123a01bba5dbadd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d89722f3f95346a3cd49d2eec2028776.setContent(html_4fd796b14cbe16d0123a01bba5dbadd3);
#
#
#
#         marker_47c78cb1e68c4a4a9cc3a74b419e73b1.bindPopup(popup_d89722f3f95346a3cd49d2eec2028776)
#         ;
#
#
#
#
#             var marker_9f239237997c4d8b8730682ad5f410d0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_283317998aa1c4f2e59b01644614060e);
#
#
#         var popup_578d0f8e641fe6443db4ea4932c163cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f2645613c369b5ddc64d0942cf170cc = $(`&lt;div id=&quot;html_9f2645613c369b5ddc64d0942cf170cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_578d0f8e641fe6443db4ea4932c163cd.setContent(html_9f2645613c369b5ddc64d0942cf170cc);
#
#
#
#         marker_9f239237997c4d8b8730682ad5f410d0.bindPopup(popup_578d0f8e641fe6443db4ea4932c163cd)
#         ;
#
#
#
#
#             var marker_67e3aba5212f9e6ee38a6f36ddaf4560 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_283317998aa1c4f2e59b01644614060e);
#
#
#         var popup_52f51d0f7b99707eb3db000cf1534e96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75bb5ffb39af2adbe5a6a6c47ab30ec5 = $(`&lt;div id=&quot;html_75bb5ffb39af2adbe5a6a6c47ab30ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_52f51d0f7b99707eb3db000cf1534e96.setContent(html_75bb5ffb39af2adbe5a6a6c47ab30ec5);
#
#
#
#         marker_67e3aba5212f9e6ee38a6f36ddaf4560.bindPopup(popup_52f51d0f7b99707eb3db000cf1534e96)
#         ;
#
#
#
#
#             var marker_8588921e1635dff20fbe3ccf83cc0adf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_283317998aa1c4f2e59b01644614060e);
#
#
#         var popup_8d4888f92471839cf84e2d31f9c39f01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d11cf24d042ffa3ff40c028ec00d2502 = $(`&lt;div id=&quot;html_d11cf24d042ffa3ff40c028ec00d2502&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8d4888f92471839cf84e2d31f9c39f01.setContent(html_d11cf24d042ffa3ff40c028ec00d2502);
#
#
#
#         marker_8588921e1635dff20fbe3ccf83cc0adf.bindPopup(popup_8d4888f92471839cf84e2d31f9c39f01)
#         ;
#
#
#
#
#             var marker_26ab14d7f2601f9f7080c56c7baffd16 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_283317998aa1c4f2e59b01644614060e);
#
#
#         var popup_4915195e0dc2cf71059a374472e54b78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b512b4a79fc788da75c479fd7303b38 = $(`&lt;div id=&quot;html_6b512b4a79fc788da75c479fd7303b38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4915195e0dc2cf71059a374472e54b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e2d9ee53c5f89e6bd425f3635ac03a2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e2d9ee53c5f89e6bd425f3635ac03a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e2d9ee53c5f89e6bd425f3635ac03a2 = L.map(
#                 &quot;map_2e2d9ee53c5f89e6bd425f3635ac03a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05f72b44d44ced80fd31247f913fa3ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05f72b44d44ced80fd31247f913fa3ec.addTo(map_2e2d9ee53c5f89e6bd425f3635ac03a2);
#
#
#             var feature_group_9f7d080355d7f62236ea2f772624405f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c91f97cc0aa8c75fc86dc5cdf0cba608 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9f7d080355d7f62236ea2f772624405f);
#
#
#         var popup_e88e2a2a146be7620b213b4ccd13cc09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ebcd7cdbd370a123ae6b6b778b5b489 = $(`&lt;div id=&quot;html_5ebcd7cdbd370a123ae6b6b778b5b489&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e88e2a2a146be7620b213b4ccd13cc09.setContent(html_5ebcd7cdbd370a123ae6b6b778b5b489);
#
#
#
#         marker_c91f97cc0aa8c75fc86dc5cdf0cba608.bindPopup(popup_e88e2a2a146be7620b213b4ccd13cc09)
#         ;
#
#
#
#
#             var marker_3d67266bdb0830ea69339c56b186b6d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9f7d080355d7f62236ea2f772624405f);
#
#
#         var popup_b67a373aeae9c2e51609e03226399d2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_087e61d82cbe2ab9108d84e183c30892 = $(`&lt;div id=&quot;html_087e61d82cbe2ab9108d84e183c30892&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b67a373aeae9c2e51609e03226399d2d.setContent(html_087e61d82cbe2ab9108d84e183c30892);
#
#
#
#         marker_3d67266bdb0830ea69339c56b186b6d7.bindPopup(popup_b67a373aeae9c2e51609e03226399d2d)
#         ;
#
#
#
#
#             var marker_894063c886a76070f3e8e39452e2d8ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9f7d080355d7f62236ea2f772624405f);
#
#
#         var popup_a36578f079dc4f61808e44c225437171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_191442b8a96dbabe2ecdf46287398e9d = $(`&lt;div id=&quot;html_191442b8a96dbabe2ecdf46287398e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a36578f079dc4f61808e44c225437171.setContent(html_191442b8a96dbabe2ecdf46287398e9d);
#
#
#
#         marker_894063c886a76070f3e8e39452e2d8ac.bindPopup(popup_a36578f079dc4f61808e44c225437171)
#         ;
#
#
#
#
#             var marker_59a9713184d7132c0b149613880a8cec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9f7d080355d7f62236ea2f772624405f);
#
#
#         var popup_e97913de081df08f51082b2b028aa226 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c149f05b23b8ca40ba239b847425faf5 = $(`&lt;div id=&quot;html_c149f05b23b8ca40ba239b847425faf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e97913de081df08f51082b2b028aa226.setContent(html_c149f05b23b8ca40ba239b847425faf5);
#
#
#
#         marker_59a9713184d7132c0b149613880a8cec.bindPopup(popup_e97913de081df08f51082b2b028aa226)
#         ;
#
#
#
#
#             var marker_159d668b99f9dab00d7ec7549b72b9d6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9f7d080355d7f62236ea2f772624405f);
#
#
#         var popup_184d30758ab488f1f55c532faf393da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53c4223ff505e5affc1f7ac01ca27a00 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53c4223ff505e5affc1f7ac01ca27a00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53c4223ff505e5affc1f7ac01ca27a00 = L.map(
#                 &quot;map_53c4223ff505e5affc1f7ac01ca27a00&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c29da25f5e6d4ae97b4105a756de20c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c29da25f5e6d4ae97b4105a756de20c.addTo(map_53c4223ff505e5affc1f7ac01ca27a00);
#
#
#             var feature_group_db6eeb49878784ec9f9e3026508ea540 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_db6eeb49878784ec9f9e3026508ea540.addTo(map_53c4223ff505e5affc1f7ac01ca27a00);
#
#
#             var feature_group_sub_group_9981c956d6699c18b1c98bdce3a202af = L.featureGroup.subGroup(
#                 feature_group_db6eeb49878784ec9f9e3026508ea540
#             );
#
#
#             var marker_c0a3ad03f54904970126b63bcafa26e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9981c956d6699c18b1c98bdce3a202af);
#
#
#         var popup_b146bb64f18e3468371c31bdba195ceb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f221d997e5e91ca765b0df243a39960 = $(`&lt;div id=&quot;html_8f221d997e5e91ca765b0df243a39960&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b146bb64f18e3468371c31bdba195ceb.setContent(html_8f221d997e5e91ca765b0df243a39960);
#
#
#
#         marker_c0a3ad03f54904970126b63bcafa26e1.bindPopup(popup_b146bb64f18e3468371c31bdba195ceb)
#         ;
#
#
#
#
#             var marker_982f669cf0dbe639c92ed79cdb27caa7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9981c956d6699c18b1c98bdce3a202af);
#
#
#         var popup_f7c89340a2d50d11adaec53a532292c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_597a01b9d46e22b1a236072624d59fb0 = $(`&lt;div id=&quot;html_597a01b9d46e22b1a236072624d59fb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f7c89340a2d50d11adaec53a532292c2.setContent(html_597a01b9d46e22b1a236072624d59fb0);
#
#
#
#         marker_982f669cf0dbe639c92ed79cdb27caa7.bindPopup(popup_f7c89340a2d50d11adaec53a532292c2)
#         ;
#
#
#
#
#             var marker_55109f3f677098a51a601cae3d9cbefb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9981c956d6699c18b1c98bdce3a202af);
#
#
#         var popup_2da2330fc9438353f6f939b15fa630e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a82a92477671b71444a4b8151bda66b5 = $(`&lt;div id=&quot;html_a82a92477671b71444a4b8151bda66b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2da2330fc9438353f6f939b15fa630e8.setContent(html_a82a92477671b71444a4b8151bda66b5);
#
#
#
#         marker_55109f3f677098a51a601cae3d9cbefb.bindPopup(popup_2da2330fc9438353f6f939b15fa630e8)
#         ;
#
#
#
#
#             var marker_fc44b0ba3b2ae4247330d8f819d92bf0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9981c956d6699c18b1c98bdce3a202af);
#
#
#         var popup_6aaf46fc9bcdcca672d73681a30c0c77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_566d8b481481a8ce8407cd9ab582a0db = $(`&lt;div id=&quot;html_566d8b481481a8ce8407cd9ab582a0db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6aaf46fc9bcdcca672d73681a30c0c77.setContent(html_566d8b481481a8ce8407cd9ab582a0db);
#
#
#
#         mark
