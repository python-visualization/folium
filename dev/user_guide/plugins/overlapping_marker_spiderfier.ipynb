# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b12be8f31bb4160cee5455cbf8e12d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b12be8f31bb4160cee5455cbf8e12d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b12be8f31bb4160cee5455cbf8e12d4 = L.map(
#                 &quot;map_2b12be8f31bb4160cee5455cbf8e12d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b58b5ab5371cac50f22c4cc7a91e090e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b58b5ab5371cac50f22c4cc7a91e090e.addTo(map_2b12be8f31bb4160cee5455cbf8e12d4);
#
#
#             var marker_86f58fa09833777ff665b9555ee29ffb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2b12be8f31bb4160cee5455cbf8e12d4);
#
#
#         var popup_c290254c6e6726d9216fd51479541da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d497db08560a4369bdfc152a7ca3d52 = $(`&lt;div id=&quot;html_4d497db08560a4369bdfc152a7ca3d52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c290254c6e6726d9216fd51479541da4.setContent(html_4d497db08560a4369bdfc152a7ca3d52);
#
#
#
#         marker_86f58fa09833777ff665b9555ee29ffb.bindPopup(popup_c290254c6e6726d9216fd51479541da4)
#         ;
#
#
#
#
#             var marker_2579a6cd2922e34d0987aa4986067d2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2b12be8f31bb4160cee5455cbf8e12d4);
#
#
#         var popup_aa414b2a784be61ab2f99fffcd736a65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fc01cf3995c8f67013647846fbcc95b = $(`&lt;div id=&quot;html_6fc01cf3995c8f67013647846fbcc95b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aa414b2a784be61ab2f99fffcd736a65.setContent(html_6fc01cf3995c8f67013647846fbcc95b);
#
#
#
#         marker_2579a6cd2922e34d0987aa4986067d2a.bindPopup(popup_aa414b2a784be61ab2f99fffcd736a65)
#         ;
#
#
#
#
#             var marker_fee83dbfa0c30a3f06a0a1209f21318a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2b12be8f31bb4160cee5455cbf8e12d4);
#
#
#         var popup_6b35699c9ef830dc082d98995ec42823 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4cfdf742b282b36fc77fab2e2aec687 = $(`&lt;div id=&quot;html_c4cfdf742b282b36fc77fab2e2aec687&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6b35699c9ef830dc082d98995ec42823.setContent(html_c4cfdf742b282b36fc77fab2e2aec687);
#
#
#
#         marker_fee83dbfa0c30a3f06a0a1209f21318a.bindPopup(popup_6b35699c9ef830dc082d98995ec42823)
#         ;
#
#
#
#
#             var marker_aad429845328400f8f87fa37e6340e92 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2b12be8f31bb4160cee5455cbf8e12d4);
#
#
#         var popup_98fac8fafd798dbda421fe756acef859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d179c9952a2540def870d86e3cbb448 = $(`&lt;div id=&quot;html_7d179c9952a2540def870d86e3cbb448&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_98fac8fafd798dbda421fe756acef859.setContent(html_7d179c9952a2540def870d86e3cbb448);
#
#
#
#         marker_aad429845328400f8f87fa37e6340e92.bindPopup(popup_98fac8fafd798dbda421fe756acef859)
#         ;
#
#
#
#
#             var marker_5adb4ac3da704013639da1508effc6f8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2b12be8f31bb4160cee5455cbf8e12d4);
#
#
#         var popup_454d36690274bdac4477e3c5bb0b363f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7ab5684c5c4474aaeba42dca2e6083f = $(`&lt;div id=&quot;html_f7ab5684c5c4474aaeba42dca2e6083f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_454d36690274bdac4477e3c5bb0b363f.setContent(html_f7ab5684c5c4474aaeba42dca2e6083f);
#
#
#
#         marker_5adb4ac3da704013639da1508effc6f8.bindPopup(popup_454d36690274bdac4477e3c5bb0b363f)
#         ;
#
#
#
#
#             var marker_538838f8e2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d82f4e9d5d95e6e420958dcc643ca94c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d82f4e9d5d95e6e420958dcc643ca94c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d82f4e9d5d95e6e420958dcc643ca94c = L.map(
#                 &quot;map_d82f4e9d5d95e6e420958dcc643ca94c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a39be26d54d173c4c30e929ecd0faac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a39be26d54d173c4c30e929ecd0faac.addTo(map_d82f4e9d5d95e6e420958dcc643ca94c);
#
#
#             var feature_group_0cae6293aa588a11ac776a3358e88dac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b1f2dc4cf76e512718b4d5174fcf15a8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0cae6293aa588a11ac776a3358e88dac);
#
#
#         var popup_402fad1a32e5e978156cd2f8c0382c45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_080a4ddbee1efe027f508af0ccf743a7 = $(`&lt;div id=&quot;html_080a4ddbee1efe027f508af0ccf743a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_402fad1a32e5e978156cd2f8c0382c45.setContent(html_080a4ddbee1efe027f508af0ccf743a7);
#
#
#
#         marker_b1f2dc4cf76e512718b4d5174fcf15a8.bindPopup(popup_402fad1a32e5e978156cd2f8c0382c45)
#         ;
#
#
#
#
#             var marker_771349fe486b67379f1b04c8f66a6486 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0cae6293aa588a11ac776a3358e88dac);
#
#
#         var popup_575f518cd07901663d15e0b6c50d689e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c4a96b5da0b43467883651f0c485699 = $(`&lt;div id=&quot;html_6c4a96b5da0b43467883651f0c485699&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_575f518cd07901663d15e0b6c50d689e.setContent(html_6c4a96b5da0b43467883651f0c485699);
#
#
#
#         marker_771349fe486b67379f1b04c8f66a6486.bindPopup(popup_575f518cd07901663d15e0b6c50d689e)
#         ;
#
#
#
#
#             var marker_7f5fe093fc5af0f616d3e6350662e9d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0cae6293aa588a11ac776a3358e88dac);
#
#
#         var popup_3f399108ca6afc6fa0a0fd6ca0b1b039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f512f56698a796ea50911f8a59f50b3 = $(`&lt;div id=&quot;html_9f512f56698a796ea50911f8a59f50b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3f399108ca6afc6fa0a0fd6ca0b1b039.setContent(html_9f512f56698a796ea50911f8a59f50b3);
#
#
#
#         marker_7f5fe093fc5af0f616d3e6350662e9d9.bindPopup(popup_3f399108ca6afc6fa0a0fd6ca0b1b039)
#         ;
#
#
#
#
#             var marker_29d7e46db86e298553187afa6e496669 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0cae6293aa588a11ac776a3358e88dac);
#
#
#         var popup_dd5fb30ac63dc8ce584819d5c63e23e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b84bab9af4bbb96b1f7fe706e2726b9e = $(`&lt;div id=&quot;html_b84bab9af4bbb96b1f7fe706e2726b9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dd5fb30ac63dc8ce584819d5c63e23e8.setContent(html_b84bab9af4bbb96b1f7fe706e2726b9e);
#
#
#
#         marker_29d7e46db86e298553187afa6e496669.bindPopup(popup_dd5fb30ac63dc8ce584819d5c63e23e8)
#         ;
#
#
#
#
#             var marker_03bdb8838770c35a5e4e17df9ccdcc7f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0cae6293aa588a11ac776a3358e88dac);
#
#
#         var popup_b359476facde10f10ee9ee9309b8551d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e432fdca25393f4dd94adf1b3f83b2ba = $(`&lt;div id=&quot;html_e432fdca25393f4dd94adf1b3f83b2ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_b359476facde10f10e

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be378eed3e9dcec5daf3d2afa91d006c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be378eed3e9dcec5daf3d2afa91d006c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be378eed3e9dcec5daf3d2afa91d006c = L.map(
#                 &quot;map_be378eed3e9dcec5daf3d2afa91d006c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f8995f23745b14d73c35dbb56bec4bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f8995f23745b14d73c35dbb56bec4bc.addTo(map_be378eed3e9dcec5daf3d2afa91d006c);
#
#
#             var feature_group_b7bb39a4dcc91904f049d82ac54de4fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b7bb39a4dcc91904f049d82ac54de4fb.addTo(map_be378eed3e9dcec5daf3d2afa91d006c);
#
#
#             var feature_group_sub_group_7f8c56866a4f2fce29329f5c149b647e = L.featureGroup.subGroup(
#                 feature_group_b7bb39a4dcc91904f049d82ac54de4fb
#             );
#
#
#             var marker_77f086542f491d4cb2915973d9482912 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8c56866a4f2fce29329f5c149b647e);
#
#
#         var popup_2cb5a3b66e5402e1fee302f5adcbd016 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8e4c72fc628ff506a4d433200a54d5e = $(`&lt;div id=&quot;html_f8e4c72fc628ff506a4d433200a54d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2cb5a3b66e5402e1fee302f5adcbd016.setContent(html_f8e4c72fc628ff506a4d433200a54d5e);
#
#
#
#         marker_77f086542f491d4cb2915973d9482912.bindPopup(popup_2cb5a3b66e5402e1fee302f5adcbd016)
#         ;
#
#
#
#
#             var marker_f8c2d37cae5c69e1739a6f864cb05762 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8c56866a4f2fce29329f5c149b647e);
#
#
#         var popup_7f59a104a3827b3de22d23e477c111c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_545c1647d305576420037ef960d987bb = $(`&lt;div id=&quot;html_545c1647d305576420037ef960d987bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f59a104a3827b3de22d23e477c111c8.setContent(html_545c1647d305576420037ef960d987bb);
#
#
#
#         marker_f8c2d37cae5c69e1739a6f864cb05762.bindPopup(popup_7f59a104a3827b3de22d23e477c111c8)
#         ;
#
#
#
#
#             var marker_ee7a479a325244780ee74135f5389b42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8c56866a4f2fce29329f5c149b647e);
#
#
#         var popup_a62033f137ecf3b4c99eba2dd3aabafb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30c3e12f120a6baaaefc928eee35ed64 = $(`&lt;div id=&quot;html_30c3e12f120a6baaaefc928eee35ed64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a62033f137ecf3b4c99eba2dd3aabafb.setContent(html_30c3e12f120a6baaaefc928eee35ed64);
#
#
#
#         marker_ee7a479a325244780ee74135f5389b42.bindPopup(popup_a62033f137ecf3b4c99eba2dd3aabafb)
#         ;
#
#
#
#
#             var marker_4c682b726af32fae7fa8d1f4ca23745c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8c56866a4f2fce29329f5c149b647e);
#
#
#         var popup_dbadda089688d194caa5e33f98460c06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8e504a993fbba6d6d26a51302b4f823 = $(`&lt;div id=&quot;html_b8e504a993fbba6d6d26a51302b4f823&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dbadda089688d194caa5e33f98460c06.setContent(html_b8e504a993fbba6d6d26a51302b4f823);
#
#
#
#         marker_4c682b726af32fae7fa8d1f4ca23745c.bindPopup(popup_dbadda089688d194caa5e33f98460c06)
#         ;
#
#
#
#
#             var marker_8091877ed7102ae475ff88119e623e80 = L.marker(
#                 [45.050399999999996, 3.0504],
