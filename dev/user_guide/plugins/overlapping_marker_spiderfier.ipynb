# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18b3e2d8be1d88ed7b4fd8b26efa7213 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18b3e2d8be1d88ed7b4fd8b26efa7213&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18b3e2d8be1d88ed7b4fd8b26efa7213 = L.map(
#                 &quot;map_18b3e2d8be1d88ed7b4fd8b26efa7213&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bea1aa0ca7f534dc901b9fa64b4b212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bea1aa0ca7f534dc901b9fa64b4b212.addTo(map_18b3e2d8be1d88ed7b4fd8b26efa7213);
#
#
#             var marker_8df71426d28b0e2d396a9681fcf30879 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_18b3e2d8be1d88ed7b4fd8b26efa7213);
#
#
#         var popup_46b8bfe2bbc4861367b7d09d8f614fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e5e79117bf0fda969da0141504f5494 = $(`&lt;div id=&quot;html_9e5e79117bf0fda969da0141504f5494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_46b8bfe2bbc4861367b7d09d8f614fcf.setContent(html_9e5e79117bf0fda969da0141504f5494);
#
#
#
#         marker_8df71426d28b0e2d396a9681fcf30879.bindPopup(popup_46b8bfe2bbc4861367b7d09d8f614fcf)
#         ;
#
#
#
#
#             var marker_00c1977efcfb9d0bf5a769c098f3e571 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_18b3e2d8be1d88ed7b4fd8b26efa7213);
#
#
#         var popup_f90648ed5953e369d9b622ff708d77f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71091f89042d41581d3efb50fc686cb2 = $(`&lt;div id=&quot;html_71091f89042d41581d3efb50fc686cb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f90648ed5953e369d9b622ff708d77f7.setContent(html_71091f89042d41581d3efb50fc686cb2);
#
#
#
#         marker_00c1977efcfb9d0bf5a769c098f3e571.bindPopup(popup_f90648ed5953e369d9b622ff708d77f7)
#         ;
#
#
#
#
#             var marker_8db31ab0de8a200c70d39f7be6f04d15 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_18b3e2d8be1d88ed7b4fd8b26efa7213);
#
#
#         var popup_20f79011feda16c8100f251316c3c6cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31847a0b9a5fcb7ef50c30c24c678d7c = $(`&lt;div id=&quot;html_31847a0b9a5fcb7ef50c30c24c678d7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_20f79011feda16c8100f251316c3c6cd.setContent(html_31847a0b9a5fcb7ef50c30c24c678d7c);
#
#
#
#         marker_8db31ab0de8a200c70d39f7be6f04d15.bindPopup(popup_20f79011feda16c8100f251316c3c6cd)
#         ;
#
#
#
#
#             var marker_59738a46252e7e429d9821311d57e391 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_18b3e2d8be1d88ed7b4fd8b26efa7213);
#
#
#         var popup_f438fc424d8a160b2e5f5ac7d224270d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_633c1f4dfb74bf7e7d808f104d7e89f5 = $(`&lt;div id=&quot;html_633c1f4dfb74bf7e7d808f104d7e89f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f438fc424d8a160b2e5f5ac7d224270d.setContent(html_633c1f4dfb74bf7e7d808f104d7e89f5);
#
#
#
#         marker_59738a46252e7e429d9821311d57e391.bindPopup(popup_f438fc424d8a160b2e5f5ac7d224270d)
#         ;
#
#
#
#
#             var marker_429c26fe400db10074ff14ae2a8b0fbb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_18b3e2d8be1d88ed7b4fd8b26efa7213);
#
#
#         var popup_40d97713205a0c01d40221440bbd9fbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_621728677e9e28047165b60f7d572ef8 = $(`&lt;div id=&quot;html_621728677e9e28047165b60f7d572ef8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_40d97713205a0c01d40221440bbd9fbd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b837776036ec4177534035039319a4dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b837776036ec4177534035039319a4dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b837776036ec4177534035039319a4dc = L.map(
#                 &quot;map_b837776036ec4177534035039319a4dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e173b53077bf99edb2b39236a06ae3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e173b53077bf99edb2b39236a06ae3d.addTo(map_b837776036ec4177534035039319a4dc);
#
#
#             var feature_group_591e79b7be53229eb90afb05d47429be = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_85755c2addc285a4d37d0c5c4d5bfb33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_591e79b7be53229eb90afb05d47429be);
#
#
#         var popup_31a9639346f464cedcf1b613165d3896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dfa1b106c6edcce6d35ca0562f01ebf = $(`&lt;div id=&quot;html_7dfa1b106c6edcce6d35ca0562f01ebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_31a9639346f464cedcf1b613165d3896.setContent(html_7dfa1b106c6edcce6d35ca0562f01ebf);
#
#
#
#         marker_85755c2addc285a4d37d0c5c4d5bfb33.bindPopup(popup_31a9639346f464cedcf1b613165d3896)
#         ;
#
#
#
#
#             var marker_ecd45910554d8082a5f15b40b29ac7e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_591e79b7be53229eb90afb05d47429be);
#
#
#         var popup_7deed70b6a2f5f182e2f2c932820099f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3a4d3818a234c250880c939d1504ac = $(`&lt;div id=&quot;html_7f3a4d3818a234c250880c939d1504ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7deed70b6a2f5f182e2f2c932820099f.setContent(html_7f3a4d3818a234c250880c939d1504ac);
#
#
#
#         marker_ecd45910554d8082a5f15b40b29ac7e5.bindPopup(popup_7deed70b6a2f5f182e2f2c932820099f)
#         ;
#
#
#
#
#             var marker_01b002e2d80a323d00c4865062782811 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_591e79b7be53229eb90afb05d47429be);
#
#
#         var popup_9429f90515fe6ca45fb788b04f603987 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3436da2fe83fa3f7fedcd0c0b4417cde = $(`&lt;div id=&quot;html_3436da2fe83fa3f7fedcd0c0b4417cde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9429f90515fe6ca45fb788b04f603987.setContent(html_3436da2fe83fa3f7fedcd0c0b4417cde);
#
#
#
#         marker_01b002e2d80a323d00c4865062782811.bindPopup(popup_9429f90515fe6ca45fb788b04f603987)
#         ;
#
#
#
#
#             var marker_75868067ab91e6bffd0f054fdab5e226 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_591e79b7be53229eb90afb05d47429be);
#
#
#         var popup_408c403473e315296ebb1022d67ec24a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a7061955e6e5232c02fb6b35d73e146 = $(`&lt;div id=&quot;html_2a7061955e6e5232c02fb6b35d73e146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_408c403473e315296ebb1022d67ec24a.setContent(html_2a7061955e6e5232c02fb6b35d73e146);
#
#
#
#         marker_75868067ab91e6bffd0f054fdab5e226.bindPopup(popup_408c403473e315296ebb1022d67ec24a)
#         ;
#
#
#
#
#             var marker_ef26703bac38610003c6dbb8d16f1498 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_591e79b7be53229eb90afb05d47429be);
#
#
#         var popup_289932d827c7412709a5ee2817d2d16d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86eb0cf9f1bf1f0fb42746f2bb479564 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86eb0cf9f1bf1f0fb42746f2bb479564&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86eb0cf9f1bf1f0fb42746f2bb479564 = L.map(
#                 &quot;map_86eb0cf9f1bf1f0fb42746f2bb479564&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22faa6fedfcbec553da1a37654d1c1f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22faa6fedfcbec553da1a37654d1c1f6.addTo(map_86eb0cf9f1bf1f0fb42746f2bb479564);
#
#
#             var feature_group_8c1580351bf0542a861c3b5889720345 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8c1580351bf0542a861c3b5889720345.addTo(map_86eb0cf9f1bf1f0fb42746f2bb479564);
#
#
#             var feature_group_sub_group_0e76dbb95b410f3e2137d68bb2159fc0 = L.featureGroup.subGroup(
#                 feature_group_8c1580351bf0542a861c3b5889720345
#             );
#
#
#             var marker_025c6f5004c825fdba89c543c3bdf4eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e76dbb95b410f3e2137d68bb2159fc0);
#
#
#         var popup_0b4ea00aa2915426272717d4ab10ae99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_909c247cf2fe108e3b173ad9791c7ec9 = $(`&lt;div id=&quot;html_909c247cf2fe108e3b173ad9791c7ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0b4ea00aa2915426272717d4ab10ae99.setContent(html_909c247cf2fe108e3b173ad9791c7ec9);
#
#
#
#         marker_025c6f5004c825fdba89c543c3bdf4eb.bindPopup(popup_0b4ea00aa2915426272717d4ab10ae99)
#         ;
#
#
#
#
#             var marker_564e440ca8c94810b6891b9c248d11d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e76dbb95b410f3e2137d68bb2159fc0);
#
#
#         var popup_87b7cdac6b24cf53e768023d58ec2dcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a74042c9aecc83bd1ec5fce13c23acc7 = $(`&lt;div id=&quot;html_a74042c9aecc83bd1ec5fce13c23acc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_87b7cdac6b24cf53e768023d58ec2dcd.setContent(html_a74042c9aecc83bd1ec5fce13c23acc7);
#
#
#
#         marker_564e440ca8c94810b6891b9c248d11d8.bindPopup(popup_87b7cdac6b24cf53e768023d58ec2dcd)
#         ;
#
#
#
#
#             var marker_02ecef53130ff90c34d13c6bc5680492 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e76dbb95b410f3e2137d68bb2159fc0);
#
#
#         var popup_6f29c96778ad3b8a867dd3839f34bf94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44a3ac61a4e22d7f6053d8888ff73f8e = $(`&lt;div id=&quot;html_44a3ac61a4e22d7f6053d8888ff73f8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6f29c96778ad3b8a867dd3839f34bf94.setContent(html_44a3ac61a4e22d7f6053d8888ff73f8e);
#
#
#
#         marker_02ecef53130ff90c34d13c6bc5680492.bindPopup(popup_6f29c96778ad3b8a867dd3839f34bf94)
#         ;
#
#
#
#
#             var marker_94881ef86fc6c0d5c2d8c1e797a1a1bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e76dbb95b410f3e2137d68bb2159fc0);
#
#
#         var popup_594bd5277aa9b1e2fb3515735322547a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_203db9416adbce496c9f2ab829e8a185 = $(`&lt;div id=&quot;html_203db9416adbce496c9f2ab829e8a185&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_594bd5277aa9b1e2fb3515735322547a.setContent(html_203db9416adbce496c9f2ab829e8a185);
#
#
#
#         marker_
