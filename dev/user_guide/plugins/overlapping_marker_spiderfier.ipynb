# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a470f73ed14219b81d0d906e3436fd68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a470f73ed14219b81d0d906e3436fd68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a470f73ed14219b81d0d906e3436fd68 = L.map(
#                 &quot;map_a470f73ed14219b81d0d906e3436fd68&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78ee5af4862114ec4ba91b4ba8f7462a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78ee5af4862114ec4ba91b4ba8f7462a.addTo(map_a470f73ed14219b81d0d906e3436fd68);
#
#
#             var marker_ecfca57d85f6bc3ca529753e83a9f95d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a470f73ed14219b81d0d906e3436fd68);
#
#
#         var popup_059ef6e3e56921c91b57552cdaa51cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6758959416c9799080715ad0853acd2 = $(`&lt;div id=&quot;html_d6758959416c9799080715ad0853acd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_059ef6e3e56921c91b57552cdaa51cb7.setContent(html_d6758959416c9799080715ad0853acd2);
#
#
#
#         marker_ecfca57d85f6bc3ca529753e83a9f95d.bindPopup(popup_059ef6e3e56921c91b57552cdaa51cb7)
#         ;
#
#
#
#
#             var marker_a4e50b4d1e92a58a68a3c90adf048cae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a470f73ed14219b81d0d906e3436fd68);
#
#
#         var popup_abaee08d6821d94f267d856e058cc113 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdb6a991f76d8f8147a4b3ec63e32088 = $(`&lt;div id=&quot;html_cdb6a991f76d8f8147a4b3ec63e32088&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_abaee08d6821d94f267d856e058cc113.setContent(html_cdb6a991f76d8f8147a4b3ec63e32088);
#
#
#
#         marker_a4e50b4d1e92a58a68a3c90adf048cae.bindPopup(popup_abaee08d6821d94f267d856e058cc113)
#         ;
#
#
#
#
#             var marker_53b985ed546e818646337dcfa39f1dde = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a470f73ed14219b81d0d906e3436fd68);
#
#
#         var popup_39272d1389840d3644ae650da2e3deee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32d954ce7f04b60d828e6878ad9a2a7 = $(`&lt;div id=&quot;html_a32d954ce7f04b60d828e6878ad9a2a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_39272d1389840d3644ae650da2e3deee.setContent(html_a32d954ce7f04b60d828e6878ad9a2a7);
#
#
#
#         marker_53b985ed546e818646337dcfa39f1dde.bindPopup(popup_39272d1389840d3644ae650da2e3deee)
#         ;
#
#
#
#
#             var marker_7c9008bea2470d9b98529bef7b7de959 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a470f73ed14219b81d0d906e3436fd68);
#
#
#         var popup_5ddba65dbd363352d95f69ff71709366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8de350bcbf986ad604f77af3ff5d56a = $(`&lt;div id=&quot;html_c8de350bcbf986ad604f77af3ff5d56a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5ddba65dbd363352d95f69ff71709366.setContent(html_c8de350bcbf986ad604f77af3ff5d56a);
#
#
#
#         marker_7c9008bea2470d9b98529bef7b7de959.bindPopup(popup_5ddba65dbd363352d95f69ff71709366)
#         ;
#
#
#
#
#             var marker_6489b8b176e9b6385f23a727054d2b5a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a470f73ed14219b81d0d906e3436fd68);
#
#
#         var popup_66ba11bf64588d3bd622d2d56aa56bb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85dc821639b9cb90279dacbe5718c674 = $(`&lt;div id=&quot;html_85dc821639b9cb90279dacbe5718c674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_66ba11bf64588d3bd622d2d56aa56bb0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27dbf8697760543f2bdf521600d41274 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27dbf8697760543f2bdf521600d41274&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27dbf8697760543f2bdf521600d41274 = L.map(
#                 &quot;map_27dbf8697760543f2bdf521600d41274&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3196a8615571edb5efbbe2bdf681b314 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3196a8615571edb5efbbe2bdf681b314.addTo(map_27dbf8697760543f2bdf521600d41274);
#
#
#             var feature_group_22684ebcb53690f615fc45adc0acf27d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_35075cdf983dbdde4758ef12bd9d21e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_22684ebcb53690f615fc45adc0acf27d);
#
#
#         var popup_0c8c5cbd843d5124f0c9de0029adcde9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fa9380574e51825bfc5734ffb3624f6 = $(`&lt;div id=&quot;html_3fa9380574e51825bfc5734ffb3624f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0c8c5cbd843d5124f0c9de0029adcde9.setContent(html_3fa9380574e51825bfc5734ffb3624f6);
#
#
#
#         marker_35075cdf983dbdde4758ef12bd9d21e8.bindPopup(popup_0c8c5cbd843d5124f0c9de0029adcde9)
#         ;
#
#
#
#
#             var marker_e698d7cc0c0f6fbf9641ecb076f0806d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_22684ebcb53690f615fc45adc0acf27d);
#
#
#         var popup_d1216b638103ef13d2bec01eceefd5b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3ae7c9556e00c150258cbcd209d707c = $(`&lt;div id=&quot;html_b3ae7c9556e00c150258cbcd209d707c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d1216b638103ef13d2bec01eceefd5b7.setContent(html_b3ae7c9556e00c150258cbcd209d707c);
#
#
#
#         marker_e698d7cc0c0f6fbf9641ecb076f0806d.bindPopup(popup_d1216b638103ef13d2bec01eceefd5b7)
#         ;
#
#
#
#
#             var marker_0f5dcc45dcf3782c986e993bf873ad28 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_22684ebcb53690f615fc45adc0acf27d);
#
#
#         var popup_41e52c19ab85a9e3772663612877d655 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48fd70c1b11e1882e92252d2c81e37b3 = $(`&lt;div id=&quot;html_48fd70c1b11e1882e92252d2c81e37b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_41e52c19ab85a9e3772663612877d655.setContent(html_48fd70c1b11e1882e92252d2c81e37b3);
#
#
#
#         marker_0f5dcc45dcf3782c986e993bf873ad28.bindPopup(popup_41e52c19ab85a9e3772663612877d655)
#         ;
#
#
#
#
#             var marker_2d0590da60197d45030a8d1b53418361 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_22684ebcb53690f615fc45adc0acf27d);
#
#
#         var popup_f2032cd9a9b8e099472fe3f1ec66ec75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_877b1ba43b53b03e6d26a0d5505aeae1 = $(`&lt;div id=&quot;html_877b1ba43b53b03e6d26a0d5505aeae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f2032cd9a9b8e099472fe3f1ec66ec75.setContent(html_877b1ba43b53b03e6d26a0d5505aeae1);
#
#
#
#         marker_2d0590da60197d45030a8d1b53418361.bindPopup(popup_f2032cd9a9b8e099472fe3f1ec66ec75)
#         ;
#
#
#
#
#             var marker_6a17cd67abb0381d23b5cf84469435a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_22684ebcb53690f615fc45adc0acf27d);
#
#
#         var popup_781ab27a148915c32caeaefe6d605d0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07712f44186afdda821ded4d10256fae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07712f44186afdda821ded4d10256fae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07712f44186afdda821ded4d10256fae = L.map(
#                 &quot;map_07712f44186afdda821ded4d10256fae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dee0a39bcfe7f6f239c72f24ee341a11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dee0a39bcfe7f6f239c72f24ee341a11.addTo(map_07712f44186afdda821ded4d10256fae);
#
#
#             var feature_group_d35223d2e50ed0a6bb597c8f06e4aeaf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d35223d2e50ed0a6bb597c8f06e4aeaf.addTo(map_07712f44186afdda821ded4d10256fae);
#
#
#             var feature_group_sub_group_cc96910be04240780d7733c355dda64b = L.featureGroup.subGroup(
#                 feature_group_d35223d2e50ed0a6bb597c8f06e4aeaf
#             );
#
#
#             var marker_ef618005eb9705ebb7863bb157b3469f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc96910be04240780d7733c355dda64b);
#
#
#         var popup_4992f64f4ce2fb6684873db08c4bb8d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f7fc303f8a765513322def9d5c23cd8 = $(`&lt;div id=&quot;html_9f7fc303f8a765513322def9d5c23cd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4992f64f4ce2fb6684873db08c4bb8d8.setContent(html_9f7fc303f8a765513322def9d5c23cd8);
#
#
#
#         marker_ef618005eb9705ebb7863bb157b3469f.bindPopup(popup_4992f64f4ce2fb6684873db08c4bb8d8)
#         ;
#
#
#
#
#             var marker_956279a165372c50eedcc18817627408 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc96910be04240780d7733c355dda64b);
#
#
#         var popup_0f82d506bbee791beef8461eaf1f84e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7d71b4394f448cc71000af82af26e63 = $(`&lt;div id=&quot;html_b7d71b4394f448cc71000af82af26e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0f82d506bbee791beef8461eaf1f84e5.setContent(html_b7d71b4394f448cc71000af82af26e63);
#
#
#
#         marker_956279a165372c50eedcc18817627408.bindPopup(popup_0f82d506bbee791beef8461eaf1f84e5)
#         ;
#
#
#
#
#             var marker_d6d24236a3e200ec26647c15fa40183f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc96910be04240780d7733c355dda64b);
#
#
#         var popup_904e995a5306b846ad77c2c6ca0d625f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c44b510ae96b1d5dccf395641d8b749a = $(`&lt;div id=&quot;html_c44b510ae96b1d5dccf395641d8b749a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_904e995a5306b846ad77c2c6ca0d625f.setContent(html_c44b510ae96b1d5dccf395641d8b749a);
#
#
#
#         marker_d6d24236a3e200ec26647c15fa40183f.bindPopup(popup_904e995a5306b846ad77c2c6ca0d625f)
#         ;
#
#
#
#
#             var marker_f86fe4ba1aa6041ac2b093c3f91c456f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc96910be04240780d7733c355dda64b);
#
#
#         var popup_4deceee3dbc44c459e99643c18c65fa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6365e79ec7a153cab86069cf929b5da2 = $(`&lt;div id=&quot;html_6365e79ec7a153cab86069cf929b5da2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4deceee3dbc44c459e99643c18c65fa5.setContent(html_6365e79ec7a153cab86069cf929b5da2);
#
#
#
#         marker_
