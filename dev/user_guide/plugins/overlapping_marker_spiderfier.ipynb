# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1626ba5e41e7690474e2750e339ff5cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1626ba5e41e7690474e2750e339ff5cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1626ba5e41e7690474e2750e339ff5cb = L.map(
#                 &quot;map_1626ba5e41e7690474e2750e339ff5cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b55b14ff6e023dbb679a7a7e778c3c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b55b14ff6e023dbb679a7a7e778c3c7.addTo(map_1626ba5e41e7690474e2750e339ff5cb);
#
#
#             var marker_a1b08cb34b899de0094e846ff6a8f451 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1626ba5e41e7690474e2750e339ff5cb);
#
#
#         var popup_a1033f1292d9e50a422797d8105a9dae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d17f398bd4665c3ea64500fb5d4702a0 = $(`&lt;div id=&quot;html_d17f398bd4665c3ea64500fb5d4702a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a1033f1292d9e50a422797d8105a9dae.setContent(html_d17f398bd4665c3ea64500fb5d4702a0);
#
#
#
#         marker_a1b08cb34b899de0094e846ff6a8f451.bindPopup(popup_a1033f1292d9e50a422797d8105a9dae)
#         ;
#
#
#
#
#             var marker_7dcfb330ae177f6a5e22a8241c94c7ad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1626ba5e41e7690474e2750e339ff5cb);
#
#
#         var popup_b32adc5195b59fe58cb2f86e345a985b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_890cd659435338fa2fc984c82b1df200 = $(`&lt;div id=&quot;html_890cd659435338fa2fc984c82b1df200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b32adc5195b59fe58cb2f86e345a985b.setContent(html_890cd659435338fa2fc984c82b1df200);
#
#
#
#         marker_7dcfb330ae177f6a5e22a8241c94c7ad.bindPopup(popup_b32adc5195b59fe58cb2f86e345a985b)
#         ;
#
#
#
#
#             var marker_7042c5632e1850bb5441e52f78741620 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1626ba5e41e7690474e2750e339ff5cb);
#
#
#         var popup_1fd98ff7c8c5db8640f76fa19c849652 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64b35ba2dba41fd18eeafe306660c0cf = $(`&lt;div id=&quot;html_64b35ba2dba41fd18eeafe306660c0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1fd98ff7c8c5db8640f76fa19c849652.setContent(html_64b35ba2dba41fd18eeafe306660c0cf);
#
#
#
#         marker_7042c5632e1850bb5441e52f78741620.bindPopup(popup_1fd98ff7c8c5db8640f76fa19c849652)
#         ;
#
#
#
#
#             var marker_1140b2cffcd3c34a23b834948ce03f0f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1626ba5e41e7690474e2750e339ff5cb);
#
#
#         var popup_93a000d43513046bf8274ec65c78cfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_203e7bfe5ccc8a0883112a3fdb9e5722 = $(`&lt;div id=&quot;html_203e7bfe5ccc8a0883112a3fdb9e5722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_93a000d43513046bf8274ec65c78cfc5.setContent(html_203e7bfe5ccc8a0883112a3fdb9e5722);
#
#
#
#         marker_1140b2cffcd3c34a23b834948ce03f0f.bindPopup(popup_93a000d43513046bf8274ec65c78cfc5)
#         ;
#
#
#
#
#             var marker_ece9d88b43136fff8c2f2be3683315bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1626ba5e41e7690474e2750e339ff5cb);
#
#
#         var popup_981d1312a04be191b6d1f2a05399f6d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d36939c8eb50785448974a2f21608ac7 = $(`&lt;div id=&quot;html_d36939c8eb50785448974a2f21608ac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_981d1312a04be191b6d1f2a05399f6d3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47c9995065099a1574efd91832194cc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47c9995065099a1574efd91832194cc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47c9995065099a1574efd91832194cc5 = L.map(
#                 &quot;map_47c9995065099a1574efd91832194cc5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0fd3e690284a77632f7269dc152c031 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0fd3e690284a77632f7269dc152c031.addTo(map_47c9995065099a1574efd91832194cc5);
#
#
#             var feature_group_7bf08a8b4cc3b8ee02bf0bc55e32568c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_790b5afca0e5415b7c038f37546d591e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7bf08a8b4cc3b8ee02bf0bc55e32568c);
#
#
#         var popup_997b7620a8b25b078886a9bcef4c5529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b22b0869343313eb1d976e0a661f3db = $(`&lt;div id=&quot;html_1b22b0869343313eb1d976e0a661f3db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_997b7620a8b25b078886a9bcef4c5529.setContent(html_1b22b0869343313eb1d976e0a661f3db);
#
#
#
#         marker_790b5afca0e5415b7c038f37546d591e.bindPopup(popup_997b7620a8b25b078886a9bcef4c5529)
#         ;
#
#
#
#
#             var marker_a49b320ea4f191d31604c9cfd049a65b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7bf08a8b4cc3b8ee02bf0bc55e32568c);
#
#
#         var popup_09d007a256421354f4c8007db69576a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63eb3a9414ce2f31a2bd08906ba0bc3a = $(`&lt;div id=&quot;html_63eb3a9414ce2f31a2bd08906ba0bc3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_09d007a256421354f4c8007db69576a5.setContent(html_63eb3a9414ce2f31a2bd08906ba0bc3a);
#
#
#
#         marker_a49b320ea4f191d31604c9cfd049a65b.bindPopup(popup_09d007a256421354f4c8007db69576a5)
#         ;
#
#
#
#
#             var marker_4b5ba4272d85f7132600b5afe67c8e08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7bf08a8b4cc3b8ee02bf0bc55e32568c);
#
#
#         var popup_ed9ab82a406730a45228bec817ad90f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec830fa945bb17172eab1a4090879d66 = $(`&lt;div id=&quot;html_ec830fa945bb17172eab1a4090879d66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ed9ab82a406730a45228bec817ad90f7.setContent(html_ec830fa945bb17172eab1a4090879d66);
#
#
#
#         marker_4b5ba4272d85f7132600b5afe67c8e08.bindPopup(popup_ed9ab82a406730a45228bec817ad90f7)
#         ;
#
#
#
#
#             var marker_6990887802168aab510412c84dd296d3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7bf08a8b4cc3b8ee02bf0bc55e32568c);
#
#
#         var popup_068fed1e3511e1802a6a741ce4004324 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b36d735b82090a437169f4bebf08cd24 = $(`&lt;div id=&quot;html_b36d735b82090a437169f4bebf08cd24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_068fed1e3511e1802a6a741ce4004324.setContent(html_b36d735b82090a437169f4bebf08cd24);
#
#
#
#         marker_6990887802168aab510412c84dd296d3.bindPopup(popup_068fed1e3511e1802a6a741ce4004324)
#         ;
#
#
#
#
#             var marker_0ce32f30beacfef9da7326af47e22f44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7bf08a8b4cc3b8ee02bf0bc55e32568c);
#
#
#         var popup_72e623f064cdabe755040d8a6159735b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_112e791e8245244312d044f5b228a244 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_112e791e8245244312d044f5b228a244&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_112e791e8245244312d044f5b228a244 = L.map(
#                 &quot;map_112e791e8245244312d044f5b228a244&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_301e0f8a5520a8f8e31c013a5b4ac70a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_301e0f8a5520a8f8e31c013a5b4ac70a.addTo(map_112e791e8245244312d044f5b228a244);
#
#
#             var feature_group_1100c8f3501dbf6739f6db1b4b309112 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1100c8f3501dbf6739f6db1b4b309112.addTo(map_112e791e8245244312d044f5b228a244);
#
#
#             var feature_group_sub_group_aa607bf68f3408c7fa0e6d2f4d3689f8 = L.featureGroup.subGroup(
#                 feature_group_1100c8f3501dbf6739f6db1b4b309112
#             );
#
#
#             var marker_4f5c42b484825d88dbbe9dd1657a474a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa607bf68f3408c7fa0e6d2f4d3689f8);
#
#
#         var popup_5147f53be9914d7fffb4105fbda476c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_630d7b0617a0e16a0f7ebb2bcbf1da2f = $(`&lt;div id=&quot;html_630d7b0617a0e16a0f7ebb2bcbf1da2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5147f53be9914d7fffb4105fbda476c6.setContent(html_630d7b0617a0e16a0f7ebb2bcbf1da2f);
#
#
#
#         marker_4f5c42b484825d88dbbe9dd1657a474a.bindPopup(popup_5147f53be9914d7fffb4105fbda476c6)
#         ;
#
#
#
#
#             var marker_641d24227878fcb9dedf5812e7670014 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa607bf68f3408c7fa0e6d2f4d3689f8);
#
#
#         var popup_f9f722dfd8b9c14e8f3b263d12b43792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53bbf3143c248f76686ad030821873b6 = $(`&lt;div id=&quot;html_53bbf3143c248f76686ad030821873b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f9f722dfd8b9c14e8f3b263d12b43792.setContent(html_53bbf3143c248f76686ad030821873b6);
#
#
#
#         marker_641d24227878fcb9dedf5812e7670014.bindPopup(popup_f9f722dfd8b9c14e8f3b263d12b43792)
#         ;
#
#
#
#
#             var marker_7e3a2a24f82597a6edcb75306375dc5b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa607bf68f3408c7fa0e6d2f4d3689f8);
#
#
#         var popup_09315d295b54e1f836f238e37c445bb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b3e0af51b343ceaf40f3388143c9b1c = $(`&lt;div id=&quot;html_9b3e0af51b343ceaf40f3388143c9b1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09315d295b54e1f836f238e37c445bb2.setContent(html_9b3e0af51b343ceaf40f3388143c9b1c);
#
#
#
#         marker_7e3a2a24f82597a6edcb75306375dc5b.bindPopup(popup_09315d295b54e1f836f238e37c445bb2)
#         ;
#
#
#
#
#             var marker_e0f1abb4693114e128c3a6cd824e2834 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa607bf68f3408c7fa0e6d2f4d3689f8);
#
#
#         var popup_2b6198e22e0f09b8f75732930164429d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d252915f4ae1a4271c9e6ad48d606d00 = $(`&lt;div id=&quot;html_d252915f4ae1a4271c9e6ad48d606d00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2b6198e22e0f09b8f75732930164429d.setContent(html_d252915f4ae1a4271c9e6ad48d606d00);
#
#
#
#         marker_
