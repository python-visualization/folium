# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6de504b8ebd9f8f708d65c4ecf149d66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6de504b8ebd9f8f708d65c4ecf149d66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6de504b8ebd9f8f708d65c4ecf149d66 = L.map(
#                 &quot;map_6de504b8ebd9f8f708d65c4ecf149d66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1a185f1cb5b4e59ea69bce966e590a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1a185f1cb5b4e59ea69bce966e590a9.addTo(map_6de504b8ebd9f8f708d65c4ecf149d66);
#
#
#             var marker_7b406884f62fbaf8bdde4ae94f75ca8d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6de504b8ebd9f8f708d65c4ecf149d66);
#
#
#         var popup_c0dfe0d6274367f04bd5498a5296a9a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2158d81b64c13b934d1753fe960534f2 = $(`&lt;div id=&quot;html_2158d81b64c13b934d1753fe960534f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c0dfe0d6274367f04bd5498a5296a9a0.setContent(html_2158d81b64c13b934d1753fe960534f2);
#
#
#
#         marker_7b406884f62fbaf8bdde4ae94f75ca8d.bindPopup(popup_c0dfe0d6274367f04bd5498a5296a9a0)
#         ;
#
#
#
#
#             var marker_900c34a4d4d78883fdcc2b93043bbf26 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6de504b8ebd9f8f708d65c4ecf149d66);
#
#
#         var popup_393ab5b12a029456a6034df79874b3ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08f663d78b25a269154100b83d636c8e = $(`&lt;div id=&quot;html_08f663d78b25a269154100b83d636c8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_393ab5b12a029456a6034df79874b3ee.setContent(html_08f663d78b25a269154100b83d636c8e);
#
#
#
#         marker_900c34a4d4d78883fdcc2b93043bbf26.bindPopup(popup_393ab5b12a029456a6034df79874b3ee)
#         ;
#
#
#
#
#             var marker_20c471bf472d39f4e55ffc38df7fe6fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6de504b8ebd9f8f708d65c4ecf149d66);
#
#
#         var popup_6c55f7ba2dd1cbdd81a29609fa3cf6d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c399ca64600795eb442160cb6f2a1ece = $(`&lt;div id=&quot;html_c399ca64600795eb442160cb6f2a1ece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6c55f7ba2dd1cbdd81a29609fa3cf6d7.setContent(html_c399ca64600795eb442160cb6f2a1ece);
#
#
#
#         marker_20c471bf472d39f4e55ffc38df7fe6fc.bindPopup(popup_6c55f7ba2dd1cbdd81a29609fa3cf6d7)
#         ;
#
#
#
#
#             var marker_754ea66e9f0baef9d870a50c0eb3d07b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6de504b8ebd9f8f708d65c4ecf149d66);
#
#
#         var popup_7d44dd0ad282f3cd6d5f22ced75d338a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0847ba0e0749684be031b51f1e08455 = $(`&lt;div id=&quot;html_a0847ba0e0749684be031b51f1e08455&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7d44dd0ad282f3cd6d5f22ced75d338a.setContent(html_a0847ba0e0749684be031b51f1e08455);
#
#
#
#         marker_754ea66e9f0baef9d870a50c0eb3d07b.bindPopup(popup_7d44dd0ad282f3cd6d5f22ced75d338a)
#         ;
#
#
#
#
#             var marker_c9e915a61d84a4f7172aef800a581936 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6de504b8ebd9f8f708d65c4ecf149d66);
#
#
#         var popup_0fe5dc5b18c78418990711fe64aaa88a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b79b96efc64f3c9762145d639b0be27 = $(`&lt;div id=&quot;html_0b79b96efc64f3c9762145d639b0be27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0fe5dc5b18c78418990711fe64aaa88a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7dc30240213b833b94b4d84ad9db487 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7dc30240213b833b94b4d84ad9db487&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7dc30240213b833b94b4d84ad9db487 = L.map(
#                 &quot;map_a7dc30240213b833b94b4d84ad9db487&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c3fcdad63fc690f56d7a8d88558cdd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c3fcdad63fc690f56d7a8d88558cdd7.addTo(map_a7dc30240213b833b94b4d84ad9db487);
#
#
#             var feature_group_decb548cfcc8571618c411e4896347f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_07de2de098cd42f1211e735781c64e07 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_decb548cfcc8571618c411e4896347f0);
#
#
#         var popup_73e0b063fcb931641c153419eaead08b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37b4ea8bd5aa977a5ff31fe28e597920 = $(`&lt;div id=&quot;html_37b4ea8bd5aa977a5ff31fe28e597920&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_73e0b063fcb931641c153419eaead08b.setContent(html_37b4ea8bd5aa977a5ff31fe28e597920);
#
#
#
#         marker_07de2de098cd42f1211e735781c64e07.bindPopup(popup_73e0b063fcb931641c153419eaead08b)
#         ;
#
#
#
#
#             var marker_47546ec91386ba3bc70197c9af1c78a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_decb548cfcc8571618c411e4896347f0);
#
#
#         var popup_0e8eb8436b40be328ab1df41b8f3b518 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1729ab669d4f3d2d51d9167cdd92ac41 = $(`&lt;div id=&quot;html_1729ab669d4f3d2d51d9167cdd92ac41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0e8eb8436b40be328ab1df41b8f3b518.setContent(html_1729ab669d4f3d2d51d9167cdd92ac41);
#
#
#
#         marker_47546ec91386ba3bc70197c9af1c78a6.bindPopup(popup_0e8eb8436b40be328ab1df41b8f3b518)
#         ;
#
#
#
#
#             var marker_9d092c34ade6fedd8a57582c6c5aad62 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_decb548cfcc8571618c411e4896347f0);
#
#
#         var popup_4102f1e9a04128197116c7643dd62fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_884a28dc2c469fc22dd7d009a6811424 = $(`&lt;div id=&quot;html_884a28dc2c469fc22dd7d009a6811424&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4102f1e9a04128197116c7643dd62fcf.setContent(html_884a28dc2c469fc22dd7d009a6811424);
#
#
#
#         marker_9d092c34ade6fedd8a57582c6c5aad62.bindPopup(popup_4102f1e9a04128197116c7643dd62fcf)
#         ;
#
#
#
#
#             var marker_b761fb9aa1cfeb32bda5b9489bcc932f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_decb548cfcc8571618c411e4896347f0);
#
#
#         var popup_fae5f433c6a7917d380d570cffa23dec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_132686df6e673525207395fc1c8b543e = $(`&lt;div id=&quot;html_132686df6e673525207395fc1c8b543e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fae5f433c6a7917d380d570cffa23dec.setContent(html_132686df6e673525207395fc1c8b543e);
#
#
#
#         marker_b761fb9aa1cfeb32bda5b9489bcc932f.bindPopup(popup_fae5f433c6a7917d380d570cffa23dec)
#         ;
#
#
#
#
#             var marker_c70fdd6f0cc8738fb845edc22f31d0e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_decb548cfcc8571618c411e4896347f0);
#
#
#         var popup_a593b89a363700dfc61235489b2df4e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_344b8f500be1c1970d7781ccb9d5ffc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_344b8f500be1c1970d7781ccb9d5ffc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_344b8f500be1c1970d7781ccb9d5ffc8 = L.map(
#                 &quot;map_344b8f500be1c1970d7781ccb9d5ffc8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dc7f5f80151a0af304821826f0d6cab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2dc7f5f80151a0af304821826f0d6cab.addTo(map_344b8f500be1c1970d7781ccb9d5ffc8);
#
#
#             var feature_group_eefeb88cefc3415a9f2999bf112c6c1f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eefeb88cefc3415a9f2999bf112c6c1f.addTo(map_344b8f500be1c1970d7781ccb9d5ffc8);
#
#
#             var feature_group_sub_group_298e6cb59f812af21ab6270a269b3695 = L.featureGroup.subGroup(
#                 feature_group_eefeb88cefc3415a9f2999bf112c6c1f
#             );
#
#
#             var marker_c3a9974a4b067f08b5d2ac1145fc44be = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_298e6cb59f812af21ab6270a269b3695);
#
#
#         var popup_6dd8e3063fd436fcfc5eb3555774d50f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63c68d28eb45277fcc23fefe990f6a61 = $(`&lt;div id=&quot;html_63c68d28eb45277fcc23fefe990f6a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6dd8e3063fd436fcfc5eb3555774d50f.setContent(html_63c68d28eb45277fcc23fefe990f6a61);
#
#
#
#         marker_c3a9974a4b067f08b5d2ac1145fc44be.bindPopup(popup_6dd8e3063fd436fcfc5eb3555774d50f)
#         ;
#
#
#
#
#             var marker_8b518b7778ff4a992ef7a828112fee13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_298e6cb59f812af21ab6270a269b3695);
#
#
#         var popup_8a57fd0019ad7b7186c2d3e99b9a9f84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8846b815fbb7796ab87554975547c1e = $(`&lt;div id=&quot;html_a8846b815fbb7796ab87554975547c1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8a57fd0019ad7b7186c2d3e99b9a9f84.setContent(html_a8846b815fbb7796ab87554975547c1e);
#
#
#
#         marker_8b518b7778ff4a992ef7a828112fee13.bindPopup(popup_8a57fd0019ad7b7186c2d3e99b9a9f84)
#         ;
#
#
#
#
#             var marker_18fc205c7584d7ff895d9abcdeb70d5c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_298e6cb59f812af21ab6270a269b3695);
#
#
#         var popup_777285b580e9142b5a71cd38b593f801 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06552791cbaadb5996c8898ce53edf80 = $(`&lt;div id=&quot;html_06552791cbaadb5996c8898ce53edf80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_777285b580e9142b5a71cd38b593f801.setContent(html_06552791cbaadb5996c8898ce53edf80);
#
#
#
#         marker_18fc205c7584d7ff895d9abcdeb70d5c.bindPopup(popup_777285b580e9142b5a71cd38b593f801)
#         ;
#
#
#
#
#             var marker_e42b6b54d5bc3b218e9610531819e7f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_298e6cb59f812af21ab6270a269b3695);
#
#
#         var popup_86f2204b2e58dcbc2623702cf4f137e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_086f20d83b0088d7c77f896a3a1dd0bf = $(`&lt;div id=&quot;html_086f20d83b0088d7c77f896a3a1dd0bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_86f2204b2e58dcbc2623702cf4f137e7.setContent(html_086f20d83b0088d7c77f896a3a1dd0bf);
#
#
#
#         marker_
