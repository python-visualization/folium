# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4889b8be41df3f116a00be35c22e8cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4889b8be41df3f116a00be35c22e8cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4889b8be41df3f116a00be35c22e8cb = L.map(
#                 &quot;map_c4889b8be41df3f116a00be35c22e8cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3736ddc475de12a77961e8313895f3db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3736ddc475de12a77961e8313895f3db.addTo(map_c4889b8be41df3f116a00be35c22e8cb);
#
#
#             var marker_6a1604dcbe6814d0a901db559f264201 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c4889b8be41df3f116a00be35c22e8cb);
#
#
#         var popup_ae708d22997a71cff7af8ef190acb27c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e818eafabd6b625f9413762ebe60f03f = $(`&lt;div id=&quot;html_e818eafabd6b625f9413762ebe60f03f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ae708d22997a71cff7af8ef190acb27c.setContent(html_e818eafabd6b625f9413762ebe60f03f);
#
#
#
#         marker_6a1604dcbe6814d0a901db559f264201.bindPopup(popup_ae708d22997a71cff7af8ef190acb27c)
#         ;
#
#
#
#
#             var marker_fec71eb19182e1a722dcfdc2340e79c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c4889b8be41df3f116a00be35c22e8cb);
#
#
#         var popup_84d3f5442f4e352a887ddcbf81ca5e1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a10d2e510dd510be1524b207e02e004 = $(`&lt;div id=&quot;html_5a10d2e510dd510be1524b207e02e004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_84d3f5442f4e352a887ddcbf81ca5e1c.setContent(html_5a10d2e510dd510be1524b207e02e004);
#
#
#
#         marker_fec71eb19182e1a722dcfdc2340e79c8.bindPopup(popup_84d3f5442f4e352a887ddcbf81ca5e1c)
#         ;
#
#
#
#
#             var marker_79b7c170eb2cc36efb5b0b11dde6d1b5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c4889b8be41df3f116a00be35c22e8cb);
#
#
#         var popup_c45ac9ede92f2ce94397dbfdef4499ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71f047d3cd638c9b7185e6f60c3c2c43 = $(`&lt;div id=&quot;html_71f047d3cd638c9b7185e6f60c3c2c43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c45ac9ede92f2ce94397dbfdef4499ed.setContent(html_71f047d3cd638c9b7185e6f60c3c2c43);
#
#
#
#         marker_79b7c170eb2cc36efb5b0b11dde6d1b5.bindPopup(popup_c45ac9ede92f2ce94397dbfdef4499ed)
#         ;
#
#
#
#
#             var marker_26dfe182b5fd066eb5b26286db755e14 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c4889b8be41df3f116a00be35c22e8cb);
#
#
#         var popup_d9b785d218201fc619990c1c8f5bd59c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ae4078dfc3dbd460873419134ebb91e = $(`&lt;div id=&quot;html_2ae4078dfc3dbd460873419134ebb91e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d9b785d218201fc619990c1c8f5bd59c.setContent(html_2ae4078dfc3dbd460873419134ebb91e);
#
#
#
#         marker_26dfe182b5fd066eb5b26286db755e14.bindPopup(popup_d9b785d218201fc619990c1c8f5bd59c)
#         ;
#
#
#
#
#             var marker_8a1867de7a50817f219f58bb81bbfba5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c4889b8be41df3f116a00be35c22e8cb);
#
#
#         var popup_3df5206c188fc9ecc5932aac709d9629 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8910922bfcbe5a006ee68215e5030e2b = $(`&lt;div id=&quot;html_8910922bfcbe5a006ee68215e5030e2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3df5206c188fc9ecc5932aac709d9629.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_011ec77c59f5337162fdf08e5f1e8abe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_011ec77c59f5337162fdf08e5f1e8abe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_011ec77c59f5337162fdf08e5f1e8abe = L.map(
#                 &quot;map_011ec77c59f5337162fdf08e5f1e8abe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15ef5e0b16a5d796d2dc7a726d08d201 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15ef5e0b16a5d796d2dc7a726d08d201.addTo(map_011ec77c59f5337162fdf08e5f1e8abe);
#
#
#             var feature_group_9fd49437058c176b30d829ee356cd13a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_072c196791c09db23b05ae1f71076e8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9fd49437058c176b30d829ee356cd13a);
#
#
#         var popup_e8b06217f579fd4739a43dfa07741376 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e54f534e4a744dfcbebde524dd0fff8 = $(`&lt;div id=&quot;html_5e54f534e4a744dfcbebde524dd0fff8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e8b06217f579fd4739a43dfa07741376.setContent(html_5e54f534e4a744dfcbebde524dd0fff8);
#
#
#
#         marker_072c196791c09db23b05ae1f71076e8e.bindPopup(popup_e8b06217f579fd4739a43dfa07741376)
#         ;
#
#
#
#
#             var marker_4ac233956f54a7b4e616104e43dbe2b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9fd49437058c176b30d829ee356cd13a);
#
#
#         var popup_50ab971b5b5911ce3b47b0efc43be34d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed83cfa206c81eefd7f7a61c3035f797 = $(`&lt;div id=&quot;html_ed83cfa206c81eefd7f7a61c3035f797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_50ab971b5b5911ce3b47b0efc43be34d.setContent(html_ed83cfa206c81eefd7f7a61c3035f797);
#
#
#
#         marker_4ac233956f54a7b4e616104e43dbe2b4.bindPopup(popup_50ab971b5b5911ce3b47b0efc43be34d)
#         ;
#
#
#
#
#             var marker_a9bb6206d7c6f67a5eea26fe6d2a7e4c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9fd49437058c176b30d829ee356cd13a);
#
#
#         var popup_6f8f198dd3f708ebb8cac46976bc5a7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f6dc4be32e2cd33b13567f0afb2ed9c = $(`&lt;div id=&quot;html_5f6dc4be32e2cd33b13567f0afb2ed9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6f8f198dd3f708ebb8cac46976bc5a7a.setContent(html_5f6dc4be32e2cd33b13567f0afb2ed9c);
#
#
#
#         marker_a9bb6206d7c6f67a5eea26fe6d2a7e4c.bindPopup(popup_6f8f198dd3f708ebb8cac46976bc5a7a)
#         ;
#
#
#
#
#             var marker_5201674f2dbff66159d3a205992700e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9fd49437058c176b30d829ee356cd13a);
#
#
#         var popup_ee202b96d206a31254de240a2d7d7c79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ad6d6c878ca93f357b584083aafb31d = $(`&lt;div id=&quot;html_9ad6d6c878ca93f357b584083aafb31d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee202b96d206a31254de240a2d7d7c79.setContent(html_9ad6d6c878ca93f357b584083aafb31d);
#
#
#
#         marker_5201674f2dbff66159d3a205992700e0.bindPopup(popup_ee202b96d206a31254de240a2d7d7c79)
#         ;
#
#
#
#
#             var marker_ebf47ac869b199609a5fb525bf9ec26a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9fd49437058c176b30d829ee356cd13a);
#
#
#         var popup_3de9c691be9358dc45402734d3f3ac79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fbfee3e7b7fd1a4d7e1739e7fdd18bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fbfee3e7b7fd1a4d7e1739e7fdd18bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fbfee3e7b7fd1a4d7e1739e7fdd18bd = L.map(
#                 &quot;map_5fbfee3e7b7fd1a4d7e1739e7fdd18bd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d80416bf149470d217b03b752492d3a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d80416bf149470d217b03b752492d3a.addTo(map_5fbfee3e7b7fd1a4d7e1739e7fdd18bd);
#
#
#             var feature_group_15c88695f5aa3cd4258516fdba479778 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_15c88695f5aa3cd4258516fdba479778.addTo(map_5fbfee3e7b7fd1a4d7e1739e7fdd18bd);
#
#
#             var feature_group_sub_group_36078511a5ca468304d16857872b5fce = L.featureGroup.subGroup(
#                 feature_group_15c88695f5aa3cd4258516fdba479778
#             );
#
#
#             var marker_73ac37ff6d47d59c547e030801b9a9d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_36078511a5ca468304d16857872b5fce);
#
#
#         var popup_9c33ab23a8411ca469c018705e0c78c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c07a47e761d41247a3d4c8b1921d59d6 = $(`&lt;div id=&quot;html_c07a47e761d41247a3d4c8b1921d59d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9c33ab23a8411ca469c018705e0c78c0.setContent(html_c07a47e761d41247a3d4c8b1921d59d6);
#
#
#
#         marker_73ac37ff6d47d59c547e030801b9a9d6.bindPopup(popup_9c33ab23a8411ca469c018705e0c78c0)
#         ;
#
#
#
#
#             var marker_a5c3a4f124aee7bf0a21868a70df085d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_36078511a5ca468304d16857872b5fce);
#
#
#         var popup_69e890c49899ef47bbace6c91b4562d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9aba3fb74ac5ac917a36a0514f453400 = $(`&lt;div id=&quot;html_9aba3fb74ac5ac917a36a0514f453400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_69e890c49899ef47bbace6c91b4562d8.setContent(html_9aba3fb74ac5ac917a36a0514f453400);
#
#
#
#         marker_a5c3a4f124aee7bf0a21868a70df085d.bindPopup(popup_69e890c49899ef47bbace6c91b4562d8)
#         ;
#
#
#
#
#             var marker_15a574cfb98c3c7bf9a9845427c7ddc4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_36078511a5ca468304d16857872b5fce);
#
#
#         var popup_ef4a01343c40d95de57a4d49a5aeec76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_011595294849df3d441e25b57f87106f = $(`&lt;div id=&quot;html_011595294849df3d441e25b57f87106f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef4a01343c40d95de57a4d49a5aeec76.setContent(html_011595294849df3d441e25b57f87106f);
#
#
#
#         marker_15a574cfb98c3c7bf9a9845427c7ddc4.bindPopup(popup_ef4a01343c40d95de57a4d49a5aeec76)
#         ;
#
#
#
#
#             var marker_c6d4036ed01a6ae3bbb0abeb1ab0bcb8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_36078511a5ca468304d16857872b5fce);
#
#
#         var popup_a011564df40057e641cdd2c832d6d924 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_134b552157f1d19a97b9a893115b1091 = $(`&lt;div id=&quot;html_134b552157f1d19a97b9a893115b1091&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a011564df40057e641cdd2c832d6d924.setContent(html_134b552157f1d19a97b9a893115b1091);
#
#
#
#         marker_
