# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83bdecaaab8e249dfe588dff01e03a6b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83bdecaaab8e249dfe588dff01e03a6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83bdecaaab8e249dfe588dff01e03a6b = L.map(
#                 &quot;map_83bdecaaab8e249dfe588dff01e03a6b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df53a06aa2c97dc87210dcef0dc7dccf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df53a06aa2c97dc87210dcef0dc7dccf.addTo(map_83bdecaaab8e249dfe588dff01e03a6b);
#
#
#             var marker_a52b8b3212b945b2d4f0a3392e221a30 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_83bdecaaab8e249dfe588dff01e03a6b);
#
#
#         var popup_ffb569cf6cec4a5c1fb312ed5e9f94d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_175d24f0efd057593cd0b0c417e440cb = $(`&lt;div id=&quot;html_175d24f0efd057593cd0b0c417e440cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ffb569cf6cec4a5c1fb312ed5e9f94d9.setContent(html_175d24f0efd057593cd0b0c417e440cb);
#
#
#
#         marker_a52b8b3212b945b2d4f0a3392e221a30.bindPopup(popup_ffb569cf6cec4a5c1fb312ed5e9f94d9)
#         ;
#
#
#
#
#             var marker_2c3f0e415dfb81a26f5a6d0b5acc51da = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_83bdecaaab8e249dfe588dff01e03a6b);
#
#
#         var popup_766b9c3ce74f8810146c6ac8daa589c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5bafe6357b7489a230954f118ddbe41 = $(`&lt;div id=&quot;html_b5bafe6357b7489a230954f118ddbe41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_766b9c3ce74f8810146c6ac8daa589c5.setContent(html_b5bafe6357b7489a230954f118ddbe41);
#
#
#
#         marker_2c3f0e415dfb81a26f5a6d0b5acc51da.bindPopup(popup_766b9c3ce74f8810146c6ac8daa589c5)
#         ;
#
#
#
#
#             var marker_845179ebbe71a6a695a106b6eaf76772 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_83bdecaaab8e249dfe588dff01e03a6b);
#
#
#         var popup_2377bfc2cb0f325c55962db324dc034e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_588b4f2be1486884c397c658fe2191ad = $(`&lt;div id=&quot;html_588b4f2be1486884c397c658fe2191ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2377bfc2cb0f325c55962db324dc034e.setContent(html_588b4f2be1486884c397c658fe2191ad);
#
#
#
#         marker_845179ebbe71a6a695a106b6eaf76772.bindPopup(popup_2377bfc2cb0f325c55962db324dc034e)
#         ;
#
#
#
#
#             var marker_41b396789b35cedd8ffbca11d2c46c67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_83bdecaaab8e249dfe588dff01e03a6b);
#
#
#         var popup_615dd08c50699f0d99a94b5c541a6d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bffccd7f1170217213020aea7c274362 = $(`&lt;div id=&quot;html_bffccd7f1170217213020aea7c274362&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_615dd08c50699f0d99a94b5c541a6d6a.setContent(html_bffccd7f1170217213020aea7c274362);
#
#
#
#         marker_41b396789b35cedd8ffbca11d2c46c67.bindPopup(popup_615dd08c50699f0d99a94b5c541a6d6a)
#         ;
#
#
#
#
#             var marker_dda8b18d393a76ede04dcd18bafd17cf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_83bdecaaab8e249dfe588dff01e03a6b);
#
#
#         var popup_f367de57d194433751ee1bf26f347337 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1b456dc58bb8f19ae9e536130dfa344 = $(`&lt;div id=&quot;html_d1b456dc58bb8f19ae9e536130dfa344&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f367de57d194433751ee1bf26f3473

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_358d3c54839b1259065f8ec7ec141b03 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_358d3c54839b1259065f8ec7ec141b03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_358d3c54839b1259065f8ec7ec141b03 = L.map(
#                 &quot;map_358d3c54839b1259065f8ec7ec141b03&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9af084d4d23fdbdee6828216a048cb42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9af084d4d23fdbdee6828216a048cb42.addTo(map_358d3c54839b1259065f8ec7ec141b03);
#
#
#             var feature_group_37cb74bfc63e84b1fc291ffa89b2859d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_27ea95ae21e5570dbd6432f46e1ebae3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_37cb74bfc63e84b1fc291ffa89b2859d);
#
#
#         var popup_3491a3bea1dcc3711613a00762edd4e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6a221aa03a3d5b8a6b965b197459298 = $(`&lt;div id=&quot;html_c6a221aa03a3d5b8a6b965b197459298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3491a3bea1dcc3711613a00762edd4e3.setContent(html_c6a221aa03a3d5b8a6b965b197459298);
#
#
#
#         marker_27ea95ae21e5570dbd6432f46e1ebae3.bindPopup(popup_3491a3bea1dcc3711613a00762edd4e3)
#         ;
#
#
#
#
#             var marker_8062d7e8d71ce81b9f220c700a236057 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_37cb74bfc63e84b1fc291ffa89b2859d);
#
#
#         var popup_231bbf2d2f6b8790fc97b73f782ec307 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_369af7f354ab67ae29c3a0ca062984e8 = $(`&lt;div id=&quot;html_369af7f354ab67ae29c3a0ca062984e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_231bbf2d2f6b8790fc97b73f782ec307.setContent(html_369af7f354ab67ae29c3a0ca062984e8);
#
#
#
#         marker_8062d7e8d71ce81b9f220c700a236057.bindPopup(popup_231bbf2d2f6b8790fc97b73f782ec307)
#         ;
#
#
#
#
#             var marker_207df2c1d487c210ec308cbf4563a953 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_37cb74bfc63e84b1fc291ffa89b2859d);
#
#
#         var popup_5b5a7422686eaeaa6df09bcd5f83a805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5928af4d4a9f55822c7dfb875e5bc16b = $(`&lt;div id=&quot;html_5928af4d4a9f55822c7dfb875e5bc16b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5b5a7422686eaeaa6df09bcd5f83a805.setContent(html_5928af4d4a9f55822c7dfb875e5bc16b);
#
#
#
#         marker_207df2c1d487c210ec308cbf4563a953.bindPopup(popup_5b5a7422686eaeaa6df09bcd5f83a805)
#         ;
#
#
#
#
#             var marker_26f28a8815d305548010cd76d99c8628 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_37cb74bfc63e84b1fc291ffa89b2859d);
#
#
#         var popup_84d8186420addf700da40e4a596ddb30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73a9c36980636962f5bcbb02051eb8e8 = $(`&lt;div id=&quot;html_73a9c36980636962f5bcbb02051eb8e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_84d8186420addf700da40e4a596ddb30.setContent(html_73a9c36980636962f5bcbb02051eb8e8);
#
#
#
#         marker_26f28a8815d305548010cd76d99c8628.bindPopup(popup_84d8186420addf700da40e4a596ddb30)
#         ;
#
#
#
#
#             var marker_f2a6bc25299c8d989a58fa346b9708ed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_37cb74bfc63e84b1fc291ffa89b2859d);
#
#
#         var popup_e5e9220955da3d0fcb895e58f89cfae9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0bfacc95ac33c685ecaca3dda3337a3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0bfacc95ac33c685ecaca3dda3337a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0bfacc95ac33c685ecaca3dda3337a3 = L.map(
#                 &quot;map_d0bfacc95ac33c685ecaca3dda3337a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_693e3f5eaba873d34fbeb48298afde02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_693e3f5eaba873d34fbeb48298afde02.addTo(map_d0bfacc95ac33c685ecaca3dda3337a3);
#
#
#             var feature_group_1cd793ffd5a9f66b6d74edc1ada9d6d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1cd793ffd5a9f66b6d74edc1ada9d6d9.addTo(map_d0bfacc95ac33c685ecaca3dda3337a3);
#
#
#             var feature_group_sub_group_e7a70f633e8f5e302dfa9b580925f2f7 = L.featureGroup.subGroup(
#                 feature_group_1cd793ffd5a9f66b6d74edc1ada9d6d9
#             );
#
#
#             var marker_b2e2cb78d0b5939ab1489eb2977abfd6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e7a70f633e8f5e302dfa9b580925f2f7);
#
#
#         var popup_0765d1e211b3fb0aceee522fc8ef6744 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87ffd462caeffc2e1762fda3416aa24e = $(`&lt;div id=&quot;html_87ffd462caeffc2e1762fda3416aa24e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0765d1e211b3fb0aceee522fc8ef6744.setContent(html_87ffd462caeffc2e1762fda3416aa24e);
#
#
#
#         marker_b2e2cb78d0b5939ab1489eb2977abfd6.bindPopup(popup_0765d1e211b3fb0aceee522fc8ef6744)
#         ;
#
#
#
#
#             var marker_0cc0ad45422b5c7bf15e73e0ba8463ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e7a70f633e8f5e302dfa9b580925f2f7);
#
#
#         var popup_69f7a0c3176148fe72ba023a8279c83e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25b2466418c25bdb4c504f4bcd63fc21 = $(`&lt;div id=&quot;html_25b2466418c25bdb4c504f4bcd63fc21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_69f7a0c3176148fe72ba023a8279c83e.setContent(html_25b2466418c25bdb4c504f4bcd63fc21);
#
#
#
#         marker_0cc0ad45422b5c7bf15e73e0ba8463ae.bindPopup(popup_69f7a0c3176148fe72ba023a8279c83e)
#         ;
#
#
#
#
#             var marker_d46e621d564f14936b3388ced2289bfa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e7a70f633e8f5e302dfa9b580925f2f7);
#
#
#         var popup_a4c0e63133cf238489beb796ef1fac32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08e0d9f5e39b83862086885e0d9847c1 = $(`&lt;div id=&quot;html_08e0d9f5e39b83862086885e0d9847c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a4c0e63133cf238489beb796ef1fac32.setContent(html_08e0d9f5e39b83862086885e0d9847c1);
#
#
#
#         marker_d46e621d564f14936b3388ced2289bfa.bindPopup(popup_a4c0e63133cf238489beb796ef1fac32)
#         ;
#
#
#
#
#             var marker_1747a6910fe8eb087b82df5f3fa73668 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e7a70f633e8f5e302dfa9b580925f2f7);
#
#
#         var popup_51a82ff8b577c3b76d5c3c922fd0ae71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40dadc60843d7874c72e0b90c45fa726 = $(`&lt;div id=&quot;html_40dadc60843d7874c72e0b90c45fa726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_51a82ff8b577c3b76d5c3c922fd0ae71.setContent(html_40dadc60843d7874c72e0b90c45fa726);
#
#
#
#         mark
