# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94ebbfdd3a5fe5cb87849d32f64e16e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94ebbfdd3a5fe5cb87849d32f64e16e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94ebbfdd3a5fe5cb87849d32f64e16e4 = L.map(
#                 &quot;map_94ebbfdd3a5fe5cb87849d32f64e16e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c270a4af60ef661e601af28744233fd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c270a4af60ef661e601af28744233fd0.addTo(map_94ebbfdd3a5fe5cb87849d32f64e16e4);
#
#
#             var marker_0b8f76c6eeb3692a69642f7edb976b14 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94ebbfdd3a5fe5cb87849d32f64e16e4);
#
#
#         var popup_91ff1fcc711dc5c58930af6ad9e8fecb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed71e4fff8c828e6d63937805d267d47 = $(`&lt;div id=&quot;html_ed71e4fff8c828e6d63937805d267d47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_91ff1fcc711dc5c58930af6ad9e8fecb.setContent(html_ed71e4fff8c828e6d63937805d267d47);
#
#
#
#         marker_0b8f76c6eeb3692a69642f7edb976b14.bindPopup(popup_91ff1fcc711dc5c58930af6ad9e8fecb)
#         ;
#
#
#
#
#             var marker_95259efa1d3a915ed21f40781accd0a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94ebbfdd3a5fe5cb87849d32f64e16e4);
#
#
#         var popup_aad8e05b2ba61e5cf351e24ce4f4bca6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c00be45f03789386550f7cca2df8ff3e = $(`&lt;div id=&quot;html_c00be45f03789386550f7cca2df8ff3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aad8e05b2ba61e5cf351e24ce4f4bca6.setContent(html_c00be45f03789386550f7cca2df8ff3e);
#
#
#
#         marker_95259efa1d3a915ed21f40781accd0a6.bindPopup(popup_aad8e05b2ba61e5cf351e24ce4f4bca6)
#         ;
#
#
#
#
#             var marker_25797ff74061aa0bde2e70aa40aeda13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94ebbfdd3a5fe5cb87849d32f64e16e4);
#
#
#         var popup_8fec5554e1d55901c9385db12ea66bd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a86c5f335460b8af69da4f2aff3d9863 = $(`&lt;div id=&quot;html_a86c5f335460b8af69da4f2aff3d9863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8fec5554e1d55901c9385db12ea66bd3.setContent(html_a86c5f335460b8af69da4f2aff3d9863);
#
#
#
#         marker_25797ff74061aa0bde2e70aa40aeda13.bindPopup(popup_8fec5554e1d55901c9385db12ea66bd3)
#         ;
#
#
#
#
#             var marker_539b90f871f90d12ac9c761f850704e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94ebbfdd3a5fe5cb87849d32f64e16e4);
#
#
#         var popup_bf78509f3094b77b860020931ab64385 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d08c91952150d2f38e8c2d988dc4e304 = $(`&lt;div id=&quot;html_d08c91952150d2f38e8c2d988dc4e304&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf78509f3094b77b860020931ab64385.setContent(html_d08c91952150d2f38e8c2d988dc4e304);
#
#
#
#         marker_539b90f871f90d12ac9c761f850704e2.bindPopup(popup_bf78509f3094b77b860020931ab64385)
#         ;
#
#
#
#
#             var marker_74089a810ee4b70d8831a043dd21f9f4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94ebbfdd3a5fe5cb87849d32f64e16e4);
#
#
#         var popup_eeaf3f2e3928c8a14eb89f979a647719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34eda397449f7b6333398c6eacd2f35d = $(`&lt;div id=&quot;html_34eda397449f7b6333398c6eacd2f35d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eeaf3f2e3928c8a14eb89f979a647719.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9441abee6f4a63dafa0ce7b3bfb4dd1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9441abee6f4a63dafa0ce7b3bfb4dd1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9441abee6f4a63dafa0ce7b3bfb4dd1b = L.map(
#                 &quot;map_9441abee6f4a63dafa0ce7b3bfb4dd1b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36bc9f5e5e2996d099254ccd489b4a6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36bc9f5e5e2996d099254ccd489b4a6b.addTo(map_9441abee6f4a63dafa0ce7b3bfb4dd1b);
#
#
#             var feature_group_97299a0f198376f22d92984f3fdd1274 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1e3e6e97078ffa95c47b3628ec38e13b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_97299a0f198376f22d92984f3fdd1274);
#
#
#         var popup_fd6415c31511292640e8dad4dbddc894 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_622280feb077471b83b1e702f5363349 = $(`&lt;div id=&quot;html_622280feb077471b83b1e702f5363349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fd6415c31511292640e8dad4dbddc894.setContent(html_622280feb077471b83b1e702f5363349);
#
#
#
#         marker_1e3e6e97078ffa95c47b3628ec38e13b.bindPopup(popup_fd6415c31511292640e8dad4dbddc894)
#         ;
#
#
#
#
#             var marker_65fb52eaf0d1474046c155694cd56513 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_97299a0f198376f22d92984f3fdd1274);
#
#
#         var popup_7cb1c64a65b205fd42c6e3c56511087d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c72b155224617cec5383c7e791956519 = $(`&lt;div id=&quot;html_c72b155224617cec5383c7e791956519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7cb1c64a65b205fd42c6e3c56511087d.setContent(html_c72b155224617cec5383c7e791956519);
#
#
#
#         marker_65fb52eaf0d1474046c155694cd56513.bindPopup(popup_7cb1c64a65b205fd42c6e3c56511087d)
#         ;
#
#
#
#
#             var marker_a32e58b0e79b14b55f6df7d0c4f06194 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_97299a0f198376f22d92984f3fdd1274);
#
#
#         var popup_644d68753aa2f8520d7e38d1d18f80a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb8f8515594dee0585cd63e60bc1bd33 = $(`&lt;div id=&quot;html_cb8f8515594dee0585cd63e60bc1bd33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_644d68753aa2f8520d7e38d1d18f80a8.setContent(html_cb8f8515594dee0585cd63e60bc1bd33);
#
#
#
#         marker_a32e58b0e79b14b55f6df7d0c4f06194.bindPopup(popup_644d68753aa2f8520d7e38d1d18f80a8)
#         ;
#
#
#
#
#             var marker_c82aea5cc79cbf8562ae19a5bddacea1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_97299a0f198376f22d92984f3fdd1274);
#
#
#         var popup_cc233d285b65ed9685b1c231e80aec07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2191b8fa1f0cf7ec32c9b169177058f4 = $(`&lt;div id=&quot;html_2191b8fa1f0cf7ec32c9b169177058f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc233d285b65ed9685b1c231e80aec07.setContent(html_2191b8fa1f0cf7ec32c9b169177058f4);
#
#
#
#         marker_c82aea5cc79cbf8562ae19a5bddacea1.bindPopup(popup_cc233d285b65ed9685b1c231e80aec07)
#         ;
#
#
#
#
#             var marker_5d4704d00ec18d13cc5923bc248cd023 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_97299a0f198376f22d92984f3fdd1274);
#
#
#         var popup_c755acef3fdf449175f8ee87c41204c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18213a7d7bb8474928138b2be4460b3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18213a7d7bb8474928138b2be4460b3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18213a7d7bb8474928138b2be4460b3d = L.map(
#                 &quot;map_18213a7d7bb8474928138b2be4460b3d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b6483e009e16a4cbf3e7b7b6d937e3a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b6483e009e16a4cbf3e7b7b6d937e3a.addTo(map_18213a7d7bb8474928138b2be4460b3d);
#
#
#             var feature_group_8350cdcdbd52d59f6c0bb3674e66384b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8350cdcdbd52d59f6c0bb3674e66384b.addTo(map_18213a7d7bb8474928138b2be4460b3d);
#
#
#             var feature_group_sub_group_313a518ab4d6f84d8f3e3bd006cb8b1f = L.featureGroup.subGroup(
#                 feature_group_8350cdcdbd52d59f6c0bb3674e66384b
#             );
#
#
#             var marker_ae9046d85622565fca1c837e0ccf93b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_313a518ab4d6f84d8f3e3bd006cb8b1f);
#
#
#         var popup_cde6689b0d74d5dc1e3c311069cd3ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fecace2a7da1ec0791c716a9051ce01 = $(`&lt;div id=&quot;html_9fecace2a7da1ec0791c716a9051ce01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cde6689b0d74d5dc1e3c311069cd3ede.setContent(html_9fecace2a7da1ec0791c716a9051ce01);
#
#
#
#         marker_ae9046d85622565fca1c837e0ccf93b4.bindPopup(popup_cde6689b0d74d5dc1e3c311069cd3ede)
#         ;
#
#
#
#
#             var marker_01b6cee97ac737cd8faaacf32814cd52 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_313a518ab4d6f84d8f3e3bd006cb8b1f);
#
#
#         var popup_efdb5a4ec6e0b0544c7b3721b9478598 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_288c1566835bed763c06b0241f3209e2 = $(`&lt;div id=&quot;html_288c1566835bed763c06b0241f3209e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_efdb5a4ec6e0b0544c7b3721b9478598.setContent(html_288c1566835bed763c06b0241f3209e2);
#
#
#
#         marker_01b6cee97ac737cd8faaacf32814cd52.bindPopup(popup_efdb5a4ec6e0b0544c7b3721b9478598)
#         ;
#
#
#
#
#             var marker_f609aa2027e9b30938b3038008a0e600 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_313a518ab4d6f84d8f3e3bd006cb8b1f);
#
#
#         var popup_b16d451ec18f210e474fc93364dcc469 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b1f08df29de75f4ac7138dbf0619dfa = $(`&lt;div id=&quot;html_8b1f08df29de75f4ac7138dbf0619dfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b16d451ec18f210e474fc93364dcc469.setContent(html_8b1f08df29de75f4ac7138dbf0619dfa);
#
#
#
#         marker_f609aa2027e9b30938b3038008a0e600.bindPopup(popup_b16d451ec18f210e474fc93364dcc469)
#         ;
#
#
#
#
#             var marker_9e3e7643efca70cfa2d028f9e3f6090d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_313a518ab4d6f84d8f3e3bd006cb8b1f);
#
#
#         var popup_564eef396142578b810242b5d2ccc371 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec8498e8b58624d42bc9a59acafce577 = $(`&lt;div id=&quot;html_ec8498e8b58624d42bc9a59acafce577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_564eef396142578b810242b5d2ccc371.setContent(html_ec8498e8b58624d42bc9a59acafce577);
#
#
#
#         marker_
