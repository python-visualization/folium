# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa2ecb79fac5d7266051b2a6258599d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa2ecb79fac5d7266051b2a6258599d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa2ecb79fac5d7266051b2a6258599d2 = L.map(
#                 &quot;map_fa2ecb79fac5d7266051b2a6258599d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1e1eeeedf3af68392b6d7687db218a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1e1eeeedf3af68392b6d7687db218a6.addTo(map_fa2ecb79fac5d7266051b2a6258599d2);
#
#
#             var marker_65414dfc4132c92a185e175bf7e96434 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fa2ecb79fac5d7266051b2a6258599d2);
#
#
#         var popup_df45c23ca4edcc350b4257f507a9ae32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c5e11cf3648dfc2e08557ba0032c8a4 = $(`&lt;div id=&quot;html_8c5e11cf3648dfc2e08557ba0032c8a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_df45c23ca4edcc350b4257f507a9ae32.setContent(html_8c5e11cf3648dfc2e08557ba0032c8a4);
#
#
#
#         marker_65414dfc4132c92a185e175bf7e96434.bindPopup(popup_df45c23ca4edcc350b4257f507a9ae32)
#         ;
#
#
#
#
#             var marker_bfbe34973659d9babda7de66e4749750 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fa2ecb79fac5d7266051b2a6258599d2);
#
#
#         var popup_083027a8d37c20ead6ab4c0b2b1dc778 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c06017bd9f66ba6dbd834b7927fc0c3 = $(`&lt;div id=&quot;html_8c06017bd9f66ba6dbd834b7927fc0c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_083027a8d37c20ead6ab4c0b2b1dc778.setContent(html_8c06017bd9f66ba6dbd834b7927fc0c3);
#
#
#
#         marker_bfbe34973659d9babda7de66e4749750.bindPopup(popup_083027a8d37c20ead6ab4c0b2b1dc778)
#         ;
#
#
#
#
#             var marker_79a9dd20c9ff4cbedce49e4824235d03 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fa2ecb79fac5d7266051b2a6258599d2);
#
#
#         var popup_f527b60b274dbe07b50316e4ca6ad232 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e7cbde076caa03d44a3715f4ef50d75 = $(`&lt;div id=&quot;html_6e7cbde076caa03d44a3715f4ef50d75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f527b60b274dbe07b50316e4ca6ad232.setContent(html_6e7cbde076caa03d44a3715f4ef50d75);
#
#
#
#         marker_79a9dd20c9ff4cbedce49e4824235d03.bindPopup(popup_f527b60b274dbe07b50316e4ca6ad232)
#         ;
#
#
#
#
#             var marker_cb7bb3b313568b063e629c214bf15e7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fa2ecb79fac5d7266051b2a6258599d2);
#
#
#         var popup_c76f471ef009db98a38c0878ee9b3231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42d06d78fdd8f5fc070e11432cc9f533 = $(`&lt;div id=&quot;html_42d06d78fdd8f5fc070e11432cc9f533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c76f471ef009db98a38c0878ee9b3231.setContent(html_42d06d78fdd8f5fc070e11432cc9f533);
#
#
#
#         marker_cb7bb3b313568b063e629c214bf15e7c.bindPopup(popup_c76f471ef009db98a38c0878ee9b3231)
#         ;
#
#
#
#
#             var marker_5141668b997d173eb8a4926a0b8aa044 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fa2ecb79fac5d7266051b2a6258599d2);
#
#
#         var popup_19f82029489f61ef68fe8c1a9bde89f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25c2f766de7542183db9e30c3cb35638 = $(`&lt;div id=&quot;html_25c2f766de7542183db9e30c3cb35638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_19f82029489f61ef68fe8c1a9bde89f6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a4b82f7f77d5d30b0356aa566bceb06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a4b82f7f77d5d30b0356aa566bceb06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a4b82f7f77d5d30b0356aa566bceb06 = L.map(
#                 &quot;map_4a4b82f7f77d5d30b0356aa566bceb06&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b972ef2d85e95cf588a292f9035c5f96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b972ef2d85e95cf588a292f9035c5f96.addTo(map_4a4b82f7f77d5d30b0356aa566bceb06);
#
#
#             var feature_group_b68cf7075bf2932154a3dde021d32b30 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f065c72fd181b075ec74e6635906c3b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b68cf7075bf2932154a3dde021d32b30);
#
#
#         var popup_66da8e08d489d3d4c5d1063366c55af6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7397c1c62418a85a7678e088c54e5498 = $(`&lt;div id=&quot;html_7397c1c62418a85a7678e088c54e5498&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_66da8e08d489d3d4c5d1063366c55af6.setContent(html_7397c1c62418a85a7678e088c54e5498);
#
#
#
#         marker_f065c72fd181b075ec74e6635906c3b5.bindPopup(popup_66da8e08d489d3d4c5d1063366c55af6)
#         ;
#
#
#
#
#             var marker_bc336a61a556c8cc1f5805836acf0527 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b68cf7075bf2932154a3dde021d32b30);
#
#
#         var popup_c55b59631737c9e6e963490303bba1d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbd63a01af2dd1c77de11c29c0c6bfd4 = $(`&lt;div id=&quot;html_bbd63a01af2dd1c77de11c29c0c6bfd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c55b59631737c9e6e963490303bba1d5.setContent(html_bbd63a01af2dd1c77de11c29c0c6bfd4);
#
#
#
#         marker_bc336a61a556c8cc1f5805836acf0527.bindPopup(popup_c55b59631737c9e6e963490303bba1d5)
#         ;
#
#
#
#
#             var marker_f06b69bbb4c408771c47667345d5eee6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b68cf7075bf2932154a3dde021d32b30);
#
#
#         var popup_60f5983f1e837809b582d573457b7926 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f9ad679ac5b23b0034e0b9101e8be34 = $(`&lt;div id=&quot;html_0f9ad679ac5b23b0034e0b9101e8be34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_60f5983f1e837809b582d573457b7926.setContent(html_0f9ad679ac5b23b0034e0b9101e8be34);
#
#
#
#         marker_f06b69bbb4c408771c47667345d5eee6.bindPopup(popup_60f5983f1e837809b582d573457b7926)
#         ;
#
#
#
#
#             var marker_7a1d39280cb99f3a6d5e00f105ddc02e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b68cf7075bf2932154a3dde021d32b30);
#
#
#         var popup_c207a9d958edd572f2cd5bddef12b3fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e7dde4807e7bb545dce934a9aa3050d = $(`&lt;div id=&quot;html_7e7dde4807e7bb545dce934a9aa3050d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c207a9d958edd572f2cd5bddef12b3fa.setContent(html_7e7dde4807e7bb545dce934a9aa3050d);
#
#
#
#         marker_7a1d39280cb99f3a6d5e00f105ddc02e.bindPopup(popup_c207a9d958edd572f2cd5bddef12b3fa)
#         ;
#
#
#
#
#             var marker_717621ba8df50403835d945e77ced8da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b68cf7075bf2932154a3dde021d32b30);
#
#
#         var popup_7630d6ee39b283b1b965603e2770fcef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50beeb51a7c56e014027fb8bd5d2f1fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50beeb51a7c56e014027fb8bd5d2f1fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50beeb51a7c56e014027fb8bd5d2f1fc = L.map(
#                 &quot;map_50beeb51a7c56e014027fb8bd5d2f1fc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9acb0fa04ddd0083bd1755b0016d276 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9acb0fa04ddd0083bd1755b0016d276.addTo(map_50beeb51a7c56e014027fb8bd5d2f1fc);
#
#
#             var feature_group_3c123c08cbb7fa08b8b0c870030b3b59 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3c123c08cbb7fa08b8b0c870030b3b59.addTo(map_50beeb51a7c56e014027fb8bd5d2f1fc);
#
#
#             var feature_group_sub_group_173c78b360f31ecee395b8cf13a4ca34 = L.featureGroup.subGroup(
#                 feature_group_3c123c08cbb7fa08b8b0c870030b3b59
#             );
#
#
#             var marker_699f2a05b3a073c9ba3ac06a6d16e373 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_173c78b360f31ecee395b8cf13a4ca34);
#
#
#         var popup_581cced0d3072ef84a244ab2abc9353e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87af55fdf372bd953208ee1804fdaf21 = $(`&lt;div id=&quot;html_87af55fdf372bd953208ee1804fdaf21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_581cced0d3072ef84a244ab2abc9353e.setContent(html_87af55fdf372bd953208ee1804fdaf21);
#
#
#
#         marker_699f2a05b3a073c9ba3ac06a6d16e373.bindPopup(popup_581cced0d3072ef84a244ab2abc9353e)
#         ;
#
#
#
#
#             var marker_74a9ca167273de77f5089c0e3c01729b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_173c78b360f31ecee395b8cf13a4ca34);
#
#
#         var popup_f83eadf63c03375dbd8196eed29297bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89b8684cdb65cb0bdd22057a053c371a = $(`&lt;div id=&quot;html_89b8684cdb65cb0bdd22057a053c371a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f83eadf63c03375dbd8196eed29297bd.setContent(html_89b8684cdb65cb0bdd22057a053c371a);
#
#
#
#         marker_74a9ca167273de77f5089c0e3c01729b.bindPopup(popup_f83eadf63c03375dbd8196eed29297bd)
#         ;
#
#
#
#
#             var marker_d320f07c172a2ab9e94c672e244d34c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_173c78b360f31ecee395b8cf13a4ca34);
#
#
#         var popup_d09c13258d2b9052a24ee996b8fd1165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d0a5c6efb48539ca275b0db9fb809af = $(`&lt;div id=&quot;html_8d0a5c6efb48539ca275b0db9fb809af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d09c13258d2b9052a24ee996b8fd1165.setContent(html_8d0a5c6efb48539ca275b0db9fb809af);
#
#
#
#         marker_d320f07c172a2ab9e94c672e244d34c5.bindPopup(popup_d09c13258d2b9052a24ee996b8fd1165)
#         ;
#
#
#
#
#             var marker_845854bc2f5db7cbc996c7f22b71677c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_173c78b360f31ecee395b8cf13a4ca34);
#
#
#         var popup_14e1eddc75f8cddd5eb3b97e701acecb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bc695a1ba1805d8dd377d706655ab00 = $(`&lt;div id=&quot;html_4bc695a1ba1805d8dd377d706655ab00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_14e1eddc75f8cddd5eb3b97e701acecb.setContent(html_4bc695a1ba1805d8dd377d706655ab00);
#
#
#
#         marker_
