# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9fa6f353adaf4f8ce80646bc28bdaef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9fa6f353adaf4f8ce80646bc28bdaef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9fa6f353adaf4f8ce80646bc28bdaef = L.map(
#                 &quot;map_c9fa6f353adaf4f8ce80646bc28bdaef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a32741dacf1a7951571563ce1b88d85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a32741dacf1a7951571563ce1b88d85.addTo(map_c9fa6f353adaf4f8ce80646bc28bdaef);
#
#
#             var marker_53d7436b99aeefeccd8dd6b688bc6d4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c9fa6f353adaf4f8ce80646bc28bdaef);
#
#
#         var popup_3dbe85fde6c6d207b7a0c0db18d2faf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29d2f3225023ed49e4c0477070667c39 = $(`&lt;div id=&quot;html_29d2f3225023ed49e4c0477070667c39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3dbe85fde6c6d207b7a0c0db18d2faf8.setContent(html_29d2f3225023ed49e4c0477070667c39);
#
#
#
#         marker_53d7436b99aeefeccd8dd6b688bc6d4d.bindPopup(popup_3dbe85fde6c6d207b7a0c0db18d2faf8)
#         ;
#
#
#
#
#             var marker_700dd5c76fb6b75be0ee74023abdbd87 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c9fa6f353adaf4f8ce80646bc28bdaef);
#
#
#         var popup_0b527f2ce874f7bf55b4b57390bf0a8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_636ea77a9fe21a7a335bb3920c3f95aa = $(`&lt;div id=&quot;html_636ea77a9fe21a7a335bb3920c3f95aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b527f2ce874f7bf55b4b57390bf0a8f.setContent(html_636ea77a9fe21a7a335bb3920c3f95aa);
#
#
#
#         marker_700dd5c76fb6b75be0ee74023abdbd87.bindPopup(popup_0b527f2ce874f7bf55b4b57390bf0a8f)
#         ;
#
#
#
#
#             var marker_d07fc2b3f95963c8796968ccabcd6c28 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c9fa6f353adaf4f8ce80646bc28bdaef);
#
#
#         var popup_a68f229dd14f8bbec474b7deadec31ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adec48b84ec3aeb46ed33c60c8118172 = $(`&lt;div id=&quot;html_adec48b84ec3aeb46ed33c60c8118172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a68f229dd14f8bbec474b7deadec31ed.setContent(html_adec48b84ec3aeb46ed33c60c8118172);
#
#
#
#         marker_d07fc2b3f95963c8796968ccabcd6c28.bindPopup(popup_a68f229dd14f8bbec474b7deadec31ed)
#         ;
#
#
#
#
#             var marker_67568f1e5587ff286722c4fc8a659cb1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c9fa6f353adaf4f8ce80646bc28bdaef);
#
#
#         var popup_3833198d1ac8a096375fcef811c7735e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea47108879f4d66c5094456e884fd0d = $(`&lt;div id=&quot;html_bea47108879f4d66c5094456e884fd0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3833198d1ac8a096375fcef811c7735e.setContent(html_bea47108879f4d66c5094456e884fd0d);
#
#
#
#         marker_67568f1e5587ff286722c4fc8a659cb1.bindPopup(popup_3833198d1ac8a096375fcef811c7735e)
#         ;
#
#
#
#
#             var marker_4a2b25b6d335a1ee57c8cf870ac029e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c9fa6f353adaf4f8ce80646bc28bdaef);
#
#
#         var popup_e4261dbc67b6e1bbdf351061eeaecdc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173b955c9692578d0b83756c790db24c = $(`&lt;div id=&quot;html_173b955c9692578d0b83756c790db24c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e4261dbc67b6e1bbdf351061eeaecdc3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5804d7fc4484688ac8c7c34e7121cd5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5804d7fc4484688ac8c7c34e7121cd5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5804d7fc4484688ac8c7c34e7121cd5e = L.map(
#                 &quot;map_5804d7fc4484688ac8c7c34e7121cd5e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_911a48801ae492978de3a909668a3a05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_911a48801ae492978de3a909668a3a05.addTo(map_5804d7fc4484688ac8c7c34e7121cd5e);
#
#
#             var feature_group_6c1291ea880166f87702f193a0882242 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bbf3e9493303d85ab05808b889194695 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6c1291ea880166f87702f193a0882242);
#
#
#         var popup_3203b10cb83b5f3226f3c832f543ce7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8080241e28cef8987b20fb49df9b7004 = $(`&lt;div id=&quot;html_8080241e28cef8987b20fb49df9b7004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3203b10cb83b5f3226f3c832f543ce7b.setContent(html_8080241e28cef8987b20fb49df9b7004);
#
#
#
#         marker_bbf3e9493303d85ab05808b889194695.bindPopup(popup_3203b10cb83b5f3226f3c832f543ce7b)
#         ;
#
#
#
#
#             var marker_49d8bfa79e6712ca80a5fc131764e859 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6c1291ea880166f87702f193a0882242);
#
#
#         var popup_110eb1d70f30984a27e5d7830644d146 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a4f026b9d5bc8fd401f498ee200e738 = $(`&lt;div id=&quot;html_6a4f026b9d5bc8fd401f498ee200e738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_110eb1d70f30984a27e5d7830644d146.setContent(html_6a4f026b9d5bc8fd401f498ee200e738);
#
#
#
#         marker_49d8bfa79e6712ca80a5fc131764e859.bindPopup(popup_110eb1d70f30984a27e5d7830644d146)
#         ;
#
#
#
#
#             var marker_5f87116e60839547cbabcb6c1c776fd3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6c1291ea880166f87702f193a0882242);
#
#
#         var popup_4d6e0acec4ca129625bfa810487dd61c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eedefcdb0026d80b63e0b6ccde48d446 = $(`&lt;div id=&quot;html_eedefcdb0026d80b63e0b6ccde48d446&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4d6e0acec4ca129625bfa810487dd61c.setContent(html_eedefcdb0026d80b63e0b6ccde48d446);
#
#
#
#         marker_5f87116e60839547cbabcb6c1c776fd3.bindPopup(popup_4d6e0acec4ca129625bfa810487dd61c)
#         ;
#
#
#
#
#             var marker_8634ab02619302d7cd8688454fcecb90 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6c1291ea880166f87702f193a0882242);
#
#
#         var popup_5fb61f24bffbe74adb0032805620abb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f83957e0f897439318fed6760186573a = $(`&lt;div id=&quot;html_f83957e0f897439318fed6760186573a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5fb61f24bffbe74adb0032805620abb3.setContent(html_f83957e0f897439318fed6760186573a);
#
#
#
#         marker_8634ab02619302d7cd8688454fcecb90.bindPopup(popup_5fb61f24bffbe74adb0032805620abb3)
#         ;
#
#
#
#
#             var marker_b6332fa1f9f416b8e8a3efa00c0f758d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6c1291ea880166f87702f193a0882242);
#
#
#         var popup_ddebbe5fa79eabcce8b5293eb05a0c6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4572bdf727e047d157f9d38ca531e6b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4572bdf727e047d157f9d38ca531e6b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4572bdf727e047d157f9d38ca531e6b6 = L.map(
#                 &quot;map_4572bdf727e047d157f9d38ca531e6b6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61b68f95a9915ece534a44a165277441 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61b68f95a9915ece534a44a165277441.addTo(map_4572bdf727e047d157f9d38ca531e6b6);
#
#
#             var feature_group_4bb7fe3b549f1865c900f0dee2ba0a0f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4bb7fe3b549f1865c900f0dee2ba0a0f.addTo(map_4572bdf727e047d157f9d38ca531e6b6);
#
#
#             var feature_group_sub_group_cec386eb7835dff7ba1574156c68d0bc = L.featureGroup.subGroup(
#                 feature_group_4bb7fe3b549f1865c900f0dee2ba0a0f
#             );
#
#
#             var marker_f6585ea8c637b180dca0ac324e54521d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cec386eb7835dff7ba1574156c68d0bc);
#
#
#         var popup_79e72af7448d89605c8218c8be64cfcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2e131c33faa0b511d3fb01e653f315c = $(`&lt;div id=&quot;html_b2e131c33faa0b511d3fb01e653f315c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_79e72af7448d89605c8218c8be64cfcd.setContent(html_b2e131c33faa0b511d3fb01e653f315c);
#
#
#
#         marker_f6585ea8c637b180dca0ac324e54521d.bindPopup(popup_79e72af7448d89605c8218c8be64cfcd)
#         ;
#
#
#
#
#             var marker_bdd35d95055809032dd9d0b1148c2d2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cec386eb7835dff7ba1574156c68d0bc);
#
#
#         var popup_af622ad259e70a6341e4ecb9cb9670d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b067caa1f4f576811beaf3c22e1bdea = $(`&lt;div id=&quot;html_9b067caa1f4f576811beaf3c22e1bdea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_af622ad259e70a6341e4ecb9cb9670d6.setContent(html_9b067caa1f4f576811beaf3c22e1bdea);
#
#
#
#         marker_bdd35d95055809032dd9d0b1148c2d2f.bindPopup(popup_af622ad259e70a6341e4ecb9cb9670d6)
#         ;
#
#
#
#
#             var marker_1e75cdedff44738e988591ee59748881 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cec386eb7835dff7ba1574156c68d0bc);
#
#
#         var popup_179159d9d39397ff9bab594c9d01b566 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12714cbca986ed9ad259faf320a1656e = $(`&lt;div id=&quot;html_12714cbca986ed9ad259faf320a1656e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_179159d9d39397ff9bab594c9d01b566.setContent(html_12714cbca986ed9ad259faf320a1656e);
#
#
#
#         marker_1e75cdedff44738e988591ee59748881.bindPopup(popup_179159d9d39397ff9bab594c9d01b566)
#         ;
#
#
#
#
#             var marker_aebb69258d13acb04ccf5cb77990053c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cec386eb7835dff7ba1574156c68d0bc);
#
#
#         var popup_8fce94e49bd34a857775634f53c7e03a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b5addad5acfb19b7f97d50710b924ee = $(`&lt;div id=&quot;html_4b5addad5acfb19b7f97d50710b924ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8fce94e49bd34a857775634f53c7e03a.setContent(html_4b5addad5acfb19b7f97d50710b924ee);
#
#
#
#         marker_
