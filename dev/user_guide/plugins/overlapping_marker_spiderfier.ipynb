# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9b2926be1f064775725bc4d4f6e7a18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9b2926be1f064775725bc4d4f6e7a18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9b2926be1f064775725bc4d4f6e7a18 = L.map(
#                 &quot;map_f9b2926be1f064775725bc4d4f6e7a18&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b814f4529698f1ba2d0aa6d6fd3d266 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b814f4529698f1ba2d0aa6d6fd3d266.addTo(map_f9b2926be1f064775725bc4d4f6e7a18);
#
#
#             var marker_fad6dbd8836be85171da84c8cce340a5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f9b2926be1f064775725bc4d4f6e7a18);
#
#
#         var popup_6ce750fc5782ddd686d82c16f19b0eb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1200c1a977f900402d06c7898808be39 = $(`&lt;div id=&quot;html_1200c1a977f900402d06c7898808be39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6ce750fc5782ddd686d82c16f19b0eb4.setContent(html_1200c1a977f900402d06c7898808be39);
#
#
#
#         marker_fad6dbd8836be85171da84c8cce340a5.bindPopup(popup_6ce750fc5782ddd686d82c16f19b0eb4)
#         ;
#
#
#
#
#             var marker_5757624319572c3f21069053c1a2012c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f9b2926be1f064775725bc4d4f6e7a18);
#
#
#         var popup_66a7364b49f5e8aee61d383b7f6df67d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aca72c3fe61429f05f68a79d76d3021b = $(`&lt;div id=&quot;html_aca72c3fe61429f05f68a79d76d3021b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_66a7364b49f5e8aee61d383b7f6df67d.setContent(html_aca72c3fe61429f05f68a79d76d3021b);
#
#
#
#         marker_5757624319572c3f21069053c1a2012c.bindPopup(popup_66a7364b49f5e8aee61d383b7f6df67d)
#         ;
#
#
#
#
#             var marker_0874d0ca5cf9b6421503817dd23b44da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f9b2926be1f064775725bc4d4f6e7a18);
#
#
#         var popup_5b52f84114999ec97c02b2006a0cc558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81d667f36b35c58b0a3304325a2266d3 = $(`&lt;div id=&quot;html_81d667f36b35c58b0a3304325a2266d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5b52f84114999ec97c02b2006a0cc558.setContent(html_81d667f36b35c58b0a3304325a2266d3);
#
#
#
#         marker_0874d0ca5cf9b6421503817dd23b44da.bindPopup(popup_5b52f84114999ec97c02b2006a0cc558)
#         ;
#
#
#
#
#             var marker_3abc1879512d4c59b8f89ee3eb6a48eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f9b2926be1f064775725bc4d4f6e7a18);
#
#
#         var popup_786c7e14d09ec104dd164d7fd9f19f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_544158d439d984955fab65916282ba69 = $(`&lt;div id=&quot;html_544158d439d984955fab65916282ba69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_786c7e14d09ec104dd164d7fd9f19f45.setContent(html_544158d439d984955fab65916282ba69);
#
#
#
#         marker_3abc1879512d4c59b8f89ee3eb6a48eb.bindPopup(popup_786c7e14d09ec104dd164d7fd9f19f45)
#         ;
#
#
#
#
#             var marker_39fe729dc227bb80a7a04132281dce31 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f9b2926be1f064775725bc4d4f6e7a18);
#
#
#         var popup_d8e9e6fbed6eaeda11ace976f0d7bed5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_453dc74d29d087e8956eabd5a1dd6ab9 = $(`&lt;div id=&quot;html_453dc74d29d087e8956eabd5a1dd6ab9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d8e9e6fbed6eaeda11ace976f0d7bed5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f4fa3aeb8829992ad4d5bc1a948694f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f4fa3aeb8829992ad4d5bc1a948694f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f4fa3aeb8829992ad4d5bc1a948694f = L.map(
#                 &quot;map_5f4fa3aeb8829992ad4d5bc1a948694f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7492c9ed2290737756abd78afdb94c2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7492c9ed2290737756abd78afdb94c2f.addTo(map_5f4fa3aeb8829992ad4d5bc1a948694f);
#
#
#             var feature_group_4f53f1ee367d6d42546b3ffb2c5c2697 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2b9655e5a85f31d1c34b386f6897522 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4f53f1ee367d6d42546b3ffb2c5c2697);
#
#
#         var popup_79c3b759d9d696ba684be74d391a6915 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b00022c4720ef7b21f743649a90f7e5 = $(`&lt;div id=&quot;html_6b00022c4720ef7b21f743649a90f7e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_79c3b759d9d696ba684be74d391a6915.setContent(html_6b00022c4720ef7b21f743649a90f7e5);
#
#
#
#         marker_b2b9655e5a85f31d1c34b386f6897522.bindPopup(popup_79c3b759d9d696ba684be74d391a6915)
#         ;
#
#
#
#
#             var marker_5a0ea93f199f39eb8999c1620cc1de1c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4f53f1ee367d6d42546b3ffb2c5c2697);
#
#
#         var popup_385289e1529e39660c887ec24359c1d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c0006fd49c38d1f61e5b5fd8707e4ca = $(`&lt;div id=&quot;html_9c0006fd49c38d1f61e5b5fd8707e4ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_385289e1529e39660c887ec24359c1d0.setContent(html_9c0006fd49c38d1f61e5b5fd8707e4ca);
#
#
#
#         marker_5a0ea93f199f39eb8999c1620cc1de1c.bindPopup(popup_385289e1529e39660c887ec24359c1d0)
#         ;
#
#
#
#
#             var marker_34b1a4ae29880dc37b16beff7a663dab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4f53f1ee367d6d42546b3ffb2c5c2697);
#
#
#         var popup_7f70e0b7b48974460d3561894fe6fbb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d3d16c5517c2e25506708c1f195e9e7 = $(`&lt;div id=&quot;html_1d3d16c5517c2e25506708c1f195e9e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7f70e0b7b48974460d3561894fe6fbb5.setContent(html_1d3d16c5517c2e25506708c1f195e9e7);
#
#
#
#         marker_34b1a4ae29880dc37b16beff7a663dab.bindPopup(popup_7f70e0b7b48974460d3561894fe6fbb5)
#         ;
#
#
#
#
#             var marker_b013bdd9ae8c0f39f58ea3860f168b75 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4f53f1ee367d6d42546b3ffb2c5c2697);
#
#
#         var popup_150589d346650cd6e082b1bf1bb5c4f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c68964a4ada946b6149192f6cff16d6c = $(`&lt;div id=&quot;html_c68964a4ada946b6149192f6cff16d6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_150589d346650cd6e082b1bf1bb5c4f4.setContent(html_c68964a4ada946b6149192f6cff16d6c);
#
#
#
#         marker_b013bdd9ae8c0f39f58ea3860f168b75.bindPopup(popup_150589d346650cd6e082b1bf1bb5c4f4)
#         ;
#
#
#
#
#             var marker_ba27caf82e062020a77e2442b3a493e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4f53f1ee367d6d42546b3ffb2c5c2697);
#
#
#         var popup_1d673051ff141dacbac7d9e40668ed2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08157774e3ae813ddd47e904bdfc4fe4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08157774e3ae813ddd47e904bdfc4fe4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08157774e3ae813ddd47e904bdfc4fe4 = L.map(
#                 &quot;map_08157774e3ae813ddd47e904bdfc4fe4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_547fc7307f1bbc50a5cfc6637d0476d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_547fc7307f1bbc50a5cfc6637d0476d1.addTo(map_08157774e3ae813ddd47e904bdfc4fe4);
#
#
#             var feature_group_a049b2b86b4be878d669c5faf8ce8a83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a049b2b86b4be878d669c5faf8ce8a83.addTo(map_08157774e3ae813ddd47e904bdfc4fe4);
#
#
#             var feature_group_sub_group_3ac415959c3d3a62996e22887c45f861 = L.featureGroup.subGroup(
#                 feature_group_a049b2b86b4be878d669c5faf8ce8a83
#             );
#
#
#             var marker_241901a9887a6cb56608de30d3c404a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ac415959c3d3a62996e22887c45f861);
#
#
#         var popup_e34c51a4505ce2d69ecf70082b23ec20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ddd8f96e8bda081c4786c881246bf12 = $(`&lt;div id=&quot;html_3ddd8f96e8bda081c4786c881246bf12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e34c51a4505ce2d69ecf70082b23ec20.setContent(html_3ddd8f96e8bda081c4786c881246bf12);
#
#
#
#         marker_241901a9887a6cb56608de30d3c404a2.bindPopup(popup_e34c51a4505ce2d69ecf70082b23ec20)
#         ;
#
#
#
#
#             var marker_d346a8d62d658af567e6316c3d2c29d9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ac415959c3d3a62996e22887c45f861);
#
#
#         var popup_431d6567c1899bea9ea87e4defb8d886 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9932bb18344ba0ef1359ae7d1abec2c = $(`&lt;div id=&quot;html_d9932bb18344ba0ef1359ae7d1abec2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_431d6567c1899bea9ea87e4defb8d886.setContent(html_d9932bb18344ba0ef1359ae7d1abec2c);
#
#
#
#         marker_d346a8d62d658af567e6316c3d2c29d9.bindPopup(popup_431d6567c1899bea9ea87e4defb8d886)
#         ;
#
#
#
#
#             var marker_e72fc8b88457fd6f9322599b80428680 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ac415959c3d3a62996e22887c45f861);
#
#
#         var popup_bba65738bedd0c53e850d033ab8cd097 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed3dd2485149c2031bd0bcd21387b9fb = $(`&lt;div id=&quot;html_ed3dd2485149c2031bd0bcd21387b9fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bba65738bedd0c53e850d033ab8cd097.setContent(html_ed3dd2485149c2031bd0bcd21387b9fb);
#
#
#
#         marker_e72fc8b88457fd6f9322599b80428680.bindPopup(popup_bba65738bedd0c53e850d033ab8cd097)
#         ;
#
#
#
#
#             var marker_a87a79fe53b968290a5dc9684a7b5d2a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ac415959c3d3a62996e22887c45f861);
#
#
#         var popup_e3725841d03f48700eb2ae257f45ca16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcfa51e07e5a6474aaf585cb9f429511 = $(`&lt;div id=&quot;html_dcfa51e07e5a6474aaf585cb9f429511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e3725841d03f48700eb2ae257f45ca16.setContent(html_dcfa51e07e5a6474aaf585cb9f429511);
#
#
#
#         marker_
