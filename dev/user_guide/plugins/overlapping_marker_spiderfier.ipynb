# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd4f7f75306838f9e02d052bc9e42534 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd4f7f75306838f9e02d052bc9e42534&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd4f7f75306838f9e02d052bc9e42534 = L.map(
#                 &quot;map_cd4f7f75306838f9e02d052bc9e42534&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7704485fda3acb9bb33871321648979c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7704485fda3acb9bb33871321648979c.addTo(map_cd4f7f75306838f9e02d052bc9e42534);
#
#
#             var marker_710e153b41b8196660ef4f02a853e219 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cd4f7f75306838f9e02d052bc9e42534);
#
#
#         var popup_2714e9486971332d3bc4bdbb47b32be9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_056354bc27fd32758668cc711e4649f5 = $(`&lt;div id=&quot;html_056354bc27fd32758668cc711e4649f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2714e9486971332d3bc4bdbb47b32be9.setContent(html_056354bc27fd32758668cc711e4649f5);
#
#
#
#         marker_710e153b41b8196660ef4f02a853e219.bindPopup(popup_2714e9486971332d3bc4bdbb47b32be9)
#         ;
#
#
#
#
#             var marker_b36ea2240c38d2aa2d245689036ac58d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cd4f7f75306838f9e02d052bc9e42534);
#
#
#         var popup_ef5ea60fce2fe79cd606faf795f98ed5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_376b9c62a4afef33f1a2bffe4a3a32e3 = $(`&lt;div id=&quot;html_376b9c62a4afef33f1a2bffe4a3a32e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ef5ea60fce2fe79cd606faf795f98ed5.setContent(html_376b9c62a4afef33f1a2bffe4a3a32e3);
#
#
#
#         marker_b36ea2240c38d2aa2d245689036ac58d.bindPopup(popup_ef5ea60fce2fe79cd606faf795f98ed5)
#         ;
#
#
#
#
#             var marker_914096ec9324c60706d2816d71ab8d1a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cd4f7f75306838f9e02d052bc9e42534);
#
#
#         var popup_c7b697414ef22a3da984f3671105adcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4370f91ff708aadc276afc0eecabf565 = $(`&lt;div id=&quot;html_4370f91ff708aadc276afc0eecabf565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c7b697414ef22a3da984f3671105adcc.setContent(html_4370f91ff708aadc276afc0eecabf565);
#
#
#
#         marker_914096ec9324c60706d2816d71ab8d1a.bindPopup(popup_c7b697414ef22a3da984f3671105adcc)
#         ;
#
#
#
#
#             var marker_dd02d5574abb8bfbfaafd50540d07c51 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cd4f7f75306838f9e02d052bc9e42534);
#
#
#         var popup_e526b2e3ccf07d4ca07308ea49c4fc44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa82073979571da717ddbbc33869fa82 = $(`&lt;div id=&quot;html_fa82073979571da717ddbbc33869fa82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e526b2e3ccf07d4ca07308ea49c4fc44.setContent(html_fa82073979571da717ddbbc33869fa82);
#
#
#
#         marker_dd02d5574abb8bfbfaafd50540d07c51.bindPopup(popup_e526b2e3ccf07d4ca07308ea49c4fc44)
#         ;
#
#
#
#
#             var marker_51d55a745b0dc509db6cfdc5bc1cfda5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cd4f7f75306838f9e02d052bc9e42534);
#
#
#         var popup_fe3b9ad727ee019df55aa26179ca71ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bf7e2ee6c4f704d6efc104f2905599a = $(`&lt;div id=&quot;html_7bf7e2ee6c4f704d6efc104f2905599a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fe3b9ad727ee019df55aa26179ca71

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69f33b125991995baa491d0348934247 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69f33b125991995baa491d0348934247&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69f33b125991995baa491d0348934247 = L.map(
#                 &quot;map_69f33b125991995baa491d0348934247&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9d5441cb2584d2f0ec57380f4236e4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9d5441cb2584d2f0ec57380f4236e4d.addTo(map_69f33b125991995baa491d0348934247);
#
#
#             var feature_group_689e888c59a42ff75824951b4b4b5028 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cbaefedf88ab88b2528a51b5b9b144ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_689e888c59a42ff75824951b4b4b5028);
#
#
#         var popup_b111b0fbd6368fbf8ce9a4addc23f157 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b793ab43639dfc4395012223cc9b99c = $(`&lt;div id=&quot;html_3b793ab43639dfc4395012223cc9b99c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b111b0fbd6368fbf8ce9a4addc23f157.setContent(html_3b793ab43639dfc4395012223cc9b99c);
#
#
#
#         marker_cbaefedf88ab88b2528a51b5b9b144ce.bindPopup(popup_b111b0fbd6368fbf8ce9a4addc23f157)
#         ;
#
#
#
#
#             var marker_4bdd739269ef8229f45f57c066338690 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_689e888c59a42ff75824951b4b4b5028);
#
#
#         var popup_85ea5b77f3900fd766dbb02835372c43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_686b3c5af26dc1cf6e8472aaec7e2b8d = $(`&lt;div id=&quot;html_686b3c5af26dc1cf6e8472aaec7e2b8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_85ea5b77f3900fd766dbb02835372c43.setContent(html_686b3c5af26dc1cf6e8472aaec7e2b8d);
#
#
#
#         marker_4bdd739269ef8229f45f57c066338690.bindPopup(popup_85ea5b77f3900fd766dbb02835372c43)
#         ;
#
#
#
#
#             var marker_b8b6a19e390b0be25310ca7732e08395 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_689e888c59a42ff75824951b4b4b5028);
#
#
#         var popup_804fe5851e5cf4a965ae6792370bc6b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_210ca4b3c9ddca202cb683e16e11004a = $(`&lt;div id=&quot;html_210ca4b3c9ddca202cb683e16e11004a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_804fe5851e5cf4a965ae6792370bc6b0.setContent(html_210ca4b3c9ddca202cb683e16e11004a);
#
#
#
#         marker_b8b6a19e390b0be25310ca7732e08395.bindPopup(popup_804fe5851e5cf4a965ae6792370bc6b0)
#         ;
#
#
#
#
#             var marker_d3fa1161b4ef305bb3bf2a1b0ae5328d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_689e888c59a42ff75824951b4b4b5028);
#
#
#         var popup_3c999b36a1d492ffbc3e4c7c8650f365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d453e4ab9fa0ed156ec9792b63e9631e = $(`&lt;div id=&quot;html_d453e4ab9fa0ed156ec9792b63e9631e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c999b36a1d492ffbc3e4c7c8650f365.setContent(html_d453e4ab9fa0ed156ec9792b63e9631e);
#
#
#
#         marker_d3fa1161b4ef305bb3bf2a1b0ae5328d.bindPopup(popup_3c999b36a1d492ffbc3e4c7c8650f365)
#         ;
#
#
#
#
#             var marker_52d8ec089fbf77844142c4c7cef15273 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_689e888c59a42ff75824951b4b4b5028);
#
#
#         var popup_ebd052bfbb71030b7ec775428cb71067 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f549773c326e76b7ca5e35191b3d0d83 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f549773c326e76b7ca5e35191b3d0d83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f549773c326e76b7ca5e35191b3d0d83 = L.map(
#                 &quot;map_f549773c326e76b7ca5e35191b3d0d83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2744a951e043966c0ef8d448968625b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2744a951e043966c0ef8d448968625b8.addTo(map_f549773c326e76b7ca5e35191b3d0d83);
#
#
#             var feature_group_f4759d4ed69e0ddec71234fbb05fc564 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f4759d4ed69e0ddec71234fbb05fc564.addTo(map_f549773c326e76b7ca5e35191b3d0d83);
#
#
#             var feature_group_sub_group_2522dddadb56898f5bf2705742199d8e = L.featureGroup.subGroup(
#                 feature_group_f4759d4ed69e0ddec71234fbb05fc564
#             );
#
#
#             var marker_dd220b2e645686e407de70e5f0184097 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2522dddadb56898f5bf2705742199d8e);
#
#
#         var popup_ee2679ecc66a619610f84bfaa248ed05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f5758f429f91c6fc98f7bc5051c6cdc = $(`&lt;div id=&quot;html_6f5758f429f91c6fc98f7bc5051c6cdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ee2679ecc66a619610f84bfaa248ed05.setContent(html_6f5758f429f91c6fc98f7bc5051c6cdc);
#
#
#
#         marker_dd220b2e645686e407de70e5f0184097.bindPopup(popup_ee2679ecc66a619610f84bfaa248ed05)
#         ;
#
#
#
#
#             var marker_187fe8ccd5cc72eca161c4aec6657580 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2522dddadb56898f5bf2705742199d8e);
#
#
#         var popup_9f10d1dbebcc1b57fb69651f1513d52a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e466496a19558180b21686751c2aa8a = $(`&lt;div id=&quot;html_8e466496a19558180b21686751c2aa8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9f10d1dbebcc1b57fb69651f1513d52a.setContent(html_8e466496a19558180b21686751c2aa8a);
#
#
#
#         marker_187fe8ccd5cc72eca161c4aec6657580.bindPopup(popup_9f10d1dbebcc1b57fb69651f1513d52a)
#         ;
#
#
#
#
#             var marker_7931dc56cd2bedf5ba314d29fa1b08f1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2522dddadb56898f5bf2705742199d8e);
#
#
#         var popup_c5a876585767e29e98cc397c1ef31901 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d638115fb21a8f9d7751d3bde5d77bf = $(`&lt;div id=&quot;html_6d638115fb21a8f9d7751d3bde5d77bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c5a876585767e29e98cc397c1ef31901.setContent(html_6d638115fb21a8f9d7751d3bde5d77bf);
#
#
#
#         marker_7931dc56cd2bedf5ba314d29fa1b08f1.bindPopup(popup_c5a876585767e29e98cc397c1ef31901)
#         ;
#
#
#
#
#             var marker_fc060485ce07cbe2a44318cb45d8f8da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2522dddadb56898f5bf2705742199d8e);
#
#
#         var popup_bbcfede6a533ab2d7b3a3625a842696a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1ef7c7cfa491be9d70f8b3cd3f98ffd = $(`&lt;div id=&quot;html_b1ef7c7cfa491be9d70f8b3cd3f98ffd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bbcfede6a533ab2d7b3a3625a842696a.setContent(html_b1ef7c7cfa491be9d70f8b3cd3f98ffd);
#
#
#
#         mark
