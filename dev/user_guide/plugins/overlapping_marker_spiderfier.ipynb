# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9aa845d25eb624874d9dd8bab56b8524 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9aa845d25eb624874d9dd8bab56b8524&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9aa845d25eb624874d9dd8bab56b8524 = L.map(
#                 &quot;map_9aa845d25eb624874d9dd8bab56b8524&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af34a87bd447ec6ef26b3fa9d38e70c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af34a87bd447ec6ef26b3fa9d38e70c2.addTo(map_9aa845d25eb624874d9dd8bab56b8524);
#
#
#             var marker_d2626ddfd39a07891e299daf5852f3eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9aa845d25eb624874d9dd8bab56b8524);
#
#
#         var popup_4efdb89e6e8996992cb25fa066442ed6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d8c41a29f08cf153dbf4219abbb1009 = $(`&lt;div id=&quot;html_7d8c41a29f08cf153dbf4219abbb1009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4efdb89e6e8996992cb25fa066442ed6.setContent(html_7d8c41a29f08cf153dbf4219abbb1009);
#
#
#
#         marker_d2626ddfd39a07891e299daf5852f3eb.bindPopup(popup_4efdb89e6e8996992cb25fa066442ed6)
#         ;
#
#
#
#
#             var marker_22dbda4eaf4301e7ed1fbe6c8cd195ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9aa845d25eb624874d9dd8bab56b8524);
#
#
#         var popup_5e526a9c1acb51764657d671b9a20bf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd6c4838a5398d73f6203c3dd4c7a4ec = $(`&lt;div id=&quot;html_fd6c4838a5398d73f6203c3dd4c7a4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5e526a9c1acb51764657d671b9a20bf4.setContent(html_fd6c4838a5398d73f6203c3dd4c7a4ec);
#
#
#
#         marker_22dbda4eaf4301e7ed1fbe6c8cd195ae.bindPopup(popup_5e526a9c1acb51764657d671b9a20bf4)
#         ;
#
#
#
#
#             var marker_34493b7f62a4daafb0ec8060a54fef66 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9aa845d25eb624874d9dd8bab56b8524);
#
#
#         var popup_15c7619dbf8a3655b30737e49f168716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7efaae70f5565d5c74a577bb1daf27a6 = $(`&lt;div id=&quot;html_7efaae70f5565d5c74a577bb1daf27a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_15c7619dbf8a3655b30737e49f168716.setContent(html_7efaae70f5565d5c74a577bb1daf27a6);
#
#
#
#         marker_34493b7f62a4daafb0ec8060a54fef66.bindPopup(popup_15c7619dbf8a3655b30737e49f168716)
#         ;
#
#
#
#
#             var marker_9547ffb0c31cc41de1479d6bcdd27b4e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9aa845d25eb624874d9dd8bab56b8524);
#
#
#         var popup_f4cdb00798d5168e7f66abb5d925a6ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4341695241493c46e2519949b78d70 = $(`&lt;div id=&quot;html_6e4341695241493c46e2519949b78d70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f4cdb00798d5168e7f66abb5d925a6ef.setContent(html_6e4341695241493c46e2519949b78d70);
#
#
#
#         marker_9547ffb0c31cc41de1479d6bcdd27b4e.bindPopup(popup_f4cdb00798d5168e7f66abb5d925a6ef)
#         ;
#
#
#
#
#             var marker_b1177ace55fe302e9d310e6368b22810 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9aa845d25eb624874d9dd8bab56b8524);
#
#
#         var popup_62bf237bbafe75d3bd0be582c5961495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0500fc7ccc54877e4893d8de54c6047 = $(`&lt;div id=&quot;html_b0500fc7ccc54877e4893d8de54c6047&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_62bf237bbafe75d3bd0be582c5961495.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_862984ca1bfe7078cd46bfb11702de7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_862984ca1bfe7078cd46bfb11702de7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_862984ca1bfe7078cd46bfb11702de7c = L.map(
#                 &quot;map_862984ca1bfe7078cd46bfb11702de7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a565806df71418eca025d2cd2998dbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a565806df71418eca025d2cd2998dbc.addTo(map_862984ca1bfe7078cd46bfb11702de7c);
#
#
#             var feature_group_4e82ff01e146afcd85942cdef0e5893a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_75ddc1fc9b4e018a0dce0197354ec1aa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4e82ff01e146afcd85942cdef0e5893a);
#
#
#         var popup_06036706af7dce463d592d9ba89045a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf69ea9a2daf357c7e2ed28caa212fb2 = $(`&lt;div id=&quot;html_bf69ea9a2daf357c7e2ed28caa212fb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_06036706af7dce463d592d9ba89045a6.setContent(html_bf69ea9a2daf357c7e2ed28caa212fb2);
#
#
#
#         marker_75ddc1fc9b4e018a0dce0197354ec1aa.bindPopup(popup_06036706af7dce463d592d9ba89045a6)
#         ;
#
#
#
#
#             var marker_cd493cca6123d4707257cf16d71a4b97 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4e82ff01e146afcd85942cdef0e5893a);
#
#
#         var popup_5d6949343c673db932aaf37fc54d4a39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_556e6af4541e2e96c39dbb785e0869f0 = $(`&lt;div id=&quot;html_556e6af4541e2e96c39dbb785e0869f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5d6949343c673db932aaf37fc54d4a39.setContent(html_556e6af4541e2e96c39dbb785e0869f0);
#
#
#
#         marker_cd493cca6123d4707257cf16d71a4b97.bindPopup(popup_5d6949343c673db932aaf37fc54d4a39)
#         ;
#
#
#
#
#             var marker_35ad8516b48870b65b711d64c40f0f32 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4e82ff01e146afcd85942cdef0e5893a);
#
#
#         var popup_beb8c02a6dd961fa7e19adab4c706af9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7aa49574e5ceb1a05d0d01540d728bd4 = $(`&lt;div id=&quot;html_7aa49574e5ceb1a05d0d01540d728bd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_beb8c02a6dd961fa7e19adab4c706af9.setContent(html_7aa49574e5ceb1a05d0d01540d728bd4);
#
#
#
#         marker_35ad8516b48870b65b711d64c40f0f32.bindPopup(popup_beb8c02a6dd961fa7e19adab4c706af9)
#         ;
#
#
#
#
#             var marker_c21d1836ec1be53eee1c176758bfbe10 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4e82ff01e146afcd85942cdef0e5893a);
#
#
#         var popup_688416898a26fd7e43b4c6ad1f80900d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_351e6b95b4a38f8a0e6617a9208c63be = $(`&lt;div id=&quot;html_351e6b95b4a38f8a0e6617a9208c63be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_688416898a26fd7e43b4c6ad1f80900d.setContent(html_351e6b95b4a38f8a0e6617a9208c63be);
#
#
#
#         marker_c21d1836ec1be53eee1c176758bfbe10.bindPopup(popup_688416898a26fd7e43b4c6ad1f80900d)
#         ;
#
#
#
#
#             var marker_00b204ae7ea90c6b5e2e2908f76ca809 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4e82ff01e146afcd85942cdef0e5893a);
#
#
#         var popup_17e7411ed37d52b4c5885a2c1f5b9bcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78ab7ac10c0523b3ba558f905d9c7512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78ab7ac10c0523b3ba558f905d9c7512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78ab7ac10c0523b3ba558f905d9c7512 = L.map(
#                 &quot;map_78ab7ac10c0523b3ba558f905d9c7512&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_286a58b388ef78b754c8ea284bb0afea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_286a58b388ef78b754c8ea284bb0afea.addTo(map_78ab7ac10c0523b3ba558f905d9c7512);
#
#
#             var feature_group_24d0bd165fee7f98206cdb44778eb675 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_24d0bd165fee7f98206cdb44778eb675.addTo(map_78ab7ac10c0523b3ba558f905d9c7512);
#
#
#             var feature_group_sub_group_7e9045476d83bdd9b8376ba465aff601 = L.featureGroup.subGroup(
#                 feature_group_24d0bd165fee7f98206cdb44778eb675
#             );
#
#
#             var marker_e223ab0070301fae378c1d24f739972a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e9045476d83bdd9b8376ba465aff601);
#
#
#         var popup_83179cf7d3daaddb002b25fbff174771 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_202df0cd9d51f0574b3164147b051a6d = $(`&lt;div id=&quot;html_202df0cd9d51f0574b3164147b051a6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_83179cf7d3daaddb002b25fbff174771.setContent(html_202df0cd9d51f0574b3164147b051a6d);
#
#
#
#         marker_e223ab0070301fae378c1d24f739972a.bindPopup(popup_83179cf7d3daaddb002b25fbff174771)
#         ;
#
#
#
#
#             var marker_ea5a5060ed582fbe8ec980569fa69ca5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e9045476d83bdd9b8376ba465aff601);
#
#
#         var popup_696e6626d5dc5d0c9081120637a5d4ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f96b382ee547c9e277a75c11142b0b4a = $(`&lt;div id=&quot;html_f96b382ee547c9e277a75c11142b0b4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_696e6626d5dc5d0c9081120637a5d4ce.setContent(html_f96b382ee547c9e277a75c11142b0b4a);
#
#
#
#         marker_ea5a5060ed582fbe8ec980569fa69ca5.bindPopup(popup_696e6626d5dc5d0c9081120637a5d4ce)
#         ;
#
#
#
#
#             var marker_2ef47ac9973d6d5e2f8b41ec9fe1bc98 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e9045476d83bdd9b8376ba465aff601);
#
#
#         var popup_4f1346d205752c173a0bf5254a476d86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_879ea2720e4ed87f7eaa3815eaf5a95b = $(`&lt;div id=&quot;html_879ea2720e4ed87f7eaa3815eaf5a95b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4f1346d205752c173a0bf5254a476d86.setContent(html_879ea2720e4ed87f7eaa3815eaf5a95b);
#
#
#
#         marker_2ef47ac9973d6d5e2f8b41ec9fe1bc98.bindPopup(popup_4f1346d205752c173a0bf5254a476d86)
#         ;
#
#
#
#
#             var marker_b8f300a54f74946c295201ede80a35a0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e9045476d83bdd9b8376ba465aff601);
#
#
#         var popup_a7137e9284c3e54b938b1fa9da6c7463 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_692d60395794008121789e81728c429b = $(`&lt;div id=&quot;html_692d60395794008121789e81728c429b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a7137e9284c3e54b938b1fa9da6c7463.setContent(html_692d60395794008121789e81728c429b);
#
#
#
#         marker_
