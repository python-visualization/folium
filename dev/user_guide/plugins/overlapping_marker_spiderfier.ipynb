# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_116847e89c07add88a996a9385e9a01f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_116847e89c07add88a996a9385e9a01f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_116847e89c07add88a996a9385e9a01f = L.map(
#                 &quot;map_116847e89c07add88a996a9385e9a01f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92f969ff70e200f68910bc66830aa598 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92f969ff70e200f68910bc66830aa598.addTo(map_116847e89c07add88a996a9385e9a01f);
#
#
#             var marker_3e5284514e486a851e69fb9fe9dfc52b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_116847e89c07add88a996a9385e9a01f);
#
#
#         var popup_702eee06768f7b0079d9b4db515df4d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_412788eb6d918ce9016d4545c946df8b = $(`&lt;div id=&quot;html_412788eb6d918ce9016d4545c946df8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_702eee06768f7b0079d9b4db515df4d3.setContent(html_412788eb6d918ce9016d4545c946df8b);
#
#
#
#         marker_3e5284514e486a851e69fb9fe9dfc52b.bindPopup(popup_702eee06768f7b0079d9b4db515df4d3)
#         ;
#
#
#
#
#             var marker_766adb6fd5686fd1a933f698782de7be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_116847e89c07add88a996a9385e9a01f);
#
#
#         var popup_c45a5372aede0d948480b61214ecd49c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9790ad4e908b6168ceaf581b7946bf5 = $(`&lt;div id=&quot;html_f9790ad4e908b6168ceaf581b7946bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c45a5372aede0d948480b61214ecd49c.setContent(html_f9790ad4e908b6168ceaf581b7946bf5);
#
#
#
#         marker_766adb6fd5686fd1a933f698782de7be.bindPopup(popup_c45a5372aede0d948480b61214ecd49c)
#         ;
#
#
#
#
#             var marker_dfc3e1fe214b7bb275eb19fbbbcc8f0d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_116847e89c07add88a996a9385e9a01f);
#
#
#         var popup_b022a3b43b1dc98a60f1bff26268ce12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4cf275f9ad1f8a68c57cb90506d6131 = $(`&lt;div id=&quot;html_c4cf275f9ad1f8a68c57cb90506d6131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b022a3b43b1dc98a60f1bff26268ce12.setContent(html_c4cf275f9ad1f8a68c57cb90506d6131);
#
#
#
#         marker_dfc3e1fe214b7bb275eb19fbbbcc8f0d.bindPopup(popup_b022a3b43b1dc98a60f1bff26268ce12)
#         ;
#
#
#
#
#             var marker_f28116584a0505fc0c98daba94054dd2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_116847e89c07add88a996a9385e9a01f);
#
#
#         var popup_0fa6080b9e5ae77411ccf5a7cb8004b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f838c888bfdc396f91fe8fc74e77afb = $(`&lt;div id=&quot;html_1f838c888bfdc396f91fe8fc74e77afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0fa6080b9e5ae77411ccf5a7cb8004b2.setContent(html_1f838c888bfdc396f91fe8fc74e77afb);
#
#
#
#         marker_f28116584a0505fc0c98daba94054dd2.bindPopup(popup_0fa6080b9e5ae77411ccf5a7cb8004b2)
#         ;
#
#
#
#
#             var marker_b90a629db3ae4070401d43860a4b66b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_116847e89c07add88a996a9385e9a01f);
#
#
#         var popup_e5792bedf8b20e1917d4e294f68268f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43c4cd7e62b3bb89847f30eb967755d6 = $(`&lt;div id=&quot;html_43c4cd7e62b3bb89847f30eb967755d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e5792bedf8b20e1917d4e294f68268f8.setContent(html_43c4cd7e62b3bb89847f30eb967755d6);
#
#
#
#         marker_b90a629db3ae4070401d43860a4b66b6.bindPopup(popup_e5792bedf8b20e1917d4e294f68268f8)
#         ;
#
#
#
#
#             var marker_52428070a3

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea79156da04c6d1c3223f486204b5e47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea79156da04c6d1c3223f486204b5e47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea79156da04c6d1c3223f486204b5e47 = L.map(
#                 &quot;map_ea79156da04c6d1c3223f486204b5e47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04950ecbfef14197bfc34fcb296ab323 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04950ecbfef14197bfc34fcb296ab323.addTo(map_ea79156da04c6d1c3223f486204b5e47);
#
#
#             var feature_group_42e5f7850410e6eeefe06bf919daf4c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4fd586e3f71e5303161611665e0cfe28 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_42e5f7850410e6eeefe06bf919daf4c9);
#
#
#         var popup_7d99b022a8ec81450ea53a0e0ac38de2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf92d89134659d58b442990c055c929a = $(`&lt;div id=&quot;html_cf92d89134659d58b442990c055c929a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7d99b022a8ec81450ea53a0e0ac38de2.setContent(html_cf92d89134659d58b442990c055c929a);
#
#
#
#         marker_4fd586e3f71e5303161611665e0cfe28.bindPopup(popup_7d99b022a8ec81450ea53a0e0ac38de2)
#         ;
#
#
#
#
#             var marker_4392f17d11100702dcce6972811f4e2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_42e5f7850410e6eeefe06bf919daf4c9);
#
#
#         var popup_20c17f716fa5ed37701e171b6285d341 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49108b25cec1984935aa56beed4d96f9 = $(`&lt;div id=&quot;html_49108b25cec1984935aa56beed4d96f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_20c17f716fa5ed37701e171b6285d341.setContent(html_49108b25cec1984935aa56beed4d96f9);
#
#
#
#         marker_4392f17d11100702dcce6972811f4e2a.bindPopup(popup_20c17f716fa5ed37701e171b6285d341)
#         ;
#
#
#
#
#             var marker_a9bd2f86e83bedc16a442e8f5f4e9e75 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_42e5f7850410e6eeefe06bf919daf4c9);
#
#
#         var popup_fffd172d68ea32a7dd6e98b14415f59f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98ba713ceb2e9dfa4f5784ac82ba3e5f = $(`&lt;div id=&quot;html_98ba713ceb2e9dfa4f5784ac82ba3e5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fffd172d68ea32a7dd6e98b14415f59f.setContent(html_98ba713ceb2e9dfa4f5784ac82ba3e5f);
#
#
#
#         marker_a9bd2f86e83bedc16a442e8f5f4e9e75.bindPopup(popup_fffd172d68ea32a7dd6e98b14415f59f)
#         ;
#
#
#
#
#             var marker_19fcbd7728eab088c630b21d94f95509 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_42e5f7850410e6eeefe06bf919daf4c9);
#
#
#         var popup_33fabd77382d1bb20dbf4e34ac98c2df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9039bfe60a8a2d214204a47f7a4bc69 = $(`&lt;div id=&quot;html_c9039bfe60a8a2d214204a47f7a4bc69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_33fabd77382d1bb20dbf4e34ac98c2df.setContent(html_c9039bfe60a8a2d214204a47f7a4bc69);
#
#
#
#         marker_19fcbd7728eab088c630b21d94f95509.bindPopup(popup_33fabd77382d1bb20dbf4e34ac98c2df)
#         ;
#
#
#
#
#             var marker_e44ce8687fb2ea8505a1ce200d2e7d25 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_42e5f7850410e6eeefe06bf919daf4c9);
#
#
#         var popup_146376bf0b6e837844a578993ddb246c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a3630d48e8baec7161043649978dc11 = $(`&lt;div id=&quot;html_3a3630d48e8baec7161043649978dc11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_146376bf0b6e837844

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdfb40fb9fc4437a75ee0669b4fb2717 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdfb40fb9fc4437a75ee0669b4fb2717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdfb40fb9fc4437a75ee0669b4fb2717 = L.map(
#                 &quot;map_fdfb40fb9fc4437a75ee0669b4fb2717&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afe5d6dfe269517b1a38b0e2f0056b5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afe5d6dfe269517b1a38b0e2f0056b5d.addTo(map_fdfb40fb9fc4437a75ee0669b4fb2717);
#
#
#             var feature_group_76c542dd7609c77bafa9ef72f5ead0cb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_76c542dd7609c77bafa9ef72f5ead0cb.addTo(map_fdfb40fb9fc4437a75ee0669b4fb2717);
#
#
#             var feature_group_sub_group_c81ddfcf6f9daa8bd2b6b38c4cad4111 = L.featureGroup.subGroup(
#                 feature_group_76c542dd7609c77bafa9ef72f5ead0cb
#             );
#
#
#             var marker_7a983b9433bb73c4704894ba797eb928 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c81ddfcf6f9daa8bd2b6b38c4cad4111);
#
#
#         var popup_dac48112bdef63933025df11d1c49ced = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09a977c71b7525d6f076576f6184d0f6 = $(`&lt;div id=&quot;html_09a977c71b7525d6f076576f6184d0f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dac48112bdef63933025df11d1c49ced.setContent(html_09a977c71b7525d6f076576f6184d0f6);
#
#
#
#         marker_7a983b9433bb73c4704894ba797eb928.bindPopup(popup_dac48112bdef63933025df11d1c49ced)
#         ;
#
#
#
#
#             var marker_9efcdad4b2f1c0d680ef849e5158897e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c81ddfcf6f9daa8bd2b6b38c4cad4111);
#
#
#         var popup_a50a1c7b63f22f800dd026c845a26ccb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6db00fbfb050742d4f9af07ea0dd05f = $(`&lt;div id=&quot;html_e6db00fbfb050742d4f9af07ea0dd05f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a50a1c7b63f22f800dd026c845a26ccb.setContent(html_e6db00fbfb050742d4f9af07ea0dd05f);
#
#
#
#         marker_9efcdad4b2f1c0d680ef849e5158897e.bindPopup(popup_a50a1c7b63f22f800dd026c845a26ccb)
#         ;
#
#
#
#
#             var marker_00ad3cd29e471f27ab72696d56cbee07 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c81ddfcf6f9daa8bd2b6b38c4cad4111);
#
#
#         var popup_6697e85c5870bd58fa8093875373f9df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2be40363695b8debe395c5fd7c09bec = $(`&lt;div id=&quot;html_d2be40363695b8debe395c5fd7c09bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6697e85c5870bd58fa8093875373f9df.setContent(html_d2be40363695b8debe395c5fd7c09bec);
#
#
#
#         marker_00ad3cd29e471f27ab72696d56cbee07.bindPopup(popup_6697e85c5870bd58fa8093875373f9df)
#         ;
#
#
#
#
#             var marker_be75d0eb3422168d9ce1b89cb96330ef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c81ddfcf6f9daa8bd2b6b38c4cad4111);
#
#
#         var popup_59829e9f352a9eb2ee997d36be02d498 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_489001b71801a8950e7d9fd61a26cd6e = $(`&lt;div id=&quot;html_489001b71801a8950e7d9fd61a26cd6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_59829e9f352a9eb2ee997d36be02d498.setContent(html_489001b71801a8950e7d9fd61a26cd6e);
#
#
#
#         marker_be75d0eb3422168d9ce1b89cb96330ef.bindPopup(popup_59829e9f352a9eb2ee997d36be02d498)
#         ;
#
#
#
#
#             var marker_66c1c54a225533550cd3a216fcd7c73a = L.marker(
#                 [45.050399999999996, 3.0504],
