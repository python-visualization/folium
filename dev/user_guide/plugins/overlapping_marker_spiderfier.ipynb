# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b82a1fac8f83002dda745be8dcae4bef {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b82a1fac8f83002dda745be8dcae4bef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b82a1fac8f83002dda745be8dcae4bef = L.map(
#                 &quot;map_b82a1fac8f83002dda745be8dcae4bef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_020fc42bae91487ff3049f6827379099 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_020fc42bae91487ff3049f6827379099.addTo(map_b82a1fac8f83002dda745be8dcae4bef);
#
#
#             var marker_8451798862dae7fc7abacdadd18c047a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b82a1fac8f83002dda745be8dcae4bef);
#
#
#         var popup_1aec757216a1f30121552136bf4c16ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19f1d13cca9dd4f34201abfe33df1435 = $(`&lt;div id=&quot;html_19f1d13cca9dd4f34201abfe33df1435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1aec757216a1f30121552136bf4c16ee.setContent(html_19f1d13cca9dd4f34201abfe33df1435);
#
#
#
#         marker_8451798862dae7fc7abacdadd18c047a.bindPopup(popup_1aec757216a1f30121552136bf4c16ee)
#         ;
#
#
#
#
#             var marker_d4a504e2358c691a7274dbb13f93aa57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b82a1fac8f83002dda745be8dcae4bef);
#
#
#         var popup_70550afd6304a8ef648dfa861cf28947 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cdd9a82b2454e13f17d1f80f4b982d2 = $(`&lt;div id=&quot;html_6cdd9a82b2454e13f17d1f80f4b982d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_70550afd6304a8ef648dfa861cf28947.setContent(html_6cdd9a82b2454e13f17d1f80f4b982d2);
#
#
#
#         marker_d4a504e2358c691a7274dbb13f93aa57.bindPopup(popup_70550afd6304a8ef648dfa861cf28947)
#         ;
#
#
#
#
#             var marker_2371b0c413aa25b69d31c332a9d9b0e2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b82a1fac8f83002dda745be8dcae4bef);
#
#
#         var popup_9c464481ea2207905753e45e5d182fbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6afdc96d1f87765fb972837d61ed6719 = $(`&lt;div id=&quot;html_6afdc96d1f87765fb972837d61ed6719&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9c464481ea2207905753e45e5d182fbe.setContent(html_6afdc96d1f87765fb972837d61ed6719);
#
#
#
#         marker_2371b0c413aa25b69d31c332a9d9b0e2.bindPopup(popup_9c464481ea2207905753e45e5d182fbe)
#         ;
#
#
#
#
#             var marker_4f5192dbb51dbd467420ada3d7d67a98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b82a1fac8f83002dda745be8dcae4bef);
#
#
#         var popup_96cdc3d32d7c8aa0636b825569e5cd7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d61157b2fd1e16bc24b673a556ddf2f = $(`&lt;div id=&quot;html_8d61157b2fd1e16bc24b673a556ddf2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_96cdc3d32d7c8aa0636b825569e5cd7f.setContent(html_8d61157b2fd1e16bc24b673a556ddf2f);
#
#
#
#         marker_4f5192dbb51dbd467420ada3d7d67a98.bindPopup(popup_96cdc3d32d7c8aa0636b825569e5cd7f)
#         ;
#
#
#
#
#             var marker_52aa9403cec7f801f26da1fc855aca0d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b82a1fac8f83002dda745be8dcae4bef);
#
#
#         var popup_a59703f45a75a4229534266620eec269 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7799f74d1b42d1c2ea3a32f63c6087ba = $(`&lt;div id=&quot;html_7799f74d1b42d1c2ea3a32f63c6087ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a59703f45a75a4229534266620eec2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d158c20df21a5f6605f5398e6d29538 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d158c20df21a5f6605f5398e6d29538&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d158c20df21a5f6605f5398e6d29538 = L.map(
#                 &quot;map_9d158c20df21a5f6605f5398e6d29538&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c215d5c168aaba443d77a7abfbea2fe9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c215d5c168aaba443d77a7abfbea2fe9.addTo(map_9d158c20df21a5f6605f5398e6d29538);
#
#
#             var feature_group_bf9dd690543a36b1dfc73ecfa8308065 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ae303214f6193610a4cb8b3b18f20b7f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bf9dd690543a36b1dfc73ecfa8308065);
#
#
#         var popup_a08c1c2899eced93a1583884d4a8a566 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea2f90f25fdcc3dda77c79ba692aa3bc = $(`&lt;div id=&quot;html_ea2f90f25fdcc3dda77c79ba692aa3bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a08c1c2899eced93a1583884d4a8a566.setContent(html_ea2f90f25fdcc3dda77c79ba692aa3bc);
#
#
#
#         marker_ae303214f6193610a4cb8b3b18f20b7f.bindPopup(popup_a08c1c2899eced93a1583884d4a8a566)
#         ;
#
#
#
#
#             var marker_adfb467af856f088333065df103eb5bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bf9dd690543a36b1dfc73ecfa8308065);
#
#
#         var popup_6b613e9ba3e78be8b6799ee34046a7b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a10c5e872acaad8d2509e9bb43006bf0 = $(`&lt;div id=&quot;html_a10c5e872acaad8d2509e9bb43006bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6b613e9ba3e78be8b6799ee34046a7b8.setContent(html_a10c5e872acaad8d2509e9bb43006bf0);
#
#
#
#         marker_adfb467af856f088333065df103eb5bd.bindPopup(popup_6b613e9ba3e78be8b6799ee34046a7b8)
#         ;
#
#
#
#
#             var marker_c3852bcd37163a1879475512c08dc45e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bf9dd690543a36b1dfc73ecfa8308065);
#
#
#         var popup_363424fa34c73514280ef07cc2c775a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a92aac9d300e76ffcc795b4c07e57b0d = $(`&lt;div id=&quot;html_a92aac9d300e76ffcc795b4c07e57b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_363424fa34c73514280ef07cc2c775a1.setContent(html_a92aac9d300e76ffcc795b4c07e57b0d);
#
#
#
#         marker_c3852bcd37163a1879475512c08dc45e.bindPopup(popup_363424fa34c73514280ef07cc2c775a1)
#         ;
#
#
#
#
#             var marker_857bf6373981320ab279dac4bbb38d7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bf9dd690543a36b1dfc73ecfa8308065);
#
#
#         var popup_11d5370235441bdb982faeb487c4af3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6e392cc4fe1f1d2ea83bcefcfae7a47 = $(`&lt;div id=&quot;html_d6e392cc4fe1f1d2ea83bcefcfae7a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_11d5370235441bdb982faeb487c4af3a.setContent(html_d6e392cc4fe1f1d2ea83bcefcfae7a47);
#
#
#
#         marker_857bf6373981320ab279dac4bbb38d7c.bindPopup(popup_11d5370235441bdb982faeb487c4af3a)
#         ;
#
#
#
#
#             var marker_f060e9f25358c357cb52ae0add2132a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bf9dd690543a36b1dfc73ecfa8308065);
#
#
#         var popup_55bab0c592ba8d970b0f0d1360ecdaf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d7be57f770428f753036bf4e0449ec7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d7be57f770428f753036bf4e0449ec7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d7be57f770428f753036bf4e0449ec7 = L.map(
#                 &quot;map_3d7be57f770428f753036bf4e0449ec7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85d232a006b421ea9a86abc49a07a1bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85d232a006b421ea9a86abc49a07a1bf.addTo(map_3d7be57f770428f753036bf4e0449ec7);
#
#
#             var feature_group_45d1b4ed9695e4d034fce06a4378e3a4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_45d1b4ed9695e4d034fce06a4378e3a4.addTo(map_3d7be57f770428f753036bf4e0449ec7);
#
#
#             var feature_group_sub_group_96f9b831762a623c3c546a56ed235582 = L.featureGroup.subGroup(
#                 feature_group_45d1b4ed9695e4d034fce06a4378e3a4
#             );
#
#
#             var marker_9dd8cff8aea121a340490454c8bef747 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f9b831762a623c3c546a56ed235582);
#
#
#         var popup_655e8a8e708ee0a8457675811b7a5a43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_386bf59faeeedfbd745bef1ff9a47e8a = $(`&lt;div id=&quot;html_386bf59faeeedfbd745bef1ff9a47e8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_655e8a8e708ee0a8457675811b7a5a43.setContent(html_386bf59faeeedfbd745bef1ff9a47e8a);
#
#
#
#         marker_9dd8cff8aea121a340490454c8bef747.bindPopup(popup_655e8a8e708ee0a8457675811b7a5a43)
#         ;
#
#
#
#
#             var marker_ecc9bf230479f7c5d7a49f344e779b48 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f9b831762a623c3c546a56ed235582);
#
#
#         var popup_1249927871d7bfc3b44329f1ba283489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7daaad851284b5a12a832bca01fd58df = $(`&lt;div id=&quot;html_7daaad851284b5a12a832bca01fd58df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1249927871d7bfc3b44329f1ba283489.setContent(html_7daaad851284b5a12a832bca01fd58df);
#
#
#
#         marker_ecc9bf230479f7c5d7a49f344e779b48.bindPopup(popup_1249927871d7bfc3b44329f1ba283489)
#         ;
#
#
#
#
#             var marker_f85eac69d61fcecac56a90dcbd9338ca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f9b831762a623c3c546a56ed235582);
#
#
#         var popup_82c4f3a6ba311c575c00454adc0eeff2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3689d5905361f0a1b5acae47f479b93f = $(`&lt;div id=&quot;html_3689d5905361f0a1b5acae47f479b93f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_82c4f3a6ba311c575c00454adc0eeff2.setContent(html_3689d5905361f0a1b5acae47f479b93f);
#
#
#
#         marker_f85eac69d61fcecac56a90dcbd9338ca.bindPopup(popup_82c4f3a6ba311c575c00454adc0eeff2)
#         ;
#
#
#
#
#             var marker_6ffd495b5877d4f9a5910c6117fc5248 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f9b831762a623c3c546a56ed235582);
#
#
#         var popup_712b619e60280915f366e4abb6bd6b99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6054e08d058b7a679e5c6eaec10d7cfd = $(`&lt;div id=&quot;html_6054e08d058b7a679e5c6eaec10d7cfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_712b619e60280915f366e4abb6bd6b99.setContent(html_6054e08d058b7a679e5c6eaec10d7cfd);
#
#
#
#         mark
