# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94649fa28a4acae6fcb244ca60b35fc2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94649fa28a4acae6fcb244ca60b35fc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94649fa28a4acae6fcb244ca60b35fc2 = L.map(
#                 &quot;map_94649fa28a4acae6fcb244ca60b35fc2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a003379a46f558ce115265ce0e6a4aad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a003379a46f558ce115265ce0e6a4aad.addTo(map_94649fa28a4acae6fcb244ca60b35fc2);
#
#
#             var marker_efd2c346841e8b6d4cbe3e4a8783ffee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94649fa28a4acae6fcb244ca60b35fc2);
#
#
#         var popup_4d0039bd14a5ba198a188b12ed5741f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2f8377b21878bec661d3710a25e1aad = $(`&lt;div id=&quot;html_a2f8377b21878bec661d3710a25e1aad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4d0039bd14a5ba198a188b12ed5741f7.setContent(html_a2f8377b21878bec661d3710a25e1aad);
#
#
#
#         marker_efd2c346841e8b6d4cbe3e4a8783ffee.bindPopup(popup_4d0039bd14a5ba198a188b12ed5741f7)
#         ;
#
#
#
#
#             var marker_fae1070fdda0fea1965f2c18c38e136d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94649fa28a4acae6fcb244ca60b35fc2);
#
#
#         var popup_7162331f94b74d7d72f4abbd22f969df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cde96874006545359143c8d9690e6709 = $(`&lt;div id=&quot;html_cde96874006545359143c8d9690e6709&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7162331f94b74d7d72f4abbd22f969df.setContent(html_cde96874006545359143c8d9690e6709);
#
#
#
#         marker_fae1070fdda0fea1965f2c18c38e136d.bindPopup(popup_7162331f94b74d7d72f4abbd22f969df)
#         ;
#
#
#
#
#             var marker_5ff38c9e8e5485b86c43bb7be73ced30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94649fa28a4acae6fcb244ca60b35fc2);
#
#
#         var popup_1d9de9519969be027b3a300fae72e928 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8203ea51763175da5cc9deb5b4e84c7 = $(`&lt;div id=&quot;html_a8203ea51763175da5cc9deb5b4e84c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d9de9519969be027b3a300fae72e928.setContent(html_a8203ea51763175da5cc9deb5b4e84c7);
#
#
#
#         marker_5ff38c9e8e5485b86c43bb7be73ced30.bindPopup(popup_1d9de9519969be027b3a300fae72e928)
#         ;
#
#
#
#
#             var marker_183b6e119b9679d4b0b8dc23332997e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94649fa28a4acae6fcb244ca60b35fc2);
#
#
#         var popup_9c1650af05a6cad1a686fa800673ddc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e38345aa03f20b5011defb20ee052f06 = $(`&lt;div id=&quot;html_e38345aa03f20b5011defb20ee052f06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9c1650af05a6cad1a686fa800673ddc5.setContent(html_e38345aa03f20b5011defb20ee052f06);
#
#
#
#         marker_183b6e119b9679d4b0b8dc23332997e8.bindPopup(popup_9c1650af05a6cad1a686fa800673ddc5)
#         ;
#
#
#
#
#             var marker_64bf04eaeb04dc6c0a316d65b7f47bd1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94649fa28a4acae6fcb244ca60b35fc2);
#
#
#         var popup_b3b9b17269c0d53017674337834a4d64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8ded66a2c95054ef0f732e6a4e09de8 = $(`&lt;div id=&quot;html_b8ded66a2c95054ef0f732e6a4e09de8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b3b9b17269c0d53017674337834a4d

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cb260b3a470b917002f0bb91e2fd9a2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cb260b3a470b917002f0bb91e2fd9a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cb260b3a470b917002f0bb91e2fd9a2 = L.map(
#                 &quot;map_3cb260b3a470b917002f0bb91e2fd9a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e62a9de4072cfad2462ae163c193dd5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e62a9de4072cfad2462ae163c193dd5c.addTo(map_3cb260b3a470b917002f0bb91e2fd9a2);
#
#
#             var feature_group_4420d7ff4d4c085f0a69d14a661b300c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ebabeb548fadd4f583819df7e7a4b051 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4420d7ff4d4c085f0a69d14a661b300c);
#
#
#         var popup_464e6f0cb77016137ff5d120eb2fe337 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8308971125d5ba7d8925beddb608411 = $(`&lt;div id=&quot;html_b8308971125d5ba7d8925beddb608411&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_464e6f0cb77016137ff5d120eb2fe337.setContent(html_b8308971125d5ba7d8925beddb608411);
#
#
#
#         marker_ebabeb548fadd4f583819df7e7a4b051.bindPopup(popup_464e6f0cb77016137ff5d120eb2fe337)
#         ;
#
#
#
#
#             var marker_308b15336723ecdc654db6deda3ed010 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4420d7ff4d4c085f0a69d14a661b300c);
#
#
#         var popup_da0aa2beeb949e97e80a43ef7d4b9e06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_916535047eb97c1862637b29402933f1 = $(`&lt;div id=&quot;html_916535047eb97c1862637b29402933f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_da0aa2beeb949e97e80a43ef7d4b9e06.setContent(html_916535047eb97c1862637b29402933f1);
#
#
#
#         marker_308b15336723ecdc654db6deda3ed010.bindPopup(popup_da0aa2beeb949e97e80a43ef7d4b9e06)
#         ;
#
#
#
#
#             var marker_fa0cdbb82ad942e6f3e3af2fe722234a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4420d7ff4d4c085f0a69d14a661b300c);
#
#
#         var popup_7183cf9da9f9efbee1feecc011c2f4d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef09ece2765854bad465aa3146eaaa21 = $(`&lt;div id=&quot;html_ef09ece2765854bad465aa3146eaaa21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7183cf9da9f9efbee1feecc011c2f4d9.setContent(html_ef09ece2765854bad465aa3146eaaa21);
#
#
#
#         marker_fa0cdbb82ad942e6f3e3af2fe722234a.bindPopup(popup_7183cf9da9f9efbee1feecc011c2f4d9)
#         ;
#
#
#
#
#             var marker_9e22d80b20651505fdc624dee73fbf84 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4420d7ff4d4c085f0a69d14a661b300c);
#
#
#         var popup_ae00a1773461b98269ea64d4d8ac7f34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03056ac4425a524ff108a5739396700a = $(`&lt;div id=&quot;html_03056ac4425a524ff108a5739396700a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ae00a1773461b98269ea64d4d8ac7f34.setContent(html_03056ac4425a524ff108a5739396700a);
#
#
#
#         marker_9e22d80b20651505fdc624dee73fbf84.bindPopup(popup_ae00a1773461b98269ea64d4d8ac7f34)
#         ;
#
#
#
#
#             var marker_efc989bba1f43317b9cf9d450fca9604 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4420d7ff4d4c085f0a69d14a661b300c);
#
#
#         var popup_479c0d57ee1f1d6e15c9f1bc80bec96a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b06f7db80f9cda5321e0029d7c008167 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b06f7db80f9cda5321e0029d7c008167&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b06f7db80f9cda5321e0029d7c008167 = L.map(
#                 &quot;map_b06f7db80f9cda5321e0029d7c008167&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2ad342e13ca7fed9388f33fe5683934 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2ad342e13ca7fed9388f33fe5683934.addTo(map_b06f7db80f9cda5321e0029d7c008167);
#
#
#             var feature_group_0caffe933f01120bbf8ff6bad433206b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0caffe933f01120bbf8ff6bad433206b.addTo(map_b06f7db80f9cda5321e0029d7c008167);
#
#
#             var feature_group_sub_group_23db7f31483b36e7be7bac9598c7599f = L.featureGroup.subGroup(
#                 feature_group_0caffe933f01120bbf8ff6bad433206b
#             );
#
#
#             var marker_faf2db3c6fdc13b26a67beddbbb9072d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_23db7f31483b36e7be7bac9598c7599f);
#
#
#         var popup_8c16144bcdd7b928db54549b41897f2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbbc03f11aa1bbead7cb7ea9ad7b9fab = $(`&lt;div id=&quot;html_fbbc03f11aa1bbead7cb7ea9ad7b9fab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8c16144bcdd7b928db54549b41897f2b.setContent(html_fbbc03f11aa1bbead7cb7ea9ad7b9fab);
#
#
#
#         marker_faf2db3c6fdc13b26a67beddbbb9072d.bindPopup(popup_8c16144bcdd7b928db54549b41897f2b)
#         ;
#
#
#
#
#             var marker_c143c91840d430428910e187bd19b058 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_23db7f31483b36e7be7bac9598c7599f);
#
#
#         var popup_b8e4f0eb66fafbb06503e7191bf1db63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2a5077d9d90bb7bf1ebf4e129211676 = $(`&lt;div id=&quot;html_f2a5077d9d90bb7bf1ebf4e129211676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b8e4f0eb66fafbb06503e7191bf1db63.setContent(html_f2a5077d9d90bb7bf1ebf4e129211676);
#
#
#
#         marker_c143c91840d430428910e187bd19b058.bindPopup(popup_b8e4f0eb66fafbb06503e7191bf1db63)
#         ;
#
#
#
#
#             var marker_71da4b1c0a8050399b8d06755226ec39 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_23db7f31483b36e7be7bac9598c7599f);
#
#
#         var popup_4e76fdbfbd91764fef68e99660982c40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfc34aed6ed4bb12b825274379c3e3c8 = $(`&lt;div id=&quot;html_dfc34aed6ed4bb12b825274379c3e3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4e76fdbfbd91764fef68e99660982c40.setContent(html_dfc34aed6ed4bb12b825274379c3e3c8);
#
#
#
#         marker_71da4b1c0a8050399b8d06755226ec39.bindPopup(popup_4e76fdbfbd91764fef68e99660982c40)
#         ;
#
#
#
#
#             var marker_116844f247ceb7797fbf2740770a5f75 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_23db7f31483b36e7be7bac9598c7599f);
#
#
#         var popup_20c4d97017e1fd1cb1f2b64340e9dad2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c4e32397966fbdd1c33367f6460a4e5 = $(`&lt;div id=&quot;html_6c4e32397966fbdd1c33367f6460a4e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_20c4d97017e1fd1cb1f2b64340e9dad2.setContent(html_6c4e32397966fbdd1c33367f6460a4e5);
#
#
#
#         mark
