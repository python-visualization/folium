# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d8b99368dfc7d2f280ce357caa9780f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d8b99368dfc7d2f280ce357caa9780f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d8b99368dfc7d2f280ce357caa9780f = L.map(
#                 &quot;map_8d8b99368dfc7d2f280ce357caa9780f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2f7c72158dd780b84ed12ca1d3d5e18 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2f7c72158dd780b84ed12ca1d3d5e18.addTo(map_8d8b99368dfc7d2f280ce357caa9780f);
#
#
#             var marker_f45247fafc0622a89a2d4151bcb1547e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8d8b99368dfc7d2f280ce357caa9780f);
#
#
#         var popup_27f822c123a90e44a5a7700d089b9552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9311b4118613760878b3fac319851fd5 = $(`&lt;div id=&quot;html_9311b4118613760878b3fac319851fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_27f822c123a90e44a5a7700d089b9552.setContent(html_9311b4118613760878b3fac319851fd5);
#
#
#
#         marker_f45247fafc0622a89a2d4151bcb1547e.bindPopup(popup_27f822c123a90e44a5a7700d089b9552)
#         ;
#
#
#
#
#             var marker_43f0035757f002d133f230ae66cc30f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8d8b99368dfc7d2f280ce357caa9780f);
#
#
#         var popup_a152aac29585c9f14123e967fd459b49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e9b85dff74ace985489c6c3ac8ee4a7 = $(`&lt;div id=&quot;html_3e9b85dff74ace985489c6c3ac8ee4a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a152aac29585c9f14123e967fd459b49.setContent(html_3e9b85dff74ace985489c6c3ac8ee4a7);
#
#
#
#         marker_43f0035757f002d133f230ae66cc30f3.bindPopup(popup_a152aac29585c9f14123e967fd459b49)
#         ;
#
#
#
#
#             var marker_66e8044b1f7b71fdeef5e98fe952ede6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8d8b99368dfc7d2f280ce357caa9780f);
#
#
#         var popup_e3af3b4053b0b816f634bc3d013534f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2b0fa5d99e46d70a8b9ae5ea25f446b = $(`&lt;div id=&quot;html_a2b0fa5d99e46d70a8b9ae5ea25f446b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e3af3b4053b0b816f634bc3d013534f5.setContent(html_a2b0fa5d99e46d70a8b9ae5ea25f446b);
#
#
#
#         marker_66e8044b1f7b71fdeef5e98fe952ede6.bindPopup(popup_e3af3b4053b0b816f634bc3d013534f5)
#         ;
#
#
#
#
#             var marker_d327ae789fc1f11b3b880f034987799b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8d8b99368dfc7d2f280ce357caa9780f);
#
#
#         var popup_9278e6cf632eb87f0b609234ecec4222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37110b96bae5923c53894e9971189fe9 = $(`&lt;div id=&quot;html_37110b96bae5923c53894e9971189fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9278e6cf632eb87f0b609234ecec4222.setContent(html_37110b96bae5923c53894e9971189fe9);
#
#
#
#         marker_d327ae789fc1f11b3b880f034987799b.bindPopup(popup_9278e6cf632eb87f0b609234ecec4222)
#         ;
#
#
#
#
#             var marker_3f1a5319d83d26d504a4c3e7dcf6cbe4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8d8b99368dfc7d2f280ce357caa9780f);
#
#
#         var popup_bbb045356359af5ec11bb315ac3ca7f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e5693485d89eac700a015edd6d4dd3 = $(`&lt;div id=&quot;html_b0e5693485d89eac700a015edd6d4dd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bbb045356359af5ec11bb315ac3ca7f3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e48e111dcbc32e3971eb696471b078c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e48e111dcbc32e3971eb696471b078c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e48e111dcbc32e3971eb696471b078c9 = L.map(
#                 &quot;map_e48e111dcbc32e3971eb696471b078c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81404716a9ae4ca500f9ac19b0a8f381 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81404716a9ae4ca500f9ac19b0a8f381.addTo(map_e48e111dcbc32e3971eb696471b078c9);
#
#
#             var feature_group_114ed4921c1586a090a3cdfe96ff8e59 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_59fb613996b7aac59c6fb5006065bcb9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_114ed4921c1586a090a3cdfe96ff8e59);
#
#
#         var popup_64570d0db83ab59a2d6db738947caea7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acbb9c3ede7c807d29a30cb66b2d1403 = $(`&lt;div id=&quot;html_acbb9c3ede7c807d29a30cb66b2d1403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_64570d0db83ab59a2d6db738947caea7.setContent(html_acbb9c3ede7c807d29a30cb66b2d1403);
#
#
#
#         marker_59fb613996b7aac59c6fb5006065bcb9.bindPopup(popup_64570d0db83ab59a2d6db738947caea7)
#         ;
#
#
#
#
#             var marker_b619c3c560dacbf86dab0e09a3ba60a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_114ed4921c1586a090a3cdfe96ff8e59);
#
#
#         var popup_1cb8cc5c242a4ef2fd19d59831f59445 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7a7163ab3dcf1ac48a8729293d891bb = $(`&lt;div id=&quot;html_b7a7163ab3dcf1ac48a8729293d891bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1cb8cc5c242a4ef2fd19d59831f59445.setContent(html_b7a7163ab3dcf1ac48a8729293d891bb);
#
#
#
#         marker_b619c3c560dacbf86dab0e09a3ba60a8.bindPopup(popup_1cb8cc5c242a4ef2fd19d59831f59445)
#         ;
#
#
#
#
#             var marker_189f04efe45916ecfc847f1a2051dba5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_114ed4921c1586a090a3cdfe96ff8e59);
#
#
#         var popup_e7c87026e1f1b0958aa5484cd81bf62f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd4028f6151fe4948e4800737fb3400d = $(`&lt;div id=&quot;html_dd4028f6151fe4948e4800737fb3400d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e7c87026e1f1b0958aa5484cd81bf62f.setContent(html_dd4028f6151fe4948e4800737fb3400d);
#
#
#
#         marker_189f04efe45916ecfc847f1a2051dba5.bindPopup(popup_e7c87026e1f1b0958aa5484cd81bf62f)
#         ;
#
#
#
#
#             var marker_b1d8d864d0f7f6f7760c9c761a9d2552 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_114ed4921c1586a090a3cdfe96ff8e59);
#
#
#         var popup_c251ae3c2a12d147cf05a31214b7366a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f677f33bc3655ba671cc3f205d5bf48 = $(`&lt;div id=&quot;html_0f677f33bc3655ba671cc3f205d5bf48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c251ae3c2a12d147cf05a31214b7366a.setContent(html_0f677f33bc3655ba671cc3f205d5bf48);
#
#
#
#         marker_b1d8d864d0f7f6f7760c9c761a9d2552.bindPopup(popup_c251ae3c2a12d147cf05a31214b7366a)
#         ;
#
#
#
#
#             var marker_db425c1034c031de7c5f4f2e30ed9edd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_114ed4921c1586a090a3cdfe96ff8e59);
#
#
#         var popup_77617aa911570a2820d6e1caebf0b77f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97499171572440217a2a1484d581a596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97499171572440217a2a1484d581a596&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97499171572440217a2a1484d581a596 = L.map(
#                 &quot;map_97499171572440217a2a1484d581a596&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e64f3d4303cd5eb768a5b9e7daa4eb15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e64f3d4303cd5eb768a5b9e7daa4eb15.addTo(map_97499171572440217a2a1484d581a596);
#
#
#             var feature_group_27a4023913bbe4dccd11c41eac4c0ca8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_27a4023913bbe4dccd11c41eac4c0ca8.addTo(map_97499171572440217a2a1484d581a596);
#
#
#             var feature_group_sub_group_289778ab992d272e56c5d6e5336e0cf4 = L.featureGroup.subGroup(
#                 feature_group_27a4023913bbe4dccd11c41eac4c0ca8
#             );
#
#
#             var marker_8932d803486494076504aa0c9e88bab6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_289778ab992d272e56c5d6e5336e0cf4);
#
#
#         var popup_ed9841d827236c0aab81671ad1f1b3b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fa9339c8701e67c7b12e01d7fb00c89 = $(`&lt;div id=&quot;html_3fa9339c8701e67c7b12e01d7fb00c89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ed9841d827236c0aab81671ad1f1b3b7.setContent(html_3fa9339c8701e67c7b12e01d7fb00c89);
#
#
#
#         marker_8932d803486494076504aa0c9e88bab6.bindPopup(popup_ed9841d827236c0aab81671ad1f1b3b7)
#         ;
#
#
#
#
#             var marker_3aca3452b00d45332fd3bee6053486fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_289778ab992d272e56c5d6e5336e0cf4);
#
#
#         var popup_369e9acef32512b36188aee449ae5fd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fc93a69cea78ea64b76a13d4c75db11 = $(`&lt;div id=&quot;html_2fc93a69cea78ea64b76a13d4c75db11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_369e9acef32512b36188aee449ae5fd4.setContent(html_2fc93a69cea78ea64b76a13d4c75db11);
#
#
#
#         marker_3aca3452b00d45332fd3bee6053486fb.bindPopup(popup_369e9acef32512b36188aee449ae5fd4)
#         ;
#
#
#
#
#             var marker_dfbcd5b90a2d99a2d1d944ef6af18730 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_289778ab992d272e56c5d6e5336e0cf4);
#
#
#         var popup_8e2e13c248de7cb02b8f9a18b8f9aec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9b3fdc38a91984ec7e229be126ee07e = $(`&lt;div id=&quot;html_e9b3fdc38a91984ec7e229be126ee07e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8e2e13c248de7cb02b8f9a18b8f9aec1.setContent(html_e9b3fdc38a91984ec7e229be126ee07e);
#
#
#
#         marker_dfbcd5b90a2d99a2d1d944ef6af18730.bindPopup(popup_8e2e13c248de7cb02b8f9a18b8f9aec1)
#         ;
#
#
#
#
#             var marker_3779933bb5e2e03add7f7a6339fb1e20 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_289778ab992d272e56c5d6e5336e0cf4);
#
#
#         var popup_55b6ec15ab5286f985699156505e2d57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fde2efe8bc17e8560bf6133c96d3701a = $(`&lt;div id=&quot;html_fde2efe8bc17e8560bf6133c96d3701a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_55b6ec15ab5286f985699156505e2d57.setContent(html_fde2efe8bc17e8560bf6133c96d3701a);
#
#
#
#         marker_
