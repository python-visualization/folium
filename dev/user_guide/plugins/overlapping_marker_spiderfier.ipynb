# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef7b7d3444393ad8fb07a40ccee5fa29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef7b7d3444393ad8fb07a40ccee5fa29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef7b7d3444393ad8fb07a40ccee5fa29 = L.map(
#                 &quot;map_ef7b7d3444393ad8fb07a40ccee5fa29&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_310f12ce0e79abc4859f9ad9a6ed32c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_310f12ce0e79abc4859f9ad9a6ed32c8.addTo(map_ef7b7d3444393ad8fb07a40ccee5fa29);
#
#
#             var marker_421caeca78899725983ba8343c7b13e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ef7b7d3444393ad8fb07a40ccee5fa29);
#
#
#         var popup_a475df0b9c8e07dbd840d30f916b1e56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a09142e2c4eb530c7d39c601022aa0 = $(`&lt;div id=&quot;html_b2a09142e2c4eb530c7d39c601022aa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a475df0b9c8e07dbd840d30f916b1e56.setContent(html_b2a09142e2c4eb530c7d39c601022aa0);
#
#
#
#         marker_421caeca78899725983ba8343c7b13e4.bindPopup(popup_a475df0b9c8e07dbd840d30f916b1e56)
#         ;
#
#
#
#
#             var marker_87ffa04a3333d1f5f57e2fc8ebcccb8a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ef7b7d3444393ad8fb07a40ccee5fa29);
#
#
#         var popup_3f8ce1d0033e6c99e409ad330b200d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_978e1bae77d86dc659027766d6fbae79 = $(`&lt;div id=&quot;html_978e1bae77d86dc659027766d6fbae79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3f8ce1d0033e6c99e409ad330b200d78.setContent(html_978e1bae77d86dc659027766d6fbae79);
#
#
#
#         marker_87ffa04a3333d1f5f57e2fc8ebcccb8a.bindPopup(popup_3f8ce1d0033e6c99e409ad330b200d78)
#         ;
#
#
#
#
#             var marker_6ad8537eac357deab793c733be63c694 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ef7b7d3444393ad8fb07a40ccee5fa29);
#
#
#         var popup_b4206a55db6c97429ca6084ace335a50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_082f6342a5ac05f2ea4d61817d082504 = $(`&lt;div id=&quot;html_082f6342a5ac05f2ea4d61817d082504&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b4206a55db6c97429ca6084ace335a50.setContent(html_082f6342a5ac05f2ea4d61817d082504);
#
#
#
#         marker_6ad8537eac357deab793c733be63c694.bindPopup(popup_b4206a55db6c97429ca6084ace335a50)
#         ;
#
#
#
#
#             var marker_1d3458e4a4d213f207638e53e4a180e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ef7b7d3444393ad8fb07a40ccee5fa29);
#
#
#         var popup_656eafed1da91175833d5ee99386e8a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_686a8570931badefa7edd22b78fa5351 = $(`&lt;div id=&quot;html_686a8570931badefa7edd22b78fa5351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_656eafed1da91175833d5ee99386e8a6.setContent(html_686a8570931badefa7edd22b78fa5351);
#
#
#
#         marker_1d3458e4a4d213f207638e53e4a180e5.bindPopup(popup_656eafed1da91175833d5ee99386e8a6)
#         ;
#
#
#
#
#             var marker_8e45b31b71358b3c34444d3dc9b60c0a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ef7b7d3444393ad8fb07a40ccee5fa29);
#
#
#         var popup_023b66d223b19ea057391ced1faf74f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2c301c9e152083f88f52aedc4df543c = $(`&lt;div id=&quot;html_a2c301c9e152083f88f52aedc4df543c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_023b66d223b19ea057391ced1faf74f4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be7b800a772b6a34e0e7b939a3e2c20e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be7b800a772b6a34e0e7b939a3e2c20e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be7b800a772b6a34e0e7b939a3e2c20e = L.map(
#                 &quot;map_be7b800a772b6a34e0e7b939a3e2c20e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0625b27c3256606a314a0b9ef97e321a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0625b27c3256606a314a0b9ef97e321a.addTo(map_be7b800a772b6a34e0e7b939a3e2c20e);
#
#
#             var feature_group_6413dc8c7bf58e6c571b4d91e62557e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cd2eaa46bfb1244c3b731199443f3e87 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6413dc8c7bf58e6c571b4d91e62557e8);
#
#
#         var popup_75740b4777e21cb88690e9f06b74761f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ea06ce18c87677a405d149c31ebe107 = $(`&lt;div id=&quot;html_0ea06ce18c87677a405d149c31ebe107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_75740b4777e21cb88690e9f06b74761f.setContent(html_0ea06ce18c87677a405d149c31ebe107);
#
#
#
#         marker_cd2eaa46bfb1244c3b731199443f3e87.bindPopup(popup_75740b4777e21cb88690e9f06b74761f)
#         ;
#
#
#
#
#             var marker_503526d2d1beb1291a7a564f5c8675b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6413dc8c7bf58e6c571b4d91e62557e8);
#
#
#         var popup_a27f7eb5abdbd4d5d49d5f2b3822ed95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f6367dc0b79a67e74c530835735eba8 = $(`&lt;div id=&quot;html_6f6367dc0b79a67e74c530835735eba8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a27f7eb5abdbd4d5d49d5f2b3822ed95.setContent(html_6f6367dc0b79a67e74c530835735eba8);
#
#
#
#         marker_503526d2d1beb1291a7a564f5c8675b5.bindPopup(popup_a27f7eb5abdbd4d5d49d5f2b3822ed95)
#         ;
#
#
#
#
#             var marker_6377ff80e243a2e3862198626adc53bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6413dc8c7bf58e6c571b4d91e62557e8);
#
#
#         var popup_cf5f1efe0dfba679aba0f4df03c8b01e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3306a3a40e9a4781f75f33d329244aee = $(`&lt;div id=&quot;html_3306a3a40e9a4781f75f33d329244aee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cf5f1efe0dfba679aba0f4df03c8b01e.setContent(html_3306a3a40e9a4781f75f33d329244aee);
#
#
#
#         marker_6377ff80e243a2e3862198626adc53bc.bindPopup(popup_cf5f1efe0dfba679aba0f4df03c8b01e)
#         ;
#
#
#
#
#             var marker_e506a8e0dc9f412a5ac65deba10f4644 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6413dc8c7bf58e6c571b4d91e62557e8);
#
#
#         var popup_311090f99e7b7b385ce95b0375562a08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f51e74e70c9fb96926ce90072a9abef8 = $(`&lt;div id=&quot;html_f51e74e70c9fb96926ce90072a9abef8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_311090f99e7b7b385ce95b0375562a08.setContent(html_f51e74e70c9fb96926ce90072a9abef8);
#
#
#
#         marker_e506a8e0dc9f412a5ac65deba10f4644.bindPopup(popup_311090f99e7b7b385ce95b0375562a08)
#         ;
#
#
#
#
#             var marker_042f53fb42e4eae3e4d8abc273f6d663 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6413dc8c7bf58e6c571b4d91e62557e8);
#
#
#         var popup_30cd5e291d248b710849a70266dc8f3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1c589e5e9038a38ed3561a8d8aa772d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1c589e5e9038a38ed3561a8d8aa772d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1c589e5e9038a38ed3561a8d8aa772d = L.map(
#                 &quot;map_e1c589e5e9038a38ed3561a8d8aa772d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1409fbbdbbc3c60bfa1d013eec0a93d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1409fbbdbbc3c60bfa1d013eec0a93d6.addTo(map_e1c589e5e9038a38ed3561a8d8aa772d);
#
#
#             var feature_group_b71a4645f03be2d181b07ea2c0999abc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b71a4645f03be2d181b07ea2c0999abc.addTo(map_e1c589e5e9038a38ed3561a8d8aa772d);
#
#
#             var feature_group_sub_group_a95d2a87d1d6a1a91e0de2c5f515c3b1 = L.featureGroup.subGroup(
#                 feature_group_b71a4645f03be2d181b07ea2c0999abc
#             );
#
#
#             var marker_166edaff78e8961a6eab0cf09c266d84 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a95d2a87d1d6a1a91e0de2c5f515c3b1);
#
#
#         var popup_9870d5c7b11126ae014f719f0005fea6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e96f2520b106f2c79cfd84b02bc02dd = $(`&lt;div id=&quot;html_3e96f2520b106f2c79cfd84b02bc02dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9870d5c7b11126ae014f719f0005fea6.setContent(html_3e96f2520b106f2c79cfd84b02bc02dd);
#
#
#
#         marker_166edaff78e8961a6eab0cf09c266d84.bindPopup(popup_9870d5c7b11126ae014f719f0005fea6)
#         ;
#
#
#
#
#             var marker_59e826e9f68e3f5625079615cb32183f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a95d2a87d1d6a1a91e0de2c5f515c3b1);
#
#
#         var popup_edb8f4c03118cabf7722d4d70cf710d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3bf0bebfa1b6df232b590252fcb5c2c = $(`&lt;div id=&quot;html_d3bf0bebfa1b6df232b590252fcb5c2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_edb8f4c03118cabf7722d4d70cf710d3.setContent(html_d3bf0bebfa1b6df232b590252fcb5c2c);
#
#
#
#         marker_59e826e9f68e3f5625079615cb32183f.bindPopup(popup_edb8f4c03118cabf7722d4d70cf710d3)
#         ;
#
#
#
#
#             var marker_17cc8e8453209b000f3c699c86914554 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a95d2a87d1d6a1a91e0de2c5f515c3b1);
#
#
#         var popup_fe505bb0eeefdb269f0bbe630fdb25fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e5f31826981d469f92a7ca33bb834d7 = $(`&lt;div id=&quot;html_2e5f31826981d469f92a7ca33bb834d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fe505bb0eeefdb269f0bbe630fdb25fb.setContent(html_2e5f31826981d469f92a7ca33bb834d7);
#
#
#
#         marker_17cc8e8453209b000f3c699c86914554.bindPopup(popup_fe505bb0eeefdb269f0bbe630fdb25fb)
#         ;
#
#
#
#
#             var marker_5c362a74a26c4b01a73ddef53eb7c872 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a95d2a87d1d6a1a91e0de2c5f515c3b1);
#
#
#         var popup_0356105907519f0e77da96e5149922ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd6d5d3525c3d337d9868c2f41cb9b6d = $(`&lt;div id=&quot;html_bd6d5d3525c3d337d9868c2f41cb9b6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0356105907519f0e77da96e5149922ce.setContent(html_bd6d5d3525c3d337d9868c2f41cb9b6d);
#
#
#
#         marker_
