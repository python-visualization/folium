# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b70bb4994c215050d240c0beae25cd33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b70bb4994c215050d240c0beae25cd33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b70bb4994c215050d240c0beae25cd33 = L.map(
#                 &quot;map_b70bb4994c215050d240c0beae25cd33&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e286ec6a937acbe1be9f9386bc4b3bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e286ec6a937acbe1be9f9386bc4b3bd.addTo(map_b70bb4994c215050d240c0beae25cd33);
#
#
#             var marker_b35180fd0e7854a79c89b40299a01ef3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b70bb4994c215050d240c0beae25cd33);
#
#
#         var popup_7eddfb62a34cc98d55969b8a22e9dcec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0b6d90f164d82e279bb231d3460a599 = $(`&lt;div id=&quot;html_e0b6d90f164d82e279bb231d3460a599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7eddfb62a34cc98d55969b8a22e9dcec.setContent(html_e0b6d90f164d82e279bb231d3460a599);
#
#
#
#         marker_b35180fd0e7854a79c89b40299a01ef3.bindPopup(popup_7eddfb62a34cc98d55969b8a22e9dcec)
#         ;
#
#
#
#
#             var marker_64e662a0afc31a26da4e1b8aeee26cb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b70bb4994c215050d240c0beae25cd33);
#
#
#         var popup_1085a25a794d9bfd96f50153239c8664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e141b6676e01466bf5ed9fac34ed76cb = $(`&lt;div id=&quot;html_e141b6676e01466bf5ed9fac34ed76cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1085a25a794d9bfd96f50153239c8664.setContent(html_e141b6676e01466bf5ed9fac34ed76cb);
#
#
#
#         marker_64e662a0afc31a26da4e1b8aeee26cb9.bindPopup(popup_1085a25a794d9bfd96f50153239c8664)
#         ;
#
#
#
#
#             var marker_f1ef6650306ab1612ab413b508b5dc20 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b70bb4994c215050d240c0beae25cd33);
#
#
#         var popup_4cf97756a4dc78becd9820ca726137d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7068e49b4ed2c9a866e89ff115d0b8c = $(`&lt;div id=&quot;html_e7068e49b4ed2c9a866e89ff115d0b8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4cf97756a4dc78becd9820ca726137d2.setContent(html_e7068e49b4ed2c9a866e89ff115d0b8c);
#
#
#
#         marker_f1ef6650306ab1612ab413b508b5dc20.bindPopup(popup_4cf97756a4dc78becd9820ca726137d2)
#         ;
#
#
#
#
#             var marker_cd93474f3a4d82f631cef23c55f8b806 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b70bb4994c215050d240c0beae25cd33);
#
#
#         var popup_b1639028ba9736b0f5cc3feb80b4d5ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acdab52c2fabc005a796b16850b4efdb = $(`&lt;div id=&quot;html_acdab52c2fabc005a796b16850b4efdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b1639028ba9736b0f5cc3feb80b4d5ff.setContent(html_acdab52c2fabc005a796b16850b4efdb);
#
#
#
#         marker_cd93474f3a4d82f631cef23c55f8b806.bindPopup(popup_b1639028ba9736b0f5cc3feb80b4d5ff)
#         ;
#
#
#
#
#             var marker_8a36dc10c9f9b1dc2f8046f45a484606 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b70bb4994c215050d240c0beae25cd33);
#
#
#         var popup_cc156c533e1f75ebb951b96f846a9ad8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_504ed20ae4b6f44a8dd5d5a3f481532f = $(`&lt;div id=&quot;html_504ed20ae4b6f44a8dd5d5a3f481532f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cc156c533e1f75ebb951b96f846a9ad8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7f34954f920c1f789980682bd570d7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7f34954f920c1f789980682bd570d7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7f34954f920c1f789980682bd570d7d = L.map(
#                 &quot;map_a7f34954f920c1f789980682bd570d7d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc9b5e028aa51418e4cefb66da908146 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc9b5e028aa51418e4cefb66da908146.addTo(map_a7f34954f920c1f789980682bd570d7d);
#
#
#             var feature_group_ead84741072787069bd6c214d0f5e1f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6e7d77113f9ca42452f557882efbc56b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ead84741072787069bd6c214d0f5e1f0);
#
#
#         var popup_400cf8693feb91d1168f5fca5c415015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fccd7558db329699657fd813d93033d = $(`&lt;div id=&quot;html_3fccd7558db329699657fd813d93033d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_400cf8693feb91d1168f5fca5c415015.setContent(html_3fccd7558db329699657fd813d93033d);
#
#
#
#         marker_6e7d77113f9ca42452f557882efbc56b.bindPopup(popup_400cf8693feb91d1168f5fca5c415015)
#         ;
#
#
#
#
#             var marker_66517275dc5134ca2e5674d6747f0586 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ead84741072787069bd6c214d0f5e1f0);
#
#
#         var popup_51394cd9a2cc34c19d1619cd54903add = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3e64abf412010a21592188252c05d39 = $(`&lt;div id=&quot;html_d3e64abf412010a21592188252c05d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_51394cd9a2cc34c19d1619cd54903add.setContent(html_d3e64abf412010a21592188252c05d39);
#
#
#
#         marker_66517275dc5134ca2e5674d6747f0586.bindPopup(popup_51394cd9a2cc34c19d1619cd54903add)
#         ;
#
#
#
#
#             var marker_a7799b85d027e58f735976edf42a1e82 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ead84741072787069bd6c214d0f5e1f0);
#
#
#         var popup_13c9388e77d3ff7e4108b50e472b04fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_353f1d05358c36b73875e0b1dbf79eb7 = $(`&lt;div id=&quot;html_353f1d05358c36b73875e0b1dbf79eb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_13c9388e77d3ff7e4108b50e472b04fd.setContent(html_353f1d05358c36b73875e0b1dbf79eb7);
#
#
#
#         marker_a7799b85d027e58f735976edf42a1e82.bindPopup(popup_13c9388e77d3ff7e4108b50e472b04fd)
#         ;
#
#
#
#
#             var marker_01ab535c38c97f8a73b552c74466d627 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ead84741072787069bd6c214d0f5e1f0);
#
#
#         var popup_d6d2e5c23989a647432b666c0a296dd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c64a56e613b4f1ebb3497211ceaba1f9 = $(`&lt;div id=&quot;html_c64a56e613b4f1ebb3497211ceaba1f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d6d2e5c23989a647432b666c0a296dd0.setContent(html_c64a56e613b4f1ebb3497211ceaba1f9);
#
#
#
#         marker_01ab535c38c97f8a73b552c74466d627.bindPopup(popup_d6d2e5c23989a647432b666c0a296dd0)
#         ;
#
#
#
#
#             var marker_5ff1a629fab3dc1a19ca50120f724b4c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ead84741072787069bd6c214d0f5e1f0);
#
#
#         var popup_61d4587244d17abefa9cc029a8caba1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c7b40850e8f070c06baa85294eb2d01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c7b40850e8f070c06baa85294eb2d01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c7b40850e8f070c06baa85294eb2d01 = L.map(
#                 &quot;map_5c7b40850e8f070c06baa85294eb2d01&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2138f262d89a546ed00f09bd1834584 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2138f262d89a546ed00f09bd1834584.addTo(map_5c7b40850e8f070c06baa85294eb2d01);
#
#
#             var feature_group_ccc9e97f46172dea2019eed7fbc62cf6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ccc9e97f46172dea2019eed7fbc62cf6.addTo(map_5c7b40850e8f070c06baa85294eb2d01);
#
#
#             var feature_group_sub_group_207d836bcfe071cdfb3bcc29832e3fab = L.featureGroup.subGroup(
#                 feature_group_ccc9e97f46172dea2019eed7fbc62cf6
#             );
#
#
#             var marker_8d061dd964bb91f928c9769c8a20c832 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_207d836bcfe071cdfb3bcc29832e3fab);
#
#
#         var popup_e1d0c5609d638e816da861aa1cf55185 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78bff2903ac0e7a121d1fb68040ff05e = $(`&lt;div id=&quot;html_78bff2903ac0e7a121d1fb68040ff05e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e1d0c5609d638e816da861aa1cf55185.setContent(html_78bff2903ac0e7a121d1fb68040ff05e);
#
#
#
#         marker_8d061dd964bb91f928c9769c8a20c832.bindPopup(popup_e1d0c5609d638e816da861aa1cf55185)
#         ;
#
#
#
#
#             var marker_d91ca917dd952599ed673174d7c858ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_207d836bcfe071cdfb3bcc29832e3fab);
#
#
#         var popup_45149ad9fe0038edf14bcf7db775c27f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68d9b37eeb3b99b4970fb3c87e0e446d = $(`&lt;div id=&quot;html_68d9b37eeb3b99b4970fb3c87e0e446d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_45149ad9fe0038edf14bcf7db775c27f.setContent(html_68d9b37eeb3b99b4970fb3c87e0e446d);
#
#
#
#         marker_d91ca917dd952599ed673174d7c858ab.bindPopup(popup_45149ad9fe0038edf14bcf7db775c27f)
#         ;
#
#
#
#
#             var marker_55992c0c0dcb4d931eccdd596adb0255 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_207d836bcfe071cdfb3bcc29832e3fab);
#
#
#         var popup_2c136db66250ef17aa708dcb92378b1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5468c4a22d4e20fbf5b4710791bbbce6 = $(`&lt;div id=&quot;html_5468c4a22d4e20fbf5b4710791bbbce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2c136db66250ef17aa708dcb92378b1c.setContent(html_5468c4a22d4e20fbf5b4710791bbbce6);
#
#
#
#         marker_55992c0c0dcb4d931eccdd596adb0255.bindPopup(popup_2c136db66250ef17aa708dcb92378b1c)
#         ;
#
#
#
#
#             var marker_14ec325b41426cad228d2570d8150b6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_207d836bcfe071cdfb3bcc29832e3fab);
#
#
#         var popup_aa0c15dcab2d85b697c388b6b3b852e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eedb63cc7bb3bed645c8a7764bac040 = $(`&lt;div id=&quot;html_9eedb63cc7bb3bed645c8a7764bac040&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aa0c15dcab2d85b697c388b6b3b852e9.setContent(html_9eedb63cc7bb3bed645c8a7764bac040);
#
#
#
#         marker_
