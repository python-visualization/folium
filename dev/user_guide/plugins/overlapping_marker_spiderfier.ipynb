# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0560e828be07911b200ad1e573451f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0560e828be07911b200ad1e573451f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0560e828be07911b200ad1e573451f0 = L.map(
#                 &quot;map_d0560e828be07911b200ad1e573451f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_951a016a659dc5e8e1501a7ea8d92f1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_951a016a659dc5e8e1501a7ea8d92f1f.addTo(map_d0560e828be07911b200ad1e573451f0);
#
#
#             var marker_67f20281d4b3e7772af1b769da77ca94 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d0560e828be07911b200ad1e573451f0);
#
#
#         var popup_21c8a907de78fa28cd4c0499ea815653 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66497e5930388b90d77a1cbdbcaf51ae = $(`&lt;div id=&quot;html_66497e5930388b90d77a1cbdbcaf51ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_21c8a907de78fa28cd4c0499ea815653.setContent(html_66497e5930388b90d77a1cbdbcaf51ae);
#
#
#
#         marker_67f20281d4b3e7772af1b769da77ca94.bindPopup(popup_21c8a907de78fa28cd4c0499ea815653)
#         ;
#
#
#
#
#             var marker_70c6cf823c12dff1cd5038f5239cc104 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d0560e828be07911b200ad1e573451f0);
#
#
#         var popup_bf3d26cd51f04fe3f9dac3a54c9adf98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0304b833761d0bfdf35dbbfce937aec0 = $(`&lt;div id=&quot;html_0304b833761d0bfdf35dbbfce937aec0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bf3d26cd51f04fe3f9dac3a54c9adf98.setContent(html_0304b833761d0bfdf35dbbfce937aec0);
#
#
#
#         marker_70c6cf823c12dff1cd5038f5239cc104.bindPopup(popup_bf3d26cd51f04fe3f9dac3a54c9adf98)
#         ;
#
#
#
#
#             var marker_59b43475b068d50eb91be3d6e10e9726 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d0560e828be07911b200ad1e573451f0);
#
#
#         var popup_302456892636150a3dfab165a257a9b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8c45b08d8fe1f794a1be1a5fa70c8f3 = $(`&lt;div id=&quot;html_e8c45b08d8fe1f794a1be1a5fa70c8f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_302456892636150a3dfab165a257a9b4.setContent(html_e8c45b08d8fe1f794a1be1a5fa70c8f3);
#
#
#
#         marker_59b43475b068d50eb91be3d6e10e9726.bindPopup(popup_302456892636150a3dfab165a257a9b4)
#         ;
#
#
#
#
#             var marker_ca56c3eb91ffb2d15bb51bd259113652 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d0560e828be07911b200ad1e573451f0);
#
#
#         var popup_58b06d98c1deb6ff5e5966d1416dd4b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b65149ad35a8b196e26a188b64b5530f = $(`&lt;div id=&quot;html_b65149ad35a8b196e26a188b64b5530f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_58b06d98c1deb6ff5e5966d1416dd4b1.setContent(html_b65149ad35a8b196e26a188b64b5530f);
#
#
#
#         marker_ca56c3eb91ffb2d15bb51bd259113652.bindPopup(popup_58b06d98c1deb6ff5e5966d1416dd4b1)
#         ;
#
#
#
#
#             var marker_5c98d218fe9feab4aceb7d0dcb4ce963 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d0560e828be07911b200ad1e573451f0);
#
#
#         var popup_e9e6f9af0a495545101514b0869d9e04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e9414194497ee58ac5d5c010676cd2f = $(`&lt;div id=&quot;html_3e9414194497ee58ac5d5c010676cd2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e9e6f9af0a495545101514b0869d9e04.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fad432896bbdd4ebe31ee404ccf6a55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fad432896bbdd4ebe31ee404ccf6a55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fad432896bbdd4ebe31ee404ccf6a55 = L.map(
#                 &quot;map_0fad432896bbdd4ebe31ee404ccf6a55&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8255f3171af0dec5e5c94bb03e50944c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8255f3171af0dec5e5c94bb03e50944c.addTo(map_0fad432896bbdd4ebe31ee404ccf6a55);
#
#
#             var feature_group_80998d37b0a262d38ebe5ee2a340a5db = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6f9bd0c69213c4c3e9868afa5399f491 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_80998d37b0a262d38ebe5ee2a340a5db);
#
#
#         var popup_aa5a49928a35e14b220fcab995dbed43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fb2dbe95565ec18e8b0454c0a92fed2 = $(`&lt;div id=&quot;html_0fb2dbe95565ec18e8b0454c0a92fed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_aa5a49928a35e14b220fcab995dbed43.setContent(html_0fb2dbe95565ec18e8b0454c0a92fed2);
#
#
#
#         marker_6f9bd0c69213c4c3e9868afa5399f491.bindPopup(popup_aa5a49928a35e14b220fcab995dbed43)
#         ;
#
#
#
#
#             var marker_2854bc1875e06da445cfcd56d62d32bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_80998d37b0a262d38ebe5ee2a340a5db);
#
#
#         var popup_a278675f19b6b7a4031ee00a4c9a35ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6558a6f7185c7030ec3c24f8883b8d9f = $(`&lt;div id=&quot;html_6558a6f7185c7030ec3c24f8883b8d9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a278675f19b6b7a4031ee00a4c9a35ee.setContent(html_6558a6f7185c7030ec3c24f8883b8d9f);
#
#
#
#         marker_2854bc1875e06da445cfcd56d62d32bc.bindPopup(popup_a278675f19b6b7a4031ee00a4c9a35ee)
#         ;
#
#
#
#
#             var marker_cb59deb284937206787496ee82f0360c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_80998d37b0a262d38ebe5ee2a340a5db);
#
#
#         var popup_5f6d3704615cd4ebac6a170c4bde38af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a0c50b272e7ac660f0ae4e01dd2bbc9 = $(`&lt;div id=&quot;html_0a0c50b272e7ac660f0ae4e01dd2bbc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5f6d3704615cd4ebac6a170c4bde38af.setContent(html_0a0c50b272e7ac660f0ae4e01dd2bbc9);
#
#
#
#         marker_cb59deb284937206787496ee82f0360c.bindPopup(popup_5f6d3704615cd4ebac6a170c4bde38af)
#         ;
#
#
#
#
#             var marker_901cbef02cc029f6fc2ab34d8c622274 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_80998d37b0a262d38ebe5ee2a340a5db);
#
#
#         var popup_5f2792867b233fcf0bf0e8ba00f383cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ed34efaa333b70b990bb6be4a08ae5 = $(`&lt;div id=&quot;html_52ed34efaa333b70b990bb6be4a08ae5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5f2792867b233fcf0bf0e8ba00f383cf.setContent(html_52ed34efaa333b70b990bb6be4a08ae5);
#
#
#
#         marker_901cbef02cc029f6fc2ab34d8c622274.bindPopup(popup_5f2792867b233fcf0bf0e8ba00f383cf)
#         ;
#
#
#
#
#             var marker_cef7bb4b04dbed7133951edab566231d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_80998d37b0a262d38ebe5ee2a340a5db);
#
#
#         var popup_e557a473bcc1e861190067e2c2f19fe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b0fd433ef8450b3606d8733ab3723bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b0fd433ef8450b3606d8733ab3723bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b0fd433ef8450b3606d8733ab3723bf = L.map(
#                 &quot;map_3b0fd433ef8450b3606d8733ab3723bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f88832281625732766e557956e495050 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f88832281625732766e557956e495050.addTo(map_3b0fd433ef8450b3606d8733ab3723bf);
#
#
#             var feature_group_a4c54f81948bc61bc99e7a876d82ae11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a4c54f81948bc61bc99e7a876d82ae11.addTo(map_3b0fd433ef8450b3606d8733ab3723bf);
#
#
#             var feature_group_sub_group_425c5abc2a50ef1f64405840c1e91c24 = L.featureGroup.subGroup(
#                 feature_group_a4c54f81948bc61bc99e7a876d82ae11
#             );
#
#
#             var marker_de669fe98ac6c8faca61a4b29b2d7aa7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_425c5abc2a50ef1f64405840c1e91c24);
#
#
#         var popup_f85413d5ae1be6e1c47ddbb55f9b75d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a62b80edfe3aa530de3e0a176b298a2 = $(`&lt;div id=&quot;html_9a62b80edfe3aa530de3e0a176b298a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f85413d5ae1be6e1c47ddbb55f9b75d4.setContent(html_9a62b80edfe3aa530de3e0a176b298a2);
#
#
#
#         marker_de669fe98ac6c8faca61a4b29b2d7aa7.bindPopup(popup_f85413d5ae1be6e1c47ddbb55f9b75d4)
#         ;
#
#
#
#
#             var marker_0fca2a222b6630ea3a430de59ba7cacd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_425c5abc2a50ef1f64405840c1e91c24);
#
#
#         var popup_943d7023e902fe15a89571f4c5aa9cff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0a5222acf62841fbeb87efab44ba150 = $(`&lt;div id=&quot;html_d0a5222acf62841fbeb87efab44ba150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_943d7023e902fe15a89571f4c5aa9cff.setContent(html_d0a5222acf62841fbeb87efab44ba150);
#
#
#
#         marker_0fca2a222b6630ea3a430de59ba7cacd.bindPopup(popup_943d7023e902fe15a89571f4c5aa9cff)
#         ;
#
#
#
#
#             var marker_19cc3ed7f2f34c7182f356638cd86fe9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_425c5abc2a50ef1f64405840c1e91c24);
#
#
#         var popup_4cab58c24c222305ecde661cd0ae2531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_405ba553ef31b151085e5f40a1e905f5 = $(`&lt;div id=&quot;html_405ba553ef31b151085e5f40a1e905f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4cab58c24c222305ecde661cd0ae2531.setContent(html_405ba553ef31b151085e5f40a1e905f5);
#
#
#
#         marker_19cc3ed7f2f34c7182f356638cd86fe9.bindPopup(popup_4cab58c24c222305ecde661cd0ae2531)
#         ;
#
#
#
#
#             var marker_787e34a6b6703652f6123456d1ec8ddf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_425c5abc2a50ef1f64405840c1e91c24);
#
#
#         var popup_dcf1d33f7cb55811684498fabc889fbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f92798d20c87dfffec03457ab95d972 = $(`&lt;div id=&quot;html_9f92798d20c87dfffec03457ab95d972&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dcf1d33f7cb55811684498fabc889fbf.setContent(html_9f92798d20c87dfffec03457ab95d972);
#
#
#
#         marker_
