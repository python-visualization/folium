# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f8206710211d70ecaa6b579fe0adcbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f8206710211d70ecaa6b579fe0adcbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f8206710211d70ecaa6b579fe0adcbf = L.map(
#                 &quot;map_6f8206710211d70ecaa6b579fe0adcbf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b1fa2715884f7c85b0f970951c387b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b1fa2715884f7c85b0f970951c387b4.addTo(map_6f8206710211d70ecaa6b579fe0adcbf);
#
#
#             var marker_d437f7585a9ad6954b8f6ed144ee6872 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6f8206710211d70ecaa6b579fe0adcbf);
#
#
#         var popup_ac7c32155cdf52e5f7ee15e8d7b70172 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ecca3303ddb3feb3709b898e27d5d0 = $(`&lt;div id=&quot;html_52ecca3303ddb3feb3709b898e27d5d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ac7c32155cdf52e5f7ee15e8d7b70172.setContent(html_52ecca3303ddb3feb3709b898e27d5d0);
#
#
#
#         marker_d437f7585a9ad6954b8f6ed144ee6872.bindPopup(popup_ac7c32155cdf52e5f7ee15e8d7b70172)
#         ;
#
#
#
#
#             var marker_4d35b60a02a5116b483d85d7bab26168 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6f8206710211d70ecaa6b579fe0adcbf);
#
#
#         var popup_a56ae54afe3c3cb63048e0fe8fe87f77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35f4d4f09c9f2fd0d404db26e3f592ab = $(`&lt;div id=&quot;html_35f4d4f09c9f2fd0d404db26e3f592ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a56ae54afe3c3cb63048e0fe8fe87f77.setContent(html_35f4d4f09c9f2fd0d404db26e3f592ab);
#
#
#
#         marker_4d35b60a02a5116b483d85d7bab26168.bindPopup(popup_a56ae54afe3c3cb63048e0fe8fe87f77)
#         ;
#
#
#
#
#             var marker_1f46b03c0ce23aacb624d045f3d3b074 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6f8206710211d70ecaa6b579fe0adcbf);
#
#
#         var popup_c1e3c83b253e8222335d6416ce3aecd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d36db62da67e65697379ea7c752b647 = $(`&lt;div id=&quot;html_9d36db62da67e65697379ea7c752b647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c1e3c83b253e8222335d6416ce3aecd6.setContent(html_9d36db62da67e65697379ea7c752b647);
#
#
#
#         marker_1f46b03c0ce23aacb624d045f3d3b074.bindPopup(popup_c1e3c83b253e8222335d6416ce3aecd6)
#         ;
#
#
#
#
#             var marker_dcd378ae83e2dcdd5d06b264d58daae8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6f8206710211d70ecaa6b579fe0adcbf);
#
#
#         var popup_634a49e2fc068277ec522789cd445d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5fc84b2cecbe8573bf968547675f8f5 = $(`&lt;div id=&quot;html_d5fc84b2cecbe8573bf968547675f8f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_634a49e2fc068277ec522789cd445d1b.setContent(html_d5fc84b2cecbe8573bf968547675f8f5);
#
#
#
#         marker_dcd378ae83e2dcdd5d06b264d58daae8.bindPopup(popup_634a49e2fc068277ec522789cd445d1b)
#         ;
#
#
#
#
#             var marker_766ab2a1451c71041042925287ee25c9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6f8206710211d70ecaa6b579fe0adcbf);
#
#
#         var popup_26e858abc1f1a63233cf6ca1f0b6202f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_926a8b7b1bc6283dde3b07dbac922374 = $(`&lt;div id=&quot;html_926a8b7b1bc6283dde3b07dbac922374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_26e858abc1f1a63233cf6ca1f0b6202f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c541863a829cf7d4f432723487bb436 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c541863a829cf7d4f432723487bb436&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c541863a829cf7d4f432723487bb436 = L.map(
#                 &quot;map_3c541863a829cf7d4f432723487bb436&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b53a402ccd2fc9f795877243d0a229e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b53a402ccd2fc9f795877243d0a229e.addTo(map_3c541863a829cf7d4f432723487bb436);
#
#
#             var feature_group_b2ad77bbf3f823c2910b45dd45eb5bde = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cbcf14dd528d813ec9eb241d84f994cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b2ad77bbf3f823c2910b45dd45eb5bde);
#
#
#         var popup_8a35a7a0e2cc6e557187e9c73cc7353d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a962cfa31c44195e6000f796dcec040a = $(`&lt;div id=&quot;html_a962cfa31c44195e6000f796dcec040a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8a35a7a0e2cc6e557187e9c73cc7353d.setContent(html_a962cfa31c44195e6000f796dcec040a);
#
#
#
#         marker_cbcf14dd528d813ec9eb241d84f994cc.bindPopup(popup_8a35a7a0e2cc6e557187e9c73cc7353d)
#         ;
#
#
#
#
#             var marker_f68edbc2789d1549d229d3b9c4eef974 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b2ad77bbf3f823c2910b45dd45eb5bde);
#
#
#         var popup_b13482f3ca068cd90345aed88c4c539e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff2f6dbb25a1d8d1bbc1a68073b12602 = $(`&lt;div id=&quot;html_ff2f6dbb25a1d8d1bbc1a68073b12602&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b13482f3ca068cd90345aed88c4c539e.setContent(html_ff2f6dbb25a1d8d1bbc1a68073b12602);
#
#
#
#         marker_f68edbc2789d1549d229d3b9c4eef974.bindPopup(popup_b13482f3ca068cd90345aed88c4c539e)
#         ;
#
#
#
#
#             var marker_95d470825dc38b4eff9b46264ddc9005 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b2ad77bbf3f823c2910b45dd45eb5bde);
#
#
#         var popup_a1a6b7b232bc3360a50f76db03168685 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4da7841d42cb3f77cb04877298b0e35 = $(`&lt;div id=&quot;html_d4da7841d42cb3f77cb04877298b0e35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a1a6b7b232bc3360a50f76db03168685.setContent(html_d4da7841d42cb3f77cb04877298b0e35);
#
#
#
#         marker_95d470825dc38b4eff9b46264ddc9005.bindPopup(popup_a1a6b7b232bc3360a50f76db03168685)
#         ;
#
#
#
#
#             var marker_fa0174f6a13a17b5efe20783380bfc10 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b2ad77bbf3f823c2910b45dd45eb5bde);
#
#
#         var popup_bcc85ba5d2d776683510da59d3b5cdc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f468d8d6180649b93913bb10cdd624a = $(`&lt;div id=&quot;html_9f468d8d6180649b93913bb10cdd624a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bcc85ba5d2d776683510da59d3b5cdc5.setContent(html_9f468d8d6180649b93913bb10cdd624a);
#
#
#
#         marker_fa0174f6a13a17b5efe20783380bfc10.bindPopup(popup_bcc85ba5d2d776683510da59d3b5cdc5)
#         ;
#
#
#
#
#             var marker_04a9547263097fb60b2e23ed17ec42c7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b2ad77bbf3f823c2910b45dd45eb5bde);
#
#
#         var popup_c5ee4a57924c389e4ed20346cbb45e47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56ad140eba0829046f05ef9dd80d32f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56ad140eba0829046f05ef9dd80d32f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56ad140eba0829046f05ef9dd80d32f2 = L.map(
#                 &quot;map_56ad140eba0829046f05ef9dd80d32f2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ffb18393d6d45a32b145757db82c7b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ffb18393d6d45a32b145757db82c7b3.addTo(map_56ad140eba0829046f05ef9dd80d32f2);
#
#
#             var feature_group_9d7e85a07bbd942e503b892d58c30fb7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9d7e85a07bbd942e503b892d58c30fb7.addTo(map_56ad140eba0829046f05ef9dd80d32f2);
#
#
#             var feature_group_sub_group_c5d98e8273a1142d4909f54116b71a59 = L.featureGroup.subGroup(
#                 feature_group_9d7e85a07bbd942e503b892d58c30fb7
#             );
#
#
#             var marker_ecf084ecba853ee27f9b809c572209b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5d98e8273a1142d4909f54116b71a59);
#
#
#         var popup_6dcaa453ec8d417620baf4c9d7081822 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_566939b4a09ca32ce7c542c31912907e = $(`&lt;div id=&quot;html_566939b4a09ca32ce7c542c31912907e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6dcaa453ec8d417620baf4c9d7081822.setContent(html_566939b4a09ca32ce7c542c31912907e);
#
#
#
#         marker_ecf084ecba853ee27f9b809c572209b4.bindPopup(popup_6dcaa453ec8d417620baf4c9d7081822)
#         ;
#
#
#
#
#             var marker_99ae8be3e103c762424a8fbf7ff56bd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5d98e8273a1142d4909f54116b71a59);
#
#
#         var popup_00ef5e3d6dd12e03c364418e426374bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d68a9cbc8b3e2718ee9b8e121ebe7819 = $(`&lt;div id=&quot;html_d68a9cbc8b3e2718ee9b8e121ebe7819&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_00ef5e3d6dd12e03c364418e426374bf.setContent(html_d68a9cbc8b3e2718ee9b8e121ebe7819);
#
#
#
#         marker_99ae8be3e103c762424a8fbf7ff56bd6.bindPopup(popup_00ef5e3d6dd12e03c364418e426374bf)
#         ;
#
#
#
#
#             var marker_c1dfcc8a59210bb4ba7cc679a40ebf8e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5d98e8273a1142d4909f54116b71a59);
#
#
#         var popup_15eb12c9f86cc17b529b07219ae45304 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7e851444a456ab2e47dffcd98afea3d = $(`&lt;div id=&quot;html_b7e851444a456ab2e47dffcd98afea3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_15eb12c9f86cc17b529b07219ae45304.setContent(html_b7e851444a456ab2e47dffcd98afea3d);
#
#
#
#         marker_c1dfcc8a59210bb4ba7cc679a40ebf8e.bindPopup(popup_15eb12c9f86cc17b529b07219ae45304)
#         ;
#
#
#
#
#             var marker_0cdb7a3835101459ce9e13e75ed9c450 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5d98e8273a1142d4909f54116b71a59);
#
#
#         var popup_29e11dfaefe03d826bbde85061b82409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9143a4de0aa0883984894b81aa1b468 = $(`&lt;div id=&quot;html_c9143a4de0aa0883984894b81aa1b468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_29e11dfaefe03d826bbde85061b82409.setContent(html_c9143a4de0aa0883984894b81aa1b468);
#
#
#
#         marker_
