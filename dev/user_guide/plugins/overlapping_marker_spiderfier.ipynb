# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca939b4100f85e63663e61f259bc8b17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca939b4100f85e63663e61f259bc8b17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca939b4100f85e63663e61f259bc8b17 = L.map(
#                 &quot;map_ca939b4100f85e63663e61f259bc8b17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1017dfdd427a73a83e1789e376bceea7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1017dfdd427a73a83e1789e376bceea7.addTo(map_ca939b4100f85e63663e61f259bc8b17);
#
#
#             var marker_433c19ecf79364fe80ed4292363e75cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ca939b4100f85e63663e61f259bc8b17);
#
#
#         var popup_ef3e55eb46ffe59407c47dde3146f33c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b8720036e99759566c7bfbd7cd8f07a = $(`&lt;div id=&quot;html_5b8720036e99759566c7bfbd7cd8f07a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ef3e55eb46ffe59407c47dde3146f33c.setContent(html_5b8720036e99759566c7bfbd7cd8f07a);
#
#
#
#         marker_433c19ecf79364fe80ed4292363e75cd.bindPopup(popup_ef3e55eb46ffe59407c47dde3146f33c)
#         ;
#
#
#
#
#             var marker_bc1b9c4b069c8cb0ddf6b38ddb055947 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ca939b4100f85e63663e61f259bc8b17);
#
#
#         var popup_c1f7bc4a21fc928d4dee792755df9752 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_906023180c6fcacc60689a5cd840dc36 = $(`&lt;div id=&quot;html_906023180c6fcacc60689a5cd840dc36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c1f7bc4a21fc928d4dee792755df9752.setContent(html_906023180c6fcacc60689a5cd840dc36);
#
#
#
#         marker_bc1b9c4b069c8cb0ddf6b38ddb055947.bindPopup(popup_c1f7bc4a21fc928d4dee792755df9752)
#         ;
#
#
#
#
#             var marker_c32a9317c81879be3f70ee70d02b4992 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ca939b4100f85e63663e61f259bc8b17);
#
#
#         var popup_aeaa5f074a3f0fe474399b69a6e39fa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b55c169328603836ad262ecf5978f659 = $(`&lt;div id=&quot;html_b55c169328603836ad262ecf5978f659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_aeaa5f074a3f0fe474399b69a6e39fa0.setContent(html_b55c169328603836ad262ecf5978f659);
#
#
#
#         marker_c32a9317c81879be3f70ee70d02b4992.bindPopup(popup_aeaa5f074a3f0fe474399b69a6e39fa0)
#         ;
#
#
#
#
#             var marker_83455662e7bce6dc3633e47a5f4a8e18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ca939b4100f85e63663e61f259bc8b17);
#
#
#         var popup_850609712c04fb25d647c9ded1aa9296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fed36388f90589ef37bdd7fa4b4c868 = $(`&lt;div id=&quot;html_8fed36388f90589ef37bdd7fa4b4c868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_850609712c04fb25d647c9ded1aa9296.setContent(html_8fed36388f90589ef37bdd7fa4b4c868);
#
#
#
#         marker_83455662e7bce6dc3633e47a5f4a8e18.bindPopup(popup_850609712c04fb25d647c9ded1aa9296)
#         ;
#
#
#
#
#             var marker_c1ccf5435b00308d773192e963279127 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ca939b4100f85e63663e61f259bc8b17);
#
#
#         var popup_10a1484c131092029d4834b6e8cbf1c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78d80af060231e0b10550ddf6dc3f6f6 = $(`&lt;div id=&quot;html_78d80af060231e0b10550ddf6dc3f6f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_10a1484c131092029d4834b6e8cbf1c4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc7e4a2561ca858a0c5e32c49e7ac696 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc7e4a2561ca858a0c5e32c49e7ac696&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc7e4a2561ca858a0c5e32c49e7ac696 = L.map(
#                 &quot;map_fc7e4a2561ca858a0c5e32c49e7ac696&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ecaaac14f7f9720080fe7fe891e3318 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ecaaac14f7f9720080fe7fe891e3318.addTo(map_fc7e4a2561ca858a0c5e32c49e7ac696);
#
#
#             var feature_group_27880be1280b4b42906871918b13e69c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5903b5e03fef637662b2cc337b774133 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_27880be1280b4b42906871918b13e69c);
#
#
#         var popup_e1ae3bbdf0e7647b34d9f28305062271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3db4006550ce371cb7333d4a7c2c6e31 = $(`&lt;div id=&quot;html_3db4006550ce371cb7333d4a7c2c6e31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e1ae3bbdf0e7647b34d9f28305062271.setContent(html_3db4006550ce371cb7333d4a7c2c6e31);
#
#
#
#         marker_5903b5e03fef637662b2cc337b774133.bindPopup(popup_e1ae3bbdf0e7647b34d9f28305062271)
#         ;
#
#
#
#
#             var marker_4e7069f83bd7b36d24828ee28934168a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_27880be1280b4b42906871918b13e69c);
#
#
#         var popup_5a7bfc1714cc32f92f4a549c9f185940 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa56629a5490636c900cded91ee0f9de = $(`&lt;div id=&quot;html_fa56629a5490636c900cded91ee0f9de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5a7bfc1714cc32f92f4a549c9f185940.setContent(html_fa56629a5490636c900cded91ee0f9de);
#
#
#
#         marker_4e7069f83bd7b36d24828ee28934168a.bindPopup(popup_5a7bfc1714cc32f92f4a549c9f185940)
#         ;
#
#
#
#
#             var marker_805bcc61e911b695a50766fb17fe7760 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_27880be1280b4b42906871918b13e69c);
#
#
#         var popup_522144393a7430d511d3e56b5bd1868e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d28a470959a049940441ff7924cb7a75 = $(`&lt;div id=&quot;html_d28a470959a049940441ff7924cb7a75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_522144393a7430d511d3e56b5bd1868e.setContent(html_d28a470959a049940441ff7924cb7a75);
#
#
#
#         marker_805bcc61e911b695a50766fb17fe7760.bindPopup(popup_522144393a7430d511d3e56b5bd1868e)
#         ;
#
#
#
#
#             var marker_f5a57f5182b1593a549a50739931beb7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_27880be1280b4b42906871918b13e69c);
#
#
#         var popup_ca5acbe1e06d06537db56ac2745e3958 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cdf08354e82cfe06690dbad41e3becf = $(`&lt;div id=&quot;html_7cdf08354e82cfe06690dbad41e3becf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ca5acbe1e06d06537db56ac2745e3958.setContent(html_7cdf08354e82cfe06690dbad41e3becf);
#
#
#
#         marker_f5a57f5182b1593a549a50739931beb7.bindPopup(popup_ca5acbe1e06d06537db56ac2745e3958)
#         ;
#
#
#
#
#             var marker_f8b72191b10c56b6c90da5fa1ab95ceb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_27880be1280b4b42906871918b13e69c);
#
#
#         var popup_a07934614778d27aa74379f97849459e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0074a07176372423cb0c9295d215aadb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0074a07176372423cb0c9295d215aadb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0074a07176372423cb0c9295d215aadb = L.map(
#                 &quot;map_0074a07176372423cb0c9295d215aadb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9703eeba2eb893204b9b6f96c4803a8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9703eeba2eb893204b9b6f96c4803a8c.addTo(map_0074a07176372423cb0c9295d215aadb);
#
#
#             var feature_group_a8640cdc1ef8ffebaaf9e3a9217bc085 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a8640cdc1ef8ffebaaf9e3a9217bc085.addTo(map_0074a07176372423cb0c9295d215aadb);
#
#
#             var feature_group_sub_group_35e13ec3c3a569e311e3ca6f7ab99572 = L.featureGroup.subGroup(
#                 feature_group_a8640cdc1ef8ffebaaf9e3a9217bc085
#             );
#
#
#             var marker_ab466d0d427a0e7da556a381f231306b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_35e13ec3c3a569e311e3ca6f7ab99572);
#
#
#         var popup_ee4fa828fe2eaa2efee3a68df59d3cc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f5cbef16cf4308b13f273e982aa4bc2 = $(`&lt;div id=&quot;html_3f5cbef16cf4308b13f273e982aa4bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ee4fa828fe2eaa2efee3a68df59d3cc2.setContent(html_3f5cbef16cf4308b13f273e982aa4bc2);
#
#
#
#         marker_ab466d0d427a0e7da556a381f231306b.bindPopup(popup_ee4fa828fe2eaa2efee3a68df59d3cc2)
#         ;
#
#
#
#
#             var marker_fdf3fc25fa7dd5c937b574b85e123f5b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_35e13ec3c3a569e311e3ca6f7ab99572);
#
#
#         var popup_233892f030385edee5fc44c00947fde3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51374d21781d629bd3f7c804240faf73 = $(`&lt;div id=&quot;html_51374d21781d629bd3f7c804240faf73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_233892f030385edee5fc44c00947fde3.setContent(html_51374d21781d629bd3f7c804240faf73);
#
#
#
#         marker_fdf3fc25fa7dd5c937b574b85e123f5b.bindPopup(popup_233892f030385edee5fc44c00947fde3)
#         ;
#
#
#
#
#             var marker_189ca96652e63c3a1fc6dd2c3c1fa1b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_35e13ec3c3a569e311e3ca6f7ab99572);
#
#
#         var popup_4828b55f10a8f9e47ab5c4ad2cd0363c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc3967574e0fdcc5e47d0953f20177ad = $(`&lt;div id=&quot;html_bc3967574e0fdcc5e47d0953f20177ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4828b55f10a8f9e47ab5c4ad2cd0363c.setContent(html_bc3967574e0fdcc5e47d0953f20177ad);
#
#
#
#         marker_189ca96652e63c3a1fc6dd2c3c1fa1b8.bindPopup(popup_4828b55f10a8f9e47ab5c4ad2cd0363c)
#         ;
#
#
#
#
#             var marker_2d9c2ca8985207e9bd11318b75c46531 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_35e13ec3c3a569e311e3ca6f7ab99572);
#
#
#         var popup_122d33f0b3655becf1028bb4617472d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c51ec96a5107dd72eca53ad2dec574b7 = $(`&lt;div id=&quot;html_c51ec96a5107dd72eca53ad2dec574b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_122d33f0b3655becf1028bb4617472d5.setContent(html_c51ec96a5107dd72eca53ad2dec574b7);
#
#
#
#         marker_
