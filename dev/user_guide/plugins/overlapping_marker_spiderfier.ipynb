# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25b29bbf25a8fe16d0c4d25c586fb17c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25b29bbf25a8fe16d0c4d25c586fb17c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25b29bbf25a8fe16d0c4d25c586fb17c = L.map(
#                 &quot;map_25b29bbf25a8fe16d0c4d25c586fb17c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_443e1038f1658798ab7873342a737972 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_443e1038f1658798ab7873342a737972.addTo(map_25b29bbf25a8fe16d0c4d25c586fb17c);
#
#
#             var marker_814e82367c9ba8caf57d5f7c7e5e6dc8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_25b29bbf25a8fe16d0c4d25c586fb17c);
#
#
#         var popup_a70807eec3b463ca3df8d49359b319d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8465ddda7b9a84933b45d291cac9c878 = $(`&lt;div id=&quot;html_8465ddda7b9a84933b45d291cac9c878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a70807eec3b463ca3df8d49359b319d8.setContent(html_8465ddda7b9a84933b45d291cac9c878);
#
#
#
#         marker_814e82367c9ba8caf57d5f7c7e5e6dc8.bindPopup(popup_a70807eec3b463ca3df8d49359b319d8)
#         ;
#
#
#
#
#             var marker_2436364a6a0177d797a1e575a349f887 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_25b29bbf25a8fe16d0c4d25c586fb17c);
#
#
#         var popup_2e51bf7db5ac491c6440e6d9f16cfdac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f44d89b728c64eeab5228b00f134b5f = $(`&lt;div id=&quot;html_8f44d89b728c64eeab5228b00f134b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2e51bf7db5ac491c6440e6d9f16cfdac.setContent(html_8f44d89b728c64eeab5228b00f134b5f);
#
#
#
#         marker_2436364a6a0177d797a1e575a349f887.bindPopup(popup_2e51bf7db5ac491c6440e6d9f16cfdac)
#         ;
#
#
#
#
#             var marker_abc55ba3a2193e19e5afc64695366388 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_25b29bbf25a8fe16d0c4d25c586fb17c);
#
#
#         var popup_df3a0ae27236d5fc382b10f36cdeefab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b398a33e480b8bfb670d283eec2abdba = $(`&lt;div id=&quot;html_b398a33e480b8bfb670d283eec2abdba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_df3a0ae27236d5fc382b10f36cdeefab.setContent(html_b398a33e480b8bfb670d283eec2abdba);
#
#
#
#         marker_abc55ba3a2193e19e5afc64695366388.bindPopup(popup_df3a0ae27236d5fc382b10f36cdeefab)
#         ;
#
#
#
#
#             var marker_1a783553f6ce6468dbc8208f9043466d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_25b29bbf25a8fe16d0c4d25c586fb17c);
#
#
#         var popup_c2a6f07f5fb94de4cd79185e13ff2aef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99bf97835cd79d2b9bab18fec702f9a4 = $(`&lt;div id=&quot;html_99bf97835cd79d2b9bab18fec702f9a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c2a6f07f5fb94de4cd79185e13ff2aef.setContent(html_99bf97835cd79d2b9bab18fec702f9a4);
#
#
#
#         marker_1a783553f6ce6468dbc8208f9043466d.bindPopup(popup_c2a6f07f5fb94de4cd79185e13ff2aef)
#         ;
#
#
#
#
#             var marker_a9ef4bf8f0470898b4af0dfcf54718b0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_25b29bbf25a8fe16d0c4d25c586fb17c);
#
#
#         var popup_0aa004601b1cfe0b48c3ce371cb7273e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5ce6aae27999c54f9b2b117f67223d3 = $(`&lt;div id=&quot;html_b5ce6aae27999c54f9b2b117f67223d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0aa004601b1cfe0b48c3ce371cb727

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_991699f81fc5953d77a9c12bcb0aaaac {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_991699f81fc5953d77a9c12bcb0aaaac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_991699f81fc5953d77a9c12bcb0aaaac = L.map(
#                 &quot;map_991699f81fc5953d77a9c12bcb0aaaac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a51db872c3d01aa03d3e8072296fa49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a51db872c3d01aa03d3e8072296fa49.addTo(map_991699f81fc5953d77a9c12bcb0aaaac);
#
#
#             var feature_group_b06527a77c85caa9d2400e66be956168 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_efdc550d8b66a3d0e6b92b9973422ac3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b06527a77c85caa9d2400e66be956168);
#
#
#         var popup_7d8d5c7342227f9a6405e5ab7b9a6a82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd1461378ad3b784d181e6f25056f97b = $(`&lt;div id=&quot;html_bd1461378ad3b784d181e6f25056f97b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7d8d5c7342227f9a6405e5ab7b9a6a82.setContent(html_bd1461378ad3b784d181e6f25056f97b);
#
#
#
#         marker_efdc550d8b66a3d0e6b92b9973422ac3.bindPopup(popup_7d8d5c7342227f9a6405e5ab7b9a6a82)
#         ;
#
#
#
#
#             var marker_4dd2f8f7d65599781f57cb8aee162cc3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b06527a77c85caa9d2400e66be956168);
#
#
#         var popup_fe3b8abdb2acbfc4f4a78e6e7a54b2ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25eaf99a84b279270798475347ca0bd4 = $(`&lt;div id=&quot;html_25eaf99a84b279270798475347ca0bd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fe3b8abdb2acbfc4f4a78e6e7a54b2ba.setContent(html_25eaf99a84b279270798475347ca0bd4);
#
#
#
#         marker_4dd2f8f7d65599781f57cb8aee162cc3.bindPopup(popup_fe3b8abdb2acbfc4f4a78e6e7a54b2ba)
#         ;
#
#
#
#
#             var marker_cd59a5f0a1f8bd990d89aef8253fc47d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b06527a77c85caa9d2400e66be956168);
#
#
#         var popup_f72ee226e5aab5c71ae9dba6617ac9b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74e8e4a6d8d835e14478405b801f26fb = $(`&lt;div id=&quot;html_74e8e4a6d8d835e14478405b801f26fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f72ee226e5aab5c71ae9dba6617ac9b4.setContent(html_74e8e4a6d8d835e14478405b801f26fb);
#
#
#
#         marker_cd59a5f0a1f8bd990d89aef8253fc47d.bindPopup(popup_f72ee226e5aab5c71ae9dba6617ac9b4)
#         ;
#
#
#
#
#             var marker_7a9341f98e2d0d684915a0dd427e19a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b06527a77c85caa9d2400e66be956168);
#
#
#         var popup_6589b03173301d17f6b59dac0891d07c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6abbd368e68899c8715d0383f47375b8 = $(`&lt;div id=&quot;html_6abbd368e68899c8715d0383f47375b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6589b03173301d17f6b59dac0891d07c.setContent(html_6abbd368e68899c8715d0383f47375b8);
#
#
#
#         marker_7a9341f98e2d0d684915a0dd427e19a4.bindPopup(popup_6589b03173301d17f6b59dac0891d07c)
#         ;
#
#
#
#
#             var marker_d3eb94b3bd0fb301b2981c48ce2cf6ef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b06527a77c85caa9d2400e66be956168);
#
#
#         var popup_5504306f5e8b6a2cf5ec187ba5620031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a08f6d00cf66f1e354e12acb2cd908d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a08f6d00cf66f1e354e12acb2cd908d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a08f6d00cf66f1e354e12acb2cd908d = L.map(
#                 &quot;map_9a08f6d00cf66f1e354e12acb2cd908d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_637d197e5be0ed748b0078752c413831 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_637d197e5be0ed748b0078752c413831.addTo(map_9a08f6d00cf66f1e354e12acb2cd908d);
#
#
#             var feature_group_fed3e507a2a039cf4198f6926e323f28 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fed3e507a2a039cf4198f6926e323f28.addTo(map_9a08f6d00cf66f1e354e12acb2cd908d);
#
#
#             var feature_group_sub_group_1254ca0f5c71005fe27751f5d1212c6b = L.featureGroup.subGroup(
#                 feature_group_fed3e507a2a039cf4198f6926e323f28
#             );
#
#
#             var marker_86cd80bd0f96c98bb2c3639b425c647f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1254ca0f5c71005fe27751f5d1212c6b);
#
#
#         var popup_7f16d05e92756f617fd7fee53dca4742 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c74ad3d4341293c626034364722606b8 = $(`&lt;div id=&quot;html_c74ad3d4341293c626034364722606b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7f16d05e92756f617fd7fee53dca4742.setContent(html_c74ad3d4341293c626034364722606b8);
#
#
#
#         marker_86cd80bd0f96c98bb2c3639b425c647f.bindPopup(popup_7f16d05e92756f617fd7fee53dca4742)
#         ;
#
#
#
#
#             var marker_1a432a2c0f60d3635b7caf72fb9ba3bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1254ca0f5c71005fe27751f5d1212c6b);
#
#
#         var popup_2136bf8926ce45c44a3f601eb3975fd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ab1f732bc063ef8a8e67a5c2f9d2f78 = $(`&lt;div id=&quot;html_8ab1f732bc063ef8a8e67a5c2f9d2f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2136bf8926ce45c44a3f601eb3975fd5.setContent(html_8ab1f732bc063ef8a8e67a5c2f9d2f78);
#
#
#
#         marker_1a432a2c0f60d3635b7caf72fb9ba3bf.bindPopup(popup_2136bf8926ce45c44a3f601eb3975fd5)
#         ;
#
#
#
#
#             var marker_c3b48fdbcaf8169c616de2e666f23c3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1254ca0f5c71005fe27751f5d1212c6b);
#
#
#         var popup_98239d208e92062ca6aabf6740206bb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c30bbb03d05346f0e958a536774a63ea = $(`&lt;div id=&quot;html_c30bbb03d05346f0e958a536774a63ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_98239d208e92062ca6aabf6740206bb8.setContent(html_c30bbb03d05346f0e958a536774a63ea);
#
#
#
#         marker_c3b48fdbcaf8169c616de2e666f23c3e.bindPopup(popup_98239d208e92062ca6aabf6740206bb8)
#         ;
#
#
#
#
#             var marker_f6d0c20f7bf41683c9a24b8f2a090b49 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1254ca0f5c71005fe27751f5d1212c6b);
#
#
#         var popup_ad562febf403bfea3a0969a814d2f85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494db5dfd781f4f9bec3e3d2cd5b8331 = $(`&lt;div id=&quot;html_494db5dfd781f4f9bec3e3d2cd5b8331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ad562febf403bfea3a0969a814d2f85b.setContent(html_494db5dfd781f4f9bec3e3d2cd5b8331);
#
#
#
#         mark
